# %% [markdown]
# # Processing with biomass data of other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/1_Estimation of tree biomass/FULL_DB_BIOMASS_OTHER_ALL_AUTHORS.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#    Groups Species  Species_ID Origin  Origin_ID  SI  A_years   H_m  DBH_cm  \
# 0       1    Pine           0      n        0.0   4       50   9.7    14.6
# 1       1    Pine           0      n        0.0   2       65  20.6    20.6
# 2       1    Pine           0      n        0.0   2       50  13.6    15.4
# 3       1    Pine           0      n        0.0   1       60  23.3    22.2
# 4       1    Pine           0      n        0.0   3       65  15.6    16.4
#
#    N_trees  RS(P)  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  Stem_wood_t_ha  \
# 0    486.0   0.35         9.7      43.9           18.9             NaN
# 1    785.0   0.70        32.2     254.0          113.1             NaN
# 2   1745.0   0.93        35.2     190.0           87.8             NaN
# 3    665.0   0.62        29.6     277.7          106.5             NaN
# 4    955.0   0.59        20.4     142.5           67.0             NaN
#
#    Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha
# 0             NaN         8.4           1.6
# 1             NaN        11.5           4.1
# 2             NaN        13.7           4.1
# 3             NaN        14.4           5.4
# 4             NaN        14.2           3.4

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['Groups','Species_ID','Origin_ID','SI','A_years','H_m','DBH_cm','RS(P)',
                                    'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
                                    'Crown_t_ha','Foliage_t_ha'])
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Groups  Species_ID  Origin_ID  SI  A_years   H_m  DBH_cm  RS(P)  \
# 0       1           0        0.0   4       50   9.7    14.6   0.35
# 1       1           0        0.0   2       65  20.6    20.6   0.70
# 2       1           0        0.0   2       50  13.6    15.4   0.93
# 3       1           0        0.0   1       60  23.3    22.2   0.62
# 4       1           0        0.0   3       65  15.6    16.4   0.59
#
#    BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  \
# 0         9.7      43.9           18.9             NaN             NaN
# 1        32.2     254.0          113.1             NaN             NaN
# 2        35.2     190.0           87.8             NaN             NaN
# 3        29.6     277.7          106.5             NaN             NaN
# 4        20.4     142.5           67.0             NaN             NaN
#
#    Crown_t_ha  Foliage_t_ha
# 0         8.4           1.6
# 1        11.5           4.1
# 2        13.7           4.1
# 3        14.4           5.4
# 4        14.2           3.4

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Groups          857 non-null    int64
#  1   Species_ID      857 non-null    int64
#  2   Origin_ID       856 non-null    float64
#  3   SI              857 non-null    int64
#  4   A_years         857 non-null    int64
#  5   H_m             857 non-null    float64
#  6   DBH_cm          856 non-null    float64
#  7   RS(P)           854 non-null    float64
#  8   BA_sq_m_ha      857 non-null    float64
#  9   GS_cub_m        857 non-null    float64
#  10  ALL_STEM_t_ha   855 non-null    float64
#  11  Stem_wood_t_ha  747 non-null    float64
#  12  Stem_bark_t_ha  747 non-null    float64
#  13  Crown_t_ha      843 non-null    float64
#  14  Foliage_t_ha    854 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 100.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species","Origin"])["BA_sq_m_ha","H_m"].describe()
# Out:
# <ipython-input-5-aaa965077f06>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Species","Origin"])["BA_sq_m_ha","H_m"].describe()
#                BA_sq_m_ha                                                     \
#                     count       mean        std   min     25%    50%     75%
# Species Origin
# Alder   a            11.0  27.854545   7.162173  20.6  22.050  28.70  31.250
#         n           104.0  26.243269   9.595284   7.3  18.400  25.65  34.100
# Aspen   n            66.0  23.056061   8.684011   6.9  16.550  20.65  28.125
# Birch   a            29.0  21.127586   8.611201   4.4  12.900  21.90  24.700
#         n            90.0  17.817778   7.397397   3.8  12.150  18.35  23.050
# Oak     a             4.0  25.325000   8.932105  17.8  18.475  23.35  30.200
#         n            87.0  27.529885  10.769446   1.7  20.350  30.10  36.300
# Pine    a           195.0  30.469231  10.685416   4.7  23.250  31.10  38.200
#         n           263.0  27.171863  10.774800   1.0  20.500  28.90  35.000
# Spruce  n             7.0  25.028571   7.756656  15.5  18.050  26.80  31.350
#
#                         H_m                                                   \
#                  max  count       mean       std   min     25%    50%    75%
# Species Origin
# Alder   a       43.4   11.0  20.236364  4.157950  15.4  16.000  21.00  22.90
#         n       43.0  104.0  17.056731  4.874339   5.2  13.100  17.40  20.50
# Aspen   n       48.9   66.0  15.024242  6.264161   2.7  10.325  15.30  19.30
# Birch   a       46.3   29.0  16.320690  7.002162   3.6   9.900  19.40  21.20
#         n       36.5   90.0  14.726667  5.990551   5.8   9.200  14.25  19.35
# Oak     a       36.8    4.0  19.350000  4.792703  13.6  16.900  19.40  21.85
#         n       48.1   87.0  20.870115  7.211427   5.0  15.800  21.60  26.00
# Pine    a       51.5  195.0  16.259487  7.553524   3.5  10.350  15.10  21.95
#         n       51.1  263.0  15.555513  7.296750   1.5  10.700  15.20  20.10
# Spruce  n       34.1    7.0  19.357143  8.967507   8.8  12.150  19.40  24.90
#
#
#                  max
# Species Origin
# Alder   a       27.3
#         n       27.3
# Aspen   n       26.0
# Birch   a       26.5
#         n       27.5
# Oak     a       25.0
#         n       33.8
# Pine    a       34.2
#         n       38.3
# Spruce  n       33.2

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = ["Foliage_t_ha"], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      Groups  Species_ID  Origin_ID  SI  A_years   H_m  DBH_cm  RS(P)  \
# 0         1           0        0.0   4       50   9.7    14.6   0.35
# 1         1           0        0.0   2       65  20.6    20.6   0.70
# 2         1           0        0.0   2       50  13.6    15.4   0.93
# 3         1           0        0.0   1       60  23.3    22.2   0.62
# 4         1           0        0.0   3       65  15.6    16.4   0.59
# ..      ...         ...        ...  ..      ...   ...     ...    ...
# 852       2           3        0.0   0        8   7.8     4.4   0.71
# 853       2           3        0.0   0       16  12.7     9.0   0.97
# 854       2           3        0.0   0       15  12.2     8.1   0.99
# 855       2           2        0.0   2       21  14.3    12.4   1.08
# 856       2           2        0.0   1       66  21.1    25.6   0.71
#
#      BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  \
# 0           9.7      43.9           18.9             NaN             NaN
# 1          32.2     254.0          113.1             NaN             NaN
# 2          35.2     190.0           87.8             NaN             NaN
# 3          29.6     277.7          106.5             NaN             NaN
# 4          20.4     142.5           67.0             NaN             NaN
# ..          ...       ...            ...             ...             ...
# 852         9.2      39.8           17.8            15.7             2.1
# 853        20.5     123.6           47.1            42.6             4.5
# 854        20.3     141.7           51.9            47.8             4.1
# 855        25.1     176.5          100.7            84.6            16.1
# 856        21.0     191.6           99.9            80.8            19.1
#
#      Crown_t_ha  Foliage_t_ha
# 0          8.40          1.60
# 1         11.50          4.10
# 2         13.70          4.10
# 3         14.40          5.40
# 4         14.20          3.40
# ..          ...           ...
# 852        2.26          2.04
# 853        2.14          1.21
# 854        2.11          1.16
# 855       16.90          4.74
# 856       16.60          2.13
#
# [854 rows x 15 columns]

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#            Groups  Species_ID   Origin_ID          SI     A_years         H_m  \
# count  854.000000  854.000000  853.000000  854.000000  854.000000  854.000000
# mean     1.374707    1.529274    0.277843    0.838407   45.104215   16.458314
# std      0.484331    1.821703    0.448198    1.639096   33.115056    7.035895
# min      1.000000    0.000000    0.000000   -4.000000    2.000000    1.500000
# 25%      1.000000    0.000000    0.000000    0.000000   23.000000   11.200000
# 50%      1.000000    0.000000    0.000000    1.000000   36.000000   16.100000
# 75%      2.000000    3.000000    1.000000    2.000000   58.000000   21.175000
# max      2.000000    5.000000    1.000000    7.000000  250.000000   38.300000
#
#            DBH_cm       RS(P)  BA_sq_m_ha    GS_cub_m  ALL_STEM_t_ha  \
# count  853.000000  851.000000  854.000000  854.000000     853.000000
# mean    17.139742    0.882432   26.331265  229.080796     102.488863
# std     10.440470    0.289568   10.636142  144.350233      68.691198
# min      1.100000    0.180000    1.000000    2.400000       1.800000
# 25%      9.900000    0.710000   19.000000  116.025000      47.500000
# 50%     15.500000    0.860000   26.850000  206.250000      93.500000
# 75%     22.100000    1.000000   34.475000  319.950000     140.500000
# max     94.000000    2.320000   51.500000  735.000000     363.900000
#
#        Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha
# count      745.000000      745.000000  843.000000    854.000000
# mean        92.682819       12.046040   13.821969      4.749356
# std         61.937108        9.587207   11.567546      2.826586
# min          2.000000        0.300000    0.500000      0.200000
# 25%         42.600000        5.900000    6.610000      2.600000
# 50%         84.600000        9.300000   10.820000      4.300000
# 75%        125.500000       15.300000   16.435000      6.367500
# max        315.200000       65.700000   69.120000     21.730000

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['Species_ID','Origin_ID','H_m','DBH_cm','BA_sq_m_ha'])
y = pd.DataFrame(select, columns= ['Foliage_t_ha'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_value = np.random.normal(10, 2, size=count)
    X['Random_col'] = norm_value
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha
# 0           0        0.0   9.7    14.6         9.7
# 1           0        0.0  20.6    20.6        32.2
# 2           0        0.0  13.6    15.4        35.2
# 3           0        0.0  23.3    22.2        29.6
# 4           0        0.0  15.6    16.4        20.4

# %%
# Columns in "y" data collections
y.head()
# Out:
#    Foliage_t_ha
# 0           1.6
# 1           4.1
# 2           4.1
# 3           5.4
# 4           3.4

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=4, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.5858404141113807, 0.40851951127591246, 0.6057905464698671, 0.6559197850915224]
#     Mean: 0.564
#     Std: 0.093
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [2.02066314 1.84057249 1.7442946  1.66483388]
#     Mean: 1.818
#     Std: 0.133
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [1.2098252754122296, 1.239160003862648, 1.2863548115161663, 1.2123401086990822]
#     Mean: 1.237
#     Std: 0.031
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=5000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y, eval_metric="rmse")

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 5000 candidates, totalling 25000 fits
# Model with rank: 1
# Mean validation score: 0.384 (std: 0.222)
# Parameters: {'colsample_bytree': 0.7735899887742076, 'gamma': 0.04912605539468079, 'learning_rate': 0.10427950972801546, 'max_depth': 4, 'n_estimators': 169, 'subsample': 0.9736807477035929}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.75515985, 0.52359014, 0.83525538, ..., 0.51081123, 0.59382567,
#        0.24633751]), 'std_fit_time': array([0.08461606, 0.09377533, 0.10149874, ..., 0.00881464, 0.01169879,
#        0.0012869 ]), 'mean_score_time': array([0.01049733, 0.01240492, 0.01191311, ..., 0.01076856, 0.01088891,
#        0.01064878]), 'std_score_time': array([1.34910791e-04, 3.69891879e-03, 7.27330292e-04, ...,
#        2.00167129e-05, 1.71949661e-04, 1.72746724e-05]), 'param_colsample_bytree': masked_array(data=[0.9336700664688481, 0.294313167671774,
#                    0.2616949113285569, ..., 0.5184636940744072,
#                    0.20097417084722613, 0.053894999453391185],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.4946039586106763, 0.17315940431355503,
#                    0.3286961010969657, ..., 0.0802169785596098,
#                    0.4564170366636023, 0.4824176428081383],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.13544422778825616, 0.236405552644755,
#                    0.2755009378116531, ..., 0.2935923157864648,
#                    0.08140710151364405, 0.10184070559770103],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[3, 3, 3, ..., 2, 2, 2],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[190, 139, 185, ..., 147, 172, 68],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.7357889241660187, 0.797154896368114,
#                    0.47682116100625344, ..., 0.5275443942099625,
#                    0.8661418744495195, 0.6248357864377356],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.9336700664688481, 'gamma': 0.4946039586106763, 'learning_rate': 0.13544422778825616, 'max_depth': 3, 'n_estimators': 190, 'subsample': 0.7357889241660187}, {'colsample_bytree': 0.294313167671774, 'gamma': 0.17315940431355503, 'learning_rate': 0.236405552644755, 'max_depth': 3, 'n_estimators': 139, 'subsample': 0.797154896368114}, {'colsample_bytree': 0.2616949113285569, 'gamma': 0.3286961010969657, 'learning_rate': 0.2755009378116531, 'max_depth': 3, 'n_estimators': 185, 'subsample': 0.47682116100625344}, {'colsample_bytree': 0.1399971730881199, 'gamma': 0.4513896490029161, 'learning_rate': 0.22245787010914045, 'max_depth': 4, 'n_estimators': 193, 'subsample': 0.8097845906386243}, {'colsample_bytree': 0.7658016814959849, 'gamma': 0.3320651226861071, 'learning_rate': 0.1990734443686473, 'max_depth': 2, 'n_estimators': 88, 'subsample': 0.7004439015699646}, {'colsample_bytree': 0.4168015678262728, 'gamma': 0.46512889581521755, 'learning_rate': 0.0174335670102308, 'max_depth': 4, 'n_estimators': 83, 'subsample': 0.9987880892111203}, {'colsample_bytree': 0.20848284844865694, 'gamma': 0.06255320084749394, 'learning_rate': 0.1536376463024491, 'max_depth': 3, 'n_estimators': 183, 'subsample': 0.8139089204481178}, {'colsample_bytree': 0.28151314043014924, 'gamma': 0.4883747946510433, 'learning_rate': 0.21365136624719427, 'max_depth': 3, 'n_estimators': 137, 'subsample': 0.9556643258453967}, {'colsample_bytree': 0.2830055431015429, 'gamma': 0.2119478541922672, 'learning_rate': 0.24899582293276293, 'max_depth': 4, 'n_estimators': 132, 'subsample': 0.48715012874655195}, {'colsample_bytree': 0.9066159285090211, 'gamma': 0.09459578402795654, 'learning_rate': 0.26299640884816405, 'max_depth': 2, 'n_estimators': 170, 'subsample': 0.6152764843454448}, {'colsample_bytree': 0.598311278762972, 'gamma': 0.4728185642096097, 'learning_rate': 0.10199194714359341, 'max_depth': 2, 'n_estimators': 137, 'subsample': 0.5893939011661272}, {'colsample_bytree': 0.4184451078379706, 'gamma': 0.11952674281031972, 'learning_rate': 0.1760358177745379, 'max_depth': 4, 'n_estimators': 191, 'subsample': 0.7789546394435183}, {'colsample_bytree': 0.1785786441033313, 'gamma': 0.1003668758307168, 'learning_rate': 0.26265955401000407, 'max_depth': 2, 'n_estimators': 52, 'subsample': 0.8258609118541653}, {'colsample_bytree': 0.352662227256779, 'gamma': 0.41837869414018247, 'learning_rate': 0.06676201933076098, 'max_depth': 4, 'n_estimators': 176, 'subsample': 0.8843994269103899}, {'colsample_bytree': 0.36738958709279784, 'gamma': 0.16842040716350704, 'learning_rate': 0.19107976739568636, 'max_depth': 4, 'n_estimators': 51, 'subsample': 0.39235775238814713}, {'colsample_bytree': 0.9456259416133526, 'gamma': 0.2941916551058966, 'learning_rate': 0.253613992775527, 'max_depth': 4, 'n_estimators': 137, 'subsample': 0.8223551006282315}, {'colsample_bytree': 0.08499819875001031, 'gamma': 0.30802991965354537, 'learning_rate': 0.2523903574704206, 'max_depth': 2, 'n_estimators': 157, 'subsample': 0.3603539100456977}, {'colsample_bytree': 0.2519226690532766, 'gamma': 0.14903431236698161, 'learning_rate': 0.022343380289673677, 'max_depth': 2, 'n_estimators': 51, 'subsample': 0.7355836766162411}, {'colsample_bytree': 0.30689788499644477, 'gamma': 0.4039746442342279, 'learning_rate': 0.12341976762717934, 'max_depth': 4, 'n_estimators': 155, 'subsample': 0.5281318589377033}, {'colsample_bytree': 0.7495093980354717, 'gamma': 0.11026928579270912, 'learning_rate': 0.12446131705420903, 'max_depth': 4, 'n_estimators': 91, 'subsample': 0.4161854530153932}, {'colsample_bytree': 0.19121544818242897, 'gamma': 0.4925439698413958, 'learning_rate': 0.05534476617358447, 'max_depth': 4, 'n_estimators': 125, 'subsample': 0.5863980833839371}, {'colsample_bytree': 0.19540933001959632, 'gamma': 0.057500828351308486, 'learning_rate': 0.1982189325872966, 'max_depth': 2, 'n_estimators': 58, 'subsample': 0.5769154340230744}, {'colsample_bytree': 0. ...
#        -0.15485148, -0.12854697]), 'split1_test_score': array([0.50416621, 0.43626705, 0.45532511, ..., 0.47537985, 0.38758819,
#        0.35336233]), 'split2_test_score': array([0.22795364, 0.27090377, 0.21079541, ..., 0.2398643 , 0.24735938,
#        0.25288548]), 'split3_test_score': array([0.3246792 , 0.1743046 , 0.20045676, ..., 0.21338308, 0.12848962,
#        0.11232439]), 'split4_test_score': array([0.64063008, 0.6334593 , 0.59648175, ..., 0.55235712, 0.54839469,
#        0.51143273]), 'mean_test_score': array([0.33329251, 0.26564874, 0.25306481, ..., 0.27184156, 0.23139608,
#        0.22029159]), 'std_test_score': array([0.23130471, 0.27472817, 0.27078375, ..., 0.2364284 , 0.23871147,
#        0.21765965]), 'rank_test_score': array([ 669, 3198, 3636, ..., 2967, 4251, 4469], dtype=int32), 'split0_train_score': array([0.85252383, 0.76028252, 0.76843174, ..., 0.74022984, 0.58829405,
#        0.52679054]), 'split1_train_score': array([0.86575685, 0.76881021, 0.7936291 , ..., 0.76809881, 0.61587339,
#        0.54597528]), 'split2_train_score': array([0.89205961, 0.80657867, 0.81123201, ..., 0.7935936 , 0.62910174,
#        0.53792059]), 'split3_train_score': array([0.87934774, 0.80095741, 0.81414227, ..., 0.78147021, 0.64916218,
#        0.57643198]), 'split4_train_score': array([0.85218363, 0.73397378, 0.74551238, ..., 0.73886515, 0.56342339,
#        0.48541817]), 'mean_train_score': array([0.86837433, 0.77412052, 0.7865895 , ..., 0.76445152, 0.60917095,
#        0.53450731]), 'std_train_score': array([0.01550249, 0.02685219, 0.02620304, ..., 0.02187945, 0.0302329 ,
#        0.02956395])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.7735899887742076
# Gamma: 0.04912605539468079
# Learning_rate: 0.10427950972801546
# Max_depth: 4
# N_estimators: 169
# Subsample: 0.9736807477035929

# %% [markdown]
# # Creating a basic XGBoost model

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Generate test and training samples
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Implementation of the scikit-learn API for XGBoost regression
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Show all parameters of XGBoost model
print(xgb_model)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.7735899887742076,
#              enable_categorical=False, eval_metric=['rmse'],
#              gamma=0.04912605539468079, gpu_id=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.10427950972801546,
#              max_delta_step=None, max_depth=4, min_child_weight=None,
#              missing=nan, monotone_constraints=None, n_estimators=169,
#              n_jobs=None, num_parallel_tree=None, predictor=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=0.9736807477035929,
#              tree_method=None, validate_parameters=None, verbosity=None)

# %%
# Fitting the model 
xgb_model.fit(X_train, y_train, early_stopping_rounds=100, eval_set=[(X_train, y_train), (X_test, y_test)])
# learning dynamics
y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:4.75119	validation_1-rmse:4.27034
# [1]	validation_0-rmse:4.38255	validation_1-rmse:3.92842
# [2]	validation_0-rmse:4.07283	validation_1-rmse:3.64533
# [3]	validation_0-rmse:3.77395	validation_1-rmse:3.38073
# [4]	validation_0-rmse:3.50061	validation_1-rmse:3.11347
# [5]	validation_0-rmse:3.25355	validation_1-rmse:2.88341
# [6]	validation_0-rmse:3.04277	validation_1-rmse:2.68180
# [7]	validation_0-rmse:2.86169	validation_1-rmse:2.52924
# [8]	validation_0-rmse:2.72579	validation_1-rmse:2.42046
# [9]	validation_0-rmse:2.59603	validation_1-rmse:2.31295
# [10]	validation_0-rmse:2.49489	validation_1-rmse:2.24167
# [11]	validation_0-rmse:2.38097	validation_1-rmse:2.13575
# [12]	validation_0-rmse:2.27539	validation_1-rmse:2.04793
# [13]	validation_0-rmse:2.18502	validation_1-rmse:1.97068
# [14]	validation_0-rmse:2.10938	validation_1-rmse:1.90901
# [15]	validation_0-rmse:2.04161	validation_1-rmse:1.85547
# [16]	validation_0-rmse:1.99402	validation_1-rmse:1.81793
# [17]	validation_0-rmse:1.94779	validation_1-rmse:1.78136
# [18]	validation_0-rmse:1.89963	validation_1-rmse:1.75778
# [19]	validation_0-rmse:1.85655	validation_1-rmse:1.72841
# [20]	validation_0-rmse:1.81902	validation_1-rmse:1.71333
# [21]	validation_0-rmse:1.78620	validation_1-rmse:1.69518
# [22]	validation_0-rmse:1.76103	validation_1-rmse:1.69015
# [23]	validation_0-rmse:1.73737	validation_1-rmse:1.67437
# [24]	validation_0-rmse:1.71137	validation_1-rmse:1.66356
# [25]	validation_0-rmse:1.69289	validation_1-rmse:1.65474
# [26]	validation_0-rmse:1.67279	validation_1-rmse:1.63958
# [27]	validation_0-rmse:1.65184	validation_1-rmse:1.63017
# [28]	validation_0-rmse:1.64030	validation_1-rmse:1.62272
# [29]	validation_0-rmse:1.62671	validation_1-rmse:1.61960
# [30]	validation_0-rmse:1.61436	validation_1-rmse:1.61154
# [31]	validation_0-rmse:1.59790	validation_1-rmse:1.60424
# [32]	validation_0-rmse:1.58671	validation_1-rmse:1.60100
# [33]	validation_0-rmse:1.58002	validation_1-rmse:1.59669
# [34]	validation_0-rmse:1.56963	validation_1-rmse:1.59828
# [35]	validation_0-rmse:1.55958	validation_1-rmse:1.58682
# [36]	validation_0-rmse:1.55055	validation_1-rmse:1.58581
# [37]	validation_0-rmse:1.53270	validation_1-rmse:1.57559
# [38]	validation_0-rmse:1.52252	validation_1-rmse:1.57600
# [39]	validation_0-rmse:1.51136	validation_1-rmse:1.57534
# [40]	validation_0-rmse:1.50545	validation_1-rmse:1.57405
# [41]	validation_0-rmse:1.49411	validation_1-rmse:1.57112
# [42]	validation_0-rmse:1.48557	validation_1-rmse:1.56871
# [43]	validation_0-rmse:1.47934	validation_1-rmse:1.56457
# [44]	validation_0-rmse:1.47290	validation_1-rmse:1.56464
# [45]	validation_0-rmse:1.47099	validation_1-rmse:1.56400
# [46]	validation_0-rmse:1.46850	validation_1-rmse:1.56403
# [47]	validation_0-rmse:1.46169	validation_1-rmse:1.55951
# [48]	validation_0-rmse:1.45626	validation_1-rmse:1.55786
# [49]	validation_0-rmse:1.45346	validation_1-rmse:1.55625
# [50]	validation_0-rmse:1.45176	validation_1-rmse:1.55664
# [51]	validation_0-rmse:1.45049	validation_1-rmse:1.55661
# [52]	validation_0-rmse:1.44714	validation_1-rmse:1.55536
# [53]	validation_0-rmse:1.44068	validation_1-rmse:1.55452
# [54]	validation_0-rmse:1.43892	validation_1-rmse:1.55493
# [55]	validation_0-rmse:1.43275	validation_1-rmse:1.54981
# [56]	validation_0-rmse:1.42098	validation_1-rmse:1.54376
# [57]	validation_0-rmse:1.41661	validation_1-rmse:1.54376
# [58]	validation_0-rmse:1.41347	validation_1-rmse:1.54191
# [59]	validation_0-rmse:1.40168	validation_1-rmse:1.53689
# [60]	validation_0-rmse:1.39881	validation_1-rmse:1.53611
# [61]	validation_0-rmse:1.39335	validation_1-rmse:1.53299
# [62]	validation_0-rmse:1.38406	validation_1-rmse:1.52921
# [63]	validation_0-rmse:1.37223	validation_1-rmse:1.52588
# [64]	validation_0-rmse:1.36218	validation_1-rmse:1.52632
# [65]	validation_0-rmse:1.35696	validation_1-rmse:1.52423
# [66]	validation_0-rmse:1.35042	validation_1-rmse:1.52136
# [67]	validation_0-rmse:1.34786	validation_1-rmse:1.52202
# [68]	validation_0-rmse:1.34102	validation_1-rmse:1.52121
# [69]	validation_0-rmse:1.33820	validation_1-rmse:1.51724
# [70]	validation_0-rmse:1.33245	validation_1-rmse:1.51396
# [71]	validation_0-rmse:1.32744	validation_1-rmse:1.51196
# [72]	validation_0-rmse:1.32420	validation_1-rmse:1.50997
# [73]	validation_0-rmse:1.31731	validation_1-rmse:1.50902
# [74]	validation_0-rmse:1.30909	validation_1-rmse:1.51043
# [75]	validation_0-rmse:1.30542	validation_1-rmse:1.51050
# [76]	validation_0-rmse:1.30126	validation_1-rmse:1.50889
# [77]	validation_0-rmse:1.29656	validation_1-rmse:1.50536
# [78]	validation_0-rmse:1.29404	validation_1-rmse:1.50612
# [79]	validation_0-rmse:1.28784	validation_1-rmse:1.50444
# [80]	validation_0-rmse:1.28587	validation_1-rmse:1.50394
# [81]	validation_0-rmse:1.28128	validation_1-rmse:1.50148
# [82]	validation_0-rmse:1.27689	validation_1-rmse:1.49957
# [83]	validation_0-rmse:1.27014	validation_1-rmse:1.49746
# [84]	validation_0-rmse:1.26955	validation_1-rmse:1.49710
# [85]	validation_0-rmse:1.26907	validation_1-rmse:1.49676
# [86]	validation_0-rmse:1.26413	validation_1-rmse:1.49515
# [87]	validation_0-rmse:1.26000	validation_1-rmse:1.49632
# [88]	validation_0-rmse:1.25741	validation_1-rmse:1.49678
# [89]	validation_0-rmse:1.25684	validation_1-rmse:1.49677
# [90]	validation_0-rmse:1.25151	validation_1-rmse:1.49333
# [91]	validation_0-rmse:1.24810	validation_1-rmse:1.49463
# [92]	validation_0-rmse:1.24009	validation_1-rmse:1.49365
# [93]	validation_0-rmse:1.23573	validation_1-rmse:1.49325
# [94]	validation_0-rmse:1.23221	validation_1-rmse:1.49302
# [95]	validation_0-rmse:1.22961	validation_1-rmse:1.49105
# [96]	validation_0-rmse:1.22496	validation_1-rmse:1.49063
# [97]	validation_0-rmse:1.21934	validation_1-rmse:1.49200
# [98]	validation_0-rmse:1.21598	validation_1-rmse:1.49197
# [99]	validation_0-rmse:1.20949	validation_1-rmse:1.48871
# [100]	validation_0-rmse:1.20899	validation_1-rmse:1.48870
# [101]	validation_0-rmse:1.20403	validation_1-rmse:1.48915
# [102]	validation_0-rmse:1.20309	validation_1-rmse:1.48907
# [103]	validation_0-rmse:1.19740	validation_1-rmse:1.48924
# [104]	validation_0-rmse:1.19318	validation_1-rmse:1.49005
# [105]	validation_0-rmse:1.18477	validation_1-rmse:1.48777
# [106]	validation_0-rmse:1.17860	validation_1-rmse:1.48834
# [107]	validation_0-rmse:1.17100	validation_1-rmse:1.48867
# [108]	validation_0-rmse:1.16744	validation_1-rmse:1.48988
# [109]	validation_0-rmse:1.16093	validation_1-rmse:1.48928
# [110]	validation_0-rmse:1.15907	validation_1-rmse:1.48901
# [111]	validation_0-rmse:1.15646	validation_1-rmse:1.48906
# [112]	validation_0-rmse:1.15053	validation_1-rmse:1.48256
# [113]	validation_0-rmse:1.14153	validation_1-rmse:1.48301
# [114]	validation_0-rmse:1.13562	validation_1-rmse:1.48366
# [115]	validation_0-rmse:1.12930	validation_1-rmse:1.48533
# [116]	validation_0-rmse:1.12849	validation_1-rmse:1.48604
# [117]	validation_0-rmse:1.12584	validation_1-rmse:1.48803
# [118]	validation_0-rmse:1.12497	validation_1-rmse:1.48751
# [119]	validation_0-rmse:1.12135	validation_1-rmse:1.49015
# [120]	validation_0-rmse:1.11625	validation_1-rmse:1.49012
# [121]	validation_0-rmse:1.11427	validation_1-rmse:1.49003
# [122]	validation_0-rmse:1.11181	validation_1-rmse:1.48768
# [123]	validation_0-rmse:1.10669	validation_1-rmse:1.48545
# [124]	validation_0-rmse:1.10573	validation_1-rmse:1.48493
# [125]	validation_0-rmse:1.09979	validation_1-rmse:1.48079
# [126]	validation_0-rmse:1.09163	validation_1-rmse:1.48197
# [127]	validation_0-rmse:1.08863	validation_1-rmse:1.48290
# [128]	validation_0-rmse:1.08519	validation_1-rmse:1.48351
# [129]	validation_0-rmse:1.07960	validation_1-rmse:1.48071
# [130]	validation_0-rmse:1.07725	validation_1-rmse:1.48112
# [131]	validation_0-rmse:1.07566	validation_1-rmse:1.48133
# [132]	validation_0-rmse:1.07175	validation_1-rmse:1.48046
# [133]	validation_0-rmse:1.06794	validation_1-rmse:1.48121
# [134]	validation_0-rmse:1.06414	validation_1-rmse:1.47968
# [135]	validation_0-rmse:1.05805	validation_1-rmse:1.47759
# [136]	validation_0-rmse:1.05402	validation_1-rmse:1.47731
# [137]	validation_0-rmse:1.05072	validation_1-rmse:1.47345
# [138]	validation_0-rmse:1.04891	validation_1-rmse:1.47304
# [139]	validation_0-rmse:1.04445	validation_1-rmse:1.47057
# [140]	validation_0-rmse:1.04124	validation_1-rmse:1.47232
# [141]	validation_0-rmse:1.03854	validation_1-rmse:1.47370
# [142]	validation_0-rmse:1.03625	validation_1-rmse:1.47512
# [143]	validation_0-rmse:1.03431	validation_1-rmse:1.47550
# [144]	validation_0-rmse:1.02662	validation_1-rmse:1.47710
# [145]	validation_0-rmse:1.02448	validation_1-rmse:1.47768
# [146]	validation_0-rmse:1.01767	validation_1-rmse:1.47424
# [147]	validation_0-rmse:1.01459	validation_1-rmse:1.47401
# [148]	validation_0-rmse:1.01173	validation_1-rmse:1.47237
# [149]	validation_0-rmse:1.00976	validation_1-rmse:1.47372
# [150]	validation_0-rmse:1.00456	validation_1-rmse:1.47169
# [151]	validation_0-rmse:1.00012	validation_1-rmse:1.47093
# [152]	validation_0-rmse:0.99243	validation_1-rmse:1.47077
# [153]	validation_0-rmse:0.98882	validation_1-rmse:1.47166
# [154]	validation_0-rmse:0.98594	validation_1-rmse:1.47238
# [155]	validation_0-rmse:0.98508	validation_1-rmse:1.47253
# [156]	validation_0-rmse:0.98283	validation_1-rmse:1.47136
# [157]	validation_0-rmse:0.97893	validation_1-rmse:1.47074
# [158]	validation_0-rmse:0.97627	validation_1-rmse:1.46923
# [159]	validation_0-rmse:0.97278	validation_1-rmse:1.46923
# [160]	validation_0-rmse:0.96753	validation_1-rmse:1.46938
# [161]	validation_0-rmse:0.96401	validation_1-rmse:1.46787
# [162]	validation_0-rmse:0.95958	validation_1-rmse:1.46711
# [163]	validation_0-rmse:0.95782	validation_1-rmse:1.46389
# [164]	validation_0-rmse:0.95485	validation_1-rmse:1.46016
# [165]	validation_0-rmse:0.95149	validation_1-rmse:1.46067
# [166]	validation_0-rmse:0.94641	validation_1-rmse:1.46025
# [167]	validation_0-rmse:0.94214	validation_1-rmse:1.46520
# [168]	validation_0-rmse:0.94044	validation_1-rmse:1.46330
# /home/dima/anaconda3/lib/python3.8/site-packages/xgboost/core.py:105: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
optimal_n= xgb_model.best_ntree_limit-1
print("The best iteration: " + str(optimal_n))
# Out:
# The best iteration: 164

# %%
# Preparing data for building a learning graph
results = xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(results['validation_0']['rmse'], label='Train')
plt.plot(results['validation_1']['rmse'], label='Test')
plt.axvline(optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a basic XGBoost model

# %%
# Convert data to 'array' type
conv_y_pred = pd.DataFrame(y_pred) # Double transformation
y_pred2 = conv_y_pred.values
y_test2 = y_test.values

# Intermediate results
n_sample = len(y_pred2)
main_sample = y_test.sum() / n_sample

# Calculation of bias
diff = y_pred2 - y_test2
bias = diff.sum()
print('Bias: %.1f' % (bias/n_sample))
print("Relative bias(%):", " %.2f" % (bias/main_sample))

# Calculation of RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %.1f" % (rmse))
print("Relative RMSE(%):", " %.3f" % (rmse/main_sample))

# Calculation of MSE
mse = mean_squared_error(y_test, y_pred)
print("MSE: %.1f" % (mse))

# Calculation of Square R
R_square = r2_score(y_test, y_pred)
print("R square: %.1f%%" % (R_square * 100.0))
# Out:
# Bias: 0.1
# Relative bias(%):  4.68
# RMSE: 1.5
# Relative RMSE(%):  0.334
# MSE: 2.1
# R square: 70.4%

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(y_test)
x_test_convert = np.array([None]*n_sample)
for i in range(n_sample):
    x_test_convert[i] = np.float(x_test_conv[i])

x_plot = x_test_convert
y_plot = y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 1.667
# a1: 0.646
# R^2: 0.712
# Uncertainty
# a0: 1.67+/-0.16
# a1: 0.646+/-0.032

# %%
# Comparison of training and testing prediction values for XGBoost model 
y_pred_train = xgb_model.predict(X_train, ntree_limit=xgb_model.best_ntree_limit)

plt.figure(figsize =(8, 5))
plt.scatter(y_train, y_pred_train, alpha=0.5, label='Training data')
plt.scatter(y_test, y_pred, s = 5, c = "red", label='Validation (test) data')
plt.xlabel('Obs.')
plt.ylabel('Predict')
plt.legend(loc='best')
# Out:
# /home/dima/anaconda3/lib/python3.8/site-packages/xgboost/core.py:105: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(xgb_model,num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, X_train, color=shap_values)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %% [markdown]
# # Testing model on new data

# %%
# Load new data (typing)
sp = input('Typing species name - Pine, Spruce, Birch, Alder, Aspen or Oak:')
if sp == 'Pine':
    sdID = 0
    print ('You typed "Pine".')
elif sp == 'Spruce':
    sdID = 1
    print ('You typed "Spruce".')
elif sp == 'Birch':
    sdID = 2
    print ('You typed "Birch".')
elif sp == 'Alder':
    sdID = 3
    print ('You typed "Alder".')
elif sp == 'Aspen':
    sdID = 4
    print ('You typed "Aspen".')
elif sp == 'Oak':
    sdID = 5
    print ('You typed "Oak".')
elif sp != 'Pine' or 'Spruce' or 'Birch' or 'Alder' or 'Aspen' or 'Oak':
    print ('No correctly specie name!')
else:
    print('\nTyping mistake!!!')

ori = input('Typing origin: n - nutural, a - artificial:')
if ori == 'n':
    orID = 0
    print ('You typed "n".')
elif ori == 'a':
    orID = 1
    print ('You typed "a".')
else:
    print('\nTyping mistake!!!')
    
dbh = float(input('Typing DBH (cm):'))

h = float(input('Typing H (m):'))

ba = float(input('Typing BA(or G) (sq.m/ha):'))

# Create new dataframe
new_data = []
new_data.append([sdID, orID, h, dbh, ba])
new_X = pd.DataFrame(new_data, columns=['Species_ID', 'Origin_ID', 'H_m', 'DBH_cm', 'BA_sq_m_sq_m'])

# Present the result based on the entered data
y_pred_new = xgb_model.predict(new_X)
out0 = str(y_pred_new)
out = out0[1:6]
print('\n', 20*'-', '\n Output result: ' + out)
# Out:
# Typing species name - Pine, Spruce, Birch, Alder, Aspen or Oak: Pine
# You typed "Pine".
# Typing origin: n - nutural, a - artificial: n
# You typed "n".
# Typing DBH (cm): 20
# Typing H (m): 20
# Typing BA(or G) (sq.m/ha): 20
#  --------------------
#  Output result: 4.516

# %% [markdown]
# # Save XGBoost model

# %%
# Save to JSON
xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/1_Estimation of tree biomass/xgb_model_M_foliage.json")
# Save to text format
xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/1_Estimation of tree biomass/xgb_model_M_foliage.txt")
