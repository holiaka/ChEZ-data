# %% [markdown]
# # Processing with biomass data of other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/1_Estimation of tree biomass/FULL_DB_BIOMASS_OTHER_ALL_AUTHORS.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#    Groups Species  Species_ID Origin  Origin_ID  SI  A_years   H_m  DBH_cm  \
# 0       1    Pine           0      n        0.0   4       50   9.7    14.6
# 1       1    Pine           0      n        0.0   2       65  20.6    20.6
# 2       1    Pine           0      n        0.0   2       50  13.6    15.4
# 3       1    Pine           0      n        0.0   1       60  23.3    22.2
# 4       1    Pine           0      n        0.0   3       65  15.6    16.4
#
#    N_trees  RS(P)  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  Stem_wood_t_ha  \
# 0    486.0   0.35         9.7      43.9           18.9             NaN
# 1    785.0   0.70        32.2     254.0          113.1             NaN
# 2   1745.0   0.93        35.2     190.0           87.8             NaN
# 3    665.0   0.62        29.6     277.7          106.5             NaN
# 4    955.0   0.59        20.4     142.5           67.0             NaN
#
#    Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha
# 0             NaN         8.4           1.6
# 1             NaN        11.5           4.1
# 2             NaN        13.7           4.1
# 3             NaN        14.4           5.4
# 4             NaN        14.2           3.4

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['Groups','Species_ID','Origin_ID','SI','A_years','H_m','DBH_cm','RS(P)',
                                    'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
                                    'Crown_t_ha','Foliage_t_ha'])
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Groups  Species_ID  Origin_ID  SI  A_years   H_m  DBH_cm  RS(P)  \
# 0       1           0        0.0   4       50   9.7    14.6   0.35
# 1       1           0        0.0   2       65  20.6    20.6   0.70
# 2       1           0        0.0   2       50  13.6    15.4   0.93
# 3       1           0        0.0   1       60  23.3    22.2   0.62
# 4       1           0        0.0   3       65  15.6    16.4   0.59
#
#    BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  \
# 0         9.7      43.9           18.9             NaN             NaN
# 1        32.2     254.0          113.1             NaN             NaN
# 2        35.2     190.0           87.8             NaN             NaN
# 3        29.6     277.7          106.5             NaN             NaN
# 4        20.4     142.5           67.0             NaN             NaN
#
#    Crown_t_ha  Foliage_t_ha
# 0         8.4           1.6
# 1        11.5           4.1
# 2        13.7           4.1
# 3        14.4           5.4
# 4        14.2           3.4

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Groups          857 non-null    int64
#  1   Species_ID      857 non-null    int64
#  2   Origin_ID       856 non-null    float64
#  3   SI              857 non-null    int64
#  4   A_years         857 non-null    int64
#  5   H_m             857 non-null    float64
#  6   DBH_cm          856 non-null    float64
#  7   RS(P)           854 non-null    float64
#  8   BA_sq_m_ha      857 non-null    float64
#  9   GS_cub_m        857 non-null    float64
#  10  ALL_STEM_t_ha   855 non-null    float64
#  11  Stem_wood_t_ha  747 non-null    float64
#  12  Stem_bark_t_ha  747 non-null    float64
#  13  Crown_t_ha      843 non-null    float64
#  14  Foliage_t_ha    854 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 100.6 KB

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#            Groups  Species_ID   Origin_ID          SI     A_years         H_m  \
# count  857.000000  857.000000  856.000000  857.000000  857.000000  857.000000
# mean     1.374562    1.529755    0.279206    0.838973   45.066511   16.452275
# std      0.484292    1.823872    0.448871    1.639102   33.086498    7.039954
# min      1.000000    0.000000    0.000000   -4.000000    2.000000    1.500000
# 25%      1.000000    0.000000    0.000000    0.000000   23.000000   11.200000
# 50%      1.000000    0.000000    0.000000    1.000000   36.000000   16.100000
# 75%      2.000000    3.000000    1.000000    2.000000   58.000000   21.200000
# max      2.000000    5.000000    1.000000    7.000000  250.000000   38.300000
#
#            DBH_cm       RS(P)  BA_sq_m_ha    GS_cub_m  ALL_STEM_t_ha  \
# count  856.000000  854.000000  857.000000  857.000000     855.000000
# mean    17.132243    0.882728   26.329988  229.013069     102.590877
# std     10.439115    0.289124   10.629993  144.362106      68.758819
# min      1.100000    0.180000    1.000000    2.400000       1.800000
# 25%      9.900000    0.710000   19.000000  116.000000      47.500000
# 50%     15.500000    0.870000   26.800000  206.000000      93.500000
# 75%     22.100000    1.000000   34.500000  320.000000     140.500000
# max     94.000000    2.320000   51.500000  735.000000     363.900000
#
#        Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha
# count      747.000000      747.000000  843.000000    854.000000
# mean        92.779518       12.060107   13.821969      4.749356
# std         61.992238        9.595428   11.567546      2.826586
# min          2.000000        0.300000    0.500000      0.200000
# 25%         42.900000        5.950000    6.610000      2.600000
# 50%         84.600000        9.300000   10.820000      4.300000
# 75%        125.500000       15.300000   16.435000      6.367500
# max        315.200000       65.700000   69.120000     21.730000

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species","Origin"])["BA_sq_m_ha","H_m"].describe()
# Out:
# <ipython-input-6-aaa965077f06>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Species","Origin"])["BA_sq_m_ha","H_m"].describe()
#                BA_sq_m_ha                                                     \
#                     count       mean        std   min     25%    50%     75%
# Species Origin
# Alder   a            11.0  27.854545   7.162173  20.6  22.050  28.70  31.250
#         n           104.0  26.243269   9.595284   7.3  18.400  25.65  34.100
# Aspen   n            66.0  23.056061   8.684011   6.9  16.550  20.65  28.125
# Birch   a            29.0  21.127586   8.611201   4.4  12.900  21.90  24.700
#         n            90.0  17.817778   7.397397   3.8  12.150  18.35  23.050
# Oak     a             4.0  25.325000   8.932105  17.8  18.475  23.35  30.200
#         n            87.0  27.529885  10.769446   1.7  20.350  30.10  36.300
# Pine    a           195.0  30.469231  10.685416   4.7  23.250  31.10  38.200
#         n           263.0  27.171863  10.774800   1.0  20.500  28.90  35.000
# Spruce  n             7.0  25.028571   7.756656  15.5  18.050  26.80  31.350
#
#                         H_m                                                   \
#                  max  count       mean       std   min     25%    50%    75%
# Species Origin
# Alder   a       43.4   11.0  20.236364  4.157950  15.4  16.000  21.00  22.90
#         n       43.0  104.0  17.056731  4.874339   5.2  13.100  17.40  20.50
# Aspen   n       48.9   66.0  15.024242  6.264161   2.7  10.325  15.30  19.30
# Birch   a       46.3   29.0  16.320690  7.002162   3.6   9.900  19.40  21.20
#         n       36.5   90.0  14.726667  5.990551   5.8   9.200  14.25  19.35
# Oak     a       36.8    4.0  19.350000  4.792703  13.6  16.900  19.40  21.85
#         n       48.1   87.0  20.870115  7.211427   5.0  15.800  21.60  26.00
# Pine    a       51.5  195.0  16.259487  7.553524   3.5  10.350  15.10  21.95
#         n       51.1  263.0  15.555513  7.296750   1.5  10.700  15.20  20.10
# Spruce  n       34.1    7.0  19.357143  8.967507   8.8  12.150  19.40  24.90
#
#
#                  max
# Species Origin
# Alder   a       27.3
#         n       27.3
# Aspen   n       26.0
# Birch   a       26.5
#         n       27.5
# Oak     a       25.0
#         n       33.8
# Pine    a       34.2
#         n       38.3
# Spruce  n       33.2

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['Species_ID','Origin_ID','H_m','DBH_cm','BA_sq_m_ha'])
y = pd.DataFrame(select, columns= ['GS_cub_m'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_value = np.random.normal(10, 2, size=count)
    X['Random_col'] = norm_value
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha
# 0           0        0.0   9.7    14.6         9.7
# 1           0        0.0  20.6    20.6        32.2
# 2           0        0.0  13.6    15.4        35.2
# 3           0        0.0  23.3    22.2        29.6
# 4           0        0.0  15.6    16.4        20.4

# %%
# Columns in "y" data collections
y.head()
# Out:
#    GS_cub_m
# 0      43.9
# 1     254.0
# 2     190.0
# 3     277.7
# 4     142.5

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=4, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.9655110224481657, 0.9654243202620074, 0.9792610077409997, 0.9679177363835785]
#     Mean: 0.970
#     Std: 0.006
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [23.72802248 26.18965095 26.49073484 27.38718086]
#     Mean: 25.949
#     Std: 1.356
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [16.34836964185848, 15.995841610988723, 15.817125135047412, 17.241318812325737]
#     Mean: 16.351
#     Std: 0.549
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=1000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y, eval_metric="rmse")

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Model with rank: 1
# Mean validation score: 0.965 (std: 0.014)
# Parameters: {'colsample_bytree': 0.8829191872975016, 'gamma': 0.4317747333990657, 'learning_rate': 0.17029218845451208, 'max_depth': 4, 'n_estimators': 172, 'subsample': 0.894854733579894}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.22344875, 0.42085567, 0.21056023, 0.55320973, 0.34935827,
#        0.26844244, 0.34109573, 0.89748116, 0.82335544, 0.21218877,
#        0.54357891, 0.53752327, 0.31889081, 0.37508941, 0.37068105,
#        0.26932588, 0.57084446, 0.75193038, 0.23078403, 0.6182507 ,
#        0.57771721, 0.66400633, 0.40355725, 0.23113594, 0.21649337,
#        0.52161655, 0.70080752, 0.64729171, 0.28620963, 0.59585366,
#        0.43721514, 0.67113037, 0.44020796, 0.50130186, 0.5232657 ,
#        5.49243447e-03, 4.35884956e-03, 4.44668653e-03, 3.96282744e-03,
#        2.94350003e-03, 2.47661752e-03, 1.81097022e-03, 6.44215703e-04,
#        1.62962168e-03, 2.05453669e-04, 3.91884642e-03, 1.18719176e-03,
#        1.07265017e-04, 1.25568798e-03, 8.98132977e-04, 1.47363617e-02,
#        1.78527693e-03, 4.50034987e-03, 3.04996371e-03, 6.84392485e-03,
#        7.42447893e-04, 1.01330766e-02, 2.86548475e-03, 2.02604884e-03,
#        5.69620596e-04, 1.51922375e-03, 3.54480582e-03, 3.60819631e-03,
#        2.54691495e-04, 5.26559430e-03, 4.47449090e-03, 2.89092689e-03,
#        9.82088297e-04, 2.48049650e-04, 1.13659180e-04, 2.92538819e-03,
#        4.59561453e-03, 4.94032327e-03, 6.83436179e-04, 3.53091130e-03,
#        3.96048262e-03, 5.07650123e-04, 1.39631058e-03, 6.70717189e-04,
#        3.96620994e-03, 1.20452165e-03, 1.38278157e-03, 4.18846618e-03,
#        2.51905765e-03, 5.69276317e-04, 2.69968127e-03, 4.52560040e-03,
#        7.11943868e-04, 1.64812850e-03, 3.23970510e-03, 3.17175284e-04,
#        3.45411618e-03, 1.36496042e-03, 6.02998774e-04, 5.93904726e-03,
#        5.97483123e-04, 7.09441303e-04, 1.67425433e-03, 1.86899683e-03,
#        3.62182944e-03, 3.93059046e-04, 8.10884142e-04, 3.44551770e-03,
#        3.38019729e-03, 3.94144713e-03, 3.09526340e-03, 4.95169040e-03,
#        1.00817833e-03, 2.74339934e-04, 3.87117983e-03, 3.74179807e-03,
#        4.24266958e-04, 1.38161420e-03, 3.22259022e-03, 2.16381020e-04,
#        1.73792047e-03, 3.57433090e-03, 3.75329452e-03, 3.68980482e-03])}

# %%
# Overwrite parameter data for the next step/stage
p1 = 0.8829191872975016     # colsample_bytree 
p2 = 0.4317747333990657    # gamma
p3 = 0.17029218845451208    # learning_rate
p4 = 4                      # max_depth
p5 = 172                    # n_estimators
p6 = 0.894854733579894     # subsample

# %% [markdown]
# # Creating a basic XGBoost model

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Generate test and training samples
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Implementation of the scikit-learn API for XGBoost regression
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Show all parameters of XGBoost model
print(xgb_model)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.8829191872975016,
#              enable_categorical=False, eval_metric=['rmse'],
#              gamma=0.4317747333990657, gpu_id=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.17029218845451208,
#              max_delta_step=None, max_depth=4, min_child_weight=None,
#              missing=nan, monotone_constraints=None, n_estimators=172,
#              n_jobs=None, num_parallel_tree=None, predictor=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=0.894854733579894,
#              tree_method=None, validate_parameters=None, verbosity=None)

# %%
# Fitting the model 
xgb_model.fit(X_train, y_train, early_stopping_rounds=200, eval_set=[(X_train, y_train), (X_test, y_test)])
# learning dynamics
y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:226.55240	validation_1-rmse:226.87639
# [1]	validation_0-rmse:191.17780	validation_1-rmse:191.71603
# [2]	validation_0-rmse:160.61243	validation_1-rmse:162.36932
# [3]	validation_0-rmse:135.06694	validation_1-rmse:137.11574
# [4]	validation_0-rmse:114.20197	validation_1-rmse:117.25774
# [5]	validation_0-rmse:96.61986	validation_1-rmse:100.19186
# [6]	validation_0-rmse:82.09298	validation_1-rmse:86.09354
# [7]	validation_0-rmse:70.04992	validation_1-rmse:73.85141
# [8]	validation_0-rmse:60.56454	validation_1-rmse:64.20415
# [9]	validation_0-rmse:52.53550	validation_1-rmse:56.01915
# [10]	validation_0-rmse:45.68973	validation_1-rmse:49.25982
# [11]	validation_0-rmse:40.28393	validation_1-rmse:44.68633
# [12]	validation_0-rmse:36.15102	validation_1-rmse:41.00310
# [13]	validation_0-rmse:32.64232	validation_1-rmse:37.68291
# [14]	validation_0-rmse:29.70726	validation_1-rmse:34.91063
# [15]	validation_0-rmse:27.42947	validation_1-rmse:32.62579
# [16]	validation_0-rmse:25.73904	validation_1-rmse:31.00951
# [17]	validation_0-rmse:24.21536	validation_1-rmse:29.49888
# [18]	validation_0-rmse:23.14757	validation_1-rmse:28.49903
# [19]	validation_0-rmse:22.21783	validation_1-rmse:27.77625
# [20]	validation_0-rmse:21.42792	validation_1-rmse:27.19833
# [21]	validation_0-rmse:20.82203	validation_1-rmse:26.82798
# [22]	validation_0-rmse:20.16690	validation_1-rmse:26.45505
# [23]	validation_0-rmse:19.72786	validation_1-rmse:26.19692
# [24]	validation_0-rmse:19.29963	validation_1-rmse:25.88193
# [25]	validation_0-rmse:18.95065	validation_1-rmse:25.55253
# [26]	validation_0-rmse:18.75191	validation_1-rmse:25.36426
# [27]	validation_0-rmse:18.46653	validation_1-rmse:25.21862
# [28]	validation_0-rmse:18.00117	validation_1-rmse:24.99579
# [29]	validation_0-rmse:17.74064	validation_1-rmse:24.81965
# [30]	validation_0-rmse:17.59907	validation_1-rmse:24.67586
# [31]	validation_0-rmse:17.25964	validation_1-rmse:24.46199
# [32]	validation_0-rmse:16.93552	validation_1-rmse:24.26537
# [33]	validation_0-rmse:16.73956	validation_1-rmse:24.25436
# [34]	validation_0-rmse:16.57766	validation_1-rmse:24.19889
# [35]	validation_0-rmse:16.51493	validation_1-rmse:24.11764
# [36]	validation_0-rmse:16.31605	validation_1-rmse:23.96869
# [37]	validation_0-rmse:16.07138	validation_1-rmse:23.99366
# [38]	validation_0-rmse:15.85039	validation_1-rmse:24.06137
# [39]	validation_0-rmse:15.67817	validation_1-rmse:24.03672
# [40]	validation_0-rmse:15.52094	validation_1-rmse:23.93727
# [41]	validation_0-rmse:15.40040	validation_1-rmse:23.88767
# [42]	validation_0-rmse:15.28749	validation_1-rmse:23.80664
# [43]	validation_0-rmse:15.15833	validation_1-rmse:23.79989
# [44]	validation_0-rmse:15.00557	validation_1-rmse:23.71192
# [45]	validation_0-rmse:14.78360	validation_1-rmse:23.68444
# [46]	validation_0-rmse:14.60747	validation_1-rmse:23.58057
# [47]	validation_0-rmse:14.51575	validation_1-rmse:23.51350
# [48]	validation_0-rmse:14.40958	validation_1-rmse:23.47699
# [49]	validation_0-rmse:14.21184	validation_1-rmse:23.40669
# [50]	validation_0-rmse:14.09615	validation_1-rmse:23.32938
# [51]	validation_0-rmse:13.93755	validation_1-rmse:23.27857
# [52]	validation_0-rmse:13.85700	validation_1-rmse:23.33561
# [53]	validation_0-rmse:13.71264	validation_1-rmse:23.22704
# [54]	validation_0-rmse:13.61668	validation_1-rmse:23.17197
# [55]	validation_0-rmse:13.51405	validation_1-rmse:23.05838
# [56]	validation_0-rmse:13.34647	validation_1-rmse:23.03545
# [57]	validation_0-rmse:13.23207	validation_1-rmse:22.96007
# [58]	validation_0-rmse:13.11558	validation_1-rmse:22.94734
# [59]	validation_0-rmse:13.07559	validation_1-rmse:22.93477
# [60]	validation_0-rmse:12.93852	validation_1-rmse:22.90398
# [61]	validation_0-rmse:12.92893	validation_1-rmse:22.91143
# [62]	validation_0-rmse:12.83898	validation_1-rmse:22.85186
# [63]	validation_0-rmse:12.73106	validation_1-rmse:22.81781
# [64]	validation_0-rmse:12.67059	validation_1-rmse:22.77296
# [65]	validation_0-rmse:12.59486	validation_1-rmse:22.80512
# [66]	validation_0-rmse:12.54503	validation_1-rmse:22.79180
# [67]	validation_0-rmse:12.50411	validation_1-rmse:22.77005
# [68]	validation_0-rmse:12.46161	validation_1-rmse:22.84440
# [69]	validation_0-rmse:12.33354	validation_1-rmse:22.87271
# [70]	validation_0-rmse:12.23132	validation_1-rmse:22.84652
# [71]	validation_0-rmse:12.15251	validation_1-rmse:22.86075
# [72]	validation_0-rmse:12.00962	validation_1-rmse:22.86440
# [73]	validation_0-rmse:11.93113	validation_1-rmse:22.80709
# [74]	validation_0-rmse:11.82924	validation_1-rmse:22.77199
# [75]	validation_0-rmse:11.76179	validation_1-rmse:22.74262
# [76]	validation_0-rmse:11.73571	validation_1-rmse:22.73088
# [77]	validation_0-rmse:11.71931	validation_1-rmse:22.67725
# [78]	validation_0-rmse:11.61427	validation_1-rmse:22.78841
# [79]	validation_0-rmse:11.55037	validation_1-rmse:22.74210
# [80]	validation_0-rmse:11.51192	validation_1-rmse:22.71509
# [81]	validation_0-rmse:11.39443	validation_1-rmse:22.64605
# [82]	validation_0-rmse:11.28237	validation_1-rmse:22.58268
# [83]	validation_0-rmse:11.18144	validation_1-rmse:22.55862
# [84]	validation_0-rmse:11.08907	validation_1-rmse:22.55253
# [85]	validation_0-rmse:10.98953	validation_1-rmse:22.52852
# [86]	validation_0-rmse:10.96049	validation_1-rmse:22.57068
# [87]	validation_0-rmse:10.93760	validation_1-rmse:22.57411
# [88]	validation_0-rmse:10.91275	validation_1-rmse:22.56344
# [89]	validation_0-rmse:10.81022	validation_1-rmse:22.55540
# [90]	validation_0-rmse:10.72678	validation_1-rmse:22.64714
# [91]	validation_0-rmse:10.65855	validation_1-rmse:22.67399
# [92]	validation_0-rmse:10.55319	validation_1-rmse:22.59001
# [93]	validation_0-rmse:10.47312	validation_1-rmse:22.57168
# [94]	validation_0-rmse:10.45987	validation_1-rmse:22.57372
# [95]	validation_0-rmse:10.41856	validation_1-rmse:22.58515
# [96]	validation_0-rmse:10.33137	validation_1-rmse:22.58056
# [97]	validation_0-rmse:10.23552	validation_1-rmse:22.58156
# [98]	validation_0-rmse:10.17291	validation_1-rmse:22.64050
# [99]	validation_0-rmse:10.07560	validation_1-rmse:22.54791
# [100]	validation_0-rmse:10.03673	validation_1-rmse:22.57639
# [101]	validation_0-rmse:9.96158	validation_1-rmse:22.62107
# [102]	validation_0-rmse:9.91483	validation_1-rmse:22.61697
# [103]	validation_0-rmse:9.83722	validation_1-rmse:22.59833
# [104]	validation_0-rmse:9.78163	validation_1-rmse:22.59520
# [105]	validation_0-rmse:9.73427	validation_1-rmse:22.57624
# [106]	validation_0-rmse:9.69801	validation_1-rmse:22.59513
# [107]	validation_0-rmse:9.59523	validation_1-rmse:22.60161
# [108]	validation_0-rmse:9.54780	validation_1-rmse:22.61366
# [109]	validation_0-rmse:9.50169	validation_1-rmse:22.65933
# [110]	validation_0-rmse:9.43053	validation_1-rmse:22.64808
# [111]	validation_0-rmse:9.36729	validation_1-rmse:22.63065
# [112]	validation_0-rmse:9.35665	validation_1-rmse:22.62629
# [113]	validation_0-rmse:9.28438	validation_1-rmse:22.60044
# [114]	validation_0-rmse:9.19965	validation_1-rmse:22.56902
# [115]	validation_0-rmse:9.12793	validation_1-rmse:22.54388
# [116]	validation_0-rmse:9.11279	validation_1-rmse:22.51059
# [117]	validation_0-rmse:9.07014	validation_1-rmse:22.54595
# [118]	validation_0-rmse:9.02534	validation_1-rmse:22.51727
# [119]	validation_0-rmse:8.98689	validation_1-rmse:22.51406
# [120]	validation_0-rmse:8.92720	validation_1-rmse:22.49576
# [121]	validation_0-rmse:8.86974	validation_1-rmse:22.48446
# [122]	validation_0-rmse:8.84867	validation_1-rmse:22.48229
# [123]	validation_0-rmse:8.78489	validation_1-rmse:22.48130
# [124]	validation_0-rmse:8.72485	validation_1-rmse:22.43960
# [125]	validation_0-rmse:8.70516	validation_1-rmse:22.42955
# [126]	validation_0-rmse:8.68435	validation_1-rmse:22.45949
# [127]	validation_0-rmse:8.67044	validation_1-rmse:22.51298
# [128]	validation_0-rmse:8.63455	validation_1-rmse:22.49628
# [129]	validation_0-rmse:8.57459	validation_1-rmse:22.48352
# [130]	validation_0-rmse:8.55565	validation_1-rmse:22.48123
# [131]	validation_0-rmse:8.53419	validation_1-rmse:22.48121
# [132]	validation_0-rmse:8.41361	validation_1-rmse:22.52559
# [133]	validation_0-rmse:8.36308	validation_1-rmse:22.57125
# [134]	validation_0-rmse:8.28880	validation_1-rmse:22.63183
# [135]	validation_0-rmse:8.23098	validation_1-rmse:22.59549
# [136]	validation_0-rmse:8.18722	validation_1-rmse:22.61264
# [137]	validation_0-rmse:8.13767	validation_1-rmse:22.62320
# [138]	validation_0-rmse:8.09540	validation_1-rmse:22.61240
# [139]	validation_0-rmse:8.04715	validation_1-rmse:22.58347
# [140]	validation_0-rmse:7.97091	validation_1-rmse:22.52877
# [141]	validation_0-rmse:7.92332	validation_1-rmse:22.50310
# [142]	validation_0-rmse:7.87993	validation_1-rmse:22.52099
# [143]	validation_0-rmse:7.83598	validation_1-rmse:22.52017
# [144]	validation_0-rmse:7.80702	validation_1-rmse:22.52339
# [145]	validation_0-rmse:7.77902	validation_1-rmse:22.51922
# [146]	validation_0-rmse:7.74592	validation_1-rmse:22.51392
# [147]	validation_0-rmse:7.70871	validation_1-rmse:22.53921
# [148]	validation_0-rmse:7.66091	validation_1-rmse:22.55294
# [149]	validation_0-rmse:7.63097	validation_1-rmse:22.53781
# [150]	validation_0-rmse:7.62830	validation_1-rmse:22.54116
# [151]	validation_0-rmse:7.57818	validation_1-rmse:22.52105
# [152]	validation_0-rmse:7.54598	validation_1-rmse:22.50109
# [153]	validation_0-rmse:7.50997	validation_1-rmse:22.51569
# [154]	validation_0-rmse:7.44659	validation_1-rmse:22.52262
# [155]	validation_0-rmse:7.38119	validation_1-rmse:22.52346
# [156]	validation_0-rmse:7.33054	validation_1-rmse:22.50605
# [157]	validation_0-rmse:7.28099	validation_1-rmse:22.50595
# [158]	validation_0-rmse:7.23479	validation_1-rmse:22.52610
# [159]	validation_0-rmse:7.22363	validation_1-rmse:22.55871
# [160]	validation_0-rmse:7.20216	validation_1-rmse:22.57745
# [161]	validation_0-rmse:7.14893	validation_1-rmse:22.58763
# [162]	validation_0-rmse:7.11936	validation_1-rmse:22.57228
# [163]	validation_0-rmse:7.09964	validation_1-rmse:22.56850
# [164]	validation_0-rmse:7.03912	validation_1-rmse:22.55338
# [165]	validation_0-rmse:6.98423	validation_1-rmse:22.55532
# [166]	validation_0-rmse:6.95750	validation_1-rmse:22.56468
# [167]	validation_0-rmse:6.93226	validation_1-rmse:22.56953
# [168]	validation_0-rmse:6.92352	validation_1-rmse:22.56897
# [169]	validation_0-rmse:6.89439	validation_1-rmse:22.55789
# [170]	validation_0-rmse:6.87070	validation_1-rmse:22.55499
# [171]	validation_0-rmse:6.82913	validation_1-rmse:22.56241
# /home/dima/anaconda3/lib/python3.8/site-packages/xgboost/core.py:105: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
optimal_n= xgb_model.best_ntree_limit-1
print("The best iteration: " + str(optimal_n))
# Out:
# The best iteration: 125

# %%
# Preparing data for building a learning graph
results = xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(results['validation_0']['rmse'], label='Train')
plt.plot(results['validation_1']['rmse'], label='Test')
plt.axvline(optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a basic XGBoost model

# %% [markdown]
# # Test (validation) observations

# %%
# Convert data to 'array' type
conv_y_pred = pd.DataFrame(y_pred) # Double transformation
y_pred2 = conv_y_pred.values
y_test2 = y_test.values

# Intermediate results
n_sample = len(y_pred2)
main_sample = y_test.sum() / n_sample

# Calculation of bias
diff = y_pred2 - y_test2
bias = diff.sum()
print('Bias: %.1f' % (bias/n_sample))
print("Relative bias(%):", " %.2f" % (bias/main_sample))

# Calculation of RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %.1f" % (rmse))
print("Relative RMSE(%):", " %.3f" % (rmse/main_sample))

# Calculation of MSE
mse = mean_squared_error(y_test, y_pred)
print("MSE: %.1f" % (mse))

# Calculation of Square R
R_square = r2_score(y_test, y_pred)
print("R square: %.1f%%" % (R_square * 100.0))
# Out:
# Bias: 1.0
# Relative bias(%):  0.78
# RMSE: 22.4
# Relative RMSE(%):  0.101
# MSE: 503.1
# R square: 97.8%

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(y_test)
x_test_convert = np.array([None]*n_sample)
for i in range(n_sample):
    x_test_convert[i] = np.float(x_test_conv[i])

x_plot = x_test_convert
y_plot = y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 4.605
# a1: 0.984
# R^2: 0.978
# Uncertainty
# a0: 4.6+/-3.0
# a1: 0.984+/-0.011

# %% [markdown]
# # All observations

# %%
# Comparison of training and testing prediction values for XGBoost model 
y_pred_train = xgb_model.predict(X_train, ntree_limit=xgb_model.best_ntree_limit)

plt.figure(figsize =(8, 5))
plt.scatter(y_train, y_pred_train, alpha=0.5, label='Training data')
plt.scatter(y_test, y_pred, s = 5, c = "red", label='Validation (test) data')
plt.xlabel('Obs.')
plt.ylabel('Predict')
plt.grid(True)
plt.legend(loc='best')
# Out:
# /home/dima/anaconda3/lib/python3.8/site-packages/xgboost/core.py:105: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %% [markdown]
# # Training sample

# %%
# Convert data to 'array' type
conv_y_pred = pd.DataFrame(y_pred_train) # Double transformation
y_pred_train2 = conv_y_pred.values
y_train2 = y_train.values

# Intermediate results
n_sample = len(y_pred_train2)
main_sample = y_train.sum() / n_sample

# Calculation of bias
diff = y_pred_train2 - y_train2
bias = diff.sum()
print('Bias: %.1f' % (bias/n_sample))
print("Relative bias(%):", " %.2f" % (bias/main_sample))

# Calculation of RMSE
rmse = np.sqrt(mean_squared_error(y_train, y_pred_train))
print("RMSE: %.1f" % (rmse))
print("Relative RMSE(%):", " %.3f" % (rmse/main_sample))

# Calculation of MSE
mse = mean_squared_error(y_train, y_pred_train)
print("MSE: %.1f" % (mse))

# Calculation of Square R
R_square = r2_score(y_train, y_pred_train)
print("R square: %.1f%%" % (R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  0.13
# RMSE: 8.7
# Relative RMSE(%):  0.038
# MSE: 75.8
# R square: 99.6%

# %%
# Convert input data
x_train_conv = np.array(y_train)
x_train_convert = np.array([None]*n_sample)
for i in range(n_sample):
    x_train_convert[i] = np.float(x_train_conv[i])

x_plot = x_train_convert
y_plot = y_pred_train
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values (Training sample)', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 1.825
# a1: 0.992
# R^2: 0.996
# Uncertainty
# a0: 1.8+/-0.6
# a1: 0.9923+/-0.0023

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(xgb_model,num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [15, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, X_train, color=shap_values)

# %% [markdown]
# # Testing model on new data

# %%
# Load new data (typing)
sp = input('Typing species name - Pine, Spruce, Birch, Alder, Aspen or Oak:')
if sp == 'Pine':
    sdID = 0
    print ('You typed "Pine".')
elif sp == 'Spruce':
    sdID = 1
    print ('You typed "Spruce".')
elif sp == 'Birch':
    sdID = 2
    print ('You typed "Birch".')
elif sp == 'Alder':
    sdID = 3
    print ('You typed "Alder".')
elif sp == 'Aspen':
    sdID = 4
    print ('You typed "Aspen".')
elif sp == 'Oak':
    sdID = 5
    print ('You typed "Oak".')
elif sp != 'Pine' or 'Spruce' or 'Birch' or 'Alder' or 'Aspen' or 'Oak':
    print ('No correctly specie name!')
else:
    print('\nTyping mistake!!!')

ori = input('Typing origin: n - nutural, a - artificial:')
if ori == 'n':
    orID = 0
    print ('You typed "n".')
elif ori == 'a':
    orID = 1
    print ('You typed "a".')
else:
    print('\nTyping mistake!!!')
    
dbh = float(input('Typing DBH (cm):'))

h = float(input('Typing H (m):'))

ba = float(input('Typing BA(or G) (sq.m/ha):'))

# Create new dataframe
new_data = []
new_data.append([sdID, orID, h, dbh, ba])
new_X = pd.DataFrame(new_data, columns=['Species_ID', 'Origin_ID', 'H_m', 'DBH_cm', 'BA_sq_m_sq_m'])

# Present the result based on the entered data
y_pred_new = xgb_model.predict(new_X)
out0 = str(y_pred_new)
out = out0[1:6]
print('\n', 20*'-', '\n Output result: ' + out)
# Out:
# Typing species name - Pine, Spruce, Birch, Alder, Aspen or Oak: Aspen
# You typed "Aspen".
# Typing origin: n - nutural, a - artificial: n
# You typed "n".
# Typing DBH (cm): 2
# Typing H (m): 2
# Typing BA(or G) (sq.m/ha): 10
#  --------------------
#  Output result: 34.34

# %% [markdown]
# # Save XGBoost model

# %%
# Save to JSON
xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/1_Estimation of tree biomass/xgb_model_GS.json")
# Save to text format
xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/1_Estimation of tree biomass/xgb_model_GS.txt")
