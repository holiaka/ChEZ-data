# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'mf_chm_Q50', 'mf_chm_MIN', 'r_MIN', 'g_MAX', 'contr_b_MAX', 'contr_b_STD'])

# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           2260           1210     -0.731      2.576
# 1       8.189       9.622           2700           1180      0.585      2.915
# 2       8.380       9.589           2500           1400      0.779      2.882
# 3       8.137       9.449           2500           1090      0.517      2.724
# 4       7.696       9.401           2400            720      0.224      2.826
#
#    AEDR_mean  mf_chm_Q50  mf_chm_MIN  r_MIN  g_MAX  contr_b_MAX  contr_b_STD
# 0       2.33   13.747563    0.445070     13    243  2713.600586   332.963753
# 1       2.47   15.015374   12.465903     24    248  1793.493042   293.868420
# 2       2.44   15.384996   13.028298     18    240  1761.097900   272.526176
# 3       2.55   15.447217    2.128231     15    244  2518.435303   299.595643
# 4       2.14   17.947407   12.171553      8    243  2525.819336   327.599176

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   mf_chm_Q50     103 non-null    float64
#  8   mf_chm_MIN     103 non-null    float64
#  9   r_MIN          103 non-null    int64
#  10  g_MAX          103 non-null    int64
#  11  contr_b_MAX    103 non-null    float64
#  12  contr_b_STD    103 non-null    float64
# dtypes: float64(9), int64(4)
# memory usage: 10.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3440.194175    1242.902913   -0.252563
# std       1.64946    1.472424    6087.580089    2037.684800    1.104610
# min       3.52600    6.075000     260.000000      50.000000   -3.033000
# 25%       6.31900    7.664000     635.000000     200.000000   -0.727500
# 50%       6.95700    8.472000    1150.000000     400.000000   -0.025000
# 75%       7.91350    9.421000    2525.000000    1400.000000    0.516500
# max      11.36700   13.864000   35200.000000   10500.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean  mf_chm_Q50  mf_chm_MIN       r_MIN       g_MAX  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     2.464709    3.570291   13.422223    3.368496   11.378641  240.572816
# std      0.904675    6.089170    6.805070    4.845054    9.139568    9.358442
# min      0.391000    0.480000    1.228214   -0.018586    2.000000  194.000000
# 25%      1.803000    0.710000    8.233259    0.482279    5.000000  236.500000
# 50%      2.603000    1.290000   13.787443    0.642883    8.000000  243.000000
# 75%      3.159000    2.960000   17.911694    3.921804   15.000000  247.000000
# max      4.659000   36.590000   29.512907   17.862923   56.000000  253.000000
#
#        contr_b_MAX  contr_b_STD
# count   103.000000   103.000000
# mean   2712.352866   349.854034
# std     864.116297    93.673105
# min     832.155518   109.232976
# 25%    2123.614868   292.544440
# 50%    2601.248047   341.904211
# 75%    3045.944336   427.359073
# max    6252.923340   588.661708

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['mf_chm_Q50', 'mf_chm_MIN', 'r_MIN', 'g_MAX', 'contr_b_MAX', 'contr_b_STD'])
y = pd.DataFrame(select, columns= ['ln_Tag_Sr'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): Yes
# Selected "Yes"!!! A new column with random values was created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    mf_chm_Q50  mf_chm_MIN  r_MIN  g_MAX  contr_b_MAX  contr_b_STD    Random1  \
# 0   13.747563    0.445070     13    243  2713.600586   332.963753  10.906155
# 1   15.015374   12.465903     24    248  1793.493042   293.868420   7.032859
# 2   15.384996   13.028298     18    240  1761.097900   272.526176   9.590015
# 3   15.447217    2.128231     15    244  2518.435303   299.595643  11.294027
# 4   17.947407   12.171553      8    243  2525.819336   327.599176   8.860224
#
#      Random2    Random3    Random4    Random5
# 0   9.375103  13.375596   8.351991  12.135311
# 1  13.731014  10.690100   9.866455   9.537521
# 2   9.919396  10.065863   9.393689  10.287394
# 3  11.002867  14.553810  10.187692  13.500081
# 4   9.481885   7.445320   9.922204   6.983844

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Tag_Sr
# 0      2.576
# 1      2.915
# 2      2.882
# 3      2.724
# 4      2.826

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.4028987865224496, -0.43828701930015956, 0.1448933545008585]
#     Mean: 0.037
#     Std: 0.352
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.86050443 0.98805752 0.63734793]
#     Mean: 0.829
#     Std: 0.145
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.5548318016597202, 0.7602661801786984, 0.7151570831467123]
#     Mean: 0.677
#     Std: 0.088
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=30, cv=7, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 7 folds for each of 30 candidates, totalling 210 fits
# Model with rank: 1
# Mean validation score: -0.129 (std: 0.683)
# Parameters: {'colsample_bytree': 0.13446792977481814, 'gamma': 0.17707587941411868, 'learning_rate': 0.02756232188165314, 'max_depth': 3, 'n_estimators': 127, 'subsample': 0.3783203769344996}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([1.08508485, 0.43748055, 0.44967818, 0.34187409, 0.3482386 ,
#        0.47323963, 0.46483248, 0.4749183 , 0.40808221, 0.37716777,
#        0.33877063, 0.48930502, 0.38769065, 0.2208552 , 0.34667785,
#        0.24885835, 0.33654349, 0.22319548, 0.33134743, 0.17160845,
#        0.47183636, 0.40135462, 0.21660498, 0.73594448, 0.32921413,
#        0.36024673, 0.44883926, 0.36123259, 0.50424801, 0.3184245 ]), 'std_fit_time': array([1.56400946, 0.19953975, 0.09433087, 0.02577433, 0.01328904,
#        0.04225748, 0.0214907 , 0.03595546, 0.02136912, 0.09418937,
#        0.08476555, 0.02303886, 0.02439226, 0.01107332, 0.01526479,
#        0.01121049, 0.0166567 , 0.01169102, 0.03718784, 0.01194949,
#        0.01849121, 0.03691744, 0.01299511, 0.31323677, 0.21747015,
#        0.19435834, 0.14253567, 0.01331743, 0.09133069, 0.03136704]), 'mean_score_time': array([0.00771117, 0.00715998, 0.00767606, 0.00770082, 0.00834843,
#        0.00662463, 0.00640086, 0.00606969, 0.0062433 , 0.00602048,
#        0.00602211, 0.00608785, 0.00668229, 0.00595856, 0.00878678,
#        0.00639806, 0.00643495, 0.00600243, 0.00602535, 0.00602593,
#        0.00620099, 0.00717919, 0.00617787, 0.00657695, 0.00729299,
#        0.00703093, 0.00657293, 0.0065324 , 0.0065874 , 0.00626966]), 'std_score_time': array([2.74748787e-03, 1.98183700e-03, 3.09987382e-03, 2.95178139e-03,
#        3.65442606e-03, 1.25610016e-03, 8.52232209e-04, 6.77492942e-05,
#        3.77667107e-04, 6.42383664e-05, 6.91630956e-05, 1.14949388e-04,
#        1.48218361e-03, 9.19413797e-05, 3.45178579e-03, 7.97262540e-04,
#        1.20629604e-03, 7.22340284e-05, 5.92077431e-05, 6.78880024e-05,
#        3.36675458e-04, 1.73486138e-03, 4.93740996e-04, 9.70432836e-04,
#        2.24284325e-03, 2.45886179e-03, 8.92917921e-04, 1.03174732e-03,
#        8.11676043e-04, 4.67651142e-04]), 'param_colsample_bytree': masked_array(data=[0.13446792977481814, 0.3620383685973573,
#                    0.392432024102782, 0.16515955137909244,
#                    0.4183368145505124, 0.12232047547012324,
#                    0.9347836612141059, 0.945932676990399,
#                    0.19542920193756047, 0.3132458047375874,
#                    0.5471130689249821, 0.1824090842083948,
#                    0.6728926073610378, 0.20134871202312765,
#                    0.5469641327310203, 0.7624658242815584,
#                    0.5973429238029807, 0.7080784628701629,
#                    0.7473353779441128, 0.5358175503391988,
#                    0.2673654872464328, 0.7382164383749684,
#                    0.5557833930763281, 0.6066609519873929,
#                    0.8982619681153008, 0.16366130857037967,
#                    0.5442842449367262, 0.4056908186207044,
#                    0.769182188937421, 0.26893670772798406],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param
#        0.00327263, 0.00117176, 0.00472841, 0.00161935, 0.01105001,
#        0.01710701, 0.00303783, 0.00605716, 0.00345719, 0.00309545])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.13446792977481814
# Gamma: 0.17707587941411868
# Learning_rate: 0.02756232188165314
# Max_depth: 3
# N_estimators: 127
# Subsample: 0.3783203769344996

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(30):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:2.08720	validation_1-rmse:2.18360
# [1]	validation_0-rmse:2.04530	validation_1-rmse:2.14023
# [2]	validation_0-rmse:2.00174	validation_1-rmse:2.09873
# [3]	validation_0-rmse:1.96591	validation_1-rmse:2.06221
# [4]	validation_0-rmse:1.91988	validation_1-rmse:2.01532
# [5]	validation_0-rmse:1.87851	validation_1-rmse:1.97398
# [78]	validation_0-rmse:0.71764	validation_1-rmse:0.74841
# [79]	validation_0-rmse:0.71284	validation_1-rmse:0.74351
# [80]	validation_0-rmse:0.70694	validation_1-rmse:0.74405
# [81]	validation_0-rmse:0.70443	validation_1-rmse:0.73929
# [82]	validation_0-rmse:0.70094	validation_1-rmse:0.74449
# [83]	validation_0-rmse:0.69699	validation_1-rmse:0.74187
# [84]	validation_0-rmse:0.69240	validation_1-rmse:0.73856
# [85]	validation_0-rmse:0.68542	validation_1-rmse:0.74235
# [86]	validation_0-rmse:0.68287	validation_1-rmse:0.74179
# [87]	validation_0-rmse:0.67691	validation_1-rmse:0.74142
# [88]	validation_0-rmse:0.67533	validation_1-rmse:0.74334
# [89]	validation_0-rmse:0.67043	validation_1-rmse:0.74237
# [90]	validation_0-rmse:0.66638	validation_1-rmse:0.74163
# [91]	validation_0-rmse:0.66284	validation_1-rmse:0.74155
# [92]	validation_0-rmse:0.65904	validation_1-rmse:0.74218
# [93]	validation_0-rmse:0.65549	validation_1-rmse:0.73948
# [94]	validation_0-rmse:0.65207	validation_1-rmse:0.73608
# [95]	validation_0-rmse:0.64987	validation_1-rmse:0.74234
# [96]	validation_0-rmse:0.64519	validation_1-rmse:0.73788
# [97]	validation_0-rmse:0.64211	validation_1-rmse:0.73844
# [98]	validation_0-rmse:0.63971	validation_1-rmse:0.73736
# [99]	validation_0-rmse:0.63713	validation_1-rmse:0.73604
# [100]	validation_0-rmse:0.63417	validation_1-rmse:0.73544
# [101]	validation_0-rmse:0.63271	validation_1-rmse:0.73728
# [102]	validation_0-rmse:0.63058	validation_1-rmse:0.73863
# [103]	validation_0-rmse:0.62759	validation_1-rmse:0.74019
# [104]	validation_0-rmse:0.62511	validation_1-rmse:0.74041
# [105]	validation_0-rmse:0.62254	validation_1-rmse:0.74242
# [106]	validation_0-rmse:0.62100	validation_1-rmse:0.74259
# [107]	validation_0-rmse:0.61708	validation_1-rmse:0.74336
# [108]	validation_0-rmse:0.61525	validation_1-rmse:0.74461
# [109]	validation_0-rmse:0.61200	validation_1-rmse:0.74640
# [110]	validation_0-rmse:0.60872	validation_1-rmse:0.74421
# [111]	validation_0-rmse:0.60639	validation_1-rmse:0.74392
# [112]	validation_0-rmse:0.60251	validation_1-rmse:0.74587
# [113]	validation_0-rmse:0.59921	validation_1-rmse:0.74500
# [114]	validation_0-rmse:0.59664	validation_1-rmse:0.74471
# [115]	validation_0-rmse:0.59355	validation_1-rmse:0.74214
# [116]	validation_0-rmse:0.59019	validation_1-rmse:0.74525
# [117]	validation_0-rmse:0.58815	validation_1-rmse:0.74164
# [118]	validation_0-rmse:0.58487	validation_1-rmse:0.73984
# [119]	validation_0-rmse:0.58347	validation_1-rmse:0.73932
# [120]	validation_0-rmse:0.57899	validation_1-rmse:0.73991
# [0]	validation_0-rmse:2.05453	validation_1-rmse:2.32829
# [1]	validation_0-rmse:2.01706	validation_1-rmse:2.28796
# [2]	validation_0-rmse:1.97458	validation_1-rmse:2.24285
# [3]	validation_0-rmse:1.93064	validation_1-rmse:2.19602
# [76]	validation_0-rmse:0.73492	validation_1-rmse:0.79634
# [77]	validation_0-rmse:0.73172	validation_1-rmse:0.79745
# [78]	validation_0-rmse:0.72906	validation_1-rmse:0.79259
# [79]	validation_0-rmse:0.72648	validation_1-rmse:0.78973
# [80]	validation_0-rmse:0.72121	validation_1-rmse:0.78877
# [81]	validation_0-rmse:0.71626	validation_1-rmse:0.78243
# [82]	validation_0-rmse:0.71181	validation_1-rmse:0.78206
# [83]	validation_0-rmse:0.70757	validation_1-rmse:0.78141
# [84]	validation_0-rmse:0.70536	validation_1-rmse:0.78109
# [85]	validation_0-rmse:0.70118	validation_1-rmse:0.77653
# [86]	validation_0-rmse:0.69810	validation_1-rmse:0.77441
# [87]	validation_0-rmse:0.69196	validation_1-rmse:0.76945
# [88]	validation_0-rmse:0.68901	validation_1-rmse:0.76957
# [89]	validation_0-rmse:0.68366	validation_1-rmse:0.76918
# [90]	validation_0-rmse:0.67880	validation_1-rmse:0.76530
# [91]	validation_0-rmse:0.67483	validation_1-rmse:0.76486
# [92]	validation_0-rmse:0.67093	validation_1-rmse:0.76155
# [93]	validation_0-rmse:0.66815	validation_1-rmse:0.76215
# [94]	validation_0-rmse:0.66528	validation_1-rmse:0.76172
# [95]	validation_0-rmse:0.66253	validation_1-rmse:0.75813
# [96]	validation_0-rmse:0.65928	validation_1-rmse:0.75462
# [97]	validation_0-rmse:0.65724	validation_1-rmse:0.75345
# [98]	validation_0-rmse:0.65644	validation_1-rmse:0.75340
# [99]	validation_0-rmse:0.65329	validation_1-rmse:0.75199
# [100]	validation_0-rmse:0.64889	validation_1-rmse:0.74943
# [101]	validation_0-rmse:0.64666	validation_1-rmse:0.74951
# [102]	validation_0-rmse:0.64604	validation_1-rmse:0.74717
# [103]	validation_0-rmse:0.64380	validation_1-rmse:0.74662
# [104]	validation_0-rmse:0.64264	validation_1-rmse:0.74433
# [105]	validation_0-rmse:0.64267	validation_1-rmse:0.74537
# [106]	validation_0-rmse:0.63969	validation_1-rmse:0.74415
# [107]	validation_0-rmse:0.63595	validation_1-rmse:0.74316
# [108]	validation_0-rmse:0.63472	validation_1-rmse:0.74282
# [109]	validation_0-rmse:0.63307	validation_1-rmse:0.74065
# [110]	validation_0-rmse:0.62977	validation_1-rmse:0.73975
# [111]	validation_0-rmse:0.62744	validation_1-rmse:0.73902
# [112]	validation_0-rmse:0.62600	validation_1-rmse:0.73859
# [113]	validation_0-rmse:0.62507	validation_1-rmse:0.73863
# [114]	validation_0-rmse:0.62124	validation_1-rmse:0.74064
# [115]	validation_0-rmse:0.61921	validation_1-rmse:0.73946
# [116]	validation_0-rmse:0.61714	validation_1-rmse:0.73978
# [117]	validation_0-rmse:0.61660	validation_1-rmse:0.74122
# [118]	validation_0-rmse:0.61584	validation_1-rmse:0.73904
# [119]	validation_0-rmse:0.61245	validation_1-rmse:0.74005
# [120]	validation_0-rmse:0.60865	validation_1-rmse:0.74170
# [121]	validation_0-rmse:0.60751	validation_1-rmse:0.73714
# [42]	validation_0-rmse:1.04573	validation_1-rmse:0.84048
# [43]	validation_0-rmse:1.03362	validation_1-rmse:0.83324
# [44]	validation_0-rmse:1.01891	validation_1-rmse:0.81919
# [45]	validation_0-rmse:1.00433	validation_1-rmse:0.80248
# [46]	validation_0-rmse:0.99026	validation_1-rmse:0.79424
# [47]	validation_0-rmse:0.97822	validation_1-rmse:0.78421
# [48]	validation_0-rmse:0.96508	validation_1-rmse:0.77337
# [49]	validation_0-rmse:0.95542	validation_1-rmse:0.76469
# [50]	validation_0-rmse:0.94328	validation_1-rmse:0.75368
# [51]	validation_0-rmse:0.93436	validation_1-rmse:0.74906
# [52]	validation_0-rmse:0.92566	validation_1-rmse:0.74000
# [53]	validation_0-rmse:0.91257	validation_1-rmse:0.72976
# [54]	validation_0-rmse:0.90333	validation_1-rmse:0.71645
# [55]	validation_0-rmse:0.89332	validation_1-rmse:0.70693
# [56]	validation_0-rmse:0.88503	validation_1-rmse:0.69823
# [57]	validation_0-rmse:0.87620	validation_1-rmse:0.68975
# [58]	validation_0-rmse:0.86629	validation_1-rmse:0.68553
# [59]	validation_0-rmse:0.85834	validation_1-rmse:0.68063
# [60]	validation_0-rmse:0.85130	validation_1-rmse:0.67573
# [61]	validation_0-rmse:0.84693	validation_1-rmse:0.67207
# [62]	validation_0-rmse:0.83816	validation_1-rmse:0.66757
# [63]	validation_0-rmse:0.82969	validation_1-rmse:0.66696
# [64]	validation_0-rmse:0.82022	validation_1-rmse:0.65796
# [65]	validation_0-rmse:0.81528	validation_1-rmse:0.65954
# [66]	validation_0-rmse:0.80904	validation_1-rmse:0.65812
# [67]	validation_0-rmse:0.80412	validation_1-rmse:0.65901
# [68]	validation_0-rmse:0.80028	validation_1-rmse:0.65895
# [69]	validation_0-rmse:0.79360	validation_1-rmse:0.65630
# [70]	validation_0-rmse:0.78702	validation_1-rmse:0.65080
# [71]	validation_0-rmse:0.77977	validation_1-rmse:0.65080
# [72]	validation_0-rmse:0.77274	validation_1-rmse:0.64750
# [73]	validation_0-rmse:0.76536	validation_1-rmse:0.64394
# [74]	validation_0-rmse:0.76027	validation_1-rmse:0.64327
# [75]	validation_0-rmse:0.75544	validation_1-rmse:0.64124
# [76]	validation_0-rmse:0.75145	validation_1-rmse:0.63698
# [77]	validation_0-rmse:0.74664	validation_1-rmse:0.63419
# [78]	validation_0-rmse:0.74215	validation_1-rmse:0.63025
# [79]	validation_0-rmse:0.73699	validation_1-rmse:0.62452
# [80]	validation_0-rmse:0.73334	validation_1-rmse:0.62097
# [81]	validation_0-rmse:0.73018	validation_1-rmse:0.62043
# [82]	validation_0-rmse:0.72719	validation_1-rmse:0.61868
# [83]	validation_0-rmse:0.72408	validation_1-rmse:0.61690
# ...
# [102]	validation_0-rmse:0.64504	validation_1-rmse:0.70498
# [103]	validation_0-rmse:0.64166	validation_1-rmse:0.70105
# [104]	validation_0-rmse:0.63959	validation_1-rmse:0.70288
# [105]	validation_0-rmse:0.63664	validation_1-rmse:0.70033
# [106]	validation_0-rmse:0.63488	validation_1-rmse:0.69872
# [107]	validation_0-rmse:0.63269	validation_1-rmse:0.69694
# [108]	validation_0-rmse:0.63065	validation_1-rmse:0.69450
# [109]	validation_0-rmse:0.62809	validation_1-rmse:0.69163
# [110]	validation_0-rmse:0.62529	validation_1-rmse:0.69191
# [111]	validation_0-rmse:0.62284	validation_1-rmse:0.69024
# [112]	validation_0-rmse:0.62012	validation_1-rmse:0.68995
# [113]	validation_0-rmse:0.61823	validation_1-rmse:0.68805
# [114]	validation_0-rmse:0.61479	validation_1-rmse:0.68694
# [115]	validation_0-rmse:0.61253	validation_1-rmse:0.68508
# [116]	validation_0-rmse:0.60880	validation_1-rmse:0.68438
# [117]	validation_0-rmse:0.60695	validation_1-rmse:0.68395
# [118]	validation_0-rmse:0.60589	validation_1-rmse:0.68271
# [119]	validation_0-rmse:0.60340	validation_1-rmse:0.68205
# [120]	validation_0-rmse:0.60115	validation_1-rmse:0.68474
# [121]	validation_0-rmse:0.59862	validation_1-rmse:0.68809
# [122]	validation_0-rmse:0.59835	validation_1-rmse:0.68756
# [123]	validation_0-rmse:0.59779	validation_1-rmse:0.69020
# [124]	validation_0-rmse:0.59638	validation_1-rmse:0.68992
# [125]	validation_0-rmse:0.59465	validation_1-rmse:0.68740
# [126]	validation_0-rmse:0.59245	validation_1-rmse:0.68577
# [0]	validation_0-rmse:2.10314	validation_1-rmse:2.15421
# [1]	validation_0-rmse:2.05816	validation_1-rmse:2.10792
# [2]	validation_0-rmse:2.01618	validation_1-rmse:2.06759
# [3]	validation_0-rmse:1.97281	validation_1-rmse:2.02198
# [4]	validation_0-rmse:1.92650	validation_1-rmse:1.97454
# [5]	validation_0-rmse:1.88644	validation_1-rmse:1.93463
# [6]	validation_0-rmse:1.84496	validation_1-rmse:1.89432
# [7]	validation_0-rmse:1.81190	validation_1-rmse:1.85736
# [8]	validation_0-rmse:1.77740	validation_1-rmse:1.82144
# [9]	validation_0-rmse:1.74472	validation_1-rmse:1.78785
# [10]	validation_0-rmse:1.70427	validation_1-rmse:1.73986
# [11]	validation_0-rmse:1.67437	validation_1-rmse:1.71066
# [12]	validation_0-rmse:1.63691	validation_1-rmse:1.67425
# [13]	validation_0-rmse:1.60354	validation_1-rmse:1.63812
# [14]	validation_0-rmse:1.56897	validation_1-rmse:1.60255
# [15]	validation_0-rmse:1.53941	validation_1-rmse:1.57205
# [16]	validation_0-rmse:1.50753	validation_1-rmse:1.54122
# [17]	validation_0-rmse:1.48108	validation_1-rmse:1.51363
# [18]	validation_0-rmse:1.45231	validation_1-rmse:1.48379
# [19]	validation_0-rmse:1.42574	validation_1-rmse:1.46077
# [20]	validation_0-rmse:1.40289	validation_1-rmse:1.43712
# [21]	validation_0-rmse:1.37490	validation_1-rmse:1.41353
# [22]	validation_0-rmse:1.35284	validation_1-rmse:1.39086
# [23]	validation_0-rmse:1.32653	validation_1-rmse:1.36317
# [24]	validation_0-rmse:1.30191	validation_1-rmse:1.33904
# [25]	validation_0-rmse:1.28113	validation_1-rmse:1.31612
# [26]	validation_0-rmse:1.26162	validation_1-rmse:1.29748
# [27]	validation_0-rmse:1.24456	validation_1-rmse:1.28458
# [28]	validation_0-rmse:1.22224	validation_1-rmse:1.25980
# [29]	validation_0-rmse:1.19888	validation_1-rmse:1.23550
# [30]	validation_0-rmse:1.17739	validation_1-rmse:1.21523
# [31]	validation_0-rmse:1.15824	validation_1-rmse:1.19371
# [32]	validation_0-rmse:1.14086	validation_1-rmse:1.17273
# [33]	validation_0-rmse:1.12656	validation_1-rmse:1.15817
# [34]	validation_0-rmse:1.11101	validation_1-rmse:1.14328
# [35]	validation_0-rmse:1.09514	validation_1-rmse:1.12736
# [36]	validation_0-rmse:1.07993	validation_1-rmse:1.11149
# [37]	validation_0-rmse:1.06679	validation_1-rmse:1.09903
# [38]	validation_0-rmse:1.05533	validation_1-rmse:1.08683
# [39]	validation_0-rmse:1.03934	validation_1-rmse:1.07009
# [40]	validation_0-rmse:1.02864	validation_1-rmse:1.06243
# [41]	validation_0-rmse:1.01590	validation_1-rmse:1.04998
# [42]	validation_0-rmse:1.00170	validation_1-rmse:1.03466
# [43]	validation_0-rmse:0.98525	validation_1-rmse:1.01934
# [44]	validation_0-rmse:0.96971	validation_1-rmse:1.00185
# [45]	validation_0-rmse:0.95964	validation_1-rmse:0.98953
# [46]	validation_0-rmse:0.95033	validation_1-rmse:0.98159
# [47]	validation_0-rmse:0.94066	validation_1-rmse:0.97349
# [48]	validation_0-rmse:0.92914	validation_1-rmse:0.95961
# [49]	validation_0-rmse:0.91761	validation_1-rmse:0.95051
# [50]	validation_0-rmse:0.90449	validation_1-rmse:0.93805
# [51]	validation_0-rmse:0.89393	validation_1-rmse:0.92822
# [52]	validation_0-rmse:0.88338	validation_1-rmse:0.91786
# [53]	validation_0-rmse:0.87289	validation_1-rmse:0.90540
# [54]	validation_0-rmse:0.86445	validation_1-rmse:0.89496
# [55]	validation_0-rmse:0.85596	validation_1-rmse:0.88946
# [56]	validation_0-rmse:0.84501	validation_1-rmse:0.87635
# [57]	validation_0-rmse:0.83694	validation_1-rmse:0.86918
# [58]	validation_0-rmse:0.83199	validation_1-rmse:0.86212
# [59]	validation_0-rmse:0.82439	validation_1-rmse:0.85339
# [60]	validation_0-rmse:0.81705	validation_1-rmse:0.84543
# [61]	validation_0-rmse:0.81399	validation_1-rmse:0.84843
# [62]	validation_0-rmse:0.80583	validation_1-rmse:0.84197
# [63]	validation_0-rmse:0.80045	validation_1-rmse:0.83884
# [64]	validation_0-rmse:0.79231	validation_1-rmse:0.82849
# [65]	validation_0-rmse:0.78867	validation_1-rmse:0.82267
# [66]	validation_0-rmse:0.78160	validation_1-rmse:0.81359
# [67]	validation_0-rmse:0.77658	validation_1-rmse:0.80674
# [68]	validation_0-rmse:0.77289	validation_1-rmse:0.80257
# [69]	validation_0-rmse:0.76868	validation_1-rmse:0.79584
# [70]	validation_0-rmse:0.76151	validation_1-rmse:0.78745
# [71]	validation_0-rmse:0.75607	validation_1-rmse:0.78169
# [72]	validation_0-rmse:0.75165	validation_1-rmse:0.78001
# [73]	validation_0-rmse:0.74552	validation_1-rmse:0.77300
# [74]	validation_0-rmse:0.74215	validation_1-rmse:0.76782
# [75]	validation_0-rmse:0.73720	validation_1-rmse:0.76301
# [76]	validation_0-rmse:0.73673	validation_1-rmse:0.76457
# [77]	validation_0-rmse:0.73283	validation_1-rmse:0.75893
# [78]	validation_0-rmse:0.72786	validation_1-rmse:0.75474
# [79]	validation_0-rmse:0.72464	validation_1-rmse:0.75215
# [80]	validation_0-rmse:0.72094	validation_1-rmse:0.75123
# [81]	validation_0-rmse:0.71772	validation_1-rmse:0.74647
# [82]	validation_0-rmse:0.71549	validation_1-rmse:0.74648
# [83]	validation_0-rmse:0.71046	validation_1-rmse:0.74594
# [84]	validation_0-rmse:0.70491	validation_1-rmse:0.74243
# [85]	validation_0-rmse:0.70095	validation_1-rmse:0.73834
# [86]	validation_0-rmse:0.69670	validation_1-rmse:0.73514
# [87]	validation_0-rmse:0.69080	validation_1-rmse:0.72734
# [88]	validation_0-rmse:0.68684	validation_1-rmse:0.72336
# [89]	validation_0-rmse:0.68340	validation_1-rmse:0.72061
# [90]	validation_0-rmse:0.67891	validation_1-rmse:0.71649
# [91]	validation_0-rmse:0.67518	validation_1-rmse:0.71108
# [92]	validation_0-rmse:0.67120	validation_1-rmse:0.70530
# [93]	validation_0-rmse:0.66744	validation_1-rmse:0.70351
# [94]	validation_0-rmse:0.66526	validation_1-rmse:0.70177
# [95]	validation_0-rmse:0.66503	validation_1-rmse:0.70324
# [96]	validation_0-rmse:0.66231	validation_1-rmse:0.70098
# [97]	validation_0-rmse:0.65846	validation_1-rmse:0.69828
# [98]	validation_0-rmse:0.65539	validation_1-rmse:0.69679
# [99]	validation_0-rmse:0.65148	validation_1-rmse:0.69402
# [100]	validation_0-rmse:0.64760	validation_1-rmse:0.69023
# [101]	validation_0-rmse:0.64423	validation_1-rmse:0.68575
# [102]	validation_0-rmse:0.64339	validation_1-rmse:0.68624
# [103]	validation_0-rmse:0.64179	validation_1-rmse:0.68318
# [104]	validation_0-rmse:0.63929	validation_1-rmse:0.68412
# [105]	validation_0-rmse:0.63665	validation_1-rmse:0.68340
# [106]	validation_0-rmse:0.63535	validation_1-rmse:0.68273
# [107]	validation_0-rmse:0.63216	validation_1-rmse:0.67869
# [108]	validation_0-rmse:0.63063	validation_1-rmse:0.67729
# [109]	validation_0-rmse:0.62974	validation_1-rmse:0.67729
# [110]	validation_0-rmse:0.62741	validation_1-rmse:0.67560
# [111]	validation_0-rmse:0.62478	validation_1-rmse:0.67449
# [112]	validation_0-rmse:0.62185	validation_1-rmse:0.67395
# [113]	validation_0-rmse:0.61912	validation_1-rmse:0.66991
# [114]	validation_0-rmse:0.61612	validation_1-rmse:0.66690
# [115]	validation_0-rmse:0.61517	validation_1-rmse:0.66557
# [116]	validation_0-rmse:0.61331	validation_1-rmse:0.66548
# [117]	validation_0-rmse:0.61175	validation_1-rmse:0.66355
# [118]	validation_0-rmse:0.60931	validation_1-rmse:0.66349
# [39]	validation_0-rmse:1.05625	validation_1-rmse:1.09322
# [40]	validation_0-rmse:1.04234	validation_1-rmse:1.08104
# [41]	validation_0-rmse:1.02767	validation_1-rmse:1.07101
# [42]	validation_0-rmse:1.01114	validation_1-rmse:1.05975
# [43]	validation_0-rmse:1.00215	validation_1-rmse:1.05036
# [44]	validation_0-rmse:0.98783	validation_1-rmse:1.03832
# [45]	validation_0-rmse:0.97639	validation_1-rmse:1.02816
# [46]	validation_0-rmse:0.96545	validation_1-rmse:1.01808
# [47]	validation_0-rmse:0.95390	validation_1-rmse:1.00744
# [48]	validation_0-rmse:0.94129	validation_1-rmse:0.99883
# [49]	validation_0-rmse:0.92777	validation_1-rmse:0.98650
# [50]	validation_0-rmse:0.91929	validation_1-rmse:0.97948
# [51]	validation_0-rmse:0.90873	validation_1-rmse:0.97423
# [52]	validation_0-rmse:0.89891	validation_1-rmse:0.96860
# [53]	validation_0-rmse:0.88913	validation_1-rmse:0.96129
# [54]	validation_0-rmse:0.88038	validation_1-rmse:0.95517
# [55]	validation_0-rmse:0.87143	validation_1-rmse:0.94666
# [56]	validation_0-rmse:0.85869	validation_1-rmse:0.93802
# [57]	validation_0-rmse:0.84806	validation_1-rmse:0.93025
# [58]	validation_0-rmse:0.84104	validation_1-rmse:0.93192
# [59]	validation_0-rmse:0.83296	validation_1-rmse:0.93153
# [60]	validation_0-rmse:0.82644	validation_1-rmse:0.92571
# [61]	validation_0-rmse:0.81930	validation_1-rmse:0.92110
# [62]	validation_0-rmse:0.80917	validation_1-rmse:0.92288
# [63]	validation_0-rmse:0.80264	validation_1-rmse:0.92017
# [64]	validation_0-rmse:0.79354	validation_1-rmse:0.91229
# [65]	validation_0-rmse:0.78523	validation_1-rmse:0.90719
# [66]	validation_0-rmse:0.78024	validation_1-rmse:0.90479
# [67]	validation_0-rmse:0.77485	validation_1-rmse:0.90177
# [68]	validation_0-rmse:0.77038	validation_1-rmse:0.89854
# [69]	validation_0-rmse:0.76420	validation_1-rmse:0.89205
# [70]	validation_0-rmse:0.75925	validation_1-rmse:0.88746
# [71]	validation_0-rmse:0.75464	validation_1-rmse:0.88510
# [72]	validation_0-rmse:0.74716	validation_1-rmse:0.88144
# [73]	validation_0-rmse:0.73957	validation_1-rmse:0.87767
# [74]	validation_0-rmse:0.73346	validation_1-rmse:0.87372
# [75]	validation_0-rmse:0.72402	validation_1-rmse:0.86592
# [76]	validation_0-rmse:0.72087	validation_1-rmse:0.86537
# [77]	validation_0-rmse:0.71558	validation_1-rmse:0.86286
# [78]	validation_0-rmse:0.70973	validation_1-rmse:0.86542
# [79]	validation_0-rmse:0.70305	validation_1-rmse:0.86368
# [80]	validation_0-rmse:0.69863	validation_1-rmse:0.86356
# [81]	validation_0-rmse:0.69541	validation_1-rmse:0.86162
# [82]	validation_0-rmse:0.69020	validation_1-rmse:0.86166
# [83]	validation_0-rmse:0.68540	validation_1-rmse:0.86007
# [84]	validation_0-rmse:0.67966	validation_1-rmse:0.86016
# [85]	validation_0-rmse:0.67390	validation_1-rmse:0.85678
# [86]	validation_0-rmse:0.66977	validation_1-rmse:0.85441
# [87]	validation_0-rmse:0.66631	validation_1-rmse:0.85053
# [88]	validation_0-rmse:0.66115	validation_1-rmse:0.85232
# [89]	validation_0-rmse:0.65671	validation_1-rmse:0.84905
# [90]	validation_0-rmse:0.65389	validation_1-rmse:0.84748
# [91]	validation_0-rmse:0.65188	validation_1-rmse:0.84882
# [92]	validation_0-rmse:0.64829	validation_1-rmse:0.84457
# [93]	validation_0-rmse:0.64478	validation_1-rmse:0.84290
# [94]	validation_0-rmse:0.64003	validation_1-rmse:0.84356
# [95]	validation_0-rmse:0.63791	validation_1-rmse:0.84152
# [96]	validation_0-rmse:0.63445	validation_1-rmse:0.83880
# [97]	validation_0-rmse:0.63180	validation_1-rmse:0.84034
# [98]	validation_0-rmse:0.62978	validation_1-rmse:0.83984
# [99]	validation_0-rmse:0.62737	validation_1-rmse:0.83787
# [100]	validation_0-rmse:0.62427	validation_1-rmse:0.83444
# [101]	validation_0-rmse:0.62255	validation_1-rmse:0.83535
# [102]	validation_0-rmse:0.62102	validation_1-rmse:0.83824
# [103]	validation_0-rmse:0.61905	validation_1-rmse:0.83670
# [104]	validation_0-rmse:0.61857	validation_1-rmse:0.83752
# [105]	validation_0-rmse:0.61705	validation_1-rmse:0.83708
# [106]	validation_0-rmse:0.61573	validation_1-rmse:0.83381
# [107]	validation_0-rmse:0.61254	validation_1-rmse:0.83503
# [108]	validation_0-rmse:0.61156	validation_1-rmse:0.83244
# [109]	validation_0-rmse:0.61079	validation_1-rmse:0.83213
# [110]	validation_0-rmse:0.60797	validation_1-rmse:0.83378
# [111]	validation_0-rmse:0.60553	validation_1-rmse:0.83420
# [112]	validation_0-rmse:0.60323	validation_1-rmse:0.83401
# [113]	validation_0-rmse:0.60060	validation_1-rmse:0.82890
# [114]	validation_0-rmse:0.59830	validation_1-rmse:0.82950
# [115]	validation_0-rmse:0.59764	validation_1-rmse:0.82694
# [116]	validation_0-rmse:0.59488	validation_1-rmse:0.82574
# [117]	validation_0-rmse:0.59188	validation_1-rmse:0.82600
# [118]	validation_0-rmse:0.58932	validation_1-rmse:0.82493
# [119]	validation_0-rmse:0.58839	validation_1-rmse:0.82376
# [120]	validation_0-rmse:0.58832	validation_1-rmse:0.82429
# [121]	validation_0-rmse:0.58560	validation_1-rmse:0.82286
# [122]	validation_0-rmse:0.58446	validation_1-rmse:0.82348
# [123]	validation_0-rmse:0.58250	validation_1-rmse:0.82229
# [124]	validation_0-rmse:0.58073	validation_1-rmse:0.82030
# [125]	validation_0-rmse:0.58003	validation_1-rmse:0.82010
# [126]	validation_0-rmse:0.57873	validation_1-rmse:0.81920

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 114.6, median: 124.5,
#  pred. interval (P(0.025)-P(0.975)): 62.625-126.0,
#  conf. interval (p-value=0.95): 113.336-125.155
# ***
# Aggregate bias statistic:
#  mean: -3.078, median: -2.676,
#  pred. interval (P(0.025)-P(0.975)): -9.784-1.68,
#  conf. interval (p-value=0.95): -4.64--1.431
# ***
# Aggregate RMSE statistic:
#  mean: 0.808, median: 0.811, pred. interval (P(0.025)-P(0.975)): 0.619-1.038,
#  conf. interval (p-value=0.95): 0.772-0.843
# ***
# Aggregate MSE statistic:
#  mean: 0.664, median: 0.658, pred. interval (P(0.025)-P(0.975)): 0.383-1.076,
#  conf. interval (p-value=0.95): 0.598-0.712
# ***
# Aggregate R^2 statistic:
#  mean: 0.119, median: 0.181, pred. interval (P(0.025)-P(0.975)): -0.408-0.338,
#  conf. interval (p-value=0.95): 0.103-0.224
# ***
# Aggregate bias(%) statistic:
#  mean: -1.142, median: -2.676, pred. interval (P(0.025)-P(0.975)): -3.616-0.817,
#  conf. interval (p-value=0.95): -1.74--0.569
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.324, median: 0.318, pred. interval (P(0.025)-P(0.975)): 0.25-0.412,
#  conf. interval (p-value=0.95): 0.297-0.344
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:2.11290
# [1]	validation_0-rmse:2.06374
# [2]	validation_0-rmse:2.01777
# [3]	validation_0-rmse:1.97811
# [4]	validation_0-rmse:1.93495
# [5]	validation_0-rmse:1.89656
# [6]	validation_0-rmse:1.85951
# [7]	validation_0-rmse:1.82072
# [8]	validation_0-rmse:1.78574
# [9]	validation_0-rmse:1.74605
# [10]	validation_0-rmse:1.70721
# [11]	validation_0-rmse:1.67353
# [12]	validation_0-rmse:1.64108
# [13]	validation_0-rmse:1.61355
# [14]	validation_0-rmse:1.58649
# [15]	validation_0-rmse:1.55598
# [16]	validation_0-rmse:1.52305
# [17]	validation_0-rmse:1.49480
# [18]	validation_0-rmse:1.46717
# [19]	validation_0-rmse:1.43761
# [20]	validation_0-rmse:1.41205
# [21]	validation_0-rmse:1.38935
# [22]	validation_0-rmse:1.36388
# [23]	validation_0-rmse:1.33710
# [24]	validation_0-rmse:1.31274
# [25]	validation_0-rmse:1.28693
# [26]	validation_0-rmse:1.27022
# [27]	validation_0-rmse:1.24900
# [28]	validation_0-rmse:1.22901
# [29]	validation_0-rmse:1.21634
# [30]	validation_0-rmse:1.19346
# [31]	validation_0-rmse:1.17474
# [32]	validation_0-rmse:1.15561
# [33]	validation_0-rmse:1.13871
# [34]	validation_0-rmse:1.12161
# [35]	validation_0-rmse:1.10641
# [36]	validation_0-rmse:1.09203
# [37]	validation_0-rmse:1.07213
# [38]	validation_0-rmse:1.05490
# [39]	validation_0-rmse:1.04058
# [40]	validation_0-rmse:1.02379
# [41]	validation_0-rmse:1.00849
# [42]	validation_0-rmse:0.99831
# [43]	validation_0-rmse:0.98344
# [44]	validation_0-rmse:0.97161
# [45]	validation_0-rmse:0.96062
# [46]	validation_0-rmse:0.94725
# [47]	validation_0-rmse:0.93508
# [48]	validation_0-rmse:0.92125
# [49]	validation_0-rmse:0.91505
# [50]	validation_0-rmse:0.90507
# [51]	validation_0-rmse:0.89534
# [52]	validation_0-rmse:0.88745
# [53]	validation_0-rmse:0.87838
# [54]	validation_0-rmse:0.87319
# [55]	validation_0-rmse:0.86482
# [56]	validation_0-rmse:0.85646
# [57]	validation_0-rmse:0.84824
# [58]	validation_0-rmse:0.84020
# [59]	validation_0-rmse:0.83546
# [60]	validation_0-rmse:0.83069
# [61]	validation_0-rmse:0.82322
# [62]	validation_0-rmse:0.81858
# [63]	validation_0-rmse:0.81193
# [64]	validation_0-rmse:0.80566
# [65]	validation_0-rmse:0.79911
# [66]	validation_0-rmse:0.79059
# [67]	validation_0-rmse:0.78334
# [68]	validation_0-rmse:0.77955
# [69]	validation_0-rmse:0.77342
# [70]	validation_0-rmse:0.76982
# [71]	validation_0-rmse:0.76453
# [72]	validation_0-rmse:0.76012
# [73]	validation_0-rmse:0.75424
# [74]	validation_0-rmse:0.74849
# [75]	validation_0-rmse:0.74299
# [76]	validation_0-rmse:0.74006
# [77]	validation_0-rmse:0.73619
# [78]	validation_0-rmse:0.73412
# [79]	validation_0-rmse:0.73053
# [80]	validation_0-rmse:0.72729
# [81]	validation_0-rmse:0.72182
# [82]	validation_0-rmse:0.71828
# [83]	validation_0-rmse:0.71174
# [84]	validation_0-rmse:0.70849
# [85]	validation_0-rmse:0.70557
# [86]	validation_0-rmse:0.70209
# [87]	validation_0-rmse:0.69911
# [88]	validation_0-rmse:0.69446
# [89]	validation_0-rmse:0.69334
# [90]	validation_0-rmse:0.69112
# [91]	validation_0-rmse:0.68638
# [92]	validation_0-rmse:0.68251
# [93]	validation_0-rmse:0.67751
# [94]	validation_0-rmse:0.67473
# [95]	validation_0-rmse:0.67117
# [96]	validation_0-rmse:0.66774
# [97]	validation_0-rmse:0.66425
# [98]	validation_0-rmse:0.66092
# [99]	validation_0-rmse:0.65727
# [100]	validation_0-rmse:0.65447
# [101]	validation_0-rmse:0.65238
# [102]	validation_0-rmse:0.65097
# [103]	validation_0-rmse:0.64980
# [104]	validation_0-rmse:0.64643
# [105]	validation_0-rmse:0.64506
# [106]	validation_0-rmse:0.64104
# [107]	validation_0-rmse:0.64039
# [108]	validation_0-rmse:0.63897
# [109]	validation_0-rmse:0.63589
# [110]	validation_0-rmse:0.63503
# [111]	validation_0-rmse:0.63247
# [112]	validation_0-rmse:0.63033
# [113]	validation_0-rmse:0.62848
# [114]	validation_0-rmse:0.62676
# [115]	validation_0-rmse:0.62361
# [116]	validation_0-rmse:0.62071
# [117]	validation_0-rmse:0.61754
# [118]	validation_0-rmse:0.61441
# [119]	validation_0-rmse:0.61211
# [120]	validation_0-rmse:0.60970
# [121]	validation_0-rmse:0.60636
# [122]	validation_0-rmse:0.60525
# [123]	validation_0-rmse:0.60534
# [124]	validation_0-rmse:0.60361
# [125]	validation_0-rmse:0.60110
# [126]	validation_0-rmse:0.59986

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 126

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.1
# Relative bias(%):  -3.02
# RMSE: 0.6
# Relative RMSE(%):  0.243
# MSE: 0.4
# R square: 55.6%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 1.458
# a1: 0.379
# R^2: 0.734
# Uncertainty
# a0: 1.46+/-0.06
# a1: 0.379+/-0.023

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
