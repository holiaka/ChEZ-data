# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_MIN', 'corr_r_Q25'])

# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           2260           1210     -0.731      2.576
# 1       8.189       9.622           2700           1180      0.585      2.915
# 2       8.380       9.589           2500           1400      0.779      2.882
# 3       8.137       9.449           2500           1090      0.517      2.724
# 4       7.696       9.401           2400            720      0.224      2.826
#
#    AEDR_mean  r_MIN      b_STD  contr_r_STD  corr_r_MIN  corr_r_Q25
# 0       2.33     13  35.145074   360.273487    0.072792    0.488754
# 1       2.47     24  36.135511   323.958625    0.098347    0.501683
# 2       2.44     18  35.938764   299.438354    0.187811    0.540056
# 3       2.55     15  35.908361   319.773395    0.020686    0.480991
# 4       2.14      8  38.062522   353.104284    0.106549    0.505257

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   r_MIN          103 non-null    int64
#  8   b_STD          103 non-null    float64
#  9   contr_r_STD    103 non-null    float64
#  10  corr_r_MIN     103 non-null    float64
#  11  corr_r_Q25     103 non-null    float64
# dtypes: float64(9), int64(3)
# memory usage: 9.8 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3440.194175    1242.902913   -0.252563
# std       1.64946    1.472424    6087.580089    2037.684800    1.104610
# min       3.52600    6.075000     260.000000      50.000000   -3.033000
# 25%       6.31900    7.664000     635.000000     200.000000   -0.727500
# 50%       6.95700    8.472000    1150.000000     400.000000   -0.025000
# 75%       7.91350    9.421000    2525.000000    1400.000000    0.516500
# max      11.36700   13.864000   35200.000000   10500.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean       r_MIN       b_STD  contr_r_STD  \
# count  103.000000  103.000000  103.000000  103.000000   103.000000
# mean     2.464709    3.570291   11.378641   35.164575   327.115078
# std      0.904675    6.089170    9.139568    5.338700   167.617957
# min      0.391000    0.480000    2.000000   20.570709     0.091058
# 25%      1.803000    0.710000    5.000000   31.746440   283.887328
# 50%      2.603000    1.290000    8.000000   36.135511   353.034542
# 75%      3.159000    2.960000   15.000000   39.139044   448.017711
# max      4.659000   36.590000   56.000000   45.825416   652.546648
#
#        corr_r_MIN  corr_r_Q25
# count  103.000000  103.000000
# mean     0.073579    0.393571
# std      0.056017    0.151801
# min     -0.062450    0.033797
# 25%      0.027204    0.407228
# 50%      0.063714    0.449670
# 75%      0.110983    0.476635
# max      0.241284    0.555648

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_MIN', 'corr_r_Q25', 'AEDR_mean'])
y = pd.DataFrame(select, columns= ['ln_Cs_wood'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    r_MIN      b_STD  contr_r_STD  corr_r_MIN  corr_r_Q25  AEDR_mean
# 0     13  35.145074   360.273487    0.072792    0.488754       2.33
# 1     24  36.135511   323.958625    0.098347    0.501683       2.47
# 2     18  35.938764   299.438354    0.187811    0.540056       2.44
# 3     15  35.908361   319.773395    0.020686    0.480991       2.55
# 4      8  38.062522   353.104284    0.106549    0.505257       2.14

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Cs_wood
# 0       6.824
# 1       8.189
# 2       8.380
# 3       8.137
# 4       7.696

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.4527683522758883, 0.5622915727510427, 0.2669446530442209]
#     Mean: 0.427
#     Std: 0.122
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.1008596  1.46057602 1.03781043]
#     Mean: 1.200
#     Std: 0.186
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.6872327031816754, 0.8970081156562356, 0.790936226452098]
#     Mean: 0.792
#     Std: 0.086
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=7, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 7 folds for each of 3000 candidates, totalling 21000 fits
# Model with rank: 1
# Mean validation score: -0.035 (std: 0.630)
# Parameters: {'colsample_bytree': 0.37679773343911427, 'gamma': 0.21630107231039897, 'learning_rate': 0.300427594799142, 'max_depth': 2, 'n_estimators': 51, 'subsample': 0.642309491037681}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.53721534, 0.24732767, 0.96334798, ..., 0.14478653, 0.31230835,
#        0.28846264]), 'std_fit_time': array([0.08600918, 0.1433499 , 0.3746983 , ..., 0.02628857, 0.01108383,
#        0.00998252]), 'mean_score_time': array([0.00626193, 0.00629176, 0.00824669, ..., 0.00591016, 0.00583598,
#        0.00627998]), 'std_score_time': array([5.03139175e-04, 4.05224720e-04, 2.85853412e-03, ...,
#        7.01838627e-05, 7.18364803e-05, 6.48641125e-04]), 'param_colsample_bytree': masked_array(data=[0.3978609509058418, 0.19846009756376393,
#                    0.5619393068944941, ..., 0.639410572611186,
#                    0.21580466355474076, 0.547466809495224],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.40793377395759084, 0.43047121916849634,
#                    0.33526392105154884, ..., 0.34926895810074565,
#                    0.2876156257078056, 0.420317824205627],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.2910847436830103, 0.1080284870738826,
#                    0.09554922928389456, ..., 0.14299676134011205,
#                    0.19770621314122064, 0.11562866540931022],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[3, 2, 3, ..., 3, 4, 4],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[178, 71, 199, ..., 52, 125, 116],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.37154323187239413, 0.4998561463092796,
#                    0.36775293002839265, ..., 0.7095445421413002,
#                    0.5195153316841405, 0.6281545663198937],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.3978609509058418, 'gamma': 0.40793377395759084, 'learning_rate': 0.2910847436830103, 'max_depth': 3, 'n_estimators': 178, 'subsample': 0.37154323187239413}, {'colsample_bytree': 0.19846009756376393, 'gamma': 0.43047121916849634, 'learning_rate': 0.1080284870738826, 'max_depth': 2, 'n_estimators': 71, 'subsample': 0.4998561463092796}, {'colsample_bytree': 0.5619393068944941, 'gamma': 0.33526392105154884, 'learning_rate': 0.09554922928389456, 'max_depth': 3, 'n_estimators': 199, 'subsample': 0.36775293002839265}, {'colsample_bytree': 0.06248630262585894, 'gamma': 0.07962333591544318, 'learning_rate': 0.20423637019928556, 'max_depth': 4, 'n_estimators': 94, 'subsample': 0.669767560843873}, {'colsample_bytree': 0.9024714030261808, 'gamma': 0.09985186317425093, 'learning_rate': 0.30925150621720526, 'max_depth': 2, 'n_estimators': 193, 'subsample': 0.990680274636881}, {'colsample_bytree': 0.5275681102166264, 'gamma': 0.025582502872241564, 'learning_rate': 0.013184641671662514, 'max_depth': 3, 'n_estimators': 76, 'subsample': 0.8567879537445298}, {'colsample_bytree': 0.3999779929731846, 'gamma': 0.06903620062659988, 'learning_rate': 0.30828302132356833, 'max_depth': 3, 'n_estimators': 161, 'subsample': 0.6972274599995448}, {'colsample_bytree': 0.4207940277411365, 'gamma': 0.25654697605170007, 'learning_rate': 0.21467948870855813, 'max_depth': 2, 'n_estimators': 178, 'subsample': 0.8809991470131031}, {'colsample_bytree': 0.06641316381714027, 'gamma': 0.2186340547402401, 'learning_rate': 0.17536702323499548, 'max_depth': 3, 'n_estimators': 141, 'subsample': 0.6039913932368985}, {'colsample_bytree': 0.12317194223964326, 'gamma': 0.10354075149581532, 'learning_rate': 0.010063468720192106, 'max_depth': 2, 'n_estimators': 85, 'subsample': 0.7066050159354762}, {'colsample_bytree': 0.49743839728656425, 'gamma': 0.09867770911236334, 'learning_rate': 0.0853376838575402, 'max_depth': 2, 'n_estimators': 149, 'subsample': 0.8017552238196568}, {'colsample_bytree': 0.19396841463124415, 'gamma': 0.03161967233312413, 'learning_rate': 0.09115564444477442, 'max_depth': 2, 'n_estimators': 173, 'subsample': 0.677140857086916}, {'colsample_bytree': 0.2242865465128422, 'gamma': 0.06803000600716697, 'learning_rate': 0.23415268459278743, 'max_depth': 2, 'n_estimators': 91, 'subsample': 0.30359372445027594}, {'colsample_bytree': 0.748511031757424, 'gamma': 0.4229995397587742, 'learning_rate': 0.13101094750761733, 'max_depth': 3, 'n_estimators': 178, 'subsample': 0.5384537823802006}, {'colsample_bytree': 0.4161890094276918, 'gamma': 0.3743505046483252, 'learning_rate': 0.03559235633204293, 'max_depth': 3, 'n_estimators': 126, 'subsample': 0.692331218269415}, {'colsample_bytree': 0.8490291805182963, 'gamma': 0.3796734733105639, 'learning_rate': 0.04481087726601593, 'max_depth': 4, 'n_estimators': 136, 'subsample': 0.5601105614908093}, {'colsample_bytree': 0.45665309220576245, 'gamma': 0.10401768825727775, 'learning_rate': 0.2133922181496641, 'max_depth': 2, 'n_estimators': 110, 'subsample': 0.6995774145823759}, {'colsample_bytree': 0.7919736821434384, 'gamma': 0.01991187504013553, 'learning_rate': 0.309858959344731, 'max_depth': 3, 'n_estimators': 179, 'subsample': 0.6686634235360036}, {'colsample_bytree': 0.20308178927771375, 'gamma': 0.07236258271847729, 'learning_rate': 0.17344933194742773, 'max_depth': 4, 'n_estimators': 181, 'subsample': 0.5299638088874435}, {'colsample_bytree': 0.081894040644959, 'gamma': 0.03680168336746048, 'learning_rate': 0.09903324478316654, 'max_depth': 4, 'n_estimators': 86, 'subsample': 0.6218755650812633}, {'colsample_bytree': 0.1401000517466625, 'gamma': 0.4824790002790088, 'learning_rate': 0.126785068706447, 'max_depth': 2, 'n_estimators': 59, 'subsample': 0.966212651757977}, {'colsample_bytree': 0.08426349953109982, 'gamma': 0.2683333903976339, 'learning_rate': 0.23828687547364816, 'max_depth': 4, 'n_estimators': 126, 'subsample': 0.5501877253456342}, {'colsample_byt ...
#        -2.44421085, -1.62193595]), 'split1_test_score': array([-3.38730663, -0.66619969, -2.47735833, ..., -1.78747651,
#        -3.28368217, -1.83670167]), 'split2_test_score': array([-0.11590465, -0.06050118,  0.20329881, ...,  0.20923718,
#        -0.30292753, -0.02134384]), 'split3_test_score': array([-1.197968  , -0.61371256, -1.22628455, ..., -0.85954865,
#        -0.80715722, -0.92272861]), 'split4_test_score': array([0.51375933, 0.57941476, 0.46945737, ..., 0.41962145, 0.28802168,
#        0.3988637 ]), 'split5_test_score': array([0.71432974, 0.57521363, 0.59284994, ..., 0.53157872, 0.4065518 ,
#        0.54246032]), 'split6_test_score': array([0.7428829 , 0.6940878 , 0.81168795, ..., 0.75513394, 0.72328346,
#        0.78569233]), 'mean_test_score': array([-0.76222254, -0.18579999, -0.47759762, ..., -0.33249762,
#        -0.77430298, -0.38224196]), 'std_test_score': array([1.55698733, 0.8454038 , 1.21089881, ..., 0.98415947, 1.41797478,
#        0.99311475]), 'rank_test_score': array([1616,    8,  547, ...,  125, 1659,  236], dtype=int32), 'split0_train_score': array([0.97652402, 0.84103525, 0.96850377, ..., 0.94804954, 0.97218699,
#        0.9686695 ]), 'split1_train_score': array([0.97361917, 0.84161053, 0.97118809, ..., 0.95126037, 0.97384877,
#        0.97147858]), 'split2_train_score': array([0.97042854, 0.81501043, 0.96796488, ..., 0.94300375, 0.96877024,
#        0.9636778 ]), 'split3_train_score': array([0.97517155, 0.86818856, 0.97175836, ..., 0.96203793, 0.97358766,
#        0.97208014]), 'split4_train_score': array([0.96558008, 0.80161239, 0.96457531, ..., 0.93521308, 0.96925965,
#        0.96529165]), 'split5_train_score': array([0.97227849, 0.83280746, 0.96591652, ..., 0.93603488, 0.97304992,
#        0.96635591]), 'split6_train_score': array([0.96822234, 0.83127984, 0.95811222, ..., 0.94014084, 0.9651765 ,
#        0.95884198]), 'mean_train_score': array([0.97168917, 0.83307778, 0.96685988, ..., 0.94510577, 0.97083996,
#        0.96662794]), 'std_train_score': array([0.00359571, 0.01959848, 0.00429755, ..., 0.00880307, 0.00297986,
#        0.00428631])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.37679773343911427
# Gamma: 0.21630107231039897
# Learning_rate: 0.300427594799142
# Max_depth: 2
# N_estimators: 51
# Subsample: 0.642309491037681

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=10, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:4.94286	validation_1-rmse:5.16318
# [1]	validation_0-rmse:3.61402	validation_1-rmse:3.87208
# [2]	validation_0-rmse:2.68944	validation_1-rmse:2.90012
# [3]	validation_0-rmse:2.03899	validation_1-rmse:2.39854
# [4]	validation_0-rmse:1.60378	validation_1-rmse:1.96119
# [5]	validation_0-rmse:1.33953	validation_1-rmse:1.68605
# [6]	validation_0-rmse:1.17810	validation_1-rmse:1.45612
# [7]	validation_0-rmse:1.04965	validation_1-rmse:1.27302
# [8]	validation_0-rmse:0.98472	validation_1-rmse:1.20100
# [9]	validation_0-rmse:0.90009	validation_1-rmse:1.11278
# [10]	validation_0-rmse:0.86930	validation_1-rmse:1.10359
# [11]	validation_0-rmse:0.80975	validation_1-rmse:1.07487
# [12]	validation_0-rmse:0.79059	validation_1-rmse:1.06939
# [13]	validation_0-rmse:0.76353	validation_1-rmse:1.07227
# [14]	validation_0-rmse:0.73362	validation_1-rmse:1.04761
# [15]	validation_0-rmse:0.72197	validation_1-rmse:1.07071
# [16]	validation_0-rmse:0.72116	validation_1-rmse:1.08082
# [17]	validation_0-rmse:0.70637	validation_1-rmse:1.04847
# [18]	validation_0-rmse:0.68191	validation_1-rmse:0.99027
# [19]	validation_0-rmse:0.66846	validation_1-rmse:0.96968
# [20]	validation_0-rmse:0.63891	validation_1-rmse:0.92067
# [21]	validation_0-rmse:0.63343	validation_1-rmse:0.93280
# [22]	validation_0-rmse:0.61447	validation_1-rmse:0.91136
# [23]	validation_0-rmse:0.61232	validation_1-rmse:0.90426
# [24]	validation_0-rmse:0.59441	validation_1-rmse:0.92096
# [25]	validation_0-rmse:0.58435	validation_1-rmse:0.94469
# [26]	validation_0-rmse:0.57248	validation_1-rmse:0.91400
# [27]	validation_0-rmse:0.56286	validation_1-rmse:0.88076
# [28]	validation_0-rmse:0.54999	validation_1-rmse:0.87819
# [29]	validation_0-rmse:0.54327	validation_1-rmse:0.87339
# [30]	validation_0-rmse:0.52854	validation_1-rmse:0.87583
# [31]	validation_0-rmse:0.51580	validation_1-rmse:0.86170
# [32]	validation_0-rmse:0.51099	validation_1-rmse:0.86317
# [33]	validation_0-rmse:0.50514	validation_1-rmse:0.86832
# [34]	validation_0-rmse:0.49839	validation_1-rmse:0.84486
# [35]	validation_0-rmse:0.49302	validation_1-rmse:0.85173
# [36]	validation_0-rmse:0.47776	validation_1-rmse:0.87302
# [37]	validation_0-rmse:0.47356	validation_1-rmse:0.85508
# [38]	validation_0-rmse:0.46801	validation_1-rmse:0.85770
# [39]	validation_0-rmse:0.46023	validation_1-rmse:0.84363
# [40]	validation_0-rmse:0.45866	validation_1-rmse:0.83957
# [41]	validation_0-rmse:0.44981	validation_1-rmse:0.84831
# [42]	validation_0-rmse:0.44370	validation_1-rmse:0.82872
# [43]	validation_0-rmse:0.43649	validation_1-rmse:0.81291
# [44]	validation_0-rmse:0.43459	validation_1-rmse:0.80723
# [45]	validation_0-rmse:0.42573	validation_1-rmse:0.81314
# [46]	validation_0-rmse:0.42132	validation_1-rmse:0.81273
# [47]	validation_0-rmse:0.41546	validation_1-rmse:0.81097
# [48]	validation_0-rmse:0.41346	validation_1-rmse:0.82394
# [49]	validation_0-rmse:0.40805	validation_1-rmse:0.82320
# [50]	validation_0-rmse:0.40316	validation_1-rmse:0.83003
# [0]	validation_0-rmse:4.92390	validation_1-rmse:4.94367
# [1]	validation_0-rmse:3.61827	validation_1-rmse:3.53179
# [2]	validation_0-rmse:2.65234	validation_1-rmse:2.59176
# [3]	validation_0-rmse:1.99810	validation_1-rmse:1.97720
# [4]	validation_0-rmse:1.62093	validation_1-rmse:1.65300
# [5]	validation_0-rmse:1.30330	validation_1-rmse:1.30335
# [6]	validation_0-rmse:1.08888	validation_1-rmse:1.13361
# [7]	validation_0-rmse:0.96940	validation_1-rmse:1.04964
# [8]	validation_0-rmse:0.88524	validation_1-rmse:1.01026
# [9]	validation_0-rmse:0.81857	validation_1-rmse:0.97530
# [10]	validation_0-rmse:0.79056	validation_1-rmse:0.96031
# [11]	validation_0-rmse:0.74574	validation_1-rmse:0.94252
# [12]	validation_0-rmse:0.71450	validation_1-rmse:0.94429
# [13]	validation_0-rmse:0.69495	validation_1-rmse:0.96285
# [14]	validation_0-rmse:0.65025	validation_1-rmse:0.96743
# [15]	validation_0-rmse:0.62801	validation_1-rmse:0.97751
# [16]	validation_0-rmse:0.60203	validation_1-rmse:0.96606
# [17]	validation_0-rmse:0.58878	validation_1-rmse:0.95324
# [18]	validation_0-rmse:0.57473	validation_1-rmse:0.95529
# [19]	validation_0-rmse:0.56410	validation_1-rmse:0.96683
# [20]	validation_0-rmse:0.55402	validation_1-rmse:0.97738
# [21]	validation_0-rmse:0.55126	validation_1-rmse:0.98065
# [0]	validation_0-rmse:4.93859	validation_1-rmse:4.72715
# [1]	validation_0-rmse:3.59350	validation_1-rmse:3.51540
# [2]	validation_0-rmse:2.63852	validation_1-rmse:2.63137
# [3]	validation_0-rmse:2.05614	validation_1-rmse:2.09930
# [4]	validation_0-rmse:1.62138	validation_1-rmse:1.72979
# [5]	validation_0-rmse:1.28384	validation_1-rmse:1.43995
# [6]	validation_0-rmse:1.07759	validation_1-rmse:1.28747
# [7]	validation_0-rmse:0.95204	validation_1-rmse:1.20770
# [8]	validation_0-rmse:0.87046	validation_1-rmse:1.16367
# [9]	validation_0-rmse:0.82420	validation_1-rmse:1.09158
# [10]	validation_0-rmse:0.78384	validation_1-rmse:1.08055
# [11]	validation_0-rmse:0.76239	validation_1-rmse:1.10112
# [12]	validation_0-rmse:0.73310	validation_1-rmse:1.14340
# [13]	validation_0-rmse:0.72046	validation_1-rmse:1.12361
# [14]	validation_0-rmse:0.70281	validation_1-rmse:1.13757
# [15]	validation_0-rmse:0.67627	validation_1-rmse:1.15249
# [16]	validation_0-rmse:0.67310	validation_1-rmse:1.19065
# [17]	validation_0-rmse:0.66398	validation_1-rmse:1.17984
# [18]	validation_0-rmse:0.64697	validation_1-rmse:1.13139
# [19]	validation_0-rmse:0.63187	validation_1-rmse:1.12774
# [0]	validation_0-rmse:4.91508	validation_1-rmse:4.97505
# [1]	validation_0-rmse:3.61934	validation_1-rmse:3.64510
# [2]	validation_0-rmse:2.66698	validation_1-rmse:2.71475
# [3]	validation_0-rmse:2.02526	validation_1-rmse:2.00223
# [4]	validation_0-rmse:1.60708	validation_1-rmse:1.57359
# [5]	validation_0-rmse:1.29685	validation_1-rmse:1.29372
# [6]	validation_0-rmse:1.09678	validation_1-rmse:1.11929
# [7]	validation_0-rmse:0.96722	validation_1-rmse:1.03964
# [8]	validation_0-rmse:0.88587	validation_1-rmse:1.00460
# [9]	validation_0-rmse:0.80704	validation_1-rmse:0.90605
# [10]	validation_0-rmse:0.78557	validation_1-rmse:0.89777
# [11]	validation_0-rmse:0.76309	validation_1-rmse:0.89763
# [12]	validation_0-rmse:0.73261	validation_1-rmse:0.86202
# [13]	validation_0-rmse:0.70764	validation_1-rmse:0.92227
# [14]	validation_0-rmse:0.66871	validation_1-rmse:0.90497
# [15]	validation_0-rmse:0.64519	validation_1-rmse:0.90249
# [16]	validation_0-rmse:0.64271	validation_1-rmse:0.92566
# [17]	validation_0-rmse:0.61415	validation_1-rmse:0.94548
# [18]	validation_0-rmse:0.60403	validation_1-rmse:0.94507
# [19]	validation_0-rmse:0.59746	validation_1-rmse:0.94259
# [20]	validation_0-rmse:0.59263	validation_1-rmse:0.93960
# [21]	validation_0-rmse:0.58647	validation_1-rmse:0.92878
# [0]	validation_0-rmse:5.01650	validation_1-rmse:4.49493
# [1]	validation_0-rmse:3.68261	validation_1-rmse:3.31169
# [2]	validation_0-rmse:2.76049	validation_1-rmse:2.45648
# [3]	validation_0-rmse:2.17588	validation_1-rmse:1.95232
# [4]	validation_0-rmse:1.72612	validation_1-rmse:1.60680
# [5]	validation_0-rmse:1.41139	validation_1-rmse:1.42489
# [6]	validation_0-rmse:1.18957	validation_1-rmse:1.27807
# [7]	validation_0-rmse:1.02706	validation_1-rmse:1.24546
# [8]	validation_0-rmse:0.93316	validation_1-rmse:1.21885
# [9]	validation_0-rmse:0.86366	validation_1-rmse:1.24102
# [10]	validation_0-rmse:0.83933	validation_1-rmse:1.26290
# [11]	validation_0-rmse:0.81213	validation_1-rmse:1.26250
# [12]	validation_0-rmse:0.78914	validation_1-rmse:1.28077
# [13]	validation_0-rmse:0.76089	validation_1-rmse:1.29788
# [14]	validation_0-rmse:0.73005	validation_1-rmse:1.27977
# [15]	validation_0-rmse:0.69720	validation_1-rmse:1.27159
# [16]	validation_0-rmse:0.67479	validation_1-rmse:1.25059
# [17]	validation_0-rmse:0.65860	validation_1-rmse:1.28327
# [18]	validation_0-rmse:0.64728	validation_1-rmse:1.26977
# [0]	validation_0-rmse:4.84656	validation_1-rmse:5.28905
# [1]	validation_0-rmse:3.54093	validation_1-rmse:4.07879
# [2]	validation_0-rmse:2.61569	validation_1-rmse:3.14641
# [3]	validation_0-rmse:2.03940	validation_1-rmse:2.53548
# [4]	validation_0-rmse:1.62166	validation_1-rmse:2.13805
# [5]	validation_0-rmse:1.32408	validation_1-rmse:1.81349
# [6]	validation_0-rmse:1.07923	validation_1-rmse:1.59000
# [7]	validation_0-rmse:0.95327	validation_1-rmse:1.48551
# [8]	validation_0-rmse:0.86279	validation_1-rmse:1.40987
# [9]	validation_0-rmse:0.79901	validation_1-rmse:1.35594
# [10]	validation_0-rmse:0.76299	validation_1-rmse:1.33640
# [11]	validation_0-rmse:0.72102	validation_1-rmse:1.31043
# [12]	validation_0-rmse:0.70300	validation_1-rmse:1.30572
# [13]	validation_0-rmse:0.69025	validation_1-rmse:1.29290
# [14]	validation_0-rmse:0.65320	validation_1-rmse:1.31157
# [15]	validation_0-rmse:0.64443	validation_1-rmse:1.32258
# [16]	validation_0-rmse:0.62166	validation_1-rmse:1.30884
# [17]	validation_0-rmse:0.61016	validation_1-rmse:1.31166
# [18]	validation_0-rmse:0.59666	validation_1-rmse:1.34005
# [19]	validation_0-rmse:0.59089	validation_1-rmse:1.35658
# [20]	validation_0-rmse:0.57086	validation_1-rmse:1.33956
# [21]	validation_0-rmse:0.56429	validation_1-rmse:1.34606
# [22]	validation_0-rmse:0.55224	validation_1-rmse:1.35892
# [23]	validation_0-rmse:0.54433	validation_1-rmse:1.36761
# [0]	validation_0-rmse:4.97288	validation_1-rmse:4.57711
# [1]	validation_0-rmse:3.65285	validation_1-rmse:3.33154
# [2]	validation_0-rmse:2.72012	validation_1-rmse:2.42767
# [3]	validation_0-rmse:2.06903	validation_1-rmse:1.82842
# [4]	validation_0-rmse:1.66540	validation_1-rmse:1.48054
# [5]	validation_0-rmse:1.34828	validation_1-rmse:1.32842
# [6]	validation_0-rmse:1.13330	validation_1-rmse:1.23121
# [7]	validation_0-rmse:0.97301	validation_1-rmse:1.19030
# [8]	validation_0-rmse:0.88507	validation_1-rmse:1.19033
# [9]	validation_0-rmse:0.82905	validation_1-rmse:1.21347
# [10]	validation_0-rmse:0.79715	validation_1-rmse:1.21727
# [11]	validation_0-rmse:0.75480	validation_1-rmse:1.25301
# [12]	validation_0-rmse:0.72923	validation_1-rmse:1.27341
# [13]	validation_0-rmse:0.71861	validation_1-rmse:1.22663
# [14]	validation_0-rmse:0.69422	validation_1-rmse:1.24705
# [15]	validation_0-rmse:0.68776	validation_1-rmse:1.26456
# [16]	validation_0-rmse:0.68772	validation_1-rmse:1.22699
# [17]	validation_0-rmse:0.66969	validation_1-rmse:1.23515
# [0]	validation_0-rmse:4.82371	validation_1-rmse:4.76650
# [1]	validation_0-rmse:3.53554	validation_1-rmse:3.49379
# [2]	validation_0-rmse:2.64622	validation_1-rmse:2.70227
# [3]	validation_0-rmse:2.10301	validation_1-rmse:2.14859
# [4]	validation_0-rmse:1.67968	validation_1-rmse:1.68837
# [5]	validation_0-rmse:1.42014	validation_1-rmse:1.38215
# [6]	validation_0-rmse:1.21343	validation_1-rmse:1.15723
# [7]	validation_0-rmse:1.06867	validation_1-rmse:0.97488
# [8]	validation_0-rmse:0.97613	validation_1-rmse:0.91317
# [9]	validation_0-rmse:0.91417	validation_1-rmse:0.88156
# [10]	validation_0-rmse:0.88584	validation_1-rmse:0.90049
# [11]	validation_0-rmse:0.85294	validation_1-rmse:0.87823
# [12]	validation_0-rmse:0.81556	validation_1-rmse:0.76738
# [13]	validation_0-rmse:0.80062	validation_1-rmse:0.77362
# [14]	validation_0-rmse:0.78737	validation_1-rmse:0.76746
# [15]	validation_0-rmse:0.76593	validation_1-rmse:0.78409
# [16]	validation_0-rmse:0.74006	validation_1-rmse:0.78461
# [17]	validation_0-rmse:0.73167	validation_1-rmse:0.77086
# [18]	validation_0-rmse:0.71342	validation_1-rmse:0.77708
# [19]	validation_0-rmse:0.70016	validation_1-rmse:0.81540
# [20]	validation_0-rmse:0.68985	validation_1-rmse:0.79074
# [21]	validation_0-rmse:0.67409	validation_1-rmse:0.80306
# [0]	validation_0-rmse:4.82626	validation_1-rmse:5.64325
# [1]	validation_0-rmse:3.55965	validation_1-rmse:4.26791
# [2]	validation_0-rmse:2.64482	validation_1-rmse:3.23807
# [3]	validation_0-rmse:2.01912	validation_1-rmse:2.43303
# [4]	validation_0-rmse:1.65763	validation_1-rmse:2.00280
# [5]	validation_0-rmse:1.38751	validation_1-rmse:1.58747
# [6]	validation_0-rmse:1.17354	validation_1-rmse:1.27847
# [7]	validation_0-rmse:1.05693	validation_1-rmse:1.08085
# [8]	validation_0-rmse:0.96790	validation_1-rmse:0.94535
# [9]	validation_0-rmse:0.88520	validation_1-rmse:0.91503
# [10]	validation_0-rmse:0.85557	validation_1-rmse:0.85431
# [11]	validation_0-rmse:0.80758	validation_1-rmse:0.85134
# [12]	validation_0-rmse:0.77989	validation_1-rmse:0.84697
# [13]	validation_0-rmse:0.75632	validation_1-rmse:0.82571
# [14]	validation_0-rmse:0.74078	validation_1-rmse:0.82264
# [15]	validation_0-rmse:0.72495	validation_1-rmse:0.77923
# [16]	validation_0-rmse:0.71771	validation_1-rmse:0.79923
# [17]	validation_0-rmse:0.71014	validation_1-rmse:0.78989
# [18]	validation_0-rmse:0.69528	validation_1-rmse:0.77709
# [19]	validation_0-rmse:0.68241	validation_1-rmse:0.75246
# [20]	validation_0-rmse:0.67231	validation_1-rmse:0.76651
# [21]	validation_0-rmse:0.66301	validation_1-rmse:0.76170
# [22]	validation_0-rmse:0.65247	validation_1-rmse:0.77907
# [23]	validation_0-rmse:0.63142	validation_1-rmse:0.75644
# [24]	validation_0-rmse:0.60907	validation_1-rmse:0.76850
# [25]	validation_0-rmse:0.60066	validation_1-rmse:0.76077
# [26]	validation_0-rmse:0.59414	validation_1-rmse:0.78667
# [27]	validation_0-rmse:0.59271	validation_1-rmse:0.79122
# [28]	validation_0-rmse:0.57806	validation_1-rmse:0.78494
# [0]	validation_0-rmse:4.77151	validation_1-rmse:5.43091
# [1]	validation_0-rmse:3.50111	validation_1-rmse:4.10228
# [2]	validation_0-rmse:2.60965	validation_1-rmse:3.13572
# [3]	validation_0-rmse:1.96997	validation_1-rmse:2.45925
# [4]	validation_0-rmse:1.55552	validation_1-rmse:2.03835
# [5]	validation_0-rmse:1.23988	validation_1-rmse:1.75940
# [6]	validation_0-rmse:1.05701	validation_1-rmse:1.51342
# [7]	validation_0-rmse:0.93349	validation_1-rmse:1.30848
# [8]	validation_0-rmse:0.86610	validation_1-rmse:1.25534
# [9]	validation_0-rmse:0.80841	validation_1-rmse:1.21729
# [10]	validation_0-rmse:0.78477	validation_1-rmse:1.21447
# [11]	validation_0-rmse:0.75571	validation_1-rmse:1.17618
# [12]	validation_0-rmse:0.73394	validation_1-rmse:1.15612
# [13]	validation_0-rmse:0.71258	validation_1-rmse:1.14308
# [14]	validation_0-rmse:0.70498	validation_1-rmse:1.11354
# [15]	validation_0-rmse:0.68671	validation_1-rmse:1.09443
# [16]	validation_0-rmse:0.66777	validation_1-rmse:1.10469
# [17]	validation_0-rmse:0.64915	validation_1-rmse:1.09667
# [18]	validation_0-rmse:0.63468	validation_1-rmse:1.07837
# [19]	validation_0-rmse:0.61883	validation_1-rmse:1.09602
# [20]	validation_0-rmse:0.61376	validation_1-rmse:1.10132
# [21]	validation_0-rmse:0.60564	validation_1-rmse:1.04328
# [22]	validation_0-rmse:0.59340	validation_1-rmse:1.05001
# [23]	validation_0-rmse:0.58525	validation_1-rmse:1.03433
# [24]	validation_0-rmse:0.57115	validation_1-rmse:1.03522
# [25]	validation_0-rmse:0.56224	validation_1-rmse:1.04873
# [26]	validation_0-rmse:0.55523	validation_1-rmse:1.06841
# [27]	validation_0-rmse:0.54488	validation_1-rmse:1.07240
# [28]	validation_0-rmse:0.53393	validation_1-rmse:1.04802
# [29]	validation_0-rmse:0.52369	validation_1-rmse:1.03473
# [30]	validation_0-rmse:0.51794	validation_1-rmse:1.02725
# [31]	validation_0-rmse:0.51491	validation_1-rmse:1.04118
# [32]	validation_0-rmse:0.50893	validation_1-rmse:1.05019
# [33]	validation_0-rmse:0.49972	validation_1-rmse:1.04734
# [34]	validation_0-rmse:0.48607	validation_1-rmse:1.04276
# [35]	validation_0-rmse:0.48212	validation_1-rmse:1.06065
# [36]	validation_0-rmse:0.47680	validation_1-rmse:1.06849
# [37]	validation_0-rmse:0.46424	validation_1-rmse:1.09061
# [38]	validation_0-rmse:0.46013	validation_1-rmse:1.07098
# [39]	validation_0-rmse:0.45279	validation_1-rmse:1.05264
# [40]	validation_0-rmse:0.44421	validation_1-rmse:1.03597
# [0]	validation_0-rmse:4.84549	validation_1-rmse:5.01831
# [1]	validation_0-rmse:3.52076	validation_1-rmse:3.82667
# [2]	validation_0-rmse:2.56089	validation_1-rmse:2.86769
# [3]	validation_0-rmse:1.96031	validation_1-rmse:2.25141
# [4]	validation_0-rmse:1.53471	validation_1-rmse:1.78985
# [5]	validation_0-rmse:1.29551	validation_1-rmse:1.49900
# [6]	validation_0-rmse:1.08055	validation_1-rmse:1.25716
# [7]	validation_0-rmse:0.96801	validation_1-rmse:1.13731
# [8]	validation_0-rmse:0.86548	validation_1-rmse:1.09020
# [9]	validation_0-rmse:0.79272	validation_1-rmse:1.03449
# [10]	validation_0-rmse:0.75639	validation_1-rmse:1.03671
# [11]	validation_0-rmse:0.73638	validation_1-rmse:1.04894
# [12]	validation_0-rmse:0.71611	validation_1-rmse:1.07337
# [13]	validation_0-rmse:0.69294	validation_1-rmse:1.09514
# [14]	validation_0-rmse:0.66136	validation_1-rmse:1.04324
# [15]	validation_0-rmse:0.65248	validation_1-rmse:1.06858
# [16]	validation_0-rmse:0.64613	validation_1-rmse:1.07829
# [17]	validation_0-rmse:0.62582	validation_1-rmse:1.08183
# [18]	validation_0-rmse:0.60661	validation_1-rmse:1.04615
# [19]	validation_0-rmse:0.59346	validation_1-rmse:1.04467
# [0]	validation_0-rmse:4.82860	validation_1-rmse:5.01247
# [1]	validation_0-rmse:3.54733	validation_1-rmse:3.83071
# [2]	validation_0-rmse:2.63039	validation_1-rmse:2.90238
# [3]	validation_0-rmse:2.08594	validation_1-rmse:2.35354
# [4]	validation_0-rmse:1.63803	validation_1-rmse:1.94846
# [5]	validation_0-rmse:1.33802	validation_1-rmse:1.67851
# [6]	validation_0-rmse:1.13804	validation_1-rmse:1.45903
# [7]	validation_0-rmse:1.01642	validation_1-rmse:1.31660
# [8]	validation_0-rmse:0.92911	validation_1-rmse:1.26656
# [9]	validation_0-rmse:0.84863	validation_1-rmse:1.25780
# [10]	validation_0-rmse:0.80080	validation_1-rmse:1.31581
# [11]	validation_0-rmse:0.76104	validation_1-rmse:1.26657
# [12]	validation_0-rmse:0.74732	validation_1-rmse:1.25839
# [13]	validation_0-rmse:0.73555	validation_1-rmse:1.27874
# [14]	validation_0-rmse:0.72846	validation_1-rmse:1.30923
# [15]	validation_0-rmse:0.70597	validation_1-rmse:1.29858
# [16]	validation_0-rmse:0.68307	validation_1-rmse:1.28941
# [17]	validation_0-rmse:0.66656	validation_1-rmse:1.29245
# [18]	validation_0-rmse:0.65879	validation_1-rmse:1.31928
# [19]	validation_0-rmse:0.64805	validation_1-rmse:1.29467
# [0]	validation_0-rmse:4.88013	validation_1-rmse:5.24881
# [1]	validation_0-rmse:3.64164	validation_1-rmse:3.98754
# [2]	validation_0-rmse:2.71053	validation_1-rmse:3.06816
# [3]	validation_0-rmse:2.05815	validation_1-rmse:2.47624
# [4]	validation_0-rmse:1.61299	validation_1-rmse:2.12571
# [5]	validation_0-rmse:1.28488	validation_1-rmse:1.82652
# [6]	validation_0-rmse:1.08774	validation_1-rmse:1.66115
# [7]	validation_0-rmse:0.94747	validation_1-rmse:1.55169
# [8]	validation_0-rmse:0.85868	validation_1-rmse:1.49444
# [9]	validation_0-rmse:0.79562	validation_1-rmse:1.42305
# [10]	validation_0-rmse:0.75248	validation_1-rmse:1.40346
# [11]	validation_0-rmse:0.71642	validation_1-rmse:1.36968
# [12]	validation_0-rmse:0.70553	validation_1-rmse:1.37092
# [13]	validation_0-rmse:0.69669	validation_1-rmse:1.35251
# [14]	validation_0-rmse:0.68278	validation_1-rmse:1.34256
# [15]	validation_0-rmse:0.66536	validation_1-rmse:1.34605
# [16]	validation_0-rmse:0.65442	validation_1-rmse:1.32610
# [17]	validation_0-rmse:0.64603	validation_1-rmse:1.30920
# [18]	validation_0-rmse:0.63501	validation_1-rmse:1.30888
# [19]	validation_0-rmse:0.62646	validation_1-rmse:1.30796
# [20]	validation_0-rmse:0.61461	validation_1-rmse:1.31294
# [21]	validation_0-rmse:0.59703	validation_1-rmse:1.34327
# [22]	validation_0-rmse:0.58163	validation_1-rmse:1.33135
# [23]	validation_0-rmse:0.57186	validation_1-rmse:1.33301
# [24]	validation_0-rmse:0.56710	validation_1-rmse:1.34256
# [25]	validation_0-rmse:0.54935	validation_1-rmse:1.33436
# [26]	validation_0-rmse:0.54087	validation_1-rmse:1.34061
# [27]	validation_0-rmse:0.52842	validation_1-rmse:1.32798
# [28]	validation_0-rmse:0.52222	validation_1-rmse:1.32068
# [29]	validation_0-rmse:0.51133	validation_1-rmse:1.33005
# [0]	validation_0-rmse:4.95687	validation_1-rmse:4.69081
# [1]	validation_0-rmse:3.64337	validation_1-rmse:3.47412
# [2]	validation_0-rmse:2.66812	validation_1-rmse:2.59686
# [3]	validation_0-rmse:2.01169	validation_1-rmse:2.01724
# [4]	validation_0-rmse:1.60130	validation_1-rmse:1.63131
# [5]	validation_0-rmse:1.32457	validation_1-rmse:1.30836
# [6]	validation_0-rmse:1.12019	validation_1-rmse:1.14877
# [7]	validation_0-rmse:1.01131	validation_1-rmse:1.08620
# [8]	validation_0-rmse:0.92847	validation_1-rmse:1.01163
# [9]	validation_0-rmse:0.86513	validation_1-rmse:0.96166
# [10]	validation_0-rmse:0.82268	validation_1-rmse:0.91170
# [11]	validation_0-rmse:0.78694	validation_1-rmse:0.88465
# [12]	validation_0-rmse:0.77772	validation_1-rmse:0.87329
# [13]	validation_0-rmse:0.74491	validation_1-rmse:0.89990
# [14]	validation_0-rmse:0.71875	validation_1-rmse:0.87613
# [15]	validation_0-rmse:0.70136	validation_1-rmse:0.87771
# [16]	validation_0-rmse:0.66341	validation_1-rmse:0.84177
# [17]	validation_0-rmse:0.64753	validation_1-rmse:0.84354
# [18]	validation_0-rmse:0.63622	validation_1-rmse:0.84752
# [19]	validation_0-rmse:0.61663	validation_1-rmse:0.83463
# [20]	validation_0-rmse:0.60712	validation_1-rmse:0.85098
# [21]	validation_0-rmse:0.59274	validation_1-rmse:0.86431
# [22]	validation_0-rmse:0.57967	validation_1-rmse:0.86072
# [23]	validation_0-rmse:0.57795	validation_1-rmse:0.87120
# [24]	validation_0-rmse:0.56672	validation_1-rmse:0.90538
# [25]	validation_0-rmse:0.56258	validation_1-rmse:0.88721
# [26]	validation_0-rmse:0.56232	validation_1-rmse:0.90182
# [27]	validation_0-rmse:0.55255	validation_1-rmse:0.92343
# [28]	validation_0-rmse:0.53710	validation_1-rmse:0.92573
# [29]	validation_0-rmse:0.52758	validation_1-rmse:0.92073
# [0]	validation_0-rmse:4.91378	validation_1-rmse:5.11797
# [1]	validation_0-rmse:3.64902	validation_1-rmse:3.82357
# [2]	validation_0-rmse:2.64909	validation_1-rmse:2.84216
# [3]	validation_0-rmse:2.03734	validation_1-rmse:2.29799
# [4]	validation_0-rmse:1.61236	validation_1-rmse:1.88847
# [5]	validation_0-rmse:1.33004	validation_1-rmse:1.62368
# [6]	validation_0-rmse:1.17458	validation_1-rmse:1.43569
# [7]	validation_0-rmse:0.99747	validation_1-rmse:1.27850
# [8]	validation_0-rmse:0.88978	validation_1-rmse:1.20830
# [9]	validation_0-rmse:0.83937	validation_1-rmse:1.12269
# [10]	validation_0-rmse:0.79363	validation_1-rmse:1.15417
# [11]	validation_0-rmse:0.73992	validation_1-rmse:1.09722
# [12]	validation_0-rmse:0.72088	validation_1-rmse:1.07093
# [13]	validation_0-rmse:0.71221	validation_1-rmse:1.10171
# [14]	validation_0-rmse:0.69871	validation_1-rmse:1.08591
# [15]	validation_0-rmse:0.67216	validation_1-rmse:1.04304
# [16]	validation_0-rmse:0.66659	validation_1-rmse:1.06085
# [17]	validation_0-rmse:0.64851	validation_1-rmse:1.06224
# [18]	validation_0-rmse:0.63795	validation_1-rmse:1.05566
# [19]	validation_0-rmse:0.62242	validation_1-rmse:1.03206
# [20]	validation_0-rmse:0.60680	validation_1-rmse:1.01052
# [21]	validation_0-rmse:0.59554	validation_1-rmse:1.00179
# [22]	validation_0-rmse:0.58523	validation_1-rmse:1.00137
# [23]	validation_0-rmse:0.57814	validation_1-rmse:1.00691
# [24]	validation_0-rmse:0.57405	validation_1-rmse:1.01883
# [25]	validation_0-rmse:0.56000	validation_1-rmse:1.01933
# [26]	validation_0-rmse:0.55168	validation_1-rmse:1.02360
# [27]	validation_0-rmse:0.53862	validation_1-rmse:1.02045
# [28]	validation_0-rmse:0.52240	validation_1-rmse:1.01418
# [29]	validation_0-rmse:0.51628	validation_1-rmse:1.01438
# [30]	validation_0-rmse:0.51076	validation_1-rmse:0.99447
# [31]	validation_0-rmse:0.49809	validation_1-rmse:0.99387
# [32]	validation_0-rmse:0.49759	validation_1-rmse:0.99609
# [33]	validation_0-rmse:0.49100	validation_1-rmse:1.00750
# [34]	validation_0-rmse:0.48744	validation_1-rmse:1.01256
# [35]	validation_0-rmse:0.47933	validation_1-rmse:0.98423
# [36]	validation_0-rmse:0.47511	validation_1-rmse:1.00508
# [37]	validation_0-rmse:0.47436	validation_1-rmse:1.01685
# [38]	validation_0-rmse:0.46154	validation_1-rmse:1.01709
# [39]	validation_0-rmse:0.46215	validation_1-rmse:1.03869
# [40]	validation_0-rmse:0.45636	validation_1-rmse:1.01333
# [41]	validation_0-rmse:0.45051	validation_1-rmse:1.03383
# [42]	validation_0-rmse:0.44312	validation_1-rmse:1.02111
# [43]	validation_0-rmse:0.43693	validation_1-rmse:1.03271
# [44]	validation_0-rmse:0.42396	validation_1-rmse:1.02165
# [45]	validation_0-rmse:0.41846	validation_1-rmse:1.02807
# [0]	validation_0-rmse:4.85738	validation_1-rmse:5.13411
# [1]	validation_0-rmse:3.56769	validation_1-rmse:3.74679
# [2]	validation_0-rmse:2.63607	validation_1-rmse:2.70831
# [3]	validation_0-rmse:2.02202	validation_1-rmse:2.04891
# [4]	validation_0-rmse:1.61908	validation_1-rmse:1.63254
# [5]	validation_0-rmse:1.29724	validation_1-rmse:1.32453
# [6]	validation_0-rmse:1.09076	validation_1-rmse:1.09558
# [7]	validation_0-rmse:0.98006	validation_1-rmse:0.95690
# [8]	validation_0-rmse:0.90789	validation_1-rmse:0.88633
# [9]	validation_0-rmse:0.85985	validation_1-rmse:0.87101
# [10]	validation_0-rmse:0.81635	validation_1-rmse:0.88333
# [11]	validation_0-rmse:0.76114	validation_1-rmse:0.86109
# [12]	validation_0-rmse:0.73946	validation_1-rmse:0.88643
# [13]	validation_0-rmse:0.72408	validation_1-rmse:0.87157
# [14]	validation_0-rmse:0.70459	validation_1-rmse:0.86940
# [15]	validation_0-rmse:0.69458	validation_1-rmse:0.85169
# [16]	validation_0-rmse:0.68503	validation_1-rmse:0.86399
# [17]	validation_0-rmse:0.67620	validation_1-rmse:0.84306
# [18]	validation_0-rmse:0.66317	validation_1-rmse:0.83334
# [19]	validation_0-rmse:0.65381	validation_1-rmse:0.82187
# [20]	validation_0-rmse:0.64254	validation_1-rmse:0.83622
# [21]	validation_0-rmse:0.62779	validation_1-rmse:0.85413
# [22]	validation_0-rmse:0.61982	validation_1-rmse:0.87590
# [23]	validation_0-rmse:0.61398	validation_1-rmse:0.86804
# [24]	validation_0-rmse:0.61157	validation_1-rmse:0.87486
# [25]	validation_0-rmse:0.59213	validation_1-rmse:0.85526
# [26]	validation_0-rmse:0.58574	validation_1-rmse:0.86298
# [27]	validation_0-rmse:0.56462	validation_1-rmse:0.86183
# [28]	validation_0-rmse:0.54579	validation_1-rmse:0.86619
# [0]	validation_0-rmse:4.97119	validation_1-rmse:4.52281
# [1]	validation_0-rmse:3.65423	validation_1-rmse:3.35034
# [2]	validation_0-rmse:2.70303	validation_1-rmse:2.55084
# [3]	validation_0-rmse:2.06167	validation_1-rmse:2.06667
# [4]	validation_0-rmse:1.61337	validation_1-rmse:1.76302
# [5]	validation_0-rmse:1.28461	validation_1-rmse:1.55831
# [6]	validation_0-rmse:1.09026	validation_1-rmse:1.52264
# [7]	validation_0-rmse:0.92578	validation_1-rmse:1.48420
# [8]	validation_0-rmse:0.84120	validation_1-rmse:1.44796
# [9]	validation_0-rmse:0.78621	validation_1-rmse:1.48136
# [10]	validation_0-rmse:0.76310	validation_1-rmse:1.46069
# [11]	validation_0-rmse:0.72264	validation_1-rmse:1.49140
# [12]	validation_0-rmse:0.70669	validation_1-rmse:1.50185
# [13]	validation_0-rmse:0.69994	validation_1-rmse:1.51051
# [14]	validation_0-rmse:0.66319	validation_1-rmse:1.50127
# [15]	validation_0-rmse:0.64776	validation_1-rmse:1.49535
# [16]	validation_0-rmse:0.63098	validation_1-rmse:1.47596
# [17]	validation_0-rmse:0.61265	validation_1-rmse:1.46871
# [18]	validation_0-rmse:0.59843	validation_1-rmse:1.45390
# [0]	validation_0-rmse:4.92864	validation_1-rmse:4.91670
# [1]	validation_0-rmse:3.66795	validation_1-rmse:3.63883
# [2]	validation_0-rmse:2.70352	validation_1-rmse:2.62474
# [3]	validation_0-rmse:2.09751	validation_1-rmse:1.97609
# [4]	validation_0-rmse:1.67010	validation_1-rmse:1.46443
# [5]	validation_0-rmse:1.40930	validation_1-rmse:1.22317
# [6]	validation_0-rmse:1.19934	validation_1-rmse:0.98975
# [7]	validation_0-rmse:1.04686	validation_1-rmse:0.85658
# [8]	validation_0-rmse:0.94778	validation_1-rmse:0.76023
# [9]	validation_0-rmse:0.90404	validation_1-rmse:0.75914
# [10]	validation_0-rmse:0.85383	validation_1-rmse:0.75282
# [11]	validation_0-rmse:0.81191	validation_1-rmse:0.80565
# [12]	validation_0-rmse:0.79524	validation_1-rmse:0.78851
# [13]	validation_0-rmse:0.78563	validation_1-rmse:0.78521
# [14]	validation_0-rmse:0.77932	validation_1-rmse:0.74759
# [15]	validation_0-rmse:0.75231	validation_1-rmse:0.76490
# [16]	validation_0-rmse:0.72238	validation_1-rmse:0.76852
# [17]	validation_0-rmse:0.69815	validation_1-rmse:0.77078
# [18]	validation_0-rmse:0.68492	validation_1-rmse:0.78408
# [19]	validation_0-rmse:0.67627	validation_1-rmse:0.77902
# [20]	validation_0-rmse:0.66549	validation_1-rmse:0.78593
# [21]	validation_0-rmse:0.66208	validation_1-rmse:0.80021
# [22]	validation_0-rmse:0.65407	validation_1-rmse:0.78294
# [23]	validation_0-rmse:0.65009	validation_1-rmse:0.80401
# [24]	validation_0-rmse:0.63368	validation_1-rmse:0.79607
# [0]	validation_0-rmse:4.89316	validation_1-rmse:4.92294
# [1]	validation_0-rmse:3.55542	validation_1-rmse:3.60701
# [2]	validation_0-rmse:2.64018	validation_1-rmse:2.69414
# [3]	validation_0-rmse:1.97716	validation_1-rmse:2.09224
# [4]	validation_0-rmse:1.56290	validation_1-rmse:1.69954
# [5]	validation_0-rmse:1.25753	validation_1-rmse:1.42481
# [6]	validation_0-rmse:1.05660	validation_1-rmse:1.27030
# [7]	validation_0-rmse:0.92828	validation_1-rmse:1.13767
# [8]	validation_0-rmse:0.84620	validation_1-rmse:1.06537
# [9]	validation_0-rmse:0.80503	validation_1-rmse:1.07657
# [10]	validation_0-rmse:0.77491	validation_1-rmse:1.05186
# [11]	validation_0-rmse:0.73359	validation_1-rmse:1.06563
# [12]	validation_0-rmse:0.69891	validation_1-rmse:1.06687
# [13]	validation_0-rmse:0.67801	validation_1-rmse:1.07376
# [14]	validation_0-rmse:0.66196	validation_1-rmse:1.08059
# [15]	validation_0-rmse:0.65412	validation_1-rmse:1.08011
# [16]	validation_0-rmse:0.64897	validation_1-rmse:1.09828
# [17]	validation_0-rmse:0.63577	validation_1-rmse:1.08665
# [18]	validation_0-rmse:0.61233	validation_1-rmse:1.08797
# [19]	validation_0-rmse:0.59608	validation_1-rmse:1.09232
# [20]	validation_0-rmse:0.59288	validation_1-rmse:1.10471
# [0]	validation_0-rmse:4.87320	validation_1-rmse:4.71180
# [1]	validation_0-rmse:3.58966	validation_1-rmse:3.39792
# [2]	validation_0-rmse:2.62554	validation_1-rmse:2.50989
# [3]	validation_0-rmse:2.01970	validation_1-rmse:1.98407
# [4]	validation_0-rmse:1.58154	validation_1-rmse:1.65580
# [5]	validation_0-rmse:1.26212	validation_1-rmse:1.47536
# [6]	validation_0-rmse:1.04230	validation_1-rmse:1.33929
# [7]	validation_0-rmse:0.91061	validation_1-rmse:1.30551
# [8]	validation_0-rmse:0.82193	validation_1-rmse:1.28929
# [9]	validation_0-rmse:0.77340	validation_1-rmse:1.29365
# [10]	validation_0-rmse:0.73414	validation_1-rmse:1.34489
# [11]	validation_0-rmse:0.71723	validation_1-rmse:1.37403
# [12]	validation_0-rmse:0.67148	validation_1-rmse:1.38547
# [13]	validation_0-rmse:0.65177	validation_1-rmse:1.40801
# [14]	validation_0-rmse:0.63283	validation_1-rmse:1.41347
# [15]	validation_0-rmse:0.61922	validation_1-rmse:1.42845
# [16]	validation_0-rmse:0.60682	validation_1-rmse:1.42877
# [17]	validation_0-rmse:0.59291	validation_1-rmse:1.41161
# [18]	validation_0-rmse:0.58077	validation_1-rmse:1.40255
# [0]	validation_0-rmse:4.84551	validation_1-rmse:5.14491
# [1]	validation_0-rmse:3.54620	validation_1-rmse:3.81714
# [2]	validation_0-rmse:2.68276	validation_1-rmse:2.87070
# [3]	validation_0-rmse:2.09468	validation_1-rmse:2.25487
# [4]	validation_0-rmse:1.67229	validation_1-rmse:1.81890
# [5]	validation_0-rmse:1.34054	validation_1-rmse:1.52994
# [6]	validation_0-rmse:1.11704	validation_1-rmse:1.27414
# [7]	validation_0-rmse:1.00452	validation_1-rmse:1.16088
# [8]	validation_0-rmse:0.93778	validation_1-rmse:1.16307
# [9]	validation_0-rmse:0.90468	validation_1-rmse:1.17824
# [10]	validation_0-rmse:0.88816	validation_1-rmse:1.18672
# [11]	validation_0-rmse:0.84235	validation_1-rmse:1.13366
# [12]	validation_0-rmse:0.80993	validation_1-rmse:1.15466
# [13]	validation_0-rmse:0.80302	validation_1-rmse:1.16341
# [14]	validation_0-rmse:0.79100	validation_1-rmse:1.14447
# [15]	validation_0-rmse:0.75987	validation_1-rmse:1.12527
# [16]	validation_0-rmse:0.75568	validation_1-rmse:1.12077
# [17]	validation_0-rmse:0.73135	validation_1-rmse:1.11655
# [18]	validation_0-rmse:0.71466	validation_1-rmse:1.10600
# [19]	validation_0-rmse:0.69652	validation_1-rmse:1.11930
# [20]	validation_0-rmse:0.68718	validation_1-rmse:1.11224
# [21]	validation_0-rmse:0.67583	validation_1-rmse:1.09730
# [22]	validation_0-rmse:0.66777	validation_1-rmse:1.08549
# [23]	validation_0-rmse:0.64600	validation_1-rmse:1.07558
# [24]	validation_0-rmse:0.63227	validation_1-rmse:1.05774
# [25]	validation_0-rmse:0.62481	validation_1-rmse:1.05423
# [26]	validation_0-rmse:0.60795	validation_1-rmse:1.06672
# [27]	validation_0-rmse:0.60644	validation_1-rmse:1.07281
# [28]	validation_0-rmse:0.58762	validation_1-rmse:1.08365
# [29]	validation_0-rmse:0.57441	validation_1-rmse:1.08164
# [30]	validation_0-rmse:0.56447	validation_1-rmse:1.07289
# [31]	validation_0-rmse:0.55327	validation_1-rmse:1.05325
# [32]	validation_0-rmse:0.54665	validation_1-rmse:1.05161
# [33]	validation_0-rmse:0.53379	validation_1-rmse:1.05002
# [34]	validation_0-rmse:0.52611	validation_1-rmse:1.04869
# [35]	validation_0-rmse:0.51771	validation_1-rmse:1.04056
# [36]	validation_0-rmse:0.50729	validation_1-rmse:1.05856
# [37]	validation_0-rmse:0.49707	validation_1-rmse:1.06341
# [38]	validation_0-rmse:0.48865	validation_1-rmse:1.07125
# [39]	validation_0-rmse:0.48489	validation_1-rmse:1.06707
# [40]	validation_0-rmse:0.47649	validation_1-rmse:1.06914
# [41]	validation_0-rmse:0.46664	validation_1-rmse:1.05523
# [42]	validation_0-rmse:0.45736	validation_1-rmse:1.06587
# [43]	validation_0-rmse:0.45390	validation_1-rmse:1.04501
# [44]	validation_0-rmse:0.44579	validation_1-rmse:1.04666
# [0]	validation_0-rmse:4.83582	validation_1-rmse:5.18744
# [1]	validation_0-rmse:3.51995	validation_1-rmse:3.97737
# [2]	validation_0-rmse:2.60802	validation_1-rmse:3.00631
# [3]	validation_0-rmse:2.01444	validation_1-rmse:2.51987
# [4]	validation_0-rmse:1.57588	validation_1-rmse:2.16078
# [5]	validation_0-rmse:1.29215	validation_1-rmse:1.87422
# [6]	validation_0-rmse:1.05777	validation_1-rmse:1.61638
# [7]	validation_0-rmse:0.93331	validation_1-rmse:1.48464
# [8]	validation_0-rmse:0.83840	validation_1-rmse:1.35738
# [9]	validation_0-rmse:0.77817	validation_1-rmse:1.29350
# [10]	validation_0-rmse:0.76493	validation_1-rmse:1.24317
# [11]	validation_0-rmse:0.74298	validation_1-rmse:1.22494
# [12]	validation_0-rmse:0.71789	validation_1-rmse:1.19103
# [13]	validation_0-rmse:0.71029	validation_1-rmse:1.19483
# [14]	validation_0-rmse:0.69464	validation_1-rmse:1.20152
# [15]	validation_0-rmse:0.68200	validation_1-rmse:1.20048
# [16]	validation_0-rmse:0.64997	validation_1-rmse:1.18069
# [17]	validation_0-rmse:0.62848	validation_1-rmse:1.20288
# [18]	validation_0-rmse:0.61286	validation_1-rmse:1.17135
# [19]	validation_0-rmse:0.60296	validation_1-rmse:1.16318
# [20]	validation_0-rmse:0.58003	validation_1-rmse:1.11501
# [21]	validation_0-rmse:0.57244	validation_1-rmse:1.12327
# [22]	validation_0-rmse:0.56846	validation_1-rmse:1.11869
# [23]	validation_0-rmse:0.56651	validation_1-rmse:1.12289
# [24]	validation_0-rmse:0.55610	validation_1-rmse:1.12871
# [25]	validation_0-rmse:0.55180	validation_1-rmse:1.15319
# [26]	validation_0-rmse:0.54106	validation_1-rmse:1.15169
# [27]	validation_0-rmse:0.53221	validation_1-rmse:1.14786
# [28]	validation_0-rmse:0.51992	validation_1-rmse:1.15331
# [29]	validation_0-rmse:0.51907	validation_1-rmse:1.14042
# [30]	validation_0-rmse:0.51712	validation_1-rmse:1.14696
# [0]	validation_0-rmse:4.91150	validation_1-rmse:4.78930
# [1]	validation_0-rmse:3.63785	validation_1-rmse:3.49325
# [2]	validation_0-rmse:2.71926	validation_1-rmse:2.50678
# [3]	validation_0-rmse:2.11450	validation_1-rmse:1.84584
# [4]	validation_0-rmse:1.72916	validation_1-rmse:1.49177
# [5]	validation_0-rmse:1.44749	validation_1-rmse:1.19069
# [6]	validation_0-rmse:1.18978	validation_1-rmse:0.95362
# [7]	validation_0-rmse:1.04151	validation_1-rmse:0.83699
# [8]	validation_0-rmse:0.94084	validation_1-rmse:0.73191
# [9]	validation_0-rmse:0.86516	validation_1-rmse:0.73580
# [10]	validation_0-rmse:0.83554	validation_1-rmse:0.72954
# [11]	validation_0-rmse:0.80001	validation_1-rmse:0.64326
# [12]	validation_0-rmse:0.77064	validation_1-rmse:0.61955
# [13]	validation_0-rmse:0.75071	validation_1-rmse:0.63808
# [14]	validation_0-rmse:0.73876	validation_1-rmse:0.63261
# [15]	validation_0-rmse:0.72258	validation_1-rmse:0.64166
# [16]	validation_0-rmse:0.70801	validation_1-rmse:0.64214
# [17]	validation_0-rmse:0.69397	validation_1-rmse:0.64333
# [18]	validation_0-rmse:0.68922	validation_1-rmse:0.63540
# [19]	validation_0-rmse:0.68135	validation_1-rmse:0.62036
# [20]	validation_0-rmse:0.64976	validation_1-rmse:0.58916
# [21]	validation_0-rmse:0.62294	validation_1-rmse:0.62325
# [22]	validation_0-rmse:0.61276	validation_1-rmse:0.62567
# [23]	validation_0-rmse:0.60267	validation_1-rmse:0.66161
# [24]	validation_0-rmse:0.59512	validation_1-rmse:0.65947
# [25]	validation_0-rmse:0.58079	validation_1-rmse:0.66904
# [26]	validation_0-rmse:0.57383	validation_1-rmse:0.66240
# [27]	validation_0-rmse:0.56117	validation_1-rmse:0.66798
# [28]	validation_0-rmse:0.55400	validation_1-rmse:0.65763
# [29]	validation_0-rmse:0.55047	validation_1-rmse:0.67913
# [30]	validation_0-rmse:0.54210	validation_1-rmse:0.66122
# [0]	validation_0-rmse:4.92642	validation_1-rmse:4.82865
# [1]	validation_0-rmse:3.60154	validation_1-rmse:3.60813
# [2]	validation_0-rmse:2.66408	validation_1-rmse:2.70177
# [3]	validation_0-rmse:2.06631	validation_1-rmse:2.16647
# [4]	validation_0-rmse:1.65789	validation_1-rmse:1.77828
# [5]	validation_0-rmse:1.36146	validation_1-rmse:1.56349
# [6]	validation_0-rmse:1.12328	validation_1-rmse:1.36381
# [7]	validation_0-rmse:0.99171	validation_1-rmse:1.26012
# [8]	validation_0-rmse:0.90242	validation_1-rmse:1.19438
# [9]	validation_0-rmse:0.87200	validation_1-rmse:1.15877
# [10]	validation_0-rmse:0.82126	validation_1-rmse:1.17603
# [11]	validation_0-rmse:0.79447	validation_1-rmse:1.15386
# [12]	validation_0-rmse:0.77280	validation_1-rmse:1.10977
# [13]	validation_0-rmse:0.76865	validation_1-rmse:1.11836
# [14]	validation_0-rmse:0.75618	validation_1-rmse:1.11622
# [15]	validation_0-rmse:0.72899	validation_1-rmse:1.08913
# [16]	validation_0-rmse:0.71309	validation_1-rmse:1.08513
# [17]	validation_0-rmse:0.68409	validation_1-rmse:1.09108
# [18]	validation_0-rmse:0.68255	validation_1-rmse:1.12875
# [19]	validation_0-rmse:0.67352	validation_1-rmse:1.12779
# [20]	validation_0-rmse:0.66567	validation_1-rmse:1.12575
# [21]	validation_0-rmse:0.65365	validation_1-rmse:1.13106
# [22]	validation_0-rmse:0.63974	validation_1-rmse:1.13046
# [23]	validation_0-rmse:0.61794	validation_1-rmse:1.10187
# [24]	validation_0-rmse:0.60798	validation_1-rmse:1.09299
# [25]	validation_0-rmse:0.60795	validation_1-rmse:1.08930
# [26]	validation_0-rmse:0.60189	validation_1-rmse:1.09676
# [0]	validation_0-rmse:4.90462	validation_1-rmse:5.02593
# [1]	validation_0-rmse:3.56574	validation_1-rmse:3.69163
# [2]	validation_0-rmse:2.62644	validation_1-rmse:2.69630
# [3]	validation_0-rmse:2.02214	validation_1-rmse:2.10339
# [4]	validation_0-rmse:1.61541	validation_1-rmse:1.70092
# [5]	validation_0-rmse:1.36877	validation_1-rmse:1.48611
# [6]	validation_0-rmse:1.16386	validation_1-rmse:1.31848
# [7]	validation_0-rmse:1.06197	validation_1-rmse:1.19966
# [8]	validation_0-rmse:0.98442	validation_1-rmse:1.13673
# [9]	validation_0-rmse:0.93117	validation_1-rmse:1.12743
# [10]	validation_0-rmse:0.89443	validation_1-rmse:1.14134
# [11]	validation_0-rmse:0.83385	validation_1-rmse:1.16349
# [12]	validation_0-rmse:0.80758	validation_1-rmse:1.19157
# [13]	validation_0-rmse:0.79699	validation_1-rmse:1.20332
# [14]	validation_0-rmse:0.74164	validation_1-rmse:1.23600
# [15]	validation_0-rmse:0.70731	validation_1-rmse:1.27310
# [16]	validation_0-rmse:0.69106	validation_1-rmse:1.29882
# [17]	validation_0-rmse:0.67551	validation_1-rmse:1.31834
# [18]	validation_0-rmse:0.66542	validation_1-rmse:1.29271
# [0]	validation_0-rmse:4.74446	validation_1-rmse:5.52462
# [1]	validation_0-rmse:3.44993	validation_1-rmse:4.22971
# [2]	validation_0-rmse:2.59149	validation_1-rmse:3.38038
# [3]	validation_0-rmse:1.98951	validation_1-rmse:2.70809
# [4]	validation_0-rmse:1.58329	validation_1-rmse:2.24224
# [5]	validation_0-rmse:1.30852	validation_1-rmse:1.93066
# [6]	validation_0-rmse:1.10320	validation_1-rmse:1.62705
# [7]	validation_0-rmse:0.98965	validation_1-rmse:1.44767
# [8]	validation_0-rmse:0.89917	validation_1-rmse:1.29700
# [9]	validation_0-rmse:0.81583	validation_1-rmse:1.21979
# [10]	validation_0-rmse:0.78412	validation_1-rmse:1.18100
# [11]	validation_0-rmse:0.74122	validation_1-rmse:1.16099
# [12]	validation_0-rmse:0.71617	validation_1-rmse:1.17992
# [13]	validation_0-rmse:0.69213	validation_1-rmse:1.17578
# [14]	validation_0-rmse:0.68359	validation_1-rmse:1.16305
# [15]	validation_0-rmse:0.66511	validation_1-rmse:1.16478
# [16]	validation_0-rmse:0.65291	validation_1-rmse:1.16726
# [17]	validation_0-rmse:0.63215	validation_1-rmse:1.15595
# [18]	validation_0-rmse:0.62344	validation_1-rmse:1.13821
# [19]	validation_0-rmse:0.61156	validation_1-rmse:1.13098
# [20]	validation_0-rmse:0.59127	validation_1-rmse:1.13899
# [21]	validation_0-rmse:0.57297	validation_1-rmse:1.12738
# [22]	validation_0-rmse:0.55269	validation_1-rmse:1.13209
# [23]	validation_0-rmse:0.54045	validation_1-rmse:1.13053
# [24]	validation_0-rmse:0.52079	validation_1-rmse:1.11581
# [25]	validation_0-rmse:0.51053	validation_1-rmse:1.12009
# [26]	validation_0-rmse:0.50224	validation_1-rmse:1.14457
# [27]	validation_0-rmse:0.47772	validation_1-rmse:1.18790
# [28]	validation_0-rmse:0.47075	validation_1-rmse:1.19392
# [29]	validation_0-rmse:0.46784	validation_1-rmse:1.19638
# [30]	validation_0-rmse:0.46256	validation_1-rmse:1.18894
# [31]	validation_0-rmse:0.45866	validation_1-rmse:1.17351
# [32]	validation_0-rmse:0.45349	validation_1-rmse:1.17151
# [33]	validation_0-rmse:0.44342	validation_1-rmse:1.16586
# [0]	validation_0-rmse:4.84715	validation_1-rmse:5.10557
# [1]	validation_0-rmse:3.51239	validation_1-rmse:3.76377
# [2]	validation_0-rmse:2.62357	validation_1-rmse:2.82651
# [3]	validation_0-rmse:1.98146	validation_1-rmse:2.13630
# [4]	validation_0-rmse:1.61607	validation_1-rmse:1.69644
# [5]	validation_0-rmse:1.34159	validation_1-rmse:1.38643
# [6]	validation_0-rmse:1.17970	validation_1-rmse:1.17331
# [7]	validation_0-rmse:1.06216	validation_1-rmse:0.99841
# [8]	validation_0-rmse:0.97759	validation_1-rmse:0.88704
# [9]	validation_0-rmse:0.90175	validation_1-rmse:0.85414
# [10]	validation_0-rmse:0.88047	validation_1-rmse:0.80046
# [11]	validation_0-rmse:0.83483	validation_1-rmse:0.74017
# [12]	validation_0-rmse:0.81552	validation_1-rmse:0.73178
# [13]	validation_0-rmse:0.79345	validation_1-rmse:0.72406
# [14]	validation_0-rmse:0.75945	validation_1-rmse:0.69362
# [15]	validation_0-rmse:0.74244	validation_1-rmse:0.71299
# [16]	validation_0-rmse:0.72453	validation_1-rmse:0.70309
# [17]	validation_0-rmse:0.70315	validation_1-rmse:0.69609
# [18]	validation_0-rmse:0.69444	validation_1-rmse:0.73823
# [19]	validation_0-rmse:0.68498	validation_1-rmse:0.72250
# [20]	validation_0-rmse:0.67436	validation_1-rmse:0.73468
# [21]	validation_0-rmse:0.66282	validation_1-rmse:0.73115
# [22]	validation_0-rmse:0.65964	validation_1-rmse:0.72579
# [23]	validation_0-rmse:0.65482	validation_1-rmse:0.70471
# [0]	validation_0-rmse:4.98383	validation_1-rmse:4.36483
# [1]	validation_0-rmse:3.65649	validation_1-rmse:3.02296
# [2]	validation_0-rmse:2.70320	validation_1-rmse:2.22392
# [3]	validation_0-rmse:2.07615	validation_1-rmse:1.69036
# [4]	validation_0-rmse:1.62654	validation_1-rmse:1.33612
# [5]	validation_0-rmse:1.27646	validation_1-rmse:1.09258
# [6]	validation_0-rmse:1.08104	validation_1-rmse:1.01395
# [7]	validation_0-rmse:0.92817	validation_1-rmse:1.03128
# [8]	validation_0-rmse:0.84807	validation_1-rmse:1.01950
# [9]	validation_0-rmse:0.79627	validation_1-rmse:1.03919
# [10]	validation_0-rmse:0.77371	validation_1-rmse:1.04842
# [11]	validation_0-rmse:0.73931	validation_1-rmse:1.05287
# [12]	validation_0-rmse:0.70599	validation_1-rmse:1.07234
# [13]	validation_0-rmse:0.68900	validation_1-rmse:1.08834
# [14]	validation_0-rmse:0.68255	validation_1-rmse:1.09791
# [15]	validation_0-rmse:0.66657	validation_1-rmse:1.06212
# [0]	validation_0-rmse:4.89133	validation_1-rmse:5.09432
# [1]	validation_0-rmse:3.59705	validation_1-rmse:3.75957
# [2]	validation_0-rmse:2.69064	validation_1-rmse:2.84158
# [3]	validation_0-rmse:2.06033	validation_1-rmse:2.27621
# [4]	validation_0-rmse:1.60963	validation_1-rmse:1.84072
# [5]	validation_0-rmse:1.31641	validation_1-rmse:1.44571
# [6]	validation_0-rmse:1.11450	validation_1-rmse:1.28055
# [7]	validation_0-rmse:0.98615	validation_1-rmse:1.15136
# [8]	validation_0-rmse:0.90807	validation_1-rmse:1.04470
# [9]	validation_0-rmse:0.86311	validation_1-rmse:0.97556
# [10]	validation_0-rmse:0.83906	validation_1-rmse:0.95132
# [11]	validation_0-rmse:0.79062	validation_1-rmse:0.92999
# [12]	validation_0-rmse:0.77805	validation_1-rmse:0.89263
# [13]	validation_0-rmse:0.77146	validation_1-rmse:0.90732
# [14]	validation_0-rmse:0.74704	validation_1-rmse:0.91578
# [15]	validation_0-rmse:0.71373	validation_1-rmse:0.89535
# [16]	validation_0-rmse:0.70210	validation_1-rmse:0.91095
# [17]	validation_0-rmse:0.67161	validation_1-rmse:0.90907
# [18]	validation_0-rmse:0.65551	validation_1-rmse:0.89968
# [19]	validation_0-rmse:0.64949	validation_1-rmse:0.90765
# [20]	validation_0-rmse:0.62494	validation_1-rmse:0.88272
# [21]	validation_0-rmse:0.60098	validation_1-rmse:0.89094
# [22]	validation_0-rmse:0.58382	validation_1-rmse:0.90300
# [23]	validation_0-rmse:0.56948	validation_1-rmse:0.90077
# [24]	validation_0-rmse:0.56176	validation_1-rmse:0.90536
# [25]	validation_0-rmse:0.54539	validation_1-rmse:0.89879
# [26]	validation_0-rmse:0.53243	validation_1-rmse:0.89262
# [27]	validation_0-rmse:0.52046	validation_1-rmse:0.89362
# [28]	validation_0-rmse:0.49823	validation_1-rmse:0.90720
# [29]	validation_0-rmse:0.49306	validation_1-rmse:0.91177
# [30]	validation_0-rmse:0.48129	validation_1-rmse:0.92561
# [0]	validation_0-rmse:4.86427	validation_1-rmse:5.04019
# [1]	validation_0-rmse:3.61652	validation_1-rmse:3.89963
# [2]	validation_0-rmse:2.67463	validation_1-rmse:2.94201
# [3]	validation_0-rmse:2.04514	validation_1-rmse:2.38138
# [4]	validation_0-rmse:1.64343	validation_1-rmse:2.05459
# [5]	validation_0-rmse:1.32271	validation_1-rmse:1.78898
# [6]	validation_0-rmse:1.10648	validation_1-rmse:1.53330
# [7]	validation_0-rmse:0.96736	validation_1-rmse:1.38320
# [8]	validation_0-rmse:0.88019	validation_1-rmse:1.28447
# [9]	validation_0-rmse:0.84028	validation_1-rmse:1.22574
# [10]	validation_0-rmse:0.81721	validation_1-rmse:1.20055
# [11]	validation_0-rmse:0.78849	validation_1-rmse:1.18807
# [12]	validation_0-rmse:0.72263	validation_1-rmse:1.17661
# [13]	validation_0-rmse:0.71125	validation_1-rmse:1.19054
# [14]	validation_0-rmse:0.69577	validation_1-rmse:1.16976
# [15]	validation_0-rmse:0.66815	validation_1-rmse:1.06297
# [16]	validation_0-rmse:0.65437	validation_1-rmse:1.10062
# [17]	validation_0-rmse:0.64736	validation_1-rmse:1.07237
# [18]	validation_0-rmse:0.64095	validation_1-rmse:1.08613
# [19]	validation_0-rmse:0.62993	validation_1-rmse:1.08226
# [20]	validation_0-rmse:0.62250	validation_1-rmse:1.08045
# [21]	validation_0-rmse:0.59790	validation_1-rmse:1.07445
# [22]	validation_0-rmse:0.57929	validation_1-rmse:1.06116
# [23]	validation_0-rmse:0.57657	validation_1-rmse:1.06687
# [24]	validation_0-rmse:0.56237	validation_1-rmse:1.06395
# [25]	validation_0-rmse:0.55562	validation_1-rmse:1.06764
# [26]	validation_0-rmse:0.54902	validation_1-rmse:1.07261
# [27]	validation_0-rmse:0.54546	validation_1-rmse:1.07269
# [28]	validation_0-rmse:0.53164	validation_1-rmse:1.06853
# [29]	validation_0-rmse:0.52644	validation_1-rmse:1.09143
# [30]	validation_0-rmse:0.51713	validation_1-rmse:1.08105
# [31]	validation_0-rmse:0.50867	validation_1-rmse:1.07766
# [32]	validation_0-rmse:0.50422	validation_1-rmse:1.07400
# [0]	validation_0-rmse:4.86274	validation_1-rmse:4.94397
# [1]	validation_0-rmse:3.58490	validation_1-rmse:3.67324
# [2]	validation_0-rmse:2.67680	validation_1-rmse:2.72042
# [3]	validation_0-rmse:2.02902	validation_1-rmse:2.03835
# [4]	validation_0-rmse:1.60839	validation_1-rmse:1.63698
# [5]	validation_0-rmse:1.32228	validation_1-rmse:1.36726
# [6]	validation_0-rmse:1.10171	validation_1-rmse:1.18682
# [7]	validation_0-rmse:0.95784	validation_1-rmse:1.06459
# [8]	validation_0-rmse:0.88344	validation_1-rmse:0.99277
# [9]	validation_0-rmse:0.83040	validation_1-rmse:0.97130
# [10]	validation_0-rmse:0.79739	validation_1-rmse:1.00398
# [11]	validation_0-rmse:0.77215	validation_1-rmse:0.99038
# [12]	validation_0-rmse:0.74272	validation_1-rmse:0.98151
# [13]	validation_0-rmse:0.72757	validation_1-rmse:1.00596
# [14]	validation_0-rmse:0.71334	validation_1-rmse:1.02622
# [15]	validation_0-rmse:0.69072	validation_1-rmse:1.04455
# [16]	validation_0-rmse:0.66362	validation_1-rmse:1.02140
# [17]	validation_0-rmse:0.64773	validation_1-rmse:1.00095
# [18]	validation_0-rmse:0.63868	validation_1-rmse:0.99657
# [19]	validation_0-rmse:0.62332	validation_1-rmse:0.95977
# [20]	validation_0-rmse:0.61051	validation_1-rmse:0.99462
# [21]	validation_0-rmse:0.59188	validation_1-rmse:1.00291
# [22]	validation_0-rmse:0.57920	validation_1-rmse:1.00978
# [23]	validation_0-rmse:0.56847	validation_1-rmse:1.00379
# [24]	validation_0-rmse:0.56306	validation_1-rmse:0.99792
# [25]	validation_0-rmse:0.55450	validation_1-rmse:0.99267
# [26]	validation_0-rmse:0.54749	validation_1-rmse:1.00036
# [27]	validation_0-rmse:0.52948	validation_1-rmse:1.01316
# [28]	validation_0-rmse:0.52655	validation_1-rmse:1.01418
# ...
# [10]	validation_0-rmse:0.82825	validation_1-rmse:1.30853
# [11]	validation_0-rmse:0.79837	validation_1-rmse:1.25553
# [12]	validation_0-rmse:0.77344	validation_1-rmse:1.23882
# [13]	validation_0-rmse:0.75994	validation_1-rmse:1.23903
# [14]	validation_0-rmse:0.74508	validation_1-rmse:1.24074
# [15]	validation_0-rmse:0.72748	validation_1-rmse:1.23531
# [16]	validation_0-rmse:0.71182	validation_1-rmse:1.18373
# [17]	validation_0-rmse:0.69523	validation_1-rmse:1.16301
# [18]	validation_0-rmse:0.69119	validation_1-rmse:1.17313
# [19]	validation_0-rmse:0.67831	validation_1-rmse:1.16690
# [20]	validation_0-rmse:0.66699	validation_1-rmse:1.16631
# [21]	validation_0-rmse:0.64059	validation_1-rmse:1.17140
# [22]	validation_0-rmse:0.63392	validation_1-rmse:1.17902
# [23]	validation_0-rmse:0.62717	validation_1-rmse:1.19921
# [24]	validation_0-rmse:0.61904	validation_1-rmse:1.19266
# [25]	validation_0-rmse:0.61565	validation_1-rmse:1.18755
# [26]	validation_0-rmse:0.60620	validation_1-rmse:1.17065
# [27]	validation_0-rmse:0.58136	validation_1-rmse:1.13397
# [28]	validation_0-rmse:0.57353	validation_1-rmse:1.11896
# [29]	validation_0-rmse:0.56716	validation_1-rmse:1.09775
# [30]	validation_0-rmse:0.55505	validation_1-rmse:1.09306
# [31]	validation_0-rmse:0.55180	validation_1-rmse:1.09516
# [32]	validation_0-rmse:0.54839	validation_1-rmse:1.09587
# [33]	validation_0-rmse:0.53836	validation_1-rmse:1.10666
# [34]	validation_0-rmse:0.51881	validation_1-rmse:1.12670
# [35]	validation_0-rmse:0.50343	validation_1-rmse:1.10189
# [36]	validation_0-rmse:0.49162	validation_1-rmse:1.09393
# [37]	validation_0-rmse:0.47811	validation_1-rmse:1.10270
# [38]	validation_0-rmse:0.47547	validation_1-rmse:1.10894
# [39]	validation_0-rmse:0.46666	validation_1-rmse:1.08969
# [40]	validation_0-rmse:0.46406	validation_1-rmse:1.05733
# [41]	validation_0-rmse:0.46689	validation_1-rmse:1.06302
# [42]	validation_0-rmse:0.46070	validation_1-rmse:1.06308
# [43]	validation_0-rmse:0.45980	validation_1-rmse:1.06602
# [44]	validation_0-rmse:0.44973	validation_1-rmse:1.07443
# [45]	validation_0-rmse:0.43998	validation_1-rmse:1.07014
# [46]	validation_0-rmse:0.43768	validation_1-rmse:1.08716
# [47]	validation_0-rmse:0.42503	validation_1-rmse:1.10953
# [48]	validation_0-rmse:0.40852	validation_1-rmse:1.10923
# [49]	validation_0-rmse:0.40609	validation_1-rmse:1.11694
# [0]	validation_0-rmse:4.70919	validation_1-rmse:5.85359
# [1]	validation_0-rmse:3.43894	validation_1-rmse:4.54067
# [2]	validation_0-rmse:2.55579	validation_1-rmse:3.51744
# [3]	validation_0-rmse:1.96174	validation_1-rmse:2.88422
# [4]	validation_0-rmse:1.54995	validation_1-rmse:2.30783
# [5]	validation_0-rmse:1.27329	validation_1-rmse:1.95734
# [6]	validation_0-rmse:1.08940	validation_1-rmse:1.58560
# [7]	validation_0-rmse:1.00308	validation_1-rmse:1.46998
# [8]	validation_0-rmse:0.92560	validation_1-rmse:1.27872
# [9]	validation_0-rmse:0.85718	validation_1-rmse:1.22139
# [10]	validation_0-rmse:0.81771	validation_1-rmse:1.19692
# [11]	validation_0-rmse:0.77512	validation_1-rmse:1.11376
# [12]	validation_0-rmse:0.76235	validation_1-rmse:1.10497
# [13]	validation_0-rmse:0.74666	validation_1-rmse:1.09360
# [14]	validation_0-rmse:0.69918	validation_1-rmse:1.01758
# [15]	validation_0-rmse:0.67727	validation_1-rmse:0.98423
# [16]	validation_0-rmse:0.64590	validation_1-rmse:0.95323
# [17]	validation_0-rmse:0.62689	validation_1-rmse:0.92064
# [18]	validation_0-rmse:0.62145	validation_1-rmse:0.89132
# [19]	validation_0-rmse:0.61201	validation_1-rmse:0.90666
# [20]	validation_0-rmse:0.60146	validation_1-rmse:0.89917
# [21]	validation_0-rmse:0.59104	validation_1-rmse:0.89997
# [22]	validation_0-rmse:0.58190	validation_1-rmse:0.89405
# [23]	validation_0-rmse:0.57009	validation_1-rmse:0.89309
# [24]	validation_0-rmse:0.55720	validation_1-rmse:0.90567
# [25]	validation_0-rmse:0.54919	validation_1-rmse:0.89416
# [26]	validation_0-rmse:0.54120	validation_1-rmse:0.89426
# [27]	validation_0-rmse:0.53877	validation_1-rmse:0.87536
# [28]	validation_0-rmse:0.52192	validation_1-rmse:0.87833
# [29]	validation_0-rmse:0.51377	validation_1-rmse:0.84511
# [30]	validation_0-rmse:0.50212	validation_1-rmse:0.84756
# [31]	validation_0-rmse:0.48681	validation_1-rmse:0.87865
# [32]	validation_0-rmse:0.47866	validation_1-rmse:0.87186
# [33]	validation_0-rmse:0.46667	validation_1-rmse:0.86177
# [34]	validation_0-rmse:0.46127	validation_1-rmse:0.88472
# [35]	validation_0-rmse:0.45903	validation_1-rmse:0.87250
# [36]	validation_0-rmse:0.45675	validation_1-rmse:0.87846
# [37]	validation_0-rmse:0.44526	validation_1-rmse:0.86531
# [38]	validation_0-rmse:0.43947	validation_1-rmse:0.86203
# [39]	validation_0-rmse:0.43424	validation_1-rmse:0.85426
# [0]	validation_0-rmse:5.03989	validation_1-rmse:4.39227
# [1]	validation_0-rmse:3.70869	validation_1-rmse:3.30523
# [2]	validation_0-rmse:2.71647	validation_1-rmse:2.45219
# [3]	validation_0-rmse:2.07883	validation_1-rmse:1.93655
# [4]	validation_0-rmse:1.63075	validation_1-rmse:1.69604
# [5]	validation_0-rmse:1.32551	validation_1-rmse:1.47720
# [6]	validation_0-rmse:1.10272	validation_1-rmse:1.33865
# [7]	validation_0-rmse:0.96594	validation_1-rmse:1.28088
# [8]	validation_0-rmse:0.88654	validation_1-rmse:1.25527
# [9]	validation_0-rmse:0.84750	validation_1-rmse:1.30190
# [10]	validation_0-rmse:0.80826	validation_1-rmse:1.32187
# [11]	validation_0-rmse:0.75726	validation_1-rmse:1.29371
# [12]	validation_0-rmse:0.72523	validation_1-rmse:1.24315
# [13]	validation_0-rmse:0.70747	validation_1-rmse:1.25546
# [14]	validation_0-rmse:0.68905	validation_1-rmse:1.25651
# [15]	validation_0-rmse:0.66573	validation_1-rmse:1.23046
# [16]	validation_0-rmse:0.63883	validation_1-rmse:1.18191
# [17]	validation_0-rmse:0.61819	validation_1-rmse:1.19687
# [18]	validation_0-rmse:0.60459	validation_1-rmse:1.16801
# [19]	validation_0-rmse:0.58896	validation_1-rmse:1.15881
# [20]	validation_0-rmse:0.57552	validation_1-rmse:1.18789
# [21]	validation_0-rmse:0.56936	validation_1-rmse:1.16857
# [22]	validation_0-rmse:0.56454	validation_1-rmse:1.17021
# [23]	validation_0-rmse:0.55955	validation_1-rmse:1.13960
# [24]	validation_0-rmse:0.54642	validation_1-rmse:1.14337
# [25]	validation_0-rmse:0.53350	validation_1-rmse:1.14828
# [26]	validation_0-rmse:0.52310	validation_1-rmse:1.14862
# [27]	validation_0-rmse:0.51160	validation_1-rmse:1.12774
# [28]	validation_0-rmse:0.50200	validation_1-rmse:1.12185
# [29]	validation_0-rmse:0.48627	validation_1-rmse:1.11694
# [30]	validation_0-rmse:0.47292	validation_1-rmse:1.13519
# [31]	validation_0-rmse:0.46384	validation_1-rmse:1.12138
# [32]	validation_0-rmse:0.45905	validation_1-rmse:1.12242
# [33]	validation_0-rmse:0.44691	validation_1-rmse:1.10569
# [34]	validation_0-rmse:0.44164	validation_1-rmse:1.11763
# [35]	validation_0-rmse:0.44282	validation_1-rmse:1.14658
# [36]	validation_0-rmse:0.43482	validation_1-rmse:1.12294
# [37]	validation_0-rmse:0.42763	validation_1-rmse:1.13131
# [38]	validation_0-rmse:0.42089	validation_1-rmse:1.11958
# [39]	validation_0-rmse:0.41233	validation_1-rmse:1.10077
# [40]	validation_0-rmse:0.40967	validation_1-rmse:1.11359
# [41]	validation_0-rmse:0.40567	validation_1-rmse:1.10517
# [42]	validation_0-rmse:0.40474	validation_1-rmse:1.09933
# [43]	validation_0-rmse:0.39908	validation_1-rmse:1.09990
# [44]	validation_0-rmse:0.38774	validation_1-rmse:1.10907
# [45]	validation_0-rmse:0.38009	validation_1-rmse:1.08761
# [46]	validation_0-rmse:0.37563	validation_1-rmse:1.09117
# [47]	validation_0-rmse:0.36998	validation_1-rmse:1.07518
# [48]	validation_0-rmse:0.36835	validation_1-rmse:1.07632
# [49]	validation_0-rmse:0.36738	validation_1-rmse:1.07336
# [50]	validation_0-rmse:0.36099	validation_1-rmse:1.08488
# [0]	validation_0-rmse:4.96675	validation_1-rmse:4.69059
# [1]	validation_0-rmse:3.61756	validation_1-rmse:3.36204
# [2]	validation_0-rmse:2.68442	validation_1-rmse:2.50596
# [3]	validation_0-rmse:2.05082	validation_1-rmse:1.87240
# [4]	validation_0-rmse:1.60261	validation_1-rmse:1.45268
# [5]	validation_0-rmse:1.27721	validation_1-rmse:1.21278
# [6]	validation_0-rmse:1.09408	validation_1-rmse:1.03898
# [7]	validation_0-rmse:0.97435	validation_1-rmse:0.95747
# [8]	validation_0-rmse:0.90999	validation_1-rmse:0.93153
# [9]	validation_0-rmse:0.86803	validation_1-rmse:0.90248
# [10]	validation_0-rmse:0.84480	validation_1-rmse:0.93208
# [11]	validation_0-rmse:0.81149	validation_1-rmse:0.91792
# [12]	validation_0-rmse:0.77639	validation_1-rmse:0.93051
# [13]	validation_0-rmse:0.75822	validation_1-rmse:0.93768
# [14]	validation_0-rmse:0.71584	validation_1-rmse:0.88987
# [15]	validation_0-rmse:0.70149	validation_1-rmse:0.89175
# [16]	validation_0-rmse:0.64955	validation_1-rmse:0.90942
# [17]	validation_0-rmse:0.63177	validation_1-rmse:0.91922
# [18]	validation_0-rmse:0.61418	validation_1-rmse:0.93107
# [19]	validation_0-rmse:0.60120	validation_1-rmse:0.91852
# [20]	validation_0-rmse:0.57198	validation_1-rmse:0.93279
# [21]	validation_0-rmse:0.56614	validation_1-rmse:0.94688
# [22]	validation_0-rmse:0.55726	validation_1-rmse:0.94130
# [23]	validation_0-rmse:0.55161	validation_1-rmse:0.93336
# [0]	validation_0-rmse:4.88371	validation_1-rmse:4.83493
# [1]	validation_0-rmse:3.56037	validation_1-rmse:3.67485
# [2]	validation_0-rmse:2.63103	validation_1-rmse:2.80201
# [3]	validation_0-rmse:2.03967	validation_1-rmse:2.32090
# [4]	validation_0-rmse:1.59004	validation_1-rmse:2.01507
# [5]	validation_0-rmse:1.28707	validation_1-rmse:1.79340
# [6]	validation_0-rmse:1.06334	validation_1-rmse:1.61802
# [7]	validation_0-rmse:0.94636	validation_1-rmse:1.52833
# [8]	validation_0-rmse:0.88329	validation_1-rmse:1.55011
# [9]	validation_0-rmse:0.81161	validation_1-rmse:1.45550
# [10]	validation_0-rmse:0.78196	validation_1-rmse:1.42649
# [11]	validation_0-rmse:0.75927	validation_1-rmse:1.39342
# [12]	validation_0-rmse:0.72988	validation_1-rmse:1.38191
# [13]	validation_0-rmse:0.72224	validation_1-rmse:1.40434
# [14]	validation_0-rmse:0.70451	validation_1-rmse:1.38635
# [15]	validation_0-rmse:0.69078	validation_1-rmse:1.38363
# [16]	validation_0-rmse:0.67816	validation_1-rmse:1.38722
# [17]	validation_0-rmse:0.66348	validation_1-rmse:1.38666
# [18]	validation_0-rmse:0.64877	validation_1-rmse:1.37223
# [19]	validation_0-rmse:0.63940	validation_1-rmse:1.34863
# [20]	validation_0-rmse:0.62289	validation_1-rmse:1.30653
# [21]	validation_0-rmse:0.61029	validation_1-rmse:1.30376
# [22]	validation_0-rmse:0.59517	validation_1-rmse:1.31728
# [23]	validation_0-rmse:0.58418	validation_1-rmse:1.30726
# [24]	validation_0-rmse:0.57668	validation_1-rmse:1.31336
# [25]	validation_0-rmse:0.55307	validation_1-rmse:1.32309
# [26]	validation_0-rmse:0.54237	validation_1-rmse:1.32446
# [27]	validation_0-rmse:0.53358	validation_1-rmse:1.32979
# [28]	validation_0-rmse:0.52466	validation_1-rmse:1.31985
# [29]	validation_0-rmse:0.51841	validation_1-rmse:1.29441
# [30]	validation_0-rmse:0.50144	validation_1-rmse:1.30082
# [31]	validation_0-rmse:0.48726	validation_1-rmse:1.27612
# [32]	validation_0-rmse:0.47499	validation_1-rmse:1.29135
# [33]	validation_0-rmse:0.46440	validation_1-rmse:1.29463
# [34]	validation_0-rmse:0.46207	validation_1-rmse:1.29334
# [35]	validation_0-rmse:0.45664	validation_1-rmse:1.28301
# [36]	validation_0-rmse:0.44103	validation_1-rmse:1.26184
# [37]	validation_0-rmse:0.43272	validation_1-rmse:1.25374
# [38]	validation_0-rmse:0.42719	validation_1-rmse:1.26618
# [39]	validation_0-rmse:0.42514	validation_1-rmse:1.27468
# [40]	validation_0-rmse:0.41946	validation_1-rmse:1.28930
# [41]	validation_0-rmse:0.40190	validation_1-rmse:1.32365
# [42]	validation_0-rmse:0.39063	validation_1-rmse:1.30175
# [43]	validation_0-rmse:0.38832	validation_1-rmse:1.29508
# [44]	validation_0-rmse:0.38264	validation_1-rmse:1.29703
# [45]	validation_0-rmse:0.37776	validation_1-rmse:1.31004
# [46]	validation_0-rmse:0.37558	validation_1-rmse:1.30499
# [0]	validation_0-rmse:4.94894	validation_1-rmse:4.92414
# [1]	validation_0-rmse:3.59710	validation_1-rmse:3.61469
# [2]	validation_0-rmse:2.67092	validation_1-rmse:2.70701
# [3]	validation_0-rmse:2.07194	validation_1-rmse:2.07339
# [4]	validation_0-rmse:1.68567	validation_1-rmse:1.72250
# [5]	validation_0-rmse:1.35210	validation_1-rmse:1.40098
# [6]	validation_0-rmse:1.14400	validation_1-rmse:1.26198
# [7]	validation_0-rmse:1.03663	validation_1-rmse:1.17030
# [8]	validation_0-rmse:0.95442	validation_1-rmse:1.10254
# [9]	validation_0-rmse:0.89020	validation_1-rmse:1.04787
# [10]	validation_0-rmse:0.85070	validation_1-rmse:1.03447
# [11]	validation_0-rmse:0.78917	validation_1-rmse:1.02019
# [12]	validation_0-rmse:0.74481	validation_1-rmse:0.98356
# [13]	validation_0-rmse:0.73556	validation_1-rmse:0.97413
# [14]	validation_0-rmse:0.72351	validation_1-rmse:1.02797
# [15]	validation_0-rmse:0.70125	validation_1-rmse:1.03381
# [16]	validation_0-rmse:0.65660	validation_1-rmse:1.04289
# [17]	validation_0-rmse:0.64077	validation_1-rmse:1.04928
# [18]	validation_0-rmse:0.62439	validation_1-rmse:1.08830
# [19]	validation_0-rmse:0.61122	validation_1-rmse:1.09374
# [20]	validation_0-rmse:0.60124	validation_1-rmse:1.08900
# [21]	validation_0-rmse:0.58889	validation_1-rmse:1.08429
# [22]	validation_0-rmse:0.57926	validation_1-rmse:1.09221
# [0]	validation_0-rmse:4.86316	validation_1-rmse:4.85633
# [1]	validation_0-rmse:3.56733	validation_1-rmse:3.51544
# [2]	validation_0-rmse:2.65372	validation_1-rmse:2.62313
# [3]	validation_0-rmse:2.05790	validation_1-rmse:2.06730
# [4]	validation_0-rmse:1.60260	validation_1-rmse:1.65491
# [5]	validation_0-rmse:1.31886	validation_1-rmse:1.32344
# [6]	validation_0-rmse:1.14000	validation_1-rmse:1.17976
# [7]	validation_0-rmse:1.01069	validation_1-rmse:1.05843
# [8]	validation_0-rmse:0.90982	validation_1-rmse:1.00833
# [9]	validation_0-rmse:0.86993	validation_1-rmse:1.00450
# [10]	validation_0-rmse:0.85309	validation_1-rmse:1.00847
# [11]	validation_0-rmse:0.81359	validation_1-rmse:1.01993
# [12]	validation_0-rmse:0.78873	validation_1-rmse:1.05030
# [13]	validation_0-rmse:0.77946	validation_1-rmse:1.04984
# [14]	validation_0-rmse:0.77026	validation_1-rmse:1.07452
# [15]	validation_0-rmse:0.72325	validation_1-rmse:1.01331
# [16]	validation_0-rmse:0.71309	validation_1-rmse:1.02722
# [17]	validation_0-rmse:0.69343	validation_1-rmse:1.08560
# [18]	validation_0-rmse:0.68389	validation_1-rmse:1.09929
# [0]	validation_0-rmse:4.94170	validation_1-rmse:4.96703
# [1]	validation_0-rmse:3.61861	validation_1-rmse:3.71343
# [2]	validation_0-rmse:2.68518	validation_1-rmse:2.79183
# [3]	validation_0-rmse:2.07592	validation_1-rmse:2.20666
# [4]	validation_0-rmse:1.66288	validation_1-rmse:1.84058
# [5]	validation_0-rmse:1.36401	validation_1-rmse:1.61203
# [6]	validation_0-rmse:1.13611	validation_1-rmse:1.40722
# [7]	validation_0-rmse:0.98597	validation_1-rmse:1.29873
# [8]	validation_0-rmse:0.89518	validation_1-rmse:1.21524
# [9]	validation_0-rmse:0.84790	validation_1-rmse:1.21070
# [10]	validation_0-rmse:0.81900	validation_1-rmse:1.21278
# [11]	validation_0-rmse:0.74941	validation_1-rmse:1.18753
# [12]	validation_0-rmse:0.72876	validation_1-rmse:1.19375
# [13]	validation_0-rmse:0.71938	validation_1-rmse:1.20333
# [14]	validation_0-rmse:0.68964	validation_1-rmse:1.18359
# [15]	validation_0-rmse:0.66269	validation_1-rmse:1.13732
# [16]	validation_0-rmse:0.65251	validation_1-rmse:1.12155
# [17]	validation_0-rmse:0.62745	validation_1-rmse:1.11875
# [18]	validation_0-rmse:0.61123	validation_1-rmse:1.09608
# [19]	validation_0-rmse:0.59962	validation_1-rmse:1.08293
# [20]	validation_0-rmse:0.59282	validation_1-rmse:1.09818
# [21]	validation_0-rmse:0.58498	validation_1-rmse:1.09209
# [22]	validation_0-rmse:0.57942	validation_1-rmse:1.09552
# [23]	validation_0-rmse:0.57287	validation_1-rmse:1.09000
# [24]	validation_0-rmse:0.56619	validation_1-rmse:1.07643
# [25]	validation_0-rmse:0.56554	validation_1-rmse:1.08774
# [26]	validation_0-rmse:0.55657	validation_1-rmse:1.06832
# [27]	validation_0-rmse:0.55343	validation_1-rmse:1.07392
# [28]	validation_0-rmse:0.54947	validation_1-rmse:1.10018
# [29]	validation_0-rmse:0.54707	validation_1-rmse:1.09930
# [30]	validation_0-rmse:0.53815	validation_1-rmse:1.11840
# [31]	validation_0-rmse:0.52753	validation_1-rmse:1.13453
# [32]	validation_0-rmse:0.51494	validation_1-rmse:1.14837
# [33]	validation_0-rmse:0.50435	validation_1-rmse:1.15160
# [34]	validation_0-rmse:0.49421	validation_1-rmse:1.14293
# [35]	validation_0-rmse:0.49093	validation_1-rmse:1.14238
# [36]	validation_0-rmse:0.48494	validation_1-rmse:1.12712

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 20.78, median: 19.0,
#  pred. interval (P(0.025)-P(0.975)): 7.0-45.0,
#  conf. interval (p-value=0.95): 15.509-24.307
# ***
# Aggregate bias statistic:
#  mean: -1.964, median: -1.887,
#  pred. interval (P(0.025)-P(0.975)): -9.767-5.332,
#  conf. interval (p-value=0.95): -3.681--0.057
# ***
# Aggregate RMSE statistic:
#  mean: 1.01, median: 1.018, pred. interval (P(0.025)-P(0.975)): 0.671-1.332,
#  conf. interval (p-value=0.95): 0.942-1.092
# ***
# Aggregate MSE statistic:
#  mean: 1.049, median: 1.037, pred. interval (P(0.025)-P(0.975)): 0.45-1.774,
#  conf. interval (p-value=0.95): 0.894-1.199
# ***
# Aggregate R^2 statistic:
#  mean: 0.565, median: 0.613, pred. interval (P(0.025)-P(0.975)): 0.148-0.817,
#  conf. interval (p-value=0.95): 0.524-0.662
# ***
# Aggregate bias(%) statistic:
#  mean: -0.27, median: -1.887, pred. interval (P(0.025)-P(0.975)): -1.357-0.794,
#  conf. interval (p-value=0.95): -0.51--0.022
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.144, median: 0.144, pred. interval (P(0.025)-P(0.975)): 0.095-0.187,
#  conf. interval (p-value=0.95): 0.133-0.155
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:4.81533
# [1]	validation_0-rmse:3.48135
# [2]	validation_0-rmse:2.58239
# [3]	validation_0-rmse:1.99385
# [4]	validation_0-rmse:1.57330
# [5]	validation_0-rmse:1.32964
# [6]	validation_0-rmse:1.13661
# [7]	validation_0-rmse:1.03681
# [8]	validation_0-rmse:0.95461
# [9]	validation_0-rmse:0.90396
# [10]	validation_0-rmse:0.85432
# [11]	validation_0-rmse:0.82138
# [12]	validation_0-rmse:0.79865
# [13]	validation_0-rmse:0.76434
# [14]	validation_0-rmse:0.73518
# [15]	validation_0-rmse:0.72532
# [16]	validation_0-rmse:0.70891
# [17]	validation_0-rmse:0.69873
# [18]	validation_0-rmse:0.69463
# [19]	validation_0-rmse:0.68975
# [20]	validation_0-rmse:0.67837
# [21]	validation_0-rmse:0.67122
# [22]	validation_0-rmse:0.64879
# [23]	validation_0-rmse:0.64057
# [24]	validation_0-rmse:0.63588
# [25]	validation_0-rmse:0.61881
# [26]	validation_0-rmse:0.60309
# [27]	validation_0-rmse:0.59389
# [28]	validation_0-rmse:0.58722
# [29]	validation_0-rmse:0.58361
# [30]	validation_0-rmse:0.57807
# [31]	validation_0-rmse:0.56178
# [32]	validation_0-rmse:0.55498
# [33]	validation_0-rmse:0.55319
# [34]	validation_0-rmse:0.54854
# [35]	validation_0-rmse:0.54583
# [36]	validation_0-rmse:0.54136
# [37]	validation_0-rmse:0.53716
# [38]	validation_0-rmse:0.52858
# [39]	validation_0-rmse:0.51726
# [40]	validation_0-rmse:0.50717
# [41]	validation_0-rmse:0.50455
# [42]	validation_0-rmse:0.49322
# [43]	validation_0-rmse:0.48678
# [44]	validation_0-rmse:0.48476
# [45]	validation_0-rmse:0.47455
# [46]	validation_0-rmse:0.47067
# [47]	validation_0-rmse:0.46378
# [48]	validation_0-rmse:0.45792
# [49]	validation_0-rmse:0.44773
# [50]	validation_0-rmse:0.44367

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 50

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.23
# RMSE: 0.4
# Relative RMSE(%):  0.063
# MSE: 0.2
# R square: 92.7%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.819
# a1: 0.881
# R^2: 0.930
# Uncertainty
# a0: 0.82+/-0.17
# a1: 0.881+/-0.024

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("./../03_output_data/XGBoost_models/UAV_ln_Cs_XGB_model_AERD&texture_2024.json")
# Save to text format
f_xgb_model.save_model("./../03_output_data/XGBoost_models/UAV_ln_Cs_XGB_model_AERD&texture_2024.txt")
