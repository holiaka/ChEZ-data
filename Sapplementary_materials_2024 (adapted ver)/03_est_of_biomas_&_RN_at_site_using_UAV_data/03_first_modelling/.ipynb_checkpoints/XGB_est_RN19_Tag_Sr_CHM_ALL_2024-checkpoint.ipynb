# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'mf_chm_MIN', 'r_MIN', 'contr_b_MAX', 'contr_b_STD'])

# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           2260           1210     -0.731      2.576
# 1       8.189       9.622           2700           1180      0.585      2.915
# 2       8.380       9.589           2500           1400      0.779      2.882
# 3       8.137       9.449           2500           1090      0.517      2.724
# 4       7.696       9.401           2400            720      0.224      2.826
#
#    AEDR_mean  mf_chm_MIN  r_MIN  contr_b_MAX  contr_b_STD
# 0       2.33    0.445070     13  2713.600586   332.963753
# 1       2.47   12.465903     24  1793.493042   293.868420
# 2       2.44   13.028298     18  1761.097900   272.526176
# 3       2.55    2.128231     15  2518.435303   299.595643
# 4       2.14   12.171553      8  2525.819336   327.599176

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   mf_chm_MIN     103 non-null    float64
#  8   r_MIN          103 non-null    int64
#  9   contr_b_MAX    103 non-null    float64
#  10  contr_b_STD    103 non-null    float64
# dtypes: float64(8), int64(3)
# memory usage: 9.0 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3440.194175    1242.902913   -0.252563
# std       1.64946    1.472424    6087.580089    2037.684800    1.104610
# min       3.52600    6.075000     260.000000      50.000000   -3.033000
# 25%       6.31900    7.664000     635.000000     200.000000   -0.727500
# 50%       6.95700    8.472000    1150.000000     400.000000   -0.025000
# 75%       7.91350    9.421000    2525.000000    1400.000000    0.516500
# max      11.36700   13.864000   35200.000000   10500.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean  mf_chm_MIN       r_MIN  contr_b_MAX  \
# count  103.000000  103.000000  103.000000  103.000000   103.000000
# mean     2.464709    3.570291    3.368496   11.378641  2712.352866
# std      0.904675    6.089170    4.845054    9.139568   864.116297
# min      0.391000    0.480000   -0.018586    2.000000   832.155518
# 25%      1.803000    0.710000    0.482279    5.000000  2123.614868
# 50%      2.603000    1.290000    0.642883    8.000000  2601.248047
# 75%      3.159000    2.960000    3.921804   15.000000  3045.944336
# max      4.659000   36.590000   17.862923   56.000000  6252.923340
#
#        contr_b_STD
# count   103.000000
# mean    349.854034
# std      93.673105
# min     109.232976
# 25%     292.544440
# 50%     341.904211
# 75%     427.359073
# max     588.661708

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['mf_chm_MIN', 'r_MIN', 'contr_b_MAX', 'contr_b_STD'])
y = pd.DataFrame(select, columns= ['ln_Tag_Sr'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    mf_chm_MIN  r_MIN  contr_b_MAX  contr_b_STD
# 0    0.445070     13  2713.600586   332.963753
# 1   12.465903     24  1793.493042   293.868420
# 2   13.028298     18  1761.097900   272.526176
# 3    2.128231     15  2518.435303   299.595643
# 4   12.171553      8  2525.819336   327.599176

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Tag_Sr
# 0      2.576
# 1      2.915
# 2      2.882
# 3      2.724
# 4      2.826

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.07623625042369175, -0.11780646623718427, 0.2576050330462204]
#     Mean: 0.072
#     Std: 0.153
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.81363647 0.60368184 1.02657336]
#     Mean: 0.815
#     Std: 0.173
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.7043005972453527, 0.7240391384433298, 0.8166006050951339]
#     Mean: 0.748
#     Std: 0.049
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.130 (std: 0.111)
# Parameters: {'colsample_bytree': 0.09397946663770174, 'gamma': 0.09875122322015767, 'learning_rate': 0.05324735530207501, 'max_depth': 4, 'n_estimators': 54, 'subsample': 0.7408234046212928}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.27686305, 0.36962438, 0.46286216, ..., 0.24844599, 0.24614248,
#        0.39995122]), 'std_fit_time': array([0.09563483, 0.17107149, 0.21712053, ..., 0.0197772 , 0.02068752,
#        0.01204672]), 'mean_score_time': array([0.00610209, 0.00922799, 0.00817308, ..., 0.00714798, 0.00575967,
#        0.00589213]), 'std_score_time': array([2.80781584e-04, 4.07550763e-03, 4.42164325e-03, ...,
#        1.84683295e-03, 4.49987262e-05, 2.35106571e-04]), 'param_colsample_bytree': masked_array(data=[0.8489381213363433, 0.8297063780597076,
#                    0.18917394453619685, ..., 0.28226865491992764,
#                    0.3400555894053085, 0.8221926362573626],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.4012642898836546, 0.2022557656766934,
#                    0.047377346325956526, ..., 0.29502749358356717,
#                    0.46919294565811026, 0.41986281429132055],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.13614211661682799, 0.060608732566401716,
#                    0.06280479793567184, ..., 0.06282313042585155,
#                    0.06393135140466835, 0.029218945995057193],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[3, 3, 4, ..., 2, 3, 2],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[91, 101, 134, ..., 98, 89, 163],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.744603825605483, 0.6138689219202138,
#                    0.3726084826114865, ..., 0.5226704057097259,
#                    0.5662412361485291, 0.8184466919381606],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.8489381213363433, 'gamma': 0.4012642898836546, 'learning_rate': 0.13614211661682799, 'max_depth': 3, 'n_estimators': 91, 'subsample': 0.744603825605483}, {'colsample_bytree': 0.8297063780597076, 'gamma': 0.2022557656766934, 'learning_rate': 0.060608732566401716, 'max_depth': 3, 'n_estimators': 101, 'subsample': 0.6138689219202138}, {'colsample_bytree': 0.18917394453619685, 'gamma': 0.047377346325956526, 'learning_rate': 0.06280479793567184, 'max_depth': 4, 'n_estimators': 134, 'subsample': 0.3726084826114865}, {'colsample_bytree': 0.30515070031538855, 'gamma': 0.10610121946181783, 'learning_rate': 0.18177382610561207, 'max_depth': 3, 'n_estimators': 136, 'subsample': 0.3610486530817272}, {'colsample_bytree': 0.3929237675362813, 'gamma': 0.032747368207681704, 'learning_rate': 0.29480399430754567, 'max_depth': 2, 'n_estimators': 90, 'subsample': 0.8406865749310399}, {'colsample_bytree': 0.7689765523092001, 'gamma': 0.2606640015605431, 'learning_rate': 0.16445416917561148, 'max_depth': 3, 'n_estimators': 175, 'subsample': 0.9912331147855835}, {'colsample_bytree': 0.893658078108772, 'gamma': 0.43047492951183236, 'learning_rate': 0.215970590907659, 'max_depth': 2, 'n_estimators': 130, 'subsample': 0.7916684414083763}, {'colsample_bytree': 0.6183047237938905, 'gamma': 0.3943785403035701, 'learning_rate': 0.2002920095525747, 'max_depth': 4, 'n_estimators': 115, 'subsample': 0.5372275281480652}, {'colsample_bytree': 0.09525275043870368, 'gamma': 0.33173294418734883, 'learning_rate': 0.2822878967455559, 'max_depth': 4, 'n_estimators': 94, 'subsample': 0.37428041208031754}, {'colsample_bytree': 0.46875855664342464, 'gamma': 0.279528250156743, 'learning_rate': 0.14512
#        0.35752628]), 'rank_test_score': array([1441, 1155, 1076, ...,  366,  297,  627], dtype=int32), 'split0_train_score': array([0.89586164, 0.87925556, 0.82329951, ..., 0.63023522, 0.69314563,
#        0.71866729]), 'split1_train_score': array([0.87119457, 0.8518709 , 0.81648232, ..., 0.61388144, 0.65879391,
#        0.66840976]), 'split2_train_score': array([0.87110882, 0.85662314, 0.8480266 , ..., 0.65771045, 0.70706216,
#        0.70504155]), 'split3_train_score': array([0.87205579, 0.85209545, 0.79852453, ..., 0.60824368, 0.66055763,
#        0.65963497]), 'split4_train_score': array([0.87789081, 0.87163846, 0.813336  , ..., 0.64310158, 0.69721182,
#        0.68246764]), 'mean_train_score': array([0.87762232, 0.8622967 , 0.81993379, ..., 0.63063447, 0.68335423,
#        0.68684424]), 'std_train_score': array([0.00946016, 0.01113394, 0.01621316, ..., 0.01827954, 0.01986386,
#        0.0221051 ])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.09397946663770174
# Gamma: 0.09875122322015767
# Learning_rate: 0.05324735530207501
# Max_depth: 4
# N_estimators: 54
# Subsample: 0.7408234046212928

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=10, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:2.05426	validation_1-rmse:2.09914
# [1]	validation_0-rmse:1.96577	validation_1-rmse:2.00887
# [2]	validation_0-rmse:1.87704	validation_1-rmse:1.92395
# [3]	validation_0-rmse:1.79944	validation_1-rmse:1.84377
# [4]	validation_0-rmse:1.72481	validation_1-rmse:1.76411
# [5]	validation_0-rmse:1.65225	validation_1-rmse:1.69034
# [6]	validation_0-rmse:1.58623	validation_1-rmse:1.62351
# [7]	validation_0-rmse:1.52176	validation_1-rmse:1.56189
# [8]	validation_0-rmse:1.46354	validation_1-rmse:1.50045
# [9]	validation_0-rmse:1.40923	validation_1-rmse:1.44690
# [10]	validation_0-rmse:1.35936	validation_1-rmse:1.39298
# [11]	validation_0-rmse:1.30814	validation_1-rmse:1.33863
# [12]	validation_0-rmse:1.26287	validation_1-rmse:1.29365
# [13]	validation_0-rmse:1.21699	validation_1-rmse:1.24533
# [14]	validation_0-rmse:1.17847	validation_1-rmse:1.20398
# [15]	validation_0-rmse:1.13743	validation_1-rmse:1.15885
# [16]	validation_0-rmse:1.10062	validation_1-rmse:1.11769
# [17]	validation_0-rmse:1.06826	validation_1-rmse:1.08184
# [18]	validation_0-rmse:1.03749	validation_1-rmse:1.04584
# [19]	validation_0-rmse:1.00613	validation_1-rmse:1.01452
# [20]	validation_0-rmse:0.97906	validation_1-rmse:0.98091
# [21]	validation_0-rmse:0.95551	validation_1-rmse:0.95838
# [22]	validation_0-rmse:0.93080	validation_1-rmse:0.93850
# [23]	validation_0-rmse:0.90629	validation_1-rmse:0.91493
# [24]	validation_0-rmse:0.88441	validation_1-rmse:0.89714
# [25]	validation_0-rmse:0.86404	validation_1-rmse:0.87370
# [26]	validation_0-rmse:0.84183	validation_1-rmse:0.84865
# [27]	validation_0-rmse:0.82332	validation_1-rmse:0.82603
# [28]	validation_0-rmse:0.80404	validation_1-rmse:0.81156
# [29]	validation_0-rmse:0.78843	validation_1-rmse:0.79797
# [30]	validation_0-rmse:0.77508	validation_1-rmse:0.78201
# [31]	validation_0-rmse:0.75898	validation_1-rmse:0.77387
# [32]	validation_0-rmse:0.74443	validation_1-rmse:0.76409
# [33]	validation_0-rmse:0.73073	validation_1-rmse:0.76041
# [34]	validation_0-rmse:0.71912	validation_1-rmse:0.75160
# [35]	validation_0-rmse:0.70885	validation_1-rmse:0.74123
# [36]	validation_0-rmse:0.69445	validation_1-rmse:0.73724
# [37]	validation_0-rmse:0.68502	validation_1-rmse:0.73053
# [38]	validation_0-rmse:0.67590	validation_1-rmse:0.72634
# [39]	validation_0-rmse:0.66662	validation_1-rmse:0.71663
# [40]	validation_0-rmse:0.65363	validation_1-rmse:0.71187
# [41]	validation_0-rmse:0.64632	validation_1-rmse:0.70319
# [42]	validation_0-rmse:0.63652	validation_1-rmse:0.69165
# [9]	validation_0-rmse:1.42043	validation_1-rmse:1.31664
# [10]	validation_0-rmse:1.37106	validation_1-rmse:1.26430
# [11]	validation_0-rmse:1.32231	validation_1-rmse:1.21217
# [12]	validation_0-rmse:1.27667	validation_1-rmse:1.15678
# [13]	validation_0-rmse:1.23278	validation_1-rmse:1.10378
# [14]	validation_0-rmse:1.19339	validation_1-rmse:1.06120
# [15]	validation_0-rmse:1.15470	validation_1-rmse:1.01424
# [16]	validation_0-rmse:1.11405	validation_1-rmse:0.96650
# [17]	validation_0-rmse:1.07982	validation_1-rmse:0.93014
# [18]	validation_0-rmse:1.04749	validation_1-rmse:0.89440
# [19]	validation_0-rmse:1.01646	validation_1-rmse:0.85970
# [20]	validation_0-rmse:0.98954	validation_1-rmse:0.82443
# [21]	validation_0-rmse:0.96474	validation_1-rmse:0.79672
# [22]	validation_0-rmse:0.94076	validation_1-rmse:0.76886
# [23]	validation_0-rmse:0.91776	validation_1-rmse:0.74125
# [24]	validation_0-rmse:0.89178	validation_1-rmse:0.71276
# [25]	validation_0-rmse:0.87243	validation_1-rmse:0.68703
# [26]	validation_0-rmse:0.85494	validation_1-rmse:0.66633
# [27]	validation_0-rmse:0.83669	validation_1-rmse:0.64354
# [28]	validation_0-rmse:0.81968	validation_1-rmse:0.62602
# [29]	validation_0-rmse:0.80370	validation_1-rmse:0.60430
# [30]	validation_0-rmse:0.78686	validation_1-rmse:0.58884
# [31]	validation_0-rmse:0.77124	validation_1-rmse:0.57387
# [32]	validation_0-rmse:0.75868	validation_1-rmse:0.56583
# [33]	validation_0-rmse:0.74675	validation_1-rmse:0.55593
# [34]	validation_0-rmse:0.73586	validation_1-rmse:0.55043
# [35]	validation_0-rmse:0.72427	validation_1-rmse:0.53905
# [36]	validation_0-rmse:0.71266	validation_1-rmse:0.52831
# [37]	validation_0-rmse:0.69951	validation_1-rmse:0.51794
# [38]	validation_0-rmse:0.68918	validation_1-rmse:0.50924
# [39]	validation_0-rmse:0.68032	validation_1-rmse:0.49518
# [40]	validation_0-rmse:0.66972	validation_1-rmse:0.48728
# [41]	validation_0-rmse:0.65987	validation_1-rmse:0.47932
# [42]	validation_0-rmse:0.65155	validation_1-rmse:0.47391
# [43]	validation_0-rmse:0.64456	validation_1-rmse:0.47613
# [44]	validation_0-rmse:0.63851	validation_1-rmse:0.47118
# [45]	validation_0-rmse:0.63163	validation_1-rmse:0.46682
# [46]	validation_0-rmse:0.62329	validation_1-rmse:0.46209
# [47]	validation_0-rmse:0.61823	validation_1-rmse:0.45661
# [48]	validation_0-rmse:0.61183	validation_1-rmse:0.45431
# [49]	validation_0-rmse:0.60727	validation_1-rmse:0.45528
# [50]	validation_0-rmse:0.60136	validation_1-rmse:0.45266
# [51]	validation_0-rmse:0.59684	validation_1-rmse:0.45025
# [52]	validation_0-rmse:0.59082	validation_1-rmse:0.44968
# [53]	validation_0-rmse:0.58710	validation_1-rmse:0.44853
# [0]	validation_0-rmse:2.01828	validation_1-rmse:2.23548
# [1]	validation_0-rmse:1.93182	validation_1-rmse:2.14270
# [39]	validation_0-rmse:0.62426	validation_1-rmse:1.00175
# [40]	validation_0-rmse:0.61281	validation_1-rmse:0.99537
# [41]	validation_0-rmse:0.60405	validation_1-rmse:0.98859
# [42]	validation_0-rmse:0.59441	validation_1-rmse:0.98792
# [43]	validation_0-rmse:0.58682	validation_1-rmse:0.97741
# [44]	validation_0-rmse:0.58189	validation_1-rmse:0.97205
# [45]	validation_0-rmse:0.57765	validation_1-rmse:0.97040
# [46]	validation_0-rmse:0.57018	validation_1-rmse:0.97152
# [47]	validation_0-rmse:0.56431	validation_1-rmse:0.96707
# [48]	validation_0-rmse:0.55931	validation_1-rmse:0.96546
# [49]	validation_0-rmse:0.55320	validation_1-rmse:0.96333
# [50]	validation_0-rmse:0.54961	validation_1-rmse:0.95795
# [51]	validation_0-rmse:0.54483	validation_1-rmse:0.95224
# [52]	validation_0-rmse:0.53968	validation_1-rmse:0.95217
# [53]	validation_0-rmse:0.53644	validation_1-rmse:0.95004
# [0]	validation_0-rmse:2.02741	validation_1-rmse:2.22872
# [1]	validation_0-rmse:1.93380	validation_1-rmse:2.13694
# [2]	validation_0-rmse:1.85433	validation_1-rmse:2.05652
# [3]	validation_0-rmse:1.77467	validation_1-rmse:1.98149
# [4]	validation_0-rmse:1.69057	validation_1-rmse:1.91209
# [5]	validation_0-rmse:1.62448	validation_1-rmse:1.85013
# [6]	validation_0-rmse:1.55643	validation_1-rmse:1.78797
# [7]	validation_0-rmse:1.48989	validation_1-rmse:1.72756
# [8]	validation_0-rmse:1.42793	validation_1-rmse:1.67407
# [9]	validation_0-rmse:1.36627	validation_1-rmse:1.61689
# [10]	validation_0-rmse:1.31562	validation_1-rmse:1.57726
# [11]	validation_0-rmse:1.26687	validation_1-rmse:1.53985
# [12]	validation_0-rmse:1.21420	validation_1-rmse:1.48861
# [13]	validation_0-rmse:1.16494	validation_1-rmse:1.44345
# [14]	validation_0-rmse:1.12164	validation_1-rmse:1.41567
# [15]	validation_0-rmse:1.08271	validation_1-rmse:1.38009
# [16]	validation_0-rmse:1.04460	validation_1-rmse:1.35141
# [17]	validation_0-rmse:1.00915	validation_1-rmse:1.32585
# [18]	validation_0-rmse:0.97628	validation_1-rmse:1.31008
# [19]	validation_0-rmse:0.94324	validation_1-rmse:1.28186
# [20]	validation_0-rmse:0.91475	validation_1-rmse:1.25786
# [21]	validation_0-rmse:0.88441	validation_1-rmse:1.23797
# [22]	validation_0-rmse:0.85934	validation_1-rmse:1.21940
# [23]	validation_0-rmse:0.83554	validation_1-rmse:1.20557
# [24]	validation_0-rmse:0.81003	validation_1-rmse:1.18293
# [25]	validation_0-rmse:0.78942	validation_1-rmse:1.16375
# [26]	validation_0-rmse:0.77031	validation_1-rmse:1.15469
# [27]	validation_0-rmse:0.75116	validation_1-rmse:1.14159
# [28]	validation_0-rmse:0.73032	validation_1-rmse:1.12423
# [29]	validation_0-rmse:0.71296	validation_1-rmse:1.11577
# [30]	validation_0-rmse:0.69464	validation_1-rmse:1.10335
# [31]	validation_0-rmse:0.67946	validation_1-rmse:1.08816
# [26]	validation_0-rmse:0.82241	validation_1-rmse:1.00238
# [27]	validation_0-rmse:0.80259	validation_1-rmse:0.98802
# [28]	validation_0-rmse:0.78320	validation_1-rmse:0.96839
# [29]	validation_0-rmse:0.77023	validation_1-rmse:0.95738
# [30]	validation_0-rmse:0.75184	validation_1-rmse:0.94583
# [31]	validation_0-rmse:0.73327	validation_1-rmse:0.92962
# [32]	validation_0-rmse:0.71965	validation_1-rmse:0.91673
# [33]	validation_0-rmse:0.70807	validation_1-rmse:0.90847
# [34]	validation_0-rmse:0.69609	validation_1-rmse:0.90027
# [35]	validation_0-rmse:0.68571	validation_1-rmse:0.89216
# [36]	validation_0-rmse:0.67397	validation_1-rmse:0.88606
# [37]	validation_0-rmse:0.66596	validation_1-rmse:0.87884
# [38]	validation_0-rmse:0.65684	validation_1-rmse:0.87261
# [39]	validation_0-rmse:0.64656	validation_1-rmse:0.86197
# [40]	validation_0-rmse:0.63758	validation_1-rmse:0.86343
# [41]	validation_0-rmse:0.62974	validation_1-rmse:0.85712
# [42]	validation_0-rmse:0.61691	validation_1-rmse:0.85461
# [43]	validation_0-rmse:0.61155	validation_1-rmse:0.85161
# [44]	validation_0-rmse:0.60380	validation_1-rmse:0.84446
# [45]	validation_0-rmse:0.59618	validation_1-rmse:0.83807
# [46]	validation_0-rmse:0.58922	validation_1-rmse:0.83140
# [47]	validation_0-rmse:0.58416	validation_1-rmse:0.82645
# [48]	validation_0-rmse:0.57889	validation_1-rmse:0.82179
# [49]	validation_0-rmse:0.57507	validation_1-rmse:0.81840
# [50]	validation_0-rmse:0.57014	validation_1-rmse:0.81477
# [51]	validation_0-rmse:0.56398	validation_1-rmse:0.81354
# [52]	validation_0-rmse:0.55750	validation_1-rmse:0.81089
# [53]	validation_0-rmse:0.55424	validation_1-rmse:0.80666
# [0]	validation_0-rmse:1.99439	validation_1-rmse:2.32778
# [1]	validation_0-rmse:1.90974	validation_1-rmse:2.24049
# [2]	validation_0-rmse:1.83213	validation_1-rmse:2.16713
# [3]	validation_0-rmse:1.74648	validation_1-rmse:2.07757
# [4]	validation_0-rmse:1.68153	validation_1-rmse:2.01091
# [5]	validation_0-rmse:1.61872	validation_1-rmse:1.94616
# [6]	validation_0-rmse:1.55489	validation_1-rmse:1.88221
# [7]	validation_0-rmse:1.49104	validation_1-rmse:1.81271
# [8]	validation_0-rmse:1.42990	validation_1-rmse:1.74927
# [9]	validation_0-rmse:1.37940	validation_1-rmse:1.69318
# [10]	validation_0-rmse:1.32803	validation_1-rmse:1.63913
# [11]	validation_0-rmse:1.27825	validation_1-rmse:1.58509
# [12]	validation_0-rmse:1.22908	validation_1-rmse:1.53215
# [13]	validation_0-rmse:1.18523	validation_1-rmse:1.48394
# [14]	validation_0-rmse:1.14264	validation_1-rmse:1.43765
# [15]	validation_0-rmse:1.10765	validation_1-rmse:1.40432
# [16]	validation_0-rmse:1.07701	validation_1-rmse:1.37037
# [17]	validation_0-rmse:1.04018	validation_1-rmse:1.33027
# [18]	validation_0-rmse:1.00973	validation_1-rmse:1.29814
# [19]	validation_0-rmse:0.97806	validation_1-rmse:1.26246
# [20]	validation_0-rmse:0.95337	validation_1-rmse:1.23281
# [21]	validation_0-rmse:0.92557	validation_1-rmse:1.20918
# [22]	validation_0-rmse:0.90690	validation_1-rmse:1.19802
# [23]	validation_0-rmse:0.88126	validation_1-rmse:1.16943
# [24]	validation_0-rmse:0.86055	validation_1-rmse:1.14952
# [25]	validation_0-rmse:0.84101	validation_1-rmse:1.12859
# [26]	validation_0-rmse:0.82461	validation_1-rmse:1.11094
# [27]	validation_0-rmse:0.80867	validation_1-rmse:1.09502
# [28]	validation_0-rmse:0.78998	validation_1-rmse:1.07721
# [29]	validation_0-rmse:0.77289	validation_1-rmse:1.05361
# [30]	validation_0-rmse:0.75427	validation_1-rmse:1.03371
# [31]	validation_0-rmse:0.73791	validation_1-rmse:1.01216
# [32]	validation_0-rmse:0.72284	validation_1-rmse:0.99243
# [33]	validation_0-rmse:0.70773	validation_1-rmse:0.98109
# [34]	validation_0-rmse:0.69646	validation_1-rmse:0.97257
# [35]	validation_0-rmse:0.68398	validation_1-rmse:0.95682
# [36]	validation_0-rmse:0.67383	validation_1-rmse:0.94872
# [37]	validation_0-rmse:0.66269	validation_1-rmse:0.93693
# [38]	validation_0-rmse:0.65385	validation_1-rmse:0.92829
# [39]	validation_0-rmse:0.64338	validation_1-rmse:0.91718
# [40]	validation_0-rmse:0.63477	validation_1-rmse:0.90704
# [41]	validation_0-rmse:0.62733	validation_1-rmse:0.89757
# [42]	validation_0-rmse:0.61571	validation_1-rmse:0.88874
# [43]	validation_0-rmse:0.61032	validation_1-rmse:0.88195
# [44]	validation_0-rmse:0.60391	validation_1-rmse:0.87000
# [45]	validation_0-rmse:0.59764	validation_1-rmse:0.86411
# [46]	validation_0-rmse:0.58903	validation_1-rmse:0.85872
# [47]	validation_0-rmse:0.58428	validation_1-rmse:0.85267
# [48]	validation_0-rmse:0.57987	validation_1-rmse:0.84737
# [49]	validation_0-rmse:0.57422	validation_1-rmse:0.84004
# [50]	validation_0-rmse:0.56942	validation_1-rmse:0.83411
# [51]	validation_0-rmse:0.56333	validation_1-rmse:0.83295
# [52]	validation_0-rmse:0.55782	validation_1-rmse:0.82888
# [53]	validation_0-rmse:0.55381	validation_1-rmse:0.82343
# [0]	validation_0-rmse:2.01459	validation_1-rmse:2.29004
# [1]	validation_0-rmse:1.92020	validation_1-rmse:2.18598
# [2]	validation_0-rmse:1.83904	validation_1-rmse:2.10708
# [3]	validation_0-rmse:1.75611	validation_1-rmse:2.01757
# [4]	validation_0-rmse:1.68182	validation_1-rmse:1.94689
# [5]	validation_0-rmse:1.61361	validation_1-rmse:1.87706
# [6]	validation_0-rmse:1.54759	validation_1-rmse:1.81027
# [7]	validation_0-rmse:1.48874	validation_1-rmse:1.75502
# [8]	validation_0-rmse:1.43198	validation_1-rmse:1.69936
# [9]	validation_0-rmse:1.37445	validation_1-rmse:1.65040
# [10]	validation_0-rmse:1.31878	validation_1-rmse:1.59413
# [11]	validation_0-rmse:1.26971	validation_1-rmse:1.54540
# [12]	validation_0-rmse:1.22310	validation_1-rmse:1.49368
# [13]	validation_0-rmse:1.17873	validation_1-rmse:1.44694
# [14]	validation_0-rmse:1.13565	validation_1-rmse:1.40392
# [15]	validation_0-rmse:1.09462	validation_1-rmse:1.36120
# [16]	validation_0-rmse:1.06072	validation_1-rmse:1.33081
# [17]	validation_0-rmse:1.02561	validation_1-rmse:1.29373
# [18]	validation_0-rmse:0.99537	validation_1-rmse:1.26477
# [19]	validation_0-rmse:0.96139	validation_1-rmse:1.23233
# [20]	validation_0-rmse:0.93243	validation_1-rmse:1.20542
# [21]	validation_0-rmse:0.90146	validation_1-rmse:1.18061
# [22]	validation_0-rmse:0.87388	validation_1-rmse:1.16436
# [23]	validation_0-rmse:0.85044	validation_1-rmse:1.14051
# [24]	validation_0-rmse:0.82697	validation_1-rmse:1.12270
# [25]	validation_0-rmse:0.80550	validation_1-rmse:1.10608
# [26]	validation_0-rmse:0.78647	validation_1-rmse:1.09273
# [27]	validation_0-rmse:0.76706	validation_1-rmse:1.07575
# [28]	validation_0-rmse:0.75018	validation_1-rmse:1.06116
# [29]	validation_0-rmse:0.73603	validation_1-rmse:1.04381
# [30]	validation_0-rmse:0.72007	validation_1-rmse:1.03169
# [31]	validation_0-rmse:0.70454	validation_1-rmse:1.01930
# [32]	validation_0-rmse:0.68952	validation_1-rmse:1.00902
# [33]	validation_0-rmse:0.67485	validation_1-rmse:0.99759
# [34]	validation_0-rmse:0.66280	validation_1-rmse:0.98644
# [35]	validation_0-rmse:0.64983	validation_1-rmse:0.97584
# [36]	validation_0-rmse:0.63499	validation_1-rmse:0.96905
# [37]	validation_0-rmse:0.62510	validation_1-rmse:0.96121
# [38]	validation_0-rmse:0.61411	validation_1-rmse:0.95371
# [39]	validation_0-rmse:0.60288	validation_1-rmse:0.94619
# [40]	validation_0-rmse:0.59362	validation_1-rmse:0.94006
# [41]	validation_0-rmse:0.58434	validation_1-rmse:0.93469
# [42]	validation_0-rmse:0.57551	validation_1-rmse:0.93115
# [43]	validation_0-rmse:0.56771	validation_1-rmse:0.92685
# [44]	validation_0-rmse:0.56006	validation_1-rmse:0.92298
# [45]	validation_0-rmse:0.55229	validation_1-rmse:0.91739
# [46]	validation_0-rmse:0.54729	validation_1-rmse:0.91533
# [47]	validation_0-rmse:0.53952	validation_1-rmse:0.91155
# [48]	validation_0-rmse:0.53262	validation_1-rmse:0.91003
# [49]	validation_0-rmse:0.52475	validation_1-rmse:0.90959
# [50]	validation_0-rmse:0.52089	validation_1-rmse:0.90718
# [51]	validation_0-rmse:0.51444	validation_1-rmse:0.90493
# [52]	validation_0-rmse:0.50757	validation_1-rmse:0.90194
# [53]	validation_0-rmse:0.50283	validation_1-rmse:0.89927
# [0]	validation_0-rmse:2.12216	validation_1-rmse:1.81612
# [1]	validation_0-rmse:2.02601	validation_1-rmse:1.71659
# [2]	validation_0-rmse:1.93428	validation_1-rmse:1.63081

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=10, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("./../03_output_data/XGBoost_models/UAV_Tag_Sr_XGB_model_2024.json")
# Save to text format
f_xgb_model.save_model("./../03_output_data/XGBoost_models/UAV_Tag_Sr_XGB_model_2024.txt")
