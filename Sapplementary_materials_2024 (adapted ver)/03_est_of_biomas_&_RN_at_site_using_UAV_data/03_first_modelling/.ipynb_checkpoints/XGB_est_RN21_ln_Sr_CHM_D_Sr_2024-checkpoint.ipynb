# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'r_MIN', 'contr_b_MAX', 'contr_b_STD'])

# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           2260           1210     -0.731      2.576
# 1       8.189       9.622           2700           1180      0.585      2.915
# 2       8.380       9.589           2500           1400      0.779      2.882
# 3       8.137       9.449           2500           1090      0.517      2.724
# 4       7.696       9.401           2400            720      0.224      2.826
#
#    AEDR_mean  r_MIN  contr_b_MAX  contr_b_STD
# 0       2.33     13  2713.600586   332.963753
# 1       2.47     24  1793.493042   293.868420
# 2       2.44     18  1761.097900   272.526176
# 3       2.55     15  2518.435303   299.595643
# 4       2.14      8  2525.819336   327.599176

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   r_MIN          103 non-null    int64
#  8   contr_b_MAX    103 non-null    float64
#  9   contr_b_STD    103 non-null    float64
# dtypes: float64(7), int64(3)
# memory usage: 8.2 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3440.194175    1242.902913   -0.252563
# std       1.64946    1.472424    6087.580089    2037.684800    1.104610
# min       3.52600    6.075000     260.000000      50.000000   -3.033000
# 25%       6.31900    7.664000     635.000000     200.000000   -0.727500
# 50%       6.95700    8.472000    1150.000000     400.000000   -0.025000
# 75%       7.91350    9.421000    2525.000000    1400.000000    0.516500
# max      11.36700   13.864000   35200.000000   10500.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean       r_MIN  contr_b_MAX  contr_b_STD
# count  103.000000  103.000000  103.000000   103.000000   103.000000
# mean     2.464709    3.570291   11.378641  2712.352866   349.854034
# std      0.904675    6.089170    9.139568   864.116297    93.673105
# min      0.391000    0.480000    2.000000   832.155518   109.232976
# 25%      1.803000    0.710000    5.000000  2123.614868   292.544440
# 50%      2.603000    1.290000    8.000000  2601.248047   341.904211
# 75%      3.159000    2.960000   15.000000  3045.944336   427.359073
# max      4.659000   36.590000   56.000000  6252.923340   588.661708

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['Sr_2021_kBq_m'])
y = pd.DataFrame(select, columns= ['ln_Sr_wood'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Sr_2021_kBq_m
# 0           1210
# 1           1180
# 2           1400
# 3           1090
# 4            720

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Sr_wood
# 0       9.240
# 1       9.622
# 2       9.589
# 3       9.449
# 4       9.401

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.6345875280660904, 0.07155066951774391, 0.4507356900676486]
#     Mean: 0.386
#     Std: 0.234
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.15101245 0.91862798 1.1711442 ]
#     Mean: 1.080
#     Std: 0.115
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.8286248441423688, 0.9598619568768669, 0.7913440523708568]
#     Mean: 0.860
#     Std: 0.072
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.183 (std: 0.362)
# Parameters: {'colsample_bytree': 0.05889981913345711, 'gamma': 0.2744957828289574, 'learning_rate': 0.07870872718428862, 'max_depth': 2, 'n_estimators': 86, 'subsample': 0.9671340269777906}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.19364934, 0.64822702, 0.33911624, ..., 0.47657928, 0.19038053,
#        0.30679512]), 'std_fit_time': array([0.04426035, 0.14523947, 0.14682064, ..., 0.02799382, 0.0043104 ,
#        0.01338644]), 'mean_score_time': array([0.0073338 , 0.00604353, 0.00575204, ..., 0.0056283 , 0.00556617,
#        0.00554366]), 'std_score_time': array([3.22616669e-03, 4.23439333e-04, 6.28719151e-05, ...,
#        4.53791170e-05, 2.37986173e-05, 2.24150999e-05]), 'param_colsample_bytree': masked_array(data=[0.40396931941842207, 0.17685181066056338,
#                    0.6496888887411811, ..., 0.6571322684230352,
#                    0.22958682142270043, 0.8558771509149443],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.06405787929028894, 0.10926878666890666,
#                    0.06828232681420465, ..., 0.2576153284964063,
#                    0.34733834135067354, 0.48231236150314144],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.07039057048195818, 0.2312360937323008,
#                    0.1946809216094524, ..., 0.09890865723880216,
#                    0.2552076356698312, 0.10738901589060496],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[4, 3, 4, ..., 3, 4, 2],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[65, 191, 97, ..., 195, 75, 126],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.6238142176276857, 0.6217838798408697,
#                    0.6367828539063327, ..., 0.8283537967119763,
#                    0.6697820351814245, 0.738903499034358],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.40396931941842207, 'gamma': 0.06405787929028894, 'learning_rate': 0.07039057048195818, 'max_depth': 4, 'n_estimators': 65, 'subsample': 0.6238142176276857}, {'colsample_bytree': 0.17685181066056338, 'gamma': 0.10926878666890666, 'learning_rate': 0.2312360937323008, 'max_depth': 3, 'n_estimators': 191, 'subsample': 0.6217838798408697}, {'colsample_bytree': 0.6496888887411811, 'gamma': 0.06828232681420465, 'learning_rate': 0.1946809216094524, 'max_depth': 4, 'n_estimators': 97, 'subsample': 0.6367828539063327}, {'colsample_bytree': 0.6648924295068112, 'gamma': 0.27911644965927707, 'learning_rate': 0.22732595851629908, 'max_depth': 4, 'n_estimators': 90, 'subsample': 0.9243857985515689}, {'colsample_bytree': 0.1359960056259859, 'gamma': 0.3168317343293558, 'learning_rate': 0.03152327610831159, 'max_depth': 3, 'n_estimators': 153, 'subsample': 0.9384889207622864}, {'colsample_bytree': 0.3447385720921683, 'gamma': 0.32948158332126687, 'learning_rate': 0.014534666719548898, 'max_depth': 3, 'n_estimators': 160, 'subsample': 0.6199212570190674}, {'colsample_bytree': 0.33428428798863613, 'gamma': 0.4261798603217332, 'learning_rate': 0.1726169088160315, 'max_depth': 4, 'n_estimators': 63, 'subsample': 0.3089076995429239}, {'colsample_bytree': 0.2764960028674483, 'gamma': 0.4196949651828248, 'learning_rate': 0.13362755777614518, 'max_depth': 3, 'n_estimators': 165, 'subsample': 0.8276429873843165}, {'colsample_bytree': 0.7080481809248812, 'gamma': 0.3782044468248502, 'learning_rate': 0.08048055794873771, 'max_depth': 2, 'n_estimators': 188, 'subsample': 0.6479249814897297}, {'colsample_bytree': 0.5141350575822964, 'gamma': 0.37588093721412014, 'learning_rate': 0.027774084423181113, 'max_depth': 3, 'n_estimators': 84, 'subsample': 0.5565394460826918}, {'colsample_bytree': 0.9043221409988899, 'gamma': 0.4237380342490746, 'learning_rate': 0.25528250451492057, 'max_depth': 2, 'n_estimators': 154, 'subsample': 0.44405783696775203}, {'colsample_bytree': 0.4136751816702425, 'gamma': 0.21050147832785437, 'learning_rate': 0.08080744817555646, 'max_depth': 4, 'n_estimators': 157, 'subsample': 0.9838543779452882}, {'colsample_bytree': 0.7816845052964652, 'gamma': 0.20791555479691137, 'learning_rate': 0.23522057546234476, 'max_depth': 3, 'n_estimators': 95, 'subsample': 0.4338254131125575}, {'colsample_bytree': 0.11103109058277494, 'gamma': 0.0037382363493367876, 'learning_rate': 0.0716609166687825, 'max_depth': 3, 'n_estimators': 80, 'subsample': 0.4217865578059641}, {'colsample_bytree': 0.5096590018280399, 'gamma': 0.17688901195776402, 'learning_rate': 0.09407242403108731, 'max_depth': 3, 'n_estimators': 135, 'subsample': 0.4182926367342816}, {'colsample_bytree': 0.4041706561723071, 'gamma': 0.15614500770845507, 'learning_rate': 0.1638210448725745, 'max_depth': 2, 'n_estimators': 180, 'subsample': 0.5167665282403711}, {'colsample_bytree': 0.9008140630037436, 'gamma': 0.4902608865137903, 'learning_rate': 0.02924641805953001, 'max_depth': 4, 'n_estimators': 68, 'subsample': 0.5477548945888076}, {'colsample_bytree': 0.5017241079329946, 'gamma': 0.0454438105583887, 'learning_rate': 0.03874315875434475, 'max_depth': 2, 'n_estimators': 153, 'subsample': 0.33634393566548954}, {'colsample_bytree': 0.20226181556090822, 'gamma': 0.32129552558098257, 'learning_rate': 0.09214251458567535, 'max_depth': 4, 'n_estimators': 102, 'subsample': 0.7867490354870914}, {'colsample_bytree': 0.8968859994092915, 'gamma': 0.007963444997844515, 'learning_rate': 0.10840813530491414, 'max_depth': 3, 'n_estimators': 167, 'subsample': 0.6614522551483271}, {'colsample_bytree': 0.6987497938462177, 'gamma': 0.4083808003001336, 'learning_rate': 0.037035648640517685, 'max_depth': 3, 'n_estimators': 95, 'subsample': 0.8027128407651174}, {'colsample_bytree': 0.7013320483190153, 'gamma': 0.3812050643112227, 'learning_rate': 0.12430147979720067, 'max_depth': 2, 'n_estimators': 152, 'subsample': 0.9501693441873709}, {'colsample_ ...
#        -1.46863786, -0.56645106]), 'split1_test_score': array([-0.61240047, -1.28378753, -1.37210528, ..., -0.75015198,
#        -0.85604763, -0.48204099]), 'split2_test_score': array([ 0.15578217, -0.66880017, -0.49516924, ..., -0.12089076,
#        -0.23881399,  0.05638317]), 'split3_test_score': array([0.46125443, 0.53695814, 0.51888331, ..., 0.59262992, 0.5603791 ,
#        0.62524573]), 'split4_test_score': array([0.68268287, 0.49592535, 0.51270123, ..., 0.57582388, 0.54669435,
#        0.59111758]), 'mean_test_score': array([ 0.01725038, -0.57114814, -0.49531319, ..., -0.14566069,
#        -0.29128521,  0.04485089]), 'std_test_score': array([0.5362663 , 0.97435685, 0.90837944, ..., 0.66424859, 0.79188521,
#        0.50728761]), 'rank_test_score': array([ 575, 2671, 2524, ..., 1305, 1844,  447], dtype=int32), 'split0_train_score': array([0.83427488, 0.91083936, 0.90972735, ..., 0.89058869, 0.89535511,
#        0.85794679]), 'split1_train_score': array([0.82757178, 0.90478561, 0.90326243, ..., 0.88432971, 0.88808081,
#        0.85031399]), 'split2_train_score': array([0.83241831, 0.92959925, 0.92855839, ..., 0.89746845, 0.90276535,
#        0.85717664]), 'split3_train_score': array([0.74338049, 0.87327823, 0.87290733, ..., 0.83674732, 0.84411804,
#        0.76926329]), 'split4_train_score': array([0.81714095, 0.91356091, 0.91517643, ..., 0.88296152, 0.88969304,
#        0.83785834]), 'mean_train_score': array([0.81095728, 0.90641267, 0.90592639, ..., 0.87841914, 0.88400247,
#        0.83451181]), 'std_train_score': array([0.03430798, 0.01848702, 0.01849093, ..., 0.02146198, 0.02059471,
#        0.03341009])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.05889981913345711
# Gamma: 0.2744957828289574
# Learning_rate: 0.07870872718428862
# Max_depth: 2
# N_estimators: 86
# Subsample: 0.9671340269777906

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=10, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:7.75725	validation_1-rmse:7.28954
# [1]	validation_0-rmse:7.17433	validation_1-rmse:6.74943
# [2]	validation_0-rmse:6.63545	validation_1-rmse:6.24752
# [3]	validation_0-rmse:6.14296	validation_1-rmse:5.76895
# [4]	validation_0-rmse:5.68604	validation_1-rmse:5.34512
# [5]	validation_0-rmse:5.26373	validation_1-rmse:4.93828
# [6]	validation_0-rmse:4.87557	validation_1-rmse:4.56478
# [7]	validation_0-rmse:4.52042	validation_1-rmse:4.23761
# [8]	validation_0-rmse:4.18887	validation_1-rmse:3.91926
# [9]	validation_0-rmse:3.88546	validation_1-rmse:3.62286
# [10]	validation_0-rmse:3.60626	validation_1-rmse:3.36732
# [11]	validation_0-rmse:3.35042	validation_1-rmse:3.13359
# [12]	validation_0-rmse:3.11108	validation_1-rmse:2.90089
# [13]	validation_0-rmse:2.89461	validation_1-rmse:2.69466
# [14]	validation_0-rmse:2.69386	validation_1-rmse:2.50222
# [15]	validation_0-rmse:2.51222	validation_1-rmse:2.32970
# [16]	validation_0-rmse:2.34569	validation_1-rmse:2.16979
# [17]	validation_0-rmse:2.18915	validation_1-rmse:2.03280
# [18]	validation_0-rmse:2.04779	validation_1-rmse:1.89734
# [19]	validation_0-rmse:1.92086	validation_1-rmse:1.77778
# [20]	validation_0-rmse:1.80225	validation_1-rmse:1.67591
# [21]	validation_0-rmse:1.69435	validation_1-rmse:1.58132
# [22]	validation_0-rmse:1.59747	validation_1-rmse:1.49656
# [23]	validation_0-rmse:1.50953	validation_1-rmse:1.41933
# [24]	validation_0-rmse:1.42648	validation_1-rmse:1.34882
# [25]	validation_0-rmse:1.35332	validation_1-rmse:1.28362
# [26]	validation_0-rmse:1.28479	validation_1-rmse:1.22961
# [27]	validation_0-rmse:1.22422	validation_1-rmse:1.17689
# [28]	validation_0-rmse:1.17237	validation_1-rmse:1.13033
# [29]	validation_0-rmse:1.12420	validation_1-rmse:1.08867
# [30]	validation_0-rmse:1.08140	validation_1-rmse:1.05419
# [31]	validation_0-rmse:1.04412	validation_1-rmse:1.02363
# [32]	validation_0-rmse:1.00588	validation_1-rmse:0.99800
# [33]	validation_0-rmse:0.97073	validation_1-rmse:0.97543
# [34]	validation_0-rmse:0.94245	validation_1-rmse:0.95194
# [35]	validation_0-rmse:0.91024	validation_1-rmse:0.93799
# [36]	validation_0-rmse:0.88789	validation_1-rmse:0.91976
# [37]	validation_0-rmse:0.86765	validation_1-rmse:0.90321
# [38]	validation_0-rmse:0.85043	validation_1-rmse:0.88984
# [39]	validation_0-rmse:0.83462	validation_1-rmse:0.87795
# [40]	validation_0-rmse:0.82030	validation_1-rmse:0.86648
# [41]	validation_0-rmse:0.80675	validation_1-rmse:0.85586
# [42]	validation_0-rmse:0.79570	validation_1-rmse:0.84816
# [43]	validation_0-rmse:0.77928	validation_1-rmse:0.84812
# [44]	validation_0-rmse:0.76472	validation_1-rmse:0.84905
# [45]	validation_0-rmse:0.75753	validation_1-rmse:0.84440
# [46]	validation_0-rmse:0.74877	validation_1-rmse:0.84347
# [47]	validation_0-rmse:0.74148	validation_1-rmse:0.83847
# [48]	validation_0-rmse:0.73505	validation_1-rmse:0.83418
# [49]	validation_0-rmse:0.73013	validation_1-rmse:0.83047
# [50]	validation_0-rmse:0.72070	validation_1-rmse:0.83409
# [51]	validation_0-rmse:0.71618	validation_1-rmse:0.83168
# [52]	validation_0-rmse:0.70825	validation_1-rmse:0.83655
# [53]	validation_0-rmse:0.70470	validation_1-rmse:0.83577
# [54]	validation_0-rmse:0.70176	validation_1-rmse:0.83419
# [55]	validation_0-rmse:0.69548	validation_1-rmse:0.83967
# [56]	validation_0-rmse:0.69014	validation_1-rmse:0.84519
# [57]	validation_0-rmse:0.68527	validation_1-rmse:0.85050
# [58]	validation_0-rmse:0.68098	validation_1-rmse:0.85618
# [0]	validation_0-rmse:7.56322	validation_1-rmse:8.07041
# [1]	validation_0-rmse:6.99791	validation_1-rmse:7.48171
# [2]	validation_0-rmse:6.47554	validation_1-rmse:6.93765
# [3]	validation_0-rmse:5.98981	validation_1-rmse:6.43146
# [4]	validation_0-rmse:5.54550	validation_1-rmse:5.97501
# [5]	validation_0-rmse:5.13662	validation_1-rmse:5.55104
# [6]	validation_0-rmse:4.75898	validation_1-rmse:5.15492
# [7]	validation_0-rmse:4.40787	validation_1-rmse:4.79087
# [8]	validation_0-rmse:4.09053	validation_1-rmse:4.45621
# [9]	validation_0-rmse:3.79750	validation_1-rmse:4.14224
# [10]	validation_0-rmse:3.52655	validation_1-rmse:3.85095
# [11]	validation_0-rmse:3.27598	validation_1-rmse:3.58246
# [12]	validation_0-rmse:3.04525	validation_1-rmse:3.33181
# [13]	validation_0-rmse:2.83249	validation_1-rmse:3.09948
# [14]	validation_0-rmse:2.63735	validation_1-rmse:2.88586
# [15]	validation_0-rmse:2.46580	validation_1-rmse:2.69400
# [16]	validation_0-rmse:2.30379	validation_1-rmse:2.51167
# [17]	validation_0-rmse:2.15730	validation_1-rmse:2.34383
# [18]	validation_0-rmse:2.02005	validation_1-rmse:2.18364
# [19]	validation_0-rmse:1.89519	validation_1-rmse:2.03804
# [20]	validation_0-rmse:1.78261	validation_1-rmse:1.90307
# [21]	validation_0-rmse:1.67990	validation_1-rmse:1.77775
# [22]	validation_0-rmse:1.59082	validation_1-rmse:1.66967
# [23]	validation_0-rmse:1.50595	validation_1-rmse:1.56548
# [24]	validation_0-rmse:1.42943	validation_1-rmse:1.47467
# [25]	validation_0-rmse:1.36013	validation_1-rmse:1.38582
# [26]	validation_0-rmse:1.29827	validation_1-rmse:1.30697
# [27]	validation_0-rmse:1.24108	validation_1-rmse:1.23374
# [28]	validation_0-rmse:1.19136	validation_1-rmse:1.17663
# [29]	validation_0-rmse:1.14420	validation_1-rmse:1.11509
# [30]	validation_0-rmse:1.10271	validation_1-rmse:1.06070
# [31]	validation_0-rmse:1.06702	validation_1-rmse:1.01970
# [32]	validation_0-rmse:1.03457	validation_1-rmse:0.97921
# [33]	validation_0-rmse:1.00559	validation_1-rmse:0.94437
# [34]	validation_0-rmse:0.97893	validation_1-rmse:0.90460
# [35]	validation_0-rmse:0.95574	validation_1-rmse:0.87273
# [36]	validation_0-rmse:0.93464	validation_1-rmse:0.84644
# [37]	validation_0-rmse:0.91612	validation_1-rmse:0.82302
# [38]	validation_0-rmse:0.89956	validation_1-rmse:0.80001
# [39]	validation_0-rmse:0.88365	validation_1-rmse:0.77857
# [40]	validation_0-rmse:0.86855	validation_1-rmse:0.75599
# [41]	validation_0-rmse:0.85691	validation_1-rmse:0.73995
# [42]	validation_0-rmse:0.84660	validation_1-rmse:0.72586
# [43]	validation_0-rmse:0.83661	validation_1-rmse:0.71299
# [44]	validation_0-rmse:0.82832	validation_1-rmse:0.70408
# [45]	validation_0-rmse:0.82068	validation_1-rmse:0.69053
# [46]	validation_0-rmse:0.81348	validation_1-rmse:0.67918
# [47]	validation_0-rmse:0.80727	validation_1-rmse:0.66992
# [48]	validation_0-rmse:0.80169	validation_1-rmse:0.66107
# [49]	validation_0-rmse:0.78984	validation_1-rmse:0.64505
# [50]	validation_0-rmse:0.78381	validation_1-rmse:0.63272
# [51]	validation_0-rmse:0.77391	validation_1-rmse:0.61920
# [52]	validation_0-rmse:0.77008	validation_1-rmse:0.61477
# [53]	validation_0-rmse:0.76168	validation_1-rmse:0.60328
# [54]	validation_0-rmse:0.75856	validation_1-rmse:0.59955
# [55]	validation_0-rmse:0.75583	validation_1-rmse:0.59646
# [56]	validation_0-rmse:0.75214	validation_1-rmse:0.58720
# [57]	validation_0-rmse:0.74515	validation_1-rmse:0.57722
# [58]	validation_0-rmse:0.74286	validation_1-rmse:0.57423
# [59]	validation_0-rmse:0.73837	validation_1-rmse:0.56988
# [60]	validation_0-rmse:0.73647	validation_1-rmse:0.56792
# [61]	validation_0-rmse:0.73286	validation_1-rmse:0.56416
# [62]	validation_0-rmse:0.73125	validation_1-rmse:0.56305
# [63]	validation_0-rmse:0.72897	validation_1-rmse:0.56211
# [64]	validation_0-rmse:0.72379	validation_1-rmse:0.55524
# [65]	validation_0-rmse:0.71931	validation_1-rmse:0.54933
# [66]	validation_0-rmse:0.71799	validation_1-rmse:0.54865
# [67]	validation_0-rmse:0.71680	validation_1-rmse:0.54767
# [68]	validation_0-rmse:0.71574	validation_1-rmse:0.54719
# [69]	validation_0-rmse:0.71156	validation_1-rmse:0.54181
# [70]	validation_0-rmse:0.71032	validation_1-rmse:0.54178
# [71]	validation_0-rmse:0.70933	validation_1-rmse:0.54220
# [72]	validation_0-rmse:0.70878	validation_1-rmse:0.54116
# [73]	validation_0-rmse:0.70830	validation_1-rmse:0.54043
# [74]	validation_0-rmse:0.70489	validation_1-rmse:0.53678
# [75]	validation_0-rmse:0.70444	validation_1-rmse:0.53670
# [76]	validation_0-rmse:0.70321	validation_1-rmse:0.53842
# [77]	validation_0-rmse:0.70019	validation_1-rmse:0.53497
# [78]	validation_0-rmse:0.69959	validation_1-rmse:0.53463
# [79]	validation_0-rmse:0.69783	validation_1-rmse:0.53135
# [80]	validation_0-rmse:0.69708	validation_1-rmse:0.53120
# [81]	validation_0-rmse:0.69630	validation_1-rmse:0.53137
# [82]	validation_0-rmse:0.69538	validation_1-rmse:0.53096
# [83]	validation_0-rmse:0.69202	validation_1-rmse:0.52859
# [84]	validation_0-rmse:0.69134	validation_1-rmse:0.52921
# [85]	validation_0-rmse:0.69134	validation_1-rmse:0.52897
# [0]	validation_0-rmse:7.68592	validation_1-rmse:7.55379
# [1]	validation_0-rmse:7.10301	validation_1-rmse:6.97041
# [2]	validation_0-rmse:6.57023	validation_1-rmse:6.43791
# [3]	validation_0-rmse:6.08034	validation_1-rmse:5.94907
# [4]	validation_0-rmse:5.62649	validation_1-rmse:5.49685
# [5]	validation_0-rmse:5.20810	validation_1-rmse:5.08057
# [6]	validation_0-rmse:4.82239	validation_1-rmse:4.71382
# [7]	validation_0-rmse:4.46438	validation_1-rmse:4.37391
# [8]	validation_0-rmse:4.13801	validation_1-rmse:4.05367
# [9]	validation_0-rmse:3.83967	validation_1-rmse:3.75956
# [10]	validation_0-rmse:3.56151	validation_1-rmse:3.49864
# [11]	validation_0-rmse:3.30686	validation_1-rmse:3.26056
# [12]	validation_0-rmse:3.07494	validation_1-rmse:3.03447
# [13]	validation_0-rmse:2.85915	validation_1-rmse:2.83482
# [14]	validation_0-rmse:2.66119	validation_1-rmse:2.65285
# [15]	validation_0-rmse:2.47673	validation_1-rmse:2.48372
# [16]	validation_0-rmse:2.30927	validation_1-rmse:2.32531
# [17]	validation_0-rmse:2.15488	validation_1-rmse:2.17838
# [18]	validation_0-rmse:2.01424	validation_1-rmse:2.05170
# [19]	validation_0-rmse:1.88553	validation_1-rmse:1.93661
# [20]	validation_0-rmse:1.76887	validation_1-rmse:1.83403
# [21]	validation_0-rmse:1.66378	validation_1-rmse:1.74090
# [22]	validation_0-rmse:1.56628	validation_1-rmse:1.65448
# [23]	validation_0-rmse:1.47583	validation_1-rmse:1.57536
# [24]	validation_0-rmse:1.39805	validation_1-rmse:1.50877
# [25]	validation_0-rmse:1.32397	validation_1-rmse:1.44576
# [26]	validation_0-rmse:1.25907	validation_1-rmse:1.39034
# [27]	validation_0-rmse:1.20175	validation_1-rmse:1.34281
# [28]	validation_0-rmse:1.15030	validation_1-rmse:1.29969
# [29]	validation_0-rmse:1.10216	validation_1-rmse:1.26235
# [30]	validation_0-rmse:1.05873	validation_1-rmse:1.22629
# [31]	validation_0-rmse:1.02168	validation_1-rmse:1.19418
# [32]	validation_0-rmse:0.98614	validation_1-rmse:1.16403
# [33]	validation_0-rmse:0.94921	validation_1-rmse:1.13397
# [34]	validation_0-rmse:0.92355	validation_1-rmse:1.10904
# [35]	validation_0-rmse:0.90153	validation_1-rmse:1.09034
# [36]	validation_0-rmse:0.88027	validation_1-rmse:1.07087
# [37]	validation_0-rmse:0.86099	validation_1-rmse:1.05228
# [38]	validation_0-rmse:0.84514	validation_1-rmse:1.03813
# [39]	validation_0-rmse:0.83106	validation_1-rmse:1.02846
# [40]	validation_0-rmse:0.81622	validation_1-rmse:1.01851
# [41]	validation_0-rmse:0.80490	validation_1-rmse:1.00629
# [42]	validation_0-rmse:0.79301	validation_1-rmse:1.00249
# [43]	validation_0-rmse:0.77677	validation_1-rmse:0.98959
# [44]	validation_0-rmse:0.76690	validation_1-rmse:0.98417
# [45]	validation_0-rmse:0.76055	validation_1-rmse:0.97758
# [46]	validation_0-rmse:0.75385	validation_1-rmse:0.97062
# [47]	validation_0-rmse:0.74821	validation_1-rmse:0.96546
# [48]	validation_0-rmse:0.74204	validation_1-rmse:0.96618
# [49]	validation_0-rmse:0.73154	validation_1-rmse:0.96251
# [50]	validation_0-rmse:0.72247	validation_1-rmse:0.95925
# [51]	validation_0-rmse:0.71412	validation_1-rmse:0.95627
# [52]	validation_0-rmse:0.71026	validation_1-rmse:0.95139
# [53]	validation_0-rmse:0.70718	validation_1-rmse:0.94609
# [54]	validation_0-rmse:0.70471	validation_1-rmse:0.94116
# [55]	validation_0-rmse:0.69849	validation_1-rmse:0.93979
# [56]	validation_0-rmse:0.69641	validation_1-rmse:0.93509
# [57]	validation_0-rmse:0.69395	validation_1-rmse:0.93133
# [58]	validation_0-rmse:0.69217	validation_1-rmse:0.92718
# [59]	validation_0-rmse:0.69054	validation_1-rmse:0.92333
# [60]	validation_0-rmse:0.68941	validation_1-rmse:0.91894
# [61]	validation_0-rmse:0.68448	validation_1-rmse:0.91672
# [62]	validation_0-rmse:0.68318	validation_1-rmse:0.91422
# [63]	validation_0-rmse:0.68195	validation_1-rmse:0.91095
# [64]	validation_0-rmse:0.68113	validation_1-rmse:0.90717
# [65]	validation_0-rmse:0.67985	validation_1-rmse:0.90238
# [66]	validation_0-rmse:0.67916	validation_1-rmse:0.89900
# [67]	validation_0-rmse:0.67857	validation_1-rmse:0.89569
# [68]	validation_0-rmse:0.67414	validation_1-rmse:0.89531
# [69]	validation_0-rmse:0.67356	validation_1-rmse:0.89232
# [70]	validation_0-rmse:0.67344	validation_1-rmse:0.89246
# [71]	validation_0-rmse:0.67184	validation_1-rmse:0.89105
# [72]	validation_0-rmse:0.66980	validation_1-rmse:0.89433
# [73]	validation_0-rmse:0.66934	validation_1-rmse:0.89131
# [74]	validation_0-rmse:0.66666	validation_1-rmse:0.89567
# [75]	validation_0-rmse:0.66436	validation_1-rmse:0.89768
# [76]	validation_0-rmse:0.66362	validation_1-rmse:0.89593
# [77]	validation_0-rmse:0.66014	validation_1-rmse:0.89614
# [78]	validation_0-rmse:0.65643	validation_1-rmse:0.89659
# [79]	validation_0-rmse:0.65356	validation_1-rmse:0.89571
# [80]	validation_0-rmse:0.65320	validation_1-rmse:0.89261
# [0]	validation_0-rmse:7.60558	validation_1-rmse:7.87601
# [1]	validation_0-rmse:7.03035	validation_1-rmse:7.29007
# [2]	validation_0-rmse:6.50345	validation_1-rmse:6.75365
# [3]	validation_0-rmse:6.01809	validation_1-rmse:6.25939
# [4]	validation_0-rmse:5.56990	validation_1-rmse:5.80346
# [5]	validation_0-rmse:5.15917	validation_1-rmse:5.39379
# [6]	validation_0-rmse:4.77853	validation_1-rmse:5.01688
# [7]	validation_0-rmse:4.42931	validation_1-rmse:4.66124
# [8]	validation_0-rmse:4.10542	validation_1-rmse:4.33119
# [9]	validation_0-rmse:3.80582	validation_1-rmse:4.03469
# [10]	validation_0-rmse:3.53159	validation_1-rmse:3.76321
# [11]	validation_0-rmse:3.27955	validation_1-rmse:3.51351
# [12]	validation_0-rmse:3.04737	validation_1-rmse:3.28323
# [13]	validation_0-rmse:2.83595	validation_1-rmse:3.06704
# [14]	validation_0-rmse:2.64520	validation_1-rmse:2.87391
# [15]	validation_0-rmse:2.46591	validation_1-rmse:2.69596
# [16]	validation_0-rmse:2.30084	validation_1-rmse:2.53186
# [17]	validation_0-rmse:2.15049	validation_1-rmse:2.38068
# [18]	validation_0-rmse:2.01396	validation_1-rmse:2.24300
# [19]	validation_0-rmse:1.88585	validation_1-rmse:2.11240
# [20]	validation_0-rmse:1.77100	validation_1-rmse:1.99482
# [21]	validation_0-rmse:1.66215	validation_1-rmse:1.88385
# [22]	validation_0-rmse:1.56712	validation_1-rmse:1.78574
# [23]	validation_0-rmse:1.48163	validation_1-rmse:1.69778
# [24]	validation_0-rmse:1.40182	validation_1-rmse:1.61413
# [25]	validation_0-rmse:1.33129	validation_1-rmse:1.54192
# [26]	validation_0-rmse:1.26870	validation_1-rmse:1.47639
# [27]	validation_0-rmse:1.20805	validation_1-rmse:1.40729
# [28]	validation_0-rmse:1.15612	validation_1-rmse:1.35075
# [29]	validation_0-rmse:1.10632	validation_1-rmse:1.29340
# [30]	validation_0-rmse:1.06040	validation_1-rmse:1.24051
# [31]	validation_0-rmse:1.02178	validation_1-rmse:1.19946
# [32]	validation_0-rmse:0.98828	validation_1-rmse:1.15772
# [33]	validation_0-rmse:0.95827	validation_1-rmse:1.12132
# [34]	validation_0-rmse:0.92947	validation_1-rmse:1.08760
# [35]	validation_0-rmse:0.90592	validation_1-rmse:1.05779
# [36]	validation_0-rmse:0.88400	validation_1-rmse:1.02997
# [37]	validation_0-rmse:0.86468	validation_1-rmse:1.00532
# [38]	validation_0-rmse:0.84788	validation_1-rmse:0.98394
# [39]	validation_0-rmse:0.83293	validation_1-rmse:0.96497
# [40]	validation_0-rmse:0.82052	validation_1-rmse:0.94849
# [41]	validation_0-rmse:0.80838	validation_1-rmse:0.93271
# [42]	validation_0-rmse:0.79744	validation_1-rmse:0.91664
# [43]	validation_0-rmse:0.78826	validation_1-rmse:0.90293
# [44]	validation_0-rmse:0.77981	validation_1-rmse:0.89255
# [45]	validation_0-rmse:0.77212	validation_1-rmse:0.88278
# [46]	validation_0-rmse:0.76496	validation_1-rmse:0.87356
# [47]	validation_0-rmse:0.75769	validation_1-rmse:0.86638
# [48]	validation_0-rmse:0.75175	validation_1-rmse:0.85924
# [49]	validation_0-rmse:0.74615	validation_1-rmse:0.85409
# [50]	validation_0-rmse:0.73989	validation_1-rmse:0.85082
# [51]	validation_0-rmse:0.73569	validation_1-rmse:0.84596
# [52]	validation_0-rmse:0.73208	validation_1-rmse:0.84083
# [53]	validation_0-rmse:0.72868	validation_1-rmse:0.83740
# [54]	validation_0-rmse:0.72542	validation_1-rmse:0.83391
# [55]	validation_0-rmse:0.72257	validation_1-rmse:0.83139
# [56]	validation_0-rmse:0.71982	validation_1-rmse:0.82762
# [57]	validation_0-rmse:0.71744	validation_1-rmse:0.82627
# [58]	validation_0-rmse:0.71506	validation_1-rmse:0.82314
# [59]	validation_0-rmse:0.71303	validation_1-rmse:0.82176
# [60]	validation_0-rmse:0.71107	validation_1-rmse:0.82048
# [61]	validation_0-rmse:0.70414	validation_1-rmse:0.80984
# [62]	validation_0-rmse:0.70247	validation_1-rmse:0.80812
# [63]	validation_0-rmse:0.69891	validation_1-rmse:0.80766
# [64]	validation_0-rmse:0.69736	validation_1-rmse:0.80708
# [65]	validation_0-rmse:0.69442	validation_1-rmse:0.80669
# [66]	validation_0-rmse:0.69306	validation_1-rmse:0.80683
# [67]	validation_0-rmse:0.68736	validation_1-rmse:0.79909
# [68]	validation_0-rmse:0.68617	validation_1-rmse:0.79862
# [69]	validation_0-rmse:0.68484	validation_1-rmse:0.79862
# [70]	validation_0-rmse:0.68295	validation_1-rmse:0.79574
# [71]	validation_0-rmse:0.68124	validation_1-rmse:0.79405
# [72]	validation_0-rmse:0.67632	validation_1-rmse:0.78726
# [73]	validation_0-rmse:0.67530	validation_1-rmse:0.78766
# [74]	validation_0-rmse:0.67473	validation_1-rmse:0.78808
# [75]	validation_0-rmse:0.67264	validation_1-rmse:0.79036
# [76]	validation_0-rmse:0.66839	validation_1-rmse:0.78459
# [77]	validation_0-rmse:0.66787	validation_1-rmse:0.78503
# [78]	validation_0-rmse:0.66704	validation_1-rmse:0.78614
# [79]	validation_0-rmse:0.66329	validation_1-rmse:0.78071
# [80]	validation_0-rmse:0.66191	validation_1-rmse:0.77945
# [81]	validation_0-rmse:0.65850	validation_1-rmse:0.77989
# [82]	validation_0-rmse:0.65844	validation_1-rmse:0.77937
# [83]	validation_0-rmse:0.65482	validation_1-rmse:0.77828
# [84]	validation_0-rmse:0.65274	validation_1-rmse:0.77848
# [85]	validation_0-rmse:0.65270	validation_1-rmse:0.77804
# [0]	validation_0-rmse:7.73781	validation_1-rmse:7.34406
# [1]	validation_0-rmse:7.15341	validation_1-rmse:6.78984
# [2]	validation_0-rmse:6.61516	validation_1-rmse:6.28056
# [3]	validation_0-rmse:6.11817	validation_1-rmse:5.81104
# [4]	validation_0-rmse:5.66048	validation_1-rmse:5.37958
# [5]	validation_0-rmse:5.23907	validation_1-rmse:4.98306
# [6]	validation_0-rmse:4.84922	validation_1-rmse:4.61869
# [7]	validation_0-rmse:4.49121	validation_1-rmse:4.28247
# [8]	validation_0-rmse:4.16067	validation_1-rmse:3.97345
# [9]	validation_0-rmse:3.85916	validation_1-rmse:3.69087
# [10]	validation_0-rmse:3.57907	validation_1-rmse:3.43409
# [11]	validation_0-rmse:3.32132	validation_1-rmse:3.19398
# [12]	validation_0-rmse:3.08528	validation_1-rmse:2.97522
# [13]	validation_0-rmse:2.86922	validation_1-rmse:2.77609
# [14]	validation_0-rmse:2.67021	validation_1-rmse:2.59385
# [15]	validation_0-rmse:2.48805	validation_1-rmse:2.43322
# [16]	validation_0-rmse:2.31940	validation_1-rmse:2.28608
# [17]	validation_0-rmse:2.16472	validation_1-rmse:2.14800
# [18]	validation_0-rmse:2.02267	validation_1-rmse:2.02662
# [19]	validation_0-rmse:1.89450	validation_1-rmse:1.91398
# [20]	validation_0-rmse:1.77699	validation_1-rmse:1.81323
# [21]	validation_0-rmse:1.66770	validation_1-rmse:1.71918
# [22]	validation_0-rmse:1.56944	validation_1-rmse:1.63489
# [23]	validation_0-rmse:1.47833	validation_1-rmse:1.55768
# [24]	validation_0-rmse:1.39569	validation_1-rmse:1.49460
# [25]	validation_0-rmse:1.32172	validation_1-rmse:1.43255
# [26]	validation_0-rmse:1.25796	validation_1-rmse:1.38087
# [27]	validation_0-rmse:1.19628	validation_1-rmse:1.33533
# [28]	validation_0-rmse:1.14355	validation_1-rmse:1.29861
# [29]	validation_0-rmse:1.09436	validation_1-rmse:1.25988
# [30]	validation_0-rmse:1.05129	validation_1-rmse:1.22624
# [31]	validation_0-rmse:1.01203	validation_1-rmse:1.19415
# [32]	validation_0-rmse:0.97670	validation_1-rmse:1.16179
# [33]	validation_0-rmse:0.93693	validation_1-rmse:1.12794
# [34]	validation_0-rmse:0.90923	validation_1-rmse:1.10944
# [35]	validation_0-rmse:0.87889	validation_1-rmse:1.08177
# [36]	validation_0-rmse:0.85758	validation_1-rmse:1.06791
# [37]	validation_0-rmse:0.83875	validation_1-rmse:1.05297
# [38]	validation_0-rmse:0.82196	validation_1-rmse:1.03987
# [39]	validation_0-rmse:0.80693	validation_1-rmse:1.02813
# [40]	validation_0-rmse:0.79425	validation_1-rmse:1.01837
# [41]	validation_0-rmse:0.78288	validation_1-rmse:1.00921
# [42]	validation_0-rmse:0.76796	validation_1-rmse:0.99994
# [43]	validation_0-rmse:0.75947	validation_1-rmse:0.99086
# [44]	validation_0-rmse:0.75160	validation_1-rmse:0.98268
# [45]	validation_0-rmse:0.74471	validation_1-rmse:0.97749
# [46]	validation_0-rmse:0.73888	validation_1-rmse:0.97078
# [47]	validation_0-rmse:0.73314	validation_1-rmse:0.96496
# [48]	validation_0-rmse:0.72765	validation_1-rmse:0.95702
# [49]	validation_0-rmse:0.72352	validation_1-rmse:0.95339
# [50]	validation_0-rmse:0.72007	validation_1-rmse:0.94874
# [51]	validation_0-rmse:0.71671	validation_1-rmse:0.94012
# [52]	validation_0-rmse:0.70785	validation_1-rmse:0.93511
# [53]	validation_0-rmse:0.70563	validation_1-rmse:0.93126
# [54]	validation_0-rmse:0.70322	validation_1-rmse:0.92759
# [55]	validation_0-rmse:0.69957	validation_1-rmse:0.92361
# [56]	validation_0-rmse:0.69793	validation_1-rmse:0.91896
# [57]	validation_0-rmse:0.69641	validation_1-rmse:0.91463
# [58]	validation_0-rmse:0.69504	validation_1-rmse:0.91058
# [59]	validation_0-rmse:0.69331	validation_1-rmse:0.90424
# [60]	validation_0-rmse:0.68667	validation_1-rmse:0.90129
# [61]	validation_0-rmse:0.68513	validation_1-rmse:0.89821
# [62]	validation_0-rmse:0.68230	validation_1-rmse:0.89423
# [63]	validation_0-rmse:0.68130	validation_1-rmse:0.89047
# [64]	validation_0-rmse:0.67560	validation_1-rmse:0.89086
# [65]	validation_0-rmse:0.67056	validation_1-rmse:0.89172
# [66]	validation_0-rmse:0.66957	validation_1-rmse:0.88643
# [67]	validation_0-rmse:0.66718	validation_1-rmse:0.88221
# [68]	validation_0-rmse:0.66245	validation_1-rmse:0.88312
# [69]	validation_0-rmse:0.65856	validation_1-rmse:0.88499
# [70]	validation_0-rmse:0.65799	validation_1-rmse:0.88170
# [71]	validation_0-rmse:0.65655	validation_1-rmse:0.88202
# [72]	validation_0-rmse:0.65605	validation_1-rmse:0.87888
# [73]	validation_0-rmse:0.65483	validation_1-rmse:0.87917
# [74]	validation_0-rmse:0.65475	validation_1-rmse:0.87940
# [75]	validation_0-rmse:0.65468	validation_1-rmse:0.87959
# [76]	validation_0-rmse:0.65465	validation_1-rmse:0.87972
# [77]	validation_0-rmse:0.65461	validation_1-rmse:0.87986
# [78]	validation_0-rmse:0.65100	validation_1-rmse:0.88132
# [79]	validation_0-rmse:0.65097	validation_1-rmse:0.88145
# [80]	validation_0-rmse:0.65056	validation_1-rmse:0.87840
# [81]	validation_0-rmse:0.65054	validation_1-rmse:0.87852
# [82]	validation_0-rmse:0.65001	validation_1-rmse:0.87556
# [83]	validation_0-rmse:0.64945	validation_1-rmse:0.87355
# [84]	validation_0-rmse:0.64671	validation_1-rmse:0.88273
# [85]	validation_0-rmse:0.64480	validation_1-rmse:0.88396
# [0]	validation_0-rmse:7.66393	validation_1-rmse:7.65486
# [1]	validation_0-rmse:7.09100	validation_1-rmse:7.08539
# [2]	validation_0-rmse:6.55969	validation_1-rmse:6.57953
# [3]	validation_0-rmse:6.07351	validation_1-rmse:6.09601
# [4]	validation_0-rmse:5.62168	validation_1-rmse:5.66686
# [5]	validation_0-rmse:5.20803	validation_1-rmse:5.25451
# [6]	validation_0-rmse:4.82502	validation_1-rmse:4.88973
# [7]	validation_0-rmse:4.47318	validation_1-rmse:4.53823
# [8]	validation_0-rmse:4.14554	validation_1-rmse:4.22335
# [9]	validation_0-rmse:3.84488	validation_1-rmse:3.93514
# [10]	validation_0-rmse:3.56859	validation_1-rmse:3.67327
# [11]	validation_0-rmse:3.31878	validation_1-rmse:3.42305
# [12]	validation_0-rmse:3.08586	validation_1-rmse:3.19975
# [13]	validation_0-rmse:2.87360	validation_1-rmse:2.98608
# [14]	validation_0-rmse:2.67697	validation_1-rmse:2.79736
# [15]	validation_0-rmse:2.49588	validation_1-rmse:2.62208
# [16]	validation_0-rmse:2.32907	validation_1-rmse:2.46083
# [17]	validation_0-rmse:2.17759	validation_1-rmse:2.31728
# [18]	validation_0-rmse:2.03950	validation_1-rmse:2.18198
# [19]	validation_0-rmse:1.91267	validation_1-rmse:2.05691
# [20]	validation_0-rmse:1.79625	validation_1-rmse:1.94177
# [21]	validation_0-rmse:1.68803	validation_1-rmse:1.83371
# [22]	validation_0-rmse:1.59091	validation_1-rmse:1.73672
# [23]	validation_0-rmse:1.50212	validation_1-rmse:1.64990
# [24]	validation_0-rmse:1.42454	validation_1-rmse:1.57514
# [25]	validation_0-rmse:1.35331	validation_1-rmse:1.50330
# [26]	validation_0-rmse:1.28569	validation_1-rmse:1.43365
# [27]	validation_0-rmse:1.22932	validation_1-rmse:1.37600
# [28]	validation_0-rmse:1.17539	validation_1-rmse:1.31938
# [29]	validation_0-rmse:1.12732	validation_1-rmse:1.26927
# [30]	validation_0-rmse:1.08443	validation_1-rmse:1.22219
# [31]	validation_0-rmse:1.04765	validation_1-rmse:1.17907
# [32]	validation_0-rmse:1.01368	validation_1-rmse:1.14150
# [33]	validation_0-rmse:0.98412	validation_1-rmse:1.10907
# [34]	validation_0-rmse:0.95560	validation_1-rmse:1.07567
# [35]	validation_0-rmse:0.93206	validation_1-rmse:1.05072
# [36]	validation_0-rmse:0.91058	validation_1-rmse:1.02482
# [37]	validation_0-rmse:0.89143	validation_1-rmse:1.00118
# [38]	validation_0-rmse:0.87339	validation_1-rmse:0.97825
# [39]	validation_0-rmse:0.85698	validation_1-rmse:0.95752
# [40]	validation_0-rmse:0.84306	validation_1-rmse:0.94033
# [41]	validation_0-rmse:0.83073	validation_1-rmse:0.92364
# [42]	validation_0-rmse:0.82019	validation_1-rmse:0.90927
# [43]	validation_0-rmse:0.81066	validation_1-rmse:0.89696
# [44]	validation_0-rmse:0.80208	validation_1-rmse:0.88508
# [45]	validation_0-rmse:0.79397	validation_1-rmse:0.87306
# [46]	validation_0-rmse:0.78671	validation_1-rmse:0.86516
# [47]	validation_0-rmse:0.77259	validation_1-rmse:0.85101
# [48]	validation_0-rmse:0.76717	validation_1-rmse:0.84368
# [49]	validation_0-rmse:0.76163	validation_1-rmse:0.83947
# [50]	validation_0-rmse:0.75711	validation_1-rmse:0.83216
# [51]	validation_0-rmse:0.74566	validation_1-rmse:0.82428
# [52]	validation_0-rmse:0.73954	validation_1-rmse:0.81908
# [53]	validation_0-rmse:0.73393	validation_1-rmse:0.81543
# [54]	validation_0-rmse:0.73066	validation_1-rmse:0.81013
# [55]	validation_0-rmse:0.72605	validation_1-rmse:0.80771
# [56]	validation_0-rmse:0.72329	validation_1-rmse:0.80305
# [57]	validation_0-rmse:0.72088	validation_1-rmse:0.80051
# [58]	validation_0-rmse:0.71818	validation_1-rmse:0.80381
# [59]	validation_0-rmse:0.70987	validation_1-rmse:0.79910
# [60]	validation_0-rmse:0.70779	validation_1-rmse:0.79565
# [61]	validation_0-rmse:0.70555	validation_1-rmse:0.79217
# [62]	validation_0-rmse:0.69871	validation_1-rmse:0.79025
# [63]	validation_0-rmse:0.69706	validation_1-rmse:0.78772
# [64]	validation_0-rmse:0.69558	validation_1-rmse:0.78537
# [65]	validation_0-rmse:0.69404	validation_1-rmse:0.78464
# [66]	validation_0-rmse:0.68809	validation_1-rmse:0.78343
# [67]	validation_0-rmse:0.68481	validation_1-rmse:0.78439
# [68]	validation_0-rmse:0.68363	validation_1-rmse:0.78348
# [69]	validation_0-rmse:0.68054	validation_1-rmse:0.78409
# [70]	validation_0-rmse:0.67944	validation_1-rmse:0.78261
# [71]	validation_0-rmse:0.67436	validation_1-rmse:0.78332
# [72]	validation_0-rmse:0.67269	validation_1-rmse:0.78799
# [73]	validation_0-rmse:0.66760	validation_1-rmse:0.78954
# [74]	validation_0-rmse:0.66666	validation_1-rmse:0.78876
# [75]	validation_0-rmse:0.66216	validation_1-rmse:0.78755
# [76]	validation_0-rmse:0.66122	validation_1-rmse:0.78631
# [77]	validation_0-rmse:0.66074	validation_1-rmse:0.78579
# [78]	validation_0-rmse:0.65867	validation_1-rmse:0.78705
# [79]	validation_0-rmse:0.65784	validation_1-rmse:0.78623
# [0]	validation_0-rmse:7.63529	validation_1-rmse:7.82404
# [1]	validation_0-rmse:7.06353	validation_1-rmse:7.23588
# [2]	validation_0-rmse:6.53512	validation_1-rmse:6.73757
# [3]	validation_0-rmse:6.04957	validation_1-rmse:6.28072
# [4]	validation_0-rmse:5.59907	validation_1-rmse:5.85384
# [5]	validation_0-rmse:5.18251	validation_1-rmse:5.42274
# [6]	validation_0-rmse:4.79887	validation_1-rmse:5.06011
# [7]	validation_0-rmse:4.44943	validation_1-rmse:4.69753
# [8]	validation_0-rmse:4.12491	validation_1-rmse:4.38929
# [9]	validation_0-rmse:3.82503	validation_1-rmse:4.10459
# [10]	validation_0-rmse:3.54942	validation_1-rmse:3.84337
# [11]	validation_0-rmse:3.29483	validation_1-rmse:3.60583
# [12]	validation_0-rmse:3.06180	validation_1-rmse:3.36112
# [13]	validation_0-rmse:2.84831	validation_1-rmse:3.16022
# [14]	validation_0-rmse:2.65347	validation_1-rmse:2.96188
# [15]	validation_0-rmse:2.47752	validation_1-rmse:2.77577
# [16]	validation_0-rmse:2.31105	validation_1-rmse:2.62017
# [17]	validation_0-rmse:2.15834	validation_1-rmse:2.48060
# [18]	validation_0-rmse:2.02138	validation_1-rmse:2.33438
# [19]	validation_0-rmse:1.89387	validation_1-rmse:2.21839
# [20]	validation_0-rmse:1.77722	validation_1-rmse:2.11243
# [21]	validation_0-rmse:1.66932	validation_1-rmse:2.01366
# [22]	validation_0-rmse:1.57379	validation_1-rmse:1.92593
# [23]	validation_0-rmse:1.48320	validation_1-rmse:1.83314
# [24]	validation_0-rmse:1.40432	validation_1-rmse:1.76480
# [25]	validation_0-rmse:1.33304	validation_1-rmse:1.69166
# [26]	validation_0-rmse:1.26713	validation_1-rmse:1.63154
# [27]	validation_0-rmse:1.20780	validation_1-rmse:1.56842
# [28]	validation_0-rmse:1.15315	validation_1-rmse:1.51672
# [29]	validation_0-rmse:1.10379	validation_1-rmse:1.46533
# [30]	validation_0-rmse:1.06121	validation_1-rmse:1.41886
# [31]	validation_0-rmse:1.02282	validation_1-rmse:1.37557
# [32]	validation_0-rmse:0.98824	validation_1-rmse:1.33558
# [33]	validation_0-rmse:0.95830	validation_1-rmse:1.30726
# [34]	validation_0-rmse:0.93047	validation_1-rmse:1.27553
# [35]	validation_0-rmse:0.90730	validation_1-rmse:1.24763
# [36]	validation_0-rmse:0.88552	validation_1-rmse:1.21818
# [37]	validation_0-rmse:0.86594	validation_1-rmse:1.19225
# [38]	validation_0-rmse:0.84804	validation_1-rmse:1.17025
# [39]	validation_0-rmse:0.83277	validation_1-rmse:1.15634
# [40]	validation_0-rmse:0.81839	validation_1-rmse:1.13764
# [41]	validation_0-rmse:0.80575	validation_1-rmse:1.12491
# [42]	validation_0-rmse:0.79402	validation_1-rmse:1.10810
# [43]	validation_0-rmse:0.78412	validation_1-rmse:1.09941
# [44]	validation_0-rmse:0.77487	validation_1-rmse:1.09048
# [45]	validation_0-rmse:0.76674	validation_1-rmse:1.07750
# [46]	validation_0-rmse:0.75778	validation_1-rmse:1.07289
# [47]	validation_0-rmse:0.74457	validation_1-rmse:1.06224
# [48]	validation_0-rmse:0.73341	validation_1-rmse:1.05488
# [49]	validation_0-rmse:0.72842	validation_1-rmse:1.04669
# [50]	validation_0-rmse:0.72383	validation_1-rmse:1.03851
# [51]	validation_0-rmse:0.71989	validation_1-rmse:1.03698
# [52]	validation_0-rmse:0.71411	validation_1-rmse:1.02887
# [53]	validation_0-rmse:0.71024	validation_1-rmse:1.02142
# [54]	validation_0-rmse:0.70726	validation_1-rmse:1.01930
# [55]	validation_0-rmse:0.70406	validation_1-rmse:1.01552
# [56]	validation_0-rmse:0.69612	validation_1-rmse:1.01182
# [57]	validation_0-rmse:0.69371	validation_1-rmse:1.01036
# [58]	validation_0-rmse:0.69018	validation_1-rmse:1.00702
# [59]	validation_0-rmse:0.68366	validation_1-rmse:1.00317
# [60]	validation_0-rmse:0.68191	validation_1-rmse:0.99889
# [61]	validation_0-rmse:0.67647	validation_1-rmse:0.99557
# [62]	validation_0-rmse:0.67470	validation_1-rmse:0.99692
# [63]	validation_0-rmse:0.67343	validation_1-rmse:0.99208
# [64]	validation_0-rmse:0.67248	validation_1-rmse:0.99055
# [65]	validation_0-rmse:0.67087	validation_1-rmse:0.98390
# [66]	validation_0-rmse:0.67005	validation_1-rmse:0.98255
# [67]	validation_0-rmse:0.66887	validation_1-rmse:0.98317
# [68]	validation_0-rmse:0.66825	validation_1-rmse:0.98232
# [69]	validation_0-rmse:0.66597	validation_1-rmse:0.98055
# [70]	validation_0-rmse:0.66133	validation_1-rmse:0.98083
# [71]	validation_0-rmse:0.65937	validation_1-rmse:0.98179
# [72]	validation_0-rmse:0.65538	validation_1-rmse:0.98203
# [73]	validation_0-rmse:0.65488	validation_1-rmse:0.98140
# [74]	validation_0-rmse:0.65479	validation_1-rmse:0.98031
# [75]	validation_0-rmse:0.65130	validation_1-rmse:0.98084
# [76]	validation_0-rmse:0.64920	validation_1-rmse:0.98209
# [77]	validation_0-rmse:0.64839	validation_1-rmse:0.98202
# [78]	validation_0-rmse:0.64666	validation_1-rmse:0.97637
# [79]	validation_0-rmse:0.64322	validation_1-rmse:0.97575
# [80]	validation_0-rmse:0.64321	validation_1-rmse:0.97541
# [81]	validation_0-rmse:0.64319	validation_1-rmse:0.97492
# [82]	validation_0-rmse:0.64181	validation_1-rmse:0.97754
# [83]	validation_0-rmse:0.64179	validation_1-rmse:0.97713
# [84]	validation_0-rmse:0.64177	validation_1-rmse:0.97660
# [85]	validation_0-rmse:0.64089	validation_1-rmse:0.97389
# [0]	validation_0-rmse:7.72099	validation_1-rmse:7.44206
# [1]	validation_0-rmse:7.13741	validation_1-rmse:6.89403
# [2]	validation_0-rmse:6.60334	validation_1-rmse:6.39069
# [3]	validation_0-rmse:6.10657	validation_1-rmse:5.89878
# [4]	validation_0-rmse:5.65104	validation_1-rmse:5.47180
# [5]	validation_0-rmse:5.23141	validation_1-rmse:5.05538
# [6]	validation_0-rmse:4.84427	validation_1-rmse:4.67171
# [7]	validation_0-rmse:4.49244	validation_1-rmse:4.34325
# [8]	validation_0-rmse:4.16550	validation_1-rmse:4.02052
# [9]	validation_0-rmse:3.86531	validation_1-rmse:3.74136
# [10]	validation_0-rmse:3.58567	validation_1-rmse:3.46661
# [11]	validation_0-rmse:3.32783	validation_1-rmse:3.21430
# [12]	validation_0-rmse:3.08981	validation_1-rmse:2.98442
# [13]	validation_0-rmse:2.87428	validation_1-rmse:2.79167
# [14]	validation_0-rmse:2.67419	validation_1-rmse:2.59838
# [15]	validation_0-rmse:2.49078	validation_1-rmse:2.42065
# [16]	validation_0-rmse:2.32207	validation_1-rmse:2.27630
# [17]	validation_0-rmse:2.16902	validation_1-rmse:2.12977
# [18]	validation_0-rmse:2.02940	validation_1-rmse:2.00026
# [19]	validation_0-rmse:1.89867	validation_1-rmse:1.88503
# [20]	validation_0-rmse:1.78080	validation_1-rmse:1.78923
# [21]	validation_0-rmse:1.67435	validation_1-rmse:1.68979
# [22]	validation_0-rmse:1.57571	validation_1-rmse:1.60495
# [23]	validation_0-rmse:1.48642	validation_1-rmse:1.52909
# [24]	validation_0-rmse:1.40413	validation_1-rmse:1.46088
# [25]	validation_0-rmse:1.32918	validation_1-rmse:1.39987
# [26]	validation_0-rmse:1.26068	validation_1-rmse:1.34383
# [27]	validation_0-rmse:1.19818	validation_1-rmse:1.29502
# [28]	validation_0-rmse:1.14349	validation_1-rmse:1.25338
# [29]	validation_0-rmse:1.09451	validation_1-rmse:1.21695
# [30]	validation_0-rmse:1.05197	validation_1-rmse:1.18060
# [31]	validation_0-rmse:1.01154	validation_1-rmse:1.15046
# [32]	validation_0-rmse:0.97498	validation_1-rmse:1.12554
# [33]	validation_0-rmse:0.94323	validation_1-rmse:1.10208
# [34]	validation_0-rmse:0.91377	validation_1-rmse:1.08357
# [35]	validation_0-rmse:0.88708	validation_1-rmse:1.06812
# [36]	validation_0-rmse:0.86390	validation_1-rmse:1.05535
# [37]	validation_0-rmse:0.84259	validation_1-rmse:1.03971
# [38]	validation_0-rmse:0.82447	validation_1-rmse:1.03079
# [39]	validation_0-rmse:0.80843	validation_1-rmse:1.02323
# [40]	validation_0-rmse:0.79362	validation_1-rmse:1.01278
# [41]	validation_0-rmse:0.78058	validation_1-rmse:1.00384
# [42]	validation_0-rmse:0.76806	validation_1-rmse:0.99468
# [43]	validation_0-rmse:0.75711	validation_1-rmse:0.98921
# [44]	validation_0-rmse:0.74530	validation_1-rmse:0.98454
# [45]	validation_0-rmse:0.73434	validation_1-rmse:0.98016
# [46]	validation_0-rmse:0.72728	validation_1-rmse:0.97573
# [47]	validation_0-rmse:0.72080	validation_1-rmse:0.97355
# [48]	validation_0-rmse:0.71494	validation_1-rmse:0.97176
# [49]	validation_0-rmse:0.70970	validation_1-rmse:0.96658
# [50]	validation_0-rmse:0.70502	validation_1-rmse:0.96531
# [51]	validation_0-rmse:0.70066	validation_1-rmse:0.96443
# [52]	validation_0-rmse:0.69676	validation_1-rmse:0.96370
# [53]	validation_0-rmse:0.69347	validation_1-rmse:0.96052
# [54]	validation_0-rmse:0.69055	validation_1-rmse:0.95797
# [55]	validation_0-rmse:0.68789	validation_1-rmse:0.95625
# [56]	validation_0-rmse:0.68284	validation_1-rmse:0.96010
# [57]	validation_0-rmse:0.67818	validation_1-rmse:0.95968
# [58]	validation_0-rmse:0.67600	validation_1-rmse:0.95777
# [59]	validation_0-rmse:0.67208	validation_1-rmse:0.95783
# [60]	validation_0-rmse:0.67017	validation_1-rmse:0.95591
# [61]	validation_0-rmse:0.66354	validation_1-rmse:0.94199
# [62]	validation_0-rmse:0.66236	validation_1-rmse:0.94158
# [63]	validation_0-rmse:0.66095	validation_1-rmse:0.94119
# [64]	validation_0-rmse:0.65870	validation_1-rmse:0.94149
# [65]	validation_0-rmse:0.65786	validation_1-rmse:0.94121
# [66]	validation_0-rmse:0.65602	validation_1-rmse:0.94170
# [67]	validation_0-rmse:0.65532	validation_1-rmse:0.94146
# [68]	validation_0-rmse:0.64987	validation_1-rmse:0.92927
# [69]	validation_0-rmse:0.64699	validation_1-rmse:0.93080
# [70]	validation_0-rmse:0.64680	validation_1-rmse:0.93059
# [71]	validation_0-rmse:0.64665	validation_1-rmse:0.93042
# [72]	validation_0-rmse:0.64652	validation_1-rmse:0.93026
# [73]	validation_0-rmse:0.64572	validation_1-rmse:0.93017
# [74]	validation_0-rmse:0.64112	validation_1-rmse:0.91952
# [75]	validation_0-rmse:0.63974	validation_1-rmse:0.92024
# [76]	validation_0-rmse:0.63576	validation_1-rmse:0.91075
# [77]	validation_0-rmse:0.63494	validation_1-rmse:0.91068
# [78]	validation_0-rmse:0.63377	validation_1-rmse:0.91146
# [79]	validation_0-rmse:0.63049	validation_1-rmse:0.90321
# [80]	validation_0-rmse:0.62991	validation_1-rmse:0.90317
# [81]	validation_0-rmse:0.62887	validation_1-rmse:0.90220
# [82]	validation_0-rmse:0.62574	validation_1-rmse:0.90263
# [83]	validation_0-rmse:0.62253	validation_1-rmse:0.89462
# [84]	validation_0-rmse:0.61891	validation_1-rmse:0.90092
# [85]	validation_0-rmse:0.61658	validation_1-rmse:0.90085
# [0]	validation_0-rmse:7.58029	validation_1-rmse:8.02121
# [1]	validation_0-rmse:7.00865	validation_1-rmse:7.44780
# [2]	validation_0-rmse:6.48320	validation_1-rmse:6.92078
# [3]	validation_0-rmse:5.99729	validation_1-rmse:6.43381
# [4]	validation_0-rmse:5.55005	validation_1-rmse:5.98585
# [5]	validation_0-rmse:5.13657	validation_1-rmse:5.57184
# [6]	validation_0-rmse:4.75845	validation_1-rmse:5.19357
# [7]	validation_0-rmse:4.41125	validation_1-rmse:4.83142
# [8]	validation_0-rmse:4.08801	validation_1-rmse:4.49646
# [9]	validation_0-rmse:3.79234	validation_1-rmse:4.20112
# [10]	validation_0-rmse:3.51956	validation_1-rmse:3.91509
# [11]	validation_0-rmse:3.26693	validation_1-rmse:3.65021
# [12]	validation_0-rmse:3.03804	validation_1-rmse:3.42750
# [13]	validation_0-rmse:2.82613	validation_1-rmse:3.20395
# [14]	validation_0-rmse:2.63145	validation_1-rmse:2.99831
# [15]	validation_0-rmse:2.45384	validation_1-rmse:2.82695
# [16]	validation_0-rmse:2.28770	validation_1-rmse:2.64718
# [17]	validation_0-rmse:2.13829	validation_1-rmse:2.48804
# [18]	validation_0-rmse:2.00182	validation_1-rmse:2.35870
# [19]	validation_0-rmse:1.87645	validation_1-rmse:2.22448
# [20]	validation_0-rmse:1.76062	validation_1-rmse:2.09883
# [21]	validation_0-rmse:1.65425	validation_1-rmse:1.98151
# [22]	validation_0-rmse:1.55785	validation_1-rmse:1.88273
# [23]	validation_0-rmse:1.46922	validation_1-rmse:1.79284
# [24]	validation_0-rmse:1.38915	validation_1-rmse:1.71109
# [25]	validation_0-rmse:1.31702	validation_1-rmse:1.63884
# [26]	validation_0-rmse:1.25171	validation_1-rmse:1.57228
# [27]	validation_0-rmse:1.19394	validation_1-rmse:1.50837
# [28]	validation_0-rmse:1.13862	validation_1-rmse:1.45793
# [29]	validation_0-rmse:1.09133	validation_1-rmse:1.40520
# [30]	validation_0-rmse:1.04802	validation_1-rmse:1.35598
# [31]	validation_0-rmse:1.00885	validation_1-rmse:1.31617
# [32]	validation_0-rmse:0.97571	validation_1-rmse:1.27892
# [33]	validation_0-rmse:0.94629	validation_1-rmse:1.25415
# [34]	validation_0-rmse:0.91862	validation_1-rmse:1.22332
# [35]	validation_0-rmse:0.89426	validation_1-rmse:1.19862
# [36]	validation_0-rmse:0.86676	validation_1-rmse:1.16764
# [37]	validation_0-rmse:0.84523	validation_1-rmse:1.14476
# [38]	validation_0-rmse:0.82900	validation_1-rmse:1.12255
# [39]	validation_0-rmse:0.81480	validation_1-rmse:1.10283
# [40]	validation_0-rmse:0.80203	validation_1-rmse:1.08369
# [41]	validation_0-rmse:0.79079	validation_1-rmse:1.06634
# [42]	validation_0-rmse:0.78105	validation_1-rmse:1.05078
# [43]	validation_0-rmse:0.77065	validation_1-rmse:1.04372
# [44]	validation_0-rmse:0.76323	validation_1-rmse:1.03192
# [45]	validation_0-rmse:0.75668	validation_1-rmse:1.02267
# [46]	validation_0-rmse:0.75082	validation_1-rmse:1.01614
# [47]	validation_0-rmse:0.74555	validation_1-rmse:1.00608
# [48]	validation_0-rmse:0.73611	validation_1-rmse:0.99553
# [49]	validation_0-rmse:0.73080	validation_1-rmse:0.98834
# [50]	validation_0-rmse:0.72666	validation_1-rmse:0.98271
# [51]	validation_0-rmse:0.72220	validation_1-rmse:0.98414
# [52]	validation_0-rmse:0.71499	validation_1-rmse:0.97387
# [53]	validation_0-rmse:0.71260	validation_1-rmse:0.96999
# [54]	validation_0-rmse:0.71022	validation_1-rmse:0.96330
# [55]	validation_0-rmse:0.70548	validation_1-rmse:0.95525
# [56]	validation_0-rmse:0.70343	validation_1-rmse:0.94933
# [57]	validation_0-rmse:0.70044	validation_1-rmse:0.95008
# [58]	validation_0-rmse:0.69887	validation_1-rmse:0.94928
# [59]	validation_0-rmse:0.69721	validation_1-rmse:0.94500
# [60]	validation_0-rmse:0.69345	validation_1-rmse:0.94538
# [61]	validation_0-rmse:0.69251	validation_1-rmse:0.94075
# [62]	validation_0-rmse:0.68848	validation_1-rmse:0.94222
# [63]	validation_0-rmse:0.68770	validation_1-rmse:0.93797
# [64]	validation_0-rmse:0.68357	validation_1-rmse:0.93522
# [65]	validation_0-rmse:0.67991	validation_1-rmse:0.93274
# [66]	validation_0-rmse:0.67923	validation_1-rmse:0.92880
# [67]	validation_0-rmse:0.67573	validation_1-rmse:0.93017
# [68]	validation_0-rmse:0.67511	validation_1-rmse:0.92645
# [69]	validation_0-rmse:0.67207	validation_1-rmse:0.92778
# [70]	validation_0-rmse:0.67154	validation_1-rmse:0.92435
# [71]	validation_0-rmse:0.66907	validation_1-rmse:0.92610
# [72]	validation_0-rmse:0.66705	validation_1-rmse:0.92649
# [73]	validation_0-rmse:0.66540	validation_1-rmse:0.92515
# [74]	validation_0-rmse:0.66239	validation_1-rmse:0.92243
# [75]	validation_0-rmse:0.66170	validation_1-rmse:0.92006
# [76]	validation_0-rmse:0.65915	validation_1-rmse:0.91763
# [77]	validation_0-rmse:0.65684	validation_1-rmse:0.91618
# [78]	validation_0-rmse:0.65488	validation_1-rmse:0.91748
# [79]	validation_0-rmse:0.65485	validation_1-rmse:0.91730
# [80]	validation_0-rmse:0.65340	validation_1-rmse:0.91625
# [81]	validation_0-rmse:0.65336	validation_1-rmse:0.91604
# [82]	validation_0-rmse:0.65336	validation_1-rmse:0.91599
# [83]	validation_0-rmse:0.65142	validation_1-rmse:0.91406
# [84]	validation_0-rmse:0.65142	validation_1-rmse:0.91410
# [85]	validation_0-rmse:0.65137	validation_1-rmse:0.91378
# [0]	validation_0-rmse:7.74695	validation_1-rmse:7.30911
# [1]	validation_0-rmse:7.16419	validation_1-rmse:6.74222
# [2]	validation_0-rmse:6.62651	validation_1-rmse:6.22006
# [3]	validation_0-rmse:6.13367	validation_1-rmse:5.75278
# [4]	validation_0-rmse:5.67650	validation_1-rmse:5.30953
# [5]	validation_0-rmse:5.25579	validation_1-rmse:4.91081
# [6]	validation_0-rmse:4.86605	validation_1-rmse:4.54213
# [7]	validation_0-rmse:4.51043	validation_1-rmse:4.19889
# [8]	validation_0-rmse:4.18021	validation_1-rmse:3.88529
# [9]	validation_0-rmse:3.87436	validation_1-rmse:3.59138
# [10]	validation_0-rmse:3.59428	validation_1-rmse:3.32723
# [11]	validation_0-rmse:3.33794	validation_1-rmse:3.08642
# [12]	validation_0-rmse:3.10228	validation_1-rmse:2.86571
# [13]	validation_0-rmse:2.88683	validation_1-rmse:2.66870
# [14]	validation_0-rmse:2.68508	validation_1-rmse:2.48601
# [15]	validation_0-rmse:2.49923	validation_1-rmse:2.31596
# [16]	validation_0-rmse:2.32909	validation_1-rmse:2.16437
# [17]	validation_0-rmse:2.17342	validation_1-rmse:2.02454
# [18]	validation_0-rmse:2.03064	validation_1-rmse:1.89996
# [19]	validation_0-rmse:1.89972	validation_1-rmse:1.78563
# [20]	validation_0-rmse:1.78048	validation_1-rmse:1.68984
# [21]	validation_0-rmse:1.67188	validation_1-rmse:1.60263
# [22]	validation_0-rmse:1.57335	validation_1-rmse:1.52077
# [23]	validation_0-rmse:1.48214	validation_1-rmse:1.44515
# [24]	validation_0-rmse:1.39899	validation_1-rmse:1.38339
# [25]	validation_0-rmse:1.32348	validation_1-rmse:1.32298
# [26]	validation_0-rmse:1.25684	validation_1-rmse:1.27305
# [27]	validation_0-rmse:1.19713	validation_1-rmse:1.22770
# [28]	validation_0-rmse:1.13897	validation_1-rmse:1.18952
# [29]	validation_0-rmse:1.09065	validation_1-rmse:1.15369
# [30]	validation_0-rmse:1.04666	validation_1-rmse:1.12231
# [31]	validation_0-rmse:1.00557	validation_1-rmse:1.09465
# [32]	validation_0-rmse:0.97030	validation_1-rmse:1.07080
# [33]	validation_0-rmse:0.93642	validation_1-rmse:1.05403
# [34]	validation_0-rmse:0.90763	validation_1-rmse:1.03449
# [35]	validation_0-rmse:0.88285	validation_1-rmse:1.01812
# [36]	validation_0-rmse:0.86013	validation_1-rmse:1.00585
# [37]	validation_0-rmse:0.84063	validation_1-rmse:0.99358
# [38]	validation_0-rmse:0.82237	validation_1-rmse:0.98475
# [39]	validation_0-rmse:0.80592	validation_1-rmse:0.97859
# [40]	validation_0-rmse:0.78266	validation_1-rmse:0.97603
# [41]	validation_0-rmse:0.76988	validation_1-rmse:0.97105
# [42]	validation_0-rmse:0.75878	validation_1-rmse:0.96769
# [43]	validation_0-rmse:0.74612	validation_1-rmse:0.96715
# [44]	validation_0-rmse:0.73049	validation_1-rmse:0.96887
# [45]	validation_0-rmse:0.72219	validation_1-rmse:0.96523
# [46]	validation_0-rmse:0.71514	validation_1-rmse:0.96432
# [47]	validation_0-rmse:0.70310	validation_1-rmse:0.96787
# [48]	validation_0-rmse:0.69731	validation_1-rmse:0.96474
# [49]	validation_0-rmse:0.69221	validation_1-rmse:0.96455
# [50]	validation_0-rmse:0.68285	validation_1-rmse:0.96902
# [51]	validation_0-rmse:0.67416	validation_1-rmse:0.97361
# [52]	validation_0-rmse:0.66667	validation_1-rmse:0.97747
# [53]	validation_0-rmse:0.66368	validation_1-rmse:0.97665
# [54]	validation_0-rmse:0.66130	validation_1-rmse:0.97561
# [55]	validation_0-rmse:0.65922	validation_1-rmse:0.97477
# [0]	validation_0-rmse:7.62426	validation_1-rmse:7.84505
# [1]	validation_0-rmse:7.04960	validation_1-rmse:7.28630
# [2]	validation_0-rmse:6.52003	validation_1-rmse:6.77169
# [3]	validation_0-rmse:6.04339	validation_1-rmse:6.29994
# [4]	validation_0-rmse:5.59275	validation_1-rmse:5.86346
# [5]	validation_0-rmse:5.17448	validation_1-rmse:5.45871
# [6]	validation_0-rmse:4.79395	validation_1-rmse:5.09079
# [7]	validation_0-rmse:4.43881	validation_1-rmse:4.74744
# [8]	validation_0-rmse:4.11430	validation_1-rmse:4.41708
# [9]	validation_0-rmse:3.81603	validation_1-rmse:4.11136
# [10]	validation_0-rmse:3.54228	validation_1-rmse:3.83386
# [11]	validation_0-rmse:3.29139	validation_1-rmse:3.59177
# [12]	validation_0-rmse:3.05992	validation_1-rmse:3.34685
# [13]	validation_0-rmse:2.84654	validation_1-rmse:3.12680
# [14]	validation_0-rmse:2.65103	validation_1-rmse:2.94059
# [15]	validation_0-rmse:2.47300	validation_1-rmse:2.75012
# [16]	validation_0-rmse:2.30778	validation_1-rmse:2.57351
# [17]	validation_0-rmse:2.15848	validation_1-rmse:2.41293
# [18]	validation_0-rmse:2.01864	validation_1-rmse:2.28140
# [19]	validation_0-rmse:1.89463	validation_1-rmse:2.16465
# [20]	validation_0-rmse:1.78035	validation_1-rmse:2.03992
# [21]	validation_0-rmse:1.67546	validation_1-rmse:1.92786
# [22]	validation_0-rmse:1.58122	validation_1-rmse:1.82477
# [23]	validation_0-rmse:1.49273	validation_1-rmse:1.72982
# [24]	validation_0-rmse:1.41688	validation_1-rmse:1.64305
# [25]	validation_0-rmse:1.34499	validation_1-rmse:1.56599
# [26]	validation_0-rmse:1.28040	validation_1-rmse:1.49298
# [27]	validation_0-rmse:1.22293	validation_1-rmse:1.42804
# [28]	validation_0-rmse:1.17065	validation_1-rmse:1.36777
# [29]	validation_0-rmse:1.12435	validation_1-rmse:1.31704
# [30]	validation_0-rmse:1.08163	validation_1-rmse:1.26391
# [31]	validation_0-rmse:1.04390	validation_1-rmse:1.21887
# [32]	validation_0-rmse:1.01067	validation_1-rmse:1.17863
# [33]	validation_0-rmse:0.98095	validation_1-rmse:1.14122
# [34]	validation_0-rmse:0.95346	validation_1-rmse:1.10788
# [35]	validation_0-rmse:0.92808	validation_1-rmse:1.08202
# [36]	validation_0-rmse:0.90597	validation_1-rmse:1.05677
# [37]	validation_0-rmse:0.88588	validation_1-rmse:1.03220
# [38]	validation_0-rmse:0.86908	validation_1-rmse:1.01230
# [39]	validation_0-rmse:0.85392	validation_1-rmse:0.99422
# [40]	validation_0-rmse:0.84032	validation_1-rmse:0.97902
# [41]	validation_0-rmse:0.82827	validation_1-rmse:0.96517
# [42]	validation_0-rmse:0.81733	validation_1-rmse:0.95262
# [43]	validation_0-rmse:0.80751	validation_1-rmse:0.93926
# [44]	validation_0-rmse:0.79928	validation_1-rmse:0.93003
# [45]	validation_0-rmse:0.79109	validation_1-rmse:0.92074
# [46]	validation_0-rmse:0.78440	validation_1-rmse:0.91351
# [47]	validation_0-rmse:0.77636	validation_1-rmse:0.90792
# [48]	validation_0-rmse:0.77038	validation_1-rmse:0.90127
# [49]	validation_0-rmse:0.76536	validation_1-rmse:0.89632
# [50]	validation_0-rmse:0.76071	validation_1-rmse:0.89179
# [51]	validation_0-rmse:0.75645	validation_1-rmse:0.88636
# ...
# [0]	validation_0-rmse:7.58763	validation_1-rmse:7.96371
# [1]	validation_0-rmse:7.02119	validation_1-rmse:7.39610
# [2]	validation_0-rmse:6.49538	validation_1-rmse:6.87374
# [3]	validation_0-rmse:6.01283	validation_1-rmse:6.39454
# [4]	validation_0-rmse:5.56578	validation_1-rmse:5.91950
# [5]	validation_0-rmse:5.15160	validation_1-rmse:5.47781
# [6]	validation_0-rmse:4.77135	validation_1-rmse:5.09996
# [7]	validation_0-rmse:4.42011	validation_1-rmse:4.74899
# [8]	validation_0-rmse:4.09716	validation_1-rmse:4.42797
# [9]	validation_0-rmse:3.79893	validation_1-rmse:4.12458
# [10]	validation_0-rmse:3.52666	validation_1-rmse:3.82983
# [11]	validation_0-rmse:3.27652	validation_1-rmse:3.57460
# [12]	validation_0-rmse:3.04551	validation_1-rmse:3.33880
# [13]	validation_0-rmse:2.83621	validation_1-rmse:3.12504
# [14]	validation_0-rmse:2.64125	validation_1-rmse:2.90921
# [15]	validation_0-rmse:2.46293	validation_1-rmse:2.72494
# [16]	validation_0-rmse:2.29822	validation_1-rmse:2.54044
# [17]	validation_0-rmse:2.15010	validation_1-rmse:2.38653
# [18]	validation_0-rmse:2.01657	validation_1-rmse:2.24431
# [19]	validation_0-rmse:1.89178	validation_1-rmse:2.11278
# [20]	validation_0-rmse:1.77743	validation_1-rmse:1.99727
# [21]	validation_0-rmse:1.67583	validation_1-rmse:1.89426
# [22]	validation_0-rmse:1.57887	validation_1-rmse:1.79908
# [23]	validation_0-rmse:1.49477	validation_1-rmse:1.71712
# [24]	validation_0-rmse:1.41416	validation_1-rmse:1.62838
# [25]	validation_0-rmse:1.34150	validation_1-rmse:1.54757
# [26]	validation_0-rmse:1.27458	validation_1-rmse:1.47110
# [27]	validation_0-rmse:1.21655	validation_1-rmse:1.40532
# [28]	validation_0-rmse:1.16163	validation_1-rmse:1.35032
# [29]	validation_0-rmse:1.11705	validation_1-rmse:1.29862
# [30]	validation_0-rmse:1.07436	validation_1-rmse:1.24371
# [31]	validation_0-rmse:1.03561	validation_1-rmse:1.20217
# [32]	validation_0-rmse:1.00251	validation_1-rmse:1.16315
# [33]	validation_0-rmse:0.97081	validation_1-rmse:1.13148
# [34]	validation_0-rmse:0.94340	validation_1-rmse:1.10699
# [35]	validation_0-rmse:0.91871	validation_1-rmse:1.07738
# [36]	validation_0-rmse:0.89747	validation_1-rmse:1.05089
# [37]	validation_0-rmse:0.87838	validation_1-rmse:1.02615
# [38]	validation_0-rmse:0.86091	validation_1-rmse:1.01010
# [39]	validation_0-rmse:0.84595	validation_1-rmse:0.99661
# [40]	validation_0-rmse:0.83280	validation_1-rmse:0.98513
# [41]	validation_0-rmse:0.82087	validation_1-rmse:0.96785
# [42]	validation_0-rmse:0.81048	validation_1-rmse:0.95863
# [43]	validation_0-rmse:0.80107	validation_1-rmse:0.94535
# [44]	validation_0-rmse:0.79256	validation_1-rmse:0.93816
# [45]	validation_0-rmse:0.78532	validation_1-rmse:0.93209
# [46]	validation_0-rmse:0.77575	validation_1-rmse:0.91138
# [47]	validation_0-rmse:0.76968	validation_1-rmse:0.90557
# [48]	validation_0-rmse:0.75743	validation_1-rmse:0.88948
# [49]	validation_0-rmse:0.75255	validation_1-rmse:0.88085
# [50]	validation_0-rmse:0.74810	validation_1-rmse:0.87771
# [51]	validation_0-rmse:0.74420	validation_1-rmse:0.87440
# [52]	validation_0-rmse:0.74031	validation_1-rmse:0.87045
# [53]	validation_0-rmse:0.73707	validation_1-rmse:0.86724
# [54]	validation_0-rmse:0.73421	validation_1-rmse:0.86119
# [55]	validation_0-rmse:0.72462	validation_1-rmse:0.84946
# [56]	validation_0-rmse:0.71616	validation_1-rmse:0.83849
# [57]	validation_0-rmse:0.71393	validation_1-rmse:0.83672
# [58]	validation_0-rmse:0.70924	validation_1-rmse:0.82601
# [59]	validation_0-rmse:0.70756	validation_1-rmse:0.82205
# [60]	validation_0-rmse:0.70573	validation_1-rmse:0.82151
# [61]	validation_0-rmse:0.70404	validation_1-rmse:0.81852
# [62]	validation_0-rmse:0.70240	validation_1-rmse:0.81845
# [63]	validation_0-rmse:0.70098	validation_1-rmse:0.81785
# [64]	validation_0-rmse:0.69462	validation_1-rmse:0.81085
# [65]	validation_0-rmse:0.69344	validation_1-rmse:0.81124
# [66]	validation_0-rmse:0.69229	validation_1-rmse:0.81063
# [67]	validation_0-rmse:0.69128	validation_1-rmse:0.81094
# [68]	validation_0-rmse:0.68539	validation_1-rmse:0.80403
# [69]	validation_0-rmse:0.68390	validation_1-rmse:0.79986
# [70]	validation_0-rmse:0.68081	validation_1-rmse:0.79256
# [71]	validation_0-rmse:0.67740	validation_1-rmse:0.78781
# [72]	validation_0-rmse:0.67519	validation_1-rmse:0.78348
# [73]	validation_0-rmse:0.67471	validation_1-rmse:0.78306
# [74]	validation_0-rmse:0.67073	validation_1-rmse:0.77900
# [75]	validation_0-rmse:0.67064	validation_1-rmse:0.77814
# [76]	validation_0-rmse:0.66825	validation_1-rmse:0.77141
# [77]	validation_0-rmse:0.66482	validation_1-rmse:0.76784
# [78]	validation_0-rmse:0.66401	validation_1-rmse:0.76706
# [79]	validation_0-rmse:0.66355	validation_1-rmse:0.76775
# [80]	validation_0-rmse:0.66278	validation_1-rmse:0.76638
# [81]	validation_0-rmse:0.66275	validation_1-rmse:0.76598
# [82]	validation_0-rmse:0.66167	validation_1-rmse:0.77212
# [83]	validation_0-rmse:0.65783	validation_1-rmse:0.77145
# [84]	validation_0-rmse:0.65417	validation_1-rmse:0.76867
# [85]	validation_0-rmse:0.65200	validation_1-rmse:0.76246
# [0]	validation_0-rmse:7.75473	validation_1-rmse:7.25204
# [1]	validation_0-rmse:7.17275	validation_1-rmse:6.66858
# [2]	validation_0-rmse:6.63512	validation_1-rmse:6.12978
# [3]	validation_0-rmse:6.13761	validation_1-rmse:5.63145
# [4]	validation_0-rmse:5.67986	validation_1-rmse:5.17504
# [5]	validation_0-rmse:5.26113	validation_1-rmse:4.75616
# [6]	validation_0-rmse:4.87284	validation_1-rmse:4.36960
# [7]	validation_0-rmse:4.51492	validation_1-rmse:4.01368
# [8]	validation_0-rmse:4.18567	validation_1-rmse:3.68545
# [9]	validation_0-rmse:3.88023	validation_1-rmse:3.38267
# [10]	validation_0-rmse:3.59988	validation_1-rmse:3.10683
# [11]	validation_0-rmse:3.34331	validation_1-rmse:2.85274
# [12]	validation_0-rmse:3.10659	validation_1-rmse:2.62016
# [13]	validation_0-rmse:2.88709	validation_1-rmse:2.40551
# [14]	validation_0-rmse:2.68910	validation_1-rmse:2.21247
# [15]	validation_0-rmse:2.50504	validation_1-rmse:2.03372
# [16]	validation_0-rmse:2.33916	validation_1-rmse:1.87662
# [17]	validation_0-rmse:2.18420	validation_1-rmse:1.72715
# [18]	validation_0-rmse:2.04147	validation_1-rmse:1.59355
# [19]	validation_0-rmse:1.91131	validation_1-rmse:1.47109
# [20]	validation_0-rmse:1.79307	validation_1-rmse:1.36636
# [21]	validation_0-rmse:1.68517	validation_1-rmse:1.27198
# [22]	validation_0-rmse:1.58630	validation_1-rmse:1.19050
# [23]	validation_0-rmse:1.49642	validation_1-rmse:1.11514
# [24]	validation_0-rmse:1.41593	validation_1-rmse:1.05944
# [25]	validation_0-rmse:1.34098	validation_1-rmse:1.00753
# [26]	validation_0-rmse:1.27342	validation_1-rmse:0.96751
# [27]	validation_0-rmse:1.21362	validation_1-rmse:0.92472
# [28]	validation_0-rmse:1.15814	validation_1-rmse:0.89925
# [29]	validation_0-rmse:1.10819	validation_1-rmse:0.87034
# [30]	validation_0-rmse:1.06361	validation_1-rmse:0.85490
# [31]	validation_0-rmse:1.02465	validation_1-rmse:0.84054
# [32]	validation_0-rmse:0.98843	validation_1-rmse:0.83738
# [33]	validation_0-rmse:0.95651	validation_1-rmse:0.83728
# [34]	validation_0-rmse:0.92814	validation_1-rmse:0.83436
# [35]	validation_0-rmse:0.90300	validation_1-rmse:0.83711
# [36]	validation_0-rmse:0.87972	validation_1-rmse:0.83819
# [37]	validation_0-rmse:0.85866	validation_1-rmse:0.84438
# [38]	validation_0-rmse:0.84163	validation_1-rmse:0.84062
# [39]	validation_0-rmse:0.82593	validation_1-rmse:0.84357
# [40]	validation_0-rmse:0.81094	validation_1-rmse:0.84719
# [41]	validation_0-rmse:0.79712	validation_1-rmse:0.84598
# [42]	validation_0-rmse:0.78576	validation_1-rmse:0.84660
# [43]	validation_0-rmse:0.77488	validation_1-rmse:0.85509
# [44]	validation_0-rmse:0.76474	validation_1-rmse:0.85958
# [0]	validation_0-rmse:7.60925	validation_1-rmse:7.91211
# [1]	validation_0-rmse:7.03479	validation_1-rmse:7.32447
# [2]	validation_0-rmse:6.50691	validation_1-rmse:6.78414
# [3]	validation_0-rmse:6.02469	validation_1-rmse:6.28996
# [4]	validation_0-rmse:5.57723	validation_1-rmse:5.83152
# [5]	validation_0-rmse:5.16633	validation_1-rmse:5.41295
# [6]	validation_0-rmse:4.78700	validation_1-rmse:5.02178
# [7]	validation_0-rmse:4.43837	validation_1-rmse:4.66285
# [8]	validation_0-rmse:4.11554	validation_1-rmse:4.32859
# [9]	validation_0-rmse:3.81828	validation_1-rmse:4.01324
# [10]	validation_0-rmse:3.54511	validation_1-rmse:3.73016
# [11]	validation_0-rmse:3.29188	validation_1-rmse:3.45972
# [12]	validation_0-rmse:3.06119	validation_1-rmse:3.21999
# [13]	validation_0-rmse:2.85069	validation_1-rmse:2.99950
# [14]	validation_0-rmse:2.65716	validation_1-rmse:2.78955
# [15]	validation_0-rmse:2.47678	validation_1-rmse:2.59392
# [16]	validation_0-rmse:2.31419	validation_1-rmse:2.41399
# [17]	validation_0-rmse:2.16355	validation_1-rmse:2.25172
# [18]	validation_0-rmse:2.02884	validation_1-rmse:2.09860
# [19]	validation_0-rmse:1.90445	validation_1-rmse:1.95654
# [20]	validation_0-rmse:1.79053	validation_1-rmse:1.82956
# [21]	validation_0-rmse:1.68696	validation_1-rmse:1.72260
# [22]	validation_0-rmse:1.58993	validation_1-rmse:1.62232
# [23]	validation_0-rmse:1.50366	validation_1-rmse:1.53293
# [24]	validation_0-rmse:1.42580	validation_1-rmse:1.45259
# [25]	validation_0-rmse:1.35194	validation_1-rmse:1.37615
# [26]	validation_0-rmse:1.28792	validation_1-rmse:1.31014
# [27]	validation_0-rmse:1.23092	validation_1-rmse:1.25111
# [28]	validation_0-rmse:1.17888	validation_1-rmse:1.19957
# [29]	validation_0-rmse:1.13336	validation_1-rmse:1.14470
# [30]	validation_0-rmse:1.09053	validation_1-rmse:1.09180
# [31]	validation_0-rmse:1.05362	validation_1-rmse:1.05429
# [32]	validation_0-rmse:1.01966	validation_1-rmse:1.01971
# [33]	validation_0-rmse:0.99003	validation_1-rmse:0.98952
# [34]	validation_0-rmse:0.96327	validation_1-rmse:0.95945
# [35]	validation_0-rmse:0.93774	validation_1-rmse:0.93507
# [36]	validation_0-rmse:0.91646	validation_1-rmse:0.91506
# [37]	validation_0-rmse:0.89409	validation_1-rmse:0.89301
# [38]	validation_0-rmse:0.87677	validation_1-rmse:0.87640
# [39]	validation_0-rmse:0.86124	validation_1-rmse:0.86125
# [40]	validation_0-rmse:0.84715	validation_1-rmse:0.85036
# [41]	validation_0-rmse:0.83448	validation_1-rmse:0.83791
# [42]	validation_0-rmse:0.82089	validation_1-rmse:0.82307
# [43]	validation_0-rmse:0.81182	validation_1-rmse:0.81354
# [44]	validation_0-rmse:0.80272	validation_1-rmse:0.80721
# [45]	validation_0-rmse:0.79365	validation_1-rmse:0.79813
# [46]	validation_0-rmse:0.78666	validation_1-rmse:0.79245
# [47]	validation_0-rmse:0.78092	validation_1-rmse:0.78825
# [48]	validation_0-rmse:0.77533	validation_1-rmse:0.78056
# [49]	validation_0-rmse:0.77033	validation_1-rmse:0.77586
# [50]	validation_0-rmse:0.75878	validation_1-rmse:0.76284
# [51]	validation_0-rmse:0.74841	validation_1-rmse:0.75188
# [52]	validation_0-rmse:0.74354	validation_1-rmse:0.74825
# [53]	validation_0-rmse:0.73527	validation_1-rmse:0.73893
# [54]	validation_0-rmse:0.72798	validation_1-rmse:0.73063
# [55]	validation_0-rmse:0.72175	validation_1-rmse:0.72232
# [56]	validation_0-rmse:0.71895	validation_1-rmse:0.71908
# [57]	validation_0-rmse:0.71657	validation_1-rmse:0.71628
# [58]	validation_0-rmse:0.71354	validation_1-rmse:0.71611
# [59]	validation_0-rmse:0.71139	validation_1-rmse:0.71475
# [60]	validation_0-rmse:0.70957	validation_1-rmse:0.71395
# [61]	validation_0-rmse:0.70804	validation_1-rmse:0.71373
# [62]	validation_0-rmse:0.70654	validation_1-rmse:0.71309
# [63]	validation_0-rmse:0.70185	validation_1-rmse:0.70576
# [64]	validation_0-rmse:0.70058	validation_1-rmse:0.70522
# [65]	validation_0-rmse:0.69943	validation_1-rmse:0.70464
# [66]	validation_0-rmse:0.69539	validation_1-rmse:0.69822
# [67]	validation_0-rmse:0.69382	validation_1-rmse:0.69563
# [68]	validation_0-rmse:0.69289	validation_1-rmse:0.69534
# [69]	validation_0-rmse:0.69203	validation_1-rmse:0.69526
# [70]	validation_0-rmse:0.69187	validation_1-rmse:0.69462
# [71]	validation_0-rmse:0.68619	validation_1-rmse:0.69091
# [72]	validation_0-rmse:0.68404	validation_1-rmse:0.69216
# [73]	validation_0-rmse:0.68138	validation_1-rmse:0.68861
# [74]	validation_0-rmse:0.68060	validation_1-rmse:0.68836
# [75]	validation_0-rmse:0.67984	validation_1-rmse:0.68749
# [76]	validation_0-rmse:0.67618	validation_1-rmse:0.68708
# [77]	validation_0-rmse:0.67615	validation_1-rmse:0.68683
# [78]	validation_0-rmse:0.67392	validation_1-rmse:0.68894
# [79]	validation_0-rmse:0.67390	validation_1-rmse:0.68879
# [80]	validation_0-rmse:0.67386	validation_1-rmse:0.68837
# [81]	validation_0-rmse:0.67384	validation_1-rmse:0.68820
# [82]	validation_0-rmse:0.67105	validation_1-rmse:0.68314
# [83]	validation_0-rmse:0.67005	validation_1-rmse:0.68115
# [84]	validation_0-rmse:0.66814	validation_1-rmse:0.67854
# [85]	validation_0-rmse:0.66750	validation_1-rmse:0.67860
# [0]	validation_0-rmse:7.61960	validation_1-rmse:7.84735
# [1]	validation_0-rmse:7.04774	validation_1-rmse:7.26175
# [2]	validation_0-rmse:6.52074	validation_1-rmse:6.72191
# [3]	validation_0-rmse:6.03537	validation_1-rmse:6.22150
# [4]	validation_0-rmse:5.58687	validation_1-rmse:5.76482
# [5]	validation_0-rmse:5.17451	validation_1-rmse:5.34496
# [6]	validation_0-rmse:4.79420	validation_1-rmse:4.95730
# [7]	validation_0-rmse:4.44419	validation_1-rmse:4.59559
# [8]	validation_0-rmse:4.12119	validation_1-rmse:4.26559
# [9]	validation_0-rmse:3.82170	validation_1-rmse:3.95968
# [10]	validation_0-rmse:3.54833	validation_1-rmse:3.67530
# [11]	validation_0-rmse:3.29584	validation_1-rmse:3.41627
# [12]	validation_0-rmse:3.06249	validation_1-rmse:3.17659
# [13]	validation_0-rmse:2.85527	validation_1-rmse:2.95706
# [14]	validation_0-rmse:2.66042	validation_1-rmse:2.75561
# [15]	validation_0-rmse:2.48514	validation_1-rmse:2.56955
# [16]	validation_0-rmse:2.32005	validation_1-rmse:2.39776
# [17]	validation_0-rmse:2.17135	validation_1-rmse:2.24252
# [18]	validation_0-rmse:2.03676	validation_1-rmse:2.09675
# [19]	validation_0-rmse:1.91161	validation_1-rmse:1.96192
# [20]	validation_0-rmse:1.79852	validation_1-rmse:1.84100
# [21]	validation_0-rmse:1.69284	validation_1-rmse:1.72281
# [22]	validation_0-rmse:1.59733	validation_1-rmse:1.61623
# [23]	validation_0-rmse:1.51086	validation_1-rmse:1.51848
# [24]	validation_0-rmse:1.43433	validation_1-rmse:1.43324
# [25]	validation_0-rmse:1.36403	validation_1-rmse:1.35263
# [26]	validation_0-rmse:1.30071	validation_1-rmse:1.28330
# [27]	validation_0-rmse:1.24565	validation_1-rmse:1.21960
# [28]	validation_0-rmse:1.19418	validation_1-rmse:1.15809
# [29]	validation_0-rmse:1.14674	validation_1-rmse:1.10925
# [30]	validation_0-rmse:1.10479	validation_1-rmse:1.06840
# [31]	validation_0-rmse:1.06560	validation_1-rmse:1.02664
# [32]	validation_0-rmse:1.03200	validation_1-rmse:0.98482
# [33]	validation_0-rmse:1.00225	validation_1-rmse:0.96272
# [34]	validation_0-rmse:0.97418	validation_1-rmse:0.93323
# [35]	validation_0-rmse:0.94931	validation_1-rmse:0.91265
# [36]	validation_0-rmse:0.92731	validation_1-rmse:0.89049
# [37]	validation_0-rmse:0.90787	validation_1-rmse:0.87773
# [38]	validation_0-rmse:0.88951	validation_1-rmse:0.86021
# [39]	validation_0-rmse:0.87342	validation_1-rmse:0.84890
# [40]	validation_0-rmse:0.85845	validation_1-rmse:0.83371
# [41]	validation_0-rmse:0.84546	validation_1-rmse:0.82633
# [42]	validation_0-rmse:0.83316	validation_1-rmse:0.81507
# [43]	validation_0-rmse:0.82269	validation_1-rmse:0.81049
# [44]	validation_0-rmse:0.81315	validation_1-rmse:0.80620
# [45]	validation_0-rmse:0.80472	validation_1-rmse:0.79706
# [46]	validation_0-rmse:0.79743	validation_1-rmse:0.78887
# [47]	validation_0-rmse:0.79014	validation_1-rmse:0.79026
# [48]	validation_0-rmse:0.78352	validation_1-rmse:0.78967
# [49]	validation_0-rmse:0.77046	validation_1-rmse:0.78326
# [50]	validation_0-rmse:0.75953	validation_1-rmse:0.77869
# [51]	validation_0-rmse:0.75482	validation_1-rmse:0.77612
# [52]	validation_0-rmse:0.74801	validation_1-rmse:0.77279
# [53]	validation_0-rmse:0.73923	validation_1-rmse:0.76984
# [54]	validation_0-rmse:0.73560	validation_1-rmse:0.76684
# [55]	validation_0-rmse:0.73210	validation_1-rmse:0.77032
# [56]	validation_0-rmse:0.72900	validation_1-rmse:0.76906
# [57]	validation_0-rmse:0.72610	validation_1-rmse:0.77280
# [58]	validation_0-rmse:0.72083	validation_1-rmse:0.77189
# [59]	validation_0-rmse:0.71346	validation_1-rmse:0.77022
# [60]	validation_0-rmse:0.71112	validation_1-rmse:0.76964
# [61]	validation_0-rmse:0.70902	validation_1-rmse:0.76913
# [62]	validation_0-rmse:0.70717	validation_1-rmse:0.76771
# [63]	validation_0-rmse:0.70508	validation_1-rmse:0.76723

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 71.54, median: 74.0,
#  pred. interval (P(0.025)-P(0.975)): 42.725-85.0,
#  conf. interval (p-value=0.95): 66.581-78.801
# ***
# Aggregate bias statistic:
#  mean: -2.176, median: -2.14,
#  pred. interval (P(0.025)-P(0.975)): -9.122-4.043,
#  conf. interval (p-value=0.95): -3.648--0.65
# ***
# Aggregate RMSE statistic:
#  mean: 0.824, median: 0.828, pred. interval (P(0.025)-P(0.975)): 0.583-1.069,
#  conf. interval (p-value=0.95): 0.771-0.882
# ***
# Aggregate MSE statistic:
#  mean: 0.695, median: 0.685, pred. interval (P(0.025)-P(0.975)): 0.339-1.143,
#  conf. interval (p-value=0.95): 0.599-0.782
# ***
# Aggregate R^2 statistic:
#  mean: 0.654, median: 0.674, pred. interval (P(0.025)-P(0.975)): 0.313-0.847,
#  conf. interval (p-value=0.95): 0.611-0.719
# ***
# Aggregate bias(%) statistic:
#  mean: -0.243, median: -2.14, pred. interval (P(0.025)-P(0.975)): -1.03-0.471,
#  conf. interval (p-value=0.95): -0.411--0.074
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.095, median: 0.095, pred. interval (P(0.025)-P(0.975)): 0.066-0.12,
#  conf. interval (p-value=0.95): 0.089-0.102
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=10, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:7.66272
# [1]	validation_0-rmse:7.08396
# [2]	validation_0-rmse:6.54740
# [3]	validation_0-rmse:6.05621
# [4]	validation_0-rmse:5.60590
# [5]	validation_0-rmse:5.18736
# [6]	validation_0-rmse:4.80405
# [7]	validation_0-rmse:4.45163
# [8]	validation_0-rmse:4.12387
# [9]	validation_0-rmse:3.82343
# [10]	validation_0-rmse:3.54951
# [11]	validation_0-rmse:3.29515
# [12]	validation_0-rmse:3.06352
# [13]	validation_0-rmse:2.84896
# [14]	validation_0-rmse:2.65352
# [15]	validation_0-rmse:2.47167
# [16]	validation_0-rmse:2.30616
# [17]	validation_0-rmse:2.15226
# [18]	validation_0-rmse:2.01235
# [19]	validation_0-rmse:1.88342
# [20]	validation_0-rmse:1.76808
# [21]	validation_0-rmse:1.66194
# [22]	validation_0-rmse:1.56275
# [23]	validation_0-rmse:1.47487
# [24]	validation_0-rmse:1.39690
# [25]	validation_0-rmse:1.32558
# [26]	validation_0-rmse:1.26071
# [27]	validation_0-rmse:1.20264
# [28]	validation_0-rmse:1.15104
# [29]	validation_0-rmse:1.10447
# [30]	validation_0-rmse:1.06373
# [31]	validation_0-rmse:1.02526
# [32]	validation_0-rmse:0.99163
# [33]	validation_0-rmse:0.96113
# [34]	validation_0-rmse:0.93423
# [35]	validation_0-rmse:0.91148
# [36]	validation_0-rmse:0.89124
# [37]	validation_0-rmse:0.87273
# [38]	validation_0-rmse:0.85642
# [39]	validation_0-rmse:0.84145
# [40]	validation_0-rmse:0.82847
# [41]	validation_0-rmse:0.81705
# [42]	validation_0-rmse:0.80608
# [43]	validation_0-rmse:0.79783
# [44]	validation_0-rmse:0.78905
# [45]	validation_0-rmse:0.78138
# [46]	validation_0-rmse:0.76716
# [47]	validation_0-rmse:0.75539
# [48]	validation_0-rmse:0.74852
# [49]	validation_0-rmse:0.73787
# [50]	validation_0-rmse:0.73360
# [51]	validation_0-rmse:0.72963
# [52]	validation_0-rmse:0.72562
# [53]	validation_0-rmse:0.72258
# [54]	validation_0-rmse:0.71460
# [55]	validation_0-rmse:0.71206
# [56]	validation_0-rmse:0.70815
# [57]	validation_0-rmse:0.70113
# [58]	validation_0-rmse:0.69893
# [59]	validation_0-rmse:0.69712
# [60]	validation_0-rmse:0.69134
# [61]	validation_0-rmse:0.68842
# [62]	validation_0-rmse:0.68375
# [63]	validation_0-rmse:0.68232
# [64]	validation_0-rmse:0.67806
# [65]	validation_0-rmse:0.67473
# [66]	validation_0-rmse:0.67183
# [67]	validation_0-rmse:0.67075
# [68]	validation_0-rmse:0.66967
# [69]	validation_0-rmse:0.66871
# [70]	validation_0-rmse:0.66689
# [71]	validation_0-rmse:0.66498
# [72]	validation_0-rmse:0.66328
# [73]	validation_0-rmse:0.66240
# [74]	validation_0-rmse:0.66205
# [75]	validation_0-rmse:0.66195
# [76]	validation_0-rmse:0.66131
# [77]	validation_0-rmse:0.66070
# [78]	validation_0-rmse:0.66002
# [79]	validation_0-rmse:0.65998
# [80]	validation_0-rmse:0.65997
# [81]	validation_0-rmse:0.65739
# [82]	validation_0-rmse:0.65581
# [83]	validation_0-rmse:0.65535
# [84]	validation_0-rmse:0.65453
# [85]	validation_0-rmse:0.65453

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 85

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.10
# RMSE: 0.7
# Relative RMSE(%):  0.076
# MSE: 0.4
# R square: 80.0%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(6, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 2.143
# a1: 0.751
# R^2: 0.804
# Uncertainty
# a0: 2.14+/-0.32
# a1: 0.75+/-0.04

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("./../03_output_data/XGBoost_models/UAV_ln_Sr_XGB_model_only_D_Sr_2024.json")
# Save to text format
f_xgb_model.save_model("./../03_output_data/XGBoost_models/UAV_ln_Sr_XGB_model_only_D_Sr_2024.txt")
