# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Sr_wood', 'Sr_2021_kBq_m', 'AEDR_mean',
                                    'mf_chm_MIN', 'mf_chm_MEAN', 'r_MIN', 'contr_b_MAX', 'contr_b_STD'])

# Show the first five columns
select.head()
# Out:
#    ln_Sr_wood  Sr_2021_kBq_m  AEDR_mean  mf_chm_MIN  mf_chm_MEAN  r_MIN  \
# 0       9.240           1210       2.33    0.445070    12.233545     13
# 1       9.622           1180       2.47   12.465903    14.964220     24
# 2       9.589           1400       2.44   13.028298    15.329449     18
# 3       9.449           1090       2.55    2.128231    15.392742     15
# 4       9.401            720       2.14   12.171553    17.944009      8
#
#    contr_b_MAX  contr_b_STD
# 0  2713.600586   332.963753
# 1  1793.493042   293.868420
# 2  1761.097900   272.526176
# 3  2518.435303   299.595643
# 4  2525.819336   327.599176

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Sr_wood     103 non-null    float64
#  1   Sr_2021_kBq_m  103 non-null    int64
#  2   AEDR_mean      103 non-null    float64
#  3   mf_chm_MIN     103 non-null    float64
#  4   mf_chm_MEAN    103 non-null    float64
#  5   r_MIN          103 non-null    int64
#  6   contr_b_MAX    103 non-null    float64
#  7   contr_b_STD    103 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 6.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Sr_wood  Sr_2021_kBq_m   AEDR_mean  mf_chm_MIN  mf_chm_MEAN  \
# count  103.000000     103.000000  103.000000  103.000000   103.000000
# mean     8.656485    1242.902913    3.570291    3.368496    13.045021
# std      1.472424    2037.684800    6.089170    4.845054     6.609366
# min      6.075000      50.000000    0.480000   -0.018586     1.293138
# 25%      7.664000     200.000000    0.710000    0.482279     8.206727
# 50%      8.472000     400.000000    1.290000    0.642883    13.072916
# 75%      9.421000    1400.000000    2.960000    3.921804    17.432255
# max     13.864000   10500.000000   36.590000   17.862923    28.916548
#
#             r_MIN  contr_b_MAX  contr_b_STD
# count  103.000000   103.000000   103.000000
# mean    11.378641  2712.352866   349.854034
# std      9.139568   864.116297    93.673105
# min      2.000000   832.155518   109.232976
# 25%      5.000000  2123.614868   292.544440
# 50%      8.000000  2601.248047   341.904211
# 75%     15.000000  3045.944336   427.359073
# max     56.000000  6252.923340   588.661708

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['Sr_2021_kBq_m', 'r_MIN', 'contr_b_MAX', 'contr_b_STD'])
y = pd.DataFrame(select, columns= ['ln_Sr_wood'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Sr_2021_kBq_m  r_MIN  contr_b_MAX  contr_b_STD
# 0           1210     13  2713.600586   332.963753
# 1           1180     24  1793.493042   293.868420
# 2           1400     18  1761.097900   272.526176
# 3           1090     15  2518.435303   299.595643
# 4            720      8  2525.819336   327.599176

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Sr_wood
# 0       9.240
# 1       9.622
# 2       9.589
# 3       9.449
# 4       9.401

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.5607110647320358, 0.5202536516386109, 0.5851036487047325]
#     Mean: 0.555
#     Std: 0.027
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.84394748 0.86031743 0.99850686]
#     Mean: 0.901
#     Std: 0.069
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.6793080381120955, 0.8157243921616498, 0.8504491148555979]
#     Mean: 0.782
#     Std: 0.074
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.284 (std: 0.333)
# Parameters: {'colsample_bytree': 0.7739672957519645, 'gamma': 0.2603283640944162, 'learning_rate': 0.09185270092482001, 'max_depth': 2, 'n_estimators': 55, 'subsample': 0.9309795604388287}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.22844868, 0.47879367, 0.76951661, ..., 0.33864012, 0.21063218,
#        0.46239285]), 'std_fit_time': array([0.04644565, 0.17225274, 0.31867131, ..., 0.02838396, 0.00109447,
#        0.01692361]), 'mean_score_time': array([0.00940433, 0.00643172, 0.0065032 , ..., 0.00680313, 0.00677319,
#        0.00693898]), 'std_score_time': array([4.24741351e-03, 9.28616225e-04, 6.96937931e-04, ...,
#        1.75003784e-05, 1.83042128e-05, 2.09798780e-04]), 'param_colsample_bytree': masked_array(data=[0.37622920556608713, 0.3437383749800008,
#                    0.8946398929048923, ..., 0.9398092844786693,
#                    0.5622369770278649, 0.49719720821973556],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.14456085184803358, 0.1973874523348218,
#                    0.0476678633309639, ..., 0.1005487359101307,
#                    0.012799632184277376, 0.4019567967741692],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.2717206340171872, 0.2995990545339121,
#                    0.027059598118142326, ..., 0.12868797630222556,
#                    0.0746958425306492, 0.0995435973864654],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[4, 4, 4, ..., 3, 3, 4],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[79, 135, 185, ..., 111, 73, 158],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.7798739277451958, 0.7072753372392957,
#                    0.6595970132988782, ..., 0.5079134498253415,
#                    0.7704558035540162, 0.689081768411255],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.37622920556608713, 'gamma': 0.14456085184803358, 'learning_rate': 0.2717206340171872, 'max_depth': 4, 'n_estimators': 79, 'subsample': 0.7798739277451958}, {'colsample_bytree': 0.3437383749800008, 'gamma': 0.1973874523348218, 'learning_rate': 0.2995990545339121, 'max_depth': 4, 'n_estimators': 135, 'subsample': 0.7072753372392957}, {'colsample_bytree': 0.8946398929048923, 'gamma': 0.0476678633309639, 'learning_rate': 0.027059598118142326, 'max_depth': 4, 'n_estimators': 185, 'subsample': 0.6595970132988782}, {'colsample_bytree': 0.49505827001382, 'gamma': 0.24072053574771707, 'learning_rate': 0.0963749679564872, 'max_depth': 4, 'n_estimators': 149, 'subsample': 0.9927053796760736}, {'colsample_bytree': 0.6016359627383326, 'gamma': 0.29499944178340526, 'learning_rate': 0.04518746197608442, 'max_depth': 2, 'n_estimators': 112, 'subsample': 0.4299745547390931}, {'colsample_bytree': 0.2566985640861732, 'gamma': 0.37698103563591046, 'learning_rate': 0.020919454893450262, 'max_depth': 4, 'n_estimators': 180, 'subsample': 0.4209893107652488}, {'colsample_bytree': 0.21343612522216798, 'gamma': 0.36958056281194535, 'learning_rate': 0.2109954593708912, 'max_depth': 2, 'n_estimators': 131, 'subsample': 0.5416746421952416}, {'colsample_bytree': 0.5427007321538969, 'gamma': 0.43566740460956205, 'learning_rate': 0.1660694951560643, 'max_depth': 4, 'n_estimators': 171, 'subsample': 0.9185045488033738}, {'colsample_bytree': 0.8527059434406302, 'gamma': 0.04371493905650636, 'learning_rate': 0.16210589335655637, 'max_depth': 4, 'n_estimators': 161, 'subsample': 0.4987760818840066}, {'colsample_bytree': 0.8596585004248544, 'gamma': 0.0036834535981794536, 'learning_rate': 0.19885531165080841, 'max_depth': 3, 'n_estimators': 149, 'subsample': 0.8871743135503669}, {'colsample_bytree': 0.2953833409524796, 'gamma': 0.3776987708895909, 'learning_rate': 0.04136116446514459, 'max_depth': 3, 'n_estimators': 195, 'subsample': 0.5486374256767214}, {'colsample_bytree': 0.6375153419591427, 'gamma': 0.260901842862599, 'learning_rate': 0.24223266216279474, 'max_depth': 2, 'n_estimators': 188, 'subsample': 0.5896525691494532}, {'colsample_bytree': 0.7547696658180574, 'gamma': 0.16818775057911656, 'learning_rate': 0.17338055300285443, 'max_depth': 2, 'n_estimators': 130, 'subsample': 0.6823492156266604}, {'colsample_bytree': 0.7036305196117599, 'gamma': 0.48126775736605093, 'learning_rate': 0.02663891043113547, 'max_depth': 3, 'n_estimators': 137, 'subsample': 0.959722480620963}, {'colsample_bytree': 0.5813834958235239, 'gamma': 0.2728041841679083, 'learning_rate': 0.08768401460836, 'max_depth': 2, 'n_estimators': 100, 'subsample': 0.8542659705116222}, {'colsample_bytree': 0.8480064441229088, 'gamma': 0.11997351834565911, 'learning_rate': 0.14898448581835713, 'max_depth': 4, 'n_estimators': 51, 'subsample': 0.6844938360947571}, {'colsample_bytree': 0.6802655837629598, 'gamma': 0.12174736532450436, 'learning_rate': 0.08075618205878349, 'max_depth': 2, 'n_estimators': 112, 'subsample': 0.30803598402879084}, {'colsample_bytree': 0.2801100048752537, 'gamma': 0.3950021678837561, 'learning_rate': 0.3020103475715375, 'max_depth': 2, 'n_estimators': 80, 'subsample': 0.5245111986927432}, {'colsample_bytree': 0.09256132759240784, 'gamma': 0.21110556613756792, 'learning_rate': 0.24987835799386207, 'max_depth': 4, 'n_estimators': 104, 'subsample': 0.6656210037462056}, {'colsample_bytree': 0.3830429161437883, 'gamma': 0.28791694590500266, 'learning_rate': 0.27142375944053687, 'max_depth': 3, 'n_estimators': 136, 'subsample': 0.5913978436773772}, {'colsample_bytree': 0.6759964087272419, 'gamma': 0.436071009274251, 'learning_rate': 0.18875442320031818, 'max_depth': 3, 'n_estimators': 194, 'subsample': 0.4051724826131102}, {'colsample_bytree': 0.11581224630382873, 'gamma': 0.094961955452453, 'learning_rate': 0.0248258544975736, 'max_depth': 2, 'n_estimators': 85, 'subsample': 0.8740702662420388}, {'colsample_bytree':  ...
#        -0.29797755, -0.69059709]), 'split1_test_score': array([ 0.02026579,  0.18257176, -0.01784316, ..., -0.07952925,
#         0.21975139, -0.00648711]), 'split2_test_score': array([-0.91809844, -0.94003086, -0.0834635 , ..., -0.3417685 ,
#        -0.1168196 , -0.18866187]), 'split3_test_score': array([0.50737432, 0.52521842, 0.5237514 , ..., 0.56358987, 0.57611048,
#        0.58447989]), 'split4_test_score': array([0.77363356, 0.79848195, 0.76766345, ..., 0.74510105, 0.75786994,
#        0.80249227]), 'mean_test_score': array([-0.23306846, -0.23388011,  0.20138899, ...,  0.05216758,
#         0.22778693,  0.10024522]), 'std_test_score': array([0.87470625, 0.9559677 , 0.37461137, ..., 0.52438611, 0.39939049,
#        0.53813098]), 'rank_test_score': array([2754, 2756,  143, ..., 1579,   56, 1102], dtype=int32), 'split0_train_score': array([0.98137978, 0.98006517, 0.93947231, ..., 0.97762163, 0.91842133,
#        0.95188733]), 'split1_train_score': array([0.97828179, 0.97798923, 0.92745123, ..., 0.96830926, 0.90246183,
#        0.93990266]), 'split2_train_score': array([0.98186673, 0.97880222, 0.93360644, ..., 0.97898406, 0.92252743,
#        0.95088234]), 'split3_train_score': array([0.96479411, 0.96366935, 0.89630864, ..., 0.96635007, 0.86804916,
#        0.91648417]), 'split4_train_score': array([0.97522441, 0.97396815, 0.92027891, ..., 0.96951844, 0.90214513,
#        0.94449019]), 'mean_train_score': array([0.97630936, 0.97489882, 0.92342351, ..., 0.97215669, 0.90272098,
#        0.94072934]), 'std_train_score': array([0.00623317, 0.00597403, 0.01498388, ..., 0.00513728, 0.01919026,
#        0.01288596])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.7739672957519645
# Gamma: 0.2603283640944162
# Learning_rate: 0.09185270092482001
# Max_depth: 2
# N_estimators: 55
# Subsample: 0.9309795604388287

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:7.59270	validation_1-rmse:7.42610
# [1]	validation_0-rmse:6.94214	validation_1-rmse:6.76526
# [2]	validation_0-rmse:6.33542	validation_1-rmse:6.16593
# [3]	validation_0-rmse:5.78782	validation_1-rmse:5.62529
# [4]	validation_0-rmse:5.28742	validation_1-rmse:5.13093
# [5]	validation_0-rmse:4.83719	validation_1-rmse:4.70971
# [6]	validation_0-rmse:4.42206	validation_1-rmse:4.32523
# [7]	validation_0-rmse:4.04345	validation_1-rmse:3.95131
# [8]	validation_0-rmse:3.69935	validation_1-rmse:3.63383
# [9]	validation_0-rmse:3.39192	validation_1-rmse:3.32199
# [10]	validation_0-rmse:3.11348	validation_1-rmse:3.05204
# [11]	validation_0-rmse:2.86277	validation_1-rmse:2.79651
# [12]	validation_0-rmse:2.63125	validation_1-rmse:2.57329
# [13]	validation_0-rmse:2.42685	validation_1-rmse:2.37322
# [14]	validation_0-rmse:2.23252	validation_1-rmse:2.17596
# [15]	validation_0-rmse:2.06046	validation_1-rmse:2.01876
# [16]	validation_0-rmse:1.90923	validation_1-rmse:1.87093
# [17]	validation_0-rmse:1.76934	validation_1-rmse:1.75434
# [18]	validation_0-rmse:1.63951	validation_1-rmse:1.62130
# [19]	validation_0-rmse:1.52960	validation_1-rmse:1.51306
# [20]	validation_0-rmse:1.42732	validation_1-rmse:1.41623
# [21]	validation_0-rmse:1.33287	validation_1-rmse:1.33964
# [22]	validation_0-rmse:1.25353	validation_1-rmse:1.25917
# [23]	validation_0-rmse:1.18592	validation_1-rmse:1.18940
# [24]	validation_0-rmse:1.11980	validation_1-rmse:1.12558
# [25]	validation_0-rmse:1.06451	validation_1-rmse:1.06887
# [26]	validation_0-rmse:1.01138	validation_1-rmse:1.02133
# [27]	validation_0-rmse:0.96429	validation_1-rmse:0.97912
# [28]	validation_0-rmse:0.92442	validation_1-rmse:0.93900
# [29]	validation_0-rmse:0.88607	validation_1-rmse:0.90829
# [30]	validation_0-rmse:0.85266	validation_1-rmse:0.88217
# [31]	validation_0-rmse:0.82312	validation_1-rmse:0.85871
# [32]	validation_0-rmse:0.79883	validation_1-rmse:0.84287
# [33]	validation_0-rmse:0.77545	validation_1-rmse:0.82251
# [34]	validation_0-rmse:0.75433	validation_1-rmse:0.80901
# [35]	validation_0-rmse:0.73667	validation_1-rmse:0.79251
# [36]	validation_0-rmse:0.72035	validation_1-rmse:0.78195
# [37]	validation_0-rmse:0.70621	validation_1-rmse:0.77315
# [38]	validation_0-rmse:0.69328	validation_1-rmse:0.76141
# [39]	validation_0-rmse:0.68027	validation_1-rmse:0.75830
# [40]	validation_0-rmse:0.67101	validation_1-rmse:0.75883
# [41]	validation_0-rmse:0.66007	validation_1-rmse:0.75242
# [42]	validation_0-rmse:0.65185	validation_1-rmse:0.74561
# [43]	validation_0-rmse:0.64174	validation_1-rmse:0.73868
# [44]	validation_0-rmse:0.63436	validation_1-rmse:0.73662
# [45]	validation_0-rmse:0.62774	validation_1-rmse:0.73390
# [46]	validation_0-rmse:0.62205	validation_1-rmse:0.73160
# [47]	validation_0-rmse:0.61678	validation_1-rmse:0.72580
# [48]	validation_0-rmse:0.61221	validation_1-rmse:0.72499
# [49]	validation_0-rmse:0.60081	validation_1-rmse:0.72083
# [50]	validation_0-rmse:0.59325	validation_1-rmse:0.71973
# [51]	validation_0-rmse:0.58919	validation_1-rmse:0.72031
# [52]	validation_0-rmse:0.58608	validation_1-rmse:0.72134
# [53]	validation_0-rmse:0.58162	validation_1-rmse:0.71810
# [54]	validation_0-rmse:0.57569	validation_1-rmse:0.72132
# [0]	validation_0-rmse:7.58977	validation_1-rmse:7.41664
# [1]	validation_0-rmse:6.93462	validation_1-rmse:6.75418
# [2]	validation_0-rmse:6.33612	validation_1-rmse:6.14787
# [3]	validation_0-rmse:5.78932	validation_1-rmse:5.58437
# [4]	validation_0-rmse:5.29236	validation_1-rmse:5.10788
# [5]	validation_0-rmse:4.84079	validation_1-rmse:4.67017
# [6]	validation_0-rmse:4.42917	validation_1-rmse:4.27679
# [7]	validation_0-rmse:4.05083	validation_1-rmse:3.90796
# [8]	validation_0-rmse:3.71247	validation_1-rmse:3.57008
# [9]	validation_0-rmse:3.40788	validation_1-rmse:3.26263
# [10]	validation_0-rmse:3.12806	validation_1-rmse:2.97448
# [11]	validation_0-rmse:2.88627	validation_1-rmse:2.70543
# [12]	validation_0-rmse:2.65696	validation_1-rmse:2.49252
# [13]	validation_0-rmse:2.44729	validation_1-rmse:2.27244
# [14]	validation_0-rmse:2.25715	validation_1-rmse:2.09511
# [15]	validation_0-rmse:2.08673	validation_1-rmse:1.93788
# [16]	validation_0-rmse:1.93161	validation_1-rmse:1.78654
# [17]	validation_0-rmse:1.78757	validation_1-rmse:1.64748
# [18]	validation_0-rmse:1.65758	validation_1-rmse:1.51546
# [19]	validation_0-rmse:1.54237	validation_1-rmse:1.39206
# [20]	validation_0-rmse:1.44024	validation_1-rmse:1.28221
# [21]	validation_0-rmse:1.34250	validation_1-rmse:1.19917
# [22]	validation_0-rmse:1.25693	validation_1-rmse:1.12172
# [23]	validation_0-rmse:1.18253	validation_1-rmse:1.04488
# [24]	validation_0-rmse:1.11256	validation_1-rmse:0.98827
# [25]	validation_0-rmse:1.05394	validation_1-rmse:0.94014
# [26]	validation_0-rmse:1.00112	validation_1-rmse:0.90053
# [27]	validation_0-rmse:0.95162	validation_1-rmse:0.85565
# [28]	validation_0-rmse:0.90813	validation_1-rmse:0.82398
# [29]	validation_0-rmse:0.87149	validation_1-rmse:0.79199
# [30]	validation_0-rmse:0.83997	validation_1-rmse:0.76891
# [31]	validation_0-rmse:0.80895	validation_1-rmse:0.74956
# [32]	validation_0-rmse:0.78270	validation_1-rmse:0.72741
# [33]	validation_0-rmse:0.76110	validation_1-rmse:0.71172
# [34]	validation_0-rmse:0.74334	validation_1-rmse:0.69776
# [35]	validation_0-rmse:0.72559	validation_1-rmse:0.68577
# [36]	validation_0-rmse:0.70936	validation_1-rmse:0.67449
# [37]	validation_0-rmse:0.69313	validation_1-rmse:0.66591
# [38]	validation_0-rmse:0.68090	validation_1-rmse:0.65932
# [39]	validation_0-rmse:0.66860	validation_1-rmse:0.65294
# [40]	validation_0-rmse:0.66032	validation_1-rmse:0.64741
# [41]	validation_0-rmse:0.65125	validation_1-rmse:0.64288
# [42]	validation_0-rmse:0.64279	validation_1-rmse:0.64503
# [43]	validation_0-rmse:0.63550	validation_1-rmse:0.63944
# [44]	validation_0-rmse:0.62894	validation_1-rmse:0.63720
# [45]	validation_0-rmse:0.62619	validation_1-rmse:0.63654
# [46]	validation_0-rmse:0.62061	validation_1-rmse:0.63051
# [47]	validation_0-rmse:0.61594	validation_1-rmse:0.62807
# [48]	validation_0-rmse:0.60909	validation_1-rmse:0.62638
# [49]	validation_0-rmse:0.60482	validation_1-rmse:0.62587
# [50]	validation_0-rmse:0.60090	validation_1-rmse:0.62532
# [51]	validation_0-rmse:0.59068	validation_1-rmse:0.61091
# [52]	validation_0-rmse:0.58312	validation_1-rmse:0.61437
# [53]	validation_0-rmse:0.58026	validation_1-rmse:0.61639
# [54]	validation_0-rmse:0.57616	validation_1-rmse:0.61879
# [0]	validation_0-rmse:7.59209	validation_1-rmse:7.41116
# [1]	validation_0-rmse:6.92717	validation_1-rmse:6.74305
# [2]	validation_0-rmse:6.32139	validation_1-rmse:6.15449
# [3]	validation_0-rmse:5.77608	validation_1-rmse:5.62330
# [4]	validation_0-rmse:5.27951	validation_1-rmse:5.14029
# [5]	validation_0-rmse:4.82468	validation_1-rmse:4.69809
# [6]	validation_0-rmse:4.40766	validation_1-rmse:4.29966
# [7]	validation_0-rmse:4.03009	validation_1-rmse:3.93255
# [8]	validation_0-rmse:3.68846	validation_1-rmse:3.60219
# [9]	validation_0-rmse:3.38157	validation_1-rmse:3.28716
# [10]	validation_0-rmse:3.10435	validation_1-rmse:3.00189
# [11]	validation_0-rmse:2.84852	validation_1-rmse:2.73874
# [12]	validation_0-rmse:2.61565	validation_1-rmse:2.51710
# [13]	validation_0-rmse:2.41000	validation_1-rmse:2.30463
# [14]	validation_0-rmse:2.21947	validation_1-rmse:2.12440
# [15]	validation_0-rmse:2.05110	validation_1-rmse:1.96514
# [16]	validation_0-rmse:1.89529	validation_1-rmse:1.81991
# [17]	validation_0-rmse:1.75439	validation_1-rmse:1.68852
# [18]	validation_0-rmse:1.62894	validation_1-rmse:1.56479
# [19]	validation_0-rmse:1.51792	validation_1-rmse:1.46031
# [20]	validation_0-rmse:1.42007	validation_1-rmse:1.35699
# [21]	validation_0-rmse:1.32648	validation_1-rmse:1.27241
# [22]	validation_0-rmse:1.24421	validation_1-rmse:1.19625
# [23]	validation_0-rmse:1.17648	validation_1-rmse:1.12485
# [24]	validation_0-rmse:1.11125	validation_1-rmse:1.06713
# [25]	validation_0-rmse:1.05212	validation_1-rmse:1.00918
# [26]	validation_0-rmse:1.00130	validation_1-rmse:0.96185
# [27]	validation_0-rmse:0.95671	validation_1-rmse:0.92416
# [28]	validation_0-rmse:0.91727	validation_1-rmse:0.88956
# [29]	validation_0-rmse:0.88024	validation_1-rmse:0.85640
# [30]	validation_0-rmse:0.84498	validation_1-rmse:0.82926
# [31]	validation_0-rmse:0.81384	validation_1-rmse:0.79970
# [32]	validation_0-rmse:0.78689	validation_1-rmse:0.77847
# [33]	validation_0-rmse:0.76535	validation_1-rmse:0.76290
# [34]	validation_0-rmse:0.74574	validation_1-rmse:0.74624
# [35]	validation_0-rmse:0.72599	validation_1-rmse:0.74403
# [36]	validation_0-rmse:0.70950	validation_1-rmse:0.73298
# [37]	validation_0-rmse:0.69389	validation_1-rmse:0.73001
# [38]	validation_0-rmse:0.67905	validation_1-rmse:0.72698
# [39]	validation_0-rmse:0.66547	validation_1-rmse:0.73136
# [40]	validation_0-rmse:0.65253	validation_1-rmse:0.72718
# [41]	validation_0-rmse:0.64228	validation_1-rmse:0.72295
# [42]	validation_0-rmse:0.63255	validation_1-rmse:0.71453
# [43]	validation_0-rmse:0.62275	validation_1-rmse:0.71056
# [44]	validation_0-rmse:0.61499	validation_1-rmse:0.70680
# [45]	validation_0-rmse:0.60760	validation_1-rmse:0.70739
# [46]	validation_0-rmse:0.60116	validation_1-rmse:0.70717
# [47]	validation_0-rmse:0.59501	validation_1-rmse:0.71168
# [48]	validation_0-rmse:0.58838	validation_1-rmse:0.70689
# [49]	validation_0-rmse:0.58214	validation_1-rmse:0.70591
# [50]	validation_0-rmse:0.57717	validation_1-rmse:0.70532
# [51]	validation_0-rmse:0.57253	validation_1-rmse:0.71062
# [52]	validation_0-rmse:0.56746	validation_1-rmse:0.70873
# [53]	validation_0-rmse:0.56366	validation_1-rmse:0.71126
# [54]	validation_0-rmse:0.56011	validation_1-rmse:0.71084
# [0]	validation_0-rmse:7.58133	validation_1-rmse:7.45160
# [1]	validation_0-rmse:6.91156	validation_1-rmse:6.78744
# [2]	validation_0-rmse:6.30659	validation_1-rmse:6.19519
# [3]	validation_0-rmse:5.75438	validation_1-rmse:5.65572
# [4]	validation_0-rmse:5.25365	validation_1-rmse:5.16773
# [5]	validation_0-rmse:4.79843	validation_1-rmse:4.72090
# [6]	validation_0-rmse:4.38937	validation_1-rmse:4.32427
# [7]	validation_0-rmse:4.01259	validation_1-rmse:3.95584
# [8]	validation_0-rmse:3.67082	validation_1-rmse:3.62326
# [9]	validation_0-rmse:3.35638	validation_1-rmse:3.31932
# [10]	validation_0-rmse:3.07816	validation_1-rmse:3.05235
# [11]	validation_0-rmse:2.83265	validation_1-rmse:2.81718
# [12]	validation_0-rmse:2.59805	validation_1-rmse:2.59428
# [13]	validation_0-rmse:2.39219	validation_1-rmse:2.40078
# [14]	validation_0-rmse:2.20111	validation_1-rmse:2.22583
# [15]	validation_0-rmse:2.02866	validation_1-rmse:2.06982
# [16]	validation_0-rmse:1.87018	validation_1-rmse:1.92554
# [17]	validation_0-rmse:1.73194	validation_1-rmse:1.80054
# [18]	validation_0-rmse:1.60327	validation_1-rmse:1.70021
# [19]	validation_0-rmse:1.48816	validation_1-rmse:1.60046
# [20]	validation_0-rmse:1.38633	validation_1-rmse:1.52168
# [21]	validation_0-rmse:1.29202	validation_1-rmse:1.44908
# [22]	validation_0-rmse:1.20418	validation_1-rmse:1.38547
# [23]	validation_0-rmse:1.12928	validation_1-rmse:1.32685
# [24]	validation_0-rmse:1.06163	validation_1-rmse:1.27818
# [25]	validation_0-rmse:1.00116	validation_1-rmse:1.23849
# [26]	validation_0-rmse:0.94623	validation_1-rmse:1.19756
# [27]	validation_0-rmse:0.89667	validation_1-rmse:1.16323
# [28]	validation_0-rmse:0.84571	validation_1-rmse:1.13237
# [29]	validation_0-rmse:0.80734	validation_1-rmse:1.11346
# [30]	validation_0-rmse:0.77189	validation_1-rmse:1.09164
# [31]	validation_0-rmse:0.74153	validation_1-rmse:1.07336
# [32]	validation_0-rmse:0.71691	validation_1-rmse:1.05662
# [33]	validation_0-rmse:0.69417	validation_1-rmse:1.04064
# [34]	validation_0-rmse:0.67286	validation_1-rmse:1.03809
# [35]	validation_0-rmse:0.65582	validation_1-rmse:1.03605
# [36]	validation_0-rmse:0.64081	validation_1-rmse:1.02580
# [37]	validation_0-rmse:0.62606	validation_1-rmse:1.01868
# [38]	validation_0-rmse:0.61313	validation_1-rmse:1.01201
# [39]	validation_0-rmse:0.60145	validation_1-rmse:1.01605
# [40]	validation_0-rmse:0.58876	validation_1-rmse:1.01955
# [41]	validation_0-rmse:0.57758	validation_1-rmse:1.01553
# [42]	validation_0-rmse:0.56922	validation_1-rmse:1.01341
# [43]	validation_0-rmse:0.56270	validation_1-rmse:1.00804
# [44]	validation_0-rmse:0.55714	validation_1-rmse:1.00252
# [45]	validation_0-rmse:0.55090	validation_1-rmse:0.99670
# [46]	validation_0-rmse:0.54455	validation_1-rmse:0.99817
# [47]	validation_0-rmse:0.53370	validation_1-rmse:0.99833
# [48]	validation_0-rmse:0.52950	validation_1-rmse:0.99794
# [49]	validation_0-rmse:0.52574	validation_1-rmse:0.99572
# [50]	validation_0-rmse:0.52254	validation_1-rmse:0.99381
# [51]	validation_0-rmse:0.51344	validation_1-rmse:0.99263
# [52]	validation_0-rmse:0.51066	validation_1-rmse:0.98601
# [53]	validation_0-rmse:0.50660	validation_1-rmse:0.98903
# [54]	validation_0-rmse:0.50413	validation_1-rmse:0.98450
# [0]	validation_0-rmse:7.53498	validation_1-rmse:7.66465
# [1]	validation_0-rmse:6.87458	validation_1-rmse:6.99899
# [2]	validation_0-rmse:6.27241	validation_1-rmse:6.41470
# [3]	validation_0-rmse:5.72568	validation_1-rmse:5.88392
# [4]	validation_0-rmse:5.23303	validation_1-rmse:5.40466
# [5]	validation_0-rmse:4.79147	validation_1-rmse:4.97272
# [6]	validation_0-rmse:4.38726	validation_1-rmse:4.57098
# [7]	validation_0-rmse:4.01432	validation_1-rmse:4.20831
# [8]	validation_0-rmse:3.67542	validation_1-rmse:3.87083
# [9]	validation_0-rmse:3.36792	validation_1-rmse:3.56413
# [10]	validation_0-rmse:3.09625	validation_1-rmse:3.27969
# [11]	validation_0-rmse:2.84602	validation_1-rmse:3.02755
# [12]	validation_0-rmse:2.61814	validation_1-rmse:2.80361
# [13]	validation_0-rmse:2.41201	validation_1-rmse:2.59472
# [14]	validation_0-rmse:2.21852	validation_1-rmse:2.40171
# [15]	validation_0-rmse:2.04366	validation_1-rmse:2.23277
# [16]	validation_0-rmse:1.88713	validation_1-rmse:2.07553
# [17]	validation_0-rmse:1.74538	validation_1-rmse:1.94067
# [18]	validation_0-rmse:1.61763	validation_1-rmse:1.81282
# [19]	validation_0-rmse:1.50950	validation_1-rmse:1.70090
# [20]	validation_0-rmse:1.41277	validation_1-rmse:1.59580
# [21]	validation_0-rmse:1.31902	validation_1-rmse:1.49936
# [22]	validation_0-rmse:1.23334	validation_1-rmse:1.42436
# [23]	validation_0-rmse:1.16372	validation_1-rmse:1.35276
# [24]	validation_0-rmse:1.09308	validation_1-rmse:1.28343
# [25]	validation_0-rmse:1.03438	validation_1-rmse:1.22522
# [26]	validation_0-rmse:0.98229	validation_1-rmse:1.17266
# [27]	validation_0-rmse:0.93342	validation_1-rmse:1.12068
# [28]	validation_0-rmse:0.88953	validation_1-rmse:1.07879
# [29]	validation_0-rmse:0.85102	validation_1-rmse:1.04114
# [30]	validation_0-rmse:0.81838	validation_1-rmse:1.01001
# [31]	validation_0-rmse:0.78971	validation_1-rmse:0.98224
# [32]	validation_0-rmse:0.76622	validation_1-rmse:0.96182
# [33]	validation_0-rmse:0.74424	validation_1-rmse:0.93520
# [34]	validation_0-rmse:0.72608	validation_1-rmse:0.91945
# [35]	validation_0-rmse:0.70895	validation_1-rmse:0.90201
# [36]	validation_0-rmse:0.69159	validation_1-rmse:0.88251
# [37]	validation_0-rmse:0.67710	validation_1-rmse:0.86346
# [38]	validation_0-rmse:0.66409	validation_1-rmse:0.84523
# [39]	validation_0-rmse:0.65342	validation_1-rmse:0.83612
# [40]	validation_0-rmse:0.64107	validation_1-rmse:0.82567
# [41]	validation_0-rmse:0.63173	validation_1-rmse:0.81039
# [42]	validation_0-rmse:0.62325	validation_1-rmse:0.80490
# [43]	validation_0-rmse:0.61412	validation_1-rmse:0.80088
# [44]	validation_0-rmse:0.60604	validation_1-rmse:0.79317
# [45]	validation_0-rmse:0.60003	validation_1-rmse:0.78514
# [46]	validation_0-rmse:0.59394	validation_1-rmse:0.78268
# [47]	validation_0-rmse:0.58824	validation_1-rmse:0.77289
# [48]	validation_0-rmse:0.58243	validation_1-rmse:0.77126
# [49]	validation_0-rmse:0.57750	validation_1-rmse:0.76501
# [50]	validation_0-rmse:0.57168	validation_1-rmse:0.76408
# [51]	validation_0-rmse:0.56789	validation_1-rmse:0.76224
# [52]	validation_0-rmse:0.56423	validation_1-rmse:0.75730
# [53]	validation_0-rmse:0.55992	validation_1-rmse:0.75380
# [54]	validation_0-rmse:0.55651	validation_1-rmse:0.75089
# [0]	validation_0-rmse:7.51991	validation_1-rmse:7.70036
# [1]	validation_0-rmse:6.86634	validation_1-rmse:7.04481
# [2]	validation_0-rmse:6.26240	validation_1-rmse:6.40438
# [3]	validation_0-rmse:5.72381	validation_1-rmse:5.83374
# [4]	validation_0-rmse:5.23435	validation_1-rmse:5.31621
# [5]	validation_0-rmse:4.78133	validation_1-rmse:4.84892
# [6]	validation_0-rmse:4.37152	validation_1-rmse:4.43127
# [7]	validation_0-rmse:4.00477	validation_1-rmse:4.03844
# [8]	validation_0-rmse:3.66503	validation_1-rmse:3.70728
# [9]	validation_0-rmse:3.35946	validation_1-rmse:3.41638
# [10]	validation_0-rmse:3.08270	validation_1-rmse:3.14361
# [11]	validation_0-rmse:2.82795	validation_1-rmse:2.89127
# [12]	validation_0-rmse:2.59520	validation_1-rmse:2.66269
# [13]	validation_0-rmse:2.39293	validation_1-rmse:2.45461
# [14]	validation_0-rmse:2.20312	validation_1-rmse:2.26910
# [15]	validation_0-rmse:2.03366	validation_1-rmse:2.10771
# [16]	validation_0-rmse:1.87604	validation_1-rmse:1.94692
# [17]	validation_0-rmse:1.73728	validation_1-rmse:1.81267
# [18]	validation_0-rmse:1.60993	validation_1-rmse:1.69770
# [19]	validation_0-rmse:1.49845	validation_1-rmse:1.59346
# [20]	validation_0-rmse:1.40046	validation_1-rmse:1.49675
# [21]	validation_0-rmse:1.30728	validation_1-rmse:1.41625
# [22]	validation_0-rmse:1.22034	validation_1-rmse:1.33274
# [23]	validation_0-rmse:1.14960	validation_1-rmse:1.26970
# [24]	validation_0-rmse:1.08400	validation_1-rmse:1.20584
# [25]	validation_0-rmse:1.02168	validation_1-rmse:1.13749
# [26]	validation_0-rmse:0.96796	validation_1-rmse:1.09591
# [27]	validation_0-rmse:0.92177	validation_1-rmse:1.05849
# [28]	validation_0-rmse:0.87853	validation_1-rmse:1.02059
# [29]	validation_0-rmse:0.84282	validation_1-rmse:0.98551
# [30]	validation_0-rmse:0.81293	validation_1-rmse:0.95678
# [31]	validation_0-rmse:0.78584	validation_1-rmse:0.93362
# [32]	validation_0-rmse:0.75975	validation_1-rmse:0.91230
# [33]	validation_0-rmse:0.73594	validation_1-rmse:0.89805
# [34]	validation_0-rmse:0.71666	validation_1-rmse:0.88241
# [35]	validation_0-rmse:0.70067	validation_1-rmse:0.86822
# [36]	validation_0-rmse:0.68524	validation_1-rmse:0.85656
# [37]	validation_0-rmse:0.67206	validation_1-rmse:0.85370
# [38]	validation_0-rmse:0.65979	validation_1-rmse:0.84440
# [39]	validation_0-rmse:0.65076	validation_1-rmse:0.83538
# [40]	validation_0-rmse:0.64055	validation_1-rmse:0.82750
# [41]	validation_0-rmse:0.63201	validation_1-rmse:0.82652
# [42]	validation_0-rmse:0.62430	validation_1-rmse:0.82696
# [43]	validation_0-rmse:0.61772	validation_1-rmse:0.82569
# [44]	validation_0-rmse:0.61137	validation_1-rmse:0.82230
# [45]	validation_0-rmse:0.60175	validation_1-rmse:0.81193
# [46]	validation_0-rmse:0.59489	validation_1-rmse:0.80901
# [47]	validation_0-rmse:0.58390	validation_1-rmse:0.80357
# [48]	validation_0-rmse:0.57846	validation_1-rmse:0.80159
# [49]	validation_0-rmse:0.57395	validation_1-rmse:0.79958
# [50]	validation_0-rmse:0.56990	validation_1-rmse:0.80273
# [51]	validation_0-rmse:0.56621	validation_1-rmse:0.80566
# [52]	validation_0-rmse:0.56292	validation_1-rmse:0.80458
# [53]	validation_0-rmse:0.55872	validation_1-rmse:0.80478
# [54]	validation_0-rmse:0.55607	validation_1-rmse:0.80378
# [0]	validation_0-rmse:7.56982	validation_1-rmse:7.52780
# [1]	validation_0-rmse:6.91425	validation_1-rmse:6.86919
# [2]	validation_0-rmse:6.31463	validation_1-rmse:6.27377
# [3]	validation_0-rmse:5.77413	validation_1-rmse:5.73640
# [4]	validation_0-rmse:5.27556	validation_1-rmse:5.24198
# [5]	validation_0-rmse:4.81881	validation_1-rmse:4.79124
# [6]	validation_0-rmse:4.40398	validation_1-rmse:4.38231
# [7]	validation_0-rmse:4.03296	validation_1-rmse:4.01269
# [8]	validation_0-rmse:3.69318	validation_1-rmse:3.67253
# [9]	validation_0-rmse:3.39795	validation_1-rmse:3.35690
# [10]	validation_0-rmse:3.11937	validation_1-rmse:3.06129
# [11]	validation_0-rmse:2.87073	validation_1-rmse:2.79526
# [12]	validation_0-rmse:2.63801	validation_1-rmse:2.55859
# [13]	validation_0-rmse:2.42950	validation_1-rmse:2.33182
# [14]	validation_0-rmse:2.24146	validation_1-rmse:2.14817
# [15]	validation_0-rmse:2.06949	validation_1-rmse:1.97416
# [16]	validation_0-rmse:1.91131	validation_1-rmse:1.81600
# [17]	validation_0-rmse:1.77257	validation_1-rmse:1.68069
# [18]	validation_0-rmse:1.64421	validation_1-rmse:1.55702
# [19]	validation_0-rmse:1.53438	validation_1-rmse:1.45317
# [20]	validation_0-rmse:1.43193	validation_1-rmse:1.35045
# [21]	validation_0-rmse:1.33839	validation_1-rmse:1.25832
# [22]	validation_0-rmse:1.25669	validation_1-rmse:1.18025
# [23]	validation_0-rmse:1.18464	validation_1-rmse:1.10971
# [24]	validation_0-rmse:1.11738	validation_1-rmse:1.04394
# [25]	validation_0-rmse:1.05745	validation_1-rmse:0.98699
# [26]	validation_0-rmse:1.00425	validation_1-rmse:0.93685
# [27]	validation_0-rmse:0.95788	validation_1-rmse:0.89576
# [28]	validation_0-rmse:0.91630	validation_1-rmse:0.85735
# [29]	validation_0-rmse:0.87936	validation_1-rmse:0.82252
# [30]	validation_0-rmse:0.84807	validation_1-rmse:0.79183
# [31]	validation_0-rmse:0.82048	validation_1-rmse:0.77077
# [32]	validation_0-rmse:0.79237	validation_1-rmse:0.75198
# [33]	validation_0-rmse:0.77131	validation_1-rmse:0.73925
# [34]	validation_0-rmse:0.74967	validation_1-rmse:0.72508
# [35]	validation_0-rmse:0.73139	validation_1-rmse:0.71051
# [36]	validation_0-rmse:0.71590	validation_1-rmse:0.70234
# [37]	validation_0-rmse:0.69968	validation_1-rmse:0.69674
# [38]	validation_0-rmse:0.68640	validation_1-rmse:0.68735
# [39]	validation_0-rmse:0.67563	validation_1-rmse:0.67895
# [40]	validation_0-rmse:0.66841	validation_1-rmse:0.67764
# [41]	validation_0-rmse:0.65916	validation_1-rmse:0.67765
# [42]	validation_0-rmse:0.65027	validation_1-rmse:0.67674
# [43]	validation_0-rmse:0.64211	validation_1-rmse:0.67478
# [44]	validation_0-rmse:0.63571	validation_1-rmse:0.67278
# [45]	validation_0-rmse:0.63068	validation_1-rmse:0.67179
# [46]	validation_0-rmse:0.62301	validation_1-rmse:0.66876
# [47]	validation_0-rmse:0.61755	validation_1-rmse:0.67141
# [48]	validation_0-rmse:0.61211	validation_1-rmse:0.67117
# [49]	validation_0-rmse:0.60791	validation_1-rmse:0.66686
# [50]	validation_0-rmse:0.60391	validation_1-rmse:0.66538
# [51]	validation_0-rmse:0.59476	validation_1-rmse:0.66174
# [52]	validation_0-rmse:0.58876	validation_1-rmse:0.65690
# [53]	validation_0-rmse:0.58453	validation_1-rmse:0.65387
# [54]	validation_0-rmse:0.57988	validation_1-rmse:0.65135
# [0]	validation_0-rmse:7.71332	validation_1-rmse:6.85630
# [1]	validation_0-rmse:7.03663	validation_1-rmse:6.17929
# [2]	validation_0-rmse:6.41872	validation_1-rmse:5.57803
# [3]	validation_0-rmse:5.85759	validation_1-rmse:5.04791
# [4]	validation_0-rmse:5.35164	validation_1-rmse:4.55592
# [5]	validation_0-rmse:4.88901	validation_1-rmse:4.12343
# [6]	validation_0-rmse:4.47142	validation_1-rmse:3.73260
# [7]	validation_0-rmse:4.09137	validation_1-rmse:3.37482
# [8]	validation_0-rmse:3.74816	validation_1-rmse:3.04423
# [9]	validation_0-rmse:3.43675	validation_1-rmse:2.74791
# [10]	validation_0-rmse:3.14985	validation_1-rmse:2.47997
# [11]	validation_0-rmse:2.89028	validation_1-rmse:2.23495
# [12]	validation_0-rmse:2.65720	validation_1-rmse:2.03226
# [13]	validation_0-rmse:2.44693	validation_1-rmse:1.83964
# [14]	validation_0-rmse:2.26079	validation_1-rmse:1.67227
# [15]	validation_0-rmse:2.08219	validation_1-rmse:1.51851
# [16]	validation_0-rmse:1.93027	validation_1-rmse:1.39384
# [17]	validation_0-rmse:1.78076	validation_1-rmse:1.27552
# [18]	validation_0-rmse:1.65719	validation_1-rmse:1.17013
# [19]	validation_0-rmse:1.54071	validation_1-rmse:1.07639
# [20]	validation_0-rmse:1.43625	validation_1-rmse:0.99742
# [21]	validation_0-rmse:1.33964	validation_1-rmse:0.93390
# [22]	validation_0-rmse:1.25194	validation_1-rmse:0.88476
# [23]	validation_0-rmse:1.17592	validation_1-rmse:0.83928
# [24]	validation_0-rmse:1.10660	validation_1-rmse:0.79613
# [25]	validation_0-rmse:1.04601	validation_1-rmse:0.76147
# [26]	validation_0-rmse:0.99260	validation_1-rmse:0.73503
# [27]	validation_0-rmse:0.94536	validation_1-rmse:0.71898
# [28]	validation_0-rmse:0.90354	validation_1-rmse:0.70899
# [29]	validation_0-rmse:0.86479	validation_1-rmse:0.70171
# [30]	validation_0-rmse:0.83118	validation_1-rmse:0.70356
# [31]	validation_0-rmse:0.80433	validation_1-rmse:0.70463
# [32]	validation_0-rmse:0.77742	validation_1-rmse:0.70449
# [33]	validation_0-rmse:0.75388	validation_1-rmse:0.71288
# [34]	validation_0-rmse:0.73472	validation_1-rmse:0.72159
# [35]	validation_0-rmse:0.71553	validation_1-rmse:0.72792
# [36]	validation_0-rmse:0.70074	validation_1-rmse:0.72561
# [37]	validation_0-rmse:0.68313	validation_1-rmse:0.72825
# [38]	validation_0-rmse:0.66972	validation_1-rmse:0.73365
# [39]	validation_0-rmse:0.65797	validation_1-rmse:0.73976
# [40]	validation_0-rmse:0.64941	validation_1-rmse:0.74644
# [41]	validation_0-rmse:0.63991	validation_1-rmse:0.75003
# [42]	validation_0-rmse:0.63085	validation_1-rmse:0.75767
# [43]	validation_0-rmse:0.62296	validation_1-rmse:0.76668
# [44]	validation_0-rmse:0.61652	validation_1-rmse:0.77371
# [45]	validation_0-rmse:0.60913	validation_1-rmse:0.77442
# [46]	validation_0-rmse:0.60145	validation_1-rmse:0.77965
# [47]	validation_0-rmse:0.59663	validation_1-rmse:0.78033
# [48]	validation_0-rmse:0.59012	validation_1-rmse:0.78230
# [0]	validation_0-rmse:7.67966	validation_1-rmse:7.07348
# [1]	validation_0-rmse:7.01093	validation_1-rmse:6.40268
# [2]	validation_0-rmse:6.40232	validation_1-rmse:5.84766
# [3]	validation_0-rmse:5.84673	validation_1-rmse:5.34592
# [4]	validation_0-rmse:5.34587	validation_1-rmse:4.88878
# [5]	validation_0-rmse:4.88781	validation_1-rmse:4.46276
# [6]	validation_0-rmse:4.47238	validation_1-rmse:4.08969
# [7]	validation_0-rmse:4.09322	validation_1-rmse:3.73908
# [8]	validation_0-rmse:3.74621	validation_1-rmse:3.41422
# [9]	validation_0-rmse:3.43436	validation_1-rmse:3.10215
# [10]	validation_0-rmse:3.15162	validation_1-rmse:2.81971
# [11]	validation_0-rmse:2.90071	validation_1-rmse:2.56933
# [12]	validation_0-rmse:2.66476	validation_1-rmse:2.38467
# [13]	validation_0-rmse:2.46283	validation_1-rmse:2.17726
# [14]	validation_0-rmse:2.27042	validation_1-rmse:2.00307
# [15]	validation_0-rmse:2.09545	validation_1-rmse:1.84810
# [16]	validation_0-rmse:1.93406	validation_1-rmse:1.73333
# [17]	validation_0-rmse:1.79366	validation_1-rmse:1.63174
# [18]	validation_0-rmse:1.66381	validation_1-rmse:1.51493
# [19]	validation_0-rmse:1.54720	validation_1-rmse:1.41320
# [20]	validation_0-rmse:1.44375	validation_1-rmse:1.32542
# [21]	validation_0-rmse:1.34219	validation_1-rmse:1.26629
# [22]	validation_0-rmse:1.25210	validation_1-rmse:1.21043
# [23]	validation_0-rmse:1.17968	validation_1-rmse:1.14435
# [24]	validation_0-rmse:1.10923	validation_1-rmse:1.10577
# [25]	validation_0-rmse:1.04611	validation_1-rmse:1.07224
# [26]	validation_0-rmse:0.98838	validation_1-rmse:1.04329
# [27]	validation_0-rmse:0.93988	validation_1-rmse:1.01421
# [28]	validation_0-rmse:0.89210	validation_1-rmse:0.98602
# [29]	validation_0-rmse:0.85093	validation_1-rmse:0.96657
# [30]	validation_0-rmse:0.81659	validation_1-rmse:0.94866
# [31]	validation_0-rmse:0.78835	validation_1-rmse:0.93016
# [32]	validation_0-rmse:0.76235	validation_1-rmse:0.92688
# [33]	validation_0-rmse:0.73833	validation_1-rmse:0.91811
# [34]	validation_0-rmse:0.71604	validation_1-rmse:0.90353
# [35]	validation_0-rmse:0.69515	validation_1-rmse:0.89297
# [36]	validation_0-rmse:0.67746	validation_1-rmse:0.88420
# [37]	validation_0-rmse:0.66226	validation_1-rmse:0.88239
# [38]	validation_0-rmse:0.64840	validation_1-rmse:0.88203
# [39]	validation_0-rmse:0.63587	validation_1-rmse:0.87881
# [40]	validation_0-rmse:0.62458	validation_1-rmse:0.87795
# [41]	validation_0-rmse:0.61491	validation_1-rmse:0.87657
# [42]	validation_0-rmse:0.60473	validation_1-rmse:0.87973
# [43]	validation_0-rmse:0.59687	validation_1-rmse:0.87540
# [44]	validation_0-rmse:0.58890	validation_1-rmse:0.87349
# [45]	validation_0-rmse:0.58205	validation_1-rmse:0.87120
# [46]	validation_0-rmse:0.57582	validation_1-rmse:0.87119
# [47]	validation_0-rmse:0.56960	validation_1-rmse:0.87317
# [48]	validation_0-rmse:0.56470	validation_1-rmse:0.86944
# [49]	validation_0-rmse:0.55967	validation_1-rmse:0.86342
# [50]	validation_0-rmse:0.55497	validation_1-rmse:0.86163
# [51]	validation_0-rmse:0.55073	validation_1-rmse:0.86511
# [52]	validation_0-rmse:0.54641	validation_1-rmse:0.86491
# [53]	validation_0-rmse:0.54298	validation_1-rmse:0.86713
# [54]	validation_0-rmse:0.53974	validation_1-rmse:0.86626
# [0]	validation_0-rmse:7.70052	validation_1-rmse:6.95375
# [1]	validation_0-rmse:7.02513	validation_1-rmse:6.27203
# [2]	validation_0-rmse:6.40648	validation_1-rmse:5.68506
# [3]	validation_0-rmse:5.85159	validation_1-rmse:5.15537
# [4]	validation_0-rmse:5.34809	validation_1-rmse:4.67026
# [5]	validation_0-rmse:4.88839	validation_1-rmse:4.23521
# [6]	validation_0-rmse:4.47169	validation_1-rmse:3.84220
# [7]	validation_0-rmse:4.09994	validation_1-rmse:3.48594
# [8]	validation_0-rmse:3.75189	validation_1-rmse:3.15817
# [9]	validation_0-rmse:3.43757	validation_1-rmse:2.84476
# [10]	validation_0-rmse:3.15571	validation_1-rmse:2.56177
# [11]	validation_0-rmse:2.90440	validation_1-rmse:2.31104
# [12]	validation_0-rmse:2.67015	validation_1-rmse:2.09975
# [13]	validation_0-rmse:2.45945	validation_1-rmse:1.88295
# [14]	validation_0-rmse:2.26336	validation_1-rmse:1.70712
# [15]	validation_0-rmse:2.08501	validation_1-rmse:1.55026
# [16]	validation_0-rmse:1.92562	validation_1-rmse:1.41852
# [17]	validation_0-rmse:1.78068	validation_1-rmse:1.29273
# [18]	validation_0-rmse:1.64992	validation_1-rmse:1.18088
# [19]	validation_0-rmse:1.54048	validation_1-rmse:1.07701
# [20]	validation_0-rmse:1.43957	validation_1-rmse:0.97858
# [21]	validation_0-rmse:1.34575	validation_1-rmse:0.91203
# [22]	validation_0-rmse:1.26008	validation_1-rmse:0.85517
# [23]	validation_0-rmse:1.18745	validation_1-rmse:0.79781
# [24]	validation_0-rmse:1.11816	validation_1-rmse:0.75974
# [25]	validation_0-rmse:1.05564	validation_1-rmse:0.72592
# [26]	validation_0-rmse:1.00328	validation_1-rmse:0.70213
# [27]	validation_0-rmse:0.95298	validation_1-rmse:0.68655
# [28]	validation_0-rmse:0.91173	validation_1-rmse:0.67378
# [29]	validation_0-rmse:0.87449	validation_1-rmse:0.66365
# [30]	validation_0-rmse:0.84386	validation_1-rmse:0.66208
# [31]	validation_0-rmse:0.81475	validation_1-rmse:0.66160
# [32]	validation_0-rmse:0.78604	validation_1-rmse:0.66165
# [33]	validation_0-rmse:0.76091	validation_1-rmse:0.66273
# [34]	validation_0-rmse:0.74064	validation_1-rmse:0.66402
# [35]	validation_0-rmse:0.72452	validation_1-rmse:0.66811
# [36]	validation_0-rmse:0.70550	validation_1-rmse:0.67330
# [37]	validation_0-rmse:0.68611	validation_1-rmse:0.67002
# [38]	validation_0-rmse:0.67288	validation_1-rmse:0.67523
# [39]	validation_0-rmse:0.66443	validation_1-rmse:0.67769
# [40]	validation_0-rmse:0.65427	validation_1-rmse:0.67727
# [41]	validation_0-rmse:0.64391	validation_1-rmse:0.68145
# [42]	validation_0-rmse:0.63515	validation_1-rmse:0.69180
# [43]	validation_0-rmse:0.62702	validation_1-rmse:0.69630
# [44]	validation_0-rmse:0.61936	validation_1-rmse:0.70025
# [45]	validation_0-rmse:0.61280	validation_1-rmse:0.70769
# [46]	validation_0-rmse:0.60648	validation_1-rmse:0.71570
# [47]	validation_0-rmse:0.60105	validation_1-rmse:0.72090
# [48]	validation_0-rmse:0.59584	validation_1-rmse:0.72913
# [49]	validation_0-rmse:0.59121	validation_1-rmse:0.73315
# [50]	validation_0-rmse:0.58724	validation_1-rmse:0.73808
# [51]	validation_0-rmse:0.58279	validation_1-rmse:0.74179
# [0]	validation_0-rmse:7.66607	validation_1-rmse:7.13084
# [1]	validation_0-rmse:6.99735	validation_1-rmse:6.45666
# [2]	validation_0-rmse:6.38637	validation_1-rmse:5.88074
# [3]	validation_0-rmse:5.82996	validation_1-rmse:5.35503
# [4]	validation_0-rmse:5.32821	validation_1-rmse:4.87125
# [5]	validation_0-rmse:4.87137	validation_1-rmse:4.44254
# [6]	validation_0-rmse:4.45531	validation_1-rmse:4.04377
# [7]	validation_0-rmse:4.08064	validation_1-rmse:3.68882
# [8]	validation_0-rmse:3.73815	validation_1-rmse:3.33577
# [9]	validation_0-rmse:3.42919	validation_1-rmse:3.01622
# [10]	validation_0-rmse:3.14780	validation_1-rmse:2.72629
# [11]	validation_0-rmse:2.88858	validation_1-rmse:2.45597
# [12]	validation_0-rmse:2.65800	validation_1-rmse:2.24161
# [13]	validation_0-rmse:2.45312	validation_1-rmse:2.02946
# [14]	validation_0-rmse:2.26260	validation_1-rmse:1.84661
# [15]	validation_0-rmse:2.08803	validation_1-rmse:1.68947
# [16]	validation_0-rmse:1.93056	validation_1-rmse:1.55260
# [17]	validation_0-rmse:1.78736	validation_1-rmse:1.42476
# [18]	validation_0-rmse:1.66234	validation_1-rmse:1.30883
# [19]	validation_0-rmse:1.55073	validation_1-rmse:1.20011
# [20]	validation_0-rmse:1.45094	validation_1-rmse:1.10593
# [21]	validation_0-rmse:1.35648	validation_1-rmse:1.03182
# [22]	validation_0-rmse:1.26772	validation_1-rmse:0.96796
# [23]	validation_0-rmse:1.19516	validation_1-rmse:0.89824
# [24]	validation_0-rmse:1.12778	validation_1-rmse:0.84989
# [25]	validation_0-rmse:1.06445	validation_1-rmse:0.80973
# [26]	validation_0-rmse:1.01192	validation_1-rmse:0.77607
# [27]	validation_0-rmse:0.96713	validation_1-rmse:0.74799
# [28]	validation_0-rmse:0.92434	validation_1-rmse:0.72671
# [29]	validation_0-rmse:0.88814	validation_1-rmse:0.70900
# [30]	validation_0-rmse:0.85450	validation_1-rmse:0.69494
# [31]	validation_0-rmse:0.82469	validation_1-rmse:0.68450
# [32]	validation_0-rmse:0.79809	validation_1-rmse:0.67552
# [33]	validation_0-rmse:0.77318	validation_1-rmse:0.67429
# [34]	validation_0-rmse:0.75711	validation_1-rmse:0.66462
# [35]	validation_0-rmse:0.74103	validation_1-rmse:0.65829
# [36]	validation_0-rmse:0.72498	validation_1-rmse:0.65587
# [37]	validation_0-rmse:0.71045	validation_1-rmse:0.65441
# [38]	validation_0-rmse:0.69491	validation_1-rmse:0.64315
# [39]	validation_0-rmse:0.68354	validation_1-rmse:0.64254
# [40]	validation_0-rmse:0.67539	validation_1-rmse:0.63834
# [41]	validation_0-rmse:0.66688	validation_1-rmse:0.64285
# [42]	validation_0-rmse:0.65901	validation_1-rmse:0.63982
# [43]	validation_0-rmse:0.64327	validation_1-rmse:0.63245
# [44]	validation_0-rmse:0.62894	validation_1-rmse:0.62311
# [45]	validation_0-rmse:0.62261	validation_1-rmse:0.62098
# [46]	validation_0-rmse:0.61623	validation_1-rmse:0.62236
# [47]	validation_0-rmse:0.61112	validation_1-rmse:0.62498
# [48]	validation_0-rmse:0.60631	validation_1-rmse:0.62737
# [49]	validation_0-rmse:0.60192	validation_1-rmse:0.62863
# [50]	validation_0-rmse:0.59816	validation_1-rmse:0.63096
# [51]	validation_0-rmse:0.58771	validation_1-rmse:0.62424
# [52]	validation_0-rmse:0.58446	validation_1-rmse:0.62365
# [53]	validation_0-rmse:0.57996	validation_1-rmse:0.63121
# [54]	validation_0-rmse:0.57702	validation_1-rmse:0.63221
# [0]	validation_0-rmse:7.52983	validation_1-rmse:7.70102
# [1]	validation_0-rmse:6.87565	validation_1-rmse:7.06449
# [2]	validation_0-rmse:6.27948	validation_1-rmse:6.47211
# [3]	validation_0-rmse:5.73347	validation_1-rmse:5.93765
# [4]	validation_0-rmse:5.25002	validation_1-rmse:5.46139
# [5]	validation_0-rmse:4.79957	validation_1-rmse:5.01147
# [6]	validation_0-rmse:4.38777	validation_1-rmse:4.59516
# [7]	validation_0-rmse:4.01479	validation_1-rmse:4.22324
# [8]	validation_0-rmse:3.67626	validation_1-rmse:3.88445
# [9]	validation_0-rmse:3.37093	validation_1-rmse:3.59180
# [10]	validation_0-rmse:3.09179	validation_1-rmse:3.32464
# [11]	validation_0-rmse:2.83792	validation_1-rmse:3.07914
# [12]	validation_0-rmse:2.61783	validation_1-rmse:2.86873
# [13]	validation_0-rmse:2.41635	validation_1-rmse:2.66940
# [14]	validation_0-rmse:2.23673	validation_1-rmse:2.49057
# [15]	validation_0-rmse:2.06076	validation_1-rmse:2.30780
# [16]	validation_0-rmse:1.90383	validation_1-rmse:2.14025
# [17]	validation_0-rmse:1.76002	validation_1-rmse:1.99584
# [18]	validation_0-rmse:1.63027	validation_1-rmse:1.86898
# [19]	validation_0-rmse:1.51360	validation_1-rmse:1.74397
# [20]	validation_0-rmse:1.41290	validation_1-rmse:1.65148
# [21]	validation_0-rmse:1.31802	validation_1-rmse:1.55275
# [22]	validation_0-rmse:1.23430	validation_1-rmse:1.47126
# [23]	validation_0-rmse:1.16202	validation_1-rmse:1.39591
# [24]	validation_0-rmse:1.09234	validation_1-rmse:1.32364
# [25]	validation_0-rmse:1.03301	validation_1-rmse:1.26324
# [26]	validation_0-rmse:0.97940	validation_1-rmse:1.20760
# [27]	validation_0-rmse:0.93313	validation_1-rmse:1.16052
# [28]	validation_0-rmse:0.89062	validation_1-rmse:1.11634
# [29]	validation_0-rmse:0.84885	validation_1-rmse:1.07529
# [30]	validation_0-rmse:0.81417	validation_1-rmse:1.04356
# [31]	validation_0-rmse:0.78326	validation_1-rmse:1.01178
# [32]	validation_0-rmse:0.75765	validation_1-rmse:0.99088
# [33]	validation_0-rmse:0.73571	validation_1-rmse:0.97365
# [34]	validation_0-rmse:0.71409	validation_1-rmse:0.95465
# [35]	validation_0-rmse:0.69482	validation_1-rmse:0.94229
# [36]	validation_0-rmse:0.67775	validation_1-rmse:0.93217
# [37]	validation_0-rmse:0.66269	validation_1-rmse:0.92074
# [38]	validation_0-rmse:0.65042	validation_1-rmse:0.91412
# [39]	validation_0-rmse:0.63681	validation_1-rmse:0.89680
# [40]	validation_0-rmse:0.62598	validation_1-rmse:0.88760
# [41]	validation_0-rmse:0.61742	validation_1-rmse:0.88405
# [42]	validation_0-rmse:0.60962	validation_1-rmse:0.88150
# [43]	validation_0-rmse:0.60150	validation_1-rmse:0.87393
# [44]	validation_0-rmse:0.59423	validation_1-rmse:0.86864
# [45]	validation_0-rmse:0.58805	validation_1-rmse:0.86464
# [46]	validation_0-rmse:0.58258	validation_1-rmse:0.86062
# [47]	validation_0-rmse:0.57732	validation_1-rmse:0.85670
# [48]	validation_0-rmse:0.57087	validation_1-rmse:0.85293
# [49]	validation_0-rmse:0.56619	validation_1-rmse:0.84887
# [50]	validation_0-rmse:0.55998	validation_1-rmse:0.84670
# [51]	validation_0-rmse:0.55446	validation_1-rmse:0.84403
# [52]	validation_0-rmse:0.55134	validation_1-rmse:0.84315
# [53]	validation_0-rmse:0.54671	validation_1-rmse:0.83965
# [54]	validation_0-rmse:0.54256	validation_1-rmse:0.83700
# [0]	validation_0-rmse:7.57297	validation_1-rmse:7.50805
# [1]	validation_0-rmse:6.91611	validation_1-rmse:6.84297
# [2]	validation_0-rmse:6.31774	validation_1-rmse:6.27711
# [3]	validation_0-rmse:5.76764	validation_1-rmse:5.72900
# [4]	validation_0-rmse:5.27383	validation_1-rmse:5.26174
# [5]	validation_0-rmse:4.82144	validation_1-rmse:4.80965
# [6]	validation_0-rmse:4.41264	validation_1-rmse:4.42277
# [7]	validation_0-rmse:4.03787	validation_1-rmse:4.06237
# [8]	validation_0-rmse:3.70022	validation_1-rmse:3.72241
# [9]	validation_0-rmse:3.39408	validation_1-rmse:3.41061
# [10]	validation_0-rmse:3.11508	validation_1-rmse:3.13132
# [11]	validation_0-rmse:2.86602	validation_1-rmse:2.87344
# [12]	validation_0-rmse:2.63378	validation_1-rmse:2.65190
# [13]	validation_0-rmse:2.42741	validation_1-rmse:2.43621
# [14]	validation_0-rmse:2.23498	validation_1-rmse:2.26301
# [15]	validation_0-rmse:2.06988	validation_1-rmse:2.10566
# [16]	validation_0-rmse:1.91278	validation_1-rmse:1.95066
# [17]	validation_0-rmse:1.76952	validation_1-rmse:1.81021
# [18]	validation_0-rmse:1.64475	validation_1-rmse:1.68858
# [19]	validation_0-rmse:1.53193	validation_1-rmse:1.56594
# [20]	validation_0-rmse:1.43189	validation_1-rmse:1.45618
# [21]	validation_0-rmse:1.34238	validation_1-rmse:1.36396
# [22]	validation_0-rmse:1.25534	validation_1-rmse:1.28033
# [23]	validation_0-rmse:1.18683	validation_1-rmse:1.21101
# [24]	validation_0-rmse:1.12230	validation_1-rmse:1.14369
# [25]	validation_0-rmse:1.06147	validation_1-rmse:1.08081
# [26]	validation_0-rmse:1.00613	validation_1-rmse:1.02578
# [27]	validation_0-rmse:0.96041	validation_1-rmse:0.98241
# [28]	validation_0-rmse:0.92360	validation_1-rmse:0.93632
# [29]	validation_0-rmse:0.88692	validation_1-rmse:0.89265
# [30]	validation_0-rmse:0.85324	validation_1-rmse:0.85695
# [31]	validation_0-rmse:0.82487	validation_1-rmse:0.83020
# [32]	validation_0-rmse:0.79768	validation_1-rmse:0.80011
# [33]	validation_0-rmse:0.77473	validation_1-rmse:0.77511
# [34]	validation_0-rmse:0.75495	validation_1-rmse:0.75167
# [35]	validation_0-rmse:0.73774	validation_1-rmse:0.73690
# [36]	validation_0-rmse:0.72211	validation_1-rmse:0.72280
# [37]	validation_0-rmse:0.70742	validation_1-rmse:0.70782
# [38]	validation_0-rmse:0.69490	validation_1-rmse:0.69792
# [39]	validation_0-rmse:0.68433	validation_1-rmse:0.69144
# [40]	validation_0-rmse:0.67486	validation_1-rmse:0.67617
# [41]	validation_0-rmse:0.66511	validation_1-rmse:0.66943
# [42]	validation_0-rmse:0.65843	validation_1-rmse:0.66208
# [43]	validation_0-rmse:0.65055	validation_1-rmse:0.65346
# [44]	validation_0-rmse:0.64279	validation_1-rmse:0.64820
# [45]	validation_0-rmse:0.63280	validation_1-rmse:0.64250
# [46]	validation_0-rmse:0.62647	validation_1-rmse:0.63988
# [47]	validation_0-rmse:0.62105	validation_1-rmse:0.63654
# [48]	validation_0-rmse:0.61647	validation_1-rmse:0.63991
# [49]	validation_0-rmse:0.61161	validation_1-rmse:0.63964
# [50]	validation_0-rmse:0.60658	validation_1-rmse:0.63710
# [51]	validation_0-rmse:0.59544	validation_1-rmse:0.62825
# [52]	validation_0-rmse:0.59150	validation_1-rmse:0.62507
# [53]	validation_0-rmse:0.58605	validation_1-rmse:0.62126
# [54]	validation_0-rmse:0.58076	validation_1-rmse:0.62195
# [0]	validation_0-rmse:7.51159	validation_1-rmse:7.74640
# [1]	validation_0-rmse:6.85868	validation_1-rmse:7.08659
# [2]	validation_0-rmse:6.26466	validation_1-rmse:6.47766
# [3]	validation_0-rmse:5.72380	validation_1-rmse:5.92225
# [4]	validation_0-rmse:5.23311	validation_1-rmse:5.41840
# [5]	validation_0-rmse:4.78951	validation_1-rmse:4.97192
# [6]	validation_0-rmse:4.38303	validation_1-rmse:4.56643
# [7]	validation_0-rmse:4.01538	validation_1-rmse:4.19700
# [8]	validation_0-rmse:3.68136	validation_1-rmse:3.85197
# [9]	validation_0-rmse:3.37537	validation_1-rmse:3.52705
# [10]	validation_0-rmse:3.10032	validation_1-rmse:3.23542
# [11]	validation_0-rmse:2.85044	validation_1-rmse:2.97204
# [12]	validation_0-rmse:2.63650	validation_1-rmse:2.75542
# [13]	validation_0-rmse:2.43837	validation_1-rmse:2.55468
# [14]	validation_0-rmse:2.24747	validation_1-rmse:2.35394
# [15]	validation_0-rmse:2.07035	validation_1-rmse:2.17026
# [16]	validation_0-rmse:1.90868	validation_1-rmse:2.00375
# [17]	validation_0-rmse:1.76494	validation_1-rmse:1.85518
# [18]	validation_0-rmse:1.63636	validation_1-rmse:1.71825
# [19]	validation_0-rmse:1.52986	validation_1-rmse:1.60034
# [20]	validation_0-rmse:1.42950	validation_1-rmse:1.49786
# [21]	validation_0-rmse:1.33643	validation_1-rmse:1.40937
# [22]	validation_0-rmse:1.24980	validation_1-rmse:1.32093
# [23]	validation_0-rmse:1.17959	validation_1-rmse:1.25117
# [24]	validation_0-rmse:1.11093	validation_1-rmse:1.18487
# [25]	validation_0-rmse:1.04558	validation_1-rmse:1.13017
# [26]	validation_0-rmse:0.99057	validation_1-rmse:1.08116
# [27]	validation_0-rmse:0.93887	validation_1-rmse:1.03247
# [28]	validation_0-rmse:0.89364	validation_1-rmse:0.99032
# [29]	validation_0-rmse:0.85824	validation_1-rmse:0.96323
# [30]	validation_0-rmse:0.82341	validation_1-rmse:0.92999
# [31]	validation_0-rmse:0.79282	validation_1-rmse:0.90505
# [32]	validation_0-rmse:0.76621	validation_1-rmse:0.88115
# [33]	validation_0-rmse:0.74275	validation_1-rmse:0.86905
# [34]	validation_0-rmse:0.72499	validation_1-rmse:0.85933
# [35]	validation_0-rmse:0.70672	validation_1-rmse:0.84712
# [36]	validation_0-rmse:0.68932	validation_1-rmse:0.83345
# [37]	validation_0-rmse:0.67180	validation_1-rmse:0.83146
# [38]	validation_0-rmse:0.65772	validation_1-rmse:0.82067
# [39]	validation_0-rmse:0.64790	validation_1-rmse:0.81670
# [40]	validation_0-rmse:0.63635	validation_1-rmse:0.81412
# [41]	validation_0-rmse:0.62621	validation_1-rmse:0.81431
# [42]	validation_0-rmse:0.61728	validation_1-rmse:0.80957
# [43]	validation_0-rmse:0.60875	validation_1-rmse:0.81073
# [44]	validation_0-rmse:0.60106	validation_1-rmse:0.80634
# [45]	validation_0-rmse:0.59301	validation_1-rmse:0.80683
# [46]	validation_0-rmse:0.58737	validation_1-rmse:0.80543
# [47]	validation_0-rmse:0.58179	validation_1-rmse:0.80807
# [48]	validation_0-rmse:0.57688	validation_1-rmse:0.80878
# [49]	validation_0-rmse:0.57175	validation_1-rmse:0.80730
# [50]	validation_0-rmse:0.55996	validation_1-rmse:0.80553
# [51]	validation_0-rmse:0.55584	validation_1-rmse:0.80318
# [52]	validation_0-rmse:0.55232	validation_1-rmse:0.80902
# [53]	validation_0-rmse:0.54662	validation_1-rmse:0.80809
# [54]	validation_0-rmse:0.54230	validation_1-rmse:0.81034
# [0]	validation_0-rmse:7.32744	validation_1-rmse:8.49591
# [1]	validation_0-rmse:6.68545	validation_1-rmse:7.85555
# [2]	validation_0-rmse:6.09791	validation_1-rmse:7.24416
# [3]	validation_0-rmse:5.56642	validation_1-rmse:6.69088
# [4]	validation_0-rmse:5.08353	validation_1-rmse:6.18880
# [5]	validation_0-rmse:4.64048	validation_1-rmse:5.72835
# [6]	validation_0-rmse:4.24111	validation_1-rmse:5.31334
# [7]	validation_0-rmse:3.88381	validation_1-rmse:4.94245
# [8]	validation_0-rmse:3.55507	validation_1-rmse:4.59108
# [9]	validation_0-rmse:3.26027	validation_1-rmse:4.29692
# [10]	validation_0-rmse:2.99092	validation_1-rmse:4.00690
# [11]	validation_0-rmse:2.75489	validation_1-rmse:3.76476
# [12]	validation_0-rmse:2.53591	validation_1-rmse:3.52594
# [13]	validation_0-rmse:2.33477	validation_1-rmse:3.30975
# [14]	validation_0-rmse:2.14842	validation_1-rmse:3.10926
# [15]	validation_0-rmse:1.97951	validation_1-rmse:2.91825
# [16]	validation_0-rmse:1.82875	validation_1-rmse:2.75468
# [17]	validation_0-rmse:1.69254	validation_1-rmse:2.61156
# [18]	validation_0-rmse:1.56702	validation_1-rmse:2.46781
# [19]	validation_0-rmse:1.45752	validation_1-rmse:2.36375
# [20]	validation_0-rmse:1.35926	validation_1-rmse:2.25561
# [21]	validation_0-rmse:1.26557	validation_1-rmse:2.13897
# [22]	validation_0-rmse:1.18223	validation_1-rmse:2.04239
# [23]	validation_0-rmse:1.11276	validation_1-rmse:1.96349
# [24]	validation_0-rmse:1.04570	validation_1-rmse:1.87881
# [25]	validation_0-rmse:0.98712	validation_1-rmse:1.79654
# [26]	validation_0-rmse:0.93353	validation_1-rmse:1.72049
# [27]	validation_0-rmse:0.88566	validation_1-rmse:1.65700
# [28]	validation_0-rmse:0.84365	validation_1-rmse:1.59419
# [29]	validation_0-rmse:0.80717	validation_1-rmse:1.54716
# [30]	validation_0-rmse:0.77609	validation_1-rmse:1.50098
# [31]	validation_0-rmse:0.74991	validation_1-rmse:1.45526
# [32]	validation_0-rmse:0.72708	validation_1-rmse:1.41221
# [33]	validation_0-rmse:0.70685	validation_1-rmse:1.38048
# [34]	validation_0-rmse:0.68738	validation_1-rmse:1.35088
# [35]	validation_0-rmse:0.66993	validation_1-rmse:1.32106
# [36]	validation_0-rmse:0.64799	validation_1-rmse:1.29963
# [37]	validation_0-rmse:0.63563	validation_1-rmse:1.27407
# [38]	validation_0-rmse:0.62263	validation_1-rmse:1.25227
# [39]	validation_0-rmse:0.61415	validation_1-rmse:1.23325
# [40]	validation_0-rmse:0.60106	validation_1-rmse:1.22441
# [41]	validation_0-rmse:0.58591	validation_1-rmse:1.21096
# [42]	validation_0-rmse:0.57815	validation_1-rmse:1.20049
# [43]	validation_0-rmse:0.57187	validation_1-rmse:1.18098
# [44]	validation_0-rmse:0.55835	validation_1-rmse:1.17296
# [45]	validation_0-rmse:0.55104	validation_1-rmse:1.16282
# [46]	validation_0-rmse:0.54559	validation_1-rmse:1.15197
# [47]	validation_0-rmse:0.53607	validation_1-rmse:1.14215
# [48]	validation_0-rmse:0.53198	validation_1-rmse:1.12979
# [49]	validation_0-rmse:0.52685	validation_1-rmse:1.12068
# [50]	validation_0-rmse:0.52297	validation_1-rmse:1.10845
# [51]	validation_0-rmse:0.51987	validation_1-rmse:1.10031
# [52]	validation_0-rmse:0.51200	validation_1-rmse:1.09910
# [53]	validation_0-rmse:0.50854	validation_1-rmse:1.09574
# [54]	validation_0-rmse:0.50552	validation_1-rmse:1.08639
# [0]	validation_0-rmse:7.60904	validation_1-rmse:7.35214
# [1]	validation_0-rmse:6.95414	validation_1-rmse:6.70038
# [2]	validation_0-rmse:6.34753	validation_1-rmse:6.11225
# [3]	validation_0-rmse:5.79296	validation_1-rmse:5.57545
# [4]	validation_0-rmse:5.29414	validation_1-rmse:5.09646
# [5]	validation_0-rmse:4.83720	validation_1-rmse:4.65557
# [6]	validation_0-rmse:4.41889	validation_1-rmse:4.24650
# [7]	validation_0-rmse:4.03726	validation_1-rmse:3.88021
# [8]	validation_0-rmse:3.69550	validation_1-rmse:3.55485
# [9]	validation_0-rmse:3.38566	validation_1-rmse:3.24147
# [10]	validation_0-rmse:3.11221	validation_1-rmse:2.96660
# [11]	validation_0-rmse:2.86032	validation_1-rmse:2.71048
# [12]	validation_0-rmse:2.62897	validation_1-rmse:2.49253
# [13]	validation_0-rmse:2.42105	validation_1-rmse:2.28552
# [14]	validation_0-rmse:2.22745	validation_1-rmse:2.09890
# [15]	validation_0-rmse:2.05302	validation_1-rmse:1.93195
# [16]	validation_0-rmse:1.89827	validation_1-rmse:1.79164
# [17]	validation_0-rmse:1.75426	validation_1-rmse:1.66175
# [18]	validation_0-rmse:1.62505	validation_1-rmse:1.54588
# [19]	validation_0-rmse:1.51374	validation_1-rmse:1.43553
# [20]	validation_0-rmse:1.41262	validation_1-rmse:1.33477
# [21]	validation_0-rmse:1.32119	validation_1-rmse:1.25774
# [22]	validation_0-rmse:1.23688	validation_1-rmse:1.18476
# [23]	validation_0-rmse:1.16301	validation_1-rmse:1.12684
# [24]	validation_0-rmse:1.09262	validation_1-rmse:1.06882
# [25]	validation_0-rmse:1.03284	validation_1-rmse:1.02201
# [26]	validation_0-rmse:0.97604	validation_1-rmse:0.97394
# [27]	validation_0-rmse:0.92528	validation_1-rmse:0.93090
# ...
# [49]	validation_0-rmse:0.58939	validation_1-rmse:0.73899
# [50]	validation_0-rmse:0.58195	validation_1-rmse:0.73676
# [51]	validation_0-rmse:0.57783	validation_1-rmse:0.73746
# [52]	validation_0-rmse:0.57287	validation_1-rmse:0.74047
# [53]	validation_0-rmse:0.56828	validation_1-rmse:0.74530
# [54]	validation_0-rmse:0.56491	validation_1-rmse:0.74432
# [0]	validation_0-rmse:7.52290	validation_1-rmse:7.65506
# [1]	validation_0-rmse:6.86463	validation_1-rmse:6.99286
# [2]	validation_0-rmse:6.26400	validation_1-rmse:6.36724
# [3]	validation_0-rmse:5.72347	validation_1-rmse:5.80373
# [4]	validation_0-rmse:5.22931	validation_1-rmse:5.29930
# [5]	validation_0-rmse:4.77994	validation_1-rmse:4.83754
# [6]	validation_0-rmse:4.37123	validation_1-rmse:4.40881
# [7]	validation_0-rmse:4.00264	validation_1-rmse:4.02933
# [8]	validation_0-rmse:3.66639	validation_1-rmse:3.68650
# [9]	validation_0-rmse:3.36217	validation_1-rmse:3.35966
# [10]	validation_0-rmse:3.08631	validation_1-rmse:3.06327
# [11]	validation_0-rmse:2.82996	validation_1-rmse:2.79395
# [12]	validation_0-rmse:2.60621	validation_1-rmse:2.55545
# [13]	validation_0-rmse:2.40289	validation_1-rmse:2.33217
# [14]	validation_0-rmse:2.22140	validation_1-rmse:2.14300
# [15]	validation_0-rmse:2.04813	validation_1-rmse:1.96475
# [16]	validation_0-rmse:1.89923	validation_1-rmse:1.81307
# [17]	validation_0-rmse:1.75646	validation_1-rmse:1.66141
# [18]	validation_0-rmse:1.63617	validation_1-rmse:1.53645
# [19]	validation_0-rmse:1.52606	validation_1-rmse:1.41418
# [20]	validation_0-rmse:1.42611	validation_1-rmse:1.30402
# [21]	validation_0-rmse:1.33423	validation_1-rmse:1.20700
# [22]	validation_0-rmse:1.25022	validation_1-rmse:1.11978
# [23]	validation_0-rmse:1.17987	validation_1-rmse:1.05417
# [24]	validation_0-rmse:1.11254	validation_1-rmse:0.98976
# [25]	validation_0-rmse:1.05300	validation_1-rmse:0.93698
# [26]	validation_0-rmse:1.00002	validation_1-rmse:0.89120
# [27]	validation_0-rmse:0.95094	validation_1-rmse:0.84947
# [28]	validation_0-rmse:0.90862	validation_1-rmse:0.81966
# [29]	validation_0-rmse:0.87112	validation_1-rmse:0.79177
# [30]	validation_0-rmse:0.83735	validation_1-rmse:0.77241
# [31]	validation_0-rmse:0.81083	validation_1-rmse:0.75935
# [32]	validation_0-rmse:0.78623	validation_1-rmse:0.74507
# [33]	validation_0-rmse:0.76381	validation_1-rmse:0.73168
# [34]	validation_0-rmse:0.74661	validation_1-rmse:0.72721
# [35]	validation_0-rmse:0.72798	validation_1-rmse:0.71894
# [36]	validation_0-rmse:0.71215	validation_1-rmse:0.71482
# [37]	validation_0-rmse:0.69833	validation_1-rmse:0.70974
# [38]	validation_0-rmse:0.68620	validation_1-rmse:0.70903
# [39]	validation_0-rmse:0.67510	validation_1-rmse:0.70889
# [40]	validation_0-rmse:0.66696	validation_1-rmse:0.70903
# [41]	validation_0-rmse:0.65883	validation_1-rmse:0.70585
# [42]	validation_0-rmse:0.64992	validation_1-rmse:0.70391
# [43]	validation_0-rmse:0.64168	validation_1-rmse:0.70251
# [44]	validation_0-rmse:0.63223	validation_1-rmse:0.70033
# [45]	validation_0-rmse:0.61952	validation_1-rmse:0.69718
# [46]	validation_0-rmse:0.61446	validation_1-rmse:0.69765
# [47]	validation_0-rmse:0.60926	validation_1-rmse:0.69779
# [48]	validation_0-rmse:0.60373	validation_1-rmse:0.70285
# [49]	validation_0-rmse:0.59762	validation_1-rmse:0.70302
# [50]	validation_0-rmse:0.59349	validation_1-rmse:0.70334
# [51]	validation_0-rmse:0.58445	validation_1-rmse:0.70733
# [52]	validation_0-rmse:0.57574	validation_1-rmse:0.70811
# [53]	validation_0-rmse:0.57021	validation_1-rmse:0.71109
# [54]	validation_0-rmse:0.56715	validation_1-rmse:0.71116
# [0]	validation_0-rmse:7.55982	validation_1-rmse:7.54806
# [1]	validation_0-rmse:6.89887	validation_1-rmse:6.88015
# [2]	validation_0-rmse:6.29674	validation_1-rmse:6.25048
# [3]	validation_0-rmse:5.74873	validation_1-rmse:5.73134
# [4]	validation_0-rmse:5.24814	validation_1-rmse:5.20543
# [5]	validation_0-rmse:4.80049	validation_1-rmse:4.78101
# [6]	validation_0-rmse:4.39511	validation_1-rmse:4.39242
# [7]	validation_0-rmse:4.02926	validation_1-rmse:4.04531
# [8]	validation_0-rmse:3.68912	validation_1-rmse:3.68032
# [9]	validation_0-rmse:3.38087	validation_1-rmse:3.35913
# [10]	validation_0-rmse:3.10539	validation_1-rmse:3.06066
# [11]	validation_0-rmse:2.86155	validation_1-rmse:2.78743
# [12]	validation_0-rmse:2.62677	validation_1-rmse:2.56004
# [13]	validation_0-rmse:2.41856	validation_1-rmse:2.33774
# [14]	validation_0-rmse:2.22616	validation_1-rmse:2.15477
# [15]	validation_0-rmse:2.05344	validation_1-rmse:1.99688
# [16]	validation_0-rmse:1.89844	validation_1-rmse:1.84937
# [17]	validation_0-rmse:1.76231	validation_1-rmse:1.71659
# [18]	validation_0-rmse:1.63718	validation_1-rmse:1.59212
# [19]	validation_0-rmse:1.52464	validation_1-rmse:1.46944
# [20]	validation_0-rmse:1.42626	validation_1-rmse:1.35792
# [21]	validation_0-rmse:1.33148	validation_1-rmse:1.27483
# [22]	validation_0-rmse:1.24457	validation_1-rmse:1.18225
# [23]	validation_0-rmse:1.17105	validation_1-rmse:1.10709
# [24]	validation_0-rmse:1.10430	validation_1-rmse:1.04196
# [25]	validation_0-rmse:1.04478	validation_1-rmse:0.98437
# [26]	validation_0-rmse:0.99117	validation_1-rmse:0.92645
# [27]	validation_0-rmse:0.94006	validation_1-rmse:0.88103
# [28]	validation_0-rmse:0.89802	validation_1-rmse:0.84126
# [29]	validation_0-rmse:0.86154	validation_1-rmse:0.80677
# [30]	validation_0-rmse:0.82992	validation_1-rmse:0.77820
# [31]	validation_0-rmse:0.80135	validation_1-rmse:0.75237
# [32]	validation_0-rmse:0.77517	validation_1-rmse:0.72931
# [33]	validation_0-rmse:0.75374	validation_1-rmse:0.72082
# [34]	validation_0-rmse:0.73528	validation_1-rmse:0.70499
# [35]	validation_0-rmse:0.71560	validation_1-rmse:0.69666
# [36]	validation_0-rmse:0.69949	validation_1-rmse:0.68566
# [37]	validation_0-rmse:0.68572	validation_1-rmse:0.67636
# [38]	validation_0-rmse:0.66455	validation_1-rmse:0.66699
# [39]	validation_0-rmse:0.65184	validation_1-rmse:0.66530
# [40]	validation_0-rmse:0.64118	validation_1-rmse:0.65881
# [41]	validation_0-rmse:0.63182	validation_1-rmse:0.65978
# [42]	validation_0-rmse:0.62282	validation_1-rmse:0.65870
# [43]	validation_0-rmse:0.60792	validation_1-rmse:0.65357
# [44]	validation_0-rmse:0.60103	validation_1-rmse:0.65152
# [45]	validation_0-rmse:0.59420	validation_1-rmse:0.65119
# [46]	validation_0-rmse:0.58719	validation_1-rmse:0.65100
# [47]	validation_0-rmse:0.58224	validation_1-rmse:0.64887
# [48]	validation_0-rmse:0.57575	validation_1-rmse:0.65331
# [49]	validation_0-rmse:0.57146	validation_1-rmse:0.65261
# [50]	validation_0-rmse:0.56792	validation_1-rmse:0.65211
# [51]	validation_0-rmse:0.56447	validation_1-rmse:0.65329
# [52]	validation_0-rmse:0.55724	validation_1-rmse:0.65143
# [53]	validation_0-rmse:0.55605	validation_1-rmse:0.65059
# [54]	validation_0-rmse:0.54783	validation_1-rmse:0.64935
# [0]	validation_0-rmse:7.64147	validation_1-rmse:7.16230
# [1]	validation_0-rmse:6.97295	validation_1-rmse:6.48813
# [2]	validation_0-rmse:6.36631	validation_1-rmse:5.88652
# [3]	validation_0-rmse:5.81583	validation_1-rmse:5.34031
# [4]	validation_0-rmse:5.31263	validation_1-rmse:4.84121
# [5]	validation_0-rmse:4.86157	validation_1-rmse:4.39417
# [6]	validation_0-rmse:4.44631	validation_1-rmse:3.98313
# [7]	validation_0-rmse:4.06660	validation_1-rmse:3.61331
# [8]	validation_0-rmse:3.72390	validation_1-rmse:3.28131
# [9]	validation_0-rmse:3.40985	validation_1-rmse:2.97975
# [10]	validation_0-rmse:3.12801	validation_1-rmse:2.71504
# [11]	validation_0-rmse:2.87537	validation_1-rmse:2.47460
# [12]	validation_0-rmse:2.63758	validation_1-rmse:2.24185
# [13]	validation_0-rmse:2.43474	validation_1-rmse:2.04025
# [14]	validation_0-rmse:2.24241	validation_1-rmse:1.86641
# [15]	validation_0-rmse:2.06747	validation_1-rmse:1.71341
# [16]	validation_0-rmse:1.90749	validation_1-rmse:1.56271
# [17]	validation_0-rmse:1.76726	validation_1-rmse:1.43825
# [18]	validation_0-rmse:1.64015	validation_1-rmse:1.32093
# [19]	validation_0-rmse:1.52279	validation_1-rmse:1.21752
# [20]	validation_0-rmse:1.41933	validation_1-rmse:1.13299
# [21]	validation_0-rmse:1.32294	validation_1-rmse:1.06040
# [22]	validation_0-rmse:1.23922	validation_1-rmse:0.99388
# [23]	validation_0-rmse:1.16785	validation_1-rmse:0.94290
# [24]	validation_0-rmse:1.09966	validation_1-rmse:0.89763
# [25]	validation_0-rmse:1.03833	validation_1-rmse:0.85215
# [26]	validation_0-rmse:0.98554	validation_1-rmse:0.82200
# [27]	validation_0-rmse:0.93799	validation_1-rmse:0.79247
# [28]	validation_0-rmse:0.89385	validation_1-rmse:0.76949
# [29]	validation_0-rmse:0.85520	validation_1-rmse:0.75237
# [30]	validation_0-rmse:0.82085	validation_1-rmse:0.73870
# [31]	validation_0-rmse:0.78722	validation_1-rmse:0.72502
# [32]	validation_0-rmse:0.76236	validation_1-rmse:0.71863
# [33]	validation_0-rmse:0.73826	validation_1-rmse:0.71354
# [34]	validation_0-rmse:0.71794	validation_1-rmse:0.71391
# [35]	validation_0-rmse:0.70083	validation_1-rmse:0.71679
# [36]	validation_0-rmse:0.68536	validation_1-rmse:0.71626
# [37]	validation_0-rmse:0.67209	validation_1-rmse:0.71818
# [38]	validation_0-rmse:0.66177	validation_1-rmse:0.72050
# [39]	validation_0-rmse:0.65012	validation_1-rmse:0.71542
# [40]	validation_0-rmse:0.63924	validation_1-rmse:0.71311
# [41]	validation_0-rmse:0.63013	validation_1-rmse:0.71875
# [42]	validation_0-rmse:0.62176	validation_1-rmse:0.72424
# [43]	validation_0-rmse:0.61373	validation_1-rmse:0.72709
# [44]	validation_0-rmse:0.60683	validation_1-rmse:0.72856
# [45]	validation_0-rmse:0.59449	validation_1-rmse:0.72845
# [46]	validation_0-rmse:0.58845	validation_1-rmse:0.73694
# [47]	validation_0-rmse:0.58352	validation_1-rmse:0.73887
# [48]	validation_0-rmse:0.57743	validation_1-rmse:0.74627
# [49]	validation_0-rmse:0.57386	validation_1-rmse:0.74722
# [50]	validation_0-rmse:0.57019	validation_1-rmse:0.74971
# [51]	validation_0-rmse:0.56634	validation_1-rmse:0.75129
# [52]	validation_0-rmse:0.56336	validation_1-rmse:0.75218
# [53]	validation_0-rmse:0.55932	validation_1-rmse:0.75512
# [54]	validation_0-rmse:0.54990	validation_1-rmse:0.75879
# [0]	validation_0-rmse:7.63054	validation_1-rmse:7.22535
# [1]	validation_0-rmse:6.96678	validation_1-rmse:6.55416
# [2]	validation_0-rmse:6.36512	validation_1-rmse:5.96718
# [3]	validation_0-rmse:5.81550	validation_1-rmse:5.43866
# [4]	validation_0-rmse:5.31894	validation_1-rmse:4.95452
# [5]	validation_0-rmse:4.86349	validation_1-rmse:4.51321
# [6]	validation_0-rmse:4.44576	validation_1-rmse:4.10942
# [7]	validation_0-rmse:4.06955	validation_1-rmse:3.75949
# [8]	validation_0-rmse:3.72952	validation_1-rmse:3.42842
# [9]	validation_0-rmse:3.41769	validation_1-rmse:3.11922
# [10]	validation_0-rmse:3.13452	validation_1-rmse:2.83852
# [11]	validation_0-rmse:2.87780	validation_1-rmse:2.58049
# [12]	validation_0-rmse:2.64141	validation_1-rmse:2.37254
# [13]	validation_0-rmse:2.43707	validation_1-rmse:2.16920
# [14]	validation_0-rmse:2.24545	validation_1-rmse:2.00404
# [15]	validation_0-rmse:2.06884	validation_1-rmse:1.83794
# [16]	validation_0-rmse:1.90881	validation_1-rmse:1.70116
# [17]	validation_0-rmse:1.76574	validation_1-rmse:1.58094
# [18]	validation_0-rmse:1.63583	validation_1-rmse:1.47663
# [19]	validation_0-rmse:1.52014	validation_1-rmse:1.37231
# [20]	validation_0-rmse:1.41942	validation_1-rmse:1.28024
# [21]	validation_0-rmse:1.32610	validation_1-rmse:1.20045
# [22]	validation_0-rmse:1.23945	validation_1-rmse:1.13814
# [23]	validation_0-rmse:1.16586	validation_1-rmse:1.08212
# [24]	validation_0-rmse:1.09599	validation_1-rmse:1.03132
# [25]	validation_0-rmse:1.03604	validation_1-rmse:0.99513
# [26]	validation_0-rmse:0.98301	validation_1-rmse:0.96998
# [27]	validation_0-rmse:0.93608	validation_1-rmse:0.93883
# [28]	validation_0-rmse:0.89298	validation_1-rmse:0.91350
# [29]	validation_0-rmse:0.85672	validation_1-rmse:0.89497
# [30]	validation_0-rmse:0.82204	validation_1-rmse:0.87534
# [31]	validation_0-rmse:0.79320	validation_1-rmse:0.85922
# [32]	validation_0-rmse:0.76672	validation_1-rmse:0.84719
# [33]	validation_0-rmse:0.74312	validation_1-rmse:0.83634
# [34]	validation_0-rmse:0.72397	validation_1-rmse:0.83649
# [35]	validation_0-rmse:0.70669	validation_1-rmse:0.82726
# [36]	validation_0-rmse:0.69070	validation_1-rmse:0.82290
# [37]	validation_0-rmse:0.67538	validation_1-rmse:0.82540
# [38]	validation_0-rmse:0.66221	validation_1-rmse:0.82288
# [39]	validation_0-rmse:0.65036	validation_1-rmse:0.81764
# [40]	validation_0-rmse:0.63806	validation_1-rmse:0.82226
# [41]	validation_0-rmse:0.62902	validation_1-rmse:0.82183
# [42]	validation_0-rmse:0.61890	validation_1-rmse:0.82278
# [43]	validation_0-rmse:0.60847	validation_1-rmse:0.82373
# [44]	validation_0-rmse:0.59924	validation_1-rmse:0.82138
# [45]	validation_0-rmse:0.59338	validation_1-rmse:0.82051
# [46]	validation_0-rmse:0.58753	validation_1-rmse:0.82558
# [47]	validation_0-rmse:0.58276	validation_1-rmse:0.83077
# [48]	validation_0-rmse:0.57789	validation_1-rmse:0.83216
# [49]	validation_0-rmse:0.57362	validation_1-rmse:0.83223
# [50]	validation_0-rmse:0.56845	validation_1-rmse:0.83265
# [51]	validation_0-rmse:0.55978	validation_1-rmse:0.82977
# [52]	validation_0-rmse:0.55629	validation_1-rmse:0.82942
# [53]	validation_0-rmse:0.55117	validation_1-rmse:0.83258
# [54]	validation_0-rmse:0.54819	validation_1-rmse:0.83235
# [0]	validation_0-rmse:7.60314	validation_1-rmse:7.40128
# [1]	validation_0-rmse:6.93651	validation_1-rmse:6.73722
# [2]	validation_0-rmse:6.32817	validation_1-rmse:6.12303
# [3]	validation_0-rmse:5.77810	validation_1-rmse:5.56910
# [4]	validation_0-rmse:5.28078	validation_1-rmse:5.06821
# [5]	validation_0-rmse:4.83084	validation_1-rmse:4.59469
# [6]	validation_0-rmse:4.42183	validation_1-rmse:4.16737
# [7]	validation_0-rmse:4.05025	validation_1-rmse:3.81540
# [8]	validation_0-rmse:3.71189	validation_1-rmse:3.46913
# [9]	validation_0-rmse:3.40146	validation_1-rmse:3.17607
# [10]	validation_0-rmse:3.12231	validation_1-rmse:2.92309
# [11]	validation_0-rmse:2.87287	validation_1-rmse:2.68770
# [12]	validation_0-rmse:2.64037	validation_1-rmse:2.44829
# [13]	validation_0-rmse:2.43586	validation_1-rmse:2.26689
# [14]	validation_0-rmse:2.24452	validation_1-rmse:2.06403
# [15]	validation_0-rmse:2.07144	validation_1-rmse:1.89597
# [16]	validation_0-rmse:1.91341	validation_1-rmse:1.74184
# [17]	validation_0-rmse:1.76915	validation_1-rmse:1.60483
# [18]	validation_0-rmse:1.64225	validation_1-rmse:1.47875
# [19]	validation_0-rmse:1.52800	validation_1-rmse:1.38700
# [20]	validation_0-rmse:1.42771	validation_1-rmse:1.30748
# [21]	validation_0-rmse:1.33311	validation_1-rmse:1.20557
# [22]	validation_0-rmse:1.24573	validation_1-rmse:1.11422
# [23]	validation_0-rmse:1.17358	validation_1-rmse:1.05953
# [24]	validation_0-rmse:1.10493	validation_1-rmse:0.99291
# [25]	validation_0-rmse:1.04315	validation_1-rmse:0.93874
# [26]	validation_0-rmse:0.99064	validation_1-rmse:0.89035
# [27]	validation_0-rmse:0.94330	validation_1-rmse:0.86639
# [28]	validation_0-rmse:0.90285	validation_1-rmse:0.83178
# [29]	validation_0-rmse:0.86478	validation_1-rmse:0.80755
# [30]	validation_0-rmse:0.83195	validation_1-rmse:0.78866
# [31]	validation_0-rmse:0.80404	validation_1-rmse:0.77460
# [32]	validation_0-rmse:0.77966	validation_1-rmse:0.75797
# [33]	validation_0-rmse:0.75440	validation_1-rmse:0.75455
# [34]	validation_0-rmse:0.73691	validation_1-rmse:0.74728
# [35]	validation_0-rmse:0.71916	validation_1-rmse:0.74324
# [36]	validation_0-rmse:0.70410	validation_1-rmse:0.74373
# [37]	validation_0-rmse:0.69197	validation_1-rmse:0.74538
# [38]	validation_0-rmse:0.67901	validation_1-rmse:0.74221
# [39]	validation_0-rmse:0.66765	validation_1-rmse:0.74661
# [40]	validation_0-rmse:0.65772	validation_1-rmse:0.75773
# [41]	validation_0-rmse:0.64757	validation_1-rmse:0.76114
# [42]	validation_0-rmse:0.63955	validation_1-rmse:0.76138
# [43]	validation_0-rmse:0.63187	validation_1-rmse:0.76069
# [44]	validation_0-rmse:0.62475	validation_1-rmse:0.76399
# [45]	validation_0-rmse:0.61812	validation_1-rmse:0.75995
# [46]	validation_0-rmse:0.61137	validation_1-rmse:0.76773
# [47]	validation_0-rmse:0.60632	validation_1-rmse:0.77029
# [48]	validation_0-rmse:0.60179	validation_1-rmse:0.77774
# [49]	validation_0-rmse:0.59697	validation_1-rmse:0.77384
# [50]	validation_0-rmse:0.58673	validation_1-rmse:0.76149
# [51]	validation_0-rmse:0.57794	validation_1-rmse:0.75523
# [52]	validation_0-rmse:0.57431	validation_1-rmse:0.75637
# [53]	validation_0-rmse:0.57038	validation_1-rmse:0.75720
# [54]	validation_0-rmse:0.56719	validation_1-rmse:0.75813

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 48.98, median: 52.0,
#  pred. interval (P(0.025)-P(0.975)): 33.0-54.0,
#  conf. interval (p-value=0.95): 46.763-52.873
# ***
# Aggregate bias statistic:
#  mean: -2.41, median: -1.945,
#  pred. interval (P(0.025)-P(0.975)): -10.355-2.87,
#  conf. interval (p-value=0.95): -3.581--0.775
# ***
# Aggregate RMSE statistic:
#  mean: 0.806, median: 0.796, pred. interval (P(0.025)-P(0.975)): 0.591-1.068,
#  conf. interval (p-value=0.95): 0.75-0.854
# ***
# Aggregate MSE statistic:
#  mean: 0.664, median: 0.634, pred. interval (P(0.025)-P(0.975)): 0.349-1.141,
#  conf. interval (p-value=0.95): 0.565-0.734
# ***
# Aggregate R^2 statistic:
#  mean: 0.64, median: 0.679, pred. interval (P(0.025)-P(0.975)): 0.299-0.816,
#  conf. interval (p-value=0.95): 0.609-0.712
# ***
# Aggregate bias(%) statistic:
#  mean: -0.273, median: -1.945, pred. interval (P(0.025)-P(0.975)): -1.157-0.339,
#  conf. interval (p-value=0.95): -0.409--0.09
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.093, median: 0.091, pred. interval (P(0.025)-P(0.975)): 0.069-0.123,
#  conf. interval (p-value=0.95): 0.086-0.098
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:7.55807
# [1]	validation_0-rmse:6.89768
# [2]	validation_0-rmse:6.28872
# [3]	validation_0-rmse:5.74198
# [4]	validation_0-rmse:5.24487
# [5]	validation_0-rmse:4.78994
# [6]	validation_0-rmse:4.38021
# [7]	validation_0-rmse:4.00996
# [8]	validation_0-rmse:3.66835
# [9]	validation_0-rmse:3.35784
# [10]	validation_0-rmse:3.08507
# [11]	validation_0-rmse:2.83191
# [12]	validation_0-rmse:2.60222
# [13]	validation_0-rmse:2.39245
# [14]	validation_0-rmse:2.20408
# [15]	validation_0-rmse:2.03416
# [16]	validation_0-rmse:1.87919
# [17]	validation_0-rmse:1.73454
# [18]	validation_0-rmse:1.60914
# [19]	validation_0-rmse:1.49498
# [20]	validation_0-rmse:1.39434
# [21]	validation_0-rmse:1.30582
# [22]	validation_0-rmse:1.22344
# [23]	validation_0-rmse:1.14992
# [24]	validation_0-rmse:1.08582
# [25]	validation_0-rmse:1.03146
# [26]	validation_0-rmse:0.97958
# [27]	validation_0-rmse:0.93340
# [28]	validation_0-rmse:0.89413
# [29]	validation_0-rmse:0.85821
# [30]	validation_0-rmse:0.82716
# [31]	validation_0-rmse:0.79779
# [32]	validation_0-rmse:0.77412
# [33]	validation_0-rmse:0.75291
# [34]	validation_0-rmse:0.73376
# [35]	validation_0-rmse:0.71737
# [36]	validation_0-rmse:0.70164
# [37]	validation_0-rmse:0.68847
# [38]	validation_0-rmse:0.67655
# [39]	validation_0-rmse:0.66715
# [40]	validation_0-rmse:0.65884
# [41]	validation_0-rmse:0.65032
# [42]	validation_0-rmse:0.64265
# [43]	validation_0-rmse:0.63416
# [44]	validation_0-rmse:0.62756
# [45]	validation_0-rmse:0.62191
# [46]	validation_0-rmse:0.61573
# [47]	validation_0-rmse:0.61141
# [48]	validation_0-rmse:0.59952
# [49]	validation_0-rmse:0.58978
# [50]	validation_0-rmse:0.58661
# [51]	validation_0-rmse:0.58380
# [52]	validation_0-rmse:0.57904
# [53]	validation_0-rmse:0.57458
# [54]	validation_0-rmse:0.57060

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 54

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.1
# Relative bias(%):  -0.63
# RMSE: 0.6
# Relative RMSE(%):  0.066
# MSE: 0.3
# R square: 84.8%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(6, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 1.938
# a1: 0.770
# R^2: 0.859
# Uncertainty
# a0: 1.94+/-0.27
# a1: 0.770+/-0.031

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("./../03_output_data/XGBoost_models/UAV_ln_Sr_XGB_model_with_textures_2024.json")
# Save to text format
f_xgb_model.save_model("./../03_output_data/XGBoost_models/UAV_ln_Sr_XGB_model_with_textures_2024.txt")
