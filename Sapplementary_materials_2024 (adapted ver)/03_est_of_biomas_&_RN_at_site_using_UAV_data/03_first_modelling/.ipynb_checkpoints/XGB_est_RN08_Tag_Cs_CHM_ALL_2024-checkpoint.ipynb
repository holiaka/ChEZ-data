# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN'])

# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           2260           1210     -0.731      2.576
# 1       8.189       9.622           2700           1180      0.585      2.915
# 2       8.380       9.589           2500           1400      0.779      2.882
# 3       8.137       9.449           2500           1090      0.517      2.724
# 4       7.696       9.401           2400            720      0.224      2.826
#
#    AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  \
# 0       2.33    0.445070     13  35.145074   360.273487    0.488754
# 1       2.47   12.465903     24  36.135511   323.958625    0.501683
# 2       2.44   13.028298     18  35.938764   299.438354    0.540056
# 3       2.55    2.128231     15  35.908361   319.773395    0.480991
# 4       2.14   12.171553      8  38.062522   353.104284    0.505257
#
#    corr_r_MIN
# 0    0.072792
# 1    0.098347
# 2    0.187811
# 3    0.020686
# 4    0.106549

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   mf_chm_MIN     103 non-null    float64
#  8   r_MIN          103 non-null    int64
#  9   b_STD          103 non-null    float64
#  10  contr_r_STD    103 non-null    float64
#  11  corr_r_Q25     103 non-null    float64
#  12  corr_r_MIN     103 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 10.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3440.194175    1242.902913   -0.252563
# std       1.64946    1.472424    6087.580089    2037.684800    1.104610
# min       3.52600    6.075000     260.000000      50.000000   -3.033000
# 25%       6.31900    7.664000     635.000000     200.000000   -0.727500
# 50%       6.95700    8.472000    1150.000000     400.000000   -0.025000
# 75%       7.91350    9.421000    2525.000000    1400.000000    0.516500
# max      11.36700   13.864000   35200.000000   10500.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean  mf_chm_MIN       r_MIN       b_STD  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     2.464709    3.570291    3.368496   11.378641   35.164575
# std      0.904675    6.089170    4.845054    9.139568    5.338700
# min      0.391000    0.480000   -0.018586    2.000000   20.570709
# 25%      1.803000    0.710000    0.482279    5.000000   31.746440
# 50%      2.603000    1.290000    0.642883    8.000000   36.135511
# 75%      3.159000    2.960000    3.921804   15.000000   39.139044
# max      4.659000   36.590000   17.862923   56.000000   45.825416
#
#        contr_r_STD  corr_r_Q25  corr_r_MIN
# count   103.000000  103.000000  103.000000
# mean    327.115078    0.393571    0.073579
# std     167.617957    0.151801    0.056017
# min       0.091058    0.033797   -0.062450
# 25%     283.887328    0.407228    0.027204
# 50%     353.034542    0.449670    0.063714
# 75%     448.017711    0.476635    0.110983
# max     652.546648    0.555648    0.241284

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN'])
y = pd.DataFrame(select, columns= ['ln_Tag_Cs'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  corr_r_MIN
# 0    0.445070     13  35.145074   360.273487    0.488754    0.072792
# 1   12.465903     24  36.135511   323.958625    0.501683    0.098347
# 2   13.028298     18  35.938764   299.438354    0.540056    0.187811
# 3    2.128231     15  35.908361   319.773395    0.480991    0.020686
# 4   12.171553      8  38.062522   353.104284    0.505257    0.106549

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Tag_Cs
# 0     -0.731
# 1      0.585
# 2      0.779
# 3      0.517
# 4      0.224

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [-0.059131471999457785, 0.12295339362295665, -0.18015169990395363]
#     Mean: -0.039
#     Std: 0.125
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.40091077 0.98022181 1.131164  ]
#     Mean: 1.171
#     Std: 0.174
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.8923584533648832, 0.7496011084020139, 0.7928536097915734]
#     Mean: 0.812
#     Std: 0.060
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=7, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 7 folds for each of 3000 candidates, totalling 21000 fits
# Model with rank: 1
# Mean validation score: -0.057 (std: 0.117)
# Parameters: {'colsample_bytree': 0.39405284878753544, 'gamma': 0.08982585259453796, 'learning_rate': 0.01673675109531391, 'max_depth': 3, 'n_estimators': 86, 'subsample': 0.48506589187163573}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([1.04386449, 1.06929244, 0.30998196, ..., 0.19307763, 0.16907075,
#        0.24003891]), 'std_fit_time': array([1.11823326, 1.23850318, 0.19856597, ..., 0.08216939, 0.00586957,
#        0.01525338]), 'mean_score_time': array([0.01021794, 0.00770627, 0.00726884, ..., 0.00587511, 0.0058043 ,
#        0.005801  ]), 'std_score_time': array([5.64111830e-03, 2.07189695e-03, 1.66423406e-03, ...,
#        6.73686943e-05, 6.89873600e-05, 7.50093397e-05]), 'param_colsample_bytree': masked_array(data=[0.5368785259814461, 0.5738677637995163,
#                    0.8639042632419669, ..., 0.7764269181806808,
#                    0.5087702174521125, 0.4244941296685248],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.45189514248657103, 0.08951660378552989,
#                    0.3091404668244874, ..., 0.0029582012728712748,
#                    0.10336710431798812, 0.45211066727244464],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.27436884736325445, 0.20153701051778175,
#                    0.24001238730537505, ..., 0.13591025659241174,
#                    0.14660183272715213, 0.03660367893537671],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[4, 3, 3, ..., 4, 4, 2],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[128, 131, 70, ..., 60, 65, 97],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.320574462501089, 0.6669181740874612,
#                    0.9911955533055183, ..., 0.5638226830959726,
#                    0.4550969148348707, 0.9733945233113706],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.5368785259814461, 'gamma': 0.45189514248657103, 'learning_rate': 0.27436884736325445, 'max_depth': 4, 'n_estimators': 128, 'subsample': 0.320574462501089}, {'colsample_bytree': 0.5738677637995163, 'gamma': 0.08951660378552989, 'learning_rate': 0.20153701051778175, 'max_depth': 3, 'n_estimators': 131, 'subsample': 0.6669181740874612}, {'colsample_bytree': 0.8639042632419669, 'gamma': 0.3091404668244874, 'learning_rate': 0.24001238730537505, 'max_depth': 3, 'n_estimators': 70, 'subsample': 0.9911955533055183}, {'colsample_bytree': 0.08882478790610301, 'gamma': 0.1821048111199654, 'learning_rate': 0.28715086155743724, 'max_depth': 3, 'n_estimators': 132, 'subsample': 0.6918426441158125}, {'colsample_bytree': 0.8426519887195827, 'gamma': 0.1168117901854357, 'learning_rate': 0.02649996411845784, 'max_depth': 4, 'n_estimators': 135, 'subsample': 0.8729688800463784}, {'colsample_bytree': 0.7819594370637581, 'gamma': 0.4085669100621127, 'learning_rate': 0.26915111573550643, 'max_depth': 2, 'n_estimators': 194, '
#        -2.08291611, -1.87316376]), 'split2_test_score': array([-0.02389688,  0.05419178,  0.15335822, ...,  0.15137346,
#         0.30588072, -0.03360186]), 'split3_test_score': array([-0.73329879, -0.22006108,  0.0337054 , ..., -0.14936392,
#        -0.37676718, -0.02722585]), 'split4_test_score': array([-1.69007802, -1.36231801, -0.63338893, ..., -1.58458258,
#        -1.64787687, -0.60808345]), 'split5_test_score': array([-0.63078641, -0.71661185, -0.98612151, ..., -0.58281388,
#        -0.50295702, -0.32133899]), 'split6_test_score': array([0.33197355, 0.25965007, 0.31296406, ..., 0.23040421, 0.33272259,
#        0.16902471]), 'mean_test_score': array([-1.29022452, -0.76920188, -0.58603557, ..., -0.61620933,
#        -0.65965288, -0.41284046]), 'std_test_score': array([1.38102862, 0.90707352, 1.02017263, ..., 0.7172107 , 0.84718887,
#        0.63890124]), 'rank_test_score': array([2852, 1728,  945, ..., 1067, 1263,  419], dtype=int32), 'split0_train_score': array([0.94056823, 0.98463135, 0.93041338, ..., 0.96945413, 0.94332421,
#        0.6477462 ]), 'split1_train_score': array([0.94373717, 0.98490796, 0.93116361, ..., 0.9679471 , 0.94947176,
#        0.67081144]), 'split2_train_score': array([0.91700684, 0.98205502, 0.85898682, ..., 0.95352345, 0.93797703,
#        0.57688682]), 'split3_train_score': array([0.93107771, 0.98223524, 0.89840598, ..., 0.97437886, 0.95529159,
#        0.6964913 ]), 'split4_train_score': array([0.93918705, 0.98540343, 0.93489463, ..., 0.97899797, 0.96139765,
#        0.63967095]), 'split5_train_score': array([0.93697284, 0.98424245, 0.90658876, ..., 0.97002905, 0.95066399,
#        0.6756466 ]), 'split6_train_score': array([0.91596304, 0.9801381 , 0.90826093, ..., 0.97092459, 0.94713714,
#        0.62469453]), 'mean_train_score': array([0.93207327, 0.98337337, 0.9098163 , ..., 0.96932217, 0.94932334,
#        0.64742112]), 'std_train_score': array([0.01049048, 0.00178543, 0.02459831, ..., 0.0073072 , 0.00709865,
#        0.03645628])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.39405284878753544
# Gamma: 0.08982585259453796
# Learning_rate: 0.01673675109531391
# Max_depth: 3
# N_estimators: 86
# Subsample: 0.48506589187163573

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:1.26827	validation_1-rmse:1.51827
# [1]	validation_0-rmse:1.25837	validation_1-rmse:1.50672
# [2]	validation_0-rmse:1.25024	validation_1-rmse:1.49836
# [3]	validation_0-rmse:1.24432	validation_1-rmse:1.49373
# [4]	validation_0-rmse:1.23761	validation_1-rmse:1.48475
# [5]	validation_0-rmse:1.22755	validation_1-rmse:1.47294
# [6]	validation_0-rmse:1.21829	validation_1-rmse:1.46286
# [7]	validation_0-rmse:1.20958	validation_1-rmse:1.45471
# [8]	validation_0-rmse:1.20111	validation_1-rmse:1.44524
# [9]	validation_0-rmse:1.19421	validation_1-rmse:1.43554
# [10]	validation_0-rmse:1.18832	validation_1-rmse:1.43039
# [11]	validation_0-rmse:1.17979	validation_1-rmse:1.42107
# [12]	validation_0-rmse:1.16998	validation_1-rmse:1.41025
# [13]	validation_0-rmse:1.16244	validation_1-rmse:1.40143
# [14]	validation_0-rmse:1.15441	validation_1-rmse:1.39462
# [15]	validation_0-rmse:1.14646	validation_1-rmse:1.38915
# [16]	validation_0-rmse:1.13633	validation_1-rmse:1.38295
# [17]	validation_0-rmse:1.13025	validation_1-rmse:1.37774
# [18]	validation_0-rmse:1.12251	validation_1-rmse:1.37003
# [19]	validation_0-rmse:1.11230	validation_1-rmse:1.35904
# [20]	validation_0-rmse:1.10715	validation_1-rmse:1.35259
# [21]	validation_0-rmse:1.09873	validation_1-rmse:1.34115
# [22]	validation_0-rmse:1.09258	validation_1-rmse:1.33827
# [23]	validation_0-rmse:1.08417	validation_1-rmse:1.32988
# [24]	validation_0-rmse:1.07728	validation_1-rmse:1.32326
# [43]	validation_0-rmse:1.02009	validation_1-rmse:0.85167
# [44]	validation_0-rmse:1.01405	validation_1-rmse:0.84831
# [45]	validation_0-rmse:1.00687	validation_1-rmse:0.84323
# [46]	validation_0-rmse:1.00200	validation_1-rmse:0.84242
# [47]	validation_0-rmse:0.99600	validation_1-rmse:0.83975
# [48]	validation_0-rmse:0.99195	validation_1-rmse:0.83695
# [49]	validation_0-rmse:0.98874	validation_1-rmse:0.83463
# [50]	validation_0-rmse:0.98521	validation_1-rmse:0.83161
# [51]	validation_0-rmse:0.98061	validation_1-rmse:0.82774
# [52]	validation_0-rmse:0.97679	validation_1-rmse:0.82595
# [53]	validation_0-rmse:0.96988	validation_1-rmse:0.82269
# [54]	validation_0-rmse:0.96892	validation_1-rmse:0.82278
# [55]	validation_0-rmse:0.96423	validation_1-rmse:0.82013
# [56]	validation_0-rmse:0.95790	validation_1-rmse:0.81523
# [57]	validation_0-rmse:0.95326	validation_1-rmse:0.81470
# [58]	validation_0-rmse:0.94691	validation_1-rmse:0.81134
# [59]	validation_0-rmse:0.94173	validation_1-rmse:0.80899
# [60]	validation_0-rmse:0.93763	validation_1-rmse:0.80465
# [61]	validation_0-rmse:0.93261	validation_1-rmse:0.80160
# [62]	validation_0-rmse:0.92691	validation_1-rmse:0.80184
# [63]	validation_0-rmse:0.92029	validation_1-rmse:0.79783
# [64]	validation_0-rmse:0.91549	validation_1-rmse:0.79582
# [65]	validation_0-rmse:0.91206	validation_1-rmse:0.79412
# [66]	validation_0-rmse:0.90864	validation_1-rmse:0.79267
# [67]	validation_0-rmse:0.90483	validation_1-rmse:0.79101
# [68]	validation_0-rmse:0.89883	validation_1-rmse:0.78786
# [69]	validation_0-rmse:0.89230	validation_1-rmse:0.78705
# [70]	validation_0-rmse:0.88907	validation_1-rmse:0.78740
# [71]	validation_0-rmse:0.88564	validation_1-rmse:0.78586
# [72]	validation_0-rmse:0.88067	validation_1-rmse:0.78248
# [73]	validation_0-rmse:0.87733	validation_1-rmse:0.78215
# [74]	validation_0-rmse:0.87268	validation_1-rmse:0.78078
# [75]	validation_0-rmse:0.86954	validation_1-rmse:0.78137
# [76]	validation_0-rmse:0.86633	validation_1-rmse:0.78195
# [77]	validation_0-rmse:0.86315	validation_1-rmse:0.78050
# [78]	validation_0-rmse:0.85907	validation_1-rmse:0.77703
# [79]	validation_0-rmse:0.85531	validation_1-rmse:0.77627
# [80]	validation_0-rmse:0.85090	validation_1-rmse:0.77569
# [81]	validation_0-rmse:0.84731	validation_1-rmse:0.77242
# [82]	validation_0-rmse:0.84480	validation_1-rmse:0.76970
# [83]	validation_0-rmse:0.84159	validation_1-rmse:0.76950
# [84]	validation_0-rmse:0.83830	validation_1-rmse:0.76842
# [85]	validation_0-rmse:0.83459	validation_1-rmse:0.76966
# [0]	validation_0-rmse:1.34937	validation_1-rmse:1.22535
# [1]	validation_0-rmse:1.33980	validation_1-rmse:1.22019
# [2]	validation_0-rmse:1.32609	validation_1-rmse:1.21222
# [3]	validation_0-rmse:1.31317	validation_1-rmse:1.20468
# [51]	validation_0-rmse:0.94972	validation_1-rmse:1.02545
# [52]	validation_0-rmse:0.94540	validation_1-rmse:1.02527
# [53]	validation_0-rmse:0.93936	validation_1-rmse:1.02022
# [54]	validation_0-rmse:0.93744	validation_1-rmse:1.02073
# [55]	validation_0-rmse:0.93242	validation_1-rmse:1.02296
# [56]	validation_0-rmse:0.92666	validation_1-rmse:1.01981
# [57]	validation_0-rmse:0.92030	validation_1-rmse:1.01827
# [58]	validation_0-rmse:0.91642	validation_1-rmse:1.01753
# [59]	validation_0-rmse:0.91200	validation_1-rmse:1.01539
# [60]	validation_0-rmse:0.90579	validation_1-rmse:1.01392
# [61]	validation_0-rmse:0.89992	validation_1-rmse:1.01124
# [62]	validation_0-rmse:0.89380	validation_1-rmse:1.00815
# [63]	validation_0-rmse:0.88772	validation_1-rmse:1.00766
# [64]	validation_0-rmse:0.88380	validation_1-rmse:1.00791
# [65]	validation_0-rmse:0.87816	validation_1-rmse:1.00383
# [66]	validation_0-rmse:0.87595	validation_1-rmse:1.00101
# [67]	validation_0-rmse:0.87301	validation_1-rmse:0.99785
# [68]	validation_0-rmse:0.86812	validation_1-rmse:0.99707
# ...
# [63]	validation_0-rmse:0.89167	validation_1-rmse:1.11042
# [64]	validation_0-rmse:0.88584	validation_1-rmse:1.11045
# [65]	validation_0-rmse:0.88183	validation_1-rmse:1.11106
# [66]	validation_0-rmse:0.87834	validation_1-rmse:1.10936
# [67]	validation_0-rmse:0.87653	validation_1-rmse:1.10842
# [68]	validation_0-rmse:0.87262	validation_1-rmse:1.10619
# [69]	validation_0-rmse:0.86768	validation_1-rmse:1.10525
# [70]	validation_0-rmse:0.86287	validation_1-rmse:1.10603
# [71]	validation_0-rmse:0.86052	validation_1-rmse:1.10117
# [72]	validation_0-rmse:0.85554	validation_1-rmse:1.09764
# [73]	validation_0-rmse:0.85254	validation_1-rmse:1.09816
# [74]	validation_0-rmse:0.84778	validation_1-rmse:1.09473
# [75]	validation_0-rmse:0.84445	validation_1-rmse:1.09656
# [76]	validation_0-rmse:0.84206	validation_1-rmse:1.09152
# [77]	validation_0-rmse:0.83741	validation_1-rmse:1.08794
# [78]	validation_0-rmse:0.83368	validation_1-rmse:1.08564
# [79]	validation_0-rmse:0.83072	validation_1-rmse:1.08356
# [80]	validation_0-rmse:0.82660	validation_1-rmse:1.08286
# [81]	validation_0-rmse:0.82241	validation_1-rmse:1.08006
# [82]	validation_0-rmse:0.81823	validation_1-rmse:1.07952
# [83]	validation_0-rmse:0.81369	validation_1-rmse:1.07301
# [84]	validation_0-rmse:0.81099	validation_1-rmse:1.06981
# [85]	validation_0-rmse:0.80814	validation_1-rmse:1.07033
# [0]	validation_0-rmse:1.26959	validation_1-rmse:1.51781
# [1]	validation_0-rmse:1.26087	validation_1-rmse:1.50966
# [2]	validation_0-rmse:1.25176	validation_1-rmse:1.50618
# [3]	validation_0-rmse:1.23973	validation_1-rmse:1.50447
# [4]	validation_0-rmse:1.23020	validation_1-rmse:1.49841
# [5]	validation_0-rmse:1.22426	validation_1-rmse:1.49331
# [61]	validation_0-rmse:0.89840	validation_1-rmse:1.01668
# [62]	validation_0-rmse:0.89455	validation_1-rmse:1.01473
# [63]	validation_0-rmse:0.88757	validation_1-rmse:1.01283
# [64]	validation_0-rmse:0.88483	validation_1-rmse:1.01166
# [65]	validation_0-rmse:0.88182	validation_1-rmse:1.00941
# [66]	validation_0-rmse:0.88020	validation_1-rmse:1.00926
# [67]	validation_0-rmse:0.87894	validation_1-rmse:1.00865
# [68]	validation_0-rmse:0.87704	validation_1-rmse:1.00910
# [69]	validation_0-rmse:0.87473	validation_1-rmse:1.00805
# [70]	validation_0-rmse:0.86990	validation_1-rmse:1.00465
# [71]	validation_0-rmse:0.86526	validation_1-rmse:1.00556
# [72]	validation_0-rmse:0.86057	validation_1-rmse:1.00251
# [73]	validation_0-rmse:0.85614	validation_1-rmse:0.99997
# [74]	validation_0-rmse:0.85131	validation_1-rmse:0.99747
# [75]	validation_0-rmse:0.84541	validation_1-rmse:0.99551
# [76]	validation_0-rmse:0.84277	validation_1-rmse:0.99727
# [77]	validation_0-rmse:0.83925	validation_1-rmse:0.99253
# [78]	validation_0-rmse:0.83614	validation_1-rmse:0.98957
# [79]	validation_0-rmse:0.83090	validation_1-rmse:0.98644
# [80]	validation_0-rmse:0.82722	validation_1-rmse:0.98557
# [81]	validation_0-rmse:0.82276	validation_1-rmse:0.98207
# [82]	validation_0-rmse:0.82203	validation_1-rmse:0.97929
# [83]	validation_0-rmse:0.81880	validation_1-rmse:0.97904
# [84]	validation_0-rmse:0.81516	validation_1-rmse:0.97623
# [85]	validation_0-rmse:0.81265	validation_1-rmse:0.97629
# [0]	validation_0-rmse:1.36882	validation_1-rmse:1.11950
# [1]	validation_0-rmse:1.35812	validation_1-rmse:1.11741
# [2]	validation_0-rmse:1.34542	validation_1-rmse:1.10996
# [3]	validation_0-rmse:1.33466	validation_1-rmse:1.10127
# [4]	validation_0-rmse:1.32458	validation_1-rmse:1.09072
# [5]	validation_0-rmse:1.31301	validation_1-rmse:1.08248
# [6]	validation_0-rmse:1.30473	validation_1-rmse:1.07690
# [7]	validation_0-rmse:1.29266	validation_1-rmse:1.06950
# [8]	validation_0-rmse:1.28430	validation_1-rmse:1.06481
# [9]	validation_0-rmse:1.27461	validation_1-rmse:1.05665
# [10]	validation_0-rmse:1.26483	validation_1-rmse:1.05003
# [11]	validation_0-rmse:1.25510	validation_1-rmse:1.04491
# [12]	validation_0-rmse:1.24600	validation_1-rmse:1.03700
# [13]	validation_0-rmse:1.23646	validation_1-rmse:1.03007
# [14]	validation_0-rmse:1.23224	validation_1-rmse:1.02805
# [15]	validation_0-rmse:1.22410	validation_1-rmse:1.02192
# [16]	validation_0-rmse:1.21351	validation_1-rmse:1.01535
# [17]	validation_0-rmse:1.20461	validation_1-rmse:1.00904
# [18]	validation_0-rmse:1.19334	validation_1-rmse:1.00671
# [19]	validation_0-rmse:1.18460	validation_1-rmse:1.00181
# [20]	validation_0-rmse:1.17373	validation_1-rmse:0.99760
# [21]	validation_0-rmse:1.16398	validation_1-rmse:0.99266
# [22]	validation_0-rmse:1.15734	validation_1-rmse:0.98868
# [23]	validation_0-rmse:1.14739	validation_1-rmse:0.98524
# [24]	validation_0-rmse:1.13888	validation_1-rmse:0.98062
# [25]	validation_0-rmse:1.13120	validation_1-rmse:0.97603
# [26]	validation_0-rmse:1.12704	validation_1-rmse:0.97292
# [27]	validation_0-rmse:1.11963	validation_1-rmse:0.96879
# [28]	validation_0-rmse:1.11427	validation_1-rmse:0.96605
# [29]	validation_0-rmse:1.10873	validation_1-rmse:0.96335
# [30]	validation_0-rmse:1.09838	validation_1-rmse:0.95989
# [31]	validation_0-rmse:1.08977	validation_1-rmse:0.95765
# [32]	validation_0-rmse:1.08559	validation_1-rmse:0.95552
# [33]	validation_0-rmse:1.07707	validation_1-rmse:0.95332
# [34]	validation_0-rmse:1.06749	validation_1-rmse:0.94997
# [35]	validation_0-rmse:1.06156	validation_1-rmse:0.94749
# [36]	validation_0-rmse:1.05573	validation_1-rmse:0.94962
# [37]	validation_0-rmse:1.04810	validation_1-rmse:0.94891
# [38]	validation_0-rmse:1.04439	validation_1-rmse:0.94762
# [39]	validation_0-rmse:1.03599	validation_1-rmse:0.94682
# [40]	validation_0-rmse:1.03065	validation_1-rmse:0.94612
# [41]	validation_0-rmse:1.02303	validation_1-rmse:0.94421
# [42]	validation_0-rmse:1.01951	validation_1-rmse:0.94206
# [43]	validation_0-rmse:1.01682	validation_1-rmse:0.94105
# [44]	validation_0-rmse:1.01143	validation_1-rmse:0.93671
# [45]	validation_0-rmse:1.00516	validation_1-rmse:0.93554
# [46]	validation_0-rmse:0.99928	validation_1-rmse:0.93266
# [47]	validation_0-rmse:0.99230	validation_1-rmse:0.93488
# [48]	validation_0-rmse:0.98629	validation_1-rmse:0.93362
# [49]	validation_0-rmse:0.97977	validation_1-rmse:0.93090
# [50]	validation_0-rmse:0.97762	validation_1-rmse:0.93025
# [51]	validation_0-rmse:0.97071	validation_1-rmse:0.92980
# [52]	validation_0-rmse:0.96761	validation_1-rmse:0.92742
# [53]	validation_0-rmse:0.96353	validation_1-rmse:0.92671
# [54]	validation_0-rmse:0.96093	validation_1-rmse:0.92747
# [55]	validation_0-rmse:0.95748	validation_1-rmse:0.92655
# [56]	validation_0-rmse:0.95206	validation_1-rmse:0.92439
# [57]	validation_0-rmse:0.94565	validation_1-rmse:0.92597
# [58]	validation_0-rmse:0.94118	validation_1-rmse:0.92525
# [59]	validation_0-rmse:0.93469	validation_1-rmse:0.92824
# [60]	validation_0-rmse:0.92835	validation_1-rmse:0.92699
# [61]	validation_0-rmse:0.92472	validation_1-rmse:0.92393
# [62]	validation_0-rmse:0.91897	validation_1-rmse:0.92079
# [63]	validation_0-rmse:0.91418	validation_1-rmse:0.92151
# [64]	validation_0-rmse:0.91021	validation_1-rmse:0.92315
# [65]	validation_0-rmse:0.90537	validation_1-rmse:0.92171
# [66]	validation_0-rmse:0.90070	validation_1-rmse:0.92176
# [67]	validation_0-rmse:0.89710	validation_1-rmse:0.91977
# [68]	validation_0-rmse:0.89199	validation_1-rmse:0.92038
# [69]	validation_0-rmse:0.88830	validation_1-rmse:0.91945
# [70]	validation_0-rmse:0.88545	validation_1-rmse:0.91884
# [71]	validation_0-rmse:0.88225	validation_1-rmse:0.91929
# [72]	validation_0-rmse:0.87811	validation_1-rmse:0.91677
# [73]	validation_0-rmse:0.87480	validation_1-rmse:0.91412
# [74]	validation_0-rmse:0.86986	validation_1-rmse:0.91445
# [75]	validation_0-rmse:0.86577	validation_1-rmse:0.91420
# [76]	validation_0-rmse:0.85992	validation_1-rmse:0.91149
# [77]	validation_0-rmse:0.85444	validation_1-rmse:0.91355
# [78]	validation_0-rmse:0.85196	validation_1-rmse:0.91224
# [79]	validation_0-rmse:0.84701	validation_1-rmse:0.91483
# [80]	validation_0-rmse:0.84389	validation_1-rmse:0.91540
# [81]	validation_0-rmse:0.83825	validation_1-rmse:0.91631
# [82]	validation_0-rmse:0.83463	validation_1-rmse:0.91683
# [83]	validation_0-rmse:0.83023	validation_1-rmse:0.91606
# [84]	validation_0-rmse:0.82550	validation_1-rmse:0.91867
# [85]	validation_0-rmse:0.82301	validation_1-rmse:0.91923

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 78.665, median: 84.0,
#  pred. interval (P(0.025)-P(0.975)): 33.975-85.0,
#  conf. interval (p-value=0.95): 80.509-84.436
# ***
# Aggregate bias statistic:
#  mean: 4.82, median: 4.64,
#  pred. interval (P(0.025)-P(0.975)): -2.75-14.792,
#  conf. interval (p-value=0.95): 2.973-6.518
# ***
# Aggregate RMSE statistic:
#  mean: 1.006, median: 1.003, pred. interval (P(0.025)-P(0.975)): 0.645-1.319,
#  conf. interval (p-value=0.95): 0.938-1.071
# ***
# Aggregate MSE statistic:
#  mean: 1.038, median: 1.005, pred. interval (P(0.025)-P(0.975)): 0.416-1.739,
#  conf. interval (p-value=0.95): 0.885-1.153
# ***
# Aggregate R^2 statistic:
#  mean: 0.097, median: 0.099, pred. interval (P(0.025)-P(0.975)): -0.258-0.351,
#  conf. interval (p-value=0.95): 0.045-0.157
# ***
# Aggregate bias(%) statistic:
#  mean: -17.215, median: 4.64, pred. interval (P(0.025)-P(0.975)): -54.941-44.826,
#  conf. interval (p-value=0.95): -21.723--14.343
# ***
# Aggregate RMSE(%) statistic:
#  mean: 4.326, median: -3.226, pred. interval (P(0.025)-P(0.975)): -27.899-30.618,
#  conf. interval (p-value=0.95): -5.202--2.497
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=10, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.32256
# [1]	validation_0-rmse:1.31492
# [2]	validation_0-rmse:1.30927
# [3]	validation_0-rmse:1.29941
# [4]	validation_0-rmse:1.28766
# [5]	validation_0-rmse:1.27817
# [6]	validation_0-rmse:1.26702
# [7]	validation_0-rmse:1.25599
# [8]	validation_0-rmse:1.24743
# [9]	validation_0-rmse:1.23819
# [10]	validation_0-rmse:1.22981
# [11]	validation_0-rmse:1.22406
# [12]	validation_0-rmse:1.21633
# [13]	validation_0-rmse:1.20489
# [14]	validation_0-rmse:1.19618
# [15]	validation_0-rmse:1.18691
# [16]	validation_0-rmse:1.18161
# [17]	validation_0-rmse:1.17607
# [18]	validation_0-rmse:1.16928
# [19]	validation_0-rmse:1.16109
# [20]	validation_0-rmse:1.15316
# [21]	validation_0-rmse:1.14492
# [22]	validation_0-rmse:1.13493
# [23]	validation_0-rmse:1.12836
# [24]	validation_0-rmse:1.12122
# [25]	validation_0-rmse:1.11575
# [26]	validation_0-rmse:1.10601
# [27]	validation_0-rmse:1.09863
# [28]	validation_0-rmse:1.09014
# [29]	validation_0-rmse:1.08041
# [30]	validation_0-rmse:1.07676
# [31]	validation_0-rmse:1.07314
# [32]	validation_0-rmse:1.06585
# [33]	validation_0-rmse:1.06138
# [34]	validation_0-rmse:1.05378
# [35]	validation_0-rmse:1.04847
# [36]	validation_0-rmse:1.04142
# [37]	validation_0-rmse:1.03702
# [38]	validation_0-rmse:1.03102
# [39]	validation_0-rmse:1.02605
# [40]	validation_0-rmse:1.02013
# [41]	validation_0-rmse:1.01578
# [42]	validation_0-rmse:1.00996
# [43]	validation_0-rmse:1.00483
# [44]	validation_0-rmse:0.99824
# [45]	validation_0-rmse:0.99009
# [46]	validation_0-rmse:0.98385
# [47]	validation_0-rmse:0.98032
# [48]	validation_0-rmse:0.97577
# [49]	validation_0-rmse:0.97051
# [50]	validation_0-rmse:0.96524
# [51]	validation_0-rmse:0.96021
# [52]	validation_0-rmse:0.95504
# [53]	validation_0-rmse:0.94936
# [54]	validation_0-rmse:0.94432
# [55]	validation_0-rmse:0.93889
# [56]	validation_0-rmse:0.93220
# [57]	validation_0-rmse:0.92794
# [58]	validation_0-rmse:0.92396
# [59]	validation_0-rmse:0.92093
# [60]	validation_0-rmse:0.91762
# [61]	validation_0-rmse:0.91170
# [62]	validation_0-rmse:0.90592
# [63]	validation_0-rmse:0.90170
# [64]	validation_0-rmse:0.89844
# [65]	validation_0-rmse:0.89518
# [66]	validation_0-rmse:0.89188
# [67]	validation_0-rmse:0.88827
# [68]	validation_0-rmse:0.88556
# [69]	validation_0-rmse:0.88160
# [70]	validation_0-rmse:0.87787
# [71]	validation_0-rmse:0.87440
# [72]	validation_0-rmse:0.86910
# [73]	validation_0-rmse:0.86512
# [74]	validation_0-rmse:0.86142
# [75]	validation_0-rmse:0.85731
# [76]	validation_0-rmse:0.85568
# [77]	validation_0-rmse:0.85119
# [78]	validation_0-rmse:0.84664
# [79]	validation_0-rmse:0.84363
# [80]	validation_0-rmse:0.84214
# [81]	validation_0-rmse:0.83995
# [82]	validation_0-rmse:0.83654
# [83]	validation_0-rmse:0.83166
# [84]	validation_0-rmse:0.82900
# [85]	validation_0-rmse:0.82384

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 85

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.2
# Relative bias(%):  -87.52
# RMSE: 0.8
# Relative RMSE(%):  -3.262
# MSE: 0.7
# R square: 43.8%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.039
# a1: 0.304
# R^2: 0.702
# Uncertainty
# a0: 0.039+/-0.022
# a1: 0.304+/-0.020

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("./../03_output_data/XGBoost_models/UAV_ln_Tag_Cs_XGB_model_2024.json")
# Save to text format
f_xgb_model.save_model("./../03_output_data/XGBoost_models/UAV_ln_Tag_Cs_XGB_model_2024.txt")
