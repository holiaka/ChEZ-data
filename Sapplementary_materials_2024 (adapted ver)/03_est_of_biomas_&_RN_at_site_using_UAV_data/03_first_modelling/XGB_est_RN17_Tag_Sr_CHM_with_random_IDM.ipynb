# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25  idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167   0.050549
# 1           3600       8.189          15100  ...   0.040919   0.048889
# 2           4360       8.380          14600  ...   0.042397   0.050463
# 3           3420       8.137          12700  ...   0.043719   0.052974
# 4           2200       7.696          12100  ...   0.040659   0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966   0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602   0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265   0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465   0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420   0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 163 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 
                                    'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 
                                    'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'])

# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           1912            784      -0.73       2.58
# 1       8.189       9.622           2005            818       0.59       2.92
# 2       8.380       9.589           2001            818       0.78       2.88
# 3       8.137       9.449           2040            833       0.52       2.72
# 4       7.696       9.401           1758            717       0.22       2.83
#
#    AEDR_mean  idm_r_MIN  idm_r_MAX  idm_r_MEAN  ...  idm_g_Q25  idm_g_Q50  \
# 0       2.33   0.018896   0.384033    0.057680  ...   0.042167   0.050549
# 1       2.47   0.020510   0.262630    0.056071  ...   0.040919   0.048889
# 2       2.44   0.021948   0.146006    0.054125  ...   0.042397   0.050463
# 3       2.55   0.019093   0.366594    0.059043  ...   0.043719   0.052974
# 4       2.14   0.016348   0.295941    0.056370  ...   0.040659   0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX  idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966    0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602    0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265    0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465    0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420    0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 28 columns]

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   idm_r_MIN      103 non-null    float64
#  8   idm_r_MAX      103 non-null    float64
#  9   idm_r_MEAN     103 non-null    float64
#  10  idm_r_STD      103 non-null    float64
#  11  idm_r_Q25      103 non-null    float64
#  12  idm_r_Q50      103 non-null    float64
#  13  idm_r_Q75      103 non-null    float64
#  14  idm_g_MIN      103 non-null    float64
#  15  idm_g_MAX      103 non-null    float64
#  16  idm_g_MEAN     103 non-null    float64
#  17  idm_g_STD      103 non-null    float64
#  18  idm_g_Q25      103 non-null    float64
#  19  idm_g_Q50      103 non-null    float64
#  20  idm_g_Q75      103 non-null    float64
#  21  idm_b_MIN      103 non-null    float64
#  22  idm_b_MAX      103 non-null    float64
#  23  idm_b_MEAN     103 non-null    float64
#  24  idm_b_STD      103 non-null    float64
#  25  idm_b_Q25      103 non-null    float64
#  26  idm_b_Q50      103 non-null    float64
#  27  idm_b_Q75      103 non-null    float64
# dtypes: float64(26), int64(2)
# memory usage: 22.7 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
# /tmp/ipykernel_23659/725619848.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3014.359223    1136.436893   -0.251845
# std       1.64946    1.472424    4988.505540    2019.773384    1.104536
# min       3.52600    6.075000     423.000000      98.000000   -3.030000
# 25%       6.31900    7.664000     635.500000     199.500000   -0.725000
# 50%       6.95700    8.472000    1145.000000     362.000000   -0.020000
# 75%       7.91350    9.421000    2423.500000     966.000000    0.520000
# max      11.36700   13.864000   25173.000000   10477.000000    1.650000
#
#         ln_Tag_Sr   AEDR_mean   idm_r_MIN   idm_r_MAX  idm_r_MEAN  ...  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  ...
# mean     2.464854    3.570291    0.018784    0.361270    0.062383  ...
# std      0.904757    6.089170    0.004371    0.159418    0.013583  ...
# min      0.390000    0.480000    0.011770    0.116429    0.045291  ...
# 25%      1.805000    0.710000    0.016082    0.229642    0.053289  ...
# 50%      2.600000    1.290000    0.017919    0.326403    0.057774  ...
# 75%      3.160000    2.960000    0.020262    0.453982    0.066262  ...
# max      4.660000   36.590000    0.036265    0.748390    0.109070  ...
#
#         idm_g_Q25   idm_g_Q50   idm_g_Q75   idm_b_MIN   idm_b_MAX  idm_b_MEAN  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     0.043780    0.053322    0.068210    0.018715    0.369862    0.063183
# std      0.009554    0.011977    0.016121    0.004613    0.167070    0.013391
# min      0.032426    0.038965    0.048217    0.010157    0.119180    0.044884
# 25%      0.038160    0.045851    0.057399    0.015803    0.235651    0.054792
# 50%      0.041431    0.050218    0.062863    0.017749    0.329936    0.059749
# 75%      0.044375    0.055068    0.074153    0.020328    0.487015    0.068365
# max      0.084755    0.100882    0.123452    0.041025    0.770000    0.107732
#
#         idm_b_STD   idm_b_Q25   idm_b_Q50   idm_b_Q75
# count  103.000000  103.000000  103.000000  103.000000
# mean     0.031414    0.045112    0.054775    0.070020
# std      0.014380    0.009520    0.011976    0.016240
# min      0.011541    0.032628    0.038965    0.048217
# 25%      0.019469    0.039603    0.047617    0.058939
# 50%      0.029068    0.042930    0.051569    0.065442
# 75%      0.037530    0.046268    0.056588    0.075429
# max      0.075240    0.087202    0.104570    0.124853
#
# [8 rows x 28 columns]

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 
                                   'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 
                                   'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'])
y = pd.DataFrame(select, columns= ['ln_Tag_Sr'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): Yes
# Selected "Yes"!!! A new column with random values was created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    idm_r_MIN  idm_r_MAX  idm_r_MEAN  idm_r_STD  idm_r_Q25  idm_r_Q50  \
# 0   0.018896   0.384033    0.057680   0.029676   0.041920   0.050301
# 1   0.020510   0.262630    0.056071   0.025267   0.042133   0.049856
# 2   0.021948   0.146006    0.054125   0.015072   0.043877   0.051675
# 3   0.019093   0.366594    0.059043   0.022897   0.044932   0.054252
# 4   0.016348   0.295941    0.056370   0.023413   0.042199   0.050681
#
#    idm_r_Q75  idm_g_MIN  idm_g_MAX  idm_g_MEAN  ...  idm_b_MEAN  idm_b_STD  \
# 0   0.062238   0.013972   0.376060    0.057730  ...    0.059749   0.030217
# 1   0.061412   0.018636   0.289322    0.055371  ...    0.057223   0.025515
# 2   0.061436   0.021988   0.170117    0.053174  ...    0.056571   0.016629
# 3   0.067136   0.015969   0.348899    0.058043  ...    0.060880   0.023964
# 4   0.063448   0.017970   0.280073    0.054908  ...    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75    Random1    Random2    Random3  \
# 0   0.043539   0.052312   0.064544  10.057839  13.071204   8.304687
# 1   0.043035   0.050941   0.062608  12.874724  10.174735   8.388717
# 2   0.045142   0.053495   0.064635   8.582575   8.877218  10.946305
# 3   0.046111   0.055601   0.069182  12.074614  11.324907   9.215163
# 4   0.043045   0.051566   0.065078  10.005146   6.733957   8.481818
#
#      Random4    Random5
# 0   8.069800  10.358930
# 1   6.937656   9.070645
# 2   9.955071   8.496231
# 3  11.714106   8.489347
# 4  10.816694  13.049818
#
# [5 rows x 26 columns]

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Tag_Sr
# 0       2.58
# 1       2.92
# 2       2.88
# 3       2.72
# 4       2.83

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.04544828658684097, 0.02705512155161971, -0.13280549849935608]
#     Mean: -0.020
#     Std: 0.080
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.91945665 0.93023728 0.98017542]
#     Mean: 0.943
#     Std: 0.026
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.7247036871228899, 0.8898350866401896, 0.6794657278762144]
#     Mean: 0.765
#     Std: 0.090
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=30, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Model with rank: 1
# Mean validation score: -0.045 (std: 0.200)
# Parameters: {'colsample_bytree': 0.7088347650341652, 'gamma': 0.27087930677017713, 'learning_rate': 0.02689693554275291, 'max_depth': 2, 'n_estimators': 105, 'subsample': 0.6919667285568886}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.42887163, 0.27749991, 0.22849865, 0.17853813, 0.28194423,
#        0.18351355, 0.33521976, 0.46632895, 0.42055216, 0.16655827,
#        0.42986512, 0.49397411, 0.43719463, 0.32113447, 0.17922592,
#        0.26405897, 0.42356172, 0.21217418, 0.25602231, 0.32625461,
#        0.38806801, 0.5027832 , 0.21569691, 0.33221073, 0.33476219,
#        0.48713069, 0.25290694, 0.45753884, 0.2919055 , 0.25782595]), 'std_fit_time': array([0.07753634, 0.00373746, 0.01975169, 0.02078341, 0.09615018,
#        0.06720346, 0.01009787, 0.0221487 , 0.0037137 , 0.00714573,
#        0.00400135, 0.03638649, 0.00978462, 0.00621206, 0.00428548,
#        0.00169347, 0.01539333, 0.01346935, 0.0390592 , 0.014315  ,
#        0.00462574, 0.00805618, 0.00510472, 0.04047586, 0.00832235,
#        0.00831396, 0.00725409, 0.00848622, 0.02083566, 0.03470615]), 'mean_score_time': array([0.00635376, 0.00627537, 0.00620379, 0.00629683, 0.00659299,
#        0.0066103 , 0.0063324 , 0.00630665, 0.00653343, 0.00622683,
#        0.00623307, 0.00629306, 0.00632095, 0.00616159, 0.00624928,
#        0.00765152, 0.00628538, 0.00762911, 0.00614877, 0.00620623,
#        0.00622954, 0.00621581, 0.00627446, 0.00622916, 0.00619192,
#        0.00630031, 0.00650582, 0.00665755, 0.00644412, 0.00640368]), 'std_score_time': array([1.85027663e-04, 7.31733615e-05, 2.62882189e-05, 7.20581887e-05,
#        4.15933275e-04, 7.01810196e-04, 2.05683475e-04, 1.08174059e-04,
#        4.61257461e-04, 9.06423917e-05, 1.02924569e-04, 7.82921020e-05,
#        6.85735935e-05, 1.98117662e-05, 1.04662074e-04, 2.75576817e-03,
#        1.34294344e-04, 2.71468812e-03, 7.42822000e-05, 9.40454650e-05,
#        1.04590141e-04, 5.57232727e-05, 4.80388293e-05, 4.93237277e-05,
#        9.11713893e-05, 2.07003990e-04, 1.34729206e-04, 3.54038582e-04,
#        9.32391143e-05, 1.05748571e-04]), 'param_colsample_bytree': masked_array(data=[0.5673403799930801, 0.6286638450150864,
#                    0.920748511826711, 0.2065069227616,
#                    0.46128509695391967, 0.8204539261010035,
#                    0.5224305204063339, 0.8964680227058929,
#                    0.1307112810289689, 0.273055407433298,
#                    0.12434585723985475, 0.21124760902413903,
#                    0.29791347145613206, 0.37885331725877097,
#                    0.06881608323784069, 0.6100584213801632,
#                    0.6859446399492544, 0.2602358677407021,
#                    0.7128560334132937, 0.4757710544950484,
#                    0.3848465510445366, 0.43657321400054105,
#                    0.5208241568035377, 0.7230067869615652,
#                    0.548774166158039, 0.13078118476740871,
#                    0.6246992936238767, 0.2512098337435146,
#                    0.7088347650341652, 0.615620721225835],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.12881476441794426, 0.43847861786180153,
#                    0.3217355933497309, 0.15138513859833153,
#                    0.22450708599021735, 0.0354479106243461,
#                    0.11886815969298925, 0.3499003721633867,
#                    0.4412881789939587, 0.46041607071134844,
#                    0.40946288199661424, 0.21320558374610032,
#                    0.33788468381074127, 0.06799551763028833,
#                    0.08245635835443377, 0.3508782485415625,
#                    0.048450950952662164, 0.24925602248258472,
#                    0.15549417996105563, 0.3167484248538048,
#                    0.30172617655144274, 0.34449109389063776,
#                    0.451139044788505, 0.1715924386172254,
#                    0.3517447048705683, 0.29274448767450895,
#                    0.4634964044876189, 0.41588159248029444,
#                    0.27087930677017713, 0.2908220507473464],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.19545658600721247, 0.2858656492443088,
#                    0.2888022116977119, 0.17082493245821861,
#                    0.22701438549957054, 0.09579081989114298,
#                    0.1898842417796198, 0.10993019660942029,
#                    0.21152027573284207, 0.028138173807409787,
#                    0.13184880333275906, 0.19124302239352375,
#                    0.0691585528688129, 0.2763259507627801,
#                    0.1522170749968924, 0.17153688631772618,
#                    0.1519424815478081, 0.15010225023079912,
#                    0.22380749888799892, 0.24479789383821834,
#                    0.19731560275587137, 0.2944714067771392,
#                    0.07978230134908643, 0.17742480572956457,
#                    0.27128388384023583, 0.23437744604080965,
#                    0.042190334891345875, 0.1933451440055586,
#                    0.02689693554275291, 0.12789026237473367],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[2, 2, 3, 2, 3, 3, 4, 4, 2, 3, 2, 4, 4, 3, 3, 4, 3, 2,
#                    4, 3, 4, 4, 2, 3, 3, 3, 4, 3, 2, 3],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[151, 107, 78, 60, 85, 52, 122, 165, 169, 61, 173, 181,
#                    167, 123, 68, 97, 161, 80, 83, 124, 146, 190, 82, 115,
#                    127, 194, 89, 176, 105, 88],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.749962893903253, 0.9903058904564968,
#                    0.5448484814176373, 0.9309523123601371,
#                    0.6916309230421948, 0.3909976785622068,
#                    0.6501124468056209, 0.6798629567154575,
#                    0.36798019166930473, 0.6894844468816546,
#                    0.808146355803042, 0.5987976446193517,
#                    0.3636516119322734, 0.8480420425506026,
#                    0.9768430496184666, 0.8691655400841265,
#                    0.5558660149214869, 0.834437363630526,
#                    0.9723417431926975, 0.7779921923161196,
#                    0.7144142063384938, 0.8896670706355643,
#                    0.6552062054454413, 0.8797826680271499,
#                    0.40622832088251093, 0.6983493285060856,
#                    0.9955316511815386, 0.9609893931774127,
#                    0.6919667285568886, 0.6321646028913503],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.5673403799930801, 'gamma': 0.12881476441794426, 'learning_rate': 0.19545658600721247, 'max_depth': 2, 'n_estimators': 151, 'subsample': 0.749962893903253}, {'colsample_bytree': 0.6286638450150864, 'gamma': 0.43847861786180153, 'learning_rate': 0.2858656492443088, 'max_depth': 2, 'n_estimators': 107, 'subsample': 0.9903058904564968}, {'colsample_bytree': 0.920748511826711, 'gamma': 0.3217355933497309, 'learning_rate': 0.2888022116977119, 'max_depth': 3, 'n_estimators': 78, 'subsample': 0.5448484814176373}, {'colsample_bytree': 0.2065069227616, 'gamma': 0.15138513859833153, 'learning_rate': 0.17082493245821861, 'max_depth': 2, 'n_estimators': 60, 'subsample': 0.9309523123601371}, {'colsample_bytree': 0.46128509695391967, 'gamma': 0.22450708599021735, 'learning_rate': 0.22701438549957054, 'max_depth': 3, 'n_estimators': 85, 'subsample': 0.6916309230421948}, {'colsample_bytree': 0.8204539261010035, 'gamma': 0.0354479106243461, 'learning_rate': 0.09579081989114298, 'max_depth': 3, 'n_estimators': 52, 'subsample': 0.3909976785622068}, {'colsample_bytree': 0.5224305204063339, 'gamma': 0.11886815969298925, 'learning_rate': 0.1898842417796198, 'max_depth': 4, 'n_estimators': 122, 'subsample': 0.6501124468056209}, {'colsample_bytree': 0.8964680227058929, 'gamma': 0.3499003721633867, 'learning_rate': 0.10993019660942029, 'max_depth': 4, 'n_estimators': 165, 'subsample': 0.6798629567154575}, {'colsample_bytree': 0.1307112810289689, 'gamma': 0.4412881789939587, 'learning_rate': 0.21152027573284207, 'max_depth': 2, 'n_estimators': 169, 'subsample': 0.36798019166930473}, {'colsample_bytree': 0.273055407433298, 'gamma': 0.46041607071134844, 'learning_rate': 0.028138173807409787, 'max_depth': 3, 'n_estimators': 61, 'subsample': 0.6894844468816546}, {'colsample_bytree': 0.12434585723985475, 'gamma': 0.40946288199661424, 'learning_rate': 0.13184880333275906, 'max_depth': 2, 'n_estimators': 173, 'subsample': 0.808146355803042}, {'colsample_bytree': 0.21124760902413903, 'gamma': 0.21320558374610032, 'learning_rate': 0.19124302239352375, 'max_depth': 4, 'n_estimators': 181, 'subsample': 0.5987976446193517}, {'colsample_bytree': 0.29791347145613206, 'gamma': 0.33788468381074127, 'learning_rate': 0.0691585528688129, 'max_depth': 4, 'n_estimators': 167, 'subsample': 0.3636516119322734}, {'colsample_bytree': 0.37885331725877097, 'gamma': 0.06799551763028833, 'learning_rate': 0.2763259507627801, 'max_depth': 3, 'n_estimators': 123, 'subsample': 0.8480420425506026}, {'colsample_bytree': 0.06881608323784069, 'gamma': 0.08245635835443377, 'learning_rate': 0.1522170749968924, 'max_depth': 3, 'n_estimators': 68, 'subsample': 0.9768430496184666}, {'colsample_bytree': 0.6100584213801632, 'gamma': 0.3508782485415625, 'learning_rate': 0.17153688631772618, 'max_depth': 4, 'n_estimators': 97, 'subsample': 0.8691655400841265}, {'colsample_bytree': 0.6859446399492544, 'gamma': 0.048450950952662164, 'learning_rate': 0.1519424815478081, 'max_depth': 3, 'n_estimators': 161, 'subsample': 0.5558660149214869}, {'colsample_bytree': 0.2602358677407021, 'gamma': 0.24925602248258472, 'learning_rate': 0.15010225023079912, 'max_depth': 2, 'n_estimators': 80, 'subsample': 0.834437363630526}, {'colsample_bytree': 0.7128560334132937, 'gamma': 0.15549417996105563, 'learning_rate': 0.22380749888799892, 'max_depth': 4, 'n_estimators': 83, 'subsample': 0.9723417431926975}, {'colsample_bytree': 0.4757710544950484, 'gamma': 0.3167484248538048, 'learning_rate': 0.24479789383821834, 'max_depth': 3, 'n_estimators': 124, 'subsample': 0.7779921923161196}, {'colsample_bytree': 0.3848465510445366, 'gamma': 0.30172617655144274, 'learning_rate': 0.19731560275587137, 'max_depth': 4, 'n_estimators': 146, 'subsample': 0.7144142063384938}, {'colsample_bytree': 0.43657321400054105, 'gamma': 0.34449109389063776, 'learning_rate': 0.2944714067771392, 'max_depth': 4, 'n_estimators': 190, 'subsample': 0.8896670706355643}, {'colsample_bytree': 0. ...
#        -0.02326014, -0.9089778 , -0.83025412, -1.10740298, -0.80682365,
#        -1.34782394, -1.39262283, -0.59409735, -1.65372325, -1.08728482,
#        -1.54533435, -0.88821977, -1.28635136, -1.67285949, -1.46337425,
#        -1.33479645, -1.09828318, -0.43713907, -1.05233615, -2.69995058,
#        -3.14222775, -1.05749812, -1.69674765, -0.24563504, -0.55797328]), 'split1_test_score': array([ 0.00984724, -0.03046937, -0.15735239, -0.08836184,  0.01784683,
#        -0.11429247, -0.07029285, -0.12366152, -0.2521783 , -0.70698685,
#        -0.09910991, -0.17789118, -0.22679258, -0.18849007, -0.06801256,
#        -0.06410771, -0.01583207, -0.17140822, -0.33455274, -0.1253969 ,
#        -0.00775981, -0.0649379 , -0.11385732, -0.14605769, -0.03644967,
#        -0.02360751, -0.26811348, -0.15058012, -0.26090467,  0.02584366]), 'split2_test_score': array([-0.30277181, -0.17586005, -0.3369299 , -0.1338803 , -0.19707412,
#        -0.29721185, -0.28374206, -0.29090224, -0.40502448,  0.01110412,
#        -0.14210663, -0.2726595 , -0.15985222, -0.32091552, -0.21738368,
#        -0.20119564, -0.22749764, -0.23808745, -0.09318458, -0.36580854,
#        -0.26509175, -0.35123022, -0.19104549, -0.14945673, -0.488855  ,
#        -0.19973785, -0.13029309, -0.11660375, -0.08987855, -0.06180709]), 'split3_test_score': array([ 0.00071249,  0.06051097,  0.05912582,  0.17244307,  0.25471325,
#         0.10987682,  0.096357  ,  0.01564421,  0.14263818, -0.01096164,
#        -0.00974282,  0.15856828,  0.18637508, -0.10576379,  0.31256686,
#         0.11941089,  0.16933521,  0.13339403,  0.11715775,  0.16308565,
#         0.05051829,  0.04908123,  0.17921546,  0.0368322 ,  0.10062741,
#         0.20938868,  0.06927225,  0.20357915,  0.13820005,  0.15683946]), 'split4_test_score': array([ 0.02430429, -0.07872192, -0.13808435, -0.02803754, -0.21555723,
#        -0.29079453,  0.05769538,  0.02941828, -0.01319552,  0.20218299,
#        -0.1484382 , -0.07883592, -0.07728078, -0.39074101, -0.05452327,
#         0.07528313, -0.09177433, -0.0451146 , -0.08151579, -0.28306458,
#         0.14291967, -0.12801468,  0.03170059,  0.21643746, -0.23652297,
#        -0.35078953,  0.0208473 ,  0.00112554,  0.23463695,  0.14510639]), 'mean_test_score': array([-0.16702863, -0.2667949 , -0.27561484, -0.2526161 , -0.21601738,
#        -0.12313644, -0.22179207, -0.23995108, -0.32703262, -0.26229701,
#        -0.3494443 , -0.35268823, -0.17432957, -0.53192673, -0.22292749,
#        -0.32318874, -0.21079772, -0.32151352, -0.41299097, -0.41491172,
#        -0.28284201, -0.31867695, -0.10622517, -0.21891618, -0.67223016,
#        -0.70139479, -0.27315703, -0.35184537, -0.04471625, -0.05839817]), 'std_test_score': array([0.2343596 , 0.42817295, 0.29284253, 0.47790857, 0.40020304,
#        0.15669088, 0.36833303, 0.31700655, 0.43353159, 0.41180521,
#        0.50164104, 0.53940725, 0.25246515, 0.56964026, 0.46610238,
#        0.6213404 , 0.3621764 , 0.49874659, 0.64600787, 0.55443093,
#        0.5431382 , 0.41105408, 0.20844981, 0.43810087, 1.03311596,
#        1.23459883, 0.40971279, 0.68376799, 0.20032075, 0.2624595 ]), 'rank_test_score': array([ 5, 15, 17, 13,  8,  4, 10, 12, 22, 14, 23, 25,  6, 28, 11, 21,  7,
#        20, 26, 27, 18, 19,  3,  9, 29, 30, 16, 24,  1,  2], dtype=int32), 'split0_train_score': array([0.97784835, 0.90700092, 0.96074557, 0.91891102, 0.96682546,
#        0.84977555, 0.98306401, 0.95479136, 0.91584454, 0.43104995,
#        0.91895414, 0.97176219, 0.91707181, 0.99073002, 0.93713605,
#        0.95491876, 0.99335968, 0.92520605, 0.97940809, 0.96133969,
#        0.95997109, 0.96302346, 0.82513977, 0.97357594, 0.95454176,
#        0.95854495, 0.90112869, 0.93541439, 0.63012633, 0.95362392]), 'split1_train_score': array([0.9777419 , 0.8888658 , 0.95117241, 0.90377128, 0.96212732,
#        0.81453671, 0.97993124, 0.94106794, 0.89934243, 0.3882988 ,
#        0.90051764, 0.96289897, 0.9089481 , 0.98849061, 0.93773435,
#        0.93791454, 0.9913259 , 0.90836994, 0.96924555, 0.94491547,
#        0.94861572, 0.94866891, 0.79618985, 0.96675529, 0.94161354,
#        0.94984737, 0.88618256, 0.92221984, 0.62073799, 0.94352228]), 'split2_train_score': array([0.97140736, 0.89187451, 0.94474224, 0.90203528, 0.96151017,
#        0.82238042, 0.98016648, 0.93613802, 0.89073639, 0.34709413,
#        0.89093786, 0.96495931, 0.88932392, 0.98963495, 0.9423016 ,
#        0.93727577, 0.98997915, 0.91700029, 0.97425303, 0.94951773,
#        0.94675489, 0.94470503, 0.82050974, 0.96781789, 0.93684023,
#        0.95307543, 0.87875827, 0.92469409, 0.62919075, 0.9360058 ]), 'split3_train_score': array([0.97695199, 0.90093172, 0.94804919, 0.8998817 , 0.96218603,
#        0.8416068 , 0.97924602, 0.94783414, 0.89877951, 0.37101953,
#        0.90680777, 0.96860903, 0.90863548, 0.98950832, 0.92868817,
#        0.93918538, 0.99210493, 0.91774007, 0.97378544, 0.95430043,
#        0.95638083, 0.95725723, 0.82390998, 0.97235182, 0.9426396 ,
#        0.95825774, 0.8700574 , 0.92980347, 0.6100664 , 0.9423553 ]), 'split4_train_score': array([0.97436562, 0.91068131, 0.95826427, 0.91581356, 0.9676339 ,
#        0.83551443, 0.98162243, 0.95286001, 0.90651966, 0.40277651,
#        0.90799488, 0.97456236, 0.91743362, 0.98889041, 0.94472052,
#        0.94866947, 0.99208746, 0.92337851, 0.9751775 , 0.95654413,
#        0.95869477, 0.95076247, 0.8304289 , 0.97513661, 0.95055758,
#        0.95338304, 0.90437698, 0.93252777, 0.61200824, 0.94717292]), 'mean_train_score': array([0.97566304, 0.89987085, 0.95259473, 0.90808257, 0.96405658,
#        0.83276278, 0.98080604, 0.94653829, 0.90224451, 0.38804778,
#        0.90504246, 0.96855837, 0.90828259, 0.98945086, 0.93811614,
#        0.94359278, 0.99177143, 0.91833897, 0.97437392, 0.95332349,
#        0.95408346, 0.95288342, 0.81923565, 0.97112751, 0.94523854,
#        0.95462171, 0.88810078, 0.92893191, 0.62042594, 0.94453605]), 'std_train_score': array([0.00247195, 0.00841287, 0.00604858, 0.00773866, 0.00261416,
#        0.01276876, 0.00136915, 0.00704055, 0.00843923, 0.02840193,
#        0.00921718, 0.0042731 , 0.01020775, 0.00076284, 0.0054978 ,
#        0.00700889, 0.00110855, 0.00590061, 0.00324499, 0.00567036,
#        0.00538165, 0.00649765, 0.01195599, 0.00327526, 0.00640732,
#        0.00332663, 0.01304735, 0.00487285, 0.00835697, 0.00579812])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.7088347650341652
# Gamma: 0.27087930677017713
# Learning_rate: 0.02689693554275291
# Max_depth: 2
# N_estimators: 105
# Subsample: 0.6919667285568886

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(30):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:2.05520	validation_1-rmse:2.33332
# [1]	validation_0-rmse:2.01104	validation_1-rmse:2.29784
# [2]	validation_0-rmse:1.96327	validation_1-rmse:2.25311
# [3]	validation_0-rmse:1.91941	validation_1-rmse:2.22139
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.87552	validation_1-rmse:2.18000
# [5]	validation_0-rmse:1.83695	validation_1-rmse:2.14027
# [6]	validation_0-rmse:1.79926	validation_1-rmse:2.10293
# [7]	validation_0-rmse:1.75954	validation_1-rmse:2.06847
# [8]	validation_0-rmse:1.72195	validation_1-rmse:2.03357
# [9]	validation_0-rmse:1.68581	validation_1-rmse:1.99628
# [10]	validation_0-rmse:1.64738	validation_1-rmse:1.95927
# [11]	validation_0-rmse:1.60897	validation_1-rmse:1.92372
# [12]	validation_0-rmse:1.57399	validation_1-rmse:1.89321
# [13]	validation_0-rmse:1.54211	validation_1-rmse:1.86397
# [14]	validation_0-rmse:1.50987	validation_1-rmse:1.83501
# [15]	validation_0-rmse:1.47856	validation_1-rmse:1.81275
# [16]	validation_0-rmse:1.44824	validation_1-rmse:1.77966
# [17]	validation_0-rmse:1.41945	validation_1-rmse:1.75841
# [18]	validation_0-rmse:1.38872	validation_1-rmse:1.73497
# [19]	validation_0-rmse:1.36046	validation_1-rmse:1.71362
# [20]	validation_0-rmse:1.33414	validation_1-rmse:1.68828
# [21]	validation_0-rmse:1.30692	validation_1-rmse:1.66152
# [22]	validation_0-rmse:1.28059	validation_1-rmse:1.64184
# [23]	validation_0-rmse:1.25576	validation_1-rmse:1.61994
# [24]	validation_0-rmse:1.23054	validation_1-rmse:1.59722
# [25]	validation_0-rmse:1.20464	validation_1-rmse:1.57921
# [26]	validation_0-rmse:1.18037	validation_1-rmse:1.56078
# [27]	validation_0-rmse:1.15813	validation_1-rmse:1.54510
# [28]	validation_0-rmse:1.13731	validation_1-rmse:1.52408
# [29]	validation_0-rmse:1.11688	validation_1-rmse:1.50883
# [30]	validation_0-rmse:1.09701	validation_1-rmse:1.48932
# [31]	validation_0-rmse:1.07753	validation_1-rmse:1.47394
# [32]	validation_0-rmse:1.05871	validation_1-rmse:1.45890
# [33]	validation_0-rmse:1.04046	validation_1-rmse:1.44366
# [34]	validation_0-rmse:1.02075	validation_1-rmse:1.42954
# [35]	validation_0-rmse:1.00198	validation_1-rmse:1.41636
# [36]	validation_0-rmse:0.98466	validation_1-rmse:1.40307
# [37]	validation_0-rmse:0.96961	validation_1-rmse:1.39442
# [38]	validation_0-rmse:0.95672	validation_1-rmse:1.38152
# [39]	validation_0-rmse:0.94228	validation_1-rmse:1.37196
# [40]	validation_0-rmse:0.92765	validation_1-rmse:1.36330
# [41]	validation_0-rmse:0.91459	validation_1-rmse:1.35854
# [42]	validation_0-rmse:0.89877	validation_1-rmse:1.34502
# [43]	validation_0-rmse:0.88521	validation_1-rmse:1.33729
# [44]	validation_0-rmse:0.87090	validation_1-rmse:1.32656
# [45]	validation_0-rmse:0.85912	validation_1-rmse:1.31665
# [46]	validation_0-rmse:0.84587	validation_1-rmse:1.30737
# [47]	validation_0-rmse:0.83477	validation_1-rmse:1.29996
# [48]	validation_0-rmse:0.82226	validation_1-rmse:1.29244
# [49]	validation_0-rmse:0.80982	validation_1-rmse:1.28281
# [50]	validation_0-rmse:0.79680	validation_1-rmse:1.27236
# [51]	validation_0-rmse:0.78597	validation_1-rmse:1.26297
# [52]	validation_0-rmse:0.77609	validation_1-rmse:1.25535
# [53]	validation_0-rmse:0.76604	validation_1-rmse:1.25115
# [54]	validation_0-rmse:0.75707	validation_1-rmse:1.24326
# [55]	validation_0-rmse:0.74754	validation_1-rmse:1.23998
# [56]	validation_0-rmse:0.73896	validation_1-rmse:1.23853
# [57]	validation_0-rmse:0.73111	validation_1-rmse:1.23215
# [58]	validation_0-rmse:0.72173	validation_1-rmse:1.22295
# [59]	validation_0-rmse:0.71293	validation_1-rmse:1.21815
# [60]	validation_0-rmse:0.70366	validation_1-rmse:1.21225
# [61]	validation_0-rmse:0.69544	validation_1-rmse:1.20827
# [62]	validation_0-rmse:0.68844	validation_1-rmse:1.20169
# [63]	validation_0-rmse:0.68208	validation_1-rmse:1.19517
# [64]	validation_0-rmse:0.67491	validation_1-rmse:1.19140
# [65]	validation_0-rmse:0.66786	validation_1-rmse:1.18581
# [66]	validation_0-rmse:0.66092	validation_1-rmse:1.18235
# [67]	validation_0-rmse:0.65561	validation_1-rmse:1.18108
# [68]	validation_0-rmse:0.64796	validation_1-rmse:1.17752
# [69]	validation_0-rmse:0.64203	validation_1-rmse:1.17303
# [70]	validation_0-rmse:0.63662	validation_1-rmse:1.17164
# [71]	validation_0-rmse:0.63011	validation_1-rmse:1.17065
# [72]	validation_0-rmse:0.62379	validation_1-rmse:1.16887
# [73]	validation_0-rmse:0.61793	validation_1-rmse:1.16356
# [74]	validation_0-rmse:0.61165	validation_1-rmse:1.15986
# [75]	validation_0-rmse:0.60597	validation_1-rmse:1.15427
# [76]	validation_0-rmse:0.60035	validation_1-rmse:1.14961
# [77]	validation_0-rmse:0.59470	validation_1-rmse:1.14756
# [78]	validation_0-rmse:0.58950	validation_1-rmse:1.14703
# [79]	validation_0-rmse:0.58403	validation_1-rmse:1.14332
# [80]	validation_0-rmse:0.58091	validation_1-rmse:1.14211
# [81]	validation_0-rmse:0.57572	validation_1-rmse:1.14241
# [82]	validation_0-rmse:0.57130	validation_1-rmse:1.14157
# [83]	validation_0-rmse:0.56762	validation_1-rmse:1.13912
# [84]	validation_0-rmse:0.56329	validation_1-rmse:1.13673
# [85]	validation_0-rmse:0.55881	validation_1-rmse:1.13797
# [86]	validation_0-rmse:0.55535	validation_1-rmse:1.13647
# [87]	validation_0-rmse:0.55039	validation_1-rmse:1.13486
# [88]	validation_0-rmse:0.54727	validation_1-rmse:1.13380
# [89]	validation_0-rmse:0.54276	validation_1-rmse:1.13295
# [90]	validation_0-rmse:0.53895	validation_1-rmse:1.13349
# [91]	validation_0-rmse:0.53528	validation_1-rmse:1.13409
# [92]	validation_0-rmse:0.53238	validation_1-rmse:1.13327
# [93]	validation_0-rmse:0.52966	validation_1-rmse:1.13238
# [94]	validation_0-rmse:0.52755	validation_1-rmse:1.13072
# [95]	validation_0-rmse:0.52409	validation_1-rmse:1.13254
# [96]	validation_0-rmse:0.52228	validation_1-rmse:1.13339
# [97]	validation_0-rmse:0.51880	validation_1-rmse:1.13335
# [98]	validation_0-rmse:0.51602	validation_1-rmse:1.12985
# [99]	validation_0-rmse:0.51282	validation_1-rmse:1.12811
# [100]	validation_0-rmse:0.50981	validation_1-rmse:1.12958
# [101]	validation_0-rmse:0.50796	validation_1-rmse:1.12876
# [102]	validation_0-rmse:0.50615	validation_1-rmse:1.12772
# [103]	validation_0-rmse:0.50292	validation_1-rmse:1.12625
# [104]	validation_0-rmse:0.49960	validation_1-rmse:1.12637
# [0]	validation_0-rmse:2.08169	validation_1-rmse:2.24035
# [1]	validation_0-rmse:2.03416	validation_1-rmse:2.19429
# [2]	validation_0-rmse:1.98764	validation_1-rmse:2.15780
# [3]	validation_0-rmse:1.94690	validation_1-rmse:2.12437
# [4]	validation_0-rmse:1.90425	validation_1-rmse:2.08448
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:1.86415	validation_1-rmse:2.05044
# [6]	validation_0-rmse:1.82361	validation_1-rmse:2.01350
# [7]	validation_0-rmse:1.78244	validation_1-rmse:1.97439
# [8]	validation_0-rmse:1.74479	validation_1-rmse:1.94002
# [9]	validation_0-rmse:1.70630	validation_1-rmse:1.90441
# [10]	validation_0-rmse:1.66795	validation_1-rmse:1.86753
# [11]	validation_0-rmse:1.63201	validation_1-rmse:1.83670
# [12]	validation_0-rmse:1.59876	validation_1-rmse:1.80449
# [13]	validation_0-rmse:1.56592	validation_1-rmse:1.77479
# [14]	validation_0-rmse:1.53590	validation_1-rmse:1.74702
# [15]	validation_0-rmse:1.50416	validation_1-rmse:1.71999
# [16]	validation_0-rmse:1.47212	validation_1-rmse:1.68912
# [17]	validation_0-rmse:1.44293	validation_1-rmse:1.66140
# [18]	validation_0-rmse:1.41422	validation_1-rmse:1.63461
# [19]	validation_0-rmse:1.38513	validation_1-rmse:1.61069
# [20]	validation_0-rmse:1.35953	validation_1-rmse:1.58548
# [21]	validation_0-rmse:1.33740	validation_1-rmse:1.56503
# [22]	validation_0-rmse:1.31265	validation_1-rmse:1.54256
# [23]	validation_0-rmse:1.28911	validation_1-rmse:1.52296
# [24]	validation_0-rmse:1.26284	validation_1-rmse:1.50011
# [25]	validation_0-rmse:1.23955	validation_1-rmse:1.48374
# [26]	validation_0-rmse:1.21876	validation_1-rmse:1.46891
# [27]	validation_0-rmse:1.19580	validation_1-rmse:1.45339
# [28]	validation_0-rmse:1.17436	validation_1-rmse:1.43589
# [29]	validation_0-rmse:1.15314	validation_1-rmse:1.41939
# [30]	validation_0-rmse:1.13225	validation_1-rmse:1.40216
# [31]	validation_0-rmse:1.11169	validation_1-rmse:1.38339
# [32]	validation_0-rmse:1.09140	validation_1-rmse:1.36368
# [33]	validation_0-rmse:1.07081	validation_1-rmse:1.34415
# [34]	validation_0-rmse:1.05140	validation_1-rmse:1.33002
# [35]	validation_0-rmse:1.03320	validation_1-rmse:1.31224
# [36]	validation_0-rmse:1.01608	validation_1-rmse:1.29627
# [37]	validation_0-rmse:0.99978	validation_1-rmse:1.28318
# [38]	validation_0-rmse:0.98314	validation_1-rmse:1.26794
# [39]	validation_0-rmse:0.96834	validation_1-rmse:1.25898
# [40]	validation_0-rmse:0.95287	validation_1-rmse:1.24691
# [41]	validation_0-rmse:0.93907	validation_1-rmse:1.23763
# [42]	validation_0-rmse:0.92590	validation_1-rmse:1.22967
# [43]	validation_0-rmse:0.91044	validation_1-rmse:1.21660
# [44]	validation_0-rmse:0.89834	validation_1-rmse:1.20448
# [45]	validation_0-rmse:0.88693	validation_1-rmse:1.19276
# [46]	validation_0-rmse:0.87187	validation_1-rmse:1.17981
# [47]	validation_0-rmse:0.85862	validation_1-rmse:1.16822
# [48]	validation_0-rmse:0.84665	validation_1-rmse:1.15941
# [49]	validation_0-rmse:0.83476	validation_1-rmse:1.14740
# [50]	validation_0-rmse:0.82479	validation_1-rmse:1.13862
# [51]	validation_0-rmse:0.81415	validation_1-rmse:1.12920
# [52]	validation_0-rmse:0.80428	validation_1-rmse:1.12239
# [53]	validation_0-rmse:0.79415	validation_1-rmse:1.11490
# [54]	validation_0-rmse:0.78369	validation_1-rmse:1.10709
# [55]	validation_0-rmse:0.77475	validation_1-rmse:1.10283
# [56]	validation_0-rmse:0.76682	validation_1-rmse:1.09538
# [57]	validation_0-rmse:0.75744	validation_1-rmse:1.09015
# [58]	validation_0-rmse:0.74857	validation_1-rmse:1.08461
# [59]	validation_0-rmse:0.73978	validation_1-rmse:1.08103
# [60]	validation_0-rmse:0.73252	validation_1-rmse:1.07589
# [61]	validation_0-rmse:0.72433	validation_1-rmse:1.07105
# [62]	validation_0-rmse:0.71883	validation_1-rmse:1.06723
# [63]	validation_0-rmse:0.71078	validation_1-rmse:1.06267
# [64]	validation_0-rmse:0.70230	validation_1-rmse:1.05473
# [65]	validation_0-rmse:0.69689	validation_1-rmse:1.04906
# [66]	validation_0-rmse:0.69075	validation_1-rmse:1.04537
# [67]	validation_0-rmse:0.68413	validation_1-rmse:1.04006
# [68]	validation_0-rmse:0.67873	validation_1-rmse:1.03638
# [69]	validation_0-rmse:0.67312	validation_1-rmse:1.03212
# [70]	validation_0-rmse:0.66738	validation_1-rmse:1.02924
# [71]	validation_0-rmse:0.66049	validation_1-rmse:1.02389
# [72]	validation_0-rmse:0.65573	validation_1-rmse:1.02198
# [73]	validation_0-rmse:0.64862	validation_1-rmse:1.01807
# [74]	validation_0-rmse:0.64218	validation_1-rmse:1.01588
# [75]	validation_0-rmse:0.63649	validation_1-rmse:1.01032
# [76]	validation_0-rmse:0.63290	validation_1-rmse:1.00653
# [77]	validation_0-rmse:0.62822	validation_1-rmse:1.00543
# [78]	validation_0-rmse:0.62338	validation_1-rmse:1.00471
# [79]	validation_0-rmse:0.61901	validation_1-rmse:1.00084
# [80]	validation_0-rmse:0.61515	validation_1-rmse:1.00147
# [81]	validation_0-rmse:0.61084	validation_1-rmse:0.99834
# [82]	validation_0-rmse:0.60581	validation_1-rmse:0.99743
# [83]	validation_0-rmse:0.60165	validation_1-rmse:0.99539
# [84]	validation_0-rmse:0.59797	validation_1-rmse:0.99564
# [85]	validation_0-rmse:0.59405	validation_1-rmse:0.99700
# [86]	validation_0-rmse:0.59058	validation_1-rmse:0.99387
# [87]	validation_0-rmse:0.58654	validation_1-rmse:0.99125
# [88]	validation_0-rmse:0.58281	validation_1-rmse:0.98613
# [89]	validation_0-rmse:0.57956	validation_1-rmse:0.98524
# [90]	validation_0-rmse:0.57682	validation_1-rmse:0.98411
# [91]	validation_0-rmse:0.57357	validation_1-rmse:0.98366
# [92]	validation_0-rmse:0.57086	validation_1-rmse:0.98187
# [93]	validation_0-rmse:0.56736	validation_1-rmse:0.98142
# [94]	validation_0-rmse:0.56416	validation_1-rmse:0.97925
# [95]	validation_0-rmse:0.56016	validation_1-rmse:0.97943
# [96]	validation_0-rmse:0.55724	validation_1-rmse:0.97985
# [97]	validation_0-rmse:0.55458	validation_1-rmse:0.97871
# [98]	validation_0-rmse:0.55113	validation_1-rmse:0.97702
# [99]	validation_0-rmse:0.54834	validation_1-rmse:0.97510
# [100]	validation_0-rmse:0.54568	validation_1-rmse:0.97453
# [101]	validation_0-rmse:0.54348	validation_1-rmse:0.97167
# [102]	validation_0-rmse:0.54053	validation_1-rmse:0.97011
# [103]	validation_0-rmse:0.53792	validation_1-rmse:0.96897
# [104]	validation_0-rmse:0.53491	validation_1-rmse:0.96889
# [0]	validation_0-rmse:2.09295	validation_1-rmse:2.18294
# [1]	validation_0-rmse:2.04311	validation_1-rmse:2.13015
# [2]	validation_0-rmse:1.99961	validation_1-rmse:2.08538
# [3]	validation_0-rmse:1.94867	validation_1-rmse:2.04137
# [4]	validation_0-rmse:1.90720	validation_1-rmse:2.00488
# [5]	validation_0-rmse:1.86551	validation_1-rmse:1.96730
# [6]	validation_0-rmse:1.82107	validation_1-rmse:1.91934
# [7]	validation_0-rmse:1.77922	validation_1-rmse:1.87964
# [8]	validation_0-rmse:1.73967	validation_1-rmse:1.84968
# [9]	validation_0-rmse:1.70200	validation_1-rmse:1.81293
# [10]	validation_0-rmse:1.66599	validation_1-rmse:1.78493
# [11]	validation_0-rmse:1.63275	validation_1-rmse:1.75573
# [12]	validation_0-rmse:1.59777	validation_1-rmse:1.72753
# [13]	validation_0-rmse:1.56416	validation_1-rmse:1.69364
# [14]	validation_0-rmse:1.53198	validation_1-rmse:1.66810
# [15]	validation_0-rmse:1.49927	validation_1-rmse:1.64240
# [16]	validation_0-rmse:1.46646	validation_1-rmse:1.61121
# [17]	validation_0-rmse:1.43763	validation_1-rmse:1.59238
# [18]	validation_0-rmse:1.40815	validation_1-rmse:1.56846
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [19]	validation_0-rmse:1.37656	validation_1-rmse:1.54579
# [20]	validation_0-rmse:1.34825	validation_1-rmse:1.52081
# [21]	validation_0-rmse:1.31723	validation_1-rmse:1.50160
# [22]	validation_0-rmse:1.29136	validation_1-rmse:1.48941
# [23]	validation_0-rmse:1.26392	validation_1-rmse:1.46605
# [24]	validation_0-rmse:1.24111	validation_1-rmse:1.44553
# [25]	validation_0-rmse:1.21559	validation_1-rmse:1.42977
# [26]	validation_0-rmse:1.19410	validation_1-rmse:1.41113
# [27]	validation_0-rmse:1.16928	validation_1-rmse:1.39162
# [28]	validation_0-rmse:1.14721	validation_1-rmse:1.38040
# [29]	validation_0-rmse:1.12536	validation_1-rmse:1.36436
# [30]	validation_0-rmse:1.10559	validation_1-rmse:1.34978
# [31]	validation_0-rmse:1.08549	validation_1-rmse:1.33476
# [32]	validation_0-rmse:1.06608	validation_1-rmse:1.31983
# [33]	validation_0-rmse:1.04766	validation_1-rmse:1.30982
# [34]	validation_0-rmse:1.02819	validation_1-rmse:1.29552
# [35]	validation_0-rmse:1.00993	validation_1-rmse:1.28675
# [36]	validation_0-rmse:0.99389	validation_1-rmse:1.27445
# [37]	validation_0-rmse:0.97720	validation_1-rmse:1.26222
# [38]	validation_0-rmse:0.96073	validation_1-rmse:1.25717
# [39]	validation_0-rmse:0.94430	validation_1-rmse:1.25121
# [40]	validation_0-rmse:0.92885	validation_1-rmse:1.24356
# [41]	validation_0-rmse:0.91394	validation_1-rmse:1.23833
# [42]	validation_0-rmse:0.89957	validation_1-rmse:1.22898
# [43]	validation_0-rmse:0.88899	validation_1-rmse:1.22243
# [44]	validation_0-rmse:0.87611	validation_1-rmse:1.21438
# [45]	validation_0-rmse:0.86578	validation_1-rmse:1.20906
# [46]	validation_0-rmse:0.85380	validation_1-rmse:1.20207
# [47]	validation_0-rmse:0.84106	validation_1-rmse:1.19537
# [48]	validation_0-rmse:0.82747	validation_1-rmse:1.19453
# [49]	validation_0-rmse:0.81830	validation_1-rmse:1.18903
# [50]	validation_0-rmse:0.80747	validation_1-rmse:1.18340
# [51]	validation_0-rmse:0.79639	validation_1-rmse:1.17785
# [52]	validation_0-rmse:0.78822	validation_1-rmse:1.17450
# [53]	validation_0-rmse:0.77885	validation_1-rmse:1.16864
# [54]	validation_0-rmse:0.76959	validation_1-rmse:1.16393
# [55]	validation_0-rmse:0.76033	validation_1-rmse:1.16554
# [56]	validation_0-rmse:0.75166	validation_1-rmse:1.16486
# [57]	validation_0-rmse:0.74315	validation_1-rmse:1.16359
# [58]	validation_0-rmse:0.73351	validation_1-rmse:1.16165
# [59]	validation_0-rmse:0.72615	validation_1-rmse:1.15835
# [60]	validation_0-rmse:0.71859	validation_1-rmse:1.15465
# [61]	validation_0-rmse:0.71143	validation_1-rmse:1.15158
# [62]	validation_0-rmse:0.70312	validation_1-rmse:1.14866
# [63]	validation_0-rmse:0.69589	validation_1-rmse:1.14849
# [64]	validation_0-rmse:0.69098	validation_1-rmse:1.14587
# [65]	validation_0-rmse:0.68262	validation_1-rmse:1.14633
# [66]	validation_0-rmse:0.67520	validation_1-rmse:1.14875
# [67]	validation_0-rmse:0.66870	validation_1-rmse:1.15106
# [68]	validation_0-rmse:0.66307	validation_1-rmse:1.14976
# [69]	validation_0-rmse:0.65632	validation_1-rmse:1.15248
# [70]	validation_0-rmse:0.65010	validation_1-rmse:1.15382
# [71]	validation_0-rmse:0.64439	validation_1-rmse:1.15074
# [72]	validation_0-rmse:0.63837	validation_1-rmse:1.14773
# [73]	validation_0-rmse:0.63312	validation_1-rmse:1.14441
# [74]	validation_0-rmse:0.62812	validation_1-rmse:1.14362
# [75]	validation_0-rmse:0.62340	validation_1-rmse:1.14293
# [76]	validation_0-rmse:0.61786	validation_1-rmse:1.14201
# [77]	validation_0-rmse:0.61345	validation_1-rmse:1.14280
# [78]	validation_0-rmse:0.60824	validation_1-rmse:1.14054
# [79]	validation_0-rmse:0.60371	validation_1-rmse:1.13997
# [80]	validation_0-rmse:0.59973	validation_1-rmse:1.14045
# [81]	validation_0-rmse:0.59415	validation_1-rmse:1.13873
# [82]	validation_0-rmse:0.58980	validation_1-rmse:1.13716
# [83]	validation_0-rmse:0.58532	validation_1-rmse:1.13591
# [84]	validation_0-rmse:0.58093	validation_1-rmse:1.13771
# [85]	validation_0-rmse:0.57782	validation_1-rmse:1.13793
# [86]	validation_0-rmse:0.57419	validation_1-rmse:1.14065
# [87]	validation_0-rmse:0.57080	validation_1-rmse:1.14051
# [88]	validation_0-rmse:0.56789	validation_1-rmse:1.13939
# [89]	validation_0-rmse:0.56454	validation_1-rmse:1.13760
# [90]	validation_0-rmse:0.56195	validation_1-rmse:1.13986
# [91]	validation_0-rmse:0.55800	validation_1-rmse:1.13993
# [92]	validation_0-rmse:0.55495	validation_1-rmse:1.14129
# [93]	validation_0-rmse:0.55265	validation_1-rmse:1.13811
# [94]	validation_0-rmse:0.54869	validation_1-rmse:1.13765
# [95]	validation_0-rmse:0.54562	validation_1-rmse:1.13777
# [96]	validation_0-rmse:0.54184	validation_1-rmse:1.13694
# [97]	validation_0-rmse:0.53945	validation_1-rmse:1.14063
# [98]	validation_0-rmse:0.53580	validation_1-rmse:1.14341
# [99]	validation_0-rmse:0.53287	validation_1-rmse:1.14588
# [100]	validation_0-rmse:0.53102	validation_1-rmse:1.14775
# [101]	validation_0-rmse:0.52939	validation_1-rmse:1.14886
# [102]	validation_0-rmse:0.52618	validation_1-rmse:1.14914
# [0]	validation_0-rmse:2.10983	validation_1-rmse:2.11878
# [1]	validation_0-rmse:2.06255	validation_1-rmse:2.06827
# [2]	validation_0-rmse:2.01534	validation_1-rmse:2.01937
# [3]	validation_0-rmse:1.97291	validation_1-rmse:1.97499
# [4]	validation_0-rmse:1.93052	validation_1-rmse:1.92817
# [5]	validation_0-rmse:1.88966	validation_1-rmse:1.88405
# [6]	validation_0-rmse:1.84878	validation_1-rmse:1.84061
# [7]	validation_0-rmse:1.80684	validation_1-rmse:1.80072
# [8]	validation_0-rmse:1.76874	validation_1-rmse:1.75804
# [9]	validation_0-rmse:1.73228	validation_1-rmse:1.72271
# [10]	validation_0-rmse:1.69851	validation_1-rmse:1.68719
# [11]	validation_0-rmse:1.66394	validation_1-rmse:1.65530
# [12]	validation_0-rmse:1.63061	validation_1-rmse:1.62486
# [13]	validation_0-rmse:1.59399	validation_1-rmse:1.58991
# [14]	validation_0-rmse:1.56190	validation_1-rmse:1.55395
# [15]	validation_0-rmse:1.53047	validation_1-rmse:1.52323
# [16]	validation_0-rmse:1.49932	validation_1-rmse:1.49013
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [17]	validation_0-rmse:1.47186	validation_1-rmse:1.46107
# [18]	validation_0-rmse:1.43990	validation_1-rmse:1.42722
# [19]	validation_0-rmse:1.41190	validation_1-rmse:1.39717
# [20]	validation_0-rmse:1.38652	validation_1-rmse:1.37171
# [21]	validation_0-rmse:1.35981	validation_1-rmse:1.34410
# [22]	validation_0-rmse:1.33344	validation_1-rmse:1.31436
# [23]	validation_0-rmse:1.30984	validation_1-rmse:1.28411
# [24]	validation_0-rmse:1.28273	validation_1-rmse:1.25542
# [25]	validation_0-rmse:1.26143	validation_1-rmse:1.23462
# [26]	validation_0-rmse:1.24000	validation_1-rmse:1.21650
# [27]	validation_0-rmse:1.21914	validation_1-rmse:1.20070
# [28]	validation_0-rmse:1.19798	validation_1-rmse:1.18393
# [29]	validation_0-rmse:1.17889	validation_1-rmse:1.16560
# [30]	validation_0-rmse:1.15711	validation_1-rmse:1.14539
# [31]	validation_0-rmse:1.14004	validation_1-rmse:1.12843
# [32]	validation_0-rmse:1.12367	validation_1-rmse:1.11518
# [33]	validation_0-rmse:1.10694	validation_1-rmse:1.09674
# [34]	validation_0-rmse:1.08997	validation_1-rmse:1.07526
# [35]	validation_0-rmse:1.07498	validation_1-rmse:1.06203
# [36]	validation_0-rmse:1.05653	validation_1-rmse:1.04186
# [37]	validation_0-rmse:1.03929	validation_1-rmse:1.02507
# [38]	validation_0-rmse:1.02398	validation_1-rmse:1.01400
# [39]	validation_0-rmse:1.00712	validation_1-rmse:0.99511
# [40]	validation_0-rmse:0.99614	validation_1-rmse:0.98391
# [41]	validation_0-rmse:0.98318	validation_1-rmse:0.97007
# [42]	validation_0-rmse:0.96871	validation_1-rmse:0.95447
# [43]	validation_0-rmse:0.95365	validation_1-rmse:0.94395
# [44]	validation_0-rmse:0.94333	validation_1-rmse:0.93445
# [45]	validation_0-rmse:0.93027	validation_1-rmse:0.92355
# [46]	validation_0-rmse:0.91896	validation_1-rmse:0.91022
# [47]	validation_0-rmse:0.90845	validation_1-rmse:0.89950
# [48]	validation_0-rmse:0.89739	validation_1-rmse:0.89479
# [49]	validation_0-rmse:0.88391	validation_1-rmse:0.88298
# [50]	validation_0-rmse:0.87285	validation_1-rmse:0.87254
# [51]	validation_0-rmse:0.86363	validation_1-rmse:0.86315
# [52]	validation_0-rmse:0.85130	validation_1-rmse:0.85293
# [53]	validation_0-rmse:0.83963	validation_1-rmse:0.84384
# [54]	validation_0-rmse:0.83012	validation_1-rmse:0.83422
# [55]	validation_0-rmse:0.82142	validation_1-rmse:0.82844
# [56]	validation_0-rmse:0.81454	validation_1-rmse:0.82309
# [57]	validation_0-rmse:0.80598	validation_1-rmse:0.81683
# [58]	validation_0-rmse:0.79604	validation_1-rmse:0.80638
# [59]	validation_0-rmse:0.79009	validation_1-rmse:0.80221
# [60]	validation_0-rmse:0.78335	validation_1-rmse:0.79244
# [61]	validation_0-rmse:0.77516	validation_1-rmse:0.78391
# [62]	validation_0-rmse:0.76769	validation_1-rmse:0.77385
# [63]	validation_0-rmse:0.76212	validation_1-rmse:0.77029
# [64]	validation_0-rmse:0.75586	validation_1-rmse:0.76324
# [65]	validation_0-rmse:0.74989	validation_1-rmse:0.76456
# [66]	validation_0-rmse:0.74471	validation_1-rmse:0.76007
# [67]	validation_0-rmse:0.73833	validation_1-rmse:0.75608
# [68]	validation_0-rmse:0.73209	validation_1-rmse:0.75322
# [69]	validation_0-rmse:0.72723	validation_1-rmse:0.74812
# [70]	validation_0-rmse:0.72046	validation_1-rmse:0.74752
# [71]	validation_0-rmse:0.71386	validation_1-rmse:0.74305
# [72]	validation_0-rmse:0.70927	validation_1-rmse:0.74549
# [73]	validation_0-rmse:0.70431	validation_1-rmse:0.74068
# [74]	validation_0-rmse:0.69973	validation_1-rmse:0.73720
# [75]	validation_0-rmse:0.69419	validation_1-rmse:0.73336
# [76]	validation_0-rmse:0.69055	validation_1-rmse:0.72950
# [77]	validation_0-rmse:0.68676	validation_1-rmse:0.72851
# [78]	validation_0-rmse:0.68231	validation_1-rmse:0.72146
# [79]	validation_0-rmse:0.67811	validation_1-rmse:0.71809
# [80]	validation_0-rmse:0.67443	validation_1-rmse:0.71899
# [81]	validation_0-rmse:0.67102	validation_1-rmse:0.71552
# [82]	validation_0-rmse:0.66669	validation_1-rmse:0.71479
# [83]	validation_0-rmse:0.66246	validation_1-rmse:0.71367
# [84]	validation_0-rmse:0.65892	validation_1-rmse:0.71060
# [85]	validation_0-rmse:0.65456	validation_1-rmse:0.70663
# [86]	validation_0-rmse:0.64956	validation_1-rmse:0.70500
# [87]	validation_0-rmse:0.64638	validation_1-rmse:0.70373
# [88]	validation_0-rmse:0.64324	validation_1-rmse:0.70234
# [89]	validation_0-rmse:0.63978	validation_1-rmse:0.70196
# [90]	validation_0-rmse:0.63641	validation_1-rmse:0.69764
# [91]	validation_0-rmse:0.63394	validation_1-rmse:0.69446
# [92]	validation_0-rmse:0.63095	validation_1-rmse:0.69485
# [93]	validation_0-rmse:0.62715	validation_1-rmse:0.69257
# [94]	validation_0-rmse:0.62367	validation_1-rmse:0.69118
# [95]	validation_0-rmse:0.62081	validation_1-rmse:0.69129
# [96]	validation_0-rmse:0.61853	validation_1-rmse:0.69139
# [97]	validation_0-rmse:0.61528	validation_1-rmse:0.69360
# [98]	validation_0-rmse:0.61267	validation_1-rmse:0.69385
# [99]	validation_0-rmse:0.61024	validation_1-rmse:0.69554
# [100]	validation_0-rmse:0.60759	validation_1-rmse:0.69267
# [101]	validation_0-rmse:0.60420	validation_1-rmse:0.69337
# [102]	validation_0-rmse:0.60127	validation_1-rmse:0.69323
# [103]	validation_0-rmse:0.59790	validation_1-rmse:0.69327
# [104]	validation_0-rmse:0.59560	validation_1-rmse:0.68720
# [0]	validation_0-rmse:2.09612	validation_1-rmse:2.16944
# [1]	validation_0-rmse:2.04892	validation_1-rmse:2.12307
# [2]	validation_0-rmse:2.00271	validation_1-rmse:2.07926
# [3]	validation_0-rmse:1.95611	validation_1-rmse:2.03650
# [4]	validation_0-rmse:1.91238	validation_1-rmse:1.99135
# [5]	validation_0-rmse:1.87000	validation_1-rmse:1.95643
# [6]	validation_0-rmse:1.83154	validation_1-rmse:1.92182
# [7]	validation_0-rmse:1.79426	validation_1-rmse:1.88792
# [8]	validation_0-rmse:1.75603	validation_1-rmse:1.85127
# [9]	validation_0-rmse:1.71778	validation_1-rmse:1.81398
# [10]	validation_0-rmse:1.68456	validation_1-rmse:1.78609
# [11]	validation_0-rmse:1.64847	validation_1-rmse:1.76030
# [12]	validation_0-rmse:1.61309	validation_1-rmse:1.72689
# [13]	validation_0-rmse:1.57865	validation_1-rmse:1.69699
# [14]	validation_0-rmse:1.54495	validation_1-rmse:1.66434
# [15]	validation_0-rmse:1.51504	validation_1-rmse:1.63621
# [16]	validation_0-rmse:1.48507	validation_1-rmse:1.61090
# [17]	validation_0-rmse:1.45676	validation_1-rmse:1.58543
# [18]	validation_0-rmse:1.42626	validation_1-rmse:1.56171
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [19]	validation_0-rmse:1.40035	validation_1-rmse:1.53938
# [20]	validation_0-rmse:1.37177	validation_1-rmse:1.51297
# [21]	validation_0-rmse:1.34634	validation_1-rmse:1.49138
# [22]	validation_0-rmse:1.32013	validation_1-rmse:1.46756
# [23]	validation_0-rmse:1.29446	validation_1-rmse:1.44627
# [24]	validation_0-rmse:1.27008	validation_1-rmse:1.42574
# [25]	validation_0-rmse:1.24879	validation_1-rmse:1.40836
# [26]	validation_0-rmse:1.22386	validation_1-rmse:1.38217
# [27]	validation_0-rmse:1.19922	validation_1-rmse:1.35840
# [28]	validation_0-rmse:1.17446	validation_1-rmse:1.33445
# [29]	validation_0-rmse:1.15489	validation_1-rmse:1.31253
# [30]	validation_0-rmse:1.13455	validation_1-rmse:1.29196
# [31]	validation_0-rmse:1.11504	validation_1-rmse:1.27257
# [32]	validation_0-rmse:1.09555	validation_1-rmse:1.26452
# [33]	validation_0-rmse:1.07906	validation_1-rmse:1.24857
# [34]	validation_0-rmse:1.06116	validation_1-rmse:1.22947
# [35]	validation_0-rmse:1.04217	validation_1-rmse:1.21566
# [36]	validation_0-rmse:1.02488	validation_1-rmse:1.19985
# [37]	validation_0-rmse:1.00834	validation_1-rmse:1.18521
# [38]	validation_0-rmse:0.99455	validation_1-rmse:1.17253
# [39]	validation_0-rmse:0.97856	validation_1-rmse:1.16359
# [40]	validation_0-rmse:0.96260	validation_1-rmse:1.15122
# [41]	validation_0-rmse:0.94902	validation_1-rmse:1.14088
# [42]	validation_0-rmse:0.93584	validation_1-rmse:1.12863
# [43]	validation_0-rmse:0.92276	validation_1-rmse:1.11728
# [44]	validation_0-rmse:0.91005	validation_1-rmse:1.10548
# [45]	validation_0-rmse:0.89799	validation_1-rmse:1.09618
# [46]	validation_0-rmse:0.88782	validation_1-rmse:1.09026
# [47]	validation_0-rmse:0.87687	validation_1-rmse:1.07991
# [48]	validation_0-rmse:0.86652	validation_1-rmse:1.07264
# [49]	validation_0-rmse:0.85352	validation_1-rmse:1.06643
# [50]	validation_0-rmse:0.84326	validation_1-rmse:1.06095
# [51]	validation_0-rmse:0.83214	validation_1-rmse:1.05246
# [52]	validation_0-rmse:0.82113	validation_1-rmse:1.04549
# [53]	validation_0-rmse:0.81065	validation_1-rmse:1.03876
# [54]	validation_0-rmse:0.80270	validation_1-rmse:1.03392
# [55]	validation_0-rmse:0.79227	validation_1-rmse:1.02703
# [56]	validation_0-rmse:0.78343	validation_1-rmse:1.02003
# [57]	validation_0-rmse:0.77462	validation_1-rmse:1.01362
# [58]	validation_0-rmse:0.76557	validation_1-rmse:1.00492
# [59]	validation_0-rmse:0.75858	validation_1-rmse:1.00230
# [60]	validation_0-rmse:0.75097	validation_1-rmse:0.99582
# [61]	validation_0-rmse:0.74011	validation_1-rmse:0.98820
# [62]	validation_0-rmse:0.73445	validation_1-rmse:0.98516
# [63]	validation_0-rmse:0.72860	validation_1-rmse:0.98142
# [64]	validation_0-rmse:0.72171	validation_1-rmse:0.97642
# [65]	validation_0-rmse:0.71512	validation_1-rmse:0.96975
# [66]	validation_0-rmse:0.70802	validation_1-rmse:0.96523
# [67]	validation_0-rmse:0.70228	validation_1-rmse:0.96148
# [68]	validation_0-rmse:0.69570	validation_1-rmse:0.95820
# [69]	validation_0-rmse:0.69073	validation_1-rmse:0.95669
# [70]	validation_0-rmse:0.68322	validation_1-rmse:0.95272
# [71]	validation_0-rmse:0.67656	validation_1-rmse:0.94816
# [72]	validation_0-rmse:0.67139	validation_1-rmse:0.94593
# [73]	validation_0-rmse:0.66520	validation_1-rmse:0.94575
# [74]	validation_0-rmse:0.65857	validation_1-rmse:0.94484
# [75]	validation_0-rmse:0.65245	validation_1-rmse:0.94354
# [76]	validation_0-rmse:0.64653	validation_1-rmse:0.94102
# [77]	validation_0-rmse:0.64208	validation_1-rmse:0.94091
# [78]	validation_0-rmse:0.63858	validation_1-rmse:0.93538
# [79]	validation_0-rmse:0.63465	validation_1-rmse:0.93342
# [80]	validation_0-rmse:0.63069	validation_1-rmse:0.93510
# [81]	validation_0-rmse:0.62578	validation_1-rmse:0.93359
# [82]	validation_0-rmse:0.62171	validation_1-rmse:0.93684
# [83]	validation_0-rmse:0.61569	validation_1-rmse:0.93278
# [84]	validation_0-rmse:0.61108	validation_1-rmse:0.93084
# [85]	validation_0-rmse:0.60724	validation_1-rmse:0.93153
# [86]	validation_0-rmse:0.60227	validation_1-rmse:0.93238
# [87]	validation_0-rmse:0.59896	validation_1-rmse:0.93133
# [88]	validation_0-rmse:0.59547	validation_1-rmse:0.93026
# [89]	validation_0-rmse:0.59162	validation_1-rmse:0.92857
# [90]	validation_0-rmse:0.58668	validation_1-rmse:0.92860
# [91]	validation_0-rmse:0.58407	validation_1-rmse:0.92896
# [92]	validation_0-rmse:0.58077	validation_1-rmse:0.92846
# [93]	validation_0-rmse:0.57680	validation_1-rmse:0.92554
# [94]	validation_0-rmse:0.57469	validation_1-rmse:0.92622
# [95]	validation_0-rmse:0.57042	validation_1-rmse:0.92628
# [96]	validation_0-rmse:0.56649	validation_1-rmse:0.92448
# [97]	validation_0-rmse:0.56339	validation_1-rmse:0.92447
# [98]	validation_0-rmse:0.56077	validation_1-rmse:0.92304
# [99]	validation_0-rmse:0.55689	validation_1-rmse:0.92655
# [100]	validation_0-rmse:0.55434	validation_1-rmse:0.92626
# [101]	validation_0-rmse:0.54978	validation_1-rmse:0.92662
# [102]	validation_0-rmse:0.54586	validation_1-rmse:0.92960
# [103]	validation_0-rmse:0.54199	validation_1-rmse:0.92909
# [104]	validation_0-rmse:0.53926	validation_1-rmse:0.92449
# [0]	validation_0-rmse:2.15202	validation_1-rmse:1.95869
# [1]	validation_0-rmse:2.10292	validation_1-rmse:1.91133
# [2]	validation_0-rmse:2.05542	validation_1-rmse:1.86319
# [3]	validation_0-rmse:2.01213	validation_1-rmse:1.81922
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.96615	validation_1-rmse:1.77214
# [5]	validation_0-rmse:1.92475	validation_1-rmse:1.73015
# [6]	validation_0-rmse:1.88302	validation_1-rmse:1.69003
# [7]	validation_0-rmse:1.84076	validation_1-rmse:1.64821
# [8]	validation_0-rmse:1.79952	validation_1-rmse:1.60931
# [9]	validation_0-rmse:1.75897	validation_1-rmse:1.57010
# [10]	validation_0-rmse:1.72314	validation_1-rmse:1.53619
# [11]	validation_0-rmse:1.68976	validation_1-rmse:1.50627
# [12]	validation_0-rmse:1.65264	validation_1-rmse:1.47335
# [13]	validation_0-rmse:1.61790	validation_1-rmse:1.43910
# [14]	validation_0-rmse:1.58543	validation_1-rmse:1.40655
# [15]	validation_0-rmse:1.55122	validation_1-rmse:1.37348
# [16]	validation_0-rmse:1.51893	validation_1-rmse:1.34483
# [17]	validation_0-rmse:1.48782	validation_1-rmse:1.31664
# [18]	validation_0-rmse:1.45926	validation_1-rmse:1.29535
# [19]	validation_0-rmse:1.43201	validation_1-rmse:1.26936
# [20]	validation_0-rmse:1.40475	validation_1-rmse:1.24834
# [21]	validation_0-rmse:1.37678	validation_1-rmse:1.22256
# [22]	validation_0-rmse:1.34902	validation_1-rmse:1.19837
# [23]	validation_0-rmse:1.32264	validation_1-rmse:1.17657
# [24]	validation_0-rmse:1.29869	validation_1-rmse:1.15403
# [25]	validation_0-rmse:1.27380	validation_1-rmse:1.13587
# [26]	validation_0-rmse:1.24888	validation_1-rmse:1.11319
# [27]	validation_0-rmse:1.22891	validation_1-rmse:1.09626
# [28]	validation_0-rmse:1.20515	validation_1-rmse:1.07790
# [29]	validation_0-rmse:1.18399	validation_1-rmse:1.05948
# [30]	validation_0-rmse:1.16278	validation_1-rmse:1.04049
# [31]	validation_0-rmse:1.14103	validation_1-rmse:1.02315
# [32]	validation_0-rmse:1.12335	validation_1-rmse:1.01413
# [33]	validation_0-rmse:1.10630	validation_1-rmse:1.00156
# [34]	validation_0-rmse:1.08792	validation_1-rmse:0.98479
# [35]	validation_0-rmse:1.07204	validation_1-rmse:0.97616
# [36]	validation_0-rmse:1.05515	validation_1-rmse:0.96154
# [37]	validation_0-rmse:1.03829	validation_1-rmse:0.94675
# [38]	validation_0-rmse:1.02241	validation_1-rmse:0.93411
# [39]	validation_0-rmse:1.00570	validation_1-rmse:0.92136
# [40]	validation_0-rmse:0.98975	validation_1-rmse:0.91009
# [41]	validation_0-rmse:0.97686	validation_1-rmse:0.90087
# [42]	validation_0-rmse:0.96344	validation_1-rmse:0.89251
# [43]	validation_0-rmse:0.95034	validation_1-rmse:0.88284
# [44]	validation_0-rmse:0.93655	validation_1-rmse:0.87794
# [45]	validation_0-rmse:0.92151	validation_1-rmse:0.86777
# [46]	validation_0-rmse:0.90786	validation_1-rmse:0.85993
# [47]	validation_0-rmse:0.89520	validation_1-rmse:0.85552
# [48]	validation_0-rmse:0.88421	validation_1-rmse:0.85153
# [49]	validation_0-rmse:0.87385	validation_1-rmse:0.84510
# [50]	validation_0-rmse:0.86001	validation_1-rmse:0.83752
# [51]	validation_0-rmse:0.84904	validation_1-rmse:0.82913
# [52]	validation_0-rmse:0.83702	validation_1-rmse:0.82338
# [53]	validation_0-rmse:0.82520	validation_1-rmse:0.82131
# [54]	validation_0-rmse:0.81705	validation_1-rmse:0.81775
# [55]	validation_0-rmse:0.80691	validation_1-rmse:0.81364
# [56]	validation_0-rmse:0.79838	validation_1-rmse:0.80994
# [57]	validation_0-rmse:0.78802	validation_1-rmse:0.80772
# [58]	validation_0-rmse:0.77962	validation_1-rmse:0.80493
# [59]	validation_0-rmse:0.76960	validation_1-rmse:0.79998
# [60]	validation_0-rmse:0.76169	validation_1-rmse:0.79821
# [61]	validation_0-rmse:0.75546	validation_1-rmse:0.79335
# [62]	validation_0-rmse:0.74749	validation_1-rmse:0.79098
# [63]	validation_0-rmse:0.74081	validation_1-rmse:0.79095
# [64]	validation_0-rmse:0.73529	validation_1-rmse:0.78991
# [65]	validation_0-rmse:0.72940	validation_1-rmse:0.78806
# [66]	validation_0-rmse:0.72264	validation_1-rmse:0.78222
# [67]	validation_0-rmse:0.71585	validation_1-rmse:0.78107
# [68]	validation_0-rmse:0.71080	validation_1-rmse:0.77584
# [69]	validation_0-rmse:0.70487	validation_1-rmse:0.77331
# [70]	validation_0-rmse:0.69952	validation_1-rmse:0.77201
# [71]	validation_0-rmse:0.69297	validation_1-rmse:0.77085
# [72]	validation_0-rmse:0.68651	validation_1-rmse:0.77214
# [73]	validation_0-rmse:0.68090	validation_1-rmse:0.77268
# [74]	validation_0-rmse:0.67508	validation_1-rmse:0.77233
# [75]	validation_0-rmse:0.66899	validation_1-rmse:0.77309
# [76]	validation_0-rmse:0.66306	validation_1-rmse:0.77099
# [77]	validation_0-rmse:0.65789	validation_1-rmse:0.77281
# [78]	validation_0-rmse:0.65424	validation_1-rmse:0.77317
# [79]	validation_0-rmse:0.64864	validation_1-rmse:0.76852
# [80]	validation_0-rmse:0.64278	validation_1-rmse:0.76904
# [81]	validation_0-rmse:0.63939	validation_1-rmse:0.76724
# [82]	validation_0-rmse:0.63614	validation_1-rmse:0.76620
# [83]	validation_0-rmse:0.63111	validation_1-rmse:0.76653
# [84]	validation_0-rmse:0.62676	validation_1-rmse:0.76630
# [85]	validation_0-rmse:0.62333	validation_1-rmse:0.76316
# [86]	validation_0-rmse:0.61904	validation_1-rmse:0.76281
# [87]	validation_0-rmse:0.61697	validation_1-rmse:0.76235
# [88]	validation_0-rmse:0.61384	validation_1-rmse:0.75948
# [89]	validation_0-rmse:0.60936	validation_1-rmse:0.76089
# [90]	validation_0-rmse:0.60534	validation_1-rmse:0.75995
# [91]	validation_0-rmse:0.60122	validation_1-rmse:0.76048
# [92]	validation_0-rmse:0.59793	validation_1-rmse:0.75936
# [93]	validation_0-rmse:0.59606	validation_1-rmse:0.76079
# [94]	validation_0-rmse:0.59369	validation_1-rmse:0.76109
# [95]	validation_0-rmse:0.59004	validation_1-rmse:0.76022
# [96]	validation_0-rmse:0.58560	validation_1-rmse:0.76194
# [97]	validation_0-rmse:0.58129	validation_1-rmse:0.76208
# [98]	validation_0-rmse:0.57883	validation_1-rmse:0.76210
# [99]	validation_0-rmse:0.57552	validation_1-rmse:0.76225
# [100]	validation_0-rmse:0.57325	validation_1-rmse:0.76072
# [101]	validation_0-rmse:0.57138	validation_1-rmse:0.75809
# [102]	validation_0-rmse:0.57064	validation_1-rmse:0.75848
# [103]	validation_0-rmse:0.56729	validation_1-rmse:0.75770
# [104]	validation_0-rmse:0.56476	validation_1-rmse:0.75852
# [0]	validation_0-rmse:2.15705	validation_1-rmse:1.92531
# [1]	validation_0-rmse:2.10821	validation_1-rmse:1.88258
# [2]	validation_0-rmse:2.06055	validation_1-rmse:1.84284
# [3]	validation_0-rmse:2.01485	validation_1-rmse:1.80680
# [4]	validation_0-rmse:1.97019	validation_1-rmse:1.76871
# [5]	validation_0-rmse:1.92662	validation_1-rmse:1.74161
# [6]	validation_0-rmse:1.88120	validation_1-rmse:1.70625
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [7]	validation_0-rmse:1.83866	validation_1-rmse:1.67043
# [8]	validation_0-rmse:1.79864	validation_1-rmse:1.64780
# [9]	validation_0-rmse:1.75611	validation_1-rmse:1.61656
# [10]	validation_0-rmse:1.71616	validation_1-rmse:1.58713
# [11]	validation_0-rmse:1.68124	validation_1-rmse:1.55705
# [12]	validation_0-rmse:1.64403	validation_1-rmse:1.52803
# [13]	validation_0-rmse:1.61030	validation_1-rmse:1.50531
# [14]	validation_0-rmse:1.57457	validation_1-rmse:1.48170
# [15]	validation_0-rmse:1.54301	validation_1-rmse:1.45708
# [16]	validation_0-rmse:1.51159	validation_1-rmse:1.43978
# [17]	validation_0-rmse:1.47904	validation_1-rmse:1.41819
# [18]	validation_0-rmse:1.44765	validation_1-rmse:1.39791
# [19]	validation_0-rmse:1.41812	validation_1-rmse:1.37826
# [20]	validation_0-rmse:1.38958	validation_1-rmse:1.36164
# [21]	validation_0-rmse:1.36267	validation_1-rmse:1.34027
# [22]	validation_0-rmse:1.33347	validation_1-rmse:1.32315
# [23]	validation_0-rmse:1.30684	validation_1-rmse:1.30338
# [24]	validation_0-rmse:1.28056	validation_1-rmse:1.28478
# [25]	validation_0-rmse:1.25533	validation_1-rmse:1.27095
# [26]	validation_0-rmse:1.22934	validation_1-rmse:1.25883
# [27]	validation_0-rmse:1.20662	validation_1-rmse:1.24537
# [28]	validation_0-rmse:1.18333	validation_1-rmse:1.23623
# [29]	validation_0-rmse:1.15838	validation_1-rmse:1.22576
# [30]	validation_0-rmse:1.13886	validation_1-rmse:1.21720
# [31]	validation_0-rmse:1.11729	validation_1-rmse:1.20694
# [32]	validation_0-rmse:1.09745	validation_1-rmse:1.19419
# [33]	validation_0-rmse:1.07706	validation_1-rmse:1.18143
# [34]	validation_0-rmse:1.05846	validation_1-rmse:1.17440
# [35]	validation_0-rmse:1.04035	validation_1-rmse:1.16303
# [36]	validation_0-rmse:1.02266	validation_1-rmse:1.15439
# [37]	validation_0-rmse:1.00589	validation_1-rmse:1.14843
# [38]	validation_0-rmse:0.98853	validation_1-rmse:1.13924
# [39]	validation_0-rmse:0.97151	validation_1-rmse:1.13102
# [40]	validation_0-rmse:0.95477	validation_1-rmse:1.12638
# [41]	validation_0-rmse:0.93824	validation_1-rmse:1.12089
# [42]	validation_0-rmse:0.92454	validation_1-rmse:1.11807
# [43]	validation_0-rmse:0.90928	validation_1-rmse:1.11268
# [44]	validation_0-rmse:0.89582	validation_1-rmse:1.10671
# [45]	validation_0-rmse:0.88186	validation_1-rmse:1.09999
# [46]	validation_0-rmse:0.86916	validation_1-rmse:1.09823
# [47]	validation_0-rmse:0.85690	validation_1-rmse:1.09465
# [48]	validation_0-rmse:0.84452	validation_1-rmse:1.09000
# [49]	validation_0-rmse:0.83012	validation_1-rmse:1.08648
# [50]	validation_0-rmse:0.81509	validation_1-rmse:1.08055
# [51]	validation_0-rmse:0.80262	validation_1-rmse:1.08120
# [52]	validation_0-rmse:0.79101	validation_1-rmse:1.08188
# [53]	validation_0-rmse:0.78013	validation_1-rmse:1.08079
# [54]	validation_0-rmse:0.77052	validation_1-rmse:1.07853
# [55]	validation_0-rmse:0.76099	validation_1-rmse:1.07579
# [56]	validation_0-rmse:0.75105	validation_1-rmse:1.07411
# [57]	validation_0-rmse:0.74153	validation_1-rmse:1.07264
# [58]	validation_0-rmse:0.73239	validation_1-rmse:1.07038
# [59]	validation_0-rmse:0.72285	validation_1-rmse:1.06886
# [60]	validation_0-rmse:0.71348	validation_1-rmse:1.06653
# [61]	validation_0-rmse:0.70524	validation_1-rmse:1.06782
# [62]	validation_0-rmse:0.69702	validation_1-rmse:1.06670
# [63]	validation_0-rmse:0.68811	validation_1-rmse:1.06636
# [64]	validation_0-rmse:0.68197	validation_1-rmse:1.06406
# [65]	validation_0-rmse:0.67216	validation_1-rmse:1.06526
# [66]	validation_0-rmse:0.66517	validation_1-rmse:1.06477
# [67]	validation_0-rmse:0.65689	validation_1-rmse:1.06770
# [68]	validation_0-rmse:0.65077	validation_1-rmse:1.06862
# [69]	validation_0-rmse:0.64350	validation_1-rmse:1.06882
# [70]	validation_0-rmse:0.63742	validation_1-rmse:1.06777
# [71]	validation_0-rmse:0.62981	validation_1-rmse:1.06567
# [72]	validation_0-rmse:0.62418	validation_1-rmse:1.06740
# [73]	validation_0-rmse:0.61922	validation_1-rmse:1.06704
# [74]	validation_0-rmse:0.61323	validation_1-rmse:1.06788
# [75]	validation_0-rmse:0.60748	validation_1-rmse:1.06799
# [76]	validation_0-rmse:0.60267	validation_1-rmse:1.07180
# [77]	validation_0-rmse:0.59633	validation_1-rmse:1.07161
# [78]	validation_0-rmse:0.59146	validation_1-rmse:1.07162
# [79]	validation_0-rmse:0.58687	validation_1-rmse:1.07450
# [80]	validation_0-rmse:0.58189	validation_1-rmse:1.07509
# [81]	validation_0-rmse:0.57728	validation_1-rmse:1.07551
# [82]	validation_0-rmse:0.57298	validation_1-rmse:1.07725
# [83]	validation_0-rmse:0.56928	validation_1-rmse:1.07938
# [84]	validation_0-rmse:0.56482	validation_1-rmse:1.08012
# [0]	validation_0-rmse:2.07587	validation_1-rmse:2.25951
# [1]	validation_0-rmse:2.02985	validation_1-rmse:2.21227
# [2]	validation_0-rmse:1.98435	validation_1-rmse:2.17139
# [3]	validation_0-rmse:1.93835	validation_1-rmse:2.12663
# [4]	validation_0-rmse:1.89661	validation_1-rmse:2.09173
# [5]	validation_0-rmse:1.85181	validation_1-rmse:2.04863
# [6]	validation_0-rmse:1.81212	validation_1-rmse:2.01153
# [7]	validation_0-rmse:1.77148	validation_1-rmse:1.97179
# [8]	validation_0-rmse:1.73303	validation_1-rmse:1.93319
# [9]	validation_0-rmse:1.69786	validation_1-rmse:1.89827
# [10]	validation_0-rmse:1.66526	validation_1-rmse:1.86535
# [11]	validation_0-rmse:1.63125	validation_1-rmse:1.83778
# [12]	validation_0-rmse:1.59745	validation_1-rmse:1.80431
# [13]	validation_0-rmse:1.56203	validation_1-rmse:1.77037
# [14]	validation_0-rmse:1.53257	validation_1-rmse:1.74509
# [15]	validation_0-rmse:1.50274	validation_1-rmse:1.71660
# [16]	validation_0-rmse:1.47182	validation_1-rmse:1.68681
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [17]	validation_0-rmse:1.44285	validation_1-rmse:1.65785
# [18]	validation_0-rmse:1.41817	validation_1-rmse:1.63704
# [19]	validation_0-rmse:1.39705	validation_1-rmse:1.62585
# [20]	validation_0-rmse:1.36920	validation_1-rmse:1.60100
# [21]	validation_0-rmse:1.34101	validation_1-rmse:1.57545
# [22]	validation_0-rmse:1.31661	validation_1-rmse:1.55712
# [23]	validation_0-rmse:1.29144	validation_1-rmse:1.53886
# [24]	validation_0-rmse:1.26659	validation_1-rmse:1.51469
# [25]	validation_0-rmse:1.24397	validation_1-rmse:1.48971
# [26]	validation_0-rmse:1.22283	validation_1-rmse:1.47248
# [27]	validation_0-rmse:1.20127	validation_1-rmse:1.45039
# [28]	validation_0-rmse:1.17914	validation_1-rmse:1.42847
# [29]	validation_0-rmse:1.15744	validation_1-rmse:1.40995
# [30]	validation_0-rmse:1.13829	validation_1-rmse:1.39121
# [31]	validation_0-rmse:1.12065	validation_1-rmse:1.37397
# [32]	validation_0-rmse:1.10271	validation_1-rmse:1.35692
# [33]	validation_0-rmse:1.08541	validation_1-rmse:1.34066
# [34]	validation_0-rmse:1.06945	validation_1-rmse:1.32873
# [35]	validation_0-rmse:1.05237	validation_1-rmse:1.31209
# [36]	validation_0-rmse:1.03505	validation_1-rmse:1.29846
# [37]	validation_0-rmse:1.01906	validation_1-rmse:1.28793
# [38]	validation_0-rmse:1.00174	validation_1-rmse:1.27134
# [39]	validation_0-rmse:0.98644	validation_1-rmse:1.25830
# [40]	validation_0-rmse:0.97080	validation_1-rmse:1.24328
# [41]	validation_0-rmse:0.95856	validation_1-rmse:1.23448
# [42]	validation_0-rmse:0.94481	validation_1-rmse:1.22106
# [43]	validation_0-rmse:0.93370	validation_1-rmse:1.21192
# [44]	validation_0-rmse:0.92026	validation_1-rmse:1.20268
# [45]	validation_0-rmse:0.90677	validation_1-rmse:1.19175
# [46]	validation_0-rmse:0.89401	validation_1-rmse:1.18248
# [47]	validation_0-rmse:0.88203	validation_1-rmse:1.17152
# [48]	validation_0-rmse:0.87079	validation_1-rmse:1.16337
# [49]	validation_0-rmse:0.86147	validation_1-rmse:1.15375
# [50]	validation_0-rmse:0.85139	validation_1-rmse:1.14593
# [51]	validation_0-rmse:0.84231	validation_1-rmse:1.13363
# [52]	validation_0-rmse:0.83287	validation_1-rmse:1.12436
# [53]	validation_0-rmse:0.82246	validation_1-rmse:1.11553
# [54]	validation_0-rmse:0.81177	validation_1-rmse:1.11052
# [55]	validation_0-rmse:0.80274	validation_1-rmse:1.10546
# [56]	validation_0-rmse:0.79319	validation_1-rmse:1.09966
# [57]	validation_0-rmse:0.78401	validation_1-rmse:1.08977
# [58]	validation_0-rmse:0.77415	validation_1-rmse:1.08616
# [59]	validation_0-rmse:0.76615	validation_1-rmse:1.07895
# [60]	validation_0-rmse:0.75682	validation_1-rmse:1.07291
# [61]	validation_0-rmse:0.74808	validation_1-rmse:1.06312
# [62]	validation_0-rmse:0.73971	validation_1-rmse:1.05829
# [63]	validation_0-rmse:0.73173	validation_1-rmse:1.05459
# [64]	validation_0-rmse:0.72507	validation_1-rmse:1.05198
# [65]	validation_0-rmse:0.71812	validation_1-rmse:1.04834
# [66]	validation_0-rmse:0.71293	validation_1-rmse:1.04603
# [67]	validation_0-rmse:0.70614	validation_1-rmse:1.03989
# [68]	validation_0-rmse:0.69839	validation_1-rmse:1.03282
# [69]	validation_0-rmse:0.69189	validation_1-rmse:1.02718
# [70]	validation_0-rmse:0.68602	validation_1-rmse:1.02174
# ...
# [43]	validation_0-rmse:0.94242	validation_1-rmse:1.00456
# [44]	validation_0-rmse:0.93065	validation_1-rmse:0.99295
# [45]	validation_0-rmse:0.91693	validation_1-rmse:0.97930
# [46]	validation_0-rmse:0.90574	validation_1-rmse:0.97023
# [47]	validation_0-rmse:0.89487	validation_1-rmse:0.96065
# [48]	validation_0-rmse:0.88293	validation_1-rmse:0.95431
# [49]	validation_0-rmse:0.87287	validation_1-rmse:0.94685
# [50]	validation_0-rmse:0.86086	validation_1-rmse:0.93488
# [51]	validation_0-rmse:0.85136	validation_1-rmse:0.92575
# [52]	validation_0-rmse:0.84044	validation_1-rmse:0.91926
# [53]	validation_0-rmse:0.83080	validation_1-rmse:0.90778
# [54]	validation_0-rmse:0.82201	validation_1-rmse:0.90244
# [55]	validation_0-rmse:0.81493	validation_1-rmse:0.89699
# [56]	validation_0-rmse:0.80690	validation_1-rmse:0.89134
# [57]	validation_0-rmse:0.79859	validation_1-rmse:0.88317
# [58]	validation_0-rmse:0.79003	validation_1-rmse:0.87673
# [59]	validation_0-rmse:0.78213	validation_1-rmse:0.86886
# [60]	validation_0-rmse:0.77581	validation_1-rmse:0.86446
# [61]	validation_0-rmse:0.77042	validation_1-rmse:0.86309
# [62]	validation_0-rmse:0.76369	validation_1-rmse:0.85887
# [63]	validation_0-rmse:0.75770	validation_1-rmse:0.85560
# [64]	validation_0-rmse:0.75152	validation_1-rmse:0.85387
# [65]	validation_0-rmse:0.74265	validation_1-rmse:0.85216
# [66]	validation_0-rmse:0.73786	validation_1-rmse:0.84983
# [67]	validation_0-rmse:0.73149	validation_1-rmse:0.84661
# [68]	validation_0-rmse:0.72638	validation_1-rmse:0.84149
# [69]	validation_0-rmse:0.71991	validation_1-rmse:0.83966
# [70]	validation_0-rmse:0.71492	validation_1-rmse:0.83612
# [71]	validation_0-rmse:0.70925	validation_1-rmse:0.83264
# [72]	validation_0-rmse:0.70390	validation_1-rmse:0.82812
# [73]	validation_0-rmse:0.69861	validation_1-rmse:0.82281
# [74]	validation_0-rmse:0.69178	validation_1-rmse:0.81636
# [75]	validation_0-rmse:0.68721	validation_1-rmse:0.81260
# [76]	validation_0-rmse:0.68228	validation_1-rmse:0.80718
# [77]	validation_0-rmse:0.67751	validation_1-rmse:0.80681
# [78]	validation_0-rmse:0.67286	validation_1-rmse:0.80549
# [79]	validation_0-rmse:0.66718	validation_1-rmse:0.80039
# [80]	validation_0-rmse:0.66361	validation_1-rmse:0.79906
# [81]	validation_0-rmse:0.65799	validation_1-rmse:0.79447
# [82]	validation_0-rmse:0.65317	validation_1-rmse:0.79206
# [83]	validation_0-rmse:0.64976	validation_1-rmse:0.78870
# [84]	validation_0-rmse:0.64617	validation_1-rmse:0.78475
# [85]	validation_0-rmse:0.64372	validation_1-rmse:0.78146
# [86]	validation_0-rmse:0.63983	validation_1-rmse:0.78096
# [87]	validation_0-rmse:0.63427	validation_1-rmse:0.78281
# [88]	validation_0-rmse:0.63078	validation_1-rmse:0.78131
# [89]	validation_0-rmse:0.62905	validation_1-rmse:0.78065
# [90]	validation_0-rmse:0.62499	validation_1-rmse:0.78127
# [91]	validation_0-rmse:0.62107	validation_1-rmse:0.78040
# [92]	validation_0-rmse:0.61720	validation_1-rmse:0.78077
# [93]	validation_0-rmse:0.61356	validation_1-rmse:0.77674
# [94]	validation_0-rmse:0.61004	validation_1-rmse:0.77478
# [95]	validation_0-rmse:0.60749	validation_1-rmse:0.77485
# [96]	validation_0-rmse:0.60491	validation_1-rmse:0.77247
# [97]	validation_0-rmse:0.60240	validation_1-rmse:0.76906
# [98]	validation_0-rmse:0.59939	validation_1-rmse:0.76708
# [99]	validation_0-rmse:0.59726	validation_1-rmse:0.76711
# [100]	validation_0-rmse:0.59408	validation_1-rmse:0.76542
# [101]	validation_0-rmse:0.59030	validation_1-rmse:0.76380
# [102]	validation_0-rmse:0.58889	validation_1-rmse:0.76665
# [103]	validation_0-rmse:0.58515	validation_1-rmse:0.76562
# [104]	validation_0-rmse:0.58367	validation_1-rmse:0.76264
# [0]	validation_0-rmse:2.17789	validation_1-rmse:1.81845
# [1]	validation_0-rmse:2.12681	validation_1-rmse:1.77138
# [2]	validation_0-rmse:2.07990	validation_1-rmse:1.72618
# [3]	validation_0-rmse:2.03659	validation_1-rmse:1.69052
# [4]	validation_0-rmse:1.98933	validation_1-rmse:1.64907
# [5]	validation_0-rmse:1.94404	validation_1-rmse:1.60860
# [6]	validation_0-rmse:1.90327	validation_1-rmse:1.56810
# [7]	validation_0-rmse:1.86056	validation_1-rmse:1.53276
# [8]	validation_0-rmse:1.82019	validation_1-rmse:1.50339
# [9]	validation_0-rmse:1.78113	validation_1-rmse:1.46811
# [10]	validation_0-rmse:1.74137	validation_1-rmse:1.43218
# [11]	validation_0-rmse:1.70737	validation_1-rmse:1.40141
# [12]	validation_0-rmse:1.67150	validation_1-rmse:1.37092
# [13]	validation_0-rmse:1.63523	validation_1-rmse:1.34038
# [14]	validation_0-rmse:1.59910	validation_1-rmse:1.30984
# [15]	validation_0-rmse:1.56910	validation_1-rmse:1.28943
# [16]	validation_0-rmse:1.53590	validation_1-rmse:1.26435
# [17]	validation_0-rmse:1.50197	validation_1-rmse:1.23868
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [18]	validation_0-rmse:1.47140	validation_1-rmse:1.21697
# [19]	validation_0-rmse:1.44198	validation_1-rmse:1.19511
# [20]	validation_0-rmse:1.41417	validation_1-rmse:1.17532
# [21]	validation_0-rmse:1.38768	validation_1-rmse:1.15754
# [22]	validation_0-rmse:1.36031	validation_1-rmse:1.14043
# [23]	validation_0-rmse:1.33353	validation_1-rmse:1.12407
# [24]	validation_0-rmse:1.30662	validation_1-rmse:1.10654
# [25]	validation_0-rmse:1.28060	validation_1-rmse:1.09026
# [26]	validation_0-rmse:1.25540	validation_1-rmse:1.07744
# [27]	validation_0-rmse:1.23483	validation_1-rmse:1.07021
# [28]	validation_0-rmse:1.21316	validation_1-rmse:1.05794
# [29]	validation_0-rmse:1.19518	validation_1-rmse:1.05000
# [30]	validation_0-rmse:1.17216	validation_1-rmse:1.03667
# [31]	validation_0-rmse:1.15242	validation_1-rmse:1.02710
# [32]	validation_0-rmse:1.13111	validation_1-rmse:1.02042
# [33]	validation_0-rmse:1.11025	validation_1-rmse:1.00713
# [34]	validation_0-rmse:1.08836	validation_1-rmse:1.00038
# [35]	validation_0-rmse:1.07069	validation_1-rmse:0.99369
# [36]	validation_0-rmse:1.05115	validation_1-rmse:0.98620
# [37]	validation_0-rmse:1.03328	validation_1-rmse:0.97923
# [38]	validation_0-rmse:1.01636	validation_1-rmse:0.97242
# [39]	validation_0-rmse:0.99939	validation_1-rmse:0.96590
# [40]	validation_0-rmse:0.98420	validation_1-rmse:0.95784
# [41]	validation_0-rmse:0.96813	validation_1-rmse:0.95145
# [42]	validation_0-rmse:0.94978	validation_1-rmse:0.94816
# [43]	validation_0-rmse:0.93384	validation_1-rmse:0.94644
# [44]	validation_0-rmse:0.91996	validation_1-rmse:0.94520
# [45]	validation_0-rmse:0.90597	validation_1-rmse:0.94392
# [46]	validation_0-rmse:0.89108	validation_1-rmse:0.94260
# [47]	validation_0-rmse:0.87786	validation_1-rmse:0.93873
# [48]	validation_0-rmse:0.86537	validation_1-rmse:0.93542
# [49]	validation_0-rmse:0.85520	validation_1-rmse:0.93455
# [50]	validation_0-rmse:0.84257	validation_1-rmse:0.93210
# [51]	validation_0-rmse:0.83292	validation_1-rmse:0.92755
# [52]	validation_0-rmse:0.82280	validation_1-rmse:0.92482
# [53]	validation_0-rmse:0.81253	validation_1-rmse:0.92511
# [54]	validation_0-rmse:0.80178	validation_1-rmse:0.92455
# [55]	validation_0-rmse:0.79173	validation_1-rmse:0.92538
# [56]	validation_0-rmse:0.78336	validation_1-rmse:0.92459
# [57]	validation_0-rmse:0.77563	validation_1-rmse:0.92561
# [58]	validation_0-rmse:0.76742	validation_1-rmse:0.92439
# [59]	validation_0-rmse:0.75817	validation_1-rmse:0.92009
# [60]	validation_0-rmse:0.75012	validation_1-rmse:0.92160
# [61]	validation_0-rmse:0.74142	validation_1-rmse:0.92169
# [62]	validation_0-rmse:0.73366	validation_1-rmse:0.92201
# [63]	validation_0-rmse:0.72494	validation_1-rmse:0.92274
# [64]	validation_0-rmse:0.71633	validation_1-rmse:0.92214
# [65]	validation_0-rmse:0.70903	validation_1-rmse:0.92261
# [66]	validation_0-rmse:0.70194	validation_1-rmse:0.92129
# [67]	validation_0-rmse:0.69400	validation_1-rmse:0.91765
# [68]	validation_0-rmse:0.68770	validation_1-rmse:0.91792
# [69]	validation_0-rmse:0.68023	validation_1-rmse:0.91828
# [70]	validation_0-rmse:0.67400	validation_1-rmse:0.91888
# [71]	validation_0-rmse:0.66820	validation_1-rmse:0.91744
# [72]	validation_0-rmse:0.66144	validation_1-rmse:0.91807
# [73]	validation_0-rmse:0.65601	validation_1-rmse:0.91729
# [74]	validation_0-rmse:0.65100	validation_1-rmse:0.91615
# [75]	validation_0-rmse:0.64666	validation_1-rmse:0.91517
# [76]	validation_0-rmse:0.64305	validation_1-rmse:0.91537
# [77]	validation_0-rmse:0.63867	validation_1-rmse:0.91535
# [78]	validation_0-rmse:0.63348	validation_1-rmse:0.91724
# [79]	validation_0-rmse:0.62819	validation_1-rmse:0.91968
# [80]	validation_0-rmse:0.62414	validation_1-rmse:0.92070
# [81]	validation_0-rmse:0.61873	validation_1-rmse:0.92101
# [82]	validation_0-rmse:0.61442	validation_1-rmse:0.92167
# [83]	validation_0-rmse:0.61022	validation_1-rmse:0.92343
# [84]	validation_0-rmse:0.60509	validation_1-rmse:0.92325
# [85]	validation_0-rmse:0.60048	validation_1-rmse:0.92420
# [86]	validation_0-rmse:0.59646	validation_1-rmse:0.92432
# [87]	validation_0-rmse:0.59319	validation_1-rmse:0.92513
# [88]	validation_0-rmse:0.58897	validation_1-rmse:0.92385
# [89]	validation_0-rmse:0.58549	validation_1-rmse:0.92525
# [90]	validation_0-rmse:0.58359	validation_1-rmse:0.92557
# [91]	validation_0-rmse:0.58014	validation_1-rmse:0.92612
# [92]	validation_0-rmse:0.57695	validation_1-rmse:0.92745
# [93]	validation_0-rmse:0.57222	validation_1-rmse:0.92803
# [94]	validation_0-rmse:0.56888	validation_1-rmse:0.92919
# [0]	validation_0-rmse:2.11632	validation_1-rmse:2.10024
# [1]	validation_0-rmse:2.06843	validation_1-rmse:2.05319
# [2]	validation_0-rmse:2.02116	validation_1-rmse:2.00960
# [3]	validation_0-rmse:1.97617	validation_1-rmse:1.97036
# [4]	validation_0-rmse:1.93090	validation_1-rmse:1.93013
# [5]	validation_0-rmse:1.89118	validation_1-rmse:1.89269
# [6]	validation_0-rmse:1.84857	validation_1-rmse:1.85485
# [7]	validation_0-rmse:1.80832	validation_1-rmse:1.81367
# [8]	validation_0-rmse:1.77092	validation_1-rmse:1.78097
# [9]	validation_0-rmse:1.73195	validation_1-rmse:1.74530
# [10]	validation_0-rmse:1.69736	validation_1-rmse:1.71574
# [11]	validation_0-rmse:1.66024	validation_1-rmse:1.68115
# [12]	validation_0-rmse:1.62549	validation_1-rmse:1.64920
# [13]	validation_0-rmse:1.59187	validation_1-rmse:1.61837
# [14]	validation_0-rmse:1.56047	validation_1-rmse:1.58860
# [15]	validation_0-rmse:1.53007	validation_1-rmse:1.56117
# [16]	validation_0-rmse:1.49954	validation_1-rmse:1.53194
# [17]	validation_0-rmse:1.47286	validation_1-rmse:1.51057
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [18]	validation_0-rmse:1.44355	validation_1-rmse:1.48668
# [19]	validation_0-rmse:1.41392	validation_1-rmse:1.46042
# [20]	validation_0-rmse:1.38697	validation_1-rmse:1.43558
# [21]	validation_0-rmse:1.35991	validation_1-rmse:1.41174
# [22]	validation_0-rmse:1.33794	validation_1-rmse:1.38967
# [23]	validation_0-rmse:1.31358	validation_1-rmse:1.37254
# [24]	validation_0-rmse:1.29048	validation_1-rmse:1.35408
# [25]	validation_0-rmse:1.26816	validation_1-rmse:1.33825
# [26]	validation_0-rmse:1.24487	validation_1-rmse:1.31594
# [27]	validation_0-rmse:1.22221	validation_1-rmse:1.29372
# [28]	validation_0-rmse:1.20303	validation_1-rmse:1.27303
# [29]	validation_0-rmse:1.18142	validation_1-rmse:1.25058
# [30]	validation_0-rmse:1.16116	validation_1-rmse:1.23375
# [31]	validation_0-rmse:1.14066	validation_1-rmse:1.21895
# [32]	validation_0-rmse:1.12193	validation_1-rmse:1.20403
# [33]	validation_0-rmse:1.10499	validation_1-rmse:1.18826
# [34]	validation_0-rmse:1.08556	validation_1-rmse:1.17130
# [35]	validation_0-rmse:1.06907	validation_1-rmse:1.15796
# [36]	validation_0-rmse:1.05246	validation_1-rmse:1.14247
# [37]	validation_0-rmse:1.03800	validation_1-rmse:1.12878
# [38]	validation_0-rmse:1.02342	validation_1-rmse:1.12066
# [39]	validation_0-rmse:1.00978	validation_1-rmse:1.11112
# [40]	validation_0-rmse:0.99408	validation_1-rmse:1.09555
# [41]	validation_0-rmse:0.97876	validation_1-rmse:1.08634
# [42]	validation_0-rmse:0.96476	validation_1-rmse:1.07707
# [43]	validation_0-rmse:0.95134	validation_1-rmse:1.06592
# [44]	validation_0-rmse:0.93955	validation_1-rmse:1.05611
# [45]	validation_0-rmse:0.92648	validation_1-rmse:1.04698
# [46]	validation_0-rmse:0.91417	validation_1-rmse:1.03816
# [47]	validation_0-rmse:0.90053	validation_1-rmse:1.02259
# [48]	validation_0-rmse:0.88817	validation_1-rmse:1.01060
# [49]	validation_0-rmse:0.87540	validation_1-rmse:0.99611
# [50]	validation_0-rmse:0.86636	validation_1-rmse:0.98685
# [51]	validation_0-rmse:0.85645	validation_1-rmse:0.97973
# [52]	validation_0-rmse:0.84514	validation_1-rmse:0.97303
# [53]	validation_0-rmse:0.83445	validation_1-rmse:0.96715
# [54]	validation_0-rmse:0.82448	validation_1-rmse:0.96052
# [55]	validation_0-rmse:0.81465	validation_1-rmse:0.95342
# [56]	validation_0-rmse:0.80558	validation_1-rmse:0.94793
# [57]	validation_0-rmse:0.79743	validation_1-rmse:0.94254
# [58]	validation_0-rmse:0.79003	validation_1-rmse:0.93845
# [59]	validation_0-rmse:0.78102	validation_1-rmse:0.93151
# [60]	validation_0-rmse:0.77295	validation_1-rmse:0.92316
# [61]	validation_0-rmse:0.76383	validation_1-rmse:0.91698
# [62]	validation_0-rmse:0.75520	validation_1-rmse:0.91065
# [63]	validation_0-rmse:0.74766	validation_1-rmse:0.90590
# [64]	validation_0-rmse:0.74054	validation_1-rmse:0.89830
# [65]	validation_0-rmse:0.73346	validation_1-rmse:0.89492
# [66]	validation_0-rmse:0.72584	validation_1-rmse:0.88741
# [67]	validation_0-rmse:0.72023	validation_1-rmse:0.88160
# [68]	validation_0-rmse:0.71291	validation_1-rmse:0.87706
# [69]	validation_0-rmse:0.70697	validation_1-rmse:0.87271
# [70]	validation_0-rmse:0.70339	validation_1-rmse:0.87188
# [71]	validation_0-rmse:0.69890	validation_1-rmse:0.87137
# [72]	validation_0-rmse:0.69258	validation_1-rmse:0.86806
# [73]	validation_0-rmse:0.68698	validation_1-rmse:0.86289
# [74]	validation_0-rmse:0.68242	validation_1-rmse:0.85851
# [75]	validation_0-rmse:0.67593	validation_1-rmse:0.85468
# [76]	validation_0-rmse:0.67129	validation_1-rmse:0.85242
# [77]	validation_0-rmse:0.66599	validation_1-rmse:0.84708
# [78]	validation_0-rmse:0.66035	validation_1-rmse:0.84443
# [79]	validation_0-rmse:0.65639	validation_1-rmse:0.84237
# [80]	validation_0-rmse:0.65239	validation_1-rmse:0.84062
# [81]	validation_0-rmse:0.64890	validation_1-rmse:0.84003
# [82]	validation_0-rmse:0.64484	validation_1-rmse:0.83790
# [83]	validation_0-rmse:0.64094	validation_1-rmse:0.83514
# [84]	validation_0-rmse:0.63735	validation_1-rmse:0.83229
# [85]	validation_0-rmse:0.63408	validation_1-rmse:0.83265
# [86]	validation_0-rmse:0.62963	validation_1-rmse:0.83256
# [87]	validation_0-rmse:0.62619	validation_1-rmse:0.83314
# [88]	validation_0-rmse:0.62274	validation_1-rmse:0.83229
# [89]	validation_0-rmse:0.61866	validation_1-rmse:0.82893
# [90]	validation_0-rmse:0.61565	validation_1-rmse:0.82653
# [91]	validation_0-rmse:0.61154	validation_1-rmse:0.82258
# [92]	validation_0-rmse:0.60824	validation_1-rmse:0.82128
# [93]	validation_0-rmse:0.60369	validation_1-rmse:0.81980
# [94]	validation_0-rmse:0.60138	validation_1-rmse:0.82002
# [95]	validation_0-rmse:0.59750	validation_1-rmse:0.81620
# [96]	validation_0-rmse:0.59547	validation_1-rmse:0.81556
# [97]	validation_0-rmse:0.59302	validation_1-rmse:0.81301
# [98]	validation_0-rmse:0.58994	validation_1-rmse:0.81038
# [99]	validation_0-rmse:0.58756	validation_1-rmse:0.80857
# [100]	validation_0-rmse:0.58539	validation_1-rmse:0.80857
# [101]	validation_0-rmse:0.58266	validation_1-rmse:0.80933
# [102]	validation_0-rmse:0.58085	validation_1-rmse:0.80585
# [103]	validation_0-rmse:0.57824	validation_1-rmse:0.80711
# [104]	validation_0-rmse:0.57523	validation_1-rmse:0.80532
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 97.267, median: 104.0,
#  pred. interval (P(0.025)-P(0.975)): 66.9-104.0,
#  conf. interval (p-value=0.95): 97.069-104.0
# ***
# Aggregate bias statistic:
#  mean: -4.209, median: -4.084,
#  pred. interval (P(0.025)-P(0.975)): -9.181-0.632,
#  conf. interval (p-value=0.95): -5.388--2.927
# ***
# Aggregate RMSE statistic:
#  mean: 0.87, median: 0.882, pred. interval (P(0.025)-P(0.975)): 0.596-1.133,
#  conf. interval (p-value=0.95): 0.817-0.93
# ***
# Aggregate MSE statistic:
#  mean: 0.778, median: 0.779, pred. interval (P(0.025)-P(0.975)): 0.356-1.284,
#  conf. interval (p-value=0.95): 0.673-0.869
# ***
# Aggregate R^2 statistic:
#  mean: 0.008, median: 0.027, pred. interval (P(0.025)-P(0.975)): -0.328-0.281,
#  conf. interval (p-value=0.95): -0.07-0.107
# ***
# Aggregate bias(%) statistic:
#  mean: -1.637, median: -4.084, pred. interval (P(0.025)-P(0.975)): -3.463-0.296,
#  conf. interval (p-value=0.95): -2.154--1.234
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.351, median: 0.342, pred. interval (P(0.025)-P(0.975)): 0.241-0.469,
#  conf. interval (p-value=0.95): 0.32-0.38
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:2.11112
# [1]	validation_0-rmse:2.06008
# [2]	validation_0-rmse:2.01164
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:1.96793
# [4]	validation_0-rmse:1.92451
# [5]	validation_0-rmse:1.88206
# [6]	validation_0-rmse:1.84196
# [7]	validation_0-rmse:1.80287
# [8]	validation_0-rmse:1.76561
# [9]	validation_0-rmse:1.72720
# [10]	validation_0-rmse:1.69217
# [11]	validation_0-rmse:1.65694
# [12]	validation_0-rmse:1.62235
# [13]	validation_0-rmse:1.58906
# [14]	validation_0-rmse:1.55686
# [15]	validation_0-rmse:1.52494
# [16]	validation_0-rmse:1.49184
# [17]	validation_0-rmse:1.46463
# [18]	validation_0-rmse:1.43572
# [19]	validation_0-rmse:1.40695
# [20]	validation_0-rmse:1.37885
# [21]	validation_0-rmse:1.35357
# [22]	validation_0-rmse:1.32650
# [23]	validation_0-rmse:1.30339
# [24]	validation_0-rmse:1.28060
# [25]	validation_0-rmse:1.25633
# [26]	validation_0-rmse:1.23345
# [27]	validation_0-rmse:1.21069
# [28]	validation_0-rmse:1.19137
# [29]	validation_0-rmse:1.17018
# [30]	validation_0-rmse:1.14996
# [31]	validation_0-rmse:1.12822
# [32]	validation_0-rmse:1.10893
# [33]	validation_0-rmse:1.09170
# [34]	validation_0-rmse:1.07310
# [35]	validation_0-rmse:1.05709
# [36]	validation_0-rmse:1.04145
# [37]	validation_0-rmse:1.02374
# [38]	validation_0-rmse:1.00666
# [39]	validation_0-rmse:0.99343
# [40]	validation_0-rmse:0.97794
# [41]	validation_0-rmse:0.96479
# [42]	validation_0-rmse:0.95089
# [43]	validation_0-rmse:0.93871
# [44]	validation_0-rmse:0.92727
# [45]	validation_0-rmse:0.91635
# [46]	validation_0-rmse:0.90366
# [47]	validation_0-rmse:0.89207
# [48]	validation_0-rmse:0.87907
# [49]	validation_0-rmse:0.86766
# [50]	validation_0-rmse:0.85716
# [51]	validation_0-rmse:0.84622
# [52]	validation_0-rmse:0.83552
# [53]	validation_0-rmse:0.82649
# [54]	validation_0-rmse:0.81938
# [55]	validation_0-rmse:0.81056
# [56]	validation_0-rmse:0.80189
# [57]	validation_0-rmse:0.79300
# [58]	validation_0-rmse:0.78465
# [59]	validation_0-rmse:0.77577
# [60]	validation_0-rmse:0.76872
# [61]	validation_0-rmse:0.76163
# [62]	validation_0-rmse:0.75447
# [63]	validation_0-rmse:0.74757
# [64]	validation_0-rmse:0.74113
# [65]	validation_0-rmse:0.73424
# [66]	validation_0-rmse:0.72737
# [67]	validation_0-rmse:0.72146
# [68]	validation_0-rmse:0.71640
# [69]	validation_0-rmse:0.70989
# [70]	validation_0-rmse:0.70451
# [71]	validation_0-rmse:0.69889
# [72]	validation_0-rmse:0.69559
# [73]	validation_0-rmse:0.69036
# [74]	validation_0-rmse:0.68726
# [75]	validation_0-rmse:0.68216
# [76]	validation_0-rmse:0.67682
# [77]	validation_0-rmse:0.67227
# [78]	validation_0-rmse:0.66893
# [79]	validation_0-rmse:0.66438
# [80]	validation_0-rmse:0.66009
# [81]	validation_0-rmse:0.65469
# [82]	validation_0-rmse:0.65107
# [83]	validation_0-rmse:0.64648
# [84]	validation_0-rmse:0.64166
# [85]	validation_0-rmse:0.63861
# [86]	validation_0-rmse:0.63641
# [87]	validation_0-rmse:0.63279
# [88]	validation_0-rmse:0.62911
# [89]	validation_0-rmse:0.62690
# [90]	validation_0-rmse:0.62391
# [91]	validation_0-rmse:0.62084
# [92]	validation_0-rmse:0.61792
# [93]	validation_0-rmse:0.61438
# [94]	validation_0-rmse:0.61185
# [95]	validation_0-rmse:0.60885
# [96]	validation_0-rmse:0.60547
# [97]	validation_0-rmse:0.60312
# [98]	validation_0-rmse:0.60116
# [99]	validation_0-rmse:0.59865
# [100]	validation_0-rmse:0.59613
# [101]	validation_0-rmse:0.59398
# [102]	validation_0-rmse:0.59141
# [103]	validation_0-rmse:0.58914
# [104]	validation_0-rmse:0.58695
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 104

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.1
# Relative bias(%):  -5.17
# RMSE: 0.6
# Relative RMSE(%):  0.238
# MSE: 0.3
# R square: 57.5%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 1.282
# a1: 0.430
# R^2: 0.695
# Uncertainty
# a0: 1.28+/-0.07
# a1: 0.430+/-0.028

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_Tag_Sr_XGB_model_.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_Tag_St_XGB_model_.txt")
