# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'contr_r_STD', 'corr_r_Q25'])

# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           2260           1210     -0.731      2.576
# 1       8.189       9.622           2700           1180      0.585      2.915
# 2       8.380       9.589           2500           1400      0.779      2.882
# 3       8.137       9.449           2500           1090      0.517      2.724
# 4       7.696       9.401           2400            720      0.224      2.826
#
#    AEDR_mean  contr_r_STD  corr_r_Q25
# 0       2.33   360.273487    0.488754
# 1       2.47   323.958625    0.501683
# 2       2.44   299.438354    0.540056
# 3       2.55   319.773395    0.480991
# 4       2.14   353.104284    0.505257

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   contr_r_STD    103 non-null    float64
#  8   corr_r_Q25     103 non-null    float64
# dtypes: float64(7), int64(2)
# memory usage: 7.4 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3440.194175    1242.902913   -0.252563
# std       1.64946    1.472424    6087.580089    2037.684800    1.104610
# min       3.52600    6.075000     260.000000      50.000000   -3.033000
# 25%       6.31900    7.664000     635.000000     200.000000   -0.727500
# 50%       6.95700    8.472000    1150.000000     400.000000   -0.025000
# 75%       7.91350    9.421000    2525.000000    1400.000000    0.516500
# max      11.36700   13.864000   35200.000000   10500.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean  contr_r_STD  corr_r_Q25
# count  103.000000  103.000000   103.000000  103.000000
# mean     2.464709    3.570291   327.115078    0.393571
# std      0.904675    6.089170   167.617957    0.151801
# min      0.391000    0.480000     0.091058    0.033797
# 25%      1.803000    0.710000   283.887328    0.407228
# 50%      2.603000    1.290000   353.034542    0.449670
# 75%      3.159000    2.960000   448.017711    0.476635
# max      4.659000   36.590000   652.546648    0.555648

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['AEDR_mean'])
y = pd.DataFrame(select, columns= ['ln_Cs_wood'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    AEDR_mean
# 0       2.33
# 1       2.47
# 2       2.44
# 3       2.55
# 4       2.14

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Cs_wood
# 0       6.824
# 1       8.189
# 2       8.380
# 3       8.137
# 4       7.696

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [-0.21606231004523924, 0.2704949814773918, 0.06381431730981857]
#     Mean: 0.039
#     Std: 0.199
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.60323409 1.80310469 1.38348671]
#     Mean: 1.597
#     Std: 0.171
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [1.005297723715646, 1.0298824247472425, 1.696874867551467]
#     Mean: 1.244
#     Std: 0.320
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: -0.438 (std: 0.963)
# Parameters: {'colsample_bytree': 0.4779190946674869, 'gamma': 0.26073043635982945, 'learning_rate': 0.10923037448181477, 'max_depth': 2, 'n_estimators': 52, 'subsample': 0.3149008329364235}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.18234744, 0.50233984, 0.48360701, ..., 0.29050813, 0.28590975,
#        0.22704992]), 'std_fit_time': array([0.02865324, 0.2901499 , 0.13710292, ..., 0.01483386, 0.00961886,
#        0.00994855]), 'mean_score_time': array([0.00675597, 0.00588565, 0.0059319 , ..., 0.00571303, 0.00557065,
#        0.00692658]), 'std_score_time': array([1.37992604e-03, 1.58050940e-04, 2.66176609e-04, ...,
#        1.96511263e-04, 6.39731740e-05, 2.79490468e-03]), 'param_colsample_bytree': masked_array(data=[0.6536018724347847, 0.30242896392536894,
#                    0.6757642145232526, ..., 0.20242383210613873,
#                    0.15480700990343582, 0.8968169797580083],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.04592625420441726, 0.4383275755564307,
#                    0.4270097472049388, ..., 0.026570350667617315,
#                    0.288656432288385, 0.019541234708151722],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.17003543303116328, 0.0626225214405551,
#                    0.07647646047952092, ..., 0.30458187630049055,
#                    0.013018929017862526, 0.10351803953030343],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[2, 4, 2, ..., 4, 2, 2],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[57, 96, 139, ..., 116, 120, 93],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.7394883154860232, 0.3203061543057862,
#                    0.7393621273204569, ..., 0.7698613278406986,
#                    0.30710953509872874, 0.5065774836568041],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.6536018724347847, 'gamma': 0.04592625420441726, 'learning_rate': 0.17003543303116328, 'max_depth': 2, 'n_estimators': 57, 'subsample': 0.7394883154860232}, {'colsample_bytree': 0.30242896392536894, 'gamma': 0.4383275755564307, 'learning_rate': 0.0626225214405551, 'max_depth': 4, 'n_estimators': 96, 'subsample': 0.3203061543057862}, {'colsample_bytree': 0.6757642145232526, 'gamma': 0.4270097472049388, 'learning_rate': 0.07647646047952092, 'max_depth': 2, 'n_estimators': 139, 'subsample': 0.7393621273204569}, {'colsample_bytree': 0.18008610411368947, 'gamma': 0.34013431696219515, 'learning_rate': 0.08316677673135776, 'max_depth': 2, 'n_estimators': 130, 'subsample': 0.9308148054194698}, {'colsample_bytree': 0.147446444842953, 'gamma': 0.28008930292277684, 'learning_rate': 0.26703810398456457, 'max_depth': 4, 'n_estimators': 187, 'subsample': 0.4185409787115072}, {'colsample_bytree': 0.6170539355413479, 'gamma': 0.30843063257576697, 'learning_rate': 0.017166218586027827, 'max_depth': 4, 'n_estimators': 162, 'subsample': 0.7507959207992421}, {'colsample_bytree': 0.8665394542029999, 'gamma': 0.24209301198100486, 'learning_rate': 0.19987154821863307, 'max_depth': 2, 'n_estimators': 81, 'subsample': 0.915538394745764}, {'colsample_bytree': 0.7800414449909379, 'gamma': 0.12006824937769423, 'learning_rate': 0.24334271535701799, 'max_depth': 4, 'n_estimators': 128, 'subsample': 0.6000299900334922}, {'colsample_bytree': 0.6507936069070086, 'gamma': 0.14151021438805028, 'learning_rate': 0.16735398884203567, 'max_depth': 3, 'n_estimators': 69, 'subsample': 0.5358845377679022}, {'colsample_bytree': 0.4677620095308071, 'gamma': 0.17247916182832534, 'learning_rate': 0.016221429404829183, 'max_depth': 4, 'n_estimators': 65, 'subsample': 0.3790819772896646}, {'colsample_bytree': 0.17959524382267766, 'gamma': 0.37714205629807573, 'learning_rate': 0.24036370715166394, 'max_depth': 3, 'n_estimators': 52, 'subsample': 0.39235066926775525}, {'colsample_bytree': 0.18102994306624648, 'gamma': 0.30011189239704944, 'learning_rate': 0.29939366719625005, 'max_depth': 2, 'n_estimators': 184, 'subsample': 0.722285808110054}, {'colsample_bytree': 0.2108408222789409, 'gamma': 0.47335061807348205, 'learning_rate': 0.2487712802431732, 'max_depth': 4, 'n_estimators': 193, 'subsample': 0.9968020589286182}, {'colsample_bytree': 0.37151943485584227, 'gamma': 0.31466739428850515, 'learning_rate': 0.0818467310491491, 'max_depth': 2, 'n_estimators': 104, 'subsample': 0.34530524544523117}, {'colsample_bytree': 0.5154825439044823, 'gamma': 0.38050413944044653, 'learning_rate': 0.1814470895948901, 'max_depth': 4, 'n_estimators': 89, 'subsample': 0.44767223805551415}, {'colsample_bytree': 0.578099324193959, 'gamma': 0.2824071529683776, 'learning_rate': 0.19905649726569047, 'max_depth': 4, 'n_estimators': 106, 'subsample': 0.5290027777302934}, {'colsample_bytree': 0.9167507555921591, 'gamma': 0.18372051110602067, 'learning_rate': 0.1885713866740283, 'max_depth': 2, 'n_estimators': 107, 'subsample': 0.6374264970635083}, {'colsample_bytree': 0.3640889212736028, 'gamma': 0.2415255219383043, 'learning_rate': 0.3053401695599042, 'max_depth': 2, 'n_estimators': 89, 'subsample': 0.648598500496186}, {'colsample_bytree': 0.1474755535649217, 'gamma': 0.2237937995271555, 'learning_rate': 0.023508219074300667, 'max_depth': 3, 'n_estimators': 106, 'subsample': 0.30912081448918755}, {'colsample_bytree': 0.1614313654938399, 'gamma': 0.056969271342742045, 'learning_rate': 0.09508079050757864, 'max_depth': 4, 'n_estimators': 193, 'subsample': 0.8955385877698256}, {'colsample_bytree': 0.31654380247810204, 'gamma': 0.44560565802824, 'learning_rate': 0.2670877561030801, 'max_depth': 4, 'n_estimators': 116, 'subsample': 0.7794694084459826}, {'colsample_bytree': 0.48746359977189335, 'gamma': 0.05587284763352801, 'learning_rate': 0.26896359285589344, 'max_depth': 3, 'n_estimators': 147, 'subsample': 0.8501250178042086}, {'colsample_byt ...
#        -12.07420782,  -3.83357921]), 'split1_test_score': array([-1.14228756, -0.99085949, -0.80067964, ..., -1.86747932,
#        -1.98445577, -1.00825649]), 'split2_test_score': array([-0.62947411, -0.68427621, -0.60272834, ..., -1.21126309,
#        -0.88650636, -0.53408567]), 'split3_test_score': array([ 0.45503634,  0.35718318,  0.49793066, ...,  0.3673538 ,
#        -3.49191728,  0.47034949]), 'split4_test_score': array([0.41605702, 0.42997625, 0.42862372, ..., 0.15949044, 0.18815984,
#        0.40457447]), 'mean_test_score': array([-0.91879896, -1.0442604 , -0.7892681 , ..., -1.87673846,
#        -3.64978548, -0.90019948]), 'std_test_score': array([1.51663593, 1.73711304, 1.43934994, ..., 2.61448649, 4.38485286,
#        1.57043127]), 'rank_test_score': array([ 520,  802,  290, ..., 2434, 2952,  475], dtype=int32), 'split0_train_score': array([ 0.77855055,  0.75079863,  0.77732434, ...,  0.84093461,
#        -0.21784191,  0.75729571]), 'split1_train_score': array([ 0.76548106,  0.73515663,  0.77839957, ...,  0.88143207,
#        -0.41547087,  0.74764939]), 'split2_train_score': array([ 0.82155458,  0.78471161,  0.82096291, ...,  0.90782414,
#        -0.39804968,  0.79740436]), 'split3_train_score': array([ 0.61366665,  0.5960104 ,  0.63725868, ...,  0.75899954,
#        -0.67655055,  0.63152841]), 'split4_train_score': array([ 0.79596931,  0.75344078,  0.79121566, ...,  0.91981557,
#        -0.6745242 ,  0.7694318 ]), 'mean_train_score': array([ 0.75504443,  0.72402361,  0.76103223, ...,  0.86180119,
#        -0.47648744,  0.74066193]), 'std_train_score': array([0.07314039, 0.06599489, 0.06385871, ..., 0.05809087, 0.17664474,
#        0.0570667 ])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.4779190946674869
# Gamma: 0.26073043635982945
# Learning_rate: 0.10923037448181477
# Max_depth: 2
# N_estimators: 52
# Subsample: 0.3149008329364235

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=10, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:6.05475	validation_1-rmse:6.00706
# [1]	validation_0-rmse:5.46267	validation_1-rmse:5.51244
# [2]	validation_0-rmse:4.94963	validation_1-rmse:5.04752
# [3]	validation_0-rmse:4.49610	validation_1-rmse:4.59623
# [4]	validation_0-rmse:4.08618	validation_1-rmse:4.18867
# [5]	validation_0-rmse:3.70153	validation_1-rmse:3.80995
# [6]	validation_0-rmse:3.37022	validation_1-rmse:3.48074
# [7]	validation_0-rmse:3.07888	validation_1-rmse:3.17672
# [8]	validation_0-rmse:2.78651	validation_1-rmse:2.90240
# [9]	validation_0-rmse:2.58429	validation_1-rmse:2.74301
# [10]	validation_0-rmse:2.36651	validation_1-rmse:2.52559
# [11]	validation_0-rmse:2.21549	validation_1-rmse:2.36817
# [12]	validation_0-rmse:2.02836	validation_1-rmse:2.16406
# [13]	validation_0-rmse:1.89817	validation_1-rmse:2.03466
# [14]	validation_0-rmse:1.75190	validation_1-rmse:1.89643
# [15]	validation_0-rmse:1.63966	validation_1-rmse:1.78054
# [16]	validation_0-rmse:1.55775	validation_1-rmse:1.73488
# [17]	validation_0-rmse:1.48534	validation_1-rmse:1.69129
# [18]	validation_0-rmse:1.42014	validation_1-rmse:1.60369
# [19]	validation_0-rmse:1.37599	validation_1-rmse:1.55455
# [20]	validation_0-rmse:1.31532	validation_1-rmse:1.47959
# [21]	validation_0-rmse:1.26270	validation_1-rmse:1.44737
# [22]	validation_0-rmse:1.23270	validation_1-rmse:1.43633
# [23]	validation_0-rmse:1.19826	validation_1-rmse:1.39739
# [24]	validation_0-rmse:1.17766	validation_1-rmse:1.35477
# [25]	validation_0-rmse:1.15064	validation_1-rmse:1.29668
# [26]	validation_0-rmse:1.13727	validation_1-rmse:1.30855
# [27]	validation_0-rmse:1.11692	validation_1-rmse:1.27368
# [28]	validation_0-rmse:1.10748	validation_1-rmse:1.26180
# [29]	validation_0-rmse:1.10172	validation_1-rmse:1.29046
# [30]	validation_0-rmse:1.09555	validation_1-rmse:1.25598
# [31]	validation_0-rmse:1.08567	validation_1-rmse:1.21597
# [32]	validation_0-rmse:1.08211	validation_1-rmse:1.17015
# [33]	validation_0-rmse:1.08398	validation_1-rmse:1.17606
# [34]	validation_0-rmse:1.07760	validation_1-rmse:1.15579
# [35]	validation_0-rmse:1.07244	validation_1-rmse:1.13848
# [36]	validation_0-rmse:1.06626	validation_1-rmse:1.11317
# [37]	validation_0-rmse:1.06932	validation_1-rmse:1.11546
# [38]	validation_0-rmse:1.06142	validation_1-rmse:1.10232
# [39]	validation_0-rmse:1.05638	validation_1-rmse:1.06059
# [40]	validation_0-rmse:1.05129	validation_1-rmse:1.07797
# [41]	validation_0-rmse:1.04878	validation_1-rmse:1.09378
# [42]	validation_0-rmse:1.04515	validation_1-rmse:1.10635
# [43]	validation_0-rmse:1.04178	validation_1-rmse:1.06810
# [44]	validation_0-rmse:1.03767	validation_1-rmse:1.07526
# [45]	validation_0-rmse:1.03649	validation_1-rmse:1.09337
# [46]	validation_0-rmse:1.03447	validation_1-rmse:1.11361
# [47]	validation_0-rmse:1.03596	validation_1-rmse:1.08544
# [48]	validation_0-rmse:1.03606	validation_1-rmse:1.11240
# [49]	validation_0-rmse:1.03490	validation_1-rmse:1.14733
# [0]	validation_0-rmse:6.16136	validation_1-rmse:5.80711
# [1]	validation_0-rmse:5.58464	validation_1-rmse:5.23902
# [2]	validation_0-rmse:5.07086	validation_1-rmse:4.79116
# [3]	validation_0-rmse:4.62696	validation_1-rmse:4.35593
# [4]	validation_0-rmse:4.17559	validation_1-rmse:3.94316
# [5]	validation_0-rmse:3.83941	validation_1-rmse:3.64955
# [6]	validation_0-rmse:3.52578	validation_1-rmse:3.34760
# [7]	validation_0-rmse:3.22470	validation_1-rmse:3.08090
# [8]	validation_0-rmse:2.94601	validation_1-rmse:2.81889
# [9]	validation_0-rmse:2.72112	validation_1-rmse:2.60786
# [10]	validation_0-rmse:2.53354	validation_1-rmse:2.44383
# [11]	validation_0-rmse:2.34113	validation_1-rmse:2.29286
# [12]	validation_0-rmse:2.15222	validation_1-rmse:2.11718
# [13]	validation_0-rmse:1.97939	validation_1-rmse:1.95230
# [14]	validation_0-rmse:1.82161	validation_1-rmse:1.82265
# [15]	validation_0-rmse:1.69075	validation_1-rmse:1.70639
# [16]	validation_0-rmse:1.58888	validation_1-rmse:1.62397
# [17]	validation_0-rmse:1.49574	validation_1-rmse:1.54615
# [18]	validation_0-rmse:1.41615	validation_1-rmse:1.49495
# [19]	validation_0-rmse:1.34638	validation_1-rmse:1.43002
# [20]	validation_0-rmse:1.28101	validation_1-rmse:1.41698
# [21]	validation_0-rmse:1.23956	validation_1-rmse:1.40264
# [22]	validation_0-rmse:1.19793	validation_1-rmse:1.40193
# [23]	validation_0-rmse:1.16595	validation_1-rmse:1.38138
# [24]	validation_0-rmse:1.13505	validation_1-rmse:1.37475
# [25]	validation_0-rmse:1.10079	validation_1-rmse:1.35874
# [26]	validation_0-rmse:1.07548	validation_1-rmse:1.33400
# [27]	validation_0-rmse:1.06317	validation_1-rmse:1.33509
# [28]	validation_0-rmse:1.04379	validation_1-rmse:1.33259
# [29]	validation_0-rmse:1.02867	validation_1-rmse:1.33487
# [30]	validation_0-rmse:1.00984	validation_1-rmse:1.33669
# [31]	validation_0-rmse:0.99407	validation_1-rmse:1.32716
# [32]	validation_0-rmse:0.98481	validation_1-rmse:1.32448
# [33]	validation_0-rmse:0.97819	validation_1-rmse:1.32544
# [34]	validation_0-rmse:0.97529	validation_1-rmse:1.31207
# [35]	validation_0-rmse:0.96706	validation_1-rmse:1.30581
# [36]	validation_0-rmse:0.95952	validation_1-rmse:1.29926
# [37]	validation_0-rmse:0.96261	validation_1-rmse:1.28419
# [38]	validation_0-rmse:0.96550	validation_1-rmse:1.28847
# [39]	validation_0-rmse:0.94999	validation_1-rmse:1.27893
# [40]	validation_0-rmse:0.94390	validation_1-rmse:1.26527
# [41]	validation_0-rmse:0.94231	validation_1-rmse:1.28257
# [42]	validation_0-rmse:0.93686	validation_1-rmse:1.27167
# [43]	validation_0-rmse:0.93514	validation_1-rmse:1.28015
# [44]	validation_0-rmse:0.93304	validation_1-rmse:1.29413
# [45]	validation_0-rmse:0.93192	validation_1-rmse:1.28463
# [46]	validation_0-rmse:0.92577	validation_1-rmse:1.29723
# [47]	validation_0-rmse:0.92242	validation_1-rmse:1.31079
# [48]	validation_0-rmse:0.91419	validation_1-rmse:1.30168
# [49]	validation_0-rmse:0.90811	validation_1-rmse:1.28983
# [50]	validation_0-rmse:0.90721	validation_1-rmse:1.28751
# [0]	validation_0-rmse:6.02398	validation_1-rmse:6.35093
# [1]	validation_0-rmse:5.43989	validation_1-rmse:5.78851
# [2]	validation_0-rmse:4.95523	validation_1-rmse:5.31172
# [3]	validation_0-rmse:4.45524	validation_1-rmse:4.80676
# [4]	validation_0-rmse:4.01408	validation_1-rmse:4.36284
# [5]	validation_0-rmse:3.64806	validation_1-rmse:3.99070
# [6]	validation_0-rmse:3.32962	validation_1-rmse:3.66380
# [7]	validation_0-rmse:3.03533	validation_1-rmse:3.33992
# [8]	validation_0-rmse:2.78468	validation_1-rmse:3.08187
# [9]	validation_0-rmse:2.55821	validation_1-rmse:2.84643
# [10]	validation_0-rmse:2.39579	validation_1-rmse:2.67565
# [11]	validation_0-rmse:2.23357	validation_1-rmse:2.52388
# [12]	validation_0-rmse:2.07509	validation_1-rmse:2.35637
# [13]	validation_0-rmse:1.90826	validation_1-rmse:2.17325
# [14]	validation_0-rmse:1.76298	validation_1-rmse:2.02351
# [15]	validation_0-rmse:1.65675	validation_1-rmse:1.91234
# [16]	validation_0-rmse:1.56776	validation_1-rmse:1.81678
# [17]	validation_0-rmse:1.49297	validation_1-rmse:1.74972
# [18]	validation_0-rmse:1.42531	validation_1-rmse:1.66778
# [19]	validation_0-rmse:1.36254	validation_1-rmse:1.60192
# [20]	validation_0-rmse:1.30533	validation_1-rmse:1.52880
# [21]	validation_0-rmse:1.26544	validation_1-rmse:1.48338
# [22]	validation_0-rmse:1.21437	validation_1-rmse:1.43141
# [23]	validation_0-rmse:1.17306	validation_1-rmse:1.37431
# [24]	validation_0-rmse:1.13496	validation_1-rmse:1.32609
# [25]	validation_0-rmse:1.10756	validation_1-rmse:1.29828
# [26]	validation_0-rmse:1.08333	validation_1-rmse:1.26288
# [27]	validation_0-rmse:1.06021	validation_1-rmse:1.24761
# [28]	validation_0-rmse:1.04850	validation_1-rmse:1.23257
# [29]	validation_0-rmse:1.04472	validation_1-rmse:1.22700
# [30]	validation_0-rmse:1.03817	validation_1-rmse:1.22901
# [31]	validation_0-rmse:1.02799	validation_1-rmse:1.22120
# [32]	validation_0-rmse:1.03149	validation_1-rmse:1.21617
# [33]	validation_0-rmse:1.01632	validation_1-rmse:1.19455
# [34]	validation_0-rmse:1.00751	validation_1-rmse:1.17758
# [35]	validation_0-rmse:1.00514	validation_1-rmse:1.15487
# [36]	validation_0-rmse:0.99897	validation_1-rmse:1.14597
# [37]	validation_0-rmse:0.99319	validation_1-rmse:1.13101
# [38]	validation_0-rmse:0.98543	validation_1-rmse:1.11063
# [39]	validation_0-rmse:0.97695	validation_1-rmse:1.12338
# [40]	validation_0-rmse:0.97039	validation_1-rmse:1.11465
# [41]	validation_0-rmse:0.96856	validation_1-rmse:1.11566
# [42]	validation_0-rmse:0.96802	validation_1-rmse:1.11368
# [43]	validation_0-rmse:0.96696	validation_1-rmse:1.14211
# [44]	validation_0-rmse:0.96394	validation_1-rmse:1.15211
# [45]	validation_0-rmse:0.95808	validation_1-rmse:1.15778
# [46]	validation_0-rmse:0.95580	validation_1-rmse:1.15230
# [47]	validation_0-rmse:0.95130	validation_1-rmse:1.13912
# [48]	validation_0-rmse:0.94517	validation_1-rmse:1.12596
# [0]	validation_0-rmse:6.10142	validation_1-rmse:5.96718
# [1]	validation_0-rmse:5.48077	validation_1-rmse:5.34255
# [2]	validation_0-rmse:4.92279	validation_1-rmse:4.78021
# [3]	validation_0-rmse:4.47075	validation_1-rmse:4.32394
# [4]	validation_0-rmse:4.03193	validation_1-rmse:3.88943
# [5]	validation_0-rmse:3.63220	validation_1-rmse:3.49005
# [6]	validation_0-rmse:3.30514	validation_1-rmse:3.15842
# [7]	validation_0-rmse:3.00176	validation_1-rmse:2.88339
# [8]	validation_0-rmse:2.77847	validation_1-rmse:2.67532
# [9]	validation_0-rmse:2.55409	validation_1-rmse:2.46028
# [10]	validation_0-rmse:2.36448	validation_1-rmse:2.27311
# [11]	validation_0-rmse:2.21752	validation_1-rmse:2.15018
# [12]	validation_0-rmse:2.03328	validation_1-rmse:1.98414
# [13]	validation_0-rmse:1.86364	validation_1-rmse:1.82975
# [14]	validation_0-rmse:1.75472	validation_1-rmse:1.74991
# [15]	validation_0-rmse:1.64701	validation_1-rmse:1.64844
# [16]	validation_0-rmse:1.55325	validation_1-rmse:1.56609
# [17]	validation_0-rmse:1.47907	validation_1-rmse:1.50970
# [18]	validation_0-rmse:1.39784	validation_1-rmse:1.43034
# [19]	validation_0-rmse:1.36334	validation_1-rmse:1.44382
# [20]	validation_0-rmse:1.29380	validation_1-rmse:1.40245
# [21]	validation_0-rmse:1.24251	validation_1-rmse:1.35921
# [22]	validation_0-rmse:1.19350	validation_1-rmse:1.32684
# [23]	validation_0-rmse:1.15379	validation_1-rmse:1.29511
# [24]	validation_0-rmse:1.11753	validation_1-rmse:1.26678
# [25]	validation_0-rmse:1.09781	validation_1-rmse:1.25081
# [26]	validation_0-rmse:1.08409	validation_1-rmse:1.25303
# [27]	validation_0-rmse:1.06649	validation_1-rmse:1.22630
# [28]	validation_0-rmse:1.04354	validation_1-rmse:1.25245
# [29]	validation_0-rmse:1.03018	validation_1-rmse:1.23742
# [30]	validation_0-rmse:1.01527	validation_1-rmse:1.23784
# [31]	validation_0-rmse:0.99869	validation_1-rmse:1.20861
# [32]	validation_0-rmse:0.99556	validation_1-rmse:1.19637
# [33]	validation_0-rmse:0.98180	validation_1-rmse:1.16700
# [34]	validation_0-rmse:0.97670	validation_1-rmse:1.13210
# [35]	validation_0-rmse:0.97043	validation_1-rmse:1.10950
# [36]	validation_0-rmse:0.96475	validation_1-rmse:1.09846
# [37]	validation_0-rmse:0.95159	validation_1-rmse:1.13485
# [38]	validation_0-rmse:0.95495	validation_1-rmse:1.15791
# [39]	validation_0-rmse:0.94588	validation_1-rmse:1.15466
# [40]	validation_0-rmse:0.93950	validation_1-rmse:1.16074
# [41]	validation_0-rmse:0.93171	validation_1-rmse:1.18383
# [42]	validation_0-rmse:0.93525	validation_1-rmse:1.16946
# [43]	validation_0-rmse:0.93264	validation_1-rmse:1.16787
# [44]	validation_0-rmse:0.93559	validation_1-rmse:1.18269
# [45]	validation_0-rmse:0.93499	validation_1-rmse:1.16304
# [0]	validation_0-rmse:5.95984	validation_1-rmse:6.54036
# [1]	validation_0-rmse:5.38772	validation_1-rmse:5.97594
# [2]	validation_0-rmse:4.88541	validation_1-rmse:5.41187
# [3]	validation_0-rmse:4.44009	validation_1-rmse:4.97389
# [4]	validation_0-rmse:4.03072	validation_1-rmse:4.57106
# [5]	validation_0-rmse:3.69094	validation_1-rmse:4.18236
# [6]	validation_0-rmse:3.38370	validation_1-rmse:3.81994
# [7]	validation_0-rmse:3.12068	validation_1-rmse:3.56586
# [8]	validation_0-rmse:2.83556	validation_1-rmse:3.24937
# [9]	validation_0-rmse:2.60992	validation_1-rmse:3.03036
# [10]	validation_0-rmse:2.41446	validation_1-rmse:2.84704
# [11]	validation_0-rmse:2.21699	validation_1-rmse:2.65069
# [12]	validation_0-rmse:2.02873	validation_1-rmse:2.42287
# [13]	validation_0-rmse:1.88567	validation_1-rmse:2.27854
# [14]	validation_0-rmse:1.75490	validation_1-rmse:2.10080
# [15]	validation_0-rmse:1.63112	validation_1-rmse:1.93766
# [16]	validation_0-rmse:1.56609	validation_1-rmse:1.85650
# [17]	validation_0-rmse:1.48214	validation_1-rmse:1.74244
# [18]	validation_0-rmse:1.42149	validation_1-rmse:1.65573
# [19]	validation_0-rmse:1.34898	validation_1-rmse:1.59485
# [20]	validation_0-rmse:1.28708	validation_1-rmse:1.50247
# [21]	validation_0-rmse:1.24560	validation_1-rmse:1.45213
# [22]	validation_0-rmse:1.22621	validation_1-rmse:1.44115
# [23]	validation_0-rmse:1.19781	validation_1-rmse:1.40006
# [24]	validation_0-rmse:1.16505	validation_1-rmse:1.34348
# [25]	validation_0-rmse:1.13162	validation_1-rmse:1.28557
# [26]	validation_0-rmse:1.09099	validation_1-rmse:1.23860
# [27]	validation_0-rmse:1.07403	validation_1-rmse:1.21375
# [28]	validation_0-rmse:1.05686	validation_1-rmse:1.18523
# [29]	validation_0-rmse:1.04621	validation_1-rmse:1.17587
# [30]	validation_0-rmse:1.03392	validation_1-rmse:1.17577
# [31]	validation_0-rmse:1.02502	validation_1-rmse:1.16726
# [32]	validation_0-rmse:1.01620	validation_1-rmse:1.16337
# [33]	validation_0-rmse:1.00109	validation_1-rmse:1.13638
# [34]	validation_0-rmse:0.98279	validation_1-rmse:1.11366
# [35]	validation_0-rmse:0.97409	validation_1-rmse:1.12135
# [36]	validation_0-rmse:0.96720	validation_1-rmse:1.11799
# [37]	validation_0-rmse:0.96898	validation_1-rmse:1.12399
# [38]	validation_0-rmse:0.96101	validation_1-rmse:1.11647
# [39]	validation_0-rmse:0.95718	validation_1-rmse:1.11176
# [40]	validation_0-rmse:0.95249	validation_1-rmse:1.10346
# [41]	validation_0-rmse:0.94659	validation_1-rmse:1.10644
# [42]	validation_0-rmse:0.94113	validation_1-rmse:1.10928
# [43]	validation_0-rmse:0.93663	validation_1-rmse:1.11031
# [44]	validation_0-rmse:0.93554	validation_1-rmse:1.10133
# [45]	validation_0-rmse:0.93082	validation_1-rmse:1.10656
# [46]	validation_0-rmse:0.92784	validation_1-rmse:1.10218
# [47]	validation_0-rmse:0.91977	validation_1-rmse:1.11323
# [48]	validation_0-rmse:0.91817	validation_1-rmse:1.11259
# [49]	validation_0-rmse:0.91639	validation_1-rmse:1.11642
# [50]	validation_0-rmse:0.91285	validation_1-rmse:1.10521
# [51]	validation_0-rmse:0.91323	validation_1-rmse:1.10318
# [0]	validation_0-rmse:6.18309	validation_1-rmse:5.77553
# [1]	validation_0-rmse:5.60154	validation_1-rmse:5.19865
# [2]	validation_0-rmse:5.05386	validation_1-rmse:4.69252
# [3]	validation_0-rmse:4.54400	validation_1-rmse:4.18978
# [4]	validation_0-rmse:4.11372	validation_1-rmse:3.76764
# [5]	validation_0-rmse:3.72858	validation_1-rmse:3.39230
# [6]	validation_0-rmse:3.40425	validation_1-rmse:3.10010
# [7]	validation_0-rmse:3.10804	validation_1-rmse:2.82849
# [8]	validation_0-rmse:2.81094	validation_1-rmse:2.56445
# [9]	validation_0-rmse:2.59938	validation_1-rmse:2.36943
# [10]	validation_0-rmse:2.37909	validation_1-rmse:2.18010
# [11]	validation_0-rmse:2.20354	validation_1-rmse:2.02063
# [12]	validation_0-rmse:2.01735	validation_1-rmse:1.88396
# [13]	validation_0-rmse:1.88487	validation_1-rmse:1.76921
# [14]	validation_0-rmse:1.73378	validation_1-rmse:1.67563
# [15]	validation_0-rmse:1.60361	validation_1-rmse:1.58733
# [16]	validation_0-rmse:1.52024	validation_1-rmse:1.54253
# [17]	validation_0-rmse:1.43421	validation_1-rmse:1.49228
# [18]	validation_0-rmse:1.37112	validation_1-rmse:1.45597
# [19]	validation_0-rmse:1.29822	validation_1-rmse:1.41508
# [20]	validation_0-rmse:1.24809	validation_1-rmse:1.39391
# [21]	validation_0-rmse:1.20339	validation_1-rmse:1.37186
# [22]	validation_0-rmse:1.17308	validation_1-rmse:1.35448
# [23]	validation_0-rmse:1.12103	validation_1-rmse:1.32913
# [24]	validation_0-rmse:1.09310	validation_1-rmse:1.32218
# [25]	validation_0-rmse:1.05826	validation_1-rmse:1.31505
# [26]	validation_0-rmse:1.01713	validation_1-rmse:1.30634
# [27]	validation_0-rmse:0.99622	validation_1-rmse:1.32654
# [28]	validation_0-rmse:0.97812	validation_1-rmse:1.31181
# [29]	validation_0-rmse:0.97028	validation_1-rmse:1.31701
# [30]	validation_0-rmse:0.96204	validation_1-rmse:1.30737
# [31]	validation_0-rmse:0.94123	validation_1-rmse:1.32783
# [32]	validation_0-rmse:0.92980	validation_1-rmse:1.33587
# [33]	validation_0-rmse:0.91786	validation_1-rmse:1.33582
# [34]	validation_0-rmse:0.90897	validation_1-rmse:1.34483
# [35]	validation_0-rmse:0.90161	validation_1-rmse:1.34863
# [0]	validation_0-rmse:6.03628	validation_1-rmse:6.20702
# [1]	validation_0-rmse:5.46461	validation_1-rmse:5.60957
# [2]	validation_0-rmse:4.94855	validation_1-rmse:5.07272
# [3]	validation_0-rmse:4.48942	validation_1-rmse:4.59062
# [4]	validation_0-rmse:4.10517	validation_1-rmse:4.18310
# [5]	validation_0-rmse:3.78621	validation_1-rmse:3.83077
# [6]	validation_0-rmse:3.46042	validation_1-rmse:3.50565
# [7]	validation_0-rmse:3.17052	validation_1-rmse:3.22892
# [8]	validation_0-rmse:2.89485	validation_1-rmse:2.97780
# [9]	validation_0-rmse:2.67417	validation_1-rmse:2.73844
# [10]	validation_0-rmse:2.44483	validation_1-rmse:2.49059
# [11]	validation_0-rmse:2.28957	validation_1-rmse:2.38620
# [12]	validation_0-rmse:2.11838	validation_1-rmse:2.22609
# [13]	validation_0-rmse:1.95191	validation_1-rmse:2.03989
# [14]	validation_0-rmse:1.81079	validation_1-rmse:1.92161
# [15]	validation_0-rmse:1.70078	validation_1-rmse:1.82843
# [16]	validation_0-rmse:1.62517	validation_1-rmse:1.74369
# [17]	validation_0-rmse:1.53025	validation_1-rmse:1.66171
# [18]	validation_0-rmse:1.46486	validation_1-rmse:1.58612
# [19]	validation_0-rmse:1.38634	validation_1-rmse:1.50598
# [20]	validation_0-rmse:1.31771	validation_1-rmse:1.42964
# [21]	validation_0-rmse:1.27991	validation_1-rmse:1.38984
# [22]	validation_0-rmse:1.22987	validation_1-rmse:1.37311
# [23]	validation_0-rmse:1.19259	validation_1-rmse:1.32062
# [24]	validation_0-rmse:1.15836	validation_1-rmse:1.26223
# [25]	validation_0-rmse:1.15481	validation_1-rmse:1.27148
# [26]	validation_0-rmse:1.14056	validation_1-rmse:1.27306
# [27]	validation_0-rmse:1.10926	validation_1-rmse:1.22015
# [28]	validation_0-rmse:1.08575	validation_1-rmse:1.18530
# [29]	validation_0-rmse:1.06381	validation_1-rmse:1.17748
# [30]	validation_0-rmse:1.04034	validation_1-rmse:1.16603
# [31]	validation_0-rmse:1.02661	validation_1-rmse:1.16130
# [32]	validation_0-rmse:1.01829	validation_1-rmse:1.14464
# [33]	validation_0-rmse:1.01179	validation_1-rmse:1.15730
# [34]	validation_0-rmse:1.00535	validation_1-rmse:1.14047
# [35]	validation_0-rmse:1.00189	validation_1-rmse:1.12382
# [36]	validation_0-rmse:1.00122	validation_1-rmse:1.12667
# [37]	validation_0-rmse:0.99677	validation_1-rmse:1.14947
# [38]	validation_0-rmse:0.99293	validation_1-rmse:1.13787
# [39]	validation_0-rmse:0.99316	validation_1-rmse:1.13470
# [40]	validation_0-rmse:0.98655	validation_1-rmse:1.14321
# [41]	validation_0-rmse:0.98392	validation_1-rmse:1.10403
# [42]	validation_0-rmse:0.98273	validation_1-rmse:1.11230
# [43]	validation_0-rmse:0.97926	validation_1-rmse:1.10761
# [44]	validation_0-rmse:0.97838	validation_1-rmse:1.11230
# [45]	validation_0-rmse:0.97495	validation_1-rmse:1.13281
# [46]	validation_0-rmse:0.97619	validation_1-rmse:1.12855
# [47]	validation_0-rmse:0.97424	validation_1-rmse:1.10011
# [48]	validation_0-rmse:0.97133	validation_1-rmse:1.08495
# [49]	validation_0-rmse:0.96774	validation_1-rmse:1.08514
# [50]	validation_0-rmse:0.96950	validation_1-rmse:1.07759
# [51]	validation_0-rmse:0.96815	validation_1-rmse:1.09124
# [0]	validation_0-rmse:6.10383	validation_1-rmse:6.03241
# [1]	validation_0-rmse:5.52570	validation_1-rmse:5.45388
# [2]	validation_0-rmse:4.98997	validation_1-rmse:4.91778
# [3]	validation_0-rmse:4.46931	validation_1-rmse:4.39677
# [4]	validation_0-rmse:4.09734	validation_1-rmse:4.02459
# [5]	validation_0-rmse:3.69670	validation_1-rmse:3.62890
# [6]	validation_0-rmse:3.41889	validation_1-rmse:3.34441
# [7]	validation_0-rmse:3.12833	validation_1-rmse:3.05667
# [8]	validation_0-rmse:2.89162	validation_1-rmse:2.81997
# [9]	validation_0-rmse:2.65812	validation_1-rmse:2.56130
# [10]	validation_0-rmse:2.45456	validation_1-rmse:2.34540
# [11]	validation_0-rmse:2.25942	validation_1-rmse:2.17120
# [12]	validation_0-rmse:2.07027	validation_1-rmse:1.99385
# [13]	validation_0-rmse:1.90304	validation_1-rmse:1.82561
# [14]	validation_0-rmse:1.79689	validation_1-rmse:1.73458
# [15]	validation_0-rmse:1.69122	validation_1-rmse:1.64105
# [16]	validation_0-rmse:1.59894	validation_1-rmse:1.55910
# [17]	validation_0-rmse:1.50474	validation_1-rmse:1.47828
# [18]	validation_0-rmse:1.43498	validation_1-rmse:1.41946
# [19]	validation_0-rmse:1.33458	validation_1-rmse:1.35631
# [20]	validation_0-rmse:1.27183	validation_1-rmse:1.32825
# [21]	validation_0-rmse:1.23157	validation_1-rmse:1.29869
# [22]	validation_0-rmse:1.18371	validation_1-rmse:1.28546
# [23]	validation_0-rmse:1.13700	validation_1-rmse:1.27333
# [24]	validation_0-rmse:1.09073	validation_1-rmse:1.26305
# [25]	validation_0-rmse:1.08169	validation_1-rmse:1.25661
# [26]	validation_0-rmse:1.07798	validation_1-rmse:1.26465
# [27]	validation_0-rmse:1.05240	validation_1-rmse:1.28472
# [28]	validation_0-rmse:1.02445	validation_1-rmse:1.28655
# [29]	validation_0-rmse:1.00295	validation_1-rmse:1.29056
# [30]	validation_0-rmse:0.99414	validation_1-rmse:1.28542
# [31]	validation_0-rmse:0.98106	validation_1-rmse:1.29381
# [32]	validation_0-rmse:0.97620	validation_1-rmse:1.31369
# [33]	validation_0-rmse:0.96463	validation_1-rmse:1.32860
# [34]	validation_0-rmse:0.94723	validation_1-rmse:1.33186
# [35]	validation_0-rmse:0.93842	validation_1-rmse:1.35221
# [0]	validation_0-rmse:6.08310	validation_1-rmse:6.09908
# [1]	validation_0-rmse:5.48537	validation_1-rmse:5.51001
# [2]	validation_0-rmse:4.97334	validation_1-rmse:5.00709
# [3]	validation_0-rmse:4.51238	validation_1-rmse:4.55613
# [4]	validation_0-rmse:4.08555	validation_1-rmse:4.14061
# [5]	validation_0-rmse:3.68830	validation_1-rmse:3.74345
# [6]	validation_0-rmse:3.38187	validation_1-rmse:3.44833
# [7]	validation_0-rmse:3.08248	validation_1-rmse:3.15571
# [8]	validation_0-rmse:2.85334	validation_1-rmse:2.91228
# [9]	validation_0-rmse:2.64078	validation_1-rmse:2.72901
# [10]	validation_0-rmse:2.41635	validation_1-rmse:2.51258
# [11]	validation_0-rmse:2.26678	validation_1-rmse:2.37081
# [12]	validation_0-rmse:2.09839	validation_1-rmse:2.19028
# [13]	validation_0-rmse:1.93312	validation_1-rmse:2.04446
# [14]	validation_0-rmse:1.81211	validation_1-rmse:1.93198
# [15]	validation_0-rmse:1.70704	validation_1-rmse:1.84850
# [16]	validation_0-rmse:1.60643	validation_1-rmse:1.75398
# [17]	validation_0-rmse:1.50462	validation_1-rmse:1.68406
# [18]	validation_0-rmse:1.42567	validation_1-rmse:1.62259
# [19]	validation_0-rmse:1.36124	validation_1-rmse:1.56522
# [20]	validation_0-rmse:1.30474	validation_1-rmse:1.50171
# [21]	validation_0-rmse:1.23298	validation_1-rmse:1.45603
# [22]	validation_0-rmse:1.18418	validation_1-rmse:1.40670
# [23]	validation_0-rmse:1.13753	validation_1-rmse:1.37363
# [24]	validation_0-rmse:1.11403	validation_1-rmse:1.35217
# [25]	validation_0-rmse:1.08459	validation_1-rmse:1.33918
# [26]	validation_0-rmse:1.05663	validation_1-rmse:1.32698
# [27]	validation_0-rmse:1.03093	validation_1-rmse:1.30853
# [28]	validation_0-rmse:1.01181	validation_1-rmse:1.28308
# [29]	validation_0-rmse:0.99342	validation_1-rmse:1.27125
# [30]	validation_0-rmse:0.98200	validation_1-rmse:1.25142
# [31]	validation_0-rmse:0.97158	validation_1-rmse:1.24272
# [32]	validation_0-rmse:0.95865	validation_1-rmse:1.27188
# [33]	validation_0-rmse:0.94338	validation_1-rmse:1.25317
# [34]	validation_0-rmse:0.93849	validation_1-rmse:1.25979
# [35]	validation_0-rmse:0.92392	validation_1-rmse:1.28411
# [36]	validation_0-rmse:0.91724	validation_1-rmse:1.27318
# [37]	validation_0-rmse:0.90620	validation_1-rmse:1.29732
# [38]	validation_0-rmse:0.90093	validation_1-rmse:1.30137
# [39]	validation_0-rmse:0.89628	validation_1-rmse:1.31124
# [40]	validation_0-rmse:0.89444	validation_1-rmse:1.30282
# [41]	validation_0-rmse:0.89099	validation_1-rmse:1.30844
# [0]	validation_0-rmse:6.25262	validation_1-rmse:5.38213
# [1]	validation_0-rmse:5.60022	validation_1-rmse:4.73119
# [2]	validation_0-rmse:5.06515	validation_1-rmse:4.18278
# [3]	validation_0-rmse:4.61116	validation_1-rmse:3.72364
# [4]	validation_0-rmse:4.17358	validation_1-rmse:3.34545
# [5]	validation_0-rmse:3.80697	validation_1-rmse:2.98005
# [6]	validation_0-rmse:3.47815	validation_1-rmse:2.66132
# [7]	validation_0-rmse:3.17506	validation_1-rmse:2.38058
# [8]	validation_0-rmse:2.90837	validation_1-rmse:2.17176
# [9]	validation_0-rmse:2.64831	validation_1-rmse:1.93248
# [10]	validation_0-rmse:2.42991	validation_1-rmse:1.77677
# [11]	validation_0-rmse:2.23871	validation_1-rmse:1.63597
# [12]	validation_0-rmse:2.06622	validation_1-rmse:1.51065
# [13]	validation_0-rmse:1.89532	validation_1-rmse:1.41287
# [14]	validation_0-rmse:1.80533	validation_1-rmse:1.35805
# [15]	validation_0-rmse:1.70085	validation_1-rmse:1.28785
# [16]	validation_0-rmse:1.59601	validation_1-rmse:1.23747
# [17]	validation_0-rmse:1.50025	validation_1-rmse:1.19597
# [18]	validation_0-rmse:1.42103	validation_1-rmse:1.17190
# [19]	validation_0-rmse:1.34716	validation_1-rmse:1.14411
# [20]	validation_0-rmse:1.29231	validation_1-rmse:1.11802
# [21]	validation_0-rmse:1.24692	validation_1-rmse:1.07628
# [22]	validation_0-rmse:1.18085	validation_1-rmse:1.06216
# [23]	validation_0-rmse:1.14052	validation_1-rmse:1.05103
# [24]	validation_0-rmse:1.10908	validation_1-rmse:1.03200
# [25]	validation_0-rmse:1.08859	validation_1-rmse:1.03252
# [26]	validation_0-rmse:1.07052	validation_1-rmse:1.03468
# [27]	validation_0-rmse:1.05561	validation_1-rmse:1.03407
# [28]	validation_0-rmse:1.03125	validation_1-rmse:1.02998
# [29]	validation_0-rmse:1.02022	validation_1-rmse:1.01477
# [30]	validation_0-rmse:1.01156	validation_1-rmse:1.03392
# [31]	validation_0-rmse:0.99996	validation_1-rmse:1.04086
# [32]	validation_0-rmse:0.98974	validation_1-rmse:1.05462
# [33]	validation_0-rmse:0.98519	validation_1-rmse:1.06617
# [34]	validation_0-rmse:0.98027	validation_1-rmse:1.06938
# [35]	validation_0-rmse:0.97768	validation_1-rmse:1.06423
# [36]	validation_0-rmse:0.97210	validation_1-rmse:1.05962
# [37]	validation_0-rmse:0.96699	validation_1-rmse:1.09069
# [38]	validation_0-rmse:0.96243	validation_1-rmse:1.11251
# [39]	validation_0-rmse:0.95666	validation_1-rmse:1.08453
# [0]	validation_0-rmse:6.13585	validation_1-rmse:5.64546
# [1]	validation_0-rmse:5.55275	validation_1-rmse:5.04886
# [2]	validation_0-rmse:5.04388	validation_1-rmse:4.52574
# [3]	validation_0-rmse:4.63144	validation_1-rmse:4.08961
# [4]	validation_0-rmse:4.20342	validation_1-rmse:3.68588
# [5]	validation_0-rmse:3.80374	validation_1-rmse:3.26774
# [6]	validation_0-rmse:3.45274	validation_1-rmse:2.93960
# [7]	validation_0-rmse:3.15401	validation_1-rmse:2.65816
# [8]	validation_0-rmse:2.88161	validation_1-rmse:2.41981
# [9]	validation_0-rmse:2.66703	validation_1-rmse:2.24117
# [10]	validation_0-rmse:2.43482	validation_1-rmse:1.98090
# [11]	validation_0-rmse:2.24442	validation_1-rmse:1.82435
# [12]	validation_0-rmse:2.06973	validation_1-rmse:1.67984
# [13]	validation_0-rmse:1.90971	validation_1-rmse:1.55026
# [14]	validation_0-rmse:1.78457	validation_1-rmse:1.47420
# [15]	validation_0-rmse:1.67993	validation_1-rmse:1.43102
# [16]	validation_0-rmse:1.57916	validation_1-rmse:1.37082
# [17]	validation_0-rmse:1.49635	validation_1-rmse:1.32165
# [18]	validation_0-rmse:1.42426	validation_1-rmse:1.28698
# [19]	validation_0-rmse:1.38141	validation_1-rmse:1.28249
# [20]	validation_0-rmse:1.33289	validation_1-rmse:1.27004
# [21]	validation_0-rmse:1.30024	validation_1-rmse:1.25111
# [22]	validation_0-rmse:1.24716	validation_1-rmse:1.22382
# [23]	validation_0-rmse:1.20141	validation_1-rmse:1.19585
# [24]	validation_0-rmse:1.16398	validation_1-rmse:1.17598
# [25]	validation_0-rmse:1.13270	validation_1-rmse:1.16805
# [26]	validation_0-rmse:1.10432	validation_1-rmse:1.17141
# [27]	validation_0-rmse:1.07470	validation_1-rmse:1.15056
# [28]	validation_0-rmse:1.05846	validation_1-rmse:1.15821
# [29]	validation_0-rmse:1.04686	validation_1-rmse:1.16893
# [30]	validation_0-rmse:1.03218	validation_1-rmse:1.18337
# [31]	validation_0-rmse:1.02025	validation_1-rmse:1.16830
# [32]	validation_0-rmse:1.00392	validation_1-rmse:1.15760
# [33]	validation_0-rmse:0.98511	validation_1-rmse:1.17190
# [34]	validation_0-rmse:0.98264	validation_1-rmse:1.18237
# [35]	validation_0-rmse:0.98067	validation_1-rmse:1.16461
# [36]	validation_0-rmse:0.96861	validation_1-rmse:1.17200
# [0]	validation_0-rmse:6.10856	validation_1-rmse:6.11230
# [1]	validation_0-rmse:5.57700	validation_1-rmse:5.61228
# [2]	validation_0-rmse:5.04881	validation_1-rmse:5.09460
# [3]	validation_0-rmse:4.52813	validation_1-rmse:4.57347
# [4]	validation_0-rmse:4.16994	validation_1-rmse:4.21486
# [5]	validation_0-rmse:3.81781	validation_1-rmse:3.85799
# [6]	validation_0-rmse:3.48860	validation_1-rmse:3.52411
# [7]	validation_0-rmse:3.15158	validation_1-rmse:3.17018
# [8]	validation_0-rmse:2.88370	validation_1-rmse:2.88180
# [9]	validation_0-rmse:2.66432	validation_1-rmse:2.62594
# [10]	validation_0-rmse:2.43306	validation_1-rmse:2.40644
# [11]	validation_0-rmse:2.26284	validation_1-rmse:2.23802
# [12]	validation_0-rmse:2.12213	validation_1-rmse:2.09912
# [13]	validation_0-rmse:1.98836	validation_1-rmse:1.97761
# [14]	validation_0-rmse:1.88654	validation_1-rmse:1.87587
# [15]	validation_0-rmse:1.75314	validation_1-rmse:1.73044
# [16]	validation_0-rmse:1.67725	validation_1-rmse:1.66068
# [17]	validation_0-rmse:1.58089	validation_1-rmse:1.56988
# [18]	validation_0-rmse:1.50957	validation_1-rmse:1.48539
# [19]	validation_0-rmse:1.42353	validation_1-rmse:1.39414
# [20]	validation_0-rmse:1.37074	validation_1-rmse:1.33367
# [21]	validation_0-rmse:1.32131	validation_1-rmse:1.26959
# [22]	validation_0-rmse:1.30640	validation_1-rmse:1.23766
# [23]	validation_0-rmse:1.25336	validation_1-rmse:1.19455
# [24]	validation_0-rmse:1.21873	validation_1-rmse:1.15763
# [25]	validation_0-rmse:1.18713	validation_1-rmse:1.12501
# [26]	validation_0-rmse:1.15573	validation_1-rmse:1.10570
# [27]	validation_0-rmse:1.13338	validation_1-rmse:1.09025
# [28]	validation_0-rmse:1.11138	validation_1-rmse:1.09817
# [29]	validation_0-rmse:1.08734	validation_1-rmse:1.06503
# [30]	validation_0-rmse:1.07145	validation_1-rmse:1.04127
# [31]	validation_0-rmse:1.05912	validation_1-rmse:1.03591
# [32]	validation_0-rmse:1.05350	validation_1-rmse:1.05930
# [33]	validation_0-rmse:1.03987	validation_1-rmse:1.05575
# [34]	validation_0-rmse:1.02995	validation_1-rmse:1.02777
# [35]	validation_0-rmse:1.02127	validation_1-rmse:1.03763
# [36]	validation_0-rmse:1.01336	validation_1-rmse:1.02203
# [37]	validation_0-rmse:1.01434	validation_1-rmse:1.02734
# [38]	validation_0-rmse:1.00559	validation_1-rmse:1.02383
# [39]	validation_0-rmse:0.99900	validation_1-rmse:1.03515
# [40]	validation_0-rmse:0.99952	validation_1-rmse:1.04829
# [41]	validation_0-rmse:0.99401	validation_1-rmse:1.03807
# [42]	validation_0-rmse:0.99603	validation_1-rmse:1.05801
# [43]	validation_0-rmse:0.99575	validation_1-rmse:1.08048
# [44]	validation_0-rmse:0.99242	validation_1-rmse:1.07718
# [45]	validation_0-rmse:0.98804	validation_1-rmse:1.08821
# [0]	validation_0-rmse:6.02054	validation_1-rmse:6.42621
# [1]	validation_0-rmse:5.46269	validation_1-rmse:5.85979
# [2]	validation_0-rmse:4.92559	validation_1-rmse:5.32242
# [3]	validation_0-rmse:4.49241	validation_1-rmse:4.88866
# [4]	validation_0-rmse:4.05346	validation_1-rmse:4.44127
# [5]	validation_0-rmse:3.73335	validation_1-rmse:4.10493
# [6]	validation_0-rmse:3.38056	validation_1-rmse:3.73005
# [7]	validation_0-rmse:3.07495	validation_1-rmse:3.44711
# [8]	validation_0-rmse:2.84076	validation_1-rmse:3.19827
# [9]	validation_0-rmse:2.60433	validation_1-rmse:2.96242
# [10]	validation_0-rmse:2.36128	validation_1-rmse:2.71677
# [11]	validation_0-rmse:2.22514	validation_1-rmse:2.58949
# [12]	validation_0-rmse:2.09214	validation_1-rmse:2.43864
# [13]	validation_0-rmse:1.91912	validation_1-rmse:2.24316
# [14]	validation_0-rmse:1.79970	validation_1-rmse:2.11376
# [15]	validation_0-rmse:1.68423	validation_1-rmse:1.99237
# [16]	validation_0-rmse:1.61018	validation_1-rmse:1.91320
# [17]	validation_0-rmse:1.51454	validation_1-rmse:1.81433
# [18]	validation_0-rmse:1.43606	validation_1-rmse:1.74037
# [19]	validation_0-rmse:1.39034	validation_1-rmse:1.67825
# [20]	validation_0-rmse:1.34858	validation_1-rmse:1.61797
# [21]	validation_0-rmse:1.29349	validation_1-rmse:1.56542
# [22]	validation_0-rmse:1.24076	validation_1-rmse:1.52057
# [23]	validation_0-rmse:1.20794	validation_1-rmse:1.47936
# [24]	validation_0-rmse:1.17815	validation_1-rmse:1.44707
# [25]	validation_0-rmse:1.14089	validation_1-rmse:1.42276
# [26]	validation_0-rmse:1.11474	validation_1-rmse:1.38697
# [27]	validation_0-rmse:1.08464	validation_1-rmse:1.37597
# [28]	validation_0-rmse:1.06009	validation_1-rmse:1.35097
# [29]	validation_0-rmse:1.04301	validation_1-rmse:1.34158
# [30]	validation_0-rmse:1.02677	validation_1-rmse:1.33104
# [31]	validation_0-rmse:1.01336	validation_1-rmse:1.31038
# [32]	validation_0-rmse:1.00395	validation_1-rmse:1.29347
# [33]	validation_0-rmse:0.98960	validation_1-rmse:1.28103
# [34]	validation_0-rmse:0.98179	validation_1-rmse:1.27948
# [35]	validation_0-rmse:0.97347	validation_1-rmse:1.27325
# [36]	validation_0-rmse:0.96611	validation_1-rmse:1.26603
# [37]	validation_0-rmse:0.96676	validation_1-rmse:1.26788
# [38]	validation_0-rmse:0.96073	validation_1-rmse:1.25252
# [39]	validation_0-rmse:0.95565	validation_1-rmse:1.25173
# [40]	validation_0-rmse:0.95526	validation_1-rmse:1.24448
# [41]	validation_0-rmse:0.94760	validation_1-rmse:1.22295
# [42]	validation_0-rmse:0.94612	validation_1-rmse:1.24524
# [43]	validation_0-rmse:0.93872	validation_1-rmse:1.25653
# [44]	validation_0-rmse:0.93431	validation_1-rmse:1.27098
# [45]	validation_0-rmse:0.93721	validation_1-rmse:1.27650
# [46]	validation_0-rmse:0.93672	validation_1-rmse:1.25692
# [47]	validation_0-rmse:0.93791	validation_1-rmse:1.24089
# [48]	validation_0-rmse:0.92970	validation_1-rmse:1.24022
# [49]	validation_0-rmse:0.92374	validation_1-rmse:1.24350
# [50]	validation_0-rmse:0.92077	validation_1-rmse:1.26154
# [0]	validation_0-rmse:6.08523	validation_1-rmse:6.04242
# [1]	validation_0-rmse:5.47368	validation_1-rmse:5.43700
# [2]	validation_0-rmse:4.93657	validation_1-rmse:4.90661
# [3]	validation_0-rmse:4.50972	validation_1-rmse:4.47879
# [4]	validation_0-rmse:4.08550	validation_1-rmse:4.06394
# [5]	validation_0-rmse:3.69739	validation_1-rmse:3.70348
# [6]	validation_0-rmse:3.36542	validation_1-rmse:3.42274
# [7]	validation_0-rmse:3.07808	validation_1-rmse:3.16718
# [8]	validation_0-rmse:2.80284	validation_1-rmse:2.93755
# [9]	validation_0-rmse:2.55288	validation_1-rmse:2.71365
# [10]	validation_0-rmse:2.38525	validation_1-rmse:2.56697
# [11]	validation_0-rmse:2.21936	validation_1-rmse:2.42911
# [12]	validation_0-rmse:2.04534	validation_1-rmse:2.30032
# [13]	validation_0-rmse:1.88816	validation_1-rmse:2.15571
# [14]	validation_0-rmse:1.77950	validation_1-rmse:2.05275
# [15]	validation_0-rmse:1.67673	validation_1-rmse:1.95561
# [16]	validation_0-rmse:1.58694	validation_1-rmse:1.87087
# [17]	validation_0-rmse:1.47610	validation_1-rmse:1.77911
# [18]	validation_0-rmse:1.39503	validation_1-rmse:1.71137
# [19]	validation_0-rmse:1.31907	validation_1-rmse:1.65042
# [20]	validation_0-rmse:1.24659	validation_1-rmse:1.59430
# [21]	validation_0-rmse:1.20814	validation_1-rmse:1.55388
# [22]	validation_0-rmse:1.16673	validation_1-rmse:1.52196
# [23]	validation_0-rmse:1.11712	validation_1-rmse:1.47663
# [24]	validation_0-rmse:1.08595	validation_1-rmse:1.45276
# [25]	validation_0-rmse:1.06040	validation_1-rmse:1.43288
# [26]	validation_0-rmse:1.04266	validation_1-rmse:1.41570
# [27]	validation_0-rmse:1.02305	validation_1-rmse:1.38371
# [28]	validation_0-rmse:1.01312	validation_1-rmse:1.36946
# [29]	validation_0-rmse:1.00000	validation_1-rmse:1.36440
# [30]	validation_0-rmse:0.99331	validation_1-rmse:1.34614
# [31]	validation_0-rmse:0.99063	validation_1-rmse:1.34867
# [32]	validation_0-rmse:0.97499	validation_1-rmse:1.32730
# [33]	validation_0-rmse:0.96971	validation_1-rmse:1.31809
# [34]	validation_0-rmse:0.96377	validation_1-rmse:1.31617
# [35]	validation_0-rmse:0.95685	validation_1-rmse:1.29965
# [36]	validation_0-rmse:0.95265	validation_1-rmse:1.30058
# [37]	validation_0-rmse:0.95734	validation_1-rmse:1.31034
# [38]	validation_0-rmse:0.95055	validation_1-rmse:1.30864
# [39]	validation_0-rmse:0.94921	validation_1-rmse:1.29511
# [40]	validation_0-rmse:0.94150	validation_1-rmse:1.28915
# [41]	validation_0-rmse:0.93540	validation_1-rmse:1.28394
# [42]	validation_0-rmse:0.92947	validation_1-rmse:1.28906
# [43]	validation_0-rmse:0.93096	validation_1-rmse:1.29758
# [44]	validation_0-rmse:0.92576	validation_1-rmse:1.30106
# [45]	validation_0-rmse:0.91831	validation_1-rmse:1.29897
# [46]	validation_0-rmse:0.91168	validation_1-rmse:1.29604
# [47]	validation_0-rmse:0.91069	validation_1-rmse:1.29291
# [48]	validation_0-rmse:0.91267	validation_1-rmse:1.29860
# [49]	validation_0-rmse:0.91158	validation_1-rmse:1.29400
# [50]	validation_0-rmse:0.90994	validation_1-rmse:1.29724
# [51]	validation_0-rmse:0.91155	validation_1-rmse:1.29569
# [0]	validation_0-rmse:6.21035	validation_1-rmse:5.63236
# [1]	validation_0-rmse:5.62001	validation_1-rmse:5.06686
# [2]	validation_0-rmse:5.10998	validation_1-rmse:4.55966
# [3]	validation_0-rmse:4.61171	validation_1-rmse:4.10957
# [4]	validation_0-rmse:4.15880	validation_1-rmse:3.70099
# [5]	validation_0-rmse:3.78832	validation_1-rmse:3.38128
# [6]	validation_0-rmse:3.40818	validation_1-rmse:3.03901
# [7]	validation_0-rmse:3.10746	validation_1-rmse:2.74730
# [8]	validation_0-rmse:2.82655	validation_1-rmse:2.49393
# [9]	validation_0-rmse:2.59547	validation_1-rmse:2.30357
# [10]	validation_0-rmse:2.36061	validation_1-rmse:2.08508
# [11]	validation_0-rmse:2.22077	validation_1-rmse:1.97141
# [12]	validation_0-rmse:2.04070	validation_1-rmse:1.82097
# [13]	validation_0-rmse:1.89850	validation_1-rmse:1.70851
# [14]	validation_0-rmse:1.75976	validation_1-rmse:1.60527
# [15]	validation_0-rmse:1.65160	validation_1-rmse:1.54053
# [16]	validation_0-rmse:1.56491	validation_1-rmse:1.48133
# [17]	validation_0-rmse:1.49740	validation_1-rmse:1.43741
# [18]	validation_0-rmse:1.38959	validation_1-rmse:1.37503
# [19]	validation_0-rmse:1.31862	validation_1-rmse:1.33855
# [20]	validation_0-rmse:1.27100	validation_1-rmse:1.32402
# [21]	validation_0-rmse:1.20734	validation_1-rmse:1.29942
# [22]	validation_0-rmse:1.16904	validation_1-rmse:1.27577
# [23]	validation_0-rmse:1.12151	validation_1-rmse:1.26193
# [24]	validation_0-rmse:1.10507	validation_1-rmse:1.26956
# [25]	validation_0-rmse:1.07163	validation_1-rmse:1.25980
# [26]	validation_0-rmse:1.05752	validation_1-rmse:1.26086
# [27]	validation_0-rmse:1.04269	validation_1-rmse:1.27338
# [28]	validation_0-rmse:1.02922	validation_1-rmse:1.26757
# [29]	validation_0-rmse:1.00597	validation_1-rmse:1.24660
# [30]	validation_0-rmse:0.98169	validation_1-rmse:1.24221
# [31]	validation_0-rmse:0.97074	validation_1-rmse:1.24501
# [32]	validation_0-rmse:0.97825	validation_1-rmse:1.25689
# [33]	validation_0-rmse:0.96198	validation_1-rmse:1.25594
# [34]	validation_0-rmse:0.94441	validation_1-rmse:1.26803
# [35]	validation_0-rmse:0.93665	validation_1-rmse:1.25051
# [36]	validation_0-rmse:0.92761	validation_1-rmse:1.25520
# [37]	validation_0-rmse:0.92282	validation_1-rmse:1.25370
# [38]	validation_0-rmse:0.91264	validation_1-rmse:1.26481
# [39]	validation_0-rmse:0.90273	validation_1-rmse:1.27435
# [40]	validation_0-rmse:0.89969	validation_1-rmse:1.27440
# [0]	validation_0-rmse:6.06567	validation_1-rmse:6.16517
# [1]	validation_0-rmse:5.47478	validation_1-rmse:5.58488
# [2]	validation_0-rmse:4.98273	validation_1-rmse:5.09621
# [3]	validation_0-rmse:4.54478	validation_1-rmse:4.67856
# [4]	validation_0-rmse:4.11079	validation_1-rmse:4.25404
# [5]	validation_0-rmse:3.79185	validation_1-rmse:3.94532
# [6]	validation_0-rmse:3.46111	validation_1-rmse:3.62189
# [7]	validation_0-rmse:3.13974	validation_1-rmse:3.29220
# [8]	validation_0-rmse:2.86921	validation_1-rmse:3.02903
# [9]	validation_0-rmse:2.63127	validation_1-rmse:2.77510
# [10]	validation_0-rmse:2.43075	validation_1-rmse:2.57171
# [11]	validation_0-rmse:2.26223	validation_1-rmse:2.41350
# [12]	validation_0-rmse:2.09923	validation_1-rmse:2.25720
# [13]	validation_0-rmse:1.93828	validation_1-rmse:2.09150
# [14]	validation_0-rmse:1.80929	validation_1-rmse:1.97471
# [15]	validation_0-rmse:1.69721	validation_1-rmse:1.87465
# [16]	validation_0-rmse:1.62436	validation_1-rmse:1.78783
# [17]	validation_0-rmse:1.51795	validation_1-rmse:1.66651
# [18]	validation_0-rmse:1.47600	validation_1-rmse:1.64316
# [19]	validation_0-rmse:1.40249	validation_1-rmse:1.55055
# [20]	validation_0-rmse:1.33987	validation_1-rmse:1.47901
# [21]	validation_0-rmse:1.30650	validation_1-rmse:1.45400
# [22]	validation_0-rmse:1.24893	validation_1-rmse:1.40376
# [23]	validation_0-rmse:1.21617	validation_1-rmse:1.35991
# [24]	validation_0-rmse:1.17792	validation_1-rmse:1.33418
# [25]	validation_0-rmse:1.16561	validation_1-rmse:1.32567
# [26]	validation_0-rmse:1.13623	validation_1-rmse:1.28422
# [27]	validation_0-rmse:1.11252	validation_1-rmse:1.24680
# [28]	validation_0-rmse:1.08054	validation_1-rmse:1.22207
# [29]	validation_0-rmse:1.06497	validation_1-rmse:1.21314
# [30]	validation_0-rmse:1.05267	validation_1-rmse:1.18481
# [31]	validation_0-rmse:1.04880	validation_1-rmse:1.19176
# [32]	validation_0-rmse:1.03443	validation_1-rmse:1.15482
# [33]	validation_0-rmse:1.02041	validation_1-rmse:1.15075
# [34]	validation_0-rmse:1.01900	validation_1-rmse:1.17158
# [35]	validation_0-rmse:1.01239	validation_1-rmse:1.18064
# [36]	validation_0-rmse:1.00451	validation_1-rmse:1.19488
# [37]	validation_0-rmse:1.00779	validation_1-rmse:1.20366
# [38]	validation_0-rmse:1.00182	validation_1-rmse:1.16999
# [39]	validation_0-rmse:0.99418	validation_1-rmse:1.16261
# [40]	validation_0-rmse:0.98933	validation_1-rmse:1.15473
# [41]	validation_0-rmse:0.98433	validation_1-rmse:1.16081
# [42]	validation_0-rmse:0.98234	validation_1-rmse:1.16193
# [43]	validation_0-rmse:0.98439	validation_1-rmse:1.11827
# [44]	validation_0-rmse:0.98523	validation_1-rmse:1.13507
# [45]	validation_0-rmse:0.97797	validation_1-rmse:1.14293
# [46]	validation_0-rmse:0.97084	validation_1-rmse:1.13903
# [47]	validation_0-rmse:0.96764	validation_1-rmse:1.14161
# [48]	validation_0-rmse:0.96372	validation_1-rmse:1.15040
# [49]	validation_0-rmse:0.95896	validation_1-rmse:1.15487
# [50]	validation_0-rmse:0.95673	validation_1-rmse:1.17106
# [51]	validation_0-rmse:0.95457	validation_1-rmse:1.17370
# [0]	validation_0-rmse:6.03143	validation_1-rmse:6.39406
# [1]	validation_0-rmse:5.41292	validation_1-rmse:5.77573
# [2]	validation_0-rmse:4.87436	validation_1-rmse:5.21020
# [3]	validation_0-rmse:4.45654	validation_1-rmse:4.79197
# [4]	validation_0-rmse:4.02562	validation_1-rmse:4.35264
# [5]	validation_0-rmse:3.61272	validation_1-rmse:3.92151
# [6]	validation_0-rmse:3.30972	validation_1-rmse:3.61137
# [7]	validation_0-rmse:3.01341	validation_1-rmse:3.30561
# [8]	validation_0-rmse:2.76021	validation_1-rmse:3.03593
# [9]	validation_0-rmse:2.50868	validation_1-rmse:2.76228
# [10]	validation_0-rmse:2.29248	validation_1-rmse:2.53959
# [11]	validation_0-rmse:2.16857	validation_1-rmse:2.39467
# [12]	validation_0-rmse:1.99580	validation_1-rmse:2.18619
# [13]	validation_0-rmse:1.85616	validation_1-rmse:2.03429
# [14]	validation_0-rmse:1.76266	validation_1-rmse:1.94158
# [15]	validation_0-rmse:1.65196	validation_1-rmse:1.82065
# [16]	validation_0-rmse:1.56235	validation_1-rmse:1.72725
# [17]	validation_0-rmse:1.48355	validation_1-rmse:1.64132
# [18]	validation_0-rmse:1.39489	validation_1-rmse:1.53211
# [19]	validation_0-rmse:1.35458	validation_1-rmse:1.47264
# [20]	validation_0-rmse:1.29738	validation_1-rmse:1.40022
# [21]	validation_0-rmse:1.27090	validation_1-rmse:1.40062
# [22]	validation_0-rmse:1.21521	validation_1-rmse:1.33406
# [23]	validation_0-rmse:1.17776	validation_1-rmse:1.28849
# [24]	validation_0-rmse:1.14601	validation_1-rmse:1.24104
# [25]	validation_0-rmse:1.12796	validation_1-rmse:1.19901
# [26]	validation_0-rmse:1.11374	validation_1-rmse:1.19160
# [27]	validation_0-rmse:1.10173	validation_1-rmse:1.18625
# [28]	validation_0-rmse:1.08707	validation_1-rmse:1.17384
# [29]	validation_0-rmse:1.06854	validation_1-rmse:1.15379
# [30]	validation_0-rmse:1.06738	validation_1-rmse:1.13376
# [31]	validation_0-rmse:1.05890	validation_1-rmse:1.14170
# [32]	validation_0-rmse:1.03759	validation_1-rmse:1.11418
# [33]	validation_0-rmse:1.02422	validation_1-rmse:1.10438
# [34]	validation_0-rmse:1.01227	validation_1-rmse:1.08715
# [35]	validation_0-rmse:1.00472	validation_1-rmse:1.07795
# [36]	validation_0-rmse:0.98846	validation_1-rmse:1.07162
# [37]	validation_0-rmse:0.98873	validation_1-rmse:1.08042
# [38]	validation_0-rmse:0.98032	validation_1-rmse:1.07058
# [39]	validation_0-rmse:0.97466	validation_1-rmse:1.05561
# [40]	validation_0-rmse:0.97101	validation_1-rmse:1.03873
# [41]	validation_0-rmse:0.96611	validation_1-rmse:1.04065
# [42]	validation_0-rmse:0.96131	validation_1-rmse:1.03743
# [43]	validation_0-rmse:0.95351	validation_1-rmse:1.03588
# [44]	validation_0-rmse:0.95289	validation_1-rmse:1.04455
# [45]	validation_0-rmse:0.94926	validation_1-rmse:1.02257
# [46]	validation_0-rmse:0.94806	validation_1-rmse:1.00942
# [47]	validation_0-rmse:0.94367	validation_1-rmse:1.01146
# [48]	validation_0-rmse:0.94253	validation_1-rmse:0.99803
# [49]	validation_0-rmse:0.93916	validation_1-rmse:0.99826
# [50]	validation_0-rmse:0.93525	validation_1-rmse:1.01252
# [51]	validation_0-rmse:0.93789	validation_1-rmse:1.03356
# [0]	validation_0-rmse:6.00263	validation_1-rmse:6.44570
# [1]	validation_0-rmse:5.42209	validation_1-rmse:5.86449
# [2]	validation_0-rmse:4.94854	validation_1-rmse:5.33989
# [3]	validation_0-rmse:4.47182	validation_1-rmse:4.86186
# [4]	validation_0-rmse:4.05046	validation_1-rmse:4.42890
# [5]	validation_0-rmse:3.68694	validation_1-rmse:4.06374
# [6]	validation_0-rmse:3.39993	validation_1-rmse:3.75969
# [7]	validation_0-rmse:3.11186	validation_1-rmse:3.44883
# [8]	validation_0-rmse:2.82510	validation_1-rmse:3.11303
# [9]	validation_0-rmse:2.62259	validation_1-rmse:2.89405
# [10]	validation_0-rmse:2.43312	validation_1-rmse:2.70456
# [11]	validation_0-rmse:2.26224	validation_1-rmse:2.52123
# [12]	validation_0-rmse:2.07018	validation_1-rmse:2.30144
# [13]	validation_0-rmse:1.90553	validation_1-rmse:2.12483
# [14]	validation_0-rmse:1.78598	validation_1-rmse:1.99080
# [15]	validation_0-rmse:1.66412	validation_1-rmse:1.86057
# [16]	validation_0-rmse:1.55146	validation_1-rmse:1.76191
# [17]	validation_0-rmse:1.46605	validation_1-rmse:1.68660
# [18]	validation_0-rmse:1.40211	validation_1-rmse:1.62967
# [19]	validation_0-rmse:1.34665	validation_1-rmse:1.56721
# [20]	validation_0-rmse:1.28345	validation_1-rmse:1.51011
# [21]	validation_0-rmse:1.24156	validation_1-rmse:1.48730
# [22]	validation_0-rmse:1.21133	validation_1-rmse:1.46158
# [23]	validation_0-rmse:1.17188	validation_1-rmse:1.42406
# [24]	validation_0-rmse:1.14816	validation_1-rmse:1.40389
# [25]	validation_0-rmse:1.12771	validation_1-rmse:1.36834
# [26]	validation_0-rmse:1.08218	validation_1-rmse:1.33901
# [27]	validation_0-rmse:1.05564	validation_1-rmse:1.32376
# [28]	validation_0-rmse:1.01875	validation_1-rmse:1.28699
# [29]	validation_0-rmse:0.99986	validation_1-rmse:1.26872
# [30]	validation_0-rmse:0.98568	validation_1-rmse:1.26711
# [31]	validation_0-rmse:0.97691	validation_1-rmse:1.25639
# [32]	validation_0-rmse:0.96342	validation_1-rmse:1.25595
# [33]	validation_0-rmse:0.95429	validation_1-rmse:1.24335
# [34]	validation_0-rmse:0.94663	validation_1-rmse:1.24405
# [35]	validation_0-rmse:0.94458	validation_1-rmse:1.23919
# [36]	validation_0-rmse:0.94679	validation_1-rmse:1.23827
# [37]	validation_0-rmse:0.94108	validation_1-rmse:1.24361
# [38]	validation_0-rmse:0.93985	validation_1-rmse:1.24284
# [39]	validation_0-rmse:0.93426	validation_1-rmse:1.24443
# [40]	validation_0-rmse:0.92398	validation_1-rmse:1.24044
# [41]	validation_0-rmse:0.92148	validation_1-rmse:1.24244
# [42]	validation_0-rmse:0.91676	validation_1-rmse:1.24692
# [43]	validation_0-rmse:0.91701	validation_1-rmse:1.24675
# [44]	validation_0-rmse:0.91408	validation_1-rmse:1.24530
# [45]	validation_0-rmse:0.90707	validation_1-rmse:1.24740
# [46]	validation_0-rmse:0.90169	validation_1-rmse:1.25462
# [0]	validation_0-rmse:5.98573	validation_1-rmse:6.56936
# [1]	validation_0-rmse:5.37856	validation_1-rmse:5.95662
# [2]	validation_0-rmse:4.84536	validation_1-rmse:5.36708
# [3]	validation_0-rmse:4.43804	validation_1-rmse:4.95448
# [4]	validation_0-rmse:4.03968	validation_1-rmse:4.51870
# [5]	validation_0-rmse:3.65709	validation_1-rmse:4.08115
# [6]	validation_0-rmse:3.32705	validation_1-rmse:3.71220
# [7]	validation_0-rmse:3.05973	validation_1-rmse:3.42924
# [8]	validation_0-rmse:2.79652	validation_1-rmse:3.13707
# [9]	validation_0-rmse:2.56465	validation_1-rmse:2.86651
# [10]	validation_0-rmse:2.37962	validation_1-rmse:2.64426
# [11]	validation_0-rmse:2.22670	validation_1-rmse:2.44746
# [12]	validation_0-rmse:2.03543	validation_1-rmse:2.19584
# ...
# [38]	validation_0-rmse:0.97210	validation_1-rmse:1.28721
# [39]	validation_0-rmse:0.97016	validation_1-rmse:1.25596
# [40]	validation_0-rmse:0.96653	validation_1-rmse:1.19637
# [41]	validation_0-rmse:0.96301	validation_1-rmse:1.18415
# [42]	validation_0-rmse:0.96289	validation_1-rmse:1.20932
# [43]	validation_0-rmse:0.95804	validation_1-rmse:1.24856
# [44]	validation_0-rmse:0.95431	validation_1-rmse:1.22673
# [45]	validation_0-rmse:0.95037	validation_1-rmse:1.19595
# [46]	validation_0-rmse:0.95259	validation_1-rmse:1.22053
# [47]	validation_0-rmse:0.94800	validation_1-rmse:1.21668
# [48]	validation_0-rmse:0.94370	validation_1-rmse:1.19424
# [49]	validation_0-rmse:0.94228	validation_1-rmse:1.23303
# [50]	validation_0-rmse:0.93655	validation_1-rmse:1.25296
# [51]	validation_0-rmse:0.93768	validation_1-rmse:1.26081
# [0]	validation_0-rmse:6.24438	validation_1-rmse:5.63433
# [1]	validation_0-rmse:5.66432	validation_1-rmse:5.04762
# [2]	validation_0-rmse:5.09879	validation_1-rmse:4.53176
# [3]	validation_0-rmse:4.62856	validation_1-rmse:4.17928
# [4]	validation_0-rmse:4.20801	validation_1-rmse:3.75332
# [5]	validation_0-rmse:3.89173	validation_1-rmse:3.41611
# [6]	validation_0-rmse:3.55124	validation_1-rmse:3.10312
# [7]	validation_0-rmse:3.24805	validation_1-rmse:2.83065
# [8]	validation_0-rmse:2.99396	validation_1-rmse:2.60602
# [9]	validation_0-rmse:2.74898	validation_1-rmse:2.35594
# [10]	validation_0-rmse:2.53039	validation_1-rmse:2.13277
# [11]	validation_0-rmse:2.32514	validation_1-rmse:1.94846
# [12]	validation_0-rmse:2.14939	validation_1-rmse:1.79890
# [13]	validation_0-rmse:2.00566	validation_1-rmse:1.66263
# [14]	validation_0-rmse:1.86520	validation_1-rmse:1.55214
# [15]	validation_0-rmse:1.73068	validation_1-rmse:1.44009
# [16]	validation_0-rmse:1.60775	validation_1-rmse:1.31952
# [17]	validation_0-rmse:1.52830	validation_1-rmse:1.26541
# [18]	validation_0-rmse:1.45208	validation_1-rmse:1.19564
# [19]	validation_0-rmse:1.38674	validation_1-rmse:1.14030
# [20]	validation_0-rmse:1.33252	validation_1-rmse:1.10109
# [21]	validation_0-rmse:1.28053	validation_1-rmse:1.07863
# [22]	validation_0-rmse:1.22441	validation_1-rmse:1.05463
# [23]	validation_0-rmse:1.19367	validation_1-rmse:1.03669
# [24]	validation_0-rmse:1.17397	validation_1-rmse:1.03168
# [25]	validation_0-rmse:1.14525	validation_1-rmse:1.00596
# [26]	validation_0-rmse:1.12401	validation_1-rmse:0.98319
# [27]	validation_0-rmse:1.11009	validation_1-rmse:0.96891
# [28]	validation_0-rmse:1.09507	validation_1-rmse:0.96450
# [29]	validation_0-rmse:1.07557	validation_1-rmse:0.95736
# [30]	validation_0-rmse:1.07181	validation_1-rmse:0.95557
# [31]	validation_0-rmse:1.05888	validation_1-rmse:0.92887
# [32]	validation_0-rmse:1.05869	validation_1-rmse:0.92510
# [33]	validation_0-rmse:1.05504	validation_1-rmse:0.92157
# [34]	validation_0-rmse:1.04281	validation_1-rmse:0.91013
# [35]	validation_0-rmse:1.03988	validation_1-rmse:0.90899
# [36]	validation_0-rmse:1.03208	validation_1-rmse:0.90666
# [37]	validation_0-rmse:1.02570	validation_1-rmse:0.89949
# [38]	validation_0-rmse:1.02255	validation_1-rmse:0.91044
# [39]	validation_0-rmse:1.01883	validation_1-rmse:0.91391
# [40]	validation_0-rmse:1.01592	validation_1-rmse:0.90940
# [41]	validation_0-rmse:1.01752	validation_1-rmse:0.91774
# [42]	validation_0-rmse:1.01688	validation_1-rmse:0.92178
# [43]	validation_0-rmse:1.01524	validation_1-rmse:0.92234
# [44]	validation_0-rmse:1.01016	validation_1-rmse:0.91965
# [45]	validation_0-rmse:1.00564	validation_1-rmse:0.91426
# [46]	validation_0-rmse:1.00564	validation_1-rmse:0.91123
# [0]	validation_0-rmse:6.14295	validation_1-rmse:5.86085
# [1]	validation_0-rmse:5.53454	validation_1-rmse:5.26886
# [2]	validation_0-rmse:4.97866	validation_1-rmse:4.73433
# [3]	validation_0-rmse:4.50968	validation_1-rmse:4.30029
# [4]	validation_0-rmse:4.12160	validation_1-rmse:3.95775
# [5]	validation_0-rmse:3.72352	validation_1-rmse:3.57922
# [6]	validation_0-rmse:3.38023	validation_1-rmse:3.28988
# [7]	validation_0-rmse:3.06980	validation_1-rmse:2.99303
# [8]	validation_0-rmse:2.81269	validation_1-rmse:2.76812
# [9]	validation_0-rmse:2.56564	validation_1-rmse:2.56934
# [10]	validation_0-rmse:2.38306	validation_1-rmse:2.40702
# [11]	validation_0-rmse:2.22136	validation_1-rmse:2.27789
# [12]	validation_0-rmse:2.07553	validation_1-rmse:2.15052
# [13]	validation_0-rmse:1.91809	validation_1-rmse:2.00939
# [14]	validation_0-rmse:1.79047	validation_1-rmse:1.89312
# [15]	validation_0-rmse:1.68337	validation_1-rmse:1.79781
# [16]	validation_0-rmse:1.58767	validation_1-rmse:1.71143
# [17]	validation_0-rmse:1.49592	validation_1-rmse:1.63075
# [18]	validation_0-rmse:1.43713	validation_1-rmse:1.57317
# [19]	validation_0-rmse:1.35500	validation_1-rmse:1.50770
# [20]	validation_0-rmse:1.31231	validation_1-rmse:1.45662
# [21]	validation_0-rmse:1.28480	validation_1-rmse:1.43336
# [22]	validation_0-rmse:1.23581	validation_1-rmse:1.39633
# [23]	validation_0-rmse:1.19167	validation_1-rmse:1.36562
# [24]	validation_0-rmse:1.17128	validation_1-rmse:1.35347
# [25]	validation_0-rmse:1.14069	validation_1-rmse:1.33233
# [26]	validation_0-rmse:1.11690	validation_1-rmse:1.31369
# [27]	validation_0-rmse:1.09889	validation_1-rmse:1.29981
# [28]	validation_0-rmse:1.07085	validation_1-rmse:1.28778
# [29]	validation_0-rmse:1.05529	validation_1-rmse:1.28386
# [30]	validation_0-rmse:1.04370	validation_1-rmse:1.29174
# [31]	validation_0-rmse:1.02561	validation_1-rmse:1.27246
# [32]	validation_0-rmse:1.01659	validation_1-rmse:1.27005
# [33]	validation_0-rmse:1.00357	validation_1-rmse:1.26125
# [34]	validation_0-rmse:0.99777	validation_1-rmse:1.25939
# [35]	validation_0-rmse:0.98436	validation_1-rmse:1.23799
# [36]	validation_0-rmse:0.97461	validation_1-rmse:1.23468
# [37]	validation_0-rmse:0.95448	validation_1-rmse:1.22473
# [38]	validation_0-rmse:0.94704	validation_1-rmse:1.21391
# [39]	validation_0-rmse:0.94582	validation_1-rmse:1.20268
# [40]	validation_0-rmse:0.94093	validation_1-rmse:1.21294
# [41]	validation_0-rmse:0.94109	validation_1-rmse:1.19745
# [42]	validation_0-rmse:0.93589	validation_1-rmse:1.19881
# [43]	validation_0-rmse:0.92917	validation_1-rmse:1.21115
# [44]	validation_0-rmse:0.92938	validation_1-rmse:1.21167
# [45]	validation_0-rmse:0.92829	validation_1-rmse:1.22469
# [46]	validation_0-rmse:0.92646	validation_1-rmse:1.22819
# [47]	validation_0-rmse:0.92470	validation_1-rmse:1.22067
# [48]	validation_0-rmse:0.92011	validation_1-rmse:1.21030
# [49]	validation_0-rmse:0.91466	validation_1-rmse:1.22056
# [50]	validation_0-rmse:0.91520	validation_1-rmse:1.23734
# [0]	validation_0-rmse:6.10644	validation_1-rmse:6.01741
# [1]	validation_0-rmse:5.53668	validation_1-rmse:5.45695
# [2]	validation_0-rmse:4.97773	validation_1-rmse:4.90023
# [3]	validation_0-rmse:4.50694	validation_1-rmse:4.43401
# [4]	validation_0-rmse:4.09272	validation_1-rmse:4.01325
# [5]	validation_0-rmse:3.69480	validation_1-rmse:3.62070
# [6]	validation_0-rmse:3.36523	validation_1-rmse:3.32514
# [7]	validation_0-rmse:3.06491	validation_1-rmse:3.04232
# [8]	validation_0-rmse:2.81301	validation_1-rmse:2.83109
# [9]	validation_0-rmse:2.58700	validation_1-rmse:2.62423
# [10]	validation_0-rmse:2.37154	validation_1-rmse:2.41522
# [11]	validation_0-rmse:2.18046	validation_1-rmse:2.22754
# [12]	validation_0-rmse:2.00252	validation_1-rmse:2.06708
# [13]	validation_0-rmse:1.87443	validation_1-rmse:1.93985
# [14]	validation_0-rmse:1.73740	validation_1-rmse:1.81911
# [15]	validation_0-rmse:1.62319	validation_1-rmse:1.71830
# [16]	validation_0-rmse:1.52614	validation_1-rmse:1.63294
# [17]	validation_0-rmse:1.44368	validation_1-rmse:1.55499
# [18]	validation_0-rmse:1.34338	validation_1-rmse:1.46190
# [19]	validation_0-rmse:1.29269	validation_1-rmse:1.41783
# [20]	validation_0-rmse:1.24011	validation_1-rmse:1.37678
# [21]	validation_0-rmse:1.20104	validation_1-rmse:1.34014
# [22]	validation_0-rmse:1.16433	validation_1-rmse:1.30144
# [23]	validation_0-rmse:1.14131	validation_1-rmse:1.29263
# [24]	validation_0-rmse:1.10289	validation_1-rmse:1.26276
# [25]	validation_0-rmse:1.07857	validation_1-rmse:1.24883
# [26]	validation_0-rmse:1.05317	validation_1-rmse:1.21507
# [27]	validation_0-rmse:1.04513	validation_1-rmse:1.20271
# [28]	validation_0-rmse:1.03667	validation_1-rmse:1.19684
# [29]	validation_0-rmse:1.02532	validation_1-rmse:1.19899
# [30]	validation_0-rmse:1.02219	validation_1-rmse:1.18756
# [31]	validation_0-rmse:0.99973	validation_1-rmse:1.17051
# [32]	validation_0-rmse:0.99468	validation_1-rmse:1.15566
# [33]	validation_0-rmse:0.98377	validation_1-rmse:1.15473
# [34]	validation_0-rmse:0.98062	validation_1-rmse:1.16180
# [35]	validation_0-rmse:0.97242	validation_1-rmse:1.16351
# [36]	validation_0-rmse:0.97861	validation_1-rmse:1.17519
# [37]	validation_0-rmse:0.97099	validation_1-rmse:1.15635
# [38]	validation_0-rmse:0.96275	validation_1-rmse:1.15867
# [39]	validation_0-rmse:0.95549	validation_1-rmse:1.15379
# [40]	validation_0-rmse:0.94533	validation_1-rmse:1.16149
# [41]	validation_0-rmse:0.94559	validation_1-rmse:1.14227
# [42]	validation_0-rmse:0.94086	validation_1-rmse:1.13958
# [43]	validation_0-rmse:0.94238	validation_1-rmse:1.14393
# [44]	validation_0-rmse:0.93793	validation_1-rmse:1.16549
# [45]	validation_0-rmse:0.93251	validation_1-rmse:1.16845
# [46]	validation_0-rmse:0.92791	validation_1-rmse:1.17317
# [47]	validation_0-rmse:0.92282	validation_1-rmse:1.18449
# [48]	validation_0-rmse:0.92412	validation_1-rmse:1.17619
# [49]	validation_0-rmse:0.92264	validation_1-rmse:1.17838
# [50]	validation_0-rmse:0.91366	validation_1-rmse:1.17925
# [51]	validation_0-rmse:0.91108	validation_1-rmse:1.18181
# [0]	validation_0-rmse:6.00438	validation_1-rmse:6.52569
# [1]	validation_0-rmse:5.43004	validation_1-rmse:5.94103
# [2]	validation_0-rmse:4.87488	validation_1-rmse:5.33991
# [3]	validation_0-rmse:4.38897	validation_1-rmse:4.84108
# [4]	validation_0-rmse:4.01874	validation_1-rmse:4.41866
# [5]	validation_0-rmse:3.62609	validation_1-rmse:3.98261
# [6]	validation_0-rmse:3.36130	validation_1-rmse:3.68222
# [7]	validation_0-rmse:3.05384	validation_1-rmse:3.33360
# [8]	validation_0-rmse:2.80361	validation_1-rmse:3.02837
# [9]	validation_0-rmse:2.59090	validation_1-rmse:2.80101
# [10]	validation_0-rmse:2.43378	validation_1-rmse:2.63078
# [11]	validation_0-rmse:2.26542	validation_1-rmse:2.43120
# [12]	validation_0-rmse:2.07124	validation_1-rmse:2.20793
# [13]	validation_0-rmse:1.91931	validation_1-rmse:2.03343
# [14]	validation_0-rmse:1.82206	validation_1-rmse:1.88870
# [15]	validation_0-rmse:1.71357	validation_1-rmse:1.73095
# [16]	validation_0-rmse:1.62309	validation_1-rmse:1.61661
# [17]	validation_0-rmse:1.53915	validation_1-rmse:1.50051
# [18]	validation_0-rmse:1.46543	validation_1-rmse:1.39482
# [19]	validation_0-rmse:1.41495	validation_1-rmse:1.32254
# [20]	validation_0-rmse:1.35649	validation_1-rmse:1.24885
# [21]	validation_0-rmse:1.31214	validation_1-rmse:1.18599
# [22]	validation_0-rmse:1.25972	validation_1-rmse:1.12734
# [23]	validation_0-rmse:1.22018	validation_1-rmse:1.07906
# [24]	validation_0-rmse:1.19586	validation_1-rmse:1.04414
# [25]	validation_0-rmse:1.16231	validation_1-rmse:0.99145
# [26]	validation_0-rmse:1.14876	validation_1-rmse:0.97352
# [27]	validation_0-rmse:1.12150	validation_1-rmse:0.93024
# [28]	validation_0-rmse:1.10834	validation_1-rmse:0.90331
# [29]	validation_0-rmse:1.09156	validation_1-rmse:0.87694
# [30]	validation_0-rmse:1.09692	validation_1-rmse:0.87598
# [31]	validation_0-rmse:1.08817	validation_1-rmse:0.88531
# [32]	validation_0-rmse:1.06924	validation_1-rmse:0.85105
# [33]	validation_0-rmse:1.06374	validation_1-rmse:0.84890
# [34]	validation_0-rmse:1.04975	validation_1-rmse:0.81589
# [35]	validation_0-rmse:1.04435	validation_1-rmse:0.78949
# [36]	validation_0-rmse:1.03251	validation_1-rmse:0.77335
# [37]	validation_0-rmse:1.03185	validation_1-rmse:0.78560
# [38]	validation_0-rmse:1.03273	validation_1-rmse:0.79924
# [39]	validation_0-rmse:1.02908	validation_1-rmse:0.78548
# [40]	validation_0-rmse:1.02491	validation_1-rmse:0.79066
# [41]	validation_0-rmse:1.01736	validation_1-rmse:0.77830
# [42]	validation_0-rmse:1.01867	validation_1-rmse:0.77818
# [43]	validation_0-rmse:1.01587	validation_1-rmse:0.77570
# [44]	validation_0-rmse:1.01583	validation_1-rmse:0.75573
# [45]	validation_0-rmse:1.01067	validation_1-rmse:0.73427
# [46]	validation_0-rmse:1.00738	validation_1-rmse:0.73709
# [47]	validation_0-rmse:1.00417	validation_1-rmse:0.72849
# [48]	validation_0-rmse:1.00592	validation_1-rmse:0.72080
# [49]	validation_0-rmse:1.00257	validation_1-rmse:0.72463
# [50]	validation_0-rmse:0.99994	validation_1-rmse:0.72043
# [51]	validation_0-rmse:0.99851	validation_1-rmse:0.72822
# [0]	validation_0-rmse:6.16021	validation_1-rmse:5.86511
# [1]	validation_0-rmse:5.57277	validation_1-rmse:5.27118
# [2]	validation_0-rmse:5.07530	validation_1-rmse:4.74910
# [3]	validation_0-rmse:4.62303	validation_1-rmse:4.28173
# [4]	validation_0-rmse:4.16879	validation_1-rmse:3.83091
# [5]	validation_0-rmse:3.81029	validation_1-rmse:3.48021
# [6]	validation_0-rmse:3.46345	validation_1-rmse:3.13949
# [7]	validation_0-rmse:3.16554	validation_1-rmse:2.84588
# [8]	validation_0-rmse:2.91981	validation_1-rmse:2.61263
# [9]	validation_0-rmse:2.66309	validation_1-rmse:2.35962
# [10]	validation_0-rmse:2.44299	validation_1-rmse:2.13635
# [11]	validation_0-rmse:2.26624	validation_1-rmse:1.98348
# [12]	validation_0-rmse:2.09296	validation_1-rmse:1.82412
# [13]	validation_0-rmse:1.92935	validation_1-rmse:1.66966
# [14]	validation_0-rmse:1.80144	validation_1-rmse:1.57043
# [15]	validation_0-rmse:1.69368	validation_1-rmse:1.47533
# [16]	validation_0-rmse:1.59779	validation_1-rmse:1.37920
# [17]	validation_0-rmse:1.51068	validation_1-rmse:1.32599
# [18]	validation_0-rmse:1.45098	validation_1-rmse:1.28284
# [19]	validation_0-rmse:1.36424	validation_1-rmse:1.22491
# [20]	validation_0-rmse:1.30594	validation_1-rmse:1.19372
# [21]	validation_0-rmse:1.23341	validation_1-rmse:1.16311
# [22]	validation_0-rmse:1.18117	validation_1-rmse:1.14398
# [23]	validation_0-rmse:1.14309	validation_1-rmse:1.14163
# [24]	validation_0-rmse:1.11959	validation_1-rmse:1.12600
# [25]	validation_0-rmse:1.09743	validation_1-rmse:1.13046
# [26]	validation_0-rmse:1.06734	validation_1-rmse:1.14306
# [27]	validation_0-rmse:1.05235	validation_1-rmse:1.14791
# [28]	validation_0-rmse:1.03555	validation_1-rmse:1.15063
# [29]	validation_0-rmse:1.00785	validation_1-rmse:1.15762
# [30]	validation_0-rmse:0.99466	validation_1-rmse:1.17499
# [31]	validation_0-rmse:0.98327	validation_1-rmse:1.17135
# [32]	validation_0-rmse:0.97941	validation_1-rmse:1.17989
# [33]	validation_0-rmse:0.96530	validation_1-rmse:1.19295
# [0]	validation_0-rmse:6.23950	validation_1-rmse:5.47325
# [1]	validation_0-rmse:5.63885	validation_1-rmse:4.91955
# [2]	validation_0-rmse:5.09725	validation_1-rmse:4.35684
# [3]	validation_0-rmse:4.59503	validation_1-rmse:3.87123
# [4]	validation_0-rmse:4.17997	validation_1-rmse:3.44477
# [5]	validation_0-rmse:3.78630	validation_1-rmse:3.07363
# [6]	validation_0-rmse:3.47239	validation_1-rmse:2.78841
# [7]	validation_0-rmse:3.13091	validation_1-rmse:2.50216
# [8]	validation_0-rmse:2.85626	validation_1-rmse:2.27203
# [9]	validation_0-rmse:2.65030	validation_1-rmse:2.13083
# [10]	validation_0-rmse:2.44557	validation_1-rmse:1.93583
# [11]	validation_0-rmse:2.26523	validation_1-rmse:1.78940
# [12]	validation_0-rmse:2.07499	validation_1-rmse:1.65844
# [13]	validation_0-rmse:1.91083	validation_1-rmse:1.55926
# [14]	validation_0-rmse:1.75833	validation_1-rmse:1.47605
# [15]	validation_0-rmse:1.64486	validation_1-rmse:1.42714
# [16]	validation_0-rmse:1.53383	validation_1-rmse:1.36764
# [17]	validation_0-rmse:1.44341	validation_1-rmse:1.33984
# [18]	validation_0-rmse:1.36257	validation_1-rmse:1.35005
# [19]	validation_0-rmse:1.27620	validation_1-rmse:1.33849
# [20]	validation_0-rmse:1.20751	validation_1-rmse:1.33887
# [21]	validation_0-rmse:1.16193	validation_1-rmse:1.32866
# [22]	validation_0-rmse:1.11407	validation_1-rmse:1.33014
# [23]	validation_0-rmse:1.06619	validation_1-rmse:1.33707
# [24]	validation_0-rmse:1.04035	validation_1-rmse:1.36929
# [25]	validation_0-rmse:1.01345	validation_1-rmse:1.37068
# [26]	validation_0-rmse:1.00022	validation_1-rmse:1.37580
# [27]	validation_0-rmse:0.97032	validation_1-rmse:1.39286
# [28]	validation_0-rmse:0.95590	validation_1-rmse:1.38987
# [29]	validation_0-rmse:0.94114	validation_1-rmse:1.40886
# [30]	validation_0-rmse:0.93247	validation_1-rmse:1.41966

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 37.733, median: 37.0,
#  pred. interval (P(0.025)-P(0.975)): 22.725-51.0,
#  conf. interval (p-value=0.95): 33.945-40.928
# ***
# Aggregate bias statistic:
#  mean: -2.761, median: -2.017,
#  pred. interval (P(0.025)-P(0.975)): -12.358-4.697,
#  conf. interval (p-value=0.95): -4.634--0.442
# ***
# Aggregate RMSE statistic:
#  mean: 1.146, median: 1.136, pred. interval (P(0.025)-P(0.975)): 0.877-1.462,
#  conf. interval (p-value=0.95): 1.071-1.211
# ***
# Aggregate MSE statistic:
#  mean: 1.337, median: 1.289, pred. interval (P(0.025)-P(0.975)): 0.769-2.138,
#  conf. interval (p-value=0.95): 1.153-1.473
# ***
# Aggregate R^2 statistic:
#  mean: 0.477, median: 0.503, pred. interval (P(0.025)-P(0.975)): 0.025-0.701,
#  conf. interval (p-value=0.95): 0.439-0.559
# ***
# Aggregate bias(%) statistic:
#  mean: -0.375, median: -2.017, pred. interval (P(0.025)-P(0.975)): -1.678-0.716,
#  conf. interval (p-value=0.95): -0.635--0.062
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.164, median: 0.161, pred. interval (P(0.025)-P(0.975)): 0.12-0.221,
#  conf. interval (p-value=0.95): 0.151-0.173
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:6.06631
# [1]	validation_0-rmse:5.44579
# [2]	validation_0-rmse:4.92250
# [3]	validation_0-rmse:4.47223
# [4]	validation_0-rmse:4.10168
# [5]	validation_0-rmse:3.72056
# [6]	validation_0-rmse:3.40601
# [7]	validation_0-rmse:3.10350
# [8]	validation_0-rmse:2.83188
# [9]	validation_0-rmse:2.59746
# [10]	validation_0-rmse:2.36224
# [11]	validation_0-rmse:2.18085
# [12]	validation_0-rmse:2.03136
# [13]	validation_0-rmse:1.90287
# [14]	validation_0-rmse:1.79152
# [15]	validation_0-rmse:1.70180
# [16]	validation_0-rmse:1.59360
# [17]	validation_0-rmse:1.49603
# [18]	validation_0-rmse:1.40543
# [19]	validation_0-rmse:1.34384
# [20]	validation_0-rmse:1.30610
# [21]	validation_0-rmse:1.26485
# [22]	validation_0-rmse:1.22907
# [23]	validation_0-rmse:1.18601
# [24]	validation_0-rmse:1.16651
# [25]	validation_0-rmse:1.13760
# [26]	validation_0-rmse:1.11655
# [27]	validation_0-rmse:1.09096
# [28]	validation_0-rmse:1.08576
# [29]	validation_0-rmse:1.07717
# [30]	validation_0-rmse:1.05691
# [31]	validation_0-rmse:1.04107
# [32]	validation_0-rmse:1.03326
# [33]	validation_0-rmse:1.01779
# [34]	validation_0-rmse:1.00907
# [35]	validation_0-rmse:1.00462
# [36]	validation_0-rmse:1.00675
# [37]	validation_0-rmse:1.00080
# [38]	validation_0-rmse:0.99244
# [39]	validation_0-rmse:0.99188
# [40]	validation_0-rmse:0.98388
# [41]	validation_0-rmse:0.98297
# [42]	validation_0-rmse:0.97782
# [43]	validation_0-rmse:0.97483
# [44]	validation_0-rmse:0.97226
# [45]	validation_0-rmse:0.97051
# [46]	validation_0-rmse:0.96554
# [47]	validation_0-rmse:0.96375
# [48]	validation_0-rmse:0.96248
# [49]	validation_0-rmse:0.95972
# [50]	validation_0-rmse:0.95940
# [51]	validation_0-rmse:0.95659

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 51

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  0.14
# RMSE: 1.0
# Relative RMSE(%):  0.136
# MSE: 0.9
# R square: 66.0%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 2.734
# a1: 0.614
# R^2: 0.664
# Uncertainty
# a0: 2.73+/-0.31
# a1: 0.61+/-0.04

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("./../03_output_data/XGBoost_models/UAV_ln_Cs_XGB_model_AERD_2024.json")
# Save to text format
f_xgb_model.save_model("./../03_output_data/XGBoost_models/UAV_ln_Cs_XGB_model_AERD_2024.txt")
