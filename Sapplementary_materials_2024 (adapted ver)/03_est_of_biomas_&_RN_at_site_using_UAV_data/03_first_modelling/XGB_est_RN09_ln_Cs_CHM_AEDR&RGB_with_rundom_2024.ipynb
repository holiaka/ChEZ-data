# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN'])

# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           2260           1210     -0.731      2.576
# 1       8.189       9.622           2700           1180      0.585      2.915
# 2       8.380       9.589           2500           1400      0.779      2.882
# 3       8.137       9.449           2500           1090      0.517      2.724
# 4       7.696       9.401           2400            720      0.224      2.826
#
#    AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  \
# 0       2.33    0.445070     13  35.145074   360.273487    0.488754
# 1       2.47   12.465903     24  36.135511   323.958625    0.501683
# 2       2.44   13.028298     18  35.938764   299.438354    0.540056
# 3       2.55    2.128231     15  35.908361   319.773395    0.480991
# 4       2.14   12.171553      8  38.062522   353.104284    0.505257
#
#    corr_r_MIN
# 0    0.072792
# 1    0.098347
# 2    0.187811
# 3    0.020686
# 4    0.106549

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   mf_chm_MIN     103 non-null    float64
#  8   r_MIN          103 non-null    int64
#  9   b_STD          103 non-null    float64
#  10  contr_r_STD    103 non-null    float64
#  11  corr_r_Q25     103 non-null    float64
#  12  corr_r_MIN     103 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 10.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3440.194175    1242.902913   -0.252563
# std       1.64946    1.472424    6087.580089    2037.684800    1.104610
# min       3.52600    6.075000     260.000000      50.000000   -3.033000
# 25%       6.31900    7.664000     635.000000     200.000000   -0.727500
# 50%       6.95700    8.472000    1150.000000     400.000000   -0.025000
# 75%       7.91350    9.421000    2525.000000    1400.000000    0.516500
# max      11.36700   13.864000   35200.000000   10500.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean  mf_chm_MIN       r_MIN       b_STD  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     2.464709    3.570291    3.368496   11.378641   35.164575
# std      0.904675    6.089170    4.845054    9.139568    5.338700
# min      0.391000    0.480000   -0.018586    2.000000   20.570709
# 25%      1.803000    0.710000    0.482279    5.000000   31.746440
# 50%      2.603000    1.290000    0.642883    8.000000   36.135511
# 75%      3.159000    2.960000    3.921804   15.000000   39.139044
# max      4.659000   36.590000   17.862923   56.000000   45.825416
#
#        contr_r_STD  corr_r_Q25  corr_r_MIN
# count   103.000000  103.000000  103.000000
# mean    327.115078    0.393571    0.073579
# std     167.617957    0.151801    0.056017
# min       0.091058    0.033797   -0.062450
# 25%     283.887328    0.407228    0.027204
# 50%     353.034542    0.449670    0.063714
# 75%     448.017711    0.476635    0.110983
# max     652.546648    0.555648    0.241284

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN', 'AEDR_mean'])
y = pd.DataFrame(select, columns= ['ln_Cs_wood'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): Yes
# Selected "Yes"!!! A new column with random values was created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  corr_r_MIN  \
# 0    0.445070     13  35.145074   360.273487    0.488754    0.072792
# 1   12.465903     24  36.135511   323.958625    0.501683    0.098347
# 2   13.028298     18  35.938764   299.438354    0.540056    0.187811
# 3    2.128231     15  35.908361   319.773395    0.480991    0.020686
# 4   12.171553      8  38.062522   353.104284    0.505257    0.106549
#
#    AEDR_mean    Random1    Random2    Random3    Random4    Random5
# 0       2.33   7.623316   7.690996   8.927259  12.091429  11.289067
# 1       2.47  10.243934  12.939246  13.123528   9.896519  12.621670
# 2       2.44  12.485551  10.515759   8.927337  13.470889   9.245945
# 3       2.55   9.952881   6.060190   7.569206  13.891008   9.210918
# 4       2.14   8.974691  15.316857   9.281380   8.767960   9.140887

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Cs_wood
# 0       6.824
# 1       8.189
# 2       8.380
# 3       8.137
# 4       7.696

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.6371187991239792, 0.3695237454836533, 0.4250159061827762]
#     Mean: 0.477
#     Std: 0.115
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.29429042 1.18989939 1.17922543]
#     Mean: 1.221
#     Std: 0.052
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.6878994419642858, 0.9521854332194609, 1.0941228612450993]
#     Mean: 0.911
#     Std: 0.168
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=30, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Model with rank: 1
# Mean validation score: 0.160 (std: 0.453)
# Parameters: {'colsample_bytree': 0.5079703169361481, 'gamma': 0.44168389623078863, 'learning_rate': 0.19421327220993195, 'max_depth': 4, 'n_estimators': 53, 'subsample': 0.45697795125998897}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.18843627, 0.37459068, 0.56112938, 0.27613735, 0.75226264,
#        0.79208198, 0.63236785, 0.19402275, 0.58852148, 0.22814679,
#        0.42424221, 0.39903312, 0.56985168, 0.36411195, 0.85995283,
#        0.48802667, 0.29703927, 0.512713  , 0.40667515, 0.3788609 ,
#        0.33947296, 0.78877473, 0.59754362, 0.29331031, 0.17137599,
#        0.21468911, 0.35599256, 0.34659448, 0.36562228, 0.14714112]), 'std_fit_time': array([0.02841777, 0.17823136, 0.17283374, 0.04187855, 0.20207809,
#        0.10876024, 0.1459507 , 0.0519438 , 0.21428179, 0.04923709,
#        0.08088086, 0.15829031, 0.17995669, 0.0814398 , 0.53211819,
#        0.02238902, 0.0249013 , 0.0290808 , 0.02387748, 0.01084387,
#        0.02292539, 0.31163146, 0.39680368, 0.15510868, 0.01442579,
#        0.01206835, 0.03762944, 0.02265385, 0.01477861, 0.00871936]), 'mean_score_time': array([0.00628376, 0.00653172, 0.00772061, 0.00680594, 0.00781617,
#        0.00835299, 0.00707183, 0.00738988, 0.00658884, 0.00763979,
#        0.00604019, 0.00761561, 0.00739193, 0.00889878, 0.00616202,
#        0.00732112, 0.00685477, 0.00657477, 0.00720687, 0.00601692,
#        0.00840526, 0.00631595, 0.00607214, 0.00632782, 0.00596013,
#        0.00606976, 0.00598998, 0.00647893, 0.00598092, 0.00610666]), 'std_score_time': array([3.09308611e-04, 9.87464351e-04, 3.16112153e-03, 1.11687897e-03,
#        2.74328442e-03, 2.41511143e-03, 1.81559771e-03, 1.65086416e-03,
#        9.47509373e-04, 2.38188742e-03, 9.16765290e-05, 3.11515332e-03,
#        2.86824401e-03, 5.27693336e-03, 1.63591050e-04, 2.25003488e-03,
#        1.33235234e-03, 1.06324491e-03, 1.90956130e-03, 9.62884536e-05,
#        4.54376461e-03, 3.23015453e-04, 1.45684217e-04, 7.42932314e-04,
#        9.10221560e-05, 2.79731454e-04, 9.44156117e-05, 1.03756764e-03,
#        9.07048311e-05, 6.22758091e-05]), 'param_colsample_bytree': masked_array(data=[0.7911852883644379, 0.8079824805062341,
#                    0.1038858424902076, 0.7646421313482221,
#                    0.26570452000814043, 0.31128039658381285,
#                    0.30675763591511396, 0.8608018171721371,
#                    0.3094230492861799, 0.8693248637337152,
#                    0.6822900972629634, 0.6853731028018291,
#                    0.28427904622531613, 0.44735382113366806,
#                    0.3586341801583618, 0.7352446357876153,
#                    0.323410926127667, 0.9040335642133414,
#                    0.6978587394560751, 0.24457597613965631,
#                    0.9441034108129965, 0.08393290869613401,
#                    0.8297973743045037, 0.5991991226164943,
#                    0.17785390047090321, 0.7745003669714501,
#                    0.2953544151123428, 0.45088203804997484,
#                    0.6834157822582287, 0.5079703169361481],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.18439352375190654, 0.49317370050413584,
#                    0.04804443377102674, 0.40624264119156833,
#                    0.04757235825216555, 0.267159177586101,
#                    0.07377666285462703, 0.3016459257609474,
#                    0.10483644253233682, 0.1948469659453378,
#                    0.27080597364700243, 0.4312567707760328,
#                    0.2567044728225142, 0.20283201223744074,
#                    0.008744583493517477, 0.06841028504110414,
#                    0.068557080378995, 0.1749539179984806,
#                    0.45338411014656677, 0.36441183970718277,
#                    0.09802341639684636, 0.32087529772479917,
#                    0.10037156240070111, 0.18302869519882375,
#                    0.3843478018404377, 0.05090250741458485,
#                    0.28895677763390776, 0.44429426183104975,
#                    0.3952795162182067, 0.44168389623078863],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.0568940923354626, 0.1332637731618169,
#                    0.2600436186762608, 0.1542739135751138,
#                    0.2689317025991821, 0.1436943862482442,
#                    0.044502439985676205, 0.10251209795553909,
#                    0.14621356202023789, 0.09310400722475769,
#                    0.15193654598497783, 0.2254700373019273,
#                    0.2157814559972312, 0.22125376709341102,
#                    0.06487110551233302, 0.30134380598018173,
#                    0.033757870208508116, 0.08897491648767426,
#                    0.07182545917281032, 0.01456829330503481,
#                    0.1977641075853291, 0.30384239918624484,
#                    0.11261696213393785, 0.07071304894245412,
#                    0.17210497581193815, 0.11227941469160624,
#                    0.21730529060227316, 0.02504918280401513,
#                    0.18920623320400362, 0.19421327220993195],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[2, 3, 3, 3, 2, 2, 3, 2, 4, 4, 2, 3, 4, 4, 4, 3, 4, 3,
#                    3, 3, 4, 4, 2, 3, 4, 3, 4, 2, 3, 4],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[69, 97, 190, 97, 166, 198, 153, 54, 153, 67, 116, 102,
#                    142, 80, 172, 191, 114, 198, 162, 154, 125, 177, 144,
#                    78, 62, 80, 132, 140, 146, 53],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.9919237797759359, 0.3989074357489416,
#                    0.4194454556780749, 0.6153172975467732,
#                    0.5027032626540543, 0.3577885086046945,
#                    0.9025118443269249, 0.8585633714930685,
#                    0.648630815890755, 0.6855098686838099,
#                    0.5599716781875292, 0.8111822320483881,
#                    0.7738265747449969, 0.9548675435149281,
#                    0.600239582270852, 0.7729526914560843,
#                    0.9522644815218266, 0.6050211038287243,
#                    0.8111602475498694, 0.9119359853344142,
#                    0.6987619013456647, 0.32937026680279646,
#                    0.5256995224722718, 0.6440448342907956,
#                    0.3714190533781825, 0.6790056437263925,
#                    0.6528384908626685, 0.5930130955475161,
#                    0.34050204281640584, 0.45697795125998897],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.7911852883644379, 'gamma': 0.18439352375190654, 'learning_rate': 0.0568940923354626, 'max_depth': 2, 'n_estimators': 69, 'subsample': 0.9919237797759359}, {'colsample_bytree': 0.8079824805062341, 'gamma': 0.49317370050413584, 'learning_rate': 0.1332637731618169, 'max_depth': 3, 'n_estimators': 97, 'subsample': 0.3989074357489416}, {'colsample_bytree': 0.1038858424902076, 'gamma': 0.04804443377102674, 'learning_rate': 0.2600436186762608, 'max_depth': 3, 'n_estimators': 190, 'subsample': 0.4194454556780749}, {'colsample_bytree': 0.7646421313482221, 'gamma': 0.40624264119156833, 'learning_rate': 0.1542739135751138, 'max_depth': 3, 'n_estimators': 97, 'subsample': 0.6153172975467732}, {'colsample_bytree': 0.26570452000814043, 'gamma': 0.04757235825216555, 'learning_rate': 0.2689317025991821, 'max_depth': 2, 'n_estimators': 166, 'subsample': 0.5027032626540543}, {'colsample_bytree': 0.31128039658381285, 'gamma': 0.267159177586101, 'learning_rate': 0.1436943862482442, 'max_depth': 2, 'n_estimators': 198, 'subsample': 0.3577885086046945}, {'colsample_bytree': 0.30675763591511396, 'gamma': 0.07377666285462703, 'learning_rate': 0.044502439985676205, 'max_depth': 3, 'n_estimators': 153, 'subsample': 0.9025118443269249}, {'colsample_bytree': 0.8608018171721371, 'gamma': 0.3016459257609474, 'learning_rate': 0.10251209795553909, 'max_depth': 2, 'n_estimators': 54, 'subsample': 0.8585633714930685}, {'colsample_bytree': 0.3094230492861799, 'gamma': 0.10483644253233682, 'learning_rate': 0.14621356202023789, 'max_depth': 4, 'n_estimators': 153, 'subsample': 0.648630815890755}, {'colsample_bytree': 0.8693248637337152, 'gamma': 0.1948469659453378, 'learning_rate': 0.09310400722475769, 'max_depth': 4, 'n_estimators': 67, 'subsample': 0.6855098686838099}, {'colsample_bytree': 0.6822900972629634, 'gamma': 0.27080597364700243, 'learning_rate': 0.15193654598497783, 'max_depth': 2, 'n_estimators': 116, 'subsample': 0.5599716781875292}, {'colsample_bytree': 0.6853731028018291, 'gamma': 0.4312567707760328, 'learning_rate': 0.2254700373019273, 'max_depth': 3, 'n_estimators': 102, 'subsample': 0.8111822320483881}, {'colsample_bytree': 0.28427904622531613, 'gamma': 0.2567044728225142, 'learning_rate': 0.2157814559972312, 'max_depth': 4, 'n_estimators': 142, 'subsample': 0.7738265747449969}, {'colsample_bytree': 0.44735382113366806, 'gamma': 0.20283201223744074, 'learning_rate': 0.22125376709341102, 'max_depth': 4, 'n_estimators': 80, 'subsample': 0.9548675435149281}, {'colsample_bytree': 0.3586341801583618, 'gamma': 0.008744583493517477, 'learning_rate': 0.06487110551233302, 'max_depth': 4, 'n_estimators': 172, 'subsample': 0.600239582270852}, {'colsample_bytree': 0.7352446357876153, 'gamma': 0.06841028504110414, 'learning_rate': 0.30134380598018173, 'max_depth': 3, 'n_estimators': 191, 'subsample': 0.7729526914560843}, {'colsample_bytree': 0.323410926127667, 'gamma': 0.068557080378995, 'learning_rate': 0.033757870208508116, 'max_depth': 4, 'n_estimators': 114, 'subsample': 0.9522644815218266}, {'colsample_bytree': 0.9040335642133414, 'gamma': 0.1749539179984806, 'learning_rate': 0.08897491648767426, 'max_depth': 3, 'n_estimators': 198, 'subsample': 0.6050211038287243}, {'colsample_bytree': 0.6978587394560751, 'gamma': 0.45338411014656677, 'learning_rate': 0.07182545917281032, 'max_depth': 3, 'n_estimators': 162, 'subsample': 0.8111602475498694}, {'colsample_bytree': 0.24457597613965631, 'gamma': 0.36441183970718277, 'learning_rate': 0.01456829330503481, 'max_depth': 3, 'n_estimators': 154, 'subsample': 0.9119359853344142}, {'colsample_bytree': 0.9441034108129965, 'gamma': 0.09802341639684636, 'learning_rate': 0.1977641075853291, 'max_depth': 4, 'n_estimators': 125, 'subsample': 0.6987619013456647}, {'colsample_bytree': 0.08393290869613401, 'gamma': 0.32087529772479917, 'learning_rate': 0.30384239918624484, 'max_depth': 4, 'n_estimators': 177, 'subsample': 0.32937026680279646}, {'colsample_bytree ...
#        -0.6320538 , -1.6827284 , -1.87901039, -1.09783819, -1.47775505,
#        -1.67656391, -1.54441818, -0.8936813 , -0.92122362, -0.63221889,
#        -2.28171111, -2.28245213, -1.08486683, -1.20822754, -5.14718959,
#        -2.037809  , -3.36522772, -1.39625677, -1.26257285, -1.83036155,
#        -1.29395933, -0.96514819, -1.98255036, -0.91406177, -0.49028741]), 'split1_test_score': array([ 0.3420627 ,  0.08641806, -0.0648813 ,  0.01587396,  0.25068325,
#         0.17823771,  0.28196143,  0.25112361,  0.29184173,  0.25821334,
#         0.22735314, -0.16806236,  0.31301862,  0.17037752,  0.36525575,
#        -0.01485937,  0.34197402,  0.21214776,  0.31327679,  0.13275272,
#         0.14457078, -0.24482   ,  0.19594942,  0.27492692,  0.22838182,
#         0.41703067,  0.21803736,  0.35823673,  0.18402643,  0.46624576]), 'split2_test_score': array([-0.23909288, -0.2964089 , -0.60292908, -0.41121323, -0.19902845,
#        -0.09515372, -0.12016829, -0.24812485, -0.2398144 , -0.37025257,
#        -0.2367238 , -0.36259908, -0.12026443, -0.20661467, -0.08121013,
#        -0.39482356, -0.07469535, -0.40012157, -0.24785425, -0.0780692 ,
#        -0.61379208, -0.74104332, -0.4214122 , -0.25776097, -0.35700032,
#        -0.31240852, -0.23892267, -0.1407844 , -0.41617587, -0.27425392]), 'split3_test_score': array([ 0.28827113,  0.18751655,  0.36165118,  0.31399848,  0.15403593,
#         0.49082136,  0.25765428,  0.42276434,  0.28924771,  0.28214939,
#         0.40436535,  0.31373729,  0.04473816,  0.2647401 ,  0.27728938,
#         0.43210533, -0.15498226,  0.37167818,  0.47552424, -1.38313414,
#         0.27636224,  0.33248345,  0.35026531,  0.24335868,  0.27151409,
#         0.24790959,  0.17181539, -0.16089369, -0.11940918,  0.45587043]), 'split4_test_score': array([0.63945004, 0.67012936, 0.64740164, 0.58881794, 0.61552925,
#        0.65249087, 0.62274658, 0.61305316, 0.63571229, 0.63547092,
#        0.62585935, 0.62109289, 0.57314886, 0.59097002, 0.63198106,
#        0.64982214, 0.60220351, 0.63692752, 0.65801911, 0.44731349,
#        0.63739823, 0.56631545, 0.64272613, 0.65537223, 0.59369898,
#        0.62505986, 0.58339948, 0.61203254, 0.55543123, 0.64440501]), 'mean_test_score': array([-0.2029974 , -0.07160869, -0.25418927, -0.10562842,  0.08523761,
#         0.11886848, -0.12810688, -0.16803883, -0.02417017, -0.1344348 ,
#        -0.13114197, -0.22804989, -0.01660802, -0.02035013,  0.11221943,
#        -0.32189331, -0.31359044, -0.05284699, -0.00185233, -1.20566534,
#        -0.31865396, -0.69045843, -0.12574562, -0.0693352 , -0.2187534 ,
#        -0.06327355, -0.04616373, -0.26279184, -0.14203783,  0.16039597]), 'std_test_score': array([0.96383895, 0.55952705, 0.79921778, 0.57120406, 0.35349137,
#        0.45526174, 0.81211572, 0.90207402, 0.60544275, 0.74573307,
#        0.82314207, 0.74419141, 0.49804266, 0.5172298 , 0.43658471,
#        1.04433896, 1.02245656, 0.61836838, 0.67505306, 2.06699219,
#        0.95134198, 1.41290013, 0.72418785, 0.66344783, 0.8621791 ,
#        0.68963551, 0.52827178, 0.90926702, 0.50288481, 0.45330418]), 'rank_test_score': array([21, 13, 24, 14,  4,  2, 16, 20,  8, 18, 17, 23,  6,  7,  3, 28, 26,
#        10,  5, 30, 27, 29, 15, 12, 22, 11,  9, 25, 19,  1], dtype=int32), 'split0_train_score': array([0.89072413, 0.97072774, 0.99630785, 0.98012404, 0.99660461,
#        0.9766277 , 0.97430975, 0.93341497, 0.99435133, 0.98148403,
#        0.98196413, 0.97947005, 0.98922951, 0.99042498, 0.99706371,
#        0.99758145, 0.94359423, 0.9914444 , 0.97726508, 0.60351614,
#        0.99618979, 0.98115527, 0.98362648, 0.95886904, 0.95326725,
#        0.98806553, 0.98756   , 0.83379738, 0.97967174, 0.97075135]), 'split1_train_score': array([0.88456994, 0.96590718, 0.99611685, 0.97996766, 0.99630625,
#        0.97600734, 0.97156038, 0.92455735, 0.99391256, 0.9797941 ,
#        0.98007125, 0.98106678, 0.98699289, 0.98935902, 0.99756604,
#        0.99687761, 0.93579373, 0.99115551, 0.97400814, 0.54638221,
#        0.99581002, 0.97733653, 0.98138143, 0.9562534 , 0.94823892,
#        0.98754701, 0.98643393, 0.81745677, 0.97582266, 0.96916675]), 'split2_train_score': array([0.91060502, 0.96928724, 0.99648172, 0.97835619, 0.99708931,
#        0.97847072, 0.97846277, 0.94919   , 0.99436904, 0.98262524,
#        0.98065725, 0.98100615, 0.98755416, 0.98927843, 0.99791311,
#        0.99709949, 0.9468848 , 0.99169934, 0.97430098, 0.5661535 ,
#        0.99584187, 0.97956587, 0.98599542, 0.96768834, 0.95996504,
#        0.99117328, 0.98583178, 0.84865506, 0.97860682, 0.96779581]), 'split3_train_score': array([0.83104199, 0.95551544, 0.99479465, 0.97053938, 0.99585485,
#        0.97062672, 0.95481729, 0.88441714, 0.99186149, 0.97100757,
#        0.97308968, 0.97449914, 0.98411744, 0.98631245, 0.99588709,
#        0.99640577, 0.90420243, 0.98792755, 0.96313454, 0.41409381,
#        0.99466784, 0.97300549, 0.97659982, 0.93225565, 0.94787231,
#        0.98058502, 0.98268119, 0.7349151 , 0.97018412, 0.95609999]), 'split4_train_score': array([0.86833984, 0.95907004, 0.99509019, 0.97295379, 0.99533176,
#        0.97146494, 0.97170369, 0.92522573, 0.99246266, 0.97858124,
#        0.97531151, 0.97518955, 0.98468567, 0.98753071, 0.99616552,
#        0.99593608, 0.93333215, 0.98746327, 0.96826654, 0.45439653,
#        0.99371219, 0.9731284 , 0.98068109, 0.95243526, 0.94110461,
#        0.98838392, 0.98161356, 0.79231357, 0.97258999, 0.95683676]), 'mean_train_score': array([0.87705618, 0.96410153, 0.99575825, 0.97638821, 0.99623736,
#        0.97463948, 0.97017078, 0.92336104, 0.99339141, 0.97869844,
#        0.97821876, 0.97824634, 0.98651593, 0.98858112, 0.99691909,
#        0.99678008, 0.93276147, 0.98993801, 0.97139505, 0.51690844,
#        0.99524434, 0.97683831, 0.98165685, 0.95350034, 0.95008963,
#        0.98715095, 0.98482409, 0.80542758, 0.97537507, 0.96413013]), 'std_train_score': array([0.0266911 , 0.0058838 , 0.00068248, 0.00391525, 0.00060529,
#        0.00305557, 0.0080734 , 0.02139978, 0.0010346 , 0.00408761,
#        0.00341072, 0.00284445, 0.00188529, 0.0014657 , 0.00078236,
#        0.00056678, 0.01511262, 0.001845  , 0.00505477, 0.07109607,
#        0.00092203, 0.00330992, 0.0031402 , 0.01174881, 0.00627205,
#        0.0035158 , 0.00227999, 0.03990526, 0.00357235, 0.00632964])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.5079703169361481
# Gamma: 0.44168389623078863
# Learning_rate: 0.19421327220993195
# Max_depth: 4
# N_estimators: 53
# Subsample: 0.45697795125998897

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:5.56723	validation_1-rmse:5.76121
# [1]	validation_0-rmse:4.63603	validation_1-rmse:4.95047
# [2]	validation_0-rmse:3.80972	validation_1-rmse:4.17437
# [3]	validation_0-rmse:3.13893	validation_1-rmse:3.52691
# [4]	validation_0-rmse:2.67457	validation_1-rmse:3.07254
# [5]	validation_0-rmse:2.26889	validation_1-rmse:2.68027
# [6]	validation_0-rmse:1.95708	validation_1-rmse:2.38050
# [7]	validation_0-rmse:1.67255	validation_1-rmse:2.08408
# [8]	validation_0-rmse:1.43740	validation_1-rmse:1.82514
# [9]	validation_0-rmse:1.26842	validation_1-rmse:1.63056
# [10]	validation_0-rmse:1.11721	validation_1-rmse:1.50436
# [11]	validation_0-rmse:0.98730	validation_1-rmse:1.42734
# [12]	validation_0-rmse:0.90072	validation_1-rmse:1.34936
# [13]	validation_0-rmse:0.82914	validation_1-rmse:1.28090
# [14]	validation_0-rmse:0.77979	validation_1-rmse:1.24121
# [15]	validation_0-rmse:0.71766	validation_1-rmse:1.20762
# [16]	validation_0-rmse:0.67535	validation_1-rmse:1.20741
# [17]	validation_0-rmse:0.65377	validation_1-rmse:1.22065
# [18]	validation_0-rmse:0.62410	validation_1-rmse:1.22830
# [19]	validation_0-rmse:0.59184	validation_1-rmse:1.18928
# [20]	validation_0-rmse:0.55472	validation_1-rmse:1.18594
# [21]	validation_0-rmse:0.53527	validation_1-rmse:1.16077
# [22]	validation_0-rmse:0.51958	validation_1-rmse:1.16614
# [23]	validation_0-rmse:0.50362	validation_1-rmse:1.15040
# [24]	validation_0-rmse:0.49431	validation_1-rmse:1.15217
# [25]	validation_0-rmse:0.47848	validation_1-rmse:1.14152
# [26]	validation_0-rmse:0.47275	validation_1-rmse:1.12342
# [27]	validation_0-rmse:0.46285	validation_1-rmse:1.14646
# [28]	validation_0-rmse:0.45337	validation_1-rmse:1.14495
# [29]	validation_0-rmse:0.44903	validation_1-rmse:1.14263
# [30]	validation_0-rmse:0.43515	validation_1-rmse:1.13990
# [31]	validation_0-rmse:0.40768	validation_1-rmse:1.15866
# [32]	validation_0-rmse:0.39663	validation_1-rmse:1.15495
# [33]	validation_0-rmse:0.39009	validation_1-rmse:1.15829
# [34]	validation_0-rmse:0.37719	validation_1-rmse:1.16503
# [35]	validation_0-rmse:0.37756	validation_1-rmse:1.16215
# [36]	validation_0-rmse:0.36904	validation_1-rmse:1.16514
# [37]	validation_0-rmse:0.36308	validation_1-rmse:1.16912
# [38]	validation_0-rmse:0.35467	validation_1-rmse:1.16026
# [39]	validation_0-rmse:0.35119	validation_1-rmse:1.15805
# [40]	validation_0-rmse:0.34032	validation_1-rmse:1.14237
# [41]	validation_0-rmse:0.33262	validation_1-rmse:1.14980
# [42]	validation_0-rmse:0.33361	validation_1-rmse:1.16597
# [43]	validation_0-rmse:0.32801	validation_1-rmse:1.16682
# [44]	validation_0-rmse:0.32579	validation_1-rmse:1.14477
# [45]	validation_0-rmse:0.32197	validation_1-rmse:1.13987
# [46]	validation_0-rmse:0.32196	validation_1-rmse:1.14025
# [0]	validation_0-rmse:5.62111	validation_1-rmse:5.57081
# [1]	validation_0-rmse:4.63909	validation_1-rmse:4.59813
# [2]	validation_0-rmse:3.83937	validation_1-rmse:3.75537
# [3]	validation_0-rmse:3.20625	validation_1-rmse:3.17885
# [4]	validation_0-rmse:2.74718	validation_1-rmse:2.69522
# [5]	validation_0-rmse:2.30656	validation_1-rmse:2.28051
# [6]	validation_0-rmse:1.89285	validation_1-rmse:1.83535
# [7]	validation_0-rmse:1.60893	validation_1-rmse:1.58203
# [8]	validation_0-rmse:1.41459	validation_1-rmse:1.47719
# [9]	validation_0-rmse:1.22120	validation_1-rmse:1.33087
# [10]	validation_0-rmse:1.10034	validation_1-rmse:1.20097
# [11]	validation_0-rmse:0.98733	validation_1-rmse:1.05797
# [12]	validation_0-rmse:0.88352	validation_1-rmse:0.99062
# [13]	validation_0-rmse:0.78968	validation_1-rmse:0.94656
# [14]	validation_0-rmse:0.74806	validation_1-rmse:0.89691
# [15]	validation_0-rmse:0.70414	validation_1-rmse:0.88436
# [16]	validation_0-rmse:0.66102	validation_1-rmse:0.83023
# [17]	validation_0-rmse:0.61015	validation_1-rmse:0.83285
# [18]	validation_0-rmse:0.57884	validation_1-rmse:0.81941
# [19]	validation_0-rmse:0.53958	validation_1-rmse:0.81625
# [20]	validation_0-rmse:0.50995	validation_1-rmse:0.79861
# [21]	validation_0-rmse:0.50059	validation_1-rmse:0.77620
# [22]	validation_0-rmse:0.49539	validation_1-rmse:0.75932
# [23]	validation_0-rmse:0.48729	validation_1-rmse:0.74642
# [24]	validation_0-rmse:0.45418	validation_1-rmse:0.75450
# [25]	validation_0-rmse:0.43367	validation_1-rmse:0.75739
# [26]	validation_0-rmse:0.42009	validation_1-rmse:0.75737
# [27]	validation_0-rmse:0.41041	validation_1-rmse:0.75597
# [28]	validation_0-rmse:0.39975	validation_1-rmse:0.73994
# [29]	validation_0-rmse:0.38637	validation_1-rmse:0.73394
# [30]	validation_0-rmse:0.36937	validation_1-rmse:0.72295
# [31]	validation_0-rmse:0.36491	validation_1-rmse:0.71856
# [32]	validation_0-rmse:0.36209	validation_1-rmse:0.71784
# [33]	validation_0-rmse:0.35990	validation_1-rmse:0.72723
# [34]	validation_0-rmse:0.35472	validation_1-rmse:0.72847
# [35]	validation_0-rmse:0.35418	validation_1-rmse:0.73875
# [36]	validation_0-rmse:0.35318	validation_1-rmse:0.73125
# [37]	validation_0-rmse:0.33953	validation_1-rmse:0.72479
# [38]	validation_0-rmse:0.33829	validation_1-rmse:0.72859
# [39]	validation_0-rmse:0.33848	validation_1-rmse:0.72906
# [40]	validation_0-rmse:0.33221	validation_1-rmse:0.72161
# [41]	validation_0-rmse:0.32931	validation_1-rmse:0.71418
# [42]	validation_0-rmse:0.32344	validation_1-rmse:0.72023
# [43]	validation_0-rmse:0.32346	validation_1-rmse:0.72031
# [44]	validation_0-rmse:0.32387	validation_1-rmse:0.72164
# [45]	validation_0-rmse:0.31374	validation_1-rmse:0.73722
# [46]	validation_0-rmse:0.30999	validation_1-rmse:0.73525
# [47]	validation_0-rmse:0.31077	validation_1-rmse:0.72241
# [48]	validation_0-rmse:0.30152	validation_1-rmse:0.72380
# [49]	validation_0-rmse:0.29517	validation_1-rmse:0.72467
# [50]	validation_0-rmse:0.29534	validation_1-rmse:0.72574
# [51]	validation_0-rmse:0.28531	validation_1-rmse:0.72933
# [52]	validation_0-rmse:0.28537	validation_1-rmse:0.72966
# [0]	validation_0-rmse:5.57318	validation_1-rmse:5.00016
# [1]	validation_0-rmse:4.55601	validation_1-rmse:4.06400
# [2]	validation_0-rmse:3.82118	validation_1-rmse:3.34495
# [3]	validation_0-rmse:3.17162	validation_1-rmse:2.74970
# [4]	validation_0-rmse:2.63419	validation_1-rmse:2.30550
# [5]	validation_0-rmse:2.19824	validation_1-rmse:2.02925
# [6]	validation_0-rmse:1.88319	validation_1-rmse:1.76537
# [7]	validation_0-rmse:1.58371	validation_1-rmse:1.57197
# [8]	validation_0-rmse:1.35349	validation_1-rmse:1.45709
# [9]	validation_0-rmse:1.15315	validation_1-rmse:1.32898
# [10]	validation_0-rmse:1.03134	validation_1-rmse:1.30508
# [11]	validation_0-rmse:0.92800	validation_1-rmse:1.28976
# [12]	validation_0-rmse:0.84070	validation_1-rmse:1.25421
# [13]	validation_0-rmse:0.76573	validation_1-rmse:1.24349
# [14]	validation_0-rmse:0.70141	validation_1-rmse:1.22559
# [15]	validation_0-rmse:0.63827	validation_1-rmse:1.20645
# [16]	validation_0-rmse:0.59041	validation_1-rmse:1.19309
# [17]	validation_0-rmse:0.54948	validation_1-rmse:1.19648
# [18]	validation_0-rmse:0.51830	validation_1-rmse:1.19783
# [19]	validation_0-rmse:0.49740	validation_1-rmse:1.20535
# [20]	validation_0-rmse:0.47758	validation_1-rmse:1.20644
# [21]	validation_0-rmse:0.46837	validation_1-rmse:1.21287
# [22]	validation_0-rmse:0.45404	validation_1-rmse:1.22599
# [23]	validation_0-rmse:0.43752	validation_1-rmse:1.23051
# [24]	validation_0-rmse:0.41991	validation_1-rmse:1.23582
# [25]	validation_0-rmse:0.40994	validation_1-rmse:1.22815
# [26]	validation_0-rmse:0.40430	validation_1-rmse:1.22985
# [27]	validation_0-rmse:0.40366	validation_1-rmse:1.21871
# [28]	validation_0-rmse:0.39082	validation_1-rmse:1.21947
# [29]	validation_0-rmse:0.37435	validation_1-rmse:1.21181
# [30]	validation_0-rmse:0.36809	validation_1-rmse:1.20677
# [31]	validation_0-rmse:0.35947	validation_1-rmse:1.19864
# [32]	validation_0-rmse:0.35340	validation_1-rmse:1.20871
# [33]	validation_0-rmse:0.35358	validation_1-rmse:1.20720
# [34]	validation_0-rmse:0.33985	validation_1-rmse:1.22718
# [35]	validation_0-rmse:0.33966	validation_1-rmse:1.22982
# [36]	validation_0-rmse:0.33974	validation_1-rmse:1.22820
# [0]	validation_0-rmse:5.62185	validation_1-rmse:5.39391
# [1]	validation_0-rmse:4.66526	validation_1-rmse:4.56854
# [2]	validation_0-rmse:3.90213	validation_1-rmse:3.87263
# [3]	validation_0-rmse:3.24525	validation_1-rmse:3.22285
# [4]	validation_0-rmse:2.73928	validation_1-rmse:2.78601
# [5]	validation_0-rmse:2.29586	validation_1-rmse:2.29783
# [6]	validation_0-rmse:1.94981	validation_1-rmse:2.06827
# [7]	validation_0-rmse:1.65756	validation_1-rmse:1.78886
# [8]	validation_0-rmse:1.40531	validation_1-rmse:1.58020
# [9]	validation_0-rmse:1.21328	validation_1-rmse:1.40170
# [10]	validation_0-rmse:1.04725	validation_1-rmse:1.34100
# [11]	validation_0-rmse:0.94127	validation_1-rmse:1.21298
# [12]	validation_0-rmse:0.88293	validation_1-rmse:1.18921
# [13]	validation_0-rmse:0.80409	validation_1-rmse:1.17021
# [14]	validation_0-rmse:0.74803	validation_1-rmse:1.13462
# [15]	validation_0-rmse:0.68970	validation_1-rmse:1.09756
# [16]	validation_0-rmse:0.64972	validation_1-rmse:1.04398
# [17]	validation_0-rmse:0.60521	validation_1-rmse:1.00487
# [18]	validation_0-rmse:0.57171	validation_1-rmse:1.01297
# [19]	validation_0-rmse:0.54311	validation_1-rmse:1.01165
# [20]	validation_0-rmse:0.50658	validation_1-rmse:1.00278
# [21]	validation_0-rmse:0.49643	validation_1-rmse:1.00956
# [22]	validation_0-rmse:0.48045	validation_1-rmse:1.01074
# [23]	validation_0-rmse:0.45398	validation_1-rmse:1.03111
# [24]	validation_0-rmse:0.44439	validation_1-rmse:1.02781
# [25]	validation_0-rmse:0.43504	validation_1-rmse:1.02197
# [26]	validation_0-rmse:0.42576	validation_1-rmse:1.01503
# [27]	validation_0-rmse:0.41357	validation_1-rmse:1.02471
# [28]	validation_0-rmse:0.40051	validation_1-rmse:1.04285
# [29]	validation_0-rmse:0.37789	validation_1-rmse:1.01919
# [30]	validation_0-rmse:0.37947	validation_1-rmse:1.02340
# [31]	validation_0-rmse:0.36224	validation_1-rmse:1.01825
# [32]	validation_0-rmse:0.35303	validation_1-rmse:1.01640
# [33]	validation_0-rmse:0.35146	validation_1-rmse:1.01013
# [34]	validation_0-rmse:0.34474	validation_1-rmse:1.01108
# [35]	validation_0-rmse:0.34448	validation_1-rmse:1.00888
# [36]	validation_0-rmse:0.33665	validation_1-rmse:1.00801
# [37]	validation_0-rmse:0.33332	validation_1-rmse:1.01174
# [38]	validation_0-rmse:0.33030	validation_1-rmse:1.01031
# [39]	validation_0-rmse:0.31934	validation_1-rmse:1.01468
# [0]	validation_0-rmse:5.51098	validation_1-rmse:5.74341
# [1]	validation_0-rmse:4.53136	validation_1-rmse:4.72050
# [2]	validation_0-rmse:3.75176	validation_1-rmse:3.91094
# [3]	validation_0-rmse:3.14806	validation_1-rmse:3.33151
# [4]	validation_0-rmse:2.64458	validation_1-rmse:2.92383
# [5]	validation_0-rmse:2.21129	validation_1-rmse:2.48093
# [6]	validation_0-rmse:1.86976	validation_1-rmse:2.17363
# [7]	validation_0-rmse:1.57688	validation_1-rmse:1.96910
# [8]	validation_0-rmse:1.40166	validation_1-rmse:1.86126
# [9]	validation_0-rmse:1.23740	validation_1-rmse:1.71540
# [10]	validation_0-rmse:1.06335	validation_1-rmse:1.58766
# [11]	validation_0-rmse:0.94079	validation_1-rmse:1.48541
# [12]	validation_0-rmse:0.85018	validation_1-rmse:1.41537
# [13]	validation_0-rmse:0.77452	validation_1-rmse:1.37791
# [14]	validation_0-rmse:0.73148	validation_1-rmse:1.37054
# [15]	validation_0-rmse:0.66952	validation_1-rmse:1.36830
# [16]	validation_0-rmse:0.63261	validation_1-rmse:1.37025
# [17]	validation_0-rmse:0.59111	validation_1-rmse:1.32641
# [18]	validation_0-rmse:0.57594	validation_1-rmse:1.32173
# [19]	validation_0-rmse:0.54030	validation_1-rmse:1.29061
# [20]	validation_0-rmse:0.49815	validation_1-rmse:1.27430
# [21]	validation_0-rmse:0.47996	validation_1-rmse:1.26547
# [22]	validation_0-rmse:0.46911	validation_1-rmse:1.25715
# [23]	validation_0-rmse:0.44951	validation_1-rmse:1.26563
# [24]	validation_0-rmse:0.42741	validation_1-rmse:1.27118
# [25]	validation_0-rmse:0.40522	validation_1-rmse:1.26228
# [26]	validation_0-rmse:0.40015	validation_1-rmse:1.26850
# [27]	validation_0-rmse:0.39293	validation_1-rmse:1.26872
# [28]	validation_0-rmse:0.37918	validation_1-rmse:1.26215
# [29]	validation_0-rmse:0.37047	validation_1-rmse:1.28213
# [30]	validation_0-rmse:0.36101	validation_1-rmse:1.27271
# [31]	validation_0-rmse:0.36200	validation_1-rmse:1.28004
# [32]	validation_0-rmse:0.36236	validation_1-rmse:1.28353
# [33]	validation_0-rmse:0.35919	validation_1-rmse:1.27820
# [34]	validation_0-rmse:0.35633	validation_1-rmse:1.27477
# [35]	validation_0-rmse:0.35185	validation_1-rmse:1.26583
# [36]	validation_0-rmse:0.34794	validation_1-rmse:1.25601
# [37]	validation_0-rmse:0.34421	validation_1-rmse:1.24280
# [38]	validation_0-rmse:0.34447	validation_1-rmse:1.24253
# [39]	validation_0-rmse:0.34162	validation_1-rmse:1.23765
# [40]	validation_0-rmse:0.34133	validation_1-rmse:1.23809
# [41]	validation_0-rmse:0.33789	validation_1-rmse:1.24260
# [42]	validation_0-rmse:0.33826	validation_1-rmse:1.24323
# [43]	validation_0-rmse:0.33810	validation_1-rmse:1.24305
# [44]	validation_0-rmse:0.33075	validation_1-rmse:1.24263
# [45]	validation_0-rmse:0.32541	validation_1-rmse:1.24089
# [46]	validation_0-rmse:0.31793	validation_1-rmse:1.23910
# [47]	validation_0-rmse:0.31847	validation_1-rmse:1.23874
# [48]	validation_0-rmse:0.31094	validation_1-rmse:1.23928
# [49]	validation_0-rmse:0.31359	validation_1-rmse:1.23037
# [50]	validation_0-rmse:0.31505	validation_1-rmse:1.22519
# [51]	validation_0-rmse:0.31457	validation_1-rmse:1.22581
# [52]	validation_0-rmse:0.31384	validation_1-rmse:1.22644
# [0]	validation_0-rmse:5.51633	validation_1-rmse:5.36363
# [1]	validation_0-rmse:4.52286	validation_1-rmse:4.40657
# [2]	validation_0-rmse:3.71810	validation_1-rmse:3.65049
# [3]	validation_0-rmse:3.06102	validation_1-rmse:2.99539
# [4]	validation_0-rmse:2.56564	validation_1-rmse:2.51860
# [5]	validation_0-rmse:2.18495	validation_1-rmse:2.18209
# [6]	validation_0-rmse:1.86890	validation_1-rmse:1.89695
# [7]	validation_0-rmse:1.61513	validation_1-rmse:1.70946
# [8]	validation_0-rmse:1.39905	validation_1-rmse:1.58145
# [9]	validation_0-rmse:1.22475	validation_1-rmse:1.45350
# [10]	validation_0-rmse:1.09022	validation_1-rmse:1.34690
# [11]	validation_0-rmse:0.96544	validation_1-rmse:1.28786
# [12]	validation_0-rmse:0.88005	validation_1-rmse:1.23483
# [13]	validation_0-rmse:0.79391	validation_1-rmse:1.17884
# [14]	validation_0-rmse:0.74963	validation_1-rmse:1.18387
# [15]	validation_0-rmse:0.68640	validation_1-rmse:1.13252
# [16]	validation_0-rmse:0.63720	validation_1-rmse:1.12057
# [17]	validation_0-rmse:0.58502	validation_1-rmse:1.08633
# [18]	validation_0-rmse:0.55585	validation_1-rmse:1.06757
# [19]	validation_0-rmse:0.53689	validation_1-rmse:1.06538
# [20]	validation_0-rmse:0.50867	validation_1-rmse:1.04648
# [21]	validation_0-rmse:0.48908	validation_1-rmse:1.02453
# [22]	validation_0-rmse:0.46714	validation_1-rmse:1.03439
# [23]	validation_0-rmse:0.45257	validation_1-rmse:1.03238
# [24]	validation_0-rmse:0.44500	validation_1-rmse:1.03375
# [25]	validation_0-rmse:0.42967	validation_1-rmse:1.03086
# [26]	validation_0-rmse:0.42979	validation_1-rmse:1.01841
# [27]	validation_0-rmse:0.41165	validation_1-rmse:1.01353
# [28]	validation_0-rmse:0.40589	validation_1-rmse:1.02196
# [29]	validation_0-rmse:0.40213	validation_1-rmse:1.01588
# [30]	validation_0-rmse:0.39039	validation_1-rmse:1.01098
# [31]	validation_0-rmse:0.36796	validation_1-rmse:1.02485
# [32]	validation_0-rmse:0.36350	validation_1-rmse:1.02612
# [33]	validation_0-rmse:0.35748	validation_1-rmse:1.02203
# [34]	validation_0-rmse:0.35162	validation_1-rmse:1.00778
# [35]	validation_0-rmse:0.34005	validation_1-rmse:1.00591
# [36]	validation_0-rmse:0.33195	validation_1-rmse:1.00758
# [37]	validation_0-rmse:0.33020	validation_1-rmse:1.01200
# [38]	validation_0-rmse:0.31835	validation_1-rmse:1.00308
# [39]	validation_0-rmse:0.31057	validation_1-rmse:1.00310
# [40]	validation_0-rmse:0.30274	validation_1-rmse:1.00526
# [41]	validation_0-rmse:0.30251	validation_1-rmse:1.00538
# [42]	validation_0-rmse:0.30190	validation_1-rmse:1.00603
# [43]	validation_0-rmse:0.30207	validation_1-rmse:1.00228
# [44]	validation_0-rmse:0.29701	validation_1-rmse:1.01094
# [45]	validation_0-rmse:0.29686	validation_1-rmse:1.01100
# [46]	validation_0-rmse:0.29725	validation_1-rmse:1.01087
# [47]	validation_0-rmse:0.29337	validation_1-rmse:1.01974
# [48]	validation_0-rmse:0.29006	validation_1-rmse:1.00741
# [49]	validation_0-rmse:0.29041	validation_1-rmse:1.00728
# [50]	validation_0-rmse:0.28878	validation_1-rmse:1.01718
# [51]	validation_0-rmse:0.28270	validation_1-rmse:1.01793
# [52]	validation_0-rmse:0.28242	validation_1-rmse:1.01817
# [0]	validation_0-rmse:5.55852	validation_1-rmse:5.77254
# [1]	validation_0-rmse:4.57875	validation_1-rmse:4.83100
# [2]	validation_0-rmse:3.78041	validation_1-rmse:4.04140
# [3]	validation_0-rmse:3.14273	validation_1-rmse:3.47049
# [4]	validation_0-rmse:2.62308	validation_1-rmse:2.96371
# [5]	validation_0-rmse:2.23911	validation_1-rmse:2.60943
# [6]	validation_0-rmse:1.87296	validation_1-rmse:2.24553
# [7]	validation_0-rmse:1.64031	validation_1-rmse:2.05430
# [8]	validation_0-rmse:1.42383	validation_1-rmse:1.91831
# [9]	validation_0-rmse:1.25201	validation_1-rmse:1.76440
# [10]	validation_0-rmse:1.11085	validation_1-rmse:1.66173
# [11]	validation_0-rmse:0.97529	validation_1-rmse:1.53365
# [12]	validation_0-rmse:0.85757	validation_1-rmse:1.50008
# [13]	validation_0-rmse:0.76300	validation_1-rmse:1.44842
# [14]	validation_0-rmse:0.71403	validation_1-rmse:1.45353
# [15]	validation_0-rmse:0.66255	validation_1-rmse:1.44041
# [16]	validation_0-rmse:0.60528	validation_1-rmse:1.40900
# [17]	validation_0-rmse:0.58374	validation_1-rmse:1.38395
# [18]	validation_0-rmse:0.56835	validation_1-rmse:1.35562
# [19]	validation_0-rmse:0.54030	validation_1-rmse:1.34176
# [20]	validation_0-rmse:0.50929	validation_1-rmse:1.32718
# [21]	validation_0-rmse:0.47894	validation_1-rmse:1.32189
# [22]	validation_0-rmse:0.46303	validation_1-rmse:1.28329
# [23]	validation_0-rmse:0.44893	validation_1-rmse:1.29028
# [24]	validation_0-rmse:0.44107	validation_1-rmse:1.26647
# [25]	validation_0-rmse:0.42631	validation_1-rmse:1.24915
# [26]	validation_0-rmse:0.41576	validation_1-rmse:1.26374
# [27]	validation_0-rmse:0.41141	validation_1-rmse:1.26484
# [28]	validation_0-rmse:0.39802	validation_1-rmse:1.26515
# [29]	validation_0-rmse:0.38695	validation_1-rmse:1.26289
# [30]	validation_0-rmse:0.38216	validation_1-rmse:1.27959
# [31]	validation_0-rmse:0.35703	validation_1-rmse:1.29221
# [32]	validation_0-rmse:0.35347	validation_1-rmse:1.30046
# [33]	validation_0-rmse:0.34547	validation_1-rmse:1.31293
# [34]	validation_0-rmse:0.34545	validation_1-rmse:1.31243
# [35]	validation_0-rmse:0.33753	validation_1-rmse:1.30426
# [36]	validation_0-rmse:0.33578	validation_1-rmse:1.30762
# [37]	validation_0-rmse:0.33587	validation_1-rmse:1.30913
# [38]	validation_0-rmse:0.33084	validation_1-rmse:1.30287
# [39]	validation_0-rmse:0.32799	validation_1-rmse:1.30565
# [40]	validation_0-rmse:0.32381	validation_1-rmse:1.30356
# [41]	validation_0-rmse:0.32446	validation_1-rmse:1.30556
# [42]	validation_0-rmse:0.32409	validation_1-rmse:1.30446
# [43]	validation_0-rmse:0.31454	validation_1-rmse:1.30024
# [44]	validation_0-rmse:0.30763	validation_1-rmse:1.29813
# [45]	validation_0-rmse:0.30732	validation_1-rmse:1.29498
# [0]	validation_0-rmse:5.50792	validation_1-rmse:5.78755
# [1]	validation_0-rmse:4.54534	validation_1-rmse:4.74407
# [2]	validation_0-rmse:3.79280	validation_1-rmse:3.99832
# [3]	validation_0-rmse:3.14507	validation_1-rmse:3.25117
# [4]	validation_0-rmse:2.65524	validation_1-rmse:2.72454
# [5]	validation_0-rmse:2.22722	validation_1-rmse:2.31293
# [6]	validation_0-rmse:1.89108	validation_1-rmse:1.99049
# [7]	validation_0-rmse:1.61765	validation_1-rmse:1.77222
# [8]	validation_0-rmse:1.39413	validation_1-rmse:1.60740
# [9]	validation_0-rmse:1.20814	validation_1-rmse:1.43490
# [10]	validation_0-rmse:1.12220	validation_1-rmse:1.38358
# [11]	validation_0-rmse:1.01459	validation_1-rmse:1.28956
# [12]	validation_0-rmse:0.92555	validation_1-rmse:1.26248
# [13]	validation_0-rmse:0.81495	validation_1-rmse:1.18616
# [14]	validation_0-rmse:0.75435	validation_1-rmse:1.12310
# [15]	validation_0-rmse:0.69410	validation_1-rmse:1.07156
# [16]	validation_0-rmse:0.63699	validation_1-rmse:1.02959
# [17]	validation_0-rmse:0.60681	validation_1-rmse:1.01542
# [18]	validation_0-rmse:0.57201	validation_1-rmse:0.98223
# [19]	validation_0-rmse:0.55684	validation_1-rmse:0.97087
# [20]	validation_0-rmse:0.53011	validation_1-rmse:0.97978
# [21]	validation_0-rmse:0.52319	validation_1-rmse:0.97098
# [22]	validation_0-rmse:0.50318	validation_1-rmse:0.95595
# [23]	validation_0-rmse:0.48901	validation_1-rmse:0.96461
# [24]	validation_0-rmse:0.47312	validation_1-rmse:0.97186
# [25]	validation_0-rmse:0.46631	validation_1-rmse:0.96723
# [26]	validation_0-rmse:0.45037	validation_1-rmse:0.97797
# [27]	validation_0-rmse:0.44040	validation_1-rmse:0.98362
# [28]	validation_0-rmse:0.42446	validation_1-rmse:0.97307
# [29]	validation_0-rmse:0.41794	validation_1-rmse:0.98211
# [30]	validation_0-rmse:0.40920	validation_1-rmse:0.98272
# [31]	validation_0-rmse:0.40414	validation_1-rmse:0.98250
# [32]	validation_0-rmse:0.39927	validation_1-rmse:0.99117
# [33]	validation_0-rmse:0.38994	validation_1-rmse:0.97929
# [34]	validation_0-rmse:0.38422	validation_1-rmse:1.00278
# [35]	validation_0-rmse:0.38466	validation_1-rmse:1.00579
# [36]	validation_0-rmse:0.37884	validation_1-rmse:1.01193
# [37]	validation_0-rmse:0.36143	validation_1-rmse:1.00752
# [38]	validation_0-rmse:0.35652	validation_1-rmse:1.00360
# [39]	validation_0-rmse:0.36192	validation_1-rmse:0.99266
# [40]	validation_0-rmse:0.34653	validation_1-rmse:1.00969
# [41]	validation_0-rmse:0.34392	validation_1-rmse:1.00805
# [42]	validation_0-rmse:0.33329	validation_1-rmse:1.01817
# [0]	validation_0-rmse:5.53170	validation_1-rmse:5.27286
# [1]	validation_0-rmse:4.56013	validation_1-rmse:4.34519
# [2]	validation_0-rmse:3.80445	validation_1-rmse:3.61073
# [3]	validation_0-rmse:3.18184	validation_1-rmse:3.06141
# [4]	validation_0-rmse:2.66214	validation_1-rmse:2.65641
# [5]	validation_0-rmse:2.21878	validation_1-rmse:2.27629
# [6]	validation_0-rmse:1.89182	validation_1-rmse:2.00990
# [7]	validation_0-rmse:1.62393	validation_1-rmse:1.81261
# [8]	validation_0-rmse:1.41494	validation_1-rmse:1.70869
# [9]	validation_0-rmse:1.24787	validation_1-rmse:1.63227
# [10]	validation_0-rmse:1.09951	validation_1-rmse:1.57992
# [11]	validation_0-rmse:0.98431	validation_1-rmse:1.52479
# [12]	validation_0-rmse:0.88364	validation_1-rmse:1.44395
# [13]	validation_0-rmse:0.78862	validation_1-rmse:1.41676
# [14]	validation_0-rmse:0.71300	validation_1-rmse:1.37294
# [15]	validation_0-rmse:0.65044	validation_1-rmse:1.34659
# [16]	validation_0-rmse:0.59642	validation_1-rmse:1.37880
# [17]	validation_0-rmse:0.56060	validation_1-rmse:1.34970
# [18]	validation_0-rmse:0.51788	validation_1-rmse:1.32580
# [19]	validation_0-rmse:0.50425	validation_1-rmse:1.32961
# [20]	validation_0-rmse:0.47545	validation_1-rmse:1.29103
# [21]	validation_0-rmse:0.47354	validation_1-rmse:1.29581
# [22]	validation_0-rmse:0.46275	validation_1-rmse:1.30300
# [23]	validation_0-rmse:0.44883	validation_1-rmse:1.30794
# [24]	validation_0-rmse:0.43428	validation_1-rmse:1.28645
# [25]	validation_0-rmse:0.42351	validation_1-rmse:1.31800
# [26]	validation_0-rmse:0.41049	validation_1-rmse:1.34771
# [27]	validation_0-rmse:0.39763	validation_1-rmse:1.34461
# [28]	validation_0-rmse:0.39004	validation_1-rmse:1.36285
# [29]	validation_0-rmse:0.38524	validation_1-rmse:1.36325
# [30]	validation_0-rmse:0.37110	validation_1-rmse:1.35646
# [31]	validation_0-rmse:0.36852	validation_1-rmse:1.34156
# [32]	validation_0-rmse:0.35038	validation_1-rmse:1.33407
# [33]	validation_0-rmse:0.34583	validation_1-rmse:1.33357
# [34]	validation_0-rmse:0.34076	validation_1-rmse:1.32547
# [35]	validation_0-rmse:0.33858	validation_1-rmse:1.34408
# [36]	validation_0-rmse:0.33566	validation_1-rmse:1.35196
# [37]	validation_0-rmse:0.33562	validation_1-rmse:1.35337
# [38]	validation_0-rmse:0.33189	validation_1-rmse:1.34518
# [39]	validation_0-rmse:0.33064	validation_1-rmse:1.33849
# [40]	validation_0-rmse:0.32503	validation_1-rmse:1.34012
# [41]	validation_0-rmse:0.31809	validation_1-rmse:1.33188
# [42]	validation_0-rmse:0.31808	validation_1-rmse:1.33209
# [43]	validation_0-rmse:0.31810	validation_1-rmse:1.33176
# [0]	validation_0-rmse:5.49075	validation_1-rmse:5.94528
# [1]	validation_0-rmse:4.50311	validation_1-rmse:4.96940
# [2]	validation_0-rmse:3.72923	validation_1-rmse:4.13724
# [3]	validation_0-rmse:3.09334	validation_1-rmse:3.45814
# [4]	validation_0-rmse:2.63009	validation_1-rmse:3.04845
# [5]	validation_0-rmse:2.21140	validation_1-rmse:2.60148
# [6]	validation_0-rmse:1.85391	validation_1-rmse:2.26345
# [7]	validation_0-rmse:1.62892	validation_1-rmse:2.03577
# [8]	validation_0-rmse:1.42234	validation_1-rmse:1.88320
# [9]	validation_0-rmse:1.23223	validation_1-rmse:1.66542
# [10]	validation_0-rmse:1.06892	validation_1-rmse:1.47376
# [11]	validation_0-rmse:0.95099	validation_1-rmse:1.37943
# [12]	validation_0-rmse:0.88018	validation_1-rmse:1.33756
# [13]	validation_0-rmse:0.81582	validation_1-rmse:1.32814
# [14]	validation_0-rmse:0.74958	validation_1-rmse:1.27150
# [15]	validation_0-rmse:0.71869	validation_1-rmse:1.24480
# [16]	validation_0-rmse:0.66086	validation_1-rmse:1.27165
# [17]	validation_0-rmse:0.60737	validation_1-rmse:1.21180
# [18]	validation_0-rmse:0.59467	validation_1-rmse:1.22511
# [19]	validation_0-rmse:0.57258	validation_1-rmse:1.20079
# [20]	validation_0-rmse:0.53842	validation_1-rmse:1.17558
# [21]	validation_0-rmse:0.51054	validation_1-rmse:1.15935
# [22]	validation_0-rmse:0.51303	validation_1-rmse:1.14903
# [23]	validation_0-rmse:0.49865	validation_1-rmse:1.15700
# [24]	validation_0-rmse:0.48101	validation_1-rmse:1.13690
# [25]	validation_0-rmse:0.45907	validation_1-rmse:1.12179
# [26]	validation_0-rmse:0.45900	validation_1-rmse:1.10906
# [27]	validation_0-rmse:0.45421	validation_1-rmse:1.11596
# [28]	validation_0-rmse:0.44964	validation_1-rmse:1.10978
# [29]	validation_0-rmse:0.44871	validation_1-rmse:1.10962
# [30]	validation_0-rmse:0.43672	validation_1-rmse:1.11022
# [31]	validation_0-rmse:0.41014	validation_1-rmse:1.14338
# [32]	validation_0-rmse:0.39281	validation_1-rmse:1.14402
# [33]	validation_0-rmse:0.39276	validation_1-rmse:1.14358
# [34]	validation_0-rmse:0.38012	validation_1-rmse:1.14174
# [35]	validation_0-rmse:0.37768	validation_1-rmse:1.14186
# [36]	validation_0-rmse:0.36842	validation_1-rmse:1.15129
# [37]	validation_0-rmse:0.36277	validation_1-rmse:1.14651
# [38]	validation_0-rmse:0.34619	validation_1-rmse:1.15013
# [39]	validation_0-rmse:0.33787	validation_1-rmse:1.12982
# [40]	validation_0-rmse:0.33605	validation_1-rmse:1.12890
# [41]	validation_0-rmse:0.33160	validation_1-rmse:1.12722
# [42]	validation_0-rmse:0.32539	validation_1-rmse:1.12162
# [43]	validation_0-rmse:0.31987	validation_1-rmse:1.13904
# [44]	validation_0-rmse:0.31445	validation_1-rmse:1.13363
# [45]	validation_0-rmse:0.31484	validation_1-rmse:1.13239
# [0]	validation_0-rmse:5.66235	validation_1-rmse:5.71204
# [1]	validation_0-rmse:4.69861	validation_1-rmse:4.80302
# [2]	validation_0-rmse:3.87477	validation_1-rmse:3.99871
# [3]	validation_0-rmse:3.23920	validation_1-rmse:3.38828
# [4]	validation_0-rmse:2.68038	validation_1-rmse:2.89617
# [5]	validation_0-rmse:2.24119	validation_1-rmse:2.50070
# [6]	validation_0-rmse:1.91416	validation_1-rmse:2.20765
# [7]	validation_0-rmse:1.63333	validation_1-rmse:1.94046
# [8]	validation_0-rmse:1.42803	validation_1-rmse:1.73170
# [9]	validation_0-rmse:1.21353	validation_1-rmse:1.55806
# [10]	validation_0-rmse:1.08015	validation_1-rmse:1.45139
# [11]	validation_0-rmse:0.98463	validation_1-rmse:1.35974
# [12]	validation_0-rmse:0.89164	validation_1-rmse:1.31813
# [13]	validation_0-rmse:0.82099	validation_1-rmse:1.26553
# [14]	validation_0-rmse:0.75838	validation_1-rmse:1.23621
# [15]	validation_0-rmse:0.70264	validation_1-rmse:1.20208
# [16]	validation_0-rmse:0.64744	validation_1-rmse:1.16700
# [17]	validation_0-rmse:0.59998	validation_1-rmse:1.16212
# [18]	validation_0-rmse:0.58683	validation_1-rmse:1.15277
# [19]	validation_0-rmse:0.57746	validation_1-rmse:1.13766
# [20]	validation_0-rmse:0.57077	validation_1-rmse:1.12445
# [21]	validation_0-rmse:0.55031	validation_1-rmse:1.10874
# [22]	validation_0-rmse:0.52418	validation_1-rmse:1.09297
# [23]	validation_0-rmse:0.50611	validation_1-rmse:1.09143
# [24]	validation_0-rmse:0.47758	validation_1-rmse:1.09048
# [25]	validation_0-rmse:0.47867	validation_1-rmse:1.08355
# [26]	validation_0-rmse:0.46321	validation_1-rmse:1.07597
# [27]	validation_0-rmse:0.44541	validation_1-rmse:1.06874
# [28]	validation_0-rmse:0.41737	validation_1-rmse:1.08918
# [29]	validation_0-rmse:0.40995	validation_1-rmse:1.08345
# [30]	validation_0-rmse:0.40447	validation_1-rmse:1.08998
# [31]	validation_0-rmse:0.39041	validation_1-rmse:1.09165
# [32]	validation_0-rmse:0.38539	validation_1-rmse:1.09356
# [33]	validation_0-rmse:0.38273	validation_1-rmse:1.09197
# [34]	validation_0-rmse:0.38351	validation_1-rmse:1.09331
# [35]	validation_0-rmse:0.37511	validation_1-rmse:1.09038
# [36]	validation_0-rmse:0.37382	validation_1-rmse:1.08443
# [37]	validation_0-rmse:0.37112	validation_1-rmse:1.08995
# [38]	validation_0-rmse:0.36185	validation_1-rmse:1.07672
# [39]	validation_0-rmse:0.36211	validation_1-rmse:1.08087
# [40]	validation_0-rmse:0.35429	validation_1-rmse:1.08001
# [41]	validation_0-rmse:0.35385	validation_1-rmse:1.08140
# [42]	validation_0-rmse:0.34722	validation_1-rmse:1.08537
# [43]	validation_0-rmse:0.34699	validation_1-rmse:1.07722
# [44]	validation_0-rmse:0.34438	validation_1-rmse:1.07495
# [45]	validation_0-rmse:0.34018	validation_1-rmse:1.07207
# [46]	validation_0-rmse:0.33577	validation_1-rmse:1.07088
# [47]	validation_0-rmse:0.33528	validation_1-rmse:1.07399
# [0]	validation_0-rmse:5.55407	validation_1-rmse:5.60474
# [1]	validation_0-rmse:4.55874	validation_1-rmse:4.69488
# [2]	validation_0-rmse:3.77814	validation_1-rmse:3.98815
# [3]	validation_0-rmse:3.18368	validation_1-rmse:3.40510
# [4]	validation_0-rmse:2.66229	validation_1-rmse:2.89532
# [5]	validation_0-rmse:2.22284	validation_1-rmse:2.46199
# [6]	validation_0-rmse:1.88581	validation_1-rmse:2.16755
# [7]	validation_0-rmse:1.57223	validation_1-rmse:1.90758
# [8]	validation_0-rmse:1.38155	validation_1-rmse:1.73190
# [9]	validation_0-rmse:1.22237	validation_1-rmse:1.59175
# [10]	validation_0-rmse:1.07038	validation_1-rmse:1.49199
# [11]	validation_0-rmse:0.95323	validation_1-rmse:1.40250
# [12]	validation_0-rmse:0.85565	validation_1-rmse:1.32779
# [13]	validation_0-rmse:0.75593	validation_1-rmse:1.24888
# [14]	validation_0-rmse:0.70767	validation_1-rmse:1.22093
# [15]	validation_0-rmse:0.66559	validation_1-rmse:1.20896
# [16]	validation_0-rmse:0.60768	validation_1-rmse:1.15083
# [17]	validation_0-rmse:0.55897	validation_1-rmse:1.12881
# [18]	validation_0-rmse:0.53183	validation_1-rmse:1.11342
# [19]	validation_0-rmse:0.50927	validation_1-rmse:1.09169
# [20]	validation_0-rmse:0.49103	validation_1-rmse:1.11012
# [21]	validation_0-rmse:0.48149	validation_1-rmse:1.11645
# [22]	validation_0-rmse:0.45487	validation_1-rmse:1.10961
# [23]	validation_0-rmse:0.43800	validation_1-rmse:1.09393
# [24]	validation_0-rmse:0.41541	validation_1-rmse:1.08964
# [25]	validation_0-rmse:0.40467	validation_1-rmse:1.07574
# [26]	validation_0-rmse:0.39551	validation_1-rmse:1.08552
# [27]	validation_0-rmse:0.38987	validation_1-rmse:1.07972
# [28]	validation_0-rmse:0.37822	validation_1-rmse:1.08707
# [29]	validation_0-rmse:0.37234	validation_1-rmse:1.08293
# [30]	validation_0-rmse:0.36352	validation_1-rmse:1.08266
# [31]	validation_0-rmse:0.36044	validation_1-rmse:1.07808
# [32]	validation_0-rmse:0.35479	validation_1-rmse:1.08617
# [33]	validation_0-rmse:0.35356	validation_1-rmse:1.08337
# [34]	validation_0-rmse:0.34956	validation_1-rmse:1.08367
# [35]	validation_0-rmse:0.34840	validation_1-rmse:1.08463
# [36]	validation_0-rmse:0.33993	validation_1-rmse:1.08572
# [37]	validation_0-rmse:0.33069	validation_1-rmse:1.09999
# [38]	validation_0-rmse:0.33039	validation_1-rmse:1.09927
# [39]	validation_0-rmse:0.32799	validation_1-rmse:1.10290
# [40]	validation_0-rmse:0.32707	validation_1-rmse:1.09692
# [41]	validation_0-rmse:0.32697	validation_1-rmse:1.09671
# [42]	validation_0-rmse:0.32485	validation_1-rmse:1.09530
# [43]	validation_0-rmse:0.32505	validation_1-rmse:1.09834
# [44]	validation_0-rmse:0.31935	validation_1-rmse:1.10052
# [0]	validation_0-rmse:5.41067	validation_1-rmse:6.04082
# [1]	validation_0-rmse:4.44964	validation_1-rmse:5.03118
# [2]	validation_0-rmse:3.67879	validation_1-rmse:4.26830
# [3]	validation_0-rmse:3.09889	validation_1-rmse:3.71308
# [4]	validation_0-rmse:2.55046	validation_1-rmse:3.13251
# [5]	validation_0-rmse:2.17402	validation_1-rmse:2.77251
# [6]	validation_0-rmse:1.86735	validation_1-rmse:2.42808
# [7]	validation_0-rmse:1.58014	validation_1-rmse:2.12889
# [8]	validation_0-rmse:1.35046	validation_1-rmse:1.89508
# [9]	validation_0-rmse:1.18249	validation_1-rmse:1.73828
# [10]	validation_0-rmse:1.06035	validation_1-rmse:1.64636
# [11]	validation_0-rmse:0.94166	validation_1-rmse:1.52350
# [12]	validation_0-rmse:0.85581	validation_1-rmse:1.48693
# [13]	validation_0-rmse:0.76832	validation_1-rmse:1.40569
# [14]	validation_0-rmse:0.71166	validation_1-rmse:1.36933
# [15]	validation_0-rmse:0.65815	validation_1-rmse:1.32768
# [16]	validation_0-rmse:0.62238	validation_1-rmse:1.32423
# [17]	validation_0-rmse:0.59702	validation_1-rmse:1.34293
# [18]	validation_0-rmse:0.55869	validation_1-rmse:1.31847
# [19]	validation_0-rmse:0.53097	validation_1-rmse:1.27862
# [20]	validation_0-rmse:0.49291	validation_1-rmse:1.25646
# [21]	validation_0-rmse:0.47641	validation_1-rmse:1.26572
# [22]	validation_0-rmse:0.45962	validation_1-rmse:1.27115
# [23]	validation_0-rmse:0.44162	validation_1-rmse:1.28277
# [24]	validation_0-rmse:0.40502	validation_1-rmse:1.30094
# [25]	validation_0-rmse:0.39005	validation_1-rmse:1.28364
# [26]	validation_0-rmse:0.38574	validation_1-rmse:1.27225
# [27]	validation_0-rmse:0.37787	validation_1-rmse:1.27754
# [28]	validation_0-rmse:0.36482	validation_1-rmse:1.26843
# [29]	validation_0-rmse:0.35699	validation_1-rmse:1.26369
# [30]	validation_0-rmse:0.35665	validation_1-rmse:1.25126
# [31]	validation_0-rmse:0.34761	validation_1-rmse:1.23716
# [32]	validation_0-rmse:0.34102	validation_1-rmse:1.23416
# [33]	validation_0-rmse:0.33620	validation_1-rmse:1.24032
# [34]	validation_0-rmse:0.32834	validation_1-rmse:1.23576
# [35]	validation_0-rmse:0.32808	validation_1-rmse:1.23542
# [36]	validation_0-rmse:0.32567	validation_1-rmse:1.23834
# [37]	validation_0-rmse:0.32555	validation_1-rmse:1.23814
# [38]	validation_0-rmse:0.32508	validation_1-rmse:1.23715
# [39]	validation_0-rmse:0.32521	validation_1-rmse:1.23113
# [40]	validation_0-rmse:0.31925	validation_1-rmse:1.23184
# [41]	validation_0-rmse:0.31497	validation_1-rmse:1.23047
# [42]	validation_0-rmse:0.30921	validation_1-rmse:1.23157
# [43]	validation_0-rmse:0.30907	validation_1-rmse:1.23107
# [44]	validation_0-rmse:0.30905	validation_1-rmse:1.23059
# [45]	validation_0-rmse:0.30084	validation_1-rmse:1.21774
# [46]	validation_0-rmse:0.30085	validation_1-rmse:1.21778
# [47]	validation_0-rmse:0.29651	validation_1-rmse:1.22920
# [48]	validation_0-rmse:0.29649	validation_1-rmse:1.22927
# [49]	validation_0-rmse:0.28868	validation_1-rmse:1.20861
# [50]	validation_0-rmse:0.28878	validation_1-rmse:1.20830
# [51]	validation_0-rmse:0.28895	validation_1-rmse:1.20804
# [52]	validation_0-rmse:0.28892	validation_1-rmse:1.20807
# [0]	validation_0-rmse:5.54974	validation_1-rmse:5.57725
# [1]	validation_0-rmse:4.59448	validation_1-rmse:4.65485
# [2]	validation_0-rmse:3.78687	validation_1-rmse:3.85424
# [3]	validation_0-rmse:3.16998	validation_1-rmse:3.36439
# [4]	validation_0-rmse:2.66599	validation_1-rmse:2.85295
# [5]	validation_0-rmse:2.24780	validation_1-rmse:2.46464
# [6]	validation_0-rmse:1.92757	validation_1-rmse:2.16345
# [7]	validation_0-rmse:1.61627	validation_1-rmse:1.93005
# [8]	validation_0-rmse:1.41251	validation_1-rmse:1.68315
# [9]	validation_0-rmse:1.22864	validation_1-rmse:1.52876
# [10]	validation_0-rmse:1.09320	validation_1-rmse:1.41256
# [11]	validation_0-rmse:0.99689	validation_1-rmse:1.33843
# [12]	validation_0-rmse:0.90929	validation_1-rmse:1.33587
# [13]	validation_0-rmse:0.79970	validation_1-rmse:1.27060
# [14]	validation_0-rmse:0.73251	validation_1-rmse:1.23566
# [15]	validation_0-rmse:0.69700	validation_1-rmse:1.23434
# [16]	validation_0-rmse:0.65301	validation_1-rmse:1.22060
# [17]	validation_0-rmse:0.60047	validation_1-rmse:1.20709
# [18]	validation_0-rmse:0.56526	validation_1-rmse:1.22236
# [19]	validation_0-rmse:0.54198	validation_1-rmse:1.20382
# [20]	validation_0-rmse:0.51314	validation_1-rmse:1.20274
# [21]	validation_0-rmse:0.50926	validation_1-rmse:1.21026
# [22]	validation_0-rmse:0.49282	validation_1-rmse:1.19845
# [23]	validation_0-rmse:0.47923	validation_1-rmse:1.21275
# [24]	validation_0-rmse:0.45651	validation_1-rmse:1.21355
# [25]	validation_0-rmse:0.44296	validation_1-rmse:1.20988
# [26]	validation_0-rmse:0.43688	validation_1-rmse:1.22175
# [27]	validation_0-rmse:0.42270	validation_1-rmse:1.21207
# [28]	validation_0-rmse:0.41190	validation_1-rmse:1.22874
# [29]	validation_0-rmse:0.40163	validation_1-rmse:1.22148
# [30]	validation_0-rmse:0.39297	validation_1-rmse:1.22642
# [31]	validation_0-rmse:0.37640	validation_1-rmse:1.21699
# [32]	validation_0-rmse:0.37653	validation_1-rmse:1.21690
# [33]	validation_0-rmse:0.36647	validation_1-rmse:1.22003
# [34]	validation_0-rmse:0.36086	validation_1-rmse:1.22043
# [35]	validation_0-rmse:0.35688	validation_1-rmse:1.22135
# [36]	validation_0-rmse:0.35356	validation_1-rmse:1.22731
# [37]	validation_0-rmse:0.35414	validation_1-rmse:1.22409
# [38]	validation_0-rmse:0.34098	validation_1-rmse:1.20541
# [39]	validation_0-rmse:0.33851	validation_1-rmse:1.20304
# [40]	validation_0-rmse:0.33849	validation_1-rmse:1.20307
# [41]	validation_0-rmse:0.32878	validation_1-rmse:1.20777
# [42]	validation_0-rmse:0.32879	validation_1-rmse:1.20775
# [0]	validation_0-rmse:5.54400	validation_1-rmse:5.46939
# [1]	validation_0-rmse:4.60739	validation_1-rmse:4.54132
# [2]	validation_0-rmse:3.82396	validation_1-rmse:3.74648
# [3]	validation_0-rmse:3.19284	validation_1-rmse:3.11093
# [4]	validation_0-rmse:2.69677	validation_1-rmse:2.58093
# [5]	validation_0-rmse:2.26494	validation_1-rmse:2.16862
# [6]	validation_0-rmse:1.92967	validation_1-rmse:1.85557
# [7]	validation_0-rmse:1.65446	validation_1-rmse:1.60913
# [8]	validation_0-rmse:1.43227	validation_1-rmse:1.42738
# [9]	validation_0-rmse:1.22883	validation_1-rmse:1.24927
# [10]	validation_0-rmse:1.07081	validation_1-rmse:1.13065
# [11]	validation_0-rmse:0.97376	validation_1-rmse:1.10038
# [12]	validation_0-rmse:0.88458	validation_1-rmse:1.05296
# [13]	validation_0-rmse:0.80932	validation_1-rmse:1.02328
# [14]	validation_0-rmse:0.76901	validation_1-rmse:0.97712
# [15]	validation_0-rmse:0.71023	validation_1-rmse:0.94580
# [16]	validation_0-rmse:0.67271	validation_1-rmse:0.92719
# [17]	validation_0-rmse:0.63675	validation_1-rmse:0.88498
# [18]	validation_0-rmse:0.60813	validation_1-rmse:0.91533
# [19]	validation_0-rmse:0.57525	validation_1-rmse:0.88493
# [20]	validation_0-rmse:0.55537	validation_1-rmse:0.89627
# [21]	validation_0-rmse:0.53397	validation_1-rmse:0.89902
# [22]	validation_0-rmse:0.51612	validation_1-rmse:0.88445
# [23]	validation_0-rmse:0.49044	validation_1-rmse:0.88557
# [24]	validation_0-rmse:0.47794	validation_1-rmse:0.87845
# [25]	validation_0-rmse:0.46699	validation_1-rmse:0.89619
# [26]	validation_0-rmse:0.46009	validation_1-rmse:0.88617
# [27]	validation_0-rmse:0.45048	validation_1-rmse:0.87583
# [28]	validation_0-rmse:0.44298	validation_1-rmse:0.86786
# [29]	validation_0-rmse:0.43221	validation_1-rmse:0.86607
# [30]	validation_0-rmse:0.42790	validation_1-rmse:0.85566
# [31]	validation_0-rmse:0.41748	validation_1-rmse:0.86088
# [32]	validation_0-rmse:0.41231	validation_1-rmse:0.85973
# [33]	validation_0-rmse:0.40916	validation_1-rmse:0.85036
# [34]	validation_0-rmse:0.39966	validation_1-rmse:0.84685
# [35]	validation_0-rmse:0.39495	validation_1-rmse:0.84432
# [36]	validation_0-rmse:0.37934	validation_1-rmse:0.85063
# [37]	validation_0-rmse:0.37696	validation_1-rmse:0.84440
# [38]	validation_0-rmse:0.36960	validation_1-rmse:0.84435
# [39]	validation_0-rmse:0.36197	validation_1-rmse:0.85562
# [40]	validation_0-rmse:0.35154	validation_1-rmse:0.86103
# [41]	validation_0-rmse:0.35195	validation_1-rmse:0.87167
# [42]	validation_0-rmse:0.34756	validation_1-rmse:0.86743
# [43]	validation_0-rmse:0.34472	validation_1-rmse:0.86390
# [44]	validation_0-rmse:0.34511	validation_1-rmse:0.86019
# [45]	validation_0-rmse:0.33887	validation_1-rmse:0.86393
# [46]	validation_0-rmse:0.32256	validation_1-rmse:0.85667
# [47]	validation_0-rmse:0.31879	validation_1-rmse:0.85678
# [48]	validation_0-rmse:0.30899	validation_1-rmse:0.85357
# [49]	validation_0-rmse:0.30354	validation_1-rmse:0.84255
# [50]	validation_0-rmse:0.30328	validation_1-rmse:0.84367
# [51]	validation_0-rmse:0.30295	validation_1-rmse:0.84593
# [52]	validation_0-rmse:0.29764	validation_1-rmse:0.84730
# [0]	validation_0-rmse:5.56584	validation_1-rmse:5.51738
# [1]	validation_0-rmse:4.57232	validation_1-rmse:4.50408
# [2]	validation_0-rmse:3.78480	validation_1-rmse:3.69577
# [3]	validation_0-rmse:3.19748	validation_1-rmse:3.09856
# [4]	validation_0-rmse:2.64837	validation_1-rmse:2.52556
# [5]	validation_0-rmse:2.23939	validation_1-rmse:2.24235
# [6]	validation_0-rmse:1.89645	validation_1-rmse:1.92856
# [7]	validation_0-rmse:1.67236	validation_1-rmse:1.71532
# [8]	validation_0-rmse:1.46783	validation_1-rmse:1.54510
# [9]	validation_0-rmse:1.30023	validation_1-rmse:1.39680
# [10]	validation_0-rmse:1.16262	validation_1-rmse:1.25330
# [11]	validation_0-rmse:1.06083	validation_1-rmse:1.14333
# [12]	validation_0-rmse:0.94788	validation_1-rmse:1.03818
# [13]	validation_0-rmse:0.85588	validation_1-rmse:1.00913
# [14]	validation_0-rmse:0.79790	validation_1-rmse:1.01458
# [15]	validation_0-rmse:0.75119	validation_1-rmse:1.00621
# [16]	validation_0-rmse:0.70353	validation_1-rmse:0.99467
# [17]	validation_0-rmse:0.65621	validation_1-rmse:0.98408
# [18]	validation_0-rmse:0.63335	validation_1-rmse:0.96791
# [19]	validation_0-rmse:0.61681	validation_1-rmse:0.96816
# [20]	validation_0-rmse:0.59572	validation_1-rmse:0.98047
# [21]	validation_0-rmse:0.58561	validation_1-rmse:0.97604
# [22]	validation_0-rmse:0.55260	validation_1-rmse:0.93979
# [23]	validation_0-rmse:0.52994	validation_1-rmse:0.92399
# [24]	validation_0-rmse:0.51312	validation_1-rmse:0.91114
# [25]	validation_0-rmse:0.49435	validation_1-rmse:0.89382
# [26]	validation_0-rmse:0.48167	validation_1-rmse:0.92372
# [27]	validation_0-rmse:0.45737	validation_1-rmse:0.89091
# [28]	validation_0-rmse:0.43917	validation_1-rmse:0.88276
# [29]	validation_0-rmse:0.42720	validation_1-rmse:0.87837
# [30]	validation_0-rmse:0.42394	validation_1-rmse:0.88169
# [31]	validation_0-rmse:0.40672	validation_1-rmse:0.87320
# [32]	validation_0-rmse:0.39735	validation_1-rmse:0.88596
# [33]	validation_0-rmse:0.38846	validation_1-rmse:0.87941
# [34]	validation_0-rmse:0.38359	validation_1-rmse:0.87371
# [35]	validation_0-rmse:0.38372	validation_1-rmse:0.87504
# [36]	validation_0-rmse:0.37327	validation_1-rmse:0.87902
# [37]	validation_0-rmse:0.36008	validation_1-rmse:0.88201
# [38]	validation_0-rmse:0.35718	validation_1-rmse:0.87644
# [39]	validation_0-rmse:0.34662	validation_1-rmse:0.87178
# [40]	validation_0-rmse:0.34509	validation_1-rmse:0.86417
# [41]	validation_0-rmse:0.34256	validation_1-rmse:0.86014
# [42]	validation_0-rmse:0.33793	validation_1-rmse:0.86034
# [43]	validation_0-rmse:0.33239	validation_1-rmse:0.87680
# [44]	validation_0-rmse:0.33108	validation_1-rmse:0.87539
# [45]	validation_0-rmse:0.32986	validation_1-rmse:0.88139
# [46]	validation_0-rmse:0.31239	validation_1-rmse:0.87860
# [47]	validation_0-rmse:0.31089	validation_1-rmse:0.87187
# [48]	validation_0-rmse:0.31063	validation_1-rmse:0.87096
# [49]	validation_0-rmse:0.31035	validation_1-rmse:0.86946
# [50]	validation_0-rmse:0.30156	validation_1-rmse:0.86664
# [51]	validation_0-rmse:0.29588	validation_1-rmse:0.86665
# [52]	validation_0-rmse:0.29593	validation_1-rmse:0.86466
# [0]	validation_0-rmse:5.59955	validation_1-rmse:5.60156
# [1]	validation_0-rmse:4.63222	validation_1-rmse:4.69142
# [2]	validation_0-rmse:3.83618	validation_1-rmse:3.86801
# [3]	validation_0-rmse:3.22031	validation_1-rmse:3.30980
# [4]	validation_0-rmse:2.68214	validation_1-rmse:2.81624
# [5]	validation_0-rmse:2.28283	validation_1-rmse:2.45398
# [6]	validation_0-rmse:1.95523	validation_1-rmse:2.09386
# [7]	validation_0-rmse:1.64585	validation_1-rmse:1.89502
# [8]	validation_0-rmse:1.41514	validation_1-rmse:1.72084
# [9]	validation_0-rmse:1.24163	validation_1-rmse:1.56447
# [10]	validation_0-rmse:1.09930	validation_1-rmse:1.46443
# [11]	validation_0-rmse:1.00243	validation_1-rmse:1.38807
# [12]	validation_0-rmse:0.89241	validation_1-rmse:1.30921
# [13]	validation_0-rmse:0.82939	validation_1-rmse:1.26712
# [14]	validation_0-rmse:0.74754	validation_1-rmse:1.19715
# [15]	validation_0-rmse:0.66854	validation_1-rmse:1.13612
# [16]	validation_0-rmse:0.61361	validation_1-rmse:1.12785
# [17]	validation_0-rmse:0.56909	validation_1-rmse:1.12707
# [18]	validation_0-rmse:0.54814	validation_1-rmse:1.11132
# [19]	validation_0-rmse:0.53079	validation_1-rmse:1.09567
# [20]	validation_0-rmse:0.51871	validation_1-rmse:1.08769
# [21]	validation_0-rmse:0.50377	validation_1-rmse:1.07409
# [22]	validation_0-rmse:0.48380	validation_1-rmse:1.06741
# [23]	validation_0-rmse:0.45768	validation_1-rmse:1.06101
# [24]	validation_0-rmse:0.44280	validation_1-rmse:1.06132
# [25]	validation_0-rmse:0.44223	validation_1-rmse:1.05921
# [26]	validation_0-rmse:0.42885	validation_1-rmse:1.06944
# [27]	validation_0-rmse:0.42167	validation_1-rmse:1.06544
# [28]	validation_0-rmse:0.40762	validation_1-rmse:1.06836
# [29]	validation_0-rmse:0.39568	validation_1-rmse:1.07819
# [30]	validation_0-rmse:0.39562	validation_1-rmse:1.06487
# [31]	validation_0-rmse:0.39117	validation_1-rmse:1.06630
# [32]	validation_0-rmse:0.38150	validation_1-rmse:1.07542
# [33]	validation_0-rmse:0.37716	validation_1-rmse:1.08915
# [34]	validation_0-rmse:0.36704	validation_1-rmse:1.10071
# [35]	validation_0-rmse:0.35837	validation_1-rmse:1.11503
# [36]	validation_0-rmse:0.35699	validation_1-rmse:1.11920
# [37]	validation_0-rmse:0.34510	validation_1-rmse:1.12170
# [38]	validation_0-rmse:0.33325	validation_1-rmse:1.12078
# [39]	validation_0-rmse:0.33171	validation_1-rmse:1.11870
# [40]	validation_0-rmse:0.33011	validation_1-rmse:1.11544
# [41]	validation_0-rmse:0.32852	validation_1-rmse:1.11684
# [42]	validation_0-rmse:0.32796	validation_1-rmse:1.11465
# [43]	validation_0-rmse:0.32208	validation_1-rmse:1.10643
# [44]	validation_0-rmse:0.32063	validation_1-rmse:1.10528
# [0]	validation_0-rmse:5.67166	validation_1-rmse:5.18808
# [1]	validation_0-rmse:4.73535	validation_1-rmse:4.28916
# [2]	validation_0-rmse:3.90177	validation_1-rmse:3.53251
# [3]	validation_0-rmse:3.22523	validation_1-rmse:2.86215
# [4]	validation_0-rmse:2.65246	validation_1-rmse:2.29341
# [5]	validation_0-rmse:2.25044	validation_1-rmse:1.93910
# [6]	validation_0-rmse:1.91214	validation_1-rmse:1.60588
# [7]	validation_0-rmse:1.62530	validation_1-rmse:1.40370
# [8]	validation_0-rmse:1.40209	validation_1-rmse:1.26352
# [9]	validation_0-rmse:1.20501	validation_1-rmse:1.16699
# [10]	validation_0-rmse:1.07571	validation_1-rmse:1.12331
# [11]	validation_0-rmse:0.98315	validation_1-rmse:1.11885
# [12]	validation_0-rmse:0.88235	validation_1-rmse:1.10185
# [13]	validation_0-rmse:0.80768	validation_1-rmse:1.05839
# [14]	validation_0-rmse:0.74197	validation_1-rmse:1.02686
# [15]	validation_0-rmse:0.66576	validation_1-rmse:0.98326
# [16]	validation_0-rmse:0.62992	validation_1-rmse:0.98551
# [17]	validation_0-rmse:0.58607	validation_1-rmse:0.99469
# [18]	validation_0-rmse:0.55812	validation_1-rmse:1.00178
# [19]	validation_0-rmse:0.53816	validation_1-rmse:1.00314
# [20]	validation_0-rmse:0.52887	validation_1-rmse:1.00618
# [21]	validation_0-rmse:0.49711	validation_1-rmse:0.98345
# [22]	validation_0-rmse:0.47981	validation_1-rmse:0.99043
# [23]	validation_0-rmse:0.46558	validation_1-rmse:0.99535
# [24]	validation_0-rmse:0.45812	validation_1-rmse:1.00437
# [25]	validation_0-rmse:0.43708	validation_1-rmse:0.99530
# [26]	validation_0-rmse:0.42912	validation_1-rmse:1.00172
# [27]	validation_0-rmse:0.42195	validation_1-rmse:1.01258
# [28]	validation_0-rmse:0.40399	validation_1-rmse:1.01331
# [29]	validation_0-rmse:0.40431	validation_1-rmse:1.02233
# [30]	validation_0-rmse:0.39682	validation_1-rmse:1.02503
# [31]	validation_0-rmse:0.37882	validation_1-rmse:1.04286
# [32]	validation_0-rmse:0.37657	validation_1-rmse:1.04306
# [33]	validation_0-rmse:0.37442	validation_1-rmse:1.04466
# [34]	validation_0-rmse:0.36892	validation_1-rmse:1.05251
# [35]	validation_0-rmse:0.36133	validation_1-rmse:1.06274
# [0]	validation_0-rmse:5.38488	validation_1-rmse:6.08285
# [1]	validation_0-rmse:4.45578	validation_1-rmse:5.14005
# [2]	validation_0-rmse:3.71217	validation_1-rmse:4.33546
# [3]	validation_0-rmse:3.10187	validation_1-rmse:3.69544
# [4]	validation_0-rmse:2.62710	validation_1-rmse:3.22919
# [5]	validation_0-rmse:2.21377	validation_1-rmse:2.81744
# [6]	validation_0-rmse:1.88266	validation_1-rmse:2.44944
# ...
# [17]	validation_0-rmse:0.69540	validation_1-rmse:0.80948
# [18]	validation_0-rmse:0.66501	validation_1-rmse:0.82245
# [19]	validation_0-rmse:0.63593	validation_1-rmse:0.80223
# [20]	validation_0-rmse:0.61190	validation_1-rmse:0.80117
# [21]	validation_0-rmse:0.59490	validation_1-rmse:0.80286
# [22]	validation_0-rmse:0.58267	validation_1-rmse:0.80936
# [23]	validation_0-rmse:0.54327	validation_1-rmse:0.81600
# [24]	validation_0-rmse:0.51675	validation_1-rmse:0.81931
# [25]	validation_0-rmse:0.48896	validation_1-rmse:0.81393
# [26]	validation_0-rmse:0.48284	validation_1-rmse:0.81824
# [27]	validation_0-rmse:0.47355	validation_1-rmse:0.83245
# [28]	validation_0-rmse:0.44636	validation_1-rmse:0.82102
# [29]	validation_0-rmse:0.43778	validation_1-rmse:0.82590
# [30]	validation_0-rmse:0.43191	validation_1-rmse:0.82841
# [31]	validation_0-rmse:0.42129	validation_1-rmse:0.82256
# [32]	validation_0-rmse:0.41545	validation_1-rmse:0.82928
# [33]	validation_0-rmse:0.39805	validation_1-rmse:0.83746
# [34]	validation_0-rmse:0.38138	validation_1-rmse:0.84084
# [35]	validation_0-rmse:0.37478	validation_1-rmse:0.83792
# [36]	validation_0-rmse:0.36877	validation_1-rmse:0.84397
# [37]	validation_0-rmse:0.35834	validation_1-rmse:0.85471
# [38]	validation_0-rmse:0.35756	validation_1-rmse:0.85279
# [39]	validation_0-rmse:0.35489	validation_1-rmse:0.85084
# [0]	validation_0-rmse:5.60265	validation_1-rmse:5.71131
# [1]	validation_0-rmse:4.66326	validation_1-rmse:4.76420
# [2]	validation_0-rmse:3.83897	validation_1-rmse:3.94398
# [3]	validation_0-rmse:3.16103	validation_1-rmse:3.23634
# [4]	validation_0-rmse:2.65512	validation_1-rmse:2.75670
# [5]	validation_0-rmse:2.22570	validation_1-rmse:2.32795
# [6]	validation_0-rmse:1.88556	validation_1-rmse:2.10900
# [7]	validation_0-rmse:1.61144	validation_1-rmse:1.87988
# [8]	validation_0-rmse:1.41650	validation_1-rmse:1.68904
# [9]	validation_0-rmse:1.25862	validation_1-rmse:1.51250
# [10]	validation_0-rmse:1.10363	validation_1-rmse:1.36221
# [11]	validation_0-rmse:0.99063	validation_1-rmse:1.34100
# [12]	validation_0-rmse:0.90026	validation_1-rmse:1.26888
# [13]	validation_0-rmse:0.83664	validation_1-rmse:1.21698
# [14]	validation_0-rmse:0.74811	validation_1-rmse:1.18880
# [15]	validation_0-rmse:0.69353	validation_1-rmse:1.16106
# [16]	validation_0-rmse:0.64144	validation_1-rmse:1.11062
# [17]	validation_0-rmse:0.60560	validation_1-rmse:1.10354
# [18]	validation_0-rmse:0.55816	validation_1-rmse:1.12322
# [19]	validation_0-rmse:0.51985	validation_1-rmse:1.12190
# [20]	validation_0-rmse:0.50995	validation_1-rmse:1.11867
# [21]	validation_0-rmse:0.50094	validation_1-rmse:1.12543
# [22]	validation_0-rmse:0.48479	validation_1-rmse:1.09641
# [23]	validation_0-rmse:0.47467	validation_1-rmse:1.09743
# [24]	validation_0-rmse:0.45971	validation_1-rmse:1.07084
# [25]	validation_0-rmse:0.43692	validation_1-rmse:1.06913
# [26]	validation_0-rmse:0.42419	validation_1-rmse:1.06221
# [27]	validation_0-rmse:0.41648	validation_1-rmse:1.07696
# [28]	validation_0-rmse:0.40979	validation_1-rmse:1.08757
# [29]	validation_0-rmse:0.40304	validation_1-rmse:1.09018
# [30]	validation_0-rmse:0.39858	validation_1-rmse:1.09990
# [31]	validation_0-rmse:0.39249	validation_1-rmse:1.09354
# [32]	validation_0-rmse:0.38902	validation_1-rmse:1.08869
# [33]	validation_0-rmse:0.38184	validation_1-rmse:1.08682
# [34]	validation_0-rmse:0.36311	validation_1-rmse:1.09969
# [35]	validation_0-rmse:0.34974	validation_1-rmse:1.09662
# [36]	validation_0-rmse:0.33973	validation_1-rmse:1.10153
# [37]	validation_0-rmse:0.33091	validation_1-rmse:1.09154
# [38]	validation_0-rmse:0.32574	validation_1-rmse:1.09455
# [39]	validation_0-rmse:0.32552	validation_1-rmse:1.09247
# [40]	validation_0-rmse:0.32330	validation_1-rmse:1.08998
# [41]	validation_0-rmse:0.31713	validation_1-rmse:1.09493
# [42]	validation_0-rmse:0.31673	validation_1-rmse:1.09101
# [43]	validation_0-rmse:0.31660	validation_1-rmse:1.08839
# [44]	validation_0-rmse:0.31713	validation_1-rmse:1.09059
# [45]	validation_0-rmse:0.30773	validation_1-rmse:1.09026
# [46]	validation_0-rmse:0.30604	validation_1-rmse:1.09282
# [0]	validation_0-rmse:5.59114	validation_1-rmse:5.31307
# [1]	validation_0-rmse:4.64505	validation_1-rmse:4.33033
# [2]	validation_0-rmse:3.86656	validation_1-rmse:3.56188
# [3]	validation_0-rmse:3.22771	validation_1-rmse:2.90527
# [4]	validation_0-rmse:2.77849	validation_1-rmse:2.52721
# [5]	validation_0-rmse:2.35185	validation_1-rmse:2.11431
# [6]	validation_0-rmse:2.03627	validation_1-rmse:1.85615
# [7]	validation_0-rmse:1.72336	validation_1-rmse:1.60536
# [8]	validation_0-rmse:1.52800	validation_1-rmse:1.42152
# [9]	validation_0-rmse:1.31066	validation_1-rmse:1.28191
# [10]	validation_0-rmse:1.16750	validation_1-rmse:1.16189
# [11]	validation_0-rmse:1.02768	validation_1-rmse:1.07998
# [12]	validation_0-rmse:0.93406	validation_1-rmse:1.06911
# [13]	validation_0-rmse:0.83694	validation_1-rmse:1.04211
# [14]	validation_0-rmse:0.76956	validation_1-rmse:1.03007
# [15]	validation_0-rmse:0.73006	validation_1-rmse:1.00693
# [16]	validation_0-rmse:0.66520	validation_1-rmse:1.03132
# [17]	validation_0-rmse:0.61895	validation_1-rmse:1.03037
# [18]	validation_0-rmse:0.59599	validation_1-rmse:1.05264
# [19]	validation_0-rmse:0.56608	validation_1-rmse:1.04192
# [20]	validation_0-rmse:0.54293	validation_1-rmse:1.05428
# [21]	validation_0-rmse:0.51915	validation_1-rmse:1.05391
# [22]	validation_0-rmse:0.50331	validation_1-rmse:1.05714
# [23]	validation_0-rmse:0.49253	validation_1-rmse:1.05021
# [24]	validation_0-rmse:0.47387	validation_1-rmse:1.05815
# [25]	validation_0-rmse:0.45964	validation_1-rmse:1.04685
# [26]	validation_0-rmse:0.45260	validation_1-rmse:1.05077
# [27]	validation_0-rmse:0.44215	validation_1-rmse:1.05871
# [28]	validation_0-rmse:0.43191	validation_1-rmse:1.05561
# [29]	validation_0-rmse:0.42308	validation_1-rmse:1.04897
# [30]	validation_0-rmse:0.42266	validation_1-rmse:1.05394
# [31]	validation_0-rmse:0.40920	validation_1-rmse:1.07043
# [32]	validation_0-rmse:0.40592	validation_1-rmse:1.07048
# [33]	validation_0-rmse:0.39291	validation_1-rmse:1.06872
# [34]	validation_0-rmse:0.37199	validation_1-rmse:1.07015
# [0]	validation_0-rmse:5.63807	validation_1-rmse:5.15640
# [1]	validation_0-rmse:4.66562	validation_1-rmse:4.20646
# [2]	validation_0-rmse:3.85459	validation_1-rmse:3.45797
# [3]	validation_0-rmse:3.24339	validation_1-rmse:2.89232
# [4]	validation_0-rmse:2.67152	validation_1-rmse:2.37452
# [5]	validation_0-rmse:2.21589	validation_1-rmse:2.02327
# [6]	validation_0-rmse:1.87820	validation_1-rmse:1.75734
# [7]	validation_0-rmse:1.61247	validation_1-rmse:1.51950
# [8]	validation_0-rmse:1.41589	validation_1-rmse:1.38593
# [9]	validation_0-rmse:1.22113	validation_1-rmse:1.31272
# [10]	validation_0-rmse:1.11317	validation_1-rmse:1.22420
# [11]	validation_0-rmse:1.04538	validation_1-rmse:1.18507
# [12]	validation_0-rmse:0.94902	validation_1-rmse:1.17126
# [13]	validation_0-rmse:0.89337	validation_1-rmse:1.15369
# [14]	validation_0-rmse:0.80074	validation_1-rmse:1.16830
# [15]	validation_0-rmse:0.74736	validation_1-rmse:1.14623
# [16]	validation_0-rmse:0.71560	validation_1-rmse:1.16412
# [17]	validation_0-rmse:0.68617	validation_1-rmse:1.15253
# [18]	validation_0-rmse:0.65960	validation_1-rmse:1.14657
# [19]	validation_0-rmse:0.62933	validation_1-rmse:1.15456
# [20]	validation_0-rmse:0.60413	validation_1-rmse:1.15363
# [21]	validation_0-rmse:0.57891	validation_1-rmse:1.13882
# [22]	validation_0-rmse:0.56023	validation_1-rmse:1.11116
# [23]	validation_0-rmse:0.53728	validation_1-rmse:1.12898
# [24]	validation_0-rmse:0.51120	validation_1-rmse:1.13423
# [25]	validation_0-rmse:0.50162	validation_1-rmse:1.15302
# [26]	validation_0-rmse:0.49194	validation_1-rmse:1.15446
# [27]	validation_0-rmse:0.48339	validation_1-rmse:1.16537
# [28]	validation_0-rmse:0.46592	validation_1-rmse:1.16551
# [29]	validation_0-rmse:0.45118	validation_1-rmse:1.14966
# [30]	validation_0-rmse:0.43618	validation_1-rmse:1.14689
# [31]	validation_0-rmse:0.42607	validation_1-rmse:1.15130
# [32]	validation_0-rmse:0.41861	validation_1-rmse:1.17598
# [33]	validation_0-rmse:0.41140	validation_1-rmse:1.18097
# [34]	validation_0-rmse:0.40256	validation_1-rmse:1.19387
# [35]	validation_0-rmse:0.39920	validation_1-rmse:1.19953
# [36]	validation_0-rmse:0.39089	validation_1-rmse:1.22354
# [37]	validation_0-rmse:0.38919	validation_1-rmse:1.21798
# [38]	validation_0-rmse:0.38182	validation_1-rmse:1.21182
# [39]	validation_0-rmse:0.37908	validation_1-rmse:1.21307
# [40]	validation_0-rmse:0.37727	validation_1-rmse:1.20889
# [41]	validation_0-rmse:0.37505	validation_1-rmse:1.21022
# [42]	validation_0-rmse:0.37027	validation_1-rmse:1.22624
# [0]	validation_0-rmse:5.73041	validation_1-rmse:5.03933
# [1]	validation_0-rmse:4.73714	validation_1-rmse:4.07768
# [2]	validation_0-rmse:3.95890	validation_1-rmse:3.42087
# [3]	validation_0-rmse:3.29037	validation_1-rmse:2.84035
# [4]	validation_0-rmse:2.80996	validation_1-rmse:2.43091
# [5]	validation_0-rmse:2.37971	validation_1-rmse:2.08236
# [6]	validation_0-rmse:2.04824	validation_1-rmse:1.80350
# [7]	validation_0-rmse:1.74588	validation_1-rmse:1.67293
# [8]	validation_0-rmse:1.52649	validation_1-rmse:1.55708
# [9]	validation_0-rmse:1.37756	validation_1-rmse:1.50507
# [10]	validation_0-rmse:1.16665	validation_1-rmse:1.41859
# [11]	validation_0-rmse:1.04805	validation_1-rmse:1.35665
# [12]	validation_0-rmse:0.91966	validation_1-rmse:1.30527
# [13]	validation_0-rmse:0.82118	validation_1-rmse:1.29319
# [14]	validation_0-rmse:0.75523	validation_1-rmse:1.26066
# [15]	validation_0-rmse:0.70465	validation_1-rmse:1.23914
# [16]	validation_0-rmse:0.66169	validation_1-rmse:1.23671
# [17]	validation_0-rmse:0.63011	validation_1-rmse:1.25590
# [18]	validation_0-rmse:0.60251	validation_1-rmse:1.27977
# [19]	validation_0-rmse:0.58900	validation_1-rmse:1.27681
# [20]	validation_0-rmse:0.54490	validation_1-rmse:1.26984
# [21]	validation_0-rmse:0.52643	validation_1-rmse:1.27696
# [22]	validation_0-rmse:0.50586	validation_1-rmse:1.27616
# [23]	validation_0-rmse:0.49047	validation_1-rmse:1.27163
# [24]	validation_0-rmse:0.46875	validation_1-rmse:1.28945
# [25]	validation_0-rmse:0.45906	validation_1-rmse:1.29250
# [26]	validation_0-rmse:0.45730	validation_1-rmse:1.27484
# [27]	validation_0-rmse:0.45206	validation_1-rmse:1.27388
# [28]	validation_0-rmse:0.43381	validation_1-rmse:1.26012
# [29]	validation_0-rmse:0.42657	validation_1-rmse:1.26499
# [30]	validation_0-rmse:0.42085	validation_1-rmse:1.27235
# [31]	validation_0-rmse:0.41817	validation_1-rmse:1.27626
# [32]	validation_0-rmse:0.40836	validation_1-rmse:1.27472
# [33]	validation_0-rmse:0.39457	validation_1-rmse:1.28743
# [34]	validation_0-rmse:0.39112	validation_1-rmse:1.29884
# [35]	validation_0-rmse:0.38212	validation_1-rmse:1.31527
# [0]	validation_0-rmse:5.61136	validation_1-rmse:5.39777
# [1]	validation_0-rmse:4.62602	validation_1-rmse:4.36031
# [2]	validation_0-rmse:3.82488	validation_1-rmse:3.53696
# [3]	validation_0-rmse:3.18740	validation_1-rmse:2.94552
# [4]	validation_0-rmse:2.64420	validation_1-rmse:2.48704
# [5]	validation_0-rmse:2.26597	validation_1-rmse:2.13138
# [6]	validation_0-rmse:1.93050	validation_1-rmse:1.83658
# [7]	validation_0-rmse:1.68845	validation_1-rmse:1.62936
# [8]	validation_0-rmse:1.44748	validation_1-rmse:1.41791
# [9]	validation_0-rmse:1.23347	validation_1-rmse:1.24991
# [10]	validation_0-rmse:1.11251	validation_1-rmse:1.20837
# [11]	validation_0-rmse:1.02266	validation_1-rmse:1.12749
# [12]	validation_0-rmse:0.93909	validation_1-rmse:1.06265
# [13]	validation_0-rmse:0.86073	validation_1-rmse:1.01358
# [14]	validation_0-rmse:0.77433	validation_1-rmse:1.00650
# [15]	validation_0-rmse:0.71963	validation_1-rmse:0.96162
# [16]	validation_0-rmse:0.65387	validation_1-rmse:0.98583
# [17]	validation_0-rmse:0.62098	validation_1-rmse:0.98831
# [18]	validation_0-rmse:0.58673	validation_1-rmse:0.96339
# [19]	validation_0-rmse:0.55925	validation_1-rmse:0.95906
# [20]	validation_0-rmse:0.52922	validation_1-rmse:0.99596
# [21]	validation_0-rmse:0.51135	validation_1-rmse:1.00479
# [22]	validation_0-rmse:0.48936	validation_1-rmse:0.97305
# [23]	validation_0-rmse:0.47543	validation_1-rmse:0.95540
# [24]	validation_0-rmse:0.45207	validation_1-rmse:0.96528
# [25]	validation_0-rmse:0.44046	validation_1-rmse:0.95840
# [26]	validation_0-rmse:0.43012	validation_1-rmse:0.96483
# [27]	validation_0-rmse:0.42131	validation_1-rmse:0.96764
# [28]	validation_0-rmse:0.41858	validation_1-rmse:0.95962
# [29]	validation_0-rmse:0.41044	validation_1-rmse:0.95723
# [30]	validation_0-rmse:0.40501	validation_1-rmse:0.97248
# [31]	validation_0-rmse:0.39263	validation_1-rmse:0.97444
# [32]	validation_0-rmse:0.38804	validation_1-rmse:0.97072
# [33]	validation_0-rmse:0.38277	validation_1-rmse:0.98181
# [34]	validation_0-rmse:0.36550	validation_1-rmse:0.99351
# [35]	validation_0-rmse:0.36163	validation_1-rmse:0.99566
# [36]	validation_0-rmse:0.34876	validation_1-rmse:0.99260
# [37]	validation_0-rmse:0.34630	validation_1-rmse:0.98871
# [38]	validation_0-rmse:0.34513	validation_1-rmse:0.98729
# [39]	validation_0-rmse:0.33807	validation_1-rmse:0.99377
# [40]	validation_0-rmse:0.33880	validation_1-rmse:0.99296
# [41]	validation_0-rmse:0.32434	validation_1-rmse:0.98895
# [42]	validation_0-rmse:0.32060	validation_1-rmse:0.99024
# [43]	validation_0-rmse:0.31808	validation_1-rmse:0.98457
# [0]	validation_0-rmse:5.51081	validation_1-rmse:6.16805
# [1]	validation_0-rmse:4.54517	validation_1-rmse:5.21748
# [2]	validation_0-rmse:3.74164	validation_1-rmse:4.39944
# [3]	validation_0-rmse:3.11322	validation_1-rmse:3.78228
# [4]	validation_0-rmse:2.61644	validation_1-rmse:3.31596
# [5]	validation_0-rmse:2.20832	validation_1-rmse:2.88282
# [6]	validation_0-rmse:1.89671	validation_1-rmse:2.50975
# [7]	validation_0-rmse:1.63137	validation_1-rmse:2.21625
# [8]	validation_0-rmse:1.43999	validation_1-rmse:2.03000
# [9]	validation_0-rmse:1.25662	validation_1-rmse:1.86946
# [10]	validation_0-rmse:1.12357	validation_1-rmse:1.70851
# [11]	validation_0-rmse:1.01336	validation_1-rmse:1.60782
# [12]	validation_0-rmse:0.91470	validation_1-rmse:1.48026
# [13]	validation_0-rmse:0.81040	validation_1-rmse:1.37422
# [14]	validation_0-rmse:0.75963	validation_1-rmse:1.33671
# [15]	validation_0-rmse:0.70652	validation_1-rmse:1.26832
# [16]	validation_0-rmse:0.69023	validation_1-rmse:1.26110
# [17]	validation_0-rmse:0.63641	validation_1-rmse:1.21084
# [18]	validation_0-rmse:0.60257	validation_1-rmse:1.17890
# [19]	validation_0-rmse:0.56873	validation_1-rmse:1.15434
# [20]	validation_0-rmse:0.54692	validation_1-rmse:1.14774
# [21]	validation_0-rmse:0.53434	validation_1-rmse:1.13988
# [22]	validation_0-rmse:0.52565	validation_1-rmse:1.13832
# [23]	validation_0-rmse:0.49178	validation_1-rmse:1.10505
# [24]	validation_0-rmse:0.47824	validation_1-rmse:1.12766
# [25]	validation_0-rmse:0.44269	validation_1-rmse:1.10105
# [26]	validation_0-rmse:0.43508	validation_1-rmse:1.09850
# [27]	validation_0-rmse:0.42094	validation_1-rmse:1.09685
# [28]	validation_0-rmse:0.41084	validation_1-rmse:1.08620
# [29]	validation_0-rmse:0.40578	validation_1-rmse:1.09049
# [30]	validation_0-rmse:0.39792	validation_1-rmse:1.10581
# [31]	validation_0-rmse:0.39413	validation_1-rmse:1.11539
# [32]	validation_0-rmse:0.38542	validation_1-rmse:1.10895
# [33]	validation_0-rmse:0.37959	validation_1-rmse:1.08390
# [34]	validation_0-rmse:0.37155	validation_1-rmse:1.09853
# [35]	validation_0-rmse:0.36449	validation_1-rmse:1.11407
# [36]	validation_0-rmse:0.36036	validation_1-rmse:1.11741
# [37]	validation_0-rmse:0.35016	validation_1-rmse:1.13626
# [38]	validation_0-rmse:0.35197	validation_1-rmse:1.12348
# [39]	validation_0-rmse:0.35184	validation_1-rmse:1.12499
# [40]	validation_0-rmse:0.35006	validation_1-rmse:1.13095
# [41]	validation_0-rmse:0.34845	validation_1-rmse:1.13601
# [42]	validation_0-rmse:0.34519	validation_1-rmse:1.14314
# [43]	validation_0-rmse:0.34389	validation_1-rmse:1.14260
# [44]	validation_0-rmse:0.33292	validation_1-rmse:1.14506
# [45]	validation_0-rmse:0.32914	validation_1-rmse:1.14755
# [46]	validation_0-rmse:0.31934	validation_1-rmse:1.14091
# [47]	validation_0-rmse:0.31557	validation_1-rmse:1.13794
# [48]	validation_0-rmse:0.31631	validation_1-rmse:1.14544
# [49]	validation_0-rmse:0.31285	validation_1-rmse:1.15063
# [50]	validation_0-rmse:0.31284	validation_1-rmse:1.15043
# [51]	validation_0-rmse:0.31361	validation_1-rmse:1.15711
# [52]	validation_0-rmse:0.31211	validation_1-rmse:1.16471

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 29.795, median: 26.0,
#  pred. interval (P(0.025)-P(0.975)): 14.975-51.0,
#  conf. interval (p-value=0.95): 22.509-34.292
# ***
# Aggregate bias statistic:
#  mean: -2.394, median: -2.183,
#  pred. interval (P(0.025)-P(0.975)): -11.789-5.006,
#  conf. interval (p-value=0.95): -4.241--0.444
# ***
# Aggregate RMSE statistic:
#  mean: 1.041, median: 1.044, pred. interval (P(0.025)-P(0.975)): 0.714-1.335,
#  conf. interval (p-value=0.95): 0.971-1.122
# ***
# Aggregate MSE statistic:
#  mean: 1.111, median: 1.09, pred. interval (P(0.025)-P(0.975)): 0.51-1.783,
#  conf. interval (p-value=0.95): 0.949-1.267
# ***
# Aggregate R^2 statistic:
#  mean: 0.54, median: 0.585, pred. interval (P(0.025)-P(0.975)): 0.094-0.778,
#  conf. interval (p-value=0.95): 0.507-0.635
# ***
# Aggregate bias(%) statistic:
#  mean: -0.324, median: -2.183, pred. interval (P(0.025)-P(0.975)): -1.553-0.689,
#  conf. interval (p-value=0.95): -0.595--0.057
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.147, median: 0.147, pred. interval (P(0.025)-P(0.975)): 0.1-0.191,
#  conf. interval (p-value=0.95): 0.136-0.158
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=10, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:5.51596
# [1]	validation_0-rmse:4.57251
# [2]	validation_0-rmse:3.82475
# [3]	validation_0-rmse:3.21654
# [4]	validation_0-rmse:2.68401
# [5]	validation_0-rmse:2.26593
# [6]	validation_0-rmse:1.93705
# [7]	validation_0-rmse:1.66097
# [8]	validation_0-rmse:1.40093
# [9]	validation_0-rmse:1.24411
# [10]	validation_0-rmse:1.06830
# [11]	validation_0-rmse:0.98001
# [12]	validation_0-rmse:0.90560
# [13]	validation_0-rmse:0.82202
# [14]	validation_0-rmse:0.79200
# [15]	validation_0-rmse:0.73727
# [16]	validation_0-rmse:0.68586
# [17]	validation_0-rmse:0.63847
# [18]	validation_0-rmse:0.60480
# [19]	validation_0-rmse:0.58249
# [20]	validation_0-rmse:0.56462
# [21]	validation_0-rmse:0.53870
# [22]	validation_0-rmse:0.51721
# [23]	validation_0-rmse:0.49225
# [24]	validation_0-rmse:0.47562
# [25]	validation_0-rmse:0.45688
# [26]	validation_0-rmse:0.43832
# [27]	validation_0-rmse:0.43287
# [28]	validation_0-rmse:0.41689
# [29]	validation_0-rmse:0.40832
# [30]	validation_0-rmse:0.40833
# [31]	validation_0-rmse:0.40044
# [32]	validation_0-rmse:0.39223
# [33]	validation_0-rmse:0.38976
# [34]	validation_0-rmse:0.38358
# [35]	validation_0-rmse:0.37240
# [36]	validation_0-rmse:0.36646
# [37]	validation_0-rmse:0.36353
# [38]	validation_0-rmse:0.36377
# [39]	validation_0-rmse:0.35021
# [40]	validation_0-rmse:0.34545
# [41]	validation_0-rmse:0.33705
# [42]	validation_0-rmse:0.32562
# [43]	validation_0-rmse:0.32014
# [44]	validation_0-rmse:0.31547
# [45]	validation_0-rmse:0.31018
# [46]	validation_0-rmse:0.30092
# [47]	validation_0-rmse:0.29548
# [48]	validation_0-rmse:0.29415
# [49]	validation_0-rmse:0.29415
# [50]	validation_0-rmse:0.29415
# [51]	validation_0-rmse:0.29437
# [52]	validation_0-rmse:0.29415

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 48

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  0.00
# RMSE: 0.3
# Relative RMSE(%):  0.042
# MSE: 0.1
# R square: 96.8%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.543
# a1: 0.923
# R^2: 0.970
# Uncertainty
# a0: 0.54+/-0.12
# a1: 0.923+/-0.016

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=1) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
