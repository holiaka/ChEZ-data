# %% [markdown]
# # *+Processing with CHM & RN & biomass data of other authors+*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25 idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167  0.050549
# 1           3600       8.189          15100  ...   0.040919  0.048889
# 2           4360       8.380          14600  ...   0.042397  0.050463
# 3           3420       8.137          12700  ...   0.043719  0.052974
# 4           2200       7.696          12100  ...   0.040659  0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX  idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966    0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602    0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265    0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465    0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420    0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 159 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX'])
            


# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0       4.8122           1.7630               -0.3147           -0.1590
# 1       5.7589           2.4570               -0.2485            0.3429
# 2       5.8464           2.5153               -0.1054            0.5493
# 3       5.7526           2.6304               -0.0834            0.3900
# 4       5.9480           2.6748                0.0000            0.5715
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX
# 0             -2.4418         1.9125     0.85    12.233545   19.097736
# 1             -0.1997         2.6319     1.00    14.964220   17.704655
# 2             -0.2144         2.7020     1.00    15.329449   17.559893
# 3             -0.3510         2.7763     0.97    15.392742   20.676994
# 4             -0.3711         2.8314     1.00    17.944009   21.851387

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
# dtypes: float64(9)
# memory usage: 7.4 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["Gs_cub_m", "M_stem_kg_m2"].describe()
# Out:
# /tmp/ipykernel_44556/594647310.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_specias"])["Gs_cub_m", "M_stem_kg_m2"].describe()
#                  Gs_cub_m                                               \
#                     count        mean         std    min    25%    50%
# Dominant_specias
# Alder                 4.0  380.250000  155.784841  199.0  283.0  386.5
# Aspen                 1.0  148.000000         NaN  148.0  148.0  148.0
# Birch                23.0  135.304348   73.156392   11.0   94.0  138.0
# Oak                   3.0  236.000000   77.504839  158.0  197.5  237.0
# Pine                 71.0  263.281690  185.083625    2.0   97.0  281.0
# Spruce                1.0  619.000000         NaN  619.0  619.0  619.0
#
#                                 M_stem_kg_m2                              \
#                      75%    max        count       mean       std    min
# Dominant_specias
# Alder             483.75  549.0          4.0  16.170000  5.186990   9.90
# Aspen             148.00  148.0          1.0   6.650000       NaN   6.65
# Birch             197.00  280.0         23.0   6.809130  3.677786   0.84
# Oak               275.00  313.0          3.0  13.513333  4.888725   9.59
# Pine              394.00  671.0         71.0  10.550000  7.252887   0.05
# Spruce            619.00  619.0          1.0  23.830000       NaN  23.83
#
#
#                       25%    50%      75%    max
# Dominant_specias
# Alder             12.9225  17.03  20.2775  20.72
# Aspen              6.6500   6.65   6.6500   6.65
# Birch              4.7650   6.19   9.7400  15.47
# Oak               10.7750  11.96  15.4750  18.99
# Pine               3.4400  11.34  16.2250  25.04
# Spruce            23.8300  23.83  23.8300  23.83

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000         103.00000
# mean      4.969534         1.827923             -0.239481           0.05436
# std       1.323782         1.325853              0.893398           0.66008
# min       0.693100        -2.995700             -3.912000          -1.55590
# 25%       4.672800         1.588100             -0.335500          -0.20955
# 50%       5.337500         2.286500             -0.040800           0.24450
# 75%       5.908100         2.730800              0.190600           0.49195
# max       6.508800         3.220500              1.654400           1.41220
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.021247       2.095454    0.808738    13.045021   17.907784
# std              0.803748       1.079203    0.276653     6.609366    7.523377
# min             -2.918800      -0.798500    0.090000     1.293138    2.733019
# 25%             -1.629700       1.801400    0.745000     8.206727   11.615798
# 50%             -0.719500       2.458700    0.960000    13.072916   18.269344
# 75%             -0.358800       2.862800    1.000000    17.432255   22.751595
# max              0.114200       3.366600    1.000000    28.916548   36.355442

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX'])
y = pd.DataFrame(select, columns= ['ln_M_stem_kg_m2'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX
# 0     0.85    12.233545   19.097736
# 1     1.00    14.964220   17.704655
# 2     1.00    15.329449   17.559893
# 3     0.97    15.392742   20.676994
# 4     1.00    17.944009   21.851387

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_stem_kg_m2
# 0           1.7630
# 1           2.4570
# 2           2.5153
# 3           2.6304
# 4           2.6748

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.8411642860552302, 0.8609200714019554, 0.8581934491154541]
#     Mean: 0.853
#     Std: 0.009
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.40625119 0.49856165 0.69942613]
#     Mean: 0.535
#     Std: 0.122
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.30503974657331195, 0.3901093504337703, 0.2422958874996971]
#     Mean: 0.312
#     Std: 0.061
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.881 (std: 0.059)
# Parameters: {'colsample_bytree': 0.8565852435738817, 'gamma': 0.12940676640076693, 'learning_rate': 0.029546354081746842, 'max_depth': 3, 'n_estimators': 189, 'subsample': 0.3060599314998912}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.31248207, 0.25468712, 0.44095802, ..., 0.88422651, 0.37964506,
#        0.56501741]), 'std_fit_time': array([0.10802308, 0.01515404, 0.01687022, ..., 0.43345656, 0.0260491 ,
#        0.03609487]), 'mean_score_time': array([0.00604596, 0.00600343, 0.00727148, ..., 0.00926485, 0.00924549,
#        0.00913477]), 'std_score_time': array([2.00791909e-04, 1.91625210e-04, 2.65851590e-03, ...,
#        2.28583897e-04, 2.96763834e-04, 8.71840381e-05]), 'param_colsample_bytree': masked_array(data=[0.5689857389725144, 0.7887581220636647,
#                    0.9269921532918489, ..., 0.19294094411179352,
#                    0.5016968927125156, 0.08482134984329665],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.43457917483374786, 0.21496693993553811,
#                    0.46938935318547353, ..., 0.4127051242475305,
#                    0.3612363399262743, 0.19591489428319997],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.012353572637762301, 0.14257734150258494,
#                    0.26097547742790134, ..., 0.05189979685141027,
#                    0.21792697606532993, 0.059133555869960636],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[4, 4, 3, ..., 3, 4, 2],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[98, 96, 180, ..., 159, 88, 134],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.9273244875025106, 0.6717876266406961,
#                    0.42582726189031816, ..., 0.6183737656284052,
#                    0.8769421958011909, 0.47049843643492106],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.5689857389725144, 'gamma': 0.43457917483374786, 'learning_rate': 0.012353572637762301, 'max_depth': 4, 'n_estimators': 98, 'subsample': 0.9273244875025106}, {'colsample_bytree': 0.7887581220636647, 'gamma': 0.21496693993553811, 'learning_rate': 0.14257734150258494, 'max_depth': 4, 'n_estimators': 96, 'subsample': 0.6717876266406961}, {'colsample_bytree': 0.9269921532918489, 'gamma': 0.46938935318547353, 'learning_rate': 0.26097547742790134, 'max_depth': 3, 'n_estimators': 180, 'subsample': 0.42582726189031816}, {'colsample_bytree': 0.7153072094736724, 'gamma': 0.11381701473667377, 'learning_rate': 0.11847854609693766, 'max_depth': 3, 'n_estimators': 148, 'subsample': 0.6995522304604389}, {'colsample_bytree': 0.7598832201593521, 'gamma': 0.4751230031259786, 'learning_rate': 0.3027423267361666, 'max_depth': 3, 'n_estimators': 65, 'subsample': 0.32060379976159953}, {'colsample_bytree': 0.8878715706066166, 'gamma': 0.29081051025139387, 'learning_rate': 0.2681910147454616, 'max_depth': 4, 'n_estimators': 159, 'subsample': 0.7390016960612598}, {'colsample_bytree': 0.4961628296750947, 'gamma': 0.24826359523410513, 'learning_rate': 0.09713938218479116, 'max_depth': 4, 'n_estimators': 154, 'subsample': 0.7766952965257121}, {'colsample_bytree': 0.7582744024756068, 'gamma': 0.21686717305866282, 'learning_rate': 0.1545816131764654, 'max_depth': 2, 'n_estimators': 109, 'subsample': 0.8742053754049255}, {'colsample_bytree': 0.9041607051722285, 'gamma': 0.38141478370766796, 'learning_rate': 0.2985983231973593, 'max_depth': 4, 'n_estimators': 87, 'subsample': 0.4351979842053728}, {'colsample_bytree': 0.46590804338450614, 'gamma': 0.12886975998996736, 'learning_rate': 0.12213555884034356, 'max_depth': 2, 'n_estimators': 197, 'subsample': 0.6785311246437753}, {'colsample_bytree': 0.7323097712788537, 'gamma': 0.09163775402878294, 'lear
#        0.95937838]), 'split1_train_score': array([0.70351862, 0.97597504, 0.9662225 , ..., 0.96147193, 0.96616243,
#        0.96348219]), 'split2_train_score': array([0.72624426, 0.9780303 , 0.96978328, ..., 0.95960456, 0.96511136,
#        0.95749048]), 'split3_train_score': array([0.72734877, 0.98023766, 0.96518071, ..., 0.95891333, 0.96380042,
#        0.95648777]), 'split4_train_score': array([0.72218355, 0.98391756, 0.97239765, ..., 0.96655688, 0.96727233,
#        0.96805358]), 'mean_train_score': array([0.72114463, 0.97929709, 0.96795064, ..., 0.96219155, 0.96690888,
#        0.96097848]), 'std_train_score': array([0.00899074, 0.00267654, 0.0027191 , ..., 0.00289618, 0.00288292,
#        0.00427127])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.8565852435738817
# Gamma: 0.12940676640076693
# Learning_rate: 0.029546354081746842
# Max_depth: 3
# N_estimators: 189
# Subsample: 0.3060599314998912

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:1.84876	validation_1-rmse:1.70705
# [1]	validation_0-rmse:1.79960	validation_1-rmse:1.66062
# [2]	validation_0-rmse:1.74987	validation_1-rmse:1.61253
# [3]	validation_0-rmse:1.70567	validation_1-rmse:1.57067
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.66404	validation_1-rmse:1.53094
# [5]	validation_0-rmse:1.62064	validation_1-rmse:1.48660
# [6]	validation_0-rmse:1.58111	validation_1-rmse:1.44674
# [7]	validation_0-rmse:1.54133	validation_1-rmse:1.40631
# [8]	validation_0-rmse:1.50448	validation_1-rmse:1.37086
# [9]	validation_0-rmse:1.46966	validation_1-rmse:1.33927
# [10]	validation_0-rmse:1.43381	validation_1-rmse:1.30100
# [11]	validation_0-rmse:1.39996	validation_1-rmse:1.26641
# [12]	validation_0-rmse:1.36463	validation_1-rmse:1.23503
# [13]	validation_0-rmse:1.33419	validation_1-rmse:1.20306
# [14]	validation_0-rmse:1.30423	validation_1-rmse:1.17183
# [15]	validation_0-rmse:1.27602	validation_1-rmse:1.14284
# [16]	validation_0-rmse:1.24493	validation_1-rmse:1.11360
# [17]	validation_0-rmse:1.21285	validation_1-rmse:1.08215
# [18]	validation_0-rmse:1.18494	validation_1-rmse:1.05575
# [19]	validation_0-rmse:1.15905	validation_1-rmse:1.03223
# [20]	validation_0-rmse:1.13230	validation_1-rmse:1.01025
# [21]	validation_0-rmse:1.10832	validation_1-rmse:0.98564
# [22]	validation_0-rmse:1.08282	validation_1-rmse:0.96098
# [23]	validation_0-rmse:1.05749	validation_1-rmse:0.93639
# [24]	validation_0-rmse:1.03020	validation_1-rmse:0.91056
# [25]	validation_0-rmse:1.00754	validation_1-rmse:0.88793
# [26]	validation_0-rmse:0.98678	validation_1-rmse:0.86494
# [27]	validation_0-rmse:0.96595	validation_1-rmse:0.84593
# [28]	validation_0-rmse:0.94620	validation_1-rmse:0.82812
# [29]	validation_0-rmse:0.92612	validation_1-rmse:0.80907
# [30]	validation_0-rmse:0.90654	validation_1-rmse:0.79270
# [31]	validation_0-rmse:0.88895	validation_1-rmse:0.77538
# [32]	validation_0-rmse:0.86777	validation_1-rmse:0.75279
# [33]	validation_0-rmse:0.84978	validation_1-rmse:0.73465
# [34]	validation_0-rmse:0.83390	validation_1-rmse:0.71838
# [35]	validation_0-rmse:0.82033	validation_1-rmse:0.70386
# [36]	validation_0-rmse:0.80573	validation_1-rmse:0.68830
# [37]	validation_0-rmse:0.79262	validation_1-rmse:0.67435
# [38]	validation_0-rmse:0.77587	validation_1-rmse:0.65832
# [39]	validation_0-rmse:0.76043	validation_1-rmse:0.64482
# [40]	validation_0-rmse:0.74843	validation_1-rmse:0.63457
# [41]	validation_0-rmse:0.73310	validation_1-rmse:0.62050
# [42]	validation_0-rmse:0.72078	validation_1-rmse:0.60760
# [86]	validation_0-rmse:0.42321	validation_1-rmse:0.21406
# [87]	validation_0-rmse:0.42150	validation_1-rmse:0.21255
# [88]	validation_0-rmse:0.41887	validation_1-rmse:0.21156
# [89]	validation_0-rmse:0.41706	validation_1-rmse:0.20932
# [90]	validation_0-rmse:0.41590	validation_1-rmse:0.20754
# [91]	validation_0-rmse:0.41321	validation_1-rmse:0.20678
# [92]	validation_0-rmse:0.41033	validation_1-rmse:0.20412
# [93]	validation_0-rmse:0.40784	validation_1-rmse:0.20338
# [94]	validation_0-rmse:0.40742	validation_1-rmse:0.20294
# [95]	validation_0-rmse:0.40580	validation_1-rmse:0.20204
# [96]	validation_0-rmse:0.40436	validation_1-rmse:0.20110
# [97]	validation_0-rmse:0.40368	validation_1-rmse:0.20134
# [98]	validation_0-rmse:0.39966	validation_1-rmse:0.20217
# [99]	validation_0-rmse:0.39760	validation_1-rmse:0.20205
# [100]	validation_0-rmse:0.39310	validation_1-rmse:0.20190
# [101]	validation_0-rmse:0.38765	validation_1-rmse:0.20121
# [102]	validation_0-rmse:0.38607	validation_1-rmse:0.20124
# [103]	validation_0-rmse:0.38253	validation_1-rmse:0.20132
# [104]	validation_0-rmse:0.38160	validation_1-rmse:0.20093
# [105]	validation_0-rmse:0.37901	validation_1-rmse:0.20016
# [106]	validation_0-rmse:0.37724	validation_1-rmse:0.20029
# [107]	validation_0-rmse:0.37664	validation_1-rmse:0.20077
# [108]	validation_0-rmse:0.37442	validation_1-rmse:0.19980
# [109]	validation_0-rmse:0.37394	validation_1-rmse:0.19874
# [110]	validation_0-rmse:0.37099	validation_1-rmse:0.19866
# [111]	validation_0-rmse:0.36785	validation_1-rmse:0.19952
# [112]	validation_0-rmse:0.36464	validation_1-rmse:0.19997
# [113]	validation_0-rmse:0.36330	validation_1-rmse:0.19996
# [114]	validation_0-rmse:0.36251	validation_1-rmse:0.19959
# [115]	validation_0-rmse:0.35858	validation_1-rmse:0.19946
# [116]	validation_0-rmse:0.35746	validation_1-rmse:0.19988
# [117]	validation_0-rmse:0.35498	validation_1-rmse:0.20019
# [118]	validation_0-rmse:0.35397	validation_1-rmse:0.20023
# [119]	validation_0-rmse:0.35223	validation_1-rmse:0.20057
# [120]	validation_0-rmse:0.34800	validation_1-rmse:0.20135
# [121]	validation_0-rmse:0.34583	validation_1-rmse:0.20173
# [122]	validation_0-rmse:0.34077	validation_1-rmse:0.20180
# [123]	validation_0-rmse:0.33924	validation_1-rmse:0.20139
# [124]	validation_0-rmse:0.33799	validation_1-rmse:0.20154
# [125]	validation_0-rmse:0.33404	validation_1-rmse:0.20183
# [126]	validation_0-rmse:0.33373	validation_1-rmse:0.20220
# [127]	validation_0-rmse:0.33206	validation_1-rmse:0.20181
# [128]	validation_0-rmse:0.33078	validation_1-rmse:0.20294
# [129]	validation_0-rmse:0.33009	validation_1-rmse:0.20132
# [0]	validation_0-rmse:1.76766	validation_1-rmse:2.03176
# [1]	validation_0-rmse:1.72599	validation_1-rmse:1.98402
# [2]	validation_0-rmse:1.68546	validation_1-rmse:1.93927
# [3]	validation_0-rmse:1.64565	validation_1-rmse:1.89405
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
#
# [46]	validation_0-rmse:0.67823	validation_1-rmse:0.60044
# [47]	validation_0-rmse:0.66746	validation_1-rmse:0.58776
# [48]	validation_0-rmse:0.65644	validation_1-rmse:0.57630
# [49]	validation_0-rmse:0.64554	validation_1-rmse:0.56239
# [50]	validation_0-rmse:0.63575	validation_1-rmse:0.55211
# [51]	validation_0-rmse:0.62419	validation_1-rmse:0.54093
# [52]	validation_0-rmse:0.61731	validation_1-rmse:0.53078
# [53]	validation_0-rmse:0.60815	validation_1-rmse:0.52178
# [54]	validation_0-rmse:0.59838	validation_1-rmse:0.51099
# ...
# [10]	validation_0-rmse:1.45224	validation_1-rmse:1.34742
# [11]	validation_0-rmse:1.42125	validation_1-rmse:1.32307
# [12]	validation_0-rmse:1.38737	validation_1-rmse:1.29757
# [13]	validation_0-rmse:1.35493	validation_1-rmse:1.27006
# [14]	validation_0-rmse:1.32091	validation_1-rmse:1.23523
# [15]	validation_0-rmse:1.29465	validation_1-rmse:1.20744
# [16]	validation_0-rmse:1.26378	validation_1-rmse:1.17496
# [17]	validation_0-rmse:1.23418	validation_1-rmse:1.14721
# [18]	validation_0-rmse:1.20835	validation_1-rmse:1.12349
# [19]	validation_0-rmse:1.17984	validation_1-rmse:1.09910
# [20]	validation_0-rmse:1.14985	validation_1-rmse:1.06602
# [21]	validation_0-rmse:1.12787	validation_1-rmse:1.04634
# [22]	validation_0-rmse:1.10056	validation_1-rmse:1.01812
# [23]	validation_0-rmse:1.07781	validation_1-rmse:0.99426
# [24]	validation_0-rmse:1.05376	validation_1-rmse:0.97360
# [25]	validation_0-rmse:1.03065	validation_1-rmse:0.95615
# [26]	validation_0-rmse:1.00619	validation_1-rmse:0.93038
# [27]	validation_0-rmse:0.98431	validation_1-rmse:0.91420
# [28]	validation_0-rmse:0.96322	validation_1-rmse:0.89251
# [29]	validation_0-rmse:0.94074	validation_1-rmse:0.87531
# [30]	validation_0-rmse:0.92187	validation_1-rmse:0.85845
# [31]	validation_0-rmse:0.90359	validation_1-rmse:0.83988
# [32]	validation_0-rmse:0.88512	validation_1-rmse:0.82731
# [33]	validation_0-rmse:0.86340	validation_1-rmse:0.81099
# [34]	validation_0-rmse:0.84815	validation_1-rmse:0.79977
# [35]	validation_0-rmse:0.83041	validation_1-rmse:0.78723
# [36]	validation_0-rmse:0.81187	validation_1-rmse:0.76692
# [37]	validation_0-rmse:0.79449	validation_1-rmse:0.75416
# [38]	validation_0-rmse:0.78033	validation_1-rmse:0.74248
# [39]	validation_0-rmse:0.76223	validation_1-rmse:0.72225
# [40]	validation_0-rmse:0.74704	validation_1-rmse:0.70432
# [41]	validation_0-rmse:0.73278	validation_1-rmse:0.69401
# [42]	validation_0-rmse:0.72077	validation_1-rmse:0.68371
# [43]	validation_0-rmse:0.70579	validation_1-rmse:0.67492
# [44]	validation_0-rmse:0.69289	validation_1-rmse:0.66471
# [45]	validation_0-rmse:0.68224	validation_1-rmse:0.65619
# [46]	validation_0-rmse:0.66837	validation_1-rmse:0.63984
# [47]	validation_0-rmse:0.65336	validation_1-rmse:0.63257
# [48]	validation_0-rmse:0.64248	validation_1-rmse:0.62612
# [49]	validation_0-rmse:0.62995	validation_1-rmse:0.61702
# [50]	validation_0-rmse:0.61999	validation_1-rmse:0.60973
# [51]	validation_0-rmse:0.60639	validation_1-rmse:0.60461
# [52]	validation_0-rmse:0.59837	validation_1-rmse:0.59866
# [53]	validation_0-rmse:0.58678	validation_1-rmse:0.59358
# [54]	validation_0-rmse:0.57480	validation_1-rmse:0.58995
# [55]	validation_0-rmse:0.56517	validation_1-rmse:0.58629
# [56]	validation_0-rmse:0.55762	validation_1-rmse:0.58169
# [57]	validation_0-rmse:0.55098	validation_1-rmse:0.57330
# [58]	validation_0-rmse:0.54402	validation_1-rmse:0.56508
# [59]	validation_0-rmse:0.53338	validation_1-rmse:0.55927
# [60]	validation_0-rmse:0.52545	validation_1-rmse:0.55304
# [61]	validation_0-rmse:0.51663	validation_1-rmse:0.54996
# [62]	validation_0-rmse:0.51133	validation_1-rmse:0.54729
# [63]	validation_0-rmse:0.50625	validation_1-rmse:0.54376
# [64]	validation_0-rmse:0.50029	validation_1-rmse:0.53862
# [65]	validation_0-rmse:0.49564	validation_1-rmse:0.53174
# [66]	validation_0-rmse:0.48736	validation_1-rmse:0.52821
# [67]	validation_0-rmse:0.48174	validation_1-rmse:0.51955
# [68]	validation_0-rmse:0.47724	validation_1-rmse:0.51736
# [69]	validation_0-rmse:0.47202	validation_1-rmse:0.51387
# [70]	validation_0-rmse:0.46716	validation_1-rmse:0.50679
# [71]	validation_0-rmse:0.46125	validation_1-rmse:0.50204
# [72]	validation_0-rmse:0.45785	validation_1-rmse:0.50045
# [73]	validation_0-rmse:0.45242	validation_1-rmse:0.49363
# [74]	validation_0-rmse:0.44447	validation_1-rmse:0.49108
# [75]	validation_0-rmse:0.43863	validation_1-rmse:0.48897
# [76]	validation_0-rmse:0.43489	validation_1-rmse:0.48805
# [77]	validation_0-rmse:0.43073	validation_1-rmse:0.48280
# [78]	validation_0-rmse:0.42552	validation_1-rmse:0.48006
# [79]	validation_0-rmse:0.42005	validation_1-rmse:0.47278
# [80]	validation_0-rmse:0.41444	validation_1-rmse:0.47130
# [81]	validation_0-rmse:0.41033	validation_1-rmse:0.47001
# [82]	validation_0-rmse:0.40746	validation_1-rmse:0.46655
# [83]	validation_0-rmse:0.40196	validation_1-rmse:0.46505
# [84]	validation_0-rmse:0.39657	validation_1-rmse:0.46404
# [85]	validation_0-rmse:0.39202	validation_1-rmse:0.46438
# [86]	validation_0-rmse:0.38844	validation_1-rmse:0.46509
# [87]	validation_0-rmse:0.38599	validation_1-rmse:0.46291
# [88]	validation_0-rmse:0.38449	validation_1-rmse:0.45984
# [89]	validation_0-rmse:0.38064	validation_1-rmse:0.46006
# [90]	validation_0-rmse:0.37761	validation_1-rmse:0.45743
# [91]	validation_0-rmse:0.37433	validation_1-rmse:0.45534
# [92]	validation_0-rmse:0.36998	validation_1-rmse:0.45026
# [93]	validation_0-rmse:0.36618	validation_1-rmse:0.44884
# [94]	validation_0-rmse:0.36284	validation_1-rmse:0.44859
# [95]	validation_0-rmse:0.36041	validation_1-rmse:0.44919
# [96]	validation_0-rmse:0.35805	validation_1-rmse:0.44846
# [97]	validation_0-rmse:0.35652	validation_1-rmse:0.44582
# [98]	validation_0-rmse:0.35342	validation_1-rmse:0.44558
# [99]	validation_0-rmse:0.35195	validation_1-rmse:0.44543
# [100]	validation_0-rmse:0.34964	validation_1-rmse:0.44621
# [101]	validation_0-rmse:0.34789	validation_1-rmse:0.44639
# [102]	validation_0-rmse:0.34476	validation_1-rmse:0.44620
# [103]	validation_0-rmse:0.34170	validation_1-rmse:0.44665
# [104]	validation_0-rmse:0.34070	validation_1-rmse:0.44742
# [105]	validation_0-rmse:0.33738	validation_1-rmse:0.44334
# [106]	validation_0-rmse:0.33619	validation_1-rmse:0.44375
# [107]	validation_0-rmse:0.33513	validation_1-rmse:0.44403
# [108]	validation_0-rmse:0.33106	validation_1-rmse:0.44558
# [109]	validation_0-rmse:0.32908	validation_1-rmse:0.44686
# [110]	validation_0-rmse:0.32824	validation_1-rmse:0.44725
# [111]	validation_0-rmse:0.32584	validation_1-rmse:0.44540
# [112]	validation_0-rmse:0.32517	validation_1-rmse:0.44585
# [113]	validation_0-rmse:0.32478	validation_1-rmse:0.44303
# [114]	validation_0-rmse:0.32312	validation_1-rmse:0.44223
# [115]	validation_0-rmse:0.32219	validation_1-rmse:0.44229
# [116]	validation_0-rmse:0.32089	validation_1-rmse:0.44294
# [117]	validation_0-rmse:0.32046	validation_1-rmse:0.44290
# [118]	validation_0-rmse:0.31934	validation_1-rmse:0.44312
# [119]	validation_0-rmse:0.31794	validation_1-rmse:0.44301
# [120]	validation_0-rmse:0.31745	validation_1-rmse:0.44322
# [121]	validation_0-rmse:0.31561	validation_1-rmse:0.44054
# [122]	validation_0-rmse:0.31417	validation_1-rmse:0.44100
# [123]	validation_0-rmse:0.31306	validation_1-rmse:0.44240
# [124]	validation_0-rmse:0.31240	validation_1-rmse:0.44079
# [125]	validation_0-rmse:0.31275	validation_1-rmse:0.44113
# [126]	validation_0-rmse:0.31288	validation_1-rmse:0.44140
# [127]	validation_0-rmse:0.31186	validation_1-rmse:0.44084
# [128]	validation_0-rmse:0.31083	validation_1-rmse:0.44031
# [129]	validation_0-rmse:0.31044	validation_1-rmse:0.44041
# [130]	validation_0-rmse:0.30954	validation_1-rmse:0.43968
# [131]	validation_0-rmse:0.30863	validation_1-rmse:0.43938
# [132]	validation_0-rmse:0.30716	validation_1-rmse:0.44064
# [133]	validation_0-rmse:0.30587	validation_1-rmse:0.43790
# [134]	validation_0-rmse:0.30460	validation_1-rmse:0.43813
# [135]	validation_0-rmse:0.30271	validation_1-rmse:0.43915
# [136]	validation_0-rmse:0.30265	validation_1-rmse:0.43947
# [137]	validation_0-rmse:0.30095	validation_1-rmse:0.44067
# [138]	validation_0-rmse:0.29988	validation_1-rmse:0.44138
# [139]	validation_0-rmse:0.29846	validation_1-rmse:0.44071
# [34]	validation_0-rmse:0.84116	validation_1-rmse:0.91652
# [35]	validation_0-rmse:0.82602	validation_1-rmse:0.90321
# [36]	validation_0-rmse:0.80736	validation_1-rmse:0.89231
# [37]	validation_0-rmse:0.79348	validation_1-rmse:0.88142
# [38]	validation_0-rmse:0.77612	validation_1-rmse:0.87072
# [39]	validation_0-rmse:0.75978	validation_1-rmse:0.85851
# [40]	validation_0-rmse:0.74935	validation_1-rmse:0.84802
# [41]	validation_0-rmse:0.73631	validation_1-rmse:0.83315
# [42]	validation_0-rmse:0.72484	validation_1-rmse:0.82380
# [43]	validation_0-rmse:0.71036	validation_1-rmse:0.81235
# [44]	validation_0-rmse:0.70190	validation_1-rmse:0.80313
# [45]	validation_0-rmse:0.69066	validation_1-rmse:0.79058
# [46]	validation_0-rmse:0.67845	validation_1-rmse:0.77867
# [47]	validation_0-rmse:0.67067	validation_1-rmse:0.77145
# [48]	validation_0-rmse:0.65938	validation_1-rmse:0.76053
# [49]	validation_0-rmse:0.64679	validation_1-rmse:0.75126
# [50]	validation_0-rmse:0.63476	validation_1-rmse:0.73867
# [51]	validation_0-rmse:0.62607	validation_1-rmse:0.73118
# [52]	validation_0-rmse:0.61337	validation_1-rmse:0.71675
# [53]	validation_0-rmse:0.60539	validation_1-rmse:0.70993
# [54]	validation_0-rmse:0.59668	validation_1-rmse:0.70446
# [55]	validation_0-rmse:0.58556	validation_1-rmse:0.69946
# [56]	validation_0-rmse:0.57750	validation_1-rmse:0.69035
# [57]	validation_0-rmse:0.56749	validation_1-rmse:0.67961
# [58]	validation_0-rmse:0.55911	validation_1-rmse:0.67078
# [59]	validation_0-rmse:0.55077	validation_1-rmse:0.66779
# [60]	validation_0-rmse:0.53945	validation_1-rmse:0.66413
# [61]	validation_0-rmse:0.53409	validation_1-rmse:0.65819
# [62]	validation_0-rmse:0.52318	validation_1-rmse:0.65410
# [63]	validation_0-rmse:0.51669	validation_1-rmse:0.65078
# [64]	validation_0-rmse:0.51154	validation_1-rmse:0.64653
# [65]	validation_0-rmse:0.50627	validation_1-rmse:0.63931
# [66]	validation_0-rmse:0.50081	validation_1-rmse:0.63455
# [67]	validation_0-rmse:0.49416	validation_1-rmse:0.62956
# [68]	validation_0-rmse:0.48878	validation_1-rmse:0.62397
# [69]	validation_0-rmse:0.48213	validation_1-rmse:0.61786
# [70]	validation_0-rmse:0.47607	validation_1-rmse:0.61747
# [71]	validation_0-rmse:0.47132	validation_1-rmse:0.61463
# [72]	validation_0-rmse:0.46696	validation_1-rmse:0.60893
# [73]	validation_0-rmse:0.46330	validation_1-rmse:0.60659
# [74]	validation_0-rmse:0.45664	validation_1-rmse:0.60283
# [75]	validation_0-rmse:0.44815	validation_1-rmse:0.60256
# [76]	validation_0-rmse:0.44478	validation_1-rmse:0.59856
# [77]	validation_0-rmse:0.43979	validation_1-rmse:0.59500
# [78]	validation_0-rmse:0.43363	validation_1-rmse:0.59298
# [79]	validation_0-rmse:0.43023	validation_1-rmse:0.59036
# [80]	validation_0-rmse:0.42608	validation_1-rmse:0.58509
# [81]	validation_0-rmse:0.42106	validation_1-rmse:0.58118
# [82]	validation_0-rmse:0.41875	validation_1-rmse:0.58067
# [83]	validation_0-rmse:0.41559	validation_1-rmse:0.57816
# [84]	validation_0-rmse:0.41154	validation_1-rmse:0.57341
# [85]	validation_0-rmse:0.40992	validation_1-rmse:0.57144
# [86]	validation_0-rmse:0.40492	validation_1-rmse:0.56914
# [87]	validation_0-rmse:0.40262	validation_1-rmse:0.56811
# [88]	validation_0-rmse:0.39949	validation_1-rmse:0.56606
# [89]	validation_0-rmse:0.39377	validation_1-rmse:0.55814
# [90]	validation_0-rmse:0.39157	validation_1-rmse:0.55896
# [91]	validation_0-rmse:0.38771	validation_1-rmse:0.55943
# [92]	validation_0-rmse:0.38500	validation_1-rmse:0.55790
# [93]	validation_0-rmse:0.38034	validation_1-rmse:0.55627
# [94]	validation_0-rmse:0.37715	validation_1-rmse:0.55291
# [95]	validation_0-rmse:0.37399	validation_1-rmse:0.55188
# [96]	validation_0-rmse:0.37257	validation_1-rmse:0.55053
# [97]	validation_0-rmse:0.37067	validation_1-rmse:0.54877
# [98]	validation_0-rmse:0.36928	validation_1-rmse:0.54775
# [99]	validation_0-rmse:0.36547	validation_1-rmse:0.54566
# [100]	validation_0-rmse:0.36029	validation_1-rmse:0.54743
# [101]	validation_0-rmse:0.35846	validation_1-rmse:0.54710
# [102]	validation_0-rmse:0.35709	validation_1-rmse:0.54535
# [103]	validation_0-rmse:0.35628	validation_1-rmse:0.54412
# [104]	validation_0-rmse:0.35356	validation_1-rmse:0.54310
# [105]	validation_0-rmse:0.35199	validation_1-rmse:0.54278
# [106]	validation_0-rmse:0.34727	validation_1-rmse:0.54540
# [107]	validation_0-rmse:0.34316	validation_1-rmse:0.54839
# [108]	validation_0-rmse:0.34002	validation_1-rmse:0.54804
# [109]	validation_0-rmse:0.33805	validation_1-rmse:0.54747
# [110]	validation_0-rmse:0.33516	validation_1-rmse:0.54970
# [111]	validation_0-rmse:0.33142	validation_1-rmse:0.55250
# [112]	validation_0-rmse:0.32983	validation_1-rmse:0.55221
# [113]	validation_0-rmse:0.32634	validation_1-rmse:0.54661
# [114]	validation_0-rmse:0.32593	validation_1-rmse:0.54639
# [115]	validation_0-rmse:0.32456	validation_1-rmse:0.54739
# [116]	validation_0-rmse:0.32341	validation_1-rmse:0.54636
# [117]	validation_0-rmse:0.32204	validation_1-rmse:0.54496
# [118]	validation_0-rmse:0.32186	validation_1-rmse:0.54479
# [119]	validation_0-rmse:0.32083	validation_1-rmse:0.54457
# [120]	validation_0-rmse:0.31931	validation_1-rmse:0.54503
# [121]	validation_0-rmse:0.31611	validation_1-rmse:0.54817
# [122]	validation_0-rmse:0.31340	validation_1-rmse:0.54582
# [123]	validation_0-rmse:0.31198	validation_1-rmse:0.54339
# [124]	validation_0-rmse:0.30953	validation_1-rmse:0.54703
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 150.03, median: 150.0,
#  pred. interval (P(0.025)-P(0.975)): 94.9-188.0,
#  conf. interval (p-value=0.95): 135.598-164.909
# ***
# Aggregate bias statistic:
#  mean: -0.022, median: -0.26,
#  pred. interval (P(0.025)-P(0.975)): -4.262-4.929,
#  conf. interval (p-value=0.95): -1.242-0.876
# ***
# Aggregate RMSE statistic:
#  mean: 0.424, median: 0.396, pred. interval (P(0.025)-P(0.975)): 0.204-0.756,
#  conf. interval (p-value=0.95): 0.334-0.486
# ***
# Aggregate MSE statistic:
#  mean: 0.206, median: 0.157, pred. interval (P(0.025)-P(0.975)): 0.042-0.571,
#  conf. interval (p-value=0.95): 0.117-0.247
# ***
# Aggregate R^2 statistic:
#  mean: 0.888, median: 0.889, pred. interval (P(0.025)-P(0.975)): 0.771-0.973,
#  conf. interval (p-value=0.95): 0.866-0.914
# ***
# Aggregate bias(%) statistic:
#  mean: 0.089, median: -0.26, pred. interval (P(0.025)-P(0.975)): -2.32-3.391,
#  conf. interval (p-value=0.95): -0.635-0.541
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.248, median: 0.219, pred. interval (P(0.025)-P(0.975)): 0.096-0.536,
#  conf. interval (p-value=0.95): 0.18-0.28
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.82553
# [1]	validation_0-rmse:1.77930
# [2]	validation_0-rmse:1.73387
# [3]	validation_0-rmse:1.68843
# [4]	validation_0-rmse:1.64761
# [5]	validation_0-rmse:1.60666
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:1.56775
# [7]	validation_0-rmse:1.53055
# [8]	validation_0-rmse:1.49742
# [9]	validation_0-rmse:1.46336
# [10]	validation_0-rmse:1.42556
# [11]	validation_0-rmse:1.39257
# [12]	validation_0-rmse:1.36269
# [13]	validation_0-rmse:1.33214
# [14]	validation_0-rmse:1.30218
# [15]	validation_0-rmse:1.27070
# [16]	validation_0-rmse:1.23792
# [17]	validation_0-rmse:1.21066
# [18]	validation_0-rmse:1.18270
# [19]	validation_0-rmse:1.15634
# [20]	validation_0-rmse:1.12821
# [21]	validation_0-rmse:1.10676
# [22]	validation_0-rmse:1.08172
# [23]	validation_0-rmse:1.05852
# [24]	validation_0-rmse:1.03562
# [25]	validation_0-rmse:1.01305
# [26]	validation_0-rmse:0.98968
# [27]	validation_0-rmse:0.96935
# [28]	validation_0-rmse:0.95007
# [29]	validation_0-rmse:0.92920
# [30]	validation_0-rmse:0.90572
# [31]	validation_0-rmse:0.88553
# [32]	validation_0-rmse:0.86863
# [33]	validation_0-rmse:0.85149
# [34]	validation_0-rmse:0.83556
# [35]	validation_0-rmse:0.82110
# [36]	validation_0-rmse:0.80704
# [37]	validation_0-rmse:0.78923
# [38]	validation_0-rmse:0.77065
# [39]	validation_0-rmse:0.75577
# [40]	validation_0-rmse:0.74124
# [41]	validation_0-rmse:0.72638
# [42]	validation_0-rmse:0.71109
# [43]	validation_0-rmse:0.69806
# [44]	validation_0-rmse:0.68612
# [45]	validation_0-rmse:0.67470
# [46]	validation_0-rmse:0.66049
# [47]	validation_0-rmse:0.64839
# [48]	validation_0-rmse:0.63794
# [49]	validation_0-rmse:0.62808
# [50]	validation_0-rmse:0.61615
# [51]	validation_0-rmse:0.60745
# [52]	validation_0-rmse:0.59985
# [53]	validation_0-rmse:0.59012
# [135]	validation_0-rmse:0.31401
# [136]	validation_0-rmse:0.31202
# [137]	validation_0-rmse:0.31198
# [138]	validation_0-rmse:0.31025
# [139]	validation_0-rmse:0.30880
# [140]	validation_0-rmse:0.30596
# [141]	validation_0-rmse:0.30543
# [142]	validation_0-rmse:0.30534
# [143]	validation_0-rmse:0.30364
# [144]	validation_0-rmse:0.30391
# [145]	validation_0-rmse:0.30198
# [146]	validation_0-rmse:0.30158
# [147]	validation_0-rmse:0.30193
# [148]	validation_0-rmse:0.30141
# [149]	validation_0-rmse:0.30140
# [150]	validation_0-rmse:0.30141
# [151]	validation_0-rmse:0.29936
# [152]	validation_0-rmse:0.29782
# [153]	validation_0-rmse:0.29709
# [154]	validation_0-rmse:0.29654
# [155]	validation_0-rmse:0.29699
# [156]	validation_0-rmse:0.29679
# [157]	validation_0-rmse:0.29422
# [158]	validation_0-rmse:0.29289
# [159]	validation_0-rmse:0.29091
# [160]	validation_0-rmse:0.28960
# [161]	validation_0-rmse:0.28916
# [162]	validation_0-rmse:0.28842
# [163]	validation_0-rmse:0.28756
# [164]	validation_0-rmse:0.28580
# [165]	validation_0-rmse:0.28617
# [166]	validation_0-rmse:0.28488
# [167]	validation_0-rmse:0.28461
# [168]	validation_0-rmse:0.28312
# [169]	validation_0-rmse:0.28276
# [170]	validation_0-rmse:0.28233
# [171]	validation_0-rmse:0.28071
# [172]	validation_0-rmse:0.27933
# [173]	validation_0-rmse:0.27809
# [174]	validation_0-rmse:0.27721
# [175]	validation_0-rmse:0.27616
# [176]	validation_0-rmse:0.27492
# [177]	validation_0-rmse:0.27402
# [178]	validation_0-rmse:0.27416
# [179]	validation_0-rmse:0.27391
# [180]	validation_0-rmse:0.27372
# [181]	validation_0-rmse:0.27292
# [182]	validation_0-rmse:0.27291
# [183]	validation_0-rmse:0.27223
# [184]	validation_0-rmse:0.27230
# [185]	validation_0-rmse:0.27156
# [186]	validation_0-rmse:0.27070
# [187]	validation_0-rmse:0.27006
# [188]	validation_0-rmse:0.26845
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 188

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.05
# RMSE: 0.3
# Relative RMSE(%):  0.147
# MSE: 0.1
# R square: 95.9%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.144
# a1: 0.921
# R^2: 0.960
# Uncertainty
# a0: 0.14+/-0.04
# a1: 0.921+/-0.019

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Mstem_XGB_model_without_texture.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Mstem_XGB_model_without_texture.txt")
