# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25  idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167   0.050549
# 1           3600       8.189          15100  ...   0.040919   0.048889
# 2           4360       8.380          14600  ...   0.042397   0.050463
# 3           3420       8.137          12700  ...   0.043719   0.052974
# 4           2200       7.696          12100  ...   0.040659   0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966   0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602   0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265   0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465   0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420   0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 163 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 
                                    'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 
                                    'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75'])

# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           1912            784      -0.73       2.58
# 1       8.189       9.622           2005            818       0.59       2.92
# 2       8.380       9.589           2001            818       0.78       2.88
# 3       8.137       9.449           2040            833       0.52       2.72
# 4       7.696       9.401           1758            717       0.22       2.83
#
#    AEDR_mean  r_MIN  r_MAX      r_MEAN  ...  g_Q25  g_Q50  g_Q75  b_MIN  \
# 0       2.33     13    247  117.308148  ...     95    136    172     10
# 1       2.47     24    234  116.193248  ...     89    136    177     15
# 2       2.44     18    222  118.713846  ...     96    138    178     12
# 3       2.55     15    222  114.468779  ...     89    133    176     10
# 4       2.14      8    227  116.849925  ...     88    132    176     13
#
#    b_MAX      b_MEAN      b_STD  b_Q25  b_Q50  b_Q75
# 0    232   92.565868  35.145074     63     92    120
# 1    191   96.102318  36.135511     66     97    126
# 2    187   97.222011  35.938764     68     97    127
# 3    199   96.135305  35.908361     67     96    127
# 4    207  100.635043  38.062522     69     99    132
#
# [5 rows x 28 columns]

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   r_MIN          103 non-null    int64
#  8   r_MAX          103 non-null    int64
#  9   r_MEAN         103 non-null    float64
#  10  r_STD          103 non-null    float64
#  11  r_Q25          103 non-null    int64
#  12  r_Q50          103 non-null    int64
#  13  r_Q75          103 non-null    int64
#  14  g_MIN          103 non-null    int64
#  15  g_MAX          103 non-null    int64
#  16  g_MEAN         103 non-null    float64
#  17  g_STD          103 non-null    float64
#  18  g_Q25          103 non-null    int64
#  19  g_Q50          103 non-null    int64
#  20  g_Q75          103 non-null    int64
#  21  b_MIN          103 non-null    int64
#  22  b_MAX          103 non-null    int64
#  23  b_MEAN         103 non-null    float64
#  24  b_STD          103 non-null    float64
#  25  b_Q25          103 non-null    int64
#  26  b_Q50          103 non-null    int64
#  27  b_Q75          103 non-null    int64
# dtypes: float64(11), int64(17)
# memory usage: 22.7 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
# /tmp/ipykernel_19498/725619848.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3014.359223    1136.436893   -0.251845
# std       1.64946    1.472424    4988.505540    2019.773384    1.104536
# min       3.52600    6.075000     423.000000      98.000000   -3.030000
# 25%       6.31900    7.664000     635.500000     199.500000   -0.725000
# 50%       6.95700    8.472000    1145.000000     362.000000   -0.020000
# 75%       7.91350    9.421000    2423.500000     966.000000    0.520000
# max      11.36700   13.864000   25173.000000   10477.000000    1.650000
#
#         ln_Tag_Sr   AEDR_mean       r_MIN       r_MAX      r_MEAN  ...  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  ...
# mean     2.464854    3.570291   11.378641  230.640777  110.887259  ...
# std      0.904757    6.089170    9.139568   14.898911   13.142533  ...
# min      0.390000    0.480000    2.000000  186.000000   76.511395  ...
# 25%      1.805000    0.710000    5.000000  220.000000  101.210585  ...
# 50%      2.600000    1.290000    8.000000  233.000000  109.991054  ...
# 75%      3.160000    2.960000   15.000000  244.000000  120.317332  ...
# max      4.660000   36.590000   56.000000  251.000000  143.611361  ...
#
#             g_Q25       g_Q50       g_Q75       b_MIN       b_MAX      b_MEAN  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  103.000000
# mean    90.864078  132.155340  168.893204   12.621359  214.495146   97.487968
# std     16.629202   14.583604   13.249427    8.475011   21.437951   10.980674
# min     53.000000   95.000000  129.000000    2.000000  152.000000   71.905752
# 25%     80.000000  123.000000  160.500000    7.000000  199.000000   90.400818
# 50%     90.000000  135.000000  170.000000   10.000000  212.000000   96.440293
# 75%    103.000000  141.000000  178.000000   17.000000  234.500000  104.549168
# max    134.000000  170.000000  196.000000   51.000000  251.000000  124.176596
#
#             b_STD       b_Q25       b_Q50       b_Q75
# count  103.000000  103.000000  103.000000  103.000000
# mean    35.164575   68.747573   97.718447  125.669903
# std      5.338700   13.415471   12.490324   12.033767
# min     20.570709   42.000000   69.000000   94.000000
# 25%     31.746440   58.500000   89.500000  119.000000
# 50%     36.135511   67.000000   98.000000  127.000000
# 75%     39.139044   78.500000  107.000000  134.000000
# max     45.825416  103.000000  129.000000  151.000000
#
# [8 rows x 28 columns]

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 
                                   'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 
                                   'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75'])
y = pd.DataFrame(select, columns= ['ln_Tag_Sr'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): Yes
# Selected "Yes"!!! A new column with random values was created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    r_MIN  r_MAX      r_MEAN      r_STD  r_Q25  r_Q50  r_Q75  g_MIN  g_MAX  \
# 0     13    247  117.308148  44.595278     80    120    153     18    243
# 1     24    234  116.193248  43.749380     79    120    153     21    248
# 2     18    222  118.713846  42.450775     84    121    155     20    240
# 3     15    222  114.468779  42.851746     78    116    152     15    244
# 4      8    227  116.849925  44.170268     80    119    155     12    243
#
#        g_MEAN  ...      b_MEAN      b_STD  b_Q25  b_Q50  b_Q75    Random1  \
# 0  133.748091  ...   92.565868  35.145074     63     92    120  10.652100
# 1  132.240460  ...   96.102318  36.135511     66     97    126  12.335353
# 2  135.985871  ...   97.222011  35.938764     68     97    127   8.834361
# 3  131.566750  ...   96.135305  35.908361     67     96    127  11.301067
# 4  131.173455  ...  100.635043  38.062522     69     99    132   9.896342
#
#      Random2    Random3    Random4    Random5
# 0   9.760279  11.605533  12.622386   8.991536
# 1  10.057367  10.131033   8.524995   7.184852
# 2   9.923034   7.316829   6.453074  12.036080
# 3   8.836837  11.915757  12.181265  13.253696
# 4   8.816197   6.682405   9.457975   8.345189
#
# [5 rows x 26 columns]

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Tag_Sr
# 0       2.58
# 1       2.92
# 2       2.88
# 3       2.72
# 4       2.83

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.26349515390186906, -0.14658357649663611, 0.1006491571161583]
#     Mean: 0.073
#     Std: 0.169
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.7254691  0.87488332 0.74958332]
#     Mean: 0.783
#     Std: 0.065
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.7074747119631086, 0.5823787320361418, 0.5430736782971549]
#     Mean: 0.611
#     Std: 0.070
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=30, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Model with rank: 1
# Mean validation score: 0.106 (std: 0.274)
# Parameters: {'colsample_bytree': 0.6803200020803802, 'gamma': 0.4181313951124618, 'learning_rate': 0.03309520722572203, 'max_depth': 2, 'n_estimators': 135, 'subsample': 0.355884922217761}

# %%
# All output data for XGBoost models after tuning parameters

#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.355500235013507, 0.1489317489457586,
#                    0.12892433740980275, 0.32961812611520885,
#                    0.06930106448129264, 0.07887874273530943,
#                    0.3588193104368987, 0.1213039499928884,
#                    0.019383407686483223, 0.4934666311034224,
#                    0.3936509242446771, 0.4381249869521236,
#                    0.0282152720398941, 0.09202725275174645,
#                    0.42759173685787955, 0.022055573635283543,
#                    0.013725972382703344, 0.4181313951124618,
#                    0.23699901222640501, 0.4727945880840571,
#                    0.35358831693258547, 0.11667857746640797,
#                    0.06795084768635884, 0.2928117699494603,
#                    0.31516447684596255, 0.36427969639458635,
#                    0.2125657440023937, 0.3375467056799335,
#                    0.3162961131561965, 0.2121669666318895],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.15430824053183032, 0.2332277293256404,
#                    0.19992702173454574, 0.2930616622363538,
#                    0.30961288086175387, 0.08162788792819997,
#                    0.14442389836353803, 0.2188351125340322,
#                    0.12285144112582486, 0.2795378079933866,
#                    0.21748557406049174, 0.13338107745433758,
#                    0.2308646161697496, 0.13809205266189464,
#                    0.2716044013272302, 0.11607451400106188,
#                    0.1489774945002683, 0.03309520722572203,
#                    0.20881975138542794, 0.2768931221410251,
#                    0.23946866153517346, 0.11740310471982898,
#                    0.24391998565930428, 0.21305345586318356,
#                    0.20454662303522733, 0.15727793635873635,
#                    0.22848395223995302, 0.16481248258547354,
#                    0.20965656265453186, 0.28917946440170256],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[4, 4, 3, 2, 2, 2, 3, 2, 3, 2, 4, 4, 3, 4, 3, 2, 4, 2,
#                    3, 2, 2, 3, 2, 2, 4, 3, 4, 4, 3, 2],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[101, 142, 198, 181, 162, 185, 120, 176, 60, 110, 174,
#                    198, 77, 127, 96, 78, 125, 135, 98, 189, 61, 122, 152,
#                    114, 150, 80, 191, 136, 127, 144],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.933831711666455, 0.8481302339094154,
#                    0.37797383086289227, 0.487429831971931,
#                    0.671571463776854, 0.6145868436290318,
#                    0.9515895966406342, 0.3426623518807387,
#                    0.5120212143688979, 0.7573557194533588,
#                    0.8004039984816782, 0.6378811359764842,
#                    0.5869831125159701, 0.3711829348401294,
#                    0.9437144062514031, 0.5906153968031381,
#                    0.6432383019339003, 0.355884922217761,
#                    0.9445340594575478, 0.5693708537638698,
#                    0.6097241488759013, 0.9026016284988634,
#                    0.6511375010694458, 0.8462351031321869,
#                    0.3038932107795744, 0.7573048649525705,
#                    0.5513241491329497, 0.5599215564583,
#                    0.4032829013247955, 0.7602803579666593],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.24223667701723445, 'gamma': 0.355500235013507, 'learning_rate': 0.15430824053183032, 'max_depth': 4, 'n_estimators': 101, 'subsample': 0.933831711666455}, {'colsample_bytree': 0.8423600259584781, 'gamma': 0.1489317489457586, 'learning_rate': 0.2332277293256404, 'max_depth': 4, 'n_estimators': 142, 'subsample': 0.8481302339094154}, {'colsample_bytree': 0.42755228812577495, 'gamma': 0.12892433740980275, 'learning_rate': 0.19992702173454574, 'max_depth': 3, 'n_estimators': 198, 'subsample': 0.37797383086289227}, {'colsample_bytree': 0.761313319619103, 'gamma': 0.32961812611520885, 'learning_rate': 0.2930616622363538, 'max_depth': 2, 'n_estimators': 181, 'subsample': 0.487429831971931}, {'colsample_bytree': 0.3237567911631955, 'gamma':
#        0.97797573, 0.94538823, 0.97862101, 0.96039041, 0.9284124 ,
#        0.94481251, 0.94131523, 0.99475777, 0.98242244, 0.93743761,
#        0.88210675, 0.99695704, 0.75787227, 0.96438051, 0.92797287,
#        0.93077209, 0.98156593, 0.98741582, 0.94991719, 0.93953441,
#        0.94186951, 0.97104372, 0.93623656, 0.95212641, 0.96977783]), 'std_train_score': array([0.0027884 , 0.0019032 , 0.00160188, 0.00589434, 0.00078985,
#        0.00130494, 0.00627054, 0.00152419, 0.00635149, 0.00695981,
#        0.00453242, 0.00592233, 0.00079523, 0.0017672 , 0.00757908,
#        0.0173148 , 0.00028802, 0.01255539, 0.0035521 , 0.00726394,
#        0.0055595 , 0.00219017, 0.00111758, 0.00907469, 0.00650457,
#        0.00595499, 0.00217237, 0.00931699, 0.00337195, 0.00291119])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.6803200020803802
# Gamma: 0.4181313951124618
# Learning_rate: 0.03309520722572203
# Max_depth: 2
# N_estimators: 135
# Subsample: 0.355884922217761

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(30):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:2.07176	validation_1-rmse:2.24655
# [1]	validation_0-rmse:2.01086	validation_1-rmse:2.18748
# [2]	validation_0-rmse:1.95966	validation_1-rmse:2.13315
# [3]	validation_0-rmse:1.91218	validation_1-rmse:2.09069
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.87116	validation_1-rmse:2.03962
# [5]	validation_0-rmse:1.81867	validation_1-rmse:1.98403
# [6]	validation_0-rmse:1.76945	validation_1-rmse:1.93112
# [7]	validation_0-rmse:1.72558	validation_1-rmse:1.88222
# [8]	validation_0-rmse:1.67879	validation_1-rmse:1.83461
# [9]	validation_0-rmse:1.63186	validation_1-rmse:1.78672
# [10]	validation_0-rmse:1.58664	validation_1-rmse:1.74146
# [11]	validation_0-rmse:1.54757	validation_1-rmse:1.69867
# [12]	validation_0-rmse:1.50949	validation_1-rmse:1.65949
# [13]	validation_0-rmse:1.47233	validation_1-rmse:1.61871
# [14]	validation_0-rmse:1.43505	validation_1-rmse:1.58256
# [15]	validation_0-rmse:1.39707	validation_1-rmse:1.55158
# [16]	validation_0-rmse:1.36315	validation_1-rmse:1.51818
# [17]	validation_0-rmse:1.32881	validation_1-rmse:1.48686
# [18]	validation_0-rmse:1.30140	validation_1-rmse:1.45575
# [19]	validation_0-rmse:1.26942	validation_1-rmse:1.42539
# [20]	validation_0-rmse:1.24163	validation_1-rmse:1.39542
# [21]	validation_0-rmse:1.21865	validation_1-rmse:1.37394
# [22]	validation_0-rmse:1.19103	validation_1-rmse:1.34807
# [23]	validation_0-rmse:1.16735	validation_1-rmse:1.32841
# [24]	validation_0-rmse:1.14076	validation_1-rmse:1.30293
# [25]	validation_0-rmse:1.11348	validation_1-rmse:1.27896
# [26]	validation_0-rmse:1.08752	validation_1-rmse:1.25433
# [27]	validation_0-rmse:1.06543	validation_1-rmse:1.22961
# [28]	validation_0-rmse:1.04862	validation_1-rmse:1.21139
# [29]	validation_0-rmse:1.02480	validation_1-rmse:1.18938
# [30]	validation_0-rmse:1.00719	validation_1-rmse:1.17451
# [31]	validation_0-rmse:0.98475	validation_1-rmse:1.15329
# [32]	validation_0-rmse:0.96714	validation_1-rmse:1.13325
# [33]	validation_0-rmse:0.95114	validation_1-rmse:1.11649
# [34]	validation_0-rmse:0.93488	validation_1-rmse:1.09662
# [35]	validation_0-rmse:0.91822	validation_1-rmse:1.08186
# [36]	validation_0-rmse:0.90080	validation_1-rmse:1.07673
# [37]	validation_0-rmse:0.88451	validation_1-rmse:1.06158
# [38]	validation_0-rmse:0.86816	validation_1-rmse:1.05065
# [39]	validation_0-rmse:0.84815	validation_1-rmse:1.03083
# [40]	validation_0-rmse:0.83737	validation_1-rmse:1.02237
# [55]	validation_0-rmse:0.69976	validation_1-rmse:0.88163
# [56]	validation_0-rmse:0.69010	validation_1-rmse:0.87241
# [57]	validation_0-rmse:0.68332	validation_1-rmse:0.86469
# [58]	validation_0-rmse:0.67891	validation_1-rmse:0.86592
# [59]	validation_0-rmse:0.67090	validation_1-rmse:0.86339
# [60]	validation_0-rmse:0.66285	validation_1-rmse:0.86099
# [61]	validation_0-rmse:0.66114	validation_1-rmse:0.86418
# [62]	validation_0-rmse:0.65585	validation_1-rmse:0.86131
# [63]	validation_0-rmse:0.64910	validation_1-rmse:0.85694
# [64]	validation_0-rmse:0.64356	validation_1-rmse:0.85272
# [65]	validation_0-rmse:0.63766	validation_1-rmse:0.84633
# [66]	validation_0-rmse:0.63409	validation_1-rmse:0.84666
# [67]	validation_0-rmse:0.62980	validation_1-rmse:0.84429
# [68]	validation_0-rmse:0.62672	validation_1-rmse:0.84219
# [69]	validation_0-rmse:0.61975	validation_1-rmse:0.83470
# [70]	validation_0-rmse:0.61346	validation_1-rmse:0.82998
# [71]	validation_0-rmse:0.60565	validation_1-rmse:0.82605
# [72]	validation_0-rmse:0.60107	validation_1-rmse:0.82279
# [73]	validation_0-rmse:0.59815	validation_1-rmse:0.82456
# [74]	validation_0-rmse:0.59122	validation_1-rmse:0.82115
# [75]	validation_0-rmse:0.58691	validation_1-rmse:0.81834
# [76]	validation_0-rmse:0.58414	validation_1-rmse:0.81756
# [77]	validation_0-rmse:0.58031	validation_1-rmse:0.81180
# [78]	validation_0-rmse:0.57290	validation_1-rmse:0.81138
# [79]	validation_0-rmse:0.57106	validation_1-rmse:0.80640
# [80]	validation_0-rmse:0.56721	validation_1-rmse:0.80361
# [81]	validation_0-rmse:0.56548	validation_1-rmse:0.79551
# [82]	validation_0-rmse:0.56162	validation_1-rmse:0.79877
# [83]	validation_0-rmse:0.55734	validation_1-rmse:0.79535
# [84]	validation_0-rmse:0.55699	validation_1-rmse:0.79739
# [85]	validation_0-rmse:0.55424	validation_1-rmse:0.79628
# [86]	validation_0-rmse:0.54986	validation_1-rmse:0.79127
# [87]	validation_0-rmse:0.54862	validation_1-rmse:0.79392
# [88]	validation_0-rmse:0.54345	validation_1-rmse:0.79370
# [89]	validation_0-rmse:0.54140	validation_1-rmse:0.79114
# [90]	validation_0-rmse:0.53635	validation_1-rmse:0.78743
# [91]	validation_0-rmse:0.53390	validation_1-rmse:0.78560
# [92]	validation_0-rmse:0.53310	validation_1-rmse:0.78611
# [93]	validation_0-rmse:0.53034	validation_1-rmse:0.78582
# [94]	validation_0-rmse:0.52691	validation_1-rmse:0.78586
# [95]	validation_0-rmse:0.52426	validation_1-rmse:0.78549
# [96]	validation_0-rmse:0.52231	validation_1-rmse:0.78703
# [97]	validation_0-rmse:0.51944	validation_1-rmse:0.78432
# [98]	validation_0-rmse:0.51740	validation_1-rmse:0.78677
# [99]	validation_0-rmse:0.51530	validation_1-rmse:0.78553
# [100]	validation_0-rmse:0.51355	validation_1-rmse:0.78541
# [61]	validation_0-rmse:0.66360	validation_1-rmse:0.74547
# [62]	validation_0-rmse:0.65483	validation_1-rmse:0.73770
# [63]	validation_0-rmse:0.64901	validation_1-rmse:0.73314
# [64]	validation_0-rmse:0.63973	validation_1-rmse:0.72825
# [65]	validation_0-rmse:0.63487	validation_1-rmse:0.72671
# [66]	validation_0-rmse:0.63106	validation_1-rmse:0.72478
# [67]	validation_0-rmse:0.62665	validation_1-rmse:0.72191
# [68]	validation_0-rmse:0.62223	validation_1-rmse:0.71840
# [69]	validation_0-rmse:0.61572	validation_1-rmse:0.71050
# [70]	validation_0-rmse:0.61242	validation_1-rmse:0.71202
# [71]	validation_0-rmse:0.60941	validation_1-rmse:0.71148
# [72]	validation_0-rmse:0.60518	validation_1-rmse:0.71063
# [73]	validation_0-rmse:0.60092	validation_1-rmse:0.70703
# [74]	validation_0-rmse:0.59438	validation_1-rmse:0.70390
# [75]	validation_0-rmse:0.59039	validation_1-rmse:0.70154
# [76]	validation_0-rmse:0.58724	validation_1-rmse:0.70475
# [77]	validation_0-rmse:0.58101	validation_1-rmse:0.70723
# [78]	validation_0-rmse:0.57696	validation_1-rmse:0.70668
# [79]	validation_0-rmse:0.57158	validation_1-rmse:0.70500
# [80]	validation_0-rmse:0.56855	validation_1-rmse:0.69906
# [81]	validation_0-rmse:0.56200	validation_1-rmse:0.69559
# [82]	validation_0-rmse:0.56123	validation_1-rmse:0.69663
# [83]	validation_0-rmse:0.55789	validation_1-rmse:0.69302
# [84]	validation_0-rmse:0.55455	validation_1-rmse:0.69044
# [85]	validation_0-rmse:0.55151	validation_1-rmse:0.68959
# [86]	validation_0-rmse:0.54886	validation_1-rmse:0.68738
# [87]	validation_0-rmse:0.54421	validation_1-rmse:0.68486
# [88]	validation_0-rmse:0.54159	validation_1-rmse:0.68620
# [89]	validation_0-rmse:0.53820	validation_1-rmse:0.68094
# [90]	validation_0-rmse:0.53677	validation_1-rmse:0.67786
# [91]	validation_0-rmse:0.53437	validation_1-rmse:0.67702
# [92]	validation_0-rmse:0.53160	validation_1-rmse:0.67659
# [93]	validation_0-rmse:0.52670	validation_1-rmse:0.67439
# [94]	validation_0-rmse:0.52463	validation_1-rmse:0.67845
# [95]	validation_0-rmse:0.52265	validation_1-rmse:0.67864
# [96]	validation_0-rmse:0.52120	validation_1-rmse:0.67750
# [97]	validation_0-rmse:0.51866	validation_1-rmse:0.67864
# [98]	validation_0-rmse:0.51454	validation_1-rmse:0.67942
# [99]	validation_0-rmse:0.51228	validation_1-rmse:0.67951
# [100]	validation_0-rmse:0.51020	validation_1-rmse:0.67622
# [101]	validation_0-rmse:0.50874	validation_1-rmse:0.67780
# [102]	validation_0-rmse:0.50564	validation_1-rmse:0.67895
# [103]	validation_0-rmse:0.50354	validation_1-rmse:0.68120
# [104]	validation_0-rmse:0.50372	validation_1-rmse:0.67780
# [105]	validation_0-rmse:0.50181	validation_1-rmse:0.68116
# [106]	validation_0-rmse:0.49862	validation_1-rmse:0.68570
# [107]	validation_0-rmse:0.49537	validation_1-rmse:0.68806
# [108]	validation_0-rmse:0.49315	validation_1-rmse:0.68970
# [109]	validation_0-rmse:0.49036	validation_1-rmse:0.69013
# [110]	validation_0-rmse:0.48705	validation_1-rmse:0.69215
# [111]	validation_0-rmse:0.48446	validation_1-rmse:0.69315
# [112]	validation_0-rmse:0.48194	validation_1-rmse:0.68969
# [113]	validation_0-rmse:0.48026	validation_1-rmse:0.69138
# [0]	validation_0-rmse:2.15017	validation_1-rmse:1.93733
# [1]	validation_0-rmse:2.09257	validation_1-rmse:1.88185
# [2]	validation_0-rmse:2.03410	validation_1-rmse:1.82946
# [3]	validation_0-rmse:1.98885	validation_1-rmse:1.79124
# [4]	validation_0-rmse:1.93836	validation_1-rmse:1.74280
# [5]	validation_0-rmse:1.89168	validation_1-rmse:1.70028
# [6]	validation_0-rmse:1.84109	validation_1-rmse:1.66220
# [7]	validation_0-rmse:1.79469	validation_1-rmse:1.61690
# [8]	validation_0-rmse:1.74491	validation_1-rmse:1.56835
# [9]	validation_0-rmse:1.69815	validation_1-rmse:1.52308
# [10]	validation_0-rmse:1.64908	validation_1-rmse:1.48104
# [11]	validation_0-rmse:1.60047	validation_1-rmse:1.43391
# [12]	validation_0-rmse:1.56451	validation_1-rmse:1.40098
# [13]	validation_0-rmse:1.52529	validation_1-rmse:1.37226
# [14]	validation_0-rmse:1.49357	validation_1-rmse:1.34345
# [15]	validation_0-rmse:1.45396	validation_1-rmse:1.30670
# [16]	validation_0-rmse:1.42186	validation_1-rmse:1.27865
# [17]	validation_0-rmse:1.38647	validation_1-rmse:1.25164
# [18]	validation_0-rmse:1.35603	validation_1-rmse:1.22958
# [19]	validation_0-rmse:1.32003	validation_1-rmse:1.20851
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [20]	validation_0-rmse:1.28876	validation_1-rmse:1.18175
# [21]	validation_0-rmse:1.25986	validation_1-rmse:1.15712
# [22]	validation_0-rmse:1.22766	validation_1-rmse:1.13562
# [23]	validation_0-rmse:1.20281	validation_1-rmse:1.11479
# [24]	validation_0-rmse:1.17852	validation_1-rmse:1.09163
# [25]	validation_0-rmse:1.15247	validation_1-rmse:1.07178
# [26]	validation_0-rmse:1.12925	validation_1-rmse:1.05393
# [27]	validation_0-rmse:1.10622	validation_1-rmse:1.03210
# [28]	validation_0-rmse:1.08369	validation_1-rmse:1.01484
# [29]	validation_0-rmse:1.05846	validation_1-rmse:1.00021
# [30]	validation_0-rmse:1.04100	validation_1-rmse:0.98923
# [31]	validation_0-rmse:1.01861	validation_1-rmse:0.96987
# [32]	validation_0-rmse:1.00287	validation_1-rmse:0.95847
# [33]	validation_0-rmse:0.98486	validation_1-rmse:0.94515
# [34]	validation_0-rmse:0.96916	validation_1-rmse:0.93263
# [35]	validation_0-rmse:0.95139	validation_1-rmse:0.91790
# [36]	validation_0-rmse:0.93375	validation_1-rmse:0.90585
# [37]	validation_0-rmse:0.92020	validation_1-rmse:0.90155
# [38]	validation_0-rmse:0.90416	validation_1-rmse:0.89744
# [39]	validation_0-rmse:0.89238	validation_1-rmse:0.88767
# [40]	validation_0-rmse:0.87637	validation_1-rmse:0.88196
# ...
# [90]	validation_0-rmse:0.50935	validation_1-rmse:0.91924
# [91]	validation_0-rmse:0.50633	validation_1-rmse:0.92005
# [92]	validation_0-rmse:0.50491	validation_1-rmse:0.91872
# [93]	validation_0-rmse:0.50392	validation_1-rmse:0.91845
# [94]	validation_0-rmse:0.49911	validation_1-rmse:0.91988
# [95]	validation_0-rmse:0.49702	validation_1-rmse:0.92053
# [96]	validation_0-rmse:0.49245	validation_1-rmse:0.91946
# [97]	validation_0-rmse:0.48985	validation_1-rmse:0.91831
# [98]	validation_0-rmse:0.48875	validation_1-rmse:0.91990
# [99]	validation_0-rmse:0.48640	validation_1-rmse:0.92010
# [100]	validation_0-rmse:0.48360	validation_1-rmse:0.92248
# [101]	validation_0-rmse:0.48002	validation_1-rmse:0.92243
# [102]	validation_0-rmse:0.47849	validation_1-rmse:0.92396
# [103]	validation_0-rmse:0.47548	validation_1-rmse:0.92066
# [104]	validation_0-rmse:0.47375	validation_1-rmse:0.91879
# [105]	validation_0-rmse:0.47169	validation_1-rmse:0.91648
# [106]	validation_0-rmse:0.47098	validation_1-rmse:0.91935
# [107]	validation_0-rmse:0.46927	validation_1-rmse:0.91856
# [108]	validation_0-rmse:0.46614	validation_1-rmse:0.91430
# [109]	validation_0-rmse:0.46520	validation_1-rmse:0.91509
# [110]	validation_0-rmse:0.46271	validation_1-rmse:0.91837
# [111]	validation_0-rmse:0.46049	validation_1-rmse:0.91795
# [112]	validation_0-rmse:0.45785	validation_1-rmse:0.91846
# [113]	validation_0-rmse:0.45588	validation_1-rmse:0.91902
# [114]	validation_0-rmse:0.45546	validation_1-rmse:0.91833
# [115]	validation_0-rmse:0.45301	validation_1-rmse:0.91615
# [116]	validation_0-rmse:0.45116	validation_1-rmse:0.91396
# [117]	validation_0-rmse:0.44981	validation_1-rmse:0.91181
# [118]	validation_0-rmse:0.44690	validation_1-rmse:0.91071
# [119]	validation_0-rmse:0.44658	validation_1-rmse:0.91202
# [120]	validation_0-rmse:0.44447	validation_1-rmse:0.91007
# [121]	validation_0-rmse:0.44155	validation_1-rmse:0.91287
# [122]	validation_0-rmse:0.44082	validation_1-rmse:0.91457
# [123]	validation_0-rmse:0.43872	validation_1-rmse:0.91387
# [124]	validation_0-rmse:0.43759	validation_1-rmse:0.91642
# [125]	validation_0-rmse:0.43659	validation_1-rmse:0.91575
# [126]	validation_0-rmse:0.43542	validation_1-rmse:0.91576
# [127]	validation_0-rmse:0.43343	validation_1-rmse:0.91411
# [128]	validation_0-rmse:0.43177	validation_1-rmse:0.91423
# [129]	validation_0-rmse:0.42853	validation_1-rmse:0.91498
# [130]	validation_0-rmse:0.42520	validation_1-rmse:0.91792
# [131]	validation_0-rmse:0.42421	validation_1-rmse:0.91719
# [132]	validation_0-rmse:0.42261	validation_1-rmse:0.91774
# [133]	validation_0-rmse:0.42086	validation_1-rmse:0.91582
# [134]	validation_0-rmse:0.41895	validation_1-rmse:0.91230
# [0]	validation_0-rmse:2.18054	validation_1-rmse:1.74895
# [1]	validation_0-rmse:2.12611	validation_1-rmse:1.68794
# [2]	validation_0-rmse:2.07414	validation_1-rmse:1.64082
# [3]	validation_0-rmse:2.02467	validation_1-rmse:1.59077
# [4]	validation_0-rmse:1.96446	validation_1-rmse:1.53261
# [5]	validation_0-rmse:1.91374	validation_1-rmse:1.49493
# [6]	validation_0-rmse:1.86145	validation_1-rmse:1.45752
# [7]	validation_0-rmse:1.81318	validation_1-rmse:1.41615
# [8]	validation_0-rmse:1.76435	validation_1-rmse:1.36856
# [9]	validation_0-rmse:1.71576	validation_1-rmse:1.32345
# [10]	validation_0-rmse:1.67632	validation_1-rmse:1.27914
# [11]	validation_0-rmse:1.63185	validation_1-rmse:1.23260
# [12]	validation_0-rmse:1.59037	validation_1-rmse:1.19613
# [13]	validation_0-rmse:1.54948	validation_1-rmse:1.16737
# [14]	validation_0-rmse:1.50985	validation_1-rmse:1.13473
# [15]	validation_0-rmse:1.47451	validation_1-rmse:1.10172
# [16]	validation_0-rmse:1.43126	validation_1-rmse:1.06369
# [17]	validation_0-rmse:1.38997	validation_1-rmse:1.02540
# [18]	validation_0-rmse:1.35136	validation_1-rmse:0.98706
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [19]	validation_0-rmse:1.31985	validation_1-rmse:0.95495
# [20]	validation_0-rmse:1.28627	validation_1-rmse:0.92719
# [21]	validation_0-rmse:1.25485	validation_1-rmse:0.89780
# [22]	validation_0-rmse:1.22774	validation_1-rmse:0.87619
# [23]	validation_0-rmse:1.20010	validation_1-rmse:0.85317
# [24]	validation_0-rmse:1.17645	validation_1-rmse:0.82958
# [25]	validation_0-rmse:1.14573	validation_1-rmse:0.80203
# [26]	validation_0-rmse:1.12051	validation_1-rmse:0.77898
# [27]	validation_0-rmse:1.09977	validation_1-rmse:0.75905
# [28]	validation_0-rmse:1.07845	validation_1-rmse:0.74692
# [29]	validation_0-rmse:1.05875	validation_1-rmse:0.73239
# [30]	validation_0-rmse:1.04752	validation_1-rmse:0.72736
# [31]	validation_0-rmse:1.02700	validation_1-rmse:0.71183
# [32]	validation_0-rmse:1.01120	validation_1-rmse:0.70615
# [33]	validation_0-rmse:0.99525	validation_1-rmse:0.69229
# [34]	validation_0-rmse:0.97560	validation_1-rmse:0.67835
# [35]	validation_0-rmse:0.95844	validation_1-rmse:0.67169
# [36]	validation_0-rmse:0.94356	validation_1-rmse:0.65904
# [37]	validation_0-rmse:0.92901	validation_1-rmse:0.65591
# [38]	validation_0-rmse:0.91215	validation_1-rmse:0.64659
# [39]	validation_0-rmse:0.89742	validation_1-rmse:0.63381
# [40]	validation_0-rmse:0.88235	validation_1-rmse:0.62986
# [41]	validation_0-rmse:0.86510	validation_1-rmse:0.62243
# [42]	validation_0-rmse:0.85292	validation_1-rmse:0.61617
# [43]	validation_0-rmse:0.84401	validation_1-rmse:0.60820
# [44]	validation_0-rmse:0.83147	validation_1-rmse:0.60904
# [45]	validation_0-rmse:0.82132	validation_1-rmse:0.60701
# [46]	validation_0-rmse:0.80600	validation_1-rmse:0.59303
# [47]	validation_0-rmse:0.79632	validation_1-rmse:0.58492
# [48]	validation_0-rmse:0.78500	validation_1-rmse:0.57921
# [49]	validation_0-rmse:0.77218	validation_1-rmse:0.57202
# [50]	validation_0-rmse:0.76273	validation_1-rmse:0.57012
# [51]	validation_0-rmse:0.74857	validation_1-rmse:0.56306
# [52]	validation_0-rmse:0.74086	validation_1-rmse:0.56111
# [53]	validation_0-rmse:0.73196	validation_1-rmse:0.56234
# [54]	validation_0-rmse:0.72481	validation_1-rmse:0.55905
# [55]	validation_0-rmse:0.71380	validation_1-rmse:0.56094
# [56]	validation_0-rmse:0.70586	validation_1-rmse:0.55496
# [57]	validation_0-rmse:0.69945	validation_1-rmse:0.55721
# [58]	validation_0-rmse:0.69404	validation_1-rmse:0.55481
# [59]	validation_0-rmse:0.68659	validation_1-rmse:0.55115
# [60]	validation_0-rmse:0.68095	validation_1-rmse:0.54562
# [61]	validation_0-rmse:0.67738	validation_1-rmse:0.54080
# [62]	validation_0-rmse:0.66973	validation_1-rmse:0.54283
# [63]	validation_0-rmse:0.66404	validation_1-rmse:0.54568
# [64]	validation_0-rmse:0.65558	validation_1-rmse:0.54557
# [65]	validation_0-rmse:0.65122	validation_1-rmse:0.54909
# [66]	validation_0-rmse:0.64387	validation_1-rmse:0.54533
# [67]	validation_0-rmse:0.63728	validation_1-rmse:0.54467
# [68]	validation_0-rmse:0.63145	validation_1-rmse:0.54434
# [69]	validation_0-rmse:0.62281	validation_1-rmse:0.55085
# [70]	validation_0-rmse:0.61773	validation_1-rmse:0.55499
# [71]	validation_0-rmse:0.61199	validation_1-rmse:0.55561
# [72]	validation_0-rmse:0.61158	validation_1-rmse:0.55651
# [73]	validation_0-rmse:0.60706	validation_1-rmse:0.56033
# [74]	validation_0-rmse:0.60278	validation_1-rmse:0.56238
# [75]	validation_0-rmse:0.59543	validation_1-rmse:0.55789
# [76]	validation_0-rmse:0.58976	validation_1-rmse:0.55500
# [77]	validation_0-rmse:0.58479	validation_1-rmse:0.55803
# [78]	validation_0-rmse:0.58112	validation_1-rmse:0.55918
# [79]	validation_0-rmse:0.57311	validation_1-rmse:0.56030
# [80]	validation_0-rmse:0.56851	validation_1-rmse:0.56088
# [0]	validation_0-rmse:2.08894	validation_1-rmse:2.16544
# [1]	validation_0-rmse:2.02559	validation_1-rmse:2.11034
# [2]	validation_0-rmse:1.96874	validation_1-rmse:2.06220
# [3]	validation_0-rmse:1.91160	validation_1-rmse:2.01161
# [4]	validation_0-rmse:1.85709	validation_1-rmse:1.95666
# [5]	validation_0-rmse:1.79823	validation_1-rmse:1.90479
# [6]	validation_0-rmse:1.74671	validation_1-rmse:1.86507
# [7]	validation_0-rmse:1.70054	validation_1-rmse:1.83066
# [8]	validation_0-rmse:1.65701	validation_1-rmse:1.80570
# [9]	validation_0-rmse:1.61790	validation_1-rmse:1.77382
# [10]	validation_0-rmse:1.57767	validation_1-rmse:1.73653
# [11]	validation_0-rmse:1.54373	validation_1-rmse:1.71463
# [12]	validation_0-rmse:1.50132	validation_1-rmse:1.67849
# [13]	validation_0-rmse:1.46416	validation_1-rmse:1.65270
# [14]	validation_0-rmse:1.42859	validation_1-rmse:1.63486
# [15]	validation_0-rmse:1.40035	validation_1-rmse:1.61728
# [16]	validation_0-rmse:1.36999	validation_1-rmse:1.59700
# [17]	validation_0-rmse:1.33484	validation_1-rmse:1.56949
# [18]	validation_0-rmse:1.30458	validation_1-rmse:1.54418
# [19]	validation_0-rmse:1.27254	validation_1-rmse:1.51969
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [20]	validation_0-rmse:1.24166	validation_1-rmse:1.49957
# [21]	validation_0-rmse:1.21194	validation_1-rmse:1.47126
# [22]	validation_0-rmse:1.18307	validation_1-rmse:1.44834
# [23]	validation_0-rmse:1.14790	validation_1-rmse:1.41920
# [24]	validation_0-rmse:1.11777	validation_1-rmse:1.39278
# [25]	validation_0-rmse:1.09281	validation_1-rmse:1.37334
# [26]	validation_0-rmse:1.06846	validation_1-rmse:1.36077
# [27]	validation_0-rmse:1.04291	validation_1-rmse:1.34778
# [28]	validation_0-rmse:1.02063	validation_1-rmse:1.33783
# [29]	validation_0-rmse:1.00236	validation_1-rmse:1.32953
# [30]	validation_0-rmse:0.98127	validation_1-rmse:1.31753
# [31]	validation_0-rmse:0.96422	validation_1-rmse:1.30160
# [32]	validation_0-rmse:0.94581	validation_1-rmse:1.28654
# [33]	validation_0-rmse:0.93360	validation_1-rmse:1.27917
# [34]	validation_0-rmse:0.91698	validation_1-rmse:1.27299
# [35]	validation_0-rmse:0.90816	validation_1-rmse:1.26682
# [36]	validation_0-rmse:0.88887	validation_1-rmse:1.25439
# [37]	validation_0-rmse:0.87473	validation_1-rmse:1.24761
# [38]	validation_0-rmse:0.85907	validation_1-rmse:1.24348
# [39]	validation_0-rmse:0.84158	validation_1-rmse:1.23324
# [40]	validation_0-rmse:0.82915	validation_1-rmse:1.22799
# [41]	validation_0-rmse:0.81614	validation_1-rmse:1.21980
# [42]	validation_0-rmse:0.80107	validation_1-rmse:1.21828
# [43]	validation_0-rmse:0.78325	validation_1-rmse:1.20728
# [44]	validation_0-rmse:0.77142	validation_1-rmse:1.20423
# [45]	validation_0-rmse:0.75881	validation_1-rmse:1.19941
# [46]	validation_0-rmse:0.74580	validation_1-rmse:1.19641
# [47]	validation_0-rmse:0.73810	validation_1-rmse:1.18665
# [48]	validation_0-rmse:0.72716	validation_1-rmse:1.17789
# [49]	validation_0-rmse:0.72108	validation_1-rmse:1.17617
# [50]	validation_0-rmse:0.71484	validation_1-rmse:1.16663
# [51]	validation_0-rmse:0.70608	validation_1-rmse:1.16498
# [52]	validation_0-rmse:0.69472	validation_1-rmse:1.15972
# [53]	validation_0-rmse:0.68598	validation_1-rmse:1.15476
# [54]	validation_0-rmse:0.67535	validation_1-rmse:1.15285
# [55]	validation_0-rmse:0.66815	validation_1-rmse:1.14678
# [56]	validation_0-rmse:0.65621	validation_1-rmse:1.13902
# [57]	validation_0-rmse:0.64756	validation_1-rmse:1.13758
# [58]	validation_0-rmse:0.63721	validation_1-rmse:1.13220
# [59]	validation_0-rmse:0.62977	validation_1-rmse:1.12575
# [60]	validation_0-rmse:0.62531	validation_1-rmse:1.12109
# [61]	validation_0-rmse:0.61698	validation_1-rmse:1.11562
# [62]	validation_0-rmse:0.60835	validation_1-rmse:1.11105
# [63]	validation_0-rmse:0.60083	validation_1-rmse:1.10484
# [64]	validation_0-rmse:0.59584	validation_1-rmse:1.10136
# [65]	validation_0-rmse:0.58892	validation_1-rmse:1.09904
# [66]	validation_0-rmse:0.58567	validation_1-rmse:1.09836
# [67]	validation_0-rmse:0.58029	validation_1-rmse:1.09722
# [68]	validation_0-rmse:0.57763	validation_1-rmse:1.09753
# [69]	validation_0-rmse:0.57408	validation_1-rmse:1.09520
# [70]	validation_0-rmse:0.56494	validation_1-rmse:1.09143
# [71]	validation_0-rmse:0.55886	validation_1-rmse:1.08878
# [72]	validation_0-rmse:0.55449	validation_1-rmse:1.08957
# [73]	validation_0-rmse:0.54943	validation_1-rmse:1.08779
# [74]	validation_0-rmse:0.54452	validation_1-rmse:1.08590
# [75]	validation_0-rmse:0.53928	validation_1-rmse:1.08799
# [76]	validation_0-rmse:0.53729	validation_1-rmse:1.09092
# [77]	validation_0-rmse:0.53315	validation_1-rmse:1.09033
# [78]	validation_0-rmse:0.52927	validation_1-rmse:1.08475
# [79]	validation_0-rmse:0.52339	validation_1-rmse:1.08251
# [80]	validation_0-rmse:0.52001	validation_1-rmse:1.08311
# [81]	validation_0-rmse:0.51872	validation_1-rmse:1.07905
# [82]	validation_0-rmse:0.51695	validation_1-rmse:1.07585
# [83]	validation_0-rmse:0.51292	validation_1-rmse:1.07545
# [84]	validation_0-rmse:0.51299	validation_1-rmse:1.07625
# [85]	validation_0-rmse:0.51162	validation_1-rmse:1.07406
# [86]	validation_0-rmse:0.50878	validation_1-rmse:1.07161
# [87]	validation_0-rmse:0.50438	validation_1-rmse:1.07037
# [88]	validation_0-rmse:0.50027	validation_1-rmse:1.07021
# [89]	validation_0-rmse:0.49516	validation_1-rmse:1.07009
# [90]	validation_0-rmse:0.49226	validation_1-rmse:1.06631
# [91]	validation_0-rmse:0.48742	validation_1-rmse:1.06385
# [92]	validation_0-rmse:0.48470	validation_1-rmse:1.06628
# [93]	validation_0-rmse:0.48397	validation_1-rmse:1.06970
# [94]	validation_0-rmse:0.48099	validation_1-rmse:1.06957
# [95]	validation_0-rmse:0.48088	validation_1-rmse:1.06566
# [96]	validation_0-rmse:0.48045	validation_1-rmse:1.06730
# [97]	validation_0-rmse:0.47748	validation_1-rmse:1.06642
# [98]	validation_0-rmse:0.47468	validation_1-rmse:1.06607
# [99]	validation_0-rmse:0.47113	validation_1-rmse:1.06387
# [100]	validation_0-rmse:0.46864	validation_1-rmse:1.06002
# [101]	validation_0-rmse:0.46722	validation_1-rmse:1.06219
# [102]	validation_0-rmse:0.46547	validation_1-rmse:1.06223
# [103]	validation_0-rmse:0.46378	validation_1-rmse:1.06614
# [104]	validation_0-rmse:0.46304	validation_1-rmse:1.06398
# [105]	validation_0-rmse:0.45987	validation_1-rmse:1.06043
# [106]	validation_0-rmse:0.45819	validation_1-rmse:1.05819
# [107]	validation_0-rmse:0.45587	validation_1-rmse:1.05800
# [108]	validation_0-rmse:0.45320	validation_1-rmse:1.05434
# [109]	validation_0-rmse:0.44963	validation_1-rmse:1.05054
# [110]	validation_0-rmse:0.44748	validation_1-rmse:1.04786
# [111]	validation_0-rmse:0.44535	validation_1-rmse:1.05038
# [112]	validation_0-rmse:0.44356	validation_1-rmse:1.05082
# [113]	validation_0-rmse:0.43907	validation_1-rmse:1.04968
# [114]	validation_0-rmse:0.43700	validation_1-rmse:1.05078
# [115]	validation_0-rmse:0.43536	validation_1-rmse:1.04919
# [116]	validation_0-rmse:0.43443	validation_1-rmse:1.04918
# [117]	validation_0-rmse:0.43347	validation_1-rmse:1.04758
# [118]	validation_0-rmse:0.43205	validation_1-rmse:1.04510
# [119]	validation_0-rmse:0.42960	validation_1-rmse:1.04064
# [120]	validation_0-rmse:0.42788	validation_1-rmse:1.04035
# [121]	validation_0-rmse:0.42599	validation_1-rmse:1.03712
# [122]	validation_0-rmse:0.42396	validation_1-rmse:1.03372
# [123]	validation_0-rmse:0.42302	validation_1-rmse:1.03198
# [124]	validation_0-rmse:0.42090	validation_1-rmse:1.03242
# [125]	validation_0-rmse:0.42069	validation_1-rmse:1.03224
# [126]	validation_0-rmse:0.41890	validation_1-rmse:1.03195
# [127]	validation_0-rmse:0.41751	validation_1-rmse:1.02928
# [128]	validation_0-rmse:0.41631	validation_1-rmse:1.02929
# [129]	validation_0-rmse:0.41540	validation_1-rmse:1.03233
# [130]	validation_0-rmse:0.41425	validation_1-rmse:1.03258
# [131]	validation_0-rmse:0.41303	validation_1-rmse:1.03490
# [132]	validation_0-rmse:0.41189	validation_1-rmse:1.03533
# [133]	validation_0-rmse:0.41074	validation_1-rmse:1.03527
# [134]	validation_0-rmse:0.40937	validation_1-rmse:1.03632
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 102.667, median: 102.5,
#  pred. interval (P(0.025)-P(0.975)): 60.175-134.0,
#  conf. interval (p-value=0.95): 91.458-115.811
# ***
# Aggregate bias statistic:
#  mean: -1.924, median: -1.798,
#  pred. interval (P(0.025)-P(0.975)): -8.718-2.577,
#  conf. interval (p-value=0.95): -2.508--0.896
# ***
# Aggregate RMSE statistic:
#  mean: 0.766, median: 0.787, pred. interval (P(0.025)-P(0.975)): 0.547-0.943,
#  conf. interval (p-value=0.95): 0.717-0.819
# ***
# Aggregate MSE statistic:
#  mean: 0.599, median: 0.619, pred. interval (P(0.025)-P(0.975)): 0.299-0.892,
#  conf. interval (p-value=0.95): 0.521-0.672
# ***
# Aggregate R^2 statistic:
#  mean: 0.17, median: 0.185, pred. interval (P(0.025)-P(0.975)): -0.095-0.421,
#  conf. interval (p-value=0.95): 0.094-0.241
# ***
# Aggregate bias(%) statistic:
#  mean: -0.738, median: -1.798, pred. interval (P(0.025)-P(0.975)): -3.162-1.221,
#  conf. interval (p-value=0.95): -1.008--0.363
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.314, median: 0.308, pred. interval (P(0.025)-P(0.975)): 0.226-0.4,
#  conf. interval (p-value=0.95): 0.285-0.333
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:2.10351
# [1]	validation_0-rmse:2.03809
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
#
# [83]	validation_0-rmse:0.55673
# [84]	validation_0-rmse:0.55320
# [85]	validation_0-rmse:0.55009
# [86]	validation_0-rmse:0.54777
# [87]	validation_0-rmse:0.54675
# [88]	validation_0-rmse:0.54300
# [89]	validation_0-rmse:0.53874
# [90]	validation_0-rmse:0.53668
# [91]	validation_0-rmse:0.53150
# [92]	validation_0-rmse:0.52939
# [93]	validation_0-rmse:0.52610
# [94]	validation_0-rmse:0.52501
# [95]	validation_0-rmse:0.52226
# [96]	validation_0-rmse:0.51998
# [97]	validation_0-rmse:0.51799
# [98]	validation_0-rmse:0.51774
# [99]	validation_0-rmse:0.51613
# [100]	validation_0-rmse:0.51365
# [101]	validation_0-rmse:0.51085
# [102]	validation_0-rmse:0.50899
# [103]	validation_0-rmse:0.50723
# [104]	validation_0-rmse:0.50506
# [105]	validation_0-rmse:0.50331
# [106]	validation_0-rmse:0.49996
# [107]	validation_0-rmse:0.49920
# [108]	validation_0-rmse:0.49806
# [109]	validation_0-rmse:0.49671
# [110]	validation_0-rmse:0.49427
# [111]	validation_0-rmse:0.49234
# [112]	validation_0-rmse:0.49067
# [113]	validation_0-rmse:0.48943
# [114]	validation_0-rmse:0.48936
# [115]	validation_0-rmse:0.48711
# [116]	validation_0-rmse:0.48601
# [117]	validation_0-rmse:0.48321
# [118]	validation_0-rmse:0.48215
# [119]	validation_0-rmse:0.47999
# [120]	validation_0-rmse:0.47890
# [121]	validation_0-rmse:0.47552
# [122]	validation_0-rmse:0.47426
# [123]	validation_0-rmse:0.47248
# [124]	validation_0-rmse:0.47107
# [125]	validation_0-rmse:0.46913
# [126]	validation_0-rmse:0.46790
# [127]	validation_0-rmse:0.46527
# [128]	validation_0-rmse:0.46419
# [129]	validation_0-rmse:0.46167
# [130]	validation_0-rmse:0.46042
# [131]	validation_0-rmse:0.46108
# [132]	validation_0-rmse:0.46067
# [133]	validation_0-rmse:0.45871
# [134]	validation_0-rmse:0.45613
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 134

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -1.73
# RMSE: 0.5
# Relative RMSE(%):  0.185
# MSE: 0.2
# R square: 74.3%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.992
# a1: 0.581
# R^2: 0.811
# Uncertainty
# a0: 0.99+/-0.07
# a1: 0.581+/-0.028

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=1) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_Tag_Sr_XGB_model_.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_Tag_St_XGB_model_.txt")
