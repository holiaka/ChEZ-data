# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN'])
            
# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           2260           1210     -0.731      2.576
# 1       8.189       9.622           2700           1180      0.585      2.915
# 2       8.380       9.589           2500           1400      0.779      2.882
# 3       8.137       9.449           2500           1090      0.517      2.724
# 4       7.696       9.401           2400            720      0.224      2.826
#
#    AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  \
# 0       2.33    0.445070     13  35.145074   360.273487    0.488754
# 1       2.47   12.465903     24  36.135511   323.958625    0.501683
# 2       2.44   13.028298     18  35.938764   299.438354    0.540056
# 3       2.55    2.128231     15  35.908361   319.773395    0.480991
# 4       2.14   12.171553      8  38.062522   353.104284    0.505257
#
#    corr_r_MIN
# 0    0.072792
# 1    0.098347
# 2    0.187811
# 3    0.020686
# 4    0.106549

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   mf_chm_MIN     103 non-null    float64
#  8   r_MIN          103 non-null    int64
#  9   b_STD          103 non-null    float64
#  10  contr_r_STD    103 non-null    float64
#  11  corr_r_Q25     103 non-null    float64
#  12  corr_r_MIN     103 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 10.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Cs_wood", "ln_Sr_wood"].describe()
# Out:
#                  ln_Cs_wood                                                 \
#                       count       mean       std     min      25%      50%
# Dominant_specias
# Alder                   4.0   7.305000  1.427622   5.886   6.6765   7.0235
# Aspen                   1.0  11.367000       NaN  11.367  11.3670  11.3670
# Birch                  23.0   7.304652  1.533182   4.533   6.3365   7.2150
# Oak                     3.0   7.430333  1.260072   6.040   6.8970   7.7540
# Pine                   71.0   6.901690  1.650166   3.526   6.3790   6.9470
# Spruce                  1.0   5.176000       NaN   5.176   5.1760   5.1760
#
#                                   ln_Sr_wood                               \
#                       75%     max      count       mean       std     min
# Dominant_specias
# Alder              7.6520   9.287        4.0   7.206000  0.650057   6.265
# Aspen             11.3670  11.367        1.0  11.090000       NaN  11.090
# Birch              8.0320  10.332       23.0   9.345478  1.626360   7.139
# Oak                8.1255   8.497        3.0   7.483667  0.815040   6.565
# Pine               7.6960  10.469       71.0   8.542592  1.359020   6.075
# Spruce             5.1760   5.176        1.0   7.783000       NaN   7.783
#
#
#                       25%      50%      75%     max
# Dominant_specias
# Alder              7.0255   7.4545   7.6350   7.650
# Aspen             11.0900  11.0900  11.0900  11.090
# Birch              8.4000   8.9910   9.9365  13.864
# Oak                7.1655   7.7660   7.9430   8.120
# Pine               7.6450   8.4720   9.3710  12.687
# Spruce             7.7830   7.7830   7.7830   7.783

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3440.194175    1242.902913   -0.252563
# std       1.64946    1.472424    6087.580089    2037.684800    1.104610
# min       3.52600    6.075000     260.000000      50.000000   -3.033000
# 25%       6.31900    7.664000     635.000000     200.000000   -0.727500
# 50%       6.95700    8.472000    1150.000000     400.000000   -0.025000
# 75%       7.91350    9.421000    2525.000000    1400.000000    0.516500
# max      11.36700   13.864000   35200.000000   10500.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean  mf_chm_MIN       r_MIN       b_STD  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     2.464709    3.570291    3.368496   11.378641   35.164575
# std      0.904675    6.089170    4.845054    9.139568    5.338700
# min      0.391000    0.480000   -0.018586    2.000000   20.570709
# 25%      1.803000    0.710000    0.482279    5.000000   31.746440
# 50%      2.603000    1.290000    0.642883    8.000000   36.135511
# 75%      3.159000    2.960000    3.921804   15.000000   39.139044
# max      4.659000   36.590000   17.862923   56.000000   45.825416
#
#        contr_r_STD  corr_r_Q25  corr_r_MIN
# count   103.000000  103.000000  103.000000
# mean    327.115078    0.393571    0.073579
# std     167.617957    0.151801    0.056017
# min       0.091058    0.033797   -0.062450
# 25%     283.887328    0.407228    0.027204
# 50%     353.034542    0.449670    0.063714
# 75%     448.017711    0.476635    0.110983
# max     652.546648    0.555648    0.241284

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_Sr_wood"
indep_variables = ['Sr_2021_kBq_m']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  \
# 0         6.824       9.240           2260           1210     -0.731
# 1         8.189       9.622           2700           1180      0.585
# 2         8.380       9.589           2500           1400      0.779
# 3         8.137       9.449           2500           1090      0.517
# 4         7.696       9.401           2400            720      0.224
# ..          ...         ...            ...            ...        ...
# 98        8.071       8.434           2500           1300      0.228
# 99        7.993      10.042           2300           1100      0.266
# 100       8.343      10.488           2400           1200      0.543
# 101       3.638       6.399            630            270     -2.811
# 102       4.787       6.877            680            290     -1.728
#
#      ln_Tag_Sr  AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  \
# 0        2.576       2.33    0.445070     13  35.145074   360.273487
# 1        2.915       2.47   12.465903     24  36.135511   323.958625
# 2        2.882       2.44   13.028298     18  35.938764   299.438354
# 3        2.724       2.55    2.128231     15  35.908361   319.773395
# 4        2.826       2.14   12.171553      8  38.062522   353.104284
# ..         ...        ...         ...    ...        ...          ...
# 98       1.514       2.92    0.528681      3  32.852994   329.221211
# 99       3.230       2.78    0.422647     18  27.970146   268.895699
# 100      3.606       2.92    0.426717     19  30.529613   251.314791
# 101      0.805       0.75    0.476680      6  37.245047   477.751734
# 102      1.199       0.78    0.410141      2  38.454424   412.535053
#
#      corr_r_Q25  corr_r_MIN
# 0      0.488754    0.072792
# 1      0.501683    0.098347
# 2      0.540056    0.187811
# 3      0.480991    0.020686
# 4      0.505257    0.106549
# ..          ...         ...
# 98     0.478581    0.079646
# 99     0.467111    0.063714
# 100    0.501777    0.128376
# 101    0.467443    0.129664
# 102    0.480964    0.157460
#
# [103 rows x 13 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Sr_2021_kBq_m
# 0           1210
# 1           1180
# 2           1400
# 3           1090
# 4            720

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Sr_wood
# 0       9.240
# 1       9.622
# 2       9.589
# 3       9.449
# 4       9.401

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.22043379865673896, 0.6789559258347571, 0.23635405655616248]
#     Mean: 0.379
#     Std: 0.212
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.15440506 1.03121442 0.83104235]
#     Mean: 1.006
#     Std: 0.133
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.8480218988691057, 0.8641171757193172, 0.8554213206347299]
#     Mean: 0.856
#     Std: 0.007
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
Colsample_bytree: 0.05889981913345711
Gamma: 0.2744957828289574
Learning_rate: 0.07870872718428862
Max_depth: 2
N_estimators: 86
Subsample: 0.9671340269777906

# Hyperparameters data for the next step/stage
p1 = 0.05889981913345711                 # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.2744957828289574                  # gamma
print('Gamma: ' + str(p2))

p3 = 0.07870872718428862                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2                                   # max_depth
print('Max_depth: ' + str(p4))

p5 = 86                                  # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.9671340269777906                   # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.05889981913345711
# Gamma: 0.2744957828289574
# Learning_rate: 0.07870872718428862
# Max_depth: 2
# N_estimators: 86
# Subsample: 0.9671340269777906

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:7.73360	validation_1-rmse:7.38527
# [1]	validation_0-rmse:7.14907	validation_1-rmse:6.84852
# [2]	validation_0-rmse:6.61042	validation_1-rmse:6.35444
# [3]	validation_0-rmse:6.11894	validation_1-rmse:5.90172
# [4]	validation_0-rmse:5.66117	validation_1-rmse:5.48354
# [5]	validation_0-rmse:5.23902	validation_1-rmse:5.08776
# [6]	validation_0-rmse:4.84943	validation_1-rmse:4.72225
# [7]	validation_0-rmse:4.48912	validation_1-rmse:4.38648
# [8]	validation_0-rmse:4.15852	validation_1-rmse:4.09065
# [9]	validation_0-rmse:3.85247	validation_1-rmse:3.80333
# [10]	validation_0-rmse:3.57234	validation_1-rmse:3.55566
# [11]	validation_0-rmse:3.31401	validation_1-rmse:3.31553
# [12]	validation_0-rmse:3.07709	validation_1-rmse:3.10181
# [13]	validation_0-rmse:2.85770	validation_1-rmse:2.90034
# [14]	validation_0-rmse:2.65920	validation_1-rmse:2.73082
# [15]	validation_0-rmse:2.47356	validation_1-rmse:2.56250
# [16]	validation_0-rmse:2.30369	validation_1-rmse:2.41928
# [17]	validation_0-rmse:2.14766	validation_1-rmse:2.28010
# [18]	validation_0-rmse:2.00875	validation_1-rmse:2.16117
# [19]	validation_0-rmse:1.87856	validation_1-rmse:2.05265
# [20]	validation_0-rmse:1.76089	validation_1-rmse:1.94964
# [21]	validation_0-rmse:1.65335	validation_1-rmse:1.86233
# [22]	validation_0-rmse:1.55435	validation_1-rmse:1.78161
# [23]	validation_0-rmse:1.46572	validation_1-rmse:1.71159
# [24]	validation_0-rmse:1.38458	validation_1-rmse:1.64727
# [25]	validation_0-rmse:1.30725	validation_1-rmse:1.58503
# [26]	validation_0-rmse:1.24011	validation_1-rmse:1.53104
# [27]	validation_0-rmse:1.17973	validation_1-rmse:1.48211
# [28]	validation_0-rmse:1.12386	validation_1-rmse:1.43991
# [29]	validation_0-rmse:1.07563	validation_1-rmse:1.40291
# [30]	validation_0-rmse:1.03032	validation_1-rmse:1.36531
# [31]	validation_0-rmse:0.98992	validation_1-rmse:1.33582
# [32]	validation_0-rmse:0.95410	validation_1-rmse:1.30537
# [33]	validation_0-rmse:0.92377	validation_1-rmse:1.28331
# [34]	validation_0-rmse:0.89666	validation_1-rmse:1.26070
# [35]	validation_0-rmse:0.87067	validation_1-rmse:1.23842
# [36]	validation_0-rmse:0.84844	validation_1-rmse:1.21540
# [37]	validation_0-rmse:0.82913	validation_1-rmse:1.19529
# [38]	validation_0-rmse:0.81178	validation_1-rmse:1.17884
# [39]	validation_0-rmse:0.79593	validation_1-rmse:1.15885
# [40]	validation_0-rmse:0.78243	validation_1-rmse:1.14512
# [41]	validation_0-rmse:0.76444	validation_1-rmse:1.12381
# [42]	validation_0-rmse:0.75426	validation_1-rmse:1.11423
# [43]	validation_0-rmse:0.74496	validation_1-rmse:1.10222
# [44]	validation_0-rmse:0.73078	validation_1-rmse:1.08613
# [45]	validation_0-rmse:0.71873	validation_1-rmse:1.07329
# [46]	validation_0-rmse:0.70877	validation_1-rmse:1.05981
# [47]	validation_0-rmse:0.70290	validation_1-rmse:1.04846
# [48]	validation_0-rmse:0.69840	validation_1-rmse:1.03922
# [49]	validation_0-rmse:0.69277	validation_1-rmse:1.03441
# [50]	validation_0-rmse:0.68893	validation_1-rmse:1.02727
# [51]	validation_0-rmse:0.68529	validation_1-rmse:1.02185
# [52]	validation_0-rmse:0.67853	validation_1-rmse:1.01394
# [53]	validation_0-rmse:0.67575	validation_1-rmse:1.00940
# [54]	validation_0-rmse:0.67324	validation_1-rmse:1.00250
# [55]	validation_0-rmse:0.67100	validation_1-rmse:0.99875
# [56]	validation_0-rmse:0.66581	validation_1-rmse:0.99212
# [57]	validation_0-rmse:0.66392	validation_1-rmse:0.98612
# [58]	validation_0-rmse:0.66079	validation_1-rmse:0.98412
# [59]	validation_0-rmse:0.65958	validation_1-rmse:0.97936
# [60]	validation_0-rmse:0.65675	validation_1-rmse:0.97706
# [61]	validation_0-rmse:0.65277	validation_1-rmse:0.97216
# [62]	validation_0-rmse:0.65044	validation_1-rmse:0.97028
# [63]	validation_0-rmse:0.64920	validation_1-rmse:0.96538
# [64]	validation_0-rmse:0.64841	validation_1-rmse:0.96146
# [65]	validation_0-rmse:0.64677	validation_1-rmse:0.96078
# [66]	validation_0-rmse:0.64615	validation_1-rmse:0.95724
# [67]	validation_0-rmse:0.64434	validation_1-rmse:0.95593
# [68]	validation_0-rmse:0.64107	validation_1-rmse:0.95212
# [69]	validation_0-rmse:0.63945	validation_1-rmse:0.95126
# [70]	validation_0-rmse:0.63931	validation_1-rmse:0.95074
# [71]	validation_0-rmse:0.63738	validation_1-rmse:0.94880
# [72]	validation_0-rmse:0.63569	validation_1-rmse:0.94850
# [73]	validation_0-rmse:0.63521	validation_1-rmse:0.94539
# [74]	validation_0-rmse:0.63210	validation_1-rmse:0.94195
# [75]	validation_0-rmse:0.63203	validation_1-rmse:0.94159
# [76]	validation_0-rmse:0.63123	validation_1-rmse:0.93782
# [77]	validation_0-rmse:0.63118	validation_1-rmse:0.93754
# [78]	validation_0-rmse:0.63112	validation_1-rmse:0.93711
# [79]	validation_0-rmse:0.62849	validation_1-rmse:0.93438
# [80]	validation_0-rmse:0.62545	validation_1-rmse:0.93156
# [81]	validation_0-rmse:0.62543	validation_1-rmse:0.93137
# [82]	validation_0-rmse:0.62543	validation_1-rmse:0.93138
# [83]	validation_0-rmse:0.62292	validation_1-rmse:0.92919
# [84]	validation_0-rmse:0.62290	validation_1-rmse:0.92884
# [85]	validation_0-rmse:0.62289	validation_1-rmse:0.92872
# [0]	validation_0-rmse:7.75692	validation_1-rmse:7.26399
# [1]	validation_0-rmse:7.17411	validation_1-rmse:6.69794
# [2]	validation_0-rmse:6.63418	validation_1-rmse:6.17302
# [3]	validation_0-rmse:6.13848	validation_1-rmse:5.70326
# [4]	validation_0-rmse:5.68053	validation_1-rmse:5.25911
# [5]	validation_0-rmse:5.26172	validation_1-rmse:4.85387
# [6]	validation_0-rmse:4.87380	validation_1-rmse:4.48604
# [7]	validation_0-rmse:4.51473	validation_1-rmse:4.13968
# [8]	validation_0-rmse:4.18397	validation_1-rmse:3.82403
# [9]	validation_0-rmse:3.88013	validation_1-rmse:3.53830
# [10]	validation_0-rmse:3.60006	validation_1-rmse:3.27222
# [11]	validation_0-rmse:3.34003	validation_1-rmse:3.02559
# [12]	validation_0-rmse:3.10483	validation_1-rmse:2.80745
# [13]	validation_0-rmse:2.88508	validation_1-rmse:2.60397
# [14]	validation_0-rmse:2.68365	validation_1-rmse:2.41331
# [15]	validation_0-rmse:2.50273	validation_1-rmse:2.24462
# [16]	validation_0-rmse:2.33506	validation_1-rmse:2.10556
# [17]	validation_0-rmse:2.18032	validation_1-rmse:1.96156
# [18]	validation_0-rmse:2.03778	validation_1-rmse:1.83253
# [19]	validation_0-rmse:1.91079	validation_1-rmse:1.71508
# [20]	validation_0-rmse:1.79428	validation_1-rmse:1.60884
# [21]	validation_0-rmse:1.68737	validation_1-rmse:1.51115
# [22]	validation_0-rmse:1.59129	validation_1-rmse:1.42523
# [23]	validation_0-rmse:1.50259	validation_1-rmse:1.34852
# [24]	validation_0-rmse:1.42098	validation_1-rmse:1.27593
# [25]	validation_0-rmse:1.34951	validation_1-rmse:1.21402
# [26]	validation_0-rmse:1.28525	validation_1-rmse:1.15911
# [27]	validation_0-rmse:1.22446	validation_1-rmse:1.11099
# [28]	validation_0-rmse:1.17121	validation_1-rmse:1.06283
# [29]	validation_0-rmse:1.12267	validation_1-rmse:1.01761
# [30]	validation_0-rmse:1.07962	validation_1-rmse:0.97930
# [31]	validation_0-rmse:1.04251	validation_1-rmse:0.94712
# [32]	validation_0-rmse:1.00885	validation_1-rmse:0.91854
# [33]	validation_0-rmse:0.97951	validation_1-rmse:0.89373
# [34]	validation_0-rmse:0.95429	validation_1-rmse:0.87276
# [35]	validation_0-rmse:0.93129	validation_1-rmse:0.85527
# [36]	validation_0-rmse:0.90719	validation_1-rmse:0.83498
# [37]	validation_0-rmse:0.88873	validation_1-rmse:0.81783
# [38]	validation_0-rmse:0.87197	validation_1-rmse:0.80350
# [39]	validation_0-rmse:0.85721	validation_1-rmse:0.79130
# [40]	validation_0-rmse:0.84183	validation_1-rmse:0.77927
# [41]	validation_0-rmse:0.82978	validation_1-rmse:0.76916
# [42]	validation_0-rmse:0.81934	validation_1-rmse:0.76025
# [43]	validation_0-rmse:0.80735	validation_1-rmse:0.75220
# [44]	validation_0-rmse:0.79951	validation_1-rmse:0.74719
# [45]	validation_0-rmse:0.79097	validation_1-rmse:0.74473
# [46]	validation_0-rmse:0.78391	validation_1-rmse:0.74014
# [47]	validation_0-rmse:0.77757	validation_1-rmse:0.73752
# [48]	validation_0-rmse:0.76355	validation_1-rmse:0.72859
# [49]	validation_0-rmse:0.75851	validation_1-rmse:0.72554
# [50]	validation_0-rmse:0.75381	validation_1-rmse:0.72310
# [51]	validation_0-rmse:0.74976	validation_1-rmse:0.72196
# [52]	validation_0-rmse:0.74590	validation_1-rmse:0.72039
# [53]	validation_0-rmse:0.74026	validation_1-rmse:0.71891
# [54]	validation_0-rmse:0.73709	validation_1-rmse:0.71717
# [55]	validation_0-rmse:0.73426	validation_1-rmse:0.71585
# [56]	validation_0-rmse:0.73172	validation_1-rmse:0.71599
# [57]	validation_0-rmse:0.72157	validation_1-rmse:0.71080
# [58]	validation_0-rmse:0.71929	validation_1-rmse:0.71035
# [59]	validation_0-rmse:0.70921	validation_1-rmse:0.71008
# [60]	validation_0-rmse:0.70716	validation_1-rmse:0.70954
# [61]	validation_0-rmse:0.70453	validation_1-rmse:0.71128
# [62]	validation_0-rmse:0.70273	validation_1-rmse:0.71054
# [63]	validation_0-rmse:0.70112	validation_1-rmse:0.71051
# [64]	validation_0-rmse:0.69956	validation_1-rmse:0.71048
# [65]	validation_0-rmse:0.69151	validation_1-rmse:0.70779
# [66]	validation_0-rmse:0.69008	validation_1-rmse:0.70757
# [67]	validation_0-rmse:0.68880	validation_1-rmse:0.70722
# [68]	validation_0-rmse:0.68468	validation_1-rmse:0.71179
# [69]	validation_0-rmse:0.68333	validation_1-rmse:0.71215
# [70]	validation_0-rmse:0.68220	validation_1-rmse:0.71219
# [71]	validation_0-rmse:0.67606	validation_1-rmse:0.70981
# [72]	validation_0-rmse:0.67064	validation_1-rmse:0.70809
# [73]	validation_0-rmse:0.66718	validation_1-rmse:0.71252
# [74]	validation_0-rmse:0.66611	validation_1-rmse:0.71289
# [75]	validation_0-rmse:0.66136	validation_1-rmse:0.71180
# [76]	validation_0-rmse:0.66077	validation_1-rmse:0.71283
# [77]	validation_0-rmse:0.65719	validation_1-rmse:0.71706
# [78]	validation_0-rmse:0.65319	validation_1-rmse:0.71579
# [79]	validation_0-rmse:0.65226	validation_1-rmse:0.71587
# [80]	validation_0-rmse:0.65177	validation_1-rmse:0.71671
# [81]	validation_0-rmse:0.64879	validation_1-rmse:0.72085
# [82]	validation_0-rmse:0.64351	validation_1-rmse:0.72340
# [83]	validation_0-rmse:0.64290	validation_1-rmse:0.72399
# [84]	validation_0-rmse:0.64199	validation_1-rmse:0.72539
# [85]	validation_0-rmse:0.64158	validation_1-rmse:0.72621
# [0]	validation_0-rmse:7.50726	validation_1-rmse:8.30704
# [1]	validation_0-rmse:6.94227	validation_1-rmse:7.74371
# [2]	validation_0-rmse:6.42115	validation_1-rmse:7.18682
# [3]	validation_0-rmse:5.94286	validation_1-rmse:6.67430
# [4]	validation_0-rmse:5.50150	validation_1-rmse:6.20130
# [5]	validation_0-rmse:5.09213	validation_1-rmse:5.76370
# [6]	validation_0-rmse:4.71810	validation_1-rmse:5.36224
# [7]	validation_0-rmse:4.37505	validation_1-rmse:4.99394
# [8]	validation_0-rmse:4.06002	validation_1-rmse:4.62242
# [9]	validation_0-rmse:3.76774	validation_1-rmse:4.27415
# [10]	validation_0-rmse:3.49937	validation_1-rmse:3.95232
# [11]	validation_0-rmse:3.25232	validation_1-rmse:3.68324
# [12]	validation_0-rmse:3.02615	validation_1-rmse:3.40655
# [13]	validation_0-rmse:2.82340	validation_1-rmse:3.18114
# [14]	validation_0-rmse:2.63256	validation_1-rmse:2.94325
# [15]	validation_0-rmse:2.46006	validation_1-rmse:2.73446
# [16]	validation_0-rmse:2.29854	validation_1-rmse:2.53122
# [17]	validation_0-rmse:2.15123	validation_1-rmse:2.36544
# [18]	validation_0-rmse:2.01694	validation_1-rmse:2.21142
# [19]	validation_0-rmse:1.89256	validation_1-rmse:2.05029
# [20]	validation_0-rmse:1.78000	validation_1-rmse:1.90914
# [21]	validation_0-rmse:1.67793	validation_1-rmse:1.77444
# [22]	validation_0-rmse:1.58726	validation_1-rmse:1.65650
# [23]	validation_0-rmse:1.50315	validation_1-rmse:1.54691
# [24]	validation_0-rmse:1.42773	validation_1-rmse:1.44695
# [25]	validation_0-rmse:1.35660	validation_1-rmse:1.35254
# [26]	validation_0-rmse:1.29550	validation_1-rmse:1.26932
# [27]	validation_0-rmse:1.23992	validation_1-rmse:1.19230
# [28]	validation_0-rmse:1.19146	validation_1-rmse:1.12450
# [29]	validation_0-rmse:1.14478	validation_1-rmse:1.06026
# [30]	validation_0-rmse:1.10421	validation_1-rmse:1.00318
# [31]	validation_0-rmse:1.06866	validation_1-rmse:0.95355
# [32]	validation_0-rmse:1.03636	validation_1-rmse:0.90456
# [33]	validation_0-rmse:1.00687	validation_1-rmse:0.86452
# [34]	validation_0-rmse:0.98187	validation_1-rmse:0.82953
# [35]	validation_0-rmse:0.95974	validation_1-rmse:0.80192
# [36]	validation_0-rmse:0.93962	validation_1-rmse:0.77521
# [37]	validation_0-rmse:0.92212	validation_1-rmse:0.75181
# [38]	validation_0-rmse:0.90586	validation_1-rmse:0.73184
# [39]	validation_0-rmse:0.89121	validation_1-rmse:0.70764
# [40]	validation_0-rmse:0.87688	validation_1-rmse:0.69054
# [41]	validation_0-rmse:0.86562	validation_1-rmse:0.67700
# [42]	validation_0-rmse:0.85472	validation_1-rmse:0.66449
# [43]	validation_0-rmse:0.84528	validation_1-rmse:0.65324
# [44]	validation_0-rmse:0.83686	validation_1-rmse:0.64348
# [45]	validation_0-rmse:0.82718	validation_1-rmse:0.63244
# [46]	validation_0-rmse:0.81999	validation_1-rmse:0.62545
# [47]	validation_0-rmse:0.80620	validation_1-rmse:0.61418
# [48]	validation_0-rmse:0.79913	validation_1-rmse:0.60754
# [49]	validation_0-rmse:0.79387	validation_1-rmse:0.60352
# [50]	validation_0-rmse:0.78946	validation_1-rmse:0.60053
# [51]	validation_0-rmse:0.78496	validation_1-rmse:0.59691
# [52]	validation_0-rmse:0.77481	validation_1-rmse:0.59015
# [53]	validation_0-rmse:0.76600	validation_1-rmse:0.58398
# [54]	validation_0-rmse:0.76179	validation_1-rmse:0.58291
# [55]	validation_0-rmse:0.75811	validation_1-rmse:0.58260
# [56]	validation_0-rmse:0.75525	validation_1-rmse:0.58155
# [57]	validation_0-rmse:0.75141	validation_1-rmse:0.58164
# [58]	validation_0-rmse:0.74898	validation_1-rmse:0.57856
# [59]	validation_0-rmse:0.74690	validation_1-rmse:0.57713
# [60]	validation_0-rmse:0.74436	validation_1-rmse:0.57989
# [61]	validation_0-rmse:0.74240	validation_1-rmse:0.57891
# [62]	validation_0-rmse:0.73518	validation_1-rmse:0.57560
# [63]	validation_0-rmse:0.72843	validation_1-rmse:0.57286
# [64]	validation_0-rmse:0.72670	validation_1-rmse:0.57299
# [65]	validation_0-rmse:0.72512	validation_1-rmse:0.57330
# [66]	validation_0-rmse:0.72323	validation_1-rmse:0.57670
# [67]	validation_0-rmse:0.72055	validation_1-rmse:0.57752
# [68]	validation_0-rmse:0.71917	validation_1-rmse:0.57806
# [69]	validation_0-rmse:0.71367	validation_1-rmse:0.57676
# [70]	validation_0-rmse:0.71242	validation_1-rmse:0.57735
# [71]	validation_0-rmse:0.71093	validation_1-rmse:0.58090
# [72]	validation_0-rmse:0.70828	validation_1-rmse:0.58097
# [73]	validation_0-rmse:0.70365	validation_1-rmse:0.58027
# [74]	validation_0-rmse:0.70256	validation_1-rmse:0.58073
# [75]	validation_0-rmse:0.70156	validation_1-rmse:0.58149
# [76]	validation_0-rmse:0.70064	validation_1-rmse:0.58350
# [77]	validation_0-rmse:0.69943	validation_1-rmse:0.58483
# [78]	validation_0-rmse:0.69703	validation_1-rmse:0.58444
# [79]	validation_0-rmse:0.69650	validation_1-rmse:0.58562
# [80]	validation_0-rmse:0.69252	validation_1-rmse:0.58514
# [81]	validation_0-rmse:0.69203	validation_1-rmse:0.58567
# [82]	validation_0-rmse:0.69130	validation_1-rmse:0.58592
# [83]	validation_0-rmse:0.69079	validation_1-rmse:0.58549
# [0]	validation_0-rmse:7.45460	validation_1-rmse:8.48798
# [1]	validation_0-rmse:6.89143	validation_1-rmse:7.93428
# [2]	validation_0-rmse:6.37144	validation_1-rmse:7.39437
# [3]	validation_0-rmse:5.89050	validation_1-rmse:6.89666
# [4]	validation_0-rmse:5.44925	validation_1-rmse:6.43964
# [5]	validation_0-rmse:5.04272	validation_1-rmse:6.01909
# [6]	validation_0-rmse:4.66709	validation_1-rmse:5.63039
# [7]	validation_0-rmse:4.32389	validation_1-rmse:5.27581
# [8]	validation_0-rmse:4.00470	validation_1-rmse:4.94337
# [9]	validation_0-rmse:3.71590	validation_1-rmse:4.64412
# [10]	validation_0-rmse:3.44640	validation_1-rmse:4.36236
# [11]	validation_0-rmse:3.20097	validation_1-rmse:4.10695
# [12]	validation_0-rmse:2.97445	validation_1-rmse:3.86501
# [13]	validation_0-rmse:2.76597	validation_1-rmse:3.64433
# [14]	validation_0-rmse:2.56992	validation_1-rmse:3.44879
# [15]	validation_0-rmse:2.39508	validation_1-rmse:3.26277
# [16]	validation_0-rmse:2.23307	validation_1-rmse:3.08152
# [17]	validation_0-rmse:2.08300	validation_1-rmse:2.93424
# [18]	validation_0-rmse:1.94621	validation_1-rmse:2.77954
# [19]	validation_0-rmse:1.82027	validation_1-rmse:2.64320
# [20]	validation_0-rmse:1.70658	validation_1-rmse:2.51289
# [21]	validation_0-rmse:1.60064	validation_1-rmse:2.41048
# [22]	validation_0-rmse:1.50735	validation_1-rmse:2.30075
# [23]	validation_0-rmse:1.41875	validation_1-rmse:2.21616
# [24]	validation_0-rmse:1.33689	validation_1-rmse:2.13524
# [25]	validation_0-rmse:1.26553	validation_1-rmse:2.04729
# [26]	validation_0-rmse:1.19993	validation_1-rmse:1.97210
# [27]	validation_0-rmse:1.14042	validation_1-rmse:1.89947
# [28]	validation_0-rmse:1.08940	validation_1-rmse:1.83999
# [29]	validation_0-rmse:1.04203	validation_1-rmse:1.79115
# [30]	validation_0-rmse:0.99547	validation_1-rmse:1.73725
# [31]	validation_0-rmse:0.95426	validation_1-rmse:1.68873
# [32]	validation_0-rmse:0.91086	validation_1-rmse:1.64403
# [33]	validation_0-rmse:0.87192	validation_1-rmse:1.60215
# [34]	validation_0-rmse:0.84470	validation_1-rmse:1.56648
# [35]	validation_0-rmse:0.82103	validation_1-rmse:1.53500
# [36]	validation_0-rmse:0.79204	validation_1-rmse:1.50465
# [37]	validation_0-rmse:0.77158	validation_1-rmse:1.47360
# [38]	validation_0-rmse:0.75456	validation_1-rmse:1.45235
# [39]	validation_0-rmse:0.73654	validation_1-rmse:1.43150
# [40]	validation_0-rmse:0.71699	validation_1-rmse:1.41379
# [41]	validation_0-rmse:0.70541	validation_1-rmse:1.39201
# [42]	validation_0-rmse:0.69559	validation_1-rmse:1.37686
# [43]	validation_0-rmse:0.68220	validation_1-rmse:1.36768
# [44]	validation_0-rmse:0.66955	validation_1-rmse:1.35340
# [45]	validation_0-rmse:0.66196	validation_1-rmse:1.34078
# [46]	validation_0-rmse:0.65197	validation_1-rmse:1.33299
# [47]	validation_0-rmse:0.64642	validation_1-rmse:1.32028
# [48]	validation_0-rmse:0.64145	validation_1-rmse:1.30915
# [49]	validation_0-rmse:0.63444	validation_1-rmse:1.30432
# [50]	validation_0-rmse:0.63056	validation_1-rmse:1.29427
# [51]	validation_0-rmse:0.62673	validation_1-rmse:1.28668
# [52]	validation_0-rmse:0.62063	validation_1-rmse:1.28319
# [53]	validation_0-rmse:0.61758	validation_1-rmse:1.27517
# [54]	validation_0-rmse:0.61524	validation_1-rmse:1.26769
# [55]	validation_0-rmse:0.61193	validation_1-rmse:1.26534
# [56]	validation_0-rmse:0.60802	validation_1-rmse:1.26391
# [57]	validation_0-rmse:0.60410	validation_1-rmse:1.26372
# [58]	validation_0-rmse:0.60241	validation_1-rmse:1.25756
# [59]	validation_0-rmse:0.60045	validation_1-rmse:1.25388
# [60]	validation_0-rmse:0.59892	validation_1-rmse:1.25039
# [61]	validation_0-rmse:0.59696	validation_1-rmse:1.24668
# [62]	validation_0-rmse:0.59573	validation_1-rmse:1.24285
# [63]	validation_0-rmse:0.59230	validation_1-rmse:1.24212
# [64]	validation_0-rmse:0.59117	validation_1-rmse:1.23939
# [65]	validation_0-rmse:0.58908	validation_1-rmse:1.23836
# [66]	validation_0-rmse:0.58889	validation_1-rmse:1.23755
# [67]	validation_0-rmse:0.58739	validation_1-rmse:1.23934
# [68]	validation_0-rmse:0.58723	validation_1-rmse:1.23859
# [69]	validation_0-rmse:0.58544	validation_1-rmse:1.23722
# [70]	validation_0-rmse:0.58532	validation_1-rmse:1.23658
# [71]	validation_0-rmse:0.58450	validation_1-rmse:1.23475
# [72]	validation_0-rmse:0.58444	validation_1-rmse:1.23439
# [73]	validation_0-rmse:0.58435	validation_1-rmse:1.23388
# [74]	validation_0-rmse:0.58348	validation_1-rmse:1.23187
# [75]	validation_0-rmse:0.58340	validation_1-rmse:1.23126
# [76]	validation_0-rmse:0.58334	validation_1-rmse:1.23083
# [77]	validation_0-rmse:0.58215	validation_1-rmse:1.23008
# [78]	validation_0-rmse:0.58212	validation_1-rmse:1.22984
# [79]	validation_0-rmse:0.58211	validation_1-rmse:1.22975
# [80]	validation_0-rmse:0.58069	validation_1-rmse:1.22954
# [81]	validation_0-rmse:0.58067	validation_1-rmse:1.22929
# [82]	validation_0-rmse:0.57788	validation_1-rmse:1.23345
# [83]	validation_0-rmse:0.57497	validation_1-rmse:1.23408
# [84]	validation_0-rmse:0.57231	validation_1-rmse:1.23495
# [85]	validation_0-rmse:0.57231	validation_1-rmse:1.23494
# [0]	validation_0-rmse:7.54517	validation_1-rmse:8.13879
# [1]	validation_0-rmse:6.97735	validation_1-rmse:7.55399
# [2]	validation_0-rmse:6.45293	validation_1-rmse:7.01498
# [3]	validation_0-rmse:5.96852	validation_1-rmse:6.51777
# [4]	validation_0-rmse:5.52292	validation_1-rmse:6.06051
# [5]	validation_0-rmse:5.11581	validation_1-rmse:5.64340
# [6]	validation_0-rmse:4.73677	validation_1-rmse:5.25569
# [7]	validation_0-rmse:4.39142	validation_1-rmse:4.91710
# [8]	validation_0-rmse:4.06954	validation_1-rmse:4.58233
# [9]	validation_0-rmse:3.77445	validation_1-rmse:4.27958
# [10]	validation_0-rmse:3.50317	validation_1-rmse:3.99378
# [11]	validation_0-rmse:3.25500	validation_1-rmse:3.72424
# [12]	validation_0-rmse:3.02555	validation_1-rmse:3.48782
# [13]	validation_0-rmse:2.81069	validation_1-rmse:3.26609
# [14]	validation_0-rmse:2.61719	validation_1-rmse:3.05981
# [15]	validation_0-rmse:2.44349	validation_1-rmse:2.87476
# [16]	validation_0-rmse:2.28106	validation_1-rmse:2.69383
# [17]	validation_0-rmse:2.13303	validation_1-rmse:2.53705
# [18]	validation_0-rmse:1.99826	validation_1-rmse:2.38420
# [19]	validation_0-rmse:1.87414	validation_1-rmse:2.24323
# [20]	validation_0-rmse:1.76073	validation_1-rmse:2.11386
# [21]	validation_0-rmse:1.65780	validation_1-rmse:2.00682
# [22]	validation_0-rmse:1.56346	validation_1-rmse:1.89736
# [23]	validation_0-rmse:1.47779	validation_1-rmse:1.80351
# [24]	validation_0-rmse:1.40204	validation_1-rmse:1.72441
# [25]	validation_0-rmse:1.33194	validation_1-rmse:1.64110
# [26]	validation_0-rmse:1.26844	validation_1-rmse:1.56494
# [27]	validation_0-rmse:1.21266	validation_1-rmse:1.49647
# [28]	validation_0-rmse:1.15963	validation_1-rmse:1.43333
# [29]	validation_0-rmse:1.11239	validation_1-rmse:1.37161
# [30]	validation_0-rmse:1.07220	validation_1-rmse:1.32163
# [31]	validation_0-rmse:1.03644	validation_1-rmse:1.27337
# [32]	validation_0-rmse:1.00352	validation_1-rmse:1.23188
# [33]	validation_0-rmse:0.97272	validation_1-rmse:1.19046
# [34]	validation_0-rmse:0.94569	validation_1-rmse:1.15958
# [35]	validation_0-rmse:0.92217	validation_1-rmse:1.12211
# [36]	validation_0-rmse:0.90292	validation_1-rmse:1.09446
# [37]	validation_0-rmse:0.88552	validation_1-rmse:1.06699
# [38]	validation_0-rmse:0.87064	validation_1-rmse:1.04407
# [39]	validation_0-rmse:0.84996	validation_1-rmse:1.01065
# [40]	validation_0-rmse:0.83208	validation_1-rmse:0.98035
# [41]	validation_0-rmse:0.82066	validation_1-rmse:0.96509
# [42]	validation_0-rmse:0.81123	validation_1-rmse:0.94663
# [43]	validation_0-rmse:0.80215	validation_1-rmse:0.93100
# [44]	validation_0-rmse:0.79347	validation_1-rmse:0.92313
# [45]	validation_0-rmse:0.78708	validation_1-rmse:0.90858
# [46]	validation_0-rmse:0.77602	validation_1-rmse:0.89557
# [47]	validation_0-rmse:0.76921	validation_1-rmse:0.89184
# [48]	validation_0-rmse:0.76440	validation_1-rmse:0.88816
# [49]	validation_0-rmse:0.75969	validation_1-rmse:0.87621
# [50]	validation_0-rmse:0.75557	validation_1-rmse:0.86568
# [51]	validation_0-rmse:0.75194	validation_1-rmse:0.85584
# [52]	validation_0-rmse:0.74809	validation_1-rmse:0.84731
# [53]	validation_0-rmse:0.74483	validation_1-rmse:0.83855
# [54]	validation_0-rmse:0.73751	validation_1-rmse:0.82985
# [55]	validation_0-rmse:0.73487	validation_1-rmse:0.82188
# [56]	validation_0-rmse:0.73243	validation_1-rmse:0.81405
# [57]	validation_0-rmse:0.72967	validation_1-rmse:0.80925
# [58]	validation_0-rmse:0.72781	validation_1-rmse:0.80227
# [59]	validation_0-rmse:0.72521	validation_1-rmse:0.79878
# [60]	validation_0-rmse:0.72343	validation_1-rmse:0.79254
# [61]	validation_0-rmse:0.72192	validation_1-rmse:0.78670
# [62]	validation_0-rmse:0.72015	validation_1-rmse:0.78621
# [63]	validation_0-rmse:0.71881	validation_1-rmse:0.78042
# [64]	validation_0-rmse:0.71747	validation_1-rmse:0.77487
# [65]	validation_0-rmse:0.71658	validation_1-rmse:0.76958
# [66]	validation_0-rmse:0.71550	validation_1-rmse:0.76453
# [67]	validation_0-rmse:0.71446	validation_1-rmse:0.75800
# [68]	validation_0-rmse:0.71377	validation_1-rmse:0.75345
# [69]	validation_0-rmse:0.70870	validation_1-rmse:0.74745
# [70]	validation_0-rmse:0.70428	validation_1-rmse:0.74230
# [71]	validation_0-rmse:0.70220	validation_1-rmse:0.74136
# [72]	validation_0-rmse:0.70168	validation_1-rmse:0.73707
# [73]	validation_0-rmse:0.70087	validation_1-rmse:0.73351
# [74]	validation_0-rmse:0.69705	validation_1-rmse:0.72923
# [75]	validation_0-rmse:0.69696	validation_1-rmse:0.72895
# [76]	validation_0-rmse:0.69630	validation_1-rmse:0.72626
# [77]	validation_0-rmse:0.69302	validation_1-rmse:0.72282
# [78]	validation_0-rmse:0.69005	validation_1-rmse:0.71921
# [79]	validation_0-rmse:0.69001	validation_1-rmse:0.71905
# [80]	validation_0-rmse:0.68996	validation_1-rmse:0.71881
# [81]	validation_0-rmse:0.68993	validation_1-rmse:0.71867
# [82]	validation_0-rmse:0.68791	validation_1-rmse:0.71437
# [83]	validation_0-rmse:0.68546	validation_1-rmse:0.71180
# [84]	validation_0-rmse:0.68311	validation_1-rmse:0.70992
# [85]	validation_0-rmse:0.68067	validation_1-rmse:0.71170
# [0]	validation_0-rmse:7.64127	validation_1-rmse:7.78142
# [1]	validation_0-rmse:7.06595	validation_1-rmse:7.23404
# [2]	validation_0-rmse:6.53443	validation_1-rmse:6.72843
# [3]	validation_0-rmse:6.04603	validation_1-rmse:6.26376
# [4]	validation_0-rmse:5.59399	validation_1-rmse:5.82888
# [5]	validation_0-rmse:5.17782	validation_1-rmse:5.42769
# [6]	validation_0-rmse:4.79374	validation_1-rmse:5.06550
# [7]	validation_0-rmse:4.43855	validation_1-rmse:4.72295
# [8]	validation_0-rmse:4.11152	validation_1-rmse:4.41565
# [9]	validation_0-rmse:3.81468	validation_1-rmse:4.13641
# [10]	validation_0-rmse:3.53726	validation_1-rmse:3.86689
# [11]	validation_0-rmse:3.28394	validation_1-rmse:3.62515
# [12]	validation_0-rmse:3.04962	validation_1-rmse:3.39853
# [13]	validation_0-rmse:2.83219	validation_1-rmse:3.18847
# [14]	validation_0-rmse:2.63348	validation_1-rmse:3.00989
# [15]	validation_0-rmse:2.45097	validation_1-rmse:2.83490
# [16]	validation_0-rmse:2.28423	validation_1-rmse:2.68030
# [17]	validation_0-rmse:2.12994	validation_1-rmse:2.53308
# [18]	validation_0-rmse:1.98812	validation_1-rmse:2.40398
# [19]	validation_0-rmse:1.85899	validation_1-rmse:2.28545
# [20]	validation_0-rmse:1.74112	validation_1-rmse:2.17754
# [21]	validation_0-rmse:1.63277	validation_1-rmse:2.07805
# [22]	validation_0-rmse:1.53416	validation_1-rmse:1.99559
# [23]	validation_0-rmse:1.44336	validation_1-rmse:1.91287
# [24]	validation_0-rmse:1.36307	validation_1-rmse:1.83943
# [25]	validation_0-rmse:1.28933	validation_1-rmse:1.77252
# [26]	validation_0-rmse:1.22117	validation_1-rmse:1.70687
# [27]	validation_0-rmse:1.16012	validation_1-rmse:1.65250
# [28]	validation_0-rmse:1.10679	validation_1-rmse:1.60754
# [29]	validation_0-rmse:1.05595	validation_1-rmse:1.56052
# [30]	validation_0-rmse:1.01102	validation_1-rmse:1.51980
# [31]	validation_0-rmse:0.96694	validation_1-rmse:1.48670
# [32]	validation_0-rmse:0.93083	validation_1-rmse:1.45301
# [33]	validation_0-rmse:0.89859	validation_1-rmse:1.42246
# [34]	validation_0-rmse:0.86621	validation_1-rmse:1.39412
# [35]	validation_0-rmse:0.83954	validation_1-rmse:1.36847
# [36]	validation_0-rmse:0.81617	validation_1-rmse:1.34520
# [37]	validation_0-rmse:0.79570	validation_1-rmse:1.32317
# [38]	validation_0-rmse:0.77442	validation_1-rmse:1.30493
# [39]	validation_0-rmse:0.75715	validation_1-rmse:1.28737
# [40]	validation_0-rmse:0.74089	validation_1-rmse:1.27173
# [41]	validation_0-rmse:0.72862	validation_1-rmse:1.25598
# [42]	validation_0-rmse:0.71612	validation_1-rmse:1.24387
# [43]	validation_0-rmse:0.70601	validation_1-rmse:1.23206
# [44]	validation_0-rmse:0.69633	validation_1-rmse:1.22495
# [45]	validation_0-rmse:0.68859	validation_1-rmse:1.21570
# [46]	validation_0-rmse:0.68144	validation_1-rmse:1.20454
# [47]	validation_0-rmse:0.67467	validation_1-rmse:1.19697
# [48]	validation_0-rmse:0.66915	validation_1-rmse:1.18773
# [49]	validation_0-rmse:0.66466	validation_1-rmse:1.18001
# [50]	validation_0-rmse:0.65527	validation_1-rmse:1.16838
# [51]	validation_0-rmse:0.65130	validation_1-rmse:1.15946
# [52]	validation_0-rmse:0.64658	validation_1-rmse:1.16027
# [53]	validation_0-rmse:0.63895	validation_1-rmse:1.15123
# [54]	validation_0-rmse:0.63236	validation_1-rmse:1.14320
# [55]	validation_0-rmse:0.62967	validation_1-rmse:1.13636
# [56]	validation_0-rmse:0.62721	validation_1-rmse:1.13116
# [57]	validation_0-rmse:0.62490	validation_1-rmse:1.12467
# [58]	validation_0-rmse:0.61963	validation_1-rmse:1.11854
# [59]	validation_0-rmse:0.61742	validation_1-rmse:1.11276
# [60]	validation_0-rmse:0.61284	validation_1-rmse:1.10729
# [61]	validation_0-rmse:0.61124	validation_1-rmse:1.10557
# [62]	validation_0-rmse:0.60981	validation_1-rmse:1.10083
# [63]	validation_0-rmse:0.60857	validation_1-rmse:1.09487
# [64]	validation_0-rmse:0.60768	validation_1-rmse:1.09034
# [65]	validation_0-rmse:0.60685	validation_1-rmse:1.08601
# [66]	validation_0-rmse:0.60454	validation_1-rmse:1.08988
# [67]	validation_0-rmse:0.60383	validation_1-rmse:1.08601
# [68]	validation_0-rmse:0.60256	validation_1-rmse:1.08297
# [69]	validation_0-rmse:0.60035	validation_1-rmse:1.08595
# [70]	validation_0-rmse:0.60021	validation_1-rmse:1.08486
# [71]	validation_0-rmse:0.59968	validation_1-rmse:1.08178
# [72]	validation_0-rmse:0.59633	validation_1-rmse:1.07880
# [73]	validation_0-rmse:0.59618	validation_1-rmse:1.07730
# [74]	validation_0-rmse:0.59313	validation_1-rmse:1.07404
# [75]	validation_0-rmse:0.59306	validation_1-rmse:1.07309
# [76]	validation_0-rmse:0.59081	validation_1-rmse:1.07881
# [77]	validation_0-rmse:0.59080	validation_1-rmse:1.07849
# [78]	validation_0-rmse:0.58994	validation_1-rmse:1.07637
# [79]	validation_0-rmse:0.58993	validation_1-rmse:1.07619
# [80]	validation_0-rmse:0.58648	validation_1-rmse:1.07011
# [81]	validation_0-rmse:0.58646	validation_1-rmse:1.06973
# [82]	validation_0-rmse:0.58641	validation_1-rmse:1.06823
# [83]	validation_0-rmse:0.58542	validation_1-rmse:1.06867
# [84]	validation_0-rmse:0.58261	validation_1-rmse:1.06461
# [85]	validation_0-rmse:0.58260	validation_1-rmse:1.06415
# [0]	validation_0-rmse:7.63312	validation_1-rmse:7.75816
# [1]	validation_0-rmse:7.05731	validation_1-rmse:7.18422
# [2]	validation_0-rmse:6.52571	validation_1-rmse:6.65508
# [3]	validation_0-rmse:6.03773	validation_1-rmse:6.17022
# [4]	validation_0-rmse:5.58655	validation_1-rmse:5.72248
# [5]	validation_0-rmse:5.17415	validation_1-rmse:5.31399
# [6]	validation_0-rmse:4.79059	validation_1-rmse:4.93490
# [7]	validation_0-rmse:4.44043	validation_1-rmse:4.58941
# [8]	validation_0-rmse:4.11605	validation_1-rmse:4.26359
# [9]	validation_0-rmse:3.81859	validation_1-rmse:3.96494
# [10]	validation_0-rmse:3.54284	validation_1-rmse:3.67976
# [11]	validation_0-rmse:3.28869	validation_1-rmse:3.42597
# [12]	validation_0-rmse:3.05738	validation_1-rmse:3.20039
# [13]	validation_0-rmse:2.84238	validation_1-rmse:2.98562
# [14]	validation_0-rmse:2.64471	validation_1-rmse:2.79373
# [15]	validation_0-rmse:2.46578	validation_1-rmse:2.61585
# [16]	validation_0-rmse:2.30030	validation_1-rmse:2.45151
# [17]	validation_0-rmse:2.14959	validation_1-rmse:2.30775
# [18]	validation_0-rmse:2.00702	validation_1-rmse:2.16768
# [19]	validation_0-rmse:1.88041	validation_1-rmse:2.04296
# [20]	validation_0-rmse:1.76459	validation_1-rmse:1.92480
# [21]	validation_0-rmse:1.66080	validation_1-rmse:1.82155
# [22]	validation_0-rmse:1.56404	validation_1-rmse:1.73094
# [23]	validation_0-rmse:1.47669	validation_1-rmse:1.64564
# [24]	validation_0-rmse:1.39456	validation_1-rmse:1.57059
# [25]	validation_0-rmse:1.32380	validation_1-rmse:1.50025
# [26]	validation_0-rmse:1.26167	validation_1-rmse:1.43832
# [27]	validation_0-rmse:1.20440	validation_1-rmse:1.38397
# [28]	validation_0-rmse:1.15328	validation_1-rmse:1.33263
# [29]	validation_0-rmse:1.10607	validation_1-rmse:1.28578
# [30]	validation_0-rmse:1.06365	validation_1-rmse:1.24180
# [31]	validation_0-rmse:1.02673	validation_1-rmse:1.20338
# [32]	validation_0-rmse:0.99379	validation_1-rmse:1.17080
# [33]	validation_0-rmse:0.96098	validation_1-rmse:1.14078
# [34]	validation_0-rmse:0.93538	validation_1-rmse:1.11582
# [35]	validation_0-rmse:0.91101	validation_1-rmse:1.08904
# [36]	validation_0-rmse:0.89038	validation_1-rmse:1.06533
# [37]	validation_0-rmse:0.87228	validation_1-rmse:1.04247
# [38]	validation_0-rmse:0.85588	validation_1-rmse:1.02185
# [39]	validation_0-rmse:0.83906	validation_1-rmse:1.00200
# [40]	validation_0-rmse:0.82419	validation_1-rmse:0.98434
# [41]	validation_0-rmse:0.81305	validation_1-rmse:0.97292
# [42]	validation_0-rmse:0.80385	validation_1-rmse:0.96163
# [43]	validation_0-rmse:0.79541	validation_1-rmse:0.95025
# [44]	validation_0-rmse:0.78764	validation_1-rmse:0.94005
# [45]	validation_0-rmse:0.78072	validation_1-rmse:0.92944
# [46]	validation_0-rmse:0.76696	validation_1-rmse:0.91848
# [47]	validation_0-rmse:0.76134	validation_1-rmse:0.91055
# [48]	validation_0-rmse:0.75601	validation_1-rmse:0.90214
# [49]	validation_0-rmse:0.75164	validation_1-rmse:0.89436
# [50]	validation_0-rmse:0.74115	validation_1-rmse:0.88573
# [51]	validation_0-rmse:0.73208	validation_1-rmse:0.87852
# [52]	validation_0-rmse:0.72850	validation_1-rmse:0.87129
# [53]	validation_0-rmse:0.72552	validation_1-rmse:0.86457
# [54]	validation_0-rmse:0.72296	validation_1-rmse:0.86000
# [55]	validation_0-rmse:0.72072	validation_1-rmse:0.85444
# [56]	validation_0-rmse:0.71719	validation_1-rmse:0.85343
# [57]	validation_0-rmse:0.71376	validation_1-rmse:0.84997
# [58]	validation_0-rmse:0.70675	validation_1-rmse:0.84485
# [59]	validation_0-rmse:0.70009	validation_1-rmse:0.84053
# [60]	validation_0-rmse:0.69889	validation_1-rmse:0.83676
# [61]	validation_0-rmse:0.69786	validation_1-rmse:0.83328
# [62]	validation_0-rmse:0.69621	validation_1-rmse:0.83107
# [63]	validation_0-rmse:0.69446	validation_1-rmse:0.82685
# [64]	validation_0-rmse:0.69366	validation_1-rmse:0.82269
# [65]	validation_0-rmse:0.69121	validation_1-rmse:0.82219
# [66]	validation_0-rmse:0.69047	validation_1-rmse:0.81832
# [67]	validation_0-rmse:0.68935	validation_1-rmse:0.81339
# [68]	validation_0-rmse:0.68857	validation_1-rmse:0.81052
# [69]	validation_0-rmse:0.68797	validation_1-rmse:0.80713
# [70]	validation_0-rmse:0.68746	validation_1-rmse:0.80372
# [71]	validation_0-rmse:0.68666	validation_1-rmse:0.79962
# [72]	validation_0-rmse:0.68206	validation_1-rmse:0.79659
# [73]	validation_0-rmse:0.67813	validation_1-rmse:0.79395
# [74]	validation_0-rmse:0.67808	validation_1-rmse:0.79404
# [75]	validation_0-rmse:0.67426	validation_1-rmse:0.79151
# [76]	validation_0-rmse:0.67420	validation_1-rmse:0.79163
# [77]	validation_0-rmse:0.67166	validation_1-rmse:0.79117
# [78]	validation_0-rmse:0.66960	validation_1-rmse:0.79104
# [79]	validation_0-rmse:0.66957	validation_1-rmse:0.79114
# [80]	validation_0-rmse:0.66955	validation_1-rmse:0.79120
# [81]	validation_0-rmse:0.66953	validation_1-rmse:0.79126
# [82]	validation_0-rmse:0.66623	validation_1-rmse:0.78923
# [83]	validation_0-rmse:0.66386	validation_1-rmse:0.79049
# [84]	validation_0-rmse:0.66281	validation_1-rmse:0.78646
# [85]	validation_0-rmse:0.66237	validation_1-rmse:0.78394
# [0]	validation_0-rmse:7.72715	validation_1-rmse:7.36914
# [1]	validation_0-rmse:7.14716	validation_1-rmse:6.78679
# [2]	validation_0-rmse:6.61101	validation_1-rmse:6.24851
# [3]	validation_0-rmse:6.11507	validation_1-rmse:5.75427
# [4]	validation_0-rmse:5.65909	validation_1-rmse:5.29670
# [5]	validation_0-rmse:5.23637	validation_1-rmse:4.87604
# [6]	validation_0-rmse:4.85006	validation_1-rmse:4.48877
# [7]	validation_0-rmse:4.49481	validation_1-rmse:4.13629
# [8]	validation_0-rmse:4.16841	validation_1-rmse:3.80959
# [9]	validation_0-rmse:3.86444	validation_1-rmse:3.50897
# [10]	validation_0-rmse:3.58528	validation_1-rmse:3.23505
# [11]	validation_0-rmse:3.32595	validation_1-rmse:2.99030
# [12]	validation_0-rmse:3.08714	validation_1-rmse:2.75529
# [13]	validation_0-rmse:2.86961	validation_1-rmse:2.54270
# [14]	validation_0-rmse:2.67399	validation_1-rmse:2.34911
# [15]	validation_0-rmse:2.49006	validation_1-rmse:2.16836
# [16]	validation_0-rmse:2.32150	validation_1-rmse:2.01324
# [17]	validation_0-rmse:2.16726	validation_1-rmse:1.87147
# [18]	validation_0-rmse:2.02867	validation_1-rmse:1.74727
# [19]	validation_0-rmse:1.90101	validation_1-rmse:1.63235
# [20]	validation_0-rmse:1.78440	validation_1-rmse:1.52523
# [21]	validation_0-rmse:1.68164	validation_1-rmse:1.43261
# [22]	validation_0-rmse:1.58104	validation_1-rmse:1.34895
# [23]	validation_0-rmse:1.49355	validation_1-rmse:1.27593
# [24]	validation_0-rmse:1.41217	validation_1-rmse:1.21267
# [25]	validation_0-rmse:1.33761	validation_1-rmse:1.15545
# [26]	validation_0-rmse:1.27036	validation_1-rmse:1.10582
# [27]	validation_0-rmse:1.20935	validation_1-rmse:1.06325
# [28]	validation_0-rmse:1.15269	validation_1-rmse:1.02426
# [29]	validation_0-rmse:1.10436	validation_1-rmse:0.99358
# [30]	validation_0-rmse:1.06266	validation_1-rmse:0.96642
# [31]	validation_0-rmse:1.02348	validation_1-rmse:0.94423
# [32]	validation_0-rmse:0.98755	validation_1-rmse:0.92503
# [33]	validation_0-rmse:0.95477	validation_1-rmse:0.90870
# [34]	validation_0-rmse:0.92765	validation_1-rmse:0.89475
# [35]	validation_0-rmse:0.89675	validation_1-rmse:0.87719
# [36]	validation_0-rmse:0.87282	validation_1-rmse:0.86810
# [37]	validation_0-rmse:0.85166	validation_1-rmse:0.86108
# [38]	validation_0-rmse:0.83352	validation_1-rmse:0.85596
# [39]	validation_0-rmse:0.81327	validation_1-rmse:0.84725
# [40]	validation_0-rmse:0.79863	validation_1-rmse:0.84456
# [41]	validation_0-rmse:0.78511	validation_1-rmse:0.84305
# [42]	validation_0-rmse:0.77237	validation_1-rmse:0.83976
# [43]	validation_0-rmse:0.76165	validation_1-rmse:0.83937
# [44]	validation_0-rmse:0.75219	validation_1-rmse:0.83935
# [45]	validation_0-rmse:0.74339	validation_1-rmse:0.83965
# [46]	validation_0-rmse:0.73581	validation_1-rmse:0.84008
# [47]	validation_0-rmse:0.72443	validation_1-rmse:0.83753
# [48]	validation_0-rmse:0.71821	validation_1-rmse:0.83832
# [49]	validation_0-rmse:0.71254	validation_1-rmse:0.83865
# [50]	validation_0-rmse:0.70720	validation_1-rmse:0.83964
# [51]	validation_0-rmse:0.70250	validation_1-rmse:0.84030
# [52]	validation_0-rmse:0.69794	validation_1-rmse:0.84176
# [53]	validation_0-rmse:0.69429	validation_1-rmse:0.84270
# [54]	validation_0-rmse:0.68868	validation_1-rmse:0.84209
# [55]	validation_0-rmse:0.68018	validation_1-rmse:0.84044
# [56]	validation_0-rmse:0.67545	validation_1-rmse:0.83982
# [57]	validation_0-rmse:0.66835	validation_1-rmse:0.83752
# [58]	validation_0-rmse:0.66593	validation_1-rmse:0.83844
# [59]	validation_0-rmse:0.66127	validation_1-rmse:0.83706
# [60]	validation_0-rmse:0.65912	validation_1-rmse:0.83782
# [61]	validation_0-rmse:0.65703	validation_1-rmse:0.83911
# [62]	validation_0-rmse:0.65170	validation_1-rmse:0.83752
# [63]	validation_0-rmse:0.64860	validation_1-rmse:0.83753
# [64]	validation_0-rmse:0.64702	validation_1-rmse:0.83795
# [65]	validation_0-rmse:0.64258	validation_1-rmse:0.83660
# [66]	validation_0-rmse:0.64123	validation_1-rmse:0.83692
# [67]	validation_0-rmse:0.64039	validation_1-rmse:0.83758
# [68]	validation_0-rmse:0.63868	validation_1-rmse:0.83951
# [69]	validation_0-rmse:0.63760	validation_1-rmse:0.83966
# [70]	validation_0-rmse:0.63388	validation_1-rmse:0.83825
# [71]	validation_0-rmse:0.63049	validation_1-rmse:0.83674
# [72]	validation_0-rmse:0.62988	validation_1-rmse:0.83740
# [73]	validation_0-rmse:0.62976	validation_1-rmse:0.83807
# [74]	validation_0-rmse:0.62771	validation_1-rmse:0.83785
# [75]	validation_0-rmse:0.62693	validation_1-rmse:0.83813
# [76]	validation_0-rmse:0.62408	validation_1-rmse:0.83719
# [77]	validation_0-rmse:0.62116	validation_1-rmse:0.83575
# [78]	validation_0-rmse:0.61984	validation_1-rmse:0.83533
# [79]	validation_0-rmse:0.61695	validation_1-rmse:0.83486
# [80]	validation_0-rmse:0.61692	validation_1-rmse:0.83512
# [81]	validation_0-rmse:0.61569	validation_1-rmse:0.83643
# [82]	validation_0-rmse:0.61486	validation_1-rmse:0.83498
# [83]	validation_0-rmse:0.61304	validation_1-rmse:0.83451
# [84]	validation_0-rmse:0.61198	validation_1-rmse:0.83548
# [85]	validation_0-rmse:0.61054	validation_1-rmse:0.83591
# [0]	validation_0-rmse:7.61757	validation_1-rmse:7.85681
# [1]	validation_0-rmse:7.04923	validation_1-rmse:7.29351
# [2]	validation_0-rmse:6.52005	validation_1-rmse:6.76925
# [3]	validation_0-rmse:6.03061	validation_1-rmse:6.29378
# [4]	validation_0-rmse:5.58179	validation_1-rmse:5.84905
# [5]	validation_0-rmse:5.16741	validation_1-rmse:5.45089
# [6]	validation_0-rmse:4.78339	validation_1-rmse:5.08125
# [7]	validation_0-rmse:4.43433	validation_1-rmse:4.74368
# [8]	validation_0-rmse:4.10918	validation_1-rmse:4.42126
# [9]	validation_0-rmse:3.81392	validation_1-rmse:4.13895
# [10]	validation_0-rmse:3.53903	validation_1-rmse:3.86614
# [11]	validation_0-rmse:3.28583	validation_1-rmse:3.62398
# [12]	validation_0-rmse:3.05486	validation_1-rmse:3.40337
# [13]	validation_0-rmse:2.83834	validation_1-rmse:3.19508
# [14]	validation_0-rmse:2.64156	validation_1-rmse:3.00504
# [15]	validation_0-rmse:2.46242	validation_1-rmse:2.83393
# [16]	validation_0-rmse:2.29547	validation_1-rmse:2.66626
# [17]	validation_0-rmse:2.14274	validation_1-rmse:2.51253
# [18]	validation_0-rmse:2.00181	validation_1-rmse:2.37638
# [19]	validation_0-rmse:1.87333	validation_1-rmse:2.25207
# [20]	validation_0-rmse:1.75623	validation_1-rmse:2.13882
# [21]	validation_0-rmse:1.65001	validation_1-rmse:2.03595
# [22]	validation_0-rmse:1.55398	validation_1-rmse:1.94160
# [23]	validation_0-rmse:1.46441	validation_1-rmse:1.85270
# [24]	validation_0-rmse:1.38501	validation_1-rmse:1.77037
# [25]	validation_0-rmse:1.31232	validation_1-rmse:1.69796
# [26]	validation_0-rmse:1.24405	validation_1-rmse:1.63024
# [27]	validation_0-rmse:1.18517	validation_1-rmse:1.56828
# [28]	validation_0-rmse:1.13161	validation_1-rmse:1.51392
# [29]	validation_0-rmse:1.08164	validation_1-rmse:1.46134
# [30]	validation_0-rmse:1.03742	validation_1-rmse:1.41520
# [31]	validation_0-rmse:0.99753	validation_1-rmse:1.37426
# [32]	validation_0-rmse:0.96171	validation_1-rmse:1.33716
# [33]	validation_0-rmse:0.93200	validation_1-rmse:1.30669
# [34]	validation_0-rmse:0.90236	validation_1-rmse:1.27433
# [35]	validation_0-rmse:0.87758	validation_1-rmse:1.24810
# [36]	validation_0-rmse:0.85395	validation_1-rmse:1.22404
# [37]	validation_0-rmse:0.83297	validation_1-rmse:1.20167
# [38]	validation_0-rmse:0.81470	validation_1-rmse:1.18105
# [39]	validation_0-rmse:0.79778	validation_1-rmse:1.16135
# [40]	validation_0-rmse:0.78338	validation_1-rmse:1.14371
# [41]	validation_0-rmse:0.77024	validation_1-rmse:1.12787
# [42]	validation_0-rmse:0.75856	validation_1-rmse:1.11231
# [43]	validation_0-rmse:0.74823	validation_1-rmse:1.09977
# [44]	validation_0-rmse:0.73861	validation_1-rmse:1.09003
# [45]	validation_0-rmse:0.72955	validation_1-rmse:1.07790
# [46]	validation_0-rmse:0.72196	validation_1-rmse:1.06817
# [47]	validation_0-rmse:0.71494	validation_1-rmse:1.05648
# [48]	validation_0-rmse:0.70669	validation_1-rmse:1.04716
# [49]	validation_0-rmse:0.70155	validation_1-rmse:1.04018
# [50]	validation_0-rmse:0.69680	validation_1-rmse:1.03410
# [51]	validation_0-rmse:0.68773	validation_1-rmse:1.01977
# [52]	validation_0-rmse:0.68379	validation_1-rmse:1.01612
# [53]	validation_0-rmse:0.68040	validation_1-rmse:1.01096
# [54]	validation_0-rmse:0.67704	validation_1-rmse:1.00634
# [55]	validation_0-rmse:0.67379	validation_1-rmse:1.00242
# [56]	validation_0-rmse:0.67117	validation_1-rmse:0.99950
# [57]	validation_0-rmse:0.66866	validation_1-rmse:0.99605
# [58]	validation_0-rmse:0.66068	validation_1-rmse:0.98480
# [59]	validation_0-rmse:0.65829	validation_1-rmse:0.97991
# [60]	validation_0-rmse:0.65440	validation_1-rmse:0.97653
# [61]	validation_0-rmse:0.64771	validation_1-rmse:0.96730
# [62]	validation_0-rmse:0.64560	validation_1-rmse:0.96527
# [63]	validation_0-rmse:0.64231	validation_1-rmse:0.96504
# [64]	validation_0-rmse:0.64075	validation_1-rmse:0.96375
# [65]	validation_0-rmse:0.63933	validation_1-rmse:0.96334
# [66]	validation_0-rmse:0.63801	validation_1-rmse:0.96211
# [67]	validation_0-rmse:0.63657	validation_1-rmse:0.96003
# [68]	validation_0-rmse:0.63515	validation_1-rmse:0.95891
# [69]	validation_0-rmse:0.62973	validation_1-rmse:0.95281
# [70]	validation_0-rmse:0.62875	validation_1-rmse:0.95228
# [71]	validation_0-rmse:0.62787	validation_1-rmse:0.95218
# [72]	validation_0-rmse:0.62268	validation_1-rmse:0.94698
# [73]	validation_0-rmse:0.62005	validation_1-rmse:0.94810
# [74]	validation_0-rmse:0.61912	validation_1-rmse:0.94800
# [75]	validation_0-rmse:0.61791	validation_1-rmse:0.94763
# [76]	validation_0-rmse:0.61708	validation_1-rmse:0.94717
# [77]	validation_0-rmse:0.61263	validation_1-rmse:0.94321
# [78]	validation_0-rmse:0.61171	validation_1-rmse:0.94328
# [79]	validation_0-rmse:0.61089	validation_1-rmse:0.94292
# [80]	validation_0-rmse:0.60579	validation_1-rmse:0.94025
# [81]	validation_0-rmse:0.60575	validation_1-rmse:0.93941
# [82]	validation_0-rmse:0.60195	validation_1-rmse:0.93368
# [83]	validation_0-rmse:0.60192	validation_1-rmse:0.93277
# [84]	validation_0-rmse:0.60191	validation_1-rmse:0.93259
# [85]	validation_0-rmse:0.60155	validation_1-rmse:0.93386
# [0]	validation_0-rmse:7.63588	validation_1-rmse:7.78124
# [1]	validation_0-rmse:7.06230	validation_1-rmse:7.20379
# [2]	validation_0-rmse:6.53232	validation_1-rmse:6.66985
# [3]	validation_0-rmse:6.05052	validation_1-rmse:6.18431
# [4]	validation_0-rmse:5.60004	validation_1-rmse:5.74019
# [5]	validation_0-rmse:5.18380	validation_1-rmse:5.33004
# [6]	validation_0-rmse:4.80159	validation_1-rmse:4.95380
# [7]	validation_0-rmse:4.44594	validation_1-rmse:4.59423
# [8]	validation_0-rmse:4.12160	validation_1-rmse:4.27546
# [9]	validation_0-rmse:3.82621	validation_1-rmse:3.97650
# [10]	validation_0-rmse:3.55057	validation_1-rmse:3.70603
# [11]	validation_0-rmse:3.29668	validation_1-rmse:3.45735
# [12]	validation_0-rmse:3.06592	validation_1-rmse:3.22289
# [13]	validation_0-rmse:2.84996	validation_1-rmse:3.01132
# [14]	validation_0-rmse:2.65202	validation_1-rmse:2.81756
# [15]	validation_0-rmse:2.47354	validation_1-rmse:2.64210
# [16]	validation_0-rmse:2.30900	validation_1-rmse:2.48147
# [17]	validation_0-rmse:2.15906	validation_1-rmse:2.32740
# [18]	validation_0-rmse:2.02288	validation_1-rmse:2.19275
# [19]	validation_0-rmse:1.89718	validation_1-rmse:2.06679
# [20]	validation_0-rmse:1.78064	validation_1-rmse:1.95131
# [21]	validation_0-rmse:1.67308	validation_1-rmse:1.83940
# [22]	validation_0-rmse:1.57679	validation_1-rmse:1.73293
# [23]	validation_0-rmse:1.48908	validation_1-rmse:1.64423
# [24]	validation_0-rmse:1.40657	validation_1-rmse:1.55981
# [25]	validation_0-rmse:1.33338	validation_1-rmse:1.48738
# [26]	validation_0-rmse:1.26765	validation_1-rmse:1.42174
# [27]	validation_0-rmse:1.20956	validation_1-rmse:1.36220
# [28]	validation_0-rmse:1.15868	validation_1-rmse:1.31185
# [29]	validation_0-rmse:1.11027	validation_1-rmse:1.26396
# [30]	validation_0-rmse:1.06659	validation_1-rmse:1.22029
# [31]	validation_0-rmse:1.02675	validation_1-rmse:1.18155
# [32]	validation_0-rmse:0.99320	validation_1-rmse:1.14822
# [33]	validation_0-rmse:0.96320	validation_1-rmse:1.11823
# [34]	validation_0-rmse:0.93542	validation_1-rmse:1.09129
# [35]	validation_0-rmse:0.91021	validation_1-rmse:1.06642
# [36]	validation_0-rmse:0.88879	validation_1-rmse:1.04684
# [37]	validation_0-rmse:0.87119	validation_1-rmse:1.02840
# [38]	validation_0-rmse:0.85433	validation_1-rmse:1.01304
# [39]	validation_0-rmse:0.83834	validation_1-rmse:0.99661
# [40]	validation_0-rmse:0.82634	validation_1-rmse:0.98436
# [41]	validation_0-rmse:0.81399	validation_1-rmse:0.97278
# [42]	validation_0-rmse:0.80299	validation_1-rmse:0.96234
# [43]	validation_0-rmse:0.79310	validation_1-rmse:0.95271
# [44]	validation_0-rmse:0.78452	validation_1-rmse:0.94328
# [45]	validation_0-rmse:0.76979	validation_1-rmse:0.92901
# [46]	validation_0-rmse:0.76336	validation_1-rmse:0.92186
# [47]	validation_0-rmse:0.75754	validation_1-rmse:0.91483
# [48]	validation_0-rmse:0.75240	validation_1-rmse:0.91486
# [49]	validation_0-rmse:0.74743	validation_1-rmse:0.90974
# [50]	validation_0-rmse:0.74319	validation_1-rmse:0.90448
# [51]	validation_0-rmse:0.73891	validation_1-rmse:0.90074
# [52]	validation_0-rmse:0.73022	validation_1-rmse:0.89107
# [53]	validation_0-rmse:0.72711	validation_1-rmse:0.88703
# [54]	validation_0-rmse:0.72429	validation_1-rmse:0.88318
# [55]	validation_0-rmse:0.71711	validation_1-rmse:0.87539
# [56]	validation_0-rmse:0.71336	validation_1-rmse:0.87338
# [57]	validation_0-rmse:0.70733	validation_1-rmse:0.86701
# [58]	validation_0-rmse:0.70404	validation_1-rmse:0.86273
# [59]	validation_0-rmse:0.70220	validation_1-rmse:0.86113
# [60]	validation_0-rmse:0.70044	validation_1-rmse:0.85875
# [61]	validation_0-rmse:0.69527	validation_1-rmse:0.85231
# [62]	validation_0-rmse:0.69128	validation_1-rmse:0.85124
# [63]	validation_0-rmse:0.68880	validation_1-rmse:0.85209
# [64]	validation_0-rmse:0.68779	validation_1-rmse:0.85106
# [65]	validation_0-rmse:0.68544	validation_1-rmse:0.85358
# [66]	validation_0-rmse:0.68421	validation_1-rmse:0.85227
# [67]	validation_0-rmse:0.68341	validation_1-rmse:0.85138
# [68]	validation_0-rmse:0.68271	validation_1-rmse:0.85060
# [69]	validation_0-rmse:0.67793	validation_1-rmse:0.84792
# [70]	validation_0-rmse:0.67644	validation_1-rmse:0.85149
# ...
# [60]	validation_0-rmse:0.61897	validation_1-rmse:0.92779
# [61]	validation_0-rmse:0.61677	validation_1-rmse:0.92674
# [62]	validation_0-rmse:0.61193	validation_1-rmse:0.92590
# [63]	validation_0-rmse:0.60753	validation_1-rmse:0.92662
# [64]	validation_0-rmse:0.60589	validation_1-rmse:0.92653
# [65]	validation_0-rmse:0.60247	validation_1-rmse:0.92691
# [66]	validation_0-rmse:0.60105	validation_1-rmse:0.92688
# [67]	validation_0-rmse:0.59723	validation_1-rmse:0.92783
# [68]	validation_0-rmse:0.59595	validation_1-rmse:0.92779
# [69]	validation_0-rmse:0.59389	validation_1-rmse:0.92982
# [70]	validation_0-rmse:0.59055	validation_1-rmse:0.93098
# [71]	validation_0-rmse:0.58913	validation_1-rmse:0.93097
# [72]	validation_0-rmse:0.58669	validation_1-rmse:0.93057
# [73]	validation_0-rmse:0.58386	validation_1-rmse:0.93028
# [74]	validation_0-rmse:0.58111	validation_1-rmse:0.93170
# [75]	validation_0-rmse:0.57945	validation_1-rmse:0.93366
# [76]	validation_0-rmse:0.57854	validation_1-rmse:0.93366
# [77]	validation_0-rmse:0.57850	validation_1-rmse:0.93366
# [78]	validation_0-rmse:0.57594	validation_1-rmse:0.93199
# [79]	validation_0-rmse:0.57494	validation_1-rmse:0.93111
# [80]	validation_0-rmse:0.57250	validation_1-rmse:0.93073
# [81]	validation_0-rmse:0.57248	validation_1-rmse:0.93073
# [82]	validation_0-rmse:0.57082	validation_1-rmse:0.93398
# [0]	validation_0-rmse:7.66163	validation_1-rmse:7.65646
# [1]	validation_0-rmse:7.08605	validation_1-rmse:7.07626
# [2]	validation_0-rmse:6.55420	validation_1-rmse:6.53278
# [3]	validation_0-rmse:6.06932	validation_1-rmse:6.04351
# [4]	validation_0-rmse:5.61783	validation_1-rmse:5.59378
# [5]	validation_0-rmse:5.19996	validation_1-rmse:5.18073
# [6]	validation_0-rmse:4.81674	validation_1-rmse:4.79367
# [7]	validation_0-rmse:4.46390	validation_1-rmse:4.44530
# [8]	validation_0-rmse:4.13714	validation_1-rmse:4.12137
# [9]	validation_0-rmse:3.83887	validation_1-rmse:3.82708
# [10]	validation_0-rmse:3.56309	validation_1-rmse:3.54790
# [11]	validation_0-rmse:3.30670	validation_1-rmse:3.29490
# [12]	validation_0-rmse:3.07147	validation_1-rmse:3.05900
# [13]	validation_0-rmse:2.85883	validation_1-rmse:2.84667
# [14]	validation_0-rmse:2.66203	validation_1-rmse:2.65300
# [15]	validation_0-rmse:2.48387	validation_1-rmse:2.47528
# [16]	validation_0-rmse:2.31809	validation_1-rmse:2.31259
# [17]	validation_0-rmse:2.16682	validation_1-rmse:2.16310
# [18]	validation_0-rmse:2.03038	validation_1-rmse:2.02755
# [19]	validation_0-rmse:1.90363	validation_1-rmse:1.90248
# [20]	validation_0-rmse:1.78833	validation_1-rmse:1.78936
# [21]	validation_0-rmse:1.68312	validation_1-rmse:1.68536
# [22]	validation_0-rmse:1.58592	validation_1-rmse:1.59331
# [23]	validation_0-rmse:1.49854	validation_1-rmse:1.50767
# [24]	validation_0-rmse:1.41776	validation_1-rmse:1.42922
# [25]	validation_0-rmse:1.34459	validation_1-rmse:1.35762
# [26]	validation_0-rmse:1.27822	validation_1-rmse:1.29320
# [27]	validation_0-rmse:1.21780	validation_1-rmse:1.23888
# [28]	validation_0-rmse:1.16502	validation_1-rmse:1.18876
# [29]	validation_0-rmse:1.11726	validation_1-rmse:1.14393
# [30]	validation_0-rmse:1.07478	validation_1-rmse:1.10745
# [31]	validation_0-rmse:1.03666	validation_1-rmse:1.07277
# [32]	validation_0-rmse:1.00284	validation_1-rmse:1.04253
# [33]	validation_0-rmse:0.96915	validation_1-rmse:1.01994
# [34]	validation_0-rmse:0.94199	validation_1-rmse:0.99977
# [35]	validation_0-rmse:0.91759	validation_1-rmse:0.98167
# [36]	validation_0-rmse:0.89518	validation_1-rmse:0.96359
# [37]	validation_0-rmse:0.87475	validation_1-rmse:0.94941
# [38]	validation_0-rmse:0.85725	validation_1-rmse:0.93754
# [39]	validation_0-rmse:0.84215	validation_1-rmse:0.92739
# [40]	validation_0-rmse:0.82633	validation_1-rmse:0.92058
# [41]	validation_0-rmse:0.81345	validation_1-rmse:0.91057
# [42]	validation_0-rmse:0.80113	validation_1-rmse:0.90296
# [43]	validation_0-rmse:0.79082	validation_1-rmse:0.89644
# [44]	validation_0-rmse:0.78012	validation_1-rmse:0.89324
# [45]	validation_0-rmse:0.77225	validation_1-rmse:0.88881
# [46]	validation_0-rmse:0.76506	validation_1-rmse:0.88496
# [47]	validation_0-rmse:0.75827	validation_1-rmse:0.87789
# [48]	validation_0-rmse:0.75249	validation_1-rmse:0.87487
# [49]	validation_0-rmse:0.74716	validation_1-rmse:0.87395
# [50]	validation_0-rmse:0.74251	validation_1-rmse:0.86860
# [51]	validation_0-rmse:0.73736	validation_1-rmse:0.86829
# [52]	validation_0-rmse:0.73373	validation_1-rmse:0.86681
# [53]	validation_0-rmse:0.72584	validation_1-rmse:0.86806
# [54]	validation_0-rmse:0.72272	validation_1-rmse:0.86388
# [55]	validation_0-rmse:0.71992	validation_1-rmse:0.86281
# [56]	validation_0-rmse:0.71281	validation_1-rmse:0.85600
# [57]	validation_0-rmse:0.70939	validation_1-rmse:0.85426
# [58]	validation_0-rmse:0.70706	validation_1-rmse:0.85365
# [59]	validation_0-rmse:0.70152	validation_1-rmse:0.84652
# [60]	validation_0-rmse:0.69970	validation_1-rmse:0.84604
# [61]	validation_0-rmse:0.69671	validation_1-rmse:0.84580
# [62]	validation_0-rmse:0.69515	validation_1-rmse:0.84561
# [63]	validation_0-rmse:0.69283	validation_1-rmse:0.84476
# [64]	validation_0-rmse:0.68793	validation_1-rmse:0.83819
# [65]	validation_0-rmse:0.68662	validation_1-rmse:0.83794
# [66]	validation_0-rmse:0.68244	validation_1-rmse:0.83101
# [67]	validation_0-rmse:0.68134	validation_1-rmse:0.83093
# [68]	validation_0-rmse:0.67808	validation_1-rmse:0.83217
# [69]	validation_0-rmse:0.67746	validation_1-rmse:0.83239
# [70]	validation_0-rmse:0.67382	validation_1-rmse:0.82714
# [71]	validation_0-rmse:0.67297	validation_1-rmse:0.82721
# [72]	validation_0-rmse:0.67013	validation_1-rmse:0.82873
# [73]	validation_0-rmse:0.66827	validation_1-rmse:0.82823
# [74]	validation_0-rmse:0.66469	validation_1-rmse:0.82196
# [75]	validation_0-rmse:0.66234	validation_1-rmse:0.82366
# [76]	validation_0-rmse:0.66029	validation_1-rmse:0.82523
# [77]	validation_0-rmse:0.65739	validation_1-rmse:0.82684
# [78]	validation_0-rmse:0.65488	validation_1-rmse:0.82253
# [79]	validation_0-rmse:0.65296	validation_1-rmse:0.82686
# [80]	validation_0-rmse:0.65228	validation_1-rmse:0.82683
# [81]	validation_0-rmse:0.65072	validation_1-rmse:0.82652
# [82]	validation_0-rmse:0.64997	validation_1-rmse:0.82651
# [83]	validation_0-rmse:0.64784	validation_1-rmse:0.82142
# [84]	validation_0-rmse:0.64608	validation_1-rmse:0.82319
# [85]	validation_0-rmse:0.64605	validation_1-rmse:0.82310
# [0]	validation_0-rmse:7.59500	validation_1-rmse:7.95623
# [1]	validation_0-rmse:7.02118	validation_1-rmse:7.38906
# [2]	validation_0-rmse:6.49343	validation_1-rmse:6.86733
# [3]	validation_0-rmse:6.01351	validation_1-rmse:6.39045
# [4]	validation_0-rmse:5.56553	validation_1-rmse:5.94798
# [5]	validation_0-rmse:5.15358	validation_1-rmse:5.54093
# [6]	validation_0-rmse:4.77283	validation_1-rmse:5.16480
# [7]	validation_0-rmse:4.42186	validation_1-rmse:4.81686
# [8]	validation_0-rmse:4.09961	validation_1-rmse:4.49539
# [9]	validation_0-rmse:3.80139	validation_1-rmse:4.20076
# [10]	validation_0-rmse:3.52759	validation_1-rmse:3.92722
# [11]	validation_0-rmse:3.27712	validation_1-rmse:3.67826
# [12]	validation_0-rmse:3.04483	validation_1-rmse:3.44100
# [13]	validation_0-rmse:2.83177	validation_1-rmse:3.22302
# [14]	validation_0-rmse:2.63708	validation_1-rmse:3.02908
# [15]	validation_0-rmse:2.46115	validation_1-rmse:2.84769
# [16]	validation_0-rmse:2.29673	validation_1-rmse:2.67808
# [17]	validation_0-rmse:2.14736	validation_1-rmse:2.52922
# [18]	validation_0-rmse:2.01236	validation_1-rmse:2.39086
# [19]	validation_0-rmse:1.88660	validation_1-rmse:2.25949
# [20]	validation_0-rmse:1.77196	validation_1-rmse:2.13888
# [21]	validation_0-rmse:1.66932	validation_1-rmse:2.03312
# [22]	validation_0-rmse:1.57451	validation_1-rmse:1.93296
# [23]	validation_0-rmse:1.48931	validation_1-rmse:1.84063
# [24]	validation_0-rmse:1.41244	validation_1-rmse:1.75860
# [25]	validation_0-rmse:1.34014	validation_1-rmse:1.67971
# [26]	validation_0-rmse:1.27497	validation_1-rmse:1.60755
# [27]	validation_0-rmse:1.21774	validation_1-rmse:1.54389
# [28]	validation_0-rmse:1.16561	validation_1-rmse:1.48530
# [29]	validation_0-rmse:1.11910	validation_1-rmse:1.43230
# [30]	validation_0-rmse:1.07625	validation_1-rmse:1.37915
# [31]	validation_0-rmse:1.03816	validation_1-rmse:1.33395
# [32]	validation_0-rmse:1.00472	validation_1-rmse:1.29929
# [33]	validation_0-rmse:0.96697	validation_1-rmse:1.25513
# [34]	validation_0-rmse:0.93478	validation_1-rmse:1.21626
# [35]	validation_0-rmse:0.91073	validation_1-rmse:1.19040
# [36]	validation_0-rmse:0.88838	validation_1-rmse:1.16214
# [37]	validation_0-rmse:0.86964	validation_1-rmse:1.13704
# [38]	validation_0-rmse:0.85207	validation_1-rmse:1.10769
# [39]	validation_0-rmse:0.83231	validation_1-rmse:1.07584
# [40]	validation_0-rmse:0.81892	validation_1-rmse:1.05093
# [41]	validation_0-rmse:0.80175	validation_1-rmse:1.03364
# [42]	validation_0-rmse:0.78523	validation_1-rmse:1.01738
# [43]	validation_0-rmse:0.77558	validation_1-rmse:0.99984
# [44]	validation_0-rmse:0.76661	validation_1-rmse:0.98143
# [45]	validation_0-rmse:0.75712	validation_1-rmse:0.97070
# [46]	validation_0-rmse:0.75038	validation_1-rmse:0.96284
# [47]	validation_0-rmse:0.74427	validation_1-rmse:0.94874
# [48]	validation_0-rmse:0.73791	validation_1-rmse:0.93984
# [49]	validation_0-rmse:0.72822	validation_1-rmse:0.93263
# [50]	validation_0-rmse:0.72383	validation_1-rmse:0.92202
# [51]	validation_0-rmse:0.72000	validation_1-rmse:0.90973
# [52]	validation_0-rmse:0.71660	validation_1-rmse:0.90049
# [53]	validation_0-rmse:0.71275	validation_1-rmse:0.89863
# [54]	validation_0-rmse:0.70611	validation_1-rmse:0.89423
# [55]	validation_0-rmse:0.70108	validation_1-rmse:0.89051
# [56]	validation_0-rmse:0.69650	validation_1-rmse:0.88591
# [57]	validation_0-rmse:0.69409	validation_1-rmse:0.87912
# [58]	validation_0-rmse:0.68891	validation_1-rmse:0.87702
# [59]	validation_0-rmse:0.68678	validation_1-rmse:0.87079
# [60]	validation_0-rmse:0.68216	validation_1-rmse:0.86874
# [61]	validation_0-rmse:0.67856	validation_1-rmse:0.86671
# [62]	validation_0-rmse:0.67679	validation_1-rmse:0.85948
# [63]	validation_0-rmse:0.67528	validation_1-rmse:0.85345
# [64]	validation_0-rmse:0.67369	validation_1-rmse:0.84862
# [65]	validation_0-rmse:0.67220	validation_1-rmse:0.84662
# [66]	validation_0-rmse:0.67014	validation_1-rmse:0.84803
# [67]	validation_0-rmse:0.66881	validation_1-rmse:0.84397
# [68]	validation_0-rmse:0.66763	validation_1-rmse:0.84037
# [69]	validation_0-rmse:0.66606	validation_1-rmse:0.83987
# [70]	validation_0-rmse:0.66217	validation_1-rmse:0.83927
# [71]	validation_0-rmse:0.65933	validation_1-rmse:0.83625
# [72]	validation_0-rmse:0.65606	validation_1-rmse:0.83643
# [73]	validation_0-rmse:0.65539	validation_1-rmse:0.83170
# [74]	validation_0-rmse:0.65259	validation_1-rmse:0.83141
# [75]	validation_0-rmse:0.65201	validation_1-rmse:0.82713
# [76]	validation_0-rmse:0.65146	validation_1-rmse:0.82293
# [77]	validation_0-rmse:0.64888	validation_1-rmse:0.82326
# [78]	validation_0-rmse:0.64682	validation_1-rmse:0.82551
# [79]	validation_0-rmse:0.64455	validation_1-rmse:0.82551
# [80]	validation_0-rmse:0.64406	validation_1-rmse:0.82157
# [81]	validation_0-rmse:0.64361	validation_1-rmse:0.81802
# [82]	validation_0-rmse:0.64072	validation_1-rmse:0.81930
# [83]	validation_0-rmse:0.63977	validation_1-rmse:0.81827
# [84]	validation_0-rmse:0.63754	validation_1-rmse:0.81795
# [85]	validation_0-rmse:0.63753	validation_1-rmse:0.81778
# [0]	validation_0-rmse:7.63475	validation_1-rmse:7.75821
# [1]	validation_0-rmse:7.05496	validation_1-rmse:7.18063
# [2]	validation_0-rmse:6.52395	validation_1-rmse:6.65234
# [3]	validation_0-rmse:6.03621	validation_1-rmse:6.16777
# [4]	validation_0-rmse:5.58492	validation_1-rmse:5.72023
# [5]	validation_0-rmse:5.16846	validation_1-rmse:5.30803
# [6]	validation_0-rmse:4.78566	validation_1-rmse:4.93003
# [7]	validation_0-rmse:4.42908	validation_1-rmse:4.57653
# [8]	validation_0-rmse:4.10527	validation_1-rmse:4.25716
# [9]	validation_0-rmse:3.80791	validation_1-rmse:3.96545
# [10]	validation_0-rmse:3.53259	validation_1-rmse:3.69326
# [11]	validation_0-rmse:3.28380	validation_1-rmse:3.45068
# [12]	validation_0-rmse:3.05026	validation_1-rmse:3.21563
# [13]	validation_0-rmse:2.83651	validation_1-rmse:3.00595
# [14]	validation_0-rmse:2.64047	validation_1-rmse:2.80909
# [15]	validation_0-rmse:2.46330	validation_1-rmse:2.63058
# [16]	validation_0-rmse:2.29489	validation_1-rmse:2.46820
# [17]	validation_0-rmse:2.14307	validation_1-rmse:2.31615
# [18]	validation_0-rmse:2.00424	validation_1-rmse:2.17763
# [19]	validation_0-rmse:1.87867	validation_1-rmse:2.05855
# [20]	validation_0-rmse:1.76215	validation_1-rmse:1.94119
# [21]	validation_0-rmse:1.65816	validation_1-rmse:1.84203
# [22]	validation_0-rmse:1.56240	validation_1-rmse:1.74750
# [23]	validation_0-rmse:1.47322	validation_1-rmse:1.65927
# [24]	validation_0-rmse:1.39215	validation_1-rmse:1.57765
# [25]	validation_0-rmse:1.32247	validation_1-rmse:1.50713
# [26]	validation_0-rmse:1.25830	validation_1-rmse:1.44386
# [27]	validation_0-rmse:1.19697	validation_1-rmse:1.38102
# [28]	validation_0-rmse:1.14377	validation_1-rmse:1.33479
# [29]	validation_0-rmse:1.09539	validation_1-rmse:1.29332
# [30]	validation_0-rmse:1.05252	validation_1-rmse:1.25237
# [31]	validation_0-rmse:1.01327	validation_1-rmse:1.21525
# [32]	validation_0-rmse:0.97935	validation_1-rmse:1.18325
# [33]	validation_0-rmse:0.94752	validation_1-rmse:1.15406
# [34]	validation_0-rmse:0.92112	validation_1-rmse:1.13030
# [35]	validation_0-rmse:0.89787	validation_1-rmse:1.10507
# [36]	validation_0-rmse:0.86848	validation_1-rmse:1.08271
# [37]	validation_0-rmse:0.84990	validation_1-rmse:1.06273
# [38]	validation_0-rmse:0.82527	validation_1-rmse:1.04233
# [39]	validation_0-rmse:0.80434	validation_1-rmse:1.02455
# [40]	validation_0-rmse:0.78983	validation_1-rmse:1.00883
# [41]	validation_0-rmse:0.77235	validation_1-rmse:0.99468
# [42]	validation_0-rmse:0.76179	validation_1-rmse:0.98457
# [43]	validation_0-rmse:0.74790	validation_1-rmse:0.97393
# [44]	validation_0-rmse:0.73572	validation_1-rmse:0.96444
# [45]	validation_0-rmse:0.72457	validation_1-rmse:0.95574
# [46]	validation_0-rmse:0.71675	validation_1-rmse:0.95279
# [47]	validation_0-rmse:0.71097	validation_1-rmse:0.94521
# [48]	validation_0-rmse:0.70593	validation_1-rmse:0.93744
# [49]	validation_0-rmse:0.70017	validation_1-rmse:0.93057
# [50]	validation_0-rmse:0.69589	validation_1-rmse:0.92656
# [51]	validation_0-rmse:0.68910	validation_1-rmse:0.92128
# [52]	validation_0-rmse:0.68306	validation_1-rmse:0.91661
# [53]	validation_0-rmse:0.67766	validation_1-rmse:0.91657
# [54]	validation_0-rmse:0.67478	validation_1-rmse:0.91169
# [55]	validation_0-rmse:0.67226	validation_1-rmse:0.90702
# [56]	validation_0-rmse:0.66789	validation_1-rmse:0.90744
# [57]	validation_0-rmse:0.66609	validation_1-rmse:0.90418
# [58]	validation_0-rmse:0.66406	validation_1-rmse:0.90153
# [59]	validation_0-rmse:0.66012	validation_1-rmse:0.90199
# [60]	validation_0-rmse:0.65846	validation_1-rmse:0.89808
# [61]	validation_0-rmse:0.65694	validation_1-rmse:0.89401
# [62]	validation_0-rmse:0.65556	validation_1-rmse:0.89052
# [63]	validation_0-rmse:0.65430	validation_1-rmse:0.88766
# [64]	validation_0-rmse:0.65311	validation_1-rmse:0.88438
# [65]	validation_0-rmse:0.65004	validation_1-rmse:0.88513
# [66]	validation_0-rmse:0.64757	validation_1-rmse:0.88602
# [67]	validation_0-rmse:0.64563	validation_1-rmse:0.88745
# [68]	validation_0-rmse:0.64503	validation_1-rmse:0.88451
# [69]	validation_0-rmse:0.64331	validation_1-rmse:0.88439
# [70]	validation_0-rmse:0.64318	validation_1-rmse:0.88469
# [71]	validation_0-rmse:0.64304	validation_1-rmse:0.88505
# [72]	validation_0-rmse:0.64216	validation_1-rmse:0.88183
# [73]	validation_0-rmse:0.64208	validation_1-rmse:0.88208
# [74]	validation_0-rmse:0.63988	validation_1-rmse:0.88277
# [75]	validation_0-rmse:0.63982	validation_1-rmse:0.88299
# [76]	validation_0-rmse:0.63859	validation_1-rmse:0.88288
# [77]	validation_0-rmse:0.63855	validation_1-rmse:0.88308
# [78]	validation_0-rmse:0.63646	validation_1-rmse:0.88191
# [79]	validation_0-rmse:0.63520	validation_1-rmse:0.88237
# [80]	validation_0-rmse:0.63519	validation_1-rmse:0.88247
# [81]	validation_0-rmse:0.63517	validation_1-rmse:0.88261
# [82]	validation_0-rmse:0.63159	validation_1-rmse:0.88307
# [83]	validation_0-rmse:0.63055	validation_1-rmse:0.88306
# [84]	validation_0-rmse:0.62737	validation_1-rmse:0.88292
# [85]	validation_0-rmse:0.62738	validation_1-rmse:0.88284

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(6, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.693
# Uncertainty
# a0: 2.83+/-0.396
# a1: 0.664+/-0.045

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: Sr_2021_kBq_m: mean - 0.935, median - 0.945, CI - [0.874-1.001]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['Sr_2021_kBq_m'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 72.825, median: 76.0,
#  pred. interval (P(0.025)-P(0.975)): 47.975-85.0,
#  conf. interval (p-value=0.95): 59.781-84.128
# ***
# Aggregate bias statistic:
#  mean: -0.086, median: -0.08,
#  pred. interval (P(0.025)-P(0.975)): -0.452-0.196,
#  conf. interval (p-value=0.95): -0.242-0.072
# ***
# Aggregate RMSE statistic:
#  mean: 0.835, median: 0.823, pred. interval (P(0.025)-P(0.975)): 0.582-1.108,
#  conf. interval (p-value=0.95): 0.724-0.932
# ***
# Aggregate MSE statistic:
#  mean: 0.715, median: 0.677, pred. interval (P(0.025)-P(0.975)): 0.339-1.227,
#  conf. interval (p-value=0.95): 0.525-0.87
# ***
# Aggregate R^2 statistic:
#  mean: 0.645, median: 0.659, pred. interval (P(0.025)-P(0.975)): 0.262-0.849,
#  conf. interval (p-value=0.95): 0.55-0.757
# ***
# Aggregate bias(%) statistic:
#  mean: -0.956, median: -0.892, pred. interval (P(0.025)-P(0.975)): -5.156-2.42,
#  conf. interval (p-value=0.95): -2.656-0.846
# ***
# Aggregate RMSE(%) statistic:
#  mean: 9.617, median: 9.479, pred. interval (P(0.025)-P(0.975)): 6.473-13.104,
#  conf. interval (p-value=0.95): 8.455-10.717
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -13910.848, median: -3270.984,
#  pred. interval (P(0.025)-P(0.975)): -66091.569-8646.307,
#  conf. interval (p-value=0.95): -39990.159--278.972
# ***
# Aggregate RMSE statistic:
#  mean: 63879.315, median: 17165.384, pred. interval (P(0.025)-P(0.975)): 5586.678-223408.448,
#  conf. interval (p-value=0.95): 9087.38-178223.643
# ***
# Aggregate MSE statistic:
#  mean: 10783329688.22, median: 294662721.217, pred. interval (P(0.025)-P(0.975)): 31230161.098-49911339706.888,
#  conf. interval (p-value=0.95): 89587598.982-34547909609.716
# ***
# Aggregate R^2 statistic:
#  mean: 0.576, median: 0.696, pred. interval (P(0.025)-P(0.975)): 0.047-0.974,
#  conf. interval (p-value=0.95): 0.269-0.829
# ***
# Aggregate bias(%) statistic:
#  mean: -28.128, median: -23.445, pred. interval (P(0.025)-P(0.975)): -79.586-28.708,
#  conf. interval (p-value=0.95): -67.968--1.937
# ***
# Aggregate RMSE(%) statistic:
#  mean: 144.647, median: 95.587, pred. interval (P(0.025)-P(0.975)): 41.359-349.048,
#  conf. interval (p-value=0.95): 72.652-269.799
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [6, 7, 8, 9, 10, 11,14])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 500, 1000, 5000, 10000, 20000, 50000, 1000000])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:7.66272
# [1]	validation_0-rmse:7.08396
# [2]	validation_0-rmse:6.54740
# [3]	validation_0-rmse:6.05621
# [4]	validation_0-rmse:5.60590
# [5]	validation_0-rmse:5.18736
# [6]	validation_0-rmse:4.80405
# [7]	validation_0-rmse:4.45163
# [8]	validation_0-rmse:4.12387
# [9]	validation_0-rmse:3.82343
# [10]	validation_0-rmse:3.54951
# [11]	validation_0-rmse:3.29515
# [12]	validation_0-rmse:3.06352
# [13]	validation_0-rmse:2.84896
# [14]	validation_0-rmse:2.65352
# [15]	validation_0-rmse:2.47167
# [16]	validation_0-rmse:2.30616
# [17]	validation_0-rmse:2.15226
# [18]	validation_0-rmse:2.01235
# [19]	validation_0-rmse:1.88342
# [20]	validation_0-rmse:1.76808
# [21]	validation_0-rmse:1.66194
# [22]	validation_0-rmse:1.56275
# [23]	validation_0-rmse:1.47487
# [24]	validation_0-rmse:1.39690
# [25]	validation_0-rmse:1.32558
# [26]	validation_0-rmse:1.26071
# [27]	validation_0-rmse:1.20264
# [28]	validation_0-rmse:1.15104
# [29]	validation_0-rmse:1.10447
# [30]	validation_0-rmse:1.06373
# [31]	validation_0-rmse:1.02526
# [32]	validation_0-rmse:0.99163
# [33]	validation_0-rmse:0.96113
# [34]	validation_0-rmse:0.93423
# [35]	validation_0-rmse:0.91148
# [36]	validation_0-rmse:0.89124
# [37]	validation_0-rmse:0.87273
# [38]	validation_0-rmse:0.85642
# [39]	validation_0-rmse:0.84145
# [40]	validation_0-rmse:0.82847
# [41]	validation_0-rmse:0.81705
# [42]	validation_0-rmse:0.80608
# [43]	validation_0-rmse:0.79783
# [44]	validation_0-rmse:0.78905
# [45]	validation_0-rmse:0.78138
# [46]	validation_0-rmse:0.76716
# [47]	validation_0-rmse:0.75539
# [48]	validation_0-rmse:0.74852
# [49]	validation_0-rmse:0.73787
# [50]	validation_0-rmse:0.73360
# [51]	validation_0-rmse:0.72963
# [52]	validation_0-rmse:0.72562
# [53]	validation_0-rmse:0.72258
# [54]	validation_0-rmse:0.71460
# [55]	validation_0-rmse:0.71206
# [56]	validation_0-rmse:0.70815
# [57]	validation_0-rmse:0.70113
# [58]	validation_0-rmse:0.69893
# [59]	validation_0-rmse:0.69712
# [60]	validation_0-rmse:0.69134
# [61]	validation_0-rmse:0.68842
# [62]	validation_0-rmse:0.68375
# [63]	validation_0-rmse:0.68232
# [64]	validation_0-rmse:0.67806
# [65]	validation_0-rmse:0.67473
# [66]	validation_0-rmse:0.67183
# [67]	validation_0-rmse:0.67075
# [68]	validation_0-rmse:0.66967
# [69]	validation_0-rmse:0.66871
# [70]	validation_0-rmse:0.66689
# [71]	validation_0-rmse:0.66498
# [72]	validation_0-rmse:0.66328
# [73]	validation_0-rmse:0.66240
# [74]	validation_0-rmse:0.66205
# [75]	validation_0-rmse:0.66195
# [76]	validation_0-rmse:0.66131
# [77]	validation_0-rmse:0.66070
# [78]	validation_0-rmse:0.66002
# [79]	validation_0-rmse:0.65998
# [80]	validation_0-rmse:0.65997
# [81]	validation_0-rmse:0.65739
# [82]	validation_0-rmse:0.65581
# [83]	validation_0-rmse:0.65535
# [84]	validation_0-rmse:0.65453
# [85]	validation_0-rmse:0.65453

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 85

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.10
# RMSE: 0.7
# Relative RMSE(%):  7.561
# MSE: 0.4
# R square: 80.0%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(6, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.804
# Uncertainty
# a0: 2.14+/-0.32
# a1: 0.75+/-0.04

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=1) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/08_LN_Sr_vs_Density_XGB_model_2024_final.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/08_LN_Sr_vs_Density_XGB_model_2024_final.txt")
