# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN'])
            
# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           2260           1210     -0.731      2.576
# 1       8.189       9.622           2700           1180      0.585      2.915
# 2       8.380       9.589           2500           1400      0.779      2.882
# 3       8.137       9.449           2500           1090      0.517      2.724
# 4       7.696       9.401           2400            720      0.224      2.826
#
#    AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  \
# 0       2.33    0.445070     13  35.145074   360.273487    0.488754
# 1       2.47   12.465903     24  36.135511   323.958625    0.501683
# 2       2.44   13.028298     18  35.938764   299.438354    0.540056
# 3       2.55    2.128231     15  35.908361   319.773395    0.480991
# 4       2.14   12.171553      8  38.062522   353.104284    0.505257
#
#    corr_r_MIN
# 0    0.072792
# 1    0.098347
# 2    0.187811
# 3    0.020686
# 4    0.106549

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   mf_chm_MIN     103 non-null    float64
#  8   r_MIN          103 non-null    int64
#  9   b_STD          103 non-null    float64
#  10  contr_r_STD    103 non-null    float64
#  11  corr_r_Q25     103 non-null    float64
#  12  corr_r_MIN     103 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 10.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Cs_wood", "ln_Sr_wood"].describe()
# Out:
#                  ln_Cs_wood                                                 \
#                       count       mean       std     min      25%      50%
# Dominant_specias
# Alder                   4.0   7.305000  1.427622   5.886   6.6765   7.0235
# Aspen                   1.0  11.367000       NaN  11.367  11.3670  11.3670
# Birch                  23.0   7.304652  1.533182   4.533   6.3365   7.2150
# Oak                     3.0   7.430333  1.260072   6.040   6.8970   7.7540
# Pine                   71.0   6.901690  1.650166   3.526   6.3790   6.9470
# Spruce                  1.0   5.176000       NaN   5.176   5.1760   5.1760
#
#                                   ln_Sr_wood                               \
#                       75%     max      count       mean       std     min
# Dominant_specias
# Alder              7.6520   9.287        4.0   7.206000  0.650057   6.265
# Aspen             11.3670  11.367        1.0  11.090000       NaN  11.090
# Birch              8.0320  10.332       23.0   9.345478  1.626360   7.139
# Oak                8.1255   8.497        3.0   7.483667  0.815040   6.565
# Pine               7.6960  10.469       71.0   8.542592  1.359020   6.075
# Spruce             5.1760   5.176        1.0   7.783000       NaN   7.783
#
#
#                       25%      50%      75%     max
# Dominant_specias
# Alder              7.0255   7.4545   7.6350   7.650
# Aspen             11.0900  11.0900  11.0900  11.090
# Birch              8.4000   8.9910   9.9365  13.864
# Oak                7.1655   7.7660   7.9430   8.120
# Pine               7.6450   8.4720   9.3710  12.687
# Spruce             7.7830   7.7830   7.7830   7.783

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3440.194175    1242.902913   -0.252563
# std       1.64946    1.472424    6087.580089    2037.684800    1.104610
# min       3.52600    6.075000     260.000000      50.000000   -3.033000
# 25%       6.31900    7.664000     635.000000     200.000000   -0.727500
# 50%       6.95700    8.472000    1150.000000     400.000000   -0.025000
# 75%       7.91350    9.421000    2525.000000    1400.000000    0.516500
# max      11.36700   13.864000   35200.000000   10500.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean  mf_chm_MIN       r_MIN       b_STD  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     2.464709    3.570291    3.368496   11.378641   35.164575
# std      0.904675    6.089170    4.845054    9.139568    5.338700
# min      0.391000    0.480000   -0.018586    2.000000   20.570709
# 25%      1.803000    0.710000    0.482279    5.000000   31.746440
# 50%      2.603000    1.290000    0.642883    8.000000   36.135511
# 75%      3.159000    2.960000    3.921804   15.000000   39.139044
# max      4.659000   36.590000   17.862923   56.000000   45.825416
#
#        contr_r_STD  corr_r_Q25  corr_r_MIN
# count   103.000000  103.000000  103.000000
# mean    327.115078    0.393571    0.073579
# std     167.617957    0.151801    0.056017
# min       0.091058    0.033797   -0.062450
# 25%     283.887328    0.407228    0.027204
# 50%     353.034542    0.449670    0.063714
# 75%     448.017711    0.476635    0.110983
# max     652.546648    0.555648    0.241284

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_Cs_wood"
indep_variables = ['AEDR_mean']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  \
# 0         6.824       9.240           2260           1210     -0.731
# 1         8.189       9.622           2700           1180      0.585
# 2         8.380       9.589           2500           1400      0.779
# 3         8.137       9.449           2500           1090      0.517
# 4         7.696       9.401           2400            720      0.224
# ..          ...         ...            ...            ...        ...
# 98        8.071       8.434           2500           1300      0.228
# 99        7.993      10.042           2300           1100      0.266
# 100       8.343      10.488           2400           1200      0.543
# 101       3.638       6.399            630            270     -2.811
# 102       4.787       6.877            680            290     -1.728
#
#      ln_Tag_Sr  AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  \
# 0        2.576       2.33    0.445070     13  35.145074   360.273487
# 1        2.915       2.47   12.465903     24  36.135511   323.958625
# 2        2.882       2.44   13.028298     18  35.938764   299.438354
# 3        2.724       2.55    2.128231     15  35.908361   319.773395
# 4        2.826       2.14   12.171553      8  38.062522   353.104284
# ..         ...        ...         ...    ...        ...          ...
# 98       1.514       2.92    0.528681      3  32.852994   329.221211
# 99       3.230       2.78    0.422647     18  27.970146   268.895699
# 100      3.606       2.92    0.426717     19  30.529613   251.314791
# 101      0.805       0.75    0.476680      6  37.245047   477.751734
# 102      1.199       0.78    0.410141      2  38.454424   412.535053
#
#      corr_r_Q25  corr_r_MIN
# 0      0.488754    0.072792
# 1      0.501683    0.098347
# 2      0.540056    0.187811
# 3      0.480991    0.020686
# 4      0.505257    0.106549
# ..          ...         ...
# 98     0.478581    0.079646
# 99     0.467111    0.063714
# 100    0.501777    0.128376
# 101    0.467443    0.129664
# 102    0.480964    0.157460
#
# [103 rows x 13 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    AEDR_mean
# 0       2.33
# 1       2.47
# 2       2.44
# 3       2.55
# 4       2.14

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Cs_wood
# 0       6.824
# 1       8.189
# 2       8.380
# 3       8.137
# 4       7.696

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.22955629077331308, -0.006395788766286659, 0.025201452842550154]
#     Mean: 0.083
#     Std: 0.105
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.43691551 1.53368429 1.53275661]
#     Mean: 1.501
#     Std: 0.045
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [1.371085469654628, 1.0018980878381165, 1.2369099682078646]
#     Mean: 1.203
#     Std: 0.153
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.4779190946674869                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.26073043635982945                 # gamma
print('Gamma: ' + str(p2))

p3 = 0.10923037448181477                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2                                   # max_depth
print('Max_depth: ' + str(p4))

p5 = 52                                  # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.3149008329364235                   # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.4779190946674869
# Gamma: 0.26073043635982945
# Learning_rate: 0.10923037448181477
# Max_depth: 2
# N_estimators: 52
# Subsample: 0.3149008329364235

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=10, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:6.23350	validation_1-rmse:5.63325
# [1]	validation_0-rmse:5.66340	validation_1-rmse:5.07099
# [2]	validation_0-rmse:5.14429	validation_1-rmse:4.57343
# [3]	validation_0-rmse:4.67377	validation_1-rmse:4.11503
# [4]	validation_0-rmse:4.26220	validation_1-rmse:3.73107
# [5]	validation_0-rmse:3.90580	validation_1-rmse:3.39930
# [6]	validation_0-rmse:3.58542	validation_1-rmse:3.11706
# [7]	validation_0-rmse:3.28602	validation_1-rmse:2.84204
# [8]	validation_0-rmse:3.03051	validation_1-rmse:2.60542
# [9]	validation_0-rmse:2.76328	validation_1-rmse:2.39821
# [10]	validation_0-rmse:2.55341	validation_1-rmse:2.22016
# [11]	validation_0-rmse:2.36521	validation_1-rmse:2.09300
# [12]	validation_0-rmse:2.18499	validation_1-rmse:1.94862
# [13]	validation_0-rmse:2.02061	validation_1-rmse:1.83916
# [14]	validation_0-rmse:1.88453	validation_1-rmse:1.75662
# [15]	validation_0-rmse:1.77349	validation_1-rmse:1.66388
# [16]	validation_0-rmse:1.64242	validation_1-rmse:1.58759
# [17]	validation_0-rmse:1.54592	validation_1-rmse:1.53015
# [18]	validation_0-rmse:1.46974	validation_1-rmse:1.49042
# [19]	validation_0-rmse:1.39708	validation_1-rmse:1.44091
# [20]	validation_0-rmse:1.32764	validation_1-rmse:1.40004
# [21]	validation_0-rmse:1.27407	validation_1-rmse:1.37849
# [22]	validation_0-rmse:1.20779	validation_1-rmse:1.36014
# [23]	validation_0-rmse:1.17262	validation_1-rmse:1.34834
# [24]	validation_0-rmse:1.14561	validation_1-rmse:1.34917
# [25]	validation_0-rmse:1.12889	validation_1-rmse:1.34129
# [26]	validation_0-rmse:1.09862	validation_1-rmse:1.32847
# [27]	validation_0-rmse:1.06353	validation_1-rmse:1.32459
# [28]	validation_0-rmse:1.03467	validation_1-rmse:1.31392
# [29]	validation_0-rmse:1.00386	validation_1-rmse:1.31732
# [30]	validation_0-rmse:0.98682	validation_1-rmse:1.32227
# [31]	validation_0-rmse:0.97723	validation_1-rmse:1.32866
# [32]	validation_0-rmse:0.97066	validation_1-rmse:1.34422
# [33]	validation_0-rmse:0.96941	validation_1-rmse:1.31960
# [34]	validation_0-rmse:0.94765	validation_1-rmse:1.33364
# [35]	validation_0-rmse:0.94036	validation_1-rmse:1.34451
# [36]	validation_0-rmse:0.93055	validation_1-rmse:1.34226
# [37]	validation_0-rmse:0.92555	validation_1-rmse:1.33910
# [0]	validation_0-rmse:6.06204	validation_1-rmse:6.01886
# [1]	validation_0-rmse:5.47856	validation_1-rmse:5.43070
# [2]	validation_0-rmse:4.94278	validation_1-rmse:4.88962
# [3]	validation_0-rmse:4.50371	validation_1-rmse:4.50261
# [4]	validation_0-rmse:4.12277	validation_1-rmse:4.17310
# [5]	validation_0-rmse:3.73931	validation_1-rmse:3.78291
# [6]	validation_0-rmse:3.42234	validation_1-rmse:3.49541
# [7]	validation_0-rmse:3.12410	validation_1-rmse:3.18884
# [8]	validation_0-rmse:2.83946	validation_1-rmse:2.90083
# [9]	validation_0-rmse:2.63459	validation_1-rmse:2.68849
# [10]	validation_0-rmse:2.42925	validation_1-rmse:2.47593
# [11]	validation_0-rmse:2.23993	validation_1-rmse:2.28538
# [12]	validation_0-rmse:2.07144	validation_1-rmse:2.15542
# [13]	validation_0-rmse:1.93112	validation_1-rmse:2.05612
# [14]	validation_0-rmse:1.79596	validation_1-rmse:1.91813
# [15]	validation_0-rmse:1.67555	validation_1-rmse:1.78610
# [16]	validation_0-rmse:1.56267	validation_1-rmse:1.67518
# [17]	validation_0-rmse:1.48186	validation_1-rmse:1.57259
# [18]	validation_0-rmse:1.42117	validation_1-rmse:1.54201
# [19]	validation_0-rmse:1.35326	validation_1-rmse:1.52158
# [20]	validation_0-rmse:1.28766	validation_1-rmse:1.49268
# [21]	validation_0-rmse:1.23962	validation_1-rmse:1.44020
# [22]	validation_0-rmse:1.17934	validation_1-rmse:1.38026
# [23]	validation_0-rmse:1.14428	validation_1-rmse:1.31678
# [24]	validation_0-rmse:1.12802	validation_1-rmse:1.32232
# [25]	validation_0-rmse:1.10708	validation_1-rmse:1.32873
# [26]	validation_0-rmse:1.08897	validation_1-rmse:1.30365
# [27]	validation_0-rmse:1.07349	validation_1-rmse:1.28515
# [28]	validation_0-rmse:1.06100	validation_1-rmse:1.23633
# [29]	validation_0-rmse:1.04594	validation_1-rmse:1.21592
# [30]	validation_0-rmse:1.04423	validation_1-rmse:1.24137
# [31]	validation_0-rmse:1.03494	validation_1-rmse:1.23817
# [32]	validation_0-rmse:1.02970	validation_1-rmse:1.25426
# [33]	validation_0-rmse:1.02461	validation_1-rmse:1.25572
# [34]	validation_0-rmse:1.02285	validation_1-rmse:1.21618
# [35]	validation_0-rmse:1.02507	validation_1-rmse:1.24535
# [36]	validation_0-rmse:1.02343	validation_1-rmse:1.23746
# [37]	validation_0-rmse:1.01424	validation_1-rmse:1.20053
# [38]	validation_0-rmse:1.01311	validation_1-rmse:1.19797
# [39]	validation_0-rmse:1.01357	validation_1-rmse:1.21308
# [40]	validation_0-rmse:1.00525	validation_1-rmse:1.16616
# [41]	validation_0-rmse:0.99202	validation_1-rmse:1.17027
# [42]	validation_0-rmse:0.99019	validation_1-rmse:1.15260
# [43]	validation_0-rmse:0.99161	validation_1-rmse:1.18360
# [44]	validation_0-rmse:0.99056	validation_1-rmse:1.20735
# [45]	validation_0-rmse:0.99005	validation_1-rmse:1.19017
# [46]	validation_0-rmse:0.98392	validation_1-rmse:1.19220
# [47]	validation_0-rmse:0.98429	validation_1-rmse:1.23406
# [48]	validation_0-rmse:0.98039	validation_1-rmse:1.20743
# [49]	validation_0-rmse:0.97288	validation_1-rmse:1.21321
# [50]	validation_0-rmse:0.97434	validation_1-rmse:1.22968
# [51]	validation_0-rmse:0.97297	validation_1-rmse:1.19534
# [0]	validation_0-rmse:5.95552	validation_1-rmse:6.65459
# [1]	validation_0-rmse:5.38399	validation_1-rmse:6.09140
# [2]	validation_0-rmse:4.88027	validation_1-rmse:5.59595
# [3]	validation_0-rmse:4.45829	validation_1-rmse:5.15224
# [4]	validation_0-rmse:4.04722	validation_1-rmse:4.72502
# [5]	validation_0-rmse:3.71531	validation_1-rmse:4.40576
# [6]	validation_0-rmse:3.36411	validation_1-rmse:4.01193
# [7]	validation_0-rmse:3.03422	validation_1-rmse:3.66349
# [8]	validation_0-rmse:2.77921	validation_1-rmse:3.38749
# [9]	validation_0-rmse:2.56421	validation_1-rmse:3.17014
# [10]	validation_0-rmse:2.37768	validation_1-rmse:2.96164
# [11]	validation_0-rmse:2.19315	validation_1-rmse:2.78437
# [12]	validation_0-rmse:2.01533	validation_1-rmse:2.57550
# [13]	validation_0-rmse:1.88928	validation_1-rmse:2.42483
# [14]	validation_0-rmse:1.75543	validation_1-rmse:2.27566
# [15]	validation_0-rmse:1.68335	validation_1-rmse:2.18580
# [16]	validation_0-rmse:1.60750	validation_1-rmse:2.10276
# [17]	validation_0-rmse:1.53290	validation_1-rmse:1.99208
# [18]	validation_0-rmse:1.45799	validation_1-rmse:1.89149
# [19]	validation_0-rmse:1.40077	validation_1-rmse:1.84119
# [20]	validation_0-rmse:1.36080	validation_1-rmse:1.77166
# [21]	validation_0-rmse:1.30117	validation_1-rmse:1.68737
# [22]	validation_0-rmse:1.24722	validation_1-rmse:1.62965
# [23]	validation_0-rmse:1.20643	validation_1-rmse:1.56602
# [24]	validation_0-rmse:1.18274	validation_1-rmse:1.54660
# [25]	validation_0-rmse:1.15518	validation_1-rmse:1.51497
# [26]	validation_0-rmse:1.15043	validation_1-rmse:1.48969
# [27]	validation_0-rmse:1.11705	validation_1-rmse:1.44078
# [28]	validation_0-rmse:1.09151	validation_1-rmse:1.38630
# [29]	validation_0-rmse:1.06672	validation_1-rmse:1.34514
# [30]	validation_0-rmse:1.05489	validation_1-rmse:1.32011
# [31]	validation_0-rmse:1.04998	validation_1-rmse:1.30223
# [32]	validation_0-rmse:1.04354	validation_1-rmse:1.29619
# [33]	validation_0-rmse:1.03981	validation_1-rmse:1.27560
# [34]	validation_0-rmse:1.03056	validation_1-rmse:1.26537
# [35]	validation_0-rmse:1.02206	validation_1-rmse:1.24592
# [36]	validation_0-rmse:1.01376	validation_1-rmse:1.22811
# [37]	validation_0-rmse:1.01233	validation_1-rmse:1.23321
# [38]	validation_0-rmse:1.00792	validation_1-rmse:1.23572
# [39]	validation_0-rmse:1.01134	validation_1-rmse:1.22949
# [40]	validation_0-rmse:1.00649	validation_1-rmse:1.23857
# [41]	validation_0-rmse:0.99546	validation_1-rmse:1.22738
# [42]	validation_0-rmse:0.98825	validation_1-rmse:1.23951
# [43]	validation_0-rmse:0.98505	validation_1-rmse:1.23191
# [44]	validation_0-rmse:0.97684	validation_1-rmse:1.22647
# [45]	validation_0-rmse:0.97589	validation_1-rmse:1.22015
# [46]	validation_0-rmse:0.97589	validation_1-rmse:1.23267
# [47]	validation_0-rmse:0.97687	validation_1-rmse:1.23850
# [48]	validation_0-rmse:0.96590	validation_1-rmse:1.23812
# [49]	validation_0-rmse:0.96215	validation_1-rmse:1.23882
# [50]	validation_0-rmse:0.95863	validation_1-rmse:1.23129
# [51]	validation_0-rmse:0.95670	validation_1-rmse:1.21822
# [0]	validation_0-rmse:6.13532	validation_1-rmse:6.03575
# [1]	validation_0-rmse:5.51304	validation_1-rmse:5.41705
# [2]	validation_0-rmse:4.97484	validation_1-rmse:4.88191
# [3]	validation_0-rmse:4.57825	validation_1-rmse:4.47198
# [4]	validation_0-rmse:4.15377	validation_1-rmse:4.08210
# [5]	validation_0-rmse:3.79297	validation_1-rmse:3.71884
# [6]	validation_0-rmse:3.41987	validation_1-rmse:3.35312
# [7]	validation_0-rmse:3.12831	validation_1-rmse:3.05465
# [8]	validation_0-rmse:2.84159	validation_1-rmse:2.79490
# [9]	validation_0-rmse:2.57491	validation_1-rmse:2.53739
# [10]	validation_0-rmse:2.36002	validation_1-rmse:2.31299
# [11]	validation_0-rmse:2.20548	validation_1-rmse:2.15946
# [12]	validation_0-rmse:2.03065	validation_1-rmse:1.98661
# [13]	validation_0-rmse:1.89938	validation_1-rmse:1.88338
# [14]	validation_0-rmse:1.78726	validation_1-rmse:1.78203
# [15]	validation_0-rmse:1.65433	validation_1-rmse:1.64550
# [16]	validation_0-rmse:1.57395	validation_1-rmse:1.58193
# [17]	validation_0-rmse:1.48274	validation_1-rmse:1.50395
# [18]	validation_0-rmse:1.41016	validation_1-rmse:1.45530
# [19]	validation_0-rmse:1.36093	validation_1-rmse:1.40382
# [20]	validation_0-rmse:1.31334	validation_1-rmse:1.37091
# [21]	validation_0-rmse:1.26506	validation_1-rmse:1.34329
# [22]	validation_0-rmse:1.22668	validation_1-rmse:1.29452
# [23]	validation_0-rmse:1.17314	validation_1-rmse:1.25878
# [24]	validation_0-rmse:1.15146	validation_1-rmse:1.23853
# [25]	validation_0-rmse:1.13280	validation_1-rmse:1.20275
# [26]	validation_0-rmse:1.12042	validation_1-rmse:1.18715
# [27]	validation_0-rmse:1.08559	validation_1-rmse:1.14204
# [28]	validation_0-rmse:1.06005	validation_1-rmse:1.13586
# [29]	validation_0-rmse:1.04439	validation_1-rmse:1.15037
# [30]	validation_0-rmse:1.03080	validation_1-rmse:1.13899
# [31]	validation_0-rmse:1.02071	validation_1-rmse:1.11553
# [32]	validation_0-rmse:1.00510	validation_1-rmse:1.11749
# [33]	validation_0-rmse:0.99460	validation_1-rmse:1.10744
# [34]	validation_0-rmse:0.97838	validation_1-rmse:1.10058
# [35]	validation_0-rmse:0.97884	validation_1-rmse:1.10415
# [36]	validation_0-rmse:0.97056	validation_1-rmse:1.10833
# [37]	validation_0-rmse:0.96366	validation_1-rmse:1.10839
# [38]	validation_0-rmse:0.96045	validation_1-rmse:1.10454
# [39]	validation_0-rmse:0.95912	validation_1-rmse:1.11458
# [40]	validation_0-rmse:0.95627	validation_1-rmse:1.10429
# [41]	validation_0-rmse:0.95481	validation_1-rmse:1.11526
# [42]	validation_0-rmse:0.95756	validation_1-rmse:1.11827
# [43]	validation_0-rmse:0.95581	validation_1-rmse:1.11691
# [0]	validation_0-rmse:6.13980	validation_1-rmse:5.94127
# [1]	validation_0-rmse:5.56573	validation_1-rmse:5.37007
# [2]	validation_0-rmse:5.04413	validation_1-rmse:4.87975
# [3]	validation_0-rmse:4.61548	validation_1-rmse:4.44897
# [4]	validation_0-rmse:4.20517	validation_1-rmse:4.03638
# [5]	validation_0-rmse:3.82428	validation_1-rmse:3.67440
# [6]	validation_0-rmse:3.47815	validation_1-rmse:3.33458
# [7]	validation_0-rmse:3.18368	validation_1-rmse:3.04724
# [8]	validation_0-rmse:2.89730	validation_1-rmse:2.78115
# [9]	validation_0-rmse:2.66528	validation_1-rmse:2.54655
# [10]	validation_0-rmse:2.46608	validation_1-rmse:2.36680
# [11]	validation_0-rmse:2.26609	validation_1-rmse:2.16931
# [12]	validation_0-rmse:2.09180	validation_1-rmse:2.02411
# [13]	validation_0-rmse:1.95716	validation_1-rmse:1.90023
# [14]	validation_0-rmse:1.83499	validation_1-rmse:1.78436
# [15]	validation_0-rmse:1.71655	validation_1-rmse:1.68009
# [16]	validation_0-rmse:1.60104	validation_1-rmse:1.58932
# [17]	validation_0-rmse:1.52001	validation_1-rmse:1.52195
# [18]	validation_0-rmse:1.46211	validation_1-rmse:1.48830
# [19]	validation_0-rmse:1.41588	validation_1-rmse:1.45520
# [20]	validation_0-rmse:1.33860	validation_1-rmse:1.38874
# [21]	validation_0-rmse:1.28642	validation_1-rmse:1.36231
# [22]	validation_0-rmse:1.24117	validation_1-rmse:1.30083
# [23]	validation_0-rmse:1.20886	validation_1-rmse:1.28229
# [24]	validation_0-rmse:1.17142	validation_1-rmse:1.24733
# [25]	validation_0-rmse:1.13840	validation_1-rmse:1.21699
# [26]	validation_0-rmse:1.09806	validation_1-rmse:1.17843
# [27]	validation_0-rmse:1.07737	validation_1-rmse:1.16344
# [28]	validation_0-rmse:1.05765	validation_1-rmse:1.15282
# [29]	validation_0-rmse:1.04241	validation_1-rmse:1.13744
# [30]	validation_0-rmse:1.02908	validation_1-rmse:1.11888
# [31]	validation_0-rmse:1.01592	validation_1-rmse:1.11793
# [32]	validation_0-rmse:0.99982	validation_1-rmse:1.10473
# [33]	validation_0-rmse:0.98760	validation_1-rmse:1.09981
# [34]	validation_0-rmse:0.98659	validation_1-rmse:1.11407
# [35]	validation_0-rmse:0.98319	validation_1-rmse:1.10241
# [36]	validation_0-rmse:0.98027	validation_1-rmse:1.10980
# [37]	validation_0-rmse:0.97221	validation_1-rmse:1.11498
# [38]	validation_0-rmse:0.96762	validation_1-rmse:1.11573
# [39]	validation_0-rmse:0.96008	validation_1-rmse:1.11485
# [40]	validation_0-rmse:0.95823	validation_1-rmse:1.11977
# [41]	validation_0-rmse:0.95471	validation_1-rmse:1.11879
# [42]	validation_0-rmse:0.94731	validation_1-rmse:1.12633
# [43]	validation_0-rmse:0.94466	validation_1-rmse:1.11048
# [0]	validation_0-rmse:6.16905	validation_1-rmse:5.87747
# [1]	validation_0-rmse:5.60096	validation_1-rmse:5.33485
# [2]	validation_0-rmse:5.03259	validation_1-rmse:4.78967
# [3]	validation_0-rmse:4.53130	validation_1-rmse:4.31494
# [4]	validation_0-rmse:4.12633	validation_1-rmse:3.94452
# [5]	validation_0-rmse:3.76123	validation_1-rmse:3.60770
# [6]	validation_0-rmse:3.41169	validation_1-rmse:3.29271
# [7]	validation_0-rmse:3.09704	validation_1-rmse:3.02455
# [8]	validation_0-rmse:2.82119	validation_1-rmse:2.78274
# [9]	validation_0-rmse:2.56480	validation_1-rmse:2.56302
# [10]	validation_0-rmse:2.35581	validation_1-rmse:2.40601
# [11]	validation_0-rmse:2.19864	validation_1-rmse:2.29448
# [12]	validation_0-rmse:2.01104	validation_1-rmse:2.13822
# [13]	validation_0-rmse:1.85832	validation_1-rmse:2.01439
# [14]	validation_0-rmse:1.75421	validation_1-rmse:1.93398
# [15]	validation_0-rmse:1.60683	validation_1-rmse:1.83830
# [16]	validation_0-rmse:1.49024	validation_1-rmse:1.74928
# [17]	validation_0-rmse:1.42900	validation_1-rmse:1.70226
# [18]	validation_0-rmse:1.32564	validation_1-rmse:1.66071
# [19]	validation_0-rmse:1.27904	validation_1-rmse:1.66171
# [20]	validation_0-rmse:1.21647	validation_1-rmse:1.63673
# [21]	validation_0-rmse:1.16753	validation_1-rmse:1.61286
# [22]	validation_0-rmse:1.12839	validation_1-rmse:1.61003
# [23]	validation_0-rmse:1.08549	validation_1-rmse:1.59200
# [24]	validation_0-rmse:1.04925	validation_1-rmse:1.56863
# [25]	validation_0-rmse:1.02340	validation_1-rmse:1.55956
# [26]	validation_0-rmse:0.99052	validation_1-rmse:1.56230
# [27]	validation_0-rmse:0.97011	validation_1-rmse:1.56472
# [28]	validation_0-rmse:0.95309	validation_1-rmse:1.54045
# [29]	validation_0-rmse:0.93359	validation_1-rmse:1.53359
# [30]	validation_0-rmse:0.93368	validation_1-rmse:1.54921
# [31]	validation_0-rmse:0.91763	validation_1-rmse:1.53812
# [32]	validation_0-rmse:0.90950	validation_1-rmse:1.53118
# [33]	validation_0-rmse:0.88935	validation_1-rmse:1.53342
# [34]	validation_0-rmse:0.87791	validation_1-rmse:1.53100
# [35]	validation_0-rmse:0.87165	validation_1-rmse:1.52177
# [36]	validation_0-rmse:0.86683	validation_1-rmse:1.54028
# [37]	validation_0-rmse:0.86297	validation_1-rmse:1.53528
# [38]	validation_0-rmse:0.85911	validation_1-rmse:1.54544
# [39]	validation_0-rmse:0.84856	validation_1-rmse:1.53240
# [40]	validation_0-rmse:0.84438	validation_1-rmse:1.52767
# [41]	validation_0-rmse:0.83887	validation_1-rmse:1.52089
# [42]	validation_0-rmse:0.83819	validation_1-rmse:1.51583
# [43]	validation_0-rmse:0.83087	validation_1-rmse:1.53048
# [44]	validation_0-rmse:0.83332	validation_1-rmse:1.54377
# [45]	validation_0-rmse:0.83062	validation_1-rmse:1.53133
# [46]	validation_0-rmse:0.82630	validation_1-rmse:1.54361
# [47]	validation_0-rmse:0.82314	validation_1-rmse:1.54500
# [48]	validation_0-rmse:0.82205	validation_1-rmse:1.53762
# [49]	validation_0-rmse:0.82023	validation_1-rmse:1.52974
# [50]	validation_0-rmse:0.81865	validation_1-rmse:1.54860
# [51]	validation_0-rmse:0.81440	validation_1-rmse:1.53550
# [0]	validation_0-rmse:6.08492	validation_1-rmse:6.02734
# [1]	validation_0-rmse:5.47786	validation_1-rmse:5.42673
# [2]	validation_0-rmse:4.94851	validation_1-rmse:4.90444
# [3]	validation_0-rmse:4.48723	validation_1-rmse:4.44651
# [4]	validation_0-rmse:4.04513	validation_1-rmse:4.01253
# [5]	validation_0-rmse:3.67034	validation_1-rmse:3.64610
# [6]	validation_0-rmse:3.35343	validation_1-rmse:3.31953
# [7]	validation_0-rmse:3.01896	validation_1-rmse:2.97466
# [8]	validation_0-rmse:2.77025	validation_1-rmse:2.71850
# [9]	validation_0-rmse:2.52859	validation_1-rmse:2.46726
# [10]	validation_0-rmse:2.30918	validation_1-rmse:2.25880
# [11]	validation_0-rmse:2.20073	validation_1-rmse:2.12018
# [12]	validation_0-rmse:2.03772	validation_1-rmse:1.94922
# [13]	validation_0-rmse:1.90985	validation_1-rmse:1.81159
# [14]	validation_0-rmse:1.79938	validation_1-rmse:1.70943
# [15]	validation_0-rmse:1.66942	validation_1-rmse:1.57903
# [16]	validation_0-rmse:1.57206	validation_1-rmse:1.49660
# [17]	validation_0-rmse:1.48120	validation_1-rmse:1.40810
# [18]	validation_0-rmse:1.42867	validation_1-rmse:1.35178
# [19]	validation_0-rmse:1.37423	validation_1-rmse:1.30421
# [20]	validation_0-rmse:1.31605	validation_1-rmse:1.24171
# [21]	validation_0-rmse:1.27368	validation_1-rmse:1.20133
# [22]	validation_0-rmse:1.23997	validation_1-rmse:1.15872
# [23]	validation_0-rmse:1.20345	validation_1-rmse:1.11035
# [24]	validation_0-rmse:1.19395	validation_1-rmse:1.08247
# [25]	validation_0-rmse:1.17047	validation_1-rmse:1.06972
# [26]	validation_0-rmse:1.14339	validation_1-rmse:1.05133
# [27]	validation_0-rmse:1.14334	validation_1-rmse:1.03028
# [28]	validation_0-rmse:1.11473	validation_1-rmse:1.02822
# [29]	validation_0-rmse:1.09792	validation_1-rmse:1.03108
# [30]	validation_0-rmse:1.08608	validation_1-rmse:1.01719
# [31]	validation_0-rmse:1.06165	validation_1-rmse:1.01651
# [32]	validation_0-rmse:1.04423	validation_1-rmse:1.00015
# [33]	validation_0-rmse:1.03481	validation_1-rmse:1.02579
# [34]	validation_0-rmse:1.03252	validation_1-rmse:0.99318
# [35]	validation_0-rmse:1.02852	validation_1-rmse:0.98693
# [36]	validation_0-rmse:1.01794	validation_1-rmse:0.98158
# [37]	validation_0-rmse:1.00540	validation_1-rmse:0.99556
# [38]	validation_0-rmse:1.00152	validation_1-rmse:1.00393
# [39]	validation_0-rmse:0.99312	validation_1-rmse:1.02717
# [40]	validation_0-rmse:0.99149	validation_1-rmse:1.02992
# [41]	validation_0-rmse:0.98981	validation_1-rmse:1.00531
# [42]	validation_0-rmse:0.98899	validation_1-rmse:1.00459
# [43]	validation_0-rmse:0.98585	validation_1-rmse:0.99966
# [44]	validation_0-rmse:0.98263	validation_1-rmse:0.98424
# [45]	validation_0-rmse:0.97861	validation_1-rmse:0.98071
# [46]	validation_0-rmse:0.97728	validation_1-rmse:0.96788
# [47]	validation_0-rmse:0.97966	validation_1-rmse:0.96353
# [48]	validation_0-rmse:0.98534	validation_1-rmse:0.97891
# [49]	validation_0-rmse:0.98361	validation_1-rmse:0.97024
# [50]	validation_0-rmse:0.97988	validation_1-rmse:0.94738
# [51]	validation_0-rmse:0.97381	validation_1-rmse:0.95031
# [0]	validation_0-rmse:6.12491	validation_1-rmse:6.14175
# [1]	validation_0-rmse:5.54713	validation_1-rmse:5.56508
# [2]	validation_0-rmse:4.99601	validation_1-rmse:4.98601
# [3]	validation_0-rmse:4.49772	validation_1-rmse:4.47186
# [4]	validation_0-rmse:4.07724	validation_1-rmse:4.03469
# [5]	validation_0-rmse:3.74619	validation_1-rmse:3.67242
# [6]	validation_0-rmse:3.42493	validation_1-rmse:3.33092
# [7]	validation_0-rmse:3.15031	validation_1-rmse:3.05570
# [8]	validation_0-rmse:2.88220	validation_1-rmse:2.80134
# [9]	validation_0-rmse:2.67709	validation_1-rmse:2.57909
# [10]	validation_0-rmse:2.46658	validation_1-rmse:2.36892
# [11]	validation_0-rmse:2.30571	validation_1-rmse:2.19024
# [12]	validation_0-rmse:2.12169	validation_1-rmse:2.01280
# [13]	validation_0-rmse:1.98426	validation_1-rmse:1.85537
# [14]	validation_0-rmse:1.84693	validation_1-rmse:1.70316
# [15]	validation_0-rmse:1.72570	validation_1-rmse:1.56787
# [16]	validation_0-rmse:1.61390	validation_1-rmse:1.47205
# [17]	validation_0-rmse:1.52551	validation_1-rmse:1.38444
# [18]	validation_0-rmse:1.44098	validation_1-rmse:1.29992
# [19]	validation_0-rmse:1.37525	validation_1-rmse:1.23756
# [20]	validation_0-rmse:1.32478	validation_1-rmse:1.17624
# [21]	validation_0-rmse:1.27419	validation_1-rmse:1.14603
# [22]	validation_0-rmse:1.24803	validation_1-rmse:1.11820
# [23]	validation_0-rmse:1.21300	validation_1-rmse:1.09386
# [24]	validation_0-rmse:1.18936	validation_1-rmse:1.07459
# [25]	validation_0-rmse:1.16862	validation_1-rmse:1.06674
# [26]	validation_0-rmse:1.14962	validation_1-rmse:1.05710
# [27]	validation_0-rmse:1.12079	validation_1-rmse:1.03965
# [28]	validation_0-rmse:1.10427	validation_1-rmse:1.03185
# [29]	validation_0-rmse:1.07941	validation_1-rmse:1.01058
# [30]	validation_0-rmse:1.06763	validation_1-rmse:0.99990
# [31]	validation_0-rmse:1.05554	validation_1-rmse:0.99489
# [32]	validation_0-rmse:1.03783	validation_1-rmse:0.96718
# [33]	validation_0-rmse:1.02885	validation_1-rmse:0.97159
# [34]	validation_0-rmse:1.03290	validation_1-rmse:0.96534
# [35]	validation_0-rmse:1.02857	validation_1-rmse:0.98454
# [36]	validation_0-rmse:1.01403	validation_1-rmse:0.99373
# [37]	validation_0-rmse:1.00343	validation_1-rmse:0.98501
# [38]	validation_0-rmse:0.99668	validation_1-rmse:0.98507
# [39]	validation_0-rmse:0.98787	validation_1-rmse:0.97997
# [40]	validation_0-rmse:0.98498	validation_1-rmse:0.96834
# [41]	validation_0-rmse:0.98031	validation_1-rmse:0.96485
# [42]	validation_0-rmse:0.97190	validation_1-rmse:0.96281
# [43]	validation_0-rmse:0.96511	validation_1-rmse:0.96819
# [44]	validation_0-rmse:0.96148	validation_1-rmse:0.98868
# [45]	validation_0-rmse:0.95820	validation_1-rmse:0.99007
# [46]	validation_0-rmse:0.96204	validation_1-rmse:1.01415
# [47]	validation_0-rmse:0.95698	validation_1-rmse:1.00559
# [48]	validation_0-rmse:0.95529	validation_1-rmse:1.01591
# [49]	validation_0-rmse:0.95250	validation_1-rmse:1.01646
# [50]	validation_0-rmse:0.94730	validation_1-rmse:1.00180
# [51]	validation_0-rmse:0.94522	validation_1-rmse:1.01059
# [0]	validation_0-rmse:5.98954	validation_1-rmse:6.52918
# [1]	validation_0-rmse:5.41079	validation_1-rmse:5.92928
# [2]	validation_0-rmse:4.91267	validation_1-rmse:5.37221
# [3]	validation_0-rmse:4.45659	validation_1-rmse:4.90306
# [4]	validation_0-rmse:4.03333	validation_1-rmse:4.47032
# [5]	validation_0-rmse:3.67154	validation_1-rmse:4.05409
# [6]	validation_0-rmse:3.36378	validation_1-rmse:3.71528
# [7]	validation_0-rmse:3.07882	validation_1-rmse:3.41353
# [8]	validation_0-rmse:2.79515	validation_1-rmse:3.08935
# [9]	validation_0-rmse:2.54925	validation_1-rmse:2.79762
# [10]	validation_0-rmse:2.38580	validation_1-rmse:2.61383
# [11]	validation_0-rmse:2.25448	validation_1-rmse:2.44572
# [12]	validation_0-rmse:2.07861	validation_1-rmse:2.25221
# [13]	validation_0-rmse:1.93803	validation_1-rmse:2.10460
# [14]	validation_0-rmse:1.86845	validation_1-rmse:2.00984
# [15]	validation_0-rmse:1.76018	validation_1-rmse:1.88959
# [16]	validation_0-rmse:1.64435	validation_1-rmse:1.72762
# [17]	validation_0-rmse:1.55522	validation_1-rmse:1.62690
# [18]	validation_0-rmse:1.45701	validation_1-rmse:1.49802
# [19]	validation_0-rmse:1.39325	validation_1-rmse:1.43769
# [20]	validation_0-rmse:1.32771	validation_1-rmse:1.37164
# [21]	validation_0-rmse:1.26730	validation_1-rmse:1.27546
# [22]	validation_0-rmse:1.22679	validation_1-rmse:1.21056
# [23]	validation_0-rmse:1.20467	validation_1-rmse:1.19100
# [24]	validation_0-rmse:1.16977	validation_1-rmse:1.12882
# [25]	validation_0-rmse:1.14743	validation_1-rmse:1.09918
# [26]	validation_0-rmse:1.12845	validation_1-rmse:1.08725
# [27]	validation_0-rmse:1.12619	validation_1-rmse:1.07882
# [28]	validation_0-rmse:1.10132	validation_1-rmse:1.05073
# [29]	validation_0-rmse:1.09721	validation_1-rmse:1.05905
# [30]	validation_0-rmse:1.08153	validation_1-rmse:1.02874
# [31]	validation_0-rmse:1.07221	validation_1-rmse:1.02158
# [32]	validation_0-rmse:1.05925	validation_1-rmse:0.98454
# [33]	validation_0-rmse:1.04850	validation_1-rmse:0.97848
# [34]	validation_0-rmse:1.04143	validation_1-rmse:0.95851
# [35]	validation_0-rmse:1.03591	validation_1-rmse:0.94335
# [36]	validation_0-rmse:1.03451	validation_1-rmse:0.95039
# [37]	validation_0-rmse:1.02808	validation_1-rmse:0.95315
# [38]	validation_0-rmse:1.02342	validation_1-rmse:0.95271
# [39]	validation_0-rmse:1.01420	validation_1-rmse:0.92930
# [40]	validation_0-rmse:1.01085	validation_1-rmse:0.91321
# [41]	validation_0-rmse:1.00972	validation_1-rmse:0.91762
# [42]	validation_0-rmse:1.00621	validation_1-rmse:0.90266
# [43]	validation_0-rmse:1.00767	validation_1-rmse:0.90612
# [44]	validation_0-rmse:1.00702	validation_1-rmse:0.91615
# [45]	validation_0-rmse:1.00558	validation_1-rmse:0.89347
# [46]	validation_0-rmse:1.00729	validation_1-rmse:0.90072
# [47]	validation_0-rmse:1.00628	validation_1-rmse:0.90614
# [48]	validation_0-rmse:1.00365	validation_1-rmse:0.89191
# [49]	validation_0-rmse:1.00175	validation_1-rmse:0.87476
# [50]	validation_0-rmse:1.00262	validation_1-rmse:0.86813
# [51]	validation_0-rmse:0.99716	validation_1-rmse:0.88502
# [0]	validation_0-rmse:6.22354	validation_1-rmse:5.47924
# [1]	validation_0-rmse:5.59347	validation_1-rmse:4.86128
# [2]	validation_0-rmse:5.03779	validation_1-rmse:4.32020
# [3]	validation_0-rmse:4.58194	validation_1-rmse:3.89344
# [4]	validation_0-rmse:4.14513	validation_1-rmse:3.46956
# [5]	validation_0-rmse:3.76770	validation_1-rmse:3.13159
# [6]	validation_0-rmse:3.47445	validation_1-rmse:2.85903
# [7]	validation_0-rmse:3.17399	validation_1-rmse:2.59788
# [8]	validation_0-rmse:2.91019	validation_1-rmse:2.38224
# [9]	validation_0-rmse:2.65008	validation_1-rmse:2.16383
# [10]	validation_0-rmse:2.45623	validation_1-rmse:2.00866
# [11]	validation_0-rmse:2.28708	validation_1-rmse:1.86614
# [12]	validation_0-rmse:2.10034	validation_1-rmse:1.72105
# [13]	validation_0-rmse:1.94015	validation_1-rmse:1.59902
# [14]	validation_0-rmse:1.78855	validation_1-rmse:1.49293
# [15]	validation_0-rmse:1.68796	validation_1-rmse:1.42713
# [16]	validation_0-rmse:1.59105	validation_1-rmse:1.35803
# [17]	validation_0-rmse:1.49574	validation_1-rmse:1.29802
# [18]	validation_0-rmse:1.42602	validation_1-rmse:1.24940
# [19]	validation_0-rmse:1.35595	validation_1-rmse:1.20726
# [20]	validation_0-rmse:1.30232	validation_1-rmse:1.17328
# [21]	validation_0-rmse:1.27406	validation_1-rmse:1.15893
# [22]	validation_0-rmse:1.21310	validation_1-rmse:1.13930
# [23]	validation_0-rmse:1.19440	validation_1-rmse:1.12668
# [24]	validation_0-rmse:1.15896	validation_1-rmse:1.12661
# [25]	validation_0-rmse:1.12609	validation_1-rmse:1.12512
# [26]	validation_0-rmse:1.10718	validation_1-rmse:1.11063
# [27]	validation_0-rmse:1.08314	validation_1-rmse:1.10188
# [28]	validation_0-rmse:1.06808	validation_1-rmse:1.09393
# [29]	validation_0-rmse:1.05266	validation_1-rmse:1.08623
# [30]	validation_0-rmse:1.04148	validation_1-rmse:1.09160
# [31]	validation_0-rmse:1.03551	validation_1-rmse:1.10109
# [32]	validation_0-rmse:1.02804	validation_1-rmse:1.10683
# [33]	validation_0-rmse:1.01895	validation_1-rmse:1.11447
# [34]	validation_0-rmse:1.01354	validation_1-rmse:1.11376
# [35]	validation_0-rmse:1.00954	validation_1-rmse:1.12662
# [36]	validation_0-rmse:1.00365	validation_1-rmse:1.12029
# [37]	validation_0-rmse:1.00627	validation_1-rmse:1.11488
# [38]	validation_0-rmse:0.99241	validation_1-rmse:1.12679
# [39]	validation_0-rmse:0.98351	validation_1-rmse:1.11834
# [0]	validation_0-rmse:6.13553	validation_1-rmse:6.02665
# [1]	validation_0-rmse:5.51305	validation_1-rmse:5.41622
# [2]	validation_0-rmse:4.95891	validation_1-rmse:4.84608
# [3]	validation_0-rmse:4.53704	validation_1-rmse:4.43037
# [4]	validation_0-rmse:4.14127	validation_1-rmse:4.04641
# [5]	validation_0-rmse:3.76992	validation_1-rmse:3.65948
# [6]	validation_0-rmse:3.41360	validation_1-rmse:3.31271
# [7]	validation_0-rmse:3.12355	validation_1-rmse:3.02597
# [8]	validation_0-rmse:2.85672	validation_1-rmse:2.77762
# [9]	validation_0-rmse:2.61404	validation_1-rmse:2.52702
# [10]	validation_0-rmse:2.43343	validation_1-rmse:2.36509
# [11]	validation_0-rmse:2.32894	validation_1-rmse:2.30803
# [12]	validation_0-rmse:2.13971	validation_1-rmse:2.12023
# [13]	validation_0-rmse:1.99755	validation_1-rmse:2.00749
# [14]	validation_0-rmse:1.86420	validation_1-rmse:1.90426
# [15]	validation_0-rmse:1.75058	validation_1-rmse:1.78693
# [16]	validation_0-rmse:1.63796	validation_1-rmse:1.68516
# [17]	validation_0-rmse:1.55051	validation_1-rmse:1.61282
# [18]	validation_0-rmse:1.47433	validation_1-rmse:1.56133
# [19]	validation_0-rmse:1.39545	validation_1-rmse:1.48435
# [20]	validation_0-rmse:1.32953	validation_1-rmse:1.43273
# [21]	validation_0-rmse:1.27650	validation_1-rmse:1.40174
# [22]	validation_0-rmse:1.22427	validation_1-rmse:1.35991
# [23]	validation_0-rmse:1.17658	validation_1-rmse:1.33559
# [24]	validation_0-rmse:1.14823	validation_1-rmse:1.31004
# [25]	validation_0-rmse:1.10217	validation_1-rmse:1.30799
# [26]	validation_0-rmse:1.07151	validation_1-rmse:1.30517
# [27]	validation_0-rmse:1.04373	validation_1-rmse:1.30145
# [28]	validation_0-rmse:1.02134	validation_1-rmse:1.28242
# [29]	validation_0-rmse:1.00005	validation_1-rmse:1.25950
# [30]	validation_0-rmse:0.99505	validation_1-rmse:1.24565
# [31]	validation_0-rmse:0.97823	validation_1-rmse:1.25083
# [32]	validation_0-rmse:0.96833	validation_1-rmse:1.26603
# [33]	validation_0-rmse:0.95439	validation_1-rmse:1.27987
# [34]	validation_0-rmse:0.93804	validation_1-rmse:1.29132
# [35]	validation_0-rmse:0.92832	validation_1-rmse:1.29312
# [36]	validation_0-rmse:0.91876	validation_1-rmse:1.28602
# [37]	validation_0-rmse:0.90337	validation_1-rmse:1.28602
# [38]	validation_0-rmse:0.89664	validation_1-rmse:1.31447
# [39]	validation_0-rmse:0.89275	validation_1-rmse:1.31389
# [40]	validation_0-rmse:0.88736	validation_1-rmse:1.34056
# [0]	validation_0-rmse:5.83248	validation_1-rmse:7.03042
# [1]	validation_0-rmse:5.22804	validation_1-rmse:6.42546
# [2]	validation_0-rmse:4.73004	validation_1-rmse:5.92598
# [3]	validation_0-rmse:4.31000	validation_1-rmse:5.41994
# [4]	validation_0-rmse:3.86395	validation_1-rmse:4.96964
# [5]	validation_0-rmse:3.47675	validation_1-rmse:4.57687
# [6]	validation_0-rmse:3.15300	validation_1-rmse:4.23509
# [7]	validation_0-rmse:2.92292	validation_1-rmse:3.98453
# [8]	validation_0-rmse:2.68607	validation_1-rmse:3.67986
# [9]	validation_0-rmse:2.43842	validation_1-rmse:3.36603
# [10]	validation_0-rmse:2.26571	validation_1-rmse:3.16228
# [11]	validation_0-rmse:2.11524	validation_1-rmse:2.98756
# [12]	validation_0-rmse:1.97311	validation_1-rmse:2.78638
# [13]	validation_0-rmse:1.85869	validation_1-rmse:2.65648
# [14]	validation_0-rmse:1.73624	validation_1-rmse:2.49322
# [15]	validation_0-rmse:1.63212	validation_1-rmse:2.37145
# [16]	validation_0-rmse:1.53396	validation_1-rmse:2.21084
# [17]	validation_0-rmse:1.47346	validation_1-rmse:2.10887
# [18]	validation_0-rmse:1.42396	validation_1-rmse:2.04006
# [19]	validation_0-rmse:1.37654	validation_1-rmse:1.95228
# [20]	validation_0-rmse:1.32767	validation_1-rmse:1.84221
# [21]	validation_0-rmse:1.26954	validation_1-rmse:1.73703
# [22]	validation_0-rmse:1.23307	validation_1-rmse:1.68822
# [23]	validation_0-rmse:1.19675	validation_1-rmse:1.59710
# [24]	validation_0-rmse:1.17538	validation_1-rmse:1.53298
# [25]	validation_0-rmse:1.15539	validation_1-rmse:1.48406
# [26]	validation_0-rmse:1.13324	validation_1-rmse:1.41810
# [27]	validation_0-rmse:1.12806	validation_1-rmse:1.43442
# [28]	validation_0-rmse:1.11437	validation_1-rmse:1.40033
# [29]	validation_0-rmse:1.09853	validation_1-rmse:1.36822
# [30]	validation_0-rmse:1.08181	validation_1-rmse:1.33069
# [31]	validation_0-rmse:1.06529	validation_1-rmse:1.27280
# [32]	validation_0-rmse:1.06729	validation_1-rmse:1.26688
# [33]	validation_0-rmse:1.06883	validation_1-rmse:1.26825
# [34]	validation_0-rmse:1.05581	validation_1-rmse:1.24521
# [35]	validation_0-rmse:1.04127	validation_1-rmse:1.20960
# [36]	validation_0-rmse:1.03542	validation_1-rmse:1.18819
# [37]	validation_0-rmse:1.03549	validation_1-rmse:1.16272
# [38]	validation_0-rmse:1.04003	validation_1-rmse:1.19554
# [39]	validation_0-rmse:1.03359	validation_1-rmse:1.16287
# [40]	validation_0-rmse:1.02816	validation_1-rmse:1.14968
# [41]	validation_0-rmse:1.02456	validation_1-rmse:1.14635
# [42]	validation_0-rmse:1.02349	validation_1-rmse:1.12481
# [43]	validation_0-rmse:1.02059	validation_1-rmse:1.11022
# [44]	validation_0-rmse:1.02784	validation_1-rmse:1.12919
# [45]	validation_0-rmse:1.02547	validation_1-rmse:1.13328
# [46]	validation_0-rmse:1.01566	validation_1-rmse:1.13665
# [47]	validation_0-rmse:1.01984	validation_1-rmse:1.13259
# [48]	validation_0-rmse:1.01262	validation_1-rmse:1.12276
# [49]	validation_0-rmse:1.00823	validation_1-rmse:1.13299
# [50]	validation_0-rmse:1.01457	validation_1-rmse:1.13920
# [51]	validation_0-rmse:1.00792	validation_1-rmse:1.14142
# [0]	validation_0-rmse:6.15210	validation_1-rmse:5.83206
# [1]	validation_0-rmse:5.51306	validation_1-rmse:5.21216
# [2]	validation_0-rmse:4.98750	validation_1-rmse:4.70665
# [3]	validation_0-rmse:4.53748	validation_1-rmse:4.26764
# [4]	validation_0-rmse:4.13135	validation_1-rmse:3.89367
# [5]	validation_0-rmse:3.74811	validation_1-rmse:3.53974
# [6]	validation_0-rmse:3.40408	validation_1-rmse:3.20615
# [7]	validation_0-rmse:3.09056	validation_1-rmse:2.91158
# [8]	validation_0-rmse:2.81322	validation_1-rmse:2.65256
# [9]	validation_0-rmse:2.56525	validation_1-rmse:2.43714
# [10]	validation_0-rmse:2.38979	validation_1-rmse:2.28312
# [11]	validation_0-rmse:2.19011	validation_1-rmse:2.10631
# [12]	validation_0-rmse:2.00790	validation_1-rmse:1.94014
# [13]	validation_0-rmse:1.86140	validation_1-rmse:1.82043
# [14]	validation_0-rmse:1.71778	validation_1-rmse:1.71179
# [15]	validation_0-rmse:1.57855	validation_1-rmse:1.60755
# [16]	validation_0-rmse:1.46223	validation_1-rmse:1.53213
# [17]	validation_0-rmse:1.38997	validation_1-rmse:1.48130
# [18]	validation_0-rmse:1.30520	validation_1-rmse:1.42859
# [19]	validation_0-rmse:1.24202	validation_1-rmse:1.37884
# [20]	validation_0-rmse:1.19005	validation_1-rmse:1.34582
# [21]	validation_0-rmse:1.15040	validation_1-rmse:1.32177
# [22]	validation_0-rmse:1.11787	validation_1-rmse:1.32351
# [23]	validation_0-rmse:1.07286	validation_1-rmse:1.30363
# [24]	validation_0-rmse:1.04593	validation_1-rmse:1.29395
# [25]	validation_0-rmse:1.03063	validation_1-rmse:1.29566
# [26]	validation_0-rmse:0.99416	validation_1-rmse:1.30483
# [27]	validation_0-rmse:0.98732	validation_1-rmse:1.30647
# [28]	validation_0-rmse:0.98353	validation_1-rmse:1.29850
# [29]	validation_0-rmse:0.97108	validation_1-rmse:1.30229
# [30]	validation_0-rmse:0.97076	validation_1-rmse:1.28916
# [31]	validation_0-rmse:0.95705	validation_1-rmse:1.29730
# [32]	validation_0-rmse:0.94247	validation_1-rmse:1.31108
# [33]	validation_0-rmse:0.93634	validation_1-rmse:1.30744
# [34]	validation_0-rmse:0.92717	validation_1-rmse:1.32312
# [35]	validation_0-rmse:0.91736	validation_1-rmse:1.33093
# [36]	validation_0-rmse:0.90902	validation_1-rmse:1.32947
# [37]	validation_0-rmse:0.89656	validation_1-rmse:1.33049
# [38]	validation_0-rmse:0.89360	validation_1-rmse:1.33539
# [39]	validation_0-rmse:0.88624	validation_1-rmse:1.33920
# [40]	validation_0-rmse:0.87952	validation_1-rmse:1.34853
# [0]	validation_0-rmse:6.16861	validation_1-rmse:5.93883
# [1]	validation_0-rmse:5.62939	validation_1-rmse:5.41052
# [2]	validation_0-rmse:5.07322	validation_1-rmse:4.85613
# [3]	validation_0-rmse:4.62443	validation_1-rmse:4.41968
# [4]	validation_0-rmse:4.21533	validation_1-rmse:4.01240
# [5]	validation_0-rmse:3.87998	validation_1-rmse:3.67913
# [6]	validation_0-rmse:3.54851	validation_1-rmse:3.36802
# [7]	validation_0-rmse:3.21941	validation_1-rmse:3.08788
# [8]	validation_0-rmse:2.90470	validation_1-rmse:2.79073
# [9]	validation_0-rmse:2.67770	validation_1-rmse:2.60152
# [10]	validation_0-rmse:2.47216	validation_1-rmse:2.40399
# [11]	validation_0-rmse:2.25285	validation_1-rmse:2.24520
# [12]	validation_0-rmse:2.05545	validation_1-rmse:2.07382
# [13]	validation_0-rmse:1.90746	validation_1-rmse:1.92265
# [14]	validation_0-rmse:1.78191	validation_1-rmse:1.82332
# [15]	validation_0-rmse:1.63552	validation_1-rmse:1.71669
# [16]	validation_0-rmse:1.54798	validation_1-rmse:1.64129
# [17]	validation_0-rmse:1.46364	validation_1-rmse:1.57615
# [18]	validation_0-rmse:1.41207	validation_1-rmse:1.53243
# [19]	validation_0-rmse:1.35766	validation_1-rmse:1.47833
# [20]	validation_0-rmse:1.29574	validation_1-rmse:1.42907
# [21]	validation_0-rmse:1.25306	validation_1-rmse:1.39662
# [22]	validation_0-rmse:1.19602	validation_1-rmse:1.33824
# [23]	validation_0-rmse:1.15853	validation_1-rmse:1.31595
# [24]	validation_0-rmse:1.12623	validation_1-rmse:1.29766
# [25]	validation_0-rmse:1.10843	validation_1-rmse:1.27853
# [26]	validation_0-rmse:1.08245	validation_1-rmse:1.26904
# [27]	validation_0-rmse:1.06020	validation_1-rmse:1.25985
# [28]	validation_0-rmse:1.03625	validation_1-rmse:1.25753
# [29]	validation_0-rmse:1.01663	validation_1-rmse:1.23547
# [30]	validation_0-rmse:1.00490	validation_1-rmse:1.23003
# [31]	validation_0-rmse:0.99191	validation_1-rmse:1.21986
# [32]	validation_0-rmse:0.98812	validation_1-rmse:1.21852
# [33]	validation_0-rmse:0.98146	validation_1-rmse:1.21413
# [34]	validation_0-rmse:0.97574	validation_1-rmse:1.21390
# [35]	validation_0-rmse:0.97081	validation_1-rmse:1.21490
# [36]	validation_0-rmse:0.96169	validation_1-rmse:1.20708
# [37]	validation_0-rmse:0.95720	validation_1-rmse:1.19450
# [38]	validation_0-rmse:0.95758	validation_1-rmse:1.22363
# [39]	validation_0-rmse:0.95085	validation_1-rmse:1.21821
# [40]	validation_0-rmse:0.95265	validation_1-rmse:1.21420
# [41]	validation_0-rmse:0.95307	validation_1-rmse:1.23941
# [42]	validation_0-rmse:0.94679	validation_1-rmse:1.22954
# [43]	validation_0-rmse:0.94303	validation_1-rmse:1.22705
# [44]	validation_0-rmse:0.94323	validation_1-rmse:1.23423
# [45]	validation_0-rmse:0.93271	validation_1-rmse:1.21201
# [46]	validation_0-rmse:0.93438	validation_1-rmse:1.21913
# [0]	validation_0-rmse:6.03355	validation_1-rmse:6.34832
# [1]	validation_0-rmse:5.46567	validation_1-rmse:5.78427
# [2]	validation_0-rmse:4.95330	validation_1-rmse:5.30075
# [3]	validation_0-rmse:4.45781	validation_1-rmse:4.79106
# [4]	validation_0-rmse:4.02764	validation_1-rmse:4.36480
# [5]	validation_0-rmse:3.69300	validation_1-rmse:4.02038
# [6]	validation_0-rmse:3.34147	validation_1-rmse:3.70007
# [7]	validation_0-rmse:3.02957	validation_1-rmse:3.39104
# [8]	validation_0-rmse:2.77459	validation_1-rmse:3.11948
# [9]	validation_0-rmse:2.57351	validation_1-rmse:2.92029
# [10]	validation_0-rmse:2.34069	validation_1-rmse:2.68577
# [11]	validation_0-rmse:2.17448	validation_1-rmse:2.55662
# [12]	validation_0-rmse:2.01199	validation_1-rmse:2.40745
# [13]	validation_0-rmse:1.85996	validation_1-rmse:2.25364
# [14]	validation_0-rmse:1.73256	validation_1-rmse:2.12528
# [15]	validation_0-rmse:1.64644	validation_1-rmse:2.04165
# [16]	validation_0-rmse:1.55697	validation_1-rmse:1.95233
# [17]	validation_0-rmse:1.45257	validation_1-rmse:1.84848
# [18]	validation_0-rmse:1.40800	validation_1-rmse:1.81214
# [19]	validation_0-rmse:1.34129	validation_1-rmse:1.73976
# [20]	validation_0-rmse:1.28644	validation_1-rmse:1.67963
# [21]	validation_0-rmse:1.21300	validation_1-rmse:1.58654
# [22]	validation_0-rmse:1.18288	validation_1-rmse:1.55313
# [23]	validation_0-rmse:1.13560	validation_1-rmse:1.51598
# [24]	validation_0-rmse:1.09299	validation_1-rmse:1.47148
# [25]	validation_0-rmse:1.06411	validation_1-rmse:1.44235
# [26]	validation_0-rmse:1.04811	validation_1-rmse:1.41569
# [27]	validation_0-rmse:1.03219	validation_1-rmse:1.38867
# [28]	validation_0-rmse:0.98846	validation_1-rmse:1.39024
# [29]	validation_0-rmse:0.97209	validation_1-rmse:1.36893
# [30]	validation_0-rmse:0.95374	validation_1-rmse:1.35605
# [31]	validation_0-rmse:0.94513	validation_1-rmse:1.34816
# [32]	validation_0-rmse:0.93580	validation_1-rmse:1.33409
# [33]	validation_0-rmse:0.92025	validation_1-rmse:1.31852
# [34]	validation_0-rmse:0.90755	validation_1-rmse:1.30510
# [35]	validation_0-rmse:0.90422	validation_1-rmse:1.29886
# [36]	validation_0-rmse:0.89021	validation_1-rmse:1.30836
# [37]	validation_0-rmse:0.88659	validation_1-rmse:1.29521
# [38]	validation_0-rmse:0.88134	validation_1-rmse:1.30111
# [39]	validation_0-rmse:0.88073	validation_1-rmse:1.29410
# [40]	validation_0-rmse:0.88078	validation_1-rmse:1.29548
# [41]	validation_0-rmse:0.87690	validation_1-rmse:1.29335
# [42]	validation_0-rmse:0.87985	validation_1-rmse:1.29738
# [43]	validation_0-rmse:0.87879	validation_1-rmse:1.29936
# [44]	validation_0-rmse:0.87804	validation_1-rmse:1.31226
# [45]	validation_0-rmse:0.87514	validation_1-rmse:1.29901
# [46]	validation_0-rmse:0.86609	validation_1-rmse:1.29851
# [47]	validation_0-rmse:0.86071	validation_1-rmse:1.30157
# [48]	validation_0-rmse:0.85739	validation_1-rmse:1.29159
# [49]	validation_0-rmse:0.85209	validation_1-rmse:1.28567
# [50]	validation_0-rmse:0.84858	validation_1-rmse:1.28889
# [51]	validation_0-rmse:0.84295	validation_1-rmse:1.29992
# [0]	validation_0-rmse:6.10926	validation_1-rmse:6.02288
# [1]	validation_0-rmse:5.51473	validation_1-rmse:5.43955
# [2]	validation_0-rmse:4.96855	validation_1-rmse:4.94204
# [3]	validation_0-rmse:4.49119	validation_1-rmse:4.47743
# [4]	validation_0-rmse:4.04869	validation_1-rmse:4.04958
# [5]	validation_0-rmse:3.68318	validation_1-rmse:3.70535
# [6]	validation_0-rmse:3.32525	validation_1-rmse:3.38377
# [7]	validation_0-rmse:3.01160	validation_1-rmse:3.08051
# [8]	validation_0-rmse:2.77382	validation_1-rmse:2.85867
# [9]	validation_0-rmse:2.54326	validation_1-rmse:2.66978
# [10]	validation_0-rmse:2.34210	validation_1-rmse:2.49748
# [11]	validation_0-rmse:2.16130	validation_1-rmse:2.33801
# [12]	validation_0-rmse:1.99670	validation_1-rmse:2.18372
# [13]	validation_0-rmse:1.87505	validation_1-rmse:2.08501
# [14]	validation_0-rmse:1.72301	validation_1-rmse:1.95044
# [15]	validation_0-rmse:1.61953	validation_1-rmse:1.85562
# [16]	validation_0-rmse:1.50608	validation_1-rmse:1.76183
# [17]	validation_0-rmse:1.41740	validation_1-rmse:1.67982
# [18]	validation_0-rmse:1.35842	validation_1-rmse:1.63552
# [19]	validation_0-rmse:1.28841	validation_1-rmse:1.57190
# [20]	validation_0-rmse:1.22337	validation_1-rmse:1.52709
# [21]	validation_0-rmse:1.18866	validation_1-rmse:1.49318
# [22]	validation_0-rmse:1.13687	validation_1-rmse:1.44501
# [23]	validation_0-rmse:1.11127	validation_1-rmse:1.42576
# [24]	validation_0-rmse:1.09046	validation_1-rmse:1.39794
# [25]	validation_0-rmse:1.04993	validation_1-rmse:1.36191
# [26]	validation_0-rmse:1.02213	validation_1-rmse:1.33596
# [27]	validation_0-rmse:1.01044	validation_1-rmse:1.32339
# [28]	validation_0-rmse:0.99377	validation_1-rmse:1.30842
# [29]	validation_0-rmse:0.98286	validation_1-rmse:1.29389
# [30]	validation_0-rmse:0.97894	validation_1-rmse:1.28108
# [31]	validation_0-rmse:0.96632	validation_1-rmse:1.27451
# [32]	validation_0-rmse:0.95550	validation_1-rmse:1.26716
# [33]	validation_0-rmse:0.95016	validation_1-rmse:1.26791
# [34]	validation_0-rmse:0.94341	validation_1-rmse:1.26335
# [35]	validation_0-rmse:0.94229	validation_1-rmse:1.26301
# [36]	validation_0-rmse:0.93847	validation_1-rmse:1.25368
# [37]	validation_0-rmse:0.93703	validation_1-rmse:1.24920
# [38]	validation_0-rmse:0.93382	validation_1-rmse:1.25041
# [39]	validation_0-rmse:0.92770	validation_1-rmse:1.26203
# [40]	validation_0-rmse:0.92459	validation_1-rmse:1.27640
# [41]	validation_0-rmse:0.92727	validation_1-rmse:1.27839
# [42]	validation_0-rmse:0.91748	validation_1-rmse:1.25772
# [43]	validation_0-rmse:0.91499	validation_1-rmse:1.25765
# [44]	validation_0-rmse:0.91299	validation_1-rmse:1.26447
# [45]	validation_0-rmse:0.90866	validation_1-rmse:1.25453
# [46]	validation_0-rmse:0.90813	validation_1-rmse:1.25698
# [47]	validation_0-rmse:0.91167	validation_1-rmse:1.25992
# [0]	validation_0-rmse:6.05744	validation_1-rmse:6.05796
# [1]	validation_0-rmse:5.45457	validation_1-rmse:5.46161
# [2]	validation_0-rmse:4.92147	validation_1-rmse:4.93565
# [3]	validation_0-rmse:4.45368	validation_1-rmse:4.49069
# [4]	validation_0-rmse:4.03089	validation_1-rmse:4.07590
# [5]	validation_0-rmse:3.69089	validation_1-rmse:3.74369
# [6]	validation_0-rmse:3.36380	validation_1-rmse:3.43844
# [7]	validation_0-rmse:3.08731	validation_1-rmse:3.17345
# [8]	validation_0-rmse:2.81816	validation_1-rmse:2.90554
# [9]	validation_0-rmse:2.60920	validation_1-rmse:2.70399
# [10]	validation_0-rmse:2.40793	validation_1-rmse:2.53720
# [11]	validation_0-rmse:2.21345	validation_1-rmse:2.35224
# [12]	validation_0-rmse:2.04136	validation_1-rmse:2.18744
# [13]	validation_0-rmse:1.91193	validation_1-rmse:2.05939
# [14]	validation_0-rmse:1.79015	validation_1-rmse:1.93618
# [15]	validation_0-rmse:1.66335	validation_1-rmse:1.80630
# [16]	validation_0-rmse:1.57005	validation_1-rmse:1.71611
# [17]	validation_0-rmse:1.47386	validation_1-rmse:1.62345
# [18]	validation_0-rmse:1.38719	validation_1-rmse:1.52153
# [19]	validation_0-rmse:1.33061	validation_1-rmse:1.47091
# [20]	validation_0-rmse:1.27190	validation_1-rmse:1.42114
# [21]	validation_0-rmse:1.22453	validation_1-rmse:1.38257
# [22]	validation_0-rmse:1.18438	validation_1-rmse:1.35032
# [23]	validation_0-rmse:1.15133	validation_1-rmse:1.31567
# [24]	validation_0-rmse:1.11955	validation_1-rmse:1.29012
# [25]	validation_0-rmse:1.10171	validation_1-rmse:1.28069
# [26]	validation_0-rmse:1.07674	validation_1-rmse:1.25528
# [27]	validation_0-rmse:1.05195	validation_1-rmse:1.24936
# [28]	validation_0-rmse:1.02857	validation_1-rmse:1.23792
# [29]	validation_0-rmse:1.01110	validation_1-rmse:1.21949
# [30]	validation_0-rmse:0.99862	validation_1-rmse:1.20880
# [31]	validation_0-rmse:0.98620	validation_1-rmse:1.18211
# [32]	validation_0-rmse:0.97184	validation_1-rmse:1.16635
# [33]	validation_0-rmse:0.96425	validation_1-rmse:1.16311
# [34]	validation_0-rmse:0.95653	validation_1-rmse:1.18135
# [35]	validation_0-rmse:0.95715	validation_1-rmse:1.17871
# [36]	validation_0-rmse:0.95353	validation_1-rmse:1.18775
# [37]	validation_0-rmse:0.94842	validation_1-rmse:1.19793
# [38]	validation_0-rmse:0.94798	validation_1-rmse:1.20072
# [39]	validation_0-rmse:0.94554	validation_1-rmse:1.19417
# [40]	validation_0-rmse:0.94686	validation_1-rmse:1.18436
# [41]	validation_0-rmse:0.93948	validation_1-rmse:1.19710
# [42]	validation_0-rmse:0.93576	validation_1-rmse:1.19117
# [0]	validation_0-rmse:6.12530	validation_1-rmse:5.91622
# [1]	validation_0-rmse:5.53836	validation_1-rmse:5.32748
# [2]	validation_0-rmse:5.01184	validation_1-rmse:4.79681
# [3]	validation_0-rmse:4.55888	validation_1-rmse:4.35330
# [4]	validation_0-rmse:4.07966	validation_1-rmse:3.87383
# [5]	validation_0-rmse:3.78510	validation_1-rmse:3.58369
# [6]	validation_0-rmse:3.46443	validation_1-rmse:3.27734
# [7]	validation_0-rmse:3.15774	validation_1-rmse:2.98875
# [8]	validation_0-rmse:2.87778	validation_1-rmse:2.72744
# [9]	validation_0-rmse:2.62538	validation_1-rmse:2.49735
# [10]	validation_0-rmse:2.43453	validation_1-rmse:2.30888
# [11]	validation_0-rmse:2.26632	validation_1-rmse:2.15809
# [12]	validation_0-rmse:2.09073	validation_1-rmse:1.99257
# [13]	validation_0-rmse:1.93619	validation_1-rmse:1.87997
# [14]	validation_0-rmse:1.81954	validation_1-rmse:1.76404
# [15]	validation_0-rmse:1.70055	validation_1-rmse:1.66287
# [16]	validation_0-rmse:1.59612	validation_1-rmse:1.54891
# [17]	validation_0-rmse:1.50578	validation_1-rmse:1.46680
# [18]	validation_0-rmse:1.43690	validation_1-rmse:1.40697
# [19]	validation_0-rmse:1.36630	validation_1-rmse:1.35919
# [20]	validation_0-rmse:1.29187	validation_1-rmse:1.28421
# [21]	validation_0-rmse:1.25135	validation_1-rmse:1.25556
# [22]	validation_0-rmse:1.21662	validation_1-rmse:1.22740
# [23]	validation_0-rmse:1.18799	validation_1-rmse:1.20050
# [24]	validation_0-rmse:1.15975	validation_1-rmse:1.18265
# [25]	validation_0-rmse:1.13616	validation_1-rmse:1.14473
# [26]	validation_0-rmse:1.11426	validation_1-rmse:1.12156
# [27]	validation_0-rmse:1.08897	validation_1-rmse:1.10581
# [28]	validation_0-rmse:1.06931	validation_1-rmse:1.10143
# [29]	validation_0-rmse:1.05764	validation_1-rmse:1.09387
# [30]	validation_0-rmse:1.05311	validation_1-rmse:1.09787
# [31]	validation_0-rmse:1.04048	validation_1-rmse:1.07875
# [32]	validation_0-rmse:1.02396	validation_1-rmse:1.07489
# [33]	validation_0-rmse:1.01444	validation_1-rmse:1.06591
# [34]	validation_0-rmse:1.00563	validation_1-rmse:1.06404
# [35]	validation_0-rmse:0.99790	validation_1-rmse:1.07365
# [36]	validation_0-rmse:0.99390	validation_1-rmse:1.07401
# [37]	validation_0-rmse:0.99345	validation_1-rmse:1.06111
# [38]	validation_0-rmse:0.98116	validation_1-rmse:1.04157
# [39]	validation_0-rmse:0.97910	validation_1-rmse:1.04882
# [40]	validation_0-rmse:0.97162	validation_1-rmse:1.05367
# [41]	validation_0-rmse:0.96683	validation_1-rmse:1.05860
# [42]	validation_0-rmse:0.96354	validation_1-rmse:1.06051
# ...
# [22]	validation_0-rmse:1.19163	validation_1-rmse:1.38387
# [23]	validation_0-rmse:1.17421	validation_1-rmse:1.36726
# [24]	validation_0-rmse:1.14187	validation_1-rmse:1.34406
# [25]	validation_0-rmse:1.11720	validation_1-rmse:1.30738
# [26]	validation_0-rmse:1.10110	validation_1-rmse:1.31378
# [27]	validation_0-rmse:1.07709	validation_1-rmse:1.27922
# [28]	validation_0-rmse:1.05821	validation_1-rmse:1.26661
# [29]	validation_0-rmse:1.03886	validation_1-rmse:1.25664
# [30]	validation_0-rmse:1.03284	validation_1-rmse:1.26736
# [31]	validation_0-rmse:1.01317	validation_1-rmse:1.25359
# [32]	validation_0-rmse:1.00676	validation_1-rmse:1.26095
# [33]	validation_0-rmse:0.99430	validation_1-rmse:1.24996
# [34]	validation_0-rmse:0.98373	validation_1-rmse:1.24241
# [35]	validation_0-rmse:0.97281	validation_1-rmse:1.24078
# [36]	validation_0-rmse:0.95855	validation_1-rmse:1.22435
# [37]	validation_0-rmse:0.95157	validation_1-rmse:1.20793
# [38]	validation_0-rmse:0.94991	validation_1-rmse:1.21852
# [39]	validation_0-rmse:0.94335	validation_1-rmse:1.20908
# [40]	validation_0-rmse:0.93977	validation_1-rmse:1.20941
# [41]	validation_0-rmse:0.93470	validation_1-rmse:1.20087
# [42]	validation_0-rmse:0.93038	validation_1-rmse:1.20691
# [43]	validation_0-rmse:0.92624	validation_1-rmse:1.19688
# [44]	validation_0-rmse:0.92465	validation_1-rmse:1.20195
# [45]	validation_0-rmse:0.92556	validation_1-rmse:1.21600
# [46]	validation_0-rmse:0.92645	validation_1-rmse:1.22929
# [47]	validation_0-rmse:0.92397	validation_1-rmse:1.23518
# [48]	validation_0-rmse:0.92169	validation_1-rmse:1.23316
# [49]	validation_0-rmse:0.91677	validation_1-rmse:1.23355
# [50]	validation_0-rmse:0.91722	validation_1-rmse:1.23392
# [51]	validation_0-rmse:0.91343	validation_1-rmse:1.23265
# [0]	validation_0-rmse:6.09682	validation_1-rmse:5.92447
# [1]	validation_0-rmse:5.50028	validation_1-rmse:5.35618
# [2]	validation_0-rmse:4.95504	validation_1-rmse:4.81771
# [3]	validation_0-rmse:4.44751	validation_1-rmse:4.32212
# [4]	validation_0-rmse:4.00980	validation_1-rmse:3.91146
# [5]	validation_0-rmse:3.63549	validation_1-rmse:3.52998
# [6]	validation_0-rmse:3.33070	validation_1-rmse:3.21358
# [7]	validation_0-rmse:3.04288	validation_1-rmse:2.96197
# [8]	validation_0-rmse:2.78857	validation_1-rmse:2.71280
# [9]	validation_0-rmse:2.60154	validation_1-rmse:2.54704
# [10]	validation_0-rmse:2.40680	validation_1-rmse:2.33472
# [11]	validation_0-rmse:2.21225	validation_1-rmse:2.14468
# [12]	validation_0-rmse:2.04081	validation_1-rmse:1.95638
# [13]	validation_0-rmse:1.89673	validation_1-rmse:1.81427
# [14]	validation_0-rmse:1.76265	validation_1-rmse:1.68506
# [15]	validation_0-rmse:1.66230	validation_1-rmse:1.59212
# [16]	validation_0-rmse:1.58292	validation_1-rmse:1.52169
# [17]	validation_0-rmse:1.49614	validation_1-rmse:1.43879
# [18]	validation_0-rmse:1.42921	validation_1-rmse:1.36552
# [19]	validation_0-rmse:1.35389	validation_1-rmse:1.27261
# [20]	validation_0-rmse:1.29951	validation_1-rmse:1.24684
# [21]	validation_0-rmse:1.25559	validation_1-rmse:1.20836
# [22]	validation_0-rmse:1.20089	validation_1-rmse:1.14668
# [23]	validation_0-rmse:1.16432	validation_1-rmse:1.11422
# [24]	validation_0-rmse:1.14002	validation_1-rmse:1.06911
# [25]	validation_0-rmse:1.11129	validation_1-rmse:1.02288
# [26]	validation_0-rmse:1.09167	validation_1-rmse:1.01580
# [27]	validation_0-rmse:1.08019	validation_1-rmse:1.00920
# [28]	validation_0-rmse:1.07701	validation_1-rmse:1.00832
# [29]	validation_0-rmse:1.06173	validation_1-rmse:1.01642
# [30]	validation_0-rmse:1.06066	validation_1-rmse:0.99447
# [31]	validation_0-rmse:1.04083	validation_1-rmse:0.97650
# [32]	validation_0-rmse:1.02514	validation_1-rmse:0.97964
# [33]	validation_0-rmse:1.02293	validation_1-rmse:0.97975
# [34]	validation_0-rmse:1.01143	validation_1-rmse:0.99703
# [35]	validation_0-rmse:1.00920	validation_1-rmse:0.99320
# [36]	validation_0-rmse:1.00415	validation_1-rmse:1.00204
# [37]	validation_0-rmse:0.99026	validation_1-rmse:0.99266
# [38]	validation_0-rmse:0.98917	validation_1-rmse:1.00518
# [39]	validation_0-rmse:0.98973	validation_1-rmse:1.01165
# [40]	validation_0-rmse:0.98518	validation_1-rmse:1.01229
# [0]	validation_0-rmse:6.24186	validation_1-rmse:5.46729
# [1]	validation_0-rmse:5.64719	validation_1-rmse:4.91919
# [2]	validation_0-rmse:5.11579	validation_1-rmse:4.45324
# [3]	validation_0-rmse:4.61500	validation_1-rmse:3.94362
# [4]	validation_0-rmse:4.15863	validation_1-rmse:3.53690
# [5]	validation_0-rmse:3.82103	validation_1-rmse:3.26736
# [6]	validation_0-rmse:3.48535	validation_1-rmse:2.96492
# [7]	validation_0-rmse:3.19363	validation_1-rmse:2.66948
# [8]	validation_0-rmse:2.90754	validation_1-rmse:2.42661
# [9]	validation_0-rmse:2.69503	validation_1-rmse:2.22327
# [10]	validation_0-rmse:2.52428	validation_1-rmse:2.07516
# [11]	validation_0-rmse:2.30532	validation_1-rmse:1.89863
# [12]	validation_0-rmse:2.13276	validation_1-rmse:1.79327
# [13]	validation_0-rmse:1.96838	validation_1-rmse:1.66341
# [14]	validation_0-rmse:1.82675	validation_1-rmse:1.55532
# [15]	validation_0-rmse:1.70937	validation_1-rmse:1.47970
# [16]	validation_0-rmse:1.58720	validation_1-rmse:1.39619
# [17]	validation_0-rmse:1.49618	validation_1-rmse:1.32626
# [18]	validation_0-rmse:1.43335	validation_1-rmse:1.27868
# [19]	validation_0-rmse:1.34678	validation_1-rmse:1.24408
# [20]	validation_0-rmse:1.28465	validation_1-rmse:1.19509
# [21]	validation_0-rmse:1.22642	validation_1-rmse:1.17998
# [22]	validation_0-rmse:1.20275	validation_1-rmse:1.17690
# [23]	validation_0-rmse:1.17356	validation_1-rmse:1.17242
# [24]	validation_0-rmse:1.14747	validation_1-rmse:1.16276
# [25]	validation_0-rmse:1.12549	validation_1-rmse:1.19593
# [26]	validation_0-rmse:1.08925	validation_1-rmse:1.16621
# [27]	validation_0-rmse:1.08325	validation_1-rmse:1.18240
# [28]	validation_0-rmse:1.04813	validation_1-rmse:1.14403
# [29]	validation_0-rmse:1.02797	validation_1-rmse:1.15262
# [30]	validation_0-rmse:1.00596	validation_1-rmse:1.13573
# [31]	validation_0-rmse:0.99355	validation_1-rmse:1.13909
# [32]	validation_0-rmse:0.98569	validation_1-rmse:1.12918
# [33]	validation_0-rmse:0.97276	validation_1-rmse:1.12760
# [34]	validation_0-rmse:0.96670	validation_1-rmse:1.15708
# [35]	validation_0-rmse:0.95694	validation_1-rmse:1.15135
# [36]	validation_0-rmse:0.95239	validation_1-rmse:1.15697
# [37]	validation_0-rmse:0.95065	validation_1-rmse:1.17712
# [38]	validation_0-rmse:0.94567	validation_1-rmse:1.17007
# [39]	validation_0-rmse:0.94042	validation_1-rmse:1.17063
# [40]	validation_0-rmse:0.92883	validation_1-rmse:1.16730
# [41]	validation_0-rmse:0.93079	validation_1-rmse:1.17037
# [42]	validation_0-rmse:0.93010	validation_1-rmse:1.17710
# [0]	validation_0-rmse:6.11421	validation_1-rmse:5.91003
# [1]	validation_0-rmse:5.48622	validation_1-rmse:5.27826
# [2]	validation_0-rmse:4.96730	validation_1-rmse:4.73694
# [3]	validation_0-rmse:4.53109	validation_1-rmse:4.29776
# [4]	validation_0-rmse:4.10921	validation_1-rmse:3.85207
# [5]	validation_0-rmse:3.73357	validation_1-rmse:3.45707
# [6]	validation_0-rmse:3.41863	validation_1-rmse:3.19217
# [7]	validation_0-rmse:3.11539	validation_1-rmse:2.88598
# [8]	validation_0-rmse:2.88554	validation_1-rmse:2.65979
# [9]	validation_0-rmse:2.63308	validation_1-rmse:2.41229
# [10]	validation_0-rmse:2.40735	validation_1-rmse:2.22427
# [11]	validation_0-rmse:2.22427	validation_1-rmse:2.04919
# [12]	validation_0-rmse:2.06145	validation_1-rmse:1.92828
# [13]	validation_0-rmse:1.90685	validation_1-rmse:1.80149
# [14]	validation_0-rmse:1.80248	validation_1-rmse:1.76417
# [15]	validation_0-rmse:1.70449	validation_1-rmse:1.68872
# [16]	validation_0-rmse:1.59909	validation_1-rmse:1.59829
# [17]	validation_0-rmse:1.49980	validation_1-rmse:1.50753
# [18]	validation_0-rmse:1.42224	validation_1-rmse:1.46200
# [19]	validation_0-rmse:1.33970	validation_1-rmse:1.41776
# [20]	validation_0-rmse:1.28084	validation_1-rmse:1.39067
# [21]	validation_0-rmse:1.24672	validation_1-rmse:1.38168
# [22]	validation_0-rmse:1.18953	validation_1-rmse:1.33821
# [23]	validation_0-rmse:1.14496	validation_1-rmse:1.31424
# [24]	validation_0-rmse:1.10799	validation_1-rmse:1.29551
# [25]	validation_0-rmse:1.06754	validation_1-rmse:1.29355
# [26]	validation_0-rmse:1.05140	validation_1-rmse:1.30667
# [27]	validation_0-rmse:1.03749	validation_1-rmse:1.30257
# [28]	validation_0-rmse:1.01184	validation_1-rmse:1.27159
# [29]	validation_0-rmse:0.99430	validation_1-rmse:1.25915
# [30]	validation_0-rmse:0.98196	validation_1-rmse:1.25965
# [31]	validation_0-rmse:0.97551	validation_1-rmse:1.26593
# [32]	validation_0-rmse:0.96613	validation_1-rmse:1.26771
# [33]	validation_0-rmse:0.95730	validation_1-rmse:1.27218
# [34]	validation_0-rmse:0.95320	validation_1-rmse:1.27774
# [35]	validation_0-rmse:0.95304	validation_1-rmse:1.27790
# [36]	validation_0-rmse:0.94223	validation_1-rmse:1.28605
# [37]	validation_0-rmse:0.93507	validation_1-rmse:1.28421
# [38]	validation_0-rmse:0.92476	validation_1-rmse:1.29304
# [39]	validation_0-rmse:0.91913	validation_1-rmse:1.28059
# [0]	validation_0-rmse:6.10976	validation_1-rmse:5.93975
# [1]	validation_0-rmse:5.47639	validation_1-rmse:5.27462
# [2]	validation_0-rmse:4.93077	validation_1-rmse:4.71465
# [3]	validation_0-rmse:4.44229	validation_1-rmse:4.22103
# [4]	validation_0-rmse:4.02190	validation_1-rmse:3.77509
# [5]	validation_0-rmse:3.64004	validation_1-rmse:3.38478
# [6]	validation_0-rmse:3.33966	validation_1-rmse:3.08194
# [7]	validation_0-rmse:3.05814	validation_1-rmse:2.79925
# [8]	validation_0-rmse:2.80252	validation_1-rmse:2.54233
# [9]	validation_0-rmse:2.58737	validation_1-rmse:2.32064
# [10]	validation_0-rmse:2.40952	validation_1-rmse:2.14652
# [11]	validation_0-rmse:2.23781	validation_1-rmse:1.99378
# [12]	validation_0-rmse:2.05812	validation_1-rmse:1.83202
# [13]	validation_0-rmse:1.91038	validation_1-rmse:1.71327
# [14]	validation_0-rmse:1.76674	validation_1-rmse:1.58804
# [15]	validation_0-rmse:1.65817	validation_1-rmse:1.50358
# [16]	validation_0-rmse:1.56639	validation_1-rmse:1.40927
# [17]	validation_0-rmse:1.47718	validation_1-rmse:1.34909
# [18]	validation_0-rmse:1.41845	validation_1-rmse:1.30706
# [19]	validation_0-rmse:1.33484	validation_1-rmse:1.25807
# [20]	validation_0-rmse:1.28166	validation_1-rmse:1.21963
# [21]	validation_0-rmse:1.23912	validation_1-rmse:1.19707
# [22]	validation_0-rmse:1.19633	validation_1-rmse:1.18576
# [23]	validation_0-rmse:1.15505	validation_1-rmse:1.16873
# [24]	validation_0-rmse:1.11894	validation_1-rmse:1.15628
# [25]	validation_0-rmse:1.09453	validation_1-rmse:1.14434
# [26]	validation_0-rmse:1.07225	validation_1-rmse:1.13911
# [27]	validation_0-rmse:1.05477	validation_1-rmse:1.13898
# [28]	validation_0-rmse:1.03703	validation_1-rmse:1.14668
# [29]	validation_0-rmse:1.02799	validation_1-rmse:1.14669
# [30]	validation_0-rmse:1.01059	validation_1-rmse:1.13999
# [31]	validation_0-rmse:0.99046	validation_1-rmse:1.14836
# [32]	validation_0-rmse:0.98518	validation_1-rmse:1.14956
# [33]	validation_0-rmse:0.97580	validation_1-rmse:1.15389
# [34]	validation_0-rmse:0.96360	validation_1-rmse:1.16534
# [35]	validation_0-rmse:0.95510	validation_1-rmse:1.17172
# [36]	validation_0-rmse:0.94537	validation_1-rmse:1.17569
# [37]	validation_0-rmse:0.93964	validation_1-rmse:1.18295
# [0]	validation_0-rmse:6.00301	validation_1-rmse:6.21580
# [1]	validation_0-rmse:5.42099	validation_1-rmse:5.59740
# [2]	validation_0-rmse:4.91380	validation_1-rmse:5.06990
# [3]	validation_0-rmse:4.44203	validation_1-rmse:4.55955
# [4]	validation_0-rmse:4.04000	validation_1-rmse:4.13125
# [5]	validation_0-rmse:3.63869	validation_1-rmse:3.71137
# [6]	validation_0-rmse:3.34022	validation_1-rmse:3.39531
# [7]	validation_0-rmse:3.04204	validation_1-rmse:3.08480
# [8]	validation_0-rmse:2.79436	validation_1-rmse:2.85256
# [9]	validation_0-rmse:2.56232	validation_1-rmse:2.60991
# [10]	validation_0-rmse:2.40467	validation_1-rmse:2.44095
# [11]	validation_0-rmse:2.22533	validation_1-rmse:2.26974
# [12]	validation_0-rmse:2.03680	validation_1-rmse:2.08414
# [13]	validation_0-rmse:1.87558	validation_1-rmse:1.90455
# [14]	validation_0-rmse:1.77020	validation_1-rmse:1.79841
# [15]	validation_0-rmse:1.66146	validation_1-rmse:1.68417
# [16]	validation_0-rmse:1.59456	validation_1-rmse:1.62090
# [17]	validation_0-rmse:1.50284	validation_1-rmse:1.55564
# [18]	validation_0-rmse:1.43583	validation_1-rmse:1.49320
# [19]	validation_0-rmse:1.35700	validation_1-rmse:1.44704
# [20]	validation_0-rmse:1.29276	validation_1-rmse:1.37787
# [21]	validation_0-rmse:1.23851	validation_1-rmse:1.32276
# [22]	validation_0-rmse:1.19361	validation_1-rmse:1.28937
# [23]	validation_0-rmse:1.14254	validation_1-rmse:1.23142
# [24]	validation_0-rmse:1.11880	validation_1-rmse:1.21247
# [25]	validation_0-rmse:1.09285	validation_1-rmse:1.20955
# [26]	validation_0-rmse:1.05992	validation_1-rmse:1.18763
# [27]	validation_0-rmse:1.03294	validation_1-rmse:1.16682
# [28]	validation_0-rmse:1.02391	validation_1-rmse:1.18406
# [29]	validation_0-rmse:1.01041	validation_1-rmse:1.16764
# [30]	validation_0-rmse:0.99973	validation_1-rmse:1.17542
# [31]	validation_0-rmse:0.99469	validation_1-rmse:1.15324
# [32]	validation_0-rmse:0.98052	validation_1-rmse:1.16102
# [33]	validation_0-rmse:0.96903	validation_1-rmse:1.15712
# [34]	validation_0-rmse:0.96736	validation_1-rmse:1.15937
# [35]	validation_0-rmse:0.96316	validation_1-rmse:1.14132
# [36]	validation_0-rmse:0.95729	validation_1-rmse:1.15456
# [37]	validation_0-rmse:0.96171	validation_1-rmse:1.15317
# [38]	validation_0-rmse:0.95559	validation_1-rmse:1.17479
# [39]	validation_0-rmse:0.95373	validation_1-rmse:1.18798
# [40]	validation_0-rmse:0.95171	validation_1-rmse:1.20826
# [41]	validation_0-rmse:0.94896	validation_1-rmse:1.19550
# [42]	validation_0-rmse:0.94701	validation_1-rmse:1.16915
# [43]	validation_0-rmse:0.94394	validation_1-rmse:1.16455
# [44]	validation_0-rmse:0.93653	validation_1-rmse:1.16014
# [0]	validation_0-rmse:6.05008	validation_1-rmse:6.36398
# [1]	validation_0-rmse:5.40210	validation_1-rmse:5.71727
# [2]	validation_0-rmse:4.86413	validation_1-rmse:5.15395
# [3]	validation_0-rmse:4.35888	validation_1-rmse:4.64948
# [4]	validation_0-rmse:3.98117	validation_1-rmse:4.24841
# [5]	validation_0-rmse:3.67155	validation_1-rmse:3.91384
# [6]	validation_0-rmse:3.34844	validation_1-rmse:3.56464
# [7]	validation_0-rmse:3.07384	validation_1-rmse:3.26515
# [8]	validation_0-rmse:2.79909	validation_1-rmse:2.96881
# [9]	validation_0-rmse:2.59791	validation_1-rmse:2.75583
# [10]	validation_0-rmse:2.38598	validation_1-rmse:2.54369
# [11]	validation_0-rmse:2.23848	validation_1-rmse:2.33430
# [12]	validation_0-rmse:2.06017	validation_1-rmse:2.12610
# [13]	validation_0-rmse:1.93870	validation_1-rmse:1.98046
# [14]	validation_0-rmse:1.82085	validation_1-rmse:1.81280
# [15]	validation_0-rmse:1.71683	validation_1-rmse:1.68358
# [16]	validation_0-rmse:1.59086	validation_1-rmse:1.53226
# [17]	validation_0-rmse:1.50230	validation_1-rmse:1.42429
# [18]	validation_0-rmse:1.40908	validation_1-rmse:1.33683
# [19]	validation_0-rmse:1.34270	validation_1-rmse:1.25246
# [20]	validation_0-rmse:1.28038	validation_1-rmse:1.18806
# [21]	validation_0-rmse:1.22302	validation_1-rmse:1.11994
# [22]	validation_0-rmse:1.18200	validation_1-rmse:1.07519
# [23]	validation_0-rmse:1.14683	validation_1-rmse:1.03327
# [24]	validation_0-rmse:1.12019	validation_1-rmse:0.99580
# [25]	validation_0-rmse:1.10470	validation_1-rmse:0.95790
# [26]	validation_0-rmse:1.08744	validation_1-rmse:0.95670
# [27]	validation_0-rmse:1.06089	validation_1-rmse:0.94607
# [28]	validation_0-rmse:1.04291	validation_1-rmse:0.93544
# [29]	validation_0-rmse:1.03481	validation_1-rmse:0.92862
# [30]	validation_0-rmse:1.03125	validation_1-rmse:0.91068
# [31]	validation_0-rmse:1.02161	validation_1-rmse:0.90633
# [32]	validation_0-rmse:1.01700	validation_1-rmse:0.89687
# [33]	validation_0-rmse:1.00825	validation_1-rmse:0.89228
# [34]	validation_0-rmse:1.00717	validation_1-rmse:0.88528
# [35]	validation_0-rmse:1.00314	validation_1-rmse:0.90488
# [36]	validation_0-rmse:1.00288	validation_1-rmse:0.89572
# [37]	validation_0-rmse:1.00451	validation_1-rmse:0.90020
# [38]	validation_0-rmse:0.99918	validation_1-rmse:0.89782
# [39]	validation_0-rmse:0.99358	validation_1-rmse:0.90470
# [40]	validation_0-rmse:0.99135	validation_1-rmse:0.89856
# [41]	validation_0-rmse:0.98771	validation_1-rmse:0.90900
# [42]	validation_0-rmse:0.98858	validation_1-rmse:0.90086
# [43]	validation_0-rmse:0.98705	validation_1-rmse:0.89973

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(3.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.537
# Uncertainty
# a0: 3.21+/-0.319
# a1: 0.525+/-0.051

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: AEDR_mean: mean - 0.972, median - 0.972, CI - [0.906-1.041]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['AEDR_mean'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 38.55, median: 38.0,
#  pred. interval (P(0.025)-P(0.975)): 25.975-51.0,
#  conf. interval (p-value=0.95): 30.775-47.031
# ***
# Aggregate bias statistic:
#  mean: -0.141, median: -0.132,
#  pred. interval (P(0.025)-P(0.975)): -0.622-0.257,
#  conf. interval (p-value=0.95): -0.345-0.056
# ***
# Aggregate RMSE statistic:
#  mean: 1.139, median: 1.142, pred. interval (P(0.025)-P(0.975)): 0.868-1.398,
#  conf. interval (p-value=0.95): 1.015-1.249
# ***
# Aggregate MSE statistic:
#  mean: 1.315, median: 1.303, pred. interval (P(0.025)-P(0.975)): 0.754-1.955,
#  conf. interval (p-value=0.95): 1.032-1.562
# ***
# Aggregate R^2 statistic:
#  mean: 0.486, median: 0.519, pred. interval (P(0.025)-P(0.975)): 0.093-0.712,
#  conf. interval (p-value=0.95): 0.381-0.613
# ***
# Aggregate bias(%) statistic:
#  mean: -1.93, median: -1.917, pred. interval (P(0.025)-P(0.975)): -8.441-3.769,
#  conf. interval (p-value=0.95): -4.766-0.812
# ***
# Aggregate RMSE(%) statistic:
#  mean: 16.224, median: 16.204, pred. interval (P(0.025)-P(0.975)): 12.008-20.985,
#  conf. interval (p-value=0.95): 14.169-18.187
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -2249.834, median: -1829.365,
#  pred. interval (P(0.025)-P(0.975)): -5484.772--159.537,
#  conf. interval (p-value=0.95): -4066.941--927.468
# ***
# Aggregate RMSE statistic:
#  mean: 7435.005, median: 5721.474, pred. interval (P(0.025)-P(0.975)): 1194.57-17642.246,
#  conf. interval (p-value=0.95): 3018.222-15481.269
# ***
# Aggregate MSE statistic:
#  mean: 85207953.602, median: 32735281.039, pred. interval (P(0.025)-P(0.975)): 1426998.029-311249087.959,
#  conf. interval (p-value=0.95): 9894205.863-249893732.309
# ***
# Aggregate R^2 statistic:
#  mean: 0.41, median: 0.465, pred. interval (P(0.025)-P(0.975)): 0.072-0.833,
#  conf. interval (p-value=0.95): 0.226-0.616
# ***
# Aggregate bias(%) statistic:
#  mean: -44.535, median: -43.969, pred. interval (P(0.025)-P(0.975)): -70.818--7.411,
#  conf. interval (p-value=0.95): -61.089--28.961
# ***
# Aggregate RMSE(%) statistic:
#  mean: 147.579, median: 136.069, pred. interval (P(0.025)-P(0.975)): 63.082-273.059,
#  conf. interval (p-value=0.95): 96.092-207.805
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [4, 5, 6, 7, 8, 9, 10, 11])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 500, 1000, 5000, 10000, 20000, 50000, 1000000])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:6.06631
# [1]	validation_0-rmse:5.44579
# [2]	validation_0-rmse:4.92250
# [3]	validation_0-rmse:4.47223
# [4]	validation_0-rmse:4.10168
# [5]	validation_0-rmse:3.72056
# [6]	validation_0-rmse:3.40601
# [7]	validation_0-rmse:3.10350
# [8]	validation_0-rmse:2.83188
# [9]	validation_0-rmse:2.59746
# [10]	validation_0-rmse:2.36224
# [11]	validation_0-rmse:2.18085
# [12]	validation_0-rmse:2.03136
# [13]	validation_0-rmse:1.90287
# [14]	validation_0-rmse:1.79152
# [15]	validation_0-rmse:1.70180
# [16]	validation_0-rmse:1.59360
# [17]	validation_0-rmse:1.49603
# [18]	validation_0-rmse:1.40543
# [19]	validation_0-rmse:1.34384
# [20]	validation_0-rmse:1.30610
# [21]	validation_0-rmse:1.26485
# [22]	validation_0-rmse:1.22907
# [23]	validation_0-rmse:1.18601
# [24]	validation_0-rmse:1.16651
# [25]	validation_0-rmse:1.13760
# [26]	validation_0-rmse:1.11655
# [27]	validation_0-rmse:1.09096
# [28]	validation_0-rmse:1.08576
# [29]	validation_0-rmse:1.07717
# [30]	validation_0-rmse:1.05691
# [31]	validation_0-rmse:1.04107
# [32]	validation_0-rmse:1.03326
# [33]	validation_0-rmse:1.01779
# [34]	validation_0-rmse:1.00907
# [35]	validation_0-rmse:1.00462
# [36]	validation_0-rmse:1.00675
# [37]	validation_0-rmse:1.00080
# [38]	validation_0-rmse:0.99244
# [39]	validation_0-rmse:0.99188
# [40]	validation_0-rmse:0.98388
# [41]	validation_0-rmse:0.98297
# [42]	validation_0-rmse:0.97782
# [43]	validation_0-rmse:0.97483
# [44]	validation_0-rmse:0.97226
# [45]	validation_0-rmse:0.97051
# [46]	validation_0-rmse:0.96554
# [47]	validation_0-rmse:0.96375
# [48]	validation_0-rmse:0.96248
# [49]	validation_0-rmse:0.95972
# [50]	validation_0-rmse:0.95940
# [51]	validation_0-rmse:0.95659

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 51

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  0.14
# RMSE: 1.0
# Relative RMSE(%):  13.570
# MSE: 0.9
# R square: 66.0%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(3.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.664
# Uncertainty
# a0: 2.73+/-0.31
# a1: 0.61+/-0.04

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/07_LN_Cs_vs_AEDR_XGB_model_2024_final.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/07_LN_Cs_vs_AEDR_XGB_model_2024_final.txt")
