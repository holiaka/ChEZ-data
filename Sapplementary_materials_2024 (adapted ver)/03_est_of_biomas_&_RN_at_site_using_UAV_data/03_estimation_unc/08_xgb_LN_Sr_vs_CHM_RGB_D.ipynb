# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../03_input_data/input_CHM_&_spectral_data_site2020.xlsx'
df = pd.read_excel(site_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Cs_wood', 'ln_Sr_wood', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 
                                    'r_MIN', 'contr_b_MAX', 'contr_b_STD'])
            
# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  r_MIN  \
# 0       6.824       9.240            784     -0.731      2.576     13
# 1       8.189       9.622            818      0.585      2.915     24
# 2       8.380       9.589            818      0.779      2.882     18
# 3       8.137       9.449            833      0.517      2.724     15
# 4       7.696       9.401            717      0.224      2.826      8
#
#    contr_b_MAX  contr_b_STD
# 0  2713.600586   332.963753
# 1  1793.493042   293.868420
# 2  1761.097900   272.526176
# 3  2518.435303   299.595643
# 4  2525.819336   327.599176

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Sr_2021_kBq_m  103 non-null    int64
#  3   ln_Tag_Cs      103 non-null    float64
#  4   ln_Tag_Sr      103 non-null    float64
#  5   r_MIN          103 non-null    int64
#  6   contr_b_MAX    103 non-null    float64
#  7   contr_b_STD    103 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 6.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Cs_wood", "ln_Sr_wood"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                  ln_Cs_wood                                                 \
#                       count       mean       std     min      25%      50%
# Dominant_specias
# Alder                   4.0   7.305000  1.427622   5.886   6.6765   7.0235
# Aspen                   1.0  11.367000       NaN  11.367  11.3670  11.3670
# Birch                  23.0   7.304652  1.533182   4.533   6.3365   7.2150
# Oak                     3.0   7.430333  1.260072   6.040   6.8970   7.7540
# Pine                   71.0   6.901690  1.650166   3.526   6.3790   6.9470
# Spruce                  1.0   5.176000       NaN   5.176   5.1760   5.1760
#
#                                   ln_Sr_wood                               \
#                       75%     max      count       mean       std     min
# Dominant_specias
# Alder              7.6520   9.287        4.0   7.206000  0.650057   6.265
# Aspen             11.3670  11.367        1.0  11.090000       NaN  11.090
# Birch              8.0320  10.332       23.0   9.345478  1.626360   7.139
# Oak                8.1255   8.497        3.0   7.483667  0.815040   6.565
# Pine               7.6960  10.469       71.0   8.542592  1.359020   6.075
# Spruce             5.1760   5.176        1.0   7.783000       NaN   7.783
#
#
#                       25%      50%      75%     max
# Dominant_specias
# Alder              7.0255   7.4545   7.6350   7.650
# Aspen             11.0900  11.0900  11.0900  11.090
# Birch              8.4000   8.9910   9.9365  13.864
# Oak                7.1655   7.7660   7.9430   8.120
# Pine               7.6450   8.4720   9.3710  12.687
# Spruce             7.7830   7.7830   7.7830   7.783

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Sr_2021_kBq_m   ln_Tag_Cs   ln_Tag_Sr  \
# count   103.00000  103.000000     103.000000  103.000000  103.000000
# mean      7.04933    8.656485    1136.436893   -0.252563    2.464709
# std       1.64946    1.472424    2019.773384    1.104610    0.904675
# min       3.52600    6.075000      98.000000   -3.033000    0.391000
# 25%       6.31900    7.664000     199.500000   -0.727500    1.803000
# 50%       6.95700    8.472000     362.000000   -0.025000    2.603000
# 75%       7.91350    9.421000     966.000000    0.516500    3.159000
# max      11.36700   13.864000   10477.000000    1.652000    4.659000
#
#             r_MIN  contr_b_MAX  contr_b_STD
# count  103.000000   103.000000   103.000000
# mean    11.378641  2712.352866   349.854034
# std      9.139568   864.116297    93.673105
# min      2.000000   832.155518   109.232976
# 25%      5.000000  2123.614868   292.544440
# 50%      8.000000  2601.248047   341.904211
# 75%     15.000000  3045.944336   427.359073
# max     56.000000  6252.923340   588.661708

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_Sr_wood"
indep_variables = ['Sr_2021_kBq_m', 'r_MIN', 'contr_b_MAX', 'contr_b_STD']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Cs_wood  ln_Sr_wood  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  r_MIN  \
# 0         6.824       9.240            784     -0.731      2.576     13
# 1         8.189       9.622            818      0.585      2.915     24
# 2         8.380       9.589            818      0.779      2.882     18
# 3         8.137       9.449            833      0.517      2.724     15
# 4         7.696       9.401            717      0.224      2.826      8
# ..          ...         ...            ...        ...        ...    ...
# 98        8.071       8.434           1012      0.228      1.514      3
# 99        7.993      10.042            908      0.266      3.230     18
# 100       8.343      10.488            975      0.543      3.606     19
# 101       3.638       6.399            269     -2.811      0.805      6
# 102       4.787       6.877            292     -1.728      1.199      2
#
#      contr_b_MAX  contr_b_STD
# 0    2713.600586   332.963753
# 1    1793.493042   293.868420
# 2    1761.097900   272.526176
# 3    2518.435303   299.595643
# 4    2525.819336   327.599176
# ..           ...          ...
# 98   3402.678467   306.364115
# 99   1918.606323   259.662727
# 100  1374.815430   227.616327
# 101  2461.437988   439.953000
# 102  2530.473633   386.530917
#
# [103 rows x 8 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Sr_2021_kBq_m  r_MIN  contr_b_MAX  contr_b_STD
# 0            784     13  2713.600586   332.963753
# 1            818     24  1793.493042   293.868420
# 2            818     18  1761.097900   272.526176
# 3            833     15  2518.435303   299.595643
# 4            717      8  2525.819336   327.599176

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Sr_wood
# 0       9.240
# 1       9.622
# 2       9.589
# 3       9.449
# 4       9.401

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.7746137173177907, 0.6351506308691086, 0.4418652923698374]
#     Mean: 0.617
#     Std: 0.136
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.77744262 0.86324726 0.93249101]
#     Mean: 0.858
#     Std: 0.063
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.6212133741106308, 0.6966216334174661, 0.7720377357707303]
#     Mean: 0.697
#     Std: 0.062
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.5206490179446539                   # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.15204082630308058                  # gamma
print('Gamma: ' + str(p2))

p3 = 0.025211624383763856                # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 4            # max_depth
print('Max_depth: ' + str(p4))

p5 = 156           # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.7951821878824858                   # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.5206490179446539
# Gamma: 0.15204082630308058
# Learning_rate: 0.025211624383763856
# Max_depth: 4
# N_estimators: 156
# Subsample: 0.7951821878824858

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:8.13608	validation_1-rmse:7.88598
# [1]	validation_0-rmse:7.93801	validation_1-rmse:7.68587
# [2]	validation_0-rmse:7.74918	validation_1-rmse:7.50058
# [3]	validation_0-rmse:7.56286	validation_1-rmse:7.31217
# [4]	validation_0-rmse:7.38013	validation_1-rmse:7.13321
# [5]	validation_0-rmse:7.21007	validation_1-rmse:6.96108
# [6]	validation_0-rmse:7.03876	validation_1-rmse:6.78760
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:6.87266	validation_1-rmse:6.61929
# [8]	validation_0-rmse:6.71090	validation_1-rmse:6.46096
# [9]	validation_0-rmse:6.55294	validation_1-rmse:6.30723
# [10]	validation_0-rmse:6.39628	validation_1-rmse:6.14824
# [11]	validation_0-rmse:6.24733	validation_1-rmse:5.99698
# [12]	validation_0-rmse:6.09933	validation_1-rmse:5.85313
# [13]	validation_0-rmse:5.95640	validation_1-rmse:5.71420
# [14]	validation_0-rmse:5.81346	validation_1-rmse:5.57057
# [15]	validation_0-rmse:5.67655	validation_1-rmse:5.43917
# [16]	validation_0-rmse:5.54340	validation_1-rmse:5.30788
# [17]	validation_0-rmse:5.41384	validation_1-rmse:5.17589
# [18]	validation_0-rmse:5.28836	validation_1-rmse:5.05409
# [19]	validation_0-rmse:5.16376	validation_1-rmse:4.93325
# [20]	validation_0-rmse:5.04483	validation_1-rmse:4.81780
# [21]	validation_0-rmse:4.92714	validation_1-rmse:4.69573
# [22]	validation_0-rmse:4.80981	validation_1-rmse:4.58163
# [23]	validation_0-rmse:4.69986	validation_1-rmse:4.47073
# [24]	validation_0-rmse:4.58770	validation_1-rmse:4.36043
# [25]	validation_0-rmse:4.48345	validation_1-rmse:4.25506
# [26]	validation_0-rmse:4.38114	validation_1-rmse:4.15613
# [27]	validation_0-rmse:4.28006	validation_1-rmse:4.05248
# [28]	validation_0-rmse:4.18313	validation_1-rmse:3.95807
# [29]	validation_0-rmse:4.09014	validation_1-rmse:3.86780
# [30]	validation_0-rmse:4.00161	validation_1-rmse:3.77536
# [31]	validation_0-rmse:3.91013	validation_1-rmse:3.68740
# [32]	validation_0-rmse:3.81944	validation_1-rmse:3.59989
# [33]	validation_0-rmse:3.73066	validation_1-rmse:3.51430
# [34]	validation_0-rmse:3.64355	validation_1-rmse:3.43041
# [35]	validation_0-rmse:3.56216	validation_1-rmse:3.35045
# [36]	validation_0-rmse:3.48096	validation_1-rmse:3.27234
# [37]	validation_0-rmse:3.40313	validation_1-rmse:3.19581
# [38]	validation_0-rmse:3.32711	validation_1-rmse:3.12259
# [39]	validation_0-rmse:3.25603	validation_1-rmse:3.05088
# [40]	validation_0-rmse:3.18654	validation_1-rmse:2.98088
# [41]	validation_0-rmse:3.11368	validation_1-rmse:2.91268
# [42]	validation_0-rmse:3.04781	validation_1-rmse:2.84580
# [43]	validation_0-rmse:2.98074	validation_1-rmse:2.78058
# [44]	validation_0-rmse:2.91218	validation_1-rmse:2.71634
# [45]	validation_0-rmse:2.84646	validation_1-rmse:2.65314
# [46]	validation_0-rmse:2.78522	validation_1-rmse:2.59442
# [47]	validation_0-rmse:2.72443	validation_1-rmse:2.53871
# [48]	validation_0-rmse:2.66636	validation_1-rmse:2.48247
# [49]	validation_0-rmse:2.61356	validation_1-rmse:2.42926
# [50]	validation_0-rmse:2.55918	validation_1-rmse:2.37409
# [51]	validation_0-rmse:2.50287	validation_1-rmse:2.32663
# [52]	validation_0-rmse:2.44883	validation_1-rmse:2.27852
# [53]	validation_0-rmse:2.39807	validation_1-rmse:2.22971
# [54]	validation_0-rmse:2.34452	validation_1-rmse:2.17714
# [55]	validation_0-rmse:2.29314	validation_1-rmse:2.13168
# [56]	validation_0-rmse:2.24482	validation_1-rmse:2.08868
# [57]	validation_0-rmse:2.19770	validation_1-rmse:2.04185
# [58]	validation_0-rmse:2.15236	validation_1-rmse:1.99929
# [59]	validation_0-rmse:2.10811	validation_1-rmse:1.95500
# [60]	validation_0-rmse:2.06320	validation_1-rmse:1.91658
# [61]	validation_0-rmse:2.02240	validation_1-rmse:1.87600
# [62]	validation_0-rmse:1.97863	validation_1-rmse:1.83721
# [63]	validation_0-rmse:1.93622	validation_1-rmse:1.80069
# [64]	validation_0-rmse:1.89580	validation_1-rmse:1.76326
# [65]	validation_0-rmse:1.85942	validation_1-rmse:1.72888
# [66]	validation_0-rmse:1.82254	validation_1-rmse:1.69488
# [67]	validation_0-rmse:1.78384	validation_1-rmse:1.66229
# [68]	validation_0-rmse:1.74929	validation_1-rmse:1.62760
# [69]	validation_0-rmse:1.71307	validation_1-rmse:1.59545
# [70]	validation_0-rmse:1.67936	validation_1-rmse:1.56063
# [71]	validation_0-rmse:1.64804	validation_1-rmse:1.52668
# [72]	validation_0-rmse:1.61451	validation_1-rmse:1.49981
# [73]	validation_0-rmse:1.58226	validation_1-rmse:1.46965
# [74]	validation_0-rmse:1.55235	validation_1-rmse:1.44487
# [75]	validation_0-rmse:1.52112	validation_1-rmse:1.41912
# [76]	validation_0-rmse:1.49428	validation_1-rmse:1.39585
# [77]	validation_0-rmse:1.46726	validation_1-rmse:1.36962
# [78]	validation_0-rmse:1.44032	validation_1-rmse:1.34726
# [79]	validation_0-rmse:1.41161	validation_1-rmse:1.32414
# [80]	validation_0-rmse:1.38362	validation_1-rmse:1.30274
# [81]	validation_0-rmse:1.35840	validation_1-rmse:1.28077
# [82]	validation_0-rmse:1.33087	validation_1-rmse:1.25813
# [83]	validation_0-rmse:1.30698	validation_1-rmse:1.23669
# [84]	validation_0-rmse:1.28647	validation_1-rmse:1.21619
# [85]	validation_0-rmse:1.26714	validation_1-rmse:1.19952
# [86]	validation_0-rmse:1.24255	validation_1-rmse:1.17875
# [87]	validation_0-rmse:1.22165	validation_1-rmse:1.15841
# [88]	validation_0-rmse:1.19729	validation_1-rmse:1.14159
# [89]	validation_0-rmse:1.17607	validation_1-rmse:1.12832
# [90]	validation_0-rmse:1.15373	validation_1-rmse:1.11126
# [91]	validation_0-rmse:1.13304	validation_1-rmse:1.09502
# [92]	validation_0-rmse:1.11306	validation_1-rmse:1.08094
# [93]	validation_0-rmse:1.09646	validation_1-rmse:1.06627
# [94]	validation_0-rmse:1.07766	validation_1-rmse:1.05043
# [95]	validation_0-rmse:1.05996	validation_1-rmse:1.03394
# [96]	validation_0-rmse:1.04036	validation_1-rmse:1.02032
# [97]	validation_0-rmse:1.02261	validation_1-rmse:1.00678
# [98]	validation_0-rmse:1.00636	validation_1-rmse:0.99562
# [99]	validation_0-rmse:0.99137	validation_1-rmse:0.98457
# [100]	validation_0-rmse:0.97423	validation_1-rmse:0.97176
# [101]	validation_0-rmse:0.95771	validation_1-rmse:0.95887
# [102]	validation_0-rmse:0.94198	validation_1-rmse:0.94935
# [103]	validation_0-rmse:0.92692	validation_1-rmse:0.94110
# [104]	validation_0-rmse:0.91202	validation_1-rmse:0.93266
# [105]	validation_0-rmse:0.89954	validation_1-rmse:0.92393
# [106]	validation_0-rmse:0.88647	validation_1-rmse:0.91420
# [107]	validation_0-rmse:0.87396	validation_1-rmse:0.90366
# [108]	validation_0-rmse:0.86183	validation_1-rmse:0.89707
# [109]	validation_0-rmse:0.84894	validation_1-rmse:0.88716
# [110]	validation_0-rmse:0.83794	validation_1-rmse:0.87856
# [111]	validation_0-rmse:0.82530	validation_1-rmse:0.87179
# [112]	validation_0-rmse:0.81596	validation_1-rmse:0.86684
# [113]	validation_0-rmse:0.80299	validation_1-rmse:0.85722
# [114]	validation_0-rmse:0.79115	validation_1-rmse:0.85039
# [115]	validation_0-rmse:0.77975	validation_1-rmse:0.84317
# [116]	validation_0-rmse:0.77065	validation_1-rmse:0.83853
# [117]	validation_0-rmse:0.75930	validation_1-rmse:0.83315
# [118]	validation_0-rmse:0.74788	validation_1-rmse:0.82575
# [119]	validation_0-rmse:0.73721	validation_1-rmse:0.81799
# [120]	validation_0-rmse:0.72797	validation_1-rmse:0.81134
# [121]	validation_0-rmse:0.71876	validation_1-rmse:0.81029
# [122]	validation_0-rmse:0.71019	validation_1-rmse:0.80553
# [123]	validation_0-rmse:0.70350	validation_1-rmse:0.79938
# [124]	validation_0-rmse:0.69437	validation_1-rmse:0.79641
# [125]	validation_0-rmse:0.68558	validation_1-rmse:0.79295
# [126]	validation_0-rmse:0.67636	validation_1-rmse:0.78961
# [127]	validation_0-rmse:0.66811	validation_1-rmse:0.78722
# [128]	validation_0-rmse:0.66059	validation_1-rmse:0.78268
# [129]	validation_0-rmse:0.65499	validation_1-rmse:0.77846
# [130]	validation_0-rmse:0.64606	validation_1-rmse:0.77309
# [131]	validation_0-rmse:0.63933	validation_1-rmse:0.76991
# [132]	validation_0-rmse:0.63135	validation_1-rmse:0.76724
# [133]	validation_0-rmse:0.62455	validation_1-rmse:0.76399
# [134]	validation_0-rmse:0.61729	validation_1-rmse:0.76368
# [135]	validation_0-rmse:0.61151	validation_1-rmse:0.76174
# [136]	validation_0-rmse:0.60429	validation_1-rmse:0.75860
# [137]	validation_0-rmse:0.60030	validation_1-rmse:0.75614
# [138]	validation_0-rmse:0.59309	validation_1-rmse:0.75333
# [139]	validation_0-rmse:0.58756	validation_1-rmse:0.75011
# [140]	validation_0-rmse:0.58066	validation_1-rmse:0.74731
# [141]	validation_0-rmse:0.57487	validation_1-rmse:0.74455
# [142]	validation_0-rmse:0.56917	validation_1-rmse:0.74364
# [143]	validation_0-rmse:0.56297	validation_1-rmse:0.74064
# [144]	validation_0-rmse:0.55769	validation_1-rmse:0.73819
# [145]	validation_0-rmse:0.55246	validation_1-rmse:0.73750
# [146]	validation_0-rmse:0.54640	validation_1-rmse:0.73524
# [147]	validation_0-rmse:0.54255	validation_1-rmse:0.73381
# [148]	validation_0-rmse:0.53737	validation_1-rmse:0.73270
# [149]	validation_0-rmse:0.53146	validation_1-rmse:0.73034
# [150]	validation_0-rmse:0.52711	validation_1-rmse:0.72783
# [151]	validation_0-rmse:0.52205	validation_1-rmse:0.72592
# [152]	validation_0-rmse:0.51630	validation_1-rmse:0.72331
# [153]	validation_0-rmse:0.51083	validation_1-rmse:0.72201
# [154]	validation_0-rmse:0.50588	validation_1-rmse:0.72107
# [155]	validation_0-rmse:0.50153	validation_1-rmse:0.72051
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:8.04002	validation_1-rmse:8.27589
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:7.84923	validation_1-rmse:8.08327
# [2]	validation_0-rmse:7.66120	validation_1-rmse:7.89099
# [3]	validation_0-rmse:7.47598	validation_1-rmse:7.70385
# [4]	validation_0-rmse:7.30163	validation_1-rmse:7.52761
# [5]	validation_0-rmse:7.12652	validation_1-rmse:7.35049
# [6]	validation_0-rmse:6.95849	validation_1-rmse:7.18043
# [7]	validation_0-rmse:6.79289	validation_1-rmse:7.01274
# [8]	validation_0-rmse:6.62916	validation_1-rmse:6.84469
# [9]	validation_0-rmse:6.47263	validation_1-rmse:6.68601
# [10]	validation_0-rmse:6.32240	validation_1-rmse:6.53361
# [11]	validation_0-rmse:6.17387	validation_1-rmse:6.38282
# [12]	validation_0-rmse:6.02862	validation_1-rmse:6.23525
# [13]	validation_0-rmse:5.88587	validation_1-rmse:6.08514
# [14]	validation_0-rmse:5.74892	validation_1-rmse:5.94037
# [15]	validation_0-rmse:5.61187	validation_1-rmse:5.79911
# [16]	validation_0-rmse:5.47936	validation_1-rmse:5.66253
# [17]	validation_0-rmse:5.35089	validation_1-rmse:5.52715
# [18]	validation_0-rmse:5.22820	validation_1-rmse:5.40120
# [19]	validation_0-rmse:5.10987	validation_1-rmse:5.27864
# [20]	validation_0-rmse:4.99108	validation_1-rmse:5.15727
# [21]	validation_0-rmse:4.87918	validation_1-rmse:5.03890
# [22]	validation_0-rmse:4.76905	validation_1-rmse:4.92620
# [23]	validation_0-rmse:4.66104	validation_1-rmse:4.81172
# [24]	validation_0-rmse:4.55355	validation_1-rmse:4.70044
# [25]	validation_0-rmse:4.44926	validation_1-rmse:4.59110
# [26]	validation_0-rmse:4.34908	validation_1-rmse:4.48734
# [27]	validation_0-rmse:4.24967	validation_1-rmse:4.38092
# [28]	validation_0-rmse:4.15183	validation_1-rmse:4.27896
# [29]	validation_0-rmse:4.06176	validation_1-rmse:4.18233
# [30]	validation_0-rmse:3.97140	validation_1-rmse:4.08604
# [31]	validation_0-rmse:3.88050	validation_1-rmse:3.99074
# [32]	validation_0-rmse:3.79080	validation_1-rmse:3.89803
# [33]	validation_0-rmse:3.70628	validation_1-rmse:3.81007
# [34]	validation_0-rmse:3.62281	validation_1-rmse:3.71946
# [35]	validation_0-rmse:3.54010	validation_1-rmse:3.62940
# [36]	validation_0-rmse:3.46152	validation_1-rmse:3.54757
# [37]	validation_0-rmse:3.38253	validation_1-rmse:3.46426
# [38]	validation_0-rmse:3.30608	validation_1-rmse:3.38469
# [39]	validation_0-rmse:3.23308	validation_1-rmse:3.30538
# [40]	validation_0-rmse:3.16222	validation_1-rmse:3.22897
# [41]	validation_0-rmse:3.09053	validation_1-rmse:3.15316
# [42]	validation_0-rmse:3.02509	validation_1-rmse:3.08294
# [43]	validation_0-rmse:2.95934	validation_1-rmse:3.01272
# [44]	validation_0-rmse:2.89162	validation_1-rmse:2.94372
# [45]	validation_0-rmse:2.82762	validation_1-rmse:2.87709
# [46]	validation_0-rmse:2.77000	validation_1-rmse:2.81539
# [47]	validation_0-rmse:2.71157	validation_1-rmse:2.75402
# [48]	validation_0-rmse:2.65528	validation_1-rmse:2.69175
# [49]	validation_0-rmse:2.60003	validation_1-rmse:2.62989
# [50]	validation_0-rmse:2.54509	validation_1-rmse:2.57053
# [51]	validation_0-rmse:2.48917	validation_1-rmse:2.51312
# [52]	validation_0-rmse:2.43549	validation_1-rmse:2.46074
# [53]	validation_0-rmse:2.38445	validation_1-rmse:2.40316
# [54]	validation_0-rmse:2.33414	validation_1-rmse:2.35147
# [55]	validation_0-rmse:2.28184	validation_1-rmse:2.29676
# [56]	validation_0-rmse:2.23606	validation_1-rmse:2.25149
# [57]	validation_0-rmse:2.18956	validation_1-rmse:2.20215
# [58]	validation_0-rmse:2.14485	validation_1-rmse:2.15726
# [59]	validation_0-rmse:2.10525	validation_1-rmse:2.11316
# [60]	validation_0-rmse:2.05908	validation_1-rmse:2.06539
# [61]	validation_0-rmse:2.02180	validation_1-rmse:2.02359
# [62]	validation_0-rmse:1.97895	validation_1-rmse:1.97983
# [63]	validation_0-rmse:1.93718	validation_1-rmse:1.93707
# [64]	validation_0-rmse:1.89821	validation_1-rmse:1.89722
# [65]	validation_0-rmse:1.85795	validation_1-rmse:1.85656
# [66]	validation_0-rmse:1.82183	validation_1-rmse:1.81773
# [67]	validation_0-rmse:1.78449	validation_1-rmse:1.77980
# [68]	validation_0-rmse:1.75376	validation_1-rmse:1.74715
# [69]	validation_0-rmse:1.71655	validation_1-rmse:1.70879
# [70]	validation_0-rmse:1.68368	validation_1-rmse:1.67237
# [71]	validation_0-rmse:1.65163	validation_1-rmse:1.63948
# [72]	validation_0-rmse:1.61841	validation_1-rmse:1.60747
# [73]	validation_0-rmse:1.58584	validation_1-rmse:1.57359
# [74]	validation_0-rmse:1.55386	validation_1-rmse:1.53973
# [75]	validation_0-rmse:1.52227	validation_1-rmse:1.50582
# [76]	validation_0-rmse:1.49549	validation_1-rmse:1.47687
# [77]	validation_0-rmse:1.46858	validation_1-rmse:1.44882
# [78]	validation_0-rmse:1.43969	validation_1-rmse:1.41929
# [79]	validation_0-rmse:1.41040	validation_1-rmse:1.38930
# [80]	validation_0-rmse:1.38438	validation_1-rmse:1.36305
# [81]	validation_0-rmse:1.36299	validation_1-rmse:1.33974
# [82]	validation_0-rmse:1.33672	validation_1-rmse:1.31259
# [83]	validation_0-rmse:1.31040	validation_1-rmse:1.28535
# [84]	validation_0-rmse:1.28930	validation_1-rmse:1.26442
# [85]	validation_0-rmse:1.26887	validation_1-rmse:1.24546
# [86]	validation_0-rmse:1.24695	validation_1-rmse:1.22290
# [87]	validation_0-rmse:1.22619	validation_1-rmse:1.20085
# [88]	validation_0-rmse:1.20319	validation_1-rmse:1.18111
# [89]	validation_0-rmse:1.18331	validation_1-rmse:1.16527
# [90]	validation_0-rmse:1.16225	validation_1-rmse:1.14303
# [91]	validation_0-rmse:1.14151	validation_1-rmse:1.12301
# [92]	validation_0-rmse:1.12308	validation_1-rmse:1.10546
# [93]	validation_0-rmse:1.10449	validation_1-rmse:1.08434
# [94]	validation_0-rmse:1.08482	validation_1-rmse:1.06415
# [95]	validation_0-rmse:1.06836	validation_1-rmse:1.05056
# [96]	validation_0-rmse:1.04882	validation_1-rmse:1.03124
# [97]	validation_0-rmse:1.02959	validation_1-rmse:1.01126
# [98]	validation_0-rmse:1.01433	validation_1-rmse:0.99418
# [99]	validation_0-rmse:0.99969	validation_1-rmse:0.97886
# [100]	validation_0-rmse:0.98245	validation_1-rmse:0.96110
# [101]	validation_0-rmse:0.96571	validation_1-rmse:0.94583
# [102]	validation_0-rmse:0.95118	validation_1-rmse:0.93203
# [103]	validation_0-rmse:0.93553	validation_1-rmse:0.91723
# [104]	validation_0-rmse:0.92152	validation_1-rmse:0.90526
# [105]	validation_0-rmse:0.90764	validation_1-rmse:0.89434
# [106]	validation_0-rmse:0.89504	validation_1-rmse:0.88487
# [107]	validation_0-rmse:0.88274	validation_1-rmse:0.87462
# [108]	validation_0-rmse:0.87123	validation_1-rmse:0.86553
# [109]	validation_0-rmse:0.85995	validation_1-rmse:0.85778
# [110]	validation_0-rmse:0.84826	validation_1-rmse:0.84966
# [111]	validation_0-rmse:0.83713	validation_1-rmse:0.83947
# [112]	validation_0-rmse:0.82716	validation_1-rmse:0.82904
# [113]	validation_0-rmse:0.81375	validation_1-rmse:0.81608
# [114]	validation_0-rmse:0.80048	validation_1-rmse:0.80494
# [115]	validation_0-rmse:0.78957	validation_1-rmse:0.79446
# [116]	validation_0-rmse:0.78130	validation_1-rmse:0.78844
# [117]	validation_0-rmse:0.77041	validation_1-rmse:0.77976
# [118]	validation_0-rmse:0.75906	validation_1-rmse:0.76993
# [119]	validation_0-rmse:0.74841	validation_1-rmse:0.75986
# [120]	validation_0-rmse:0.73975	validation_1-rmse:0.75081
# [121]	validation_0-rmse:0.73213	validation_1-rmse:0.74663
# [122]	validation_0-rmse:0.72399	validation_1-rmse:0.74362
# [123]	validation_0-rmse:0.71387	validation_1-rmse:0.73736
# [124]	validation_0-rmse:0.70529	validation_1-rmse:0.73172
# [125]	validation_0-rmse:0.69723	validation_1-rmse:0.72887
# [126]	validation_0-rmse:0.68717	validation_1-rmse:0.72259
# [127]	validation_0-rmse:0.67873	validation_1-rmse:0.71664
# [128]	validation_0-rmse:0.67133	validation_1-rmse:0.71067
# [129]	validation_0-rmse:0.66415	validation_1-rmse:0.70724
# [130]	validation_0-rmse:0.65445	validation_1-rmse:0.69900
# [131]	validation_0-rmse:0.64651	validation_1-rmse:0.69508
# [132]	validation_0-rmse:0.63888	validation_1-rmse:0.69018
# [133]	validation_0-rmse:0.63187	validation_1-rmse:0.68433
# [134]	validation_0-rmse:0.62530	validation_1-rmse:0.68164
# [135]	validation_0-rmse:0.61936	validation_1-rmse:0.67789
# [136]	validation_0-rmse:0.61378	validation_1-rmse:0.67505
# [137]	validation_0-rmse:0.60862	validation_1-rmse:0.67229
# [138]	validation_0-rmse:0.60179	validation_1-rmse:0.66784
# [139]	validation_0-rmse:0.59422	validation_1-rmse:0.66439
# [140]	validation_0-rmse:0.58856	validation_1-rmse:0.66180
# [141]	validation_0-rmse:0.58147	validation_1-rmse:0.65864
# [142]	validation_0-rmse:0.57514	validation_1-rmse:0.65532
# [143]	validation_0-rmse:0.56924	validation_1-rmse:0.65112
# [144]	validation_0-rmse:0.56449	validation_1-rmse:0.65054
# [145]	validation_0-rmse:0.55926	validation_1-rmse:0.64761
# [146]	validation_0-rmse:0.55339	validation_1-rmse:0.64505
# [147]	validation_0-rmse:0.54896	validation_1-rmse:0.64385
# [148]	validation_0-rmse:0.54478	validation_1-rmse:0.64313
# [149]	validation_0-rmse:0.53958	validation_1-rmse:0.63998
# [150]	validation_0-rmse:0.53569	validation_1-rmse:0.63696
# [151]	validation_0-rmse:0.53211	validation_1-rmse:0.63327
# [152]	validation_0-rmse:0.52656	validation_1-rmse:0.63058
# [153]	validation_0-rmse:0.52141	validation_1-rmse:0.62890
# [154]	validation_0-rmse:0.51517	validation_1-rmse:0.62545
# [155]	validation_0-rmse:0.51183	validation_1-rmse:0.62331
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:8.14828	validation_1-rmse:7.81818
# [1]	validation_0-rmse:7.94964	validation_1-rmse:7.61823
# [2]	validation_0-rmse:7.75899	validation_1-rmse:7.41886
# [3]	validation_0-rmse:7.57443	validation_1-rmse:7.23297
# [4]	validation_0-rmse:7.39417	validation_1-rmse:7.04411
# [5]	validation_0-rmse:7.21805	validation_1-rmse:6.86663
# [6]	validation_0-rmse:7.04720	validation_1-rmse:6.69439
# [7]	validation_0-rmse:6.87902	validation_1-rmse:6.52478
# [8]	validation_0-rmse:6.71333	validation_1-rmse:6.35034
# [9]	validation_0-rmse:6.55510	validation_1-rmse:6.19174
# [10]	validation_0-rmse:6.40294	validation_1-rmse:6.03815
# [11]	validation_0-rmse:6.25479	validation_1-rmse:5.88856
# [12]	validation_0-rmse:6.10987	validation_1-rmse:5.74339
# [13]	validation_0-rmse:5.96561	validation_1-rmse:5.59871
# [14]	validation_0-rmse:5.82738	validation_1-rmse:5.46021
# [15]	validation_0-rmse:5.69077	validation_1-rmse:5.31573
# [16]	validation_0-rmse:5.55615	validation_1-rmse:5.17324
# [17]	validation_0-rmse:5.42797	validation_1-rmse:5.04358
# [18]	validation_0-rmse:5.30310	validation_1-rmse:4.91167
# [19]	validation_0-rmse:5.18196	validation_1-rmse:4.79003
# [20]	validation_0-rmse:5.06038	validation_1-rmse:4.66813
# [21]	validation_0-rmse:4.94541	validation_1-rmse:4.55167
# [22]	validation_0-rmse:4.83081	validation_1-rmse:4.43551
# [23]	validation_0-rmse:4.71977	validation_1-rmse:4.32402
# [24]	validation_0-rmse:4.60821	validation_1-rmse:4.21656
# [25]	validation_0-rmse:4.50289	validation_1-rmse:4.11090
# [26]	validation_0-rmse:4.39855	validation_1-rmse:3.99861
# [27]	validation_0-rmse:4.29520	validation_1-rmse:3.89474
# [28]	validation_0-rmse:4.19518	validation_1-rmse:3.79885
# [29]	validation_0-rmse:4.10297	validation_1-rmse:3.70652
# [30]	validation_0-rmse:4.01221	validation_1-rmse:3.61261
# [31]	validation_0-rmse:3.92129	validation_1-rmse:3.51566
# [32]	validation_0-rmse:3.83167	validation_1-rmse:3.43007
# [33]	validation_0-rmse:3.74452	validation_1-rmse:3.33604
# [34]	validation_0-rmse:3.65873	validation_1-rmse:3.24920
# [35]	validation_0-rmse:3.57802	validation_1-rmse:3.16820
# [36]	validation_0-rmse:3.49586	validation_1-rmse:3.08978
# [37]	validation_0-rmse:3.41628	validation_1-rmse:3.01363
# [38]	validation_0-rmse:3.33697	validation_1-rmse:2.93807
# [39]	validation_0-rmse:3.26321	validation_1-rmse:2.86398
# [40]	validation_0-rmse:3.19063	validation_1-rmse:2.79066
# [41]	validation_0-rmse:3.11936	validation_1-rmse:2.72049
# [42]	validation_0-rmse:3.05267	validation_1-rmse:2.64970
# [43]	validation_0-rmse:2.98853	validation_1-rmse:2.58686
# [44]	validation_0-rmse:2.92130	validation_1-rmse:2.52431
# [45]	validation_0-rmse:2.85794	validation_1-rmse:2.45794
# [46]	validation_0-rmse:2.79879	validation_1-rmse:2.40277
# [47]	validation_0-rmse:2.73689	validation_1-rmse:2.34415
# [48]	validation_0-rmse:2.67834	validation_1-rmse:2.28929
# [49]	validation_0-rmse:2.62151	validation_1-rmse:2.23263
# [50]	validation_0-rmse:2.56613	validation_1-rmse:2.17722
# [51]	validation_0-rmse:2.50957	validation_1-rmse:2.12317
# [52]	validation_0-rmse:2.45485	validation_1-rmse:2.06956
# [53]	validation_0-rmse:2.40435	validation_1-rmse:2.02172
# [54]	validation_0-rmse:2.35156	validation_1-rmse:1.96974
# [55]	validation_0-rmse:2.29980	validation_1-rmse:1.92140
# [56]	validation_0-rmse:2.25090	validation_1-rmse:1.87489
# [57]	validation_0-rmse:2.20425	validation_1-rmse:1.82688
# [58]	validation_0-rmse:2.16169	validation_1-rmse:1.78447
# [59]	validation_0-rmse:2.12089	validation_1-rmse:1.74123
# [60]	validation_0-rmse:2.07649	validation_1-rmse:1.69956
# [61]	validation_0-rmse:2.03422	validation_1-rmse:1.65837
# [62]	validation_0-rmse:1.99098	validation_1-rmse:1.61627
# [63]	validation_0-rmse:1.95047	validation_1-rmse:1.57647
# [64]	validation_0-rmse:1.90996	validation_1-rmse:1.53874
# [65]	validation_0-rmse:1.87229	validation_1-rmse:1.49897
# [66]	validation_0-rmse:1.83484	validation_1-rmse:1.46474
# [67]	validation_0-rmse:1.79771	validation_1-rmse:1.43129
# [68]	validation_0-rmse:1.76503	validation_1-rmse:1.40391
# [69]	validation_0-rmse:1.72903	validation_1-rmse:1.36846
# [70]	validation_0-rmse:1.69443	validation_1-rmse:1.34039
# [71]	validation_0-rmse:1.66251	validation_1-rmse:1.30926
# [72]	validation_0-rmse:1.62957	validation_1-rmse:1.27880
# [73]	validation_0-rmse:1.59593	validation_1-rmse:1.25005
# [74]	validation_0-rmse:1.56547	validation_1-rmse:1.22504
# [75]	validation_0-rmse:1.53728	validation_1-rmse:1.20104
# [76]	validation_0-rmse:1.51042	validation_1-rmse:1.17534
# [77]	validation_0-rmse:1.48293	validation_1-rmse:1.15447
# [78]	validation_0-rmse:1.45304	validation_1-rmse:1.12782
# [79]	validation_0-rmse:1.42502	validation_1-rmse:1.10555
# [80]	validation_0-rmse:1.39721	validation_1-rmse:1.08195
# [81]	validation_0-rmse:1.37359	validation_1-rmse:1.06023
# [82]	validation_0-rmse:1.34705	validation_1-rmse:1.03722
# [83]	validation_0-rmse:1.32072	validation_1-rmse:1.01598
# [84]	validation_0-rmse:1.29845	validation_1-rmse:0.99990
# [85]	validation_0-rmse:1.27504	validation_1-rmse:0.98123
# [86]	validation_0-rmse:1.25394	validation_1-rmse:0.96276
# [87]	validation_0-rmse:1.23123	validation_1-rmse:0.95282
# [88]	validation_0-rmse:1.20803	validation_1-rmse:0.93490
# [89]	validation_0-rmse:1.18863	validation_1-rmse:0.92270
# [90]	validation_0-rmse:1.16715	validation_1-rmse:0.90515
# [91]	validation_0-rmse:1.14708	validation_1-rmse:0.88994
# [92]	validation_0-rmse:1.12844	validation_1-rmse:0.87832
# [93]	validation_0-rmse:1.11071	validation_1-rmse:0.86770
# [94]	validation_0-rmse:1.09076	validation_1-rmse:0.85265
# [95]	validation_0-rmse:1.07465	validation_1-rmse:0.84196
# [96]	validation_0-rmse:1.05438	validation_1-rmse:0.82827
# [97]	validation_0-rmse:1.03550	validation_1-rmse:0.81186
# [98]	validation_0-rmse:1.02009	validation_1-rmse:0.80306
# [99]	validation_0-rmse:1.00546	validation_1-rmse:0.79506
# [100]	validation_0-rmse:0.99045	validation_1-rmse:0.78313
# [101]	validation_0-rmse:0.97375	validation_1-rmse:0.77299
# [102]	validation_0-rmse:0.95700	validation_1-rmse:0.76332
# [103]	validation_0-rmse:0.94219	validation_1-rmse:0.75397
# [104]	validation_0-rmse:0.92787	validation_1-rmse:0.74650
# [105]	validation_0-rmse:0.91274	validation_1-rmse:0.73722
# [106]	validation_0-rmse:0.89954	validation_1-rmse:0.73172
# [107]	validation_0-rmse:0.88615	validation_1-rmse:0.72509
# [108]	validation_0-rmse:0.87365	validation_1-rmse:0.71910
# [109]	validation_0-rmse:0.86133	validation_1-rmse:0.71838
# [110]	validation_0-rmse:0.85006	validation_1-rmse:0.71761
# [111]	validation_0-rmse:0.84023	validation_1-rmse:0.71699
# [112]	validation_0-rmse:0.83161	validation_1-rmse:0.71280
# [113]	validation_0-rmse:0.81769	validation_1-rmse:0.70751
# [114]	validation_0-rmse:0.80590	validation_1-rmse:0.69997
# [115]	validation_0-rmse:0.79602	validation_1-rmse:0.69482
# [116]	validation_0-rmse:0.78748	validation_1-rmse:0.69154
# [117]	validation_0-rmse:0.77523	validation_1-rmse:0.68560
# [118]	validation_0-rmse:0.76433	validation_1-rmse:0.68060
# [119]	validation_0-rmse:0.75539	validation_1-rmse:0.67743
# [120]	validation_0-rmse:0.74535	validation_1-rmse:0.67853
# [121]	validation_0-rmse:0.73593	validation_1-rmse:0.67850
# [122]	validation_0-rmse:0.72882	validation_1-rmse:0.67985
# [123]	validation_0-rmse:0.71972	validation_1-rmse:0.67864
# [124]	validation_0-rmse:0.70939	validation_1-rmse:0.67439
# [125]	validation_0-rmse:0.69968	validation_1-rmse:0.67067
# [126]	validation_0-rmse:0.69041	validation_1-rmse:0.66709
# [127]	validation_0-rmse:0.68099	validation_1-rmse:0.66377
# [128]	validation_0-rmse:0.67116	validation_1-rmse:0.66139
# [129]	validation_0-rmse:0.66393	validation_1-rmse:0.66041
# [130]	validation_0-rmse:0.65507	validation_1-rmse:0.65826
# [131]	validation_0-rmse:0.64774	validation_1-rmse:0.65555
# [132]	validation_0-rmse:0.63938	validation_1-rmse:0.65241
# [133]	validation_0-rmse:0.63319	validation_1-rmse:0.65387
# [134]	validation_0-rmse:0.62637	validation_1-rmse:0.65270
# [135]	validation_0-rmse:0.62060	validation_1-rmse:0.65462
# [136]	validation_0-rmse:0.61183	validation_1-rmse:0.65222
# [137]	validation_0-rmse:0.60605	validation_1-rmse:0.65440
# [138]	validation_0-rmse:0.59928	validation_1-rmse:0.65326
# [139]	validation_0-rmse:0.59196	validation_1-rmse:0.65171
# [140]	validation_0-rmse:0.58626	validation_1-rmse:0.65072
# [141]	validation_0-rmse:0.57895	validation_1-rmse:0.65021
# [142]	validation_0-rmse:0.57400	validation_1-rmse:0.64930
# [143]	validation_0-rmse:0.56688	validation_1-rmse:0.64916
# [144]	validation_0-rmse:0.56231	validation_1-rmse:0.65068
# [145]	validation_0-rmse:0.55682	validation_1-rmse:0.65083
# [146]	validation_0-rmse:0.55196	validation_1-rmse:0.65082
# [147]	validation_0-rmse:0.54800	validation_1-rmse:0.65278
# [148]	validation_0-rmse:0.54366	validation_1-rmse:0.65687
# [149]	validation_0-rmse:0.53862	validation_1-rmse:0.65625
# [150]	validation_0-rmse:0.53374	validation_1-rmse:0.65899
# [151]	validation_0-rmse:0.52911	validation_1-rmse:0.65989
# [152]	validation_0-rmse:0.52433	validation_1-rmse:0.65912
# [153]	validation_0-rmse:0.51930	validation_1-rmse:0.65938
# [154]	validation_0-rmse:0.51429	validation_1-rmse:0.66047
# [155]	validation_0-rmse:0.51013	validation_1-rmse:0.66063
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:8.08835	validation_1-rmse:8.07887
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:7.89378	validation_1-rmse:7.88289
# [2]	validation_0-rmse:7.70386	validation_1-rmse:7.69029
# [3]	validation_0-rmse:7.52089	validation_1-rmse:7.50588
# [4]	validation_0-rmse:7.34287	validation_1-rmse:7.32521
# [5]	validation_0-rmse:7.16880	validation_1-rmse:7.14964
# [6]	validation_0-rmse:6.99682	validation_1-rmse:6.97611
# [7]	validation_0-rmse:6.83257	validation_1-rmse:6.81030
# [8]	validation_0-rmse:6.67158	validation_1-rmse:6.64677
# [9]	validation_0-rmse:6.51559	validation_1-rmse:6.48917
# [10]	validation_0-rmse:6.36575	validation_1-rmse:6.34007
# [11]	validation_0-rmse:6.21705	validation_1-rmse:6.18969
# [12]	validation_0-rmse:6.07075	validation_1-rmse:6.04166
# [13]	validation_0-rmse:5.92559	validation_1-rmse:5.89470
# [14]	validation_0-rmse:5.79003	validation_1-rmse:5.76020
# [15]	validation_0-rmse:5.65556	validation_1-rmse:5.62313
# [16]	validation_0-rmse:5.52198	validation_1-rmse:5.48684
# [17]	validation_0-rmse:5.39492	validation_1-rmse:5.35625
# [18]	validation_0-rmse:5.26868	validation_1-rmse:5.22860
# [19]	validation_0-rmse:5.14915	validation_1-rmse:5.10911
# [20]	validation_0-rmse:5.03328	validation_1-rmse:4.99368
# [21]	validation_0-rmse:4.91852	validation_1-rmse:4.87695
# [22]	validation_0-rmse:4.80423	validation_1-rmse:4.76312
# [23]	validation_0-rmse:4.69149	validation_1-rmse:4.65068
# [24]	validation_0-rmse:4.58284	validation_1-rmse:4.54490
# [25]	validation_0-rmse:4.47716	validation_1-rmse:4.43937
# [26]	validation_0-rmse:4.37598	validation_1-rmse:4.33555
# [27]	validation_0-rmse:4.27728	validation_1-rmse:4.23667
# [28]	validation_0-rmse:4.17837	validation_1-rmse:4.13507
# [29]	validation_0-rmse:4.08647	validation_1-rmse:4.04099
# [30]	validation_0-rmse:3.99481	validation_1-rmse:3.94659
# [31]	validation_0-rmse:3.90586	validation_1-rmse:3.85418
# [32]	validation_0-rmse:3.81520	validation_1-rmse:3.76652
# [33]	validation_0-rmse:3.72895	validation_1-rmse:3.68212
# [34]	validation_0-rmse:3.64709	validation_1-rmse:3.59977
# [35]	validation_0-rmse:3.56748	validation_1-rmse:3.51906
# [36]	validation_0-rmse:3.48750	validation_1-rmse:3.44454
# [37]	validation_0-rmse:3.40649	validation_1-rmse:3.36647
# [38]	validation_0-rmse:3.32856	validation_1-rmse:3.29370
# [39]	validation_0-rmse:3.25428	validation_1-rmse:3.21870
# [40]	validation_0-rmse:3.18379	validation_1-rmse:3.14753
# [41]	validation_0-rmse:3.11267	validation_1-rmse:3.07832
# [42]	validation_0-rmse:3.04524	validation_1-rmse:3.00736
# [43]	validation_0-rmse:2.97978	validation_1-rmse:2.94122
# [44]	validation_0-rmse:2.91526	validation_1-rmse:2.88021
# [45]	validation_0-rmse:2.85259	validation_1-rmse:2.82021
# [46]	validation_0-rmse:2.79449	validation_1-rmse:2.76127
# [47]	validation_0-rmse:2.73444	validation_1-rmse:2.69878
# [48]	validation_0-rmse:2.67707	validation_1-rmse:2.63935
# [49]	validation_0-rmse:2.62240	validation_1-rmse:2.58351
# [50]	validation_0-rmse:2.56888	validation_1-rmse:2.52855
# [51]	validation_0-rmse:2.51366	validation_1-rmse:2.47491
# [52]	validation_0-rmse:2.45880	validation_1-rmse:2.42711
# [53]	validation_0-rmse:2.41070	validation_1-rmse:2.37422
# [54]	validation_0-rmse:2.35990	validation_1-rmse:2.32536
# [55]	validation_0-rmse:2.30958	validation_1-rmse:2.27759
# [56]	validation_0-rmse:2.26114	validation_1-rmse:2.22865
# [57]	validation_0-rmse:2.21610	validation_1-rmse:2.18340
# [58]	validation_0-rmse:2.17294	validation_1-rmse:2.14221
# [59]	validation_0-rmse:2.12982	validation_1-rmse:2.09708
# [60]	validation_0-rmse:2.08705	validation_1-rmse:2.05972
# [61]	validation_0-rmse:2.04355	validation_1-rmse:2.01678
# [62]	validation_0-rmse:2.00015	validation_1-rmse:1.97498
# [63]	validation_0-rmse:1.95679	validation_1-rmse:1.93449
# [64]	validation_0-rmse:1.91704	validation_1-rmse:1.89443
# [65]	validation_0-rmse:1.87713	validation_1-rmse:1.85616
# [66]	validation_0-rmse:1.84297	validation_1-rmse:1.82231
# [67]	validation_0-rmse:1.80322	validation_1-rmse:1.78312
# [68]	validation_0-rmse:1.76958	validation_1-rmse:1.75064
# [69]	validation_0-rmse:1.73193	validation_1-rmse:1.71303
# [70]	validation_0-rmse:1.69993	validation_1-rmse:1.68077
# [71]	validation_0-rmse:1.66753	validation_1-rmse:1.65091
# [72]	validation_0-rmse:1.63308	validation_1-rmse:1.61771
# [73]	validation_0-rmse:1.60068	validation_1-rmse:1.58859
# [74]	validation_0-rmse:1.56577	validation_1-rmse:1.55406
# [75]	validation_0-rmse:1.53635	validation_1-rmse:1.52516
# [76]	validation_0-rmse:1.51090	validation_1-rmse:1.50078
# [77]	validation_0-rmse:1.48384	validation_1-rmse:1.47387
# [78]	validation_0-rmse:1.45445	validation_1-rmse:1.44696
# [79]	validation_0-rmse:1.42527	validation_1-rmse:1.42179
# [80]	validation_0-rmse:1.39767	validation_1-rmse:1.39658
# [81]	validation_0-rmse:1.37311	validation_1-rmse:1.37590
# [82]	validation_0-rmse:1.34878	validation_1-rmse:1.35201
# [83]	validation_0-rmse:1.32236	validation_1-rmse:1.33004
# [84]	validation_0-rmse:1.29979	validation_1-rmse:1.30911
# [85]	validation_0-rmse:1.27953	validation_1-rmse:1.28940
# [86]	validation_0-rmse:1.25707	validation_1-rmse:1.27021
# [87]	validation_0-rmse:1.23726	validation_1-rmse:1.25374
# [88]	validation_0-rmse:1.21413	validation_1-rmse:1.22997
# [89]	validation_0-rmse:1.19549	validation_1-rmse:1.21241
# [90]	validation_0-rmse:1.17272	validation_1-rmse:1.19626
# [91]	validation_0-rmse:1.15090	validation_1-rmse:1.17827
# [92]	validation_0-rmse:1.13143	validation_1-rmse:1.15998
# [93]	validation_0-rmse:1.11310	validation_1-rmse:1.14428
# [94]	validation_0-rmse:1.09251	validation_1-rmse:1.12884
# [95]	validation_0-rmse:1.07640	validation_1-rmse:1.11657
# [96]	validation_0-rmse:1.05652	validation_1-rmse:1.09763
# [97]	validation_0-rmse:1.03904	validation_1-rmse:1.08026
# [98]	validation_0-rmse:1.02531	validation_1-rmse:1.06703
# [99]	validation_0-rmse:1.01029	validation_1-rmse:1.05071
# [100]	validation_0-rmse:0.99245	validation_1-rmse:1.03843
# [101]	validation_0-rmse:0.97533	validation_1-rmse:1.02509
# [102]	validation_0-rmse:0.96194	validation_1-rmse:1.01616
# [103]	validation_0-rmse:0.94730	validation_1-rmse:1.00391
# [104]	validation_0-rmse:0.93376	validation_1-rmse:0.99318
# [105]	validation_0-rmse:0.91829	validation_1-rmse:0.97900
# [106]	validation_0-rmse:0.90636	validation_1-rmse:0.97208
# [107]	validation_0-rmse:0.89347	validation_1-rmse:0.95938
# [108]	validation_0-rmse:0.88099	validation_1-rmse:0.94921
# [109]	validation_0-rmse:0.86928	validation_1-rmse:0.94046
# [110]	validation_0-rmse:0.85938	validation_1-rmse:0.93013
# [111]	validation_0-rmse:0.84905	validation_1-rmse:0.92158
# [112]	validation_0-rmse:0.83659	validation_1-rmse:0.91298
# [113]	validation_0-rmse:0.82393	validation_1-rmse:0.90203
# [114]	validation_0-rmse:0.81108	validation_1-rmse:0.89318
# [115]	validation_0-rmse:0.80045	validation_1-rmse:0.88605
# [116]	validation_0-rmse:0.79131	validation_1-rmse:0.88017
# [117]	validation_0-rmse:0.77899	validation_1-rmse:0.87022
# [118]	validation_0-rmse:0.76736	validation_1-rmse:0.85770
# [119]	validation_0-rmse:0.75647	validation_1-rmse:0.84985
# [120]	validation_0-rmse:0.74639	validation_1-rmse:0.84084
# [121]	validation_0-rmse:0.73918	validation_1-rmse:0.83499
# [122]	validation_0-rmse:0.72977	validation_1-rmse:0.82536
# [123]	validation_0-rmse:0.71957	validation_1-rmse:0.81872
# [124]	validation_0-rmse:0.70984	validation_1-rmse:0.81281
# [125]	validation_0-rmse:0.69985	validation_1-rmse:0.80413
# [126]	validation_0-rmse:0.68985	validation_1-rmse:0.79924
# [127]	validation_0-rmse:0.68071	validation_1-rmse:0.79290
# [128]	validation_0-rmse:0.67231	validation_1-rmse:0.78789
# [129]	validation_0-rmse:0.66591	validation_1-rmse:0.78387
# [130]	validation_0-rmse:0.65663	validation_1-rmse:0.77711
# [131]	validation_0-rmse:0.64829	validation_1-rmse:0.77250
# [132]	validation_0-rmse:0.64008	validation_1-rmse:0.76656
# [133]	validation_0-rmse:0.63410	validation_1-rmse:0.76204
# [134]	validation_0-rmse:0.62619	validation_1-rmse:0.75680
# [135]	validation_0-rmse:0.61973	validation_1-rmse:0.75220
# [136]	validation_0-rmse:0.61264	validation_1-rmse:0.74698
# [137]	validation_0-rmse:0.60643	validation_1-rmse:0.74118
# [138]	validation_0-rmse:0.59936	validation_1-rmse:0.73918
# [139]	validation_0-rmse:0.59232	validation_1-rmse:0.73490
# [140]	validation_0-rmse:0.58514	validation_1-rmse:0.73026
# [141]	validation_0-rmse:0.57790	validation_1-rmse:0.72594
# [142]	validation_0-rmse:0.57249	validation_1-rmse:0.72363
# [143]	validation_0-rmse:0.56810	validation_1-rmse:0.72114
# [144]	validation_0-rmse:0.56259	validation_1-rmse:0.71659
# [145]	validation_0-rmse:0.55786	validation_1-rmse:0.71351
# [146]	validation_0-rmse:0.55265	validation_1-rmse:0.71108
# [147]	validation_0-rmse:0.54787	validation_1-rmse:0.70946
# [148]	validation_0-rmse:0.54473	validation_1-rmse:0.70710
# [149]	validation_0-rmse:0.53895	validation_1-rmse:0.70361
# [150]	validation_0-rmse:0.53418	validation_1-rmse:0.70168
# [151]	validation_0-rmse:0.53067	validation_1-rmse:0.69937
# [152]	validation_0-rmse:0.52539	validation_1-rmse:0.69640
# [153]	validation_0-rmse:0.51971	validation_1-rmse:0.69312
# [154]	validation_0-rmse:0.51484	validation_1-rmse:0.69155
# [155]	validation_0-rmse:0.51030	validation_1-rmse:0.69011
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:8.25802	validation_1-rmse:7.39010
# [1]	validation_0-rmse:8.06307	validation_1-rmse:7.19401
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:7.86827	validation_1-rmse:7.01334
# [3]	validation_0-rmse:7.68106	validation_1-rmse:6.82497
# [4]	validation_0-rmse:7.49615	validation_1-rmse:6.65278
# [5]	validation_0-rmse:7.31695	validation_1-rmse:6.47241
# [6]	validation_0-rmse:7.14336	validation_1-rmse:6.29764
# [7]	validation_0-rmse:6.97230	validation_1-rmse:6.12539
# [8]	validation_0-rmse:6.80407	validation_1-rmse:5.97080
# [9]	validation_0-rmse:6.64588	validation_1-rmse:5.81145
# [10]	validation_0-rmse:6.48935	validation_1-rmse:5.65374
# [11]	validation_0-rmse:6.33588	validation_1-rmse:5.49908
# [12]	validation_0-rmse:6.18866	validation_1-rmse:5.35067
# [13]	validation_0-rmse:6.04863	validation_1-rmse:5.20948
# [14]	validation_0-rmse:5.91006	validation_1-rmse:5.06974
# [15]	validation_0-rmse:5.77250	validation_1-rmse:4.94474
# [16]	validation_0-rmse:5.63828	validation_1-rmse:4.82202
# [17]	validation_0-rmse:5.50741	validation_1-rmse:4.68999
# [18]	validation_0-rmse:5.38060	validation_1-rmse:4.57542
# [19]	validation_0-rmse:5.25517	validation_1-rmse:4.45771
# [20]	validation_0-rmse:5.13366	validation_1-rmse:4.34399
# [21]	validation_0-rmse:5.01276	validation_1-rmse:4.22136
# [22]	validation_0-rmse:4.89716	validation_1-rmse:4.11731
# [23]	validation_0-rmse:4.78656	validation_1-rmse:4.01469
# [24]	validation_0-rmse:4.67634	validation_1-rmse:3.91736
# [25]	validation_0-rmse:4.57132	validation_1-rmse:3.81935
# [26]	validation_0-rmse:4.46918	validation_1-rmse:3.72714
# [27]	validation_0-rmse:4.36674	validation_1-rmse:3.63549
# [28]	validation_0-rmse:4.26522	validation_1-rmse:3.54516
# [29]	validation_0-rmse:4.16782	validation_1-rmse:3.45449
# [30]	validation_0-rmse:4.07260	validation_1-rmse:3.35792
# [31]	validation_0-rmse:3.97838	validation_1-rmse:3.27726
# [32]	validation_0-rmse:3.88849	validation_1-rmse:3.19537
# [33]	validation_0-rmse:3.79986	validation_1-rmse:3.12052
# [34]	validation_0-rmse:3.71400	validation_1-rmse:3.04832
# [35]	validation_0-rmse:3.62871	validation_1-rmse:2.96946
# [36]	validation_0-rmse:3.54756	validation_1-rmse:2.90613
# [37]	validation_0-rmse:3.46836	validation_1-rmse:2.84178
# [38]	validation_0-rmse:3.38901	validation_1-rmse:2.77792
# [39]	validation_0-rmse:3.31607	validation_1-rmse:2.71199
# [40]	validation_0-rmse:3.24115	validation_1-rmse:2.64614
# [41]	validation_0-rmse:3.16877	validation_1-rmse:2.59066
# [42]	validation_0-rmse:3.10171	validation_1-rmse:2.52433
# [43]	validation_0-rmse:3.03700	validation_1-rmse:2.46605
# [44]	validation_0-rmse:2.96748	validation_1-rmse:2.41294
# [45]	validation_0-rmse:2.90083	validation_1-rmse:2.35822
# [46]	validation_0-rmse:2.83509	validation_1-rmse:2.29848
# [47]	validation_0-rmse:2.77278	validation_1-rmse:2.25174
# [48]	validation_0-rmse:2.71402	validation_1-rmse:2.20027
# [49]	validation_0-rmse:2.65790	validation_1-rmse:2.14867
# [50]	validation_0-rmse:2.60089	validation_1-rmse:2.09792
# [51]	validation_0-rmse:2.54128	validation_1-rmse:2.04705
# [52]	validation_0-rmse:2.48374	validation_1-rmse:2.00338
# [53]	validation_0-rmse:2.43212	validation_1-rmse:1.95622
# [54]	validation_0-rmse:2.38036	validation_1-rmse:1.91253
# [55]	validation_0-rmse:2.32772	validation_1-rmse:1.87334
# [56]	validation_0-rmse:2.27732	validation_1-rmse:1.83113
# [57]	validation_0-rmse:2.23166	validation_1-rmse:1.79334
# [58]	validation_0-rmse:2.18842	validation_1-rmse:1.75285
# [59]	validation_0-rmse:2.14462	validation_1-rmse:1.70966
# [60]	validation_0-rmse:2.09916	validation_1-rmse:1.67808
# [61]	validation_0-rmse:2.05738	validation_1-rmse:1.64113
# [62]	validation_0-rmse:2.01445	validation_1-rmse:1.61050
# [63]	validation_0-rmse:1.97354	validation_1-rmse:1.58240
# [64]	validation_0-rmse:1.93168	validation_1-rmse:1.55082
# [65]	validation_0-rmse:1.89299	validation_1-rmse:1.52599
# [66]	validation_0-rmse:1.85717	validation_1-rmse:1.49298
# [67]	validation_0-rmse:1.81894	validation_1-rmse:1.46569
# [68]	validation_0-rmse:1.78549	validation_1-rmse:1.43709
# [69]	validation_0-rmse:1.74835	validation_1-rmse:1.41269
# [70]	validation_0-rmse:1.71722	validation_1-rmse:1.38694
# [71]	validation_0-rmse:1.68361	validation_1-rmse:1.35742
# [72]	validation_0-rmse:1.64860	validation_1-rmse:1.33556
# [73]	validation_0-rmse:1.61454	validation_1-rmse:1.31371
# [74]	validation_0-rmse:1.58184	validation_1-rmse:1.29286
# [75]	validation_0-rmse:1.54924	validation_1-rmse:1.27332
# [76]	validation_0-rmse:1.52089	validation_1-rmse:1.25304
# [77]	validation_0-rmse:1.49335	validation_1-rmse:1.22809
# [78]	validation_0-rmse:1.46366	validation_1-rmse:1.21218
# [79]	validation_0-rmse:1.43399	validation_1-rmse:1.19276
# [80]	validation_0-rmse:1.40453	validation_1-rmse:1.17578
# [81]	validation_0-rmse:1.38149	validation_1-rmse:1.15488
# [82]	validation_0-rmse:1.35505	validation_1-rmse:1.13833
# [83]	validation_0-rmse:1.32963	validation_1-rmse:1.12376
# [84]	validation_0-rmse:1.30733	validation_1-rmse:1.10778
# [85]	validation_0-rmse:1.28597	validation_1-rmse:1.09338
# [86]	validation_0-rmse:1.26099	validation_1-rmse:1.08197
# [87]	validation_0-rmse:1.23966	validation_1-rmse:1.06535
# [88]	validation_0-rmse:1.21933	validation_1-rmse:1.05540
# [89]	validation_0-rmse:1.19977	validation_1-rmse:1.03964
# [90]	validation_0-rmse:1.17687	validation_1-rmse:1.02554
# [91]	validation_0-rmse:1.15486	validation_1-rmse:1.01139
# [92]	validation_0-rmse:1.13390	validation_1-rmse:1.00237
# [93]	validation_0-rmse:1.11563	validation_1-rmse:0.99058
# [94]	validation_0-rmse:1.09562	validation_1-rmse:0.97879
# [95]	validation_0-rmse:1.07904	validation_1-rmse:0.96660
# [96]	validation_0-rmse:1.05997	validation_1-rmse:0.95695
# [97]	validation_0-rmse:1.04181	validation_1-rmse:0.94886
# [98]	validation_0-rmse:1.02517	validation_1-rmse:0.93717
# [99]	validation_0-rmse:1.00914	validation_1-rmse:0.92488
# [100]	validation_0-rmse:0.99044	validation_1-rmse:0.91333
# [101]	validation_0-rmse:0.97277	validation_1-rmse:0.90626
# [102]	validation_0-rmse:0.95843	validation_1-rmse:0.89909
# [103]	validation_0-rmse:0.94231	validation_1-rmse:0.89203
# [104]	validation_0-rmse:0.93019	validation_1-rmse:0.88650
# [105]	validation_0-rmse:0.91436	validation_1-rmse:0.88072
# [106]	validation_0-rmse:0.90227	validation_1-rmse:0.87323
# [107]	validation_0-rmse:0.88957	validation_1-rmse:0.86869
# [108]	validation_0-rmse:0.87603	validation_1-rmse:0.86292
# [109]	validation_0-rmse:0.86308	validation_1-rmse:0.85515
# [110]	validation_0-rmse:0.85005	validation_1-rmse:0.84791
# [111]	validation_0-rmse:0.83908	validation_1-rmse:0.84054
# [112]	validation_0-rmse:0.82801	validation_1-rmse:0.83641
# [113]	validation_0-rmse:0.81454	validation_1-rmse:0.83282
# [114]	validation_0-rmse:0.80467	validation_1-rmse:0.82531
# [115]	validation_0-rmse:0.79308	validation_1-rmse:0.82030
# [116]	validation_0-rmse:0.78274	validation_1-rmse:0.81585
# [117]	validation_0-rmse:0.77021	validation_1-rmse:0.81117
# [118]	validation_0-rmse:0.75965	validation_1-rmse:0.80491
# [119]	validation_0-rmse:0.74868	validation_1-rmse:0.80353
# [120]	validation_0-rmse:0.73861	validation_1-rmse:0.79990
# [121]	validation_0-rmse:0.73028	validation_1-rmse:0.79786
# [122]	validation_0-rmse:0.72129	validation_1-rmse:0.79523
# [123]	validation_0-rmse:0.71087	validation_1-rmse:0.79145
# [124]	validation_0-rmse:0.69948	validation_1-rmse:0.78609
# [125]	validation_0-rmse:0.68971	validation_1-rmse:0.78582
# [126]	validation_0-rmse:0.67928	validation_1-rmse:0.78184
# [127]	validation_0-rmse:0.66909	validation_1-rmse:0.77648
# [128]	validation_0-rmse:0.65905	validation_1-rmse:0.77257
# [129]	validation_0-rmse:0.65179	validation_1-rmse:0.77174
# [130]	validation_0-rmse:0.64315	validation_1-rmse:0.77079
# [131]	validation_0-rmse:0.63536	validation_1-rmse:0.76681
# [132]	validation_0-rmse:0.62669	validation_1-rmse:0.76447
# [133]	validation_0-rmse:0.61986	validation_1-rmse:0.76135
# [134]	validation_0-rmse:0.61210	validation_1-rmse:0.75820
# [135]	validation_0-rmse:0.60676	validation_1-rmse:0.75869
# [136]	validation_0-rmse:0.59799	validation_1-rmse:0.75697
# [137]	validation_0-rmse:0.59138	validation_1-rmse:0.75546
# [138]	validation_0-rmse:0.58441	validation_1-rmse:0.75419
# [139]	validation_0-rmse:0.57753	validation_1-rmse:0.75270
# [140]	validation_0-rmse:0.57043	validation_1-rmse:0.75155
# [141]	validation_0-rmse:0.56229	validation_1-rmse:0.75172
# [142]	validation_0-rmse:0.55516	validation_1-rmse:0.74967
# [143]	validation_0-rmse:0.54836	validation_1-rmse:0.74847
# [144]	validation_0-rmse:0.54377	validation_1-rmse:0.74748
# [145]	validation_0-rmse:0.53859	validation_1-rmse:0.74734
# [146]	validation_0-rmse:0.53299	validation_1-rmse:0.74642
# [147]	validation_0-rmse:0.52763	validation_1-rmse:0.74759
# [148]	validation_0-rmse:0.52285	validation_1-rmse:0.74811
# [149]	validation_0-rmse:0.51790	validation_1-rmse:0.74886
# [150]	validation_0-rmse:0.51239	validation_1-rmse:0.74819
# [151]	validation_0-rmse:0.50775	validation_1-rmse:0.74845
# [152]	validation_0-rmse:0.50205	validation_1-rmse:0.74778
# [153]	validation_0-rmse:0.49688	validation_1-rmse:0.74613
# [154]	validation_0-rmse:0.49128	validation_1-rmse:0.74364
# [155]	validation_0-rmse:0.48690	validation_1-rmse:0.74404
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:8.01518	validation_1-rmse:8.38579
# [1]	validation_0-rmse:7.82028	validation_1-rmse:8.19159
# [2]	validation_0-rmse:7.63305	validation_1-rmse:8.00505
# [3]	validation_0-rmse:7.44918	validation_1-rmse:7.82189
# [4]	validation_0-rmse:7.27177	validation_1-rmse:7.63469
# [5]	validation_0-rmse:7.09325	validation_1-rmse:7.45692
# [6]	validation_0-rmse:6.92175	validation_1-rmse:7.28616
# [7]	validation_0-rmse:6.75876	validation_1-rmse:7.12390
# [8]	validation_0-rmse:6.59598	validation_1-rmse:6.95144
# [9]	validation_0-rmse:6.44078	validation_1-rmse:6.79700
# [10]	validation_0-rmse:6.28907	validation_1-rmse:6.64606
# [11]	validation_0-rmse:6.14349	validation_1-rmse:6.50124
# [12]	validation_0-rmse:6.00009	validation_1-rmse:6.35861
# [13]	validation_0-rmse:5.85898	validation_1-rmse:6.21828
# [14]	validation_0-rmse:5.72272	validation_1-rmse:6.08280
# [15]	validation_0-rmse:5.58719	validation_1-rmse:5.93832
# [16]	validation_0-rmse:5.45476	validation_1-rmse:5.79639
# ...
# [46]	validation_0-rmse:2.71960	validation_1-rmse:3.14749
# [47]	validation_0-rmse:2.65848	validation_1-rmse:3.08055
# [48]	validation_0-rmse:2.59851	validation_1-rmse:3.01807
# [49]	validation_0-rmse:2.54412	validation_1-rmse:2.96364
# [50]	validation_0-rmse:2.48982	validation_1-rmse:2.90809
# [51]	validation_0-rmse:2.43675	validation_1-rmse:2.85491
# [52]	validation_0-rmse:2.38277	validation_1-rmse:2.79773
# [53]	validation_0-rmse:2.33243	validation_1-rmse:2.74495
# [54]	validation_0-rmse:2.28013	validation_1-rmse:2.68886
# [55]	validation_0-rmse:2.23016	validation_1-rmse:2.63566
# [56]	validation_0-rmse:2.18487	validation_1-rmse:2.59469
# [57]	validation_0-rmse:2.13952	validation_1-rmse:2.55398
# [58]	validation_0-rmse:2.09621	validation_1-rmse:2.51472
# [59]	validation_0-rmse:2.05450	validation_1-rmse:2.47501
# [60]	validation_0-rmse:2.01063	validation_1-rmse:2.42915
# [61]	validation_0-rmse:1.97280	validation_1-rmse:2.39222
# [62]	validation_0-rmse:1.93165	validation_1-rmse:2.34855
# [63]	validation_0-rmse:1.89181	validation_1-rmse:2.30550
# [64]	validation_0-rmse:1.85252	validation_1-rmse:2.26478
# [65]	validation_0-rmse:1.81256	validation_1-rmse:2.22265
# [66]	validation_0-rmse:1.77862	validation_1-rmse:2.18758
# [67]	validation_0-rmse:1.74145	validation_1-rmse:2.14917
# [68]	validation_0-rmse:1.71067	validation_1-rmse:2.11903
# [69]	validation_0-rmse:1.67548	validation_1-rmse:2.08493
# [70]	validation_0-rmse:1.64378	validation_1-rmse:2.05494
# [71]	validation_0-rmse:1.61303	validation_1-rmse:2.02706
# [72]	validation_0-rmse:1.57995	validation_1-rmse:1.99324
# [73]	validation_0-rmse:1.54752	validation_1-rmse:1.96055
# [74]	validation_0-rmse:1.51759	validation_1-rmse:1.92940
# [75]	validation_0-rmse:1.48581	validation_1-rmse:1.89297
# [76]	validation_0-rmse:1.45682	validation_1-rmse:1.86555
# [77]	validation_0-rmse:1.43015	validation_1-rmse:1.83979
# [78]	validation_0-rmse:1.40190	validation_1-rmse:1.81174
# [79]	validation_0-rmse:1.37466	validation_1-rmse:1.78331
# [80]	validation_0-rmse:1.34700	validation_1-rmse:1.75570
# [81]	validation_0-rmse:1.32345	validation_1-rmse:1.73449
# [82]	validation_0-rmse:1.29761	validation_1-rmse:1.70765
# [83]	validation_0-rmse:1.27301	validation_1-rmse:1.68305
# [84]	validation_0-rmse:1.25179	validation_1-rmse:1.66272
# [85]	validation_0-rmse:1.23061	validation_1-rmse:1.64325
# [86]	validation_0-rmse:1.20819	validation_1-rmse:1.61972
# [87]	validation_0-rmse:1.18716	validation_1-rmse:1.59971
# [88]	validation_0-rmse:1.16512	validation_1-rmse:1.57655
# [89]	validation_0-rmse:1.14618	validation_1-rmse:1.56272
# [90]	validation_0-rmse:1.12518	validation_1-rmse:1.54121
# [91]	validation_0-rmse:1.10420	validation_1-rmse:1.52185
# [92]	validation_0-rmse:1.08352	validation_1-rmse:1.50085
# [93]	validation_0-rmse:1.06585	validation_1-rmse:1.48919
# [94]	validation_0-rmse:1.04687	validation_1-rmse:1.47259
# [95]	validation_0-rmse:1.03117	validation_1-rmse:1.45919
# [96]	validation_0-rmse:1.01269	validation_1-rmse:1.44153
# [97]	validation_0-rmse:0.99496	validation_1-rmse:1.42382
# [98]	validation_0-rmse:0.98035	validation_1-rmse:1.41171
# [99]	validation_0-rmse:0.96682	validation_1-rmse:1.40155
# [100]	validation_0-rmse:0.95111	validation_1-rmse:1.38619
# [101]	validation_0-rmse:0.93533	validation_1-rmse:1.36940
# [102]	validation_0-rmse:0.92140	validation_1-rmse:1.35376
# [103]	validation_0-rmse:0.90545	validation_1-rmse:1.33829
# [104]	validation_0-rmse:0.89107	validation_1-rmse:1.32667
# [105]	validation_0-rmse:0.87627	validation_1-rmse:1.31079
# [106]	validation_0-rmse:0.86327	validation_1-rmse:1.30225
# [107]	validation_0-rmse:0.85178	validation_1-rmse:1.29243
# [108]	validation_0-rmse:0.84019	validation_1-rmse:1.28214
# [109]	validation_0-rmse:0.82813	validation_1-rmse:1.27515
# [110]	validation_0-rmse:0.81760	validation_1-rmse:1.26633
# [111]	validation_0-rmse:0.80700	validation_1-rmse:1.25774
# [112]	validation_0-rmse:0.79642	validation_1-rmse:1.24987
# [113]	validation_0-rmse:0.78352	validation_1-rmse:1.23815
# [114]	validation_0-rmse:0.77044	validation_1-rmse:1.22320
# [115]	validation_0-rmse:0.75943	validation_1-rmse:1.21246
# [116]	validation_0-rmse:0.74957	validation_1-rmse:1.20440
# [117]	validation_0-rmse:0.73862	validation_1-rmse:1.19451
# [118]	validation_0-rmse:0.72867	validation_1-rmse:1.18391
# [119]	validation_0-rmse:0.71808	validation_1-rmse:1.17341
# [120]	validation_0-rmse:0.70928	validation_1-rmse:1.16754
# [121]	validation_0-rmse:0.70144	validation_1-rmse:1.16359
# [122]	validation_0-rmse:0.69474	validation_1-rmse:1.15682
# [123]	validation_0-rmse:0.68465	validation_1-rmse:1.14726
# [124]	validation_0-rmse:0.67667	validation_1-rmse:1.14029
# [125]	validation_0-rmse:0.66717	validation_1-rmse:1.13218
# [126]	validation_0-rmse:0.65730	validation_1-rmse:1.12270
# [127]	validation_0-rmse:0.64926	validation_1-rmse:1.11591
# [128]	validation_0-rmse:0.64177	validation_1-rmse:1.10795
# [129]	validation_0-rmse:0.63467	validation_1-rmse:1.10367
# [130]	validation_0-rmse:0.62647	validation_1-rmse:1.09520
# [131]	validation_0-rmse:0.61808	validation_1-rmse:1.08801
# [132]	validation_0-rmse:0.61081	validation_1-rmse:1.08093
# [133]	validation_0-rmse:0.60498	validation_1-rmse:1.07649
# [134]	validation_0-rmse:0.59721	validation_1-rmse:1.06855
# [135]	validation_0-rmse:0.59155	validation_1-rmse:1.06526
# [136]	validation_0-rmse:0.58502	validation_1-rmse:1.06045
# [137]	validation_0-rmse:0.57912	validation_1-rmse:1.05660
# [138]	validation_0-rmse:0.57291	validation_1-rmse:1.05035
# [139]	validation_0-rmse:0.56663	validation_1-rmse:1.04321
# [140]	validation_0-rmse:0.56078	validation_1-rmse:1.03755
# [141]	validation_0-rmse:0.55447	validation_1-rmse:1.03469
# [142]	validation_0-rmse:0.54943	validation_1-rmse:1.03341
# [143]	validation_0-rmse:0.54357	validation_1-rmse:1.02817
# [144]	validation_0-rmse:0.53882	validation_1-rmse:1.02747
# [145]	validation_0-rmse:0.53602	validation_1-rmse:1.02534
# [146]	validation_0-rmse:0.52981	validation_1-rmse:1.01967
# [147]	validation_0-rmse:0.52488	validation_1-rmse:1.01795
# [148]	validation_0-rmse:0.52035	validation_1-rmse:1.01578
# [149]	validation_0-rmse:0.51466	validation_1-rmse:1.01022
# [150]	validation_0-rmse:0.50893	validation_1-rmse:1.00709
# [151]	validation_0-rmse:0.50531	validation_1-rmse:1.00500
# [152]	validation_0-rmse:0.50084	validation_1-rmse:1.00085
# [153]	validation_0-rmse:0.49617	validation_1-rmse:0.99583
# [154]	validation_0-rmse:0.49088	validation_1-rmse:0.99188
# [155]	validation_0-rmse:0.48703	validation_1-rmse:0.98950
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:8.14246	validation_1-rmse:7.87000
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:7.94906	validation_1-rmse:7.67575
# [2]	validation_0-rmse:7.75787	validation_1-rmse:7.48806
# [3]	validation_0-rmse:7.57251	validation_1-rmse:7.30181
# [4]	validation_0-rmse:7.39163	validation_1-rmse:7.12440
# [5]	validation_0-rmse:7.21314	validation_1-rmse:6.94496
# [6]	validation_0-rmse:7.04413	validation_1-rmse:6.77501
# [7]	validation_0-rmse:6.87350	validation_1-rmse:6.60339
# [8]	validation_0-rmse:6.70871	validation_1-rmse:6.44158
# [9]	validation_0-rmse:6.54990	validation_1-rmse:6.28177
# [10]	validation_0-rmse:6.39752	validation_1-rmse:6.12836
# [11]	validation_0-rmse:6.24607	validation_1-rmse:5.97587
# [12]	validation_0-rmse:6.09861	validation_1-rmse:5.82182
# [13]	validation_0-rmse:5.95459	validation_1-rmse:5.67116
# [14]	validation_0-rmse:5.81716	validation_1-rmse:5.53261
# [15]	validation_0-rmse:5.67949	validation_1-rmse:5.39745
# [16]	validation_0-rmse:5.54682	validation_1-rmse:5.26705
# [17]	validation_0-rmse:5.41647	validation_1-rmse:5.13548
# [18]	validation_0-rmse:5.29335	validation_1-rmse:5.01437
# [19]	validation_0-rmse:5.17007	validation_1-rmse:4.88984
# [20]	validation_0-rmse:5.05393	validation_1-rmse:4.76811
# [21]	validation_0-rmse:4.93982	validation_1-rmse:4.65820
# [22]	validation_0-rmse:4.82744	validation_1-rmse:4.53923
# [23]	validation_0-rmse:4.71538	validation_1-rmse:4.42083
# [24]	validation_0-rmse:4.60431	validation_1-rmse:4.31924
# [25]	validation_0-rmse:4.50340	validation_1-rmse:4.21259
# [26]	validation_0-rmse:4.40181	validation_1-rmse:4.11302
# [27]	validation_0-rmse:4.30395	validation_1-rmse:4.00924
# [28]	validation_0-rmse:4.20766	validation_1-rmse:3.91451
# [29]	validation_0-rmse:4.11288	validation_1-rmse:3.81721
# [30]	validation_0-rmse:4.01912	validation_1-rmse:3.72635
# [31]	validation_0-rmse:3.92584	validation_1-rmse:3.63696
# [32]	validation_0-rmse:3.83739	validation_1-rmse:3.55226
# [33]	validation_0-rmse:3.74937	validation_1-rmse:3.46877
# [34]	validation_0-rmse:3.67167	validation_1-rmse:3.38627
# [35]	validation_0-rmse:3.59135	validation_1-rmse:3.30083
# [36]	validation_0-rmse:3.51006	validation_1-rmse:3.22320
# [37]	validation_0-rmse:3.42937	validation_1-rmse:3.14457
# [38]	validation_0-rmse:3.35126	validation_1-rmse:3.06955
# [39]	validation_0-rmse:3.27564	validation_1-rmse:2.98824
# [40]	validation_0-rmse:3.20501	validation_1-rmse:2.92292
# [41]	validation_0-rmse:3.13230	validation_1-rmse:2.85170
# [42]	validation_0-rmse:3.06550	validation_1-rmse:2.78773
# [43]	validation_0-rmse:3.00093	validation_1-rmse:2.71868
# [44]	validation_0-rmse:2.93407	validation_1-rmse:2.65213
# [45]	validation_0-rmse:2.86806	validation_1-rmse:2.58957
# [46]	validation_0-rmse:2.80587	validation_1-rmse:2.52207
# [47]	validation_0-rmse:2.74422	validation_1-rmse:2.46371
# [48]	validation_0-rmse:2.68810	validation_1-rmse:2.40251
# [49]	validation_0-rmse:2.62917	validation_1-rmse:2.33785
# [50]	validation_0-rmse:2.57318	validation_1-rmse:2.27704
# [51]	validation_0-rmse:2.51705	validation_1-rmse:2.22333
# [52]	validation_0-rmse:2.46423	validation_1-rmse:2.17286
# [53]	validation_0-rmse:2.41179	validation_1-rmse:2.11497
# [54]	validation_0-rmse:2.36168	validation_1-rmse:2.06873
# [55]	validation_0-rmse:2.31006	validation_1-rmse:2.01901
# [56]	validation_0-rmse:2.26285	validation_1-rmse:1.96812
# [57]	validation_0-rmse:2.21953	validation_1-rmse:1.93033
# [58]	validation_0-rmse:2.17619	validation_1-rmse:1.88509
# [59]	validation_0-rmse:2.13528	validation_1-rmse:1.84842
# [60]	validation_0-rmse:2.08905	validation_1-rmse:1.80384
# [61]	validation_0-rmse:2.05065	validation_1-rmse:1.76963
# [62]	validation_0-rmse:2.00815	validation_1-rmse:1.73349
# [63]	validation_0-rmse:1.96477	validation_1-rmse:1.69225
# [64]	validation_0-rmse:1.92360	validation_1-rmse:1.65237
# [65]	validation_0-rmse:1.88119	validation_1-rmse:1.61169
# [66]	validation_0-rmse:1.84542	validation_1-rmse:1.57369
# [67]	validation_0-rmse:1.80820	validation_1-rmse:1.53664
# [68]	validation_0-rmse:1.77417	validation_1-rmse:1.49602
# [69]	validation_0-rmse:1.73754	validation_1-rmse:1.46098
# [70]	validation_0-rmse:1.70700	validation_1-rmse:1.42611
# [71]	validation_0-rmse:1.67598	validation_1-rmse:1.39625
# [72]	validation_0-rmse:1.64217	validation_1-rmse:1.36376
# [73]	validation_0-rmse:1.61034	validation_1-rmse:1.33424
# [74]	validation_0-rmse:1.57817	validation_1-rmse:1.30391
# [75]	validation_0-rmse:1.54658	validation_1-rmse:1.27445
# [76]	validation_0-rmse:1.51960	validation_1-rmse:1.24952
# [77]	validation_0-rmse:1.49345	validation_1-rmse:1.22243
# [78]	validation_0-rmse:1.46645	validation_1-rmse:1.19740
# [79]	validation_0-rmse:1.43770	validation_1-rmse:1.17251
# [80]	validation_0-rmse:1.40905	validation_1-rmse:1.14598
# [81]	validation_0-rmse:1.38461	validation_1-rmse:1.12743
# [82]	validation_0-rmse:1.35883	validation_1-rmse:1.10353
# [83]	validation_0-rmse:1.33294	validation_1-rmse:1.08313
# [84]	validation_0-rmse:1.30896	validation_1-rmse:1.05903
# [85]	validation_0-rmse:1.28661	validation_1-rmse:1.04115
# [86]	validation_0-rmse:1.26313	validation_1-rmse:1.01946
# [87]	validation_0-rmse:1.24354	validation_1-rmse:1.00098
# [88]	validation_0-rmse:1.21899	validation_1-rmse:0.97854
# [89]	validation_0-rmse:1.19896	validation_1-rmse:0.96536
# [90]	validation_0-rmse:1.17781	validation_1-rmse:0.94908
# [91]	validation_0-rmse:1.15776	validation_1-rmse:0.93423
# [92]	validation_0-rmse:1.13747	validation_1-rmse:0.92133
# [93]	validation_0-rmse:1.11899	validation_1-rmse:0.90872
# [94]	validation_0-rmse:1.10042	validation_1-rmse:0.89264
# [95]	validation_0-rmse:1.08288	validation_1-rmse:0.87737
# [96]	validation_0-rmse:1.06401	validation_1-rmse:0.86203
# [97]	validation_0-rmse:1.04587	validation_1-rmse:0.84509
# [98]	validation_0-rmse:1.02957	validation_1-rmse:0.83502
# [99]	validation_0-rmse:1.01378	validation_1-rmse:0.81868
# [100]	validation_0-rmse:0.99734	validation_1-rmse:0.80359
# [101]	validation_0-rmse:0.98038	validation_1-rmse:0.78966
# [102]	validation_0-rmse:0.96391	validation_1-rmse:0.77656
# [103]	validation_0-rmse:0.94859	validation_1-rmse:0.76525
# [104]	validation_0-rmse:0.93526	validation_1-rmse:0.75679
# [105]	validation_0-rmse:0.91955	validation_1-rmse:0.74406
# [106]	validation_0-rmse:0.90620	validation_1-rmse:0.73859
# [107]	validation_0-rmse:0.89339	validation_1-rmse:0.73162
# [108]	validation_0-rmse:0.88243	validation_1-rmse:0.72592
# [109]	validation_0-rmse:0.87092	validation_1-rmse:0.71515
# [110]	validation_0-rmse:0.85932	validation_1-rmse:0.70950
# [111]	validation_0-rmse:0.85100	validation_1-rmse:0.70465
# [112]	validation_0-rmse:0.84080	validation_1-rmse:0.69742
# [113]	validation_0-rmse:0.82869	validation_1-rmse:0.68859
# [114]	validation_0-rmse:0.81691	validation_1-rmse:0.68209
# [115]	validation_0-rmse:0.80439	validation_1-rmse:0.67435
# [116]	validation_0-rmse:0.79431	validation_1-rmse:0.67074
# [117]	validation_0-rmse:0.78355	validation_1-rmse:0.66312
# [118]	validation_0-rmse:0.77035	validation_1-rmse:0.65529
# [119]	validation_0-rmse:0.75918	validation_1-rmse:0.64925
# [120]	validation_0-rmse:0.75026	validation_1-rmse:0.64479
# [121]	validation_0-rmse:0.74093	validation_1-rmse:0.63831
# [122]	validation_0-rmse:0.73245	validation_1-rmse:0.63514
# [123]	validation_0-rmse:0.72321	validation_1-rmse:0.62974
# [124]	validation_0-rmse:0.71387	validation_1-rmse:0.62351
# [125]	validation_0-rmse:0.70520	validation_1-rmse:0.61913
# [126]	validation_0-rmse:0.69592	validation_1-rmse:0.61463
# [127]	validation_0-rmse:0.68604	validation_1-rmse:0.60956
# [128]	validation_0-rmse:0.67765	validation_1-rmse:0.60583
# [129]	validation_0-rmse:0.66989	validation_1-rmse:0.60034
# [130]	validation_0-rmse:0.66023	validation_1-rmse:0.59593
# [131]	validation_0-rmse:0.65107	validation_1-rmse:0.59027
# [132]	validation_0-rmse:0.64317	validation_1-rmse:0.58722
# [133]	validation_0-rmse:0.63705	validation_1-rmse:0.58696
# [134]	validation_0-rmse:0.62999	validation_1-rmse:0.58374
# [135]	validation_0-rmse:0.62422	validation_1-rmse:0.58320
# [136]	validation_0-rmse:0.61753	validation_1-rmse:0.58112
# [137]	validation_0-rmse:0.61073	validation_1-rmse:0.58122
# [138]	validation_0-rmse:0.60380	validation_1-rmse:0.58051
# [139]	validation_0-rmse:0.59704	validation_1-rmse:0.57784
# [140]	validation_0-rmse:0.58990	validation_1-rmse:0.57892
# [141]	validation_0-rmse:0.58386	validation_1-rmse:0.57615
# [142]	validation_0-rmse:0.57840	validation_1-rmse:0.57482
# [143]	validation_0-rmse:0.57284	validation_1-rmse:0.57331
# [144]	validation_0-rmse:0.56748	validation_1-rmse:0.57277
# [145]	validation_0-rmse:0.56354	validation_1-rmse:0.57161
# [146]	validation_0-rmse:0.55780	validation_1-rmse:0.57004
# [147]	validation_0-rmse:0.55322	validation_1-rmse:0.57022
# [148]	validation_0-rmse:0.54855	validation_1-rmse:0.56896
# [149]	validation_0-rmse:0.54330	validation_1-rmse:0.56809
# [150]	validation_0-rmse:0.53975	validation_1-rmse:0.56940
# [151]	validation_0-rmse:0.53618	validation_1-rmse:0.57177
# [152]	validation_0-rmse:0.53010	validation_1-rmse:0.57193
# [153]	validation_0-rmse:0.52593	validation_1-rmse:0.57165
# [154]	validation_0-rmse:0.52082	validation_1-rmse:0.57194
# [155]	validation_0-rmse:0.51686	validation_1-rmse:0.57318
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(6, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.723
# Uncertainty
# a0: 3.11+/-0.319
# a1: 0.614+/-0.038

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: Sr_2021_kBq_m: mean - 0.666, median - 0.669, CI - [0.622-0.705]
#
# SHAP-values for: contr_b_MAX: mean - 0.077, median - 0.075, CI - [0.06-0.094]
#
# SHAP-values for: contr_b_STD: mean - 0.138, median - 0.134, CI - [0.111-0.166]
#
# SHAP-values for: r_MIN: mean - 0.298, median - 0.295, CI - [0.263-0.328]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['Sr_2021_kBq_m', 'r_MIN', 'contr_b_STD', 'contr_b_MAX'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 153.32, median: 155.0,
#  pred. interval (P(0.025)-P(0.975)): 142.95-155.0,
#  conf. interval (p-value=0.95): 154.097-155.0
# ***
# Aggregate bias statistic:
#  mean: -0.245, median: -0.227,
#  pred. interval (P(0.025)-P(0.975)): -0.608-0.071,
#  conf. interval (p-value=0.95): -0.405--0.067
# ***
# Aggregate RMSE statistic:
#  mean: 0.82, median: 0.797, pred. interval (P(0.025)-P(0.975)): 0.624-1.126,
#  conf. interval (p-value=0.95): 0.699-0.949
# ***
# Aggregate MSE statistic:
#  mean: 0.692, median: 0.635, pred. interval (P(0.025)-P(0.975)): 0.389-1.268,
#  conf. interval (p-value=0.95): 0.489-0.904
# ***
# Aggregate R^2 statistic:
#  mean: 0.646, median: 0.665, pred. interval (P(0.025)-P(0.975)): 0.363-0.795,
#  conf. interval (p-value=0.95): 0.559-0.739
# ***
# Aggregate bias(%) statistic:
#  mean: -2.775, median: -2.609, pred. interval (P(0.025)-P(0.975)): -6.546-0.858,
#  conf. interval (p-value=0.95): -4.534--0.778
# ***
# Aggregate RMSE(%) statistic:
#  mean: 9.43, median: 9.256, pred. interval (P(0.025)-P(0.975)): 7.36-12.574,
#  conf. interval (p-value=0.95): 8.103-10.851
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -18451.791, median: -8162.727,
#  pred. interval (P(0.025)-P(0.975)): -70114.91--1003.293,
#  conf. interval (p-value=0.95): -46809.421--3657.288
# ***
# Aggregate RMSE statistic:
#  mean: 65353.871, median: 22086.791, pred. interval (P(0.025)-P(0.975)): 4547.96-228693.305,
#  conf. interval (p-value=0.95): 10617.728-197908.252
# ***
# Aggregate MSE statistic:
#  mean: 11154366316.184, median: 487827766.846, pred. interval (P(0.025)-P(0.975)): 20684026.648-52300627912.277,
#  conf. interval (p-value=0.95): 126857819.808-42485742876.15
# ***
# Aggregate R^2 statistic:
#  mean: 0.396, median: 0.433, pred. interval (P(0.025)-P(0.975)): -0.009-0.862,
#  conf. interval (p-value=0.95): 0.083-0.649
# ***
# Aggregate bias(%) statistic:
#  mean: -51.335, median: -48.482, pred. interval (P(0.025)-P(0.975)): -87.759--11.488,
#  conf. interval (p-value=0.95): -80.022--30.868
# ***
# Aggregate RMSE(%) statistic:
#  mean: 168.659, median: 124.318, pred. interval (P(0.025)-P(0.975)): 59.241-366.594,
#  conf. interval (p-value=0.95): 87.241-286.754
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [6, 7, 8, 9, 10, 11, 14])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 500, 1000, 5000, 10000, 20000, 50000, 1000000])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:8.08599
# [1]	validation_0-rmse:7.89149
# [2]	validation_0-rmse:7.70392
# [3]	validation_0-rmse:7.51889
# [4]	validation_0-rmse:7.33805
# [5]	validation_0-rmse:7.16013
# [6]	validation_0-rmse:6.98910
# [7]	validation_0-rmse:6.82130
# [8]	validation_0-rmse:6.65794
# [9]	validation_0-rmse:6.49984
# [10]	validation_0-rmse:6.34563
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:6.19406
# [12]	validation_0-rmse:6.04648
# [13]	validation_0-rmse:5.90572
# [14]	validation_0-rmse:5.76713
# [15]	validation_0-rmse:5.63244
# [16]	validation_0-rmse:5.49608
# [17]	validation_0-rmse:5.36834
# [18]	validation_0-rmse:5.24232
# [19]	validation_0-rmse:5.11771
# [20]	validation_0-rmse:4.99928
# [21]	validation_0-rmse:4.88347
# [22]	validation_0-rmse:4.76971
# [23]	validation_0-rmse:4.65801
# [24]	validation_0-rmse:4.55330
# [25]	validation_0-rmse:4.44861
# [26]	validation_0-rmse:4.34689
# [27]	validation_0-rmse:4.24701
# [28]	validation_0-rmse:4.14937
# [29]	validation_0-rmse:4.05277
# [30]	validation_0-rmse:3.95901
# [31]	validation_0-rmse:3.86542
# [32]	validation_0-rmse:3.77825
# [33]	validation_0-rmse:3.69279
# [34]	validation_0-rmse:3.60693
# [35]	validation_0-rmse:3.52413
# [36]	validation_0-rmse:3.44489
# [37]	validation_0-rmse:3.36468
# [38]	validation_0-rmse:3.28772
# [39]	validation_0-rmse:3.21250
# [40]	validation_0-rmse:3.14234
# [41]	validation_0-rmse:3.07265
# [42]	validation_0-rmse:3.00299
# [43]	validation_0-rmse:2.93699
# [44]	validation_0-rmse:2.87050
# [45]	validation_0-rmse:2.80746
# [46]	validation_0-rmse:2.74644
# [47]	validation_0-rmse:2.68506
# [48]	validation_0-rmse:2.62520
# [49]	validation_0-rmse:2.56585
# [50]	validation_0-rmse:2.50897
# [51]	validation_0-rmse:2.45445
# [52]	validation_0-rmse:2.40238
# [53]	validation_0-rmse:2.35388
# [54]	validation_0-rmse:2.30728
# [55]	validation_0-rmse:2.25703
# [56]	validation_0-rmse:2.20890
# [57]	validation_0-rmse:2.16207
# [58]	validation_0-rmse:2.11467
# [59]	validation_0-rmse:2.06841
# [60]	validation_0-rmse:2.02725
# [61]	validation_0-rmse:1.98525
# [62]	validation_0-rmse:1.94326
# [63]	validation_0-rmse:1.90568
# [64]	validation_0-rmse:1.86400
# [65]	validation_0-rmse:1.82446
# [66]	validation_0-rmse:1.78759
# [67]	validation_0-rmse:1.74969
# [68]	validation_0-rmse:1.71287
# [69]	validation_0-rmse:1.67783
# [70]	validation_0-rmse:1.64371
# [71]	validation_0-rmse:1.61143
# [72]	validation_0-rmse:1.58093
# [73]	validation_0-rmse:1.54979
# [74]	validation_0-rmse:1.52030
# [75]	validation_0-rmse:1.49055
# [76]	validation_0-rmse:1.46055
# [77]	validation_0-rmse:1.43210
# [78]	validation_0-rmse:1.40305
# [79]	validation_0-rmse:1.37779
# [80]	validation_0-rmse:1.35283
# [81]	validation_0-rmse:1.32827
# [82]	validation_0-rmse:1.30272
# [83]	validation_0-rmse:1.27882
# [84]	validation_0-rmse:1.25674
# [85]	validation_0-rmse:1.23539
# [86]	validation_0-rmse:1.21290
# [87]	validation_0-rmse:1.18984
# [88]	validation_0-rmse:1.17087
# [89]	validation_0-rmse:1.14974
# [90]	validation_0-rmse:1.12963
# [91]	validation_0-rmse:1.11084
# [92]	validation_0-rmse:1.09197
# [93]	validation_0-rmse:1.07462
# [94]	validation_0-rmse:1.05814
# [95]	validation_0-rmse:1.03910
# [96]	validation_0-rmse:1.02192
# [97]	validation_0-rmse:1.00700
# [98]	validation_0-rmse:0.99143
# [99]	validation_0-rmse:0.97494
# [100]	validation_0-rmse:0.95965
# [101]	validation_0-rmse:0.94581
# [102]	validation_0-rmse:0.93031
# [103]	validation_0-rmse:0.91646
# [104]	validation_0-rmse:0.90440
# [105]	validation_0-rmse:0.89194
# [106]	validation_0-rmse:0.87610
# [107]	validation_0-rmse:0.86320
# [108]	validation_0-rmse:0.84915
# [109]	validation_0-rmse:0.83731
# [110]	validation_0-rmse:0.82589
# [111]	validation_0-rmse:0.81537
# [112]	validation_0-rmse:0.80285
# [113]	validation_0-rmse:0.79236
# [114]	validation_0-rmse:0.78005
# [115]	validation_0-rmse:0.76914
# [116]	validation_0-rmse:0.75770
# [117]	validation_0-rmse:0.74890
# [118]	validation_0-rmse:0.73894
# [119]	validation_0-rmse:0.72868
# [120]	validation_0-rmse:0.71994
# [121]	validation_0-rmse:0.70890
# [122]	validation_0-rmse:0.70044
# [123]	validation_0-rmse:0.69380
# [124]	validation_0-rmse:0.68459
# [125]	validation_0-rmse:0.67560
# [126]	validation_0-rmse:0.66848
# [127]	validation_0-rmse:0.66082
# [128]	validation_0-rmse:0.65297
# [129]	validation_0-rmse:0.64534
# [130]	validation_0-rmse:0.63815
# [131]	validation_0-rmse:0.63075
# [132]	validation_0-rmse:0.62316
# [133]	validation_0-rmse:0.61801
# [134]	validation_0-rmse:0.61040
# [135]	validation_0-rmse:0.60356
# [136]	validation_0-rmse:0.59791
# [137]	validation_0-rmse:0.59181
# [138]	validation_0-rmse:0.58555
# [139]	validation_0-rmse:0.57933
# [140]	validation_0-rmse:0.57314
# [141]	validation_0-rmse:0.56769
# [142]	validation_0-rmse:0.56316
# [143]	validation_0-rmse:0.55803
# [144]	validation_0-rmse:0.55304
# [145]	validation_0-rmse:0.54750
# [146]	validation_0-rmse:0.54274
# [147]	validation_0-rmse:0.53909
# [148]	validation_0-rmse:0.53413
# [149]	validation_0-rmse:0.52979
# [150]	validation_0-rmse:0.52637
# [151]	validation_0-rmse:0.52310
# [152]	validation_0-rmse:0.51849
# [153]	validation_0-rmse:0.51397
# [154]	validation_0-rmse:0.51027
# [155]	validation_0-rmse:0.50655
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 155

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.2
# Relative bias(%):  -2.21
# RMSE: 0.5
# Relative RMSE(%):  5.852
# MSE: 0.3
# R square: 88.0%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(6, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.921
# Uncertainty
# a0: 1.77+/-0.20
# a1: 0.774+/-0.023

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/08_LN_Sr_vs_CHM_RGB_D_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/08_LN_Sr_vs_CHM_RGB_D_XGB_model.txt")
