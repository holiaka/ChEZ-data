# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN','contr_b_MAX', 'contr_b_STD'])
            
# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           2260           1210     -0.731      2.576
# 1       8.189       9.622           2700           1180      0.585      2.915
# 2       8.380       9.589           2500           1400      0.779      2.882
# 3       8.137       9.449           2500           1090      0.517      2.724
# 4       7.696       9.401           2400            720      0.224      2.826
#
#    AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  \
# 0       2.33    0.445070     13  35.145074   360.273487    0.488754
# 1       2.47   12.465903     24  36.135511   323.958625    0.501683
# 2       2.44   13.028298     18  35.938764   299.438354    0.540056
# 3       2.55    2.128231     15  35.908361   319.773395    0.480991
# 4       2.14   12.171553      8  38.062522   353.104284    0.505257
#
#    corr_r_MIN  contr_b_MAX  contr_b_STD
# 0    0.072792  2713.600586   332.963753
# 1    0.098347  1793.493042   293.868420
# 2    0.187811  1761.097900   272.526176
# 3    0.020686  2518.435303   299.595643
# 4    0.106549  2525.819336   327.599176

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   mf_chm_MIN     103 non-null    float64
#  8   r_MIN          103 non-null    int64
#  9   b_STD          103 non-null    float64
#  10  contr_r_STD    103 non-null    float64
#  11  corr_r_Q25     103 non-null    float64
#  12  corr_r_MIN     103 non-null    float64
#  13  contr_b_MAX    103 non-null    float64
#  14  contr_b_STD    103 non-null    float64
# dtypes: float64(12), int64(3)
# memory usage: 12.2 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Cs_wood", "ln_Sr_wood"].describe()
# Out:
#                  ln_Cs_wood                                                 \
#                       count       mean       std     min      25%      50%
# Dominant_specias
# Alder                   4.0   7.305000  1.427622   5.886   6.6765   7.0235
# Aspen                   1.0  11.367000       NaN  11.367  11.3670  11.3670
# Birch                  23.0   7.304652  1.533182   4.533   6.3365   7.2150
# Oak                     3.0   7.430333  1.260072   6.040   6.8970   7.7540
# Pine                   71.0   6.901690  1.650166   3.526   6.3790   6.9470
# Spruce                  1.0   5.176000       NaN   5.176   5.1760   5.1760
#
#                                   ln_Sr_wood                               \
#                       75%     max      count       mean       std     min
# Dominant_specias
# Alder              7.6520   9.287        4.0   7.206000  0.650057   6.265
# Aspen             11.3670  11.367        1.0  11.090000       NaN  11.090
# Birch              8.0320  10.332       23.0   9.345478  1.626360   7.139
# Oak                8.1255   8.497        3.0   7.483667  0.815040   6.565
# Pine               7.6960  10.469       71.0   8.542592  1.359020   6.075
# Spruce             5.1760   5.176        1.0   7.783000       NaN   7.783
#
#
#                       25%      50%      75%     max
# Dominant_specias
# Alder              7.0255   7.4545   7.6350   7.650
# Aspen             11.0900  11.0900  11.0900  11.090
# Birch              8.4000   8.9910   9.9365  13.864
# Oak                7.1655   7.7660   7.9430   8.120
# Pine               7.6450   8.4720   9.3710  12.687
# Spruce             7.7830   7.7830   7.7830   7.783

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3440.194175    1242.902913   -0.252563
# std       1.64946    1.472424    6087.580089    2037.684800    1.104610
# min       3.52600    6.075000     260.000000      50.000000   -3.033000
# 25%       6.31900    7.664000     635.000000     200.000000   -0.727500
# 50%       6.95700    8.472000    1150.000000     400.000000   -0.025000
# 75%       7.91350    9.421000    2525.000000    1400.000000    0.516500
# max      11.36700   13.864000   35200.000000   10500.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean  mf_chm_MIN       r_MIN       b_STD  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     2.464709    3.570291    3.368496   11.378641   35.164575
# std      0.904675    6.089170    4.845054    9.139568    5.338700
# min      0.391000    0.480000   -0.018586    2.000000   20.570709
# 25%      1.803000    0.710000    0.482279    5.000000   31.746440
# 50%      2.603000    1.290000    0.642883    8.000000   36.135511
# 75%      3.159000    2.960000    3.921804   15.000000   39.139044
# max      4.659000   36.590000   17.862923   56.000000   45.825416
#
#        contr_r_STD  corr_r_Q25  corr_r_MIN  contr_b_MAX  contr_b_STD
# count   103.000000  103.000000  103.000000   103.000000   103.000000
# mean    327.115078    0.393571    0.073579  2712.352866   349.854034
# std     167.617957    0.151801    0.056017   864.116297    93.673105
# min       0.091058    0.033797   -0.062450   832.155518   109.232976
# 25%     283.887328    0.407228    0.027204  2123.614868   292.544440
# 50%     353.034542    0.449670    0.063714  2601.248047   341.904211
# 75%     448.017711    0.476635    0.110983  3045.944336   427.359073
# max     652.546648    0.555648    0.241284  6252.923340   588.661708

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_Tag_Sr"
indep_variables = ['mf_chm_MIN', 'r_MIN', 'contr_b_MAX', 'contr_b_STD']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  \
# 0         6.824       9.240           2260           1210     -0.731
# 1         8.189       9.622           2700           1180      0.585
# 2         8.380       9.589           2500           1400      0.779
# 3         8.137       9.449           2500           1090      0.517
# 4         7.696       9.401           2400            720      0.224
# ..          ...         ...            ...            ...        ...
# 98        8.071       8.434           2500           1300      0.228
# 99        7.993      10.042           2300           1100      0.266
# 100       8.343      10.488           2400           1200      0.543
# 101       3.638       6.399            630            270     -2.811
# 102       4.787       6.877            680            290     -1.728
#
#      ln_Tag_Sr  AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  \
# 0        2.576       2.33    0.445070     13  35.145074   360.273487
# 1        2.915       2.47   12.465903     24  36.135511   323.958625
# 2        2.882       2.44   13.028298     18  35.938764   299.438354
# 3        2.724       2.55    2.128231     15  35.908361   319.773395
# 4        2.826       2.14   12.171553      8  38.062522   353.104284
# ..         ...        ...         ...    ...        ...          ...
# 98       1.514       2.92    0.528681      3  32.852994   329.221211
# 99       3.230       2.78    0.422647     18  27.970146   268.895699
# 100      3.606       2.92    0.426717     19  30.529613   251.314791
# 101      0.805       0.75    0.476680      6  37.245047   477.751734
# 102      1.199       0.78    0.410141      2  38.454424   412.535053
#
#      corr_r_Q25  corr_r_MIN  contr_b_MAX  contr_b_STD
# 0      0.488754    0.072792  2713.600586   332.963753
# 1      0.501683    0.098347  1793.493042   293.868420
# 2      0.540056    0.187811  1761.097900   272.526176
# 3      0.480991    0.020686  2518.435303   299.595643
# 4      0.505257    0.106549  2525.819336   327.599176
# ..          ...         ...          ...          ...
# 98     0.478581    0.079646  3402.678467   306.364115
# 99     0.467111    0.063714  1918.606323   259.662727
# 100    0.501777    0.128376  1374.815430   227.616327
# 101    0.467443    0.129664  2461.437988   439.953000
# 102    0.480964    0.157460  2530.473633   386.530917
#
# [103 rows x 15 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    mf_chm_MIN  r_MIN  contr_b_MAX  contr_b_STD
# 0    0.445070     13  2713.600586   332.963753
# 1   12.465903     24  1793.493042   293.868420
# 2   13.028298     18  1761.097900   272.526176
# 3    2.128231     15  2518.435303   299.595643
# 4   12.171553      8  2525.819336   327.599176

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Tag_Sr
# 0      2.576
# 1      2.915
# 2      2.882
# 3      2.724
# 4      2.826

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [-0.20484449027017693, 0.20133756828747895, -0.42796139963534796]
#     Mean: -0.144
#     Std: 0.261
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.85882989 0.78822524 0.97424025]
#     Mean: 0.874
#     Std: 0.077
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.6480861064365933, 0.6497382567069109, 0.6726732284041013]
#     Mean: 0.657
#     Std: 0.011
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.09397946663770174                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.09875122322015767                  # gamma
print('Gamma: ' + str(p2))

p3 = 0.05324735530207501                  # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 4                                   # max_depth
print('Max_depth: ' + str(p4))

p5 = 54                                  # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.7408234046212928                   # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.09397946663770174
# Gamma: 0.09875122322015767
# Learning_rate: 0.05324735530207501
# Max_depth: 4
# N_estimators: 54
# Subsample: 0.7408234046212928

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:2.10819	validation_1-rmse:1.88370
# [1]	validation_0-rmse:2.01453	validation_1-rmse:1.79189
# [2]	validation_0-rmse:1.92523	validation_1-rmse:1.70560
# [3]	validation_0-rmse:1.83999	validation_1-rmse:1.61780
# [4]	validation_0-rmse:1.75806	validation_1-rmse:1.54022
# [5]	validation_0-rmse:1.68397	validation_1-rmse:1.47468
# [6]	validation_0-rmse:1.61347	validation_1-rmse:1.41220
# [7]	validation_0-rmse:1.54957	validation_1-rmse:1.35134
# [8]	validation_0-rmse:1.48760	validation_1-rmse:1.29458
# [9]	validation_0-rmse:1.42921	validation_1-rmse:1.24115
# [10]	validation_0-rmse:1.37271	validation_1-rmse:1.18878
# [11]	validation_0-rmse:1.31927	validation_1-rmse:1.15182
# [12]	validation_0-rmse:1.26542	validation_1-rmse:1.10562
# [13]	validation_0-rmse:1.22109	validation_1-rmse:1.06223
# [14]	validation_0-rmse:1.17704	validation_1-rmse:1.02526
# [15]	validation_0-rmse:1.13338	validation_1-rmse:0.98541
# [16]	validation_0-rmse:1.09428	validation_1-rmse:0.95336
# [17]	validation_0-rmse:1.06378	validation_1-rmse:0.93264
# [18]	validation_0-rmse:1.02912	validation_1-rmse:0.90730
# [19]	validation_0-rmse:0.99815	validation_1-rmse:0.88319
# [20]	validation_0-rmse:0.96854	validation_1-rmse:0.86056
# [21]	validation_0-rmse:0.93982	validation_1-rmse:0.84696
# [22]	validation_0-rmse:0.91241	validation_1-rmse:0.83044
# [23]	validation_0-rmse:0.88591	validation_1-rmse:0.81582
# [24]	validation_0-rmse:0.86252	validation_1-rmse:0.80136
# [25]	validation_0-rmse:0.84474	validation_1-rmse:0.79162
# [26]	validation_0-rmse:0.82488	validation_1-rmse:0.78181
# [27]	validation_0-rmse:0.80758	validation_1-rmse:0.76829
# [28]	validation_0-rmse:0.78965	validation_1-rmse:0.76088
# [29]	validation_0-rmse:0.77009	validation_1-rmse:0.75305
# [30]	validation_0-rmse:0.75551	validation_1-rmse:0.75220
# [31]	validation_0-rmse:0.74070	validation_1-rmse:0.74010
# [32]	validation_0-rmse:0.72921	validation_1-rmse:0.73366
# [33]	validation_0-rmse:0.71783	validation_1-rmse:0.73163
# [34]	validation_0-rmse:0.70579	validation_1-rmse:0.72896
# [35]	validation_0-rmse:0.69712	validation_1-rmse:0.72675
# [36]	validation_0-rmse:0.68592	validation_1-rmse:0.72419
# [37]	validation_0-rmse:0.67425	validation_1-rmse:0.72872
# [38]	validation_0-rmse:0.66462	validation_1-rmse:0.72787
# [39]	validation_0-rmse:0.65524	validation_1-rmse:0.72641
# [40]	validation_0-rmse:0.64038	validation_1-rmse:0.73290
# [41]	validation_0-rmse:0.63347	validation_1-rmse:0.73119
# [42]	validation_0-rmse:0.62393	validation_1-rmse:0.73024
# [43]	validation_0-rmse:0.61641	validation_1-rmse:0.72796
# [44]	validation_0-rmse:0.61049	validation_1-rmse:0.72586
# [45]	validation_0-rmse:0.60237	validation_1-rmse:0.72555
# [46]	validation_0-rmse:0.59678	validation_1-rmse:0.72910
# [47]	validation_0-rmse:0.59066	validation_1-rmse:0.72822
# [48]	validation_0-rmse:0.58528	validation_1-rmse:0.72604
# [49]	validation_0-rmse:0.57688	validation_1-rmse:0.72739
# [50]	validation_0-rmse:0.57472	validation_1-rmse:0.72808
# [51]	validation_0-rmse:0.56893	validation_1-rmse:0.73146
# [52]	validation_0-rmse:0.56310	validation_1-rmse:0.73246
# [53]	validation_0-rmse:0.55826	validation_1-rmse:0.73231
# [0]	validation_0-rmse:2.04156	validation_1-rmse:2.15336
# [1]	validation_0-rmse:1.95417	validation_1-rmse:2.05904
# [2]	validation_0-rmse:1.86888	validation_1-rmse:1.96647
# [3]	validation_0-rmse:1.78840	validation_1-rmse:1.87820
# [4]	validation_0-rmse:1.71257	validation_1-rmse:1.80235
# [5]	validation_0-rmse:1.63816	validation_1-rmse:1.72787
# [6]	validation_0-rmse:1.56614	validation_1-rmse:1.65716
# [7]	validation_0-rmse:1.50433	validation_1-rmse:1.59621
# [8]	validation_0-rmse:1.44311	validation_1-rmse:1.53615
# [9]	validation_0-rmse:1.38414	validation_1-rmse:1.47969
# [10]	validation_0-rmse:1.33399	validation_1-rmse:1.42753
# [11]	validation_0-rmse:1.28978	validation_1-rmse:1.37933
# [12]	validation_0-rmse:1.24473	validation_1-rmse:1.32364
# [13]	validation_0-rmse:1.20337	validation_1-rmse:1.27371
# [14]	validation_0-rmse:1.16666	validation_1-rmse:1.23623
# [15]	validation_0-rmse:1.12754	validation_1-rmse:1.18986
# [16]	validation_0-rmse:1.09209	validation_1-rmse:1.15169
# [17]	validation_0-rmse:1.05629	validation_1-rmse:1.11553
# [18]	validation_0-rmse:1.02760	validation_1-rmse:1.08445
# [19]	validation_0-rmse:0.99614	validation_1-rmse:1.04594
# [20]	validation_0-rmse:0.96345	validation_1-rmse:1.01143
# [21]	validation_0-rmse:0.93788	validation_1-rmse:0.98847
# [22]	validation_0-rmse:0.90952	validation_1-rmse:0.96184
# [23]	validation_0-rmse:0.88774	validation_1-rmse:0.94622
# [24]	validation_0-rmse:0.86428	validation_1-rmse:0.92597
# [25]	validation_0-rmse:0.84245	validation_1-rmse:0.90679
# [26]	validation_0-rmse:0.82427	validation_1-rmse:0.88807
# [27]	validation_0-rmse:0.80765	validation_1-rmse:0.87672
# [28]	validation_0-rmse:0.78867	validation_1-rmse:0.86296
# [29]	validation_0-rmse:0.77260	validation_1-rmse:0.84679
# [30]	validation_0-rmse:0.75437	validation_1-rmse:0.83211
# [31]	validation_0-rmse:0.73761	validation_1-rmse:0.82129
# [32]	validation_0-rmse:0.72755	validation_1-rmse:0.81893
# [33]	validation_0-rmse:0.71182	validation_1-rmse:0.80897
# [34]	validation_0-rmse:0.70254	validation_1-rmse:0.79800
# [35]	validation_0-rmse:0.69089	validation_1-rmse:0.78630
# [36]	validation_0-rmse:0.68015	validation_1-rmse:0.77598
# [37]	validation_0-rmse:0.67021	validation_1-rmse:0.76924
# [38]	validation_0-rmse:0.65917	validation_1-rmse:0.76383
# [39]	validation_0-rmse:0.64791	validation_1-rmse:0.75522
# [40]	validation_0-rmse:0.63481	validation_1-rmse:0.74736
# [41]	validation_0-rmse:0.62546	validation_1-rmse:0.74170
# [42]	validation_0-rmse:0.61313	validation_1-rmse:0.73499
# [43]	validation_0-rmse:0.60623	validation_1-rmse:0.73144
# [44]	validation_0-rmse:0.59980	validation_1-rmse:0.73177
# [45]	validation_0-rmse:0.58810	validation_1-rmse:0.73005
# [46]	validation_0-rmse:0.58181	validation_1-rmse:0.72723
# [47]	validation_0-rmse:0.57645	validation_1-rmse:0.72647
# [48]	validation_0-rmse:0.57079	validation_1-rmse:0.72275
# [49]	validation_0-rmse:0.56438	validation_1-rmse:0.71773
# [50]	validation_0-rmse:0.55774	validation_1-rmse:0.72031
# [51]	validation_0-rmse:0.55224	validation_1-rmse:0.72022
# [52]	validation_0-rmse:0.54722	validation_1-rmse:0.71975
# [53]	validation_0-rmse:0.54391	validation_1-rmse:0.72035
# [0]	validation_0-rmse:2.09104	validation_1-rmse:1.96241
# [1]	validation_0-rmse:1.99647	validation_1-rmse:1.87063
# [2]	validation_0-rmse:1.91194	validation_1-rmse:1.79412
# [3]	validation_0-rmse:1.82488	validation_1-rmse:1.70977
# [4]	validation_0-rmse:1.74631	validation_1-rmse:1.63502
# [5]	validation_0-rmse:1.67138	validation_1-rmse:1.56858
# [6]	validation_0-rmse:1.60317	validation_1-rmse:1.50409
# [7]	validation_0-rmse:1.54109	validation_1-rmse:1.45238
# [8]	validation_0-rmse:1.47733	validation_1-rmse:1.39932
# [9]	validation_0-rmse:1.42119	validation_1-rmse:1.35393
# [10]	validation_0-rmse:1.36934	validation_1-rmse:1.31480
# [11]	validation_0-rmse:1.31617	validation_1-rmse:1.26982
# [12]	validation_0-rmse:1.27154	validation_1-rmse:1.23579
# [13]	validation_0-rmse:1.22799	validation_1-rmse:1.19917
# [14]	validation_0-rmse:1.18161	validation_1-rmse:1.15744
# [15]	validation_0-rmse:1.14401	validation_1-rmse:1.12669
# [16]	validation_0-rmse:1.10495	validation_1-rmse:1.09681
# [17]	validation_0-rmse:1.06811	validation_1-rmse:1.06709
# [18]	validation_0-rmse:1.03605	validation_1-rmse:1.04861
# [19]	validation_0-rmse:1.00588	validation_1-rmse:1.02325
# [20]	validation_0-rmse:0.97516	validation_1-rmse:0.99891
# [21]	validation_0-rmse:0.94697	validation_1-rmse:0.98975
# [22]	validation_0-rmse:0.92393	validation_1-rmse:0.97291
# [23]	validation_0-rmse:0.90345	validation_1-rmse:0.95519
# [24]	validation_0-rmse:0.87976	validation_1-rmse:0.93105
# [25]	validation_0-rmse:0.85874	validation_1-rmse:0.91041
# [26]	validation_0-rmse:0.83696	validation_1-rmse:0.89587
# [27]	validation_0-rmse:0.81968	validation_1-rmse:0.88139
# [28]	validation_0-rmse:0.80387	validation_1-rmse:0.86988
# [29]	validation_0-rmse:0.78996	validation_1-rmse:0.85720
# [30]	validation_0-rmse:0.77127	validation_1-rmse:0.85084
# [31]	validation_0-rmse:0.75660	validation_1-rmse:0.83330
# [32]	validation_0-rmse:0.74159	validation_1-rmse:0.81820
# [33]	validation_0-rmse:0.72965	validation_1-rmse:0.80715
# [34]	validation_0-rmse:0.71526	validation_1-rmse:0.80297
# [35]	validation_0-rmse:0.70501	validation_1-rmse:0.79569
# [36]	validation_0-rmse:0.69321	validation_1-rmse:0.78643
# [37]	validation_0-rmse:0.68005	validation_1-rmse:0.78833
# [38]	validation_0-rmse:0.66808	validation_1-rmse:0.77618
# [39]	validation_0-rmse:0.65913	validation_1-rmse:0.76683
# [40]	validation_0-rmse:0.64828	validation_1-rmse:0.76191
# [41]	validation_0-rmse:0.64101	validation_1-rmse:0.75229
# [42]	validation_0-rmse:0.63130	validation_1-rmse:0.74863
# [43]	validation_0-rmse:0.62271	validation_1-rmse:0.74801
# [44]	validation_0-rmse:0.61603	validation_1-rmse:0.74002
# [45]	validation_0-rmse:0.60833	validation_1-rmse:0.73624
# [46]	validation_0-rmse:0.59785	validation_1-rmse:0.73440
# [47]	validation_0-rmse:0.59258	validation_1-rmse:0.72785
# [48]	validation_0-rmse:0.58711	validation_1-rmse:0.72072
# [49]	validation_0-rmse:0.57831	validation_1-rmse:0.72520
# [42]	validation_0-rmse:0.64080	validation_1-rmse:0.66368
# [43]	validation_0-rmse:0.63527	validation_1-rmse:0.65810
# [44]	validation_0-rmse:0.62853	validation_1-rmse:0.65556
# [45]	validation_0-rmse:0.62217	validation_1-rmse:0.65318
# [46]	validation_0-rmse:0.61319	validation_1-rmse:0.65038
# [47]	validation_0-rmse:0.60647	validation_1-rmse:0.64665
# [48]	validation_0-rmse:0.60058	validation_1-rmse:0.64800
# [49]	validation_0-rmse:0.59460	validation_1-rmse:0.65015
# [50]	validation_0-rmse:0.59096	validation_1-rmse:0.64759
# [51]	validation_0-rmse:0.58583	validation_1-rmse:0.64480
# [52]	validation_0-rmse:0.57978	validation_1-rmse:0.64312
# [53]	validation_0-rmse:0.57549	validation_1-rmse:0.64313
# [0]	validation_0-rmse:2.01892	validation_1-rmse:2.27978
# [1]	validation_0-rmse:1.93057	validation_1-rmse:2.18907
# [2]	validation_0-rmse:1.84455	validation_1-rmse:2.10680
# [3]	validation_0-rmse:1.76265	validation_1-rmse:2.02143
# [4]	validation_0-rmse:1.69297	validation_1-rmse:1.94664
# [5]	validation_0-rmse:1.61616	validation_1-rmse:1.86416
# [6]	validation_0-rmse:1.54684	validation_1-rmse:1.79040
# [7]	validation_0-rmse:1.48434	validation_1-rmse:1.72106
# [8]	validation_0-rmse:1.42677	validation_1-rmse:1.65858
# [9]	validation_0-rmse:1.36712	validation_1-rmse:1.59373
# [10]	validation_0-rmse:1.31316	validation_1-rmse:1.53388
# [11]	validation_0-rmse:1.26473	validation_1-rmse:1.48361
# [12]	validation_0-rmse:1.22033	validation_1-rmse:1.44141
# [13]	validation_0-rmse:1.17846	validation_1-rmse:1.40180
# [14]	validation_0-rmse:1.14288	validation_1-rmse:1.36807
# [15]	validation_0-rmse:1.10421	validation_1-rmse:1.32964
# [16]	validation_0-rmse:1.06808	validation_1-rmse:1.28870
# [17]	validation_0-rmse:1.03193	validation_1-rmse:1.25514
# [18]	validation_0-rmse:1.00320	validation_1-rmse:1.22270
# [19]	validation_0-rmse:0.97056	validation_1-rmse:1.19017
# [20]	validation_0-rmse:0.94162	validation_1-rmse:1.16187
# [21]	validation_0-rmse:0.91502	validation_1-rmse:1.13543
# [22]	validation_0-rmse:0.88368	validation_1-rmse:1.10321
# [23]	validation_0-rmse:0.86046	validation_1-rmse:1.08289
# [24]	validation_0-rmse:0.83411	validation_1-rmse:1.06517
# [25]	validation_0-rmse:0.81058	validation_1-rmse:1.04155
# [26]	validation_0-rmse:0.79141	validation_1-rmse:1.02261
# [27]	validation_0-rmse:0.77362	validation_1-rmse:1.00348
# [28]	validation_0-rmse:0.75620	validation_1-rmse:0.98843
# [29]	validation_0-rmse:0.74157	validation_1-rmse:0.97492
# [30]	validation_0-rmse:0.72863	validation_1-rmse:0.96492
# [31]	validation_0-rmse:0.71110	validation_1-rmse:0.95232
# [32]	validation_0-rmse:0.69782	validation_1-rmse:0.94199
# [33]	validation_0-rmse:0.68428	validation_1-rmse:0.93282
# [34]	validation_0-rmse:0.67339	validation_1-rmse:0.92588
# [35]	validation_0-rmse:0.66364	validation_1-rmse:0.91300
# [36]	validation_0-rmse:0.65115	validation_1-rmse:0.90416
# [37]	validation_0-rmse:0.64067	validation_1-rmse:0.89422
# [38]	validation_0-rmse:0.63131	validation_1-rmse:0.88632
# [39]	validation_0-rmse:0.62281	validation_1-rmse:0.87590
# [40]	validation_0-rmse:0.61185	validation_1-rmse:0.86332
# [41]	validation_0-rmse:0.60433	validation_1-rmse:0.85419
# [42]	validation_0-rmse:0.59828	validation_1-rmse:0.85387
# [43]	validation_0-rmse:0.59141	validation_1-rmse:0.84630
# [44]	validation_0-rmse:0.58644	validation_1-rmse:0.84004
# [45]	validation_0-rmse:0.57920	validation_1-rmse:0.83640
# [46]	validation_0-rmse:0.57317	validation_1-rmse:0.83364
# [47]	validation_0-rmse:0.56817	validation_1-rmse:0.82594
# [48]	validation_0-rmse:0.56350	validation_1-rmse:0.81971
# [49]	validation_0-rmse:0.55916	validation_1-rmse:0.81620
# [50]	validation_0-rmse:0.55436	validation_1-rmse:0.81036
# [51]	validation_0-rmse:0.54642	validation_1-rmse:0.81274
# [52]	validation_0-rmse:0.53922	validation_1-rmse:0.81252
# [53]	validation_0-rmse:0.53652	validation_1-rmse:0.81021
# [0]	validation_0-rmse:2.07259	validation_1-rmse:2.04785
# [1]	validation_0-rmse:1.98329	validation_1-rmse:1.95667
# [2]	validation_0-rmse:1.89931	validation_1-rmse:1.87476
# [3]	validation_0-rmse:1.81758	validation_1-rmse:1.79070
# [4]	validation_0-rmse:1.74166	validation_1-rmse:1.71034
# [5]	validation_0-rmse:1.66900	validation_1-rmse:1.64034
# [6]	validation_0-rmse:1.59817	validation_1-rmse:1.56687
# [7]	validation_0-rmse:1.52991	validation_1-rmse:1.49354
# [8]	validation_0-rmse:1.46889	validation_1-rmse:1.43031
# [9]	validation_0-rmse:1.41435	validation_1-rmse:1.37578
# [10]	validation_0-rmse:1.36502	validation_1-rmse:1.32612
# [11]	validation_0-rmse:1.31505	validation_1-rmse:1.27658
# [12]	validation_0-rmse:1.26775	validation_1-rmse:1.23681
# [13]	validation_0-rmse:1.22122	validation_1-rmse:1.19583
# [14]	validation_0-rmse:1.17829	validation_1-rmse:1.14702
# [15]	validation_0-rmse:1.13713	validation_1-rmse:1.10358
# [16]	validation_0-rmse:1.09709	validation_1-rmse:1.06655
# [17]	validation_0-rmse:1.06536	validation_1-rmse:1.03510
# [18]	validation_0-rmse:1.03459	validation_1-rmse:0.99830
# [19]	validation_0-rmse:1.00510	validation_1-rmse:0.96574
# [20]	validation_0-rmse:0.97563	validation_1-rmse:0.93265
# [21]	validation_0-rmse:0.94785	validation_1-rmse:0.90478
# [22]	validation_0-rmse:0.92323	validation_1-rmse:0.88663
# [23]	validation_0-rmse:0.90036	validation_1-rmse:0.86441
# [24]	validation_0-rmse:0.87634	validation_1-rmse:0.84973
# [25]	validation_0-rmse:0.85593	validation_1-rmse:0.83137
# [26]	validation_0-rmse:0.83705	validation_1-rmse:0.81120
# [12]	validation_0-rmse:1.28296	validation_1-rmse:1.09791
# [13]	validation_0-rmse:1.23738	validation_1-rmse:1.05921
# [14]	validation_0-rmse:1.19745	validation_1-rmse:1.02463
# [15]	validation_0-rmse:1.15844	validation_1-rmse:0.99262
# [16]	validation_0-rmse:1.12164	validation_1-rmse:0.96357
# [17]	validation_0-rmse:1.08819	validation_1-rmse:0.93807
# [18]	validation_0-rmse:1.05343	validation_1-rmse:0.91462
# [19]	validation_0-rmse:1.01922	validation_1-rmse:0.88758
# [20]	validation_0-rmse:0.99297	validation_1-rmse:0.86660
# [21]	validation_0-rmse:0.96416	validation_1-rmse:0.85537
# [22]	validation_0-rmse:0.93642	validation_1-rmse:0.84287
# [23]	validation_0-rmse:0.91091	validation_1-rmse:0.82920
# [24]	validation_0-rmse:0.88445	validation_1-rmse:0.81440
# [25]	validation_0-rmse:0.86341	validation_1-rmse:0.80278
# [26]	validation_0-rmse:0.84388	validation_1-rmse:0.78661
# [27]	validation_0-rmse:0.81927	validation_1-rmse:0.77056
# [28]	validation_0-rmse:0.79993	validation_1-rmse:0.76520
# [29]	validation_0-rmse:0.78111	validation_1-rmse:0.75079
# [30]	validation_0-rmse:0.76115	validation_1-rmse:0.73562
# [31]	validation_0-rmse:0.74338	validation_1-rmse:0.73499
# [32]	validation_0-rmse:0.72886	validation_1-rmse:0.73157
# [33]	validation_0-rmse:0.71603	validation_1-rmse:0.73038
# [34]	validation_0-rmse:0.70375	validation_1-rmse:0.72723
# [35]	validation_0-rmse:0.68907	validation_1-rmse:0.72192
# [36]	validation_0-rmse:0.67694	validation_1-rmse:0.71809
# [37]	validation_0-rmse:0.66537	validation_1-rmse:0.71393
# [38]	validation_0-rmse:0.65563	validation_1-rmse:0.71858
# [39]	validation_0-rmse:0.64545	validation_1-rmse:0.71608
# [40]	validation_0-rmse:0.63457	validation_1-rmse:0.71997
# [41]	validation_0-rmse:0.62543	validation_1-rmse:0.71613
# [42]	validation_0-rmse:0.61616	validation_1-rmse:0.71663
# [43]	validation_0-rmse:0.60881	validation_1-rmse:0.71474
# [44]	validation_0-rmse:0.60124	validation_1-rmse:0.71396
# [45]	validation_0-rmse:0.59238	validation_1-rmse:0.71868
# [46]	validation_0-rmse:0.58470	validation_1-rmse:0.71787
# [47]	validation_0-rmse:0.57950	validation_1-rmse:0.71893
# [48]	validation_0-rmse:0.57356	validation_1-rmse:0.71925
# [49]	validation_0-rmse:0.56700	validation_1-rmse:0.71459
# [50]	validation_0-rmse:0.56138	validation_1-rmse:0.71464
# [51]	validation_0-rmse:0.55564	validation_1-rmse:0.71571
# [52]	validation_0-rmse:0.54987	validation_1-rmse:0.72073
# [53]	validation_0-rmse:0.54589	validation_1-rmse:0.71942
# [0]	validation_0-rmse:2.05647	validation_1-rmse:2.10419
# [1]	validation_0-rmse:1.96292	validation_1-rmse:2.01730
# [2]	validation_0-rmse:1.87786	validation_1-rmse:1.94404
# [3]	validation_0-rmse:1.79469	validation_1-rmse:1.86640
# [4]	validation_0-rmse:1.71501	validation_1-rmse:1.79237
# [5]	validation_0-rmse:1.63763	validation_1-rmse:1.72740
# [6]	validation_0-rmse:1.56902	validation_1-rmse:1.66957
# [7]	validation_0-rmse:1.50446	validation_1-rmse:1.62047
# [8]	validation_0-rmse:1.44391	validation_1-rmse:1.56795
# [9]	validation_0-rmse:1.38452	validation_1-rmse:1.52303
# [10]	validation_0-rmse:1.33244	validation_1-rmse:1.47789
# [11]	validation_0-rmse:1.28425	validation_1-rmse:1.43787
# [12]	validation_0-rmse:1.23530	validation_1-rmse:1.39974
# [13]	validation_0-rmse:1.18848	validation_1-rmse:1.36731
# [14]	validation_0-rmse:1.14698	validation_1-rmse:1.33409
# [15]	validation_0-rmse:1.10680	validation_1-rmse:1.30363
# [16]	validation_0-rmse:1.06918	validation_1-rmse:1.27717
# [17]	validation_0-rmse:1.03364	validation_1-rmse:1.24616
# [18]	validation_0-rmse:1.00008	validation_1-rmse:1.22076
# [19]	validation_0-rmse:0.97024	validation_1-rmse:1.19980
# [20]	validation_0-rmse:0.93962	validation_1-rmse:1.17806
# [21]	validation_0-rmse:0.91197	validation_1-rmse:1.15948
# [22]	validation_0-rmse:0.88646	validation_1-rmse:1.14060
# [23]	validation_0-rmse:0.86129	validation_1-rmse:1.11969
# [24]	validation_0-rmse:0.83841	validation_1-rmse:1.10262
# [25]	validation_0-rmse:0.81824	validation_1-rmse:1.09084
# [26]	validation_0-rmse:0.80048	validation_1-rmse:1.08759
# [27]	validation_0-rmse:0.78189	validation_1-rmse:1.07130
# [28]	validation_0-rmse:0.76267	validation_1-rmse:1.05721
# [29]	validation_0-rmse:0.74771	validation_1-rmse:1.04713
# [30]	validation_0-rmse:0.73265	validation_1-rmse:1.03785
# [31]	validation_0-rmse:0.71923	validation_1-rmse:1.02880
# [32]	validation_0-rmse:0.70402	validation_1-rmse:1.01780
# [33]	validation_0-rmse:0.69080	validation_1-rmse:1.01135
# [34]	validation_0-rmse:0.67829	validation_1-rmse:1.00636
# [35]	validation_0-rmse:0.66786	validation_1-rmse:0.99976
# [36]	validation_0-rmse:0.65523	validation_1-rmse:0.99055
# [37]	validation_0-rmse:0.64288	validation_1-rmse:0.98073
# [38]	validation_0-rmse:0.63345	validation_1-rmse:0.97425
# [39]	validation_0-rmse:0.62338	validation_1-rmse:0.96865
# [40]	validation_0-rmse:0.61293	validation_1-rmse:0.96081
# [41]	validation_0-rmse:0.60407	validation_1-rmse:0.95610
# [42]	validation_0-rmse:0.59630	validation_1-rmse:0.95159
# [43]	validation_0-rmse:0.59066	validation_1-rmse:0.94707
# [44]	validation_0-rmse:0.58369	validation_1-rmse:0.94172
# [45]	validation_0-rmse:0.57652	validation_1-rmse:0.93615
# [46]	validation_0-rmse:0.56930	validation_1-rmse:0.93473
# [47]	validation_0-rmse:0.56320	validation_1-rmse:0.93070
# [48]	validation_0-rmse:0.55737	validation_1-rmse:0.92682
# [49]	validation_0-rmse:0.55253	validation_1-rmse:0.92665
# [12]	validation_0-rmse:1.24727	validation_1-rmse:1.20769
# [13]	validation_0-rmse:1.19797	validation_1-rmse:1.16165
# [14]	validation_0-rmse:1.15310	validation_1-rmse:1.12453
# [15]	validation_0-rmse:1.11075	validation_1-rmse:1.08654
# [16]	validation_0-rmse:1.07435	validation_1-rmse:1.06070
# [17]	validation_0-rmse:1.03985	validation_1-rmse:1.02805
# [18]	validation_0-rmse:1.00245	validation_1-rmse:1.00354
# [19]	validation_0-rmse:0.97134	validation_1-rmse:0.97594
# [20]	validation_0-rmse:0.94416	validation_1-rmse:0.95424
# [21]	validation_0-rmse:0.91338	validation_1-rmse:0.94019
# [22]	validation_0-rmse:0.88699	validation_1-rmse:0.93139
# [23]	validation_0-rmse:0.86359	validation_1-rmse:0.92103
# [24]	validation_0-rmse:0.84000	validation_1-rmse:0.90905
# [25]	validation_0-rmse:0.81671	validation_1-rmse:0.89434
# [26]	validation_0-rmse:0.79769	validation_1-rmse:0.88630
# [27]	validation_0-rmse:0.78088	validation_1-rmse:0.87482
# [28]	validation_0-rmse:0.76439	validation_1-rmse:0.86948
# [29]	validation_0-rmse:0.74959	validation_1-rmse:0.86075
# [30]	validation_0-rmse:0.73529	validation_1-rmse:0.85409
# [31]	validation_0-rmse:0.71823	validation_1-rmse:0.85085
# [32]	validation_0-rmse:0.70253	validation_1-rmse:0.85598
# [33]	validation_0-rmse:0.68848	validation_1-rmse:0.85652
# [34]	validation_0-rmse:0.67513	validation_1-rmse:0.85251
# [35]	validation_0-rmse:0.66568	validation_1-rmse:0.84748
# [36]	validation_0-rmse:0.65338	validation_1-rmse:0.84914
# [37]	validation_0-rmse:0.64338	validation_1-rmse:0.84905
# [38]	validation_0-rmse:0.63269	validation_1-rmse:0.84700
# [39]	validation_0-rmse:0.62460	validation_1-rmse:0.84415
# [40]	validation_0-rmse:0.61406	validation_1-rmse:0.84775
# [41]	validation_0-rmse:0.60641	validation_1-rmse:0.84486
# [42]	validation_0-rmse:0.59686	validation_1-rmse:0.84673
# [43]	validation_0-rmse:0.59003	validation_1-rmse:0.84503
# [44]	validation_0-rmse:0.58282	validation_1-rmse:0.84347
# [45]	validation_0-rmse:0.57650	validation_1-rmse:0.84633
# [46]	validation_0-rmse:0.56997	validation_1-rmse:0.84764
# [47]	validation_0-rmse:0.56421	validation_1-rmse:0.84804
# [48]	validation_0-rmse:0.55884	validation_1-rmse:0.84684
# [49]	validation_0-rmse:0.55334	validation_1-rmse:0.84899
# [50]	validation_0-rmse:0.54948	validation_1-rmse:0.84847
# [51]	validation_0-rmse:0.54393	validation_1-rmse:0.84815
# [52]	validation_0-rmse:0.53854	validation_1-rmse:0.84686
# [53]	validation_0-rmse:0.53482	validation_1-rmse:0.84600
# [0]	validation_0-rmse:2.03261	validation_1-rmse:2.20532
# [1]	validation_0-rmse:1.94425	validation_1-rmse:2.11231
# [2]	validation_0-rmse:1.86003	validation_1-rmse:2.01840
# [3]	validation_0-rmse:1.78076	validation_1-rmse:1.94049
# [4]	validation_0-rmse:1.70959	validation_1-rmse:1.85684
# [5]	validation_0-rmse:1.63631	validation_1-rmse:1.77985
# [6]	validation_0-rmse:1.56799	validation_1-rmse:1.71273
# [7]	validation_0-rmse:1.50802	validation_1-rmse:1.64992
# [8]	validation_0-rmse:1.45079	validation_1-rmse:1.58840
# [9]	validation_0-rmse:1.39259	validation_1-rmse:1.52805
# [10]	validation_0-rmse:1.33958	validation_1-rmse:1.47348
# [11]	validation_0-rmse:1.29109	validation_1-rmse:1.41453
# [12]	validation_0-rmse:1.24406	validation_1-rmse:1.36525
# [13]	validation_0-rmse:1.20130	validation_1-rmse:1.32529
# [14]	validation_0-rmse:1.16097	validation_1-rmse:1.28095
# [15]	validation_0-rmse:1.11960	validation_1-rmse:1.23631
# [16]	validation_0-rmse:1.08533	validation_1-rmse:1.19643
# [17]	validation_0-rmse:1.05326	validation_1-rmse:1.16901
# [18]	validation_0-rmse:1.02430	validation_1-rmse:1.14280
# [19]	validation_0-rmse:0.98995	validation_1-rmse:1.10550
# [20]	validation_0-rmse:0.96115	validation_1-rmse:1.07342
# [21]	validation_0-rmse:0.93125	validation_1-rmse:1.04590
# [22]	validation_0-rmse:0.90643	validation_1-rmse:1.03029
# [23]	validation_0-rmse:0.88332	validation_1-rmse:1.00425
# [24]	validation_0-rmse:0.85826	validation_1-rmse:0.98402
# [25]	validation_0-rmse:0.83571	validation_1-rmse:0.96006
# [26]	validation_0-rmse:0.81587	validation_1-rmse:0.94382
# [27]	validation_0-rmse:0.79758	validation_1-rmse:0.92687
# [28]	validation_0-rmse:0.78003	validation_1-rmse:0.91695
# [29]	validation_0-rmse:0.76528	validation_1-rmse:0.90308
# [30]	validation_0-rmse:0.75402	validation_1-rmse:0.88815
# [31]	validation_0-rmse:0.73942	validation_1-rmse:0.87588
# [32]	validation_0-rmse:0.72499	validation_1-rmse:0.87085
# [33]	validation_0-rmse:0.71212	validation_1-rmse:0.86358
# [34]	validation_0-rmse:0.70026	validation_1-rmse:0.85051
# [35]	validation_0-rmse:0.69043	validation_1-rmse:0.84158
# [36]	validation_0-rmse:0.67720	validation_1-rmse:0.83097
# [37]	validation_0-rmse:0.66776	validation_1-rmse:0.82093
# [38]	validation_0-rmse:0.65778	validation_1-rmse:0.81118
# [39]	validation_0-rmse:0.64842	validation_1-rmse:0.80303
# [40]	validation_0-rmse:0.63781	validation_1-rmse:0.79749
# [41]	validation_0-rmse:0.63064	validation_1-rmse:0.79208
# [42]	validation_0-rmse:0.62183	validation_1-rmse:0.78700
# [43]	validation_0-rmse:0.61456	validation_1-rmse:0.78141
# [44]	validation_0-rmse:0.60820	validation_1-rmse:0.77596
# [45]	validation_0-rmse:0.59987	validation_1-rmse:0.76800
# [46]	validation_0-rmse:0.59138	validation_1-rmse:0.76515
# [47]	validation_0-rmse:0.58636	validation_1-rmse:0.76289
# [48]	validation_0-rmse:0.58124	validation_1-rmse:0.75698
# [49]	validation_0-rmse:0.57439	validation_1-rmse:0.74913
# [50]	validation_0-rmse:0.57107	validation_1-rmse:0.74991
# [51]	validation_0-rmse:0.56480	validation_1-rmse:0.75091
# [52]	validation_0-rmse:0.55815	validation_1-rmse:0.74959
# [53]	validation_0-rmse:0.55652	validation_1-rmse:0.75033
# [0]	validation_0-rmse:2.03763	validation_1-rmse:2.16832
# [1]	validation_0-rmse:1.94611	validation_1-rmse:2.07849
# [2]	validation_0-rmse:1.85892	validation_1-rmse:1.99185
# [3]	validation_0-rmse:1.77898	validation_1-rmse:1.91387
# [4]	validation_0-rmse:1.70118	validation_1-rmse:1.83883
# [5]	validation_0-rmse:1.63373	validation_1-rmse:1.77197
# [6]	validation_0-rmse:1.56783	validation_1-rmse:1.70880
# [7]	validation_0-rmse:1.50293	validation_1-rmse:1.64465
# [8]	validation_0-rmse:1.44541	validation_1-rmse:1.59593
# [9]	validation_0-rmse:1.39387	validation_1-rmse:1.54287
# [10]	validation_0-rmse:1.33769	validation_1-rmse:1.49172
# [11]	validation_0-rmse:1.28469	validation_1-rmse:1.44332
# [12]	validation_0-rmse:1.23775	validation_1-rmse:1.39585
# [13]	validation_0-rmse:1.18953	validation_1-rmse:1.34728
# [14]	validation_0-rmse:1.14974	validation_1-rmse:1.31179
# [15]	validation_0-rmse:1.11110	validation_1-rmse:1.27386
# [16]	validation_0-rmse:1.07658	validation_1-rmse:1.24275
# [17]	validation_0-rmse:1.04266	validation_1-rmse:1.21245
# [18]	validation_0-rmse:1.01132	validation_1-rmse:1.18887
# [19]	validation_0-rmse:0.98042	validation_1-rmse:1.15700
# [20]	validation_0-rmse:0.95221	validation_1-rmse:1.13045
# [21]	validation_0-rmse:0.92500	validation_1-rmse:1.10583
# [22]	validation_0-rmse:0.90344	validation_1-rmse:1.08514
# [23]	validation_0-rmse:0.87614	validation_1-rmse:1.06421
# [24]	validation_0-rmse:0.85057	validation_1-rmse:1.04315
# [25]	validation_0-rmse:0.83132	validation_1-rmse:1.02203
# [26]	validation_0-rmse:0.81317	validation_1-rmse:1.00731
# [27]	validation_0-rmse:0.79481	validation_1-rmse:0.98846
# [28]	validation_0-rmse:0.77514	validation_1-rmse:0.97660
# [29]	validation_0-rmse:0.76129	validation_1-rmse:0.96414
# [30]	validation_0-rmse:0.74650	validation_1-rmse:0.95584
# [31]	validation_0-rmse:0.73331	validation_1-rmse:0.95219
# [32]	validation_0-rmse:0.71933	validation_1-rmse:0.94519
# [33]	validation_0-rmse:0.70502	validation_1-rmse:0.93931
# ...
# [39]	validation_0-rmse:0.60149	validation_1-rmse:1.03790
# [40]	validation_0-rmse:0.59352	validation_1-rmse:1.03176
# [41]	validation_0-rmse:0.58502	validation_1-rmse:1.02540
# [42]	validation_0-rmse:0.57993	validation_1-rmse:1.02360
# [43]	validation_0-rmse:0.57169	validation_1-rmse:1.02082
# [44]	validation_0-rmse:0.56352	validation_1-rmse:1.02190
# [45]	validation_0-rmse:0.55332	validation_1-rmse:1.01866
# [46]	validation_0-rmse:0.54676	validation_1-rmse:1.01451
# [47]	validation_0-rmse:0.53993	validation_1-rmse:1.00871
# [40]	validation_0-rmse:0.60454	validation_1-rmse:0.95744
# [41]	validation_0-rmse:0.59909	validation_1-rmse:0.95257
# [42]	validation_0-rmse:0.59088	validation_1-rmse:0.94914
# [43]	validation_0-rmse:0.58306	validation_1-rmse:0.94080
# [44]	validation_0-rmse:0.57541	validation_1-rmse:0.93913
# [45]	validation_0-rmse:0.56886	validation_1-rmse:0.93612
# [46]	validation_0-rmse:0.56315	validation_1-rmse:0.93360
# [47]	validation_0-rmse:0.55752	validation_1-rmse:0.92661
# [48]	validation_0-rmse:0.55373	validation_1-rmse:0.92314
# [49]	validation_0-rmse:0.54838	validation_1-rmse:0.92287
# [50]	validation_0-rmse:0.54462	validation_1-rmse:0.92020
# [51]	validation_0-rmse:0.54020	validation_1-rmse:0.91958
# [52]	validation_0-rmse:0.53430	validation_1-rmse:0.91758
# [53]	validation_0-rmse:0.53052	validation_1-rmse:0.91675
# [0]	validation_0-rmse:2.07433	validation_1-rmse:2.03725
# [1]	validation_0-rmse:1.98132	validation_1-rmse:1.93529
# [2]	validation_0-rmse:1.89262	validation_1-rmse:1.85613
# [3]	validation_0-rmse:1.80914	validation_1-rmse:1.76586
# [4]	validation_0-rmse:1.72796	validation_1-rmse:1.69123
# [5]	validation_0-rmse:1.65489	validation_1-rmse:1.62400
# [6]	validation_0-rmse:1.58961	validation_1-rmse:1.56269
# [7]	validation_0-rmse:1.52608	validation_1-rmse:1.50433
# [8]	validation_0-rmse:1.46644	validation_1-rmse:1.44710
# [9]	validation_0-rmse:1.40955	validation_1-rmse:1.39534
# [10]	validation_0-rmse:1.35851	validation_1-rmse:1.34193
# [11]	validation_0-rmse:1.30835	validation_1-rmse:1.29209
# [12]	validation_0-rmse:1.25637	validation_1-rmse:1.23702
# [13]	validation_0-rmse:1.21046	validation_1-rmse:1.18826
# [14]	validation_0-rmse:1.16750	validation_1-rmse:1.15272
# [15]	validation_0-rmse:1.12628	validation_1-rmse:1.10990
# [16]	validation_0-rmse:1.08576	validation_1-rmse:1.07296
# [17]	validation_0-rmse:1.05483	validation_1-rmse:1.04201
# [18]	validation_0-rmse:1.02247	validation_1-rmse:1.01296
# [19]	validation_0-rmse:0.98948	validation_1-rmse:0.98130
# [20]	validation_0-rmse:0.95857	validation_1-rmse:0.95232
# [21]	validation_0-rmse:0.92945	validation_1-rmse:0.93066
# [22]	validation_0-rmse:0.90296	validation_1-rmse:0.91913
# [23]	validation_0-rmse:0.87916	validation_1-rmse:0.89690
# [24]	validation_0-rmse:0.85537	validation_1-rmse:0.88074
# [25]	validation_0-rmse:0.83365	validation_1-rmse:0.86404
# [26]	validation_0-rmse:0.81288	validation_1-rmse:0.85138
# [27]	validation_0-rmse:0.79265	validation_1-rmse:0.83548
# [28]	validation_0-rmse:0.77388	validation_1-rmse:0.82570
# [29]	validation_0-rmse:0.75582	validation_1-rmse:0.81114
# [30]	validation_0-rmse:0.74104	validation_1-rmse:0.80058
# [31]	validation_0-rmse:0.72699	validation_1-rmse:0.79411
# [32]	validation_0-rmse:0.71326	validation_1-rmse:0.78834
# [33]	validation_0-rmse:0.70113	validation_1-rmse:0.78752
# [34]	validation_0-rmse:0.68866	validation_1-rmse:0.78676
# [35]	validation_0-rmse:0.67710	validation_1-rmse:0.78146
# [36]	validation_0-rmse:0.66537	validation_1-rmse:0.77674
# [37]	validation_0-rmse:0.65552	validation_1-rmse:0.77850
# [38]	validation_0-rmse:0.64658	validation_1-rmse:0.77734
# [39]	validation_0-rmse:0.63724	validation_1-rmse:0.77170
# [40]	validation_0-rmse:0.62634	validation_1-rmse:0.77039
# [41]	validation_0-rmse:0.61850	validation_1-rmse:0.76685
# [42]	validation_0-rmse:0.61057	validation_1-rmse:0.77233
# [43]	validation_0-rmse:0.60325	validation_1-rmse:0.76992
# [44]	validation_0-rmse:0.59802	validation_1-rmse:0.76875
# [45]	validation_0-rmse:0.59061	validation_1-rmse:0.76784
# [46]	validation_0-rmse:0.58443	validation_1-rmse:0.76319
# [47]	validation_0-rmse:0.57820	validation_1-rmse:0.76233
# [48]	validation_0-rmse:0.57253	validation_1-rmse:0.76054
# [49]	validation_0-rmse:0.56460	validation_1-rmse:0.76562
# [50]	validation_0-rmse:0.56010	validation_1-rmse:0.76450
# [51]	validation_0-rmse:0.55458	validation_1-rmse:0.76467
# [52]	validation_0-rmse:0.55105	validation_1-rmse:0.76231
# [53]	validation_0-rmse:0.54749	validation_1-rmse:0.76182
# [0]	validation_0-rmse:2.12980	validation_1-rmse:1.76708
# [1]	validation_0-rmse:2.03069	validation_1-rmse:1.68789
# [2]	validation_0-rmse:1.94111	validation_1-rmse:1.61259
# [3]	validation_0-rmse:1.85415	validation_1-rmse:1.54327
# [4]	validation_0-rmse:1.76959	validation_1-rmse:1.47271
# [5]	validation_0-rmse:1.69022	validation_1-rmse:1.41095
# [6]	validation_0-rmse:1.61504	validation_1-rmse:1.35485
# [7]	validation_0-rmse:1.54695	validation_1-rmse:1.30549
# [8]	validation_0-rmse:1.48214	validation_1-rmse:1.25762
# [9]	validation_0-rmse:1.42031	validation_1-rmse:1.21670
# [10]	validation_0-rmse:1.36390	validation_1-rmse:1.17944
# [11]	validation_0-rmse:1.30806	validation_1-rmse:1.14440
# [12]	validation_0-rmse:1.25429	validation_1-rmse:1.11486
# [13]	validation_0-rmse:1.20345	validation_1-rmse:1.08442
# [14]	validation_0-rmse:1.16021	validation_1-rmse:1.06293
# [15]	validation_0-rmse:1.12205	validation_1-rmse:1.04062
# [16]	validation_0-rmse:1.08224	validation_1-rmse:1.02091
# [17]	validation_0-rmse:1.04444	validation_1-rmse:1.00424
# [18]	validation_0-rmse:1.01055	validation_1-rmse:0.99158
# [19]	validation_0-rmse:0.97882	validation_1-rmse:0.98617
# [20]	validation_0-rmse:0.94648	validation_1-rmse:0.96826
# [21]	validation_0-rmse:0.91364	validation_1-rmse:0.96129
# [22]	validation_0-rmse:0.88217	validation_1-rmse:0.95644
# [23]	validation_0-rmse:0.86006	validation_1-rmse:0.94984
# [24]	validation_0-rmse:0.83572	validation_1-rmse:0.94675
# [25]	validation_0-rmse:0.81232	validation_1-rmse:0.94226
# [26]	validation_0-rmse:0.79251	validation_1-rmse:0.94202
# [27]	validation_0-rmse:0.77463	validation_1-rmse:0.93489
# [28]	validation_0-rmse:0.75274	validation_1-rmse:0.93331
# [29]	validation_0-rmse:0.73531	validation_1-rmse:0.92934
# [30]	validation_0-rmse:0.72062	validation_1-rmse:0.93178
# [31]	validation_0-rmse:0.70249	validation_1-rmse:0.93820
# [32]	validation_0-rmse:0.68645	validation_1-rmse:0.94238
# [33]	validation_0-rmse:0.67095	validation_1-rmse:0.94973
# [34]	validation_0-rmse:0.65892	validation_1-rmse:0.95312
# [35]	validation_0-rmse:0.64608	validation_1-rmse:0.95010
# [36]	validation_0-rmse:0.63263	validation_1-rmse:0.95535
# [37]	validation_0-rmse:0.62063	validation_1-rmse:0.96117
# [38]	validation_0-rmse:0.60798	validation_1-rmse:0.96812
# [39]	validation_0-rmse:0.59967	validation_1-rmse:0.96470
# [40]	validation_0-rmse:0.58953	validation_1-rmse:0.96873
# [41]	validation_0-rmse:0.58162	validation_1-rmse:0.96919
# [42]	validation_0-rmse:0.57406	validation_1-rmse:0.96882
# [43]	validation_0-rmse:0.56874	validation_1-rmse:0.96975
# [44]	validation_0-rmse:0.56193	validation_1-rmse:0.96968
# [45]	validation_0-rmse:0.55547	validation_1-rmse:0.97602
# [46]	validation_0-rmse:0.54599	validation_1-rmse:0.97411
# [47]	validation_0-rmse:0.54032	validation_1-rmse:0.97403
# [48]	validation_0-rmse:0.53475	validation_1-rmse:0.97715
# [49]	validation_0-rmse:0.53019	validation_1-rmse:0.97657
# [0]	validation_0-rmse:2.04448	validation_1-rmse:2.12748
# [1]	validation_0-rmse:1.95231	validation_1-rmse:2.02706
# [2]	validation_0-rmse:1.86719	validation_1-rmse:1.93915
# [3]	validation_0-rmse:1.79053	validation_1-rmse:1.85171
# [4]	validation_0-rmse:1.71591	validation_1-rmse:1.77676
# [5]	validation_0-rmse:1.64194	validation_1-rmse:1.69910
# [6]	validation_0-rmse:1.57515	validation_1-rmse:1.62982
# [7]	validation_0-rmse:1.51329	validation_1-rmse:1.56422
# [8]	validation_0-rmse:1.45337	validation_1-rmse:1.50219
# [9]	validation_0-rmse:1.39395	validation_1-rmse:1.44123
# [10]	validation_0-rmse:1.34178	validation_1-rmse:1.39000
# [11]	validation_0-rmse:1.29163	validation_1-rmse:1.34163
# [12]	validation_0-rmse:1.24370	validation_1-rmse:1.29018
# [13]	validation_0-rmse:1.19869	validation_1-rmse:1.24242
# [14]	validation_0-rmse:1.15647	validation_1-rmse:1.20588
# [15]	validation_0-rmse:1.11611	validation_1-rmse:1.16409
# [16]	validation_0-rmse:1.08195	validation_1-rmse:1.13453
# [17]	validation_0-rmse:1.05144	validation_1-rmse:1.10377
# [18]	validation_0-rmse:1.02147	validation_1-rmse:1.08096
# [19]	validation_0-rmse:0.99233	validation_1-rmse:1.05272
# [20]	validation_0-rmse:0.96558	validation_1-rmse:1.02245
# [21]	validation_0-rmse:0.94204	validation_1-rmse:1.00551
# [22]	validation_0-rmse:0.91468	validation_1-rmse:0.98402
# [23]	validation_0-rmse:0.89191	validation_1-rmse:0.96975
# [24]	validation_0-rmse:0.86665	validation_1-rmse:0.95018
# [25]	validation_0-rmse:0.84746	validation_1-rmse:0.93088
# [26]	validation_0-rmse:0.82801	validation_1-rmse:0.91475
# [27]	validation_0-rmse:0.81150	validation_1-rmse:0.90009
# [28]	validation_0-rmse:0.79276	validation_1-rmse:0.88728
# [29]	validation_0-rmse:0.77608	validation_1-rmse:0.87277
# [30]	validation_0-rmse:0.76016	validation_1-rmse:0.86372
# [31]	validation_0-rmse:0.74425	validation_1-rmse:0.85673
# [32]	validation_0-rmse:0.72969	validation_1-rmse:0.85388
# [33]	validation_0-rmse:0.71832	validation_1-rmse:0.85406
# [34]	validation_0-rmse:0.70734	validation_1-rmse:0.85035
# [35]	validation_0-rmse:0.69646	validation_1-rmse:0.83979
# [36]	validation_0-rmse:0.68569	validation_1-rmse:0.83395
# [37]	validation_0-rmse:0.67695	validation_1-rmse:0.82927
# [38]	validation_0-rmse:0.66716	validation_1-rmse:0.82775
# [39]	validation_0-rmse:0.65910	validation_1-rmse:0.82135
# [40]	validation_0-rmse:0.65092	validation_1-rmse:0.82166
# [41]	validation_0-rmse:0.64348	validation_1-rmse:0.81324
# [42]	validation_0-rmse:0.63389	validation_1-rmse:0.81317
# [43]	validation_0-rmse:0.62651	validation_1-rmse:0.80932
# [44]	validation_0-rmse:0.61788	validation_1-rmse:0.80243
# [45]	validation_0-rmse:0.61156	validation_1-rmse:0.80267
# [46]	validation_0-rmse:0.60366	validation_1-rmse:0.80016
# [47]	validation_0-rmse:0.59858	validation_1-rmse:0.79815
# [48]	validation_0-rmse:0.59300	validation_1-rmse:0.79533
# [49]	validation_0-rmse:0.58700	validation_1-rmse:0.80004
# [50]	validation_0-rmse:0.58153	validation_1-rmse:0.79799
# [51]	validation_0-rmse:0.57602	validation_1-rmse:0.80199
# [52]	validation_0-rmse:0.57140	validation_1-rmse:0.80401
# [53]	validation_0-rmse:0.56674	validation_1-rmse:0.80622
# [0]	validation_0-rmse:2.06496	validation_1-rmse:2.05945
# [1]	validation_0-rmse:1.97008	validation_1-rmse:1.96332
# [2]	validation_0-rmse:1.88098	validation_1-rmse:1.88363
# [3]	validation_0-rmse:1.80358	validation_1-rmse:1.80748
# [4]	validation_0-rmse:1.72968	validation_1-rmse:1.73803
# [5]	validation_0-rmse:1.66199	validation_1-rmse:1.69202
# [6]	validation_0-rmse:1.59241	validation_1-rmse:1.62408
# [7]	validation_0-rmse:1.52733	validation_1-rmse:1.56072
# [8]	validation_0-rmse:1.46742	validation_1-rmse:1.50481
# [9]	validation_0-rmse:1.41019	validation_1-rmse:1.44920
# [10]	validation_0-rmse:1.35469	validation_1-rmse:1.39872
# [11]	validation_0-rmse:1.31192	validation_1-rmse:1.36154
# [12]	validation_0-rmse:1.26673	validation_1-rmse:1.31592
# [13]	validation_0-rmse:1.22255	validation_1-rmse:1.26998
# [14]	validation_0-rmse:1.18339	validation_1-rmse:1.23942
# [15]	validation_0-rmse:1.14233	validation_1-rmse:1.19835
# [16]	validation_0-rmse:1.10657	validation_1-rmse:1.16117
# [17]	validation_0-rmse:1.07192	validation_1-rmse:1.13939
# [18]	validation_0-rmse:1.04208	validation_1-rmse:1.11368
# [19]	validation_0-rmse:1.01331	validation_1-rmse:1.08445
# [20]	validation_0-rmse:0.98728	validation_1-rmse:1.05696
# [21]	validation_0-rmse:0.95719	validation_1-rmse:1.03514
# [22]	validation_0-rmse:0.93394	validation_1-rmse:1.01618
# [23]	validation_0-rmse:0.90942	validation_1-rmse:0.99773
# [24]	validation_0-rmse:0.88812	validation_1-rmse:0.98312
# [25]	validation_0-rmse:0.86858	validation_1-rmse:0.96351
# [26]	validation_0-rmse:0.84984	validation_1-rmse:0.95794
# [27]	validation_0-rmse:0.82953	validation_1-rmse:0.94039
# [28]	validation_0-rmse:0.80852	validation_1-rmse:0.92208
# [29]	validation_0-rmse:0.79144	validation_1-rmse:0.90640
# [30]	validation_0-rmse:0.77609	validation_1-rmse:0.89790
# [31]	validation_0-rmse:0.75894	validation_1-rmse:0.88812
# [32]	validation_0-rmse:0.74557	validation_1-rmse:0.88124
# [33]	validation_0-rmse:0.73419	validation_1-rmse:0.87417
# [34]	validation_0-rmse:0.72111	validation_1-rmse:0.86822
# [35]	validation_0-rmse:0.71013	validation_1-rmse:0.86083
# [36]	validation_0-rmse:0.69879	validation_1-rmse:0.85434
# [37]	validation_0-rmse:0.68738	validation_1-rmse:0.84768
# [38]	validation_0-rmse:0.67769	validation_1-rmse:0.84435
# [39]	validation_0-rmse:0.66943	validation_1-rmse:0.83518
# [40]	validation_0-rmse:0.65812	validation_1-rmse:0.83403
# [41]	validation_0-rmse:0.64961	validation_1-rmse:0.82710
# [42]	validation_0-rmse:0.63808	validation_1-rmse:0.82698
# [43]	validation_0-rmse:0.63441	validation_1-rmse:0.82393
# [44]	validation_0-rmse:0.62632	validation_1-rmse:0.81503
# [45]	validation_0-rmse:0.62067	validation_1-rmse:0.81306
# [46]	validation_0-rmse:0.61442	validation_1-rmse:0.81219
# [47]	validation_0-rmse:0.60928	validation_1-rmse:0.80992
# [48]	validation_0-rmse:0.60376	validation_1-rmse:0.80624
# [49]	validation_0-rmse:0.59849	validation_1-rmse:0.80288
# [50]	validation_0-rmse:0.59263	validation_1-rmse:0.79906
# [51]	validation_0-rmse:0.58573	validation_1-rmse:0.79405
# [52]	validation_0-rmse:0.57947	validation_1-rmse:0.79037
# [53]	validation_0-rmse:0.57444	validation_1-rmse:0.78722

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(0.4, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.258
# Uncertainty
# a0: 1.711+/-0.102
# a1: 0.239+/-0.038

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: contr_b_MAX: mean - 0.144, median - 0.147, CI - [0.126-0.161]
#
# SHAP-values for: contr_b_STD: mean - 0.088, median - 0.088, CI - [0.075-0.1]
#
# SHAP-values for: mf_chm_MIN: mean - 0.086, median - 0.088, CI - [0.073-0.099]
#
# SHAP-values for: r_MIN: mean - 0.202, median - 0.205, CI - [0.182-0.226]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['r_MIN', 'contr_b_MAX', 'contr_b_STD', 'mf_chm_MIN'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 48.94, median: 52.0,
#  pred. interval (P(0.025)-P(0.975)): 30.0-53.0,
#  conf. interval (p-value=0.95): 43.872-52.903
# ***
# Aggregate bias statistic:
#  mean: -0.156, median: -0.132,
#  pred. interval (P(0.025)-P(0.975)): -0.452-0.097,
#  conf. interval (p-value=0.95): -0.307--0.018
# ***
# Aggregate RMSE statistic:
#  mean: 0.795, median: 0.79, pred. interval (P(0.025)-P(0.975)): 0.599-1.014,
#  conf. interval (p-value=0.95): 0.695-0.884
# ***
# Aggregate MSE statistic:
#  mean: 0.642, median: 0.624, pred. interval (P(0.025)-P(0.975)): 0.359-1.028,
#  conf. interval (p-value=0.95): 0.484-0.783
# ***
# Aggregate R^2 statistic:
#  mean: 0.182, median: 0.221, pred. interval (P(0.025)-P(0.975)): -0.233-0.44,
#  conf. interval (p-value=0.95): 0.033-0.328
# ***
# Aggregate bias(%) statistic:
#  mean: -6.014, median: -5.458, pred. interval (P(0.025)-P(0.975)): -16.727-4.7,
#  conf. interval (p-value=0.95): -11.775--0.768
# ***
# Aggregate RMSE(%) statistic:
#  mean: 32.473, median: 32.384, pred. interval (P(0.025)-P(0.975)): 24.822-41.041,
#  conf. interval (p-value=0.95): 28.567-36.25
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -6.105, median: -5.602,
#  pred. interval (P(0.025)-P(0.975)): -12.013--1.98,
#  conf. interval (p-value=0.95): -8.71--3.377
# ***
# Aggregate RMSE statistic:
#  mean: 14.989, median: 13.646, pred. interval (P(0.025)-P(0.975)): 7.613-25.4,
#  conf. interval (p-value=0.95): 9.821-21.399
# ***
# Aggregate MSE statistic:
#  mean: 254.676, median: 186.232, pred. interval (P(0.025)-P(0.975)): 57.957-645.159,
#  conf. interval (p-value=0.95): 98.025-464.375
# ***
# Aggregate R^2 statistic:
#  mean: -0.057, median: -0.018, pred. interval (P(0.025)-P(0.975)): -0.464-0.203,
#  conf. interval (p-value=0.95): -0.186-0.08
# ***
# Aggregate bias(%) statistic:
#  mean: -34.413, median: -34.222, pred. interval (P(0.025)-P(0.975)): -54.783--14.585,
#  conf. interval (p-value=0.95): -44.84--23.186
# ***
# Aggregate RMSE(%) statistic:
#  mean: 86.463, median: 84.215, pred. interval (P(0.025)-P(0.975)): 56.219-125.382,
#  conf. interval (p-value=0.95): 67.807-108.645
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [0, 1, 2, 3, 4, 5])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 1, 5, 10, 20, 40, 100])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:2.06441
# [1]	validation_0-rmse:1.96987
# [2]	validation_0-rmse:1.87720
# [3]	validation_0-rmse:1.80007
# [4]	validation_0-rmse:1.72290
# [5]	validation_0-rmse:1.65092
# [6]	validation_0-rmse:1.58323
# [7]	validation_0-rmse:1.52042
# [8]	validation_0-rmse:1.46072
# [9]	validation_0-rmse:1.40166
# [10]	validation_0-rmse:1.35047
# [11]	validation_0-rmse:1.30220
# [12]	validation_0-rmse:1.25699
# [13]	validation_0-rmse:1.21542
# [14]	validation_0-rmse:1.17382
# [15]	validation_0-rmse:1.13275
# [16]	validation_0-rmse:1.09453
# [17]	validation_0-rmse:1.06480
# [18]	validation_0-rmse:1.03335
# [19]	validation_0-rmse:1.00127
# [20]	validation_0-rmse:0.97069
# [21]	validation_0-rmse:0.94666
# [22]	validation_0-rmse:0.92098
# [23]	validation_0-rmse:0.90086
# [24]	validation_0-rmse:0.87965
# [25]	validation_0-rmse:0.85960
# [26]	validation_0-rmse:0.83974
# [27]	validation_0-rmse:0.82238
# [28]	validation_0-rmse:0.80654
# [29]	validation_0-rmse:0.79326
# [30]	validation_0-rmse:0.77681
# [31]	validation_0-rmse:0.76329
# [32]	validation_0-rmse:0.75062
# [33]	validation_0-rmse:0.73595
# [34]	validation_0-rmse:0.72226
# [35]	validation_0-rmse:0.71026
# [36]	validation_0-rmse:0.70280
# [37]	validation_0-rmse:0.69116
# [38]	validation_0-rmse:0.67740
# [39]	validation_0-rmse:0.66760
# [40]	validation_0-rmse:0.65657
# [41]	validation_0-rmse:0.64833
# [42]	validation_0-rmse:0.64136
# [43]	validation_0-rmse:0.63541
# [44]	validation_0-rmse:0.62867
# [45]	validation_0-rmse:0.62103
# [46]	validation_0-rmse:0.61257
# [47]	validation_0-rmse:0.60838
# [48]	validation_0-rmse:0.60183
# [49]	validation_0-rmse:0.59486
# [50]	validation_0-rmse:0.58757
# [51]	validation_0-rmse:0.58368
# [52]	validation_0-rmse:0.57925
# [53]	validation_0-rmse:0.57328

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 53

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.1
# Relative bias(%):  -5.17
# RMSE: 0.6
# Relative RMSE(%):  23.260
# MSE: 0.3
# R square: 59.5%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0.4, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.705
# Uncertainty
# a0: 1.22+/-0.08
# a1: 0.452+/-0.029

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/08_LN_Tag_Sr_vs_CHM_RGB_XGB_model_2024_final.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/08_LN_Tag_Sr_vs_CHM_RGB_XGB_model_2024_final.txt")
