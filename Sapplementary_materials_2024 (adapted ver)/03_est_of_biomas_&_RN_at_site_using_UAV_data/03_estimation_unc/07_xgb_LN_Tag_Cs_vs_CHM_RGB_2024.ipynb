# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN'])
            
# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           2260           1210     -0.731      2.576
# 1       8.189       9.622           2700           1180      0.585      2.915
# 2       8.380       9.589           2500           1400      0.779      2.882
# 3       8.137       9.449           2500           1090      0.517      2.724
# 4       7.696       9.401           2400            720      0.224      2.826
#
#    AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  \
# 0       2.33    0.445070     13  35.145074   360.273487    0.488754
# 1       2.47   12.465903     24  36.135511   323.958625    0.501683
# 2       2.44   13.028298     18  35.938764   299.438354    0.540056
# 3       2.55    2.128231     15  35.908361   319.773395    0.480991
# 4       2.14   12.171553      8  38.062522   353.104284    0.505257
#
#    corr_r_MIN
# 0    0.072792
# 1    0.098347
# 2    0.187811
# 3    0.020686
# 4    0.106549

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   mf_chm_MIN     103 non-null    float64
#  8   r_MIN          103 non-null    int64
#  9   b_STD          103 non-null    float64
#  10  contr_r_STD    103 non-null    float64
#  11  corr_r_Q25     103 non-null    float64
#  12  corr_r_MIN     103 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 10.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Cs_wood", "ln_Sr_wood"].describe()
# Out:
#                  ln_Cs_wood                                                 \
#                       count       mean       std     min      25%      50%
# Dominant_specias
# Alder                   4.0   7.305000  1.427622   5.886   6.6765   7.0235
# Aspen                   1.0  11.367000       NaN  11.367  11.3670  11.3670
# Birch                  23.0   7.304652  1.533182   4.533   6.3365   7.2150
# Oak                     3.0   7.430333  1.260072   6.040   6.8970   7.7540
# Pine                   71.0   6.901690  1.650166   3.526   6.3790   6.9470
# Spruce                  1.0   5.176000       NaN   5.176   5.1760   5.1760
#
#                                   ln_Sr_wood                               \
#                       75%     max      count       mean       std     min
# Dominant_specias
# Alder              7.6520   9.287        4.0   7.206000  0.650057   6.265
# Aspen             11.3670  11.367        1.0  11.090000       NaN  11.090
# Birch              8.0320  10.332       23.0   9.345478  1.626360   7.139
# Oak                8.1255   8.497        3.0   7.483667  0.815040   6.565
# Pine               7.6960  10.469       71.0   8.542592  1.359020   6.075
# Spruce             5.1760   5.176        1.0   7.783000       NaN   7.783
#
#
#                       25%      50%      75%     max
# Dominant_specias
# Alder              7.0255   7.4545   7.6350   7.650
# Aspen             11.0900  11.0900  11.0900  11.090
# Birch              8.4000   8.9910   9.9365  13.864
# Oak                7.1655   7.7660   7.9430   8.120
# Pine               7.6450   8.4720   9.3710  12.687
# Spruce             7.7830   7.7830   7.7830   7.783

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3440.194175    1242.902913   -0.252563
# std       1.64946    1.472424    6087.580089    2037.684800    1.104610
# min       3.52600    6.075000     260.000000      50.000000   -3.033000
# 25%       6.31900    7.664000     635.000000     200.000000   -0.727500
# 50%       6.95700    8.472000    1150.000000     400.000000   -0.025000
# 75%       7.91350    9.421000    2525.000000    1400.000000    0.516500
# max      11.36700   13.864000   35200.000000   10500.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean  mf_chm_MIN       r_MIN       b_STD  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     2.464709    3.570291    3.368496   11.378641   35.164575
# std      0.904675    6.089170    4.845054    9.139568    5.338700
# min      0.391000    0.480000   -0.018586    2.000000   20.570709
# 25%      1.803000    0.710000    0.482279    5.000000   31.746440
# 50%      2.603000    1.290000    0.642883    8.000000   36.135511
# 75%      3.159000    2.960000    3.921804   15.000000   39.139044
# max      4.659000   36.590000   17.862923   56.000000   45.825416
#
#        contr_r_STD  corr_r_Q25  corr_r_MIN
# count   103.000000  103.000000  103.000000
# mean    327.115078    0.393571    0.073579
# std     167.617957    0.151801    0.056017
# min       0.091058    0.033797   -0.062450
# 25%     283.887328    0.407228    0.027204
# 50%     353.034542    0.449670    0.063714
# 75%     448.017711    0.476635    0.110983
# max     652.546648    0.555648    0.241284

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_Tag_Cs"
indep_variables = ['mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  \
# 0         6.824       9.240           2260           1210     -0.731
# 1         8.189       9.622           2700           1180      0.585
# 2         8.380       9.589           2500           1400      0.779
# 3         8.137       9.449           2500           1090      0.517
# 4         7.696       9.401           2400            720      0.224
# ..          ...         ...            ...            ...        ...
# 98        8.071       8.434           2500           1300      0.228
# 99        7.993      10.042           2300           1100      0.266
# 100       8.343      10.488           2400           1200      0.543
# 101       3.638       6.399            630            270     -2.811
# 102       4.787       6.877            680            290     -1.728
#
#      ln_Tag_Sr  AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  \
# 0        2.576       2.33    0.445070     13  35.145074   360.273487
# 1        2.915       2.47   12.465903     24  36.135511   323.958625
# 2        2.882       2.44   13.028298     18  35.938764   299.438354
# 3        2.724       2.55    2.128231     15  35.908361   319.773395
# 4        2.826       2.14   12.171553      8  38.062522   353.104284
# ..         ...        ...         ...    ...        ...          ...
# 98       1.514       2.92    0.528681      3  32.852994   329.221211
# 99       3.230       2.78    0.422647     18  27.970146   268.895699
# 100      3.606       2.92    0.426717     19  30.529613   251.314791
# 101      0.805       0.75    0.476680      6  37.245047   477.751734
# 102      1.199       0.78    0.410141      2  38.454424   412.535053
#
#      corr_r_Q25  corr_r_MIN
# 0      0.488754    0.072792
# 1      0.501683    0.098347
# 2      0.540056    0.187811
# 3      0.480991    0.020686
# 4      0.505257    0.106549
# ..          ...         ...
# 98     0.478581    0.079646
# 99     0.467111    0.063714
# 100    0.501777    0.128376
# 101    0.467443    0.129664
# 102    0.480964    0.157460
#
# [103 rows x 13 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  corr_r_MIN
# 0    0.445070     13  35.145074   360.273487    0.488754    0.072792
# 1   12.465903     24  36.135511   323.958625    0.501683    0.098347
# 2   13.028298     18  35.938764   299.438354    0.540056    0.187811
# 3    2.128231     15  35.908361   319.773395    0.480991    0.020686
# 4   12.171553      8  38.062522   353.104284    0.505257    0.106549

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Tag_Cs
# 0     -0.731
# 1      0.585
# 2      0.779
# 3      0.517
# 4      0.224

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [-0.2288635857581902, -1.3002091008391, -0.03901855700636392]
#     Mean: -0.523
#     Std: 0.555
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.25158654 0.93206275 1.37963611]
#     Mean: 1.188
#     Std: 0.188
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.7994726860267775, 1.0258272923213594, 0.6640075898773091]
#     Mean: 0.830
#     Std: 0.149
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
Colsample_bytree: 0.39405284878753544
Gamma: 0.08982585259453796
Learning_rate: 0.01673675109531391
Max_depth: 3
N_estimators: 86
Subsample: 0.48506589187163573

# Hyperparameters data for the next step/stage
p1 = 0.39405284878753544                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.08982585259453796                  # gamma
print('Gamma: ' + str(p2))

p3 = 0.01673675109531391                  # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 3                                    # max_depth
print('Max_depth: ' + str(p4))

p5 = 86                                   # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.48506589187163573                   # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.39405284878753544
# Gamma: 0.08982585259453796
# Learning_rate: 0.01673675109531391
# Max_depth: 3
# N_estimators: 86
# Subsample: 0.48506589187163573

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=10, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.41625	validation_1-rmse:0.83548
# [1]	validation_0-rmse:1.40321	validation_1-rmse:0.83251
# [2]	validation_0-rmse:1.39409	validation_1-rmse:0.83252
# [3]	validation_0-rmse:1.38254	validation_1-rmse:0.83135
# [4]	validation_0-rmse:1.36850	validation_1-rmse:0.82918
# [5]	validation_0-rmse:1.35957	validation_1-rmse:0.82922
# [6]	validation_0-rmse:1.34606	validation_1-rmse:0.82934
# [7]	validation_0-rmse:1.33330	validation_1-rmse:0.82375
# [8]	validation_0-rmse:1.32061	validation_1-rmse:0.82019
# [9]	validation_0-rmse:1.31020	validation_1-rmse:0.81717
# [10]	validation_0-rmse:1.30107	validation_1-rmse:0.81290
# [11]	validation_0-rmse:1.29215	validation_1-rmse:0.81318
# [12]	validation_0-rmse:1.28154	validation_1-rmse:0.81129
# [13]	validation_0-rmse:1.27190	validation_1-rmse:0.81119
# [14]	validation_0-rmse:1.25866	validation_1-rmse:0.80967
# [15]	validation_0-rmse:1.24866	validation_1-rmse:0.80857
# [16]	validation_0-rmse:1.24361	validation_1-rmse:0.80831
# [17]	validation_0-rmse:1.23243	validation_1-rmse:0.80574
# [18]	validation_0-rmse:1.22255	validation_1-rmse:0.80344
# [19]	validation_0-rmse:1.21500	validation_1-rmse:0.80347
# [20]	validation_0-rmse:1.20245	validation_1-rmse:0.80566
# [21]	validation_0-rmse:1.19618	validation_1-rmse:0.80390
# [22]	validation_0-rmse:1.18955	validation_1-rmse:0.80068
# [23]	validation_0-rmse:1.18104	validation_1-rmse:0.80260
# [24]	validation_0-rmse:1.17211	validation_1-rmse:0.80048
# [25]	validation_0-rmse:1.16399	validation_1-rmse:0.80087
# [26]	validation_0-rmse:1.15743	validation_1-rmse:0.79985
# [27]	validation_0-rmse:1.14836	validation_1-rmse:0.80198
# [28]	validation_0-rmse:1.13939	validation_1-rmse:0.80232
# [29]	validation_0-rmse:1.13217	validation_1-rmse:0.80272
# [30]	validation_0-rmse:1.12388	validation_1-rmse:0.80133
# [31]	validation_0-rmse:1.11404	validation_1-rmse:0.79982
# [32]	validation_0-rmse:1.10741	validation_1-rmse:0.79845
# [33]	validation_0-rmse:1.09700	validation_1-rmse:0.79950
# [34]	validation_0-rmse:1.09104	validation_1-rmse:0.80157
# [35]	validation_0-rmse:1.08371	validation_1-rmse:0.80304
# [36]	validation_0-rmse:1.07673	validation_1-rmse:0.80317
# [37]	validation_0-rmse:1.06892	validation_1-rmse:0.80134
# [38]	validation_0-rmse:1.06036	validation_1-rmse:0.79944
# [39]	validation_0-rmse:1.05412	validation_1-rmse:0.80299
# [40]	validation_0-rmse:1.04642	validation_1-rmse:0.80204
# [41]	validation_0-rmse:1.04112	validation_1-rmse:0.80218
# [0]	validation_0-rmse:1.36712	validation_1-rmse:1.11292
# [1]	validation_0-rmse:1.35576	validation_1-rmse:1.10834
# [2]	validation_0-rmse:1.34703	validation_1-rmse:1.09980
# [3]	validation_0-rmse:1.33708	validation_1-rmse:1.09074
# [4]	validation_0-rmse:1.32523	validation_1-rmse:1.08300
# [5]	validation_0-rmse:1.31636	validation_1-rmse:1.07538
# [6]	validation_0-rmse:1.30532	validation_1-rmse:1.06938
# [7]	validation_0-rmse:1.29321	validation_1-rmse:1.06167
# [8]	validation_0-rmse:1.28270	validation_1-rmse:1.05188
# [9]	validation_0-rmse:1.27237	validation_1-rmse:1.04211
# [10]	validation_0-rmse:1.26498	validation_1-rmse:1.03593
# [11]	validation_0-rmse:1.25479	validation_1-rmse:1.03313
# [12]	validation_0-rmse:1.24500	validation_1-rmse:1.02731
# [13]	validation_0-rmse:1.23669	validation_1-rmse:1.02329
# [14]	validation_0-rmse:1.22498	validation_1-rmse:1.02245
# [15]	validation_0-rmse:1.21592	validation_1-rmse:1.01818
# [16]	validation_0-rmse:1.20565	validation_1-rmse:1.01634
# [17]	validation_0-rmse:1.19599	validation_1-rmse:1.00880
# [18]	validation_0-rmse:1.18372	validation_1-rmse:1.00391
# [19]	validation_0-rmse:1.17503	validation_1-rmse:0.99793
# [20]	validation_0-rmse:1.16682	validation_1-rmse:0.99384
# [21]	validation_0-rmse:1.15917	validation_1-rmse:0.98857
# [22]	validation_0-rmse:1.15355	validation_1-rmse:0.98547
# [23]	validation_0-rmse:1.14676	validation_1-rmse:0.98255
# [24]	validation_0-rmse:1.13865	validation_1-rmse:0.97963
# [25]	validation_0-rmse:1.13331	validation_1-rmse:0.97633
# [26]	validation_0-rmse:1.12958	validation_1-rmse:0.97200
# [27]	validation_0-rmse:1.11918	validation_1-rmse:0.96849
# [28]	validation_0-rmse:1.11001	validation_1-rmse:0.96259
# [29]	validation_0-rmse:1.10105	validation_1-rmse:0.96064
# [30]	validation_0-rmse:1.09071	validation_1-rmse:0.95264
# [31]	validation_0-rmse:1.08298	validation_1-rmse:0.94789
# [32]	validation_0-rmse:1.07621	validation_1-rmse:0.94783
# [33]	validation_0-rmse:1.06679	validation_1-rmse:0.94531
# [34]	validation_0-rmse:1.06021	validation_1-rmse:0.93753
# [35]	validation_0-rmse:1.05641	validation_1-rmse:0.93537
# [36]	validation_0-rmse:1.05040	validation_1-rmse:0.93507
# [37]	validation_0-rmse:1.04127	validation_1-rmse:0.93556
# [38]	validation_0-rmse:1.03440	validation_1-rmse:0.93154
# [39]	validation_0-rmse:1.02808	validation_1-rmse:0.92994
# [40]	validation_0-rmse:1.02220	validation_1-rmse:0.92517
# [41]	validation_0-rmse:1.01494	validation_1-rmse:0.92491
# [42]	validation_0-rmse:1.00788	validation_1-rmse:0.92100
# [43]	validation_0-rmse:1.00101	validation_1-rmse:0.91214
# [44]	validation_0-rmse:0.99546	validation_1-rmse:0.90723
# [45]	validation_0-rmse:0.98997	validation_1-rmse:0.90336
# [46]	validation_0-rmse:0.98401	validation_1-rmse:0.90170
# [47]	validation_0-rmse:0.98140	validation_1-rmse:0.90162
# [48]	validation_0-rmse:0.97806	validation_1-rmse:0.90131
# [49]	validation_0-rmse:0.97330	validation_1-rmse:0.90068
# [50]	validation_0-rmse:0.96936	validation_1-rmse:0.89846
# [51]	validation_0-rmse:0.96343	validation_1-rmse:0.89445
# [52]	validation_0-rmse:0.95831	validation_1-rmse:0.89149
# [53]	validation_0-rmse:0.95208	validation_1-rmse:0.88823
# [54]	validation_0-rmse:0.94626	validation_1-rmse:0.88560
# [55]	validation_0-rmse:0.94062	validation_1-rmse:0.88317
# [56]	validation_0-rmse:0.93718	validation_1-rmse:0.88293
# [57]	validation_0-rmse:0.93040	validation_1-rmse:0.87924
# [58]	validation_0-rmse:0.92585	validation_1-rmse:0.87399
# [59]	validation_0-rmse:0.92031	validation_1-rmse:0.87429
# [60]	validation_0-rmse:0.91702	validation_1-rmse:0.87312
# [61]	validation_0-rmse:0.91142	validation_1-rmse:0.87233
# [62]	validation_0-rmse:0.90660	validation_1-rmse:0.86931
# [63]	validation_0-rmse:0.90214	validation_1-rmse:0.86954
# [64]	validation_0-rmse:0.89740	validation_1-rmse:0.86500
# [65]	validation_0-rmse:0.89458	validation_1-rmse:0.86261
# [66]	validation_0-rmse:0.89036	validation_1-rmse:0.85898
# [67]	validation_0-rmse:0.88528	validation_1-rmse:0.85570
# [68]	validation_0-rmse:0.88056	validation_1-rmse:0.85133
# [69]	validation_0-rmse:0.87693	validation_1-rmse:0.85178
# [70]	validation_0-rmse:0.87405	validation_1-rmse:0.85193
# [71]	validation_0-rmse:0.87078	validation_1-rmse:0.85181
# [72]	validation_0-rmse:0.86678	validation_1-rmse:0.85175
# [73]	validation_0-rmse:0.86200	validation_1-rmse:0.84685
# [74]	validation_0-rmse:0.85700	validation_1-rmse:0.84395
# [75]	validation_0-rmse:0.85357	validation_1-rmse:0.84348
# [76]	validation_0-rmse:0.84957	validation_1-rmse:0.84348
# [77]	validation_0-rmse:0.84458	validation_1-rmse:0.84042
# [78]	validation_0-rmse:0.84015	validation_1-rmse:0.84211
# [79]	validation_0-rmse:0.83518	validation_1-rmse:0.84388
# [80]	validation_0-rmse:0.83236	validation_1-rmse:0.84520
# [81]	validation_0-rmse:0.83008	validation_1-rmse:0.84645
# [82]	validation_0-rmse:0.82805	validation_1-rmse:0.84437
# [83]	validation_0-rmse:0.82270	validation_1-rmse:0.84511
# [84]	validation_0-rmse:0.82036	validation_1-rmse:0.84484
# [85]	validation_0-rmse:0.81707	validation_1-rmse:0.84358
# [0]	validation_0-rmse:1.29596	validation_1-rmse:1.41972
# [1]	validation_0-rmse:1.28707	validation_1-rmse:1.41259
# [2]	validation_0-rmse:1.27705	validation_1-rmse:1.40151
# [3]	validation_0-rmse:1.26636	validation_1-rmse:1.39625
# [4]	validation_0-rmse:1.25928	validation_1-rmse:1.39104
# [5]	validation_0-rmse:1.24759	validation_1-rmse:1.38845
# [6]	validation_0-rmse:1.23822	validation_1-rmse:1.37944
# [7]	validation_0-rmse:1.23408	validation_1-rmse:1.37185
# [8]	validation_0-rmse:1.22384	validation_1-rmse:1.36711
# [9]	validation_0-rmse:1.21523	validation_1-rmse:1.36005
# [10]	validation_0-rmse:1.20575	validation_1-rmse:1.35477
# [11]	validation_0-rmse:1.19528	validation_1-rmse:1.34467
# [12]	validation_0-rmse:1.18337	validation_1-rmse:1.33602
# [13]	validation_0-rmse:1.17538	validation_1-rmse:1.33045
# [14]	validation_0-rmse:1.16659	validation_1-rmse:1.32336
# [15]	validation_0-rmse:1.15655	validation_1-rmse:1.31726
# [16]	validation_0-rmse:1.14689	validation_1-rmse:1.30682
# [17]	validation_0-rmse:1.13800	validation_1-rmse:1.30291
# [18]	validation_0-rmse:1.13091	validation_1-rmse:1.29685
# [19]	validation_0-rmse:1.11845	validation_1-rmse:1.28869
# [20]	validation_0-rmse:1.10996	validation_1-rmse:1.28030
# [21]	validation_0-rmse:1.10556	validation_1-rmse:1.27746
# [22]	validation_0-rmse:1.09508	validation_1-rmse:1.26973
# [23]	validation_0-rmse:1.08657	validation_1-rmse:1.26288
# [24]	validation_0-rmse:1.07902	validation_1-rmse:1.25852
# [25]	validation_0-rmse:1.07113	validation_1-rmse:1.24909
# [26]	validation_0-rmse:1.06492	validation_1-rmse:1.24417
# [27]	validation_0-rmse:1.05606	validation_1-rmse:1.23942
# [28]	validation_0-rmse:1.04927	validation_1-rmse:1.23382
# [29]	validation_0-rmse:1.04244	validation_1-rmse:1.22832
# [30]	validation_0-rmse:1.03545	validation_1-rmse:1.22166
# [31]	validation_0-rmse:1.02826	validation_1-rmse:1.21728
# [32]	validation_0-rmse:1.02467	validation_1-rmse:1.21398
# [33]	validation_0-rmse:1.01729	validation_1-rmse:1.21011
# [34]	validation_0-rmse:1.00952	validation_1-rmse:1.20463
# [35]	validation_0-rmse:1.00645	validation_1-rmse:1.20289
# [36]	validation_0-rmse:0.99789	validation_1-rmse:1.19616
# [37]	validation_0-rmse:0.99169	validation_1-rmse:1.19204
# [38]	validation_0-rmse:0.98417	validation_1-rmse:1.18586
# [39]	validation_0-rmse:0.97639	validation_1-rmse:1.17961
# [40]	validation_0-rmse:0.97098	validation_1-rmse:1.17582
# [41]	validation_0-rmse:0.96579	validation_1-rmse:1.17258
# [42]	validation_0-rmse:0.96089	validation_1-rmse:1.16788
# [43]	validation_0-rmse:0.95543	validation_1-rmse:1.16266
# [44]	validation_0-rmse:0.94943	validation_1-rmse:1.16436
# [45]	validation_0-rmse:0.94126	validation_1-rmse:1.15566
# [46]	validation_0-rmse:0.93518	validation_1-rmse:1.15366
# [47]	validation_0-rmse:0.93221	validation_1-rmse:1.15358
# [48]	validation_0-rmse:0.92745	validation_1-rmse:1.15386
# [49]	validation_0-rmse:0.92377	validation_1-rmse:1.15328
# [50]	validation_0-rmse:0.91845	validation_1-rmse:1.15123
# [51]	validation_0-rmse:0.91171	validation_1-rmse:1.15031
# [52]	validation_0-rmse:0.90443	validation_1-rmse:1.15287
# [53]	validation_0-rmse:0.90021	validation_1-rmse:1.15156
# [54]	validation_0-rmse:0.89635	validation_1-rmse:1.15045
# [55]	validation_0-rmse:0.89315	validation_1-rmse:1.15157
# [56]	validation_0-rmse:0.88800	validation_1-rmse:1.14682
# [57]	validation_0-rmse:0.88302	validation_1-rmse:1.13953
# [58]	validation_0-rmse:0.87754	validation_1-rmse:1.13644
# [59]	validation_0-rmse:0.87220	validation_1-rmse:1.13486
# [60]	validation_0-rmse:0.86724	validation_1-rmse:1.13247
# [61]	validation_0-rmse:0.86385	validation_1-rmse:1.13323
# [62]	validation_0-rmse:0.85903	validation_1-rmse:1.12913
# [63]	validation_0-rmse:0.85576	validation_1-rmse:1.13039
# [64]	validation_0-rmse:0.85295	validation_1-rmse:1.12986
# [65]	validation_0-rmse:0.84910	validation_1-rmse:1.12714
# [66]	validation_0-rmse:0.84511	validation_1-rmse:1.12807
# [67]	validation_0-rmse:0.84272	validation_1-rmse:1.12818
# [68]	validation_0-rmse:0.83901	validation_1-rmse:1.12549
# [69]	validation_0-rmse:0.83581	validation_1-rmse:1.12403
# [70]	validation_0-rmse:0.83017	validation_1-rmse:1.12517
# [71]	validation_0-rmse:0.82745	validation_1-rmse:1.12511
# [72]	validation_0-rmse:0.82497	validation_1-rmse:1.12305
# [73]	validation_0-rmse:0.82321	validation_1-rmse:1.12206
# [74]	validation_0-rmse:0.81957	validation_1-rmse:1.12260
# [75]	validation_0-rmse:0.81601	validation_1-rmse:1.12286
# [76]	validation_0-rmse:0.81107	validation_1-rmse:1.11824
# [77]	validation_0-rmse:0.80630	validation_1-rmse:1.11095
# [78]	validation_0-rmse:0.80239	validation_1-rmse:1.11335
# [79]	validation_0-rmse:0.79871	validation_1-rmse:1.11286
# [80]	validation_0-rmse:0.79608	validation_1-rmse:1.11275
# [81]	validation_0-rmse:0.79370	validation_1-rmse:1.11189
# [82]	validation_0-rmse:0.79112	validation_1-rmse:1.11236
# [83]	validation_0-rmse:0.78647	validation_1-rmse:1.10967
# [84]	validation_0-rmse:0.78171	validation_1-rmse:1.10715
# [85]	validation_0-rmse:0.77833	validation_1-rmse:1.10691
# [0]	validation_0-rmse:1.33204	validation_1-rmse:1.27241
# [1]	validation_0-rmse:1.32110	validation_1-rmse:1.26073
# [2]	validation_0-rmse:1.30947	validation_1-rmse:1.25254
# [3]	validation_0-rmse:1.30017	validation_1-rmse:1.24425
# [4]	validation_0-rmse:1.29303	validation_1-rmse:1.23790
# [5]	validation_0-rmse:1.28231	validation_1-rmse:1.23158
# [6]	validation_0-rmse:1.27223	validation_1-rmse:1.22401
# [7]	validation_0-rmse:1.26410	validation_1-rmse:1.21616
# [8]	validation_0-rmse:1.25477	validation_1-rmse:1.20592
# [9]	validation_0-rmse:1.24543	validation_1-rmse:1.19883
# [10]	validation_0-rmse:1.23642	validation_1-rmse:1.19302
# [11]	validation_0-rmse:1.22811	validation_1-rmse:1.18724
# [12]	validation_0-rmse:1.21762	validation_1-rmse:1.17565
# [13]	validation_0-rmse:1.21097	validation_1-rmse:1.17340
# [14]	validation_0-rmse:1.19995	validation_1-rmse:1.16241
# [15]	validation_0-rmse:1.18980	validation_1-rmse:1.16111
# [16]	validation_0-rmse:1.18035	validation_1-rmse:1.15484
# [17]	validation_0-rmse:1.17234	validation_1-rmse:1.14960
# [18]	validation_0-rmse:1.16360	validation_1-rmse:1.14547
# [19]	validation_0-rmse:1.15562	validation_1-rmse:1.13561
# [20]	validation_0-rmse:1.14603	validation_1-rmse:1.13081
# [21]	validation_0-rmse:1.13640	validation_1-rmse:1.12972
# [22]	validation_0-rmse:1.12936	validation_1-rmse:1.12358
# [23]	validation_0-rmse:1.12085	validation_1-rmse:1.11899
# [24]	validation_0-rmse:1.11043	validation_1-rmse:1.10947
# [25]	validation_0-rmse:1.10291	validation_1-rmse:1.10283
# [26]	validation_0-rmse:1.09699	validation_1-rmse:1.09900
# [27]	validation_0-rmse:1.08837	validation_1-rmse:1.09158
# [28]	validation_0-rmse:1.07949	validation_1-rmse:1.08429
# [29]	validation_0-rmse:1.06948	validation_1-rmse:1.08277
# [30]	validation_0-rmse:1.06130	validation_1-rmse:1.07697
# [31]	validation_0-rmse:1.05435	validation_1-rmse:1.06969
# [32]	validation_0-rmse:1.04894	validation_1-rmse:1.06671
# [33]	validation_0-rmse:1.04342	validation_1-rmse:1.06471
# [34]	validation_0-rmse:1.03538	validation_1-rmse:1.06366
# [35]	validation_0-rmse:1.03012	validation_1-rmse:1.05926
# [36]	validation_0-rmse:1.02528	validation_1-rmse:1.05778
# [37]	validation_0-rmse:1.01863	validation_1-rmse:1.05391
# [38]	validation_0-rmse:1.01284	validation_1-rmse:1.05002
# [39]	validation_0-rmse:1.00567	validation_1-rmse:1.04583
# [40]	validation_0-rmse:0.99818	validation_1-rmse:1.04084
# [41]	validation_0-rmse:0.99389	validation_1-rmse:1.03767
# [42]	validation_0-rmse:0.98971	validation_1-rmse:1.03601
# [43]	validation_0-rmse:0.98442	validation_1-rmse:1.03411
# [44]	validation_0-rmse:0.98114	validation_1-rmse:1.03293
# [45]	validation_0-rmse:0.97780	validation_1-rmse:1.03166
# [46]	validation_0-rmse:0.97482	validation_1-rmse:1.03021
# [47]	validation_0-rmse:0.97065	validation_1-rmse:1.02733
# [48]	validation_0-rmse:0.96526	validation_1-rmse:1.02583
# [49]	validation_0-rmse:0.96251	validation_1-rmse:1.02499
# [50]	validation_0-rmse:0.95828	validation_1-rmse:1.02282
# [51]	validation_0-rmse:0.95243	validation_1-rmse:1.02128
# [52]	validation_0-rmse:0.94912	validation_1-rmse:1.01913
# [53]	validation_0-rmse:0.94322	validation_1-rmse:1.01520
# [54]	validation_0-rmse:0.94206	validation_1-rmse:1.01232
# [55]	validation_0-rmse:0.93713	validation_1-rmse:1.00849
# [56]	validation_0-rmse:0.93072	validation_1-rmse:1.00461
# [57]	validation_0-rmse:0.92375	validation_1-rmse:0.99968
# [58]	validation_0-rmse:0.91879	validation_1-rmse:0.99830
# [59]	validation_0-rmse:0.91442	validation_1-rmse:0.99535
# [60]	validation_0-rmse:0.91095	validation_1-rmse:0.99269
# [61]	validation_0-rmse:0.90502	validation_1-rmse:0.99394
# [62]	validation_0-rmse:0.90013	validation_1-rmse:0.99092
# [63]	validation_0-rmse:0.89532	validation_1-rmse:0.98900
# [64]	validation_0-rmse:0.89282	validation_1-rmse:0.98706
# [65]	validation_0-rmse:0.88882	validation_1-rmse:0.98727
# [66]	validation_0-rmse:0.88630	validation_1-rmse:0.98626
# [67]	validation_0-rmse:0.88165	validation_1-rmse:0.98334
# [68]	validation_0-rmse:0.87823	validation_1-rmse:0.98518
# [69]	validation_0-rmse:0.87550	validation_1-rmse:0.98215
# [70]	validation_0-rmse:0.87100	validation_1-rmse:0.98019
# [71]	validation_0-rmse:0.86656	validation_1-rmse:0.98037
# [72]	validation_0-rmse:0.86307	validation_1-rmse:0.98014
# [73]	validation_0-rmse:0.86090	validation_1-rmse:0.97831
# [74]	validation_0-rmse:0.85797	validation_1-rmse:0.97702
# [75]	validation_0-rmse:0.85481	validation_1-rmse:0.97512
# [76]	validation_0-rmse:0.85085	validation_1-rmse:0.97522
# [77]	validation_0-rmse:0.84453	validation_1-rmse:0.97329
# [78]	validation_0-rmse:0.84162	validation_1-rmse:0.97497
# [79]	validation_0-rmse:0.83696	validation_1-rmse:0.97538
# [80]	validation_0-rmse:0.83420	validation_1-rmse:0.97347
# [81]	validation_0-rmse:0.82927	validation_1-rmse:0.97271
# [82]	validation_0-rmse:0.82708	validation_1-rmse:0.97241
# [83]	validation_0-rmse:0.82270	validation_1-rmse:0.97191
# [84]	validation_0-rmse:0.81782	validation_1-rmse:0.96964
# [85]	validation_0-rmse:0.81407	validation_1-rmse:0.96885
# [0]	validation_0-rmse:1.32453	validation_1-rmse:1.31441
# [1]	validation_0-rmse:1.31261	validation_1-rmse:1.30593
# [2]	validation_0-rmse:1.30074	validation_1-rmse:1.29225
# [3]	validation_0-rmse:1.29114	validation_1-rmse:1.28014
# [4]	validation_0-rmse:1.28100	validation_1-rmse:1.27190
# [5]	validation_0-rmse:1.27172	validation_1-rmse:1.26638
# [6]	validation_0-rmse:1.26320	validation_1-rmse:1.25548
# [7]	validation_0-rmse:1.25573	validation_1-rmse:1.24654
# [8]	validation_0-rmse:1.24464	validation_1-rmse:1.23248
# [9]	validation_0-rmse:1.23583	validation_1-rmse:1.22725
# [10]	validation_0-rmse:1.22909	validation_1-rmse:1.22077
# [11]	validation_0-rmse:1.21889	validation_1-rmse:1.21490
# [12]	validation_0-rmse:1.20800	validation_1-rmse:1.20654
# [13]	validation_0-rmse:1.19983	validation_1-rmse:1.20079
# [14]	validation_0-rmse:1.19266	validation_1-rmse:1.19387
# [15]	validation_0-rmse:1.18267	validation_1-rmse:1.18761
# [16]	validation_0-rmse:1.17195	validation_1-rmse:1.18110
# [17]	validation_0-rmse:1.16662	validation_1-rmse:1.18183
# [18]	validation_0-rmse:1.15888	validation_1-rmse:1.17212
# [19]	validation_0-rmse:1.15330	validation_1-rmse:1.16740
# [20]	validation_0-rmse:1.14350	validation_1-rmse:1.16064
# [21]	validation_0-rmse:1.13728	validation_1-rmse:1.15706
# [22]	validation_0-rmse:1.13105	validation_1-rmse:1.15341
# [23]	validation_0-rmse:1.12387	validation_1-rmse:1.14753
# [24]	validation_0-rmse:1.11560	validation_1-rmse:1.14089
# [25]	validation_0-rmse:1.11029	validation_1-rmse:1.13587
# [26]	validation_0-rmse:1.10257	validation_1-rmse:1.13139
# [27]	validation_0-rmse:1.09754	validation_1-rmse:1.13029
# [28]	validation_0-rmse:1.08983	validation_1-rmse:1.12468
# [29]	validation_0-rmse:1.08281	validation_1-rmse:1.12003
# [30]	validation_0-rmse:1.07783	validation_1-rmse:1.11823
# [31]	validation_0-rmse:1.06994	validation_1-rmse:1.10877
# [32]	validation_0-rmse:1.06488	validation_1-rmse:1.10439
# [33]	validation_0-rmse:1.05549	validation_1-rmse:1.09585
# [34]	validation_0-rmse:1.05102	validation_1-rmse:1.08966
# [35]	validation_0-rmse:1.04427	validation_1-rmse:1.08086
# [36]	validation_0-rmse:1.03782	validation_1-rmse:1.07814
# [37]	validation_0-rmse:1.02978	validation_1-rmse:1.06631
# [38]	validation_0-rmse:1.02411	validation_1-rmse:1.06554
# [39]	validation_0-rmse:1.01658	validation_1-rmse:1.06017
# [40]	validation_0-rmse:1.01109	validation_1-rmse:1.05397
# [41]	validation_0-rmse:1.00687	validation_1-rmse:1.04994
# [42]	validation_0-rmse:1.00160	validation_1-rmse:1.04249
# [43]	validation_0-rmse:0.99937	validation_1-rmse:1.04417
# [44]	validation_0-rmse:0.99344	validation_1-rmse:1.03869
# [45]	validation_0-rmse:0.99032	validation_1-rmse:1.03730
# [46]	validation_0-rmse:0.98701	validation_1-rmse:1.03652
# [47]	validation_0-rmse:0.98171	validation_1-rmse:1.03490
# [48]	validation_0-rmse:0.97579	validation_1-rmse:1.03007
# [49]	validation_0-rmse:0.97006	validation_1-rmse:1.02700
# [50]	validation_0-rmse:0.96641	validation_1-rmse:1.02218
# [51]	validation_0-rmse:0.96101	validation_1-rmse:1.01582
# [52]	validation_0-rmse:0.95763	validation_1-rmse:1.01372
# [53]	validation_0-rmse:0.95346	validation_1-rmse:1.01272
# [54]	validation_0-rmse:0.94932	validation_1-rmse:1.00561
# [55]	validation_0-rmse:0.94689	validation_1-rmse:1.00391
# [56]	validation_0-rmse:0.94237	validation_1-rmse:1.00564
# [57]	validation_0-rmse:0.93600	validation_1-rmse:1.00147
# [58]	validation_0-rmse:0.92958	validation_1-rmse:0.99371
# [59]	validation_0-rmse:0.92551	validation_1-rmse:0.99341
# [60]	validation_0-rmse:0.92160	validation_1-rmse:0.99156
# [61]	validation_0-rmse:0.91658	validation_1-rmse:0.99083
# [62]	validation_0-rmse:0.91160	validation_1-rmse:0.98724
# [63]	validation_0-rmse:0.90521	validation_1-rmse:0.98426
# [64]	validation_0-rmse:0.90174	validation_1-rmse:0.98528
# [65]	validation_0-rmse:0.89635	validation_1-rmse:0.98021
# [66]	validation_0-rmse:0.89405	validation_1-rmse:0.97936
# [67]	validation_0-rmse:0.89057	validation_1-rmse:0.97857
# [68]	validation_0-rmse:0.88600	validation_1-rmse:0.97284
# [69]	validation_0-rmse:0.88150	validation_1-rmse:0.96758
# [70]	validation_0-rmse:0.87799	validation_1-rmse:0.96524
# [71]	validation_0-rmse:0.87489	validation_1-rmse:0.96133
# [72]	validation_0-rmse:0.87086	validation_1-rmse:0.95986
# [73]	validation_0-rmse:0.86893	validation_1-rmse:0.96059
# [74]	validation_0-rmse:0.86243	validation_1-rmse:0.95779
# [75]	validation_0-rmse:0.85866	validation_1-rmse:0.95482
# [76]	validation_0-rmse:0.85624	validation_1-rmse:0.95463
# [77]	validation_0-rmse:0.85070	validation_1-rmse:0.94987
# [78]	validation_0-rmse:0.84771	validation_1-rmse:0.94775
# [79]	validation_0-rmse:0.84367	validation_1-rmse:0.94141
# [80]	validation_0-rmse:0.84112	validation_1-rmse:0.93870
# [81]	validation_0-rmse:0.83770	validation_1-rmse:0.93373
# [82]	validation_0-rmse:0.83439	validation_1-rmse:0.93066
# [83]	validation_0-rmse:0.83238	validation_1-rmse:0.93186
# [84]	validation_0-rmse:0.83020	validation_1-rmse:0.93018
# [85]	validation_0-rmse:0.82863	validation_1-rmse:0.92956
# [0]	validation_0-rmse:1.36680	validation_1-rmse:1.13128
# [1]	validation_0-rmse:1.35747	validation_1-rmse:1.12284
# [2]	validation_0-rmse:1.34573	validation_1-rmse:1.11255
# [3]	validation_0-rmse:1.33664	validation_1-rmse:1.10047
# [4]	validation_0-rmse:1.32680	validation_1-rmse:1.08893
# [5]	validation_0-rmse:1.31867	validation_1-rmse:1.08017
# [6]	validation_0-rmse:1.30566	validation_1-rmse:1.06779
# [7]	validation_0-rmse:1.29592	validation_1-rmse:1.05846
# [8]	validation_0-rmse:1.28416	validation_1-rmse:1.04180
# [9]	validation_0-rmse:1.27645	validation_1-rmse:1.03551
# [10]	validation_0-rmse:1.26854	validation_1-rmse:1.02660
# [11]	validation_0-rmse:1.25900	validation_1-rmse:1.01621
# [12]	validation_0-rmse:1.25065	validation_1-rmse:1.00635
# [13]	validation_0-rmse:1.24294	validation_1-rmse:0.99616
# [14]	validation_0-rmse:1.23362	validation_1-rmse:0.98191
# [15]	validation_0-rmse:1.22249	validation_1-rmse:0.97150
# [16]	validation_0-rmse:1.21647	validation_1-rmse:0.96663
# [17]	validation_0-rmse:1.21127	validation_1-rmse:0.96177
# [18]	validation_0-rmse:1.20184	validation_1-rmse:0.94752
# [19]	validation_0-rmse:1.19395	validation_1-rmse:0.94026
# [20]	validation_0-rmse:1.18687	validation_1-rmse:0.93406
# [21]	validation_0-rmse:1.17972	validation_1-rmse:0.92985
# [22]	validation_0-rmse:1.17225	validation_1-rmse:0.92121
# [23]	validation_0-rmse:1.16844	validation_1-rmse:0.91552
# [24]	validation_0-rmse:1.15902	validation_1-rmse:0.90491
# [25]	validation_0-rmse:1.14896	validation_1-rmse:0.89539
# [26]	validation_0-rmse:1.14160	validation_1-rmse:0.88410
# [27]	validation_0-rmse:1.13670	validation_1-rmse:0.88589
# [28]	validation_0-rmse:1.12915	validation_1-rmse:0.87852
# [29]	validation_0-rmse:1.12309	validation_1-rmse:0.87003
# [30]	validation_0-rmse:1.11332	validation_1-rmse:0.86241
# [31]	validation_0-rmse:1.10596	validation_1-rmse:0.85467
# [32]	validation_0-rmse:1.10001	validation_1-rmse:0.84673
# [33]	validation_0-rmse:1.09271	validation_1-rmse:0.84092
# [34]	validation_0-rmse:1.08555	validation_1-rmse:0.83614
# [35]	validation_0-rmse:1.07978	validation_1-rmse:0.83331
# [36]	validation_0-rmse:1.07156	validation_1-rmse:0.82362
# [37]	validation_0-rmse:1.06371	validation_1-rmse:0.81276
# [38]	validation_0-rmse:1.05780	validation_1-rmse:0.80072
# [39]	validation_0-rmse:1.05048	validation_1-rmse:0.79141
# [40]	validation_0-rmse:1.04495	validation_1-rmse:0.78879
# [41]	validation_0-rmse:1.04019	validation_1-rmse:0.78459
# [42]	validation_0-rmse:1.03667	validation_1-rmse:0.78437
# [43]	validation_0-rmse:1.03501	validation_1-rmse:0.78176
# [44]	validation_0-rmse:1.02996	validation_1-rmse:0.77652
# [45]	validation_0-rmse:1.02434	validation_1-rmse:0.77110
# [46]	validation_0-rmse:1.01963	validation_1-rmse:0.76385
# [47]	validation_0-rmse:1.01605	validation_1-rmse:0.75539
# [48]	validation_0-rmse:1.01146	validation_1-rmse:0.75127
# [49]	validation_0-rmse:1.00747	validation_1-rmse:0.74577
# [50]	validation_0-rmse:1.00274	validation_1-rmse:0.74061
# [51]	validation_0-rmse:0.99717	validation_1-rmse:0.73651
# [52]	validation_0-rmse:0.99192	validation_1-rmse:0.73150
# [53]	validation_0-rmse:0.98622	validation_1-rmse:0.72092
# [54]	validation_0-rmse:0.98339	validation_1-rmse:0.71855
# [55]	validation_0-rmse:0.98227	validation_1-rmse:0.72104
# [56]	validation_0-rmse:0.97995	validation_1-rmse:0.71726
# [57]	validation_0-rmse:0.97372	validation_1-rmse:0.70852
# [58]	validation_0-rmse:0.96719	validation_1-rmse:0.70163
# [59]	validation_0-rmse:0.96499	validation_1-rmse:0.70165
# [60]	validation_0-rmse:0.96042	validation_1-rmse:0.69651
# [61]	validation_0-rmse:0.95584	validation_1-rmse:0.69150
# [62]	validation_0-rmse:0.95039	validation_1-rmse:0.68692
# [63]	validation_0-rmse:0.94641	validation_1-rmse:0.68211
# [64]	validation_0-rmse:0.94476	validation_1-rmse:0.68292
# [65]	validation_0-rmse:0.94230	validation_1-rmse:0.68171
# [66]	validation_0-rmse:0.93918	validation_1-rmse:0.68177
# [67]	validation_0-rmse:0.93673	validation_1-rmse:0.68031
# [68]	validation_0-rmse:0.93230	validation_1-rmse:0.67507
# [69]	validation_0-rmse:0.92754	validation_1-rmse:0.67316
# [70]	validation_0-rmse:0.92437	validation_1-rmse:0.66916
# [71]	validation_0-rmse:0.92107	validation_1-rmse:0.66775
# [72]	validation_0-rmse:0.91613	validation_1-rmse:0.66127
# [73]	validation_0-rmse:0.91350	validation_1-rmse:0.66040
# [74]	validation_0-rmse:0.90849	validation_1-rmse:0.65470
# [75]	validation_0-rmse:0.90487	validation_1-rmse:0.65162
# [76]	validation_0-rmse:0.90110	validation_1-rmse:0.65318
# [77]	validation_0-rmse:0.89757	validation_1-rmse:0.65493
# [78]	validation_0-rmse:0.89455	validation_1-rmse:0.65385
# [79]	validation_0-rmse:0.88944	validation_1-rmse:0.65391
# [80]	validation_0-rmse:0.88658	validation_1-rmse:0.65319
# [81]	validation_0-rmse:0.88230	validation_1-rmse:0.65152
# [82]	validation_0-rmse:0.87888	validation_1-rmse:0.64455
# [83]	validation_0-rmse:0.87555	validation_1-rmse:0.64113
# [84]	validation_0-rmse:0.87244	validation_1-rmse:0.64020
# [85]	validation_0-rmse:0.87054	validation_1-rmse:0.64040
# [0]	validation_0-rmse:1.24820	validation_1-rmse:1.58282
# [1]	validation_0-rmse:1.23902	validation_1-rmse:1.57437
# [2]	validation_0-rmse:1.23002	validation_1-rmse:1.55890
# [3]	validation_0-rmse:1.22172	validation_1-rmse:1.55080
# [4]	validation_0-rmse:1.21103	validation_1-rmse:1.53898
# [5]	validation_0-rmse:1.20077	validation_1-rmse:1.52883
# [6]	validation_0-rmse:1.19127	validation_1-rmse:1.51376
# [7]	validation_0-rmse:1.18250	validation_1-rmse:1.51273
# [8]	validation_0-rmse:1.17249	validation_1-rmse:1.50425
# [9]	validation_0-rmse:1.16321	validation_1-rmse:1.49931
# [10]	validation_0-rmse:1.15603	validation_1-rmse:1.49132
# [11]	validation_0-rmse:1.14950	validation_1-rmse:1.48466
# [12]	validation_0-rmse:1.14079	validation_1-rmse:1.48081
# [13]	validation_0-rmse:1.13551	validation_1-rmse:1.48029
# [14]	validation_0-rmse:1.12792	validation_1-rmse:1.47810
# [15]	validation_0-rmse:1.11970	validation_1-rmse:1.46433
# [16]	validation_0-rmse:1.11142	validation_1-rmse:1.45565
# [17]	validation_0-rmse:1.10747	validation_1-rmse:1.45403
# [18]	validation_0-rmse:1.09794	validation_1-rmse:1.44160
# [19]	validation_0-rmse:1.09270	validation_1-rmse:1.43490
# [20]	validation_0-rmse:1.08702	validation_1-rmse:1.43161
# [21]	validation_0-rmse:1.07895	validation_1-rmse:1.42545
# [22]	validation_0-rmse:1.07428	validation_1-rmse:1.42154
# [23]	validation_0-rmse:1.06759	validation_1-rmse:1.41460
# [24]	validation_0-rmse:1.06087	validation_1-rmse:1.40847
# [25]	validation_0-rmse:1.05390	validation_1-rmse:1.39888
# [26]	validation_0-rmse:1.04947	validation_1-rmse:1.39501
# [27]	validation_0-rmse:1.04318	validation_1-rmse:1.38558
# [28]	validation_0-rmse:1.03868	validation_1-rmse:1.38162
# [29]	validation_0-rmse:1.03064	validation_1-rmse:1.37541
# [30]	validation_0-rmse:1.02352	validation_1-rmse:1.36953
# [31]	validation_0-rmse:1.01797	validation_1-rmse:1.35950
# [32]	validation_0-rmse:1.01287	validation_1-rmse:1.35824
# [33]	validation_0-rmse:1.00649	validation_1-rmse:1.35277
# [34]	validation_0-rmse:0.99961	validation_1-rmse:1.34264
# [35]	validation_0-rmse:0.99456	validation_1-rmse:1.34087
# [36]	validation_0-rmse:0.98843	validation_1-rmse:1.32746
# [37]	validation_0-rmse:0.98419	validation_1-rmse:1.32501
# [38]	validation_0-rmse:0.97999	validation_1-rmse:1.32786
# [39]	validation_0-rmse:0.97644	validation_1-rmse:1.32618
# [40]	validation_0-rmse:0.97160	validation_1-rmse:1.31866
# [41]	validation_0-rmse:0.96870	validation_1-rmse:1.31522
# [42]	validation_0-rmse:0.96397	validation_1-rmse:1.31028
# [43]	validation_0-rmse:0.95932	validation_1-rmse:1.30951
# [44]	validation_0-rmse:0.95643	validation_1-rmse:1.30335
# [45]	validation_0-rmse:0.95292	validation_1-rmse:1.30160
# [46]	validation_0-rmse:0.95008	validation_1-rmse:1.29805
# [47]	validation_0-rmse:0.94821	validation_1-rmse:1.29776
# [48]	validation_0-rmse:0.94463	validation_1-rmse:1.29611
# [49]	validation_0-rmse:0.94030	validation_1-rmse:1.29254
# [50]	validation_0-rmse:0.93638	validation_1-rmse:1.28856
# [51]	validation_0-rmse:0.93179	validation_1-rmse:1.28004
# [52]	validation_0-rmse:0.92864	validation_1-rmse:1.27674
# [53]	validation_0-rmse:0.92571	validation_1-rmse:1.27414
# [54]	validation_0-rmse:0.91995	validation_1-rmse:1.26459
# [55]	validation_0-rmse:0.91585	validation_1-rmse:1.25930
# [56]	validation_0-rmse:0.91326	validation_1-rmse:1.25756
# [57]	validation_0-rmse:0.90742	validation_1-rmse:1.25516
# [58]	validation_0-rmse:0.90365	validation_1-rmse:1.25352
# [59]	validation_0-rmse:0.89954	validation_1-rmse:1.24883
# [60]	validation_0-rmse:0.89698	validation_1-rmse:1.24371
# [61]	validation_0-rmse:0.89229	validation_1-rmse:1.24407
# [62]	validation_0-rmse:0.88784	validation_1-rmse:1.23901
# [63]	validation_0-rmse:0.88339	validation_1-rmse:1.23484
# [64]	validation_0-rmse:0.87926	validation_1-rmse:1.23171
# [65]	validation_0-rmse:0.87608	validation_1-rmse:1.22705
# [66]	validation_0-rmse:0.87196	validation_1-rmse:1.22661
# [67]	validation_0-rmse:0.86933	validation_1-rmse:1.22314
# [68]	validation_0-rmse:0.86800	validation_1-rmse:1.22248
# [69]	validation_0-rmse:0.86528	validation_1-rmse:1.21957
# [70]	validation_0-rmse:0.86060	validation_1-rmse:1.21787
# [71]	validation_0-rmse:0.85616	validation_1-rmse:1.21801
# [72]	validation_0-rmse:0.85403	validation_1-rmse:1.21751
# [73]	validation_0-rmse:0.85234	validation_1-rmse:1.21628
# [74]	validation_0-rmse:0.84741	validation_1-rmse:1.20999
# [75]	validation_0-rmse:0.84379	validation_1-rmse:1.21037
# [76]	validation_0-rmse:0.84017	validation_1-rmse:1.20584
# [77]	validation_0-rmse:0.83815	validation_1-rmse:1.20457
# [78]	validation_0-rmse:0.83545	validation_1-rmse:1.20260
# [79]	validation_0-rmse:0.83371	validation_1-rmse:1.20337
# [80]	validation_0-rmse:0.83231	validation_1-rmse:1.20400
# [81]	validation_0-rmse:0.83009	validation_1-rmse:1.19858
# [82]	validation_0-rmse:0.82527	validation_1-rmse:1.19055
# [83]	validation_0-rmse:0.82113	validation_1-rmse:1.18663
# [84]	validation_0-rmse:0.81830	validation_1-rmse:1.17927
# [85]	validation_0-rmse:0.81492	validation_1-rmse:1.17739
# [0]	validation_0-rmse:1.34580	validation_1-rmse:1.21611
# [1]	validation_0-rmse:1.33418	validation_1-rmse:1.20350
# [2]	validation_0-rmse:1.31975	validation_1-rmse:1.19325
# [3]	validation_0-rmse:1.31361	validation_1-rmse:1.18291
# [4]	validation_0-rmse:1.30570	validation_1-rmse:1.17431
# [5]	validation_0-rmse:1.29272	validation_1-rmse:1.16418
# [6]	validation_0-rmse:1.28294	validation_1-rmse:1.15607
# [7]	validation_0-rmse:1.27162	validation_1-rmse:1.14961
# [8]	validation_0-rmse:1.25970	validation_1-rmse:1.14387
# [9]	validation_0-rmse:1.24949	validation_1-rmse:1.13746
# [10]	validation_0-rmse:1.24188	validation_1-rmse:1.12911
# [11]	validation_0-rmse:1.23405	validation_1-rmse:1.12000
# [12]	validation_0-rmse:1.22554	validation_1-rmse:1.11226
# [13]	validation_0-rmse:1.21758	validation_1-rmse:1.10547
# [14]	validation_0-rmse:1.20606	validation_1-rmse:1.09581
# [15]	validation_0-rmse:1.19932	validation_1-rmse:1.09231
# [16]	validation_0-rmse:1.18897	validation_1-rmse:1.08224
# [17]	validation_0-rmse:1.17674	validation_1-rmse:1.07221
# [18]	validation_0-rmse:1.16615	validation_1-rmse:1.06700
# [19]	validation_0-rmse:1.15733	validation_1-rmse:1.06114
# [20]	validation_0-rmse:1.15133	validation_1-rmse:1.05456
# [21]	validation_0-rmse:1.14664	validation_1-rmse:1.05044
# [22]	validation_0-rmse:1.13674	validation_1-rmse:1.04427
# [23]	validation_0-rmse:1.12742	validation_1-rmse:1.03945
# [24]	validation_0-rmse:1.11935	validation_1-rmse:1.03213
# [25]	validation_0-rmse:1.11197	validation_1-rmse:1.02849
# [26]	validation_0-rmse:1.10700	validation_1-rmse:1.02258
# [27]	validation_0-rmse:1.10270	validation_1-rmse:1.01981
# [28]	validation_0-rmse:1.09468	validation_1-rmse:1.01377
# [29]	validation_0-rmse:1.08657	validation_1-rmse:1.00539
# [30]	validation_0-rmse:1.07982	validation_1-rmse:1.00263
# [31]	validation_0-rmse:1.07156	validation_1-rmse:0.99837
# [32]	validation_0-rmse:1.06531	validation_1-rmse:0.99035
# [33]	validation_0-rmse:1.05724	validation_1-rmse:0.97966
# [34]	validation_0-rmse:1.04993	validation_1-rmse:0.97507
# [35]	validation_0-rmse:1.04551	validation_1-rmse:0.97422
# [36]	validation_0-rmse:1.03817	validation_1-rmse:0.96842
# [37]	validation_0-rmse:1.02949	validation_1-rmse:0.96325
# [38]	validation_0-rmse:1.02619	validation_1-rmse:0.96118
# [39]	validation_0-rmse:1.01855	validation_1-rmse:0.95730
# [40]	validation_0-rmse:1.01300	validation_1-rmse:0.95565
# [41]	validation_0-rmse:1.00736	validation_1-rmse:0.95194
# [42]	validation_0-rmse:1.00072	validation_1-rmse:0.94672
# [43]	validation_0-rmse:0.99634	validation_1-rmse:0.94693
# [44]	validation_0-rmse:0.99366	validation_1-rmse:0.94645
# [45]	validation_0-rmse:0.98594	validation_1-rmse:0.94433
# [46]	validation_0-rmse:0.98156	validation_1-rmse:0.94016
# [47]	validation_0-rmse:0.97466	validation_1-rmse:0.93540
# [48]	validation_0-rmse:0.97052	validation_1-rmse:0.93065
# [49]	validation_0-rmse:0.96582	validation_1-rmse:0.92926
# [50]	validation_0-rmse:0.96227	validation_1-rmse:0.92750
# [51]	validation_0-rmse:0.95948	validation_1-rmse:0.92564
# [52]	validation_0-rmse:0.95389	validation_1-rmse:0.92407
# [53]	validation_0-rmse:0.94913	validation_1-rmse:0.92230
# [54]	validation_0-rmse:0.94509	validation_1-rmse:0.92019
# [55]	validation_0-rmse:0.94118	validation_1-rmse:0.92097
# [56]	validation_0-rmse:0.93519	validation_1-rmse:0.91929
# [57]	validation_0-rmse:0.92841	validation_1-rmse:0.91650
# [58]	validation_0-rmse:0.92471	validation_1-rmse:0.91531
# [59]	validation_0-rmse:0.91953	validation_1-rmse:0.91406
# [60]	validation_0-rmse:0.91453	validation_1-rmse:0.90805
# [61]	validation_0-rmse:0.90970	validation_1-rmse:0.90390
# [62]	validation_0-rmse:0.90346	validation_1-rmse:0.90156
# [63]	validation_0-rmse:0.89665	validation_1-rmse:0.90054
# [64]	validation_0-rmse:0.89275	validation_1-rmse:0.89857
# [65]	validation_0-rmse:0.89125	validation_1-rmse:0.89772
# [66]	validation_0-rmse:0.88945	validation_1-rmse:0.89558
# [67]	validation_0-rmse:0.88540	validation_1-rmse:0.89193
# [68]	validation_0-rmse:0.88250	validation_1-rmse:0.89184
# [69]	validation_0-rmse:0.87898	validation_1-rmse:0.88873
# [70]	validation_0-rmse:0.87429	validation_1-rmse:0.88618
# [71]	validation_0-rmse:0.87082	validation_1-rmse:0.88598
# [72]	validation_0-rmse:0.86766	validation_1-rmse:0.88199
# [73]	validation_0-rmse:0.86377	validation_1-rmse:0.87899
# [74]	validation_0-rmse:0.85747	validation_1-rmse:0.87867
# [75]	validation_0-rmse:0.85408	validation_1-rmse:0.87480
# [76]	validation_0-rmse:0.85116	validation_1-rmse:0.87235
# [77]	validation_0-rmse:0.84598	validation_1-rmse:0.87123
# [78]	validation_0-rmse:0.84327	validation_1-rmse:0.86933
# [79]	validation_0-rmse:0.83696	validation_1-rmse:0.86965
# [80]	validation_0-rmse:0.83527	validation_1-rmse:0.86847
# [81]	validation_0-rmse:0.83201	validation_1-rmse:0.86983
# [82]	validation_0-rmse:0.82767	validation_1-rmse:0.86865
# [83]	validation_0-rmse:0.82299	validation_1-rmse:0.86532
# [84]	validation_0-rmse:0.82139	validation_1-rmse:0.86394
# [85]	validation_0-rmse:0.82075	validation_1-rmse:0.86344
# [0]	validation_0-rmse:1.32015	validation_1-rmse:1.34691
# [1]	validation_0-rmse:1.30912	validation_1-rmse:1.34198
# [2]	validation_0-rmse:1.30091	validation_1-rmse:1.33353
# [3]	validation_0-rmse:1.29275	validation_1-rmse:1.32709
# [4]	validation_0-rmse:1.28226	validation_1-rmse:1.32123
# [5]	validation_0-rmse:1.27164	validation_1-rmse:1.31277
# [6]	validation_0-rmse:1.25866	validation_1-rmse:1.30153
# [7]	validation_0-rmse:1.25437	validation_1-rmse:1.29619
# [8]	validation_0-rmse:1.24412	validation_1-rmse:1.28675
# [9]	validation_0-rmse:1.23605	validation_1-rmse:1.28108
# [10]	validation_0-rmse:1.22978	validation_1-rmse:1.27722
# [11]	validation_0-rmse:1.22335	validation_1-rmse:1.27584
# [12]	validation_0-rmse:1.21543	validation_1-rmse:1.26956
# [13]	validation_0-rmse:1.20733	validation_1-rmse:1.26454
# [14]	validation_0-rmse:1.19786	validation_1-rmse:1.25325
# [15]	validation_0-rmse:1.18936	validation_1-rmse:1.24618
# [16]	validation_0-rmse:1.17913	validation_1-rmse:1.24505
# [17]	validation_0-rmse:1.17115	validation_1-rmse:1.23881
# [18]	validation_0-rmse:1.16363	validation_1-rmse:1.23132
# [19]	validation_0-rmse:1.15862	validation_1-rmse:1.23284
# [20]	validation_0-rmse:1.15102	validation_1-rmse:1.22596
# [21]	validation_0-rmse:1.14499	validation_1-rmse:1.22087
# [22]	validation_0-rmse:1.13708	validation_1-rmse:1.21669
# [23]	validation_0-rmse:1.13435	validation_1-rmse:1.21284
# [24]	validation_0-rmse:1.12749	validation_1-rmse:1.20672
# [25]	validation_0-rmse:1.11671	validation_1-rmse:1.19652
# [26]	validation_0-rmse:1.11209	validation_1-rmse:1.19324
# [27]	validation_0-rmse:1.10279	validation_1-rmse:1.18594
# [28]	validation_0-rmse:1.09646	validation_1-rmse:1.17705
# [29]	validation_0-rmse:1.08999	validation_1-rmse:1.17549
# [30]	validation_0-rmse:1.08162	validation_1-rmse:1.16884
# [31]	validation_0-rmse:1.07369	validation_1-rmse:1.16310
# [32]	validation_0-rmse:1.06884	validation_1-rmse:1.15656
# [33]	validation_0-rmse:1.06035	validation_1-rmse:1.15395
# [34]	validation_0-rmse:1.05039	validation_1-rmse:1.14776
# [35]	validation_0-rmse:1.04360	validation_1-rmse:1.14218
# [36]	validation_0-rmse:1.03695	validation_1-rmse:1.13748
# [37]	validation_0-rmse:1.03134	validation_1-rmse:1.13843
# [38]	validation_0-rmse:1.02327	validation_1-rmse:1.13146
# [39]	validation_0-rmse:1.01473	validation_1-rmse:1.12349
# [40]	validation_0-rmse:1.00959	validation_1-rmse:1.11999
# [41]	validation_0-rmse:1.00338	validation_1-rmse:1.11001
# [42]	validation_0-rmse:0.99974	validation_1-rmse:1.10730
# [43]	validation_0-rmse:0.99806	validation_1-rmse:1.10647
# [44]	validation_0-rmse:0.99374	validation_1-rmse:1.09864
# [45]	validation_0-rmse:0.98749	validation_1-rmse:1.09097
# [46]	validation_0-rmse:0.98080	validation_1-rmse:1.09190
# [47]	validation_0-rmse:0.97514	validation_1-rmse:1.08642
# [48]	validation_0-rmse:0.96986	validation_1-rmse:1.08215
# [49]	validation_0-rmse:0.96422	validation_1-rmse:1.08188
# [50]	validation_0-rmse:0.95843	validation_1-rmse:1.08050
# [51]	validation_0-rmse:0.95404	validation_1-rmse:1.07932
# [52]	validation_0-rmse:0.94944	validation_1-rmse:1.07165
# [53]	validation_0-rmse:0.94544	validation_1-rmse:1.06780
# [54]	validation_0-rmse:0.94250	validation_1-rmse:1.06503
# [55]	validation_0-rmse:0.93963	validation_1-rmse:1.05909
# [56]	validation_0-rmse:0.93539	validation_1-rmse:1.05483
# [57]	validation_0-rmse:0.93093	validation_1-rmse:1.05034
# [58]	validation_0-rmse:0.92724	validation_1-rmse:1.04371
# [59]	validation_0-rmse:0.92183	validation_1-rmse:1.04353
# [60]	validation_0-rmse:0.91918	validation_1-rmse:1.04086
# [61]	validation_0-rmse:0.91724	validation_1-rmse:1.03971
# [62]	validation_0-rmse:0.91078	validation_1-rmse:1.03627
# [63]	validation_0-rmse:0.90477	validation_1-rmse:1.03388
# [64]	validation_0-rmse:0.90079	validation_1-rmse:1.03057
# [65]	validation_0-rmse:0.89628	validation_1-rmse:1.02518
# [66]	validation_0-rmse:0.89081	validation_1-rmse:1.02333
# [67]	validation_0-rmse:0.88631	validation_1-rmse:1.02047
# [68]	validation_0-rmse:0.88042	validation_1-rmse:1.01624
# [69]	validation_0-rmse:0.87580	validation_1-rmse:1.01273
# [70]	validation_0-rmse:0.87462	validation_1-rmse:1.01030
# [71]	validation_0-rmse:0.87178	validation_1-rmse:1.00974
# [72]	validation_0-rmse:0.86821	validation_1-rmse:1.00593
# [73]	validation_0-rmse:0.86598	validation_1-rmse:1.00309
# [74]	validation_0-rmse:0.86208	validation_1-rmse:0.99800
# [75]	validation_0-rmse:0.85876	validation_1-rmse:0.99944
# [76]	validation_0-rmse:0.85527	validation_1-rmse:0.99708
# [77]	validation_0-rmse:0.85208	validation_1-rmse:0.99404
# [78]	validation_0-rmse:0.84864	validation_1-rmse:0.99009
# [79]	validation_0-rmse:0.84480	validation_1-rmse:0.99051
# [80]	validation_0-rmse:0.84240	validation_1-rmse:0.98604
# [81]	validation_0-rmse:0.83730	validation_1-rmse:0.98121
# [82]	validation_0-rmse:0.83344	validation_1-rmse:0.97912
# [83]	validation_0-rmse:0.82998	validation_1-rmse:0.97667
# [84]	validation_0-rmse:0.82630	validation_1-rmse:0.97086
# [85]	validation_0-rmse:0.82234	validation_1-rmse:0.97038
# [0]	validation_0-rmse:1.30027	validation_1-rmse:1.39272
# [1]	validation_0-rmse:1.28959	validation_1-rmse:1.38095
# [2]	validation_0-rmse:1.27865	validation_1-rmse:1.36775
# [3]	validation_0-rmse:1.26999	validation_1-rmse:1.36148
# [4]	validation_0-rmse:1.25963	validation_1-rmse:1.35495
# [5]	validation_0-rmse:1.24949	validation_1-rmse:1.34507
# [6]	validation_0-rmse:1.24392	validation_1-rmse:1.34409
# [7]	validation_0-rmse:1.23411	validation_1-rmse:1.33112
# [8]	validation_0-rmse:1.22430	validation_1-rmse:1.32092
# [9]	validation_0-rmse:1.21102	validation_1-rmse:1.31046
# [10]	validation_0-rmse:1.20435	validation_1-rmse:1.30414
# [11]	validation_0-rmse:1.19755	validation_1-rmse:1.29749
# [12]	validation_0-rmse:1.18779	validation_1-rmse:1.29172
# [13]	validation_0-rmse:1.17866	validation_1-rmse:1.28180
# [14]	validation_0-rmse:1.17274	validation_1-rmse:1.27501
# [15]	validation_0-rmse:1.16266	validation_1-rmse:1.27248
# [16]	validation_0-rmse:1.15570	validation_1-rmse:1.26672
# [17]	validation_0-rmse:1.14814	validation_1-rmse:1.26012
# [18]	validation_0-rmse:1.14083	validation_1-rmse:1.25611
# [19]	validation_0-rmse:1.13249	validation_1-rmse:1.24485
# [20]	validation_0-rmse:1.12541	validation_1-rmse:1.23758
# [21]	validation_0-rmse:1.12078	validation_1-rmse:1.23759
# [22]	validation_0-rmse:1.11190	validation_1-rmse:1.23009
# [23]	validation_0-rmse:1.10587	validation_1-rmse:1.22775
# [24]	validation_0-rmse:1.09669	validation_1-rmse:1.22164
# [25]	validation_0-rmse:1.09268	validation_1-rmse:1.21868
# [26]	validation_0-rmse:1.08772	validation_1-rmse:1.21685
# [27]	validation_0-rmse:1.08126	validation_1-rmse:1.21067
# [28]	validation_0-rmse:1.07506	validation_1-rmse:1.20457
# [29]	validation_0-rmse:1.06606	validation_1-rmse:1.19285
# [30]	validation_0-rmse:1.05791	validation_1-rmse:1.18624
# [31]	validation_0-rmse:1.05355	validation_1-rmse:1.18482
# [32]	validation_0-rmse:1.04803	validation_1-rmse:1.18565
# [33]	validation_0-rmse:1.04092	validation_1-rmse:1.18045
# [34]	validation_0-rmse:1.03126	validation_1-rmse:1.16949
# [35]	validation_0-rmse:1.02520	validation_1-rmse:1.16534
# [36]	validation_0-rmse:1.01771	validation_1-rmse:1.16212
# [37]	validation_0-rmse:1.01055	validation_1-rmse:1.15396
# [38]	validation_0-rmse:1.00438	validation_1-rmse:1.14667
# [39]	validation_0-rmse:1.00140	validation_1-rmse:1.14496
# [40]	validation_0-rmse:0.99588	validation_1-rmse:1.13898
# [41]	validation_0-rmse:0.99035	validation_1-rmse:1.13671
# [42]	validation_0-rmse:0.98473	validation_1-rmse:1.13203
# [43]	validation_0-rmse:0.98056	validation_1-rmse:1.12801
# [44]	validation_0-rmse:0.97710	validation_1-rmse:1.12752
# [45]	validation_0-rmse:0.97301	validation_1-rmse:1.12761
# [46]	validation_0-rmse:0.96767	validation_1-rmse:1.12204
# [47]	validation_0-rmse:0.96316	validation_1-rmse:1.12189
# [48]	validation_0-rmse:0.95871	validation_1-rmse:1.11953
# [49]	validation_0-rmse:0.95413	validation_1-rmse:1.11593
# [50]	validation_0-rmse:0.95180	validation_1-rmse:1.11382
# [51]	validation_0-rmse:0.94560	validation_1-rmse:1.10869
# [52]	validation_0-rmse:0.94000	validation_1-rmse:1.10776
# [53]	validation_0-rmse:0.93537	validation_1-rmse:1.10422
# [54]	validation_0-rmse:0.93088	validation_1-rmse:1.09993
# [55]	validation_0-rmse:0.92668	validation_1-rmse:1.10072
# [56]	validation_0-rmse:0.92267	validation_1-rmse:1.09815
# [57]	validation_0-rmse:0.91882	validation_1-rmse:1.09199
# [58]	validation_0-rmse:0.91327	validation_1-rmse:1.09025
# [59]	validation_0-rmse:0.91008	validation_1-rmse:1.08830
# [60]	validation_0-rmse:0.90570	validation_1-rmse:1.08482
# [61]	validation_0-rmse:0.90211	validation_1-rmse:1.08126
# [62]	validation_0-rmse:0.89841	validation_1-rmse:1.07466
# [63]	validation_0-rmse:0.89381	validation_1-rmse:1.07202
# [64]	validation_0-rmse:0.88876	validation_1-rmse:1.07270
# [65]	validation_0-rmse:0.88373	validation_1-rmse:1.07331
# [66]	validation_0-rmse:0.88093	validation_1-rmse:1.07243
# [67]	validation_0-rmse:0.87655	validation_1-rmse:1.07337
# [68]	validation_0-rmse:0.87285	validation_1-rmse:1.07198
# [69]	validation_0-rmse:0.86767	validation_1-rmse:1.07094
# [70]	validation_0-rmse:0.86384	validation_1-rmse:1.06852
# [71]	validation_0-rmse:0.86062	validation_1-rmse:1.06500
# [72]	validation_0-rmse:0.85613	validation_1-rmse:1.06594
# [73]	validation_0-rmse:0.85308	validation_1-rmse:1.06769
# [74]	validation_0-rmse:0.84889	validation_1-rmse:1.06390
# [75]	validation_0-rmse:0.84497	validation_1-rmse:1.06260
# [76]	validation_0-rmse:0.84084	validation_1-rmse:1.05753
# [77]	validation_0-rmse:0.83672	validation_1-rmse:1.05050
# [78]	validation_0-rmse:0.83245	validation_1-rmse:1.05088
# [79]	validation_0-rmse:0.82846	validation_1-rmse:1.04714
# [80]	validation_0-rmse:0.82530	validation_1-rmse:1.04893
# [81]	validation_0-rmse:0.82276	validation_1-rmse:1.04952
# [82]	validation_0-rmse:0.81940	validation_1-rmse:1.04856
# [83]	validation_0-rmse:0.81416	validation_1-rmse:1.04410
# [84]	validation_0-rmse:0.81169	validation_1-rmse:1.04175
# [85]	validation_0-rmse:0.80449	validation_1-rmse:1.03937
# [0]	validation_0-rmse:1.34028	validation_1-rmse:1.24414
# [1]	validation_0-rmse:1.32847	validation_1-rmse:1.23508
# [2]	validation_0-rmse:1.31775	validation_1-rmse:1.22688
# [3]	validation_0-rmse:1.30881	validation_1-rmse:1.21702
# [4]	validation_0-rmse:1.29979	validation_1-rmse:1.20819
# [5]	validation_0-rmse:1.28902	validation_1-rmse:1.20086
# [6]	validation_0-rmse:1.28011	validation_1-rmse:1.19398
# [7]	validation_0-rmse:1.26822	validation_1-rmse:1.19236
# [8]	validation_0-rmse:1.26029	validation_1-rmse:1.18753
# [9]	validation_0-rmse:1.25186	validation_1-rmse:1.17853
# [10]	validation_0-rmse:1.24317	validation_1-rmse:1.17028
# [11]	validation_0-rmse:1.23445	validation_1-rmse:1.16070
# [12]	validation_0-rmse:1.22723	validation_1-rmse:1.15332
# [13]	validation_0-rmse:1.21871	validation_1-rmse:1.14585
# [14]	validation_0-rmse:1.21150	validation_1-rmse:1.13883
# [15]	validation_0-rmse:1.20674	validation_1-rmse:1.13195
# [16]	validation_0-rmse:1.19876	validation_1-rmse:1.12377
# [17]	validation_0-rmse:1.19260	validation_1-rmse:1.11780
# [18]	validation_0-rmse:1.18672	validation_1-rmse:1.11236
# [19]	validation_0-rmse:1.17628	validation_1-rmse:1.10373
# [20]	validation_0-rmse:1.17041	validation_1-rmse:1.09920
# [21]	validation_0-rmse:1.16212	validation_1-rmse:1.09192
# [22]	validation_0-rmse:1.15285	validation_1-rmse:1.08517
# [23]	validation_0-rmse:1.14649	validation_1-rmse:1.07829
# [24]	validation_0-rmse:1.14022	validation_1-rmse:1.06923
# [25]	validation_0-rmse:1.13203	validation_1-rmse:1.05975
# [26]	validation_0-rmse:1.12841	validation_1-rmse:1.05479
# [27]	validation_0-rmse:1.11967	validation_1-rmse:1.04736
# ...
# [5]	validation_0-rmse:1.35090	validation_1-rmse:0.83937
# [6]	validation_0-rmse:1.33713	validation_1-rmse:0.83030
# [7]	validation_0-rmse:1.32395	validation_1-rmse:0.82833
# [8]	validation_0-rmse:1.31451	validation_1-rmse:0.82998
# [9]	validation_0-rmse:1.30242	validation_1-rmse:0.83004
# [10]	validation_0-rmse:1.29195	validation_1-rmse:0.83048
# [11]	validation_0-rmse:1.27924	validation_1-rmse:0.82611
# [12]	validation_0-rmse:1.26871	validation_1-rmse:0.82231
# [13]	validation_0-rmse:1.26015	validation_1-rmse:0.82340
# [14]	validation_0-rmse:1.24784	validation_1-rmse:0.82503
# [15]	validation_0-rmse:1.23886	validation_1-rmse:0.82291
# [16]	validation_0-rmse:1.22794	validation_1-rmse:0.82102
# [17]	validation_0-rmse:1.21630	validation_1-rmse:0.81997
# [18]	validation_0-rmse:1.20647	validation_1-rmse:0.82207
# [19]	validation_0-rmse:1.19342	validation_1-rmse:0.82543
# [20]	validation_0-rmse:1.18338	validation_1-rmse:0.82330
# [21]	validation_0-rmse:1.17180	validation_1-rmse:0.82484
# [22]	validation_0-rmse:1.16394	validation_1-rmse:0.82576
# [23]	validation_0-rmse:1.15589	validation_1-rmse:0.82566
# [24]	validation_0-rmse:1.14694	validation_1-rmse:0.82545
# [25]	validation_0-rmse:1.13830	validation_1-rmse:0.83010
# [26]	validation_0-rmse:1.13245	validation_1-rmse:0.83085
# [27]	validation_0-rmse:1.12249	validation_1-rmse:0.83118
# [0]	validation_0-rmse:1.31935	validation_1-rmse:1.32444
# [1]	validation_0-rmse:1.30784	validation_1-rmse:1.31532
# [2]	validation_0-rmse:1.29515	validation_1-rmse:1.30168
# [3]	validation_0-rmse:1.28680	validation_1-rmse:1.29599
# [4]	validation_0-rmse:1.27914	validation_1-rmse:1.28622
# [5]	validation_0-rmse:1.26751	validation_1-rmse:1.27693
# [6]	validation_0-rmse:1.25506	validation_1-rmse:1.26822
# [7]	validation_0-rmse:1.24303	validation_1-rmse:1.26146
# [8]	validation_0-rmse:1.23471	validation_1-rmse:1.25753
# [9]	validation_0-rmse:1.22544	validation_1-rmse:1.25157
# [10]	validation_0-rmse:1.21968	validation_1-rmse:1.24925
# [11]	validation_0-rmse:1.21381	validation_1-rmse:1.24519
# [12]	validation_0-rmse:1.20526	validation_1-rmse:1.23713
# [13]	validation_0-rmse:1.20052	validation_1-rmse:1.23146
# [14]	validation_0-rmse:1.18680	validation_1-rmse:1.22487
# [15]	validation_0-rmse:1.17904	validation_1-rmse:1.21877
# [16]	validation_0-rmse:1.16810	validation_1-rmse:1.21352
# [17]	validation_0-rmse:1.15864	validation_1-rmse:1.20661
# [18]	validation_0-rmse:1.14776	validation_1-rmse:1.20010
# [19]	validation_0-rmse:1.13988	validation_1-rmse:1.19257
# [20]	validation_0-rmse:1.13385	validation_1-rmse:1.19222
# [21]	validation_0-rmse:1.12881	validation_1-rmse:1.19037
# [22]	validation_0-rmse:1.12190	validation_1-rmse:1.18565
# [23]	validation_0-rmse:1.11620	validation_1-rmse:1.18502
# [24]	validation_0-rmse:1.10899	validation_1-rmse:1.18285
# [25]	validation_0-rmse:1.09630	validation_1-rmse:1.17862
# [26]	validation_0-rmse:1.08796	validation_1-rmse:1.17050
# [27]	validation_0-rmse:1.08160	validation_1-rmse:1.16578
# [28]	validation_0-rmse:1.07657	validation_1-rmse:1.16088
# [29]	validation_0-rmse:1.06767	validation_1-rmse:1.15350
# [30]	validation_0-rmse:1.06243	validation_1-rmse:1.15087
# [31]	validation_0-rmse:1.05356	validation_1-rmse:1.14632
# [32]	validation_0-rmse:1.04747	validation_1-rmse:1.14311
# [33]	validation_0-rmse:1.03836	validation_1-rmse:1.13820
# [34]	validation_0-rmse:1.02863	validation_1-rmse:1.13300
# [35]	validation_0-rmse:1.02061	validation_1-rmse:1.12961
# [36]	validation_0-rmse:1.01441	validation_1-rmse:1.12759
# [37]	validation_0-rmse:1.00644	validation_1-rmse:1.12394
# [38]	validation_0-rmse:1.00035	validation_1-rmse:1.12126
# [39]	validation_0-rmse:0.99827	validation_1-rmse:1.11874
# [40]	validation_0-rmse:0.99294	validation_1-rmse:1.11534
# [41]	validation_0-rmse:0.98810	validation_1-rmse:1.11518
# [42]	validation_0-rmse:0.98214	validation_1-rmse:1.11094
# [43]	validation_0-rmse:0.97850	validation_1-rmse:1.11176
# [44]	validation_0-rmse:0.97372	validation_1-rmse:1.11001
# [45]	validation_0-rmse:0.96875	validation_1-rmse:1.10819
# [46]	validation_0-rmse:0.96477	validation_1-rmse:1.10916
# [47]	validation_0-rmse:0.95887	validation_1-rmse:1.10444
# [48]	validation_0-rmse:0.95383	validation_1-rmse:1.10364
# [49]	validation_0-rmse:0.94849	validation_1-rmse:1.09948
# [50]	validation_0-rmse:0.94655	validation_1-rmse:1.09693
# [51]	validation_0-rmse:0.94004	validation_1-rmse:1.09351
# [52]	validation_0-rmse:0.93520	validation_1-rmse:1.09156
# [53]	validation_0-rmse:0.92810	validation_1-rmse:1.08845
# [54]	validation_0-rmse:0.92600	validation_1-rmse:1.09105
# [55]	validation_0-rmse:0.92077	validation_1-rmse:1.08900
# [56]	validation_0-rmse:0.91446	validation_1-rmse:1.08848
# [57]	validation_0-rmse:0.90972	validation_1-rmse:1.08645
# [58]	validation_0-rmse:0.90434	validation_1-rmse:1.08498
# [59]	validation_0-rmse:0.89855	validation_1-rmse:1.08479
# [60]	validation_0-rmse:0.89444	validation_1-rmse:1.08399
# [61]	validation_0-rmse:0.89214	validation_1-rmse:1.08360
# [62]	validation_0-rmse:0.88457	validation_1-rmse:1.08258
# [63]	validation_0-rmse:0.87976	validation_1-rmse:1.08004
# [64]	validation_0-rmse:0.87579	validation_1-rmse:1.07950
# [65]	validation_0-rmse:0.87306	validation_1-rmse:1.07906
# [66]	validation_0-rmse:0.86965	validation_1-rmse:1.07855
# [67]	validation_0-rmse:0.86587	validation_1-rmse:1.07820
# [68]	validation_0-rmse:0.86391	validation_1-rmse:1.07503
# [69]	validation_0-rmse:0.85950	validation_1-rmse:1.07271
# [70]	validation_0-rmse:0.85830	validation_1-rmse:1.07399
# [71]	validation_0-rmse:0.85483	validation_1-rmse:1.07379
# [72]	validation_0-rmse:0.85138	validation_1-rmse:1.07216
# [73]	validation_0-rmse:0.84967	validation_1-rmse:1.07154
# [74]	validation_0-rmse:0.84198	validation_1-rmse:1.07163
# [75]	validation_0-rmse:0.83814	validation_1-rmse:1.07277
# [76]	validation_0-rmse:0.83445	validation_1-rmse:1.07176
# [77]	validation_0-rmse:0.83125	validation_1-rmse:1.07109
# [78]	validation_0-rmse:0.82776	validation_1-rmse:1.06878
# [79]	validation_0-rmse:0.82253	validation_1-rmse:1.06933
# [80]	validation_0-rmse:0.81839	validation_1-rmse:1.07014
# [81]	validation_0-rmse:0.81390	validation_1-rmse:1.06923
# [82]	validation_0-rmse:0.80954	validation_1-rmse:1.06801
# [83]	validation_0-rmse:0.80556	validation_1-rmse:1.06774
# [84]	validation_0-rmse:0.80250	validation_1-rmse:1.06685
# [85]	validation_0-rmse:0.79963	validation_1-rmse:1.06487
# [0]	validation_0-rmse:1.28220	validation_1-rmse:1.47189
# [1]	validation_0-rmse:1.27373	validation_1-rmse:1.46630
# [2]	validation_0-rmse:1.26405	validation_1-rmse:1.45167
# [3]	validation_0-rmse:1.25439	validation_1-rmse:1.43742
# [4]	validation_0-rmse:1.24366	validation_1-rmse:1.43182
# [5]	validation_0-rmse:1.23508	validation_1-rmse:1.42231
# [6]	validation_0-rmse:1.23052	validation_1-rmse:1.41784
# [7]	validation_0-rmse:1.22032	validation_1-rmse:1.40443
# [8]	validation_0-rmse:1.21337	validation_1-rmse:1.39478
# [9]	validation_0-rmse:1.20304	validation_1-rmse:1.38576
# [10]	validation_0-rmse:1.19599	validation_1-rmse:1.37697
# [11]	validation_0-rmse:1.18721	validation_1-rmse:1.36670
# [12]	validation_0-rmse:1.18039	validation_1-rmse:1.36040
# [13]	validation_0-rmse:1.17576	validation_1-rmse:1.35448
# [14]	validation_0-rmse:1.16564	validation_1-rmse:1.33892
# [15]	validation_0-rmse:1.16045	validation_1-rmse:1.33596
# [16]	validation_0-rmse:1.15282	validation_1-rmse:1.32660
# [17]	validation_0-rmse:1.14409	validation_1-rmse:1.31855
# [18]	validation_0-rmse:1.13685	validation_1-rmse:1.31108
# [19]	validation_0-rmse:1.13266	validation_1-rmse:1.30535
# [20]	validation_0-rmse:1.12566	validation_1-rmse:1.29611
# [21]	validation_0-rmse:1.11957	validation_1-rmse:1.28880
# [22]	validation_0-rmse:1.11062	validation_1-rmse:1.27829
# [23]	validation_0-rmse:1.10564	validation_1-rmse:1.27552
# [24]	validation_0-rmse:1.09809	validation_1-rmse:1.26941
# [25]	validation_0-rmse:1.09337	validation_1-rmse:1.26234
# [26]	validation_0-rmse:1.09031	validation_1-rmse:1.26186
# [27]	validation_0-rmse:1.08518	validation_1-rmse:1.25519
# [28]	validation_0-rmse:1.07953	validation_1-rmse:1.24917
# [29]	validation_0-rmse:1.07265	validation_1-rmse:1.24287
# [30]	validation_0-rmse:1.06984	validation_1-rmse:1.24168
# [31]	validation_0-rmse:1.06221	validation_1-rmse:1.23024
# [32]	validation_0-rmse:1.06037	validation_1-rmse:1.23026
# [33]	validation_0-rmse:1.05344	validation_1-rmse:1.22491
# [34]	validation_0-rmse:1.04823	validation_1-rmse:1.21735
# [35]	validation_0-rmse:1.04304	validation_1-rmse:1.21506
# [36]	validation_0-rmse:1.03586	validation_1-rmse:1.21098
# [37]	validation_0-rmse:1.03036	validation_1-rmse:1.20379
# [38]	validation_0-rmse:1.02515	validation_1-rmse:1.19717
# [39]	validation_0-rmse:1.02013	validation_1-rmse:1.19049
# [40]	validation_0-rmse:1.01503	validation_1-rmse:1.18636
# [41]	validation_0-rmse:1.00828	validation_1-rmse:1.17740
# [42]	validation_0-rmse:1.00222	validation_1-rmse:1.16996
# [43]	validation_0-rmse:0.99796	validation_1-rmse:1.16304
# [44]	validation_0-rmse:0.99226	validation_1-rmse:1.15979
# [45]	validation_0-rmse:0.98736	validation_1-rmse:1.15637
# [46]	validation_0-rmse:0.98374	validation_1-rmse:1.15090
# [47]	validation_0-rmse:0.97961	validation_1-rmse:1.14552
# [48]	validation_0-rmse:0.97537	validation_1-rmse:1.14141
# [49]	validation_0-rmse:0.97019	validation_1-rmse:1.13400
# [50]	validation_0-rmse:0.96718	validation_1-rmse:1.12922
# [51]	validation_0-rmse:0.96298	validation_1-rmse:1.12261
# [52]	validation_0-rmse:0.95718	validation_1-rmse:1.12075
# [53]	validation_0-rmse:0.95278	validation_1-rmse:1.11570
# [54]	validation_0-rmse:0.94933	validation_1-rmse:1.11376
# [55]	validation_0-rmse:0.94465	validation_1-rmse:1.11204
# [56]	validation_0-rmse:0.93808	validation_1-rmse:1.10177
# [57]	validation_0-rmse:0.93551	validation_1-rmse:1.09835
# [58]	validation_0-rmse:0.93052	validation_1-rmse:1.09142
# [59]	validation_0-rmse:0.92745	validation_1-rmse:1.08556
# [60]	validation_0-rmse:0.92586	validation_1-rmse:1.08634
# [61]	validation_0-rmse:0.92022	validation_1-rmse:1.08056
# [62]	validation_0-rmse:0.91606	validation_1-rmse:1.07556
# [63]	validation_0-rmse:0.91358	validation_1-rmse:1.07184
# [64]	validation_0-rmse:0.90875	validation_1-rmse:1.07116
# [65]	validation_0-rmse:0.90573	validation_1-rmse:1.06620
# [66]	validation_0-rmse:0.90223	validation_1-rmse:1.06301
# [67]	validation_0-rmse:0.89915	validation_1-rmse:1.06236
# [68]	validation_0-rmse:0.89340	validation_1-rmse:1.05646
# [69]	validation_0-rmse:0.89046	validation_1-rmse:1.05617
# [70]	validation_0-rmse:0.88746	validation_1-rmse:1.05362
# [71]	validation_0-rmse:0.88295	validation_1-rmse:1.04843
# [72]	validation_0-rmse:0.87897	validation_1-rmse:1.04467
# [73]	validation_0-rmse:0.87587	validation_1-rmse:1.04329
# [74]	validation_0-rmse:0.87311	validation_1-rmse:1.04201
# [75]	validation_0-rmse:0.86967	validation_1-rmse:1.04090
# [76]	validation_0-rmse:0.86597	validation_1-rmse:1.03810
# [77]	validation_0-rmse:0.86269	validation_1-rmse:1.03656
# [78]	validation_0-rmse:0.85932	validation_1-rmse:1.03423
# [79]	validation_0-rmse:0.85673	validation_1-rmse:1.03292
# [80]	validation_0-rmse:0.85219	validation_1-rmse:1.03156
# [81]	validation_0-rmse:0.84953	validation_1-rmse:1.02695
# [82]	validation_0-rmse:0.84696	validation_1-rmse:1.02578
# [83]	validation_0-rmse:0.84367	validation_1-rmse:1.02478
# [84]	validation_0-rmse:0.83879	validation_1-rmse:1.01881
# [85]	validation_0-rmse:0.83729	validation_1-rmse:1.01711
# [0]	validation_0-rmse:1.27456	validation_1-rmse:1.49842
# [1]	validation_0-rmse:1.26395	validation_1-rmse:1.49086
# [2]	validation_0-rmse:1.25312	validation_1-rmse:1.47684
# [3]	validation_0-rmse:1.24402	validation_1-rmse:1.46860
# [4]	validation_0-rmse:1.23457	validation_1-rmse:1.46406
# [5]	validation_0-rmse:1.22549	validation_1-rmse:1.45919
# [6]	validation_0-rmse:1.22088	validation_1-rmse:1.45563
# [7]	validation_0-rmse:1.21391	validation_1-rmse:1.44765
# [8]	validation_0-rmse:1.20821	validation_1-rmse:1.44584
# [9]	validation_0-rmse:1.20289	validation_1-rmse:1.44215
# [10]	validation_0-rmse:1.19579	validation_1-rmse:1.43392
# [11]	validation_0-rmse:1.18369	validation_1-rmse:1.42256
# [12]	validation_0-rmse:1.17283	validation_1-rmse:1.41171
# [13]	validation_0-rmse:1.16437	validation_1-rmse:1.40185
# [14]	validation_0-rmse:1.15366	validation_1-rmse:1.38646
# [15]	validation_0-rmse:1.14657	validation_1-rmse:1.38060
# [16]	validation_0-rmse:1.13989	validation_1-rmse:1.37482
# [17]	validation_0-rmse:1.13222	validation_1-rmse:1.36545
# [18]	validation_0-rmse:1.12641	validation_1-rmse:1.35733
# [19]	validation_0-rmse:1.11950	validation_1-rmse:1.34680
# [20]	validation_0-rmse:1.11285	validation_1-rmse:1.34142
# [21]	validation_0-rmse:1.10784	validation_1-rmse:1.33781
# [22]	validation_0-rmse:1.10030	validation_1-rmse:1.32991
# [23]	validation_0-rmse:1.09208	validation_1-rmse:1.32462
# [24]	validation_0-rmse:1.08357	validation_1-rmse:1.32132
# [25]	validation_0-rmse:1.07631	validation_1-rmse:1.31269
# [26]	validation_0-rmse:1.07096	validation_1-rmse:1.31282
# [27]	validation_0-rmse:1.06305	validation_1-rmse:1.29979
# [28]	validation_0-rmse:1.05582	validation_1-rmse:1.28926
# [29]	validation_0-rmse:1.04961	validation_1-rmse:1.28612
# [30]	validation_0-rmse:1.04396	validation_1-rmse:1.28042
# [31]	validation_0-rmse:1.03778	validation_1-rmse:1.27295
# [32]	validation_0-rmse:1.03184	validation_1-rmse:1.26655
# [33]	validation_0-rmse:1.02342	validation_1-rmse:1.25915
# [34]	validation_0-rmse:1.01646	validation_1-rmse:1.24951
# [35]	validation_0-rmse:1.00965	validation_1-rmse:1.24191
# [36]	validation_0-rmse:1.00414	validation_1-rmse:1.23725
# [37]	validation_0-rmse:0.99643	validation_1-rmse:1.22821
# [38]	validation_0-rmse:0.99385	validation_1-rmse:1.22432
# [39]	validation_0-rmse:0.98679	validation_1-rmse:1.21410
# [40]	validation_0-rmse:0.98079	validation_1-rmse:1.20932
# [41]	validation_0-rmse:0.97749	validation_1-rmse:1.20646
# [42]	validation_0-rmse:0.97120	validation_1-rmse:1.20531
# [43]	validation_0-rmse:0.96787	validation_1-rmse:1.20444
# [44]	validation_0-rmse:0.96263	validation_1-rmse:1.19848
# [45]	validation_0-rmse:0.95666	validation_1-rmse:1.19575
# [46]	validation_0-rmse:0.95303	validation_1-rmse:1.19689
# [47]	validation_0-rmse:0.94753	validation_1-rmse:1.19111
# [48]	validation_0-rmse:0.94422	validation_1-rmse:1.18819
# [49]	validation_0-rmse:0.94026	validation_1-rmse:1.18585
# [50]	validation_0-rmse:0.93489	validation_1-rmse:1.17936
# [51]	validation_0-rmse:0.93097	validation_1-rmse:1.17695
# [52]	validation_0-rmse:0.92675	validation_1-rmse:1.17456
# [53]	validation_0-rmse:0.92142	validation_1-rmse:1.16744
# [54]	validation_0-rmse:0.91487	validation_1-rmse:1.16465
# [55]	validation_0-rmse:0.91173	validation_1-rmse:1.16407
# [56]	validation_0-rmse:0.90821	validation_1-rmse:1.15965
# [57]	validation_0-rmse:0.90329	validation_1-rmse:1.15236
# [58]	validation_0-rmse:0.89863	validation_1-rmse:1.15121
# [59]	validation_0-rmse:0.89550	validation_1-rmse:1.15172
# [60]	validation_0-rmse:0.89127	validation_1-rmse:1.14865
# [61]	validation_0-rmse:0.88820	validation_1-rmse:1.14584
# [62]	validation_0-rmse:0.88408	validation_1-rmse:1.14202
# [63]	validation_0-rmse:0.87961	validation_1-rmse:1.13567
# [64]	validation_0-rmse:0.87579	validation_1-rmse:1.13388
# [65]	validation_0-rmse:0.87345	validation_1-rmse:1.13219
# [66]	validation_0-rmse:0.86978	validation_1-rmse:1.13168
# [67]	validation_0-rmse:0.86482	validation_1-rmse:1.13326
# [68]	validation_0-rmse:0.86151	validation_1-rmse:1.13056
# [69]	validation_0-rmse:0.85714	validation_1-rmse:1.12737
# [70]	validation_0-rmse:0.85177	validation_1-rmse:1.12344
# [71]	validation_0-rmse:0.84543	validation_1-rmse:1.11998
# [72]	validation_0-rmse:0.84148	validation_1-rmse:1.12031
# [73]	validation_0-rmse:0.83862	validation_1-rmse:1.11645
# [74]	validation_0-rmse:0.83291	validation_1-rmse:1.11052
# [75]	validation_0-rmse:0.82886	validation_1-rmse:1.10811
# [76]	validation_0-rmse:0.82462	validation_1-rmse:1.10280
# [77]	validation_0-rmse:0.82198	validation_1-rmse:1.09868
# [78]	validation_0-rmse:0.81860	validation_1-rmse:1.10059
# [79]	validation_0-rmse:0.81361	validation_1-rmse:1.09429
# [80]	validation_0-rmse:0.80907	validation_1-rmse:1.09188
# [81]	validation_0-rmse:0.80486	validation_1-rmse:1.08699
# [82]	validation_0-rmse:0.80192	validation_1-rmse:1.08394
# [83]	validation_0-rmse:0.79657	validation_1-rmse:1.08174
# [84]	validation_0-rmse:0.79292	validation_1-rmse:1.07826
# [85]	validation_0-rmse:0.79213	validation_1-rmse:1.07711

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-3.1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.232
# Uncertainty
# a0: 0.019+/-0.03
# a1: 0.139+/-0.025

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: b_STD: mean - 0.074, median - 0.075, CI - [0.054-0.092]
#
# SHAP-values for: contr_r_STD: mean - 0.07, median - 0.072, CI - [0.058-0.083]
#
# SHAP-values for: corr_r_MIN: mean - 0.069, median - 0.068, CI - [0.056-0.082]
#
# SHAP-values for: corr_r_Q25: mean - 0.078, median - 0.077, CI - [0.062-0.097]
#
# SHAP-values for: mf_chm_MIN: mean - 0.05, median - 0.051, CI - [0.037-0.065]
#
# SHAP-values for: r_MIN: mean - 0.088, median - 0.088, CI - [0.065-0.109]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['r_MIN', 'corr_r_Q25', 'b_STD', 'contr_r_STD', 'corr_r_MIN', 'mf_chm_MIN', ])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 79.292, median: 85.0,
#  pred. interval (P(0.025)-P(0.975)): 31.975-85.0,
#  conf. interval (p-value=0.95): 78.715-85.0
# ***
# Aggregate bias statistic:
#  mean: 0.249, median: 0.227,
#  pred. interval (P(0.025)-P(0.975)): -0.061-0.694,
#  conf. interval (p-value=0.95): 0.069-0.382
# ***
# Aggregate RMSE statistic:
#  mean: 1.029, median: 1.028, pred. interval (P(0.025)-P(0.975)): 0.756-1.332,
#  conf. interval (p-value=0.95): 0.884-1.168
# ***
# Aggregate MSE statistic:
#  mean: 1.085, median: 1.058, pred. interval (P(0.025)-P(0.975)): 0.572-1.773,
#  conf. interval (p-value=0.95): 0.784-1.367
# ***
# Aggregate R^2 statistic:
#  mean: 0.116, median: 0.123, pred. interval (P(0.025)-P(0.975)): -0.139-0.344,
#  conf. interval (p-value=0.95): 0.021-0.227
# ***
# Aggregate bias(%) statistic:
#  mean: 1806.676, median: -86.467, pred. interval (P(0.025)-P(0.975)): -189.922-901.956,
#  conf. interval (p-value=0.95): -105.127--33.369
# ***
# Aggregate RMSE(%) statistic:
#  mean: 12658.172, median: -338.254, pred. interval (P(0.025)-P(0.975)): -12652.444-4165.53,
#  conf. interval (p-value=0.95): -597.129--224.997
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -0.19, median: -0.181,
#  pred. interval (P(0.025)-P(0.975)): -0.579-0.228,
#  conf. interval (p-value=0.95): -0.377-0.001
# ***
# Aggregate RMSE statistic:
#  mean: 0.999, median: 0.961, pred. interval (P(0.025)-P(0.975)): 0.594-1.519,
#  conf. interval (p-value=0.95): 0.745-1.284
# ***
# Aggregate MSE statistic:
#  mean: 1.074, median: 0.924, pred. interval (P(0.025)-P(0.975)): 0.353-2.309,
#  conf. interval (p-value=0.95): 0.56-1.659
# ***
# Aggregate R^2 statistic:
#  mean: -0.004, median: 0.016, pred. interval (P(0.025)-P(0.975)): -0.33-0.249,
#  conf. interval (p-value=0.95): -0.128-0.131
# ***
# Aggregate bias(%) statistic:
#  mean: -13.051, median: -15.376, pred. interval (P(0.025)-P(0.975)): -39.52-28.259,
#  conf. interval (p-value=0.95): -26.897-0.393
# ***
# Aggregate RMSE(%) statistic:
#  mean: 81.499, median: 79.656, pred. interval (P(0.025)-P(0.975)): 56.728-109.018,
#  conf. interval (p-value=0.95): 67.87-95.892
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-3, -2, -1, 0, 1, 2])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 0.5, 1, 2, 3, 5])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=10, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.32256
# [1]	validation_0-rmse:1.31492
# [2]	validation_0-rmse:1.30927
# [3]	validation_0-rmse:1.29941
# [4]	validation_0-rmse:1.28766
# [5]	validation_0-rmse:1.27817
# [6]	validation_0-rmse:1.26702
# [7]	validation_0-rmse:1.25599
# [8]	validation_0-rmse:1.24743
# [9]	validation_0-rmse:1.23819
# [10]	validation_0-rmse:1.22981
# [11]	validation_0-rmse:1.22406
# [12]	validation_0-rmse:1.21633
# [13]	validation_0-rmse:1.20489
# [14]	validation_0-rmse:1.19618
# [15]	validation_0-rmse:1.18691
# [16]	validation_0-rmse:1.18161
# [17]	validation_0-rmse:1.17607
# [18]	validation_0-rmse:1.16928
# [19]	validation_0-rmse:1.16109
# [20]	validation_0-rmse:1.15316
# [21]	validation_0-rmse:1.14492
# [22]	validation_0-rmse:1.13493
# [23]	validation_0-rmse:1.12836
# [24]	validation_0-rmse:1.12122
# [25]	validation_0-rmse:1.11575
# [26]	validation_0-rmse:1.10601
# [27]	validation_0-rmse:1.09863
# [28]	validation_0-rmse:1.09014
# [29]	validation_0-rmse:1.08041
# [30]	validation_0-rmse:1.07676
# [31]	validation_0-rmse:1.07314
# [32]	validation_0-rmse:1.06585
# [33]	validation_0-rmse:1.06138
# [34]	validation_0-rmse:1.05378
# [35]	validation_0-rmse:1.04847
# [36]	validation_0-rmse:1.04142
# [37]	validation_0-rmse:1.03702
# [38]	validation_0-rmse:1.03102
# [39]	validation_0-rmse:1.02605
# [40]	validation_0-rmse:1.02013
# [41]	validation_0-rmse:1.01578
# [42]	validation_0-rmse:1.00996
# [43]	validation_0-rmse:1.00483
# [44]	validation_0-rmse:0.99824
# [45]	validation_0-rmse:0.99009
# [46]	validation_0-rmse:0.98385
# [47]	validation_0-rmse:0.98032
# [48]	validation_0-rmse:0.97577
# [49]	validation_0-rmse:0.97051
# [50]	validation_0-rmse:0.96524
# [51]	validation_0-rmse:0.96021
# [52]	validation_0-rmse:0.95504
# [53]	validation_0-rmse:0.94936
# [54]	validation_0-rmse:0.94432
# [55]	validation_0-rmse:0.93889
# [56]	validation_0-rmse:0.93220
# [57]	validation_0-rmse:0.92794
# [58]	validation_0-rmse:0.92396
# [59]	validation_0-rmse:0.92093
# [60]	validation_0-rmse:0.91762
# [61]	validation_0-rmse:0.91170
# [62]	validation_0-rmse:0.90592
# [63]	validation_0-rmse:0.90170
# [64]	validation_0-rmse:0.89844
# [65]	validation_0-rmse:0.89518
# [66]	validation_0-rmse:0.89188
# [67]	validation_0-rmse:0.88827
# [68]	validation_0-rmse:0.88556
# [69]	validation_0-rmse:0.88160
# [70]	validation_0-rmse:0.87787
# [71]	validation_0-rmse:0.87440
# [72]	validation_0-rmse:0.86910
# [73]	validation_0-rmse:0.86512
# [74]	validation_0-rmse:0.86142
# [75]	validation_0-rmse:0.85731
# [76]	validation_0-rmse:0.85568
# [77]	validation_0-rmse:0.85119
# [78]	validation_0-rmse:0.84664
# [79]	validation_0-rmse:0.84363
# [80]	validation_0-rmse:0.84214
# [81]	validation_0-rmse:0.83995
# [82]	validation_0-rmse:0.83654
# [83]	validation_0-rmse:0.83166
# [84]	validation_0-rmse:0.82900
# [85]	validation_0-rmse:0.82384

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 85

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.2
# Relative bias(%):  -84.97
# RMSE: 0.8
# Relative RMSE(%):  -326.192
# MSE: 0.7
# R square: 43.8%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-3.1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.702
# Uncertainty
# a0: 0.039+/-0.022
# a1: 0.304+/-0.020

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/07_LN_Tag_Cs_vs_CHM_RGB_XGB_model_2024_final.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/07_LN_Tag_Cs_vs_CHM_RGB_XGB_model_2024_final.txt")
