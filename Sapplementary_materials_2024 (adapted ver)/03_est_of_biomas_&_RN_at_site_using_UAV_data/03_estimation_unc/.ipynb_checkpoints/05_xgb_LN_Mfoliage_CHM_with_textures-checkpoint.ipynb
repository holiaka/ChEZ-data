# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../03_input_data/input_CHM_&_spectral_data_site2020.xlsx'
df = pd.read_excel(site_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0        4.771            1.792                -0.211            -0.261
# 1        5.808            2.496                -0.073             0.392
# 2        5.796            2.546                 0.030             0.501
# 3        5.826            2.643                 0.000             0.419
# 4        6.059            2.643                 0.122             0.647
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  \
# 0              -2.040          1.932     0.85    12.233545   19.097736    243
# 1              -0.139          2.674     1.00    14.964220   17.704655    248
# 2              -0.030          2.734     1.00    15.329449   17.559893    240
# 3              -0.431          2.785     0.97    15.392742   20.676994    244
# 4              -0.386          2.809     1.00    17.944009   21.851387    243
#
#    contr_g_MAX
# 0  2961.898193
# 1  2218.239746
# 2  2220.297119
# 3  3033.770752
# 4  3003.818848

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
#  9   g_MAX                 103 non-null    int64
#  10  contr_g_MAX           103 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 9.0 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Gs_cub_m", "ln_M_AG_kg_m2"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                  ln_Gs_cub_m                                             \
#                        count      mean       std    min      25%    50%
# Dominant_specias
# Alder                    4.0  5.907250  0.445830  5.342  5.65925  5.985
# Aspen                    1.0  4.956000       NaN  4.956  4.95600  4.956
# Birch                   23.0  4.676174  0.813911  2.398  4.56900  4.949
# Oak                      3.0  5.409667  0.406291  4.956  5.24450  5.533
# Pine                    71.0  4.990775  1.410734  1.609  4.44850  5.642
# Spruce                   1.0  6.431000       NaN  6.431  6.43100  6.431
#
#                                 ln_M_AG_kg_m2                             \
#                      75%    max         count      mean       std    min
# Dominant_specias
# Alder             6.2330  6.317           4.0  2.862250  0.386813  2.407
# Aspen             4.9560  4.956           1.0  1.932000       NaN  1.932
# Birch             5.2930  5.680          23.0  1.855783  0.744496  0.000
# Oak               5.6365  5.740           3.0  2.687333  0.316282  2.398
# Pine              5.9215  6.457          71.0  2.073789  1.174954 -0.693
# Spruce            6.4310  6.431           1.0  3.506000       NaN  3.506
#
#
#                       25%    50%     75%    max
# Dominant_specias
# Alder             2.61775  2.892  3.1365  3.258
# Aspen             1.93200  1.932  1.9320  1.932
# Birch             1.68350  2.001  2.3930  2.803
# Oak               2.51850  2.639  2.8320  3.025
# Pine              1.48500  2.588  2.8620  3.515
# Spruce            3.50600  3.506  3.5060  3.506

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000        103.000000
# mean      4.981961         1.863184             -0.327942         -0.063369
# std       1.264300         1.198731              0.866380          0.795365
# min       1.609000        -1.347000             -2.659000         -2.408000
# 25%       4.677000         1.584500             -0.554000         -0.386500
# 50%       5.342000         2.294000             -0.051000          0.182000
# 75%       5.875000         2.663000              0.207000          0.495000
# max       6.457000         3.428000              1.384000          1.756000
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX  \
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.015971       2.086126    0.808738    13.045021   17.907784
# std              0.799205       1.067542    0.276653     6.609366    7.523377
# min             -3.507000      -0.693000    0.090000     1.293138    2.733019
# 25%             -1.609000       1.758000    0.745000     8.206727   11.615798
# 50%             -0.844000       2.442000    0.960000    13.072916   18.269344
# 75%             -0.364000       2.809000    1.000000    17.432255   22.751595
# max              0.157000       3.515000    1.000000    28.916548   36.355442
#
#             g_MAX  contr_g_MAX
# count  103.000000   103.000000
# mean   240.572816  3008.938899
# std      9.358442   876.023529
# min    194.000000   815.342712
# 25%    236.500000  2464.687256
# 50%    243.000000  2994.793701
# 75%    247.000000  3464.970947
# max    253.000000  6230.940918

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_M_foliage_kg_m2"
indep_variables = ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0          4.771            1.792                -0.211            -0.261
# 1          5.808            2.496                -0.073             0.392
# 2          5.796            2.546                 0.030             0.501
# 3          5.826            2.643                 0.000             0.419
# 4          6.059            2.643                 0.122             0.647
# ..           ...              ...                   ...               ...
# 98         5.389            2.366                 0.531             0.182
# 99         2.398           -0.186                -1.309            -1.966
# 100        1.792           -0.968                -2.120            -1.966
# 101        4.836            1.733                -0.386             0.732
# 102        2.944           -0.211                -1.966            -1.470
#
#      ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  \
# 0                -2.040          1.932     0.85    12.233545   19.097736
# 1                -0.139          2.674     1.00    14.964220   17.704655
# 2                -0.030          2.734     1.00    15.329449   17.559893
# 3                -0.431          2.785     0.97    15.392742   20.676994
# 4                -0.386          2.809     1.00    17.944009   21.851387
# ..                  ...            ...      ...          ...         ...
# 98               -1.386          2.493     0.84    11.654902   17.083910
# 99               -3.507          0.000     0.17     4.722706   10.924606
# 100              -2.408         -0.511     0.17     4.620455   10.747827
# 101              -0.041          2.163     0.88     7.371921   11.443830
# 102              -1.609          0.182     0.28     2.765120    8.069081
#
#      g_MAX  contr_g_MAX
# 0      243  2961.898193
# 1      248  2218.239746
# 2      240  2220.297119
# 3      244  3033.770752
# 4      243  3003.818848
# ..     ...          ...
# 98     250  3469.805908
# 99     241  1748.447998
# 100    233  1708.681763
# 101    241  3066.087402
# 102    227  2756.989014
#
# [103 rows x 11 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  contr_g_MAX
# 0     0.85    12.233545   19.097736    243  2961.898193
# 1     1.00    14.964220   17.704655    248  2218.239746
# 2     1.00    15.329449   17.559893    240  2220.297119
# 3     0.97    15.392742   20.676994    244  3033.770752
# 4     1.00    17.944009   21.851387    243  3003.818848

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_foliage_kg_m2
# 0              -2.040
# 1              -0.139
# 2              -0.030
# 3              -0.431
# 4              -0.386

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.13656354852628427, 0.483533588123773, 0.5334366437459974]
#     Mean: 0.385
#     Std: 0.177
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.70641485 0.72138606 0.51063792]
#     Mean: 0.646
#     Std: 0.096
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.5150360778808594, 0.511330657914281, 0.47297338302696446]
#     Mean: 0.500
#     Std: 0.019
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.6164078606364067                    # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.46457263110215186                  # gamma
print('Gamma: ' + str(p2))

p3 = 0.026157819305236585                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 4            # max_depth
print('Max_depth: ' + str(p4))

p5 = 151          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.458494354105843                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.6164078606364067
# Gamma: 0.46457263110215186
# Learning_rate: 0.026157819305236585
# Max_depth: 4
# N_estimators: 151
# Subsample: 0.458494354105843

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.68138	validation_1-rmse:1.65201
# [1]	validation_0-rmse:1.64865	validation_1-rmse:1.62217
# [2]	validation_0-rmse:1.61017	validation_1-rmse:1.58436
# [3]	validation_0-rmse:1.57447	validation_1-rmse:1.54794
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:1.54012	validation_1-rmse:1.51042
# [5]	validation_0-rmse:1.50983	validation_1-rmse:1.47911
# [6]	validation_0-rmse:1.47764	validation_1-rmse:1.44644
# [7]	validation_0-rmse:1.44854	validation_1-rmse:1.41451
# [8]	validation_0-rmse:1.42073	validation_1-rmse:1.38403
# [9]	validation_0-rmse:1.39587	validation_1-rmse:1.36144
# [10]	validation_0-rmse:1.36924	validation_1-rmse:1.33059
# [11]	validation_0-rmse:1.34091	validation_1-rmse:1.30300
# [12]	validation_0-rmse:1.31590	validation_1-rmse:1.27301
# [13]	validation_0-rmse:1.29291	validation_1-rmse:1.25131
# [14]	validation_0-rmse:1.26523	validation_1-rmse:1.22234
# [15]	validation_0-rmse:1.24116	validation_1-rmse:1.19695
# [16]	validation_0-rmse:1.21673	validation_1-rmse:1.17064
# [17]	validation_0-rmse:1.19487	validation_1-rmse:1.15059
# [18]	validation_0-rmse:1.17270	validation_1-rmse:1.13055
# [19]	validation_0-rmse:1.14899	validation_1-rmse:1.10836
# [20]	validation_0-rmse:1.12835	validation_1-rmse:1.09012
# [21]	validation_0-rmse:1.10449	validation_1-rmse:1.06532
# [22]	validation_0-rmse:1.08562	validation_1-rmse:1.04761
# [23]	validation_0-rmse:1.06472	validation_1-rmse:1.02602
# [24]	validation_0-rmse:1.04506	validation_1-rmse:1.00678
# [25]	validation_0-rmse:1.02727	validation_1-rmse:0.98965
# [26]	validation_0-rmse:1.00465	validation_1-rmse:0.96822
# [27]	validation_0-rmse:0.98500	validation_1-rmse:0.94718
# [28]	validation_0-rmse:0.96876	validation_1-rmse:0.93213
# [29]	validation_0-rmse:0.95662	validation_1-rmse:0.91834
# [30]	validation_0-rmse:0.94257	validation_1-rmse:0.90456
# [31]	validation_0-rmse:0.92505	validation_1-rmse:0.88851
# [32]	validation_0-rmse:0.90974	validation_1-rmse:0.87219
# [33]	validation_0-rmse:0.89385	validation_1-rmse:0.85431
# [34]	validation_0-rmse:0.87713	validation_1-rmse:0.84102
# [35]	validation_0-rmse:0.86203	validation_1-rmse:0.82645
# [36]	validation_0-rmse:0.84675	validation_1-rmse:0.81181
# [37]	validation_0-rmse:0.83218	validation_1-rmse:0.80003
# [38]	validation_0-rmse:0.81672	validation_1-rmse:0.78511
# [39]	validation_0-rmse:0.80338	validation_1-rmse:0.77653
# [40]	validation_0-rmse:0.79272	validation_1-rmse:0.76557
# [41]	validation_0-rmse:0.77996	validation_1-rmse:0.75404
# [42]	validation_0-rmse:0.76705	validation_1-rmse:0.74474
# [43]	validation_0-rmse:0.75592	validation_1-rmse:0.73471
# [44]	validation_0-rmse:0.74371	validation_1-rmse:0.72172
# [45]	validation_0-rmse:0.73100	validation_1-rmse:0.71000
# [46]	validation_0-rmse:0.71994	validation_1-rmse:0.69982
# [47]	validation_0-rmse:0.70979	validation_1-rmse:0.69154
# [48]	validation_0-rmse:0.70056	validation_1-rmse:0.68396
# [49]	validation_0-rmse:0.69307	validation_1-rmse:0.67899
# [50]	validation_0-rmse:0.68571	validation_1-rmse:0.67284
# [51]	validation_0-rmse:0.67725	validation_1-rmse:0.66526
# [52]	validation_0-rmse:0.66697	validation_1-rmse:0.65915
# [53]	validation_0-rmse:0.65978	validation_1-rmse:0.65663
# [54]	validation_0-rmse:0.65283	validation_1-rmse:0.65043
# [55]	validation_0-rmse:0.64488	validation_1-rmse:0.64444
# [56]	validation_0-rmse:0.63926	validation_1-rmse:0.63888
# [57]	validation_0-rmse:0.63170	validation_1-rmse:0.63322
# [58]	validation_0-rmse:0.62665	validation_1-rmse:0.62956
# [59]	validation_0-rmse:0.61808	validation_1-rmse:0.62128
# [60]	validation_0-rmse:0.61034	validation_1-rmse:0.61600
# [61]	validation_0-rmse:0.60506	validation_1-rmse:0.61428
# [62]	validation_0-rmse:0.59667	validation_1-rmse:0.61015
# [63]	validation_0-rmse:0.58951	validation_1-rmse:0.60671
# [64]	validation_0-rmse:0.58206	validation_1-rmse:0.60248
# [65]	validation_0-rmse:0.57795	validation_1-rmse:0.60028
# [66]	validation_0-rmse:0.57401	validation_1-rmse:0.59608
# [67]	validation_0-rmse:0.56764	validation_1-rmse:0.59268
# [68]	validation_0-rmse:0.56149	validation_1-rmse:0.58964
# [69]	validation_0-rmse:0.55873	validation_1-rmse:0.58670
# [70]	validation_0-rmse:0.55242	validation_1-rmse:0.58213
# [71]	validation_0-rmse:0.54642	validation_1-rmse:0.57838
# [72]	validation_0-rmse:0.54167	validation_1-rmse:0.57423
# [73]	validation_0-rmse:0.53614	validation_1-rmse:0.57254
# [74]	validation_0-rmse:0.53138	validation_1-rmse:0.56808
# [75]	validation_0-rmse:0.52724	validation_1-rmse:0.56704
# [76]	validation_0-rmse:0.52479	validation_1-rmse:0.56659
# [77]	validation_0-rmse:0.51980	validation_1-rmse:0.56477
# [78]	validation_0-rmse:0.51670	validation_1-rmse:0.56308
# [79]	validation_0-rmse:0.51241	validation_1-rmse:0.55926
# [80]	validation_0-rmse:0.50746	validation_1-rmse:0.55685
# [81]	validation_0-rmse:0.50234	validation_1-rmse:0.55569
# [82]	validation_0-rmse:0.49841	validation_1-rmse:0.55150
# [83]	validation_0-rmse:0.49441	validation_1-rmse:0.55088
# [84]	validation_0-rmse:0.49089	validation_1-rmse:0.54912
# [85]	validation_0-rmse:0.48794	validation_1-rmse:0.54876
# [86]	validation_0-rmse:0.48531	validation_1-rmse:0.54676
# [87]	validation_0-rmse:0.48079	validation_1-rmse:0.54435
# [88]	validation_0-rmse:0.47727	validation_1-rmse:0.54237
# [89]	validation_0-rmse:0.47395	validation_1-rmse:0.54093
# [90]	validation_0-rmse:0.47023	validation_1-rmse:0.53817
# [91]	validation_0-rmse:0.46709	validation_1-rmse:0.53671
# [92]	validation_0-rmse:0.46369	validation_1-rmse:0.53586
# [93]	validation_0-rmse:0.46049	validation_1-rmse:0.53459
# [94]	validation_0-rmse:0.45861	validation_1-rmse:0.53247
# [95]	validation_0-rmse:0.45601	validation_1-rmse:0.53269
# [96]	validation_0-rmse:0.45395	validation_1-rmse:0.53328
# [97]	validation_0-rmse:0.45070	validation_1-rmse:0.53114
# [98]	validation_0-rmse:0.44723	validation_1-rmse:0.52822
# [99]	validation_0-rmse:0.44449	validation_1-rmse:0.52874
# [100]	validation_0-rmse:0.44103	validation_1-rmse:0.52776
# [101]	validation_0-rmse:0.43950	validation_1-rmse:0.52763
# [102]	validation_0-rmse:0.43775	validation_1-rmse:0.52680
# [103]	validation_0-rmse:0.43669	validation_1-rmse:0.52574
# [104]	validation_0-rmse:0.43425	validation_1-rmse:0.52493
# [105]	validation_0-rmse:0.43025	validation_1-rmse:0.52437
# [106]	validation_0-rmse:0.42934	validation_1-rmse:0.52344
# [107]	validation_0-rmse:0.42707	validation_1-rmse:0.52383
# [108]	validation_0-rmse:0.42659	validation_1-rmse:0.52048
# [109]	validation_0-rmse:0.42378	validation_1-rmse:0.51847
# [110]	validation_0-rmse:0.42102	validation_1-rmse:0.51750
# [111]	validation_0-rmse:0.41923	validation_1-rmse:0.51507
# [112]	validation_0-rmse:0.41700	validation_1-rmse:0.51350
# [113]	validation_0-rmse:0.41369	validation_1-rmse:0.51085
# [114]	validation_0-rmse:0.41245	validation_1-rmse:0.51150
# [115]	validation_0-rmse:0.41038	validation_1-rmse:0.51058
# [116]	validation_0-rmse:0.40927	validation_1-rmse:0.51041
# [117]	validation_0-rmse:0.40767	validation_1-rmse:0.51051
# [118]	validation_0-rmse:0.40682	validation_1-rmse:0.51197
# [119]	validation_0-rmse:0.40515	validation_1-rmse:0.51167
# [120]	validation_0-rmse:0.40312	validation_1-rmse:0.51271
# [121]	validation_0-rmse:0.40226	validation_1-rmse:0.51351
# [122]	validation_0-rmse:0.40153	validation_1-rmse:0.51297
# [123]	validation_0-rmse:0.39885	validation_1-rmse:0.51220
# [124]	validation_0-rmse:0.39755	validation_1-rmse:0.51363
# [125]	validation_0-rmse:0.39711	validation_1-rmse:0.51463
# [126]	validation_0-rmse:0.39527	validation_1-rmse:0.51604
# [127]	validation_0-rmse:0.39494	validation_1-rmse:0.51570
# [128]	validation_0-rmse:0.39396	validation_1-rmse:0.51542
# [129]	validation_0-rmse:0.39348	validation_1-rmse:0.51492
# [130]	validation_0-rmse:0.39165	validation_1-rmse:0.51379
# [131]	validation_0-rmse:0.38992	validation_1-rmse:0.51429
# [132]	validation_0-rmse:0.38863	validation_1-rmse:0.51299
# [133]	validation_0-rmse:0.38644	validation_1-rmse:0.51023
# [134]	validation_0-rmse:0.38475	validation_1-rmse:0.51162
# [135]	validation_0-rmse:0.38367	validation_1-rmse:0.51103
# [136]	validation_0-rmse:0.38286	validation_1-rmse:0.51104
# [137]	validation_0-rmse:0.38275	validation_1-rmse:0.50968
# [138]	validation_0-rmse:0.38191	validation_1-rmse:0.50906
# [139]	validation_0-rmse:0.38083	validation_1-rmse:0.51050
# [140]	validation_0-rmse:0.37933	validation_1-rmse:0.51065
# [141]	validation_0-rmse:0.37882	validation_1-rmse:0.51051
# [142]	validation_0-rmse:0.37735	validation_1-rmse:0.50989
# [143]	validation_0-rmse:0.37704	validation_1-rmse:0.50952
# [144]	validation_0-rmse:0.37661	validation_1-rmse:0.51051
# [145]	validation_0-rmse:0.37645	validation_1-rmse:0.51031
# [146]	validation_0-rmse:0.37466	validation_1-rmse:0.51100
# [147]	validation_0-rmse:0.37385	validation_1-rmse:0.50999
# [148]	validation_0-rmse:0.37385	validation_1-rmse:0.50998
# [149]	validation_0-rmse:0.37205	validation_1-rmse:0.51108
# [150]	validation_0-rmse:0.37098	validation_1-rmse:0.51103
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.70113	validation_1-rmse:1.57042
# [1]	validation_0-rmse:1.66659	validation_1-rmse:1.54137
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:1.62922	validation_1-rmse:1.51240
# [3]	validation_0-rmse:1.59369	validation_1-rmse:1.48423
# [4]	validation_0-rmse:1.56135	validation_1-rmse:1.45508
# [5]	validation_0-rmse:1.52677	validation_1-rmse:1.42692
# [6]	validation_0-rmse:1.49520	validation_1-rmse:1.40307
# [7]	validation_0-rmse:1.47042	validation_1-rmse:1.37876
# [8]	validation_0-rmse:1.44167	validation_1-rmse:1.35104
# [9]	validation_0-rmse:1.41450	validation_1-rmse:1.32758
# [10]	validation_0-rmse:1.38979	validation_1-rmse:1.30765
# [11]	validation_0-rmse:1.36243	validation_1-rmse:1.28667
# [12]	validation_0-rmse:1.33839	validation_1-rmse:1.26695
# [13]	validation_0-rmse:1.31478	validation_1-rmse:1.24334
# [14]	validation_0-rmse:1.28742	validation_1-rmse:1.21983
# [15]	validation_0-rmse:1.26187	validation_1-rmse:1.20099
# [16]	validation_0-rmse:1.23676	validation_1-rmse:1.18246
# [17]	validation_0-rmse:1.21285	validation_1-rmse:1.16178
# [18]	validation_0-rmse:1.19201	validation_1-rmse:1.14538
# [19]	validation_0-rmse:1.16942	validation_1-rmse:1.12948
# [20]	validation_0-rmse:1.14861	validation_1-rmse:1.11408
# [21]	validation_0-rmse:1.12772	validation_1-rmse:1.09866
# [22]	validation_0-rmse:1.10580	validation_1-rmse:1.08563
# [23]	validation_0-rmse:1.08584	validation_1-rmse:1.06915
# [24]	validation_0-rmse:1.06534	validation_1-rmse:1.05504
# [25]	validation_0-rmse:1.04421	validation_1-rmse:1.04001
# [26]	validation_0-rmse:1.02754	validation_1-rmse:1.02710
# [27]	validation_0-rmse:1.01131	validation_1-rmse:1.01316
# [28]	validation_0-rmse:0.99357	validation_1-rmse:0.99850
# [29]	validation_0-rmse:0.98051	validation_1-rmse:0.98781
# [30]	validation_0-rmse:0.96489	validation_1-rmse:0.97420
# [31]	validation_0-rmse:0.94839	validation_1-rmse:0.96273
# [32]	validation_0-rmse:0.93425	validation_1-rmse:0.94989
# [33]	validation_0-rmse:0.91970	validation_1-rmse:0.93683
# [34]	validation_0-rmse:0.90364	validation_1-rmse:0.92666
# [35]	validation_0-rmse:0.88963	validation_1-rmse:0.91589
# [36]	validation_0-rmse:0.87306	validation_1-rmse:0.90296
# [37]	validation_0-rmse:0.85810	validation_1-rmse:0.89164
# [38]	validation_0-rmse:0.84469	validation_1-rmse:0.87942
# [39]	validation_0-rmse:0.83361	validation_1-rmse:0.86601
# [40]	validation_0-rmse:0.82257	validation_1-rmse:0.85989
# [41]	validation_0-rmse:0.80951	validation_1-rmse:0.85061
# [42]	validation_0-rmse:0.79678	validation_1-rmse:0.84732
# [43]	validation_0-rmse:0.78656	validation_1-rmse:0.83885
# [44]	validation_0-rmse:0.77417	validation_1-rmse:0.83266
# [45]	validation_0-rmse:0.76285	validation_1-rmse:0.82409
# [46]	validation_0-rmse:0.75126	validation_1-rmse:0.81411
# [47]	validation_0-rmse:0.74134	validation_1-rmse:0.80768
# [48]	validation_0-rmse:0.73005	validation_1-rmse:0.79746
# [49]	validation_0-rmse:0.72269	validation_1-rmse:0.79228
# [50]	validation_0-rmse:0.71052	validation_1-rmse:0.78383
# [51]	validation_0-rmse:0.70248	validation_1-rmse:0.77661
# [52]	validation_0-rmse:0.69209	validation_1-rmse:0.77019
# [53]	validation_0-rmse:0.68403	validation_1-rmse:0.76656
# [54]	validation_0-rmse:0.67508	validation_1-rmse:0.76030
# [55]	validation_0-rmse:0.66687	validation_1-rmse:0.75598
# [56]	validation_0-rmse:0.66054	validation_1-rmse:0.75219
# [57]	validation_0-rmse:0.65378	validation_1-rmse:0.74682
# [58]	validation_0-rmse:0.64831	validation_1-rmse:0.74176
# [59]	validation_0-rmse:0.64021	validation_1-rmse:0.73657
# [60]	validation_0-rmse:0.63419	validation_1-rmse:0.73365
# [61]	validation_0-rmse:0.62770	validation_1-rmse:0.73067
# [62]	validation_0-rmse:0.61916	validation_1-rmse:0.72530
# [63]	validation_0-rmse:0.61243	validation_1-rmse:0.72078
# [64]	validation_0-rmse:0.60513	validation_1-rmse:0.71540
# [65]	validation_0-rmse:0.60091	validation_1-rmse:0.71225
# [66]	validation_0-rmse:0.59401	validation_1-rmse:0.70913
# [67]	validation_0-rmse:0.58738	validation_1-rmse:0.70461
# [68]	validation_0-rmse:0.58301	validation_1-rmse:0.70310
# [69]	validation_0-rmse:0.57585	validation_1-rmse:0.69775
# [70]	validation_0-rmse:0.57072	validation_1-rmse:0.69244
# [71]	validation_0-rmse:0.56449	validation_1-rmse:0.69127
# [72]	validation_0-rmse:0.55781	validation_1-rmse:0.68828
# [73]	validation_0-rmse:0.55342	validation_1-rmse:0.68639
# [74]	validation_0-rmse:0.55016	validation_1-rmse:0.68459
# [75]	validation_0-rmse:0.54555	validation_1-rmse:0.68065
# [76]	validation_0-rmse:0.54211	validation_1-rmse:0.67804
# [77]	validation_0-rmse:0.53802	validation_1-rmse:0.67569
# [78]	validation_0-rmse:0.53098	validation_1-rmse:0.66799
# [79]	validation_0-rmse:0.52671	validation_1-rmse:0.66554
# [80]	validation_0-rmse:0.52125	validation_1-rmse:0.66339
# [81]	validation_0-rmse:0.51805	validation_1-rmse:0.66246
# [82]	validation_0-rmse:0.51179	validation_1-rmse:0.65914
# [83]	validation_0-rmse:0.50589	validation_1-rmse:0.65536
# [84]	validation_0-rmse:0.50274	validation_1-rmse:0.65241
# [85]	validation_0-rmse:0.49896	validation_1-rmse:0.65148
# [86]	validation_0-rmse:0.49445	validation_1-rmse:0.64837
# [87]	validation_0-rmse:0.48996	validation_1-rmse:0.64566
# [88]	validation_0-rmse:0.48663	validation_1-rmse:0.64241
# [89]	validation_0-rmse:0.48458	validation_1-rmse:0.64195
# [90]	validation_0-rmse:0.48140	validation_1-rmse:0.64063
# [91]	validation_0-rmse:0.47705	validation_1-rmse:0.63813
# [92]	validation_0-rmse:0.47372	validation_1-rmse:0.63606
# [93]	validation_0-rmse:0.47025	validation_1-rmse:0.63404
# [94]	validation_0-rmse:0.46598	validation_1-rmse:0.63183
# [95]	validation_0-rmse:0.46208	validation_1-rmse:0.62892
# [96]	validation_0-rmse:0.46067	validation_1-rmse:0.62777
# [97]	validation_0-rmse:0.45876	validation_1-rmse:0.62801
# [98]	validation_0-rmse:0.45611	validation_1-rmse:0.62821
# [99]	validation_0-rmse:0.45368	validation_1-rmse:0.62880
# [100]	validation_0-rmse:0.45040	validation_1-rmse:0.62718
# [101]	validation_0-rmse:0.44854	validation_1-rmse:0.62530
# [102]	validation_0-rmse:0.44605	validation_1-rmse:0.62606
# [103]	validation_0-rmse:0.44121	validation_1-rmse:0.62301
# [104]	validation_0-rmse:0.43924	validation_1-rmse:0.62047
# [105]	validation_0-rmse:0.43670	validation_1-rmse:0.61892
# [106]	validation_0-rmse:0.43492	validation_1-rmse:0.61874
# [107]	validation_0-rmse:0.43296	validation_1-rmse:0.61847
# [108]	validation_0-rmse:0.43097	validation_1-rmse:0.61864
# [109]	validation_0-rmse:0.42786	validation_1-rmse:0.61727
# [110]	validation_0-rmse:0.42541	validation_1-rmse:0.61661
# [111]	validation_0-rmse:0.42425	validation_1-rmse:0.61498
# [112]	validation_0-rmse:0.42256	validation_1-rmse:0.61398
# [113]	validation_0-rmse:0.42040	validation_1-rmse:0.61238
# [114]	validation_0-rmse:0.41739	validation_1-rmse:0.61274
# [115]	validation_0-rmse:0.41441	validation_1-rmse:0.61240
# [116]	validation_0-rmse:0.41312	validation_1-rmse:0.61243
# [117]	validation_0-rmse:0.41151	validation_1-rmse:0.61296
# [118]	validation_0-rmse:0.41050	validation_1-rmse:0.61235
# [119]	validation_0-rmse:0.40897	validation_1-rmse:0.61047
# [120]	validation_0-rmse:0.40701	validation_1-rmse:0.60907
# [121]	validation_0-rmse:0.40589	validation_1-rmse:0.60695
# [122]	validation_0-rmse:0.40444	validation_1-rmse:0.60772
# [123]	validation_0-rmse:0.40354	validation_1-rmse:0.60787
# [124]	validation_0-rmse:0.40102	validation_1-rmse:0.60748
# [125]	validation_0-rmse:0.39991	validation_1-rmse:0.60634
# [126]	validation_0-rmse:0.39874	validation_1-rmse:0.60578
# [127]	validation_0-rmse:0.39797	validation_1-rmse:0.60478
# [128]	validation_0-rmse:0.39651	validation_1-rmse:0.60327
# [129]	validation_0-rmse:0.39505	validation_1-rmse:0.60165
# [130]	validation_0-rmse:0.39323	validation_1-rmse:0.60010
# [131]	validation_0-rmse:0.39168	validation_1-rmse:0.59901
# [132]	validation_0-rmse:0.39137	validation_1-rmse:0.59841
# [133]	validation_0-rmse:0.38947	validation_1-rmse:0.59641
# [134]	validation_0-rmse:0.38851	validation_1-rmse:0.59407
# [135]	validation_0-rmse:0.38728	validation_1-rmse:0.59563
# [136]	validation_0-rmse:0.38727	validation_1-rmse:0.59561
# [137]	validation_0-rmse:0.38714	validation_1-rmse:0.59517
# [138]	validation_0-rmse:0.38628	validation_1-rmse:0.59599
# [139]	validation_0-rmse:0.38424	validation_1-rmse:0.59447
# [140]	validation_0-rmse:0.38418	validation_1-rmse:0.59435
# [141]	validation_0-rmse:0.38309	validation_1-rmse:0.59441
# [142]	validation_0-rmse:0.38276	validation_1-rmse:0.59369
# [143]	validation_0-rmse:0.38004	validation_1-rmse:0.59332
# [144]	validation_0-rmse:0.37826	validation_1-rmse:0.59162
# [145]	validation_0-rmse:0.37748	validation_1-rmse:0.59107
# [146]	validation_0-rmse:0.37654	validation_1-rmse:0.59016
# [147]	validation_0-rmse:0.37585	validation_1-rmse:0.59076
# [148]	validation_0-rmse:0.37449	validation_1-rmse:0.59185
# [149]	validation_0-rmse:0.37259	validation_1-rmse:0.59100
# [150]	validation_0-rmse:0.37143	validation_1-rmse:0.59031
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.67273	validation_1-rmse:1.69013
# [1]	validation_0-rmse:1.63855	validation_1-rmse:1.65562
# [2]	validation_0-rmse:1.60151	validation_1-rmse:1.61515
# [3]	validation_0-rmse:1.56596	validation_1-rmse:1.57689
# [4]	validation_0-rmse:1.53440	validation_1-rmse:1.54434
# [5]	validation_0-rmse:1.50252	validation_1-rmse:1.51263
# [6]	validation_0-rmse:1.46980	validation_1-rmse:1.48035
# [7]	validation_0-rmse:1.44103	validation_1-rmse:1.45218
# [8]	validation_0-rmse:1.41461	validation_1-rmse:1.42737
# [9]	validation_0-rmse:1.38922	validation_1-rmse:1.39995
# [10]	validation_0-rmse:1.36059	validation_1-rmse:1.37113
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:1.33655	validation_1-rmse:1.34886
# [12]	validation_0-rmse:1.31110	validation_1-rmse:1.32522
# [13]	validation_0-rmse:1.28343	validation_1-rmse:1.29653
# [14]	validation_0-rmse:1.25941	validation_1-rmse:1.27170
# [15]	validation_0-rmse:1.23417	validation_1-rmse:1.24430
# [16]	validation_0-rmse:1.21392	validation_1-rmse:1.22280
# [17]	validation_0-rmse:1.19029	validation_1-rmse:1.19653
# [18]	validation_0-rmse:1.16695	validation_1-rmse:1.17087
# [19]	validation_0-rmse:1.14502	validation_1-rmse:1.14615
# [20]	validation_0-rmse:1.12390	validation_1-rmse:1.12427
# [21]	validation_0-rmse:1.10042	validation_1-rmse:1.09908
# [22]	validation_0-rmse:1.07850	validation_1-rmse:1.07391
# [23]	validation_0-rmse:1.05949	validation_1-rmse:1.05427
# [24]	validation_0-rmse:1.04158	validation_1-rmse:1.03490
# [25]	validation_0-rmse:1.02274	validation_1-rmse:1.01385
# [26]	validation_0-rmse:1.00347	validation_1-rmse:0.99663
# [27]	validation_0-rmse:0.98669	validation_1-rmse:0.98081
# [28]	validation_0-rmse:0.96962	validation_1-rmse:0.96181
# [29]	validation_0-rmse:0.95559	validation_1-rmse:0.94732
# [30]	validation_0-rmse:0.94390	validation_1-rmse:0.93267
# [31]	validation_0-rmse:0.93088	validation_1-rmse:0.92170
# [32]	validation_0-rmse:0.91501	validation_1-rmse:0.90719
# [33]	validation_0-rmse:0.90100	validation_1-rmse:0.89197
# [34]	validation_0-rmse:0.88723	validation_1-rmse:0.87565
# [35]	validation_0-rmse:0.87493	validation_1-rmse:0.86302
# [36]	validation_0-rmse:0.86203	validation_1-rmse:0.84804
# [37]	validation_0-rmse:0.84933	validation_1-rmse:0.83411
# [38]	validation_0-rmse:0.83636	validation_1-rmse:0.81949
# [39]	validation_0-rmse:0.82141	validation_1-rmse:0.80196
# [40]	validation_0-rmse:0.81027	validation_1-rmse:0.79298
# [41]	validation_0-rmse:0.79810	validation_1-rmse:0.78201
# [42]	validation_0-rmse:0.78789	validation_1-rmse:0.77112
# [43]	validation_0-rmse:0.77790	validation_1-rmse:0.76086
# [44]	validation_0-rmse:0.76624	validation_1-rmse:0.74770
# [45]	validation_0-rmse:0.75575	validation_1-rmse:0.73347
# [46]	validation_0-rmse:0.74653	validation_1-rmse:0.72374
# [47]	validation_0-rmse:0.73568	validation_1-rmse:0.71445
# [48]	validation_0-rmse:0.72618	validation_1-rmse:0.70679
# [49]	validation_0-rmse:0.71686	validation_1-rmse:0.69584
# [50]	validation_0-rmse:0.70944	validation_1-rmse:0.68746
# [51]	validation_0-rmse:0.70243	validation_1-rmse:0.68028
# [52]	validation_0-rmse:0.69303	validation_1-rmse:0.67144
# [53]	validation_0-rmse:0.68826	validation_1-rmse:0.66627
# [54]	validation_0-rmse:0.68254	validation_1-rmse:0.66294
# [55]	validation_0-rmse:0.67419	validation_1-rmse:0.65520
# [56]	validation_0-rmse:0.66610	validation_1-rmse:0.64718
# [57]	validation_0-rmse:0.65859	validation_1-rmse:0.63885
# [58]	validation_0-rmse:0.65089	validation_1-rmse:0.62881
# [59]	validation_0-rmse:0.64169	validation_1-rmse:0.62096
# [60]	validation_0-rmse:0.63479	validation_1-rmse:0.61329
# [61]	validation_0-rmse:0.62912	validation_1-rmse:0.60609
# [62]	validation_0-rmse:0.61994	validation_1-rmse:0.59747
# [63]	validation_0-rmse:0.61237	validation_1-rmse:0.59045
# [64]	validation_0-rmse:0.60763	validation_1-rmse:0.58462
# [65]	validation_0-rmse:0.60182	validation_1-rmse:0.57802
# [66]	validation_0-rmse:0.59486	validation_1-rmse:0.56851
# [67]	validation_0-rmse:0.58830	validation_1-rmse:0.56207
# [68]	validation_0-rmse:0.58263	validation_1-rmse:0.55810
# [69]	validation_0-rmse:0.57546	validation_1-rmse:0.54896
# [70]	validation_0-rmse:0.57012	validation_1-rmse:0.54203
# [71]	validation_0-rmse:0.56680	validation_1-rmse:0.53952
# [72]	validation_0-rmse:0.55987	validation_1-rmse:0.53849
# [73]	validation_0-rmse:0.55379	validation_1-rmse:0.53225
# [74]	validation_0-rmse:0.54924	validation_1-rmse:0.53004
# [75]	validation_0-rmse:0.54496	validation_1-rmse:0.52792
# [76]	validation_0-rmse:0.54058	validation_1-rmse:0.52389
# [77]	validation_0-rmse:0.53565	validation_1-rmse:0.51776
# [78]	validation_0-rmse:0.53126	validation_1-rmse:0.51383
# [79]	validation_0-rmse:0.52734	validation_1-rmse:0.50840
# [80]	validation_0-rmse:0.52248	validation_1-rmse:0.50359
# [81]	validation_0-rmse:0.51848	validation_1-rmse:0.50035
# [82]	validation_0-rmse:0.51414	validation_1-rmse:0.50000
# [83]	validation_0-rmse:0.50890	validation_1-rmse:0.49919
# [84]	validation_0-rmse:0.50529	validation_1-rmse:0.49485
# [85]	validation_0-rmse:0.50133	validation_1-rmse:0.49325
# [86]	validation_0-rmse:0.49765	validation_1-rmse:0.48989
# [87]	validation_0-rmse:0.49280	validation_1-rmse:0.48630
# [88]	validation_0-rmse:0.49048	validation_1-rmse:0.48542
# [89]	validation_0-rmse:0.48794	validation_1-rmse:0.48373
# [90]	validation_0-rmse:0.48440	validation_1-rmse:0.47972
# [91]	validation_0-rmse:0.48015	validation_1-rmse:0.47429
# [92]	validation_0-rmse:0.47623	validation_1-rmse:0.47116
# [93]	validation_0-rmse:0.47283	validation_1-rmse:0.46596
# [94]	validation_0-rmse:0.47057	validation_1-rmse:0.46684
# [95]	validation_0-rmse:0.46844	validation_1-rmse:0.46391
# [96]	validation_0-rmse:0.46647	validation_1-rmse:0.46327
# [97]	validation_0-rmse:0.46177	validation_1-rmse:0.46162
# [98]	validation_0-rmse:0.46112	validation_1-rmse:0.46071
# [99]	validation_0-rmse:0.46008	validation_1-rmse:0.46115
# [100]	validation_0-rmse:0.45673	validation_1-rmse:0.45685
# [101]	validation_0-rmse:0.45426	validation_1-rmse:0.45575
# [102]	validation_0-rmse:0.45215	validation_1-rmse:0.45484
# [103]	validation_0-rmse:0.44945	validation_1-rmse:0.45402
# [104]	validation_0-rmse:0.44745	validation_1-rmse:0.45255
# [105]	validation_0-rmse:0.44594	validation_1-rmse:0.44829
# [106]	validation_0-rmse:0.44319	validation_1-rmse:0.44573
# [107]	validation_0-rmse:0.44091	validation_1-rmse:0.44537
# [108]	validation_0-rmse:0.43970	validation_1-rmse:0.44541
# [109]	validation_0-rmse:0.43672	validation_1-rmse:0.44392
# [110]	validation_0-rmse:0.43476	validation_1-rmse:0.44347
# [111]	validation_0-rmse:0.43365	validation_1-rmse:0.44374
# [112]	validation_0-rmse:0.43049	validation_1-rmse:0.44059
# [113]	validation_0-rmse:0.42852	validation_1-rmse:0.43966
# [114]	validation_0-rmse:0.42614	validation_1-rmse:0.43880
# [115]	validation_0-rmse:0.42401	validation_1-rmse:0.43540
# [116]	validation_0-rmse:0.42175	validation_1-rmse:0.43407
# [117]	validation_0-rmse:0.42075	validation_1-rmse:0.43304
# [118]	validation_0-rmse:0.41960	validation_1-rmse:0.43446
# [119]	validation_0-rmse:0.41751	validation_1-rmse:0.43138
# [120]	validation_0-rmse:0.41577	validation_1-rmse:0.43040
# [121]	validation_0-rmse:0.41565	validation_1-rmse:0.43110
# [122]	validation_0-rmse:0.41474	validation_1-rmse:0.42835
# [123]	validation_0-rmse:0.41367	validation_1-rmse:0.42646
# [124]	validation_0-rmse:0.41208	validation_1-rmse:0.42749
# [125]	validation_0-rmse:0.41080	validation_1-rmse:0.42871
# [126]	validation_0-rmse:0.40816	validation_1-rmse:0.43043
# [127]	validation_0-rmse:0.40739	validation_1-rmse:0.42891
# [128]	validation_0-rmse:0.40597	validation_1-rmse:0.42668
# [129]	validation_0-rmse:0.40389	validation_1-rmse:0.42691
# [130]	validation_0-rmse:0.40130	validation_1-rmse:0.42671
# [131]	validation_0-rmse:0.39917	validation_1-rmse:0.42422
# [132]	validation_0-rmse:0.39852	validation_1-rmse:0.42297
# [133]	validation_0-rmse:0.39752	validation_1-rmse:0.42436
# [134]	validation_0-rmse:0.39611	validation_1-rmse:0.42326
# [135]	validation_0-rmse:0.39493	validation_1-rmse:0.42058
# [136]	validation_0-rmse:0.39455	validation_1-rmse:0.42027
# [137]	validation_0-rmse:0.39446	validation_1-rmse:0.42011
# [138]	validation_0-rmse:0.39387	validation_1-rmse:0.41851
# [139]	validation_0-rmse:0.39255	validation_1-rmse:0.41694
# [140]	validation_0-rmse:0.39245	validation_1-rmse:0.41675
# [141]	validation_0-rmse:0.39141	validation_1-rmse:0.41609
# [142]	validation_0-rmse:0.39128	validation_1-rmse:0.41584
# [143]	validation_0-rmse:0.38987	validation_1-rmse:0.41654
# [144]	validation_0-rmse:0.38908	validation_1-rmse:0.41678
# [145]	validation_0-rmse:0.38859	validation_1-rmse:0.41799
# [146]	validation_0-rmse:0.38771	validation_1-rmse:0.41780
# [147]	validation_0-rmse:0.38701	validation_1-rmse:0.41737
# [148]	validation_0-rmse:0.38512	validation_1-rmse:0.41538
# [149]	validation_0-rmse:0.38388	validation_1-rmse:0.41332
# [150]	validation_0-rmse:0.38272	validation_1-rmse:0.41319
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.70447	validation_1-rmse:1.57842
# [1]	validation_0-rmse:1.67798	validation_1-rmse:1.55165
# [2]	validation_0-rmse:1.63945	validation_1-rmse:1.51560
# [3]	validation_0-rmse:1.60900	validation_1-rmse:1.48402
# [4]	validation_0-rmse:1.57502	validation_1-rmse:1.45073
# [5]	validation_0-rmse:1.54590	validation_1-rmse:1.42213
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:1.51255	validation_1-rmse:1.39033
# [7]	validation_0-rmse:1.48583	validation_1-rmse:1.36330
# [8]	validation_0-rmse:1.45816	validation_1-rmse:1.33884
# [9]	validation_0-rmse:1.43476	validation_1-rmse:1.31540
# [10]	validation_0-rmse:1.40853	validation_1-rmse:1.29812
# [11]	validation_0-rmse:1.37972	validation_1-rmse:1.27010
# [12]	validation_0-rmse:1.35206	validation_1-rmse:1.24648
# [13]	validation_0-rmse:1.32612	validation_1-rmse:1.22913
# [14]	validation_0-rmse:1.29789	validation_1-rmse:1.20130
# [15]	validation_0-rmse:1.27277	validation_1-rmse:1.17622
# [16]	validation_0-rmse:1.24897	validation_1-rmse:1.15371
# [17]	validation_0-rmse:1.22542	validation_1-rmse:1.13077
# [18]	validation_0-rmse:1.20412	validation_1-rmse:1.11268
# [19]	validation_0-rmse:1.18092	validation_1-rmse:1.09069
# [20]	validation_0-rmse:1.15736	validation_1-rmse:1.07137
# [21]	validation_0-rmse:1.13698	validation_1-rmse:1.05337
# [22]	validation_0-rmse:1.11486	validation_1-rmse:1.03180
# [23]	validation_0-rmse:1.09628	validation_1-rmse:1.01411
# [24]	validation_0-rmse:1.07776	validation_1-rmse:0.99850
# [25]	validation_0-rmse:1.06048	validation_1-rmse:0.98766
# [26]	validation_0-rmse:1.04209	validation_1-rmse:0.98100
# [27]	validation_0-rmse:1.02671	validation_1-rmse:0.97245
# [28]	validation_0-rmse:1.00707	validation_1-rmse:0.95547
# [29]	validation_0-rmse:0.98988	validation_1-rmse:0.94222
# [30]	validation_0-rmse:0.97440	validation_1-rmse:0.93302
# [31]	validation_0-rmse:0.95795	validation_1-rmse:0.91915
# [32]	validation_0-rmse:0.94150	validation_1-rmse:0.90548
# [33]	validation_0-rmse:0.92369	validation_1-rmse:0.88718
# [34]	validation_0-rmse:0.91211	validation_1-rmse:0.87773
# [35]	validation_0-rmse:0.89568	validation_1-rmse:0.86571
# [36]	validation_0-rmse:0.87835	validation_1-rmse:0.84969
# [37]	validation_0-rmse:0.86413	validation_1-rmse:0.84055
# [38]	validation_0-rmse:0.85057	validation_1-rmse:0.82768
# [39]	validation_0-rmse:0.83819	validation_1-rmse:0.81944
# [40]	validation_0-rmse:0.82923	validation_1-rmse:0.81191
# [41]	validation_0-rmse:0.81515	validation_1-rmse:0.79926
# [42]	validation_0-rmse:0.80186	validation_1-rmse:0.78724
# [43]	validation_0-rmse:0.79008	validation_1-rmse:0.77850
# [44]	validation_0-rmse:0.77657	validation_1-rmse:0.76449
# [45]	validation_0-rmse:0.76522	validation_1-rmse:0.75410
# [46]	validation_0-rmse:0.75322	validation_1-rmse:0.74372
# [47]	validation_0-rmse:0.74498	validation_1-rmse:0.73911
# [48]	validation_0-rmse:0.73587	validation_1-rmse:0.73242
# [49]	validation_0-rmse:0.72586	validation_1-rmse:0.72938
# [50]	validation_0-rmse:0.71584	validation_1-rmse:0.72626
# [51]	validation_0-rmse:0.70623	validation_1-rmse:0.72424
# [52]	validation_0-rmse:0.69755	validation_1-rmse:0.71466
# [53]	validation_0-rmse:0.68822	validation_1-rmse:0.70887
# [54]	validation_0-rmse:0.68075	validation_1-rmse:0.70340
# [55]	validation_0-rmse:0.66851	validation_1-rmse:0.69626
# [56]	validation_0-rmse:0.66050	validation_1-rmse:0.69243
# [57]	validation_0-rmse:0.65103	validation_1-rmse:0.68664
# [58]	validation_0-rmse:0.64250	validation_1-rmse:0.68468
# [59]	validation_0-rmse:0.63555	validation_1-rmse:0.67995
# [60]	validation_0-rmse:0.62999	validation_1-rmse:0.67712
# [61]	validation_0-rmse:0.62405	validation_1-rmse:0.67156
# [62]	validation_0-rmse:0.61670	validation_1-rmse:0.66513
# [63]	validation_0-rmse:0.60941	validation_1-rmse:0.66046
# [64]	validation_0-rmse:0.60139	validation_1-rmse:0.65845
# [65]	validation_0-rmse:0.59429	validation_1-rmse:0.65450
# [66]	validation_0-rmse:0.58795	validation_1-rmse:0.64931
# [67]	validation_0-rmse:0.58213	validation_1-rmse:0.64551
# [68]	validation_0-rmse:0.57581	validation_1-rmse:0.64421
# [69]	validation_0-rmse:0.57099	validation_1-rmse:0.64127
# [70]	validation_0-rmse:0.56411	validation_1-rmse:0.63540
# [71]	validation_0-rmse:0.55923	validation_1-rmse:0.63247
# [72]	validation_0-rmse:0.55379	validation_1-rmse:0.63021
# [73]	validation_0-rmse:0.54869	validation_1-rmse:0.62856
# [74]	validation_0-rmse:0.54442	validation_1-rmse:0.62497
# [75]	validation_0-rmse:0.53977	validation_1-rmse:0.62391
# [76]	validation_0-rmse:0.53547	validation_1-rmse:0.62238
# [77]	validation_0-rmse:0.52864	validation_1-rmse:0.61946
# [78]	validation_0-rmse:0.52390	validation_1-rmse:0.61781
# [79]	validation_0-rmse:0.51995	validation_1-rmse:0.61726
# [80]	validation_0-rmse:0.51494	validation_1-rmse:0.61573
# [81]	validation_0-rmse:0.51267	validation_1-rmse:0.61417
# [82]	validation_0-rmse:0.50674	validation_1-rmse:0.61040
# [83]	validation_0-rmse:0.50249	validation_1-rmse:0.60932
# [84]	validation_0-rmse:0.49838	validation_1-rmse:0.60726
# [85]	validation_0-rmse:0.49581	validation_1-rmse:0.60617
# [86]	validation_0-rmse:0.49293	validation_1-rmse:0.60405
# [87]	validation_0-rmse:0.48939	validation_1-rmse:0.60132
# [88]	validation_0-rmse:0.48798	validation_1-rmse:0.59960
# [89]	validation_0-rmse:0.48488	validation_1-rmse:0.59883
# [90]	validation_0-rmse:0.48052	validation_1-rmse:0.59651
# [91]	validation_0-rmse:0.47720	validation_1-rmse:0.59641
# [92]	validation_0-rmse:0.47294	validation_1-rmse:0.59544
# [93]	validation_0-rmse:0.47112	validation_1-rmse:0.59392
# [94]	validation_0-rmse:0.46735	validation_1-rmse:0.59291
# [95]	validation_0-rmse:0.46460	validation_1-rmse:0.59233
# [96]	validation_0-rmse:0.46182	validation_1-rmse:0.59176
# [97]	validation_0-rmse:0.45896	validation_1-rmse:0.59268
# [98]	validation_0-rmse:0.45623	validation_1-rmse:0.59153
# [99]	validation_0-rmse:0.45350	validation_1-rmse:0.58946
# [100]	validation_0-rmse:0.45151	validation_1-rmse:0.58801
# [101]	validation_0-rmse:0.44743	validation_1-rmse:0.58630
# [102]	validation_0-rmse:0.44337	validation_1-rmse:0.58453
# [103]	validation_0-rmse:0.43940	validation_1-rmse:0.58111
# [104]	validation_0-rmse:0.43660	validation_1-rmse:0.57880
# [105]	validation_0-rmse:0.43496	validation_1-rmse:0.58075
# [106]	validation_0-rmse:0.43298	validation_1-rmse:0.58093
# [107]	validation_0-rmse:0.43098	validation_1-rmse:0.57869
# [108]	validation_0-rmse:0.42747	validation_1-rmse:0.57946
# [109]	validation_0-rmse:0.42660	validation_1-rmse:0.57907
# [110]	validation_0-rmse:0.42471	validation_1-rmse:0.58140
# [111]	validation_0-rmse:0.42230	validation_1-rmse:0.58158
# [112]	validation_0-rmse:0.42059	validation_1-rmse:0.58198
# [113]	validation_0-rmse:0.41783	validation_1-rmse:0.58026
# [114]	validation_0-rmse:0.41594	validation_1-rmse:0.58115
# [115]	validation_0-rmse:0.41348	validation_1-rmse:0.58118
# [116]	validation_0-rmse:0.41074	validation_1-rmse:0.57966
# [117]	validation_0-rmse:0.41016	validation_1-rmse:0.57947
# [118]	validation_0-rmse:0.40863	validation_1-rmse:0.57902
# [119]	validation_0-rmse:0.40731	validation_1-rmse:0.57864
# [120]	validation_0-rmse:0.40391	validation_1-rmse:0.57795
# [121]	validation_0-rmse:0.40364	validation_1-rmse:0.57811
# [122]	validation_0-rmse:0.40043	validation_1-rmse:0.58051
# [123]	validation_0-rmse:0.39910	validation_1-rmse:0.58193
# [124]	validation_0-rmse:0.39663	validation_1-rmse:0.58076
# [125]	validation_0-rmse:0.39496	validation_1-rmse:0.58100
# [126]	validation_0-rmse:0.39335	validation_1-rmse:0.58113
# [127]	validation_0-rmse:0.39217	validation_1-rmse:0.57994
# [128]	validation_0-rmse:0.38951	validation_1-rmse:0.57631
# [129]	validation_0-rmse:0.38896	validation_1-rmse:0.57676
# [130]	validation_0-rmse:0.38785	validation_1-rmse:0.57597
# [131]	validation_0-rmse:0.38578	validation_1-rmse:0.57768
# [132]	validation_0-rmse:0.38492	validation_1-rmse:0.57829
# [133]	validation_0-rmse:0.38404	validation_1-rmse:0.57839
# [134]	validation_0-rmse:0.38381	validation_1-rmse:0.57833
# [135]	validation_0-rmse:0.38350	validation_1-rmse:0.57907
# [136]	validation_0-rmse:0.38218	validation_1-rmse:0.57661
# [137]	validation_0-rmse:0.38135	validation_1-rmse:0.57702
# [138]	validation_0-rmse:0.38038	validation_1-rmse:0.57562
# [139]	validation_0-rmse:0.37956	validation_1-rmse:0.57457
# [140]	validation_0-rmse:0.37918	validation_1-rmse:0.57272
# [141]	validation_0-rmse:0.37833	validation_1-rmse:0.57183
# [142]	validation_0-rmse:0.37778	validation_1-rmse:0.57201
# [143]	validation_0-rmse:0.37726	validation_1-rmse:0.57185
# [144]	validation_0-rmse:0.37531	validation_1-rmse:0.57136
# [145]	validation_0-rmse:0.37525	validation_1-rmse:0.57135
# [146]	validation_0-rmse:0.37502	validation_1-rmse:0.57132
# [147]	validation_0-rmse:0.37487	validation_1-rmse:0.57131
# [148]	validation_0-rmse:0.37428	validation_1-rmse:0.57328
# [149]	validation_0-rmse:0.37420	validation_1-rmse:0.57225
# [150]	validation_0-rmse:0.37330	validation_1-rmse:0.57182
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.67301	validation_1-rmse:1.68471
# [1]	validation_0-rmse:1.63863	validation_1-rmse:1.64547
# [2]	validation_0-rmse:1.60256	validation_1-rmse:1.60711
# [3]	validation_0-rmse:1.56610	validation_1-rmse:1.56994
# [4]	validation_0-rmse:1.53876	validation_1-rmse:1.54212
# [5]	validation_0-rmse:1.50364	validation_1-rmse:1.50757
# [6]	validation_0-rmse:1.47409	validation_1-rmse:1.47669
# [7]	validation_0-rmse:1.44406	validation_1-rmse:1.44637
# [8]	validation_0-rmse:1.41652	validation_1-rmse:1.41592
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [9]	validation_0-rmse:1.38771	validation_1-rmse:1.38373
# [10]	validation_0-rmse:1.36119	validation_1-rmse:1.36641
# [11]	validation_0-rmse:1.33150	validation_1-rmse:1.33518
# [12]	validation_0-rmse:1.30486	validation_1-rmse:1.31396
# [13]	validation_0-rmse:1.28029	validation_1-rmse:1.28979
# [14]	validation_0-rmse:1.25489	validation_1-rmse:1.26666
# [15]	validation_0-rmse:1.22674	validation_1-rmse:1.24000
# [16]	validation_0-rmse:1.20034	validation_1-rmse:1.21276
# [17]	validation_0-rmse:1.17937	validation_1-rmse:1.19039
# [18]	validation_0-rmse:1.15753	validation_1-rmse:1.16721
# [19]	validation_0-rmse:1.13513	validation_1-rmse:1.14535
# [20]	validation_0-rmse:1.11667	validation_1-rmse:1.12795
# [21]	validation_0-rmse:1.09514	validation_1-rmse:1.10471
# [22]	validation_0-rmse:1.07832	validation_1-rmse:1.09029
# [23]	validation_0-rmse:1.05677	validation_1-rmse:1.06849
# [24]	validation_0-rmse:1.04057	validation_1-rmse:1.05305
# [25]	validation_0-rmse:1.02202	validation_1-rmse:1.03839
# [26]	validation_0-rmse:1.00808	validation_1-rmse:1.02591
# [27]	validation_0-rmse:0.99118	validation_1-rmse:1.00919
# [28]	validation_0-rmse:0.97095	validation_1-rmse:0.99146
# [29]	validation_0-rmse:0.95386	validation_1-rmse:0.97644
# [30]	validation_0-rmse:0.94216	validation_1-rmse:0.96246
# [31]	validation_0-rmse:0.92811	validation_1-rmse:0.94569
# [32]	validation_0-rmse:0.91313	validation_1-rmse:0.93289
# [33]	validation_0-rmse:0.89717	validation_1-rmse:0.91823
# [34]	validation_0-rmse:0.88113	validation_1-rmse:0.90236
# [35]	validation_0-rmse:0.86497	validation_1-rmse:0.88830
# [36]	validation_0-rmse:0.85154	validation_1-rmse:0.87571
# [37]	validation_0-rmse:0.83712	validation_1-rmse:0.86361
# [38]	validation_0-rmse:0.82221	validation_1-rmse:0.85117
# [39]	validation_0-rmse:0.81051	validation_1-rmse:0.83897
# [40]	validation_0-rmse:0.79609	validation_1-rmse:0.82316
# [41]	validation_0-rmse:0.78533	validation_1-rmse:0.81407
# [42]	validation_0-rmse:0.77358	validation_1-rmse:0.80288
# [43]	validation_0-rmse:0.76273	validation_1-rmse:0.79343
# [44]	validation_0-rmse:0.75444	validation_1-rmse:0.78746
# [45]	validation_0-rmse:0.74399	validation_1-rmse:0.77891
# [46]	validation_0-rmse:0.73389	validation_1-rmse:0.77296
# [47]	validation_0-rmse:0.72374	validation_1-rmse:0.76482
# [48]	validation_0-rmse:0.71379	validation_1-rmse:0.75569
# [49]	validation_0-rmse:0.70448	validation_1-rmse:0.74824
# [50]	validation_0-rmse:0.69588	validation_1-rmse:0.74172
# [51]	validation_0-rmse:0.68379	validation_1-rmse:0.73452
# [52]	validation_0-rmse:0.67739	validation_1-rmse:0.72838
# [53]	validation_0-rmse:0.67340	validation_1-rmse:0.72476
# [54]	validation_0-rmse:0.66542	validation_1-rmse:0.71570
# [55]	validation_0-rmse:0.65678	validation_1-rmse:0.71155
# [56]	validation_0-rmse:0.64992	validation_1-rmse:0.71033
# [57]	validation_0-rmse:0.64077	validation_1-rmse:0.70629
# [58]	validation_0-rmse:0.63302	validation_1-rmse:0.70085
# [59]	validation_0-rmse:0.62427	validation_1-rmse:0.69434
# [60]	validation_0-rmse:0.61573	validation_1-rmse:0.68885
# [61]	validation_0-rmse:0.60897	validation_1-rmse:0.68452
# [62]	validation_0-rmse:0.60039	validation_1-rmse:0.67839
# [63]	validation_0-rmse:0.59326	validation_1-rmse:0.67277
# [64]	validation_0-rmse:0.58815	validation_1-rmse:0.66889
# [65]	validation_0-rmse:0.58117	validation_1-rmse:0.66673
# [66]	validation_0-rmse:0.57324	validation_1-rmse:0.66565
# [67]	validation_0-rmse:0.56690	validation_1-rmse:0.66120
# [68]	validation_0-rmse:0.56219	validation_1-rmse:0.65867
# [69]	validation_0-rmse:0.55335	validation_1-rmse:0.65232
# [70]	validation_0-rmse:0.54847	validation_1-rmse:0.64592
# [71]	validation_0-rmse:0.54235	validation_1-rmse:0.64498
# [72]	validation_0-rmse:0.53626	validation_1-rmse:0.64244
# [73]	validation_0-rmse:0.53043	validation_1-rmse:0.63844
# [74]	validation_0-rmse:0.52380	validation_1-rmse:0.63648
# [75]	validation_0-rmse:0.51890	validation_1-rmse:0.63315
# [76]	validation_0-rmse:0.51443	validation_1-rmse:0.63138
# [77]	validation_0-rmse:0.50855	validation_1-rmse:0.62906
# [78]	validation_0-rmse:0.50550	validation_1-rmse:0.62605
# [79]	validation_0-rmse:0.50222	validation_1-rmse:0.62441
# [80]	validation_0-rmse:0.49783	validation_1-rmse:0.62368
# [81]	validation_0-rmse:0.49475	validation_1-rmse:0.62037
# [82]	validation_0-rmse:0.49190	validation_1-rmse:0.62038
# [83]	validation_0-rmse:0.48674	validation_1-rmse:0.61995
# [84]	validation_0-rmse:0.48192	validation_1-rmse:0.61858
# [85]	validation_0-rmse:0.47968	validation_1-rmse:0.61646
# [86]	validation_0-rmse:0.47640	validation_1-rmse:0.61683
# [87]	validation_0-rmse:0.47333	validation_1-rmse:0.61492
# [88]	validation_0-rmse:0.46995	validation_1-rmse:0.61284
# [89]	validation_0-rmse:0.46758	validation_1-rmse:0.61210
# [90]	validation_0-rmse:0.46319	validation_1-rmse:0.61012
# [91]	validation_0-rmse:0.46124	validation_1-rmse:0.60934
# [92]	validation_0-rmse:0.45917	validation_1-rmse:0.60775
# [93]	validation_0-rmse:0.45656	validation_1-rmse:0.60658
# [94]	validation_0-rmse:0.45314	validation_1-rmse:0.60529
# [95]	validation_0-rmse:0.45140	validation_1-rmse:0.60463
# [96]	validation_0-rmse:0.44826	validation_1-rmse:0.60475
# [97]	validation_0-rmse:0.44586	validation_1-rmse:0.60472
# [98]	validation_0-rmse:0.44363	validation_1-rmse:0.60290
# [99]	validation_0-rmse:0.44275	validation_1-rmse:0.60389
# [100]	validation_0-rmse:0.43951	validation_1-rmse:0.60371
# [101]	validation_0-rmse:0.43699	validation_1-rmse:0.60265
# [102]	validation_0-rmse:0.43460	validation_1-rmse:0.60398
# [103]	validation_0-rmse:0.43181	validation_1-rmse:0.60431
# [104]	validation_0-rmse:0.43071	validation_1-rmse:0.60381
# [105]	validation_0-rmse:0.42911	validation_1-rmse:0.60381
# [106]	validation_0-rmse:0.42646	validation_1-rmse:0.60221
# [107]	validation_0-rmse:0.42474	validation_1-rmse:0.60257
# [108]	validation_0-rmse:0.42352	validation_1-rmse:0.60134
# [109]	validation_0-rmse:0.42066	validation_1-rmse:0.59964
# [110]	validation_0-rmse:0.41832	validation_1-rmse:0.60077
# [111]	validation_0-rmse:0.41628	validation_1-rmse:0.60182
# [112]	validation_0-rmse:0.41203	validation_1-rmse:0.60165
# [113]	validation_0-rmse:0.40898	validation_1-rmse:0.60104
# [114]	validation_0-rmse:0.40702	validation_1-rmse:0.60050
# [115]	validation_0-rmse:0.40603	validation_1-rmse:0.60038
# [116]	validation_0-rmse:0.40435	validation_1-rmse:0.59921
# [117]	validation_0-rmse:0.40149	validation_1-rmse:0.59947
# [118]	validation_0-rmse:0.39996	validation_1-rmse:0.59879
# [119]	validation_0-rmse:0.39831	validation_1-rmse:0.59899
# [120]	validation_0-rmse:0.39679	validation_1-rmse:0.60021
# [121]	validation_0-rmse:0.39529	validation_1-rmse:0.60084
# [122]	validation_0-rmse:0.39363	validation_1-rmse:0.60019
# [123]	validation_0-rmse:0.39313	validation_1-rmse:0.59983
# [124]	validation_0-rmse:0.39122	validation_1-rmse:0.60278
# [125]	validation_0-rmse:0.39133	validation_1-rmse:0.60286
# [126]	validation_0-rmse:0.38912	validation_1-rmse:0.60317
# [127]	validation_0-rmse:0.38817	validation_1-rmse:0.60235
# [128]	validation_0-rmse:0.38715	validation_1-rmse:0.60308
# [129]	validation_0-rmse:0.38718	validation_1-rmse:0.60310
# [130]	validation_0-rmse:0.38512	validation_1-rmse:0.60239
# [131]	validation_0-rmse:0.38300	validation_1-rmse:0.60471
# [132]	validation_0-rmse:0.38201	validation_1-rmse:0.60475
# [133]	validation_0-rmse:0.38182	validation_1-rmse:0.60486
# [134]	validation_0-rmse:0.38147	validation_1-rmse:0.60459
# [135]	validation_0-rmse:0.38067	validation_1-rmse:0.60427
# [136]	validation_0-rmse:0.38031	validation_1-rmse:0.60399
# [137]	validation_0-rmse:0.37944	validation_1-rmse:0.60227
# [138]	validation_0-rmse:0.37783	validation_1-rmse:0.60231
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.68648	validation_1-rmse:1.62653
# [1]	validation_0-rmse:1.65018	validation_1-rmse:1.59576
# [2]	validation_0-rmse:1.61634	validation_1-rmse:1.56454
# [3]	validation_0-rmse:1.58230	validation_1-rmse:1.53365
# [4]	validation_0-rmse:1.55013	validation_1-rmse:1.50566
# [5]	validation_0-rmse:1.51856	validation_1-rmse:1.47643
# [6]	validation_0-rmse:1.48564	validation_1-rmse:1.44526
# [7]	validation_0-rmse:1.45359	validation_1-rmse:1.42134
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:1.42539	validation_1-rmse:1.39771
# [9]	validation_0-rmse:1.39959	validation_1-rmse:1.37515
# [10]	validation_0-rmse:1.37301	validation_1-rmse:1.35420
# [11]	validation_0-rmse:1.34471	validation_1-rmse:1.32361
# [12]	validation_0-rmse:1.31779	validation_1-rmse:1.30358
# [13]	validation_0-rmse:1.29306	validation_1-rmse:1.28424
# [14]	validation_0-rmse:1.26770	validation_1-rmse:1.26338
# [15]	validation_0-rmse:1.24077	validation_1-rmse:1.23837
# [16]	validation_0-rmse:1.21654	validation_1-rmse:1.21599
# [17]	validation_0-rmse:1.19387	validation_1-rmse:1.19787
# [18]	validation_0-rmse:1.17192	validation_1-rmse:1.17950
# [19]	validation_0-rmse:1.14581	validation_1-rmse:1.15963
# [20]	validation_0-rmse:1.12078	validation_1-rmse:1.13941
# [21]	validation_0-rmse:1.10051	validation_1-rmse:1.12270
# [22]	validation_0-rmse:1.07816	validation_1-rmse:1.10705
# [23]	validation_0-rmse:1.05838	validation_1-rmse:1.08944
# [24]	validation_0-rmse:1.03916	validation_1-rmse:1.07147
# [25]	validation_0-rmse:1.02299	validation_1-rmse:1.05687
# [26]	validation_0-rmse:1.00785	validation_1-rmse:1.04373
# [27]	validation_0-rmse:0.99239	validation_1-rmse:1.03471
# [28]	validation_0-rmse:0.97314	validation_1-rmse:1.01875
# [29]	validation_0-rmse:0.95671	validation_1-rmse:1.00847
# [30]	validation_0-rmse:0.94387	validation_1-rmse:0.99821
# [31]	validation_0-rmse:0.92846	validation_1-rmse:0.99219
# [32]	validation_0-rmse:0.91362	validation_1-rmse:0.97907
# [33]	validation_0-rmse:0.90324	validation_1-rmse:0.97251
# [34]	validation_0-rmse:0.88662	validation_1-rmse:0.96138
# [35]	validation_0-rmse:0.87328	validation_1-rmse:0.95313
# [36]	validation_0-rmse:0.86072	validation_1-rmse:0.94267
# [37]	validation_0-rmse:0.84763	validation_1-rmse:0.92923
# [38]	validation_0-rmse:0.83521	validation_1-rmse:0.92143
# [39]	validation_0-rmse:0.82281	validation_1-rmse:0.91281
# [40]	validation_0-rmse:0.80917	validation_1-rmse:0.90675
# [41]	validation_0-rmse:0.79572	validation_1-rmse:0.89592
# [42]	validation_0-rmse:0.78526	validation_1-rmse:0.88390
# [43]	validation_0-rmse:0.77460	validation_1-rmse:0.87669
# [44]	validation_0-rmse:0.76299	validation_1-rmse:0.86870
# [45]	validation_0-rmse:0.75326	validation_1-rmse:0.86540
# [46]	validation_0-rmse:0.74142	validation_1-rmse:0.85798
# [47]	validation_0-rmse:0.73337	validation_1-rmse:0.85319
# [48]	validation_0-rmse:0.72346	validation_1-rmse:0.84961
# [49]	validation_0-rmse:0.71279	validation_1-rmse:0.84230
# [50]	validation_0-rmse:0.70346	validation_1-rmse:0.83776
# [51]	validation_0-rmse:0.69406	validation_1-rmse:0.83435
# [52]	validation_0-rmse:0.68237	validation_1-rmse:0.82524
# [53]	validation_0-rmse:0.67159	validation_1-rmse:0.81816
# [54]	validation_0-rmse:0.66398	validation_1-rmse:0.81497
# ...
# [36]	validation_0-rmse:0.82963	validation_1-rmse:1.11215
# [37]	validation_0-rmse:0.81837	validation_1-rmse:1.09796
# [38]	validation_0-rmse:0.80429	validation_1-rmse:1.08230
# [39]	validation_0-rmse:0.79731	validation_1-rmse:1.07399
# [40]	validation_0-rmse:0.78833	validation_1-rmse:1.06772
# [41]	validation_0-rmse:0.77783	validation_1-rmse:1.05784
# [42]	validation_0-rmse:0.76477	validation_1-rmse:1.04221
# [43]	validation_0-rmse:0.75707	validation_1-rmse:1.03196
# [44]	validation_0-rmse:0.74375	validation_1-rmse:1.01707
# [45]	validation_0-rmse:0.73405	validation_1-rmse:1.00476
# [46]	validation_0-rmse:0.72422	validation_1-rmse:0.99404
# [47]	validation_0-rmse:0.71395	validation_1-rmse:0.98159
# [48]	validation_0-rmse:0.70383	validation_1-rmse:0.97390
# [49]	validation_0-rmse:0.69492	validation_1-rmse:0.96689
# [50]	validation_0-rmse:0.68670	validation_1-rmse:0.96125
# [51]	validation_0-rmse:0.68038	validation_1-rmse:0.95219
# [52]	validation_0-rmse:0.67153	validation_1-rmse:0.94420
# [53]	validation_0-rmse:0.66195	validation_1-rmse:0.93548
# [54]	validation_0-rmse:0.65413	validation_1-rmse:0.92816
# [55]	validation_0-rmse:0.64480	validation_1-rmse:0.91746
# [56]	validation_0-rmse:0.63976	validation_1-rmse:0.90919
# [57]	validation_0-rmse:0.63022	validation_1-rmse:0.89715
# [58]	validation_0-rmse:0.62381	validation_1-rmse:0.89215
# [59]	validation_0-rmse:0.61514	validation_1-rmse:0.88168
# [60]	validation_0-rmse:0.60809	validation_1-rmse:0.87411
# [61]	validation_0-rmse:0.60100	validation_1-rmse:0.86745
# [62]	validation_0-rmse:0.59203	validation_1-rmse:0.85799
# [63]	validation_0-rmse:0.58651	validation_1-rmse:0.85186
# [64]	validation_0-rmse:0.57803	validation_1-rmse:0.84070
# [65]	validation_0-rmse:0.57182	validation_1-rmse:0.83215
# [66]	validation_0-rmse:0.56751	validation_1-rmse:0.82825
# [67]	validation_0-rmse:0.56274	validation_1-rmse:0.82361
# [68]	validation_0-rmse:0.55905	validation_1-rmse:0.81905
# [69]	validation_0-rmse:0.55601	validation_1-rmse:0.81426
# [70]	validation_0-rmse:0.55012	validation_1-rmse:0.80798
# [71]	validation_0-rmse:0.54719	validation_1-rmse:0.80754
# [72]	validation_0-rmse:0.54191	validation_1-rmse:0.80103
# [73]	validation_0-rmse:0.53727	validation_1-rmse:0.79845
# [74]	validation_0-rmse:0.53102	validation_1-rmse:0.78948
# [75]	validation_0-rmse:0.52538	validation_1-rmse:0.78541
# [76]	validation_0-rmse:0.51984	validation_1-rmse:0.78214
# [77]	validation_0-rmse:0.51457	validation_1-rmse:0.77758
# [78]	validation_0-rmse:0.50999	validation_1-rmse:0.77279
# [79]	validation_0-rmse:0.50565	validation_1-rmse:0.77138
# [80]	validation_0-rmse:0.50055	validation_1-rmse:0.76606
# [81]	validation_0-rmse:0.49720	validation_1-rmse:0.76326
# [82]	validation_0-rmse:0.49326	validation_1-rmse:0.75843
# [83]	validation_0-rmse:0.48793	validation_1-rmse:0.75114
# [84]	validation_0-rmse:0.48439	validation_1-rmse:0.74594
# [85]	validation_0-rmse:0.48306	validation_1-rmse:0.74585
# [86]	validation_0-rmse:0.47895	validation_1-rmse:0.74032
# [87]	validation_0-rmse:0.47626	validation_1-rmse:0.73645
# [88]	validation_0-rmse:0.47342	validation_1-rmse:0.73330
# [89]	validation_0-rmse:0.47040	validation_1-rmse:0.72693
# [90]	validation_0-rmse:0.46658	validation_1-rmse:0.72059
# [91]	validation_0-rmse:0.46351	validation_1-rmse:0.71321
# [92]	validation_0-rmse:0.46140	validation_1-rmse:0.71370
# [93]	validation_0-rmse:0.45640	validation_1-rmse:0.70952
# [94]	validation_0-rmse:0.45321	validation_1-rmse:0.70860
# [95]	validation_0-rmse:0.45055	validation_1-rmse:0.70727
# [96]	validation_0-rmse:0.44859	validation_1-rmse:0.70439
# [97]	validation_0-rmse:0.44769	validation_1-rmse:0.70231
# [98]	validation_0-rmse:0.44513	validation_1-rmse:0.69949
# [99]	validation_0-rmse:0.44271	validation_1-rmse:0.69643
# [100]	validation_0-rmse:0.44048	validation_1-rmse:0.69526
# [101]	validation_0-rmse:0.43874	validation_1-rmse:0.69183
# [102]	validation_0-rmse:0.43595	validation_1-rmse:0.69054
# [103]	validation_0-rmse:0.43288	validation_1-rmse:0.68995
# [104]	validation_0-rmse:0.43082	validation_1-rmse:0.68770
# [105]	validation_0-rmse:0.42759	validation_1-rmse:0.68207
# [106]	validation_0-rmse:0.42426	validation_1-rmse:0.68063
# [107]	validation_0-rmse:0.42258	validation_1-rmse:0.68055
# [108]	validation_0-rmse:0.42014	validation_1-rmse:0.67583
# [109]	validation_0-rmse:0.41785	validation_1-rmse:0.67395
# [110]	validation_0-rmse:0.41592	validation_1-rmse:0.67268
# [111]	validation_0-rmse:0.41449	validation_1-rmse:0.66790
# [112]	validation_0-rmse:0.41326	validation_1-rmse:0.66431
# [113]	validation_0-rmse:0.41188	validation_1-rmse:0.66198
# [114]	validation_0-rmse:0.41046	validation_1-rmse:0.66112
# [115]	validation_0-rmse:0.40776	validation_1-rmse:0.66141
# [116]	validation_0-rmse:0.40645	validation_1-rmse:0.65826
# [117]	validation_0-rmse:0.40551	validation_1-rmse:0.65889
# [118]	validation_0-rmse:0.40424	validation_1-rmse:0.65972
# [119]	validation_0-rmse:0.40281	validation_1-rmse:0.65720
# [120]	validation_0-rmse:0.40173	validation_1-rmse:0.65575
# [121]	validation_0-rmse:0.40056	validation_1-rmse:0.65436
# [122]	validation_0-rmse:0.39863	validation_1-rmse:0.65302
# [123]	validation_0-rmse:0.39838	validation_1-rmse:0.65218
# [124]	validation_0-rmse:0.39679	validation_1-rmse:0.65058
# [125]	validation_0-rmse:0.39660	validation_1-rmse:0.65081
# [126]	validation_0-rmse:0.39561	validation_1-rmse:0.65029
# [127]	validation_0-rmse:0.39378	validation_1-rmse:0.64778
# [128]	validation_0-rmse:0.39216	validation_1-rmse:0.64762
# [129]	validation_0-rmse:0.39229	validation_1-rmse:0.64812
# [130]	validation_0-rmse:0.39141	validation_1-rmse:0.64674
# [131]	validation_0-rmse:0.38954	validation_1-rmse:0.64643
# [132]	validation_0-rmse:0.38756	validation_1-rmse:0.64643
# [133]	validation_0-rmse:0.38742	validation_1-rmse:0.64588
# [134]	validation_0-rmse:0.38535	validation_1-rmse:0.64050
# [135]	validation_0-rmse:0.38453	validation_1-rmse:0.63963
# [136]	validation_0-rmse:0.38262	validation_1-rmse:0.63907
# [137]	validation_0-rmse:0.38191	validation_1-rmse:0.63600
# [138]	validation_0-rmse:0.38076	validation_1-rmse:0.63250
# [139]	validation_0-rmse:0.37944	validation_1-rmse:0.63113
# [140]	validation_0-rmse:0.37774	validation_1-rmse:0.62909
# [141]	validation_0-rmse:0.37675	validation_1-rmse:0.62694
# [142]	validation_0-rmse:0.37530	validation_1-rmse:0.62701
# [143]	validation_0-rmse:0.37435	validation_1-rmse:0.62541
# [144]	validation_0-rmse:0.37375	validation_1-rmse:0.62576
# [145]	validation_0-rmse:0.37223	validation_1-rmse:0.62672
# [146]	validation_0-rmse:0.37221	validation_1-rmse:0.62663
# [147]	validation_0-rmse:0.37113	validation_1-rmse:0.62683
# [148]	validation_0-rmse:0.37044	validation_1-rmse:0.62683
# [149]	validation_0-rmse:0.37010	validation_1-rmse:0.62597
# [150]	validation_0-rmse:0.37005	validation_1-rmse:0.62680
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.64358	validation_1-rmse:1.78509
# [1]	validation_0-rmse:1.60882	validation_1-rmse:1.74683
# [2]	validation_0-rmse:1.57572	validation_1-rmse:1.71089
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:1.54336	validation_1-rmse:1.67504
# [4]	validation_0-rmse:1.51000	validation_1-rmse:1.64166
# [5]	validation_0-rmse:1.48003	validation_1-rmse:1.60737
# [6]	validation_0-rmse:1.45001	validation_1-rmse:1.57236
# [7]	validation_0-rmse:1.42238	validation_1-rmse:1.54268
# [8]	validation_0-rmse:1.39700	validation_1-rmse:1.51776
# [9]	validation_0-rmse:1.36990	validation_1-rmse:1.49290
# [10]	validation_0-rmse:1.34520	validation_1-rmse:1.46410
# [11]	validation_0-rmse:1.31946	validation_1-rmse:1.43714
# [12]	validation_0-rmse:1.29849	validation_1-rmse:1.41441
# [13]	validation_0-rmse:1.27142	validation_1-rmse:1.38197
# [14]	validation_0-rmse:1.24857	validation_1-rmse:1.35578
# [15]	validation_0-rmse:1.22354	validation_1-rmse:1.33082
# [16]	validation_0-rmse:1.19644	validation_1-rmse:1.30078
# [17]	validation_0-rmse:1.17718	validation_1-rmse:1.27967
# [18]	validation_0-rmse:1.15651	validation_1-rmse:1.25661
# [19]	validation_0-rmse:1.13773	validation_1-rmse:1.23594
# [20]	validation_0-rmse:1.11803	validation_1-rmse:1.21445
# [21]	validation_0-rmse:1.09640	validation_1-rmse:1.18784
# [22]	validation_0-rmse:1.07478	validation_1-rmse:1.16559
# [23]	validation_0-rmse:1.05293	validation_1-rmse:1.13836
# [24]	validation_0-rmse:1.03514	validation_1-rmse:1.11798
# [25]	validation_0-rmse:1.01911	validation_1-rmse:1.10080
# [26]	validation_0-rmse:1.00682	validation_1-rmse:1.09260
# [27]	validation_0-rmse:0.99133	validation_1-rmse:1.07486
# [28]	validation_0-rmse:0.97574	validation_1-rmse:1.05746
# [29]	validation_0-rmse:0.96463	validation_1-rmse:1.04771
# [30]	validation_0-rmse:0.94836	validation_1-rmse:1.03276
# [31]	validation_0-rmse:0.93466	validation_1-rmse:1.01996
# [32]	validation_0-rmse:0.92292	validation_1-rmse:1.01205
# [33]	validation_0-rmse:0.91018	validation_1-rmse:0.99883
# [34]	validation_0-rmse:0.89533	validation_1-rmse:0.97976
# [35]	validation_0-rmse:0.88049	validation_1-rmse:0.96111
# [36]	validation_0-rmse:0.86517	validation_1-rmse:0.94714
# [37]	validation_0-rmse:0.84850	validation_1-rmse:0.92795
# [38]	validation_0-rmse:0.83411	validation_1-rmse:0.91173
# [39]	validation_0-rmse:0.82144	validation_1-rmse:0.89829
# [40]	validation_0-rmse:0.81033	validation_1-rmse:0.88791
# [41]	validation_0-rmse:0.79744	validation_1-rmse:0.87332
# [42]	validation_0-rmse:0.78539	validation_1-rmse:0.86062
# [43]	validation_0-rmse:0.77231	validation_1-rmse:0.84538
# [44]	validation_0-rmse:0.76250	validation_1-rmse:0.83496
# [45]	validation_0-rmse:0.75553	validation_1-rmse:0.82716
# [46]	validation_0-rmse:0.74287	validation_1-rmse:0.81286
# [47]	validation_0-rmse:0.73389	validation_1-rmse:0.80275
# [48]	validation_0-rmse:0.72443	validation_1-rmse:0.79290
# [49]	validation_0-rmse:0.71655	validation_1-rmse:0.78463
# [50]	validation_0-rmse:0.70728	validation_1-rmse:0.77423
# [51]	validation_0-rmse:0.69775	validation_1-rmse:0.76268
# [52]	validation_0-rmse:0.68989	validation_1-rmse:0.75346
# [53]	validation_0-rmse:0.68351	validation_1-rmse:0.74346
# [54]	validation_0-rmse:0.67491	validation_1-rmse:0.73653
# [55]	validation_0-rmse:0.66764	validation_1-rmse:0.72951
# [56]	validation_0-rmse:0.65941	validation_1-rmse:0.72078
# [57]	validation_0-rmse:0.65040	validation_1-rmse:0.71091
# [58]	validation_0-rmse:0.64120	validation_1-rmse:0.70206
# [59]	validation_0-rmse:0.63307	validation_1-rmse:0.69216
# [60]	validation_0-rmse:0.62511	validation_1-rmse:0.68323
# [61]	validation_0-rmse:0.61853	validation_1-rmse:0.67658
# [62]	validation_0-rmse:0.61256	validation_1-rmse:0.67276
# [63]	validation_0-rmse:0.60813	validation_1-rmse:0.66845
# [64]	validation_0-rmse:0.60244	validation_1-rmse:0.66228
# [65]	validation_0-rmse:0.59733	validation_1-rmse:0.65892
# [66]	validation_0-rmse:0.59042	validation_1-rmse:0.65206
# [67]	validation_0-rmse:0.58303	validation_1-rmse:0.64559
# [68]	validation_0-rmse:0.57940	validation_1-rmse:0.63993
# [69]	validation_0-rmse:0.57317	validation_1-rmse:0.63533
# [70]	validation_0-rmse:0.56736	validation_1-rmse:0.63145
# [71]	validation_0-rmse:0.56139	validation_1-rmse:0.62562
# [72]	validation_0-rmse:0.55232	validation_1-rmse:0.61647
# [73]	validation_0-rmse:0.54559	validation_1-rmse:0.61000
# [74]	validation_0-rmse:0.53984	validation_1-rmse:0.60676
# [75]	validation_0-rmse:0.53433	validation_1-rmse:0.60098
# [76]	validation_0-rmse:0.52988	validation_1-rmse:0.59578
# [77]	validation_0-rmse:0.52389	validation_1-rmse:0.58793
# [78]	validation_0-rmse:0.52106	validation_1-rmse:0.58441
# [79]	validation_0-rmse:0.51593	validation_1-rmse:0.58076
# [80]	validation_0-rmse:0.51275	validation_1-rmse:0.57940
# [81]	validation_0-rmse:0.50969	validation_1-rmse:0.57540
# [82]	validation_0-rmse:0.50248	validation_1-rmse:0.57154
# [83]	validation_0-rmse:0.49895	validation_1-rmse:0.57028
# [84]	validation_0-rmse:0.49600	validation_1-rmse:0.56717
# [85]	validation_0-rmse:0.49409	validation_1-rmse:0.56588
# [86]	validation_0-rmse:0.49169	validation_1-rmse:0.56505
# [87]	validation_0-rmse:0.48854	validation_1-rmse:0.56182
# [88]	validation_0-rmse:0.48424	validation_1-rmse:0.55762
# [89]	validation_0-rmse:0.47964	validation_1-rmse:0.55269
# [90]	validation_0-rmse:0.47574	validation_1-rmse:0.55183
# [91]	validation_0-rmse:0.47116	validation_1-rmse:0.54965
# [92]	validation_0-rmse:0.46712	validation_1-rmse:0.54736
# [93]	validation_0-rmse:0.46410	validation_1-rmse:0.54651
# [94]	validation_0-rmse:0.46037	validation_1-rmse:0.54138
# [95]	validation_0-rmse:0.45990	validation_1-rmse:0.54139
# [96]	validation_0-rmse:0.45889	validation_1-rmse:0.54103
# [97]	validation_0-rmse:0.45727	validation_1-rmse:0.53958
# [98]	validation_0-rmse:0.45518	validation_1-rmse:0.53708
# [99]	validation_0-rmse:0.45184	validation_1-rmse:0.53619
# [100]	validation_0-rmse:0.44996	validation_1-rmse:0.53524
# [101]	validation_0-rmse:0.44665	validation_1-rmse:0.53510
# [102]	validation_0-rmse:0.44470	validation_1-rmse:0.53341
# [103]	validation_0-rmse:0.44124	validation_1-rmse:0.53232
# [104]	validation_0-rmse:0.44035	validation_1-rmse:0.53281
# [105]	validation_0-rmse:0.43821	validation_1-rmse:0.53276
# [106]	validation_0-rmse:0.43626	validation_1-rmse:0.53037
# [107]	validation_0-rmse:0.43346	validation_1-rmse:0.52931
# [108]	validation_0-rmse:0.43245	validation_1-rmse:0.52979
# [109]	validation_0-rmse:0.42962	validation_1-rmse:0.52971
# [110]	validation_0-rmse:0.42806	validation_1-rmse:0.53108
# [111]	validation_0-rmse:0.42469	validation_1-rmse:0.52878
# [112]	validation_0-rmse:0.42350	validation_1-rmse:0.52864
# [113]	validation_0-rmse:0.42213	validation_1-rmse:0.52721
# [114]	validation_0-rmse:0.41984	validation_1-rmse:0.52674
# [115]	validation_0-rmse:0.41585	validation_1-rmse:0.52516
# [116]	validation_0-rmse:0.41333	validation_1-rmse:0.52451
# [117]	validation_0-rmse:0.41199	validation_1-rmse:0.52278
# [118]	validation_0-rmse:0.41142	validation_1-rmse:0.52364
# [119]	validation_0-rmse:0.41001	validation_1-rmse:0.52321
# [120]	validation_0-rmse:0.40685	validation_1-rmse:0.52368
# [121]	validation_0-rmse:0.40590	validation_1-rmse:0.52345
# [122]	validation_0-rmse:0.40246	validation_1-rmse:0.52140
# [123]	validation_0-rmse:0.40123	validation_1-rmse:0.52046
# [124]	validation_0-rmse:0.40037	validation_1-rmse:0.51997
# [125]	validation_0-rmse:0.39911	validation_1-rmse:0.51896
# [126]	validation_0-rmse:0.39668	validation_1-rmse:0.51931
# [127]	validation_0-rmse:0.39496	validation_1-rmse:0.51790
# [128]	validation_0-rmse:0.39471	validation_1-rmse:0.51793
# [129]	validation_0-rmse:0.39359	validation_1-rmse:0.51602
# [130]	validation_0-rmse:0.39240	validation_1-rmse:0.51510
# [131]	validation_0-rmse:0.39122	validation_1-rmse:0.51422
# [132]	validation_0-rmse:0.38960	validation_1-rmse:0.51321
# [133]	validation_0-rmse:0.38860	validation_1-rmse:0.51380
# [134]	validation_0-rmse:0.38726	validation_1-rmse:0.51206
# [135]	validation_0-rmse:0.38535	validation_1-rmse:0.51075
# [136]	validation_0-rmse:0.38339	validation_1-rmse:0.50952
# [137]	validation_0-rmse:0.38116	validation_1-rmse:0.50974
# [138]	validation_0-rmse:0.38025	validation_1-rmse:0.51028
# [139]	validation_0-rmse:0.38028	validation_1-rmse:0.51030
# [140]	validation_0-rmse:0.38015	validation_1-rmse:0.51020
# [141]	validation_0-rmse:0.37856	validation_1-rmse:0.51031
# [142]	validation_0-rmse:0.37818	validation_1-rmse:0.51128
# [143]	validation_0-rmse:0.37656	validation_1-rmse:0.51209
# [144]	validation_0-rmse:0.37600	validation_1-rmse:0.51172
# [145]	validation_0-rmse:0.37481	validation_1-rmse:0.51176
# [146]	validation_0-rmse:0.37323	validation_1-rmse:0.51189
# [147]	validation_0-rmse:0.37187	validation_1-rmse:0.51201
# [148]	validation_0-rmse:0.37087	validation_1-rmse:0.51198
# [149]	validation_0-rmse:0.36966	validation_1-rmse:0.50941
# [150]	validation_0-rmse:0.36881	validation_1-rmse:0.50838
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-3.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.461
# Uncertainty
# a0: -0.496+/-0.057
# a1: 0.435+/-0.045

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: %_cover: mean - 0.314, median - 0.314, CI - [0.29-0.34]
#
# SHAP-values for: contr_g_MAX: mean - 0.058, median - 0.056, CI - [0.043-0.074]
#
# SHAP-values for: g_MAX: mean - 0.053, median - 0.052, CI - [0.041-0.065]
#
# SHAP-values for: mf_chm_MAX: mean - 0.068, median - 0.067, CI - [0.056-0.08]
#
# SHAP-values for: mf_chm_MEAN: mean - 0.139, median - 0.138, CI - [0.12-0.155]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'contr_g_MAX', 'g_MAX'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 129.79, median: 142.5,
#  pred. interval (P(0.025)-P(0.975)): 72.875-150.0,
#  conf. interval (p-value=0.95): 102.313-149.273
# ***
# Aggregate bias statistic:
#  mean: 0.074, median: 0.054,
#  pred. interval (P(0.025)-P(0.975)): -0.099-0.286,
#  conf. interval (p-value=0.95): -0.023-0.168
# ***
# Aggregate RMSE statistic:
#  mean: 0.58, median: 0.58, pred. interval (P(0.025)-P(0.975)): 0.417-0.752,
#  conf. interval (p-value=0.95): 0.494-0.657
# ***
# Aggregate MSE statistic:
#  mean: 0.344, median: 0.336, pred. interval (P(0.025)-P(0.975)): 0.174-0.566,
#  conf. interval (p-value=0.95): 0.245-0.433
# ***
# Aggregate R^2 statistic:
#  mean: 0.418, median: 0.44, pred. interval (P(0.025)-P(0.975)): 0.05-0.626,
#  conf. interval (p-value=0.95): 0.303-0.558
# ***
# Aggregate bias(%) statistic:
#  mean: -6.479, median: -5.759, pred. interval (P(0.025)-P(0.975)): -24.083-11.383,
#  conf. interval (p-value=0.95): -15.255-2.426
# ***
# Aggregate RMSE(%) statistic:
#  mean: -58.323, median: -57.295, pred. interval (P(0.025)-P(0.975)): -79.126--41.632,
#  conf. interval (p-value=0.95): -67.198--49.67
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -0.034, median: -0.034,
#  pred. interval (P(0.025)-P(0.975)): -0.131-0.055,
#  conf. interval (p-value=0.95): -0.075-0.002
# ***
# Aggregate RMSE statistic:
#  mean: 0.235, median: 0.233, pred. interval (P(0.025)-P(0.975)): 0.157-0.313,
#  conf. interval (p-value=0.95): 0.201-0.27
# ***
# Aggregate MSE statistic:
#  mean: 0.057, median: 0.054, pred. interval (P(0.025)-P(0.975)): 0.025-0.098,
#  conf. interval (p-value=0.95): 0.04-0.073
# ***
# Aggregate R^2 statistic:
#  mean: 0.315, median: 0.332, pred. interval (P(0.025)-P(0.975)): -0.048-0.62,
#  conf. interval (p-value=0.95): 0.187-0.471
# ***
# Aggregate bias(%) statistic:
#  mean: -6.408, median: -6.755, pred. interval (P(0.025)-P(0.975)): -24.127-14.818,
#  conf. interval (p-value=0.95): -15.012-0.556
# ***
# Aggregate RMSE(%) statistic:
#  mean: 50.121, median: 50.496, pred. interval (P(0.025)-P(0.975)): 35.386-66.948,
#  conf. interval (p-value=0.95): 42.289-57.508
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-3, -2.5, -2, -1.5, -1, -0.5, 0])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 0.25, 0.5, 0.75, 1])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.67248
# [1]	validation_0-rmse:1.63521
# [2]	validation_0-rmse:1.60038
# [3]	validation_0-rmse:1.56826
# [4]	validation_0-rmse:1.53288
# [5]	validation_0-rmse:1.50023
# [6]	validation_0-rmse:1.46718
# [7]	validation_0-rmse:1.43614
# [8]	validation_0-rmse:1.40816
# [9]	validation_0-rmse:1.38081
# [10]	validation_0-rmse:1.35212
# [11]	validation_0-rmse:1.32695
# [12]	validation_0-rmse:1.30152
# [13]	validation_0-rmse:1.27872
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [14]	validation_0-rmse:1.25540
# [15]	validation_0-rmse:1.23247
# [16]	validation_0-rmse:1.20836
# [17]	validation_0-rmse:1.18646
# [18]	validation_0-rmse:1.16279
# [19]	validation_0-rmse:1.14072
# [20]	validation_0-rmse:1.12040
# [21]	validation_0-rmse:1.09441
# [22]	validation_0-rmse:1.07527
# [23]	validation_0-rmse:1.05532
# [24]	validation_0-rmse:1.03909
# [25]	validation_0-rmse:1.02318
# [26]	validation_0-rmse:1.00485
# [27]	validation_0-rmse:0.99004
# [28]	validation_0-rmse:0.97195
# [29]	validation_0-rmse:0.95491
# [30]	validation_0-rmse:0.93677
# [31]	validation_0-rmse:0.92247
# [32]	validation_0-rmse:0.90705
# [33]	validation_0-rmse:0.89066
# [34]	validation_0-rmse:0.87557
# [35]	validation_0-rmse:0.85877
# [36]	validation_0-rmse:0.84395
# [37]	validation_0-rmse:0.83423
# [38]	validation_0-rmse:0.82081
# [39]	validation_0-rmse:0.80882
# [40]	validation_0-rmse:0.80011
# [41]	validation_0-rmse:0.78960
# [42]	validation_0-rmse:0.77769
# [43]	validation_0-rmse:0.76509
# [44]	validation_0-rmse:0.75244
# [45]	validation_0-rmse:0.74167
# [46]	validation_0-rmse:0.73401
# [47]	validation_0-rmse:0.72281
# [48]	validation_0-rmse:0.71230
# [49]	validation_0-rmse:0.70208
# [50]	validation_0-rmse:0.69336
# [51]	validation_0-rmse:0.68433
# [52]	validation_0-rmse:0.67541
# [53]	validation_0-rmse:0.66487
# [54]	validation_0-rmse:0.65817
# [55]	validation_0-rmse:0.65210
# [56]	validation_0-rmse:0.64260
# [57]	validation_0-rmse:0.63461
# [58]	validation_0-rmse:0.62622
# [59]	validation_0-rmse:0.62025
# [60]	validation_0-rmse:0.61222
# [61]	validation_0-rmse:0.60601
# [62]	validation_0-rmse:0.60005
# [63]	validation_0-rmse:0.59221
# [64]	validation_0-rmse:0.58393
# [65]	validation_0-rmse:0.57816
# [66]	validation_0-rmse:0.57166
# [67]	validation_0-rmse:0.56506
# [68]	validation_0-rmse:0.55974
# [69]	validation_0-rmse:0.55354
# [70]	validation_0-rmse:0.54899
# [71]	validation_0-rmse:0.54347
# [72]	validation_0-rmse:0.53521
# [73]	validation_0-rmse:0.53115
# [74]	validation_0-rmse:0.52746
# [75]	validation_0-rmse:0.52286
# [76]	validation_0-rmse:0.51894
# [77]	validation_0-rmse:0.51549
# [78]	validation_0-rmse:0.51022
# [79]	validation_0-rmse:0.50599
# [80]	validation_0-rmse:0.50087
# [81]	validation_0-rmse:0.49661
# [82]	validation_0-rmse:0.49144
# [83]	validation_0-rmse:0.48819
# [84]	validation_0-rmse:0.48609
# [85]	validation_0-rmse:0.48271
# [86]	validation_0-rmse:0.47973
# [87]	validation_0-rmse:0.47557
# [88]	validation_0-rmse:0.47213
# [89]	validation_0-rmse:0.46945
# [90]	validation_0-rmse:0.46609
# [91]	validation_0-rmse:0.46309
# [92]	validation_0-rmse:0.46133
# [93]	validation_0-rmse:0.45814
# [94]	validation_0-rmse:0.45773
# [95]	validation_0-rmse:0.45396
# [96]	validation_0-rmse:0.45153
# [97]	validation_0-rmse:0.44782
# [98]	validation_0-rmse:0.44582
# [99]	validation_0-rmse:0.44444
# [100]	validation_0-rmse:0.44231
# [101]	validation_0-rmse:0.43927
# [102]	validation_0-rmse:0.43605
# [103]	validation_0-rmse:0.43263
# [104]	validation_0-rmse:0.42919
# [105]	validation_0-rmse:0.42784
# [106]	validation_0-rmse:0.42498
# [107]	validation_0-rmse:0.42248
# [108]	validation_0-rmse:0.42065
# [109]	validation_0-rmse:0.41836
# [110]	validation_0-rmse:0.41589
# [111]	validation_0-rmse:0.41532
# [112]	validation_0-rmse:0.41464
# [113]	validation_0-rmse:0.41198
# [114]	validation_0-rmse:0.41032
# [115]	validation_0-rmse:0.40897
# [116]	validation_0-rmse:0.40841
# [117]	validation_0-rmse:0.40744
# [118]	validation_0-rmse:0.40524
# [119]	validation_0-rmse:0.40411
# [120]	validation_0-rmse:0.40271
# [121]	validation_0-rmse:0.40115
# [122]	validation_0-rmse:0.40060
# [123]	validation_0-rmse:0.39962
# [124]	validation_0-rmse:0.39907
# [125]	validation_0-rmse:0.39871
# [126]	validation_0-rmse:0.39582
# [127]	validation_0-rmse:0.39381
# [128]	validation_0-rmse:0.39326
# [129]	validation_0-rmse:0.39154
# [130]	validation_0-rmse:0.39043
# [131]	validation_0-rmse:0.38941
# [132]	validation_0-rmse:0.38762
# [133]	validation_0-rmse:0.38558
# [134]	validation_0-rmse:0.38401
# [135]	validation_0-rmse:0.38322
# [136]	validation_0-rmse:0.38180
# [137]	validation_0-rmse:0.38082
# [138]	validation_0-rmse:0.37966
# [139]	validation_0-rmse:0.37787
# [140]	validation_0-rmse:0.37702
# [141]	validation_0-rmse:0.37516
# [142]	validation_0-rmse:0.37402
# [143]	validation_0-rmse:0.37343
# [144]	validation_0-rmse:0.37257
# [145]	validation_0-rmse:0.37110
# [146]	validation_0-rmse:0.36991
# [147]	validation_0-rmse:0.36948
# [148]	validation_0-rmse:0.36916
# [149]	validation_0-rmse:0.36881
# [150]	validation_0-rmse:0.36787
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 150

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  -4.88
# RMSE: 0.4
# Relative RMSE(%):  -36.209
# MSE: 0.1
# R square: 78.6%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-3.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.824
# Uncertainty
# a0: -0.30+/-0.04
# a1: 0.657+/-0.030

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/05_LN_Mfoliage_CHM_with_RGB_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/05_LN_Mfoliage_CHM_with_RGB_XGB_model.txt")
