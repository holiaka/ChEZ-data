# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../03_input_data/input_CHM_&_spectral_data_site2020.xlsx'
df = pd.read_excel(site_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0        4.771            1.792                -0.211            -0.261
# 1        5.808            2.496                -0.073             0.392
# 2        5.796            2.546                 0.030             0.501
# 3        5.826            2.643                 0.000             0.419
# 4        6.059            2.643                 0.122             0.647
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX
# 0              -2.040          1.932     0.85    12.233545   19.097736
# 1              -0.139          2.674     1.00    14.964220   17.704655
# 2              -0.030          2.734     1.00    15.329449   17.559893
# 3              -0.431          2.785     0.97    15.392742   20.676994
# 4              -0.386          2.809     1.00    17.944009   21.851387

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
# dtypes: float64(9)
# memory usage: 7.4 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Gs_cub_m", "ln_M_AG_kg_m2"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                  ln_Gs_cub_m                                             \
#                        count      mean       std    min      25%    50%
# Dominant_specias
# Alder                    4.0  5.907250  0.445830  5.342  5.65925  5.985
# Aspen                    1.0  4.956000       NaN  4.956  4.95600  4.956
# Birch                   23.0  4.676174  0.813911  2.398  4.56900  4.949
# Oak                      3.0  5.409667  0.406291  4.956  5.24450  5.533
# Pine                    71.0  4.990775  1.410734  1.609  4.44850  5.642
# Spruce                   1.0  6.431000       NaN  6.431  6.43100  6.431
#
#                                 ln_M_AG_kg_m2                             \
#                      75%    max         count      mean       std    min
# Dominant_specias
# Alder             6.2330  6.317           4.0  2.862250  0.386813  2.407
# Aspen             4.9560  4.956           1.0  1.932000       NaN  1.932
# Birch             5.2930  5.680          23.0  1.855783  0.744496  0.000
# Oak               5.6365  5.740           3.0  2.687333  0.316282  2.398
# Pine              5.9215  6.457          71.0  2.073789  1.174954 -0.693
# Spruce            6.4310  6.431           1.0  3.506000       NaN  3.506
#
#
#                       25%    50%     75%    max
# Dominant_specias
# Alder             2.61775  2.892  3.1365  3.258
# Aspen             1.93200  1.932  1.9320  1.932
# Birch             1.68350  2.001  2.3930  2.803
# Oak               2.51850  2.639  2.8320  3.025
# Pine              1.48500  2.588  2.8620  3.515
# Spruce            3.50600  3.506  3.5060  3.506

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000        103.000000
# mean      4.981961         1.863184             -0.327942         -0.063369
# std       1.264300         1.198731              0.866380          0.795365
# min       1.609000        -1.347000             -2.659000         -2.408000
# 25%       4.677000         1.584500             -0.554000         -0.386500
# 50%       5.342000         2.294000             -0.051000          0.182000
# 75%       5.875000         2.663000              0.207000          0.495000
# max       6.457000         3.428000              1.384000          1.756000
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.015971       2.086126    0.808738    13.045021   17.907784
# std              0.799205       1.067542    0.276653     6.609366    7.523377
# min             -3.507000      -0.693000    0.090000     1.293138    2.733019
# 25%             -1.609000       1.758000    0.745000     8.206727   11.615798
# 50%             -0.844000       2.442000    0.960000    13.072916   18.269344
# 75%             -0.364000       2.809000    1.000000    17.432255   22.751595
# max              0.157000       3.515000    1.000000    28.916548   36.355442

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_M_stem_kg_m2"
indep_variables = ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0          4.771            1.792                -0.211            -0.261
# 1          5.808            2.496                -0.073             0.392
# 2          5.796            2.546                 0.030             0.501
# 3          5.826            2.643                 0.000             0.419
# 4          6.059            2.643                 0.122             0.647
# ..           ...              ...                   ...               ...
# 98         5.389            2.366                 0.531             0.182
# 99         2.398           -0.186                -1.309            -1.966
# 100        1.792           -0.968                -2.120            -1.966
# 101        4.836            1.733                -0.386             0.732
# 102        2.944           -0.211                -1.966            -1.470
#
#      ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX
# 0                -2.040          1.932     0.85    12.233545   19.097736
# 1                -0.139          2.674     1.00    14.964220   17.704655
# 2                -0.030          2.734     1.00    15.329449   17.559893
# 3                -0.431          2.785     0.97    15.392742   20.676994
# 4                -0.386          2.809     1.00    17.944009   21.851387
# ..                  ...            ...      ...          ...         ...
# 98               -1.386          2.493     0.84    11.654902   17.083910
# 99               -3.507          0.000     0.17     4.722706   10.924606
# 100              -2.408         -0.511     0.17     4.620455   10.747827
# 101              -0.041          2.163     0.88     7.371921   11.443830
# 102              -1.609          0.182     0.28     2.765120    8.069081
#
# [103 rows x 9 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX
# 0     0.85    12.233545   19.097736
# 1     1.00    14.964220   17.704655
# 2     1.00    15.329449   17.559893
# 3     0.97    15.392742   20.676994
# 4     1.00    17.944009   21.851387

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_stem_kg_m2
# 0            1.792
# 1            2.496
# 2            2.546
# 3            2.643
# 4            2.643

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.9185999086295552, 0.9369953363636283, 0.9150460326248963]
#     Mean: 0.924
#     Std: 0.010
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.36006591 0.27330416 0.29216985]
#     Mean: 0.309
#     Std: 0.037
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.29928595677954806, 0.20170586872802063, 0.23502185502560705]
#     Mean: 0.245
#     Std: 0.040
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.8565852435738817                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.12940676640076693                 # gamma
print('Gamma: ' + str(p2))

p3 = 0.029546354081746842                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 3            # max_depth
print('Max_depth: ' + str(p4))

p5 = 189          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.3060599314998912                   # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.8565852435738817
# Gamma: 0.12940676640076693
# Learning_rate: 0.029546354081746842
# Max_depth: 3
# N_estimators: 189
# Subsample: 0.3060599314998912

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.77348	validation_1-rmse:1.73983
# [1]	validation_0-rmse:1.72537	validation_1-rmse:1.69780
# [2]	validation_0-rmse:1.68210	validation_1-rmse:1.65861
# [3]	validation_0-rmse:1.64101	validation_1-rmse:1.62302
# [4]	validation_0-rmse:1.60239	validation_1-rmse:1.59050
# [5]	validation_0-rmse:1.56538	validation_1-rmse:1.55643
# [6]	validation_0-rmse:1.52547	validation_1-rmse:1.52208
# [7]	validation_0-rmse:1.49075	validation_1-rmse:1.48909
# [8]	validation_0-rmse:1.45355	validation_1-rmse:1.45712
# [9]	validation_0-rmse:1.41691	validation_1-rmse:1.42370
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [10]	validation_0-rmse:1.38381	validation_1-rmse:1.39352
# [11]	validation_0-rmse:1.35137	validation_1-rmse:1.36366
# [12]	validation_0-rmse:1.31950	validation_1-rmse:1.33489
# [13]	validation_0-rmse:1.28786	validation_1-rmse:1.30606
# [14]	validation_0-rmse:1.25501	validation_1-rmse:1.27804
# [15]	validation_0-rmse:1.22236	validation_1-rmse:1.24932
# [16]	validation_0-rmse:1.19294	validation_1-rmse:1.22478
# [17]	validation_0-rmse:1.16044	validation_1-rmse:1.19942
# [18]	validation_0-rmse:1.12990	validation_1-rmse:1.17396
# [19]	validation_0-rmse:1.10265	validation_1-rmse:1.15057
# [20]	validation_0-rmse:1.07540	validation_1-rmse:1.12817
# [21]	validation_0-rmse:1.04716	validation_1-rmse:1.10664
# [22]	validation_0-rmse:1.02167	validation_1-rmse:1.08678
# [23]	validation_0-rmse:0.99666	validation_1-rmse:1.06506
# [24]	validation_0-rmse:0.97283	validation_1-rmse:1.04550
# [25]	validation_0-rmse:0.95064	validation_1-rmse:1.02891
# [26]	validation_0-rmse:0.92964	validation_1-rmse:1.01031
# [27]	validation_0-rmse:0.90951	validation_1-rmse:0.99238
# [28]	validation_0-rmse:0.88762	validation_1-rmse:0.97381
# [29]	validation_0-rmse:0.86556	validation_1-rmse:0.95985
# [30]	validation_0-rmse:0.84358	validation_1-rmse:0.94135
# [31]	validation_0-rmse:0.82365	validation_1-rmse:0.92658
# [32]	validation_0-rmse:0.80754	validation_1-rmse:0.91053
# [33]	validation_0-rmse:0.79006	validation_1-rmse:0.89672
# [34]	validation_0-rmse:0.77287	validation_1-rmse:0.88143
# [35]	validation_0-rmse:0.75678	validation_1-rmse:0.86763
# [36]	validation_0-rmse:0.73918	validation_1-rmse:0.85439
# [37]	validation_0-rmse:0.72294	validation_1-rmse:0.84382
# [38]	validation_0-rmse:0.70678	validation_1-rmse:0.83063
# [39]	validation_0-rmse:0.68892	validation_1-rmse:0.81771
# [40]	validation_0-rmse:0.67543	validation_1-rmse:0.80804
# [41]	validation_0-rmse:0.65960	validation_1-rmse:0.79579
# [42]	validation_0-rmse:0.64412	validation_1-rmse:0.78466
# [43]	validation_0-rmse:0.62952	validation_1-rmse:0.77284
# [44]	validation_0-rmse:0.61649	validation_1-rmse:0.76246
# [45]	validation_0-rmse:0.60299	validation_1-rmse:0.75027
# [46]	validation_0-rmse:0.59083	validation_1-rmse:0.74105
# [47]	validation_0-rmse:0.58031	validation_1-rmse:0.73582
# [48]	validation_0-rmse:0.56984	validation_1-rmse:0.72592
# [49]	validation_0-rmse:0.55662	validation_1-rmse:0.71928
# [50]	validation_0-rmse:0.54585	validation_1-rmse:0.70816
# [51]	validation_0-rmse:0.53394	validation_1-rmse:0.69779
# [52]	validation_0-rmse:0.52324	validation_1-rmse:0.68717
# [53]	validation_0-rmse:0.51264	validation_1-rmse:0.67781
# [54]	validation_0-rmse:0.50278	validation_1-rmse:0.67110
# [55]	validation_0-rmse:0.49193	validation_1-rmse:0.66297
# [56]	validation_0-rmse:0.48148	validation_1-rmse:0.65183
# [57]	validation_0-rmse:0.47145	validation_1-rmse:0.64393
# [58]	validation_0-rmse:0.46315	validation_1-rmse:0.63697
# [59]	validation_0-rmse:0.45506	validation_1-rmse:0.63037
# [60]	validation_0-rmse:0.44653	validation_1-rmse:0.62325
# [61]	validation_0-rmse:0.44010	validation_1-rmse:0.61875
# [62]	validation_0-rmse:0.43181	validation_1-rmse:0.61373
# [63]	validation_0-rmse:0.42279	validation_1-rmse:0.60902
# [64]	validation_0-rmse:0.41649	validation_1-rmse:0.60462
# [65]	validation_0-rmse:0.40916	validation_1-rmse:0.59796
# [66]	validation_0-rmse:0.40095	validation_1-rmse:0.59204
# [67]	validation_0-rmse:0.39253	validation_1-rmse:0.58665
# [68]	validation_0-rmse:0.38676	validation_1-rmse:0.58262
# [69]	validation_0-rmse:0.38017	validation_1-rmse:0.57772
# [70]	validation_0-rmse:0.37407	validation_1-rmse:0.57493
# [71]	validation_0-rmse:0.36697	validation_1-rmse:0.57265
# [72]	validation_0-rmse:0.36068	validation_1-rmse:0.56930
# [73]	validation_0-rmse:0.35626	validation_1-rmse:0.56577
# [74]	validation_0-rmse:0.35143	validation_1-rmse:0.56193
# [75]	validation_0-rmse:0.34688	validation_1-rmse:0.55938
# [76]	validation_0-rmse:0.34102	validation_1-rmse:0.55754
# [77]	validation_0-rmse:0.33594	validation_1-rmse:0.55510
# [78]	validation_0-rmse:0.33104	validation_1-rmse:0.55253
# [79]	validation_0-rmse:0.32717	validation_1-rmse:0.54976
# [80]	validation_0-rmse:0.32246	validation_1-rmse:0.54482
# [81]	validation_0-rmse:0.31793	validation_1-rmse:0.54306
# [82]	validation_0-rmse:0.31356	validation_1-rmse:0.53933
# [83]	validation_0-rmse:0.30983	validation_1-rmse:0.53677
# [84]	validation_0-rmse:0.30530	validation_1-rmse:0.53547
# [85]	validation_0-rmse:0.30156	validation_1-rmse:0.53269
# [86]	validation_0-rmse:0.29840	validation_1-rmse:0.52963
# [87]	validation_0-rmse:0.29497	validation_1-rmse:0.52743
# [88]	validation_0-rmse:0.28948	validation_1-rmse:0.52529
# [89]	validation_0-rmse:0.28598	validation_1-rmse:0.52209
# [90]	validation_0-rmse:0.28330	validation_1-rmse:0.51984
# [91]	validation_0-rmse:0.27934	validation_1-rmse:0.51739
# [92]	validation_0-rmse:0.27611	validation_1-rmse:0.51532
# [93]	validation_0-rmse:0.27323	validation_1-rmse:0.51236
# [94]	validation_0-rmse:0.26996	validation_1-rmse:0.50870
# [95]	validation_0-rmse:0.26819	validation_1-rmse:0.50667
# [96]	validation_0-rmse:0.26593	validation_1-rmse:0.50453
# [97]	validation_0-rmse:0.26420	validation_1-rmse:0.50346
# [98]	validation_0-rmse:0.26200	validation_1-rmse:0.50146
# [99]	validation_0-rmse:0.25917	validation_1-rmse:0.50017
# [100]	validation_0-rmse:0.25693	validation_1-rmse:0.49717
# [101]	validation_0-rmse:0.25528	validation_1-rmse:0.49612
# [102]	validation_0-rmse:0.25340	validation_1-rmse:0.49508
# [103]	validation_0-rmse:0.25166	validation_1-rmse:0.49291
# [104]	validation_0-rmse:0.24806	validation_1-rmse:0.48968
# [105]	validation_0-rmse:0.24519	validation_1-rmse:0.48928
# [106]	validation_0-rmse:0.24264	validation_1-rmse:0.48700
# [107]	validation_0-rmse:0.24120	validation_1-rmse:0.48757
# [108]	validation_0-rmse:0.24049	validation_1-rmse:0.48697
# [109]	validation_0-rmse:0.23888	validation_1-rmse:0.48519
# [110]	validation_0-rmse:0.23765	validation_1-rmse:0.48399
# [111]	validation_0-rmse:0.23588	validation_1-rmse:0.48250
# [112]	validation_0-rmse:0.23313	validation_1-rmse:0.48187
# [113]	validation_0-rmse:0.23076	validation_1-rmse:0.48237
# [114]	validation_0-rmse:0.22897	validation_1-rmse:0.48057
# [115]	validation_0-rmse:0.22744	validation_1-rmse:0.48049
# [116]	validation_0-rmse:0.22600	validation_1-rmse:0.47823
# [117]	validation_0-rmse:0.22359	validation_1-rmse:0.47830
# [118]	validation_0-rmse:0.22203	validation_1-rmse:0.47663
# [119]	validation_0-rmse:0.22020	validation_1-rmse:0.47645
# [120]	validation_0-rmse:0.21888	validation_1-rmse:0.47633
# [121]	validation_0-rmse:0.21768	validation_1-rmse:0.47592
# [122]	validation_0-rmse:0.21567	validation_1-rmse:0.47348
# [123]	validation_0-rmse:0.21475	validation_1-rmse:0.47169
# [124]	validation_0-rmse:0.21416	validation_1-rmse:0.47104
# [125]	validation_0-rmse:0.21315	validation_1-rmse:0.47072
# [126]	validation_0-rmse:0.21265	validation_1-rmse:0.47141
# [127]	validation_0-rmse:0.21136	validation_1-rmse:0.47170
# [128]	validation_0-rmse:0.21124	validation_1-rmse:0.47156
# [129]	validation_0-rmse:0.21072	validation_1-rmse:0.47184
# [130]	validation_0-rmse:0.21015	validation_1-rmse:0.47122
# [131]	validation_0-rmse:0.20864	validation_1-rmse:0.47227
# [132]	validation_0-rmse:0.20835	validation_1-rmse:0.47244
# [133]	validation_0-rmse:0.20747	validation_1-rmse:0.47116
# [134]	validation_0-rmse:0.20738	validation_1-rmse:0.47105
# [135]	validation_0-rmse:0.20631	validation_1-rmse:0.47090
# [136]	validation_0-rmse:0.20534	validation_1-rmse:0.46956
# [137]	validation_0-rmse:0.20398	validation_1-rmse:0.46836
# [138]	validation_0-rmse:0.20275	validation_1-rmse:0.46761
# [139]	validation_0-rmse:0.20239	validation_1-rmse:0.46713
# [140]	validation_0-rmse:0.20254	validation_1-rmse:0.46612
# [141]	validation_0-rmse:0.20201	validation_1-rmse:0.46544
# [142]	validation_0-rmse:0.20198	validation_1-rmse:0.46411
# [143]	validation_0-rmse:0.20144	validation_1-rmse:0.46360
# [144]	validation_0-rmse:0.20113	validation_1-rmse:0.46274
# [145]	validation_0-rmse:0.20024	validation_1-rmse:0.46014
# [146]	validation_0-rmse:0.19956	validation_1-rmse:0.46046
# [147]	validation_0-rmse:0.19933	validation_1-rmse:0.46007
# [148]	validation_0-rmse:0.19827	validation_1-rmse:0.45994
# [149]	validation_0-rmse:0.19657	validation_1-rmse:0.46041
# [150]	validation_0-rmse:0.19601	validation_1-rmse:0.46033
# [151]	validation_0-rmse:0.19597	validation_1-rmse:0.46026
# [152]	validation_0-rmse:0.19540	validation_1-rmse:0.46103
# [153]	validation_0-rmse:0.19513	validation_1-rmse:0.46194
# [154]	validation_0-rmse:0.19501	validation_1-rmse:0.46170
# [155]	validation_0-rmse:0.19441	validation_1-rmse:0.46154
# [156]	validation_0-rmse:0.19373	validation_1-rmse:0.46128
# [157]	validation_0-rmse:0.19322	validation_1-rmse:0.45983
# [158]	validation_0-rmse:0.19280	validation_1-rmse:0.45952
# [159]	validation_0-rmse:0.19269	validation_1-rmse:0.45923
# [160]	validation_0-rmse:0.19193	validation_1-rmse:0.45853
# [161]	validation_0-rmse:0.19160	validation_1-rmse:0.45801
# [162]	validation_0-rmse:0.19154	validation_1-rmse:0.45787
# [163]	validation_0-rmse:0.19112	validation_1-rmse:0.45707
# [164]	validation_0-rmse:0.19103	validation_1-rmse:0.45684
# [165]	validation_0-rmse:0.19022	validation_1-rmse:0.45687
# [166]	validation_0-rmse:0.19049	validation_1-rmse:0.45785
# [167]	validation_0-rmse:0.19052	validation_1-rmse:0.45793
# [168]	validation_0-rmse:0.18990	validation_1-rmse:0.45765
# [169]	validation_0-rmse:0.18874	validation_1-rmse:0.45880
# [170]	validation_0-rmse:0.18871	validation_1-rmse:0.45874
# [171]	validation_0-rmse:0.18885	validation_1-rmse:0.45904
# [172]	validation_0-rmse:0.18818	validation_1-rmse:0.45924
# [173]	validation_0-rmse:0.18818	validation_1-rmse:0.45924
# [174]	validation_0-rmse:0.18758	validation_1-rmse:0.45886
# [175]	validation_0-rmse:0.18733	validation_1-rmse:0.45817
# [176]	validation_0-rmse:0.18731	validation_1-rmse:0.45813
# [177]	validation_0-rmse:0.18735	validation_1-rmse:0.45820
# [178]	validation_0-rmse:0.18709	validation_1-rmse:0.45734
# [179]	validation_0-rmse:0.18627	validation_1-rmse:0.45777
# [180]	validation_0-rmse:0.18619	validation_1-rmse:0.45843
# [181]	validation_0-rmse:0.18563	validation_1-rmse:0.45816
# [182]	validation_0-rmse:0.18475	validation_1-rmse:0.45885
# [183]	validation_0-rmse:0.18473	validation_1-rmse:0.45881
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.76327	validation_1-rmse:1.78459
# [1]	validation_0-rmse:1.71683	validation_1-rmse:1.74161
# [2]	validation_0-rmse:1.67027	validation_1-rmse:1.70309
# [3]	validation_0-rmse:1.62753	validation_1-rmse:1.66049
# [4]	validation_0-rmse:1.58651	validation_1-rmse:1.62526
# [5]	validation_0-rmse:1.54700	validation_1-rmse:1.58589
# [6]	validation_0-rmse:1.50787	validation_1-rmse:1.55034
# [7]	validation_0-rmse:1.47066	validation_1-rmse:1.51605
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:1.43784	validation_1-rmse:1.48759
# [9]	validation_0-rmse:1.40444	validation_1-rmse:1.45393
# [10]	validation_0-rmse:1.37223	validation_1-rmse:1.42400
# [11]	validation_0-rmse:1.33580	validation_1-rmse:1.38751
# [12]	validation_0-rmse:1.30003	validation_1-rmse:1.35243
# [13]	validation_0-rmse:1.26749	validation_1-rmse:1.32224
# [14]	validation_0-rmse:1.23689	validation_1-rmse:1.29289
# [15]	validation_0-rmse:1.20569	validation_1-rmse:1.26400
# [16]	validation_0-rmse:1.17604	validation_1-rmse:1.23383
# [17]	validation_0-rmse:1.14594	validation_1-rmse:1.20547
# [18]	validation_0-rmse:1.11712	validation_1-rmse:1.17984
# [19]	validation_0-rmse:1.08821	validation_1-rmse:1.15265
# [20]	validation_0-rmse:1.06084	validation_1-rmse:1.12428
# [21]	validation_0-rmse:1.03592	validation_1-rmse:1.09870
# [22]	validation_0-rmse:1.01204	validation_1-rmse:1.07308
# [23]	validation_0-rmse:0.98771	validation_1-rmse:1.05128
# [24]	validation_0-rmse:0.96286	validation_1-rmse:1.02467
# [25]	validation_0-rmse:0.94025	validation_1-rmse:1.00394
# [26]	validation_0-rmse:0.92126	validation_1-rmse:0.98549
# [27]	validation_0-rmse:0.89803	validation_1-rmse:0.96172
# [28]	validation_0-rmse:0.87653	validation_1-rmse:0.94185
# [29]	validation_0-rmse:0.85563	validation_1-rmse:0.92225
# [30]	validation_0-rmse:0.83852	validation_1-rmse:0.90322
# [31]	validation_0-rmse:0.81950	validation_1-rmse:0.88254
# [32]	validation_0-rmse:0.80282	validation_1-rmse:0.86703
# [33]	validation_0-rmse:0.78279	validation_1-rmse:0.84742
# [34]	validation_0-rmse:0.76255	validation_1-rmse:0.82836
# [35]	validation_0-rmse:0.74541	validation_1-rmse:0.81202
# [36]	validation_0-rmse:0.72962	validation_1-rmse:0.79481
# [37]	validation_0-rmse:0.71653	validation_1-rmse:0.78426
# [38]	validation_0-rmse:0.69999	validation_1-rmse:0.76764
# [39]	validation_0-rmse:0.68533	validation_1-rmse:0.75224
# [40]	validation_0-rmse:0.67129	validation_1-rmse:0.73729
# [41]	validation_0-rmse:0.65744	validation_1-rmse:0.72350
# [42]	validation_0-rmse:0.64234	validation_1-rmse:0.70835
# [43]	validation_0-rmse:0.62933	validation_1-rmse:0.69414
# [44]	validation_0-rmse:0.61519	validation_1-rmse:0.68146
# [45]	validation_0-rmse:0.60174	validation_1-rmse:0.67001
# [46]	validation_0-rmse:0.58944	validation_1-rmse:0.65677
# [47]	validation_0-rmse:0.57700	validation_1-rmse:0.64372
# [48]	validation_0-rmse:0.56511	validation_1-rmse:0.63182
# [49]	validation_0-rmse:0.55481	validation_1-rmse:0.62039
# [50]	validation_0-rmse:0.54317	validation_1-rmse:0.61047
# [51]	validation_0-rmse:0.53239	validation_1-rmse:0.59855
# [52]	validation_0-rmse:0.52344	validation_1-rmse:0.59060
# [53]	validation_0-rmse:0.51525	validation_1-rmse:0.58094
# [54]	validation_0-rmse:0.50598	validation_1-rmse:0.56965
# [55]	validation_0-rmse:0.49690	validation_1-rmse:0.56182
# [56]	validation_0-rmse:0.48690	validation_1-rmse:0.55044
# [57]	validation_0-rmse:0.47848	validation_1-rmse:0.54094
# [58]	validation_0-rmse:0.47011	validation_1-rmse:0.53239
# [59]	validation_0-rmse:0.46068	validation_1-rmse:0.52292
# [60]	validation_0-rmse:0.45110	validation_1-rmse:0.51331
# [61]	validation_0-rmse:0.44166	validation_1-rmse:0.50375
# [62]	validation_0-rmse:0.43392	validation_1-rmse:0.49736
# [63]	validation_0-rmse:0.42554	validation_1-rmse:0.49001
# [64]	validation_0-rmse:0.41872	validation_1-rmse:0.48217
# [65]	validation_0-rmse:0.41411	validation_1-rmse:0.47744
# [66]	validation_0-rmse:0.40665	validation_1-rmse:0.46993
# [67]	validation_0-rmse:0.40069	validation_1-rmse:0.46196
# [68]	validation_0-rmse:0.39513	validation_1-rmse:0.45502
# [69]	validation_0-rmse:0.38829	validation_1-rmse:0.44683
# [70]	validation_0-rmse:0.38359	validation_1-rmse:0.44218
# [71]	validation_0-rmse:0.37883	validation_1-rmse:0.43683
# [72]	validation_0-rmse:0.37243	validation_1-rmse:0.42964
# [73]	validation_0-rmse:0.36737	validation_1-rmse:0.42397
# [74]	validation_0-rmse:0.36296	validation_1-rmse:0.41812
# [75]	validation_0-rmse:0.35781	validation_1-rmse:0.41271
# [76]	validation_0-rmse:0.35223	validation_1-rmse:0.40707
# [77]	validation_0-rmse:0.34726	validation_1-rmse:0.40181
# [78]	validation_0-rmse:0.34231	validation_1-rmse:0.39788
# [79]	validation_0-rmse:0.33774	validation_1-rmse:0.39258
# [80]	validation_0-rmse:0.33361	validation_1-rmse:0.38864
# [81]	validation_0-rmse:0.33085	validation_1-rmse:0.38518
# [82]	validation_0-rmse:0.32602	validation_1-rmse:0.38163
# [83]	validation_0-rmse:0.32148	validation_1-rmse:0.37619
# [84]	validation_0-rmse:0.31782	validation_1-rmse:0.37042
# [85]	validation_0-rmse:0.31482	validation_1-rmse:0.36793
# [86]	validation_0-rmse:0.31253	validation_1-rmse:0.36567
# [87]	validation_0-rmse:0.30880	validation_1-rmse:0.36051
# [88]	validation_0-rmse:0.30628	validation_1-rmse:0.35700
# [89]	validation_0-rmse:0.30248	validation_1-rmse:0.35243
# [90]	validation_0-rmse:0.29789	validation_1-rmse:0.34858
# [91]	validation_0-rmse:0.29499	validation_1-rmse:0.34418
# [92]	validation_0-rmse:0.29090	validation_1-rmse:0.33981
# [93]	validation_0-rmse:0.28805	validation_1-rmse:0.33663
# [94]	validation_0-rmse:0.28746	validation_1-rmse:0.33505
# [95]	validation_0-rmse:0.28699	validation_1-rmse:0.33404
# [96]	validation_0-rmse:0.28386	validation_1-rmse:0.33091
# [97]	validation_0-rmse:0.28095	validation_1-rmse:0.32740
# [98]	validation_0-rmse:0.27938	validation_1-rmse:0.32519
# [99]	validation_0-rmse:0.27679	validation_1-rmse:0.32208
# [100]	validation_0-rmse:0.27557	validation_1-rmse:0.32261
# [101]	validation_0-rmse:0.27414	validation_1-rmse:0.32086
# [102]	validation_0-rmse:0.27251	validation_1-rmse:0.31848
# [103]	validation_0-rmse:0.27170	validation_1-rmse:0.31680
# [104]	validation_0-rmse:0.27081	validation_1-rmse:0.31486
# [105]	validation_0-rmse:0.26821	validation_1-rmse:0.31213
# [106]	validation_0-rmse:0.26578	validation_1-rmse:0.30939
# [107]	validation_0-rmse:0.26356	validation_1-rmse:0.30595
# [108]	validation_0-rmse:0.26184	validation_1-rmse:0.30465
# [109]	validation_0-rmse:0.26026	validation_1-rmse:0.30191
# [110]	validation_0-rmse:0.25802	validation_1-rmse:0.29975
# [111]	validation_0-rmse:0.25737	validation_1-rmse:0.29808
# [112]	validation_0-rmse:0.25628	validation_1-rmse:0.29531
# [113]	validation_0-rmse:0.25400	validation_1-rmse:0.29465
# [114]	validation_0-rmse:0.25252	validation_1-rmse:0.29341
# [115]	validation_0-rmse:0.25166	validation_1-rmse:0.29192
# [116]	validation_0-rmse:0.24980	validation_1-rmse:0.29072
# [117]	validation_0-rmse:0.24864	validation_1-rmse:0.28758
# [118]	validation_0-rmse:0.24769	validation_1-rmse:0.28676
# [119]	validation_0-rmse:0.24707	validation_1-rmse:0.28417
# [120]	validation_0-rmse:0.24571	validation_1-rmse:0.28174
# [121]	validation_0-rmse:0.24430	validation_1-rmse:0.28252
# [122]	validation_0-rmse:0.24372	validation_1-rmse:0.28225
# [123]	validation_0-rmse:0.24287	validation_1-rmse:0.28127
# [124]	validation_0-rmse:0.24122	validation_1-rmse:0.27921
# [125]	validation_0-rmse:0.24050	validation_1-rmse:0.27821
# [126]	validation_0-rmse:0.23992	validation_1-rmse:0.27650
# [127]	validation_0-rmse:0.23819	validation_1-rmse:0.27483
# [128]	validation_0-rmse:0.23746	validation_1-rmse:0.27435
# [129]	validation_0-rmse:0.23674	validation_1-rmse:0.27186
# [130]	validation_0-rmse:0.23595	validation_1-rmse:0.27017
# [131]	validation_0-rmse:0.23496	validation_1-rmse:0.26883
# [132]	validation_0-rmse:0.23434	validation_1-rmse:0.26970
# [133]	validation_0-rmse:0.23276	validation_1-rmse:0.26785
# [134]	validation_0-rmse:0.23270	validation_1-rmse:0.26740
# [135]	validation_0-rmse:0.23248	validation_1-rmse:0.26623
# [136]	validation_0-rmse:0.23240	validation_1-rmse:0.26554
# [137]	validation_0-rmse:0.23190	validation_1-rmse:0.26316
# [138]	validation_0-rmse:0.23174	validation_1-rmse:0.26268
# [139]	validation_0-rmse:0.23133	validation_1-rmse:0.26062
# [140]	validation_0-rmse:0.23085	validation_1-rmse:0.26006
# [141]	validation_0-rmse:0.23085	validation_1-rmse:0.25984
# [142]	validation_0-rmse:0.22980	validation_1-rmse:0.25940
# [143]	validation_0-rmse:0.22891	validation_1-rmse:0.26000
# [144]	validation_0-rmse:0.22739	validation_1-rmse:0.25948
# [145]	validation_0-rmse:0.22725	validation_1-rmse:0.25842
# [146]	validation_0-rmse:0.22672	validation_1-rmse:0.25868
# [147]	validation_0-rmse:0.22504	validation_1-rmse:0.25805
# [148]	validation_0-rmse:0.22504	validation_1-rmse:0.25838
# [149]	validation_0-rmse:0.22441	validation_1-rmse:0.25828
# [150]	validation_0-rmse:0.22403	validation_1-rmse:0.25717
# [151]	validation_0-rmse:0.22330	validation_1-rmse:0.25739
# [152]	validation_0-rmse:0.22238	validation_1-rmse:0.25723
# [153]	validation_0-rmse:0.22143	validation_1-rmse:0.25712
# [154]	validation_0-rmse:0.22090	validation_1-rmse:0.25570
# [155]	validation_0-rmse:0.22061	validation_1-rmse:0.25406
# [156]	validation_0-rmse:0.22061	validation_1-rmse:0.25433
# [157]	validation_0-rmse:0.22019	validation_1-rmse:0.25384
# [158]	validation_0-rmse:0.22020	validation_1-rmse:0.25344
# [159]	validation_0-rmse:0.21977	validation_1-rmse:0.25327
# [160]	validation_0-rmse:0.21930	validation_1-rmse:0.25256
# [161]	validation_0-rmse:0.21878	validation_1-rmse:0.25169
# [162]	validation_0-rmse:0.21776	validation_1-rmse:0.25156
# [163]	validation_0-rmse:0.21698	validation_1-rmse:0.25057
# [164]	validation_0-rmse:0.21624	validation_1-rmse:0.25075
# [165]	validation_0-rmse:0.21609	validation_1-rmse:0.25125
# [166]	validation_0-rmse:0.21551	validation_1-rmse:0.25215
# [167]	validation_0-rmse:0.21499	validation_1-rmse:0.25207
# [168]	validation_0-rmse:0.21499	validation_1-rmse:0.25162
# [169]	validation_0-rmse:0.21450	validation_1-rmse:0.25308
# [170]	validation_0-rmse:0.21453	validation_1-rmse:0.25314
# [171]	validation_0-rmse:0.21379	validation_1-rmse:0.25313
# [172]	validation_0-rmse:0.21379	validation_1-rmse:0.25332
# [173]	validation_0-rmse:0.21354	validation_1-rmse:0.25517
# [174]	validation_0-rmse:0.21306	validation_1-rmse:0.25548
# [175]	validation_0-rmse:0.21183	validation_1-rmse:0.25451
# [176]	validation_0-rmse:0.21140	validation_1-rmse:0.25396
# [177]	validation_0-rmse:0.21089	validation_1-rmse:0.25330
# [178]	validation_0-rmse:0.21088	validation_1-rmse:0.25264
# [179]	validation_0-rmse:0.21088	validation_1-rmse:0.25264
# [180]	validation_0-rmse:0.21046	validation_1-rmse:0.25185
# [181]	validation_0-rmse:0.21048	validation_1-rmse:0.25134
# [182]	validation_0-rmse:0.21014	validation_1-rmse:0.25113
# [183]	validation_0-rmse:0.21027	validation_1-rmse:0.25110
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.75384	validation_1-rmse:1.81601
# [1]	validation_0-rmse:1.70754	validation_1-rmse:1.76647
# [2]	validation_0-rmse:1.66234	validation_1-rmse:1.71756
# [3]	validation_0-rmse:1.61965	validation_1-rmse:1.67081
# [4]	validation_0-rmse:1.58162	validation_1-rmse:1.62937
# [5]	validation_0-rmse:1.54168	validation_1-rmse:1.58763
# [6]	validation_0-rmse:1.50312	validation_1-rmse:1.54520
# [7]	validation_0-rmse:1.46466	validation_1-rmse:1.50798
# [8]	validation_0-rmse:1.42711	validation_1-rmse:1.46890
# [9]	validation_0-rmse:1.39240	validation_1-rmse:1.43282
# [10]	validation_0-rmse:1.36190	validation_1-rmse:1.40241
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:1.32903	validation_1-rmse:1.36596
# [12]	validation_0-rmse:1.29624	validation_1-rmse:1.33099
# [13]	validation_0-rmse:1.26309	validation_1-rmse:1.29551
# [14]	validation_0-rmse:1.23200	validation_1-rmse:1.26186
# [15]	validation_0-rmse:1.20309	validation_1-rmse:1.23375
# [16]	validation_0-rmse:1.17358	validation_1-rmse:1.20230
# [17]	validation_0-rmse:1.14375	validation_1-rmse:1.17080
# [18]	validation_0-rmse:1.11894	validation_1-rmse:1.14526
# [19]	validation_0-rmse:1.09261	validation_1-rmse:1.11655
# [20]	validation_0-rmse:1.06624	validation_1-rmse:1.08804
# [21]	validation_0-rmse:1.04487	validation_1-rmse:1.06476
# [22]	validation_0-rmse:1.02233	validation_1-rmse:1.04240
# [23]	validation_0-rmse:0.99772	validation_1-rmse:1.01698
# [24]	validation_0-rmse:0.97473	validation_1-rmse:0.99265
# [25]	validation_0-rmse:0.95260	validation_1-rmse:0.96872
# [26]	validation_0-rmse:0.93166	validation_1-rmse:0.94637
# [27]	validation_0-rmse:0.90944	validation_1-rmse:0.92444
# [28]	validation_0-rmse:0.88695	validation_1-rmse:0.90124
# [29]	validation_0-rmse:0.86516	validation_1-rmse:0.87991
# [30]	validation_0-rmse:0.84656	validation_1-rmse:0.86026
# [31]	validation_0-rmse:0.82755	validation_1-rmse:0.84229
# [32]	validation_0-rmse:0.80867	validation_1-rmse:0.82435
# [33]	validation_0-rmse:0.78994	validation_1-rmse:0.80609
# [34]	validation_0-rmse:0.77293	validation_1-rmse:0.79052
# [35]	validation_0-rmse:0.75616	validation_1-rmse:0.77417
# [36]	validation_0-rmse:0.73833	validation_1-rmse:0.75799
# [37]	validation_0-rmse:0.72306	validation_1-rmse:0.74241
# [38]	validation_0-rmse:0.70694	validation_1-rmse:0.72674
# [39]	validation_0-rmse:0.69247	validation_1-rmse:0.71241
# [40]	validation_0-rmse:0.67811	validation_1-rmse:0.70001
# [41]	validation_0-rmse:0.66443	validation_1-rmse:0.68590
# [42]	validation_0-rmse:0.65145	validation_1-rmse:0.67317
# [43]	validation_0-rmse:0.63785	validation_1-rmse:0.65843
# [44]	validation_0-rmse:0.62537	validation_1-rmse:0.64765
# [45]	validation_0-rmse:0.61069	validation_1-rmse:0.63205
# [46]	validation_0-rmse:0.59700	validation_1-rmse:0.61646
# [47]	validation_0-rmse:0.58545	validation_1-rmse:0.60314
# [48]	validation_0-rmse:0.57355	validation_1-rmse:0.59209
# [49]	validation_0-rmse:0.56269	validation_1-rmse:0.58156
# [50]	validation_0-rmse:0.55254	validation_1-rmse:0.57247
# [51]	validation_0-rmse:0.54341	validation_1-rmse:0.56337
# [52]	validation_0-rmse:0.53316	validation_1-rmse:0.55398
# [53]	validation_0-rmse:0.52293	validation_1-rmse:0.54459
# [54]	validation_0-rmse:0.51209	validation_1-rmse:0.53581
# [55]	validation_0-rmse:0.50082	validation_1-rmse:0.52510
# [56]	validation_0-rmse:0.49096	validation_1-rmse:0.51641
# [57]	validation_0-rmse:0.48039	validation_1-rmse:0.50822
# [58]	validation_0-rmse:0.47113	validation_1-rmse:0.50111
# [59]	validation_0-rmse:0.46264	validation_1-rmse:0.49370
# [60]	validation_0-rmse:0.45549	validation_1-rmse:0.48639
# [61]	validation_0-rmse:0.44883	validation_1-rmse:0.47890
# [62]	validation_0-rmse:0.44040	validation_1-rmse:0.47284
# [63]	validation_0-rmse:0.43308	validation_1-rmse:0.46747
# [64]	validation_0-rmse:0.42433	validation_1-rmse:0.45895
# [65]	validation_0-rmse:0.41911	validation_1-rmse:0.45397
# [66]	validation_0-rmse:0.41255	validation_1-rmse:0.44970
# [67]	validation_0-rmse:0.40409	validation_1-rmse:0.44341
# [68]	validation_0-rmse:0.39935	validation_1-rmse:0.43919
# [69]	validation_0-rmse:0.39322	validation_1-rmse:0.43368
# [70]	validation_0-rmse:0.38640	validation_1-rmse:0.42960
# [71]	validation_0-rmse:0.38032	validation_1-rmse:0.42519
# [72]	validation_0-rmse:0.37346	validation_1-rmse:0.42029
# [73]	validation_0-rmse:0.36697	validation_1-rmse:0.41506
# [74]	validation_0-rmse:0.36211	validation_1-rmse:0.41125
# [75]	validation_0-rmse:0.35719	validation_1-rmse:0.40701
# [76]	validation_0-rmse:0.35256	validation_1-rmse:0.40465
# [77]	validation_0-rmse:0.34770	validation_1-rmse:0.40194
# [78]	validation_0-rmse:0.34206	validation_1-rmse:0.39698
# [79]	validation_0-rmse:0.33682	validation_1-rmse:0.39456
# [80]	validation_0-rmse:0.33218	validation_1-rmse:0.39027
# [81]	validation_0-rmse:0.32725	validation_1-rmse:0.38993
# [82]	validation_0-rmse:0.32426	validation_1-rmse:0.38772
# [83]	validation_0-rmse:0.32045	validation_1-rmse:0.38600
# [84]	validation_0-rmse:0.31729	validation_1-rmse:0.38354
# [85]	validation_0-rmse:0.31364	validation_1-rmse:0.38058
# [86]	validation_0-rmse:0.31052	validation_1-rmse:0.37959
# [87]	validation_0-rmse:0.30835	validation_1-rmse:0.37852
# [88]	validation_0-rmse:0.30470	validation_1-rmse:0.37622
# [89]	validation_0-rmse:0.30088	validation_1-rmse:0.37365
# [90]	validation_0-rmse:0.29994	validation_1-rmse:0.37301
# [91]	validation_0-rmse:0.29672	validation_1-rmse:0.37111
# [92]	validation_0-rmse:0.29425	validation_1-rmse:0.36887
# [93]	validation_0-rmse:0.29149	validation_1-rmse:0.36618
# [94]	validation_0-rmse:0.28772	validation_1-rmse:0.36313
# [95]	validation_0-rmse:0.28368	validation_1-rmse:0.36045
# [96]	validation_0-rmse:0.28194	validation_1-rmse:0.35975
# [97]	validation_0-rmse:0.27972	validation_1-rmse:0.35872
# [98]	validation_0-rmse:0.27814	validation_1-rmse:0.35823
# [99]	validation_0-rmse:0.27496	validation_1-rmse:0.35648
# [100]	validation_0-rmse:0.27334	validation_1-rmse:0.35548
# [101]	validation_0-rmse:0.27099	validation_1-rmse:0.35527
# [102]	validation_0-rmse:0.26826	validation_1-rmse:0.35260
# [103]	validation_0-rmse:0.26651	validation_1-rmse:0.35218
# [104]	validation_0-rmse:0.26363	validation_1-rmse:0.34929
# [105]	validation_0-rmse:0.26090	validation_1-rmse:0.34950
# [106]	validation_0-rmse:0.25925	validation_1-rmse:0.34973
# [107]	validation_0-rmse:0.25799	validation_1-rmse:0.34867
# [108]	validation_0-rmse:0.25548	validation_1-rmse:0.34632
# [109]	validation_0-rmse:0.25299	validation_1-rmse:0.34423
# [110]	validation_0-rmse:0.25201	validation_1-rmse:0.34397
# [111]	validation_0-rmse:0.25060	validation_1-rmse:0.34344
# [112]	validation_0-rmse:0.24927	validation_1-rmse:0.34295
# [113]	validation_0-rmse:0.24742	validation_1-rmse:0.34138
# [114]	validation_0-rmse:0.24632	validation_1-rmse:0.34119
# [115]	validation_0-rmse:0.24605	validation_1-rmse:0.34228
# [116]	validation_0-rmse:0.24412	validation_1-rmse:0.34184
# [117]	validation_0-rmse:0.24348	validation_1-rmse:0.34173
# [118]	validation_0-rmse:0.24233	validation_1-rmse:0.34295
# [119]	validation_0-rmse:0.24030	validation_1-rmse:0.34163
# [120]	validation_0-rmse:0.23999	validation_1-rmse:0.34152
# [121]	validation_0-rmse:0.23921	validation_1-rmse:0.34143
# [122]	validation_0-rmse:0.23778	validation_1-rmse:0.34042
# [123]	validation_0-rmse:0.23668	validation_1-rmse:0.34052
# [124]	validation_0-rmse:0.23593	validation_1-rmse:0.33941
# [125]	validation_0-rmse:0.23508	validation_1-rmse:0.33910
# [126]	validation_0-rmse:0.23417	validation_1-rmse:0.33901
# [127]	validation_0-rmse:0.23288	validation_1-rmse:0.33953
# [128]	validation_0-rmse:0.23143	validation_1-rmse:0.34000
# [129]	validation_0-rmse:0.22994	validation_1-rmse:0.33983
# [130]	validation_0-rmse:0.22953	validation_1-rmse:0.33920
# [131]	validation_0-rmse:0.22904	validation_1-rmse:0.33892
# [132]	validation_0-rmse:0.22774	validation_1-rmse:0.33994
# [133]	validation_0-rmse:0.22658	validation_1-rmse:0.34049
# [134]	validation_0-rmse:0.22505	validation_1-rmse:0.34163
# [135]	validation_0-rmse:0.22459	validation_1-rmse:0.34156
# [136]	validation_0-rmse:0.22386	validation_1-rmse:0.34222
# [137]	validation_0-rmse:0.22286	validation_1-rmse:0.34249
# [138]	validation_0-rmse:0.22233	validation_1-rmse:0.34282
# [139]	validation_0-rmse:0.22215	validation_1-rmse:0.34280
# [140]	validation_0-rmse:0.22077	validation_1-rmse:0.34318
# [141]	validation_0-rmse:0.22023	validation_1-rmse:0.34166
# [142]	validation_0-rmse:0.22010	validation_1-rmse:0.34165
# [143]	validation_0-rmse:0.21932	validation_1-rmse:0.34164
# [144]	validation_0-rmse:0.21827	validation_1-rmse:0.34149
# [145]	validation_0-rmse:0.21809	validation_1-rmse:0.34150
# [146]	validation_0-rmse:0.21713	validation_1-rmse:0.34129
# [147]	validation_0-rmse:0.21693	validation_1-rmse:0.34193
# [148]	validation_0-rmse:0.21548	validation_1-rmse:0.34339
# [149]	validation_0-rmse:0.21538	validation_1-rmse:0.34339
# [150]	validation_0-rmse:0.21475	validation_1-rmse:0.34241
# [151]	validation_0-rmse:0.21353	validation_1-rmse:0.34190
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.76053	validation_1-rmse:1.79323
# [1]	validation_0-rmse:1.71582	validation_1-rmse:1.74604
# [2]	validation_0-rmse:1.67136	validation_1-rmse:1.70028
# [3]	validation_0-rmse:1.63073	validation_1-rmse:1.65621
# [4]	validation_0-rmse:1.59291	validation_1-rmse:1.61955
# [5]	validation_0-rmse:1.55265	validation_1-rmse:1.57678
# [6]	validation_0-rmse:1.51747	validation_1-rmse:1.53756
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:1.48283	validation_1-rmse:1.50185
# [8]	validation_0-rmse:1.44657	validation_1-rmse:1.46567
# [9]	validation_0-rmse:1.40850	validation_1-rmse:1.42465
# [10]	validation_0-rmse:1.37929	validation_1-rmse:1.39358
# [11]	validation_0-rmse:1.35010	validation_1-rmse:1.36070
# [12]	validation_0-rmse:1.31852	validation_1-rmse:1.32688
# [13]	validation_0-rmse:1.28743	validation_1-rmse:1.29337
# [14]	validation_0-rmse:1.25528	validation_1-rmse:1.25888
# [15]	validation_0-rmse:1.22585	validation_1-rmse:1.22885
# [16]	validation_0-rmse:1.19724	validation_1-rmse:1.19698
# [17]	validation_0-rmse:1.16660	validation_1-rmse:1.16529
# [18]	validation_0-rmse:1.13736	validation_1-rmse:1.13327
# [19]	validation_0-rmse:1.10926	validation_1-rmse:1.10451
# [20]	validation_0-rmse:1.08294	validation_1-rmse:1.07589
# [21]	validation_0-rmse:1.05553	validation_1-rmse:1.04460
# [22]	validation_0-rmse:1.02876	validation_1-rmse:1.01712
# [23]	validation_0-rmse:1.00357	validation_1-rmse:0.98795
# [24]	validation_0-rmse:0.97891	validation_1-rmse:0.96235
# [25]	validation_0-rmse:0.95674	validation_1-rmse:0.93738
# [26]	validation_0-rmse:0.93427	validation_1-rmse:0.91228
# [27]	validation_0-rmse:0.91184	validation_1-rmse:0.88896
# [28]	validation_0-rmse:0.89194	validation_1-rmse:0.86729
# [29]	validation_0-rmse:0.87034	validation_1-rmse:0.84509
# [30]	validation_0-rmse:0.85270	validation_1-rmse:0.82624
# [31]	validation_0-rmse:0.83311	validation_1-rmse:0.80449
# [32]	validation_0-rmse:0.81722	validation_1-rmse:0.78572
# [33]	validation_0-rmse:0.80052	validation_1-rmse:0.76900
# [34]	validation_0-rmse:0.78047	validation_1-rmse:0.74715
# [35]	validation_0-rmse:0.76409	validation_1-rmse:0.73099
# [36]	validation_0-rmse:0.74502	validation_1-rmse:0.71055
# [37]	validation_0-rmse:0.73119	validation_1-rmse:0.69597
# [38]	validation_0-rmse:0.71691	validation_1-rmse:0.67883
# [39]	validation_0-rmse:0.70133	validation_1-rmse:0.66186
# [40]	validation_0-rmse:0.69017	validation_1-rmse:0.64988
# [41]	validation_0-rmse:0.67411	validation_1-rmse:0.63445
# [42]	validation_0-rmse:0.65906	validation_1-rmse:0.61883
# [43]	validation_0-rmse:0.64551	validation_1-rmse:0.60293
# [44]	validation_0-rmse:0.63385	validation_1-rmse:0.58715
# [45]	validation_0-rmse:0.62127	validation_1-rmse:0.57317
# [46]	validation_0-rmse:0.60954	validation_1-rmse:0.56148
# [47]	validation_0-rmse:0.59768	validation_1-rmse:0.55033
# [48]	validation_0-rmse:0.58619	validation_1-rmse:0.53815
# [49]	validation_0-rmse:0.57365	validation_1-rmse:0.52551
# [50]	validation_0-rmse:0.56236	validation_1-rmse:0.51557
# [51]	validation_0-rmse:0.55109	validation_1-rmse:0.50415
# [52]	validation_0-rmse:0.53909	validation_1-rmse:0.49177
# [53]	validation_0-rmse:0.52906	validation_1-rmse:0.48268
# [54]	validation_0-rmse:0.51889	validation_1-rmse:0.47117
# [55]	validation_0-rmse:0.51254	validation_1-rmse:0.46415
# [56]	validation_0-rmse:0.50308	validation_1-rmse:0.45447
# [57]	validation_0-rmse:0.49393	validation_1-rmse:0.44643
# [58]	validation_0-rmse:0.48499	validation_1-rmse:0.43815
# [59]	validation_0-rmse:0.47687	validation_1-rmse:0.42981
# [60]	validation_0-rmse:0.46972	validation_1-rmse:0.42261
# [61]	validation_0-rmse:0.46260	validation_1-rmse:0.41479
# [62]	validation_0-rmse:0.45501	validation_1-rmse:0.40731
# [63]	validation_0-rmse:0.44809	validation_1-rmse:0.40354
# [64]	validation_0-rmse:0.44129	validation_1-rmse:0.39547
# [65]	validation_0-rmse:0.43583	validation_1-rmse:0.39357
# [66]	validation_0-rmse:0.42820	validation_1-rmse:0.38587
# [67]	validation_0-rmse:0.42112	validation_1-rmse:0.37813
# [68]	validation_0-rmse:0.41622	validation_1-rmse:0.37180
# [69]	validation_0-rmse:0.40924	validation_1-rmse:0.36470
# [70]	validation_0-rmse:0.40259	validation_1-rmse:0.35805
# [71]	validation_0-rmse:0.39683	validation_1-rmse:0.35254
# [72]	validation_0-rmse:0.39023	validation_1-rmse:0.34837
# [73]	validation_0-rmse:0.38526	validation_1-rmse:0.34299
# [74]	validation_0-rmse:0.37905	validation_1-rmse:0.33843
# [75]	validation_0-rmse:0.37441	validation_1-rmse:0.33342
# [76]	validation_0-rmse:0.36971	validation_1-rmse:0.32930
# [77]	validation_0-rmse:0.36531	validation_1-rmse:0.32529
# [78]	validation_0-rmse:0.36320	validation_1-rmse:0.32450
# [79]	validation_0-rmse:0.35888	validation_1-rmse:0.31965
# [80]	validation_0-rmse:0.35516	validation_1-rmse:0.31484
# [81]	validation_0-rmse:0.35104	validation_1-rmse:0.31167
# [82]	validation_0-rmse:0.34503	validation_1-rmse:0.30863
# [83]	validation_0-rmse:0.34034	validation_1-rmse:0.30547
# [84]	validation_0-rmse:0.33618	validation_1-rmse:0.30237
# [85]	validation_0-rmse:0.33340	validation_1-rmse:0.29998
# [86]	validation_0-rmse:0.32936	validation_1-rmse:0.29700
# [87]	validation_0-rmse:0.32642	validation_1-rmse:0.29440
# [88]	validation_0-rmse:0.32451	validation_1-rmse:0.29403
# [89]	validation_0-rmse:0.32097	validation_1-rmse:0.29140
# [90]	validation_0-rmse:0.31748	validation_1-rmse:0.28862
# [91]	validation_0-rmse:0.31334	validation_1-rmse:0.28576
# [92]	validation_0-rmse:0.30919	validation_1-rmse:0.28263
# [93]	validation_0-rmse:0.30659	validation_1-rmse:0.28043
# [94]	validation_0-rmse:0.30480	validation_1-rmse:0.27895
# [95]	validation_0-rmse:0.30182	validation_1-rmse:0.27662
# [96]	validation_0-rmse:0.29985	validation_1-rmse:0.27543
# [97]	validation_0-rmse:0.29669	validation_1-rmse:0.27223
# [98]	validation_0-rmse:0.29416	validation_1-rmse:0.26842
# [99]	validation_0-rmse:0.29078	validation_1-rmse:0.26570
# [100]	validation_0-rmse:0.29029	validation_1-rmse:0.26511
# [101]	validation_0-rmse:0.28810	validation_1-rmse:0.26285
# [102]	validation_0-rmse:0.28665	validation_1-rmse:0.26332
# [103]	validation_0-rmse:0.28511	validation_1-rmse:0.26145
# [104]	validation_0-rmse:0.28346	validation_1-rmse:0.25924
# [105]	validation_0-rmse:0.28062	validation_1-rmse:0.25747
# [106]	validation_0-rmse:0.27940	validation_1-rmse:0.25603
# [107]	validation_0-rmse:0.27707	validation_1-rmse:0.25631
# [108]	validation_0-rmse:0.27570	validation_1-rmse:0.25441
# [109]	validation_0-rmse:0.27326	validation_1-rmse:0.25403
# [110]	validation_0-rmse:0.27112	validation_1-rmse:0.25274
# [111]	validation_0-rmse:0.26859	validation_1-rmse:0.25301
# [112]	validation_0-rmse:0.26745	validation_1-rmse:0.25192
# [113]	validation_0-rmse:0.26555	validation_1-rmse:0.25044
# [114]	validation_0-rmse:0.26305	validation_1-rmse:0.25042
# [115]	validation_0-rmse:0.26118	validation_1-rmse:0.24898
# [116]	validation_0-rmse:0.26015	validation_1-rmse:0.24843
# [117]	validation_0-rmse:0.25916	validation_1-rmse:0.24733
# [118]	validation_0-rmse:0.25857	validation_1-rmse:0.24662
# [119]	validation_0-rmse:0.25586	validation_1-rmse:0.24781
# [120]	validation_0-rmse:0.25455	validation_1-rmse:0.24699
# [121]	validation_0-rmse:0.25384	validation_1-rmse:0.24653
# [122]	validation_0-rmse:0.25213	validation_1-rmse:0.24638
# [123]	validation_0-rmse:0.25145	validation_1-rmse:0.24636
# [124]	validation_0-rmse:0.24964	validation_1-rmse:0.24590
# [125]	validation_0-rmse:0.24856	validation_1-rmse:0.24546
# [126]	validation_0-rmse:0.24749	validation_1-rmse:0.24452
# [127]	validation_0-rmse:0.24607	validation_1-rmse:0.24402
# [128]	validation_0-rmse:0.24485	validation_1-rmse:0.24315
# [129]	validation_0-rmse:0.24370	validation_1-rmse:0.24288
# [130]	validation_0-rmse:0.24204	validation_1-rmse:0.24450
# [131]	validation_0-rmse:0.24123	validation_1-rmse:0.24467
# [132]	validation_0-rmse:0.23980	validation_1-rmse:0.24427
# [133]	validation_0-rmse:0.23851	validation_1-rmse:0.24361
# [134]	validation_0-rmse:0.23858	validation_1-rmse:0.24507
# [135]	validation_0-rmse:0.23798	validation_1-rmse:0.24427
# [136]	validation_0-rmse:0.23802	validation_1-rmse:0.24435
# [137]	validation_0-rmse:0.23668	validation_1-rmse:0.24607
# [138]	validation_0-rmse:0.23576	validation_1-rmse:0.24610
# [139]	validation_0-rmse:0.23567	validation_1-rmse:0.24595
# [140]	validation_0-rmse:0.23447	validation_1-rmse:0.24611
# [141]	validation_0-rmse:0.23374	validation_1-rmse:0.24545
# [142]	validation_0-rmse:0.23250	validation_1-rmse:0.24726
# [143]	validation_0-rmse:0.23171	validation_1-rmse:0.24720
# [144]	validation_0-rmse:0.23104	validation_1-rmse:0.24873
# [145]	validation_0-rmse:0.23048	validation_1-rmse:0.24731
# [146]	validation_0-rmse:0.22921	validation_1-rmse:0.24777
# [147]	validation_0-rmse:0.22871	validation_1-rmse:0.24663
# [148]	validation_0-rmse:0.22846	validation_1-rmse:0.24590
# [149]	validation_0-rmse:0.22774	validation_1-rmse:0.24477
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.84323	validation_1-rmse:1.43627
# [1]	validation_0-rmse:1.79555	validation_1-rmse:1.39525
# [2]	validation_0-rmse:1.74907	validation_1-rmse:1.35037
# [3]	validation_0-rmse:1.70153	validation_1-rmse:1.30695
# [4]	validation_0-rmse:1.66166	validation_1-rmse:1.27139
# [5]	validation_0-rmse:1.61684	validation_1-rmse:1.23048
# [6]	validation_0-rmse:1.57532	validation_1-rmse:1.19126
# [7]	validation_0-rmse:1.53374	validation_1-rmse:1.15541
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:1.49509	validation_1-rmse:1.11992
# [9]	validation_0-rmse:1.45905	validation_1-rmse:1.08545
# [10]	validation_0-rmse:1.42753	validation_1-rmse:1.05561
# [11]	validation_0-rmse:1.40247	validation_1-rmse:1.03343
# [12]	validation_0-rmse:1.36551	validation_1-rmse:0.99911
# [13]	validation_0-rmse:1.33140	validation_1-rmse:0.96790
# [14]	validation_0-rmse:1.29974	validation_1-rmse:0.93824
# [15]	validation_0-rmse:1.26911	validation_1-rmse:0.91260
# [16]	validation_0-rmse:1.23770	validation_1-rmse:0.88419
# [17]	validation_0-rmse:1.20572	validation_1-rmse:0.85819
# [18]	validation_0-rmse:1.17700	validation_1-rmse:0.83346
# [19]	validation_0-rmse:1.14486	validation_1-rmse:0.80673
# [20]	validation_0-rmse:1.11729	validation_1-rmse:0.78338
# [21]	validation_0-rmse:1.08892	validation_1-rmse:0.75834
# [22]	validation_0-rmse:1.06259	validation_1-rmse:0.73634
# [23]	validation_0-rmse:1.03581	validation_1-rmse:0.71111
# [24]	validation_0-rmse:1.01179	validation_1-rmse:0.69049
# [25]	validation_0-rmse:0.98810	validation_1-rmse:0.67274
# [26]	validation_0-rmse:0.96540	validation_1-rmse:0.65217
# [27]	validation_0-rmse:0.94182	validation_1-rmse:0.63209
# [28]	validation_0-rmse:0.92081	validation_1-rmse:0.61415
# [29]	validation_0-rmse:0.89830	validation_1-rmse:0.59779
# [30]	validation_0-rmse:0.88162	validation_1-rmse:0.58352
# [31]	validation_0-rmse:0.86130	validation_1-rmse:0.56829
# [32]	validation_0-rmse:0.84472	validation_1-rmse:0.55790
# [33]	validation_0-rmse:0.82393	validation_1-rmse:0.54297
# [34]	validation_0-rmse:0.80446	validation_1-rmse:0.52731
# [35]	validation_0-rmse:0.78801	validation_1-rmse:0.52014
# [36]	validation_0-rmse:0.77039	validation_1-rmse:0.50401
# [37]	validation_0-rmse:0.75399	validation_1-rmse:0.49479
# [38]	validation_0-rmse:0.73641	validation_1-rmse:0.48370
# [39]	validation_0-rmse:0.71803	validation_1-rmse:0.47236
# [40]	validation_0-rmse:0.70177	validation_1-rmse:0.45975
# [41]	validation_0-rmse:0.68887	validation_1-rmse:0.45137
# [42]	validation_0-rmse:0.67308	validation_1-rmse:0.44198
# [43]	validation_0-rmse:0.65767	validation_1-rmse:0.43295
# [44]	validation_0-rmse:0.64203	validation_1-rmse:0.42017
# [45]	validation_0-rmse:0.63067	validation_1-rmse:0.41455
# [46]	validation_0-rmse:0.61792	validation_1-rmse:0.40542
# [47]	validation_0-rmse:0.60294	validation_1-rmse:0.39450
# [48]	validation_0-rmse:0.58886	validation_1-rmse:0.38712
# [49]	validation_0-rmse:0.57616	validation_1-rmse:0.37985
# [50]	validation_0-rmse:0.56583	validation_1-rmse:0.37477
# [51]	validation_0-rmse:0.55442	validation_1-rmse:0.36764
# [52]	validation_0-rmse:0.54309	validation_1-rmse:0.35999
# [53]	validation_0-rmse:0.53553	validation_1-rmse:0.35561
# [54]	validation_0-rmse:0.52534	validation_1-rmse:0.35042
# [55]	validation_0-rmse:0.51492	validation_1-rmse:0.34655
# [56]	validation_0-rmse:0.50464	validation_1-rmse:0.34343
# [57]	validation_0-rmse:0.49391	validation_1-rmse:0.33938
# [58]	validation_0-rmse:0.48485	validation_1-rmse:0.33737
# [59]	validation_0-rmse:0.47356	validation_1-rmse:0.33327
# [60]	validation_0-rmse:0.46381	validation_1-rmse:0.33027
# [61]	validation_0-rmse:0.45272	validation_1-rmse:0.32339
# [62]	validation_0-rmse:0.44531	validation_1-rmse:0.31954
# [63]	validation_0-rmse:0.43757	validation_1-rmse:0.31957
# [64]	validation_0-rmse:0.42876	validation_1-rmse:0.31577
# [65]	validation_0-rmse:0.42337	validation_1-rmse:0.31186
# [66]	validation_0-rmse:0.41487	validation_1-rmse:0.30924
# [67]	validation_0-rmse:0.40721	validation_1-rmse:0.30633
# [68]	validation_0-rmse:0.40141	validation_1-rmse:0.30481
# [69]	validation_0-rmse:0.39365	validation_1-rmse:0.30193
# [70]	validation_0-rmse:0.38728	validation_1-rmse:0.30119
# [71]	validation_0-rmse:0.38018	validation_1-rmse:0.30147
# [72]	validation_0-rmse:0.37427	validation_1-rmse:0.29955
# [73]	validation_0-rmse:0.36918	validation_1-rmse:0.29766
# [74]	validation_0-rmse:0.36305	validation_1-rmse:0.29722
# [75]	validation_0-rmse:0.35781	validation_1-rmse:0.29545
# [76]	validation_0-rmse:0.35221	validation_1-rmse:0.29433
# [77]	validation_0-rmse:0.34717	validation_1-rmse:0.29414
# [78]	validation_0-rmse:0.34268	validation_1-rmse:0.29538
# [79]	validation_0-rmse:0.33670	validation_1-rmse:0.29525
# [80]	validation_0-rmse:0.33157	validation_1-rmse:0.29476
# [81]	validation_0-rmse:0.32715	validation_1-rmse:0.29430
# [82]	validation_0-rmse:0.32288	validation_1-rmse:0.29417
# [83]	validation_0-rmse:0.31755	validation_1-rmse:0.29288
# [84]	validation_0-rmse:0.31223	validation_1-rmse:0.29390
# [85]	validation_0-rmse:0.30849	validation_1-rmse:0.29382
# [86]	validation_0-rmse:0.30476	validation_1-rmse:0.29275
# [87]	validation_0-rmse:0.30121	validation_1-rmse:0.29198
# [88]	validation_0-rmse:0.29727	validation_1-rmse:0.29147
# [89]	validation_0-rmse:0.29325	validation_1-rmse:0.29330
# [90]	validation_0-rmse:0.29082	validation_1-rmse:0.29376
# [91]	validation_0-rmse:0.28795	validation_1-rmse:0.29339
# [92]	validation_0-rmse:0.28535	validation_1-rmse:0.29288
# [93]	validation_0-rmse:0.28226	validation_1-rmse:0.29250
# [94]	validation_0-rmse:0.27957	validation_1-rmse:0.29200
# [95]	validation_0-rmse:0.27819	validation_1-rmse:0.29298
# [96]	validation_0-rmse:0.27654	validation_1-rmse:0.29242
# [97]	validation_0-rmse:0.27395	validation_1-rmse:0.29319
# [98]	validation_0-rmse:0.27075	validation_1-rmse:0.29493
# [99]	validation_0-rmse:0.26852	validation_1-rmse:0.29440
# [100]	validation_0-rmse:0.26555	validation_1-rmse:0.29507
# [101]	validation_0-rmse:0.26253	validation_1-rmse:0.29670
# [102]	validation_0-rmse:0.25998	validation_1-rmse:0.29844
# [103]	validation_0-rmse:0.25709	validation_1-rmse:0.29846
# [104]	validation_0-rmse:0.25609	validation_1-rmse:0.29940
# [105]	validation_0-rmse:0.25467	validation_1-rmse:0.29904
# [106]	validation_0-rmse:0.25252	validation_1-rmse:0.29891
# [107]	validation_0-rmse:0.25105	validation_1-rmse:0.29878
# [108]	validation_0-rmse:0.25016	validation_1-rmse:0.29788
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.75990	validation_1-rmse:1.77483
# [1]	validation_0-rmse:1.71588	validation_1-rmse:1.73587
# [2]	validation_0-rmse:1.66788	validation_1-rmse:1.69261
# [3]	validation_0-rmse:1.62380	validation_1-rmse:1.65340
# [4]	validation_0-rmse:1.58519	validation_1-rmse:1.61789
# [5]	validation_0-rmse:1.54240	validation_1-rmse:1.57854
# [6]	validation_0-rmse:1.50548	validation_1-rmse:1.54143
# [7]	validation_0-rmse:1.46681	validation_1-rmse:1.50584
# [8]	validation_0-rmse:1.42843	validation_1-rmse:1.47343
# [9]	validation_0-rmse:1.39836	validation_1-rmse:1.44456
# [10]	validation_0-rmse:1.36436	validation_1-rmse:1.41291
# [11]	validation_0-rmse:1.33259	validation_1-rmse:1.38350
# [12]	validation_0-rmse:1.29557	validation_1-rmse:1.34960
# [13]	validation_0-rmse:1.26392	validation_1-rmse:1.31798
# [14]	validation_0-rmse:1.23167	validation_1-rmse:1.28897
# [15]	validation_0-rmse:1.20188	validation_1-rmse:1.26014
# [16]	validation_0-rmse:1.17108	validation_1-rmse:1.23107
# [17]	validation_0-rmse:1.14228	validation_1-rmse:1.20861
# ...
# [77]	validation_0-rmse:0.35791	validation_1-rmse:0.44184
# [78]	validation_0-rmse:0.35395	validation_1-rmse:0.43809
# [79]	validation_0-rmse:0.34804	validation_1-rmse:0.43321
# [80]	validation_0-rmse:0.34358	validation_1-rmse:0.43070
# [81]	validation_0-rmse:0.33916	validation_1-rmse:0.42602
# [82]	validation_0-rmse:0.33483	validation_1-rmse:0.42132
# [83]	validation_0-rmse:0.33037	validation_1-rmse:0.41659
# [84]	validation_0-rmse:0.32514	validation_1-rmse:0.41164
# [85]	validation_0-rmse:0.32100	validation_1-rmse:0.40669
# [86]	validation_0-rmse:0.31695	validation_1-rmse:0.40456
# [87]	validation_0-rmse:0.31299	validation_1-rmse:0.40129
# [88]	validation_0-rmse:0.30939	validation_1-rmse:0.39822
# [89]	validation_0-rmse:0.30695	validation_1-rmse:0.39608
# [90]	validation_0-rmse:0.30338	validation_1-rmse:0.39258
# [91]	validation_0-rmse:0.29998	validation_1-rmse:0.39004
# [92]	validation_0-rmse:0.29740	validation_1-rmse:0.38855
# [93]	validation_0-rmse:0.29464	validation_1-rmse:0.38473
# [94]	validation_0-rmse:0.29273	validation_1-rmse:0.38391
# [95]	validation_0-rmse:0.29057	validation_1-rmse:0.38279
# [96]	validation_0-rmse:0.28824	validation_1-rmse:0.38190
# [97]	validation_0-rmse:0.28674	validation_1-rmse:0.38153
# [98]	validation_0-rmse:0.28316	validation_1-rmse:0.37870
# [99]	validation_0-rmse:0.28087	validation_1-rmse:0.37639
# [100]	validation_0-rmse:0.27758	validation_1-rmse:0.37687
# [101]	validation_0-rmse:0.27611	validation_1-rmse:0.37591
# [102]	validation_0-rmse:0.27440	validation_1-rmse:0.37505
# [103]	validation_0-rmse:0.27221	validation_1-rmse:0.37267
# [104]	validation_0-rmse:0.27077	validation_1-rmse:0.37201
# [105]	validation_0-rmse:0.26907	validation_1-rmse:0.37093
# [106]	validation_0-rmse:0.26772	validation_1-rmse:0.36825
# [107]	validation_0-rmse:0.26427	validation_1-rmse:0.36786
# [108]	validation_0-rmse:0.26230	validation_1-rmse:0.36435
# [109]	validation_0-rmse:0.26137	validation_1-rmse:0.36431
# [110]	validation_0-rmse:0.25975	validation_1-rmse:0.36205
# [111]	validation_0-rmse:0.25937	validation_1-rmse:0.36272
# [112]	validation_0-rmse:0.25785	validation_1-rmse:0.36263
# [113]	validation_0-rmse:0.25661	validation_1-rmse:0.36123
# [114]	validation_0-rmse:0.25508	validation_1-rmse:0.36006
# [115]	validation_0-rmse:0.25342	validation_1-rmse:0.36018
# [116]	validation_0-rmse:0.25303	validation_1-rmse:0.35989
# [117]	validation_0-rmse:0.25094	validation_1-rmse:0.35751
# [118]	validation_0-rmse:0.24982	validation_1-rmse:0.35678
# [119]	validation_0-rmse:0.24882	validation_1-rmse:0.35677
# [120]	validation_0-rmse:0.24754	validation_1-rmse:0.35595
# [121]	validation_0-rmse:0.24514	validation_1-rmse:0.35602
# [122]	validation_0-rmse:0.24380	validation_1-rmse:0.35478
# [123]	validation_0-rmse:0.24279	validation_1-rmse:0.35595
# [124]	validation_0-rmse:0.24156	validation_1-rmse:0.35529
# [125]	validation_0-rmse:0.24146	validation_1-rmse:0.35530
# [126]	validation_0-rmse:0.24028	validation_1-rmse:0.35313
# [127]	validation_0-rmse:0.23892	validation_1-rmse:0.35078
# [128]	validation_0-rmse:0.23833	validation_1-rmse:0.35052
# [129]	validation_0-rmse:0.23760	validation_1-rmse:0.34992
# [130]	validation_0-rmse:0.23669	validation_1-rmse:0.34943
# [131]	validation_0-rmse:0.23573	validation_1-rmse:0.34726
# [132]	validation_0-rmse:0.23387	validation_1-rmse:0.34848
# [133]	validation_0-rmse:0.23315	validation_1-rmse:0.34830
# [134]	validation_0-rmse:0.23231	validation_1-rmse:0.34779
# [135]	validation_0-rmse:0.23151	validation_1-rmse:0.34690
# [136]	validation_0-rmse:0.23074	validation_1-rmse:0.34582
# [137]	validation_0-rmse:0.23010	validation_1-rmse:0.34512
# [138]	validation_0-rmse:0.22843	validation_1-rmse:0.34618
# [139]	validation_0-rmse:0.22769	validation_1-rmse:0.34496
# [140]	validation_0-rmse:0.22593	validation_1-rmse:0.34592
# [141]	validation_0-rmse:0.22601	validation_1-rmse:0.34785
# [142]	validation_0-rmse:0.22465	validation_1-rmse:0.34892
# [143]	validation_0-rmse:0.22407	validation_1-rmse:0.34814
# [144]	validation_0-rmse:0.22266	validation_1-rmse:0.34600
# [145]	validation_0-rmse:0.22220	validation_1-rmse:0.34679
# [146]	validation_0-rmse:0.22146	validation_1-rmse:0.34638
# [147]	validation_0-rmse:0.22139	validation_1-rmse:0.34644
# [148]	validation_0-rmse:0.21964	validation_1-rmse:0.34636
# [149]	validation_0-rmse:0.21958	validation_1-rmse:0.34641
# [150]	validation_0-rmse:0.21819	validation_1-rmse:0.34778
# [151]	validation_0-rmse:0.21811	validation_1-rmse:0.34884
# [152]	validation_0-rmse:0.21671	validation_1-rmse:0.34672
# [153]	validation_0-rmse:0.21668	validation_1-rmse:0.34674
# [154]	validation_0-rmse:0.21662	validation_1-rmse:0.34678
# [155]	validation_0-rmse:0.21618	validation_1-rmse:0.34665
# [156]	validation_0-rmse:0.21586	validation_1-rmse:0.34715
# [157]	validation_0-rmse:0.21452	validation_1-rmse:0.34536
# [158]	validation_0-rmse:0.21332	validation_1-rmse:0.34656
# [159]	validation_0-rmse:0.21277	validation_1-rmse:0.34565
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.77833	validation_1-rmse:1.70579
# [1]	validation_0-rmse:1.73143	validation_1-rmse:1.65677
# [2]	validation_0-rmse:1.68561	validation_1-rmse:1.61048
# [3]	validation_0-rmse:1.64137	validation_1-rmse:1.56632
# [4]	validation_0-rmse:1.60308	validation_1-rmse:1.52773
# [5]	validation_0-rmse:1.55845	validation_1-rmse:1.48199
# [6]	validation_0-rmse:1.51772	validation_1-rmse:1.43985
# [7]	validation_0-rmse:1.47826	validation_1-rmse:1.40127
# [8]	validation_0-rmse:1.44096	validation_1-rmse:1.36355
# [9]	validation_0-rmse:1.40531	validation_1-rmse:1.32771
# [10]	validation_0-rmse:1.37021	validation_1-rmse:1.29347
# [11]	validation_0-rmse:1.34009	validation_1-rmse:1.26302
# [12]	validation_0-rmse:1.30644	validation_1-rmse:1.22850
# [13]	validation_0-rmse:1.27607	validation_1-rmse:1.19776
# [14]	validation_0-rmse:1.24268	validation_1-rmse:1.16394
# [15]	validation_0-rmse:1.21401	validation_1-rmse:1.13554
# [16]	validation_0-rmse:1.18416	validation_1-rmse:1.10630
# [17]	validation_0-rmse:1.15409	validation_1-rmse:1.07586
# [18]	validation_0-rmse:1.12512	validation_1-rmse:1.04716
# [19]	validation_0-rmse:1.09935	validation_1-rmse:1.02127
# [20]	validation_0-rmse:1.07123	validation_1-rmse:0.99285
# [21]	validation_0-rmse:1.04321	validation_1-rmse:0.96502
# [22]	validation_0-rmse:1.01788	validation_1-rmse:0.94089
# [23]	validation_0-rmse:0.99362	validation_1-rmse:0.91675
# [24]	validation_0-rmse:0.97102	validation_1-rmse:0.89446
# [25]	validation_0-rmse:0.94747	validation_1-rmse:0.87302
# [26]	validation_0-rmse:0.92501	validation_1-rmse:0.85010
# [27]	validation_0-rmse:0.90525	validation_1-rmse:0.83144
# [28]	validation_0-rmse:0.88547	validation_1-rmse:0.81171
# [29]	validation_0-rmse:0.86532	validation_1-rmse:0.79205
# [30]	validation_0-rmse:0.84974	validation_1-rmse:0.77655
# [31]	validation_0-rmse:0.82971	validation_1-rmse:0.75679
# [32]	validation_0-rmse:0.80940	validation_1-rmse:0.73507
# [33]	validation_0-rmse:0.79216	validation_1-rmse:0.71777
# [34]	validation_0-rmse:0.77447	validation_1-rmse:0.70055
# [35]	validation_0-rmse:0.75680	validation_1-rmse:0.68296
# [36]	validation_0-rmse:0.74010	validation_1-rmse:0.66659
# [37]	validation_0-rmse:0.72318	validation_1-rmse:0.65279
# [38]	validation_0-rmse:0.70803	validation_1-rmse:0.63831
# [39]	validation_0-rmse:0.69222	validation_1-rmse:0.62285
# [40]	validation_0-rmse:0.67713	validation_1-rmse:0.60801
# [41]	validation_0-rmse:0.66288	validation_1-rmse:0.59374
# [42]	validation_0-rmse:0.64776	validation_1-rmse:0.57909
# [43]	validation_0-rmse:0.63517	validation_1-rmse:0.56605
# [44]	validation_0-rmse:0.62406	validation_1-rmse:0.55566
# [45]	validation_0-rmse:0.61258	validation_1-rmse:0.54397
# [46]	validation_0-rmse:0.59982	validation_1-rmse:0.53129
# [47]	validation_0-rmse:0.58895	validation_1-rmse:0.52083
# [48]	validation_0-rmse:0.57874	validation_1-rmse:0.51078
# [49]	validation_0-rmse:0.56709	validation_1-rmse:0.49955
# [50]	validation_0-rmse:0.55962	validation_1-rmse:0.49328
# [51]	validation_0-rmse:0.54847	validation_1-rmse:0.48266
# [52]	validation_0-rmse:0.53926	validation_1-rmse:0.47398
# [53]	validation_0-rmse:0.52839	validation_1-rmse:0.46472
# [54]	validation_0-rmse:0.51796	validation_1-rmse:0.45527
# [55]	validation_0-rmse:0.50739	validation_1-rmse:0.44561
# [56]	validation_0-rmse:0.49731	validation_1-rmse:0.43584
# [57]	validation_0-rmse:0.48929	validation_1-rmse:0.42800
# [58]	validation_0-rmse:0.48035	validation_1-rmse:0.41996
# [59]	validation_0-rmse:0.47159	validation_1-rmse:0.41259
# [60]	validation_0-rmse:0.46216	validation_1-rmse:0.40348
# [61]	validation_0-rmse:0.45688	validation_1-rmse:0.39852
# [62]	validation_0-rmse:0.44905	validation_1-rmse:0.39076
# [63]	validation_0-rmse:0.44169	validation_1-rmse:0.38432
# [64]	validation_0-rmse:0.43331	validation_1-rmse:0.37697
# [65]	validation_0-rmse:0.42747	validation_1-rmse:0.37068
# [66]	validation_0-rmse:0.42094	validation_1-rmse:0.36437
# [67]	validation_0-rmse:0.41324	validation_1-rmse:0.35891
# [68]	validation_0-rmse:0.40709	validation_1-rmse:0.35166
# [69]	validation_0-rmse:0.40074	validation_1-rmse:0.34615
# [70]	validation_0-rmse:0.39469	validation_1-rmse:0.34236
# [71]	validation_0-rmse:0.38935	validation_1-rmse:0.33776
# [72]	validation_0-rmse:0.38349	validation_1-rmse:0.33457
# [73]	validation_0-rmse:0.37641	validation_1-rmse:0.32976
# [74]	validation_0-rmse:0.37231	validation_1-rmse:0.32577
# [75]	validation_0-rmse:0.36886	validation_1-rmse:0.32130
# [76]	validation_0-rmse:0.36386	validation_1-rmse:0.31877
# [77]	validation_0-rmse:0.35997	validation_1-rmse:0.31530
# [78]	validation_0-rmse:0.35478	validation_1-rmse:0.31160
# [79]	validation_0-rmse:0.35083	validation_1-rmse:0.30855
# [80]	validation_0-rmse:0.34629	validation_1-rmse:0.30609
# [81]	validation_0-rmse:0.34239	validation_1-rmse:0.30344
# [82]	validation_0-rmse:0.33741	validation_1-rmse:0.30133
# [83]	validation_0-rmse:0.33476	validation_1-rmse:0.29965
# [84]	validation_0-rmse:0.33173	validation_1-rmse:0.29625
# [85]	validation_0-rmse:0.32980	validation_1-rmse:0.29483
# [86]	validation_0-rmse:0.32563	validation_1-rmse:0.29081
# [87]	validation_0-rmse:0.32260	validation_1-rmse:0.28939
# [88]	validation_0-rmse:0.31896	validation_1-rmse:0.28572
# [89]	validation_0-rmse:0.31532	validation_1-rmse:0.28353
# [90]	validation_0-rmse:0.31358	validation_1-rmse:0.28457
# [91]	validation_0-rmse:0.30989	validation_1-rmse:0.28094
# [92]	validation_0-rmse:0.30635	validation_1-rmse:0.27764
# [93]	validation_0-rmse:0.30446	validation_1-rmse:0.27754
# [94]	validation_0-rmse:0.30141	validation_1-rmse:0.27439
# [95]	validation_0-rmse:0.29921	validation_1-rmse:0.27460
# [96]	validation_0-rmse:0.29728	validation_1-rmse:0.27410
# [97]	validation_0-rmse:0.29482	validation_1-rmse:0.27036
# [98]	validation_0-rmse:0.29174	validation_1-rmse:0.26808
# [99]	validation_0-rmse:0.28906	validation_1-rmse:0.26657
# [100]	validation_0-rmse:0.28722	validation_1-rmse:0.26578
# [101]	validation_0-rmse:0.28520	validation_1-rmse:0.26423
# [102]	validation_0-rmse:0.28360	validation_1-rmse:0.26332
# [103]	validation_0-rmse:0.28171	validation_1-rmse:0.26154
# [104]	validation_0-rmse:0.27913	validation_1-rmse:0.25936
# [105]	validation_0-rmse:0.27656	validation_1-rmse:0.25778
# [106]	validation_0-rmse:0.27407	validation_1-rmse:0.25630
# [107]	validation_0-rmse:0.27261	validation_1-rmse:0.25451
# [108]	validation_0-rmse:0.27021	validation_1-rmse:0.25314
# [109]	validation_0-rmse:0.26807	validation_1-rmse:0.25385
# [110]	validation_0-rmse:0.26698	validation_1-rmse:0.25428
# [111]	validation_0-rmse:0.26543	validation_1-rmse:0.25404
# [112]	validation_0-rmse:0.26377	validation_1-rmse:0.25358
# [113]	validation_0-rmse:0.26180	validation_1-rmse:0.25358
# [114]	validation_0-rmse:0.25908	validation_1-rmse:0.25372
# [115]	validation_0-rmse:0.25745	validation_1-rmse:0.25313
# [116]	validation_0-rmse:0.25566	validation_1-rmse:0.25371
# [117]	validation_0-rmse:0.25442	validation_1-rmse:0.25422
# [118]	validation_0-rmse:0.25258	validation_1-rmse:0.25153
# [119]	validation_0-rmse:0.25082	validation_1-rmse:0.25112
# [120]	validation_0-rmse:0.24931	validation_1-rmse:0.25091
# [121]	validation_0-rmse:0.24769	validation_1-rmse:0.25153
# [122]	validation_0-rmse:0.24662	validation_1-rmse:0.25269
# [123]	validation_0-rmse:0.24590	validation_1-rmse:0.25278
# [124]	validation_0-rmse:0.24413	validation_1-rmse:0.25349
# [125]	validation_0-rmse:0.24407	validation_1-rmse:0.25358
# [126]	validation_0-rmse:0.24372	validation_1-rmse:0.25417
# [127]	validation_0-rmse:0.24249	validation_1-rmse:0.25388
# [128]	validation_0-rmse:0.24201	validation_1-rmse:0.25481
# [129]	validation_0-rmse:0.24107	validation_1-rmse:0.25472
# [130]	validation_0-rmse:0.23998	validation_1-rmse:0.25536
# [131]	validation_0-rmse:0.23934	validation_1-rmse:0.25433
# [132]	validation_0-rmse:0.23771	validation_1-rmse:0.25302
# [133]	validation_0-rmse:0.23658	validation_1-rmse:0.25281
# [134]	validation_0-rmse:0.23532	validation_1-rmse:0.25160
# [135]	validation_0-rmse:0.23447	validation_1-rmse:0.25196
# [136]	validation_0-rmse:0.23365	validation_1-rmse:0.25180
# [137]	validation_0-rmse:0.23184	validation_1-rmse:0.25114
# [138]	validation_0-rmse:0.23055	validation_1-rmse:0.24977
# [139]	validation_0-rmse:0.23056	validation_1-rmse:0.24974
# [140]	validation_0-rmse:0.23010	validation_1-rmse:0.24923
# [141]	validation_0-rmse:0.22906	validation_1-rmse:0.25044
# [142]	validation_0-rmse:0.22868	validation_1-rmse:0.24975
# [143]	validation_0-rmse:0.22876	validation_1-rmse:0.24954
# [144]	validation_0-rmse:0.22833	validation_1-rmse:0.24869
# [145]	validation_0-rmse:0.22810	validation_1-rmse:0.24658
# [146]	validation_0-rmse:0.22767	validation_1-rmse:0.24563
# [147]	validation_0-rmse:0.22707	validation_1-rmse:0.24505
# [148]	validation_0-rmse:0.22654	validation_1-rmse:0.24406
# [149]	validation_0-rmse:0.22618	validation_1-rmse:0.24370
# [150]	validation_0-rmse:0.22500	validation_1-rmse:0.24377
# [151]	validation_0-rmse:0.22439	validation_1-rmse:0.24457
# [152]	validation_0-rmse:0.22389	validation_1-rmse:0.24506
# [153]	validation_0-rmse:0.22284	validation_1-rmse:0.24352
# [154]	validation_0-rmse:0.22222	validation_1-rmse:0.24320
# [155]	validation_0-rmse:0.22186	validation_1-rmse:0.24268
# [156]	validation_0-rmse:0.22134	validation_1-rmse:0.24299
# [157]	validation_0-rmse:0.22002	validation_1-rmse:0.24214
# [158]	validation_0-rmse:0.21976	validation_1-rmse:0.24330
# [159]	validation_0-rmse:0.22003	validation_1-rmse:0.24330
# [160]	validation_0-rmse:0.21966	validation_1-rmse:0.24263
# [161]	validation_0-rmse:0.21875	validation_1-rmse:0.24217
# [162]	validation_0-rmse:0.21831	validation_1-rmse:0.24195
# [163]	validation_0-rmse:0.21710	validation_1-rmse:0.24156
# [164]	validation_0-rmse:0.21679	validation_1-rmse:0.24291
# [165]	validation_0-rmse:0.21644	validation_1-rmse:0.24204
# [166]	validation_0-rmse:0.21614	validation_1-rmse:0.24309
# [167]	validation_0-rmse:0.21523	validation_1-rmse:0.24353
# [168]	validation_0-rmse:0.21519	validation_1-rmse:0.24392
# [169]	validation_0-rmse:0.21513	validation_1-rmse:0.24453
# [170]	validation_0-rmse:0.21474	validation_1-rmse:0.24485
# [171]	validation_0-rmse:0.21487	validation_1-rmse:0.24435
# [172]	validation_0-rmse:0.21441	validation_1-rmse:0.24508
# [173]	validation_0-rmse:0.21385	validation_1-rmse:0.24451
# [174]	validation_0-rmse:0.21366	validation_1-rmse:0.24455
# [175]	validation_0-rmse:0.21279	validation_1-rmse:0.24443
# [176]	validation_0-rmse:0.21273	validation_1-rmse:0.24528
# [177]	validation_0-rmse:0.21258	validation_1-rmse:0.24452
# [178]	validation_0-rmse:0.21218	validation_1-rmse:0.24382
# [179]	validation_0-rmse:0.21200	validation_1-rmse:0.24302
# [180]	validation_0-rmse:0.21155	validation_1-rmse:0.24301
# [181]	validation_0-rmse:0.21103	validation_1-rmse:0.24355
# [182]	validation_0-rmse:0.21075	validation_1-rmse:0.24442
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-1.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.934
# Uncertainty
# a0: 0.160+/-0.051
# a1: 0.904+/-0.026

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: %_cover: mean - 0.198, median - 0.197, CI - [0.168-0.224]
#
# SHAP-values for: mf_chm_MAX: mean - 0.276, median - 0.278, CI - [0.251-0.304]
#
# SHAP-values for: mf_chm_MEAN: mean - 0.473, median - 0.472, CI - [0.447-0.5]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['mf_chm_MEAN', 'mf_chm_MAX', '%_cover'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 163.695, median: 171.0,
#  pred. interval (P(0.025)-P(0.975)): 106.0-188.0,
#  conf. interval (p-value=0.95): 139.393-185.449
# ***
# Aggregate bias statistic:
#  mean: -0.019, median: -0.026,
#  pred. interval (P(0.025)-P(0.975)): -0.139-0.136,
#  conf. interval (p-value=0.95): -0.077-0.042
# ***
# Aggregate RMSE statistic:
#  mean: 0.303, median: 0.294, pred. interval (P(0.025)-P(0.975)): 0.199-0.45,
#  conf. interval (p-value=0.95): 0.243-0.361
# ***
# Aggregate MSE statistic:
#  mean: 0.096, median: 0.087, pred. interval (P(0.025)-P(0.975)): 0.04-0.202,
#  conf. interval (p-value=0.95): 0.059-0.131
# ***
# Aggregate R^2 statistic:
#  mean: 0.927, median: 0.927, pred. interval (P(0.025)-P(0.975)): 0.871-0.976,
#  conf. interval (p-value=0.95): 0.907-0.951
# ***
# Aggregate bias(%) statistic:
#  mean: -0.795, median: -1.363, pred. interval (P(0.025)-P(0.975)): -7.6-8.35,
#  conf. interval (p-value=0.95): -4.047-2.404
# ***
# Aggregate RMSE(%) statistic:
#  mean: 16.804, median: 15.609, pred. interval (P(0.025)-P(0.975)): 8.609-27.658,
#  conf. interval (p-value=0.95): 12.214-21.059
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -0.649, median: -0.649,
#  pred. interval (P(0.025)-P(0.975)): -1.602-0.35,
#  conf. interval (p-value=0.95): -1.058--0.237
# ***
# Aggregate RMSE statistic:
#  mean: 2.445, median: 2.317, pred. interval (P(0.025)-P(0.975)): 1.521-3.567,
#  conf. interval (p-value=0.95): 1.893-3.093
# ***
# Aggregate MSE statistic:
#  mean: 6.331, median: 5.37, pred. interval (P(0.025)-P(0.975)): 2.312-12.724,
#  conf. interval (p-value=0.95): 3.601-9.631
# ***
# Aggregate R^2 statistic:
#  mean: 0.869, median: 0.873, pred. interval (P(0.025)-P(0.975)): 0.763-0.947,
#  conf. interval (p-value=0.95): 0.828-0.912
# ***
# Aggregate bias(%) statistic:
#  mean: -6.154, median: -6.638, pred. interval (P(0.025)-P(0.975)): -14.391-3.592,
#  conf. interval (p-value=0.95): -10.18--2.451
# ***
# Aggregate RMSE(%) statistic:
#  mean: 24.256, median: 23.488, pred. interval (P(0.025)-P(0.975)): 16.249-33.96,
#  conf. interval (p-value=0.95): 19.832-28.81
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-1, 0, 1, 2, 3])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 1, 5, 10, 20, 30])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.76553
# [1]	validation_0-rmse:1.72066
# [2]	validation_0-rmse:1.67424
# [3]	validation_0-rmse:1.62878
# [4]	validation_0-rmse:1.58684
# [5]	validation_0-rmse:1.54590
# [6]	validation_0-rmse:1.50594
# [7]	validation_0-rmse:1.46747
# [8]	validation_0-rmse:1.43480
# [9]	validation_0-rmse:1.40110
# [10]	validation_0-rmse:1.36464
# [11]	validation_0-rmse:1.33070
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [12]	validation_0-rmse:1.29984
# [13]	validation_0-rmse:1.26823
# [14]	validation_0-rmse:1.23730
# [15]	validation_0-rmse:1.20535
# [16]	validation_0-rmse:1.17327
# [17]	validation_0-rmse:1.14692
# [18]	validation_0-rmse:1.11809
# [19]	validation_0-rmse:1.09057
# [20]	validation_0-rmse:1.06156
# [21]	validation_0-rmse:1.03948
# [22]	validation_0-rmse:1.01448
# [23]	validation_0-rmse:0.99060
# [24]	validation_0-rmse:0.96759
# [25]	validation_0-rmse:0.94438
# [26]	validation_0-rmse:0.92054
# [27]	validation_0-rmse:0.89856
# [28]	validation_0-rmse:0.87778
# [29]	validation_0-rmse:0.85624
# [30]	validation_0-rmse:0.83377
# [31]	validation_0-rmse:0.81332
# [32]	validation_0-rmse:0.79517
# [33]	validation_0-rmse:0.77736
# [34]	validation_0-rmse:0.75907
# [35]	validation_0-rmse:0.74276
# [36]	validation_0-rmse:0.72693
# [37]	validation_0-rmse:0.71160
# [38]	validation_0-rmse:0.69476
# [39]	validation_0-rmse:0.67839
# [40]	validation_0-rmse:0.66419
# [41]	validation_0-rmse:0.64820
# [42]	validation_0-rmse:0.63274
# [43]	validation_0-rmse:0.62043
# [44]	validation_0-rmse:0.60822
# [45]	validation_0-rmse:0.59612
# [46]	validation_0-rmse:0.58117
# [47]	validation_0-rmse:0.56865
# [48]	validation_0-rmse:0.55689
# [49]	validation_0-rmse:0.54498
# [50]	validation_0-rmse:0.53301
# [51]	validation_0-rmse:0.52427
# [52]	validation_0-rmse:0.51513
# [53]	validation_0-rmse:0.50476
# [54]	validation_0-rmse:0.49496
# [55]	validation_0-rmse:0.48421
# [56]	validation_0-rmse:0.47527
# [57]	validation_0-rmse:0.46672
# [58]	validation_0-rmse:0.45907
# [59]	validation_0-rmse:0.44984
# [60]	validation_0-rmse:0.44173
# [61]	validation_0-rmse:0.43400
# [62]	validation_0-rmse:0.42659
# [63]	validation_0-rmse:0.42019
# [64]	validation_0-rmse:0.41353
# [65]	validation_0-rmse:0.40656
# [66]	validation_0-rmse:0.40078
# [67]	validation_0-rmse:0.39495
# [68]	validation_0-rmse:0.38847
# [69]	validation_0-rmse:0.38512
# [70]	validation_0-rmse:0.38066
# [71]	validation_0-rmse:0.37417
# [72]	validation_0-rmse:0.36860
# [73]	validation_0-rmse:0.36179
# [74]	validation_0-rmse:0.35592
# [75]	validation_0-rmse:0.35170
# [76]	validation_0-rmse:0.34670
# [77]	validation_0-rmse:0.34218
# [78]	validation_0-rmse:0.33772
# [79]	validation_0-rmse:0.33456
# [80]	validation_0-rmse:0.33027
# [81]	validation_0-rmse:0.32581
# [82]	validation_0-rmse:0.32229
# [83]	validation_0-rmse:0.31800
# [84]	validation_0-rmse:0.31311
# [85]	validation_0-rmse:0.30957
# [86]	validation_0-rmse:0.30615
# [87]	validation_0-rmse:0.30373
# [88]	validation_0-rmse:0.30031
# [89]	validation_0-rmse:0.29745
# [90]	validation_0-rmse:0.29417
# [91]	validation_0-rmse:0.29166
# [92]	validation_0-rmse:0.28887
# [93]	validation_0-rmse:0.28620
# [94]	validation_0-rmse:0.28332
# [95]	validation_0-rmse:0.28012
# [96]	validation_0-rmse:0.27773
# [97]	validation_0-rmse:0.27535
# [98]	validation_0-rmse:0.27386
# [99]	validation_0-rmse:0.27213
# [100]	validation_0-rmse:0.27134
# [101]	validation_0-rmse:0.26916
# [102]	validation_0-rmse:0.26784
# [103]	validation_0-rmse:0.26555
# [104]	validation_0-rmse:0.26417
# [105]	validation_0-rmse:0.26286
# [106]	validation_0-rmse:0.26034
# [107]	validation_0-rmse:0.25893
# [108]	validation_0-rmse:0.25691
# [109]	validation_0-rmse:0.25568
# [110]	validation_0-rmse:0.25397
# [111]	validation_0-rmse:0.25341
# [112]	validation_0-rmse:0.25161
# [113]	validation_0-rmse:0.24995
# [114]	validation_0-rmse:0.24874
# [115]	validation_0-rmse:0.24749
# [116]	validation_0-rmse:0.24719
# [117]	validation_0-rmse:0.24516
# [118]	validation_0-rmse:0.24403
# [119]	validation_0-rmse:0.24306
# [120]	validation_0-rmse:0.24229
# [121]	validation_0-rmse:0.24072
# [122]	validation_0-rmse:0.24056
# [123]	validation_0-rmse:0.23992
# [124]	validation_0-rmse:0.23856
# [125]	validation_0-rmse:0.23685
# [126]	validation_0-rmse:0.23586
# [127]	validation_0-rmse:0.23441
# [128]	validation_0-rmse:0.23343
# [129]	validation_0-rmse:0.23249
# [130]	validation_0-rmse:0.23249
# [131]	validation_0-rmse:0.23189
# [132]	validation_0-rmse:0.23126
# [133]	validation_0-rmse:0.22997
# [134]	validation_0-rmse:0.22811
# [135]	validation_0-rmse:0.22759
# [136]	validation_0-rmse:0.22638
# [137]	validation_0-rmse:0.22609
# [138]	validation_0-rmse:0.22472
# [139]	validation_0-rmse:0.22371
# [140]	validation_0-rmse:0.22246
# [141]	validation_0-rmse:0.22203
# [142]	validation_0-rmse:0.22196
# [143]	validation_0-rmse:0.22086
# [144]	validation_0-rmse:0.22044
# [145]	validation_0-rmse:0.21943
# [146]	validation_0-rmse:0.21874
# [147]	validation_0-rmse:0.21863
# [148]	validation_0-rmse:0.21788
# [149]	validation_0-rmse:0.21776
# [150]	validation_0-rmse:0.21770
# [151]	validation_0-rmse:0.21695
# [152]	validation_0-rmse:0.21632
# [153]	validation_0-rmse:0.21580
# [154]	validation_0-rmse:0.21542
# [155]	validation_0-rmse:0.21542
# [156]	validation_0-rmse:0.21468
# [157]	validation_0-rmse:0.21330
# [158]	validation_0-rmse:0.21277
# [159]	validation_0-rmse:0.21201
# [160]	validation_0-rmse:0.21157
# [161]	validation_0-rmse:0.21097
# [162]	validation_0-rmse:0.21051
# [163]	validation_0-rmse:0.21021
# [164]	validation_0-rmse:0.20897
# [165]	validation_0-rmse:0.20897
# [166]	validation_0-rmse:0.20826
# [167]	validation_0-rmse:0.20826
# [168]	validation_0-rmse:0.20767
# [169]	validation_0-rmse:0.20758
# [170]	validation_0-rmse:0.20732
# [171]	validation_0-rmse:0.20611
# [172]	validation_0-rmse:0.20545
# [173]	validation_0-rmse:0.20505
# [174]	validation_0-rmse:0.20451
# [175]	validation_0-rmse:0.20423
# [176]	validation_0-rmse:0.20369
# [177]	validation_0-rmse:0.20320
# [178]	validation_0-rmse:0.20317
# [179]	validation_0-rmse:0.20296
# [180]	validation_0-rmse:0.20271
# [181]	validation_0-rmse:0.20201
# [182]	validation_0-rmse:0.20202
# [183]	validation_0-rmse:0.20175
# [184]	validation_0-rmse:0.20174
# [185]	validation_0-rmse:0.20142
# [186]	validation_0-rmse:0.20132
# [187]	validation_0-rmse:0.20103
# [188]	validation_0-rmse:0.20068
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 188

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.08
# RMSE: 0.2
# Relative RMSE(%):  10.771
# MSE: 0.0
# R square: 97.2%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-1.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.972
# Uncertainty
# a0: 0.101+/-0.035
# a1: 0.945+/-0.016

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/02_LN_Mstem_CHM_without_RGB_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/02_LN_Mstem_CHM_without_RGB_XGB_model.txt")
