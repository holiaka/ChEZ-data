# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../03_input_data/input_CHM_&_spectral_data_site2020.xlsx'
df = pd.read_excel(site_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0        4.771            1.792                -0.211            -0.261
# 1        5.808            2.496                -0.073             0.392
# 2        5.796            2.546                 0.030             0.501
# 3        5.826            2.643                 0.000             0.419
# 4        6.059            2.643                 0.122             0.647
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  \
# 0              -2.040          1.932     0.85    12.233545   19.097736    243
# 1              -0.139          2.674     1.00    14.964220   17.704655    248
# 2              -0.030          2.734     1.00    15.329449   17.559893    240
# 3              -0.431          2.785     0.97    15.392742   20.676994    244
# 4              -0.386          2.809     1.00    17.944009   21.851387    243
#
#    contr_g_MAX
# 0  2961.898193
# 1  2218.239746
# 2  2220.297119
# 3  3033.770752
# 4  3003.818848

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
#  9   g_MAX                 103 non-null    int64
#  10  contr_g_MAX           103 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 9.0 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Gs_cub_m", "ln_M_AG_kg_m2"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                  ln_Gs_cub_m                                             \
#                        count      mean       std    min      25%    50%
# Dominant_specias
# Alder                    4.0  5.907250  0.445830  5.342  5.65925  5.985
# Aspen                    1.0  4.956000       NaN  4.956  4.95600  4.956
# Birch                   23.0  4.676174  0.813911  2.398  4.56900  4.949
# Oak                      3.0  5.409667  0.406291  4.956  5.24450  5.533
# Pine                    71.0  4.990775  1.410734  1.609  4.44850  5.642
# Spruce                   1.0  6.431000       NaN  6.431  6.43100  6.431
#
#                                 ln_M_AG_kg_m2                             \
#                      75%    max         count      mean       std    min
# Dominant_specias
# Alder             6.2330  6.317           4.0  2.862250  0.386813  2.407
# Aspen             4.9560  4.956           1.0  1.932000       NaN  1.932
# Birch             5.2930  5.680          23.0  1.855783  0.744496  0.000
# Oak               5.6365  5.740           3.0  2.687333  0.316282  2.398
# Pine              5.9215  6.457          71.0  2.073789  1.174954 -0.693
# Spruce            6.4310  6.431           1.0  3.506000       NaN  3.506
#
#
#                       25%    50%     75%    max
# Dominant_specias
# Alder             2.61775  2.892  3.1365  3.258
# Aspen             1.93200  1.932  1.9320  1.932
# Birch             1.68350  2.001  2.3930  2.803
# Oak               2.51850  2.639  2.8320  3.025
# Pine              1.48500  2.588  2.8620  3.515
# Spruce            3.50600  3.506  3.5060  3.506

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000        103.000000
# mean      4.981961         1.863184             -0.327942         -0.063369
# std       1.264300         1.198731              0.866380          0.795365
# min       1.609000        -1.347000             -2.659000         -2.408000
# 25%       4.677000         1.584500             -0.554000         -0.386500
# 50%       5.342000         2.294000             -0.051000          0.182000
# 75%       5.875000         2.663000              0.207000          0.495000
# max       6.457000         3.428000              1.384000          1.756000
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX  \
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.015971       2.086126    0.808738    13.045021   17.907784
# std              0.799205       1.067542    0.276653     6.609366    7.523377
# min             -3.507000      -0.693000    0.090000     1.293138    2.733019
# 25%             -1.609000       1.758000    0.745000     8.206727   11.615798
# 50%             -0.844000       2.442000    0.960000    13.072916   18.269344
# 75%             -0.364000       2.809000    1.000000    17.432255   22.751595
# max              0.157000       3.515000    1.000000    28.916548   36.355442
#
#             g_MAX  contr_g_MAX
# count  103.000000   103.000000
# mean   240.572816  3008.938899
# std      9.358442   876.023529
# min    194.000000   815.342712
# 25%    236.500000  2464.687256
# 50%    243.000000  2994.793701
# 75%    247.000000  3464.970947
# max    253.000000  6230.940918

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_M_stem_kg_m2"
indep_variables = ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0          4.771            1.792                -0.211            -0.261
# 1          5.808            2.496                -0.073             0.392
# 2          5.796            2.546                 0.030             0.501
# 3          5.826            2.643                 0.000             0.419
# 4          6.059            2.643                 0.122             0.647
# ..           ...              ...                   ...               ...
# 98         5.389            2.366                 0.531             0.182
# 99         2.398           -0.186                -1.309            -1.966
# 100        1.792           -0.968                -2.120            -1.966
# 101        4.836            1.733                -0.386             0.732
# 102        2.944           -0.211                -1.966            -1.470
#
#      ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  \
# 0                -2.040          1.932     0.85    12.233545   19.097736
# 1                -0.139          2.674     1.00    14.964220   17.704655
# 2                -0.030          2.734     1.00    15.329449   17.559893
# 3                -0.431          2.785     0.97    15.392742   20.676994
# 4                -0.386          2.809     1.00    17.944009   21.851387
# ..                  ...            ...      ...          ...         ...
# 98               -1.386          2.493     0.84    11.654902   17.083910
# 99               -3.507          0.000     0.17     4.722706   10.924606
# 100              -2.408         -0.511     0.17     4.620455   10.747827
# 101              -0.041          2.163     0.88     7.371921   11.443830
# 102              -1.609          0.182     0.28     2.765120    8.069081
#
#      g_MAX  contr_g_MAX
# 0      243  2961.898193
# 1      248  2218.239746
# 2      240  2220.297119
# 3      244  3033.770752
# 4      243  3003.818848
# ..     ...          ...
# 98     250  3469.805908
# 99     241  1748.447998
# 100    233  1708.681763
# 101    241  3066.087402
# 102    227  2756.989014
#
# [103 rows x 11 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  contr_g_MAX
# 0     0.85    12.233545   19.097736    243  2961.898193
# 1     1.00    14.964220   17.704655    248  2218.239746
# 2     1.00    15.329449   17.559893    240  2220.297119
# 3     0.97    15.392742   20.676994    244  3033.770752
# 4     1.00    17.944009   21.851387    243  3003.818848

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_stem_kg_m2
# 0            1.792
# 1            2.496
# 2            2.546
# 3            2.643
# 4            2.643

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.8738261907263865, 0.9273316113916492, 0.9072561006447565]
#     Mean: 0.903
#     Std: 0.022
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.31213016 0.25048043 0.42164637]
#     Mean: 0.328
#     Std: 0.071
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.25137399346125977, 0.31679685848863687, 0.189406475750839]
#     Mean: 0.253
#     Std: 0.052
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.0.80110549223012                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.04458503693712479                 # gamma
print('Gamma: ' + str(p2))

p3 = 0.16079094589246523                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 4            # max_depth
print('Max_depth: ' + str(p4))

p5 = 90          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.8298291034528749                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.8565852435738817
# Gamma: 0.12940676640076693
# Learning_rate: 0.029546354081746842
# Max_depth: 3
# N_estimators: 189
# Subsample: 0.3060599314998912

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.76033	validation_1-rmse:1.77802
# [1]	validation_0-rmse:1.71218	validation_1-rmse:1.73712
# [2]	validation_0-rmse:1.66553	validation_1-rmse:1.69488
# [3]	validation_0-rmse:1.62172	validation_1-rmse:1.65811
# [4]	validation_0-rmse:1.58127	validation_1-rmse:1.62183
# [5]	validation_0-rmse:1.54203	validation_1-rmse:1.58744
# [6]	validation_0-rmse:1.50683	validation_1-rmse:1.55909
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:1.46592	validation_1-rmse:1.52636
# [8]	validation_0-rmse:1.42634	validation_1-rmse:1.49205
# [9]	validation_0-rmse:1.39422	validation_1-rmse:1.47100
# [10]	validation_0-rmse:1.35858	validation_1-rmse:1.44436
# [11]	validation_0-rmse:1.32628	validation_1-rmse:1.41702
# [12]	validation_0-rmse:1.28935	validation_1-rmse:1.38607
# [13]	validation_0-rmse:1.25442	validation_1-rmse:1.35868
# [14]	validation_0-rmse:1.22385	validation_1-rmse:1.33041
# [15]	validation_0-rmse:1.19383	validation_1-rmse:1.30372
# [16]	validation_0-rmse:1.16202	validation_1-rmse:1.27559
# [17]	validation_0-rmse:1.13105	validation_1-rmse:1.24974
# [18]	validation_0-rmse:1.10470	validation_1-rmse:1.22951
# [19]	validation_0-rmse:1.07499	validation_1-rmse:1.20575
# [20]	validation_0-rmse:1.04669	validation_1-rmse:1.18187
# [21]	validation_0-rmse:1.02283	validation_1-rmse:1.16356
# [22]	validation_0-rmse:0.99838	validation_1-rmse:1.14278
# [23]	validation_0-rmse:0.97052	validation_1-rmse:1.12012
# [24]	validation_0-rmse:0.94606	validation_1-rmse:1.10304
# [25]	validation_0-rmse:0.92188	validation_1-rmse:1.08198
# [26]	validation_0-rmse:0.89994	validation_1-rmse:1.06523
# [27]	validation_0-rmse:0.87861	validation_1-rmse:1.04940
# [28]	validation_0-rmse:0.85918	validation_1-rmse:1.03514
# [29]	validation_0-rmse:0.83706	validation_1-rmse:1.01947
# [30]	validation_0-rmse:0.81561	validation_1-rmse:1.00390
# [31]	validation_0-rmse:0.79843	validation_1-rmse:0.99126
# [32]	validation_0-rmse:0.77969	validation_1-rmse:0.97696
# [33]	validation_0-rmse:0.76169	validation_1-rmse:0.96547
# [34]	validation_0-rmse:0.74546	validation_1-rmse:0.95598
# [35]	validation_0-rmse:0.72820	validation_1-rmse:0.94331
# [36]	validation_0-rmse:0.71027	validation_1-rmse:0.92804
# [37]	validation_0-rmse:0.69328	validation_1-rmse:0.91249
# [38]	validation_0-rmse:0.67807	validation_1-rmse:0.89978
# [39]	validation_0-rmse:0.66257	validation_1-rmse:0.88821
# [40]	validation_0-rmse:0.64782	validation_1-rmse:0.87808
# [41]	validation_0-rmse:0.63362	validation_1-rmse:0.87095
# [42]	validation_0-rmse:0.61970	validation_1-rmse:0.85851
# [43]	validation_0-rmse:0.60557	validation_1-rmse:0.84537
# [44]	validation_0-rmse:0.59240	validation_1-rmse:0.83372
# [45]	validation_0-rmse:0.57818	validation_1-rmse:0.82246
# [46]	validation_0-rmse:0.56399	validation_1-rmse:0.81199
# [47]	validation_0-rmse:0.55355	validation_1-rmse:0.80581
# [48]	validation_0-rmse:0.53981	validation_1-rmse:0.79643
# [49]	validation_0-rmse:0.52870	validation_1-rmse:0.78778
# [50]	validation_0-rmse:0.51894	validation_1-rmse:0.77893
# [51]	validation_0-rmse:0.50777	validation_1-rmse:0.76927
# [52]	validation_0-rmse:0.49617	validation_1-rmse:0.76208
# [53]	validation_0-rmse:0.48619	validation_1-rmse:0.75652
# [54]	validation_0-rmse:0.47807	validation_1-rmse:0.75045
# [55]	validation_0-rmse:0.47033	validation_1-rmse:0.74559
# [56]	validation_0-rmse:0.46012	validation_1-rmse:0.73572
# [57]	validation_0-rmse:0.45179	validation_1-rmse:0.72979
# [58]	validation_0-rmse:0.44132	validation_1-rmse:0.72081
# [59]	validation_0-rmse:0.43268	validation_1-rmse:0.71464
# [60]	validation_0-rmse:0.42524	validation_1-rmse:0.70956
# [61]	validation_0-rmse:0.41889	validation_1-rmse:0.70104
# [62]	validation_0-rmse:0.40996	validation_1-rmse:0.69283
# [63]	validation_0-rmse:0.40240	validation_1-rmse:0.68664
# [64]	validation_0-rmse:0.39518	validation_1-rmse:0.68234
# [65]	validation_0-rmse:0.38794	validation_1-rmse:0.67567
# [66]	validation_0-rmse:0.38210	validation_1-rmse:0.66983
# [67]	validation_0-rmse:0.37686	validation_1-rmse:0.66716
# [68]	validation_0-rmse:0.36905	validation_1-rmse:0.66270
# [69]	validation_0-rmse:0.36427	validation_1-rmse:0.65792
# [70]	validation_0-rmse:0.35897	validation_1-rmse:0.65080
# [71]	validation_0-rmse:0.35382	validation_1-rmse:0.64723
# [72]	validation_0-rmse:0.34819	validation_1-rmse:0.64360
# [73]	validation_0-rmse:0.34411	validation_1-rmse:0.64260
# [74]	validation_0-rmse:0.33867	validation_1-rmse:0.63697
# [75]	validation_0-rmse:0.33496	validation_1-rmse:0.63607
# [76]	validation_0-rmse:0.33045	validation_1-rmse:0.63120
# [77]	validation_0-rmse:0.32560	validation_1-rmse:0.62847
# [78]	validation_0-rmse:0.31931	validation_1-rmse:0.62042
# [79]	validation_0-rmse:0.31501	validation_1-rmse:0.61659
# [80]	validation_0-rmse:0.30961	validation_1-rmse:0.61185
# [81]	validation_0-rmse:0.30505	validation_1-rmse:0.60979
# [82]	validation_0-rmse:0.30239	validation_1-rmse:0.60773
# [83]	validation_0-rmse:0.29767	validation_1-rmse:0.60208
# [84]	validation_0-rmse:0.29441	validation_1-rmse:0.59908
# [85]	validation_0-rmse:0.28985	validation_1-rmse:0.59575
# [86]	validation_0-rmse:0.28534	validation_1-rmse:0.59151
# [87]	validation_0-rmse:0.28219	validation_1-rmse:0.58871
# [88]	validation_0-rmse:0.27968	validation_1-rmse:0.58700
# [89]	validation_0-rmse:0.27550	validation_1-rmse:0.58216
# [90]	validation_0-rmse:0.27309	validation_1-rmse:0.58124
# [91]	validation_0-rmse:0.26863	validation_1-rmse:0.57638
# [92]	validation_0-rmse:0.26586	validation_1-rmse:0.57412
# [93]	validation_0-rmse:0.26298	validation_1-rmse:0.57236
# [94]	validation_0-rmse:0.26074	validation_1-rmse:0.56929
# [95]	validation_0-rmse:0.25934	validation_1-rmse:0.56874
# [96]	validation_0-rmse:0.25670	validation_1-rmse:0.56569
# [97]	validation_0-rmse:0.25329	validation_1-rmse:0.56278
# [98]	validation_0-rmse:0.25046	validation_1-rmse:0.56066
# [99]	validation_0-rmse:0.24797	validation_1-rmse:0.56005
# [100]	validation_0-rmse:0.24554	validation_1-rmse:0.55938
# [101]	validation_0-rmse:0.24276	validation_1-rmse:0.55685
# [102]	validation_0-rmse:0.24089	validation_1-rmse:0.55610
# [103]	validation_0-rmse:0.23740	validation_1-rmse:0.55270
# [104]	validation_0-rmse:0.23584	validation_1-rmse:0.55300
# [105]	validation_0-rmse:0.23406	validation_1-rmse:0.55237
# [106]	validation_0-rmse:0.23295	validation_1-rmse:0.55335
# [107]	validation_0-rmse:0.23136	validation_1-rmse:0.55224
# [108]	validation_0-rmse:0.22985	validation_1-rmse:0.55053
# [109]	validation_0-rmse:0.22848	validation_1-rmse:0.55034
# [110]	validation_0-rmse:0.22703	validation_1-rmse:0.54925
# [111]	validation_0-rmse:0.22588	validation_1-rmse:0.54861
# [112]	validation_0-rmse:0.22382	validation_1-rmse:0.54380
# [113]	validation_0-rmse:0.22174	validation_1-rmse:0.54116
# [114]	validation_0-rmse:0.22080	validation_1-rmse:0.54124
# [115]	validation_0-rmse:0.21992	validation_1-rmse:0.54038
# [116]	validation_0-rmse:0.21785	validation_1-rmse:0.53822
# [117]	validation_0-rmse:0.21611	validation_1-rmse:0.53778
# [118]	validation_0-rmse:0.21471	validation_1-rmse:0.53685
# [119]	validation_0-rmse:0.21369	validation_1-rmse:0.53523
# [120]	validation_0-rmse:0.21211	validation_1-rmse:0.53407
# [121]	validation_0-rmse:0.21128	validation_1-rmse:0.53251
# [122]	validation_0-rmse:0.20930	validation_1-rmse:0.53062
# [158]	validation_0-rmse:0.20421	validation_1-rmse:0.31631
# [159]	validation_0-rmse:0.20312	validation_1-rmse:0.31580
# [160]	validation_0-rmse:0.20305	validation_1-rmse:0.31595
# [161]	validation_0-rmse:0.20241	validation_1-rmse:0.31541
# [162]	validation_0-rmse:0.20162	validation_1-rmse:0.31463
# [163]	validation_0-rmse:0.20159	validation_1-rmse:0.31471
# [164]	validation_0-rmse:0.20049	validation_1-rmse:0.31476
# [165]	validation_0-rmse:0.20055	validation_1-rmse:0.31532
# [166]	validation_0-rmse:0.20020	validation_1-rmse:0.31613
# [167]	validation_0-rmse:0.20013	validation_1-rmse:0.31634
# [168]	validation_0-rmse:0.19979	validation_1-rmse:0.31602
# [169]	validation_0-rmse:0.19977	validation_1-rmse:0.31607
# [170]	validation_0-rmse:0.19930	validation_1-rmse:0.31488
# [171]	validation_0-rmse:0.19921	validation_1-rmse:0.31530
# [172]	validation_0-rmse:0.19874	validation_1-rmse:0.31440
# [173]	validation_0-rmse:0.19830	validation_1-rmse:0.31338
# [174]	validation_0-rmse:0.19810	validation_1-rmse:0.31338
# [175]	validation_0-rmse:0.19762	validation_1-rmse:0.31210
# [176]	validation_0-rmse:0.19586	validation_1-rmse:0.31020
# [177]	validation_0-rmse:0.19503	validation_1-rmse:0.30657
# [178]	validation_0-rmse:0.19453	validation_1-rmse:0.30611
# [179]	validation_0-rmse:0.19453	validation_1-rmse:0.30604
# [180]	validation_0-rmse:0.19396	validation_1-rmse:0.30460
# [181]	validation_0-rmse:0.19329	validation_1-rmse:0.30382
# [182]	validation_0-rmse:0.19329	validation_1-rmse:0.30431
# [183]	validation_0-rmse:0.19276	validation_1-rmse:0.30392
# [184]	validation_0-rmse:0.19212	validation_1-rmse:0.30323
# [185]	validation_0-rmse:0.19159	validation_1-rmse:0.30291
# [186]	validation_0-rmse:0.19132	validation_1-rmse:0.30229
# [187]	validation_0-rmse:0.19131	validation_1-rmse:0.30243
# [188]	validation_0-rmse:0.19137	validation_1-rmse:0.30216
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.76816	validation_1-rmse:1.75191
# [1]	validation_0-rmse:1.72224	validation_1-rmse:1.70341
# [2]	validation_0-rmse:1.67905	validation_1-rmse:1.65850
# [3]	validation_0-rmse:1.63568	validation_1-rmse:1.61473
# [4]	validation_0-rmse:1.59688	validation_1-rmse:1.57416
# [5]	validation_0-rmse:1.55683	validation_1-rmse:1.53501
# [6]	validation_0-rmse:1.51817	validation_1-rmse:1.49697
# [7]	validation_0-rmse:1.48045	validation_1-rmse:1.45909
# [8]	validation_0-rmse:1.44315	validation_1-rmse:1.42057
# [9]	validation_0-rmse:1.40591	validation_1-rmse:1.38287
# [10]	validation_0-rmse:1.36870	validation_1-rmse:1.34635
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:1.33583	validation_1-rmse:1.31179
# [12]	validation_0-rmse:1.30183	validation_1-rmse:1.27473
# [13]	validation_0-rmse:1.26775	validation_1-rmse:1.24090
# [14]	validation_0-rmse:1.23608	validation_1-rmse:1.20913
# [15]	validation_0-rmse:1.20394	validation_1-rmse:1.17647
# [16]	validation_0-rmse:1.17386	validation_1-rmse:1.14424
# [17]	validation_0-rmse:1.14489	validation_1-rmse:1.11472
# [18]	validation_0-rmse:1.12064	validation_1-rmse:1.08880
# [19]	validation_0-rmse:1.09505	validation_1-rmse:1.06350
# [20]	validation_0-rmse:1.06979	validation_1-rmse:1.03756
# [21]	validation_0-rmse:1.04387	validation_1-rmse:1.00911
# [22]	validation_0-rmse:1.01838	validation_1-rmse:0.98336
# [23]	validation_0-rmse:0.99256	validation_1-rmse:0.95629
# [24]	validation_0-rmse:0.96882	validation_1-rmse:0.93043
# [25]	validation_0-rmse:0.94652	validation_1-rmse:0.90764
# [26]	validation_0-rmse:0.92453	validation_1-rmse:0.88640
# [27]	validation_0-rmse:0.90485	validation_1-rmse:0.86551
# [28]	validation_0-rmse:0.88653	validation_1-rmse:0.84702
# [29]	validation_0-rmse:0.86674	validation_1-rmse:0.82533
# [30]	validation_0-rmse:0.84998	validation_1-rmse:0.80841
# [31]	validation_0-rmse:0.82695	validation_1-rmse:0.78811
# [32]	validation_0-rmse:0.80957	validation_1-rmse:0.77047
# [33]	validation_0-rmse:0.79215	validation_1-rmse:0.75274
# [34]	validation_0-rmse:0.77693	validation_1-rmse:0.73722
# [35]	validation_0-rmse:0.75947	validation_1-rmse:0.71798
# [36]	validation_0-rmse:0.74234	validation_1-rmse:0.70022
# [37]	validation_0-rmse:0.72657	validation_1-rmse:0.68277
# [38]	validation_0-rmse:0.71061	validation_1-rmse:0.66540
# [39]	validation_0-rmse:0.69616	validation_1-rmse:0.65120
# [40]	validation_0-rmse:0.68150	validation_1-rmse:0.63524
# [41]	validation_0-rmse:0.66689	validation_1-rmse:0.62600
# [42]	validation_0-rmse:0.65278	validation_1-rmse:0.61184
# [43]	validation_0-rmse:0.63791	validation_1-rmse:0.59530
# [44]	validation_0-rmse:0.62433	validation_1-rmse:0.58212
# [45]	validation_0-rmse:0.61202	validation_1-rmse:0.56984
# [46]	validation_0-rmse:0.59975	validation_1-rmse:0.55931
# ...
# [12]	validation_0-rmse:1.31589	validation_1-rmse:1.27209
# [13]	validation_0-rmse:1.28157	validation_1-rmse:1.23870
# [14]	validation_0-rmse:1.25154	validation_1-rmse:1.21014
# [15]	validation_0-rmse:1.21772	validation_1-rmse:1.17946
# [16]	validation_0-rmse:1.18830	validation_1-rmse:1.15082
# [17]	validation_0-rmse:1.15904	validation_1-rmse:1.12393
# [18]	validation_0-rmse:1.13540	validation_1-rmse:1.10657
# [19]	validation_0-rmse:1.11078	validation_1-rmse:1.07921
# [20]	validation_0-rmse:1.08255	validation_1-rmse:1.05081
# [21]	validation_0-rmse:1.05517	validation_1-rmse:1.02581
# [22]	validation_0-rmse:1.03098	validation_1-rmse:1.00528
# [23]	validation_0-rmse:1.00646	validation_1-rmse:0.98097
# [24]	validation_0-rmse:0.98187	validation_1-rmse:0.95679
# [25]	validation_0-rmse:0.96017	validation_1-rmse:0.93685
# [26]	validation_0-rmse:0.94189	validation_1-rmse:0.91903
# [27]	validation_0-rmse:0.92136	validation_1-rmse:0.89890
# [28]	validation_0-rmse:0.89822	validation_1-rmse:0.87781
# [29]	validation_0-rmse:0.87766	validation_1-rmse:0.85909
# [30]	validation_0-rmse:0.85884	validation_1-rmse:0.83869
# [31]	validation_0-rmse:0.84067	validation_1-rmse:0.81986
# [32]	validation_0-rmse:0.82151	validation_1-rmse:0.80198
# [33]	validation_0-rmse:0.80236	validation_1-rmse:0.78515
# [34]	validation_0-rmse:0.78597	validation_1-rmse:0.76799
# [35]	validation_0-rmse:0.76742	validation_1-rmse:0.75120
# [36]	validation_0-rmse:0.75041	validation_1-rmse:0.73598
# [37]	validation_0-rmse:0.73323	validation_1-rmse:0.72106
# [38]	validation_0-rmse:0.71825	validation_1-rmse:0.70494
# [39]	validation_0-rmse:0.70273	validation_1-rmse:0.68959
# [40]	validation_0-rmse:0.69002	validation_1-rmse:0.67603
# [41]	validation_0-rmse:0.67680	validation_1-rmse:0.66355
# [42]	validation_0-rmse:0.66251	validation_1-rmse:0.64865
# [43]	validation_0-rmse:0.64881	validation_1-rmse:0.63567
# [44]	validation_0-rmse:0.63585	validation_1-rmse:0.62134
# [45]	validation_0-rmse:0.62322	validation_1-rmse:0.60936
# [46]	validation_0-rmse:0.61195	validation_1-rmse:0.59790
# [47]	validation_0-rmse:0.60397	validation_1-rmse:0.58973
# [48]	validation_0-rmse:0.59128	validation_1-rmse:0.57451
# [49]	validation_0-rmse:0.57845	validation_1-rmse:0.56263
# [50]	validation_0-rmse:0.56767	validation_1-rmse:0.55275
# [51]	validation_0-rmse:0.55863	validation_1-rmse:0.54421
# [52]	validation_0-rmse:0.54765	validation_1-rmse:0.53377
# [53]	validation_0-rmse:0.53792	validation_1-rmse:0.52421
# [54]	validation_0-rmse:0.52777	validation_1-rmse:0.51439
# [55]	validation_0-rmse:0.51781	validation_1-rmse:0.50385
# [56]	validation_0-rmse:0.50746	validation_1-rmse:0.49311
# [57]	validation_0-rmse:0.49782	validation_1-rmse:0.48329
# [58]	validation_0-rmse:0.48799	validation_1-rmse:0.47306
# [59]	validation_0-rmse:0.47873	validation_1-rmse:0.46845
# [60]	validation_0-rmse:0.47214	validation_1-rmse:0.46154
# [61]	validation_0-rmse:0.46333	validation_1-rmse:0.45148
# [62]	validation_0-rmse:0.45407	validation_1-rmse:0.44423
# [63]	validation_0-rmse:0.44760	validation_1-rmse:0.43696
# [64]	validation_0-rmse:0.43867	validation_1-rmse:0.42888
# [65]	validation_0-rmse:0.42979	validation_1-rmse:0.42504
# [66]	validation_0-rmse:0.42270	validation_1-rmse:0.41696
# [67]	validation_0-rmse:0.41601	validation_1-rmse:0.41156
# [68]	validation_0-rmse:0.40838	validation_1-rmse:0.40498
# [69]	validation_0-rmse:0.40273	validation_1-rmse:0.40051
# [70]	validation_0-rmse:0.39379	validation_1-rmse:0.39398
# [71]	validation_0-rmse:0.38770	validation_1-rmse:0.38951
# [72]	validation_0-rmse:0.38161	validation_1-rmse:0.38351
# [73]	validation_0-rmse:0.37524	validation_1-rmse:0.38176
# [74]	validation_0-rmse:0.36925	validation_1-rmse:0.37631
# [75]	validation_0-rmse:0.36424	validation_1-rmse:0.37044
# [76]	validation_0-rmse:0.36031	validation_1-rmse:0.36529
# [77]	validation_0-rmse:0.35617	validation_1-rmse:0.36027
# [78]	validation_0-rmse:0.35129	validation_1-rmse:0.35429
# [79]	validation_0-rmse:0.34726	validation_1-rmse:0.34924
# [80]	validation_0-rmse:0.34282	validation_1-rmse:0.34413
# [81]	validation_0-rmse:0.33884	validation_1-rmse:0.33997
# [82]	validation_0-rmse:0.33458	validation_1-rmse:0.33857
# [83]	validation_0-rmse:0.33142	validation_1-rmse:0.33624
# [84]	validation_0-rmse:0.32738	validation_1-rmse:0.33174
# [85]	validation_0-rmse:0.32451	validation_1-rmse:0.33049
# [86]	validation_0-rmse:0.32009	validation_1-rmse:0.32674
# [87]	validation_0-rmse:0.31722	validation_1-rmse:0.32339
# [88]	validation_0-rmse:0.31519	validation_1-rmse:0.32060
# [89]	validation_0-rmse:0.31084	validation_1-rmse:0.31568
# [90]	validation_0-rmse:0.30808	validation_1-rmse:0.31120
# [91]	validation_0-rmse:0.30474	validation_1-rmse:0.30985
# [92]	validation_0-rmse:0.30359	validation_1-rmse:0.30692
# [93]	validation_0-rmse:0.30180	validation_1-rmse:0.30425
# [94]	validation_0-rmse:0.30073	validation_1-rmse:0.30256
# [95]	validation_0-rmse:0.29951	validation_1-rmse:0.29916
# [96]	validation_0-rmse:0.29712	validation_1-rmse:0.30062
# [97]	validation_0-rmse:0.29349	validation_1-rmse:0.29661
# [98]	validation_0-rmse:0.28989	validation_1-rmse:0.29446
# [99]	validation_0-rmse:0.28779	validation_1-rmse:0.29181
# [100]	validation_0-rmse:0.28592	validation_1-rmse:0.29011
# [101]	validation_0-rmse:0.28322	validation_1-rmse:0.28931
# [102]	validation_0-rmse:0.28166	validation_1-rmse:0.28775
# [103]	validation_0-rmse:0.28033	validation_1-rmse:0.28558
# [104]	validation_0-rmse:0.27831	validation_1-rmse:0.28247
# [105]	validation_0-rmse:0.27722	validation_1-rmse:0.28084
# [106]	validation_0-rmse:0.27526	validation_1-rmse:0.28122
# [107]	validation_0-rmse:0.27486	validation_1-rmse:0.27887
# [108]	validation_0-rmse:0.27288	validation_1-rmse:0.27803
# [109]	validation_0-rmse:0.27055	validation_1-rmse:0.27558
# [110]	validation_0-rmse:0.26875	validation_1-rmse:0.27405
# [111]	validation_0-rmse:0.26660	validation_1-rmse:0.27212
# [112]	validation_0-rmse:0.26370	validation_1-rmse:0.27138
# [113]	validation_0-rmse:0.26043	validation_1-rmse:0.27113
# [114]	validation_0-rmse:0.25901	validation_1-rmse:0.26971
# [115]	validation_0-rmse:0.25830	validation_1-rmse:0.26991
# [116]	validation_0-rmse:0.25694	validation_1-rmse:0.26915
# [117]	validation_0-rmse:0.25534	validation_1-rmse:0.26698
# [118]	validation_0-rmse:0.25325	validation_1-rmse:0.26477
# [119]	validation_0-rmse:0.25124	validation_1-rmse:0.26260
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.79168	validation_1-rmse:1.64701
# [1]	validation_0-rmse:1.74712	validation_1-rmse:1.60107
# [2]	validation_0-rmse:1.70124	validation_1-rmse:1.55324
# [3]	validation_0-rmse:1.65817	validation_1-rmse:1.51105
# [4]	validation_0-rmse:1.61706	validation_1-rmse:1.47208
# [5]	validation_0-rmse:1.57796	validation_1-rmse:1.43423
# [6]	validation_0-rmse:1.54037	validation_1-rmse:1.39637
# [7]	validation_0-rmse:1.49882	validation_1-rmse:1.35202
# [8]	validation_0-rmse:1.46089	validation_1-rmse:1.31274
# [9]	validation_0-rmse:1.42324	validation_1-rmse:1.27378
# [10]	validation_0-rmse:1.38586	validation_1-rmse:1.23681
# [11]	validation_0-rmse:1.35080	validation_1-rmse:1.20118
# [12]	validation_0-rmse:1.31830	validation_1-rmse:1.16916
# [13]	validation_0-rmse:1.28552	validation_1-rmse:1.13669
# [14]	validation_0-rmse:1.25570	validation_1-rmse:1.10626
# [15]	validation_0-rmse:1.22219	validation_1-rmse:1.07364
# [16]	validation_0-rmse:1.19250	validation_1-rmse:1.04449
# [17]	validation_0-rmse:1.16099	validation_1-rmse:1.01364
# [18]	validation_0-rmse:1.13513	validation_1-rmse:0.98658
# [19]	validation_0-rmse:1.10988	validation_1-rmse:0.96025
# [20]	validation_0-rmse:1.08486	validation_1-rmse:0.93543
# [21]	validation_0-rmse:1.05639	validation_1-rmse:0.90671
# [22]	validation_0-rmse:1.03095	validation_1-rmse:0.88310
# [23]	validation_0-rmse:1.00589	validation_1-rmse:0.85925
# [24]	validation_0-rmse:0.98211	validation_1-rmse:0.83661
# [25]	validation_0-rmse:0.95949	validation_1-rmse:0.81719
# [26]	validation_0-rmse:0.93887	validation_1-rmse:0.79816
# [27]	validation_0-rmse:0.91867	validation_1-rmse:0.77829
# [28]	validation_0-rmse:0.89779	validation_1-rmse:0.75863
# [29]	validation_0-rmse:0.87585	validation_1-rmse:0.73634
# [30]	validation_0-rmse:0.85608	validation_1-rmse:0.71681
# [31]	validation_0-rmse:0.83969	validation_1-rmse:0.70182
# [32]	validation_0-rmse:0.82233	validation_1-rmse:0.68374
# [33]	validation_0-rmse:0.80325	validation_1-rmse:0.66555
# [34]	validation_0-rmse:0.78476	validation_1-rmse:0.64714
# [35]	validation_0-rmse:0.76649	validation_1-rmse:0.62948
# [36]	validation_0-rmse:0.75069	validation_1-rmse:0.61478
# [37]	validation_0-rmse:0.73519	validation_1-rmse:0.60121
# [38]	validation_0-rmse:0.72309	validation_1-rmse:0.58901
# [39]	validation_0-rmse:0.70816	validation_1-rmse:0.57519
# [40]	validation_0-rmse:0.69347	validation_1-rmse:0.56268
# [41]	validation_0-rmse:0.67862	validation_1-rmse:0.54864
# [42]	validation_0-rmse:0.66371	validation_1-rmse:0.53564
# [43]	validation_0-rmse:0.65121	validation_1-rmse:0.52271
# [44]	validation_0-rmse:0.63709	validation_1-rmse:0.51013
# [45]	validation_0-rmse:0.62554	validation_1-rmse:0.49918
# [46]	validation_0-rmse:0.61159	validation_1-rmse:0.48552
# [47]	validation_0-rmse:0.59852	validation_1-rmse:0.47497
# [48]	validation_0-rmse:0.58713	validation_1-rmse:0.46375
# [49]	validation_0-rmse:0.57501	validation_1-rmse:0.45381
# [50]	validation_0-rmse:0.56243	validation_1-rmse:0.44327
# [51]	validation_0-rmse:0.54968	validation_1-rmse:0.43159
# [52]	validation_0-rmse:0.53964	validation_1-rmse:0.42282
# [53]	validation_0-rmse:0.52865	validation_1-rmse:0.41406
# [54]	validation_0-rmse:0.51833	validation_1-rmse:0.40662
# [55]	validation_0-rmse:0.50893	validation_1-rmse:0.39898
# [56]	validation_0-rmse:0.49903	validation_1-rmse:0.39044
# [57]	validation_0-rmse:0.48969	validation_1-rmse:0.38128
# [58]	validation_0-rmse:0.48044	validation_1-rmse:0.37499
# [59]	validation_0-rmse:0.47248	validation_1-rmse:0.37020
# [60]	validation_0-rmse:0.46289	validation_1-rmse:0.36386
# [61]	validation_0-rmse:0.45594	validation_1-rmse:0.35893
# [62]	validation_0-rmse:0.44648	validation_1-rmse:0.35118
# [63]	validation_0-rmse:0.43808	validation_1-rmse:0.34777
# [64]	validation_0-rmse:0.42930	validation_1-rmse:0.34112
# [65]	validation_0-rmse:0.42205	validation_1-rmse:0.33784
# [66]	validation_0-rmse:0.41441	validation_1-rmse:0.33420
# [67]	validation_0-rmse:0.40726	validation_1-rmse:0.33114
# [68]	validation_0-rmse:0.39988	validation_1-rmse:0.32514
# [69]	validation_0-rmse:0.39326	validation_1-rmse:0.32075
# [70]	validation_0-rmse:0.38945	validation_1-rmse:0.31923
# [71]	validation_0-rmse:0.38290	validation_1-rmse:0.31402
# [72]	validation_0-rmse:0.37813	validation_1-rmse:0.31232
# [73]	validation_0-rmse:0.37289	validation_1-rmse:0.31118
# [74]	validation_0-rmse:0.36627	validation_1-rmse:0.30865
# [75]	validation_0-rmse:0.36226	validation_1-rmse:0.30661
# [76]	validation_0-rmse:0.35664	validation_1-rmse:0.30250
# [77]	validation_0-rmse:0.35366	validation_1-rmse:0.30280
# [78]	validation_0-rmse:0.34876	validation_1-rmse:0.29581
# [79]	validation_0-rmse:0.34347	validation_1-rmse:0.29335
# [80]	validation_0-rmse:0.33711	validation_1-rmse:0.29054
# [81]	validation_0-rmse:0.33328	validation_1-rmse:0.28964
# [82]	validation_0-rmse:0.32870	validation_1-rmse:0.28649
# [83]	validation_0-rmse:0.32328	validation_1-rmse:0.28323
# [84]	validation_0-rmse:0.31755	validation_1-rmse:0.28096
# [85]	validation_0-rmse:0.31434	validation_1-rmse:0.27755
# [86]	validation_0-rmse:0.31024	validation_1-rmse:0.27609
# [87]	validation_0-rmse:0.30794	validation_1-rmse:0.27557
# [88]	validation_0-rmse:0.30436	validation_1-rmse:0.27392
# [89]	validation_0-rmse:0.30185	validation_1-rmse:0.27342
# [90]	validation_0-rmse:0.29875	validation_1-rmse:0.27362
# [91]	validation_0-rmse:0.29459	validation_1-rmse:0.27264
# [92]	validation_0-rmse:0.29019	validation_1-rmse:0.27013
# [93]	validation_0-rmse:0.28799	validation_1-rmse:0.27039
# [94]	validation_0-rmse:0.28463	validation_1-rmse:0.26956
# [95]	validation_0-rmse:0.28286	validation_1-rmse:0.26959
# [96]	validation_0-rmse:0.27929	validation_1-rmse:0.26766
# [97]	validation_0-rmse:0.27658	validation_1-rmse:0.26828
# [98]	validation_0-rmse:0.27551	validation_1-rmse:0.26933
# [99]	validation_0-rmse:0.27377	validation_1-rmse:0.26919
# [100]	validation_0-rmse:0.27116	validation_1-rmse:0.27094
# [101]	validation_0-rmse:0.26896	validation_1-rmse:0.27162
# [102]	validation_0-rmse:0.26550	validation_1-rmse:0.27109
# [103]	validation_0-rmse:0.26254	validation_1-rmse:0.27096
# [104]	validation_0-rmse:0.26041	validation_1-rmse:0.27128
# [105]	validation_0-rmse:0.25994	validation_1-rmse:0.27200
# [106]	validation_0-rmse:0.25874	validation_1-rmse:0.27228
# [107]	validation_0-rmse:0.25643	validation_1-rmse:0.27023
# [108]	validation_0-rmse:0.25523	validation_1-rmse:0.27079
# [109]	validation_0-rmse:0.25352	validation_1-rmse:0.27036
# [110]	validation_0-rmse:0.25190	validation_1-rmse:0.27063
# [111]	validation_0-rmse:0.24930	validation_1-rmse:0.26970
# [112]	validation_0-rmse:0.24637	validation_1-rmse:0.27207
# [113]	validation_0-rmse:0.24511	validation_1-rmse:0.27167
# [114]	validation_0-rmse:0.24268	validation_1-rmse:0.27129
# [115]	validation_0-rmse:0.24185	validation_1-rmse:0.27160
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-1.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.934
# Uncertainty
# a0: 0.165+/-0.051
# a1: 0.903+/-0.026

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: %_cover: mean - 0.206, median - 0.205, CI - [0.175-0.237]
#
# SHAP-values for: contr_g_MAX: mean - 0.06, median - 0.061, CI - [0.048-0.073]
#
# SHAP-values for: g_MAX: mean - 0.013, median - 0.012, CI - [0.009-0.017]
#
# SHAP-values for: mf_chm_MAX: mean - 0.224, median - 0.225, CI - [0.194-0.25]
#
# SHAP-values for: mf_chm_MEAN: mean - 0.493, median - 0.497, CI - [0.459-0.524]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['mf_chm_MAX', 'mf_chm_MEAN', '%_cover', 'contr_g_MAX', 'g_MAX'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [1, 2, 3, 4, 5, 6])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 10, 50, 100, 200, 600])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(1.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/02_LN_Mstem_CHM_with_RGB_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/02_LN_Mstem_CHM_with_RGB_XGB_model.txt")
