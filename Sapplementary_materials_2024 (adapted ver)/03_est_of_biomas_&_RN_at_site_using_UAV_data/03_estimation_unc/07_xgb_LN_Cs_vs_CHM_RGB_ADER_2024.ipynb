# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN'])
            
# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           2260           1210     -0.731      2.576
# 1       8.189       9.622           2700           1180      0.585      2.915
# 2       8.380       9.589           2500           1400      0.779      2.882
# 3       8.137       9.449           2500           1090      0.517      2.724
# 4       7.696       9.401           2400            720      0.224      2.826
#
#    AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  \
# 0       2.33    0.445070     13  35.145074   360.273487    0.488754
# 1       2.47   12.465903     24  36.135511   323.958625    0.501683
# 2       2.44   13.028298     18  35.938764   299.438354    0.540056
# 3       2.55    2.128231     15  35.908361   319.773395    0.480991
# 4       2.14   12.171553      8  38.062522   353.104284    0.505257
#
#    corr_r_MIN
# 0    0.072792
# 1    0.098347
# 2    0.187811
# 3    0.020686
# 4    0.106549

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   mf_chm_MIN     103 non-null    float64
#  8   r_MIN          103 non-null    int64
#  9   b_STD          103 non-null    float64
#  10  contr_r_STD    103 non-null    float64
#  11  corr_r_Q25     103 non-null    float64
#  12  corr_r_MIN     103 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 10.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Cs_wood", "ln_Sr_wood"].describe()
# Out:
#                  ln_Cs_wood                                                 \
#                       count       mean       std     min      25%      50%
# Dominant_specias
# Alder                   4.0   7.305000  1.427622   5.886   6.6765   7.0235
# Aspen                   1.0  11.367000       NaN  11.367  11.3670  11.3670
# Birch                  23.0   7.304652  1.533182   4.533   6.3365   7.2150
# Oak                     3.0   7.430333  1.260072   6.040   6.8970   7.7540
# Pine                   71.0   6.901690  1.650166   3.526   6.3790   6.9470
# Spruce                  1.0   5.176000       NaN   5.176   5.1760   5.1760
#
#                                   ln_Sr_wood                               \
#                       75%     max      count       mean       std     min
# Dominant_specias
# Alder              7.6520   9.287        4.0   7.206000  0.650057   6.265
# Aspen             11.3670  11.367        1.0  11.090000       NaN  11.090
# Birch              8.0320  10.332       23.0   9.345478  1.626360   7.139
# Oak                8.1255   8.497        3.0   7.483667  0.815040   6.565
# Pine               7.6960  10.469       71.0   8.542592  1.359020   6.075
# Spruce             5.1760   5.176        1.0   7.783000       NaN   7.783
#
#
#                       25%      50%      75%     max
# Dominant_specias
# Alder              7.0255   7.4545   7.6350   7.650
# Aspen             11.0900  11.0900  11.0900  11.090
# Birch              8.4000   8.9910   9.9365  13.864
# Oak                7.1655   7.7660   7.9430   8.120
# Pine               7.6450   8.4720   9.3710  12.687
# Spruce             7.7830   7.7830   7.7830   7.783

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3440.194175    1242.902913   -0.252563
# std       1.64946    1.472424    6087.580089    2037.684800    1.104610
# min       3.52600    6.075000     260.000000      50.000000   -3.033000
# 25%       6.31900    7.664000     635.000000     200.000000   -0.727500
# 50%       6.95700    8.472000    1150.000000     400.000000   -0.025000
# 75%       7.91350    9.421000    2525.000000    1400.000000    0.516500
# max      11.36700   13.864000   35200.000000   10500.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean  mf_chm_MIN       r_MIN       b_STD  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     2.464709    3.570291    3.368496   11.378641   35.164575
# std      0.904675    6.089170    4.845054    9.139568    5.338700
# min      0.391000    0.480000   -0.018586    2.000000   20.570709
# 25%      1.803000    0.710000    0.482279    5.000000   31.746440
# 50%      2.603000    1.290000    0.642883    8.000000   36.135511
# 75%      3.159000    2.960000    3.921804   15.000000   39.139044
# max      4.659000   36.590000   17.862923   56.000000   45.825416
#
#        contr_r_STD  corr_r_Q25  corr_r_MIN
# count   103.000000  103.000000  103.000000
# mean    327.115078    0.393571    0.073579
# std     167.617957    0.151801    0.056017
# min       0.091058    0.033797   -0.062450
# 25%     283.887328    0.407228    0.027204
# 50%     353.034542    0.449670    0.063714
# 75%     448.017711    0.476635    0.110983
# max     652.546648    0.555648    0.241284

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_Cs_wood"
indep_variables = ['r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_MIN', 'corr_r_Q25', 'AEDR_mean']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  \
# 0         6.824       9.240           2260           1210     -0.731
# 1         8.189       9.622           2700           1180      0.585
# 2         8.380       9.589           2500           1400      0.779
# 3         8.137       9.449           2500           1090      0.517
# 4         7.696       9.401           2400            720      0.224
# ..          ...         ...            ...            ...        ...
# 98        8.071       8.434           2500           1300      0.228
# 99        7.993      10.042           2300           1100      0.266
# 100       8.343      10.488           2400           1200      0.543
# 101       3.638       6.399            630            270     -2.811
# 102       4.787       6.877            680            290     -1.728
#
#      ln_Tag_Sr  AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  \
# 0        2.576       2.33    0.445070     13  35.145074   360.273487
# 1        2.915       2.47   12.465903     24  36.135511   323.958625
# 2        2.882       2.44   13.028298     18  35.938764   299.438354
# 3        2.724       2.55    2.128231     15  35.908361   319.773395
# 4        2.826       2.14   12.171553      8  38.062522   353.104284
# ..         ...        ...         ...    ...        ...          ...
# 98       1.514       2.92    0.528681      3  32.852994   329.221211
# 99       3.230       2.78    0.422647     18  27.970146   268.895699
# 100      3.606       2.92    0.426717     19  30.529613   251.314791
# 101      0.805       0.75    0.476680      6  37.245047   477.751734
# 102      1.199       0.78    0.410141      2  38.454424   412.535053
#
#      corr_r_Q25  corr_r_MIN
# 0      0.488754    0.072792
# 1      0.501683    0.098347
# 2      0.540056    0.187811
# 3      0.480991    0.020686
# 4      0.505257    0.106549
# ..          ...         ...
# 98     0.478581    0.079646
# 99     0.467111    0.063714
# 100    0.501777    0.128376
# 101    0.467443    0.129664
# 102    0.480964    0.157460
#
# [103 rows x 13 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    r_MIN      b_STD  contr_r_STD  corr_r_MIN  corr_r_Q25  AEDR_mean
# 0     13  35.145074   360.273487    0.072792    0.488754       2.33
# 1     24  36.135511   323.958625    0.098347    0.501683       2.47
# 2     18  35.938764   299.438354    0.187811    0.540056       2.44
# 3     15  35.908361   319.773395    0.020686    0.480991       2.55
# 4      8  38.062522   353.104284    0.106549    0.505257       2.14

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Cs_wood
# 0       6.824
# 1       8.189
# 2       8.380
# 3       8.137
# 4       7.696

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.5194430163388599, 0.6158388904320162, 0.6259108118910774]
#     Mean: 0.587
#     Std: 0.048
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.92529176 1.18064932 1.1639362 ]
#     Mean: 1.090
#     Std: 0.117
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.9130315884181432, 0.8262097596561208, 0.7314796147066004]
#     Mean: 0.824
#     Std: 0.074
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.37679773343911427                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.21630107231039897                  # gamma
print('Gamma: ' + str(p2))

p3 = 0.300427594799142                    # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2                                    # max_depth
print('Max_depth: ' + str(p4))

p5 = 51                                  # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.642309491037681                   # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.37679773343911427
# Gamma: 0.21630107231039897
# Learning_rate: 0.300427594799142
# Max_depth: 2
# N_estimators: 51
# Subsample: 0.642309491037681

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:4.99259	validation_1-rmse:4.63131
# [1]	validation_0-rmse:3.67451	validation_1-rmse:3.44334
# [2]	validation_0-rmse:2.68572	validation_1-rmse:2.53332
# [3]	validation_0-rmse:2.06846	validation_1-rmse:2.02410
# [4]	validation_0-rmse:1.63755	validation_1-rmse:1.78204
# [5]	validation_0-rmse:1.32967	validation_1-rmse:1.56536
# [6]	validation_0-rmse:1.11859	validation_1-rmse:1.41070
# [7]	validation_0-rmse:1.00089	validation_1-rmse:1.34799
# [8]	validation_0-rmse:0.92318	validation_1-rmse:1.29590
# [9]	validation_0-rmse:0.85102	validation_1-rmse:1.29941
# [10]	validation_0-rmse:0.83683	validation_1-rmse:1.32660
# [11]	validation_0-rmse:0.81802	validation_1-rmse:1.31251
# [12]	validation_0-rmse:0.80109	validation_1-rmse:1.33085
# [13]	validation_0-rmse:0.79290	validation_1-rmse:1.30996
# [14]	validation_0-rmse:0.76227	validation_1-rmse:1.30353
# [15]	validation_0-rmse:0.72569	validation_1-rmse:1.24433
# [16]	validation_0-rmse:0.71396	validation_1-rmse:1.20295
# [17]	validation_0-rmse:0.69736	validation_1-rmse:1.22669
# [18]	validation_0-rmse:0.68399	validation_1-rmse:1.23281
# [19]	validation_0-rmse:0.67350	validation_1-rmse:1.21998
# [20]	validation_0-rmse:0.66328	validation_1-rmse:1.22198
# [21]	validation_0-rmse:0.65653	validation_1-rmse:1.21064
# [22]	validation_0-rmse:0.64315	validation_1-rmse:1.23183
# [23]	validation_0-rmse:0.62393	validation_1-rmse:1.20145
# [24]	validation_0-rmse:0.61212	validation_1-rmse:1.14270
# [25]	validation_0-rmse:0.60231	validation_1-rmse:1.12966
# [26]	validation_0-rmse:0.59273	validation_1-rmse:1.11833
# [27]	validation_0-rmse:0.59000	validation_1-rmse:1.12327
# [28]	validation_0-rmse:0.57863	validation_1-rmse:1.12310
# [29]	validation_0-rmse:0.57513	validation_1-rmse:1.17391
# [30]	validation_0-rmse:0.57177	validation_1-rmse:1.18197
# [31]	validation_0-rmse:0.55669	validation_1-rmse:1.16745
# [32]	validation_0-rmse:0.54821	validation_1-rmse:1.13480
# [33]	validation_0-rmse:0.54178	validation_1-rmse:1.12125
# [34]	validation_0-rmse:0.53893	validation_1-rmse:1.12447
# [35]	validation_0-rmse:0.53753	validation_1-rmse:1.11430
# [36]	validation_0-rmse:0.51785	validation_1-rmse:1.08724
# [37]	validation_0-rmse:0.50773	validation_1-rmse:1.08855
# [38]	validation_0-rmse:0.49972	validation_1-rmse:1.09243
# [39]	validation_0-rmse:0.49121	validation_1-rmse:1.07128
# [40]	validation_0-rmse:0.47791	validation_1-rmse:1.08966
# [41]	validation_0-rmse:0.47131	validation_1-rmse:1.09014
# [42]	validation_0-rmse:0.46513	validation_1-rmse:1.08828
# [43]	validation_0-rmse:0.46018	validation_1-rmse:1.09482
# [44]	validation_0-rmse:0.45545	validation_1-rmse:1.09172
# [45]	validation_0-rmse:0.44596	validation_1-rmse:1.07470
# [46]	validation_0-rmse:0.44592	validation_1-rmse:1.09195
# [47]	validation_0-rmse:0.43267	validation_1-rmse:1.08527
# [48]	validation_0-rmse:0.42463	validation_1-rmse:1.07329
# [49]	validation_0-rmse:0.41901	validation_1-rmse:1.07284
# [50]	validation_0-rmse:0.41794	validation_1-rmse:1.06208
# [0]	validation_0-rmse:4.74447	validation_1-rmse:5.37171
# [1]	validation_0-rmse:3.49538	validation_1-rmse:4.21412
# [2]	validation_0-rmse:2.61112	validation_1-rmse:3.28665
# [3]	validation_0-rmse:2.05225	validation_1-rmse:2.71630
# [4]	validation_0-rmse:1.62518	validation_1-rmse:2.20833
# [5]	validation_0-rmse:1.34716	validation_1-rmse:1.94273
# [6]	validation_0-rmse:1.11593	validation_1-rmse:1.61870
# [7]	validation_0-rmse:0.95100	validation_1-rmse:1.38844
# [8]	validation_0-rmse:0.86683	validation_1-rmse:1.30677
# [9]	validation_0-rmse:0.81367	validation_1-rmse:1.24314
# [10]	validation_0-rmse:0.76886	validation_1-rmse:1.16725
# [11]	validation_0-rmse:0.72880	validation_1-rmse:1.17562
# [12]	validation_0-rmse:0.69999	validation_1-rmse:1.15166
# [13]	validation_0-rmse:0.67147	validation_1-rmse:1.14679
# [14]	validation_0-rmse:0.65611	validation_1-rmse:1.12469
# [15]	validation_0-rmse:0.65199	validation_1-rmse:1.17807
# [16]	validation_0-rmse:0.65116	validation_1-rmse:1.18529
# [17]	validation_0-rmse:0.63196	validation_1-rmse:1.12800
# [18]	validation_0-rmse:0.60893	validation_1-rmse:1.12086
# [19]	validation_0-rmse:0.60301	validation_1-rmse:1.12241
# [20]	validation_0-rmse:0.59406	validation_1-rmse:1.12346
# [21]	validation_0-rmse:0.58875	validation_1-rmse:1.13488
# [22]	validation_0-rmse:0.58017	validation_1-rmse:1.15902
# [23]	validation_0-rmse:0.55431	validation_1-rmse:1.16001
# [24]	validation_0-rmse:0.54503	validation_1-rmse:1.15575
# [25]	validation_0-rmse:0.53309	validation_1-rmse:1.15014
# [26]	validation_0-rmse:0.52948	validation_1-rmse:1.15835
# [27]	validation_0-rmse:0.52474	validation_1-rmse:1.17387
# [28]	validation_0-rmse:0.51968	validation_1-rmse:1.15698
# [29]	validation_0-rmse:0.50886	validation_1-rmse:1.16019
# [30]	validation_0-rmse:0.50515	validation_1-rmse:1.16107
# [31]	validation_0-rmse:0.49104	validation_1-rmse:1.17333
# [32]	validation_0-rmse:0.47965	validation_1-rmse:1.18516
# [33]	validation_0-rmse:0.47158	validation_1-rmse:1.18627
# [34]	validation_0-rmse:0.46347	validation_1-rmse:1.15891
# [35]	validation_0-rmse:0.44863	validation_1-rmse:1.15521
# [36]	validation_0-rmse:0.43161	validation_1-rmse:1.17071
# [37]	validation_0-rmse:0.41476	validation_1-rmse:1.16685
# [38]	validation_0-rmse:0.39896	validation_1-rmse:1.16475
# [0]	validation_0-rmse:4.92667	validation_1-rmse:5.18593
# [1]	validation_0-rmse:3.65020	validation_1-rmse:3.91720
# [2]	validation_0-rmse:2.69687	validation_1-rmse:2.90027
# [3]	validation_0-rmse:2.04191	validation_1-rmse:2.23605
# [4]	validation_0-rmse:1.65148	validation_1-rmse:1.86494
# [5]	validation_0-rmse:1.30792	validation_1-rmse:1.53254
# [6]	validation_0-rmse:1.09918	validation_1-rmse:1.32274
# [7]	validation_0-rmse:0.95021	validation_1-rmse:1.18286
# [8]	validation_0-rmse:0.84668	validation_1-rmse:1.07123
# [9]	validation_0-rmse:0.79748	validation_1-rmse:1.06303
# [10]	validation_0-rmse:0.76354	validation_1-rmse:1.02626
# [11]	validation_0-rmse:0.70785	validation_1-rmse:1.05976
# [12]	validation_0-rmse:0.68924	validation_1-rmse:1.04568
# [13]	validation_0-rmse:0.67967	validation_1-rmse:1.04591
# [14]	validation_0-rmse:0.65298	validation_1-rmse:1.02337
# [15]	validation_0-rmse:0.62015	validation_1-rmse:1.01447
# [16]	validation_0-rmse:0.58239	validation_1-rmse:1.01497
# [17]	validation_0-rmse:0.56546	validation_1-rmse:1.00033
# [18]	validation_0-rmse:0.53861	validation_1-rmse:0.99052
# [19]	validation_0-rmse:0.52980	validation_1-rmse:0.99179
# [20]	validation_0-rmse:0.52052	validation_1-rmse:1.00127
# [21]	validation_0-rmse:0.51484	validation_1-rmse:1.00508
# [22]	validation_0-rmse:0.50293	validation_1-rmse:1.01249
# [23]	validation_0-rmse:0.49905	validation_1-rmse:1.00937
# [24]	validation_0-rmse:0.49612	validation_1-rmse:0.99481
# [25]	validation_0-rmse:0.48885	validation_1-rmse:1.00675
# [26]	validation_0-rmse:0.47793	validation_1-rmse:1.00099
# [27]	validation_0-rmse:0.46501	validation_1-rmse:1.00720
# [28]	validation_0-rmse:0.45714	validation_1-rmse:1.00172
# [29]	validation_0-rmse:0.44900	validation_1-rmse:1.01428
# [30]	validation_0-rmse:0.44704	validation_1-rmse:1.02094
# [31]	validation_0-rmse:0.43906	validation_1-rmse:1.02763
# [32]	validation_0-rmse:0.43427	validation_1-rmse:1.02289
# [33]	validation_0-rmse:0.42667	validation_1-rmse:1.01568
# [34]	validation_0-rmse:0.41913	validation_1-rmse:1.01671
# [35]	validation_0-rmse:0.41478	validation_1-rmse:1.02280
# [36]	validation_0-rmse:0.40927	validation_1-rmse:1.02444
# [37]	validation_0-rmse:0.40454	validation_1-rmse:1.04160
# [38]	validation_0-rmse:0.40087	validation_1-rmse:1.02928
# [0]	validation_0-rmse:4.78989	validation_1-rmse:5.51742
# [1]	validation_0-rmse:3.56202	validation_1-rmse:4.33400
# [2]	validation_0-rmse:2.69670	validation_1-rmse:3.39058
# [3]	validation_0-rmse:2.05649	validation_1-rmse:2.74761
# [4]	validation_0-rmse:1.63364	validation_1-rmse:2.29100
# [5]	validation_0-rmse:1.31223	validation_1-rmse:1.91386
# [6]	validation_0-rmse:1.11972	validation_1-rmse:1.64355
# [7]	validation_0-rmse:1.00170	validation_1-rmse:1.42906
# [8]	validation_0-rmse:0.92598	validation_1-rmse:1.25077
# [9]	validation_0-rmse:0.85872	validation_1-rmse:1.21048
# [10]	validation_0-rmse:0.82819	validation_1-rmse:1.17959
# [11]	validation_0-rmse:0.76655	validation_1-rmse:1.08503
# [12]	validation_0-rmse:0.73400	validation_1-rmse:1.08701
# [13]	validation_0-rmse:0.71642	validation_1-rmse:1.10625
# [14]	validation_0-rmse:0.69089	validation_1-rmse:1.09697
# [15]	validation_0-rmse:0.66186	validation_1-rmse:1.08581
# [16]	validation_0-rmse:0.64664	validation_1-rmse:1.09736
# [17]	validation_0-rmse:0.63622	validation_1-rmse:1.12939
# [18]	validation_0-rmse:0.62097	validation_1-rmse:1.13607
# [19]	validation_0-rmse:0.60342	validation_1-rmse:1.13297
# [20]	validation_0-rmse:0.58738	validation_1-rmse:1.12021
# [21]	validation_0-rmse:0.57483	validation_1-rmse:1.12383
# [22]	validation_0-rmse:0.56740	validation_1-rmse:1.12605
# [23]	validation_0-rmse:0.55907	validation_1-rmse:1.13117
# [24]	validation_0-rmse:0.54415	validation_1-rmse:1.12518
# [25]	validation_0-rmse:0.53683	validation_1-rmse:1.13083
# [26]	validation_0-rmse:0.53029	validation_1-rmse:1.12302
# [27]	validation_0-rmse:0.52457	validation_1-rmse:1.12188
# [28]	validation_0-rmse:0.51545	validation_1-rmse:1.13000
# [29]	validation_0-rmse:0.51264	validation_1-rmse:1.12436
# [30]	validation_0-rmse:0.50970	validation_1-rmse:1.14545
# [31]	validation_0-rmse:0.50679	validation_1-rmse:1.14973
# [0]	validation_0-rmse:4.85916	validation_1-rmse:5.14989
# [1]	validation_0-rmse:3.56525	validation_1-rmse:3.87305
# [2]	validation_0-rmse:2.64769	validation_1-rmse:2.97599
# [3]	validation_0-rmse:2.07419	validation_1-rmse:2.42394
# [4]	validation_0-rmse:1.66424	validation_1-rmse:2.05958
# [5]	validation_0-rmse:1.33156	validation_1-rmse:1.67499
# [6]	validation_0-rmse:1.09878	validation_1-rmse:1.41303
# [7]	validation_0-rmse:0.95640	validation_1-rmse:1.29883
# [8]	validation_0-rmse:0.87255	validation_1-rmse:1.18062
# [9]	validation_0-rmse:0.80741	validation_1-rmse:1.12908
# [10]	validation_0-rmse:0.76994	validation_1-rmse:1.10034
# [11]	validation_0-rmse:0.74032	validation_1-rmse:1.04149
# [12]	validation_0-rmse:0.72541	validation_1-rmse:1.02300
# [13]	validation_0-rmse:0.71445	validation_1-rmse:1.03486
# [14]	validation_0-rmse:0.68875	validation_1-rmse:1.02306
# [15]	validation_0-rmse:0.66248	validation_1-rmse:1.04150
# [16]	validation_0-rmse:0.65517	validation_1-rmse:1.02627
# [17]	validation_0-rmse:0.63326	validation_1-rmse:1.05236
# [18]	validation_0-rmse:0.61854	validation_1-rmse:1.09392
# [19]	validation_0-rmse:0.61645	validation_1-rmse:1.11144
# [20]	validation_0-rmse:0.59722	validation_1-rmse:1.07959
# [21]	validation_0-rmse:0.59029	validation_1-rmse:1.07149
# [22]	validation_0-rmse:0.57361	validation_1-rmse:1.07255
# [23]	validation_0-rmse:0.57065	validation_1-rmse:1.04115
# [24]	validation_0-rmse:0.56019	validation_1-rmse:1.02440
# [25]	validation_0-rmse:0.54889	validation_1-rmse:1.03716
# [26]	validation_0-rmse:0.54327	validation_1-rmse:1.05265
# [27]	validation_0-rmse:0.53235	validation_1-rmse:1.05494
# [28]	validation_0-rmse:0.52651	validation_1-rmse:1.05431
# [29]	validation_0-rmse:0.51553	validation_1-rmse:1.03980
# [30]	validation_0-rmse:0.50121	validation_1-rmse:1.05979
# [31]	validation_0-rmse:0.49258	validation_1-rmse:1.05309
# [0]	validation_0-rmse:4.91512	validation_1-rmse:5.16400
# [1]	validation_0-rmse:3.60141	validation_1-rmse:3.68750
# [2]	validation_0-rmse:2.66566	validation_1-rmse:2.66910
# [3]	validation_0-rmse:1.97847	validation_1-rmse:2.01971
# [4]	validation_0-rmse:1.58155	validation_1-rmse:1.56492
# [5]	validation_0-rmse:1.31492	validation_1-rmse:1.32381
# [6]	validation_0-rmse:1.11824	validation_1-rmse:1.14390
# [7]	validation_0-rmse:0.97906	validation_1-rmse:1.04709
# [8]	validation_0-rmse:0.90635	validation_1-rmse:1.00129
# [9]	validation_0-rmse:0.82616	validation_1-rmse:0.98037
# [10]	validation_0-rmse:0.80323	validation_1-rmse:0.97550
# [11]	validation_0-rmse:0.77989	validation_1-rmse:0.95443
# [12]	validation_0-rmse:0.75583	validation_1-rmse:0.97798
# [13]	validation_0-rmse:0.73542	validation_1-rmse:0.99377
# [14]	validation_0-rmse:0.71084	validation_1-rmse:0.94762
# [15]	validation_0-rmse:0.68948	validation_1-rmse:0.94420
# [16]	validation_0-rmse:0.67150	validation_1-rmse:0.95189
# [17]	validation_0-rmse:0.64524	validation_1-rmse:0.96774
# [18]	validation_0-rmse:0.64022	validation_1-rmse:0.97665
# [19]	validation_0-rmse:0.63065	validation_1-rmse:0.97544
# [20]	validation_0-rmse:0.61908	validation_1-rmse:0.94391
# [21]	validation_0-rmse:0.59373	validation_1-rmse:0.92848
# [22]	validation_0-rmse:0.58073	validation_1-rmse:0.92020
# [23]	validation_0-rmse:0.57694	validation_1-rmse:0.92258
# [24]	validation_0-rmse:0.56912	validation_1-rmse:0.93177
# [25]	validation_0-rmse:0.55341	validation_1-rmse:0.94742
# [26]	validation_0-rmse:0.54551	validation_1-rmse:0.94424
# [27]	validation_0-rmse:0.54387	validation_1-rmse:0.93722
# [28]	validation_0-rmse:0.53577	validation_1-rmse:0.94953
# [29]	validation_0-rmse:0.52936	validation_1-rmse:0.93861
# [30]	validation_0-rmse:0.51567	validation_1-rmse:0.94700
# [31]	validation_0-rmse:0.49736	validation_1-rmse:0.94041
# [32]	validation_0-rmse:0.48598	validation_1-rmse:0.94346
# [33]	validation_0-rmse:0.47361	validation_1-rmse:0.93074
# [34]	validation_0-rmse:0.46926	validation_1-rmse:0.94177
# [35]	validation_0-rmse:0.45792	validation_1-rmse:0.92582
# [36]	validation_0-rmse:0.45176	validation_1-rmse:0.93178
# [37]	validation_0-rmse:0.44961	validation_1-rmse:0.92000
# [38]	validation_0-rmse:0.44384	validation_1-rmse:0.92559
# [39]	validation_0-rmse:0.44075	validation_1-rmse:0.92971
# [40]	validation_0-rmse:0.44175	validation_1-rmse:0.92459
# [41]	validation_0-rmse:0.44099	validation_1-rmse:0.91389
# [42]	validation_0-rmse:0.43966	validation_1-rmse:0.94640
# [43]	validation_0-rmse:0.43373	validation_1-rmse:0.94153
# [44]	validation_0-rmse:0.42825	validation_1-rmse:0.94129
# [45]	validation_0-rmse:0.42328	validation_1-rmse:0.91948
# [46]	validation_0-rmse:0.41619	validation_1-rmse:0.92122
# [47]	validation_0-rmse:0.41278	validation_1-rmse:0.93488
# [48]	validation_0-rmse:0.41017	validation_1-rmse:0.93744
# [49]	validation_0-rmse:0.40719	validation_1-rmse:0.94028
# [50]	validation_0-rmse:0.39803	validation_1-rmse:0.94015
# [0]	validation_0-rmse:4.85876	validation_1-rmse:5.18873
# [1]	validation_0-rmse:3.57997	validation_1-rmse:3.85797
# [2]	validation_0-rmse:2.63246	validation_1-rmse:2.88894
# [3]	validation_0-rmse:2.07618	validation_1-rmse:2.39678
# [4]	validation_0-rmse:1.67452	validation_1-rmse:1.89564
# [5]	validation_0-rmse:1.39265	validation_1-rmse:1.53106
# [6]	validation_0-rmse:1.18497	validation_1-rmse:1.20450
# [7]	validation_0-rmse:1.04540	validation_1-rmse:1.04764
# [8]	validation_0-rmse:0.95882	validation_1-rmse:0.91334
# [9]	validation_0-rmse:0.91410	validation_1-rmse:0.82013
# [10]	validation_0-rmse:0.89023	validation_1-rmse:0.81537
# [11]	validation_0-rmse:0.81865	validation_1-rmse:0.80147
# [12]	validation_0-rmse:0.78269	validation_1-rmse:0.77221
# [13]	validation_0-rmse:0.76038	validation_1-rmse:0.75103
# [14]	validation_0-rmse:0.72563	validation_1-rmse:0.75384
# [15]	validation_0-rmse:0.71673	validation_1-rmse:0.75936
# [16]	validation_0-rmse:0.70470	validation_1-rmse:0.76526
# [17]	validation_0-rmse:0.68473	validation_1-rmse:0.73709
# [18]	validation_0-rmse:0.67675	validation_1-rmse:0.73140
# [19]	validation_0-rmse:0.66771	validation_1-rmse:0.74135
# [20]	validation_0-rmse:0.64809	validation_1-rmse:0.74150
# [21]	validation_0-rmse:0.63389	validation_1-rmse:0.76979
# [22]	validation_0-rmse:0.61108	validation_1-rmse:0.76949
# [23]	validation_0-rmse:0.60078	validation_1-rmse:0.74255
# [24]	validation_0-rmse:0.59375	validation_1-rmse:0.74098
# [25]	validation_0-rmse:0.58829	validation_1-rmse:0.76007
# [26]	validation_0-rmse:0.58497	validation_1-rmse:0.75146
# [27]	validation_0-rmse:0.57714	validation_1-rmse:0.72340
# [28]	validation_0-rmse:0.56770	validation_1-rmse:0.70398
# [29]	validation_0-rmse:0.56338	validation_1-rmse:0.69312
# [30]	validation_0-rmse:0.55854	validation_1-rmse:0.67135
# [31]	validation_0-rmse:0.54602	validation_1-rmse:0.67718
# [32]	validation_0-rmse:0.53736	validation_1-rmse:0.65284
# [33]	validation_0-rmse:0.52703	validation_1-rmse:0.66117
# [34]	validation_0-rmse:0.52532	validation_1-rmse:0.67617
# [35]	validation_0-rmse:0.52048	validation_1-rmse:0.69585
# [36]	validation_0-rmse:0.51687	validation_1-rmse:0.69339
# [37]	validation_0-rmse:0.50924	validation_1-rmse:0.70284
# [38]	validation_0-rmse:0.49920	validation_1-rmse:0.70393
# [39]	validation_0-rmse:0.49718	validation_1-rmse:0.72008
# [40]	validation_0-rmse:0.49595	validation_1-rmse:0.71374
# [41]	validation_0-rmse:0.48765	validation_1-rmse:0.71695
# [42]	validation_0-rmse:0.48094	validation_1-rmse:0.70556
# [43]	validation_0-rmse:0.47615	validation_1-rmse:0.71151
# [44]	validation_0-rmse:0.47749	validation_1-rmse:0.70547
# [45]	validation_0-rmse:0.47215	validation_1-rmse:0.70509
# [46]	validation_0-rmse:0.47056	validation_1-rmse:0.70021
# [47]	validation_0-rmse:0.45732	validation_1-rmse:0.70929
# [48]	validation_0-rmse:0.45004	validation_1-rmse:0.70855
# [49]	validation_0-rmse:0.44708	validation_1-rmse:0.70923
# [50]	validation_0-rmse:0.44255	validation_1-rmse:0.70946
# [0]	validation_0-rmse:4.89425	validation_1-rmse:5.07263
# [1]	validation_0-rmse:3.58719	validation_1-rmse:3.74607
# [2]	validation_0-rmse:2.66189	validation_1-rmse:2.87181
# [3]	validation_0-rmse:2.08245	validation_1-rmse:2.30789
# [4]	validation_0-rmse:1.67121	validation_1-rmse:1.85697
# [5]	validation_0-rmse:1.34086	validation_1-rmse:1.55406
# [6]	validation_0-rmse:1.12312	validation_1-rmse:1.37433
# [7]	validation_0-rmse:0.98585	validation_1-rmse:1.23568
# [8]	validation_0-rmse:0.90016	validation_1-rmse:1.14047
# [9]	validation_0-rmse:0.85746	validation_1-rmse:1.11711
# [10]	validation_0-rmse:0.81610	validation_1-rmse:1.09638
# [11]	validation_0-rmse:0.75357	validation_1-rmse:1.05363
# [12]	validation_0-rmse:0.73897	validation_1-rmse:1.03264
# [13]	validation_0-rmse:0.72755	validation_1-rmse:1.05035
# [14]	validation_0-rmse:0.69313	validation_1-rmse:1.05852
# [15]	validation_0-rmse:0.65703	validation_1-rmse:1.07825
# [16]	validation_0-rmse:0.65322	validation_1-rmse:1.08700
# [17]	validation_0-rmse:0.63027	validation_1-rmse:1.09052
# [18]	validation_0-rmse:0.61851	validation_1-rmse:1.08375
# [19]	validation_0-rmse:0.61280	validation_1-rmse:1.09925
# [20]	validation_0-rmse:0.60214	validation_1-rmse:1.10555
# [21]	validation_0-rmse:0.58970	validation_1-rmse:1.08320
# [22]	validation_0-rmse:0.58660	validation_1-rmse:1.07694
# [23]	validation_0-rmse:0.57751	validation_1-rmse:1.07303
# [24]	validation_0-rmse:0.57065	validation_1-rmse:1.08546
# [25]	validation_0-rmse:0.56218	validation_1-rmse:1.08561
# [26]	validation_0-rmse:0.54889	validation_1-rmse:1.05952
# [27]	validation_0-rmse:0.54812	validation_1-rmse:1.06383
# [28]	validation_0-rmse:0.53515	validation_1-rmse:1.08734
# [29]	validation_0-rmse:0.52105	validation_1-rmse:1.09042
# [30]	validation_0-rmse:0.51693	validation_1-rmse:1.10279
# [31]	validation_0-rmse:0.51077	validation_1-rmse:1.10922
# [0]	validation_0-rmse:4.99343	validation_1-rmse:4.84859
# [1]	validation_0-rmse:3.74972	validation_1-rmse:3.70046
# [2]	validation_0-rmse:2.77106	validation_1-rmse:2.86441
# [3]	validation_0-rmse:2.08631	validation_1-rmse:2.25551
# [4]	validation_0-rmse:1.64331	validation_1-rmse:1.86926
# [5]	validation_0-rmse:1.32061	validation_1-rmse:1.63341
# [6]	validation_0-rmse:1.08962	validation_1-rmse:1.49328
# [7]	validation_0-rmse:0.94920	validation_1-rmse:1.38630
# [8]	validation_0-rmse:0.85687	validation_1-rmse:1.30379
# [9]	validation_0-rmse:0.80577	validation_1-rmse:1.27381
# [10]	validation_0-rmse:0.75363	validation_1-rmse:1.23834
# [11]	validation_0-rmse:0.70645	validation_1-rmse:1.25225
# [12]	validation_0-rmse:0.67682	validation_1-rmse:1.23429
# [13]	validation_0-rmse:0.66585	validation_1-rmse:1.23431
# [14]	validation_0-rmse:0.63094	validation_1-rmse:1.20446
# [15]	validation_0-rmse:0.61189	validation_1-rmse:1.20643
# [16]	validation_0-rmse:0.60379	validation_1-rmse:1.20840
# [17]	validation_0-rmse:0.59110	validation_1-rmse:1.21386
# [18]	validation_0-rmse:0.58765	validation_1-rmse:1.22093
# [19]	validation_0-rmse:0.57678	validation_1-rmse:1.22746
# [20]	validation_0-rmse:0.56059	validation_1-rmse:1.21600
# [21]	validation_0-rmse:0.55533	validation_1-rmse:1.20963
# [22]	validation_0-rmse:0.53484	validation_1-rmse:1.20533
# [23]	validation_0-rmse:0.52647	validation_1-rmse:1.21783
# [24]	validation_0-rmse:0.50935	validation_1-rmse:1.19054
# [25]	validation_0-rmse:0.49775	validation_1-rmse:1.18841
# [26]	validation_0-rmse:0.49309	validation_1-rmse:1.19401
# [27]	validation_0-rmse:0.48830	validation_1-rmse:1.18928
# [28]	validation_0-rmse:0.47761	validation_1-rmse:1.19581
# [29]	validation_0-rmse:0.47119	validation_1-rmse:1.19974
# [30]	validation_0-rmse:0.46207	validation_1-rmse:1.19637
# [31]	validation_0-rmse:0.45546	validation_1-rmse:1.18432
# [32]	validation_0-rmse:0.44903	validation_1-rmse:1.18964
# [33]	validation_0-rmse:0.43751	validation_1-rmse:1.20618
# [34]	validation_0-rmse:0.43070	validation_1-rmse:1.20704
# [35]	validation_0-rmse:0.42341	validation_1-rmse:1.22826
# [36]	validation_0-rmse:0.42054	validation_1-rmse:1.22987
# [37]	validation_0-rmse:0.41482	validation_1-rmse:1.23261
# [38]	validation_0-rmse:0.40399	validation_1-rmse:1.24556
# [39]	validation_0-rmse:0.39691	validation_1-rmse:1.24379
# [40]	validation_0-rmse:0.39144	validation_1-rmse:1.24508
# [41]	validation_0-rmse:0.39035	validation_1-rmse:1.24010
# [42]	validation_0-rmse:0.38888	validation_1-rmse:1.25808
# [43]	validation_0-rmse:0.39005	validation_1-rmse:1.27085
# [44]	validation_0-rmse:0.38418	validation_1-rmse:1.26604
# [45]	validation_0-rmse:0.37710	validation_1-rmse:1.26659
# [46]	validation_0-rmse:0.37007	validation_1-rmse:1.27136
# [47]	validation_0-rmse:0.36261	validation_1-rmse:1.27709
# [48]	validation_0-rmse:0.36168	validation_1-rmse:1.27707
# [49]	validation_0-rmse:0.35287	validation_1-rmse:1.27590
# [50]	validation_0-rmse:0.35309	validation_1-rmse:1.28272
# [0]	validation_0-rmse:4.88991	validation_1-rmse:5.04375
# [1]	validation_0-rmse:3.58667	validation_1-rmse:3.68377
# [2]	validation_0-rmse:2.64027	validation_1-rmse:2.80707
# [3]	validation_0-rmse:2.07560	validation_1-rmse:2.26252
# [4]	validation_0-rmse:1.61808	validation_1-rmse:1.78409
# [5]	validation_0-rmse:1.31989	validation_1-rmse:1.48787
# [6]	validation_0-rmse:1.10831	validation_1-rmse:1.31764
# [7]	validation_0-rmse:0.96521	validation_1-rmse:1.16930
# [8]	validation_0-rmse:0.88022	validation_1-rmse:1.09932
# [9]	validation_0-rmse:0.84311	validation_1-rmse:1.11992
# [10]	validation_0-rmse:0.81795	validation_1-rmse:1.09497
# [11]	validation_0-rmse:0.77536	validation_1-rmse:1.09887
# [12]	validation_0-rmse:0.76320	validation_1-rmse:1.06768
# [13]	validation_0-rmse:0.75523	validation_1-rmse:1.05492
# [14]	validation_0-rmse:0.72488	validation_1-rmse:1.03857
# [15]	validation_0-rmse:0.70944	validation_1-rmse:1.06161
# [16]	validation_0-rmse:0.68249	validation_1-rmse:1.08567
# [17]	validation_0-rmse:0.65016	validation_1-rmse:1.04904
# [18]	validation_0-rmse:0.63195	validation_1-rmse:1.03000
# [19]	validation_0-rmse:0.61914	validation_1-rmse:1.02809
# [20]	validation_0-rmse:0.61492	validation_1-rmse:1.03699
# [21]	validation_0-rmse:0.60425	validation_1-rmse:1.04513
# [22]	validation_0-rmse:0.59056	validation_1-rmse:1.04670
# [23]	validation_0-rmse:0.57081	validation_1-rmse:1.05126
# [24]	validation_0-rmse:0.55830	validation_1-rmse:1.04685
# [25]	validation_0-rmse:0.54963	validation_1-rmse:1.04268
# [26]	validation_0-rmse:0.54323	validation_1-rmse:1.03903
# [27]	validation_0-rmse:0.53577	validation_1-rmse:1.07278
# [28]	validation_0-rmse:0.52577	validation_1-rmse:1.05985
# [29]	validation_0-rmse:0.52278	validation_1-rmse:1.06946
# [30]	validation_0-rmse:0.51454	validation_1-rmse:1.06168
# [31]	validation_0-rmse:0.50965	validation_1-rmse:1.06211
# [32]	validation_0-rmse:0.49856	validation_1-rmse:1.04580
# [33]	validation_0-rmse:0.49336	validation_1-rmse:1.04361
# [34]	validation_0-rmse:0.48982	validation_1-rmse:1.04643
# [35]	validation_0-rmse:0.48546	validation_1-rmse:1.04299
# [36]	validation_0-rmse:0.47513	validation_1-rmse:1.04533
# [37]	validation_0-rmse:0.47408	validation_1-rmse:1.07271
# [38]	validation_0-rmse:0.46669	validation_1-rmse:1.07155
# [0]	validation_0-rmse:5.00536	validation_1-rmse:4.68309
# [1]	validation_0-rmse:3.65019	validation_1-rmse:3.40569
# [2]	validation_0-rmse:2.72985	validation_1-rmse:2.56664
# [3]	validation_0-rmse:2.08667	validation_1-rmse:1.97648
# [4]	validation_0-rmse:1.67765	validation_1-rmse:1.58772
# [5]	validation_0-rmse:1.37734	validation_1-rmse:1.32069
# [6]	validation_0-rmse:1.15191	validation_1-rmse:1.17990
# [7]	validation_0-rmse:1.01361	validation_1-rmse:1.11477
# [8]	validation_0-rmse:0.90450	validation_1-rmse:1.07232
# [9]	validation_0-rmse:0.85709	validation_1-rmse:1.09157
# [10]	validation_0-rmse:0.81689	validation_1-rmse:1.10344
# [11]	validation_0-rmse:0.74489	validation_1-rmse:1.05215
# [12]	validation_0-rmse:0.71347	validation_1-rmse:1.07958
# [13]	validation_0-rmse:0.70400	validation_1-rmse:1.06897
# [14]	validation_0-rmse:0.67391	validation_1-rmse:1.03499
# [15]	validation_0-rmse:0.65488	validation_1-rmse:0.97520
# [16]	validation_0-rmse:0.64186	validation_1-rmse:0.96589
# [17]	validation_0-rmse:0.62333	validation_1-rmse:0.97094
# [18]	validation_0-rmse:0.61663	validation_1-rmse:0.94741
# [19]	validation_0-rmse:0.60817	validation_1-rmse:0.95627
# [20]	validation_0-rmse:0.60110	validation_1-rmse:0.95794
# [21]	validation_0-rmse:0.58463	validation_1-rmse:0.94521
# [22]	validation_0-rmse:0.57274	validation_1-rmse:0.96641
# [23]	validation_0-rmse:0.56386	validation_1-rmse:0.93856
# [24]	validation_0-rmse:0.54429	validation_1-rmse:0.92483
# [25]	validation_0-rmse:0.53586	validation_1-rmse:0.92472
# [26]	validation_0-rmse:0.53122	validation_1-rmse:0.92122
# [27]	validation_0-rmse:0.52852	validation_1-rmse:0.93242
# [28]	validation_0-rmse:0.50832	validation_1-rmse:0.91662
# [29]	validation_0-rmse:0.50406	validation_1-rmse:0.92391
# [30]	validation_0-rmse:0.49638	validation_1-rmse:0.92026
# [31]	validation_0-rmse:0.48279	validation_1-rmse:0.91942
# [32]	validation_0-rmse:0.48202	validation_1-rmse:0.92801
# [33]	validation_0-rmse:0.47041	validation_1-rmse:0.92035
# [34]	validation_0-rmse:0.46545	validation_1-rmse:0.91013
# [35]	validation_0-rmse:0.46146	validation_1-rmse:0.91647
# [36]	validation_0-rmse:0.45391	validation_1-rmse:0.92453
# [37]	validation_0-rmse:0.44194	validation_1-rmse:0.92457
# [38]	validation_0-rmse:0.44230	validation_1-rmse:0.92523
# [39]	validation_0-rmse:0.43722	validation_1-rmse:0.90704
# [40]	validation_0-rmse:0.42905	validation_1-rmse:0.89847
# [41]	validation_0-rmse:0.41632	validation_1-rmse:0.93218
# [42]	validation_0-rmse:0.40487	validation_1-rmse:0.94046
# [43]	validation_0-rmse:0.40464	validation_1-rmse:0.93929
# [44]	validation_0-rmse:0.40519	validation_1-rmse:0.92512
# [45]	validation_0-rmse:0.40059	validation_1-rmse:0.92059
# [46]	validation_0-rmse:0.39304	validation_1-rmse:0.92443
# [47]	validation_0-rmse:0.39361	validation_1-rmse:0.93147
# [48]	validation_0-rmse:0.38547	validation_1-rmse:0.93728
# [49]	validation_0-rmse:0.37918	validation_1-rmse:0.94253
# [50]	validation_0-rmse:0.37022	validation_1-rmse:0.94853
# [0]	validation_0-rmse:5.00916	validation_1-rmse:4.48837
# [1]	validation_0-rmse:3.68534	validation_1-rmse:3.19018
# [2]	validation_0-rmse:2.68775	validation_1-rmse:2.42271
# [3]	validation_0-rmse:2.07533	validation_1-rmse:1.89756
# [4]	validation_0-rmse:1.64218	validation_1-rmse:1.60185
# [5]	validation_0-rmse:1.32178	validation_1-rmse:1.41702
# [6]	validation_0-rmse:1.11025	validation_1-rmse:1.34102
# [7]	validation_0-rmse:0.96031	validation_1-rmse:1.32874
# [8]	validation_0-rmse:0.87406	validation_1-rmse:1.32159
# [9]	validation_0-rmse:0.82482	validation_1-rmse:1.34927
# [10]	validation_0-rmse:0.78402	validation_1-rmse:1.36950
# [11]	validation_0-rmse:0.75071	validation_1-rmse:1.37735
# [12]	validation_0-rmse:0.71648	validation_1-rmse:1.35217
# [13]	validation_0-rmse:0.70348	validation_1-rmse:1.35355
# [14]	validation_0-rmse:0.66844	validation_1-rmse:1.36105
# [15]	validation_0-rmse:0.64971	validation_1-rmse:1.33304
# [16]	validation_0-rmse:0.64481	validation_1-rmse:1.32859
# [17]	validation_0-rmse:0.63072	validation_1-rmse:1.36114
# [18]	validation_0-rmse:0.63163	validation_1-rmse:1.37471
# [19]	validation_0-rmse:0.62131	validation_1-rmse:1.34345
# [20]	validation_0-rmse:0.61326	validation_1-rmse:1.33322
# [21]	validation_0-rmse:0.60268	validation_1-rmse:1.33870
# [22]	validation_0-rmse:0.59189	validation_1-rmse:1.33858
# [23]	validation_0-rmse:0.58803	validation_1-rmse:1.34540
# [24]	validation_0-rmse:0.57236	validation_1-rmse:1.33556
# [25]	validation_0-rmse:0.57195	validation_1-rmse:1.32288
# [26]	validation_0-rmse:0.56293	validation_1-rmse:1.32716
# [27]	validation_0-rmse:0.55791	validation_1-rmse:1.35432
# [28]	validation_0-rmse:0.55324	validation_1-rmse:1.34673
# [0]	validation_0-rmse:4.90245	validation_1-rmse:4.97946
# [1]	validation_0-rmse:3.62157	validation_1-rmse:3.57082
# [2]	validation_0-rmse:2.66361	validation_1-rmse:2.62705
# [3]	validation_0-rmse:2.03982	validation_1-rmse:1.94862
# [4]	validation_0-rmse:1.61607	validation_1-rmse:1.54938
# [5]	validation_0-rmse:1.31071	validation_1-rmse:1.29551
# [6]	validation_0-rmse:1.11094	validation_1-rmse:1.16776
# [7]	validation_0-rmse:0.97739	validation_1-rmse:1.07639
# [8]	validation_0-rmse:0.90396	validation_1-rmse:1.04894
# [9]	validation_0-rmse:0.84241	validation_1-rmse:1.05282
# [10]	validation_0-rmse:0.83351	validation_1-rmse:1.04830
# [11]	validation_0-rmse:0.79571	validation_1-rmse:1.04974
# [12]	validation_0-rmse:0.75454	validation_1-rmse:1.03583
# [13]	validation_0-rmse:0.73919	validation_1-rmse:1.03451
# [14]	validation_0-rmse:0.70853	validation_1-rmse:1.00113
# [15]	validation_0-rmse:0.68501	validation_1-rmse:0.99659
# [16]	validation_0-rmse:0.67992	validation_1-rmse:0.99651
# [17]	validation_0-rmse:0.65707	validation_1-rmse:0.96671
# [18]	validation_0-rmse:0.62954	validation_1-rmse:0.97199
# [19]	validation_0-rmse:0.62547	validation_1-rmse:0.97581
# [20]	validation_0-rmse:0.60315	validation_1-rmse:0.95660
# [21]	validation_0-rmse:0.59772	validation_1-rmse:0.95735
# [22]	validation_0-rmse:0.58788	validation_1-rmse:0.96345
# [23]	validation_0-rmse:0.57788	validation_1-rmse:0.96287
# [24]	validation_0-rmse:0.55640	validation_1-rmse:0.97111
# [25]	validation_0-rmse:0.55424	validation_1-rmse:0.97138
# [26]	validation_0-rmse:0.55028	validation_1-rmse:0.96659
# [27]	validation_0-rmse:0.55195	validation_1-rmse:0.95491
# [28]	validation_0-rmse:0.54825	validation_1-rmse:0.94570
# [29]	validation_0-rmse:0.53901	validation_1-rmse:0.94522
# [30]	validation_0-rmse:0.52800	validation_1-rmse:0.94080
# [31]	validation_0-rmse:0.52019	validation_1-rmse:0.93071
# [32]	validation_0-rmse:0.50620	validation_1-rmse:0.92995
# [33]	validation_0-rmse:0.48992	validation_1-rmse:0.92743
# [34]	validation_0-rmse:0.47815	validation_1-rmse:0.92905
# [35]	validation_0-rmse:0.47190	validation_1-rmse:0.94619
# [36]	validation_0-rmse:0.45148	validation_1-rmse:0.93234
# [37]	validation_0-rmse:0.44358	validation_1-rmse:0.93630
# [38]	validation_0-rmse:0.43980	validation_1-rmse:0.92761
# [39]	validation_0-rmse:0.42893	validation_1-rmse:0.92769
# [40]	validation_0-rmse:0.42393	validation_1-rmse:0.90924
# [41]	validation_0-rmse:0.42059	validation_1-rmse:0.90907
# [42]	validation_0-rmse:0.41259	validation_1-rmse:0.90948
# [43]	validation_0-rmse:0.40834	validation_1-rmse:0.89974
# [44]	validation_0-rmse:0.40070	validation_1-rmse:0.90215
# [45]	validation_0-rmse:0.39623	validation_1-rmse:0.87910
# [46]	validation_0-rmse:0.38759	validation_1-rmse:0.87104
# [47]	validation_0-rmse:0.38821	validation_1-rmse:0.87785
# [48]	validation_0-rmse:0.38307	validation_1-rmse:0.87795
# [49]	validation_0-rmse:0.38213	validation_1-rmse:0.88010
# [50]	validation_0-rmse:0.37758	validation_1-rmse:0.87987
# [0]	validation_0-rmse:4.91619	validation_1-rmse:5.10490
# [1]	validation_0-rmse:3.67441	validation_1-rmse:3.88933
# [2]	validation_0-rmse:2.74064	validation_1-rmse:2.98848
# [3]	validation_0-rmse:2.11660	validation_1-rmse:2.35036
# [4]	validation_0-rmse:1.70861	validation_1-rmse:1.96262
# [5]	validation_0-rmse:1.42357	validation_1-rmse:1.68572
# [6]	validation_0-rmse:1.21677	validation_1-rmse:1.58168
# [7]	validation_0-rmse:1.07686	validation_1-rmse:1.43762
# [8]	validation_0-rmse:0.96136	validation_1-rmse:1.32669
# [9]	validation_0-rmse:0.88705	validation_1-rmse:1.29411
# [10]	validation_0-rmse:0.84102	validation_1-rmse:1.28974
# [11]	validation_0-rmse:0.80982	validation_1-rmse:1.25347
# [12]	validation_0-rmse:0.76084	validation_1-rmse:1.24720
# [13]	validation_0-rmse:0.73829	validation_1-rmse:1.21633
# [14]	validation_0-rmse:0.72375	validation_1-rmse:1.20845
# [15]	validation_0-rmse:0.70694	validation_1-rmse:1.18753
# [16]	validation_0-rmse:0.66506	validation_1-rmse:1.16914
# [17]	validation_0-rmse:0.65075	validation_1-rmse:1.16006
# [18]	validation_0-rmse:0.64788	validation_1-rmse:1.18240
# [19]	validation_0-rmse:0.62861	validation_1-rmse:1.17584
# [20]	validation_0-rmse:0.60822	validation_1-rmse:1.16598
# [21]	validation_0-rmse:0.59589	validation_1-rmse:1.17482
# [22]	validation_0-rmse:0.58056	validation_1-rmse:1.17350
# [23]	validation_0-rmse:0.57242	validation_1-rmse:1.20184
# [24]	validation_0-rmse:0.55020	validation_1-rmse:1.19547
# [25]	validation_0-rmse:0.53793	validation_1-rmse:1.19280
# [26]	validation_0-rmse:0.53130	validation_1-rmse:1.18682
# [27]	validation_0-rmse:0.52776	validation_1-rmse:1.19745
# [28]	validation_0-rmse:0.51693	validation_1-rmse:1.18985
# [29]	validation_0-rmse:0.50373	validation_1-rmse:1.17050
# [30]	validation_0-rmse:0.50192	validation_1-rmse:1.14396
# [31]	validation_0-rmse:0.49499	validation_1-rmse:1.13558
# [32]	validation_0-rmse:0.48216	validation_1-rmse:1.16564
# [33]	validation_0-rmse:0.47657	validation_1-rmse:1.15797
# [34]	validation_0-rmse:0.47069	validation_1-rmse:1.15744
# [35]	validation_0-rmse:0.46358	validation_1-rmse:1.15524
# [36]	validation_0-rmse:0.45594	validation_1-rmse:1.16104
# [37]	validation_0-rmse:0.44926	validation_1-rmse:1.16122
# [38]	validation_0-rmse:0.44828	validation_1-rmse:1.14965
# [39]	validation_0-rmse:0.44424	validation_1-rmse:1.15035
# [40]	validation_0-rmse:0.42834	validation_1-rmse:1.15609
# [41]	validation_0-rmse:0.42326	validation_1-rmse:1.15842
# [42]	validation_0-rmse:0.41894	validation_1-rmse:1.15484
# [43]	validation_0-rmse:0.41442	validation_1-rmse:1.15899
# [44]	validation_0-rmse:0.40445	validation_1-rmse:1.15911
# [45]	validation_0-rmse:0.40589	validation_1-rmse:1.16040
# [46]	validation_0-rmse:0.40062	validation_1-rmse:1.16192
# [47]	validation_0-rmse:0.39271	validation_1-rmse:1.16610
# [48]	validation_0-rmse:0.38958	validation_1-rmse:1.17248
# [49]	validation_0-rmse:0.38670	validation_1-rmse:1.17937
# [50]	validation_0-rmse:0.38009	validation_1-rmse:1.17654
# [0]	validation_0-rmse:4.92650	validation_1-rmse:4.85755
# [1]	validation_0-rmse:3.64297	validation_1-rmse:3.62213
# [2]	validation_0-rmse:2.66330	validation_1-rmse:2.85827
# [3]	validation_0-rmse:2.03124	validation_1-rmse:2.33350
# [4]	validation_0-rmse:1.57909	validation_1-rmse:2.01039
# [5]	validation_0-rmse:1.29828	validation_1-rmse:1.74677
# [6]	validation_0-rmse:1.08973	validation_1-rmse:1.57191
# [7]	validation_0-rmse:0.94391	validation_1-rmse:1.45031
# [8]	validation_0-rmse:0.85526	validation_1-rmse:1.37051
# [9]	validation_0-rmse:0.80682	validation_1-rmse:1.30286
# [10]	validation_0-rmse:0.75396	validation_1-rmse:1.27218
# [11]	validation_0-rmse:0.73910	validation_1-rmse:1.27526
# [12]	validation_0-rmse:0.70941	validation_1-rmse:1.24863
# [13]	validation_0-rmse:0.67384	validation_1-rmse:1.25874
# [14]	validation_0-rmse:0.65175	validation_1-rmse:1.25424
# [15]	validation_0-rmse:0.64154	validation_1-rmse:1.24663
# [16]	validation_0-rmse:0.62787	validation_1-rmse:1.24631
# [17]	validation_0-rmse:0.60684	validation_1-rmse:1.24765
# [18]	validation_0-rmse:0.59415	validation_1-rmse:1.25006
# [19]	validation_0-rmse:0.57720	validation_1-rmse:1.24054
# [20]	validation_0-rmse:0.57852	validation_1-rmse:1.25344
# [21]	validation_0-rmse:0.57682	validation_1-rmse:1.25097
# [22]	validation_0-rmse:0.55665	validation_1-rmse:1.25127
# [23]	validation_0-rmse:0.53062	validation_1-rmse:1.22178
# [24]	validation_0-rmse:0.51484	validation_1-rmse:1.19339
# [25]	validation_0-rmse:0.50452	validation_1-rmse:1.19368
# [26]	validation_0-rmse:0.48775	validation_1-rmse:1.17224
# [27]	validation_0-rmse:0.47100	validation_1-rmse:1.13742
# [28]	validation_0-rmse:0.45811	validation_1-rmse:1.13619
# [29]	validation_0-rmse:0.45287	validation_1-rmse:1.13793
# [30]	validation_0-rmse:0.45035	validation_1-rmse:1.13593
# [31]	validation_0-rmse:0.44374	validation_1-rmse:1.13262
# [32]	validation_0-rmse:0.44162	validation_1-rmse:1.13839
# [33]	validation_0-rmse:0.43488	validation_1-rmse:1.13454
# [34]	validation_0-rmse:0.42823	validation_1-rmse:1.13980
# [35]	validation_0-rmse:0.42461	validation_1-rmse:1.14265
# [36]	validation_0-rmse:0.41920	validation_1-rmse:1.13273
# [37]	validation_0-rmse:0.41367	validation_1-rmse:1.12984
# [38]	validation_0-rmse:0.41050	validation_1-rmse:1.13384
# [39]	validation_0-rmse:0.40318	validation_1-rmse:1.12131
# [40]	validation_0-rmse:0.40222	validation_1-rmse:1.12902
# [41]	validation_0-rmse:0.39445	validation_1-rmse:1.14769
# [42]	validation_0-rmse:0.38923	validation_1-rmse:1.15616
# [43]	validation_0-rmse:0.37915	validation_1-rmse:1.16757
# [44]	validation_0-rmse:0.37503	validation_1-rmse:1.16604
# [45]	validation_0-rmse:0.36285	validation_1-rmse:1.16397
# [46]	validation_0-rmse:0.35560	validation_1-rmse:1.16800
# [47]	validation_0-rmse:0.35009	validation_1-rmse:1.17168
# [48]	validation_0-rmse:0.34937	validation_1-rmse:1.17041
# [49]	validation_0-rmse:0.34518	validation_1-rmse:1.16665
# [50]	validation_0-rmse:0.34228	validation_1-rmse:1.16721
# [0]	validation_0-rmse:4.87592	validation_1-rmse:4.44425
# [1]	validation_0-rmse:3.61788	validation_1-rmse:3.19896
# [2]	validation_0-rmse:2.66115	validation_1-rmse:2.31318
# [3]	validation_0-rmse:2.01812	validation_1-rmse:1.76485
# [4]	validation_0-rmse:1.63188	validation_1-rmse:1.39282
# [5]	validation_0-rmse:1.32413	validation_1-rmse:1.11290
# [6]	validation_0-rmse:1.10195	validation_1-rmse:0.94562
# [7]	validation_0-rmse:0.98019	validation_1-rmse:0.89041
# [8]	validation_0-rmse:0.90477	validation_1-rmse:0.85425
# [9]	validation_0-rmse:0.85734	validation_1-rmse:0.84890
# [10]	validation_0-rmse:0.83124	validation_1-rmse:0.82591
# [11]	validation_0-rmse:0.80663	validation_1-rmse:0.82039
# [12]	validation_0-rmse:0.78736	validation_1-rmse:0.83730
# [13]	validation_0-rmse:0.77439	validation_1-rmse:0.82426
# [14]	validation_0-rmse:0.75005	validation_1-rmse:0.84118
# [15]	validation_0-rmse:0.73538	validation_1-rmse:0.82162
# [16]	validation_0-rmse:0.72947	validation_1-rmse:0.81580
# [17]	validation_0-rmse:0.71055	validation_1-rmse:0.78734
# [18]	validation_0-rmse:0.69421	validation_1-rmse:0.77156
# [19]	validation_0-rmse:0.68276	validation_1-rmse:0.76222
# [20]	validation_0-rmse:0.67888	validation_1-rmse:0.74073
# [21]	validation_0-rmse:0.65943	validation_1-rmse:0.73364
# [22]	validation_0-rmse:0.65033	validation_1-rmse:0.71419
# [23]	validation_0-rmse:0.63610	validation_1-rmse:0.70672
# [24]	validation_0-rmse:0.62575	validation_1-rmse:0.69662
# [25]	validation_0-rmse:0.61769	validation_1-rmse:0.70202
# [26]	validation_0-rmse:0.61003	validation_1-rmse:0.68499
# [27]	validation_0-rmse:0.60242	validation_1-rmse:0.67769
# [28]	validation_0-rmse:0.59606	validation_1-rmse:0.67342
# [29]	validation_0-rmse:0.58615	validation_1-rmse:0.68166
# [30]	validation_0-rmse:0.58172	validation_1-rmse:0.68088
# [31]	validation_0-rmse:0.58411	validation_1-rmse:0.68492
# [32]	validation_0-rmse:0.58058	validation_1-rmse:0.66862
# [33]	validation_0-rmse:0.56695	validation_1-rmse:0.68863
# [34]	validation_0-rmse:0.56077	validation_1-rmse:0.70364
# [35]	validation_0-rmse:0.55826	validation_1-rmse:0.69748
# [36]	validation_0-rmse:0.53913	validation_1-rmse:0.71840
# [37]	validation_0-rmse:0.53314	validation_1-rmse:0.70781
# [38]	validation_0-rmse:0.52898	validation_1-rmse:0.68785
# [39]	validation_0-rmse:0.53171	validation_1-rmse:0.69533
# [40]	validation_0-rmse:0.52542	validation_1-rmse:0.69853
# [41]	validation_0-rmse:0.52262	validation_1-rmse:0.68668
# [42]	validation_0-rmse:0.50822	validation_1-rmse:0.71110
# [43]	validation_0-rmse:0.49726	validation_1-rmse:0.74248
# [44]	validation_0-rmse:0.49283	validation_1-rmse:0.74627
# [45]	validation_0-rmse:0.48914	validation_1-rmse:0.75528
# [46]	validation_0-rmse:0.48236	validation_1-rmse:0.78323
# [47]	validation_0-rmse:0.47936	validation_1-rmse:0.77169
# [48]	validation_0-rmse:0.47585	validation_1-rmse:0.78824
# [49]	validation_0-rmse:0.47356	validation_1-rmse:0.83636
# [50]	validation_0-rmse:0.47145	validation_1-rmse:0.82420
# [0]	validation_0-rmse:4.94643	validation_1-rmse:4.50827
# [1]	validation_0-rmse:3.62710	validation_1-rmse:3.26310
# [2]	validation_0-rmse:2.67533	validation_1-rmse:2.45460
# [3]	validation_0-rmse:2.01194	validation_1-rmse:1.83888
# [4]	validation_0-rmse:1.58938	validation_1-rmse:1.49710
# [5]	validation_0-rmse:1.29936	validation_1-rmse:1.36370
# [6]	validation_0-rmse:1.10274	validation_1-rmse:1.23166
# [7]	validation_0-rmse:0.96599	validation_1-rmse:1.23502
# [8]	validation_0-rmse:0.87307	validation_1-rmse:1.20092
# [9]	validation_0-rmse:0.83113	validation_1-rmse:1.21653
# [10]	validation_0-rmse:0.81326	validation_1-rmse:1.18858
# [11]	validation_0-rmse:0.74088	validation_1-rmse:1.21191
# [12]	validation_0-rmse:0.71636	validation_1-rmse:1.20459
# [13]	validation_0-rmse:0.69952	validation_1-rmse:1.22355
# [14]	validation_0-rmse:0.68918	validation_1-rmse:1.19498
# [15]	validation_0-rmse:0.66468	validation_1-rmse:1.20716
# [16]	validation_0-rmse:0.64373	validation_1-rmse:1.21846
# [17]	validation_0-rmse:0.62230	validation_1-rmse:1.17895
# [18]	validation_0-rmse:0.61484	validation_1-rmse:1.14937
# [19]	validation_0-rmse:0.60968	validation_1-rmse:1.13143
# [20]	validation_0-rmse:0.57942	validation_1-rmse:1.18564
# [21]	validation_0-rmse:0.57183	validation_1-rmse:1.19453
# [22]	validation_0-rmse:0.55300	validation_1-rmse:1.18212
# [23]	validation_0-rmse:0.54083	validation_1-rmse:1.20220
# [24]	validation_0-rmse:0.53041	validation_1-rmse:1.22466
# [25]	validation_0-rmse:0.51506	validation_1-rmse:1.21585
# [26]	validation_0-rmse:0.51084	validation_1-rmse:1.20093
# [27]	validation_0-rmse:0.51081	validation_1-rmse:1.19190
# [28]	validation_0-rmse:0.49357	validation_1-rmse:1.23482
# [29]	validation_0-rmse:0.48740	validation_1-rmse:1.22937
# [30]	validation_0-rmse:0.47426	validation_1-rmse:1.24767
# [31]	validation_0-rmse:0.46612	validation_1-rmse:1.25499
# [32]	validation_0-rmse:0.46054	validation_1-rmse:1.25745
# [33]	validation_0-rmse:0.45226	validation_1-rmse:1.22918
# [34]	validation_0-rmse:0.44985	validation_1-rmse:1.23725
# [35]	validation_0-rmse:0.44183	validation_1-rmse:1.23574
# [36]	validation_0-rmse:0.43582	validation_1-rmse:1.23217
# [37]	validation_0-rmse:0.43266	validation_1-rmse:1.23179
# [38]	validation_0-rmse:0.42607	validation_1-rmse:1.24282
# [39]	validation_0-rmse:0.41531	validation_1-rmse:1.25038
# [0]	validation_0-rmse:4.90853	validation_1-rmse:5.01108
# [1]	validation_0-rmse:3.58675	validation_1-rmse:3.68511
# [2]	validation_0-rmse:2.63235	validation_1-rmse:2.75965
# [3]	validation_0-rmse:2.02646	validation_1-rmse:2.10934
# [4]	validation_0-rmse:1.61603	validation_1-rmse:1.69104
# [5]	validation_0-rmse:1.28469	validation_1-rmse:1.39438
# [6]	validation_0-rmse:1.07862	validation_1-rmse:1.22927
# [7]	validation_0-rmse:0.96333	validation_1-rmse:1.15605
# [8]	validation_0-rmse:0.88291	validation_1-rmse:1.14052
# [9]	validation_0-rmse:0.84410	validation_1-rmse:1.12534
# [10]	validation_0-rmse:0.82823	validation_1-rmse:1.10974
# [11]	validation_0-rmse:0.77770	validation_1-rmse:1.08995
# [12]	validation_0-rmse:0.75916	validation_1-rmse:1.10471
# [13]	validation_0-rmse:0.75923	validation_1-rmse:1.09168
# [14]	validation_0-rmse:0.71847	validation_1-rmse:1.07947
# [15]	validation_0-rmse:0.67409	validation_1-rmse:1.08339
# [16]	validation_0-rmse:0.66362	validation_1-rmse:1.07090
# [17]	validation_0-rmse:0.64993	validation_1-rmse:1.07555
# [18]	validation_0-rmse:0.63971	validation_1-rmse:1.09038
# [19]	validation_0-rmse:0.63863	validation_1-rmse:1.08547
# [20]	validation_0-rmse:0.61789	validation_1-rmse:1.11187
# [21]	validation_0-rmse:0.60165	validation_1-rmse:1.09885
# [22]	validation_0-rmse:0.58583	validation_1-rmse:1.10666
# [23]	validation_0-rmse:0.57966	validation_1-rmse:1.10373
# [24]	validation_0-rmse:0.55868	validation_1-rmse:1.12760
# [25]	validation_0-rmse:0.54827	validation_1-rmse:1.14901
# [26]	validation_0-rmse:0.52464	validation_1-rmse:1.15046
# [27]	validation_0-rmse:0.51837	validation_1-rmse:1.14099
# [28]	validation_0-rmse:0.51322	validation_1-rmse:1.13750
# [29]	validation_0-rmse:0.50850	validation_1-rmse:1.15306
# [30]	validation_0-rmse:0.50493	validation_1-rmse:1.14358
# [31]	validation_0-rmse:0.49883	validation_1-rmse:1.15071
# [32]	validation_0-rmse:0.48864	validation_1-rmse:1.15884
# [33]	validation_0-rmse:0.48491	validation_1-rmse:1.16525
# [34]	validation_0-rmse:0.47649	validation_1-rmse:1.19327
# [35]	validation_0-rmse:0.46592	validation_1-rmse:1.18999
# [36]	validation_0-rmse:0.45544	validation_1-rmse:1.19910
# [0]	validation_0-rmse:4.93664	validation_1-rmse:4.85504
# [1]	validation_0-rmse:3.61080	validation_1-rmse:3.60859
# [2]	validation_0-rmse:2.66811	validation_1-rmse:2.53473
# [3]	validation_0-rmse:2.07561	validation_1-rmse:2.08666
# [4]	validation_0-rmse:1.61171	validation_1-rmse:1.72336
# [5]	validation_0-rmse:1.35240	validation_1-rmse:1.49462
# [6]	validation_0-rmse:1.13900	validation_1-rmse:1.27764
# [7]	validation_0-rmse:1.00302	validation_1-rmse:1.16240
# [8]	validation_0-rmse:0.91724	validation_1-rmse:1.11500
# [9]	validation_0-rmse:0.84169	validation_1-rmse:1.11656
# [10]	validation_0-rmse:0.80021	validation_1-rmse:1.11488
# [11]	validation_0-rmse:0.77081	validation_1-rmse:1.08697
# [12]	validation_0-rmse:0.73334	validation_1-rmse:1.10366
# [13]	validation_0-rmse:0.72614	validation_1-rmse:1.10767
# [14]	validation_0-rmse:0.71877	validation_1-rmse:1.11405
# [15]	validation_0-rmse:0.68969	validation_1-rmse:1.07709
# [16]	validation_0-rmse:0.66457	validation_1-rmse:1.03356
# [17]	validation_0-rmse:0.64561	validation_1-rmse:1.01905
# [18]	validation_0-rmse:0.63749	validation_1-rmse:0.99276
# [19]	validation_0-rmse:0.62189	validation_1-rmse:0.96068
# [20]	validation_0-rmse:0.61391	validation_1-rmse:0.94704
# [21]	validation_0-rmse:0.61488	validation_1-rmse:0.93313
# [22]	validation_0-rmse:0.60193	validation_1-rmse:0.91233
# [23]	validation_0-rmse:0.59219	validation_1-rmse:0.94202
# [24]	validation_0-rmse:0.58051	validation_1-rmse:0.94213
# [25]	validation_0-rmse:0.57186	validation_1-rmse:0.96253
# [26]	validation_0-rmse:0.56387	validation_1-rmse:0.96478
# [27]	validation_0-rmse:0.56322	validation_1-rmse:0.94338
# [28]	validation_0-rmse:0.54365	validation_1-rmse:0.95414
# [29]	validation_0-rmse:0.54197	validation_1-rmse:0.95656
# [30]	validation_0-rmse:0.52994	validation_1-rmse:0.95913
# [31]	validation_0-rmse:0.51671	validation_1-rmse:0.94497
# [32]	validation_0-rmse:0.50352	validation_1-rmse:0.96166
# [33]	validation_0-rmse:0.49539	validation_1-rmse:0.96733
# [34]	validation_0-rmse:0.48886	validation_1-rmse:0.97449
# [35]	validation_0-rmse:0.48212	validation_1-rmse:0.96385
# [36]	validation_0-rmse:0.47503	validation_1-rmse:0.97318
# [37]	validation_0-rmse:0.47007	validation_1-rmse:0.95823
# [38]	validation_0-rmse:0.46272	validation_1-rmse:0.97154
# [39]	validation_0-rmse:0.44287	validation_1-rmse:0.96747
# [40]	validation_0-rmse:0.43503	validation_1-rmse:0.96695
# [41]	validation_0-rmse:0.42325	validation_1-rmse:0.96060
# [42]	validation_0-rmse:0.41700	validation_1-rmse:0.95159
# [0]	validation_0-rmse:4.89915	validation_1-rmse:5.01234
# [1]	validation_0-rmse:3.58385	validation_1-rmse:3.71345
# [2]	validation_0-rmse:2.69478	validation_1-rmse:2.83561
# [3]	validation_0-rmse:2.06357	validation_1-rmse:2.19901
# [4]	validation_0-rmse:1.71152	validation_1-rmse:1.83683
# [5]	validation_0-rmse:1.38377	validation_1-rmse:1.54286
# [6]	validation_0-rmse:1.16614	validation_1-rmse:1.26789
# [7]	validation_0-rmse:1.04280	validation_1-rmse:1.10725
# [8]	validation_0-rmse:0.95718	validation_1-rmse:1.01445
# [9]	validation_0-rmse:0.89951	validation_1-rmse:0.99654
# [10]	validation_0-rmse:0.85796	validation_1-rmse:0.97842
# [11]	validation_0-rmse:0.81423	validation_1-rmse:0.95064
# [12]	validation_0-rmse:0.78723	validation_1-rmse:0.91863
# [13]	validation_0-rmse:0.75781	validation_1-rmse:0.92265
# [14]	validation_0-rmse:0.73662	validation_1-rmse:0.90679
# [15]	validation_0-rmse:0.72054	validation_1-rmse:0.87784
# [16]	validation_0-rmse:0.71088	validation_1-rmse:0.89218
# [17]	validation_0-rmse:0.68330	validation_1-rmse:0.85261
# [18]	validation_0-rmse:0.67484	validation_1-rmse:0.84912
# [19]	validation_0-rmse:0.66223	validation_1-rmse:0.81332
# [20]	validation_0-rmse:0.64103	validation_1-rmse:0.84702
# [21]	validation_0-rmse:0.62956	validation_1-rmse:0.85543
# [22]	validation_0-rmse:0.61253	validation_1-rmse:0.86651
# [23]	validation_0-rmse:0.59823	validation_1-rmse:0.85418
# ...
# [23]	validation_0-rmse:0.57128	validation_1-rmse:0.96671
# [24]	validation_0-rmse:0.56444	validation_1-rmse:0.95508
# [25]	validation_0-rmse:0.55804	validation_1-rmse:0.95393
# [26]	validation_0-rmse:0.55635	validation_1-rmse:0.95618
# [27]	validation_0-rmse:0.55228	validation_1-rmse:0.96527
# [28]	validation_0-rmse:0.54339	validation_1-rmse:0.95223
# [29]	validation_0-rmse:0.53272	validation_1-rmse:0.93250
# [30]	validation_0-rmse:0.52978	validation_1-rmse:0.94442
# [31]	validation_0-rmse:0.51381	validation_1-rmse:0.94465
# [32]	validation_0-rmse:0.50632	validation_1-rmse:0.93751
# [33]	validation_0-rmse:0.49101	validation_1-rmse:0.94378
# [34]	validation_0-rmse:0.48236	validation_1-rmse:0.96343
# [35]	validation_0-rmse:0.47749	validation_1-rmse:0.96368
# [36]	validation_0-rmse:0.45942	validation_1-rmse:0.97323
# [37]	validation_0-rmse:0.45252	validation_1-rmse:0.96036
# [38]	validation_0-rmse:0.44762	validation_1-rmse:0.95895
# [39]	validation_0-rmse:0.43828	validation_1-rmse:0.96396
# [40]	validation_0-rmse:0.42821	validation_1-rmse:0.96236
# [41]	validation_0-rmse:0.42276	validation_1-rmse:0.95881
# [42]	validation_0-rmse:0.41957	validation_1-rmse:0.94916
# [43]	validation_0-rmse:0.41155	validation_1-rmse:0.94841
# [44]	validation_0-rmse:0.40925	validation_1-rmse:0.94685
# [45]	validation_0-rmse:0.40842	validation_1-rmse:0.95357
# [46]	validation_0-rmse:0.40328	validation_1-rmse:0.96177
# [47]	validation_0-rmse:0.39755	validation_1-rmse:0.96196
# [48]	validation_0-rmse:0.39045	validation_1-rmse:0.96453
# [0]	validation_0-rmse:4.88237	validation_1-rmse:4.82732
# [1]	validation_0-rmse:3.57572	validation_1-rmse:3.45671
# [2]	validation_0-rmse:2.63588	validation_1-rmse:2.53596
# [3]	validation_0-rmse:2.01233	validation_1-rmse:1.88650
# [4]	validation_0-rmse:1.62018	validation_1-rmse:1.50003
# [5]	validation_0-rmse:1.29931	validation_1-rmse:1.26250
# [6]	validation_0-rmse:1.08414	validation_1-rmse:1.11956
# [7]	validation_0-rmse:0.94837	validation_1-rmse:1.04349
# [8]	validation_0-rmse:0.86840	validation_1-rmse:1.01061
# [9]	validation_0-rmse:0.83344	validation_1-rmse:0.98441
# [10]	validation_0-rmse:0.79738	validation_1-rmse:0.99135
# [11]	validation_0-rmse:0.76750	validation_1-rmse:0.98916
# [12]	validation_0-rmse:0.74143	validation_1-rmse:0.97703
# [13]	validation_0-rmse:0.70689	validation_1-rmse:0.99722
# [14]	validation_0-rmse:0.67249	validation_1-rmse:0.97027
# [15]	validation_0-rmse:0.66196	validation_1-rmse:0.96564
# [16]	validation_0-rmse:0.65185	validation_1-rmse:0.97695
# [17]	validation_0-rmse:0.63390	validation_1-rmse:0.98010
# [18]	validation_0-rmse:0.60396	validation_1-rmse:0.96863
# [19]	validation_0-rmse:0.59177	validation_1-rmse:0.97447
# [20]	validation_0-rmse:0.56270	validation_1-rmse:0.98079
# [21]	validation_0-rmse:0.55607	validation_1-rmse:0.97971
# [22]	validation_0-rmse:0.54223	validation_1-rmse:0.99697
# [23]	validation_0-rmse:0.51376	validation_1-rmse:1.01660
# [24]	validation_0-rmse:0.49544	validation_1-rmse:1.02445
# [25]	validation_0-rmse:0.48339	validation_1-rmse:1.01963
# [26]	validation_0-rmse:0.47234	validation_1-rmse:1.03169
# [27]	validation_0-rmse:0.46244	validation_1-rmse:1.02689
# [28]	validation_0-rmse:0.45125	validation_1-rmse:1.02032
# [29]	validation_0-rmse:0.44508	validation_1-rmse:1.02182
# [30]	validation_0-rmse:0.44291	validation_1-rmse:1.01982
# [31]	validation_0-rmse:0.44125	validation_1-rmse:0.99717
# [32]	validation_0-rmse:0.43002	validation_1-rmse:1.00084
# [33]	validation_0-rmse:0.42632	validation_1-rmse:0.98746
# [34]	validation_0-rmse:0.41895	validation_1-rmse:0.99014
# [0]	validation_0-rmse:4.82192	validation_1-rmse:5.24430
# [1]	validation_0-rmse:3.53314	validation_1-rmse:3.93296
# [2]	validation_0-rmse:2.63028	validation_1-rmse:2.88344
# [3]	validation_0-rmse:1.98834	validation_1-rmse:2.17103
# [4]	validation_0-rmse:1.58746	validation_1-rmse:1.76321
# [5]	validation_0-rmse:1.27138	validation_1-rmse:1.50677
# [6]	validation_0-rmse:1.07585	validation_1-rmse:1.23604
# [7]	validation_0-rmse:0.96587	validation_1-rmse:1.10746
# [8]	validation_0-rmse:0.89646	validation_1-rmse:1.03947
# [9]	validation_0-rmse:0.80390	validation_1-rmse:0.99463
# [10]	validation_0-rmse:0.76821	validation_1-rmse:0.98576
# [11]	validation_0-rmse:0.73206	validation_1-rmse:0.99750
# [12]	validation_0-rmse:0.69854	validation_1-rmse:1.03294
# [13]	validation_0-rmse:0.66373	validation_1-rmse:1.03262
# [14]	validation_0-rmse:0.65342	validation_1-rmse:1.05902
# [15]	validation_0-rmse:0.62105	validation_1-rmse:1.06737
# [16]	validation_0-rmse:0.59919	validation_1-rmse:1.07054
# [17]	validation_0-rmse:0.59542	validation_1-rmse:1.04376
# [18]	validation_0-rmse:0.58142	validation_1-rmse:1.02879
# [19]	validation_0-rmse:0.57011	validation_1-rmse:1.02999
# [20]	validation_0-rmse:0.55546	validation_1-rmse:1.04862
# [21]	validation_0-rmse:0.55067	validation_1-rmse:1.04835
# [22]	validation_0-rmse:0.53016	validation_1-rmse:1.03382
# [23]	validation_0-rmse:0.51820	validation_1-rmse:1.06301
# [24]	validation_0-rmse:0.50817	validation_1-rmse:1.05553
# [25]	validation_0-rmse:0.50013	validation_1-rmse:1.03525
# [26]	validation_0-rmse:0.49413	validation_1-rmse:1.02265
# [27]	validation_0-rmse:0.47707	validation_1-rmse:1.01680
# [28]	validation_0-rmse:0.47148	validation_1-rmse:1.02372
# [29]	validation_0-rmse:0.46307	validation_1-rmse:1.00081
# [0]	validation_0-rmse:4.86895	validation_1-rmse:5.31127
# [1]	validation_0-rmse:3.56310	validation_1-rmse:3.85894
# [2]	validation_0-rmse:2.62170	validation_1-rmse:2.80637
# [3]	validation_0-rmse:2.03001	validation_1-rmse:2.12158
# [4]	validation_0-rmse:1.61366	validation_1-rmse:1.80719
# [5]	validation_0-rmse:1.34259	validation_1-rmse:1.70885
# [6]	validation_0-rmse:1.13466	validation_1-rmse:1.44657
# [7]	validation_0-rmse:1.01104	validation_1-rmse:1.30783
# [8]	validation_0-rmse:0.93136	validation_1-rmse:1.21237
# [9]	validation_0-rmse:0.83371	validation_1-rmse:1.20367
# [10]	validation_0-rmse:0.78566	validation_1-rmse:1.17878
# [11]	validation_0-rmse:0.75591	validation_1-rmse:1.15976
# [12]	validation_0-rmse:0.73784	validation_1-rmse:1.18865
# [13]	validation_0-rmse:0.71937	validation_1-rmse:1.18222
# [14]	validation_0-rmse:0.69676	validation_1-rmse:1.18748
# [15]	validation_0-rmse:0.67391	validation_1-rmse:1.15073
# [16]	validation_0-rmse:0.66810	validation_1-rmse:1.14159
# [17]	validation_0-rmse:0.64555	validation_1-rmse:1.09707
# [18]	validation_0-rmse:0.63972	validation_1-rmse:1.10852
# [19]	validation_0-rmse:0.62543	validation_1-rmse:1.10306
# [20]	validation_0-rmse:0.62221	validation_1-rmse:1.08520
# [21]	validation_0-rmse:0.59705	validation_1-rmse:1.06393
# [22]	validation_0-rmse:0.58023	validation_1-rmse:1.08835
# [23]	validation_0-rmse:0.57248	validation_1-rmse:1.09760
# [24]	validation_0-rmse:0.55357	validation_1-rmse:1.09303
# [25]	validation_0-rmse:0.53677	validation_1-rmse:1.08562
# [26]	validation_0-rmse:0.52897	validation_1-rmse:1.07456
# [27]	validation_0-rmse:0.51843	validation_1-rmse:1.08608
# [28]	validation_0-rmse:0.50802	validation_1-rmse:1.09734
# [29]	validation_0-rmse:0.50490	validation_1-rmse:1.12013
# [30]	validation_0-rmse:0.49412	validation_1-rmse:1.10980
# [31]	validation_0-rmse:0.48833	validation_1-rmse:1.10296
# [32]	validation_0-rmse:0.48461	validation_1-rmse:1.11560
# [33]	validation_0-rmse:0.47361	validation_1-rmse:1.12559
# [34]	validation_0-rmse:0.46436	validation_1-rmse:1.12988
# [35]	validation_0-rmse:0.45431	validation_1-rmse:1.12482
# [36]	validation_0-rmse:0.44894	validation_1-rmse:1.13634
# [37]	validation_0-rmse:0.44391	validation_1-rmse:1.13981
# [38]	validation_0-rmse:0.43761	validation_1-rmse:1.14175
# [39]	validation_0-rmse:0.42466	validation_1-rmse:1.14011
# [40]	validation_0-rmse:0.41590	validation_1-rmse:1.13181
# [41]	validation_0-rmse:0.41622	validation_1-rmse:1.13018
# [0]	validation_0-rmse:4.93296	validation_1-rmse:4.68976
# [1]	validation_0-rmse:3.58821	validation_1-rmse:3.38937
# [2]	validation_0-rmse:2.66904	validation_1-rmse:2.55742
# [3]	validation_0-rmse:2.11674	validation_1-rmse:2.06935
# [4]	validation_0-rmse:1.71628	validation_1-rmse:1.70140
# [5]	validation_0-rmse:1.36548	validation_1-rmse:1.46417
# [6]	validation_0-rmse:1.10385	validation_1-rmse:1.29229
# [7]	validation_0-rmse:0.94753	validation_1-rmse:1.17735
# [8]	validation_0-rmse:0.84011	validation_1-rmse:1.11487
# [9]	validation_0-rmse:0.77150	validation_1-rmse:1.09650
# [10]	validation_0-rmse:0.73965	validation_1-rmse:1.10267
# [11]	validation_0-rmse:0.69609	validation_1-rmse:1.04412
# [12]	validation_0-rmse:0.68144	validation_1-rmse:1.05971
# [13]	validation_0-rmse:0.66559	validation_1-rmse:1.06602
# [14]	validation_0-rmse:0.65277	validation_1-rmse:1.07680
# [15]	validation_0-rmse:0.64094	validation_1-rmse:1.10930
# [16]	validation_0-rmse:0.61040	validation_1-rmse:1.12633
# [17]	validation_0-rmse:0.58432	validation_1-rmse:1.14193
# [18]	validation_0-rmse:0.56602	validation_1-rmse:1.14243
# [19]	validation_0-rmse:0.56695	validation_1-rmse:1.14794
# [20]	validation_0-rmse:0.56116	validation_1-rmse:1.15044
# [21]	validation_0-rmse:0.55101	validation_1-rmse:1.17297
# [22]	validation_0-rmse:0.55067	validation_1-rmse:1.16791
# [23]	validation_0-rmse:0.54349	validation_1-rmse:1.19069
# [24]	validation_0-rmse:0.52316	validation_1-rmse:1.15737
# [25]	validation_0-rmse:0.51559	validation_1-rmse:1.15557
# [26]	validation_0-rmse:0.51152	validation_1-rmse:1.14567
# [27]	validation_0-rmse:0.50772	validation_1-rmse:1.12967
# [28]	validation_0-rmse:0.48843	validation_1-rmse:1.15327
# [29]	validation_0-rmse:0.47399	validation_1-rmse:1.15837
# [30]	validation_0-rmse:0.47406	validation_1-rmse:1.14540
# [0]	validation_0-rmse:4.91419	validation_1-rmse:4.64241
# [1]	validation_0-rmse:3.58187	validation_1-rmse:3.39188
# [2]	validation_0-rmse:2.69522	validation_1-rmse:2.56794
# [3]	validation_0-rmse:2.06144	validation_1-rmse:2.01375
# [4]	validation_0-rmse:1.60320	validation_1-rmse:1.60043
# [5]	validation_0-rmse:1.25727	validation_1-rmse:1.36993
# [6]	validation_0-rmse:1.05985	validation_1-rmse:1.21681
# [7]	validation_0-rmse:0.94998	validation_1-rmse:1.10245
# [8]	validation_0-rmse:0.88291	validation_1-rmse:1.04545
# [9]	validation_0-rmse:0.82225	validation_1-rmse:1.01407
# [10]	validation_0-rmse:0.80454	validation_1-rmse:0.99883
# [11]	validation_0-rmse:0.74579	validation_1-rmse:0.98843
# [12]	validation_0-rmse:0.72649	validation_1-rmse:0.99213
# [13]	validation_0-rmse:0.71452	validation_1-rmse:0.98054
# [14]	validation_0-rmse:0.69906	validation_1-rmse:0.97642
# [15]	validation_0-rmse:0.68896	validation_1-rmse:0.95918
# [16]	validation_0-rmse:0.67492	validation_1-rmse:0.92420
# [17]	validation_0-rmse:0.66726	validation_1-rmse:0.94297
# [18]	validation_0-rmse:0.63302	validation_1-rmse:0.96875
# [19]	validation_0-rmse:0.61395	validation_1-rmse:0.98812
# [20]	validation_0-rmse:0.58415	validation_1-rmse:0.97728
# [21]	validation_0-rmse:0.56520	validation_1-rmse:0.96119
# [22]	validation_0-rmse:0.56522	validation_1-rmse:0.96310
# [23]	validation_0-rmse:0.54650	validation_1-rmse:0.95901
# [24]	validation_0-rmse:0.53822	validation_1-rmse:0.96310
# [25]	validation_0-rmse:0.52942	validation_1-rmse:0.99632
# [26]	validation_0-rmse:0.52366	validation_1-rmse:0.98543
# [27]	validation_0-rmse:0.51898	validation_1-rmse:0.98537
# [28]	validation_0-rmse:0.50720	validation_1-rmse:1.01417
# [29]	validation_0-rmse:0.49932	validation_1-rmse:1.02113
# [30]	validation_0-rmse:0.49095	validation_1-rmse:1.01485
# [31]	validation_0-rmse:0.48240	validation_1-rmse:1.04175
# [32]	validation_0-rmse:0.48045	validation_1-rmse:1.05649
# [33]	validation_0-rmse:0.47102	validation_1-rmse:1.07352
# [34]	validation_0-rmse:0.45147	validation_1-rmse:1.07918
# [35]	validation_0-rmse:0.44372	validation_1-rmse:1.07792
# [36]	validation_0-rmse:0.43333	validation_1-rmse:1.07499
# [0]	validation_0-rmse:4.88084	validation_1-rmse:4.75081
# [1]	validation_0-rmse:3.55348	validation_1-rmse:3.47003
# [2]	validation_0-rmse:2.65675	validation_1-rmse:2.67523
# [3]	validation_0-rmse:2.05072	validation_1-rmse:2.04409
# [4]	validation_0-rmse:1.60989	validation_1-rmse:1.67777
# [5]	validation_0-rmse:1.35081	validation_1-rmse:1.49742
# [6]	validation_0-rmse:1.14963	validation_1-rmse:1.32270
# [7]	validation_0-rmse:1.02997	validation_1-rmse:1.24327
# [8]	validation_0-rmse:0.97391	validation_1-rmse:1.13678
# [9]	validation_0-rmse:0.93266	validation_1-rmse:1.13301
# [10]	validation_0-rmse:0.89622	validation_1-rmse:1.10464
# [11]	validation_0-rmse:0.87492	validation_1-rmse:1.08303
# [12]	validation_0-rmse:0.82876	validation_1-rmse:1.03315
# [13]	validation_0-rmse:0.81513	validation_1-rmse:1.02264
# [14]	validation_0-rmse:0.80408	validation_1-rmse:1.02505
# [15]	validation_0-rmse:0.78274	validation_1-rmse:1.03833
# [16]	validation_0-rmse:0.74925	validation_1-rmse:0.97671
# [17]	validation_0-rmse:0.72655	validation_1-rmse:0.97279
# [18]	validation_0-rmse:0.71688	validation_1-rmse:0.96381
# [19]	validation_0-rmse:0.71586	validation_1-rmse:0.97422
# [20]	validation_0-rmse:0.70908	validation_1-rmse:0.95527
# [21]	validation_0-rmse:0.70434	validation_1-rmse:0.96219
# [22]	validation_0-rmse:0.70060	validation_1-rmse:0.99075
# [23]	validation_0-rmse:0.69388	validation_1-rmse:0.99026
# [24]	validation_0-rmse:0.69435	validation_1-rmse:0.97781
# [25]	validation_0-rmse:0.67904	validation_1-rmse:0.97269
# [26]	validation_0-rmse:0.66583	validation_1-rmse:0.95610
# [27]	validation_0-rmse:0.65545	validation_1-rmse:0.95173
# [28]	validation_0-rmse:0.64384	validation_1-rmse:0.92726
# [29]	validation_0-rmse:0.63204	validation_1-rmse:0.93062
# [30]	validation_0-rmse:0.62391	validation_1-rmse:0.91088
# [31]	validation_0-rmse:0.61063	validation_1-rmse:0.90681
# [32]	validation_0-rmse:0.59650	validation_1-rmse:0.92134
# [33]	validation_0-rmse:0.59397	validation_1-rmse:0.93828
# [34]	validation_0-rmse:0.58992	validation_1-rmse:0.93344
# [35]	validation_0-rmse:0.57630	validation_1-rmse:0.94060
# [36]	validation_0-rmse:0.56898	validation_1-rmse:0.91637
# [37]	validation_0-rmse:0.56681	validation_1-rmse:0.91865
# [38]	validation_0-rmse:0.56096	validation_1-rmse:0.90848
# [39]	validation_0-rmse:0.55660	validation_1-rmse:0.92352
# [40]	validation_0-rmse:0.53873	validation_1-rmse:0.91357
# [41]	validation_0-rmse:0.53117	validation_1-rmse:0.90710
# [42]	validation_0-rmse:0.52279	validation_1-rmse:0.90101
# [43]	validation_0-rmse:0.51986	validation_1-rmse:0.89451
# [44]	validation_0-rmse:0.50607	validation_1-rmse:0.89409
# [45]	validation_0-rmse:0.49652	validation_1-rmse:0.89149
# [46]	validation_0-rmse:0.48901	validation_1-rmse:0.89871
# [47]	validation_0-rmse:0.48167	validation_1-rmse:0.89167
# [48]	validation_0-rmse:0.46644	validation_1-rmse:0.88129
# [49]	validation_0-rmse:0.46142	validation_1-rmse:0.89104
# [50]	validation_0-rmse:0.45987	validation_1-rmse:0.88330
# [0]	validation_0-rmse:4.93454	validation_1-rmse:4.69529
# [1]	validation_0-rmse:3.60837	validation_1-rmse:3.37421
# [2]	validation_0-rmse:2.68366	validation_1-rmse:2.39285
# [3]	validation_0-rmse:2.07421	validation_1-rmse:1.81855
# [4]	validation_0-rmse:1.64573	validation_1-rmse:1.47959
# [5]	validation_0-rmse:1.38332	validation_1-rmse:1.28470
# [6]	validation_0-rmse:1.15526	validation_1-rmse:1.09014
# [7]	validation_0-rmse:1.02119	validation_1-rmse:0.98893
# [8]	validation_0-rmse:0.90791	validation_1-rmse:0.94057
# [9]	validation_0-rmse:0.84343	validation_1-rmse:0.94579
# [10]	validation_0-rmse:0.81806	validation_1-rmse:0.95340
# [11]	validation_0-rmse:0.81009	validation_1-rmse:0.94388
# [12]	validation_0-rmse:0.79661	validation_1-rmse:0.96084
# [13]	validation_0-rmse:0.77281	validation_1-rmse:0.99098
# [14]	validation_0-rmse:0.74813	validation_1-rmse:0.99603
# [15]	validation_0-rmse:0.74230	validation_1-rmse:0.99947
# [16]	validation_0-rmse:0.72719	validation_1-rmse:1.00368
# [17]	validation_0-rmse:0.70339	validation_1-rmse:1.05950
# [18]	validation_0-rmse:0.69220	validation_1-rmse:1.04956
# [19]	validation_0-rmse:0.68106	validation_1-rmse:1.03309
# [20]	validation_0-rmse:0.67391	validation_1-rmse:1.04170
# [21]	validation_0-rmse:0.66652	validation_1-rmse:1.02273
# [22]	validation_0-rmse:0.65948	validation_1-rmse:1.02809
# [23]	validation_0-rmse:0.64476	validation_1-rmse:1.02622
# [24]	validation_0-rmse:0.63628	validation_1-rmse:0.97483
# [25]	validation_0-rmse:0.62279	validation_1-rmse:0.96542
# [26]	validation_0-rmse:0.61235	validation_1-rmse:0.97778
# [27]	validation_0-rmse:0.60379	validation_1-rmse:1.00085
# [28]	validation_0-rmse:0.59666	validation_1-rmse:0.99805

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(3.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.612
# Uncertainty
# a0: 2.51+/-0.383
# a1: 0.634+/-0.051

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: AEDR_mean: mean - 0.51, median - 0.507, CI - [0.447-0.571]
#
# SHAP-values for: b_STD: mean - 0.113, median - 0.113, CI - [0.08-0.147]
#
# SHAP-values for: contr_r_STD: mean - 0.404, median - 0.403, CI - [0.338-0.47]
#
# SHAP-values for: corr_r_MIN: mean - 0.206, median - 0.207, CI - [0.17-0.245]
#
# SHAP-values for: corr_r_Q25: mean - 0.244, median - 0.246, CI - [0.176-0.309]
#
# SHAP-values for: r_MIN: mean - 0.069, median - 0.071, CI - [0.016-0.109]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['AEDR_mean', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN', 'b_STD', 'r_MIN'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 21.955, median: 20.0,
#  pred. interval (P(0.025)-P(0.975)): 8.0-48.025,
#  conf. interval (p-value=0.95): 11.872-33.691
# ***
# Aggregate bias statistic:
#  mean: -0.063, median: -0.071,
#  pred. interval (P(0.025)-P(0.975)): -0.573-0.345,
#  conf. interval (p-value=0.95): -0.248-0.142
# ***
# Aggregate RMSE statistic:
#  mean: 1.004, median: 1.006, pred. interval (P(0.025)-P(0.975)): 0.675-1.322,
#  conf. interval (p-value=0.95): 0.884-1.124
# ***
# Aggregate MSE statistic:
#  mean: 1.029, median: 1.012, pred. interval (P(0.025)-P(0.975)): 0.456-1.749,
#  conf. interval (p-value=0.95): 0.782-1.266
# ***
# Aggregate R^2 statistic:
#  mean: 0.563, median: 0.591, pred. interval (P(0.025)-P(0.975)): 0.172-0.8,
#  conf. interval (p-value=0.95): 0.403-0.707
# ***
# Aggregate bias(%) statistic:
#  mean: -0.832, median: -1.007, pred. interval (P(0.025)-P(0.975)): -7.995-5.034,
#  conf. interval (p-value=0.95): -3.531-1.984
# ***
# Aggregate RMSE(%) statistic:
#  mean: 14.307, median: 14.237, pred. interval (P(0.025)-P(0.975)): 10.032-19.694,
#  conf. interval (p-value=0.95): 12.417-16.241
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -1323.45, median: -835.994,
#  pred. interval (P(0.025)-P(0.975)): -5570.369-1164.9,
#  conf. interval (p-value=0.95): -3020.267--112.032
# ***
# Aggregate RMSE statistic:
#  mean: 6142.589, median: 4530.106, pred. interval (P(0.025)-P(0.975)): 1136.46-17309.805,
#  conf. interval (p-value=0.95): 2486.224-13893.917
# ***
# Aggregate MSE statistic:
#  mean: 62251201.312, median: 20522069.207, pred. interval (P(0.025)-P(0.975)): 1291572.712-299629355.428,
#  conf. interval (p-value=0.95): 6629744.527-202453983.058
# ***
# Aggregate R^2 statistic:
#  mean: 0.397, median: 0.539, pred. interval (P(0.025)-P(0.975)): -1.383-0.886,
#  conf. interval (p-value=0.95): 0.221-0.72
# ***
# Aggregate bias(%) statistic:
#  mean: -24.444, median: -26.944, pred. interval (P(0.025)-P(0.975)): -66.48-37.991,
#  conf. interval (p-value=0.95): -49.653--3.447
# ***
# Aggregate RMSE(%) statistic:
#  mean: 133.093, median: 118.61, pred. interval (P(0.025)-P(0.975)): 61.448-271.367,
#  conf. interval (p-value=0.95): 87.396-178.338
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [4, 5, 6, 7, 8, 9, 10, 11])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 500, 1000, 5000, 10000, 20000, 50000, 1000000])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:4.81533
# [1]	validation_0-rmse:3.48135
# [2]	validation_0-rmse:2.58239
# [3]	validation_0-rmse:1.99385
# [4]	validation_0-rmse:1.57330
# [5]	validation_0-rmse:1.32964
# [6]	validation_0-rmse:1.13661
# [7]	validation_0-rmse:1.03681
# [8]	validation_0-rmse:0.95461
# [9]	validation_0-rmse:0.90396
# [10]	validation_0-rmse:0.85432
# [11]	validation_0-rmse:0.82138
# [12]	validation_0-rmse:0.79865
# [13]	validation_0-rmse:0.76434
# [14]	validation_0-rmse:0.73518
# [15]	validation_0-rmse:0.72532
# [16]	validation_0-rmse:0.70891
# [17]	validation_0-rmse:0.69873
# [18]	validation_0-rmse:0.69463
# [19]	validation_0-rmse:0.68975
# [20]	validation_0-rmse:0.67837
# [21]	validation_0-rmse:0.67122
# [22]	validation_0-rmse:0.64879
# [23]	validation_0-rmse:0.64057
# [24]	validation_0-rmse:0.63588
# [25]	validation_0-rmse:0.61881
# [26]	validation_0-rmse:0.60309
# [27]	validation_0-rmse:0.59389
# [28]	validation_0-rmse:0.58722
# [29]	validation_0-rmse:0.58361
# [30]	validation_0-rmse:0.57807
# [31]	validation_0-rmse:0.56178
# [32]	validation_0-rmse:0.55498
# [33]	validation_0-rmse:0.55319
# [34]	validation_0-rmse:0.54854
# [35]	validation_0-rmse:0.54583
# [36]	validation_0-rmse:0.54136
# [37]	validation_0-rmse:0.53716
# [38]	validation_0-rmse:0.52858
# [39]	validation_0-rmse:0.51726
# [40]	validation_0-rmse:0.50717
# [41]	validation_0-rmse:0.50455
# [42]	validation_0-rmse:0.49322
# [43]	validation_0-rmse:0.48678
# [44]	validation_0-rmse:0.48476
# [45]	validation_0-rmse:0.47455
# [46]	validation_0-rmse:0.47067
# [47]	validation_0-rmse:0.46378
# [48]	validation_0-rmse:0.45792
# [49]	validation_0-rmse:0.44773
# [50]	validation_0-rmse:0.44367

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 50

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.23
# RMSE: 0.4
# Relative RMSE(%):  6.294
# MSE: 0.2
# R square: 92.7%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(3.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.930
# Uncertainty
# a0: 0.82+/-0.17
# a1: 0.881+/-0.024

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/07_LN_Cs_vs_CHM_RGB_AEDR_XGB_model_2024_final.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/07_LN_Cs_vs_CHM_RGB_AEDR_XGB_model_2024_final.txt")
