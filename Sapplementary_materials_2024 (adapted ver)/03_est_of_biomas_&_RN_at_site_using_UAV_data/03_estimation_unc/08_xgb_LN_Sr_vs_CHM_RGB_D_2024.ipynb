# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../03_input_data/input_CHM_&_spectral_data_site2020_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Cs_wood', 'ln_Sr_wood', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 
                                    'r_MIN', 'contr_b_MAX', 'contr_b_STD'])
            
# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  r_MIN  \
# 0       6.824       9.240           1210     -0.731      2.576     13
# 1       8.189       9.622           1180      0.585      2.915     24
# 2       8.380       9.589           1400      0.779      2.882     18
# 3       8.137       9.449           1090      0.517      2.724     15
# 4       7.696       9.401            720      0.224      2.826      8
#
#    contr_b_MAX  contr_b_STD
# 0  2713.600586   332.963753
# 1  1793.493042   293.868420
# 2  1761.097900   272.526176
# 3  2518.435303   299.595643
# 4  2525.819336   327.599176

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Sr_2021_kBq_m  103 non-null    int64
#  3   ln_Tag_Cs      103 non-null    float64
#  4   ln_Tag_Sr      103 non-null    float64
#  5   r_MIN          103 non-null    int64
#  6   contr_b_MAX    103 non-null    float64
#  7   contr_b_STD    103 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 6.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Cs_wood", "ln_Sr_wood"].describe()
# Out:
#                  ln_Cs_wood                                                 \
#                       count       mean       std     min      25%      50%
# Dominant_specias
# Alder                   4.0   7.305000  1.427622   5.886   6.6765   7.0235
# Aspen                   1.0  11.367000       NaN  11.367  11.3670  11.3670
# Birch                  23.0   7.304652  1.533182   4.533   6.3365   7.2150
# Oak                     3.0   7.430333  1.260072   6.040   6.8970   7.7540
# Pine                   71.0   6.901690  1.650166   3.526   6.3790   6.9470
# Spruce                  1.0   5.176000       NaN   5.176   5.1760   5.1760
#
#                                   ln_Sr_wood                               \
#                       75%     max      count       mean       std     min
# Dominant_specias
# Alder              7.6520   9.287        4.0   7.206000  0.650057   6.265
# Aspen             11.3670  11.367        1.0  11.090000       NaN  11.090
# Birch              8.0320  10.332       23.0   9.345478  1.626360   7.139
# Oak                8.1255   8.497        3.0   7.483667  0.815040   6.565
# Pine               7.6960  10.469       71.0   8.542592  1.359020   6.075
# Spruce             5.1760   5.176        1.0   7.783000       NaN   7.783
#
#
#                       25%      50%      75%     max
# Dominant_specias
# Alder              7.0255   7.4545   7.6350   7.650
# Aspen             11.0900  11.0900  11.0900  11.090
# Birch              8.4000   8.9910   9.9365  13.864
# Oak                7.1655   7.7660   7.9430   8.120
# Pine               7.6450   8.4720   9.3710  12.687
# Spruce             7.7830   7.7830   7.7830   7.783

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Sr_2021_kBq_m   ln_Tag_Cs   ln_Tag_Sr  \
# count   103.00000  103.000000     103.000000  103.000000  103.000000
# mean      7.04933    8.656485    1242.902913   -0.252563    2.464709
# std       1.64946    1.472424    2037.684800    1.104610    0.904675
# min       3.52600    6.075000      50.000000   -3.033000    0.391000
# 25%       6.31900    7.664000     200.000000   -0.727500    1.803000
# 50%       6.95700    8.472000     400.000000   -0.025000    2.603000
# 75%       7.91350    9.421000    1400.000000    0.516500    3.159000
# max      11.36700   13.864000   10500.000000    1.652000    4.659000
#
#             r_MIN  contr_b_MAX  contr_b_STD
# count  103.000000   103.000000   103.000000
# mean    11.378641  2712.352866   349.854034
# std      9.139568   864.116297    93.673105
# min      2.000000   832.155518   109.232976
# 25%      5.000000  2123.614868   292.544440
# 50%      8.000000  2601.248047   341.904211
# 75%     15.000000  3045.944336   427.359073
# max     56.000000  6252.923340   588.661708

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_Sr_wood"
indep_variables = ['Sr_2021_kBq_m', 'r_MIN', 'contr_b_MAX', 'contr_b_STD']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Cs_wood  ln_Sr_wood  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  r_MIN  \
# 0         6.824       9.240           1210     -0.731      2.576     13
# 1         8.189       9.622           1180      0.585      2.915     24
# 2         8.380       9.589           1400      0.779      2.882     18
# 3         8.137       9.449           1090      0.517      2.724     15
# 4         7.696       9.401            720      0.224      2.826      8
# ..          ...         ...            ...        ...        ...    ...
# 98        8.071       8.434           1300      0.228      1.514      3
# 99        7.993      10.042           1100      0.266      3.230     18
# 100       8.343      10.488           1200      0.543      3.606     19
# 101       3.638       6.399            270     -2.811      0.805      6
# 102       4.787       6.877            290     -1.728      1.199      2
#
#      contr_b_MAX  contr_b_STD
# 0    2713.600586   332.963753
# 1    1793.493042   293.868420
# 2    1761.097900   272.526176
# 3    2518.435303   299.595643
# 4    2525.819336   327.599176
# ..           ...          ...
# 98   3402.678467   306.364115
# 99   1918.606323   259.662727
# 100  1374.815430   227.616327
# 101  2461.437988   439.953000
# 102  2530.473633   386.530917
#
# [103 rows x 8 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Sr_2021_kBq_m  r_MIN  contr_b_MAX  contr_b_STD
# 0           1210     13  2713.600586   332.963753
# 1           1180     24  1793.493042   293.868420
# 2           1400     18  1761.097900   272.526176
# 3           1090     15  2518.435303   299.595643
# 4            720      8  2525.819336   327.599176

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Sr_wood
# 0       9.240
# 1       9.622
# 2       9.589
# 3       9.449
# 4       9.401

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.7005766879368744, 0.4329126443246192, 0.6443467391330469]
#     Mean: 0.593
#     Std: 0.115
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.9247601  1.0104922  0.91623221]
#     Mean: 0.950
#     Std: 0.043
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.7965682882036481, 0.7748773443558636, 0.6712666310703054]
#     Mean: 0.748
#     Std: 0.055
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.7739672957519645                 # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.2603283640944162                 # gamma
print('Gamma: ' + str(p2))

p3 = 0.09185270092482001                # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2                                  # max_depth
print('Max_depth: ' + str(p4))

p5 = 55                                # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.9309795604388287                # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.7739672957519645
# Gamma: 0.2603283640944162
# Learning_rate: 0.09185270092482001
# Max_depth: 2
# N_estimators: 55
# Subsample: 0.9309795604388287

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=10, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:7.60421	validation_1-rmse:7.36766
# [1]	validation_0-rmse:6.93400	validation_1-rmse:6.70192
# [2]	validation_0-rmse:6.32882	validation_1-rmse:6.11758
# [3]	validation_0-rmse:5.77967	validation_1-rmse:5.58947
# [4]	validation_0-rmse:5.27735	validation_1-rmse:5.12023
# [5]	validation_0-rmse:4.82044	validation_1-rmse:4.69236
# [6]	validation_0-rmse:4.40949	validation_1-rmse:4.29920
# [7]	validation_0-rmse:4.03756	validation_1-rmse:3.94411
# [8]	validation_0-rmse:3.69588	validation_1-rmse:3.63721
# [9]	validation_0-rmse:3.38683	validation_1-rmse:3.34780
# [10]	validation_0-rmse:3.10649	validation_1-rmse:3.08436
# [11]	validation_0-rmse:2.85922	validation_1-rmse:2.84470
# [12]	validation_0-rmse:2.62501	validation_1-rmse:2.63920
# [13]	validation_0-rmse:2.42168	validation_1-rmse:2.45014
# [14]	validation_0-rmse:2.22707	validation_1-rmse:2.28363
# [15]	validation_0-rmse:2.05049	validation_1-rmse:2.12739
# [16]	validation_0-rmse:1.89107	validation_1-rmse:1.98893
# [17]	validation_0-rmse:1.75184	validation_1-rmse:1.86947
# [18]	validation_0-rmse:1.62165	validation_1-rmse:1.75611
# [19]	validation_0-rmse:1.50361	validation_1-rmse:1.66031
# [20]	validation_0-rmse:1.40285	validation_1-rmse:1.57980
# [21]	validation_0-rmse:1.30022	validation_1-rmse:1.50150
# [22]	validation_0-rmse:1.21270	validation_1-rmse:1.43557
# [23]	validation_0-rmse:1.14000	validation_1-rmse:1.37585
# [24]	validation_0-rmse:1.06597	validation_1-rmse:1.31806
# [25]	validation_0-rmse:1.00535	validation_1-rmse:1.26889
# [26]	validation_0-rmse:0.94722	validation_1-rmse:1.22930
# [27]	validation_0-rmse:0.89615	validation_1-rmse:1.18786
# [28]	validation_0-rmse:0.85381	validation_1-rmse:1.15321
# [29]	validation_0-rmse:0.81064	validation_1-rmse:1.12501
# [30]	validation_0-rmse:0.77499	validation_1-rmse:1.09734
# [31]	validation_0-rmse:0.74321	validation_1-rmse:1.07401
# [32]	validation_0-rmse:0.71700	validation_1-rmse:1.05252
# [33]	validation_0-rmse:0.68899	validation_1-rmse:1.03510
# [34]	validation_0-rmse:0.66928	validation_1-rmse:1.01822
# [35]	validation_0-rmse:0.65132	validation_1-rmse:1.00984
# [36]	validation_0-rmse:0.63483	validation_1-rmse:0.99299
# [37]	validation_0-rmse:0.62019	validation_1-rmse:0.97876
# [38]	validation_0-rmse:0.60708	validation_1-rmse:0.96671
# [39]	validation_0-rmse:0.59504	validation_1-rmse:0.96494
# [40]	validation_0-rmse:0.58489	validation_1-rmse:0.95947
# [41]	validation_0-rmse:0.57531	validation_1-rmse:0.94929
# [42]	validation_0-rmse:0.56687	validation_1-rmse:0.94419
# [43]	validation_0-rmse:0.55527	validation_1-rmse:0.94031
# [44]	validation_0-rmse:0.54482	validation_1-rmse:0.93703
# [45]	validation_0-rmse:0.53902	validation_1-rmse:0.93162
# [46]	validation_0-rmse:0.53420	validation_1-rmse:0.92643
# [47]	validation_0-rmse:0.52955	validation_1-rmse:0.92005
# [48]	validation_0-rmse:0.52353	validation_1-rmse:0.92035
# [49]	validation_0-rmse:0.51802	validation_1-rmse:0.91541
# [50]	validation_0-rmse:0.51475	validation_1-rmse:0.90912
# [51]	validation_0-rmse:0.51185	validation_1-rmse:0.90268
# [52]	validation_0-rmse:0.50935	validation_1-rmse:0.90018
# [53]	validation_0-rmse:0.50614	validation_1-rmse:0.90165
# [54]	validation_0-rmse:0.50399	validation_1-rmse:0.89475
# [0]	validation_0-rmse:7.52390	validation_1-rmse:7.74263
# [1]	validation_0-rmse:6.86843	validation_1-rmse:7.08709
# [2]	validation_0-rmse:6.26788	validation_1-rmse:6.47326
# [3]	validation_0-rmse:5.72435	validation_1-rmse:5.91791
# [4]	validation_0-rmse:5.23414	validation_1-rmse:5.41651
# [5]	validation_0-rmse:4.77975	validation_1-rmse:4.95177
# [6]	validation_0-rmse:4.37167	validation_1-rmse:4.53132
# [7]	validation_0-rmse:4.00287	validation_1-rmse:4.15540
# [8]	validation_0-rmse:3.66715	validation_1-rmse:3.81203
# [9]	validation_0-rmse:3.36331	validation_1-rmse:3.49537
# [10]	validation_0-rmse:3.08665	validation_1-rmse:3.20584
# [11]	validation_0-rmse:2.83618	validation_1-rmse:2.94388
# [12]	validation_0-rmse:2.60879	validation_1-rmse:2.71415
# [13]	validation_0-rmse:2.40556	validation_1-rmse:2.50069
# [14]	validation_0-rmse:2.22038	validation_1-rmse:2.30696
# [15]	validation_0-rmse:2.05099	validation_1-rmse:2.14469
# [16]	validation_0-rmse:1.89757	validation_1-rmse:1.99041
# [17]	validation_0-rmse:1.75979	validation_1-rmse:1.85224
# [18]	validation_0-rmse:1.63245	validation_1-rmse:1.73147
# [19]	validation_0-rmse:1.52180	validation_1-rmse:1.62855
# [20]	validation_0-rmse:1.42192	validation_1-rmse:1.52106
# [21]	validation_0-rmse:1.32710	validation_1-rmse:1.44593
# [22]	validation_0-rmse:1.24598	validation_1-rmse:1.37617
# [23]	validation_0-rmse:1.17408	validation_1-rmse:1.30875
# [24]	validation_0-rmse:1.10756	validation_1-rmse:1.25368
# [25]	validation_0-rmse:1.04494	validation_1-rmse:1.19269
# [26]	validation_0-rmse:0.98872	validation_1-rmse:1.14699
# [27]	validation_0-rmse:0.93782	validation_1-rmse:1.10060
# [28]	validation_0-rmse:0.89478	validation_1-rmse:1.07034
# [29]	validation_0-rmse:0.85547	validation_1-rmse:1.03862
# [30]	validation_0-rmse:0.82171	validation_1-rmse:1.01296
# [31]	validation_0-rmse:0.79354	validation_1-rmse:0.99039
# [32]	validation_0-rmse:0.76484	validation_1-rmse:0.96776
# [33]	validation_0-rmse:0.73647	validation_1-rmse:0.94581
# [34]	validation_0-rmse:0.71743	validation_1-rmse:0.92935
# [35]	validation_0-rmse:0.69799	validation_1-rmse:0.91867
# [36]	validation_0-rmse:0.68032	validation_1-rmse:0.90884
# [37]	validation_0-rmse:0.66536	validation_1-rmse:0.90163
# [38]	validation_0-rmse:0.65105	validation_1-rmse:0.89212
# [39]	validation_0-rmse:0.63969	validation_1-rmse:0.88772
# [40]	validation_0-rmse:0.62867	validation_1-rmse:0.87920
# [41]	validation_0-rmse:0.61859	validation_1-rmse:0.87242
# [42]	validation_0-rmse:0.61035	validation_1-rmse:0.86979
# [43]	validation_0-rmse:0.60117	validation_1-rmse:0.86609
# [44]	validation_0-rmse:0.59307	validation_1-rmse:0.86223
# [45]	validation_0-rmse:0.58619	validation_1-rmse:0.86077
# [46]	validation_0-rmse:0.57981	validation_1-rmse:0.86054
# [47]	validation_0-rmse:0.57198	validation_1-rmse:0.85427
# [48]	validation_0-rmse:0.56634	validation_1-rmse:0.85131
# [49]	validation_0-rmse:0.56006	validation_1-rmse:0.84657
# [50]	validation_0-rmse:0.55538	validation_1-rmse:0.84546
# [51]	validation_0-rmse:0.55128	validation_1-rmse:0.84650
# [52]	validation_0-rmse:0.54094	validation_1-rmse:0.84384
# [53]	validation_0-rmse:0.53658	validation_1-rmse:0.84428
# [54]	validation_0-rmse:0.53308	validation_1-rmse:0.84375
# [0]	validation_0-rmse:7.52317	validation_1-rmse:7.72686
# [1]	validation_0-rmse:6.86238	validation_1-rmse:7.06844
# [2]	validation_0-rmse:6.25881	validation_1-rmse:6.48777
# [3]	validation_0-rmse:5.71320	validation_1-rmse:5.96298
# [4]	validation_0-rmse:5.21327	validation_1-rmse:5.48361
# [5]	validation_0-rmse:4.75824	validation_1-rmse:5.03421
# [6]	validation_0-rmse:4.34880	validation_1-rmse:4.64332
# [7]	validation_0-rmse:3.97388	validation_1-rmse:4.27231
# [8]	validation_0-rmse:3.63338	validation_1-rmse:3.93536
# [9]	validation_0-rmse:3.33030	validation_1-rmse:3.64697
# [10]	validation_0-rmse:3.05615	validation_1-rmse:3.38643
# [11]	validation_0-rmse:2.80377	validation_1-rmse:3.13369
# [12]	validation_0-rmse:2.57208	validation_1-rmse:2.91213
# [13]	validation_0-rmse:2.36882	validation_1-rmse:2.70864
# [14]	validation_0-rmse:2.18254	validation_1-rmse:2.53840
# [15]	validation_0-rmse:2.01053	validation_1-rmse:2.37306
# [16]	validation_0-rmse:1.85469	validation_1-rmse:2.22920
# [17]	validation_0-rmse:1.71676	validation_1-rmse:2.10237
# [18]	validation_0-rmse:1.59353	validation_1-rmse:1.99460
# [19]	validation_0-rmse:1.48122	validation_1-rmse:1.89004
# [20]	validation_0-rmse:1.38013	validation_1-rmse:1.79760
# [21]	validation_0-rmse:1.28931	validation_1-rmse:1.71116
# [22]	validation_0-rmse:1.20559	validation_1-rmse:1.63126
# [23]	validation_0-rmse:1.13643	validation_1-rmse:1.57094
# [24]	validation_0-rmse:1.06930	validation_1-rmse:1.50768
# [25]	validation_0-rmse:1.00782	validation_1-rmse:1.44674
# [26]	validation_0-rmse:0.95098	validation_1-rmse:1.38918
# [27]	validation_0-rmse:0.90217	validation_1-rmse:1.34391
# [28]	validation_0-rmse:0.85778	validation_1-rmse:1.30845
# [29]	validation_0-rmse:0.82106	validation_1-rmse:1.27046
# [30]	validation_0-rmse:0.78811	validation_1-rmse:1.23736
# [31]	validation_0-rmse:0.75795	validation_1-rmse:1.20524
# [32]	validation_0-rmse:0.73386	validation_1-rmse:1.18548
# [33]	validation_0-rmse:0.70578	validation_1-rmse:1.15683
# [34]	validation_0-rmse:0.68573	validation_1-rmse:1.14470
# [35]	validation_0-rmse:0.66957	validation_1-rmse:1.13604
# [36]	validation_0-rmse:0.65251	validation_1-rmse:1.11756
# [37]	validation_0-rmse:0.63269	validation_1-rmse:1.10425
# [38]	validation_0-rmse:0.62031	validation_1-rmse:1.08811
# [39]	validation_0-rmse:0.61116	validation_1-rmse:1.07506
# [40]	validation_0-rmse:0.60150	validation_1-rmse:1.07101
# [41]	validation_0-rmse:0.59073	validation_1-rmse:1.06247
# [42]	validation_0-rmse:0.58225	validation_1-rmse:1.06225
# [43]	validation_0-rmse:0.57486	validation_1-rmse:1.05782
# [44]	validation_0-rmse:0.56871	validation_1-rmse:1.05342
# [45]	validation_0-rmse:0.56426	validation_1-rmse:1.04859
# [46]	validation_0-rmse:0.55866	validation_1-rmse:1.04471
# [47]	validation_0-rmse:0.55463	validation_1-rmse:1.03637
# [48]	validation_0-rmse:0.55251	validation_1-rmse:1.03569
# [49]	validation_0-rmse:0.54428	validation_1-rmse:1.03432
# [50]	validation_0-rmse:0.54068	validation_1-rmse:1.02351
# [51]	validation_0-rmse:0.53706	validation_1-rmse:1.01595
# [52]	validation_0-rmse:0.53081	validation_1-rmse:1.01701
# [53]	validation_0-rmse:0.52641	validation_1-rmse:1.01594
# [54]	validation_0-rmse:0.52388	validation_1-rmse:1.01161
# [0]	validation_0-rmse:7.45728	validation_1-rmse:7.99590
# [1]	validation_0-rmse:6.81035	validation_1-rmse:7.34624
# [2]	validation_0-rmse:6.21670	validation_1-rmse:6.74838
# [3]	validation_0-rmse:5.67190	validation_1-rmse:6.19939
# [4]	validation_0-rmse:5.18645	validation_1-rmse:5.70977
# [5]	validation_0-rmse:4.73665	validation_1-rmse:5.24901
# [6]	validation_0-rmse:4.33282	validation_1-rmse:4.83700
# [7]	validation_0-rmse:3.96489	validation_1-rmse:4.46451
# [8]	validation_0-rmse:3.63319	validation_1-rmse:4.11722
# [9]	validation_0-rmse:3.33361	validation_1-rmse:3.80015
# [10]	validation_0-rmse:3.06290	validation_1-rmse:3.51559
# [11]	validation_0-rmse:2.81383	validation_1-rmse:3.24292
# [12]	validation_0-rmse:2.58346	validation_1-rmse:2.99772
# [13]	validation_0-rmse:2.38464	validation_1-rmse:2.78340
# [14]	validation_0-rmse:2.19755	validation_1-rmse:2.58510
# [15]	validation_0-rmse:2.02612	validation_1-rmse:2.40297
# [16]	validation_0-rmse:1.86951	validation_1-rmse:2.24084
# [17]	validation_0-rmse:1.73372	validation_1-rmse:2.09508
# [18]	validation_0-rmse:1.60886	validation_1-rmse:1.95643
# [19]	validation_0-rmse:1.50110	validation_1-rmse:1.82995
# [20]	validation_0-rmse:1.40283	validation_1-rmse:1.71730
# [21]	validation_0-rmse:1.31514	validation_1-rmse:1.61941
# [22]	validation_0-rmse:1.23564	validation_1-rmse:1.53081
# [23]	validation_0-rmse:1.16634	validation_1-rmse:1.45251
# [24]	validation_0-rmse:1.10223	validation_1-rmse:1.37156
# [25]	validation_0-rmse:1.04469	validation_1-rmse:1.30060
# [26]	validation_0-rmse:0.99606	validation_1-rmse:1.23788
# [27]	validation_0-rmse:0.95113	validation_1-rmse:1.18396
# [28]	validation_0-rmse:0.90316	validation_1-rmse:1.13211
# [29]	validation_0-rmse:0.86774	validation_1-rmse:1.08708
# [30]	validation_0-rmse:0.83686	validation_1-rmse:1.04788
# [31]	validation_0-rmse:0.80957	validation_1-rmse:1.00782
# [32]	validation_0-rmse:0.78474	validation_1-rmse:0.97483
# [33]	validation_0-rmse:0.76328	validation_1-rmse:0.94099
# [34]	validation_0-rmse:0.74683	validation_1-rmse:0.91390
# [35]	validation_0-rmse:0.73405	validation_1-rmse:0.90063
# [36]	validation_0-rmse:0.71933	validation_1-rmse:0.87792
# [37]	validation_0-rmse:0.70565	validation_1-rmse:0.86097
# [38]	validation_0-rmse:0.69305	validation_1-rmse:0.84391
# [39]	validation_0-rmse:0.68186	validation_1-rmse:0.83008
# [40]	validation_0-rmse:0.67141	validation_1-rmse:0.80953
# [41]	validation_0-rmse:0.66252	validation_1-rmse:0.79696
# [42]	validation_0-rmse:0.65267	validation_1-rmse:0.79395
# [43]	validation_0-rmse:0.64519	validation_1-rmse:0.78527
# [44]	validation_0-rmse:0.63895	validation_1-rmse:0.77636
# [45]	validation_0-rmse:0.63398	validation_1-rmse:0.76719
# [46]	validation_0-rmse:0.62854	validation_1-rmse:0.75945
# [47]	validation_0-rmse:0.62386	validation_1-rmse:0.74913
# [48]	validation_0-rmse:0.61774	validation_1-rmse:0.74605
# [49]	validation_0-rmse:0.61318	validation_1-rmse:0.73611
# [50]	validation_0-rmse:0.60826	validation_1-rmse:0.72956
# [51]	validation_0-rmse:0.60445	validation_1-rmse:0.72418
# [52]	validation_0-rmse:0.60115	validation_1-rmse:0.72329
# [53]	validation_0-rmse:0.59645	validation_1-rmse:0.72109
# [54]	validation_0-rmse:0.59345	validation_1-rmse:0.72019
# [0]	validation_0-rmse:7.61386	validation_1-rmse:7.31721
# [1]	validation_0-rmse:6.95097	validation_1-rmse:6.64851
# [2]	validation_0-rmse:6.34663	validation_1-rmse:6.07195
# [3]	validation_0-rmse:5.80030	validation_1-rmse:5.54922
# [4]	validation_0-rmse:5.29887	validation_1-rmse:5.06690
# [5]	validation_0-rmse:4.84160	validation_1-rmse:4.63236
# [6]	validation_0-rmse:4.43177	validation_1-rmse:4.24026
# [7]	validation_0-rmse:4.05388	validation_1-rmse:3.88015
# [8]	validation_0-rmse:3.71269	validation_1-rmse:3.55416
# [9]	validation_0-rmse:3.40589	validation_1-rmse:3.24084
# [10]	validation_0-rmse:3.13479	validation_1-rmse:2.94678
# [11]	validation_0-rmse:2.88605	validation_1-rmse:2.68908
# [12]	validation_0-rmse:2.65201	validation_1-rmse:2.45358
# [13]	validation_0-rmse:2.45075	validation_1-rmse:2.24924
# [14]	validation_0-rmse:2.25626	validation_1-rmse:2.06253
# [15]	validation_0-rmse:2.08254	validation_1-rmse:1.90127
# [16]	validation_0-rmse:1.92251	validation_1-rmse:1.75618
# [17]	validation_0-rmse:1.77835	validation_1-rmse:1.61750
# [18]	validation_0-rmse:1.64882	validation_1-rmse:1.50063
# [19]	validation_0-rmse:1.53482	validation_1-rmse:1.38579
# [20]	validation_0-rmse:1.43556	validation_1-rmse:1.27834
# [21]	validation_0-rmse:1.34432	validation_1-rmse:1.18520
# [22]	validation_0-rmse:1.26059	validation_1-rmse:1.11701
# [23]	validation_0-rmse:1.18936	validation_1-rmse:1.04929
# [24]	validation_0-rmse:1.12085	validation_1-rmse:0.99575
# [25]	validation_0-rmse:1.05953	validation_1-rmse:0.93479
# [26]	validation_0-rmse:1.00844	validation_1-rmse:0.88554
# [27]	validation_0-rmse:0.96082	validation_1-rmse:0.85041
# [28]	validation_0-rmse:0.91217	validation_1-rmse:0.82016
# [29]	validation_0-rmse:0.87751	validation_1-rmse:0.78992
# [30]	validation_0-rmse:0.84509	validation_1-rmse:0.76887
# [31]	validation_0-rmse:0.81608	validation_1-rmse:0.74862
# [32]	validation_0-rmse:0.78759	validation_1-rmse:0.73238
# [33]	validation_0-rmse:0.76915	validation_1-rmse:0.71865
# [34]	validation_0-rmse:0.74855	validation_1-rmse:0.71445
# [35]	validation_0-rmse:0.73045	validation_1-rmse:0.70453
# [36]	validation_0-rmse:0.71177	validation_1-rmse:0.69337
# [37]	validation_0-rmse:0.69664	validation_1-rmse:0.68756
# [38]	validation_0-rmse:0.68461	validation_1-rmse:0.68029
# [39]	validation_0-rmse:0.67235	validation_1-rmse:0.68170
# [40]	validation_0-rmse:0.66381	validation_1-rmse:0.68615
# [41]	validation_0-rmse:0.65424	validation_1-rmse:0.68114
# [42]	validation_0-rmse:0.64656	validation_1-rmse:0.68156
# [43]	validation_0-rmse:0.63897	validation_1-rmse:0.67822
# [44]	validation_0-rmse:0.63042	validation_1-rmse:0.67444
# [45]	validation_0-rmse:0.62262	validation_1-rmse:0.66852
# [46]	validation_0-rmse:0.61624	validation_1-rmse:0.67557
# [47]	validation_0-rmse:0.61119	validation_1-rmse:0.67394
# [48]	validation_0-rmse:0.60567	validation_1-rmse:0.67069
# [49]	validation_0-rmse:0.60154	validation_1-rmse:0.66878
# [50]	validation_0-rmse:0.59671	validation_1-rmse:0.66537
# [51]	validation_0-rmse:0.59193	validation_1-rmse:0.66359
# [52]	validation_0-rmse:0.58875	validation_1-rmse:0.66281
# [53]	validation_0-rmse:0.58384	validation_1-rmse:0.66995
# [54]	validation_0-rmse:0.58106	validation_1-rmse:0.66961
# [0]	validation_0-rmse:7.50509	validation_1-rmse:7.80802
# [1]	validation_0-rmse:6.85272	validation_1-rmse:7.16494
# [2]	validation_0-rmse:6.25501	validation_1-rmse:6.58937
# [3]	validation_0-rmse:5.70912	validation_1-rmse:6.06480
# [4]	validation_0-rmse:5.21055	validation_1-rmse:5.58606
# [5]	validation_0-rmse:4.76189	validation_1-rmse:5.15546
# [6]	validation_0-rmse:4.35496	validation_1-rmse:4.76600
# [7]	validation_0-rmse:3.98383	validation_1-rmse:4.39445
# [8]	validation_0-rmse:3.65018	validation_1-rmse:4.07522
# [9]	validation_0-rmse:3.34396	validation_1-rmse:3.77112
# [10]	validation_0-rmse:3.06650	validation_1-rmse:3.50176
# [11]	validation_0-rmse:2.81653	validation_1-rmse:3.25563
# [12]	validation_0-rmse:2.58555	validation_1-rmse:3.02449
# [13]	validation_0-rmse:2.38043	validation_1-rmse:2.84372
# [14]	validation_0-rmse:2.18624	validation_1-rmse:2.64265
# [15]	validation_0-rmse:2.01496	validation_1-rmse:2.46669
# [16]	validation_0-rmse:1.85954	validation_1-rmse:2.31965
# [17]	validation_0-rmse:1.72247	validation_1-rmse:2.19250
# [18]	validation_0-rmse:1.59462	validation_1-rmse:2.05571
# [19]	validation_0-rmse:1.47944	validation_1-rmse:1.94883
# [20]	validation_0-rmse:1.37769	validation_1-rmse:1.87256
# [21]	validation_0-rmse:1.28460	validation_1-rmse:1.78265
# [22]	validation_0-rmse:1.19821	validation_1-rmse:1.69477
# [23]	validation_0-rmse:1.12395	validation_1-rmse:1.64774
# [24]	validation_0-rmse:1.05712	validation_1-rmse:1.58423
# [25]	validation_0-rmse:0.99733	validation_1-rmse:1.51576
# [26]	validation_0-rmse:0.94306	validation_1-rmse:1.45669
# [27]	validation_0-rmse:0.89847	validation_1-rmse:1.42024
# [28]	validation_0-rmse:0.85681	validation_1-rmse:1.37259
# [29]	validation_0-rmse:0.81985	validation_1-rmse:1.33430
# [30]	validation_0-rmse:0.78786	validation_1-rmse:1.30223
# [31]	validation_0-rmse:0.75847	validation_1-rmse:1.27028
# [32]	validation_0-rmse:0.73218	validation_1-rmse:1.24484
# [33]	validation_0-rmse:0.70999	validation_1-rmse:1.21587
# [34]	validation_0-rmse:0.69096	validation_1-rmse:1.20824
# [35]	validation_0-rmse:0.67135	validation_1-rmse:1.19874
# [36]	validation_0-rmse:0.65519	validation_1-rmse:1.17620
# [37]	validation_0-rmse:0.64101	validation_1-rmse:1.15333
# [38]	validation_0-rmse:0.62749	validation_1-rmse:1.13576
# [39]	validation_0-rmse:0.61559	validation_1-rmse:1.12573
# [40]	validation_0-rmse:0.60471	validation_1-rmse:1.12386
# [41]	validation_0-rmse:0.59567	validation_1-rmse:1.10935
# [42]	validation_0-rmse:0.58623	validation_1-rmse:1.10662
# [43]	validation_0-rmse:0.57938	validation_1-rmse:1.09677
# [44]	validation_0-rmse:0.57244	validation_1-rmse:1.08277
# [45]	validation_0-rmse:0.56739	validation_1-rmse:1.07401
# [46]	validation_0-rmse:0.56060	validation_1-rmse:1.07492
# [47]	validation_0-rmse:0.54960	validation_1-rmse:1.06144
# [48]	validation_0-rmse:0.54609	validation_1-rmse:1.05554
# [49]	validation_0-rmse:0.54073	validation_1-rmse:1.04576
# [50]	validation_0-rmse:0.53765	validation_1-rmse:1.04264
# [51]	validation_0-rmse:0.53034	validation_1-rmse:1.03662
# [52]	validation_0-rmse:0.52713	validation_1-rmse:1.02799
# [53]	validation_0-rmse:0.52227	validation_1-rmse:1.03171
# [54]	validation_0-rmse:0.51925	validation_1-rmse:1.02460
# [0]	validation_0-rmse:7.58923	validation_1-rmse:7.41479
# [1]	validation_0-rmse:6.92783	validation_1-rmse:6.74694
# [2]	validation_0-rmse:6.32537	validation_1-rmse:6.15176
# [3]	validation_0-rmse:5.77772	validation_1-rmse:5.61015
# [4]	validation_0-rmse:5.27766	validation_1-rmse:5.11552
# [5]	validation_0-rmse:4.82571	validation_1-rmse:4.66418
# [6]	validation_0-rmse:4.41353	validation_1-rmse:4.25250
# [7]	validation_0-rmse:4.04255	validation_1-rmse:3.88532
# [8]	validation_0-rmse:3.70367	validation_1-rmse:3.55166
# [9]	validation_0-rmse:3.39618	validation_1-rmse:3.23143
# [10]	validation_0-rmse:3.11891	validation_1-rmse:2.94119
# [11]	validation_0-rmse:2.87118	validation_1-rmse:2.68064
# [12]	validation_0-rmse:2.64223	validation_1-rmse:2.45398
# [13]	validation_0-rmse:2.44232	validation_1-rmse:2.23802
# [14]	validation_0-rmse:2.24800	validation_1-rmse:2.04598
# [15]	validation_0-rmse:2.07810	validation_1-rmse:1.87548
# [16]	validation_0-rmse:1.92238	validation_1-rmse:1.72996
# [17]	validation_0-rmse:1.78187	validation_1-rmse:1.59675
# [18]	validation_0-rmse:1.65258	validation_1-rmse:1.48061
# [19]	validation_0-rmse:1.54378	validation_1-rmse:1.36526
# [20]	validation_0-rmse:1.44561	validation_1-rmse:1.25836
# [21]	validation_0-rmse:1.34858	validation_1-rmse:1.17297
# [22]	validation_0-rmse:1.26598	validation_1-rmse:1.11040
# [23]	validation_0-rmse:1.19572	validation_1-rmse:1.03515
# [24]	validation_0-rmse:1.12619	validation_1-rmse:0.98241
# [25]	validation_0-rmse:1.06709	validation_1-rmse:0.94390
# [26]	validation_0-rmse:1.01456	validation_1-rmse:0.90925
# [27]	validation_0-rmse:0.96859	validation_1-rmse:0.87105
# [28]	validation_0-rmse:0.92536	validation_1-rmse:0.84326
# [29]	validation_0-rmse:0.88954	validation_1-rmse:0.81888
# [30]	validation_0-rmse:0.85589	validation_1-rmse:0.80004
# [31]	validation_0-rmse:0.82628	validation_1-rmse:0.78413
# [32]	validation_0-rmse:0.80143	validation_1-rmse:0.76983
# [33]	validation_0-rmse:0.77737	validation_1-rmse:0.75000
# [34]	validation_0-rmse:0.75747	validation_1-rmse:0.73973
# [35]	validation_0-rmse:0.74237	validation_1-rmse:0.73128
# [36]	validation_0-rmse:0.71800	validation_1-rmse:0.73581
# [37]	validation_0-rmse:0.70354	validation_1-rmse:0.73234
# [38]	validation_0-rmse:0.69042	validation_1-rmse:0.72864
# [39]	validation_0-rmse:0.68201	validation_1-rmse:0.72660
# [40]	validation_0-rmse:0.67071	validation_1-rmse:0.71735
# [41]	validation_0-rmse:0.66101	validation_1-rmse:0.71140
# [42]	validation_0-rmse:0.65274	validation_1-rmse:0.71645
# [43]	validation_0-rmse:0.64434	validation_1-rmse:0.71734
# [44]	validation_0-rmse:0.63373	validation_1-rmse:0.71664
# [45]	validation_0-rmse:0.62454	validation_1-rmse:0.71696
# [46]	validation_0-rmse:0.61948	validation_1-rmse:0.71886
# [47]	validation_0-rmse:0.61386	validation_1-rmse:0.72138
# [48]	validation_0-rmse:0.60947	validation_1-rmse:0.72088
# [49]	validation_0-rmse:0.60510	validation_1-rmse:0.71919
# [50]	validation_0-rmse:0.59574	validation_1-rmse:0.73115
# [0]	validation_0-rmse:7.69933	validation_1-rmse:6.92797
# [1]	validation_0-rmse:7.02428	validation_1-rmse:6.24798
# [2]	validation_0-rmse:6.41337	validation_1-rmse:5.66664
# [3]	validation_0-rmse:5.85571	validation_1-rmse:5.13836
# [4]	validation_0-rmse:5.35057	validation_1-rmse:4.66172
# [5]	validation_0-rmse:4.89303	validation_1-rmse:4.22612
# [6]	validation_0-rmse:4.47358	validation_1-rmse:3.82746
# [7]	validation_0-rmse:4.09575	validation_1-rmse:3.49248
# [8]	validation_0-rmse:3.75014	validation_1-rmse:3.17081
# [9]	validation_0-rmse:3.43598	validation_1-rmse:2.87508
# [10]	validation_0-rmse:3.15213	validation_1-rmse:2.60843
# [11]	validation_0-rmse:2.89342	validation_1-rmse:2.36685
# [12]	validation_0-rmse:2.65398	validation_1-rmse:2.16977
# [13]	validation_0-rmse:2.44128	validation_1-rmse:1.97336
# [14]	validation_0-rmse:2.25333	validation_1-rmse:1.81447
# [15]	validation_0-rmse:2.07385	validation_1-rmse:1.66810
# [16]	validation_0-rmse:1.91535	validation_1-rmse:1.53582
# [17]	validation_0-rmse:1.76949	validation_1-rmse:1.41800
# [18]	validation_0-rmse:1.64237	validation_1-rmse:1.32203
# [19]	validation_0-rmse:1.52474	validation_1-rmse:1.23627
# [20]	validation_0-rmse:1.42047	validation_1-rmse:1.15339
# [21]	validation_0-rmse:1.32038	validation_1-rmse:1.09403
# [22]	validation_0-rmse:1.23807	validation_1-rmse:1.04209
# [23]	validation_0-rmse:1.16361	validation_1-rmse:0.98890
# [24]	validation_0-rmse:1.08961	validation_1-rmse:0.95931
# [25]	validation_0-rmse:1.02495	validation_1-rmse:0.92737
# [26]	validation_0-rmse:0.96825	validation_1-rmse:0.90877
# [27]	validation_0-rmse:0.92661	validation_1-rmse:0.89503
# [28]	validation_0-rmse:0.88053	validation_1-rmse:0.88248
# [29]	validation_0-rmse:0.83995	validation_1-rmse:0.86918
# [30]	validation_0-rmse:0.80393	validation_1-rmse:0.86774
# [31]	validation_0-rmse:0.77249	validation_1-rmse:0.86672
# [32]	validation_0-rmse:0.74355	validation_1-rmse:0.86278
# [33]	validation_0-rmse:0.71646	validation_1-rmse:0.85672
# [34]	validation_0-rmse:0.69316	validation_1-rmse:0.85557
# [35]	validation_0-rmse:0.67432	validation_1-rmse:0.85190
# [36]	validation_0-rmse:0.65591	validation_1-rmse:0.84980
# [37]	validation_0-rmse:0.64070	validation_1-rmse:0.84892
# [38]	validation_0-rmse:0.62683	validation_1-rmse:0.84838
# [39]	validation_0-rmse:0.61437	validation_1-rmse:0.84898
# [40]	validation_0-rmse:0.60286	validation_1-rmse:0.85083
# [41]	validation_0-rmse:0.59208	validation_1-rmse:0.85407
# [42]	validation_0-rmse:0.58456	validation_1-rmse:0.85856
# [43]	validation_0-rmse:0.57595	validation_1-rmse:0.86019
# [44]	validation_0-rmse:0.56883	validation_1-rmse:0.86085
# [45]	validation_0-rmse:0.55631	validation_1-rmse:0.85409
# [46]	validation_0-rmse:0.54918	validation_1-rmse:0.85767
# [47]	validation_0-rmse:0.54176	validation_1-rmse:0.85933
# [48]	validation_0-rmse:0.53587	validation_1-rmse:0.86441
# [0]	validation_0-rmse:7.55485	validation_1-rmse:7.59422
# [1]	validation_0-rmse:6.89153	validation_1-rmse:6.93162
# [2]	validation_0-rmse:6.28611	validation_1-rmse:6.33565
# [3]	validation_0-rmse:5.73809	validation_1-rmse:5.79922
# [4]	validation_0-rmse:5.23703	validation_1-rmse:5.30553
# [5]	validation_0-rmse:4.79022	validation_1-rmse:4.86943
# [6]	validation_0-rmse:4.37989	validation_1-rmse:4.47181
# [7]	validation_0-rmse:4.00725	validation_1-rmse:4.10541
# [8]	validation_0-rmse:3.66927	validation_1-rmse:3.78006
# [9]	validation_0-rmse:3.36719	validation_1-rmse:3.48524
# [10]	validation_0-rmse:3.08976	validation_1-rmse:3.22114
# [11]	validation_0-rmse:2.84005	validation_1-rmse:2.97983
# [12]	validation_0-rmse:2.60948	validation_1-rmse:2.76229
# [13]	validation_0-rmse:2.40361	validation_1-rmse:2.56785
# [14]	validation_0-rmse:2.21289	validation_1-rmse:2.38982
# [15]	validation_0-rmse:2.04024	validation_1-rmse:2.23086
# [16]	validation_0-rmse:1.88031	validation_1-rmse:2.08631
# [17]	validation_0-rmse:1.73658	validation_1-rmse:1.95249
# [18]	validation_0-rmse:1.60836	validation_1-rmse:1.83494
# [19]	validation_0-rmse:1.49649	validation_1-rmse:1.73196
# [20]	validation_0-rmse:1.39720	validation_1-rmse:1.64501
# [21]	validation_0-rmse:1.30359	validation_1-rmse:1.56238
# [22]	validation_0-rmse:1.21741	validation_1-rmse:1.48572
# [23]	validation_0-rmse:1.14424	validation_1-rmse:1.42648
# [24]	validation_0-rmse:1.07363	validation_1-rmse:1.37211
# [25]	validation_0-rmse:1.00936	validation_1-rmse:1.32691
# [26]	validation_0-rmse:0.95607	validation_1-rmse:1.28459
# [27]	validation_0-rmse:0.90463	validation_1-rmse:1.24304
# [28]	validation_0-rmse:0.86017	validation_1-rmse:1.20367
# [29]	validation_0-rmse:0.82254	validation_1-rmse:1.17204
# [30]	validation_0-rmse:0.78858	validation_1-rmse:1.14297
# [31]	validation_0-rmse:0.75811	validation_1-rmse:1.11296
# [32]	validation_0-rmse:0.73287	validation_1-rmse:1.08507
# [33]	validation_0-rmse:0.70971	validation_1-rmse:1.06534
# [34]	validation_0-rmse:0.69142	validation_1-rmse:1.05329
# [35]	validation_0-rmse:0.67535	validation_1-rmse:1.04728
# [36]	validation_0-rmse:0.65605	validation_1-rmse:1.03591
# [37]	validation_0-rmse:0.64068	validation_1-rmse:1.02134
# [38]	validation_0-rmse:0.62678	validation_1-rmse:1.00731
# [39]	validation_0-rmse:0.61513	validation_1-rmse:1.00472
# [40]	validation_0-rmse:0.60514	validation_1-rmse:0.99284
# [41]	validation_0-rmse:0.59529	validation_1-rmse:0.98382
# [42]	validation_0-rmse:0.58790	validation_1-rmse:0.98166
# [43]	validation_0-rmse:0.57997	validation_1-rmse:0.97549
# [44]	validation_0-rmse:0.57251	validation_1-rmse:0.96775
# [45]	validation_0-rmse:0.56634	validation_1-rmse:0.96194
# [46]	validation_0-rmse:0.55996	validation_1-rmse:0.96172
# [47]	validation_0-rmse:0.55326	validation_1-rmse:0.95888
# [48]	validation_0-rmse:0.54804	validation_1-rmse:0.95289
# [49]	validation_0-rmse:0.54288	validation_1-rmse:0.94906
# [50]	validation_0-rmse:0.53842	validation_1-rmse:0.94972
# [51]	validation_0-rmse:0.53457	validation_1-rmse:0.94503
# [52]	validation_0-rmse:0.53053	validation_1-rmse:0.94267
# [53]	validation_0-rmse:0.52534	validation_1-rmse:0.94166
# [54]	validation_0-rmse:0.52193	validation_1-rmse:0.93997
# [0]	validation_0-rmse:7.62601	validation_1-rmse:7.29279
# [1]	validation_0-rmse:6.96372	validation_1-rmse:6.62440
# [2]	validation_0-rmse:6.35296	validation_1-rmse:6.01815
# [3]	validation_0-rmse:5.80278	validation_1-rmse:5.47163
# [4]	validation_0-rmse:5.30061	validation_1-rmse:4.95776
# [5]	validation_0-rmse:4.84632	validation_1-rmse:4.50662
# [6]	validation_0-rmse:4.43463	validation_1-rmse:4.08456
# [7]	validation_0-rmse:4.06067	validation_1-rmse:3.70841
# [8]	validation_0-rmse:3.71942	validation_1-rmse:3.37730
# [9]	validation_0-rmse:3.41188	validation_1-rmse:3.08047
# [10]	validation_0-rmse:3.13021	validation_1-rmse:2.79691
# [11]	validation_0-rmse:2.87408	validation_1-rmse:2.53902
# [12]	validation_0-rmse:2.64148	validation_1-rmse:2.31761
# [13]	validation_0-rmse:2.43669	validation_1-rmse:2.12060
# [14]	validation_0-rmse:2.24247	validation_1-rmse:1.95948
# [15]	validation_0-rmse:2.06814	validation_1-rmse:1.79795
# [16]	validation_0-rmse:1.90859	validation_1-rmse:1.66186
# [17]	validation_0-rmse:1.76395	validation_1-rmse:1.54768
# [18]	validation_0-rmse:1.63298	validation_1-rmse:1.43932
# [19]	validation_0-rmse:1.52090	validation_1-rmse:1.33923
# [20]	validation_0-rmse:1.42109	validation_1-rmse:1.25513
# [21]	validation_0-rmse:1.33013	validation_1-rmse:1.17568
# [22]	validation_0-rmse:1.24516	validation_1-rmse:1.11378
# [23]	validation_0-rmse:1.17729	validation_1-rmse:1.06611
# [24]	validation_0-rmse:1.11393	validation_1-rmse:1.01156
# [25]	validation_0-rmse:1.05075	validation_1-rmse:0.97584
# [26]	validation_0-rmse:0.99668	validation_1-rmse:0.94381
# [27]	validation_0-rmse:0.95417	validation_1-rmse:0.91373
# [28]	validation_0-rmse:0.90916	validation_1-rmse:0.88107
# [29]	validation_0-rmse:0.87605	validation_1-rmse:0.85650
# [30]	validation_0-rmse:0.84633	validation_1-rmse:0.83390
# [31]	validation_0-rmse:0.81451	validation_1-rmse:0.82054
# [32]	validation_0-rmse:0.78619	validation_1-rmse:0.80251
# [33]	validation_0-rmse:0.76166	validation_1-rmse:0.78762
# [34]	validation_0-rmse:0.74367	validation_1-rmse:0.78649
# [35]	validation_0-rmse:0.72725	validation_1-rmse:0.77293
# [36]	validation_0-rmse:0.71014	validation_1-rmse:0.77169
# [37]	validation_0-rmse:0.69354	validation_1-rmse:0.76352
# [38]	validation_0-rmse:0.67953	validation_1-rmse:0.75913
# [39]	validation_0-rmse:0.66879	validation_1-rmse:0.75219
# [40]	validation_0-rmse:0.65884	validation_1-rmse:0.75817
# [41]	validation_0-rmse:0.64917	validation_1-rmse:0.75610
# [42]	validation_0-rmse:0.64033	validation_1-rmse:0.76297
# [43]	validation_0-rmse:0.63282	validation_1-rmse:0.76002
# [44]	validation_0-rmse:0.62525	validation_1-rmse:0.75876
# [45]	validation_0-rmse:0.61926	validation_1-rmse:0.75629
# [46]	validation_0-rmse:0.61358	validation_1-rmse:0.75662
# [47]	validation_0-rmse:0.60827	validation_1-rmse:0.75601
# [48]	validation_0-rmse:0.60328	validation_1-rmse:0.75490
# [49]	validation_0-rmse:0.59755	validation_1-rmse:0.75314
# [0]	validation_0-rmse:7.50481	validation_1-rmse:7.78286
# [1]	validation_0-rmse:6.84102	validation_1-rmse:7.12490
# [2]	validation_0-rmse:6.24331	validation_1-rmse:6.50478
# [3]	validation_0-rmse:5.69807	validation_1-rmse:5.93960
# [4]	validation_0-rmse:5.20066	validation_1-rmse:5.44050
# [5]	validation_0-rmse:4.75070	validation_1-rmse:4.98692
# [6]	validation_0-rmse:4.34422	validation_1-rmse:4.56537
# [7]	validation_0-rmse:3.97369	validation_1-rmse:4.19024
# [8]	validation_0-rmse:3.63570	validation_1-rmse:3.83716
# [9]	validation_0-rmse:3.33565	validation_1-rmse:3.52389
# [10]	validation_0-rmse:3.06176	validation_1-rmse:3.22727
# [11]	validation_0-rmse:2.81578	validation_1-rmse:2.95932
# [12]	validation_0-rmse:2.58805	validation_1-rmse:2.72421
# [13]	validation_0-rmse:2.38926	validation_1-rmse:2.52165
# [14]	validation_0-rmse:2.20143	validation_1-rmse:2.33574
# [15]	validation_0-rmse:2.03070	validation_1-rmse:2.16341
# [16]	validation_0-rmse:1.87327	validation_1-rmse:2.00793
# [17]	validation_0-rmse:1.72930	validation_1-rmse:1.86038
# [18]	validation_0-rmse:1.60295	validation_1-rmse:1.72907
# [19]	validation_0-rmse:1.49334	validation_1-rmse:1.60856
# [20]	validation_0-rmse:1.39490	validation_1-rmse:1.50574
# [21]	validation_0-rmse:1.30081	validation_1-rmse:1.41582
# [22]	validation_0-rmse:1.22028	validation_1-rmse:1.33589
# [23]	validation_0-rmse:1.15016	validation_1-rmse:1.28056
# [24]	validation_0-rmse:1.08525	validation_1-rmse:1.22757
# [25]	validation_0-rmse:1.02550	validation_1-rmse:1.16617
# [26]	validation_0-rmse:0.97254	validation_1-rmse:1.11188
# [27]	validation_0-rmse:0.92138	validation_1-rmse:1.06500
# [28]	validation_0-rmse:0.87984	validation_1-rmse:1.02782
# [29]	validation_0-rmse:0.84295	validation_1-rmse:0.99825
# [30]	validation_0-rmse:0.80951	validation_1-rmse:0.97408
# [31]	validation_0-rmse:0.78175	validation_1-rmse:0.95053
# [32]	validation_0-rmse:0.75730	validation_1-rmse:0.93128
# [33]	validation_0-rmse:0.73396	validation_1-rmse:0.91143
# [34]	validation_0-rmse:0.71347	validation_1-rmse:0.90321
# [35]	validation_0-rmse:0.69760	validation_1-rmse:0.88575
# [36]	validation_0-rmse:0.68167	validation_1-rmse:0.87671
# [37]	validation_0-rmse:0.66779	validation_1-rmse:0.86943
# [38]	validation_0-rmse:0.65593	validation_1-rmse:0.86365
# [39]	validation_0-rmse:0.64586	validation_1-rmse:0.85388
# [40]	validation_0-rmse:0.63498	validation_1-rmse:0.85497
# [41]	validation_0-rmse:0.62477	validation_1-rmse:0.84786
# [42]	validation_0-rmse:0.61694	validation_1-rmse:0.84928
# [43]	validation_0-rmse:0.60923	validation_1-rmse:0.84385
# [44]	validation_0-rmse:0.60296	validation_1-rmse:0.84104
# [45]	validation_0-rmse:0.59719	validation_1-rmse:0.83713
# [46]	validation_0-rmse:0.59138	validation_1-rmse:0.83582
# [47]	validation_0-rmse:0.58629	validation_1-rmse:0.83390
# [48]	validation_0-rmse:0.58117	validation_1-rmse:0.83904
# [49]	validation_0-rmse:0.57670	validation_1-rmse:0.83792
# [50]	validation_0-rmse:0.57270	validation_1-rmse:0.83777
# [51]	validation_0-rmse:0.56993	validation_1-rmse:0.83688
# [52]	validation_0-rmse:0.56649	validation_1-rmse:0.83518
# [53]	validation_0-rmse:0.56306	validation_1-rmse:0.83808
# [54]	validation_0-rmse:0.56019	validation_1-rmse:0.83763
# [0]	validation_0-rmse:7.59218	validation_1-rmse:7.46414
# [1]	validation_0-rmse:6.92659	validation_1-rmse:6.79575
# [2]	validation_0-rmse:6.32293	validation_1-rmse:6.22983
# [3]	validation_0-rmse:5.77536	validation_1-rmse:5.71402
# [4]	validation_0-rmse:5.28055	validation_1-rmse:5.22482
# [5]	validation_0-rmse:4.83462	validation_1-rmse:4.80299
# [6]	validation_0-rmse:4.42064	validation_1-rmse:4.39180
# [7]	validation_0-rmse:4.04574	validation_1-rmse:4.03570
# [8]	validation_0-rmse:3.70278	validation_1-rmse:3.70968
# [9]	validation_0-rmse:3.39646	validation_1-rmse:3.41538
# [10]	validation_0-rmse:3.11650	validation_1-rmse:3.14675
# [11]	validation_0-rmse:2.86427	validation_1-rmse:2.91092
# [12]	validation_0-rmse:2.63911	validation_1-rmse:2.69661
# [13]	validation_0-rmse:2.43866	validation_1-rmse:2.49995
# [14]	validation_0-rmse:2.24504	validation_1-rmse:2.32191
# [15]	validation_0-rmse:2.07111	validation_1-rmse:2.14697
# [16]	validation_0-rmse:1.91405	validation_1-rmse:1.99094
# [17]	validation_0-rmse:1.76945	validation_1-rmse:1.85077
# [18]	validation_0-rmse:1.64021	validation_1-rmse:1.73672
# [19]	validation_0-rmse:1.52343	validation_1-rmse:1.62848
# [20]	validation_0-rmse:1.42439	validation_1-rmse:1.53831
# [21]	validation_0-rmse:1.32953	validation_1-rmse:1.45211
# [22]	validation_0-rmse:1.24160	validation_1-rmse:1.36826
# [23]	validation_0-rmse:1.16915	validation_1-rmse:1.29881
# [24]	validation_0-rmse:1.10045	validation_1-rmse:1.23346
# [25]	validation_0-rmse:1.03839	validation_1-rmse:1.17433
# [26]	validation_0-rmse:0.98591	validation_1-rmse:1.12222
# [27]	validation_0-rmse:0.93665	validation_1-rmse:1.07644
# [28]	validation_0-rmse:0.89205	validation_1-rmse:1.03568
# [29]	validation_0-rmse:0.85443	validation_1-rmse:1.00229
# [30]	validation_0-rmse:0.82119	validation_1-rmse:0.97137
# [31]	validation_0-rmse:0.78894	validation_1-rmse:0.94336
# [32]	validation_0-rmse:0.76280	validation_1-rmse:0.92470
# [33]	validation_0-rmse:0.73834	validation_1-rmse:0.90460
# [34]	validation_0-rmse:0.71824	validation_1-rmse:0.89067
# [35]	validation_0-rmse:0.70104	validation_1-rmse:0.87930
# [36]	validation_0-rmse:0.68359	validation_1-rmse:0.86989
# [37]	validation_0-rmse:0.66696	validation_1-rmse:0.85847
# [38]	validation_0-rmse:0.65255	validation_1-rmse:0.84800
# [39]	validation_0-rmse:0.64297	validation_1-rmse:0.83445
# [40]	validation_0-rmse:0.63277	validation_1-rmse:0.82791
# [41]	validation_0-rmse:0.62327	validation_1-rmse:0.82012
# [42]	validation_0-rmse:0.61579	validation_1-rmse:0.81723
# [43]	validation_0-rmse:0.60311	validation_1-rmse:0.80098
# [44]	validation_0-rmse:0.59539	validation_1-rmse:0.79860
# [45]	validation_0-rmse:0.58826	validation_1-rmse:0.79228
# [46]	validation_0-rmse:0.58079	validation_1-rmse:0.79054
# [47]	validation_0-rmse:0.57537	validation_1-rmse:0.78862
# [48]	validation_0-rmse:0.57100	validation_1-rmse:0.78824
# [49]	validation_0-rmse:0.56487	validation_1-rmse:0.78855
# [50]	validation_0-rmse:0.56040	validation_1-rmse:0.78746
# [51]	validation_0-rmse:0.55649	validation_1-rmse:0.78745
# [52]	validation_0-rmse:0.55100	validation_1-rmse:0.78732
# [53]	validation_0-rmse:0.54781	validation_1-rmse:0.78513
# [54]	validation_0-rmse:0.54449	validation_1-rmse:0.78414
# [0]	validation_0-rmse:7.53293	validation_1-rmse:7.64684
# [1]	validation_0-rmse:6.87185	validation_1-rmse:6.98350
# [2]	validation_0-rmse:6.27166	validation_1-rmse:6.34663
# [3]	validation_0-rmse:5.72650	validation_1-rmse:5.76862
# [4]	validation_0-rmse:5.22963	validation_1-rmse:5.24133
# [5]	validation_0-rmse:4.78074	validation_1-rmse:4.78245
# [6]	validation_0-rmse:4.37347	validation_1-rmse:4.34547
# [7]	validation_0-rmse:4.00441	validation_1-rmse:3.96955
# [8]	validation_0-rmse:3.66756	validation_1-rmse:3.62644
# [9]	validation_0-rmse:3.36830	validation_1-rmse:3.33232
# [10]	validation_0-rmse:3.09642	validation_1-rmse:3.06114
# [11]	validation_0-rmse:2.84496	validation_1-rmse:2.80398
# [12]	validation_0-rmse:2.61889	validation_1-rmse:2.57036
# [13]	validation_0-rmse:2.41773	validation_1-rmse:2.36234
# [14]	validation_0-rmse:2.22606	validation_1-rmse:2.17677
# [15]	validation_0-rmse:2.05394	validation_1-rmse:1.99421
# [16]	validation_0-rmse:1.90230	validation_1-rmse:1.82885
# [17]	validation_0-rmse:1.76565	validation_1-rmse:1.68024
# [18]	validation_0-rmse:1.64071	validation_1-rmse:1.54506
# [19]	validation_0-rmse:1.53167	validation_1-rmse:1.42565
# [20]	validation_0-rmse:1.43400	validation_1-rmse:1.31913
# [21]	validation_0-rmse:1.34310	validation_1-rmse:1.22075
# [22]	validation_0-rmse:1.26077	validation_1-rmse:1.13532
# [23]	validation_0-rmse:1.19166	validation_1-rmse:1.06320
# [24]	validation_0-rmse:1.12585	validation_1-rmse:0.99494
# [25]	validation_0-rmse:1.06675	validation_1-rmse:0.93274
# [26]	validation_0-rmse:1.01619	validation_1-rmse:0.88167
# [27]	validation_0-rmse:0.96863	validation_1-rmse:0.83550
# [28]	validation_0-rmse:0.92698	validation_1-rmse:0.79114
# [29]	validation_0-rmse:0.89103	validation_1-rmse:0.75601
# [30]	validation_0-rmse:0.85878	validation_1-rmse:0.72854
# [31]	validation_0-rmse:0.83110	validation_1-rmse:0.70766
# [32]	validation_0-rmse:0.80469	validation_1-rmse:0.68562
# [33]	validation_0-rmse:0.78287	validation_1-rmse:0.66743
# [34]	validation_0-rmse:0.76468	validation_1-rmse:0.65113
# [35]	validation_0-rmse:0.74758	validation_1-rmse:0.64250
# [36]	validation_0-rmse:0.73295	validation_1-rmse:0.63278
# [37]	validation_0-rmse:0.71918	validation_1-rmse:0.62247
# [38]	validation_0-rmse:0.70686	validation_1-rmse:0.61417
# [39]	validation_0-rmse:0.69549	validation_1-rmse:0.60609
# [40]	validation_0-rmse:0.68426	validation_1-rmse:0.60335
# [41]	validation_0-rmse:0.67534	validation_1-rmse:0.60021
# [42]	validation_0-rmse:0.66738	validation_1-rmse:0.59617
# [43]	validation_0-rmse:0.65980	validation_1-rmse:0.59413
# [44]	validation_0-rmse:0.65180	validation_1-rmse:0.58835
# [45]	validation_0-rmse:0.64629	validation_1-rmse:0.58709
# [46]	validation_0-rmse:0.63990	validation_1-rmse:0.58653
# [47]	validation_0-rmse:0.63503	validation_1-rmse:0.58544
# [48]	validation_0-rmse:0.63069	validation_1-rmse:0.58598
# [49]	validation_0-rmse:0.62502	validation_1-rmse:0.57947
# [50]	validation_0-rmse:0.61974	validation_1-rmse:0.58000
# [51]	validation_0-rmse:0.60982	validation_1-rmse:0.57548
# [52]	validation_0-rmse:0.60652	validation_1-rmse:0.57535
# [53]	validation_0-rmse:0.60349	validation_1-rmse:0.57296
# [54]	validation_0-rmse:0.60036	validation_1-rmse:0.57288
# [0]	validation_0-rmse:7.50850	validation_1-rmse:7.74051
# [1]	validation_0-rmse:6.85615	validation_1-rmse:7.08824
# [2]	validation_0-rmse:6.25275	validation_1-rmse:6.46221
# [3]	validation_0-rmse:5.70587	validation_1-rmse:5.89497
# [4]	validation_0-rmse:5.21838	validation_1-rmse:5.39128
# [5]	validation_0-rmse:4.77427	validation_1-rmse:4.93358
# [6]	validation_0-rmse:4.36736	validation_1-rmse:4.51505
# [7]	validation_0-rmse:4.00040	validation_1-rmse:4.14112
# [8]	validation_0-rmse:3.66261	validation_1-rmse:3.79160
# [9]	validation_0-rmse:3.35771	validation_1-rmse:3.47847
# [10]	validation_0-rmse:3.08314	validation_1-rmse:3.19031
# [11]	validation_0-rmse:2.83604	validation_1-rmse:2.93022
# [12]	validation_0-rmse:2.61337	validation_1-rmse:2.70510
# [13]	validation_0-rmse:2.41158	validation_1-rmse:2.49828
# [14]	validation_0-rmse:2.22601	validation_1-rmse:2.30512
# [15]	validation_0-rmse:2.05375	validation_1-rmse:2.12634
# [16]	validation_0-rmse:1.90330	validation_1-rmse:1.96315
# [17]	validation_0-rmse:1.76539	validation_1-rmse:1.81262
# [18]	validation_0-rmse:1.64125	validation_1-rmse:1.69476
# [19]	validation_0-rmse:1.53002	validation_1-rmse:1.58003
# [20]	validation_0-rmse:1.42900	validation_1-rmse:1.47266
# [21]	validation_0-rmse:1.33629	validation_1-rmse:1.37189
# [22]	validation_0-rmse:1.25350	validation_1-rmse:1.29100
# [23]	validation_0-rmse:1.18243	validation_1-rmse:1.22948
# [24]	validation_0-rmse:1.11637	validation_1-rmse:1.16463
# [25]	validation_0-rmse:1.05565	validation_1-rmse:1.10861
# [26]	validation_0-rmse:1.00180	validation_1-rmse:1.05475
# [27]	validation_0-rmse:0.95544	validation_1-rmse:1.01025
# [28]	validation_0-rmse:0.91469	validation_1-rmse:0.97519
# [29]	validation_0-rmse:0.87790	validation_1-rmse:0.94043
# [30]	validation_0-rmse:0.84538	validation_1-rmse:0.91498
# [31]	validation_0-rmse:0.81618	validation_1-rmse:0.89155
# [32]	validation_0-rmse:0.79272	validation_1-rmse:0.87135
# [33]	validation_0-rmse:0.77128	validation_1-rmse:0.85653
# [34]	validation_0-rmse:0.75094	validation_1-rmse:0.84336
# [35]	validation_0-rmse:0.73295	validation_1-rmse:0.82995
# [36]	validation_0-rmse:0.71694	validation_1-rmse:0.81709
# [37]	validation_0-rmse:0.70366	validation_1-rmse:0.80854
# [38]	validation_0-rmse:0.69122	validation_1-rmse:0.79998
# [39]	validation_0-rmse:0.68044	validation_1-rmse:0.79372
# [40]	validation_0-rmse:0.67025	validation_1-rmse:0.79250
# [41]	validation_0-rmse:0.66205	validation_1-rmse:0.78592
# [42]	validation_0-rmse:0.65438	validation_1-rmse:0.78062
# [43]	validation_0-rmse:0.63872	validation_1-rmse:0.77204
# [44]	validation_0-rmse:0.63206	validation_1-rmse:0.76670
# [45]	validation_0-rmse:0.62564	validation_1-rmse:0.77069
# [46]	validation_0-rmse:0.62073	validation_1-rmse:0.76477
# [47]	validation_0-rmse:0.61528	validation_1-rmse:0.76216
# [48]	validation_0-rmse:0.61022	validation_1-rmse:0.75934
# [49]	validation_0-rmse:0.60596	validation_1-rmse:0.76085
# [50]	validation_0-rmse:0.60199	validation_1-rmse:0.76048
# [51]	validation_0-rmse:0.59801	validation_1-rmse:0.75101
# [52]	validation_0-rmse:0.59497	validation_1-rmse:0.74960
# [53]	validation_0-rmse:0.59164	validation_1-rmse:0.75320
# [54]	validation_0-rmse:0.58868	validation_1-rmse:0.75292
# [0]	validation_0-rmse:7.59167	validation_1-rmse:7.42426
# [1]	validation_0-rmse:6.93478	validation_1-rmse:6.77322
# [2]	validation_0-rmse:6.33018	validation_1-rmse:6.18807
# [3]	validation_0-rmse:5.77864	validation_1-rmse:5.65447
# [4]	validation_0-rmse:5.28279	validation_1-rmse:5.17449
# [5]	validation_0-rmse:4.82830	validation_1-rmse:4.71718
# [6]	validation_0-rmse:4.41815	validation_1-rmse:4.30225
# [7]	validation_0-rmse:4.03835	validation_1-rmse:3.91833
# [8]	validation_0-rmse:3.69704	validation_1-rmse:3.61417
# [9]	validation_0-rmse:3.38776	validation_1-rmse:3.32814
# [10]	validation_0-rmse:3.10889	validation_1-rmse:3.07905
# [11]	validation_0-rmse:2.86704	validation_1-rmse:2.85664
# [12]	validation_0-rmse:2.63316	validation_1-rmse:2.62598
# [13]	validation_0-rmse:2.42504	validation_1-rmse:2.44051
# [14]	validation_0-rmse:2.23326	validation_1-rmse:2.24903
# [15]	validation_0-rmse:2.06325	validation_1-rmse:2.08789
# [16]	validation_0-rmse:1.90661	validation_1-rmse:1.93286
# [17]	validation_0-rmse:1.76154	validation_1-rmse:1.79569
# [18]	validation_0-rmse:1.63432	validation_1-rmse:1.66937
# [19]	validation_0-rmse:1.52104	validation_1-rmse:1.56889
# [20]	validation_0-rmse:1.41927	validation_1-rmse:1.49320
# [21]	validation_0-rmse:1.32205	validation_1-rmse:1.39897
# [22]	validation_0-rmse:1.23812	validation_1-rmse:1.32921
# [23]	validation_0-rmse:1.16555	validation_1-rmse:1.26969
# [24]	validation_0-rmse:1.09608	validation_1-rmse:1.20340
# [25]	validation_0-rmse:1.03444	validation_1-rmse:1.15374
# [26]	validation_0-rmse:0.97615	validation_1-rmse:1.09873
# [27]	validation_0-rmse:0.92903	validation_1-rmse:1.05641
# [28]	validation_0-rmse:0.88774	validation_1-rmse:1.02562
# [29]	validation_0-rmse:0.84782	validation_1-rmse:0.98771
# [30]	validation_0-rmse:0.81192	validation_1-rmse:0.95950
# [31]	validation_0-rmse:0.78256	validation_1-rmse:0.94082
# [32]	validation_0-rmse:0.75531	validation_1-rmse:0.92424
# [33]	validation_0-rmse:0.73155	validation_1-rmse:0.91116
# [34]	validation_0-rmse:0.70930	validation_1-rmse:0.90761
# [35]	validation_0-rmse:0.68969	validation_1-rmse:0.91001
# [36]	validation_0-rmse:0.67312	validation_1-rmse:0.89786
# [37]	validation_0-rmse:0.65820	validation_1-rmse:0.88759
# [38]	validation_0-rmse:0.64600	validation_1-rmse:0.87916
# [39]	validation_0-rmse:0.63228	validation_1-rmse:0.88231
# [40]	validation_0-rmse:0.62352	validation_1-rmse:0.88606
# [41]	validation_0-rmse:0.61440	validation_1-rmse:0.88034
# [42]	validation_0-rmse:0.60773	validation_1-rmse:0.88242
# [43]	validation_0-rmse:0.59999	validation_1-rmse:0.87759
# [44]	validation_0-rmse:0.59335	validation_1-rmse:0.87097
# [45]	validation_0-rmse:0.58763	validation_1-rmse:0.86632
# [46]	validation_0-rmse:0.58078	validation_1-rmse:0.87171
# [47]	validation_0-rmse:0.57544	validation_1-rmse:0.86565
# [48]	validation_0-rmse:0.57044	validation_1-rmse:0.86909
# [49]	validation_0-rmse:0.56512	validation_1-rmse:0.86606
# [50]	validation_0-rmse:0.56117	validation_1-rmse:0.86497
# [51]	validation_0-rmse:0.55747	validation_1-rmse:0.86490
# [52]	validation_0-rmse:0.55415	validation_1-rmse:0.86372
# [53]	validation_0-rmse:0.55182	validation_1-rmse:0.86320
# [54]	validation_0-rmse:0.54889	validation_1-rmse:0.86228
# [0]	validation_0-rmse:7.43450	validation_1-rmse:8.03723
# [1]	validation_0-rmse:6.78906	validation_1-rmse:7.39017
# [2]	validation_0-rmse:6.19847	validation_1-rmse:6.77706
# [3]	validation_0-rmse:5.66412	validation_1-rmse:6.22136
# [4]	validation_0-rmse:5.17362	validation_1-rmse:5.70900
# [5]	validation_0-rmse:4.73282	validation_1-rmse:5.28142
# [6]	validation_0-rmse:4.32528	validation_1-rmse:4.85518
# [7]	validation_0-rmse:3.95664	validation_1-rmse:4.48467
# [8]	validation_0-rmse:3.62741	validation_1-rmse:4.15329
# [9]	validation_0-rmse:3.32833	validation_1-rmse:3.85171
# [10]	validation_0-rmse:3.05632	validation_1-rmse:3.57673
# [11]	validation_0-rmse:2.81002	validation_1-rmse:3.32707
# [12]	validation_0-rmse:2.58825	validation_1-rmse:3.08859
# [13]	validation_0-rmse:2.38954	validation_1-rmse:2.89381
# [14]	validation_0-rmse:2.20278	validation_1-rmse:2.69782
# [15]	validation_0-rmse:2.02999	validation_1-rmse:2.50803
# [16]	validation_0-rmse:1.87671	validation_1-rmse:2.33667
# [17]	validation_0-rmse:1.73551	validation_1-rmse:2.18143
# [18]	validation_0-rmse:1.61341	validation_1-rmse:2.04619
# [19]	validation_0-rmse:1.50261	validation_1-rmse:1.94425
# [20]	validation_0-rmse:1.40510	validation_1-rmse:1.85648
# [21]	validation_0-rmse:1.31256	validation_1-rmse:1.74799
# [22]	validation_0-rmse:1.23066	validation_1-rmse:1.64826
# [23]	validation_0-rmse:1.15943	validation_1-rmse:1.57970
# [24]	validation_0-rmse:1.09506	validation_1-rmse:1.49226
# [25]	validation_0-rmse:1.03725	validation_1-rmse:1.42209
# [26]	validation_0-rmse:0.98489	validation_1-rmse:1.34831
# [27]	validation_0-rmse:0.93758	validation_1-rmse:1.28319
# [28]	validation_0-rmse:0.89576	validation_1-rmse:1.22143
# [29]	validation_0-rmse:0.85940	validation_1-rmse:1.16793
# [30]	validation_0-rmse:0.82907	validation_1-rmse:1.12197
# [31]	validation_0-rmse:0.80184	validation_1-rmse:1.07931
# [32]	validation_0-rmse:0.77684	validation_1-rmse:1.04114
# [33]	validation_0-rmse:0.75649	validation_1-rmse:1.00853
# ...
# [30]	validation_0-rmse:0.81896	validation_1-rmse:0.84157
# [31]	validation_0-rmse:0.78863	validation_1-rmse:0.84312
# [32]	validation_0-rmse:0.75708	validation_1-rmse:0.84630
# [33]	validation_0-rmse:0.73005	validation_1-rmse:0.84529
# [34]	validation_0-rmse:0.71333	validation_1-rmse:0.84561
# [35]	validation_0-rmse:0.69401	validation_1-rmse:0.85549
# [36]	validation_0-rmse:0.67604	validation_1-rmse:0.85984
# [37]	validation_0-rmse:0.66007	validation_1-rmse:0.86474
# [0]	validation_0-rmse:7.63585	validation_1-rmse:7.26282
# [1]	validation_0-rmse:6.96295	validation_1-rmse:6.58901
# [2]	validation_0-rmse:6.35663	validation_1-rmse:6.01113
# [3]	validation_0-rmse:5.80089	validation_1-rmse:5.48044
# [4]	validation_0-rmse:5.29556	validation_1-rmse:4.99432
# [5]	validation_0-rmse:4.84260	validation_1-rmse:4.55511
# [6]	validation_0-rmse:4.43333	validation_1-rmse:4.16792
# [7]	validation_0-rmse:4.05808	validation_1-rmse:3.81713
# [8]	validation_0-rmse:3.71667	validation_1-rmse:3.50594
# [9]	validation_0-rmse:3.40885	validation_1-rmse:3.21126
# [10]	validation_0-rmse:3.12812	validation_1-rmse:2.94163
# [11]	validation_0-rmse:2.87455	validation_1-rmse:2.69691
# [12]	validation_0-rmse:2.64426	validation_1-rmse:2.48951
# [13]	validation_0-rmse:2.43947	validation_1-rmse:2.29663
# [14]	validation_0-rmse:2.24531	validation_1-rmse:2.12841
# [15]	validation_0-rmse:2.07481	validation_1-rmse:1.98299
# [16]	validation_0-rmse:1.91477	validation_1-rmse:1.84248
# [17]	validation_0-rmse:1.76782	validation_1-rmse:1.72285
# [18]	validation_0-rmse:1.63856	validation_1-rmse:1.61705
# [19]	validation_0-rmse:1.52603	validation_1-rmse:1.52200
# [20]	validation_0-rmse:1.42605	validation_1-rmse:1.43403
# [21]	validation_0-rmse:1.32900	validation_1-rmse:1.36248
# [22]	validation_0-rmse:1.24460	validation_1-rmse:1.29314
# [23]	validation_0-rmse:1.17495	validation_1-rmse:1.23338
# [24]	validation_0-rmse:1.10360	validation_1-rmse:1.18339
# [25]	validation_0-rmse:1.04017	validation_1-rmse:1.13796
# [26]	validation_0-rmse:0.98530	validation_1-rmse:1.10447
# [27]	validation_0-rmse:0.93404	validation_1-rmse:1.07432
# [28]	validation_0-rmse:0.89039	validation_1-rmse:1.04711
# [29]	validation_0-rmse:0.85036	validation_1-rmse:1.02049
# [30]	validation_0-rmse:0.81653	validation_1-rmse:1.00141
# [31]	validation_0-rmse:0.78580	validation_1-rmse:0.98153
# [32]	validation_0-rmse:0.75865	validation_1-rmse:0.96538
# [33]	validation_0-rmse:0.73580	validation_1-rmse:0.95111
# [34]	validation_0-rmse:0.71570	validation_1-rmse:0.93865
# [35]	validation_0-rmse:0.70099	validation_1-rmse:0.93008
# [36]	validation_0-rmse:0.68172	validation_1-rmse:0.92491
# [37]	validation_0-rmse:0.66649	validation_1-rmse:0.91503
# [38]	validation_0-rmse:0.65382	validation_1-rmse:0.90673
# [39]	validation_0-rmse:0.64400	validation_1-rmse:0.89958
# [40]	validation_0-rmse:0.63354	validation_1-rmse:0.89488
# [41]	validation_0-rmse:0.62378	validation_1-rmse:0.89272
# [42]	validation_0-rmse:0.61582	validation_1-rmse:0.88512
# [43]	validation_0-rmse:0.60826	validation_1-rmse:0.88359
# [44]	validation_0-rmse:0.60124	validation_1-rmse:0.88119
# [45]	validation_0-rmse:0.58799	validation_1-rmse:0.87479
# [46]	validation_0-rmse:0.58237	validation_1-rmse:0.87532
# [47]	validation_0-rmse:0.57437	validation_1-rmse:0.87609
# [48]	validation_0-rmse:0.56988	validation_1-rmse:0.87853
# [49]	validation_0-rmse:0.56460	validation_1-rmse:0.87773
# [50]	validation_0-rmse:0.55995	validation_1-rmse:0.87695
# [51]	validation_0-rmse:0.55588	validation_1-rmse:0.87580
# [52]	validation_0-rmse:0.55171	validation_1-rmse:0.87344
# [53]	validation_0-rmse:0.54827	validation_1-rmse:0.87350
# [54]	validation_0-rmse:0.54503	validation_1-rmse:0.87332
# [0]	validation_0-rmse:7.45277	validation_1-rmse:8.00836
# [1]	validation_0-rmse:6.79766	validation_1-rmse:7.34836
# [2]	validation_0-rmse:6.20541	validation_1-rmse:6.73950
# [3]	validation_0-rmse:5.66862	validation_1-rmse:6.18726
# [4]	validation_0-rmse:5.18577	validation_1-rmse:5.69029
# [5]	validation_0-rmse:4.73894	validation_1-rmse:5.21864
# [6]	validation_0-rmse:4.33383	validation_1-rmse:4.79886
# [7]	validation_0-rmse:3.96582	validation_1-rmse:4.40753
# [8]	validation_0-rmse:3.63159	validation_1-rmse:4.04834
# [9]	validation_0-rmse:3.33331	validation_1-rmse:3.73090
# [10]	validation_0-rmse:3.06441	validation_1-rmse:3.44685
# [11]	validation_0-rmse:2.81940	validation_1-rmse:3.18456
# [12]	validation_0-rmse:2.59015	validation_1-rmse:2.93339
# [13]	validation_0-rmse:2.39117	validation_1-rmse:2.71728
# [14]	validation_0-rmse:2.20271	validation_1-rmse:2.50632
# [15]	validation_0-rmse:2.03681	validation_1-rmse:2.33356
# [16]	validation_0-rmse:1.88299	validation_1-rmse:2.16610
# [17]	validation_0-rmse:1.74793	validation_1-rmse:2.01764
# [18]	validation_0-rmse:1.62118	validation_1-rmse:1.88638
# [19]	validation_0-rmse:1.51259	validation_1-rmse:1.76886
# [20]	validation_0-rmse:1.41330	validation_1-rmse:1.65495
# [21]	validation_0-rmse:1.32025	validation_1-rmse:1.54468
# [22]	validation_0-rmse:1.23813	validation_1-rmse:1.45600
# [23]	validation_0-rmse:1.16684	validation_1-rmse:1.37628
# [24]	validation_0-rmse:1.09817	validation_1-rmse:1.30155
# [25]	validation_0-rmse:1.03609	validation_1-rmse:1.22925
# [26]	validation_0-rmse:0.97965	validation_1-rmse:1.15898
# [27]	validation_0-rmse:0.93411	validation_1-rmse:1.11665
# [28]	validation_0-rmse:0.89324	validation_1-rmse:1.07714
# [29]	validation_0-rmse:0.85489	validation_1-rmse:1.03812
# [30]	validation_0-rmse:0.82083	validation_1-rmse:1.00162
# [31]	validation_0-rmse:0.79044	validation_1-rmse:0.97019
# [32]	validation_0-rmse:0.76491	validation_1-rmse:0.94070
# [33]	validation_0-rmse:0.74110	validation_1-rmse:0.91606
# [34]	validation_0-rmse:0.72093	validation_1-rmse:0.89643
# [35]	validation_0-rmse:0.70228	validation_1-rmse:0.88565
# [36]	validation_0-rmse:0.68695	validation_1-rmse:0.87176
# [37]	validation_0-rmse:0.67271	validation_1-rmse:0.86142
# [38]	validation_0-rmse:0.66035	validation_1-rmse:0.85115
# [39]	validation_0-rmse:0.64819	validation_1-rmse:0.84165
# [40]	validation_0-rmse:0.63669	validation_1-rmse:0.82478
# [41]	validation_0-rmse:0.62735	validation_1-rmse:0.81966
# [42]	validation_0-rmse:0.61780	validation_1-rmse:0.81174
# [43]	validation_0-rmse:0.60800	validation_1-rmse:0.80528
# [44]	validation_0-rmse:0.60034	validation_1-rmse:0.79990
# [45]	validation_0-rmse:0.58709	validation_1-rmse:0.78731
# [46]	validation_0-rmse:0.58033	validation_1-rmse:0.79245
# [47]	validation_0-rmse:0.57493	validation_1-rmse:0.78795
# [48]	validation_0-rmse:0.57094	validation_1-rmse:0.79257
# [49]	validation_0-rmse:0.56637	validation_1-rmse:0.79046
# [50]	validation_0-rmse:0.56231	validation_1-rmse:0.78642
# [51]	validation_0-rmse:0.55826	validation_1-rmse:0.78361
# [52]	validation_0-rmse:0.55326	validation_1-rmse:0.78331
# [53]	validation_0-rmse:0.54942	validation_1-rmse:0.78079
# [54]	validation_0-rmse:0.54637	validation_1-rmse:0.77746
# [0]	validation_0-rmse:7.68283	validation_1-rmse:7.02347
# [1]	validation_0-rmse:7.01767	validation_1-rmse:6.35056
# [2]	validation_0-rmse:6.40356	validation_1-rmse:5.76271
# [3]	validation_0-rmse:5.84455	validation_1-rmse:5.22050
# [4]	validation_0-rmse:5.34429	validation_1-rmse:4.73340
# [5]	validation_0-rmse:4.88351	validation_1-rmse:4.30682
# [6]	validation_0-rmse:4.46312	validation_1-rmse:3.91798
# [7]	validation_0-rmse:4.08094	validation_1-rmse:3.55081
# [8]	validation_0-rmse:3.73541	validation_1-rmse:3.24913
# [9]	validation_0-rmse:3.42331	validation_1-rmse:2.96929
# [10]	validation_0-rmse:3.14312	validation_1-rmse:2.71522
# [11]	validation_0-rmse:2.88896	validation_1-rmse:2.48927
# [12]	validation_0-rmse:2.65147	validation_1-rmse:2.29672
# [13]	validation_0-rmse:2.43816	validation_1-rmse:2.10172
# [14]	validation_0-rmse:2.24152	validation_1-rmse:1.94519
# [15]	validation_0-rmse:2.06758	validation_1-rmse:1.80718
# [16]	validation_0-rmse:1.90898	validation_1-rmse:1.68713
# [17]	validation_0-rmse:1.76944	validation_1-rmse:1.57601
# [18]	validation_0-rmse:1.63593	validation_1-rmse:1.47495
# [19]	validation_0-rmse:1.52311	validation_1-rmse:1.38389
# [20]	validation_0-rmse:1.42451	validation_1-rmse:1.30822
# [21]	validation_0-rmse:1.32650	validation_1-rmse:1.23405
# [22]	validation_0-rmse:1.24465	validation_1-rmse:1.17858
# [23]	validation_0-rmse:1.17180	validation_1-rmse:1.11966
# [24]	validation_0-rmse:1.10449	validation_1-rmse:1.07170
# [25]	validation_0-rmse:1.04338	validation_1-rmse:1.02633
# [26]	validation_0-rmse:0.98850	validation_1-rmse:0.98958
# [27]	validation_0-rmse:0.93740	validation_1-rmse:0.95589
# [28]	validation_0-rmse:0.89677	validation_1-rmse:0.92978
# [29]	validation_0-rmse:0.85881	validation_1-rmse:0.90611
# [30]	validation_0-rmse:0.82662	validation_1-rmse:0.88024
# [31]	validation_0-rmse:0.79736	validation_1-rmse:0.85924
# [32]	validation_0-rmse:0.77192	validation_1-rmse:0.83911
# [33]	validation_0-rmse:0.75304	validation_1-rmse:0.82379
# [34]	validation_0-rmse:0.73383	validation_1-rmse:0.81378
# [35]	validation_0-rmse:0.71574	validation_1-rmse:0.81091
# [36]	validation_0-rmse:0.69940	validation_1-rmse:0.80113
# [37]	validation_0-rmse:0.68475	validation_1-rmse:0.79026
# [38]	validation_0-rmse:0.67249	validation_1-rmse:0.78441
# [39]	validation_0-rmse:0.66037	validation_1-rmse:0.77875
# [40]	validation_0-rmse:0.65001	validation_1-rmse:0.77394
# [41]	validation_0-rmse:0.64054	validation_1-rmse:0.76726
# [42]	validation_0-rmse:0.63205	validation_1-rmse:0.76715
# [43]	validation_0-rmse:0.62429	validation_1-rmse:0.76249
# [44]	validation_0-rmse:0.61740	validation_1-rmse:0.75800
# [45]	validation_0-rmse:0.61174	validation_1-rmse:0.75942
# [46]	validation_0-rmse:0.60186	validation_1-rmse:0.75968
# [47]	validation_0-rmse:0.59543	validation_1-rmse:0.75719
# [48]	validation_0-rmse:0.58895	validation_1-rmse:0.75512
# [49]	validation_0-rmse:0.58463	validation_1-rmse:0.75322
# [50]	validation_0-rmse:0.57255	validation_1-rmse:0.74269
# [51]	validation_0-rmse:0.56913	validation_1-rmse:0.73941
# [52]	validation_0-rmse:0.56516	validation_1-rmse:0.73614
# [53]	validation_0-rmse:0.56122	validation_1-rmse:0.73634
# [54]	validation_0-rmse:0.55821	validation_1-rmse:0.73605
# [0]	validation_0-rmse:7.66556	validation_1-rmse:7.09846
# [1]	validation_0-rmse:6.99949	validation_1-rmse:6.42667
# [2]	validation_0-rmse:6.39416	validation_1-rmse:5.85016
# [3]	validation_0-rmse:5.84276	validation_1-rmse:5.34430
# [4]	validation_0-rmse:5.34161	validation_1-rmse:4.86900
# [5]	validation_0-rmse:4.88141	validation_1-rmse:4.44994
# [6]	validation_0-rmse:4.46494	validation_1-rmse:4.05680
# [7]	validation_0-rmse:4.08598	validation_1-rmse:3.71322
# [8]	validation_0-rmse:3.74027	validation_1-rmse:3.40252
# [9]	validation_0-rmse:3.42838	validation_1-rmse:3.10720
# [10]	validation_0-rmse:3.14435	validation_1-rmse:2.83299
# [11]	validation_0-rmse:2.89145	validation_1-rmse:2.56492
# [12]	validation_0-rmse:2.65479	validation_1-rmse:2.35569
# [13]	validation_0-rmse:2.44352	validation_1-rmse:2.12704
# [14]	validation_0-rmse:2.25020	validation_1-rmse:1.95780
# [15]	validation_0-rmse:2.06974	validation_1-rmse:1.78988
# [16]	validation_0-rmse:1.91407	validation_1-rmse:1.66059
# [17]	validation_0-rmse:1.77193	validation_1-rmse:1.54039
# [18]	validation_0-rmse:1.64359	validation_1-rmse:1.42942
# [19]	validation_0-rmse:1.52955	validation_1-rmse:1.31684
# [20]	validation_0-rmse:1.42761	validation_1-rmse:1.22462
# [21]	validation_0-rmse:1.32978	validation_1-rmse:1.14813
# [22]	validation_0-rmse:1.24303	validation_1-rmse:1.07988
# [23]	validation_0-rmse:1.16999	validation_1-rmse:1.02193
# [24]	validation_0-rmse:1.09875	validation_1-rmse:0.97918
# [25]	validation_0-rmse:1.03794	validation_1-rmse:0.94116
# [26]	validation_0-rmse:0.98766	validation_1-rmse:0.90705
# [27]	validation_0-rmse:0.93831	validation_1-rmse:0.88256
# [28]	validation_0-rmse:0.89284	validation_1-rmse:0.86596
# [29]	validation_0-rmse:0.85318	validation_1-rmse:0.84883
# [30]	validation_0-rmse:0.81940	validation_1-rmse:0.83551
# [31]	validation_0-rmse:0.79187	validation_1-rmse:0.82314
# [32]	validation_0-rmse:0.76395	validation_1-rmse:0.81480
# [33]	validation_0-rmse:0.74056	validation_1-rmse:0.80471
# [34]	validation_0-rmse:0.72004	validation_1-rmse:0.79868
# [35]	validation_0-rmse:0.70269	validation_1-rmse:0.80297
# [36]	validation_0-rmse:0.68398	validation_1-rmse:0.79577
# [37]	validation_0-rmse:0.66739	validation_1-rmse:0.79077
# [38]	validation_0-rmse:0.65201	validation_1-rmse:0.79223
# [39]	validation_0-rmse:0.63979	validation_1-rmse:0.79468
# [40]	validation_0-rmse:0.63037	validation_1-rmse:0.79220
# [41]	validation_0-rmse:0.62097	validation_1-rmse:0.79330
# [42]	validation_0-rmse:0.61127	validation_1-rmse:0.79022
# [43]	validation_0-rmse:0.60473	validation_1-rmse:0.78994
# [44]	validation_0-rmse:0.59722	validation_1-rmse:0.79151
# [45]	validation_0-rmse:0.59113	validation_1-rmse:0.79377
# [46]	validation_0-rmse:0.58369	validation_1-rmse:0.80148
# [47]	validation_0-rmse:0.57843	validation_1-rmse:0.80112
# [48]	validation_0-rmse:0.57117	validation_1-rmse:0.80277
# [49]	validation_0-rmse:0.56636	validation_1-rmse:0.80339
# [50]	validation_0-rmse:0.55414	validation_1-rmse:0.81381
# [51]	validation_0-rmse:0.54449	validation_1-rmse:0.82517
# [52]	validation_0-rmse:0.53563	validation_1-rmse:0.83668
# [0]	validation_0-rmse:7.56928	validation_1-rmse:7.53956
# [1]	validation_0-rmse:6.90667	validation_1-rmse:6.87625
# [2]	validation_0-rmse:6.30155	validation_1-rmse:6.27049
# [3]	validation_0-rmse:5.75234	validation_1-rmse:5.72110
# [4]	validation_0-rmse:5.25317	validation_1-rmse:5.22220
# [5]	validation_0-rmse:4.80204	validation_1-rmse:4.77012
# [6]	validation_0-rmse:4.39171	validation_1-rmse:4.36662
# [7]	validation_0-rmse:4.01520	validation_1-rmse:4.00559
# [8]	validation_0-rmse:3.67496	validation_1-rmse:3.68216
# [9]	validation_0-rmse:3.37460	validation_1-rmse:3.38877
# [10]	validation_0-rmse:3.09431	validation_1-rmse:3.11649
# [11]	validation_0-rmse:2.84566	validation_1-rmse:2.88208
# [12]	validation_0-rmse:2.61488	validation_1-rmse:2.66561
# [13]	validation_0-rmse:2.40793	validation_1-rmse:2.46125
# [14]	validation_0-rmse:2.21568	validation_1-rmse:2.28388
# [15]	validation_0-rmse:2.04204	validation_1-rmse:2.12523
# [16]	validation_0-rmse:1.88554	validation_1-rmse:1.97586
# [17]	validation_0-rmse:1.74351	validation_1-rmse:1.84805
# [18]	validation_0-rmse:1.61723	validation_1-rmse:1.73463
# [19]	validation_0-rmse:1.50621	validation_1-rmse:1.63024
# [20]	validation_0-rmse:1.40400	validation_1-rmse:1.54244
# [21]	validation_0-rmse:1.30928	validation_1-rmse:1.46025
# [22]	validation_0-rmse:1.21802	validation_1-rmse:1.38218
# [23]	validation_0-rmse:1.14369	validation_1-rmse:1.32627
# [24]	validation_0-rmse:1.07254	validation_1-rmse:1.27063
# [25]	validation_0-rmse:1.01078	validation_1-rmse:1.22772
# [26]	validation_0-rmse:0.95410	validation_1-rmse:1.18512
# [27]	validation_0-rmse:0.90274	validation_1-rmse:1.14831
# [28]	validation_0-rmse:0.85671	validation_1-rmse:1.11429
# [29]	validation_0-rmse:0.81906	validation_1-rmse:1.08754
# [30]	validation_0-rmse:0.78683	validation_1-rmse:1.06561
# [31]	validation_0-rmse:0.75454	validation_1-rmse:1.04553
# [32]	validation_0-rmse:0.72704	validation_1-rmse:1.02559
# [33]	validation_0-rmse:0.70343	validation_1-rmse:1.00770
# [34]	validation_0-rmse:0.68490	validation_1-rmse:0.99920
# [35]	validation_0-rmse:0.66821	validation_1-rmse:0.98826
# [36]	validation_0-rmse:0.65308	validation_1-rmse:0.98569
# [37]	validation_0-rmse:0.63756	validation_1-rmse:0.96814
# [38]	validation_0-rmse:0.62426	validation_1-rmse:0.95677
# [39]	validation_0-rmse:0.61264	validation_1-rmse:0.94933
# [40]	validation_0-rmse:0.60246	validation_1-rmse:0.94492
# [41]	validation_0-rmse:0.59264	validation_1-rmse:0.93574
# [42]	validation_0-rmse:0.58444	validation_1-rmse:0.93685
# [43]	validation_0-rmse:0.57655	validation_1-rmse:0.93252
# [44]	validation_0-rmse:0.56861	validation_1-rmse:0.92742
# [45]	validation_0-rmse:0.56209	validation_1-rmse:0.92005
# [46]	validation_0-rmse:0.55706	validation_1-rmse:0.92267
# [47]	validation_0-rmse:0.55139	validation_1-rmse:0.91842
# [48]	validation_0-rmse:0.54577	validation_1-rmse:0.91728
# [49]	validation_0-rmse:0.54086	validation_1-rmse:0.91389
# [50]	validation_0-rmse:0.53734	validation_1-rmse:0.91630
# [51]	validation_0-rmse:0.53057	validation_1-rmse:0.92065
# [52]	validation_0-rmse:0.52663	validation_1-rmse:0.91653
# [53]	validation_0-rmse:0.52196	validation_1-rmse:0.91759
# [54]	validation_0-rmse:0.51883	validation_1-rmse:0.91435

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(6, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.710
# Uncertainty
# a0: 2.85+/-0.383
# a1: 0.658+/-0.038

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: Sr_2021_kBq_m: mean - 0.751, median - 0.754, CI - [0.707-0.804]
#
# SHAP-values for: contr_b_MAX: mean - 0.076, median - 0.072, CI - [0.047-0.103]
#
# SHAP-values for: contr_b_STD: mean - 0.107, median - 0.105, CI - [0.073-0.138]
#
# SHAP-values for: r_MIN: mean - 0.288, median - 0.288, CI - [0.259-0.321]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['Sr_2021_kBq_m', 'r_MIN', 'contr_b_STD', 'contr_b_MAX'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 49.025, median: 53.0,
#  pred. interval (P(0.025)-P(0.975)): 32.975-54.0,
#  conf. interval (p-value=0.95): 41.116-53.903
# ***
# Aggregate bias statistic:
#  mean: -0.115, median: -0.094,
#  pred. interval (P(0.025)-P(0.975)): -0.465-0.132,
#  conf. interval (p-value=0.95): -0.269-0.022
# ***
# Aggregate RMSE statistic:
#  mean: 0.798, median: 0.784, pred. interval (P(0.025)-P(0.975)): 0.584-1.022,
#  conf. interval (p-value=0.95): 0.704-0.896
# ***
# Aggregate MSE statistic:
#  mean: 0.65, median: 0.614, pred. interval (P(0.025)-P(0.975)): 0.341-1.045,
#  conf. interval (p-value=0.95): 0.496-0.804
# ***
# Aggregate R^2 statistic:
#  mean: 0.664, median: 0.686, pred. interval (P(0.025)-P(0.975)): 0.395-0.824,
#  conf. interval (p-value=0.95): 0.568-0.764
# ***
# Aggregate bias(%) statistic:
#  mean: -1.29, median: -1.084, pred. interval (P(0.025)-P(0.975)): -4.969-1.584,
#  conf. interval (p-value=0.95): -2.954-0.281
# ***
# Aggregate RMSE(%) statistic:
#  mean: 9.219, median: 9.105, pred. interval (P(0.025)-P(0.975)): 6.801-11.626,
#  conf. interval (p-value=0.95): 8.113-10.348
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -14736.388, median: -5243.561,
#  pred. interval (P(0.025)-P(0.975)): -60221.061--57.67,
#  conf. interval (p-value=0.95): -42256.623--2152.313
# ***
# Aggregate RMSE statistic:
#  mean: 58272.259, median: 17651.32, pred. interval (P(0.025)-P(0.975)): 5225.34-219428.015,
#  conf. interval (p-value=0.95): 10255.588-188298.349
# ***
# Aggregate MSE statistic:
#  mean: 9798520573.661, median: 311685898.928, pred. interval (P(0.025)-P(0.975)): 27308430.573-48148660887.776,
#  conf. interval (p-value=0.95): 111064496.931-38581938835.404
# ***
# Aggregate R^2 statistic:
#  mean: 0.545, median: 0.657, pred. interval (P(0.025)-P(0.975)): 0.057-0.903,
#  conf. interval (p-value=0.95): 0.176-0.804
# ***
# Aggregate bias(%) statistic:
#  mean: -37.772, median: -32.361, pred. interval (P(0.025)-P(0.975)): -82.347--0.459,
#  conf. interval (p-value=0.95): -70.835--18.251
# ***
# Aggregate RMSE(%) statistic:
#  mean: 145.041, median: 103.494, pred. interval (P(0.025)-P(0.975)): 62.233-352.195,
#  conf. interval (p-value=0.95): 79.088-286.736
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [6, 7, 8, 9, 10, 11, 14])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 500, 1000, 5000, 10000, 20000, 50000, 1000000])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=10, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:7.55807
# [1]	validation_0-rmse:6.89768
# [2]	validation_0-rmse:6.28872
# [3]	validation_0-rmse:5.74198
# [4]	validation_0-rmse:5.24487
# [5]	validation_0-rmse:4.78994
# [6]	validation_0-rmse:4.38021
# [7]	validation_0-rmse:4.00996
# [8]	validation_0-rmse:3.66835
# [9]	validation_0-rmse:3.35784
# [10]	validation_0-rmse:3.08507
# [11]	validation_0-rmse:2.83191
# [12]	validation_0-rmse:2.60222
# [13]	validation_0-rmse:2.39245
# [14]	validation_0-rmse:2.20408
# [15]	validation_0-rmse:2.03416
# [16]	validation_0-rmse:1.87919
# [17]	validation_0-rmse:1.73454
# [18]	validation_0-rmse:1.60914
# [19]	validation_0-rmse:1.49498
# [20]	validation_0-rmse:1.39434
# [21]	validation_0-rmse:1.30582
# [22]	validation_0-rmse:1.22344
# [23]	validation_0-rmse:1.14992
# [24]	validation_0-rmse:1.08582
# [25]	validation_0-rmse:1.03146
# [26]	validation_0-rmse:0.97958
# [27]	validation_0-rmse:0.93340
# [28]	validation_0-rmse:0.89413
# [29]	validation_0-rmse:0.85821
# [30]	validation_0-rmse:0.82716
# [31]	validation_0-rmse:0.79779
# [32]	validation_0-rmse:0.77412
# [33]	validation_0-rmse:0.75291
# [34]	validation_0-rmse:0.73376
# [35]	validation_0-rmse:0.71737
# [36]	validation_0-rmse:0.70164
# [37]	validation_0-rmse:0.68847
# [38]	validation_0-rmse:0.67655
# [39]	validation_0-rmse:0.66715
# [40]	validation_0-rmse:0.65884
# [41]	validation_0-rmse:0.65032
# [42]	validation_0-rmse:0.64265
# [43]	validation_0-rmse:0.63416
# [44]	validation_0-rmse:0.62756
# [45]	validation_0-rmse:0.62191
# [46]	validation_0-rmse:0.61573
# [47]	validation_0-rmse:0.61141
# [48]	validation_0-rmse:0.59952
# [49]	validation_0-rmse:0.58978
# [50]	validation_0-rmse:0.58661
# [51]	validation_0-rmse:0.58380
# [52]	validation_0-rmse:0.57904
# [53]	validation_0-rmse:0.57458
# [54]	validation_0-rmse:0.57060

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 54

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.1
# Relative bias(%):  -0.61
# RMSE: 0.6
# Relative RMSE(%):  6.592
# MSE: 0.3
# R square: 84.8%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(6, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.859
# Uncertainty
# a0: 1.94+/-0.27
# a1: 0.770+/-0.031

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/08_LN_Sr_vs_CHM_RGB_D_XGB_model_2024_final.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/08_LN_Sr_vs_CHM_RGB_D_XGB_model_2024_final.txt")
