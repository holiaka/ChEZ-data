# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../03_input_data/input_CHM_&_spectral_data_site2020.xlsx'
df = pd.read_excel(site_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0        4.771            1.792                -0.211            -0.261
# 1        5.808            2.496                -0.073             0.392
# 2        5.796            2.546                 0.030             0.501
# 3        5.826            2.643                 0.000             0.419
# 4        6.059            2.643                 0.122             0.647
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  \
# 0              -2.040          1.932     0.85    12.233545   19.097736    243
# 1              -0.139          2.674     1.00    14.964220   17.704655    248
# 2              -0.030          2.734     1.00    15.329449   17.559893    240
# 3              -0.431          2.785     0.97    15.392742   20.676994    244
# 4              -0.386          2.809     1.00    17.944009   21.851387    243
#
#    contr_g_MAX
# 0  2961.898193
# 1  2218.239746
# 2  2220.297119
# 3  3033.770752
# 4  3003.818848

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
#  9   g_MAX                 103 non-null    int64
#  10  contr_g_MAX           103 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 9.0 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Gs_cub_m", "ln_M_AG_kg_m2"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                  ln_Gs_cub_m                                             \
#                        count      mean       std    min      25%    50%
# Dominant_specias
# Alder                    4.0  5.907250  0.445830  5.342  5.65925  5.985
# Aspen                    1.0  4.956000       NaN  4.956  4.95600  4.956
# Birch                   23.0  4.676174  0.813911  2.398  4.56900  4.949
# Oak                      3.0  5.409667  0.406291  4.956  5.24450  5.533
# Pine                    71.0  4.990775  1.410734  1.609  4.44850  5.642
# Spruce                   1.0  6.431000       NaN  6.431  6.43100  6.431
#
#                                 ln_M_AG_kg_m2                             \
#                      75%    max         count      mean       std    min
# Dominant_specias
# Alder             6.2330  6.317           4.0  2.862250  0.386813  2.407
# Aspen             4.9560  4.956           1.0  1.932000       NaN  1.932
# Birch             5.2930  5.680          23.0  1.855783  0.744496  0.000
# Oak               5.6365  5.740           3.0  2.687333  0.316282  2.398
# Pine              5.9215  6.457          71.0  2.073789  1.174954 -0.693
# Spruce            6.4310  6.431           1.0  3.506000       NaN  3.506
#
#
#                       25%    50%     75%    max
# Dominant_specias
# Alder             2.61775  2.892  3.1365  3.258
# Aspen             1.93200  1.932  1.9320  1.932
# Birch             1.68350  2.001  2.3930  2.803
# Oak               2.51850  2.639  2.8320  3.025
# Pine              1.48500  2.588  2.8620  3.515
# Spruce            3.50600  3.506  3.5060  3.506

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000        103.000000
# mean      4.981961         1.863184             -0.327942         -0.063369
# std       1.264300         1.198731              0.866380          0.795365
# min       1.609000        -1.347000             -2.659000         -2.408000
# 25%       4.677000         1.584500             -0.554000         -0.386500
# 50%       5.342000         2.294000             -0.051000          0.182000
# 75%       5.875000         2.663000              0.207000          0.495000
# max       6.457000         3.428000              1.384000          1.756000
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX  \
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.015971       2.086126    0.808738    13.045021   17.907784
# std              0.799205       1.067542    0.276653     6.609366    7.523377
# min             -3.507000      -0.693000    0.090000     1.293138    2.733019
# 25%             -1.609000       1.758000    0.745000     8.206727   11.615798
# 50%             -0.844000       2.442000    0.960000    13.072916   18.269344
# 75%             -0.364000       2.809000    1.000000    17.432255   22.751595
# max              0.157000       3.515000    1.000000    28.916548   36.355442
#
#             g_MAX  contr_g_MAX
# count  103.000000   103.000000
# mean   240.572816  3008.938899
# std      9.358442   876.023529
# min    194.000000   815.342712
# 25%    236.500000  2464.687256
# 50%    243.000000  2994.793701
# 75%    247.000000  3464.970947
# max    253.000000  6230.940918

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_M_stem_bark_kg_m2"
indep_variables = ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0          4.771            1.792                -0.211            -0.261
# 1          5.808            2.496                -0.073             0.392
# 2          5.796            2.546                 0.030             0.501
# 3          5.826            2.643                 0.000             0.419
# 4          6.059            2.643                 0.122             0.647
# ..           ...              ...                   ...               ...
# 98         5.389            2.366                 0.531             0.182
# 99         2.398           -0.186                -1.309            -1.966
# 100        1.792           -0.968                -2.120            -1.966
# 101        4.836            1.733                -0.386             0.732
# 102        2.944           -0.211                -1.966            -1.470
#
#      ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  \
# 0                -2.040          1.932     0.85    12.233545   19.097736
# 1                -0.139          2.674     1.00    14.964220   17.704655
# 2                -0.030          2.734     1.00    15.329449   17.559893
# 3                -0.431          2.785     0.97    15.392742   20.676994
# 4                -0.386          2.809     1.00    17.944009   21.851387
# ..                  ...            ...      ...          ...         ...
# 98               -1.386          2.493     0.84    11.654902   17.083910
# 99               -3.507          0.000     0.17     4.722706   10.924606
# 100              -2.408         -0.511     0.17     4.620455   10.747827
# 101              -0.041          2.163     0.88     7.371921   11.443830
# 102              -1.609          0.182     0.28     2.765120    8.069081
#
#      g_MAX  contr_g_MAX
# 0      243  2961.898193
# 1      248  2218.239746
# 2      240  2220.297119
# 3      244  3033.770752
# 4      243  3003.818848
# ..     ...          ...
# 98     250  3469.805908
# 99     241  1748.447998
# 100    233  1708.681763
# 101    241  3066.087402
# 102    227  2756.989014
#
# [103 rows x 11 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  contr_g_MAX
# 0     0.85    12.233545   19.097736    243  2961.898193
# 1     1.00    14.964220   17.704655    248  2218.239746
# 2     1.00    15.329449   17.559893    240  2220.297119
# 3     0.97    15.392742   20.676994    244  3033.770752
# 4     1.00    17.944009   21.851387    243  3003.818848

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_stem_bark_kg_m2
# 0                -0.211
# 1                -0.073
# 2                 0.030
# 3                 0.000
# 4                 0.122

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.8177972820161272, 0.8257588966634692, 0.9037938329415656]
#     Mean: 0.849
#     Std: 0.039
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.32595666 0.35648991 0.44398583]
#     Mean: 0.375
#     Std: 0.050
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.23425398349321744, 0.2592126990764894, 0.2678941740678514]
#     Mean: 0.254
#     Std: 0.014
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.7693307547782491                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.3356266169778283                 # gamma
print('Gamma: ' + str(p2))

p3 = 0.08478629356985941                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2            # max_depth
print('Max_depth: ' + str(p4))

p5 = 76          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.30404665028506594                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.7693307547782491
# Gamma: 0.3356266169778283
# Learning_rate: 0.08478629356985941
# Max_depth: 2
# N_estimators: 76
# Subsample: 0.30404665028506594

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.07287	validation_1-rmse:1.25663
# [1]	validation_0-rmse:0.99611	validation_1-rmse:1.16626
# [2]	validation_0-rmse:0.93567	validation_1-rmse:1.10343
# [3]	validation_0-rmse:0.88278	validation_1-rmse:1.04666
# [4]	validation_0-rmse:0.83504	validation_1-rmse:0.99159
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:0.80615	validation_1-rmse:0.96077
# [6]	validation_0-rmse:0.76184	validation_1-rmse:0.90816
# [7]	validation_0-rmse:0.71333	validation_1-rmse:0.84834
# [8]	validation_0-rmse:0.68493	validation_1-rmse:0.82009
# [9]	validation_0-rmse:0.64370	validation_1-rmse:0.77220
# [10]	validation_0-rmse:0.60544	validation_1-rmse:0.72858
# [11]	validation_0-rmse:0.58328	validation_1-rmse:0.70347
# [12]	validation_0-rmse:0.56772	validation_1-rmse:0.68743
# [13]	validation_0-rmse:0.54079	validation_1-rmse:0.65492
# [14]	validation_0-rmse:0.51989	validation_1-rmse:0.62915
# [15]	validation_0-rmse:0.49460	validation_1-rmse:0.60725
# [16]	validation_0-rmse:0.47152	validation_1-rmse:0.57848
# [17]	validation_0-rmse:0.44962	validation_1-rmse:0.55278
# [18]	validation_0-rmse:0.41895	validation_1-rmse:0.53245
# [19]	validation_0-rmse:0.40314	validation_1-rmse:0.52180
# [20]	validation_0-rmse:0.39683	validation_1-rmse:0.51602
# [21]	validation_0-rmse:0.39189	validation_1-rmse:0.50997
# [22]	validation_0-rmse:0.37653	validation_1-rmse:0.49935
# [23]	validation_0-rmse:0.37119	validation_1-rmse:0.49289
# [24]	validation_0-rmse:0.35893	validation_1-rmse:0.47246
# [25]	validation_0-rmse:0.34827	validation_1-rmse:0.45865
# [26]	validation_0-rmse:0.34362	validation_1-rmse:0.45513
# [27]	validation_0-rmse:0.33411	validation_1-rmse:0.44341
# [28]	validation_0-rmse:0.32844	validation_1-rmse:0.43653
# [29]	validation_0-rmse:0.31927	validation_1-rmse:0.42956
# [30]	validation_0-rmse:0.31506	validation_1-rmse:0.42516
# [31]	validation_0-rmse:0.30985	validation_1-rmse:0.41776
# [32]	validation_0-rmse:0.30626	validation_1-rmse:0.41522
# [33]	validation_0-rmse:0.30597	validation_1-rmse:0.41474
# [34]	validation_0-rmse:0.29283	validation_1-rmse:0.39098
# [35]	validation_0-rmse:0.29213	validation_1-rmse:0.38967
# [36]	validation_0-rmse:0.29211	validation_1-rmse:0.38962
# [37]	validation_0-rmse:0.28772	validation_1-rmse:0.38142
# [38]	validation_0-rmse:0.28258	validation_1-rmse:0.37283
# [39]	validation_0-rmse:0.27734	validation_1-rmse:0.36818
# [40]	validation_0-rmse:0.27701	validation_1-rmse:0.36748
# [41]	validation_0-rmse:0.27211	validation_1-rmse:0.35822
# [42]	validation_0-rmse:0.27060	validation_1-rmse:0.35847
# [43]	validation_0-rmse:0.27057	validation_1-rmse:0.35839
# [44]	validation_0-rmse:0.26968	validation_1-rmse:0.35635
# [45]	validation_0-rmse:0.26953	validation_1-rmse:0.35598
# [46]	validation_0-rmse:0.26527	validation_1-rmse:0.35510
# [47]	validation_0-rmse:0.26054	validation_1-rmse:0.34536
# [48]	validation_0-rmse:0.26018	validation_1-rmse:0.34431
# [49]	validation_0-rmse:0.26001	validation_1-rmse:0.34379
# [50]	validation_0-rmse:0.26020	validation_1-rmse:0.34438
# [51]	validation_0-rmse:0.25692	validation_1-rmse:0.33676
# [52]	validation_0-rmse:0.25388	validation_1-rmse:0.33539
# [53]	validation_0-rmse:0.25362	validation_1-rmse:0.33454
# [54]	validation_0-rmse:0.25363	validation_1-rmse:0.33457
# [55]	validation_0-rmse:0.25337	validation_1-rmse:0.33364
# [56]	validation_0-rmse:0.25110	validation_1-rmse:0.32802
# [57]	validation_0-rmse:0.24842	validation_1-rmse:0.32744
# [58]	validation_0-rmse:0.24839	validation_1-rmse:0.32736
# [59]	validation_0-rmse:0.24551	validation_1-rmse:0.32766
# [60]	validation_0-rmse:0.24543	validation_1-rmse:0.32706
# [61]	validation_0-rmse:0.24354	validation_1-rmse:0.32942
# [62]	validation_0-rmse:0.24076	validation_1-rmse:0.33034
# [63]	validation_0-rmse:0.24070	validation_1-rmse:0.33000
# [64]	validation_0-rmse:0.24063	validation_1-rmse:0.32963
# [65]	validation_0-rmse:0.24068	validation_1-rmse:0.32991
# [66]	validation_0-rmse:0.24051	validation_1-rmse:0.32870
# [67]	validation_0-rmse:0.23890	validation_1-rmse:0.32944
# [68]	validation_0-rmse:0.23895	validation_1-rmse:0.32877
# [69]	validation_0-rmse:0.23909	validation_1-rmse:0.32789
# [70]	validation_0-rmse:0.23928	validation_1-rmse:0.32717
# [71]	validation_0-rmse:0.23926	validation_1-rmse:0.32726
# [72]	validation_0-rmse:0.23755	validation_1-rmse:0.33199
# [73]	validation_0-rmse:0.23776	validation_1-rmse:0.33127
# [74]	validation_0-rmse:0.23772	validation_1-rmse:0.33141
# [75]	validation_0-rmse:0.23791	validation_1-rmse:0.33089
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.13812	validation_1-rmse:1.03493
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.05821	validation_1-rmse:0.96109
# [2]	validation_0-rmse:0.99143	validation_1-rmse:0.89787
# [3]	validation_0-rmse:0.92580	validation_1-rmse:0.83625
# [4]	validation_0-rmse:0.87539	validation_1-rmse:0.78569
# [5]	validation_0-rmse:0.83132	validation_1-rmse:0.74197
# [6]	validation_0-rmse:0.79312	validation_1-rmse:0.70224
# [7]	validation_0-rmse:0.74910	validation_1-rmse:0.65976
# [8]	validation_0-rmse:0.70687	validation_1-rmse:0.62151
# [9]	validation_0-rmse:0.66283	validation_1-rmse:0.57669
# [10]	validation_0-rmse:0.63433	validation_1-rmse:0.55021
# [11]	validation_0-rmse:0.60199	validation_1-rmse:0.51356
# [12]	validation_0-rmse:0.58337	validation_1-rmse:0.49281
# [13]	validation_0-rmse:0.55526	validation_1-rmse:0.46988
# [14]	validation_0-rmse:0.52834	validation_1-rmse:0.44292
# [15]	validation_0-rmse:0.49760	validation_1-rmse:0.41056
# [16]	validation_0-rmse:0.46881	validation_1-rmse:0.37870
# [17]	validation_0-rmse:0.44611	validation_1-rmse:0.35712
# [18]	validation_0-rmse:0.43685	validation_1-rmse:0.35059
# [19]	validation_0-rmse:0.42008	validation_1-rmse:0.34079
# [20]	validation_0-rmse:0.41217	validation_1-rmse:0.33335
# [21]	validation_0-rmse:0.40267	validation_1-rmse:0.32848
# [22]	validation_0-rmse:0.39017	validation_1-rmse:0.31843
# [23]	validation_0-rmse:0.37330	validation_1-rmse:0.30372
# [24]	validation_0-rmse:0.36398	validation_1-rmse:0.29864
# [25]	validation_0-rmse:0.36283	validation_1-rmse:0.29752
# [26]	validation_0-rmse:0.35011	validation_1-rmse:0.28840
# [27]	validation_0-rmse:0.34573	validation_1-rmse:0.28663
# [28]	validation_0-rmse:0.33920	validation_1-rmse:0.28044
# [29]	validation_0-rmse:0.33474	validation_1-rmse:0.27394
# [30]	validation_0-rmse:0.33333	validation_1-rmse:0.27272
# [31]	validation_0-rmse:0.32048	validation_1-rmse:0.26622
# [32]	validation_0-rmse:0.31387	validation_1-rmse:0.26254
# [33]	validation_0-rmse:0.30900	validation_1-rmse:0.26477
# [34]	validation_0-rmse:0.30528	validation_1-rmse:0.26136
# [35]	validation_0-rmse:0.30284	validation_1-rmse:0.26235
# [36]	validation_0-rmse:0.29388	validation_1-rmse:0.25569
# [37]	validation_0-rmse:0.29211	validation_1-rmse:0.25443
# [38]	validation_0-rmse:0.28819	validation_1-rmse:0.25017
# [39]	validation_0-rmse:0.28302	validation_1-rmse:0.24735
# [40]	validation_0-rmse:0.28239	validation_1-rmse:0.24696
# [41]	validation_0-rmse:0.28053	validation_1-rmse:0.24719
# [42]	validation_0-rmse:0.27905	validation_1-rmse:0.24890
# [43]	validation_0-rmse:0.27929	validation_1-rmse:0.25108
# [44]	validation_0-rmse:0.27936	validation_1-rmse:0.25112
# [45]	validation_0-rmse:0.27299	validation_1-rmse:0.25322
# [46]	validation_0-rmse:0.27242	validation_1-rmse:0.25307
# [47]	validation_0-rmse:0.26766	validation_1-rmse:0.25066
# [48]	validation_0-rmse:0.26515	validation_1-rmse:0.25120
# [49]	validation_0-rmse:0.26382	validation_1-rmse:0.25173
# [50]	validation_0-rmse:0.26189	validation_1-rmse:0.25175
# [51]	validation_0-rmse:0.25985	validation_1-rmse:0.24898
# [52]	validation_0-rmse:0.25710	validation_1-rmse:0.24595
# [53]	validation_0-rmse:0.25693	validation_1-rmse:0.24600
# [54]	validation_0-rmse:0.25655	validation_1-rmse:0.24628
# [55]	validation_0-rmse:0.25231	validation_1-rmse:0.24453
# [56]	validation_0-rmse:0.25226	validation_1-rmse:0.24458
# [57]	validation_0-rmse:0.25211	validation_1-rmse:0.24484
# [58]	validation_0-rmse:0.25215	validation_1-rmse:0.24474
# [59]	validation_0-rmse:0.25216	validation_1-rmse:0.24474
# [60]	validation_0-rmse:0.25048	validation_1-rmse:0.24366
# [61]	validation_0-rmse:0.25029	validation_1-rmse:0.24402
# [62]	validation_0-rmse:0.24887	validation_1-rmse:0.24188
# [63]	validation_0-rmse:0.24900	validation_1-rmse:0.24157
# [64]	validation_0-rmse:0.24895	validation_1-rmse:0.24165
# [65]	validation_0-rmse:0.24637	validation_1-rmse:0.24108
# [66]	validation_0-rmse:0.24651	validation_1-rmse:0.24093
# [67]	validation_0-rmse:0.24492	validation_1-rmse:0.24209
# [68]	validation_0-rmse:0.24487	validation_1-rmse:0.24231
# [69]	validation_0-rmse:0.24503	validation_1-rmse:0.24190
# [70]	validation_0-rmse:0.24393	validation_1-rmse:0.24347
# [71]	validation_0-rmse:0.24375	validation_1-rmse:0.24369
# [72]	validation_0-rmse:0.24333	validation_1-rmse:0.24492
# [73]	validation_0-rmse:0.24328	validation_1-rmse:0.24503
# [74]	validation_0-rmse:0.24318	validation_1-rmse:0.24542
# [75]	validation_0-rmse:0.24324	validation_1-rmse:0.24517
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.10467	validation_1-rmse:1.18217
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.02395	validation_1-rmse:1.11483
# [2]	validation_0-rmse:0.95451	validation_1-rmse:1.05737
# [3]	validation_0-rmse:0.90516	validation_1-rmse:0.99059
# [4]	validation_0-rmse:0.86018	validation_1-rmse:0.93782
# [5]	validation_0-rmse:0.82747	validation_1-rmse:0.90118
# [6]	validation_0-rmse:0.79460	validation_1-rmse:0.86502
# [7]	validation_0-rmse:0.73837	validation_1-rmse:0.79078
# [8]	validation_0-rmse:0.69544	validation_1-rmse:0.73759
# [9]	validation_0-rmse:0.65550	validation_1-rmse:0.69005
# [10]	validation_0-rmse:0.62928	validation_1-rmse:0.66025
# [11]	validation_0-rmse:0.60866	validation_1-rmse:0.62469
# [12]	validation_0-rmse:0.57496	validation_1-rmse:0.58380
# [13]	validation_0-rmse:0.55908	validation_1-rmse:0.57213
# [14]	validation_0-rmse:0.54898	validation_1-rmse:0.55962
# [15]	validation_0-rmse:0.53593	validation_1-rmse:0.54511
# [16]	validation_0-rmse:0.51079	validation_1-rmse:0.53349
# [17]	validation_0-rmse:0.48411	validation_1-rmse:0.50201
# [18]	validation_0-rmse:0.46544	validation_1-rmse:0.47194
# [19]	validation_0-rmse:0.43561	validation_1-rmse:0.43174
# [20]	validation_0-rmse:0.42259	validation_1-rmse:0.42688
# [21]	validation_0-rmse:0.41294	validation_1-rmse:0.41423
# [22]	validation_0-rmse:0.39809	validation_1-rmse:0.40859
# [23]	validation_0-rmse:0.38307	validation_1-rmse:0.38798
# [24]	validation_0-rmse:0.37281	validation_1-rmse:0.36831
# [25]	validation_0-rmse:0.36280	validation_1-rmse:0.36623
# [26]	validation_0-rmse:0.35456	validation_1-rmse:0.35458
# [27]	validation_0-rmse:0.34695	validation_1-rmse:0.34977
# [28]	validation_0-rmse:0.34089	validation_1-rmse:0.34205
# [29]	validation_0-rmse:0.32798	validation_1-rmse:0.33561
# [30]	validation_0-rmse:0.32701	validation_1-rmse:0.33414
# [31]	validation_0-rmse:0.32188	validation_1-rmse:0.32668
# [32]	validation_0-rmse:0.32035	validation_1-rmse:0.32432
# [33]	validation_0-rmse:0.31254	validation_1-rmse:0.32245
# [34]	validation_0-rmse:0.30638	validation_1-rmse:0.32124
# [35]	validation_0-rmse:0.30189	validation_1-rmse:0.32448
# [36]	validation_0-rmse:0.29244	validation_1-rmse:0.32491
# [37]	validation_0-rmse:0.29311	validation_1-rmse:0.32601
# [38]	validation_0-rmse:0.28561	validation_1-rmse:0.32384
# [39]	validation_0-rmse:0.28077	validation_1-rmse:0.31441
# [40]	validation_0-rmse:0.28009	validation_1-rmse:0.31300
# [41]	validation_0-rmse:0.27925	validation_1-rmse:0.31114
# [42]	validation_0-rmse:0.27900	validation_1-rmse:0.31052
# [43]	validation_0-rmse:0.27871	validation_1-rmse:0.30979
# [44]	validation_0-rmse:0.27567	validation_1-rmse:0.30990
# [45]	validation_0-rmse:0.27254	validation_1-rmse:0.30503
# [46]	validation_0-rmse:0.27063	validation_1-rmse:0.30470
# [47]	validation_0-rmse:0.27054	validation_1-rmse:0.30448
# [48]	validation_0-rmse:0.26830	validation_1-rmse:0.30434
# [49]	validation_0-rmse:0.26684	validation_1-rmse:0.30683
# [50]	validation_0-rmse:0.26518	validation_1-rmse:0.30378
# [51]	validation_0-rmse:0.26532	validation_1-rmse:0.30411
# [52]	validation_0-rmse:0.26010	validation_1-rmse:0.30389
# [53]	validation_0-rmse:0.25975	validation_1-rmse:0.30286
# [54]	validation_0-rmse:0.25898	validation_1-rmse:0.30711
# [55]	validation_0-rmse:0.25728	validation_1-rmse:0.30567
# [56]	validation_0-rmse:0.25660	validation_1-rmse:0.30378
# [57]	validation_0-rmse:0.25652	validation_1-rmse:0.30355
# [58]	validation_0-rmse:0.25621	validation_1-rmse:0.30242
# [59]	validation_0-rmse:0.25606	validation_1-rmse:0.30172
# [60]	validation_0-rmse:0.25590	validation_1-rmse:0.30083
# [61]	validation_0-rmse:0.25581	validation_1-rmse:0.29969
# [62]	validation_0-rmse:0.25582	validation_1-rmse:0.29911
# [63]	validation_0-rmse:0.25582	validation_1-rmse:0.29994
# [64]	validation_0-rmse:0.25582	validation_1-rmse:0.29911
# [65]	validation_0-rmse:0.25418	validation_1-rmse:0.29566
# [66]	validation_0-rmse:0.25426	validation_1-rmse:0.29514
# [67]	validation_0-rmse:0.25441	validation_1-rmse:0.29461
# [68]	validation_0-rmse:0.25434	validation_1-rmse:0.29481
# [69]	validation_0-rmse:0.25438	validation_1-rmse:0.29470
# [70]	validation_0-rmse:0.25155	validation_1-rmse:0.29548
# [71]	validation_0-rmse:0.25148	validation_1-rmse:0.29593
# [72]	validation_0-rmse:0.25143	validation_1-rmse:0.29676
# [73]	validation_0-rmse:0.25145	validation_1-rmse:0.29722
# [74]	validation_0-rmse:0.25143	validation_1-rmse:0.29669
# [75]	validation_0-rmse:0.25146	validation_1-rmse:0.29745
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.07481	validation_1-rmse:1.33096
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.01399	validation_1-rmse:1.26474
# [2]	validation_0-rmse:0.93997	validation_1-rmse:1.17836
# [3]	validation_0-rmse:0.87709	validation_1-rmse:1.10787
# [4]	validation_0-rmse:0.82544	validation_1-rmse:1.04551
# [5]	validation_0-rmse:0.77830	validation_1-rmse:1.00957
# [6]	validation_0-rmse:0.74023	validation_1-rmse:0.97443
# [7]	validation_0-rmse:0.69342	validation_1-rmse:0.91808
# [8]	validation_0-rmse:0.65283	validation_1-rmse:0.87276
# [9]	validation_0-rmse:0.62241	validation_1-rmse:0.84505
# [10]	validation_0-rmse:0.58217	validation_1-rmse:0.79495
# [11]	validation_0-rmse:0.55794	validation_1-rmse:0.77339
# [12]	validation_0-rmse:0.53496	validation_1-rmse:0.74764
# [13]	validation_0-rmse:0.50877	validation_1-rmse:0.71692
# [14]	validation_0-rmse:0.49484	validation_1-rmse:0.69317
# [15]	validation_0-rmse:0.47480	validation_1-rmse:0.66674
# [16]	validation_0-rmse:0.45541	validation_1-rmse:0.63948
# [17]	validation_0-rmse:0.42915	validation_1-rmse:0.60654
# [18]	validation_0-rmse:0.40720	validation_1-rmse:0.58471
# [19]	validation_0-rmse:0.39723	validation_1-rmse:0.57667
# [20]	validation_0-rmse:0.38136	validation_1-rmse:0.55697
# [21]	validation_0-rmse:0.37389	validation_1-rmse:0.53811
# [22]	validation_0-rmse:0.36002	validation_1-rmse:0.51911
# [23]	validation_0-rmse:0.34780	validation_1-rmse:0.50632
# [24]	validation_0-rmse:0.33404	validation_1-rmse:0.48798
# [25]	validation_0-rmse:0.31595	validation_1-rmse:0.46886
# [26]	validation_0-rmse:0.30240	validation_1-rmse:0.45121
# [27]	validation_0-rmse:0.29579	validation_1-rmse:0.44889
# [28]	validation_0-rmse:0.29235	validation_1-rmse:0.44148
# [29]	validation_0-rmse:0.29034	validation_1-rmse:0.43964
# [30]	validation_0-rmse:0.28404	validation_1-rmse:0.43112
# [31]	validation_0-rmse:0.27982	validation_1-rmse:0.42483
# [32]	validation_0-rmse:0.27817	validation_1-rmse:0.42423
# [33]	validation_0-rmse:0.27057	validation_1-rmse:0.41284
# [34]	validation_0-rmse:0.26421	validation_1-rmse:0.41348
# [35]	validation_0-rmse:0.26286	validation_1-rmse:0.41098
# [36]	validation_0-rmse:0.25958	validation_1-rmse:0.41145
# [37]	validation_0-rmse:0.25984	validation_1-rmse:0.41171
# [38]	validation_0-rmse:0.25928	validation_1-rmse:0.41115
# [39]	validation_0-rmse:0.25829	validation_1-rmse:0.41011
# [40]	validation_0-rmse:0.25302	validation_1-rmse:0.40105
# [41]	validation_0-rmse:0.25181	validation_1-rmse:0.39983
# [42]	validation_0-rmse:0.25171	validation_1-rmse:0.39973
# [43]	validation_0-rmse:0.24907	validation_1-rmse:0.39982
# [44]	validation_0-rmse:0.24576	validation_1-rmse:0.40084
# [45]	validation_0-rmse:0.24363	validation_1-rmse:0.40145
# [46]	validation_0-rmse:0.24190	validation_1-rmse:0.40132
# [47]	validation_0-rmse:0.24163	validation_1-rmse:0.40061
# [48]	validation_0-rmse:0.24161	validation_1-rmse:0.40051
# [49]	validation_0-rmse:0.24165	validation_1-rmse:0.40069
# [50]	validation_0-rmse:0.24169	validation_1-rmse:0.40082
# [51]	validation_0-rmse:0.23938	validation_1-rmse:0.40135
# [52]	validation_0-rmse:0.23942	validation_1-rmse:0.40144
# [53]	validation_0-rmse:0.23932	validation_1-rmse:0.40122
# [54]	validation_0-rmse:0.23919	validation_1-rmse:0.40078
# [55]	validation_0-rmse:0.24112	validation_1-rmse:0.40295
# [56]	validation_0-rmse:0.24114	validation_1-rmse:0.40288
# [57]	validation_0-rmse:0.24113	validation_1-rmse:0.40292
# [58]	validation_0-rmse:0.23963	validation_1-rmse:0.40010
# [59]	validation_0-rmse:0.23876	validation_1-rmse:0.40008
# [60]	validation_0-rmse:0.23674	validation_1-rmse:0.40184
# [61]	validation_0-rmse:0.23664	validation_1-rmse:0.40235
# [62]	validation_0-rmse:0.23510	validation_1-rmse:0.39567
# [63]	validation_0-rmse:0.23516	validation_1-rmse:0.39594
# [64]	validation_0-rmse:0.23519	validation_1-rmse:0.39605
# [65]	validation_0-rmse:0.23518	validation_1-rmse:0.39603
# [66]	validation_0-rmse:0.23511	validation_1-rmse:0.39574
# [67]	validation_0-rmse:0.23345	validation_1-rmse:0.39686
# [68]	validation_0-rmse:0.23345	validation_1-rmse:0.39709
# [69]	validation_0-rmse:0.23345	validation_1-rmse:0.39699
# [70]	validation_0-rmse:0.23346	validation_1-rmse:0.39684
# [71]	validation_0-rmse:0.23093	validation_1-rmse:0.39021
# [72]	validation_0-rmse:0.22972	validation_1-rmse:0.39205
# [73]	validation_0-rmse:0.22975	validation_1-rmse:0.39194
# [74]	validation_0-rmse:0.22975	validation_1-rmse:0.39196
# [75]	validation_0-rmse:0.22976	validation_1-rmse:0.39192
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.13008	validation_1-rmse:1.08452
# [1]	validation_0-rmse:1.05242	validation_1-rmse:1.00922
# [2]	validation_0-rmse:0.97747	validation_1-rmse:0.93774
# [3]	validation_0-rmse:0.92398	validation_1-rmse:0.88635
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:0.86889	validation_1-rmse:0.83118
# [5]	validation_0-rmse:0.81348	validation_1-rmse:0.77678
# [6]	validation_0-rmse:0.76852	validation_1-rmse:0.73167
# [7]	validation_0-rmse:0.72020	validation_1-rmse:0.68264
# [8]	validation_0-rmse:0.67852	validation_1-rmse:0.63957
# [9]	validation_0-rmse:0.64316	validation_1-rmse:0.60021
# [10]	validation_0-rmse:0.61959	validation_1-rmse:0.57278
# [11]	validation_0-rmse:0.59745	validation_1-rmse:0.56007
# [12]	validation_0-rmse:0.56467	validation_1-rmse:0.52186
# [13]	validation_0-rmse:0.53976	validation_1-rmse:0.49443
# [14]	validation_0-rmse:0.52530	validation_1-rmse:0.47637
# [15]	validation_0-rmse:0.49778	validation_1-rmse:0.44696
# [16]	validation_0-rmse:0.48288	validation_1-rmse:0.43004
# [17]	validation_0-rmse:0.46717	validation_1-rmse:0.41558
# [18]	validation_0-rmse:0.44511	validation_1-rmse:0.39149
# [19]	validation_0-rmse:0.42661	validation_1-rmse:0.37672
# [20]	validation_0-rmse:0.41163	validation_1-rmse:0.35810
# [21]	validation_0-rmse:0.40373	validation_1-rmse:0.34719
# [22]	validation_0-rmse:0.38730	validation_1-rmse:0.32795
# [23]	validation_0-rmse:0.37757	validation_1-rmse:0.31865
# [24]	validation_0-rmse:0.36355	validation_1-rmse:0.30303
# [25]	validation_0-rmse:0.35556	validation_1-rmse:0.29222
# [26]	validation_0-rmse:0.34979	validation_1-rmse:0.28783
# [27]	validation_0-rmse:0.34336	validation_1-rmse:0.28212
# [28]	validation_0-rmse:0.33606	validation_1-rmse:0.27674
# [29]	validation_0-rmse:0.33219	validation_1-rmse:0.27096
# [30]	validation_0-rmse:0.32604	validation_1-rmse:0.26128
# [31]	validation_0-rmse:0.32240	validation_1-rmse:0.25929
# [32]	validation_0-rmse:0.31701	validation_1-rmse:0.25285
# [33]	validation_0-rmse:0.31221	validation_1-rmse:0.24858
# [34]	validation_0-rmse:0.30249	validation_1-rmse:0.24018
# [35]	validation_0-rmse:0.30183	validation_1-rmse:0.24000
# [36]	validation_0-rmse:0.29726	validation_1-rmse:0.23665
# [37]	validation_0-rmse:0.29127	validation_1-rmse:0.23196
# [38]	validation_0-rmse:0.28445	validation_1-rmse:0.22909
# [39]	validation_0-rmse:0.28147	validation_1-rmse:0.22818
# [40]	validation_0-rmse:0.28076	validation_1-rmse:0.22699
# [41]	validation_0-rmse:0.27841	validation_1-rmse:0.22506
# [42]	validation_0-rmse:0.27618	validation_1-rmse:0.22448
# [43]	validation_0-rmse:0.27303	validation_1-rmse:0.22380
# [44]	validation_0-rmse:0.27238	validation_1-rmse:0.22260
# [45]	validation_0-rmse:0.27247	validation_1-rmse:0.22277
# [46]	validation_0-rmse:0.26863	validation_1-rmse:0.22658
# [47]	validation_0-rmse:0.26933	validation_1-rmse:0.22791
# [48]	validation_0-rmse:0.26621	validation_1-rmse:0.22597
# [49]	validation_0-rmse:0.26577	validation_1-rmse:0.22516
# [50]	validation_0-rmse:0.26205	validation_1-rmse:0.22190
# [51]	validation_0-rmse:0.26181	validation_1-rmse:0.22135
# [52]	validation_0-rmse:0.26163	validation_1-rmse:0.22093
# [53]	validation_0-rmse:0.26144	validation_1-rmse:0.22041
# [54]	validation_0-rmse:0.26157	validation_1-rmse:0.22076
# [55]	validation_0-rmse:0.26139	validation_1-rmse:0.22028
# [56]	validation_0-rmse:0.26122	validation_1-rmse:0.21973
# [57]	validation_0-rmse:0.25904	validation_1-rmse:0.21842
# [58]	validation_0-rmse:0.25763	validation_1-rmse:0.21847
# [59]	validation_0-rmse:0.25763	validation_1-rmse:0.21844
# [60]	validation_0-rmse:0.25762	validation_1-rmse:0.21831
# [61]	validation_0-rmse:0.25774	validation_1-rmse:0.21779
# [62]	validation_0-rmse:0.25769	validation_1-rmse:0.21786
# [63]	validation_0-rmse:0.25563	validation_1-rmse:0.21916
# [64]	validation_0-rmse:0.25573	validation_1-rmse:0.21903
# [65]	validation_0-rmse:0.25574	validation_1-rmse:0.21902
# [66]	validation_0-rmse:0.25568	validation_1-rmse:0.21908
# [67]	validation_0-rmse:0.25556	validation_1-rmse:0.21942
# [68]	validation_0-rmse:0.25555	validation_1-rmse:0.21957
# [69]	validation_0-rmse:0.25555	validation_1-rmse:0.21955
# [70]	validation_0-rmse:0.25556	validation_1-rmse:0.21977
# [71]	validation_0-rmse:0.25496	validation_1-rmse:0.22007
# [72]	validation_0-rmse:0.25371	validation_1-rmse:0.22241
# [73]	validation_0-rmse:0.25376	validation_1-rmse:0.22283
# [74]	validation_0-rmse:0.25372	validation_1-rmse:0.22232
# [75]	validation_0-rmse:0.25373	validation_1-rmse:0.22220
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.17588	validation_1-rmse:0.88800
# [1]	validation_0-rmse:1.10103	validation_1-rmse:0.85563
# [2]	validation_0-rmse:1.04791	validation_1-rmse:0.81820
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:0.97650	validation_1-rmse:0.76610
# [4]	validation_0-rmse:0.91194	validation_1-rmse:0.72499
# [5]	validation_0-rmse:0.86654	validation_1-rmse:0.69669
# [6]	validation_0-rmse:0.81223	validation_1-rmse:0.66132
# [7]	validation_0-rmse:0.78013	validation_1-rmse:0.63567
# [8]	validation_0-rmse:0.73288	validation_1-rmse:0.60664
# [9]	validation_0-rmse:0.68787	validation_1-rmse:0.59006
# [10]	validation_0-rmse:0.65270	validation_1-rmse:0.55852
# [11]	validation_0-rmse:0.61104	validation_1-rmse:0.52930
# [12]	validation_0-rmse:0.57192	validation_1-rmse:0.50788
# [13]	validation_0-rmse:0.54135	validation_1-rmse:0.49757
# [14]	validation_0-rmse:0.51859	validation_1-rmse:0.49372
# [15]	validation_0-rmse:0.49103	validation_1-rmse:0.48165
# [16]	validation_0-rmse:0.46464	validation_1-rmse:0.47841
# [17]	validation_0-rmse:0.44636	validation_1-rmse:0.47736
# [18]	validation_0-rmse:0.43257	validation_1-rmse:0.47209
# [19]	validation_0-rmse:0.41980	validation_1-rmse:0.46456
# [20]	validation_0-rmse:0.40476	validation_1-rmse:0.46220
# [21]	validation_0-rmse:0.38477	validation_1-rmse:0.45282
# [22]	validation_0-rmse:0.37328	validation_1-rmse:0.44724
# [23]	validation_0-rmse:0.35779	validation_1-rmse:0.43558
# [24]	validation_0-rmse:0.35641	validation_1-rmse:0.43546
# [25]	validation_0-rmse:0.34473	validation_1-rmse:0.43020
# [26]	validation_0-rmse:0.34166	validation_1-rmse:0.43009
# [27]	validation_0-rmse:0.33351	validation_1-rmse:0.42600
# [28]	validation_0-rmse:0.32826	validation_1-rmse:0.42383
# [29]	validation_0-rmse:0.31376	validation_1-rmse:0.41940
# [30]	validation_0-rmse:0.31068	validation_1-rmse:0.41983
# [31]	validation_0-rmse:0.30180	validation_1-rmse:0.41953
# [32]	validation_0-rmse:0.30074	validation_1-rmse:0.41979
# [33]	validation_0-rmse:0.29453	validation_1-rmse:0.41458
# [34]	validation_0-rmse:0.28770	validation_1-rmse:0.41123
# [35]	validation_0-rmse:0.28155	validation_1-rmse:0.40532
# [36]	validation_0-rmse:0.27078	validation_1-rmse:0.40304
# [37]	validation_0-rmse:0.26913	validation_1-rmse:0.40386
# [38]	validation_0-rmse:0.26073	validation_1-rmse:0.40371
# [39]	validation_0-rmse:0.25520	validation_1-rmse:0.40373
# [40]	validation_0-rmse:0.25426	validation_1-rmse:0.40438
# [41]	validation_0-rmse:0.25509	validation_1-rmse:0.40380
# [42]	validation_0-rmse:0.25063	validation_1-rmse:0.40102
# [43]	validation_0-rmse:0.25043	validation_1-rmse:0.40119
# [44]	validation_0-rmse:0.24740	validation_1-rmse:0.40143
# [45]	validation_0-rmse:0.24517	validation_1-rmse:0.40017
# [46]	validation_0-rmse:0.24434	validation_1-rmse:0.40117
# [47]	validation_0-rmse:0.24436	validation_1-rmse:0.40115
# [48]	validation_0-rmse:0.24436	validation_1-rmse:0.40114
# [49]	validation_0-rmse:0.24425	validation_1-rmse:0.40130
# [50]	validation_0-rmse:0.24430	validation_1-rmse:0.40123
# [51]	validation_0-rmse:0.24395	validation_1-rmse:0.40179
# [52]	validation_0-rmse:0.24365	validation_1-rmse:0.40238
# [53]	validation_0-rmse:0.24367	validation_1-rmse:0.40233
# [54]	validation_0-rmse:0.24324	validation_1-rmse:0.40344
# [55]	validation_0-rmse:0.23997	validation_1-rmse:0.40033
# [56]	validation_0-rmse:0.23626	validation_1-rmse:0.39972
# [57]	validation_0-rmse:0.23605	validation_1-rmse:0.40031
# [58]	validation_0-rmse:0.23582	validation_1-rmse:0.40123
# [59]	validation_0-rmse:0.23578	validation_1-rmse:0.40142
# [60]	validation_0-rmse:0.23337	validation_1-rmse:0.40097
# [61]	validation_0-rmse:0.23325	validation_1-rmse:0.40200
# [62]	validation_0-rmse:0.23018	validation_1-rmse:0.39917
# [63]	validation_0-rmse:0.22773	validation_1-rmse:0.40008
# [64]	validation_0-rmse:0.22644	validation_1-rmse:0.39719
# [65]	validation_0-rmse:0.22646	validation_1-rmse:0.39765
# [66]	validation_0-rmse:0.22648	validation_1-rmse:0.39622
# [67]	validation_0-rmse:0.22375	validation_1-rmse:0.39503
# [68]	validation_0-rmse:0.22387	validation_1-rmse:0.39441
# [69]	validation_0-rmse:0.22341	validation_1-rmse:0.39031
# [70]	validation_0-rmse:0.22294	validation_1-rmse:0.38679
# [71]	validation_0-rmse:0.22327	validation_1-rmse:0.38589
# [72]	validation_0-rmse:0.22303	validation_1-rmse:0.38649
# [73]	validation_0-rmse:0.22311	validation_1-rmse:0.38627
# [74]	validation_0-rmse:0.22286	validation_1-rmse:0.38710
# [75]	validation_0-rmse:0.22301	validation_1-rmse:0.38655
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:0.96709	validation_1-rmse:1.60250
# [1]	validation_0-rmse:0.91389	validation_1-rmse:1.52936
# [2]	validation_0-rmse:0.85640	validation_1-rmse:1.44191
# [3]	validation_0-rmse:0.80259	validation_1-rmse:1.35465
# [4]	validation_0-rmse:0.76663	validation_1-rmse:1.30230
# [5]	validation_0-rmse:0.72681	validation_1-rmse:1.24656
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:0.69686	validation_1-rmse:1.20207
# [7]	validation_0-rmse:0.65709	validation_1-rmse:1.14583
# [8]	validation_0-rmse:0.61212	validation_1-rmse:1.07425
# [9]	validation_0-rmse:0.58295	validation_1-rmse:1.03367
# [10]	validation_0-rmse:0.55677	validation_1-rmse:0.99368
# [11]	validation_0-rmse:0.53149	validation_1-rmse:0.94918
# [12]	validation_0-rmse:0.50100	validation_1-rmse:0.89427
# [13]	validation_0-rmse:0.47499	validation_1-rmse:0.85350
# [14]	validation_0-rmse:0.45733	validation_1-rmse:0.82730
# [15]	validation_0-rmse:0.43110	validation_1-rmse:0.78352
# [16]	validation_0-rmse:0.40936	validation_1-rmse:0.74398
# [17]	validation_0-rmse:0.39301	validation_1-rmse:0.71283
# [18]	validation_0-rmse:0.38564	validation_1-rmse:0.70189
# [19]	validation_0-rmse:0.37897	validation_1-rmse:0.68800
# [20]	validation_0-rmse:0.36525	validation_1-rmse:0.66188
# [21]	validation_0-rmse:0.35349	validation_1-rmse:0.63953
# [22]	validation_0-rmse:0.34297	validation_1-rmse:0.62155
# [23]	validation_0-rmse:0.32894	validation_1-rmse:0.59320
# [24]	validation_0-rmse:0.31703	validation_1-rmse:0.56823
# [25]	validation_0-rmse:0.31087	validation_1-rmse:0.55311
# [26]	validation_0-rmse:0.30401	validation_1-rmse:0.53913
# [27]	validation_0-rmse:0.30228	validation_1-rmse:0.53363
# [28]	validation_0-rmse:0.29837	validation_1-rmse:0.53006
# [29]	validation_0-rmse:0.29218	validation_1-rmse:0.51544
# [30]	validation_0-rmse:0.28812	validation_1-rmse:0.50308
# [31]	validation_0-rmse:0.28443	validation_1-rmse:0.49649
# [32]	validation_0-rmse:0.28059	validation_1-rmse:0.48887
# [33]	validation_0-rmse:0.27789	validation_1-rmse:0.48701
# [34]	validation_0-rmse:0.27765	validation_1-rmse:0.48590
# [35]	validation_0-rmse:0.27737	validation_1-rmse:0.48447
# [36]	validation_0-rmse:0.27778	validation_1-rmse:0.48650
# [37]	validation_0-rmse:0.27685	validation_1-rmse:0.48160
# [38]	validation_0-rmse:0.27055	validation_1-rmse:0.46721
# [39]	validation_0-rmse:0.26693	validation_1-rmse:0.45815
# [40]	validation_0-rmse:0.26480	validation_1-rmse:0.44828
# [41]	validation_0-rmse:0.26049	validation_1-rmse:0.43821
# [42]	validation_0-rmse:0.26060	validation_1-rmse:0.43908
# [43]	validation_0-rmse:0.25892	validation_1-rmse:0.44174
# [44]	validation_0-rmse:0.25895	validation_1-rmse:0.44192
# [45]	validation_0-rmse:0.25845	validation_1-rmse:0.43833
# [46]	validation_0-rmse:0.25607	validation_1-rmse:0.43784
# [47]	validation_0-rmse:0.25590	validation_1-rmse:0.43634
# [48]	validation_0-rmse:0.25299	validation_1-rmse:0.43094
# [49]	validation_0-rmse:0.25277	validation_1-rmse:0.42880
# [50]	validation_0-rmse:0.25289	validation_1-rmse:0.43006
# [51]	validation_0-rmse:0.25107	validation_1-rmse:0.42235
# [52]	validation_0-rmse:0.25098	validation_1-rmse:0.42157
# [53]	validation_0-rmse:0.24792	validation_1-rmse:0.41595
# [54]	validation_0-rmse:0.24666	validation_1-rmse:0.41761
# [55]	validation_0-rmse:0.24681	validation_1-rmse:0.41881
# [56]	validation_0-rmse:0.24397	validation_1-rmse:0.40971
# [57]	validation_0-rmse:0.24265	validation_1-rmse:0.40821
# [58]	validation_0-rmse:0.24204	validation_1-rmse:0.40932
# [59]	validation_0-rmse:0.24184	validation_1-rmse:0.40789
# [60]	validation_0-rmse:0.23898	validation_1-rmse:0.39994
# [61]	validation_0-rmse:0.23908	validation_1-rmse:0.40096
# [62]	validation_0-rmse:0.23904	validation_1-rmse:0.40058
# [63]	validation_0-rmse:0.23814	validation_1-rmse:0.39906
# [64]	validation_0-rmse:0.23821	validation_1-rmse:0.39979
# [65]	validation_0-rmse:0.23804	validation_1-rmse:0.39794
# [66]	validation_0-rmse:0.23824	validation_1-rmse:0.40011
# [67]	validation_0-rmse:0.23660	validation_1-rmse:0.39709
# [68]	validation_0-rmse:0.23664	validation_1-rmse:0.39767
# [69]	validation_0-rmse:0.23387	validation_1-rmse:0.39174
# [70]	validation_0-rmse:0.23378	validation_1-rmse:0.39029
# [71]	validation_0-rmse:0.23381	validation_1-rmse:0.39074
# [72]	validation_0-rmse:0.23144	validation_1-rmse:0.38549
# [73]	validation_0-rmse:0.22934	validation_1-rmse:0.38374
# [74]	validation_0-rmse:0.22942	validation_1-rmse:0.38589
# [75]	validation_0-rmse:0.22934	validation_1-rmse:0.38243
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.19020	validation_1-rmse:0.75571
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.11478	validation_1-rmse:0.73260
# [2]	validation_0-rmse:1.03694	validation_1-rmse:0.70353
# [3]	validation_0-rmse:0.96968	validation_1-rmse:0.65244
# [4]	validation_0-rmse:0.92193	validation_1-rmse:0.62740
# [5]	validation_0-rmse:0.87459	validation_1-rmse:0.59563
# [6]	validation_0-rmse:0.81712	validation_1-rmse:0.57121
# [7]	validation_0-rmse:0.76849	validation_1-rmse:0.54800
# [8]	validation_0-rmse:0.72033	validation_1-rmse:0.52620
# [9]	validation_0-rmse:0.67969	validation_1-rmse:0.50904
# [10]	validation_0-rmse:0.64780	validation_1-rmse:0.49505
# [11]	validation_0-rmse:0.61936	validation_1-rmse:0.49141
# [12]	validation_0-rmse:0.58568	validation_1-rmse:0.48606
# [13]	validation_0-rmse:0.55461	validation_1-rmse:0.47342
# [14]	validation_0-rmse:0.52143	validation_1-rmse:0.46597
# [15]	validation_0-rmse:0.50344	validation_1-rmse:0.46151
# [16]	validation_0-rmse:0.48044	validation_1-rmse:0.45925
# [17]	validation_0-rmse:0.45773	validation_1-rmse:0.45430
# [18]	validation_0-rmse:0.44456	validation_1-rmse:0.45204
# [19]	validation_0-rmse:0.41536	validation_1-rmse:0.45280
# [20]	validation_0-rmse:0.40343	validation_1-rmse:0.45304
# [21]	validation_0-rmse:0.38654	validation_1-rmse:0.44362
# [22]	validation_0-rmse:0.36739	validation_1-rmse:0.44413
# [23]	validation_0-rmse:0.35694	validation_1-rmse:0.44289
# [24]	validation_0-rmse:0.34027	validation_1-rmse:0.44316
# [25]	validation_0-rmse:0.32697	validation_1-rmse:0.44615
# [26]	validation_0-rmse:0.31254	validation_1-rmse:0.44875
# [27]	validation_0-rmse:0.30470	validation_1-rmse:0.44832
# [28]	validation_0-rmse:0.29467	validation_1-rmse:0.44940
# [29]	validation_0-rmse:0.28750	validation_1-rmse:0.45008
# [30]	validation_0-rmse:0.28216	validation_1-rmse:0.44943
# [31]	validation_0-rmse:0.27169	validation_1-rmse:0.45048
# [32]	validation_0-rmse:0.26879	validation_1-rmse:0.45343
# [33]	validation_0-rmse:0.26714	validation_1-rmse:0.45530
# [34]	validation_0-rmse:0.25799	validation_1-rmse:0.45287
# [35]	validation_0-rmse:0.25249	validation_1-rmse:0.45830
# [36]	validation_0-rmse:0.24564	validation_1-rmse:0.46008
# [37]	validation_0-rmse:0.24390	validation_1-rmse:0.46309
# [38]	validation_0-rmse:0.24352	validation_1-rmse:0.46381
# [39]	validation_0-rmse:0.24292	validation_1-rmse:0.46506
# [40]	validation_0-rmse:0.23762	validation_1-rmse:0.46655
# [41]	validation_0-rmse:0.23768	validation_1-rmse:0.46642
# [42]	validation_0-rmse:0.23325	validation_1-rmse:0.46944
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.19768	validation_1-rmse:0.71804
# [1]	validation_0-rmse:1.11374	validation_1-rmse:0.66323
# [2]	validation_0-rmse:1.04633	validation_1-rmse:0.61091
# [3]	validation_0-rmse:0.98591	validation_1-rmse:0.57906
# [4]	validation_0-rmse:0.92528	validation_1-rmse:0.53740
# [5]	validation_0-rmse:0.87752	validation_1-rmse:0.50988
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:0.82751	validation_1-rmse:0.48179
# [7]	validation_0-rmse:0.77344	validation_1-rmse:0.44491
# [8]	validation_0-rmse:0.72095	validation_1-rmse:0.42248
# [9]	validation_0-rmse:0.67364	validation_1-rmse:0.40233
# [10]	validation_0-rmse:0.63205	validation_1-rmse:0.38508
# [11]	validation_0-rmse:0.61888	validation_1-rmse:0.38086
# [12]	validation_0-rmse:0.58866	validation_1-rmse:0.36992
# [13]	validation_0-rmse:0.55973	validation_1-rmse:0.34678
# [14]	validation_0-rmse:0.54068	validation_1-rmse:0.34097
# [15]	validation_0-rmse:0.51283	validation_1-rmse:0.33556
# [16]	validation_0-rmse:0.49544	validation_1-rmse:0.32925
# [17]	validation_0-rmse:0.47468	validation_1-rmse:0.31782
# [18]	validation_0-rmse:0.46207	validation_1-rmse:0.31774
# [19]	validation_0-rmse:0.44923	validation_1-rmse:0.31639
# [20]	validation_0-rmse:0.43365	validation_1-rmse:0.31574
# [21]	validation_0-rmse:0.42372	validation_1-rmse:0.30970
# [22]	validation_0-rmse:0.40746	validation_1-rmse:0.30748
# [23]	validation_0-rmse:0.38529	validation_1-rmse:0.30411
# [24]	validation_0-rmse:0.37563	validation_1-rmse:0.30362
# [25]	validation_0-rmse:0.36350	validation_1-rmse:0.30319
# [26]	validation_0-rmse:0.35404	validation_1-rmse:0.30495
# [27]	validation_0-rmse:0.34242	validation_1-rmse:0.30999
# [28]	validation_0-rmse:0.32637	validation_1-rmse:0.30987
# [29]	validation_0-rmse:0.31983	validation_1-rmse:0.31158
# [30]	validation_0-rmse:0.31010	validation_1-rmse:0.31286
# [31]	validation_0-rmse:0.30881	validation_1-rmse:0.31477
# [32]	validation_0-rmse:0.29809	validation_1-rmse:0.31585
# [33]	validation_0-rmse:0.28400	validation_1-rmse:0.31465
# [34]	validation_0-rmse:0.28316	validation_1-rmse:0.31621
# [35]	validation_0-rmse:0.27928	validation_1-rmse:0.31436
# [36]	validation_0-rmse:0.27153	validation_1-rmse:0.31538
# [37]	validation_0-rmse:0.26954	validation_1-rmse:0.31923
# [38]	validation_0-rmse:0.26835	validation_1-rmse:0.32187
# [39]	validation_0-rmse:0.26708	validation_1-rmse:0.32502
# [40]	validation_0-rmse:0.26679	validation_1-rmse:0.32580
# [41]	validation_0-rmse:0.26738	validation_1-rmse:0.32424
# [42]	validation_0-rmse:0.26629	validation_1-rmse:0.32721
# [43]	validation_0-rmse:0.26493	validation_1-rmse:0.33164
# [44]	validation_0-rmse:0.26081	validation_1-rmse:0.33228
# [45]	validation_0-rmse:0.25713	validation_1-rmse:0.33247
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.11349	validation_1-rmse:1.04701
# [1]	validation_0-rmse:1.02712	validation_1-rmse:0.96043
# [2]	validation_0-rmse:0.95945	validation_1-rmse:0.89167
# [3]	validation_0-rmse:0.91363	validation_1-rmse:0.85257
# [4]	validation_0-rmse:0.84445	validation_1-rmse:0.78992
# [5]	validation_0-rmse:0.79401	validation_1-rmse:0.75067
# [6]	validation_0-rmse:0.74056	validation_1-rmse:0.70171
# [7]	validation_0-rmse:0.70596	validation_1-rmse:0.66456
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:0.65655	validation_1-rmse:0.61936
# [9]	validation_0-rmse:0.61949	validation_1-rmse:0.58620
# [10]	validation_0-rmse:0.60364	validation_1-rmse:0.57189
# [11]	validation_0-rmse:0.57964	validation_1-rmse:0.54953
# [12]	validation_0-rmse:0.54304	validation_1-rmse:0.51682
# [13]	validation_0-rmse:0.52045	validation_1-rmse:0.49545
# [14]	validation_0-rmse:0.49808	validation_1-rmse:0.47724
# [15]	validation_0-rmse:0.46913	validation_1-rmse:0.45362
# [16]	validation_0-rmse:0.44889	validation_1-rmse:0.43348
# [17]	validation_0-rmse:0.42760	validation_1-rmse:0.41793
# [18]	validation_0-rmse:0.41535	validation_1-rmse:0.40385
# [19]	validation_0-rmse:0.40599	validation_1-rmse:0.39902
# [20]	validation_0-rmse:0.38734	validation_1-rmse:0.38162
# [21]	validation_0-rmse:0.36844	validation_1-rmse:0.36895
# [22]	validation_0-rmse:0.35411	validation_1-rmse:0.35755
# [23]	validation_0-rmse:0.33940	validation_1-rmse:0.34765
# [24]	validation_0-rmse:0.33032	validation_1-rmse:0.34077
# [25]	validation_0-rmse:0.32400	validation_1-rmse:0.33477
# [26]	validation_0-rmse:0.31828	validation_1-rmse:0.33072
# [27]	validation_0-rmse:0.31408	validation_1-rmse:0.32777
# [28]	validation_0-rmse:0.30619	validation_1-rmse:0.32307
# [29]	validation_0-rmse:0.30090	validation_1-rmse:0.32024
# [30]	validation_0-rmse:0.29458	validation_1-rmse:0.31671
# [31]	validation_0-rmse:0.29326	validation_1-rmse:0.31592
# [32]	validation_0-rmse:0.29362	validation_1-rmse:0.31613
# [33]	validation_0-rmse:0.29315	validation_1-rmse:0.31585
# [34]	validation_0-rmse:0.28910	validation_1-rmse:0.31535
# [35]	validation_0-rmse:0.28674	validation_1-rmse:0.31407
# [36]	validation_0-rmse:0.28152	validation_1-rmse:0.31156
# [37]	validation_0-rmse:0.28115	validation_1-rmse:0.31138
# [38]	validation_0-rmse:0.27547	validation_1-rmse:0.30836
# [39]	validation_0-rmse:0.26683	validation_1-rmse:0.30398
# [40]	validation_0-rmse:0.26357	validation_1-rmse:0.30268
# [41]	validation_0-rmse:0.26409	validation_1-rmse:0.30288
# [42]	validation_0-rmse:0.26365	validation_1-rmse:0.30271
# [43]	validation_0-rmse:0.26144	validation_1-rmse:0.30352
# [44]	validation_0-rmse:0.25965	validation_1-rmse:0.30507
# [45]	validation_0-rmse:0.25895	validation_1-rmse:0.30483
# [46]	validation_0-rmse:0.25572	validation_1-rmse:0.30396
# [47]	validation_0-rmse:0.25622	validation_1-rmse:0.30413
# [48]	validation_0-rmse:0.25097	validation_1-rmse:0.30134
# [49]	validation_0-rmse:0.24567	validation_1-rmse:0.29891
# [50]	validation_0-rmse:0.24490	validation_1-rmse:0.29874
# [51]	validation_0-rmse:0.24213	validation_1-rmse:0.29747
# [52]	validation_0-rmse:0.23960	validation_1-rmse:0.29583
# [53]	validation_0-rmse:0.23981	validation_1-rmse:0.29581
# [54]	validation_0-rmse:0.23616	validation_1-rmse:0.29332
# [55]	validation_0-rmse:0.23599	validation_1-rmse:0.29340
# [56]	validation_0-rmse:0.23585	validation_1-rmse:0.29350
# [57]	validation_0-rmse:0.23562	validation_1-rmse:0.29371
# [58]	validation_0-rmse:0.23574	validation_1-rmse:0.29359
# [59]	validation_0-rmse:0.23577	validation_1-rmse:0.29356
# [60]	validation_0-rmse:0.23606	validation_1-rmse:0.29337
# [61]	validation_0-rmse:0.23578	validation_1-rmse:0.29355
# [62]	validation_0-rmse:0.23444	validation_1-rmse:0.29663
# [63]	validation_0-rmse:0.23445	validation_1-rmse:0.29662
# [64]	validation_0-rmse:0.23222	validation_1-rmse:0.29584
# [65]	validation_0-rmse:0.23229	validation_1-rmse:0.29577
# [66]	validation_0-rmse:0.23017	validation_1-rmse:0.29629
# [67]	validation_0-rmse:0.23023	validation_1-rmse:0.29621
# [68]	validation_0-rmse:0.23032	validation_1-rmse:0.29612
# [69]	validation_0-rmse:0.23043	validation_1-rmse:0.29603
# [70]	validation_0-rmse:0.23020	validation_1-rmse:0.29625
# [71]	validation_0-rmse:0.22886	validation_1-rmse:0.29653
# [72]	validation_0-rmse:0.22875	validation_1-rmse:0.29672
# [73]	validation_0-rmse:0.22872	validation_1-rmse:0.29678
# [74]	validation_0-rmse:0.22871	validation_1-rmse:0.29679
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.14700	validation_1-rmse:1.00485
# [1]	validation_0-rmse:1.06627	validation_1-rmse:0.94005
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:1.00380	validation_1-rmse:0.88210
# [3]	validation_0-rmse:0.93051	validation_1-rmse:0.81883
# [4]	validation_0-rmse:0.87684	validation_1-rmse:0.76820
# [5]	validation_0-rmse:0.81728	validation_1-rmse:0.71414
# [6]	validation_0-rmse:0.77501	validation_1-rmse:0.67846
# [7]	validation_0-rmse:0.72741	validation_1-rmse:0.63165
# [8]	validation_0-rmse:0.68676	validation_1-rmse:0.59542
# [9]	validation_0-rmse:0.65402	validation_1-rmse:0.56768
# [10]	validation_0-rmse:0.62342	validation_1-rmse:0.54270
# [11]	validation_0-rmse:0.59630	validation_1-rmse:0.52366
# [12]	validation_0-rmse:0.55727	validation_1-rmse:0.49060
# [13]	validation_0-rmse:0.52876	validation_1-rmse:0.45950
# [14]	validation_0-rmse:0.51582	validation_1-rmse:0.45005
# [15]	validation_0-rmse:0.48700	validation_1-rmse:0.42794
# [16]	validation_0-rmse:0.46212	validation_1-rmse:0.40667
# [17]	validation_0-rmse:0.44386	validation_1-rmse:0.38938
# [18]	validation_0-rmse:0.42707	validation_1-rmse:0.37598
# [19]	validation_0-rmse:0.41324	validation_1-rmse:0.36639
# [20]	validation_0-rmse:0.39602	validation_1-rmse:0.35181
# [21]	validation_0-rmse:0.38466	validation_1-rmse:0.34023
# [22]	validation_0-rmse:0.37318	validation_1-rmse:0.33122
# [23]	validation_0-rmse:0.37255	validation_1-rmse:0.33065
# [24]	validation_0-rmse:0.36162	validation_1-rmse:0.32216
# [25]	validation_0-rmse:0.34752	validation_1-rmse:0.30838
# [26]	validation_0-rmse:0.33797	validation_1-rmse:0.30033
# [27]	validation_0-rmse:0.33331	validation_1-rmse:0.29544
# [28]	validation_0-rmse:0.32566	validation_1-rmse:0.28777
# [29]	validation_0-rmse:0.32199	validation_1-rmse:0.28815
# [30]	validation_0-rmse:0.31482	validation_1-rmse:0.28216
# [31]	validation_0-rmse:0.30839	validation_1-rmse:0.27683
# [32]	validation_0-rmse:0.30006	validation_1-rmse:0.26939
# [33]	validation_0-rmse:0.29277	validation_1-rmse:0.26346
# [34]	validation_0-rmse:0.28799	validation_1-rmse:0.25780
# [35]	validation_0-rmse:0.28754	validation_1-rmse:0.25728
# [36]	validation_0-rmse:0.28390	validation_1-rmse:0.25446
# [37]	validation_0-rmse:0.28275	validation_1-rmse:0.25116
# [38]	validation_0-rmse:0.27876	validation_1-rmse:0.24837
# [39]	validation_0-rmse:0.27826	validation_1-rmse:0.24779
# [40]	validation_0-rmse:0.27383	validation_1-rmse:0.24522
# [41]	validation_0-rmse:0.27258	validation_1-rmse:0.24556
# [42]	validation_0-rmse:0.27206	validation_1-rmse:0.24491
# [43]	validation_0-rmse:0.27194	validation_1-rmse:0.24476
# [44]	validation_0-rmse:0.27104	validation_1-rmse:0.24356
# [45]	validation_0-rmse:0.26893	validation_1-rmse:0.24094
# [46]	validation_0-rmse:0.26881	validation_1-rmse:0.24075
# [47]	validation_0-rmse:0.26574	validation_1-rmse:0.23909
# [48]	validation_0-rmse:0.26567	validation_1-rmse:0.23898
# [49]	validation_0-rmse:0.26320	validation_1-rmse:0.23626
# [50]	validation_0-rmse:0.26162	validation_1-rmse:0.23530
# [51]	validation_0-rmse:0.26170	validation_1-rmse:0.23549
# [52]	validation_0-rmse:0.25882	validation_1-rmse:0.23319
# [53]	validation_0-rmse:0.25875	validation_1-rmse:0.23287
# [54]	validation_0-rmse:0.25879	validation_1-rmse:0.23306
# [55]	validation_0-rmse:0.25878	validation_1-rmse:0.23304
# [56]	validation_0-rmse:0.25686	validation_1-rmse:0.23254
# [57]	validation_0-rmse:0.25684	validation_1-rmse:0.23246
# [58]	validation_0-rmse:0.25606	validation_1-rmse:0.23239
# [59]	validation_0-rmse:0.25610	validation_1-rmse:0.23272
# [60]	validation_0-rmse:0.25468	validation_1-rmse:0.23196
# [61]	validation_0-rmse:0.25474	validation_1-rmse:0.23220
# [62]	validation_0-rmse:0.25298	validation_1-rmse:0.23282
# [63]	validation_0-rmse:0.25134	validation_1-rmse:0.23251
# [64]	validation_0-rmse:0.25133	validation_1-rmse:0.23246
# [65]	validation_0-rmse:0.25165	validation_1-rmse:0.23372
# [66]	validation_0-rmse:0.25138	validation_1-rmse:0.23271
# [67]	validation_0-rmse:0.25129	validation_1-rmse:0.23213
# [68]	validation_0-rmse:0.25128	validation_1-rmse:0.23167
# ...
# [23]	validation_0-rmse:0.36762	validation_1-rmse:0.49574
# [24]	validation_0-rmse:0.35635	validation_1-rmse:0.48218
# [25]	validation_0-rmse:0.34222	validation_1-rmse:0.47240
# [26]	validation_0-rmse:0.33089	validation_1-rmse:0.45589
# [27]	validation_0-rmse:0.31883	validation_1-rmse:0.43801
# [28]	validation_0-rmse:0.31689	validation_1-rmse:0.43677
# [29]	validation_0-rmse:0.31335	validation_1-rmse:0.43341
# [30]	validation_0-rmse:0.31427	validation_1-rmse:0.43519
# [31]	validation_0-rmse:0.30694	validation_1-rmse:0.42499
# [32]	validation_0-rmse:0.30632	validation_1-rmse:0.42370
# [33]	validation_0-rmse:0.30562	validation_1-rmse:0.42222
# [34]	validation_0-rmse:0.29395	validation_1-rmse:0.40357
# [35]	validation_0-rmse:0.29094	validation_1-rmse:0.39488
# [36]	validation_0-rmse:0.29107	validation_1-rmse:0.39519
# [37]	validation_0-rmse:0.29073	validation_1-rmse:0.39439
# [38]	validation_0-rmse:0.28668	validation_1-rmse:0.39182
# [39]	validation_0-rmse:0.28128	validation_1-rmse:0.38756
# [40]	validation_0-rmse:0.27965	validation_1-rmse:0.38370
# [41]	validation_0-rmse:0.27847	validation_1-rmse:0.38066
# [42]	validation_0-rmse:0.27665	validation_1-rmse:0.37876
# [43]	validation_0-rmse:0.27213	validation_1-rmse:0.37290
# [44]	validation_0-rmse:0.27220	validation_1-rmse:0.37309
# [45]	validation_0-rmse:0.26988	validation_1-rmse:0.36684
# [46]	validation_0-rmse:0.26687	validation_1-rmse:0.36242
# [47]	validation_0-rmse:0.26690	validation_1-rmse:0.36251
# [48]	validation_0-rmse:0.26430	validation_1-rmse:0.35630
# [49]	validation_0-rmse:0.26404	validation_1-rmse:0.35521
# [50]	validation_0-rmse:0.26396	validation_1-rmse:0.35493
# [51]	validation_0-rmse:0.26128	validation_1-rmse:0.35228
# [52]	validation_0-rmse:0.25594	validation_1-rmse:0.34404
# [53]	validation_0-rmse:0.25637	validation_1-rmse:0.34546
# [54]	validation_0-rmse:0.25614	validation_1-rmse:0.34690
# [55]	validation_0-rmse:0.25271	validation_1-rmse:0.34347
# [56]	validation_0-rmse:0.24887	validation_1-rmse:0.33802
# [57]	validation_0-rmse:0.24800	validation_1-rmse:0.33471
# [58]	validation_0-rmse:0.24738	validation_1-rmse:0.33187
# [59]	validation_0-rmse:0.24699	validation_1-rmse:0.33260
# [60]	validation_0-rmse:0.24528	validation_1-rmse:0.33184
# [61]	validation_0-rmse:0.24558	validation_1-rmse:0.33321
# [62]	validation_0-rmse:0.24519	validation_1-rmse:0.33224
# [63]	validation_0-rmse:0.24480	validation_1-rmse:0.33026
# [64]	validation_0-rmse:0.24473	validation_1-rmse:0.32990
# [65]	validation_0-rmse:0.24406	validation_1-rmse:0.32483
# [66]	validation_0-rmse:0.24105	validation_1-rmse:0.32410
# [67]	validation_0-rmse:0.24095	validation_1-rmse:0.32298
# [68]	validation_0-rmse:0.24088	validation_1-rmse:0.32200
# [69]	validation_0-rmse:0.24082	validation_1-rmse:0.32059
# [70]	validation_0-rmse:0.24081	validation_1-rmse:0.32001
# [71]	validation_0-rmse:0.24083	validation_1-rmse:0.32085
# [72]	validation_0-rmse:0.24081	validation_1-rmse:0.31998
# [73]	validation_0-rmse:0.24080	validation_1-rmse:0.31988
# [74]	validation_0-rmse:0.24018	validation_1-rmse:0.31777
# [75]	validation_0-rmse:0.24031	validation_1-rmse:0.31576
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.11769	validation_1-rmse:1.17095
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.05636	validation_1-rmse:1.11510
# [2]	validation_0-rmse:0.99313	validation_1-rmse:1.04358
# [3]	validation_0-rmse:0.94167	validation_1-rmse:0.98617
# [4]	validation_0-rmse:0.88880	validation_1-rmse:0.92020
# [5]	validation_0-rmse:0.85644	validation_1-rmse:0.89375
# [6]	validation_0-rmse:0.80693	validation_1-rmse:0.83398
# [7]	validation_0-rmse:0.77792	validation_1-rmse:0.80068
# [8]	validation_0-rmse:0.72482	validation_1-rmse:0.74309
# [9]	validation_0-rmse:0.69293	validation_1-rmse:0.70797
# [10]	validation_0-rmse:0.67035	validation_1-rmse:0.68310
# [11]	validation_0-rmse:0.63034	validation_1-rmse:0.62863
# [12]	validation_0-rmse:0.59176	validation_1-rmse:0.59353
# [13]	validation_0-rmse:0.57023	validation_1-rmse:0.56548
# [14]	validation_0-rmse:0.54602	validation_1-rmse:0.54627
# [15]	validation_0-rmse:0.51837	validation_1-rmse:0.51332
# [16]	validation_0-rmse:0.49434	validation_1-rmse:0.48294
# [17]	validation_0-rmse:0.47082	validation_1-rmse:0.46353
# [18]	validation_0-rmse:0.46444	validation_1-rmse:0.45603
# [19]	validation_0-rmse:0.43988	validation_1-rmse:0.42328
# [20]	validation_0-rmse:0.41691	validation_1-rmse:0.39418
# [21]	validation_0-rmse:0.40627	validation_1-rmse:0.38133
# [22]	validation_0-rmse:0.39417	validation_1-rmse:0.36727
# [23]	validation_0-rmse:0.38607	validation_1-rmse:0.35681
# [24]	validation_0-rmse:0.37645	validation_1-rmse:0.34847
# [25]	validation_0-rmse:0.36805	validation_1-rmse:0.33766
# [26]	validation_0-rmse:0.36230	validation_1-rmse:0.32817
# [27]	validation_0-rmse:0.35602	validation_1-rmse:0.31963
# [28]	validation_0-rmse:0.34435	validation_1-rmse:0.30551
# [29]	validation_0-rmse:0.33883	validation_1-rmse:0.30503
# [30]	validation_0-rmse:0.32657	validation_1-rmse:0.29041
# [31]	validation_0-rmse:0.31916	validation_1-rmse:0.28365
# [32]	validation_0-rmse:0.31909	validation_1-rmse:0.28353
# [33]	validation_0-rmse:0.31362	validation_1-rmse:0.27804
# [34]	validation_0-rmse:0.30910	validation_1-rmse:0.27394
# [35]	validation_0-rmse:0.30669	validation_1-rmse:0.27135
# [36]	validation_0-rmse:0.30524	validation_1-rmse:0.27048
# [37]	validation_0-rmse:0.30500	validation_1-rmse:0.27009
# [38]	validation_0-rmse:0.29765	validation_1-rmse:0.26085
# [39]	validation_0-rmse:0.29225	validation_1-rmse:0.25664
# [40]	validation_0-rmse:0.28718	validation_1-rmse:0.25298
# [41]	validation_0-rmse:0.28689	validation_1-rmse:0.25247
# [42]	validation_0-rmse:0.28387	validation_1-rmse:0.24977
# [43]	validation_0-rmse:0.28371	validation_1-rmse:0.24947
# [44]	validation_0-rmse:0.28056	validation_1-rmse:0.24587
# [45]	validation_0-rmse:0.27864	validation_1-rmse:0.24559
# [46]	validation_0-rmse:0.27333	validation_1-rmse:0.24442
# [47]	validation_0-rmse:0.27348	validation_1-rmse:0.24477
# [48]	validation_0-rmse:0.27034	validation_1-rmse:0.24436
# [49]	validation_0-rmse:0.26994	validation_1-rmse:0.24330
# [50]	validation_0-rmse:0.26791	validation_1-rmse:0.23837
# [51]	validation_0-rmse:0.26580	validation_1-rmse:0.23744
# [52]	validation_0-rmse:0.26582	validation_1-rmse:0.23755
# [53]	validation_0-rmse:0.26586	validation_1-rmse:0.23773
# [54]	validation_0-rmse:0.26582	validation_1-rmse:0.23755
# [55]	validation_0-rmse:0.26586	validation_1-rmse:0.23773
# [56]	validation_0-rmse:0.26597	validation_1-rmse:0.23816
# [57]	validation_0-rmse:0.26592	validation_1-rmse:0.23798
# [58]	validation_0-rmse:0.26604	validation_1-rmse:0.23840
# [59]	validation_0-rmse:0.26472	validation_1-rmse:0.23841
# [60]	validation_0-rmse:0.26215	validation_1-rmse:0.24010
# [61]	validation_0-rmse:0.26163	validation_1-rmse:0.23884
# [62]	validation_0-rmse:0.26139	validation_1-rmse:0.23811
# [63]	validation_0-rmse:0.26136	validation_1-rmse:0.23799
# [64]	validation_0-rmse:0.26118	validation_1-rmse:0.23712
# [65]	validation_0-rmse:0.25969	validation_1-rmse:0.23642
# [66]	validation_0-rmse:0.25974	validation_1-rmse:0.23662
# [67]	validation_0-rmse:0.25995	validation_1-rmse:0.23731
# [68]	validation_0-rmse:0.25961	validation_1-rmse:0.23590
# [69]	validation_0-rmse:0.25810	validation_1-rmse:0.23650
# [70]	validation_0-rmse:0.25826	validation_1-rmse:0.23762
# [71]	validation_0-rmse:0.25819	validation_1-rmse:0.23735
# [72]	validation_0-rmse:0.25811	validation_1-rmse:0.23682
# [73]	validation_0-rmse:0.25827	validation_1-rmse:0.23768
# [74]	validation_0-rmse:0.25823	validation_1-rmse:0.23755
# [75]	validation_0-rmse:0.25755	validation_1-rmse:0.24122
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.13790	validation_1-rmse:1.02404
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.06731	validation_1-rmse:0.97014
# [2]	validation_0-rmse:0.99596	validation_1-rmse:0.91429
# [3]	validation_0-rmse:0.93519	validation_1-rmse:0.86169
# [4]	validation_0-rmse:0.87133	validation_1-rmse:0.81618
# [5]	validation_0-rmse:0.83986	validation_1-rmse:0.77944
# [6]	validation_0-rmse:0.79125	validation_1-rmse:0.75385
# [7]	validation_0-rmse:0.74978	validation_1-rmse:0.71685
# [8]	validation_0-rmse:0.70836	validation_1-rmse:0.68235
# [9]	validation_0-rmse:0.69038	validation_1-rmse:0.66613
# [10]	validation_0-rmse:0.64994	validation_1-rmse:0.63448
# [11]	validation_0-rmse:0.62331	validation_1-rmse:0.61175
# [12]	validation_0-rmse:0.58498	validation_1-rmse:0.58105
# [13]	validation_0-rmse:0.55811	validation_1-rmse:0.55874
# [14]	validation_0-rmse:0.53371	validation_1-rmse:0.54898
# [15]	validation_0-rmse:0.49832	validation_1-rmse:0.51846
# [16]	validation_0-rmse:0.47930	validation_1-rmse:0.50380
# [17]	validation_0-rmse:0.45999	validation_1-rmse:0.48649
# [18]	validation_0-rmse:0.44061	validation_1-rmse:0.48173
# [19]	validation_0-rmse:0.42536	validation_1-rmse:0.47740
# [20]	validation_0-rmse:0.41574	validation_1-rmse:0.46316
# [21]	validation_0-rmse:0.39596	validation_1-rmse:0.44534
# [22]	validation_0-rmse:0.38417	validation_1-rmse:0.44420
# [23]	validation_0-rmse:0.37986	validation_1-rmse:0.43889
# [24]	validation_0-rmse:0.36454	validation_1-rmse:0.43386
# [25]	validation_0-rmse:0.35416	validation_1-rmse:0.41968
# [26]	validation_0-rmse:0.34794	validation_1-rmse:0.41201
# [27]	validation_0-rmse:0.34313	validation_1-rmse:0.40888
# [28]	validation_0-rmse:0.33068	validation_1-rmse:0.38973
# [29]	validation_0-rmse:0.32138	validation_1-rmse:0.37753
# [30]	validation_0-rmse:0.31509	validation_1-rmse:0.36458
# [31]	validation_0-rmse:0.31513	validation_1-rmse:0.36466
# [32]	validation_0-rmse:0.31216	validation_1-rmse:0.36161
# [33]	validation_0-rmse:0.30636	validation_1-rmse:0.34818
# [34]	validation_0-rmse:0.30059	validation_1-rmse:0.35464
# [35]	validation_0-rmse:0.29979	validation_1-rmse:0.35310
# [36]	validation_0-rmse:0.29745	validation_1-rmse:0.35469
# [37]	validation_0-rmse:0.29709	validation_1-rmse:0.35399
# [38]	validation_0-rmse:0.29709	validation_1-rmse:0.35399
# [39]	validation_0-rmse:0.29450	validation_1-rmse:0.35324
# [40]	validation_0-rmse:0.29149	validation_1-rmse:0.35588
# [41]	validation_0-rmse:0.29079	validation_1-rmse:0.35446
# [42]	validation_0-rmse:0.28946	validation_1-rmse:0.35159
# [43]	validation_0-rmse:0.28724	validation_1-rmse:0.34714
# [44]	validation_0-rmse:0.28177	validation_1-rmse:0.34159
# [45]	validation_0-rmse:0.28136	validation_1-rmse:0.34056
# [46]	validation_0-rmse:0.27864	validation_1-rmse:0.34248
# [47]	validation_0-rmse:0.27901	validation_1-rmse:0.34333
# [48]	validation_0-rmse:0.27443	validation_1-rmse:0.33594
# [49]	validation_0-rmse:0.27302	validation_1-rmse:0.33652
# [50]	validation_0-rmse:0.26650	validation_1-rmse:0.32689
# [51]	validation_0-rmse:0.26060	validation_1-rmse:0.32261
# [52]	validation_0-rmse:0.26004	validation_1-rmse:0.32537
# [53]	validation_0-rmse:0.25915	validation_1-rmse:0.32279
# [54]	validation_0-rmse:0.25947	validation_1-rmse:0.32374
# [55]	validation_0-rmse:0.25922	validation_1-rmse:0.32299
# [56]	validation_0-rmse:0.25683	validation_1-rmse:0.31599
# [57]	validation_0-rmse:0.25384	validation_1-rmse:0.30996
# [58]	validation_0-rmse:0.25340	validation_1-rmse:0.30847
# [59]	validation_0-rmse:0.25349	validation_1-rmse:0.30880
# [60]	validation_0-rmse:0.25335	validation_1-rmse:0.30830
# [61]	validation_0-rmse:0.25293	validation_1-rmse:0.30675
# [62]	validation_0-rmse:0.25258	validation_1-rmse:0.30530
# [63]	validation_0-rmse:0.25171	validation_1-rmse:0.30062
# [64]	validation_0-rmse:0.25171	validation_1-rmse:0.30064
# [65]	validation_0-rmse:0.25155	validation_1-rmse:0.29930
# [66]	validation_0-rmse:0.24931	validation_1-rmse:0.29355
# [67]	validation_0-rmse:0.24929	validation_1-rmse:0.29290
# [68]	validation_0-rmse:0.24929	validation_1-rmse:0.29300
# [69]	validation_0-rmse:0.24821	validation_1-rmse:0.29550
# [70]	validation_0-rmse:0.24740	validation_1-rmse:0.30124
# [71]	validation_0-rmse:0.24581	validation_1-rmse:0.29682
# [72]	validation_0-rmse:0.24570	validation_1-rmse:0.29553
# [73]	validation_0-rmse:0.24646	validation_1-rmse:0.29408
# [74]	validation_0-rmse:0.24644	validation_1-rmse:0.29267
# [75]	validation_0-rmse:0.24644	validation_1-rmse:0.29314
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.16045	validation_1-rmse:0.89098
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.08734	validation_1-rmse:0.83233
# [2]	validation_0-rmse:1.01936	validation_1-rmse:0.77476
# [3]	validation_0-rmse:0.95319	validation_1-rmse:0.71244
# [4]	validation_0-rmse:0.88755	validation_1-rmse:0.65489
# [5]	validation_0-rmse:0.83431	validation_1-rmse:0.60052
# [6]	validation_0-rmse:0.78565	validation_1-rmse:0.56418
# [7]	validation_0-rmse:0.75387	validation_1-rmse:0.53924
# [8]	validation_0-rmse:0.71573	validation_1-rmse:0.51108
# [9]	validation_0-rmse:0.67053	validation_1-rmse:0.47676
# [10]	validation_0-rmse:0.63512	validation_1-rmse:0.44629
# [11]	validation_0-rmse:0.60746	validation_1-rmse:0.43260
# [12]	validation_0-rmse:0.57253	validation_1-rmse:0.40802
# [13]	validation_0-rmse:0.53993	validation_1-rmse:0.38782
# [14]	validation_0-rmse:0.52415	validation_1-rmse:0.38114
# [15]	validation_0-rmse:0.49408	validation_1-rmse:0.36866
# [16]	validation_0-rmse:0.47021	validation_1-rmse:0.36127
# [17]	validation_0-rmse:0.44154	validation_1-rmse:0.34809
# [18]	validation_0-rmse:0.42928	validation_1-rmse:0.34777
# [19]	validation_0-rmse:0.41471	validation_1-rmse:0.34636
# [20]	validation_0-rmse:0.40097	validation_1-rmse:0.34804
# [21]	validation_0-rmse:0.37751	validation_1-rmse:0.34413
# [22]	validation_0-rmse:0.36409	validation_1-rmse:0.33897
# [23]	validation_0-rmse:0.34471	validation_1-rmse:0.33439
# [24]	validation_0-rmse:0.33516	validation_1-rmse:0.33635
# [25]	validation_0-rmse:0.32497	validation_1-rmse:0.33544
# [26]	validation_0-rmse:0.31771	validation_1-rmse:0.33423
# [27]	validation_0-rmse:0.30409	validation_1-rmse:0.33409
# [28]	validation_0-rmse:0.29477	validation_1-rmse:0.33352
# [29]	validation_0-rmse:0.29395	validation_1-rmse:0.33465
# [30]	validation_0-rmse:0.29068	validation_1-rmse:0.33960
# [31]	validation_0-rmse:0.28870	validation_1-rmse:0.33711
# [32]	validation_0-rmse:0.28805	validation_1-rmse:0.33820
# [33]	validation_0-rmse:0.27635	validation_1-rmse:0.33804
# [34]	validation_0-rmse:0.26965	validation_1-rmse:0.33957
# [35]	validation_0-rmse:0.26313	validation_1-rmse:0.34572
# [36]	validation_0-rmse:0.26308	validation_1-rmse:0.34587
# [37]	validation_0-rmse:0.26274	validation_1-rmse:0.34676
# [38]	validation_0-rmse:0.25661	validation_1-rmse:0.34677
# [39]	validation_0-rmse:0.25589	validation_1-rmse:0.34872
# [40]	validation_0-rmse:0.25279	validation_1-rmse:0.34585
# [41]	validation_0-rmse:0.25104	validation_1-rmse:0.35110
# [42]	validation_0-rmse:0.25004	validation_1-rmse:0.35483
# [43]	validation_0-rmse:0.25016	validation_1-rmse:0.35434
# [44]	validation_0-rmse:0.24718	validation_1-rmse:0.35074
# [45]	validation_0-rmse:0.24664	validation_1-rmse:0.35258
# [46]	validation_0-rmse:0.24348	validation_1-rmse:0.35258
# [47]	validation_0-rmse:0.23784	validation_1-rmse:0.35582
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-2.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.878
# Uncertainty
# a0: -0.045+/-0.026
# a1: 0.823+/-0.032

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: %_cover: mean - 0.09, median - 0.087, CI - [0.066-0.112]
#
# SHAP-values for: contr_g_MAX: mean - 0.067, median - 0.066, CI - [0.052-0.081]
#
# SHAP-values for: g_MAX: mean - 0.02, median - 0.019, CI - [0.01-0.029]
#
# SHAP-values for: mf_chm_MAX: mean - 0.223, median - 0.225, CI - [0.196-0.248]
#
# SHAP-values for: mf_chm_MEAN: mean - 0.291, median - 0.29, CI - [0.261-0.323]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['mf_chm_MEAN', 'mf_chm_MAX', '%_cover', 'contr_g_MAX', 'g_MAX'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 59.73, median: 65.0,
#  pred. interval (P(0.025)-P(0.975)): 25.0-75.0,
#  conf. interval (p-value=0.95): 43.182-74.031
# ***
# Aggregate bias statistic:
#  mean: 0.011, median: 0.015,
#  pred. interval (P(0.025)-P(0.975)): -0.116-0.143,
#  conf. interval (p-value=0.95): -0.046-0.06
# ***
# Aggregate RMSE statistic:
#  mean: 0.298, median: 0.295, pred. interval (P(0.025)-P(0.975)): 0.194-0.406,
#  conf. interval (p-value=0.95): 0.241-0.355
# ***
# Aggregate MSE statistic:
#  mean: 0.092, median: 0.087, pred. interval (P(0.025)-P(0.975)): 0.038-0.165,
#  conf. interval (p-value=0.95): 0.059-0.126
# ***
# Aggregate R^2 statistic:
#  mean: 0.862, median: 0.872, pred. interval (P(0.025)-P(0.975)): 0.719-0.933,
#  conf. interval (p-value=0.95): 0.829-0.907
# ***
# Aggregate bias(%) statistic:
#  mean: 22.471, median: -4.971, pred. interval (P(0.025)-P(0.975)): -101.753-112.824,
#  conf. interval (p-value=0.95): -21.078-19.609
# ***
# Aggregate RMSE(%) statistic:
#  mean: -333.237, median: -91.422, pred. interval (P(0.025)-P(0.975)): -616.319-217.745,
#  conf. interval (p-value=0.95): -171.954--58.345
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -0.053, median: -0.042,
#  pred. interval (P(0.025)-P(0.975)): -0.267-0.089,
#  conf. interval (p-value=0.95): -0.133-0.026
# ***
# Aggregate RMSE statistic:
#  mean: 0.378, median: 0.348, pred. interval (P(0.025)-P(0.975)): 0.159-0.7,
#  conf. interval (p-value=0.95): 0.233-0.542
# ***
# Aggregate MSE statistic:
#  mean: 0.17, median: 0.121, pred. interval (P(0.025)-P(0.975)): 0.025-0.489,
#  conf. interval (p-value=0.95): 0.056-0.298
# ***
# Aggregate R^2 statistic:
#  mean: 0.631, median: 0.622, pred. interval (P(0.025)-P(0.975)): 0.36-0.867,
#  conf. interval (p-value=0.95): 0.492-0.776
# ***
# Aggregate bias(%) statistic:
#  mean: -4.745, median: -4.32, pred. interval (P(0.025)-P(0.975)): -20.974-10.067,
#  conf. interval (p-value=0.95): -12.518-3.052
# ***
# Aggregate RMSE(%) statistic:
#  mean: 38.404, median: 35.701, pred. interval (P(0.025)-P(0.975)): 18.673-61.497,
#  conf. interval (p-value=0.95): 25.709-52.86
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-3, -2, -1, 0, 1, 2])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 0.5, 1, 2, 3, 4])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.11107
# [1]	validation_0-rmse:1.02693
# [2]	validation_0-rmse:0.96994
# [3]	validation_0-rmse:0.90239
# [4]	validation_0-rmse:0.84541
# [5]	validation_0-rmse:0.78634
# [6]	validation_0-rmse:0.75242
# [7]	validation_0-rmse:0.72035
# [8]	validation_0-rmse:0.67655
# [9]	validation_0-rmse:0.64270
# [10]	validation_0-rmse:0.60854
# [11]	validation_0-rmse:0.57383
# [12]	validation_0-rmse:0.55069
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [13]	validation_0-rmse:0.52804
# [14]	validation_0-rmse:0.51011
# [15]	validation_0-rmse:0.48063
# [16]	validation_0-rmse:0.45667
# [17]	validation_0-rmse:0.43550
# [18]	validation_0-rmse:0.41895
# [19]	validation_0-rmse:0.39904
# [20]	validation_0-rmse:0.38433
# [21]	validation_0-rmse:0.37568
# [22]	validation_0-rmse:0.37297
# [23]	validation_0-rmse:0.36147
# [24]	validation_0-rmse:0.34818
# [25]	validation_0-rmse:0.33659
# [26]	validation_0-rmse:0.32681
# [27]	validation_0-rmse:0.32367
# [28]	validation_0-rmse:0.31930
# [29]	validation_0-rmse:0.31316
# [30]	validation_0-rmse:0.30549
# [31]	validation_0-rmse:0.29763
# [32]	validation_0-rmse:0.29381
# [33]	validation_0-rmse:0.28745
# [34]	validation_0-rmse:0.27871
# [35]	validation_0-rmse:0.27695
# [36]	validation_0-rmse:0.27445
# [37]	validation_0-rmse:0.27017
# [38]	validation_0-rmse:0.26782
# [39]	validation_0-rmse:0.26264
# [40]	validation_0-rmse:0.26022
# [41]	validation_0-rmse:0.25758
# [42]	validation_0-rmse:0.25416
# [43]	validation_0-rmse:0.25169
# [44]	validation_0-rmse:0.25142
# [45]	validation_0-rmse:0.24827
# [46]	validation_0-rmse:0.24552
# [47]	validation_0-rmse:0.24521
# [48]	validation_0-rmse:0.24496
# [49]	validation_0-rmse:0.24509
# [50]	validation_0-rmse:0.24484
# [51]	validation_0-rmse:0.24487
# [52]	validation_0-rmse:0.24500
# [53]	validation_0-rmse:0.24478
# [54]	validation_0-rmse:0.24322
# [55]	validation_0-rmse:0.24332
# [56]	validation_0-rmse:0.24335
# [57]	validation_0-rmse:0.24240
# [58]	validation_0-rmse:0.24243
# [59]	validation_0-rmse:0.24240
# [60]	validation_0-rmse:0.24245
# [61]	validation_0-rmse:0.24224
# [62]	validation_0-rmse:0.24225
# [63]	validation_0-rmse:0.24217
# [64]	validation_0-rmse:0.24214
# [65]	validation_0-rmse:0.24222
# [66]	validation_0-rmse:0.24216
# [67]	validation_0-rmse:0.24214
# [68]	validation_0-rmse:0.24214
# [69]	validation_0-rmse:0.24214
# [70]	validation_0-rmse:0.24217
# [71]	validation_0-rmse:0.24223
# [72]	validation_0-rmse:0.24218
# [73]	validation_0-rmse:0.23910
# [74]	validation_0-rmse:0.23907
# [75]	validation_0-rmse:0.23909
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 74

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  -1.64
# RMSE: 0.2
# Relative RMSE(%):  -72.899
# MSE: 0.1
# R square: 92.3%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-2.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.924
# Uncertainty
# a0: -0.031+/-0.023
# a1: 0.889+/-0.025

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/03_LN_MstemBark_CHM_with_RGB_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/03_LN_MstemBark_CHM_with_RGB_XGB_model.txt")
