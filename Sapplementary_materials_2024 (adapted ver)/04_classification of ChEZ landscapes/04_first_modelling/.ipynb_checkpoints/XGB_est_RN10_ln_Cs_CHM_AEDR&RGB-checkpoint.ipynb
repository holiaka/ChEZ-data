# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25  idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167   0.050549
# 1           3600       8.189          15100  ...   0.040919   0.048889
# 2           4360       8.380          14600  ...   0.042397   0.050463
# 3           3420       8.137          12700  ...   0.043719   0.052974
# 4           2200       7.696          12100  ...   0.040659   0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966   0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602   0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265   0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465   0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420   0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 163 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'contr_r_STD', 'corr_r_Q25'])

# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           1912            784      -0.73       2.58
# 1       8.189       9.622           2005            818       0.59       2.92
# 2       8.380       9.589           2001            818       0.78       2.88
# 3       8.137       9.449           2040            833       0.52       2.72
# 4       7.696       9.401           1758            717       0.22       2.83
#
#    AEDR_mean  contr_r_STD  corr_r_Q25
# 0       2.33   360.273487    0.488754
# 1       2.47   323.958625    0.501683
# 2       2.44   299.438354    0.540056
# 3       2.55   319.773395    0.480991
# 4       2.14   353.104284    0.505257

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   contr_r_STD    103 non-null    float64
#  8   corr_r_Q25     103 non-null    float64
# dtypes: float64(7), int64(2)
# memory usage: 7.4 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
# /tmp/ipykernel_9737/725619848.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3014.359223    1136.436893   -0.251845
# std       1.64946    1.472424    4988.505540    2019.773384    1.104536
# min       3.52600    6.075000     423.000000      98.000000   -3.030000
# 25%       6.31900    7.664000     635.500000     199.500000   -0.725000
# 50%       6.95700    8.472000    1145.000000     362.000000   -0.020000
# 75%       7.91350    9.421000    2423.500000     966.000000    0.520000
# max      11.36700   13.864000   25173.000000   10477.000000    1.650000
#
#         ln_Tag_Sr   AEDR_mean  contr_r_STD  corr_r_Q25
# count  103.000000  103.000000   103.000000  103.000000
# mean     2.464854    3.570291   327.115078    0.393571
# std      0.904757    6.089170   167.617957    0.151801
# min      0.390000    0.480000     0.091058    0.033797
# 25%      1.805000    0.710000   283.887328    0.407228
# 50%      2.600000    1.290000   353.034542    0.449670
# 75%      3.160000    2.960000   448.017711    0.476635
# max      4.660000   36.590000   652.546648    0.555648

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['contr_r_STD', 'corr_r_Q25', 'AEDR_mean'])
y = pd.DataFrame(select, columns= ['ln_Cs_wood'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    contr_r_STD  corr_r_Q25  AEDR_mean
# 0   360.273487    0.488754       2.33
# 1   323.958625    0.501683       2.47
# 2   299.438354    0.540056       2.44
# 3   319.773395    0.480991       2.55
# 4   353.104284    0.505257       2.14

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Cs_wood
# 0       6.824
# 1       8.189
# 2       8.380
# 3       8.137
# 4       7.696

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.32921266048328046, 0.7923317296930705, 0.5951401054146386]
#     Mean: 0.572
#     Std: 0.190
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.96786753 1.07519815 1.15519795]
#     Mean: 1.066
#     Std: 0.077
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.8431706768580844, 0.8517309890634874, 0.8935579322366152]
#     Mean: 0.863
#     Std: 0.022
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.015 (std: 0.712)
# Parameters: {'colsample_bytree': 0.9212602280924751, 'gamma': 0.2075762813132193, 'learning_rate': 0.047829301314752076, 'max_depth': 2, 'n_estimators': 125, 'subsample': 0.5305811756183811}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.23384213, 0.84451962, 0.17675996, ..., 0.38616729, 0.54353757,
#        0.15629921]), 'std_fit_time': array([0.0624123 , 0.1972631 , 0.05945465, ..., 0.03225135, 0.00750373,
#        0.00394658]), 'mean_score_time': array([0.00776129, 0.0082324 , 0.00616965, ..., 0.00643401, 0.00645204,
#        0.00654063]), 'std_score_time': array([1.94965872e-03, 2.06866445e-03, 1.16617310e-04, ...,
#        1.21875082e-04, 4.90142212e-05, 9.76916571e-05]), 'param_colsample_bytree': masked_array(data=[0.9243072309556185, 0.9186539172921058,
#                    0.4297880446535389, ..., 0.5267301876027524,
#                    0.43576208729987453, 0.7678958023778248],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.3066584214587804, 0.15707776213691116,
#                    0.3283649728748867, ..., 0.3992905323650006,
#                    0.11023724807225999, 0.09744972579741984],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.12523438456524175, 0.04540222730518652,
#                    0.06721503130679585, ..., 0.20161047021847328,
#                    0.3047038155243363, 0.27078953628333663],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[4, 3, 3, ..., 4, 4, 4],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[55, 174, 53, ..., 132, 194, 53],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.3276768541739684, 0.4233813768119786,
#                    0.6977503362425292, ..., 0.9386833597413731,
#                    0.9008096643643837, 0.31581775277119256],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.9243072309556185, 'gamma': 0.3066584214587804, 'learning_rate': 0.12523438456524175, 'max_depth': 4, 'n_estimators': 55, 'subsample': 0.3276768541739684}, {'colsample_bytree': 0.9186539172921058, 'gamma': 0.15707776213691116, 'learning_rate': 0.04540222730518652, 'max_depth': 3, 'n_estimators': 174, 'subsample': 0.4233813768119786}, {'colsample_bytree': 0.4297880446535389, 'gamma': 0.3283649728748867, 'learning_rate': 0.06721503130679585, 'max_depth': 3, 'n_estimators': 53, 'subsample': 0.6977503362425292}, {'colsample_bytree': 0.1593132318250139, 'gamma': 0.20515412649850173, 'learning_rate': 0.2792690333429282, 'max_depth': 3, 'n_estimators': 52, 'subsample': 0.6726198602489463}, {'colsample_bytree': 0.7643411962313608, 'gamma': 0.26291206145379625, 'learning_rate': 0.2403220217301943, 'max_depth': 3, 'n_estimators': 182, 'subsample': 0.7830857269279291}, {'colsample_bytree': 0.49820288919150996, 'gamma': 0.15558885261900984, 'learning_rate': 0.2545401660848387, 'max_depth': 2, 'n_estimators': 129, 'subsample': 0.36698053721164986}, {'colsample_bytree': 0.5446956770197026, 'gamma': 0.11617436966571332, 'learning_rate': 0.187243471000252, 'max_depth': 3, 'n_estimators': 116, 'subsample': 0.5138143690376226}, {'colsample_bytree': 0.8648642589864639, 'gamma': 0.33527268495200724, 'learning_rate': 0.09680272748278622, 'max_depth': 4, 'n_estimators': 140, 'subsample': 0.48116285612396603}, {'colsample_bytree': 0.4541209913104489, 'gamma': 0.08906618923646525, 'learning_rate': 0.014641967167854066, 'max_depth': 4, 'n_estimators': 128, 'subsample': 0.7172377847993269}, {'colsample_bytree': 0.9359283859860559, 'gamma': 0.4378640263458827, 'learning_rate': 0.04856741170915936, 'max_depth': 4, 'n_estimators': 81, 'subsample': 0.6060884692482646}, {'colsample_bytree': 0.8966893463744943, 'gamma': 0.17280382736189498, 'learning_rate': 0.10811569239184654, 'max_depth': 4, 'n_estimators': 188, 'subsample': 0.6913711488797384}, {'colsample_bytree': 0.5284813419394111, 'gamma': 0.1384606118462624, 'learning_rate': 0.26441510766495446, 'max_depth': 4, 'n_estimators': 152, 'subsample': 0.30040148167140684}, {'colsample_bytree': 0.4042357842296881, 'gamma': 0.18625178623033795, 'learning_rate': 0.05390921496499379, 'max_depth': 3, 'n_estimators': 146, 'subsample': 0.5323146026205329}, {'colsample_bytree': 0.6815829828670275, 'gamma': 0.3974190603913268, 'learning_rate': 0.28044031219883336, 'max_depth': 4, 'n_estimators': 69, 'subsample': 0.9223511852999964}, {'colsample_bytree': 0.19243116489969952, 'gamma': 0.39571608627693805, 'learning_rate': 0.1005597302867507, 'max_depth': 2, 'n_estimators': 146, 'subsample': 0.43758436792939653}, {'colsample_bytree': 0.37360294688196094, 'gamma': 0.33687741186265613, 'learning_rate': 0.24021580906356588, 'max_depth': 4, 'n_estimators': 162, 'subsample': 0.7787457670334159}, {'colsample_bytree': 0.1941864157343226, 'gamma': 0.03175751968273982, 'learning_rate': 0.2884303539241153, 'max_depth': 4, 'n_estimators': 100, 'subsample': 0.4102321954358047}, {'colsample_bytree': 0.592340504487825, 'gamma': 0.0778358544176544, 'learning_rate': 0.10831387644084607, 'max_depth': 4, 'n_estimators': 66, 'subsample': 0.8139783929269524}, {'colsample_bytree': 0.26445964598933014, 'gamma': 0.0263081120081185, 'learning_rate': 0.12519785782085224, 'max_depth': 2, 'n_estimators': 181, 'subsample': 0.3506867183696593}, {'colsample_bytree': 0.541854204265641, 'gamma': 0.005046024037489383, 'learning_rate': 0.07057490839051951, 'max_depth': 2, 'n_estimators': 143, 'subsample': 0.3815815754173164}, {'colsample_bytree': 0.2403817823596615, 'gamma': 0.4081661742807477, 'learning_rate': 0.18721832596106178, 'max_depth': 4, 'n_estimators': 115, 'subsample': 0.6057292104907348}, {'colsample_bytree': 0.09001579606212987, 'gamma': 0.4488396563706393, 'learning_rate': 0.23283705837057597, 'max_depth': 3, 'n_estimators': 89, 'subsample': 0.4807435382837438}, {'colsample_bytr ...
#        -3.88151379, -2.47376091]), 'split1_test_score': array([-0.12192588,  0.23205026,  0.01464761, ...,  0.00610682,
#        -0.13228971, -0.66374771]), 'split2_test_score': array([-0.46724102, -0.28033103, -0.08446287, ..., -0.07840296,
#        -0.20967318, -0.21780231]), 'split3_test_score': array([0.43730366, 0.5498956 , 0.16008457, ..., 0.4766433 , 0.30343117,
#        0.43357193]), 'split4_test_score': array([0.56940103, 0.66638947, 0.63280846, ..., 0.56982441, 0.61837722,
#        0.58684611]), 'mean_test_score': array([-0.20719228, -0.03797247, -0.51355892, ..., -0.21090423,
#        -0.66033366, -0.46697858]), 'std_test_score': array([0.72755052, 0.73695118, 1.41028715, ..., 0.94353212, 1.63840599,
#        1.09995636]), 'rank_test_score': array([ 927,   27, 2608, ...,  957, 2793, 2457], dtype=int32), 'split0_train_score': array([0.89897542, 0.92249593, 0.8065235 , ..., 0.95871534, 0.98858472,
#        0.96315629]), 'split1_train_score': array([0.88750375, 0.90963088, 0.78298493, ..., 0.95017775, 0.98673933,
#        0.95319727]), 'split2_train_score': array([0.91866326, 0.9365177 , 0.83606312, ..., 0.95505721, 0.98926135,
#        0.9729885 ]), 'split3_train_score': array([0.8279383 , 0.87595932, 0.7076687 , ..., 0.92723208, 0.9803642 ,
#        0.92207519]), 'split4_train_score': array([0.86292512, 0.90708959, 0.78018362, ..., 0.94341577, 0.98511216,
#        0.94186309]), 'mean_train_score': array([0.87920117, 0.91033869, 0.78268477, ..., 0.94691963, 0.98601235,
#        0.95065607]), 'std_train_score': array([0.03133688, 0.02013026, 0.04254713, ..., 0.01109821, 0.00317533,
#        0.01763879])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.9212602280924751
# Gamma: 0.2075762813132193
# Learning_rate: 0.047829301314752076
# Max_depth: 2
# N_estimators: 125
# Subsample: 0.5305811756183811

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:6.53923	validation_1-rmse:6.11605
# [1]	validation_0-rmse:6.25759	validation_1-rmse:5.84624
# [2]	validation_0-rmse:5.98052	validation_1-rmse:5.58514
# [3]	validation_0-rmse:5.73115	validation_1-rmse:5.33037
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:5.47567	validation_1-rmse:5.08000
# [5]	validation_0-rmse:5.23060	validation_1-rmse:4.84384
# [6]	validation_0-rmse:4.99960	validation_1-rmse:4.62308
# [7]	validation_0-rmse:4.79067	validation_1-rmse:4.42743
# [8]	validation_0-rmse:4.58419	validation_1-rmse:4.22934
# [9]	validation_0-rmse:4.38687	validation_1-rmse:4.03828
# [10]	validation_0-rmse:4.20219	validation_1-rmse:3.87129
# [11]	validation_0-rmse:4.03544	validation_1-rmse:3.71224
# [12]	validation_0-rmse:3.86458	validation_1-rmse:3.54697
# [13]	validation_0-rmse:3.70445	validation_1-rmse:3.38917
# [14]	validation_0-rmse:3.55118	validation_1-rmse:3.24107
# [15]	validation_0-rmse:3.40373	validation_1-rmse:3.09369
# [16]	validation_0-rmse:3.26686	validation_1-rmse:2.95395
# [17]	validation_0-rmse:3.14075	validation_1-rmse:2.83275
# [18]	validation_0-rmse:3.01584	validation_1-rmse:2.71498
# [19]	validation_0-rmse:2.89699	validation_1-rmse:2.60057
# [20]	validation_0-rmse:2.77889	validation_1-rmse:2.49318
# [21]	validation_0-rmse:2.66386	validation_1-rmse:2.38392
# [22]	validation_0-rmse:2.55416	validation_1-rmse:2.29257
# [23]	validation_0-rmse:2.45738	validation_1-rmse:2.20949
# [24]	validation_0-rmse:2.36301	validation_1-rmse:2.11369
# [25]	validation_0-rmse:2.28107	validation_1-rmse:2.04156
# [26]	validation_0-rmse:2.19778	validation_1-rmse:1.96874
# [27]	validation_0-rmse:2.12200	validation_1-rmse:1.89979
# [28]	validation_0-rmse:2.04675	validation_1-rmse:1.83409
# [29]	validation_0-rmse:1.97256	validation_1-rmse:1.76752
# [30]	validation_0-rmse:1.90419	validation_1-rmse:1.71080
# [31]	validation_0-rmse:1.83890	validation_1-rmse:1.65155
# [32]	validation_0-rmse:1.78205	validation_1-rmse:1.60370
# [33]	validation_0-rmse:1.72632	validation_1-rmse:1.56318
# [34]	validation_0-rmse:1.67629	validation_1-rmse:1.52610
# [35]	validation_0-rmse:1.62992	validation_1-rmse:1.48507
# [36]	validation_0-rmse:1.57933	validation_1-rmse:1.44703
# [37]	validation_0-rmse:1.52915	validation_1-rmse:1.40375
# [38]	validation_0-rmse:1.47824	validation_1-rmse:1.37182
# [39]	validation_0-rmse:1.43058	validation_1-rmse:1.34086
# [40]	validation_0-rmse:1.38884	validation_1-rmse:1.31555
# [41]	validation_0-rmse:1.34524	validation_1-rmse:1.28312
# [42]	validation_0-rmse:1.30860	validation_1-rmse:1.25379
# [43]	validation_0-rmse:1.27130	validation_1-rmse:1.22181
# [44]	validation_0-rmse:1.23641	validation_1-rmse:1.19477
# [45]	validation_0-rmse:1.20971	validation_1-rmse:1.17796
# [46]	validation_0-rmse:1.18064	validation_1-rmse:1.15828
# [47]	validation_0-rmse:1.15120	validation_1-rmse:1.13682
# [48]	validation_0-rmse:1.12557	validation_1-rmse:1.12312
# [49]	validation_0-rmse:1.10731	validation_1-rmse:1.10765
# [50]	validation_0-rmse:1.08627	validation_1-rmse:1.08919
# [51]	validation_0-rmse:1.06407	validation_1-rmse:1.07943
# [52]	validation_0-rmse:1.04725	validation_1-rmse:1.06902
# [53]	validation_0-rmse:1.02904	validation_1-rmse:1.06756
# [54]	validation_0-rmse:1.00898	validation_1-rmse:1.05487
# [55]	validation_0-rmse:0.99567	validation_1-rmse:1.04478
# [56]	validation_0-rmse:0.97739	validation_1-rmse:1.04341
# [57]	validation_0-rmse:0.96180	validation_1-rmse:1.03746
# [58]	validation_0-rmse:0.94832	validation_1-rmse:1.03147
# [59]	validation_0-rmse:0.93699	validation_1-rmse:1.01926
# [60]	validation_0-rmse:0.92280	validation_1-rmse:1.01333
# [61]	validation_0-rmse:0.91150	validation_1-rmse:1.01495
# [62]	validation_0-rmse:0.90058	validation_1-rmse:1.01094
# [63]	validation_0-rmse:0.88811	validation_1-rmse:1.01136
# [64]	validation_0-rmse:0.88103	validation_1-rmse:1.00947
# [65]	validation_0-rmse:0.87166	validation_1-rmse:1.00904
# [66]	validation_0-rmse:0.85913	validation_1-rmse:1.00737
# [67]	validation_0-rmse:0.84956	validation_1-rmse:1.00316
# [68]	validation_0-rmse:0.84536	validation_1-rmse:1.00712
# [69]	validation_0-rmse:0.83787	validation_1-rmse:0.99941
# [70]	validation_0-rmse:0.82610	validation_1-rmse:0.99637
# [71]	validation_0-rmse:0.81915	validation_1-rmse:0.99703
# [72]	validation_0-rmse:0.81286	validation_1-rmse:0.99484
# [73]	validation_0-rmse:0.80883	validation_1-rmse:0.99852
# [74]	validation_0-rmse:0.80063	validation_1-rmse:0.99547
# [75]	validation_0-rmse:0.79696	validation_1-rmse:1.00022
# [76]	validation_0-rmse:0.79602	validation_1-rmse:1.00621
# [77]	validation_0-rmse:0.78847	validation_1-rmse:1.00010
# [78]	validation_0-rmse:0.78486	validation_1-rmse:0.99953
# [79]	validation_0-rmse:0.77987	validation_1-rmse:0.99228
# [80]	validation_0-rmse:0.77700	validation_1-rmse:0.99319
# [81]	validation_0-rmse:0.77401	validation_1-rmse:0.99063
# [82]	validation_0-rmse:0.76810	validation_1-rmse:0.98886
# [83]	validation_0-rmse:0.76190	validation_1-rmse:0.98691
# [84]	validation_0-rmse:0.75878	validation_1-rmse:0.98983
# [85]	validation_0-rmse:0.75483	validation_1-rmse:0.99071
# [86]	validation_0-rmse:0.75074	validation_1-rmse:0.99769
# [87]	validation_0-rmse:0.74600	validation_1-rmse:0.99756
# [88]	validation_0-rmse:0.74239	validation_1-rmse:0.99664
# [89]	validation_0-rmse:0.74050	validation_1-rmse:0.99818
# [90]	validation_0-rmse:0.73894	validation_1-rmse:0.99217
# [91]	validation_0-rmse:0.73722	validation_1-rmse:0.99402
# [92]	validation_0-rmse:0.73383	validation_1-rmse:0.99944
# [93]	validation_0-rmse:0.73189	validation_1-rmse:0.99940
# [94]	validation_0-rmse:0.72735	validation_1-rmse:0.99939
# [95]	validation_0-rmse:0.72209	validation_1-rmse:0.99331
# [96]	validation_0-rmse:0.71913	validation_1-rmse:1.00191
# [97]	validation_0-rmse:0.71842	validation_1-rmse:1.00643
# [98]	validation_0-rmse:0.71688	validation_1-rmse:1.00492
# [99]	validation_0-rmse:0.71484	validation_1-rmse:1.00562
# [100]	validation_0-rmse:0.71335	validation_1-rmse:1.00533
# [101]	validation_0-rmse:0.71158	validation_1-rmse:1.00756
# [102]	validation_0-rmse:0.70869	validation_1-rmse:1.00590
# [103]	validation_0-rmse:0.70716	validation_1-rmse:1.00341
# [0]	validation_0-rmse:6.56579	validation_1-rmse:5.95758
# [1]	validation_0-rmse:6.27056	validation_1-rmse:5.66793
# [2]	validation_0-rmse:5.99041	validation_1-rmse:5.39340
# [3]	validation_0-rmse:5.73226	validation_1-rmse:5.16497
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:5.48040	validation_1-rmse:4.94072
# [5]	validation_0-rmse:5.23623	validation_1-rmse:4.69962
# [6]	validation_0-rmse:5.00679	validation_1-rmse:4.47433
# [7]	validation_0-rmse:4.79240	validation_1-rmse:4.26320
# [8]	validation_0-rmse:4.58996	validation_1-rmse:4.08456
# [9]	validation_0-rmse:4.39837	validation_1-rmse:3.90125
# [10]	validation_0-rmse:4.20949	validation_1-rmse:3.71906
# [11]	validation_0-rmse:4.02409	validation_1-rmse:3.53602
# [12]	validation_0-rmse:3.85306	validation_1-rmse:3.38302
# [13]	validation_0-rmse:3.69790	validation_1-rmse:3.24259
# [14]	validation_0-rmse:3.54676	validation_1-rmse:3.10119
# [15]	validation_0-rmse:3.40580	validation_1-rmse:2.97602
# [16]	validation_0-rmse:3.27192	validation_1-rmse:2.83981
# [17]	validation_0-rmse:3.12922	validation_1-rmse:2.71136
# [18]	validation_0-rmse:3.00944	validation_1-rmse:2.61041
# [19]	validation_0-rmse:2.88672	validation_1-rmse:2.48793
# [20]	validation_0-rmse:2.76471	validation_1-rmse:2.38561
# [21]	validation_0-rmse:2.65068	validation_1-rmse:2.28060
# [22]	validation_0-rmse:2.54772	validation_1-rmse:2.19632
# [23]	validation_0-rmse:2.45380	validation_1-rmse:2.10932
# [24]	validation_0-rmse:2.35513	validation_1-rmse:2.02016
# [25]	validation_0-rmse:2.26987	validation_1-rmse:1.95643
# [26]	validation_0-rmse:2.18756	validation_1-rmse:1.88849
# [27]	validation_0-rmse:2.11512	validation_1-rmse:1.83923
# [28]	validation_0-rmse:2.03762	validation_1-rmse:1.78011
# [29]	validation_0-rmse:1.96315	validation_1-rmse:1.71796
# [30]	validation_0-rmse:1.89523	validation_1-rmse:1.65737
# [31]	validation_0-rmse:1.83347	validation_1-rmse:1.60570
# [32]	validation_0-rmse:1.77598	validation_1-rmse:1.55716
# [33]	validation_0-rmse:1.71331	validation_1-rmse:1.51112
# [34]	validation_0-rmse:1.65805	validation_1-rmse:1.47070
# [35]	validation_0-rmse:1.60322	validation_1-rmse:1.43958
# [36]	validation_0-rmse:1.55753	validation_1-rmse:1.40622
# [37]	validation_0-rmse:1.50997	validation_1-rmse:1.37786
# [38]	validation_0-rmse:1.46011	validation_1-rmse:1.34698
# [39]	validation_0-rmse:1.41377	validation_1-rmse:1.31157
# [40]	validation_0-rmse:1.37309	validation_1-rmse:1.28429
# [41]	validation_0-rmse:1.33271	validation_1-rmse:1.26084
# [42]	validation_0-rmse:1.29128	validation_1-rmse:1.24556
# [43]	validation_0-rmse:1.26217	validation_1-rmse:1.23714
# [44]	validation_0-rmse:1.22753	validation_1-rmse:1.21552
# [45]	validation_0-rmse:1.19118	validation_1-rmse:1.19526
# [46]	validation_0-rmse:1.15960	validation_1-rmse:1.17726
# [47]	validation_0-rmse:1.13789	validation_1-rmse:1.16259
# [48]	validation_0-rmse:1.10981	validation_1-rmse:1.15000
# [49]	validation_0-rmse:1.08810	validation_1-rmse:1.13788
# [50]	validation_0-rmse:1.06760	validation_1-rmse:1.12628
# [51]	validation_0-rmse:1.04482	validation_1-rmse:1.11393
# [52]	validation_0-rmse:1.02402	validation_1-rmse:1.10792
# [53]	validation_0-rmse:1.00303	validation_1-rmse:1.10498
# [54]	validation_0-rmse:0.98265	validation_1-rmse:1.10040
# [55]	validation_0-rmse:0.96264	validation_1-rmse:1.09535
# [56]	validation_0-rmse:0.94542	validation_1-rmse:1.09342
# [57]	validation_0-rmse:0.93138	validation_1-rmse:1.08992
# [58]	validation_0-rmse:0.91946	validation_1-rmse:1.08462
# [59]	validation_0-rmse:0.90881	validation_1-rmse:1.08561
# [60]	validation_0-rmse:0.89606	validation_1-rmse:1.08808
# [61]	validation_0-rmse:0.88188	validation_1-rmse:1.08062
# [62]	validation_0-rmse:0.87225	validation_1-rmse:1.08007
# [63]	validation_0-rmse:0.86200	validation_1-rmse:1.07739
# [64]	validation_0-rmse:0.85041	validation_1-rmse:1.07432
# [65]	validation_0-rmse:0.84386	validation_1-rmse:1.07351
# [66]	validation_0-rmse:0.83381	validation_1-rmse:1.07069
# [67]	validation_0-rmse:0.82533	validation_1-rmse:1.07158
# [68]	validation_0-rmse:0.81668	validation_1-rmse:1.07414
# [69]	validation_0-rmse:0.81081	validation_1-rmse:1.07490
# [70]	validation_0-rmse:0.80336	validation_1-rmse:1.07233
# [71]	validation_0-rmse:0.79591	validation_1-rmse:1.06728
# [72]	validation_0-rmse:0.78982	validation_1-rmse:1.06985
# [73]	validation_0-rmse:0.78350	validation_1-rmse:1.06957
# [74]	validation_0-rmse:0.77864	validation_1-rmse:1.07046
# [75]	validation_0-rmse:0.76984	validation_1-rmse:1.06611
# [76]	validation_0-rmse:0.76341	validation_1-rmse:1.07067
# [77]	validation_0-rmse:0.75963	validation_1-rmse:1.06837
# [78]	validation_0-rmse:0.75743	validation_1-rmse:1.06756
# [79]	validation_0-rmse:0.75212	validation_1-rmse:1.07171
# [80]	validation_0-rmse:0.74929	validation_1-rmse:1.07025
# [81]	validation_0-rmse:0.74583	validation_1-rmse:1.07247
# [82]	validation_0-rmse:0.73921	validation_1-rmse:1.06063
# [83]	validation_0-rmse:0.73420	validation_1-rmse:1.05594
# [84]	validation_0-rmse:0.72909	validation_1-rmse:1.05925
# [85]	validation_0-rmse:0.72601	validation_1-rmse:1.06671
# [86]	validation_0-rmse:0.72324	validation_1-rmse:1.06598
# [87]	validation_0-rmse:0.72056	validation_1-rmse:1.06951
# [88]	validation_0-rmse:0.71468	validation_1-rmse:1.06329
# [89]	validation_0-rmse:0.70778	validation_1-rmse:1.05481
# [90]	validation_0-rmse:0.70626	validation_1-rmse:1.05465
# [91]	validation_0-rmse:0.70364	validation_1-rmse:1.05880
# [92]	validation_0-rmse:0.70038	validation_1-rmse:1.05714
# [93]	validation_0-rmse:0.69868	validation_1-rmse:1.05541
# [94]	validation_0-rmse:0.69637	validation_1-rmse:1.05858
# [95]	validation_0-rmse:0.69285	validation_1-rmse:1.06076
# [96]	validation_0-rmse:0.68963	validation_1-rmse:1.06434
# [97]	validation_0-rmse:0.68822	validation_1-rmse:1.06050
# [98]	validation_0-rmse:0.68708	validation_1-rmse:1.06060
# [99]	validation_0-rmse:0.68492	validation_1-rmse:1.06051
# [100]	validation_0-rmse:0.68032	validation_1-rmse:1.06093
# [101]	validation_0-rmse:0.67710	validation_1-rmse:1.06524
# [102]	validation_0-rmse:0.67530	validation_1-rmse:1.06827
# [103]	validation_0-rmse:0.67117	validation_1-rmse:1.06603
# [104]	validation_0-rmse:0.66671	validation_1-rmse:1.06402
# [105]	validation_0-rmse:0.66582	validation_1-rmse:1.06246
# [106]	validation_0-rmse:0.66400	validation_1-rmse:1.06283
# [107]	validation_0-rmse:0.66306	validation_1-rmse:1.06276
# [108]	validation_0-rmse:0.66165	validation_1-rmse:1.06638
# [109]	validation_0-rmse:0.65966	validation_1-rmse:1.06506
# [0]	validation_0-rmse:6.38280	validation_1-rmse:6.74184
# [1]	validation_0-rmse:6.10339	validation_1-rmse:6.46762
# [2]	validation_0-rmse:5.82870	validation_1-rmse:6.16971
# [3]	validation_0-rmse:5.57508	validation_1-rmse:5.91492
# [4]	validation_0-rmse:5.33386	validation_1-rmse:5.67630
# [5]	validation_0-rmse:5.10761	validation_1-rmse:5.44871
# [6]	validation_0-rmse:4.88588	validation_1-rmse:5.23186
# [7]	validation_0-rmse:4.68222	validation_1-rmse:5.04696
# [8]	validation_0-rmse:4.47927	validation_1-rmse:4.86095
# [9]	validation_0-rmse:4.29130	validation_1-rmse:4.65388
# [10]	validation_0-rmse:4.10770	validation_1-rmse:4.48272
# [11]	validation_0-rmse:3.94695	validation_1-rmse:4.32792
# [12]	validation_0-rmse:3.77743	validation_1-rmse:4.15396
# [13]	validation_0-rmse:3.61345	validation_1-rmse:3.97467
# [14]	validation_0-rmse:3.46902	validation_1-rmse:3.81728
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:3.32971	validation_1-rmse:3.68446
# [16]	validation_0-rmse:3.19572	validation_1-rmse:3.55326
# [17]	validation_0-rmse:3.07183	validation_1-rmse:3.43233
# [18]	validation_0-rmse:2.94700	validation_1-rmse:3.29410
# [19]	validation_0-rmse:2.83662	validation_1-rmse:3.17913
# [20]	validation_0-rmse:2.72447	validation_1-rmse:3.06483
# [21]	validation_0-rmse:2.62450	validation_1-rmse:2.95790
# [22]	validation_0-rmse:2.52093	validation_1-rmse:2.85323
# [23]	validation_0-rmse:2.41885	validation_1-rmse:2.75216
# [24]	validation_0-rmse:2.32028	validation_1-rmse:2.66135
# [25]	validation_0-rmse:2.23044	validation_1-rmse:2.57563
# [26]	validation_0-rmse:2.14798	validation_1-rmse:2.49962
# [27]	validation_0-rmse:2.06197	validation_1-rmse:2.41348
# [28]	validation_0-rmse:1.98570	validation_1-rmse:2.33727
# [29]	validation_0-rmse:1.91022	validation_1-rmse:2.26414
# [30]	validation_0-rmse:1.84454	validation_1-rmse:2.20730
# [31]	validation_0-rmse:1.77585	validation_1-rmse:2.13850
# [32]	validation_0-rmse:1.71219	validation_1-rmse:2.08290
# [33]	validation_0-rmse:1.64930	validation_1-rmse:2.02177
# [34]	validation_0-rmse:1.59908	validation_1-rmse:1.96725
# [35]	validation_0-rmse:1.54709	validation_1-rmse:1.91795
# [36]	validation_0-rmse:1.49480	validation_1-rmse:1.86645
# [37]	validation_0-rmse:1.44746	validation_1-rmse:1.83088
# [38]	validation_0-rmse:1.40329	validation_1-rmse:1.79287
# [39]	validation_0-rmse:1.36054	validation_1-rmse:1.75207
# [40]	validation_0-rmse:1.31872	validation_1-rmse:1.70783
# [41]	validation_0-rmse:1.28303	validation_1-rmse:1.67373
# [42]	validation_0-rmse:1.24783	validation_1-rmse:1.64550
# [43]	validation_0-rmse:1.20829	validation_1-rmse:1.61692
# [44]	validation_0-rmse:1.17383	validation_1-rmse:1.59422
# [45]	validation_0-rmse:1.14370	validation_1-rmse:1.56558
# [46]	validation_0-rmse:1.11574	validation_1-rmse:1.54018
# [47]	validation_0-rmse:1.08587	validation_1-rmse:1.52406
# [48]	validation_0-rmse:1.06002	validation_1-rmse:1.50105
# [49]	validation_0-rmse:1.03512	validation_1-rmse:1.47888
# [50]	validation_0-rmse:1.01218	validation_1-rmse:1.45537
# [51]	validation_0-rmse:0.99401	validation_1-rmse:1.44272
# [52]	validation_0-rmse:0.97619	validation_1-rmse:1.42725
# [53]	validation_0-rmse:0.95795	validation_1-rmse:1.40968
# [54]	validation_0-rmse:0.94577	validation_1-rmse:1.40045
# [55]	validation_0-rmse:0.93174	validation_1-rmse:1.39070
# [56]	validation_0-rmse:0.91468	validation_1-rmse:1.37506
# [57]	validation_0-rmse:0.89931	validation_1-rmse:1.36207
# [58]	validation_0-rmse:0.88568	validation_1-rmse:1.35118
# [59]	validation_0-rmse:0.87080	validation_1-rmse:1.34580
# [60]	validation_0-rmse:0.85805	validation_1-rmse:1.33406
# [61]	validation_0-rmse:0.84824	validation_1-rmse:1.33163
# [62]	validation_0-rmse:0.83533	validation_1-rmse:1.31934
# [63]	validation_0-rmse:0.82283	validation_1-rmse:1.30591
# [64]	validation_0-rmse:0.81417	validation_1-rmse:1.29856
# [65]	validation_0-rmse:0.80872	validation_1-rmse:1.29034
# [66]	validation_0-rmse:0.79974	validation_1-rmse:1.28274
# [67]	validation_0-rmse:0.78944	validation_1-rmse:1.27295
# [68]	validation_0-rmse:0.78012	validation_1-rmse:1.26336
# [69]	validation_0-rmse:0.77260	validation_1-rmse:1.25245
# [70]	validation_0-rmse:0.76748	validation_1-rmse:1.24825
# [71]	validation_0-rmse:0.76073	validation_1-rmse:1.23973
# [72]	validation_0-rmse:0.75545	validation_1-rmse:1.23780
# [73]	validation_0-rmse:0.75226	validation_1-rmse:1.23160
# [74]	validation_0-rmse:0.74696	validation_1-rmse:1.23735
# [75]	validation_0-rmse:0.74254	validation_1-rmse:1.23370
# [76]	validation_0-rmse:0.73752	validation_1-rmse:1.22607
# [77]	validation_0-rmse:0.73151	validation_1-rmse:1.21649
# [78]	validation_0-rmse:0.72472	validation_1-rmse:1.21622
# [79]	validation_0-rmse:0.72028	validation_1-rmse:1.21498
# [80]	validation_0-rmse:0.71550	validation_1-rmse:1.21326
# [81]	validation_0-rmse:0.71305	validation_1-rmse:1.21018
# [82]	validation_0-rmse:0.70960	validation_1-rmse:1.21341
# [83]	validation_0-rmse:0.70746	validation_1-rmse:1.21580
# [84]	validation_0-rmse:0.70297	validation_1-rmse:1.21299
# [85]	validation_0-rmse:0.69927	validation_1-rmse:1.20997
# [86]	validation_0-rmse:0.69712	validation_1-rmse:1.20321
# [87]	validation_0-rmse:0.69409	validation_1-rmse:1.20356
# [88]	validation_0-rmse:0.68690	validation_1-rmse:1.19199
# [89]	validation_0-rmse:0.68371	validation_1-rmse:1.18886
# [90]	validation_0-rmse:0.68105	validation_1-rmse:1.19321
# [91]	validation_0-rmse:0.67660	validation_1-rmse:1.18990
# [92]	validation_0-rmse:0.67370	validation_1-rmse:1.18666
# [93]	validation_0-rmse:0.67110	validation_1-rmse:1.18108
# [94]	validation_0-rmse:0.66920	validation_1-rmse:1.18155
# [95]	validation_0-rmse:0.66818	validation_1-rmse:1.18837
# [96]	validation_0-rmse:0.66554	validation_1-rmse:1.18841
# [97]	validation_0-rmse:0.66185	validation_1-rmse:1.18300
# [98]	validation_0-rmse:0.66051	validation_1-rmse:1.18682
# [99]	validation_0-rmse:0.65701	validation_1-rmse:1.18084
# [100]	validation_0-rmse:0.65516	validation_1-rmse:1.18030
# [101]	validation_0-rmse:0.65307	validation_1-rmse:1.18240
# [102]	validation_0-rmse:0.65183	validation_1-rmse:1.17739
# [103]	validation_0-rmse:0.64996	validation_1-rmse:1.17279
# [104]	validation_0-rmse:0.64754	validation_1-rmse:1.16487
# [105]	validation_0-rmse:0.64573	validation_1-rmse:1.16422
# [106]	validation_0-rmse:0.64294	validation_1-rmse:1.16519
# [107]	validation_0-rmse:0.64111	validation_1-rmse:1.16417
# [108]	validation_0-rmse:0.63762	validation_1-rmse:1.17251
# [109]	validation_0-rmse:0.63517	validation_1-rmse:1.17154
# [110]	validation_0-rmse:0.63379	validation_1-rmse:1.16929
# [111]	validation_0-rmse:0.63025	validation_1-rmse:1.16323
# [112]	validation_0-rmse:0.62916	validation_1-rmse:1.16374
# [113]	validation_0-rmse:0.62646	validation_1-rmse:1.16720
# [114]	validation_0-rmse:0.62375	validation_1-rmse:1.16773
# [115]	validation_0-rmse:0.62253	validation_1-rmse:1.16646
# [116]	validation_0-rmse:0.62109	validation_1-rmse:1.16559
# [117]	validation_0-rmse:0.61873	validation_1-rmse:1.16388
# [118]	validation_0-rmse:0.61842	validation_1-rmse:1.16393
# [119]	validation_0-rmse:0.61600	validation_1-rmse:1.16832
# [120]	validation_0-rmse:0.61255	validation_1-rmse:1.16535
# [121]	validation_0-rmse:0.61153	validation_1-rmse:1.16579
# [122]	validation_0-rmse:0.60873	validation_1-rmse:1.16665
# [123]	validation_0-rmse:0.60692	validation_1-rmse:1.16784
# [124]	validation_0-rmse:0.60597	validation_1-rmse:1.16819
# [0]	validation_0-rmse:6.54976	validation_1-rmse:6.08906
# [1]	validation_0-rmse:6.26990	validation_1-rmse:5.83572
# [2]	validation_0-rmse:5.99576	validation_1-rmse:5.57425
# [3]	validation_0-rmse:5.73943	validation_1-rmse:5.32236
# [4]	validation_0-rmse:5.48595	validation_1-rmse:5.08027
# [5]	validation_0-rmse:5.24342	validation_1-rmse:4.84952
# [6]	validation_0-rmse:5.00528	validation_1-rmse:4.62305
# [7]	validation_0-rmse:4.78560	validation_1-rmse:4.42206
# [8]	validation_0-rmse:4.58092	validation_1-rmse:4.25526
# [9]	validation_0-rmse:4.38762	validation_1-rmse:4.07278
# [10]	validation_0-rmse:4.20517	validation_1-rmse:3.90607
# [11]	validation_0-rmse:4.03156	validation_1-rmse:3.74748
# [12]	validation_0-rmse:3.86012	validation_1-rmse:3.59560
# [13]	validation_0-rmse:3.69852	validation_1-rmse:3.44742
# [14]	validation_0-rmse:3.53073	validation_1-rmse:3.29930
# [15]	validation_0-rmse:3.37974	validation_1-rmse:3.16753
# [16]	validation_0-rmse:3.23899	validation_1-rmse:3.04317
# [17]	validation_0-rmse:3.10491	validation_1-rmse:2.93311
# [18]	validation_0-rmse:2.98182	validation_1-rmse:2.82617
# [19]	validation_0-rmse:2.86113	validation_1-rmse:2.71607
# [20]	validation_0-rmse:2.74096	validation_1-rmse:2.61842
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [21]	validation_0-rmse:2.62699	validation_1-rmse:2.51959
# [22]	validation_0-rmse:2.52369	validation_1-rmse:2.42974
# [23]	validation_0-rmse:2.43115	validation_1-rmse:2.34936
# [24]	validation_0-rmse:2.33404	validation_1-rmse:2.26560
# [25]	validation_0-rmse:2.24439	validation_1-rmse:2.19322
# [26]	validation_0-rmse:2.16626	validation_1-rmse:2.12698
# [27]	validation_0-rmse:2.08575	validation_1-rmse:2.05860
# [28]	validation_0-rmse:2.00595	validation_1-rmse:1.99723
# [29]	validation_0-rmse:1.93400	validation_1-rmse:1.93951
# [30]	validation_0-rmse:1.86442	validation_1-rmse:1.88575
# [31]	validation_0-rmse:1.79336	validation_1-rmse:1.82775
# [32]	validation_0-rmse:1.73045	validation_1-rmse:1.77368
# [33]	validation_0-rmse:1.66830	validation_1-rmse:1.72309
# [34]	validation_0-rmse:1.61859	validation_1-rmse:1.69111
# [35]	validation_0-rmse:1.56513	validation_1-rmse:1.64847
# [36]	validation_0-rmse:1.51891	validation_1-rmse:1.60803
# [37]	validation_0-rmse:1.47106	validation_1-rmse:1.57124
# [38]	validation_0-rmse:1.43164	validation_1-rmse:1.53986
# [39]	validation_0-rmse:1.38734	validation_1-rmse:1.52310
# [40]	validation_0-rmse:1.34875	validation_1-rmse:1.49555
# [41]	validation_0-rmse:1.30550	validation_1-rmse:1.46705
# [42]	validation_0-rmse:1.27047	validation_1-rmse:1.44304
# [43]	validation_0-rmse:1.23634	validation_1-rmse:1.41613
# [44]	validation_0-rmse:1.20650	validation_1-rmse:1.39513
# [45]	validation_0-rmse:1.17142	validation_1-rmse:1.36877
# [46]	validation_0-rmse:1.13568	validation_1-rmse:1.34708
# [47]	validation_0-rmse:1.11396	validation_1-rmse:1.33457
# [48]	validation_0-rmse:1.09107	validation_1-rmse:1.32122
# [49]	validation_0-rmse:1.06237	validation_1-rmse:1.30171
# [50]	validation_0-rmse:1.03876	validation_1-rmse:1.28662
# [51]	validation_0-rmse:1.01476	validation_1-rmse:1.27288
# [52]	validation_0-rmse:0.99671	validation_1-rmse:1.26773
# [53]	validation_0-rmse:0.97489	validation_1-rmse:1.25406
# [54]	validation_0-rmse:0.95934	validation_1-rmse:1.24464
# [55]	validation_0-rmse:0.94645	validation_1-rmse:1.23849
# [56]	validation_0-rmse:0.93130	validation_1-rmse:1.22847
# [57]	validation_0-rmse:0.91691	validation_1-rmse:1.21866
# [58]	validation_0-rmse:0.90358	validation_1-rmse:1.21298
# [59]	validation_0-rmse:0.88847	validation_1-rmse:1.20563
# [60]	validation_0-rmse:0.87593	validation_1-rmse:1.19603
# [61]	validation_0-rmse:0.86577	validation_1-rmse:1.19184
# [62]	validation_0-rmse:0.85569	validation_1-rmse:1.18588
# [63]	validation_0-rmse:0.84769	validation_1-rmse:1.18717
# [64]	validation_0-rmse:0.83787	validation_1-rmse:1.18566
# [65]	validation_0-rmse:0.83390	validation_1-rmse:1.18351
# [66]	validation_0-rmse:0.81882	validation_1-rmse:1.16834
# [67]	validation_0-rmse:0.80966	validation_1-rmse:1.16189
# [68]	validation_0-rmse:0.80435	validation_1-rmse:1.15612
# [69]	validation_0-rmse:0.79769	validation_1-rmse:1.15210
# [70]	validation_0-rmse:0.79144	validation_1-rmse:1.14639
# [71]	validation_0-rmse:0.78200	validation_1-rmse:1.13490
# [72]	validation_0-rmse:0.77821	validation_1-rmse:1.13297
# [73]	validation_0-rmse:0.77262	validation_1-rmse:1.12692
# [74]	validation_0-rmse:0.76670	validation_1-rmse:1.12272
# [75]	validation_0-rmse:0.75669	validation_1-rmse:1.12322
# [76]	validation_0-rmse:0.75199	validation_1-rmse:1.11849
# [77]	validation_0-rmse:0.74231	validation_1-rmse:1.11836
# [78]	validation_0-rmse:0.73752	validation_1-rmse:1.11542
# [79]	validation_0-rmse:0.73242	validation_1-rmse:1.11383
# [80]	validation_0-rmse:0.72852	validation_1-rmse:1.12166
# [81]	validation_0-rmse:0.72590	validation_1-rmse:1.11523
# [82]	validation_0-rmse:0.72364	validation_1-rmse:1.11473
# [83]	validation_0-rmse:0.71914	validation_1-rmse:1.11377
# [84]	validation_0-rmse:0.70983	validation_1-rmse:1.10509
# [85]	validation_0-rmse:0.70825	validation_1-rmse:1.10276
# [86]	validation_0-rmse:0.70383	validation_1-rmse:1.09936
# [87]	validation_0-rmse:0.69908	validation_1-rmse:1.09838
# [88]	validation_0-rmse:0.69078	validation_1-rmse:1.09459
# [89]	validation_0-rmse:0.68488	validation_1-rmse:1.09522
# [90]	validation_0-rmse:0.68213	validation_1-rmse:1.09366
# [91]	validation_0-rmse:0.67935	validation_1-rmse:1.09631
# [92]	validation_0-rmse:0.67784	validation_1-rmse:1.09238
# [93]	validation_0-rmse:0.67395	validation_1-rmse:1.09434
# [94]	validation_0-rmse:0.66810	validation_1-rmse:1.09477
# [95]	validation_0-rmse:0.66658	validation_1-rmse:1.09462
# [96]	validation_0-rmse:0.66519	validation_1-rmse:1.09960
# [97]	validation_0-rmse:0.66265	validation_1-rmse:1.09564
# [98]	validation_0-rmse:0.65987	validation_1-rmse:1.09613
# [99]	validation_0-rmse:0.65772	validation_1-rmse:1.09511
# [100]	validation_0-rmse:0.65580	validation_1-rmse:1.09397
# [101]	validation_0-rmse:0.65390	validation_1-rmse:1.09337
# [102]	validation_0-rmse:0.64821	validation_1-rmse:1.09214
# [103]	validation_0-rmse:0.64485	validation_1-rmse:1.09123
# [104]	validation_0-rmse:0.64189	validation_1-rmse:1.09014
# [105]	validation_0-rmse:0.63989	validation_1-rmse:1.08675
# [106]	validation_0-rmse:0.63844	validation_1-rmse:1.08590
# [107]	validation_0-rmse:0.63320	validation_1-rmse:1.08587
# [108]	validation_0-rmse:0.63042	validation_1-rmse:1.08355
# [109]	validation_0-rmse:0.62784	validation_1-rmse:1.08713
# [110]	validation_0-rmse:0.62482	validation_1-rmse:1.08716
# [111]	validation_0-rmse:0.62339	validation_1-rmse:1.08899
# [112]	validation_0-rmse:0.62096	validation_1-rmse:1.08815
# [113]	validation_0-rmse:0.61992	validation_1-rmse:1.08683
# [114]	validation_0-rmse:0.61666	validation_1-rmse:1.08706
# [115]	validation_0-rmse:0.61519	validation_1-rmse:1.08367
# [116]	validation_0-rmse:0.61330	validation_1-rmse:1.08376
# [117]	validation_0-rmse:0.61081	validation_1-rmse:1.08570
# [118]	validation_0-rmse:0.60980	validation_1-rmse:1.07831
# [119]	validation_0-rmse:0.60810	validation_1-rmse:1.07781
# [120]	validation_0-rmse:0.60451	validation_1-rmse:1.08017
# [121]	validation_0-rmse:0.60301	validation_1-rmse:1.07885
# [122]	validation_0-rmse:0.60173	validation_1-rmse:1.07905
# [123]	validation_0-rmse:0.60022	validation_1-rmse:1.08306
# [124]	validation_0-rmse:0.59878	validation_1-rmse:1.08436
# [0]	validation_0-rmse:6.50703	validation_1-rmse:6.23390
# [1]	validation_0-rmse:6.22319	validation_1-rmse:5.93895
# [2]	validation_0-rmse:5.95239	validation_1-rmse:5.67084
# [3]	validation_0-rmse:5.69671	validation_1-rmse:5.42899
# [4]	validation_0-rmse:5.44072	validation_1-rmse:5.17347
# [5]	validation_0-rmse:5.21022	validation_1-rmse:4.95383
# [6]	validation_0-rmse:4.98469	validation_1-rmse:4.72270
# [7]	validation_0-rmse:4.77396	validation_1-rmse:4.52295
# [8]	validation_0-rmse:4.56560	validation_1-rmse:4.32959
# [9]	validation_0-rmse:4.37333	validation_1-rmse:4.14979
# [10]	validation_0-rmse:4.18101	validation_1-rmse:3.96227
# [11]	validation_0-rmse:4.01061	validation_1-rmse:3.79901
# [12]	validation_0-rmse:3.83794	validation_1-rmse:3.63758
# [13]	validation_0-rmse:3.67080	validation_1-rmse:3.47734
# [14]	validation_0-rmse:3.50443	validation_1-rmse:3.31343
# [15]	validation_0-rmse:3.37165	validation_1-rmse:3.18862
# [16]	validation_0-rmse:3.24706	validation_1-rmse:3.06944
# [17]	validation_0-rmse:3.11402	validation_1-rmse:2.94914
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [18]	validation_0-rmse:2.97829	validation_1-rmse:2.84312
# [19]	validation_0-rmse:2.85947	validation_1-rmse:2.74355
# [20]	validation_0-rmse:2.74497	validation_1-rmse:2.63650
# [21]	validation_0-rmse:2.64472	validation_1-rmse:2.54308
# [22]	validation_0-rmse:2.54237	validation_1-rmse:2.44557
# [23]	validation_0-rmse:2.44108	validation_1-rmse:2.34941
# [24]	validation_0-rmse:2.34692	validation_1-rmse:2.27440
# [25]	validation_0-rmse:2.25442	validation_1-rmse:2.18926
# [26]	validation_0-rmse:2.17465	validation_1-rmse:2.12122
# [27]	validation_0-rmse:2.08964	validation_1-rmse:2.04858
# [28]	validation_0-rmse:2.01063	validation_1-rmse:1.98229
# [29]	validation_0-rmse:1.93759	validation_1-rmse:1.92514
# [30]	validation_0-rmse:1.86706	validation_1-rmse:1.86271
# [31]	validation_0-rmse:1.80668	validation_1-rmse:1.80847
# [32]	validation_0-rmse:1.74020	validation_1-rmse:1.74444
# [33]	validation_0-rmse:1.67814	validation_1-rmse:1.68619
# [34]	validation_0-rmse:1.61909	validation_1-rmse:1.63508
# [35]	validation_0-rmse:1.56389	validation_1-rmse:1.58265
# [36]	validation_0-rmse:1.50981	validation_1-rmse:1.53640
# [37]	validation_0-rmse:1.46171	validation_1-rmse:1.49284
# [38]	validation_0-rmse:1.41604	validation_1-rmse:1.46234
# [39]	validation_0-rmse:1.38102	validation_1-rmse:1.43921
# [40]	validation_0-rmse:1.34115	validation_1-rmse:1.41188
# [41]	validation_0-rmse:1.30829	validation_1-rmse:1.38662
# [42]	validation_0-rmse:1.27205	validation_1-rmse:1.36431
# [43]	validation_0-rmse:1.24129	validation_1-rmse:1.34224
# [44]	validation_0-rmse:1.20996	validation_1-rmse:1.32390
# [45]	validation_0-rmse:1.18932	validation_1-rmse:1.30015
# [46]	validation_0-rmse:1.15881	validation_1-rmse:1.27880
# [47]	validation_0-rmse:1.13036	validation_1-rmse:1.25673
# [48]	validation_0-rmse:1.10462	validation_1-rmse:1.23280
# [49]	validation_0-rmse:1.08409	validation_1-rmse:1.22746
# [50]	validation_0-rmse:1.05847	validation_1-rmse:1.21804
# [51]	validation_0-rmse:1.04043	validation_1-rmse:1.21066
# [52]	validation_0-rmse:1.01512	validation_1-rmse:1.19573
# [53]	validation_0-rmse:0.99577	validation_1-rmse:1.18787
# [54]	validation_0-rmse:0.97636	validation_1-rmse:1.17633
# [55]	validation_0-rmse:0.96190	validation_1-rmse:1.16540
# [56]	validation_0-rmse:0.94796	validation_1-rmse:1.15787
# [57]	validation_0-rmse:0.93696	validation_1-rmse:1.15805
# [58]	validation_0-rmse:0.92285	validation_1-rmse:1.15012
# [59]	validation_0-rmse:0.90979	validation_1-rmse:1.14038
# [60]	validation_0-rmse:0.89644	validation_1-rmse:1.12690
# [61]	validation_0-rmse:0.88520	validation_1-rmse:1.12083
# [62]	validation_0-rmse:0.87387	validation_1-rmse:1.11230
# [63]	validation_0-rmse:0.86389	validation_1-rmse:1.10765
# [64]	validation_0-rmse:0.85047	validation_1-rmse:1.09857
# [65]	validation_0-rmse:0.84336	validation_1-rmse:1.10535
# [66]	validation_0-rmse:0.83384	validation_1-rmse:1.10130
# [67]	validation_0-rmse:0.82569	validation_1-rmse:1.09551
# [68]	validation_0-rmse:0.82134	validation_1-rmse:1.09374
# [69]	validation_0-rmse:0.81296	validation_1-rmse:1.08884
# [70]	validation_0-rmse:0.80291	validation_1-rmse:1.08091
# [71]	validation_0-rmse:0.79684	validation_1-rmse:1.08122
# [72]	validation_0-rmse:0.78959	validation_1-rmse:1.07527
# [73]	validation_0-rmse:0.78183	validation_1-rmse:1.07087
# [74]	validation_0-rmse:0.77377	validation_1-rmse:1.06851
# [75]	validation_0-rmse:0.76835	validation_1-rmse:1.06621
# [76]	validation_0-rmse:0.76579	validation_1-rmse:1.06362
# [77]	validation_0-rmse:0.75870	validation_1-rmse:1.05959
# [78]	validation_0-rmse:0.75383	validation_1-rmse:1.05840
# [79]	validation_0-rmse:0.74991	validation_1-rmse:1.05454
# [80]	validation_0-rmse:0.74461	validation_1-rmse:1.05653
# [81]	validation_0-rmse:0.74127	validation_1-rmse:1.05809
# [82]	validation_0-rmse:0.73651	validation_1-rmse:1.06279
# [83]	validation_0-rmse:0.73456	validation_1-rmse:1.06915
# [84]	validation_0-rmse:0.73045	validation_1-rmse:1.06835
# [85]	validation_0-rmse:0.72660	validation_1-rmse:1.07290
# [86]	validation_0-rmse:0.72302	validation_1-rmse:1.07082
# [87]	validation_0-rmse:0.72048	validation_1-rmse:1.07284
# [88]	validation_0-rmse:0.71615	validation_1-rmse:1.07243
# [89]	validation_0-rmse:0.71368	validation_1-rmse:1.07271
# [90]	validation_0-rmse:0.71091	validation_1-rmse:1.07720
# [91]	validation_0-rmse:0.70957	validation_1-rmse:1.07807
# [92]	validation_0-rmse:0.70696	validation_1-rmse:1.07618
# [93]	validation_0-rmse:0.70451	validation_1-rmse:1.07615
# [94]	validation_0-rmse:0.70223	validation_1-rmse:1.07708
# [95]	validation_0-rmse:0.69691	validation_1-rmse:1.07527
# [96]	validation_0-rmse:0.69330	validation_1-rmse:1.07578
# [97]	validation_0-rmse:0.69049	validation_1-rmse:1.07598
# [98]	validation_0-rmse:0.68863	validation_1-rmse:1.07951
# [0]	validation_0-rmse:6.47333	validation_1-rmse:6.31997
# [1]	validation_0-rmse:6.19616	validation_1-rmse:6.05377
# [2]	validation_0-rmse:5.91964	validation_1-rmse:5.77197
# [3]	validation_0-rmse:5.65620	validation_1-rmse:5.51884
# [4]	validation_0-rmse:5.40839	validation_1-rmse:5.27757
# [5]	validation_0-rmse:5.17010	validation_1-rmse:5.04843
# [6]	validation_0-rmse:4.94660	validation_1-rmse:4.82337
# [7]	validation_0-rmse:4.74177	validation_1-rmse:4.63610
# [8]	validation_0-rmse:4.54534	validation_1-rmse:4.45104
# [9]	validation_0-rmse:4.35994	validation_1-rmse:4.26382
# [10]	validation_0-rmse:4.17010	validation_1-rmse:4.07398
# [11]	validation_0-rmse:3.98052	validation_1-rmse:3.89328
# [12]	validation_0-rmse:3.82448	validation_1-rmse:3.75327
# [13]	validation_0-rmse:3.67291	validation_1-rmse:3.62387
# [14]	validation_0-rmse:3.51666	validation_1-rmse:3.47759
# [15]	validation_0-rmse:3.37975	validation_1-rmse:3.35627
# [16]	validation_0-rmse:3.24526	validation_1-rmse:3.23697
# [17]	validation_0-rmse:3.11701	validation_1-rmse:3.12177
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [18]	validation_0-rmse:3.00504	validation_1-rmse:3.01138
# [19]	validation_0-rmse:2.88477	validation_1-rmse:2.90012
# [20]	validation_0-rmse:2.76691	validation_1-rmse:2.78299
# [21]	validation_0-rmse:2.66596	validation_1-rmse:2.68143
# [22]	validation_0-rmse:2.55574	validation_1-rmse:2.57250
# [23]	validation_0-rmse:2.45521	validation_1-rmse:2.47775
# [24]	validation_0-rmse:2.36422	validation_1-rmse:2.39429
# [25]	validation_0-rmse:2.27789	validation_1-rmse:2.31309
# [26]	validation_0-rmse:2.19194	validation_1-rmse:2.24329
# [27]	validation_0-rmse:2.11138	validation_1-rmse:2.17954
# [28]	validation_0-rmse:2.03784	validation_1-rmse:2.10849
# [29]	validation_0-rmse:1.96826	validation_1-rmse:2.04135
# [30]	validation_0-rmse:1.90194	validation_1-rmse:1.98211
# [31]	validation_0-rmse:1.83544	validation_1-rmse:1.92171
# [32]	validation_0-rmse:1.77594	validation_1-rmse:1.86132
# [33]	validation_0-rmse:1.71630	validation_1-rmse:1.81083
# [34]	validation_0-rmse:1.65724	validation_1-rmse:1.75197
# [35]	validation_0-rmse:1.59790	validation_1-rmse:1.70256
# [36]	validation_0-rmse:1.54726	validation_1-rmse:1.65086
# [37]	validation_0-rmse:1.49703	validation_1-rmse:1.61089
# [38]	validation_0-rmse:1.45970	validation_1-rmse:1.57978
# [39]	validation_0-rmse:1.41738	validation_1-rmse:1.53647
# [40]	validation_0-rmse:1.37560	validation_1-rmse:1.48945
# [41]	validation_0-rmse:1.33405	validation_1-rmse:1.45504
# [42]	validation_0-rmse:1.29502	validation_1-rmse:1.41482
# [43]	validation_0-rmse:1.25823	validation_1-rmse:1.38887
# [44]	validation_0-rmse:1.22391	validation_1-rmse:1.35674
# [45]	validation_0-rmse:1.19289	validation_1-rmse:1.32326
# [46]	validation_0-rmse:1.16573	validation_1-rmse:1.30279
# [47]	validation_0-rmse:1.14005	validation_1-rmse:1.28734
# [48]	validation_0-rmse:1.11710	validation_1-rmse:1.26943
# [49]	validation_0-rmse:1.09579	validation_1-rmse:1.25406
# [50]	validation_0-rmse:1.07308	validation_1-rmse:1.23921
# [51]	validation_0-rmse:1.04259	validation_1-rmse:1.21259
# [52]	validation_0-rmse:1.02632	validation_1-rmse:1.19913
# [53]	validation_0-rmse:1.01091	validation_1-rmse:1.18448
# [54]	validation_0-rmse:0.99149	validation_1-rmse:1.16687
# [55]	validation_0-rmse:0.97806	validation_1-rmse:1.15382
# [56]	validation_0-rmse:0.96231	validation_1-rmse:1.14645
# [57]	validation_0-rmse:0.94884	validation_1-rmse:1.13758
# [58]	validation_0-rmse:0.93474	validation_1-rmse:1.13009
# [59]	validation_0-rmse:0.91906	validation_1-rmse:1.11756
# [60]	validation_0-rmse:0.90787	validation_1-rmse:1.10598
# [61]	validation_0-rmse:0.89394	validation_1-rmse:1.09426
# [62]	validation_0-rmse:0.88628	validation_1-rmse:1.09439
# [63]	validation_0-rmse:0.87748	validation_1-rmse:1.08125
# [64]	validation_0-rmse:0.86728	validation_1-rmse:1.07223
# [65]	validation_0-rmse:0.86110	validation_1-rmse:1.06693
# [66]	validation_0-rmse:0.84827	validation_1-rmse:1.05299
# [67]	validation_0-rmse:0.84174	validation_1-rmse:1.04682
# [68]	validation_0-rmse:0.83565	validation_1-rmse:1.03891
# [69]	validation_0-rmse:0.82814	validation_1-rmse:1.03672
# [70]	validation_0-rmse:0.82064	validation_1-rmse:1.02735
# [71]	validation_0-rmse:0.81528	validation_1-rmse:1.02050
# [72]	validation_0-rmse:0.80759	validation_1-rmse:1.02009
# [73]	validation_0-rmse:0.80304	validation_1-rmse:1.01842
# [74]	validation_0-rmse:0.79840	validation_1-rmse:1.01495
# [75]	validation_0-rmse:0.79007	validation_1-rmse:1.01263
# [76]	validation_0-rmse:0.78770	validation_1-rmse:1.01469
# [77]	validation_0-rmse:0.78275	validation_1-rmse:1.01361
# [78]	validation_0-rmse:0.77801	validation_1-rmse:1.00832
# [79]	validation_0-rmse:0.77220	validation_1-rmse:1.00106
# [80]	validation_0-rmse:0.76854	validation_1-rmse:1.00094
# [81]	validation_0-rmse:0.76048	validation_1-rmse:0.99365
# [82]	validation_0-rmse:0.75482	validation_1-rmse:0.99136
# [83]	validation_0-rmse:0.75123	validation_1-rmse:0.98584
# [84]	validation_0-rmse:0.74637	validation_1-rmse:0.98327
# [85]	validation_0-rmse:0.74412	validation_1-rmse:0.98245
# [86]	validation_0-rmse:0.74262	validation_1-rmse:0.98508
# [87]	validation_0-rmse:0.73911	validation_1-rmse:0.98758
# [88]	validation_0-rmse:0.73747	validation_1-rmse:0.98410
# [89]	validation_0-rmse:0.73478	validation_1-rmse:0.98362
# [90]	validation_0-rmse:0.73220	validation_1-rmse:0.98458
# [91]	validation_0-rmse:0.72837	validation_1-rmse:0.97878
# [92]	validation_0-rmse:0.72441	validation_1-rmse:0.98697
# [93]	validation_0-rmse:0.72243	validation_1-rmse:0.98831
# [94]	validation_0-rmse:0.71941	validation_1-rmse:0.98861
# [95]	validation_0-rmse:0.71669	validation_1-rmse:0.98626
# [96]	validation_0-rmse:0.71223	validation_1-rmse:0.99052
# [97]	validation_0-rmse:0.71038	validation_1-rmse:0.99184
# [98]	validation_0-rmse:0.70804	validation_1-rmse:0.99401
# [99]	validation_0-rmse:0.70643	validation_1-rmse:0.99600
# [100]	validation_0-rmse:0.70401	validation_1-rmse:0.99574
# [101]	validation_0-rmse:0.70164	validation_1-rmse:0.99420
# [102]	validation_0-rmse:0.69779	validation_1-rmse:0.99119
# [103]	validation_0-rmse:0.69348	validation_1-rmse:0.98922
# [104]	validation_0-rmse:0.68832	validation_1-rmse:0.98822
# [105]	validation_0-rmse:0.68522	validation_1-rmse:0.98713
# [106]	validation_0-rmse:0.68215	validation_1-rmse:0.98225
# [107]	validation_0-rmse:0.68012	validation_1-rmse:0.98353
# [108]	validation_0-rmse:0.67853	validation_1-rmse:0.97999
# [109]	validation_0-rmse:0.67570	validation_1-rmse:0.98271
# [110]	validation_0-rmse:0.67202	validation_1-rmse:0.98281
# [111]	validation_0-rmse:0.66886	validation_1-rmse:0.98360
# [0]	validation_0-rmse:6.46654	validation_1-rmse:6.37352
# [1]	validation_0-rmse:6.18291	validation_1-rmse:6.09081
# [2]	validation_0-rmse:5.90394	validation_1-rmse:5.82464
# [3]	validation_0-rmse:5.64103	validation_1-rmse:5.57360
# [4]	validation_0-rmse:5.40432	validation_1-rmse:5.35027
# [5]	validation_0-rmse:5.17796	validation_1-rmse:5.12173
# [6]	validation_0-rmse:4.95232	validation_1-rmse:4.90015
# [7]	validation_0-rmse:4.73419	validation_1-rmse:4.68910
# [8]	validation_0-rmse:4.54131	validation_1-rmse:4.49635
# [9]	validation_0-rmse:4.35574	validation_1-rmse:4.32143
# [10]	validation_0-rmse:4.16990	validation_1-rmse:4.15262
# [11]	validation_0-rmse:3.98619	validation_1-rmse:3.98177
# [12]	validation_0-rmse:3.83068	validation_1-rmse:3.84370
# [13]	validation_0-rmse:3.67728	validation_1-rmse:3.71242
# [14]	validation_0-rmse:3.53320	validation_1-rmse:3.57679
# [15]	validation_0-rmse:3.38792	validation_1-rmse:3.43619
# [16]	validation_0-rmse:3.25180	validation_1-rmse:3.31295
# [17]	validation_0-rmse:3.11715	validation_1-rmse:3.19020
# [18]	validation_0-rmse:2.99465	validation_1-rmse:3.07253
# [19]	validation_0-rmse:2.87243	validation_1-rmse:2.96213
# [20]	validation_0-rmse:2.76239	validation_1-rmse:2.85867
# [21]	validation_0-rmse:2.65916	validation_1-rmse:2.76409
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [22]	validation_0-rmse:2.55744	validation_1-rmse:2.66522
# [23]	validation_0-rmse:2.46358	validation_1-rmse:2.57877
# [24]	validation_0-rmse:2.36624	validation_1-rmse:2.50014
# [25]	validation_0-rmse:2.28430	validation_1-rmse:2.42499
# [26]	validation_0-rmse:2.19586	validation_1-rmse:2.35845
# [27]	validation_0-rmse:2.12410	validation_1-rmse:2.29839
# [28]	validation_0-rmse:2.05554	validation_1-rmse:2.22918
# [29]	validation_0-rmse:1.98393	validation_1-rmse:2.14819
# [30]	validation_0-rmse:1.91826	validation_1-rmse:2.09314
# [31]	validation_0-rmse:1.84282	validation_1-rmse:2.02817
# [32]	validation_0-rmse:1.78045	validation_1-rmse:1.97539
# [33]	validation_0-rmse:1.72331	validation_1-rmse:1.93407
# [34]	validation_0-rmse:1.66337	validation_1-rmse:1.88783
# [35]	validation_0-rmse:1.61290	validation_1-rmse:1.84115
# [36]	validation_0-rmse:1.56568	validation_1-rmse:1.79905
# [37]	validation_0-rmse:1.51294	validation_1-rmse:1.76423
# [38]	validation_0-rmse:1.46635	validation_1-rmse:1.72426
# [39]	validation_0-rmse:1.42238	validation_1-rmse:1.67933
# [40]	validation_0-rmse:1.38290	validation_1-rmse:1.65133
# [41]	validation_0-rmse:1.33803	validation_1-rmse:1.62184
# [42]	validation_0-rmse:1.30439	validation_1-rmse:1.59848
# [43]	validation_0-rmse:1.27212	validation_1-rmse:1.57733
# [44]	validation_0-rmse:1.23772	validation_1-rmse:1.55652
# [45]	validation_0-rmse:1.20532	validation_1-rmse:1.53132
# [46]	validation_0-rmse:1.17691	validation_1-rmse:1.50612
# [47]	validation_0-rmse:1.14374	validation_1-rmse:1.47908
# [48]	validation_0-rmse:1.11751	validation_1-rmse:1.45664
# [49]	validation_0-rmse:1.08925	validation_1-rmse:1.43098
# [50]	validation_0-rmse:1.06476	validation_1-rmse:1.41092
# [51]	validation_0-rmse:1.03867	validation_1-rmse:1.39132
# [52]	validation_0-rmse:1.01559	validation_1-rmse:1.36940
# [53]	validation_0-rmse:0.99375	validation_1-rmse:1.35005
# [54]	validation_0-rmse:0.97614	validation_1-rmse:1.33743
# [55]	validation_0-rmse:0.96099	validation_1-rmse:1.32274
# [56]	validation_0-rmse:0.94863	validation_1-rmse:1.32226
# [57]	validation_0-rmse:0.93168	validation_1-rmse:1.31193
# [58]	validation_0-rmse:0.91564	validation_1-rmse:1.29948
# [59]	validation_0-rmse:0.90402	validation_1-rmse:1.29776
# [60]	validation_0-rmse:0.88999	validation_1-rmse:1.28469
# [61]	validation_0-rmse:0.88068	validation_1-rmse:1.28117
# [62]	validation_0-rmse:0.86974	validation_1-rmse:1.27081
# [63]	validation_0-rmse:0.86043	validation_1-rmse:1.26272
# [64]	validation_0-rmse:0.85197	validation_1-rmse:1.25693
# [65]	validation_0-rmse:0.84772	validation_1-rmse:1.25403
# [66]	validation_0-rmse:0.83933	validation_1-rmse:1.25332
# [67]	validation_0-rmse:0.82665	validation_1-rmse:1.24361
# [68]	validation_0-rmse:0.82054	validation_1-rmse:1.23908
# [69]	validation_0-rmse:0.81476	validation_1-rmse:1.24418
# [70]	validation_0-rmse:0.81028	validation_1-rmse:1.23996
# [71]	validation_0-rmse:0.80389	validation_1-rmse:1.23781
# [72]	validation_0-rmse:0.79723	validation_1-rmse:1.23593
# [73]	validation_0-rmse:0.79117	validation_1-rmse:1.23049
# [74]	validation_0-rmse:0.78224	validation_1-rmse:1.21847
# [75]	validation_0-rmse:0.77455	validation_1-rmse:1.21143
# [76]	validation_0-rmse:0.76792	validation_1-rmse:1.20485
# [77]	validation_0-rmse:0.76285	validation_1-rmse:1.20034
# [78]	validation_0-rmse:0.76028	validation_1-rmse:1.20550
# [79]	validation_0-rmse:0.75529	validation_1-rmse:1.20459
# [80]	validation_0-rmse:0.75163	validation_1-rmse:1.20026
# [81]	validation_0-rmse:0.74574	validation_1-rmse:1.19638
# [82]	validation_0-rmse:0.74104	validation_1-rmse:1.18986
# [83]	validation_0-rmse:0.73671	validation_1-rmse:1.18187
# [84]	validation_0-rmse:0.73074	validation_1-rmse:1.18309
# [85]	validation_0-rmse:0.72625	validation_1-rmse:1.18431
# [86]	validation_0-rmse:0.72527	validation_1-rmse:1.18415
# [87]	validation_0-rmse:0.72225	validation_1-rmse:1.17362
# [88]	validation_0-rmse:0.71786	validation_1-rmse:1.16675
# [89]	validation_0-rmse:0.71613	validation_1-rmse:1.16330
# [90]	validation_0-rmse:0.71244	validation_1-rmse:1.16296
# [91]	validation_0-rmse:0.70848	validation_1-rmse:1.15234
# [92]	validation_0-rmse:0.70531	validation_1-rmse:1.14917
# [93]	validation_0-rmse:0.70250	validation_1-rmse:1.14892
# [94]	validation_0-rmse:0.69816	validation_1-rmse:1.14657
# [95]	validation_0-rmse:0.69661	validation_1-rmse:1.14511
# [96]	validation_0-rmse:0.69288	validation_1-rmse:1.14128
# [97]	validation_0-rmse:0.69004	validation_1-rmse:1.13752
# [98]	validation_0-rmse:0.68579	validation_1-rmse:1.13671
# [99]	validation_0-rmse:0.68352	validation_1-rmse:1.12992
# [100]	validation_0-rmse:0.68041	validation_1-rmse:1.13141
# [101]	validation_0-rmse:0.67888	validation_1-rmse:1.13463
# [102]	validation_0-rmse:0.67802	validation_1-rmse:1.13601
# [103]	validation_0-rmse:0.67602	validation_1-rmse:1.13469
# [104]	validation_0-rmse:0.67395	validation_1-rmse:1.14005
# [105]	validation_0-rmse:0.67230	validation_1-rmse:1.13901
# [106]	validation_0-rmse:0.67121	validation_1-rmse:1.13714
# [107]	validation_0-rmse:0.66874	validation_1-rmse:1.13672
# [108]	validation_0-rmse:0.66688	validation_1-rmse:1.14162
# [109]	validation_0-rmse:0.66535	validation_1-rmse:1.14191
# [110]	validation_0-rmse:0.66204	validation_1-rmse:1.14301
# [111]	validation_0-rmse:0.66064	validation_1-rmse:1.14541
# [112]	validation_0-rmse:0.65901	validation_1-rmse:1.14431
# [113]	validation_0-rmse:0.65579	validation_1-rmse:1.14440
# [114]	validation_0-rmse:0.65239	validation_1-rmse:1.13898
# ...
# [105]	validation_0-rmse:0.69156	validation_1-rmse:0.90256
# [106]	validation_0-rmse:0.69085	validation_1-rmse:0.90234
# [107]	validation_0-rmse:0.68762	validation_1-rmse:0.90378
# [108]	validation_0-rmse:0.68607	validation_1-rmse:0.90257
# [109]	validation_0-rmse:0.68502	validation_1-rmse:0.90366
# [110]	validation_0-rmse:0.68295	validation_1-rmse:0.90158
# [111]	validation_0-rmse:0.68125	validation_1-rmse:0.90354
# [112]	validation_0-rmse:0.68059	validation_1-rmse:0.90461
# [113]	validation_0-rmse:0.67892	validation_1-rmse:0.90439
# [114]	validation_0-rmse:0.67612	validation_1-rmse:0.90712
# [115]	validation_0-rmse:0.67427	validation_1-rmse:0.90760
# [0]	validation_0-rmse:6.40276	validation_1-rmse:6.68527
# [1]	validation_0-rmse:6.12749	validation_1-rmse:6.40181
# [2]	validation_0-rmse:5.85598	validation_1-rmse:6.11638
# [3]	validation_0-rmse:5.60242	validation_1-rmse:5.85162
# [4]	validation_0-rmse:5.37206	validation_1-rmse:5.60356
# [5]	validation_0-rmse:5.14381	validation_1-rmse:5.35073
# [6]	validation_0-rmse:4.93445	validation_1-rmse:5.12142
# [7]	validation_0-rmse:4.72489	validation_1-rmse:4.88669
# [8]	validation_0-rmse:4.51965	validation_1-rmse:4.66586
# [9]	validation_0-rmse:4.33556	validation_1-rmse:4.46760
# [10]	validation_0-rmse:4.15304	validation_1-rmse:4.28024
# [11]	validation_0-rmse:3.99149	validation_1-rmse:4.11516
# [12]	validation_0-rmse:3.82039	validation_1-rmse:3.93748
# [13]	validation_0-rmse:3.67560	validation_1-rmse:3.77350
# [14]	validation_0-rmse:3.52941	validation_1-rmse:3.60900
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:3.39102	validation_1-rmse:3.45197
# [16]	validation_0-rmse:3.25657	validation_1-rmse:3.30854
# [17]	validation_0-rmse:3.12014	validation_1-rmse:3.17446
# [18]	validation_0-rmse:2.98815	validation_1-rmse:3.03703
# [19]	validation_0-rmse:2.87186	validation_1-rmse:2.91831
# [20]	validation_0-rmse:2.76337	validation_1-rmse:2.80574
# [21]	validation_0-rmse:2.66182	validation_1-rmse:2.70951
# [22]	validation_0-rmse:2.56538	validation_1-rmse:2.59849
# [23]	validation_0-rmse:2.46950	validation_1-rmse:2.48741
# [24]	validation_0-rmse:2.38187	validation_1-rmse:2.39914
# [25]	validation_0-rmse:2.28557	validation_1-rmse:2.29589
# [26]	validation_0-rmse:2.20537	validation_1-rmse:2.20928
# [27]	validation_0-rmse:2.12554	validation_1-rmse:2.12081
# [28]	validation_0-rmse:2.05245	validation_1-rmse:2.04064
# [29]	validation_0-rmse:1.98103	validation_1-rmse:1.97020
# [30]	validation_0-rmse:1.90780	validation_1-rmse:1.89449
# [31]	validation_0-rmse:1.84363	validation_1-rmse:1.82935
# [32]	validation_0-rmse:1.78704	validation_1-rmse:1.76160
# [33]	validation_0-rmse:1.72355	validation_1-rmse:1.69760
# [34]	validation_0-rmse:1.66839	validation_1-rmse:1.63614
# [35]	validation_0-rmse:1.61008	validation_1-rmse:1.57105
# [36]	validation_0-rmse:1.56138	validation_1-rmse:1.51782
# [37]	validation_0-rmse:1.50958	validation_1-rmse:1.46253
# [38]	validation_0-rmse:1.46646	validation_1-rmse:1.41958
# [39]	validation_0-rmse:1.42152	validation_1-rmse:1.37382
# [40]	validation_0-rmse:1.38232	validation_1-rmse:1.33077
# [41]	validation_0-rmse:1.34703	validation_1-rmse:1.28466
# [42]	validation_0-rmse:1.31628	validation_1-rmse:1.25528
# [43]	validation_0-rmse:1.27784	validation_1-rmse:1.21578
# [44]	validation_0-rmse:1.24659	validation_1-rmse:1.18232
# [45]	validation_0-rmse:1.21939	validation_1-rmse:1.15179
# [46]	validation_0-rmse:1.19410	validation_1-rmse:1.12454
# [47]	validation_0-rmse:1.16565	validation_1-rmse:1.09791
# [48]	validation_0-rmse:1.14122	validation_1-rmse:1.07278
# [49]	validation_0-rmse:1.11565	validation_1-rmse:1.05226
# [50]	validation_0-rmse:1.09386	validation_1-rmse:1.03919
# [51]	validation_0-rmse:1.07123	validation_1-rmse:1.01979
# [52]	validation_0-rmse:1.05143	validation_1-rmse:0.99906
# [53]	validation_0-rmse:1.03542	validation_1-rmse:0.98717
# [54]	validation_0-rmse:1.02147	validation_1-rmse:0.96909
# [55]	validation_0-rmse:1.00438	validation_1-rmse:0.94896
# [56]	validation_0-rmse:0.98802	validation_1-rmse:0.93278
# [57]	validation_0-rmse:0.97387	validation_1-rmse:0.92543
# [58]	validation_0-rmse:0.96358	validation_1-rmse:0.91455
# [59]	validation_0-rmse:0.94889	validation_1-rmse:0.89871
# [60]	validation_0-rmse:0.93844	validation_1-rmse:0.88789
# [61]	validation_0-rmse:0.92683	validation_1-rmse:0.87543
# [62]	validation_0-rmse:0.91739	validation_1-rmse:0.86882
# [63]	validation_0-rmse:0.91019	validation_1-rmse:0.86105
# [64]	validation_0-rmse:0.89606	validation_1-rmse:0.85134
# [65]	validation_0-rmse:0.88631	validation_1-rmse:0.84431
# [66]	validation_0-rmse:0.87637	validation_1-rmse:0.84386
# [67]	validation_0-rmse:0.86905	validation_1-rmse:0.83549
# [68]	validation_0-rmse:0.86185	validation_1-rmse:0.83203
# [69]	validation_0-rmse:0.85584	validation_1-rmse:0.83399
# [70]	validation_0-rmse:0.84677	validation_1-rmse:0.83030
# [71]	validation_0-rmse:0.83808	validation_1-rmse:0.82638
# [72]	validation_0-rmse:0.83274	validation_1-rmse:0.82443
# [73]	validation_0-rmse:0.82420	validation_1-rmse:0.81995
# [74]	validation_0-rmse:0.81753	validation_1-rmse:0.81682
# [75]	validation_0-rmse:0.81230	validation_1-rmse:0.81518
# [76]	validation_0-rmse:0.80617	validation_1-rmse:0.81508
# [77]	validation_0-rmse:0.80271	validation_1-rmse:0.81403
# [78]	validation_0-rmse:0.80164	validation_1-rmse:0.81386
# [79]	validation_0-rmse:0.79778	validation_1-rmse:0.81325
# [80]	validation_0-rmse:0.79337	validation_1-rmse:0.81395
# [81]	validation_0-rmse:0.79046	validation_1-rmse:0.80941
# [82]	validation_0-rmse:0.78662	validation_1-rmse:0.80685
# [83]	validation_0-rmse:0.77887	validation_1-rmse:0.79836
# [84]	validation_0-rmse:0.77151	validation_1-rmse:0.79404
# [85]	validation_0-rmse:0.76831	validation_1-rmse:0.79275
# [86]	validation_0-rmse:0.76606	validation_1-rmse:0.78973
# [87]	validation_0-rmse:0.76121	validation_1-rmse:0.79202
# [88]	validation_0-rmse:0.75895	validation_1-rmse:0.79614
# [89]	validation_0-rmse:0.75530	validation_1-rmse:0.79618
# [90]	validation_0-rmse:0.75194	validation_1-rmse:0.79836
# [91]	validation_0-rmse:0.74999	validation_1-rmse:0.79041
# [92]	validation_0-rmse:0.74557	validation_1-rmse:0.79098
# [93]	validation_0-rmse:0.74324	validation_1-rmse:0.78789
# [94]	validation_0-rmse:0.74155	validation_1-rmse:0.78479
# [95]	validation_0-rmse:0.73815	validation_1-rmse:0.79062
# [96]	validation_0-rmse:0.73553	validation_1-rmse:0.79093
# [97]	validation_0-rmse:0.73556	validation_1-rmse:0.79312
# [98]	validation_0-rmse:0.73423	validation_1-rmse:0.79115
# [99]	validation_0-rmse:0.73114	validation_1-rmse:0.78969
# [100]	validation_0-rmse:0.72903	validation_1-rmse:0.78984
# [101]	validation_0-rmse:0.72569	validation_1-rmse:0.78354
# [102]	validation_0-rmse:0.72258	validation_1-rmse:0.78121
# [103]	validation_0-rmse:0.72026	validation_1-rmse:0.78473
# [104]	validation_0-rmse:0.71798	validation_1-rmse:0.77874
# [105]	validation_0-rmse:0.71516	validation_1-rmse:0.77807
# [106]	validation_0-rmse:0.71386	validation_1-rmse:0.78160
# [107]	validation_0-rmse:0.71214	validation_1-rmse:0.77885
# [108]	validation_0-rmse:0.70953	validation_1-rmse:0.77567
# [109]	validation_0-rmse:0.70682	validation_1-rmse:0.77807
# [110]	validation_0-rmse:0.70572	validation_1-rmse:0.77803
# [111]	validation_0-rmse:0.70485	validation_1-rmse:0.77856
# [112]	validation_0-rmse:0.70346	validation_1-rmse:0.77505
# [113]	validation_0-rmse:0.70106	validation_1-rmse:0.77605
# [114]	validation_0-rmse:0.69963	validation_1-rmse:0.77619
# [115]	validation_0-rmse:0.69753	validation_1-rmse:0.77488
# [116]	validation_0-rmse:0.69530	validation_1-rmse:0.77758
# [117]	validation_0-rmse:0.69450	validation_1-rmse:0.77710
# [118]	validation_0-rmse:0.69240	validation_1-rmse:0.77741
# [119]	validation_0-rmse:0.69073	validation_1-rmse:0.77795
# [120]	validation_0-rmse:0.68902	validation_1-rmse:0.77404
# [121]	validation_0-rmse:0.68802	validation_1-rmse:0.77150
# [122]	validation_0-rmse:0.68702	validation_1-rmse:0.77427
# [123]	validation_0-rmse:0.68642	validation_1-rmse:0.77153
# [124]	validation_0-rmse:0.68378	validation_1-rmse:0.77249
# [0]	validation_0-rmse:6.40299	validation_1-rmse:6.67245
# [1]	validation_0-rmse:6.11855	validation_1-rmse:6.37607
# [2]	validation_0-rmse:5.85645	validation_1-rmse:6.12616
# [3]	validation_0-rmse:5.59691	validation_1-rmse:5.86886
# [4]	validation_0-rmse:5.35348	validation_1-rmse:5.62769
# [5]	validation_0-rmse:5.12819	validation_1-rmse:5.40605
# [6]	validation_0-rmse:4.91536	validation_1-rmse:5.18611
# [7]	validation_0-rmse:4.70869	validation_1-rmse:4.99040
# [8]	validation_0-rmse:4.50622	validation_1-rmse:4.80025
# [9]	validation_0-rmse:4.32380	validation_1-rmse:4.61968
# [10]	validation_0-rmse:4.14274	validation_1-rmse:4.44509
# [11]	validation_0-rmse:3.96911	validation_1-rmse:4.28201
# [12]	validation_0-rmse:3.80310	validation_1-rmse:4.11779
# [13]	validation_0-rmse:3.63847	validation_1-rmse:3.94866
# [14]	validation_0-rmse:3.48803	validation_1-rmse:3.80006
# [15]	validation_0-rmse:3.34373	validation_1-rmse:3.64188
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [16]	validation_0-rmse:3.21182	validation_1-rmse:3.50691
# [17]	validation_0-rmse:3.08131	validation_1-rmse:3.36921
# [18]	validation_0-rmse:2.96149	validation_1-rmse:3.24412
# [19]	validation_0-rmse:2.84171	validation_1-rmse:3.12422
# [20]	validation_0-rmse:2.73471	validation_1-rmse:3.00468
# [21]	validation_0-rmse:2.62835	validation_1-rmse:2.88675
# [22]	validation_0-rmse:2.53564	validation_1-rmse:2.78982
# [23]	validation_0-rmse:2.44548	validation_1-rmse:2.69931
# [24]	validation_0-rmse:2.35032	validation_1-rmse:2.60566
# [25]	validation_0-rmse:2.26163	validation_1-rmse:2.50597
# [26]	validation_0-rmse:2.18988	validation_1-rmse:2.43601
# [27]	validation_0-rmse:2.10993	validation_1-rmse:2.35702
# [28]	validation_0-rmse:2.03506	validation_1-rmse:2.27409
# [29]	validation_0-rmse:1.96823	validation_1-rmse:2.20798
# [30]	validation_0-rmse:1.89032	validation_1-rmse:2.11993
# [31]	validation_0-rmse:1.81878	validation_1-rmse:2.04023
# [32]	validation_0-rmse:1.75884	validation_1-rmse:1.96762
# [33]	validation_0-rmse:1.70692	validation_1-rmse:1.90340
# [34]	validation_0-rmse:1.65018	validation_1-rmse:1.83980
# [35]	validation_0-rmse:1.59998	validation_1-rmse:1.77945
# [36]	validation_0-rmse:1.54879	validation_1-rmse:1.72027
# [37]	validation_0-rmse:1.49911	validation_1-rmse:1.66117
# [38]	validation_0-rmse:1.45280	validation_1-rmse:1.60721
# [39]	validation_0-rmse:1.41255	validation_1-rmse:1.56179
# [40]	validation_0-rmse:1.37502	validation_1-rmse:1.52550
# [41]	validation_0-rmse:1.34310	validation_1-rmse:1.48751
# [42]	validation_0-rmse:1.31042	validation_1-rmse:1.44489
# [43]	validation_0-rmse:1.27525	validation_1-rmse:1.40521
# [44]	validation_0-rmse:1.24284	validation_1-rmse:1.36386
# [45]	validation_0-rmse:1.21234	validation_1-rmse:1.33554
# [46]	validation_0-rmse:1.18634	validation_1-rmse:1.29803
# [47]	validation_0-rmse:1.16126	validation_1-rmse:1.27310
# [48]	validation_0-rmse:1.13765	validation_1-rmse:1.24807
# [49]	validation_0-rmse:1.11450	validation_1-rmse:1.22009
# [50]	validation_0-rmse:1.09244	validation_1-rmse:1.19795
# [51]	validation_0-rmse:1.07305	validation_1-rmse:1.18189
# [52]	validation_0-rmse:1.04873	validation_1-rmse:1.15403
# [53]	validation_0-rmse:1.02707	validation_1-rmse:1.13338
# [54]	validation_0-rmse:1.01248	validation_1-rmse:1.11602
# [55]	validation_0-rmse:0.99803	validation_1-rmse:1.09539
# [56]	validation_0-rmse:0.98343	validation_1-rmse:1.07911
# [57]	validation_0-rmse:0.96636	validation_1-rmse:1.06874
# [58]	validation_0-rmse:0.95249	validation_1-rmse:1.05875
# [59]	validation_0-rmse:0.94370	validation_1-rmse:1.04977
# [60]	validation_0-rmse:0.93093	validation_1-rmse:1.03414
# [61]	validation_0-rmse:0.92123	validation_1-rmse:1.02680
# [62]	validation_0-rmse:0.91104	validation_1-rmse:1.01100
# [63]	validation_0-rmse:0.90098	validation_1-rmse:0.99787
# [64]	validation_0-rmse:0.89214	validation_1-rmse:0.98402
# [65]	validation_0-rmse:0.88787	validation_1-rmse:0.97396
# [66]	validation_0-rmse:0.88021	validation_1-rmse:0.96784
# [67]	validation_0-rmse:0.87072	validation_1-rmse:0.95887
# [68]	validation_0-rmse:0.86200	validation_1-rmse:0.94460
# [69]	validation_0-rmse:0.85660	validation_1-rmse:0.94126
# [70]	validation_0-rmse:0.84990	validation_1-rmse:0.93345
# [71]	validation_0-rmse:0.84392	validation_1-rmse:0.93049
# [72]	validation_0-rmse:0.83788	validation_1-rmse:0.91939
# [73]	validation_0-rmse:0.83284	validation_1-rmse:0.91073
# [74]	validation_0-rmse:0.82467	validation_1-rmse:0.90436
# [75]	validation_0-rmse:0.81896	validation_1-rmse:0.89546
# [76]	validation_0-rmse:0.81225	validation_1-rmse:0.89079
# [77]	validation_0-rmse:0.80443	validation_1-rmse:0.88670
# [78]	validation_0-rmse:0.80077	validation_1-rmse:0.87861
# [79]	validation_0-rmse:0.79613	validation_1-rmse:0.86861
# [80]	validation_0-rmse:0.79140	validation_1-rmse:0.86466
# [81]	validation_0-rmse:0.78601	validation_1-rmse:0.86147
# [82]	validation_0-rmse:0.78084	validation_1-rmse:0.85753
# [83]	validation_0-rmse:0.77342	validation_1-rmse:0.85485
# [84]	validation_0-rmse:0.76693	validation_1-rmse:0.85304
# [85]	validation_0-rmse:0.76183	validation_1-rmse:0.84561
# [86]	validation_0-rmse:0.76041	validation_1-rmse:0.84310
# [87]	validation_0-rmse:0.75820	validation_1-rmse:0.84379
# [88]	validation_0-rmse:0.75310	validation_1-rmse:0.84254
# [89]	validation_0-rmse:0.75147	validation_1-rmse:0.84117
# [90]	validation_0-rmse:0.74806	validation_1-rmse:0.84157
# [91]	validation_0-rmse:0.74527	validation_1-rmse:0.83633
# [92]	validation_0-rmse:0.74257	validation_1-rmse:0.83088
# [93]	validation_0-rmse:0.74162	validation_1-rmse:0.83148
# [94]	validation_0-rmse:0.74096	validation_1-rmse:0.82810
# [95]	validation_0-rmse:0.73532	validation_1-rmse:0.82618
# [96]	validation_0-rmse:0.73300	validation_1-rmse:0.82615
# [97]	validation_0-rmse:0.73171	validation_1-rmse:0.82970
# [98]	validation_0-rmse:0.72952	validation_1-rmse:0.82541
# [99]	validation_0-rmse:0.72612	validation_1-rmse:0.82576
# [100]	validation_0-rmse:0.72439	validation_1-rmse:0.82523
# [101]	validation_0-rmse:0.72324	validation_1-rmse:0.82426
# [102]	validation_0-rmse:0.72323	validation_1-rmse:0.82424
# [103]	validation_0-rmse:0.72206	validation_1-rmse:0.82695
# [104]	validation_0-rmse:0.71960	validation_1-rmse:0.82399
# [105]	validation_0-rmse:0.71731	validation_1-rmse:0.82765
# [106]	validation_0-rmse:0.71515	validation_1-rmse:0.82969
# [107]	validation_0-rmse:0.71235	validation_1-rmse:0.82587
# [108]	validation_0-rmse:0.71075	validation_1-rmse:0.82503
# [109]	validation_0-rmse:0.70940	validation_1-rmse:0.82448
# [110]	validation_0-rmse:0.70685	validation_1-rmse:0.82540
# [111]	validation_0-rmse:0.70546	validation_1-rmse:0.82790
# [112]	validation_0-rmse:0.70233	validation_1-rmse:0.82566
# [113]	validation_0-rmse:0.69935	validation_1-rmse:0.82458
# [114]	validation_0-rmse:0.69740	validation_1-rmse:0.82235
# [115]	validation_0-rmse:0.69555	validation_1-rmse:0.82480
# [116]	validation_0-rmse:0.69190	validation_1-rmse:0.82472
# [117]	validation_0-rmse:0.69001	validation_1-rmse:0.82726
# [118]	validation_0-rmse:0.68776	validation_1-rmse:0.82505
# [119]	validation_0-rmse:0.68726	validation_1-rmse:0.82595
# [120]	validation_0-rmse:0.68370	validation_1-rmse:0.82571
# [121]	validation_0-rmse:0.68215	validation_1-rmse:0.82316
# [122]	validation_0-rmse:0.68150	validation_1-rmse:0.82209
# [123]	validation_0-rmse:0.67814	validation_1-rmse:0.82455
# [124]	validation_0-rmse:0.67583	validation_1-rmse:0.82310
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 99.735, median: 104.0,
#  pred. interval (P(0.025)-P(0.975)): 63.0-124.0,
#  conf. interval (p-value=0.95): 92.146-111.419
# ***
# Aggregate bias statistic:
#  mean: -1.803, median: -1.65,
#  pred. interval (P(0.025)-P(0.975)): -9.907-5.242,
#  conf. interval (p-value=0.95): -3.496-0.121
# ***
# Aggregate RMSE statistic:
#  mean: 1.002, median: 1.005, pred. interval (P(0.025)-P(0.975)): 0.73-1.242,
#  conf. interval (p-value=0.95): 0.944-1.059
# ***
# Aggregate MSE statistic:
#  mean: 1.023, median: 1.011, pred. interval (P(0.025)-P(0.975)): 0.532-1.542,
#  conf. interval (p-value=0.95): 0.896-1.125
# ***
# Aggregate R^2 statistic:
#  mean: 0.572, median: 0.592, pred. interval (P(0.025)-P(0.975)): 0.048-0.802,
#  conf. interval (p-value=0.95): 0.528-0.65
# ***
# Aggregate bias(%) statistic:
#  mean: -0.243, median: -1.65, pred. interval (P(0.025)-P(0.975)): -1.325-0.833,
#  conf. interval (p-value=0.95): -0.497-0.019
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.143, median: 0.144, pred. interval (P(0.025)-P(0.975)): 0.098-0.187,
#  conf. interval (p-value=0.95): 0.134-0.152
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:6.44343
# [1]	validation_0-rmse:6.15729
# [2]	validation_0-rmse:5.88313
# [3]	validation_0-rmse:5.63401
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:5.39570
# [5]	validation_0-rmse:5.16145
# [6]	validation_0-rmse:4.94512
# [7]	validation_0-rmse:4.73580
# [8]	validation_0-rmse:4.53614
# [9]	validation_0-rmse:4.34605
# [10]	validation_0-rmse:4.14875
# [11]	validation_0-rmse:3.98343
# [12]	validation_0-rmse:3.81627
# [13]	validation_0-rmse:3.65920
# [14]	validation_0-rmse:3.51691
# [15]	validation_0-rmse:3.38093
# [16]	validation_0-rmse:3.23580
# [17]	validation_0-rmse:3.09623
# [18]	validation_0-rmse:2.96535
# [19]	validation_0-rmse:2.85211
# [20]	validation_0-rmse:2.74315
# [21]	validation_0-rmse:2.64493
# [22]	validation_0-rmse:2.54381
# [23]	validation_0-rmse:2.44432
# [24]	validation_0-rmse:2.35571
# [25]	validation_0-rmse:2.26210
# [26]	validation_0-rmse:2.18047
# [27]	validation_0-rmse:2.09735
# [28]	validation_0-rmse:2.02378
# [29]	validation_0-rmse:1.95036
# [30]	validation_0-rmse:1.87743
# [31]	validation_0-rmse:1.80674
# [32]	validation_0-rmse:1.74255
# [33]	validation_0-rmse:1.68379
# [34]	validation_0-rmse:1.62750
# [35]	validation_0-rmse:1.57570
# [36]	validation_0-rmse:1.52823
# [37]	validation_0-rmse:1.48134
# [38]	validation_0-rmse:1.43350
# [39]	validation_0-rmse:1.38840
# [40]	validation_0-rmse:1.35060
# [41]	validation_0-rmse:1.31335
# [42]	validation_0-rmse:1.27640
# [43]	validation_0-rmse:1.24309
# [44]	validation_0-rmse:1.21513
# [45]	validation_0-rmse:1.18559
# [46]	validation_0-rmse:1.15496
# [47]	validation_0-rmse:1.12771
# [48]	validation_0-rmse:1.10356
# [49]	validation_0-rmse:1.08957
# [50]	validation_0-rmse:1.07256
# [51]	validation_0-rmse:1.05068
# [52]	validation_0-rmse:1.03228
# [53]	validation_0-rmse:1.01373
# [54]	validation_0-rmse:0.99900
# [55]	validation_0-rmse:0.98265
# [56]	validation_0-rmse:0.96579
# [57]	validation_0-rmse:0.95105
# [58]	validation_0-rmse:0.93523
# [59]	validation_0-rmse:0.92409
# [60]	validation_0-rmse:0.91345
# [61]	validation_0-rmse:0.90458
# [62]	validation_0-rmse:0.89474
# [63]	validation_0-rmse:0.88369
# [64]	validation_0-rmse:0.87285
# [65]	validation_0-rmse:0.86500
# [66]	validation_0-rmse:0.85927
# [67]	validation_0-rmse:0.85265
# [68]	validation_0-rmse:0.84499
# [69]	validation_0-rmse:0.83667
# [70]	validation_0-rmse:0.83085
# [71]	validation_0-rmse:0.82594
# [72]	validation_0-rmse:0.81812
# [73]	validation_0-rmse:0.81243
# [74]	validation_0-rmse:0.80804
# [75]	validation_0-rmse:0.80330
# [76]	validation_0-rmse:0.79892
# [77]	validation_0-rmse:0.79130
# [78]	validation_0-rmse:0.78656
# [79]	validation_0-rmse:0.78319
# [80]	validation_0-rmse:0.78027
# [81]	validation_0-rmse:0.77595
# [82]	validation_0-rmse:0.76931
# [83]	validation_0-rmse:0.76722
# [84]	validation_0-rmse:0.76437
# [85]	validation_0-rmse:0.76129
# [86]	validation_0-rmse:0.75757
# [87]	validation_0-rmse:0.75564
# [88]	validation_0-rmse:0.75502
# [89]	validation_0-rmse:0.75208
# [90]	validation_0-rmse:0.74954
# [91]	validation_0-rmse:0.74581
# [92]	validation_0-rmse:0.74324
# [93]	validation_0-rmse:0.74052
# [94]	validation_0-rmse:0.73873
# [95]	validation_0-rmse:0.73722
# [96]	validation_0-rmse:0.73532
# [97]	validation_0-rmse:0.73370
# [98]	validation_0-rmse:0.72950
# [99]	validation_0-rmse:0.72801
# [100]	validation_0-rmse:0.72731
# [101]	validation_0-rmse:0.72625
# [102]	validation_0-rmse:0.72455
# [103]	validation_0-rmse:0.72321
# [104]	validation_0-rmse:0.72172
# [105]	validation_0-rmse:0.72125
# [106]	validation_0-rmse:0.71927
# [107]	validation_0-rmse:0.71841
# [108]	validation_0-rmse:0.71526
# [109]	validation_0-rmse:0.71394
# [110]	validation_0-rmse:0.71194
# [111]	validation_0-rmse:0.71045
# [112]	validation_0-rmse:0.70603
# [113]	validation_0-rmse:0.70341
# [114]	validation_0-rmse:0.70237
# [115]	validation_0-rmse:0.70093
# [116]	validation_0-rmse:0.69693
# [117]	validation_0-rmse:0.69388
# [118]	validation_0-rmse:0.69179
# [119]	validation_0-rmse:0.69047
# [120]	validation_0-rmse:0.68967
# [121]	validation_0-rmse:0.68853
# [122]	validation_0-rmse:0.68673
# [123]	validation_0-rmse:0.68390
# [124]	validation_0-rmse:0.68140
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 124

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.37
# RMSE: 0.7
# Relative RMSE(%):  0.097
# MSE: 0.5
# R square: 82.8%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 1.688
# a1: 0.757
# R^2: 0.835
# Uncertainty
# a0: 1.69+/-0.24
# a1: 0.757+/-0.033

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Cs_XGB_model_AERD&texture.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Cs_XGB_model_AERD&texture.txt")
