# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../05_input_data/Sites_with_Sentinel_bands_data_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input_2019')
df.head()
# Out:
#   Site # Origin Dominant_s  LN_GS_cub_m  LN_M_stem_kg_m2  \
# 0      1      n      Birch        4.771            1.792
# 1      2      a       Pine        5.808            2.496
# 2      3      a       Pine        5.796            2.546
# 3      4      a       Pine        5.826            2.643
# 4      5      a       Pine        6.059            2.643
#
#    LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  LN_M_foliage_kg_m2  LN_M_AG_kg_m2  \
# 0                -0.211            -0.261              -2.040          1.932
# 1                -0.073             0.392              -0.139          2.674
# 2                 0.030             0.501              -0.030          2.734
# 3                 0.000             0.419              -0.431          2.785
# 4                 0.122             0.647              -0.386          2.809
#
#         X_N36  ...  r2019B03  r2019B04  r2019B05  r2019B06  r2019B07  \
# 0  298987.203  ...  0.030628  0.266210  0.166299  0.081316  0.793351
# 1  299016.572  ...  0.027934  0.183349  0.102656  0.052144  0.735493
# 2  299072.773  ...  0.026123  0.184066  0.099625  0.050684  0.751436
# 3  299152.693  ...  0.027390  0.177221  0.102540  0.052198  0.732404
# 4  299249.689  ...  0.025702  0.183705  0.101394  0.050437  0.754481
#
#    r2019B08  r2019B09   r2019B10   r2019B11  r2019B12
# 0 -0.733693  0.532051 -15.396488 -11.262037  0.731937
# 1 -0.655456  0.557000 -16.012156  -9.364664  0.584920
# 2 -0.650575  0.568148 -13.609903  -9.726108  0.715177
# 3 -0.648310  0.544717 -14.321650 -10.457536  0.730390
# 4 -0.660382  0.569112 -13.934375 -11.393335  0.817430
#
# [5 rows x 34 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Site #', 'Origin', 'Dominant_s', 'LN_GS_cub_m', 'LN_M_stem_kg_m2', 'LN_M_stem_bark_kg_m2', 'LN_M_crown_kg_m2', 'LN_M_foliage_kg_m2', 'LN_M_AG_kg_m2', 'F_Soil', 'M_Soil', 'X_N36', 'Y_N36', 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'LN_Cs_wood', 'LN_Sr_wood', 'Tag_Cs', 'Tag_Sr', 'LN_Tag_Cs', 'LN_Tag_Sr', 'Cs_2021_kB', 'Sr_2021_kB', 'AEDR_mean', 'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['LN_Tag_Cs', 'LN_Tag_Sr',
                                  'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'])

# Show the first five columns
select.head()
# Out:
#    LN_Tag_Cs  LN_Tag_Sr  r2019B01  r2019B02  r2019B03  r2019B04  r2019B05  \
# 0  -0.898746   2.141524  0.025483  0.040910  0.030628  0.266210  0.166299
# 1   0.287682   2.549180  0.024075  0.038164  0.027934  0.183349  0.102656
# 2   0.556181   2.344549  0.022492  0.038968  0.026123  0.184066  0.099625
# 3   0.313350   2.455424  0.023742  0.037811  0.027390  0.177221  0.102540
# 4  -0.087011   2.821710  0.022916  0.037557  0.025702  0.183705  0.101394
#
#    r2019B06  r2019B07  r2019B08  r2019B09   r2019B10   r2019B11  r2019B12
# 0  0.081316  0.793351 -0.733693  0.532051 -15.396488 -11.262037  0.731937
# 1  0.052144  0.735493 -0.655456  0.557000 -16.012156  -9.364664  0.584920
# 2  0.050684  0.751436 -0.650575  0.568148 -13.609903  -9.726108  0.715177
# 3  0.052198  0.732404 -0.648310  0.544717 -14.321650 -10.457536  0.730390
# 4  0.050437  0.754481 -0.660382  0.569112 -13.934375 -11.393335  0.817430

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LN_Tag_Cs  205 non-null    float64
#  1   LN_Tag_Sr  205 non-null    float64
#  2   r2019B01   205 non-null    float64
#  3   r2019B02   205 non-null    float64
#  4   r2019B03   205 non-null    float64
#  5   r2019B04   205 non-null    float64
#  6   r2019B05   205 non-null    float64
#  7   r2019B06   205 non-null    float64
#  8   r2019B07   205 non-null    float64
#  9   r2019B08   205 non-null    float64
#  10  r2019B09   205 non-null    float64
#  11  r2019B10   205 non-null    float64
#  12  r2019B11   205 non-null    float64
#  13  r2019B12   205 non-null    float64
# dtypes: float64(14)
# memory usage: 22.5 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_s"])["LN_Tag_Cs", "LN_Tag_Sr"].describe()
# Out:
#            LN_Tag_Cs                                                    \
#                count      mean       std       min       25%       50%
# Dominant_s
# Alder           13.0 -1.185909  1.201457 -2.903562 -2.230264 -1.122877
# Aspen            7.0 -1.023735  1.633734 -2.965427 -2.103570 -1.369487
# Birch           45.0 -1.040653  1.021197 -4.379730 -1.265666 -0.847298
# Oak              9.0 -0.562587  1.857761 -4.704870 -1.098612  0.115513
# Pine           130.0 -0.471626  1.250166 -4.005355 -1.136277 -0.205292
# Spruce           1.0 -2.409639       NaN -2.409639 -2.409639 -2.409639
#
#                                LN_Tag_Sr                                \
#                  75%       max     count      mean       std       min
# Dominant_s
# Alder      -0.498161  0.853490      13.0  1.149722  0.672975 -0.167054
# Aspen      -0.088089  1.552087       7.0  2.321064  0.727889  1.396245
# Birch      -0.459154  0.439951      45.0  2.415305  0.869843  0.182322
# Oak         0.663547  1.338048       9.0  1.544409  0.935054  0.549108
# Pine        0.420004  1.645806     130.0  2.329967  0.993133 -0.784714
# Spruce     -2.409639 -2.409639       1.0  1.817077       NaN  1.817077
#
#
#                  25%       50%       75%       max
# Dominant_s
# Alder       0.672094  1.346020  1.543687  2.133509
# Aspen       1.973656  2.071837  2.717515  3.397022
# Birch       1.891843  2.506529  2.687847  5.227895
# Oak         0.753772  1.568616  1.923050  3.342567
# Pine        1.690423  2.400414  3.098610  4.820282
# Spruce      1.817077  1.817077  1.817077  1.817077

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#         LN_Tag_Cs   LN_Tag_Sr    r2019B01    r2019B02    r2019B03    r2019B04  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean    -0.674130    2.236561    0.023623    0.038592    0.028895    0.219361
# std      1.266477    0.986675    0.006540    0.007341    0.010704    0.049137
# min     -4.704870   -0.784714    0.014194    0.026402    0.015301    0.140309
# 25%     -1.435085    1.568616    0.019895    0.034516    0.022685    0.183403
# 50%     -0.545366    2.275067    0.022415    0.036966    0.026123    0.199665
# 75%      0.288154    2.921624    0.025339    0.040237    0.030628    0.250913
# max      1.645806    5.227895    0.059051    0.077038    0.081675    0.423326
#
#          r2019B05    r2019B06    r2019B07    r2019B08    r2019B09    r2019B10  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.131344    0.068068    0.759654   -0.692408    0.526662  -15.737088
# std      0.036023    0.026479    0.091469    0.070703    0.144729    1.547144
# min      0.078918    0.035914    0.363395   -0.849155   -0.037478  -22.820204
# 25%      0.102471    0.051182    0.727961   -0.735660    0.470852  -16.494671
# 50%      0.121704    0.060839    0.771691   -0.693779    0.562326  -15.454248
# 75%      0.153232    0.078586    0.814177   -0.660039    0.626609  -14.760403
# max      0.252487    0.196544    0.914709   -0.389420    0.740912  -12.365163
#
#          r2019B11    r2019B12
# count  205.000000  205.000000
# mean   -10.490763    0.668847
# std      1.471517    0.081010
# min    -16.820473    0.386847
# 25%    -11.364958    0.615553
# 50%    -10.299303    0.666882
# 75%     -9.547850    0.728737
# max     -5.703308    0.877743

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "LN_Tag_Cs"
indep_variables = ['r2019B01', 'r2019B04', 'r2019B08', 'r2019B10', 'r2019B11']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      LN_Tag_Cs  LN_Tag_Sr  r2019B01  r2019B02  r2019B03  r2019B04  r2019B05  \
# 0    -0.898746   2.141524  0.025483  0.040910  0.030628  0.266210  0.166299
# 1     0.287682   2.549180  0.024075  0.038164  0.027934  0.183349  0.102656
# 2     0.556181   2.344549  0.022492  0.038968  0.026123  0.184066  0.099625
# 3     0.313350   2.455424  0.023742  0.037811  0.027390  0.177221  0.102540
# 4    -0.087011   2.821710  0.022916  0.037557  0.025702  0.183705  0.101394
# ..         ...        ...       ...       ...       ...       ...       ...
# 200  -0.427127   1.648659  0.021045  0.035508  0.026143  0.199300  0.095774
# 201  -0.235870   2.466215  0.019699  0.034608  0.022056  0.208607  0.097603
# 202   0.196182   1.677646  0.020443  0.036471  0.027264  0.177812  0.105252
# 203   1.559113   1.897120  0.020905  0.037477  0.024510  0.213548  0.117474
# 204  -0.924323   1.799665  0.020603  0.035681  0.024394  0.196295  0.093705
#
#      r2019B06  r2019B07  r2019B08  r2019B09   r2019B10   r2019B11  r2019B12
# 0    0.081316  0.793351 -0.733693  0.532051 -15.396488 -11.262037  0.731937
# 1    0.052144  0.735493 -0.655456  0.557000 -16.012156  -9.364664  0.584920
# 2    0.050684  0.751436 -0.650575  0.568148 -13.609903  -9.726108  0.715177
# 3    0.052198  0.732404 -0.648310  0.544717 -14.321650 -10.457536  0.730390
# 4    0.050437  0.754481 -0.660382  0.569112 -13.934375 -11.393335  0.817430
# ..        ...       ...       ...       ...        ...        ...       ...
# 200  0.045219  0.768490 -0.697576  0.629676 -14.238754  -8.134297  0.571699
# 201  0.044494  0.808730 -0.715291  0.648211 -12.803756 -11.046638  0.862806
# 202  0.054239  0.733975 -0.659608  0.532328 -16.458857 -10.048693  0.610619
# 203  0.055805  0.794069 -0.701348  0.585421 -13.451569 -10.497206  0.785254
# 204  0.046686  0.778950 -0.692400  0.615253 -13.836473 -10.086078  0.729378
#
# [205 rows x 14 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    r2019B01  r2019B04  r2019B08   r2019B10   r2019B11
# 0  0.025483  0.266210 -0.733693 -15.396488 -11.262037
# 1  0.024075  0.183349 -0.655456 -16.012156  -9.364664
# 2  0.022492  0.184066 -0.650575 -13.609903  -9.726108
# 3  0.023742  0.177221 -0.648310 -14.321650 -10.457536
# 4  0.022916  0.183705 -0.660382 -13.934375 -11.393335

# %%
# Columns in "y" data collections
y.head()
# Out:
#    LN_Tag_Cs
# 0  -0.898746
# 1   0.287682
# 2   0.556181
# 3   0.313350
# 4  -0.087011

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.08017426250304693, 0.17703326070229009, 0.10343361600852241]
#     Mean: 0.120
#     Std: 0.041
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.19162985 0.93996982 1.21818035]
#     Mean: 1.117
#     Std: 0.125
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.7577053096778843, 0.8119757707847906, 0.9908043163858281]
#     Mean: 0.853
#     Std: 0.100
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.752002626894473                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.11989669723875046                # gamma
print('Gamma: ' + str(p2))

p3 = 0.03080239065859549                # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 3                                  # max_depth
print('Max_depth: ' + str(p4))

p5 = 104                                # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.6466036483851302                 # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.752002626894473
# Gamma: 0.11989669723875046
# Learning_rate: 0.03080239065859549
# Max_depth: 3
# N_estimators: 104
# Subsample: 0.6466036483851302

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.74957	validation_1-rmse:1.43594
# [1]	validation_0-rmse:1.71712	validation_1-rmse:1.40146
# [2]	validation_0-rmse:1.68084	validation_1-rmse:1.37122
# [3]	validation_0-rmse:1.65040	validation_1-rmse:1.34438
# [4]	validation_0-rmse:1.61745	validation_1-rmse:1.31182
# [5]	validation_0-rmse:1.58701	validation_1-rmse:1.28347
# [6]	validation_0-rmse:1.55736	validation_1-rmse:1.25334
# [7]	validation_0-rmse:1.52802	validation_1-rmse:1.22686
# [8]	validation_0-rmse:1.49994	validation_1-rmse:1.20049
# [9]	validation_0-rmse:1.47562	validation_1-rmse:1.17483
# [10]	validation_0-rmse:1.45176	validation_1-rmse:1.15339
# [11]	validation_0-rmse:1.42613	validation_1-rmse:1.13515
# [12]	validation_0-rmse:1.40504	validation_1-rmse:1.11941
# [13]	validation_0-rmse:1.38844	validation_1-rmse:1.10584
# [14]	validation_0-rmse:1.36834	validation_1-rmse:1.08801
# [15]	validation_0-rmse:1.34618	validation_1-rmse:1.06872
# [16]	validation_0-rmse:1.32408	validation_1-rmse:1.05147
# [17]	validation_0-rmse:1.30761	validation_1-rmse:1.03769
# [18]	validation_0-rmse:1.28753	validation_1-rmse:1.01424
# [19]	validation_0-rmse:1.27067	validation_1-rmse:1.00163
# [20]	validation_0-rmse:1.24896	validation_1-rmse:0.98876
# [21]	validation_0-rmse:1.22896	validation_1-rmse:0.97823
# [22]	validation_0-rmse:1.21382	validation_1-rmse:0.96619
# [23]	validation_0-rmse:1.19683	validation_1-rmse:0.95053
# [24]	validation_0-rmse:1.18119	validation_1-rmse:0.94082
# [25]	validation_0-rmse:1.16686	validation_1-rmse:0.92933
# [26]	validation_0-rmse:1.15209	validation_1-rmse:0.91561
# [27]	validation_0-rmse:1.13670	validation_1-rmse:0.90956
# [28]	validation_0-rmse:1.12244	validation_1-rmse:0.89910
# [29]	validation_0-rmse:1.11048	validation_1-rmse:0.89027
# [30]	validation_0-rmse:1.09630	validation_1-rmse:0.88155
# [31]	validation_0-rmse:1.08615	validation_1-rmse:0.87615
# [32]	validation_0-rmse:1.07413	validation_1-rmse:0.86977
# [33]	validation_0-rmse:1.06132	validation_1-rmse:0.86440
# [34]	validation_0-rmse:1.04992	validation_1-rmse:0.85692
# [35]	validation_0-rmse:1.03728	validation_1-rmse:0.84884
# [36]	validation_0-rmse:1.02421	validation_1-rmse:0.84403
# [37]	validation_0-rmse:1.01575	validation_1-rmse:0.84113
# [38]	validation_0-rmse:1.00772	validation_1-rmse:0.83789
# [39]	validation_0-rmse:0.99633	validation_1-rmse:0.83394
# [40]	validation_0-rmse:0.98789	validation_1-rmse:0.82889
# [41]	validation_0-rmse:0.98137	validation_1-rmse:0.82622
# [42]	validation_0-rmse:0.97309	validation_1-rmse:0.82146
# [43]	validation_0-rmse:0.96225	validation_1-rmse:0.81616
# [44]	validation_0-rmse:0.95334	validation_1-rmse:0.81330
# [45]	validation_0-rmse:0.94588	validation_1-rmse:0.80824
# [46]	validation_0-rmse:0.93709	validation_1-rmse:0.80665
# [47]	validation_0-rmse:0.93023	validation_1-rmse:0.80568
# [48]	validation_0-rmse:0.92582	validation_1-rmse:0.80356
# [49]	validation_0-rmse:0.92163	validation_1-rmse:0.80314
# [50]	validation_0-rmse:0.91402	validation_1-rmse:0.79777
# [51]	validation_0-rmse:0.90803	validation_1-rmse:0.79632
# [52]	validation_0-rmse:0.90137	validation_1-rmse:0.79046
# [53]	validation_0-rmse:0.89569	validation_1-rmse:0.78966
# [54]	validation_0-rmse:0.88930	validation_1-rmse:0.78744
# [55]	validation_0-rmse:0.88201	validation_1-rmse:0.78677
# [56]	validation_0-rmse:0.87757	validation_1-rmse:0.78461
# [57]	validation_0-rmse:0.87138	validation_1-rmse:0.78433
# [58]	validation_0-rmse:0.86547	validation_1-rmse:0.78235
# [59]	validation_0-rmse:0.86054	validation_1-rmse:0.78126
# [60]	validation_0-rmse:0.85536	validation_1-rmse:0.78138
# [61]	validation_0-rmse:0.85005	validation_1-rmse:0.77883
# [62]	validation_0-rmse:0.84519	validation_1-rmse:0.77353
# [63]	validation_0-rmse:0.84165	validation_1-rmse:0.77684
# [64]	validation_0-rmse:0.83696	validation_1-rmse:0.77531
# [65]	validation_0-rmse:0.83093	validation_1-rmse:0.77350
# [66]	validation_0-rmse:0.82597	validation_1-rmse:0.77239
# [67]	validation_0-rmse:0.82057	validation_1-rmse:0.77285
# [68]	validation_0-rmse:0.81556	validation_1-rmse:0.77275
# [69]	validation_0-rmse:0.81189	validation_1-rmse:0.77247
# [70]	validation_0-rmse:0.80650	validation_1-rmse:0.77198
# [71]	validation_0-rmse:0.80330	validation_1-rmse:0.77080
# [72]	validation_0-rmse:0.79907	validation_1-rmse:0.77249
# [73]	validation_0-rmse:0.79509	validation_1-rmse:0.77161
# [74]	validation_0-rmse:0.79165	validation_1-rmse:0.77087
# [75]	validation_0-rmse:0.78867	validation_1-rmse:0.77123
# [76]	validation_0-rmse:0.78427	validation_1-rmse:0.77091
# [77]	validation_0-rmse:0.78164	validation_1-rmse:0.77040
# [78]	validation_0-rmse:0.77857	validation_1-rmse:0.77085
# [79]	validation_0-rmse:0.77598	validation_1-rmse:0.77119
# [80]	validation_0-rmse:0.77258	validation_1-rmse:0.77177
# [81]	validation_0-rmse:0.76959	validation_1-rmse:0.77217
# [82]	validation_0-rmse:0.76580	validation_1-rmse:0.77345
# [83]	validation_0-rmse:0.76289	validation_1-rmse:0.77386
# [84]	validation_0-rmse:0.75982	validation_1-rmse:0.77317
# [85]	validation_0-rmse:0.75732	validation_1-rmse:0.77201
# [86]	validation_0-rmse:0.75335	validation_1-rmse:0.77267
# [87]	validation_0-rmse:0.74941	validation_1-rmse:0.77220
# [88]	validation_0-rmse:0.74660	validation_1-rmse:0.77190
# [89]	validation_0-rmse:0.74466	validation_1-rmse:0.77287
# [90]	validation_0-rmse:0.74122	validation_1-rmse:0.77223
# [91]	validation_0-rmse:0.73852	validation_1-rmse:0.77036
# [92]	validation_0-rmse:0.73498	validation_1-rmse:0.77127
# [93]	validation_0-rmse:0.73318	validation_1-rmse:0.77157
# [94]	validation_0-rmse:0.73148	validation_1-rmse:0.77260
# [95]	validation_0-rmse:0.72790	validation_1-rmse:0.77153
# [96]	validation_0-rmse:0.72518	validation_1-rmse:0.77025
# [97]	validation_0-rmse:0.72136	validation_1-rmse:0.77087
# [98]	validation_0-rmse:0.72053	validation_1-rmse:0.77197
# [99]	validation_0-rmse:0.71794	validation_1-rmse:0.77468
# [100]	validation_0-rmse:0.71520	validation_1-rmse:0.77539
# [101]	validation_0-rmse:0.71250	validation_1-rmse:0.77432
# [102]	validation_0-rmse:0.71071	validation_1-rmse:0.77483
# [103]	validation_0-rmse:0.70816	validation_1-rmse:0.77477
# [0]	validation_0-rmse:1.63516	validation_1-rmse:1.89412
# [1]	validation_0-rmse:1.60189	validation_1-rmse:1.85852
# [2]	validation_0-rmse:1.56775	validation_1-rmse:1.82906
# [3]	validation_0-rmse:1.53820	validation_1-rmse:1.80067
# [4]	validation_0-rmse:1.50733	validation_1-rmse:1.77343
# [5]	validation_0-rmse:1.47603	validation_1-rmse:1.74088
# [6]	validation_0-rmse:1.45038	validation_1-rmse:1.71637
# [7]	validation_0-rmse:1.42292	validation_1-rmse:1.68982
# [8]	validation_0-rmse:1.39385	validation_1-rmse:1.66332
# [9]	validation_0-rmse:1.36888	validation_1-rmse:1.63577
# [10]	validation_0-rmse:1.34724	validation_1-rmse:1.61439
# [11]	validation_0-rmse:1.32306	validation_1-rmse:1.59629
# [12]	validation_0-rmse:1.30030	validation_1-rmse:1.57746
# [13]	validation_0-rmse:1.27993	validation_1-rmse:1.56085
# [14]	validation_0-rmse:1.26115	validation_1-rmse:1.54480
# [15]	validation_0-rmse:1.24387	validation_1-rmse:1.52956
# [16]	validation_0-rmse:1.22284	validation_1-rmse:1.51318
# [17]	validation_0-rmse:1.20384	validation_1-rmse:1.49920
# [18]	validation_0-rmse:1.18754	validation_1-rmse:1.48638
# [19]	validation_0-rmse:1.16971	validation_1-rmse:1.46583
# [20]	validation_0-rmse:1.15232	validation_1-rmse:1.45345
# [21]	validation_0-rmse:1.13880	validation_1-rmse:1.44356
# [22]	validation_0-rmse:1.12246	validation_1-rmse:1.42856
# [23]	validation_0-rmse:1.10654	validation_1-rmse:1.41788
# [24]	validation_0-rmse:1.09131	validation_1-rmse:1.40622
# [25]	validation_0-rmse:1.07846	validation_1-rmse:1.39275
# [26]	validation_0-rmse:1.06269	validation_1-rmse:1.38094
# [27]	validation_0-rmse:1.05031	validation_1-rmse:1.37207
# [28]	validation_0-rmse:1.03652	validation_1-rmse:1.36466
# [29]	validation_0-rmse:1.02345	validation_1-rmse:1.35697
# [30]	validation_0-rmse:1.01221	validation_1-rmse:1.35063
# [31]	validation_0-rmse:1.00067	validation_1-rmse:1.34058
# [32]	validation_0-rmse:0.98911	validation_1-rmse:1.33260
# [33]	validation_0-rmse:0.97802	validation_1-rmse:1.32326
# [34]	validation_0-rmse:0.96696	validation_1-rmse:1.31755
# [35]	validation_0-rmse:0.95953	validation_1-rmse:1.31269
# [36]	validation_0-rmse:0.95064	validation_1-rmse:1.30300
# [37]	validation_0-rmse:0.94262	validation_1-rmse:1.29563
# [38]	validation_0-rmse:0.93378	validation_1-rmse:1.29194
# [39]	validation_0-rmse:0.92433	validation_1-rmse:1.28470
# [40]	validation_0-rmse:0.91611	validation_1-rmse:1.27700
# [41]	validation_0-rmse:0.90843	validation_1-rmse:1.26941
# [42]	validation_0-rmse:0.90111	validation_1-rmse:1.26129
# [43]	validation_0-rmse:0.89378	validation_1-rmse:1.25752
# [44]	validation_0-rmse:0.88499	validation_1-rmse:1.25139
# [45]	validation_0-rmse:0.87834	validation_1-rmse:1.25112
# [46]	validation_0-rmse:0.86955	validation_1-rmse:1.24500
# [47]	validation_0-rmse:0.86422	validation_1-rmse:1.23987
# [48]	validation_0-rmse:0.85591	validation_1-rmse:1.23597
# [49]	validation_0-rmse:0.84860	validation_1-rmse:1.23367
# [50]	validation_0-rmse:0.84175	validation_1-rmse:1.23083
# [51]	validation_0-rmse:0.83670	validation_1-rmse:1.22719
# [52]	validation_0-rmse:0.83051	validation_1-rmse:1.22456
# [53]	validation_0-rmse:0.82418	validation_1-rmse:1.22344
# [54]	validation_0-rmse:0.81997	validation_1-rmse:1.22077
# [55]	validation_0-rmse:0.81337	validation_1-rmse:1.21382
# [56]	validation_0-rmse:0.80875	validation_1-rmse:1.20937
# [57]	validation_0-rmse:0.80186	validation_1-rmse:1.20488
# [58]	validation_0-rmse:0.79531	validation_1-rmse:1.20377
# [59]	validation_0-rmse:0.79054	validation_1-rmse:1.20305
# [60]	validation_0-rmse:0.78742	validation_1-rmse:1.20016
# [61]	validation_0-rmse:0.78437	validation_1-rmse:1.19855
# [62]	validation_0-rmse:0.77987	validation_1-rmse:1.19951
# [63]	validation_0-rmse:0.77507	validation_1-rmse:1.19626
# [64]	validation_0-rmse:0.77022	validation_1-rmse:1.19218
# [65]	validation_0-rmse:0.76634	validation_1-rmse:1.18942
# [66]	validation_0-rmse:0.76207	validation_1-rmse:1.18974
# [67]	validation_0-rmse:0.75731	validation_1-rmse:1.18856
# [68]	validation_0-rmse:0.75294	validation_1-rmse:1.18883
# [69]	validation_0-rmse:0.74813	validation_1-rmse:1.18760
# [70]	validation_0-rmse:0.74449	validation_1-rmse:1.18843
# [71]	validation_0-rmse:0.74055	validation_1-rmse:1.18887
# [72]	validation_0-rmse:0.73803	validation_1-rmse:1.18617
# [73]	validation_0-rmse:0.73374	validation_1-rmse:1.18453
# [74]	validation_0-rmse:0.73073	validation_1-rmse:1.18023
# [75]	validation_0-rmse:0.72704	validation_1-rmse:1.18163
# [76]	validation_0-rmse:0.72387	validation_1-rmse:1.17689
# [77]	validation_0-rmse:0.72273	validation_1-rmse:1.17678
# [78]	validation_0-rmse:0.72067	validation_1-rmse:1.17413
# [79]	validation_0-rmse:0.71920	validation_1-rmse:1.17519
# [80]	validation_0-rmse:0.71706	validation_1-rmse:1.17611
# [81]	validation_0-rmse:0.71333	validation_1-rmse:1.17510
# [82]	validation_0-rmse:0.71048	validation_1-rmse:1.17221
# [83]	validation_0-rmse:0.70758	validation_1-rmse:1.17094
# [84]	validation_0-rmse:0.70587	validation_1-rmse:1.17191
# [85]	validation_0-rmse:0.70260	validation_1-rmse:1.17273
# [86]	validation_0-rmse:0.69857	validation_1-rmse:1.17290
# [87]	validation_0-rmse:0.69512	validation_1-rmse:1.17420
# [88]	validation_0-rmse:0.69305	validation_1-rmse:1.17552
# [89]	validation_0-rmse:0.69021	validation_1-rmse:1.17565
# [90]	validation_0-rmse:0.68760	validation_1-rmse:1.17652
# [91]	validation_0-rmse:0.68503	validation_1-rmse:1.17583
# [92]	validation_0-rmse:0.68261	validation_1-rmse:1.17375
# [93]	validation_0-rmse:0.68055	validation_1-rmse:1.17442
# [94]	validation_0-rmse:0.67836	validation_1-rmse:1.17549
# [95]	validation_0-rmse:0.67629	validation_1-rmse:1.17608
# [96]	validation_0-rmse:0.67510	validation_1-rmse:1.17589
# [97]	validation_0-rmse:0.67195	validation_1-rmse:1.17662
# [98]	validation_0-rmse:0.67017	validation_1-rmse:1.17614
# [99]	validation_0-rmse:0.66756	validation_1-rmse:1.17695
# [100]	validation_0-rmse:0.66553	validation_1-rmse:1.17776
# [101]	validation_0-rmse:0.66291	validation_1-rmse:1.17514
# [102]	validation_0-rmse:0.66102	validation_1-rmse:1.17238
# [103]	validation_0-rmse:0.65902	validation_1-rmse:1.17388
# [0]	validation_0-rmse:1.72338	validation_1-rmse:1.53247
# [1]	validation_0-rmse:1.69175	validation_1-rmse:1.50252
# [2]	validation_0-rmse:1.65434	validation_1-rmse:1.46829
# [3]	validation_0-rmse:1.62562	validation_1-rmse:1.44361
# [4]	validation_0-rmse:1.59453	validation_1-rmse:1.41244
# [5]	validation_0-rmse:1.56226	validation_1-rmse:1.38340
# [6]	validation_0-rmse:1.53536	validation_1-rmse:1.36270
# [7]	validation_0-rmse:1.50753	validation_1-rmse:1.33729
# [8]	validation_0-rmse:1.47852	validation_1-rmse:1.30781
# [9]	validation_0-rmse:1.45829	validation_1-rmse:1.29284
# [10]	validation_0-rmse:1.43400	validation_1-rmse:1.27244
# [11]	validation_0-rmse:1.41381	validation_1-rmse:1.25349
# [12]	validation_0-rmse:1.39116	validation_1-rmse:1.23353
# [13]	validation_0-rmse:1.37107	validation_1-rmse:1.21606
# [14]	validation_0-rmse:1.34985	validation_1-rmse:1.19662
# [15]	validation_0-rmse:1.32745	validation_1-rmse:1.17752
# [16]	validation_0-rmse:1.30634	validation_1-rmse:1.16020
# [17]	validation_0-rmse:1.28901	validation_1-rmse:1.14766
# [18]	validation_0-rmse:1.26949	validation_1-rmse:1.13005
# [19]	validation_0-rmse:1.25148	validation_1-rmse:1.11735
# [20]	validation_0-rmse:1.23195	validation_1-rmse:1.10017
# [21]	validation_0-rmse:1.21358	validation_1-rmse:1.08682
# [22]	validation_0-rmse:1.19549	validation_1-rmse:1.07496
# [23]	validation_0-rmse:1.17889	validation_1-rmse:1.06349
# [24]	validation_0-rmse:1.16352	validation_1-rmse:1.04799
# [25]	validation_0-rmse:1.15010	validation_1-rmse:1.04139
# [26]	validation_0-rmse:1.13685	validation_1-rmse:1.03168
# [27]	validation_0-rmse:1.12024	validation_1-rmse:1.01876
# [28]	validation_0-rmse:1.10424	validation_1-rmse:1.00777
# [29]	validation_0-rmse:1.09125	validation_1-rmse:0.99768
# [30]	validation_0-rmse:1.07846	validation_1-rmse:0.98863
# [31]	validation_0-rmse:1.06748	validation_1-rmse:0.97953
# [32]	validation_0-rmse:1.05334	validation_1-rmse:0.97576
# [33]	validation_0-rmse:1.04086	validation_1-rmse:0.97078
# [34]	validation_0-rmse:1.03124	validation_1-rmse:0.96629
# [35]	validation_0-rmse:1.02140	validation_1-rmse:0.95892
# [36]	validation_0-rmse:1.00866	validation_1-rmse:0.95326
# [37]	validation_0-rmse:0.99743	validation_1-rmse:0.94506
# [38]	validation_0-rmse:0.98794	validation_1-rmse:0.94023
# [39]	validation_0-rmse:0.97723	validation_1-rmse:0.93726
# [40]	validation_0-rmse:0.96774	validation_1-rmse:0.93151
# [41]	validation_0-rmse:0.96188	validation_1-rmse:0.93395
# [42]	validation_0-rmse:0.95292	validation_1-rmse:0.92983
# [43]	validation_0-rmse:0.94372	validation_1-rmse:0.92569
# [44]	validation_0-rmse:0.93734	validation_1-rmse:0.92161
# [45]	validation_0-rmse:0.92938	validation_1-rmse:0.91973
# [46]	validation_0-rmse:0.92133	validation_1-rmse:0.91683
# [47]	validation_0-rmse:0.91549	validation_1-rmse:0.91488
# [48]	validation_0-rmse:0.90659	validation_1-rmse:0.91266
# [49]	validation_0-rmse:0.89895	validation_1-rmse:0.90729
# [50]	validation_0-rmse:0.88870	validation_1-rmse:0.90449
# [51]	validation_0-rmse:0.88193	validation_1-rmse:0.90291
# [52]	validation_0-rmse:0.87565	validation_1-rmse:0.90081
# [53]	validation_0-rmse:0.87016	validation_1-rmse:0.89871
# [54]	validation_0-rmse:0.86290	validation_1-rmse:0.89632
# [55]	validation_0-rmse:0.85708	validation_1-rmse:0.89308
# [56]	validation_0-rmse:0.85112	validation_1-rmse:0.89252
# [57]	validation_0-rmse:0.84623	validation_1-rmse:0.89305
# [58]	validation_0-rmse:0.84030	validation_1-rmse:0.89061
# [59]	validation_0-rmse:0.83460	validation_1-rmse:0.89100
# [60]	validation_0-rmse:0.83090	validation_1-rmse:0.88915
# [61]	validation_0-rmse:0.82473	validation_1-rmse:0.88784
# [62]	validation_0-rmse:0.81879	validation_1-rmse:0.88541
# [63]	validation_0-rmse:0.81333	validation_1-rmse:0.88404
# [64]	validation_0-rmse:0.80870	validation_1-rmse:0.88268
# [65]	validation_0-rmse:0.80369	validation_1-rmse:0.88537
# [66]	validation_0-rmse:0.79945	validation_1-rmse:0.88659
# [67]	validation_0-rmse:0.79456	validation_1-rmse:0.88583
# [68]	validation_0-rmse:0.79048	validation_1-rmse:0.88452
# [69]	validation_0-rmse:0.78680	validation_1-rmse:0.88445
# [70]	validation_0-rmse:0.78368	validation_1-rmse:0.88713
# [71]	validation_0-rmse:0.78055	validation_1-rmse:0.88694
# [72]	validation_0-rmse:0.77533	validation_1-rmse:0.88973
# [73]	validation_0-rmse:0.77271	validation_1-rmse:0.89019
# [74]	validation_0-rmse:0.76795	validation_1-rmse:0.88926
# [75]	validation_0-rmse:0.76359	validation_1-rmse:0.89048
# [76]	validation_0-rmse:0.75969	validation_1-rmse:0.89093
# [77]	validation_0-rmse:0.75578	validation_1-rmse:0.89017
# [78]	validation_0-rmse:0.75196	validation_1-rmse:0.88955
# [79]	validation_0-rmse:0.74982	validation_1-rmse:0.89066
# [80]	validation_0-rmse:0.74667	validation_1-rmse:0.89174
# [81]	validation_0-rmse:0.74336	validation_1-rmse:0.89635
# [82]	validation_0-rmse:0.74033	validation_1-rmse:0.89825
# [83]	validation_0-rmse:0.73735	validation_1-rmse:0.90064
# [84]	validation_0-rmse:0.73473	validation_1-rmse:0.90164
# [0]	validation_0-rmse:1.66085	validation_1-rmse:1.79420
# [1]	validation_0-rmse:1.62315	validation_1-rmse:1.76323
# [2]	validation_0-rmse:1.59398	validation_1-rmse:1.73512
# [3]	validation_0-rmse:1.56301	validation_1-rmse:1.70744
# [4]	validation_0-rmse:1.53233	validation_1-rmse:1.68327
# [5]	validation_0-rmse:1.50598	validation_1-rmse:1.65924
# [6]	validation_0-rmse:1.47995	validation_1-rmse:1.63797
# [7]	validation_0-rmse:1.45436	validation_1-rmse:1.61462
# [8]	validation_0-rmse:1.42773	validation_1-rmse:1.59437
# [9]	validation_0-rmse:1.40530	validation_1-rmse:1.58172
# [10]	validation_0-rmse:1.38234	validation_1-rmse:1.56849
# [11]	validation_0-rmse:1.35891	validation_1-rmse:1.54631
# [12]	validation_0-rmse:1.33683	validation_1-rmse:1.53257
# [13]	validation_0-rmse:1.31321	validation_1-rmse:1.52047
# [14]	validation_0-rmse:1.29314	validation_1-rmse:1.50843
# [15]	validation_0-rmse:1.27312	validation_1-rmse:1.49204
# [16]	validation_0-rmse:1.25335	validation_1-rmse:1.47385
# [17]	validation_0-rmse:1.23627	validation_1-rmse:1.46195
# [18]	validation_0-rmse:1.21846	validation_1-rmse:1.45383
# [19]	validation_0-rmse:1.20183	validation_1-rmse:1.43805
# [20]	validation_0-rmse:1.18518	validation_1-rmse:1.42439
# [21]	validation_0-rmse:1.17036	validation_1-rmse:1.41643
# [22]	validation_0-rmse:1.15439	validation_1-rmse:1.40399
# [23]	validation_0-rmse:1.13984	validation_1-rmse:1.39055
# [24]	validation_0-rmse:1.12481	validation_1-rmse:1.38200
# [25]	validation_0-rmse:1.11433	validation_1-rmse:1.37317
# [26]	validation_0-rmse:1.09880	validation_1-rmse:1.36660
# [27]	validation_0-rmse:1.08337	validation_1-rmse:1.35785
# [28]	validation_0-rmse:1.06772	validation_1-rmse:1.34118
# [29]	validation_0-rmse:1.05722	validation_1-rmse:1.33642
# [30]	validation_0-rmse:1.04487	validation_1-rmse:1.33087
# [31]	validation_0-rmse:1.03239	validation_1-rmse:1.32873
# [32]	validation_0-rmse:1.01866	validation_1-rmse:1.31920
# [33]	validation_0-rmse:1.00817	validation_1-rmse:1.31215
# [34]	validation_0-rmse:0.99742	validation_1-rmse:1.30057
# [35]	validation_0-rmse:0.98725	validation_1-rmse:1.29414
# [36]	validation_0-rmse:0.97662	validation_1-rmse:1.28804
# [37]	validation_0-rmse:0.96734	validation_1-rmse:1.28172
# [38]	validation_0-rmse:0.95913	validation_1-rmse:1.27377
# [39]	validation_0-rmse:0.95001	validation_1-rmse:1.26851
# [40]	validation_0-rmse:0.94032	validation_1-rmse:1.26336
# [41]	validation_0-rmse:0.93056	validation_1-rmse:1.26432
# [42]	validation_0-rmse:0.92125	validation_1-rmse:1.25955
# [43]	validation_0-rmse:0.91161	validation_1-rmse:1.25136
# [44]	validation_0-rmse:0.90441	validation_1-rmse:1.24784
# [45]	validation_0-rmse:0.89717	validation_1-rmse:1.24198
# [46]	validation_0-rmse:0.88977	validation_1-rmse:1.23791
# [47]	validation_0-rmse:0.88351	validation_1-rmse:1.23174
# [48]	validation_0-rmse:0.87636	validation_1-rmse:1.22856
# [49]	validation_0-rmse:0.86946	validation_1-rmse:1.22435
# [50]	validation_0-rmse:0.86278	validation_1-rmse:1.21647
# [51]	validation_0-rmse:0.85536	validation_1-rmse:1.21517
# [52]	validation_0-rmse:0.84781	validation_1-rmse:1.20688
# [53]	validation_0-rmse:0.84265	validation_1-rmse:1.20545
# [54]	validation_0-rmse:0.83761	validation_1-rmse:1.20265
# [55]	validation_0-rmse:0.83157	validation_1-rmse:1.19776
# [56]	validation_0-rmse:0.82667	validation_1-rmse:1.19557
# [57]	validation_0-rmse:0.81926	validation_1-rmse:1.19163
# [58]	validation_0-rmse:0.81372	validation_1-rmse:1.18761
# [59]	validation_0-rmse:0.80816	validation_1-rmse:1.18015
# [60]	validation_0-rmse:0.80381	validation_1-rmse:1.18212
# [61]	validation_0-rmse:0.79911	validation_1-rmse:1.18215
# [62]	validation_0-rmse:0.79418	validation_1-rmse:1.18004
# [63]	validation_0-rmse:0.78878	validation_1-rmse:1.17837
# [64]	validation_0-rmse:0.78420	validation_1-rmse:1.18095
# [65]	validation_0-rmse:0.78187	validation_1-rmse:1.18804
# [66]	validation_0-rmse:0.77716	validation_1-rmse:1.18465
# [67]	validation_0-rmse:0.77287	validation_1-rmse:1.17754
# [68]	validation_0-rmse:0.76914	validation_1-rmse:1.17227
# [69]	validation_0-rmse:0.76654	validation_1-rmse:1.16886
# [70]	validation_0-rmse:0.76318	validation_1-rmse:1.16959
# [71]	validation_0-rmse:0.75834	validation_1-rmse:1.16743
# [72]	validation_0-rmse:0.75361	validation_1-rmse:1.16740
# [73]	validation_0-rmse:0.74997	validation_1-rmse:1.16105
# [74]	validation_0-rmse:0.74652	validation_1-rmse:1.16220
# [75]	validation_0-rmse:0.74318	validation_1-rmse:1.15998
# [76]	validation_0-rmse:0.73944	validation_1-rmse:1.15906
# [77]	validation_0-rmse:0.73607	validation_1-rmse:1.16213
# [78]	validation_0-rmse:0.73292	validation_1-rmse:1.15960
# [79]	validation_0-rmse:0.72990	validation_1-rmse:1.16078
# [80]	validation_0-rmse:0.72672	validation_1-rmse:1.16037
# [81]	validation_0-rmse:0.72272	validation_1-rmse:1.16050
# [82]	validation_0-rmse:0.72001	validation_1-rmse:1.15755
# [83]	validation_0-rmse:0.71625	validation_1-rmse:1.15871
# [84]	validation_0-rmse:0.71363	validation_1-rmse:1.15673
# [85]	validation_0-rmse:0.71006	validation_1-rmse:1.15579
# [86]	validation_0-rmse:0.70639	validation_1-rmse:1.15157
# [87]	validation_0-rmse:0.70439	validation_1-rmse:1.14883
# [88]	validation_0-rmse:0.70082	validation_1-rmse:1.14740
# [89]	validation_0-rmse:0.69737	validation_1-rmse:1.14904
# [90]	validation_0-rmse:0.69585	validation_1-rmse:1.14832
# [91]	validation_0-rmse:0.69335	validation_1-rmse:1.14783
# [92]	validation_0-rmse:0.69117	validation_1-rmse:1.14732
# [93]	validation_0-rmse:0.68928	validation_1-rmse:1.14750
# [94]	validation_0-rmse:0.68804	validation_1-rmse:1.14665
# [95]	validation_0-rmse:0.68536	validation_1-rmse:1.14363
# [96]	validation_0-rmse:0.68397	validation_1-rmse:1.14395
# [97]	validation_0-rmse:0.68164	validation_1-rmse:1.14349
# [98]	validation_0-rmse:0.67966	validation_1-rmse:1.14335
# [99]	validation_0-rmse:0.67673	validation_1-rmse:1.14396
# [100]	validation_0-rmse:0.67529	validation_1-rmse:1.14132
# [101]	validation_0-rmse:0.67388	validation_1-rmse:1.14361
# [102]	validation_0-rmse:0.67092	validation_1-rmse:1.14349
# [103]	validation_0-rmse:0.66887	validation_1-rmse:1.14178
# [0]	validation_0-rmse:1.72618	validation_1-rmse:1.53727
# [1]	validation_0-rmse:1.69388	validation_1-rmse:1.50266
# [2]	validation_0-rmse:1.65816	validation_1-rmse:1.46441
# [3]	validation_0-rmse:1.63024	validation_1-rmse:1.43501
# [4]	validation_0-rmse:1.60469	validation_1-rmse:1.40799
# [5]	validation_0-rmse:1.57616	validation_1-rmse:1.37284
# [6]	validation_0-rmse:1.55175	validation_1-rmse:1.35252
# [7]	validation_0-rmse:1.52239	validation_1-rmse:1.32186
# [8]	validation_0-rmse:1.49671	validation_1-rmse:1.29994
# [9]	validation_0-rmse:1.47223	validation_1-rmse:1.27291
# [10]	validation_0-rmse:1.44719	validation_1-rmse:1.24572
# [11]	validation_0-rmse:1.42487	validation_1-rmse:1.22383
# [12]	validation_0-rmse:1.40272	validation_1-rmse:1.19772
# [13]	validation_0-rmse:1.38118	validation_1-rmse:1.17628
# [14]	validation_0-rmse:1.36021	validation_1-rmse:1.15425
# [15]	validation_0-rmse:1.33860	validation_1-rmse:1.13146
# [16]	validation_0-rmse:1.31660	validation_1-rmse:1.10819
# [17]	validation_0-rmse:1.29820	validation_1-rmse:1.09345
# [18]	validation_0-rmse:1.28082	validation_1-rmse:1.07745
# [19]	validation_0-rmse:1.26487	validation_1-rmse:1.06231
# [20]	validation_0-rmse:1.24941	validation_1-rmse:1.05263
# [21]	validation_0-rmse:1.23213	validation_1-rmse:1.03290
# [22]	validation_0-rmse:1.21476	validation_1-rmse:1.01709
# [23]	validation_0-rmse:1.19629	validation_1-rmse:1.00427
# [24]	validation_0-rmse:1.17938	validation_1-rmse:0.99097
# [25]	validation_0-rmse:1.16287	validation_1-rmse:0.97800
# [26]	validation_0-rmse:1.14834	validation_1-rmse:0.96338
# [27]	validation_0-rmse:1.13324	validation_1-rmse:0.94936
# [28]	validation_0-rmse:1.11954	validation_1-rmse:0.93180
# [29]	validation_0-rmse:1.10555	validation_1-rmse:0.91430
# [30]	validation_0-rmse:1.09360	validation_1-rmse:0.90654
# [31]	validation_0-rmse:1.08180	validation_1-rmse:0.89690
# [32]	validation_0-rmse:1.06987	validation_1-rmse:0.88547
# [33]	validation_0-rmse:1.05737	validation_1-rmse:0.87595
# [34]	validation_0-rmse:1.04829	validation_1-rmse:0.86927
# [35]	validation_0-rmse:1.03541	validation_1-rmse:0.85906
# [36]	validation_0-rmse:1.02474	validation_1-rmse:0.85094
# [37]	validation_0-rmse:1.01502	validation_1-rmse:0.84510
# [38]	validation_0-rmse:1.00676	validation_1-rmse:0.84140
# [39]	validation_0-rmse:0.99736	validation_1-rmse:0.83639
# [40]	validation_0-rmse:0.99021	validation_1-rmse:0.83447
# [41]	validation_0-rmse:0.98117	validation_1-rmse:0.83110
# [42]	validation_0-rmse:0.97316	validation_1-rmse:0.82942
# [43]	validation_0-rmse:0.96421	validation_1-rmse:0.82171
# [44]	validation_0-rmse:0.95517	validation_1-rmse:0.81372
# [45]	validation_0-rmse:0.94805	validation_1-rmse:0.80865
# [46]	validation_0-rmse:0.93920	validation_1-rmse:0.80359
# [47]	validation_0-rmse:0.93213	validation_1-rmse:0.80039
# [48]	validation_0-rmse:0.92471	validation_1-rmse:0.79795
# [49]	validation_0-rmse:0.91794	validation_1-rmse:0.78866
# [50]	validation_0-rmse:0.91181	validation_1-rmse:0.78304
# [51]	validation_0-rmse:0.90647	validation_1-rmse:0.78010
# [52]	validation_0-rmse:0.90009	validation_1-rmse:0.78313
# [53]	validation_0-rmse:0.89456	validation_1-rmse:0.78268
# [54]	validation_0-rmse:0.88899	validation_1-rmse:0.77883
# [55]	validation_0-rmse:0.88275	validation_1-rmse:0.77845
# [56]	validation_0-rmse:0.87565	validation_1-rmse:0.78084
# [57]	validation_0-rmse:0.87077	validation_1-rmse:0.78014
# [58]	validation_0-rmse:0.86407	validation_1-rmse:0.77900
# [59]	validation_0-rmse:0.85850	validation_1-rmse:0.77835
# [60]	validation_0-rmse:0.85349	validation_1-rmse:0.77838
# [61]	validation_0-rmse:0.84989	validation_1-rmse:0.77769
# [62]	validation_0-rmse:0.84518	validation_1-rmse:0.77360
# [63]	validation_0-rmse:0.84022	validation_1-rmse:0.77108
# [64]	validation_0-rmse:0.83529	validation_1-rmse:0.77053
# [65]	validation_0-rmse:0.83186	validation_1-rmse:0.77089
# [66]	validation_0-rmse:0.82901	validation_1-rmse:0.77010
# [67]	validation_0-rmse:0.82377	validation_1-rmse:0.77103
# [68]	validation_0-rmse:0.81912	validation_1-rmse:0.76711
# [69]	validation_0-rmse:0.81483	validation_1-rmse:0.76594
# [70]	validation_0-rmse:0.80995	validation_1-rmse:0.76492
# [71]	validation_0-rmse:0.80684	validation_1-rmse:0.76922
# [72]	validation_0-rmse:0.80265	validation_1-rmse:0.76729
# [73]	validation_0-rmse:0.79946	validation_1-rmse:0.76668
# [74]	validation_0-rmse:0.79440	validation_1-rmse:0.77096
# [75]	validation_0-rmse:0.79086	validation_1-rmse:0.77410
# [76]	validation_0-rmse:0.78909	validation_1-rmse:0.77747
# [77]	validation_0-rmse:0.78607	validation_1-rmse:0.77930
# [78]	validation_0-rmse:0.78400	validation_1-rmse:0.78080
# [79]	validation_0-rmse:0.78282	validation_1-rmse:0.78077
# [80]	validation_0-rmse:0.77948	validation_1-rmse:0.78186
# [81]	validation_0-rmse:0.77550	validation_1-rmse:0.78401
# [82]	validation_0-rmse:0.77192	validation_1-rmse:0.78119
# [83]	validation_0-rmse:0.76895	validation_1-rmse:0.77659
# [84]	validation_0-rmse:0.76518	validation_1-rmse:0.77441
# [85]	validation_0-rmse:0.76211	validation_1-rmse:0.77447
# [86]	validation_0-rmse:0.75819	validation_1-rmse:0.77482
# [87]	validation_0-rmse:0.75533	validation_1-rmse:0.77586
# [88]	validation_0-rmse:0.75356	validation_1-rmse:0.77754
# [89]	validation_0-rmse:0.75055	validation_1-rmse:0.77649
# [0]	validation_0-rmse:1.72813	validation_1-rmse:1.50921
# [1]	validation_0-rmse:1.69338	validation_1-rmse:1.47972
# [2]	validation_0-rmse:1.65785	validation_1-rmse:1.45219
# [3]	validation_0-rmse:1.62646	validation_1-rmse:1.42769
# [4]	validation_0-rmse:1.59408	validation_1-rmse:1.40343
# [5]	validation_0-rmse:1.56545	validation_1-rmse:1.38217
# [6]	validation_0-rmse:1.53794	validation_1-rmse:1.36277
# [7]	validation_0-rmse:1.51070	validation_1-rmse:1.34406
# [8]	validation_0-rmse:1.48697	validation_1-rmse:1.32634
# [9]	validation_0-rmse:1.46308	validation_1-rmse:1.30983
# [10]	validation_0-rmse:1.43474	validation_1-rmse:1.28979
# [11]	validation_0-rmse:1.40939	validation_1-rmse:1.27324
# [12]	validation_0-rmse:1.38706	validation_1-rmse:1.25573
# [13]	validation_0-rmse:1.36582	validation_1-rmse:1.23960
# [14]	validation_0-rmse:1.34592	validation_1-rmse:1.22475
# [15]	validation_0-rmse:1.32107	validation_1-rmse:1.20874
# [16]	validation_0-rmse:1.29926	validation_1-rmse:1.19447
# [17]	validation_0-rmse:1.27986	validation_1-rmse:1.18272
# [18]	validation_0-rmse:1.25974	validation_1-rmse:1.16740
# [19]	validation_0-rmse:1.23894	validation_1-rmse:1.15463
# [20]	validation_0-rmse:1.21926	validation_1-rmse:1.14511
# [21]	validation_0-rmse:1.20115	validation_1-rmse:1.13344
# [22]	validation_0-rmse:1.18446	validation_1-rmse:1.12405
# [23]	validation_0-rmse:1.17129	validation_1-rmse:1.11516
# [24]	validation_0-rmse:1.15608	validation_1-rmse:1.10577
# [25]	validation_0-rmse:1.14164	validation_1-rmse:1.09591
# [26]	validation_0-rmse:1.12922	validation_1-rmse:1.08873
# [27]	validation_0-rmse:1.11560	validation_1-rmse:1.08260
# [28]	validation_0-rmse:1.10000	validation_1-rmse:1.07383
# [29]	validation_0-rmse:1.08623	validation_1-rmse:1.07053
# [30]	validation_0-rmse:1.07388	validation_1-rmse:1.06435
# [31]	validation_0-rmse:1.06241	validation_1-rmse:1.05879
# [32]	validation_0-rmse:1.04981	validation_1-rmse:1.05575
# [33]	validation_0-rmse:1.03856	validation_1-rmse:1.05241
# [34]	validation_0-rmse:1.02680	validation_1-rmse:1.04781
# [35]	validation_0-rmse:1.01402	validation_1-rmse:1.04306
# [36]	validation_0-rmse:1.00327	validation_1-rmse:1.03852
# [37]	validation_0-rmse:0.99088	validation_1-rmse:1.03540
# [38]	validation_0-rmse:0.98269	validation_1-rmse:1.03214
# [39]	validation_0-rmse:0.97402	validation_1-rmse:1.03130
# [40]	validation_0-rmse:0.96522	validation_1-rmse:1.02718
# [41]	validation_0-rmse:0.95659	validation_1-rmse:1.02368
# [42]	validation_0-rmse:0.95019	validation_1-rmse:1.02108
# [43]	validation_0-rmse:0.94016	validation_1-rmse:1.01894
# [44]	validation_0-rmse:0.93294	validation_1-rmse:1.01699
# [45]	validation_0-rmse:0.92269	validation_1-rmse:1.01132
# [46]	validation_0-rmse:0.91612	validation_1-rmse:1.00923
# [47]	validation_0-rmse:0.90809	validation_1-rmse:1.00802
# [48]	validation_0-rmse:0.90132	validation_1-rmse:1.00778
# [49]	validation_0-rmse:0.89276	validation_1-rmse:1.00504
# [50]	validation_0-rmse:0.88659	validation_1-rmse:1.00364
# [51]	validation_0-rmse:0.88005	validation_1-rmse:1.00243
# [52]	validation_0-rmse:0.87324	validation_1-rmse:1.00060
# [53]	validation_0-rmse:0.86732	validation_1-rmse:0.99934
# [54]	validation_0-rmse:0.86042	validation_1-rmse:0.99781
# [55]	validation_0-rmse:0.85395	validation_1-rmse:0.99729
# [56]	validation_0-rmse:0.84852	validation_1-rmse:0.99711
# [57]	validation_0-rmse:0.84450	validation_1-rmse:0.99867
# [58]	validation_0-rmse:0.83866	validation_1-rmse:0.99727
# [59]	validation_0-rmse:0.83268	validation_1-rmse:0.99807
# [60]	validation_0-rmse:0.82757	validation_1-rmse:0.99916
# [61]	validation_0-rmse:0.82255	validation_1-rmse:0.99739
# [62]	validation_0-rmse:0.81782	validation_1-rmse:0.99812
# [63]	validation_0-rmse:0.81374	validation_1-rmse:0.99760
# [64]	validation_0-rmse:0.80663	validation_1-rmse:0.99767
# [65]	validation_0-rmse:0.80269	validation_1-rmse:0.99853
# [66]	validation_0-rmse:0.79761	validation_1-rmse:0.99863
# [67]	validation_0-rmse:0.79377	validation_1-rmse:1.00066
# [68]	validation_0-rmse:0.78780	validation_1-rmse:1.00291
# [69]	validation_0-rmse:0.78493	validation_1-rmse:1.00528
# [70]	validation_0-rmse:0.78042	validation_1-rmse:1.00736
# [71]	validation_0-rmse:0.77518	validation_1-rmse:1.00562
# [72]	validation_0-rmse:0.77065	validation_1-rmse:1.00865
# [73]	validation_0-rmse:0.76673	validation_1-rmse:1.00966
# [74]	validation_0-rmse:0.76263	validation_1-rmse:1.01142
# [75]	validation_0-rmse:0.75849	validation_1-rmse:1.01203
# [76]	validation_0-rmse:0.75416	validation_1-rmse:1.01629
# [0]	validation_0-rmse:1.72073	validation_1-rmse:1.55185
# [1]	validation_0-rmse:1.68505	validation_1-rmse:1.53447
# [2]	validation_0-rmse:1.65236	validation_1-rmse:1.50947
# [3]	validation_0-rmse:1.61495	validation_1-rmse:1.48607
# [4]	validation_0-rmse:1.58404	validation_1-rmse:1.46670
# [5]	validation_0-rmse:1.55471	validation_1-rmse:1.45217
# [6]	validation_0-rmse:1.52343	validation_1-rmse:1.43512
# [7]	validation_0-rmse:1.49365	validation_1-rmse:1.41614
# [8]	validation_0-rmse:1.46628	validation_1-rmse:1.39869
# [9]	validation_0-rmse:1.43926	validation_1-rmse:1.37853
# [10]	validation_0-rmse:1.41182	validation_1-rmse:1.36557
# [11]	validation_0-rmse:1.38600	validation_1-rmse:1.34407
# [12]	validation_0-rmse:1.35896	validation_1-rmse:1.32710
# [13]	validation_0-rmse:1.33962	validation_1-rmse:1.31710
# [14]	validation_0-rmse:1.31516	validation_1-rmse:1.30419
# [15]	validation_0-rmse:1.29139	validation_1-rmse:1.29048
# [16]	validation_0-rmse:1.26811	validation_1-rmse:1.27835
# [17]	validation_0-rmse:1.24833	validation_1-rmse:1.26417
# [18]	validation_0-rmse:1.23026	validation_1-rmse:1.25613
# [19]	validation_0-rmse:1.20969	validation_1-rmse:1.24625
# [20]	validation_0-rmse:1.19119	validation_1-rmse:1.24080
# [21]	validation_0-rmse:1.17293	validation_1-rmse:1.23270
# [22]	validation_0-rmse:1.15612	validation_1-rmse:1.22157
# [23]	validation_0-rmse:1.13897	validation_1-rmse:1.21534
# [24]	validation_0-rmse:1.12190	validation_1-rmse:1.20912
# [25]	validation_0-rmse:1.10719	validation_1-rmse:1.20180
# [26]	validation_0-rmse:1.09188	validation_1-rmse:1.19455
# [27]	validation_0-rmse:1.07781	validation_1-rmse:1.18864
# [28]	validation_0-rmse:1.06346	validation_1-rmse:1.18468
# [29]	validation_0-rmse:1.04988	validation_1-rmse:1.17778
# [30]	validation_0-rmse:1.03701	validation_1-rmse:1.17786
# [31]	validation_0-rmse:1.02586	validation_1-rmse:1.17879
# [32]	validation_0-rmse:1.01450	validation_1-rmse:1.17663
# [33]	validation_0-rmse:1.00273	validation_1-rmse:1.17191
# [34]	validation_0-rmse:0.99276	validation_1-rmse:1.16871
# [35]	validation_0-rmse:0.98249	validation_1-rmse:1.16513
# [36]	validation_0-rmse:0.97068	validation_1-rmse:1.16109
# [37]	validation_0-rmse:0.96165	validation_1-rmse:1.16174
# [38]	validation_0-rmse:0.95120	validation_1-rmse:1.15923
# [39]	validation_0-rmse:0.94167	validation_1-rmse:1.15877
# [40]	validation_0-rmse:0.93196	validation_1-rmse:1.16163
# [41]	validation_0-rmse:0.92282	validation_1-rmse:1.16269
# [42]	validation_0-rmse:0.91423	validation_1-rmse:1.15927
# [43]	validation_0-rmse:0.90626	validation_1-rmse:1.15694
# [44]	validation_0-rmse:0.89778	validation_1-rmse:1.15789
# [45]	validation_0-rmse:0.88923	validation_1-rmse:1.15629
# [46]	validation_0-rmse:0.88019	validation_1-rmse:1.15085
# [47]	validation_0-rmse:0.87412	validation_1-rmse:1.15063
# [48]	validation_0-rmse:0.86581	validation_1-rmse:1.14673
# [49]	validation_0-rmse:0.86092	validation_1-rmse:1.14678
# [50]	validation_0-rmse:0.85368	validation_1-rmse:1.14727
# [51]	validation_0-rmse:0.84719	validation_1-rmse:1.14632
# [52]	validation_0-rmse:0.83953	validation_1-rmse:1.14810
# [53]	validation_0-rmse:0.83351	validation_1-rmse:1.15170
# [54]	validation_0-rmse:0.82564	validation_1-rmse:1.15024
# [55]	validation_0-rmse:0.82062	validation_1-rmse:1.14804
# [56]	validation_0-rmse:0.81398	validation_1-rmse:1.15181
# [57]	validation_0-rmse:0.80871	validation_1-rmse:1.15213
# [58]	validation_0-rmse:0.80334	validation_1-rmse:1.15348
# [59]	validation_0-rmse:0.79725	validation_1-rmse:1.15465
# [60]	validation_0-rmse:0.79272	validation_1-rmse:1.15690
# [61]	validation_0-rmse:0.78694	validation_1-rmse:1.15676
# [62]	validation_0-rmse:0.78197	validation_1-rmse:1.15985
# [63]	validation_0-rmse:0.77802	validation_1-rmse:1.16047
# [64]	validation_0-rmse:0.77295	validation_1-rmse:1.16065
# [65]	validation_0-rmse:0.76818	validation_1-rmse:1.16302
# [66]	validation_0-rmse:0.76320	validation_1-rmse:1.16415
# [67]	validation_0-rmse:0.75912	validation_1-rmse:1.16273
# [68]	validation_0-rmse:0.75584	validation_1-rmse:1.16305
# [69]	validation_0-rmse:0.75335	validation_1-rmse:1.16315
# [70]	validation_0-rmse:0.74922	validation_1-rmse:1.16472
# [71]	validation_0-rmse:0.74551	validation_1-rmse:1.16467
# [0]	validation_0-rmse:1.74111	validation_1-rmse:1.44753
# [1]	validation_0-rmse:1.70538	validation_1-rmse:1.41978
# [2]	validation_0-rmse:1.66991	validation_1-rmse:1.38836
# [3]	validation_0-rmse:1.63619	validation_1-rmse:1.36037
# [4]	validation_0-rmse:1.60477	validation_1-rmse:1.33754
# [5]	validation_0-rmse:1.57677	validation_1-rmse:1.31752
# [6]	validation_0-rmse:1.54358	validation_1-rmse:1.29360
# [7]	validation_0-rmse:1.51539	validation_1-rmse:1.27002
# [8]	validation_0-rmse:1.48634	validation_1-rmse:1.24817
# [9]	validation_0-rmse:1.46205	validation_1-rmse:1.23449
# [10]	validation_0-rmse:1.43422	validation_1-rmse:1.21728
# [11]	validation_0-rmse:1.41369	validation_1-rmse:1.20078
# [12]	validation_0-rmse:1.38897	validation_1-rmse:1.18496
# [13]	validation_0-rmse:1.36743	validation_1-rmse:1.17224
# [14]	validation_0-rmse:1.34420	validation_1-rmse:1.16094
# [15]	validation_0-rmse:1.31967	validation_1-rmse:1.14739
# [16]	validation_0-rmse:1.30162	validation_1-rmse:1.13663
# [17]	validation_0-rmse:1.28022	validation_1-rmse:1.11960
# [18]	validation_0-rmse:1.26260	validation_1-rmse:1.10860
# [19]	validation_0-rmse:1.24495	validation_1-rmse:1.10006
# [20]	validation_0-rmse:1.22503	validation_1-rmse:1.09178
# [21]	validation_0-rmse:1.20714	validation_1-rmse:1.08047
# [22]	validation_0-rmse:1.18643	validation_1-rmse:1.07306
# [23]	validation_0-rmse:1.17009	validation_1-rmse:1.06298
# [24]	validation_0-rmse:1.15317	validation_1-rmse:1.05594
# [25]	validation_0-rmse:1.13564	validation_1-rmse:1.04852
# [26]	validation_0-rmse:1.12023	validation_1-rmse:1.04074
# [27]	validation_0-rmse:1.10534	validation_1-rmse:1.03666
# [28]	validation_0-rmse:1.09106	validation_1-rmse:1.03279
# [29]	validation_0-rmse:1.07571	validation_1-rmse:1.02596
# [30]	validation_0-rmse:1.06297	validation_1-rmse:1.02488
# [31]	validation_0-rmse:1.05050	validation_1-rmse:1.02390
# [32]	validation_0-rmse:1.03872	validation_1-rmse:1.02226
# [33]	validation_0-rmse:1.02781	validation_1-rmse:1.01899
# [34]	validation_0-rmse:1.01893	validation_1-rmse:1.01651
# [35]	validation_0-rmse:1.00758	validation_1-rmse:1.01260
# [36]	validation_0-rmse:0.99577	validation_1-rmse:1.00974
# [37]	validation_0-rmse:0.98492	validation_1-rmse:1.00645
# [38]	validation_0-rmse:0.97611	validation_1-rmse:1.00543
# [39]	validation_0-rmse:0.96713	validation_1-rmse:1.00243
# [40]	validation_0-rmse:0.95895	validation_1-rmse:1.00360
# [41]	validation_0-rmse:0.94668	validation_1-rmse:1.00269
# [42]	validation_0-rmse:0.93881	validation_1-rmse:1.00096
# [43]	validation_0-rmse:0.93021	validation_1-rmse:0.99818
# [44]	validation_0-rmse:0.92197	validation_1-rmse:0.99486
# [45]	validation_0-rmse:0.91419	validation_1-rmse:0.99330
# [46]	validation_0-rmse:0.90525	validation_1-rmse:0.99258
# [47]	validation_0-rmse:0.89667	validation_1-rmse:0.98870
# [48]	validation_0-rmse:0.89028	validation_1-rmse:0.98612
# [49]	validation_0-rmse:0.88346	validation_1-rmse:0.98860
# [50]	validation_0-rmse:0.87559	validation_1-rmse:0.98856
# [51]	validation_0-rmse:0.86945	validation_1-rmse:0.99056
# [52]	validation_0-rmse:0.86522	validation_1-rmse:0.99438
# [53]	validation_0-rmse:0.85961	validation_1-rmse:0.99671
# [54]	validation_0-rmse:0.85217	validation_1-rmse:0.99260
# [55]	validation_0-rmse:0.84502	validation_1-rmse:0.99323
# [56]	validation_0-rmse:0.84103	validation_1-rmse:0.99358
# [57]	validation_0-rmse:0.83470	validation_1-rmse:0.99347
# [58]	validation_0-rmse:0.83028	validation_1-rmse:0.99451
# [59]	validation_0-rmse:0.82410	validation_1-rmse:0.99228
# [60]	validation_0-rmse:0.81655	validation_1-rmse:0.99726
# [61]	validation_0-rmse:0.81272	validation_1-rmse:0.99676
# [62]	validation_0-rmse:0.80805	validation_1-rmse:0.99480
# [63]	validation_0-rmse:0.80269	validation_1-rmse:0.99620
# [64]	validation_0-rmse:0.79795	validation_1-rmse:0.99757
# [65]	validation_0-rmse:0.79282	validation_1-rmse:0.99908
# [66]	validation_0-rmse:0.78865	validation_1-rmse:1.00334
# [67]	validation_0-rmse:0.78366	validation_1-rmse:1.00449
# [68]	validation_0-rmse:0.77782	validation_1-rmse:1.00716
# [0]	validation_0-rmse:1.72329	validation_1-rmse:1.56861
# [1]	validation_0-rmse:1.69155	validation_1-rmse:1.52984
# [2]	validation_0-rmse:1.66123	validation_1-rmse:1.49521
# [3]	validation_0-rmse:1.63170	validation_1-rmse:1.46230
# [4]	validation_0-rmse:1.60124	validation_1-rmse:1.43117
# [5]	validation_0-rmse:1.57345	validation_1-rmse:1.40609
# [6]	validation_0-rmse:1.54411	validation_1-rmse:1.37597
# [7]	validation_0-rmse:1.51784	validation_1-rmse:1.34530
# [8]	validation_0-rmse:1.49172	validation_1-rmse:1.31717
# [9]	validation_0-rmse:1.46764	validation_1-rmse:1.29181
# [10]	validation_0-rmse:1.44470	validation_1-rmse:1.27004
# [11]	validation_0-rmse:1.42134	validation_1-rmse:1.24990
# [12]	validation_0-rmse:1.40176	validation_1-rmse:1.22488
# [13]	validation_0-rmse:1.38369	validation_1-rmse:1.20887
# [14]	validation_0-rmse:1.36359	validation_1-rmse:1.18938
# [15]	validation_0-rmse:1.34010	validation_1-rmse:1.16679
# [16]	validation_0-rmse:1.31992	validation_1-rmse:1.14979
# [17]	validation_0-rmse:1.30171	validation_1-rmse:1.12983
# [18]	validation_0-rmse:1.28443	validation_1-rmse:1.11281
# [19]	validation_0-rmse:1.26684	validation_1-rmse:1.09833
# [20]	validation_0-rmse:1.24728	validation_1-rmse:1.07732
# [21]	validation_0-rmse:1.23373	validation_1-rmse:1.06042
# [22]	validation_0-rmse:1.21738	validation_1-rmse:1.04541
# [23]	validation_0-rmse:1.20302	validation_1-rmse:1.03325
# [24]	validation_0-rmse:1.19097	validation_1-rmse:1.02036
# [25]	validation_0-rmse:1.17561	validation_1-rmse:1.00676
# [26]	validation_0-rmse:1.16127	validation_1-rmse:0.99115
# [27]	validation_0-rmse:1.14810	validation_1-rmse:0.97997
# [28]	validation_0-rmse:1.13247	validation_1-rmse:0.96271
# [29]	validation_0-rmse:1.12083	validation_1-rmse:0.95044
# [30]	validation_0-rmse:1.10869	validation_1-rmse:0.93699
# [31]	validation_0-rmse:1.09824	validation_1-rmse:0.93035
# [32]	validation_0-rmse:1.08469	validation_1-rmse:0.91872
# [33]	validation_0-rmse:1.07213	validation_1-rmse:0.90758
# [34]	validation_0-rmse:1.06106	validation_1-rmse:0.90277
# [35]	validation_0-rmse:1.05063	validation_1-rmse:0.89352
# [36]	validation_0-rmse:1.04092	validation_1-rmse:0.88703
# [37]	validation_0-rmse:1.03004	validation_1-rmse:0.87941
# [38]	validation_0-rmse:1.02177	validation_1-rmse:0.87260
# [39]	validation_0-rmse:1.00996	validation_1-rmse:0.86231
# [40]	validation_0-rmse:1.00251	validation_1-rmse:0.85793
# [41]	validation_0-rmse:0.99683	validation_1-rmse:0.85120
# [42]	validation_0-rmse:0.98996	validation_1-rmse:0.84566
# [43]	validation_0-rmse:0.97967	validation_1-rmse:0.83815
# [44]	validation_0-rmse:0.97140	validation_1-rmse:0.83402
# [45]	validation_0-rmse:0.96444	validation_1-rmse:0.82808
# [46]	validation_0-rmse:0.95613	validation_1-rmse:0.82410
# [47]	validation_0-rmse:0.94957	validation_1-rmse:0.81731
# [48]	validation_0-rmse:0.94346	validation_1-rmse:0.80968
# [49]	validation_0-rmse:0.93710	validation_1-rmse:0.80588
# [50]	validation_0-rmse:0.93057	validation_1-rmse:0.80305
# [51]	validation_0-rmse:0.92561	validation_1-rmse:0.80099
# [52]	validation_0-rmse:0.92055	validation_1-rmse:0.79683
# [53]	validation_0-rmse:0.91672	validation_1-rmse:0.79132
# [54]	validation_0-rmse:0.91098	validation_1-rmse:0.78979
# [55]	validation_0-rmse:0.90510	validation_1-rmse:0.78406
# [56]	validation_0-rmse:0.90058	validation_1-rmse:0.78042
# [57]	validation_0-rmse:0.89717	validation_1-rmse:0.78268
# [58]	validation_0-rmse:0.89186	validation_1-rmse:0.77676
# [59]	validation_0-rmse:0.88739	validation_1-rmse:0.77643
# [60]	validation_0-rmse:0.88281	validation_1-rmse:0.77538
# [61]	validation_0-rmse:0.87783	validation_1-rmse:0.77354
# [62]	validation_0-rmse:0.87266	validation_1-rmse:0.77051
# [63]	validation_0-rmse:0.86813	validation_1-rmse:0.76703
# [64]	validation_0-rmse:0.86346	validation_1-rmse:0.76565
# [65]	validation_0-rmse:0.85850	validation_1-rmse:0.76391
# [66]	validation_0-rmse:0.85357	validation_1-rmse:0.76436
# [67]	validation_0-rmse:0.84867	validation_1-rmse:0.76262
# [68]	validation_0-rmse:0.84487	validation_1-rmse:0.76087
# [69]	validation_0-rmse:0.84049	validation_1-rmse:0.75776
# [70]	validation_0-rmse:0.83471	validation_1-rmse:0.75577
# [71]	validation_0-rmse:0.83142	validation_1-rmse:0.75414
# [72]	validation_0-rmse:0.82719	validation_1-rmse:0.75489
# [73]	validation_0-rmse:0.82356	validation_1-rmse:0.75757
# [74]	validation_0-rmse:0.81971	validation_1-rmse:0.75532
# [75]	validation_0-rmse:0.81698	validation_1-rmse:0.75123
# [76]	validation_0-rmse:0.81287	validation_1-rmse:0.75110
# [77]	validation_0-rmse:0.81120	validation_1-rmse:0.74856
# [78]	validation_0-rmse:0.80880	validation_1-rmse:0.74766
# [79]	validation_0-rmse:0.80763	validation_1-rmse:0.74478
# [80]	validation_0-rmse:0.80479	validation_1-rmse:0.74437
# [81]	validation_0-rmse:0.80037	validation_1-rmse:0.74234
# [82]	validation_0-rmse:0.79723	validation_1-rmse:0.74007
# [83]	validation_0-rmse:0.79517	validation_1-rmse:0.73666
# [84]	validation_0-rmse:0.79232	validation_1-rmse:0.73718
# [85]	validation_0-rmse:0.79016	validation_1-rmse:0.73786
# [86]	validation_0-rmse:0.78754	validation_1-rmse:0.73706
# [87]	validation_0-rmse:0.78339	validation_1-rmse:0.73553
# [88]	validation_0-rmse:0.78023	validation_1-rmse:0.73689
# [89]	validation_0-rmse:0.77803	validation_1-rmse:0.73550
# [90]	validation_0-rmse:0.77424	validation_1-rmse:0.73225
# [91]	validation_0-rmse:0.77188	validation_1-rmse:0.72920
# [92]	validation_0-rmse:0.76861	validation_1-rmse:0.73042
# [93]	validation_0-rmse:0.76602	validation_1-rmse:0.73308
# [94]	validation_0-rmse:0.76461	validation_1-rmse:0.73358
# [95]	validation_0-rmse:0.76277	validation_1-rmse:0.73586
# [96]	validation_0-rmse:0.76028	validation_1-rmse:0.73672
# [97]	validation_0-rmse:0.75734	validation_1-rmse:0.73823
# [98]	validation_0-rmse:0.75421	validation_1-rmse:0.73639
# [99]	validation_0-rmse:0.75088	validation_1-rmse:0.73845
# [100]	validation_0-rmse:0.74931	validation_1-rmse:0.73746
# [101]	validation_0-rmse:0.74751	validation_1-rmse:0.73551
# [102]	validation_0-rmse:0.74457	validation_1-rmse:0.73511
# [103]	validation_0-rmse:0.74282	validation_1-rmse:0.73251
# [0]	validation_0-rmse:1.68595	validation_1-rmse:1.71505
# [1]	validation_0-rmse:1.65688	validation_1-rmse:1.68382
# [2]	validation_0-rmse:1.62401	validation_1-rmse:1.65358
# [3]	validation_0-rmse:1.59283	validation_1-rmse:1.61796
# [4]	validation_0-rmse:1.56399	validation_1-rmse:1.59004
# [5]	validation_0-rmse:1.53506	validation_1-rmse:1.56545
# [6]	validation_0-rmse:1.50581	validation_1-rmse:1.53550
# [7]	validation_0-rmse:1.48020	validation_1-rmse:1.50696
# [8]	validation_0-rmse:1.45520	validation_1-rmse:1.47875
# [9]	validation_0-rmse:1.43059	validation_1-rmse:1.45739
# [10]	validation_0-rmse:1.40977	validation_1-rmse:1.43779
# [11]	validation_0-rmse:1.38816	validation_1-rmse:1.42209
# [12]	validation_0-rmse:1.36596	validation_1-rmse:1.40043
# [13]	validation_0-rmse:1.34283	validation_1-rmse:1.38095
# [14]	validation_0-rmse:1.32283	validation_1-rmse:1.36215
# [15]	validation_0-rmse:1.30054	validation_1-rmse:1.34386
# [16]	validation_0-rmse:1.27977	validation_1-rmse:1.32650
# [17]	validation_0-rmse:1.26255	validation_1-rmse:1.30784
# [18]	validation_0-rmse:1.24874	validation_1-rmse:1.29178
# [19]	validation_0-rmse:1.23151	validation_1-rmse:1.27964
# [20]	validation_0-rmse:1.21427	validation_1-rmse:1.26511
# [21]	validation_0-rmse:1.19605	validation_1-rmse:1.24993
# [22]	validation_0-rmse:1.18165	validation_1-rmse:1.23687
# [23]	validation_0-rmse:1.16704	validation_1-rmse:1.22520
# [24]	validation_0-rmse:1.15279	validation_1-rmse:1.21038
# [25]	validation_0-rmse:1.13936	validation_1-rmse:1.19836
# [26]	validation_0-rmse:1.12626	validation_1-rmse:1.18535
# [27]	validation_0-rmse:1.11215	validation_1-rmse:1.17421
# [28]	validation_0-rmse:1.09535	validation_1-rmse:1.16301
# [29]	validation_0-rmse:1.08039	validation_1-rmse:1.15366
# [30]	validation_0-rmse:1.06917	validation_1-rmse:1.14202
# [31]	validation_0-rmse:1.05605	validation_1-rmse:1.12868
# [32]	validation_0-rmse:1.04361	validation_1-rmse:1.12308
# [33]	validation_0-rmse:1.03148	validation_1-rmse:1.11724
# ...
# [8]	validation_0-rmse:1.47679	validation_1-rmse:1.38397
# [9]	validation_0-rmse:1.45234	validation_1-rmse:1.36099
# [10]	validation_0-rmse:1.42886	validation_1-rmse:1.33398
# [11]	validation_0-rmse:1.40732	validation_1-rmse:1.31195
# [12]	validation_0-rmse:1.38198	validation_1-rmse:1.28139
# [13]	validation_0-rmse:1.36155	validation_1-rmse:1.26418
# [14]	validation_0-rmse:1.34105	validation_1-rmse:1.24241
# [15]	validation_0-rmse:1.31803	validation_1-rmse:1.22050
# [16]	validation_0-rmse:1.29690	validation_1-rmse:1.19880
# [17]	validation_0-rmse:1.27410	validation_1-rmse:1.17401
# [18]	validation_0-rmse:1.25741	validation_1-rmse:1.15970
# [19]	validation_0-rmse:1.23813	validation_1-rmse:1.13918
# [20]	validation_0-rmse:1.21720	validation_1-rmse:1.11796
# [21]	validation_0-rmse:1.20159	validation_1-rmse:1.10300
# [22]	validation_0-rmse:1.18617	validation_1-rmse:1.08837
# [23]	validation_0-rmse:1.16917	validation_1-rmse:1.07460
# [24]	validation_0-rmse:1.15519	validation_1-rmse:1.06532
# [25]	validation_0-rmse:1.14089	validation_1-rmse:1.05334
# [26]	validation_0-rmse:1.12784	validation_1-rmse:1.04494
# [27]	validation_0-rmse:1.11415	validation_1-rmse:1.03057
# [28]	validation_0-rmse:1.09874	validation_1-rmse:1.02121
# [29]	validation_0-rmse:1.08450	validation_1-rmse:1.01105
# [30]	validation_0-rmse:1.07245	validation_1-rmse:1.00366
# [31]	validation_0-rmse:1.06006	validation_1-rmse:0.99958
# [32]	validation_0-rmse:1.05015	validation_1-rmse:0.99301
# [33]	validation_0-rmse:1.04009	validation_1-rmse:0.98611
# [34]	validation_0-rmse:1.03076	validation_1-rmse:0.97847
# [35]	validation_0-rmse:1.02175	validation_1-rmse:0.97243
# [36]	validation_0-rmse:1.01008	validation_1-rmse:0.96495
# [37]	validation_0-rmse:0.99871	validation_1-rmse:0.95604
# [38]	validation_0-rmse:0.98943	validation_1-rmse:0.95240
# [39]	validation_0-rmse:0.97901	validation_1-rmse:0.94524
# [40]	validation_0-rmse:0.96973	validation_1-rmse:0.93808
# [41]	validation_0-rmse:0.96144	validation_1-rmse:0.93731
# [42]	validation_0-rmse:0.95301	validation_1-rmse:0.93127
# [43]	validation_0-rmse:0.94458	validation_1-rmse:0.93070
# [44]	validation_0-rmse:0.93610	validation_1-rmse:0.92381
# [45]	validation_0-rmse:0.92790	validation_1-rmse:0.92044
# [46]	validation_0-rmse:0.91856	validation_1-rmse:0.91719
# [47]	validation_0-rmse:0.91217	validation_1-rmse:0.91433
# [48]	validation_0-rmse:0.90434	validation_1-rmse:0.91111
# [49]	validation_0-rmse:0.89664	validation_1-rmse:0.90833
# [50]	validation_0-rmse:0.88958	validation_1-rmse:0.90642
# [51]	validation_0-rmse:0.88394	validation_1-rmse:0.90582
# [52]	validation_0-rmse:0.87893	validation_1-rmse:0.90285
# [53]	validation_0-rmse:0.87254	validation_1-rmse:0.89788
# [54]	validation_0-rmse:0.86441	validation_1-rmse:0.89598
# [55]	validation_0-rmse:0.85866	validation_1-rmse:0.89168
# [56]	validation_0-rmse:0.85126	validation_1-rmse:0.88815
# [57]	validation_0-rmse:0.84687	validation_1-rmse:0.88580
# [58]	validation_0-rmse:0.84072	validation_1-rmse:0.88568
# [59]	validation_0-rmse:0.83527	validation_1-rmse:0.88556
# [60]	validation_0-rmse:0.82915	validation_1-rmse:0.88388
# [61]	validation_0-rmse:0.82470	validation_1-rmse:0.88663
# [62]	validation_0-rmse:0.81942	validation_1-rmse:0.88675
# [63]	validation_0-rmse:0.81695	validation_1-rmse:0.88926
# [64]	validation_0-rmse:0.81273	validation_1-rmse:0.88705
# [65]	validation_0-rmse:0.80671	validation_1-rmse:0.88653
# [66]	validation_0-rmse:0.80343	validation_1-rmse:0.88447
# [67]	validation_0-rmse:0.79848	validation_1-rmse:0.88501
# [68]	validation_0-rmse:0.79379	validation_1-rmse:0.88545
# [69]	validation_0-rmse:0.78966	validation_1-rmse:0.88577
# [70]	validation_0-rmse:0.78549	validation_1-rmse:0.88599
# [71]	validation_0-rmse:0.78306	validation_1-rmse:0.88745
# [72]	validation_0-rmse:0.77879	validation_1-rmse:0.88980
# [73]	validation_0-rmse:0.77589	validation_1-rmse:0.89144
# [74]	validation_0-rmse:0.77208	validation_1-rmse:0.89187
# [75]	validation_0-rmse:0.76777	validation_1-rmse:0.89262
# [76]	validation_0-rmse:0.76351	validation_1-rmse:0.89219
# [77]	validation_0-rmse:0.75988	validation_1-rmse:0.89128
# [78]	validation_0-rmse:0.75446	validation_1-rmse:0.88670
# [79]	validation_0-rmse:0.75066	validation_1-rmse:0.88580
# [0]	validation_0-rmse:1.63807	validation_1-rmse:1.88837
# [1]	validation_0-rmse:1.60681	validation_1-rmse:1.85782
# [2]	validation_0-rmse:1.57654	validation_1-rmse:1.83562
# [3]	validation_0-rmse:1.54704	validation_1-rmse:1.80776
# [4]	validation_0-rmse:1.51917	validation_1-rmse:1.78328
# [5]	validation_0-rmse:1.49011	validation_1-rmse:1.75285
# [6]	validation_0-rmse:1.46539	validation_1-rmse:1.72620
# [7]	validation_0-rmse:1.43696	validation_1-rmse:1.70537
# [8]	validation_0-rmse:1.40647	validation_1-rmse:1.67437
# [9]	validation_0-rmse:1.38380	validation_1-rmse:1.65072
# [10]	validation_0-rmse:1.36263	validation_1-rmse:1.62851
# [11]	validation_0-rmse:1.33890	validation_1-rmse:1.60692
# [12]	validation_0-rmse:1.31494	validation_1-rmse:1.58684
# [13]	validation_0-rmse:1.29735	validation_1-rmse:1.57217
# [14]	validation_0-rmse:1.27676	validation_1-rmse:1.55316
# [15]	validation_0-rmse:1.25336	validation_1-rmse:1.53617
# [16]	validation_0-rmse:1.23179	validation_1-rmse:1.51795
# [17]	validation_0-rmse:1.21119	validation_1-rmse:1.50088
# [18]	validation_0-rmse:1.19225	validation_1-rmse:1.48250
# [19]	validation_0-rmse:1.17456	validation_1-rmse:1.46694
# [20]	validation_0-rmse:1.15594	validation_1-rmse:1.45099
# [21]	validation_0-rmse:1.13964	validation_1-rmse:1.43531
# [22]	validation_0-rmse:1.12910	validation_1-rmse:1.42679
# [23]	validation_0-rmse:1.11454	validation_1-rmse:1.41286
# [24]	validation_0-rmse:1.10075	validation_1-rmse:1.40383
# [25]	validation_0-rmse:1.08930	validation_1-rmse:1.39305
# [26]	validation_0-rmse:1.07619	validation_1-rmse:1.38061
# [27]	validation_0-rmse:1.06367	validation_1-rmse:1.36979
# [28]	validation_0-rmse:1.04967	validation_1-rmse:1.35593
# [29]	validation_0-rmse:1.03901	validation_1-rmse:1.34916
# [30]	validation_0-rmse:1.02792	validation_1-rmse:1.33977
# [31]	validation_0-rmse:1.01807	validation_1-rmse:1.33171
# [32]	validation_0-rmse:1.00508	validation_1-rmse:1.32395
# [33]	validation_0-rmse:0.99303	validation_1-rmse:1.31519
# [34]	validation_0-rmse:0.98076	validation_1-rmse:1.30827
# [35]	validation_0-rmse:0.97363	validation_1-rmse:1.30420
# [36]	validation_0-rmse:0.96207	validation_1-rmse:1.29853
# [37]	validation_0-rmse:0.95180	validation_1-rmse:1.29043
# [38]	validation_0-rmse:0.94355	validation_1-rmse:1.28585
# [39]	validation_0-rmse:0.93374	validation_1-rmse:1.27899
# [40]	validation_0-rmse:0.92467	validation_1-rmse:1.27151
# [41]	validation_0-rmse:0.92052	validation_1-rmse:1.26823
# [42]	validation_0-rmse:0.91187	validation_1-rmse:1.26114
# [43]	validation_0-rmse:0.90392	validation_1-rmse:1.25535
# [44]	validation_0-rmse:0.89652	validation_1-rmse:1.25384
# [45]	validation_0-rmse:0.88994	validation_1-rmse:1.24814
# [46]	validation_0-rmse:0.88240	validation_1-rmse:1.24237
# [47]	validation_0-rmse:0.87581	validation_1-rmse:1.23891
# [48]	validation_0-rmse:0.86686	validation_1-rmse:1.23400
# [49]	validation_0-rmse:0.86165	validation_1-rmse:1.23282
# [50]	validation_0-rmse:0.85406	validation_1-rmse:1.22631
# [51]	validation_0-rmse:0.84815	validation_1-rmse:1.22063
# [52]	validation_0-rmse:0.84278	validation_1-rmse:1.21327
# [53]	validation_0-rmse:0.83668	validation_1-rmse:1.20979
# [54]	validation_0-rmse:0.83015	validation_1-rmse:1.20707
# [55]	validation_0-rmse:0.82373	validation_1-rmse:1.20785
# [56]	validation_0-rmse:0.81850	validation_1-rmse:1.20468
# [57]	validation_0-rmse:0.81172	validation_1-rmse:1.20130
# [58]	validation_0-rmse:0.80748	validation_1-rmse:1.19813
# [59]	validation_0-rmse:0.80168	validation_1-rmse:1.19093
# [60]	validation_0-rmse:0.79859	validation_1-rmse:1.19190
# [61]	validation_0-rmse:0.79323	validation_1-rmse:1.19133
# [62]	validation_0-rmse:0.78864	validation_1-rmse:1.18542
# [63]	validation_0-rmse:0.78413	validation_1-rmse:1.18227
# [64]	validation_0-rmse:0.78027	validation_1-rmse:1.17975
# [65]	validation_0-rmse:0.77587	validation_1-rmse:1.17893
# [66]	validation_0-rmse:0.77094	validation_1-rmse:1.17632
# [67]	validation_0-rmse:0.76632	validation_1-rmse:1.17633
# [68]	validation_0-rmse:0.76238	validation_1-rmse:1.17595
# [69]	validation_0-rmse:0.75930	validation_1-rmse:1.17250
# [70]	validation_0-rmse:0.75562	validation_1-rmse:1.17032
# [71]	validation_0-rmse:0.75346	validation_1-rmse:1.17218
# [72]	validation_0-rmse:0.74889	validation_1-rmse:1.17261
# [73]	validation_0-rmse:0.74511	validation_1-rmse:1.16857
# [74]	validation_0-rmse:0.74158	validation_1-rmse:1.16382
# [75]	validation_0-rmse:0.73931	validation_1-rmse:1.16414
# [76]	validation_0-rmse:0.73540	validation_1-rmse:1.16655
# [77]	validation_0-rmse:0.73275	validation_1-rmse:1.16744
# [78]	validation_0-rmse:0.72951	validation_1-rmse:1.16709
# [79]	validation_0-rmse:0.72611	validation_1-rmse:1.16084
# [80]	validation_0-rmse:0.72370	validation_1-rmse:1.15847
# [81]	validation_0-rmse:0.72050	validation_1-rmse:1.15438
# [82]	validation_0-rmse:0.71645	validation_1-rmse:1.15325
# [83]	validation_0-rmse:0.71403	validation_1-rmse:1.15238
# [84]	validation_0-rmse:0.71166	validation_1-rmse:1.15242
# [85]	validation_0-rmse:0.70858	validation_1-rmse:1.14866
# [86]	validation_0-rmse:0.70612	validation_1-rmse:1.14542
# [87]	validation_0-rmse:0.70410	validation_1-rmse:1.14624
# [88]	validation_0-rmse:0.70037	validation_1-rmse:1.14531
# [89]	validation_0-rmse:0.69797	validation_1-rmse:1.14537
# [90]	validation_0-rmse:0.69484	validation_1-rmse:1.14397
# [91]	validation_0-rmse:0.69290	validation_1-rmse:1.14615
# [92]	validation_0-rmse:0.68809	validation_1-rmse:1.14208
# [93]	validation_0-rmse:0.68655	validation_1-rmse:1.14232
# [94]	validation_0-rmse:0.68514	validation_1-rmse:1.14233
# [95]	validation_0-rmse:0.68132	validation_1-rmse:1.14233
# [96]	validation_0-rmse:0.67772	validation_1-rmse:1.14020
# [97]	validation_0-rmse:0.67512	validation_1-rmse:1.13995
# [98]	validation_0-rmse:0.67199	validation_1-rmse:1.13527
# [99]	validation_0-rmse:0.66899	validation_1-rmse:1.13194
# [100]	validation_0-rmse:0.66679	validation_1-rmse:1.13245
# [101]	validation_0-rmse:0.66358	validation_1-rmse:1.13104
# [102]	validation_0-rmse:0.66090	validation_1-rmse:1.12910
# [103]	validation_0-rmse:0.65870	validation_1-rmse:1.13034
# [0]	validation_0-rmse:1.63700	validation_1-rmse:1.89932
# [1]	validation_0-rmse:1.60355	validation_1-rmse:1.87044
# [2]	validation_0-rmse:1.56695	validation_1-rmse:1.83673
# [3]	validation_0-rmse:1.53782	validation_1-rmse:1.81359
# [4]	validation_0-rmse:1.50615	validation_1-rmse:1.78672
# [5]	validation_0-rmse:1.47707	validation_1-rmse:1.76014
# [6]	validation_0-rmse:1.44823	validation_1-rmse:1.73655
# [7]	validation_0-rmse:1.42120	validation_1-rmse:1.71200
# [8]	validation_0-rmse:1.39868	validation_1-rmse:1.69317
# [9]	validation_0-rmse:1.37491	validation_1-rmse:1.67257
# [10]	validation_0-rmse:1.34873	validation_1-rmse:1.65129
# [11]	validation_0-rmse:1.32580	validation_1-rmse:1.62712
# [12]	validation_0-rmse:1.30097	validation_1-rmse:1.60324
# [13]	validation_0-rmse:1.28035	validation_1-rmse:1.58395
# [14]	validation_0-rmse:1.25908	validation_1-rmse:1.56904
# [15]	validation_0-rmse:1.23475	validation_1-rmse:1.54809
# [16]	validation_0-rmse:1.21309	validation_1-rmse:1.53300
# [17]	validation_0-rmse:1.19288	validation_1-rmse:1.51967
# [18]	validation_0-rmse:1.17421	validation_1-rmse:1.50672
# [19]	validation_0-rmse:1.15953	validation_1-rmse:1.49352
# [20]	validation_0-rmse:1.14256	validation_1-rmse:1.48125
# [21]	validation_0-rmse:1.12626	validation_1-rmse:1.46391
# [22]	validation_0-rmse:1.11404	validation_1-rmse:1.45363
# [23]	validation_0-rmse:1.09740	validation_1-rmse:1.43924
# [24]	validation_0-rmse:1.08376	validation_1-rmse:1.42790
# [25]	validation_0-rmse:1.07010	validation_1-rmse:1.41623
# [26]	validation_0-rmse:1.05568	validation_1-rmse:1.40393
# [27]	validation_0-rmse:1.04117	validation_1-rmse:1.39149
# [28]	validation_0-rmse:1.02849	validation_1-rmse:1.37921
# [29]	validation_0-rmse:1.01806	validation_1-rmse:1.36865
# [30]	validation_0-rmse:1.00846	validation_1-rmse:1.36060
# [31]	validation_0-rmse:0.99708	validation_1-rmse:1.34877
# [32]	validation_0-rmse:0.98654	validation_1-rmse:1.34062
# [33]	validation_0-rmse:0.97702	validation_1-rmse:1.33319
# [34]	validation_0-rmse:0.96657	validation_1-rmse:1.32297
# [35]	validation_0-rmse:0.95580	validation_1-rmse:1.31386
# [36]	validation_0-rmse:0.94574	validation_1-rmse:1.30328
# [37]	validation_0-rmse:0.93496	validation_1-rmse:1.29300
# [38]	validation_0-rmse:0.92642	validation_1-rmse:1.28799
# [39]	validation_0-rmse:0.91832	validation_1-rmse:1.27984
# [40]	validation_0-rmse:0.90936	validation_1-rmse:1.27131
# [41]	validation_0-rmse:0.90092	validation_1-rmse:1.26736
# [42]	validation_0-rmse:0.89409	validation_1-rmse:1.26190
# [43]	validation_0-rmse:0.88774	validation_1-rmse:1.25682
# [44]	validation_0-rmse:0.87932	validation_1-rmse:1.24739
# [45]	validation_0-rmse:0.87099	validation_1-rmse:1.24670
# [46]	validation_0-rmse:0.86552	validation_1-rmse:1.23766
# [47]	validation_0-rmse:0.85810	validation_1-rmse:1.23353
# [48]	validation_0-rmse:0.85006	validation_1-rmse:1.22825
# [49]	validation_0-rmse:0.84276	validation_1-rmse:1.22388
# [50]	validation_0-rmse:0.83812	validation_1-rmse:1.22087
# [51]	validation_0-rmse:0.83156	validation_1-rmse:1.21831
# [52]	validation_0-rmse:0.82495	validation_1-rmse:1.21097
# [53]	validation_0-rmse:0.81734	validation_1-rmse:1.20799
# [54]	validation_0-rmse:0.81195	validation_1-rmse:1.20514
# [55]	validation_0-rmse:0.80613	validation_1-rmse:1.20212
# [56]	validation_0-rmse:0.80227	validation_1-rmse:1.20039
# [57]	validation_0-rmse:0.79734	validation_1-rmse:1.19660
# [58]	validation_0-rmse:0.79315	validation_1-rmse:1.19394
# [59]	validation_0-rmse:0.78974	validation_1-rmse:1.19319
# [60]	validation_0-rmse:0.78486	validation_1-rmse:1.18929
# [61]	validation_0-rmse:0.78279	validation_1-rmse:1.18666
# [62]	validation_0-rmse:0.77830	validation_1-rmse:1.18592
# [63]	validation_0-rmse:0.77231	validation_1-rmse:1.18555
# [64]	validation_0-rmse:0.76906	validation_1-rmse:1.18398
# [65]	validation_0-rmse:0.76523	validation_1-rmse:1.18249
# [66]	validation_0-rmse:0.76114	validation_1-rmse:1.17908
# [67]	validation_0-rmse:0.75741	validation_1-rmse:1.17810
# [68]	validation_0-rmse:0.75261	validation_1-rmse:1.17702
# [69]	validation_0-rmse:0.74891	validation_1-rmse:1.17130
# [70]	validation_0-rmse:0.74613	validation_1-rmse:1.17027
# [71]	validation_0-rmse:0.74180	validation_1-rmse:1.16712
# [72]	validation_0-rmse:0.73820	validation_1-rmse:1.16484
# [73]	validation_0-rmse:0.73525	validation_1-rmse:1.16461
# [74]	validation_0-rmse:0.73292	validation_1-rmse:1.16321
# [75]	validation_0-rmse:0.72974	validation_1-rmse:1.16010
# [76]	validation_0-rmse:0.72624	validation_1-rmse:1.15660
# [77]	validation_0-rmse:0.72355	validation_1-rmse:1.15725
# [78]	validation_0-rmse:0.72099	validation_1-rmse:1.15708
# [79]	validation_0-rmse:0.71759	validation_1-rmse:1.15452
# [80]	validation_0-rmse:0.71445	validation_1-rmse:1.15303
# [81]	validation_0-rmse:0.71131	validation_1-rmse:1.15087
# [82]	validation_0-rmse:0.70847	validation_1-rmse:1.15090
# [83]	validation_0-rmse:0.70664	validation_1-rmse:1.15102
# [84]	validation_0-rmse:0.70324	validation_1-rmse:1.14752
# [85]	validation_0-rmse:0.69891	validation_1-rmse:1.14873
# [86]	validation_0-rmse:0.69635	validation_1-rmse:1.14950
# [87]	validation_0-rmse:0.69461	validation_1-rmse:1.14812
# [88]	validation_0-rmse:0.69180	validation_1-rmse:1.14721
# [89]	validation_0-rmse:0.68933	validation_1-rmse:1.14594
# [90]	validation_0-rmse:0.68746	validation_1-rmse:1.14904
# [91]	validation_0-rmse:0.68536	validation_1-rmse:1.14736
# [92]	validation_0-rmse:0.68261	validation_1-rmse:1.14581
# [93]	validation_0-rmse:0.68027	validation_1-rmse:1.14410
# [94]	validation_0-rmse:0.67746	validation_1-rmse:1.14286
# [95]	validation_0-rmse:0.67507	validation_1-rmse:1.14122
# [96]	validation_0-rmse:0.67382	validation_1-rmse:1.14131
# [97]	validation_0-rmse:0.67159	validation_1-rmse:1.13923
# [98]	validation_0-rmse:0.66975	validation_1-rmse:1.13642
# [99]	validation_0-rmse:0.66631	validation_1-rmse:1.13515
# [100]	validation_0-rmse:0.66370	validation_1-rmse:1.13424
# [101]	validation_0-rmse:0.66052	validation_1-rmse:1.13249
# [102]	validation_0-rmse:0.65909	validation_1-rmse:1.13253
# [103]	validation_0-rmse:0.65654	validation_1-rmse:1.13123

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-4.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.371
# Uncertainty
# a0: -0.333+/-0.044
# a1: 0.344+/-0.029

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: r2019B01: mean - 0.242, median - 0.245, CI - [0.202-0.281]
#
# SHAP-values for: r2019B04: mean - 0.159, median - 0.161, CI - [0.13-0.184]
#
# SHAP-values for: r2019B08: mean - 0.305, median - 0.305, CI - [0.273-0.338]
#
# SHAP-values for: r2019B10: mean - 0.105, median - 0.104, CI - [0.087-0.123]
#
# SHAP-values for: r2019B11: mean - 0.159, median - 0.16, CI - [0.139-0.178]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['r2019B08', 'r2019B01', 'r2019B04',  'r2019B11', 'r2019B10'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 84.258, median: 91.5,
#  pred. interval (P(0.025)-P(0.975)): 47.9-103.0,
#  conf. interval (p-value=0.95): 64.22-100.891
# ***
# Aggregate bias statistic:
#  mean: 0.099, median: 0.092,
#  pred. interval (P(0.025)-P(0.975)): -0.101-0.351,
#  conf. interval (p-value=0.95): -0.028-0.211
# ***
# Aggregate RMSE statistic:
#  mean: 0.971, median: 0.963, pred. interval (P(0.025)-P(0.975)): 0.755-1.211,
#  conf. interval (p-value=0.95): 0.862-1.078
# ***
# Aggregate MSE statistic:
#  mean: 0.957, median: 0.927, pred. interval (P(0.025)-P(0.975)): 0.57-1.466,
#  conf. interval (p-value=0.95): 0.744-1.163
# ***
# Aggregate R^2 statistic:
#  mean: 0.348, median: 0.366, pred. interval (P(0.025)-P(0.975)): 0.163-0.52,
#  conf. interval (p-value=0.95): 0.269-0.431
# ***
# Aggregate bias(%) statistic:
#  mean: -10.234, median: -13.243, pred. interval (P(0.025)-P(0.975)): -40.919-24.234,
#  conf. interval (p-value=0.95): -28.252-6.081
# ***
# Aggregate RMSE(%) statistic:
#  mean: -165.913, median: -143.338, pred. interval (P(0.025)-P(0.975)): -255.537--103.239,
#  conf. interval (p-value=0.95): -186.713--123.038
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -0.23, median: -0.223,
#  pred. interval (P(0.025)-P(0.975)): -0.451-0.046,
#  conf. interval (p-value=0.95): -0.346--0.122
# ***
# Aggregate RMSE statistic:
#  mean: 0.89, median: 0.893, pred. interval (P(0.025)-P(0.975)): 0.512-1.283,
#  conf. interval (p-value=0.95): 0.699-1.095
# ***
# Aggregate MSE statistic:
#  mean: 0.834, median: 0.797, pred. interval (P(0.025)-P(0.975)): 0.262-1.645,
#  conf. interval (p-value=0.95): 0.494-1.204
# ***
# Aggregate R^2 statistic:
#  mean: 0.14, median: 0.129, pred. interval (P(0.025)-P(0.975)): -0.065-0.411,
#  conf. interval (p-value=0.95): 0.034-0.248
# ***
# Aggregate bias(%) statistic:
#  mean: -23.265, median: -24.357, pred. interval (P(0.025)-P(0.975)): -41.316-6.86,
#  conf. interval (p-value=0.95): -33.402--13.978
# ***
# Aggregate RMSE(%) statistic:
#  mean: 94.536, median: 94.024, pred. interval (P(0.025)-P(0.975)): 66.918-120.171,
#  conf. interval (p-value=0.95): 81.729-108.821
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-4, -3, -2, -1, 0, 1, 2])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 0.2, 0.5, 1, 2, 5])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.68982
# [1]	validation_0-rmse:1.65572
# [2]	validation_0-rmse:1.62321
# [3]	validation_0-rmse:1.59286
# [4]	validation_0-rmse:1.56288
# [5]	validation_0-rmse:1.53634
# [6]	validation_0-rmse:1.50662
# [7]	validation_0-rmse:1.47905
# [8]	validation_0-rmse:1.45076
# [9]	validation_0-rmse:1.42255
# [10]	validation_0-rmse:1.39861
# [11]	validation_0-rmse:1.38043
# [12]	validation_0-rmse:1.35887
# [13]	validation_0-rmse:1.33810
# [14]	validation_0-rmse:1.31898
# [15]	validation_0-rmse:1.29888
# [16]	validation_0-rmse:1.27883
# [17]	validation_0-rmse:1.26006
# [18]	validation_0-rmse:1.24075
# [19]	validation_0-rmse:1.22140
# [20]	validation_0-rmse:1.20523
# [21]	validation_0-rmse:1.18775
# [22]	validation_0-rmse:1.17109
# [23]	validation_0-rmse:1.15525
# [24]	validation_0-rmse:1.14274
# [25]	validation_0-rmse:1.12688
# [26]	validation_0-rmse:1.11322
# [27]	validation_0-rmse:1.10124
# [28]	validation_0-rmse:1.08899
# [29]	validation_0-rmse:1.07600
# [30]	validation_0-rmse:1.06391
# [31]	validation_0-rmse:1.05148
# [32]	validation_0-rmse:1.03789
# [33]	validation_0-rmse:1.02713
# [34]	validation_0-rmse:1.01878
# [35]	validation_0-rmse:1.00776
# [36]	validation_0-rmse:0.99729
# [37]	validation_0-rmse:0.98818
# [38]	validation_0-rmse:0.98019
# [39]	validation_0-rmse:0.97133
# [40]	validation_0-rmse:0.96300
# [41]	validation_0-rmse:0.95549
# [42]	validation_0-rmse:0.94686
# [43]	validation_0-rmse:0.94075
# [44]	validation_0-rmse:0.93395
# [45]	validation_0-rmse:0.92534
# [46]	validation_0-rmse:0.91802
# [47]	validation_0-rmse:0.91002
# [48]	validation_0-rmse:0.90306
# [49]	validation_0-rmse:0.89762
# [50]	validation_0-rmse:0.89236
# [51]	validation_0-rmse:0.88556
# [52]	validation_0-rmse:0.88095
# [53]	validation_0-rmse:0.87286
# [54]	validation_0-rmse:0.86735
# [55]	validation_0-rmse:0.86231
# [56]	validation_0-rmse:0.85857
# [57]	validation_0-rmse:0.85398
# [58]	validation_0-rmse:0.85102
# [59]	validation_0-rmse:0.84749
# [60]	validation_0-rmse:0.84103
# [61]	validation_0-rmse:0.83719
# [62]	validation_0-rmse:0.83374
# [63]	validation_0-rmse:0.83107
# [64]	validation_0-rmse:0.82674
# [65]	validation_0-rmse:0.82208
# [66]	validation_0-rmse:0.81768
# [67]	validation_0-rmse:0.81436
# [68]	validation_0-rmse:0.81092
# [69]	validation_0-rmse:0.80673
# [70]	validation_0-rmse:0.80378
# [71]	validation_0-rmse:0.79946
# [72]	validation_0-rmse:0.79710
# [73]	validation_0-rmse:0.79310
# [74]	validation_0-rmse:0.78970
# [75]	validation_0-rmse:0.78690
# [76]	validation_0-rmse:0.78250
# [77]	validation_0-rmse:0.78008
# [78]	validation_0-rmse:0.77595
# [79]	validation_0-rmse:0.77276
# [80]	validation_0-rmse:0.76947
# [81]	validation_0-rmse:0.76720
# [82]	validation_0-rmse:0.76462
# [83]	validation_0-rmse:0.76148
# [84]	validation_0-rmse:0.75957
# [85]	validation_0-rmse:0.75640
# [86]	validation_0-rmse:0.75446
# [87]	validation_0-rmse:0.75155
# [88]	validation_0-rmse:0.74956
# [89]	validation_0-rmse:0.74690
# [90]	validation_0-rmse:0.74475
# [91]	validation_0-rmse:0.74218
# [92]	validation_0-rmse:0.73963
# [93]	validation_0-rmse:0.73633
# [94]	validation_0-rmse:0.73377
# [95]	validation_0-rmse:0.73172
# [96]	validation_0-rmse:0.73033
# [97]	validation_0-rmse:0.72789
# [98]	validation_0-rmse:0.72613
# [99]	validation_0-rmse:0.72396
# [100]	validation_0-rmse:0.72213
# [101]	validation_0-rmse:0.71955
# [102]	validation_0-rmse:0.71692
# [103]	validation_0-rmse:0.71596

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 103

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.1
# Relative bias(%):  -7.92
# RMSE: 0.7
# Relative RMSE(%):  -106.205
# MSE: 0.5
# R square: 67.9%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-4.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.722
# Uncertainty
# a0: -0.250+/-0.034
# a1: 0.549+/-0.024

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../05_output_data/XGBoost_models/04_LN_Tag_Cs_SENTINEL_2019_XGB_model_2024_final.json")
# Save to text format
f_xgb_model.save_model("../05_output_data/XGBoost_models/04_LN_Tag_Cs_SENTINEL_2019_XGB_model_2024_final.txt")
