# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
biomass_data = './../05_input_data/Sites_with_Sentinel_bands_data_2024.xlsx'
df = pd.read_excel(biomass_data, sheet_name='input_2019')
df.head()
# Out:
#   Site # Origin Dominant_s  LN_GS_cub_m  LN_M_stem_kg_m2  \
# 0      1      n      Birch        4.771            1.792
# 1      2      a       Pine        5.808            2.496
# 2      3      a       Pine        5.796            2.546
# 3      4      a       Pine        5.826            2.643
# 4      5      a       Pine        6.059            2.643
#
#    LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  LN_M_foliage_kg_m2  LN_M_AG_kg_m2  \
# 0                -0.211            -0.261              -2.040          1.932
# 1                -0.073             0.392              -0.139          2.674
# 2                 0.030             0.501              -0.030          2.734
# 3                 0.000             0.419              -0.431          2.785
# 4                 0.122             0.647              -0.386          2.809
#
#         X_N36  ...  r2019B03  r2019B04  r2019B05  r2019B06  r2019B07  \
# 0  298987.203  ...  0.030628  0.266210  0.166299  0.081316  0.793351
# 1  299016.572  ...  0.027934  0.183349  0.102656  0.052144  0.735493
# 2  299072.773  ...  0.026123  0.184066  0.099625  0.050684  0.751436
# 3  299152.693  ...  0.027390  0.177221  0.102540  0.052198  0.732404
# 4  299249.689  ...  0.025702  0.183705  0.101394  0.050437  0.754481
#
#    r2019B08  r2019B09   r2019B10   r2019B11  r2019B12
# 0 -0.733693  0.532051 -15.396488 -11.262037  0.731937
# 1 -0.655456  0.557000 -16.012156  -9.364664  0.584920
# 2 -0.650575  0.568148 -13.609903  -9.726108  0.715177
# 3 -0.648310  0.544717 -14.321650 -10.457536  0.730390
# 4 -0.660382  0.569112 -13.934375 -11.393335  0.817430
#
# [5 rows x 34 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Site #', 'Origin', 'Dominant_s', 'LN_GS_cub_m', 'LN_M_stem_kg_m2', 'LN_M_stem_bark_kg_m2', 'LN_M_crown_kg_m2', 'LN_M_foliage_kg_m2', 'LN_M_AG_kg_m2', 'F_Soil', 'M_Soil', 'X_N36', 'Y_N36', 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'LN_Cs_wood', 'LN_Sr_wood', 'Tag_Cs', 'Tag_Sr', 'LN_Tag_Cs', 'LN_Tag_Sr', 'Cs_2021_kB', 'Sr_2021_kB', 'AEDR_mean', 'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['LN_Tag_Cs', 'LN_Tag_Sr',
                                  'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'])

# Show the first five columns
select.head()
# Out:
#    LN_Tag_Cs  LN_Tag_Sr  r2019B01  r2019B02  r2019B03  r2019B04  r2019B05  \
# 0  -0.898746   2.141524  0.025483  0.040910  0.030628  0.266210  0.166299
# 1   0.287682   2.549180  0.024075  0.038164  0.027934  0.183349  0.102656
# 2   0.556181   2.344549  0.022492  0.038968  0.026123  0.184066  0.099625
# 3   0.313350   2.455424  0.023742  0.037811  0.027390  0.177221  0.102540
# 4  -0.087011   2.821710  0.022916  0.037557  0.025702  0.183705  0.101394
#
#    r2019B06  r2019B07  r2019B08  r2019B09   r2019B10   r2019B11  r2019B12
# 0  0.081316  0.793351 -0.733693  0.532051 -15.396488 -11.262037  0.731937
# 1  0.052144  0.735493 -0.655456  0.557000 -16.012156  -9.364664  0.584920
# 2  0.050684  0.751436 -0.650575  0.568148 -13.609903  -9.726108  0.715177
# 3  0.052198  0.732404 -0.648310  0.544717 -14.321650 -10.457536  0.730390
# 4  0.050437  0.754481 -0.660382  0.569112 -13.934375 -11.393335  0.817430

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LN_Tag_Cs  205 non-null    float64
#  1   LN_Tag_Sr  205 non-null    float64
#  2   r2019B01   205 non-null    float64
#  3   r2019B02   205 non-null    float64
#  4   r2019B03   205 non-null    float64
#  5   r2019B04   205 non-null    float64
#  6   r2019B05   205 non-null    float64
#  7   r2019B06   205 non-null    float64
#  8   r2019B07   205 non-null    float64
#  9   r2019B08   205 non-null    float64
#  10  r2019B09   205 non-null    float64
#  11  r2019B10   205 non-null    float64
#  12  r2019B11   205 non-null    float64
#  13  r2019B12   205 non-null    float64
# dtypes: float64(14)
# memory usage: 22.5 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_s"])["LN_Tag_Cs", "LN_Tag_Sr"].describe()
# Out:
#            LN_Tag_Cs                                                    \
#                count      mean       std       min       25%       50%
# Dominant_s
# Alder           13.0 -1.185909  1.201457 -2.903562 -2.230264 -1.122877
# Aspen            7.0 -1.023735  1.633734 -2.965427 -2.103570 -1.369487
# Birch           45.0 -1.040653  1.021197 -4.379730 -1.265666 -0.847298
# Oak              9.0 -0.562587  1.857761 -4.704870 -1.098612  0.115513
# Pine           130.0 -0.471626  1.250166 -4.005355 -1.136277 -0.205292
# Spruce           1.0 -2.409639       NaN -2.409639 -2.409639 -2.409639
#
#                                LN_Tag_Sr                                \
#                  75%       max     count      mean       std       min
# Dominant_s
# Alder      -0.498161  0.853490      13.0  1.149722  0.672975 -0.167054
# Aspen      -0.088089  1.552087       7.0  2.321064  0.727889  1.396245
# Birch      -0.459154  0.439951      45.0  2.415305  0.869843  0.182322
# Oak         0.663547  1.338048       9.0  1.544409  0.935054  0.549108
# Pine        0.420004  1.645806     130.0  2.329967  0.993133 -0.784714
# Spruce     -2.409639 -2.409639       1.0  1.817077       NaN  1.817077
#
#
#                  25%       50%       75%       max
# Dominant_s
# Alder       0.672094  1.346020  1.543687  2.133509
# Aspen       1.973656  2.071837  2.717515  3.397022
# Birch       1.891843  2.506529  2.687847  5.227895
# Oak         0.753772  1.568616  1.923050  3.342567
# Pine        1.690423  2.400414  3.098610  4.820282
# Spruce      1.817077  1.817077  1.817077  1.817077

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#         LN_Tag_Cs   LN_Tag_Sr    r2019B01    r2019B02    r2019B03    r2019B04  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean    -0.674130    2.236561    0.023623    0.038592    0.028895    0.219361
# std      1.266477    0.986675    0.006540    0.007341    0.010704    0.049137
# min     -4.704870   -0.784714    0.014194    0.026402    0.015301    0.140309
# 25%     -1.435085    1.568616    0.019895    0.034516    0.022685    0.183403
# 50%     -0.545366    2.275067    0.022415    0.036966    0.026123    0.199665
# 75%      0.288154    2.921624    0.025339    0.040237    0.030628    0.250913
# max      1.645806    5.227895    0.059051    0.077038    0.081675    0.423326
#
#          r2019B05    r2019B06    r2019B07    r2019B08    r2019B09    r2019B10  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.131344    0.068068    0.759654   -0.692408    0.526662  -15.737088
# std      0.036023    0.026479    0.091469    0.070703    0.144729    1.547144
# min      0.078918    0.035914    0.363395   -0.849155   -0.037478  -22.820204
# 25%      0.102471    0.051182    0.727961   -0.735660    0.470852  -16.494671
# 50%      0.121704    0.060839    0.771691   -0.693779    0.562326  -15.454248
# 75%      0.153232    0.078586    0.814177   -0.660039    0.626609  -14.760403
# max      0.252487    0.196544    0.914709   -0.389420    0.740912  -12.365163
#
#          r2019B11    r2019B12
# count  205.000000  205.000000
# mean   -10.490763    0.668847
# std      1.471517    0.081010
# min    -16.820473    0.386847
# 25%    -11.364958    0.615553
# 50%    -10.299303    0.666882
# 75%     -9.547850    0.728737
# max     -5.703308    0.877743

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "LN_Tag_Cs"
indep_variables = ['r2019B01', 'r2019B04', 'r2019B08', 'r2019B10', 'r2019B11']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      LN_Tag_Cs  LN_Tag_Sr  r2019B01  r2019B02  r2019B03  r2019B04  r2019B05  \
# 0    -0.898746   2.141524  0.025483  0.040910  0.030628  0.266210  0.166299
# 1     0.287682   2.549180  0.024075  0.038164  0.027934  0.183349  0.102656
# 2     0.556181   2.344549  0.022492  0.038968  0.026123  0.184066  0.099625
# 3     0.313350   2.455424  0.023742  0.037811  0.027390  0.177221  0.102540
# 4    -0.087011   2.821710  0.022916  0.037557  0.025702  0.183705  0.101394
# ..         ...        ...       ...       ...       ...       ...       ...
# 200  -0.427127   1.648659  0.021045  0.035508  0.026143  0.199300  0.095774
# 201  -0.235870   2.466215  0.019699  0.034608  0.022056  0.208607  0.097603
# 202   0.196182   1.677646  0.020443  0.036471  0.027264  0.177812  0.105252
# 203   1.559113   1.897120  0.020905  0.037477  0.024510  0.213548  0.117474
# 204  -0.924323   1.799665  0.020603  0.035681  0.024394  0.196295  0.093705
#
#      r2019B06  r2019B07  r2019B08  r2019B09   r2019B10   r2019B11  r2019B12
# 0    0.081316  0.793351 -0.733693  0.532051 -15.396488 -11.262037  0.731937
# 1    0.052144  0.735493 -0.655456  0.557000 -16.012156  -9.364664  0.584920
# 2    0.050684  0.751436 -0.650575  0.568148 -13.609903  -9.726108  0.715177
# 3    0.052198  0.732404 -0.648310  0.544717 -14.321650 -10.457536  0.730390
# 4    0.050437  0.754481 -0.660382  0.569112 -13.934375 -11.393335  0.817430
# ..        ...       ...       ...       ...        ...        ...       ...
# 200  0.045219  0.768490 -0.697576  0.629676 -14.238754  -8.134297  0.571699
# 201  0.044494  0.808730 -0.715291  0.648211 -12.803756 -11.046638  0.862806
# 202  0.054239  0.733975 -0.659608  0.532328 -16.458857 -10.048693  0.610619
# 203  0.055805  0.794069 -0.701348  0.585421 -13.451569 -10.497206  0.785254
# 204  0.046686  0.778950 -0.692400  0.615253 -13.836473 -10.086078  0.729378
#
# [205 rows x 14 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    r2019B01  r2019B04  r2019B08   r2019B10   r2019B11
# 0  0.025483  0.266210 -0.733693 -15.396488 -11.262037
# 1  0.024075  0.183349 -0.655456 -16.012156  -9.364664
# 2  0.022492  0.184066 -0.650575 -13.609903  -9.726108
# 3  0.023742  0.177221 -0.648310 -14.321650 -10.457536
# 4  0.022916  0.183705 -0.660382 -13.934375 -11.393335

# %%
# Columns in "y" data collections
y.head()
# Out:
#    LN_Tag_Cs
# 0  -0.898746
# 1   0.287682
# 2   0.556181
# 3   0.313350
# 4  -0.087011

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.41513507931767546, 0.21859627573686524, 0.03091314502075071]
#     Mean: 0.222
#     Std: 0.157
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.14035729 0.92893965 1.13526307]
#     Mean: 1.068
#     Std: 0.098
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.8094090616348165, 0.7489987953127359, 0.964151190789152]
#     Mean: 0.841
#     Std: 0.091
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.752002626894473                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.11989669723875046                # gamma
print('Gamma: ' + str(p2))

p3 = 0.03080239065859549                # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 3                                  # max_depth
print('Max_depth: ' + str(p4))

p5 = 104                                # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.6466036483851302                 # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.752002626894473
# Gamma: 0.11989669723875046
# Learning_rate: 0.03080239065859549
# Max_depth: 3
# N_estimators: 104
# Subsample: 0.6466036483851302

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.70855	validation_1-rmse:1.60851
# [1]	validation_0-rmse:1.67824	validation_1-rmse:1.57866
# [2]	validation_0-rmse:1.64600	validation_1-rmse:1.55103
# [3]	validation_0-rmse:1.61286	validation_1-rmse:1.52060
# [4]	validation_0-rmse:1.58453	validation_1-rmse:1.49045
# [5]	validation_0-rmse:1.55208	validation_1-rmse:1.46412
# [6]	validation_0-rmse:1.52556	validation_1-rmse:1.44603
# [7]	validation_0-rmse:1.49765	validation_1-rmse:1.42195
# [8]	validation_0-rmse:1.47050	validation_1-rmse:1.40146
# [9]	validation_0-rmse:1.44586	validation_1-rmse:1.38214
# [10]	validation_0-rmse:1.42068	validation_1-rmse:1.35725
# [11]	validation_0-rmse:1.39935	validation_1-rmse:1.34047
# [12]	validation_0-rmse:1.37937	validation_1-rmse:1.32583
# [13]	validation_0-rmse:1.35810	validation_1-rmse:1.30933
# [14]	validation_0-rmse:1.33662	validation_1-rmse:1.29239
# [15]	validation_0-rmse:1.31244	validation_1-rmse:1.27782
# [16]	validation_0-rmse:1.29396	validation_1-rmse:1.26508
# [17]	validation_0-rmse:1.27387	validation_1-rmse:1.25222
# [18]	validation_0-rmse:1.25717	validation_1-rmse:1.23738
# [19]	validation_0-rmse:1.24037	validation_1-rmse:1.22307
# [20]	validation_0-rmse:1.22017	validation_1-rmse:1.21021
# [21]	validation_0-rmse:1.20338	validation_1-rmse:1.20092
# [22]	validation_0-rmse:1.18885	validation_1-rmse:1.19211
# [23]	validation_0-rmse:1.17176	validation_1-rmse:1.17798
# [24]	validation_0-rmse:1.15744	validation_1-rmse:1.16775
# [25]	validation_0-rmse:1.14107	validation_1-rmse:1.15477
# [26]	validation_0-rmse:1.12711	validation_1-rmse:1.14968
# [27]	validation_0-rmse:1.11075	validation_1-rmse:1.13593
# [28]	validation_0-rmse:1.09887	validation_1-rmse:1.12871
# [29]	validation_0-rmse:1.08476	validation_1-rmse:1.12252
# [30]	validation_0-rmse:1.07122	validation_1-rmse:1.11179
# [31]	validation_0-rmse:1.06197	validation_1-rmse:1.10445
# [32]	validation_0-rmse:1.05051	validation_1-rmse:1.10057
# [33]	validation_0-rmse:1.03672	validation_1-rmse:1.09045
# [34]	validation_0-rmse:1.02508	validation_1-rmse:1.08281
# [35]	validation_0-rmse:1.01537	validation_1-rmse:1.07383
# [36]	validation_0-rmse:1.00281	validation_1-rmse:1.06686
# [37]	validation_0-rmse:0.99263	validation_1-rmse:1.06172
# [38]	validation_0-rmse:0.98316	validation_1-rmse:1.05831
# [39]	validation_0-rmse:0.97438	validation_1-rmse:1.05458
# [40]	validation_0-rmse:0.96660	validation_1-rmse:1.05360
# [41]	validation_0-rmse:0.95870	validation_1-rmse:1.04863
# [42]	validation_0-rmse:0.95167	validation_1-rmse:1.04451
# [43]	validation_0-rmse:0.94357	validation_1-rmse:1.04190
# [44]	validation_0-rmse:0.93661	validation_1-rmse:1.04040
# [45]	validation_0-rmse:0.92822	validation_1-rmse:1.03922
# [46]	validation_0-rmse:0.92014	validation_1-rmse:1.03550
# [47]	validation_0-rmse:0.91173	validation_1-rmse:1.03244
# [48]	validation_0-rmse:0.90536	validation_1-rmse:1.02811
# [49]	validation_0-rmse:0.89873	validation_1-rmse:1.02590
# [50]	validation_0-rmse:0.89062	validation_1-rmse:1.02187
# [51]	validation_0-rmse:0.88517	validation_1-rmse:1.02000
# [52]	validation_0-rmse:0.87876	validation_1-rmse:1.02049
# [53]	validation_0-rmse:0.87262	validation_1-rmse:1.02019
# [54]	validation_0-rmse:0.86549	validation_1-rmse:1.01744
# [55]	validation_0-rmse:0.85704	validation_1-rmse:1.01333
# [56]	validation_0-rmse:0.85221	validation_1-rmse:1.01040
# [57]	validation_0-rmse:0.84683	validation_1-rmse:1.00694
# [58]	validation_0-rmse:0.84150	validation_1-rmse:1.00454
# [59]	validation_0-rmse:0.83528	validation_1-rmse:1.00560
# [60]	validation_0-rmse:0.83123	validation_1-rmse:1.00789
# [61]	validation_0-rmse:0.82673	validation_1-rmse:1.01027
# [62]	validation_0-rmse:0.82375	validation_1-rmse:1.00788
# [63]	validation_0-rmse:0.82046	validation_1-rmse:1.00733
# [64]	validation_0-rmse:0.81793	validation_1-rmse:1.01020
# [65]	validation_0-rmse:0.81293	validation_1-rmse:1.01059
# [66]	validation_0-rmse:0.80854	validation_1-rmse:1.00728
# [67]	validation_0-rmse:0.80439	validation_1-rmse:1.00773
# [68]	validation_0-rmse:0.79963	validation_1-rmse:1.00466
# [69]	validation_0-rmse:0.79535	validation_1-rmse:1.00374
# [70]	validation_0-rmse:0.79203	validation_1-rmse:1.00176
# [71]	validation_0-rmse:0.78816	validation_1-rmse:1.00106
# [72]	validation_0-rmse:0.78486	validation_1-rmse:0.99744
# [73]	validation_0-rmse:0.78303	validation_1-rmse:0.99873
# [74]	validation_0-rmse:0.77906	validation_1-rmse:0.99909
# [75]	validation_0-rmse:0.77641	validation_1-rmse:1.00430
# [76]	validation_0-rmse:0.77343	validation_1-rmse:1.00581
# [77]	validation_0-rmse:0.77081	validation_1-rmse:1.00290
# [78]	validation_0-rmse:0.76629	validation_1-rmse:1.00156
# [79]	validation_0-rmse:0.76265	validation_1-rmse:0.99963
# [80]	validation_0-rmse:0.75949	validation_1-rmse:1.00278
# [81]	validation_0-rmse:0.75550	validation_1-rmse:0.99849
# [82]	validation_0-rmse:0.75313	validation_1-rmse:1.00181
# [83]	validation_0-rmse:0.74846	validation_1-rmse:1.00259
# [84]	validation_0-rmse:0.74496	validation_1-rmse:0.99898
# [85]	validation_0-rmse:0.74101	validation_1-rmse:0.99622
# [86]	validation_0-rmse:0.73751	validation_1-rmse:0.99846
# [87]	validation_0-rmse:0.73378	validation_1-rmse:1.00050
# [88]	validation_0-rmse:0.73039	validation_1-rmse:1.00402
# [89]	validation_0-rmse:0.72809	validation_1-rmse:1.00623
# [90]	validation_0-rmse:0.72641	validation_1-rmse:1.00885
# [91]	validation_0-rmse:0.72414	validation_1-rmse:1.01066
# [92]	validation_0-rmse:0.72163	validation_1-rmse:1.01053
# [93]	validation_0-rmse:0.71849	validation_1-rmse:1.01089
# [94]	validation_0-rmse:0.71677	validation_1-rmse:1.01117
# [95]	validation_0-rmse:0.71320	validation_1-rmse:1.01020
# [96]	validation_0-rmse:0.71086	validation_1-rmse:1.00965
# [97]	validation_0-rmse:0.70883	validation_1-rmse:1.00394
# [98]	validation_0-rmse:0.70727	validation_1-rmse:1.00392
# [99]	validation_0-rmse:0.70518	validation_1-rmse:1.00592
# [100]	validation_0-rmse:0.70207	validation_1-rmse:1.00492
# [101]	validation_0-rmse:0.69913	validation_1-rmse:1.00525
# [102]	validation_0-rmse:0.69733	validation_1-rmse:1.00798
# [103]	validation_0-rmse:0.69412	validation_1-rmse:1.01013
# [0]	validation_0-rmse:1.62683	validation_1-rmse:1.91869
# [1]	validation_0-rmse:1.59485	validation_1-rmse:1.88388
# [2]	validation_0-rmse:1.56414	validation_1-rmse:1.85551
# [3]	validation_0-rmse:1.53295	validation_1-rmse:1.82411
# [4]	validation_0-rmse:1.50520	validation_1-rmse:1.79957
# [5]	validation_0-rmse:1.47849	validation_1-rmse:1.77482
# [6]	validation_0-rmse:1.45104	validation_1-rmse:1.74767
# [7]	validation_0-rmse:1.42150	validation_1-rmse:1.71777
# [8]	validation_0-rmse:1.39714	validation_1-rmse:1.69542
# [9]	validation_0-rmse:1.37304	validation_1-rmse:1.67052
# [10]	validation_0-rmse:1.35193	validation_1-rmse:1.64829
# [11]	validation_0-rmse:1.32975	validation_1-rmse:1.62233
# [12]	validation_0-rmse:1.30693	validation_1-rmse:1.59865
# [13]	validation_0-rmse:1.28853	validation_1-rmse:1.58079
# [14]	validation_0-rmse:1.27168	validation_1-rmse:1.56485
# [15]	validation_0-rmse:1.25154	validation_1-rmse:1.54008
# [16]	validation_0-rmse:1.22960	validation_1-rmse:1.52271
# [17]	validation_0-rmse:1.21061	validation_1-rmse:1.50335
# [18]	validation_0-rmse:1.19529	validation_1-rmse:1.49035
# [19]	validation_0-rmse:1.17826	validation_1-rmse:1.47133
# [20]	validation_0-rmse:1.16184	validation_1-rmse:1.45047
# [21]	validation_0-rmse:1.14725	validation_1-rmse:1.43452
# [22]	validation_0-rmse:1.13229	validation_1-rmse:1.42675
# [23]	validation_0-rmse:1.12083	validation_1-rmse:1.42170
# [24]	validation_0-rmse:1.10679	validation_1-rmse:1.41240
# [25]	validation_0-rmse:1.09660	validation_1-rmse:1.40120
# [26]	validation_0-rmse:1.08223	validation_1-rmse:1.39271
# [27]	validation_0-rmse:1.07011	validation_1-rmse:1.38198
# [28]	validation_0-rmse:1.05791	validation_1-rmse:1.37130
# [29]	validation_0-rmse:1.04470	validation_1-rmse:1.35228
# [30]	validation_0-rmse:1.03400	validation_1-rmse:1.34460
# [31]	validation_0-rmse:1.02257	validation_1-rmse:1.33223
# [32]	validation_0-rmse:1.01190	validation_1-rmse:1.31767
# [33]	validation_0-rmse:0.99965	validation_1-rmse:1.29965
# [34]	validation_0-rmse:0.99007	validation_1-rmse:1.29285
# [35]	validation_0-rmse:0.97651	validation_1-rmse:1.28512
# [36]	validation_0-rmse:0.96606	validation_1-rmse:1.27493
# [37]	validation_0-rmse:0.95553	validation_1-rmse:1.26502
# [38]	validation_0-rmse:0.94757	validation_1-rmse:1.25919
# [39]	validation_0-rmse:0.93928	validation_1-rmse:1.24874
# [40]	validation_0-rmse:0.93224	validation_1-rmse:1.24388
# [41]	validation_0-rmse:0.92534	validation_1-rmse:1.23691
# [42]	validation_0-rmse:0.91868	validation_1-rmse:1.23107
# [43]	validation_0-rmse:0.90970	validation_1-rmse:1.22393
# [44]	validation_0-rmse:0.90262	validation_1-rmse:1.21811
# [45]	validation_0-rmse:0.89492	validation_1-rmse:1.21110
# [46]	validation_0-rmse:0.88730	validation_1-rmse:1.20470
# [47]	validation_0-rmse:0.88166	validation_1-rmse:1.19707
# [48]	validation_0-rmse:0.87595	validation_1-rmse:1.18926
# [49]	validation_0-rmse:0.86988	validation_1-rmse:1.18458
# [50]	validation_0-rmse:0.86302	validation_1-rmse:1.17782
# [51]	validation_0-rmse:0.85630	validation_1-rmse:1.17485
# [52]	validation_0-rmse:0.85240	validation_1-rmse:1.17158
# [53]	validation_0-rmse:0.84711	validation_1-rmse:1.16722
# [54]	validation_0-rmse:0.83977	validation_1-rmse:1.15943
# [55]	validation_0-rmse:0.83358	validation_1-rmse:1.15235
# [56]	validation_0-rmse:0.83064	validation_1-rmse:1.14977
# [57]	validation_0-rmse:0.82551	validation_1-rmse:1.14653
# [58]	validation_0-rmse:0.82004	validation_1-rmse:1.14288
# [59]	validation_0-rmse:0.81501	validation_1-rmse:1.13679
# [60]	validation_0-rmse:0.81050	validation_1-rmse:1.13411
# [61]	validation_0-rmse:0.80544	validation_1-rmse:1.13128
# [62]	validation_0-rmse:0.80112	validation_1-rmse:1.12980
# [63]	validation_0-rmse:0.79671	validation_1-rmse:1.12665
# [64]	validation_0-rmse:0.79258	validation_1-rmse:1.12317
# [65]	validation_0-rmse:0.78876	validation_1-rmse:1.11972
# [66]	validation_0-rmse:0.78527	validation_1-rmse:1.11763
# [67]	validation_0-rmse:0.78287	validation_1-rmse:1.11593
# [68]	validation_0-rmse:0.77783	validation_1-rmse:1.11195
# [69]	validation_0-rmse:0.77443	validation_1-rmse:1.10701
# [70]	validation_0-rmse:0.76987	validation_1-rmse:1.10657
# [71]	validation_0-rmse:0.76633	validation_1-rmse:1.10559
# [72]	validation_0-rmse:0.76232	validation_1-rmse:1.10403
# [73]	validation_0-rmse:0.76038	validation_1-rmse:1.10167
# [74]	validation_0-rmse:0.75805	validation_1-rmse:1.10044
# [75]	validation_0-rmse:0.75482	validation_1-rmse:1.09693
# [76]	validation_0-rmse:0.75304	validation_1-rmse:1.09596
# [77]	validation_0-rmse:0.75023	validation_1-rmse:1.09395
# [78]	validation_0-rmse:0.74695	validation_1-rmse:1.09061
# [79]	validation_0-rmse:0.74367	validation_1-rmse:1.09054
# [80]	validation_0-rmse:0.74079	validation_1-rmse:1.08728
# [81]	validation_0-rmse:0.73812	validation_1-rmse:1.08449
# [82]	validation_0-rmse:0.73545	validation_1-rmse:1.08306
# [83]	validation_0-rmse:0.73358	validation_1-rmse:1.08176
# [84]	validation_0-rmse:0.73024	validation_1-rmse:1.07781
# [85]	validation_0-rmse:0.72849	validation_1-rmse:1.07754
# [86]	validation_0-rmse:0.72384	validation_1-rmse:1.07576
# [87]	validation_0-rmse:0.72047	validation_1-rmse:1.07568
# [88]	validation_0-rmse:0.71770	validation_1-rmse:1.07516
# [89]	validation_0-rmse:0.71519	validation_1-rmse:1.07424
# [90]	validation_0-rmse:0.71263	validation_1-rmse:1.07082
# [91]	validation_0-rmse:0.70978	validation_1-rmse:1.06952
# [92]	validation_0-rmse:0.70732	validation_1-rmse:1.06488
# [93]	validation_0-rmse:0.70508	validation_1-rmse:1.06308
# [94]	validation_0-rmse:0.70187	validation_1-rmse:1.06256
# [95]	validation_0-rmse:0.69928	validation_1-rmse:1.06152
# [96]	validation_0-rmse:0.69748	validation_1-rmse:1.05986
# [97]	validation_0-rmse:0.69500	validation_1-rmse:1.05988
# [98]	validation_0-rmse:0.69325	validation_1-rmse:1.06022
# [99]	validation_0-rmse:0.69063	validation_1-rmse:1.05847
# [100]	validation_0-rmse:0.68877	validation_1-rmse:1.05857
# [101]	validation_0-rmse:0.68640	validation_1-rmse:1.05719
# [102]	validation_0-rmse:0.68494	validation_1-rmse:1.05733
# [103]	validation_0-rmse:0.68343	validation_1-rmse:1.05577
# [0]	validation_0-rmse:1.67399	validation_1-rmse:1.77322
# [1]	validation_0-rmse:1.64104	validation_1-rmse:1.74716
# [2]	validation_0-rmse:1.60806	validation_1-rmse:1.71911
# [3]	validation_0-rmse:1.57842	validation_1-rmse:1.69454
# [4]	validation_0-rmse:1.55043	validation_1-rmse:1.66986
# [5]	validation_0-rmse:1.52211	validation_1-rmse:1.64471
# [6]	validation_0-rmse:1.49767	validation_1-rmse:1.62470
# [7]	validation_0-rmse:1.47055	validation_1-rmse:1.60227
# [8]	validation_0-rmse:1.44372	validation_1-rmse:1.57796
# [9]	validation_0-rmse:1.41678	validation_1-rmse:1.55632
# [10]	validation_0-rmse:1.39527	validation_1-rmse:1.53855
# [11]	validation_0-rmse:1.37273	validation_1-rmse:1.52410
# [12]	validation_0-rmse:1.35190	validation_1-rmse:1.50577
# [13]	validation_0-rmse:1.33096	validation_1-rmse:1.49007
# [14]	validation_0-rmse:1.30894	validation_1-rmse:1.47272
# [15]	validation_0-rmse:1.29167	validation_1-rmse:1.46248
# [16]	validation_0-rmse:1.27047	validation_1-rmse:1.44320
# [17]	validation_0-rmse:1.25151	validation_1-rmse:1.42994
# [18]	validation_0-rmse:1.23325	validation_1-rmse:1.41828
# [19]	validation_0-rmse:1.21493	validation_1-rmse:1.40347
# [20]	validation_0-rmse:1.19682	validation_1-rmse:1.38903
# [21]	validation_0-rmse:1.18119	validation_1-rmse:1.37653
# [22]	validation_0-rmse:1.16417	validation_1-rmse:1.36658
# [23]	validation_0-rmse:1.14818	validation_1-rmse:1.35458
# [24]	validation_0-rmse:1.13207	validation_1-rmse:1.34474
# [25]	validation_0-rmse:1.11841	validation_1-rmse:1.33468
# [26]	validation_0-rmse:1.10347	validation_1-rmse:1.32589
# [27]	validation_0-rmse:1.08965	validation_1-rmse:1.31597
# [28]	validation_0-rmse:1.07381	validation_1-rmse:1.30260
# [29]	validation_0-rmse:1.06154	validation_1-rmse:1.29023
# [30]	validation_0-rmse:1.05048	validation_1-rmse:1.28099
# [31]	validation_0-rmse:1.03789	validation_1-rmse:1.27325
# [32]	validation_0-rmse:1.02539	validation_1-rmse:1.26439
# [33]	validation_0-rmse:1.01270	validation_1-rmse:1.25404
# [34]	validation_0-rmse:1.00190	validation_1-rmse:1.24601
# [35]	validation_0-rmse:0.99078	validation_1-rmse:1.23760
# [36]	validation_0-rmse:0.98117	validation_1-rmse:1.23062
# [37]	validation_0-rmse:0.97255	validation_1-rmse:1.22473
# [38]	validation_0-rmse:0.96416	validation_1-rmse:1.21897
# [39]	validation_0-rmse:0.95570	validation_1-rmse:1.21314
# [40]	validation_0-rmse:0.94714	validation_1-rmse:1.20657
# [41]	validation_0-rmse:0.93842	validation_1-rmse:1.19943
# [42]	validation_0-rmse:0.93281	validation_1-rmse:1.19588
# [43]	validation_0-rmse:0.92449	validation_1-rmse:1.19343
# [44]	validation_0-rmse:0.91713	validation_1-rmse:1.18877
# [45]	validation_0-rmse:0.90976	validation_1-rmse:1.18175
# [46]	validation_0-rmse:0.90236	validation_1-rmse:1.17676
# [47]	validation_0-rmse:0.89449	validation_1-rmse:1.16824
# [48]	validation_0-rmse:0.88632	validation_1-rmse:1.16232
# [49]	validation_0-rmse:0.88169	validation_1-rmse:1.15788
# [50]	validation_0-rmse:0.87552	validation_1-rmse:1.15287
# [51]	validation_0-rmse:0.86877	validation_1-rmse:1.14867
# [52]	validation_0-rmse:0.86155	validation_1-rmse:1.14806
# [53]	validation_0-rmse:0.85512	validation_1-rmse:1.14257
# [54]	validation_0-rmse:0.84739	validation_1-rmse:1.14318
# [55]	validation_0-rmse:0.84059	validation_1-rmse:1.13822
# [56]	validation_0-rmse:0.83526	validation_1-rmse:1.13456
# [57]	validation_0-rmse:0.82905	validation_1-rmse:1.12944
# [58]	validation_0-rmse:0.82391	validation_1-rmse:1.12457
# [59]	validation_0-rmse:0.82017	validation_1-rmse:1.12230
# [60]	validation_0-rmse:0.81594	validation_1-rmse:1.12338
# [61]	validation_0-rmse:0.81234	validation_1-rmse:1.12021
# [62]	validation_0-rmse:0.80790	validation_1-rmse:1.11838
# [63]	validation_0-rmse:0.80331	validation_1-rmse:1.11563
# [64]	validation_0-rmse:0.79870	validation_1-rmse:1.11285
# [65]	validation_0-rmse:0.79496	validation_1-rmse:1.11027
# [66]	validation_0-rmse:0.79072	validation_1-rmse:1.10711
# [67]	validation_0-rmse:0.78688	validation_1-rmse:1.10823
# [68]	validation_0-rmse:0.78153	validation_1-rmse:1.10521
# [69]	validation_0-rmse:0.77879	validation_1-rmse:1.10258
# [70]	validation_0-rmse:0.77549	validation_1-rmse:1.10059
# [71]	validation_0-rmse:0.77050	validation_1-rmse:1.09155
# [72]	validation_0-rmse:0.76662	validation_1-rmse:1.09234
# [73]	validation_0-rmse:0.76305	validation_1-rmse:1.09093
# [74]	validation_0-rmse:0.76077	validation_1-rmse:1.09326
# [75]	validation_0-rmse:0.75799	validation_1-rmse:1.09158
# [76]	validation_0-rmse:0.75393	validation_1-rmse:1.08924
# [77]	validation_0-rmse:0.74944	validation_1-rmse:1.08864
# [78]	validation_0-rmse:0.74709	validation_1-rmse:1.09013
# [79]	validation_0-rmse:0.74344	validation_1-rmse:1.08926
# [80]	validation_0-rmse:0.74069	validation_1-rmse:1.09053
# [81]	validation_0-rmse:0.73806	validation_1-rmse:1.09198
# [82]	validation_0-rmse:0.73518	validation_1-rmse:1.09092
# [83]	validation_0-rmse:0.73142	validation_1-rmse:1.09319
# [84]	validation_0-rmse:0.72887	validation_1-rmse:1.09420
# [85]	validation_0-rmse:0.72503	validation_1-rmse:1.09096
# [86]	validation_0-rmse:0.72184	validation_1-rmse:1.08780
# [87]	validation_0-rmse:0.72018	validation_1-rmse:1.08597
# [88]	validation_0-rmse:0.71831	validation_1-rmse:1.08505
# [89]	validation_0-rmse:0.71427	validation_1-rmse:1.08185
# [90]	validation_0-rmse:0.70949	validation_1-rmse:1.07807
# [91]	validation_0-rmse:0.70797	validation_1-rmse:1.07841
# [92]	validation_0-rmse:0.70624	validation_1-rmse:1.07764
# [93]	validation_0-rmse:0.70303	validation_1-rmse:1.07546
# [94]	validation_0-rmse:0.70080	validation_1-rmse:1.07607
# [95]	validation_0-rmse:0.69764	validation_1-rmse:1.07532
# [96]	validation_0-rmse:0.69620	validation_1-rmse:1.07571
# [97]	validation_0-rmse:0.69323	validation_1-rmse:1.07557
# [98]	validation_0-rmse:0.69109	validation_1-rmse:1.07504
# [99]	validation_0-rmse:0.68828	validation_1-rmse:1.07607
# [100]	validation_0-rmse:0.68690	validation_1-rmse:1.07526
# [101]	validation_0-rmse:0.68423	validation_1-rmse:1.07398
# [102]	validation_0-rmse:0.68235	validation_1-rmse:1.07075
# [103]	validation_0-rmse:0.67931	validation_1-rmse:1.07225
# [0]	validation_0-rmse:1.66614	validation_1-rmse:1.77572
# [1]	validation_0-rmse:1.63300	validation_1-rmse:1.75348
# [2]	validation_0-rmse:1.59914	validation_1-rmse:1.72818
# [3]	validation_0-rmse:1.57086	validation_1-rmse:1.70514
# [4]	validation_0-rmse:1.53938	validation_1-rmse:1.67856
# [5]	validation_0-rmse:1.50689	validation_1-rmse:1.65687
# [6]	validation_0-rmse:1.47874	validation_1-rmse:1.63553
# [7]	validation_0-rmse:1.45286	validation_1-rmse:1.60967
# [8]	validation_0-rmse:1.42488	validation_1-rmse:1.59272
# [9]	validation_0-rmse:1.40301	validation_1-rmse:1.57593
# [10]	validation_0-rmse:1.37744	validation_1-rmse:1.55817
# [11]	validation_0-rmse:1.36053	validation_1-rmse:1.54226
# [12]	validation_0-rmse:1.33759	validation_1-rmse:1.52609
# [13]	validation_0-rmse:1.31644	validation_1-rmse:1.51243
# [14]	validation_0-rmse:1.29457	validation_1-rmse:1.49741
# [15]	validation_0-rmse:1.27340	validation_1-rmse:1.48440
# [16]	validation_0-rmse:1.25679	validation_1-rmse:1.46975
# [17]	validation_0-rmse:1.23823	validation_1-rmse:1.45861
# [18]	validation_0-rmse:1.22012	validation_1-rmse:1.44464
# [19]	validation_0-rmse:1.20009	validation_1-rmse:1.43159
# [20]	validation_0-rmse:1.17973	validation_1-rmse:1.41277
# [21]	validation_0-rmse:1.16122	validation_1-rmse:1.39539
# [22]	validation_0-rmse:1.14566	validation_1-rmse:1.38604
# [23]	validation_0-rmse:1.12876	validation_1-rmse:1.38107
# [24]	validation_0-rmse:1.11382	validation_1-rmse:1.37366
# [25]	validation_0-rmse:1.09934	validation_1-rmse:1.36201
# [26]	validation_0-rmse:1.08424	validation_1-rmse:1.35213
# [27]	validation_0-rmse:1.07222	validation_1-rmse:1.34126
# [28]	validation_0-rmse:1.05812	validation_1-rmse:1.32710
# [29]	validation_0-rmse:1.04509	validation_1-rmse:1.31624
# [30]	validation_0-rmse:1.03413	validation_1-rmse:1.31387
# [31]	validation_0-rmse:1.02492	validation_1-rmse:1.31725
# [32]	validation_0-rmse:1.01299	validation_1-rmse:1.30745
# [33]	validation_0-rmse:1.00393	validation_1-rmse:1.29998
# [34]	validation_0-rmse:0.99063	validation_1-rmse:1.29424
# [35]	validation_0-rmse:0.98185	validation_1-rmse:1.28746
# [36]	validation_0-rmse:0.97086	validation_1-rmse:1.28127
# [37]	validation_0-rmse:0.96326	validation_1-rmse:1.27286
# [38]	validation_0-rmse:0.95390	validation_1-rmse:1.26659
# [39]	validation_0-rmse:0.94326	validation_1-rmse:1.25791
# [40]	validation_0-rmse:0.93469	validation_1-rmse:1.25443
# [41]	validation_0-rmse:0.92509	validation_1-rmse:1.24853
# [42]	validation_0-rmse:0.91636	validation_1-rmse:1.24342
# [43]	validation_0-rmse:0.90959	validation_1-rmse:1.23904
# [44]	validation_0-rmse:0.89981	validation_1-rmse:1.23107
# [45]	validation_0-rmse:0.89162	validation_1-rmse:1.22642
# [46]	validation_0-rmse:0.88205	validation_1-rmse:1.21920
# [47]	validation_0-rmse:0.87466	validation_1-rmse:1.21409
# [48]	validation_0-rmse:0.86706	validation_1-rmse:1.21294
# [49]	validation_0-rmse:0.86159	validation_1-rmse:1.21062
# [50]	validation_0-rmse:0.85333	validation_1-rmse:1.20750
# [51]	validation_0-rmse:0.84798	validation_1-rmse:1.20483
# [52]	validation_0-rmse:0.84181	validation_1-rmse:1.20135
# [53]	validation_0-rmse:0.83681	validation_1-rmse:1.19903
# [54]	validation_0-rmse:0.82885	validation_1-rmse:1.19277
# [55]	validation_0-rmse:0.82287	validation_1-rmse:1.18947
# [56]	validation_0-rmse:0.81717	validation_1-rmse:1.18791
# [57]	validation_0-rmse:0.81094	validation_1-rmse:1.18139
# [58]	validation_0-rmse:0.80568	validation_1-rmse:1.17518
# [59]	validation_0-rmse:0.80016	validation_1-rmse:1.17195
# [60]	validation_0-rmse:0.79582	validation_1-rmse:1.17008
# [61]	validation_0-rmse:0.78943	validation_1-rmse:1.16697
# [62]	validation_0-rmse:0.78409	validation_1-rmse:1.16630
# [63]	validation_0-rmse:0.77997	validation_1-rmse:1.16447
# [64]	validation_0-rmse:0.77468	validation_1-rmse:1.16924
# [65]	validation_0-rmse:0.76921	validation_1-rmse:1.16782
# [66]	validation_0-rmse:0.76515	validation_1-rmse:1.16696
# [67]	validation_0-rmse:0.76018	validation_1-rmse:1.16444
# [68]	validation_0-rmse:0.75519	validation_1-rmse:1.16740
# [69]	validation_0-rmse:0.75112	validation_1-rmse:1.17049
# [70]	validation_0-rmse:0.74665	validation_1-rmse:1.16593
# [71]	validation_0-rmse:0.74174	validation_1-rmse:1.16315
# [72]	validation_0-rmse:0.73739	validation_1-rmse:1.16013
# [73]	validation_0-rmse:0.73494	validation_1-rmse:1.15913
# [74]	validation_0-rmse:0.73168	validation_1-rmse:1.15834
# [75]	validation_0-rmse:0.72811	validation_1-rmse:1.15810
# [76]	validation_0-rmse:0.72372	validation_1-rmse:1.15768
# [77]	validation_0-rmse:0.72125	validation_1-rmse:1.15539
# [78]	validation_0-rmse:0.71863	validation_1-rmse:1.15505
# [79]	validation_0-rmse:0.71571	validation_1-rmse:1.15622
# [80]	validation_0-rmse:0.71246	validation_1-rmse:1.15589
# [81]	validation_0-rmse:0.70847	validation_1-rmse:1.15361
# [82]	validation_0-rmse:0.70570	validation_1-rmse:1.15077
# [83]	validation_0-rmse:0.70284	validation_1-rmse:1.15287
# [84]	validation_0-rmse:0.70029	validation_1-rmse:1.15241
# [85]	validation_0-rmse:0.69719	validation_1-rmse:1.15168
# [86]	validation_0-rmse:0.69357	validation_1-rmse:1.14960
# [87]	validation_0-rmse:0.69119	validation_1-rmse:1.14875
# [88]	validation_0-rmse:0.68792	validation_1-rmse:1.15344
# [89]	validation_0-rmse:0.68523	validation_1-rmse:1.14943
# [90]	validation_0-rmse:0.68254	validation_1-rmse:1.15008
# [91]	validation_0-rmse:0.67969	validation_1-rmse:1.14956
# [92]	validation_0-rmse:0.67787	validation_1-rmse:1.15169
# [93]	validation_0-rmse:0.67503	validation_1-rmse:1.14897
# [94]	validation_0-rmse:0.67169	validation_1-rmse:1.14920
# [95]	validation_0-rmse:0.66885	validation_1-rmse:1.14969
# [96]	validation_0-rmse:0.66625	validation_1-rmse:1.14927
# [97]	validation_0-rmse:0.66286	validation_1-rmse:1.15348
# [98]	validation_0-rmse:0.66058	validation_1-rmse:1.15349
# [99]	validation_0-rmse:0.65774	validation_1-rmse:1.15067
# [100]	validation_0-rmse:0.65568	validation_1-rmse:1.14977
# [101]	validation_0-rmse:0.65299	validation_1-rmse:1.14895
# [102]	validation_0-rmse:0.64985	validation_1-rmse:1.15055
# [103]	validation_0-rmse:0.64754	validation_1-rmse:1.14723
# [0]	validation_0-rmse:1.74806	validation_1-rmse:1.42418
# [1]	validation_0-rmse:1.71194	validation_1-rmse:1.39513
# [2]	validation_0-rmse:1.67475	validation_1-rmse:1.36968
# [3]	validation_0-rmse:1.64358	validation_1-rmse:1.34610
# [4]	validation_0-rmse:1.61092	validation_1-rmse:1.32361
# [5]	validation_0-rmse:1.57844	validation_1-rmse:1.30628
# [6]	validation_0-rmse:1.54781	validation_1-rmse:1.28915
# [7]	validation_0-rmse:1.51685	validation_1-rmse:1.27298
# [8]	validation_0-rmse:1.48997	validation_1-rmse:1.25655
# [9]	validation_0-rmse:1.46572	validation_1-rmse:1.24246
# [10]	validation_0-rmse:1.44188	validation_1-rmse:1.23356
# [11]	validation_0-rmse:1.41618	validation_1-rmse:1.21850
# [12]	validation_0-rmse:1.39291	validation_1-rmse:1.20801
# [13]	validation_0-rmse:1.37107	validation_1-rmse:1.19646
# [14]	validation_0-rmse:1.34660	validation_1-rmse:1.18400
# [15]	validation_0-rmse:1.32566	validation_1-rmse:1.17175
# [16]	validation_0-rmse:1.30432	validation_1-rmse:1.15844
# [17]	validation_0-rmse:1.28510	validation_1-rmse:1.14842
# [18]	validation_0-rmse:1.26577	validation_1-rmse:1.14152
# [19]	validation_0-rmse:1.24604	validation_1-rmse:1.12703
# [20]	validation_0-rmse:1.22729	validation_1-rmse:1.11636
# [21]	validation_0-rmse:1.21004	validation_1-rmse:1.10694
# [22]	validation_0-rmse:1.19165	validation_1-rmse:1.09983
# [23]	validation_0-rmse:1.17481	validation_1-rmse:1.09447
# [24]	validation_0-rmse:1.15858	validation_1-rmse:1.08789
# [25]	validation_0-rmse:1.14324	validation_1-rmse:1.08046
# [26]	validation_0-rmse:1.12790	validation_1-rmse:1.07366
# [27]	validation_0-rmse:1.11383	validation_1-rmse:1.06408
# [28]	validation_0-rmse:1.09822	validation_1-rmse:1.05998
# [29]	validation_0-rmse:1.08345	validation_1-rmse:1.05767
# [30]	validation_0-rmse:1.07257	validation_1-rmse:1.05541
# [31]	validation_0-rmse:1.05894	validation_1-rmse:1.05029
# [32]	validation_0-rmse:1.04690	validation_1-rmse:1.04503
# [33]	validation_0-rmse:1.03408	validation_1-rmse:1.03582
# [34]	validation_0-rmse:1.02389	validation_1-rmse:1.02954
# [35]	validation_0-rmse:1.01294	validation_1-rmse:1.02082
# [36]	validation_0-rmse:1.00209	validation_1-rmse:1.01436
# [37]	validation_0-rmse:0.99207	validation_1-rmse:1.01346
# [38]	validation_0-rmse:0.98166	validation_1-rmse:1.01295
# [39]	validation_0-rmse:0.97041	validation_1-rmse:1.00669
# [40]	validation_0-rmse:0.96206	validation_1-rmse:1.00344
# [41]	validation_0-rmse:0.95096	validation_1-rmse:1.00241
# [42]	validation_0-rmse:0.94334	validation_1-rmse:1.00098
# [43]	validation_0-rmse:0.93501	validation_1-rmse:0.99953
# [44]	validation_0-rmse:0.92688	validation_1-rmse:0.99926
# [45]	validation_0-rmse:0.92001	validation_1-rmse:0.99732
# [46]	validation_0-rmse:0.91142	validation_1-rmse:0.99385
# [47]	validation_0-rmse:0.90381	validation_1-rmse:0.99425
# [48]	validation_0-rmse:0.89676	validation_1-rmse:0.99149
# [49]	validation_0-rmse:0.88949	validation_1-rmse:0.98995
# [50]	validation_0-rmse:0.88253	validation_1-rmse:0.98749
# [51]	validation_0-rmse:0.87635	validation_1-rmse:0.98656
# [52]	validation_0-rmse:0.86875	validation_1-rmse:0.98897
# [53]	validation_0-rmse:0.86228	validation_1-rmse:0.99018
# [54]	validation_0-rmse:0.85696	validation_1-rmse:0.98849
# [55]	validation_0-rmse:0.84993	validation_1-rmse:0.98941
# [56]	validation_0-rmse:0.84496	validation_1-rmse:0.99002
# [57]	validation_0-rmse:0.83868	validation_1-rmse:0.98867
# [58]	validation_0-rmse:0.83353	validation_1-rmse:0.98808
# [59]	validation_0-rmse:0.82753	validation_1-rmse:0.98567
# [60]	validation_0-rmse:0.82284	validation_1-rmse:0.98331
# [61]	validation_0-rmse:0.81698	validation_1-rmse:0.98339
# [62]	validation_0-rmse:0.81184	validation_1-rmse:0.98342
# [63]	validation_0-rmse:0.80844	validation_1-rmse:0.98512
# [64]	validation_0-rmse:0.80318	validation_1-rmse:0.98809
# [65]	validation_0-rmse:0.79844	validation_1-rmse:0.98686
# [66]	validation_0-rmse:0.79454	validation_1-rmse:0.98737
# [67]	validation_0-rmse:0.78989	validation_1-rmse:0.98490
# [68]	validation_0-rmse:0.78603	validation_1-rmse:0.98390
# [69]	validation_0-rmse:0.78239	validation_1-rmse:0.98474
# [70]	validation_0-rmse:0.77868	validation_1-rmse:0.98436
# [71]	validation_0-rmse:0.77484	validation_1-rmse:0.98315
# [72]	validation_0-rmse:0.77258	validation_1-rmse:0.98485
# [73]	validation_0-rmse:0.76925	validation_1-rmse:0.98507
# [74]	validation_0-rmse:0.76513	validation_1-rmse:0.98507
# [75]	validation_0-rmse:0.76162	validation_1-rmse:0.98518
# [76]	validation_0-rmse:0.75670	validation_1-rmse:0.98389
# [77]	validation_0-rmse:0.75434	validation_1-rmse:0.98298
# [78]	validation_0-rmse:0.75018	validation_1-rmse:0.98001
# [79]	validation_0-rmse:0.74732	validation_1-rmse:0.97989
# [80]	validation_0-rmse:0.74322	validation_1-rmse:0.98087
# [81]	validation_0-rmse:0.73862	validation_1-rmse:0.97802
# [82]	validation_0-rmse:0.73606	validation_1-rmse:0.98038
# [83]	validation_0-rmse:0.73241	validation_1-rmse:0.98086
# [84]	validation_0-rmse:0.72920	validation_1-rmse:0.98293
# [85]	validation_0-rmse:0.72636	validation_1-rmse:0.98513
# [86]	validation_0-rmse:0.72343	validation_1-rmse:0.98561
# [87]	validation_0-rmse:0.72092	validation_1-rmse:0.98712
# [88]	validation_0-rmse:0.71894	validation_1-rmse:0.98726
# [89]	validation_0-rmse:0.71652	validation_1-rmse:0.98803
# [90]	validation_0-rmse:0.71298	validation_1-rmse:0.98851
# [91]	validation_0-rmse:0.71159	validation_1-rmse:0.99052
# [92]	validation_0-rmse:0.70996	validation_1-rmse:0.98973
# [93]	validation_0-rmse:0.70762	validation_1-rmse:0.98961
# [94]	validation_0-rmse:0.70562	validation_1-rmse:0.99094
# [95]	validation_0-rmse:0.70285	validation_1-rmse:0.98819
# [96]	validation_0-rmse:0.69917	validation_1-rmse:0.98658
# [97]	validation_0-rmse:0.69703	validation_1-rmse:0.98670
# [98]	validation_0-rmse:0.69417	validation_1-rmse:0.98455
# [99]	validation_0-rmse:0.69290	validation_1-rmse:0.98434
# [100]	validation_0-rmse:0.69111	validation_1-rmse:0.98320
# [0]	validation_0-rmse:1.74725	validation_1-rmse:1.43773
# [1]	validation_0-rmse:1.71116	validation_1-rmse:1.41364
# [2]	validation_0-rmse:1.68138	validation_1-rmse:1.39009
# [3]	validation_0-rmse:1.64811	validation_1-rmse:1.36101
# [4]	validation_0-rmse:1.61978	validation_1-rmse:1.33650
# [5]	validation_0-rmse:1.58824	validation_1-rmse:1.31301
# [6]	validation_0-rmse:1.55665	validation_1-rmse:1.29228
# [7]	validation_0-rmse:1.52763	validation_1-rmse:1.27471
# [8]	validation_0-rmse:1.49760	validation_1-rmse:1.25282
# [9]	validation_0-rmse:1.47245	validation_1-rmse:1.23720
# [10]	validation_0-rmse:1.44888	validation_1-rmse:1.21908
# [11]	validation_0-rmse:1.42034	validation_1-rmse:1.20165
# [12]	validation_0-rmse:1.39647	validation_1-rmse:1.18725
# [13]	validation_0-rmse:1.37660	validation_1-rmse:1.17675
# [14]	validation_0-rmse:1.35831	validation_1-rmse:1.16701
# [15]	validation_0-rmse:1.33665	validation_1-rmse:1.15690
# [16]	validation_0-rmse:1.31315	validation_1-rmse:1.14400
# [17]	validation_0-rmse:1.29071	validation_1-rmse:1.13299
# [18]	validation_0-rmse:1.27105	validation_1-rmse:1.11856
# [19]	validation_0-rmse:1.25121	validation_1-rmse:1.10878
# [20]	validation_0-rmse:1.23346	validation_1-rmse:1.09757
# [21]	validation_0-rmse:1.21710	validation_1-rmse:1.08909
# [22]	validation_0-rmse:1.20211	validation_1-rmse:1.07690
# [23]	validation_0-rmse:1.18799	validation_1-rmse:1.06829
# [24]	validation_0-rmse:1.17271	validation_1-rmse:1.06097
# [25]	validation_0-rmse:1.15788	validation_1-rmse:1.05325
# [26]	validation_0-rmse:1.14051	validation_1-rmse:1.04088
# [27]	validation_0-rmse:1.12430	validation_1-rmse:1.03303
# [28]	validation_0-rmse:1.11067	validation_1-rmse:1.03127
# [29]	validation_0-rmse:1.09782	validation_1-rmse:1.02847
# [30]	validation_0-rmse:1.08720	validation_1-rmse:1.01989
# [31]	validation_0-rmse:1.07415	validation_1-rmse:1.01195
# [32]	validation_0-rmse:1.05928	validation_1-rmse:1.00565
# [33]	validation_0-rmse:1.04653	validation_1-rmse:1.00442
# [34]	validation_0-rmse:1.03480	validation_1-rmse:1.00026
# [35]	validation_0-rmse:1.02580	validation_1-rmse:0.99676
# [36]	validation_0-rmse:1.01199	validation_1-rmse:0.99324
# [37]	validation_0-rmse:1.00060	validation_1-rmse:0.99273
# [38]	validation_0-rmse:0.99159	validation_1-rmse:0.98734
# [39]	validation_0-rmse:0.98166	validation_1-rmse:0.98253
# [40]	validation_0-rmse:0.97511	validation_1-rmse:0.97747
# [41]	validation_0-rmse:0.96701	validation_1-rmse:0.97237
# [42]	validation_0-rmse:0.95813	validation_1-rmse:0.96960
# [43]	validation_0-rmse:0.94890	validation_1-rmse:0.96876
# [44]	validation_0-rmse:0.93903	validation_1-rmse:0.96519
# [45]	validation_0-rmse:0.93110	validation_1-rmse:0.96222
# [46]	validation_0-rmse:0.92315	validation_1-rmse:0.96304
# [47]	validation_0-rmse:0.91447	validation_1-rmse:0.96345
# [48]	validation_0-rmse:0.90757	validation_1-rmse:0.96030
# [49]	validation_0-rmse:0.90101	validation_1-rmse:0.95902
# [50]	validation_0-rmse:0.89525	validation_1-rmse:0.96164
# [51]	validation_0-rmse:0.89014	validation_1-rmse:0.96156
# [52]	validation_0-rmse:0.88505	validation_1-rmse:0.96305
# [53]	validation_0-rmse:0.87913	validation_1-rmse:0.96052
# [54]	validation_0-rmse:0.87312	validation_1-rmse:0.96099
# [55]	validation_0-rmse:0.86551	validation_1-rmse:0.95794
# [56]	validation_0-rmse:0.86010	validation_1-rmse:0.95497
# [57]	validation_0-rmse:0.85332	validation_1-rmse:0.95545
# [58]	validation_0-rmse:0.84817	validation_1-rmse:0.95636
# [59]	validation_0-rmse:0.84134	validation_1-rmse:0.95955
# [60]	validation_0-rmse:0.83790	validation_1-rmse:0.96052
# [61]	validation_0-rmse:0.83214	validation_1-rmse:0.95950
# [62]	validation_0-rmse:0.82692	validation_1-rmse:0.96089
# [63]	validation_0-rmse:0.82382	validation_1-rmse:0.96313
# [64]	validation_0-rmse:0.81969	validation_1-rmse:0.96009
# [65]	validation_0-rmse:0.81638	validation_1-rmse:0.95993
# [66]	validation_0-rmse:0.81262	validation_1-rmse:0.96134
# [67]	validation_0-rmse:0.80792	validation_1-rmse:0.96110
# [68]	validation_0-rmse:0.80328	validation_1-rmse:0.96061
# [69]	validation_0-rmse:0.79854	validation_1-rmse:0.96475
# [70]	validation_0-rmse:0.79539	validation_1-rmse:0.96524
# [71]	validation_0-rmse:0.79081	validation_1-rmse:0.96835
# [72]	validation_0-rmse:0.78539	validation_1-rmse:0.97168
# [73]	validation_0-rmse:0.78104	validation_1-rmse:0.97475
# [74]	validation_0-rmse:0.77756	validation_1-rmse:0.97742
# [75]	validation_0-rmse:0.77420	validation_1-rmse:0.98046
# [76]	validation_0-rmse:0.77033	validation_1-rmse:0.98033
# [0]	validation_0-rmse:1.73228	validation_1-rmse:1.50652
# [1]	validation_0-rmse:1.69968	validation_1-rmse:1.48138
# [2]	validation_0-rmse:1.66349	validation_1-rmse:1.45530
# [3]	validation_0-rmse:1.63062	validation_1-rmse:1.43136
# [4]	validation_0-rmse:1.60032	validation_1-rmse:1.41544
# [5]	validation_0-rmse:1.57284	validation_1-rmse:1.39774
# [6]	validation_0-rmse:1.54024	validation_1-rmse:1.37656
# [7]	validation_0-rmse:1.51181	validation_1-rmse:1.35920
# [8]	validation_0-rmse:1.48371	validation_1-rmse:1.34292
# [9]	validation_0-rmse:1.45698	validation_1-rmse:1.32304
# [10]	validation_0-rmse:1.42966	validation_1-rmse:1.30194
# [11]	validation_0-rmse:1.40281	validation_1-rmse:1.29296
# [12]	validation_0-rmse:1.37771	validation_1-rmse:1.28318
# [13]	validation_0-rmse:1.35710	validation_1-rmse:1.26550
# [14]	validation_0-rmse:1.33597	validation_1-rmse:1.25344
# [15]	validation_0-rmse:1.31454	validation_1-rmse:1.23897
# [16]	validation_0-rmse:1.29221	validation_1-rmse:1.22217
# [17]	validation_0-rmse:1.27560	validation_1-rmse:1.21333
# [18]	validation_0-rmse:1.25592	validation_1-rmse:1.20357
# [19]	validation_0-rmse:1.23478	validation_1-rmse:1.19505
# [20]	validation_0-rmse:1.22005	validation_1-rmse:1.18958
# [21]	validation_0-rmse:1.20102	validation_1-rmse:1.18225
# [22]	validation_0-rmse:1.18350	validation_1-rmse:1.17544
# [23]	validation_0-rmse:1.16457	validation_1-rmse:1.16562
# [24]	validation_0-rmse:1.14731	validation_1-rmse:1.15846
# [25]	validation_0-rmse:1.13184	validation_1-rmse:1.14889
# [26]	validation_0-rmse:1.11724	validation_1-rmse:1.14366
# [27]	validation_0-rmse:1.10070	validation_1-rmse:1.13946
# [28]	validation_0-rmse:1.08676	validation_1-rmse:1.13622
# [29]	validation_0-rmse:1.07148	validation_1-rmse:1.13055
# [30]	validation_0-rmse:1.05752	validation_1-rmse:1.13104
# [31]	validation_0-rmse:1.04649	validation_1-rmse:1.12716
# [32]	validation_0-rmse:1.03378	validation_1-rmse:1.12492
# [33]	validation_0-rmse:1.02076	validation_1-rmse:1.11966
# [34]	validation_0-rmse:1.00883	validation_1-rmse:1.11538
# [35]	validation_0-rmse:0.99743	validation_1-rmse:1.11317
# [36]	validation_0-rmse:0.98702	validation_1-rmse:1.10916
# [37]	validation_0-rmse:0.97483	validation_1-rmse:1.10251
# [38]	validation_0-rmse:0.96603	validation_1-rmse:1.10195
# [39]	validation_0-rmse:0.95508	validation_1-rmse:1.10183
# [40]	validation_0-rmse:0.94533	validation_1-rmse:1.10252
# [41]	validation_0-rmse:0.93610	validation_1-rmse:1.09958
# [42]	validation_0-rmse:0.92900	validation_1-rmse:1.09723
# [43]	validation_0-rmse:0.91994	validation_1-rmse:1.09697
# [44]	validation_0-rmse:0.91023	validation_1-rmse:1.09734
# [45]	validation_0-rmse:0.90380	validation_1-rmse:1.09548
# [46]	validation_0-rmse:0.89692	validation_1-rmse:1.09246
# [47]	validation_0-rmse:0.88957	validation_1-rmse:1.09090
# [48]	validation_0-rmse:0.88047	validation_1-rmse:1.08932
# [49]	validation_0-rmse:0.87648	validation_1-rmse:1.09020
# [50]	validation_0-rmse:0.86879	validation_1-rmse:1.08689
# [51]	validation_0-rmse:0.86258	validation_1-rmse:1.08555
# [52]	validation_0-rmse:0.85597	validation_1-rmse:1.08510
# [53]	validation_0-rmse:0.84974	validation_1-rmse:1.08737
# [54]	validation_0-rmse:0.84362	validation_1-rmse:1.08920
# [55]	validation_0-rmse:0.83742	validation_1-rmse:1.08782
# [56]	validation_0-rmse:0.83243	validation_1-rmse:1.08877
# [57]	validation_0-rmse:0.82901	validation_1-rmse:1.08513
# [58]	validation_0-rmse:0.82308	validation_1-rmse:1.08351
# [59]	validation_0-rmse:0.81714	validation_1-rmse:1.08012
# [60]	validation_0-rmse:0.81451	validation_1-rmse:1.07877
# [61]	validation_0-rmse:0.80945	validation_1-rmse:1.07809
# [62]	validation_0-rmse:0.80370	validation_1-rmse:1.07763
# [63]	validation_0-rmse:0.79797	validation_1-rmse:1.08060
# [64]	validation_0-rmse:0.79361	validation_1-rmse:1.08206
# [65]	validation_0-rmse:0.79015	validation_1-rmse:1.08282
# [66]	validation_0-rmse:0.78539	validation_1-rmse:1.08241
# [67]	validation_0-rmse:0.78108	validation_1-rmse:1.08215
# [68]	validation_0-rmse:0.77608	validation_1-rmse:1.08572
# [69]	validation_0-rmse:0.77190	validation_1-rmse:1.08448
# [70]	validation_0-rmse:0.76766	validation_1-rmse:1.08389
# [71]	validation_0-rmse:0.76328	validation_1-rmse:1.08333
# [72]	validation_0-rmse:0.75898	validation_1-rmse:1.08297
# [73]	validation_0-rmse:0.75659	validation_1-rmse:1.08331
# [74]	validation_0-rmse:0.75233	validation_1-rmse:1.08261
# [75]	validation_0-rmse:0.74916	validation_1-rmse:1.08457
# [76]	validation_0-rmse:0.74677	validation_1-rmse:1.08442
# [77]	validation_0-rmse:0.74369	validation_1-rmse:1.08328
# [78]	validation_0-rmse:0.73895	validation_1-rmse:1.08179
# [79]	validation_0-rmse:0.73551	validation_1-rmse:1.08212
# [80]	validation_0-rmse:0.73381	validation_1-rmse:1.08463
# [81]	validation_0-rmse:0.73096	validation_1-rmse:1.08848
# [0]	validation_0-rmse:1.74424	validation_1-rmse:1.45611
# [1]	validation_0-rmse:1.71206	validation_1-rmse:1.42493
# [2]	validation_0-rmse:1.67796	validation_1-rmse:1.38919
# [3]	validation_0-rmse:1.64333	validation_1-rmse:1.35781
# [4]	validation_0-rmse:1.61281	validation_1-rmse:1.32497
# [5]	validation_0-rmse:1.58289	validation_1-rmse:1.29640
# [6]	validation_0-rmse:1.55578	validation_1-rmse:1.27396
# [7]	validation_0-rmse:1.52768	validation_1-rmse:1.24666
# [8]	validation_0-rmse:1.49994	validation_1-rmse:1.22188
# [9]	validation_0-rmse:1.47587	validation_1-rmse:1.20200
# [10]	validation_0-rmse:1.45079	validation_1-rmse:1.18014
# [11]	validation_0-rmse:1.43057	validation_1-rmse:1.16959
# [12]	validation_0-rmse:1.40561	validation_1-rmse:1.14814
# [13]	validation_0-rmse:1.38547	validation_1-rmse:1.13247
# [14]	validation_0-rmse:1.36399	validation_1-rmse:1.11219
# [15]	validation_0-rmse:1.34206	validation_1-rmse:1.09553
# [16]	validation_0-rmse:1.31850	validation_1-rmse:1.07795
# [17]	validation_0-rmse:1.29560	validation_1-rmse:1.06146
# [18]	validation_0-rmse:1.27659	validation_1-rmse:1.04388
# [19]	validation_0-rmse:1.25748	validation_1-rmse:1.02703
# [20]	validation_0-rmse:1.23887	validation_1-rmse:1.01279
# [21]	validation_0-rmse:1.21895	validation_1-rmse:0.99926
# [22]	validation_0-rmse:1.20098	validation_1-rmse:0.98268
# [23]	validation_0-rmse:1.18343	validation_1-rmse:0.96932
# [24]	validation_0-rmse:1.16836	validation_1-rmse:0.95898
# [25]	validation_0-rmse:1.15383	validation_1-rmse:0.94880
# [26]	validation_0-rmse:1.13936	validation_1-rmse:0.93562
# [27]	validation_0-rmse:1.12784	validation_1-rmse:0.92279
# [28]	validation_0-rmse:1.11433	validation_1-rmse:0.91683
# [29]	validation_0-rmse:1.10181	validation_1-rmse:0.90625
# [30]	validation_0-rmse:1.08953	validation_1-rmse:0.89856
# [31]	validation_0-rmse:1.07768	validation_1-rmse:0.89358
# [32]	validation_0-rmse:1.06620	validation_1-rmse:0.88617
# [33]	validation_0-rmse:1.05512	validation_1-rmse:0.87741
# [34]	validation_0-rmse:1.04392	validation_1-rmse:0.86979
# [35]	validation_0-rmse:1.03266	validation_1-rmse:0.86296
# [36]	validation_0-rmse:1.02166	validation_1-rmse:0.85457
# [37]	validation_0-rmse:1.01184	validation_1-rmse:0.84772
# [38]	validation_0-rmse:1.00323	validation_1-rmse:0.84313
# [39]	validation_0-rmse:0.99339	validation_1-rmse:0.83684
# [40]	validation_0-rmse:0.98690	validation_1-rmse:0.83144
# [41]	validation_0-rmse:0.98161	validation_1-rmse:0.82954
# [42]	validation_0-rmse:0.97372	validation_1-rmse:0.82712
# [43]	validation_0-rmse:0.96405	validation_1-rmse:0.82575
# [44]	validation_0-rmse:0.95386	validation_1-rmse:0.82300
# [45]	validation_0-rmse:0.94511	validation_1-rmse:0.81488
# [46]	validation_0-rmse:0.93503	validation_1-rmse:0.81112
# [47]	validation_0-rmse:0.92959	validation_1-rmse:0.80927
# [48]	validation_0-rmse:0.92084	validation_1-rmse:0.80276
# [49]	validation_0-rmse:0.91523	validation_1-rmse:0.79785
# [50]	validation_0-rmse:0.91056	validation_1-rmse:0.79736
# [51]	validation_0-rmse:0.90373	validation_1-rmse:0.79648
# [52]	validation_0-rmse:0.89638	validation_1-rmse:0.79476
# [53]	validation_0-rmse:0.89271	validation_1-rmse:0.79164
# [54]	validation_0-rmse:0.88712	validation_1-rmse:0.78902
# [55]	validation_0-rmse:0.88008	validation_1-rmse:0.78364
# [56]	validation_0-rmse:0.87432	validation_1-rmse:0.78520
# [57]	validation_0-rmse:0.86791	validation_1-rmse:0.78328
# [58]	validation_0-rmse:0.86215	validation_1-rmse:0.78201
# [59]	validation_0-rmse:0.85722	validation_1-rmse:0.77873
# [60]	validation_0-rmse:0.85299	validation_1-rmse:0.77638
# [61]	validation_0-rmse:0.85036	validation_1-rmse:0.77468
# [62]	validation_0-rmse:0.84575	validation_1-rmse:0.77122
# [63]	validation_0-rmse:0.84139	validation_1-rmse:0.77088
# [64]	validation_0-rmse:0.83627	validation_1-rmse:0.77227
# [65]	validation_0-rmse:0.83176	validation_1-rmse:0.77081
# [66]	validation_0-rmse:0.82871	validation_1-rmse:0.77102
# [67]	validation_0-rmse:0.82496	validation_1-rmse:0.77011
# [68]	validation_0-rmse:0.81975	validation_1-rmse:0.76990
# [69]	validation_0-rmse:0.81602	validation_1-rmse:0.77268
# [70]	validation_0-rmse:0.81141	validation_1-rmse:0.77380
# [71]	validation_0-rmse:0.80772	validation_1-rmse:0.77369
# [72]	validation_0-rmse:0.80288	validation_1-rmse:0.77280
# [73]	validation_0-rmse:0.79748	validation_1-rmse:0.77347
# [74]	validation_0-rmse:0.79379	validation_1-rmse:0.77428
# [75]	validation_0-rmse:0.78997	validation_1-rmse:0.77347
# [76]	validation_0-rmse:0.78592	validation_1-rmse:0.77216
# [77]	validation_0-rmse:0.78224	validation_1-rmse:0.77412
# [78]	validation_0-rmse:0.77988	validation_1-rmse:0.77344
# [79]	validation_0-rmse:0.77780	validation_1-rmse:0.77314
# [80]	validation_0-rmse:0.77371	validation_1-rmse:0.77374
# [81]	validation_0-rmse:0.77045	validation_1-rmse:0.77386
# [82]	validation_0-rmse:0.76792	validation_1-rmse:0.77458
# [83]	validation_0-rmse:0.76464	validation_1-rmse:0.77455
# [84]	validation_0-rmse:0.76189	validation_1-rmse:0.77493
# [85]	validation_0-rmse:0.75834	validation_1-rmse:0.77477
# [86]	validation_0-rmse:0.75640	validation_1-rmse:0.77348
# [87]	validation_0-rmse:0.75425	validation_1-rmse:0.77550
# [88]	validation_0-rmse:0.75027	validation_1-rmse:0.77634
# [0]	validation_0-rmse:1.72608	validation_1-rmse:1.52228
# [1]	validation_0-rmse:1.68795	validation_1-rmse:1.48983
# [2]	validation_0-rmse:1.65319	validation_1-rmse:1.45793
# [3]	validation_0-rmse:1.61974	validation_1-rmse:1.43627
# [4]	validation_0-rmse:1.59356	validation_1-rmse:1.41363
# [5]	validation_0-rmse:1.56159	validation_1-rmse:1.38800
# [6]	validation_0-rmse:1.53433	validation_1-rmse:1.36532
# [7]	validation_0-rmse:1.50596	validation_1-rmse:1.34082
# [8]	validation_0-rmse:1.47831	validation_1-rmse:1.31436
# [9]	validation_0-rmse:1.45356	validation_1-rmse:1.29112
# [10]	validation_0-rmse:1.42853	validation_1-rmse:1.27444
# [11]	validation_0-rmse:1.40434	validation_1-rmse:1.26087
# [12]	validation_0-rmse:1.38199	validation_1-rmse:1.24345
# [13]	validation_0-rmse:1.35853	validation_1-rmse:1.22953
# [14]	validation_0-rmse:1.33617	validation_1-rmse:1.21648
# [15]	validation_0-rmse:1.31287	validation_1-rmse:1.19782
# [16]	validation_0-rmse:1.29174	validation_1-rmse:1.18280
# [17]	validation_0-rmse:1.27074	validation_1-rmse:1.16820
# [18]	validation_0-rmse:1.25426	validation_1-rmse:1.16127
# [19]	validation_0-rmse:1.23621	validation_1-rmse:1.14721
# [20]	validation_0-rmse:1.21506	validation_1-rmse:1.13233
# [21]	validation_0-rmse:1.20246	validation_1-rmse:1.12537
# [22]	validation_0-rmse:1.18560	validation_1-rmse:1.11645
# [23]	validation_0-rmse:1.17030	validation_1-rmse:1.11230
# [24]	validation_0-rmse:1.15522	validation_1-rmse:1.10306
# [25]	validation_0-rmse:1.13854	validation_1-rmse:1.09999
# [26]	validation_0-rmse:1.12315	validation_1-rmse:1.09189
# [27]	validation_0-rmse:1.10649	validation_1-rmse:1.08616
# [28]	validation_0-rmse:1.09472	validation_1-rmse:1.07707
# [29]	validation_0-rmse:1.07984	validation_1-rmse:1.06508
# [30]	validation_0-rmse:1.06738	validation_1-rmse:1.05914
# [31]	validation_0-rmse:1.05499	validation_1-rmse:1.05605
# [32]	validation_0-rmse:1.04417	validation_1-rmse:1.04806
# [33]	validation_0-rmse:1.03251	validation_1-rmse:1.04418
# [34]	validation_0-rmse:1.02283	validation_1-rmse:1.04143
# [35]	validation_0-rmse:1.01336	validation_1-rmse:1.04160
# [36]	validation_0-rmse:1.00244	validation_1-rmse:1.03481
# [37]	validation_0-rmse:0.99253	validation_1-rmse:1.03189
# [38]	validation_0-rmse:0.98420	validation_1-rmse:1.03154

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-4.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['r2019B08', 'r2019B01', 'r2019B04',  'r2019B11', 'r2019B10'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-4, -3, -2, -1, 0, 1, 2])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 0.2, 0.5, 1, 2, 5])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-4.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../05_output_data/XGBoost_models/04_LN_Tag_Cs_SENTINEL_2019_XGB_model_2024_final.json")
# Save to text format
f_xgb_model.save_model("../05_output_data/XGBoost_models/04_LN_Tag_Cs_SENTINEL_2019_XGB_model_2024_final.txt")
