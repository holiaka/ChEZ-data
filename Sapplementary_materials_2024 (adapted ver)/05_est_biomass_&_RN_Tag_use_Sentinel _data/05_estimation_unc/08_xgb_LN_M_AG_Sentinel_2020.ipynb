# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../05_input_data/Sites_with_Sentinel_bands_data.xlsx'
df = pd.read_excel(site_data, sheet_name='input_2020')
df.head()
# Out:
#   Site # Origin Dominant_s  LN_GS_cub_m  LN_M_stem_kg_m2  \
# 0      1      n      Birch        4.771            1.792
# 1      2      a       Pine        5.808            2.496
# 2      3      a       Pine        5.796            2.546
# 3      4      a       Pine        5.826            2.643
# 4      5      a       Pine        6.059            2.643
#
#    LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  LN_M_foliage_kg_m2  LN_M_AG_kg_m2  \
# 0                -0.211            -0.261              -2.040          1.932
# 1                -0.073             0.392              -0.139          2.674
# 2                 0.030             0.501              -0.030          2.734
# 3                 0.000             0.419              -0.431          2.785
# 4                 0.122             0.647              -0.386          2.809
#
#         X_N36  ...  r2020B04  r2020B05  r2020B06  r2020B07  r2020B08  \
# 0  298987.203  ...  0.254417  0.175280  0.086611  0.797761 -0.749311
# 1  299016.572  ...  0.189826  0.092225  0.047120  0.789129 -0.705355
# 2  299072.773  ...  0.204363  0.093062  0.043824  0.812120 -0.704758
# 3  299152.693  ...  0.187998  0.102872  0.048585  0.762431 -0.695416
# 4  299249.689  ...  0.216271  0.096981  0.044880  0.793606 -0.717562
#
#    r2020B09   r2020B10   r2020B11  r2020B12  r2020B13
# 0  0.491270 -15.527246 -11.385074  0.733806  0.040781
# 1  0.659775 -16.547673 -10.947565  0.661723 -0.102776
# 2  0.631348 -14.341917 -11.884799  0.829603 -0.063200
# 3  0.601894 -14.885610 -11.725163  0.787609 -0.057177
# 4  0.642942 -14.647913 -11.512282  0.785698 -0.073830
#
# [5 rows x 35 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Site #', 'Origin', 'Dominant_s', 'LN_GS_cub_m', 'LN_M_stem_kg_m2', 'LN_M_stem_bark_kg_m2', 'LN_M_crown_kg_m2', 'LN_M_foliage_kg_m2', 'LN_M_AG_kg_m2', 'F_Soil', 'M_Soil', 'X_N36', 'Y_N36', 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'LN_Cs_wood', 'LN_Sr_wood', 'Tag_Cs', 'Tag_Sr', 'LN_Tag_Cs', 'LN_Tag_Sr', 'Cs_2021_kB', 'Sr_2021_kB', 'AEDR_mean', 'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['LN_GS_cub_m', 'LN_M_stem_kg_m2', 'LN_M_stem_bark_kg_m2', 'LN_M_crown_kg_m2', 'LN_M_foliage_kg_m2', 'LN_M_AG_kg_m2', 'LN_Tag_Cs', 'LN_Tag_Sr',
                                  'r2020B01', 'r2020B02', 'r2020B03', 'r2020B04', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11', 'r2020B12'])

# Show the first five columns
select.head()
# Out:
#    LN_GS_cub_m  LN_M_stem_kg_m2  LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  \
# 0        4.771            1.792                -0.211            -0.261
# 1        5.808            2.496                -0.073             0.392
# 2        5.796            2.546                 0.030             0.501
# 3        5.826            2.643                 0.000             0.419
# 4        6.059            2.643                 0.122             0.647
#
#    LN_M_foliage_kg_m2  LN_M_AG_kg_m2  LN_Tag_Cs  LN_Tag_Sr  r2020B01  \
# 0              -2.040          1.932      -0.73       2.58  0.019397
# 1              -0.139          2.674       0.59       2.92  0.019167
# 2              -0.030          2.734       0.78       2.88  0.019568
# 3              -0.431          2.785       0.52       2.72  0.020556
# 4              -0.386          2.809       0.22       2.83  0.019003
#
#    r2020B02  r2020B03  r2020B04  r2020B05  r2020B06  r2020B07  r2020B08  \
# 0  0.035344  0.028616  0.254417  0.175280  0.086611  0.797761 -0.749311
# 1  0.033537  0.022230  0.189826  0.092225  0.047120  0.789129 -0.705355
# 2  0.035957  0.021190  0.204363  0.093062  0.043824  0.812120 -0.704758
# 3  0.033868  0.025284  0.187998  0.102872  0.048585  0.762431 -0.695416
# 4  0.036153  0.024911  0.216271  0.096981  0.044880  0.793606 -0.717562
#
#    r2020B09   r2020B10   r2020B11  r2020B12
# 0  0.491270 -15.527246 -11.385074  0.733806
# 1  0.659775 -16.547673 -10.947565  0.661723
# 2  0.631348 -14.341917 -11.884799  0.829603
# 3  0.601894 -14.885610 -11.725163  0.787609
# 4  0.642942 -14.647913 -11.512282  0.785698

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   LN_GS_cub_m           198 non-null    float64
#  1   LN_M_stem_kg_m2       198 non-null    float64
#  2   LN_M_stem_bark_kg_m2  198 non-null    float64
#  3   LN_M_crown_kg_m2      198 non-null    float64
#  4   LN_M_foliage_kg_m2    198 non-null    float64
#  5   LN_M_AG_kg_m2         198 non-null    float64
#  6   LN_Tag_Cs             198 non-null    float64
#  7   LN_Tag_Sr             198 non-null    float64
#  8   r2020B01              198 non-null    float64
#  9   r2020B02              198 non-null    float64
#  10  r2020B03              198 non-null    float64
#  11  r2020B04              198 non-null    float64
#  12  r2020B05              198 non-null    float64
#  13  r2020B06              198 non-null    float64
#  14  r2020B07              198 non-null    float64
#  15  r2020B08              198 non-null    float64
#  16  r2020B09              198 non-null    float64
#  17  r2020B10              198 non-null    float64
#  18  r2020B11              198 non-null    float64
#  19  r2020B12              198 non-null    float64
# dtypes: float64(20)
# memory usage: 31.1 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_s"])["LN_GS_cub_m", "LN_M_AG_kg_m2"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            LN_GS_cub_m                                                   \
#                  count      mean       std    min     25%    50%    75%
# Dominant_s
# Alder             13.0  5.954615  0.321593  5.342  5.7620  6.023  6.205
# Aspen              7.0  5.382429  0.530860  4.844  4.9900  5.231  5.713
# Birch             45.0  4.897244  0.745395  2.398  4.6440  5.004  5.366
# Oak                9.0  5.213444  0.513140  4.344  4.7710  5.460  5.642
# Pine             123.0  5.270488  1.252592  1.609  4.9665  5.784  6.100
# Spruce             1.0  6.431000       NaN  6.431  6.4310  6.431  6.431
#
#                   LN_M_AG_kg_m2                                            \
#               max         count      mean       std    min     25%    50%
# Dominant_s
# Alder       6.330          13.0  2.891692  0.293107  2.407  2.6530  2.970
# Aspen       6.196           7.0  2.459000  0.532848  1.902  2.0420  2.370
# Birch       5.858          45.0  2.051800  0.678888  0.000  1.7580  2.219
# Oak         5.765           9.0  2.459333  0.507916  1.569  2.0010  2.715
# Pine        6.457         123.0  2.305008  1.053778 -0.693  2.0605  2.681
# Spruce      6.431           1.0  3.506000       NaN  3.506  3.5060  3.506
#
#
#                75%    max
# Dominant_s
# Alder       3.1350  3.258
# Aspen       2.8375  3.182
# Birch       2.5260  2.923
# Oak         2.8150  3.025
# Pine        3.0110  3.515
# Spruce      3.5060  3.506

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        LN_GS_cub_m  LN_M_stem_kg_m2  LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  \
# count   198.000000       198.000000             198.00000        198.000000
# mean      5.237803         2.109995              -0.11297          0.075646
# std       1.091051         1.039582               0.78467          0.711102
# min       1.609000        -1.347000              -2.65900         -2.408000
# 25%       4.914250         1.797000              -0.27075         -0.148000
# 50%       5.517000         2.413000               0.04400          0.289000
# 75%       5.989750         2.798500               0.33250          0.531000
# max       6.457000         3.428000               1.38400          1.756000
#
#        LN_M_foliage_kg_m2  LN_M_AG_kg_m2   LN_Tag_Cs   LN_Tag_Sr    r2020B01  \
# count          198.000000     198.000000  198.000000  198.000000  198.000000
# mean            -0.970066       2.304505   -0.566313    2.340253    0.022479
# std              0.713109       0.928222    1.248087    0.938549    0.005381
# min             -3.507000      -0.693000   -4.680000   -0.250000    0.012648
# 25%             -1.514000       2.001000   -1.327500    1.742500    0.019615
# 50%             -0.788000       2.565000   -0.465000    2.460000    0.021938
# 75%             -0.386000       2.899750    0.380000    2.992500    0.023920
# max              0.157000       3.515000    1.650000    4.660000    0.058966
#
#          r2020B02    r2020B03    r2020B04    r2020B05    r2020B06    r2020B07  \
# count  198.000000  198.000000  198.000000  198.000000  198.000000  198.000000
# mean     0.036321    0.027499    0.213645    0.125537    0.063662    0.767194
# std      0.006531    0.009532    0.042641    0.035475    0.023731    0.078273
# min      0.024838    0.014640    0.124161    0.079896    0.036570    0.381333
# 25%      0.033225    0.022284    0.187070    0.095832    0.046290    0.745438
# 50%      0.035316    0.024743    0.204261    0.115558    0.058209    0.784239
# 75%      0.037919    0.028527    0.236440    0.150857    0.072122    0.808780
# max      0.075169    0.080615    0.369338    0.243667    0.187427    0.885319
#
#          r2020B08    r2020B09    r2020B10    r2020B11    r2020B12
# count  198.000000  198.000000  198.000000  198.000000  198.000000
# mean    -0.703079    0.540963  -16.145709  -10.863669    0.675418
# std      0.060738    0.132304    1.343250    1.161017    0.069250
# min     -0.823403    0.038198  -22.517731  -14.262763    0.492975
# 25%     -0.735205    0.502225  -16.970102  -11.519514    0.628884
# 50%     -0.704881    0.577675  -16.010171  -10.784612    0.667561
# 75%     -0.680539    0.632284  -15.159997  -10.008004    0.720595
# max     -0.410944    0.710583  -13.281957   -7.650135    0.860863

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "LN_M_AG_kg_m2"
indep_variables = ['r2020B01', 'r2020B03', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B10', 'r2020B11']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      LN_GS_cub_m  LN_M_stem_kg_m2  LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  \
# 0          4.771            1.792                -0.211            -0.261
# 1          5.808            2.496                -0.073             0.392
# 2          5.796            2.546                 0.030             0.501
# 3          5.826            2.643                 0.000             0.419
# 4          6.059            2.643                 0.122             0.647
# ..           ...              ...                   ...               ...
# 193        6.238            3.125                 0.322             0.560
# 194        5.861            2.702                 0.058             0.482
# 195        5.935            2.775                -0.030             0.372
# 196        5.784            2.546                -0.117             0.182
# 197        6.277            2.949                 0.182             0.501
#
#      LN_M_foliage_kg_m2  LN_M_AG_kg_m2  LN_Tag_Cs  LN_Tag_Sr  r2020B01  \
# 0                -2.040          1.932      -0.73       2.58  0.019397
# 1                -0.139          2.674       0.59       2.92  0.019167
# 2                -0.030          2.734       0.78       2.88  0.019568
# 3                -0.431          2.785       0.52       2.72  0.020556
# 4                -0.386          2.809       0.22       2.83  0.019003
# ..                  ...            ...        ...        ...       ...
# 193              -0.301          3.231      -0.03       1.79  0.019099
# 194              -0.386          2.845       0.31       2.87  0.019472
# 195              -0.545          2.896       0.51       1.74  0.021964
# 196              -0.386          2.681       1.61       2.18  0.019709
# 197              -0.315          3.068      -0.41       1.95  0.019602
#
#      r2020B02  r2020B03  r2020B04  r2020B05  r2020B06  r2020B07  r2020B08  \
# 0    0.035344  0.028616  0.254417  0.175280  0.086611  0.797761 -0.749311
# 1    0.033537  0.022230  0.189826  0.092225  0.047120  0.789129 -0.705355
# 2    0.035957  0.021190  0.204363  0.093062  0.043824  0.812120 -0.704758
# 3    0.033868  0.025284  0.187998  0.102872  0.048585  0.762431 -0.695416
# 4    0.036153  0.024911  0.216271  0.096981  0.044880  0.793606 -0.717562
# ..        ...       ...       ...       ...       ...       ...       ...
# 193  0.033500  0.024009  0.183141  0.087021  0.041353  0.768626 -0.690308
# 194  0.033282  0.023425  0.213063  0.097829  0.043719  0.801855 -0.724049
# 195  0.035577  0.028173  0.180433  0.099119  0.050874  0.730297 -0.679586
# 196  0.036504  0.025100  0.219419  0.111967  0.051884  0.794534 -0.709182
# 197  0.032982  0.024029  0.187890  0.088149  0.042660  0.773055 -0.701580
#
#      r2020B09   r2020B10   r2020B11  r2020B12
# 0    0.491270 -15.527246 -11.385074  0.733806
# 1    0.659775 -16.547673 -10.947565  0.661723
# 2    0.631348 -14.341917 -11.884799  0.829603
# 3    0.601894 -14.885610 -11.725163  0.787609
# 4    0.642942 -14.647913 -11.512282  0.785698
# ..        ...        ...        ...       ...
# 193  0.647180 -15.082615  -8.697043  0.576864
# 194  0.616405 -13.816830 -11.614223  0.840547
# 195  0.568144 -17.216035 -10.492416  0.609540
# 196  0.601278 -14.444945 -11.085873  0.771277
# 197  0.607420 -13.819343 -10.713423  0.775819
#
# [198 rows x 20 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    r2020B01  r2020B03  r2020B05  r2020B06  r2020B07   r2020B10   r2020B11
# 0  0.019397  0.028616  0.175280  0.086611  0.797761 -15.527246 -11.385074
# 1  0.019167  0.022230  0.092225  0.047120  0.789129 -16.547673 -10.947565
# 2  0.019568  0.021190  0.093062  0.043824  0.812120 -14.341917 -11.884799
# 3  0.020556  0.025284  0.102872  0.048585  0.762431 -14.885610 -11.725163
# 4  0.019003  0.024911  0.096981  0.044880  0.793606 -14.647913 -11.512282

# %%
# Columns in "y" data collections
y.head()
# Out:
#    LN_M_AG_kg_m2
# 0          1.932
# 1          2.674
# 2          2.734
# 3          2.785
# 4          2.809

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.4256390343638169, 0.45188595622687533, -0.3065799080930214]
#     Mean: 0.190
#     Std: 0.352
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.71408543 0.84178138 0.83860243]
#     Mean: 0.798
#     Std: 0.059
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.5029190032337651, 0.6021848483139818, 0.6523283069097634]
#     Mean: 0.586
#     Std: 0.062
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.19889386656261027                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.4101907802915649                  # gamma
print('Gamma: ' + str(p2))

p3 = 0.04473444304408665                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2            # max_depth
print('Max_depth: ' + str(p4))

p5 = 114          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.4126482988885791                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.19889386656261027
# Gamma: 0.4101907802915649
# Learning_rate: 0.04473444304408665
# Max_depth: 2
# N_estimators: 114
# Subsample: 0.4126482988885791

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.94003	validation_1-rmse:2.01054
# [1]	validation_0-rmse:1.86479	validation_1-rmse:1.93627
# [2]	validation_0-rmse:1.79717	validation_1-rmse:1.87203
# [3]	validation_0-rmse:1.73292	validation_1-rmse:1.80889
# [4]	validation_0-rmse:1.67286	validation_1-rmse:1.75083
# [5]	validation_0-rmse:1.61522	validation_1-rmse:1.69367
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:1.56258	validation_1-rmse:1.64417
# [7]	validation_0-rmse:1.50425	validation_1-rmse:1.58997
# [8]	validation_0-rmse:1.45092	validation_1-rmse:1.53658
# [9]	validation_0-rmse:1.40371	validation_1-rmse:1.49216
# [10]	validation_0-rmse:1.36197	validation_1-rmse:1.45590
# [11]	validation_0-rmse:1.31563	validation_1-rmse:1.40946
# [12]	validation_0-rmse:1.27410	validation_1-rmse:1.37030
# [13]	validation_0-rmse:1.23957	validation_1-rmse:1.34001
# [14]	validation_0-rmse:1.20170	validation_1-rmse:1.30532
# [15]	validation_0-rmse:1.16592	validation_1-rmse:1.27001
# [16]	validation_0-rmse:1.13236	validation_1-rmse:1.23881
# [17]	validation_0-rmse:1.09333	validation_1-rmse:1.20323
# [18]	validation_0-rmse:1.06787	validation_1-rmse:1.17715
# [19]	validation_0-rmse:1.04197	validation_1-rmse:1.15301
# [20]	validation_0-rmse:1.01167	validation_1-rmse:1.12591
# [21]	validation_0-rmse:0.98567	validation_1-rmse:1.10106
# [22]	validation_0-rmse:0.95882	validation_1-rmse:1.07838
# [23]	validation_0-rmse:0.93295	validation_1-rmse:1.05566
# [24]	validation_0-rmse:0.90721	validation_1-rmse:1.03233
# [25]	validation_0-rmse:0.88684	validation_1-rmse:1.01369
# [26]	validation_0-rmse:0.86641	validation_1-rmse:0.99435
# [27]	validation_0-rmse:0.84888	validation_1-rmse:0.97644
# [28]	validation_0-rmse:0.83528	validation_1-rmse:0.96503
# [29]	validation_0-rmse:0.81641	validation_1-rmse:0.94998
# [30]	validation_0-rmse:0.80060	validation_1-rmse:0.93591
# [31]	validation_0-rmse:0.78988	validation_1-rmse:0.92955
# [32]	validation_0-rmse:0.77325	validation_1-rmse:0.91502
# [33]	validation_0-rmse:0.76121	validation_1-rmse:0.90512
# [34]	validation_0-rmse:0.75002	validation_1-rmse:0.89704
# [35]	validation_0-rmse:0.73920	validation_1-rmse:0.88516
# [36]	validation_0-rmse:0.73033	validation_1-rmse:0.87739
# [37]	validation_0-rmse:0.72067	validation_1-rmse:0.86788
# [38]	validation_0-rmse:0.71505	validation_1-rmse:0.86152
# [39]	validation_0-rmse:0.70432	validation_1-rmse:0.85293
# [40]	validation_0-rmse:0.69882	validation_1-rmse:0.84684
# [41]	validation_0-rmse:0.69075	validation_1-rmse:0.84128
# [42]	validation_0-rmse:0.68445	validation_1-rmse:0.84004
# [43]	validation_0-rmse:0.67800	validation_1-rmse:0.83880
# [44]	validation_0-rmse:0.67084	validation_1-rmse:0.83390
# [45]	validation_0-rmse:0.66190	validation_1-rmse:0.82789
# [46]	validation_0-rmse:0.65506	validation_1-rmse:0.82230
# [47]	validation_0-rmse:0.64768	validation_1-rmse:0.81731
# [48]	validation_0-rmse:0.64315	validation_1-rmse:0.81454
# [49]	validation_0-rmse:0.63509	validation_1-rmse:0.81067
# [50]	validation_0-rmse:0.62909	validation_1-rmse:0.80484
# [51]	validation_0-rmse:0.62440	validation_1-rmse:0.80240
# [52]	validation_0-rmse:0.61955	validation_1-rmse:0.80204
# [53]	validation_0-rmse:0.61460	validation_1-rmse:0.79970
# [54]	validation_0-rmse:0.61079	validation_1-rmse:0.79647
# [55]	validation_0-rmse:0.60646	validation_1-rmse:0.79561
# [56]	validation_0-rmse:0.60308	validation_1-rmse:0.79504
# [57]	validation_0-rmse:0.60008	validation_1-rmse:0.79343
# [58]	validation_0-rmse:0.59796	validation_1-rmse:0.79233
# [59]	validation_0-rmse:0.59438	validation_1-rmse:0.79047
# [60]	validation_0-rmse:0.59228	validation_1-rmse:0.78922
# [61]	validation_0-rmse:0.58964	validation_1-rmse:0.78669
# [62]	validation_0-rmse:0.58887	validation_1-rmse:0.78580
# [63]	validation_0-rmse:0.58576	validation_1-rmse:0.78569
# [64]	validation_0-rmse:0.58351	validation_1-rmse:0.78529
# [65]	validation_0-rmse:0.58086	validation_1-rmse:0.78325
# [66]	validation_0-rmse:0.57854	validation_1-rmse:0.78307
# [67]	validation_0-rmse:0.57639	validation_1-rmse:0.78018
# [68]	validation_0-rmse:0.57336	validation_1-rmse:0.77935
# [69]	validation_0-rmse:0.57207	validation_1-rmse:0.77968
# [70]	validation_0-rmse:0.57080	validation_1-rmse:0.78097
# [71]	validation_0-rmse:0.56795	validation_1-rmse:0.77955
# [72]	validation_0-rmse:0.56842	validation_1-rmse:0.77770
# [73]	validation_0-rmse:0.56748	validation_1-rmse:0.77792
# [74]	validation_0-rmse:0.56462	validation_1-rmse:0.77246
# [75]	validation_0-rmse:0.56307	validation_1-rmse:0.77100
# [76]	validation_0-rmse:0.56137	validation_1-rmse:0.77083
# [77]	validation_0-rmse:0.56018	validation_1-rmse:0.77095
# [78]	validation_0-rmse:0.55801	validation_1-rmse:0.77044
# [79]	validation_0-rmse:0.55681	validation_1-rmse:0.76976
# [80]	validation_0-rmse:0.55504	validation_1-rmse:0.77005
# [81]	validation_0-rmse:0.55455	validation_1-rmse:0.77063
# [82]	validation_0-rmse:0.55402	validation_1-rmse:0.76933
# [83]	validation_0-rmse:0.55332	validation_1-rmse:0.77127
# [84]	validation_0-rmse:0.55318	validation_1-rmse:0.77000
# [85]	validation_0-rmse:0.55169	validation_1-rmse:0.76918
# [86]	validation_0-rmse:0.55077	validation_1-rmse:0.76954
# [87]	validation_0-rmse:0.54779	validation_1-rmse:0.76989
# [88]	validation_0-rmse:0.54484	validation_1-rmse:0.77227
# [89]	validation_0-rmse:0.54423	validation_1-rmse:0.77224
# [90]	validation_0-rmse:0.54294	validation_1-rmse:0.77418
# [91]	validation_0-rmse:0.54212	validation_1-rmse:0.77362
# [92]	validation_0-rmse:0.54007	validation_1-rmse:0.77409
# [93]	validation_0-rmse:0.53997	validation_1-rmse:0.77377
# [94]	validation_0-rmse:0.53873	validation_1-rmse:0.77169
# [95]	validation_0-rmse:0.53749	validation_1-rmse:0.77342
# [96]	validation_0-rmse:0.53633	validation_1-rmse:0.77366
# [97]	validation_0-rmse:0.53458	validation_1-rmse:0.77339
# [98]	validation_0-rmse:0.53393	validation_1-rmse:0.77312
# [99]	validation_0-rmse:0.53314	validation_1-rmse:0.77420
# [100]	validation_0-rmse:0.53146	validation_1-rmse:0.77720
# [101]	validation_0-rmse:0.53011	validation_1-rmse:0.77743
# [102]	validation_0-rmse:0.52895	validation_1-rmse:0.77800
# [103]	validation_0-rmse:0.52807	validation_1-rmse:0.77894
# [104]	validation_0-rmse:0.52719	validation_1-rmse:0.77790
# [105]	validation_0-rmse:0.52580	validation_1-rmse:0.77990
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.94445	validation_1-rmse:1.99281
# [1]	validation_0-rmse:1.86768	validation_1-rmse:1.91626
# [2]	validation_0-rmse:1.79919	validation_1-rmse:1.85380
# [3]	validation_0-rmse:1.73456	validation_1-rmse:1.78890
# [4]	validation_0-rmse:1.67293	validation_1-rmse:1.73085
# [5]	validation_0-rmse:1.61725	validation_1-rmse:1.67615
# [6]	validation_0-rmse:1.56382	validation_1-rmse:1.63241
# [7]	validation_0-rmse:1.50483	validation_1-rmse:1.57319
# [8]	validation_0-rmse:1.45432	validation_1-rmse:1.52392
# [9]	validation_0-rmse:1.40820	validation_1-rmse:1.47794
# [10]	validation_0-rmse:1.36278	validation_1-rmse:1.43753
# [11]	validation_0-rmse:1.31937	validation_1-rmse:1.39920
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [12]	validation_0-rmse:1.27750	validation_1-rmse:1.35663
# [13]	validation_0-rmse:1.23835	validation_1-rmse:1.32478
# [14]	validation_0-rmse:1.19928	validation_1-rmse:1.28530
# [15]	validation_0-rmse:1.16155	validation_1-rmse:1.24938
# [16]	validation_0-rmse:1.12410	validation_1-rmse:1.21466
# [17]	validation_0-rmse:1.09447	validation_1-rmse:1.18297
# [18]	validation_0-rmse:1.06378	validation_1-rmse:1.15759
# [19]	validation_0-rmse:1.03327	validation_1-rmse:1.13012
# [20]	validation_0-rmse:1.00538	validation_1-rmse:1.10454
# [21]	validation_0-rmse:0.97844	validation_1-rmse:1.07935
# [22]	validation_0-rmse:0.95419	validation_1-rmse:1.05598
# [23]	validation_0-rmse:0.93032	validation_1-rmse:1.03224
# [24]	validation_0-rmse:0.90838	validation_1-rmse:1.01226
# [25]	validation_0-rmse:0.88668	validation_1-rmse:0.98684
# [26]	validation_0-rmse:0.86945	validation_1-rmse:0.97548
# [27]	validation_0-rmse:0.85286	validation_1-rmse:0.96132
# [28]	validation_0-rmse:0.84013	validation_1-rmse:0.95023
# [29]	validation_0-rmse:0.82371	validation_1-rmse:0.93092
# [30]	validation_0-rmse:0.80615	validation_1-rmse:0.91363
# [31]	validation_0-rmse:0.79232	validation_1-rmse:0.90307
# [32]	validation_0-rmse:0.77898	validation_1-rmse:0.88878
# [33]	validation_0-rmse:0.76528	validation_1-rmse:0.87408
# [34]	validation_0-rmse:0.75514	validation_1-rmse:0.86537
# [35]	validation_0-rmse:0.74537	validation_1-rmse:0.86091
# [36]	validation_0-rmse:0.73299	validation_1-rmse:0.85436
# [37]	validation_0-rmse:0.72316	validation_1-rmse:0.84525
# [38]	validation_0-rmse:0.71404	validation_1-rmse:0.83908
# [39]	validation_0-rmse:0.70405	validation_1-rmse:0.82788
# [40]	validation_0-rmse:0.69734	validation_1-rmse:0.82383
# [41]	validation_0-rmse:0.68801	validation_1-rmse:0.81524
# [42]	validation_0-rmse:0.68104	validation_1-rmse:0.80855
# [43]	validation_0-rmse:0.67652	validation_1-rmse:0.80509
# [44]	validation_0-rmse:0.67119	validation_1-rmse:0.79980
# [45]	validation_0-rmse:0.66713	validation_1-rmse:0.79915
# [46]	validation_0-rmse:0.66074	validation_1-rmse:0.79265
# [47]	validation_0-rmse:0.65387	validation_1-rmse:0.78358
# [48]	validation_0-rmse:0.64857	validation_1-rmse:0.78362
# [49]	validation_0-rmse:0.64434	validation_1-rmse:0.78208
# [50]	validation_0-rmse:0.63845	validation_1-rmse:0.77401
# [51]	validation_0-rmse:0.63438	validation_1-rmse:0.77339
# [52]	validation_0-rmse:0.62905	validation_1-rmse:0.77124
# [53]	validation_0-rmse:0.62522	validation_1-rmse:0.76523
# [54]	validation_0-rmse:0.62347	validation_1-rmse:0.76659
# [55]	validation_0-rmse:0.62113	validation_1-rmse:0.76709
# [56]	validation_0-rmse:0.61914	validation_1-rmse:0.77107
# [57]	validation_0-rmse:0.61780	validation_1-rmse:0.77150
# [58]	validation_0-rmse:0.61443	validation_1-rmse:0.76963
# [59]	validation_0-rmse:0.61147	validation_1-rmse:0.76854
# [60]	validation_0-rmse:0.60875	validation_1-rmse:0.76594
# [61]	validation_0-rmse:0.60720	validation_1-rmse:0.76279
# [62]	validation_0-rmse:0.60453	validation_1-rmse:0.76043
# [63]	validation_0-rmse:0.60165	validation_1-rmse:0.76061
# [64]	validation_0-rmse:0.59888	validation_1-rmse:0.75836
# [65]	validation_0-rmse:0.59513	validation_1-rmse:0.75582
# [66]	validation_0-rmse:0.59327	validation_1-rmse:0.75219
# [67]	validation_0-rmse:0.59125	validation_1-rmse:0.74841
# [68]	validation_0-rmse:0.59040	validation_1-rmse:0.74730
# [69]	validation_0-rmse:0.58835	validation_1-rmse:0.74435
# [70]	validation_0-rmse:0.58546	validation_1-rmse:0.74174
# [71]	validation_0-rmse:0.58297	validation_1-rmse:0.74039
# [72]	validation_0-rmse:0.58171	validation_1-rmse:0.74175
# [73]	validation_0-rmse:0.57877	validation_1-rmse:0.73641
# [74]	validation_0-rmse:0.57736	validation_1-rmse:0.73242
# [75]	validation_0-rmse:0.57644	validation_1-rmse:0.73264
# [76]	validation_0-rmse:0.57429	validation_1-rmse:0.73296
# [77]	validation_0-rmse:0.57328	validation_1-rmse:0.73145
# [78]	validation_0-rmse:0.57134	validation_1-rmse:0.72638
# [79]	validation_0-rmse:0.57124	validation_1-rmse:0.72661
# [80]	validation_0-rmse:0.57118	validation_1-rmse:0.72704
# [81]	validation_0-rmse:0.57066	validation_1-rmse:0.72762
# [82]	validation_0-rmse:0.57070	validation_1-rmse:0.72734
# [83]	validation_0-rmse:0.56970	validation_1-rmse:0.72631
# [84]	validation_0-rmse:0.56866	validation_1-rmse:0.72553
# [85]	validation_0-rmse:0.56797	validation_1-rmse:0.72148
# [86]	validation_0-rmse:0.56793	validation_1-rmse:0.72208
# [87]	validation_0-rmse:0.56670	validation_1-rmse:0.72098
# [88]	validation_0-rmse:0.56471	validation_1-rmse:0.72134
# [89]	validation_0-rmse:0.56434	validation_1-rmse:0.72159
# [90]	validation_0-rmse:0.56431	validation_1-rmse:0.72206
# [91]	validation_0-rmse:0.56197	validation_1-rmse:0.71876
# [92]	validation_0-rmse:0.56116	validation_1-rmse:0.71562
# [93]	validation_0-rmse:0.56018	validation_1-rmse:0.71734
# [94]	validation_0-rmse:0.55907	validation_1-rmse:0.71883
# [95]	validation_0-rmse:0.55795	validation_1-rmse:0.71925
# [96]	validation_0-rmse:0.55675	validation_1-rmse:0.72000
# [97]	validation_0-rmse:0.55506	validation_1-rmse:0.71622
# [98]	validation_0-rmse:0.55426	validation_1-rmse:0.71661
# [99]	validation_0-rmse:0.55250	validation_1-rmse:0.71737
# [100]	validation_0-rmse:0.55110	validation_1-rmse:0.72020
# [101]	validation_0-rmse:0.54959	validation_1-rmse:0.71879
# [102]	validation_0-rmse:0.54803	validation_1-rmse:0.71849
# [103]	validation_0-rmse:0.54700	validation_1-rmse:0.71584
# [104]	validation_0-rmse:0.54485	validation_1-rmse:0.71439
# [105]	validation_0-rmse:0.54379	validation_1-rmse:0.71415
# [106]	validation_0-rmse:0.54315	validation_1-rmse:0.71583
# [107]	validation_0-rmse:0.54122	validation_1-rmse:0.71679
# [108]	validation_0-rmse:0.54009	validation_1-rmse:0.71588
# [109]	validation_0-rmse:0.53937	validation_1-rmse:0.71509
# [110]	validation_0-rmse:0.53925	validation_1-rmse:0.71570
# [111]	validation_0-rmse:0.53840	validation_1-rmse:0.71826
# [112]	validation_0-rmse:0.53647	validation_1-rmse:0.71646
# [113]	validation_0-rmse:0.53613	validation_1-rmse:0.71555
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.96046	validation_1-rmse:1.92937
# [1]	validation_0-rmse:1.88282	validation_1-rmse:1.85083
# [2]	validation_0-rmse:1.80854	validation_1-rmse:1.77917
# [3]	validation_0-rmse:1.74988	validation_1-rmse:1.72377
# [4]	validation_0-rmse:1.69180	validation_1-rmse:1.66565
# [5]	validation_0-rmse:1.62797	validation_1-rmse:1.60120
# [6]	validation_0-rmse:1.57225	validation_1-rmse:1.54681
# [7]	validation_0-rmse:1.51890	validation_1-rmse:1.49340
# [8]	validation_0-rmse:1.46439	validation_1-rmse:1.43958
# [9]	validation_0-rmse:1.41477	validation_1-rmse:1.39281
# [10]	validation_0-rmse:1.36820	validation_1-rmse:1.34806
# [11]	validation_0-rmse:1.31788	validation_1-rmse:1.29923
# [12]	validation_0-rmse:1.27653	validation_1-rmse:1.25603
# [13]	validation_0-rmse:1.23763	validation_1-rmse:1.21945
# [14]	validation_0-rmse:1.19511	validation_1-rmse:1.17641
# [15]	validation_0-rmse:1.15920	validation_1-rmse:1.13956
# [16]	validation_0-rmse:1.12804	validation_1-rmse:1.11164
# [17]	validation_0-rmse:1.09193	validation_1-rmse:1.07664
# [18]	validation_0-rmse:1.06240	validation_1-rmse:1.04868
# [19]	validation_0-rmse:1.03535	validation_1-rmse:1.02211
# [20]	validation_0-rmse:1.00678	validation_1-rmse:0.99461
# [21]	validation_0-rmse:0.98078	validation_1-rmse:0.97256
# [22]	validation_0-rmse:0.95782	validation_1-rmse:0.95030
# [23]	validation_0-rmse:0.93427	validation_1-rmse:0.92968
# [24]	validation_0-rmse:0.91856	validation_1-rmse:0.91555
# [25]	validation_0-rmse:0.89532	validation_1-rmse:0.89611
# [26]	validation_0-rmse:0.87429	validation_1-rmse:0.87694
# [27]	validation_0-rmse:0.85689	validation_1-rmse:0.85979
# [28]	validation_0-rmse:0.84401	validation_1-rmse:0.84738
# [29]	validation_0-rmse:0.82646	validation_1-rmse:0.83336
# [30]	validation_0-rmse:0.80958	validation_1-rmse:0.81874
# [31]	validation_0-rmse:0.79754	validation_1-rmse:0.80713
# [32]	validation_0-rmse:0.78339	validation_1-rmse:0.79676
# [33]	validation_0-rmse:0.76994	validation_1-rmse:0.78672
# [34]	validation_0-rmse:0.75687	validation_1-rmse:0.77398
# [35]	validation_0-rmse:0.74801	validation_1-rmse:0.77063
# [36]	validation_0-rmse:0.74016	validation_1-rmse:0.76542
# [37]	validation_0-rmse:0.72750	validation_1-rmse:0.75694
# [38]	validation_0-rmse:0.71896	validation_1-rmse:0.75237
# [39]	validation_0-rmse:0.70843	validation_1-rmse:0.74739
# [40]	validation_0-rmse:0.70228	validation_1-rmse:0.74305
# [41]	validation_0-rmse:0.69290	validation_1-rmse:0.73771
# [42]	validation_0-rmse:0.68596	validation_1-rmse:0.73338
# [43]	validation_0-rmse:0.68191	validation_1-rmse:0.73306
# [44]	validation_0-rmse:0.67525	validation_1-rmse:0.72880
# [45]	validation_0-rmse:0.66764	validation_1-rmse:0.72355
# [46]	validation_0-rmse:0.65831	validation_1-rmse:0.71969
# [47]	validation_0-rmse:0.65155	validation_1-rmse:0.72080
# [48]	validation_0-rmse:0.64563	validation_1-rmse:0.71730
# [49]	validation_0-rmse:0.63891	validation_1-rmse:0.71489
# [50]	validation_0-rmse:0.63325	validation_1-rmse:0.71316
# [51]	validation_0-rmse:0.62863	validation_1-rmse:0.71547
# [52]	validation_0-rmse:0.62541	validation_1-rmse:0.71319
# [53]	validation_0-rmse:0.62000	validation_1-rmse:0.71157
# [54]	validation_0-rmse:0.61439	validation_1-rmse:0.70728
# [55]	validation_0-rmse:0.61026	validation_1-rmse:0.70609
# [56]	validation_0-rmse:0.60807	validation_1-rmse:0.70547
# [57]	validation_0-rmse:0.60513	validation_1-rmse:0.70527
# [58]	validation_0-rmse:0.60253	validation_1-rmse:0.70307
# [59]	validation_0-rmse:0.59892	validation_1-rmse:0.70228
# [60]	validation_0-rmse:0.59665	validation_1-rmse:0.70097
# [61]	validation_0-rmse:0.59190	validation_1-rmse:0.70233
# [62]	validation_0-rmse:0.58987	validation_1-rmse:0.70077
# [63]	validation_0-rmse:0.58720	validation_1-rmse:0.70021
# [64]	validation_0-rmse:0.58500	validation_1-rmse:0.70057
# [65]	validation_0-rmse:0.58116	validation_1-rmse:0.70295
# [66]	validation_0-rmse:0.58082	validation_1-rmse:0.70328
# [67]	validation_0-rmse:0.57697	validation_1-rmse:0.70350
# [68]	validation_0-rmse:0.57425	validation_1-rmse:0.70289
# [69]	validation_0-rmse:0.57233	validation_1-rmse:0.70205
# [70]	validation_0-rmse:0.57133	validation_1-rmse:0.70202
# [71]	validation_0-rmse:0.56877	validation_1-rmse:0.70212
# [72]	validation_0-rmse:0.56707	validation_1-rmse:0.70282
# [73]	validation_0-rmse:0.56492	validation_1-rmse:0.70378
# [74]	validation_0-rmse:0.56151	validation_1-rmse:0.70364
# [75]	validation_0-rmse:0.56036	validation_1-rmse:0.70500
# [76]	validation_0-rmse:0.55990	validation_1-rmse:0.70538
# [77]	validation_0-rmse:0.55876	validation_1-rmse:0.70660
# [78]	validation_0-rmse:0.55602	validation_1-rmse:0.70577
# [79]	validation_0-rmse:0.55442	validation_1-rmse:0.70528
# [80]	validation_0-rmse:0.55226	validation_1-rmse:0.70488
# [81]	validation_0-rmse:0.55085	validation_1-rmse:0.70533
# [82]	validation_0-rmse:0.55006	validation_1-rmse:0.70537
# [83]	validation_0-rmse:0.54903	validation_1-rmse:0.70420
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.94751	validation_1-rmse:2.02364
# [1]	validation_0-rmse:1.88379	validation_1-rmse:1.95448
# [2]	validation_0-rmse:1.82132	validation_1-rmse:1.88149
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:1.75534	validation_1-rmse:1.81338
# [4]	validation_0-rmse:1.69351	validation_1-rmse:1.74059
# [5]	validation_0-rmse:1.63412	validation_1-rmse:1.68199
# [6]	validation_0-rmse:1.57989	validation_1-rmse:1.61946
# [7]	validation_0-rmse:1.52845	validation_1-rmse:1.56470
# [8]	validation_0-rmse:1.47048	validation_1-rmse:1.50010
# [9]	validation_0-rmse:1.42090	validation_1-rmse:1.45091
# [10]	validation_0-rmse:1.37981	validation_1-rmse:1.40152
# [11]	validation_0-rmse:1.33492	validation_1-rmse:1.35073
# [12]	validation_0-rmse:1.29593	validation_1-rmse:1.31016
# [13]	validation_0-rmse:1.26099	validation_1-rmse:1.26498
# [14]	validation_0-rmse:1.22471	validation_1-rmse:1.22565
# [15]	validation_0-rmse:1.19329	validation_1-rmse:1.19097
# [16]	validation_0-rmse:1.15733	validation_1-rmse:1.15444
# [17]	validation_0-rmse:1.12837	validation_1-rmse:1.12316
# [18]	validation_0-rmse:1.09764	validation_1-rmse:1.08435
# [19]	validation_0-rmse:1.06722	validation_1-rmse:1.05324
# [20]	validation_0-rmse:1.03837	validation_1-rmse:1.02162
# [21]	validation_0-rmse:1.01208	validation_1-rmse:0.99432
# [22]	validation_0-rmse:0.99179	validation_1-rmse:0.97012
# [23]	validation_0-rmse:0.96940	validation_1-rmse:0.94490
# [24]	validation_0-rmse:0.94792	validation_1-rmse:0.92044
# [25]	validation_0-rmse:0.92641	validation_1-rmse:0.89451
# [26]	validation_0-rmse:0.90702	validation_1-rmse:0.87162
# [27]	validation_0-rmse:0.88667	validation_1-rmse:0.85003
# [28]	validation_0-rmse:0.87256	validation_1-rmse:0.82988
# [29]	validation_0-rmse:0.85588	validation_1-rmse:0.80999
# [30]	validation_0-rmse:0.83895	validation_1-rmse:0.79345
# [31]	validation_0-rmse:0.82866	validation_1-rmse:0.78097
# [32]	validation_0-rmse:0.81188	validation_1-rmse:0.76219
# [33]	validation_0-rmse:0.80034	validation_1-rmse:0.74910
# [34]	validation_0-rmse:0.78652	validation_1-rmse:0.73464
# [35]	validation_0-rmse:0.77670	validation_1-rmse:0.72069
# [36]	validation_0-rmse:0.76788	validation_1-rmse:0.70943
# [37]	validation_0-rmse:0.75509	validation_1-rmse:0.69894
# [38]	validation_0-rmse:0.74797	validation_1-rmse:0.68953
# [39]	validation_0-rmse:0.73707	validation_1-rmse:0.68193
# [40]	validation_0-rmse:0.73120	validation_1-rmse:0.67310
# [41]	validation_0-rmse:0.72211	validation_1-rmse:0.66870
# [42]	validation_0-rmse:0.71430	validation_1-rmse:0.65962
# [43]	validation_0-rmse:0.70904	validation_1-rmse:0.65247
# [44]	validation_0-rmse:0.70086	validation_1-rmse:0.64704
# [45]	validation_0-rmse:0.69312	validation_1-rmse:0.63896
# [46]	validation_0-rmse:0.68507	validation_1-rmse:0.63372
# [47]	validation_0-rmse:0.68065	validation_1-rmse:0.62881
# [48]	validation_0-rmse:0.67874	validation_1-rmse:0.62429
# [49]	validation_0-rmse:0.67189	validation_1-rmse:0.61740
# [50]	validation_0-rmse:0.66715	validation_1-rmse:0.61339
# [51]	validation_0-rmse:0.66106	validation_1-rmse:0.60758
# [52]	validation_0-rmse:0.65840	validation_1-rmse:0.60648
# [53]	validation_0-rmse:0.65588	validation_1-rmse:0.60485
# [54]	validation_0-rmse:0.65299	validation_1-rmse:0.60079
# [55]	validation_0-rmse:0.65048	validation_1-rmse:0.59844
# [56]	validation_0-rmse:0.64775	validation_1-rmse:0.59297
# [57]	validation_0-rmse:0.64503	validation_1-rmse:0.58906
# [58]	validation_0-rmse:0.64326	validation_1-rmse:0.58722
# [59]	validation_0-rmse:0.63848	validation_1-rmse:0.58552
# [60]	validation_0-rmse:0.63581	validation_1-rmse:0.58090
# [61]	validation_0-rmse:0.63250	validation_1-rmse:0.58255
# [62]	validation_0-rmse:0.62990	validation_1-rmse:0.57743
# [63]	validation_0-rmse:0.62746	validation_1-rmse:0.57811
# [64]	validation_0-rmse:0.62350	validation_1-rmse:0.57797
# [65]	validation_0-rmse:0.62002	validation_1-rmse:0.57608
# [66]	validation_0-rmse:0.61785	validation_1-rmse:0.57276
# [67]	validation_0-rmse:0.61386	validation_1-rmse:0.57252
# [68]	validation_0-rmse:0.60959	validation_1-rmse:0.56893
# [69]	validation_0-rmse:0.60748	validation_1-rmse:0.56563
# [70]	validation_0-rmse:0.60544	validation_1-rmse:0.56447
# [71]	validation_0-rmse:0.60243	validation_1-rmse:0.56307
# [72]	validation_0-rmse:0.60136	validation_1-rmse:0.56030
# [73]	validation_0-rmse:0.59815	validation_1-rmse:0.55821
# [74]	validation_0-rmse:0.59531	validation_1-rmse:0.55582
# [75]	validation_0-rmse:0.59352	validation_1-rmse:0.55359
# [76]	validation_0-rmse:0.59118	validation_1-rmse:0.55541
# [77]	validation_0-rmse:0.58857	validation_1-rmse:0.55733
# [78]	validation_0-rmse:0.58618	validation_1-rmse:0.55579
# [79]	validation_0-rmse:0.58404	validation_1-rmse:0.55756
# [80]	validation_0-rmse:0.58170	validation_1-rmse:0.55778
# [81]	validation_0-rmse:0.58019	validation_1-rmse:0.55548
# [82]	validation_0-rmse:0.57977	validation_1-rmse:0.55625
# [83]	validation_0-rmse:0.57728	validation_1-rmse:0.55583
# [84]	validation_0-rmse:0.57681	validation_1-rmse:0.55548
# [85]	validation_0-rmse:0.57520	validation_1-rmse:0.55550
# [86]	validation_0-rmse:0.57350	validation_1-rmse:0.55466
# [87]	validation_0-rmse:0.57086	validation_1-rmse:0.55396
# [88]	validation_0-rmse:0.56842	validation_1-rmse:0.55351
# [89]	validation_0-rmse:0.56770	validation_1-rmse:0.55278
# [90]	validation_0-rmse:0.56719	validation_1-rmse:0.54931
# [91]	validation_0-rmse:0.56507	validation_1-rmse:0.55024
# [92]	validation_0-rmse:0.56415	validation_1-rmse:0.54889
# [93]	validation_0-rmse:0.56377	validation_1-rmse:0.55102
# [94]	validation_0-rmse:0.56224	validation_1-rmse:0.55095
# [95]	validation_0-rmse:0.56090	validation_1-rmse:0.55012
# [96]	validation_0-rmse:0.56016	validation_1-rmse:0.54934
# [97]	validation_0-rmse:0.55873	validation_1-rmse:0.55086
# [98]	validation_0-rmse:0.55808	validation_1-rmse:0.54965
# [99]	validation_0-rmse:0.55791	validation_1-rmse:0.55024
# [100]	validation_0-rmse:0.55629	validation_1-rmse:0.55118
# [101]	validation_0-rmse:0.55506	validation_1-rmse:0.55061
# [102]	validation_0-rmse:0.55250	validation_1-rmse:0.54960
# [103]	validation_0-rmse:0.55222	validation_1-rmse:0.54909
# [104]	validation_0-rmse:0.54983	validation_1-rmse:0.54773
# [105]	validation_0-rmse:0.54848	validation_1-rmse:0.54830
# [106]	validation_0-rmse:0.54734	validation_1-rmse:0.54966
# [107]	validation_0-rmse:0.54728	validation_1-rmse:0.55121
# [108]	validation_0-rmse:0.54676	validation_1-rmse:0.54916
# [109]	validation_0-rmse:0.54619	validation_1-rmse:0.55267
# [110]	validation_0-rmse:0.54580	validation_1-rmse:0.55263
# [111]	validation_0-rmse:0.54498	validation_1-rmse:0.55198
# [112]	validation_0-rmse:0.54446	validation_1-rmse:0.55197
# [113]	validation_0-rmse:0.54356	validation_1-rmse:0.55524
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.96219	validation_1-rmse:1.91441
# [1]	validation_0-rmse:1.89547	validation_1-rmse:1.84386
# [2]	validation_0-rmse:1.82943	validation_1-rmse:1.77836
# [3]	validation_0-rmse:1.76062	validation_1-rmse:1.70596
# [4]	validation_0-rmse:1.70065	validation_1-rmse:1.64540
# [5]	validation_0-rmse:1.64270	validation_1-rmse:1.58171
# [6]	validation_0-rmse:1.58949	validation_1-rmse:1.52875
# [7]	validation_0-rmse:1.53326	validation_1-rmse:1.47033
# [8]	validation_0-rmse:1.47998	validation_1-rmse:1.41610
# [9]	validation_0-rmse:1.42816	validation_1-rmse:1.36394
# [10]	validation_0-rmse:1.38979	validation_1-rmse:1.32769
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:1.34313	validation_1-rmse:1.27904
# [12]	validation_0-rmse:1.30189	validation_1-rmse:1.23527
# [13]	validation_0-rmse:1.26420	validation_1-rmse:1.19519
# [14]	validation_0-rmse:1.22834	validation_1-rmse:1.15662
# [15]	validation_0-rmse:1.19153	validation_1-rmse:1.11814
# [16]	validation_0-rmse:1.15148	validation_1-rmse:1.07816
# [17]	validation_0-rmse:1.11785	validation_1-rmse:1.04450
# [18]	validation_0-rmse:1.09267	validation_1-rmse:1.01689
# [19]	validation_0-rmse:1.06306	validation_1-rmse:0.98472
# [20]	validation_0-rmse:1.03426	validation_1-rmse:0.95387
# [21]	validation_0-rmse:1.01382	validation_1-rmse:0.93113
# [22]	validation_0-rmse:0.99155	validation_1-rmse:0.90847
# [23]	validation_0-rmse:0.97005	validation_1-rmse:0.88739
# [24]	validation_0-rmse:0.94959	validation_1-rmse:0.86567
# [25]	validation_0-rmse:0.92733	validation_1-rmse:0.84449
# [26]	validation_0-rmse:0.90741	validation_1-rmse:0.82447
# [27]	validation_0-rmse:0.89300	validation_1-rmse:0.81242
# [28]	validation_0-rmse:0.87608	validation_1-rmse:0.79728
# [29]	validation_0-rmse:0.85857	validation_1-rmse:0.78063
# [30]	validation_0-rmse:0.84154	validation_1-rmse:0.76488
# [31]	validation_0-rmse:0.82980	validation_1-rmse:0.75082
# [32]	validation_0-rmse:0.81161	validation_1-rmse:0.73529
# [33]	validation_0-rmse:0.79928	validation_1-rmse:0.72308
# [34]	validation_0-rmse:0.78621	validation_1-rmse:0.71194
# [35]	validation_0-rmse:0.77562	validation_1-rmse:0.70224
# [36]	validation_0-rmse:0.76701	validation_1-rmse:0.69376
# [37]	validation_0-rmse:0.75607	validation_1-rmse:0.68444
# [38]	validation_0-rmse:0.74769	validation_1-rmse:0.67722
# [39]	validation_0-rmse:0.73959	validation_1-rmse:0.67083
# [40]	validation_0-rmse:0.73180	validation_1-rmse:0.66388
# [41]	validation_0-rmse:0.72254	validation_1-rmse:0.65530
# [42]	validation_0-rmse:0.71528	validation_1-rmse:0.65429
# [43]	validation_0-rmse:0.71120	validation_1-rmse:0.64951
# [44]	validation_0-rmse:0.70434	validation_1-rmse:0.64231
# [45]	validation_0-rmse:0.70203	validation_1-rmse:0.64109
# [46]	validation_0-rmse:0.69425	validation_1-rmse:0.63382
# [47]	validation_0-rmse:0.68867	validation_1-rmse:0.62954
# [48]	validation_0-rmse:0.68326	validation_1-rmse:0.62587
# [49]	validation_0-rmse:0.67802	validation_1-rmse:0.62126
# [50]	validation_0-rmse:0.67200	validation_1-rmse:0.61575
# [51]	validation_0-rmse:0.66838	validation_1-rmse:0.61344
# [52]	validation_0-rmse:0.66465	validation_1-rmse:0.61099
# [53]	validation_0-rmse:0.65985	validation_1-rmse:0.60765
# [54]	validation_0-rmse:0.65627	validation_1-rmse:0.60439
# [55]	validation_0-rmse:0.65255	validation_1-rmse:0.60170
# [56]	validation_0-rmse:0.64854	validation_1-rmse:0.59935
# [57]	validation_0-rmse:0.64493	validation_1-rmse:0.59625
# [58]	validation_0-rmse:0.64304	validation_1-rmse:0.59483
# [59]	validation_0-rmse:0.63825	validation_1-rmse:0.59150
# [60]	validation_0-rmse:0.63514	validation_1-rmse:0.59201
# [61]	validation_0-rmse:0.63135	validation_1-rmse:0.58961
# [62]	validation_0-rmse:0.62890	validation_1-rmse:0.58801
# [63]	validation_0-rmse:0.62788	validation_1-rmse:0.58766
# [64]	validation_0-rmse:0.62459	validation_1-rmse:0.58894
# [65]	validation_0-rmse:0.62229	validation_1-rmse:0.58632
# [66]	validation_0-rmse:0.61925	validation_1-rmse:0.58501
# [67]	validation_0-rmse:0.61662	validation_1-rmse:0.58338
# [68]	validation_0-rmse:0.61473	validation_1-rmse:0.58198
# [69]	validation_0-rmse:0.61257	validation_1-rmse:0.58254
# [70]	validation_0-rmse:0.61106	validation_1-rmse:0.58091
# [71]	validation_0-rmse:0.60827	validation_1-rmse:0.57932
# [72]	validation_0-rmse:0.60740	validation_1-rmse:0.57946
# [73]	validation_0-rmse:0.60655	validation_1-rmse:0.57701
# [74]	validation_0-rmse:0.60507	validation_1-rmse:0.57658
# [75]	validation_0-rmse:0.60371	validation_1-rmse:0.57638
# [76]	validation_0-rmse:0.60093	validation_1-rmse:0.57796
# [77]	validation_0-rmse:0.60012	validation_1-rmse:0.57985
# [78]	validation_0-rmse:0.59772	validation_1-rmse:0.57969
# [79]	validation_0-rmse:0.59509	validation_1-rmse:0.58181
# [80]	validation_0-rmse:0.59393	validation_1-rmse:0.58123
# [81]	validation_0-rmse:0.59269	validation_1-rmse:0.58304
# [82]	validation_0-rmse:0.59120	validation_1-rmse:0.58209
# [83]	validation_0-rmse:0.58974	validation_1-rmse:0.58150
# [84]	validation_0-rmse:0.58839	validation_1-rmse:0.57983
# [85]	validation_0-rmse:0.58712	validation_1-rmse:0.58150
# [86]	validation_0-rmse:0.58470	validation_1-rmse:0.58112
# [87]	validation_0-rmse:0.58238	validation_1-rmse:0.58044
# [88]	validation_0-rmse:0.58179	validation_1-rmse:0.58120
# [89]	validation_0-rmse:0.58062	validation_1-rmse:0.58445
# [90]	validation_0-rmse:0.58082	validation_1-rmse:0.58552
# [91]	validation_0-rmse:0.57895	validation_1-rmse:0.58260
# [92]	validation_0-rmse:0.57822	validation_1-rmse:0.58291
# [93]	validation_0-rmse:0.57766	validation_1-rmse:0.58292
# [94]	validation_0-rmse:0.57654	validation_1-rmse:0.58012
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.95212	validation_1-rmse:1.94991
# [1]	validation_0-rmse:1.87949	validation_1-rmse:1.87823
# [2]	validation_0-rmse:1.81222	validation_1-rmse:1.81067
# [3]	validation_0-rmse:1.74074	validation_1-rmse:1.74100
# [4]	validation_0-rmse:1.68208	validation_1-rmse:1.68147
# [5]	validation_0-rmse:1.62559	validation_1-rmse:1.63055
# [6]	validation_0-rmse:1.57216	validation_1-rmse:1.57791
# [7]	validation_0-rmse:1.51923	validation_1-rmse:1.52885
# [8]	validation_0-rmse:1.46791	validation_1-rmse:1.47929
# [9]	validation_0-rmse:1.42076	validation_1-rmse:1.43437
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [10]	validation_0-rmse:1.37659	validation_1-rmse:1.38678
# [11]	validation_0-rmse:1.33165	validation_1-rmse:1.34386
# [12]	validation_0-rmse:1.28764	validation_1-rmse:1.29978
# [13]	validation_0-rmse:1.24922	validation_1-rmse:1.25983
# [14]	validation_0-rmse:1.20824	validation_1-rmse:1.22583
# [15]	validation_0-rmse:1.17259	validation_1-rmse:1.18593
# [16]	validation_0-rmse:1.13993	validation_1-rmse:1.15300
# [17]	validation_0-rmse:1.10978	validation_1-rmse:1.12506
# [18]	validation_0-rmse:1.08165	validation_1-rmse:1.09691
# [19]	validation_0-rmse:1.05142	validation_1-rmse:1.06454
# [20]	validation_0-rmse:1.02905	validation_1-rmse:1.04988
# [21]	validation_0-rmse:1.00132	validation_1-rmse:1.02166
# [22]	validation_0-rmse:0.97877	validation_1-rmse:1.00109
# [23]	validation_0-rmse:0.95505	validation_1-rmse:0.97849
# [24]	validation_0-rmse:0.93438	validation_1-rmse:0.96204
# [25]	validation_0-rmse:0.90849	validation_1-rmse:0.93265
# [26]	validation_0-rmse:0.89392	validation_1-rmse:0.91679
# [27]	validation_0-rmse:0.87767	validation_1-rmse:0.90265
# [28]	validation_0-rmse:0.86355	validation_1-rmse:0.88604
# [29]	validation_0-rmse:0.84671	validation_1-rmse:0.86818
# [30]	validation_0-rmse:0.83028	validation_1-rmse:0.85024
# [31]	validation_0-rmse:0.81998	validation_1-rmse:0.84139
# [32]	validation_0-rmse:0.80670	validation_1-rmse:0.82676
# [33]	validation_0-rmse:0.79502	validation_1-rmse:0.81622
# [34]	validation_0-rmse:0.78518	validation_1-rmse:0.80867
# [35]	validation_0-rmse:0.77770	validation_1-rmse:0.80167
# [36]	validation_0-rmse:0.76994	validation_1-rmse:0.79333
# [37]	validation_0-rmse:0.76078	validation_1-rmse:0.78423
# [38]	validation_0-rmse:0.75212	validation_1-rmse:0.77434
# [39]	validation_0-rmse:0.74306	validation_1-rmse:0.76498
# [40]	validation_0-rmse:0.73591	validation_1-rmse:0.75567
# [41]	validation_0-rmse:0.72725	validation_1-rmse:0.74851
# [42]	validation_0-rmse:0.71974	validation_1-rmse:0.74188
# [43]	validation_0-rmse:0.71354	validation_1-rmse:0.73538
# [44]	validation_0-rmse:0.70911	validation_1-rmse:0.73335
# [45]	validation_0-rmse:0.70310	validation_1-rmse:0.73231
# [46]	validation_0-rmse:0.69505	validation_1-rmse:0.72605
# [47]	validation_0-rmse:0.68743	validation_1-rmse:0.71684
# [48]	validation_0-rmse:0.68413	validation_1-rmse:0.71181
# [49]	validation_0-rmse:0.67943	validation_1-rmse:0.70538
# [50]	validation_0-rmse:0.67287	validation_1-rmse:0.70006
# [51]	validation_0-rmse:0.66938	validation_1-rmse:0.69705
# [52]	validation_0-rmse:0.66553	validation_1-rmse:0.69210
# [53]	validation_0-rmse:0.66130	validation_1-rmse:0.68937
# [54]	validation_0-rmse:0.65675	validation_1-rmse:0.68135
# [55]	validation_0-rmse:0.65412	validation_1-rmse:0.67670
# [56]	validation_0-rmse:0.65228	validation_1-rmse:0.67675
# [57]	validation_0-rmse:0.64930	validation_1-rmse:0.67030
# [58]	validation_0-rmse:0.64724	validation_1-rmse:0.66557
# [59]	validation_0-rmse:0.64294	validation_1-rmse:0.66061
# [60]	validation_0-rmse:0.63986	validation_1-rmse:0.65129
# [61]	validation_0-rmse:0.63709	validation_1-rmse:0.65109
# [62]	validation_0-rmse:0.63327	validation_1-rmse:0.64868
# [63]	validation_0-rmse:0.63120	validation_1-rmse:0.64501
# [64]	validation_0-rmse:0.62931	validation_1-rmse:0.64325
# [65]	validation_0-rmse:0.62780	validation_1-rmse:0.64159
# [66]	validation_0-rmse:0.62521	validation_1-rmse:0.64040
# [67]	validation_0-rmse:0.62236	validation_1-rmse:0.63471
# [68]	validation_0-rmse:0.61913	validation_1-rmse:0.62549
# [69]	validation_0-rmse:0.61694	validation_1-rmse:0.62209
# [70]	validation_0-rmse:0.61478	validation_1-rmse:0.62203
# [71]	validation_0-rmse:0.61383	validation_1-rmse:0.62230
# [72]	validation_0-rmse:0.61311	validation_1-rmse:0.62239
# [73]	validation_0-rmse:0.61126	validation_1-rmse:0.62046
# [74]	validation_0-rmse:0.60934	validation_1-rmse:0.61921
# [75]	validation_0-rmse:0.60842	validation_1-rmse:0.61701
# [76]	validation_0-rmse:0.60710	validation_1-rmse:0.61618
# [77]	validation_0-rmse:0.60600	validation_1-rmse:0.61523
# [78]	validation_0-rmse:0.60462	validation_1-rmse:0.61381
# [79]	validation_0-rmse:0.60369	validation_1-rmse:0.61573
# [80]	validation_0-rmse:0.60106	validation_1-rmse:0.61434
# [81]	validation_0-rmse:0.59858	validation_1-rmse:0.61201
# [82]	validation_0-rmse:0.59750	validation_1-rmse:0.60524
# [83]	validation_0-rmse:0.59678	validation_1-rmse:0.60189
# [84]	validation_0-rmse:0.59448	validation_1-rmse:0.59754
# [85]	validation_0-rmse:0.59352	validation_1-rmse:0.59509
# [86]	validation_0-rmse:0.59271	validation_1-rmse:0.59066
# [87]	validation_0-rmse:0.59145	validation_1-rmse:0.58802
# [88]	validation_0-rmse:0.58989	validation_1-rmse:0.58782
# [89]	validation_0-rmse:0.58967	validation_1-rmse:0.58843
# [90]	validation_0-rmse:0.58684	validation_1-rmse:0.59027
# [91]	validation_0-rmse:0.58483	validation_1-rmse:0.58769
# [92]	validation_0-rmse:0.58366	validation_1-rmse:0.58564
# [93]	validation_0-rmse:0.58281	validation_1-rmse:0.58717
# [94]	validation_0-rmse:0.58226	validation_1-rmse:0.58851
# [95]	validation_0-rmse:0.57934	validation_1-rmse:0.58506
# [96]	validation_0-rmse:0.57753	validation_1-rmse:0.58691
# [97]	validation_0-rmse:0.57689	validation_1-rmse:0.58852
# [98]	validation_0-rmse:0.57525	validation_1-rmse:0.58849
# [99]	validation_0-rmse:0.57469	validation_1-rmse:0.59057
# [100]	validation_0-rmse:0.57338	validation_1-rmse:0.59105
# [101]	validation_0-rmse:0.57178	validation_1-rmse:0.58964
# [102]	validation_0-rmse:0.57088	validation_1-rmse:0.59597
# [103]	validation_0-rmse:0.57096	validation_1-rmse:0.59494
# [104]	validation_0-rmse:0.56901	validation_1-rmse:0.58906
# [105]	validation_0-rmse:0.56829	validation_1-rmse:0.58465
# [106]	validation_0-rmse:0.56710	validation_1-rmse:0.58528
# [107]	validation_0-rmse:0.56715	validation_1-rmse:0.58526
# [108]	validation_0-rmse:0.56660	validation_1-rmse:0.58394
# [109]	validation_0-rmse:0.56471	validation_1-rmse:0.58278
# [110]	validation_0-rmse:0.56440	validation_1-rmse:0.58280
# [111]	validation_0-rmse:0.56233	validation_1-rmse:0.58350
# [112]	validation_0-rmse:0.56195	validation_1-rmse:0.57886
# [113]	validation_0-rmse:0.56110	validation_1-rmse:0.57737
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.96739	validation_1-rmse:1.87237
# [1]	validation_0-rmse:1.89378	validation_1-rmse:1.80143
# [2]	validation_0-rmse:1.82562	validation_1-rmse:1.73121
# [3]	validation_0-rmse:1.75609	validation_1-rmse:1.66488
# [4]	validation_0-rmse:1.69401	validation_1-rmse:1.60049
# [5]	validation_0-rmse:1.63271	validation_1-rmse:1.54501
# [6]	validation_0-rmse:1.57800	validation_1-rmse:1.48812
# [7]	validation_0-rmse:1.51731	validation_1-rmse:1.43191
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:1.46686	validation_1-rmse:1.38645
# [9]	validation_0-rmse:1.41437	validation_1-rmse:1.34168
# [10]	validation_0-rmse:1.37007	validation_1-rmse:1.29777
# [11]	validation_0-rmse:1.32666	validation_1-rmse:1.26006
# [12]	validation_0-rmse:1.28315	validation_1-rmse:1.22145
# [13]	validation_0-rmse:1.24726	validation_1-rmse:1.18882
# [14]	validation_0-rmse:1.20578	validation_1-rmse:1.15087
# [15]	validation_0-rmse:1.16852	validation_1-rmse:1.12052
# [16]	validation_0-rmse:1.12969	validation_1-rmse:1.09188
# [17]	validation_0-rmse:1.09886	validation_1-rmse:1.06714
# [18]	validation_0-rmse:1.06927	validation_1-rmse:1.04349
# [19]	validation_0-rmse:1.03769	validation_1-rmse:1.01762
# [20]	validation_0-rmse:1.00820	validation_1-rmse:0.99759
# [21]	validation_0-rmse:0.98234	validation_1-rmse:0.97628
# [22]	validation_0-rmse:0.95571	validation_1-rmse:0.95740
# [23]	validation_0-rmse:0.93198	validation_1-rmse:0.94132
# [24]	validation_0-rmse:0.90910	validation_1-rmse:0.92684
# [25]	validation_0-rmse:0.88775	validation_1-rmse:0.91464
# [26]	validation_0-rmse:0.87155	validation_1-rmse:0.90460
# [27]	validation_0-rmse:0.85112	validation_1-rmse:0.89598
# [28]	validation_0-rmse:0.83459	validation_1-rmse:0.88493
# [29]	validation_0-rmse:0.81557	validation_1-rmse:0.87581
# [30]	validation_0-rmse:0.79785	validation_1-rmse:0.86562
# [31]	validation_0-rmse:0.78454	validation_1-rmse:0.85894
# [32]	validation_0-rmse:0.76683	validation_1-rmse:0.85319
# [33]	validation_0-rmse:0.75382	validation_1-rmse:0.84544
# [34]	validation_0-rmse:0.74213	validation_1-rmse:0.84097
# [35]	validation_0-rmse:0.73169	validation_1-rmse:0.83323
# [36]	validation_0-rmse:0.72084	validation_1-rmse:0.82793
# [37]	validation_0-rmse:0.70819	validation_1-rmse:0.81984
# [38]	validation_0-rmse:0.69974	validation_1-rmse:0.81647
# [39]	validation_0-rmse:0.68939	validation_1-rmse:0.81315
# [40]	validation_0-rmse:0.68332	validation_1-rmse:0.81103
# [41]	validation_0-rmse:0.67394	validation_1-rmse:0.80041
# [42]	validation_0-rmse:0.66543	validation_1-rmse:0.79897
# [43]	validation_0-rmse:0.65872	validation_1-rmse:0.79609
# [44]	validation_0-rmse:0.65108	validation_1-rmse:0.79556
# [45]	validation_0-rmse:0.64244	validation_1-rmse:0.79227
# [46]	validation_0-rmse:0.63335	validation_1-rmse:0.78721
# [47]	validation_0-rmse:0.62512	validation_1-rmse:0.78677
# [48]	validation_0-rmse:0.62045	validation_1-rmse:0.78322
# [49]	validation_0-rmse:0.61229	validation_1-rmse:0.78026
# [50]	validation_0-rmse:0.60582	validation_1-rmse:0.77873
# [51]	validation_0-rmse:0.59916	validation_1-rmse:0.77937
# [52]	validation_0-rmse:0.59515	validation_1-rmse:0.78072
# [53]	validation_0-rmse:0.59120	validation_1-rmse:0.78041
# [54]	validation_0-rmse:0.58781	validation_1-rmse:0.78153
# [55]	validation_0-rmse:0.58391	validation_1-rmse:0.78205
# [56]	validation_0-rmse:0.57986	validation_1-rmse:0.78244
# [57]	validation_0-rmse:0.57687	validation_1-rmse:0.78240
# [58]	validation_0-rmse:0.57260	validation_1-rmse:0.78276
# [59]	validation_0-rmse:0.56870	validation_1-rmse:0.78563
# [60]	validation_0-rmse:0.56527	validation_1-rmse:0.78779
# [61]	validation_0-rmse:0.56324	validation_1-rmse:0.78953
# [62]	validation_0-rmse:0.56152	validation_1-rmse:0.78837
# [63]	validation_0-rmse:0.55929	validation_1-rmse:0.78954
# [64]	validation_0-rmse:0.55642	validation_1-rmse:0.79138
# [65]	validation_0-rmse:0.55345	validation_1-rmse:0.79465
# [66]	validation_0-rmse:0.55184	validation_1-rmse:0.79738
# [67]	validation_0-rmse:0.54970	validation_1-rmse:0.79701
# [68]	validation_0-rmse:0.54720	validation_1-rmse:0.79719
# [69]	validation_0-rmse:0.54555	validation_1-rmse:0.79973
# [70]	validation_0-rmse:0.54389	validation_1-rmse:0.80077
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.97726	validation_1-rmse:1.85461
# [1]	validation_0-rmse:1.90401	validation_1-rmse:1.78366
# [2]	validation_0-rmse:1.83703	validation_1-rmse:1.71578
# [3]	validation_0-rmse:1.76850	validation_1-rmse:1.65017
# [4]	validation_0-rmse:1.71176	validation_1-rmse:1.59255
# [5]	validation_0-rmse:1.64785	validation_1-rmse:1.53114
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:1.58970	validation_1-rmse:1.47434
# [7]	validation_0-rmse:1.53150	validation_1-rmse:1.41926
# [8]	validation_0-rmse:1.47646	validation_1-rmse:1.36739
# [9]	validation_0-rmse:1.42710	validation_1-rmse:1.32436
# [10]	validation_0-rmse:1.38225	validation_1-rmse:1.28348
# [11]	validation_0-rmse:1.33137	validation_1-rmse:1.23507
# [12]	validation_0-rmse:1.28943	validation_1-rmse:1.19577
# [13]	validation_0-rmse:1.25243	validation_1-rmse:1.16164
# [14]	validation_0-rmse:1.21587	validation_1-rmse:1.12485
# [15]	validation_0-rmse:1.17882	validation_1-rmse:1.08955
# [16]	validation_0-rmse:1.13940	validation_1-rmse:1.05299
# [17]	validation_0-rmse:1.10784	validation_1-rmse:1.02338
# [18]	validation_0-rmse:1.08296	validation_1-rmse:0.99729
# [19]	validation_0-rmse:1.05366	validation_1-rmse:0.97041
# [20]	validation_0-rmse:1.02519	validation_1-rmse:0.94208
# [21]	validation_0-rmse:0.99965	validation_1-rmse:0.91862
# [22]	validation_0-rmse:0.97377	validation_1-rmse:0.89521
# [23]	validation_0-rmse:0.95301	validation_1-rmse:0.87528
# [24]	validation_0-rmse:0.93321	validation_1-rmse:0.85935
# [25]	validation_0-rmse:0.91302	validation_1-rmse:0.84437
# [26]	validation_0-rmse:0.89052	validation_1-rmse:0.82486
# [27]	validation_0-rmse:0.87296	validation_1-rmse:0.81294
# [28]	validation_0-rmse:0.85874	validation_1-rmse:0.80091
# [29]	validation_0-rmse:0.84012	validation_1-rmse:0.78424
# [30]	validation_0-rmse:0.82453	validation_1-rmse:0.77139
# [31]	validation_0-rmse:0.81289	validation_1-rmse:0.76479
# [32]	validation_0-rmse:0.79811	validation_1-rmse:0.75280
# [33]	validation_0-rmse:0.78605	validation_1-rmse:0.74365
# [34]	validation_0-rmse:0.77562	validation_1-rmse:0.73542
# [35]	validation_0-rmse:0.76801	validation_1-rmse:0.73163
# [36]	validation_0-rmse:0.75823	validation_1-rmse:0.73103
# [37]	validation_0-rmse:0.74570	validation_1-rmse:0.72050
# [38]	validation_0-rmse:0.73906	validation_1-rmse:0.71911
# [39]	validation_0-rmse:0.73068	validation_1-rmse:0.71287
# [40]	validation_0-rmse:0.72372	validation_1-rmse:0.71046
# [41]	validation_0-rmse:0.71526	validation_1-rmse:0.70922
# [42]	validation_0-rmse:0.70520	validation_1-rmse:0.70203
# [43]	validation_0-rmse:0.69824	validation_1-rmse:0.69573
# [44]	validation_0-rmse:0.68997	validation_1-rmse:0.69089
# [45]	validation_0-rmse:0.68575	validation_1-rmse:0.68807
# [46]	validation_0-rmse:0.67824	validation_1-rmse:0.68238
# [47]	validation_0-rmse:0.67100	validation_1-rmse:0.67808
# [48]	validation_0-rmse:0.66594	validation_1-rmse:0.67520
# [49]	validation_0-rmse:0.66048	validation_1-rmse:0.67213
# [50]	validation_0-rmse:0.65478	validation_1-rmse:0.66708
# [51]	validation_0-rmse:0.65180	validation_1-rmse:0.66809
# [52]	validation_0-rmse:0.64793	validation_1-rmse:0.66357
# [53]	validation_0-rmse:0.64249	validation_1-rmse:0.66123
# [54]	validation_0-rmse:0.63667	validation_1-rmse:0.66070
# [55]	validation_0-rmse:0.63356	validation_1-rmse:0.66114
# [56]	validation_0-rmse:0.62998	validation_1-rmse:0.65925
# [57]	validation_0-rmse:0.62651	validation_1-rmse:0.65780
# [58]	validation_0-rmse:0.62358	validation_1-rmse:0.65743
# [59]	validation_0-rmse:0.61955	validation_1-rmse:0.65543
# [60]	validation_0-rmse:0.61566	validation_1-rmse:0.65723
# [61]	validation_0-rmse:0.61252	validation_1-rmse:0.65539
# [62]	validation_0-rmse:0.60950	validation_1-rmse:0.65431
# [63]	validation_0-rmse:0.60624	validation_1-rmse:0.65273
# [64]	validation_0-rmse:0.60360	validation_1-rmse:0.65197
# [65]	validation_0-rmse:0.59982	validation_1-rmse:0.64763
# [66]	validation_0-rmse:0.59730	validation_1-rmse:0.64861
# [67]	validation_0-rmse:0.59476	validation_1-rmse:0.64627
# [68]	validation_0-rmse:0.59231	validation_1-rmse:0.64545
# [69]	validation_0-rmse:0.59069	validation_1-rmse:0.64405
# [70]	validation_0-rmse:0.58943	validation_1-rmse:0.64680
# [71]	validation_0-rmse:0.58719	validation_1-rmse:0.64739
# [72]	validation_0-rmse:0.58645	validation_1-rmse:0.64692
# [73]	validation_0-rmse:0.58414	validation_1-rmse:0.64653
# [74]	validation_0-rmse:0.58171	validation_1-rmse:0.64611
# [75]	validation_0-rmse:0.58035	validation_1-rmse:0.64814
# [76]	validation_0-rmse:0.57987	validation_1-rmse:0.64822
# [77]	validation_0-rmse:0.57693	validation_1-rmse:0.65228
# [78]	validation_0-rmse:0.57575	validation_1-rmse:0.65242
# [79]	validation_0-rmse:0.57538	validation_1-rmse:0.65182
# [80]	validation_0-rmse:0.57362	validation_1-rmse:0.65224
# [81]	validation_0-rmse:0.57178	validation_1-rmse:0.65393
# [82]	validation_0-rmse:0.57065	validation_1-rmse:0.65365
# [83]	validation_0-rmse:0.57007	validation_1-rmse:0.65431
# [84]	validation_0-rmse:0.56861	validation_1-rmse:0.65441
# [85]	validation_0-rmse:0.56638	validation_1-rmse:0.65477
# [86]	validation_0-rmse:0.56530	validation_1-rmse:0.65440
# [87]	validation_0-rmse:0.56387	validation_1-rmse:0.65335
# ...
# [54]	validation_0-rmse:0.63125	validation_1-rmse:0.66953
# [55]	validation_0-rmse:0.62778	validation_1-rmse:0.66612
# [56]	validation_0-rmse:0.62662	validation_1-rmse:0.66584
# [57]	validation_0-rmse:0.62353	validation_1-rmse:0.66275
# [58]	validation_0-rmse:0.62110	validation_1-rmse:0.66129
# [59]	validation_0-rmse:0.61601	validation_1-rmse:0.65888
# [60]	validation_0-rmse:0.61294	validation_1-rmse:0.65756
# [61]	validation_0-rmse:0.60988	validation_1-rmse:0.65542
# [62]	validation_0-rmse:0.60736	validation_1-rmse:0.65405
# [63]	validation_0-rmse:0.60340	validation_1-rmse:0.65124
# [64]	validation_0-rmse:0.60039	validation_1-rmse:0.65229
# [65]	validation_0-rmse:0.59922	validation_1-rmse:0.65213
# [66]	validation_0-rmse:0.59578	validation_1-rmse:0.64921
# [67]	validation_0-rmse:0.59269	validation_1-rmse:0.64667
# [68]	validation_0-rmse:0.59001	validation_1-rmse:0.64438
# [69]	validation_0-rmse:0.58750	validation_1-rmse:0.64404
# [70]	validation_0-rmse:0.58394	validation_1-rmse:0.64572
# [71]	validation_0-rmse:0.58021	validation_1-rmse:0.64577
# [72]	validation_0-rmse:0.57886	validation_1-rmse:0.64563
# [73]	validation_0-rmse:0.57730	validation_1-rmse:0.64491
# [74]	validation_0-rmse:0.57575	validation_1-rmse:0.64461
# [75]	validation_0-rmse:0.57548	validation_1-rmse:0.64357
# [76]	validation_0-rmse:0.57471	validation_1-rmse:0.64109
# [77]	validation_0-rmse:0.57371	validation_1-rmse:0.64117
# [78]	validation_0-rmse:0.57220	validation_1-rmse:0.63963
# [79]	validation_0-rmse:0.57113	validation_1-rmse:0.64077
# [80]	validation_0-rmse:0.56949	validation_1-rmse:0.64059
# [81]	validation_0-rmse:0.56897	validation_1-rmse:0.64030
# [82]	validation_0-rmse:0.56769	validation_1-rmse:0.64030
# [83]	validation_0-rmse:0.56464	validation_1-rmse:0.63996
# [84]	validation_0-rmse:0.56186	validation_1-rmse:0.64092
# [85]	validation_0-rmse:0.56125	validation_1-rmse:0.64020
# [86]	validation_0-rmse:0.56087	validation_1-rmse:0.63983
# [87]	validation_0-rmse:0.55886	validation_1-rmse:0.64124
# [88]	validation_0-rmse:0.55667	validation_1-rmse:0.64162
# [89]	validation_0-rmse:0.55568	validation_1-rmse:0.64303
# [90]	validation_0-rmse:0.55542	validation_1-rmse:0.64271
# [91]	validation_0-rmse:0.55415	validation_1-rmse:0.64059
# [92]	validation_0-rmse:0.55257	validation_1-rmse:0.64285
# [93]	validation_0-rmse:0.55242	validation_1-rmse:0.64280
# [94]	validation_0-rmse:0.55138	validation_1-rmse:0.64147
# [95]	validation_0-rmse:0.55056	validation_1-rmse:0.64117
# [96]	validation_0-rmse:0.54969	validation_1-rmse:0.64232
# [97]	validation_0-rmse:0.54764	validation_1-rmse:0.64452
# [98]	validation_0-rmse:0.54721	validation_1-rmse:0.64469
# [0]	validation_0-rmse:1.93109	validation_1-rmse:2.04230
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.85829	validation_1-rmse:1.96836
# [2]	validation_0-rmse:1.79632	validation_1-rmse:1.90253
# [3]	validation_0-rmse:1.72912	validation_1-rmse:1.82788
# [4]	validation_0-rmse:1.66811	validation_1-rmse:1.76843
# [5]	validation_0-rmse:1.60827	validation_1-rmse:1.70168
# [6]	validation_0-rmse:1.55709	validation_1-rmse:1.64988
# [7]	validation_0-rmse:1.49904	validation_1-rmse:1.58855
# [8]	validation_0-rmse:1.44726	validation_1-rmse:1.53254
# [9]	validation_0-rmse:1.39796	validation_1-rmse:1.47694
# [10]	validation_0-rmse:1.35568	validation_1-rmse:1.43182
# [11]	validation_0-rmse:1.31223	validation_1-rmse:1.38401
# [12]	validation_0-rmse:1.27153	validation_1-rmse:1.33728
# [13]	validation_0-rmse:1.23511	validation_1-rmse:1.29970
# [14]	validation_0-rmse:1.19947	validation_1-rmse:1.26165
# [15]	validation_0-rmse:1.16598	validation_1-rmse:1.22095
# [16]	validation_0-rmse:1.13042	validation_1-rmse:1.17752
# [17]	validation_0-rmse:1.10256	validation_1-rmse:1.14415
# [18]	validation_0-rmse:1.07693	validation_1-rmse:1.11730
# [19]	validation_0-rmse:1.04950	validation_1-rmse:1.08557
# [20]	validation_0-rmse:1.02710	validation_1-rmse:1.06155
# [21]	validation_0-rmse:1.00555	validation_1-rmse:1.03657
# [22]	validation_0-rmse:0.98326	validation_1-rmse:1.00664
# [23]	validation_0-rmse:0.95992	validation_1-rmse:0.98211
# [24]	validation_0-rmse:0.94157	validation_1-rmse:0.96393
# [25]	validation_0-rmse:0.91980	validation_1-rmse:0.94228
# [26]	validation_0-rmse:0.90317	validation_1-rmse:0.92351
# [27]	validation_0-rmse:0.88612	validation_1-rmse:0.89921
# [28]	validation_0-rmse:0.86859	validation_1-rmse:0.87817
# [29]	validation_0-rmse:0.84917	validation_1-rmse:0.85691
# [30]	validation_0-rmse:0.83527	validation_1-rmse:0.83852
# [31]	validation_0-rmse:0.82057	validation_1-rmse:0.82149
# [32]	validation_0-rmse:0.80691	validation_1-rmse:0.80281
# [33]	validation_0-rmse:0.79398	validation_1-rmse:0.78240
# [34]	validation_0-rmse:0.78694	validation_1-rmse:0.77627
# [35]	validation_0-rmse:0.77931	validation_1-rmse:0.76618
# [36]	validation_0-rmse:0.77152	validation_1-rmse:0.75681
# [37]	validation_0-rmse:0.76041	validation_1-rmse:0.74526
# [38]	validation_0-rmse:0.75319	validation_1-rmse:0.73653
# [39]	validation_0-rmse:0.74701	validation_1-rmse:0.72547
# [40]	validation_0-rmse:0.73786	validation_1-rmse:0.71730
# [41]	validation_0-rmse:0.73050	validation_1-rmse:0.70836
# [42]	validation_0-rmse:0.72518	validation_1-rmse:0.70647
# [43]	validation_0-rmse:0.71817	validation_1-rmse:0.69834
# [44]	validation_0-rmse:0.71155	validation_1-rmse:0.68833
# [45]	validation_0-rmse:0.70431	validation_1-rmse:0.68090
# [46]	validation_0-rmse:0.69799	validation_1-rmse:0.67377
# [47]	validation_0-rmse:0.69239	validation_1-rmse:0.66677
# [48]	validation_0-rmse:0.68901	validation_1-rmse:0.66524
# [49]	validation_0-rmse:0.68206	validation_1-rmse:0.66332
# [50]	validation_0-rmse:0.67614	validation_1-rmse:0.65775
# [51]	validation_0-rmse:0.67323	validation_1-rmse:0.65093
# [52]	validation_0-rmse:0.67089	validation_1-rmse:0.64855
# [53]	validation_0-rmse:0.66516	validation_1-rmse:0.64348
# [54]	validation_0-rmse:0.66359	validation_1-rmse:0.64210
# [55]	validation_0-rmse:0.66064	validation_1-rmse:0.63883
# [56]	validation_0-rmse:0.65647	validation_1-rmse:0.63252
# [57]	validation_0-rmse:0.65429	validation_1-rmse:0.62942
# [58]	validation_0-rmse:0.65149	validation_1-rmse:0.62610
# [59]	validation_0-rmse:0.64729	validation_1-rmse:0.62466
# [60]	validation_0-rmse:0.64450	validation_1-rmse:0.62073
# [61]	validation_0-rmse:0.64094	validation_1-rmse:0.61943
# [62]	validation_0-rmse:0.63862	validation_1-rmse:0.61603
# [63]	validation_0-rmse:0.63649	validation_1-rmse:0.61238
# [64]	validation_0-rmse:0.63415	validation_1-rmse:0.60928
# [65]	validation_0-rmse:0.63011	validation_1-rmse:0.60834
# [66]	validation_0-rmse:0.62821	validation_1-rmse:0.60682
# [67]	validation_0-rmse:0.62445	validation_1-rmse:0.60634
# [68]	validation_0-rmse:0.62114	validation_1-rmse:0.60971
# [69]	validation_0-rmse:0.61861	validation_1-rmse:0.60709
# [70]	validation_0-rmse:0.61774	validation_1-rmse:0.60717
# [71]	validation_0-rmse:0.61527	validation_1-rmse:0.60774
# [72]	validation_0-rmse:0.61342	validation_1-rmse:0.60623
# [73]	validation_0-rmse:0.61055	validation_1-rmse:0.60404
# [74]	validation_0-rmse:0.60741	validation_1-rmse:0.60392
# [75]	validation_0-rmse:0.60658	validation_1-rmse:0.60255
# [76]	validation_0-rmse:0.60460	validation_1-rmse:0.60054
# [77]	validation_0-rmse:0.60378	validation_1-rmse:0.59773
# [78]	validation_0-rmse:0.60144	validation_1-rmse:0.59745
# [79]	validation_0-rmse:0.59986	validation_1-rmse:0.59574
# [80]	validation_0-rmse:0.59761	validation_1-rmse:0.59444
# [81]	validation_0-rmse:0.59595	validation_1-rmse:0.59627
# [82]	validation_0-rmse:0.59431	validation_1-rmse:0.59594
# [83]	validation_0-rmse:0.59247	validation_1-rmse:0.59630
# [84]	validation_0-rmse:0.59070	validation_1-rmse:0.59560
# [85]	validation_0-rmse:0.58939	validation_1-rmse:0.59844
# [86]	validation_0-rmse:0.58767	validation_1-rmse:0.59821
# [87]	validation_0-rmse:0.58672	validation_1-rmse:0.59926
# [88]	validation_0-rmse:0.58456	validation_1-rmse:0.59757
# [89]	validation_0-rmse:0.58404	validation_1-rmse:0.59599
# [90]	validation_0-rmse:0.58276	validation_1-rmse:0.59511
# [91]	validation_0-rmse:0.58002	validation_1-rmse:0.59766
# [92]	validation_0-rmse:0.57914	validation_1-rmse:0.59785
# [93]	validation_0-rmse:0.57864	validation_1-rmse:0.59919
# [94]	validation_0-rmse:0.57762	validation_1-rmse:0.59916
# [95]	validation_0-rmse:0.57663	validation_1-rmse:0.59975
# [96]	validation_0-rmse:0.57602	validation_1-rmse:0.59953
# [97]	validation_0-rmse:0.57543	validation_1-rmse:0.59887
# [98]	validation_0-rmse:0.57498	validation_1-rmse:0.59804
# [99]	validation_0-rmse:0.57470	validation_1-rmse:0.59722
# [100]	validation_0-rmse:0.57398	validation_1-rmse:0.59988
# [0]	validation_0-rmse:1.93406	validation_1-rmse:2.03730
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.86370	validation_1-rmse:1.96966
# [2]	validation_0-rmse:1.80155	validation_1-rmse:1.91352
# [3]	validation_0-rmse:1.73336	validation_1-rmse:1.84491
# [4]	validation_0-rmse:1.66511	validation_1-rmse:1.77912
# [5]	validation_0-rmse:1.59611	validation_1-rmse:1.71405
# [6]	validation_0-rmse:1.53823	validation_1-rmse:1.65908
# [7]	validation_0-rmse:1.48373	validation_1-rmse:1.60707
# [8]	validation_0-rmse:1.42712	validation_1-rmse:1.55342
# [9]	validation_0-rmse:1.37983	validation_1-rmse:1.51131
# [10]	validation_0-rmse:1.33145	validation_1-rmse:1.46756
# [11]	validation_0-rmse:1.28747	validation_1-rmse:1.42926
# [12]	validation_0-rmse:1.24583	validation_1-rmse:1.38992
# [13]	validation_0-rmse:1.20778	validation_1-rmse:1.35573
# [14]	validation_0-rmse:1.17165	validation_1-rmse:1.32561
# [15]	validation_0-rmse:1.13823	validation_1-rmse:1.29235
# [16]	validation_0-rmse:1.10212	validation_1-rmse:1.26701
# [17]	validation_0-rmse:1.07090	validation_1-rmse:1.24046
# [18]	validation_0-rmse:1.03767	validation_1-rmse:1.21274
# [19]	validation_0-rmse:1.00930	validation_1-rmse:1.18755
# [20]	validation_0-rmse:0.98325	validation_1-rmse:1.16514
# [21]	validation_0-rmse:0.95655	validation_1-rmse:1.14233
# [22]	validation_0-rmse:0.92976	validation_1-rmse:1.12062
# [23]	validation_0-rmse:0.90460	validation_1-rmse:1.10006
# [24]	validation_0-rmse:0.88271	validation_1-rmse:1.07875
# [25]	validation_0-rmse:0.86161	validation_1-rmse:1.06082
# [26]	validation_0-rmse:0.84466	validation_1-rmse:1.04578
# [27]	validation_0-rmse:0.82557	validation_1-rmse:1.02791
# [28]	validation_0-rmse:0.80811	validation_1-rmse:1.01760
# [29]	validation_0-rmse:0.79236	validation_1-rmse:1.00718
# [30]	validation_0-rmse:0.77634	validation_1-rmse:0.99446
# [31]	validation_0-rmse:0.75997	validation_1-rmse:0.98316
# [32]	validation_0-rmse:0.74606	validation_1-rmse:0.96950
# [33]	validation_0-rmse:0.73381	validation_1-rmse:0.96179
# [34]	validation_0-rmse:0.72522	validation_1-rmse:0.95573
# [35]	validation_0-rmse:0.71664	validation_1-rmse:0.95462
# [36]	validation_0-rmse:0.70728	validation_1-rmse:0.95257
# [37]	validation_0-rmse:0.69575	validation_1-rmse:0.94513
# [38]	validation_0-rmse:0.68441	validation_1-rmse:0.93714
# [39]	validation_0-rmse:0.67636	validation_1-rmse:0.93175
# [40]	validation_0-rmse:0.66843	validation_1-rmse:0.92813
# [41]	validation_0-rmse:0.65951	validation_1-rmse:0.92146
# [42]	validation_0-rmse:0.65090	validation_1-rmse:0.91244
# [43]	validation_0-rmse:0.64353	validation_1-rmse:0.91168
# [44]	validation_0-rmse:0.63899	validation_1-rmse:0.90936
# [45]	validation_0-rmse:0.62923	validation_1-rmse:0.90423
# [46]	validation_0-rmse:0.62224	validation_1-rmse:0.90041
# [47]	validation_0-rmse:0.61605	validation_1-rmse:0.89783
# [48]	validation_0-rmse:0.61007	validation_1-rmse:0.89428
# [49]	validation_0-rmse:0.60518	validation_1-rmse:0.88913
# [50]	validation_0-rmse:0.59956	validation_1-rmse:0.88534
# [51]	validation_0-rmse:0.59545	validation_1-rmse:0.88144
# [52]	validation_0-rmse:0.59094	validation_1-rmse:0.87652
# [53]	validation_0-rmse:0.58524	validation_1-rmse:0.87441
# [54]	validation_0-rmse:0.58263	validation_1-rmse:0.87221
# [55]	validation_0-rmse:0.57966	validation_1-rmse:0.87137
# [56]	validation_0-rmse:0.57701	validation_1-rmse:0.87024
# [57]	validation_0-rmse:0.57481	validation_1-rmse:0.86772
# [58]	validation_0-rmse:0.57227	validation_1-rmse:0.86768
# [59]	validation_0-rmse:0.56847	validation_1-rmse:0.86531
# [60]	validation_0-rmse:0.56642	validation_1-rmse:0.86204
# [61]	validation_0-rmse:0.56347	validation_1-rmse:0.86065
# [62]	validation_0-rmse:0.56119	validation_1-rmse:0.86113
# [63]	validation_0-rmse:0.55883	validation_1-rmse:0.86030
# [64]	validation_0-rmse:0.55715	validation_1-rmse:0.85822
# [65]	validation_0-rmse:0.55422	validation_1-rmse:0.85592
# [66]	validation_0-rmse:0.55255	validation_1-rmse:0.85759
# [67]	validation_0-rmse:0.55080	validation_1-rmse:0.85678
# [68]	validation_0-rmse:0.54769	validation_1-rmse:0.85622
# [69]	validation_0-rmse:0.54495	validation_1-rmse:0.85546
# [70]	validation_0-rmse:0.54314	validation_1-rmse:0.85589
# [71]	validation_0-rmse:0.54104	validation_1-rmse:0.85507
# [72]	validation_0-rmse:0.53895	validation_1-rmse:0.85754
# [73]	validation_0-rmse:0.53745	validation_1-rmse:0.85775
# [74]	validation_0-rmse:0.53589	validation_1-rmse:0.85718
# [75]	validation_0-rmse:0.53418	validation_1-rmse:0.86153
# [76]	validation_0-rmse:0.53253	validation_1-rmse:0.85967
# [77]	validation_0-rmse:0.53134	validation_1-rmse:0.85831
# [78]	validation_0-rmse:0.52939	validation_1-rmse:0.85870
# [79]	validation_0-rmse:0.52883	validation_1-rmse:0.85833
# [80]	validation_0-rmse:0.52749	validation_1-rmse:0.85784
# [81]	validation_0-rmse:0.52663	validation_1-rmse:0.85819
# [82]	validation_0-rmse:0.52561	validation_1-rmse:0.85724
# [83]	validation_0-rmse:0.52271	validation_1-rmse:0.85786
# [84]	validation_0-rmse:0.52070	validation_1-rmse:0.85667
# [85]	validation_0-rmse:0.51989	validation_1-rmse:0.85601
# [86]	validation_0-rmse:0.51890	validation_1-rmse:0.85561
# [87]	validation_0-rmse:0.51743	validation_1-rmse:0.85500
# [88]	validation_0-rmse:0.51733	validation_1-rmse:0.85386
# [89]	validation_0-rmse:0.51718	validation_1-rmse:0.85717
# [90]	validation_0-rmse:0.51655	validation_1-rmse:0.85464
# [91]	validation_0-rmse:0.51573	validation_1-rmse:0.85485
# [92]	validation_0-rmse:0.51505	validation_1-rmse:0.85477
# [93]	validation_0-rmse:0.51442	validation_1-rmse:0.85429
# [94]	validation_0-rmse:0.51439	validation_1-rmse:0.85341
# [95]	validation_0-rmse:0.51259	validation_1-rmse:0.85312
# [96]	validation_0-rmse:0.51199	validation_1-rmse:0.85216
# [97]	validation_0-rmse:0.50978	validation_1-rmse:0.85154
# [98]	validation_0-rmse:0.50896	validation_1-rmse:0.85127
# [99]	validation_0-rmse:0.50805	validation_1-rmse:0.85033
# [100]	validation_0-rmse:0.50723	validation_1-rmse:0.85014
# [101]	validation_0-rmse:0.50685	validation_1-rmse:0.84999
# [102]	validation_0-rmse:0.50653	validation_1-rmse:0.84967
# [103]	validation_0-rmse:0.50603	validation_1-rmse:0.85088
# [104]	validation_0-rmse:0.50505	validation_1-rmse:0.85182
# [105]	validation_0-rmse:0.50476	validation_1-rmse:0.85148
# [106]	validation_0-rmse:0.50471	validation_1-rmse:0.85052
# [107]	validation_0-rmse:0.50516	validation_1-rmse:0.85326
# [108]	validation_0-rmse:0.50485	validation_1-rmse:0.85314
# [109]	validation_0-rmse:0.50435	validation_1-rmse:0.85273
# [110]	validation_0-rmse:0.50357	validation_1-rmse:0.85163
# [111]	validation_0-rmse:0.50179	validation_1-rmse:0.85058
# [112]	validation_0-rmse:0.50117	validation_1-rmse:0.85026
# [113]	validation_0-rmse:0.50084	validation_1-rmse:0.84978
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-0.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.477
# Uncertainty
# a0: 1.276+/-0.076
# a1: 0.430+/-0.032

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: r2020B01: mean - 0.131, median - 0.131, CI - [0.116-0.147]
#
# SHAP-values for: r2020B03: mean - 0.078, median - 0.078, CI - [0.066-0.09]
#
# SHAP-values for: r2020B05: mean - 0.088, median - 0.087, CI - [0.078-0.098]
#
# SHAP-values for: r2020B06: mean - 0.081, median - 0.082, CI - [0.07-0.094]
#
# SHAP-values for: r2020B07: mean - 0.049, median - 0.049, CI - [0.042-0.058]
#
# SHAP-values for: r2020B10: mean - 0.064, median - 0.064, CI - [0.052-0.075]
#
# SHAP-values for: r2020B11: mean - 0.102, median - 0.103, CI - [0.09-0.114]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['r2020B01', 'r2020B11', 'r2020B05', 'r2020B06', 'r2020B03', 'r2020B10', 'r2020B07'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 91.55, median: 95.0,
#  pred. interval (P(0.025)-P(0.975)): 50.0-113.0,
#  conf. interval (p-value=0.95): 76.122-109.383
# ***
# Aggregate bias statistic:
#  mean: -0.035, median: -0.042,
#  pred. interval (P(0.025)-P(0.975)): -0.236-0.16,
#  conf. interval (p-value=0.95): -0.124-0.055
# ***
# Aggregate RMSE statistic:
#  mean: 0.677, median: 0.673, pred. interval (P(0.025)-P(0.975)): 0.503-0.87,
#  conf. interval (p-value=0.95): 0.587-0.76
# ***
# Aggregate MSE statistic:
#  mean: 0.468, median: 0.453, pred. interval (P(0.025)-P(0.975)): 0.253-0.757,
#  conf. interval (p-value=0.95): 0.345-0.579
# ***
# Aggregate R^2 statistic:
#  mean: 0.441, median: 0.472, pred. interval (P(0.025)-P(0.975)): 0.052-0.662,
#  conf. interval (p-value=0.95): 0.321-0.579
# ***
# Aggregate bias(%) statistic:
#  mean: -1.326, median: -1.846, pred. interval (P(0.025)-P(0.975)): -9.269-7.579,
#  conf. interval (p-value=0.95): -5.004-2.538
# ***
# Aggregate RMSE(%) statistic:
#  mean: 29.714, median: 29.155, pred. interval (P(0.025)-P(0.975)): 20.028-42.21,
#  conf. interval (p-value=0.95): 24.74-34.617
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -2.437, median: -2.42,
#  pred. interval (P(0.025)-P(0.975)): -4.273--0.822,
#  conf. interval (p-value=0.95): -3.252--1.652
# ***
# Aggregate RMSE statistic:
#  mean: 6.576, median: 6.595, pred. interval (P(0.025)-P(0.975)): 5.18-7.806,
#  conf. interval (p-value=0.95): 6.018-7.169
# ***
# Aggregate MSE statistic:
#  mean: 43.707, median: 43.491, pred. interval (P(0.025)-P(0.975)): 26.834-60.939,
#  conf. interval (p-value=0.95): 36.254-51.425
# ***
# Aggregate R^2 statistic:
#  mean: 0.234, median: 0.261, pred. interval (P(0.025)-P(0.975)): -0.104-0.452,
#  conf. interval (p-value=0.95): 0.118-0.363
# ***
# Aggregate bias(%) statistic:
#  mean: -18.04, median: -18.432, pred. interval (P(0.025)-P(0.975)): -28.055--6.82,
#  conf. interval (p-value=0.95): -23.5--13.005
# ***
# Aggregate RMSE(%) statistic:
#  mean: 49.526, median: 49.794, pred. interval (P(0.025)-P(0.975)): 40.423-60.013,
#  conf. interval (p-value=0.95): 45.239-53.33
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-1, 0, 1, 2, 3, 4])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 5, 10, 15, 20, 25, 30])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.95120
# [1]	validation_0-rmse:1.87338
# [2]	validation_0-rmse:1.79942
# [3]	validation_0-rmse:1.73382
# [4]	validation_0-rmse:1.66680
# [5]	validation_0-rmse:1.60569
# [6]	validation_0-rmse:1.55240
# [7]	validation_0-rmse:1.49800
# [8]	validation_0-rmse:1.44744
# [9]	validation_0-rmse:1.39978
# [10]	validation_0-rmse:1.35078
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:1.30499
# [12]	validation_0-rmse:1.26056
# [13]	validation_0-rmse:1.22193
# [14]	validation_0-rmse:1.18385
# [15]	validation_0-rmse:1.14732
# [16]	validation_0-rmse:1.11203
# [17]	validation_0-rmse:1.07678
# [18]	validation_0-rmse:1.04812
# [19]	validation_0-rmse:1.02036
# [20]	validation_0-rmse:0.99510
# [21]	validation_0-rmse:0.97298
# [22]	validation_0-rmse:0.94668
# [23]	validation_0-rmse:0.92395
# [24]	validation_0-rmse:0.90393
# [25]	validation_0-rmse:0.88625
# [26]	validation_0-rmse:0.86718
# [27]	validation_0-rmse:0.84975
# [28]	validation_0-rmse:0.83128
# [29]	validation_0-rmse:0.81745
# [30]	validation_0-rmse:0.80280
# [31]	validation_0-rmse:0.78778
# [32]	validation_0-rmse:0.77264
# [33]	validation_0-rmse:0.76303
# [34]	validation_0-rmse:0.75055
# [35]	validation_0-rmse:0.73936
# [36]	validation_0-rmse:0.73033
# [37]	validation_0-rmse:0.71743
# [38]	validation_0-rmse:0.70970
# [39]	validation_0-rmse:0.70037
# [40]	validation_0-rmse:0.69285
# [41]	validation_0-rmse:0.68784
# [42]	validation_0-rmse:0.68152
# [43]	validation_0-rmse:0.67580
# [44]	validation_0-rmse:0.66948
# [45]	validation_0-rmse:0.66344
# [46]	validation_0-rmse:0.65795
# [47]	validation_0-rmse:0.65338
# [48]	validation_0-rmse:0.64820
# [49]	validation_0-rmse:0.64405
# [50]	validation_0-rmse:0.63996
# [51]	validation_0-rmse:0.63596
# [52]	validation_0-rmse:0.63267
# [53]	validation_0-rmse:0.62965
# [54]	validation_0-rmse:0.62729
# [55]	validation_0-rmse:0.62595
# [56]	validation_0-rmse:0.62410
# [57]	validation_0-rmse:0.62067
# [58]	validation_0-rmse:0.61945
# [59]	validation_0-rmse:0.61590
# [60]	validation_0-rmse:0.61270
# [61]	validation_0-rmse:0.60981
# [62]	validation_0-rmse:0.60791
# [63]	validation_0-rmse:0.60635
# [64]	validation_0-rmse:0.60452
# [65]	validation_0-rmse:0.60260
# [66]	validation_0-rmse:0.60192
# [67]	validation_0-rmse:0.60015
# [68]	validation_0-rmse:0.59816
# [69]	validation_0-rmse:0.59696
# [70]	validation_0-rmse:0.59557
# [71]	validation_0-rmse:0.59495
# [72]	validation_0-rmse:0.59338
# [73]	validation_0-rmse:0.59183
# [74]	validation_0-rmse:0.59149
# [75]	validation_0-rmse:0.58927
# [76]	validation_0-rmse:0.58681
# [77]	validation_0-rmse:0.58537
# [78]	validation_0-rmse:0.58405
# [79]	validation_0-rmse:0.58234
# [80]	validation_0-rmse:0.58110
# [81]	validation_0-rmse:0.58083
# [82]	validation_0-rmse:0.58011
# [83]	validation_0-rmse:0.57929
# [84]	validation_0-rmse:0.57851
# [85]	validation_0-rmse:0.57756
# [86]	validation_0-rmse:0.57652
# [87]	validation_0-rmse:0.57414
# [88]	validation_0-rmse:0.57338
# [89]	validation_0-rmse:0.57307
# [90]	validation_0-rmse:0.57259
# [91]	validation_0-rmse:0.57122
# [92]	validation_0-rmse:0.57030
# [93]	validation_0-rmse:0.56988
# [94]	validation_0-rmse:0.56858
# [95]	validation_0-rmse:0.56715
# [96]	validation_0-rmse:0.56624
# [97]	validation_0-rmse:0.56609
# [98]	validation_0-rmse:0.56484
# [99]	validation_0-rmse:0.56373
# [100]	validation_0-rmse:0.56288
# [101]	validation_0-rmse:0.56214
# [102]	validation_0-rmse:0.56105
# [103]	validation_0-rmse:0.55953
# [104]	validation_0-rmse:0.55863
# [105]	validation_0-rmse:0.55741
# [106]	validation_0-rmse:0.55715
# [107]	validation_0-rmse:0.55641
# [108]	validation_0-rmse:0.55549
# [109]	validation_0-rmse:0.55475
# [110]	validation_0-rmse:0.55351
# [111]	validation_0-rmse:0.55261
# [112]	validation_0-rmse:0.55183
# [113]	validation_0-rmse:0.55098
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 113

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.37
# RMSE: 0.6
# Relative RMSE(%):  23.909
# MSE: 0.3
# R square: 64.6%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-0.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.657
# Uncertainty
# a0: 0.97+/-0.07
# a1: 0.573+/-0.030

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../05_output_data/XGBoost_models/08_LN_M_AG_SENTINEL_2020_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../05_output_data/XGBoost_models/08_LN_M_AG_SENTINEL_2020_XGB_model.txt")
