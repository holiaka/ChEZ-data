# %% [markdown]
# ## Processing with RN data obtained from forest sites

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Block warnings messages
import warnings
warnings.filterwarnings('ignore')

# %%
# Load biomass dataset
site_data = '../02_input_data/RN_sites_data_2024.xlsx'
df = pd.read_excel(site_data, sheet_name='RN_filtration_data')
df.head()
# Out:
#    Ідентифікатор    Site # Species  Species_ID  Ntrees at site  % composition  \
# 0             81  001_2021    Pine           0              23     100.000000
# 1            219  002_2021    Pine           0              60      90.178571
# 2            224  003_2021    Pine           0              44     100.000000
# 3            228  004_2021    Pine           0              23     100.000000
# 4            232  005_2021    Pine           0              26     100.000000
#
#         D_cm        H_m    G_m2_ha  N_ha  ...   T_ag_Cs  ln_T_ag_Cs  \
# 0  26.060965  25.423284  49.081648   920  ...  0.792857   -0.232112
# 1   4.303100   4.705979   8.731641  6000  ...  1.565517    0.448216
# 2  28.142898  27.556869  54.703060   880  ...  0.431579   -0.840305
# 3  14.953551   8.506028  40.420188  2300  ...  0.123529   -2.091276
# 4   7.208435   3.425669   2.120687   520  ...  0.221212   -1.508633
#
#      T_ag_Sr  ln_T_ag_Sr  AEDR_count AEDR_mean  AEDR_median  AEDR_std  \
# 0   8.990000    2.196113          26  3.524231        3.530  0.235489
# 1  24.191919    3.186019          15  3.830667        3.780  0.166272
# 2   6.800000    1.916923          28  0.483571        0.475  0.068931
# 3   2.460000    0.900161          20  0.364500        0.365  0.029576
# 4   6.629225    1.891488          18  0.333333        0.345  0.036515
#
#    Distance_km  Azimuth
# 0     5.926403      249
# 1     6.018960      249
# 2    13.046428      189
# 3    12.741627      189
# 4    12.893213      189
#
# [5 rows x 51 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Species', 'Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
#                                     'Origin', 'Origin_ID','A_year', 'D_live_cm', 'H_live_m', 'G_live_m2_ha',
#                                     'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
#                                     'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_A_Cs', 'ln_A_Sr',
#                                     'T_ag_Cs', 'ln_T_ag_Cs', 'T_ag_Sr', 'ln_T_ag_Sr'
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species', 'Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
                                    'Origin', 'Origin_ID','A_year',
                                    'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
                                    'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_A_Cs', 'ln_A_Sr', 
                                    'ln_T_ag_Cs', 'ln_T_ag_Sr'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#   Species  Species_ID  % composition       D_cm        H_m    G_m2_ha Origin  \
# 0    Pine           0     100.000000  26.060965  25.423284  49.081648      a
# 1    Pine           0      90.178571   4.303100   4.705979   8.731641      n
# 2    Pine           0     100.000000  28.142898  27.556869  54.703060      n
# 3    Pine           0     100.000000  14.953551   8.506028  40.420188      n
# 4    Pine           0     100.000000   7.208435   3.425669   2.120687      n
#
#    Origin_ID  A_year  F_Soil_ID  M_Soil  AEDR_mean  Distance_km  Azimuth  \
# 0          1      68          1       2   3.524231     5.926403      249
# 1          0      15          1       2   3.830667     6.018960      249
# 2          0      69          1       2   0.483571    13.046428      189
# 3          0      15          2       2   0.364500    12.741627      189
# 4          0      10          2       2   0.333333    12.893213      189
#
#    Cs_2021_kBq_m  Sr_2021_kBq_m   ln_A_Cs    ln_A_Sr  ln_T_ag_Cs  ln_T_ag_Sr
# 0         2800.0    1000.000000  7.705262   9.103868   -0.232112    2.196113
# 1         2900.0     990.000000  8.420682  10.083724    0.448216    3.186019
# 2          380.0      90.000000  5.099866   6.416732   -0.840305    1.916923
# 3          340.0     150.000000  3.737670   5.910797   -2.091276    0.900161
# 4          330.0      69.993095  4.290459   6.139885   -1.508633    1.891488

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Species        209 non-null    object
#  1   Species_ID     209 non-null    int64
#  2   % composition  209 non-null    float64
#  3   D_cm           209 non-null    float64
#  4   H_m            209 non-null    float64
#  5   G_m2_ha        209 non-null    float64
#  6   Origin         209 non-null    object
#  7   Origin_ID      209 non-null    int64
#  8   A_year         209 non-null    int64
#  9   F_Soil_ID      209 non-null    int64
#  10  M_Soil         209 non-null    int64
#  11  AEDR_mean      209 non-null    float64
#  12  Distance_km    209 non-null    float64
#  13  Azimuth        209 non-null    int64
#  14  Cs_2021_kBq_m  209 non-null    float64
#  15  Sr_2021_kBq_m  209 non-null    float64
#  16  ln_A_Cs        209 non-null    float64
#  17  ln_A_Sr        209 non-null    float64
#  18  ln_T_ag_Cs     209 non-null    float64
#  19  ln_T_ag_Sr     209 non-null    float64
# dtypes: float64(12), int64(6), object(2)
# memory usage: 32.8+ KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species"])["ln_A_Cs", "ln_A_Sr"].describe()
# Out:
#         ln_A_Cs                                                              \
#           count      mean       std       min       25%       50%       75%
# Species
# Alder      13.0  6.249674  1.661129  3.295837  5.840642  6.040255  6.940222
# Aspen       9.0  5.584313  3.039601  2.708050  3.295837  4.204693  6.729824
# Birch      45.0  5.737563  2.249143  2.079442  3.761200  6.173786  7.229839
# Oak         7.0  6.900674  2.917841  2.397895  4.966038  7.753624  9.021902
# Pine      130.0  6.066275  1.963371  1.504077  4.358932  6.564371  7.374614
# Red oak     3.0  3.445685  0.588708  2.833213  3.164860  3.496508  3.751920
# Robinia     1.0  4.394449       NaN  4.394449  4.394449  4.394449  4.394449
# Spruce      1.0  5.176150       NaN  5.176150  5.176150  5.176150  5.176150
#
#                    ln_A_Sr                                                    \
#                max   count      mean       std       min       25%       50%
# Species
# Alder     9.287301    13.0  6.055811  1.449620  4.094345  4.442651  6.302619
# Aspen    11.366743     9.0  7.575485  2.597130  4.615121  5.209486  7.870930
# Birch    10.332018    45.0  7.671630  2.317833  2.660260  5.752573  7.749322
# Oak      10.177324     7.0  7.188390  2.638333  3.871201  5.248545  7.766417
# Pine     10.468801   130.0  7.470846  1.889243  2.406945  6.165469  7.588295
# Red oak   4.007333     3.0  4.697638  0.334751  4.418841  4.512005  4.605170
# Robinia   4.394449     1.0  7.265430       NaN  7.265430  7.265430  7.265430
# Spruce    5.176150     1.0  7.783224       NaN  7.783224  7.783224  7.783224
#
#
#               75%        max
# Species
# Alder    7.286192   7.649693
# Aspen    8.881836  11.180246
# Birch    8.995909  13.864301
# Oak      8.529114  11.125791
# Pine     8.730280  12.687263
# Red oak  4.837037   5.068904
# Robinia  7.265430   7.265430
# Spruce   7.783224   7.783224

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID  % composition        D_cm         H_m     G_m2_ha  \
# count  209.000000     209.000000  209.000000  209.000000  209.000000
# mean     1.057416      94.337925   17.770981   16.978858   30.000765
# std      1.524339      14.155594    8.921738    6.832292   15.907971
# min      0.000000      20.805369    1.914854    2.704460    0.259356
# 25%      0.000000      96.775081   11.601519   12.401789   17.519173
# 50%      0.000000     100.000000   16.817809   17.466646   30.845307
# 75%      2.000000     100.000000   22.264253   21.414562   42.817263
# max      5.000000     100.000000   52.228464   34.048688   66.922093
#
#         Origin_ID      A_year   F_Soil_ID      M_Soil   AEDR_mean  \
# count  209.000000  209.000000  209.000000  209.000000  209.000000
# mean     0.454545   47.464115    1.918660    2.220096    2.526858
# std      0.499125   24.724635    0.634039    0.692944    4.756383
# min      0.000000   10.000000    1.000000    0.000000    0.110000
# 25%      0.000000   30.000000    2.000000    2.000000    0.460000
# 50%      0.000000   45.000000    2.000000    2.000000    0.756000
# 75%      1.000000   60.000000    2.000000    3.000000    2.401667
# max      1.000000  150.000000    3.000000    4.000000   36.591739
#
#        Distance_km     Azimuth  Cs_2021_kBq_m  Sr_2021_kBq_m     ln_A_Cs  \
# count   209.000000  209.000000     209.000000     209.000000  209.000000
# mean     14.640059  174.296651    2588.391812     738.540435    5.964225
# std      12.363729   99.912885    4938.371798    1556.255010    2.095016
# min       3.998568    9.000000      22.000000       1.000000    1.504077
# 25%       6.562497   56.000000     390.000000      29.466637    4.110874
# 50%       9.203749  189.000000     710.000000     210.000000    6.309918
# 75%      20.865459  261.000000    2400.000000     620.000000    7.306531
# max      57.286577  342.000000   35200.000000   10500.000000   11.366743
#
#           ln_A_Sr  ln_T_ag_Cs  ln_T_ag_Sr
# count  209.000000  209.000000  209.000000
# mean     7.381811   -0.696999    2.239622
# std      2.042856    1.294511    0.973844
# min      2.406945   -5.130702   -0.784714
# 25%      5.752573   -1.456701    1.633535
# 50%      7.506592   -0.608351    2.301556
# 75%      8.846497    0.288154    2.867382
# max     13.864301    1.645806    5.227895

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_T_ag_Sr"
indep_variables = ['Species_ID','D_cm', 'H_m', 'G_m2_ha', 'A_year',
    'Origin_ID', 'F_Soil_ID', 'M_Soil']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#     Species  Species_ID  % composition       D_cm        H_m    G_m2_ha  \
# 0      Pine           0     100.000000  26.060965  25.423284  49.081648
# 1      Pine           0      90.178571   4.303100   4.705979   8.731641
# 2      Pine           0     100.000000  28.142898  27.556869  54.703060
# 3      Pine           0     100.000000  14.953551   8.506028  40.420188
# 4      Pine           0     100.000000   7.208435   3.425669   2.120687
# ..      ...         ...            ...        ...        ...        ...
# 204   Aspen           4      99.930119  11.401754  14.676282  17.972410
# 205   Birch           2     100.000000   7.912790  13.818368  19.279495
# 206    Pine           0     100.000000  16.041613  17.515821  31.533411
# 207    Pine           0      96.775081  14.946465  18.178975  44.220927
# 208    Pine           0     100.000000  15.387224  17.673021  55.824342
#
#     Origin  Origin_ID  A_year  F_Soil_ID  M_Soil  AEDR_mean  Distance_km  \
# 0        a          1      68          1       2   3.524231     5.926403
# 1        n          0      15          1       2   3.830667     6.018960
# 2        n          0      69          1       2   0.483571    13.046428
# 3        n          0      15          2       2   0.364500    12.741627
# 4        n          0      10          2       2   0.333333    12.893213
# ..     ...        ...     ...        ...     ...        ...          ...
# 204      n          0      25          2       3  20.051250     5.190617
# 205      n          0      18          2       3  14.987391     4.749715
# 206      a          1      58          1       2   0.650000     7.850538
# 207      a          1      60          1       2   0.649063     7.276525
# 208      a          1      40          1       2   0.628214     7.292122
#
#      Azimuth  Cs_2021_kBq_m  Sr_2021_kBq_m    ln_A_Cs    ln_A_Sr  ln_T_ag_Cs  \
# 0        249    2800.000000    1000.000000   7.705262   9.103868   -0.232112
# 1        249    2900.000000     990.000000   8.420682  10.083724    0.448216
# 2        189     380.000000      90.000000   5.099866   6.416732   -0.840305
# 3        189     340.000000     150.000000   3.737670   5.910797   -2.091276
# 4        189     330.000000      69.993095   4.290459   6.139885   -1.508633
# ..       ...            ...            ...        ...        ...         ...
# 204      265   18300.000000    7300.000000  11.366743  11.089805    1.552087
# 205      262   22000.000000    8400.000000   9.539644  11.501865   -0.459154
# 206      106     539.850835     240.000000   6.498282   8.283999    0.206989
# 207       85     519.756852     220.000000   6.720220   8.575462    0.466859
# 208       86     520.000000     150.000000   6.674561   8.216088    0.420733
#
#      ln_T_ag_Sr
# 0      2.196113
# 1      3.186019
# 2      1.916923
# 3      0.900161
# 4      1.891488
# ..          ...
# 204    2.194176
# 205    2.465878
# 206    2.803360
# 207    3.181835
# 208    3.205453
#
# [209 rows x 20 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_value_1 = np.random.normal(10, 2, size=count)
    norm_value_2 = np.random.normal(10, 2, size=count)
    norm_value_3 = np.random.normal(10, 2, size=count)
    norm_value_4 = np.random.normal(10, 2, size=count)
    norm_value_5 = np.random.normal(10, 2, size=count)
    X['Random_col_1'], X['Random_col_2'], X['Random_col_3'], X['Random_col_4'], X['Random_col_5'] = norm_value_1, norm_value_2, norm_value_3, norm_value_4, norm_value_5
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): Yes
# Selected "Yes"!!! A new column with random values was created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID       D_cm        H_m    G_m2_ha  A_year  Origin_ID  F_Soil_ID  \
# 0           0  26.060965  25.423284  49.081648      68          1          1
# 1           0   4.303100   4.705979   8.731641      15          0          1
# 2           0  28.142898  27.556869  54.703060      69          0          1
# 3           0  14.953551   8.506028  40.420188      15          0          2
# 4           0   7.208435   3.425669   2.120687      10          0          2
#
#    M_Soil  Random_col_1  Random_col_2  Random_col_3  Random_col_4  \
# 0       2      9.242995      8.175968      8.826768     10.195598
# 1       2      6.689879      8.183079     10.054317      8.565346
# 2       2     10.358532     10.022471      7.184173      7.768184
# 3       2     14.306922     10.256144     10.415944     12.053827
# 4       2      7.804738      9.453279     13.106855     10.286502
#
#    Random_col_5
# 0     13.060841
# 1     11.257014
# 2     10.755967
# 3      9.623615
# 4      9.072023

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_T_ag_Sr
# 0    2.196113
# 1    3.186019
# 2    1.916923
# 3    0.900161
# 4    1.891488

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.11346912099375905, 0.33413060591845745, 0.06139643662791672]
#     Mean: 0.170
#     Std: 0.118
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.71267055 0.94335153 0.92166706]
#     Mean: 0.859
#     Std: 0.104
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.6903622126055056, 0.6742651875383691, 0.6265746278290588]
#     Mean: 0.664
#     Std: 0.027
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.7327675639923839                   # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.04558812083388075                  # gamma
print('Gamma: ' + str(p2))

p3 = 0.10198012556475948                  # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2                                    # max_depth
print('Max_depth: ' + str(p4))

p5 = 79                                   # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.811521748868657                    # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.7327675639923839
# Gamma: 0.04558812083388075
# Learning_rate: 0.10198012556475948
# Max_depth: 2
# N_estimators: 79
# Subsample: 0.811521748868657

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.87077	validation_1-rmse:1.62801
# [1]	validation_0-rmse:1.72579	validation_1-rmse:1.49505
# [2]	validation_0-rmse:1.59087	validation_1-rmse:1.37408
# [3]	validation_0-rmse:1.48008	validation_1-rmse:1.26796
# [4]	validation_0-rmse:1.37808	validation_1-rmse:1.18314
# [5]	validation_0-rmse:1.28053	validation_1-rmse:1.09694
# [6]	validation_0-rmse:1.19944	validation_1-rmse:1.02191
# [7]	validation_0-rmse:1.13027	validation_1-rmse:0.95904
# [8]	validation_0-rmse:1.06514	validation_1-rmse:0.90372
# [9]	validation_0-rmse:1.01439	validation_1-rmse:0.86217
# [10]	validation_0-rmse:0.96549	validation_1-rmse:0.82822
# [11]	validation_0-rmse:0.92722	validation_1-rmse:0.79614
# [12]	validation_0-rmse:0.89500	validation_1-rmse:0.76912
# [13]	validation_0-rmse:0.86984	validation_1-rmse:0.75469
# [14]	validation_0-rmse:0.84259	validation_1-rmse:0.73514
# [15]	validation_0-rmse:0.81847	validation_1-rmse:0.71888
# [16]	validation_0-rmse:0.79090	validation_1-rmse:0.70824
# [17]	validation_0-rmse:0.77247	validation_1-rmse:0.69850
# [18]	validation_0-rmse:0.75696	validation_1-rmse:0.69309
# [19]	validation_0-rmse:0.74306	validation_1-rmse:0.68598
# [20]	validation_0-rmse:0.72947	validation_1-rmse:0.67551
# [21]	validation_0-rmse:0.72006	validation_1-rmse:0.67277
# [22]	validation_0-rmse:0.70654	validation_1-rmse:0.67082
# [23]	validation_0-rmse:0.69889	validation_1-rmse:0.67090
# [24]	validation_0-rmse:0.69073	validation_1-rmse:0.67199
# [25]	validation_0-rmse:0.68281	validation_1-rmse:0.67140
# [26]	validation_0-rmse:0.67476	validation_1-rmse:0.66820
# [27]	validation_0-rmse:0.66782	validation_1-rmse:0.67078
# [28]	validation_0-rmse:0.66213	validation_1-rmse:0.66676
# [29]	validation_0-rmse:0.65665	validation_1-rmse:0.66889
# [30]	validation_0-rmse:0.65342	validation_1-rmse:0.67042
# [31]	validation_0-rmse:0.64860	validation_1-rmse:0.67539
# [32]	validation_0-rmse:0.64613	validation_1-rmse:0.67328
# [33]	validation_0-rmse:0.64154	validation_1-rmse:0.67184
# [34]	validation_0-rmse:0.63668	validation_1-rmse:0.67740
# [35]	validation_0-rmse:0.63066	validation_1-rmse:0.67666
# [36]	validation_0-rmse:0.62804	validation_1-rmse:0.67809
# [37]	validation_0-rmse:0.62584	validation_1-rmse:0.67662
# [38]	validation_0-rmse:0.62221	validation_1-rmse:0.67823
# [39]	validation_0-rmse:0.61917	validation_1-rmse:0.67874
# [40]	validation_0-rmse:0.61662	validation_1-rmse:0.67989
# [41]	validation_0-rmse:0.61162	validation_1-rmse:0.68257
# [42]	validation_0-rmse:0.60688	validation_1-rmse:0.68401
# [43]	validation_0-rmse:0.60437	validation_1-rmse:0.67958
# [44]	validation_0-rmse:0.60133	validation_1-rmse:0.67655
# [45]	validation_0-rmse:0.59480	validation_1-rmse:0.67143
# [46]	validation_0-rmse:0.59284	validation_1-rmse:0.67010
# [47]	validation_0-rmse:0.58988	validation_1-rmse:0.66504
# [48]	validation_0-rmse:0.58683	validation_1-rmse:0.66404
# [49]	validation_0-rmse:0.58307	validation_1-rmse:0.66626
# [50]	validation_0-rmse:0.58078	validation_1-rmse:0.66422
# [51]	validation_0-rmse:0.57580	validation_1-rmse:0.66643
# [52]	validation_0-rmse:0.57202	validation_1-rmse:0.66627
# [53]	validation_0-rmse:0.56858	validation_1-rmse:0.66731
# [54]	validation_0-rmse:0.56649	validation_1-rmse:0.66617
# [55]	validation_0-rmse:0.56301	validation_1-rmse:0.66683
# [56]	validation_0-rmse:0.55972	validation_1-rmse:0.66461
# [57]	validation_0-rmse:0.55760	validation_1-rmse:0.66371
# [58]	validation_0-rmse:0.55294	validation_1-rmse:0.66333
# [59]	validation_0-rmse:0.54999	validation_1-rmse:0.66477
# [60]	validation_0-rmse:0.54804	validation_1-rmse:0.66475
# [61]	validation_0-rmse:0.54388	validation_1-rmse:0.66025
# [62]	validation_0-rmse:0.54198	validation_1-rmse:0.65559
# [63]	validation_0-rmse:0.53951	validation_1-rmse:0.65705
# [64]	validation_0-rmse:0.53588	validation_1-rmse:0.66033
# [65]	validation_0-rmse:0.53401	validation_1-rmse:0.65421
# [66]	validation_0-rmse:0.53072	validation_1-rmse:0.65245
# [67]	validation_0-rmse:0.52814	validation_1-rmse:0.65046
# [68]	validation_0-rmse:0.52485	validation_1-rmse:0.65378
# [69]	validation_0-rmse:0.51909	validation_1-rmse:0.65535
# [70]	validation_0-rmse:0.51736	validation_1-rmse:0.65460
# [71]	validation_0-rmse:0.51527	validation_1-rmse:0.65870
# [72]	validation_0-rmse:0.51292	validation_1-rmse:0.66071
# [73]	validation_0-rmse:0.50950	validation_1-rmse:0.65906
# [74]	validation_0-rmse:0.50783	validation_1-rmse:0.65973
# [75]	validation_0-rmse:0.50466	validation_1-rmse:0.65867
# [76]	validation_0-rmse:0.50120	validation_1-rmse:0.65860
# [77]	validation_0-rmse:0.49902	validation_1-rmse:0.65961
# [78]	validation_0-rmse:0.49670	validation_1-rmse:0.66100
# [0]	validation_0-rmse:1.81694	validation_1-rmse:1.89820
# [1]	validation_0-rmse:1.67428	validation_1-rmse:1.76505
# [2]	validation_0-rmse:1.54598	validation_1-rmse:1.64813
# [3]	validation_0-rmse:1.43582	validation_1-rmse:1.54886
# [4]	validation_0-rmse:1.33952	validation_1-rmse:1.46096
# [5]	validation_0-rmse:1.25951	validation_1-rmse:1.38407
# [6]	validation_0-rmse:1.18479	validation_1-rmse:1.31098
# [7]	validation_0-rmse:1.10880	validation_1-rmse:1.23384
# [8]	validation_0-rmse:1.04868	validation_1-rmse:1.18035
# [9]	validation_0-rmse:0.99586	validation_1-rmse:1.12536
# [10]	validation_0-rmse:0.95061	validation_1-rmse:1.08329
# [11]	validation_0-rmse:0.90619	validation_1-rmse:1.04011
# [12]	validation_0-rmse:0.87416	validation_1-rmse:1.01437
# [13]	validation_0-rmse:0.84093	validation_1-rmse:0.97913
# [14]	validation_0-rmse:0.81737	validation_1-rmse:0.95967
# [15]	validation_0-rmse:0.79678	validation_1-rmse:0.94289
# [16]	validation_0-rmse:0.77440	validation_1-rmse:0.92388
# [17]	validation_0-rmse:0.75755	validation_1-rmse:0.90965
# [18]	validation_0-rmse:0.74070	validation_1-rmse:0.89727
# [19]	validation_0-rmse:0.72581	validation_1-rmse:0.88333
# [20]	validation_0-rmse:0.71043	validation_1-rmse:0.87635
# [21]	validation_0-rmse:0.69981	validation_1-rmse:0.87057
# [22]	validation_0-rmse:0.68939	validation_1-rmse:0.86174
# [23]	validation_0-rmse:0.68120	validation_1-rmse:0.85454
# [24]	validation_0-rmse:0.67340	validation_1-rmse:0.84936
# [25]	validation_0-rmse:0.66513	validation_1-rmse:0.84655
# [26]	validation_0-rmse:0.65804	validation_1-rmse:0.84296
# [27]	validation_0-rmse:0.65121	validation_1-rmse:0.83477
# [28]	validation_0-rmse:0.64554	validation_1-rmse:0.83256
# [29]	validation_0-rmse:0.64078	validation_1-rmse:0.82891
# [30]	validation_0-rmse:0.63562	validation_1-rmse:0.82970
# [31]	validation_0-rmse:0.63083	validation_1-rmse:0.82514
# [32]	validation_0-rmse:0.62185	validation_1-rmse:0.82558
# [33]	validation_0-rmse:0.61754	validation_1-rmse:0.82727
# [34]	validation_0-rmse:0.61326	validation_1-rmse:0.82814
# [35]	validation_0-rmse:0.60744	validation_1-rmse:0.82750
# [36]	validation_0-rmse:0.60301	validation_1-rmse:0.82711
# [37]	validation_0-rmse:0.59742	validation_1-rmse:0.82793
# [38]	validation_0-rmse:0.59415	validation_1-rmse:0.82773
# [39]	validation_0-rmse:0.59226	validation_1-rmse:0.82960
# [40]	validation_0-rmse:0.58807	validation_1-rmse:0.83061
# [41]	validation_0-rmse:0.58281	validation_1-rmse:0.83367
# [42]	validation_0-rmse:0.57836	validation_1-rmse:0.83341
# [43]	validation_0-rmse:0.57173	validation_1-rmse:0.83667
# [44]	validation_0-rmse:0.56604	validation_1-rmse:0.83533
# [45]	validation_0-rmse:0.56221	validation_1-rmse:0.83458
# [46]	validation_0-rmse:0.55935	validation_1-rmse:0.83474
# [47]	validation_0-rmse:0.55539	validation_1-rmse:0.83587
# [48]	validation_0-rmse:0.55170	validation_1-rmse:0.83846
# [49]	validation_0-rmse:0.54636	validation_1-rmse:0.83869
# [50]	validation_0-rmse:0.54321	validation_1-rmse:0.83957
# [51]	validation_0-rmse:0.54158	validation_1-rmse:0.83800
# [0]	validation_0-rmse:1.84696	validation_1-rmse:1.78272
# [1]	validation_0-rmse:1.69956	validation_1-rmse:1.62183
# [2]	validation_0-rmse:1.57162	validation_1-rmse:1.48810
# [3]	validation_0-rmse:1.46299	validation_1-rmse:1.37988
# [4]	validation_0-rmse:1.36812	validation_1-rmse:1.27655
# [5]	validation_0-rmse:1.28571	validation_1-rmse:1.18690
# [6]	validation_0-rmse:1.20550	validation_1-rmse:1.10128
# [7]	validation_0-rmse:1.13059	validation_1-rmse:1.01796
# [8]	validation_0-rmse:1.07216	validation_1-rmse:0.94846
# [9]	validation_0-rmse:1.02616	validation_1-rmse:0.90013
# [10]	validation_0-rmse:0.98595	validation_1-rmse:0.85531
# [11]	validation_0-rmse:0.94060	validation_1-rmse:0.81117
# [12]	validation_0-rmse:0.90659	validation_1-rmse:0.77648
# [13]	validation_0-rmse:0.87982	validation_1-rmse:0.75080
# [14]	validation_0-rmse:0.85387	validation_1-rmse:0.72592
# [15]	validation_0-rmse:0.83299	validation_1-rmse:0.70814
# [16]	validation_0-rmse:0.81032	validation_1-rmse:0.68949
# [17]	validation_0-rmse:0.79327	validation_1-rmse:0.68520
# [18]	validation_0-rmse:0.77590	validation_1-rmse:0.67201
# [19]	validation_0-rmse:0.76613	validation_1-rmse:0.67161
# [20]	validation_0-rmse:0.75521	validation_1-rmse:0.66013
# [21]	validation_0-rmse:0.74440	validation_1-rmse:0.65402
# [22]	validation_0-rmse:0.73499	validation_1-rmse:0.64907
# [23]	validation_0-rmse:0.72756	validation_1-rmse:0.64586
# [24]	validation_0-rmse:0.71798	validation_1-rmse:0.63928
# [25]	validation_0-rmse:0.70930	validation_1-rmse:0.63853
# [26]	validation_0-rmse:0.70330	validation_1-rmse:0.63631
# [27]	validation_0-rmse:0.69738	validation_1-rmse:0.63134
# [28]	validation_0-rmse:0.69338	validation_1-rmse:0.62636
# [29]	validation_0-rmse:0.68945	validation_1-rmse:0.62387
# [30]	validation_0-rmse:0.68434	validation_1-rmse:0.62711
# [31]	validation_0-rmse:0.68048	validation_1-rmse:0.62369
# [32]	validation_0-rmse:0.67645	validation_1-rmse:0.62587
# [33]	validation_0-rmse:0.67289	validation_1-rmse:0.62708
# [34]	validation_0-rmse:0.66632	validation_1-rmse:0.63000
# [35]	validation_0-rmse:0.66044	validation_1-rmse:0.62749
# [36]	validation_0-rmse:0.65577	validation_1-rmse:0.62624
# [37]	validation_0-rmse:0.65158	validation_1-rmse:0.62648
# [38]	validation_0-rmse:0.64608	validation_1-rmse:0.63061
# [39]	validation_0-rmse:0.64381	validation_1-rmse:0.63088
# [40]	validation_0-rmse:0.64082	validation_1-rmse:0.63413
# [41]	validation_0-rmse:0.63373	validation_1-rmse:0.63237
# [42]	validation_0-rmse:0.63137	validation_1-rmse:0.63340
# [43]	validation_0-rmse:0.62900	validation_1-rmse:0.63209
# [44]	validation_0-rmse:0.62457	validation_1-rmse:0.62377
# [45]	validation_0-rmse:0.61992	validation_1-rmse:0.61266
# [46]	validation_0-rmse:0.61576	validation_1-rmse:0.61125
# [47]	validation_0-rmse:0.60964	validation_1-rmse:0.61348
# [48]	validation_0-rmse:0.60590	validation_1-rmse:0.61217
# [49]	validation_0-rmse:0.60036	validation_1-rmse:0.61299
# [50]	validation_0-rmse:0.59638	validation_1-rmse:0.61210
# [51]	validation_0-rmse:0.59130	validation_1-rmse:0.61371
# [52]	validation_0-rmse:0.58812	validation_1-rmse:0.61257
# [53]	validation_0-rmse:0.58606	validation_1-rmse:0.61324
# [54]	validation_0-rmse:0.57842	validation_1-rmse:0.61716
# [55]	validation_0-rmse:0.57305	validation_1-rmse:0.62114
# [56]	validation_0-rmse:0.56886	validation_1-rmse:0.61358
# [57]	validation_0-rmse:0.56445	validation_1-rmse:0.61859
# [58]	validation_0-rmse:0.56159	validation_1-rmse:0.61592
# [59]	validation_0-rmse:0.55832	validation_1-rmse:0.61637
# [60]	validation_0-rmse:0.55594	validation_1-rmse:0.61763
# [61]	validation_0-rmse:0.55428	validation_1-rmse:0.61754
# [62]	validation_0-rmse:0.54952	validation_1-rmse:0.61870
# [63]	validation_0-rmse:0.54370	validation_1-rmse:0.62204
# [64]	validation_0-rmse:0.54200	validation_1-rmse:0.62507
# [65]	validation_0-rmse:0.53859	validation_1-rmse:0.62597
# [66]	validation_0-rmse:0.53613	validation_1-rmse:0.62658
# [0]	validation_0-rmse:1.82292	validation_1-rmse:1.86775
# [1]	validation_0-rmse:1.68491	validation_1-rmse:1.72651
# [2]	validation_0-rmse:1.56360	validation_1-rmse:1.60008
# [3]	validation_0-rmse:1.46077	validation_1-rmse:1.49039
# [4]	validation_0-rmse:1.36202	validation_1-rmse:1.38181
# [5]	validation_0-rmse:1.27194	validation_1-rmse:1.28846
# [6]	validation_0-rmse:1.19869	validation_1-rmse:1.21528
# [7]	validation_0-rmse:1.13625	validation_1-rmse:1.15034
# [8]	validation_0-rmse:1.07658	validation_1-rmse:1.08854
# [9]	validation_0-rmse:1.02373	validation_1-rmse:1.03249
# [10]	validation_0-rmse:0.97289	validation_1-rmse:0.98063
# [11]	validation_0-rmse:0.93841	validation_1-rmse:0.94379
# [12]	validation_0-rmse:0.90281	validation_1-rmse:0.90113
# [13]	validation_0-rmse:0.87359	validation_1-rmse:0.86927
# [14]	validation_0-rmse:0.84718	validation_1-rmse:0.84260
# [15]	validation_0-rmse:0.82967	validation_1-rmse:0.82544
# [16]	validation_0-rmse:0.80934	validation_1-rmse:0.80578
# [17]	validation_0-rmse:0.79345	validation_1-rmse:0.79366
# [18]	validation_0-rmse:0.77761	validation_1-rmse:0.77575
# [19]	validation_0-rmse:0.76355	validation_1-rmse:0.75872
# [20]	validation_0-rmse:0.75214	validation_1-rmse:0.74970
# [21]	validation_0-rmse:0.74419	validation_1-rmse:0.74271
# [22]	validation_0-rmse:0.73639	validation_1-rmse:0.73600
# [23]	validation_0-rmse:0.72768	validation_1-rmse:0.72924
# [24]	validation_0-rmse:0.71906	validation_1-rmse:0.72615
# [25]	validation_0-rmse:0.71230	validation_1-rmse:0.72359
# [26]	validation_0-rmse:0.70150	validation_1-rmse:0.72195
# [27]	validation_0-rmse:0.69553	validation_1-rmse:0.72252
# [28]	validation_0-rmse:0.68959	validation_1-rmse:0.72456
# [29]	validation_0-rmse:0.68174	validation_1-rmse:0.72336
# [30]	validation_0-rmse:0.67665	validation_1-rmse:0.73113
# [31]	validation_0-rmse:0.67166	validation_1-rmse:0.72558
# [32]	validation_0-rmse:0.66688	validation_1-rmse:0.72490
# [33]	validation_0-rmse:0.66206	validation_1-rmse:0.72035
# [34]	validation_0-rmse:0.65585	validation_1-rmse:0.71841
# [35]	validation_0-rmse:0.65249	validation_1-rmse:0.71904
# [36]	validation_0-rmse:0.64804	validation_1-rmse:0.71807
# [37]	validation_0-rmse:0.64303	validation_1-rmse:0.71473
# [38]	validation_0-rmse:0.63966	validation_1-rmse:0.71681
# [39]	validation_0-rmse:0.63385	validation_1-rmse:0.71589
# [40]	validation_0-rmse:0.63032	validation_1-rmse:0.71433
# [41]	validation_0-rmse:0.62640	validation_1-rmse:0.71098
# [42]	validation_0-rmse:0.61955	validation_1-rmse:0.71193
# [43]	validation_0-rmse:0.61588	validation_1-rmse:0.71246
# [44]	validation_0-rmse:0.61158	validation_1-rmse:0.70834
# [45]	validation_0-rmse:0.60769	validation_1-rmse:0.70883
# [46]	validation_0-rmse:0.60438	validation_1-rmse:0.71037
# [47]	validation_0-rmse:0.59979	validation_1-rmse:0.70732
# [48]	validation_0-rmse:0.59543	validation_1-rmse:0.70841
# [49]	validation_0-rmse:0.59098	validation_1-rmse:0.70966
# [50]	validation_0-rmse:0.58732	validation_1-rmse:0.71263
# [51]	validation_0-rmse:0.58503	validation_1-rmse:0.71093
# [52]	validation_0-rmse:0.57934	validation_1-rmse:0.71073
# [53]	validation_0-rmse:0.57216	validation_1-rmse:0.71810
# [54]	validation_0-rmse:0.56506	validation_1-rmse:0.70863
# [55]	validation_0-rmse:0.56092	validation_1-rmse:0.70925
# [56]	validation_0-rmse:0.55751	validation_1-rmse:0.70882
# [57]	validation_0-rmse:0.55488	validation_1-rmse:0.71104
# [58]	validation_0-rmse:0.55006	validation_1-rmse:0.71147
# [59]	validation_0-rmse:0.54658	validation_1-rmse:0.71606
# [60]	validation_0-rmse:0.54466	validation_1-rmse:0.71783
# [61]	validation_0-rmse:0.54256	validation_1-rmse:0.71697
# [62]	validation_0-rmse:0.53929	validation_1-rmse:0.71697
# [63]	validation_0-rmse:0.53689	validation_1-rmse:0.71797
# [64]	validation_0-rmse:0.53313	validation_1-rmse:0.71487
# [65]	validation_0-rmse:0.53128	validation_1-rmse:0.71590
# [66]	validation_0-rmse:0.52669	validation_1-rmse:0.72073
# [0]	validation_0-rmse:1.83984	validation_1-rmse:1.79571
# [1]	validation_0-rmse:1.69911	validation_1-rmse:1.64895
# [2]	validation_0-rmse:1.57480	validation_1-rmse:1.52017
# [3]	validation_0-rmse:1.46790	validation_1-rmse:1.41641
# [4]	validation_0-rmse:1.36878	validation_1-rmse:1.31793
# [5]	validation_0-rmse:1.28283	validation_1-rmse:1.23688
# [6]	validation_0-rmse:1.19704	validation_1-rmse:1.14429
# [7]	validation_0-rmse:1.12002	validation_1-rmse:1.06318
# [8]	validation_0-rmse:1.05813	validation_1-rmse:1.01248
# [9]	validation_0-rmse:1.00629	validation_1-rmse:0.96228
# [10]	validation_0-rmse:0.95808	validation_1-rmse:0.91640
# [11]	validation_0-rmse:0.91667	validation_1-rmse:0.87408
# [12]	validation_0-rmse:0.88256	validation_1-rmse:0.84839
# [13]	validation_0-rmse:0.84882	validation_1-rmse:0.81825
# [14]	validation_0-rmse:0.82274	validation_1-rmse:0.79834
# [15]	validation_0-rmse:0.80047	validation_1-rmse:0.78254
# [16]	validation_0-rmse:0.77893	validation_1-rmse:0.76595
# [17]	validation_0-rmse:0.76431	validation_1-rmse:0.76254
# [18]	validation_0-rmse:0.74594	validation_1-rmse:0.75253
# [19]	validation_0-rmse:0.73355	validation_1-rmse:0.74708
# [20]	validation_0-rmse:0.72130	validation_1-rmse:0.73908
# [21]	validation_0-rmse:0.70796	validation_1-rmse:0.73830
# [22]	validation_0-rmse:0.69907	validation_1-rmse:0.73623
# [23]	validation_0-rmse:0.69048	validation_1-rmse:0.73026
# [24]	validation_0-rmse:0.68399	validation_1-rmse:0.72669
# [25]	validation_0-rmse:0.67473	validation_1-rmse:0.72254
# [26]	validation_0-rmse:0.67058	validation_1-rmse:0.72032
# [27]	validation_0-rmse:0.66185	validation_1-rmse:0.71754
# [28]	validation_0-rmse:0.65471	validation_1-rmse:0.72147
# [29]	validation_0-rmse:0.64733	validation_1-rmse:0.72160
# [30]	validation_0-rmse:0.64257	validation_1-rmse:0.72253
# [31]	validation_0-rmse:0.63947	validation_1-rmse:0.72255
# [32]	validation_0-rmse:0.63323	validation_1-rmse:0.72121
# [33]	validation_0-rmse:0.62906	validation_1-rmse:0.72186
# [34]	validation_0-rmse:0.62408	validation_1-rmse:0.71685
# [35]	validation_0-rmse:0.61999	validation_1-rmse:0.71363
# [36]	validation_0-rmse:0.61382	validation_1-rmse:0.71730
# [37]	validation_0-rmse:0.61061	validation_1-rmse:0.71542
# [38]	validation_0-rmse:0.60620	validation_1-rmse:0.71891
# [39]	validation_0-rmse:0.60187	validation_1-rmse:0.71871
# [40]	validation_0-rmse:0.59903	validation_1-rmse:0.72002
# [41]	validation_0-rmse:0.59191	validation_1-rmse:0.72249
# [42]	validation_0-rmse:0.58663	validation_1-rmse:0.71845
# [43]	validation_0-rmse:0.58244	validation_1-rmse:0.71514
# [44]	validation_0-rmse:0.57785	validation_1-rmse:0.71637
# [45]	validation_0-rmse:0.57393	validation_1-rmse:0.72220
# [46]	validation_0-rmse:0.57057	validation_1-rmse:0.72356
# [47]	validation_0-rmse:0.56625	validation_1-rmse:0.72352
# [48]	validation_0-rmse:0.56286	validation_1-rmse:0.72195
# [49]	validation_0-rmse:0.56044	validation_1-rmse:0.72086
# [50]	validation_0-rmse:0.55783	validation_1-rmse:0.72351
# [51]	validation_0-rmse:0.55402	validation_1-rmse:0.72457
# [52]	validation_0-rmse:0.55150	validation_1-rmse:0.72298
# [53]	validation_0-rmse:0.54458	validation_1-rmse:0.72358
# [54]	validation_0-rmse:0.54033	validation_1-rmse:0.72597
# [55]	validation_0-rmse:0.53669	validation_1-rmse:0.72955
# [0]	validation_0-rmse:1.84134	validation_1-rmse:1.79276
# [1]	validation_0-rmse:1.69854	validation_1-rmse:1.64807
# [2]	validation_0-rmse:1.56842	validation_1-rmse:1.51191
# [3]	validation_0-rmse:1.45263	validation_1-rmse:1.40215
# [4]	validation_0-rmse:1.35600	validation_1-rmse:1.31587
# [5]	validation_0-rmse:1.26209	validation_1-rmse:1.22270
# [6]	validation_0-rmse:1.18565	validation_1-rmse:1.15208
# [7]	validation_0-rmse:1.12205	validation_1-rmse:1.08729
# [8]	validation_0-rmse:1.06782	validation_1-rmse:1.03197
# [9]	validation_0-rmse:1.01642	validation_1-rmse:0.97639
# [10]	validation_0-rmse:0.96911	validation_1-rmse:0.93592
# [11]	validation_0-rmse:0.92856	validation_1-rmse:0.89768
# [12]	validation_0-rmse:0.89828	validation_1-rmse:0.89084
# [13]	validation_0-rmse:0.86671	validation_1-rmse:0.85857
# [14]	validation_0-rmse:0.83916	validation_1-rmse:0.83902
# [15]	validation_0-rmse:0.81555	validation_1-rmse:0.81210
# [16]	validation_0-rmse:0.79901	validation_1-rmse:0.79889
# [17]	validation_0-rmse:0.78131	validation_1-rmse:0.79906
# [18]	validation_0-rmse:0.76767	validation_1-rmse:0.79655
# [19]	validation_0-rmse:0.75405	validation_1-rmse:0.79850
# [20]	validation_0-rmse:0.73956	validation_1-rmse:0.78450
# [21]	validation_0-rmse:0.72928	validation_1-rmse:0.77428
# [22]	validation_0-rmse:0.71976	validation_1-rmse:0.76681
# [23]	validation_0-rmse:0.71070	validation_1-rmse:0.75499
# [24]	validation_0-rmse:0.70479	validation_1-rmse:0.75337
# [25]	validation_0-rmse:0.69728	validation_1-rmse:0.74972
# [26]	validation_0-rmse:0.69123	validation_1-rmse:0.74933
# [27]	validation_0-rmse:0.68572	validation_1-rmse:0.74680
# [28]	validation_0-rmse:0.67995	validation_1-rmse:0.75036
# [29]	validation_0-rmse:0.67399	validation_1-rmse:0.74659
# [30]	validation_0-rmse:0.67059	validation_1-rmse:0.74563
# [31]	validation_0-rmse:0.66365	validation_1-rmse:0.74868
# [32]	validation_0-rmse:0.65483	validation_1-rmse:0.74257
# [33]	validation_0-rmse:0.64902	validation_1-rmse:0.74650
# [34]	validation_0-rmse:0.64491	validation_1-rmse:0.74322
# [35]	validation_0-rmse:0.63912	validation_1-rmse:0.74667
# [36]	validation_0-rmse:0.63493	validation_1-rmse:0.74708
# [37]	validation_0-rmse:0.63187	validation_1-rmse:0.74749
# [38]	validation_0-rmse:0.62893	validation_1-rmse:0.75326
# [39]	validation_0-rmse:0.62373	validation_1-rmse:0.75527
# [40]	validation_0-rmse:0.61904	validation_1-rmse:0.74799
# [41]	validation_0-rmse:0.61221	validation_1-rmse:0.74925
# [42]	validation_0-rmse:0.60992	validation_1-rmse:0.74853
# [43]	validation_0-rmse:0.60717	validation_1-rmse:0.74622
# [44]	validation_0-rmse:0.60319	validation_1-rmse:0.74397
# [45]	validation_0-rmse:0.59760	validation_1-rmse:0.74066
# [46]	validation_0-rmse:0.59431	validation_1-rmse:0.74348
# [47]	validation_0-rmse:0.59111	validation_1-rmse:0.74483
# [48]	validation_0-rmse:0.58733	validation_1-rmse:0.74609
# [49]	validation_0-rmse:0.58400	validation_1-rmse:0.74647
# [50]	validation_0-rmse:0.57968	validation_1-rmse:0.74515
# [51]	validation_0-rmse:0.57563	validation_1-rmse:0.74769
# [52]	validation_0-rmse:0.57189	validation_1-rmse:0.74809
# [53]	validation_0-rmse:0.56851	validation_1-rmse:0.75503
# [54]	validation_0-rmse:0.56564	validation_1-rmse:0.76221
# [55]	validation_0-rmse:0.56221	validation_1-rmse:0.76356
# [56]	validation_0-rmse:0.55975	validation_1-rmse:0.76255
# [57]	validation_0-rmse:0.55704	validation_1-rmse:0.75937
# [58]	validation_0-rmse:0.55295	validation_1-rmse:0.76252
# [59]	validation_0-rmse:0.55082	validation_1-rmse:0.76164
# [60]	validation_0-rmse:0.54755	validation_1-rmse:0.75946
# [61]	validation_0-rmse:0.54604	validation_1-rmse:0.75957
# [62]	validation_0-rmse:0.54353	validation_1-rmse:0.75805
# [63]	validation_0-rmse:0.53993	validation_1-rmse:0.75312
# [64]	validation_0-rmse:0.53672	validation_1-rmse:0.75486
# [0]	validation_0-rmse:1.80549	validation_1-rmse:1.92617
# [1]	validation_0-rmse:1.66434	validation_1-rmse:1.78937
# [2]	validation_0-rmse:1.53335	validation_1-rmse:1.67496
# [3]	validation_0-rmse:1.41948	validation_1-rmse:1.56595
# [4]	validation_0-rmse:1.32229	validation_1-rmse:1.47217
# [5]	validation_0-rmse:1.23552	validation_1-rmse:1.39090
# [6]	validation_0-rmse:1.15975	validation_1-rmse:1.31430
# [7]	validation_0-rmse:1.08903	validation_1-rmse:1.25858
# [8]	validation_0-rmse:1.03135	validation_1-rmse:1.21438
# [9]	validation_0-rmse:0.98231	validation_1-rmse:1.17218
# [10]	validation_0-rmse:0.93637	validation_1-rmse:1.12612
# [11]	validation_0-rmse:0.89328	validation_1-rmse:1.09289
# [12]	validation_0-rmse:0.85920	validation_1-rmse:1.07295
# [13]	validation_0-rmse:0.83238	validation_1-rmse:1.03922
# [14]	validation_0-rmse:0.79818	validation_1-rmse:1.01559
# [15]	validation_0-rmse:0.77711	validation_1-rmse:1.00059
# [16]	validation_0-rmse:0.75726	validation_1-rmse:0.98202
# [17]	validation_0-rmse:0.74161	validation_1-rmse:0.96745
# [18]	validation_0-rmse:0.72046	validation_1-rmse:0.96345
# [19]	validation_0-rmse:0.70618	validation_1-rmse:0.95087
# [20]	validation_0-rmse:0.69312	validation_1-rmse:0.94639
# [21]	validation_0-rmse:0.68270	validation_1-rmse:0.93506
# [22]	validation_0-rmse:0.67316	validation_1-rmse:0.92544
# [23]	validation_0-rmse:0.66613	validation_1-rmse:0.92638
# [24]	validation_0-rmse:0.65825	validation_1-rmse:0.92146
# [25]	validation_0-rmse:0.64922	validation_1-rmse:0.92103
# [26]	validation_0-rmse:0.64174	validation_1-rmse:0.92063
# [27]	validation_0-rmse:0.63538	validation_1-rmse:0.91663
# [28]	validation_0-rmse:0.63164	validation_1-rmse:0.91614
# [29]	validation_0-rmse:0.62586	validation_1-rmse:0.91865
# [30]	validation_0-rmse:0.62014	validation_1-rmse:0.92131
# [31]	validation_0-rmse:0.61568	validation_1-rmse:0.91635
# [32]	validation_0-rmse:0.61148	validation_1-rmse:0.92062
# [33]	validation_0-rmse:0.60610	validation_1-rmse:0.91993
# [34]	validation_0-rmse:0.60347	validation_1-rmse:0.92411
# [35]	validation_0-rmse:0.59872	validation_1-rmse:0.92509
# [36]	validation_0-rmse:0.59410	validation_1-rmse:0.92621
# [37]	validation_0-rmse:0.59074	validation_1-rmse:0.92516
# [38]	validation_0-rmse:0.58634	validation_1-rmse:0.91795
# [39]	validation_0-rmse:0.58244	validation_1-rmse:0.92026
# [40]	validation_0-rmse:0.57732	validation_1-rmse:0.91436
# [41]	validation_0-rmse:0.57339	validation_1-rmse:0.91400
# [42]	validation_0-rmse:0.57007	validation_1-rmse:0.91526
# [43]	validation_0-rmse:0.56151	validation_1-rmse:0.91426
# [44]	validation_0-rmse:0.55608	validation_1-rmse:0.91362
# [45]	validation_0-rmse:0.55298	validation_1-rmse:0.91465
# [46]	validation_0-rmse:0.55098	validation_1-rmse:0.91461
# [47]	validation_0-rmse:0.54638	validation_1-rmse:0.92040
# [48]	validation_0-rmse:0.54293	validation_1-rmse:0.92163
# [49]	validation_0-rmse:0.53877	validation_1-rmse:0.92159
# [50]	validation_0-rmse:0.53446	validation_1-rmse:0.91690
# [51]	validation_0-rmse:0.53104	validation_1-rmse:0.91904
# [52]	validation_0-rmse:0.52889	validation_1-rmse:0.91747
# [53]	validation_0-rmse:0.52650	validation_1-rmse:0.91806
# [54]	validation_0-rmse:0.52378	validation_1-rmse:0.92108
# [55]	validation_0-rmse:0.51938	validation_1-rmse:0.92366
# [56]	validation_0-rmse:0.51697	validation_1-rmse:0.92155
# [57]	validation_0-rmse:0.51310	validation_1-rmse:0.92044
# [58]	validation_0-rmse:0.51131	validation_1-rmse:0.91650
# [59]	validation_0-rmse:0.50948	validation_1-rmse:0.91944
# [60]	validation_0-rmse:0.50758	validation_1-rmse:0.92008
# [61]	validation_0-rmse:0.50323	validation_1-rmse:0.92152
# [62]	validation_0-rmse:0.50090	validation_1-rmse:0.91977
# [63]	validation_0-rmse:0.49842	validation_1-rmse:0.91857
# [0]	validation_0-rmse:1.84805	validation_1-rmse:1.76249
# [1]	validation_0-rmse:1.70630	validation_1-rmse:1.61508
# [2]	validation_0-rmse:1.56907	validation_1-rmse:1.47905
# [3]	validation_0-rmse:1.45844	validation_1-rmse:1.37635
# [4]	validation_0-rmse:1.35912	validation_1-rmse:1.28038
# [5]	validation_0-rmse:1.27087	validation_1-rmse:1.20233
# [6]	validation_0-rmse:1.19526	validation_1-rmse:1.13339
# [7]	validation_0-rmse:1.12321	validation_1-rmse:1.06692
# [8]	validation_0-rmse:1.06376	validation_1-rmse:1.01342
# [9]	validation_0-rmse:1.01140	validation_1-rmse:0.97107
# [10]	validation_0-rmse:0.96864	validation_1-rmse:0.95294
# [11]	validation_0-rmse:0.92584	validation_1-rmse:0.92307
# [12]	validation_0-rmse:0.89216	validation_1-rmse:0.89796
# [13]	validation_0-rmse:0.86520	validation_1-rmse:0.87902
# [14]	validation_0-rmse:0.84088	validation_1-rmse:0.85951
# [15]	validation_0-rmse:0.81680	validation_1-rmse:0.84862
# [16]	validation_0-rmse:0.79294	validation_1-rmse:0.82569
# [17]	validation_0-rmse:0.77719	validation_1-rmse:0.82695
# [18]	validation_0-rmse:0.76151	validation_1-rmse:0.82245
# [19]	validation_0-rmse:0.75003	validation_1-rmse:0.80957
# [20]	validation_0-rmse:0.74111	validation_1-rmse:0.80155
# [21]	validation_0-rmse:0.72852	validation_1-rmse:0.80275
# [22]	validation_0-rmse:0.71714	validation_1-rmse:0.79739
# [23]	validation_0-rmse:0.70818	validation_1-rmse:0.79824
# [24]	validation_0-rmse:0.69859	validation_1-rmse:0.79945
# [25]	validation_0-rmse:0.69059	validation_1-rmse:0.79968
# [26]	validation_0-rmse:0.68319	validation_1-rmse:0.79824
# [27]	validation_0-rmse:0.67762	validation_1-rmse:0.79593
# [28]	validation_0-rmse:0.67120	validation_1-rmse:0.79753
# [29]	validation_0-rmse:0.66529	validation_1-rmse:0.79244
# [30]	validation_0-rmse:0.66078	validation_1-rmse:0.79079
# [31]	validation_0-rmse:0.65598	validation_1-rmse:0.78960
# [32]	validation_0-rmse:0.64848	validation_1-rmse:0.78879
# [33]	validation_0-rmse:0.64383	validation_1-rmse:0.78825
# [34]	validation_0-rmse:0.63834	validation_1-rmse:0.79405
# [35]	validation_0-rmse:0.63555	validation_1-rmse:0.79255
# [36]	validation_0-rmse:0.63281	validation_1-rmse:0.79220
# [37]	validation_0-rmse:0.62877	validation_1-rmse:0.78799
# [38]	validation_0-rmse:0.62535	validation_1-rmse:0.79098
# [39]	validation_0-rmse:0.62378	validation_1-rmse:0.79025
# [40]	validation_0-rmse:0.61913	validation_1-rmse:0.79635
# [41]	validation_0-rmse:0.61085	validation_1-rmse:0.78475
# [42]	validation_0-rmse:0.60705	validation_1-rmse:0.77554
# [43]	validation_0-rmse:0.60210	validation_1-rmse:0.77402
# [44]	validation_0-rmse:0.59786	validation_1-rmse:0.77244
# [45]	validation_0-rmse:0.59372	validation_1-rmse:0.77448
# [46]	validation_0-rmse:0.58786	validation_1-rmse:0.77853
# [47]	validation_0-rmse:0.58350	validation_1-rmse:0.77653
# [48]	validation_0-rmse:0.58128	validation_1-rmse:0.77657
# [49]	validation_0-rmse:0.57240	validation_1-rmse:0.77757
# [50]	validation_0-rmse:0.56896	validation_1-rmse:0.77759
# [51]	validation_0-rmse:0.56642	validation_1-rmse:0.78002
# [52]	validation_0-rmse:0.56215	validation_1-rmse:0.78280
# [53]	validation_0-rmse:0.55922	validation_1-rmse:0.78475
# [54]	validation_0-rmse:0.55656	validation_1-rmse:0.78839
# [55]	validation_0-rmse:0.55337	validation_1-rmse:0.78366
# [56]	validation_0-rmse:0.54927	validation_1-rmse:0.77833
# [57]	validation_0-rmse:0.54443	validation_1-rmse:0.77909
# [58]	validation_0-rmse:0.54225	validation_1-rmse:0.77949
# [59]	validation_0-rmse:0.53952	validation_1-rmse:0.78538
# [60]	validation_0-rmse:0.53698	validation_1-rmse:0.78462
# [61]	validation_0-rmse:0.53468	validation_1-rmse:0.78502
# [62]	validation_0-rmse:0.53305	validation_1-rmse:0.78581
# [63]	validation_0-rmse:0.53076	validation_1-rmse:0.78619
# [0]	validation_0-rmse:1.84807	validation_1-rmse:1.79186
# [1]	validation_0-rmse:1.69861	validation_1-rmse:1.65161
# [2]	validation_0-rmse:1.57016	validation_1-rmse:1.52760
# [3]	validation_0-rmse:1.45945	validation_1-rmse:1.42549
# [4]	validation_0-rmse:1.35709	validation_1-rmse:1.33209
# [5]	validation_0-rmse:1.26799	validation_1-rmse:1.24467
# [6]	validation_0-rmse:1.19331	validation_1-rmse:1.17694
# [7]	validation_0-rmse:1.12338	validation_1-rmse:1.11116
# [8]	validation_0-rmse:1.06406	validation_1-rmse:1.05804
# [9]	validation_0-rmse:1.01366	validation_1-rmse:1.01651
# [10]	validation_0-rmse:0.96677	validation_1-rmse:0.97918
# [11]	validation_0-rmse:0.92150	validation_1-rmse:0.94064
# [12]	validation_0-rmse:0.88658	validation_1-rmse:0.92094
# [13]	validation_0-rmse:0.85857	validation_1-rmse:0.89822
# [14]	validation_0-rmse:0.83243	validation_1-rmse:0.87472
# [15]	validation_0-rmse:0.80993	validation_1-rmse:0.86115
# [16]	validation_0-rmse:0.79005	validation_1-rmse:0.84221
# [17]	validation_0-rmse:0.77316	validation_1-rmse:0.83395
# [18]	validation_0-rmse:0.75860	validation_1-rmse:0.82421
# [19]	validation_0-rmse:0.74796	validation_1-rmse:0.81952
# [20]	validation_0-rmse:0.73621	validation_1-rmse:0.81189
# [21]	validation_0-rmse:0.72699	validation_1-rmse:0.80263
# [22]	validation_0-rmse:0.71873	validation_1-rmse:0.79798
# [23]	validation_0-rmse:0.71165	validation_1-rmse:0.78972
# [24]	validation_0-rmse:0.70622	validation_1-rmse:0.78540
# [25]	validation_0-rmse:0.69826	validation_1-rmse:0.78028
# [26]	validation_0-rmse:0.68903	validation_1-rmse:0.77752
# [27]	validation_0-rmse:0.68295	validation_1-rmse:0.77606
# [28]	validation_0-rmse:0.67941	validation_1-rmse:0.77335
# [29]	validation_0-rmse:0.67404	validation_1-rmse:0.77059
# [30]	validation_0-rmse:0.67030	validation_1-rmse:0.77070
# [31]	validation_0-rmse:0.66711	validation_1-rmse:0.76938
# [32]	validation_0-rmse:0.66261	validation_1-rmse:0.76554
# [33]	validation_0-rmse:0.65901	validation_1-rmse:0.76503
# [34]	validation_0-rmse:0.65437	validation_1-rmse:0.76403
# [35]	validation_0-rmse:0.65021	validation_1-rmse:0.75909
# [36]	validation_0-rmse:0.64760	validation_1-rmse:0.75807
# [37]	validation_0-rmse:0.64277	validation_1-rmse:0.76190
# [38]	validation_0-rmse:0.63478	validation_1-rmse:0.77019
# [39]	validation_0-rmse:0.63121	validation_1-rmse:0.77709
# [40]	validation_0-rmse:0.62542	validation_1-rmse:0.78154
# [41]	validation_0-rmse:0.61796	validation_1-rmse:0.78216
# [42]	validation_0-rmse:0.61456	validation_1-rmse:0.77783
# [43]	validation_0-rmse:0.60690	validation_1-rmse:0.76758
# [44]	validation_0-rmse:0.60344	validation_1-rmse:0.76735
# [45]	validation_0-rmse:0.60142	validation_1-rmse:0.76806
# [46]	validation_0-rmse:0.59695	validation_1-rmse:0.76300
# [47]	validation_0-rmse:0.59090	validation_1-rmse:0.76887
# [48]	validation_0-rmse:0.58731	validation_1-rmse:0.76192
# [49]	validation_0-rmse:0.58334	validation_1-rmse:0.76140
# [50]	validation_0-rmse:0.57946	validation_1-rmse:0.76379
# [51]	validation_0-rmse:0.57709	validation_1-rmse:0.76580
# [52]	validation_0-rmse:0.57363	validation_1-rmse:0.76546
# [53]	validation_0-rmse:0.57129	validation_1-rmse:0.76301
# [54]	validation_0-rmse:0.56951	validation_1-rmse:0.76491
# [55]	validation_0-rmse:0.56413	validation_1-rmse:0.75623
# [56]	validation_0-rmse:0.56154	validation_1-rmse:0.75937
# [57]	validation_0-rmse:0.55756	validation_1-rmse:0.76354
# [58]	validation_0-rmse:0.55319	validation_1-rmse:0.76199
# [59]	validation_0-rmse:0.55091	validation_1-rmse:0.76477
# [60]	validation_0-rmse:0.54722	validation_1-rmse:0.76257
# [61]	validation_0-rmse:0.54454	validation_1-rmse:0.75767
# [62]	validation_0-rmse:0.54079	validation_1-rmse:0.75853
# [63]	validation_0-rmse:0.53885	validation_1-rmse:0.75607
# [64]	validation_0-rmse:0.53740	validation_1-rmse:0.75633
# [65]	validation_0-rmse:0.53412	validation_1-rmse:0.75624
# [66]	validation_0-rmse:0.53216	validation_1-rmse:0.75596
# [67]	validation_0-rmse:0.52488	validation_1-rmse:0.76457
# [68]	validation_0-rmse:0.52355	validation_1-rmse:0.76495
# [69]	validation_0-rmse:0.52048	validation_1-rmse:0.76327
# [70]	validation_0-rmse:0.51879	validation_1-rmse:0.76454
# [71]	validation_0-rmse:0.51608	validation_1-rmse:0.76246
# [72]	validation_0-rmse:0.51502	validation_1-rmse:0.76438
# [73]	validation_0-rmse:0.51289	validation_1-rmse:0.76483
# [74]	validation_0-rmse:0.51078	validation_1-rmse:0.76084
# [75]	validation_0-rmse:0.50575	validation_1-rmse:0.77046
# [76]	validation_0-rmse:0.50189	validation_1-rmse:0.77287
# [77]	validation_0-rmse:0.49969	validation_1-rmse:0.76942
# [78]	validation_0-rmse:0.49636	validation_1-rmse:0.77098
# [0]	validation_0-rmse:1.82635	validation_1-rmse:1.81765
# [1]	validation_0-rmse:1.67933	validation_1-rmse:1.66687
# [2]	validation_0-rmse:1.54813	validation_1-rmse:1.53532
# [3]	validation_0-rmse:1.43638	validation_1-rmse:1.42609
# [4]	validation_0-rmse:1.33690	validation_1-rmse:1.33321
# [5]	validation_0-rmse:1.24212	validation_1-rmse:1.25357
# [6]	validation_0-rmse:1.16182	validation_1-rmse:1.17619
# [7]	validation_0-rmse:1.09928	validation_1-rmse:1.12064
# [8]	validation_0-rmse:1.04062	validation_1-rmse:1.07559
# [9]	validation_0-rmse:0.98802	validation_1-rmse:1.03986
# [10]	validation_0-rmse:0.93686	validation_1-rmse:1.00017
# [11]	validation_0-rmse:0.89737	validation_1-rmse:0.97346
# [12]	validation_0-rmse:0.86563	validation_1-rmse:0.94798
# [13]	validation_0-rmse:0.83306	validation_1-rmse:0.93244
# [14]	validation_0-rmse:0.80699	validation_1-rmse:0.91643
# [15]	validation_0-rmse:0.78565	validation_1-rmse:0.91007
# [16]	validation_0-rmse:0.76291	validation_1-rmse:0.89228
# [17]	validation_0-rmse:0.74440	validation_1-rmse:0.88166
# [18]	validation_0-rmse:0.73031	validation_1-rmse:0.87426
# [19]	validation_0-rmse:0.71906	validation_1-rmse:0.86828
# [20]	validation_0-rmse:0.70658	validation_1-rmse:0.86636
# [21]	validation_0-rmse:0.69260	validation_1-rmse:0.86051
# [22]	validation_0-rmse:0.68279	validation_1-rmse:0.85996
# [23]	validation_0-rmse:0.67404	validation_1-rmse:0.85806
# [24]	validation_0-rmse:0.66331	validation_1-rmse:0.86296
# [25]	validation_0-rmse:0.65471	validation_1-rmse:0.86315
# [26]	validation_0-rmse:0.64544	validation_1-rmse:0.86646
# [27]	validation_0-rmse:0.63931	validation_1-rmse:0.86789
# [28]	validation_0-rmse:0.63245	validation_1-rmse:0.86838
# [29]	validation_0-rmse:0.62725	validation_1-rmse:0.87073
# [30]	validation_0-rmse:0.62193	validation_1-rmse:0.87083
# [31]	validation_0-rmse:0.61573	validation_1-rmse:0.86969
# [32]	validation_0-rmse:0.60883	validation_1-rmse:0.87398
# [33]	validation_0-rmse:0.60236	validation_1-rmse:0.87849
# [34]	validation_0-rmse:0.59718	validation_1-rmse:0.88402
# [35]	validation_0-rmse:0.59183	validation_1-rmse:0.88527
# [36]	validation_0-rmse:0.58452	validation_1-rmse:0.88456
# [37]	validation_0-rmse:0.57908	validation_1-rmse:0.88574
# [38]	validation_0-rmse:0.57580	validation_1-rmse:0.88703
# [39]	validation_0-rmse:0.57180	validation_1-rmse:0.88994
# [40]	validation_0-rmse:0.56657	validation_1-rmse:0.89432
# [41]	validation_0-rmse:0.56347	validation_1-rmse:0.89135
# [42]	validation_0-rmse:0.56022	validation_1-rmse:0.89190
# [0]	validation_0-rmse:1.86000	validation_1-rmse:1.70593
# [1]	validation_0-rmse:1.71954	validation_1-rmse:1.54263
# [2]	validation_0-rmse:1.58957	validation_1-rmse:1.39650
# [3]	validation_0-rmse:1.47425	validation_1-rmse:1.27687
# [4]	validation_0-rmse:1.37037	validation_1-rmse:1.16804
# [5]	validation_0-rmse:1.28004	validation_1-rmse:1.06862
# [6]	validation_0-rmse:1.20102	validation_1-rmse:0.98029
# [7]	validation_0-rmse:1.13929	validation_1-rmse:0.91368
# [8]	validation_0-rmse:1.08139	validation_1-rmse:0.85613
# [9]	validation_0-rmse:1.03524	validation_1-rmse:0.80210
# [10]	validation_0-rmse:0.99472	validation_1-rmse:0.77438
# [11]	validation_0-rmse:0.95808	validation_1-rmse:0.73916
# [12]	validation_0-rmse:0.92836	validation_1-rmse:0.71031
# [13]	validation_0-rmse:0.89829	validation_1-rmse:0.67946
# [14]	validation_0-rmse:0.87127	validation_1-rmse:0.65399
# [15]	validation_0-rmse:0.84719	validation_1-rmse:0.63094
# [16]	validation_0-rmse:0.82265	validation_1-rmse:0.61388
# [17]	validation_0-rmse:0.80509	validation_1-rmse:0.61140
# [18]	validation_0-rmse:0.78962	validation_1-rmse:0.59923
# [19]	validation_0-rmse:0.77483	validation_1-rmse:0.59306
# [20]	validation_0-rmse:0.76232	validation_1-rmse:0.59106
# [21]	validation_0-rmse:0.75224	validation_1-rmse:0.59840
# [22]	validation_0-rmse:0.74163	validation_1-rmse:0.59306
# [23]	validation_0-rmse:0.73088	validation_1-rmse:0.59144
# [24]	validation_0-rmse:0.72225	validation_1-rmse:0.58814
# [25]	validation_0-rmse:0.71426	validation_1-rmse:0.58517
# [26]	validation_0-rmse:0.70621	validation_1-rmse:0.58598
# [27]	validation_0-rmse:0.69907	validation_1-rmse:0.59124
# [28]	validation_0-rmse:0.69304	validation_1-rmse:0.59642
# [29]	validation_0-rmse:0.68848	validation_1-rmse:0.59313
# [30]	validation_0-rmse:0.67963	validation_1-rmse:0.59356
# [31]	validation_0-rmse:0.67632	validation_1-rmse:0.58926
# [32]	validation_0-rmse:0.66567	validation_1-rmse:0.59209
# [33]	validation_0-rmse:0.66188	validation_1-rmse:0.59442
# [34]	validation_0-rmse:0.65790	validation_1-rmse:0.59724
# [35]	validation_0-rmse:0.65218	validation_1-rmse:0.59653
# [36]	validation_0-rmse:0.64710	validation_1-rmse:0.59790
# [37]	validation_0-rmse:0.64150	validation_1-rmse:0.59686
# [38]	validation_0-rmse:0.63783	validation_1-rmse:0.59665
# [39]	validation_0-rmse:0.63435	validation_1-rmse:0.59790
# [40]	validation_0-rmse:0.63054	validation_1-rmse:0.59462
# [41]	validation_0-rmse:0.62534	validation_1-rmse:0.59691
# [42]	validation_0-rmse:0.62004	validation_1-rmse:0.59760
# [43]	validation_0-rmse:0.61697	validation_1-rmse:0.59840
# [44]	validation_0-rmse:0.61209	validation_1-rmse:0.59645
# [0]	validation_0-rmse:1.82955	validation_1-rmse:1.80408
# [1]	validation_0-rmse:1.68772	validation_1-rmse:1.66490
# [2]	validation_0-rmse:1.55712	validation_1-rmse:1.55333
# [3]	validation_0-rmse:1.44498	validation_1-rmse:1.45070
# [4]	validation_0-rmse:1.34745	validation_1-rmse:1.36164
# [5]	validation_0-rmse:1.25165	validation_1-rmse:1.27802
# [6]	validation_0-rmse:1.17562	validation_1-rmse:1.20883
# [7]	validation_0-rmse:1.10705	validation_1-rmse:1.14345
# [8]	validation_0-rmse:1.04900	validation_1-rmse:1.09275
# [9]	validation_0-rmse:0.99259	validation_1-rmse:1.04833
# [10]	validation_0-rmse:0.94020	validation_1-rmse:1.00168
# [11]	validation_0-rmse:0.90062	validation_1-rmse:0.97097
# [12]	validation_0-rmse:0.86566	validation_1-rmse:0.95406
# [13]	validation_0-rmse:0.83639	validation_1-rmse:0.93114
# [14]	validation_0-rmse:0.80961	validation_1-rmse:0.91125
# [15]	validation_0-rmse:0.78595	validation_1-rmse:0.90157
# [16]	validation_0-rmse:0.76038	validation_1-rmse:0.88482
# [17]	validation_0-rmse:0.74100	validation_1-rmse:0.87312
# [18]	validation_0-rmse:0.72197	validation_1-rmse:0.86154
# [19]	validation_0-rmse:0.71081	validation_1-rmse:0.85275
# [20]	validation_0-rmse:0.69903	validation_1-rmse:0.85154
# [21]	validation_0-rmse:0.68992	validation_1-rmse:0.85206
# [22]	validation_0-rmse:0.68099	validation_1-rmse:0.85815
# [23]	validation_0-rmse:0.67336	validation_1-rmse:0.85176
# [24]	validation_0-rmse:0.66408	validation_1-rmse:0.85115
# [25]	validation_0-rmse:0.65781	validation_1-rmse:0.84749
# [26]	validation_0-rmse:0.65183	validation_1-rmse:0.84697
# [27]	validation_0-rmse:0.64747	validation_1-rmse:0.84835
# [28]	validation_0-rmse:0.64393	validation_1-rmse:0.84607
# [29]	validation_0-rmse:0.63747	validation_1-rmse:0.84765
# [30]	validation_0-rmse:0.63194	validation_1-rmse:0.84407
# [31]	validation_0-rmse:0.62685	validation_1-rmse:0.84665
# [32]	validation_0-rmse:0.62048	validation_1-rmse:0.84726
# [33]	validation_0-rmse:0.61574	validation_1-rmse:0.85127
# [34]	validation_0-rmse:0.60961	validation_1-rmse:0.85163
# [35]	validation_0-rmse:0.60282	validation_1-rmse:0.85612
# [36]	validation_0-rmse:0.60028	validation_1-rmse:0.85687
# [37]	validation_0-rmse:0.59739	validation_1-rmse:0.85557
# [38]	validation_0-rmse:0.59400	validation_1-rmse:0.85577
# [39]	validation_0-rmse:0.59064	validation_1-rmse:0.85708
# [40]	validation_0-rmse:0.58801	validation_1-rmse:0.85987
# [41]	validation_0-rmse:0.58482	validation_1-rmse:0.85876
# [42]	validation_0-rmse:0.58010	validation_1-rmse:0.86483
# [43]	validation_0-rmse:0.57635	validation_1-rmse:0.86578
# [44]	validation_0-rmse:0.57269	validation_1-rmse:0.86758
# [45]	validation_0-rmse:0.56885	validation_1-rmse:0.86834
# [46]	validation_0-rmse:0.56456	validation_1-rmse:0.86748
# [47]	validation_0-rmse:0.56314	validation_1-rmse:0.86644
# [48]	validation_0-rmse:0.56112	validation_1-rmse:0.86761
# [49]	validation_0-rmse:0.55369	validation_1-rmse:0.86476
# [50]	validation_0-rmse:0.55016	validation_1-rmse:0.86062
# [0]	validation_0-rmse:1.85440	validation_1-rmse:1.72445
# [1]	validation_0-rmse:1.70796	validation_1-rmse:1.58540
# [2]	validation_0-rmse:1.57455	validation_1-rmse:1.45200
# [3]	validation_0-rmse:1.45937	validation_1-rmse:1.33961
# [4]	validation_0-rmse:1.35489	validation_1-rmse:1.24851
# [5]	validation_0-rmse:1.26948	validation_1-rmse:1.17151
# [6]	validation_0-rmse:1.18416	validation_1-rmse:1.09614
# [7]	validation_0-rmse:1.11897	validation_1-rmse:1.04686
# [8]	validation_0-rmse:1.06208	validation_1-rmse:0.99715
# [9]	validation_0-rmse:1.00603	validation_1-rmse:0.95062
# [10]	validation_0-rmse:0.95518	validation_1-rmse:0.91557
# [11]	validation_0-rmse:0.91056	validation_1-rmse:0.88296
# [12]	validation_0-rmse:0.87783	validation_1-rmse:0.86747
# [13]	validation_0-rmse:0.84688	validation_1-rmse:0.85144
# [14]	validation_0-rmse:0.81994	validation_1-rmse:0.83753
# [15]	validation_0-rmse:0.79966	validation_1-rmse:0.82965
# [16]	validation_0-rmse:0.78217	validation_1-rmse:0.82560
# [17]	validation_0-rmse:0.76443	validation_1-rmse:0.81721
# [18]	validation_0-rmse:0.75085	validation_1-rmse:0.81502
# [19]	validation_0-rmse:0.74241	validation_1-rmse:0.81481
# [20]	validation_0-rmse:0.72963	validation_1-rmse:0.81712
# [21]	validation_0-rmse:0.72018	validation_1-rmse:0.81450
# [22]	validation_0-rmse:0.71174	validation_1-rmse:0.81164
# [23]	validation_0-rmse:0.70173	validation_1-rmse:0.81292
# [24]	validation_0-rmse:0.69541	validation_1-rmse:0.81424
# [25]	validation_0-rmse:0.68821	validation_1-rmse:0.81335
# [26]	validation_0-rmse:0.68140	validation_1-rmse:0.81299
# [27]	validation_0-rmse:0.67716	validation_1-rmse:0.81497
# [28]	validation_0-rmse:0.66954	validation_1-rmse:0.81701
# [29]	validation_0-rmse:0.66497	validation_1-rmse:0.82066
# [30]	validation_0-rmse:0.66070	validation_1-rmse:0.82419
# [31]	validation_0-rmse:0.65576	validation_1-rmse:0.82730
# [32]	validation_0-rmse:0.64732	validation_1-rmse:0.82577
# [33]	validation_0-rmse:0.64217	validation_1-rmse:0.82023
# [34]	validation_0-rmse:0.63595	validation_1-rmse:0.82063
# [35]	validation_0-rmse:0.63260	validation_1-rmse:0.82169
# [36]	validation_0-rmse:0.62598	validation_1-rmse:0.82671
# [37]	validation_0-rmse:0.62207	validation_1-rmse:0.82902
# [38]	validation_0-rmse:0.61888	validation_1-rmse:0.82794
# [39]	validation_0-rmse:0.61623	validation_1-rmse:0.82754
# [40]	validation_0-rmse:0.61255	validation_1-rmse:0.82667
# [41]	validation_0-rmse:0.60600	validation_1-rmse:0.82311
# [42]	validation_0-rmse:0.60281	validation_1-rmse:0.82138
# [0]	validation_0-rmse:1.80747	validation_1-rmse:1.92403
# [1]	validation_0-rmse:1.66538	validation_1-rmse:1.78364
# [2]	validation_0-rmse:1.54578	validation_1-rmse:1.65557
# [3]	validation_0-rmse:1.43495	validation_1-rmse:1.54164
# [4]	validation_0-rmse:1.33767	validation_1-rmse:1.43934
# [5]	validation_0-rmse:1.25638	validation_1-rmse:1.35991
# [6]	validation_0-rmse:1.18025	validation_1-rmse:1.28195
# [7]	validation_0-rmse:1.10853	validation_1-rmse:1.20253
# [8]	validation_0-rmse:1.05517	validation_1-rmse:1.15021
# [9]	validation_0-rmse:1.00444	validation_1-rmse:1.10006
# [10]	validation_0-rmse:0.95244	validation_1-rmse:1.05048
# [11]	validation_0-rmse:0.91213	validation_1-rmse:1.00769
# [12]	validation_0-rmse:0.88101	validation_1-rmse:0.96941
# [13]	validation_0-rmse:0.85396	validation_1-rmse:0.93565
# [14]	validation_0-rmse:0.82525	validation_1-rmse:0.90939
# [15]	validation_0-rmse:0.80510	validation_1-rmse:0.89244
# [16]	validation_0-rmse:0.78572	validation_1-rmse:0.87140
# [17]	validation_0-rmse:0.76997	validation_1-rmse:0.85517
# [18]	validation_0-rmse:0.75160	validation_1-rmse:0.84006
# [19]	validation_0-rmse:0.73780	validation_1-rmse:0.83253
# [20]	validation_0-rmse:0.72810	validation_1-rmse:0.82599
# [21]	validation_0-rmse:0.71607	validation_1-rmse:0.81442
# [22]	validation_0-rmse:0.70530	validation_1-rmse:0.81206
# [23]	validation_0-rmse:0.69747	validation_1-rmse:0.81149
# [24]	validation_0-rmse:0.68871	validation_1-rmse:0.80429
# [25]	validation_0-rmse:0.67664	validation_1-rmse:0.79823
# [26]	validation_0-rmse:0.66890	validation_1-rmse:0.79684
# [27]	validation_0-rmse:0.66300	validation_1-rmse:0.79648
# [28]	validation_0-rmse:0.65570	validation_1-rmse:0.79458
# [29]	validation_0-rmse:0.65043	validation_1-rmse:0.79302
# [30]	validation_0-rmse:0.64454	validation_1-rmse:0.78688
# [31]	validation_0-rmse:0.64076	validation_1-rmse:0.78255
# [32]	validation_0-rmse:0.63628	validation_1-rmse:0.78515
# [33]	validation_0-rmse:0.63272	validation_1-rmse:0.78298
# [34]	validation_0-rmse:0.62898	validation_1-rmse:0.78378
# [35]	validation_0-rmse:0.62244	validation_1-rmse:0.78334
# [36]	validation_0-rmse:0.61674	validation_1-rmse:0.78431
# [37]	validation_0-rmse:0.61206	validation_1-rmse:0.77970
# [38]	validation_0-rmse:0.60701	validation_1-rmse:0.78368
# [39]	validation_0-rmse:0.59925	validation_1-rmse:0.78454
# [40]	validation_0-rmse:0.59647	validation_1-rmse:0.78531
# [41]	validation_0-rmse:0.59073	validation_1-rmse:0.79026
# [42]	validation_0-rmse:0.58541	validation_1-rmse:0.78822
# [43]	validation_0-rmse:0.58108	validation_1-rmse:0.79023
# [44]	validation_0-rmse:0.57762	validation_1-rmse:0.79169
# [45]	validation_0-rmse:0.57358	validation_1-rmse:0.79172
# [46]	validation_0-rmse:0.56915	validation_1-rmse:0.79439
# [47]	validation_0-rmse:0.56651	validation_1-rmse:0.79172
# [48]	validation_0-rmse:0.56299	validation_1-rmse:0.79567
# [49]	validation_0-rmse:0.56029	validation_1-rmse:0.80011
# [50]	validation_0-rmse:0.55051	validation_1-rmse:0.79742
# [51]	validation_0-rmse:0.54581	validation_1-rmse:0.79530
# [52]	validation_0-rmse:0.54176	validation_1-rmse:0.79428
# [53]	validation_0-rmse:0.53679	validation_1-rmse:0.79231
# [54]	validation_0-rmse:0.53374	validation_1-rmse:0.79185
# [55]	validation_0-rmse:0.53028	validation_1-rmse:0.79571
# [56]	validation_0-rmse:0.52669	validation_1-rmse:0.79563
# [0]	validation_0-rmse:1.80999	validation_1-rmse:1.92969
# [1]	validation_0-rmse:1.66580	validation_1-rmse:1.79416
# [2]	validation_0-rmse:1.54215	validation_1-rmse:1.67642
# [3]	validation_0-rmse:1.42995	validation_1-rmse:1.57244
# [4]	validation_0-rmse:1.33422	validation_1-rmse:1.48120
# [5]	validation_0-rmse:1.24282	validation_1-rmse:1.38798
# [6]	validation_0-rmse:1.16842	validation_1-rmse:1.32441
# [7]	validation_0-rmse:1.09683	validation_1-rmse:1.25722
# [8]	validation_0-rmse:1.03726	validation_1-rmse:1.20223
# [9]	validation_0-rmse:0.98901	validation_1-rmse:1.16102
# [10]	validation_0-rmse:0.94122	validation_1-rmse:1.11923
# [11]	validation_0-rmse:0.89824	validation_1-rmse:1.07958
# ...
# [54]	validation_0-rmse:0.54454	validation_1-rmse:0.91575
# [55]	validation_0-rmse:0.54026	validation_1-rmse:0.92052
# [56]	validation_0-rmse:0.53814	validation_1-rmse:0.91899
# [57]	validation_0-rmse:0.53590	validation_1-rmse:0.91998
# [58]	validation_0-rmse:0.53351	validation_1-rmse:0.91820
# [59]	validation_0-rmse:0.52973	validation_1-rmse:0.92028
# [60]	validation_0-rmse:0.52811	validation_1-rmse:0.91935
# [61]	validation_0-rmse:0.52522	validation_1-rmse:0.91562
# [0]	validation_0-rmse:1.83115	validation_1-rmse:1.81158
# [1]	validation_0-rmse:1.68425	validation_1-rmse:1.66949
# [2]	validation_0-rmse:1.55769	validation_1-rmse:1.55271
# [3]	validation_0-rmse:1.44239	validation_1-rmse:1.44082
# [4]	validation_0-rmse:1.34620	validation_1-rmse:1.34818
# [5]	validation_0-rmse:1.26397	validation_1-rmse:1.27973
# [6]	validation_0-rmse:1.18746	validation_1-rmse:1.20682
# [7]	validation_0-rmse:1.12288	validation_1-rmse:1.13876
# [8]	validation_0-rmse:1.06440	validation_1-rmse:1.07991
# [9]	validation_0-rmse:1.01718	validation_1-rmse:1.04311
# [10]	validation_0-rmse:0.96596	validation_1-rmse:0.99093
# [11]	validation_0-rmse:0.93176	validation_1-rmse:0.95922
# [12]	validation_0-rmse:0.90044	validation_1-rmse:0.92975
# [13]	validation_0-rmse:0.87685	validation_1-rmse:0.90219
# [14]	validation_0-rmse:0.85260	validation_1-rmse:0.88122
# [15]	validation_0-rmse:0.83179	validation_1-rmse:0.85549
# [16]	validation_0-rmse:0.81461	validation_1-rmse:0.83500
# [17]	validation_0-rmse:0.79857	validation_1-rmse:0.82607
# [18]	validation_0-rmse:0.78306	validation_1-rmse:0.81426
# [19]	validation_0-rmse:0.77094	validation_1-rmse:0.81001
# [20]	validation_0-rmse:0.75792	validation_1-rmse:0.80114
# [21]	validation_0-rmse:0.74840	validation_1-rmse:0.78566
# [22]	validation_0-rmse:0.73729	validation_1-rmse:0.77512
# [23]	validation_0-rmse:0.72671	validation_1-rmse:0.77024
# [24]	validation_0-rmse:0.72078	validation_1-rmse:0.76500
# [25]	validation_0-rmse:0.71272	validation_1-rmse:0.76164
# [26]	validation_0-rmse:0.70850	validation_1-rmse:0.75972
# [27]	validation_0-rmse:0.70227	validation_1-rmse:0.76214
# [28]	validation_0-rmse:0.69547	validation_1-rmse:0.76410
# [29]	validation_0-rmse:0.69050	validation_1-rmse:0.76122
# [30]	validation_0-rmse:0.68690	validation_1-rmse:0.76126
# [31]	validation_0-rmse:0.68380	validation_1-rmse:0.75937
# [32]	validation_0-rmse:0.67864	validation_1-rmse:0.75985
# [33]	validation_0-rmse:0.67228	validation_1-rmse:0.75772
# [34]	validation_0-rmse:0.66838	validation_1-rmse:0.75929
# [35]	validation_0-rmse:0.66329	validation_1-rmse:0.76076
# [36]	validation_0-rmse:0.65930	validation_1-rmse:0.75295
# [37]	validation_0-rmse:0.65678	validation_1-rmse:0.75393
# [38]	validation_0-rmse:0.65327	validation_1-rmse:0.75045
# [39]	validation_0-rmse:0.64933	validation_1-rmse:0.74420
# [40]	validation_0-rmse:0.64559	validation_1-rmse:0.73969
# [41]	validation_0-rmse:0.64108	validation_1-rmse:0.73839
# [42]	validation_0-rmse:0.63628	validation_1-rmse:0.73831
# [43]	validation_0-rmse:0.63197	validation_1-rmse:0.74001
# [44]	validation_0-rmse:0.62690	validation_1-rmse:0.73019
# [45]	validation_0-rmse:0.62297	validation_1-rmse:0.72398
# [46]	validation_0-rmse:0.61888	validation_1-rmse:0.72602
# [47]	validation_0-rmse:0.61306	validation_1-rmse:0.71836
# [48]	validation_0-rmse:0.60974	validation_1-rmse:0.71642
# [49]	validation_0-rmse:0.60696	validation_1-rmse:0.71843
# [50]	validation_0-rmse:0.60194	validation_1-rmse:0.71436
# [51]	validation_0-rmse:0.59708	validation_1-rmse:0.71289
# [52]	validation_0-rmse:0.59526	validation_1-rmse:0.71456
# [53]	validation_0-rmse:0.59170	validation_1-rmse:0.71790
# [54]	validation_0-rmse:0.58694	validation_1-rmse:0.71719
# [55]	validation_0-rmse:0.58228	validation_1-rmse:0.71599
# [56]	validation_0-rmse:0.57852	validation_1-rmse:0.71740
# [57]	validation_0-rmse:0.57478	validation_1-rmse:0.71802
# [58]	validation_0-rmse:0.57125	validation_1-rmse:0.71892
# [59]	validation_0-rmse:0.56700	validation_1-rmse:0.71887
# [60]	validation_0-rmse:0.56452	validation_1-rmse:0.71809
# [61]	validation_0-rmse:0.56135	validation_1-rmse:0.71301
# [62]	validation_0-rmse:0.55912	validation_1-rmse:0.71652
# [63]	validation_0-rmse:0.55495	validation_1-rmse:0.71897
# [64]	validation_0-rmse:0.55005	validation_1-rmse:0.71609
# [65]	validation_0-rmse:0.54732	validation_1-rmse:0.71974
# [66]	validation_0-rmse:0.54535	validation_1-rmse:0.72076
# [67]	validation_0-rmse:0.54254	validation_1-rmse:0.72222
# [68]	validation_0-rmse:0.54044	validation_1-rmse:0.72401
# [69]	validation_0-rmse:0.53781	validation_1-rmse:0.72361
# [70]	validation_0-rmse:0.53449	validation_1-rmse:0.72497
# [0]	validation_0-rmse:1.78337	validation_1-rmse:2.04011
# [1]	validation_0-rmse:1.63739	validation_1-rmse:1.90706
# [2]	validation_0-rmse:1.50968	validation_1-rmse:1.77777
# [3]	validation_0-rmse:1.39564	validation_1-rmse:1.67366
# [4]	validation_0-rmse:1.29848	validation_1-rmse:1.58490
# [5]	validation_0-rmse:1.20800	validation_1-rmse:1.49542
# [6]	validation_0-rmse:1.13403	validation_1-rmse:1.43294
# [7]	validation_0-rmse:1.06992	validation_1-rmse:1.37529
# [8]	validation_0-rmse:1.01040	validation_1-rmse:1.32306
# [9]	validation_0-rmse:0.95990	validation_1-rmse:1.27928
# [10]	validation_0-rmse:0.91131	validation_1-rmse:1.22994
# [11]	validation_0-rmse:0.86708	validation_1-rmse:1.18564
# [12]	validation_0-rmse:0.83562	validation_1-rmse:1.15640
# [13]	validation_0-rmse:0.80410	validation_1-rmse:1.12837
# [14]	validation_0-rmse:0.77939	validation_1-rmse:1.10353
# [15]	validation_0-rmse:0.75948	validation_1-rmse:1.08769
# [16]	validation_0-rmse:0.73778	validation_1-rmse:1.06702
# [17]	validation_0-rmse:0.71925	validation_1-rmse:1.05267
# [18]	validation_0-rmse:0.70686	validation_1-rmse:1.04238
# [19]	validation_0-rmse:0.69625	validation_1-rmse:1.03197
# [20]	validation_0-rmse:0.68422	validation_1-rmse:1.02105
# [21]	validation_0-rmse:0.67461	validation_1-rmse:1.01449
# [22]	validation_0-rmse:0.66317	validation_1-rmse:1.00493
# [23]	validation_0-rmse:0.65343	validation_1-rmse:0.99607
# [24]	validation_0-rmse:0.64807	validation_1-rmse:0.99288
# [25]	validation_0-rmse:0.64284	validation_1-rmse:0.98829
# [26]	validation_0-rmse:0.63651	validation_1-rmse:0.98334
# [27]	validation_0-rmse:0.63177	validation_1-rmse:0.98096
# [28]	validation_0-rmse:0.62424	validation_1-rmse:0.97465
# [29]	validation_0-rmse:0.61916	validation_1-rmse:0.97088
# [30]	validation_0-rmse:0.61359	validation_1-rmse:0.96986
# [31]	validation_0-rmse:0.60820	validation_1-rmse:0.96636
# [32]	validation_0-rmse:0.60389	validation_1-rmse:0.96006
# [33]	validation_0-rmse:0.59900	validation_1-rmse:0.95757
# [34]	validation_0-rmse:0.59173	validation_1-rmse:0.95454
# [35]	validation_0-rmse:0.58576	validation_1-rmse:0.95263
# [36]	validation_0-rmse:0.58084	validation_1-rmse:0.95099
# [37]	validation_0-rmse:0.57526	validation_1-rmse:0.94522
# [38]	validation_0-rmse:0.57191	validation_1-rmse:0.94593
# [39]	validation_0-rmse:0.56735	validation_1-rmse:0.94193
# [40]	validation_0-rmse:0.56548	validation_1-rmse:0.94387
# [41]	validation_0-rmse:0.55818	validation_1-rmse:0.93984
# [42]	validation_0-rmse:0.55197	validation_1-rmse:0.93335
# [43]	validation_0-rmse:0.54724	validation_1-rmse:0.92980
# [44]	validation_0-rmse:0.54427	validation_1-rmse:0.92452
# [45]	validation_0-rmse:0.54239	validation_1-rmse:0.92362
# [46]	validation_0-rmse:0.53980	validation_1-rmse:0.92474
# [47]	validation_0-rmse:0.53701	validation_1-rmse:0.92523
# [48]	validation_0-rmse:0.53377	validation_1-rmse:0.92436
# [49]	validation_0-rmse:0.52993	validation_1-rmse:0.92751
# [50]	validation_0-rmse:0.52442	validation_1-rmse:0.92577
# [51]	validation_0-rmse:0.51979	validation_1-rmse:0.92399
# [52]	validation_0-rmse:0.51597	validation_1-rmse:0.92663
# [53]	validation_0-rmse:0.51390	validation_1-rmse:0.92611
# [54]	validation_0-rmse:0.51026	validation_1-rmse:0.92516
# [55]	validation_0-rmse:0.50649	validation_1-rmse:0.92545
# [56]	validation_0-rmse:0.50442	validation_1-rmse:0.92387
# [57]	validation_0-rmse:0.50170	validation_1-rmse:0.92288
# [58]	validation_0-rmse:0.49870	validation_1-rmse:0.92105
# [59]	validation_0-rmse:0.49685	validation_1-rmse:0.92148
# [60]	validation_0-rmse:0.49459	validation_1-rmse:0.92028
# [61]	validation_0-rmse:0.49326	validation_1-rmse:0.92187
# [62]	validation_0-rmse:0.49121	validation_1-rmse:0.92153
# [63]	validation_0-rmse:0.48831	validation_1-rmse:0.92379
# [64]	validation_0-rmse:0.48668	validation_1-rmse:0.92119
# [65]	validation_0-rmse:0.48418	validation_1-rmse:0.91957
# [66]	validation_0-rmse:0.48035	validation_1-rmse:0.92304
# [67]	validation_0-rmse:0.47883	validation_1-rmse:0.92239
# [68]	validation_0-rmse:0.47666	validation_1-rmse:0.92200
# [69]	validation_0-rmse:0.47560	validation_1-rmse:0.92167
# [70]	validation_0-rmse:0.47246	validation_1-rmse:0.91921
# [71]	validation_0-rmse:0.47004	validation_1-rmse:0.92000
# [72]	validation_0-rmse:0.46609	validation_1-rmse:0.92060
# [73]	validation_0-rmse:0.46474	validation_1-rmse:0.92091
# [74]	validation_0-rmse:0.46360	validation_1-rmse:0.92042
# [75]	validation_0-rmse:0.46015	validation_1-rmse:0.92049
# [76]	validation_0-rmse:0.45852	validation_1-rmse:0.91967
# [77]	validation_0-rmse:0.45521	validation_1-rmse:0.91747
# [78]	validation_0-rmse:0.45277	validation_1-rmse:0.91469
# [0]	validation_0-rmse:1.84027	validation_1-rmse:1.78744
# [1]	validation_0-rmse:1.69753	validation_1-rmse:1.66822
# [2]	validation_0-rmse:1.56820	validation_1-rmse:1.55148
# [3]	validation_0-rmse:1.45236	validation_1-rmse:1.44799
# [4]	validation_0-rmse:1.35296	validation_1-rmse:1.36265
# [5]	validation_0-rmse:1.26186	validation_1-rmse:1.28788
# [6]	validation_0-rmse:1.18306	validation_1-rmse:1.21048
# [7]	validation_0-rmse:1.11083	validation_1-rmse:1.14896
# [8]	validation_0-rmse:1.05009	validation_1-rmse:1.10224
# [9]	validation_0-rmse:1.00099	validation_1-rmse:1.06678
# [10]	validation_0-rmse:0.95343	validation_1-rmse:1.03120
# [11]	validation_0-rmse:0.90858	validation_1-rmse:1.00883
# [12]	validation_0-rmse:0.87216	validation_1-rmse:0.98534
# [13]	validation_0-rmse:0.84283	validation_1-rmse:0.97829
# [14]	validation_0-rmse:0.81463	validation_1-rmse:0.96114
# [15]	validation_0-rmse:0.79328	validation_1-rmse:0.95047
# [16]	validation_0-rmse:0.77210	validation_1-rmse:0.93512
# [17]	validation_0-rmse:0.75403	validation_1-rmse:0.92591
# [18]	validation_0-rmse:0.73977	validation_1-rmse:0.91995
# [19]	validation_0-rmse:0.72640	validation_1-rmse:0.90996
# [20]	validation_0-rmse:0.71586	validation_1-rmse:0.90399
# [21]	validation_0-rmse:0.70709	validation_1-rmse:0.90110
# [22]	validation_0-rmse:0.69483	validation_1-rmse:0.90038
# [23]	validation_0-rmse:0.68350	validation_1-rmse:0.90124
# [24]	validation_0-rmse:0.67531	validation_1-rmse:0.89871
# [25]	validation_0-rmse:0.66936	validation_1-rmse:0.90066
# [26]	validation_0-rmse:0.65725	validation_1-rmse:0.88783
# [27]	validation_0-rmse:0.64925	validation_1-rmse:0.88689
# [28]	validation_0-rmse:0.64503	validation_1-rmse:0.88129
# [29]	validation_0-rmse:0.63880	validation_1-rmse:0.88485
# [30]	validation_0-rmse:0.63441	validation_1-rmse:0.88572
# [31]	validation_0-rmse:0.62966	validation_1-rmse:0.88567
# [32]	validation_0-rmse:0.62444	validation_1-rmse:0.88189
# [33]	validation_0-rmse:0.61874	validation_1-rmse:0.88179
# [34]	validation_0-rmse:0.61425	validation_1-rmse:0.88205
# [35]	validation_0-rmse:0.61011	validation_1-rmse:0.87765
# [36]	validation_0-rmse:0.60527	validation_1-rmse:0.87906
# [37]	validation_0-rmse:0.60209	validation_1-rmse:0.88011
# [38]	validation_0-rmse:0.59852	validation_1-rmse:0.87820
# [39]	validation_0-rmse:0.59559	validation_1-rmse:0.87807
# [40]	validation_0-rmse:0.59160	validation_1-rmse:0.87590
# [41]	validation_0-rmse:0.58835	validation_1-rmse:0.87684
# [42]	validation_0-rmse:0.58533	validation_1-rmse:0.87745
# [43]	validation_0-rmse:0.58239	validation_1-rmse:0.87649
# [44]	validation_0-rmse:0.57868	validation_1-rmse:0.87830
# [45]	validation_0-rmse:0.57367	validation_1-rmse:0.87144
# [46]	validation_0-rmse:0.57018	validation_1-rmse:0.86934
# [47]	validation_0-rmse:0.56399	validation_1-rmse:0.86814
# [48]	validation_0-rmse:0.56020	validation_1-rmse:0.86847
# [49]	validation_0-rmse:0.55456	validation_1-rmse:0.86803
# [50]	validation_0-rmse:0.55154	validation_1-rmse:0.86760
# [51]	validation_0-rmse:0.54622	validation_1-rmse:0.86790
# [52]	validation_0-rmse:0.54341	validation_1-rmse:0.86972
# [53]	validation_0-rmse:0.53983	validation_1-rmse:0.87361
# [54]	validation_0-rmse:0.53627	validation_1-rmse:0.87302
# [55]	validation_0-rmse:0.53450	validation_1-rmse:0.87306
# [56]	validation_0-rmse:0.53137	validation_1-rmse:0.87316
# [57]	validation_0-rmse:0.52905	validation_1-rmse:0.87447
# [58]	validation_0-rmse:0.52721	validation_1-rmse:0.87260
# [59]	validation_0-rmse:0.52362	validation_1-rmse:0.87150
# [60]	validation_0-rmse:0.52128	validation_1-rmse:0.87394
# [61]	validation_0-rmse:0.51769	validation_1-rmse:0.87621
# [62]	validation_0-rmse:0.51539	validation_1-rmse:0.87684
# [63]	validation_0-rmse:0.51239	validation_1-rmse:0.87529
# [64]	validation_0-rmse:0.50961	validation_1-rmse:0.87765
# [65]	validation_0-rmse:0.50748	validation_1-rmse:0.87698
# [66]	validation_0-rmse:0.50533	validation_1-rmse:0.87852
# [67]	validation_0-rmse:0.50375	validation_1-rmse:0.87952
# [68]	validation_0-rmse:0.50163	validation_1-rmse:0.87874
# [69]	validation_0-rmse:0.49992	validation_1-rmse:0.88040
# [70]	validation_0-rmse:0.49658	validation_1-rmse:0.88131
# [0]	validation_0-rmse:1.83738	validation_1-rmse:1.79343
# [1]	validation_0-rmse:1.69634	validation_1-rmse:1.65623
# [2]	validation_0-rmse:1.57490	validation_1-rmse:1.54449
# [3]	validation_0-rmse:1.46589	validation_1-rmse:1.44706
# [4]	validation_0-rmse:1.36432	validation_1-rmse:1.34763
# [5]	validation_0-rmse:1.27174	validation_1-rmse:1.25381
# [6]	validation_0-rmse:1.19902	validation_1-rmse:1.19050
# [7]	validation_0-rmse:1.13099	validation_1-rmse:1.12274
# [8]	validation_0-rmse:1.06874	validation_1-rmse:1.07338
# [9]	validation_0-rmse:1.01705	validation_1-rmse:1.02486
# [10]	validation_0-rmse:0.96747	validation_1-rmse:0.98791
# [11]	validation_0-rmse:0.93304	validation_1-rmse:0.95052
# [12]	validation_0-rmse:0.89764	validation_1-rmse:0.92793
# [13]	validation_0-rmse:0.87179	validation_1-rmse:0.90917
# [14]	validation_0-rmse:0.84544	validation_1-rmse:0.89450
# [15]	validation_0-rmse:0.82135	validation_1-rmse:0.88023
# [16]	validation_0-rmse:0.80226	validation_1-rmse:0.86997
# [17]	validation_0-rmse:0.78350	validation_1-rmse:0.86171
# [18]	validation_0-rmse:0.76349	validation_1-rmse:0.84207
# [19]	validation_0-rmse:0.74687	validation_1-rmse:0.82886
# [20]	validation_0-rmse:0.73234	validation_1-rmse:0.82298
# [21]	validation_0-rmse:0.72269	validation_1-rmse:0.81826
# [22]	validation_0-rmse:0.71311	validation_1-rmse:0.81602
# [23]	validation_0-rmse:0.70262	validation_1-rmse:0.81285
# [24]	validation_0-rmse:0.69309	validation_1-rmse:0.81128
# [25]	validation_0-rmse:0.68505	validation_1-rmse:0.80951
# [26]	validation_0-rmse:0.67873	validation_1-rmse:0.80589
# [27]	validation_0-rmse:0.67256	validation_1-rmse:0.80291
# [28]	validation_0-rmse:0.66589	validation_1-rmse:0.79526
# [29]	validation_0-rmse:0.66010	validation_1-rmse:0.79525
# [30]	validation_0-rmse:0.65596	validation_1-rmse:0.79673
# [31]	validation_0-rmse:0.65153	validation_1-rmse:0.79102
# [32]	validation_0-rmse:0.64565	validation_1-rmse:0.79405
# [33]	validation_0-rmse:0.64094	validation_1-rmse:0.79553
# [34]	validation_0-rmse:0.63734	validation_1-rmse:0.79713
# [35]	validation_0-rmse:0.63238	validation_1-rmse:0.79808
# [36]	validation_0-rmse:0.62906	validation_1-rmse:0.79825
# [37]	validation_0-rmse:0.62522	validation_1-rmse:0.79797
# [38]	validation_0-rmse:0.61986	validation_1-rmse:0.80173
# [39]	validation_0-rmse:0.61647	validation_1-rmse:0.80394
# [40]	validation_0-rmse:0.61388	validation_1-rmse:0.80076
# [41]	validation_0-rmse:0.61124	validation_1-rmse:0.80653
# [42]	validation_0-rmse:0.60853	validation_1-rmse:0.80654
# [43]	validation_0-rmse:0.60417	validation_1-rmse:0.80751
# [44]	validation_0-rmse:0.60018	validation_1-rmse:0.81067
# [45]	validation_0-rmse:0.59813	validation_1-rmse:0.81091
# [46]	validation_0-rmse:0.59655	validation_1-rmse:0.81306
# [47]	validation_0-rmse:0.59247	validation_1-rmse:0.81570
# [48]	validation_0-rmse:0.59025	validation_1-rmse:0.81591
# [49]	validation_0-rmse:0.58715	validation_1-rmse:0.82019
# [50]	validation_0-rmse:0.58530	validation_1-rmse:0.82191
# [51]	validation_0-rmse:0.57989	validation_1-rmse:0.81738

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.322
# Uncertainty
# a0: 1.571+/-0.067
# a1: 0.280+/-0.027

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: A_year: mean - 0.083, median - 0.082, CI - [0.058-0.104]
#
# SHAP-values for: D_cm: mean - 0.252, median - 0.252, CI - [0.21-0.301]
#
# SHAP-values for: F_Soil_ID: mean - 0.157, median - 0.16, CI - [0.125-0.189]
#
# SHAP-values for: G_m2_ha: mean - 0.026, median - 0.023, CI - [0.013-0.041]
#
# SHAP-values for: H_m: mean - 0.116, median - 0.111, CI - [0.084-0.152]
#
# SHAP-values for: M_Soil: mean - 0.068, median - 0.067, CI - [0.042-0.092]
#
# SHAP-values for: Origin_ID: mean - 0.054, median - 0.048, CI - [0.03-0.078]
#
# SHAP-values for: Random_col_1: mean - 0.032, median - 0.029, CI - [0.016-0.05]
#
# SHAP-values for: Random_col_2: mean - 0.028, median - 0.027, CI - [0.012-0.044]
#
# SHAP-values for: Random_col_3: mean - 0.022, median - 0.021, CI - [0.015-0.031]
#
# SHAP-values for: Random_col_4: mean - 0.027, median - 0.025, CI - [0.011-0.043]
#
# SHAP-values for: Random_col_5: mean - 0.044, median - 0.044, CI - [0.024-0.06]
#
# SHAP-values for: Species_ID: mean - 0.071, median - 0.074, CI - [0.043-0.096]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['D_cm', 'H_m', 'F_Soil_ID', 'A_year', 
  'Species_ID', 'M_Soil', 'Origin_ID', 'G_m2_ha', 'Random_col_1', 'Random_col_2', 'Random_col_3', 'Random_col_4', 'Random_col_5'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [0, 1, 2, 3, 4, 5])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 5, 10, 20, 50, 100])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../02_output_data/XGBoost_models/03_LN_Tag_Sr_XGB_model_2024_final.json")
# Save to text format
f_xgb_model.save_model("../02_output_data/XGBoost_models/03_LN_Tag_Sr_XGB_model_2024_final.txt")
