# %% [markdown]
# # Processing with biomass data of other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/1_Estimation of tree biomass/FULL_DB_BIOMASS_OTHER_ALL_AUTHORS.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#    Groups Species  Species_ID Origin  Origin_ID  SI  A_years   H_m  DBH_cm  \
# 0       1    Pine           0      n        0.0   4       50   9.7    14.6
# 1       1    Pine           0      n        0.0   2       65  20.6    20.6
# 2       1    Pine           0      n        0.0   2       50  13.6    15.4
# 3       1    Pine           0      n        0.0   1       60  23.3    22.2
# 4       1    Pine           0      n        0.0   3       65  15.6    16.4
#
#    N_trees  RS(P)  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  Stem_wood_t_ha  \
# 0    486.0   0.35         9.7      43.9           18.9             NaN
# 1    785.0   0.70        32.2     254.0          113.1             NaN
# 2   1745.0   0.93        35.2     190.0           87.8             NaN
# 3    665.0   0.62        29.6     277.7          106.5             NaN
# 4    955.0   0.59        20.4     142.5           67.0             NaN
#
#    Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha
# 0             NaN         8.4           1.6
# 1             NaN        11.5           4.1
# 2             NaN        13.7           4.1
# 3             NaN        14.4           5.4
# 4             NaN        14.2           3.4

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['Groups','Species_ID','Origin_ID','SI','A_years','H_m','DBH_cm','RS(P)',
                                    'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
                                    'Crown_t_ha','Foliage_t_ha'])
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Groups  Species_ID  Origin_ID  SI  A_years   H_m  DBH_cm  RS(P)  \
# 0       1           0        0.0   4       50   9.7    14.6   0.35
# 1       1           0        0.0   2       65  20.6    20.6   0.70
# 2       1           0        0.0   2       50  13.6    15.4   0.93
# 3       1           0        0.0   1       60  23.3    22.2   0.62
# 4       1           0        0.0   3       65  15.6    16.4   0.59
#
#    BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  \
# 0         9.7      43.9           18.9             NaN             NaN
# 1        32.2     254.0          113.1             NaN             NaN
# 2        35.2     190.0           87.8             NaN             NaN
# 3        29.6     277.7          106.5             NaN             NaN
# 4        20.4     142.5           67.0             NaN             NaN
#
#    Crown_t_ha  Foliage_t_ha
# 0         8.4           1.6
# 1        11.5           4.1
# 2        13.7           4.1
# 3        14.4           5.4
# 4        14.2           3.4

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Groups          857 non-null    int64
#  1   Species_ID      857 non-null    int64
#  2   Origin_ID       856 non-null    float64
#  3   SI              857 non-null    int64
#  4   A_years         857 non-null    int64
#  5   H_m             857 non-null    float64
#  6   DBH_cm          856 non-null    float64
#  7   RS(P)           854 non-null    float64
#  8   BA_sq_m_ha      857 non-null    float64
#  9   GS_cub_m        857 non-null    float64
#  10  ALL_STEM_t_ha   855 non-null    float64
#  11  Stem_wood_t_ha  747 non-null    float64
#  12  Stem_bark_t_ha  747 non-null    float64
#  13  Crown_t_ha      843 non-null    float64
#  14  Foliage_t_ha    854 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 100.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species","Origin"])["BA_sq_m_ha","H_m"].describe()
# Out:
# <ipython-input-5-aaa965077f06>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Species","Origin"])["BA_sq_m_ha","H_m"].describe()
#                BA_sq_m_ha                                                     \
#                     count       mean        std   min     25%    50%     75%
# Species Origin
# Alder   a            11.0  27.854545   7.162173  20.6  22.050  28.70  31.250
#         n           104.0  26.243269   9.595284   7.3  18.400  25.65  34.100
# Aspen   n            66.0  23.056061   8.684011   6.9  16.550  20.65  28.125
# Birch   a            29.0  21.127586   8.611201   4.4  12.900  21.90  24.700
#         n            90.0  17.817778   7.397397   3.8  12.150  18.35  23.050
# Oak     a             4.0  25.325000   8.932105  17.8  18.475  23.35  30.200
#         n            87.0  27.529885  10.769446   1.7  20.350  30.10  36.300
# Pine    a           195.0  30.469231  10.685416   4.7  23.250  31.10  38.200
#         n           263.0  27.171863  10.774800   1.0  20.500  28.90  35.000
# Spruce  n             7.0  25.028571   7.756656  15.5  18.050  26.80  31.350
#
#                         H_m                                                   \
#                  max  count       mean       std   min     25%    50%    75%
# Species Origin
# Alder   a       43.4   11.0  20.236364  4.157950  15.4  16.000  21.00  22.90
#         n       43.0  104.0  17.056731  4.874339   5.2  13.100  17.40  20.50
# Aspen   n       48.9   66.0  15.024242  6.264161   2.7  10.325  15.30  19.30
# Birch   a       46.3   29.0  16.320690  7.002162   3.6   9.900  19.40  21.20
#         n       36.5   90.0  14.726667  5.990551   5.8   9.200  14.25  19.35
# Oak     a       36.8    4.0  19.350000  4.792703  13.6  16.900  19.40  21.85
#         n       48.1   87.0  20.870115  7.211427   5.0  15.800  21.60  26.00
# Pine    a       51.5  195.0  16.259487  7.553524   3.5  10.350  15.10  21.95
#         n       51.1  263.0  15.555513  7.296750   1.5  10.700  15.20  20.10
# Spruce  n       34.1    7.0  19.357143  8.967507   8.8  12.150  19.40  24.90
#
#
#                  max
# Species Origin
# Alder   a       27.3
#         n       27.3
# Aspen   n       26.0
# Birch   a       26.5
#         n       27.5
# Oak     a       25.0
#         n       33.8
# Pine    a       34.2
#         n       38.3
# Spruce  n       33.2

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = ["ALL_STEM_t_ha"], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      Groups  Species_ID  Origin_ID  SI  A_years   H_m  DBH_cm  RS(P)  \
# 0         1           0        0.0   4       50   9.7    14.6   0.35
# 1         1           0        0.0   2       65  20.6    20.6   0.70
# 2         1           0        0.0   2       50  13.6    15.4   0.93
# 3         1           0        0.0   1       60  23.3    22.2   0.62
# 4         1           0        0.0   3       65  15.6    16.4   0.59
# ..      ...         ...        ...  ..      ...   ...     ...    ...
# 852       2           3        0.0   0        8   7.8     4.4   0.71
# 853       2           3        0.0   0       16  12.7     9.0   0.97
# 854       2           3        0.0   0       15  12.2     8.1   0.99
# 855       2           2        0.0   2       21  14.3    12.4   1.08
# 856       2           2        0.0   1       66  21.1    25.6   0.71
#
#      BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  \
# 0           9.7      43.9           18.9             NaN             NaN
# 1          32.2     254.0          113.1             NaN             NaN
# 2          35.2     190.0           87.8             NaN             NaN
# 3          29.6     277.7          106.5             NaN             NaN
# 4          20.4     142.5           67.0             NaN             NaN
# ..          ...       ...            ...             ...             ...
# 852         9.2      39.8           17.8            15.7             2.1
# 853        20.5     123.6           47.1            42.6             4.5
# 854        20.3     141.7           51.9            47.8             4.1
# 855        25.1     176.5          100.7            84.6            16.1
# 856        21.0     191.6           99.9            80.8            19.1
#
#      Crown_t_ha  Foliage_t_ha
# 0          8.40          1.60
# 1         11.50          4.10
# 2         13.70          4.10
# 3         14.40          5.40
# 4         14.20          3.40
# ..          ...           ...
# 852        2.26          2.04
# 853        2.14          1.21
# 854        2.11          1.16
# 855       16.90          4.74
# 856       16.60          2.13
#
# [855 rows x 15 columns]

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#            Groups  Species_ID   Origin_ID          SI     A_years         H_m  \
# count  855.000000  855.000000  854.000000  855.000000  855.000000  855.000000
# mean     1.375439    1.527485    0.279859    0.835088   44.987135   16.450409
# std      0.484519    1.821387    0.449193    1.638868   32.952433    7.025889
# min      1.000000    0.000000    0.000000   -4.000000    2.000000    1.500000
# 25%      1.000000    0.000000    0.000000    0.000000   23.000000   11.200000
# 50%      1.000000    0.000000    0.000000    1.000000   36.000000   16.100000
# 75%      2.000000    3.000000    1.000000    2.000000   58.000000   21.150000
# max      2.000000    5.000000    1.000000    7.000000  250.000000   38.300000
#
#            DBH_cm       RS(P)  BA_sq_m_ha    GS_cub_m  ALL_STEM_t_ha  \
# count  854.000000  852.000000  855.000000  855.000000     855.000000
# mean    17.115574    0.882711   26.330409  228.928538     102.590877
# std     10.403541    0.289463   10.629943  144.145949      68.758819
# min      1.100000    0.180000    1.000000    2.400000       1.800000
# 25%      9.900000    0.710000   19.000000  116.050000      47.500000
# 50%     15.500000    0.865000   26.800000  206.000000      93.500000
# 75%     22.100000    1.000000   34.450000  319.900000     140.500000
# max     94.000000    2.320000   51.500000  735.000000     363.900000
#
#        Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha
# count      747.000000      747.000000  842.000000    853.000000
# mean        92.779518       12.060107   13.759145      4.749859
# std         61.992238        9.595428   11.429613      2.828206
# min          2.000000        0.300000    0.500000      0.200000
# 25%         42.900000        5.950000    6.605000      2.600000
# 50%         84.600000        9.300000   10.810000      4.300000
# 75%        125.500000       15.300000   16.430000      6.370000
# max        315.200000       65.700000   69.120000     21.730000

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['Species_ID','Origin_ID','H_m','DBH_cm','BA_sq_m_ha'])
y = pd.DataFrame(select, columns= ['ALL_STEM_t_ha'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_value = np.random.normal(10, 2, size=count)
    X['Random_col'] = norm_value
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha
# 0           0        0.0   9.7    14.6         9.7
# 1           0        0.0  20.6    20.6        32.2
# 2           0        0.0  13.6    15.4        35.2
# 3           0        0.0  23.3    22.2        29.6
# 4           0        0.0  15.6    16.4        20.4

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ALL_STEM_t_ha
# 0           18.9
# 1          113.1
# 2           87.8
# 3          106.5
# 4           67.0

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=4, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.9195516436620944, 0.9338055351889146, 0.932893649284728, 0.9169692622935589]
#     Mean: 0.926
#     Std: 0.008
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [19.25689976 15.42951808 16.49861263 16.07529544]
#     Mean: 16.815
#     Std: 1.460
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [10.316668816816026, 11.704069679919803, 10.513767247779347, 10.116250933615815]
#     Mean: 10.663
#     Std: 0.617
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=2000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y, eval_metric="rmse")

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 2000 candidates, totalling 10000 fits
# Model with rank: 1
# Mean validation score: 0.884 (std: 0.063)
# Parameters: {'colsample_bytree': 0.7658578011184654, 'gamma': 0.19219571931631796, 'learning_rate': 0.28748915735552544, 'max_depth': 2, 'n_estimators': 199, 'subsample': 0.9585132255045361}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.36600933, 0.63866391, 0.27347302, ..., 1.28164511, 0.73388243,
#        0.58554063]), 'std_fit_time': array([0.02468408, 0.01322907, 0.00282423, ..., 0.1500606 , 0.0818001 ,
#        0.1484262 ]), 'mean_score_time': array([0.00997248, 0.01013398, 0.00987539, ..., 0.03232594, 0.02133594,
#        0.01661053]), 'std_score_time': array([5.25613427e-05, 3.47437310e-05, 6.54797605e-05, ...,
#        1.73097475e-02, 5.20005467e-03, 5.97480072e-04]), 'param_colsample_bytree': masked_array(data=[0.1252781842185009, 0.5706377364220963,
#                    0.15845099813206326, ..., 0.44928610022072024,
#                    0.12846431511033837, 0.7270371549700757],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.4418804511298934, 0.16646741295707096,
#                    0.3805406674199993, ..., 0.1260023956241056,
#                    0.49134108515712727, 0.13281096443435075],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.23831977699151558, 0.1536935582025393,
#                    0.13613737147236396, ..., 0.09137301309884921,
#                    0.30033598729350564, 0.051985610511118],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[4, 4, 4, ..., 2, 2, 2],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[106, 195, 82, ..., 170, 97, 79],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.9781571339253019, 0.3542005870241042,
#                    0.8152936381581466, ..., 0.8992050404796557,
#                    0.5999235232024576, 0.36838268026862186],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.1252781842185009, 'gamma': 0.4418804511298934, 'learning_rate': 0.23831977699151558, 'max_depth': 4, 'n_estimators': 106, 'subsample': 0.9781571339253019}, {'colsample_bytree': 0.5706377364220963, 'gamma': 0.16646741295707096, 'learning_rate': 0.1536935582025393, 'max_depth': 4, 'n_estimators': 195, 'subsample': 0.3542005870241042}, {'colsample_bytree': 0.15845099813206326, 'gamma': 0.3805406674199993, 'learning_rate': 0.13613737147236396, 'max_depth': 4, 'n_estimators': 82, 'subsample': 0.8152936381581466}, {'colsample_bytree': 0.7630958130355989, 'gamma': 0.430684001675139, 'learning_rate': 0.17771362305079766, 'max_depth': 4, 'n_estimators': 188, 'subsample': 0.3204276078970614}, {'colsample_bytree': 0.46973620393126064, 'gamma': 0.09646554723319944, 'learning_rate': 0.2810374789898702, 'max_depth': 3, 'n_estimators': 180, 'subsample': 0.9714623186436759}, {'colsample_bytree': 0.18260041717241532, 'gamma': 0.19674006831048368, 'learning_rate': 0.16888432791073896, 'max_depth': 4, 'n_estimators': 123, 'subsample': 0.684702899377646}, {'colsample_bytree': 0.23938093625847373, 'gamma': 0.30537253970239353, 'learning_rate': 0.08487734154698329, 'max_depth': 3, 'n_estimators': 112, 'subsample': 0.6465322603714398}, {'colsample_bytree': 0.3795318077091536, 'gamma': 0.29425927442279, 'learning_rate': 0.2350008489210945, 'max_depth': 3, 'n_estimators': 126, 'subsample': 0.5181037639874193}, {'colsample_bytree': 0.24648913579067466, 'gamma': 0.03510715976208273, 'learning_rate': 0.1284221518849749, 'max_depth': 2, 'n_estimators': 185, 'subsample': 0.6957695778338173}, {'colsample_bytree': 0.2379152820885398, 'gamma': 0.4392059288451568, 'learning_rate': 0.19526000459627194, 'max_depth': 4, 'n_estimators': 191, 'subsample': 0.963134886658708}, {'colsample_bytree': 0.3670887519141097, 'gamma': 0.1710267678847593, 'learning_rate': 0.07320756937263545, 'max_depth': 2, 'n_estimators': 95, 'subsample': 0.5885621970458426}, {'colsample_bytree': 0.3695548206050951, 'gamma': 0.3791157742915052, 'learning_rate': 0.2839308688756882, 'max_depth': 2, 'n_estimators': 116, 'subsample': 0.5622020399512593}, {'colsample_bytree': 0.41001926636619246, 'gamma': 0.3016692136581328, 'learning_rate': 0.300728136446416, 'max_depth': 3, 'n_estimators': 188, 'subsample': 0.7094668326997469}, {'colsample_bytree': 0.32684805521881044, 'gamma': 0.09503610128036288, 'learning_rate': 0.10622299199612521, 'max_depth': 4, 'n_estimators': 81, 'subsample': 0.626533256505219}, {'colsample_bytree': 0.7530518728346514, 'gamma': 0.04705923656800337, 'learning_rate': 0.0852604739703377, 'max_depth': 3, 'n_estimators': 113, 'subsample': 0.9330217811174644}, {'colsample_bytree': 0.3179340294161672, 'gamma': 0.406761504453527, 'learning_rate': 0.020880986223910207, 'max_depth': 2, 'n_estimators': 169, 'subsample': 0.550250680788036}, {'colsample_bytree': 0.11406930159022466, 'gamma': 0.3568719896303684, 'learning_rate': 0.06783763659752373, 'max_depth': 3, 'n_estimators': 181, 'subsample': 0.9205066617452962}, {'colsample_bytree': 0.8127139167792388, 'gamma': 0.1651830303820831, 'learning_rate': 0.11556654325529418, 'max_depth': 2, 'n_estimators': 198, 'subsample': 0.7148070983175694}, {'colsample_bytree': 0.8685680008289707, 'gamma': 0.04341526023836978, 'learning_rate': 0.21974331889192913, 'max_depth': 3, 'n_estimators': 167, 'subsample': 0.5279452369233198}, {'colsample_bytree': 0.5293537918278841, 'gamma': 0.10675242895425402, 'learning_rate': 0.20589666402044618, 'max_depth': 4, 'n_estimators': 67, 'subsample': 0.48435767206281005}, {'colsample_bytree': 0.7383546565144007, 'gamma': 0.00990841112740215, 'learning_rate': 0.19684860930963258, 'max_depth': 3, 'n_estimators': 145, 'subsample': 0.9640058425152167}, {'colsample_bytree': 0.44991709819239034, 'gamma': 0.4117100868726494, 'learning_rate': 0.14938559676994725, 'max_depth': 2, 'n_estimators': 146, 'subsample': 0.9633951439108501}, {'colsample_bytree': 0. ...
#        0.78472774]), 'split1_test_score': array([0.90639018, 0.90295095, 0.89172631, ..., 0.92096787, 0.90151932,
#        0.9037707 ]), 'split2_test_score': array([0.71597169, 0.74921436, 0.74299948, ..., 0.72424287, 0.72619796,
#        0.7839939 ]), 'split3_test_score': array([0.79183068, 0.85701369, 0.75448148, ..., 0.86040609, 0.78250656,
#        0.86704762]), 'split4_test_score': array([0.88463397, 0.91590238, 0.86624116, ..., 0.90209465, 0.86396886,
#        0.89407471]), 'mean_test_score': array([0.81234559, 0.84647016, 0.79964161, ..., 0.84530781, 0.81167477,
#        0.84672294]), 'std_test_score': array([0.07242032, 0.0618344 , 0.0654193 , ..., 0.07005009, 0.06280077,
#        0.05232221]), 'rank_test_score': array([1255,  898, 1705, ...,  924, 1262,  887], dtype=int32), 'split0_train_score': array([0.96613383, 0.98340174, 0.94087364, ..., 0.94795948, 0.94103461,
#        0.91241646]), 'split1_train_score': array([0.96795218, 0.98884177, 0.94836506, ..., 0.96399694, 0.94302728,
#        0.93951175]), 'split2_train_score': array([0.97685686, 0.99091943, 0.96080762, ..., 0.97307097, 0.95737435,
#        0.95237922]), 'split3_train_score': array([0.97184933, 0.98767122, 0.95404207, ..., 0.96203396, 0.95068255,
#        0.93523733]), 'split4_train_score': array([0.97107666, 0.98721037, 0.95102481, ..., 0.96272614, 0.94234861,
#        0.9356156 ]), 'mean_train_score': array([0.97077377, 0.9876089 , 0.95102264, ..., 0.9619575 , 0.94689348,
#        0.93503207]), 'std_train_score': array([0.00368084, 0.00246343, 0.00655634, ..., 0.00805245, 0.00623114,
#        0.01290612])}

# %%
# Overwrite parameter data for the next step/stage
p1 = 0.7658578011184654     # colsample_bytree 
p2 = 0.19219571931631796    # gamma
p3 = 0.28748915735552544    # learning_rate
p4 = 2                      # max_depth
p5 = 199                    # n_estimators
p6 = 0.9585132255045361     # subsample

# %% [markdown]
# # Creating a basic XGBoost model

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Generate test and training samples
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Implementation of the scikit-learn API for XGBoost regression
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Show all parameters of XGBoost model
print(xgb_model)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.7658578011184654,
#              enable_categorical=False, eval_metric=['rmse'],
#              gamma=0.19219571931631796, gpu_id=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.28748915735552544,
#              max_delta_step=None, max_depth=2, min_child_weight=None,
#              missing=nan, monotone_constraints=None, n_estimators=199,
#              n_jobs=None, num_parallel_tree=None, predictor=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=0.9585132255045361,
#              tree_method=None, validate_parameters=None, verbosity=None)

# %%
# Fitting the model 
xgb_model.fit(X_train, y_train, early_stopping_rounds=200, eval_set=[(X_train, y_train), (X_test, y_test)])
# learning dynamics
y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:91.12208	validation_1-rmse:94.09275
# [1]	validation_0-rmse:68.86369	validation_1-rmse:71.00311
# [2]	validation_0-rmse:53.91548	validation_1-rmse:56.06518
# [3]	validation_0-rmse:42.02610	validation_1-rmse:43.47883
# [4]	validation_0-rmse:34.86476	validation_1-rmse:35.45795
# [5]	validation_0-rmse:28.96494	validation_1-rmse:29.58319
# [6]	validation_0-rmse:25.10309	validation_1-rmse:25.09215
# [7]	validation_0-rmse:22.45071	validation_1-rmse:22.60612
# [8]	validation_0-rmse:20.93285	validation_1-rmse:20.79385
# [9]	validation_0-rmse:19.91377	validation_1-rmse:19.62995
# [10]	validation_0-rmse:19.05124	validation_1-rmse:18.45822
# [11]	validation_0-rmse:18.25950	validation_1-rmse:17.70141
# [12]	validation_0-rmse:17.95512	validation_1-rmse:17.35833
# [13]	validation_0-rmse:17.72068	validation_1-rmse:17.14832
# [14]	validation_0-rmse:17.47181	validation_1-rmse:16.74171
# [15]	validation_0-rmse:17.12337	validation_1-rmse:16.39946
# [16]	validation_0-rmse:16.79041	validation_1-rmse:16.17957
# [17]	validation_0-rmse:16.56702	validation_1-rmse:15.93916
# [18]	validation_0-rmse:16.40538	validation_1-rmse:15.79295
# [19]	validation_0-rmse:16.32614	validation_1-rmse:15.64348
# [20]	validation_0-rmse:16.19772	validation_1-rmse:15.40544
# [21]	validation_0-rmse:16.06803	validation_1-rmse:15.37849
# [22]	validation_0-rmse:15.95654	validation_1-rmse:15.31193
# [23]	validation_0-rmse:15.80066	validation_1-rmse:15.17710
# [24]	validation_0-rmse:15.74500	validation_1-rmse:15.10222
# [25]	validation_0-rmse:15.66725	validation_1-rmse:15.03171
# [26]	validation_0-rmse:15.57600	validation_1-rmse:14.96206
# [27]	validation_0-rmse:15.47716	validation_1-rmse:14.85900
# [28]	validation_0-rmse:15.35892	validation_1-rmse:14.71811
# [29]	validation_0-rmse:15.24854	validation_1-rmse:14.69926
# [30]	validation_0-rmse:15.19481	validation_1-rmse:14.67313
# [31]	validation_0-rmse:15.13074	validation_1-rmse:14.63028
# [32]	validation_0-rmse:15.04268	validation_1-rmse:14.62998
# [33]	validation_0-rmse:14.96512	validation_1-rmse:14.57716
# [34]	validation_0-rmse:14.79301	validation_1-rmse:14.48040
# [35]	validation_0-rmse:14.73117	validation_1-rmse:14.46417
# [36]	validation_0-rmse:14.63314	validation_1-rmse:14.38985
# [37]	validation_0-rmse:14.55679	validation_1-rmse:14.36663
# [38]	validation_0-rmse:14.50146	validation_1-rmse:14.36645
# [39]	validation_0-rmse:14.39333	validation_1-rmse:14.36367
# [40]	validation_0-rmse:14.27539	validation_1-rmse:14.24711
# [41]	validation_0-rmse:14.18903	validation_1-rmse:14.14634
# [42]	validation_0-rmse:14.04256	validation_1-rmse:14.15502
# [43]	validation_0-rmse:13.92625	validation_1-rmse:14.06816
# [44]	validation_0-rmse:13.88634	validation_1-rmse:14.04519
# [45]	validation_0-rmse:13.82674	validation_1-rmse:14.07760
# [46]	validation_0-rmse:13.75043	validation_1-rmse:14.03699
# [47]	validation_0-rmse:13.71697	validation_1-rmse:14.08450
# [48]	validation_0-rmse:13.63213	validation_1-rmse:14.01908
# [49]	validation_0-rmse:13.57310	validation_1-rmse:13.91554
# [50]	validation_0-rmse:13.53483	validation_1-rmse:13.90774
# [51]	validation_0-rmse:13.48929	validation_1-rmse:13.87097
# [52]	validation_0-rmse:13.41213	validation_1-rmse:13.92709
# [53]	validation_0-rmse:13.32509	validation_1-rmse:13.97888
# [54]	validation_0-rmse:13.16161	validation_1-rmse:13.87865
# [55]	validation_0-rmse:13.10103	validation_1-rmse:13.83388
# [56]	validation_0-rmse:13.09058	validation_1-rmse:13.83880
# [57]	validation_0-rmse:13.07316	validation_1-rmse:13.79412
# [58]	validation_0-rmse:12.98659	validation_1-rmse:13.71022
# [59]	validation_0-rmse:12.90946	validation_1-rmse:13.62865
# [60]	validation_0-rmse:12.88185	validation_1-rmse:13.61397
# [61]	validation_0-rmse:12.78133	validation_1-rmse:13.59604
# [62]	validation_0-rmse:12.74868	validation_1-rmse:13.60134
# [63]	validation_0-rmse:12.67085	validation_1-rmse:13.59013
# [64]	validation_0-rmse:12.56034	validation_1-rmse:13.53192
# [65]	validation_0-rmse:12.49451	validation_1-rmse:13.54607
# [66]	validation_0-rmse:12.41149	validation_1-rmse:13.50198
# [67]	validation_0-rmse:12.40026	validation_1-rmse:13.50554
# [68]	validation_0-rmse:12.38297	validation_1-rmse:13.47588
# [69]	validation_0-rmse:12.34579	validation_1-rmse:13.46876
# [70]	validation_0-rmse:12.31450	validation_1-rmse:13.42987
# [71]	validation_0-rmse:12.28160	validation_1-rmse:13.49535
# [72]	validation_0-rmse:12.24677	validation_1-rmse:13.54816
# [73]	validation_0-rmse:12.18632	validation_1-rmse:13.55067
# [74]	validation_0-rmse:12.14258	validation_1-rmse:13.51728
# [75]	validation_0-rmse:12.12136	validation_1-rmse:13.52712
# [76]	validation_0-rmse:12.09993	validation_1-rmse:13.53300
# [77]	validation_0-rmse:12.02838	validation_1-rmse:13.44321
# [78]	validation_0-rmse:11.97343	validation_1-rmse:13.43000
# [79]	validation_0-rmse:11.91654	validation_1-rmse:13.39136
# [80]	validation_0-rmse:11.86593	validation_1-rmse:13.39502
# [81]	validation_0-rmse:11.80675	validation_1-rmse:13.38947
# [82]	validation_0-rmse:11.78391	validation_1-rmse:13.39693
# [83]	validation_0-rmse:11.71145	validation_1-rmse:13.38554
# [84]	validation_0-rmse:11.70063	validation_1-rmse:13.38488
# [85]	validation_0-rmse:11.66936	validation_1-rmse:13.36628
# [86]	validation_0-rmse:11.60500	validation_1-rmse:13.37664
# [87]	validation_0-rmse:11.57925	validation_1-rmse:13.36093
# [88]	validation_0-rmse:11.56309	validation_1-rmse:13.41133
# [89]	validation_0-rmse:11.55620	validation_1-rmse:13.40861
# [90]	validation_0-rmse:11.54090	validation_1-rmse:13.40895
# [91]	validation_0-rmse:11.51265	validation_1-rmse:13.47113
# [92]	validation_0-rmse:11.48292	validation_1-rmse:13.46010
# [93]	validation_0-rmse:11.43733	validation_1-rmse:13.43556
# [94]	validation_0-rmse:11.37262	validation_1-rmse:13.46521
# [95]	validation_0-rmse:11.36810	validation_1-rmse:13.49009
# [96]	validation_0-rmse:11.33044	validation_1-rmse:13.50202
# [97]	validation_0-rmse:11.32200	validation_1-rmse:13.47235
# [98]	validation_0-rmse:11.29809	validation_1-rmse:13.47626
# [99]	validation_0-rmse:11.28665	validation_1-rmse:13.47748
# [100]	validation_0-rmse:11.23824	validation_1-rmse:13.47137
# [101]	validation_0-rmse:11.22219	validation_1-rmse:13.46837
# [102]	validation_0-rmse:11.21467	validation_1-rmse:13.47255
# [103]	validation_0-rmse:11.14141	validation_1-rmse:13.40806
# [104]	validation_0-rmse:11.10718	validation_1-rmse:13.33657
# [105]	validation_0-rmse:11.07689	validation_1-rmse:13.34447
# [106]	validation_0-rmse:11.05450	validation_1-rmse:13.35065
# [107]	validation_0-rmse:11.03937	validation_1-rmse:13.35296
# [108]	validation_0-rmse:11.03650	validation_1-rmse:13.33964
# [109]	validation_0-rmse:11.00139	validation_1-rmse:13.30545
# [110]	validation_0-rmse:10.97885	validation_1-rmse:13.29069
# [111]	validation_0-rmse:10.92691	validation_1-rmse:13.28957
# [112]	validation_0-rmse:10.89030	validation_1-rmse:13.26472
# [113]	validation_0-rmse:10.85734	validation_1-rmse:13.26373
# [114]	validation_0-rmse:10.84062	validation_1-rmse:13.28296
# [115]	validation_0-rmse:10.82271	validation_1-rmse:13.26826
# [116]	validation_0-rmse:10.80246	validation_1-rmse:13.33442
# [117]	validation_0-rmse:10.76661	validation_1-rmse:13.32582
# [118]	validation_0-rmse:10.71788	validation_1-rmse:13.34417
# [119]	validation_0-rmse:10.68611	validation_1-rmse:13.40866
# [120]	validation_0-rmse:10.63406	validation_1-rmse:13.38852
# [121]	validation_0-rmse:10.62630	validation_1-rmse:13.38392
# [122]	validation_0-rmse:10.59699	validation_1-rmse:13.44214
# [123]	validation_0-rmse:10.57846	validation_1-rmse:13.41628
# [124]	validation_0-rmse:10.56800	validation_1-rmse:13.41253
# [125]	validation_0-rmse:10.54369	validation_1-rmse:13.39086
# [126]	validation_0-rmse:10.52888	validation_1-rmse:13.42317
# [127]	validation_0-rmse:10.50778	validation_1-rmse:13.35568
# [128]	validation_0-rmse:10.47220	validation_1-rmse:13.35722
# [129]	validation_0-rmse:10.46068	validation_1-rmse:13.35773
# [130]	validation_0-rmse:10.42666	validation_1-rmse:13.35274
# [131]	validation_0-rmse:10.41203	validation_1-rmse:13.35240
# [132]	validation_0-rmse:10.38973	validation_1-rmse:13.36395
# [133]	validation_0-rmse:10.36694	validation_1-rmse:13.38500
# [134]	validation_0-rmse:10.34010	validation_1-rmse:13.37964
# [135]	validation_0-rmse:10.33679	validation_1-rmse:13.38160
# [136]	validation_0-rmse:10.32498	validation_1-rmse:13.38946
# [137]	validation_0-rmse:10.32139	validation_1-rmse:13.37488
# [138]	validation_0-rmse:10.29832	validation_1-rmse:13.34252
# [139]	validation_0-rmse:10.27313	validation_1-rmse:13.33034
# [140]	validation_0-rmse:10.25320	validation_1-rmse:13.31954
# [141]	validation_0-rmse:10.22414	validation_1-rmse:13.33980
# [142]	validation_0-rmse:10.20698	validation_1-rmse:13.37115
# [143]	validation_0-rmse:10.17606	validation_1-rmse:13.37326
# [144]	validation_0-rmse:10.14717	validation_1-rmse:13.37371
# [145]	validation_0-rmse:10.11674	validation_1-rmse:13.34086
# [146]	validation_0-rmse:10.09847	validation_1-rmse:13.37059
# [147]	validation_0-rmse:10.08981	validation_1-rmse:13.36286
# [148]	validation_0-rmse:10.06943	validation_1-rmse:13.38496
# [149]	validation_0-rmse:10.04398	validation_1-rmse:13.39966
# [150]	validation_0-rmse:9.99430	validation_1-rmse:13.40869
# [151]	validation_0-rmse:9.98084	validation_1-rmse:13.40743
# [152]	validation_0-rmse:9.95481	validation_1-rmse:13.39512
# [153]	validation_0-rmse:9.95030	validation_1-rmse:13.36853
# [154]	validation_0-rmse:9.92467	validation_1-rmse:13.30569
# [155]	validation_0-rmse:9.91592	validation_1-rmse:13.30361
# [156]	validation_0-rmse:9.91269	validation_1-rmse:13.26700
# [157]	validation_0-rmse:9.91069	validation_1-rmse:13.25302
# [158]	validation_0-rmse:9.89938	validation_1-rmse:13.23976
# [159]	validation_0-rmse:9.87452	validation_1-rmse:13.26657
# [160]	validation_0-rmse:9.86862	validation_1-rmse:13.29039
# [161]	validation_0-rmse:9.86106	validation_1-rmse:13.29699
# [162]	validation_0-rmse:9.84105	validation_1-rmse:13.32136
# [163]	validation_0-rmse:9.81253	validation_1-rmse:13.37209
# [164]	validation_0-rmse:9.79778	validation_1-rmse:13.37581
# [165]	validation_0-rmse:9.76192	validation_1-rmse:13.37660
# [166]	validation_0-rmse:9.72371	validation_1-rmse:13.40901
# [167]	validation_0-rmse:9.70338	validation_1-rmse:13.45215
# [168]	validation_0-rmse:9.67487	validation_1-rmse:13.46014
# [169]	validation_0-rmse:9.66639	validation_1-rmse:13.46085
# [170]	validation_0-rmse:9.65076	validation_1-rmse:13.47293
# [171]	validation_0-rmse:9.63890	validation_1-rmse:13.41544
# [172]	validation_0-rmse:9.62199	validation_1-rmse:13.40992
# [173]	validation_0-rmse:9.61119	validation_1-rmse:13.40477
# [174]	validation_0-rmse:9.59405	validation_1-rmse:13.38747
# [175]	validation_0-rmse:9.57310	validation_1-rmse:13.40187
# [176]	validation_0-rmse:9.56360	validation_1-rmse:13.39462
# [177]	validation_0-rmse:9.55297	validation_1-rmse:13.37678
# [178]	validation_0-rmse:9.53074	validation_1-rmse:13.37606
# [179]	validation_0-rmse:9.50006	validation_1-rmse:13.37885
# [180]	validation_0-rmse:9.48289	validation_1-rmse:13.37427
# [181]	validation_0-rmse:9.44005	validation_1-rmse:13.41858
# [182]	validation_0-rmse:9.43384	validation_1-rmse:13.41857
# [183]	validation_0-rmse:9.41393	validation_1-rmse:13.41865
# [184]	validation_0-rmse:9.39481	validation_1-rmse:13.48188
# [185]	validation_0-rmse:9.38730	validation_1-rmse:13.48269
# [186]	validation_0-rmse:9.35857	validation_1-rmse:13.48366
# [187]	validation_0-rmse:9.33591	validation_1-rmse:13.48096
# [188]	validation_0-rmse:9.33055	validation_1-rmse:13.50011
# [189]	validation_0-rmse:9.31758	validation_1-rmse:13.49566
# [190]	validation_0-rmse:9.31180	validation_1-rmse:13.49300
# [191]	validation_0-rmse:9.29285	validation_1-rmse:13.48782
# [192]	validation_0-rmse:9.27706	validation_1-rmse:13.53059
# [193]	validation_0-rmse:9.25176	validation_1-rmse:13.53321
# [194]	validation_0-rmse:9.24352	validation_1-rmse:13.52828
# [195]	validation_0-rmse:9.23450	validation_1-rmse:13.54032
# [196]	validation_0-rmse:9.21442	validation_1-rmse:13.55191
# [197]	validation_0-rmse:9.20228	validation_1-rmse:13.60267
# [198]	validation_0-rmse:9.18125	validation_1-rmse:13.60725

# %%
# Iteration with the best result
optimal_n= xgb_model.best_ntree_limit-1
print("The best iteration: " + str(optimal_n))
# Out:
# The best iteration: 158

# %%
# Preparing data for building a learning graph
results = xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(results['validation_0']['rmse'], label='Train')
plt.plot(results['validation_1']['rmse'], label='Test')
plt.axvline(optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a basic XGBoost model

# %%
# Convert data to 'array' type
conv_y_pred = pd.DataFrame(y_pred) # Double transformation
y_pred2 = conv_y_pred.values
y_test2 = y_test.values

# Intermediate results
n_sample = len(y_pred2)
main_sample = y_test.sum() / n_sample

# Calculation of bias
diff = y_pred2 - y_test2
bias = diff.sum()
print('Bias: %.1f' % (bias/n_sample))
print("Relative bias(%):", " %.2f" % (bias/main_sample))

# Calculation of RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %.1f" % (rmse))
print("Relative RMSE(%):", " %.3f" % (rmse/main_sample))

# Calculation of MSE
mse = mean_squared_error(y_test, y_pred)
print("MSE: %.1f" % (mse))

# Calculation of Square R
R_square = r2_score(y_test, y_pred)
print("R square: %.1f%%" % (R_square * 100.0))
# Out:
# Bias: -1.0
# Relative bias(%):  -1.75
# RMSE: 13.2
# Relative RMSE(%):  0.129
# MSE: 175.3
# R square: 96.6%

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(y_test)
x_test_convert = np.array([None]*n_sample)
for i in range(n_sample):
    x_test_convert[i] = np.float(x_test_conv[i])

x_plot = x_test_convert
y_plot = y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 2.712
# a1: 0.963
# R^2: 0.967
# Uncertainty
# a0: 2.7+/-1.7
# a1: 0.963+/-0.014

# %%
# Comparison of training and testing prediction values for XGBoost model 
y_pred_train = xgb_model.predict(X_train, ntree_limit=xgb_model.best_ntree_limit)

plt.figure(figsize =(8, 5))
plt.scatter(y_train, y_pred_train, alpha=0.5, label='Training data')
plt.scatter(y_test, y_pred, s = 5, c = "red", label='Validation (test) data')
plt.xlabel('Obs.')
plt.ylabel('Predict')
plt.legend(loc='best')
# Out:
# /home/dima/anaconda3/lib/python3.8/site-packages/xgboost/core.py:105: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(xgb_model,num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, X_train, color=shap_values)

# %% [markdown]
# # Testing model on new data

# %%
# Load new data (typing)
sp = input('Typing species name - Pine, Spruce, Birch, Alder, Aspen or Oak:')
if sp == 'Pine':
    sdID = 0
    print ('You typed "Pine".')
elif sp == 'Spruce':
    sdID = 1
    print ('You typed "Spruce".')
elif sp == 'Birch':
    sdID = 2
    print ('You typed "Birch".')
elif sp == 'Alder':
    sdID = 3
    print ('You typed "Alder".')
elif sp == 'Aspen':
    sdID = 4
    print ('You typed "Aspen".')
elif sp == 'Oak':
    sdID = 5
    print ('You typed "Oak".')
elif sp != 'Pine' or 'Spruce' or 'Birch' or 'Alder' or 'Aspen' or 'Oak':
    print ('No correctly specie name!')
else:
    print('\nTyping mistake!!!')

ori = input('Typing origin: n - nutural, a - artificial:')
if ori == 'n':
    orID = 0
    print ('You typed "n".')
elif ori == 'a':
    orID = 1
    print ('You typed "a".')
else:
    print('\nTyping mistake!!!')
    
dbh = float(input('Typing DBH (cm):'))

h = float(input('Typing H (m):'))

ba = float(input('Typing BA(or G) (sq.m/ha):'))

# Create new dataframe
new_data = []
new_data.append([sdID, orID, h, dbh, ba])
new_X = pd.DataFrame(new_data, columns=['Species_ID', 'Origin_ID', 'H_m', 'DBH_cm', 'BA_sq_m_sq_m'])

# Present the result based on the entered data
y_pred_new = xgb_model.predict(new_X)
out0 = str(y_pred_new)
out = out0[1:6]
print('\n', 20*'-', '\n Output result: ' + out)
# Out:
# Typing species name - Pine, Spruce, Birch, Alder, Aspen or Oak: Spruce
# You typed "Spruce".
# Typing origin: n - nutural, a - artificial: a
# You typed "a".
# Typing DBH (cm): 1
# Typing H (m): 1
# Typing BA(or G) (sq.m/ha): 10
#  --------------------
#  Output result: 12.26

# %% [markdown]
# # Save XGBoost model

# %%
# Save to JSON
xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/1_Estimation of tree biomass/xgb_model_M_all_stem.json")
# Save to text format
xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/1_Estimation of tree biomass/xgb_model_M_all_stem.txt")
