# %% [markdown]
# ## Processing with RN data obtained from forest sites

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../02_input_data/RN_sites_data.xlsx'
df = pd.read_excel(site_data, sheet_name='RN_filtration_data')
df.head()
# Out:
#    Ідентифікатор    Site # Species  Species_ID  Ntrees at site  % composition  \
# 0             81  001_2021    Pine           0              23     100.000000
# 1            219  002_2021    Pine           0              60      90.178571
# 2            224  003_2021    Pine           0              44     100.000000
# 3            228  004_2021    Pine           0              23     100.000000
# 4            232  005_2021    Pine           0              26     100.000000
#
#         D_cm        H_m    G_m2_ha  N_ha  ...   T_ag_Cs  ln_T_ag_Cs  \
# 0  26.060965  25.423284  49.081648   920  ...  0.781087   -0.247069
# 1   4.303100   4.705979   8.731641  6000  ...  1.549336    0.437826
# 2  28.142898  27.556869  54.703060   880  ...  0.583447   -0.538802
# 3  14.953551   8.506028  40.420188  2300  ...  0.145072   -1.930528
# 4   7.208435   3.425669   2.120687   520  ...  0.254295   -1.369259
#
#      T_ag_Sr  ln_T_ag_Sr  AEDR_count AEDR_mean  AEDR_median  AEDR_std  \
# 0   9.004084    2.197678          26  3.524231        3.530  0.235489
# 1  24.247024    3.188294          15  3.830667        3.780  0.166272
# 2   9.304047    2.230449          28  0.483571        0.475  0.068931
# 3   5.279971    1.663921          20  0.364500        0.365  0.029576
# 4   6.629225    1.891488          18  0.333333        0.345  0.036515
#
#    Distance_km  Azimuth
# 0     5.926403      249
# 1     6.018960      249
# 2    13.046428      189
# 3    12.741627      189
# 4    12.893213      189
#
# [5 rows x 51 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Species', 'Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
#                                     'Origin', 'Origin_ID','A_year', 'D_live_cm', 'H_live_m', 'G_live_m2_ha',
#                                     'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
#                                     'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_A_Cs', 'ln_A_Sr',
#                                     'T_ag_Cs', 'ln_T_ag_Cs', 'T_ag_Sr', 'ln_T_ag_Sr'
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species', 'Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
                                    'Origin', 'Origin_ID','A_year',
                                    'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
                                    'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_A_Cs', 'ln_A_Sr', 
                                    'ln_T_ag_Cs', 'ln_T_ag_Sr'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#   Species  Species_ID  % composition       D_cm        H_m    G_m2_ha Origin  \
# 0    Pine           0     100.000000  26.060965  25.423284  49.081648      a
# 1    Pine           0      90.178571   4.303100   4.705979   8.731641      n
# 2    Pine           0     100.000000  28.142898  27.556869  54.703060      n
# 3    Pine           0     100.000000  14.953551   8.506028  40.420188      n
# 4    Pine           0     100.000000   7.208435   3.425669   2.120687      n
#
#    Origin_ID  A_year  F_Soil_ID  M_Soil  AEDR_mean  Distance_km  Azimuth  \
# 0          1      68          1       2   3.524231     5.926403      249
# 1          0      15          1       2   3.830667     6.018960      249
# 2          0      69          1       2   0.483571    13.046428      189
# 3          0      15          2       2   0.364500    12.741627      189
# 4          0      10          2       2   0.333333    12.893213      189
#
#    Cs_2021_kBq_m  Sr_2021_kBq_m   ln_A_Cs    ln_A_Sr  ln_T_ag_Cs  ln_T_ag_Sr
# 0    2842.194109     998.435843  7.705262   9.103868   -0.247069    2.197678
# 1    2930.287815     987.750099  8.420682  10.083724    0.437826    3.188294
# 2     281.088291      65.777826  5.099866   6.416732   -0.538802    2.230449
# 3     289.512268      69.886752  3.737670   5.910797   -1.930528    1.663921
# 4     287.067816      69.993095  4.290459   6.139885   -1.369259    1.891488

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Species        209 non-null    object
#  1   Species_ID     209 non-null    int64
#  2   % composition  209 non-null    float64
#  3   D_cm           209 non-null    float64
#  4   H_m            209 non-null    float64
#  5   G_m2_ha        209 non-null    float64
#  6   Origin         209 non-null    object
#  7   Origin_ID      209 non-null    int64
#  8   A_year         209 non-null    int64
#  9   F_Soil_ID      209 non-null    int64
#  10  M_Soil         209 non-null    int64
#  11  AEDR_mean      209 non-null    float64
#  12  Distance_km    209 non-null    float64
#  13  Azimuth        209 non-null    int64
#  14  Cs_2021_kBq_m  209 non-null    float64
#  15  Sr_2021_kBq_m  209 non-null    float64
#  16  ln_A_Cs        209 non-null    float64
#  17  ln_A_Sr        209 non-null    float64
#  18  ln_T_ag_Cs     209 non-null    float64
#  19  ln_T_ag_Sr     209 non-null    float64
# dtypes: float64(12), int64(6), object(2)
# memory usage: 32.8+ KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species"])["ln_A_Cs", "ln_A_Sr"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#         ln_A_Cs                                                              \
#           count      mean       std       min       25%       50%       75%
# Species
# Alder      13.0  6.249674  1.661129  3.295837  5.840642  6.040255  6.940222
# Aspen       9.0  5.584313  3.039601  2.708050  3.295837  4.204693  6.729824
# Birch      45.0  5.737563  2.249143  2.079442  3.761200  6.173786  7.229839
# Oak         7.0  6.900674  2.917841  2.397895  4.966038  7.753624  9.021902
# Pine      130.0  6.066275  1.963371  1.504077  4.358932  6.564371  7.374614
# Red oak     3.0  3.445685  0.588708  2.833213  3.164860  3.496508  3.751920
# Robinia     1.0  4.394449       NaN  4.394449  4.394449  4.394449  4.394449
# Spruce      1.0  5.176150       NaN  5.176150  5.176150  5.176150  5.176150
#
#                    ln_A_Sr                                                    \
#                max   count      mean       std       min       25%       50%
# Species
# Alder     9.287301    13.0  6.055811  1.449620  4.094345  4.442651  6.302619
# Aspen    11.366743     9.0  7.575485  2.597130  4.615121  5.209486  7.870930
# Birch    10.332018    45.0  7.671630  2.317833  2.660260  5.752573  7.749322
# Oak      10.177324     7.0  7.188390  2.638333  3.871201  5.248545  7.766417
# Pine     10.468801   130.0  7.470846  1.889243  2.406945  6.165469  7.588295
# Red oak   4.007333     3.0  4.697638  0.334751  4.418841  4.512005  4.605170
# Robinia   4.394449     1.0  7.265430       NaN  7.265430  7.265430  7.265430
# Spruce    5.176150     1.0  7.783224       NaN  7.783224  7.783224  7.783224
#
#
#               75%        max
# Species
# Alder    7.286192   7.649693
# Aspen    8.881836  11.180246
# Birch    8.995909  13.864301
# Oak      8.529114  11.125791
# Pine     8.730280  12.687263
# Red oak  4.837037   5.068904
# Robinia  7.265430   7.265430
# Spruce   7.783224   7.783224

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID  % composition        D_cm         H_m     G_m2_ha  \
# count  209.000000     209.000000  209.000000  209.000000  209.000000
# mean     1.057416      94.337925   17.770981   16.978858   30.000765
# std      1.524339      14.155594    8.921738    6.832292   15.907971
# min      0.000000      20.805369    1.914854    2.704460    0.259356
# 25%      0.000000      96.775081   11.601519   12.401789   17.519173
# 50%      0.000000     100.000000   16.817809   17.466646   30.845307
# 75%      2.000000     100.000000   22.264253   21.414562   42.817263
# max      5.000000     100.000000   52.228464   34.048688   66.922093
#
#         Origin_ID      A_year   F_Soil_ID      M_Soil   AEDR_mean  \
# count  209.000000  209.000000  209.000000  209.000000  209.000000
# mean     0.454545   47.464115    1.918660    2.220096    2.526858
# std      0.499125   24.724635    0.634039    0.692944    4.756383
# min      0.000000   10.000000    1.000000    0.000000    0.110000
# 25%      0.000000   30.000000    2.000000    2.000000    0.460000
# 50%      0.000000   45.000000    2.000000    2.000000    0.756000
# 75%      1.000000   60.000000    2.000000    3.000000    2.401667
# max      1.000000  150.000000    3.000000    4.000000   36.591739
#
#        Distance_km     Azimuth  Cs_2021_kBq_m  Sr_2021_kBq_m     ln_A_Cs  \
# count   209.000000  209.000000     209.000000     209.000000  209.000000
# mean     14.640059  174.296651    2040.059453     670.875816    5.964225
# std      12.363729   99.912885    3821.573719    1529.917216    2.095016
# min       3.998568    9.000000      28.815348       2.402062    1.504077
# 25%       6.562497   56.000000     446.906289      44.007562    4.110874
# 50%       9.203749  189.000000     708.799781     187.465954    6.309918
# 75%      20.865459  261.000000    1940.992207     442.523198    7.306531
# max      57.286577  342.000000   25173.384978   10477.431302   11.366743
#
#           ln_A_Sr  ln_T_ag_Cs  ln_T_ag_Sr
# count  209.000000  209.000000  209.000000
# mean     7.381811   -0.640088    2.317915
# std      2.042856    1.288804    0.931775
# min      2.406945   -4.677466   -0.222660
# 25%      5.752573   -1.390832    1.734814
# 50%      7.506592   -0.504711    2.420262
# 75%      8.846497    0.338120    2.967019
# max     13.864301    1.651960    4.658771

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_A_Cs"
indep_variables = ['Species_ID', 'D_cm', 'H_m', 'G_m2_ha', 'A_year', 'F_Soil_ID', 'AEDR_mean']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#     Species  Species_ID  % composition       D_cm        H_m    G_m2_ha  \
# 0      Pine           0     100.000000  26.060965  25.423284  49.081648
# 1      Pine           0      90.178571   4.303100   4.705979   8.731641
# 2      Pine           0     100.000000  28.142898  27.556869  54.703060
# 3      Pine           0     100.000000  14.953551   8.506028  40.420188
# 4      Pine           0     100.000000   7.208435   3.425669   2.120687
# ..      ...         ...            ...        ...        ...        ...
# 204   Aspen           4      99.930119  11.401754  14.676282  17.972410
# 205   Birch           2     100.000000   7.912790  13.818368  19.279495
# 206    Pine           0     100.000000  16.041613  17.515821  31.533411
# 207    Pine           0      96.775081  14.946465  18.178975  44.220927
# 208    Pine           0     100.000000  15.387224  17.673021  55.824342
#
#     Origin  Origin_ID  A_year  F_Soil_ID  M_Soil  AEDR_mean  Distance_km  \
# 0        a          1      68          1       2   3.524231     5.926403
# 1        n          0      15          1       2   3.830667     6.018960
# 2        n          0      69          1       2   0.483571    13.046428
# 3        n          0      15          2       2   0.364500    12.741627
# 4        n          0      10          2       2   0.333333    12.893213
# ..     ...        ...     ...        ...     ...        ...          ...
# 204      n          0      25          2       3  20.051250     5.190617
# 205      n          0      18          2       3  14.987391     4.749715
# 206      a          1      58          1       2   0.650000     7.850538
# 207      a          1      60          1       2   0.649063     7.276525
# 208      a          1      40          1       2   0.628214     7.292122
#
#      Azimuth  Cs_2021_kBq_m  Sr_2021_kBq_m    ln_A_Cs    ln_A_Sr  ln_T_ag_Cs  \
# 0        249    2842.194109     998.435843   7.705262   9.103868   -0.247069
# 1        249    2930.287815     987.750099   8.420682  10.083724    0.437826
# 2        189     281.088291      65.777826   5.099866   6.416732   -0.538802
# 3        189     289.512268      69.886752   3.737670   5.910797   -1.930528
# 4        189     287.067816      69.993095   4.290459   6.139885   -1.369259
# ..       ...            ...            ...        ...        ...         ...
# 204      265   18333.074578    7311.788354  11.366743  11.089805    1.550281
# 205      262   22082.849575    8387.428089   9.539644  11.501865   -0.462912
# 206      106     539.850835     148.369587   6.498282   8.283999    0.206989
# 207       85     519.756852     136.839876   6.720220   8.575462    0.466859
# 208       86     518.079556     135.439932   6.674561   8.216088    0.424433
#
#      ln_T_ag_Sr
# 0      2.197678
# 1      3.188294
# 2      2.230449
# 3      1.663921
# 4      1.891488
# ..          ...
# 204    2.192562
# 205    2.467375
# 206    3.284293
# 207    3.656651
# 208    3.307560
#
# [209 rows x 20 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID       D_cm        H_m    G_m2_ha  A_year  F_Soil_ID  AEDR_mean
# 0           0  26.060965  25.423284  49.081648      68          1   3.524231
# 1           0   4.303100   4.705979   8.731641      15          1   3.830667
# 2           0  28.142898  27.556869  54.703060      69          1   0.483571
# 3           0  14.953551   8.506028  40.420188      15          2   0.364500
# 4           0   7.208435   3.425669   2.120687      10          2   0.333333

# %%
# Columns in "y" data collections
y.head()
# Out:
#     ln_A_Cs
# 0  7.705262
# 1  8.420682
# 2  5.099866
# 3  3.737670
# 4  4.290459

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.6636828229960756, 0.8176004325311712, 0.5000248454492509]
#     Mean: 0.660
#     Std: 0.130
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.1434665  1.00276228 1.06825701]
#     Mean: 1.071
#     Std: 0.057
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.838294855014213, 0.7944475652933676, 0.8859050520406886]
#     Mean: 0.840
#     Std: 0.037
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.6770642459868581                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.1863184876162866                 # gamma
print('Gamma: ' + str(p2))

p3 = 0.1354475314452787                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 3            # max_depth
print('Max_depth: ' + str(p4))

p5 = 159         # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.9411648912889603                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.6770642459868581
# Gamma: 0.1863184876162866
# Learning_rate: 0.1354475314452787
# Max_depth: 3
# N_estimators: 159
# Subsample: 0.9411648912889603

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(20):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    exp_R_square = r2_score(exp_y_test, exp_y_pred)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:5.15559	validation_1-rmse:5.20006
# [1]	validation_0-rmse:4.56563	validation_1-rmse:4.60786
# [2]	validation_0-rmse:4.00142	validation_1-rmse:4.10899
# [3]	validation_0-rmse:3.56889	validation_1-rmse:3.68079
# [4]	validation_0-rmse:3.20677	validation_1-rmse:3.32962
# [5]	validation_0-rmse:2.89433	validation_1-rmse:3.02574
# [6]	validation_0-rmse:2.63086	validation_1-rmse:2.76195
# [7]	validation_0-rmse:2.33200	validation_1-rmse:2.51876
# [8]	validation_0-rmse:2.14045	validation_1-rmse:2.33419
# [9]	validation_0-rmse:1.91168	validation_1-rmse:2.12940
# [10]	validation_0-rmse:1.77885	validation_1-rmse:2.00802
# [11]	validation_0-rmse:1.59464	validation_1-rmse:1.84560
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [12]	validation_0-rmse:1.49066	validation_1-rmse:1.74527
# [13]	validation_0-rmse:1.35321	validation_1-rmse:1.64334
# [14]	validation_0-rmse:1.28035	validation_1-rmse:1.57466
# [15]	validation_0-rmse:1.16429	validation_1-rmse:1.47459
# [16]	validation_0-rmse:1.07269	validation_1-rmse:1.40373
# [17]	validation_0-rmse:1.02148	validation_1-rmse:1.36097
# [18]	validation_0-rmse:0.98264	validation_1-rmse:1.32300
# [19]	validation_0-rmse:0.95246	validation_1-rmse:1.29045
# [20]	validation_0-rmse:0.92382	validation_1-rmse:1.27394
# [21]	validation_0-rmse:0.86553	validation_1-rmse:1.23426
# [22]	validation_0-rmse:0.81185	validation_1-rmse:1.20333
# [23]	validation_0-rmse:0.79317	validation_1-rmse:1.19753
# [24]	validation_0-rmse:0.75428	validation_1-rmse:1.17041
# [25]	validation_0-rmse:0.72643	validation_1-rmse:1.16131
# [26]	validation_0-rmse:0.69103	validation_1-rmse:1.14060
# [27]	validation_0-rmse:0.66217	validation_1-rmse:1.13088
# [28]	validation_0-rmse:0.64420	validation_1-rmse:1.11709
# [29]	validation_0-rmse:0.62427	validation_1-rmse:1.10231
# [30]	validation_0-rmse:0.61016	validation_1-rmse:1.09797
# [31]	validation_0-rmse:0.59514	validation_1-rmse:1.08683
# [32]	validation_0-rmse:0.58296	validation_1-rmse:1.07769
# [33]	validation_0-rmse:0.57112	validation_1-rmse:1.06879
# [34]	validation_0-rmse:0.55726	validation_1-rmse:1.06314
# [35]	validation_0-rmse:0.54402	validation_1-rmse:1.05317
# [36]	validation_0-rmse:0.53456	validation_1-rmse:1.04986
# [37]	validation_0-rmse:0.52240	validation_1-rmse:1.04490
# [38]	validation_0-rmse:0.51083	validation_1-rmse:1.04470
# [39]	validation_0-rmse:0.50143	validation_1-rmse:1.04041
# [40]	validation_0-rmse:0.49073	validation_1-rmse:1.03459
# [41]	validation_0-rmse:0.48378	validation_1-rmse:1.03013
# [42]	validation_0-rmse:0.47728	validation_1-rmse:1.02842
# [43]	validation_0-rmse:0.46926	validation_1-rmse:1.02631
# [44]	validation_0-rmse:0.46500	validation_1-rmse:1.02729
# [45]	validation_0-rmse:0.46107	validation_1-rmse:1.02687
# [46]	validation_0-rmse:0.45798	validation_1-rmse:1.02655
# [47]	validation_0-rmse:0.45439	validation_1-rmse:1.02689
# [48]	validation_0-rmse:0.45162	validation_1-rmse:1.02740
# [49]	validation_0-rmse:0.44215	validation_1-rmse:1.02563
# [50]	validation_0-rmse:0.43636	validation_1-rmse:1.02650
# [51]	validation_0-rmse:0.43316	validation_1-rmse:1.02786
# [52]	validation_0-rmse:0.42869	validation_1-rmse:1.02573
# [53]	validation_0-rmse:0.42601	validation_1-rmse:1.02526
# [54]	validation_0-rmse:0.42258	validation_1-rmse:1.02373
# [55]	validation_0-rmse:0.42046	validation_1-rmse:1.02370
# [56]	validation_0-rmse:0.41731	validation_1-rmse:1.02331
# [57]	validation_0-rmse:0.41307	validation_1-rmse:1.02080
# [58]	validation_0-rmse:0.40978	validation_1-rmse:1.02202
# [59]	validation_0-rmse:0.40798	validation_1-rmse:1.02116
# [60]	validation_0-rmse:0.40289	validation_1-rmse:1.02071
# [61]	validation_0-rmse:0.39909	validation_1-rmse:1.01841
# [62]	validation_0-rmse:0.39331	validation_1-rmse:1.01895
# [63]	validation_0-rmse:0.38925	validation_1-rmse:1.01858
# [64]	validation_0-rmse:0.38661	validation_1-rmse:1.01967
# [65]	validation_0-rmse:0.38543	validation_1-rmse:1.01851
# [66]	validation_0-rmse:0.38185	validation_1-rmse:1.01687
# [67]	validation_0-rmse:0.38056	validation_1-rmse:1.01732
# [68]	validation_0-rmse:0.37302	validation_1-rmse:1.01821
# [69]	validation_0-rmse:0.37124	validation_1-rmse:1.01958
# [70]	validation_0-rmse:0.36769	validation_1-rmse:1.01984
# [71]	validation_0-rmse:0.36348	validation_1-rmse:1.01524
# [72]	validation_0-rmse:0.35925	validation_1-rmse:1.01240
# [73]	validation_0-rmse:0.35714	validation_1-rmse:1.01229
# [74]	validation_0-rmse:0.35593	validation_1-rmse:1.01245
# [75]	validation_0-rmse:0.35260	validation_1-rmse:1.01104
# [76]	validation_0-rmse:0.34923	validation_1-rmse:1.00936
# [77]	validation_0-rmse:0.34707	validation_1-rmse:1.00984
# [78]	validation_0-rmse:0.34449	validation_1-rmse:1.01076
# [79]	validation_0-rmse:0.34028	validation_1-rmse:1.01183
# [80]	validation_0-rmse:0.33964	validation_1-rmse:1.01202
# [81]	validation_0-rmse:0.33817	validation_1-rmse:1.01170
# [82]	validation_0-rmse:0.33697	validation_1-rmse:1.01300
# [83]	validation_0-rmse:0.33304	validation_1-rmse:1.01367
# [84]	validation_0-rmse:0.33119	validation_1-rmse:1.01393
# [85]	validation_0-rmse:0.32562	validation_1-rmse:1.01619
# [86]	validation_0-rmse:0.32180	validation_1-rmse:1.01407
# [87]	validation_0-rmse:0.31903	validation_1-rmse:1.01098
# [88]	validation_0-rmse:0.31377	validation_1-rmse:1.01036
# [89]	validation_0-rmse:0.31280	validation_1-rmse:1.01046
# [90]	validation_0-rmse:0.31192	validation_1-rmse:1.00968
# [91]	validation_0-rmse:0.31031	validation_1-rmse:1.00946
# [92]	validation_0-rmse:0.30932	validation_1-rmse:1.00906
# [93]	validation_0-rmse:0.30726	validation_1-rmse:1.00630
# [94]	validation_0-rmse:0.30617	validation_1-rmse:1.00630
# [95]	validation_0-rmse:0.30040	validation_1-rmse:1.00690
# [96]	validation_0-rmse:0.29780	validation_1-rmse:1.00616
# [97]	validation_0-rmse:0.29392	validation_1-rmse:1.00770
# [98]	validation_0-rmse:0.29092	validation_1-rmse:1.00947
# [99]	validation_0-rmse:0.29092	validation_1-rmse:1.00949
# [100]	validation_0-rmse:0.29091	validation_1-rmse:1.00961
# [101]	validation_0-rmse:0.29092	validation_1-rmse:1.00959
# [102]	validation_0-rmse:0.29091	validation_1-rmse:1.00980
# [103]	validation_0-rmse:0.28836	validation_1-rmse:1.01009
# [104]	validation_0-rmse:0.28766	validation_1-rmse:1.00986
# [105]	validation_0-rmse:0.28565	validation_1-rmse:1.01189
# [106]	validation_0-rmse:0.28430	validation_1-rmse:1.01260
# [107]	validation_0-rmse:0.28429	validation_1-rmse:1.01266
# [108]	validation_0-rmse:0.28429	validation_1-rmse:1.01267
# [109]	validation_0-rmse:0.28429	validation_1-rmse:1.01270
# [110]	validation_0-rmse:0.28429	validation_1-rmse:1.01291
# [111]	validation_0-rmse:0.28234	validation_1-rmse:1.01266
# [112]	validation_0-rmse:0.28233	validation_1-rmse:1.01275
# [113]	validation_0-rmse:0.28234	validation_1-rmse:1.01272
# [114]	validation_0-rmse:0.27933	validation_1-rmse:1.01218
# [115]	validation_0-rmse:0.27933	validation_1-rmse:1.01230
# [116]	validation_0-rmse:0.27933	validation_1-rmse:1.01237
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:5.05833	validation_1-rmse:5.61373
# [1]	validation_0-rmse:4.47145	validation_1-rmse:5.01495
# [2]	validation_0-rmse:3.92089	validation_1-rmse:4.47077
# [3]	validation_0-rmse:3.48260	validation_1-rmse:4.02237
# [4]	validation_0-rmse:3.12013	validation_1-rmse:3.64689
# [5]	validation_0-rmse:2.80114	validation_1-rmse:3.32536
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:2.54481	validation_1-rmse:3.06277
# [7]	validation_0-rmse:2.26145	validation_1-rmse:2.73799
# [8]	validation_0-rmse:2.07016	validation_1-rmse:2.56917
# [9]	validation_0-rmse:1.84913	validation_1-rmse:2.36194
# [10]	validation_0-rmse:1.70794	validation_1-rmse:2.22846
# [11]	validation_0-rmse:1.54177	validation_1-rmse:2.04397
# [12]	validation_0-rmse:1.45010	validation_1-rmse:1.95428
# [13]	validation_0-rmse:1.32267	validation_1-rmse:1.83042
# [14]	validation_0-rmse:1.24542	validation_1-rmse:1.77299
# [15]	validation_0-rmse:1.13797	validation_1-rmse:1.65772
# [16]	validation_0-rmse:1.05247	validation_1-rmse:1.56450
# [17]	validation_0-rmse:1.00502	validation_1-rmse:1.51825
# [18]	validation_0-rmse:0.96956	validation_1-rmse:1.49456
# [19]	validation_0-rmse:0.94106	validation_1-rmse:1.48604
# [20]	validation_0-rmse:0.91944	validation_1-rmse:1.47811
# [21]	validation_0-rmse:0.86777	validation_1-rmse:1.43871
# [22]	validation_0-rmse:0.82428	validation_1-rmse:1.38626
# [23]	validation_0-rmse:0.80893	validation_1-rmse:1.37977
# [24]	validation_0-rmse:0.77272	validation_1-rmse:1.33276
# [25]	validation_0-rmse:0.74267	validation_1-rmse:1.31094
# [26]	validation_0-rmse:0.71506	validation_1-rmse:1.28946
# [27]	validation_0-rmse:0.69039	validation_1-rmse:1.27463
# [28]	validation_0-rmse:0.66838	validation_1-rmse:1.25824
# [29]	validation_0-rmse:0.65387	validation_1-rmse:1.23937
# [30]	validation_0-rmse:0.63615	validation_1-rmse:1.23411
# [31]	validation_0-rmse:0.61804	validation_1-rmse:1.21054
# [32]	validation_0-rmse:0.60314	validation_1-rmse:1.19632
# [33]	validation_0-rmse:0.59470	validation_1-rmse:1.20078
# [34]	validation_0-rmse:0.58616	validation_1-rmse:1.20693
# [35]	validation_0-rmse:0.57040	validation_1-rmse:1.19641
# [36]	validation_0-rmse:0.56263	validation_1-rmse:1.18902
# [37]	validation_0-rmse:0.55291	validation_1-rmse:1.17531
# [38]	validation_0-rmse:0.54543	validation_1-rmse:1.17144
# [39]	validation_0-rmse:0.54030	validation_1-rmse:1.16967
# [40]	validation_0-rmse:0.53324	validation_1-rmse:1.16742
# [41]	validation_0-rmse:0.52506	validation_1-rmse:1.16614
# [42]	validation_0-rmse:0.51864	validation_1-rmse:1.16497
# [43]	validation_0-rmse:0.51228	validation_1-rmse:1.16803
# [44]	validation_0-rmse:0.50507	validation_1-rmse:1.16555
# [45]	validation_0-rmse:0.49466	validation_1-rmse:1.17128
# [46]	validation_0-rmse:0.48695	validation_1-rmse:1.17044
# [47]	validation_0-rmse:0.48182	validation_1-rmse:1.16946
# [48]	validation_0-rmse:0.47502	validation_1-rmse:1.17429
# [49]	validation_0-rmse:0.47043	validation_1-rmse:1.17986
# [50]	validation_0-rmse:0.46190	validation_1-rmse:1.17715
# [51]	validation_0-rmse:0.45548	validation_1-rmse:1.17525
# [52]	validation_0-rmse:0.45183	validation_1-rmse:1.17783
# [53]	validation_0-rmse:0.44880	validation_1-rmse:1.18165
# [54]	validation_0-rmse:0.44290	validation_1-rmse:1.17986
# [55]	validation_0-rmse:0.43864	validation_1-rmse:1.18288
# [56]	validation_0-rmse:0.43468	validation_1-rmse:1.18803
# [57]	validation_0-rmse:0.42918	validation_1-rmse:1.18176
# [58]	validation_0-rmse:0.42221	validation_1-rmse:1.17709
# [59]	validation_0-rmse:0.41676	validation_1-rmse:1.17638
# [60]	validation_0-rmse:0.41338	validation_1-rmse:1.18244
# [61]	validation_0-rmse:0.40721	validation_1-rmse:1.17857
# [0]	validation_0-rmse:5.12251	validation_1-rmse:5.42801
# [1]	validation_0-rmse:4.54295	validation_1-rmse:4.85307
# [2]	validation_0-rmse:3.98562	validation_1-rmse:4.30054
# [3]	validation_0-rmse:3.54635	validation_1-rmse:3.83669
# [4]	validation_0-rmse:3.17494	validation_1-rmse:3.47409
# [5]	validation_0-rmse:2.86385	validation_1-rmse:3.14340
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:2.60516	validation_1-rmse:2.86795
# [7]	validation_0-rmse:2.30699	validation_1-rmse:2.56906
# [8]	validation_0-rmse:2.12047	validation_1-rmse:2.37779
# [9]	validation_0-rmse:1.89054	validation_1-rmse:2.17075
# [10]	validation_0-rmse:1.75512	validation_1-rmse:2.04363
# [11]	validation_0-rmse:1.58023	validation_1-rmse:1.86760
# [12]	validation_0-rmse:1.48357	validation_1-rmse:1.77145
# [13]	validation_0-rmse:1.35761	validation_1-rmse:1.65336
# [14]	validation_0-rmse:1.29019	validation_1-rmse:1.60433
# [15]	validation_0-rmse:1.18381	validation_1-rmse:1.50372
# [16]	validation_0-rmse:1.09673	validation_1-rmse:1.40436
# [17]	validation_0-rmse:1.05598	validation_1-rmse:1.36964
# [18]	validation_0-rmse:1.01300	validation_1-rmse:1.35104
# [19]	validation_0-rmse:0.98531	validation_1-rmse:1.33319
# [20]	validation_0-rmse:0.96131	validation_1-rmse:1.32222
# [21]	validation_0-rmse:0.90848	validation_1-rmse:1.27587
# [22]	validation_0-rmse:0.86116	validation_1-rmse:1.23601
# [23]	validation_0-rmse:0.83840	validation_1-rmse:1.21780
# [24]	validation_0-rmse:0.79951	validation_1-rmse:1.18922
# [25]	validation_0-rmse:0.76699	validation_1-rmse:1.15095
# [26]	validation_0-rmse:0.73927	validation_1-rmse:1.12450
# [27]	validation_0-rmse:0.70967	validation_1-rmse:1.10325
# [28]	validation_0-rmse:0.69330	validation_1-rmse:1.08815
# [29]	validation_0-rmse:0.67083	validation_1-rmse:1.07257
# [30]	validation_0-rmse:0.65687	validation_1-rmse:1.06135
# [31]	validation_0-rmse:0.64124	validation_1-rmse:1.04674
# [32]	validation_0-rmse:0.62611	validation_1-rmse:1.04906
# [33]	validation_0-rmse:0.61351	validation_1-rmse:1.03901
# [34]	validation_0-rmse:0.60255	validation_1-rmse:1.03760
# [35]	validation_0-rmse:0.59241	validation_1-rmse:1.03572
# [36]	validation_0-rmse:0.58413	validation_1-rmse:1.03387
# [37]	validation_0-rmse:0.57166	validation_1-rmse:1.02060
# [38]	validation_0-rmse:0.56271	validation_1-rmse:1.01456
# [39]	validation_0-rmse:0.55780	validation_1-rmse:1.01166
# [40]	validation_0-rmse:0.54940	validation_1-rmse:1.01092
# [41]	validation_0-rmse:0.54017	validation_1-rmse:1.00152
# [42]	validation_0-rmse:0.53303	validation_1-rmse:1.00323
# [43]	validation_0-rmse:0.52582	validation_1-rmse:1.00235
# [44]	validation_0-rmse:0.52248	validation_1-rmse:1.00150
# [45]	validation_0-rmse:0.51698	validation_1-rmse:1.00052
# [46]	validation_0-rmse:0.51197	validation_1-rmse:0.99418
# [47]	validation_0-rmse:0.50579	validation_1-rmse:0.98935
# [48]	validation_0-rmse:0.49944	validation_1-rmse:0.98698
# [49]	validation_0-rmse:0.49616	validation_1-rmse:0.98999
# [50]	validation_0-rmse:0.49344	validation_1-rmse:0.99111
# [51]	validation_0-rmse:0.48412	validation_1-rmse:0.99269
# [52]	validation_0-rmse:0.48214	validation_1-rmse:0.99346
# [53]	validation_0-rmse:0.47934	validation_1-rmse:0.99030
# [54]	validation_0-rmse:0.47149	validation_1-rmse:0.98700
# [55]	validation_0-rmse:0.46686	validation_1-rmse:0.98656
# [56]	validation_0-rmse:0.46419	validation_1-rmse:0.98701
# [57]	validation_0-rmse:0.45959	validation_1-rmse:0.98355
# [58]	validation_0-rmse:0.45516	validation_1-rmse:0.98237
# [59]	validation_0-rmse:0.44904	validation_1-rmse:0.97956
# [60]	validation_0-rmse:0.44491	validation_1-rmse:0.98474
# [61]	validation_0-rmse:0.44154	validation_1-rmse:0.98973
# [62]	validation_0-rmse:0.43888	validation_1-rmse:0.99380
# [63]	validation_0-rmse:0.43173	validation_1-rmse:0.99359
# [64]	validation_0-rmse:0.42655	validation_1-rmse:0.99116
# [65]	validation_0-rmse:0.42503	validation_1-rmse:0.99196
# [66]	validation_0-rmse:0.41825	validation_1-rmse:0.98561
# [67]	validation_0-rmse:0.41663	validation_1-rmse:0.98535
# [68]	validation_0-rmse:0.40984	validation_1-rmse:0.98874
# [69]	validation_0-rmse:0.40717	validation_1-rmse:0.98936
# [70]	validation_0-rmse:0.40381	validation_1-rmse:0.98886
# [71]	validation_0-rmse:0.39812	validation_1-rmse:0.98824
# [72]	validation_0-rmse:0.39225	validation_1-rmse:0.98703
# [73]	validation_0-rmse:0.38777	validation_1-rmse:0.99132
# [74]	validation_0-rmse:0.38268	validation_1-rmse:0.99039
# [75]	validation_0-rmse:0.37978	validation_1-rmse:0.98999
# [76]	validation_0-rmse:0.37837	validation_1-rmse:0.99361
# [77]	validation_0-rmse:0.37264	validation_1-rmse:0.99435
# [78]	validation_0-rmse:0.37008	validation_1-rmse:0.99590
# [79]	validation_0-rmse:0.36796	validation_1-rmse:0.99639
# [0]	validation_0-rmse:5.09400	validation_1-rmse:5.50591
# [1]	validation_0-rmse:4.49805	validation_1-rmse:4.96835
# [2]	validation_0-rmse:3.94200	validation_1-rmse:4.37214
# [3]	validation_0-rmse:3.50048	validation_1-rmse:3.99295
# [4]	validation_0-rmse:3.13441	validation_1-rmse:3.66048
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:2.81252	validation_1-rmse:3.37845
# [6]	validation_0-rmse:2.54061	validation_1-rmse:3.15146
# [7]	validation_0-rmse:2.24199	validation_1-rmse:2.85277
# [8]	validation_0-rmse:2.05030	validation_1-rmse:2.68001
# [9]	validation_0-rmse:1.82645	validation_1-rmse:2.45953
# [10]	validation_0-rmse:1.68052	validation_1-rmse:2.35530
# [11]	validation_0-rmse:1.50625	validation_1-rmse:2.17603
# [12]	validation_0-rmse:1.40063	validation_1-rmse:2.11403
# [13]	validation_0-rmse:1.27474	validation_1-rmse:1.98790
# [14]	validation_0-rmse:1.20196	validation_1-rmse:1.92625
# [15]	validation_0-rmse:1.09681	validation_1-rmse:1.82260
# [16]	validation_0-rmse:1.01079	validation_1-rmse:1.74177
# [17]	validation_0-rmse:0.96570	validation_1-rmse:1.70489
# [18]	validation_0-rmse:0.93028	validation_1-rmse:1.67845
# [19]	validation_0-rmse:0.89927	validation_1-rmse:1.65928
# [20]	validation_0-rmse:0.87042	validation_1-rmse:1.63034
# [21]	validation_0-rmse:0.81854	validation_1-rmse:1.57931
# [22]	validation_0-rmse:0.77369	validation_1-rmse:1.52987
# [23]	validation_0-rmse:0.75642	validation_1-rmse:1.52221
# [24]	validation_0-rmse:0.72069	validation_1-rmse:1.49618
# [25]	validation_0-rmse:0.69311	validation_1-rmse:1.46161
# [26]	validation_0-rmse:0.66788	validation_1-rmse:1.44636
# [27]	validation_0-rmse:0.64782	validation_1-rmse:1.42896
# [28]	validation_0-rmse:0.63083	validation_1-rmse:1.41827
# [29]	validation_0-rmse:0.61645	validation_1-rmse:1.39726
# [30]	validation_0-rmse:0.60611	validation_1-rmse:1.38822
# [31]	validation_0-rmse:0.59087	validation_1-rmse:1.38255
# [32]	validation_0-rmse:0.57665	validation_1-rmse:1.36343
# [33]	validation_0-rmse:0.56502	validation_1-rmse:1.35800
# [34]	validation_0-rmse:0.55655	validation_1-rmse:1.35750
# [35]	validation_0-rmse:0.54729	validation_1-rmse:1.35472
# [36]	validation_0-rmse:0.53924	validation_1-rmse:1.34007
# [37]	validation_0-rmse:0.53151	validation_1-rmse:1.34183
# [38]	validation_0-rmse:0.52467	validation_1-rmse:1.33923
# [39]	validation_0-rmse:0.51662	validation_1-rmse:1.33250
# [40]	validation_0-rmse:0.51020	validation_1-rmse:1.33195
# [41]	validation_0-rmse:0.50300	validation_1-rmse:1.32811
# [42]	validation_0-rmse:0.49683	validation_1-rmse:1.32406
# [43]	validation_0-rmse:0.49075	validation_1-rmse:1.32633
# [44]	validation_0-rmse:0.48771	validation_1-rmse:1.32458
# [45]	validation_0-rmse:0.47884	validation_1-rmse:1.31574
# [46]	validation_0-rmse:0.47321	validation_1-rmse:1.31680
# [47]	validation_0-rmse:0.46836	validation_1-rmse:1.32109
# [48]	validation_0-rmse:0.46340	validation_1-rmse:1.32258
# [49]	validation_0-rmse:0.45629	validation_1-rmse:1.32543
# [50]	validation_0-rmse:0.44722	validation_1-rmse:1.33463
# [51]	validation_0-rmse:0.44361	validation_1-rmse:1.33097
# [52]	validation_0-rmse:0.43828	validation_1-rmse:1.33009
# [53]	validation_0-rmse:0.43358	validation_1-rmse:1.33037
# [54]	validation_0-rmse:0.43177	validation_1-rmse:1.32962
# [55]	validation_0-rmse:0.42644	validation_1-rmse:1.33168
# [56]	validation_0-rmse:0.42279	validation_1-rmse:1.32565
# [57]	validation_0-rmse:0.41631	validation_1-rmse:1.32444
# [58]	validation_0-rmse:0.41046	validation_1-rmse:1.32303
# [59]	validation_0-rmse:0.40754	validation_1-rmse:1.32182
# [60]	validation_0-rmse:0.40356	validation_1-rmse:1.32548
# [61]	validation_0-rmse:0.39853	validation_1-rmse:1.32655
# [62]	validation_0-rmse:0.39483	validation_1-rmse:1.32868
# [63]	validation_0-rmse:0.39070	validation_1-rmse:1.32068
# [64]	validation_0-rmse:0.38777	validation_1-rmse:1.32283
# [65]	validation_0-rmse:0.38477	validation_1-rmse:1.32297
# [0]	validation_0-rmse:5.17985	validation_1-rmse:5.08172
# [1]	validation_0-rmse:4.58957	validation_1-rmse:4.49816
# [2]	validation_0-rmse:4.01313	validation_1-rmse:3.91177
# [3]	validation_0-rmse:3.57624	validation_1-rmse:3.49708
# [4]	validation_0-rmse:3.20677	validation_1-rmse:3.11700
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:2.89632	validation_1-rmse:2.81188
# [6]	validation_0-rmse:2.62458	validation_1-rmse:2.55824
# [7]	validation_0-rmse:2.31765	validation_1-rmse:2.27391
# [8]	validation_0-rmse:2.12899	validation_1-rmse:2.11333
# [9]	validation_0-rmse:1.89631	validation_1-rmse:1.91801
# [10]	validation_0-rmse:1.76755	validation_1-rmse:1.80118
# [11]	validation_0-rmse:1.58370	validation_1-rmse:1.67037
# [12]	validation_0-rmse:1.48323	validation_1-rmse:1.60947
# [13]	validation_0-rmse:1.34202	validation_1-rmse:1.50952
# [14]	validation_0-rmse:1.26442	validation_1-rmse:1.45875
# [15]	validation_0-rmse:1.14662	validation_1-rmse:1.39081
# [16]	validation_0-rmse:1.05143	validation_1-rmse:1.33533
# [17]	validation_0-rmse:1.00786	validation_1-rmse:1.31859
# [18]	validation_0-rmse:0.97296	validation_1-rmse:1.30360
# [19]	validation_0-rmse:0.94232	validation_1-rmse:1.28833
# [20]	validation_0-rmse:0.91781	validation_1-rmse:1.28995
# [21]	validation_0-rmse:0.86013	validation_1-rmse:1.27081
# [22]	validation_0-rmse:0.80803	validation_1-rmse:1.24346
# [23]	validation_0-rmse:0.79055	validation_1-rmse:1.24726
# [24]	validation_0-rmse:0.75237	validation_1-rmse:1.22682
# [25]	validation_0-rmse:0.71952	validation_1-rmse:1.21163
# [26]	validation_0-rmse:0.68902	validation_1-rmse:1.20255
# [27]	validation_0-rmse:0.66887	validation_1-rmse:1.19687
# [28]	validation_0-rmse:0.64924	validation_1-rmse:1.19737
# [29]	validation_0-rmse:0.63344	validation_1-rmse:1.19459
# [30]	validation_0-rmse:0.62327	validation_1-rmse:1.18685
# [31]	validation_0-rmse:0.60893	validation_1-rmse:1.18591
# [32]	validation_0-rmse:0.59096	validation_1-rmse:1.17874
# [33]	validation_0-rmse:0.58449	validation_1-rmse:1.17902
# [34]	validation_0-rmse:0.57786	validation_1-rmse:1.17683
# [35]	validation_0-rmse:0.56920	validation_1-rmse:1.17160
# [36]	validation_0-rmse:0.56027	validation_1-rmse:1.16485
# [37]	validation_0-rmse:0.55142	validation_1-rmse:1.16686
# [38]	validation_0-rmse:0.54265	validation_1-rmse:1.16480
# [39]	validation_0-rmse:0.53581	validation_1-rmse:1.16608
# [40]	validation_0-rmse:0.52706	validation_1-rmse:1.17167
# [41]	validation_0-rmse:0.52250	validation_1-rmse:1.16994
# [42]	validation_0-rmse:0.51593	validation_1-rmse:1.17357
# [43]	validation_0-rmse:0.50384	validation_1-rmse:1.17193
# [44]	validation_0-rmse:0.49564	validation_1-rmse:1.16965
# [45]	validation_0-rmse:0.48947	validation_1-rmse:1.17295
# [46]	validation_0-rmse:0.48633	validation_1-rmse:1.17658
# [47]	validation_0-rmse:0.48141	validation_1-rmse:1.17367
# [48]	validation_0-rmse:0.47335	validation_1-rmse:1.17878
# [49]	validation_0-rmse:0.46738	validation_1-rmse:1.17655
# [50]	validation_0-rmse:0.45990	validation_1-rmse:1.18280
# [51]	validation_0-rmse:0.45464	validation_1-rmse:1.18520
# [52]	validation_0-rmse:0.45042	validation_1-rmse:1.18609
# [53]	validation_0-rmse:0.44264	validation_1-rmse:1.18498
# [54]	validation_0-rmse:0.43297	validation_1-rmse:1.17896
# [55]	validation_0-rmse:0.43098	validation_1-rmse:1.17876
# [56]	validation_0-rmse:0.42614	validation_1-rmse:1.18278
# [57]	validation_0-rmse:0.42180	validation_1-rmse:1.18188
# [58]	validation_0-rmse:0.41822	validation_1-rmse:1.18281
# [0]	validation_0-rmse:5.08040	validation_1-rmse:5.45963
# [1]	validation_0-rmse:4.50607	validation_1-rmse:4.83731
# [2]	validation_0-rmse:3.94885	validation_1-rmse:4.24650
# [3]	validation_0-rmse:3.51583	validation_1-rmse:3.78396
# [4]	validation_0-rmse:3.15370	validation_1-rmse:3.41927
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:2.84258	validation_1-rmse:3.09044
# [6]	validation_0-rmse:2.57906	validation_1-rmse:2.85067
# [7]	validation_0-rmse:2.28984	validation_1-rmse:2.54653
# [8]	validation_0-rmse:2.09165	validation_1-rmse:2.37498
# [9]	validation_0-rmse:1.86684	validation_1-rmse:2.13434
# [10]	validation_0-rmse:1.72277	validation_1-rmse:1.98942
# [11]	validation_0-rmse:1.54736	validation_1-rmse:1.80653
# [12]	validation_0-rmse:1.45238	validation_1-rmse:1.72576
# [13]	validation_0-rmse:1.32746	validation_1-rmse:1.57532
# [14]	validation_0-rmse:1.25531	validation_1-rmse:1.50456
# [15]	validation_0-rmse:1.15279	validation_1-rmse:1.40465
# [16]	validation_0-rmse:1.06563	validation_1-rmse:1.31198
# [17]	validation_0-rmse:1.01567	validation_1-rmse:1.29239
# [18]	validation_0-rmse:0.97365	validation_1-rmse:1.26652
# [19]	validation_0-rmse:0.94775	validation_1-rmse:1.24516
# [20]	validation_0-rmse:0.92355	validation_1-rmse:1.23552
# [21]	validation_0-rmse:0.87001	validation_1-rmse:1.17472
# [22]	validation_0-rmse:0.82553	validation_1-rmse:1.12464
# [23]	validation_0-rmse:0.81238	validation_1-rmse:1.11530
# [24]	validation_0-rmse:0.77744	validation_1-rmse:1.07706
# [25]	validation_0-rmse:0.74697	validation_1-rmse:1.03945
# [26]	validation_0-rmse:0.71581	validation_1-rmse:1.01622
# [27]	validation_0-rmse:0.69246	validation_1-rmse:0.99738
# [28]	validation_0-rmse:0.67578	validation_1-rmse:0.97908
# [29]	validation_0-rmse:0.66011	validation_1-rmse:0.96041
# [30]	validation_0-rmse:0.64867	validation_1-rmse:0.96482
# [31]	validation_0-rmse:0.63803	validation_1-rmse:0.95469
# [32]	validation_0-rmse:0.62047	validation_1-rmse:0.94208
# [33]	validation_0-rmse:0.61307	validation_1-rmse:0.94085
# [34]	validation_0-rmse:0.59770	validation_1-rmse:0.93922
# [35]	validation_0-rmse:0.59053	validation_1-rmse:0.92909
# [36]	validation_0-rmse:0.58262	validation_1-rmse:0.92372
# [37]	validation_0-rmse:0.56555	validation_1-rmse:0.92562
# [38]	validation_0-rmse:0.55319	validation_1-rmse:0.91007
# [39]	validation_0-rmse:0.54894	validation_1-rmse:0.90151
# [40]	validation_0-rmse:0.53950	validation_1-rmse:0.89427
# [41]	validation_0-rmse:0.53107	validation_1-rmse:0.88624
# [42]	validation_0-rmse:0.52393	validation_1-rmse:0.88159
# [43]	validation_0-rmse:0.51977	validation_1-rmse:0.88257
# [44]	validation_0-rmse:0.51437	validation_1-rmse:0.87874
# [45]	validation_0-rmse:0.50495	validation_1-rmse:0.88034
# [46]	validation_0-rmse:0.49696	validation_1-rmse:0.88199
# [47]	validation_0-rmse:0.48578	validation_1-rmse:0.88215
# [48]	validation_0-rmse:0.48091	validation_1-rmse:0.87671
# [49]	validation_0-rmse:0.47618	validation_1-rmse:0.87572
# [50]	validation_0-rmse:0.47210	validation_1-rmse:0.87228
# [51]	validation_0-rmse:0.46322	validation_1-rmse:0.86795
# [52]	validation_0-rmse:0.45758	validation_1-rmse:0.86625
# [53]	validation_0-rmse:0.45200	validation_1-rmse:0.86300
# [54]	validation_0-rmse:0.44460	validation_1-rmse:0.86236
# [55]	validation_0-rmse:0.43854	validation_1-rmse:0.86353
# [56]	validation_0-rmse:0.43238	validation_1-rmse:0.86374
# [57]	validation_0-rmse:0.42546	validation_1-rmse:0.86017
# [58]	validation_0-rmse:0.42106	validation_1-rmse:0.85652
# [59]	validation_0-rmse:0.41569	validation_1-rmse:0.85718
# [60]	validation_0-rmse:0.41101	validation_1-rmse:0.85712
# [61]	validation_0-rmse:0.40900	validation_1-rmse:0.85651
# [62]	validation_0-rmse:0.40669	validation_1-rmse:0.85665
# [63]	validation_0-rmse:0.40205	validation_1-rmse:0.85727
# [64]	validation_0-rmse:0.39725	validation_1-rmse:0.85615
# [65]	validation_0-rmse:0.39267	validation_1-rmse:0.85474
# [66]	validation_0-rmse:0.39155	validation_1-rmse:0.85443
# [67]	validation_0-rmse:0.38909	validation_1-rmse:0.85247
# [68]	validation_0-rmse:0.38424	validation_1-rmse:0.85303
# [69]	validation_0-rmse:0.38424	validation_1-rmse:0.85301
# [70]	validation_0-rmse:0.38140	validation_1-rmse:0.85188
# [71]	validation_0-rmse:0.37821	validation_1-rmse:0.85413
# [72]	validation_0-rmse:0.37604	validation_1-rmse:0.84851
# [73]	validation_0-rmse:0.37098	validation_1-rmse:0.84873
# [74]	validation_0-rmse:0.36633	validation_1-rmse:0.84838
# [75]	validation_0-rmse:0.36135	validation_1-rmse:0.84659
# [76]	validation_0-rmse:0.35701	validation_1-rmse:0.84672
# [77]	validation_0-rmse:0.35442	validation_1-rmse:0.84553
# [78]	validation_0-rmse:0.35285	validation_1-rmse:0.84552
# [79]	validation_0-rmse:0.35250	validation_1-rmse:0.84606
# [80]	validation_0-rmse:0.34788	validation_1-rmse:0.84625
# [81]	validation_0-rmse:0.34396	validation_1-rmse:0.84702
# [82]	validation_0-rmse:0.34110	validation_1-rmse:0.84635
# [83]	validation_0-rmse:0.33989	validation_1-rmse:0.84653
# [84]	validation_0-rmse:0.33785	validation_1-rmse:0.84900
# [85]	validation_0-rmse:0.33691	validation_1-rmse:0.84921
# [86]	validation_0-rmse:0.33691	validation_1-rmse:0.84911
# [87]	validation_0-rmse:0.33485	validation_1-rmse:0.84946
# [88]	validation_0-rmse:0.33188	validation_1-rmse:0.84749
# [89]	validation_0-rmse:0.32954	validation_1-rmse:0.85032
# [90]	validation_0-rmse:0.32808	validation_1-rmse:0.85032
# [91]	validation_0-rmse:0.32395	validation_1-rmse:0.84992
# [92]	validation_0-rmse:0.32395	validation_1-rmse:0.84997
# [93]	validation_0-rmse:0.32394	validation_1-rmse:0.84987
# [94]	validation_0-rmse:0.32395	validation_1-rmse:0.84997
# [95]	validation_0-rmse:0.32028	validation_1-rmse:0.85105
# [96]	validation_0-rmse:0.31961	validation_1-rmse:0.85178
# [97]	validation_0-rmse:0.31543	validation_1-rmse:0.85377
# [98]	validation_0-rmse:0.31543	validation_1-rmse:0.85369
# [0]	validation_0-rmse:5.24849	validation_1-rmse:4.70908
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:4.65107	validation_1-rmse:4.12938
# [2]	validation_0-rmse:4.06646	validation_1-rmse:3.63070
# [3]	validation_0-rmse:3.61120	validation_1-rmse:3.19316
# [4]	validation_0-rmse:3.23896	validation_1-rmse:2.86628
# [5]	validation_0-rmse:2.90793	validation_1-rmse:2.56665
# [6]	validation_0-rmse:2.63439	validation_1-rmse:2.34741
# [7]	validation_0-rmse:2.32913	validation_1-rmse:2.12472
# [8]	validation_0-rmse:2.13742	validation_1-rmse:2.00021
# [9]	validation_0-rmse:1.91070	validation_1-rmse:1.83741
# [10]	validation_0-rmse:1.76860	validation_1-rmse:1.74906
# [11]	validation_0-rmse:1.58634	validation_1-rmse:1.63963
# [12]	validation_0-rmse:1.48504	validation_1-rmse:1.57897
# [13]	validation_0-rmse:1.34409	validation_1-rmse:1.48844
# [14]	validation_0-rmse:1.26615	validation_1-rmse:1.47392
# [15]	validation_0-rmse:1.15927	validation_1-rmse:1.41113
# [16]	validation_0-rmse:1.06827	validation_1-rmse:1.35474
# [17]	validation_0-rmse:1.01788	validation_1-rmse:1.34194
# [18]	validation_0-rmse:0.97331	validation_1-rmse:1.34446
# [19]	validation_0-rmse:0.94316	validation_1-rmse:1.34239
# [20]	validation_0-rmse:0.91586	validation_1-rmse:1.34598
# [21]	validation_0-rmse:0.85543	validation_1-rmse:1.30300
# [22]	validation_0-rmse:0.80797	validation_1-rmse:1.27852
# [23]	validation_0-rmse:0.78762	validation_1-rmse:1.27810
# [24]	validation_0-rmse:0.74796	validation_1-rmse:1.25523
# [25]	validation_0-rmse:0.71486	validation_1-rmse:1.23372
# [26]	validation_0-rmse:0.68273	validation_1-rmse:1.21602
# [27]	validation_0-rmse:0.65712	validation_1-rmse:1.20186
# [28]	validation_0-rmse:0.63648	validation_1-rmse:1.18706
# [29]	validation_0-rmse:0.62040	validation_1-rmse:1.17259
# [30]	validation_0-rmse:0.60881	validation_1-rmse:1.17582
# [31]	validation_0-rmse:0.59207	validation_1-rmse:1.16616
# [32]	validation_0-rmse:0.57517	validation_1-rmse:1.16386
# [33]	validation_0-rmse:0.56821	validation_1-rmse:1.15747
# [34]	validation_0-rmse:0.56038	validation_1-rmse:1.15972
# [35]	validation_0-rmse:0.54622	validation_1-rmse:1.15456
# [36]	validation_0-rmse:0.53730	validation_1-rmse:1.14444
# [37]	validation_0-rmse:0.52320	validation_1-rmse:1.14090
# [38]	validation_0-rmse:0.51429	validation_1-rmse:1.13999
# [39]	validation_0-rmse:0.50496	validation_1-rmse:1.13737
# [40]	validation_0-rmse:0.49711	validation_1-rmse:1.13452
# [41]	validation_0-rmse:0.48818	validation_1-rmse:1.13020
# [42]	validation_0-rmse:0.48207	validation_1-rmse:1.12336
# [43]	validation_0-rmse:0.47314	validation_1-rmse:1.12336
# [44]	validation_0-rmse:0.46911	validation_1-rmse:1.11896
# [45]	validation_0-rmse:0.46037	validation_1-rmse:1.11590
# [46]	validation_0-rmse:0.45590	validation_1-rmse:1.11185
# [47]	validation_0-rmse:0.44915	validation_1-rmse:1.10898
# [48]	validation_0-rmse:0.44549	validation_1-rmse:1.11100
# [49]	validation_0-rmse:0.44119	validation_1-rmse:1.11091
# [50]	validation_0-rmse:0.43739	validation_1-rmse:1.10695
# [51]	validation_0-rmse:0.43424	validation_1-rmse:1.09891
# [52]	validation_0-rmse:0.42918	validation_1-rmse:1.09600
# [53]	validation_0-rmse:0.42763	validation_1-rmse:1.09643
# [54]	validation_0-rmse:0.42242	validation_1-rmse:1.09791
# [55]	validation_0-rmse:0.41807	validation_1-rmse:1.09643
# [56]	validation_0-rmse:0.41495	validation_1-rmse:1.09483
# [57]	validation_0-rmse:0.41344	validation_1-rmse:1.09379
# [58]	validation_0-rmse:0.41252	validation_1-rmse:1.09378
# [59]	validation_0-rmse:0.40864	validation_1-rmse:1.09583
# [60]	validation_0-rmse:0.40484	validation_1-rmse:1.09631
# [61]	validation_0-rmse:0.40314	validation_1-rmse:1.09757
# [62]	validation_0-rmse:0.39682	validation_1-rmse:1.09415
# [63]	validation_0-rmse:0.39600	validation_1-rmse:1.09541
# [64]	validation_0-rmse:0.39510	validation_1-rmse:1.09308
# [65]	validation_0-rmse:0.38978	validation_1-rmse:1.09170
# [66]	validation_0-rmse:0.38653	validation_1-rmse:1.08998
# [67]	validation_0-rmse:0.38119	validation_1-rmse:1.08981
# [68]	validation_0-rmse:0.37659	validation_1-rmse:1.08804
# [69]	validation_0-rmse:0.37418	validation_1-rmse:1.08725
# [70]	validation_0-rmse:0.36994	validation_1-rmse:1.08590
# [71]	validation_0-rmse:0.36413	validation_1-rmse:1.09138
# [72]	validation_0-rmse:0.35955	validation_1-rmse:1.08939
# [73]	validation_0-rmse:0.35421	validation_1-rmse:1.09167
# [74]	validation_0-rmse:0.35314	validation_1-rmse:1.09124
# [75]	validation_0-rmse:0.35236	validation_1-rmse:1.09118
# [76]	validation_0-rmse:0.34963	validation_1-rmse:1.09123
# [77]	validation_0-rmse:0.34498	validation_1-rmse:1.09493
# [78]	validation_0-rmse:0.34434	validation_1-rmse:1.09302
# [79]	validation_0-rmse:0.34373	validation_1-rmse:1.09367
# [80]	validation_0-rmse:0.33809	validation_1-rmse:1.09328
# [81]	validation_0-rmse:0.33499	validation_1-rmse:1.09535
# [82]	validation_0-rmse:0.33390	validation_1-rmse:1.09600
# [83]	validation_0-rmse:0.32874	validation_1-rmse:1.09720
# [84]	validation_0-rmse:0.32773	validation_1-rmse:1.09731
# [85]	validation_0-rmse:0.32398	validation_1-rmse:1.09950
# [86]	validation_0-rmse:0.32324	validation_1-rmse:1.09917
# [87]	validation_0-rmse:0.32177	validation_1-rmse:1.09961
# [88]	validation_0-rmse:0.32103	validation_1-rmse:1.10054
# [89]	validation_0-rmse:0.31905	validation_1-rmse:1.10150
# [0]	validation_0-rmse:5.03401	validation_1-rmse:5.67955
# [1]	validation_0-rmse:4.45524	validation_1-rmse:5.10610
# [2]	validation_0-rmse:3.90782	validation_1-rmse:4.52479
# [3]	validation_0-rmse:3.47545	validation_1-rmse:4.06427
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:3.12082	validation_1-rmse:3.69710
# [5]	validation_0-rmse:2.80917	validation_1-rmse:3.42059
# [6]	validation_0-rmse:2.53447	validation_1-rmse:3.18636
# [7]	validation_0-rmse:2.25505	validation_1-rmse:2.87408
# [8]	validation_0-rmse:2.07708	validation_1-rmse:2.68150
# [9]	validation_0-rmse:1.85550	validation_1-rmse:2.41003
# [10]	validation_0-rmse:1.71828	validation_1-rmse:2.26131
# [11]	validation_0-rmse:1.53997	validation_1-rmse:2.05070
# [12]	validation_0-rmse:1.44061	validation_1-rmse:1.93757
# [13]	validation_0-rmse:1.31474	validation_1-rmse:1.80284
# [14]	validation_0-rmse:1.23633	validation_1-rmse:1.74065
# [15]	validation_0-rmse:1.13421	validation_1-rmse:1.61861
# [16]	validation_0-rmse:1.04643	validation_1-rmse:1.53645
# [17]	validation_0-rmse:1.00350	validation_1-rmse:1.50664
# [18]	validation_0-rmse:0.97041	validation_1-rmse:1.48543
# [19]	validation_0-rmse:0.93617	validation_1-rmse:1.47421
# [20]	validation_0-rmse:0.90803	validation_1-rmse:1.45449
# [21]	validation_0-rmse:0.85211	validation_1-rmse:1.39429
# [22]	validation_0-rmse:0.80959	validation_1-rmse:1.35342
# [23]	validation_0-rmse:0.78987	validation_1-rmse:1.33777
# [24]	validation_0-rmse:0.75214	validation_1-rmse:1.31295
# [25]	validation_0-rmse:0.72269	validation_1-rmse:1.28951
# [26]	validation_0-rmse:0.69171	validation_1-rmse:1.24831
# [27]	validation_0-rmse:0.66675	validation_1-rmse:1.21268
# [28]	validation_0-rmse:0.64645	validation_1-rmse:1.18261
# [29]	validation_0-rmse:0.63022	validation_1-rmse:1.15919
# [30]	validation_0-rmse:0.62178	validation_1-rmse:1.15373
# [31]	validation_0-rmse:0.60747	validation_1-rmse:1.13608
# [32]	validation_0-rmse:0.59105	validation_1-rmse:1.12262
# [33]	validation_0-rmse:0.58386	validation_1-rmse:1.12070
# [34]	validation_0-rmse:0.57144	validation_1-rmse:1.11733
# [35]	validation_0-rmse:0.56066	validation_1-rmse:1.11207
# [36]	validation_0-rmse:0.54414	validation_1-rmse:1.11435
# [37]	validation_0-rmse:0.53289	validation_1-rmse:1.10769
# [38]	validation_0-rmse:0.52334	validation_1-rmse:1.10251
# [39]	validation_0-rmse:0.51716	validation_1-rmse:1.09920
# [40]	validation_0-rmse:0.51183	validation_1-rmse:1.09567
# [41]	validation_0-rmse:0.50569	validation_1-rmse:1.08991
# [42]	validation_0-rmse:0.49829	validation_1-rmse:1.08386
# [43]	validation_0-rmse:0.49002	validation_1-rmse:1.08212
# [44]	validation_0-rmse:0.48179	validation_1-rmse:1.07507
# [45]	validation_0-rmse:0.47601	validation_1-rmse:1.07474
# [46]	validation_0-rmse:0.47282	validation_1-rmse:1.07233
# [47]	validation_0-rmse:0.46537	validation_1-rmse:1.06957
# [48]	validation_0-rmse:0.46181	validation_1-rmse:1.06853
# [49]	validation_0-rmse:0.45844	validation_1-rmse:1.06631
# [50]	validation_0-rmse:0.44892	validation_1-rmse:1.07301
# [51]	validation_0-rmse:0.44704	validation_1-rmse:1.07124
# [52]	validation_0-rmse:0.44253	validation_1-rmse:1.07081
# [53]	validation_0-rmse:0.43726	validation_1-rmse:1.06952
# [54]	validation_0-rmse:0.43178	validation_1-rmse:1.06520
# [55]	validation_0-rmse:0.42953	validation_1-rmse:1.06541
# [56]	validation_0-rmse:0.42109	validation_1-rmse:1.06110
# [57]	validation_0-rmse:0.41724	validation_1-rmse:1.06196
# [58]	validation_0-rmse:0.40995	validation_1-rmse:1.05744
# [59]	validation_0-rmse:0.40424	validation_1-rmse:1.05344
# [60]	validation_0-rmse:0.40219	validation_1-rmse:1.05516
# [61]	validation_0-rmse:0.39930	validation_1-rmse:1.05414
# [62]	validation_0-rmse:0.39156	validation_1-rmse:1.05380
# [63]	validation_0-rmse:0.39010	validation_1-rmse:1.05534
# [64]	validation_0-rmse:0.38602	validation_1-rmse:1.05366
# [65]	validation_0-rmse:0.37976	validation_1-rmse:1.05041
# [66]	validation_0-rmse:0.37478	validation_1-rmse:1.04565
# [67]	validation_0-rmse:0.37112	validation_1-rmse:1.04589
# [68]	validation_0-rmse:0.36803	validation_1-rmse:1.04839
# [69]	validation_0-rmse:0.36689	validation_1-rmse:1.04742
# [70]	validation_0-rmse:0.36233	validation_1-rmse:1.04667
# [71]	validation_0-rmse:0.35714	validation_1-rmse:1.05381
# [72]	validation_0-rmse:0.35236	validation_1-rmse:1.05109
# [73]	validation_0-rmse:0.35122	validation_1-rmse:1.05204
# [74]	validation_0-rmse:0.35122	validation_1-rmse:1.05213
# [75]	validation_0-rmse:0.35122	validation_1-rmse:1.05274
# [76]	validation_0-rmse:0.34606	validation_1-rmse:1.05320
# [77]	validation_0-rmse:0.34407	validation_1-rmse:1.05116
# [78]	validation_0-rmse:0.34407	validation_1-rmse:1.05104
# [79]	validation_0-rmse:0.34291	validation_1-rmse:1.04960
# [80]	validation_0-rmse:0.34135	validation_1-rmse:1.04903
# [81]	validation_0-rmse:0.33800	validation_1-rmse:1.04881
# [82]	validation_0-rmse:0.33634	validation_1-rmse:1.04936
# [83]	validation_0-rmse:0.33406	validation_1-rmse:1.04664
# [84]	validation_0-rmse:0.33158	validation_1-rmse:1.04806
# [85]	validation_0-rmse:0.32650	validation_1-rmse:1.04274
# [86]	validation_0-rmse:0.32215	validation_1-rmse:1.04143
# [87]	validation_0-rmse:0.31782	validation_1-rmse:1.04489
# [88]	validation_0-rmse:0.31712	validation_1-rmse:1.04479
# [89]	validation_0-rmse:0.31616	validation_1-rmse:1.04360
# [90]	validation_0-rmse:0.31616	validation_1-rmse:1.04396
# [91]	validation_0-rmse:0.31441	validation_1-rmse:1.04316
# [92]	validation_0-rmse:0.31186	validation_1-rmse:1.04414
# [93]	validation_0-rmse:0.30908	validation_1-rmse:1.04732
# [94]	validation_0-rmse:0.30805	validation_1-rmse:1.04660
# [95]	validation_0-rmse:0.30578	validation_1-rmse:1.04676
# [96]	validation_0-rmse:0.30311	validation_1-rmse:1.04660
# [97]	validation_0-rmse:0.30224	validation_1-rmse:1.04659
# [98]	validation_0-rmse:0.29900	validation_1-rmse:1.04616
# [99]	validation_0-rmse:0.29646	validation_1-rmse:1.04900
# [100]	validation_0-rmse:0.29646	validation_1-rmse:1.04914
# [101]	validation_0-rmse:0.29312	validation_1-rmse:1.04991
# [102]	validation_0-rmse:0.29312	validation_1-rmse:1.04972
# [103]	validation_0-rmse:0.29005	validation_1-rmse:1.05061
# [104]	validation_0-rmse:0.28912	validation_1-rmse:1.05236
# [105]	validation_0-rmse:0.28595	validation_1-rmse:1.05164
# [0]	validation_0-rmse:5.17933	validation_1-rmse:5.15410
# [1]	validation_0-rmse:4.57973	validation_1-rmse:4.59711
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:4.01191	validation_1-rmse:4.05807
# [3]	validation_0-rmse:3.56882	validation_1-rmse:3.62867
# [4]	validation_0-rmse:3.19944	validation_1-rmse:3.25620
# [5]	validation_0-rmse:2.87099	validation_1-rmse:2.94439
# [6]	validation_0-rmse:2.60589	validation_1-rmse:2.72162
# [7]	validation_0-rmse:2.31050	validation_1-rmse:2.46072
# [8]	validation_0-rmse:2.11343	validation_1-rmse:2.28807
# [9]	validation_0-rmse:1.87312	validation_1-rmse:2.06841
# [10]	validation_0-rmse:1.74021	validation_1-rmse:1.95881
# [11]	validation_0-rmse:1.55862	validation_1-rmse:1.81776
# [12]	validation_0-rmse:1.45817	validation_1-rmse:1.72745
# [13]	validation_0-rmse:1.31824	validation_1-rmse:1.62254
# [14]	validation_0-rmse:1.24805	validation_1-rmse:1.56495
# [15]	validation_0-rmse:1.13384	validation_1-rmse:1.47389
# [16]	validation_0-rmse:1.04355	validation_1-rmse:1.40256
# [17]	validation_0-rmse:0.99637	validation_1-rmse:1.36554
# [18]	validation_0-rmse:0.96453	validation_1-rmse:1.34383
# [19]	validation_0-rmse:0.93560	validation_1-rmse:1.31408
# [20]	validation_0-rmse:0.91096	validation_1-rmse:1.30440
# [21]	validation_0-rmse:0.85492	validation_1-rmse:1.26285
# [22]	validation_0-rmse:0.80824	validation_1-rmse:1.23239
# [23]	validation_0-rmse:0.78705	validation_1-rmse:1.22189
# [24]	validation_0-rmse:0.74610	validation_1-rmse:1.19031
# [25]	validation_0-rmse:0.70968	validation_1-rmse:1.16960
# [26]	validation_0-rmse:0.67599	validation_1-rmse:1.14642
# [27]	validation_0-rmse:0.64723	validation_1-rmse:1.12437
# [28]	validation_0-rmse:0.62390	validation_1-rmse:1.10716
# [29]	validation_0-rmse:0.60587	validation_1-rmse:1.09720
# [30]	validation_0-rmse:0.59060	validation_1-rmse:1.09555
# [31]	validation_0-rmse:0.57492	validation_1-rmse:1.08668
# [32]	validation_0-rmse:0.56085	validation_1-rmse:1.07404
# [33]	validation_0-rmse:0.55089	validation_1-rmse:1.07172
# [34]	validation_0-rmse:0.54068	validation_1-rmse:1.07200
# [35]	validation_0-rmse:0.52763	validation_1-rmse:1.06728
# [36]	validation_0-rmse:0.51548	validation_1-rmse:1.05930
# [37]	validation_0-rmse:0.50568	validation_1-rmse:1.04796
# [38]	validation_0-rmse:0.49925	validation_1-rmse:1.04884
# [39]	validation_0-rmse:0.49089	validation_1-rmse:1.04545
# [40]	validation_0-rmse:0.48137	validation_1-rmse:1.04283
# [41]	validation_0-rmse:0.47299	validation_1-rmse:1.04399
# [42]	validation_0-rmse:0.46705	validation_1-rmse:1.04285
# [43]	validation_0-rmse:0.46150	validation_1-rmse:1.04291
# [44]	validation_0-rmse:0.45685	validation_1-rmse:1.04042
# [45]	validation_0-rmse:0.45098	validation_1-rmse:1.04317
# [46]	validation_0-rmse:0.44388	validation_1-rmse:1.03697
# [47]	validation_0-rmse:0.44077	validation_1-rmse:1.03646
# [48]	validation_0-rmse:0.43783	validation_1-rmse:1.03744
# [49]	validation_0-rmse:0.43152	validation_1-rmse:1.03818
# [50]	validation_0-rmse:0.42535	validation_1-rmse:1.03322
# [51]	validation_0-rmse:0.41984	validation_1-rmse:1.03571
# [52]	validation_0-rmse:0.41720	validation_1-rmse:1.03527
# [53]	validation_0-rmse:0.41183	validation_1-rmse:1.03215
# [54]	validation_0-rmse:0.40790	validation_1-rmse:1.03183
# [55]	validation_0-rmse:0.40192	validation_1-rmse:1.03586
# [56]	validation_0-rmse:0.39691	validation_1-rmse:1.03835
# [57]	validation_0-rmse:0.39213	validation_1-rmse:1.03828
# [58]	validation_0-rmse:0.38924	validation_1-rmse:1.04099
# [59]	validation_0-rmse:0.38621	validation_1-rmse:1.03854
# [60]	validation_0-rmse:0.38428	validation_1-rmse:1.04003
# [61]	validation_0-rmse:0.37992	validation_1-rmse:1.03747
# [62]	validation_0-rmse:0.37683	validation_1-rmse:1.03865
# [63]	validation_0-rmse:0.37438	validation_1-rmse:1.04237
# [64]	validation_0-rmse:0.37169	validation_1-rmse:1.04263
# [65]	validation_0-rmse:0.36818	validation_1-rmse:1.04042
# [66]	validation_0-rmse:0.36483	validation_1-rmse:1.04101
# [67]	validation_0-rmse:0.36312	validation_1-rmse:1.03916
# [68]	validation_0-rmse:0.36061	validation_1-rmse:1.03936
# [69]	validation_0-rmse:0.35961	validation_1-rmse:1.03947
# [70]	validation_0-rmse:0.35520	validation_1-rmse:1.03986
# [71]	validation_0-rmse:0.34764	validation_1-rmse:1.03114
# [72]	validation_0-rmse:0.34450	validation_1-rmse:1.03213
# [73]	validation_0-rmse:0.33859	validation_1-rmse:1.02697
# [74]	validation_0-rmse:0.33575	validation_1-rmse:1.02789
# [75]	validation_0-rmse:0.33426	validation_1-rmse:1.02799
# [76]	validation_0-rmse:0.33426	validation_1-rmse:1.02800
# [77]	validation_0-rmse:0.33425	validation_1-rmse:1.02815
# [78]	validation_0-rmse:0.32909	validation_1-rmse:1.02500
# [79]	validation_0-rmse:0.32910	validation_1-rmse:1.02506
# [80]	validation_0-rmse:0.32754	validation_1-rmse:1.02444
# [81]	validation_0-rmse:0.32754	validation_1-rmse:1.02441
# [82]	validation_0-rmse:0.32242	validation_1-rmse:1.02386
# [83]	validation_0-rmse:0.32163	validation_1-rmse:1.02434
# [84]	validation_0-rmse:0.32163	validation_1-rmse:1.02434
# [85]	validation_0-rmse:0.32163	validation_1-rmse:1.02421
# [86]	validation_0-rmse:0.31872	validation_1-rmse:1.02598
# [87]	validation_0-rmse:0.31410	validation_1-rmse:1.02684
# [88]	validation_0-rmse:0.31203	validation_1-rmse:1.02886
# [89]	validation_0-rmse:0.31063	validation_1-rmse:1.02934
# [90]	validation_0-rmse:0.30956	validation_1-rmse:1.02931
# [91]	validation_0-rmse:0.30696	validation_1-rmse:1.03303
# [92]	validation_0-rmse:0.30240	validation_1-rmse:1.03390
# [93]	validation_0-rmse:0.30081	validation_1-rmse:1.03465
# [94]	validation_0-rmse:0.29968	validation_1-rmse:1.03441
# [95]	validation_0-rmse:0.29968	validation_1-rmse:1.03423
# [96]	validation_0-rmse:0.29627	validation_1-rmse:1.03423
# [97]	validation_0-rmse:0.29474	validation_1-rmse:1.03425
# [98]	validation_0-rmse:0.29055	validation_1-rmse:1.03371
# [99]	validation_0-rmse:0.28644	validation_1-rmse:1.03226
# ...
# [31]	validation_0-rmse:0.65841	validation_1-rmse:0.68481
# [32]	validation_0-rmse:0.64418	validation_1-rmse:0.67575
# [33]	validation_0-rmse:0.62836	validation_1-rmse:0.66197
# [34]	validation_0-rmse:0.62028	validation_1-rmse:0.65775
# [35]	validation_0-rmse:0.61124	validation_1-rmse:0.65441
# [36]	validation_0-rmse:0.60053	validation_1-rmse:0.65296
# [37]	validation_0-rmse:0.58741	validation_1-rmse:0.65654
# [38]	validation_0-rmse:0.58051	validation_1-rmse:0.65724
# [39]	validation_0-rmse:0.57003	validation_1-rmse:0.66255
# [40]	validation_0-rmse:0.56246	validation_1-rmse:0.64965
# [41]	validation_0-rmse:0.55648	validation_1-rmse:0.65010
# [42]	validation_0-rmse:0.54398	validation_1-rmse:0.64953
# [43]	validation_0-rmse:0.53745	validation_1-rmse:0.65080
# [44]	validation_0-rmse:0.53068	validation_1-rmse:0.64351
# [45]	validation_0-rmse:0.52847	validation_1-rmse:0.64285
# [46]	validation_0-rmse:0.52467	validation_1-rmse:0.64707
# [47]	validation_0-rmse:0.51986	validation_1-rmse:0.64099
# [48]	validation_0-rmse:0.51621	validation_1-rmse:0.63833
# [49]	validation_0-rmse:0.51219	validation_1-rmse:0.63776
# [50]	validation_0-rmse:0.50808	validation_1-rmse:0.63643
# [51]	validation_0-rmse:0.50453	validation_1-rmse:0.63561
# [52]	validation_0-rmse:0.50146	validation_1-rmse:0.63885
# [53]	validation_0-rmse:0.49826	validation_1-rmse:0.64014
# [54]	validation_0-rmse:0.49506	validation_1-rmse:0.63813
# [55]	validation_0-rmse:0.49299	validation_1-rmse:0.63489
# [56]	validation_0-rmse:0.48640	validation_1-rmse:0.63521
# [57]	validation_0-rmse:0.47580	validation_1-rmse:0.63094
# [58]	validation_0-rmse:0.46912	validation_1-rmse:0.63136
# [59]	validation_0-rmse:0.46369	validation_1-rmse:0.63616
# [60]	validation_0-rmse:0.45472	validation_1-rmse:0.63618
# [61]	validation_0-rmse:0.45295	validation_1-rmse:0.64184
# [62]	validation_0-rmse:0.45023	validation_1-rmse:0.64457
# [63]	validation_0-rmse:0.44421	validation_1-rmse:0.64404
# [64]	validation_0-rmse:0.44027	validation_1-rmse:0.64551
# [65]	validation_0-rmse:0.43354	validation_1-rmse:0.63879
# [66]	validation_0-rmse:0.42969	validation_1-rmse:0.63710
# [67]	validation_0-rmse:0.42853	validation_1-rmse:0.63752
# [68]	validation_0-rmse:0.42442	validation_1-rmse:0.63861
# [69]	validation_0-rmse:0.42321	validation_1-rmse:0.63821
# [70]	validation_0-rmse:0.41928	validation_1-rmse:0.63483
# [71]	validation_0-rmse:0.41148	validation_1-rmse:0.63198
# [72]	validation_0-rmse:0.40834	validation_1-rmse:0.63238
# [73]	validation_0-rmse:0.40163	validation_1-rmse:0.62946
# [74]	validation_0-rmse:0.39861	validation_1-rmse:0.62928
# [75]	validation_0-rmse:0.39335	validation_1-rmse:0.62454
# [76]	validation_0-rmse:0.39226	validation_1-rmse:0.62577
# [77]	validation_0-rmse:0.38949	validation_1-rmse:0.62696
# [78]	validation_0-rmse:0.38289	validation_1-rmse:0.62749
# [79]	validation_0-rmse:0.38197	validation_1-rmse:0.62833
# [80]	validation_0-rmse:0.37702	validation_1-rmse:0.62892
# [81]	validation_0-rmse:0.37516	validation_1-rmse:0.62798
# [82]	validation_0-rmse:0.37160	validation_1-rmse:0.63074
# [83]	validation_0-rmse:0.36726	validation_1-rmse:0.63382
# [84]	validation_0-rmse:0.36306	validation_1-rmse:0.63577
# [85]	validation_0-rmse:0.36164	validation_1-rmse:0.63280
# [86]	validation_0-rmse:0.35796	validation_1-rmse:0.63338
# [87]	validation_0-rmse:0.35736	validation_1-rmse:0.63313
# [88]	validation_0-rmse:0.35358	validation_1-rmse:0.63276
# [89]	validation_0-rmse:0.35247	validation_1-rmse:0.63200
# [90]	validation_0-rmse:0.34892	validation_1-rmse:0.63039
# [91]	validation_0-rmse:0.34419	validation_1-rmse:0.62828
# [92]	validation_0-rmse:0.33961	validation_1-rmse:0.62641
# [93]	validation_0-rmse:0.33693	validation_1-rmse:0.62430
# [94]	validation_0-rmse:0.33693	validation_1-rmse:0.62431
# [95]	validation_0-rmse:0.33693	validation_1-rmse:0.62428
# [96]	validation_0-rmse:0.33581	validation_1-rmse:0.62628
# [97]	validation_0-rmse:0.33117	validation_1-rmse:0.62815
# [98]	validation_0-rmse:0.32721	validation_1-rmse:0.62658
# [99]	validation_0-rmse:0.32326	validation_1-rmse:0.62328
# [100]	validation_0-rmse:0.32172	validation_1-rmse:0.62320
# [101]	validation_0-rmse:0.31532	validation_1-rmse:0.62445
# [102]	validation_0-rmse:0.31304	validation_1-rmse:0.62398
# [103]	validation_0-rmse:0.30969	validation_1-rmse:0.62521
# [104]	validation_0-rmse:0.30536	validation_1-rmse:0.62822
# [105]	validation_0-rmse:0.30362	validation_1-rmse:0.62988
# [106]	validation_0-rmse:0.30362	validation_1-rmse:0.62986
# [107]	validation_0-rmse:0.30361	validation_1-rmse:0.62994
# [108]	validation_0-rmse:0.30237	validation_1-rmse:0.62990
# [109]	validation_0-rmse:0.30153	validation_1-rmse:0.63008
# [110]	validation_0-rmse:0.29877	validation_1-rmse:0.63382
# [111]	validation_0-rmse:0.29879	validation_1-rmse:0.63376
# [112]	validation_0-rmse:0.29767	validation_1-rmse:0.63518
# [113]	validation_0-rmse:0.29700	validation_1-rmse:0.63544
# [114]	validation_0-rmse:0.29700	validation_1-rmse:0.63544
# [115]	validation_0-rmse:0.29518	validation_1-rmse:0.63514
# [116]	validation_0-rmse:0.29517	validation_1-rmse:0.63521
# [117]	validation_0-rmse:0.29517	validation_1-rmse:0.63519
# [118]	validation_0-rmse:0.29394	validation_1-rmse:0.63605
# [119]	validation_0-rmse:0.29121	validation_1-rmse:0.63475
# [120]	validation_0-rmse:0.28856	validation_1-rmse:0.63599
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:5.16137	validation_1-rmse:5.21168
# [1]	validation_0-rmse:4.57608	validation_1-rmse:4.63778
# [2]	validation_0-rmse:4.01122	validation_1-rmse:4.11278
# [3]	validation_0-rmse:3.56559	validation_1-rmse:3.66029
# [4]	validation_0-rmse:3.20114	validation_1-rmse:3.31845
# [5]	validation_0-rmse:2.88070	validation_1-rmse:3.00335
# [6]	validation_0-rmse:2.60184	validation_1-rmse:2.72669
# [7]	validation_0-rmse:2.29367	validation_1-rmse:2.47094
# [8]	validation_0-rmse:2.10680	validation_1-rmse:2.29532
# [9]	validation_0-rmse:1.87707	validation_1-rmse:2.10361
# [10]	validation_0-rmse:1.73475	validation_1-rmse:1.98044
# [11]	validation_0-rmse:1.55431	validation_1-rmse:1.82555
# [12]	validation_0-rmse:1.45358	validation_1-rmse:1.73286
# [13]	validation_0-rmse:1.32091	validation_1-rmse:1.63428
# [14]	validation_0-rmse:1.24677	validation_1-rmse:1.57412
# [15]	validation_0-rmse:1.13828	validation_1-rmse:1.49101
# [16]	validation_0-rmse:1.04547	validation_1-rmse:1.41914
# [17]	validation_0-rmse:1.00290	validation_1-rmse:1.37733
# [18]	validation_0-rmse:0.97023	validation_1-rmse:1.35803
# [19]	validation_0-rmse:0.94634	validation_1-rmse:1.34980
# [20]	validation_0-rmse:0.92213	validation_1-rmse:1.32921
# [21]	validation_0-rmse:0.86647	validation_1-rmse:1.28787
# [22]	validation_0-rmse:0.81188	validation_1-rmse:1.24914
# [23]	validation_0-rmse:0.79512	validation_1-rmse:1.23988
# [24]	validation_0-rmse:0.75828	validation_1-rmse:1.22790
# [25]	validation_0-rmse:0.72387	validation_1-rmse:1.21176
# [26]	validation_0-rmse:0.69389	validation_1-rmse:1.19508
# [27]	validation_0-rmse:0.66827	validation_1-rmse:1.17991
# [28]	validation_0-rmse:0.64872	validation_1-rmse:1.16376
# [29]	validation_0-rmse:0.63210	validation_1-rmse:1.15497
# [30]	validation_0-rmse:0.61533	validation_1-rmse:1.15003
# [31]	validation_0-rmse:0.60287	validation_1-rmse:1.14659
# [32]	validation_0-rmse:0.58527	validation_1-rmse:1.14541
# [33]	validation_0-rmse:0.57447	validation_1-rmse:1.14157
# [34]	validation_0-rmse:0.56836	validation_1-rmse:1.13885
# [35]	validation_0-rmse:0.55390	validation_1-rmse:1.13564
# [36]	validation_0-rmse:0.54321	validation_1-rmse:1.13187
# [37]	validation_0-rmse:0.53007	validation_1-rmse:1.13135
# [38]	validation_0-rmse:0.52150	validation_1-rmse:1.13095
# [39]	validation_0-rmse:0.51538	validation_1-rmse:1.13032
# [40]	validation_0-rmse:0.50914	validation_1-rmse:1.12216
# [41]	validation_0-rmse:0.50050	validation_1-rmse:1.12103
# [42]	validation_0-rmse:0.49346	validation_1-rmse:1.12333
# [43]	validation_0-rmse:0.48989	validation_1-rmse:1.12429
# [44]	validation_0-rmse:0.48581	validation_1-rmse:1.11670
# [45]	validation_0-rmse:0.47990	validation_1-rmse:1.11575
# [46]	validation_0-rmse:0.47556	validation_1-rmse:1.11438
# [47]	validation_0-rmse:0.46838	validation_1-rmse:1.11464
# [48]	validation_0-rmse:0.46066	validation_1-rmse:1.11050
# [49]	validation_0-rmse:0.45644	validation_1-rmse:1.10763
# [50]	validation_0-rmse:0.45052	validation_1-rmse:1.10972
# [51]	validation_0-rmse:0.44522	validation_1-rmse:1.11119
# [52]	validation_0-rmse:0.44170	validation_1-rmse:1.11063
# [53]	validation_0-rmse:0.43724	validation_1-rmse:1.10977
# [54]	validation_0-rmse:0.43320	validation_1-rmse:1.10951
# [55]	validation_0-rmse:0.42722	validation_1-rmse:1.11005
# [56]	validation_0-rmse:0.42421	validation_1-rmse:1.11404
# [57]	validation_0-rmse:0.41923	validation_1-rmse:1.11693
# [58]	validation_0-rmse:0.41359	validation_1-rmse:1.12455
# [59]	validation_0-rmse:0.40860	validation_1-rmse:1.12434
# [60]	validation_0-rmse:0.40296	validation_1-rmse:1.12478
# [61]	validation_0-rmse:0.39796	validation_1-rmse:1.12531
# [62]	validation_0-rmse:0.39512	validation_1-rmse:1.12279
# [63]	validation_0-rmse:0.39034	validation_1-rmse:1.12122
# [64]	validation_0-rmse:0.38668	validation_1-rmse:1.12056
# [65]	validation_0-rmse:0.38298	validation_1-rmse:1.12152
# [66]	validation_0-rmse:0.37694	validation_1-rmse:1.11891
# [67]	validation_0-rmse:0.37238	validation_1-rmse:1.11904
# [68]	validation_0-rmse:0.37003	validation_1-rmse:1.12117
# [0]	validation_0-rmse:5.20192	validation_1-rmse:4.93210
# [1]	validation_0-rmse:4.61101	validation_1-rmse:4.35701
# [2]	validation_0-rmse:4.04179	validation_1-rmse:3.78017
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:3.59988	validation_1-rmse:3.33450
# [4]	validation_0-rmse:3.23346	validation_1-rmse:2.99283
# [5]	validation_0-rmse:2.91519	validation_1-rmse:2.67339
# [6]	validation_0-rmse:2.65397	validation_1-rmse:2.40648
# [7]	validation_0-rmse:2.34713	validation_1-rmse:2.08041
# [8]	validation_0-rmse:2.15725	validation_1-rmse:1.91650
# [9]	validation_0-rmse:1.93521	validation_1-rmse:1.68832
# [10]	validation_0-rmse:1.80082	validation_1-rmse:1.56837
# [11]	validation_0-rmse:1.61740	validation_1-rmse:1.40988
# [12]	validation_0-rmse:1.51325	validation_1-rmse:1.32658
# [13]	validation_0-rmse:1.37237	validation_1-rmse:1.21734
# [14]	validation_0-rmse:1.29230	validation_1-rmse:1.16764
# [15]	validation_0-rmse:1.18537	validation_1-rmse:1.09193
# [16]	validation_0-rmse:1.09465	validation_1-rmse:1.02436
# [17]	validation_0-rmse:1.05113	validation_1-rmse:1.01834
# [18]	validation_0-rmse:1.01651	validation_1-rmse:1.02188
# [19]	validation_0-rmse:0.98252	validation_1-rmse:1.00707
# [20]	validation_0-rmse:0.95900	validation_1-rmse:1.00798
# [21]	validation_0-rmse:0.89996	validation_1-rmse:0.96632
# [22]	validation_0-rmse:0.84866	validation_1-rmse:0.95385
# [23]	validation_0-rmse:0.82981	validation_1-rmse:0.95463
# [24]	validation_0-rmse:0.79253	validation_1-rmse:0.93534
# [25]	validation_0-rmse:0.75816	validation_1-rmse:0.93675
# [26]	validation_0-rmse:0.72002	validation_1-rmse:0.91497
# [27]	validation_0-rmse:0.69519	validation_1-rmse:0.90703
# [28]	validation_0-rmse:0.67323	validation_1-rmse:0.90211
# [29]	validation_0-rmse:0.65256	validation_1-rmse:0.89495
# [30]	validation_0-rmse:0.64257	validation_1-rmse:0.89441
# [31]	validation_0-rmse:0.62316	validation_1-rmse:0.88223
# [32]	validation_0-rmse:0.60573	validation_1-rmse:0.88583
# [33]	validation_0-rmse:0.59583	validation_1-rmse:0.88463
# [34]	validation_0-rmse:0.58716	validation_1-rmse:0.88570
# [35]	validation_0-rmse:0.57403	validation_1-rmse:0.88354
# [36]	validation_0-rmse:0.56620	validation_1-rmse:0.88278
# [37]	validation_0-rmse:0.55189	validation_1-rmse:0.88423
# [38]	validation_0-rmse:0.54403	validation_1-rmse:0.87204
# [39]	validation_0-rmse:0.53846	validation_1-rmse:0.87174
# [40]	validation_0-rmse:0.52686	validation_1-rmse:0.86801
# [41]	validation_0-rmse:0.51932	validation_1-rmse:0.87565
# [42]	validation_0-rmse:0.51460	validation_1-rmse:0.87658
# [43]	validation_0-rmse:0.50669	validation_1-rmse:0.87162
# [44]	validation_0-rmse:0.49826	validation_1-rmse:0.87513
# [45]	validation_0-rmse:0.49259	validation_1-rmse:0.87503
# [46]	validation_0-rmse:0.48754	validation_1-rmse:0.87465
# [47]	validation_0-rmse:0.48359	validation_1-rmse:0.87361
# [48]	validation_0-rmse:0.48092	validation_1-rmse:0.87055
# [49]	validation_0-rmse:0.47545	validation_1-rmse:0.86376
# [50]	validation_0-rmse:0.46851	validation_1-rmse:0.86542
# [51]	validation_0-rmse:0.46396	validation_1-rmse:0.86598
# [52]	validation_0-rmse:0.46028	validation_1-rmse:0.86410
# [53]	validation_0-rmse:0.45365	validation_1-rmse:0.85704
# [54]	validation_0-rmse:0.45105	validation_1-rmse:0.85313
# [55]	validation_0-rmse:0.44469	validation_1-rmse:0.85243
# [56]	validation_0-rmse:0.43966	validation_1-rmse:0.84578
# [57]	validation_0-rmse:0.43442	validation_1-rmse:0.84705
# [58]	validation_0-rmse:0.42832	validation_1-rmse:0.84729
# [59]	validation_0-rmse:0.42643	validation_1-rmse:0.84776
# [60]	validation_0-rmse:0.42236	validation_1-rmse:0.85293
# [61]	validation_0-rmse:0.41770	validation_1-rmse:0.84834
# [62]	validation_0-rmse:0.41250	validation_1-rmse:0.84686
# [63]	validation_0-rmse:0.41021	validation_1-rmse:0.84555
# [64]	validation_0-rmse:0.40822	validation_1-rmse:0.84314
# [65]	validation_0-rmse:0.40627	validation_1-rmse:0.83979
# [66]	validation_0-rmse:0.40243	validation_1-rmse:0.84247
# [67]	validation_0-rmse:0.39865	validation_1-rmse:0.84591
# [68]	validation_0-rmse:0.39745	validation_1-rmse:0.84455
# [69]	validation_0-rmse:0.39241	validation_1-rmse:0.84371
# [70]	validation_0-rmse:0.38851	validation_1-rmse:0.84223
# [71]	validation_0-rmse:0.38453	validation_1-rmse:0.84303
# [72]	validation_0-rmse:0.38302	validation_1-rmse:0.83995
# [73]	validation_0-rmse:0.38032	validation_1-rmse:0.83836
# [74]	validation_0-rmse:0.37759	validation_1-rmse:0.83944
# [75]	validation_0-rmse:0.37541	validation_1-rmse:0.84015
# [76]	validation_0-rmse:0.37116	validation_1-rmse:0.84002
# [77]	validation_0-rmse:0.37011	validation_1-rmse:0.84011
# [78]	validation_0-rmse:0.36621	validation_1-rmse:0.83900
# [79]	validation_0-rmse:0.36373	validation_1-rmse:0.83858
# [80]	validation_0-rmse:0.36104	validation_1-rmse:0.83346
# [81]	validation_0-rmse:0.35567	validation_1-rmse:0.83319
# [82]	validation_0-rmse:0.35387	validation_1-rmse:0.83414
# [83]	validation_0-rmse:0.35264	validation_1-rmse:0.83372
# [84]	validation_0-rmse:0.35129	validation_1-rmse:0.83385
# [85]	validation_0-rmse:0.34998	validation_1-rmse:0.83642
# [86]	validation_0-rmse:0.34568	validation_1-rmse:0.83703
# [87]	validation_0-rmse:0.34027	validation_1-rmse:0.83832
# [88]	validation_0-rmse:0.34027	validation_1-rmse:0.83845
# [89]	validation_0-rmse:0.33858	validation_1-rmse:0.83799
# [90]	validation_0-rmse:0.33635	validation_1-rmse:0.83747
# [91]	validation_0-rmse:0.33560	validation_1-rmse:0.83843
# [92]	validation_0-rmse:0.33315	validation_1-rmse:0.83774
# [93]	validation_0-rmse:0.33182	validation_1-rmse:0.83769
# [94]	validation_0-rmse:0.33015	validation_1-rmse:0.83944
# [95]	validation_0-rmse:0.32765	validation_1-rmse:0.84002
# [96]	validation_0-rmse:0.32425	validation_1-rmse:0.83996
# [97]	validation_0-rmse:0.32319	validation_1-rmse:0.84006
# [98]	validation_0-rmse:0.32000	validation_1-rmse:0.84119
# [99]	validation_0-rmse:0.31728	validation_1-rmse:0.84073
# [100]	validation_0-rmse:0.31292	validation_1-rmse:0.83996
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['16%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-2, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.755
# Uncertainty
# a0: 1.60+/-0.182
# a1: 0.720+/-0.028

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: AEDR_mean: mean - 1.162, median - 1.16, CI - [1.13-1.204]
#
# SHAP-values for: A_year: mean - 0.454, median - 0.46, CI - [0.41-0.486]
#
# SHAP-values for: D_cm: mean - 0.233, median - 0.229, CI - [0.204-0.275]
#
# SHAP-values for: F_Soil_ID: mean - 0.196, median - 0.204, CI - [0.162-0.226]
#
# SHAP-values for: G_m2_ha: mean - 0.19, median - 0.195, CI - [0.156-0.211]
#
# SHAP-values for: H_m: mean - 0.194, median - 0.199, CI - [0.169-0.217]
#
# SHAP-values for: Species_ID: mean - 0.051, median - 0.051, CI - [0.044-0.06]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['AEDR_mean', 'A_year', 'D_cm', 'F_Soil_ID', 'H_m', 'G_m2_ha', 'Species_ID'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 76.55, median: 78.5,
#  pred. interval (P(0.025)-P(0.975)): 39.9-128.425,
#  conf. interval (p-value=0.95): 52.41-94.19
# ***
# Aggregate bias statistic:
#  mean: -0.104, median: -0.15,
#  pred. interval (P(0.025)-P(0.975)): -0.327-0.224,
#  conf. interval (p-value=0.95): -0.23-0.011
# ***
# Aggregate RMSE statistic:
#  mean: 1.012, median: 1.033, pred. interval (P(0.025)-P(0.975)): 0.723-1.278,
#  conf. interval (p-value=0.95): 0.865-1.151
# ***
# Aggregate MSE statistic:
#  mean: 1.051, median: 1.066, pred. interval (P(0.025)-P(0.975)): 0.534-1.635,
#  conf. interval (p-value=0.95): 0.752-1.325
# ***
# Aggregate R^2 statistic:
#  mean: 0.748, median: 0.745, pred. interval (P(0.025)-P(0.975)): 0.637-0.867,
#  conf. interval (p-value=0.95): 0.698-0.794
# ***
# Aggregate bias(%) statistic:
#  mean: -1.617, median: -0.15, pred. interval (P(0.025)-P(0.975)): -5.205-3.975,
#  conf. interval (p-value=0.95): -3.673-0.233
# ***
# Aggregate RMSE(%) statistic:
#  mean: 16.64, median: 16.968, pred. interval (P(0.025)-P(0.975)): 12.365-20.547,
#  conf. interval (p-value=0.95): 14.114-19.446
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -1257.862, median: -1048.202,
#  pred. interval (P(0.025)-P(0.975)): -2919.361--222.623,
#  conf. interval (p-value=0.95): -2201.581--504.269
# ***
# Aggregate RMSE statistic:
#  mean: 5355.279, median: 4318.893, pred. interval (P(0.025)-P(0.975)): 1753.293-12813.082,
#  conf. interval (p-value=0.95): 2516.186-10817.767
# ***
# Aggregate MSE statistic:
#  mean: 42584328.974, median: 18836088.912, pred. interval (P(0.025)-P(0.975)): 3076348.924-164240904.357,
#  conf. interval (p-value=0.95): 6726589.128-123231365.911
# ***
# Aggregate R^2 statistic:
#  mean: 0.48, median: 0.538, pred. interval (P(0.025)-P(0.975)): -0.084-0.857,
#  conf. interval (p-value=0.95): 0.251-0.686
# ***
# Aggregate bias(%) statistic:
#  mean: -40.351, median: -1048.202, pred. interval (P(0.025)-P(0.975)): -70.15--11.521,
#  conf. interval (p-value=0.95): -55.463--24.493
# ***
# Aggregate RMSE(%) statistic:
#  mean: 173.577, median: 151.782, pred. interval (P(0.025)-P(0.975)): 109.477-308.482,
#  conf. interval (p-value=0.95): 120.435-267.473
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

ln_intervals = pd.cut(results_y[predictor], [0, 2, 4, 6, 8, 10])
T_exp_intervals = pd.cut(results_y[predictor], [0, 20000, 40000, 60000, 80000, 100000])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

print(list(ln_grouped)[1][1][predictor])
# results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)
# Out:
# 2      2.397895
# 5      3.218876
# 8      2.833213
# 12     3.663562
# 17     2.708050
#          ...
# 821    2.995732
# 823    2.890372
# 831    3.367296
# 835    2.995732
# 836    3.610918
# Name: ln_A_Cs, Length: 164, dtype: float64

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=ln_grouped, inner="box", palette="Spectral", order=['AEDR_mean', 'A_year', 'D_cm', 'F_Soil_ID', 'H_m', 'G_m2_ha', 'Species_ID'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [57], in <cell line: 2>()
#       1 sns.set(font_scale=1.2)
# ----> 2 sns.violinplot(x="Importance", y="Feature", data=ln_grouped, inner="box", palette="Spectral", order=['AEDR_mean', 'A_year', 'D_cm', 'F_Soil_ID', 'H_m', 'G_m2_ha', 'Species_ID'])
#       3 sns.set(rc={'figure.figsize':(8,4)})
#       4 plt.show()
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:2400, in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2388 @_deprecate_positional_args
#    2389 def violinplot(
#    2390     *,
#    (...)
#    2397     ax=None, **kwargs,
#    2398 ):
# -> 2400     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
#    2401                              bw, cut, scale, scale_hue, gridsize,
#    2402                              width, inner, split, dodge, orient, linewidth,
#    2403                              color, palette, saturation)
#    2405     if ax is None:
#    2406         ax = plt.gca()
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:522, in _ViolinPlotter.__init__(self, x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation)
#     517 def __init__(self, x, y, hue, data, order, hue_order,
#     518              bw, cut, scale, scale_hue, gridsize,
#     519              width, inner, split, dodge, orient, linewidth,
#     520              color, palette, saturation):
# --> 522     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     523     self.establish_colors(color, palette, saturation)
#     524     self.estimate_densities(bw, cut, scale, scale_hue, gridsize)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:144, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     136 # Option 2:
#     137 # We are plotting a long-form dataset
#     138 # -----------------------------------
#    (...)
#     141
#     142     # See if we need to get variables from `data`
#     143     if data is not None:
# --> 144         x = data.get(x, x)
#     145         y = data.get(y, y)
#     146         hue = data.get(hue, hue)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'get'

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-2, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../01_output_data/XGBoost_models/05_LN_M_foliage_other_authors_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../01_output_data/XGBoost_models/05_LN_M_foliage_other_authors_XGB_model.txt")
