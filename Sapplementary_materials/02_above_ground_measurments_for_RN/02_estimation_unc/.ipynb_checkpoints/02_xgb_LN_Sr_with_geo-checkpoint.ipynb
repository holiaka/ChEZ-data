# %% [markdown]
# ## Processing with RN data obtained from forest sites

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../02_input_data/RN_sites_data.xlsx'
df = pd.read_excel(site_data, sheet_name='RN_filtration_data')
df.head()
# Out:
#    Ідентифікатор    Site # Species  Species_ID  Ntrees at site  % composition  \
# 0             81  001_2021    Pine           0              23     100.000000
# 1            219  002_2021    Pine           0              60      90.178571
# 2            224  003_2021    Pine           0              44     100.000000
# 3            228  004_2021    Pine           0              23     100.000000
# 4            232  005_2021    Pine           0              26     100.000000
#
#         D_cm        H_m    G_m2_ha  N_ha  ...   T_ag_Cs  ln_T_ag_Cs  \
# 0  26.060965  25.423284  49.081648   920  ...  0.781087   -0.247069
# 1   4.303100   4.705979   8.731641  6000  ...  1.549336    0.437826
# 2  28.142898  27.556869  54.703060   880  ...  0.583447   -0.538802
# 3  14.953551   8.506028  40.420188  2300  ...  0.145072   -1.930528
# 4   7.208435   3.425669   2.120687   520  ...  0.254295   -1.369259
#
#      T_ag_Sr  ln_T_ag_Sr  AEDR_count AEDR_mean  AEDR_median  AEDR_std  \
# 0   9.004084    2.197678          26  3.524231        3.530  0.235489
# 1  24.247024    3.188294          15  3.830667        3.780  0.166272
# 2   9.304047    2.230449          28  0.483571        0.475  0.068931
# 3   5.279971    1.663921          20  0.364500        0.365  0.029576
# 4   6.629225    1.891488          18  0.333333        0.345  0.036515
#
#    Distance_km  Azimuth
# 0     5.926403      249
# 1     6.018960      249
# 2    13.046428      189
# 3    12.741627      189
# 4    12.893213      189
#
# [5 rows x 51 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Species', 'Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
#                                     'Origin', 'Origin_ID','A_year', 'D_live_cm', 'H_live_m', 'G_live_m2_ha',
#                                     'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
#                                     'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_A_Cs', 'ln_A_Sr',
#                                     'T_ag_Cs', 'ln_T_ag_Cs', 'T_ag_Sr', 'ln_T_ag_Sr'
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species', 'Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
                                    'Origin', 'Origin_ID','A_year',
                                    'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
                                    'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_A_Cs', 'ln_A_Sr', 
                                    'ln_T_ag_Cs', 'ln_T_ag_Sr'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#   Species  Species_ID  % composition       D_cm        H_m    G_m2_ha Origin  \
# 0    Pine           0     100.000000  26.060965  25.423284  49.081648      a
# 1    Pine           0      90.178571   4.303100   4.705979   8.731641      n
# 2    Pine           0     100.000000  28.142898  27.556869  54.703060      n
# 3    Pine           0     100.000000  14.953551   8.506028  40.420188      n
# 4    Pine           0     100.000000   7.208435   3.425669   2.120687      n
#
#    Origin_ID  A_year  F_Soil_ID  M_Soil  AEDR_mean  Distance_km  Azimuth  \
# 0          1      68          1       2   3.524231     5.926403      249
# 1          0      15          1       2   3.830667     6.018960      249
# 2          0      69          1       2   0.483571    13.046428      189
# 3          0      15          2       2   0.364500    12.741627      189
# 4          0      10          2       2   0.333333    12.893213      189
#
#    Cs_2021_kBq_m  Sr_2021_kBq_m   ln_A_Cs    ln_A_Sr  ln_T_ag_Cs  ln_T_ag_Sr
# 0    2842.194109     998.435843  7.705262   9.103868   -0.247069    2.197678
# 1    2930.287815     987.750099  8.420682  10.083724    0.437826    3.188294
# 2     281.088291      65.777826  5.099866   6.416732   -0.538802    2.230449
# 3     289.512268      69.886752  3.737670   5.910797   -1.930528    1.663921
# 4     287.067816      69.993095  4.290459   6.139885   -1.369259    1.891488

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Species        209 non-null    object
#  1   Species_ID     209 non-null    int64
#  2   % composition  209 non-null    float64
#  3   D_cm           209 non-null    float64
#  4   H_m            209 non-null    float64
#  5   G_m2_ha        209 non-null    float64
#  6   Origin         209 non-null    object
#  7   Origin_ID      209 non-null    int64
#  8   A_year         209 non-null    int64
#  9   F_Soil_ID      209 non-null    int64
#  10  M_Soil         209 non-null    int64
#  11  AEDR_mean      209 non-null    float64
#  12  Distance_km    209 non-null    float64
#  13  Azimuth        209 non-null    int64
#  14  Cs_2021_kBq_m  209 non-null    float64
#  15  Sr_2021_kBq_m  209 non-null    float64
#  16  ln_A_Cs        209 non-null    float64
#  17  ln_A_Sr        209 non-null    float64
#  18  ln_T_ag_Cs     209 non-null    float64
#  19  ln_T_ag_Sr     209 non-null    float64
# dtypes: float64(12), int64(6), object(2)
# memory usage: 32.8+ KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species"])["ln_A_Cs", "ln_A_Sr"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#         ln_A_Cs                                                              \
#           count      mean       std       min       25%       50%       75%
# Species
# Alder      13.0  6.249674  1.661129  3.295837  5.840642  6.040255  6.940222
# Aspen       9.0  5.584313  3.039601  2.708050  3.295837  4.204693  6.729824
# Birch      45.0  5.737563  2.249143  2.079442  3.761200  6.173786  7.229839
# Oak         7.0  6.900674  2.917841  2.397895  4.966038  7.753624  9.021902
# Pine      130.0  6.066275  1.963371  1.504077  4.358932  6.564371  7.374614
# Red oak     3.0  3.445685  0.588708  2.833213  3.164860  3.496508  3.751920
# Robinia     1.0  4.394449       NaN  4.394449  4.394449  4.394449  4.394449
# Spruce      1.0  5.176150       NaN  5.176150  5.176150  5.176150  5.176150
#
#                    ln_A_Sr                                                    \
#                max   count      mean       std       min       25%       50%
# Species
# Alder     9.287301    13.0  6.055811  1.449620  4.094345  4.442651  6.302619
# Aspen    11.366743     9.0  7.575485  2.597130  4.615121  5.209486  7.870930
# Birch    10.332018    45.0  7.671630  2.317833  2.660260  5.752573  7.749322
# Oak      10.177324     7.0  7.188390  2.638333  3.871201  5.248545  7.766417
# Pine     10.468801   130.0  7.470846  1.889243  2.406945  6.165469  7.588295
# Red oak   4.007333     3.0  4.697638  0.334751  4.418841  4.512005  4.605170
# Robinia   4.394449     1.0  7.265430       NaN  7.265430  7.265430  7.265430
# Spruce    5.176150     1.0  7.783224       NaN  7.783224  7.783224  7.783224
#
#
#               75%        max
# Species
# Alder    7.286192   7.649693
# Aspen    8.881836  11.180246
# Birch    8.995909  13.864301
# Oak      8.529114  11.125791
# Pine     8.730280  12.687263
# Red oak  4.837037   5.068904
# Robinia  7.265430   7.265430
# Spruce   7.783224   7.783224

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID  % composition        D_cm         H_m     G_m2_ha  \
# count  209.000000     209.000000  209.000000  209.000000  209.000000
# mean     1.057416      94.337925   17.770981   16.978858   30.000765
# std      1.524339      14.155594    8.921738    6.832292   15.907971
# min      0.000000      20.805369    1.914854    2.704460    0.259356
# 25%      0.000000      96.775081   11.601519   12.401789   17.519173
# 50%      0.000000     100.000000   16.817809   17.466646   30.845307
# 75%      2.000000     100.000000   22.264253   21.414562   42.817263
# max      5.000000     100.000000   52.228464   34.048688   66.922093
#
#         Origin_ID      A_year   F_Soil_ID      M_Soil   AEDR_mean  \
# count  209.000000  209.000000  209.000000  209.000000  209.000000
# mean     0.454545   47.464115    1.918660    2.220096    2.526858
# std      0.499125   24.724635    0.634039    0.692944    4.756383
# min      0.000000   10.000000    1.000000    0.000000    0.110000
# 25%      0.000000   30.000000    2.000000    2.000000    0.460000
# 50%      0.000000   45.000000    2.000000    2.000000    0.756000
# 75%      1.000000   60.000000    2.000000    3.000000    2.401667
# max      1.000000  150.000000    3.000000    4.000000   36.591739
#
#        Distance_km     Azimuth  Cs_2021_kBq_m  Sr_2021_kBq_m     ln_A_Cs  \
# count   209.000000  209.000000     209.000000     209.000000  209.000000
# mean     14.640059  174.296651    2040.059453     670.875816    5.964225
# std      12.363729   99.912885    3821.573719    1529.917216    2.095016
# min       3.998568    9.000000      28.815348       2.402062    1.504077
# 25%       6.562497   56.000000     446.906289      44.007562    4.110874
# 50%       9.203749  189.000000     708.799781     187.465954    6.309918
# 75%      20.865459  261.000000    1940.992207     442.523198    7.306531
# max      57.286577  342.000000   25173.384978   10477.431302   11.366743
#
#           ln_A_Sr  ln_T_ag_Cs  ln_T_ag_Sr
# count  209.000000  209.000000  209.000000
# mean     7.381811   -0.640088    2.317915
# std      2.042856    1.288804    0.931775
# min      2.406945   -4.677466   -0.222660
# 25%      5.752573   -1.390832    1.734814
# 50%      7.506592   -0.504711    2.420262
# 75%      8.846497    0.338120    2.967019
# max     13.864301    1.651960    4.658771

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_A_Sr"
indep_variables = ['Species_ID', 'D_cm', 'F_Soil_ID', 'AEDR_mean',
    'Sr_2021_kBq_m', 'Distance_km', 'Azimuth']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#     Species  Species_ID  % composition       D_cm        H_m    G_m2_ha  \
# 0      Pine           0     100.000000  26.060965  25.423284  49.081648
# 1      Pine           0      90.178571   4.303100   4.705979   8.731641
# 2      Pine           0     100.000000  28.142898  27.556869  54.703060
# 3      Pine           0     100.000000  14.953551   8.506028  40.420188
# 4      Pine           0     100.000000   7.208435   3.425669   2.120687
# ..      ...         ...            ...        ...        ...        ...
# 204   Aspen           4      99.930119  11.401754  14.676282  17.972410
# 205   Birch           2     100.000000   7.912790  13.818368  19.279495
# 206    Pine           0     100.000000  16.041613  17.515821  31.533411
# 207    Pine           0      96.775081  14.946465  18.178975  44.220927
# 208    Pine           0     100.000000  15.387224  17.673021  55.824342
#
#     Origin  Origin_ID  A_year  F_Soil_ID  M_Soil  AEDR_mean  Distance_km  \
# 0        a          1      68          1       2   3.524231     5.926403
# 1        n          0      15          1       2   3.830667     6.018960
# 2        n          0      69          1       2   0.483571    13.046428
# 3        n          0      15          2       2   0.364500    12.741627
# 4        n          0      10          2       2   0.333333    12.893213
# ..     ...        ...     ...        ...     ...        ...          ...
# 204      n          0      25          2       3  20.051250     5.190617
# 205      n          0      18          2       3  14.987391     4.749715
# 206      a          1      58          1       2   0.650000     7.850538
# 207      a          1      60          1       2   0.649063     7.276525
# 208      a          1      40          1       2   0.628214     7.292122
#
#      Azimuth  Cs_2021_kBq_m  Sr_2021_kBq_m    ln_A_Cs    ln_A_Sr  ln_T_ag_Cs  \
# 0        249    2842.194109     998.435843   7.705262   9.103868   -0.247069
# 1        249    2930.287815     987.750099   8.420682  10.083724    0.437826
# 2        189     281.088291      65.777826   5.099866   6.416732   -0.538802
# 3        189     289.512268      69.886752   3.737670   5.910797   -1.930528
# 4        189     287.067816      69.993095   4.290459   6.139885   -1.369259
# ..       ...            ...            ...        ...        ...         ...
# 204      265   18333.074578    7311.788354  11.366743  11.089805    1.550281
# 205      262   22082.849575    8387.428089   9.539644  11.501865   -0.462912
# 206      106     539.850835     148.369587   6.498282   8.283999    0.206989
# 207       85     519.756852     136.839876   6.720220   8.575462    0.466859
# 208       86     518.079556     135.439932   6.674561   8.216088    0.424433
#
#      ln_T_ag_Sr
# 0      2.197678
# 1      3.188294
# 2      2.230449
# 3      1.663921
# 4      1.891488
# ..          ...
# 204    2.192562
# 205    2.467375
# 206    3.284293
# 207    3.656651
# 208    3.307560
#
# [209 rows x 20 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID       D_cm  F_Soil_ID  AEDR_mean  Sr_2021_kBq_m  Distance_km  \
# 0           0  26.060965          1   3.524231     998.435843     5.926403
# 1           0   4.303100          1   3.830667     987.750099     6.018960
# 2           0  28.142898          1   0.483571      65.777826    13.046428
# 3           0  14.953551          2   0.364500      69.886752    12.741627
# 4           0   7.208435          2   0.333333      69.993095    12.893213
#
#    Azimuth
# 0      249
# 1      249
# 2      189
# 3      189
# 4      189

# %%
# Columns in "y" data collections
y.head()
# Out:
#      ln_A_Sr
# 0   9.103868
# 1  10.083724
# 2   6.416732
# 3   5.910797
# 4   6.139885

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.7952093475818266, 0.90132866255006, 0.8684443952023669]
#     Mean: 0.855
#     Std: 0.044
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.80192237 0.83710553 0.71174282]
#     Mean: 0.784
#     Std: 0.053
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.5811513441396344, 0.5558660149788, 0.6580365752285667]
#     Mean: 0.598
#     Std: 0.043
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.9176503346702123                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.32416217454349816                 # gamma
print('Gamma: ' + str(p2))

p3 = 0.09251860424939151                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2            # max_depth
print('Max_depth: ' + str(p4))

p5 = 164          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.34765153803612303                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.9176503346702123
# Gamma: 0.32416217454349816
# Learning_rate: 0.09251860424939151
# Max_depth: 2
# N_estimators: 164
# Subsample: 0.34765153803612303

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    exp_R_square = r2_score(exp_y_test, exp_y_pred)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:6.60782	validation_1-rmse:6.36020
# [1]	validation_0-rmse:6.04591	validation_1-rmse:5.83644
# [2]	validation_0-rmse:5.49847	validation_1-rmse:5.34289
# [3]	validation_0-rmse:5.02490	validation_1-rmse:4.91183
# [4]	validation_0-rmse:4.60146	validation_1-rmse:4.50932
# [5]	validation_0-rmse:4.21078	validation_1-rmse:4.15664
# [6]	validation_0-rmse:3.85761	validation_1-rmse:3.82402
# [7]	validation_0-rmse:3.53975	validation_1-rmse:3.53293
# [8]	validation_0-rmse:3.24460	validation_1-rmse:3.26614
# [9]	validation_0-rmse:2.96652	validation_1-rmse:3.01508
# [10]	validation_0-rmse:2.73007	validation_1-rmse:2.80133
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:2.50693	validation_1-rmse:2.59882
# [12]	validation_0-rmse:2.31641	validation_1-rmse:2.42345
# [13]	validation_0-rmse:2.14493	validation_1-rmse:2.24687
# [14]	validation_0-rmse:1.97767	validation_1-rmse:2.09332
# [15]	validation_0-rmse:1.83728	validation_1-rmse:1.97590
# [16]	validation_0-rmse:1.70625	validation_1-rmse:1.85091
# [17]	validation_0-rmse:1.58201	validation_1-rmse:1.73179
# [18]	validation_0-rmse:1.45979	validation_1-rmse:1.62031
# [19]	validation_0-rmse:1.36630	validation_1-rmse:1.53568
# [20]	validation_0-rmse:1.28530	validation_1-rmse:1.46019
# [21]	validation_0-rmse:1.21377	validation_1-rmse:1.40617
# [22]	validation_0-rmse:1.14496	validation_1-rmse:1.35970
# [23]	validation_0-rmse:1.08672	validation_1-rmse:1.31402
# [24]	validation_0-rmse:1.02702	validation_1-rmse:1.27314
# [25]	validation_0-rmse:0.95982	validation_1-rmse:1.20316
# [26]	validation_0-rmse:0.92150	validation_1-rmse:1.17678
# [27]	validation_0-rmse:0.87929	validation_1-rmse:1.14142
# [28]	validation_0-rmse:0.83588	validation_1-rmse:1.09569
# [29]	validation_0-rmse:0.81156	validation_1-rmse:1.08527
# [30]	validation_0-rmse:0.78352	validation_1-rmse:1.06022
# [31]	validation_0-rmse:0.75608	validation_1-rmse:1.03492
# [32]	validation_0-rmse:0.73352	validation_1-rmse:1.02313
# [33]	validation_0-rmse:0.71070	validation_1-rmse:0.99885
# [34]	validation_0-rmse:0.69667	validation_1-rmse:0.98433
# [35]	validation_0-rmse:0.68335	validation_1-rmse:0.97041
# [36]	validation_0-rmse:0.66067	validation_1-rmse:0.94894
# [37]	validation_0-rmse:0.64820	validation_1-rmse:0.93467
# [38]	validation_0-rmse:0.63837	validation_1-rmse:0.92437
# [39]	validation_0-rmse:0.62755	validation_1-rmse:0.91495
# [40]	validation_0-rmse:0.61798	validation_1-rmse:0.90613
# [41]	validation_0-rmse:0.61287	validation_1-rmse:0.90181
# [42]	validation_0-rmse:0.60436	validation_1-rmse:0.90069
# [43]	validation_0-rmse:0.59283	validation_1-rmse:0.88808
# [44]	validation_0-rmse:0.58381	validation_1-rmse:0.87753
# [45]	validation_0-rmse:0.57411	validation_1-rmse:0.87390
# [46]	validation_0-rmse:0.56666	validation_1-rmse:0.86370
# [47]	validation_0-rmse:0.56120	validation_1-rmse:0.85958
# [48]	validation_0-rmse:0.55976	validation_1-rmse:0.85598
# [49]	validation_0-rmse:0.55773	validation_1-rmse:0.85299
# [50]	validation_0-rmse:0.55235	validation_1-rmse:0.84507
# [51]	validation_0-rmse:0.55064	validation_1-rmse:0.84050
# [52]	validation_0-rmse:0.54231	validation_1-rmse:0.83393
# [53]	validation_0-rmse:0.53707	validation_1-rmse:0.83099
# [54]	validation_0-rmse:0.53210	validation_1-rmse:0.83074
# [55]	validation_0-rmse:0.52701	validation_1-rmse:0.81889
# [56]	validation_0-rmse:0.52191	validation_1-rmse:0.81438
# [57]	validation_0-rmse:0.51875	validation_1-rmse:0.81128
# [58]	validation_0-rmse:0.51644	validation_1-rmse:0.80716
# [59]	validation_0-rmse:0.51233	validation_1-rmse:0.80606
# [60]	validation_0-rmse:0.50980	validation_1-rmse:0.80506
# [61]	validation_0-rmse:0.50481	validation_1-rmse:0.80323
# [62]	validation_0-rmse:0.50152	validation_1-rmse:0.80933
# [63]	validation_0-rmse:0.49787	validation_1-rmse:0.80854
# [64]	validation_0-rmse:0.49445	validation_1-rmse:0.81054
# [65]	validation_0-rmse:0.49148	validation_1-rmse:0.80196
# [66]	validation_0-rmse:0.49137	validation_1-rmse:0.80300
# [67]	validation_0-rmse:0.48927	validation_1-rmse:0.80140
# [68]	validation_0-rmse:0.48568	validation_1-rmse:0.80067
# [69]	validation_0-rmse:0.48285	validation_1-rmse:0.79735
# [70]	validation_0-rmse:0.48066	validation_1-rmse:0.79934
# [71]	validation_0-rmse:0.47891	validation_1-rmse:0.79579
# [72]	validation_0-rmse:0.47669	validation_1-rmse:0.79084
# [73]	validation_0-rmse:0.47151	validation_1-rmse:0.78832
# [74]	validation_0-rmse:0.46943	validation_1-rmse:0.78637
# [75]	validation_0-rmse:0.46595	validation_1-rmse:0.78086
# [76]	validation_0-rmse:0.46354	validation_1-rmse:0.78293
# [77]	validation_0-rmse:0.46185	validation_1-rmse:0.77989
# [78]	validation_0-rmse:0.45904	validation_1-rmse:0.78112
# [79]	validation_0-rmse:0.45325	validation_1-rmse:0.77793
# [80]	validation_0-rmse:0.44978	validation_1-rmse:0.78389
# [81]	validation_0-rmse:0.44905	validation_1-rmse:0.78411
# [82]	validation_0-rmse:0.44479	validation_1-rmse:0.78113
# [83]	validation_0-rmse:0.44380	validation_1-rmse:0.77630
# [84]	validation_0-rmse:0.44111	validation_1-rmse:0.77504
# [85]	validation_0-rmse:0.43861	validation_1-rmse:0.77135
# [86]	validation_0-rmse:0.43720	validation_1-rmse:0.77163
# [87]	validation_0-rmse:0.43602	validation_1-rmse:0.77159
# [88]	validation_0-rmse:0.43265	validation_1-rmse:0.77018
# [89]	validation_0-rmse:0.43208	validation_1-rmse:0.77207
# [90]	validation_0-rmse:0.43099	validation_1-rmse:0.77569
# [91]	validation_0-rmse:0.42924	validation_1-rmse:0.77309
# [92]	validation_0-rmse:0.42700	validation_1-rmse:0.76982
# [93]	validation_0-rmse:0.42562	validation_1-rmse:0.77161
# [94]	validation_0-rmse:0.42381	validation_1-rmse:0.77493
# [95]	validation_0-rmse:0.42196	validation_1-rmse:0.77226
# [96]	validation_0-rmse:0.41894	validation_1-rmse:0.76922
# [97]	validation_0-rmse:0.41751	validation_1-rmse:0.76085
# [98]	validation_0-rmse:0.41456	validation_1-rmse:0.75890
# [99]	validation_0-rmse:0.41126	validation_1-rmse:0.75810
# [100]	validation_0-rmse:0.41013	validation_1-rmse:0.75839
# [101]	validation_0-rmse:0.40693	validation_1-rmse:0.75901
# [102]	validation_0-rmse:0.40650	validation_1-rmse:0.75902
# [103]	validation_0-rmse:0.40487	validation_1-rmse:0.75751
# [104]	validation_0-rmse:0.40487	validation_1-rmse:0.75763
# [105]	validation_0-rmse:0.40378	validation_1-rmse:0.75668
# [106]	validation_0-rmse:0.40238	validation_1-rmse:0.75857
# [107]	validation_0-rmse:0.40125	validation_1-rmse:0.75761
# [108]	validation_0-rmse:0.39949	validation_1-rmse:0.75350
# [109]	validation_0-rmse:0.39737	validation_1-rmse:0.75754
# [110]	validation_0-rmse:0.39325	validation_1-rmse:0.75652
# [111]	validation_0-rmse:0.39085	validation_1-rmse:0.75907
# [112]	validation_0-rmse:0.38797	validation_1-rmse:0.75864
# [113]	validation_0-rmse:0.38633	validation_1-rmse:0.75566
# [114]	validation_0-rmse:0.38608	validation_1-rmse:0.75834
# [115]	validation_0-rmse:0.38430	validation_1-rmse:0.75761
# [116]	validation_0-rmse:0.38340	validation_1-rmse:0.75276
# [117]	validation_0-rmse:0.38128	validation_1-rmse:0.75289
# [118]	validation_0-rmse:0.38049	validation_1-rmse:0.74906
# [119]	validation_0-rmse:0.37995	validation_1-rmse:0.74950
# [120]	validation_0-rmse:0.37929	validation_1-rmse:0.74821
# [121]	validation_0-rmse:0.37806	validation_1-rmse:0.74535
# [122]	validation_0-rmse:0.37757	validation_1-rmse:0.74174
# [123]	validation_0-rmse:0.37673	validation_1-rmse:0.74155
# [124]	validation_0-rmse:0.37584	validation_1-rmse:0.73767
# [125]	validation_0-rmse:0.37458	validation_1-rmse:0.73833
# [126]	validation_0-rmse:0.37380	validation_1-rmse:0.73874
# [127]	validation_0-rmse:0.37259	validation_1-rmse:0.73751
# [128]	validation_0-rmse:0.37227	validation_1-rmse:0.73819
# [129]	validation_0-rmse:0.37114	validation_1-rmse:0.73564
# [130]	validation_0-rmse:0.37018	validation_1-rmse:0.73245
# [131]	validation_0-rmse:0.36733	validation_1-rmse:0.73220
# [132]	validation_0-rmse:0.36746	validation_1-rmse:0.73196
# [133]	validation_0-rmse:0.36636	validation_1-rmse:0.73144
# [134]	validation_0-rmse:0.36498	validation_1-rmse:0.73017
# [135]	validation_0-rmse:0.36380	validation_1-rmse:0.72689
# [136]	validation_0-rmse:0.36299	validation_1-rmse:0.72306
# [137]	validation_0-rmse:0.36175	validation_1-rmse:0.72439
# [138]	validation_0-rmse:0.36009	validation_1-rmse:0.72381
# [139]	validation_0-rmse:0.35952	validation_1-rmse:0.72361
# [140]	validation_0-rmse:0.35955	validation_1-rmse:0.72188
# [141]	validation_0-rmse:0.35862	validation_1-rmse:0.72114
# [142]	validation_0-rmse:0.35645	validation_1-rmse:0.72274
# [143]	validation_0-rmse:0.35469	validation_1-rmse:0.72424
# [144]	validation_0-rmse:0.35364	validation_1-rmse:0.72558
# [145]	validation_0-rmse:0.35295	validation_1-rmse:0.72356
# [146]	validation_0-rmse:0.35188	validation_1-rmse:0.72217
# [147]	validation_0-rmse:0.35167	validation_1-rmse:0.72042
# [148]	validation_0-rmse:0.34954	validation_1-rmse:0.72162
# [149]	validation_0-rmse:0.34954	validation_1-rmse:0.72162
# [150]	validation_0-rmse:0.34994	validation_1-rmse:0.72358
# [151]	validation_0-rmse:0.34884	validation_1-rmse:0.72399
# [152]	validation_0-rmse:0.34834	validation_1-rmse:0.72481
# [153]	validation_0-rmse:0.34674	validation_1-rmse:0.72666
# [154]	validation_0-rmse:0.34397	validation_1-rmse:0.73222
# [155]	validation_0-rmse:0.34293	validation_1-rmse:0.73015
# [156]	validation_0-rmse:0.34287	validation_1-rmse:0.72844
# [157]	validation_0-rmse:0.34264	validation_1-rmse:0.72980
# [158]	validation_0-rmse:0.34124	validation_1-rmse:0.72661
# [159]	validation_0-rmse:0.34104	validation_1-rmse:0.72351
# [160]	validation_0-rmse:0.33956	validation_1-rmse:0.72233
# [161]	validation_0-rmse:0.33867	validation_1-rmse:0.72509
# [162]	validation_0-rmse:0.33813	validation_1-rmse:0.72134
# [163]	validation_0-rmse:0.33755	validation_1-rmse:0.72229
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.75785	validation_1-rmse:5.81190
# [1]	validation_0-rmse:6.19342	validation_1-rmse:5.31667
# [2]	validation_0-rmse:5.64939	validation_1-rmse:4.87444
# [3]	validation_0-rmse:5.18361	validation_1-rmse:4.47365
# [4]	validation_0-rmse:4.74099	validation_1-rmse:4.09351
# [5]	validation_0-rmse:4.34743	validation_1-rmse:3.74193
# [6]	validation_0-rmse:3.97372	validation_1-rmse:3.42229
# [7]	validation_0-rmse:3.64182	validation_1-rmse:3.15554
# [8]	validation_0-rmse:3.33972	validation_1-rmse:2.89995
# [9]	validation_0-rmse:3.09066	validation_1-rmse:2.67253
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [10]	validation_0-rmse:2.83159	validation_1-rmse:2.46183
# [11]	validation_0-rmse:2.61191	validation_1-rmse:2.27969
# [12]	validation_0-rmse:2.41263	validation_1-rmse:2.11336
# [13]	validation_0-rmse:2.24011	validation_1-rmse:1.95806
# [14]	validation_0-rmse:2.06796	validation_1-rmse:1.83231
# [15]	validation_0-rmse:1.91785	validation_1-rmse:1.71282
# [16]	validation_0-rmse:1.78115	validation_1-rmse:1.61925
# [17]	validation_0-rmse:1.65171	validation_1-rmse:1.51707
# [18]	validation_0-rmse:1.53203	validation_1-rmse:1.43053
# [19]	validation_0-rmse:1.42942	validation_1-rmse:1.36694
# [20]	validation_0-rmse:1.33250	validation_1-rmse:1.29322
# [21]	validation_0-rmse:1.25700	validation_1-rmse:1.24528
# [22]	validation_0-rmse:1.17705	validation_1-rmse:1.18882
# [23]	validation_0-rmse:1.11214	validation_1-rmse:1.13809
# [24]	validation_0-rmse:1.05792	validation_1-rmse:1.11172
# [25]	validation_0-rmse:1.00929	validation_1-rmse:1.08609
# [26]	validation_0-rmse:0.97592	validation_1-rmse:1.06776
# [27]	validation_0-rmse:0.92303	validation_1-rmse:1.04767
# [28]	validation_0-rmse:0.88686	validation_1-rmse:1.02842
# [29]	validation_0-rmse:0.85589	validation_1-rmse:1.01488
# [30]	validation_0-rmse:0.81963	validation_1-rmse:0.99684
# [31]	validation_0-rmse:0.79348	validation_1-rmse:0.98593
# [32]	validation_0-rmse:0.76220	validation_1-rmse:0.96987
# [33]	validation_0-rmse:0.73751	validation_1-rmse:0.95367
# [34]	validation_0-rmse:0.72046	validation_1-rmse:0.94359
# [35]	validation_0-rmse:0.70445	validation_1-rmse:0.93863
# [36]	validation_0-rmse:0.68177	validation_1-rmse:0.93134
# [37]	validation_0-rmse:0.66338	validation_1-rmse:0.92242
# [38]	validation_0-rmse:0.64976	validation_1-rmse:0.91505
# [39]	validation_0-rmse:0.63561	validation_1-rmse:0.91470
# [40]	validation_0-rmse:0.62552	validation_1-rmse:0.91154
# [41]	validation_0-rmse:0.61400	validation_1-rmse:0.90624
# [42]	validation_0-rmse:0.60354	validation_1-rmse:0.90514
# [43]	validation_0-rmse:0.59677	validation_1-rmse:0.90418
# [44]	validation_0-rmse:0.58566	validation_1-rmse:0.90411
# [45]	validation_0-rmse:0.57931	validation_1-rmse:0.90729
# [46]	validation_0-rmse:0.57424	validation_1-rmse:0.90344
# [47]	validation_0-rmse:0.56945	validation_1-rmse:0.90104
# [48]	validation_0-rmse:0.56386	validation_1-rmse:0.90025
# [49]	validation_0-rmse:0.55999	validation_1-rmse:0.89600
# [50]	validation_0-rmse:0.55152	validation_1-rmse:0.90190
# [51]	validation_0-rmse:0.54379	validation_1-rmse:0.90055
# [52]	validation_0-rmse:0.53541	validation_1-rmse:0.89877
# [53]	validation_0-rmse:0.52818	validation_1-rmse:0.89869
# [54]	validation_0-rmse:0.52202	validation_1-rmse:0.89894
# [55]	validation_0-rmse:0.51715	validation_1-rmse:0.90451
# [56]	validation_0-rmse:0.51246	validation_1-rmse:0.90522
# [57]	validation_0-rmse:0.51003	validation_1-rmse:0.90784
# [58]	validation_0-rmse:0.50394	validation_1-rmse:0.90537
# [59]	validation_0-rmse:0.49923	validation_1-rmse:0.90119
# [60]	validation_0-rmse:0.49518	validation_1-rmse:0.90342
# [61]	validation_0-rmse:0.49311	validation_1-rmse:0.90358
# [62]	validation_0-rmse:0.49042	validation_1-rmse:0.90491
# [63]	validation_0-rmse:0.48936	validation_1-rmse:0.90521
# [64]	validation_0-rmse:0.48956	validation_1-rmse:0.90471
# [65]	validation_0-rmse:0.48475	validation_1-rmse:0.90644
# [66]	validation_0-rmse:0.48234	validation_1-rmse:0.90834
# [67]	validation_0-rmse:0.48091	validation_1-rmse:0.90234
# [68]	validation_0-rmse:0.47801	validation_1-rmse:0.90199
# [0]	validation_0-rmse:6.45279	validation_1-rmse:6.93072
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:5.88197	validation_1-rmse:6.33931
# [2]	validation_0-rmse:5.38148	validation_1-rmse:5.82917
# [3]	validation_0-rmse:4.93229	validation_1-rmse:5.36542
# [4]	validation_0-rmse:4.52221	validation_1-rmse:4.95393
# [5]	validation_0-rmse:4.15210	validation_1-rmse:4.59812
# [6]	validation_0-rmse:3.79456	validation_1-rmse:4.23196
# [7]	validation_0-rmse:3.47320	validation_1-rmse:3.90559
# [8]	validation_0-rmse:3.16799	validation_1-rmse:3.58694
# [9]	validation_0-rmse:2.91529	validation_1-rmse:3.32953
# [10]	validation_0-rmse:2.68632	validation_1-rmse:3.10160
# [11]	validation_0-rmse:2.48081	validation_1-rmse:2.88186
# [12]	validation_0-rmse:2.28286	validation_1-rmse:2.68704
# [13]	validation_0-rmse:2.10604	validation_1-rmse:2.49373
# [14]	validation_0-rmse:1.97155	validation_1-rmse:2.36495
# [15]	validation_0-rmse:1.82082	validation_1-rmse:2.20595
# [16]	validation_0-rmse:1.70218	validation_1-rmse:2.08053
# [17]	validation_0-rmse:1.59519	validation_1-rmse:1.98399
# [18]	validation_0-rmse:1.48512	validation_1-rmse:1.86953
# [19]	validation_0-rmse:1.38833	validation_1-rmse:1.75215
# [20]	validation_0-rmse:1.29584	validation_1-rmse:1.64216
# [21]	validation_0-rmse:1.20483	validation_1-rmse:1.53820
# [22]	validation_0-rmse:1.13308	validation_1-rmse:1.45176
# [23]	validation_0-rmse:1.08378	validation_1-rmse:1.40970
# [24]	validation_0-rmse:1.02836	validation_1-rmse:1.34348
# [25]	validation_0-rmse:0.97244	validation_1-rmse:1.27820
# [26]	validation_0-rmse:0.92780	validation_1-rmse:1.22766
# [27]	validation_0-rmse:0.89113	validation_1-rmse:1.19335
# [28]	validation_0-rmse:0.84930	validation_1-rmse:1.14271
# [29]	validation_0-rmse:0.82011	validation_1-rmse:1.10346
# [30]	validation_0-rmse:0.79470	validation_1-rmse:1.06508
# [31]	validation_0-rmse:0.76756	validation_1-rmse:1.03118
# [32]	validation_0-rmse:0.74497	validation_1-rmse:1.00593
# [33]	validation_0-rmse:0.72971	validation_1-rmse:0.98938
# [34]	validation_0-rmse:0.71314	validation_1-rmse:0.96702
# [35]	validation_0-rmse:0.69954	validation_1-rmse:0.95066
# [36]	validation_0-rmse:0.68675	validation_1-rmse:0.93455
# [37]	validation_0-rmse:0.67275	validation_1-rmse:0.91200
# [38]	validation_0-rmse:0.65809	validation_1-rmse:0.89336
# [39]	validation_0-rmse:0.64715	validation_1-rmse:0.88829
# [40]	validation_0-rmse:0.63325	validation_1-rmse:0.86939
# [41]	validation_0-rmse:0.62721	validation_1-rmse:0.86391
# [42]	validation_0-rmse:0.61241	validation_1-rmse:0.84636
# [43]	validation_0-rmse:0.60697	validation_1-rmse:0.83364
# [44]	validation_0-rmse:0.60094	validation_1-rmse:0.83076
# [45]	validation_0-rmse:0.59508	validation_1-rmse:0.82206
# [46]	validation_0-rmse:0.58765	validation_1-rmse:0.81348
# [47]	validation_0-rmse:0.57873	validation_1-rmse:0.79901
# [48]	validation_0-rmse:0.57294	validation_1-rmse:0.79370
# [49]	validation_0-rmse:0.56581	validation_1-rmse:0.78328
# [50]	validation_0-rmse:0.56386	validation_1-rmse:0.78588
# [51]	validation_0-rmse:0.55922	validation_1-rmse:0.77485
# [52]	validation_0-rmse:0.55415	validation_1-rmse:0.77114
# [53]	validation_0-rmse:0.54924	validation_1-rmse:0.76281
# [54]	validation_0-rmse:0.54246	validation_1-rmse:0.75430
# [55]	validation_0-rmse:0.53975	validation_1-rmse:0.75690
# [56]	validation_0-rmse:0.53483	validation_1-rmse:0.75269
# [57]	validation_0-rmse:0.52705	validation_1-rmse:0.75091
# [58]	validation_0-rmse:0.52543	validation_1-rmse:0.75058
# [59]	validation_0-rmse:0.52080	validation_1-rmse:0.73897
# [60]	validation_0-rmse:0.51739	validation_1-rmse:0.73372
# [61]	validation_0-rmse:0.51476	validation_1-rmse:0.72513
# [62]	validation_0-rmse:0.51324	validation_1-rmse:0.72405
# [63]	validation_0-rmse:0.51040	validation_1-rmse:0.71852
# [64]	validation_0-rmse:0.50868	validation_1-rmse:0.71691
# [65]	validation_0-rmse:0.50678	validation_1-rmse:0.72567
# [66]	validation_0-rmse:0.50519	validation_1-rmse:0.72785
# [67]	validation_0-rmse:0.50441	validation_1-rmse:0.72772
# [68]	validation_0-rmse:0.50265	validation_1-rmse:0.72952
# [69]	validation_0-rmse:0.49911	validation_1-rmse:0.73593
# [70]	validation_0-rmse:0.49703	validation_1-rmse:0.73093
# [71]	validation_0-rmse:0.49360	validation_1-rmse:0.73014
# [72]	validation_0-rmse:0.49194	validation_1-rmse:0.72520
# [73]	validation_0-rmse:0.48785	validation_1-rmse:0.71878
# [74]	validation_0-rmse:0.48320	validation_1-rmse:0.72011
# [75]	validation_0-rmse:0.48030	validation_1-rmse:0.71946
# [76]	validation_0-rmse:0.47653	validation_1-rmse:0.71436
# [77]	validation_0-rmse:0.47565	validation_1-rmse:0.71523
# [78]	validation_0-rmse:0.47380	validation_1-rmse:0.71378
# [79]	validation_0-rmse:0.47053	validation_1-rmse:0.71594
# [80]	validation_0-rmse:0.46814	validation_1-rmse:0.71729
# [81]	validation_0-rmse:0.46653	validation_1-rmse:0.71276
# [82]	validation_0-rmse:0.46486	validation_1-rmse:0.71535
# [83]	validation_0-rmse:0.46268	validation_1-rmse:0.71705
# [84]	validation_0-rmse:0.45985	validation_1-rmse:0.71847
# [85]	validation_0-rmse:0.45813	validation_1-rmse:0.71471
# [86]	validation_0-rmse:0.45744	validation_1-rmse:0.71429
# [87]	validation_0-rmse:0.45465	validation_1-rmse:0.71481
# [88]	validation_0-rmse:0.45471	validation_1-rmse:0.71803
# [89]	validation_0-rmse:0.45501	validation_1-rmse:0.71370
# [90]	validation_0-rmse:0.45349	validation_1-rmse:0.70967
# [91]	validation_0-rmse:0.45264	validation_1-rmse:0.71011
# [92]	validation_0-rmse:0.45010	validation_1-rmse:0.70744
# [93]	validation_0-rmse:0.44891	validation_1-rmse:0.70785
# [94]	validation_0-rmse:0.44767	validation_1-rmse:0.70427
# [95]	validation_0-rmse:0.44504	validation_1-rmse:0.70105
# [96]	validation_0-rmse:0.44131	validation_1-rmse:0.70438
# [97]	validation_0-rmse:0.43844	validation_1-rmse:0.70575
# [98]	validation_0-rmse:0.43572	validation_1-rmse:0.70457
# [99]	validation_0-rmse:0.43371	validation_1-rmse:0.70156
# [100]	validation_0-rmse:0.43162	validation_1-rmse:0.70406
# [101]	validation_0-rmse:0.43122	validation_1-rmse:0.70598
# [102]	validation_0-rmse:0.43186	validation_1-rmse:0.70296
# [103]	validation_0-rmse:0.43065	validation_1-rmse:0.71110
# [104]	validation_0-rmse:0.42814	validation_1-rmse:0.71418
# [105]	validation_0-rmse:0.42758	validation_1-rmse:0.71043
# [106]	validation_0-rmse:0.42633	validation_1-rmse:0.71528
# [107]	validation_0-rmse:0.42638	validation_1-rmse:0.71556
# [108]	validation_0-rmse:0.42620	validation_1-rmse:0.71887
# [109]	validation_0-rmse:0.42276	validation_1-rmse:0.71812
# [110]	validation_0-rmse:0.42131	validation_1-rmse:0.71943
# [111]	validation_0-rmse:0.42017	validation_1-rmse:0.72028
# [112]	validation_0-rmse:0.41903	validation_1-rmse:0.72747
# [113]	validation_0-rmse:0.41738	validation_1-rmse:0.72938
# [114]	validation_0-rmse:0.41648	validation_1-rmse:0.72740
# [115]	validation_0-rmse:0.41461	validation_1-rmse:0.73506
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:6.57239	validation_1-rmse:6.53269
# [1]	validation_0-rmse:6.00935	validation_1-rmse:5.99148
# [2]	validation_0-rmse:5.50488	validation_1-rmse:5.51356
# [3]	validation_0-rmse:5.03609	validation_1-rmse:5.07396
# [4]	validation_0-rmse:4.62530	validation_1-rmse:4.69178
# [5]	validation_0-rmse:4.23718	validation_1-rmse:4.33324
# [6]	validation_0-rmse:3.87859	validation_1-rmse:4.00373
# [7]	validation_0-rmse:3.56472	validation_1-rmse:3.71572
# [8]	validation_0-rmse:3.27009	validation_1-rmse:3.43951
# [9]	validation_0-rmse:3.03882	validation_1-rmse:3.20994
# [10]	validation_0-rmse:2.79258	validation_1-rmse:2.98414
# [11]	validation_0-rmse:2.57437	validation_1-rmse:2.79704
# [12]	validation_0-rmse:2.36774	validation_1-rmse:2.61487
# [13]	validation_0-rmse:2.19895	validation_1-rmse:2.46022
# [14]	validation_0-rmse:2.03674	validation_1-rmse:2.31485
# [15]	validation_0-rmse:1.88170	validation_1-rmse:2.16260
# [16]	validation_0-rmse:1.74416	validation_1-rmse:2.04116
# [17]	validation_0-rmse:1.63123	validation_1-rmse:1.94543
# [18]	validation_0-rmse:1.53289	validation_1-rmse:1.84194
# [19]	validation_0-rmse:1.43015	validation_1-rmse:1.75075
# [20]	validation_0-rmse:1.34295	validation_1-rmse:1.65914
# [21]	validation_0-rmse:1.25151	validation_1-rmse:1.56858
# [22]	validation_0-rmse:1.18945	validation_1-rmse:1.51478
# [23]	validation_0-rmse:1.12392	validation_1-rmse:1.44636
# [24]	validation_0-rmse:1.06227	validation_1-rmse:1.38651
# [25]	validation_0-rmse:1.00502	validation_1-rmse:1.33379
# [26]	validation_0-rmse:0.95512	validation_1-rmse:1.29383
# [27]	validation_0-rmse:0.91153	validation_1-rmse:1.25815
# [28]	validation_0-rmse:0.87795	validation_1-rmse:1.22589
# [29]	validation_0-rmse:0.84860	validation_1-rmse:1.19154
# [30]	validation_0-rmse:0.82099	validation_1-rmse:1.15816
# [31]	validation_0-rmse:0.79661	validation_1-rmse:1.13705
# [32]	validation_0-rmse:0.77378	validation_1-rmse:1.11300
# [33]	validation_0-rmse:0.74838	validation_1-rmse:1.09404
# [34]	validation_0-rmse:0.73099	validation_1-rmse:1.07768
# [35]	validation_0-rmse:0.70623	validation_1-rmse:1.05082
# [36]	validation_0-rmse:0.69481	validation_1-rmse:1.03207
# [37]	validation_0-rmse:0.68168	validation_1-rmse:1.02101
# [38]	validation_0-rmse:0.66581	validation_1-rmse:0.99960
# [39]	validation_0-rmse:0.65268	validation_1-rmse:0.98663
# [40]	validation_0-rmse:0.63957	validation_1-rmse:0.97399
# [41]	validation_0-rmse:0.62822	validation_1-rmse:0.96573
# [42]	validation_0-rmse:0.61721	validation_1-rmse:0.94658
# [43]	validation_0-rmse:0.60940	validation_1-rmse:0.93910
# [44]	validation_0-rmse:0.60541	validation_1-rmse:0.93572
# [45]	validation_0-rmse:0.60061	validation_1-rmse:0.93077
# [46]	validation_0-rmse:0.59066	validation_1-rmse:0.91411
# [47]	validation_0-rmse:0.58480	validation_1-rmse:0.91354
# [48]	validation_0-rmse:0.57729	validation_1-rmse:0.90292
# [49]	validation_0-rmse:0.57265	validation_1-rmse:0.89720
# [50]	validation_0-rmse:0.56655	validation_1-rmse:0.88945
# [51]	validation_0-rmse:0.56385	validation_1-rmse:0.88255
# [52]	validation_0-rmse:0.55934	validation_1-rmse:0.86933
# [53]	validation_0-rmse:0.55469	validation_1-rmse:0.85846
# [54]	validation_0-rmse:0.55326	validation_1-rmse:0.85050
# [55]	validation_0-rmse:0.54846	validation_1-rmse:0.84376
# [56]	validation_0-rmse:0.54458	validation_1-rmse:0.83944
# [57]	validation_0-rmse:0.53997	validation_1-rmse:0.82949
# [58]	validation_0-rmse:0.53592	validation_1-rmse:0.82800
# [59]	validation_0-rmse:0.53277	validation_1-rmse:0.82235
# [60]	validation_0-rmse:0.52873	validation_1-rmse:0.82228
# [61]	validation_0-rmse:0.52428	validation_1-rmse:0.82264
# [62]	validation_0-rmse:0.52137	validation_1-rmse:0.82038
# [63]	validation_0-rmse:0.51804	validation_1-rmse:0.81675
# [64]	validation_0-rmse:0.51633	validation_1-rmse:0.81444
# [65]	validation_0-rmse:0.51447	validation_1-rmse:0.81282
# [66]	validation_0-rmse:0.51384	validation_1-rmse:0.81004
# [67]	validation_0-rmse:0.51113	validation_1-rmse:0.81185
# [68]	validation_0-rmse:0.51001	validation_1-rmse:0.81395
# [69]	validation_0-rmse:0.50600	validation_1-rmse:0.81287
# [70]	validation_0-rmse:0.50261	validation_1-rmse:0.80908
# [71]	validation_0-rmse:0.49892	validation_1-rmse:0.80625
# [72]	validation_0-rmse:0.49722	validation_1-rmse:0.80549
# [73]	validation_0-rmse:0.49340	validation_1-rmse:0.80287
# [74]	validation_0-rmse:0.49199	validation_1-rmse:0.80659
# [75]	validation_0-rmse:0.49096	validation_1-rmse:0.80851
# [76]	validation_0-rmse:0.48658	validation_1-rmse:0.80595
# [77]	validation_0-rmse:0.48395	validation_1-rmse:0.80862
# [78]	validation_0-rmse:0.48081	validation_1-rmse:0.80077
# [79]	validation_0-rmse:0.47979	validation_1-rmse:0.79947
# [80]	validation_0-rmse:0.47634	validation_1-rmse:0.79408
# [81]	validation_0-rmse:0.47405	validation_1-rmse:0.79002
# [82]	validation_0-rmse:0.47047	validation_1-rmse:0.79098
# [83]	validation_0-rmse:0.46875	validation_1-rmse:0.79071
# [84]	validation_0-rmse:0.46517	validation_1-rmse:0.78940
# [85]	validation_0-rmse:0.46323	validation_1-rmse:0.78955
# [86]	validation_0-rmse:0.46215	validation_1-rmse:0.78409
# [87]	validation_0-rmse:0.46029	validation_1-rmse:0.78329
# [88]	validation_0-rmse:0.46067	validation_1-rmse:0.78144
# [89]	validation_0-rmse:0.45732	validation_1-rmse:0.78193
# [90]	validation_0-rmse:0.45427	validation_1-rmse:0.77959
# [91]	validation_0-rmse:0.45297	validation_1-rmse:0.78039
# [92]	validation_0-rmse:0.45008	validation_1-rmse:0.77832
# [93]	validation_0-rmse:0.44533	validation_1-rmse:0.78360
# [94]	validation_0-rmse:0.44292	validation_1-rmse:0.78457
# [95]	validation_0-rmse:0.44132	validation_1-rmse:0.78671
# [96]	validation_0-rmse:0.43955	validation_1-rmse:0.79086
# [97]	validation_0-rmse:0.43764	validation_1-rmse:0.78912
# [98]	validation_0-rmse:0.43542	validation_1-rmse:0.78995
# [99]	validation_0-rmse:0.43356	validation_1-rmse:0.78672
# [100]	validation_0-rmse:0.43142	validation_1-rmse:0.78568
# [101]	validation_0-rmse:0.43076	validation_1-rmse:0.78243
# [102]	validation_0-rmse:0.42978	validation_1-rmse:0.78641
# [103]	validation_0-rmse:0.42903	validation_1-rmse:0.78884
# [104]	validation_0-rmse:0.42869	validation_1-rmse:0.78904
# [105]	validation_0-rmse:0.42735	validation_1-rmse:0.78579
# [106]	validation_0-rmse:0.42571	validation_1-rmse:0.78741
# [107]	validation_0-rmse:0.42578	validation_1-rmse:0.78637
# [108]	validation_0-rmse:0.42412	validation_1-rmse:0.79186
# [109]	validation_0-rmse:0.42274	validation_1-rmse:0.79405
# [110]	validation_0-rmse:0.42082	validation_1-rmse:0.79694
# [111]	validation_0-rmse:0.41930	validation_1-rmse:0.79903
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.50134	validation_1-rmse:6.74308
# [1]	validation_0-rmse:5.92873	validation_1-rmse:6.18027
# [2]	validation_0-rmse:5.40301	validation_1-rmse:5.65479
# [3]	validation_0-rmse:4.98171	validation_1-rmse:5.21656
# [4]	validation_0-rmse:4.56724	validation_1-rmse:4.78330
# [5]	validation_0-rmse:4.19751	validation_1-rmse:4.39320
# [6]	validation_0-rmse:3.86080	validation_1-rmse:4.03605
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:3.54355	validation_1-rmse:3.69895
# [8]	validation_0-rmse:3.24370	validation_1-rmse:3.38520
# [9]	validation_0-rmse:2.98363	validation_1-rmse:3.10943
# [10]	validation_0-rmse:2.75822	validation_1-rmse:2.87491
# [11]	validation_0-rmse:2.56997	validation_1-rmse:2.67612
# [12]	validation_0-rmse:2.37187	validation_1-rmse:2.47112
# [13]	validation_0-rmse:2.17734	validation_1-rmse:2.28282
# [14]	validation_0-rmse:2.02435	validation_1-rmse:2.12179
# [15]	validation_0-rmse:1.89778	validation_1-rmse:1.97557
# [16]	validation_0-rmse:1.75968	validation_1-rmse:1.83294
# [17]	validation_0-rmse:1.64090	validation_1-rmse:1.71686
# [18]	validation_0-rmse:1.52863	validation_1-rmse:1.60034
# [19]	validation_0-rmse:1.44257	validation_1-rmse:1.49854
# [20]	validation_0-rmse:1.34354	validation_1-rmse:1.40595
# [21]	validation_0-rmse:1.26215	validation_1-rmse:1.32081
# [22]	validation_0-rmse:1.19220	validation_1-rmse:1.24375
# [23]	validation_0-rmse:1.13505	validation_1-rmse:1.18159
# [24]	validation_0-rmse:1.07174	validation_1-rmse:1.11445
# [25]	validation_0-rmse:1.02617	validation_1-rmse:1.06050
# [26]	validation_0-rmse:0.97757	validation_1-rmse:1.02622
# [27]	validation_0-rmse:0.93821	validation_1-rmse:0.97778
# [28]	validation_0-rmse:0.90308	validation_1-rmse:0.94361
# [29]	validation_0-rmse:0.86246	validation_1-rmse:0.90032
# [30]	validation_0-rmse:0.83455	validation_1-rmse:0.86365
# [31]	validation_0-rmse:0.80744	validation_1-rmse:0.83007
# [32]	validation_0-rmse:0.78303	validation_1-rmse:0.81193
# [33]	validation_0-rmse:0.76223	validation_1-rmse:0.78617
# [34]	validation_0-rmse:0.74382	validation_1-rmse:0.76898
# [35]	validation_0-rmse:0.72576	validation_1-rmse:0.75176
# [36]	validation_0-rmse:0.71673	validation_1-rmse:0.73865
# [37]	validation_0-rmse:0.69772	validation_1-rmse:0.72295
# [38]	validation_0-rmse:0.68390	validation_1-rmse:0.71699
# [39]	validation_0-rmse:0.67230	validation_1-rmse:0.70736
# [40]	validation_0-rmse:0.65801	validation_1-rmse:0.70375
# [41]	validation_0-rmse:0.64755	validation_1-rmse:0.69218
# [42]	validation_0-rmse:0.63852	validation_1-rmse:0.67943
# [43]	validation_0-rmse:0.63154	validation_1-rmse:0.67336
# [44]	validation_0-rmse:0.62613	validation_1-rmse:0.66857
# [45]	validation_0-rmse:0.62032	validation_1-rmse:0.66501
# [46]	validation_0-rmse:0.61453	validation_1-rmse:0.65923
# [47]	validation_0-rmse:0.60983	validation_1-rmse:0.65230
# [48]	validation_0-rmse:0.60977	validation_1-rmse:0.66131
# [49]	validation_0-rmse:0.60490	validation_1-rmse:0.65974
# [50]	validation_0-rmse:0.59569	validation_1-rmse:0.64442
# [51]	validation_0-rmse:0.58886	validation_1-rmse:0.63467
# [52]	validation_0-rmse:0.58113	validation_1-rmse:0.63713
# [53]	validation_0-rmse:0.57385	validation_1-rmse:0.63913
# [54]	validation_0-rmse:0.56812	validation_1-rmse:0.63665
# [55]	validation_0-rmse:0.56347	validation_1-rmse:0.63071
# [56]	validation_0-rmse:0.55999	validation_1-rmse:0.62446
# [57]	validation_0-rmse:0.55568	validation_1-rmse:0.62908
# [58]	validation_0-rmse:0.54993	validation_1-rmse:0.63302
# [59]	validation_0-rmse:0.54739	validation_1-rmse:0.63228
# [60]	validation_0-rmse:0.54523	validation_1-rmse:0.63504
# [61]	validation_0-rmse:0.54312	validation_1-rmse:0.63754
# [62]	validation_0-rmse:0.53835	validation_1-rmse:0.64589
# [63]	validation_0-rmse:0.52972	validation_1-rmse:0.63896
# [64]	validation_0-rmse:0.52628	validation_1-rmse:0.63955
# [65]	validation_0-rmse:0.52336	validation_1-rmse:0.64249
# [66]	validation_0-rmse:0.52022	validation_1-rmse:0.64463
# [67]	validation_0-rmse:0.51732	validation_1-rmse:0.64598
# [68]	validation_0-rmse:0.51274	validation_1-rmse:0.64829
# [69]	validation_0-rmse:0.51133	validation_1-rmse:0.65345
# [70]	validation_0-rmse:0.50917	validation_1-rmse:0.65108
# [71]	validation_0-rmse:0.50757	validation_1-rmse:0.65412
# [72]	validation_0-rmse:0.50476	validation_1-rmse:0.65014
# [73]	validation_0-rmse:0.50206	validation_1-rmse:0.64874
# [74]	validation_0-rmse:0.49928	validation_1-rmse:0.64775
# [75]	validation_0-rmse:0.49809	validation_1-rmse:0.64598
# [76]	validation_0-rmse:0.49636	validation_1-rmse:0.64988
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:6.60262	validation_1-rmse:6.34823
# [1]	validation_0-rmse:6.01679	validation_1-rmse:5.75239
# [2]	validation_0-rmse:5.51165	validation_1-rmse:5.22492
# [3]	validation_0-rmse:5.05508	validation_1-rmse:4.77648
# [4]	validation_0-rmse:4.65563	validation_1-rmse:4.37177
# [5]	validation_0-rmse:4.26856	validation_1-rmse:3.96736
# [6]	validation_0-rmse:3.91328	validation_1-rmse:3.60051
# [7]	validation_0-rmse:3.60113	validation_1-rmse:3.28651
# [8]	validation_0-rmse:3.29236	validation_1-rmse:2.97668
# [9]	validation_0-rmse:3.06079	validation_1-rmse:2.73578
# [10]	validation_0-rmse:2.82738	validation_1-rmse:2.49529
# [11]	validation_0-rmse:2.61840	validation_1-rmse:2.29184
# [12]	validation_0-rmse:2.42857	validation_1-rmse:2.09538
# [13]	validation_0-rmse:2.25429	validation_1-rmse:1.93613
# [14]	validation_0-rmse:2.08247	validation_1-rmse:1.76557
# [15]	validation_0-rmse:1.92334	validation_1-rmse:1.61920
# [16]	validation_0-rmse:1.79927	validation_1-rmse:1.50919
# [17]	validation_0-rmse:1.67102	validation_1-rmse:1.40297
# [18]	validation_0-rmse:1.56484	validation_1-rmse:1.29768
# [19]	validation_0-rmse:1.44795	validation_1-rmse:1.20171
# [20]	validation_0-rmse:1.34733	validation_1-rmse:1.11208
# [21]	validation_0-rmse:1.26821	validation_1-rmse:1.04194
# [22]	validation_0-rmse:1.19097	validation_1-rmse:0.98349
# [23]	validation_0-rmse:1.12626	validation_1-rmse:0.93641
# [24]	validation_0-rmse:1.07593	validation_1-rmse:0.89423
# [25]	validation_0-rmse:1.02460	validation_1-rmse:0.85713
# [26]	validation_0-rmse:0.98203	validation_1-rmse:0.82515
# [27]	validation_0-rmse:0.95030	validation_1-rmse:0.80463
# [28]	validation_0-rmse:0.90660	validation_1-rmse:0.77499
# [29]	validation_0-rmse:0.87214	validation_1-rmse:0.75234
# [30]	validation_0-rmse:0.84742	validation_1-rmse:0.73747
# [31]	validation_0-rmse:0.82108	validation_1-rmse:0.72481
# [32]	validation_0-rmse:0.80432	validation_1-rmse:0.71376
# [33]	validation_0-rmse:0.78277	validation_1-rmse:0.69041
# [34]	validation_0-rmse:0.75661	validation_1-rmse:0.68322
# [35]	validation_0-rmse:0.74098	validation_1-rmse:0.68361
# [36]	validation_0-rmse:0.72536	validation_1-rmse:0.67682
# [37]	validation_0-rmse:0.70994	validation_1-rmse:0.66606
# [38]	validation_0-rmse:0.69386	validation_1-rmse:0.66183
# [39]	validation_0-rmse:0.68589	validation_1-rmse:0.65241
# [40]	validation_0-rmse:0.67308	validation_1-rmse:0.64710
# [41]	validation_0-rmse:0.66165	validation_1-rmse:0.65419
# [42]	validation_0-rmse:0.65117	validation_1-rmse:0.64841
# [43]	validation_0-rmse:0.63841	validation_1-rmse:0.64588
# [44]	validation_0-rmse:0.63634	validation_1-rmse:0.64129
# [45]	validation_0-rmse:0.63087	validation_1-rmse:0.64020
# [46]	validation_0-rmse:0.62153	validation_1-rmse:0.64080
# [47]	validation_0-rmse:0.61698	validation_1-rmse:0.63872
# [48]	validation_0-rmse:0.61085	validation_1-rmse:0.63437
# [49]	validation_0-rmse:0.60666	validation_1-rmse:0.63394
# [50]	validation_0-rmse:0.60127	validation_1-rmse:0.62969
# [51]	validation_0-rmse:0.59262	validation_1-rmse:0.63460
# [52]	validation_0-rmse:0.58622	validation_1-rmse:0.63905
# [53]	validation_0-rmse:0.58206	validation_1-rmse:0.62973
# [54]	validation_0-rmse:0.57523	validation_1-rmse:0.63042
# [55]	validation_0-rmse:0.57239	validation_1-rmse:0.63262
# [56]	validation_0-rmse:0.57192	validation_1-rmse:0.62967
# [57]	validation_0-rmse:0.56639	validation_1-rmse:0.62415
# [58]	validation_0-rmse:0.56315	validation_1-rmse:0.62853
# [59]	validation_0-rmse:0.55861	validation_1-rmse:0.63012
# [60]	validation_0-rmse:0.55453	validation_1-rmse:0.62812
# [61]	validation_0-rmse:0.55131	validation_1-rmse:0.63205
# [62]	validation_0-rmse:0.54842	validation_1-rmse:0.63510
# [63]	validation_0-rmse:0.54624	validation_1-rmse:0.63946
# [64]	validation_0-rmse:0.54204	validation_1-rmse:0.63349
# [65]	validation_0-rmse:0.53750	validation_1-rmse:0.62469
# [66]	validation_0-rmse:0.53246	validation_1-rmse:0.62441
# [67]	validation_0-rmse:0.52849	validation_1-rmse:0.62539
# [68]	validation_0-rmse:0.52639	validation_1-rmse:0.61847
# [69]	validation_0-rmse:0.52471	validation_1-rmse:0.61990
# [70]	validation_0-rmse:0.52192	validation_1-rmse:0.62081
# [71]	validation_0-rmse:0.51795	validation_1-rmse:0.62244
# [72]	validation_0-rmse:0.51569	validation_1-rmse:0.62207
# [73]	validation_0-rmse:0.51405	validation_1-rmse:0.62521
# [74]	validation_0-rmse:0.51192	validation_1-rmse:0.62294
# [75]	validation_0-rmse:0.51152	validation_1-rmse:0.62600
# [76]	validation_0-rmse:0.50931	validation_1-rmse:0.62965
# [77]	validation_0-rmse:0.50829	validation_1-rmse:0.62749
# [78]	validation_0-rmse:0.50376	validation_1-rmse:0.63048
# [79]	validation_0-rmse:0.50212	validation_1-rmse:0.62720
# [80]	validation_0-rmse:0.49938	validation_1-rmse:0.62682
# [81]	validation_0-rmse:0.49791	validation_1-rmse:0.63122
# [82]	validation_0-rmse:0.49682	validation_1-rmse:0.63586
# [83]	validation_0-rmse:0.49572	validation_1-rmse:0.63258
# [84]	validation_0-rmse:0.49489	validation_1-rmse:0.63134
# [85]	validation_0-rmse:0.49263	validation_1-rmse:0.62539
# [86]	validation_0-rmse:0.49153	validation_1-rmse:0.62296
# [87]	validation_0-rmse:0.48919	validation_1-rmse:0.62615
# [0]	validation_0-rmse:6.56998	validation_1-rmse:6.61257
# [1]	validation_0-rmse:5.99425	validation_1-rmse:6.04529
# [2]	validation_0-rmse:5.48571	validation_1-rmse:5.53497
# [3]	validation_0-rmse:4.99912	validation_1-rmse:5.04680
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:4.57203	validation_1-rmse:4.60347
# [5]	validation_0-rmse:4.22564	validation_1-rmse:4.25482
# [6]	validation_0-rmse:3.87494	validation_1-rmse:3.88845
# [7]	validation_0-rmse:3.55553	validation_1-rmse:3.57677
# [8]	validation_0-rmse:3.27075	validation_1-rmse:3.29265
# [9]	validation_0-rmse:3.00217	validation_1-rmse:3.02024
# [10]	validation_0-rmse:2.75767	validation_1-rmse:2.76113
# [11]	validation_0-rmse:2.57440	validation_1-rmse:2.58218
# [12]	validation_0-rmse:2.37426	validation_1-rmse:2.37430
# [13]	validation_0-rmse:2.18341	validation_1-rmse:2.18371
# [14]	validation_0-rmse:2.02490	validation_1-rmse:2.00792
# [15]	validation_0-rmse:1.88968	validation_1-rmse:1.87310
# [16]	validation_0-rmse:1.75180	validation_1-rmse:1.73147
# [17]	validation_0-rmse:1.63076	validation_1-rmse:1.61269
# [18]	validation_0-rmse:1.51538	validation_1-rmse:1.49446
# [19]	validation_0-rmse:1.42902	validation_1-rmse:1.41633
# [20]	validation_0-rmse:1.34310	validation_1-rmse:1.32900
# [21]	validation_0-rmse:1.25714	validation_1-rmse:1.24712
# [22]	validation_0-rmse:1.18070	validation_1-rmse:1.18308
# [23]	validation_0-rmse:1.11993	validation_1-rmse:1.13228
# [24]	validation_0-rmse:1.06103	validation_1-rmse:1.07475
# [25]	validation_0-rmse:1.00791	validation_1-rmse:1.02569
# [26]	validation_0-rmse:0.96809	validation_1-rmse:0.98653
# [27]	validation_0-rmse:0.92562	validation_1-rmse:0.93916
# [28]	validation_0-rmse:0.88396	validation_1-rmse:0.90695
# [29]	validation_0-rmse:0.84790	validation_1-rmse:0.88296
# [30]	validation_0-rmse:0.81380	validation_1-rmse:0.85683
# [31]	validation_0-rmse:0.77730	validation_1-rmse:0.82628
# [32]	validation_0-rmse:0.75622	validation_1-rmse:0.81124
# [33]	validation_0-rmse:0.73359	validation_1-rmse:0.79241
# [34]	validation_0-rmse:0.71776	validation_1-rmse:0.78011
# [35]	validation_0-rmse:0.69689	validation_1-rmse:0.77322
# [36]	validation_0-rmse:0.67869	validation_1-rmse:0.75485
# [37]	validation_0-rmse:0.66230	validation_1-rmse:0.74949
# [38]	validation_0-rmse:0.64677	validation_1-rmse:0.73964
# [39]	validation_0-rmse:0.63157	validation_1-rmse:0.73123
# [40]	validation_0-rmse:0.62231	validation_1-rmse:0.72600
# [41]	validation_0-rmse:0.60815	validation_1-rmse:0.71978
# [42]	validation_0-rmse:0.60003	validation_1-rmse:0.71682
# [43]	validation_0-rmse:0.59494	validation_1-rmse:0.70991
# [44]	validation_0-rmse:0.58872	validation_1-rmse:0.69981
# [45]	validation_0-rmse:0.58026	validation_1-rmse:0.69411
# [46]	validation_0-rmse:0.57336	validation_1-rmse:0.68905
# [47]	validation_0-rmse:0.56508	validation_1-rmse:0.69975
# [48]	validation_0-rmse:0.56276	validation_1-rmse:0.69526
# [49]	validation_0-rmse:0.55942	validation_1-rmse:0.68935
# [50]	validation_0-rmse:0.55419	validation_1-rmse:0.69269
# [51]	validation_0-rmse:0.55112	validation_1-rmse:0.68821
# [52]	validation_0-rmse:0.54548	validation_1-rmse:0.69159
# [53]	validation_0-rmse:0.54176	validation_1-rmse:0.69256
# [54]	validation_0-rmse:0.53662	validation_1-rmse:0.68993
# [55]	validation_0-rmse:0.53095	validation_1-rmse:0.68864
# [56]	validation_0-rmse:0.52813	validation_1-rmse:0.68857
# [57]	validation_0-rmse:0.52186	validation_1-rmse:0.68609
# [58]	validation_0-rmse:0.51965	validation_1-rmse:0.68170
# [59]	validation_0-rmse:0.51478	validation_1-rmse:0.67779
# [60]	validation_0-rmse:0.51273	validation_1-rmse:0.67832
# [61]	validation_0-rmse:0.50624	validation_1-rmse:0.67213
# [62]	validation_0-rmse:0.50576	validation_1-rmse:0.67543
# [63]	validation_0-rmse:0.50325	validation_1-rmse:0.67106
# [64]	validation_0-rmse:0.50053	validation_1-rmse:0.67036
# [65]	validation_0-rmse:0.49772	validation_1-rmse:0.66833
# [66]	validation_0-rmse:0.49551	validation_1-rmse:0.66581
# [67]	validation_0-rmse:0.49252	validation_1-rmse:0.66650
# [68]	validation_0-rmse:0.48780	validation_1-rmse:0.66948
# [69]	validation_0-rmse:0.48545	validation_1-rmse:0.66838
# [70]	validation_0-rmse:0.48297	validation_1-rmse:0.67379
# [71]	validation_0-rmse:0.48160	validation_1-rmse:0.67209
# [72]	validation_0-rmse:0.47771	validation_1-rmse:0.67252
# [73]	validation_0-rmse:0.47412	validation_1-rmse:0.67026
# [74]	validation_0-rmse:0.47291	validation_1-rmse:0.66456
# [75]	validation_0-rmse:0.47213	validation_1-rmse:0.66529
# [76]	validation_0-rmse:0.47046	validation_1-rmse:0.66626
# [77]	validation_0-rmse:0.47008	validation_1-rmse:0.66900
# [78]	validation_0-rmse:0.46858	validation_1-rmse:0.67110
# [79]	validation_0-rmse:0.46578	validation_1-rmse:0.67322
# [80]	validation_0-rmse:0.46513	validation_1-rmse:0.67032
# [81]	validation_0-rmse:0.46292	validation_1-rmse:0.67453
# [82]	validation_0-rmse:0.46240	validation_1-rmse:0.67918
# [83]	validation_0-rmse:0.46060	validation_1-rmse:0.67360
# [84]	validation_0-rmse:0.45777	validation_1-rmse:0.67034
# [85]	validation_0-rmse:0.45627	validation_1-rmse:0.67076
# [86]	validation_0-rmse:0.45725	validation_1-rmse:0.66884
# [87]	validation_0-rmse:0.45620	validation_1-rmse:0.66739
# [88]	validation_0-rmse:0.45556	validation_1-rmse:0.66720
# [89]	validation_0-rmse:0.45517	validation_1-rmse:0.66671
# [90]	validation_0-rmse:0.45476	validation_1-rmse:0.66905
# [91]	validation_0-rmse:0.45387	validation_1-rmse:0.66924
# [92]	validation_0-rmse:0.45257	validation_1-rmse:0.66959
# [93]	validation_0-rmse:0.45074	validation_1-rmse:0.67045
# [0]	validation_0-rmse:6.53398	validation_1-rmse:6.70018
# [1]	validation_0-rmse:5.95240	validation_1-rmse:6.10186
# [2]	validation_0-rmse:5.46858	validation_1-rmse:5.59051
# [3]	validation_0-rmse:4.99040	validation_1-rmse:5.09041
# [4]	validation_0-rmse:4.56663	validation_1-rmse:4.64376
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:4.19821	validation_1-rmse:4.26559
# [6]	validation_0-rmse:3.85793	validation_1-rmse:3.90337
# [7]	validation_0-rmse:3.55936	validation_1-rmse:3.58368
# [8]	validation_0-rmse:3.28504	validation_1-rmse:3.30634
# [9]	validation_0-rmse:3.01161	validation_1-rmse:3.02900
# [10]	validation_0-rmse:2.75668	validation_1-rmse:2.77495
# [11]	validation_0-rmse:2.54663	validation_1-rmse:2.58265
# [12]	validation_0-rmse:2.34639	validation_1-rmse:2.38144
# [13]	validation_0-rmse:2.19135	validation_1-rmse:2.24645
# [14]	validation_0-rmse:2.02755	validation_1-rmse:2.08893
# [15]	validation_0-rmse:1.88258	validation_1-rmse:1.94134
# [16]	validation_0-rmse:1.74061	validation_1-rmse:1.79607
# [17]	validation_0-rmse:1.61571	validation_1-rmse:1.67330
# [18]	validation_0-rmse:1.49328	validation_1-rmse:1.53737
# [19]	validation_0-rmse:1.39976	validation_1-rmse:1.45617
# [20]	validation_0-rmse:1.31076	validation_1-rmse:1.36639
# [21]	validation_0-rmse:1.23409	validation_1-rmse:1.30067
# [22]	validation_0-rmse:1.16128	validation_1-rmse:1.22725
# [23]	validation_0-rmse:1.09439	validation_1-rmse:1.16221
# [24]	validation_0-rmse:1.03730	validation_1-rmse:1.09625
# [25]	validation_0-rmse:0.98480	validation_1-rmse:1.05411
# [26]	validation_0-rmse:0.94420	validation_1-rmse:1.01722
# [27]	validation_0-rmse:0.90741	validation_1-rmse:0.97982
# [28]	validation_0-rmse:0.87657	validation_1-rmse:0.94613
# [29]	validation_0-rmse:0.83997	validation_1-rmse:0.91995
# [30]	validation_0-rmse:0.80088	validation_1-rmse:0.88571
# [31]	validation_0-rmse:0.78333	validation_1-rmse:0.87323
# [32]	validation_0-rmse:0.75679	validation_1-rmse:0.85620
# [33]	validation_0-rmse:0.74008	validation_1-rmse:0.84611
# [34]	validation_0-rmse:0.71672	validation_1-rmse:0.82041
# [35]	validation_0-rmse:0.70226	validation_1-rmse:0.80617
# [36]	validation_0-rmse:0.68573	validation_1-rmse:0.79414
# [37]	validation_0-rmse:0.67255	validation_1-rmse:0.78273
# [38]	validation_0-rmse:0.66164	validation_1-rmse:0.77462
# [39]	validation_0-rmse:0.64418	validation_1-rmse:0.76532
# [40]	validation_0-rmse:0.63005	validation_1-rmse:0.75395
# [41]	validation_0-rmse:0.62369	validation_1-rmse:0.75158
# [42]	validation_0-rmse:0.61765	validation_1-rmse:0.75273
# [43]	validation_0-rmse:0.60973	validation_1-rmse:0.74683
# [44]	validation_0-rmse:0.60282	validation_1-rmse:0.74614
# [45]	validation_0-rmse:0.59628	validation_1-rmse:0.74288
# [46]	validation_0-rmse:0.59292	validation_1-rmse:0.74160
# [47]	validation_0-rmse:0.58681	validation_1-rmse:0.73992
# [48]	validation_0-rmse:0.58103	validation_1-rmse:0.73965
# [49]	validation_0-rmse:0.57509	validation_1-rmse:0.73536
# [50]	validation_0-rmse:0.56967	validation_1-rmse:0.73945
# [51]	validation_0-rmse:0.56441	validation_1-rmse:0.73198
# [52]	validation_0-rmse:0.56054	validation_1-rmse:0.73389
# [53]	validation_0-rmse:0.55442	validation_1-rmse:0.72634
# [54]	validation_0-rmse:0.55318	validation_1-rmse:0.72304
# [55]	validation_0-rmse:0.54950	validation_1-rmse:0.71864
# [56]	validation_0-rmse:0.54640	validation_1-rmse:0.71947
# [57]	validation_0-rmse:0.54559	validation_1-rmse:0.72316
# [58]	validation_0-rmse:0.54141	validation_1-rmse:0.72110
# [59]	validation_0-rmse:0.53897	validation_1-rmse:0.72075
# [60]	validation_0-rmse:0.53639	validation_1-rmse:0.72102
# [61]	validation_0-rmse:0.53479	validation_1-rmse:0.71671
# [62]	validation_0-rmse:0.53185	validation_1-rmse:0.71721
# [63]	validation_0-rmse:0.52959	validation_1-rmse:0.71514
# [64]	validation_0-rmse:0.52663	validation_1-rmse:0.71454
# ...
# [62]	validation_0-rmse:0.50951	validation_1-rmse:0.69573
# [63]	validation_0-rmse:0.50358	validation_1-rmse:0.69075
# [64]	validation_0-rmse:0.50255	validation_1-rmse:0.69135
# [65]	validation_0-rmse:0.49971	validation_1-rmse:0.69393
# [66]	validation_0-rmse:0.49713	validation_1-rmse:0.69513
# [67]	validation_0-rmse:0.49475	validation_1-rmse:0.69874
# [68]	validation_0-rmse:0.49027	validation_1-rmse:0.69268
# [69]	validation_0-rmse:0.48446	validation_1-rmse:0.69970
# [70]	validation_0-rmse:0.48213	validation_1-rmse:0.69931
# [71]	validation_0-rmse:0.48053	validation_1-rmse:0.70336
# [72]	validation_0-rmse:0.47897	validation_1-rmse:0.70235
# [73]	validation_0-rmse:0.47667	validation_1-rmse:0.69922
# [74]	validation_0-rmse:0.47522	validation_1-rmse:0.69281
# [75]	validation_0-rmse:0.47486	validation_1-rmse:0.68874
# [76]	validation_0-rmse:0.47392	validation_1-rmse:0.68634
# [77]	validation_0-rmse:0.47219	validation_1-rmse:0.68484
# [78]	validation_0-rmse:0.47106	validation_1-rmse:0.68251
# [79]	validation_0-rmse:0.46699	validation_1-rmse:0.68229
# [80]	validation_0-rmse:0.46380	validation_1-rmse:0.68300
# [81]	validation_0-rmse:0.46243	validation_1-rmse:0.68598
# [82]	validation_0-rmse:0.46119	validation_1-rmse:0.68651
# [83]	validation_0-rmse:0.45890	validation_1-rmse:0.68376
# [84]	validation_0-rmse:0.45809	validation_1-rmse:0.68461
# [85]	validation_0-rmse:0.45652	validation_1-rmse:0.67839
# [86]	validation_0-rmse:0.45408	validation_1-rmse:0.67741
# [87]	validation_0-rmse:0.45445	validation_1-rmse:0.67782
# [88]	validation_0-rmse:0.45346	validation_1-rmse:0.68260
# [89]	validation_0-rmse:0.45124	validation_1-rmse:0.69124
# [90]	validation_0-rmse:0.44935	validation_1-rmse:0.69050
# [91]	validation_0-rmse:0.44713	validation_1-rmse:0.68987
# [92]	validation_0-rmse:0.44625	validation_1-rmse:0.69359
# [93]	validation_0-rmse:0.44459	validation_1-rmse:0.69619
# [94]	validation_0-rmse:0.44299	validation_1-rmse:0.69984
# [95]	validation_0-rmse:0.44168	validation_1-rmse:0.69638
# [96]	validation_0-rmse:0.44015	validation_1-rmse:0.69185
# [97]	validation_0-rmse:0.43874	validation_1-rmse:0.68883
# [98]	validation_0-rmse:0.43678	validation_1-rmse:0.69227
# [99]	validation_0-rmse:0.43222	validation_1-rmse:0.69059
# [100]	validation_0-rmse:0.43174	validation_1-rmse:0.69325
# [101]	validation_0-rmse:0.43025	validation_1-rmse:0.69799
# [102]	validation_0-rmse:0.42863	validation_1-rmse:0.69805
# [103]	validation_0-rmse:0.42863	validation_1-rmse:0.69875
# [104]	validation_0-rmse:0.42778	validation_1-rmse:0.69463
# [105]	validation_0-rmse:0.42513	validation_1-rmse:0.69578
# [106]	validation_0-rmse:0.42230	validation_1-rmse:0.69997
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.50324	validation_1-rmse:6.71768
# [1]	validation_0-rmse:5.95570	validation_1-rmse:6.13413
# [2]	validation_0-rmse:5.42251	validation_1-rmse:5.58536
# [3]	validation_0-rmse:4.95566	validation_1-rmse:5.11489
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:4.53585	validation_1-rmse:4.67864
# [5]	validation_0-rmse:4.14299	validation_1-rmse:4.25634
# [6]	validation_0-rmse:3.83323	validation_1-rmse:3.94308
# [7]	validation_0-rmse:3.51359	validation_1-rmse:3.60282
# [8]	validation_0-rmse:3.24608	validation_1-rmse:3.32331
# [9]	validation_0-rmse:2.96784	validation_1-rmse:3.03604
# [10]	validation_0-rmse:2.74596	validation_1-rmse:2.80769
# [11]	validation_0-rmse:2.53613	validation_1-rmse:2.60102
# [12]	validation_0-rmse:2.33262	validation_1-rmse:2.36756
# [13]	validation_0-rmse:2.16925	validation_1-rmse:2.19249
# [14]	validation_0-rmse:2.00587	validation_1-rmse:2.00654
# [15]	validation_0-rmse:1.86934	validation_1-rmse:1.85747
# [16]	validation_0-rmse:1.74879	validation_1-rmse:1.73252
# [17]	validation_0-rmse:1.63328	validation_1-rmse:1.61457
# [18]	validation_0-rmse:1.52244	validation_1-rmse:1.49902
# [19]	validation_0-rmse:1.41989	validation_1-rmse:1.39304
# [20]	validation_0-rmse:1.33629	validation_1-rmse:1.30780
# [21]	validation_0-rmse:1.25851	validation_1-rmse:1.21663
# [22]	validation_0-rmse:1.18308	validation_1-rmse:1.14965
# [23]	validation_0-rmse:1.11375	validation_1-rmse:1.07296
# [24]	validation_0-rmse:1.06155	validation_1-rmse:1.02739
# [25]	validation_0-rmse:1.01848	validation_1-rmse:0.99514
# [26]	validation_0-rmse:0.98015	validation_1-rmse:0.95412
# [27]	validation_0-rmse:0.94673	validation_1-rmse:0.92467
# [28]	validation_0-rmse:0.90806	validation_1-rmse:0.88064
# [29]	validation_0-rmse:0.87174	validation_1-rmse:0.84771
# [30]	validation_0-rmse:0.84047	validation_1-rmse:0.82186
# [31]	validation_0-rmse:0.80801	validation_1-rmse:0.79736
# [32]	validation_0-rmse:0.79230	validation_1-rmse:0.78220
# [33]	validation_0-rmse:0.76474	validation_1-rmse:0.75031
# [34]	validation_0-rmse:0.74192	validation_1-rmse:0.73648
# [35]	validation_0-rmse:0.73045	validation_1-rmse:0.72870
# [36]	validation_0-rmse:0.71603	validation_1-rmse:0.71728
# [37]	validation_0-rmse:0.70053	validation_1-rmse:0.70341
# [38]	validation_0-rmse:0.69087	validation_1-rmse:0.69569
# [39]	validation_0-rmse:0.67769	validation_1-rmse:0.69111
# [40]	validation_0-rmse:0.66808	validation_1-rmse:0.68600
# [41]	validation_0-rmse:0.65947	validation_1-rmse:0.68156
# [42]	validation_0-rmse:0.65076	validation_1-rmse:0.68095
# [43]	validation_0-rmse:0.64255	validation_1-rmse:0.67687
# [44]	validation_0-rmse:0.63709	validation_1-rmse:0.67474
# [45]	validation_0-rmse:0.62876	validation_1-rmse:0.66467
# [46]	validation_0-rmse:0.62393	validation_1-rmse:0.65993
# [47]	validation_0-rmse:0.62202	validation_1-rmse:0.65907
# [48]	validation_0-rmse:0.61161	validation_1-rmse:0.64560
# [49]	validation_0-rmse:0.60323	validation_1-rmse:0.64522
# [50]	validation_0-rmse:0.59518	validation_1-rmse:0.63631
# [51]	validation_0-rmse:0.58930	validation_1-rmse:0.63303
# [52]	validation_0-rmse:0.58334	validation_1-rmse:0.62760
# [53]	validation_0-rmse:0.57802	validation_1-rmse:0.61984
# [54]	validation_0-rmse:0.57522	validation_1-rmse:0.62410
# [55]	validation_0-rmse:0.57122	validation_1-rmse:0.62536
# [56]	validation_0-rmse:0.56694	validation_1-rmse:0.62946
# [57]	validation_0-rmse:0.56414	validation_1-rmse:0.62840
# [58]	validation_0-rmse:0.55917	validation_1-rmse:0.62064
# [59]	validation_0-rmse:0.55416	validation_1-rmse:0.62053
# [60]	validation_0-rmse:0.55301	validation_1-rmse:0.62086
# [61]	validation_0-rmse:0.55047	validation_1-rmse:0.61507
# [62]	validation_0-rmse:0.54726	validation_1-rmse:0.61656
# [63]	validation_0-rmse:0.54255	validation_1-rmse:0.61369
# [64]	validation_0-rmse:0.53861	validation_1-rmse:0.61875
# [65]	validation_0-rmse:0.53378	validation_1-rmse:0.62658
# [66]	validation_0-rmse:0.53268	validation_1-rmse:0.63385
# [67]	validation_0-rmse:0.53101	validation_1-rmse:0.63241
# [68]	validation_0-rmse:0.52661	validation_1-rmse:0.62889
# [69]	validation_0-rmse:0.52255	validation_1-rmse:0.62653
# [70]	validation_0-rmse:0.52071	validation_1-rmse:0.61766
# [71]	validation_0-rmse:0.51883	validation_1-rmse:0.62434
# [72]	validation_0-rmse:0.51528	validation_1-rmse:0.62035
# [73]	validation_0-rmse:0.51126	validation_1-rmse:0.61380
# [74]	validation_0-rmse:0.50825	validation_1-rmse:0.60736
# [75]	validation_0-rmse:0.50417	validation_1-rmse:0.61157
# [76]	validation_0-rmse:0.50417	validation_1-rmse:0.61178
# [77]	validation_0-rmse:0.50107	validation_1-rmse:0.61457
# [78]	validation_0-rmse:0.49882	validation_1-rmse:0.61401
# [79]	validation_0-rmse:0.49792	validation_1-rmse:0.61528
# [80]	validation_0-rmse:0.49398	validation_1-rmse:0.61182
# [81]	validation_0-rmse:0.49181	validation_1-rmse:0.62444
# [82]	validation_0-rmse:0.48928	validation_1-rmse:0.61515
# [83]	validation_0-rmse:0.48498	validation_1-rmse:0.61609
# [84]	validation_0-rmse:0.48335	validation_1-rmse:0.61478
# [85]	validation_0-rmse:0.48234	validation_1-rmse:0.60935
# [86]	validation_0-rmse:0.48041	validation_1-rmse:0.61094
# [87]	validation_0-rmse:0.47825	validation_1-rmse:0.61212
# [88]	validation_0-rmse:0.47679	validation_1-rmse:0.60904
# [89]	validation_0-rmse:0.47663	validation_1-rmse:0.60716
# [90]	validation_0-rmse:0.47487	validation_1-rmse:0.60208
# [91]	validation_0-rmse:0.47478	validation_1-rmse:0.60262
# [92]	validation_0-rmse:0.47227	validation_1-rmse:0.60110
# [93]	validation_0-rmse:0.46926	validation_1-rmse:0.59860
# [94]	validation_0-rmse:0.46851	validation_1-rmse:0.59872
# [95]	validation_0-rmse:0.46466	validation_1-rmse:0.59682
# [96]	validation_0-rmse:0.46217	validation_1-rmse:0.59310
# [97]	validation_0-rmse:0.46100	validation_1-rmse:0.59418
# [98]	validation_0-rmse:0.45986	validation_1-rmse:0.59615
# [99]	validation_0-rmse:0.45964	validation_1-rmse:0.60005
# [100]	validation_0-rmse:0.45700	validation_1-rmse:0.60138
# [101]	validation_0-rmse:0.45565	validation_1-rmse:0.60239
# [102]	validation_0-rmse:0.45404	validation_1-rmse:0.59916
# [103]	validation_0-rmse:0.45211	validation_1-rmse:0.59744
# [104]	validation_0-rmse:0.44976	validation_1-rmse:0.60064
# [105]	validation_0-rmse:0.44710	validation_1-rmse:0.59683
# [106]	validation_0-rmse:0.44449	validation_1-rmse:0.59639
# [107]	validation_0-rmse:0.44276	validation_1-rmse:0.59816
# [108]	validation_0-rmse:0.44197	validation_1-rmse:0.59957
# [109]	validation_0-rmse:0.43913	validation_1-rmse:0.60165
# [110]	validation_0-rmse:0.43672	validation_1-rmse:0.60313
# [111]	validation_0-rmse:0.43607	validation_1-rmse:0.59838
# [112]	validation_0-rmse:0.43461	validation_1-rmse:0.59729
# [113]	validation_0-rmse:0.43278	validation_1-rmse:0.59871
# [114]	validation_0-rmse:0.43024	validation_1-rmse:0.60070
# [115]	validation_0-rmse:0.42893	validation_1-rmse:0.60175
# [116]	validation_0-rmse:0.42763	validation_1-rmse:0.60015
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.63944	validation_1-rmse:6.33493
# [1]	validation_0-rmse:6.09074	validation_1-rmse:5.77489
# [2]	validation_0-rmse:5.57470	validation_1-rmse:5.27907
# [3]	validation_0-rmse:5.11382	validation_1-rmse:4.79862
# [4]	validation_0-rmse:4.70175	validation_1-rmse:4.36901
# [5]	validation_0-rmse:4.32009	validation_1-rmse:3.97516
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:3.97272	validation_1-rmse:3.65414
# [7]	validation_0-rmse:3.64533	validation_1-rmse:3.33830
# [8]	validation_0-rmse:3.34555	validation_1-rmse:3.05394
# [9]	validation_0-rmse:3.09313	validation_1-rmse:2.80839
# [10]	validation_0-rmse:2.83882	validation_1-rmse:2.57871
# [11]	validation_0-rmse:2.61737	validation_1-rmse:2.37308
# [12]	validation_0-rmse:2.41001	validation_1-rmse:2.20433
# [13]	validation_0-rmse:2.23628	validation_1-rmse:2.03333
# [14]	validation_0-rmse:2.06312	validation_1-rmse:1.86943
# [15]	validation_0-rmse:1.91813	validation_1-rmse:1.71224
# [16]	validation_0-rmse:1.79009	validation_1-rmse:1.58406
# [17]	validation_0-rmse:1.65775	validation_1-rmse:1.46620
# [18]	validation_0-rmse:1.55609	validation_1-rmse:1.34406
# [19]	validation_0-rmse:1.46517	validation_1-rmse:1.24620
# [20]	validation_0-rmse:1.36980	validation_1-rmse:1.17074
# [21]	validation_0-rmse:1.29295	validation_1-rmse:1.08945
# [22]	validation_0-rmse:1.21860	validation_1-rmse:1.03512
# [23]	validation_0-rmse:1.14840	validation_1-rmse:0.97567
# [24]	validation_0-rmse:1.08577	validation_1-rmse:0.93484
# [25]	validation_0-rmse:1.02648	validation_1-rmse:0.88407
# [26]	validation_0-rmse:0.99008	validation_1-rmse:0.85275
# [27]	validation_0-rmse:0.94552	validation_1-rmse:0.80507
# [28]	validation_0-rmse:0.90781	validation_1-rmse:0.77911
# [29]	validation_0-rmse:0.87587	validation_1-rmse:0.74907
# [30]	validation_0-rmse:0.83819	validation_1-rmse:0.72079
# [31]	validation_0-rmse:0.80621	validation_1-rmse:0.69705
# [32]	validation_0-rmse:0.77562	validation_1-rmse:0.67316
# [33]	validation_0-rmse:0.75455	validation_1-rmse:0.65655
# [34]	validation_0-rmse:0.73603	validation_1-rmse:0.64212
# [35]	validation_0-rmse:0.71769	validation_1-rmse:0.63474
# [36]	validation_0-rmse:0.70463	validation_1-rmse:0.62310
# [37]	validation_0-rmse:0.68697	validation_1-rmse:0.61610
# [38]	validation_0-rmse:0.67575	validation_1-rmse:0.59460
# [39]	validation_0-rmse:0.66033	validation_1-rmse:0.58081
# [40]	validation_0-rmse:0.64826	validation_1-rmse:0.58112
# [41]	validation_0-rmse:0.63858	validation_1-rmse:0.57514
# [42]	validation_0-rmse:0.63014	validation_1-rmse:0.56480
# [43]	validation_0-rmse:0.62339	validation_1-rmse:0.56379
# [44]	validation_0-rmse:0.61944	validation_1-rmse:0.56044
# [45]	validation_0-rmse:0.61602	validation_1-rmse:0.55883
# [46]	validation_0-rmse:0.60775	validation_1-rmse:0.55049
# [47]	validation_0-rmse:0.59945	validation_1-rmse:0.54835
# [48]	validation_0-rmse:0.59215	validation_1-rmse:0.54497
# [49]	validation_0-rmse:0.58832	validation_1-rmse:0.54502
# [50]	validation_0-rmse:0.58339	validation_1-rmse:0.54794
# [51]	validation_0-rmse:0.57637	validation_1-rmse:0.54015
# [52]	validation_0-rmse:0.57081	validation_1-rmse:0.52795
# [53]	validation_0-rmse:0.56684	validation_1-rmse:0.52621
# [54]	validation_0-rmse:0.56094	validation_1-rmse:0.52583
# [55]	validation_0-rmse:0.55784	validation_1-rmse:0.52425
# [56]	validation_0-rmse:0.55511	validation_1-rmse:0.51906
# [57]	validation_0-rmse:0.55163	validation_1-rmse:0.51889
# [58]	validation_0-rmse:0.55038	validation_1-rmse:0.51690
# [59]	validation_0-rmse:0.54708	validation_1-rmse:0.51340
# [60]	validation_0-rmse:0.54502	validation_1-rmse:0.50776
# [61]	validation_0-rmse:0.54424	validation_1-rmse:0.50929
# [62]	validation_0-rmse:0.54023	validation_1-rmse:0.51022
# [63]	validation_0-rmse:0.54033	validation_1-rmse:0.50968
# [64]	validation_0-rmse:0.53890	validation_1-rmse:0.50598
# [65]	validation_0-rmse:0.53627	validation_1-rmse:0.50247
# [66]	validation_0-rmse:0.53363	validation_1-rmse:0.49655
# [67]	validation_0-rmse:0.52863	validation_1-rmse:0.49572
# [68]	validation_0-rmse:0.52667	validation_1-rmse:0.49621
# [69]	validation_0-rmse:0.52309	validation_1-rmse:0.49128
# [70]	validation_0-rmse:0.52057	validation_1-rmse:0.49000
# [71]	validation_0-rmse:0.51956	validation_1-rmse:0.49091
# [72]	validation_0-rmse:0.51736	validation_1-rmse:0.49201
# [73]	validation_0-rmse:0.51598	validation_1-rmse:0.48715
# [74]	validation_0-rmse:0.51469	validation_1-rmse:0.48712
# [75]	validation_0-rmse:0.51353	validation_1-rmse:0.48556
# [76]	validation_0-rmse:0.51140	validation_1-rmse:0.48078
# [77]	validation_0-rmse:0.50992	validation_1-rmse:0.47919
# [78]	validation_0-rmse:0.50665	validation_1-rmse:0.48050
# [79]	validation_0-rmse:0.50274	validation_1-rmse:0.48498
# [80]	validation_0-rmse:0.49916	validation_1-rmse:0.48554
# [81]	validation_0-rmse:0.49732	validation_1-rmse:0.48796
# [82]	validation_0-rmse:0.49319	validation_1-rmse:0.48640
# [83]	validation_0-rmse:0.49248	validation_1-rmse:0.48484
# [84]	validation_0-rmse:0.49188	validation_1-rmse:0.48873
# [85]	validation_0-rmse:0.49274	validation_1-rmse:0.48630
# [86]	validation_0-rmse:0.48951	validation_1-rmse:0.48456
# [87]	validation_0-rmse:0.48691	validation_1-rmse:0.48498
# [88]	validation_0-rmse:0.48300	validation_1-rmse:0.48572
# [89]	validation_0-rmse:0.47791	validation_1-rmse:0.48431
# [90]	validation_0-rmse:0.47465	validation_1-rmse:0.48140
# [91]	validation_0-rmse:0.47176	validation_1-rmse:0.48428
# [92]	validation_0-rmse:0.47168	validation_1-rmse:0.48386
# [93]	validation_0-rmse:0.47080	validation_1-rmse:0.48789
# [94]	validation_0-rmse:0.46870	validation_1-rmse:0.48603
# [95]	validation_0-rmse:0.46557	validation_1-rmse:0.49162
# [96]	validation_0-rmse:0.46386	validation_1-rmse:0.49595
# [97]	validation_0-rmse:0.46241	validation_1-rmse:0.49524
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(2, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.891
# Uncertainty
# a0: 0.826+/-0.165
# a1: 0.8873+/-0.022

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: AEDR_mean: mean - 0.454, median - 0.455, CI - [0.39-0.518]
#
# SHAP-values for: Azimuth: mean - 0.168, median - 0.166, CI - [0.135-0.204]
#
# SHAP-values for: D_cm: mean - 0.198, median - 0.199, CI - [0.173-0.22]
#
# SHAP-values for: Distance_km: mean - 0.418, median - 0.416, CI - [0.343-0.488]
#
# SHAP-values for: F_Soil_ID: mean - 0.132, median - 0.131, CI - [0.107-0.157]
#
# SHAP-values for: Species_ID: mean - 0.097, median - 0.098, CI - [0.073-0.121]
#
# SHAP-values for: Sr_2021_kBq_m: mean - 0.678, median - 0.671, CI - [0.596-0.76]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'D_cm', 'Azimuth', 'F_Soil_ID', 'Species_ID'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 102.13, median: 97.0,
#  pred. interval (P(0.025)-P(0.975)): 50.975-162.0,
#  conf. interval (p-value=0.95): 71.0-135.696
# ***
# Aggregate bias statistic:
#  mean: -0.006, median: -0.003,
#  pred. interval (P(0.025)-P(0.975)): -0.24-0.17,
#  conf. interval (p-value=0.95): -0.091-0.087
# ***
# Aggregate RMSE statistic:
#  mean: 0.666, median: 0.662, pred. interval (P(0.025)-P(0.975)): 0.491-0.854,
#  conf. interval (p-value=0.95): 0.575-0.751
# ***
# Aggregate MSE statistic:
#  mean: 0.453, median: 0.438, pred. interval (P(0.025)-P(0.975)): 0.242-0.729,
#  conf. interval (p-value=0.95): 0.331-0.565
# ***
# Aggregate R^2 statistic:
#  mean: 0.887, median: 0.891, pred. interval (P(0.025)-P(0.975)): 0.804-0.94,
#  conf. interval (p-value=0.95): 0.86-0.915
# ***
# Aggregate bias(%) statistic:
#  mean: -0.073, median: -0.039, pred. interval (P(0.025)-P(0.975)): -3.133-2.277,
#  conf. interval (p-value=0.95): -1.185-1.197
# ***
# Aggregate RMSE(%) statistic:
#  mean: 9.034, median: 8.983, pred. interval (P(0.025)-P(0.975)): 6.617-11.736,
#  conf. interval (p-value=0.95): 7.836-10.201
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -6688.751, median: -1682.56,
#  pred. interval (P(0.025)-P(0.975)): -26142.804-976.467,
#  conf. interval (p-value=0.95): -19296.541--272.231
# ***
# Aggregate RMSE statistic:
#  mean: 42810.519, median: 10853.146, pred. interval (P(0.025)-P(0.975)): 2983.703-146518.044,
#  conf. interval (p-value=0.95): 6001.429-125009.215
# ***
# Aggregate MSE statistic:
#  mean: 5087027765.924, median: 117798356.669, pred. interval (P(0.025)-P(0.975)): 8902490.136-21467539949.474,
#  conf. interval (p-value=0.95): 38734732.606-17130746015.285
# ***
# Aggregate R^2 statistic:
#  mean: 0.634, median: 0.742, pred. interval (P(0.025)-P(0.975)): 0.143-0.97,
#  conf. interval (p-value=0.95): 0.297-0.893
# ***
# Aggregate bias(%) statistic:
#  mean: -25.491, median: -19.317, pred. interval (P(0.025)-P(0.975)): -75.085-19.717,
#  conf. interval (p-value=0.95): -60.488--3.196
# ***
# Aggregate RMSE(%) statistic:
#  mean: 182.307, median: 112.622, pred. interval (P(0.025)-P(0.975)): 47.683-476.766,
#  conf. interval (p-value=0.95): 76.833-370.351
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [0, 3, 6, 9, 12, 15])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 1000, 10000, 50000, 100000, 1000000])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:6.55662
# [1]	validation_0-rmse:6.00064
# [2]	validation_0-rmse:5.49198
# [3]	validation_0-rmse:5.03199
# [4]	validation_0-rmse:4.61111
# [5]	validation_0-rmse:4.22998
# [6]	validation_0-rmse:3.89392
# [7]	validation_0-rmse:3.57629
# [8]	validation_0-rmse:3.28119
# [9]	validation_0-rmse:3.00603
# [10]	validation_0-rmse:2.77445
# [11]	validation_0-rmse:2.56195
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [12]	validation_0-rmse:2.36963
# [13]	validation_0-rmse:2.19663
# [14]	validation_0-rmse:2.03657
# [15]	validation_0-rmse:1.89121
# [16]	validation_0-rmse:1.75308
# [17]	validation_0-rmse:1.63450
# [18]	validation_0-rmse:1.52385
# [19]	validation_0-rmse:1.42357
# [20]	validation_0-rmse:1.34303
# [21]	validation_0-rmse:1.26173
# [22]	validation_0-rmse:1.18357
# [23]	validation_0-rmse:1.11503
# [24]	validation_0-rmse:1.05937
# [25]	validation_0-rmse:1.00869
# [26]	validation_0-rmse:0.96443
# [27]	validation_0-rmse:0.92572
# [28]	validation_0-rmse:0.89276
# [29]	validation_0-rmse:0.85653
# [30]	validation_0-rmse:0.82526
# [31]	validation_0-rmse:0.80362
# [32]	validation_0-rmse:0.78607
# [33]	validation_0-rmse:0.76628
# [34]	validation_0-rmse:0.74238
# [35]	validation_0-rmse:0.72632
# [36]	validation_0-rmse:0.70985
# [37]	validation_0-rmse:0.70128
# [38]	validation_0-rmse:0.68735
# [39]	validation_0-rmse:0.67338
# [40]	validation_0-rmse:0.66470
# [41]	validation_0-rmse:0.65388
# [42]	validation_0-rmse:0.64623
# [43]	validation_0-rmse:0.63431
# [44]	validation_0-rmse:0.62490
# [45]	validation_0-rmse:0.61844
# [46]	validation_0-rmse:0.61326
# [47]	validation_0-rmse:0.60771
# [48]	validation_0-rmse:0.60357
# [49]	validation_0-rmse:0.59983
# [50]	validation_0-rmse:0.59345
# [51]	validation_0-rmse:0.58933
# [52]	validation_0-rmse:0.58405
# [53]	validation_0-rmse:0.57672
# [54]	validation_0-rmse:0.57038
# [55]	validation_0-rmse:0.56594
# [56]	validation_0-rmse:0.56019
# [57]	validation_0-rmse:0.55721
# [58]	validation_0-rmse:0.55288
# [59]	validation_0-rmse:0.55022
# [60]	validation_0-rmse:0.54739
# [61]	validation_0-rmse:0.54537
# [62]	validation_0-rmse:0.54296
# [63]	validation_0-rmse:0.54078
# [64]	validation_0-rmse:0.53798
# [65]	validation_0-rmse:0.53540
# [66]	validation_0-rmse:0.53117
# [67]	validation_0-rmse:0.52939
# [68]	validation_0-rmse:0.52737
# [69]	validation_0-rmse:0.52551
# [70]	validation_0-rmse:0.52080
# [71]	validation_0-rmse:0.51721
# [72]	validation_0-rmse:0.51564
# [73]	validation_0-rmse:0.51287
# [74]	validation_0-rmse:0.51000
# [75]	validation_0-rmse:0.50773
# [76]	validation_0-rmse:0.50620
# [77]	validation_0-rmse:0.50403
# [78]	validation_0-rmse:0.50278
# [79]	validation_0-rmse:0.50060
# [80]	validation_0-rmse:0.50106
# [81]	validation_0-rmse:0.49797
# [82]	validation_0-rmse:0.49697
# [83]	validation_0-rmse:0.49475
# [84]	validation_0-rmse:0.49306
# [85]	validation_0-rmse:0.49147
# [86]	validation_0-rmse:0.48863
# [87]	validation_0-rmse:0.48664
# [88]	validation_0-rmse:0.48511
# [89]	validation_0-rmse:0.48352
# [90]	validation_0-rmse:0.48117
# [91]	validation_0-rmse:0.47928
# [92]	validation_0-rmse:0.47806
# [93]	validation_0-rmse:0.47735
# [94]	validation_0-rmse:0.47469
# [95]	validation_0-rmse:0.47308
# [96]	validation_0-rmse:0.47023
# [97]	validation_0-rmse:0.46849
# [98]	validation_0-rmse:0.46605
# [99]	validation_0-rmse:0.46309
# [100]	validation_0-rmse:0.45940
# [101]	validation_0-rmse:0.45746
# [102]	validation_0-rmse:0.45550
# [103]	validation_0-rmse:0.45359
# [104]	validation_0-rmse:0.45246
# [105]	validation_0-rmse:0.45152
# [106]	validation_0-rmse:0.44837
# [107]	validation_0-rmse:0.44709
# [108]	validation_0-rmse:0.44550
# [109]	validation_0-rmse:0.44488
# [110]	validation_0-rmse:0.44363
# [111]	validation_0-rmse:0.44285
# [112]	validation_0-rmse:0.44210
# [113]	validation_0-rmse:0.44120
# [114]	validation_0-rmse:0.44076
# [115]	validation_0-rmse:0.43780
# [116]	validation_0-rmse:0.43613
# [117]	validation_0-rmse:0.43442
# [118]	validation_0-rmse:0.43350
# [119]	validation_0-rmse:0.43295
# [120]	validation_0-rmse:0.43126
# [121]	validation_0-rmse:0.43059
# [122]	validation_0-rmse:0.42945
# [123]	validation_0-rmse:0.42714
# [124]	validation_0-rmse:0.42583
# [125]	validation_0-rmse:0.42389
# [126]	validation_0-rmse:0.42088
# [127]	validation_0-rmse:0.41994
# [128]	validation_0-rmse:0.41942
# [129]	validation_0-rmse:0.41875
# [130]	validation_0-rmse:0.41649
# [131]	validation_0-rmse:0.41634
# [132]	validation_0-rmse:0.41639
# [133]	validation_0-rmse:0.41515
# [134]	validation_0-rmse:0.41370
# [135]	validation_0-rmse:0.41270
# [136]	validation_0-rmse:0.41137
# [137]	validation_0-rmse:0.41013
# [138]	validation_0-rmse:0.40886
# [139]	validation_0-rmse:0.40602
# [140]	validation_0-rmse:0.40627
# [141]	validation_0-rmse:0.40514
# [142]	validation_0-rmse:0.40462
# [143]	validation_0-rmse:0.40379
# [144]	validation_0-rmse:0.40288
# [145]	validation_0-rmse:0.40192
# [146]	validation_0-rmse:0.40067
# [147]	validation_0-rmse:0.39924
# [148]	validation_0-rmse:0.39904
# [149]	validation_0-rmse:0.39894
# [150]	validation_0-rmse:0.39756
# [151]	validation_0-rmse:0.39618
# [152]	validation_0-rmse:0.39606
# [153]	validation_0-rmse:0.39573
# [154]	validation_0-rmse:0.39500
# [155]	validation_0-rmse:0.39433
# [156]	validation_0-rmse:0.39404
# [157]	validation_0-rmse:0.39310
# [158]	validation_0-rmse:0.39236
# [159]	validation_0-rmse:0.39172
# [160]	validation_0-rmse:0.39005
# [161]	validation_0-rmse:0.38935
# [162]	validation_0-rmse:0.38782
# [163]	validation_0-rmse:0.38638
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 163

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.00
# RMSE: 0.4
# Relative RMSE(%):  5.234
# MSE: 0.1
# R square: 96.4%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(2, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.964
# Uncertainty
# a0: 0.36+/-0.10
# a1: 0.951+/-0.013

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../02_output_data/XGBoost_models/02_LN_Sr_content_with_geo_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../02_output_data/XGBoost_models/02_LN_Sr_content_with_geo_XGB_model.txt")
