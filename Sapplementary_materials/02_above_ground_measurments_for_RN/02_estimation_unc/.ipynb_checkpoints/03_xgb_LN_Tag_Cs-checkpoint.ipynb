# %% [markdown]
# ## Processing with RN data obtained from forest sites

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../02_input_data/RN_sites_data.xlsx'
df = pd.read_excel(site_data, sheet_name='RN_filtration_data')
df.head()
# Out:
#    Ідентифікатор    Site # Species  Species_ID  Ntrees at site  % composition  \
# 0             81  001_2021    Pine           0              23     100.000000
# 1            219  002_2021    Pine           0              60      90.178571
# 2            224  003_2021    Pine           0              44     100.000000
# 3            228  004_2021    Pine           0              23     100.000000
# 4            232  005_2021    Pine           0              26     100.000000
#
#         D_cm        H_m    G_m2_ha  N_ha  ...   T_ag_Cs  ln_T_ag_Cs  \
# 0  26.060965  25.423284  49.081648   920  ...  0.781087   -0.247069
# 1   4.303100   4.705979   8.731641  6000  ...  1.549336    0.437826
# 2  28.142898  27.556869  54.703060   880  ...  0.583447   -0.538802
# 3  14.953551   8.506028  40.420188  2300  ...  0.145072   -1.930528
# 4   7.208435   3.425669   2.120687   520  ...  0.254295   -1.369259
#
#      T_ag_Sr  ln_T_ag_Sr  AEDR_count AEDR_mean  AEDR_median  AEDR_std  \
# 0   9.004084    2.197678          26  3.524231        3.530  0.235489
# 1  24.247024    3.188294          15  3.830667        3.780  0.166272
# 2   9.304047    2.230449          28  0.483571        0.475  0.068931
# 3   5.279971    1.663921          20  0.364500        0.365  0.029576
# 4   6.629225    1.891488          18  0.333333        0.345  0.036515
#
#    Distance_km  Azimuth
# 0     5.926403      249
# 1     6.018960      249
# 2    13.046428      189
# 3    12.741627      189
# 4    12.893213      189
#
# [5 rows x 51 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Species', 'Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
#                                     'Origin', 'Origin_ID','A_year', 'D_live_cm', 'H_live_m', 'G_live_m2_ha',
#                                     'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
#                                     'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_A_Cs', 'ln_A_Sr',
#                                     'T_ag_Cs', 'ln_T_ag_Cs', 'T_ag_Sr', 'ln_T_ag_Sr'
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species', 'Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
                                    'Origin', 'Origin_ID','A_year',
                                    'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
                                    'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_A_Cs', 'ln_A_Sr', 
                                    'ln_T_ag_Cs', 'ln_T_ag_Sr'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#   Species  Species_ID  % composition       D_cm        H_m    G_m2_ha Origin  \
# 0    Pine           0     100.000000  26.060965  25.423284  49.081648      a
# 1    Pine           0      90.178571   4.303100   4.705979   8.731641      n
# 2    Pine           0     100.000000  28.142898  27.556869  54.703060      n
# 3    Pine           0     100.000000  14.953551   8.506028  40.420188      n
# 4    Pine           0     100.000000   7.208435   3.425669   2.120687      n
#
#    Origin_ID  A_year  F_Soil_ID  M_Soil  AEDR_mean  Distance_km  Azimuth  \
# 0          1      68          1       2   3.524231     5.926403      249
# 1          0      15          1       2   3.830667     6.018960      249
# 2          0      69          1       2   0.483571    13.046428      189
# 3          0      15          2       2   0.364500    12.741627      189
# 4          0      10          2       2   0.333333    12.893213      189
#
#    Cs_2021_kBq_m  Sr_2021_kBq_m   ln_A_Cs    ln_A_Sr  ln_T_ag_Cs  ln_T_ag_Sr
# 0    2842.194109     998.435843  7.705262   9.103868   -0.247069    2.197678
# 1    2930.287815     987.750099  8.420682  10.083724    0.437826    3.188294
# 2     281.088291      65.777826  5.099866   6.416732   -0.538802    2.230449
# 3     289.512268      69.886752  3.737670   5.910797   -1.930528    1.663921
# 4     287.067816      69.993095  4.290459   6.139885   -1.369259    1.891488

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Species        209 non-null    object
#  1   Species_ID     209 non-null    int64
#  2   % composition  209 non-null    float64
#  3   D_cm           209 non-null    float64
#  4   H_m            209 non-null    float64
#  5   G_m2_ha        209 non-null    float64
#  6   Origin         209 non-null    object
#  7   Origin_ID      209 non-null    int64
#  8   A_year         209 non-null    int64
#  9   F_Soil_ID      209 non-null    int64
#  10  M_Soil         209 non-null    int64
#  11  AEDR_mean      209 non-null    float64
#  12  Distance_km    209 non-null    float64
#  13  Azimuth        209 non-null    int64
#  14  Cs_2021_kBq_m  209 non-null    float64
#  15  Sr_2021_kBq_m  209 non-null    float64
#  16  ln_A_Cs        209 non-null    float64
#  17  ln_A_Sr        209 non-null    float64
#  18  ln_T_ag_Cs     209 non-null    float64
#  19  ln_T_ag_Sr     209 non-null    float64
# dtypes: float64(12), int64(6), object(2)
# memory usage: 32.8+ KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species"])["ln_T_ag_Cs", "ln_T_ag_Sr"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#         ln_T_ag_Cs                                                    \
#              count      mean       std       min       25%       50%
# Species
# Alder         13.0 -0.621091  1.079748 -2.054670 -1.409349 -0.890892
# Aspen          9.0 -0.930356  1.335868 -2.444532 -1.853749 -1.029875
# Birch         45.0 -1.044739  1.196316 -4.108084 -1.510900 -0.745616
# Oak            7.0 -0.035739  1.168828 -1.788996 -0.938084  0.643762
# Pine         130.0 -0.475106  1.288430 -4.677466 -1.320049 -0.050791
# Red oak        3.0 -0.579268  1.040146 -1.253902 -1.178204 -1.102506
# Robinia        1.0 -4.160037       NaN -4.160037 -4.160037 -4.160037
# Spruce         1.0 -2.405881       NaN -2.405881 -2.405881 -2.405881
#
#                             ln_T_ag_Sr                                \
#               75%       max      count      mean       std       min
# Species
# Alder    0.599227  1.107047       13.0  1.114066  0.639805 -0.169130
# Aspen   -0.638032  1.550281        9.0  2.833696  0.588208  1.974979
# Birch   -0.238936  1.534340       45.0  2.370196  0.858688 -0.222660
# Oak      0.714661  1.341910        7.0  1.450404  0.926819  0.552561
# Pine     0.464423  1.651960      130.0  2.438000  0.904689 -0.113856
# Red oak -0.241951  0.618604        3.0  2.351417  0.608020  1.649582
# Robinia -4.160037 -4.160037        1.0  1.845017       NaN  1.845017
# Spruce  -2.405881 -2.405881        1.0  1.807111       NaN  1.807111
#
#
#               25%       50%       75%       max
# Species
# Alder    0.519859  1.340031  1.537968  1.797310
# Aspen    2.415378  2.710312  3.171806  3.759708
# Birch    2.054711  2.467375  2.681882  4.658771
# Oak      0.880759  1.258733  1.625258  3.329504
# Pine     1.825535  2.616560  3.143035  4.114105
# Red oak  2.167897  2.686212  2.702334  2.718456
# Robinia  1.845017  1.845017  1.845017  1.845017
# Spruce   1.807111  1.807111  1.807111  1.807111

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID  % composition        D_cm         H_m     G_m2_ha  \
# count  209.000000     209.000000  209.000000  209.000000  209.000000
# mean     1.057416      94.337925   17.770981   16.978858   30.000765
# std      1.524339      14.155594    8.921738    6.832292   15.907971
# min      0.000000      20.805369    1.914854    2.704460    0.259356
# 25%      0.000000      96.775081   11.601519   12.401789   17.519173
# 50%      0.000000     100.000000   16.817809   17.466646   30.845307
# 75%      2.000000     100.000000   22.264253   21.414562   42.817263
# max      5.000000     100.000000   52.228464   34.048688   66.922093
#
#         Origin_ID      A_year   F_Soil_ID      M_Soil   AEDR_mean  \
# count  209.000000  209.000000  209.000000  209.000000  209.000000
# mean     0.454545   47.464115    1.918660    2.220096    2.526858
# std      0.499125   24.724635    0.634039    0.692944    4.756383
# min      0.000000   10.000000    1.000000    0.000000    0.110000
# 25%      0.000000   30.000000    2.000000    2.000000    0.460000
# 50%      0.000000   45.000000    2.000000    2.000000    0.756000
# 75%      1.000000   60.000000    2.000000    3.000000    2.401667
# max      1.000000  150.000000    3.000000    4.000000   36.591739
#
#        Distance_km     Azimuth  Cs_2021_kBq_m  Sr_2021_kBq_m     ln_A_Cs  \
# count   209.000000  209.000000     209.000000     209.000000  209.000000
# mean     14.640059  174.296651    2040.059453     670.875816    5.964225
# std      12.363729   99.912885    3821.573719    1529.917216    2.095016
# min       3.998568    9.000000      28.815348       2.402062    1.504077
# 25%       6.562497   56.000000     446.906289      44.007562    4.110874
# 50%       9.203749  189.000000     708.799781     187.465954    6.309918
# 75%      20.865459  261.000000    1940.992207     442.523198    7.306531
# max      57.286577  342.000000   25173.384978   10477.431302   11.366743
#
#           ln_A_Sr  ln_T_ag_Cs  ln_T_ag_Sr
# count  209.000000  209.000000  209.000000
# mean     7.381811   -0.640088    2.317915
# std      2.042856    1.288804    0.931775
# min      2.406945   -4.677466   -0.222660
# 25%      5.752573   -1.390832    1.734814
# 50%      7.506592   -0.504711    2.420262
# 75%      8.846497    0.338120    2.967019
# max     13.864301    1.651960    4.658771

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_T_ag_Cs"
indep_variables = ['Species_ID','D_cm', 'H_m', 'G_m2_ha', 'A_year',
    'Origin_ID', 'F_Soil_ID', 'M_Soil']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#     Species  Species_ID  % composition       D_cm        H_m    G_m2_ha  \
# 0      Pine           0     100.000000  26.060965  25.423284  49.081648
# 1      Pine           0      90.178571   4.303100   4.705979   8.731641
# 2      Pine           0     100.000000  28.142898  27.556869  54.703060
# 3      Pine           0     100.000000  14.953551   8.506028  40.420188
# 4      Pine           0     100.000000   7.208435   3.425669   2.120687
# ..      ...         ...            ...        ...        ...        ...
# 204   Aspen           4      99.930119  11.401754  14.676282  17.972410
# 205   Birch           2     100.000000   7.912790  13.818368  19.279495
# 206    Pine           0     100.000000  16.041613  17.515821  31.533411
# 207    Pine           0      96.775081  14.946465  18.178975  44.220927
# 208    Pine           0     100.000000  15.387224  17.673021  55.824342
#
#     Origin  Origin_ID  A_year  F_Soil_ID  M_Soil  AEDR_mean  Distance_km  \
# 0        a          1      68          1       2   3.524231     5.926403
# 1        n          0      15          1       2   3.830667     6.018960
# 2        n          0      69          1       2   0.483571    13.046428
# 3        n          0      15          2       2   0.364500    12.741627
# 4        n          0      10          2       2   0.333333    12.893213
# ..     ...        ...     ...        ...     ...        ...          ...
# 204      n          0      25          2       3  20.051250     5.190617
# 205      n          0      18          2       3  14.987391     4.749715
# 206      a          1      58          1       2   0.650000     7.850538
# 207      a          1      60          1       2   0.649063     7.276525
# 208      a          1      40          1       2   0.628214     7.292122
#
#      Azimuth  Cs_2021_kBq_m  Sr_2021_kBq_m    ln_A_Cs    ln_A_Sr  ln_T_ag_Cs  \
# 0        249    2842.194109     998.435843   7.705262   9.103868   -0.247069
# 1        249    2930.287815     987.750099   8.420682  10.083724    0.437826
# 2        189     281.088291      65.777826   5.099866   6.416732   -0.538802
# 3        189     289.512268      69.886752   3.737670   5.910797   -1.930528
# 4        189     287.067816      69.993095   4.290459   6.139885   -1.369259
# ..       ...            ...            ...        ...        ...         ...
# 204      265   18333.074578    7311.788354  11.366743  11.089805    1.550281
# 205      262   22082.849575    8387.428089   9.539644  11.501865   -0.462912
# 206      106     539.850835     148.369587   6.498282   8.283999    0.206989
# 207       85     519.756852     136.839876   6.720220   8.575462    0.466859
# 208       86     518.079556     135.439932   6.674561   8.216088    0.424433
#
#      ln_T_ag_Sr
# 0      2.197678
# 1      3.188294
# 2      2.230449
# 3      1.663921
# 4      1.891488
# ..          ...
# 204    2.192562
# 205    2.467375
# 206    3.284293
# 207    3.656651
# 208    3.307560
#
# [209 rows x 20 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID       D_cm        H_m    G_m2_ha  A_year  Origin_ID  F_Soil_ID  \
# 0           0  26.060965  25.423284  49.081648      68          1          1
# 1           0   4.303100   4.705979   8.731641      15          0          1
# 2           0  28.142898  27.556869  54.703060      69          0          1
# 3           0  14.953551   8.506028  40.420188      15          0          2
# 4           0   7.208435   3.425669   2.120687      10          0          2
#
#    M_Soil
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_T_ag_Cs
# 0   -0.247069
# 1    0.437826
# 2   -0.538802
# 3   -1.930528
# 4   -1.369259

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.21442245334899446, 0.2232319613913185, 0.15851798900088865]
#     Mean: 0.199
#     Std: 0.029
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.15727918 1.12307935 1.15049056]
#     Mean: 1.144
#     Std: 0.015
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.8482301603366558, 0.9962964488745669, 1.00477295021393]
#     Mean: 0.950
#     Std: 0.072
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.45691821501086227                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.2560259537637241                    # gamma
print('Gamma: ' + str(p2))

p3 = 0.012598221621159957                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 4            # max_depth
print('Max_depth: ' + str(p4))

p5 = 63          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.9043195843997436                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.45691821501086227
# Gamma: 0.2560259537637241
# Learning_rate: 0.012598221621159957
# Max_depth: 4
# N_estimators: 63
# Subsample: 0.9043195843997436

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    exp_R_square = r2_score(exp_y_test, exp_y_pred)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.62700	validation_1-rmse:1.98838
# [1]	validation_0-rmse:1.61702	validation_1-rmse:1.97804
# [2]	validation_0-rmse:1.60536	validation_1-rmse:1.96544
# [3]	validation_0-rmse:1.59541	validation_1-rmse:1.95614
# [4]	validation_0-rmse:1.58522	validation_1-rmse:1.94489
# [5]	validation_0-rmse:1.57411	validation_1-rmse:1.93853
# [6]	validation_0-rmse:1.56315	validation_1-rmse:1.92669
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:1.55185	validation_1-rmse:1.91515
# [8]	validation_0-rmse:1.54097	validation_1-rmse:1.90293
# [9]	validation_0-rmse:1.53140	validation_1-rmse:1.89346
# [10]	validation_0-rmse:1.52078	validation_1-rmse:1.88214
# [11]	validation_0-rmse:1.51002	validation_1-rmse:1.86927
# [12]	validation_0-rmse:1.50120	validation_1-rmse:1.85933
# [13]	validation_0-rmse:1.49230	validation_1-rmse:1.85000
# [14]	validation_0-rmse:1.48364	validation_1-rmse:1.84404
# [15]	validation_0-rmse:1.47314	validation_1-rmse:1.83245
# [16]	validation_0-rmse:1.46294	validation_1-rmse:1.82056
# [17]	validation_0-rmse:1.45267	validation_1-rmse:1.80972
# [18]	validation_0-rmse:1.44361	validation_1-rmse:1.80051
# [19]	validation_0-rmse:1.43301	validation_1-rmse:1.79003
# [20]	validation_0-rmse:1.42538	validation_1-rmse:1.78061
# [21]	validation_0-rmse:1.41567	validation_1-rmse:1.77062
# [22]	validation_0-rmse:1.40765	validation_1-rmse:1.76202
# [23]	validation_0-rmse:1.39840	validation_1-rmse:1.75259
# [24]	validation_0-rmse:1.38888	validation_1-rmse:1.74159
# [25]	validation_0-rmse:1.37997	validation_1-rmse:1.73309
# [26]	validation_0-rmse:1.37220	validation_1-rmse:1.72570
# [27]	validation_0-rmse:1.36304	validation_1-rmse:1.71550
# [28]	validation_0-rmse:1.35574	validation_1-rmse:1.70832
# [29]	validation_0-rmse:1.34651	validation_1-rmse:1.69879
# [30]	validation_0-rmse:1.34027	validation_1-rmse:1.69183
# [31]	validation_0-rmse:1.33345	validation_1-rmse:1.68374
# [32]	validation_0-rmse:1.32492	validation_1-rmse:1.67620
# [33]	validation_0-rmse:1.31807	validation_1-rmse:1.67094
# [34]	validation_0-rmse:1.30968	validation_1-rmse:1.66219
# [35]	validation_0-rmse:1.30344	validation_1-rmse:1.65553
# [36]	validation_0-rmse:1.29725	validation_1-rmse:1.65073
# [37]	validation_0-rmse:1.29089	validation_1-rmse:1.64431
# [38]	validation_0-rmse:1.28376	validation_1-rmse:1.63655
# [39]	validation_0-rmse:1.27654	validation_1-rmse:1.62978
# [40]	validation_0-rmse:1.26947	validation_1-rmse:1.62165
# [41]	validation_0-rmse:1.26344	validation_1-rmse:1.61591
# [42]	validation_0-rmse:1.25670	validation_1-rmse:1.61244
# [43]	validation_0-rmse:1.25067	validation_1-rmse:1.60611
# [44]	validation_0-rmse:1.24413	validation_1-rmse:1.59990
# [45]	validation_0-rmse:1.23838	validation_1-rmse:1.59554
# [46]	validation_0-rmse:1.23113	validation_1-rmse:1.58772
# [47]	validation_0-rmse:1.22520	validation_1-rmse:1.58228
# [48]	validation_0-rmse:1.21786	validation_1-rmse:1.57337
# [49]	validation_0-rmse:1.21131	validation_1-rmse:1.56686
# [50]	validation_0-rmse:1.20462	validation_1-rmse:1.55881
# [51]	validation_0-rmse:1.19759	validation_1-rmse:1.55064
# [52]	validation_0-rmse:1.19123	validation_1-rmse:1.54393
# [53]	validation_0-rmse:1.18644	validation_1-rmse:1.53850
# [54]	validation_0-rmse:1.18134	validation_1-rmse:1.53319
# [55]	validation_0-rmse:1.17606	validation_1-rmse:1.52818
# [56]	validation_0-rmse:1.16964	validation_1-rmse:1.52155
# [57]	validation_0-rmse:1.16206	validation_1-rmse:1.51489
# [58]	validation_0-rmse:1.15682	validation_1-rmse:1.50852
# [59]	validation_0-rmse:1.15189	validation_1-rmse:1.50246
# [60]	validation_0-rmse:1.14759	validation_1-rmse:1.49868
# [61]	validation_0-rmse:1.14117	validation_1-rmse:1.49606
# [62]	validation_0-rmse:1.13489	validation_1-rmse:1.49077
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.63724	validation_1-rmse:1.95223
# [1]	validation_0-rmse:1.62718	validation_1-rmse:1.94092
# [2]	validation_0-rmse:1.61378	validation_1-rmse:1.92889
# [3]	validation_0-rmse:1.60411	validation_1-rmse:1.91962
# [4]	validation_0-rmse:1.59370	validation_1-rmse:1.90885
# [5]	validation_0-rmse:1.58260	validation_1-rmse:1.89968
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:1.57232	validation_1-rmse:1.89119
# [7]	validation_0-rmse:1.56175	validation_1-rmse:1.88122
# [8]	validation_0-rmse:1.55080	validation_1-rmse:1.87123
# [9]	validation_0-rmse:1.54138	validation_1-rmse:1.86401
# [10]	validation_0-rmse:1.53033	validation_1-rmse:1.85655
# [11]	validation_0-rmse:1.52005	validation_1-rmse:1.84458
# [12]	validation_0-rmse:1.51195	validation_1-rmse:1.83374
# [13]	validation_0-rmse:1.50216	validation_1-rmse:1.82262
# [14]	validation_0-rmse:1.49206	validation_1-rmse:1.81617
# [15]	validation_0-rmse:1.48018	validation_1-rmse:1.80608
# [16]	validation_0-rmse:1.46983	validation_1-rmse:1.79653
# [17]	validation_0-rmse:1.45970	validation_1-rmse:1.78668
# [18]	validation_0-rmse:1.44940	validation_1-rmse:1.77728
# [19]	validation_0-rmse:1.43964	validation_1-rmse:1.76765
# [20]	validation_0-rmse:1.43076	validation_1-rmse:1.75924
# [21]	validation_0-rmse:1.42074	validation_1-rmse:1.75085
# [22]	validation_0-rmse:1.41258	validation_1-rmse:1.74024
# [23]	validation_0-rmse:1.40362	validation_1-rmse:1.73072
# [24]	validation_0-rmse:1.39467	validation_1-rmse:1.72244
# [25]	validation_0-rmse:1.38592	validation_1-rmse:1.71426
# [26]	validation_0-rmse:1.37949	validation_1-rmse:1.70649
# [27]	validation_0-rmse:1.37016	validation_1-rmse:1.69546
# [28]	validation_0-rmse:1.36265	validation_1-rmse:1.68693
# [29]	validation_0-rmse:1.35396	validation_1-rmse:1.67828
# [30]	validation_0-rmse:1.34748	validation_1-rmse:1.66921
# [31]	validation_0-rmse:1.33962	validation_1-rmse:1.66248
# [32]	validation_0-rmse:1.33114	validation_1-rmse:1.65722
# [33]	validation_0-rmse:1.32283	validation_1-rmse:1.64892
# [34]	validation_0-rmse:1.31400	validation_1-rmse:1.64025
# [35]	validation_0-rmse:1.30781	validation_1-rmse:1.63255
# [36]	validation_0-rmse:1.30187	validation_1-rmse:1.62844
# [37]	validation_0-rmse:1.29495	validation_1-rmse:1.62033
# [38]	validation_0-rmse:1.28736	validation_1-rmse:1.61270
# [39]	validation_0-rmse:1.28021	validation_1-rmse:1.60766
# [40]	validation_0-rmse:1.27278	validation_1-rmse:1.60285
# [41]	validation_0-rmse:1.26656	validation_1-rmse:1.59581
# [42]	validation_0-rmse:1.25924	validation_1-rmse:1.58900
# [43]	validation_0-rmse:1.25274	validation_1-rmse:1.58501
# [44]	validation_0-rmse:1.24677	validation_1-rmse:1.57991
# [45]	validation_0-rmse:1.24163	validation_1-rmse:1.57650
# [46]	validation_0-rmse:1.23369	validation_1-rmse:1.56861
# [47]	validation_0-rmse:1.22664	validation_1-rmse:1.56177
# [48]	validation_0-rmse:1.21924	validation_1-rmse:1.55474
# [49]	validation_0-rmse:1.21285	validation_1-rmse:1.54839
# [50]	validation_0-rmse:1.20597	validation_1-rmse:1.54205
# [51]	validation_0-rmse:1.19865	validation_1-rmse:1.53505
# [52]	validation_0-rmse:1.19215	validation_1-rmse:1.52682
# [53]	validation_0-rmse:1.18710	validation_1-rmse:1.52171
# [54]	validation_0-rmse:1.18152	validation_1-rmse:1.51701
# [55]	validation_0-rmse:1.17636	validation_1-rmse:1.51111
# [56]	validation_0-rmse:1.17034	validation_1-rmse:1.50662
# [57]	validation_0-rmse:1.16291	validation_1-rmse:1.50026
# [58]	validation_0-rmse:1.15789	validation_1-rmse:1.49431
# [59]	validation_0-rmse:1.15252	validation_1-rmse:1.48900
# [60]	validation_0-rmse:1.14623	validation_1-rmse:1.48427
# [61]	validation_0-rmse:1.13982	validation_1-rmse:1.48060
# [62]	validation_0-rmse:1.13238	validation_1-rmse:1.47467
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.68145	validation_1-rmse:1.79462
# [1]	validation_0-rmse:1.67046	validation_1-rmse:1.78385
# [2]	validation_0-rmse:1.65664	validation_1-rmse:1.77314
# [3]	validation_0-rmse:1.64580	validation_1-rmse:1.76223
# [4]	validation_0-rmse:1.63376	validation_1-rmse:1.75171
# [5]	validation_0-rmse:1.62289	validation_1-rmse:1.74424
# [6]	validation_0-rmse:1.61120	validation_1-rmse:1.73324
# [7]	validation_0-rmse:1.59892	validation_1-rmse:1.72272
# [8]	validation_0-rmse:1.58780	validation_1-rmse:1.71152
# [9]	validation_0-rmse:1.57839	validation_1-rmse:1.70127
# [10]	validation_0-rmse:1.56755	validation_1-rmse:1.69091
# [11]	validation_0-rmse:1.55661	validation_1-rmse:1.67933
# [12]	validation_0-rmse:1.54712	validation_1-rmse:1.67012
# [13]	validation_0-rmse:1.53735	validation_1-rmse:1.66159
# [14]	validation_0-rmse:1.52825	validation_1-rmse:1.65376
# [15]	validation_0-rmse:1.51650	validation_1-rmse:1.64202
# [16]	validation_0-rmse:1.50515	validation_1-rmse:1.63043
# [17]	validation_0-rmse:1.49430	validation_1-rmse:1.62163
# [18]	validation_0-rmse:1.48279	validation_1-rmse:1.61235
# [19]	validation_0-rmse:1.47318	validation_1-rmse:1.60341
# [20]	validation_0-rmse:1.46406	validation_1-rmse:1.59507
# [21]	validation_0-rmse:1.45420	validation_1-rmse:1.58473
# [22]	validation_0-rmse:1.44513	validation_1-rmse:1.57645
# [23]	validation_0-rmse:1.43543	validation_1-rmse:1.56749
# [24]	validation_0-rmse:1.42557	validation_1-rmse:1.55822
# [25]	validation_0-rmse:1.41547	validation_1-rmse:1.55005
# [26]	validation_0-rmse:1.40730	validation_1-rmse:1.54297
# [27]	validation_0-rmse:1.39727	validation_1-rmse:1.53528
# [28]	validation_0-rmse:1.38886	validation_1-rmse:1.52850
# [29]	validation_0-rmse:1.37911	validation_1-rmse:1.52193
# [30]	validation_0-rmse:1.37163	validation_1-rmse:1.51475
# [31]	validation_0-rmse:1.36341	validation_1-rmse:1.50885
# [32]	validation_0-rmse:1.35435	validation_1-rmse:1.50080
# [33]	validation_0-rmse:1.34509	validation_1-rmse:1.49078
# [34]	validation_0-rmse:1.33628	validation_1-rmse:1.48466
# [35]	validation_0-rmse:1.32986	validation_1-rmse:1.47845
# [36]	validation_0-rmse:1.32273	validation_1-rmse:1.47184
# [37]	validation_0-rmse:1.31549	validation_1-rmse:1.46675
# [38]	validation_0-rmse:1.30813	validation_1-rmse:1.45945
# [39]	validation_0-rmse:1.30130	validation_1-rmse:1.45459
# [40]	validation_0-rmse:1.29589	validation_1-rmse:1.44894
# [41]	validation_0-rmse:1.28990	validation_1-rmse:1.44202
# [42]	validation_0-rmse:1.28235	validation_1-rmse:1.43543
# [43]	validation_0-rmse:1.27661	validation_1-rmse:1.43066
# [44]	validation_0-rmse:1.27007	validation_1-rmse:1.42588
# [45]	validation_0-rmse:1.26492	validation_1-rmse:1.42097
# [46]	validation_0-rmse:1.25699	validation_1-rmse:1.41409
# [47]	validation_0-rmse:1.24995	validation_1-rmse:1.40584
# [48]	validation_0-rmse:1.24306	validation_1-rmse:1.39924
# [49]	validation_0-rmse:1.23592	validation_1-rmse:1.39418
# [50]	validation_0-rmse:1.22868	validation_1-rmse:1.38771
# [51]	validation_0-rmse:1.22108	validation_1-rmse:1.38178
# [52]	validation_0-rmse:1.21439	validation_1-rmse:1.37670
# [53]	validation_0-rmse:1.20893	validation_1-rmse:1.37123
# [54]	validation_0-rmse:1.20295	validation_1-rmse:1.36764
# [55]	validation_0-rmse:1.19783	validation_1-rmse:1.36292
# [56]	validation_0-rmse:1.19203	validation_1-rmse:1.35685
# [57]	validation_0-rmse:1.18405	validation_1-rmse:1.34935
# [58]	validation_0-rmse:1.17819	validation_1-rmse:1.34439
# [59]	validation_0-rmse:1.17229	validation_1-rmse:1.34051
# [60]	validation_0-rmse:1.16815	validation_1-rmse:1.33618
# [61]	validation_0-rmse:1.16280	validation_1-rmse:1.33284
# [62]	validation_0-rmse:1.15643	validation_1-rmse:1.32890
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.66966	validation_1-rmse:1.83600
# [1]	validation_0-rmse:1.65908	validation_1-rmse:1.82488
# [2]	validation_0-rmse:1.64564	validation_1-rmse:1.81258
# [3]	validation_0-rmse:1.63586	validation_1-rmse:1.80193
# [4]	validation_0-rmse:1.62475	validation_1-rmse:1.79163
# [5]	validation_0-rmse:1.61424	validation_1-rmse:1.78153
# [6]	validation_0-rmse:1.60256	validation_1-rmse:1.77066
# [7]	validation_0-rmse:1.59019	validation_1-rmse:1.75947
# [8]	validation_0-rmse:1.57841	validation_1-rmse:1.74908
# [9]	validation_0-rmse:1.56947	validation_1-rmse:1.74028
# [10]	validation_0-rmse:1.55907	validation_1-rmse:1.73058
# [11]	validation_0-rmse:1.54773	validation_1-rmse:1.71982
# [12]	validation_0-rmse:1.53800	validation_1-rmse:1.71075
# [13]	validation_0-rmse:1.52833	validation_1-rmse:1.70104
# [14]	validation_0-rmse:1.51935	validation_1-rmse:1.69155
# [15]	validation_0-rmse:1.50719	validation_1-rmse:1.67993
# [16]	validation_0-rmse:1.49673	validation_1-rmse:1.66995
# [17]	validation_0-rmse:1.48602	validation_1-rmse:1.66065
# [18]	validation_0-rmse:1.47443	validation_1-rmse:1.65156
# [19]	validation_0-rmse:1.46450	validation_1-rmse:1.64207
# [20]	validation_0-rmse:1.45556	validation_1-rmse:1.63531
# [21]	validation_0-rmse:1.44565	validation_1-rmse:1.62626
# [22]	validation_0-rmse:1.43673	validation_1-rmse:1.61775
# [23]	validation_0-rmse:1.42698	validation_1-rmse:1.60795
# [24]	validation_0-rmse:1.41758	validation_1-rmse:1.59937
# [25]	validation_0-rmse:1.40755	validation_1-rmse:1.59135
# [26]	validation_0-rmse:1.39898	validation_1-rmse:1.58390
# [27]	validation_0-rmse:1.38947	validation_1-rmse:1.57556
# [28]	validation_0-rmse:1.38084	validation_1-rmse:1.56828
# [29]	validation_0-rmse:1.37098	validation_1-rmse:1.56127
# [30]	validation_0-rmse:1.36338	validation_1-rmse:1.55465
# [31]	validation_0-rmse:1.35602	validation_1-rmse:1.54850
# [32]	validation_0-rmse:1.34669	validation_1-rmse:1.54000
# [33]	validation_0-rmse:1.33757	validation_1-rmse:1.53255
# [34]	validation_0-rmse:1.32815	validation_1-rmse:1.52791
# [35]	validation_0-rmse:1.32138	validation_1-rmse:1.52222
# [36]	validation_0-rmse:1.31505	validation_1-rmse:1.51647
# [37]	validation_0-rmse:1.30813	validation_1-rmse:1.50938
# [38]	validation_0-rmse:1.29993	validation_1-rmse:1.50159
# [39]	validation_0-rmse:1.29288	validation_1-rmse:1.49440
# [40]	validation_0-rmse:1.28547	validation_1-rmse:1.48764
# [41]	validation_0-rmse:1.27947	validation_1-rmse:1.48210
# [42]	validation_0-rmse:1.27200	validation_1-rmse:1.47704
# [43]	validation_0-rmse:1.26628	validation_1-rmse:1.47236
# [44]	validation_0-rmse:1.25961	validation_1-rmse:1.46782
# [45]	validation_0-rmse:1.25441	validation_1-rmse:1.46243
# [46]	validation_0-rmse:1.24656	validation_1-rmse:1.45451
# [47]	validation_0-rmse:1.23905	validation_1-rmse:1.44843
# [48]	validation_0-rmse:1.23112	validation_1-rmse:1.44144
# [49]	validation_0-rmse:1.22383	validation_1-rmse:1.43454
# [50]	validation_0-rmse:1.21643	validation_1-rmse:1.42873
# [51]	validation_0-rmse:1.20825	validation_1-rmse:1.42239
# [52]	validation_0-rmse:1.20065	validation_1-rmse:1.41710
# [53]	validation_0-rmse:1.19511	validation_1-rmse:1.41243
# [54]	validation_0-rmse:1.18941	validation_1-rmse:1.40703
# [55]	validation_0-rmse:1.18341	validation_1-rmse:1.40307
# [56]	validation_0-rmse:1.17748	validation_1-rmse:1.39759
# [57]	validation_0-rmse:1.16987	validation_1-rmse:1.39166
# [58]	validation_0-rmse:1.16381	validation_1-rmse:1.38742
# [59]	validation_0-rmse:1.15797	validation_1-rmse:1.38339
# [60]	validation_0-rmse:1.15237	validation_1-rmse:1.37828
# [61]	validation_0-rmse:1.14611	validation_1-rmse:1.37319
# [62]	validation_0-rmse:1.13930	validation_1-rmse:1.36865
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.75959	validation_1-rmse:1.46571
# [1]	validation_0-rmse:1.74801	validation_1-rmse:1.45370
# [2]	validation_0-rmse:1.73495	validation_1-rmse:1.44379
# [3]	validation_0-rmse:1.72375	validation_1-rmse:1.43351
# [4]	validation_0-rmse:1.71106	validation_1-rmse:1.42221
# [5]	validation_0-rmse:1.69839	validation_1-rmse:1.41010
# [6]	validation_0-rmse:1.68597	validation_1-rmse:1.39673
# [7]	validation_0-rmse:1.67386	validation_1-rmse:1.38655
# [8]	validation_0-rmse:1.66111	validation_1-rmse:1.37484
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [9]	validation_0-rmse:1.65097	validation_1-rmse:1.36513
# [10]	validation_0-rmse:1.63975	validation_1-rmse:1.35314
# [11]	validation_0-rmse:1.62754	validation_1-rmse:1.33909
# [12]	validation_0-rmse:1.61778	validation_1-rmse:1.32867
# [13]	validation_0-rmse:1.60660	validation_1-rmse:1.31795
# [14]	validation_0-rmse:1.59716	validation_1-rmse:1.30888
# [15]	validation_0-rmse:1.58484	validation_1-rmse:1.29872
# [16]	validation_0-rmse:1.57437	validation_1-rmse:1.28783
# [17]	validation_0-rmse:1.56325	validation_1-rmse:1.27710
# [18]	validation_0-rmse:1.55297	validation_1-rmse:1.26889
# [19]	validation_0-rmse:1.54232	validation_1-rmse:1.25890
# [20]	validation_0-rmse:1.53330	validation_1-rmse:1.24986
# [21]	validation_0-rmse:1.52253	validation_1-rmse:1.24060
# [22]	validation_0-rmse:1.51345	validation_1-rmse:1.23170
# [23]	validation_0-rmse:1.50259	validation_1-rmse:1.22165
# [24]	validation_0-rmse:1.49262	validation_1-rmse:1.21269
# [25]	validation_0-rmse:1.48260	validation_1-rmse:1.20407
# [26]	validation_0-rmse:1.47477	validation_1-rmse:1.19671
# [27]	validation_0-rmse:1.46417	validation_1-rmse:1.18709
# [28]	validation_0-rmse:1.45597	validation_1-rmse:1.17930
# [29]	validation_0-rmse:1.44613	validation_1-rmse:1.17287
# [30]	validation_0-rmse:1.43894	validation_1-rmse:1.16562
# [31]	validation_0-rmse:1.43065	validation_1-rmse:1.15915
# [32]	validation_0-rmse:1.42092	validation_1-rmse:1.15085
# [33]	validation_0-rmse:1.41220	validation_1-rmse:1.14340
# [34]	validation_0-rmse:1.40314	validation_1-rmse:1.13785
# [35]	validation_0-rmse:1.39693	validation_1-rmse:1.13248
# [36]	validation_0-rmse:1.38997	validation_1-rmse:1.12639
# [37]	validation_0-rmse:1.38217	validation_1-rmse:1.12043
# [38]	validation_0-rmse:1.37392	validation_1-rmse:1.11381
# [39]	validation_0-rmse:1.36639	validation_1-rmse:1.10691
# [40]	validation_0-rmse:1.35815	validation_1-rmse:1.10171
# [41]	validation_0-rmse:1.35197	validation_1-rmse:1.09566
# [42]	validation_0-rmse:1.34535	validation_1-rmse:1.08943
# [43]	validation_0-rmse:1.33865	validation_1-rmse:1.08498
# [44]	validation_0-rmse:1.33172	validation_1-rmse:1.07893
# [45]	validation_0-rmse:1.32559	validation_1-rmse:1.07389
# [46]	validation_0-rmse:1.31637	validation_1-rmse:1.06605
# [47]	validation_0-rmse:1.30920	validation_1-rmse:1.05890
# [48]	validation_0-rmse:1.30055	validation_1-rmse:1.05211
# [49]	validation_0-rmse:1.29374	validation_1-rmse:1.04724
# [50]	validation_0-rmse:1.28643	validation_1-rmse:1.03932
# [51]	validation_0-rmse:1.27870	validation_1-rmse:1.03496
# [52]	validation_0-rmse:1.27173	validation_1-rmse:1.03009
# [53]	validation_0-rmse:1.26657	validation_1-rmse:1.02540
# [54]	validation_0-rmse:1.26010	validation_1-rmse:1.02182
# [55]	validation_0-rmse:1.25428	validation_1-rmse:1.01719
# [56]	validation_0-rmse:1.24828	validation_1-rmse:1.01259
# [57]	validation_0-rmse:1.24137	validation_1-rmse:1.00809
# [58]	validation_0-rmse:1.23497	validation_1-rmse:1.00486
# [59]	validation_0-rmse:1.22906	validation_1-rmse:1.00126
# [60]	validation_0-rmse:1.22293	validation_1-rmse:0.99719
# [61]	validation_0-rmse:1.21652	validation_1-rmse:0.99370
# [62]	validation_0-rmse:1.20981	validation_1-rmse:0.99019
# [0]	validation_0-rmse:1.71487	validation_1-rmse:1.66498
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.70356	validation_1-rmse:1.65518
# [2]	validation_0-rmse:1.68900	validation_1-rmse:1.64201
# [3]	validation_0-rmse:1.67805	validation_1-rmse:1.63242
# [4]	validation_0-rmse:1.66629	validation_1-rmse:1.62028
# [5]	validation_0-rmse:1.65527	validation_1-rmse:1.60890
# [6]	validation_0-rmse:1.64471	validation_1-rmse:1.59823
# [7]	validation_0-rmse:1.63239	validation_1-rmse:1.58741
# [8]	validation_0-rmse:1.62048	validation_1-rmse:1.57656
# [9]	validation_0-rmse:1.61033	validation_1-rmse:1.56795
# [10]	validation_0-rmse:1.59915	validation_1-rmse:1.55863
# [11]	validation_0-rmse:1.58860	validation_1-rmse:1.54910
# [12]	validation_0-rmse:1.57887	validation_1-rmse:1.54001
# [13]	validation_0-rmse:1.56846	validation_1-rmse:1.52899
# [14]	validation_0-rmse:1.55961	validation_1-rmse:1.51971
# [15]	validation_0-rmse:1.54729	validation_1-rmse:1.50783
# [16]	validation_0-rmse:1.53640	validation_1-rmse:1.49647
# [17]	validation_0-rmse:1.52426	validation_1-rmse:1.48599
# [18]	validation_0-rmse:1.51197	validation_1-rmse:1.47670
# [19]	validation_0-rmse:1.50072	validation_1-rmse:1.46638
# [20]	validation_0-rmse:1.49161	validation_1-rmse:1.45693
# [21]	validation_0-rmse:1.48173	validation_1-rmse:1.44870
# [22]	validation_0-rmse:1.47279	validation_1-rmse:1.44123
# [23]	validation_0-rmse:1.46302	validation_1-rmse:1.43291
# [24]	validation_0-rmse:1.45286	validation_1-rmse:1.42335
# [25]	validation_0-rmse:1.44323	validation_1-rmse:1.41496
# [26]	validation_0-rmse:1.43446	validation_1-rmse:1.40927
# [27]	validation_0-rmse:1.42412	validation_1-rmse:1.40087
# [28]	validation_0-rmse:1.41605	validation_1-rmse:1.39556
# [29]	validation_0-rmse:1.40580	validation_1-rmse:1.38714
# [30]	validation_0-rmse:1.39792	validation_1-rmse:1.38016
# [31]	validation_0-rmse:1.38996	validation_1-rmse:1.37343
# [32]	validation_0-rmse:1.38149	validation_1-rmse:1.36534
# [33]	validation_0-rmse:1.37258	validation_1-rmse:1.36016
# [34]	validation_0-rmse:1.36329	validation_1-rmse:1.35300
# [35]	validation_0-rmse:1.35655	validation_1-rmse:1.34713
# [36]	validation_0-rmse:1.34981	validation_1-rmse:1.34197
# [37]	validation_0-rmse:1.34246	validation_1-rmse:1.33476
# [38]	validation_0-rmse:1.33415	validation_1-rmse:1.32773
# [39]	validation_0-rmse:1.32653	validation_1-rmse:1.32058
# [40]	validation_0-rmse:1.31874	validation_1-rmse:1.31291
# [41]	validation_0-rmse:1.31272	validation_1-rmse:1.30791
# [42]	validation_0-rmse:1.30542	validation_1-rmse:1.30116
# [43]	validation_0-rmse:1.29962	validation_1-rmse:1.29521
# [44]	validation_0-rmse:1.29261	validation_1-rmse:1.28857
# [45]	validation_0-rmse:1.28677	validation_1-rmse:1.28438
# [46]	validation_0-rmse:1.27877	validation_1-rmse:1.27738
# [47]	validation_0-rmse:1.27132	validation_1-rmse:1.27048
# [48]	validation_0-rmse:1.26349	validation_1-rmse:1.26575
# [49]	validation_0-rmse:1.25611	validation_1-rmse:1.25930
# [50]	validation_0-rmse:1.24865	validation_1-rmse:1.25305
# [51]	validation_0-rmse:1.24014	validation_1-rmse:1.24624
# [52]	validation_0-rmse:1.23305	validation_1-rmse:1.24046
# [53]	validation_0-rmse:1.22760	validation_1-rmse:1.23601
# [54]	validation_0-rmse:1.22245	validation_1-rmse:1.23193
# [55]	validation_0-rmse:1.21630	validation_1-rmse:1.22632
# [56]	validation_0-rmse:1.21059	validation_1-rmse:1.22107
# [57]	validation_0-rmse:1.20242	validation_1-rmse:1.21276
# [58]	validation_0-rmse:1.19637	validation_1-rmse:1.20848
# [59]	validation_0-rmse:1.19060	validation_1-rmse:1.20435
# [60]	validation_0-rmse:1.18612	validation_1-rmse:1.20063
# [61]	validation_0-rmse:1.18083	validation_1-rmse:1.19536
# [62]	validation_0-rmse:1.17425	validation_1-rmse:1.19069
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.74906	validation_1-rmse:1.51459
# [1]	validation_0-rmse:1.73808	validation_1-rmse:1.50403
# [2]	validation_0-rmse:1.72491	validation_1-rmse:1.49524
# [3]	validation_0-rmse:1.71384	validation_1-rmse:1.48592
# [4]	validation_0-rmse:1.70184	validation_1-rmse:1.47617
# [5]	validation_0-rmse:1.68867	validation_1-rmse:1.46698
# [6]	validation_0-rmse:1.67683	validation_1-rmse:1.45676
# [7]	validation_0-rmse:1.66426	validation_1-rmse:1.44443
# [8]	validation_0-rmse:1.65261	validation_1-rmse:1.43642
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [9]	validation_0-rmse:1.64175	validation_1-rmse:1.42853
# [10]	validation_0-rmse:1.62989	validation_1-rmse:1.41906
# [11]	validation_0-rmse:1.61846	validation_1-rmse:1.41103
# [12]	validation_0-rmse:1.60842	validation_1-rmse:1.40314
# [13]	validation_0-rmse:1.59700	validation_1-rmse:1.39413
# [14]	validation_0-rmse:1.58645	validation_1-rmse:1.38507
# [15]	validation_0-rmse:1.57367	validation_1-rmse:1.37326
# [16]	validation_0-rmse:1.56275	validation_1-rmse:1.36407
# [17]	validation_0-rmse:1.55087	validation_1-rmse:1.35510
# [18]	validation_0-rmse:1.54041	validation_1-rmse:1.34600
# [19]	validation_0-rmse:1.52943	validation_1-rmse:1.33571
# [20]	validation_0-rmse:1.51996	validation_1-rmse:1.32803
# [21]	validation_0-rmse:1.51005	validation_1-rmse:1.31871
# [22]	validation_0-rmse:1.50087	validation_1-rmse:1.31237
# [23]	validation_0-rmse:1.49095	validation_1-rmse:1.30394
# [24]	validation_0-rmse:1.48023	validation_1-rmse:1.29415
# [25]	validation_0-rmse:1.47005	validation_1-rmse:1.28565
# [26]	validation_0-rmse:1.46045	validation_1-rmse:1.27821
# [27]	validation_0-rmse:1.45004	validation_1-rmse:1.27143
# [28]	validation_0-rmse:1.44152	validation_1-rmse:1.26540
# [29]	validation_0-rmse:1.43302	validation_1-rmse:1.25989
# [30]	validation_0-rmse:1.42494	validation_1-rmse:1.25399
# [31]	validation_0-rmse:1.41630	validation_1-rmse:1.24751
# [32]	validation_0-rmse:1.40605	validation_1-rmse:1.24160
# [33]	validation_0-rmse:1.39800	validation_1-rmse:1.23529
# [34]	validation_0-rmse:1.38937	validation_1-rmse:1.23063
# [35]	validation_0-rmse:1.38282	validation_1-rmse:1.22648
# [36]	validation_0-rmse:1.37597	validation_1-rmse:1.22054
# [37]	validation_0-rmse:1.36702	validation_1-rmse:1.21438
# [38]	validation_0-rmse:1.35861	validation_1-rmse:1.20813
# [39]	validation_0-rmse:1.35131	validation_1-rmse:1.20281
# [40]	validation_0-rmse:1.34287	validation_1-rmse:1.19797
# [41]	validation_0-rmse:1.33654	validation_1-rmse:1.19354
# [42]	validation_0-rmse:1.32807	validation_1-rmse:1.18630
# [43]	validation_0-rmse:1.32067	validation_1-rmse:1.18165
# [44]	validation_0-rmse:1.31390	validation_1-rmse:1.17612
# [45]	validation_0-rmse:1.30810	validation_1-rmse:1.17089
# [46]	validation_0-rmse:1.29964	validation_1-rmse:1.16424
# [47]	validation_0-rmse:1.29328	validation_1-rmse:1.16011
# [48]	validation_0-rmse:1.28505	validation_1-rmse:1.15552
# [49]	validation_0-rmse:1.27737	validation_1-rmse:1.15017
# [50]	validation_0-rmse:1.26927	validation_1-rmse:1.14429
# [51]	validation_0-rmse:1.26223	validation_1-rmse:1.13915
# [52]	validation_0-rmse:1.25575	validation_1-rmse:1.13546
# [53]	validation_0-rmse:1.25036	validation_1-rmse:1.13213
# [54]	validation_0-rmse:1.24398	validation_1-rmse:1.12806
# [55]	validation_0-rmse:1.23744	validation_1-rmse:1.12497
# [56]	validation_0-rmse:1.23126	validation_1-rmse:1.11991
# [57]	validation_0-rmse:1.22354	validation_1-rmse:1.11356
# [58]	validation_0-rmse:1.21745	validation_1-rmse:1.11110
# [59]	validation_0-rmse:1.21187	validation_1-rmse:1.10726
# [60]	validation_0-rmse:1.20494	validation_1-rmse:1.10352
# [61]	validation_0-rmse:1.19820	validation_1-rmse:1.09913
# [62]	validation_0-rmse:1.19137	validation_1-rmse:1.09371
# [0]	validation_0-rmse:1.72545	validation_1-rmse:1.61358
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.71413	validation_1-rmse:1.60355
# [2]	validation_0-rmse:1.70015	validation_1-rmse:1.59341
# [3]	validation_0-rmse:1.68873	validation_1-rmse:1.58401
# [4]	validation_0-rmse:1.67699	validation_1-rmse:1.57210
# [5]	validation_0-rmse:1.66483	validation_1-rmse:1.56254
# [6]	validation_0-rmse:1.65252	validation_1-rmse:1.55273
# [7]	validation_0-rmse:1.64033	validation_1-rmse:1.54290
# [8]	validation_0-rmse:1.62814	validation_1-rmse:1.53410
# [9]	validation_0-rmse:1.61746	validation_1-rmse:1.52518
# [10]	validation_0-rmse:1.60517	validation_1-rmse:1.51759
# [11]	validation_0-rmse:1.59394	validation_1-rmse:1.50714
# [12]	validation_0-rmse:1.58416	validation_1-rmse:1.49849
# [13]	validation_0-rmse:1.57422	validation_1-rmse:1.49181
# [14]	validation_0-rmse:1.56353	validation_1-rmse:1.48429
# [15]	validation_0-rmse:1.55068	validation_1-rmse:1.47663
# [16]	validation_0-rmse:1.53902	validation_1-rmse:1.46929
# [17]	validation_0-rmse:1.52842	validation_1-rmse:1.46012
# [18]	validation_0-rmse:1.51700	validation_1-rmse:1.45286
# [19]	validation_0-rmse:1.50584	validation_1-rmse:1.44615
# [20]	validation_0-rmse:1.49555	validation_1-rmse:1.43934
# [21]	validation_0-rmse:1.48550	validation_1-rmse:1.43204
# [22]	validation_0-rmse:1.47635	validation_1-rmse:1.42383
# [23]	validation_0-rmse:1.46636	validation_1-rmse:1.41722
# [24]	validation_0-rmse:1.45548	validation_1-rmse:1.41074
# [25]	validation_0-rmse:1.44524	validation_1-rmse:1.40291
# [26]	validation_0-rmse:1.43661	validation_1-rmse:1.39700
# [27]	validation_0-rmse:1.42670	validation_1-rmse:1.38931
# [28]	validation_0-rmse:1.41831	validation_1-rmse:1.38398
# [29]	validation_0-rmse:1.40820	validation_1-rmse:1.37735
# [30]	validation_0-rmse:1.40074	validation_1-rmse:1.37010
# [31]	validation_0-rmse:1.39274	validation_1-rmse:1.36454
# [32]	validation_0-rmse:1.38305	validation_1-rmse:1.35746
# [33]	validation_0-rmse:1.37490	validation_1-rmse:1.35258
# [34]	validation_0-rmse:1.36546	validation_1-rmse:1.34744
# [35]	validation_0-rmse:1.35854	validation_1-rmse:1.34077
# [36]	validation_0-rmse:1.35178	validation_1-rmse:1.33619
# [37]	validation_0-rmse:1.34407	validation_1-rmse:1.33136
# [38]	validation_0-rmse:1.33584	validation_1-rmse:1.32661
# [39]	validation_0-rmse:1.32759	validation_1-rmse:1.32201
# [40]	validation_0-rmse:1.31975	validation_1-rmse:1.31865
# [41]	validation_0-rmse:1.31308	validation_1-rmse:1.31275
# [42]	validation_0-rmse:1.30408	validation_1-rmse:1.31068
# [43]	validation_0-rmse:1.29682	validation_1-rmse:1.30763
# [44]	validation_0-rmse:1.28892	validation_1-rmse:1.30360
# [45]	validation_0-rmse:1.28287	validation_1-rmse:1.29949
# [46]	validation_0-rmse:1.27455	validation_1-rmse:1.29414
# [47]	validation_0-rmse:1.26638	validation_1-rmse:1.29021
# [48]	validation_0-rmse:1.25823	validation_1-rmse:1.28499
# [49]	validation_0-rmse:1.25100	validation_1-rmse:1.28014
# [50]	validation_0-rmse:1.24445	validation_1-rmse:1.27737
# [51]	validation_0-rmse:1.23609	validation_1-rmse:1.27323
# [52]	validation_0-rmse:1.22852	validation_1-rmse:1.26822
# [53]	validation_0-rmse:1.22304	validation_1-rmse:1.26541
# [54]	validation_0-rmse:1.21701	validation_1-rmse:1.26137
# [55]	validation_0-rmse:1.21053	validation_1-rmse:1.25865
# [56]	validation_0-rmse:1.20364	validation_1-rmse:1.25677
# [57]	validation_0-rmse:1.19581	validation_1-rmse:1.25146
# [58]	validation_0-rmse:1.19041	validation_1-rmse:1.24564
# [59]	validation_0-rmse:1.18517	validation_1-rmse:1.24144
# [60]	validation_0-rmse:1.17944	validation_1-rmse:1.23806
# [61]	validation_0-rmse:1.17286	validation_1-rmse:1.23702
# [62]	validation_0-rmse:1.16580	validation_1-rmse:1.23380
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.78637	validation_1-rmse:1.32840
# [1]	validation_0-rmse:1.77451	validation_1-rmse:1.31703
# [2]	validation_0-rmse:1.76049	validation_1-rmse:1.30877
# [3]	validation_0-rmse:1.75026	validation_1-rmse:1.30019
# [4]	validation_0-rmse:1.73821	validation_1-rmse:1.28913
# [5]	validation_0-rmse:1.72609	validation_1-rmse:1.27956
# [6]	validation_0-rmse:1.71348	validation_1-rmse:1.26826
# [7]	validation_0-rmse:1.70041	validation_1-rmse:1.26022
# [8]	validation_0-rmse:1.68866	validation_1-rmse:1.25127
# [9]	validation_0-rmse:1.67903	validation_1-rmse:1.24291
# [10]	validation_0-rmse:1.66633	validation_1-rmse:1.23619
# [11]	validation_0-rmse:1.65365	validation_1-rmse:1.22761
# [12]	validation_0-rmse:1.64327	validation_1-rmse:1.21847
# [13]	validation_0-rmse:1.63165	validation_1-rmse:1.20902
# [14]	validation_0-rmse:1.62197	validation_1-rmse:1.20105
# [15]	validation_0-rmse:1.60800	validation_1-rmse:1.18922
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [16]	validation_0-rmse:1.59660	validation_1-rmse:1.18187
# [17]	validation_0-rmse:1.58495	validation_1-rmse:1.17547
# [18]	validation_0-rmse:1.57303	validation_1-rmse:1.16941
# [19]	validation_0-rmse:1.56120	validation_1-rmse:1.16078
# [20]	validation_0-rmse:1.55046	validation_1-rmse:1.15481
# [21]	validation_0-rmse:1.53847	validation_1-rmse:1.14615
# [22]	validation_0-rmse:1.52883	validation_1-rmse:1.13740
# [23]	validation_0-rmse:1.51780	validation_1-rmse:1.12895
# [24]	validation_0-rmse:1.50745	validation_1-rmse:1.12129
# [25]	validation_0-rmse:1.49611	validation_1-rmse:1.11430
# [26]	validation_0-rmse:1.48652	validation_1-rmse:1.10720
# [27]	validation_0-rmse:1.47585	validation_1-rmse:1.09841
# [28]	validation_0-rmse:1.46667	validation_1-rmse:1.09170
# [29]	validation_0-rmse:1.45716	validation_1-rmse:1.08452
# [30]	validation_0-rmse:1.44902	validation_1-rmse:1.07805
# [31]	validation_0-rmse:1.44042	validation_1-rmse:1.07151
# [32]	validation_0-rmse:1.42969	validation_1-rmse:1.06659
# [33]	validation_0-rmse:1.42064	validation_1-rmse:1.06098
# [34]	validation_0-rmse:1.41173	validation_1-rmse:1.05527
# [35]	validation_0-rmse:1.40445	validation_1-rmse:1.04892
# [36]	validation_0-rmse:1.39769	validation_1-rmse:1.04238
# [37]	validation_0-rmse:1.38977	validation_1-rmse:1.03676
# [38]	validation_0-rmse:1.38136	validation_1-rmse:1.03205
# [39]	validation_0-rmse:1.37353	validation_1-rmse:1.02514
# [40]	validation_0-rmse:1.36603	validation_1-rmse:1.01884
# [41]	validation_0-rmse:1.35977	validation_1-rmse:1.01447
# [42]	validation_0-rmse:1.35322	validation_1-rmse:1.01096
# [43]	validation_0-rmse:1.34716	validation_1-rmse:1.00680
# [44]	validation_0-rmse:1.33915	validation_1-rmse:1.00375
# [45]	validation_0-rmse:1.33354	validation_1-rmse:0.99900
# [46]	validation_0-rmse:1.32431	validation_1-rmse:0.99290
# [47]	validation_0-rmse:1.31548	validation_1-rmse:0.98754
# [48]	validation_0-rmse:1.30730	validation_1-rmse:0.98066
# [49]	validation_0-rmse:1.29957	validation_1-rmse:0.97613
# [50]	validation_0-rmse:1.29210	validation_1-rmse:0.97373
# [51]	validation_0-rmse:1.28363	validation_1-rmse:0.96925
# [52]	validation_0-rmse:1.27587	validation_1-rmse:0.96596
# [53]	validation_0-rmse:1.27009	validation_1-rmse:0.96249
# [54]	validation_0-rmse:1.26375	validation_1-rmse:0.95975
# [55]	validation_0-rmse:1.25718	validation_1-rmse:0.95764
# [56]	validation_0-rmse:1.25180	validation_1-rmse:0.95303
# [57]	validation_0-rmse:1.24323	validation_1-rmse:0.94902
# [58]	validation_0-rmse:1.23711	validation_1-rmse:0.94663
# [59]	validation_0-rmse:1.23118	validation_1-rmse:0.94333
# [60]	validation_0-rmse:1.22552	validation_1-rmse:0.93938
# [61]	validation_0-rmse:1.21893	validation_1-rmse:0.93763
# [62]	validation_0-rmse:1.21233	validation_1-rmse:0.93427
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.68971	validation_1-rmse:1.76285
# [1]	validation_0-rmse:1.67835	validation_1-rmse:1.74993
# [2]	validation_0-rmse:1.66642	validation_1-rmse:1.73739
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:1.65638	validation_1-rmse:1.72941
# [4]	validation_0-rmse:1.64484	validation_1-rmse:1.71680
# [5]	validation_0-rmse:1.63257	validation_1-rmse:1.70502
# [6]	validation_0-rmse:1.62025	validation_1-rmse:1.69521
# [7]	validation_0-rmse:1.60768	validation_1-rmse:1.68470
# [8]	validation_0-rmse:1.59657	validation_1-rmse:1.67464
# [9]	validation_0-rmse:1.58644	validation_1-rmse:1.66563
# [10]	validation_0-rmse:1.57545	validation_1-rmse:1.65430
# [11]	validation_0-rmse:1.56379	validation_1-rmse:1.64230
# [12]	validation_0-rmse:1.55389	validation_1-rmse:1.63110
# [13]	validation_0-rmse:1.54383	validation_1-rmse:1.62240
# [14]	validation_0-rmse:1.53495	validation_1-rmse:1.61447
# [15]	validation_0-rmse:1.52279	validation_1-rmse:1.60654
# [16]	validation_0-rmse:1.51363	validation_1-rmse:1.59826
# [17]	validation_0-rmse:1.50216	validation_1-rmse:1.58632
# [18]	validation_0-rmse:1.49194	validation_1-rmse:1.57494
# [19]	validation_0-rmse:1.48126	validation_1-rmse:1.56636
# [20]	validation_0-rmse:1.47231	validation_1-rmse:1.55944
# [21]	validation_0-rmse:1.46243	validation_1-rmse:1.55320
# [22]	validation_0-rmse:1.45334	validation_1-rmse:1.54568
# [23]	validation_0-rmse:1.44260	validation_1-rmse:1.53470
# [24]	validation_0-rmse:1.43228	validation_1-rmse:1.52445
# [25]	validation_0-rmse:1.42198	validation_1-rmse:1.51739
# [26]	validation_0-rmse:1.41428	validation_1-rmse:1.50913
# [27]	validation_0-rmse:1.40389	validation_1-rmse:1.49996
# [28]	validation_0-rmse:1.39586	validation_1-rmse:1.49116
# [29]	validation_0-rmse:1.38676	validation_1-rmse:1.48159
# [30]	validation_0-rmse:1.37974	validation_1-rmse:1.47398
# [31]	validation_0-rmse:1.37199	validation_1-rmse:1.46649
# [32]	validation_0-rmse:1.36274	validation_1-rmse:1.45959
# [33]	validation_0-rmse:1.35494	validation_1-rmse:1.45507
# [34]	validation_0-rmse:1.34720	validation_1-rmse:1.44805
# [35]	validation_0-rmse:1.34049	validation_1-rmse:1.44127
# [36]	validation_0-rmse:1.33425	validation_1-rmse:1.43593
# [37]	validation_0-rmse:1.32685	validation_1-rmse:1.43054
# [38]	validation_0-rmse:1.31866	validation_1-rmse:1.42570
# [39]	validation_0-rmse:1.31093	validation_1-rmse:1.42031
# [40]	validation_0-rmse:1.30295	validation_1-rmse:1.41416
# [41]	validation_0-rmse:1.29693	validation_1-rmse:1.40830
# [42]	validation_0-rmse:1.28959	validation_1-rmse:1.40161
# [43]	validation_0-rmse:1.28255	validation_1-rmse:1.39671
# [44]	validation_0-rmse:1.27479	validation_1-rmse:1.39134
# [45]	validation_0-rmse:1.26929	validation_1-rmse:1.38721
# [46]	validation_0-rmse:1.26094	validation_1-rmse:1.38266
# [47]	validation_0-rmse:1.25403	validation_1-rmse:1.37774
# [48]	validation_0-rmse:1.24610	validation_1-rmse:1.37258
# [49]	validation_0-rmse:1.23858	validation_1-rmse:1.36559
# [50]	validation_0-rmse:1.23204	validation_1-rmse:1.36133
# [51]	validation_0-rmse:1.22391	validation_1-rmse:1.35440
# [52]	validation_0-rmse:1.21588	validation_1-rmse:1.34726
# [53]	validation_0-rmse:1.21071	validation_1-rmse:1.34235
# [54]	validation_0-rmse:1.20449	validation_1-rmse:1.33781
# [55]	validation_0-rmse:1.19865	validation_1-rmse:1.33396
# [56]	validation_0-rmse:1.19221	validation_1-rmse:1.33194
# [57]	validation_0-rmse:1.18426	validation_1-rmse:1.32728
# [58]	validation_0-rmse:1.17822	validation_1-rmse:1.32267
# [59]	validation_0-rmse:1.17307	validation_1-rmse:1.31835
# [60]	validation_0-rmse:1.16693	validation_1-rmse:1.31519
# [61]	validation_0-rmse:1.16028	validation_1-rmse:1.30953
# [62]	validation_0-rmse:1.15370	validation_1-rmse:1.30395
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.59926	validation_1-rmse:2.07566
# [1]	validation_0-rmse:1.58887	validation_1-rmse:2.06358
# [2]	validation_0-rmse:1.57670	validation_1-rmse:2.05124
# [3]	validation_0-rmse:1.56719	validation_1-rmse:2.04007
# [4]	validation_0-rmse:1.55659	validation_1-rmse:2.02885
# [5]	validation_0-rmse:1.54727	validation_1-rmse:2.01980
# [6]	validation_0-rmse:1.53625	validation_1-rmse:2.00925
# [7]	validation_0-rmse:1.52494	validation_1-rmse:1.99678
# [8]	validation_0-rmse:1.51464	validation_1-rmse:1.98579
# [9]	validation_0-rmse:1.50631	validation_1-rmse:1.97559
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [10]	validation_0-rmse:1.49601	validation_1-rmse:1.96635
# [11]	validation_0-rmse:1.48568	validation_1-rmse:1.95383
# [12]	validation_0-rmse:1.47737	validation_1-rmse:1.94447
# [13]	validation_0-rmse:1.46737	validation_1-rmse:1.93545
# [14]	validation_0-rmse:1.45920	validation_1-rmse:1.92844
# [15]	validation_0-rmse:1.44734	validation_1-rmse:1.91529
# [16]	validation_0-rmse:1.43802	validation_1-rmse:1.90491
# [17]	validation_0-rmse:1.42742	validation_1-rmse:1.89408
# [18]	validation_0-rmse:1.41784	validation_1-rmse:1.88411
# [19]	validation_0-rmse:1.40772	validation_1-rmse:1.87335
# [20]	validation_0-rmse:1.40023	validation_1-rmse:1.86509
# [21]	validation_0-rmse:1.39245	validation_1-rmse:1.85889
# [22]	validation_0-rmse:1.38418	validation_1-rmse:1.84916
# [23]	validation_0-rmse:1.37476	validation_1-rmse:1.84011
# [24]	validation_0-rmse:1.36535	validation_1-rmse:1.83038
# [25]	validation_0-rmse:1.35589	validation_1-rmse:1.81841
# [26]	validation_0-rmse:1.34861	validation_1-rmse:1.81010
# [27]	validation_0-rmse:1.33947	validation_1-rmse:1.80060
# [28]	validation_0-rmse:1.33297	validation_1-rmse:1.79326
# [29]	validation_0-rmse:1.32517	validation_1-rmse:1.78530
# [30]	validation_0-rmse:1.31874	validation_1-rmse:1.77778
# [31]	validation_0-rmse:1.31186	validation_1-rmse:1.77131
# [32]	validation_0-rmse:1.30384	validation_1-rmse:1.76241
# [33]	validation_0-rmse:1.29610	validation_1-rmse:1.75591
# [34]	validation_0-rmse:1.28766	validation_1-rmse:1.74774
# [35]	validation_0-rmse:1.28220	validation_1-rmse:1.74052
# [36]	validation_0-rmse:1.27665	validation_1-rmse:1.73349
# [37]	validation_0-rmse:1.27076	validation_1-rmse:1.72802
# [38]	validation_0-rmse:1.26297	validation_1-rmse:1.72073
# [39]	validation_0-rmse:1.25540	validation_1-rmse:1.71519
# [40]	validation_0-rmse:1.24985	validation_1-rmse:1.71036
# [41]	validation_0-rmse:1.24484	validation_1-rmse:1.70464
# [42]	validation_0-rmse:1.23964	validation_1-rmse:1.69857
# [43]	validation_0-rmse:1.23472	validation_1-rmse:1.69292
# [44]	validation_0-rmse:1.22822	validation_1-rmse:1.68671
# [45]	validation_0-rmse:1.22386	validation_1-rmse:1.68259
# [46]	validation_0-rmse:1.21570	validation_1-rmse:1.67552
# [47]	validation_0-rmse:1.20854	validation_1-rmse:1.66904
# [48]	validation_0-rmse:1.20101	validation_1-rmse:1.66192
# [49]	validation_0-rmse:1.19401	validation_1-rmse:1.65522
# [50]	validation_0-rmse:1.18660	validation_1-rmse:1.64808
# [51]	validation_0-rmse:1.17945	validation_1-rmse:1.64167
# [52]	validation_0-rmse:1.17235	validation_1-rmse:1.63548
# [53]	validation_0-rmse:1.16772	validation_1-rmse:1.62987
# [54]	validation_0-rmse:1.16241	validation_1-rmse:1.62446
# [55]	validation_0-rmse:1.15822	validation_1-rmse:1.61976
# [56]	validation_0-rmse:1.15165	validation_1-rmse:1.61330
# [57]	validation_0-rmse:1.14548	validation_1-rmse:1.60734
# [58]	validation_0-rmse:1.14005	validation_1-rmse:1.60231
# [59]	validation_0-rmse:1.13491	validation_1-rmse:1.59682
# [60]	validation_0-rmse:1.13027	validation_1-rmse:1.59350
# [61]	validation_0-rmse:1.12558	validation_1-rmse:1.58898
# [62]	validation_0-rmse:1.11957	validation_1-rmse:1.58347
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.62600	validation_1-rmse:1.98836
# [1]	validation_0-rmse:1.61573	validation_1-rmse:1.97686
# [2]	validation_0-rmse:1.60479	validation_1-rmse:1.96330
# [3]	validation_0-rmse:1.59506	validation_1-rmse:1.95303
# [4]	validation_0-rmse:1.58452	validation_1-rmse:1.94135
# [5]	validation_0-rmse:1.57451	validation_1-rmse:1.92936
# [6]	validation_0-rmse:1.56312	validation_1-rmse:1.91692
# [7]	validation_0-rmse:1.55204	validation_1-rmse:1.90506
# [8]	validation_0-rmse:1.54205	validation_1-rmse:1.89248
# [9]	validation_0-rmse:1.53217	validation_1-rmse:1.88286
# [10]	validation_0-rmse:1.52158	validation_1-rmse:1.87323
# [11]	validation_0-rmse:1.51054	validation_1-rmse:1.86283
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [12]	validation_0-rmse:1.50208	validation_1-rmse:1.85286
# [13]	validation_0-rmse:1.49335	validation_1-rmse:1.84269
# [14]	validation_0-rmse:1.48523	validation_1-rmse:1.83254
# [15]	validation_0-rmse:1.47409	validation_1-rmse:1.82187
# [16]	validation_0-rmse:1.46342	validation_1-rmse:1.81012
# [17]	validation_0-rmse:1.45280	validation_1-rmse:1.80021
# [18]	validation_0-rmse:1.44338	validation_1-rmse:1.79142
# [19]	validation_0-rmse:1.43309	validation_1-rmse:1.78349
# [20]	validation_0-rmse:1.42441	validation_1-rmse:1.77565
# [21]	validation_0-rmse:1.41565	validation_1-rmse:1.76696
# [22]	validation_0-rmse:1.40727	validation_1-rmse:1.75801
# [23]	validation_0-rmse:1.39751	validation_1-rmse:1.74919
# [24]	validation_0-rmse:1.38793	validation_1-rmse:1.74025
# [25]	validation_0-rmse:1.37873	validation_1-rmse:1.73110
# [26]	validation_0-rmse:1.37150	validation_1-rmse:1.72254
# [27]	validation_0-rmse:1.36381	validation_1-rmse:1.71219
# [28]	validation_0-rmse:1.35690	validation_1-rmse:1.70444
# [29]	validation_0-rmse:1.34816	validation_1-rmse:1.69364
# [30]	validation_0-rmse:1.34092	validation_1-rmse:1.68501
# [31]	validation_0-rmse:1.33395	validation_1-rmse:1.67646
# [32]	validation_0-rmse:1.32536	validation_1-rmse:1.66846
# [33]	validation_0-rmse:1.31787	validation_1-rmse:1.66232
# [34]	validation_0-rmse:1.31087	validation_1-rmse:1.65438
# [35]	validation_0-rmse:1.30455	validation_1-rmse:1.64682
# [36]	validation_0-rmse:1.29877	validation_1-rmse:1.64053
# [37]	validation_0-rmse:1.29263	validation_1-rmse:1.63409
# [38]	validation_0-rmse:1.28506	validation_1-rmse:1.62741
# [39]	validation_0-rmse:1.27842	validation_1-rmse:1.61980
# [40]	validation_0-rmse:1.27233	validation_1-rmse:1.61380
# [41]	validation_0-rmse:1.26703	validation_1-rmse:1.60742
# [42]	validation_0-rmse:1.26025	validation_1-rmse:1.60275
# [43]	validation_0-rmse:1.25456	validation_1-rmse:1.59679
# [44]	validation_0-rmse:1.24788	validation_1-rmse:1.59101
# [45]	validation_0-rmse:1.24257	validation_1-rmse:1.58601
# [46]	validation_0-rmse:1.23528	validation_1-rmse:1.57757
# [47]	validation_0-rmse:1.22830	validation_1-rmse:1.57086
# [48]	validation_0-rmse:1.22180	validation_1-rmse:1.56167
# [49]	validation_0-rmse:1.21497	validation_1-rmse:1.55648
# [50]	validation_0-rmse:1.20727	validation_1-rmse:1.54990
# [51]	validation_0-rmse:1.20040	validation_1-rmse:1.54301
# [52]	validation_0-rmse:1.19361	validation_1-rmse:1.53684
# [53]	validation_0-rmse:1.18935	validation_1-rmse:1.53177
# [54]	validation_0-rmse:1.18390	validation_1-rmse:1.52577
# [55]	validation_0-rmse:1.17950	validation_1-rmse:1.52142
# [56]	validation_0-rmse:1.17415	validation_1-rmse:1.51742
# [57]	validation_0-rmse:1.16769	validation_1-rmse:1.51060
# [58]	validation_0-rmse:1.16348	validation_1-rmse:1.50541
# [59]	validation_0-rmse:1.15834	validation_1-rmse:1.50019
# [60]	validation_0-rmse:1.15364	validation_1-rmse:1.49602
# [61]	validation_0-rmse:1.14849	validation_1-rmse:1.49356
# [62]	validation_0-rmse:1.14269	validation_1-rmse:1.48676
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ...
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.74827	validation_1-rmse:1.45521
# [2]	validation_0-rmse:1.73582	validation_1-rmse:1.44541
# [3]	validation_0-rmse:1.72429	validation_1-rmse:1.43688
# [4]	validation_0-rmse:1.71204	validation_1-rmse:1.42519
# [5]	validation_0-rmse:1.69929	validation_1-rmse:1.41723
# [6]	validation_0-rmse:1.68687	validation_1-rmse:1.40772
# [7]	validation_0-rmse:1.67400	validation_1-rmse:1.39946
# [8]	validation_0-rmse:1.66165	validation_1-rmse:1.39128
# [9]	validation_0-rmse:1.65048	validation_1-rmse:1.38202
# [10]	validation_0-rmse:1.63902	validation_1-rmse:1.37197
# [11]	validation_0-rmse:1.62588	validation_1-rmse:1.36206
# [12]	validation_0-rmse:1.61567	validation_1-rmse:1.35321
# [13]	validation_0-rmse:1.60397	validation_1-rmse:1.34386
# [14]	validation_0-rmse:1.59323	validation_1-rmse:1.33589
# [15]	validation_0-rmse:1.58068	validation_1-rmse:1.32820
# [16]	validation_0-rmse:1.56900	validation_1-rmse:1.32076
# [17]	validation_0-rmse:1.55703	validation_1-rmse:1.31043
# [18]	validation_0-rmse:1.54648	validation_1-rmse:1.30318
# [19]	validation_0-rmse:1.53494	validation_1-rmse:1.29225
# [20]	validation_0-rmse:1.52492	validation_1-rmse:1.28528
# [21]	validation_0-rmse:1.51323	validation_1-rmse:1.27850
# [22]	validation_0-rmse:1.50391	validation_1-rmse:1.27249
# [23]	validation_0-rmse:1.49267	validation_1-rmse:1.26382
# [24]	validation_0-rmse:1.48206	validation_1-rmse:1.25562
# [25]	validation_0-rmse:1.47138	validation_1-rmse:1.24985
# [26]	validation_0-rmse:1.46185	validation_1-rmse:1.24481
# [27]	validation_0-rmse:1.45139	validation_1-rmse:1.23959
# [28]	validation_0-rmse:1.44316	validation_1-rmse:1.23336
# [29]	validation_0-rmse:1.43430	validation_1-rmse:1.22662
# [30]	validation_0-rmse:1.42657	validation_1-rmse:1.22054
# [31]	validation_0-rmse:1.41831	validation_1-rmse:1.21498
# [32]	validation_0-rmse:1.40892	validation_1-rmse:1.20880
# [33]	validation_0-rmse:1.39864	validation_1-rmse:1.20260
# [34]	validation_0-rmse:1.38926	validation_1-rmse:1.19931
# [35]	validation_0-rmse:1.38212	validation_1-rmse:1.19458
# [36]	validation_0-rmse:1.37440	validation_1-rmse:1.18914
# [37]	validation_0-rmse:1.36639	validation_1-rmse:1.18456
# [38]	validation_0-rmse:1.35732	validation_1-rmse:1.17753
# [39]	validation_0-rmse:1.34968	validation_1-rmse:1.17199
# [40]	validation_0-rmse:1.34034	validation_1-rmse:1.16863
# [41]	validation_0-rmse:1.33378	validation_1-rmse:1.16435
# [42]	validation_0-rmse:1.32730	validation_1-rmse:1.16067
# [43]	validation_0-rmse:1.31948	validation_1-rmse:1.15778
# [44]	validation_0-rmse:1.31196	validation_1-rmse:1.15299
# [45]	validation_0-rmse:1.30499	validation_1-rmse:1.14925
# [46]	validation_0-rmse:1.29616	validation_1-rmse:1.14514
# [47]	validation_0-rmse:1.28939	validation_1-rmse:1.14165
# [48]	validation_0-rmse:1.28099	validation_1-rmse:1.13776
# [49]	validation_0-rmse:1.27295	validation_1-rmse:1.13212
# [50]	validation_0-rmse:1.26474	validation_1-rmse:1.12617
# [51]	validation_0-rmse:1.25588	validation_1-rmse:1.12227
# [52]	validation_0-rmse:1.24797	validation_1-rmse:1.11914
# [53]	validation_0-rmse:1.24214	validation_1-rmse:1.11595
# [54]	validation_0-rmse:1.23615	validation_1-rmse:1.11213
# [55]	validation_0-rmse:1.22934	validation_1-rmse:1.11047
# [56]	validation_0-rmse:1.22320	validation_1-rmse:1.10746
# [57]	validation_0-rmse:1.21513	validation_1-rmse:1.10208
# [58]	validation_0-rmse:1.20901	validation_1-rmse:1.09982
# [59]	validation_0-rmse:1.20301	validation_1-rmse:1.09748
# [60]	validation_0-rmse:1.19593	validation_1-rmse:1.09568
# [61]	validation_0-rmse:1.18946	validation_1-rmse:1.09464
# [62]	validation_0-rmse:1.18256	validation_1-rmse:1.09108
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.71332	validation_1-rmse:1.66602
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.70169	validation_1-rmse:1.65566
# [2]	validation_0-rmse:1.68825	validation_1-rmse:1.64519
# [3]	validation_0-rmse:1.67734	validation_1-rmse:1.63552
# [4]	validation_0-rmse:1.66599	validation_1-rmse:1.62644
# [5]	validation_0-rmse:1.65297	validation_1-rmse:1.61700
# [6]	validation_0-rmse:1.64089	validation_1-rmse:1.60858
# [7]	validation_0-rmse:1.62793	validation_1-rmse:1.60216
# [8]	validation_0-rmse:1.61466	validation_1-rmse:1.59389
# [9]	validation_0-rmse:1.60470	validation_1-rmse:1.58586
# [10]	validation_0-rmse:1.59220	validation_1-rmse:1.57980
# [11]	validation_0-rmse:1.58101	validation_1-rmse:1.56993
# [12]	validation_0-rmse:1.57096	validation_1-rmse:1.56272
# [13]	validation_0-rmse:1.56012	validation_1-rmse:1.55484
# [14]	validation_0-rmse:1.54990	validation_1-rmse:1.54900
# [15]	validation_0-rmse:1.53720	validation_1-rmse:1.54023
# [16]	validation_0-rmse:1.52539	validation_1-rmse:1.53687
# [17]	validation_0-rmse:1.51415	validation_1-rmse:1.52718
# [18]	validation_0-rmse:1.50376	validation_1-rmse:1.51995
# [19]	validation_0-rmse:1.49265	validation_1-rmse:1.51117
# [20]	validation_0-rmse:1.48168	validation_1-rmse:1.50835
# [21]	validation_0-rmse:1.47065	validation_1-rmse:1.50215
# [22]	validation_0-rmse:1.46183	validation_1-rmse:1.49490
# [23]	validation_0-rmse:1.45170	validation_1-rmse:1.48611
# [24]	validation_0-rmse:1.44168	validation_1-rmse:1.47827
# [25]	validation_0-rmse:1.43127	validation_1-rmse:1.47159
# [26]	validation_0-rmse:1.42200	validation_1-rmse:1.46531
# [27]	validation_0-rmse:1.41225	validation_1-rmse:1.45806
# [28]	validation_0-rmse:1.40362	validation_1-rmse:1.45323
# [29]	validation_0-rmse:1.39379	validation_1-rmse:1.44796
# [30]	validation_0-rmse:1.38564	validation_1-rmse:1.44121
# [31]	validation_0-rmse:1.37703	validation_1-rmse:1.43567
# [32]	validation_0-rmse:1.36742	validation_1-rmse:1.42970
# [33]	validation_0-rmse:1.35736	validation_1-rmse:1.42579
# [34]	validation_0-rmse:1.34742	validation_1-rmse:1.42117
# [35]	validation_0-rmse:1.34008	validation_1-rmse:1.41636
# [36]	validation_0-rmse:1.33296	validation_1-rmse:1.41199
# [37]	validation_0-rmse:1.32467	validation_1-rmse:1.40743
# [38]	validation_0-rmse:1.31604	validation_1-rmse:1.40052
# [39]	validation_0-rmse:1.30756	validation_1-rmse:1.39671
# [40]	validation_0-rmse:1.30019	validation_1-rmse:1.39291
# [41]	validation_0-rmse:1.29375	validation_1-rmse:1.38864
# [42]	validation_0-rmse:1.28535	validation_1-rmse:1.38574
# [43]	validation_0-rmse:1.27795	validation_1-rmse:1.38183
# [44]	validation_0-rmse:1.26907	validation_1-rmse:1.38004
# [45]	validation_0-rmse:1.26347	validation_1-rmse:1.37664
# [46]	validation_0-rmse:1.25610	validation_1-rmse:1.37061
# [47]	validation_0-rmse:1.24736	validation_1-rmse:1.36743
# [48]	validation_0-rmse:1.23920	validation_1-rmse:1.36100
# [49]	validation_0-rmse:1.23155	validation_1-rmse:1.35499
# [50]	validation_0-rmse:1.22317	validation_1-rmse:1.35224
# [51]	validation_0-rmse:1.21519	validation_1-rmse:1.34634
# [52]	validation_0-rmse:1.20889	validation_1-rmse:1.34291
# [53]	validation_0-rmse:1.20324	validation_1-rmse:1.33914
# [54]	validation_0-rmse:1.19783	validation_1-rmse:1.33578
# [55]	validation_0-rmse:1.19087	validation_1-rmse:1.33363
# [56]	validation_0-rmse:1.18285	validation_1-rmse:1.33125
# [57]	validation_0-rmse:1.17479	validation_1-rmse:1.32600
# [58]	validation_0-rmse:1.16900	validation_1-rmse:1.32341
# [59]	validation_0-rmse:1.16284	validation_1-rmse:1.32022
# [60]	validation_0-rmse:1.15710	validation_1-rmse:1.31752
# [61]	validation_0-rmse:1.15051	validation_1-rmse:1.31569
# [62]	validation_0-rmse:1.14316	validation_1-rmse:1.31060
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.72411	validation_1-rmse:1.62589
# [1]	validation_0-rmse:1.71217	validation_1-rmse:1.61665
# [2]	validation_0-rmse:1.69908	validation_1-rmse:1.60656
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:1.68840	validation_1-rmse:1.59734
# [4]	validation_0-rmse:1.67593	validation_1-rmse:1.58876
# [5]	validation_0-rmse:1.66396	validation_1-rmse:1.58037
# [6]	validation_0-rmse:1.65102	validation_1-rmse:1.57076
# [7]	validation_0-rmse:1.63832	validation_1-rmse:1.56344
# [8]	validation_0-rmse:1.62522	validation_1-rmse:1.55483
# [9]	validation_0-rmse:1.61602	validation_1-rmse:1.54632
# [10]	validation_0-rmse:1.60454	validation_1-rmse:1.53626
# [11]	validation_0-rmse:1.59290	validation_1-rmse:1.52544
# [12]	validation_0-rmse:1.58283	validation_1-rmse:1.51717
# [13]	validation_0-rmse:1.57122	validation_1-rmse:1.50868
# [14]	validation_0-rmse:1.56058	validation_1-rmse:1.50060
# [15]	validation_0-rmse:1.54801	validation_1-rmse:1.49259
# [16]	validation_0-rmse:1.53680	validation_1-rmse:1.48380
# [17]	validation_0-rmse:1.52653	validation_1-rmse:1.47497
# [18]	validation_0-rmse:1.51571	validation_1-rmse:1.46719
# [19]	validation_0-rmse:1.50474	validation_1-rmse:1.45888
# [20]	validation_0-rmse:1.49427	validation_1-rmse:1.45123
# [21]	validation_0-rmse:1.48313	validation_1-rmse:1.44221
# [22]	validation_0-rmse:1.47507	validation_1-rmse:1.43514
# [23]	validation_0-rmse:1.46467	validation_1-rmse:1.42592
# [24]	validation_0-rmse:1.45422	validation_1-rmse:1.41805
# [25]	validation_0-rmse:1.44400	validation_1-rmse:1.41221
# [26]	validation_0-rmse:1.43536	validation_1-rmse:1.40634
# [27]	validation_0-rmse:1.42534	validation_1-rmse:1.40000
# [28]	validation_0-rmse:1.41640	validation_1-rmse:1.39438
# [29]	validation_0-rmse:1.40724	validation_1-rmse:1.38849
# [30]	validation_0-rmse:1.39989	validation_1-rmse:1.38195
# [31]	validation_0-rmse:1.39093	validation_1-rmse:1.37638
# [32]	validation_0-rmse:1.38181	validation_1-rmse:1.37019
# [33]	validation_0-rmse:1.37146	validation_1-rmse:1.36447
# [34]	validation_0-rmse:1.36280	validation_1-rmse:1.35930
# [35]	validation_0-rmse:1.35619	validation_1-rmse:1.35232
# [36]	validation_0-rmse:1.34989	validation_1-rmse:1.34725
# [37]	validation_0-rmse:1.34159	validation_1-rmse:1.34204
# [38]	validation_0-rmse:1.33316	validation_1-rmse:1.33537
# [39]	validation_0-rmse:1.32509	validation_1-rmse:1.33121
# [40]	validation_0-rmse:1.31771	validation_1-rmse:1.32709
# [41]	validation_0-rmse:1.31138	validation_1-rmse:1.32204
# [42]	validation_0-rmse:1.30390	validation_1-rmse:1.31762
# [43]	validation_0-rmse:1.29675	validation_1-rmse:1.31367
# [44]	validation_0-rmse:1.29015	validation_1-rmse:1.30877
# [45]	validation_0-rmse:1.28434	validation_1-rmse:1.30487
# [46]	validation_0-rmse:1.27616	validation_1-rmse:1.30112
# [47]	validation_0-rmse:1.26826	validation_1-rmse:1.29545
# [48]	validation_0-rmse:1.26095	validation_1-rmse:1.29128
# [49]	validation_0-rmse:1.25384	validation_1-rmse:1.28610
# [50]	validation_0-rmse:1.24610	validation_1-rmse:1.28098
# [51]	validation_0-rmse:1.23712	validation_1-rmse:1.27604
# [52]	validation_0-rmse:1.23011	validation_1-rmse:1.27102
# [53]	validation_0-rmse:1.22506	validation_1-rmse:1.26714
# [54]	validation_0-rmse:1.21884	validation_1-rmse:1.26447
# [55]	validation_0-rmse:1.21276	validation_1-rmse:1.26169
# [56]	validation_0-rmse:1.20448	validation_1-rmse:1.25741
# [57]	validation_0-rmse:1.19623	validation_1-rmse:1.25369
# [58]	validation_0-rmse:1.19065	validation_1-rmse:1.25076
# [59]	validation_0-rmse:1.18467	validation_1-rmse:1.24819
# [60]	validation_0-rmse:1.17833	validation_1-rmse:1.24416
# [61]	validation_0-rmse:1.17185	validation_1-rmse:1.24101
# [62]	validation_0-rmse:1.16469	validation_1-rmse:1.23584
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.74056	validation_1-rmse:1.55640
# [1]	validation_0-rmse:1.72871	validation_1-rmse:1.54664
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:1.71431	validation_1-rmse:1.53424
# [3]	validation_0-rmse:1.70308	validation_1-rmse:1.52526
# [4]	validation_0-rmse:1.69062	validation_1-rmse:1.51713
# [5]	validation_0-rmse:1.67836	validation_1-rmse:1.50900
# [6]	validation_0-rmse:1.66624	validation_1-rmse:1.50119
# [7]	validation_0-rmse:1.65274	validation_1-rmse:1.49039
# [8]	validation_0-rmse:1.64057	validation_1-rmse:1.48026
# [9]	validation_0-rmse:1.63083	validation_1-rmse:1.47376
# [10]	validation_0-rmse:1.61894	validation_1-rmse:1.46350
# [11]	validation_0-rmse:1.60753	validation_1-rmse:1.45381
# [12]	validation_0-rmse:1.59728	validation_1-rmse:1.44487
# [13]	validation_0-rmse:1.58540	validation_1-rmse:1.43826
# [14]	validation_0-rmse:1.57492	validation_1-rmse:1.43102
# [15]	validation_0-rmse:1.56241	validation_1-rmse:1.42368
# [16]	validation_0-rmse:1.55192	validation_1-rmse:1.41375
# [17]	validation_0-rmse:1.54081	validation_1-rmse:1.40521
# [18]	validation_0-rmse:1.52928	validation_1-rmse:1.39648
# [19]	validation_0-rmse:1.51854	validation_1-rmse:1.38861
# [20]	validation_0-rmse:1.50960	validation_1-rmse:1.38031
# [21]	validation_0-rmse:1.49984	validation_1-rmse:1.37306
# [22]	validation_0-rmse:1.49088	validation_1-rmse:1.36624
# [23]	validation_0-rmse:1.48044	validation_1-rmse:1.35979
# [24]	validation_0-rmse:1.47001	validation_1-rmse:1.35203
# [25]	validation_0-rmse:1.45897	validation_1-rmse:1.34339
# [26]	validation_0-rmse:1.44987	validation_1-rmse:1.33712
# [27]	validation_0-rmse:1.43966	validation_1-rmse:1.33152
# [28]	validation_0-rmse:1.43083	validation_1-rmse:1.32529
# [29]	validation_0-rmse:1.42171	validation_1-rmse:1.31796
# [30]	validation_0-rmse:1.41406	validation_1-rmse:1.31193
# [31]	validation_0-rmse:1.40573	validation_1-rmse:1.30750
# [32]	validation_0-rmse:1.39562	validation_1-rmse:1.29983
# [33]	validation_0-rmse:1.38641	validation_1-rmse:1.29282
# [34]	validation_0-rmse:1.37732	validation_1-rmse:1.28844
# [35]	validation_0-rmse:1.37035	validation_1-rmse:1.28250
# [36]	validation_0-rmse:1.36330	validation_1-rmse:1.27765
# [37]	validation_0-rmse:1.35472	validation_1-rmse:1.27242
# [38]	validation_0-rmse:1.34567	validation_1-rmse:1.26637
# [39]	validation_0-rmse:1.33713	validation_1-rmse:1.26230
# [40]	validation_0-rmse:1.32906	validation_1-rmse:1.25736
# [41]	validation_0-rmse:1.32247	validation_1-rmse:1.25225
# [42]	validation_0-rmse:1.31468	validation_1-rmse:1.24662
# [43]	validation_0-rmse:1.30738	validation_1-rmse:1.24244
# [44]	validation_0-rmse:1.29993	validation_1-rmse:1.23624
# [45]	validation_0-rmse:1.29424	validation_1-rmse:1.23247
# [46]	validation_0-rmse:1.28619	validation_1-rmse:1.22713
# [47]	validation_0-rmse:1.27914	validation_1-rmse:1.22166
# [48]	validation_0-rmse:1.27093	validation_1-rmse:1.21693
# [49]	validation_0-rmse:1.26354	validation_1-rmse:1.21338
# [50]	validation_0-rmse:1.25604	validation_1-rmse:1.20772
# [51]	validation_0-rmse:1.24809	validation_1-rmse:1.20352
# [52]	validation_0-rmse:1.24132	validation_1-rmse:1.19986
# [53]	validation_0-rmse:1.23570	validation_1-rmse:1.19586
# [54]	validation_0-rmse:1.22967	validation_1-rmse:1.19316
# [55]	validation_0-rmse:1.22269	validation_1-rmse:1.18915
# [56]	validation_0-rmse:1.21607	validation_1-rmse:1.18397
# [57]	validation_0-rmse:1.20756	validation_1-rmse:1.17921
# [58]	validation_0-rmse:1.20115	validation_1-rmse:1.17533
# [59]	validation_0-rmse:1.19487	validation_1-rmse:1.17242
# [60]	validation_0-rmse:1.18871	validation_1-rmse:1.16865
# [61]	validation_0-rmse:1.18195	validation_1-rmse:1.16440
# [62]	validation_0-rmse:1.17512	validation_1-rmse:1.15970
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-4.8, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.283
# Uncertainty
# a0: -0.0292+/-0.018
# a1: 0.1126+/-0.013

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: A_year: mean - 0.105, median - 0.104, CI - [0.097-0.114]
#
# SHAP-values for: D_cm: mean - 0.07, median - 0.07, CI - [0.064-0.075]
#
# SHAP-values for: F_Soil_ID: mean - 0.053, median - 0.053, CI - [0.046-0.059]
#
# SHAP-values for: G_m2_ha: mean - 0.04, median - 0.04, CI - [0.033-0.046]
#
# SHAP-values for: H_m: mean - 0.042, median - 0.041, CI - [0.037-0.047]
#
# SHAP-values for: M_Soil: mean - 0.023, median - 0.022, CI - [0.018-0.026]
#
# SHAP-values for: Origin_ID: mean - 0.067, median - 0.066, CI - [0.056-0.078]
#
# SHAP-values for: Species_ID: mean - 0.019, median - 0.019, CI - [0.015-0.023]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['A_year', 'D_cm', 'Origin_ID', 'F_Soil_ID', 'H_m',   
  'G_m2_ha', 'M_Soil', 'Species_ID'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 62.0, median: 62.0,
#  pred. interval (P(0.025)-P(0.975)): 62.0-62.0,
#  conf. interval (p-value=0.95): 62.0-62.0
# ***
# Aggregate bias statistic:
#  mean: 0.544, median: 0.556,
#  pred. interval (P(0.025)-P(0.975)): 0.189-0.903,
#  conf. interval (p-value=0.95): 0.38-0.689
# ***
# Aggregate RMSE statistic:
#  mean: 1.282, median: 1.283, pred. interval (P(0.025)-P(0.975)): 0.984-1.584,
#  conf. interval (p-value=0.95): 1.138-1.432
# ***
# Aggregate MSE statistic:
#  mean: 1.671, median: 1.647, pred. interval (P(0.025)-P(0.975)): 0.968-2.508,
#  conf. interval (p-value=0.95): 1.297-2.054
# ***
# Aggregate R^2 statistic:
#  mean: -0.008, median: 0.014, pred. interval (P(0.025)-P(0.975)): -0.279-0.188,
#  conf. interval (p-value=0.95): -0.099-0.092
# ***
# Aggregate bias(%) statistic:
#  mean: -82.849, median: -84.514, pred. interval (P(0.025)-P(0.975)): -95.995--59.363,
#  conf. interval (p-value=0.95): -90.602--76.212
# ***
# Aggregate RMSE(%) statistic:
#  mean: -209.022, median: -197.255, pred. interval (P(0.025)-P(0.975)): -348.441--150.686,
#  conf. interval (p-value=0.95): -243.086--173.053
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -0.046, median: -0.035,
#  pred. interval (P(0.025)-P(0.975)): -0.375-0.203,
#  conf. interval (p-value=0.95): -0.17-0.083
# ***
# Aggregate RMSE statistic:
#  mean: 0.919, median: 0.912, pred. interval (P(0.025)-P(0.975)): 0.581-1.292,
#  conf. interval (p-value=0.95): 0.756-1.087
# ***
# Aggregate MSE statistic:
#  mean: 0.877, median: 0.832, pred. interval (P(0.025)-P(0.975)): 0.338-1.671,
#  conf. interval (p-value=0.95): 0.574-1.186
# ***
# Aggregate R^2 statistic:
#  mean: 0.147, median: 0.152, pred. interval (P(0.025)-P(0.975)): -0.002-0.28,
#  conf. interval (p-value=0.95): 0.07-0.222
# ***
# Aggregate bias(%) statistic:
#  mean: -2.867, median: -3.621, pred. interval (P(0.025)-P(0.975)): -29.287-26.407,
#  conf. interval (p-value=0.95): -15.282-9.661
# ***
# Aggregate RMSE(%) statistic:
#  mean: 93.24, median: 93.597, pred. interval (P(0.025)-P(0.975)): 69.143-116.689,
#  conf. interval (p-value=0.95): 82.354-104.463
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-5, -3, -2, -1, 0, 2])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 0.1, 0.5, 1, 2, 5])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.70463
# [1]	validation_0-rmse:1.69394
# [2]	validation_0-rmse:1.68121
# [3]	validation_0-rmse:1.66790
# [4]	validation_0-rmse:1.65536
# [5]	validation_0-rmse:1.64333
# [6]	validation_0-rmse:1.63198
# [7]	validation_0-rmse:1.61898
# [8]	validation_0-rmse:1.60861
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [9]	validation_0-rmse:1.59668
# [10]	validation_0-rmse:1.58722
# [11]	validation_0-rmse:1.57550
# [12]	validation_0-rmse:1.56441
# [13]	validation_0-rmse:1.55489
# [14]	validation_0-rmse:1.54483
# [15]	validation_0-rmse:1.53500
# [16]	validation_0-rmse:1.52534
# [17]	validation_0-rmse:1.51509
# [18]	validation_0-rmse:1.50525
# [19]	validation_0-rmse:1.49474
# [20]	validation_0-rmse:1.48550
# [21]	validation_0-rmse:1.47525
# [22]	validation_0-rmse:1.46689
# [23]	validation_0-rmse:1.45817
# [24]	validation_0-rmse:1.45015
# [25]	validation_0-rmse:1.44236
# [26]	validation_0-rmse:1.43421
# [27]	validation_0-rmse:1.42518
# [28]	validation_0-rmse:1.41637
# [29]	validation_0-rmse:1.40733
# [30]	validation_0-rmse:1.39761
# [31]	validation_0-rmse:1.38944
# [32]	validation_0-rmse:1.38092
# [33]	validation_0-rmse:1.37175
# [34]	validation_0-rmse:1.36371
# [35]	validation_0-rmse:1.35599
# [36]	validation_0-rmse:1.34593
# [37]	validation_0-rmse:1.33861
# [38]	validation_0-rmse:1.33179
# [39]	validation_0-rmse:1.32410
# [40]	validation_0-rmse:1.31584
# [41]	validation_0-rmse:1.30765
# [42]	validation_0-rmse:1.30084
# [43]	validation_0-rmse:1.29437
# [44]	validation_0-rmse:1.28729
# [45]	validation_0-rmse:1.28073
# [46]	validation_0-rmse:1.27494
# [47]	validation_0-rmse:1.26917
# [48]	validation_0-rmse:1.26199
# [49]	validation_0-rmse:1.25489
# [50]	validation_0-rmse:1.24712
# [51]	validation_0-rmse:1.23959
# [52]	validation_0-rmse:1.23325
# [53]	validation_0-rmse:1.22681
# [54]	validation_0-rmse:1.22053
# [55]	validation_0-rmse:1.21459
# [56]	validation_0-rmse:1.20926
# [57]	validation_0-rmse:1.20389
# [58]	validation_0-rmse:1.19788
# [59]	validation_0-rmse:1.19319
# [60]	validation_0-rmse:1.18735
# [61]	validation_0-rmse:1.18058
# [62]	validation_0-rmse:1.17633
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 62

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.5
# Relative bias(%):  -83.02
# RMSE: 1.2
# Relative RMSE(%):  -183.776
# MSE: 1.4
# R square: 16.3%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-4.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.637
# Uncertainty
# a0: 0.018+/-0.015
# a1: 0.198+/-0.010

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../02_output_data/XGBoost_models/03_LN_Tag_Cs_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../02_output_data/XGBoost_models/03_LN_Tag_Cs_XGB_model.txt")
