# %% [markdown]
# # ***Processing with Cs-137 activity concentration data in stem woody biomass for forest sites***

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
site_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/4_RN_content_in_wood/Unit_site_data.xlsx'
df = pd.read_excel(site_data, sheet_name='RN_filtration_data')
df.head()
# Out:
#    Ідентифікатор    Site #  Species  Species_ID  Ntrees at site  \
# 0            214  095_2021     Pine           0              40
# 1            472  060_2021  Robinia           5              39
# 2            218  096_2021    Birch           2              35
# 3            430  051_2021     Pine           0              24
# 4            204  092_2021    Birch           2              41
#
#    % composition       D_cm        H_m    G_m2_ha  N_ha  ...   T_ag_Cs  \
# 0     100.000000   9.173331   8.917017  26.454278  4000  ...  0.009303
# 1      42.287838  10.248202  20.161437  12.869754  1560  ...  0.015607
# 2     100.000000  17.188036  20.614192  32.488588  1400  ...  0.016439
# 3     100.000000  22.133120  13.684873  36.940844   960  ...  0.018700
# 4     100.000000  28.217794  27.000746  25.643676   410  ...  0.019196
#
#    ln_T_ag_Cs    T_ag_Sr  ln_T_ag_Sr  AEDR_count  AEDR_mean  AEDR_median  \
# 0   -4.677466  17.136062    2.841185          30   0.141667         0.14
# 1   -4.160037   6.328208    1.845017          21  10.249524        10.20
# 2   -4.108084   0.800387   -0.222660          26   0.381538         0.39
# 3   -3.979215   4.799847    1.568584          31   0.552581         0.56
# 4   -3.953053   2.440077    0.892029          34   0.204412         0.20
#
#    AEDR_std  Distance_km  Azimuth
# 0  0.009339    51.395430      246
# 1  0.923954    33.428831      254
# 2  0.044522    54.895591      247
# 3  0.071300    17.571824      265
# 4  0.017689    51.095388      246
#
# [5 rows x 51 columns]

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['Species', 'Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
                                    'Origin', 'Origin_ID','A_year', 'D_live_cm', 'H_live_m', 'G_live_m2_ha',
                                    'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
                                    'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'A_Cs, Bq/kg', 'A_Sr, Bq/kg'])
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Species  Species_ID  % composition       D_cm        H_m    G_m2_ha Origin  \
# 0     Pine           0     100.000000   9.173331   8.917017  26.454278      n
# 1  Robinia           5      42.287838  10.248202  20.161437  12.869754      n
# 2    Birch           2     100.000000  17.188036  20.614192  32.488588      n
# 3     Pine           0     100.000000  22.133120  13.684873  36.940844      n
# 4    Birch           2     100.000000  28.217794  27.000746  25.643676      a
#
#    Origin_ID  A_year  D_live_cm  ...  G_live_m2_ha  F_Soil_ID  M_Soil  \
# 0          0      20   9.173331  ...     26.454278          3       2
# 1          0      40  13.518680  ...     30.433701          3       3
# 2          0      30  17.188036  ...     32.488588          2       3
# 3          0      20  22.133120  ...     36.940844          2       2
# 4          1      57  28.217794  ...     25.643676          2       2
#
#    AEDR_mean  Distance_km  Azimuth  Cs_2021_kBq_m  Sr_2021_kBq_m  A_Cs, Bq/kg  \
# 0   0.141667    51.395430      246     752.481287       9.803886          7.0
# 1  10.249524    33.428831      254    5189.986119     225.972345         81.0
# 2   0.381538    54.895591      247    1034.110727      17.866359         17.0
# 3   0.552581    17.571824      265     588.225430     144.587942         11.0
# 4   0.204412    51.095388      246     677.224124      12.294696         13.0
#
#    A_Sr, Bq/kg
# 0        168.0
# 1       1430.0
# 2         14.3
# 3        694.0
# 4         30.0
#
# [5 rows x 21 columns]

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Species        209 non-null    object
#  1   Species_ID     209 non-null    int64
#  2   % composition  209 non-null    float64
#  3   D_cm           209 non-null    float64
#  4   H_m            209 non-null    float64
#  5   G_m2_ha        209 non-null    float64
#  6   Origin         209 non-null    object
#  7   Origin_ID      209 non-null    int64
#  8   A_year         209 non-null    int64
#  9   D_live_cm      209 non-null    float64
#  10  H_live_m       209 non-null    float64
#  11  G_live_m2_ha   209 non-null    float64
#  12  F_Soil_ID      209 non-null    int64
#  13  M_Soil         209 non-null    int64
#  14  AEDR_mean      209 non-null    float64
#  15  Distance_km    209 non-null    float64
#  16  Azimuth        209 non-null    int64
#  17  Cs_2021_kBq_m  209 non-null    float64
#  18  Sr_2021_kBq_m  209 non-null    float64
#  19  A_Cs, Bq/kg    209 non-null    float64
#  20  A_Sr, Bq/kg    209 non-null    float64
# dtypes: float64(13), int64(6), object(2)
# memory usage: 34.4+ KB

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID  % composition        D_cm         H_m     G_m2_ha  \
# count  209.000000     209.000000  209.000000  209.000000  209.000000
# mean     1.057416      94.337925   17.770981   16.978858   30.000765
# std      1.524339      14.155594    8.921738    6.832292   15.907971
# min      0.000000      20.805369    1.914854    2.704460    0.259356
# 25%      0.000000      96.775081   11.601519   12.401789   17.519173
# 50%      0.000000     100.000000   16.817809   17.466646   30.845307
# 75%      2.000000     100.000000   22.264253   21.414562   42.817263
# max      5.000000     100.000000   52.228464   34.048688   66.922093
#
#         Origin_ID      A_year   D_live_cm    H_live_m  G_live_m2_ha  \
# count  209.000000  209.000000  209.000000  209.000000    209.000000
# mean     0.454545   47.464115   17.555614   16.999369     31.436810
# std      0.499125   24.724635    8.470174    6.783414     15.470759
# min      0.000000   10.000000    1.874874    2.704460      0.656684
# 25%      0.000000   30.000000   12.307179   12.193980     20.938452
# 50%      0.000000   45.000000   16.780740   17.365162     31.800484
# 75%      1.000000   60.000000   22.023624   21.604236     43.193896
# max      1.000000  150.000000   41.664506   33.436497     71.679126
#
#         F_Soil_ID      M_Soil   AEDR_mean  Distance_km     Azimuth  \
# count  209.000000  209.000000  209.000000   209.000000  209.000000
# mean     1.918660    2.220096    2.526858    14.640059  174.296651
# std      0.634039    0.692944    4.756383    12.363729   99.912885
# min      1.000000    0.000000    0.110000     3.998568    9.000000
# 25%      2.000000    2.000000    0.460000     6.562497   56.000000
# 50%      2.000000    2.000000    0.756000     9.203749  189.000000
# 75%      2.000000    3.000000    2.401667    20.865459  261.000000
# max      3.000000    4.000000   36.591739    57.286577  342.000000
#
#        Cs_2021_kBq_m  Sr_2021_kBq_m   A_Cs, Bq/kg   A_Sr, Bq/kg
# count     209.000000     209.000000    209.000000  2.090000e+02
# mean     2040.059453     670.875816   2715.828230  1.460083e+04
# std      3821.573719    1529.917216   8041.339665  7.762897e+04
# min        28.815348       2.402062      4.500000  1.110000e+01
# 25%       446.906289      44.007562     61.000000  3.150000e+02
# 50%       708.799781     187.465954    550.000000  1.820000e+03
# 75%      1940.992207     442.523198   1490.000000  6.950000e+03
# max     25173.384978   10477.431302  86400.000000  1.050000e+06

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species","Origin"])["A_Cs, Bq/kg","A_Sr, Bq/kg"].describe()
# Out:
# /tmp/ipykernel_13267/1143735144.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Species","Origin"])["A_Cs, Bq/kg","A_Sr, Bq/kg"].describe()
#                A_Cs, Bq/kg                                              \
#                      count          mean           std    min      25%
# Species Origin
# Alder   n             13.0   1645.384615   3012.117625   27.0   344.00
# Aspen   n              9.0  11170.111111  28524.501891   15.0    27.00
# Birch   a              8.0   1436.875000   3825.098260   13.0    17.00
#         n             37.0   2653.702703   6025.865447    8.0    89.00
# Oak     a              4.0  11312.250000  11544.614917   49.0  3687.25
#         n              3.0    920.333333   1237.816761   11.0   215.50
# Pine    a             79.0   2339.096203   5611.184745    4.6   176.50
#         n             51.0   2016.539216   5505.888031    4.5    44.00
# Red oak a              3.0     35.000000     19.078784   17.0    25.00
# Robinia n              1.0     81.000000           NaN   81.0    81.00
# Spruce  a              1.0    177.000000           NaN  177.0   177.00
#
#                                           A_Sr, Bq/kg                \
#                    50%       75%      max       count          mean
# Species Origin
# Alder   n        420.0   1033.00  10800.0        13.0    876.307692
# Aspen   n         67.0    837.00  86400.0         9.0  17176.111111
# Birch   a         25.5    248.25  10900.0         8.0  21309.625000
#         n        580.0   1490.00  30700.0        37.0  37961.359459
# Oak     a       9450.0  17075.00  26300.0         4.0  19732.750000
#         n        420.0   1375.00   2330.0         3.0   1039.333333
# Pine    a        908.0   1660.00  35200.0        79.0   7681.659494
#         n        287.0   1045.00  30600.0        51.0  12107.411765
# Red oak a         33.0     44.00     55.0         3.0    114.000000
# Robinia n         81.0     81.00     81.0         1.0   1430.000000
# Spruce  a        177.0    177.00    177.0         1.0   2400.000000
#
#
#                           std     min      25%     50%      75%        max
# Species Origin
# Alder   n          815.259405    60.0    85.00   546.0   1460.0     2100.0
# Aspen   n        29330.875402   101.0   183.00  2620.0   7200.0    71700.0
# Birch   a        54522.275993    30.0   171.50   270.5   5555.0   156000.0
#         n       172221.102648    14.3   966.00  2500.0   8070.0  1050000.0
# Oak     a        32260.610196    51.0  2532.75  5490.0  22690.0    67900.0
#         n         1190.664240    48.0   379.00   710.0   1535.0     2360.0
# Pine    a        14934.295459    11.1   542.00  3050.0   7315.0    87400.0
#         n        46628.041232    75.0   449.50  1010.0   4140.0   323600.0
# Red oak a           39.887341    83.0    91.50   100.0    129.5      159.0
# Robinia n                 NaN  1430.0  1430.00  1430.0   1430.0     1430.0
# Spruce  a                 NaN  2400.0  2400.00  2400.0   2400.0     2400.0

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = ["A_Cs, Bq/kg"], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      Species  Species_ID  % composition       D_cm        H_m    G_m2_ha  \
# 0       Pine           0     100.000000   9.173331   8.917017  26.454278
# 1    Robinia           5      42.287838  10.248202  20.161437  12.869754
# 2      Birch           2     100.000000  17.188036  20.614192  32.488588
# 3       Pine           0     100.000000  22.133120  13.684873  36.940844
# 4      Birch           2     100.000000  28.217794  27.000746  25.643676
# ..       ...         ...            ...        ...        ...        ...
# 204     Pine           0     100.000000  13.411189  13.346519  28.256274
# 205    Birch           2      28.448276   1.914854   4.359681   0.259356
# 206    Aspen           4      99.930119  11.401754  14.676282  17.972410
# 207     Pine           0      96.284658  16.557714  17.797635  32.733666
# 208     Pine           0     100.000000  13.427365  16.722719  48.177280
#
#     Origin  Origin_ID  A_year  D_live_cm  ...  G_live_m2_ha  F_Soil_ID  \
# 0        n          0      20   9.173331  ...     26.454278          3
# 1        n          0      40  13.518680  ...     30.433701          3
# 2        n          0      30  17.188036  ...     32.488588          2
# 3        n          0      20  22.133120  ...     36.940844          2
# 4        a          1      57  28.217794  ...     25.643676          2
# ..     ...        ...     ...        ...  ...           ...        ...
# 204      a          1      45  13.411189  ...     28.256274          1
# 205      n          0      15   1.874874  ...      0.911674          3
# 206      n          0      25  11.278298  ...     17.984979          2
# 207      a          1      40  16.245074  ...     33.996762          2
# 208      a          1      60  13.427365  ...     48.177280          1
#
#      M_Soil  AEDR_mean  Distance_km  Azimuth  Cs_2021_kBq_m  Sr_2021_kBq_m  \
# 0         2   0.141667    51.395430      246     752.481287       9.803886
# 1         3  10.249524    33.428831      254    5189.986119     225.972345
# 2         3   0.381538    54.895591      247    1034.110727      17.866359
# 3         2   0.552581    17.571824      265     588.225430     144.587942
# 4         2   0.204412    51.095388      246     677.224124      12.294696
# ..      ...        ...          ...      ...            ...            ...
# 204       2   9.277941     4.538803      266    7691.680341    3335.843604
# 205       3   0.480938    11.826929       55     437.663645      97.900731
# 206       3  20.051250     5.190617      265   18333.074578    7311.788354
# 207       2   2.182143    57.241684      247    1555.592844      18.001217
# 208       2   0.633333     7.376963       84     536.686565     140.891592
#
#      A_Cs, Bq/kg  A_Sr, Bq/kg
# 0            7.0        168.0
# 1           81.0       1430.0
# 2           17.0         14.3
# 3           11.0        694.0
# 4           13.0         30.0
# ..           ...          ...
# 204      31900.0      80000.0
# 205       2030.0        978.0
# 206      86400.0      65500.0
# 207       7750.0        160.0
# 208       2800.0       6200.0
#
# [209 rows x 21 columns]

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['Species_ID', 'D_cm', 'H_m', 'G_m2_ha',
                                    'A_year', 'F_Soil_ID', 'AEDR_mean'])
y = pd.DataFrame(select, columns= ['A_Cs, Bq/kg'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_value = np.random.normal(10, 2, size=count)
    X['Random_col'] = norm_value
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID       D_cm        H_m    G_m2_ha  A_year  F_Soil_ID  AEDR_mean
# 0           0   9.173331   8.917017  26.454278      20          3   0.141667
# 1           5  10.248202  20.161437  12.869754      40          3  10.249524
# 2           2  17.188036  20.614192  32.488588      30          2   0.381538
# 3           0  22.133120  13.684873  36.940844      20          2   0.552581
# 4           2  28.217794  27.000746  25.643676      57          2   0.204412

# %%
# Columns in "y" data collections
y.head()
# Out:
#    A_Cs, Bq/kg
# 0          7.0
# 1         81.0
# 2         17.0
# 3         11.0
# 4         13.0

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=4, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.878148940288462, 0.4633980390939052, 0.029989660461863132, -0.25885363741902045]
#     Mean: 0.278
#     Std: 0.431
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [ 4347.42222304  2313.08375202 10746.82616212  4285.6492694 ]
#     Mean: 5423.245
#     Std: 3180.611
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [1562.6645346947437, 1386.683026653528, 2513.0972459522577, 1303.4521469723147]
#     Mean: 1691.474
#     Std: 483.507
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: -18.799 (std: 27.787)
# Parameters: {'colsample_bytree': 0.31009887624479704, 'gamma': 0.4718762710542139, 'learning_rate': 0.014052451938914925, 'max_depth': 2, 'n_estimators': 61, 'subsample': 0.41248429610335946}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.54722934, 0.3054451 , 0.58710985, ..., 0.59512601, 0.32353954,
#        0.6905386 ]), 'std_fit_time': array([0.01946169, 0.08128569, 0.02875221, ..., 0.00574261, 0.0058219 ,
#        0.03540719]), 'mean_score_time': array([0.00874763, 0.00870399, 0.00963025, ..., 0.01015964, 0.00968294,
#        0.01199536]), 'std_score_time': array([2.55787399e-04, 4.37319090e-04, 6.90191823e-04, ...,
#        4.96402978e-04, 6.16836371e-06, 4.36630740e-03]), 'param_colsample_bytree': masked_array(data=[0.9068799199840879, 0.3641493570080284,
#                    0.6687633223986539, ..., 0.5457812121526214,
#                    0.8606146345120036, 0.918467186376975],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.0831537159856317, 0.362344182646572,
#                    0.39001928758661614, ..., 0.47461949886758487,
#                    0.4621791333901104, 0.273594842694484],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.164445922614616, 0.30045443035858244,
#                    0.19103099380937463, ..., 0.07496071300939919,
#                    0.1774662457426587, 0.17675025813915327],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[3, 3, 3, ..., 3, 4, 3],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[183, 87, 184, ..., 171, 87, 191],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.6733858367185628, 0.5107430491657194,
#                    0.5941738316972982, ..., 0.6174811563375437,
#                    0.8124654050272295, 0.8337944207080739],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.9068799199840879, 'gamma': 0.0831537159856317, 'learning_rate': 0.164445922614616, 'max_depth': 3, 'n_estimators': 183, 'subsample': 0.6733858367185628}, {'colsample_bytree': 0.3641493570080284, 'gamma': 0.362344182646572, 'learning_rate': 0.30045443035858244, 'max_depth': 3, 'n_estimators': 87, 'subsample': 0.5107430491657194}, {'colsample_bytree': 0.6687633223986539, 'gamma': 0.39001928758661614, 'learning_rate': 0.19103099380937463, 'max_depth': 3, 'n_estimators': 184, 'subsample': 0.5941738316972982}, {'colsample_bytree': 0.8052420115578698, 'gamma': 0.4198529200577407, 'learning_rate': 0.032004662793508214, 'max_depth': 4, 'n_estimators': 94, 'subsample': 0.7019737357157092}, {'colsample_bytree': 0.5735847004658189, 'gamma': 0.35842998426716577, 'learning_rate': 0.29045251529786675, 'max_depth': 4, 'n_estimators': 60, 'subsample': 0.5363722889326135}, {'colsample_bytree': 0.3173088899963533, 'gamma': 0.28146715905557707, 'learning_rate': 0.24306178849439017, 'max_depth': 2, 'n_estimators': 148, 'subsample': 0.9523396215652116}, {'colsample_bytree': 0.8170396590748945, 'gamma': 0.31605386118903944, 'learning_rate': 0.10255509083834508, 'max_depth': 3, 'n_estimators': 161, 'subsample': 0.668431546774118}, {'colsample_bytree': 0.08711446259502473, 'gamma': 0.3675414589415924, 'learning_rate': 0.2456528284912894, 'max_depth': 2, 'n_estimators': 117, 'subsample': 0.981563443049793}, {'colsample_bytree': 0.9301388418471548, 'gamma': 0.3005413736309846, 'learning_rate': 0.02130014398414606, 'max_depth': 3, 'n_estimators': 80, 'subsample': 0.9485884209957973}, {'colsample_bytree': 0.08244034052278595, 'gamma': 0.46602145267760625, 'learning_rate': 0.1634677033903641, 'max_depth': 4, 'n_estimators': 191, 'subsample': 0.7233226424047139}, {'colsample_bytree': 0.16374591733386273, 'gamma': 0.32747543186895467, 'learning_rate': 0.10080479680537502, 'max_depth': 3, 'n_estimators': 58, 'subsample': 0.3137741544057427}, {'colsample_bytree': 0.5800914039173808, 'gamma': 0.19404372693692878, 'learning_rate': 0.284807571938564, 'max_depth': 4, 'n_estimators': 180, 'subsample': 0.6148296747049367}, {'colsample_bytree': 0.6626747750298744, 'gamma': 0.4283207778578375, 'learning_rate': 0.2976210961907344, 'max_depth': 4, 'n_estimators': 80, 'subsample': 0.830449480561303}, {'colsample_bytree': 0.19894296760502655, 'gamma': 0.08897969062292865, 'learning_rate': 0.11329949030712766, 'max_depth': 4, 'n_estimators': 165, 'subsample': 0.4817691696965053}, {'colsample_bytree': 0.23090851631429976, 'gamma': 0.20946341389835793, 'learning_rate': 0.07545289210353304, 'max_depth': 2, 'n_estimators': 68, 'subsample': 0.4759819676005483}, {'colsample_bytree': 0.9226269580454528, 'gamma': 0.4706268890080366, 'learning_rate': 0.07988792751398519, 'max_depth': 3, 'n_estimators': 161, 'subsample': 0.5262707855039044}, {'colsample_bytree': 0.8913934492670281, 'gamma': 0.2177370867640563, 'learning_rate': 0.06234917637549893, 'max_depth': 2, 'n_estimators': 109, 'subsample': 0.7891897712777136}, {'colsample_bytree': 0.33994575603648974, 'gamma': 0.22870419932208885, 'learning_rate': 0.11480098301428111, 'max_depth': 3, 'n_estimators': 69, 'subsample': 0.7012224544738321}, {'colsample_bytree': 0.21797970365009772, 'gamma': 0.4187831102199764, 'learning_rate': 0.17178900798808164, 'max_depth': 2, 'n_estimators': 103, 'subsample': 0.6960731398924334}, {'colsample_bytree': 0.6213872225146905, 'gamma': 0.08209774168714523, 'learning_rate': 0.1783858829344658, 'max_depth': 2, 'n_estimators': 129, 'subsample': 0.4313202694852012}, {'colsample_bytree': 0.9417034101246711, 'gamma': 0.46518807513442895, 'learning_rate': 0.011771413932356235, 'max_depth': 2, 'n_estimators': 179, 'subsample': 0.5666481506894006}, {'colsample_bytree': 0.23437976019669998, 'gamma': 0.34339891875379175, 'learning_rate': 0.21762589484755088, 'max_depth': 3, 'n_estimators': 106, 'subsample': 0.4588398376093673}, {'colsample_bytree':  ...
#        -527.57875308, -448.97076134]), 'split1_test_score': array([ -58.48797293, -691.47589367,  -75.8055493 , ...,  -81.31404326,
#         -37.94924356,  -35.77719584]), 'split2_test_score': array([-3.4105833 , -1.79981468, -2.86276167, ..., -1.9366434 ,
#        -1.83125892, -2.3335287 ]), 'split3_test_score': array([0.74895923, 0.32155831, 0.80202694, ..., 0.82663741, 0.91507573,
#        0.94109414]), 'split4_test_score': array([0.21857558, 0.07794627, 0.13677754, ..., 0.15841637, 0.22322627,
#        0.23411873]), 'mean_test_score': array([ -82.76471281, -280.23524736,  -99.06128929, ..., -115.96542078,
#        -113.24419071,  -97.1812546 ]), 'std_test_score': array([136.90598379, 342.68709571, 161.90129355, ..., 193.36181423,
#        207.68365022, 176.43137866]), 'rank_test_score': array([ 434, 2898,  737, ..., 1052, 1006,  703], dtype=int32), 'split0_train_score': array([0.99961063, 0.98744349, 0.99927384, ..., 0.99259047, 0.99967219,
#        0.99985387]), 'split1_train_score': array([0.99962812, 0.9877752 , 0.99902526, ..., 0.99044167, 0.99960769,
#        0.99983586]), 'split2_train_score': array([0.99947773, 0.98314515, 0.99915107, ..., 0.98827186, 0.99956216,
#        0.99983416]), 'split3_train_score': array([0.99952227, 0.98976007, 0.99918375, ..., 0.98793586, 0.99939407,
#        0.99976586]), 'split4_train_score': array([0.99959195, 0.98789808, 0.99953024, ..., 0.99104962, 0.99959291,
#        0.99985827]), 'mean_train_score': array([0.99956614, 0.9872044 , 0.99923283, ..., 0.99005789, 0.99956581,
#        0.9998296 ]), 'std_train_score': array([5.69670122e-05, 2.18509102e-03, 1.68710074e-04, ...,
#        1.74572015e-03, 9.30721528e-05, 3.32659048e-05])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.31009887624479704
# Gamma: 0.4718762710542139
# Learning_rate: 0.014052451938914925
# Max_depth: 2
# N_estimators: 61
# Subsample: 0.41248429610335946

# %% [markdown]
# # Creating a basic XGBoost model

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Generate test and training samples
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# Implementation of the scikit-learn API for XGBoost regression
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5+50, subsample=p6, eval_metric=["rmse"])

# %%
# Show all parameters of XGBoost model
print(xgb_model)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.31009887624479704, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=['rmse'],
#              gamma=0.4718762710542139, gpu_id=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.014052451938914925, max_bin=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, n_estimators=111, n_jobs=None,
#              num_parallel_tree=None, predictor=None, random_state=None,
#              reg_alpha=None, reg_lambda=None, ...)

# %%
# Fitting the model 
xgb_model.fit(X_train, y_train, early_stopping_rounds=50, eval_set=[(X_train, y_train), (X_test, y_test)])
# learning dynamics
y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:8218.03635	validation_1-rmse:8987.81221
# [1]	validation_0-rmse:8163.19073	validation_1-rmse:8962.07616
# [2]	validation_0-rmse:8137.23817	validation_1-rmse:8953.07180
# [3]	validation_0-rmse:8099.42630	validation_1-rmse:8942.88307
# [4]	validation_0-rmse:8091.80253	validation_1-rmse:8934.27279
# [5]	validation_0-rmse:8083.00556	validation_1-rmse:8925.24465
# [6]	validation_0-rmse:8078.30228	validation_1-rmse:8919.93134
# [7]	validation_0-rmse:8067.32254	validation_1-rmse:8911.49642
# [8]	validation_0-rmse:8061.92064	validation_1-rmse:8906.17043
# [9]	validation_0-rmse:8033.07280	validation_1-rmse:8880.79267
# [10]	validation_0-rmse:8029.77359	validation_1-rmse:8876.25733
# [11]	validation_0-rmse:8027.82128	validation_1-rmse:8874.37189
# [12]	validation_0-rmse:8018.35501	validation_1-rmse:8868.76314
# [13]	validation_0-rmse:8013.19117	validation_1-rmse:8862.94566
# [14]	validation_0-rmse:8010.64245	validation_1-rmse:8860.05427
# [15]	validation_0-rmse:7981.78562	validation_1-rmse:8813.76903
# [16]	validation_0-rmse:7921.75475	validation_1-rmse:8745.10183
# [17]	validation_0-rmse:7905.00726	validation_1-rmse:8715.49904
# [18]	validation_0-rmse:7901.41940	validation_1-rmse:8712.49150
# [19]	validation_0-rmse:7856.97739	validation_1-rmse:8706.85527
# [20]	validation_0-rmse:7856.55602	validation_1-rmse:8704.73973
# [21]	validation_0-rmse:7847.58586	validation_1-rmse:8697.55619
# [22]	validation_0-rmse:7783.05576	validation_1-rmse:8629.35206
# [23]	validation_0-rmse:7778.75978	validation_1-rmse:8622.32295
# [24]	validation_0-rmse:7756.14248	validation_1-rmse:8579.30954
# [25]	validation_0-rmse:7747.46229	validation_1-rmse:8563.57124
# [26]	validation_0-rmse:7702.73613	validation_1-rmse:8526.66262
# [27]	validation_0-rmse:7701.67155	validation_1-rmse:8525.16428
# [28]	validation_0-rmse:7692.10453	validation_1-rmse:8514.95006
# [29]	validation_0-rmse:7685.06974	validation_1-rmse:8510.82177
# [30]	validation_0-rmse:7681.85824	validation_1-rmse:8509.53495
# [31]	validation_0-rmse:7654.81625	validation_1-rmse:8452.92907
# [32]	validation_0-rmse:7611.56873	validation_1-rmse:8446.33617
# [33]	validation_0-rmse:7604.78885	validation_1-rmse:8442.40916
# [34]	validation_0-rmse:7562.79564	validation_1-rmse:8438.63792
# [35]	validation_0-rmse:7561.21941	validation_1-rmse:8437.94734
# [36]	validation_0-rmse:7517.30808	validation_1-rmse:8427.47014
# [37]	validation_0-rmse:7510.05991	validation_1-rmse:8421.53136
# [38]	validation_0-rmse:7491.48786	validation_1-rmse:8386.22345
# [39]	validation_0-rmse:7449.24951	validation_1-rmse:8388.50872
# [40]	validation_0-rmse:7445.75346	validation_1-rmse:8388.02651
# [41]	validation_0-rmse:7427.80241	validation_1-rmse:8382.33997
# [42]	validation_0-rmse:7400.50324	validation_1-rmse:8380.81489
# [43]	validation_0-rmse:7371.70032	validation_1-rmse:8325.26015
# [44]	validation_0-rmse:7350.21032	validation_1-rmse:8323.58131
# [45]	validation_0-rmse:7348.24543	validation_1-rmse:8321.02673
# [46]	validation_0-rmse:7339.48054	validation_1-rmse:8315.94772
# [47]	validation_0-rmse:7321.41717	validation_1-rmse:8299.73724
# [48]	validation_0-rmse:7279.39855	validation_1-rmse:8287.50706
# [49]	validation_0-rmse:7279.63718	validation_1-rmse:8286.66151
# [50]	validation_0-rmse:7278.73903	validation_1-rmse:8286.86607
# [51]	validation_0-rmse:7225.04119	validation_1-rmse:8233.01160
# [52]	validation_0-rmse:7202.28701	validation_1-rmse:8198.48146
# [53]	validation_0-rmse:7164.08688	validation_1-rmse:8199.60492
# [54]	validation_0-rmse:7116.84095	validation_1-rmse:8165.76983
# [55]	validation_0-rmse:7114.54109	validation_1-rmse:8163.79275
# [56]	validation_0-rmse:7109.93171	validation_1-rmse:8162.08561
# [57]	validation_0-rmse:7088.58192	validation_1-rmse:8132.94208
# [58]	validation_0-rmse:7053.88277	validation_1-rmse:8128.77354
# [59]	validation_0-rmse:7033.08053	validation_1-rmse:8128.91530
# [60]	validation_0-rmse:7001.95411	validation_1-rmse:8132.85714
# [61]	validation_0-rmse:7000.79355	validation_1-rmse:8132.53458
# [62]	validation_0-rmse:6954.99938	validation_1-rmse:8140.38810
# [63]	validation_0-rmse:6929.85861	validation_1-rmse:8092.34909
# [64]	validation_0-rmse:6892.26177	validation_1-rmse:8088.27136
# [65]	validation_0-rmse:6888.13673	validation_1-rmse:8083.28532
# [66]	validation_0-rmse:6887.84940	validation_1-rmse:8084.75845
# [67]	validation_0-rmse:6843.58270	validation_1-rmse:8081.87946
# [68]	validation_0-rmse:6842.40931	validation_1-rmse:8080.31571
# [69]	validation_0-rmse:6834.21803	validation_1-rmse:8080.35451
# [70]	validation_0-rmse:6835.15247	validation_1-rmse:8080.84234
# [71]	validation_0-rmse:6834.48353	validation_1-rmse:8081.52399
# [72]	validation_0-rmse:6827.57685	validation_1-rmse:8075.00445
# [73]	validation_0-rmse:6823.35187	validation_1-rmse:8073.38495
# [74]	validation_0-rmse:6820.26947	validation_1-rmse:8074.51628
# [75]	validation_0-rmse:6795.47393	validation_1-rmse:8082.89493
# [76]	validation_0-rmse:6795.82181	validation_1-rmse:8086.98644
# [77]	validation_0-rmse:6773.53893	validation_1-rmse:8090.80838
# [78]	validation_0-rmse:6757.40813	validation_1-rmse:8060.56596
# [79]	validation_0-rmse:6757.28731	validation_1-rmse:8058.53332
# [80]	validation_0-rmse:6753.09880	validation_1-rmse:8058.32806
# [81]	validation_0-rmse:6717.07653	validation_1-rmse:8067.80000
# [82]	validation_0-rmse:6716.26568	validation_1-rmse:8069.10614
# [83]	validation_0-rmse:6715.78106	validation_1-rmse:8068.99223
# [84]	validation_0-rmse:6703.43586	validation_1-rmse:8045.84681
# [85]	validation_0-rmse:6682.56671	validation_1-rmse:8041.34289
# [86]	validation_0-rmse:6645.30137	validation_1-rmse:8035.41855
# [87]	validation_0-rmse:6646.43570	validation_1-rmse:8034.04834
# [88]	validation_0-rmse:6645.54400	validation_1-rmse:8035.24684
# [89]	validation_0-rmse:6624.30504	validation_1-rmse:8020.97492
# [90]	validation_0-rmse:6621.56218	validation_1-rmse:8022.81303
# [91]	validation_0-rmse:6601.45474	validation_1-rmse:7979.26202
# [92]	validation_0-rmse:6551.82553	validation_1-rmse:7944.37847
# [93]	validation_0-rmse:6501.39509	validation_1-rmse:7898.80785
# [94]	validation_0-rmse:6495.44452	validation_1-rmse:7899.49790
# [95]	validation_0-rmse:6439.88486	validation_1-rmse:7853.82360
# [96]	validation_0-rmse:6391.19166	validation_1-rmse:7818.06447
# [97]	validation_0-rmse:6390.77971	validation_1-rmse:7816.47047
# [98]	validation_0-rmse:6387.31372	validation_1-rmse:7816.17525
# [99]	validation_0-rmse:6383.74924	validation_1-rmse:7805.83002
# [100]	validation_0-rmse:6363.73223	validation_1-rmse:7766.69044
# [101]	validation_0-rmse:6347.83641	validation_1-rmse:7746.81915
# [102]	validation_0-rmse:6343.64611	validation_1-rmse:7743.45704
# [103]	validation_0-rmse:6342.95587	validation_1-rmse:7743.05476
# [104]	validation_0-rmse:6329.04217	validation_1-rmse:7716.67169
# [105]	validation_0-rmse:6313.21457	validation_1-rmse:7704.18762
# [106]	validation_0-rmse:6293.27774	validation_1-rmse:7665.68406
# [107]	validation_0-rmse:6270.07695	validation_1-rmse:7674.06011
# [108]	validation_0-rmse:6268.41655	validation_1-rmse:7673.33909
# [109]	validation_0-rmse:6253.41638	validation_1-rmse:7643.33063
# [110]	validation_0-rmse:6218.75069	validation_1-rmse:7644.28525

# %%
# Iteration with the best result
optimal_n= xgb_model.best_ntree_limit-1
print("The best iteration: " + str(optimal_n))
# Out:
# The best iteration: 109

# %%
# Preparing data for building a learning graph
results = xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(results['validation_0']['rmse'], label='Train')
plt.plot(results['validation_1']['rmse'], label='Test')
plt.axvline(optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a basic XGBoost model

# %% [markdown]
# # Test (validation) observations

# %%
# Convert data to 'array' type
conv_y_pred = pd.DataFrame(y_pred) # Double transformation
y_pred2 = conv_y_pred.values
y_test2 = y_test.values

# Intermediate results
n_sample = len(y_pred2)
main_sample = y_test.sum() / n_sample

# Calculation of bias
diff = y_pred2 - y_test2
bias = diff.sum()
print('Bias: %.1f' % (bias/n_sample))
print("Relative bias(%):", " %.2f" % (bias/main_sample))

# Calculation of RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %.1f" % (rmse))
print("Relative RMSE(%):", " %.3f" % (rmse/main_sample))

# Calculation of MSE
mse = mean_squared_error(y_test, y_pred)
print("MSE: %.1f" % (mse))

# Calculation of Square R
R_square = r2_score(y_test, y_pred)
print("R square: %.1f%%" % (R_square * 100.0))
# Out:
# Bias: -2096.9
# Relative bias(%):  -33.55
# RMSE: 7643.3
# Relative RMSE(%):  1.941
# MSE: 58420503.2
# R square: 10.8%

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(y_test)
x_test_convert = np.array([None]*n_sample)
for i in range(n_sample):
    x_test_convert[i] = float(x_test_conv[i])

x_plot = x_test_convert
y_plot = y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 1408.386
# a1: 0.110
# R^2: 0.269
# Uncertainty
# a0: (1.41+/-0.21)e+03
# a1: 0.110+/-0.023

# %% [markdown]
# # All observations

# %%
# Comparison of training and testing prediction values for XGBoost model 
y_pred_train = xgb_model.predict(X_train, ntree_limit=xgb_model.best_ntree_limit)

plt.figure(figsize =(8, 5))
plt.scatter(y_train, y_pred_train, alpha=0.5, label='Training data')
plt.scatter(y_test, y_pred, s = 5, c = "red", label='Validation (test) data')
plt.xlabel('Obs.')
plt.ylabel('Predict')
plt.grid(True)
plt.legend(loc='best')
# Out:
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %% [markdown]
# # Estimation training sample

# %%
# Convert data to 'array' type
conv_y_pred = pd.DataFrame(y_pred_train) # Double transformation
y_pred_train2 = conv_y_pred.values
y_train2 = y_train.values

# Intermediate results
n_sample = len(y_pred_train2)
main_sample = y_train.sum() / n_sample

# Calculation of bias
diff = y_pred_train2 - y_train2
bias = diff.sum()
print('Bias: %.1f' % (bias/n_sample))
print("Relative bias(%):", " %.2f" % (bias/main_sample))

# Calculation of RMSE
rmse = np.sqrt(mean_squared_error(y_train, y_pred_train))
print("RMSE: %.1f" % (rmse))
print("Relative RMSE(%):", " %.3f" % (rmse/main_sample))

# Calculation of MSE
mse = mean_squared_error(y_train, y_pred_train)
print("MSE: %.1f" % (mse))

# Calculation of Square R
R_square = r2_score(y_train, y_pred_train)
print("R square: %.1f%%" % (R_square * 100.0))
# Out:
# Bias: -763.5
# Relative bias(%):  -50.94
# RMSE: 6253.4
# Relative RMSE(%):  2.857
# MSE: 39105218.7
# R square: 37.9%

# %%
# Convert input data
x_train_conv = np.array(y_train)
x_train_convert = np.array([None]*n_sample)
for i in range(n_sample):
    x_train_convert[i] = float(x_train_conv[i])

x_plot = x_train_convert
y_plot = y_pred_train
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values (Training sample)', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 933.820
# a1: 0.224
# R^2: 0.828
# Uncertainty
# a0: (9.3+/-0.7)e+02
# a1: 0.224+/-0.009

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(xgb_model,num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [15, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, X_train, color=shap_values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [235], in <cell line: 2>()
#       1 # Create a dependence scatter plot to show the effect of a single feature across the whole dataset
#       2 for name in X_train.columns:
# ----> 3     shap.dependence_plot(name, shap_values, X_train, color=shap_values)
#
# File ~/anaconda3/lib/python3.9/site-packages/shap/plots/_scatter.py:676, in dependence_legacy(ind, shap_values, features, feature_names, display_features, interaction_index, color, axis_color, cmap, dot_size, x_jitter, alpha, title, xmin, xmax, ax, show)
#     674     cvals[cvals_imp > chigh] = chigh
#     675     cvals[cvals_imp < clow] = clow
# --> 676     p = ax.scatter(
#     677         xv[xv_notnan], s[xv_notnan], s=dot_size, linewidth=0, c=cvals[xv_notnan],
#     678         cmap=cmap, alpha=alpha, vmin=clow, vmax=chigh,
#     679         norm=color_norm, rasterized=len(xv) > 500
#     680     )
#     681     p.set_array(cvals[xv_notnan])
#     682 else:
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:4474, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4472     collection.set_cmap(cmap)
#    4473     collection.set_norm(norm)
# -> 4474     collection._scale_norm(norm, vmin, vmax)
#    4476 # Classic mode only:
#    4477 # ensure there are margins to allow for the
#    4478 # finite size of the symbols.  In v2.x, margins
#    4479 # are present by default, so we disable this
#    4480 # scatter-specific override.
#    4481 if rcParams['_internal.classic_mode']:
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/cm.py:380, in ScalarMappable._scale_norm(self, norm, vmin, vmax)
#     378     self.set_clim(vmin, vmax)
#     379     if norm is not None:
# --> 380         raise ValueError(
#     381             "Passing parameters norm and vmin/vmax simultaneously is "
#     382             "not supported. Please pass vmin/vmax directly to the "
#     383             "norm when creating it.")
#     385 # always resolve the autoscaling so we have concrete limits
#     386 # rather than deferring to draw time.
#     387 self.autoscale_None()
#
# ValueError: Passing parameters norm and vmin/vmax simultaneously is not supported. Please pass vmin/vmax directly to the norm when creating it.

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:8453.67552
# [1]	validation_0-rmse:8430.95709
# [2]	validation_0-rmse:8424.60781
# [3]	validation_0-rmse:8396.48381
# [4]	validation_0-rmse:8382.66840
# [5]	validation_0-rmse:8361.05527
# [6]	validation_0-rmse:8351.46060
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:8342.99090
# [8]	validation_0-rmse:8303.30734
# [9]	validation_0-rmse:8269.25572
# [10]	validation_0-rmse:8251.35619
# [11]	validation_0-rmse:8219.43815
# [12]	validation_0-rmse:8205.34003
# [13]	validation_0-rmse:8162.76139
# [14]	validation_0-rmse:8146.08416
# [15]	validation_0-rmse:8101.96739
# [16]	validation_0-rmse:8092.56755
# [17]	validation_0-rmse:8041.06261
# [18]	validation_0-rmse:7946.69948
# [19]	validation_0-rmse:7939.98806
# [20]	validation_0-rmse:7931.19071
# [21]	validation_0-rmse:7894.86386
# [22]	validation_0-rmse:7837.85727
# [23]	validation_0-rmse:7820.85109
# [24]	validation_0-rmse:7775.23881
# [25]	validation_0-rmse:7717.82580
# [26]	validation_0-rmse:7693.95099
# [27]	validation_0-rmse:7689.31140
# [28]	validation_0-rmse:7663.69590
# [29]	validation_0-rmse:7654.03362
# [30]	validation_0-rmse:7600.42157
# [31]	validation_0-rmse:7590.74097
# [32]	validation_0-rmse:7586.82260
# [33]	validation_0-rmse:7523.13354
# [34]	validation_0-rmse:7461.14970
# [35]	validation_0-rmse:7456.52251
# [36]	validation_0-rmse:7440.96784
# [37]	validation_0-rmse:7371.93672
# [38]	validation_0-rmse:7351.21000
# [39]	validation_0-rmse:7317.65812
# [40]	validation_0-rmse:7311.32284
# [41]	validation_0-rmse:7303.20389
# [42]	validation_0-rmse:7290.20661
# [43]	validation_0-rmse:7284.14160
# [44]	validation_0-rmse:7280.30857
# [45]	validation_0-rmse:7243.59081
# [46]	validation_0-rmse:7238.22163
# [47]	validation_0-rmse:7236.16191
# [48]	validation_0-rmse:7218.66344
# [49]	validation_0-rmse:7212.08142
# [50]	validation_0-rmse:7206.11567
# [51]	validation_0-rmse:7190.12034
# [52]	validation_0-rmse:7127.12181
# [53]	validation_0-rmse:7123.40806
# [54]	validation_0-rmse:7102.92934
# [55]	validation_0-rmse:7089.89590
# [56]	validation_0-rmse:7084.22965
# [57]	validation_0-rmse:7079.10689
# [58]	validation_0-rmse:7008.88773
# [59]	validation_0-rmse:7001.64078
# [60]	validation_0-rmse:6939.88701
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 109

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -1279.8
# Relative bias(%):  -98.49
# RMSE: 6939.9
# Relative RMSE(%):  2.555
# MSE: 48162031.9
# R square: 25.2%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(0.001, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 1012.908
# a1: 0.156
# R^2: 0.703
# Uncertainty
# a0: (1.01+/-0.06)e+03
# a1: 0.156+/-0.007

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/4_RN_content_in_wood/Output_pred_data/xgb_model_Cs_without_geo.json")
# Save to text format
xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/4_RN_content_in_wood/Output_pred_data/xgb_model_Cs_without_geo.txt")
