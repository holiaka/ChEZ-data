# %% [markdown]
# # ***Processing with RN data in stem woody biomass for forest sites***

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
site_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/4_RN_content_in _wood/Unit_site_data.xlsx'
df = pd.read_excel(site_data, sheet_name='RN_filtration_data')
df.head()
# Out:
#    Ідентифікатор Site # Species  Species_ID  Ntrees at site  % composition  \
# 0            728     59    Pine           0              27     100.000000
# 1            732     60    Pine           0              34     100.000000
# 2            561     18    Pine           0              31     100.000000
# 3            583     24    Pine           0              41     100.000000
# 4            607     30    Pine           0              29      97.488699
#
#         D_cm        H_m    G_m2_ha  N_ha  ... Sr_2021_kBq_m  ln_Sr_2021_kBq_m  \
# 0  13.689683  14.172733  39.767869  2700  ...    142.473352          4.959155
# 1  13.427365  16.722719  48.177280  3400  ...    140.891592          4.947991
# 2  36.101112  22.899803  31.736072   310  ...    127.861465          4.850947
# 3  22.675871  19.058137  33.092769   820  ...    132.062791          4.883277
# 4  11.569878   7.286778   3.049340   290  ...    256.528882          5.547241
#
#     T_ag_Cs    T_ag_Sr  AEDR_count AEDR_mean  AEDR_median  AEDR_std  \
# 0  4.086871  32.707871          22  0.635455        0.625  0.026411
# 1  5.217198  44.005465          27  0.633333        0.640  0.033333
# 2  1.376541  11.262189          26  0.667308        0.700  0.097134
# 3  1.012129  14.614260          32  0.650625        0.645  0.052556
# 4  1.320400  22.726486          37  0.977838        0.980  0.100193
#
#    Distance_km  Azimuth
# 0     7.371249       83
# 1     7.376963       84
# 2    11.738311       56
# 3    11.738726       56
# 4     9.296014       49
#
# [5 rows x 51 columns]

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['Species', 'Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
                                    'Origin', 'Origin_ID','A_year', 'D_live_cm', 'H_live_m', 'G_live_m2_ha',
                                    'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
                                    'ln_Cs_2021_kBq_m', 'ln_Sr_2021_kBq_m', 'ln_A_Cs', 'ln_A_Sr', 'T_ag_Cs', 'T_ag_Sr'])
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0" is nutural stand, "1" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#   Species  Species_ID  % composition       D_cm        H_m    G_m2_ha Origin  \
# 0    Pine           0     100.000000  13.689683  14.172733  39.767869      a
# 1    Pine           0     100.000000  13.427365  16.722719  48.177280      a
# 2    Pine           0     100.000000  36.101112  22.899803  31.736072      n
# 3    Pine           0     100.000000  22.675871  19.058137  33.092769      a
# 4    Pine           0      97.488699  11.569878   7.286778   3.049340      n
#
#    Origin_ID  A_year  D_live_cm  ...  M_Soil  AEDR_mean  Distance_km  Azimuth  \
# 0          1      60  13.689683  ...       1   0.635455     7.371249       83
# 1          1      60  13.427365  ...       2   0.633333     7.376963       84
# 2          0     105  36.101112  ...       2   0.667308    11.738311       56
# 3          1      65  22.675871  ...       2   0.650625    11.738726       56
# 4          0      50  11.520995  ...       0   0.977838     9.296014       49
#
#    ln_Cs_2021_kBq_m  ln_Sr_2021_kBq_m   ln_A_Cs   ln_A_Sr   T_ag_Cs    T_ag_Sr
# 0          6.288433          4.959155  7.696213  8.446771  4.086871  32.707871
# 1          6.285414          4.947991  7.937375  8.732305  5.217198  44.005465
# 2          6.324216          4.850947  6.643790  7.272398  1.376541  11.262189
# 3          6.315880          4.883277  6.327937  7.565275  1.012129  14.614260
# 4          6.678611          5.547241  6.956545  8.670772  1.320400  22.726486
#
# [5 rows x 23 columns]

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Species           209 non-null    object
#  1   Species_ID        209 non-null    int64
#  2   % composition     209 non-null    float64
#  3   D_cm              209 non-null    float64
#  4   H_m               209 non-null    float64
#  5   G_m2_ha           209 non-null    float64
#  6   Origin            209 non-null    object
#  7   Origin_ID         209 non-null    int64
#  8   A_year            209 non-null    int64
#  9   D_live_cm         209 non-null    float64
#  10  H_live_m          209 non-null    float64
#  11  G_live_m2_ha      209 non-null    float64
#  12  F_Soil_ID         209 non-null    int64
#  13  M_Soil            209 non-null    int64
#  14  AEDR_mean         209 non-null    float64
#  15  Distance_km       209 non-null    float64
#  16  Azimuth           209 non-null    int64
#  17  ln_Cs_2021_kBq_m  209 non-null    float64
#  18  ln_Sr_2021_kBq_m  209 non-null    float64
#  19  ln_A_Cs           209 non-null    float64
#  20  ln_A_Sr           209 non-null    float64
#  21  T_ag_Cs           209 non-null    float64
#  22  T_ag_Sr           209 non-null    float64
# dtypes: float64(15), int64(6), object(2)
# memory usage: 37.7+ KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species","Origin"])['ln_A_Cs', 'ln_A_Sr'].describe()
# Out:
# <ipython-input-5-cb3922d68dae>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Species","Origin"])['ln_A_Cs', 'ln_A_Sr'].describe()
#                ln_A_Cs                                                    \
#                  count      mean       std       min       25%       50%
# Species Origin
# Alder   n         13.0  6.249674  1.661129  3.295837  5.840642  6.040255
# Aspen   n          9.0  5.584313  3.039601  2.708050  3.295837  4.204693
# Birch   a          8.0  4.362177  2.328619  2.564949  2.827543  3.233849
#         n         37.0  6.034944  2.148756  2.079442  4.488636  6.363028
# Oak     a          4.0  8.028237  2.843374  3.891820  7.345698  9.021902
#         n          3.0  5.397258  2.735149  2.397895  4.219075  6.040255
# Pine    a         79.0  6.394467  1.794226  1.526056  5.172417  6.811244
#         n         51.0  5.557900  2.118875  1.504077  3.783156  5.659482
# Red oak a          3.0  3.445685  0.588708  2.833213  3.164860  3.496508
# Robinia n          1.0  4.394449       NaN  4.394449  4.394449  4.394449
# Spruce  a          1.0  5.176150       NaN  5.176150  5.176150  5.176150
#
#                                     ln_A_Sr                                \
#                      75%        max   count      mean       std       min
# Species Origin
# Alder   n       6.940222   9.287301    13.0  6.055811  1.449620  4.094345
# Aspen   n       6.729824  11.366743     9.0  7.575485  2.597130  4.615121
# Birch   a       5.514399   9.296518     8.0  6.723859  2.848366  3.401197
#         n       7.306531  10.332018    37.0  7.876554  2.178501  2.660260
# Oak     a       9.704441  10.177324     4.0  8.028961  3.011778  3.931826
#         n       6.896939   7.753624     3.0  6.067628  1.994720  3.871201
# Pine    a       7.413919  10.468801    79.0  7.586615  1.908352  2.406945
#         n       6.951761  10.328755    51.0  7.291517  1.863717  4.317488
# Red oak a       3.751920   4.007333     3.0  4.697638  0.334751  4.418841
# Robinia n       4.394449   4.394449     1.0  7.265430       NaN  7.265430
# Spruce  a       5.176150   5.176150     1.0  7.783224       NaN  7.783224
#
#
#                      25%       50%       75%        max
# Species Origin
# Alder   n       4.442651  6.302619  7.286192   7.649693
# Aspen   n       5.209486  7.870930  8.881836  11.180246
# Birch   a       5.087325  5.586554  8.559757  11.957611
#         n       6.873164  7.824046  8.995909  13.864301
# Oak     a       7.072729  8.529114  9.485347  11.125791
#         n       5.218233  6.565265  7.165841   7.766417
# Pine    a       6.293930  8.022897  8.896975  11.378251
#         n       6.107615  6.917706  8.327879  12.687263
# Red oak a       4.512005  4.605170  4.837037   5.068904
# Robinia n       7.265430  7.265430  7.265430   7.265430
# Spruce  a       7.783224  7.783224  7.783224   7.783224

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = ["ln_A_Sr"], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#     Species  Species_ID  % composition       D_cm        H_m    G_m2_ha  \
# 0      Pine           0     100.000000  13.689683  14.172733  39.767869
# 1      Pine           0     100.000000  13.427365  16.722719  48.177280
# 2      Pine           0     100.000000  36.101112  22.899803  31.736072
# 3      Pine           0     100.000000  22.675871  19.058137  33.092769
# 4      Pine           0      97.488699  11.569878   7.286778   3.049340
# ..      ...         ...            ...        ...        ...        ...
# 204    Pine           0     100.000000  35.040189  30.408979  52.037681
# 205   Aspen           4     100.000000   7.826238  10.127355  26.931363
# 206   Alder           3     100.000000  28.978440  26.563984  36.908750
# 207    Pine           0     100.000000   9.173331   8.917017  26.454278
# 208   Birch           2      99.642147   7.546824  12.122158  19.695312
#
#     Origin  Origin_ID  A_year  D_live_cm  ...  M_Soil  AEDR_mean  Distance_km  \
# 0        a          1      60  13.689683  ...       1   0.635455     7.371249
# 1        a          1      60  13.427365  ...       2   0.633333     7.376963
# 2        n          0     105  36.101112  ...       2   0.667308    11.738311
# 3        a          1      65  22.675871  ...       2   0.650625    11.738726
# 4        n          0      50  11.520995  ...       0   0.977838     9.296014
# ..     ...        ...     ...        ...  ...     ...        ...          ...
# 204      a          1      90  35.040189  ...       2   0.196071    28.101579
# 205      n          0      20   7.826238  ...       3   2.051667    17.500269
# 206      n          0      75  28.978440  ...       4   0.354615    21.662263
# 207      n          0      20   9.173331  ...       2   0.141667    51.395430
# 208      n          0      10   7.475887  ...       4   4.437826     6.802058
#
#      Azimuth  ln_Cs_2021_kBq_m  ln_Sr_2021_kBq_m   ln_A_Cs   ln_A_Sr  \
# 0         83          6.288433          4.959155  7.696213  8.446771
# 1         84          6.285414          4.947991  7.937375  8.732305
# 2         56          6.324216          4.850947  6.643790  7.272398
# 3         56          6.315880          4.883277  6.327937  7.565275
# 4         49          6.678611          5.547241  6.956545  8.670772
# ..       ...               ...               ...       ...       ...
# 204      177          4.294728          2.386717  3.806662  4.369448
# 205      270          7.685552          5.678281  5.288267  8.839277
# 206      257          5.441028          3.892589  6.040255  4.094345
# 207      246          6.623376          2.282779  1.945910  5.123964
# 208      341          8.889716          7.917537  8.326033  8.083329
#
#       T_ag_Cs    T_ag_Sr
# 0    4.086871  32.707871
# 1    5.217198  44.005465
# 2    1.376541  11.262189
# 3    1.012129  14.614260
# 4    1.320400  22.726486
# ..        ...        ...
# 204  0.613813   7.262549
# 205  0.090965  23.594083
# 206  1.820711   1.223549
# 207  0.009303  17.136062
# 208  0.569109   1.180327
#
# [209 rows x 23 columns]

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID  % composition        D_cm         H_m     G_m2_ha  \
# count  209.000000     209.000000  209.000000  209.000000  209.000000
# mean     1.076555      94.337925   17.770981   16.978858   30.000765
# std      1.579276      14.155594    8.921738    6.832292   15.907971
# min      0.000000      20.805369    1.914854    2.704460    0.259356
# 25%      0.000000      96.775081   11.601519   12.401789   17.519173
# 50%      0.000000     100.000000   16.817809   17.466646   30.845307
# 75%      2.000000     100.000000   22.264253   21.414562   42.817263
# max      6.000000     100.000000   52.228464   34.048688   66.922093
#
#         Origin_ID      A_year   D_live_cm    H_live_m  G_live_m2_ha  ...  \
# count  209.000000  209.000000  209.000000  209.000000    209.000000  ...
# mean     0.454545   47.464115   17.555614   16.999369     31.436810  ...
# std      0.499125   24.724635    8.470174    6.783414     15.470759  ...
# min      0.000000   10.000000    1.874874    2.704460      0.656684  ...
# 25%      0.000000   30.000000   12.307179   12.193980     20.938452  ...
# 50%      0.000000   45.000000   16.780740   17.365162     31.800484  ...
# 75%      1.000000   60.000000   22.023624   21.604236     43.193896  ...
# max      1.000000  150.000000   41.664506   33.436497     71.679126  ...
#
#            M_Soil   AEDR_mean  Distance_km     Azimuth  ln_Cs_2021_kBq_m  \
# count  209.000000  209.000000   209.000000  209.000000        209.000000
# mean     2.220096    2.526858    14.640059  174.296651          6.604313
# std      0.692944    4.756383    12.363729   99.912885          1.489537
# min      0.000000    0.110000     3.998568    9.000000          3.360908
# 25%      2.000000    0.460000     6.562497   56.000000          6.102349
# 50%      2.000000    0.756000     9.203749  189.000000          6.563573
# 75%      3.000000    2.401667    20.865459  261.000000          7.570955
# max      4.000000   36.591739    57.286577  342.000000         10.133543
#
#        ln_Sr_2021_kBq_m     ln_A_Cs     ln_A_Sr     T_ag_Cs     T_ag_Sr
# count        209.000000  209.000000  209.000000  209.000000  209.000000
# mean           5.063896    5.964225    7.381811    0.981351   14.880664
# std            1.836778    2.095016    2.042856    1.011648   13.738437
# min            0.876328    1.504077    2.406945    0.009303    0.800387
# 25%            3.784361    4.110874    5.752573    0.248868    5.667873
# 50%            5.233597    6.309918    7.506592    0.603680   11.248801
# 75%            6.092493    7.306531    8.846497    1.402308   19.433892
# max            9.256979   11.366743   13.864301    5.217198  105.506332
#
# [8 rows x 21 columns]

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
                                    'Origin_ID','A_year', 'D_live_cm', 'H_live_m', 'G_live_m2_ha',
                                    'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
                                    'ln_Cs_2021_kBq_m', 'ln_Sr_2021_kBq_m'])
y = pd.DataFrame(select, columns= ['ln_A_Sr'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_value = np.random.normal(10, 2, size=count)
    X['Random_col'] = norm_value
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): Yes
# Selected "Yes"!!! A new column with random values was created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID  % composition       D_cm        H_m    G_m2_ha  Origin_ID  \
# 0           0     100.000000  13.689683  14.172733  39.767869          1
# 1           0     100.000000  13.427365  16.722719  48.177280          1
# 2           0     100.000000  36.101112  22.899803  31.736072          0
# 3           0     100.000000  22.675871  19.058137  33.092769          1
# 4           0      97.488699  11.569878   7.286778   3.049340          0
#
#    A_year  D_live_cm   H_live_m  G_live_m2_ha  F_Soil_ID  M_Soil  AEDR_mean  \
# 0      60  13.689683  14.172733     39.767869          1       1   0.635455
# 1      60  13.427365  16.722719     48.177280          1       2   0.633333
# 2     105  36.101112  22.899803     31.736072          1       2   0.667308
# 3      65  22.675871  19.058137     33.092769          1       2   0.650625
# 4      50  11.520995   7.265345      3.127891          1       0   0.977838
#
#    Distance_km  Azimuth  ln_Cs_2021_kBq_m  ln_Sr_2021_kBq_m  Random_col
# 0     7.371249       83          6.288433          4.959155   10.259832
# 1     7.376963       84          6.285414          4.947991    8.115458
# 2    11.738311       56          6.324216          4.850947    9.158389
# 3    11.738726       56          6.315880          4.883277    9.230564
# 4     9.296014       49          6.678611          5.547241   10.696970

# %%
# Columns in "y" data collections
y.head()
# Out:
#     ln_A_Sr
# 0  8.446771
# 1  8.732305
# 2  7.272398
# 3  7.565275
# 4  8.670772

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.8801502785447858, 0.89751904820754, 0.8158731562343546]
#     Mean: 0.865
#     Std: 0.035
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.72737537 0.87110765 0.85081513]
#     Mean: 0.816
#     Std: 0.064
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.5533181389830119, 0.563138857262203, 0.6285175254834933]
#     Mean: 0.582
#     Std: 0.033
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=100, cv=3, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y, eval_metric="rmse")

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
ytree': 0.40991618088764514, 'gamma': 0.006347555200316157, 'learning_rate': 0.28160182602281336, 'max_depth': 4, 'n_estimators': 174, 'subsample': 0.3517459207203589}, {'colsample_bytree': 0.7890843371982076, 'gamma': 0.03329046551354531, 'learning_rate': 0.11066627302101004, 'max_depth': 4, 'n_estimators': 65, 'subsample': 0.5204153436030099}, {'colsample_bytree': 0.7663205884636493, 'gamma': 0.2688679879939203, 'learning_rate': 0.1669015232730963, 'max_depth': 4, 'n_estimators': 158, 'subsample': 0.5601357459934755}, {'colsample_bytree': 0.770520166849878, 'gamma': 0.2277885937527095, 'learning_rate': 0.1359475411309458, 'max_depth': 4, 'n_estimators': 100, 'subsample': 0.6229565379227476}, {'colsample_bytree': 0.43532065600037917, 'gamma': 0.2622315243754545, 'learning_rate': 0.1934540454367469, 'max_depth': 4, 'n_estimators': 56, 'subsample': 0.4840145541962706}, {'colsample_bytree':  ...
#         0.68487448,  0.72384554,  0.68178592,  0.75511043,  0.67056312,
#         0.77515788,  0.68776551,  0.69939291,  0.10749249,  0.59856017,
#         0.66820285,  0.3402513 ,  0.75963369,  0.71496002,  0.70560018,
#         0.68194787,  0.68849703,  0.63645782,  0.61932569,  0.68511515,
#        -0.58570082,  0.66715385,  0.70517902,  0.48827173,  0.55393481,
#         0.71263234,  0.56668627,  0.56961801,  0.62441851,  0.63681511,
#         0.68942771,  0.64285883,  0.26753894,  0.58443237,  0.63042249,
#        -0.5941369 ,  0.68304013,  0.55171034,  0.53007017,  0.70133431,
#         0.74426813,  0.38959702,  0.68611651,  0.56958409,  0.62381932,
#         0.66936701,  0.44213609,  0.73429935,  0.68284116,  0.72781157,
#         0.62590469, -0.47207508,  0.24298698,  0.6499403 , -0.08846516,
#         0.46673249,  0.59115051,  0.71843371,  0.4550492 ,  0.65416356,
#        -2.61959594,  0.61897614,  0.69753786,  0.71301451,  0.74612235,
#         0.77096968,  0.75016716,  0.66691037,  0.69898757,  0.72006141,
#         0.68180629,  0.69352997,  0.65772032,  0.66639283,  0.71965675,
#         0.7033462 ,  0.74601507,  0.75188064,  0.66516189,  0.6652176 ,
#         0.54490013,  0.73062033,  0.72477071,  0.63737016,  0.70515946,
#         0.71866424,  0.64574724,  0.62529496,  0.62840561,  0.06906426,
#         0.71112727,  0.7399301 ,  0.42669438,  0.13608578,  0.67865752]), 'split1_test_score': array([ 0.91812383,  0.90439318,  0.8202731 ,  0.80469911,  0.80790953,
#         0.91472725,  0.91881659,  0.90775442,  0.91075877,  0.88158631,
#         0.90661027,  0.8585959 ,  0.89150184,  0.71114406,  0.83790774,
#         0.91384916,  0.77985078,  0.81492653,  0.92607191,  0.86705338,
#         0.91640645,  0.86561077,  0.91025447,  0.88703589,  0.90862683,
#         0.38390103,  0.81220534,  0.88891246,  0.89022649,  0.83645225,
#         0.90471949,  0.87882204,  0.81967059,  0.8246251 ,  0.9056893 ,
#         0.90334499,  0.83840671,  0.72163488,  0.83129371,  0.87685817,
#         0.97258081,  0.99222272,  0.98366436,  0.99181358,  0.98683014,
#         0.97489292,  0.99227429,  0.98769135,  0.99263843,  0.79723211,
#         0.97676171,  0.99329841,  0.97399824,  0.87282428,  0.97382333]), 'std_train_score': array([2.15488135e-03, 1.27867456e-04, 4.20013856e-04, 9.70676113e-03,
#        3.59483239e-04, 3.42647487e-04, 3.04596092e-03, 7.01977777e-04,
#        3.82403173e-04, 3.27833042e-04, 6.80336510e-04, 7.91869014e-04,
#        2.06616333e-03, 1.17670424e-03, 2.76380662e-04, 6.04035289e-04,
#        2.20023755e-03, 2.86658872e-05, 1.35177736e-03, 3.38466414e-04,
#        4.91768616e-05, 5.81853637e-04, 4.69525319e-03, 5.18561572e-03,
#        4.30435344e-03, 8.51236503e-03, 1.81086072e-04, 6.90024640e-04,
#        3.53420462e-03, 3.05334027e-04, 1.64392650e-03, 4.10155278e-03,
#        7.12626846e-04, 4.43031246e-04, 1.82218604e-03, 1.18349842e-03,
#        5.68758069e-04, 1.24922133e-03, 4.57307727e-04, 9.25998348e-04,
#        3.52112792e-02, 1.37092044e-04, 4.99635284e-04, 1.99001041e-03,
#        2.57212034e-03, 1.10323163e-03, 1.59976835e-03, 7.98104894e-04,
#        2.11591675e-03, 5.74634084e-04, 3.38383759e-03, 2.43685866e-03,
#        4.56030904e-04, 4.27764673e-04, 1.93610319e-04, 8.33300504e-04,
#        4.29877746e-02, 7.06057807e-03, 4.34076793e-04, 2.02380835e-02,
#        4.32056232e-04, 5.43516050e-04, 3.23330892e-04, 1.03810409e-03,
#        9.36129732e-04, 2.19483998e-01, 2.08008440e-03, 4.22143443e-04,
#        1.49025283e-03, 5.37950379e-04, 9.27146204e-04, 2.31653768e-03,
#        5.82075239e-05, 4.00137997e-04, 1.83113515e-04, 5.13499572e-04,
#        3.80591464e-03, 3.66334692e-03, 3.38697322e-03, 4.31341400e-03,
#        6.09328549e-04, 6.17084566e-04, 1.64361793e-03, 1.43778526e-03,
#        3.56187219e-04, 1.49673517e-03, 9.70924160e-04, 1.11810899e-03,
#        4.39919487e-04, 9.08173650e-04, 2.00286634e-03, 2.74461860e-04,
#        5.76582529e-04, 2.83416656e-04, 1.30859733e-02, 5.53345988e-04,
#        2.16369455e-04, 1.22849481e-03, 1.03471482e-02, 3.08568401e-03])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.7262998386942109
# Gamma: 0.06472919068787036
# Learning_rate: 0.07002379800931303
# Max_depth: 3
# N_estimators: 196
# Subsample: 0.30133462624707114

# %% [markdown]
# # Creating a basic XGBoost model

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Generate test and training samples
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Implementation of the scikit-learn API for XGBoost regression
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Show all parameters of XGBoost model
print(xgb_model)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.7262998386942109,
#              enable_categorical=False, eval_metric=['rmse'],
#              gamma=0.06472919068787036, gpu_id=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.07002379800931303,
#              max_delta_step=None, max_depth=3, min_child_weight=None,
#              missing=nan, monotone_constraints=None, n_estimators=196,
#              n_jobs=None, num_parallel_tree=None, predictor=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=0.30133462624707114,
#              tree_method=None, validate_parameters=None, verbosity=None)

# %%
# Fitting the model 
xgb_model.fit(X_train, y_train, early_stopping_rounds=100, eval_set=[(X_train, y_train), (X_test, y_test)])
# learning dynamics
y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:6.74018	validation_1-rmse:6.59657
# [1]	validation_0-rmse:6.30638	validation_1-rmse:6.16927
# [2]	validation_0-rmse:5.88778	validation_1-rmse:5.77052
# [3]	validation_0-rmse:5.49298	validation_1-rmse:5.37625
# [4]	validation_0-rmse:5.14522	validation_1-rmse:5.03446
# [5]	validation_0-rmse:4.82709	validation_1-rmse:4.70944
# [6]	validation_0-rmse:4.52309	validation_1-rmse:4.41705
# [7]	validation_0-rmse:4.25265	validation_1-rmse:4.16134
# [8]	validation_0-rmse:3.98784	validation_1-rmse:3.90217
# [9]	validation_0-rmse:3.75629	validation_1-rmse:3.67983
# [10]	validation_0-rmse:3.52282	validation_1-rmse:3.46487
# [11]	validation_0-rmse:3.30248	validation_1-rmse:3.24941
# [12]	validation_0-rmse:3.10079	validation_1-rmse:3.06387
# [13]	validation_0-rmse:2.91272	validation_1-rmse:2.88383
# [14]	validation_0-rmse:2.73377	validation_1-rmse:2.72651
# [15]	validation_0-rmse:2.56518	validation_1-rmse:2.56989
# [16]	validation_0-rmse:2.41955	validation_1-rmse:2.43287
# [17]	validation_0-rmse:2.27366	validation_1-rmse:2.29364
# [18]	validation_0-rmse:2.15976	validation_1-rmse:2.18539
# [19]	validation_0-rmse:2.03423	validation_1-rmse:2.07558
# [20]	validation_0-rmse:1.91530	validation_1-rmse:1.96209
# [21]	validation_0-rmse:1.81196	validation_1-rmse:1.85970
# [22]	validation_0-rmse:1.72776	validation_1-rmse:1.78140
# [23]	validation_0-rmse:1.63902	validation_1-rmse:1.69963
# [24]	validation_0-rmse:1.53813	validation_1-rmse:1.61071
# [25]	validation_0-rmse:1.46676	validation_1-rmse:1.54976
# [26]	validation_0-rmse:1.39722	validation_1-rmse:1.49392
# [27]	validation_0-rmse:1.32016	validation_1-rmse:1.43461
# [28]	validation_0-rmse:1.25796	validation_1-rmse:1.38534
# [29]	validation_0-rmse:1.20760	validation_1-rmse:1.34731
# [30]	validation_0-rmse:1.15239	validation_1-rmse:1.29804
# [31]	validation_0-rmse:1.09752	validation_1-rmse:1.25509
# [32]	validation_0-rmse:1.05261	validation_1-rmse:1.22008
# [33]	validation_0-rmse:1.00242	validation_1-rmse:1.17956
# [34]	validation_0-rmse:0.96137	validation_1-rmse:1.15317
# [35]	validation_0-rmse:0.92344	validation_1-rmse:1.12921
# [36]	validation_0-rmse:0.88399	validation_1-rmse:1.10263
# [37]	validation_0-rmse:0.85255	validation_1-rmse:1.08208
# [38]	validation_0-rmse:0.82467	validation_1-rmse:1.06352
# [39]	validation_0-rmse:0.80906	validation_1-rmse:1.05449
# [40]	validation_0-rmse:0.77644	validation_1-rmse:1.03310
# [41]	validation_0-rmse:0.74689	validation_1-rmse:1.01404
# [42]	validation_0-rmse:0.72880	validation_1-rmse:0.99901
# [43]	validation_0-rmse:0.70927	validation_1-rmse:0.97997
# [44]	validation_0-rmse:0.68453	validation_1-rmse:0.96034
# [45]	validation_0-rmse:0.66536	validation_1-rmse:0.93927
# [46]	validation_0-rmse:0.65019	validation_1-rmse:0.92524
# [47]	validation_0-rmse:0.63734	validation_1-rmse:0.91733
# [48]	validation_0-rmse:0.62033	validation_1-rmse:0.90873
# [49]	validation_0-rmse:0.60804	validation_1-rmse:0.90100
# [50]	validation_0-rmse:0.59662	validation_1-rmse:0.88379
# [51]	validation_0-rmse:0.58247	validation_1-rmse:0.87685
# [52]	validation_0-rmse:0.57261	validation_1-rmse:0.87474
# [53]	validation_0-rmse:0.55964	validation_1-rmse:0.86388
# [54]	validation_0-rmse:0.54670	validation_1-rmse:0.85637
# [55]	validation_0-rmse:0.53926	validation_1-rmse:0.85049
# [56]	validation_0-rmse:0.53201	validation_1-rmse:0.84490
# [57]	validation_0-rmse:0.52452	validation_1-rmse:0.84592
# [58]	validation_0-rmse:0.52169	validation_1-rmse:0.83922
# [59]	validation_0-rmse:0.51266	validation_1-rmse:0.83611
# [60]	validation_0-rmse:0.50555	validation_1-rmse:0.82831
# [61]	validation_0-rmse:0.49937	validation_1-rmse:0.82369
# [62]	validation_0-rmse:0.49478	validation_1-rmse:0.81678
# [63]	validation_0-rmse:0.48631	validation_1-rmse:0.81373
# [64]	validation_0-rmse:0.48065	validation_1-rmse:0.80658
# [65]	validation_0-rmse:0.47344	validation_1-rmse:0.80278
# [66]	validation_0-rmse:0.46547	validation_1-rmse:0.79413
# [67]	validation_0-rmse:0.46021	validation_1-rmse:0.78586
# [68]	validation_0-rmse:0.45379	validation_1-rmse:0.78050
# [69]	validation_0-rmse:0.44864	validation_1-rmse:0.77668
# [70]	validation_0-rmse:0.44497	validation_1-rmse:0.77678
# [71]	validation_0-rmse:0.44309	validation_1-rmse:0.78143
# [72]	validation_0-rmse:0.43875	validation_1-rmse:0.78116
# [73]	validation_0-rmse:0.43670	validation_1-rmse:0.77446
# [74]	validation_0-rmse:0.43336	validation_1-rmse:0.77119
# [75]	validation_0-rmse:0.43232	validation_1-rmse:0.77028
# [76]	validation_0-rmse:0.42876	validation_1-rmse:0.76975
# [77]	validation_0-rmse:0.42429	validation_1-rmse:0.76888
# [78]	validation_0-rmse:0.42208	validation_1-rmse:0.76898
# [79]	validation_0-rmse:0.42208	validation_1-rmse:0.77080
# [80]	validation_0-rmse:0.41807	validation_1-rmse:0.76973
# [81]	validation_0-rmse:0.41547	validation_1-rmse:0.77147
# [82]	validation_0-rmse:0.41097	validation_1-rmse:0.76934
# [83]	validation_0-rmse:0.40802	validation_1-rmse:0.76381
# [84]	validation_0-rmse:0.40700	validation_1-rmse:0.76477
# [85]	validation_0-rmse:0.40667	validation_1-rmse:0.76806
# [86]	validation_0-rmse:0.40336	validation_1-rmse:0.76691
# [87]	validation_0-rmse:0.40081	validation_1-rmse:0.76348
# [88]	validation_0-rmse:0.39635	validation_1-rmse:0.76596
# [89]	validation_0-rmse:0.39417	validation_1-rmse:0.76561
# [90]	validation_0-rmse:0.39125	validation_1-rmse:0.76151
# [91]	validation_0-rmse:0.38827	validation_1-rmse:0.76331
# [92]	validation_0-rmse:0.38706	validation_1-rmse:0.75894
# [93]	validation_0-rmse:0.38494	validation_1-rmse:0.75577
# [94]	validation_0-rmse:0.38151	validation_1-rmse:0.75229
# [95]	validation_0-rmse:0.37851	validation_1-rmse:0.75136
# [96]	validation_0-rmse:0.37580	validation_1-rmse:0.75454
# [97]	validation_0-rmse:0.37268	validation_1-rmse:0.75674
# [98]	validation_0-rmse:0.37038	validation_1-rmse:0.75815
# [99]	validation_0-rmse:0.36676	validation_1-rmse:0.75853
# [100]	validation_0-rmse:0.36540	validation_1-rmse:0.75575
# [101]	validation_0-rmse:0.36461	validation_1-rmse:0.75487
# [102]	validation_0-rmse:0.36197	validation_1-rmse:0.75450
# [103]	validation_0-rmse:0.35987	validation_1-rmse:0.75725
# [104]	validation_0-rmse:0.35717	validation_1-rmse:0.75276
# [105]	validation_0-rmse:0.35480	validation_1-rmse:0.75487
# [106]	validation_0-rmse:0.35328	validation_1-rmse:0.75373
# [107]	validation_0-rmse:0.35080	validation_1-rmse:0.75092
# [108]	validation_0-rmse:0.34791	validation_1-rmse:0.74628
# [109]	validation_0-rmse:0.34662	validation_1-rmse:0.74605
# [110]	validation_0-rmse:0.34477	validation_1-rmse:0.74770
# [111]	validation_0-rmse:0.34271	validation_1-rmse:0.74559
# [112]	validation_0-rmse:0.34199	validation_1-rmse:0.74740
# [113]	validation_0-rmse:0.34019	validation_1-rmse:0.74667
# [114]	validation_0-rmse:0.33838	validation_1-rmse:0.74832
# [115]	validation_0-rmse:0.33650	validation_1-rmse:0.75126
# [116]	validation_0-rmse:0.33473	validation_1-rmse:0.75225
# [117]	validation_0-rmse:0.33278	validation_1-rmse:0.75190
# [118]	validation_0-rmse:0.33002	validation_1-rmse:0.75183
# [119]	validation_0-rmse:0.32704	validation_1-rmse:0.74765
# [120]	validation_0-rmse:0.32773	validation_1-rmse:0.74750
# [121]	validation_0-rmse:0.32718	validation_1-rmse:0.74591
# [122]	validation_0-rmse:0.32588	validation_1-rmse:0.74461
# [123]	validation_0-rmse:0.32399	validation_1-rmse:0.74503
# [124]	validation_0-rmse:0.32083	validation_1-rmse:0.74380
# [125]	validation_0-rmse:0.31910	validation_1-rmse:0.74145
# [126]	validation_0-rmse:0.31710	validation_1-rmse:0.74116
# [127]	validation_0-rmse:0.31543	validation_1-rmse:0.74085
# [128]	validation_0-rmse:0.31304	validation_1-rmse:0.74232
# [129]	validation_0-rmse:0.31306	validation_1-rmse:0.74035
# [130]	validation_0-rmse:0.31116	validation_1-rmse:0.73873
# [131]	validation_0-rmse:0.30969	validation_1-rmse:0.73689
# [132]	validation_0-rmse:0.30987	validation_1-rmse:0.74016
# [133]	validation_0-rmse:0.30888	validation_1-rmse:0.73774
# [134]	validation_0-rmse:0.30524	validation_1-rmse:0.73640
# [135]	validation_0-rmse:0.30332	validation_1-rmse:0.73714
# [136]	validation_0-rmse:0.30191	validation_1-rmse:0.73528
# [137]	validation_0-rmse:0.30044	validation_1-rmse:0.73598
# [138]	validation_0-rmse:0.29907	validation_1-rmse:0.73462
# [139]	validation_0-rmse:0.29743	validation_1-rmse:0.73120
# [140]	validation_0-rmse:0.29543	validation_1-rmse:0.73025
# [141]	validation_0-rmse:0.29391	validation_1-rmse:0.72898
# [142]	validation_0-rmse:0.29134	validation_1-rmse:0.72974
# [143]	validation_0-rmse:0.28874	validation_1-rmse:0.72873
# [144]	validation_0-rmse:0.28748	validation_1-rmse:0.72596
# [145]	validation_0-rmse:0.28593	validation_1-rmse:0.72669
# [146]	validation_0-rmse:0.28310	validation_1-rmse:0.72796
# [147]	validation_0-rmse:0.28220	validation_1-rmse:0.72504
# [148]	validation_0-rmse:0.28026	validation_1-rmse:0.72851
# [149]	validation_0-rmse:0.27797	validation_1-rmse:0.72363
# [150]	validation_0-rmse:0.27655	validation_1-rmse:0.72321
# [151]	validation_0-rmse:0.27502	validation_1-rmse:0.72956
# [152]	validation_0-rmse:0.27405	validation_1-rmse:0.73123
# [153]	validation_0-rmse:0.27223	validation_1-rmse:0.72988
# [154]	validation_0-rmse:0.27118	validation_1-rmse:0.72601
# [155]	validation_0-rmse:0.26949	validation_1-rmse:0.72505
# [156]	validation_0-rmse:0.26738	validation_1-rmse:0.72755
# [157]	validation_0-rmse:0.26684	validation_1-rmse:0.72539
# [158]	validation_0-rmse:0.26642	validation_1-rmse:0.72486
# [159]	validation_0-rmse:0.26404	validation_1-rmse:0.72530
# [160]	validation_0-rmse:0.26230	validation_1-rmse:0.72636
# [161]	validation_0-rmse:0.26155	validation_1-rmse:0.72459
# [162]	validation_0-rmse:0.25955	validation_1-rmse:0.72330
# [163]	validation_0-rmse:0.25721	validation_1-rmse:0.72486
# [164]	validation_0-rmse:0.25577	validation_1-rmse:0.72643
# [165]	validation_0-rmse:0.25478	validation_1-rmse:0.73078
# [166]	validation_0-rmse:0.25312	validation_1-rmse:0.73078
# [167]	validation_0-rmse:0.25241	validation_1-rmse:0.73024
# [168]	validation_0-rmse:0.25200	validation_1-rmse:0.72831
# [169]	validation_0-rmse:0.25155	validation_1-rmse:0.72894
# [170]	validation_0-rmse:0.25079	validation_1-rmse:0.72956
# [171]	validation_0-rmse:0.24986	validation_1-rmse:0.72946
# [172]	validation_0-rmse:0.24909	validation_1-rmse:0.72920
# [173]	validation_0-rmse:0.24872	validation_1-rmse:0.72916
# [174]	validation_0-rmse:0.24868	validation_1-rmse:0.72842
# [175]	validation_0-rmse:0.24719	validation_1-rmse:0.72813
# [176]	validation_0-rmse:0.24447	validation_1-rmse:0.72719
# [177]	validation_0-rmse:0.24313	validation_1-rmse:0.72717
# [178]	validation_0-rmse:0.24256	validation_1-rmse:0.72647
# [179]	validation_0-rmse:0.24214	validation_1-rmse:0.72702
# [180]	validation_0-rmse:0.23988	validation_1-rmse:0.72847
# [181]	validation_0-rmse:0.23822	validation_1-rmse:0.73008
# [182]	validation_0-rmse:0.23628	validation_1-rmse:0.73126
# [183]	validation_0-rmse:0.23416	validation_1-rmse:0.73182
# [184]	validation_0-rmse:0.23177	validation_1-rmse:0.73421
# [185]	validation_0-rmse:0.23055	validation_1-rmse:0.73226
# [186]	validation_0-rmse:0.22883	validation_1-rmse:0.73441
# [187]	validation_0-rmse:0.22721	validation_1-rmse:0.73620
# [188]	validation_0-rmse:0.22608	validation_1-rmse:0.73922
# [189]	validation_0-rmse:0.22503	validation_1-rmse:0.73844
# [190]	validation_0-rmse:0.22471	validation_1-rmse:0.73749
# [191]	validation_0-rmse:0.22391	validation_1-rmse:0.73919
# [192]	validation_0-rmse:0.22338	validation_1-rmse:0.74197
# [193]	validation_0-rmse:0.22269	validation_1-rmse:0.74053
# [194]	validation_0-rmse:0.22139	validation_1-rmse:0.73916
# [195]	validation_0-rmse:0.22121	validation_1-rmse:0.73822

# %%
# Iteration with the best result
optimal_n= xgb_model.best_ntree_limit-1
print("The best iteration: " + str(optimal_n))
# Out:
# The best iteration: 150

# %%
# Preparing data for building a learning graph
results = xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(results['validation_0']['rmse'], label='Train')
plt.plot(results['validation_1']['rmse'], label='Test')
plt.axvline(optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a basic XGBoost model

# %%
# Convert data to 'array' type
conv_y_pred = pd.DataFrame(y_pred) # Double transformation
y_pred2 = conv_y_pred.values
y_test2 = y_test.values

# Intermediate results
n_sample = len(y_pred2)
main_sample = y_test.sum() / n_sample

# Calculation of bias
diff = y_pred2 - y_test2
bias = diff.sum()
print('Bias: %.1f' % (bias/n_sample))
print("Relative bias(%):", " %.2f" % (bias/main_sample))

# Calculation of RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %.1f" % (rmse))
print("Relative RMSE(%):", " %.3f" % (rmse/main_sample))

# Calculation of MSE
mse = mean_squared_error(y_test, y_pred)
print("MSE: %.1f" % (mse))

# Calculation of Square R
R_square = r2_score(y_test, y_pred)
print("R square: %.1f%%" % (R_square * 100.0))
# Out:
# Bias: 0.1
# Relative bias(%):  0.56
# RMSE: 0.7
# Relative RMSE(%):  0.100
# MSE: 0.5
# R square: 89.4%

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(y_test)
x_test_convert = np.array([None]*n_sample)
for i in range(n_sample):
    x_test_convert[i] = np.float(x_test_conv[i])

x_plot = x_test_convert
y_plot = y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 1.510
# a1: 0.804
# R^2: 0.908
# Uncertainty
# a0: 1.51+/-0.31
# a1: 0.80+/-0.04

# %%
# Comparison of training and testing prediction values for XGBoost model 
y_pred_train = xgb_model.predict(X_train, ntree_limit=xgb_model.best_ntree_limit)

plt.figure(figsize =(8, 5))
plt.scatter(y_train, y_pred_train, alpha=0.5, label='Training data')
plt.scatter(y_test, y_pred, s = 5, c = "red", label='Validation (test) data')
plt.xlabel('Obs.')
plt.ylabel('Predict')
plt.legend(loc='best')
# Out:
# /home/dima/anaconda3/lib/python3.8/site-packages/xgboost/core.py:105: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(xgb_model,num_trees=1) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, X_train, color=shap_values)
