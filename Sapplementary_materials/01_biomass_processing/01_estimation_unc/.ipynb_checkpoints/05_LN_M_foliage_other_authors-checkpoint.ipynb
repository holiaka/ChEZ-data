# %% [markdown]
# ## Processing with aboveground biomass data based on my fieldworks and other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
input_data = './FULL_DB_BIOMASS_OTHER_ALL_AUTHORS.csv'
df = pd.read_csv(input_data)
df.head()
# Out:
#    Groups Species  Species_ID Origin  Origin_ID  SI  A_years   H_m  DBH_cm  \
# 0       1    Pine           0      n        0.0   4       50   9.7    14.6
# 1       1    Pine           0      n        0.0   2       65  20.6    20.6
# 2       1    Pine           0      n        0.0   2       50  13.6    15.4
# 3       1    Pine           0      n        0.0   1       60  23.3    22.2
# 4       1    Pine           0      n        0.0   3       65  15.6    16.4
#
#    N_trees  ...  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  \
# 0    486.0  ...             NaN             NaN         8.4           1.6
# 1    785.0  ...             NaN             NaN        11.5           4.1
# 2   1745.0  ...             NaN             NaN        13.7           4.1
# 3    665.0  ...             NaN             NaN        14.4           5.4
# 4    955.0  ...             NaN             NaN        14.2           3.4
#
#    LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  \
# 0         3.78              2.94                NaN                NaN
# 1         5.54              4.73                NaN                NaN
# 2         5.25              4.48                NaN                NaN
# 3         5.63              4.67                NaN                NaN
# 4         4.96              4.20                NaN                NaN
#
#    LN_Crown_t_ha  LN_Foliage_t_ha
# 0           2.13             0.47
# 1           2.44             1.41
# 2           2.62             1.41
# 3           2.67             1.69
# 4           2.65             1.22
#
# [5 rows x 24 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
#
# 'Groups','Species_ID','Origin_ID','SI','A_years','H_m','DBH_cm','RS(P)',          'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
# 'Crown_t_ha','Foliage_t_ha'
# 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species_ID','Origin_ID','H_m','DBH_cm', 'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
'Crown_t_ha','Foliage_t_ha', 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0           0        0.0   9.7    14.6         9.7      43.9           18.9
# 1           0        0.0  20.6    20.6        32.2     254.0          113.1
# 2           0        0.0  13.6    15.4        35.2     190.0           87.8
# 3           0        0.0  23.3    22.2        29.6     277.7          106.5
# 4           0        0.0  15.6    16.4        20.4     142.5           67.0
#
#    Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0             NaN             NaN         8.4           1.6         3.78
# 1             NaN             NaN        11.5           4.1         5.54
# 2             NaN             NaN        13.7           4.1         5.25
# 3             NaN             NaN        14.4           5.4         5.63
# 4             NaN             NaN        14.2           3.4         4.96
#
#    LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0              2.94                NaN                NaN           2.13
# 1              4.73                NaN                NaN           2.44
# 2              4.48                NaN                NaN           2.62
# 3              4.67                NaN                NaN           2.67
# 4              4.20                NaN                NaN           2.65
#
#    LN_Foliage_t_ha
# 0             0.47
# 1             1.41
# 2             1.41
# 3             1.69
# 4             1.22

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Species_ID         857 non-null    int64
#  1   Origin_ID          856 non-null    float64
#  2   H_m                857 non-null    float64
#  3   DBH_cm             856 non-null    float64
#  4   BA_sq_m_ha         857 non-null    float64
#  5   GS_cub_m           857 non-null    float64
#  6   ALL_STEM_t_ha      855 non-null    float64
#  7   Stem_wood_t_ha     747 non-null    float64
#  8   Stem_bark_t_ha     747 non-null    float64
#  9   Crown_t_ha         843 non-null    float64
#  10  Foliage_t_ha       854 non-null    float64
#  11  LN_GS_cub_m        857 non-null    float64
#  12  LN_ALL_STEM_t_ha   855 non-null    float64
#  13  LN_Stem_wood_t_ha  747 non-null    float64
#  14  LN_Stem_bark_t_ha  747 non-null    float64
#  15  LN_Crown_t_ha      843 non-null    float64
#  16  LN_Foliage_t_ha    854 non-null    float64
# dtypes: float64(16), int64(1)
# memory usage: 113.9 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species_ID"])["LN_Foliage_t_ha", "ALL_STEM_t_ha"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            LN_Foliage_t_ha                                                  \
#                      count      mean       std   min    25%    50%     75%
# Species_ID
# 0                    456.0  1.669211  0.508590 -1.61  1.420  1.780  2.0300
# 1                      7.0  2.688571  0.372936  2.12  2.405  2.850  2.9800
# 2                    120.0  0.701333  0.753190 -1.11  0.305  0.790  1.2650
# 3                    115.0  0.901826  0.470374 -0.22  0.590  0.870  1.2300
# 4                     66.0  1.210152  0.428082 -0.07  0.960  1.255  1.4700
# 5                     90.0  1.310111  0.569079 -0.65  1.005  1.465  1.7375
#
#                  ALL_STEM_t_ha                                              \
#              max         count        mean        std   min     25%    50%
# Species_ID
# 0           2.69         457.0   97.049891  61.854506   1.8  47.500   92.7
# 1           3.08           7.0  123.814286  61.879895  46.3  70.650  133.9
# 2           2.78         120.0   74.495000  44.523333   5.1  37.275   68.1
# 3           2.03         115.0  107.607826  55.589186  11.0  62.700  106.8
# 4           2.15          66.0   84.946970  58.875162   8.2  40.750   61.2
# 5           1.92          90.0  173.065556  99.100647   5.0  93.075  161.3
#
#
#                 75%    max
# Species_ID
# 0           135.900  310.7
# 1           174.550  196.1
# 2           103.075  193.5
# 3           145.450  251.6
# 4           125.000  245.4
# 5           253.375  363.9

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID   Origin_ID         H_m      DBH_cm  BA_sq_m_ha    GS_cub_m  \
# count  857.000000  856.000000  857.000000  856.000000  857.000000  857.000000
# mean     1.529755    0.279206   16.452275   17.132243   26.329988  229.013069
# std      1.823872    0.448871    7.039954   10.439115   10.629993  144.362106
# min      0.000000    0.000000    1.500000    1.100000    1.000000    2.400000
# 25%      0.000000    0.000000   11.200000    9.900000   19.000000  116.000000
# 50%      0.000000    0.000000   16.100000   15.500000   26.800000  206.000000
# 75%      3.000000    1.000000   21.200000   22.100000   34.500000  320.000000
# max      5.000000    1.000000   38.300000   94.000000   51.500000  735.000000
#
#        ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  \
# count     855.000000      747.000000      747.000000  843.000000
# mean      102.590877       92.779518       12.060107   13.821969
# std        68.758819       61.992238        9.595428   11.567546
# min         1.800000        2.000000        0.300000    0.500000
# 25%        47.500000       42.900000        5.950000    6.610000
# 50%        93.500000       84.600000        9.300000   10.820000
# 75%       140.500000      125.500000       15.300000   16.435000
# max       363.900000      315.200000       65.700000   69.120000
#
#        Foliage_t_ha  LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  \
# count    854.000000   857.000000        855.000000         747.000000
# mean       4.749356     5.166919          4.343766           4.246975
# std        2.826586     0.839680          0.869479           0.854856
# min        0.200000     0.880000          0.590000           0.690000
# 25%        2.600000     4.750000          3.860000           3.760000
# 50%        4.300000     5.330000          4.540000           4.440000
# 75%        6.367500     5.770000          4.950000           4.830000
# max       21.730000     6.600000          5.900000           5.750000
#
#        LN_Stem_bark_t_ha  LN_Crown_t_ha  LN_Foliage_t_ha
# count         747.000000     843.000000       854.000000
# mean            2.201232       2.318149         1.364906
# std             0.806766       0.829446         0.672551
# min            -1.200000      -0.690000        -1.610000
# 25%             1.780000       1.890000         0.960000
# 50%             2.230000       2.380000         1.460000
# 75%             2.730000       2.800000         1.850000
# max             4.190000       4.240000         3.080000

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "LN_Foliage_t_ha"
indep_variables = ['Species_ID','Origin_ID','H_m','DBH_cm','BA_sq_m_ha']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0             0        0.0   9.7    14.6         9.7      43.9           18.9
# 1             0        0.0  20.6    20.6        32.2     254.0          113.1
# 2             0        0.0  13.6    15.4        35.2     190.0           87.8
# 3             0        0.0  23.3    22.2        29.6     277.7          106.5
# 4             0        0.0  15.6    16.4        20.4     142.5           67.0
# ..          ...        ...   ...     ...         ...       ...            ...
# 852           3        0.0   7.8     4.4         9.2      39.8           17.8
# 853           3        0.0  12.7     9.0        20.5     123.6           47.1
# 854           3        0.0  12.2     8.1        20.3     141.7           51.9
# 855           2        0.0  14.3    12.4        25.1     176.5          100.7
# 856           2        0.0  21.1    25.6        21.0     191.6           99.9
#
#      Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0               NaN             NaN        8.40          1.60         3.78
# 1               NaN             NaN       11.50          4.10         5.54
# 2               NaN             NaN       13.70          4.10         5.25
# 3               NaN             NaN       14.40          5.40         5.63
# 4               NaN             NaN       14.20          3.40         4.96
# ..              ...             ...         ...           ...          ...
# 852            15.7             2.1        2.26          2.04         3.68
# 853            42.6             4.5        2.14          1.21         4.82
# 854            47.8             4.1        2.11          1.16         4.95
# 855            84.6            16.1       16.90          4.74         5.17
# 856            80.8            19.1       16.60          2.13         5.26
#
#      LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0                2.94                NaN                NaN           2.13
# 1                4.73                NaN                NaN           2.44
# 2                4.48                NaN                NaN           2.62
# 3                4.67                NaN                NaN           2.67
# 4                4.20                NaN                NaN           2.65
# ..                ...                ...                ...            ...
# 852              2.88               2.75               0.74           0.82
# 853              3.85               3.75               1.50           0.76
# 854              3.95               3.87               1.41           0.75
# 855              4.61               4.44               2.78           2.83
# 856              4.60               4.39               2.95           2.81
#
#      LN_Foliage_t_ha
# 0               0.47
# 1               1.41
# 2               1.41
# 3               1.69
# 4               1.22
# ..               ...
# 852             0.71
# 853             0.19
# 854             0.15
# 855             1.56
# 856             0.76
#
# [854 rows x 17 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha
# 0           0        0.0   9.7    14.6         9.7
# 1           0        0.0  20.6    20.6        32.2
# 2           0        0.0  13.6    15.4        35.2
# 3           0        0.0  23.3    22.2        29.6
# 4           0        0.0  15.6    16.4        20.4

# %%
# Columns in "y" data collections
y.head()
# Out:
#    LN_Foliage_t_ha
# 0             0.47
# 1             1.41
# 2             1.41
# 3             1.69
# 4             1.22

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.5894110486052753, 0.6237680228193012, 0.5570578611674215]
#     Mean: 0.590
#     Std: 0.027
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.60561473 0.41017256 0.4767388 ]
#     Mean: 0.498
#     Std: 0.081
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.2896559690498469, 0.30380767822618543, 0.2999521222359068]
#     Mean: 0.298
#     Std: 0.006
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.6376420855691677                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.030051961019074536                # gamma
print('Gamma: ' + str(p2))

p3 = 0.2640899209518656                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 4            # max_depth
print('Max_depth: ' + str(p4))

p5 = 196         # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.7879876518750124                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.6376420855691677
# Gamma: 0.030051961019074536
# Learning_rate: 0.2640899209518656
# Max_depth: 4
# N_estimators: 196
# Subsample: 0.7879876518750124

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:0.87066	validation_1-rmse:0.85826
# [1]	validation_0-rmse:0.71859	validation_1-rmse:0.71661
# [2]	validation_0-rmse:0.62776	validation_1-rmse:0.63001
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:0.55243	validation_1-rmse:0.56644
# [4]	validation_0-rmse:0.49142	validation_1-rmse:0.51427
# [5]	validation_0-rmse:0.44777	validation_1-rmse:0.48148
# [6]	validation_0-rmse:0.42291	validation_1-rmse:0.46498
# [7]	validation_0-rmse:0.40441	validation_1-rmse:0.45914
# [8]	validation_0-rmse:0.39865	validation_1-rmse:0.45882
# [9]	validation_0-rmse:0.38606	validation_1-rmse:0.45246
# [10]	validation_0-rmse:0.37467	validation_1-rmse:0.44655
# [11]	validation_0-rmse:0.36502	validation_1-rmse:0.44228
# [12]	validation_0-rmse:0.35786	validation_1-rmse:0.44104
# [13]	validation_0-rmse:0.35169	validation_1-rmse:0.44153
# [14]	validation_0-rmse:0.34642	validation_1-rmse:0.43941
# [15]	validation_0-rmse:0.34034	validation_1-rmse:0.43940
# [16]	validation_0-rmse:0.33692	validation_1-rmse:0.43912
# [17]	validation_0-rmse:0.33431	validation_1-rmse:0.43793
# [18]	validation_0-rmse:0.32805	validation_1-rmse:0.43971
# [19]	validation_0-rmse:0.32392	validation_1-rmse:0.43998
# [20]	validation_0-rmse:0.32118	validation_1-rmse:0.43960
# [21]	validation_0-rmse:0.31713	validation_1-rmse:0.43776
# [22]	validation_0-rmse:0.31262	validation_1-rmse:0.43395
# [23]	validation_0-rmse:0.30954	validation_1-rmse:0.43416
# [24]	validation_0-rmse:0.30460	validation_1-rmse:0.43194
# [25]	validation_0-rmse:0.30163	validation_1-rmse:0.43112
# [26]	validation_0-rmse:0.29851	validation_1-rmse:0.43289
# [27]	validation_0-rmse:0.29586	validation_1-rmse:0.43242
# [28]	validation_0-rmse:0.29190	validation_1-rmse:0.43533
# [29]	validation_0-rmse:0.28975	validation_1-rmse:0.43456
# [30]	validation_0-rmse:0.28702	validation_1-rmse:0.43767
# [31]	validation_0-rmse:0.28476	validation_1-rmse:0.43538
# [32]	validation_0-rmse:0.28321	validation_1-rmse:0.43380
# [33]	validation_0-rmse:0.27936	validation_1-rmse:0.42882
# [34]	validation_0-rmse:0.27764	validation_1-rmse:0.42730
# [35]	validation_0-rmse:0.27464	validation_1-rmse:0.42259
# [36]	validation_0-rmse:0.27221	validation_1-rmse:0.42319
# [37]	validation_0-rmse:0.26762	validation_1-rmse:0.42020
# [38]	validation_0-rmse:0.26364	validation_1-rmse:0.41962
# [39]	validation_0-rmse:0.26099	validation_1-rmse:0.41794
# [40]	validation_0-rmse:0.25933	validation_1-rmse:0.41975
# [41]	validation_0-rmse:0.25656	validation_1-rmse:0.41773
# [42]	validation_0-rmse:0.25400	validation_1-rmse:0.41626
# [43]	validation_0-rmse:0.25192	validation_1-rmse:0.41385
# [44]	validation_0-rmse:0.24869	validation_1-rmse:0.41506
# [45]	validation_0-rmse:0.24742	validation_1-rmse:0.41450
# [46]	validation_0-rmse:0.24631	validation_1-rmse:0.41567
# [47]	validation_0-rmse:0.24448	validation_1-rmse:0.41580
# [48]	validation_0-rmse:0.24250	validation_1-rmse:0.41491
# [49]	validation_0-rmse:0.23951	validation_1-rmse:0.41130
# [50]	validation_0-rmse:0.23788	validation_1-rmse:0.41026
# [51]	validation_0-rmse:0.23685	validation_1-rmse:0.40938
# [52]	validation_0-rmse:0.23579	validation_1-rmse:0.40932
# [53]	validation_0-rmse:0.23307	validation_1-rmse:0.40798
# [54]	validation_0-rmse:0.23017	validation_1-rmse:0.40569
# [55]	validation_0-rmse:0.22832	validation_1-rmse:0.40603
# [56]	validation_0-rmse:0.22699	validation_1-rmse:0.40669
# [57]	validation_0-rmse:0.22642	validation_1-rmse:0.40596
# [58]	validation_0-rmse:0.22502	validation_1-rmse:0.40514
# [59]	validation_0-rmse:0.22327	validation_1-rmse:0.40547
# [60]	validation_0-rmse:0.22215	validation_1-rmse:0.40587
# [61]	validation_0-rmse:0.22038	validation_1-rmse:0.40722
# [62]	validation_0-rmse:0.21796	validation_1-rmse:0.40788
# [63]	validation_0-rmse:0.21662	validation_1-rmse:0.40701
# [64]	validation_0-rmse:0.21473	validation_1-rmse:0.40512
# [65]	validation_0-rmse:0.21272	validation_1-rmse:0.40623
# [66]	validation_0-rmse:0.21163	validation_1-rmse:0.40563
# [67]	validation_0-rmse:0.20991	validation_1-rmse:0.40622
# [68]	validation_0-rmse:0.20786	validation_1-rmse:0.40703
# [69]	validation_0-rmse:0.20703	validation_1-rmse:0.40634
# [70]	validation_0-rmse:0.20636	validation_1-rmse:0.40773
# [71]	validation_0-rmse:0.20569	validation_1-rmse:0.40641
# [72]	validation_0-rmse:0.20478	validation_1-rmse:0.40649
# [73]	validation_0-rmse:0.20375	validation_1-rmse:0.40599
# [74]	validation_0-rmse:0.20300	validation_1-rmse:0.40745
# [75]	validation_0-rmse:0.20165	validation_1-rmse:0.40885
# [76]	validation_0-rmse:0.20067	validation_1-rmse:0.40862
# [77]	validation_0-rmse:0.19948	validation_1-rmse:0.40573
# [78]	validation_0-rmse:0.19822	validation_1-rmse:0.40605
# [79]	validation_0-rmse:0.19615	validation_1-rmse:0.40483
# [80]	validation_0-rmse:0.19448	validation_1-rmse:0.40478
# [81]	validation_0-rmse:0.19355	validation_1-rmse:0.40412
# [82]	validation_0-rmse:0.19267	validation_1-rmse:0.40470
# [83]	validation_0-rmse:0.19108	validation_1-rmse:0.40543
# [84]	validation_0-rmse:0.18963	validation_1-rmse:0.40498
# [85]	validation_0-rmse:0.18831	validation_1-rmse:0.40431
# [86]	validation_0-rmse:0.18687	validation_1-rmse:0.40431
# [87]	validation_0-rmse:0.18594	validation_1-rmse:0.40389
# [88]	validation_0-rmse:0.18505	validation_1-rmse:0.40350
# [89]	validation_0-rmse:0.18390	validation_1-rmse:0.40339
# [90]	validation_0-rmse:0.18321	validation_1-rmse:0.40301
# [91]	validation_0-rmse:0.18251	validation_1-rmse:0.40292
# [92]	validation_0-rmse:0.18146	validation_1-rmse:0.40370
# [93]	validation_0-rmse:0.17982	validation_1-rmse:0.40435
# [94]	validation_0-rmse:0.17878	validation_1-rmse:0.40436
# [95]	validation_0-rmse:0.17757	validation_1-rmse:0.40411
# [96]	validation_0-rmse:0.17708	validation_1-rmse:0.40399
# [97]	validation_0-rmse:0.17552	validation_1-rmse:0.40372
# [98]	validation_0-rmse:0.17516	validation_1-rmse:0.40414
# [99]	validation_0-rmse:0.17449	validation_1-rmse:0.40419
# [100]	validation_0-rmse:0.17370	validation_1-rmse:0.40484
# [101]	validation_0-rmse:0.17226	validation_1-rmse:0.40497
# [102]	validation_0-rmse:0.17135	validation_1-rmse:0.40512
# [103]	validation_0-rmse:0.17116	validation_1-rmse:0.40498
# [104]	validation_0-rmse:0.17057	validation_1-rmse:0.40630
# [105]	validation_0-rmse:0.16991	validation_1-rmse:0.40710
# [106]	validation_0-rmse:0.16935	validation_1-rmse:0.40564
# [107]	validation_0-rmse:0.16863	validation_1-rmse:0.40568
# [108]	validation_0-rmse:0.16795	validation_1-rmse:0.40665
# [109]	validation_0-rmse:0.16634	validation_1-rmse:0.40559
# [110]	validation_0-rmse:0.16547	validation_1-rmse:0.40579
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:0.86656	validation_1-rmse:0.87661
# [1]	validation_0-rmse:0.71704	validation_1-rmse:0.73121
# [2]	validation_0-rmse:0.62495	validation_1-rmse:0.64237
# [3]	validation_0-rmse:0.55324	validation_1-rmse:0.57840
# [4]	validation_0-rmse:0.49729	validation_1-rmse:0.51727
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:0.45691	validation_1-rmse:0.47130
# [6]	validation_0-rmse:0.43239	validation_1-rmse:0.44456
# [7]	validation_0-rmse:0.41033	validation_1-rmse:0.42105
# [8]	validation_0-rmse:0.40268	validation_1-rmse:0.41440
# [9]	validation_0-rmse:0.38795	validation_1-rmse:0.40600
# [10]	validation_0-rmse:0.38081	validation_1-rmse:0.40345
# [11]	validation_0-rmse:0.37272	validation_1-rmse:0.40521
# [12]	validation_0-rmse:0.36561	validation_1-rmse:0.39647
# [13]	validation_0-rmse:0.35782	validation_1-rmse:0.38919
# [14]	validation_0-rmse:0.35366	validation_1-rmse:0.38872
# [15]	validation_0-rmse:0.34956	validation_1-rmse:0.38936
# [16]	validation_0-rmse:0.34462	validation_1-rmse:0.38509
# [17]	validation_0-rmse:0.34197	validation_1-rmse:0.38593
# [18]	validation_0-rmse:0.33598	validation_1-rmse:0.38607
# [19]	validation_0-rmse:0.32883	validation_1-rmse:0.38616
# [20]	validation_0-rmse:0.32467	validation_1-rmse:0.38426
# [21]	validation_0-rmse:0.31970	validation_1-rmse:0.38210
# [22]	validation_0-rmse:0.31378	validation_1-rmse:0.38242
# [23]	validation_0-rmse:0.31084	validation_1-rmse:0.38295
# [24]	validation_0-rmse:0.30897	validation_1-rmse:0.38426
# [25]	validation_0-rmse:0.30671	validation_1-rmse:0.38329
# [26]	validation_0-rmse:0.30426	validation_1-rmse:0.38091
# [27]	validation_0-rmse:0.30147	validation_1-rmse:0.38098
# [28]	validation_0-rmse:0.29922	validation_1-rmse:0.38096
# [29]	validation_0-rmse:0.29705	validation_1-rmse:0.38200
# [30]	validation_0-rmse:0.29384	validation_1-rmse:0.38206
# [31]	validation_0-rmse:0.28967	validation_1-rmse:0.38244
# [32]	validation_0-rmse:0.28577	validation_1-rmse:0.37955
# [33]	validation_0-rmse:0.28443	validation_1-rmse:0.37629
# [34]	validation_0-rmse:0.28026	validation_1-rmse:0.37886
# [35]	validation_0-rmse:0.27754	validation_1-rmse:0.38343
# [36]	validation_0-rmse:0.27423	validation_1-rmse:0.38135
# [37]	validation_0-rmse:0.27226	validation_1-rmse:0.38039
# [38]	validation_0-rmse:0.26905	validation_1-rmse:0.37962
# [39]	validation_0-rmse:0.26787	validation_1-rmse:0.38025
# [40]	validation_0-rmse:0.26554	validation_1-rmse:0.38189
# [41]	validation_0-rmse:0.26308	validation_1-rmse:0.38132
# [42]	validation_0-rmse:0.25984	validation_1-rmse:0.38014
# [43]	validation_0-rmse:0.25681	validation_1-rmse:0.38114
# [44]	validation_0-rmse:0.25391	validation_1-rmse:0.38115
# [45]	validation_0-rmse:0.25073	validation_1-rmse:0.38041
# [46]	validation_0-rmse:0.24935	validation_1-rmse:0.38121
# [47]	validation_0-rmse:0.24470	validation_1-rmse:0.38185
# [48]	validation_0-rmse:0.24182	validation_1-rmse:0.38045
# [49]	validation_0-rmse:0.23871	validation_1-rmse:0.37918
# [50]	validation_0-rmse:0.23763	validation_1-rmse:0.38023
# [51]	validation_0-rmse:0.23672	validation_1-rmse:0.38081
# [52]	validation_0-rmse:0.23562	validation_1-rmse:0.37899
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:0.86129	validation_1-rmse:0.90242
# [1]	validation_0-rmse:0.71206	validation_1-rmse:0.76303
# [2]	validation_0-rmse:0.62070	validation_1-rmse:0.67617
# [3]	validation_0-rmse:0.54442	validation_1-rmse:0.60168
# [4]	validation_0-rmse:0.48567	validation_1-rmse:0.55370
# [5]	validation_0-rmse:0.44507	validation_1-rmse:0.52288
# [6]	validation_0-rmse:0.41875	validation_1-rmse:0.50582
# [7]	validation_0-rmse:0.39996	validation_1-rmse:0.49344
# [8]	validation_0-rmse:0.38885	validation_1-rmse:0.48931
# [9]	validation_0-rmse:0.37501	validation_1-rmse:0.48391
# [10]	validation_0-rmse:0.36785	validation_1-rmse:0.48322
# [11]	validation_0-rmse:0.35927	validation_1-rmse:0.48176
# [12]	validation_0-rmse:0.35010	validation_1-rmse:0.49106
# [13]	validation_0-rmse:0.34395	validation_1-rmse:0.49276
# [14]	validation_0-rmse:0.34145	validation_1-rmse:0.49345
# [15]	validation_0-rmse:0.33760	validation_1-rmse:0.49192
# [16]	validation_0-rmse:0.33338	validation_1-rmse:0.49269
# [17]	validation_0-rmse:0.32889	validation_1-rmse:0.49142
# [18]	validation_0-rmse:0.32151	validation_1-rmse:0.48195
# [19]	validation_0-rmse:0.31697	validation_1-rmse:0.47839
# [20]	validation_0-rmse:0.31402	validation_1-rmse:0.47684
# [21]	validation_0-rmse:0.30984	validation_1-rmse:0.47459
# [22]	validation_0-rmse:0.30491	validation_1-rmse:0.47554
# [23]	validation_0-rmse:0.30359	validation_1-rmse:0.47460
# [24]	validation_0-rmse:0.30172	validation_1-rmse:0.47469
# [25]	validation_0-rmse:0.29984	validation_1-rmse:0.47434
# [26]	validation_0-rmse:0.29806	validation_1-rmse:0.47091
# [27]	validation_0-rmse:0.29309	validation_1-rmse:0.46593
# [28]	validation_0-rmse:0.28711	validation_1-rmse:0.46579
# [29]	validation_0-rmse:0.28422	validation_1-rmse:0.46563
# [30]	validation_0-rmse:0.28301	validation_1-rmse:0.46561
# [31]	validation_0-rmse:0.27770	validation_1-rmse:0.46539
# [32]	validation_0-rmse:0.27568	validation_1-rmse:0.46147
# [33]	validation_0-rmse:0.27344	validation_1-rmse:0.46160
# [34]	validation_0-rmse:0.27060	validation_1-rmse:0.46220
# [35]	validation_0-rmse:0.26827	validation_1-rmse:0.46203
# [36]	validation_0-rmse:0.26559	validation_1-rmse:0.46390
# [37]	validation_0-rmse:0.26258	validation_1-rmse:0.46282
# [38]	validation_0-rmse:0.25833	validation_1-rmse:0.46205
# [39]	validation_0-rmse:0.25607	validation_1-rmse:0.45847
# [40]	validation_0-rmse:0.25306	validation_1-rmse:0.46029
# [41]	validation_0-rmse:0.25119	validation_1-rmse:0.45998
# [42]	validation_0-rmse:0.24962	validation_1-rmse:0.45730
# [43]	validation_0-rmse:0.24782	validation_1-rmse:0.45396
# [44]	validation_0-rmse:0.24506	validation_1-rmse:0.45437
# [45]	validation_0-rmse:0.24232	validation_1-rmse:0.45371
# [46]	validation_0-rmse:0.24029	validation_1-rmse:0.45181
# [47]	validation_0-rmse:0.23828	validation_1-rmse:0.45230
# [48]	validation_0-rmse:0.23540	validation_1-rmse:0.45079
# [49]	validation_0-rmse:0.23215	validation_1-rmse:0.45290
# [50]	validation_0-rmse:0.23055	validation_1-rmse:0.45217
# [51]	validation_0-rmse:0.22834	validation_1-rmse:0.45273
# [52]	validation_0-rmse:0.22781	validation_1-rmse:0.45417
# [53]	validation_0-rmse:0.22641	validation_1-rmse:0.45290
# [54]	validation_0-rmse:0.22482	validation_1-rmse:0.45396
# [55]	validation_0-rmse:0.22345	validation_1-rmse:0.45527
# [56]	validation_0-rmse:0.22204	validation_1-rmse:0.45393
# [57]	validation_0-rmse:0.22162	validation_1-rmse:0.45522
# [58]	validation_0-rmse:0.22023	validation_1-rmse:0.45546
# [59]	validation_0-rmse:0.21708	validation_1-rmse:0.45406
# [60]	validation_0-rmse:0.21629	validation_1-rmse:0.45234
# [61]	validation_0-rmse:0.21384	validation_1-rmse:0.45214
# [62]	validation_0-rmse:0.21269	validation_1-rmse:0.45365
# [63]	validation_0-rmse:0.21009	validation_1-rmse:0.45424
# [64]	validation_0-rmse:0.20739	validation_1-rmse:0.45571
# [65]	validation_0-rmse:0.20526	validation_1-rmse:0.45661
# [66]	validation_0-rmse:0.20322	validation_1-rmse:0.45675
# [67]	validation_0-rmse:0.20160	validation_1-rmse:0.45716
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:0.87815	validation_1-rmse:0.83511
# [1]	validation_0-rmse:0.72754	validation_1-rmse:0.69356
# [2]	validation_0-rmse:0.63230	validation_1-rmse:0.60870
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:0.55279	validation_1-rmse:0.53929
# [4]	validation_0-rmse:0.49488	validation_1-rmse:0.48657
# [5]	validation_0-rmse:0.45407	validation_1-rmse:0.45098
# [6]	validation_0-rmse:0.42920	validation_1-rmse:0.43824
# [7]	validation_0-rmse:0.40841	validation_1-rmse:0.43147
# [8]	validation_0-rmse:0.39713	validation_1-rmse:0.42869
# [9]	validation_0-rmse:0.38424	validation_1-rmse:0.42454
# [10]	validation_0-rmse:0.37672	validation_1-rmse:0.42485
# [11]	validation_0-rmse:0.36927	validation_1-rmse:0.42090
# [12]	validation_0-rmse:0.36462	validation_1-rmse:0.41924
# [13]	validation_0-rmse:0.36068	validation_1-rmse:0.41691
# [14]	validation_0-rmse:0.35777	validation_1-rmse:0.41543
# [15]	validation_0-rmse:0.35179	validation_1-rmse:0.41290
# [16]	validation_0-rmse:0.34780	validation_1-rmse:0.41011
# [17]	validation_0-rmse:0.34437	validation_1-rmse:0.40860
# [18]	validation_0-rmse:0.33695	validation_1-rmse:0.40646
# [19]	validation_0-rmse:0.33150	validation_1-rmse:0.40769
# [20]	validation_0-rmse:0.32767	validation_1-rmse:0.40697
# [21]	validation_0-rmse:0.32018	validation_1-rmse:0.40901
# [22]	validation_0-rmse:0.31574	validation_1-rmse:0.41277
# [23]	validation_0-rmse:0.31210	validation_1-rmse:0.41078
# [24]	validation_0-rmse:0.30807	validation_1-rmse:0.41146
# [25]	validation_0-rmse:0.30456	validation_1-rmse:0.41208
# [26]	validation_0-rmse:0.30096	validation_1-rmse:0.41120
# [27]	validation_0-rmse:0.29700	validation_1-rmse:0.41468
# [28]	validation_0-rmse:0.29419	validation_1-rmse:0.41282
# [29]	validation_0-rmse:0.28978	validation_1-rmse:0.40960
# [30]	validation_0-rmse:0.28804	validation_1-rmse:0.40726
# [31]	validation_0-rmse:0.28436	validation_1-rmse:0.40636
# [32]	validation_0-rmse:0.28066	validation_1-rmse:0.40729
# [33]	validation_0-rmse:0.27846	validation_1-rmse:0.40688
# [34]	validation_0-rmse:0.27447	validation_1-rmse:0.40553
# [35]	validation_0-rmse:0.27158	validation_1-rmse:0.40493
# [36]	validation_0-rmse:0.26958	validation_1-rmse:0.40570
# [37]	validation_0-rmse:0.26891	validation_1-rmse:0.40462
# [38]	validation_0-rmse:0.26614	validation_1-rmse:0.40386
# [39]	validation_0-rmse:0.26129	validation_1-rmse:0.40475
# [40]	validation_0-rmse:0.25913	validation_1-rmse:0.40722
# [41]	validation_0-rmse:0.25518	validation_1-rmse:0.41009
# [42]	validation_0-rmse:0.25323	validation_1-rmse:0.41140
# [43]	validation_0-rmse:0.25194	validation_1-rmse:0.41132
# [44]	validation_0-rmse:0.25125	validation_1-rmse:0.41104
# [45]	validation_0-rmse:0.24700	validation_1-rmse:0.41056
# [46]	validation_0-rmse:0.24369	validation_1-rmse:0.41284
# [47]	validation_0-rmse:0.24115	validation_1-rmse:0.41284
# [48]	validation_0-rmse:0.23908	validation_1-rmse:0.41256
# [49]	validation_0-rmse:0.23698	validation_1-rmse:0.41226
# [50]	validation_0-rmse:0.23412	validation_1-rmse:0.41136
# [51]	validation_0-rmse:0.23262	validation_1-rmse:0.41245
# [52]	validation_0-rmse:0.23187	validation_1-rmse:0.41170
# [53]	validation_0-rmse:0.22930	validation_1-rmse:0.41157
# [54]	validation_0-rmse:0.22682	validation_1-rmse:0.41055
# [55]	validation_0-rmse:0.22640	validation_1-rmse:0.41171
# [56]	validation_0-rmse:0.22564	validation_1-rmse:0.41185
# [57]	validation_0-rmse:0.22516	validation_1-rmse:0.41214
# [58]	validation_0-rmse:0.22451	validation_1-rmse:0.41119
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:0.86961	validation_1-rmse:0.83985
# [1]	validation_0-rmse:0.72026	validation_1-rmse:0.69556
# [2]	validation_0-rmse:0.63189	validation_1-rmse:0.60752
# [3]	validation_0-rmse:0.55800	validation_1-rmse:0.54831
# [4]	validation_0-rmse:0.49858	validation_1-rmse:0.49104
# [5]	validation_0-rmse:0.45687	validation_1-rmse:0.46037
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:0.42986	validation_1-rmse:0.43952
# [7]	validation_0-rmse:0.41151	validation_1-rmse:0.43477
# [8]	validation_0-rmse:0.40319	validation_1-rmse:0.42656
# [9]	validation_0-rmse:0.38993	validation_1-rmse:0.42515
# [10]	validation_0-rmse:0.38382	validation_1-rmse:0.42128
# [11]	validation_0-rmse:0.37380	validation_1-rmse:0.41713
# [12]	validation_0-rmse:0.36792	validation_1-rmse:0.41748
# [13]	validation_0-rmse:0.36099	validation_1-rmse:0.41732
# [14]	validation_0-rmse:0.35640	validation_1-rmse:0.41506
# [15]	validation_0-rmse:0.35133	validation_1-rmse:0.41445
# [16]	validation_0-rmse:0.34458	validation_1-rmse:0.41264
# [17]	validation_0-rmse:0.33977	validation_1-rmse:0.41459
# [18]	validation_0-rmse:0.33280	validation_1-rmse:0.41014
# [19]	validation_0-rmse:0.32880	validation_1-rmse:0.40984
# [20]	validation_0-rmse:0.32686	validation_1-rmse:0.41077
# [21]	validation_0-rmse:0.32405	validation_1-rmse:0.41068
# [22]	validation_0-rmse:0.32023	validation_1-rmse:0.41232
# [23]	validation_0-rmse:0.31693	validation_1-rmse:0.41217
# [24]	validation_0-rmse:0.31558	validation_1-rmse:0.41184
# [25]	validation_0-rmse:0.31463	validation_1-rmse:0.41235
# [26]	validation_0-rmse:0.31304	validation_1-rmse:0.41254
# [27]	validation_0-rmse:0.30864	validation_1-rmse:0.41284
# [28]	validation_0-rmse:0.30581	validation_1-rmse:0.41271
# [29]	validation_0-rmse:0.30488	validation_1-rmse:0.41231
# [30]	validation_0-rmse:0.30093	validation_1-rmse:0.41121
# [31]	validation_0-rmse:0.29724	validation_1-rmse:0.40918
# [32]	validation_0-rmse:0.29590	validation_1-rmse:0.40725
# [33]	validation_0-rmse:0.29490	validation_1-rmse:0.40687
# [34]	validation_0-rmse:0.29163	validation_1-rmse:0.40631
# [35]	validation_0-rmse:0.28829	validation_1-rmse:0.40443
# [36]	validation_0-rmse:0.28615	validation_1-rmse:0.40454
# [37]	validation_0-rmse:0.28430	validation_1-rmse:0.40502
# [38]	validation_0-rmse:0.28054	validation_1-rmse:0.40526
# [39]	validation_0-rmse:0.27707	validation_1-rmse:0.40783
# [40]	validation_0-rmse:0.27325	validation_1-rmse:0.40561
# [41]	validation_0-rmse:0.27043	validation_1-rmse:0.40737
# [42]	validation_0-rmse:0.26842	validation_1-rmse:0.40718
# [43]	validation_0-rmse:0.26469	validation_1-rmse:0.40417
# [44]	validation_0-rmse:0.26135	validation_1-rmse:0.40379
# [45]	validation_0-rmse:0.25949	validation_1-rmse:0.40281
# [46]	validation_0-rmse:0.25782	validation_1-rmse:0.40263
# [47]	validation_0-rmse:0.25338	validation_1-rmse:0.40035
# [48]	validation_0-rmse:0.24785	validation_1-rmse:0.39858
# [49]	validation_0-rmse:0.24542	validation_1-rmse:0.39821
# [50]	validation_0-rmse:0.24408	validation_1-rmse:0.39744
# [51]	validation_0-rmse:0.24335	validation_1-rmse:0.39771
# [52]	validation_0-rmse:0.24251	validation_1-rmse:0.39802
# [53]	validation_0-rmse:0.24090	validation_1-rmse:0.39726
# [54]	validation_0-rmse:0.23918	validation_1-rmse:0.39716
# [55]	validation_0-rmse:0.23684	validation_1-rmse:0.39772
# [56]	validation_0-rmse:0.23537	validation_1-rmse:0.39745
# [57]	validation_0-rmse:0.23166	validation_1-rmse:0.39686
# [58]	validation_0-rmse:0.22943	validation_1-rmse:0.39668
# [59]	validation_0-rmse:0.22648	validation_1-rmse:0.39707
# [60]	validation_0-rmse:0.22455	validation_1-rmse:0.39687
# [61]	validation_0-rmse:0.22240	validation_1-rmse:0.39758
# [62]	validation_0-rmse:0.22075	validation_1-rmse:0.40052
# [63]	validation_0-rmse:0.21821	validation_1-rmse:0.40084
# [64]	validation_0-rmse:0.21728	validation_1-rmse:0.40152
# [65]	validation_0-rmse:0.21651	validation_1-rmse:0.40170
# [66]	validation_0-rmse:0.21396	validation_1-rmse:0.40128
# [67]	validation_0-rmse:0.21257	validation_1-rmse:0.40111
# [68]	validation_0-rmse:0.20930	validation_1-rmse:0.40339
# [69]	validation_0-rmse:0.20816	validation_1-rmse:0.40328
# [70]	validation_0-rmse:0.20638	validation_1-rmse:0.40543
# [71]	validation_0-rmse:0.20506	validation_1-rmse:0.40445
# [72]	validation_0-rmse:0.20372	validation_1-rmse:0.40502
# [73]	validation_0-rmse:0.20205	validation_1-rmse:0.40627
# [74]	validation_0-rmse:0.19972	validation_1-rmse:0.40578
# [75]	validation_0-rmse:0.19838	validation_1-rmse:0.40807
# [76]	validation_0-rmse:0.19686	validation_1-rmse:0.40751
# [77]	validation_0-rmse:0.19624	validation_1-rmse:0.40814
# [78]	validation_0-rmse:0.19450	validation_1-rmse:0.40907
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:0.86238	validation_1-rmse:0.89700
# [1]	validation_0-rmse:0.70939	validation_1-rmse:0.77159
# [2]	validation_0-rmse:0.60833	validation_1-rmse:0.69204
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:0.53051	validation_1-rmse:0.63683
# [4]	validation_0-rmse:0.47070	validation_1-rmse:0.59170
# [5]	validation_0-rmse:0.43055	validation_1-rmse:0.55838
# [6]	validation_0-rmse:0.40795	validation_1-rmse:0.53832
# [7]	validation_0-rmse:0.39244	validation_1-rmse:0.53362
# [8]	validation_0-rmse:0.38268	validation_1-rmse:0.53120
# [9]	validation_0-rmse:0.37149	validation_1-rmse:0.52539
# [10]	validation_0-rmse:0.36608	validation_1-rmse:0.52303
# [11]	validation_0-rmse:0.35743	validation_1-rmse:0.51566
# [12]	validation_0-rmse:0.35065	validation_1-rmse:0.50899
# [13]	validation_0-rmse:0.34363	validation_1-rmse:0.50683
# [14]	validation_0-rmse:0.33912	validation_1-rmse:0.50543
# [15]	validation_0-rmse:0.33686	validation_1-rmse:0.50284
# [16]	validation_0-rmse:0.33363	validation_1-rmse:0.49956
# [17]	validation_0-rmse:0.33005	validation_1-rmse:0.49870
# [18]	validation_0-rmse:0.32538	validation_1-rmse:0.49471
# [19]	validation_0-rmse:0.32171	validation_1-rmse:0.49376
# [20]	validation_0-rmse:0.31669	validation_1-rmse:0.49235
# [21]	validation_0-rmse:0.31120	validation_1-rmse:0.49275
# [22]	validation_0-rmse:0.30753	validation_1-rmse:0.49478
# [23]	validation_0-rmse:0.30368	validation_1-rmse:0.49200
# [24]	validation_0-rmse:0.30194	validation_1-rmse:0.49325
# [25]	validation_0-rmse:0.29764	validation_1-rmse:0.49453
# [26]	validation_0-rmse:0.29455	validation_1-rmse:0.49315
# [27]	validation_0-rmse:0.29085	validation_1-rmse:0.49296
# [28]	validation_0-rmse:0.28875	validation_1-rmse:0.49467
# [29]	validation_0-rmse:0.28374	validation_1-rmse:0.49495
# [30]	validation_0-rmse:0.27997	validation_1-rmse:0.49785
# [31]	validation_0-rmse:0.27846	validation_1-rmse:0.49661
# [32]	validation_0-rmse:0.27578	validation_1-rmse:0.49226
# [33]	validation_0-rmse:0.27245	validation_1-rmse:0.49062
# [34]	validation_0-rmse:0.26999	validation_1-rmse:0.49320
# [35]	validation_0-rmse:0.26761	validation_1-rmse:0.49362
# [36]	validation_0-rmse:0.26566	validation_1-rmse:0.49368
# [37]	validation_0-rmse:0.26367	validation_1-rmse:0.49330
# [38]	validation_0-rmse:0.26099	validation_1-rmse:0.49270
# [39]	validation_0-rmse:0.25799	validation_1-rmse:0.49252
# [40]	validation_0-rmse:0.25598	validation_1-rmse:0.49250
# [41]	validation_0-rmse:0.25406	validation_1-rmse:0.48919
# [42]	validation_0-rmse:0.25120	validation_1-rmse:0.48833
# [43]	validation_0-rmse:0.24908	validation_1-rmse:0.48972
# [44]	validation_0-rmse:0.24789	validation_1-rmse:0.49057
# [45]	validation_0-rmse:0.24730	validation_1-rmse:0.49188
# [46]	validation_0-rmse:0.24569	validation_1-rmse:0.49216
# [47]	validation_0-rmse:0.24274	validation_1-rmse:0.48973
# [48]	validation_0-rmse:0.23917	validation_1-rmse:0.49002
# [49]	validation_0-rmse:0.23645	validation_1-rmse:0.48906
# [50]	validation_0-rmse:0.23509	validation_1-rmse:0.48799
# [51]	validation_0-rmse:0.23313	validation_1-rmse:0.48515
# [52]	validation_0-rmse:0.23125	validation_1-rmse:0.48639
# [53]	validation_0-rmse:0.22875	validation_1-rmse:0.48572
# [54]	validation_0-rmse:0.22725	validation_1-rmse:0.48502
# [55]	validation_0-rmse:0.22512	validation_1-rmse:0.48626
# [56]	validation_0-rmse:0.22369	validation_1-rmse:0.48579
# [57]	validation_0-rmse:0.22227	validation_1-rmse:0.48624
# [58]	validation_0-rmse:0.22139	validation_1-rmse:0.48683
# [59]	validation_0-rmse:0.21921	validation_1-rmse:0.48644
# [60]	validation_0-rmse:0.21783	validation_1-rmse:0.48414
# [61]	validation_0-rmse:0.21550	validation_1-rmse:0.48117
# [62]	validation_0-rmse:0.21519	validation_1-rmse:0.48073
# [63]	validation_0-rmse:0.21213	validation_1-rmse:0.47856
# [64]	validation_0-rmse:0.20919	validation_1-rmse:0.47916
# [65]	validation_0-rmse:0.20834	validation_1-rmse:0.47981
# [66]	validation_0-rmse:0.20664	validation_1-rmse:0.47988
# [67]	validation_0-rmse:0.20530	validation_1-rmse:0.47937
# [68]	validation_0-rmse:0.20279	validation_1-rmse:0.47896
# [69]	validation_0-rmse:0.20194	validation_1-rmse:0.47905
# [70]	validation_0-rmse:0.19956	validation_1-rmse:0.48073
# [71]	validation_0-rmse:0.19861	validation_1-rmse:0.47993
# [72]	validation_0-rmse:0.19739	validation_1-rmse:0.48164
# [73]	validation_0-rmse:0.19649	validation_1-rmse:0.48109
# [74]	validation_0-rmse:0.19536	validation_1-rmse:0.48105
# [75]	validation_0-rmse:0.19335	validation_1-rmse:0.48082
# [76]	validation_0-rmse:0.19214	validation_1-rmse:0.47919
# [77]	validation_0-rmse:0.19162	validation_1-rmse:0.47932
# [78]	validation_0-rmse:0.19147	validation_1-rmse:0.47955
# [79]	validation_0-rmse:0.19020	validation_1-rmse:0.47913
# [80]	validation_0-rmse:0.18915	validation_1-rmse:0.47941
# [81]	validation_0-rmse:0.18761	validation_1-rmse:0.47833
# [82]	validation_0-rmse:0.18636	validation_1-rmse:0.47872
# [83]	validation_0-rmse:0.18470	validation_1-rmse:0.47875
# [84]	validation_0-rmse:0.18310	validation_1-rmse:0.47779
# [85]	validation_0-rmse:0.18252	validation_1-rmse:0.47717
# [86]	validation_0-rmse:0.18125	validation_1-rmse:0.47676
# [87]	validation_0-rmse:0.18087	validation_1-rmse:0.47673
# [88]	validation_0-rmse:0.17958	validation_1-rmse:0.47673
# [89]	validation_0-rmse:0.17785	validation_1-rmse:0.47573
# [90]	validation_0-rmse:0.17714	validation_1-rmse:0.47602
# [91]	validation_0-rmse:0.17659	validation_1-rmse:0.47655
# [92]	validation_0-rmse:0.17585	validation_1-rmse:0.47635
# [93]	validation_0-rmse:0.17461	validation_1-rmse:0.47610
# [94]	validation_0-rmse:0.17340	validation_1-rmse:0.47622
# [95]	validation_0-rmse:0.17120	validation_1-rmse:0.47622
# [96]	validation_0-rmse:0.17030	validation_1-rmse:0.47593
# [97]	validation_0-rmse:0.16950	validation_1-rmse:0.47602
# [98]	validation_0-rmse:0.16801	validation_1-rmse:0.47484
# [99]	validation_0-rmse:0.16729	validation_1-rmse:0.47526
# [100]	validation_0-rmse:0.16617	validation_1-rmse:0.47522
# [101]	validation_0-rmse:0.16466	validation_1-rmse:0.47652
# [102]	validation_0-rmse:0.16317	validation_1-rmse:0.47660
# [103]	validation_0-rmse:0.16282	validation_1-rmse:0.47662
# [104]	validation_0-rmse:0.16131	validation_1-rmse:0.47547
# [105]	validation_0-rmse:0.16003	validation_1-rmse:0.47491
# [106]	validation_0-rmse:0.15961	validation_1-rmse:0.47516
# [107]	validation_0-rmse:0.15936	validation_1-rmse:0.47507
# [108]	validation_0-rmse:0.15818	validation_1-rmse:0.47500
# [109]	validation_0-rmse:0.15699	validation_1-rmse:0.47497
# [110]	validation_0-rmse:0.15600	validation_1-rmse:0.47422
# [111]	validation_0-rmse:0.15499	validation_1-rmse:0.47336
# [112]	validation_0-rmse:0.15413	validation_1-rmse:0.47389
# [113]	validation_0-rmse:0.15310	validation_1-rmse:0.47412
# [114]	validation_0-rmse:0.15217	validation_1-rmse:0.47310
# [115]	validation_0-rmse:0.15157	validation_1-rmse:0.47171
# [116]	validation_0-rmse:0.15115	validation_1-rmse:0.47173
# [117]	validation_0-rmse:0.15064	validation_1-rmse:0.47204
# [118]	validation_0-rmse:0.14990	validation_1-rmse:0.47114
# [119]	validation_0-rmse:0.14930	validation_1-rmse:0.47176
# [120]	validation_0-rmse:0.14930	validation_1-rmse:0.47176
# [121]	validation_0-rmse:0.14789	validation_1-rmse:0.47134
# [122]	validation_0-rmse:0.14686	validation_1-rmse:0.47189
# [123]	validation_0-rmse:0.14629	validation_1-rmse:0.47187
# [124]	validation_0-rmse:0.14623	validation_1-rmse:0.47193
# [125]	validation_0-rmse:0.14534	validation_1-rmse:0.47167
# [126]	validation_0-rmse:0.14495	validation_1-rmse:0.47182
# [127]	validation_0-rmse:0.14413	validation_1-rmse:0.47158
# [128]	validation_0-rmse:0.14244	validation_1-rmse:0.47159
# [129]	validation_0-rmse:0.14193	validation_1-rmse:0.47122
# [130]	validation_0-rmse:0.14123	validation_1-rmse:0.47149
# [131]	validation_0-rmse:0.13996	validation_1-rmse:0.47264
# [132]	validation_0-rmse:0.13963	validation_1-rmse:0.47275
# [133]	validation_0-rmse:0.13857	validation_1-rmse:0.47264
# [134]	validation_0-rmse:0.13700	validation_1-rmse:0.47353
# [135]	validation_0-rmse:0.13625	validation_1-rmse:0.47264
# [136]	validation_0-rmse:0.13566	validation_1-rmse:0.47267
# [137]	validation_0-rmse:0.13502	validation_1-rmse:0.47295
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:0.87648	validation_1-rmse:0.82299
# [1]	validation_0-rmse:0.72463	validation_1-rmse:0.68757
# [2]	validation_0-rmse:0.62928	validation_1-rmse:0.60928
# [3]	validation_0-rmse:0.55269	validation_1-rmse:0.54642
# [4]	validation_0-rmse:0.49272	validation_1-rmse:0.50302
# [5]	validation_0-rmse:0.45411	validation_1-rmse:0.47083
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:0.42739	validation_1-rmse:0.46080
# [7]	validation_0-rmse:0.40625	validation_1-rmse:0.44605
# [8]	validation_0-rmse:0.39344	validation_1-rmse:0.44332
# [9]	validation_0-rmse:0.38147	validation_1-rmse:0.43741
# [10]	validation_0-rmse:0.37423	validation_1-rmse:0.43753
# [11]	validation_0-rmse:0.36369	validation_1-rmse:0.43696
# [12]	validation_0-rmse:0.35560	validation_1-rmse:0.43434
# [13]	validation_0-rmse:0.34886	validation_1-rmse:0.43255
# [14]	validation_0-rmse:0.34418	validation_1-rmse:0.43161
# [15]	validation_0-rmse:0.34123	validation_1-rmse:0.43056
# [16]	validation_0-rmse:0.33625	validation_1-rmse:0.43153
# [17]	validation_0-rmse:0.33008	validation_1-rmse:0.43287
# [18]	validation_0-rmse:0.32400	validation_1-rmse:0.42460
# [19]	validation_0-rmse:0.32138	validation_1-rmse:0.42348
# [20]	validation_0-rmse:0.31674	validation_1-rmse:0.42724
# [21]	validation_0-rmse:0.31403	validation_1-rmse:0.42685
# [22]	validation_0-rmse:0.31129	validation_1-rmse:0.42400
# [23]	validation_0-rmse:0.30924	validation_1-rmse:0.42194
# [24]	validation_0-rmse:0.30675	validation_1-rmse:0.41962
# [25]	validation_0-rmse:0.30185	validation_1-rmse:0.42065
# [26]	validation_0-rmse:0.29916	validation_1-rmse:0.41893
# [27]	validation_0-rmse:0.29693	validation_1-rmse:0.41872
# [28]	validation_0-rmse:0.29174	validation_1-rmse:0.42011
# [29]	validation_0-rmse:0.28848	validation_1-rmse:0.41775
# [30]	validation_0-rmse:0.28475	validation_1-rmse:0.41642
# [31]	validation_0-rmse:0.28273	validation_1-rmse:0.41818
# [32]	validation_0-rmse:0.28155	validation_1-rmse:0.41743
# [33]	validation_0-rmse:0.27903	validation_1-rmse:0.41683
# [34]	validation_0-rmse:0.27804	validation_1-rmse:0.41592
# [35]	validation_0-rmse:0.27622	validation_1-rmse:0.41567
# [36]	validation_0-rmse:0.27426	validation_1-rmse:0.41534
# [37]	validation_0-rmse:0.27021	validation_1-rmse:0.41205
# [38]	validation_0-rmse:0.26494	validation_1-rmse:0.41274
# [39]	validation_0-rmse:0.26370	validation_1-rmse:0.41527
# [40]	validation_0-rmse:0.25983	validation_1-rmse:0.41152
# [41]	validation_0-rmse:0.25774	validation_1-rmse:0.41073
# [42]	validation_0-rmse:0.25470	validation_1-rmse:0.40717
# [43]	validation_0-rmse:0.25253	validation_1-rmse:0.40731
# [44]	validation_0-rmse:0.25051	validation_1-rmse:0.40625
# [45]	validation_0-rmse:0.24801	validation_1-rmse:0.40643
# [46]	validation_0-rmse:0.24681	validation_1-rmse:0.40454
# [47]	validation_0-rmse:0.24472	validation_1-rmse:0.40455
# [48]	validation_0-rmse:0.24250	validation_1-rmse:0.40604
# [49]	validation_0-rmse:0.24035	validation_1-rmse:0.40620
# [50]	validation_0-rmse:0.23826	validation_1-rmse:0.40707
# [51]	validation_0-rmse:0.23725	validation_1-rmse:0.40774
# [52]	validation_0-rmse:0.23588	validation_1-rmse:0.40851
# [53]	validation_0-rmse:0.23417	validation_1-rmse:0.40688
# [54]	validation_0-rmse:0.23208	validation_1-rmse:0.40598
# [55]	validation_0-rmse:0.22927	validation_1-rmse:0.40815
# [56]	validation_0-rmse:0.22879	validation_1-rmse:0.40751
# [57]	validation_0-rmse:0.22672	validation_1-rmse:0.40639
# [58]	validation_0-rmse:0.22471	validation_1-rmse:0.40987
# [59]	validation_0-rmse:0.22345	validation_1-rmse:0.40799
# [60]	validation_0-rmse:0.22323	validation_1-rmse:0.40772
# [61]	validation_0-rmse:0.22203	validation_1-rmse:0.40722
# [62]	validation_0-rmse:0.22026	validation_1-rmse:0.40730
# [63]	validation_0-rmse:0.21818	validation_1-rmse:0.40708
# [64]	validation_0-rmse:0.21634	validation_1-rmse:0.40778
# [65]	validation_0-rmse:0.21391	validation_1-rmse:0.40758
# [66]	validation_0-rmse:0.21330	validation_1-rmse:0.40831
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:0.87344	validation_1-rmse:0.84258
# [1]	validation_0-rmse:0.71814	validation_1-rmse:0.69451
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:0.62771	validation_1-rmse:0.61181
# [3]	validation_0-rmse:0.54957	validation_1-rmse:0.54300
# [4]	validation_0-rmse:0.48806	validation_1-rmse:0.49590
# [5]	validation_0-rmse:0.44873	validation_1-rmse:0.46323
# [6]	validation_0-rmse:0.42232	validation_1-rmse:0.44886
# [7]	validation_0-rmse:0.40263	validation_1-rmse:0.43782
# [8]	validation_0-rmse:0.39206	validation_1-rmse:0.43649
# [9]	validation_0-rmse:0.37828	validation_1-rmse:0.43642
# [10]	validation_0-rmse:0.37055	validation_1-rmse:0.43784
# [11]	validation_0-rmse:0.36135	validation_1-rmse:0.43409
# [12]	validation_0-rmse:0.35279	validation_1-rmse:0.42999
# [13]	validation_0-rmse:0.34778	validation_1-rmse:0.43068
# [14]	validation_0-rmse:0.34323	validation_1-rmse:0.42950
# [15]	validation_0-rmse:0.33805	validation_1-rmse:0.43036
# [16]	validation_0-rmse:0.33236	validation_1-rmse:0.42807
# [17]	validation_0-rmse:0.32724	validation_1-rmse:0.43051
# [18]	validation_0-rmse:0.32298	validation_1-rmse:0.42964
# [19]	validation_0-rmse:0.31662	validation_1-rmse:0.42752
# [20]	validation_0-rmse:0.31239	validation_1-rmse:0.42324
# [21]	validation_0-rmse:0.30737	validation_1-rmse:0.42442
# [22]	validation_0-rmse:0.30389	validation_1-rmse:0.42584
# [23]	validation_0-rmse:0.29980	validation_1-rmse:0.42659
# [24]	validation_0-rmse:0.29644	validation_1-rmse:0.42470
# [25]	validation_0-rmse:0.29059	validation_1-rmse:0.42722
# [26]	validation_0-rmse:0.28847	validation_1-rmse:0.42939
# [27]	validation_0-rmse:0.28674	validation_1-rmse:0.42958
# [28]	validation_0-rmse:0.28272	validation_1-rmse:0.42969
# [29]	validation_0-rmse:0.28022	validation_1-rmse:0.43339
# [30]	validation_0-rmse:0.27982	validation_1-rmse:0.43159
# [31]	validation_0-rmse:0.27479	validation_1-rmse:0.43239
# [32]	validation_0-rmse:0.27366	validation_1-rmse:0.43438
# [33]	validation_0-rmse:0.27072	validation_1-rmse:0.43472
# [34]	validation_0-rmse:0.26781	validation_1-rmse:0.43490
# [35]	validation_0-rmse:0.26729	validation_1-rmse:0.43587
# [36]	validation_0-rmse:0.26362	validation_1-rmse:0.43626
# [37]	validation_0-rmse:0.26124	validation_1-rmse:0.43584
# [38]	validation_0-rmse:0.25771	validation_1-rmse:0.43541
# [39]	validation_0-rmse:0.25522	validation_1-rmse:0.43550
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:0.85326	validation_1-rmse:0.89776
# [1]	validation_0-rmse:0.70514	validation_1-rmse:0.76106
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:0.61463	validation_1-rmse:0.67632
# [3]	validation_0-rmse:0.53948	validation_1-rmse:0.61086
# [4]	validation_0-rmse:0.48039	validation_1-rmse:0.56084
# [5]	validation_0-rmse:0.44156	validation_1-rmse:0.53311
# [6]	validation_0-rmse:0.41544	validation_1-rmse:0.51289
# [7]	validation_0-rmse:0.40032	validation_1-rmse:0.50045
# [8]	validation_0-rmse:0.39119	validation_1-rmse:0.49808
# [9]	validation_0-rmse:0.38312	validation_1-rmse:0.49043
# [10]	validation_0-rmse:0.37581	validation_1-rmse:0.48713
# [11]	validation_0-rmse:0.36736	validation_1-rmse:0.48025
# [12]	validation_0-rmse:0.35761	validation_1-rmse:0.47897
# [13]	validation_0-rmse:0.35141	validation_1-rmse:0.47853
# [14]	validation_0-rmse:0.34450	validation_1-rmse:0.47877
# [15]	validation_0-rmse:0.33970	validation_1-rmse:0.47862
# [16]	validation_0-rmse:0.33300	validation_1-rmse:0.47857
# [17]	validation_0-rmse:0.33006	validation_1-rmse:0.47906
# [18]	validation_0-rmse:0.32523	validation_1-rmse:0.47552
# [19]	validation_0-rmse:0.31927	validation_1-rmse:0.47354
# [20]	validation_0-rmse:0.31636	validation_1-rmse:0.47370
# [21]	validation_0-rmse:0.31218	validation_1-rmse:0.47138
# [22]	validation_0-rmse:0.30796	validation_1-rmse:0.46865
# [23]	validation_0-rmse:0.30504	validation_1-rmse:0.46960
# [24]	validation_0-rmse:0.30283	validation_1-rmse:0.46947
# [25]	validation_0-rmse:0.29733	validation_1-rmse:0.46757
# [26]	validation_0-rmse:0.29392	validation_1-rmse:0.46607
# [27]	validation_0-rmse:0.29206	validation_1-rmse:0.46382
# [28]	validation_0-rmse:0.28913	validation_1-rmse:0.46157
# [29]	validation_0-rmse:0.28705	validation_1-rmse:0.46235
# [30]	validation_0-rmse:0.28326	validation_1-rmse:0.46354
# [31]	validation_0-rmse:0.27962	validation_1-rmse:0.46359
# [32]	validation_0-rmse:0.27774	validation_1-rmse:0.46451
# [33]	validation_0-rmse:0.27309	validation_1-rmse:0.46190
# [34]	validation_0-rmse:0.26958	validation_1-rmse:0.46104
# [35]	validation_0-rmse:0.26686	validation_1-rmse:0.46066
# [36]	validation_0-rmse:0.26551	validation_1-rmse:0.46258
# [37]	validation_0-rmse:0.26238	validation_1-rmse:0.46273
# [38]	validation_0-rmse:0.25852	validation_1-rmse:0.46517
# [39]	validation_0-rmse:0.25478	validation_1-rmse:0.46602
# [40]	validation_0-rmse:0.25408	validation_1-rmse:0.46639
# [41]	validation_0-rmse:0.25267	validation_1-rmse:0.46366
# [42]	validation_0-rmse:0.25063	validation_1-rmse:0.46466
# [43]	validation_0-rmse:0.24802	validation_1-rmse:0.46491
# [44]	validation_0-rmse:0.24684	validation_1-rmse:0.46424
# [45]	validation_0-rmse:0.24540	validation_1-rmse:0.46394
# [46]	validation_0-rmse:0.24390	validation_1-rmse:0.46664
# [47]	validation_0-rmse:0.23983	validation_1-rmse:0.46587
# [48]	validation_0-rmse:0.23525	validation_1-rmse:0.46650
# [49]	validation_0-rmse:0.23394	validation_1-rmse:0.46664
# [50]	validation_0-rmse:0.23328	validation_1-rmse:0.46655
# [51]	validation_0-rmse:0.23149	validation_1-rmse:0.46722
# [52]	validation_0-rmse:0.22940	validation_1-rmse:0.46789
# [53]	validation_0-rmse:0.22666	validation_1-rmse:0.46814
# [54]	validation_0-rmse:0.22495	validation_1-rmse:0.46571
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:0.87355	validation_1-rmse:0.83542
# [1]	validation_0-rmse:0.72452	validation_1-rmse:0.69747
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:0.63205	validation_1-rmse:0.62202
# [3]	validation_0-rmse:0.55610	validation_1-rmse:0.56218
# [4]	validation_0-rmse:0.49240	validation_1-rmse:0.52190
# [5]	validation_0-rmse:0.45075	validation_1-rmse:0.50081
# [6]	validation_0-rmse:0.42358	validation_1-rmse:0.49011
# [7]	validation_0-rmse:0.40279	validation_1-rmse:0.47466
# [8]	validation_0-rmse:0.39194	validation_1-rmse:0.47370
# [9]	validation_0-rmse:0.38123	validation_1-rmse:0.46489
# [10]	validation_0-rmse:0.37373	validation_1-rmse:0.46458
# [11]	validation_0-rmse:0.36463	validation_1-rmse:0.46145
# [12]	validation_0-rmse:0.35806	validation_1-rmse:0.46094
# [13]	validation_0-rmse:0.35335	validation_1-rmse:0.45935
# [14]	validation_0-rmse:0.34924	validation_1-rmse:0.45881
# [15]	validation_0-rmse:0.34219	validation_1-rmse:0.45763
# [16]	validation_0-rmse:0.33934	validation_1-rmse:0.45657
# [17]	validation_0-rmse:0.33478	validation_1-rmse:0.45499
# [18]	validation_0-rmse:0.33062	validation_1-rmse:0.44886
# [19]	validation_0-rmse:0.32788	validation_1-rmse:0.44940
# [20]	validation_0-rmse:0.32248	validation_1-rmse:0.44637
# [21]	validation_0-rmse:0.31823	validation_1-rmse:0.44394
# [22]	validation_0-rmse:0.31286	validation_1-rmse:0.44338
# [23]	validation_0-rmse:0.31066	validation_1-rmse:0.44588
# [24]	validation_0-rmse:0.30467	validation_1-rmse:0.45085
# [25]	validation_0-rmse:0.30208	validation_1-rmse:0.45098
# [26]	validation_0-rmse:0.29958	validation_1-rmse:0.44975
# [27]	validation_0-rmse:0.29302	validation_1-rmse:0.45205
# [28]	validation_0-rmse:0.28943	validation_1-rmse:0.45199
# [29]	validation_0-rmse:0.28655	validation_1-rmse:0.45115
# [30]	validation_0-rmse:0.28407	validation_1-rmse:0.45271
# [31]	validation_0-rmse:0.28285	validation_1-rmse:0.45197
# [32]	validation_0-rmse:0.27981	validation_1-rmse:0.45180
# [33]	validation_0-rmse:0.27870	validation_1-rmse:0.45181
# [34]	validation_0-rmse:0.27586	validation_1-rmse:0.45368
# [35]	validation_0-rmse:0.27419	validation_1-rmse:0.45294
# [36]	validation_0-rmse:0.27219	validation_1-rmse:0.45240
# [37]	validation_0-rmse:0.26763	validation_1-rmse:0.45183
# [38]	validation_0-rmse:0.26478	validation_1-rmse:0.45420
# [39]	validation_0-rmse:0.26274	validation_1-rmse:0.45503
# [40]	validation_0-rmse:0.26011	validation_1-rmse:0.45520
# [41]	validation_0-rmse:0.25746	validation_1-rmse:0.45705
# [42]	validation_0-rmse:0.25416	validation_1-rmse:0.45730
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:0.85730	validation_1-rmse:0.91172
# [1]	validation_0-rmse:0.70914	validation_1-rmse:0.76908
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:0.62142	validation_1-rmse:0.68607
# [3]	validation_0-rmse:0.54633	validation_1-rmse:0.61565
# [4]	validation_0-rmse:0.49188	validation_1-rmse:0.55339
# [5]	validation_0-rmse:0.45171	validation_1-rmse:0.51631
# [6]	validation_0-rmse:0.42613	validation_1-rmse:0.48779
# [7]	validation_0-rmse:0.40828	validation_1-rmse:0.47079
# [8]	validation_0-rmse:0.39607	validation_1-rmse:0.46744
# [9]	validation_0-rmse:0.38446	validation_1-rmse:0.45966
# [10]	validation_0-rmse:0.37647	validation_1-rmse:0.45699
# [11]	validation_0-rmse:0.36969	validation_1-rmse:0.45016
# [12]	validation_0-rmse:0.36259	validation_1-rmse:0.44321
# [13]	validation_0-rmse:0.35833	validation_1-rmse:0.43842
# [14]	validation_0-rmse:0.35269	validation_1-rmse:0.43749
# [15]	validation_0-rmse:0.34987	validation_1-rmse:0.43600
# [16]	validation_0-rmse:0.34410	validation_1-rmse:0.42846
# [17]	validation_0-rmse:0.34185	validation_1-rmse:0.42449
# [18]	validation_0-rmse:0.33880	validation_1-rmse:0.42301
# [19]	validation_0-rmse:0.33332	validation_1-rmse:0.42310
# [20]	validation_0-rmse:0.32688	validation_1-rmse:0.41782
# [21]	validation_0-rmse:0.32438	validation_1-rmse:0.41682
# [22]	validation_0-rmse:0.32036	validation_1-rmse:0.41429
# [23]	validation_0-rmse:0.31742	validation_1-rmse:0.41504
# [24]	validation_0-rmse:0.31477	validation_1-rmse:0.41202
# [25]	validation_0-rmse:0.31106	validation_1-rmse:0.40978
# [26]	validation_0-rmse:0.30948	validation_1-rmse:0.40883
# [27]	validation_0-rmse:0.30655	validation_1-rmse:0.40724
# [28]	validation_0-rmse:0.30444	validation_1-rmse:0.40508
# [29]	validation_0-rmse:0.29987	validation_1-rmse:0.40224
# [30]	validation_0-rmse:0.29686	validation_1-rmse:0.40067
# [31]	validation_0-rmse:0.29584	validation_1-rmse:0.40092
# [32]	validation_0-rmse:0.29101	validation_1-rmse:0.39741
# [33]	validation_0-rmse:0.28741	validation_1-rmse:0.39801
# [34]	validation_0-rmse:0.28252	validation_1-rmse:0.40135
# [35]	validation_0-rmse:0.28001	validation_1-rmse:0.39840
# [36]	validation_0-rmse:0.27711	validation_1-rmse:0.39262
# [37]	validation_0-rmse:0.27434	validation_1-rmse:0.39045
# [38]	validation_0-rmse:0.27182	validation_1-rmse:0.38931
# [39]	validation_0-rmse:0.26877	validation_1-rmse:0.38620
# [40]	validation_0-rmse:0.26707	validation_1-rmse:0.38822
# [41]	validation_0-rmse:0.26409	validation_1-rmse:0.38571
# [42]	validation_0-rmse:0.26125	validation_1-rmse:0.38543
# [43]	validation_0-rmse:0.25633	validation_1-rmse:0.38458
# [44]	validation_0-rmse:0.25491	validation_1-rmse:0.38460
# [45]	validation_0-rmse:0.25167	validation_1-rmse:0.38322
# [46]	validation_0-rmse:0.25070	validation_1-rmse:0.38153
# [47]	validation_0-rmse:0.24665	validation_1-rmse:0.38330
# [48]	validation_0-rmse:0.24328	validation_1-rmse:0.38159
# [49]	validation_0-rmse:0.24223	validation_1-rmse:0.38324
# [50]	validation_0-rmse:0.24070	validation_1-rmse:0.38316
# ...
# [29]	validation_0-rmse:0.29160	validation_1-rmse:0.41177
# [30]	validation_0-rmse:0.28813	validation_1-rmse:0.41593
# [31]	validation_0-rmse:0.28500	validation_1-rmse:0.41334
# [32]	validation_0-rmse:0.28082	validation_1-rmse:0.41033
# [33]	validation_0-rmse:0.27819	validation_1-rmse:0.40771
# [34]	validation_0-rmse:0.27433	validation_1-rmse:0.40739
# [35]	validation_0-rmse:0.27165	validation_1-rmse:0.40691
# [36]	validation_0-rmse:0.26944	validation_1-rmse:0.40686
# [37]	validation_0-rmse:0.26776	validation_1-rmse:0.40518
# [38]	validation_0-rmse:0.26606	validation_1-rmse:0.40553
# [39]	validation_0-rmse:0.26399	validation_1-rmse:0.40675
# [40]	validation_0-rmse:0.26205	validation_1-rmse:0.40788
# [41]	validation_0-rmse:0.26045	validation_1-rmse:0.40877
# [42]	validation_0-rmse:0.25766	validation_1-rmse:0.40835
# [43]	validation_0-rmse:0.25523	validation_1-rmse:0.40901
# [44]	validation_0-rmse:0.25246	validation_1-rmse:0.40761
# [45]	validation_0-rmse:0.24923	validation_1-rmse:0.40673
# [46]	validation_0-rmse:0.24812	validation_1-rmse:0.40559
# [47]	validation_0-rmse:0.24484	validation_1-rmse:0.40592
# [48]	validation_0-rmse:0.24249	validation_1-rmse:0.40911
# [49]	validation_0-rmse:0.24009	validation_1-rmse:0.41034
# [50]	validation_0-rmse:0.23710	validation_1-rmse:0.40902
# [51]	validation_0-rmse:0.23577	validation_1-rmse:0.40800
# [52]	validation_0-rmse:0.23496	validation_1-rmse:0.40785
# [53]	validation_0-rmse:0.23271	validation_1-rmse:0.40726
# [54]	validation_0-rmse:0.23053	validation_1-rmse:0.40584
# [55]	validation_0-rmse:0.22834	validation_1-rmse:0.40591
# [56]	validation_0-rmse:0.22609	validation_1-rmse:0.40800
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:0.86677	validation_1-rmse:0.86526
# [1]	validation_0-rmse:0.71946	validation_1-rmse:0.73470
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:0.62657	validation_1-rmse:0.64970
# [3]	validation_0-rmse:0.54908	validation_1-rmse:0.57909
# [4]	validation_0-rmse:0.48946	validation_1-rmse:0.52562
# [5]	validation_0-rmse:0.44980	validation_1-rmse:0.49476
# [6]	validation_0-rmse:0.42560	validation_1-rmse:0.47724
# [7]	validation_0-rmse:0.40479	validation_1-rmse:0.46363
# [8]	validation_0-rmse:0.39297	validation_1-rmse:0.46064
# [9]	validation_0-rmse:0.38075	validation_1-rmse:0.45417
# [10]	validation_0-rmse:0.37354	validation_1-rmse:0.45171
# [11]	validation_0-rmse:0.36585	validation_1-rmse:0.45084
# [12]	validation_0-rmse:0.36282	validation_1-rmse:0.45383
# [13]	validation_0-rmse:0.35694	validation_1-rmse:0.45622
# [14]	validation_0-rmse:0.35216	validation_1-rmse:0.45721
# [15]	validation_0-rmse:0.34880	validation_1-rmse:0.45700
# [16]	validation_0-rmse:0.34303	validation_1-rmse:0.45579
# [17]	validation_0-rmse:0.33604	validation_1-rmse:0.45203
# [18]	validation_0-rmse:0.33188	validation_1-rmse:0.45172
# [19]	validation_0-rmse:0.32697	validation_1-rmse:0.45311
# [20]	validation_0-rmse:0.32390	validation_1-rmse:0.44961
# [21]	validation_0-rmse:0.31988	validation_1-rmse:0.44799
# [22]	validation_0-rmse:0.31762	validation_1-rmse:0.44940
# [23]	validation_0-rmse:0.31394	validation_1-rmse:0.44774
# [24]	validation_0-rmse:0.31224	validation_1-rmse:0.44905
# [25]	validation_0-rmse:0.30812	validation_1-rmse:0.44870
# [26]	validation_0-rmse:0.30543	validation_1-rmse:0.44535
# [27]	validation_0-rmse:0.30116	validation_1-rmse:0.44572
# [28]	validation_0-rmse:0.29969	validation_1-rmse:0.44645
# [29]	validation_0-rmse:0.29567	validation_1-rmse:0.44580
# [30]	validation_0-rmse:0.29163	validation_1-rmse:0.44352
# [31]	validation_0-rmse:0.28792	validation_1-rmse:0.44122
# [32]	validation_0-rmse:0.28580	validation_1-rmse:0.44173
# [33]	validation_0-rmse:0.28303	validation_1-rmse:0.44001
# [34]	validation_0-rmse:0.27954	validation_1-rmse:0.43801
# [35]	validation_0-rmse:0.27653	validation_1-rmse:0.43720
# [36]	validation_0-rmse:0.27463	validation_1-rmse:0.43881
# [37]	validation_0-rmse:0.26973	validation_1-rmse:0.43814
# [38]	validation_0-rmse:0.26725	validation_1-rmse:0.43429
# [39]	validation_0-rmse:0.26608	validation_1-rmse:0.43146
# [40]	validation_0-rmse:0.26422	validation_1-rmse:0.43101
# [41]	validation_0-rmse:0.26307	validation_1-rmse:0.43070
# [42]	validation_0-rmse:0.26180	validation_1-rmse:0.43170
# [43]	validation_0-rmse:0.25906	validation_1-rmse:0.43066
# [44]	validation_0-rmse:0.25641	validation_1-rmse:0.43103
# [45]	validation_0-rmse:0.25534	validation_1-rmse:0.42973
# [46]	validation_0-rmse:0.25238	validation_1-rmse:0.42990
# [47]	validation_0-rmse:0.24800	validation_1-rmse:0.42852
# [48]	validation_0-rmse:0.24615	validation_1-rmse:0.42783
# [49]	validation_0-rmse:0.24292	validation_1-rmse:0.42592
# [50]	validation_0-rmse:0.23944	validation_1-rmse:0.42547
# [51]	validation_0-rmse:0.23862	validation_1-rmse:0.42655
# [52]	validation_0-rmse:0.23662	validation_1-rmse:0.42791
# [53]	validation_0-rmse:0.23536	validation_1-rmse:0.42744
# [54]	validation_0-rmse:0.23442	validation_1-rmse:0.42548
# [55]	validation_0-rmse:0.23233	validation_1-rmse:0.42511
# [56]	validation_0-rmse:0.23103	validation_1-rmse:0.42447
# [57]	validation_0-rmse:0.22746	validation_1-rmse:0.42634
# [58]	validation_0-rmse:0.22481	validation_1-rmse:0.42665
# [59]	validation_0-rmse:0.22311	validation_1-rmse:0.42670
# [60]	validation_0-rmse:0.22148	validation_1-rmse:0.42515
# [61]	validation_0-rmse:0.22009	validation_1-rmse:0.42404
# [62]	validation_0-rmse:0.21623	validation_1-rmse:0.42425
# [63]	validation_0-rmse:0.21390	validation_1-rmse:0.42323
# [64]	validation_0-rmse:0.21262	validation_1-rmse:0.42476
# [65]	validation_0-rmse:0.21143	validation_1-rmse:0.42380
# [66]	validation_0-rmse:0.20891	validation_1-rmse:0.42430
# [67]	validation_0-rmse:0.20808	validation_1-rmse:0.42403
# [68]	validation_0-rmse:0.20580	validation_1-rmse:0.42367
# [69]	validation_0-rmse:0.20354	validation_1-rmse:0.42466
# [70]	validation_0-rmse:0.20315	validation_1-rmse:0.42477
# [71]	validation_0-rmse:0.20166	validation_1-rmse:0.42475
# [72]	validation_0-rmse:0.20139	validation_1-rmse:0.42420
# [73]	validation_0-rmse:0.20003	validation_1-rmse:0.42378
# [74]	validation_0-rmse:0.19855	validation_1-rmse:0.42340
# [75]	validation_0-rmse:0.19697	validation_1-rmse:0.42494
# [76]	validation_0-rmse:0.19392	validation_1-rmse:0.42300
# [77]	validation_0-rmse:0.19271	validation_1-rmse:0.42283
# [78]	validation_0-rmse:0.19126	validation_1-rmse:0.42460
# [79]	validation_0-rmse:0.19032	validation_1-rmse:0.42598
# [80]	validation_0-rmse:0.18958	validation_1-rmse:0.42630
# [81]	validation_0-rmse:0.18868	validation_1-rmse:0.42764
# [82]	validation_0-rmse:0.18768	validation_1-rmse:0.42768
# [83]	validation_0-rmse:0.18676	validation_1-rmse:0.42732
# [84]	validation_0-rmse:0.18589	validation_1-rmse:0.42767
# [85]	validation_0-rmse:0.18523	validation_1-rmse:0.42833
# [86]	validation_0-rmse:0.18387	validation_1-rmse:0.42796
# [87]	validation_0-rmse:0.18269	validation_1-rmse:0.42876
# [88]	validation_0-rmse:0.18134	validation_1-rmse:0.42902
# [89]	validation_0-rmse:0.18084	validation_1-rmse:0.42833
# [90]	validation_0-rmse:0.18005	validation_1-rmse:0.42917
# [91]	validation_0-rmse:0.17959	validation_1-rmse:0.42823
# [92]	validation_0-rmse:0.17808	validation_1-rmse:0.42645
# [93]	validation_0-rmse:0.17699	validation_1-rmse:0.42544
# [94]	validation_0-rmse:0.17485	validation_1-rmse:0.42569
# [95]	validation_0-rmse:0.17372	validation_1-rmse:0.42537
# [96]	validation_0-rmse:0.17301	validation_1-rmse:0.42384
# [97]	validation_0-rmse:0.17089	validation_1-rmse:0.42441
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:0.87797	validation_1-rmse:0.84649
# [1]	validation_0-rmse:0.72139	validation_1-rmse:0.72650
# [2]	validation_0-rmse:0.63125	validation_1-rmse:0.65466
# [3]	validation_0-rmse:0.55427	validation_1-rmse:0.59852
# [4]	validation_0-rmse:0.49482	validation_1-rmse:0.53703
# [5]	validation_0-rmse:0.45439	validation_1-rmse:0.49563
# [6]	validation_0-rmse:0.43014	validation_1-rmse:0.48114
# [7]	validation_0-rmse:0.41575	validation_1-rmse:0.47301
# [8]	validation_0-rmse:0.40696	validation_1-rmse:0.47374
# [9]	validation_0-rmse:0.39605	validation_1-rmse:0.46846
# [10]	validation_0-rmse:0.38846	validation_1-rmse:0.46943
# [11]	validation_0-rmse:0.37809	validation_1-rmse:0.46309
# [12]	validation_0-rmse:0.37050	validation_1-rmse:0.45685
# [13]	validation_0-rmse:0.36161	validation_1-rmse:0.45225
# [14]	validation_0-rmse:0.35324	validation_1-rmse:0.45394
# [15]	validation_0-rmse:0.34543	validation_1-rmse:0.45206
# [16]	validation_0-rmse:0.34173	validation_1-rmse:0.45268
# [17]	validation_0-rmse:0.33931	validation_1-rmse:0.45334
# [18]	validation_0-rmse:0.33416	validation_1-rmse:0.45066
# [19]	validation_0-rmse:0.32788	validation_1-rmse:0.45074
# [20]	validation_0-rmse:0.32070	validation_1-rmse:0.45275
# [21]	validation_0-rmse:0.31855	validation_1-rmse:0.45207
# [22]	validation_0-rmse:0.31601	validation_1-rmse:0.45355
# [23]	validation_0-rmse:0.31451	validation_1-rmse:0.45197
# [24]	validation_0-rmse:0.31185	validation_1-rmse:0.44665
# [25]	validation_0-rmse:0.30828	validation_1-rmse:0.44991
# [26]	validation_0-rmse:0.30449	validation_1-rmse:0.44895
# [27]	validation_0-rmse:0.29966	validation_1-rmse:0.44470
# [28]	validation_0-rmse:0.29703	validation_1-rmse:0.44611
# [29]	validation_0-rmse:0.29317	validation_1-rmse:0.44277
# [30]	validation_0-rmse:0.29083	validation_1-rmse:0.44223
# [31]	validation_0-rmse:0.28867	validation_1-rmse:0.44233
# [32]	validation_0-rmse:0.28469	validation_1-rmse:0.44267
# [33]	validation_0-rmse:0.28098	validation_1-rmse:0.44619
# [34]	validation_0-rmse:0.27842	validation_1-rmse:0.44956
# [35]	validation_0-rmse:0.27572	validation_1-rmse:0.45044
# [36]	validation_0-rmse:0.27434	validation_1-rmse:0.44700
# [37]	validation_0-rmse:0.27100	validation_1-rmse:0.44956
# [38]	validation_0-rmse:0.26896	validation_1-rmse:0.44565
# [39]	validation_0-rmse:0.26710	validation_1-rmse:0.44220
# [40]	validation_0-rmse:0.26593	validation_1-rmse:0.44415
# [41]	validation_0-rmse:0.26252	validation_1-rmse:0.44279
# [42]	validation_0-rmse:0.26062	validation_1-rmse:0.44055
# [43]	validation_0-rmse:0.25620	validation_1-rmse:0.44103
# [44]	validation_0-rmse:0.25364	validation_1-rmse:0.44132
# [45]	validation_0-rmse:0.25243	validation_1-rmse:0.44094
# [46]	validation_0-rmse:0.24963	validation_1-rmse:0.43954
# [47]	validation_0-rmse:0.24822	validation_1-rmse:0.43797
# [48]	validation_0-rmse:0.24574	validation_1-rmse:0.43801
# [49]	validation_0-rmse:0.24440	validation_1-rmse:0.43907
# [50]	validation_0-rmse:0.24251	validation_1-rmse:0.44008
# [51]	validation_0-rmse:0.24119	validation_1-rmse:0.44257
# [52]	validation_0-rmse:0.23949	validation_1-rmse:0.44226
# [53]	validation_0-rmse:0.23715	validation_1-rmse:0.44262
# [54]	validation_0-rmse:0.23449	validation_1-rmse:0.44121
# [55]	validation_0-rmse:0.23263	validation_1-rmse:0.43942
# [56]	validation_0-rmse:0.23186	validation_1-rmse:0.43879
# [57]	validation_0-rmse:0.23021	validation_1-rmse:0.43722
# [58]	validation_0-rmse:0.22891	validation_1-rmse:0.43776
# [59]	validation_0-rmse:0.22668	validation_1-rmse:0.43815
# [60]	validation_0-rmse:0.22556	validation_1-rmse:0.43819
# [61]	validation_0-rmse:0.22385	validation_1-rmse:0.43799
# [62]	validation_0-rmse:0.22170	validation_1-rmse:0.43843
# [63]	validation_0-rmse:0.21873	validation_1-rmse:0.44019
# [64]	validation_0-rmse:0.21646	validation_1-rmse:0.43946
# [65]	validation_0-rmse:0.21493	validation_1-rmse:0.43921
# [66]	validation_0-rmse:0.21376	validation_1-rmse:0.43847
# [67]	validation_0-rmse:0.21254	validation_1-rmse:0.44010
# [68]	validation_0-rmse:0.21040	validation_1-rmse:0.43877
# [69]	validation_0-rmse:0.20803	validation_1-rmse:0.43626
# [70]	validation_0-rmse:0.20617	validation_1-rmse:0.43636
# [71]	validation_0-rmse:0.20411	validation_1-rmse:0.43678
# [72]	validation_0-rmse:0.20338	validation_1-rmse:0.43762
# [73]	validation_0-rmse:0.20227	validation_1-rmse:0.43741
# [74]	validation_0-rmse:0.20045	validation_1-rmse:0.43811
# [75]	validation_0-rmse:0.19842	validation_1-rmse:0.43879
# [76]	validation_0-rmse:0.19635	validation_1-rmse:0.43629
# [77]	validation_0-rmse:0.19510	validation_1-rmse:0.43573
# [78]	validation_0-rmse:0.19383	validation_1-rmse:0.43618
# [79]	validation_0-rmse:0.19298	validation_1-rmse:0.43600
# [80]	validation_0-rmse:0.19215	validation_1-rmse:0.43615
# [81]	validation_0-rmse:0.19131	validation_1-rmse:0.43630
# [82]	validation_0-rmse:0.19007	validation_1-rmse:0.43576
# [83]	validation_0-rmse:0.18935	validation_1-rmse:0.43586
# [84]	validation_0-rmse:0.18659	validation_1-rmse:0.43420
# [85]	validation_0-rmse:0.18565	validation_1-rmse:0.43461
# [86]	validation_0-rmse:0.18475	validation_1-rmse:0.43446
# [87]	validation_0-rmse:0.18346	validation_1-rmse:0.43566
# [88]	validation_0-rmse:0.18197	validation_1-rmse:0.43704
# [89]	validation_0-rmse:0.18136	validation_1-rmse:0.43662
# [90]	validation_0-rmse:0.18033	validation_1-rmse:0.43636
# [91]	validation_0-rmse:0.17892	validation_1-rmse:0.43578
# [92]	validation_0-rmse:0.17688	validation_1-rmse:0.43721
# [93]	validation_0-rmse:0.17601	validation_1-rmse:0.43855
# [94]	validation_0-rmse:0.17492	validation_1-rmse:0.43788
# [95]	validation_0-rmse:0.17365	validation_1-rmse:0.43851
# [96]	validation_0-rmse:0.17253	validation_1-rmse:0.43915
# [97]	validation_0-rmse:0.17130	validation_1-rmse:0.43598
# [98]	validation_0-rmse:0.16974	validation_1-rmse:0.43465
# [99]	validation_0-rmse:0.16959	validation_1-rmse:0.43456
# [100]	validation_0-rmse:0.16832	validation_1-rmse:0.43412
# [101]	validation_0-rmse:0.16711	validation_1-rmse:0.43424
# [102]	validation_0-rmse:0.16579	validation_1-rmse:0.43564
# [103]	validation_0-rmse:0.16490	validation_1-rmse:0.43575
# [104]	validation_0-rmse:0.16315	validation_1-rmse:0.43582
# [105]	validation_0-rmse:0.16282	validation_1-rmse:0.43577
# [106]	validation_0-rmse:0.16226	validation_1-rmse:0.43535
# [107]	validation_0-rmse:0.16168	validation_1-rmse:0.43507
# [108]	validation_0-rmse:0.16018	validation_1-rmse:0.43432
# [109]	validation_0-rmse:0.15955	validation_1-rmse:0.43453
# [110]	validation_0-rmse:0.15861	validation_1-rmse:0.43554
# [111]	validation_0-rmse:0.15753	validation_1-rmse:0.43507
# [112]	validation_0-rmse:0.15605	validation_1-rmse:0.43506
# [113]	validation_0-rmse:0.15462	validation_1-rmse:0.43385
# [114]	validation_0-rmse:0.15355	validation_1-rmse:0.43496
# [115]	validation_0-rmse:0.15313	validation_1-rmse:0.43456
# [116]	validation_0-rmse:0.15222	validation_1-rmse:0.43600
# [117]	validation_0-rmse:0.15146	validation_1-rmse:0.43611
# [118]	validation_0-rmse:0.15036	validation_1-rmse:0.43517
# [119]	validation_0-rmse:0.14972	validation_1-rmse:0.43527
# [120]	validation_0-rmse:0.14866	validation_1-rmse:0.43547
# [121]	validation_0-rmse:0.14823	validation_1-rmse:0.43437
# [122]	validation_0-rmse:0.14785	validation_1-rmse:0.43490
# [123]	validation_0-rmse:0.14706	validation_1-rmse:0.43472
# [124]	validation_0-rmse:0.14662	validation_1-rmse:0.43529
# [125]	validation_0-rmse:0.14583	validation_1-rmse:0.43535
# [126]	validation_0-rmse:0.14499	validation_1-rmse:0.43475
# [127]	validation_0-rmse:0.14355	validation_1-rmse:0.43529
# [128]	validation_0-rmse:0.14265	validation_1-rmse:0.43550
# [129]	validation_0-rmse:0.14139	validation_1-rmse:0.43557
# [130]	validation_0-rmse:0.14044	validation_1-rmse:0.43569
# [131]	validation_0-rmse:0.13962	validation_1-rmse:0.43533
# [132]	validation_0-rmse:0.13821	validation_1-rmse:0.43621
# [133]	validation_0-rmse:0.13748	validation_1-rmse:0.43657
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['16%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-2, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.608
# Uncertainty
# a0: 0.536+/-0.025
# a1: 0.6081+/-0.016

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: BA_sq_m_ha: mean - 0.266, median - 0.269, CI - [0.248-0.284]
#
# SHAP-values for: DBH_cm: mean - 0.084, median - 0.085, CI - [0.062-0.104]
#
# SHAP-values for: H_m: mean - 0.143, median - 0.144, CI - [0.119-0.164]
#
# SHAP-values for: Origin_ID: mean - 0.063, median - 0.063, CI - [0.055-0.071]
#
# SHAP-values for: Species_ID: mean - 0.233, median - 0.233, CI - [0.224-0.243]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['BA_sq_m_ha', 'Species_ID', 'H_m', 'DBH_cm', 'Origin_ID'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 56.55, median: 53.0,
#  pred. interval (P(0.025)-P(0.975)): 13.0-151.1,
#  conf. interval (p-value=0.95): 25.113-83.715
# ***
# Aggregate bias statistic:
#  mean: 0.002, median: -0.001,
#  pred. interval (P(0.025)-P(0.975)): -0.06-0.077,
#  conf. interval (p-value=0.95): -0.033-0.033
# ***
# Aggregate RMSE statistic:
#  mean: 0.419, median: 0.414, pred. interval (P(0.025)-P(0.975)): 0.352-0.494,
#  conf. interval (p-value=0.95): 0.387-0.457
# ***
# Aggregate MSE statistic:
#  mean: 0.177, median: 0.172, pred. interval (P(0.025)-P(0.975)): 0.124-0.244,
#  conf. interval (p-value=0.95): 0.15-0.209
# ***
# Aggregate R^2 statistic:
#  mean: 0.605, median: 0.605, pred. interval (P(0.025)-P(0.975)): 0.489-0.709,
#  conf. interval (p-value=0.95): 0.557-0.653
# ***
# Aggregate bias(%) statistic:
#  mean: 0.191, median: -0.001, pred. interval (P(0.025)-P(0.975)): -4.531-5.892,
#  conf. interval (p-value=0.95): -2.313-2.551
# ***
# Aggregate RMSE(%) statistic:
#  mean: 30.836, median: 30.627, pred. interval (P(0.025)-P(0.975)): 24.846-37.823,
#  conf. interval (p-value=0.95): 27.798-34.05
# ***

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:0.86536
# [1]	validation_0-rmse:0.73088
# [2]	validation_0-rmse:0.62140
# [3]	validation_0-rmse:0.54470
# [4]	validation_0-rmse:0.49127
# [5]	validation_0-rmse:0.45696
# [6]	validation_0-rmse:0.42882
# [7]	validation_0-rmse:0.41355
# [8]	validation_0-rmse:0.39490
# [9]	validation_0-rmse:0.38401
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [10]	validation_0-rmse:0.37339
# [11]	validation_0-rmse:0.36800
# [12]	validation_0-rmse:0.36120
# [13]	validation_0-rmse:0.35601
# [14]	validation_0-rmse:0.34739
# [15]	validation_0-rmse:0.34374
# [16]	validation_0-rmse:0.34124
# [17]	validation_0-rmse:0.33899
# [18]	validation_0-rmse:0.33534
# [19]	validation_0-rmse:0.33078
# [20]	validation_0-rmse:0.32696
# [21]	validation_0-rmse:0.32410
# [22]	validation_0-rmse:0.32242
# [23]	validation_0-rmse:0.31665
# [24]	validation_0-rmse:0.31511
# [25]	validation_0-rmse:0.31335
# [26]	validation_0-rmse:0.31193
# [27]	validation_0-rmse:0.30847
# [28]	validation_0-rmse:0.30764
# [29]	validation_0-rmse:0.30644
# [30]	validation_0-rmse:0.30283
# [31]	validation_0-rmse:0.29986
# [32]	validation_0-rmse:0.29724
# [33]	validation_0-rmse:0.29547
# [34]	validation_0-rmse:0.29270
# [35]	validation_0-rmse:0.29110
# [36]	validation_0-rmse:0.28813
# [37]	validation_0-rmse:0.28675
# [38]	validation_0-rmse:0.28469
# [39]	validation_0-rmse:0.28307
# [40]	validation_0-rmse:0.27905
# [41]	validation_0-rmse:0.27831
# [42]	validation_0-rmse:0.27578
# [43]	validation_0-rmse:0.27322
# [44]	validation_0-rmse:0.27193
# [45]	validation_0-rmse:0.27053
# [46]	validation_0-rmse:0.26836
# [47]	validation_0-rmse:0.26637
# [48]	validation_0-rmse:0.26498
# [49]	validation_0-rmse:0.26241
# [50]	validation_0-rmse:0.25979
# [51]	validation_0-rmse:0.25764
# [52]	validation_0-rmse:0.25410
# [53]	validation_0-rmse:0.25170
# [54]	validation_0-rmse:0.24878
# [55]	validation_0-rmse:0.24606
# [56]	validation_0-rmse:0.24396
# [57]	validation_0-rmse:0.24200
# [58]	validation_0-rmse:0.23946
# [59]	validation_0-rmse:0.23810
# [60]	validation_0-rmse:0.23619
# [61]	validation_0-rmse:0.23423
# [62]	validation_0-rmse:0.23200
# [63]	validation_0-rmse:0.23029
# [64]	validation_0-rmse:0.22841
# [65]	validation_0-rmse:0.22726
# [66]	validation_0-rmse:0.22541
# [67]	validation_0-rmse:0.22416
# [68]	validation_0-rmse:0.22308
# [69]	validation_0-rmse:0.22185
# [70]	validation_0-rmse:0.22004
# [71]	validation_0-rmse:0.21928
# [72]	validation_0-rmse:0.21835
# [73]	validation_0-rmse:0.21707
# [74]	validation_0-rmse:0.21585
# [75]	validation_0-rmse:0.21463
# [76]	validation_0-rmse:0.21340
# [77]	validation_0-rmse:0.21212
# [78]	validation_0-rmse:0.21143
# [79]	validation_0-rmse:0.20993
# [80]	validation_0-rmse:0.20816
# [81]	validation_0-rmse:0.20707
# [82]	validation_0-rmse:0.20650
# [83]	validation_0-rmse:0.20613
# [84]	validation_0-rmse:0.20449
# [85]	validation_0-rmse:0.20366
# [86]	validation_0-rmse:0.20185
# [87]	validation_0-rmse:0.20048
# [88]	validation_0-rmse:0.19852
# [89]	validation_0-rmse:0.19721
# [90]	validation_0-rmse:0.19557
# [91]	validation_0-rmse:0.19386
# [92]	validation_0-rmse:0.19308
# [93]	validation_0-rmse:0.19204
# [94]	validation_0-rmse:0.19078
# [95]	validation_0-rmse:0.18931
# [96]	validation_0-rmse:0.18836
# [97]	validation_0-rmse:0.18780
# [98]	validation_0-rmse:0.18751
# [99]	validation_0-rmse:0.18709
# [100]	validation_0-rmse:0.18588
# [101]	validation_0-rmse:0.18500
# [102]	validation_0-rmse:0.18396
# [103]	validation_0-rmse:0.18341
# [104]	validation_0-rmse:0.18252
# [105]	validation_0-rmse:0.18119
# [106]	validation_0-rmse:0.18039
# [107]	validation_0-rmse:0.17941
# [108]	validation_0-rmse:0.17934
# [109]	validation_0-rmse:0.17822
# [110]	validation_0-rmse:0.17740
# [111]	validation_0-rmse:0.17613
# [112]	validation_0-rmse:0.17519
# [113]	validation_0-rmse:0.17482
# [114]	validation_0-rmse:0.17439
# [115]	validation_0-rmse:0.17323
# [116]	validation_0-rmse:0.17225
# [117]	validation_0-rmse:0.17132
# [118]	validation_0-rmse:0.17019
# [119]	validation_0-rmse:0.16911
# [120]	validation_0-rmse:0.16778
# [121]	validation_0-rmse:0.16740
# [122]	validation_0-rmse:0.16646
# [123]	validation_0-rmse:0.16541
# [124]	validation_0-rmse:0.16454
# [125]	validation_0-rmse:0.16322
# [126]	validation_0-rmse:0.16315
# [127]	validation_0-rmse:0.16253
# [128]	validation_0-rmse:0.16210
# [129]	validation_0-rmse:0.16099
# [130]	validation_0-rmse:0.16015
# [131]	validation_0-rmse:0.15910
# [132]	validation_0-rmse:0.15791
# [133]	validation_0-rmse:0.15775
# [134]	validation_0-rmse:0.15705
# [135]	validation_0-rmse:0.15648
# [136]	validation_0-rmse:0.15552
# [137]	validation_0-rmse:0.15413
# [138]	validation_0-rmse:0.15372
# [139]	validation_0-rmse:0.15251
# [140]	validation_0-rmse:0.15227
# [141]	validation_0-rmse:0.15184
# [142]	validation_0-rmse:0.15076
# [143]	validation_0-rmse:0.14917
# [144]	validation_0-rmse:0.14858
# [145]	validation_0-rmse:0.14852
# [146]	validation_0-rmse:0.14728
# [147]	validation_0-rmse:0.14604
# [148]	validation_0-rmse:0.14469
# [149]	validation_0-rmse:0.14349
# [150]	validation_0-rmse:0.14299
# [151]	validation_0-rmse:0.14271
# [152]	validation_0-rmse:0.14233
# [153]	validation_0-rmse:0.14183
# [154]	validation_0-rmse:0.14081
# [155]	validation_0-rmse:0.14042
# [156]	validation_0-rmse:0.14014
# [157]	validation_0-rmse:0.13956
# [158]	validation_0-rmse:0.13882
# [159]	validation_0-rmse:0.13875
# [160]	validation_0-rmse:0.13782
# [161]	validation_0-rmse:0.13750
# [162]	validation_0-rmse:0.13729
# [163]	validation_0-rmse:0.13672
# [164]	validation_0-rmse:0.13588
# [165]	validation_0-rmse:0.13560
# [166]	validation_0-rmse:0.13537
# [167]	validation_0-rmse:0.13527
# [168]	validation_0-rmse:0.13513
# [169]	validation_0-rmse:0.13459
# [170]	validation_0-rmse:0.13441
# [171]	validation_0-rmse:0.13403
# [172]	validation_0-rmse:0.13393
# [173]	validation_0-rmse:0.13330
# [174]	validation_0-rmse:0.13243
# [175]	validation_0-rmse:0.13168
# [176]	validation_0-rmse:0.13086
# [177]	validation_0-rmse:0.13059
# [178]	validation_0-rmse:0.13042
# [179]	validation_0-rmse:0.13007
# [180]	validation_0-rmse:0.12979
# [181]	validation_0-rmse:0.12970
# [182]	validation_0-rmse:0.12889
# [183]	validation_0-rmse:0.12881
# [184]	validation_0-rmse:0.12791
# [185]	validation_0-rmse:0.12788
# [186]	validation_0-rmse:0.12697
# [187]	validation_0-rmse:0.12614
# [188]	validation_0-rmse:0.12568
# [189]	validation_0-rmse:0.12568
# [190]	validation_0-rmse:0.12489
# [191]	validation_0-rmse:0.12447
# [192]	validation_0-rmse:0.12414
# [193]	validation_0-rmse:0.12370
# [194]	validation_0-rmse:0.12351
# [195]	validation_0-rmse:0.12325
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 195

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.11
# RMSE: 0.1
# Relative RMSE(%):  9.030
# MSE: 0.0
# R square: 96.6%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-2, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.968
# Uncertainty
# a0: 0.103+/-0.009
# a1: 0.924+/-0.006

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../01_output_data/XGBoost_models/05_LN_M_foliage_other_authors_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../01_output_data/XGBoost_models/05_LN_M_foliage_other_authors_XGB_model.txt")
