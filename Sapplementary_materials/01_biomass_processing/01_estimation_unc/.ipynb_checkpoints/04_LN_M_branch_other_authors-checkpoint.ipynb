# %% [markdown]
# ## Processing with aboveground biomass data based on my fieldworks and other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
input_data = './FULL_DB_BIOMASS_OTHER_ALL_AUTHORS.csv'
df = pd.read_csv(input_data)
df.head()
# Out:
#    Groups Species  Species_ID Origin  Origin_ID  SI  A_years   H_m  DBH_cm  \
# 0       1    Pine           0      n        0.0   4       50   9.7    14.6
# 1       1    Pine           0      n        0.0   2       65  20.6    20.6
# 2       1    Pine           0      n        0.0   2       50  13.6    15.4
# 3       1    Pine           0      n        0.0   1       60  23.3    22.2
# 4       1    Pine           0      n        0.0   3       65  15.6    16.4
#
#    N_trees  ...  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  \
# 0    486.0  ...             NaN             NaN         8.4           1.6
# 1    785.0  ...             NaN             NaN        11.5           4.1
# 2   1745.0  ...             NaN             NaN        13.7           4.1
# 3    665.0  ...             NaN             NaN        14.4           5.4
# 4    955.0  ...             NaN             NaN        14.2           3.4
#
#    LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  \
# 0         3.78              2.94                NaN                NaN
# 1         5.54              4.73                NaN                NaN
# 2         5.25              4.48                NaN                NaN
# 3         5.63              4.67                NaN                NaN
# 4         4.96              4.20                NaN                NaN
#
#    LN_Crown_t_ha  LN_Foliage_t_ha
# 0           2.13             0.47
# 1           2.44             1.41
# 2           2.62             1.41
# 3           2.67             1.69
# 4           2.65             1.22
#
# [5 rows x 24 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
#
# 'Groups','Species_ID','Origin_ID','SI','A_years','H_m','DBH_cm','RS(P)',          'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
# 'Crown_t_ha','Foliage_t_ha'
# 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species_ID','Origin_ID','H_m','DBH_cm', 'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
'Crown_t_ha','Foliage_t_ha', 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0           0        0.0   9.7    14.6         9.7      43.9           18.9
# 1           0        0.0  20.6    20.6        32.2     254.0          113.1
# 2           0        0.0  13.6    15.4        35.2     190.0           87.8
# 3           0        0.0  23.3    22.2        29.6     277.7          106.5
# 4           0        0.0  15.6    16.4        20.4     142.5           67.0
#
#    Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0             NaN             NaN         8.4           1.6         3.78
# 1             NaN             NaN        11.5           4.1         5.54
# 2             NaN             NaN        13.7           4.1         5.25
# 3             NaN             NaN        14.4           5.4         5.63
# 4             NaN             NaN        14.2           3.4         4.96
#
#    LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0              2.94                NaN                NaN           2.13
# 1              4.73                NaN                NaN           2.44
# 2              4.48                NaN                NaN           2.62
# 3              4.67                NaN                NaN           2.67
# 4              4.20                NaN                NaN           2.65
#
#    LN_Foliage_t_ha
# 0             0.47
# 1             1.41
# 2             1.41
# 3             1.69
# 4             1.22

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Species_ID         857 non-null    int64
#  1   Origin_ID          856 non-null    float64
#  2   H_m                857 non-null    float64
#  3   DBH_cm             856 non-null    float64
#  4   BA_sq_m_ha         857 non-null    float64
#  5   GS_cub_m           857 non-null    float64
#  6   ALL_STEM_t_ha      855 non-null    float64
#  7   Stem_wood_t_ha     747 non-null    float64
#  8   Stem_bark_t_ha     747 non-null    float64
#  9   Crown_t_ha         843 non-null    float64
#  10  Foliage_t_ha       854 non-null    float64
#  11  LN_GS_cub_m        857 non-null    float64
#  12  LN_ALL_STEM_t_ha   855 non-null    float64
#  13  LN_Stem_wood_t_ha  747 non-null    float64
#  14  LN_Stem_bark_t_ha  747 non-null    float64
#  15  LN_Crown_t_ha      843 non-null    float64
#  16  LN_Foliage_t_ha    854 non-null    float64
# dtypes: float64(16), int64(1)
# memory usage: 113.9 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species_ID"])["Stem_bark_t_ha", "ALL_STEM_t_ha"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            Stem_bark_t_ha                                                    \
#                     count       mean        std  min     25%    50%     75%
# Species_ID
# 0                   371.0   7.894070   4.128113  0.3   4.900   7.70  10.350
# 1                     7.0  34.728571  23.382095  8.3  13.950  35.70  52.750
# 2                   120.0  11.320000   7.552123  0.8   6.375   9.45  15.250
# 3                   115.0  15.307826   8.294197  2.1   7.950  15.30  21.450
# 4                    66.0  11.296970   6.528234  1.6   6.500   9.25  16.575
# 5                    68.0  29.010294  12.702287  2.5  18.400  29.70  39.675
#
#                  ALL_STEM_t_ha                                              \
#              max         count        mean        std   min     25%    50%
# Species_ID
# 0           23.2         457.0   97.049891  61.854506   1.8  47.500   92.7
# 1           65.7           7.0  123.814286  61.879895  46.3  70.650  133.9
# 2           38.8         120.0   74.495000  44.523333   5.1  37.275   68.1
# 3           41.1         115.0  107.607826  55.589186  11.0  62.700  106.8
# 4           28.7          66.0   84.946970  58.875162   8.2  40.750   61.2
# 5           48.8          90.0  173.065556  99.100647   5.0  93.075  161.3
#
#
#                 75%    max
# Species_ID
# 0           135.900  310.7
# 1           174.550  196.1
# 2           103.075  193.5
# 3           145.450  251.6
# 4           125.000  245.4
# 5           253.375  363.9

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID   Origin_ID         H_m      DBH_cm  BA_sq_m_ha    GS_cub_m  \
# count  857.000000  856.000000  857.000000  856.000000  857.000000  857.000000
# mean     1.529755    0.279206   16.452275   17.132243   26.329988  229.013069
# std      1.823872    0.448871    7.039954   10.439115   10.629993  144.362106
# min      0.000000    0.000000    1.500000    1.100000    1.000000    2.400000
# 25%      0.000000    0.000000   11.200000    9.900000   19.000000  116.000000
# 50%      0.000000    0.000000   16.100000   15.500000   26.800000  206.000000
# 75%      3.000000    1.000000   21.200000   22.100000   34.500000  320.000000
# max      5.000000    1.000000   38.300000   94.000000   51.500000  735.000000
#
#        ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  \
# count     855.000000      747.000000      747.000000  843.000000
# mean      102.590877       92.779518       12.060107   13.821969
# std        68.758819       61.992238        9.595428   11.567546
# min         1.800000        2.000000        0.300000    0.500000
# 25%        47.500000       42.900000        5.950000    6.610000
# 50%        93.500000       84.600000        9.300000   10.820000
# 75%       140.500000      125.500000       15.300000   16.435000
# max       363.900000      315.200000       65.700000   69.120000
#
#        Foliage_t_ha  LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  \
# count    854.000000   857.000000        855.000000         747.000000
# mean       4.749356     5.166919          4.343766           4.246975
# std        2.826586     0.839680          0.869479           0.854856
# min        0.200000     0.880000          0.590000           0.690000
# 25%        2.600000     4.750000          3.860000           3.760000
# 50%        4.300000     5.330000          4.540000           4.440000
# 75%        6.367500     5.770000          4.950000           4.830000
# max       21.730000     6.600000          5.900000           5.750000
#
#        LN_Stem_bark_t_ha  LN_Crown_t_ha  LN_Foliage_t_ha
# count         747.000000     843.000000       854.000000
# mean            2.201232       2.318149         1.364906
# std             0.806766       0.829446         0.672551
# min            -1.200000      -0.690000        -1.610000
# 25%             1.780000       1.890000         0.960000
# 50%             2.230000       2.380000         1.460000
# 75%             2.730000       2.800000         1.850000
# max             4.190000       4.240000         3.080000

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "Crown_t_ha"
indep_variables = ['Species_ID','Origin_ID','H_m','DBH_cm','BA_sq_m_ha']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0             0        0.0   9.7    14.6         9.7      43.9           18.9
# 1             0        0.0  20.6    20.6        32.2     254.0          113.1
# 2             0        0.0  13.6    15.4        35.2     190.0           87.8
# 3             0        0.0  23.3    22.2        29.6     277.7          106.5
# 4             0        0.0  15.6    16.4        20.4     142.5           67.0
# ..          ...        ...   ...     ...         ...       ...            ...
# 852           3        0.0   7.8     4.4         9.2      39.8           17.8
# 853           3        0.0  12.7     9.0        20.5     123.6           47.1
# 854           3        0.0  12.2     8.1        20.3     141.7           51.9
# 855           2        0.0  14.3    12.4        25.1     176.5          100.7
# 856           2        0.0  21.1    25.6        21.0     191.6           99.9
#
#      Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0               NaN             NaN        8.40          1.60         3.78
# 1               NaN             NaN       11.50          4.10         5.54
# 2               NaN             NaN       13.70          4.10         5.25
# 3               NaN             NaN       14.40          5.40         5.63
# 4               NaN             NaN       14.20          3.40         4.96
# ..              ...             ...         ...           ...          ...
# 852            15.7             2.1        2.26          2.04         3.68
# 853            42.6             4.5        2.14          1.21         4.82
# 854            47.8             4.1        2.11          1.16         4.95
# 855            84.6            16.1       16.90          4.74         5.17
# 856            80.8            19.1       16.60          2.13         5.26
#
#      LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0                2.94                NaN                NaN           2.13
# 1                4.73                NaN                NaN           2.44
# 2                4.48                NaN                NaN           2.62
# 3                4.67                NaN                NaN           2.67
# 4                4.20                NaN                NaN           2.65
# ..                ...                ...                ...            ...
# 852              2.88               2.75               0.74           0.82
# 853              3.85               3.75               1.50           0.76
# 854              3.95               3.87               1.41           0.75
# 855              4.61               4.44               2.78           2.83
# 856              4.60               4.39               2.95           2.81
#
#      LN_Foliage_t_ha
# 0               0.47
# 1               1.41
# 2               1.41
# 3               1.69
# 4               1.22
# ..               ...
# 852             0.71
# 853             0.19
# 854             0.15
# 855             1.56
# 856             0.76
#
# [843 rows x 17 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha
# 0           0        0.0   9.7    14.6         9.7
# 1           0        0.0  20.6    20.6        32.2
# 2           0        0.0  13.6    15.4        35.2
# 3           0        0.0  23.3    22.2        29.6
# 4           0        0.0  15.6    16.4        20.4

# %%
# Columns in "y" data collections
y.head()
# Out:
#    Crown_t_ha
# 0         8.4
# 1        11.5
# 2        13.7
# 3        14.4
# 4        14.2

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.7090204783441107, 0.7059529188564422, 0.7459889101630726]
#     Mean: 0.720
#     Std: 0.018
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [6.3579673  5.24845579 6.00536291]
#     Mean: 5.871
#     Std: 0.463
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [3.9518620453440847, 3.786568587742666, 4.083306854237866]
#     Mean: 3.941
#     Std: 0.121
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.7848716719102183                 # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.4866695626319013                 # gamma
print('Gamma: ' + str(p2))

p3 = 0.2038298608008555                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 4            # max_depth
print('Max_depth: ' + str(p4))

p5 = 172         # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.8630421607056131                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.7848716719102183
# Gamma: 0.4866695626319013
# Learning_rate: 0.2038298608008555
# Max_depth: 4
# N_estimators: 172
# Subsample: 0.8630421607056131

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:14.97946	validation_1-rmse:13.22541
# [1]	validation_0-rmse:12.64519	validation_1-rmse:10.88092
# [2]	validation_0-rmse:11.00882	validation_1-rmse:9.50214
# [3]	validation_0-rmse:9.60231	validation_1-rmse:8.22003
# [4]	validation_0-rmse:8.59068	validation_1-rmse:7.23361
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:7.70606	validation_1-rmse:6.47997
# [6]	validation_0-rmse:7.12125	validation_1-rmse:5.96250
# [7]	validation_0-rmse:6.63170	validation_1-rmse:5.50782
# [8]	validation_0-rmse:6.29453	validation_1-rmse:5.28627
# [9]	validation_0-rmse:6.00597	validation_1-rmse:5.12281
# [10]	validation_0-rmse:5.81438	validation_1-rmse:4.90253
# [11]	validation_0-rmse:5.70465	validation_1-rmse:4.84994
# [12]	validation_0-rmse:5.41629	validation_1-rmse:4.76246
# [13]	validation_0-rmse:5.34070	validation_1-rmse:4.76191
# [14]	validation_0-rmse:5.23993	validation_1-rmse:4.75749
# [15]	validation_0-rmse:5.16350	validation_1-rmse:4.73144
# [16]	validation_0-rmse:5.07739	validation_1-rmse:4.67249
# [17]	validation_0-rmse:4.87666	validation_1-rmse:4.64329
# [18]	validation_0-rmse:4.83715	validation_1-rmse:4.64240
# [19]	validation_0-rmse:4.78024	validation_1-rmse:4.62312
# [20]	validation_0-rmse:4.73875	validation_1-rmse:4.54004
# [21]	validation_0-rmse:4.66163	validation_1-rmse:4.56082
# [22]	validation_0-rmse:4.50687	validation_1-rmse:4.56741
# [23]	validation_0-rmse:4.40581	validation_1-rmse:4.57528
# [24]	validation_0-rmse:4.38667	validation_1-rmse:4.58202
# [25]	validation_0-rmse:4.29789	validation_1-rmse:4.61716
# [26]	validation_0-rmse:4.23070	validation_1-rmse:4.61786
# [27]	validation_0-rmse:4.17709	validation_1-rmse:4.60985
# [28]	validation_0-rmse:4.11869	validation_1-rmse:4.60713
# [29]	validation_0-rmse:4.04114	validation_1-rmse:4.60725
# [30]	validation_0-rmse:3.97859	validation_1-rmse:4.59226
# [31]	validation_0-rmse:3.93309	validation_1-rmse:4.59712
# [32]	validation_0-rmse:3.90465	validation_1-rmse:4.61410
# [33]	validation_0-rmse:3.83623	validation_1-rmse:4.54364
# [34]	validation_0-rmse:3.75663	validation_1-rmse:4.53799
# [35]	validation_0-rmse:3.72017	validation_1-rmse:4.54068
# [36]	validation_0-rmse:3.68144	validation_1-rmse:4.54640
# [37]	validation_0-rmse:3.64919	validation_1-rmse:4.56015
# [38]	validation_0-rmse:3.63147	validation_1-rmse:4.52536
# [39]	validation_0-rmse:3.59223	validation_1-rmse:4.51878
# [40]	validation_0-rmse:3.55951	validation_1-rmse:4.51661
# [41]	validation_0-rmse:3.53829	validation_1-rmse:4.52066
# [42]	validation_0-rmse:3.50710	validation_1-rmse:4.51964
# [43]	validation_0-rmse:3.46493	validation_1-rmse:4.51366
# [44]	validation_0-rmse:3.41663	validation_1-rmse:4.52202
# [45]	validation_0-rmse:3.36386	validation_1-rmse:4.51146
# [46]	validation_0-rmse:3.31395	validation_1-rmse:4.50173
# [47]	validation_0-rmse:3.30358	validation_1-rmse:4.50669
# [48]	validation_0-rmse:3.27244	validation_1-rmse:4.50046
# [49]	validation_0-rmse:3.25982	validation_1-rmse:4.48982
# [50]	validation_0-rmse:3.21437	validation_1-rmse:4.51870
# [51]	validation_0-rmse:3.19327	validation_1-rmse:4.52134
# [52]	validation_0-rmse:3.18334	validation_1-rmse:4.51764
# [53]	validation_0-rmse:3.16374	validation_1-rmse:4.50105
# [54]	validation_0-rmse:3.11640	validation_1-rmse:4.48876
# [55]	validation_0-rmse:3.09452	validation_1-rmse:4.48916
# [56]	validation_0-rmse:3.06846	validation_1-rmse:4.48928
# [57]	validation_0-rmse:3.03623	validation_1-rmse:4.50360
# [58]	validation_0-rmse:3.02025	validation_1-rmse:4.50834
# [59]	validation_0-rmse:2.99029	validation_1-rmse:4.50113
# [60]	validation_0-rmse:2.95105	validation_1-rmse:4.49334
# [61]	validation_0-rmse:2.90940	validation_1-rmse:4.51910
# [62]	validation_0-rmse:2.90445	validation_1-rmse:4.52790
# [63]	validation_0-rmse:2.87741	validation_1-rmse:4.53106
# [64]	validation_0-rmse:2.84878	validation_1-rmse:4.52969
# [65]	validation_0-rmse:2.82111	validation_1-rmse:4.54945
# [66]	validation_0-rmse:2.79534	validation_1-rmse:4.55702
# [67]	validation_0-rmse:2.76502	validation_1-rmse:4.56999
# [68]	validation_0-rmse:2.73903	validation_1-rmse:4.56041
# [69]	validation_0-rmse:2.72924	validation_1-rmse:4.57012
# [70]	validation_0-rmse:2.71523	validation_1-rmse:4.57875
# [71]	validation_0-rmse:2.67864	validation_1-rmse:4.59571
# [72]	validation_0-rmse:2.65919	validation_1-rmse:4.59944
# [73]	validation_0-rmse:2.64710	validation_1-rmse:4.59981
# [74]	validation_0-rmse:2.63573	validation_1-rmse:4.59879
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:15.07609	validation_1-rmse:12.87561
# [1]	validation_0-rmse:12.73129	validation_1-rmse:10.66450
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:11.08539	validation_1-rmse:9.14838
# [3]	validation_0-rmse:9.59848	validation_1-rmse:7.73212
# [4]	validation_0-rmse:8.66304	validation_1-rmse:6.94675
# [5]	validation_0-rmse:7.81169	validation_1-rmse:6.18992
# [6]	validation_0-rmse:7.14889	validation_1-rmse:5.75170
# [7]	validation_0-rmse:6.64333	validation_1-rmse:5.37059
# [8]	validation_0-rmse:6.30918	validation_1-rmse:5.09338
# [9]	validation_0-rmse:6.05606	validation_1-rmse:4.89859
# [10]	validation_0-rmse:5.82294	validation_1-rmse:4.80133
# [11]	validation_0-rmse:5.62284	validation_1-rmse:4.70113
# [12]	validation_0-rmse:5.50434	validation_1-rmse:4.69740
# [13]	validation_0-rmse:5.41799	validation_1-rmse:4.71271
# [14]	validation_0-rmse:5.16816	validation_1-rmse:4.68833
# [15]	validation_0-rmse:5.09951	validation_1-rmse:4.69223
# [16]	validation_0-rmse:4.91060	validation_1-rmse:4.69580
# [17]	validation_0-rmse:4.77078	validation_1-rmse:4.66149
# [18]	validation_0-rmse:4.72535	validation_1-rmse:4.65669
# [19]	validation_0-rmse:4.70436	validation_1-rmse:4.66237
# [20]	validation_0-rmse:4.65936	validation_1-rmse:4.72080
# [21]	validation_0-rmse:4.60776	validation_1-rmse:4.75152
# [22]	validation_0-rmse:4.51445	validation_1-rmse:4.72211
# [23]	validation_0-rmse:4.47898	validation_1-rmse:4.69485
# [24]	validation_0-rmse:4.45039	validation_1-rmse:4.71441
# [25]	validation_0-rmse:4.40102	validation_1-rmse:4.73741
# [26]	validation_0-rmse:4.35337	validation_1-rmse:4.75767
# [27]	validation_0-rmse:4.30468	validation_1-rmse:4.77096
# [28]	validation_0-rmse:4.24390	validation_1-rmse:4.77082
# [29]	validation_0-rmse:4.19739	validation_1-rmse:4.75720
# [30]	validation_0-rmse:4.12190	validation_1-rmse:4.75764
# [31]	validation_0-rmse:4.09649	validation_1-rmse:4.77059
# [32]	validation_0-rmse:4.03677	validation_1-rmse:4.79835
# [33]	validation_0-rmse:4.00302	validation_1-rmse:4.83089
# [34]	validation_0-rmse:3.95797	validation_1-rmse:4.84668
# [35]	validation_0-rmse:3.90866	validation_1-rmse:4.83348
# [36]	validation_0-rmse:3.84612	validation_1-rmse:4.83693
# [37]	validation_0-rmse:3.82300	validation_1-rmse:4.84795
# [38]	validation_0-rmse:3.79978	validation_1-rmse:4.85150
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:14.63233	validation_1-rmse:15.25742
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:12.34361	validation_1-rmse:12.89293
# [2]	validation_0-rmse:10.76696	validation_1-rmse:11.42298
# [3]	validation_0-rmse:9.34277	validation_1-rmse:10.01878
# [4]	validation_0-rmse:8.35762	validation_1-rmse:9.16562
# [5]	validation_0-rmse:7.45105	validation_1-rmse:8.28706
# [6]	validation_0-rmse:6.64833	validation_1-rmse:7.71931
# [7]	validation_0-rmse:6.13645	validation_1-rmse:7.29953
# [8]	validation_0-rmse:5.77459	validation_1-rmse:7.03044
# [9]	validation_0-rmse:5.44161	validation_1-rmse:6.86016
# [10]	validation_0-rmse:5.26033	validation_1-rmse:6.76061
# [11]	validation_0-rmse:5.12675	validation_1-rmse:6.67377
# [12]	validation_0-rmse:4.88875	validation_1-rmse:6.58132
# [13]	validation_0-rmse:4.79847	validation_1-rmse:6.53484
# [14]	validation_0-rmse:4.61106	validation_1-rmse:6.48212
# [15]	validation_0-rmse:4.53706	validation_1-rmse:6.40558
# [16]	validation_0-rmse:4.39804	validation_1-rmse:6.33669
# [17]	validation_0-rmse:4.34369	validation_1-rmse:6.31454
# [18]	validation_0-rmse:4.27480	validation_1-rmse:6.29446
# [19]	validation_0-rmse:4.21691	validation_1-rmse:6.30227
# [20]	validation_0-rmse:4.14951	validation_1-rmse:6.26700
# [21]	validation_0-rmse:4.11527	validation_1-rmse:6.25180
# [22]	validation_0-rmse:4.05424	validation_1-rmse:6.26170
# [23]	validation_0-rmse:4.02712	validation_1-rmse:6.28215
# [24]	validation_0-rmse:3.96058	validation_1-rmse:6.28632
# [25]	validation_0-rmse:3.91512	validation_1-rmse:6.30771
# [26]	validation_0-rmse:3.85187	validation_1-rmse:6.30753
# [27]	validation_0-rmse:3.79834	validation_1-rmse:6.29603
# [28]	validation_0-rmse:3.73121	validation_1-rmse:6.29554
# [29]	validation_0-rmse:3.67606	validation_1-rmse:6.30234
# [30]	validation_0-rmse:3.64225	validation_1-rmse:6.31393
# [31]	validation_0-rmse:3.60129	validation_1-rmse:6.29455
# [32]	validation_0-rmse:3.56203	validation_1-rmse:6.25500
# [33]	validation_0-rmse:3.52386	validation_1-rmse:6.25007
# [34]	validation_0-rmse:3.49575	validation_1-rmse:6.25203
# [35]	validation_0-rmse:3.47603	validation_1-rmse:6.26786
# [36]	validation_0-rmse:3.43373	validation_1-rmse:6.24873
# [37]	validation_0-rmse:3.40322	validation_1-rmse:6.23970
# [38]	validation_0-rmse:3.35374	validation_1-rmse:6.24151
# [39]	validation_0-rmse:3.33067	validation_1-rmse:6.23089
# [40]	validation_0-rmse:3.28910	validation_1-rmse:6.23518
# [41]	validation_0-rmse:3.23771	validation_1-rmse:6.23359
# [42]	validation_0-rmse:3.20282	validation_1-rmse:6.22624
# [43]	validation_0-rmse:3.17032	validation_1-rmse:6.22496
# [44]	validation_0-rmse:3.11409	validation_1-rmse:6.23962
# [45]	validation_0-rmse:3.07619	validation_1-rmse:6.24237
# [46]	validation_0-rmse:3.02762	validation_1-rmse:6.22439
# [47]	validation_0-rmse:3.00878	validation_1-rmse:6.21398
# [48]	validation_0-rmse:2.98036	validation_1-rmse:6.23518
# [49]	validation_0-rmse:2.96085	validation_1-rmse:6.22760
# [50]	validation_0-rmse:2.94089	validation_1-rmse:6.23250
# [51]	validation_0-rmse:2.90247	validation_1-rmse:6.25787
# [52]	validation_0-rmse:2.88133	validation_1-rmse:6.25230
# [53]	validation_0-rmse:2.85158	validation_1-rmse:6.26144
# [54]	validation_0-rmse:2.81679	validation_1-rmse:6.27124
# [55]	validation_0-rmse:2.79934	validation_1-rmse:6.26334
# [56]	validation_0-rmse:2.76921	validation_1-rmse:6.28797
# [57]	validation_0-rmse:2.74271	validation_1-rmse:6.28889
# [58]	validation_0-rmse:2.72902	validation_1-rmse:6.28511
# [59]	validation_0-rmse:2.71022	validation_1-rmse:6.28270
# [60]	validation_0-rmse:2.68817	validation_1-rmse:6.29595
# [61]	validation_0-rmse:2.67321	validation_1-rmse:6.30225
# [62]	validation_0-rmse:2.65617	validation_1-rmse:6.29697
# [63]	validation_0-rmse:2.63511	validation_1-rmse:6.29446
# [64]	validation_0-rmse:2.60601	validation_1-rmse:6.31422
# [65]	validation_0-rmse:2.57269	validation_1-rmse:6.34244
# [66]	validation_0-rmse:2.54962	validation_1-rmse:6.34765
# [67]	validation_0-rmse:2.51207	validation_1-rmse:6.33903
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:14.55473	validation_1-rmse:15.23902
# [1]	validation_0-rmse:12.27639	validation_1-rmse:13.15770
# [2]	validation_0-rmse:10.70311	validation_1-rmse:11.72602
# [3]	validation_0-rmse:9.21936	validation_1-rmse:10.31009
# [4]	validation_0-rmse:8.18778	validation_1-rmse:9.45936
# [5]	validation_0-rmse:7.35821	validation_1-rmse:8.71659
# [6]	validation_0-rmse:6.74624	validation_1-rmse:8.14611
# [7]	validation_0-rmse:6.26793	validation_1-rmse:7.81144
# [8]	validation_0-rmse:5.90828	validation_1-rmse:7.50743
# [9]	validation_0-rmse:5.65545	validation_1-rmse:7.29177
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [10]	validation_0-rmse:5.48052	validation_1-rmse:7.15141
# [11]	validation_0-rmse:5.31542	validation_1-rmse:7.07187
# [12]	validation_0-rmse:5.17121	validation_1-rmse:6.97481
# [13]	validation_0-rmse:5.09393	validation_1-rmse:6.95525
# [14]	validation_0-rmse:4.99386	validation_1-rmse:6.88426
# [15]	validation_0-rmse:4.93877	validation_1-rmse:6.87742
# [16]	validation_0-rmse:4.89315	validation_1-rmse:6.83556
# [17]	validation_0-rmse:4.76296	validation_1-rmse:6.47596
# [18]	validation_0-rmse:4.72188	validation_1-rmse:6.44795
# [19]	validation_0-rmse:4.62289	validation_1-rmse:6.18005
# [20]	validation_0-rmse:4.55519	validation_1-rmse:6.17418
# [21]	validation_0-rmse:4.47789	validation_1-rmse:6.20580
# [22]	validation_0-rmse:4.36929	validation_1-rmse:6.03840
# [23]	validation_0-rmse:4.28451	validation_1-rmse:5.87300
# [24]	validation_0-rmse:4.25970	validation_1-rmse:5.87131
# [25]	validation_0-rmse:4.19397	validation_1-rmse:5.88031
# [26]	validation_0-rmse:4.12494	validation_1-rmse:5.85207
# [27]	validation_0-rmse:4.08112	validation_1-rmse:5.86085
# [28]	validation_0-rmse:4.06174	validation_1-rmse:5.85817
# [29]	validation_0-rmse:4.01783	validation_1-rmse:5.81492
# [30]	validation_0-rmse:3.99483	validation_1-rmse:5.81120
# [31]	validation_0-rmse:3.96314	validation_1-rmse:5.81505
# [32]	validation_0-rmse:3.90261	validation_1-rmse:5.82003
# [33]	validation_0-rmse:3.84659	validation_1-rmse:5.81825
# [34]	validation_0-rmse:3.81591	validation_1-rmse:5.79945
# [35]	validation_0-rmse:3.77396	validation_1-rmse:5.78653
# [36]	validation_0-rmse:3.74229	validation_1-rmse:5.76757
# [37]	validation_0-rmse:3.71505	validation_1-rmse:5.75935
# [38]	validation_0-rmse:3.64893	validation_1-rmse:5.71795
# [39]	validation_0-rmse:3.61462	validation_1-rmse:5.69293
# [40]	validation_0-rmse:3.56434	validation_1-rmse:5.66839
# [41]	validation_0-rmse:3.54404	validation_1-rmse:5.66928
# [42]	validation_0-rmse:3.52544	validation_1-rmse:5.66629
# [43]	validation_0-rmse:3.47915	validation_1-rmse:5.66068
# [44]	validation_0-rmse:3.40494	validation_1-rmse:5.55789
# [45]	validation_0-rmse:3.36849	validation_1-rmse:5.55663
# [46]	validation_0-rmse:3.32273	validation_1-rmse:5.54092
# [47]	validation_0-rmse:3.30173	validation_1-rmse:5.53598
# [48]	validation_0-rmse:3.27167	validation_1-rmse:5.54526
# [49]	validation_0-rmse:3.26205	validation_1-rmse:5.54959
# [50]	validation_0-rmse:3.24247	validation_1-rmse:5.54590
# [51]	validation_0-rmse:3.20659	validation_1-rmse:5.45763
# [52]	validation_0-rmse:3.19633	validation_1-rmse:5.46069
# [53]	validation_0-rmse:3.16442	validation_1-rmse:5.47598
# [54]	validation_0-rmse:3.14566	validation_1-rmse:5.48994
# [55]	validation_0-rmse:3.12185	validation_1-rmse:5.49567
# [56]	validation_0-rmse:3.10240	validation_1-rmse:5.46651
# [57]	validation_0-rmse:3.06994	validation_1-rmse:5.46184
# [58]	validation_0-rmse:3.04191	validation_1-rmse:5.47996
# [59]	validation_0-rmse:3.02654	validation_1-rmse:5.49115
# [60]	validation_0-rmse:3.00013	validation_1-rmse:5.48893
# [61]	validation_0-rmse:2.96754	validation_1-rmse:5.46404
# [62]	validation_0-rmse:2.92010	validation_1-rmse:5.39823
# [63]	validation_0-rmse:2.88696	validation_1-rmse:5.31945
# [64]	validation_0-rmse:2.85289	validation_1-rmse:5.31553
# [65]	validation_0-rmse:2.82495	validation_1-rmse:5.32193
# [66]	validation_0-rmse:2.80783	validation_1-rmse:5.32083
# [67]	validation_0-rmse:2.78214	validation_1-rmse:5.33171
# [68]	validation_0-rmse:2.76285	validation_1-rmse:5.32527
# [69]	validation_0-rmse:2.75202	validation_1-rmse:5.31824
# [70]	validation_0-rmse:2.72688	validation_1-rmse:5.30097
# [71]	validation_0-rmse:2.69256	validation_1-rmse:5.29205
# [72]	validation_0-rmse:2.67334	validation_1-rmse:5.29238
# [73]	validation_0-rmse:2.65305	validation_1-rmse:5.26893
# [74]	validation_0-rmse:2.63978	validation_1-rmse:5.26367
# [75]	validation_0-rmse:2.61277	validation_1-rmse:5.25848
# [76]	validation_0-rmse:2.60507	validation_1-rmse:5.25488
# [77]	validation_0-rmse:2.59025	validation_1-rmse:5.24607
# [78]	validation_0-rmse:2.57953	validation_1-rmse:5.24670
# [79]	validation_0-rmse:2.57088	validation_1-rmse:5.23520
# [80]	validation_0-rmse:2.55756	validation_1-rmse:5.25761
# [81]	validation_0-rmse:2.53758	validation_1-rmse:5.27269
# [82]	validation_0-rmse:2.52029	validation_1-rmse:5.27381
# [83]	validation_0-rmse:2.50972	validation_1-rmse:5.26547
# [84]	validation_0-rmse:2.48789	validation_1-rmse:5.26703
# [85]	validation_0-rmse:2.47623	validation_1-rmse:5.25034
# [86]	validation_0-rmse:2.45693	validation_1-rmse:5.25499
# [87]	validation_0-rmse:2.42777	validation_1-rmse:5.25004
# [88]	validation_0-rmse:2.41808	validation_1-rmse:5.24403
# [89]	validation_0-rmse:2.40361	validation_1-rmse:5.23945
# [90]	validation_0-rmse:2.39153	validation_1-rmse:5.22883
# [91]	validation_0-rmse:2.38215	validation_1-rmse:5.22858
# [92]	validation_0-rmse:2.36471	validation_1-rmse:5.23376
# [93]	validation_0-rmse:2.34878	validation_1-rmse:5.23128
# [94]	validation_0-rmse:2.32675	validation_1-rmse:5.17287
# [95]	validation_0-rmse:2.31086	validation_1-rmse:5.18329
# [96]	validation_0-rmse:2.30167	validation_1-rmse:5.17472
# [97]	validation_0-rmse:2.29188	validation_1-rmse:5.16253
# [98]	validation_0-rmse:2.27892	validation_1-rmse:5.17307
# [99]	validation_0-rmse:2.27012	validation_1-rmse:5.17312
# [100]	validation_0-rmse:2.25596	validation_1-rmse:5.18287
# [101]	validation_0-rmse:2.23812	validation_1-rmse:5.17688
# [102]	validation_0-rmse:2.22650	validation_1-rmse:5.18504
# [103]	validation_0-rmse:2.21643	validation_1-rmse:5.18321
# [104]	validation_0-rmse:2.19675	validation_1-rmse:5.17671
# [105]	validation_0-rmse:2.18871	validation_1-rmse:5.17955
# [106]	validation_0-rmse:2.17621	validation_1-rmse:5.18183
# [107]	validation_0-rmse:2.15949	validation_1-rmse:5.19009
# [108]	validation_0-rmse:2.15195	validation_1-rmse:5.18819
# [109]	validation_0-rmse:2.13536	validation_1-rmse:5.18555
# [110]	validation_0-rmse:2.11472	validation_1-rmse:5.15546
# [111]	validation_0-rmse:2.09949	validation_1-rmse:5.13256
# [112]	validation_0-rmse:2.09273	validation_1-rmse:5.13583
# [113]	validation_0-rmse:2.08218	validation_1-rmse:5.14186
# [114]	validation_0-rmse:2.06836	validation_1-rmse:5.13821
# [115]	validation_0-rmse:2.05252	validation_1-rmse:5.12873
# [116]	validation_0-rmse:2.04345	validation_1-rmse:5.12343
# [117]	validation_0-rmse:2.02694	validation_1-rmse:5.14241
# [118]	validation_0-rmse:2.01852	validation_1-rmse:5.14705
# [119]	validation_0-rmse:2.01274	validation_1-rmse:5.15057
# [120]	validation_0-rmse:2.00654	validation_1-rmse:5.14941
# [121]	validation_0-rmse:1.99424	validation_1-rmse:5.15299
# [122]	validation_0-rmse:1.98681	validation_1-rmse:5.15553
# [123]	validation_0-rmse:1.97295	validation_1-rmse:5.15521
# [124]	validation_0-rmse:1.96579	validation_1-rmse:5.13773
# [125]	validation_0-rmse:1.95919	validation_1-rmse:5.14162
# [126]	validation_0-rmse:1.95183	validation_1-rmse:5.13971
# [127]	validation_0-rmse:1.94295	validation_1-rmse:5.14710
# [128]	validation_0-rmse:1.93099	validation_1-rmse:5.15954
# [129]	validation_0-rmse:1.91840	validation_1-rmse:5.15967
# [130]	validation_0-rmse:1.90630	validation_1-rmse:5.15435
# [131]	validation_0-rmse:1.88815	validation_1-rmse:5.16456
# [132]	validation_0-rmse:1.88413	validation_1-rmse:5.16122
# [133]	validation_0-rmse:1.86806	validation_1-rmse:5.16070
# [134]	validation_0-rmse:1.85608	validation_1-rmse:5.15231
# [135]	validation_0-rmse:1.84987	validation_1-rmse:5.14630
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:14.84120	validation_1-rmse:14.16178
# [1]	validation_0-rmse:12.53344	validation_1-rmse:11.94848
# [2]	validation_0-rmse:10.96501	validation_1-rmse:10.56610
# [3]	validation_0-rmse:9.55580	validation_1-rmse:9.25912
# [4]	validation_0-rmse:8.58184	validation_1-rmse:8.50173
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:7.59033	validation_1-rmse:7.82001
# [6]	validation_0-rmse:6.94583	validation_1-rmse:7.26928
# [7]	validation_0-rmse:6.43743	validation_1-rmse:6.84219
# [8]	validation_0-rmse:6.05797	validation_1-rmse:6.48405
# [9]	validation_0-rmse:5.72060	validation_1-rmse:6.25592
# [10]	validation_0-rmse:5.54953	validation_1-rmse:6.08482
# [11]	validation_0-rmse:5.37967	validation_1-rmse:6.00078
# [12]	validation_0-rmse:5.15646	validation_1-rmse:5.90987
# [13]	validation_0-rmse:5.04113	validation_1-rmse:5.85414
# [14]	validation_0-rmse:4.89400	validation_1-rmse:5.80534
# [15]	validation_0-rmse:4.81794	validation_1-rmse:5.64677
# [16]	validation_0-rmse:4.75177	validation_1-rmse:5.64487
# [17]	validation_0-rmse:4.68726	validation_1-rmse:5.60560
# [18]	validation_0-rmse:4.64220	validation_1-rmse:5.59124
# [19]	validation_0-rmse:4.55171	validation_1-rmse:5.56527
# [20]	validation_0-rmse:4.45014	validation_1-rmse:5.54869
# [21]	validation_0-rmse:4.37185	validation_1-rmse:5.54880
# [22]	validation_0-rmse:4.26745	validation_1-rmse:5.55570
# [23]	validation_0-rmse:4.20315	validation_1-rmse:5.55321
# [24]	validation_0-rmse:4.16179	validation_1-rmse:5.55345
# [25]	validation_0-rmse:4.12562	validation_1-rmse:5.55964
# [26]	validation_0-rmse:4.08785	validation_1-rmse:5.52977
# [27]	validation_0-rmse:4.06069	validation_1-rmse:5.53531
# [28]	validation_0-rmse:4.01396	validation_1-rmse:5.53238
# [29]	validation_0-rmse:3.97085	validation_1-rmse:5.55977
# [30]	validation_0-rmse:3.91204	validation_1-rmse:5.58387
# [31]	validation_0-rmse:3.85994	validation_1-rmse:5.58625
# [32]	validation_0-rmse:3.80995	validation_1-rmse:5.51887
# [33]	validation_0-rmse:3.74463	validation_1-rmse:5.53710
# [34]	validation_0-rmse:3.68976	validation_1-rmse:5.53329
# [35]	validation_0-rmse:3.64767	validation_1-rmse:5.53050
# [36]	validation_0-rmse:3.61879	validation_1-rmse:5.53849
# [37]	validation_0-rmse:3.60132	validation_1-rmse:5.54515
# [38]	validation_0-rmse:3.57679	validation_1-rmse:5.55744
# [39]	validation_0-rmse:3.53454	validation_1-rmse:5.56662
# [40]	validation_0-rmse:3.49742	validation_1-rmse:5.56756
# [41]	validation_0-rmse:3.46486	validation_1-rmse:5.56787
# [42]	validation_0-rmse:3.44668	validation_1-rmse:5.56428
# [43]	validation_0-rmse:3.41869	validation_1-rmse:5.57276
# [44]	validation_0-rmse:3.39272	validation_1-rmse:5.60183
# [45]	validation_0-rmse:3.36045	validation_1-rmse:5.62016
# [46]	validation_0-rmse:3.31773	validation_1-rmse:5.62088
# [47]	validation_0-rmse:3.29311	validation_1-rmse:5.61335
# [48]	validation_0-rmse:3.24395	validation_1-rmse:5.61426
# [49]	validation_0-rmse:3.20866	validation_1-rmse:5.62550
# [50]	validation_0-rmse:3.19439	validation_1-rmse:5.62171
# [51]	validation_0-rmse:3.17236	validation_1-rmse:5.60836
# [52]	validation_0-rmse:3.16873	validation_1-rmse:5.61270
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:14.72535	validation_1-rmse:14.40176
# [1]	validation_0-rmse:12.40921	validation_1-rmse:12.25627
# [2]	validation_0-rmse:10.81506	validation_1-rmse:10.81799
# [3]	validation_0-rmse:9.42900	validation_1-rmse:9.47233
# [4]	validation_0-rmse:8.41583	validation_1-rmse:8.49487
# [5]	validation_0-rmse:7.56830	validation_1-rmse:7.61888
# [6]	validation_0-rmse:6.91205	validation_1-rmse:7.03669
# [7]	validation_0-rmse:6.46215	validation_1-rmse:6.66758
# [8]	validation_0-rmse:6.10256	validation_1-rmse:6.35062
# [9]	validation_0-rmse:5.86414	validation_1-rmse:6.19398
# [10]	validation_0-rmse:5.64376	validation_1-rmse:6.09455
# [11]	validation_0-rmse:5.48290	validation_1-rmse:6.03164
# [12]	validation_0-rmse:5.22078	validation_1-rmse:5.77359
# [13]	validation_0-rmse:5.13374	validation_1-rmse:5.78089
# [14]	validation_0-rmse:4.94712	validation_1-rmse:5.61996
# [15]	validation_0-rmse:4.85709	validation_1-rmse:5.66397
# [16]	validation_0-rmse:4.72918	validation_1-rmse:5.52972
# [17]	validation_0-rmse:4.61941	validation_1-rmse:5.42459
# [18]	validation_0-rmse:4.54922	validation_1-rmse:5.41203
# [19]	validation_0-rmse:4.52465	validation_1-rmse:5.42832
# [20]	validation_0-rmse:4.47507	validation_1-rmse:5.42028
# [21]	validation_0-rmse:4.42042	validation_1-rmse:5.41246
# [22]	validation_0-rmse:4.36456	validation_1-rmse:5.36153
# [23]	validation_0-rmse:4.34064	validation_1-rmse:5.35673
# [24]	validation_0-rmse:4.31116	validation_1-rmse:5.37098
# [25]	validation_0-rmse:4.23354	validation_1-rmse:5.36930
# [26]	validation_0-rmse:4.17391	validation_1-rmse:5.38048
# [27]	validation_0-rmse:4.11039	validation_1-rmse:5.39116
# [28]	validation_0-rmse:4.09601	validation_1-rmse:5.40002
# [29]	validation_0-rmse:4.05225	validation_1-rmse:5.39339
# [30]	validation_0-rmse:4.00805	validation_1-rmse:5.45896
# [31]	validation_0-rmse:3.95825	validation_1-rmse:5.42303
# [32]	validation_0-rmse:3.91253	validation_1-rmse:5.44485
# [33]	validation_0-rmse:3.85947	validation_1-rmse:5.43236
# [34]	validation_0-rmse:3.81948	validation_1-rmse:5.42807
# [35]	validation_0-rmse:3.77953	validation_1-rmse:5.43707
# [36]	validation_0-rmse:3.73216	validation_1-rmse:5.46389
# [37]	validation_0-rmse:3.68006	validation_1-rmse:5.46269
# [38]	validation_0-rmse:3.65174	validation_1-rmse:5.45524
# [39]	validation_0-rmse:3.63428	validation_1-rmse:5.45852
# [40]	validation_0-rmse:3.60195	validation_1-rmse:5.47355
# [41]	validation_0-rmse:3.59231	validation_1-rmse:5.47808
# [42]	validation_0-rmse:3.56152	validation_1-rmse:5.52789
# [43]	validation_0-rmse:3.53343	validation_1-rmse:5.49904
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:14.51399	validation_1-rmse:15.58887
# [1]	validation_0-rmse:12.18809	validation_1-rmse:13.57386
# [2]	validation_0-rmse:10.69442	validation_1-rmse:12.28378
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:9.30829	validation_1-rmse:10.90661
# [4]	validation_0-rmse:8.29966	validation_1-rmse:10.01566
# [5]	validation_0-rmse:7.44823	validation_1-rmse:9.10458
# [6]	validation_0-rmse:6.80244	validation_1-rmse:8.37950
# [7]	validation_0-rmse:6.28939	validation_1-rmse:7.97165
# [8]	validation_0-rmse:5.96634	validation_1-rmse:7.70087
# [9]	validation_0-rmse:5.69343	validation_1-rmse:7.45752
# [10]	validation_0-rmse:5.54127	validation_1-rmse:7.42072
# [11]	validation_0-rmse:5.35680	validation_1-rmse:7.33697
# [12]	validation_0-rmse:5.24428	validation_1-rmse:7.22098
# [13]	validation_0-rmse:5.12928	validation_1-rmse:7.23237
# [14]	validation_0-rmse:4.89703	validation_1-rmse:7.04532
# [15]	validation_0-rmse:4.82022	validation_1-rmse:7.02584
# [16]	validation_0-rmse:4.66407	validation_1-rmse:6.86923
# [17]	validation_0-rmse:4.60026	validation_1-rmse:6.85112
# [18]	validation_0-rmse:4.44001	validation_1-rmse:6.70411
# [19]	validation_0-rmse:4.41589	validation_1-rmse:6.70388
# [20]	validation_0-rmse:4.37653	validation_1-rmse:6.73724
# [21]	validation_0-rmse:4.30759	validation_1-rmse:6.71576
# [22]	validation_0-rmse:4.28103	validation_1-rmse:6.71683
# [23]	validation_0-rmse:4.25193	validation_1-rmse:6.78005
# [24]	validation_0-rmse:4.18931	validation_1-rmse:6.71640
# [25]	validation_0-rmse:4.14126	validation_1-rmse:6.70649
# [26]	validation_0-rmse:4.08956	validation_1-rmse:6.68702
# [27]	validation_0-rmse:4.02212	validation_1-rmse:6.67740
# [28]	validation_0-rmse:3.99469	validation_1-rmse:6.68538
# [29]	validation_0-rmse:3.92909	validation_1-rmse:6.61437
# [30]	validation_0-rmse:3.90514	validation_1-rmse:6.59756
# [31]	validation_0-rmse:3.86829	validation_1-rmse:6.58884
# [32]	validation_0-rmse:3.82837	validation_1-rmse:6.60564
# [33]	validation_0-rmse:3.76981	validation_1-rmse:6.52867
# [34]	validation_0-rmse:3.72361	validation_1-rmse:6.52507
# [35]	validation_0-rmse:3.66079	validation_1-rmse:6.49518
# [36]	validation_0-rmse:3.62575	validation_1-rmse:6.42946
# [37]	validation_0-rmse:3.60340	validation_1-rmse:6.43527
# [38]	validation_0-rmse:3.56519	validation_1-rmse:6.42443
# [39]	validation_0-rmse:3.52922	validation_1-rmse:6.40602
# [40]	validation_0-rmse:3.46686	validation_1-rmse:6.42342
# [41]	validation_0-rmse:3.42733	validation_1-rmse:6.38851
# [42]	validation_0-rmse:3.40412	validation_1-rmse:6.39274
# [43]	validation_0-rmse:3.37588	validation_1-rmse:6.41129
# [44]	validation_0-rmse:3.36080	validation_1-rmse:6.40569
# [45]	validation_0-rmse:3.31869	validation_1-rmse:6.36626
# [46]	validation_0-rmse:3.29373	validation_1-rmse:6.36604
# [47]	validation_0-rmse:3.26748	validation_1-rmse:6.34049
# [48]	validation_0-rmse:3.24188	validation_1-rmse:6.29611
# [49]	validation_0-rmse:3.23139	validation_1-rmse:6.30100
# [50]	validation_0-rmse:3.18316	validation_1-rmse:6.28510
# [51]	validation_0-rmse:3.13723	validation_1-rmse:6.20799
# [52]	validation_0-rmse:3.11054	validation_1-rmse:6.19163
# [53]	validation_0-rmse:3.07919	validation_1-rmse:6.20154
# [54]	validation_0-rmse:3.06239	validation_1-rmse:6.20612
# [55]	validation_0-rmse:3.04534	validation_1-rmse:6.22037
# [56]	validation_0-rmse:3.02478	validation_1-rmse:6.22882
# [57]	validation_0-rmse:2.99354	validation_1-rmse:6.24235
# [58]	validation_0-rmse:2.97176	validation_1-rmse:6.22685
# [59]	validation_0-rmse:2.93145	validation_1-rmse:6.22277
# [60]	validation_0-rmse:2.90367	validation_1-rmse:6.22010
# [61]	validation_0-rmse:2.88393	validation_1-rmse:6.20904
# [62]	validation_0-rmse:2.86552	validation_1-rmse:6.20942
# [63]	validation_0-rmse:2.84396	validation_1-rmse:6.20331
# [64]	validation_0-rmse:2.82531	validation_1-rmse:6.21838
# [65]	validation_0-rmse:2.79439	validation_1-rmse:6.23179
# [66]	validation_0-rmse:2.77689	validation_1-rmse:6.24302
# [67]	validation_0-rmse:2.75267	validation_1-rmse:6.24332
# [68]	validation_0-rmse:2.74174	validation_1-rmse:6.24056
# [69]	validation_0-rmse:2.71470	validation_1-rmse:6.22674
# [70]	validation_0-rmse:2.68906	validation_1-rmse:6.20540
# [71]	validation_0-rmse:2.66190	validation_1-rmse:6.18888
# [72]	validation_0-rmse:2.64727	validation_1-rmse:6.19687
# [73]	validation_0-rmse:2.62302	validation_1-rmse:6.20969
# [74]	validation_0-rmse:2.61420	validation_1-rmse:6.21504
# [75]	validation_0-rmse:2.59677	validation_1-rmse:6.22277
# [76]	validation_0-rmse:2.57774	validation_1-rmse:6.22687
# [77]	validation_0-rmse:2.55585	validation_1-rmse:6.20452
# [78]	validation_0-rmse:2.54099	validation_1-rmse:6.18363
# [79]	validation_0-rmse:2.52882	validation_1-rmse:6.18544
# [80]	validation_0-rmse:2.50972	validation_1-rmse:6.16523
# [81]	validation_0-rmse:2.49077	validation_1-rmse:6.16542
# [82]	validation_0-rmse:2.48246	validation_1-rmse:6.15537
# [83]	validation_0-rmse:2.46476	validation_1-rmse:6.13837
# [84]	validation_0-rmse:2.44649	validation_1-rmse:6.13680
# [85]	validation_0-rmse:2.42362	validation_1-rmse:6.13423
# [86]	validation_0-rmse:2.41211	validation_1-rmse:6.13986
# [87]	validation_0-rmse:2.38338	validation_1-rmse:6.11716
# [88]	validation_0-rmse:2.36731	validation_1-rmse:6.13134
# [89]	validation_0-rmse:2.35103	validation_1-rmse:6.12982
# [90]	validation_0-rmse:2.33386	validation_1-rmse:6.10849
# [91]	validation_0-rmse:2.32199	validation_1-rmse:6.10352
# [92]	validation_0-rmse:2.30950	validation_1-rmse:6.09906
# [93]	validation_0-rmse:2.28105	validation_1-rmse:6.10512
# [94]	validation_0-rmse:2.26615	validation_1-rmse:6.11684
# [95]	validation_0-rmse:2.25735	validation_1-rmse:6.10044
# [96]	validation_0-rmse:2.24495	validation_1-rmse:6.08757
# [97]	validation_0-rmse:2.22947	validation_1-rmse:6.08105
# [98]	validation_0-rmse:2.22528	validation_1-rmse:6.07399
# [99]	validation_0-rmse:2.21483	validation_1-rmse:6.07302
# [100]	validation_0-rmse:2.20049	validation_1-rmse:6.08252
# [101]	validation_0-rmse:2.18436	validation_1-rmse:6.08341
# [102]	validation_0-rmse:2.17019	validation_1-rmse:6.07771
# [103]	validation_0-rmse:2.15019	validation_1-rmse:6.06990
# [104]	validation_0-rmse:2.13124	validation_1-rmse:6.07400
# [105]	validation_0-rmse:2.12433	validation_1-rmse:6.07790
# [106]	validation_0-rmse:2.11292	validation_1-rmse:6.07764
# [107]	validation_0-rmse:2.10603	validation_1-rmse:6.08817
# [108]	validation_0-rmse:2.09096	validation_1-rmse:6.07548
# [109]	validation_0-rmse:2.08535	validation_1-rmse:6.06908
# [110]	validation_0-rmse:2.07243	validation_1-rmse:6.06423
# [111]	validation_0-rmse:2.05744	validation_1-rmse:6.06268
# [112]	validation_0-rmse:2.04623	validation_1-rmse:6.07905
# [113]	validation_0-rmse:2.03515	validation_1-rmse:6.08367
# [114]	validation_0-rmse:2.02035	validation_1-rmse:6.08392
# [115]	validation_0-rmse:2.01226	validation_1-rmse:6.09497
# [116]	validation_0-rmse:2.00784	validation_1-rmse:6.09804
# [117]	validation_0-rmse:1.99649	validation_1-rmse:6.09480
# [118]	validation_0-rmse:1.98426	validation_1-rmse:6.09776
# [119]	validation_0-rmse:1.96742	validation_1-rmse:6.09584
# [120]	validation_0-rmse:1.95755	validation_1-rmse:6.09985
# [121]	validation_0-rmse:1.94789	validation_1-rmse:6.10986
# [122]	validation_0-rmse:1.93964	validation_1-rmse:6.10079
# [123]	validation_0-rmse:1.92434	validation_1-rmse:6.09356
# [124]	validation_0-rmse:1.90802	validation_1-rmse:6.09062
# [125]	validation_0-rmse:1.88699	validation_1-rmse:6.08655
# [126]	validation_0-rmse:1.87422	validation_1-rmse:6.07880
# [127]	validation_0-rmse:1.86109	validation_1-rmse:6.08604
# [128]	validation_0-rmse:1.85087	validation_1-rmse:6.09068
# [129]	validation_0-rmse:1.84328	validation_1-rmse:6.08420
# [130]	validation_0-rmse:1.83288	validation_1-rmse:6.09261
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:14.42399	validation_1-rmse:15.92368
# [1]	validation_0-rmse:12.19825	validation_1-rmse:13.44991
# [2]	validation_0-rmse:10.58884	validation_1-rmse:11.74502
# [3]	validation_0-rmse:9.23814	validation_1-rmse:10.24041
# [4]	validation_0-rmse:8.30867	validation_1-rmse:9.24400
# [5]	validation_0-rmse:7.43924	validation_1-rmse:8.32092
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:6.77854	validation_1-rmse:7.64052
# [7]	validation_0-rmse:6.34142	validation_1-rmse:7.13957
# [8]	validation_0-rmse:5.99157	validation_1-rmse:6.75280
# [9]	validation_0-rmse:5.71830	validation_1-rmse:6.45284
# [10]	validation_0-rmse:5.53468	validation_1-rmse:6.31757
# [11]	validation_0-rmse:5.38292	validation_1-rmse:6.18990
# [12]	validation_0-rmse:5.09855	validation_1-rmse:5.99455
# [13]	validation_0-rmse:5.00303	validation_1-rmse:5.96357
# [14]	validation_0-rmse:4.91067	validation_1-rmse:5.91196
# [15]	validation_0-rmse:4.82652	validation_1-rmse:5.90376
# [16]	validation_0-rmse:4.64380	validation_1-rmse:5.86003
# [17]	validation_0-rmse:4.59878	validation_1-rmse:5.83798
# [18]	validation_0-rmse:4.49883	validation_1-rmse:5.80744
# [19]	validation_0-rmse:4.42180	validation_1-rmse:5.82341
# [20]	validation_0-rmse:4.39779	validation_1-rmse:5.81687
# [21]	validation_0-rmse:4.36089	validation_1-rmse:5.78626
# [22]	validation_0-rmse:4.23700	validation_1-rmse:5.78424
# [23]	validation_0-rmse:4.18764	validation_1-rmse:5.75388
# [24]	validation_0-rmse:4.13325	validation_1-rmse:5.74303
# [25]	validation_0-rmse:4.07448	validation_1-rmse:5.64784
# [26]	validation_0-rmse:4.04047	validation_1-rmse:5.63739
# [27]	validation_0-rmse:3.98271	validation_1-rmse:5.61978
# [28]	validation_0-rmse:3.96959	validation_1-rmse:5.60891
# [29]	validation_0-rmse:3.92406	validation_1-rmse:5.57909
# [30]	validation_0-rmse:3.90187	validation_1-rmse:5.57029
# [31]	validation_0-rmse:3.86194	validation_1-rmse:5.53954
# [32]	validation_0-rmse:3.80159	validation_1-rmse:5.54641
# [33]	validation_0-rmse:3.76132	validation_1-rmse:5.49869
# [34]	validation_0-rmse:3.69202	validation_1-rmse:5.45777
# [35]	validation_0-rmse:3.66625	validation_1-rmse:5.44205
# [36]	validation_0-rmse:3.62797	validation_1-rmse:5.42014
# [37]	validation_0-rmse:3.60501	validation_1-rmse:5.42813
# [38]	validation_0-rmse:3.59460	validation_1-rmse:5.42630
# [39]	validation_0-rmse:3.56816	validation_1-rmse:5.42589
# [40]	validation_0-rmse:3.52285	validation_1-rmse:5.41508
# [41]	validation_0-rmse:3.49642	validation_1-rmse:5.41033
# [42]	validation_0-rmse:3.46493	validation_1-rmse:5.42603
# [43]	validation_0-rmse:3.44536	validation_1-rmse:5.43374
# [44]	validation_0-rmse:3.39891	validation_1-rmse:5.41014
# [45]	validation_0-rmse:3.36516	validation_1-rmse:5.43124
# [46]	validation_0-rmse:3.34795	validation_1-rmse:5.44304
# [47]	validation_0-rmse:3.27527	validation_1-rmse:5.43258
# [48]	validation_0-rmse:3.26554	validation_1-rmse:5.43729
# [49]	validation_0-rmse:3.24433	validation_1-rmse:5.43254
# [50]	validation_0-rmse:3.21686	validation_1-rmse:5.44194
# [51]	validation_0-rmse:3.19990	validation_1-rmse:5.42941
# [52]	validation_0-rmse:3.17228	validation_1-rmse:5.42429
# [53]	validation_0-rmse:3.13892	validation_1-rmse:5.41535
# [54]	validation_0-rmse:3.09347	validation_1-rmse:5.41025
# [55]	validation_0-rmse:3.06410	validation_1-rmse:5.40959
# [56]	validation_0-rmse:3.02274	validation_1-rmse:5.37383
# [57]	validation_0-rmse:2.97546	validation_1-rmse:5.29096
# [58]	validation_0-rmse:2.94287	validation_1-rmse:5.28877
# [59]	validation_0-rmse:2.91982	validation_1-rmse:5.27746
# [60]	validation_0-rmse:2.89292	validation_1-rmse:5.30630
# [61]	validation_0-rmse:2.87747	validation_1-rmse:5.32149
# [62]	validation_0-rmse:2.84402	validation_1-rmse:5.24615
# [63]	validation_0-rmse:2.81814	validation_1-rmse:5.23158
# [64]	validation_0-rmse:2.79838	validation_1-rmse:5.22542
# [65]	validation_0-rmse:2.78017	validation_1-rmse:5.20117
# [66]	validation_0-rmse:2.75675	validation_1-rmse:5.21690
# [67]	validation_0-rmse:2.73927	validation_1-rmse:5.22742
# [68]	validation_0-rmse:2.72371	validation_1-rmse:5.23126
# [69]	validation_0-rmse:2.70659	validation_1-rmse:5.22281
# [70]	validation_0-rmse:2.68531	validation_1-rmse:5.20779
# [71]	validation_0-rmse:2.65998	validation_1-rmse:5.19461
# [72]	validation_0-rmse:2.65209	validation_1-rmse:5.19860
# [73]	validation_0-rmse:2.62670	validation_1-rmse:5.15763
# [74]	validation_0-rmse:2.61335	validation_1-rmse:5.15864
# [75]	validation_0-rmse:2.60347	validation_1-rmse:5.15465
# [76]	validation_0-rmse:2.58795	validation_1-rmse:5.12115
# [77]	validation_0-rmse:2.57223	validation_1-rmse:5.11379
# [78]	validation_0-rmse:2.55173	validation_1-rmse:5.10477
# [79]	validation_0-rmse:2.54440	validation_1-rmse:5.09732
# [80]	validation_0-rmse:2.52558	validation_1-rmse:5.08538
# [81]	validation_0-rmse:2.48840	validation_1-rmse:5.02388
# [82]	validation_0-rmse:2.48014	validation_1-rmse:5.02301
# [83]	validation_0-rmse:2.46935	validation_1-rmse:5.01901
# [84]	validation_0-rmse:2.44967	validation_1-rmse:5.01243
# [85]	validation_0-rmse:2.43952	validation_1-rmse:5.00698
# [86]	validation_0-rmse:2.41963	validation_1-rmse:5.00844
# [87]	validation_0-rmse:2.40500	validation_1-rmse:4.99862
# [88]	validation_0-rmse:2.39114	validation_1-rmse:5.01045
# [89]	validation_0-rmse:2.37797	validation_1-rmse:5.00891
# [90]	validation_0-rmse:2.35564	validation_1-rmse:4.99471
# [91]	validation_0-rmse:2.33932	validation_1-rmse:5.00016
# [92]	validation_0-rmse:2.31637	validation_1-rmse:4.96209
# [93]	validation_0-rmse:2.29936	validation_1-rmse:4.94573
# [94]	validation_0-rmse:2.28650	validation_1-rmse:4.95604
# [95]	validation_0-rmse:2.26820	validation_1-rmse:4.96667
# [96]	validation_0-rmse:2.25915	validation_1-rmse:4.97074
# [97]	validation_0-rmse:2.25511	validation_1-rmse:4.97181
# [98]	validation_0-rmse:2.24213	validation_1-rmse:4.96154
# [99]	validation_0-rmse:2.23735	validation_1-rmse:4.96676
# [100]	validation_0-rmse:2.22075	validation_1-rmse:4.96474
# [101]	validation_0-rmse:2.21697	validation_1-rmse:4.96402
# [102]	validation_0-rmse:2.19313	validation_1-rmse:4.96248
# [103]	validation_0-rmse:2.18320	validation_1-rmse:4.95145
# [104]	validation_0-rmse:2.17620	validation_1-rmse:4.94452
# [105]	validation_0-rmse:2.16527	validation_1-rmse:4.94871
# [106]	validation_0-rmse:2.15162	validation_1-rmse:4.95562
# [107]	validation_0-rmse:2.12870	validation_1-rmse:4.95906
# [108]	validation_0-rmse:2.11847	validation_1-rmse:4.96394
# [109]	validation_0-rmse:2.09400	validation_1-rmse:4.94609
# [110]	validation_0-rmse:2.07802	validation_1-rmse:4.93865
# [111]	validation_0-rmse:2.06891	validation_1-rmse:4.94430
# [112]	validation_0-rmse:2.06491	validation_1-rmse:4.94332
# [113]	validation_0-rmse:2.04829	validation_1-rmse:4.95004
# [114]	validation_0-rmse:2.03923	validation_1-rmse:4.93418
# [115]	validation_0-rmse:2.03319	validation_1-rmse:4.93355
# [116]	validation_0-rmse:2.02402	validation_1-rmse:4.94078
# [117]	validation_0-rmse:2.00926	validation_1-rmse:4.93233
# [118]	validation_0-rmse:2.00296	validation_1-rmse:4.93055
# [119]	validation_0-rmse:1.98519	validation_1-rmse:4.94498
# [120]	validation_0-rmse:1.97267	validation_1-rmse:4.94999
# [121]	validation_0-rmse:1.95766	validation_1-rmse:4.92121
# [122]	validation_0-rmse:1.95163	validation_1-rmse:4.91402
# [123]	validation_0-rmse:1.93873	validation_1-rmse:4.91448
# [124]	validation_0-rmse:1.92192	validation_1-rmse:4.91516
# [125]	validation_0-rmse:1.91425	validation_1-rmse:4.90565
# [126]	validation_0-rmse:1.89974	validation_1-rmse:4.90086
# [127]	validation_0-rmse:1.89404	validation_1-rmse:4.89990
# [128]	validation_0-rmse:1.89019	validation_1-rmse:4.90231
# [129]	validation_0-rmse:1.88172	validation_1-rmse:4.87990
# [130]	validation_0-rmse:1.86705	validation_1-rmse:4.85031
# [131]	validation_0-rmse:1.85632	validation_1-rmse:4.85158
# [132]	validation_0-rmse:1.85173	validation_1-rmse:4.85026
# [133]	validation_0-rmse:1.84505	validation_1-rmse:4.83637
# [134]	validation_0-rmse:1.83586	validation_1-rmse:4.85230
# [135]	validation_0-rmse:1.82860	validation_1-rmse:4.85205
# [136]	validation_0-rmse:1.81883	validation_1-rmse:4.86561
# [137]	validation_0-rmse:1.81382	validation_1-rmse:4.86104
# [138]	validation_0-rmse:1.79693	validation_1-rmse:4.85939
# [139]	validation_0-rmse:1.78831	validation_1-rmse:4.86335
# [140]	validation_0-rmse:1.78283	validation_1-rmse:4.87135
# [141]	validation_0-rmse:1.77971	validation_1-rmse:4.87117
# [142]	validation_0-rmse:1.77318	validation_1-rmse:4.87557
# [143]	validation_0-rmse:1.76782	validation_1-rmse:4.88160
# [144]	validation_0-rmse:1.76226	validation_1-rmse:4.87929
# [145]	validation_0-rmse:1.75554	validation_1-rmse:4.87909
# [146]	validation_0-rmse:1.74520	validation_1-rmse:4.88550
# [147]	validation_0-rmse:1.74153	validation_1-rmse:4.88915
# [148]	validation_0-rmse:1.73661	validation_1-rmse:4.88191
# [149]	validation_0-rmse:1.73535	validation_1-rmse:4.87557
# [150]	validation_0-rmse:1.72150	validation_1-rmse:4.86935
# [151]	validation_0-rmse:1.71299	validation_1-rmse:4.88281
# [152]	validation_0-rmse:1.70664	validation_1-rmse:4.89089
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:14.73861	validation_1-rmse:14.27766
# [1]	validation_0-rmse:12.37554	validation_1-rmse:12.24558
# [2]	validation_0-rmse:10.79745	validation_1-rmse:10.87214
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:9.37597	validation_1-rmse:9.70020
# [4]	validation_0-rmse:8.37590	validation_1-rmse:8.90443
# [5]	validation_0-rmse:7.52520	validation_1-rmse:8.35005
# [6]	validation_0-rmse:6.89906	validation_1-rmse:7.90903
# [7]	validation_0-rmse:6.36387	validation_1-rmse:7.44945
# [8]	validation_0-rmse:5.97875	validation_1-rmse:7.15133
# [9]	validation_0-rmse:5.68775	validation_1-rmse:6.97653
# [10]	validation_0-rmse:5.50876	validation_1-rmse:6.86431
# [11]	validation_0-rmse:5.33888	validation_1-rmse:6.79702
# [12]	validation_0-rmse:5.19392	validation_1-rmse:6.72392
# [13]	validation_0-rmse:5.07399	validation_1-rmse:6.67038
# [14]	validation_0-rmse:4.91436	validation_1-rmse:6.42624
# [15]	validation_0-rmse:4.82673	validation_1-rmse:6.41422
# [16]	validation_0-rmse:4.76051	validation_1-rmse:6.39202
# [17]	validation_0-rmse:4.67087	validation_1-rmse:6.22282
# [18]	validation_0-rmse:4.61649	validation_1-rmse:6.14816
# [19]	validation_0-rmse:4.54885	validation_1-rmse:6.12764
# [20]	validation_0-rmse:4.52136	validation_1-rmse:6.11940
# [21]	validation_0-rmse:4.43436	validation_1-rmse:6.12622
# [22]	validation_0-rmse:4.36293	validation_1-rmse:6.12057
# [23]	validation_0-rmse:4.29665	validation_1-rmse:6.11868
# [24]	validation_0-rmse:4.27191	validation_1-rmse:6.11627
# [25]	validation_0-rmse:4.26131	validation_1-rmse:6.12667
# [26]	validation_0-rmse:4.18791	validation_1-rmse:6.17027
# [27]	validation_0-rmse:4.14479	validation_1-rmse:6.18403
# [28]	validation_0-rmse:4.08523	validation_1-rmse:6.06967
# [29]	validation_0-rmse:4.03479	validation_1-rmse:5.95795
# [30]	validation_0-rmse:3.98414	validation_1-rmse:5.92650
# [31]	validation_0-rmse:3.94442	validation_1-rmse:5.91452
# [32]	validation_0-rmse:3.92276	validation_1-rmse:5.91543
# [33]	validation_0-rmse:3.86903	validation_1-rmse:5.93172
# [34]	validation_0-rmse:3.83053	validation_1-rmse:5.96384
# [35]	validation_0-rmse:3.77864	validation_1-rmse:5.87476
# [36]	validation_0-rmse:3.73406	validation_1-rmse:5.87522
# [37]	validation_0-rmse:3.70259	validation_1-rmse:5.87902
# [38]	validation_0-rmse:3.68701	validation_1-rmse:5.87499
# [39]	validation_0-rmse:3.62773	validation_1-rmse:5.87269
# [40]	validation_0-rmse:3.57272	validation_1-rmse:5.85414
# [41]	validation_0-rmse:3.52423	validation_1-rmse:5.76155
# [42]	validation_0-rmse:3.48414	validation_1-rmse:5.76177
# [43]	validation_0-rmse:3.44019	validation_1-rmse:5.72308
# [44]	validation_0-rmse:3.41560	validation_1-rmse:5.72159
# [45]	validation_0-rmse:3.38745	validation_1-rmse:5.73345
# [46]	validation_0-rmse:3.35452	validation_1-rmse:5.75085
# [47]	validation_0-rmse:3.33520	validation_1-rmse:5.68998
# [48]	validation_0-rmse:3.30357	validation_1-rmse:5.63246
# [49]	validation_0-rmse:3.28882	validation_1-rmse:5.61921
# [50]	validation_0-rmse:3.26351	validation_1-rmse:5.60023
# [51]	validation_0-rmse:3.23784	validation_1-rmse:5.55764
# [52]	validation_0-rmse:3.21294	validation_1-rmse:5.55774
# [53]	validation_0-rmse:3.17911	validation_1-rmse:5.54978
# [54]	validation_0-rmse:3.15584	validation_1-rmse:5.55802
# [55]	validation_0-rmse:3.11719	validation_1-rmse:5.55708
# [56]	validation_0-rmse:3.09158	validation_1-rmse:5.57269
# [57]	validation_0-rmse:3.08353	validation_1-rmse:5.57889
# [58]	validation_0-rmse:3.06914	validation_1-rmse:5.59785
# [59]	validation_0-rmse:3.02950	validation_1-rmse:5.61261
# [60]	validation_0-rmse:2.98409	validation_1-rmse:5.58154
# [61]	validation_0-rmse:2.96060	validation_1-rmse:5.57575
# [62]	validation_0-rmse:2.93599	validation_1-rmse:5.57746
# [63]	validation_0-rmse:2.90932	validation_1-rmse:5.57203
# [64]	validation_0-rmse:2.86883	validation_1-rmse:5.55340
# [65]	validation_0-rmse:2.84296	validation_1-rmse:5.55059
# [66]	validation_0-rmse:2.81887	validation_1-rmse:5.55830
# [67]	validation_0-rmse:2.79951	validation_1-rmse:5.55978
# [68]	validation_0-rmse:2.78674	validation_1-rmse:5.55671
# [69]	validation_0-rmse:2.76697	validation_1-rmse:5.54983
# [70]	validation_0-rmse:2.76202	validation_1-rmse:5.55804
# [71]	validation_0-rmse:2.73431	validation_1-rmse:5.55847
# [72]	validation_0-rmse:2.71639	validation_1-rmse:5.52695
# [73]	validation_0-rmse:2.70182	validation_1-rmse:5.52598
# [74]	validation_0-rmse:2.67878	validation_1-rmse:5.51779
# [75]	validation_0-rmse:2.65350	validation_1-rmse:5.50876
# [76]	validation_0-rmse:2.63239	validation_1-rmse:5.49915
# ...
# [5]	validation_0-rmse:7.61311	validation_1-rmse:6.94079
# [6]	validation_0-rmse:6.98532	validation_1-rmse:6.37601
# [7]	validation_0-rmse:6.50997	validation_1-rmse:5.94870
# [8]	validation_0-rmse:6.16836	validation_1-rmse:5.72353
# [9]	validation_0-rmse:5.93149	validation_1-rmse:5.55347
# [10]	validation_0-rmse:5.71124	validation_1-rmse:5.47681
# [11]	validation_0-rmse:5.54837	validation_1-rmse:5.41316
# [12]	validation_0-rmse:5.25061	validation_1-rmse:5.31928
# [13]	validation_0-rmse:5.16301	validation_1-rmse:5.30451
# [14]	validation_0-rmse:4.95991	validation_1-rmse:5.30110
# [15]	validation_0-rmse:4.88571	validation_1-rmse:5.22633
# [16]	validation_0-rmse:4.75768	validation_1-rmse:5.23268
# [17]	validation_0-rmse:4.69156	validation_1-rmse:5.16068
# [18]	validation_0-rmse:4.65717	validation_1-rmse:5.15085
# [19]	validation_0-rmse:4.62647	validation_1-rmse:5.15014
# [20]	validation_0-rmse:4.60730	validation_1-rmse:5.14796
# [21]	validation_0-rmse:4.52308	validation_1-rmse:5.12986
# [22]	validation_0-rmse:4.44163	validation_1-rmse:5.10491
# [23]	validation_0-rmse:4.41122	validation_1-rmse:5.12136
# [24]	validation_0-rmse:4.34282	validation_1-rmse:5.09992
# [25]	validation_0-rmse:4.31935	validation_1-rmse:5.11444
# [26]	validation_0-rmse:4.28314	validation_1-rmse:5.07102
# [27]	validation_0-rmse:4.20772	validation_1-rmse:5.07228
# [28]	validation_0-rmse:4.16586	validation_1-rmse:5.06906
# [29]	validation_0-rmse:4.13975	validation_1-rmse:5.07725
# [30]	validation_0-rmse:4.07289	validation_1-rmse:4.93428
# [31]	validation_0-rmse:4.01084	validation_1-rmse:4.93771
# [32]	validation_0-rmse:3.96445	validation_1-rmse:4.93684
# [33]	validation_0-rmse:3.89743	validation_1-rmse:4.90774
# [34]	validation_0-rmse:3.84901	validation_1-rmse:4.91609
# [35]	validation_0-rmse:3.81053	validation_1-rmse:4.88743
# [36]	validation_0-rmse:3.78146	validation_1-rmse:4.86941
# [37]	validation_0-rmse:3.74612	validation_1-rmse:4.87613
# [38]	validation_0-rmse:3.71924	validation_1-rmse:4.87582
# [39]	validation_0-rmse:3.67334	validation_1-rmse:4.83046
# [40]	validation_0-rmse:3.64055	validation_1-rmse:4.80468
# [41]	validation_0-rmse:3.62837	validation_1-rmse:4.79710
# [42]	validation_0-rmse:3.60417	validation_1-rmse:4.79632
# [43]	validation_0-rmse:3.58081	validation_1-rmse:4.78917
# [44]	validation_0-rmse:3.54892	validation_1-rmse:4.71781
# [45]	validation_0-rmse:3.53736	validation_1-rmse:4.72278
# [46]	validation_0-rmse:3.50530	validation_1-rmse:4.73070
# [47]	validation_0-rmse:3.47733	validation_1-rmse:4.72770
# [48]	validation_0-rmse:3.41781	validation_1-rmse:4.72021
# [49]	validation_0-rmse:3.40029	validation_1-rmse:4.71814
# [50]	validation_0-rmse:3.38500	validation_1-rmse:4.72327
# [51]	validation_0-rmse:3.33583	validation_1-rmse:4.65222
# [52]	validation_0-rmse:3.29242	validation_1-rmse:4.64185
# [53]	validation_0-rmse:3.26583	validation_1-rmse:4.64204
# [54]	validation_0-rmse:3.25430	validation_1-rmse:4.64201
# [55]	validation_0-rmse:3.21528	validation_1-rmse:4.60257
# [56]	validation_0-rmse:3.18889	validation_1-rmse:4.57132
# [57]	validation_0-rmse:3.16131	validation_1-rmse:4.54652
# [58]	validation_0-rmse:3.12813	validation_1-rmse:4.55638
# [59]	validation_0-rmse:3.10311	validation_1-rmse:4.55602
# [60]	validation_0-rmse:3.07953	validation_1-rmse:4.56360
# [61]	validation_0-rmse:3.06259	validation_1-rmse:4.57316
# [62]	validation_0-rmse:3.03524	validation_1-rmse:4.57343
# [63]	validation_0-rmse:3.00251	validation_1-rmse:4.55192
# [64]	validation_0-rmse:2.99176	validation_1-rmse:4.53343
# [65]	validation_0-rmse:2.97273	validation_1-rmse:4.49162
# [66]	validation_0-rmse:2.94795	validation_1-rmse:4.47854
# [67]	validation_0-rmse:2.92897	validation_1-rmse:4.47624
# [68]	validation_0-rmse:2.90572	validation_1-rmse:4.47308
# [69]	validation_0-rmse:2.88200	validation_1-rmse:4.46296
# [70]	validation_0-rmse:2.86374	validation_1-rmse:4.48395
# [71]	validation_0-rmse:2.83466	validation_1-rmse:4.49385
# [72]	validation_0-rmse:2.82982	validation_1-rmse:4.49648
# [73]	validation_0-rmse:2.82038	validation_1-rmse:4.50362
# [74]	validation_0-rmse:2.78621	validation_1-rmse:4.47043
# [75]	validation_0-rmse:2.77041	validation_1-rmse:4.47614
# [76]	validation_0-rmse:2.74950	validation_1-rmse:4.48044
# [77]	validation_0-rmse:2.73190	validation_1-rmse:4.46552
# [78]	validation_0-rmse:2.72456	validation_1-rmse:4.46664
# [79]	validation_0-rmse:2.70690	validation_1-rmse:4.43538
# [80]	validation_0-rmse:2.69081	validation_1-rmse:4.42040
# [81]	validation_0-rmse:2.67678	validation_1-rmse:4.41640
# [82]	validation_0-rmse:2.66029	validation_1-rmse:4.43079
# [83]	validation_0-rmse:2.64976	validation_1-rmse:4.42697
# [84]	validation_0-rmse:2.62563	validation_1-rmse:4.41932
# [85]	validation_0-rmse:2.60815	validation_1-rmse:4.43674
# [86]	validation_0-rmse:2.58631	validation_1-rmse:4.41488
# [87]	validation_0-rmse:2.56518	validation_1-rmse:4.41509
# [88]	validation_0-rmse:2.54984	validation_1-rmse:4.40796
# [89]	validation_0-rmse:2.53905	validation_1-rmse:4.41485
# [90]	validation_0-rmse:2.52561	validation_1-rmse:4.44805
# [91]	validation_0-rmse:2.51312	validation_1-rmse:4.44764
# [92]	validation_0-rmse:2.50232	validation_1-rmse:4.45162
# [93]	validation_0-rmse:2.49047	validation_1-rmse:4.45249
# [94]	validation_0-rmse:2.48009	validation_1-rmse:4.44776
# [95]	validation_0-rmse:2.47563	validation_1-rmse:4.44880
# [96]	validation_0-rmse:2.45801	validation_1-rmse:4.45963
# [97]	validation_0-rmse:2.44279	validation_1-rmse:4.46076
# [98]	validation_0-rmse:2.42194	validation_1-rmse:4.45688
# [99]	validation_0-rmse:2.40126	validation_1-rmse:4.45652
# [100]	validation_0-rmse:2.38026	validation_1-rmse:4.44668
# [101]	validation_0-rmse:2.35982	validation_1-rmse:4.44451
# [102]	validation_0-rmse:2.35220	validation_1-rmse:4.44834
# [103]	validation_0-rmse:2.33281	validation_1-rmse:4.44868
# [104]	validation_0-rmse:2.32015	validation_1-rmse:4.44648
# [105]	validation_0-rmse:2.30712	validation_1-rmse:4.44548
# [106]	validation_0-rmse:2.28628	validation_1-rmse:4.43716
# [107]	validation_0-rmse:2.26485	validation_1-rmse:4.43547
# [108]	validation_0-rmse:2.24375	validation_1-rmse:4.44102
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:14.61613	validation_1-rmse:15.12975
# [1]	validation_0-rmse:12.32216	validation_1-rmse:13.12138
# [2]	validation_0-rmse:10.78540	validation_1-rmse:11.78220
# [3]	validation_0-rmse:9.37400	validation_1-rmse:10.57078
# [4]	validation_0-rmse:8.37530	validation_1-rmse:9.83440
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:7.51382	validation_1-rmse:8.95712
# [6]	validation_0-rmse:6.81148	validation_1-rmse:8.33549
# [7]	validation_0-rmse:6.37636	validation_1-rmse:7.99507
# [8]	validation_0-rmse:5.99103	validation_1-rmse:7.72501
# [9]	validation_0-rmse:5.69569	validation_1-rmse:7.48211
# [10]	validation_0-rmse:5.46525	validation_1-rmse:7.41677
# [11]	validation_0-rmse:5.24651	validation_1-rmse:7.36308
# [12]	validation_0-rmse:5.05577	validation_1-rmse:7.27291
# [13]	validation_0-rmse:4.92771	validation_1-rmse:7.26940
# [14]	validation_0-rmse:4.84303	validation_1-rmse:7.20433
# [15]	validation_0-rmse:4.75846	validation_1-rmse:7.18786
# [16]	validation_0-rmse:4.60667	validation_1-rmse:6.94033
# [17]	validation_0-rmse:4.49664	validation_1-rmse:6.75969
# [18]	validation_0-rmse:4.46704	validation_1-rmse:6.74266
# [19]	validation_0-rmse:4.42472	validation_1-rmse:6.72078
# [20]	validation_0-rmse:4.37556	validation_1-rmse:6.71593
# [21]	validation_0-rmse:4.31827	validation_1-rmse:6.71966
# [22]	validation_0-rmse:4.22877	validation_1-rmse:6.58100
# [23]	validation_0-rmse:4.18939	validation_1-rmse:6.55009
# [24]	validation_0-rmse:4.11731	validation_1-rmse:6.41465
# [25]	validation_0-rmse:4.06668	validation_1-rmse:6.36857
# [26]	validation_0-rmse:3.98620	validation_1-rmse:6.36008
# [27]	validation_0-rmse:3.93579	validation_1-rmse:6.38955
# [28]	validation_0-rmse:3.91551	validation_1-rmse:6.37499
# [29]	validation_0-rmse:3.86058	validation_1-rmse:6.35332
# [30]	validation_0-rmse:3.83369	validation_1-rmse:6.34082
# [31]	validation_0-rmse:3.78002	validation_1-rmse:6.35965
# [32]	validation_0-rmse:3.72622	validation_1-rmse:6.31422
# [33]	validation_0-rmse:3.67547	validation_1-rmse:6.28103
# [34]	validation_0-rmse:3.62979	validation_1-rmse:6.29331
# [35]	validation_0-rmse:3.60278	validation_1-rmse:6.27861
# [36]	validation_0-rmse:3.56004	validation_1-rmse:6.24938
# [37]	validation_0-rmse:3.52223	validation_1-rmse:6.24604
# [38]	validation_0-rmse:3.47475	validation_1-rmse:6.23701
# [39]	validation_0-rmse:3.45312	validation_1-rmse:6.20657
# [40]	validation_0-rmse:3.43230	validation_1-rmse:6.20740
# [41]	validation_0-rmse:3.37404	validation_1-rmse:6.13600
# [42]	validation_0-rmse:3.35601	validation_1-rmse:6.12675
# [43]	validation_0-rmse:3.32217	validation_1-rmse:6.14265
# [44]	validation_0-rmse:3.30301	validation_1-rmse:6.14215
# [45]	validation_0-rmse:3.27622	validation_1-rmse:6.16342
# [46]	validation_0-rmse:3.23249	validation_1-rmse:6.16023
# [47]	validation_0-rmse:3.20611	validation_1-rmse:6.14670
# [48]	validation_0-rmse:3.16892	validation_1-rmse:6.14319
# [49]	validation_0-rmse:3.12691	validation_1-rmse:6.08365
# [50]	validation_0-rmse:3.10239	validation_1-rmse:6.08674
# [51]	validation_0-rmse:3.09009	validation_1-rmse:6.08182
# [52]	validation_0-rmse:3.08126	validation_1-rmse:6.05471
# [53]	validation_0-rmse:3.03722	validation_1-rmse:6.00495
# [54]	validation_0-rmse:3.02469	validation_1-rmse:6.00468
# [55]	validation_0-rmse:2.99748	validation_1-rmse:5.99682
# [56]	validation_0-rmse:2.98052	validation_1-rmse:6.00151
# [57]	validation_0-rmse:2.93329	validation_1-rmse:5.99063
# [58]	validation_0-rmse:2.91198	validation_1-rmse:5.98464
# [59]	validation_0-rmse:2.88142	validation_1-rmse:5.98705
# [60]	validation_0-rmse:2.86607	validation_1-rmse:5.98686
# [61]	validation_0-rmse:2.84536	validation_1-rmse:5.98405
# [62]	validation_0-rmse:2.82502	validation_1-rmse:5.97357
# [63]	validation_0-rmse:2.79157	validation_1-rmse:5.93982
# [64]	validation_0-rmse:2.76651	validation_1-rmse:5.92613
# [65]	validation_0-rmse:2.75534	validation_1-rmse:5.91497
# [66]	validation_0-rmse:2.73298	validation_1-rmse:5.91067
# [67]	validation_0-rmse:2.71116	validation_1-rmse:5.91888
# [68]	validation_0-rmse:2.69173	validation_1-rmse:5.90951
# [69]	validation_0-rmse:2.67870	validation_1-rmse:5.90070
# [70]	validation_0-rmse:2.66238	validation_1-rmse:5.89631
# [71]	validation_0-rmse:2.63803	validation_1-rmse:5.89500
# [72]	validation_0-rmse:2.62472	validation_1-rmse:5.86821
# [73]	validation_0-rmse:2.61034	validation_1-rmse:5.84251
# [74]	validation_0-rmse:2.58924	validation_1-rmse:5.83904
# [75]	validation_0-rmse:2.57596	validation_1-rmse:5.83159
# [76]	validation_0-rmse:2.55694	validation_1-rmse:5.82026
# [77]	validation_0-rmse:2.54697	validation_1-rmse:5.83355
# [78]	validation_0-rmse:2.52645	validation_1-rmse:5.83785
# [79]	validation_0-rmse:2.51646	validation_1-rmse:5.83887
# [80]	validation_0-rmse:2.50759	validation_1-rmse:5.84088
# [81]	validation_0-rmse:2.47724	validation_1-rmse:5.82660
# [82]	validation_0-rmse:2.45793	validation_1-rmse:5.79614
# [83]	validation_0-rmse:2.44728	validation_1-rmse:5.78988
# [84]	validation_0-rmse:2.43027	validation_1-rmse:5.77820
# [85]	validation_0-rmse:2.42355	validation_1-rmse:5.77537
# [86]	validation_0-rmse:2.39991	validation_1-rmse:5.78110
# [87]	validation_0-rmse:2.38402	validation_1-rmse:5.77844
# [88]	validation_0-rmse:2.37699	validation_1-rmse:5.78193
# [89]	validation_0-rmse:2.36498	validation_1-rmse:5.79439
# [90]	validation_0-rmse:2.35317	validation_1-rmse:5.78554
# [91]	validation_0-rmse:2.33421	validation_1-rmse:5.79035
# [92]	validation_0-rmse:2.32812	validation_1-rmse:5.79522
# [93]	validation_0-rmse:2.31203	validation_1-rmse:5.79264
# [94]	validation_0-rmse:2.29547	validation_1-rmse:5.78729
# [95]	validation_0-rmse:2.28742	validation_1-rmse:5.79686
# [96]	validation_0-rmse:2.27396	validation_1-rmse:5.78068
# [97]	validation_0-rmse:2.25562	validation_1-rmse:5.77198
# [98]	validation_0-rmse:2.24264	validation_1-rmse:5.77780
# [99]	validation_0-rmse:2.22283	validation_1-rmse:5.77721
# [100]	validation_0-rmse:2.20962	validation_1-rmse:5.77138
# [101]	validation_0-rmse:2.19141	validation_1-rmse:5.77344
# [102]	validation_0-rmse:2.17637	validation_1-rmse:5.76457
# [103]	validation_0-rmse:2.16169	validation_1-rmse:5.77744
# [104]	validation_0-rmse:2.15443	validation_1-rmse:5.77187
# [105]	validation_0-rmse:2.14851	validation_1-rmse:5.77210
# [106]	validation_0-rmse:2.13373	validation_1-rmse:5.77278
# [107]	validation_0-rmse:2.11436	validation_1-rmse:5.76922
# [108]	validation_0-rmse:2.10297	validation_1-rmse:5.76642
# [109]	validation_0-rmse:2.09405	validation_1-rmse:5.75758
# [110]	validation_0-rmse:2.07367	validation_1-rmse:5.72561
# [111]	validation_0-rmse:2.06130	validation_1-rmse:5.72693
# [112]	validation_0-rmse:2.04829	validation_1-rmse:5.71157
# [113]	validation_0-rmse:2.02823	validation_1-rmse:5.70761
# [114]	validation_0-rmse:2.02201	validation_1-rmse:5.70698
# [115]	validation_0-rmse:2.00128	validation_1-rmse:5.70054
# [116]	validation_0-rmse:1.99091	validation_1-rmse:5.70124
# [117]	validation_0-rmse:1.98310	validation_1-rmse:5.69779
# [118]	validation_0-rmse:1.97643	validation_1-rmse:5.69089
# [119]	validation_0-rmse:1.96074	validation_1-rmse:5.69769
# [120]	validation_0-rmse:1.94664	validation_1-rmse:5.69697
# [121]	validation_0-rmse:1.93667	validation_1-rmse:5.69776
# [122]	validation_0-rmse:1.92861	validation_1-rmse:5.68717
# [123]	validation_0-rmse:1.91855	validation_1-rmse:5.68391
# [124]	validation_0-rmse:1.90753	validation_1-rmse:5.68829
# [125]	validation_0-rmse:1.90026	validation_1-rmse:5.68728
# [126]	validation_0-rmse:1.88852	validation_1-rmse:5.69129
# [127]	validation_0-rmse:1.87954	validation_1-rmse:5.68346
# [128]	validation_0-rmse:1.86932	validation_1-rmse:5.68607
# [129]	validation_0-rmse:1.86132	validation_1-rmse:5.68527
# [130]	validation_0-rmse:1.84190	validation_1-rmse:5.68278
# [131]	validation_0-rmse:1.83360	validation_1-rmse:5.68099
# [132]	validation_0-rmse:1.82699	validation_1-rmse:5.68536
# [133]	validation_0-rmse:1.81551	validation_1-rmse:5.68266
# [134]	validation_0-rmse:1.81022	validation_1-rmse:5.67525
# [135]	validation_0-rmse:1.80456	validation_1-rmse:5.67509
# [136]	validation_0-rmse:1.79918	validation_1-rmse:5.67756
# [137]	validation_0-rmse:1.79550	validation_1-rmse:5.67238
# [138]	validation_0-rmse:1.78574	validation_1-rmse:5.67264
# [139]	validation_0-rmse:1.77968	validation_1-rmse:5.66898
# [140]	validation_0-rmse:1.76876	validation_1-rmse:5.66381
# [141]	validation_0-rmse:1.76039	validation_1-rmse:5.67002
# [142]	validation_0-rmse:1.75259	validation_1-rmse:5.65855
# [143]	validation_0-rmse:1.74561	validation_1-rmse:5.66041
# [144]	validation_0-rmse:1.73654	validation_1-rmse:5.66043
# [145]	validation_0-rmse:1.73104	validation_1-rmse:5.66076
# [146]	validation_0-rmse:1.72335	validation_1-rmse:5.66549
# [147]	validation_0-rmse:1.71724	validation_1-rmse:5.66501
# [148]	validation_0-rmse:1.70884	validation_1-rmse:5.67119
# [149]	validation_0-rmse:1.70120	validation_1-rmse:5.66963
# [150]	validation_0-rmse:1.68918	validation_1-rmse:5.66384
# [151]	validation_0-rmse:1.68204	validation_1-rmse:5.67004
# [152]	validation_0-rmse:1.67266	validation_1-rmse:5.68483
# [153]	validation_0-rmse:1.66157	validation_1-rmse:5.68429
# [154]	validation_0-rmse:1.65317	validation_1-rmse:5.68915
# [155]	validation_0-rmse:1.64630	validation_1-rmse:5.68563
# [156]	validation_0-rmse:1.64015	validation_1-rmse:5.69321
# [157]	validation_0-rmse:1.63313	validation_1-rmse:5.69352
# [158]	validation_0-rmse:1.62557	validation_1-rmse:5.68680
# [159]	validation_0-rmse:1.62140	validation_1-rmse:5.68581
# [160]	validation_0-rmse:1.60996	validation_1-rmse:5.67105
# [161]	validation_0-rmse:1.59801	validation_1-rmse:5.67355
# [162]	validation_0-rmse:1.59237	validation_1-rmse:5.67705
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['16%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(0.6, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.775
# Uncertainty
# a0: 3.21+/-0.253
# a1: 0.7562+/-0.014

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: BA_sq_m_ha: mean - 2.725, median - 2.759, CI - [2.458-2.999]
#
# SHAP-values for: DBH_cm: mean - 2.202, median - 2.23, CI - [1.92-2.491]
#
# SHAP-values for: H_m: mean - 1.583, median - 1.559, CI - [1.392-1.78]
#
# SHAP-values for: Origin_ID: mean - 0.303, median - 0.301, CI - [0.25-0.359]
#
# SHAP-values for: Species_ID: mean - 4.138, median - 4.161, CI - [3.935-4.33]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['Species_ID', 'BA_sq_m_ha', 'DBH_cm', 'H_m', 'Origin_ID'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 87.65, median: 86.5,
#  pred. interval (P(0.025)-P(0.975)): 22.925-166.025,
#  conf. interval (p-value=0.95): 44.86-130.827
# ***
# Aggregate bias statistic:
#  mean: -0.161, median: -0.12,
#  pred. interval (P(0.025)-P(0.975)): -1.175-0.675,
#  conf. interval (p-value=0.95): -0.525-0.221
# ***
# Aggregate RMSE statistic:
#  mean: 5.468, median: 5.393, pred. interval (P(0.025)-P(0.975)): 4.406-6.89,
#  conf. interval (p-value=0.95): 4.894-6.03
# ***
# Aggregate MSE statistic:
#  mean: 30.305, median: 29.087, pred. interval (P(0.025)-P(0.975)): 19.411-47.472,
#  conf. interval (p-value=0.95): 23.982-36.408
# ***
# Aggregate R^2 statistic:
#  mean: 0.769, median: 0.775, pred. interval (P(0.025)-P(0.975)): 0.653-0.853,
#  conf. interval (p-value=0.95): 0.727-0.815
# ***
# Aggregate bias(%) statistic:
#  mean: -1.073, median: -0.12, pred. interval (P(0.025)-P(0.975)): -7.978-4.945,
#  conf. interval (p-value=0.95): -3.731-1.64
# ***
# Aggregate RMSE(%) statistic:
#  mean: 39.618, median: 39.48, pred. interval (P(0.025)-P(0.975)): 32.321-48.028,
#  conf. interval (p-value=0.95): 35.531-43.405
# ***

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:14.66011
# [1]	validation_0-rmse:12.36023
# [2]	validation_0-rmse:10.58667
# [3]	validation_0-rmse:9.31591
# [4]	validation_0-rmse:8.30416
# [5]	validation_0-rmse:7.55587
# [6]	validation_0-rmse:6.95542
# [7]	validation_0-rmse:6.47527
# [8]	validation_0-rmse:6.15947
# [9]	validation_0-rmse:5.90619
# [10]	validation_0-rmse:5.68390
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:5.52732
# [12]	validation_0-rmse:5.28280
# [13]	validation_0-rmse:5.18979
# [14]	validation_0-rmse:5.11632
# [15]	validation_0-rmse:5.05383
# [16]	validation_0-rmse:4.89428
# [17]	validation_0-rmse:4.75572
# [18]	validation_0-rmse:4.68685
# [19]	validation_0-rmse:4.61631
# [20]	validation_0-rmse:4.54745
# [21]	validation_0-rmse:4.47225
# [22]	validation_0-rmse:4.42092
# [23]	validation_0-rmse:4.39596
# [24]	validation_0-rmse:4.38117
# [25]	validation_0-rmse:4.35364
# [26]	validation_0-rmse:4.31483
# [27]	validation_0-rmse:4.25265
# [28]	validation_0-rmse:4.19959
# [29]	validation_0-rmse:4.16540
# [30]	validation_0-rmse:4.14094
# [31]	validation_0-rmse:4.06418
# [32]	validation_0-rmse:3.98665
# [33]	validation_0-rmse:3.97202
# [34]	validation_0-rmse:3.92912
# [35]	validation_0-rmse:3.86894
# [36]	validation_0-rmse:3.85441
# [37]	validation_0-rmse:3.83833
# [38]	validation_0-rmse:3.79129
# [39]	validation_0-rmse:3.75902
# [40]	validation_0-rmse:3.74319
# [41]	validation_0-rmse:3.72701
# [42]	validation_0-rmse:3.70797
# [43]	validation_0-rmse:3.65653
# [44]	validation_0-rmse:3.61830
# [45]	validation_0-rmse:3.58695
# [46]	validation_0-rmse:3.54757
# [47]	validation_0-rmse:3.50920
# [48]	validation_0-rmse:3.47719
# [49]	validation_0-rmse:3.46512
# [50]	validation_0-rmse:3.44066
# [51]	validation_0-rmse:3.40068
# [52]	validation_0-rmse:3.39374
# [53]	validation_0-rmse:3.35705
# [54]	validation_0-rmse:3.30876
# [55]	validation_0-rmse:3.28480
# [56]	validation_0-rmse:3.24242
# [57]	validation_0-rmse:3.23203
# [58]	validation_0-rmse:3.21043
# [59]	validation_0-rmse:3.20191
# [60]	validation_0-rmse:3.16917
# [61]	validation_0-rmse:3.16273
# [62]	validation_0-rmse:3.14412
# [63]	validation_0-rmse:3.11676
# [64]	validation_0-rmse:3.09096
# [65]	validation_0-rmse:3.06285
# [66]	validation_0-rmse:3.02491
# [67]	validation_0-rmse:3.00552
# [68]	validation_0-rmse:2.98099
# [69]	validation_0-rmse:2.96612
# [70]	validation_0-rmse:2.94619
# [71]	validation_0-rmse:2.93767
# [72]	validation_0-rmse:2.90383
# [73]	validation_0-rmse:2.88888
# [74]	validation_0-rmse:2.85898
# [75]	validation_0-rmse:2.83755
# [76]	validation_0-rmse:2.82116
# [77]	validation_0-rmse:2.80924
# [78]	validation_0-rmse:2.78363
# [79]	validation_0-rmse:2.76607
# [80]	validation_0-rmse:2.74900
# [81]	validation_0-rmse:2.73660
# [82]	validation_0-rmse:2.73155
# [83]	validation_0-rmse:2.70251
# [84]	validation_0-rmse:2.68425
# [85]	validation_0-rmse:2.66908
# [86]	validation_0-rmse:2.65885
# [87]	validation_0-rmse:2.63218
# [88]	validation_0-rmse:2.61590
# [89]	validation_0-rmse:2.59226
# [90]	validation_0-rmse:2.57799
# [91]	validation_0-rmse:2.56162
# [92]	validation_0-rmse:2.54484
# [93]	validation_0-rmse:2.50725
# [94]	validation_0-rmse:2.49030
# [95]	validation_0-rmse:2.47245
# [96]	validation_0-rmse:2.45806
# [97]	validation_0-rmse:2.44544
# [98]	validation_0-rmse:2.43038
# [99]	validation_0-rmse:2.42178
# [100]	validation_0-rmse:2.40984
# [101]	validation_0-rmse:2.40145
# [102]	validation_0-rmse:2.38524
# [103]	validation_0-rmse:2.36758
# [104]	validation_0-rmse:2.35363
# [105]	validation_0-rmse:2.33961
# [106]	validation_0-rmse:2.32038
# [107]	validation_0-rmse:2.30884
# [108]	validation_0-rmse:2.30005
# [109]	validation_0-rmse:2.29228
# [110]	validation_0-rmse:2.27247
# [111]	validation_0-rmse:2.25451
# [112]	validation_0-rmse:2.24230
# [113]	validation_0-rmse:2.22972
# [114]	validation_0-rmse:2.22071
# [115]	validation_0-rmse:2.21135
# [116]	validation_0-rmse:2.20572
# [117]	validation_0-rmse:2.18897
# [118]	validation_0-rmse:2.18431
# [119]	validation_0-rmse:2.17531
# [120]	validation_0-rmse:2.15855
# [121]	validation_0-rmse:2.14477
# [122]	validation_0-rmse:2.13596
# [123]	validation_0-rmse:2.12500
# [124]	validation_0-rmse:2.11457
# [125]	validation_0-rmse:2.10371
# [126]	validation_0-rmse:2.09724
# [127]	validation_0-rmse:2.08059
# [128]	validation_0-rmse:2.07559
# [129]	validation_0-rmse:2.06172
# [130]	validation_0-rmse:2.05385
# [131]	validation_0-rmse:2.04390
# [132]	validation_0-rmse:2.03577
# [133]	validation_0-rmse:2.01902
# [134]	validation_0-rmse:2.01273
# [135]	validation_0-rmse:2.00430
# [136]	validation_0-rmse:1.99573
# [137]	validation_0-rmse:1.98753
# [138]	validation_0-rmse:1.97936
# [139]	validation_0-rmse:1.96925
# [140]	validation_0-rmse:1.96136
# [141]	validation_0-rmse:1.95419
# [142]	validation_0-rmse:1.94649
# [143]	validation_0-rmse:1.93397
# [144]	validation_0-rmse:1.92498
# [145]	validation_0-rmse:1.91874
# [146]	validation_0-rmse:1.91422
# [147]	validation_0-rmse:1.90935
# [148]	validation_0-rmse:1.89635
# [149]	validation_0-rmse:1.88992
# [150]	validation_0-rmse:1.88216
# [151]	validation_0-rmse:1.87579
# [152]	validation_0-rmse:1.86719
# [153]	validation_0-rmse:1.85795
# [154]	validation_0-rmse:1.84696
# [155]	validation_0-rmse:1.83827
# [156]	validation_0-rmse:1.83087
# [157]	validation_0-rmse:1.82010
# [158]	validation_0-rmse:1.81509
# [159]	validation_0-rmse:1.80723
# [160]	validation_0-rmse:1.80018
# [161]	validation_0-rmse:1.79369
# [162]	validation_0-rmse:1.78378
# [163]	validation_0-rmse:1.77438
# [164]	validation_0-rmse:1.76431
# [165]	validation_0-rmse:1.75661
# [166]	validation_0-rmse:1.75013
# [167]	validation_0-rmse:1.74127
# [168]	validation_0-rmse:1.73798
# [169]	validation_0-rmse:1.73285
# [170]	validation_0-rmse:1.71821
# [171]	validation_0-rmse:1.71162
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 171

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.04
# RMSE: 1.7
# Relative RMSE(%):  12.383
# MSE: 2.9
# R square: 97.8%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0.9, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.979
# Uncertainty
# a0: 0.65+/-0.09
# a1: 0.952+/-0.005

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../01_output_data/XGBoost_models/04_M_branch_other_authors_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../01_output_data/XGBoost_models/04_M_branch_other_authors_XGB_model.txt")
