# %% [markdown]
# ## Processing with aboveground biomass data based on my fieldworks and other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
input_data = './FULL_DB_BIOMASS_OTHER_ALL_AUTHORS.csv'
df = pd.read_csv(input_data)
df.head()
# Out:
#    Groups Species  Species_ID Origin  Origin_ID  SI  A_years   H_m  DBH_cm  \
# 0       1    Pine           0      n        0.0   4       50   9.7    14.6
# 1       1    Pine           0      n        0.0   2       65  20.6    20.6
# 2       1    Pine           0      n        0.0   2       50  13.6    15.4
# 3       1    Pine           0      n        0.0   1       60  23.3    22.2
# 4       1    Pine           0      n        0.0   3       65  15.6    16.4
#
#    N_trees  ...  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  \
# 0    486.0  ...             NaN             NaN         8.4           1.6
# 1    785.0  ...             NaN             NaN        11.5           4.1
# 2   1745.0  ...             NaN             NaN        13.7           4.1
# 3    665.0  ...             NaN             NaN        14.4           5.4
# 4    955.0  ...             NaN             NaN        14.2           3.4
#
#    LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  \
# 0         3.78              2.94                NaN                NaN
# 1         5.54              4.73                NaN                NaN
# 2         5.25              4.48                NaN                NaN
# 3         5.63              4.67                NaN                NaN
# 4         4.96              4.20                NaN                NaN
#
#    LN_Crown_t_ha  LN_Foliage_t_ha
# 0           2.13             0.47
# 1           2.44             1.41
# 2           2.62             1.41
# 3           2.67             1.69
# 4           2.65             1.22
#
# [5 rows x 24 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
#
# 'Groups','Species_ID','Origin_ID','SI','A_years','H_m','DBH_cm','RS(P)',          'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
# 'Crown_t_ha','Foliage_t_ha'
# 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species_ID','Origin_ID','H_m','DBH_cm', 'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
'Crown_t_ha','Foliage_t_ha', 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0           0        0.0   9.7    14.6         9.7      43.9           18.9
# 1           0        0.0  20.6    20.6        32.2     254.0          113.1
# 2           0        0.0  13.6    15.4        35.2     190.0           87.8
# 3           0        0.0  23.3    22.2        29.6     277.7          106.5
# 4           0        0.0  15.6    16.4        20.4     142.5           67.0
#
#    Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0             NaN             NaN         8.4           1.6         3.78
# 1             NaN             NaN        11.5           4.1         5.54
# 2             NaN             NaN        13.7           4.1         5.25
# 3             NaN             NaN        14.4           5.4         5.63
# 4             NaN             NaN        14.2           3.4         4.96
#
#    LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0              2.94                NaN                NaN           2.13
# 1              4.73                NaN                NaN           2.44
# 2              4.48                NaN                NaN           2.62
# 3              4.67                NaN                NaN           2.67
# 4              4.20                NaN                NaN           2.65
#
#    LN_Foliage_t_ha
# 0             0.47
# 1             1.41
# 2             1.41
# 3             1.69
# 4             1.22

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Species_ID         857 non-null    int64
#  1   Origin_ID          856 non-null    float64
#  2   H_m                857 non-null    float64
#  3   DBH_cm             856 non-null    float64
#  4   BA_sq_m_ha         857 non-null    float64
#  5   GS_cub_m           857 non-null    float64
#  6   ALL_STEM_t_ha      855 non-null    float64
#  7   Stem_wood_t_ha     747 non-null    float64
#  8   Stem_bark_t_ha     747 non-null    float64
#  9   Crown_t_ha         843 non-null    float64
#  10  Foliage_t_ha       854 non-null    float64
#  11  LN_GS_cub_m        857 non-null    float64
#  12  LN_ALL_STEM_t_ha   855 non-null    float64
#  13  LN_Stem_wood_t_ha  747 non-null    float64
#  14  LN_Stem_bark_t_ha  747 non-null    float64
#  15  LN_Crown_t_ha      843 non-null    float64
#  16  LN_Foliage_t_ha    854 non-null    float64
# dtypes: float64(16), int64(1)
# memory usage: 113.9 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species_ID"])["Stem_bark_t_ha", "ALL_STEM_t_ha"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            Stem_bark_t_ha                                                    \
#                     count       mean        std  min     25%    50%     75%
# Species_ID
# 0                   371.0   7.894070   4.128113  0.3   4.900   7.70  10.350
# 1                     7.0  34.728571  23.382095  8.3  13.950  35.70  52.750
# 2                   120.0  11.320000   7.552123  0.8   6.375   9.45  15.250
# 3                   115.0  15.307826   8.294197  2.1   7.950  15.30  21.450
# 4                    66.0  11.296970   6.528234  1.6   6.500   9.25  16.575
# 5                    68.0  29.010294  12.702287  2.5  18.400  29.70  39.675
#
#                  ALL_STEM_t_ha                                              \
#              max         count        mean        std   min     25%    50%
# Species_ID
# 0           23.2         457.0   97.049891  61.854506   1.8  47.500   92.7
# 1           65.7           7.0  123.814286  61.879895  46.3  70.650  133.9
# 2           38.8         120.0   74.495000  44.523333   5.1  37.275   68.1
# 3           41.1         115.0  107.607826  55.589186  11.0  62.700  106.8
# 4           28.7          66.0   84.946970  58.875162   8.2  40.750   61.2
# 5           48.8          90.0  173.065556  99.100647   5.0  93.075  161.3
#
#
#                 75%    max
# Species_ID
# 0           135.900  310.7
# 1           174.550  196.1
# 2           103.075  193.5
# 3           145.450  251.6
# 4           125.000  245.4
# 5           253.375  363.9

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID   Origin_ID         H_m      DBH_cm  BA_sq_m_ha    GS_cub_m  \
# count  857.000000  856.000000  857.000000  856.000000  857.000000  857.000000
# mean     1.529755    0.279206   16.452275   17.132243   26.329988  229.013069
# std      1.823872    0.448871    7.039954   10.439115   10.629993  144.362106
# min      0.000000    0.000000    1.500000    1.100000    1.000000    2.400000
# 25%      0.000000    0.000000   11.200000    9.900000   19.000000  116.000000
# 50%      0.000000    0.000000   16.100000   15.500000   26.800000  206.000000
# 75%      3.000000    1.000000   21.200000   22.100000   34.500000  320.000000
# max      5.000000    1.000000   38.300000   94.000000   51.500000  735.000000
#
#        ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  \
# count     855.000000      747.000000      747.000000  843.000000
# mean      102.590877       92.779518       12.060107   13.821969
# std        68.758819       61.992238        9.595428   11.567546
# min         1.800000        2.000000        0.300000    0.500000
# 25%        47.500000       42.900000        5.950000    6.610000
# 50%        93.500000       84.600000        9.300000   10.820000
# 75%       140.500000      125.500000       15.300000   16.435000
# max       363.900000      315.200000       65.700000   69.120000
#
#        Foliage_t_ha  LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  \
# count    854.000000   857.000000        855.000000         747.000000
# mean       4.749356     5.166919          4.343766           4.246975
# std        2.826586     0.839680          0.869479           0.854856
# min        0.200000     0.880000          0.590000           0.690000
# 25%        2.600000     4.750000          3.860000           3.760000
# 50%        4.300000     5.330000          4.540000           4.440000
# 75%        6.367500     5.770000          4.950000           4.830000
# max       21.730000     6.600000          5.900000           5.750000
#
#        LN_Stem_bark_t_ha  LN_Crown_t_ha  LN_Foliage_t_ha
# count         747.000000     843.000000       854.000000
# mean            2.201232       2.318149         1.364906
# std             0.806766       0.829446         0.672551
# min            -1.200000      -0.690000        -1.610000
# 25%             1.780000       1.890000         0.960000
# 50%             2.230000       2.380000         1.460000
# 75%             2.730000       2.800000         1.850000
# max             4.190000       4.240000         3.080000

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "LN_Stem_bark_t_ha"
indep_variables = ['Species_ID','Origin_ID','H_m','DBH_cm','BA_sq_m_ha']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 10            5        0.0  18.2    19.6        18.3     159.0          101.8
# 11            1        0.0   8.8     5.2        15.5     105.0           46.3
# 12            1        0.0  10.2     6.7        16.2     122.0           54.1
# 13            1        0.0  14.1    10.0        19.9     194.0           87.2
# 14            1        0.0  19.4    15.9        26.8     299.0          133.9
# ..          ...        ...   ...     ...         ...       ...            ...
# 852           3        0.0   7.8     4.4         9.2      39.8           17.8
# 853           3        0.0  12.7     9.0        20.5     123.6           47.1
# 854           3        0.0  12.2     8.1        20.3     141.7           51.9
# 855           2        0.0  14.3    12.4        25.1     176.5          100.7
# 856           2        0.0  21.1    25.6        21.0     191.6           99.9
#
#      Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 10             85.4            16.4       20.40          2.60         5.07
# 11             38.0             8.3       18.48         17.22         4.65
# 12             45.0             9.1       24.64         19.28         4.80
# 13             68.4            18.8       30.65         21.73         5.27
# 14             98.2            35.7       42.76         20.03         5.70
# ..              ...             ...         ...           ...          ...
# 852            15.7             2.1        2.26          2.04         3.68
# 853            42.6             4.5        2.14          1.21         4.82
# 854            47.8             4.1        2.11          1.16         4.95
# 855            84.6            16.1       16.90          4.74         5.17
# 856            80.8            19.1       16.60          2.13         5.26
#
#      LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 10               4.62               4.45               2.80           3.02
# 11               3.84               3.64               2.12           2.92
# 12               3.99               3.81               2.21           3.20
# 13               4.47               4.23               2.93           3.42
# 14               4.90               4.59               3.58           3.76
# ..                ...                ...                ...            ...
# 852              2.88               2.75               0.74           0.82
# 853              3.85               3.75               1.50           0.76
# 854              3.95               3.87               1.41           0.75
# 855              4.61               4.44               2.78           2.83
# 856              4.60               4.39               2.95           2.81
#
#      LN_Foliage_t_ha
# 10              0.96
# 11              2.85
# 12              2.96
# 13              3.08
# 14              3.00
# ..               ...
# 852             0.71
# 853             0.19
# 854             0.15
# 855             1.56
# 856             0.76
#
# [747 rows x 17 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#     Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha
# 10           5        0.0  18.2    19.6        18.3
# 11           1        0.0   8.8     5.2        15.5
# 12           1        0.0  10.2     6.7        16.2
# 13           1        0.0  14.1    10.0        19.9
# 14           1        0.0  19.4    15.9        26.8

# %%
# Columns in "y" data collections
y.head()
# Out:
#     LN_Stem_bark_t_ha
# 10               2.80
# 11               2.12
# 12               2.21
# 13               2.93
# 14               3.58

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.7841368357493024, 0.8139568151273118, 0.8498345495167378]
#     Mean: 0.816
#     Std: 0.027
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.3303125  0.28761518 0.34403108]
#     Mean: 0.321
#     Std: 0.024
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.2207547231922188, 0.19992001320942338, 0.21463406648023062]
#     Mean: 0.212
#     Std: 0.009
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.8942960625751492                 # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.27892087021094436                # gamma
print('Gamma: ' + str(p2))

p3 = 0.11832141467878397                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 3            # max_depth
print('Max_depth: ' + str(p4))

p5 = 197         # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.7296434500976409                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.8942960625751492
# Gamma: 0.27892087021094436
# Learning_rate: 0.11832141467878397
# Max_depth: 3
# N_estimators: 197
# Subsample: 0.7296434500976409

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    exp_R_square = r2_score(exp_y_test, exp_y_pred)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.68370	validation_1-rmse:1.63692
# [1]	validation_0-rmse:1.49726	validation_1-rmse:1.45426
# [2]	validation_0-rmse:1.33465	validation_1-rmse:1.29849
# [3]	validation_0-rmse:1.19108	validation_1-rmse:1.15804
# [4]	validation_0-rmse:1.06548	validation_1-rmse:1.03346
# [5]	validation_0-rmse:0.96020	validation_1-rmse:0.93390
# [6]	validation_0-rmse:0.86167	validation_1-rmse:0.84443
# [7]	validation_0-rmse:0.77556	validation_1-rmse:0.76406
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:0.69940	validation_1-rmse:0.69365
# [9]	validation_0-rmse:0.63637	validation_1-rmse:0.63654
# [10]	validation_0-rmse:0.58198	validation_1-rmse:0.58652
# [11]	validation_0-rmse:0.53481	validation_1-rmse:0.54325
# [12]	validation_0-rmse:0.49116	validation_1-rmse:0.50715
# [13]	validation_0-rmse:0.45307	validation_1-rmse:0.47625
# [14]	validation_0-rmse:0.42373	validation_1-rmse:0.45011
# [15]	validation_0-rmse:0.39842	validation_1-rmse:0.43042
# [16]	validation_0-rmse:0.37637	validation_1-rmse:0.41347
# [17]	validation_0-rmse:0.35846	validation_1-rmse:0.39966
# [18]	validation_0-rmse:0.34250	validation_1-rmse:0.38753
# [19]	validation_0-rmse:0.33021	validation_1-rmse:0.37843
# [20]	validation_0-rmse:0.32011	validation_1-rmse:0.37016
# [21]	validation_0-rmse:0.31055	validation_1-rmse:0.36534
# [22]	validation_0-rmse:0.30284	validation_1-rmse:0.35967
# [23]	validation_0-rmse:0.29524	validation_1-rmse:0.35203
# [24]	validation_0-rmse:0.28964	validation_1-rmse:0.34849
# [25]	validation_0-rmse:0.28566	validation_1-rmse:0.34594
# [26]	validation_0-rmse:0.28222	validation_1-rmse:0.34436
# [27]	validation_0-rmse:0.27803	validation_1-rmse:0.34320
# [28]	validation_0-rmse:0.27543	validation_1-rmse:0.34102
# [29]	validation_0-rmse:0.27316	validation_1-rmse:0.34013
# [30]	validation_0-rmse:0.27100	validation_1-rmse:0.33903
# [31]	validation_0-rmse:0.26759	validation_1-rmse:0.33732
# [32]	validation_0-rmse:0.26596	validation_1-rmse:0.33738
# [33]	validation_0-rmse:0.26368	validation_1-rmse:0.33581
# [34]	validation_0-rmse:0.26268	validation_1-rmse:0.33528
# [35]	validation_0-rmse:0.26166	validation_1-rmse:0.33461
# [36]	validation_0-rmse:0.26034	validation_1-rmse:0.33467
# [37]	validation_0-rmse:0.25916	validation_1-rmse:0.33485
# [38]	validation_0-rmse:0.25740	validation_1-rmse:0.33390
# [39]	validation_0-rmse:0.25553	validation_1-rmse:0.33175
# [40]	validation_0-rmse:0.25511	validation_1-rmse:0.33174
# [41]	validation_0-rmse:0.25463	validation_1-rmse:0.33142
# [42]	validation_0-rmse:0.25382	validation_1-rmse:0.33139
# [43]	validation_0-rmse:0.25339	validation_1-rmse:0.33154
# [44]	validation_0-rmse:0.25179	validation_1-rmse:0.33213
# [45]	validation_0-rmse:0.25107	validation_1-rmse:0.33167
# [46]	validation_0-rmse:0.25028	validation_1-rmse:0.33245
# [47]	validation_0-rmse:0.24920	validation_1-rmse:0.33209
# [48]	validation_0-rmse:0.24866	validation_1-rmse:0.33204
# [49]	validation_0-rmse:0.24805	validation_1-rmse:0.33215
# [50]	validation_0-rmse:0.24805	validation_1-rmse:0.33215
# [51]	validation_0-rmse:0.24807	validation_1-rmse:0.33217
# [52]	validation_0-rmse:0.24714	validation_1-rmse:0.33192
# [53]	validation_0-rmse:0.24633	validation_1-rmse:0.33130
# [54]	validation_0-rmse:0.24631	validation_1-rmse:0.33128
# [55]	validation_0-rmse:0.24543	validation_1-rmse:0.33043
# [56]	validation_0-rmse:0.24483	validation_1-rmse:0.33017
# [57]	validation_0-rmse:0.24437	validation_1-rmse:0.33006
# [58]	validation_0-rmse:0.24382	validation_1-rmse:0.33005
# [59]	validation_0-rmse:0.24340	validation_1-rmse:0.33011
# [60]	validation_0-rmse:0.24306	validation_1-rmse:0.33019
# [61]	validation_0-rmse:0.24230	validation_1-rmse:0.32920
# [62]	validation_0-rmse:0.24228	validation_1-rmse:0.32918
# [63]	validation_0-rmse:0.24182	validation_1-rmse:0.32899
# [64]	validation_0-rmse:0.24152	validation_1-rmse:0.32929
# [65]	validation_0-rmse:0.24121	validation_1-rmse:0.32971
# [66]	validation_0-rmse:0.24122	validation_1-rmse:0.32971
# [67]	validation_0-rmse:0.24084	validation_1-rmse:0.32952
# [68]	validation_0-rmse:0.24084	validation_1-rmse:0.32953
# [69]	validation_0-rmse:0.24047	validation_1-rmse:0.32929
# [70]	validation_0-rmse:0.23988	validation_1-rmse:0.32885
# [71]	validation_0-rmse:0.23872	validation_1-rmse:0.32785
# [72]	validation_0-rmse:0.23872	validation_1-rmse:0.32785
# [73]	validation_0-rmse:0.23872	validation_1-rmse:0.32786
# [74]	validation_0-rmse:0.23846	validation_1-rmse:0.32764
# [75]	validation_0-rmse:0.23813	validation_1-rmse:0.32767
# [76]	validation_0-rmse:0.23764	validation_1-rmse:0.32822
# [77]	validation_0-rmse:0.23727	validation_1-rmse:0.32827
# [78]	validation_0-rmse:0.23727	validation_1-rmse:0.32826
# [79]	validation_0-rmse:0.23727	validation_1-rmse:0.32826
# [80]	validation_0-rmse:0.23727	validation_1-rmse:0.32826
# [81]	validation_0-rmse:0.23727	validation_1-rmse:0.32827
# [82]	validation_0-rmse:0.23591	validation_1-rmse:0.32824
# [83]	validation_0-rmse:0.23567	validation_1-rmse:0.32807
# [84]	validation_0-rmse:0.23509	validation_1-rmse:0.32694
# [85]	validation_0-rmse:0.23456	validation_1-rmse:0.32647
# [86]	validation_0-rmse:0.23417	validation_1-rmse:0.32575
# [87]	validation_0-rmse:0.23417	validation_1-rmse:0.32575
# [88]	validation_0-rmse:0.23356	validation_1-rmse:0.32564
# [89]	validation_0-rmse:0.23356	validation_1-rmse:0.32566
# [90]	validation_0-rmse:0.23356	validation_1-rmse:0.32565
# [91]	validation_0-rmse:0.23356	validation_1-rmse:0.32564
# [92]	validation_0-rmse:0.23313	validation_1-rmse:0.32591
# [93]	validation_0-rmse:0.23313	validation_1-rmse:0.32589
# [94]	validation_0-rmse:0.23270	validation_1-rmse:0.32594
# [95]	validation_0-rmse:0.23244	validation_1-rmse:0.32596
# [96]	validation_0-rmse:0.23245	validation_1-rmse:0.32594
# [97]	validation_0-rmse:0.23244	validation_1-rmse:0.32595
# [98]	validation_0-rmse:0.23207	validation_1-rmse:0.32515
# [99]	validation_0-rmse:0.23175	validation_1-rmse:0.32523
# [100]	validation_0-rmse:0.23176	validation_1-rmse:0.32521
# [101]	validation_0-rmse:0.23175	validation_1-rmse:0.32522
# [102]	validation_0-rmse:0.23162	validation_1-rmse:0.32503
# [103]	validation_0-rmse:0.23162	validation_1-rmse:0.32503
# [104]	validation_0-rmse:0.23118	validation_1-rmse:0.32466
# [105]	validation_0-rmse:0.22975	validation_1-rmse:0.32485
# [106]	validation_0-rmse:0.22941	validation_1-rmse:0.32539
# [107]	validation_0-rmse:0.22905	validation_1-rmse:0.32471
# [108]	validation_0-rmse:0.22905	validation_1-rmse:0.32471
# [109]	validation_0-rmse:0.22905	validation_1-rmse:0.32472
# [110]	validation_0-rmse:0.22904	validation_1-rmse:0.32472
# [111]	validation_0-rmse:0.22905	validation_1-rmse:0.32471
# [112]	validation_0-rmse:0.22853	validation_1-rmse:0.32481
# [113]	validation_0-rmse:0.22826	validation_1-rmse:0.32507
# [114]	validation_0-rmse:0.22826	validation_1-rmse:0.32509
# [115]	validation_0-rmse:0.22785	validation_1-rmse:0.32500
# [116]	validation_0-rmse:0.22745	validation_1-rmse:0.32530
# [117]	validation_0-rmse:0.22745	validation_1-rmse:0.32529
# [118]	validation_0-rmse:0.22745	validation_1-rmse:0.32529
# [119]	validation_0-rmse:0.22745	validation_1-rmse:0.32532
# [120]	validation_0-rmse:0.22711	validation_1-rmse:0.32580
# [121]	validation_0-rmse:0.22711	validation_1-rmse:0.32579
# [122]	validation_0-rmse:0.22711	validation_1-rmse:0.32578
# [123]	validation_0-rmse:0.22673	validation_1-rmse:0.32554
# [124]	validation_0-rmse:0.22673	validation_1-rmse:0.32554
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.69073	validation_1-rmse:1.60289
# [1]	validation_0-rmse:1.50597	validation_1-rmse:1.43266
# [2]	validation_0-rmse:1.34514	validation_1-rmse:1.28198
# [3]	validation_0-rmse:1.19942	validation_1-rmse:1.14386
# [4]	validation_0-rmse:1.07370	validation_1-rmse:1.02878
# [5]	validation_0-rmse:0.96288	validation_1-rmse:0.93064
# [6]	validation_0-rmse:0.86297	validation_1-rmse:0.83914
# [7]	validation_0-rmse:0.77932	validation_1-rmse:0.76357
# [8]	validation_0-rmse:0.70760	validation_1-rmse:0.70221
# [9]	validation_0-rmse:0.64511	validation_1-rmse:0.64610
# [10]	validation_0-rmse:0.59088	validation_1-rmse:0.60210
# [11]	validation_0-rmse:0.54164	validation_1-rmse:0.55966
# [12]	validation_0-rmse:0.49777	validation_1-rmse:0.52228
# [13]	validation_0-rmse:0.46014	validation_1-rmse:0.49189
# [14]	validation_0-rmse:0.42908	validation_1-rmse:0.46631
# [15]	validation_0-rmse:0.40163	validation_1-rmse:0.44774
# [16]	validation_0-rmse:0.37778	validation_1-rmse:0.43090
# [17]	validation_0-rmse:0.35925	validation_1-rmse:0.41773
# [18]	validation_0-rmse:0.34404	validation_1-rmse:0.40831
# [19]	validation_0-rmse:0.32988	validation_1-rmse:0.39706
# [20]	validation_0-rmse:0.31926	validation_1-rmse:0.39011
# [21]	validation_0-rmse:0.30914	validation_1-rmse:0.38425
# [22]	validation_0-rmse:0.30167	validation_1-rmse:0.37991
# [23]	validation_0-rmse:0.29539	validation_1-rmse:0.37728
# [24]	validation_0-rmse:0.28939	validation_1-rmse:0.37381
# [25]	validation_0-rmse:0.28532	validation_1-rmse:0.37134
# [26]	validation_0-rmse:0.28090	validation_1-rmse:0.36958
# [27]	validation_0-rmse:0.27815	validation_1-rmse:0.36809
# [28]	validation_0-rmse:0.27410	validation_1-rmse:0.36695
# [29]	validation_0-rmse:0.27079	validation_1-rmse:0.36598
# [30]	validation_0-rmse:0.26828	validation_1-rmse:0.36295
# [31]	validation_0-rmse:0.26501	validation_1-rmse:0.36108
# [32]	validation_0-rmse:0.26305	validation_1-rmse:0.36040
# [33]	validation_0-rmse:0.26154	validation_1-rmse:0.35926
# [34]	validation_0-rmse:0.25933	validation_1-rmse:0.35938
# [35]	validation_0-rmse:0.25818	validation_1-rmse:0.35854
# [36]	validation_0-rmse:0.25698	validation_1-rmse:0.35775
# [37]	validation_0-rmse:0.25559	validation_1-rmse:0.35717
# [38]	validation_0-rmse:0.25476	validation_1-rmse:0.35643
# [39]	validation_0-rmse:0.25331	validation_1-rmse:0.35630
# [40]	validation_0-rmse:0.25244	validation_1-rmse:0.35647
# [41]	validation_0-rmse:0.25096	validation_1-rmse:0.35579
# [42]	validation_0-rmse:0.24948	validation_1-rmse:0.35485
# [43]	validation_0-rmse:0.24879	validation_1-rmse:0.35452
# [44]	validation_0-rmse:0.24773	validation_1-rmse:0.35340
# [45]	validation_0-rmse:0.24695	validation_1-rmse:0.35254
# [46]	validation_0-rmse:0.24669	validation_1-rmse:0.35271
# [47]	validation_0-rmse:0.24607	validation_1-rmse:0.35219
# [48]	validation_0-rmse:0.24590	validation_1-rmse:0.35194
# [49]	validation_0-rmse:0.24591	validation_1-rmse:0.35191
# [50]	validation_0-rmse:0.24462	validation_1-rmse:0.35160
# [51]	validation_0-rmse:0.24459	validation_1-rmse:0.35176
# [52]	validation_0-rmse:0.24412	validation_1-rmse:0.35139
# [53]	validation_0-rmse:0.24411	validation_1-rmse:0.35143
# [54]	validation_0-rmse:0.24411	validation_1-rmse:0.35147
# [55]	validation_0-rmse:0.24262	validation_1-rmse:0.35042
# [56]	validation_0-rmse:0.24177	validation_1-rmse:0.35080
# [57]	validation_0-rmse:0.24080	validation_1-rmse:0.34918
# [58]	validation_0-rmse:0.24079	validation_1-rmse:0.34936
# [59]	validation_0-rmse:0.24079	validation_1-rmse:0.34932
# [60]	validation_0-rmse:0.24026	validation_1-rmse:0.34886
# [61]	validation_0-rmse:0.24026	validation_1-rmse:0.34892
# [62]	validation_0-rmse:0.24026	validation_1-rmse:0.34890
# [63]	validation_0-rmse:0.23958	validation_1-rmse:0.34916
# [64]	validation_0-rmse:0.23896	validation_1-rmse:0.34886
# [65]	validation_0-rmse:0.23895	validation_1-rmse:0.34891
# [66]	validation_0-rmse:0.23895	validation_1-rmse:0.34904
# [67]	validation_0-rmse:0.23805	validation_1-rmse:0.34904
# [68]	validation_0-rmse:0.23750	validation_1-rmse:0.34861
# [69]	validation_0-rmse:0.23750	validation_1-rmse:0.34862
# [70]	validation_0-rmse:0.23694	validation_1-rmse:0.34807
# [71]	validation_0-rmse:0.23695	validation_1-rmse:0.34818
# [72]	validation_0-rmse:0.23658	validation_1-rmse:0.34833
# [73]	validation_0-rmse:0.23658	validation_1-rmse:0.34825
# [74]	validation_0-rmse:0.23658	validation_1-rmse:0.34824
# [75]	validation_0-rmse:0.23658	validation_1-rmse:0.34822
# [76]	validation_0-rmse:0.23618	validation_1-rmse:0.34835
# [77]	validation_0-rmse:0.23567	validation_1-rmse:0.34959
# [78]	validation_0-rmse:0.23568	validation_1-rmse:0.34971
# [79]	validation_0-rmse:0.23518	validation_1-rmse:0.34952
# [80]	validation_0-rmse:0.23518	validation_1-rmse:0.34943
# [81]	validation_0-rmse:0.23428	validation_1-rmse:0.34880
# [82]	validation_0-rmse:0.23381	validation_1-rmse:0.34892
# [83]	validation_0-rmse:0.23381	validation_1-rmse:0.34896
# [84]	validation_0-rmse:0.23343	validation_1-rmse:0.34931
# [85]	validation_0-rmse:0.23343	validation_1-rmse:0.34921
# [86]	validation_0-rmse:0.23343	validation_1-rmse:0.34927
# [87]	validation_0-rmse:0.23343	validation_1-rmse:0.34923
# [88]	validation_0-rmse:0.23343	validation_1-rmse:0.34923
# [89]	validation_0-rmse:0.23344	validation_1-rmse:0.34915
# [90]	validation_0-rmse:0.23310	validation_1-rmse:0.34935
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.67197	validation_1-rmse:1.67579
# [1]	validation_0-rmse:1.49095	validation_1-rmse:1.48934
# [2]	validation_0-rmse:1.33308	validation_1-rmse:1.32732
# [3]	validation_0-rmse:1.19095	validation_1-rmse:1.18551
# [4]	validation_0-rmse:1.06689	validation_1-rmse:1.06043
# [5]	validation_0-rmse:0.95863	validation_1-rmse:0.94855
# [6]	validation_0-rmse:0.86344	validation_1-rmse:0.85184
# [7]	validation_0-rmse:0.77651	validation_1-rmse:0.76514
# [8]	validation_0-rmse:0.70384	validation_1-rmse:0.69220
# [9]	validation_0-rmse:0.64255	validation_1-rmse:0.63154
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [10]	validation_0-rmse:0.58909	validation_1-rmse:0.57690
# [11]	validation_0-rmse:0.54171	validation_1-rmse:0.52981
# [12]	validation_0-rmse:0.49934	validation_1-rmse:0.49060
# [13]	validation_0-rmse:0.46236	validation_1-rmse:0.45532
# [14]	validation_0-rmse:0.43245	validation_1-rmse:0.42788
# [15]	validation_0-rmse:0.40642	validation_1-rmse:0.40573
# [16]	validation_0-rmse:0.38451	validation_1-rmse:0.38587
# [17]	validation_0-rmse:0.36706	validation_1-rmse:0.37001
# [18]	validation_0-rmse:0.35126	validation_1-rmse:0.35559
# [19]	validation_0-rmse:0.33944	validation_1-rmse:0.34606
# [20]	validation_0-rmse:0.32756	validation_1-rmse:0.33663
# [21]	validation_0-rmse:0.31851	validation_1-rmse:0.33005
# [22]	validation_0-rmse:0.31127	validation_1-rmse:0.32576
# [23]	validation_0-rmse:0.30500	validation_1-rmse:0.32070
# [24]	validation_0-rmse:0.29960	validation_1-rmse:0.31576
# [25]	validation_0-rmse:0.29427	validation_1-rmse:0.31183
# [26]	validation_0-rmse:0.28969	validation_1-rmse:0.31128
# [27]	validation_0-rmse:0.28496	validation_1-rmse:0.30913
# [28]	validation_0-rmse:0.28094	validation_1-rmse:0.30724
# [29]	validation_0-rmse:0.27867	validation_1-rmse:0.30698
# [30]	validation_0-rmse:0.27563	validation_1-rmse:0.30443
# [31]	validation_0-rmse:0.27415	validation_1-rmse:0.30434
# [32]	validation_0-rmse:0.27247	validation_1-rmse:0.30340
# [33]	validation_0-rmse:0.27140	validation_1-rmse:0.30181
# [34]	validation_0-rmse:0.26989	validation_1-rmse:0.29986
# [35]	validation_0-rmse:0.26901	validation_1-rmse:0.29950
# [36]	validation_0-rmse:0.26720	validation_1-rmse:0.29736
# [37]	validation_0-rmse:0.26608	validation_1-rmse:0.29741
# [38]	validation_0-rmse:0.26526	validation_1-rmse:0.29679
# [39]	validation_0-rmse:0.26464	validation_1-rmse:0.29572
# [40]	validation_0-rmse:0.26347	validation_1-rmse:0.29579
# [41]	validation_0-rmse:0.26312	validation_1-rmse:0.29602
# [42]	validation_0-rmse:0.26150	validation_1-rmse:0.29482
# [43]	validation_0-rmse:0.26005	validation_1-rmse:0.29442
# [44]	validation_0-rmse:0.25916	validation_1-rmse:0.29584
# [45]	validation_0-rmse:0.25800	validation_1-rmse:0.29672
# [46]	validation_0-rmse:0.25713	validation_1-rmse:0.29614
# [47]	validation_0-rmse:0.25714	validation_1-rmse:0.29605
# [48]	validation_0-rmse:0.25652	validation_1-rmse:0.29604
# [49]	validation_0-rmse:0.25554	validation_1-rmse:0.29564
# [50]	validation_0-rmse:0.25477	validation_1-rmse:0.29548
# [51]	validation_0-rmse:0.25388	validation_1-rmse:0.29474
# [52]	validation_0-rmse:0.25318	validation_1-rmse:0.29465
# [53]	validation_0-rmse:0.25288	validation_1-rmse:0.29442
# [54]	validation_0-rmse:0.25258	validation_1-rmse:0.29383
# [55]	validation_0-rmse:0.25258	validation_1-rmse:0.29398
# [56]	validation_0-rmse:0.25187	validation_1-rmse:0.29350
# [57]	validation_0-rmse:0.25100	validation_1-rmse:0.29385
# [58]	validation_0-rmse:0.25045	validation_1-rmse:0.29343
# [59]	validation_0-rmse:0.24963	validation_1-rmse:0.29338
# [60]	validation_0-rmse:0.24894	validation_1-rmse:0.29516
# [61]	validation_0-rmse:0.24658	validation_1-rmse:0.29439
# [62]	validation_0-rmse:0.24658	validation_1-rmse:0.29437
# [63]	validation_0-rmse:0.24552	validation_1-rmse:0.29420
# [64]	validation_0-rmse:0.24483	validation_1-rmse:0.29360
# [65]	validation_0-rmse:0.24376	validation_1-rmse:0.29381
# [66]	validation_0-rmse:0.24305	validation_1-rmse:0.29326
# [67]	validation_0-rmse:0.24234	validation_1-rmse:0.29374
# [68]	validation_0-rmse:0.24234	validation_1-rmse:0.29360
# [69]	validation_0-rmse:0.24234	validation_1-rmse:0.29374
# [70]	validation_0-rmse:0.24234	validation_1-rmse:0.29361
# [71]	validation_0-rmse:0.24172	validation_1-rmse:0.29308
# [72]	validation_0-rmse:0.24068	validation_1-rmse:0.29236
# [73]	validation_0-rmse:0.24024	validation_1-rmse:0.29207
# [74]	validation_0-rmse:0.23948	validation_1-rmse:0.29233
# [75]	validation_0-rmse:0.23896	validation_1-rmse:0.29214
# [76]	validation_0-rmse:0.23896	validation_1-rmse:0.29221
# [77]	validation_0-rmse:0.23808	validation_1-rmse:0.29305
# [78]	validation_0-rmse:0.23808	validation_1-rmse:0.29328
# [79]	validation_0-rmse:0.23757	validation_1-rmse:0.29272
# [80]	validation_0-rmse:0.23729	validation_1-rmse:0.29217
# [81]	validation_0-rmse:0.23729	validation_1-rmse:0.29195
# [82]	validation_0-rmse:0.23663	validation_1-rmse:0.29138
# [83]	validation_0-rmse:0.23644	validation_1-rmse:0.29172
# [84]	validation_0-rmse:0.23644	validation_1-rmse:0.29187
# [85]	validation_0-rmse:0.23644	validation_1-rmse:0.29185
# [86]	validation_0-rmse:0.23615	validation_1-rmse:0.29211
# [87]	validation_0-rmse:0.23582	validation_1-rmse:0.29210
# [88]	validation_0-rmse:0.23559	validation_1-rmse:0.29202
# [89]	validation_0-rmse:0.23550	validation_1-rmse:0.29187
# [90]	validation_0-rmse:0.23550	validation_1-rmse:0.29174
# [91]	validation_0-rmse:0.23550	validation_1-rmse:0.29198
# [92]	validation_0-rmse:0.23517	validation_1-rmse:0.29234
# [93]	validation_0-rmse:0.23517	validation_1-rmse:0.29251
# [94]	validation_0-rmse:0.23468	validation_1-rmse:0.29182
# [95]	validation_0-rmse:0.23378	validation_1-rmse:0.29207
# [96]	validation_0-rmse:0.23350	validation_1-rmse:0.29156
# [97]	validation_0-rmse:0.23328	validation_1-rmse:0.29144
# [98]	validation_0-rmse:0.23293	validation_1-rmse:0.29167
# [99]	validation_0-rmse:0.23294	validation_1-rmse:0.29204
# [100]	validation_0-rmse:0.23293	validation_1-rmse:0.29165
# [101]	validation_0-rmse:0.23293	validation_1-rmse:0.29161
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.68070	validation_1-rmse:1.64761
# [1]	validation_0-rmse:1.49924	validation_1-rmse:1.46943
# [2]	validation_0-rmse:1.33556	validation_1-rmse:1.31016
# [3]	validation_0-rmse:1.19338	validation_1-rmse:1.17133
# [4]	validation_0-rmse:1.06765	validation_1-rmse:1.04407
# [5]	validation_0-rmse:0.96094	validation_1-rmse:0.93981
# [6]	validation_0-rmse:0.86293	validation_1-rmse:0.84605
# [7]	validation_0-rmse:0.78092	validation_1-rmse:0.76693
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:0.70598	validation_1-rmse:0.69512
# [9]	validation_0-rmse:0.64351	validation_1-rmse:0.63596
# [10]	validation_0-rmse:0.58951	validation_1-rmse:0.58199
# [11]	validation_0-rmse:0.54252	validation_1-rmse:0.53670
# [12]	validation_0-rmse:0.49893	validation_1-rmse:0.49471
# [13]	validation_0-rmse:0.46352	validation_1-rmse:0.46133
# [14]	validation_0-rmse:0.43348	validation_1-rmse:0.43537
# [15]	validation_0-rmse:0.40729	validation_1-rmse:0.41023
# [16]	validation_0-rmse:0.38426	validation_1-rmse:0.38922
# [17]	validation_0-rmse:0.36740	validation_1-rmse:0.37350
# [18]	validation_0-rmse:0.35270	validation_1-rmse:0.36062
# [19]	validation_0-rmse:0.33870	validation_1-rmse:0.35041
# [20]	validation_0-rmse:0.32930	validation_1-rmse:0.34239
# [21]	validation_0-rmse:0.32009	validation_1-rmse:0.33425
# [22]	validation_0-rmse:0.31345	validation_1-rmse:0.32855
# [23]	validation_0-rmse:0.30696	validation_1-rmse:0.32504
# [24]	validation_0-rmse:0.30113	validation_1-rmse:0.32140
# [25]	validation_0-rmse:0.29664	validation_1-rmse:0.31785
# [26]	validation_0-rmse:0.29246	validation_1-rmse:0.31312
# [27]	validation_0-rmse:0.28989	validation_1-rmse:0.31177
# [28]	validation_0-rmse:0.28609	validation_1-rmse:0.30920
# [29]	validation_0-rmse:0.28308	validation_1-rmse:0.30636
# [30]	validation_0-rmse:0.28022	validation_1-rmse:0.30418
# [31]	validation_0-rmse:0.27797	validation_1-rmse:0.30304
# [32]	validation_0-rmse:0.27609	validation_1-rmse:0.30268
# [33]	validation_0-rmse:0.27477	validation_1-rmse:0.30144
# [34]	validation_0-rmse:0.27298	validation_1-rmse:0.30090
# [35]	validation_0-rmse:0.27232	validation_1-rmse:0.30054
# [36]	validation_0-rmse:0.27116	validation_1-rmse:0.30112
# [37]	validation_0-rmse:0.26975	validation_1-rmse:0.30024
# [38]	validation_0-rmse:0.26881	validation_1-rmse:0.30040
# [39]	validation_0-rmse:0.26748	validation_1-rmse:0.30056
# [40]	validation_0-rmse:0.26634	validation_1-rmse:0.30062
# [41]	validation_0-rmse:0.26510	validation_1-rmse:0.29900
# [42]	validation_0-rmse:0.26385	validation_1-rmse:0.29775
# [43]	validation_0-rmse:0.26314	validation_1-rmse:0.29777
# [44]	validation_0-rmse:0.26298	validation_1-rmse:0.29749
# [45]	validation_0-rmse:0.26166	validation_1-rmse:0.29741
# [46]	validation_0-rmse:0.26166	validation_1-rmse:0.29746
# [47]	validation_0-rmse:0.26076	validation_1-rmse:0.29653
# [48]	validation_0-rmse:0.25945	validation_1-rmse:0.29563
# [49]	validation_0-rmse:0.25906	validation_1-rmse:0.29525
# [50]	validation_0-rmse:0.25826	validation_1-rmse:0.29541
# [51]	validation_0-rmse:0.25713	validation_1-rmse:0.29555
# [52]	validation_0-rmse:0.25642	validation_1-rmse:0.29520
# [53]	validation_0-rmse:0.25643	validation_1-rmse:0.29510
# [54]	validation_0-rmse:0.25543	validation_1-rmse:0.29540
# [55]	validation_0-rmse:0.25542	validation_1-rmse:0.29553
# [56]	validation_0-rmse:0.25404	validation_1-rmse:0.29541
# [57]	validation_0-rmse:0.25375	validation_1-rmse:0.29469
# [58]	validation_0-rmse:0.25290	validation_1-rmse:0.29586
# [59]	validation_0-rmse:0.25220	validation_1-rmse:0.29439
# [60]	validation_0-rmse:0.25160	validation_1-rmse:0.29376
# [61]	validation_0-rmse:0.25044	validation_1-rmse:0.29305
# [62]	validation_0-rmse:0.25044	validation_1-rmse:0.29298
# [63]	validation_0-rmse:0.24961	validation_1-rmse:0.29293
# [64]	validation_0-rmse:0.24942	validation_1-rmse:0.29271
# [65]	validation_0-rmse:0.24868	validation_1-rmse:0.29290
# [66]	validation_0-rmse:0.24777	validation_1-rmse:0.29262
# [67]	validation_0-rmse:0.24693	validation_1-rmse:0.29215
# [68]	validation_0-rmse:0.24613	validation_1-rmse:0.29123
# [69]	validation_0-rmse:0.24521	validation_1-rmse:0.29178
# [70]	validation_0-rmse:0.24415	validation_1-rmse:0.29068
# [71]	validation_0-rmse:0.24317	validation_1-rmse:0.29188
# [72]	validation_0-rmse:0.24218	validation_1-rmse:0.29083
# [73]	validation_0-rmse:0.24147	validation_1-rmse:0.29063
# [74]	validation_0-rmse:0.24109	validation_1-rmse:0.29052
# [75]	validation_0-rmse:0.24028	validation_1-rmse:0.28912
# [76]	validation_0-rmse:0.23965	validation_1-rmse:0.28888
# [77]	validation_0-rmse:0.23916	validation_1-rmse:0.28920
# [78]	validation_0-rmse:0.23841	validation_1-rmse:0.28902
# [79]	validation_0-rmse:0.23815	validation_1-rmse:0.28853
# [80]	validation_0-rmse:0.23767	validation_1-rmse:0.28901
# [81]	validation_0-rmse:0.23708	validation_1-rmse:0.28932
# [82]	validation_0-rmse:0.23705	validation_1-rmse:0.28896
# [83]	validation_0-rmse:0.23705	validation_1-rmse:0.28888
# [84]	validation_0-rmse:0.23672	validation_1-rmse:0.28963
# [85]	validation_0-rmse:0.23599	validation_1-rmse:0.28982
# [86]	validation_0-rmse:0.23570	validation_1-rmse:0.28930
# [87]	validation_0-rmse:0.23468	validation_1-rmse:0.28912
# [88]	validation_0-rmse:0.23468	validation_1-rmse:0.28904
# [89]	validation_0-rmse:0.23468	validation_1-rmse:0.28903
# [90]	validation_0-rmse:0.23413	validation_1-rmse:0.28957
# [91]	validation_0-rmse:0.23388	validation_1-rmse:0.29001
# [92]	validation_0-rmse:0.23329	validation_1-rmse:0.28971
# [93]	validation_0-rmse:0.23328	validation_1-rmse:0.28967
# [94]	validation_0-rmse:0.23297	validation_1-rmse:0.28964
# [95]	validation_0-rmse:0.23254	validation_1-rmse:0.29005
# [96]	validation_0-rmse:0.23254	validation_1-rmse:0.28994
# [97]	validation_0-rmse:0.23221	validation_1-rmse:0.28882
# [98]	validation_0-rmse:0.23168	validation_1-rmse:0.28838
# [99]	validation_0-rmse:0.23168	validation_1-rmse:0.28826
# [100]	validation_0-rmse:0.23168	validation_1-rmse:0.28834
# [101]	validation_0-rmse:0.23168	validation_1-rmse:0.28825
# [102]	validation_0-rmse:0.23139	validation_1-rmse:0.28826
# [103]	validation_0-rmse:0.23140	validation_1-rmse:0.28818
# [104]	validation_0-rmse:0.23140	validation_1-rmse:0.28811
# [105]	validation_0-rmse:0.23140	validation_1-rmse:0.28812
# [106]	validation_0-rmse:0.23096	validation_1-rmse:0.28829
# [107]	validation_0-rmse:0.23080	validation_1-rmse:0.28834
# [108]	validation_0-rmse:0.22993	validation_1-rmse:0.28919
# [109]	validation_0-rmse:0.22992	validation_1-rmse:0.28923
# [110]	validation_0-rmse:0.22912	validation_1-rmse:0.28957
# [111]	validation_0-rmse:0.22911	validation_1-rmse:0.28966
# [112]	validation_0-rmse:0.22912	validation_1-rmse:0.28979
# [113]	validation_0-rmse:0.22912	validation_1-rmse:0.28970
# [114]	validation_0-rmse:0.22912	validation_1-rmse:0.28954
# [115]	validation_0-rmse:0.22911	validation_1-rmse:0.28965
# [116]	validation_0-rmse:0.22911	validation_1-rmse:0.28967
# [117]	validation_0-rmse:0.22911	validation_1-rmse:0.28959
# [118]	validation_0-rmse:0.22912	validation_1-rmse:0.28946
# [119]	validation_0-rmse:0.22912	validation_1-rmse:0.28949
# [120]	validation_0-rmse:0.22874	validation_1-rmse:0.28919
# [121]	validation_0-rmse:0.22874	validation_1-rmse:0.28920
# [122]	validation_0-rmse:0.22874	validation_1-rmse:0.28926
# [123]	validation_0-rmse:0.22874	validation_1-rmse:0.28928
# [124]	validation_0-rmse:0.22874	validation_1-rmse:0.28915
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.67163	validation_1-rmse:1.67575
# [1]	validation_0-rmse:1.49009	validation_1-rmse:1.49500
# [2]	validation_0-rmse:1.33023	validation_1-rmse:1.33486
# [3]	validation_0-rmse:1.18986	validation_1-rmse:1.19376
# [4]	validation_0-rmse:1.06685	validation_1-rmse:1.07123
# [5]	validation_0-rmse:0.95713	validation_1-rmse:0.96000
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:0.86109	validation_1-rmse:0.86283
# [7]	validation_0-rmse:0.77560	validation_1-rmse:0.77799
# [8]	validation_0-rmse:0.70422	validation_1-rmse:0.70769
# [9]	validation_0-rmse:0.64178	validation_1-rmse:0.64581
# [10]	validation_0-rmse:0.58813	validation_1-rmse:0.59359
# [11]	validation_0-rmse:0.54259	validation_1-rmse:0.54731
# [12]	validation_0-rmse:0.49976	validation_1-rmse:0.50857
# [13]	validation_0-rmse:0.46278	validation_1-rmse:0.47227
# [14]	validation_0-rmse:0.43434	validation_1-rmse:0.44591
# [15]	validation_0-rmse:0.40916	validation_1-rmse:0.42218
# [16]	validation_0-rmse:0.38678	validation_1-rmse:0.40304
# [17]	validation_0-rmse:0.36967	validation_1-rmse:0.38717
# [18]	validation_0-rmse:0.35394	validation_1-rmse:0.37225
# [19]	validation_0-rmse:0.34156	validation_1-rmse:0.36162
# [20]	validation_0-rmse:0.33137	validation_1-rmse:0.35034
# [21]	validation_0-rmse:0.32163	validation_1-rmse:0.34023
# [22]	validation_0-rmse:0.31331	validation_1-rmse:0.33406
# [23]	validation_0-rmse:0.30714	validation_1-rmse:0.32771
# [24]	validation_0-rmse:0.30190	validation_1-rmse:0.32250
# [25]	validation_0-rmse:0.29780	validation_1-rmse:0.31886
# [26]	validation_0-rmse:0.29447	validation_1-rmse:0.31592
# [27]	validation_0-rmse:0.29135	validation_1-rmse:0.31230
# [28]	validation_0-rmse:0.28736	validation_1-rmse:0.30976
# [29]	validation_0-rmse:0.28475	validation_1-rmse:0.30812
# [30]	validation_0-rmse:0.28198	validation_1-rmse:0.30625
# [31]	validation_0-rmse:0.27997	validation_1-rmse:0.30540
# [32]	validation_0-rmse:0.27758	validation_1-rmse:0.30422
# [33]	validation_0-rmse:0.27625	validation_1-rmse:0.30259
# [34]	validation_0-rmse:0.27418	validation_1-rmse:0.30150
# [35]	validation_0-rmse:0.27270	validation_1-rmse:0.29985
# [36]	validation_0-rmse:0.27062	validation_1-rmse:0.30054
# [37]	validation_0-rmse:0.26959	validation_1-rmse:0.29952
# [38]	validation_0-rmse:0.26744	validation_1-rmse:0.29791
# [39]	validation_0-rmse:0.26669	validation_1-rmse:0.29766
# [40]	validation_0-rmse:0.26561	validation_1-rmse:0.29737
# [41]	validation_0-rmse:0.26441	validation_1-rmse:0.29674
# [42]	validation_0-rmse:0.26394	validation_1-rmse:0.29689
# [43]	validation_0-rmse:0.26202	validation_1-rmse:0.29617
# [44]	validation_0-rmse:0.26119	validation_1-rmse:0.29690
# [45]	validation_0-rmse:0.25959	validation_1-rmse:0.29721
# [46]	validation_0-rmse:0.25883	validation_1-rmse:0.29657
# [47]	validation_0-rmse:0.25840	validation_1-rmse:0.29674
# [48]	validation_0-rmse:0.25737	validation_1-rmse:0.29535
# [49]	validation_0-rmse:0.25703	validation_1-rmse:0.29495
# [50]	validation_0-rmse:0.25570	validation_1-rmse:0.29450
# [51]	validation_0-rmse:0.25491	validation_1-rmse:0.29341
# [52]	validation_0-rmse:0.25438	validation_1-rmse:0.29305
# [53]	validation_0-rmse:0.25331	validation_1-rmse:0.29371
# [54]	validation_0-rmse:0.25262	validation_1-rmse:0.29359
# [55]	validation_0-rmse:0.25213	validation_1-rmse:0.29413
# [56]	validation_0-rmse:0.25130	validation_1-rmse:0.29296
# [57]	validation_0-rmse:0.25075	validation_1-rmse:0.29317
# [58]	validation_0-rmse:0.25023	validation_1-rmse:0.29340
# [59]	validation_0-rmse:0.24984	validation_1-rmse:0.29318
# [60]	validation_0-rmse:0.24925	validation_1-rmse:0.29303
# [61]	validation_0-rmse:0.24861	validation_1-rmse:0.29301
# [62]	validation_0-rmse:0.24776	validation_1-rmse:0.29299
# [63]	validation_0-rmse:0.24776	validation_1-rmse:0.29299
# [64]	validation_0-rmse:0.24692	validation_1-rmse:0.29358
# [65]	validation_0-rmse:0.24644	validation_1-rmse:0.29359
# [66]	validation_0-rmse:0.24620	validation_1-rmse:0.29356
# [67]	validation_0-rmse:0.24568	validation_1-rmse:0.29337
# [68]	validation_0-rmse:0.24529	validation_1-rmse:0.29366
# [69]	validation_0-rmse:0.24496	validation_1-rmse:0.29399
# [70]	validation_0-rmse:0.24496	validation_1-rmse:0.29398
# [71]	validation_0-rmse:0.24466	validation_1-rmse:0.29355
# [72]	validation_0-rmse:0.24454	validation_1-rmse:0.29337
# [73]	validation_0-rmse:0.24454	validation_1-rmse:0.29337
# [74]	validation_0-rmse:0.24384	validation_1-rmse:0.29289
# [75]	validation_0-rmse:0.24383	validation_1-rmse:0.29288
# [76]	validation_0-rmse:0.24383	validation_1-rmse:0.29287
# [77]	validation_0-rmse:0.24383	validation_1-rmse:0.29288
# [78]	validation_0-rmse:0.24336	validation_1-rmse:0.29275
# [79]	validation_0-rmse:0.24294	validation_1-rmse:0.29278
# [80]	validation_0-rmse:0.24170	validation_1-rmse:0.29163
# [81]	validation_0-rmse:0.24128	validation_1-rmse:0.29215
# [82]	validation_0-rmse:0.24109	validation_1-rmse:0.29196
# [83]	validation_0-rmse:0.24055	validation_1-rmse:0.29229
# [84]	validation_0-rmse:0.23992	validation_1-rmse:0.29254
# [85]	validation_0-rmse:0.23958	validation_1-rmse:0.29206
# [86]	validation_0-rmse:0.23958	validation_1-rmse:0.29206
# [87]	validation_0-rmse:0.23890	validation_1-rmse:0.29235
# [88]	validation_0-rmse:0.23890	validation_1-rmse:0.29235
# [89]	validation_0-rmse:0.23862	validation_1-rmse:0.29237
# [90]	validation_0-rmse:0.23813	validation_1-rmse:0.29233
# [91]	validation_0-rmse:0.23797	validation_1-rmse:0.29213
# [92]	validation_0-rmse:0.23726	validation_1-rmse:0.29160
# [93]	validation_0-rmse:0.23726	validation_1-rmse:0.29160
# [94]	validation_0-rmse:0.23726	validation_1-rmse:0.29161
# [95]	validation_0-rmse:0.23668	validation_1-rmse:0.29067
# [96]	validation_0-rmse:0.23598	validation_1-rmse:0.29091
# [97]	validation_0-rmse:0.23548	validation_1-rmse:0.29082
# [98]	validation_0-rmse:0.23548	validation_1-rmse:0.29083
# [99]	validation_0-rmse:0.23548	validation_1-rmse:0.29082
# [100]	validation_0-rmse:0.23548	validation_1-rmse:0.29082
# [101]	validation_0-rmse:0.23548	validation_1-rmse:0.29082
# [102]	validation_0-rmse:0.23507	validation_1-rmse:0.29055
# [103]	validation_0-rmse:0.23463	validation_1-rmse:0.29058
# [104]	validation_0-rmse:0.23424	validation_1-rmse:0.29048
# [105]	validation_0-rmse:0.23425	validation_1-rmse:0.29048
# [106]	validation_0-rmse:0.23424	validation_1-rmse:0.29047
# [107]	validation_0-rmse:0.23423	validation_1-rmse:0.29046
# [108]	validation_0-rmse:0.23423	validation_1-rmse:0.29046
# [109]	validation_0-rmse:0.23423	validation_1-rmse:0.29045
# [110]	validation_0-rmse:0.23424	validation_1-rmse:0.29045
# [111]	validation_0-rmse:0.23423	validation_1-rmse:0.29045
# [112]	validation_0-rmse:0.23424	validation_1-rmse:0.29045
# [113]	validation_0-rmse:0.23356	validation_1-rmse:0.29088
# [114]	validation_0-rmse:0.23346	validation_1-rmse:0.29087
# [115]	validation_0-rmse:0.23346	validation_1-rmse:0.29087
# [116]	validation_0-rmse:0.23288	validation_1-rmse:0.29089
# [117]	validation_0-rmse:0.23288	validation_1-rmse:0.29089
# [118]	validation_0-rmse:0.23288	validation_1-rmse:0.29089
# [119]	validation_0-rmse:0.23217	validation_1-rmse:0.29097
# [120]	validation_0-rmse:0.23217	validation_1-rmse:0.29097
# [121]	validation_0-rmse:0.23183	validation_1-rmse:0.29108
# [122]	validation_0-rmse:0.23182	validation_1-rmse:0.29108
# [123]	validation_0-rmse:0.23138	validation_1-rmse:0.29107
# [124]	validation_0-rmse:0.23092	validation_1-rmse:0.29078
# [125]	validation_0-rmse:0.23093	validation_1-rmse:0.29078
# [126]	validation_0-rmse:0.23093	validation_1-rmse:0.29078
# [127]	validation_0-rmse:0.23092	validation_1-rmse:0.29078
# [128]	validation_0-rmse:0.23075	validation_1-rmse:0.29067
# [129]	validation_0-rmse:0.23075	validation_1-rmse:0.29067
# [130]	validation_0-rmse:0.23075	validation_1-rmse:0.29067
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.67330	validation_1-rmse:1.68330
# [1]	validation_0-rmse:1.49287	validation_1-rmse:1.50541
# [2]	validation_0-rmse:1.33285	validation_1-rmse:1.34790
# [3]	validation_0-rmse:1.19032	validation_1-rmse:1.20563
# [4]	validation_0-rmse:1.06674	validation_1-rmse:1.08079
# [5]	validation_0-rmse:0.95989	validation_1-rmse:0.97451
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:0.86316	validation_1-rmse:0.88144
# [7]	validation_0-rmse:0.77688	validation_1-rmse:0.79662
# [8]	validation_0-rmse:0.70380	validation_1-rmse:0.72521
# [9]	validation_0-rmse:0.64030	validation_1-rmse:0.66351
# [10]	validation_0-rmse:0.58622	validation_1-rmse:0.61038
# [11]	validation_0-rmse:0.53879	validation_1-rmse:0.56464
# [12]	validation_0-rmse:0.49623	validation_1-rmse:0.52330
# [13]	validation_0-rmse:0.46061	validation_1-rmse:0.48953
# [14]	validation_0-rmse:0.43118	validation_1-rmse:0.46179
# [15]	validation_0-rmse:0.40516	validation_1-rmse:0.43841
# [16]	validation_0-rmse:0.38474	validation_1-rmse:0.41964
# [17]	validation_0-rmse:0.36715	validation_1-rmse:0.40305
# [18]	validation_0-rmse:0.35089	validation_1-rmse:0.38833
# [19]	validation_0-rmse:0.33673	validation_1-rmse:0.37669
# [20]	validation_0-rmse:0.32565	validation_1-rmse:0.36755
# [21]	validation_0-rmse:0.31618	validation_1-rmse:0.35783
# [22]	validation_0-rmse:0.30903	validation_1-rmse:0.35306
# [23]	validation_0-rmse:0.30162	validation_1-rmse:0.34822
# [24]	validation_0-rmse:0.29519	validation_1-rmse:0.34261
# [25]	validation_0-rmse:0.28892	validation_1-rmse:0.33862
# [26]	validation_0-rmse:0.28466	validation_1-rmse:0.33485
# [27]	validation_0-rmse:0.28080	validation_1-rmse:0.33098
# [28]	validation_0-rmse:0.27675	validation_1-rmse:0.32807
# [29]	validation_0-rmse:0.27457	validation_1-rmse:0.32647
# [30]	validation_0-rmse:0.27122	validation_1-rmse:0.32248
# [31]	validation_0-rmse:0.26980	validation_1-rmse:0.32189
# [32]	validation_0-rmse:0.26748	validation_1-rmse:0.31947
# [33]	validation_0-rmse:0.26689	validation_1-rmse:0.31818
# [34]	validation_0-rmse:0.26526	validation_1-rmse:0.31707
# [35]	validation_0-rmse:0.26383	validation_1-rmse:0.31486
# [36]	validation_0-rmse:0.26300	validation_1-rmse:0.31393
# [37]	validation_0-rmse:0.26160	validation_1-rmse:0.31396
# [38]	validation_0-rmse:0.26140	validation_1-rmse:0.31331
# [39]	validation_0-rmse:0.25986	validation_1-rmse:0.31229
# [40]	validation_0-rmse:0.25846	validation_1-rmse:0.31239
# [41]	validation_0-rmse:0.25819	validation_1-rmse:0.31234
# [42]	validation_0-rmse:0.25652	validation_1-rmse:0.31177
# [43]	validation_0-rmse:0.25563	validation_1-rmse:0.31172
# [44]	validation_0-rmse:0.25552	validation_1-rmse:0.31136
# [45]	validation_0-rmse:0.25457	validation_1-rmse:0.31099
# [46]	validation_0-rmse:0.25305	validation_1-rmse:0.31088
# [47]	validation_0-rmse:0.25224	validation_1-rmse:0.31079
# [48]	validation_0-rmse:0.25126	validation_1-rmse:0.31037
# [49]	validation_0-rmse:0.25077	validation_1-rmse:0.31020
# [50]	validation_0-rmse:0.24965	validation_1-rmse:0.30908
# [51]	validation_0-rmse:0.24906	validation_1-rmse:0.30865
# [52]	validation_0-rmse:0.24907	validation_1-rmse:0.30867
# [53]	validation_0-rmse:0.24857	validation_1-rmse:0.30820
# [54]	validation_0-rmse:0.24734	validation_1-rmse:0.30842
# [55]	validation_0-rmse:0.24734	validation_1-rmse:0.30843
# [56]	validation_0-rmse:0.24671	validation_1-rmse:0.30819
# [57]	validation_0-rmse:0.24557	validation_1-rmse:0.30720
# [58]	validation_0-rmse:0.24441	validation_1-rmse:0.30626
# [59]	validation_0-rmse:0.24431	validation_1-rmse:0.30615
# [60]	validation_0-rmse:0.24430	validation_1-rmse:0.30613
# [61]	validation_0-rmse:0.24399	validation_1-rmse:0.30609
# [62]	validation_0-rmse:0.24398	validation_1-rmse:0.30603
# [63]	validation_0-rmse:0.24372	validation_1-rmse:0.30598
# [64]	validation_0-rmse:0.24307	validation_1-rmse:0.30525
# [65]	validation_0-rmse:0.24307	validation_1-rmse:0.30527
# [66]	validation_0-rmse:0.24277	validation_1-rmse:0.30519
# [67]	validation_0-rmse:0.24235	validation_1-rmse:0.30582
# [68]	validation_0-rmse:0.24142	validation_1-rmse:0.30544
# [69]	validation_0-rmse:0.24106	validation_1-rmse:0.30571
# [70]	validation_0-rmse:0.24105	validation_1-rmse:0.30562
# [71]	validation_0-rmse:0.24105	validation_1-rmse:0.30563
# [72]	validation_0-rmse:0.24052	validation_1-rmse:0.30629
# [73]	validation_0-rmse:0.23970	validation_1-rmse:0.30646
# [74]	validation_0-rmse:0.23970	validation_1-rmse:0.30650
# [75]	validation_0-rmse:0.23970	validation_1-rmse:0.30646
# [76]	validation_0-rmse:0.23885	validation_1-rmse:0.30770
# [77]	validation_0-rmse:0.23886	validation_1-rmse:0.30771
# [78]	validation_0-rmse:0.23786	validation_1-rmse:0.30668
# [79]	validation_0-rmse:0.23786	validation_1-rmse:0.30669
# [80]	validation_0-rmse:0.23747	validation_1-rmse:0.30681
# [81]	validation_0-rmse:0.23747	validation_1-rmse:0.30683
# [82]	validation_0-rmse:0.23747	validation_1-rmse:0.30681
# [83]	validation_0-rmse:0.23700	validation_1-rmse:0.30742
# [84]	validation_0-rmse:0.23679	validation_1-rmse:0.30730
# [85]	validation_0-rmse:0.23637	validation_1-rmse:0.30659
# [86]	validation_0-rmse:0.23589	validation_1-rmse:0.30643
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.66947	validation_1-rmse:1.69060
# [1]	validation_0-rmse:1.48842	validation_1-rmse:1.51051
# [2]	validation_0-rmse:1.32758	validation_1-rmse:1.35176
# [3]	validation_0-rmse:1.18596	validation_1-rmse:1.20636
# [4]	validation_0-rmse:1.06144	validation_1-rmse:1.08257
# [5]	validation_0-rmse:0.95352	validation_1-rmse:0.97689
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:0.85473	validation_1-rmse:0.87695
# [7]	validation_0-rmse:0.77192	validation_1-rmse:0.79647
# [8]	validation_0-rmse:0.69831	validation_1-rmse:0.72434
# [9]	validation_0-rmse:0.63474	validation_1-rmse:0.66083
# [10]	validation_0-rmse:0.58177	validation_1-rmse:0.60887
# [11]	validation_0-rmse:0.53582	validation_1-rmse:0.56452
# [12]	validation_0-rmse:0.49350	validation_1-rmse:0.52483
# [13]	validation_0-rmse:0.45826	validation_1-rmse:0.49192
# [14]	validation_0-rmse:0.42951	validation_1-rmse:0.46495
# [15]	validation_0-rmse:0.40243	validation_1-rmse:0.44121
# [16]	validation_0-rmse:0.37814	validation_1-rmse:0.41869
# [17]	validation_0-rmse:0.36204	validation_1-rmse:0.40427
# [18]	validation_0-rmse:0.34653	validation_1-rmse:0.38947
# [19]	validation_0-rmse:0.33303	validation_1-rmse:0.37742
# [20]	validation_0-rmse:0.32427	validation_1-rmse:0.36967
# [21]	validation_0-rmse:0.31530	validation_1-rmse:0.36155
# [22]	validation_0-rmse:0.30866	validation_1-rmse:0.35620
# [23]	validation_0-rmse:0.30277	validation_1-rmse:0.35201
# [24]	validation_0-rmse:0.29737	validation_1-rmse:0.34698
# [25]	validation_0-rmse:0.29273	validation_1-rmse:0.34227
# [26]	validation_0-rmse:0.28879	validation_1-rmse:0.33862
# [27]	validation_0-rmse:0.28567	validation_1-rmse:0.33632
# [28]	validation_0-rmse:0.28322	validation_1-rmse:0.33435
# [29]	validation_0-rmse:0.27956	validation_1-rmse:0.33117
# [30]	validation_0-rmse:0.27614	validation_1-rmse:0.32930
# [31]	validation_0-rmse:0.27521	validation_1-rmse:0.32875
# [32]	validation_0-rmse:0.27256	validation_1-rmse:0.32620
# [33]	validation_0-rmse:0.27065	validation_1-rmse:0.32562
# [34]	validation_0-rmse:0.26820	validation_1-rmse:0.32477
# [35]	validation_0-rmse:0.26686	validation_1-rmse:0.32388
# [36]	validation_0-rmse:0.26607	validation_1-rmse:0.32295
# [37]	validation_0-rmse:0.26391	validation_1-rmse:0.32064
# [38]	validation_0-rmse:0.26352	validation_1-rmse:0.32037
# [39]	validation_0-rmse:0.26250	validation_1-rmse:0.31973
# [40]	validation_0-rmse:0.26141	validation_1-rmse:0.31978
# [41]	validation_0-rmse:0.26079	validation_1-rmse:0.32012
# [42]	validation_0-rmse:0.25966	validation_1-rmse:0.31825
# [43]	validation_0-rmse:0.25940	validation_1-rmse:0.31793
# [44]	validation_0-rmse:0.25886	validation_1-rmse:0.31745
# [45]	validation_0-rmse:0.25808	validation_1-rmse:0.31677
# [46]	validation_0-rmse:0.25758	validation_1-rmse:0.31668
# [47]	validation_0-rmse:0.25715	validation_1-rmse:0.31742
# [48]	validation_0-rmse:0.25655	validation_1-rmse:0.31737
# [49]	validation_0-rmse:0.25529	validation_1-rmse:0.31639
# [50]	validation_0-rmse:0.25529	validation_1-rmse:0.31640
# [51]	validation_0-rmse:0.25528	validation_1-rmse:0.31643
# [52]	validation_0-rmse:0.25460	validation_1-rmse:0.31558
# [53]	validation_0-rmse:0.25392	validation_1-rmse:0.31523
# [54]	validation_0-rmse:0.25392	validation_1-rmse:0.31524
# [55]	validation_0-rmse:0.25265	validation_1-rmse:0.31369
# [56]	validation_0-rmse:0.25212	validation_1-rmse:0.31342
# [57]	validation_0-rmse:0.25127	validation_1-rmse:0.31194
# [58]	validation_0-rmse:0.25127	validation_1-rmse:0.31195
# [59]	validation_0-rmse:0.25043	validation_1-rmse:0.31181
# [60]	validation_0-rmse:0.24964	validation_1-rmse:0.31069
# [61]	validation_0-rmse:0.24867	validation_1-rmse:0.30977
# [62]	validation_0-rmse:0.24867	validation_1-rmse:0.30977
# [63]	validation_0-rmse:0.24814	validation_1-rmse:0.30956
# [64]	validation_0-rmse:0.24671	validation_1-rmse:0.30864
# [65]	validation_0-rmse:0.24630	validation_1-rmse:0.30864
# [66]	validation_0-rmse:0.24630	validation_1-rmse:0.30862
# [67]	validation_0-rmse:0.24542	validation_1-rmse:0.30752
# [68]	validation_0-rmse:0.24482	validation_1-rmse:0.30765
# [69]	validation_0-rmse:0.24446	validation_1-rmse:0.30764
# [70]	validation_0-rmse:0.24343	validation_1-rmse:0.30703
# [71]	validation_0-rmse:0.24267	validation_1-rmse:0.30752
# [72]	validation_0-rmse:0.24240	validation_1-rmse:0.30586
# [73]	validation_0-rmse:0.24120	validation_1-rmse:0.30449
# [74]	validation_0-rmse:0.24034	validation_1-rmse:0.30460
# [75]	validation_0-rmse:0.23972	validation_1-rmse:0.30492
# [76]	validation_0-rmse:0.23908	validation_1-rmse:0.30535
# [77]	validation_0-rmse:0.23908	validation_1-rmse:0.30532
# [78]	validation_0-rmse:0.23908	validation_1-rmse:0.30530
# [79]	validation_0-rmse:0.23865	validation_1-rmse:0.30488
# [80]	validation_0-rmse:0.23865	validation_1-rmse:0.30493
# [81]	validation_0-rmse:0.23866	validation_1-rmse:0.30498
# [82]	validation_0-rmse:0.23776	validation_1-rmse:0.30428
# [83]	validation_0-rmse:0.23776	validation_1-rmse:0.30427
# [84]	validation_0-rmse:0.23736	validation_1-rmse:0.30509
# [85]	validation_0-rmse:0.23719	validation_1-rmse:0.30481
# [86]	validation_0-rmse:0.23658	validation_1-rmse:0.30505
# [87]	validation_0-rmse:0.23658	validation_1-rmse:0.30501
# [88]	validation_0-rmse:0.23600	validation_1-rmse:0.30633
# [89]	validation_0-rmse:0.23530	validation_1-rmse:0.30564
# [90]	validation_0-rmse:0.23530	validation_1-rmse:0.30562
# [91]	validation_0-rmse:0.23450	validation_1-rmse:0.30647
# [92]	validation_0-rmse:0.23450	validation_1-rmse:0.30648
# [93]	validation_0-rmse:0.23387	validation_1-rmse:0.30688
# [94]	validation_0-rmse:0.23387	validation_1-rmse:0.30693
# [95]	validation_0-rmse:0.23365	validation_1-rmse:0.30672
# [96]	validation_0-rmse:0.23334	validation_1-rmse:0.30664
# [97]	validation_0-rmse:0.23333	validation_1-rmse:0.30668
# [98]	validation_0-rmse:0.23310	validation_1-rmse:0.30673
# [99]	validation_0-rmse:0.23310	validation_1-rmse:0.30669
# [100]	validation_0-rmse:0.23286	validation_1-rmse:0.30688
# [101]	validation_0-rmse:0.23286	validation_1-rmse:0.30690
# [102]	validation_0-rmse:0.23286	validation_1-rmse:0.30692
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.66514	validation_1-rmse:1.72180
# [1]	validation_0-rmse:1.48131	validation_1-rmse:1.53564
# [2]	validation_0-rmse:1.31947	validation_1-rmse:1.37182
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:1.17958	validation_1-rmse:1.22836
# [4]	validation_0-rmse:1.05917	validation_1-rmse:1.10567
# [5]	validation_0-rmse:0.95142	validation_1-rmse:0.99593
# [6]	validation_0-rmse:0.85695	validation_1-rmse:0.89777
# [7]	validation_0-rmse:0.77468	validation_1-rmse:0.81299
# [8]	validation_0-rmse:0.70167	validation_1-rmse:0.73507
# [9]	validation_0-rmse:0.63983	validation_1-rmse:0.67098
# [10]	validation_0-rmse:0.58422	validation_1-rmse:0.61333
# [11]	validation_0-rmse:0.53852	validation_1-rmse:0.56527
# [12]	validation_0-rmse:0.49720	validation_1-rmse:0.52160
# [13]	validation_0-rmse:0.46274	validation_1-rmse:0.48327
# [14]	validation_0-rmse:0.43430	validation_1-rmse:0.45444
# [15]	validation_0-rmse:0.41017	validation_1-rmse:0.42880
# [16]	validation_0-rmse:0.38779	validation_1-rmse:0.40484
# [17]	validation_0-rmse:0.37000	validation_1-rmse:0.38671
# [18]	validation_0-rmse:0.35363	validation_1-rmse:0.37019
# [19]	validation_0-rmse:0.34026	validation_1-rmse:0.35559
# [20]	validation_0-rmse:0.33011	validation_1-rmse:0.34570
# ...
# [25]	validation_0-rmse:0.28263	validation_1-rmse:0.38779
# [26]	validation_0-rmse:0.27870	validation_1-rmse:0.38632
# [27]	validation_0-rmse:0.27653	validation_1-rmse:0.38562
# [28]	validation_0-rmse:0.27287	validation_1-rmse:0.38271
# [29]	validation_0-rmse:0.27069	validation_1-rmse:0.38241
# [30]	validation_0-rmse:0.26796	validation_1-rmse:0.37938
# [31]	validation_0-rmse:0.26618	validation_1-rmse:0.37832
# [32]	validation_0-rmse:0.26448	validation_1-rmse:0.37754
# [33]	validation_0-rmse:0.26347	validation_1-rmse:0.37705
# [34]	validation_0-rmse:0.26097	validation_1-rmse:0.37570
# [35]	validation_0-rmse:0.26030	validation_1-rmse:0.37670
# [36]	validation_0-rmse:0.25853	validation_1-rmse:0.37483
# [37]	validation_0-rmse:0.25727	validation_1-rmse:0.37463
# [38]	validation_0-rmse:0.25700	validation_1-rmse:0.37524
# [39]	validation_0-rmse:0.25629	validation_1-rmse:0.37472
# [40]	validation_0-rmse:0.25501	validation_1-rmse:0.37324
# [41]	validation_0-rmse:0.25425	validation_1-rmse:0.37250
# [42]	validation_0-rmse:0.25328	validation_1-rmse:0.37265
# [43]	validation_0-rmse:0.25226	validation_1-rmse:0.37083
# [44]	validation_0-rmse:0.25190	validation_1-rmse:0.37044
# [45]	validation_0-rmse:0.25126	validation_1-rmse:0.37014
# [46]	validation_0-rmse:0.25022	validation_1-rmse:0.36947
# [47]	validation_0-rmse:0.25023	validation_1-rmse:0.36946
# [48]	validation_0-rmse:0.24877	validation_1-rmse:0.36840
# [49]	validation_0-rmse:0.24878	validation_1-rmse:0.36839
# [50]	validation_0-rmse:0.24873	validation_1-rmse:0.36857
# [51]	validation_0-rmse:0.24732	validation_1-rmse:0.36860
# [52]	validation_0-rmse:0.24685	validation_1-rmse:0.36840
# [53]	validation_0-rmse:0.24683	validation_1-rmse:0.36847
# [54]	validation_0-rmse:0.24613	validation_1-rmse:0.36753
# [55]	validation_0-rmse:0.24572	validation_1-rmse:0.36664
# [56]	validation_0-rmse:0.24524	validation_1-rmse:0.36434
# [57]	validation_0-rmse:0.24484	validation_1-rmse:0.36477
# [58]	validation_0-rmse:0.24335	validation_1-rmse:0.36313
# [59]	validation_0-rmse:0.24300	validation_1-rmse:0.36268
# [60]	validation_0-rmse:0.24245	validation_1-rmse:0.36304
# [61]	validation_0-rmse:0.24148	validation_1-rmse:0.36267
# [62]	validation_0-rmse:0.24091	validation_1-rmse:0.36213
# [63]	validation_0-rmse:0.24007	validation_1-rmse:0.36200
# [64]	validation_0-rmse:0.24008	validation_1-rmse:0.36197
# [65]	validation_0-rmse:0.24007	validation_1-rmse:0.36202
# [66]	validation_0-rmse:0.23959	validation_1-rmse:0.36115
# [67]	validation_0-rmse:0.23959	validation_1-rmse:0.36111
# [68]	validation_0-rmse:0.23949	validation_1-rmse:0.36057
# [69]	validation_0-rmse:0.23948	validation_1-rmse:0.36066
# [70]	validation_0-rmse:0.23873	validation_1-rmse:0.35880
# [71]	validation_0-rmse:0.23800	validation_1-rmse:0.35917
# [72]	validation_0-rmse:0.23704	validation_1-rmse:0.35840
# [73]	validation_0-rmse:0.23665	validation_1-rmse:0.35709
# [74]	validation_0-rmse:0.23615	validation_1-rmse:0.35667
# [75]	validation_0-rmse:0.23563	validation_1-rmse:0.35768
# [76]	validation_0-rmse:0.23563	validation_1-rmse:0.35767
# [77]	validation_0-rmse:0.23564	validation_1-rmse:0.35754
# [78]	validation_0-rmse:0.23564	validation_1-rmse:0.35754
# [79]	validation_0-rmse:0.23565	validation_1-rmse:0.35745
# [80]	validation_0-rmse:0.23535	validation_1-rmse:0.35650
# [81]	validation_0-rmse:0.23534	validation_1-rmse:0.35655
# [82]	validation_0-rmse:0.23535	validation_1-rmse:0.35653
# [83]	validation_0-rmse:0.23465	validation_1-rmse:0.35700
# [84]	validation_0-rmse:0.23419	validation_1-rmse:0.35715
# [85]	validation_0-rmse:0.23419	validation_1-rmse:0.35719
# [86]	validation_0-rmse:0.23419	validation_1-rmse:0.35719
# [87]	validation_0-rmse:0.23419	validation_1-rmse:0.35722
# [88]	validation_0-rmse:0.23396	validation_1-rmse:0.35736
# [89]	validation_0-rmse:0.23335	validation_1-rmse:0.35730
# [90]	validation_0-rmse:0.23336	validation_1-rmse:0.35735
# [91]	validation_0-rmse:0.23337	validation_1-rmse:0.35748
# [92]	validation_0-rmse:0.23336	validation_1-rmse:0.35735
# [93]	validation_0-rmse:0.23273	validation_1-rmse:0.35730
# [94]	validation_0-rmse:0.23273	validation_1-rmse:0.35729
# [95]	validation_0-rmse:0.23173	validation_1-rmse:0.35774
# [96]	validation_0-rmse:0.23171	validation_1-rmse:0.35754
# [97]	validation_0-rmse:0.23138	validation_1-rmse:0.35739
# [98]	validation_0-rmse:0.23139	validation_1-rmse:0.35729
# [99]	validation_0-rmse:0.23094	validation_1-rmse:0.35732
# [100]	validation_0-rmse:0.23094	validation_1-rmse:0.35730
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.65719	validation_1-rmse:1.73435
# [1]	validation_0-rmse:1.47784	validation_1-rmse:1.54854
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:1.32059	validation_1-rmse:1.38978
# [3]	validation_0-rmse:1.17943	validation_1-rmse:1.24474
# [4]	validation_0-rmse:1.05399	validation_1-rmse:1.11393
# [5]	validation_0-rmse:0.95088	validation_1-rmse:1.00488
# [6]	validation_0-rmse:0.85518	validation_1-rmse:0.90143
# [7]	validation_0-rmse:0.77396	validation_1-rmse:0.81345
# [8]	validation_0-rmse:0.69981	validation_1-rmse:0.73898
# [9]	validation_0-rmse:0.63960	validation_1-rmse:0.68002
# [10]	validation_0-rmse:0.58547	validation_1-rmse:0.62431
# [11]	validation_0-rmse:0.53889	validation_1-rmse:0.57828
# [12]	validation_0-rmse:0.49653	validation_1-rmse:0.53401
# [13]	validation_0-rmse:0.46112	validation_1-rmse:0.49933
# [14]	validation_0-rmse:0.43078	validation_1-rmse:0.46891
# [15]	validation_0-rmse:0.40645	validation_1-rmse:0.44266
# [16]	validation_0-rmse:0.38543	validation_1-rmse:0.42047
# [17]	validation_0-rmse:0.36709	validation_1-rmse:0.40133
# [18]	validation_0-rmse:0.35099	validation_1-rmse:0.38489
# [19]	validation_0-rmse:0.33747	validation_1-rmse:0.37128
# [20]	validation_0-rmse:0.32950	validation_1-rmse:0.36183
# [21]	validation_0-rmse:0.31906	validation_1-rmse:0.35162
# [22]	validation_0-rmse:0.31167	validation_1-rmse:0.34337
# [23]	validation_0-rmse:0.30525	validation_1-rmse:0.33842
# [24]	validation_0-rmse:0.29894	validation_1-rmse:0.33212
# [25]	validation_0-rmse:0.29516	validation_1-rmse:0.32822
# [26]	validation_0-rmse:0.29165	validation_1-rmse:0.32579
# [27]	validation_0-rmse:0.28819	validation_1-rmse:0.32312
# [28]	validation_0-rmse:0.28407	validation_1-rmse:0.32274
# [29]	validation_0-rmse:0.28048	validation_1-rmse:0.32122
# [30]	validation_0-rmse:0.27747	validation_1-rmse:0.31844
# [31]	validation_0-rmse:0.27606	validation_1-rmse:0.31752
# [32]	validation_0-rmse:0.27495	validation_1-rmse:0.31645
# [33]	validation_0-rmse:0.27266	validation_1-rmse:0.31476
# [34]	validation_0-rmse:0.27052	validation_1-rmse:0.31349
# [35]	validation_0-rmse:0.26782	validation_1-rmse:0.31180
# [36]	validation_0-rmse:0.26701	validation_1-rmse:0.31220
# [37]	validation_0-rmse:0.26549	validation_1-rmse:0.31311
# [38]	validation_0-rmse:0.26404	validation_1-rmse:0.31363
# [39]	validation_0-rmse:0.26309	validation_1-rmse:0.31255
# [40]	validation_0-rmse:0.26163	validation_1-rmse:0.31164
# [41]	validation_0-rmse:0.26017	validation_1-rmse:0.31135
# [42]	validation_0-rmse:0.25930	validation_1-rmse:0.31068
# [43]	validation_0-rmse:0.25784	validation_1-rmse:0.31060
# [44]	validation_0-rmse:0.25626	validation_1-rmse:0.30906
# [45]	validation_0-rmse:0.25607	validation_1-rmse:0.30869
# [46]	validation_0-rmse:0.25503	validation_1-rmse:0.30716
# [47]	validation_0-rmse:0.25404	validation_1-rmse:0.30743
# [48]	validation_0-rmse:0.25217	validation_1-rmse:0.30753
# [49]	validation_0-rmse:0.25144	validation_1-rmse:0.30813
# [50]	validation_0-rmse:0.25144	validation_1-rmse:0.30816
# [51]	validation_0-rmse:0.25083	validation_1-rmse:0.30790
# [52]	validation_0-rmse:0.25073	validation_1-rmse:0.30781
# [53]	validation_0-rmse:0.25013	validation_1-rmse:0.30708
# [54]	validation_0-rmse:0.24931	validation_1-rmse:0.30569
# [55]	validation_0-rmse:0.24750	validation_1-rmse:0.30583
# [56]	validation_0-rmse:0.24667	validation_1-rmse:0.30665
# [57]	validation_0-rmse:0.24615	validation_1-rmse:0.30621
# [58]	validation_0-rmse:0.24572	validation_1-rmse:0.30672
# [59]	validation_0-rmse:0.24517	validation_1-rmse:0.30575
# [60]	validation_0-rmse:0.24426	validation_1-rmse:0.30616
# [61]	validation_0-rmse:0.24317	validation_1-rmse:0.30589
# [62]	validation_0-rmse:0.24276	validation_1-rmse:0.30501
# [63]	validation_0-rmse:0.24213	validation_1-rmse:0.30512
# [64]	validation_0-rmse:0.24177	validation_1-rmse:0.30545
# [65]	validation_0-rmse:0.24169	validation_1-rmse:0.30599
# [66]	validation_0-rmse:0.24169	validation_1-rmse:0.30599
# [67]	validation_0-rmse:0.24168	validation_1-rmse:0.30601
# [68]	validation_0-rmse:0.24128	validation_1-rmse:0.30574
# [69]	validation_0-rmse:0.23964	validation_1-rmse:0.30540
# [70]	validation_0-rmse:0.23928	validation_1-rmse:0.30581
# [71]	validation_0-rmse:0.23900	validation_1-rmse:0.30573
# [72]	validation_0-rmse:0.23900	validation_1-rmse:0.30571
# [73]	validation_0-rmse:0.23900	validation_1-rmse:0.30572
# [74]	validation_0-rmse:0.23851	validation_1-rmse:0.30587
# [75]	validation_0-rmse:0.23705	validation_1-rmse:0.30624
# [76]	validation_0-rmse:0.23664	validation_1-rmse:0.30697
# [77]	validation_0-rmse:0.23664	validation_1-rmse:0.30698
# [78]	validation_0-rmse:0.23616	validation_1-rmse:0.30696
# [79]	validation_0-rmse:0.23550	validation_1-rmse:0.30684
# [80]	validation_0-rmse:0.23498	validation_1-rmse:0.30672
# [81]	validation_0-rmse:0.23424	validation_1-rmse:0.30711
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.67295	validation_1-rmse:1.68358
# [1]	validation_0-rmse:1.48909	validation_1-rmse:1.50292
# [2]	validation_0-rmse:1.32996	validation_1-rmse:1.34933
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:1.18605	validation_1-rmse:1.20740
# [4]	validation_0-rmse:1.06175	validation_1-rmse:1.08914
# [5]	validation_0-rmse:0.95519	validation_1-rmse:0.98480
# [6]	validation_0-rmse:0.85998	validation_1-rmse:0.89091
# [7]	validation_0-rmse:0.77438	validation_1-rmse:0.80963
# [8]	validation_0-rmse:0.70153	validation_1-rmse:0.73809
# [9]	validation_0-rmse:0.63805	validation_1-rmse:0.67498
# [10]	validation_0-rmse:0.58354	validation_1-rmse:0.62486
# [11]	validation_0-rmse:0.53779	validation_1-rmse:0.57916
# [12]	validation_0-rmse:0.49402	validation_1-rmse:0.53884
# [13]	validation_0-rmse:0.45456	validation_1-rmse:0.50332
# [14]	validation_0-rmse:0.42491	validation_1-rmse:0.47554
# [15]	validation_0-rmse:0.39782	validation_1-rmse:0.44983
# [16]	validation_0-rmse:0.37507	validation_1-rmse:0.43039
# [17]	validation_0-rmse:0.35802	validation_1-rmse:0.41440
# [18]	validation_0-rmse:0.34134	validation_1-rmse:0.40179
# [19]	validation_0-rmse:0.32791	validation_1-rmse:0.39129
# [20]	validation_0-rmse:0.31776	validation_1-rmse:0.38352
# [21]	validation_0-rmse:0.30912	validation_1-rmse:0.37620
# [22]	validation_0-rmse:0.30023	validation_1-rmse:0.36989
# [23]	validation_0-rmse:0.29384	validation_1-rmse:0.36427
# [24]	validation_0-rmse:0.28759	validation_1-rmse:0.36107
# [25]	validation_0-rmse:0.28222	validation_1-rmse:0.35775
# [26]	validation_0-rmse:0.27845	validation_1-rmse:0.35649
# [27]	validation_0-rmse:0.27561	validation_1-rmse:0.35435
# [28]	validation_0-rmse:0.27184	validation_1-rmse:0.35082
# [29]	validation_0-rmse:0.26992	validation_1-rmse:0.34969
# [30]	validation_0-rmse:0.26837	validation_1-rmse:0.34889
# [31]	validation_0-rmse:0.26736	validation_1-rmse:0.34811
# [32]	validation_0-rmse:0.26575	validation_1-rmse:0.34789
# [33]	validation_0-rmse:0.26391	validation_1-rmse:0.34596
# [34]	validation_0-rmse:0.26230	validation_1-rmse:0.34564
# [35]	validation_0-rmse:0.26142	validation_1-rmse:0.34564
# [36]	validation_0-rmse:0.25905	validation_1-rmse:0.34517
# [37]	validation_0-rmse:0.25806	validation_1-rmse:0.34415
# [38]	validation_0-rmse:0.25500	validation_1-rmse:0.34171
# [39]	validation_0-rmse:0.25373	validation_1-rmse:0.34005
# [40]	validation_0-rmse:0.25286	validation_1-rmse:0.34024
# [41]	validation_0-rmse:0.25166	validation_1-rmse:0.33941
# [42]	validation_0-rmse:0.25061	validation_1-rmse:0.33795
# [43]	validation_0-rmse:0.24985	validation_1-rmse:0.33707
# [44]	validation_0-rmse:0.24929	validation_1-rmse:0.33644
# [45]	validation_0-rmse:0.24836	validation_1-rmse:0.33609
# [46]	validation_0-rmse:0.24707	validation_1-rmse:0.33651
# [47]	validation_0-rmse:0.24706	validation_1-rmse:0.33655
# [48]	validation_0-rmse:0.24638	validation_1-rmse:0.33604
# [49]	validation_0-rmse:0.24584	validation_1-rmse:0.33519
# [50]	validation_0-rmse:0.24507	validation_1-rmse:0.33479
# [51]	validation_0-rmse:0.24507	validation_1-rmse:0.33479
# [52]	validation_0-rmse:0.24506	validation_1-rmse:0.33482
# [53]	validation_0-rmse:0.24439	validation_1-rmse:0.33469
# [54]	validation_0-rmse:0.24439	validation_1-rmse:0.33469
# [55]	validation_0-rmse:0.24413	validation_1-rmse:0.33412
# [56]	validation_0-rmse:0.24342	validation_1-rmse:0.33319
# [57]	validation_0-rmse:0.24286	validation_1-rmse:0.33340
# [58]	validation_0-rmse:0.24241	validation_1-rmse:0.33200
# [59]	validation_0-rmse:0.24059	validation_1-rmse:0.33188
# [60]	validation_0-rmse:0.24007	validation_1-rmse:0.33224
# [61]	validation_0-rmse:0.23938	validation_1-rmse:0.33218
# [62]	validation_0-rmse:0.23829	validation_1-rmse:0.33199
# [63]	validation_0-rmse:0.23729	validation_1-rmse:0.33165
# [64]	validation_0-rmse:0.23729	validation_1-rmse:0.33164
# [65]	validation_0-rmse:0.23688	validation_1-rmse:0.33141
# [66]	validation_0-rmse:0.23688	validation_1-rmse:0.33144
# [67]	validation_0-rmse:0.23688	validation_1-rmse:0.33143
# [68]	validation_0-rmse:0.23688	validation_1-rmse:0.33144
# [69]	validation_0-rmse:0.23645	validation_1-rmse:0.33189
# [70]	validation_0-rmse:0.23609	validation_1-rmse:0.33218
# [71]	validation_0-rmse:0.23609	validation_1-rmse:0.33225
# [72]	validation_0-rmse:0.23522	validation_1-rmse:0.33235
# [73]	validation_0-rmse:0.23522	validation_1-rmse:0.33235
# [74]	validation_0-rmse:0.23478	validation_1-rmse:0.33276
# [75]	validation_0-rmse:0.23457	validation_1-rmse:0.33254
# [76]	validation_0-rmse:0.23457	validation_1-rmse:0.33252
# [77]	validation_0-rmse:0.23458	validation_1-rmse:0.33251
# [78]	validation_0-rmse:0.23457	validation_1-rmse:0.33254
# [79]	validation_0-rmse:0.23394	validation_1-rmse:0.33166
# [80]	validation_0-rmse:0.23310	validation_1-rmse:0.33165
# [81]	validation_0-rmse:0.23311	validation_1-rmse:0.33169
# [82]	validation_0-rmse:0.23269	validation_1-rmse:0.33101
# [83]	validation_0-rmse:0.23230	validation_1-rmse:0.33154
# [84]	validation_0-rmse:0.23230	validation_1-rmse:0.33158
# [85]	validation_0-rmse:0.23140	validation_1-rmse:0.33222
# [86]	validation_0-rmse:0.23139	validation_1-rmse:0.33221
# [87]	validation_0-rmse:0.23139	validation_1-rmse:0.33207
# [88]	validation_0-rmse:0.23139	validation_1-rmse:0.33198
# [89]	validation_0-rmse:0.23139	validation_1-rmse:0.33199
# [90]	validation_0-rmse:0.23106	validation_1-rmse:0.33245
# [91]	validation_0-rmse:0.23036	validation_1-rmse:0.33169
# [92]	validation_0-rmse:0.23022	validation_1-rmse:0.33181
# [93]	validation_0-rmse:0.23022	validation_1-rmse:0.33183
# [94]	validation_0-rmse:0.23009	validation_1-rmse:0.33194
# [95]	validation_0-rmse:0.22973	validation_1-rmse:0.33182
# [96]	validation_0-rmse:0.22972	validation_1-rmse:0.33191
# [97]	validation_0-rmse:0.22973	validation_1-rmse:0.33182
# [98]	validation_0-rmse:0.22973	validation_1-rmse:0.33181
# [99]	validation_0-rmse:0.22973	validation_1-rmse:0.33181
# [100]	validation_0-rmse:0.22929	validation_1-rmse:0.33187
# [101]	validation_0-rmse:0.22929	validation_1-rmse:0.33183
# [102]	validation_0-rmse:0.22928	validation_1-rmse:0.33190
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-1.2, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.853
# Uncertainty
# a0: 0.353+/-0.032
# a1: 0.8392+/-0.013

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: BA_sq_m_ha: mean - 0.277, median - 0.276, CI - [0.263-0.289]
#
# SHAP-values for: DBH_cm: mean - 0.03, median - 0.029, CI - [0.022-0.038]
#
# SHAP-values for: H_m: mean - 0.265, median - 0.264, CI - [0.25-0.282]
#
# SHAP-values for: Origin_ID: mean - 0.013, median - 0.012, CI - [0.009-0.016]
#
# SHAP-values for: Species_ID: mean - 0.323, median - 0.323, CI - [0.315-0.329]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['Species_ID', 'BA_sq_m_ha', 'H_m', 'DBH_cm', 'Origin_ID'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 84.225, median: 80.0,
#  pred. interval (P(0.025)-P(0.975)): 35.0-153.175,
#  conf. interval (p-value=0.95): 57.451-108.822
# ***
# Aggregate bias statistic:
#  mean: -0.001, median: -0.001,
#  pred. interval (P(0.025)-P(0.975)): -0.054-0.051,
#  conf. interval (p-value=0.95): -0.023-0.027
# ***
# Aggregate RMSE statistic:
#  mean: 0.307, median: 0.307, pred. interval (P(0.025)-P(0.975)): 0.259-0.352,
#  conf. interval (p-value=0.95): 0.283-0.33
# ***
# Aggregate MSE statistic:
#  mean: 0.095, median: 0.094, pred. interval (P(0.025)-P(0.975)): 0.067-0.124,
#  conf. interval (p-value=0.95): 0.08-0.109
# ***
# Aggregate R^2 statistic:
#  mean: 0.849, median: 0.851, pred. interval (P(0.025)-P(0.975)): 0.789-0.903,
#  conf. interval (p-value=0.95): 0.821-0.877
# ***
# Aggregate bias(%) statistic:
#  mean: -0.031, median: -0.048, pred. interval (P(0.025)-P(0.975)): -2.42-2.282,
#  conf. interval (p-value=0.95): -1.095-1.254
# ***
# Aggregate RMSE(%) statistic:
#  mean: 13.976, median: 13.964, pred. interval (P(0.025)-P(0.975)): 11.666-16.336,
#  conf. interval (p-value=0.95): 12.791-15.063
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -0.572, median: -0.558,
#  pred. interval (P(0.025)-P(0.975)): -1.323-0.015,
#  conf. interval (p-value=0.95): -0.873--0.269
# ***
# Aggregate RMSE statistic:
#  mean: 3.599, median: 3.486, pred. interval (P(0.025)-P(0.975)): 2.788-5.001,
#  conf. interval (p-value=0.95): 3.113-4.013
# ***
# Aggregate MSE statistic:
#  mean: 13.264, median: 12.152, pred. interval (P(0.025)-P(0.975)): 7.772-25.007,
#  conf. interval (p-value=0.95): 9.709-16.134
# ***
# Aggregate R^2 statistic:
#  mean: 0.854, median: 0.857, pred. interval (P(0.025)-P(0.975)): 0.775-0.916,
#  conf. interval (p-value=0.95): 0.823-0.89
# ***
# Aggregate bias(%) statistic:
#  mean: -4.708, median: -4.741, pred. interval (P(0.025)-P(0.975)): -10.295-0.125,
#  conf. interval (p-value=0.95): -7.354--2.24
# ***
# Aggregate RMSE(%) statistic:
#  mean: 29.915, median: 29.55, pred. interval (P(0.025)-P(0.975)): 23.011-38.952,
#  conf. interval (p-value=0.95): 26.244-32.942
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-1, 0, 1, 2, 3, 4])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 10, 20, 30, 40, 70])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])

# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.67509
# [1]	validation_0-rmse:1.49177
# [2]	validation_0-rmse:1.33156
# [3]	validation_0-rmse:1.18787
# [4]	validation_0-rmse:1.06277
# [5]	validation_0-rmse:0.95527
# [6]	validation_0-rmse:0.86096
# [7]	validation_0-rmse:0.77472
# [8]	validation_0-rmse:0.69958
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [9]	validation_0-rmse:0.63491
# [10]	validation_0-rmse:0.58200
# [11]	validation_0-rmse:0.53591
# [12]	validation_0-rmse:0.49489
# [13]	validation_0-rmse:0.45972
# [14]	validation_0-rmse:0.43051
# [15]	validation_0-rmse:0.40471
# [16]	validation_0-rmse:0.38243
# [17]	validation_0-rmse:0.36457
# [18]	validation_0-rmse:0.35087
# [19]	validation_0-rmse:0.33768
# [20]	validation_0-rmse:0.32635
# [21]	validation_0-rmse:0.31655
# [22]	validation_0-rmse:0.30920
# [23]	validation_0-rmse:0.30371
# [24]	validation_0-rmse:0.29835
# [25]	validation_0-rmse:0.29369
# [26]	validation_0-rmse:0.28936
# [27]	validation_0-rmse:0.28662
# [28]	validation_0-rmse:0.28386
# [29]	validation_0-rmse:0.28132
# [30]	validation_0-rmse:0.28003
# [31]	validation_0-rmse:0.27834
# [32]	validation_0-rmse:0.27650
# [33]	validation_0-rmse:0.27373
# [34]	validation_0-rmse:0.27158
# [35]	validation_0-rmse:0.27091
# [36]	validation_0-rmse:0.26927
# [37]	validation_0-rmse:0.26704
# [38]	validation_0-rmse:0.26645
# [39]	validation_0-rmse:0.26529
# [40]	validation_0-rmse:0.26396
# [41]	validation_0-rmse:0.26176
# [42]	validation_0-rmse:0.26050
# [43]	validation_0-rmse:0.25921
# [44]	validation_0-rmse:0.25857
# [45]	validation_0-rmse:0.25773
# [46]	validation_0-rmse:0.25742
# [47]	validation_0-rmse:0.25607
# [48]	validation_0-rmse:0.25547
# [49]	validation_0-rmse:0.25518
# [50]	validation_0-rmse:0.25423
# [51]	validation_0-rmse:0.25402
# [52]	validation_0-rmse:0.25370
# [53]	validation_0-rmse:0.25364
# [54]	validation_0-rmse:0.25295
# [55]	validation_0-rmse:0.25214
# [56]	validation_0-rmse:0.25214
# [57]	validation_0-rmse:0.25185
# [58]	validation_0-rmse:0.25080
# [59]	validation_0-rmse:0.25033
# [60]	validation_0-rmse:0.25010
# [61]	validation_0-rmse:0.24944
# [62]	validation_0-rmse:0.24875
# [63]	validation_0-rmse:0.24825
# [64]	validation_0-rmse:0.24825
# [65]	validation_0-rmse:0.24786
# [66]	validation_0-rmse:0.24752
# [67]	validation_0-rmse:0.24752
# [68]	validation_0-rmse:0.24690
# [69]	validation_0-rmse:0.24658
# [70]	validation_0-rmse:0.24591
# [71]	validation_0-rmse:0.24574
# [72]	validation_0-rmse:0.24549
# [73]	validation_0-rmse:0.24549
# [74]	validation_0-rmse:0.24447
# [75]	validation_0-rmse:0.24443
# [76]	validation_0-rmse:0.24443
# [77]	validation_0-rmse:0.24297
# [78]	validation_0-rmse:0.24275
# [79]	validation_0-rmse:0.24214
# [80]	validation_0-rmse:0.24151
# [81]	validation_0-rmse:0.24151
# [82]	validation_0-rmse:0.24151
# [83]	validation_0-rmse:0.24120
# [84]	validation_0-rmse:0.24109
# [85]	validation_0-rmse:0.24019
# [86]	validation_0-rmse:0.23979
# [87]	validation_0-rmse:0.23979
# [88]	validation_0-rmse:0.23950
# [89]	validation_0-rmse:0.23905
# [90]	validation_0-rmse:0.23905
# [91]	validation_0-rmse:0.23905
# [92]	validation_0-rmse:0.23879
# [93]	validation_0-rmse:0.23835
# [94]	validation_0-rmse:0.23797
# [95]	validation_0-rmse:0.23797
# [96]	validation_0-rmse:0.23740
# [97]	validation_0-rmse:0.23741
# [98]	validation_0-rmse:0.23698
# [99]	validation_0-rmse:0.23653
# [100]	validation_0-rmse:0.23633
# [101]	validation_0-rmse:0.23608
# [102]	validation_0-rmse:0.23608
# [103]	validation_0-rmse:0.23590
# [104]	validation_0-rmse:0.23559
# [105]	validation_0-rmse:0.23559
# [106]	validation_0-rmse:0.23559
# [107]	validation_0-rmse:0.23488
# [108]	validation_0-rmse:0.23488
# [109]	validation_0-rmse:0.23488
# [110]	validation_0-rmse:0.23488
# [111]	validation_0-rmse:0.23461
# [112]	validation_0-rmse:0.23461
# [113]	validation_0-rmse:0.23414
# [114]	validation_0-rmse:0.23350
# [115]	validation_0-rmse:0.23340
# [116]	validation_0-rmse:0.23340
# [117]	validation_0-rmse:0.23340
# [118]	validation_0-rmse:0.23303
# [119]	validation_0-rmse:0.23262
# [120]	validation_0-rmse:0.23239
# [121]	validation_0-rmse:0.23210
# [122]	validation_0-rmse:0.23209
# [123]	validation_0-rmse:0.23160
# [124]	validation_0-rmse:0.23082
# [125]	validation_0-rmse:0.23082
# [126]	validation_0-rmse:0.23064
# [127]	validation_0-rmse:0.23065
# [128]	validation_0-rmse:0.23065
# [129]	validation_0-rmse:0.23058
# [130]	validation_0-rmse:0.23059
# [131]	validation_0-rmse:0.23059
# [132]	validation_0-rmse:0.23039
# [133]	validation_0-rmse:0.23014
# [134]	validation_0-rmse:0.23013
# [135]	validation_0-rmse:0.23013
# [136]	validation_0-rmse:0.23014
# [137]	validation_0-rmse:0.23009
# [138]	validation_0-rmse:0.23010
# [139]	validation_0-rmse:0.22983
# [140]	validation_0-rmse:0.22937
# [141]	validation_0-rmse:0.22937
# [142]	validation_0-rmse:0.22915
# [143]	validation_0-rmse:0.22915
# [144]	validation_0-rmse:0.22854
# [145]	validation_0-rmse:0.22821
# [146]	validation_0-rmse:0.22787
# [147]	validation_0-rmse:0.22786
# [148]	validation_0-rmse:0.22786
# [149]	validation_0-rmse:0.22786
# [150]	validation_0-rmse:0.22785
# [151]	validation_0-rmse:0.22785
# [152]	validation_0-rmse:0.22785
# [153]	validation_0-rmse:0.22786
# [154]	validation_0-rmse:0.22743
# [155]	validation_0-rmse:0.22742
# [156]	validation_0-rmse:0.22702
# [157]	validation_0-rmse:0.22703
# [158]	validation_0-rmse:0.22703
# [159]	validation_0-rmse:0.22703
# [160]	validation_0-rmse:0.22702
# [161]	validation_0-rmse:0.22683
# [162]	validation_0-rmse:0.22683
# [163]	validation_0-rmse:0.22683
# [164]	validation_0-rmse:0.22683
# [165]	validation_0-rmse:0.22655
# [166]	validation_0-rmse:0.22655
# [167]	validation_0-rmse:0.22655
# [168]	validation_0-rmse:0.22654
# [169]	validation_0-rmse:0.22654
# [170]	validation_0-rmse:0.22654
# [171]	validation_0-rmse:0.22607
# [172]	validation_0-rmse:0.22572
# [173]	validation_0-rmse:0.22572
# [174]	validation_0-rmse:0.22540
# [175]	validation_0-rmse:0.22514
# [176]	validation_0-rmse:0.22513
# [177]	validation_0-rmse:0.22491
# [178]	validation_0-rmse:0.22491
# [179]	validation_0-rmse:0.22457
# [180]	validation_0-rmse:0.22421
# [181]	validation_0-rmse:0.22348
# [182]	validation_0-rmse:0.22348
# [183]	validation_0-rmse:0.22348
# [184]	validation_0-rmse:0.22348
# [185]	validation_0-rmse:0.22348
# [186]	validation_0-rmse:0.22348
# [187]	validation_0-rmse:0.22348
# [188]	validation_0-rmse:0.22311
# [189]	validation_0-rmse:0.22276
# [190]	validation_0-rmse:0.22242
# [191]	validation_0-rmse:0.22242
# [192]	validation_0-rmse:0.22215
# [193]	validation_0-rmse:0.22185
# [194]	validation_0-rmse:0.22185
# [195]	validation_0-rmse:0.22185
# [196]	validation_0-rmse:0.22185
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 195

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  0.00
# RMSE: 0.2
# Relative RMSE(%):  10.078
# MSE: 0.0
# R square: 92.4%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-1.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.925
# Uncertainty
# a0: 0.213+/-0.022
# a1: 0.903+/-0.009

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../01_output_data/XGBoost_models/03_LN_M_stem_bark_other_authors_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../01_output_data/XGBoost_models/03_LN_M_stem_bark_other_authors_XGB_model.txt")
