# %% [markdown]
# ## Processing with biomass data of other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
input_data = './FULL_DB_BIOMASS_OTHER_ALL_AUTHORS.csv'
df = pd.read_csv(input_data)
df.head()
# Out:
#    Groups Species  Species_ID Origin  Origin_ID  SI  A_years   H_m  DBH_cm  \
# 0       1    Pine           0      n        0.0   4       50   9.7    14.6
# 1       1    Pine           0      n        0.0   2       65  20.6    20.6
# 2       1    Pine           0      n        0.0   2       50  13.6    15.4
# 3       1    Pine           0      n        0.0   1       60  23.3    22.2
# 4       1    Pine           0      n        0.0   3       65  15.6    16.4
#
#    N_trees  ...  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  \
# 0    486.0  ...             NaN             NaN         8.4           1.6
# 1    785.0  ...             NaN             NaN        11.5           4.1
# 2   1745.0  ...             NaN             NaN        13.7           4.1
# 3    665.0  ...             NaN             NaN        14.4           5.4
# 4    955.0  ...             NaN             NaN        14.2           3.4
#
#    LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  \
# 0         3.78              2.94                NaN                NaN
# 1         5.54              4.73                NaN                NaN
# 2         5.25              4.48                NaN                NaN
# 3         5.63              4.67                NaN                NaN
# 4         4.96              4.20                NaN                NaN
#
#    LN_Crown_t_ha  LN_Foliage_t_ha
# 0           2.13             0.47
# 1           2.44             1.41
# 2           2.62             1.41
# 3           2.67             1.69
# 4           2.65             1.22
#
# [5 rows x 24 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
#
# 'Groups','Species_ID','Origin_ID','SI','A_years','H_m','DBH_cm','RS(P)',          'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
# 'Crown_t_ha','Foliage_t_ha'
# 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species_ID','Origin_ID','H_m','DBH_cm', 'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
'Crown_t_ha','Foliage_t_ha', 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0           0        0.0   9.7    14.6         9.7      43.9           18.9
# 1           0        0.0  20.6    20.6        32.2     254.0          113.1
# 2           0        0.0  13.6    15.4        35.2     190.0           87.8
# 3           0        0.0  23.3    22.2        29.6     277.7          106.5
# 4           0        0.0  15.6    16.4        20.4     142.5           67.0
#
#    Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0             NaN             NaN         8.4           1.6         3.78
# 1             NaN             NaN        11.5           4.1         5.54
# 2             NaN             NaN        13.7           4.1         5.25
# 3             NaN             NaN        14.4           5.4         5.63
# 4             NaN             NaN        14.2           3.4         4.96
#
#    LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0              2.94                NaN                NaN           2.13
# 1              4.73                NaN                NaN           2.44
# 2              4.48                NaN                NaN           2.62
# 3              4.67                NaN                NaN           2.67
# 4              4.20                NaN                NaN           2.65
#
#    LN_Foliage_t_ha
# 0             0.47
# 1             1.41
# 2             1.41
# 3             1.69
# 4             1.22

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Species_ID         857 non-null    int64
#  1   Origin_ID          856 non-null    float64
#  2   H_m                857 non-null    float64
#  3   DBH_cm             856 non-null    float64
#  4   BA_sq_m_ha         857 non-null    float64
#  5   GS_cub_m           857 non-null    float64
#  6   ALL_STEM_t_ha      855 non-null    float64
#  7   Stem_wood_t_ha     747 non-null    float64
#  8   Stem_bark_t_ha     747 non-null    float64
#  9   Crown_t_ha         843 non-null    float64
#  10  Foliage_t_ha       854 non-null    float64
#  11  LN_GS_cub_m        857 non-null    float64
#  12  LN_ALL_STEM_t_ha   855 non-null    float64
#  13  LN_Stem_wood_t_ha  747 non-null    float64
#  14  LN_Stem_bark_t_ha  747 non-null    float64
#  15  LN_Crown_t_ha      843 non-null    float64
#  16  LN_Foliage_t_ha    854 non-null    float64
# dtypes: float64(16), int64(1)
# memory usage: 113.9 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species_ID"])["LN_GS_cub_m", "ALL_STEM_t_ha"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            LN_GS_cub_m                                                         \
#                  count      mean       std   min     25%    50%     75%   max
# Species_ID
# 0                458.0  5.192052  0.897136  0.88  4.8350  5.415  5.8075  6.60
# 1                  7.0  5.490000  0.589463  4.65  5.0350  5.700  5.9650  6.08
# 2                120.0  4.741667  0.702628  2.31  4.2150  4.855  5.3025  5.92
# 3                115.0  5.345478  0.624346  3.32  4.9250  5.500  5.8000  6.31
# 4                 66.0  5.057273  0.732497  3.05  4.6175  5.010  5.6675  6.26
# 5                 91.0  5.430220  0.830515  2.20  5.0700  5.610  6.0300  6.40
#
#            ALL_STEM_t_ha                                                       \
#                    count        mean        std   min     25%    50%      75%
# Species_ID
# 0                  457.0   97.049891  61.854506   1.8  47.500   92.7  135.900
# 1                    7.0  123.814286  61.879895  46.3  70.650  133.9  174.550
# 2                  120.0   74.495000  44.523333   5.1  37.275   68.1  103.075
# 3                  115.0  107.607826  55.589186  11.0  62.700  106.8  145.450
# 4                   66.0   84.946970  58.875162   8.2  40.750   61.2  125.000
# 5                   90.0  173.065556  99.100647   5.0  93.075  161.3  253.375
#
#
#               max
# Species_ID
# 0           310.7
# 1           196.1
# 2           193.5
# 3           251.6
# 4           245.4
# 5           363.9

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID   Origin_ID         H_m      DBH_cm  BA_sq_m_ha    GS_cub_m  \
# count  857.000000  856.000000  857.000000  856.000000  857.000000  857.000000
# mean     1.529755    0.279206   16.452275   17.132243   26.329988  229.013069
# std      1.823872    0.448871    7.039954   10.439115   10.629993  144.362106
# min      0.000000    0.000000    1.500000    1.100000    1.000000    2.400000
# 25%      0.000000    0.000000   11.200000    9.900000   19.000000  116.000000
# 50%      0.000000    0.000000   16.100000   15.500000   26.800000  206.000000
# 75%      3.000000    1.000000   21.200000   22.100000   34.500000  320.000000
# max      5.000000    1.000000   38.300000   94.000000   51.500000  735.000000
#
#        ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  \
# count     855.000000      747.000000      747.000000  843.000000
# mean      102.590877       92.779518       12.060107   13.821969
# std        68.758819       61.992238        9.595428   11.567546
# min         1.800000        2.000000        0.300000    0.500000
# 25%        47.500000       42.900000        5.950000    6.610000
# 50%        93.500000       84.600000        9.300000   10.820000
# 75%       140.500000      125.500000       15.300000   16.435000
# max       363.900000      315.200000       65.700000   69.120000
#
#        Foliage_t_ha  LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  \
# count    854.000000   857.000000        855.000000         747.000000
# mean       4.749356     5.166919          4.343766           4.246975
# std        2.826586     0.839680          0.869479           0.854856
# min        0.200000     0.880000          0.590000           0.690000
# 25%        2.600000     4.750000          3.860000           3.760000
# 50%        4.300000     5.330000          4.540000           4.440000
# 75%        6.367500     5.770000          4.950000           4.830000
# max       21.730000     6.600000          5.900000           5.750000
#
#        LN_Stem_bark_t_ha  LN_Crown_t_ha  LN_Foliage_t_ha
# count         747.000000     843.000000       854.000000
# mean            2.201232       2.318149         1.364906
# std             0.806766       0.829446         0.672551
# min            -1.200000      -0.690000        -1.610000
# 25%             1.780000       1.890000         0.960000
# 50%             2.230000       2.380000         1.460000
# 75%             2.730000       2.800000         1.850000
# max             4.190000       4.240000         3.080000

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['Species_ID','Origin_ID','H_m','DBH_cm','BA_sq_m_ha'])
y = pd.DataFrame(select, columns= ['GS_cub_m'])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha
# 0           0        0.0   9.7    14.6         9.7
# 1           0        0.0  20.6    20.6        32.2
# 2           0        0.0  13.6    15.4        35.2
# 3           0        0.0  23.3    22.2        29.6
# 4           0        0.0  15.6    16.4        20.4

# %%
# Columns in "y" data collections
y.head()
# Out:
#    GS_cub_m
# 0      43.9
# 1     254.0
# 2     190.0
# 3     277.7
# 4     142.5

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.9642204678299023, 0.9686814563213224, 0.9715340704339973]
#     Mean: 0.968
#     Std: 0.003
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [26.58718026 23.2556431  27.9260993 ]
#     Mean: 25.923
#     Std: 1.964
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [17.814951901335814, 17.966373831075387, 16.392036375748482]
#     Mean: 17.391
#     Std: 0.709
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.8829191872975016               # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.4317747333990657               # gamma
print('Gamma: ' + str(p2))

p3 = 0.17029218845451208              # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 4            # max_depth
print('Max_depth: ' + str(p4))

p5 = 172         # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.894854733579894            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.8829191872975016
# Gamma: 0.4317747333990657
# Learning_rate: 0.17029218845451208
# Max_depth: 4
# N_estimators: 172
# Subsample: 0.894854733579894

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:227.52680	validation_1-rmse:221.21383
# [1]	validation_0-rmse:192.00352	validation_1-rmse:187.46699
# [2]	validation_0-rmse:161.08932	validation_1-rmse:158.78864
# [3]	validation_0-rmse:135.70260	validation_1-rmse:134.94473
# [4]	validation_0-rmse:114.64620	validation_1-rmse:114.88237
# [5]	validation_0-rmse:96.95416	validation_1-rmse:98.40312
# [6]	validation_0-rmse:82.31309	validation_1-rmse:85.21834
# [7]	validation_0-rmse:70.13452	validation_1-rmse:73.99367
# [8]	validation_0-rmse:60.58436	validation_1-rmse:65.41461
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [9]	validation_0-rmse:52.36046	validation_1-rmse:57.64982
# [10]	validation_0-rmse:45.68470	validation_1-rmse:51.21540
# [11]	validation_0-rmse:40.07694	validation_1-rmse:45.84996
# [12]	validation_0-rmse:35.78956	validation_1-rmse:42.23605
# [13]	validation_0-rmse:32.14386	validation_1-rmse:38.92684
# [14]	validation_0-rmse:29.32809	validation_1-rmse:36.46252
# [15]	validation_0-rmse:27.00310	validation_1-rmse:34.28296
# [16]	validation_0-rmse:25.09974	validation_1-rmse:32.41514
# [17]	validation_0-rmse:23.65921	validation_1-rmse:30.93820
# [18]	validation_0-rmse:22.38590	validation_1-rmse:29.85636
# [19]	validation_0-rmse:21.42503	validation_1-rmse:28.80401
# [20]	validation_0-rmse:20.69253	validation_1-rmse:27.84626
# [21]	validation_0-rmse:20.01208	validation_1-rmse:26.88847
# [22]	validation_0-rmse:19.42072	validation_1-rmse:26.46197
# [70]	validation_0-rmse:11.94092	validation_1-rmse:22.41262
# [71]	validation_0-rmse:11.88413	validation_1-rmse:22.35848
# [72]	validation_0-rmse:11.80239	validation_1-rmse:22.36217
# [73]	validation_0-rmse:11.73131	validation_1-rmse:22.35742
# [74]	validation_0-rmse:11.65325	validation_1-rmse:22.39473
# [75]	validation_0-rmse:11.61338	validation_1-rmse:22.43110
# [76]	validation_0-rmse:11.45180	validation_1-rmse:22.37194
# [77]	validation_0-rmse:11.34414	validation_1-rmse:22.37092
# [78]	validation_0-rmse:11.24932	validation_1-rmse:22.32413
# [79]	validation_0-rmse:11.16205	validation_1-rmse:22.27779
# [80]	validation_0-rmse:11.05270	validation_1-rmse:22.24686
# [81]	validation_0-rmse:10.98712	validation_1-rmse:22.23856
# [82]	validation_0-rmse:10.87672	validation_1-rmse:22.21775
# [83]	validation_0-rmse:10.78919	validation_1-rmse:22.13334
# [84]	validation_0-rmse:10.75480	validation_1-rmse:22.07391
# [85]	validation_0-rmse:10.66862	validation_1-rmse:22.03767
# [86]	validation_0-rmse:10.58026	validation_1-rmse:21.98975
# [87]	validation_0-rmse:10.49410	validation_1-rmse:21.98396
# [88]	validation_0-rmse:10.43905	validation_1-rmse:21.91276
# [89]	validation_0-rmse:10.41833	validation_1-rmse:21.90696
# [90]	validation_0-rmse:10.33943	validation_1-rmse:21.89885
# [91]	validation_0-rmse:10.29401	validation_1-rmse:21.92399
# [92]	validation_0-rmse:10.19694	validation_1-rmse:21.99368
# [93]	validation_0-rmse:10.10283	validation_1-rmse:22.01402
# [94]	validation_0-rmse:10.04625	validation_1-rmse:21.99841
# [95]	validation_0-rmse:9.97546	validation_1-rmse:21.94253
# [96]	validation_0-rmse:9.91139	validation_1-rmse:21.85865
# [97]	validation_0-rmse:9.85042	validation_1-rmse:21.82526
# [98]	validation_0-rmse:9.80199	validation_1-rmse:21.83073
# [99]	validation_0-rmse:9.70999	validation_1-rmse:21.82963
# [100]	validation_0-rmse:9.63962	validation_1-rmse:21.80294
# [101]	validation_0-rmse:9.60970	validation_1-rmse:21.78378
# [102]	validation_0-rmse:9.55402	validation_1-rmse:21.76118
# [103]	validation_0-rmse:9.54038	validation_1-rmse:21.75960
# [104]	validation_0-rmse:9.48709	validation_1-rmse:21.73076
# [105]	validation_0-rmse:9.45574	validation_1-rmse:21.70292
# [106]	validation_0-rmse:9.39506	validation_1-rmse:21.68652
# [107]	validation_0-rmse:9.33999	validation_1-rmse:21.67692
# [108]	validation_0-rmse:9.29432	validation_1-rmse:21.63689
# [109]	validation_0-rmse:9.22922	validation_1-rmse:21.59244
# [110]	validation_0-rmse:9.21717	validation_1-rmse:21.56874
# [111]	validation_0-rmse:9.13630	validation_1-rmse:21.62590
# [112]	validation_0-rmse:9.09411	validation_1-rmse:21.62142
# [113]	validation_0-rmse:9.05006	validation_1-rmse:21.66403
# [114]	validation_0-rmse:8.98764	validation_1-rmse:21.63167
# [115]	validation_0-rmse:8.92528	validation_1-rmse:21.64165
# [116]	validation_0-rmse:8.88542	validation_1-rmse:21.65164
# [39]	validation_0-rmse:15.45323	validation_1-rmse:29.89701
# [40]	validation_0-rmse:15.25739	validation_1-rmse:29.88343
# [41]	validation_0-rmse:15.10332	validation_1-rmse:29.80958
# [42]	validation_0-rmse:14.93769	validation_1-rmse:29.78738
# [43]	validation_0-rmse:14.74339	validation_1-rmse:29.64988
# [44]	validation_0-rmse:14.57166	validation_1-rmse:29.66755
# [45]	validation_0-rmse:14.41710	validation_1-rmse:29.70418
# [46]	validation_0-rmse:14.18992	validation_1-rmse:29.67498
# [47]	validation_0-rmse:14.14404	validation_1-rmse:29.67391
# [48]	validation_0-rmse:13.94167	validation_1-rmse:29.58363
# [49]	validation_0-rmse:13.76902	validation_1-rmse:29.38623
# [50]	validation_0-rmse:13.68919	validation_1-rmse:29.28274
# [51]	validation_0-rmse:13.62606	validation_1-rmse:29.26040
# [52]	validation_0-rmse:13.58118	validation_1-rmse:29.21650
# [53]	validation_0-rmse:13.41521	validation_1-rmse:29.17660
# [54]	validation_0-rmse:13.32182	validation_1-rmse:29.13135
# [55]	validation_0-rmse:13.17018	validation_1-rmse:29.03745
# [56]	validation_0-rmse:13.00622	validation_1-rmse:28.97307
# [57]	validation_0-rmse:12.91210	validation_1-rmse:28.97690
# [58]	validation_0-rmse:12.75729	validation_1-rmse:28.87773
# [59]	validation_0-rmse:12.64495	validation_1-rmse:28.90640
# [60]	validation_0-rmse:12.54763	validation_1-rmse:28.81419
# [61]	validation_0-rmse:12.48600	validation_1-rmse:28.78065
# [62]	validation_0-rmse:12.33532	validation_1-rmse:28.73482
# [63]	validation_0-rmse:12.26742	validation_1-rmse:28.62800
# [64]	validation_0-rmse:12.22940	validation_1-rmse:28.68737
# [65]	validation_0-rmse:12.07921	validation_1-rmse:28.67874
# [66]	validation_0-rmse:11.97625	validation_1-rmse:28.70052
# [67]	validation_0-rmse:11.91304	validation_1-rmse:28.66690
# [68]	validation_0-rmse:11.79223	validation_1-rmse:28.61328
# [69]	validation_0-rmse:11.73705	validation_1-rmse:28.60761
# [70]	validation_0-rmse:11.67665	validation_1-rmse:28.63776
# [71]	validation_0-rmse:11.60414	validation_1-rmse:28.65040
# [72]	validation_0-rmse:11.57295	validation_1-rmse:28.72092
# [73]	validation_0-rmse:11.52065	validation_1-rmse:28.68408
# [74]	validation_0-rmse:11.41501	validation_1-rmse:28.70857
# [75]	validation_0-rmse:11.34959	validation_1-rmse:28.71278
# [76]	validation_0-rmse:11.20171	validation_1-rmse:28.54765
# [77]	validation_0-rmse:11.16245	validation_1-rmse:28.59155
# [78]	validation_0-rmse:11.12268	validation_1-rmse:28.56713
# [79]	validation_0-rmse:11.03444	validation_1-rmse:28.57480
# [80]	validation_0-rmse:10.97414	validation_1-rmse:28.55964
# [81]	validation_0-rmse:10.85976	validation_1-rmse:28.53631
# [82]	validation_0-rmse:10.83284	validation_1-rmse:28.44476
# [83]	validation_0-rmse:10.75527	validation_1-rmse:28.48639
# [84]	validation_0-rmse:10.69825	validation_1-rmse:28.43174
# [85]	validation_0-rmse:10.57875	validation_1-rmse:28.42190
# [133]	validation_0-rmse:8.03587	validation_1-rmse:27.97361
# [134]	validation_0-rmse:7.96684	validation_1-rmse:27.94955
# [135]	validation_0-rmse:7.93878	validation_1-rmse:27.94890
# [136]	validation_0-rmse:7.90390	validation_1-rmse:27.89887
# [137]	validation_0-rmse:7.86358	validation_1-rmse:27.89579
# [138]	validation_0-rmse:7.80671	validation_1-rmse:27.88584
# [139]	validation_0-rmse:7.78874	validation_1-rmse:27.85551
# [140]	validation_0-rmse:7.73028	validation_1-rmse:27.84449
# [141]	validation_0-rmse:7.67922	validation_1-rmse:27.82164
# [142]	validation_0-rmse:7.62328	validation_1-rmse:27.86693
# [143]	validation_0-rmse:7.59223	validation_1-rmse:27.86051
# [144]	validation_0-rmse:7.57344	validation_1-rmse:27.84577
# [145]	validation_0-rmse:7.51654	validation_1-rmse:27.81811
# [146]	validation_0-rmse:7.46492	validation_1-rmse:27.82510
# [147]	validation_0-rmse:7.41935	validation_1-rmse:27.83261
# [148]	validation_0-rmse:7.38804	validation_1-rmse:27.82691
# [149]	validation_0-rmse:7.35796	validation_1-rmse:27.83122
# [150]	validation_0-rmse:7.35123	validation_1-rmse:27.85221
# [151]	validation_0-rmse:7.32652	validation_1-rmse:27.82273
# [152]	validation_0-rmse:7.26228	validation_1-rmse:27.85744
# [153]	validation_0-rmse:7.20157	validation_1-rmse:27.86169
# [154]	validation_0-rmse:7.18498	validation_1-rmse:27.85552
# [155]	validation_0-rmse:7.12053	validation_1-rmse:27.83207
# [156]	validation_0-rmse:7.06672	validation_1-rmse:27.80764
# [157]	validation_0-rmse:7.03773	validation_1-rmse:27.79614
# [158]	validation_0-rmse:6.99594	validation_1-rmse:27.79805
# [159]	validation_0-rmse:6.93508	validation_1-rmse:27.74793
# [160]	validation_0-rmse:6.88772	validation_1-rmse:27.74603
# [161]	validation_0-rmse:6.87957	validation_1-rmse:27.76314
# [162]	validation_0-rmse:6.86968	validation_1-rmse:27.76589
# [163]	validation_0-rmse:6.81828	validation_1-rmse:27.79952
# [164]	validation_0-rmse:6.81063	validation_1-rmse:27.79457
# [165]	validation_0-rmse:6.78161	validation_1-rmse:27.79557
# [166]	validation_0-rmse:6.77270	validation_1-rmse:27.80259
# [167]	validation_0-rmse:6.74806	validation_1-rmse:27.78573
# [168]	validation_0-rmse:6.71426	validation_1-rmse:27.77208
# [169]	validation_0-rmse:6.67116	validation_1-rmse:27.78447
# [170]	validation_0-rmse:6.64295	validation_1-rmse:27.76276
# [171]	validation_0-rmse:6.59883	validation_1-rmse:27.79239
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:225.96277	validation_1-rmse:229.81492
# [1]	validation_0-rmse:190.69529	validation_1-rmse:195.44576
# [2]	validation_0-rmse:159.84087	validation_1-rmse:164.92230
# [3]	validation_0-rmse:134.61846	validation_1-rmse:140.23290
# [4]	validation_0-rmse:113.58340	validation_1-rmse:119.36757
# [5]	validation_0-rmse:95.92778	validation_1-rmse:102.23167
# [6]	validation_0-rmse:81.31327	validation_1-rmse:87.96113
# [7]	validation_0-rmse:69.47029	validation_1-rmse:76.72857
# [8]	validation_0-rmse:59.95910	validation_1-rmse:68.11008
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#
# [56]	validation_0-rmse:12.60225	validation_1-rmse:28.64989
# [57]	validation_0-rmse:12.56171	validation_1-rmse:28.62358
# [58]	validation_0-rmse:12.51953	validation_1-rmse:28.62192
# [59]	validation_0-rmse:12.29945	validation_1-rmse:28.54688
# [60]	validation_0-rmse:12.24081	validation_1-rmse:28.52191
# [61]	validation_0-rmse:12.17243	validation_1-rmse:28.47339
# [62]	validation_0-rmse:12.06991	validation_1-rmse:28.48278
# [63]	validation_0-rmse:11.96263	validation_1-rmse:28.45251
# [64]	validation_0-rmse:11.90614	validation_1-rmse:28.47181
# [65]	validation_0-rmse:11.84622	validation_1-rmse:28.40083
# [66]	validation_0-rmse:11.79047	validation_1-rmse:28.39428
# [67]	validation_0-rmse:11.68356	validation_1-rmse:28.41077
# [68]	validation_0-rmse:11.65897	validation_1-rmse:28.39725
# [69]	validation_0-rmse:11.57476	validation_1-rmse:28.34153
# [70]	validation_0-rmse:11.48108	validation_1-rmse:28.28803
# [71]	validation_0-rmse:11.34895	validation_1-rmse:28.18035
# [72]	validation_0-rmse:11.19957	validation_1-rmse:28.19534
# [73]	validation_0-rmse:11.17376	validation_1-rmse:28.20841
# [74]	validation_0-rmse:11.08084	validation_1-rmse:28.18181
# [75]	validation_0-rmse:11.03324	validation_1-rmse:28.14950
# [76]	validation_0-rmse:10.97210	validation_1-rmse:28.07593
# [77]	validation_0-rmse:10.91148	validation_1-rmse:28.03686
# [78]	validation_0-rmse:10.77131	validation_1-rmse:27.94487
# [79]	validation_0-rmse:10.69169	validation_1-rmse:27.91243
# [80]	validation_0-rmse:10.66965	validation_1-rmse:27.89947
# [81]	validation_0-rmse:10.57815	validation_1-rmse:27.90647
# [82]	validation_0-rmse:10.52269	validation_1-rmse:27.90294
# [83]	validation_0-rmse:10.44623	validation_1-rmse:27.92710
# [84]	validation_0-rmse:10.37204	validation_1-rmse:27.85704
# [85]	validation_0-rmse:10.31724	validation_1-rmse:27.84828
# [86]	validation_0-rmse:10.23818	validation_1-rmse:27.82079
# [87]	validation_0-rmse:10.20695	validation_1-rmse:27.82093
# [88]	validation_0-rmse:10.15242	validation_1-rmse:27.77759
# [89]	validation_0-rmse:10.08616	validation_1-rmse:27.80231
# [90]	validation_0-rmse:10.04992	validation_1-rmse:27.82195
# [91]	validation_0-rmse:9.99506	validation_1-rmse:27.81000
# [92]	validation_0-rmse:9.95006	validation_1-rmse:27.74775
# [93]	validation_0-rmse:9.91981	validation_1-rmse:27.72482
# [94]	validation_0-rmse:9.81835	validation_1-rmse:27.66682
# [95]	validation_0-rmse:9.71042	validation_1-rmse:27.69077
# [96]	validation_0-rmse:9.64486	validation_1-rmse:27.65556
# [97]	validation_0-rmse:9.56782	validation_1-rmse:27.63558
# [98]	validation_0-rmse:9.53872	validation_1-rmse:27.63498
# [99]	validation_0-rmse:9.45379	validation_1-rmse:27.65611
# [100]	validation_0-rmse:9.38458	validation_1-rmse:27.60934
# [101]	validation_0-rmse:9.32644	validation_1-rmse:27.51006
# [102]	validation_0-rmse:9.23023	validation_1-rmse:27.48574
# [103]	validation_0-rmse:9.16627	validation_1-rmse:27.46002
# [104]	validation_0-rmse:9.09751	validation_1-rmse:27.41082
# [105]	validation_0-rmse:9.05661	validation_1-rmse:27.38585
# [106]	validation_0-rmse:9.03807	validation_1-rmse:27.38007
# [107]	validation_0-rmse:8.97676	validation_1-rmse:27.41853
# [108]	validation_0-rmse:8.94127	validation_1-rmse:27.41680
# [109]	validation_0-rmse:8.88557	validation_1-rmse:27.41599
# [110]	validation_0-rmse:8.82784	validation_1-rmse:27.39962
# [111]	validation_0-rmse:8.79246	validation_1-rmse:27.39459
# [112]	validation_0-rmse:8.72224	validation_1-rmse:27.36809
# [113]	validation_0-rmse:8.63392	validation_1-rmse:27.32793
# [114]	validation_0-rmse:8.58918	validation_1-rmse:27.35137
# [115]	validation_0-rmse:8.54470	validation_1-rmse:27.35514
# [116]	validation_0-rmse:8.47056	validation_1-rmse:27.32356
# [117]	validation_0-rmse:8.41241	validation_1-rmse:27.35494
# [118]	validation_0-rmse:8.39075	validation_1-rmse:27.34308
# [119]	validation_0-rmse:8.37250	validation_1-rmse:27.30719
# [120]	validation_0-rmse:8.35285	validation_1-rmse:27.27706
# [121]	validation_0-rmse:8.32361	validation_1-rmse:27.26364
# [122]	validation_0-rmse:8.28440	validation_1-rmse:27.25442
# [123]	validation_0-rmse:8.24078	validation_1-rmse:27.22386
# [124]	validation_0-rmse:8.19135	validation_1-rmse:27.21442
# [125]	validation_0-rmse:8.13833	validation_1-rmse:27.19909
# [126]	validation_0-rmse:8.08752	validation_1-rmse:27.15435
# [127]	validation_0-rmse:8.00720	validation_1-rmse:27.17413
# [128]	validation_0-rmse:7.98903	validation_1-rmse:27.17148
# [129]	validation_0-rmse:7.96370	validation_1-rmse:27.16989
# [130]	validation_0-rmse:7.93009	validation_1-rmse:27.18762
# [131]	validation_0-rmse:7.85716	validation_1-rmse:27.19825
# [132]	validation_0-rmse:7.84231	validation_1-rmse:27.19862
# [133]	validation_0-rmse:7.77457	validation_1-rmse:27.14757
# [134]	validation_0-rmse:7.69363	validation_1-rmse:27.17930
# [135]	validation_0-rmse:7.62240	validation_1-rmse:27.18289
# [136]	validation_0-rmse:7.57903	validation_1-rmse:27.17076
# [137]	validation_0-rmse:7.56046	validation_1-rmse:27.16598
# [138]	validation_0-rmse:7.49459	validation_1-rmse:27.12977
# [139]	validation_0-rmse:7.45911	validation_1-rmse:27.12702
# [140]	validation_0-rmse:7.39757	validation_1-rmse:27.13530
# [141]	validation_0-rmse:7.36276	validation_1-rmse:27.13169
# [142]	validation_0-rmse:7.31409	validation_1-rmse:27.14426
# [143]	validation_0-rmse:7.28037	validation_1-rmse:27.12287
# [144]	validation_0-rmse:7.23687	validation_1-rmse:27.13299
# [145]	validation_0-rmse:7.20690	validation_1-rmse:27.11761
# [146]	validation_0-rmse:7.14240	validation_1-rmse:27.07569
# [147]	validation_0-rmse:7.11535	validation_1-rmse:27.05626
# [148]	validation_0-rmse:7.07843	validation_1-rmse:27.05214
# [149]	validation_0-rmse:7.03125	validation_1-rmse:27.04268
# [150]	validation_0-rmse:6.98657	validation_1-rmse:27.05369
# [151]	validation_0-rmse:6.96020	validation_1-rmse:27.03413
# [152]	validation_0-rmse:6.92357	validation_1-rmse:26.99545
# [153]	validation_0-rmse:6.90187	validation_1-rmse:27.00204
# [154]	validation_0-rmse:6.87018	validation_1-rmse:26.98331
# [155]	validation_0-rmse:6.83939	validation_1-rmse:26.96326
# [156]	validation_0-rmse:6.78419	validation_1-rmse:26.91143
# [157]	validation_0-rmse:6.75649	validation_1-rmse:26.89879
# [158]	validation_0-rmse:6.71804	validation_1-rmse:26.92361
# [159]	validation_0-rmse:6.67169	validation_1-rmse:26.93167
# [160]	validation_0-rmse:6.64800	validation_1-rmse:26.95464
# [161]	validation_0-rmse:6.62367	validation_1-rmse:26.98516
# [162]	validation_0-rmse:6.59391	validation_1-rmse:26.98265
# [163]	validation_0-rmse:6.55702	validation_1-rmse:26.97674
# [164]	validation_0-rmse:6.53368	validation_1-rmse:26.94983
# [165]	validation_0-rmse:6.49798	validation_1-rmse:26.95610
# [166]	validation_0-rmse:6.47149	validation_1-rmse:26.96341
# [167]	validation_0-rmse:6.44889	validation_1-rmse:26.96518
# [168]	validation_0-rmse:6.41309	validation_1-rmse:26.96646
# [169]	validation_0-rmse:6.38891	validation_1-rmse:26.95168
# [170]	validation_0-rmse:6.36106	validation_1-rmse:26.96761
# [171]	validation_0-rmse:6.32314	validation_1-rmse:26.96380
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:222.66112	validation_1-rmse:240.57411
# [1]	validation_0-rmse:188.29223	validation_1-rmse:203.87906
# [2]	validation_0-rmse:158.20682	validation_1-rmse:171.08585
# [3]	validation_0-rmse:133.16438	validation_1-rmse:143.43316
# [4]	validation_0-rmse:112.60449	validation_1-rmse:120.52828
# [5]	validation_0-rmse:95.37505	validation_1-rmse:101.57046
# [6]	validation_0-rmse:80.93786	validation_1-rmse:86.45996
# [7]	validation_0-rmse:69.26066	validation_1-rmse:73.86655
# [8]	validation_0-rmse:60.09700	validation_1-rmse:64.52158
# [9]	validation_0-rmse:52.05510	validation_1-rmse:56.50652
# [10]	validation_0-rmse:45.31132	validation_1-rmse:49.75901
# [11]	validation_0-rmse:39.87429	validation_1-rmse:44.70763
# [12]	validation_0-rmse:35.84360	validation_1-rmse:40.94231
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [13]	validation_0-rmse:32.17619	validation_1-rmse:37.73970
# [14]	validation_0-rmse:29.21016	validation_1-rmse:35.16826
# [15]	validation_0-rmse:26.90234	validation_1-rmse:33.38553
# [16]	validation_0-rmse:25.13029	validation_1-rmse:32.09284
# [17]	validation_0-rmse:23.60573	validation_1-rmse:31.20313
# [18]	validation_0-rmse:22.40687	validation_1-rmse:30.52966
# [19]	validation_0-rmse:21.44821	validation_1-rmse:29.86203
# [20]	validation_0-rmse:20.72384	validation_1-rmse:29.54077
# [21]	validation_0-rmse:20.13167	validation_1-rmse:29.22756
# [22]	validation_0-rmse:19.63981	validation_1-rmse:29.11561
# [23]	validation_0-rmse:19.27961	validation_1-rmse:29.10751
# [24]	validation_0-rmse:18.94257	validation_1-rmse:28.83231
# [25]	validation_0-rmse:18.48973	validation_1-rmse:28.44294
# [73]	validation_0-rmse:12.07944	validation_1-rmse:25.15077
# [74]	validation_0-rmse:11.98731	validation_1-rmse:25.09846
# [75]	validation_0-rmse:11.91271	validation_1-rmse:24.98241
# [76]	validation_0-rmse:11.88363	validation_1-rmse:24.96535
# [77]	validation_0-rmse:11.81639	validation_1-rmse:24.93873
# [78]	validation_0-rmse:11.75518	validation_1-rmse:24.93083
# [79]	validation_0-rmse:11.66520	validation_1-rmse:25.01750
# [80]	validation_0-rmse:11.60437	validation_1-rmse:24.98222
# [81]	validation_0-rmse:11.49032	validation_1-rmse:24.92435
# [82]	validation_0-rmse:11.40700	validation_1-rmse:24.89670
# [83]	validation_0-rmse:11.33601	validation_1-rmse:24.85815
# [84]	validation_0-rmse:11.25050	validation_1-rmse:24.83847
# [85]	validation_0-rmse:11.22831	validation_1-rmse:24.78190
# [86]	validation_0-rmse:11.15412	validation_1-rmse:24.76827
# [87]	validation_0-rmse:11.09139	validation_1-rmse:24.68775
# [88]	validation_0-rmse:11.00412	validation_1-rmse:24.61446
# [89]	validation_0-rmse:10.93873	validation_1-rmse:24.61639
# [90]	validation_0-rmse:10.84484	validation_1-rmse:24.49835
# [91]	validation_0-rmse:10.80117	validation_1-rmse:24.48018
# [92]	validation_0-rmse:10.72745	validation_1-rmse:24.46926
# [93]	validation_0-rmse:10.69058	validation_1-rmse:24.46717
# [94]	validation_0-rmse:10.63218	validation_1-rmse:24.35442
# [95]	validation_0-rmse:10.56008	validation_1-rmse:24.34911
# [96]	validation_0-rmse:10.49177	validation_1-rmse:24.34853
# [97]	validation_0-rmse:10.42275	validation_1-rmse:24.30286
# [98]	validation_0-rmse:10.36399	validation_1-rmse:24.27457
# [99]	validation_0-rmse:10.33422	validation_1-rmse:24.28016
# [100]	validation_0-rmse:10.29294	validation_1-rmse:24.28513
# [101]	validation_0-rmse:10.22319	validation_1-rmse:24.21489
# [102]	validation_0-rmse:10.14119	validation_1-rmse:24.22492
# [103]	validation_0-rmse:10.06441	validation_1-rmse:24.24071
# [104]	validation_0-rmse:9.98890	validation_1-rmse:24.19545
# [105]	validation_0-rmse:9.94978	validation_1-rmse:24.12306
# [106]	validation_0-rmse:9.89205	validation_1-rmse:24.05333
# [107]	validation_0-rmse:9.83177	validation_1-rmse:24.01728
# [108]	validation_0-rmse:9.73621	validation_1-rmse:23.96367
# [109]	validation_0-rmse:9.71860	validation_1-rmse:23.96838
# [110]	validation_0-rmse:9.69406	validation_1-rmse:23.95641
# [111]	validation_0-rmse:9.62932	validation_1-rmse:23.88606
# [112]	validation_0-rmse:9.59817	validation_1-rmse:23.93834
# [113]	validation_0-rmse:9.52377	validation_1-rmse:23.96347
# [114]	validation_0-rmse:9.47248	validation_1-rmse:23.96260
# [115]	validation_0-rmse:9.36366	validation_1-rmse:23.91291
# [116]	validation_0-rmse:9.32442	validation_1-rmse:23.83550
# [117]	validation_0-rmse:9.25684	validation_1-rmse:23.81294
# [118]	validation_0-rmse:9.17730	validation_1-rmse:23.75628
# [119]	validation_0-rmse:9.09415	validation_1-rmse:23.67849
# [120]	validation_0-rmse:9.01725	validation_1-rmse:23.72507
# [121]	validation_0-rmse:8.90599	validation_1-rmse:23.66702
# ...
# [19]	validation_0-rmse:21.10360	validation_1-rmse:33.35721
# [20]	validation_0-rmse:20.43672	validation_1-rmse:32.79188
# [21]	validation_0-rmse:19.65700	validation_1-rmse:31.81492
# [22]	validation_0-rmse:19.14066	validation_1-rmse:31.24647
# [23]	validation_0-rmse:18.74764	validation_1-rmse:30.98995
# [24]	validation_0-rmse:18.28702	validation_1-rmse:30.56104
# [25]	validation_0-rmse:17.98578	validation_1-rmse:30.19318
# [26]	validation_0-rmse:17.73438	validation_1-rmse:29.86589
# [27]	validation_0-rmse:17.48083	validation_1-rmse:29.51035
# [28]	validation_0-rmse:17.19973	validation_1-rmse:29.27159
# [29]	validation_0-rmse:17.00278	validation_1-rmse:28.99697
# [30]	validation_0-rmse:16.79928	validation_1-rmse:28.70178
# [31]	validation_0-rmse:16.48563	validation_1-rmse:28.47172
# [32]	validation_0-rmse:16.23860	validation_1-rmse:28.12045
# [33]	validation_0-rmse:16.06262	validation_1-rmse:27.97776
# [34]	validation_0-rmse:15.95641	validation_1-rmse:27.85038
# [35]	validation_0-rmse:15.77840	validation_1-rmse:27.65250
# [36]	validation_0-rmse:15.69189	validation_1-rmse:27.52738
# [37]	validation_0-rmse:15.56096	validation_1-rmse:27.43633
# [38]	validation_0-rmse:15.51571	validation_1-rmse:27.37153
# [39]	validation_0-rmse:15.28303	validation_1-rmse:27.14147
# [40]	validation_0-rmse:15.06951	validation_1-rmse:26.94247
# [41]	validation_0-rmse:14.94353	validation_1-rmse:26.85879
# [42]	validation_0-rmse:14.87363	validation_1-rmse:26.79970
# [43]	validation_0-rmse:14.80656	validation_1-rmse:26.74254
# [44]	validation_0-rmse:14.71209	validation_1-rmse:26.66316
# [45]	validation_0-rmse:14.59214	validation_1-rmse:26.63991
# [46]	validation_0-rmse:14.50498	validation_1-rmse:26.53532
# [47]	validation_0-rmse:14.42259	validation_1-rmse:26.54105
# [48]	validation_0-rmse:14.26910	validation_1-rmse:26.48647
# [49]	validation_0-rmse:14.01844	validation_1-rmse:26.42464
# [50]	validation_0-rmse:13.77103	validation_1-rmse:26.12464
# [51]	validation_0-rmse:13.70662	validation_1-rmse:26.04925
# [52]	validation_0-rmse:13.66657	validation_1-rmse:26.01332
# [53]	validation_0-rmse:13.51022	validation_1-rmse:25.81522
# [54]	validation_0-rmse:13.44725	validation_1-rmse:25.79089
# [55]	validation_0-rmse:13.28760	validation_1-rmse:25.75370
# [56]	validation_0-rmse:13.18853	validation_1-rmse:25.70172
# [57]	validation_0-rmse:13.06732	validation_1-rmse:25.63165
# [58]	validation_0-rmse:12.94481	validation_1-rmse:25.50973
# [59]	validation_0-rmse:12.88411	validation_1-rmse:25.58796
# [60]	validation_0-rmse:12.81458	validation_1-rmse:25.56758
# [61]	validation_0-rmse:12.74748	validation_1-rmse:25.47623
# [62]	validation_0-rmse:12.58481	validation_1-rmse:25.36186
# [63]	validation_0-rmse:12.45664	validation_1-rmse:25.29865
# [64]	validation_0-rmse:12.38526	validation_1-rmse:25.26668
# [65]	validation_0-rmse:12.35491	validation_1-rmse:25.18359
# [66]	validation_0-rmse:12.28627	validation_1-rmse:25.23411
# [67]	validation_0-rmse:12.16853	validation_1-rmse:25.22157
# [68]	validation_0-rmse:12.04240	validation_1-rmse:25.21256
# [69]	validation_0-rmse:11.96826	validation_1-rmse:25.19735
# [70]	validation_0-rmse:11.90674	validation_1-rmse:25.12202
# [71]	validation_0-rmse:11.78135	validation_1-rmse:25.12297
# [72]	validation_0-rmse:11.72954	validation_1-rmse:25.13951
# [73]	validation_0-rmse:11.60583	validation_1-rmse:25.12519
# [74]	validation_0-rmse:11.47531	validation_1-rmse:25.09424
# [75]	validation_0-rmse:11.42277	validation_1-rmse:25.06429
# [76]	validation_0-rmse:11.27558	validation_1-rmse:25.03770
# [77]	validation_0-rmse:11.16494	validation_1-rmse:24.99183
# [78]	validation_0-rmse:11.09781	validation_1-rmse:25.04365
# [79]	validation_0-rmse:11.02490	validation_1-rmse:25.04493
# [80]	validation_0-rmse:10.95165	validation_1-rmse:24.95682
# [81]	validation_0-rmse:10.88321	validation_1-rmse:24.95635
# [82]	validation_0-rmse:10.79439	validation_1-rmse:24.89004
# [83]	validation_0-rmse:10.75277	validation_1-rmse:24.87435
# [84]	validation_0-rmse:10.66797	validation_1-rmse:24.78497
# [85]	validation_0-rmse:10.61895	validation_1-rmse:24.75973
# [86]	validation_0-rmse:10.58751	validation_1-rmse:24.81051
# [87]	validation_0-rmse:10.51951	validation_1-rmse:24.76760
# [88]	validation_0-rmse:10.45267	validation_1-rmse:24.71197
# [89]	validation_0-rmse:10.34990	validation_1-rmse:24.63793
# [90]	validation_0-rmse:10.29235	validation_1-rmse:24.64257
# [91]	validation_0-rmse:10.22667	validation_1-rmse:24.61000
# [92]	validation_0-rmse:10.19869	validation_1-rmse:24.57888
# [93]	validation_0-rmse:10.17120	validation_1-rmse:24.57643
# [94]	validation_0-rmse:10.07895	validation_1-rmse:24.49874
# [95]	validation_0-rmse:10.01076	validation_1-rmse:24.47012
# [96]	validation_0-rmse:9.91050	validation_1-rmse:24.44847
# [97]	validation_0-rmse:9.82046	validation_1-rmse:24.33508
# [98]	validation_0-rmse:9.74898	validation_1-rmse:24.29289
# [99]	validation_0-rmse:9.67464	validation_1-rmse:24.27469
# [100]	validation_0-rmse:9.62922	validation_1-rmse:24.24922
# [101]	validation_0-rmse:9.54884	validation_1-rmse:24.15584
# [102]	validation_0-rmse:9.48430	validation_1-rmse:24.12957
# [103]	validation_0-rmse:9.43359	validation_1-rmse:24.08590
# [104]	validation_0-rmse:9.36682	validation_1-rmse:24.02095
# [105]	validation_0-rmse:9.32654	validation_1-rmse:24.02113
# [106]	validation_0-rmse:9.25628	validation_1-rmse:23.99080
# [107]	validation_0-rmse:9.16431	validation_1-rmse:23.90832
# [108]	validation_0-rmse:9.09955	validation_1-rmse:23.90797
# [109]	validation_0-rmse:9.05306	validation_1-rmse:23.86665
# [110]	validation_0-rmse:8.97858	validation_1-rmse:23.87012
# [111]	validation_0-rmse:8.93288	validation_1-rmse:23.84903
# [112]	validation_0-rmse:8.88731	validation_1-rmse:23.83171
# [113]	validation_0-rmse:8.85111	validation_1-rmse:23.83447
# [114]	validation_0-rmse:8.83373	validation_1-rmse:23.86723
# [115]	validation_0-rmse:8.76687	validation_1-rmse:23.81583
# [116]	validation_0-rmse:8.68410	validation_1-rmse:23.82701
# [117]	validation_0-rmse:8.64565	validation_1-rmse:23.82913
# [118]	validation_0-rmse:8.57151	validation_1-rmse:23.80334
# [119]	validation_0-rmse:8.53214	validation_1-rmse:23.80994
# [120]	validation_0-rmse:8.46046	validation_1-rmse:23.79763
# [121]	validation_0-rmse:8.42615	validation_1-rmse:23.79656
# [122]	validation_0-rmse:8.39837	validation_1-rmse:23.76716
# [123]	validation_0-rmse:8.37198	validation_1-rmse:23.75412
# [124]	validation_0-rmse:8.33023	validation_1-rmse:23.73900
# [125]	validation_0-rmse:8.30796	validation_1-rmse:23.80023
# [126]	validation_0-rmse:8.28967	validation_1-rmse:23.80088
# [127]	validation_0-rmse:8.22930	validation_1-rmse:23.80515
# [128]	validation_0-rmse:8.20959	validation_1-rmse:23.81396
# [129]	validation_0-rmse:8.15490	validation_1-rmse:23.79356
# [130]	validation_0-rmse:8.08329	validation_1-rmse:23.77939
# [131]	validation_0-rmse:8.04543	validation_1-rmse:23.78176
# [132]	validation_0-rmse:7.97067	validation_1-rmse:23.78825
# [133]	validation_0-rmse:7.92738	validation_1-rmse:23.78577
# [134]	validation_0-rmse:7.89081	validation_1-rmse:23.77941
# [135]	validation_0-rmse:7.80753	validation_1-rmse:23.75663
# [136]	validation_0-rmse:7.78666	validation_1-rmse:23.74393
# [137]	validation_0-rmse:7.76370	validation_1-rmse:23.73283
# [138]	validation_0-rmse:7.72601	validation_1-rmse:23.62396
# [139]	validation_0-rmse:7.66845	validation_1-rmse:23.60787
# [140]	validation_0-rmse:7.59806	validation_1-rmse:23.61845
# [141]	validation_0-rmse:7.54987	validation_1-rmse:23.59623
# [142]	validation_0-rmse:7.50115	validation_1-rmse:23.57176
# [143]	validation_0-rmse:7.45619	validation_1-rmse:23.51702
# [144]	validation_0-rmse:7.42283	validation_1-rmse:23.51701
# [145]	validation_0-rmse:7.38677	validation_1-rmse:23.50468
# [146]	validation_0-rmse:7.32491	validation_1-rmse:23.44724
# [147]	validation_0-rmse:7.29208	validation_1-rmse:23.43669
# [148]	validation_0-rmse:7.26277	validation_1-rmse:23.43698
# [149]	validation_0-rmse:7.22626	validation_1-rmse:23.45051
# [150]	validation_0-rmse:7.19183	validation_1-rmse:23.43031
# [151]	validation_0-rmse:7.16490	validation_1-rmse:23.43140
# [152]	validation_0-rmse:7.12462	validation_1-rmse:23.41123
# [153]	validation_0-rmse:7.11822	validation_1-rmse:23.40403
# [154]	validation_0-rmse:7.09630	validation_1-rmse:23.38034
# [155]	validation_0-rmse:7.07875	validation_1-rmse:23.37494
# [156]	validation_0-rmse:7.04262	validation_1-rmse:23.37112
# [157]	validation_0-rmse:7.00885	validation_1-rmse:23.36057
# [158]	validation_0-rmse:6.97667	validation_1-rmse:23.36374
# [159]	validation_0-rmse:6.94079	validation_1-rmse:23.39037
# [160]	validation_0-rmse:6.92422	validation_1-rmse:23.37927
# [161]	validation_0-rmse:6.91043	validation_1-rmse:23.39067
# [162]	validation_0-rmse:6.89785	validation_1-rmse:23.40211
# [163]	validation_0-rmse:6.87949	validation_1-rmse:23.40480
# [164]	validation_0-rmse:6.86420	validation_1-rmse:23.40578
# [165]	validation_0-rmse:6.83609	validation_1-rmse:23.39199
# [166]	validation_0-rmse:6.82275	validation_1-rmse:23.38654
# [167]	validation_0-rmse:6.78281	validation_1-rmse:23.40133
# [168]	validation_0-rmse:6.75306	validation_1-rmse:23.41230
# [169]	validation_0-rmse:6.69860	validation_1-rmse:23.41060
# [170]	validation_0-rmse:6.66577	validation_1-rmse:23.41503
# [171]	validation_0-rmse:6.65130	validation_1-rmse:23.42622
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:223.89854	validation_1-rmse:233.69860
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:189.29271	validation_1-rmse:197.12376
# [2]	validation_0-rmse:158.87830	validation_1-rmse:164.24778
# [3]	validation_0-rmse:133.50236	validation_1-rmse:136.78367
# [4]	validation_0-rmse:113.01662	validation_1-rmse:114.80285
# [5]	validation_0-rmse:95.63493	validation_1-rmse:95.39951
# [6]	validation_0-rmse:81.21782	validation_1-rmse:79.94760
# [7]	validation_0-rmse:69.43734	validation_1-rmse:67.56089
# [8]	validation_0-rmse:60.27626	validation_1-rmse:58.53603
# [9]	validation_0-rmse:52.07334	validation_1-rmse:50.42040
# [10]	validation_0-rmse:45.56398	validation_1-rmse:44.13077
# [11]	validation_0-rmse:40.03792	validation_1-rmse:39.39978
# [12]	validation_0-rmse:35.82998	validation_1-rmse:35.97288
# [13]	validation_0-rmse:32.26194	validation_1-rmse:32.95840
# [14]	validation_0-rmse:29.35987	validation_1-rmse:30.80181
# [15]	validation_0-rmse:27.18801	validation_1-rmse:29.71939
# [16]	validation_0-rmse:25.39452	validation_1-rmse:28.93244
# [17]	validation_0-rmse:23.97229	validation_1-rmse:28.44451
# [18]	validation_0-rmse:22.86842	validation_1-rmse:28.26595
# [19]	validation_0-rmse:21.85962	validation_1-rmse:27.78622
# [20]	validation_0-rmse:20.97892	validation_1-rmse:27.80568
# [21]	validation_0-rmse:20.40148	validation_1-rmse:27.80802
# [22]	validation_0-rmse:19.85191	validation_1-rmse:27.68905
# [23]	validation_0-rmse:19.41762	validation_1-rmse:27.75617
# [24]	validation_0-rmse:19.10904	validation_1-rmse:27.61863
# [25]	validation_0-rmse:18.61190	validation_1-rmse:27.68810
# [26]	validation_0-rmse:18.30948	validation_1-rmse:27.50957
# [27]	validation_0-rmse:18.03617	validation_1-rmse:27.44753
# [28]	validation_0-rmse:17.81804	validation_1-rmse:27.36801
# [29]	validation_0-rmse:17.69428	validation_1-rmse:27.35499
# [30]	validation_0-rmse:17.43265	validation_1-rmse:27.31952
# [31]	validation_0-rmse:17.27396	validation_1-rmse:27.30406
# [32]	validation_0-rmse:16.98918	validation_1-rmse:27.18936
# [33]	validation_0-rmse:16.86748	validation_1-rmse:27.05152
# [34]	validation_0-rmse:16.72189	validation_1-rmse:26.99330
# [35]	validation_0-rmse:16.51134	validation_1-rmse:26.97776
# [36]	validation_0-rmse:16.34900	validation_1-rmse:27.03936
# [37]	validation_0-rmse:16.16341	validation_1-rmse:26.95245
# [38]	validation_0-rmse:16.04035	validation_1-rmse:26.92088
# [39]	validation_0-rmse:15.87751	validation_1-rmse:26.74435
# [40]	validation_0-rmse:15.84057	validation_1-rmse:26.71700
# [41]	validation_0-rmse:15.60701	validation_1-rmse:26.67119
# [42]	validation_0-rmse:15.43324	validation_1-rmse:26.80831
# [43]	validation_0-rmse:15.34272	validation_1-rmse:26.76340
# [44]	validation_0-rmse:15.23150	validation_1-rmse:26.71365
# [45]	validation_0-rmse:15.04584	validation_1-rmse:26.74462
# [46]	validation_0-rmse:14.91716	validation_1-rmse:26.68734
# [47]	validation_0-rmse:14.75694	validation_1-rmse:26.61305
# [48]	validation_0-rmse:14.62144	validation_1-rmse:26.58189
# [49]	validation_0-rmse:14.49118	validation_1-rmse:26.55895
# [50]	validation_0-rmse:14.27230	validation_1-rmse:26.28873
# [51]	validation_0-rmse:14.12797	validation_1-rmse:26.34416
# [52]	validation_0-rmse:14.09600	validation_1-rmse:26.33324
# [53]	validation_0-rmse:13.93583	validation_1-rmse:26.35471
# [54]	validation_0-rmse:13.90574	validation_1-rmse:26.29218
# [55]	validation_0-rmse:13.84087	validation_1-rmse:26.28551
# [56]	validation_0-rmse:13.66124	validation_1-rmse:26.13358
# [57]	validation_0-rmse:13.59713	validation_1-rmse:26.13174
# [58]	validation_0-rmse:13.48147	validation_1-rmse:26.06315
# [59]	validation_0-rmse:13.31227	validation_1-rmse:25.85008
# [60]	validation_0-rmse:13.16197	validation_1-rmse:25.75468
# [61]	validation_0-rmse:12.94690	validation_1-rmse:25.71592
# [62]	validation_0-rmse:12.76800	validation_1-rmse:25.62573
# [63]	validation_0-rmse:12.65800	validation_1-rmse:25.59381
# [64]	validation_0-rmse:12.57443	validation_1-rmse:25.54709
# [65]	validation_0-rmse:12.50018	validation_1-rmse:25.56793
# [66]	validation_0-rmse:12.39053	validation_1-rmse:25.50878
# [67]	validation_0-rmse:12.33419	validation_1-rmse:25.51810
# [68]	validation_0-rmse:12.23408	validation_1-rmse:25.51715
# [69]	validation_0-rmse:12.12554	validation_1-rmse:25.44733
# [70]	validation_0-rmse:11.99671	validation_1-rmse:25.32514
# [71]	validation_0-rmse:11.91796	validation_1-rmse:25.30270
# [72]	validation_0-rmse:11.80331	validation_1-rmse:25.17989
# [73]	validation_0-rmse:11.75615	validation_1-rmse:25.15021
# [74]	validation_0-rmse:11.64222	validation_1-rmse:25.22599
# [75]	validation_0-rmse:11.58009	validation_1-rmse:25.22436
# [76]	validation_0-rmse:11.49559	validation_1-rmse:25.27804
# [77]	validation_0-rmse:11.40775	validation_1-rmse:25.42621
# [78]	validation_0-rmse:11.30049	validation_1-rmse:25.37168
# [79]	validation_0-rmse:11.20334	validation_1-rmse:25.30800
# [80]	validation_0-rmse:11.14791	validation_1-rmse:25.33433
# [81]	validation_0-rmse:11.02047	validation_1-rmse:25.31888
# [82]	validation_0-rmse:10.93008	validation_1-rmse:25.29478
# [83]	validation_0-rmse:10.82097	validation_1-rmse:25.30817
# [84]	validation_0-rmse:10.74023	validation_1-rmse:25.31150
# [85]	validation_0-rmse:10.68835	validation_1-rmse:25.23129
# [86]	validation_0-rmse:10.59627	validation_1-rmse:25.26354
# [87]	validation_0-rmse:10.54422	validation_1-rmse:25.33961
# [88]	validation_0-rmse:10.43936	validation_1-rmse:25.26519
# [89]	validation_0-rmse:10.41770	validation_1-rmse:25.27608
# [90]	validation_0-rmse:10.32347	validation_1-rmse:25.22682
# [91]	validation_0-rmse:10.28295	validation_1-rmse:25.23096
# [92]	validation_0-rmse:10.24116	validation_1-rmse:25.21817
# [93]	validation_0-rmse:10.21082	validation_1-rmse:25.23184
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:228.09939	validation_1-rmse:218.48522
# [1]	validation_0-rmse:192.77227	validation_1-rmse:183.93343
# [2]	validation_0-rmse:161.58495	validation_1-rmse:153.52419
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:136.23531	validation_1-rmse:129.55001
# [4]	validation_0-rmse:115.03932	validation_1-rmse:109.53988
# [5]	validation_0-rmse:97.36648	validation_1-rmse:92.67153
# [6]	validation_0-rmse:82.55793	validation_1-rmse:78.87545
# [7]	validation_0-rmse:70.55145	validation_1-rmse:67.44726
# [8]	validation_0-rmse:61.06503	validation_1-rmse:58.41660

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])['GS_cub_m', 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['16%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y["GS_cub_m"])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]
print(am_a0, '+-', ci_a0)

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y**0.5)/(n_stat_y**0.5), 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y**0.5)/(n_stat_y**0.5), 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y['GS_cub_m']['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t
    print(f"{list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
print("\n")

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['BA_sq_m_ha', 'H_m', 'DBH_cm', 'Species_ID', 'Origin_ID'])
sns.set(rc={'figure.figsize':(15,9)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

# %% [markdown]
# # Creating final XGBoost model using all obs. for its training
