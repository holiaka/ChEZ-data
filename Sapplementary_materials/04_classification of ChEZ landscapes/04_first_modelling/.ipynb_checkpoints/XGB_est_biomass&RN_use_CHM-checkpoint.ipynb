# %% [markdown]
# # Processing with CHM & RN & biomass data of other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25 idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167  0.050549
# 1           3600       8.189          15100  ...   0.040919  0.048889
# 2           4360       8.380          14600  ...   0.042397  0.050463
# 3           3420       8.137          12700  ...   0.043719  0.052974
# 4           2200       7.696          12100  ...   0.040659  0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX  idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966    0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602    0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265    0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465    0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420    0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 159 columns]

# %%
"""
All parameters:
'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood',
'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
'%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 
'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 
'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 
'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 
'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 
'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 
'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 
'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 
'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 
'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 
'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 
'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 
'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 
'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 
'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 
'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 
'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'

"""
# Out:
# "\nAll parameters:\n'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood',\n'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',\n'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',\n'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',\n'%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', \n'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', \n'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', \n'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', \n'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', \n'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', \n'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', \n'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', \n'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', \n'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', \n'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', \n'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', \n'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', \n'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', \n'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', \n'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', \n'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'\n\n"

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood',
                                    'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
                                    'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 
                                    'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 
                                    'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'])
            


# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  AEDR_mean  \
# 0       6.824       9.240           1912            784       2.33
# 1       8.189       9.622           2005            818       2.47
# 2       8.380       9.589           2001            818       2.44
# 3       8.137       9.449           2040            833       2.55
# 4       7.696       9.401           1758            717       2.14
#
#    Distance_km  Azimuth  ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  \
# 0          5.2        9       4.8122           1.7630               -0.3147
# 1          5.0       10       5.7589           2.4570               -0.2485
# 2          5.1       11       5.8464           2.5153               -0.1054
# 3          5.1       11       5.7526           2.6304               -0.0834
# 4          5.1       13       5.9480           2.6748                0.0000
#
#    ...  idm_g_Q25  idm_g_Q50  idm_g_Q75  idm_b_MIN  idm_b_MAX  idm_b_MEAN  \
# 0  ...   0.042167   0.050549   0.062270   0.017730   0.408966    0.059749
# 1  ...   0.040919   0.048889   0.060698   0.020078   0.258602    0.057223
# 2  ...   0.042397   0.050463   0.060603   0.020761   0.156265    0.056571
# 3  ...   0.043719   0.052974   0.066027   0.017239   0.327465    0.060880
# 4  ...   0.040659   0.049303   0.061803   0.014276   0.274420    0.057902
#
#    idm_b_STD  idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.030217   0.043539   0.052312   0.064544
# 1   0.025515   0.043035   0.050941   0.062608
# 2   0.016629   0.045142   0.053495   0.064635
# 3   0.023964   0.046111   0.055601   0.069182
# 4   0.024283   0.043045   0.051566   0.065078
#
# [5 rows x 34 columns]

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Cs_wood            103 non-null    float64
#  1   ln_Sr_wood            103 non-null    float64
#  2   Cs_2021_kBq_m         103 non-null    int64
#  3   Sr_2021_kBq_m         103 non-null    int64
#  4   AEDR_mean             103 non-null    float64
#  5   Distance_km           103 non-null    float64
#  6   Azimuth               103 non-null    int64
#  7   ln_Gs_cub_m           103 non-null    float64
#  8   ln_M_stem_kg_m2       103 non-null    float64
#  9   ln_M_stem_bark_kg_m2  103 non-null    float64
#  10  ln_M_crown_kg_m2      103 non-null    float64
#  11  ln_M_foliage_kg_m2    103 non-null    float64
#  12  ln_M_AG_kg_m2         103 non-null    float64
#  13  idm_r_MIN             103 non-null    float64
#  14  idm_r_MAX             103 non-null    float64
#  15  idm_r_MEAN            103 non-null    float64
#  16  idm_r_STD             103 non-null    float64
#  17  idm_r_Q25             103 non-null    float64
#  18  idm_r_Q50             103 non-null    float64
#  19  idm_r_Q75             103 non-null    float64
#  20  idm_g_MIN             103 non-null    float64
#  21  idm_g_MAX             103 non-null    float64
#  22  idm_g_MEAN            103 non-null    float64
#  23  idm_g_STD             103 non-null    float64
#  24  idm_g_Q25             103 non-null    float64
#  25  idm_g_Q50             103 non-null    float64
#  26  idm_g_Q75             103 non-null    float64
#  27  idm_b_MIN             103 non-null    float64
#  28  idm_b_MAX             103 non-null    float64
#  29  idm_b_MEAN            103 non-null    float64
#  30  idm_b_STD             103 non-null    float64
#  31  idm_b_Q25             103 non-null    float64
#  32  idm_b_Q50             103 non-null    float64
#  33  idm_b_Q75             103 non-null    float64
# dtypes: float64(31), int64(3)
# memory usage: 27.5 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["Cs_wood_Bq/kg","Sr_wood_Bq/kg"].describe()
# Out:
# /tmp/ipykernel_12486/359812478.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_specias"])["Cs_wood_Bq/kg","Sr_wood_Bq/kg"].describe()
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   AEDR_mean  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3014.359223    1136.436893    3.570291
# std       1.64946    1.472424    4988.505540    2019.773384    6.089170
# min       3.52600    6.075000     423.000000      98.000000    0.480000
# 25%       6.31900    7.664000     635.500000     199.500000    0.710000
# 50%       6.95700    8.472000    1145.000000     362.000000    1.290000
# 75%       7.91350    9.421000    2423.500000     966.000000    2.960000
# max      11.36700   13.864000   25173.000000   10477.000000   36.590000
#
#        Distance_km     Azimuth  ln_Gs_cub_m  ln_M_stem_kg_m2  \
# count   103.000000  103.000000   103.000000       103.000000
# mean      7.029126  114.572816     4.969534         1.827923
# std       2.201365   99.077371     1.323782         1.325853
# min       4.000000    9.000000     0.693100        -2.995700
# 25%       4.950000   40.000000     4.672800         1.588100
# 50%       6.900000   56.000000     5.337500         2.286500
# 75%       8.950000  245.000000     5.908100         2.730800
# max      11.800000  268.000000     6.508800         3.220500
#
#        ln_M_stem_bark_kg_m2  ...   idm_g_Q25   idm_g_Q50   idm_g_Q75  \
# count            103.000000  ...  103.000000  103.000000  103.000000
# mean              -0.239481  ...    0.043780    0.053322    0.068210
# std                0.893398  ...    0.009554    0.011977    0.016121
# min               -3.912000  ...    0.032426    0.038965    0.048217
# 25%               -0.335500  ...    0.038160    0.045851    0.057399
# 50%               -0.040800  ...    0.041431    0.050218    0.062863
# 75%                0.190600  ...    0.044375    0.055068    0.074153
# max                1.654400  ...    0.084755    0.100882    0.123452
#
#         idm_b_MIN   idm_b_MAX  idm_b_MEAN   idm_b_STD   idm_b_Q25   idm_b_Q50  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     0.018715    0.369862    0.063183    0.031414    0.045112    0.054775
# std      0.004613    0.167070    0.013391    0.014380    0.009520    0.011976
# min      0.010157    0.119180    0.044884    0.011541    0.032628    0.038965
# 25%      0.015803    0.235651    0.054792    0.019469    0.039603    0.047617
# 50%      0.017749    0.329936    0.059749    0.029068    0.042930    0.051569
# 75%      0.020328    0.487015    0.068365    0.037530    0.046268    0.056588
# max      0.041025    0.770000    0.107732    0.075240    0.087202    0.104570
#
#         idm_b_Q75
# count  103.000000
# mean     0.070020
# std      0.016240
# min      0.048217
# 25%      0.058939
# 50%      0.065442
# 75%      0.075429
# max      0.124853
#
# [8 rows x 34 columns]

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 
                                    'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 
                                    'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'])
y = pd.DataFrame(select, columns= ['ln_Gs_cub_m'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): Yes
# Selected "Yes"!!! A new column with random values was created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    idm_r_MIN  idm_r_MAX  idm_r_MEAN  idm_r_STD  idm_r_Q25  idm_r_Q50  \
# 0   0.018896   0.384033    0.057680   0.029676   0.041920   0.050301
# 1   0.020510   0.262630    0.056071   0.025267   0.042133   0.049856
# 2   0.021948   0.146006    0.054125   0.015072   0.043877   0.051675
# 3   0.019093   0.366594    0.059043   0.022897   0.044932   0.054252
# 4   0.016348   0.295941    0.056370   0.023413   0.042199   0.050681
#
#    idm_r_Q75  idm_g_MIN  idm_g_MAX  idm_g_MEAN  ...  idm_b_MEAN  idm_b_STD  \
# 0   0.062238   0.013972   0.376060    0.057730  ...    0.059749   0.030217
# 1   0.061412   0.018636   0.289322    0.055371  ...    0.057223   0.025515
# 2   0.061436   0.021988   0.170117    0.053174  ...    0.056571   0.016629
# 3   0.067136   0.015969   0.348899    0.058043  ...    0.060880   0.023964
# 4   0.063448   0.017970   0.280073    0.054908  ...    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75    Random1    Random2    Random3  \
# 0   0.043539   0.052312   0.064544   7.433154   8.106495   9.005465
# 1   0.043035   0.050941   0.062608   6.460334  10.002458  11.944014
# 2   0.045142   0.053495   0.064635  12.091343  10.659527  10.278194
# 3   0.046111   0.055601   0.069182  10.249354   8.749879  10.466922
# 4   0.043045   0.051566   0.065078   7.121866  12.492243   7.140527
#
#      Random4    Random5
# 0  10.828506   7.862679
# 1   8.507489   7.894057
# 2   8.628037   9.551116
# 3  10.694675  13.505499
# 4   9.007039  11.389677
#
# [5 rows x 26 columns]

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Gs_cub_m
# 0       4.8122
# 1       5.7589
# 2       5.8464
# 3       5.7526
# 4       5.9480

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.27276667772719754, 0.04048549294294446, -0.4522828320918646]
#     Mean: -0.046
#     Std: 0.302
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.38001775 1.35464591 1.29441074]
#     Mean: 1.343
#     Std: 0.036
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.7643009249005999, 1.1758542451073142, 0.9990567770845749]
#     Mean: 0.980
#     Std: 0.169
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=5, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Model with rank: 1
# Mean validation score: 0.090 (std: 0.120)
# Parameters: {'colsample_bytree': 0.625633801772045, 'gamma': 0.21719745167513232, 'learning_rate': 0.10146836569318562, 'max_depth': 4, 'n_estimators': 131, 'subsample': 0.777681985030638}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.5651825 , 0.23523493, 0.56331077, 0.52666335, 0.81754084]), 'std_fit_time': array([0.11480166, 0.05135901, 0.04023259, 0.16967769, 0.80908849]), 'mean_score_time': array([0.00872726, 0.00736842, 0.00806446, 0.01146092, 0.01102757]), 'std_score_time': array([0.00333667, 0.00042779, 0.0016966 , 0.00612491, 0.00467082]), 'param_colsample_bytree': masked_array(data=[0.16749114620958197, 0.12468503357043681,
#                    0.27144240917541035, 0.625633801772045,
#                    0.18302588838547856],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.45050358078615554, 0.0347103565532359,
#                    0.13983795528913534, 0.21719745167513232,
#                    0.3797087154711596],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.1795032130914453, 0.2975056499011234,
#                    0.10275236430011819, 0.10146836569318562,
#                    0.23630155870889155],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[2, 3, 2, 4, 4],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[112, 66, 189, 131, 69],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.6143435376266551, 0.5407538244407728,
#                    0.598768431349411, 0.777681985030638,
#                    0.8402018392922019],
#              mask=[False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.16749114620958197, 'gamma': 0.45050358078615554, 'learning_rate': 0.1795032130914453, 'max_depth': 2, 'n_estimators': 112, 'subsample': 0.6143435376266551}, {'colsample_bytree': 0.12468503357043681, 'gamma': 0.0347103565532359, 'learning_rate': 0.2975056499011234, 'max_depth': 3, 'n_estimators': 66, 'subsample': 0.5407538244407728}, {'colsample_bytree': 0.27144240917541035, 'gamma': 0.13983795528913534, 'learning_rate': 0.10275236430011819, 'max_depth': 2, 'n_estimators': 189, 'subsample': 0.598768431349411}, {'colsample_bytree': 0.625633801772045, 'gamma': 0.21719745167513232, 'learning_rate': 0.10146836569318562, 'max_depth': 4, 'n_estimators': 131, 'subsample': 0.777681985030638}, {'colsample_bytree': 0.18302588838547856, 'gamma': 0.3797087154711596, 'learning_rate': 0.23630155870889155, 'max_depth': 4, 'n_estimators': 69, 'subsample': 0.8402018392922019}], 'split0_test_score': array([-0.42105612, -1.02689706, -0.40109842, -0.10852952, -0.77015053]), 'split1_test_score': array([ 0.14625166,  0.3305586 ,  0.108941  ,  0.10608552, -0.09344284]), 'split2_test_score': array([0.12083722, 0.16372612, 0.10050419, 0.05684986, 0.09335321]), 'split3_test_score': array([ 0.15352759, -0.03144488,  0.03453058,  0.1367067 ,  0.2736166 ]), 'split4_test_score': array([ 0.38065653, -0.06243422,  0.42115167,  0.26068383,  0.0804869 ]), 'mean_test_score': array([ 0.07604338, -0.12529829,  0.05280581,  0.09035928, -0.08322733]), 'std_test_score': array([0.26564509, 0.47264814, 0.26361639, 0.12007122, 0.36257095]), 'rank_test_score': array([2, 5, 3, 1, 4], dtype=int32), 'split0_train_score': array([0.95809077, 0.99208068, 0.98186624, 0.98302435, 0.97180598]), 'split1_train_score': array([0.94566557, 0.99127031, 0.97832517, 0.9809003 , 0.96475791]), 'split2_train_score': array([0.9491476 , 0.99160445, 0.97830904, 0.98187886, 0.96665792]), 'split3_train_score': array([0.95091863, 0.99295071, 0.97686291, 0.98197667, 0.96859712]), 'split4_train_score': array([0.95415888, 0.99272154, 0.97865718, 0.9809543 , 0.96740141]), 'mean_train_score': array([0.95159629, 0.99212554, 0.97880411, 0.9817469 , 0.96784407]), 'std_train_score': array([0.00425144, 0.00063892, 0.00165172, 0.00078064, 0.00234056])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.625633801772045
# Gamma: 0.21719745167513232
# Learning_rate: 0.10146836569318562
# Max_depth: 4
# N_estimators: 131
# Subsample: 0.777681985030638

# %% [markdown]
# # Creating a basic XGBoost model

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Generate test and training samples
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# Implementation of the scikit-learn API for XGBoost regression
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Show all parameters of XGBoost model
print(xgb_model)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.625633801772045, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=['rmse'],
#              gamma=0.21719745167513232, gpu_id=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.10146836569318562, max_bin=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, n_estimators=131, n_jobs=None,
#              num_parallel_tree=None, predictor=None, random_state=None,
#              reg_alpha=None, reg_lambda=None, ...)

# %%
# Fitting the model 
xgb_model.fit(X_train, y_train, early_stopping_rounds=100, eval_set=[(X_train, y_train), (X_test, y_test)])
# learning dynamics
y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:4.35087	validation_1-rmse:3.85864
# [1]	validation_0-rmse:3.94289	validation_1-rmse:3.49188
# [2]	validation_0-rmse:3.57450	validation_1-rmse:3.18903
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:3.24368	validation_1-rmse:2.91703
# [4]	validation_0-rmse:2.94718	validation_1-rmse:2.68704
# [5]	validation_0-rmse:2.66728	validation_1-rmse:2.45179
# [6]	validation_0-rmse:2.44136	validation_1-rmse:2.29719
# [7]	validation_0-rmse:2.23665	validation_1-rmse:2.15285
# [8]	validation_0-rmse:2.03370	validation_1-rmse:2.02513
# [9]	validation_0-rmse:1.85856	validation_1-rmse:1.93351
# [10]	validation_0-rmse:1.70188	validation_1-rmse:1.84305
# [11]	validation_0-rmse:1.55792	validation_1-rmse:1.79433
# [12]	validation_0-rmse:1.42888	validation_1-rmse:1.74192
# [13]	validation_0-rmse:1.31239	validation_1-rmse:1.72148
# [14]	validation_0-rmse:1.20624	validation_1-rmse:1.68926
# [15]	validation_0-rmse:1.12473	validation_1-rmse:1.68177
# [16]	validation_0-rmse:1.02724	validation_1-rmse:1.65670
# [17]	validation_0-rmse:0.94914	validation_1-rmse:1.63388
# [18]	validation_0-rmse:0.88095	validation_1-rmse:1.62084
# [19]	validation_0-rmse:0.81513	validation_1-rmse:1.61298
# [20]	validation_0-rmse:0.76609	validation_1-rmse:1.60983
# [21]	validation_0-rmse:0.71246	validation_1-rmse:1.62136
# [22]	validation_0-rmse:0.65701	validation_1-rmse:1.62768
# [23]	validation_0-rmse:0.61290	validation_1-rmse:1.63439
# [24]	validation_0-rmse:0.58324	validation_1-rmse:1.63788
# [25]	validation_0-rmse:0.54154	validation_1-rmse:1.63892
# [26]	validation_0-rmse:0.51205	validation_1-rmse:1.64619
# [27]	validation_0-rmse:0.48768	validation_1-rmse:1.66401
# [28]	validation_0-rmse:0.46274	validation_1-rmse:1.67484
# [29]	validation_0-rmse:0.43596	validation_1-rmse:1.67135
# [30]	validation_0-rmse:0.41832	validation_1-rmse:1.67743
# [31]	validation_0-rmse:0.39981	validation_1-rmse:1.68837
# [32]	validation_0-rmse:0.38450	validation_1-rmse:1.69255
# [33]	validation_0-rmse:0.36097	validation_1-rmse:1.68815
# [34]	validation_0-rmse:0.34069	validation_1-rmse:1.69909
# [35]	validation_0-rmse:0.32722	validation_1-rmse:1.69876
# [36]	validation_0-rmse:0.31332	validation_1-rmse:1.70706
# [37]	validation_0-rmse:0.30238	validation_1-rmse:1.71732
# [38]	validation_0-rmse:0.29099	validation_1-rmse:1.72000
# [39]	validation_0-rmse:0.28196	validation_1-rmse:1.71983
# [40]	validation_0-rmse:0.27162	validation_1-rmse:1.72459
# [41]	validation_0-rmse:0.26526	validation_1-rmse:1.72886
# [42]	validation_0-rmse:0.25619	validation_1-rmse:1.72775
# [43]	validation_0-rmse:0.24978	validation_1-rmse:1.72711
# [44]	validation_0-rmse:0.24138	validation_1-rmse:1.73499
# [45]	validation_0-rmse:0.23467	validation_1-rmse:1.74238
# [46]	validation_0-rmse:0.22954	validation_1-rmse:1.74028
# [47]	validation_0-rmse:0.22718	validation_1-rmse:1.74296
# [48]	validation_0-rmse:0.22578	validation_1-rmse:1.74438
# [49]	validation_0-rmse:0.22287	validation_1-rmse:1.74060
# [50]	validation_0-rmse:0.22100	validation_1-rmse:1.73948
# [51]	validation_0-rmse:0.21794	validation_1-rmse:1.74309
# [52]	validation_0-rmse:0.21528	validation_1-rmse:1.74425
# [53]	validation_0-rmse:0.21037	validation_1-rmse:1.74359
# [54]	validation_0-rmse:0.21020	validation_1-rmse:1.74430
# [55]	validation_0-rmse:0.21002	validation_1-rmse:1.74508
# [56]	validation_0-rmse:0.20977	validation_1-rmse:1.74638
# [57]	validation_0-rmse:0.20614	validation_1-rmse:1.74348
# [58]	validation_0-rmse:0.20603	validation_1-rmse:1.74407
# [59]	validation_0-rmse:0.20599	validation_1-rmse:1.74435
# [60]	validation_0-rmse:0.20588	validation_1-rmse:1.74502
# [61]	validation_0-rmse:0.20146	validation_1-rmse:1.75194
# [62]	validation_0-rmse:0.19669	validation_1-rmse:1.75289
# [63]	validation_0-rmse:0.19338	validation_1-rmse:1.75299
# [64]	validation_0-rmse:0.18932	validation_1-rmse:1.75687
# [65]	validation_0-rmse:0.18933	validation_1-rmse:1.75680
# [66]	validation_0-rmse:0.18932	validation_1-rmse:1.75685
# [67]	validation_0-rmse:0.18929	validation_1-rmse:1.75722
# [68]	validation_0-rmse:0.18929	validation_1-rmse:1.75719
# [69]	validation_0-rmse:0.18934	validation_1-rmse:1.75661
# [70]	validation_0-rmse:0.18508	validation_1-rmse:1.75674
# [71]	validation_0-rmse:0.18507	validation_1-rmse:1.75688
# [72]	validation_0-rmse:0.18310	validation_1-rmse:1.75886
# [73]	validation_0-rmse:0.18296	validation_1-rmse:1.76062
# [74]	validation_0-rmse:0.18293	validation_1-rmse:1.76154
# [75]	validation_0-rmse:0.18293	validation_1-rmse:1.76176
# [76]	validation_0-rmse:0.18293	validation_1-rmse:1.76162
# [77]	validation_0-rmse:0.18293	validation_1-rmse:1.76227
# [78]	validation_0-rmse:0.18293	validation_1-rmse:1.76249
# [79]	validation_0-rmse:0.18292	validation_1-rmse:1.76203
# [80]	validation_0-rmse:0.18068	validation_1-rmse:1.76099
# [81]	validation_0-rmse:0.17794	validation_1-rmse:1.76036
# [82]	validation_0-rmse:0.17793	validation_1-rmse:1.76081
# [83]	validation_0-rmse:0.17794	validation_1-rmse:1.76021
# [84]	validation_0-rmse:0.17795	validation_1-rmse:1.76017
# [85]	validation_0-rmse:0.17797	validation_1-rmse:1.75956
# [86]	validation_0-rmse:0.17797	validation_1-rmse:1.75968
# [87]	validation_0-rmse:0.17797	validation_1-rmse:1.75959
# [88]	validation_0-rmse:0.17469	validation_1-rmse:1.76282
# [89]	validation_0-rmse:0.17402	validation_1-rmse:1.76679
# [90]	validation_0-rmse:0.17399	validation_1-rmse:1.76788
# [91]	validation_0-rmse:0.17399	validation_1-rmse:1.76775
# [92]	validation_0-rmse:0.17399	validation_1-rmse:1.76863
# [93]	validation_0-rmse:0.17399	validation_1-rmse:1.76812
# [94]	validation_0-rmse:0.17400	validation_1-rmse:1.76907
# [95]	validation_0-rmse:0.17400	validation_1-rmse:1.76895
# [96]	validation_0-rmse:0.17401	validation_1-rmse:1.76938
# [97]	validation_0-rmse:0.17400	validation_1-rmse:1.76920
# [98]	validation_0-rmse:0.17403	validation_1-rmse:1.76989
# [99]	validation_0-rmse:0.17404	validation_1-rmse:1.77003
# [100]	validation_0-rmse:0.17402	validation_1-rmse:1.76956
# [101]	validation_0-rmse:0.17402	validation_1-rmse:1.76962
# [102]	validation_0-rmse:0.17399	validation_1-rmse:1.76886
# [103]	validation_0-rmse:0.17399	validation_1-rmse:1.76874
# [104]	validation_0-rmse:0.17399	validation_1-rmse:1.76828
# [105]	validation_0-rmse:0.17399	validation_1-rmse:1.76784
# [106]	validation_0-rmse:0.17400	validation_1-rmse:1.76736
# [107]	validation_0-rmse:0.17399	validation_1-rmse:1.76825
# [108]	validation_0-rmse:0.17399	validation_1-rmse:1.76842
# [109]	validation_0-rmse:0.17400	validation_1-rmse:1.76896
# [110]	validation_0-rmse:0.17399	validation_1-rmse:1.76892
# [111]	validation_0-rmse:0.17400	validation_1-rmse:1.76907
# [112]	validation_0-rmse:0.17401	validation_1-rmse:1.76936
# [113]	validation_0-rmse:0.17401	validation_1-rmse:1.76933
# [114]	validation_0-rmse:0.17401	validation_1-rmse:1.76945
# [115]	validation_0-rmse:0.17400	validation_1-rmse:1.76920
# [116]	validation_0-rmse:0.17401	validation_1-rmse:1.76935
# [117]	validation_0-rmse:0.17401	validation_1-rmse:1.76950
# [118]	validation_0-rmse:0.17401	validation_1-rmse:1.76934
# [119]	validation_0-rmse:0.17400	validation_1-rmse:1.76896
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
optimal_n= xgb_model.best_ntree_limit-1
print("The best iteration: " + str(optimal_n))
# Out:
# The best iteration: 20

# %%
# Preparing data for building a learning graph
results = xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(results['validation_0']['rmse'], label='Train')
plt.plot(results['validation_1']['rmse'], label='Test')
plt.axvline(optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a basic XGBoost model

# %%
# Convert data to 'array' type
conv_y_pred = pd.DataFrame(y_pred) # Double transformation
y_pred2 = conv_y_pred.values
y_test2 = y_test.values

# Intermediate results
n_sample = len(y_pred2)
main_sample = y_test.sum() / n_sample

# Calculation of bias
diff = y_pred2 - y_test2
bias = diff.sum()
print('Bias: %.1f' % (bias/n_sample))
print("Relative bias(%):", " %.2f" % (bias/main_sample))

# Calculation of RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %.1f" % (rmse))
print("Relative RMSE(%):", " %.3f" % (rmse/main_sample))

# Calculation of MSE
mse = mean_squared_error(y_test, y_pred)
print("MSE: %.1f" % (mse))

# Calculation of Square R
R_square = r2_score(y_test, y_pred)
print("R square: %.1f%%" % (R_square * 100.0))
# Out:
# Bias: 0.1
# Relative bias(%):  0.39
# RMSE: 1.6
# Relative RMSE(%):  0.359
# MSE: 2.6
# R square: 0.4%

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(y_test)
x_test_convert = np.array([None]*n_sample)
for i in range(n_sample):
    x_test_convert[i] = np.float(x_test_conv[i])

x_plot = x_test_convert
y_plot = y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)
# Out:
# `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 4.313
# a1: 0.051
# R^2: 0.027
# Uncertainty
# a0: 4.31+/-0.27
# a1: 0.05+/-0.06

# %%
# Comparison of training and testing prediction values for XGBoost model 
y_pred_train = xgb_model.predict(X_train, ntree_limit=xgb_model.best_ntree_limit)

plt.figure(figsize =(8, 5))
plt.scatter(y_train, y_pred_train, alpha=0.5, label='Training data')
plt.scatter(y_test, y_pred, s = 5, c = "red", label='Validation (test) data')
plt.xlabel('Obs.')
plt.ylabel('Predict')
plt.legend(loc='best')
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(xgb_model,num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, X_train, color=shap_values)

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)

# %%
# Iteration with the best result
f_optimal_n = xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(0.001, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/.json")
# Save to text format
xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/.txt")
