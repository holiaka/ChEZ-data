# %% [markdown]
# # *+Processing with Sentinel bands & RN & biomass data of other authors+*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
input_data = '/home/dima/Desktop/WORK/GIS and ML algoritms/6_Est_RN&biomass_all_site_Sentinel/Pre_GIS_data/Site_with_Sentinel_bands_data_2019.csv'
df = pd.read_csv(input_data)
df.head()
# Out:
#   Site # Origin Dominant_s  N_trees at  A_year  D_live_cm  H_live_m  \
# 0      1      n      Birch          57      35       13.5      17.3
# 1      2      a       Pine          25      58       15.0      16.9
# 2      3      a       Pine          32      58       13.7      16.8
# 3      4      a       Pine          63      58       20.3      18.4
# 4      5      a       Pine          53      58       17.5      19.9
#
#    G_live_m2_  f_Gs_cub_m  f_M_stem_kg_m2  ...  r2019B03  r2019B04  r2019B05  \
# 0        15.1         123            5.83  ...  0.030628  0.266210  0.166299
# 1        39.0         317           11.67  ...  0.027934  0.183349  0.102656
# 2        42.8         346           12.37  ...  0.026123  0.184066  0.099625
# 3        38.8         315           13.88  ...  0.027390  0.177221  0.102540
# 4        48.3         383           14.51  ...  0.025702  0.183705  0.101394
#
#    r2019B06  r2019B07  r2019B08  r2019B09   r2019B10   r2019B11  r2019B12
# 0  0.081316  0.793351 -0.733693  0.532051 -15.396488 -11.262037  0.731937
# 1  0.052144  0.735493 -0.655456  0.557000 -16.012156  -9.364664  0.584920
# 2  0.050684  0.751436 -0.650575  0.568148 -13.609903  -9.726108  0.715177
# 3  0.052198  0.732404 -0.648310  0.544717 -14.321650 -10.457536  0.730390
# 4  0.050437  0.754481 -0.660382  0.569112 -13.934375 -11.393335  0.817430
#
# [5 rows x 63 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
#
# 'Site #', 'Origin', 'Dominant_s', 'N_trees at', 'A_year', 'D_live_cm', 'H_live_m', 'G_live_m2_', 'f_Gs_cub_m', 'f_M_stem_kg_m2', 'f_M_stem_bark_kg_m2', 'f_M_crown_kg_m2', 'f_M_foliage_kg_m2', 'f_M_AG_kg_m2', 'Ln_Gs_cub_m', 'Ln_M_stem_kg_m2', 'Ln_M_stem_bark_kg_m2', 'Ln_M_crown_kg_m2', 'Ln_M_foliage_kg_m2', 'Ln_M_AG_kg_m2', 'F_Soil', 'M_Soil', 'X_N36', 'Y_N36', 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'Ln_Cs_wood', 'Ln_Sr_wood', 'Tag_Cs', 'Tag_Sr', 'Ln_Tag_Cs', 'Ln_Tag_Sr', 'Cs_2021_kB', 'Sr_2021_kB', 'AEDR_count', 'AEDR_mean', 'Distance_k', 'Azimuth', 'r2020B01', 'r2020B02', 'r2020B03', 'r2020B04', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11', 'r2020B12', 'r2020B13', 'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Ln_Gs_cub_m', 'Ln_M_stem_kg_m2', 'Ln_M_stem_bark_kg_m2', 'Ln_M_crown_kg_m2', 'Ln_M_foliage_kg_m2', 'Ln_M_AG_kg_m2', 'Ln_Cs_wood', 'Ln_Sr_wood', 'Ln_Tag_Cs', 'Ln_Tag_Sr', 'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'])
            


# Show the first five columns
select.head()
# Out:
#    Ln_Gs_cub_m  Ln_M_stem_kg_m2  Ln_M_stem_bark_kg_m2  Ln_M_crown_kg_m2  \
# 0         4.81             1.76                 -0.31             -0.16
# 1         5.76             2.46                 -0.25              0.34
# 2         5.85             2.52                 -0.11              0.55
# 3         5.75             2.63                 -0.08              0.39
# 4         5.95             2.67                  0.00              0.57
#
#    Ln_M_foliage_kg_m2  Ln_M_AG_kg_m2  Ln_Cs_wood  Ln_Sr_wood  Ln_Tag_Cs  \
# 0               -2.44           1.91         6.8         9.2       -0.7
# 1               -0.20           2.63         8.2         9.6        0.6
# 2               -0.21           2.70         8.4         9.6        0.8
# 3               -0.35           2.78         8.1         9.4        0.5
# 4               -0.37           2.83         7.7         9.4        0.2
#
#    Ln_Tag_Sr  ...  r2019B03  r2019B04  r2019B05  r2019B06  r2019B07  r2019B08  \
# 0        2.6  ...  0.030628  0.266210  0.166299  0.081316  0.793351 -0.733693
# 1        2.9  ...  0.027934  0.183349  0.102656  0.052144  0.735493 -0.655456
# 2        2.9  ...  0.026123  0.184066  0.099625  0.050684  0.751436 -0.650575
# 3        2.7  ...  0.027390  0.177221  0.102540  0.052198  0.732404 -0.648310
# 4        2.8  ...  0.025702  0.183705  0.101394  0.050437  0.754481 -0.660382
#
#    r2019B09   r2019B10   r2019B11  r2019B12
# 0  0.532051 -15.396488 -11.262037  0.731937
# 1  0.557000 -16.012156  -9.364664  0.584920
# 2  0.568148 -13.609903  -9.726108  0.715177
# 3  0.544717 -14.321650 -10.457536  0.730390
# 4  0.569112 -13.934375 -11.393335  0.817430
#
# [5 rows x 22 columns]

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ln_Gs_cub_m           205 non-null    float64
#  1   Ln_M_stem_kg_m2       205 non-null    float64
#  2   Ln_M_stem_bark_kg_m2  205 non-null    float64
#  3   Ln_M_crown_kg_m2      205 non-null    float64
#  4   Ln_M_foliage_kg_m2    205 non-null    float64
#  5   Ln_M_AG_kg_m2         205 non-null    float64
#  6   Ln_Cs_wood            205 non-null    float64
#  7   Ln_Sr_wood            205 non-null    float64
#  8   Ln_Tag_Cs             205 non-null    float64
#  9   Ln_Tag_Sr             205 non-null    float64
#  10  r2019B01              205 non-null    float64
#  11  r2019B02              205 non-null    float64
#  12  r2019B03              205 non-null    float64
#  13  r2019B04              205 non-null    float64
#  14  r2019B05              205 non-null    float64
#  15  r2019B06              205 non-null    float64
#  16  r2019B07              205 non-null    float64
#  17  r2019B08              205 non-null    float64
#  18  r2019B09              205 non-null    float64
#  19  r2019B10              205 non-null    float64
#  20  r2019B11              205 non-null    float64
#  21  r2019B12              205 non-null    float64
# dtypes: float64(22)
# memory usage: 35.4 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_s"])["f_Gs_cub_m", "f_M_stem_kg_m2"].describe()
# Out:
# /tmp/ipykernel_15593/4147815954.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_s"])["f_Gs_cub_m", "f_M_stem_kg_m2"].describe()
#            f_Gs_cub_m                                                      \
#                 count        mean         std    min    25%    50%    75%
# Dominant_s
# Alder            13.0  393.153846  113.795757  199.0  311.0  434.0  462.0
# Aspen             7.0  241.571429  134.878782  121.0  147.0  194.0  321.0
# Birch            45.0  164.622222   83.668254   11.0  107.0  157.0  222.0
# Oak               9.0  199.777778   88.192655   79.0  112.0  220.0  255.0
# Pine            130.0  299.023077  185.204955    2.0  144.0  316.0  451.0
# Spruce            1.0  619.000000         NaN  619.0  619.0  619.0  619.0
#
#                   f_M_stem_kg_m2                                             \
#               max          count       mean       std    min     25%    50%
# Dominant_s
# Alder       558.0           13.0  16.823846  4.334304   9.90  13.560  16.96
# Aspen       440.0            7.0  11.862857  7.997334   4.64   6.470   9.79
# Birch       346.0           45.0   8.030444  4.090891   0.84   4.960   7.75
# Oak         313.0            9.0  10.728889  4.976167   3.59   5.870  11.72
# Pine        671.0          130.0  11.784154  7.069419   0.05   5.915  11.96
# Spruce      619.0            1.0  23.830000       NaN  23.83  23.830  23.83
#
#
#                75%    max
# Dominant_s
# Alder       20.130  24.29
# Aspen       14.810  26.05
# Birch       10.990  17.00
# Oak         13.590  18.99
# Pine        17.305  25.37
# Spruce      23.830  23.83

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Ln_Gs_cub_m  Ln_M_stem_kg_m2  Ln_M_stem_bark_kg_m2  Ln_M_crown_kg_m2  \
# count   205.000000       205.000000            205.000000        205.000000
# mean      5.224390         2.071854             -0.042439          0.168537
# std       1.125422         1.119577              0.780389          0.583474
# min       0.690000        -3.000000             -3.910000         -1.560000
# 25%       4.930000         1.770000             -0.190000         -0.030000
# 50%       5.510000         2.410000              0.060000          0.310000
# 75%       5.980000         2.800000              0.370000          0.530000
# max       6.510000         3.260000              1.650000          1.410000
#
#        Ln_M_foliage_kg_m2  Ln_M_AG_kg_m2  Ln_Cs_wood  Ln_Sr_wood   Ln_Tag_Cs  \
# count          205.000000     205.000000  205.000000  205.000000  205.000000
# mean            -0.941463       2.297463    5.995610    7.382927   -0.620000
# std              0.714443       0.926225    2.084309    2.041062    1.275808
# min             -2.920000      -0.800000    1.600000    2.400000   -4.700000
# 25%             -1.510000       2.050000    4.100000    5.800000   -1.400000
# 50%             -0.680000       2.570000    6.300000    7.500000   -0.500000
# 75%             -0.360000       2.930000    7.300000    8.700000    0.300000
# max              0.110000       3.390000   11.400000   13.900000    1.700000
#
#         Ln_Tag_Sr  ...    r2019B03    r2019B04    r2019B05    r2019B06  \
# count  205.000000  ...  205.000000  205.000000  205.000000  205.000000
# mean     2.310732  ...    0.028895    0.219361    0.131344    0.068068
# std      0.951460  ...    0.010704    0.049137    0.036023    0.026479
# min     -0.300000  ...    0.015301    0.140309    0.078918    0.035914
# 25%      1.700000  ...    0.022685    0.183403    0.102471    0.051182
# 50%      2.400000  ...    0.026123    0.199665    0.121704    0.060839
# 75%      3.000000  ...    0.030628    0.250913    0.153232    0.078586
# max      4.700000  ...    0.081675    0.423326    0.252487    0.196544
#
#          r2019B07    r2019B08    r2019B09    r2019B10    r2019B11    r2019B12
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.759654   -0.692408    0.526662  -15.737088  -10.490763    0.668847
# std      0.091469    0.070703    0.144729    1.547144    1.471517    0.081010
# min      0.363395   -0.849155   -0.037478  -22.820204  -16.820473    0.386847
# 25%      0.727961   -0.735660    0.470852  -16.494671  -11.364958    0.615553
# 50%      0.771691   -0.693779    0.562326  -15.454248  -10.299303    0.666882
# 75%      0.814177   -0.660039    0.626609  -14.760403   -9.547850    0.728737
# max      0.914709   -0.389420    0.740912  -12.365163   -5.703308    0.877743
#
# [8 rows x 22 columns]

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['r2019B01', 'r2019B04', 'r2019B08', 'r2019B10', 'r2019B11'])
y = pd.DataFrame(select, columns= ['Ln_Tag_Cs'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    r2019B01  r2019B04  r2019B08   r2019B10   r2019B11
# 0  0.025483  0.266210 -0.733693 -15.396488 -11.262037
# 1  0.024075  0.183349 -0.655456 -16.012156  -9.364664
# 2  0.022492  0.184066 -0.650575 -13.609903  -9.726108
# 3  0.023742  0.177221 -0.648310 -14.321650 -10.457536
# 4  0.022916  0.183705 -0.660382 -13.934375 -11.393335

# %%
# Columns in "y" data collections
y.head()
# Out:
#    Ln_Tag_Cs
# 0       -0.7
# 1        0.6
# 2        0.8
# 3        0.5
# 4        0.2

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.22455126444562368, 0.13555009838601217, 0.044778000811066754]
#     Mean: 0.135
#     Std: 0.073
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.11511986 1.43597815 1.30486191]
#     Mean: 1.285
#     Std: 0.132
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.8703057573568346, 0.8381593611036591, 0.9698404601220425]
#     Mean: 0.893
#     Std: 0.056
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.180 (std: 0.171)
# Parameters: {'colsample_bytree': 0.8478701266030472, 'gamma': 0.26026245736585507, 'learning_rate': 0.0914008527255964, 'max_depth': 2, 'n_estimators': 52, 'subsample': 0.6047757242309929}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.20507336, 0.4376997 , 0.37335443, ..., 0.16190457, 0.09399314,
#        0.17994232]), 'std_fit_time': array([0.01942816, 0.13400684, 0.11836849, ..., 0.0056998 , 0.00518494,
#        0.00694134]), 'mean_score_time': array([0.00507755, 0.00476937, 0.00469475, ..., 0.0044148 , 0.00436654,
#        0.00435858]), 'std_score_time': array([1.02318342e-03, 1.37769585e-04, 7.18296897e-05, ...,
#        1.89890842e-04, 1.08656489e-04, 7.61838058e-05]), 'param_colsample_bytree': masked_array(data=[0.2562313142675038, 0.8040403271414246,
#                    0.2854919890837761, ..., 0.2348558370224833,
#                    0.17588714307378522, 0.12784890019529394],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.08743198626823873, 0.1543025439290997,
#                    0.07016059983711814, ..., 0.04820076224316394,
#                    0.4665250635872873, 0.060357167460410865],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.21527545553768032, 0.17253731562992064,
#                    0.23800134011606186, ..., 0.12036458546404999,
#                    0.25659249054776256, 0.13111385965478561],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[4, 2, 3, ..., 2, 3, 2],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[110, 199, 166, ..., 95, 51, 108],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.7669284289467966, 0.6713741026981177,
#                    0.8173998988252962, ..., 0.6106050522189126,
#                    0.9363640024543605, 0.586316667493773],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.2562313142675038, 'gamma': 0.08743198626823873, 'learning_rate': 0.21527545553768032, 'max_depth': 4, 'n_estimators': 110, 'subsample': 0.7669284289467966}, {'colsample_bytree': 0.8040403271414246, 'gamma': 0.1543025439290997, 'learning_rate': 0.17253731562992064, 'max_depth': 2, 'n_estimators': 199, 'subsample': 0.6713741026981177}, {'colsample_bytree': 0.2854919890837761, 'gamma': 0.07016059983711814, 'learning_rate': 0.23800134011606186, 'max_depth': 3, 'n_estimators': 166, 'subsample': 0.8173998988252962}, {'colsample_bytree': 0.48373639310566247, 'gamma': 0.36054552768273923, 'lear
797}, {'colsample_bytree': 0.6136171803192744, 'gamma': 0.45323181127211415, 'learning_rate': 0.20739083785478404, 'max_depth': 3, 'n_estimators': 94, 'subsample': 0.620505796841248}, {'colsample_bytree': 0.2848297439984829, 'gamma': 0.04641949142289853, 'learning_rate': 0.16736747598871302, 'max_depth': 3, 'n_estimators': 182, 'subsample': 0.4855304611369688}, {'colsample_bytree' ...
#        -0.08946353,  0.07343988]), 'split1_test_score': array([-0.22906644,  0.03029714, -0.11254798, ..., -0.14275688,
#        -0.19427087, -0.15882131]), 'split2_test_score': array([0.26527421, 0.39452752, 0.30576484, ..., 0.27004017, 0.33352482,
#        0.26790241]), 'split3_test_score': array([ 0.0849265 ,  0.07091621, -0.04047631, ...,  0.16381093,
#         0.15517424,  0.06406687]), 'split4_test_score': array([-0.34603664, -0.40293388, -0.29875032, ..., -0.16698229,
#        -0.35136985, -0.23694469]), 'mean_test_score': array([-0.13257521,  0.02592373, -0.03951777, ...,  0.04522357,
#        -0.02928104,  0.00192863]), 'std_test_score': array([0.26598336, 0.25375169, 0.19590886, ..., 0.17216136, 0.24504555,
#        0.18034305]), 'rank_test_score': array([2815, 1380, 2251, ..., 1103, 2138, 1744], dtype=int32), 'split0_train_score': array([0.98153547, 0.94267996, 0.98209785, ..., 0.67719493, 0.85371481,
#        0.71662349]), 'split1_train_score': array([0.97822619, 0.94890815, 0.98114233, ..., 0.7152374 , 0.87231147,
#        0.75058546]), 'split2_train_score': array([0.97789442, 0.93125854, 0.98031027, ..., 0.67822962, 0.85443473,
#        0.70921046]), 'split3_train_score': array([0.97722979, 0.94112145, 0.97753677, ..., 0.68418979, 0.8548616 ,
#        0.72796207]), 'split4_train_score': array([0.97722856, 0.95648882, 0.98023899, ..., 0.75140687, 0.87200295,
#        0.78644675]), 'mean_train_score': array([0.97842289, 0.94409138, 0.98026524, ..., 0.70125172, 0.86146511,
#        0.73816564]), 'std_train_score': array([0.0016035 , 0.00839514, 0.00152151, ..., 0.02867401, 0.0087383 ,
#        0.02789945])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.8478701266030472
# Gamma: 0.26026245736585507
# Learning_rate: 0.0914008527255964
# Max_depth: 2
# N_estimators: 52
# Subsample: 0.6047757242309929

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:1.57225	validation_1-rmse:1.69799
# [1]	validation_0-rmse:1.49525	validation_1-rmse:1.62508
# [2]	validation_0-rmse:1.42902	validation_1-rmse:1.57212
# [3]	validation_0-rmse:1.36383	validation_1-rmse:1.50812
# [4]	validation_0-rmse:1.31080	validation_1-rmse:1.45354
# [5]	validation_0-rmse:1.26518	validation_1-rmse:1.40734
# [6]	validation_0-rmse:1.22568	validation_1-rmse:1.36676
# [7]	validation_0-rmse:1.18876	validation_1-rmse:1.33624
# [8]	validation_0-rmse:1.15291	validation_1-rmse:1.30150
# [9]	validation_0-rmse:1.12192	validation_1-rmse:1.27064
# [10]	validation_0-rmse:1.08756	validation_1-rmse:1.23791
# [11]	validation_0-rmse:1.05605	validation_1-rmse:1.22472
# [12]	validation_0-rmse:1.03115	validation_1-rmse:1.21026
# [13]	validation_0-rmse:1.00693	validation_1-rmse:1.19491
# [14]	validation_0-rmse:0.98591	validation_1-rmse:1.17765
# [15]	validation_0-rmse:0.97348	validation_1-rmse:1.17121
# [16]	validation_0-rmse:0.96178	validation_1-rmse:1.16660
# [17]	validation_0-rmse:0.95203	validation_1-rmse:1.16191
# [18]	validation_0-rmse:0.94063	validation_1-rmse:1.15916
# [19]	validation_0-rmse:0.93122	validation_1-rmse:1.15772
# [20]	validation_0-rmse:0.92128	validation_1-rmse:1.15684
# [21]	validation_0-rmse:0.91360	validation_1-rmse:1.14943
# [22]	validation_0-rmse:0.90516	validation_1-rmse:1.13463
# [23]	validation_0-rmse:0.89133	validation_1-rmse:1.12195
# [24]	validation_0-rmse:0.88688	validation_1-rmse:1.11997
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
#
# [51]	validation_0-rmse:0.76441	validation_1-rmse:1.09007
# [0]	validation_0-rmse:1.63916	validation_1-rmse:1.47846
# [1]	validation_0-rmse:1.55531	validation_1-rmse:1.40568
# [2]	validation_0-rmse:1.47975	validation_1-rmse:1.33099
# [3]	validation_0-rmse:1.40238	validation_1-rmse:1.24745
# [4]	validation_0-rmse:1.33935	validation_1-rmse:1.19968
# [5]	validation_0-rmse:1.27607	validation_1-rmse:1.15149
# [6]	validation_0-rmse:1.22920	validation_1-rmse:1.12032
# [7]	validation_0-rmse:1.19795	validation_1-rmse:1.09340
# [8]	validation_0-rmse:1.15698	validation_1-rmse:1.06735
# [9]	validation_0-rmse:1.12614	validation_1-rmse:1.04859
# [10]	validation_0-rmse:1.10255	validation_1-rmse:1.04704
# [11]	validation_0-rmse:1.08047	validation_1-rmse:1.04060
# [12]	validation_0-rmse:1.06079	validation_1-rmse:1.04043
# [13]	validation_0-rmse:1.03636	validation_1-rmse:1.02702
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [14]	validation_0-rmse:1.01475	validation_1-rmse:1.02249
# [15]	validation_0-rmse:0.99871	validation_1-rmse:1.02834
# [16]	validation_0-rmse:0.98963	validation_1-rmse:1.03043
# [17]	validation_0-rmse:0.97102	validation_1-rmse:1.03699
# [18]	validation_0-rmse:0.95812	validation_1-rmse:1.03768
# [19]	validation_0-rmse:0.94234	validation_1-rmse:1.04147
# [20]	validation_0-rmse:0.93137	validation_1-rmse:1.05217
# [21]	validation_0-rmse:0.92155	validation_1-rmse:1.05626
# [22]	validation_0-rmse:0.91214	validation_1-rmse:1.05608
# [23]	validation_0-rmse:0.90546	validation_1-rmse:1.05642
# [24]	validation_0-rmse:0.89726	validation_1-rmse:1.05795
# [25]	validation_0-rmse:0.88853	validation_1-rmse:1.05911
# [26]	validation_0-rmse:0.88250	validation_1-rmse:1.05941
# [27]	validation_0-rmse:0.87430	validation_1-rmse:1.05917
# [28]	validation_0-rmse:0.86850	validation_1-rmse:1.05931
# [29]	validation_0-rmse:0.86284	validation_1-rmse:1.05658
# [30]	validation_0-rmse:0.85605	validation_1-rmse:1.06361
# [31]	validation_0-rmse:0.85149	validation_1-rmse:1.06819
# [32]	validation_0-rmse:0.84737	validation_1-rmse:1.07013
# [33]	validation_0-rmse:0.84279	validation_1-rmse:1.07691
# [0]	validation_0-rmse:1.62239	validation_1-rmse:1.55639
# [1]	validation_0-rmse:1.53434	validation_1-rmse:1.46909
# [2]	validation_0-rmse:1.45814	validation_1-rmse:1.40347
# [3]	validation_0-rmse:1.39901	validation_1-rmse:1.36551
# [4]	validation_0-rmse:1.35012	validation_1-rmse:1.31205
# [5]	validation_0-rmse:1.30050	validation_1-rmse:1.27851
# [6]	validation_0-rmse:1.25507	validation_1-rmse:1.23367
# [7]	validation_0-rmse:1.20509	validation_1-rmse:1.20446
# [8]	validation_0-rmse:1.16247	validation_1-rmse:1.16333
# [9]	validation_0-rmse:1.13290	validation_1-rmse:1.13222
# [10]	validation_0-rmse:1.10537	validation_1-rmse:1.11864
# [27]	validation_0-rmse:0.91964	validation_1-rmse:0.96598
# [28]	validation_0-rmse:0.91293	validation_1-rmse:0.95872
# [29]	validation_0-rmse:0.90491	validation_1-rmse:0.95606
# [30]	validation_0-rmse:0.89905	validation_1-rmse:0.95082
# [31]	validation_0-rmse:0.89595	validation_1-rmse:0.95546
# [32]	validation_0-rmse:0.89377	validation_1-rmse:0.96132
# [33]	validation_0-rmse:0.88658	validation_1-rmse:0.95732
# [34]	validation_0-rmse:0.88101	validation_1-rmse:0.96060
# [35]	validation_0-rmse:0.87715	validation_1-rmse:0.95283
# [36]	validation_0-rmse:0.87433	validation_1-rmse:0.95363
# [37]	validation_0-rmse:0.86977	validation_1-rmse:0.95361
# [38]	validation_0-rmse:0.86501	validation_1-rmse:0.95367
# [39]	validation_0-rmse:0.86045	validation_1-rmse:0.94771
# [40]	validation_0-rmse:0.85438	validation_1-rmse:0.95156
# [41]	validation_0-rmse:0.85167	validation_1-rmse:0.94617
# [42]	validation_0-rmse:0.84758	validation_1-rmse:0.95139
# [43]	validation_0-rmse:0.84408	validation_1-rmse:0.95206
# [44]	validation_0-rmse:0.84217	validation_1-rmse:0.95082
# [45]	validation_0-rmse:0.83900	validation_1-rmse:0.95804
# [46]	validation_0-rmse:0.83473	validation_1-rmse:0.96044
# [47]	validation_0-rmse:0.82993	validation_1-rmse:0.95987
# [48]	validation_0-rmse:0.82780	validation_1-rmse:0.96358
# [49]	validation_0-rmse:0.82439	validation_1-rmse:0.97058
# [50]	validation_0-rmse:0.82070	validation_1-rmse:0.97345
# [51]	validation_0-rmse:0.81718	validation_1-rmse:0.97520
# [0]	validation_0-rmse:1.53193	validation_1-rmse:1.85069
# [1]	validation_0-rmse:1.44902	validation_1-rmse:1.77477
# [2]	validation_0-rmse:1.38730	validation_1-rmse:1.71679
# [3]	validation_0-rmse:1.32997	validation_1-rmse:1.67008
# [4]	validation_0-rmse:1.27462	validation_1-rmse:1.61699
# [5]	validation_0-rmse:1.23421	validation_1-rmse:1.57420
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:1.19778	validation_1-rmse:1.52878
# [7]	validation_0-rmse:1.16386	validation_1-rmse:1.49652
# [8]	validation_0-rmse:1.13290	validation_1-rmse:1.45705
# [9]	validation_0-rmse:1.10596	validation_1-rmse:1.42489
# [10]	validation_0-rmse:1.08142	validation_1-rmse:1.40382
# [11]	validation_0-rmse:1.05213	validation_1-rmse:1.36286
# [12]	validation_0-rmse:1.02939	validation_1-rmse:1.33514
# [13]	validation_0-rmse:1.00746	validation_1-rmse:1.30161
# [14]	validation_0-rmse:0.99129	validation_1-rmse:1.28175
# [15]	validation_0-rmse:0.97995	validation_1-rmse:1.26079
# [16]	validation_0-rmse:0.97246	validation_1-rmse:1.25434
# [17]	validation_0-rmse:0.95993	validation_1-rmse:1.23616
# [18]	validation_0-rmse:0.95248	validation_1-rmse:1.23041
# [19]	validation_0-rmse:0.94460	validation_1-rmse:1.21635
# [20]	validation_0-rmse:0.93608	validation_1-rmse:1.20568
# [21]	validation_0-rmse:0.92987	validation_1-rmse:1.19836
# [22]	validation_0-rmse:0.92193	validation_1-rmse:1.18976
# [23]	validation_0-rmse:0.91785	validation_1-rmse:1.18540
# [24]	validation_0-rmse:0.90965	validation_1-rmse:1.18167
# [25]	validation_0-rmse:0.90170	validation_1-rmse:1.16735
# [26]	validation_0-rmse:0.89280	validation_1-rmse:1.15580
# [27]	validation_0-rmse:0.88789	validation_1-rmse:1.14772
# [28]	validation_0-rmse:0.87863	validation_1-rmse:1.13350
# [29]	validation_0-rmse:0.87167	validation_1-rmse:1.11758
# [30]	validation_0-rmse:0.86735	validation_1-rmse:1.10723
# [31]	validation_0-rmse:0.86119	validation_1-rmse:1.10417
# [32]	validation_0-rmse:0.85375	validation_1-rmse:1.09407
# [33]	validation_0-rmse:0.85134	validation_1-rmse:1.08761
# [34]	validation_0-rmse:0.84678	validation_1-rmse:1.08859
# [35]	validation_0-rmse:0.84247	validation_1-rmse:1.09107
# [36]	validation_0-rmse:0.83675	validation_1-rmse:1.09075
# [37]	validation_0-rmse:0.83193	validation_1-rmse:1.08584
# [38]	validation_0-rmse:0.82911	validation_1-rmse:1.08335
# [39]	validation_0-rmse:0.82630	validation_1-rmse:1.09035
# ...
# [10]	validation_0-rmse:1.08733	validation_1-rmse:1.38685
# [11]	validation_0-rmse:1.05927	validation_1-rmse:1.36154
# [12]	validation_0-rmse:1.03593	validation_1-rmse:1.32997
# [13]	validation_0-rmse:1.01397	validation_1-rmse:1.31070
# [14]	validation_0-rmse:0.99257	validation_1-rmse:1.29723
# [15]	validation_0-rmse:0.97522	validation_1-rmse:1.26961
# [16]	validation_0-rmse:0.95999	validation_1-rmse:1.25386
# [17]	validation_0-rmse:0.94861	validation_1-rmse:1.24642
# [18]	validation_0-rmse:0.93574	validation_1-rmse:1.25309
# [19]	validation_0-rmse:0.92572	validation_1-rmse:1.25050
# [20]	validation_0-rmse:0.91624	validation_1-rmse:1.22833
# [21]	validation_0-rmse:0.90579	validation_1-rmse:1.22080
# [22]	validation_0-rmse:0.89423	validation_1-rmse:1.20361
# [23]	validation_0-rmse:0.88783	validation_1-rmse:1.19950
# [24]	validation_0-rmse:0.88224	validation_1-rmse:1.19388
# [25]	validation_0-rmse:0.87503	validation_1-rmse:1.18556
# [26]	validation_0-rmse:0.86926	validation_1-rmse:1.17997
# [27]	validation_0-rmse:0.86305	validation_1-rmse:1.17635
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [28]	validation_0-rmse:0.85525	validation_1-rmse:1.18094
# [29]	validation_0-rmse:0.84887	validation_1-rmse:1.17619
# [30]	validation_0-rmse:0.84328	validation_1-rmse:1.17036
# [31]	validation_0-rmse:0.84054	validation_1-rmse:1.16724
# [32]	validation_0-rmse:0.83446	validation_1-rmse:1.18075
# [33]	validation_0-rmse:0.82872	validation_1-rmse:1.18225
# [34]	validation_0-rmse:0.82437	validation_1-rmse:1.18934
# [35]	validation_0-rmse:0.82260	validation_1-rmse:1.18579
# [36]	validation_0-rmse:0.81750	validation_1-rmse:1.17940
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [27]	validation_0-rmse:0.84829	validation_1-rmse:1.17066
# [28]	validation_0-rmse:0.84120	validation_1-rmse:1.17089
# [29]	validation_0-rmse:0.83533	validation_1-rmse:1.17107
# [30]	validation_0-rmse:0.82946	validation_1-rmse:1.16393
# [31]	validation_0-rmse:0.82408	validation_1-rmse:1.16751
# [32]	validation_0-rmse:0.81734	validation_1-rmse:1.16929
# [33]	validation_0-rmse:0.80893	validation_1-rmse:1.16371
# [34]	validation_0-rmse:0.80380	validation_1-rmse:1.16508
# [35]	validation_0-rmse:0.79856	validation_1-rmse:1.15733
# [36]	validation_0-rmse:0.79209	validation_1-rmse:1.15432
# [37]	validation_0-rmse:0.78759	validation_1-rmse:1.15142
# [38]	validation_0-rmse:0.78321	validation_1-rmse:1.15367
# [39]	validation_0-rmse:0.77939	validation_1-rmse:1.15715
# [40]	validation_0-rmse:0.77777	validation_1-rmse:1.15437
# [41]	validation_0-rmse:0.77561	validation_1-rmse:1.15299
# [42]	validation_0-rmse:0.77178	validation_1-rmse:1.14754
# [43]	validation_0-rmse:0.76798	validation_1-rmse:1.14399
# [44]	validation_0-rmse:0.76622	validation_1-rmse:1.13909
# [45]	validation_0-rmse:0.76273	validation_1-rmse:1.14258
# [46]	validation_0-rmse:0.75841	validation_1-rmse:1.15174
# [47]	validation_0-rmse:0.75487	validation_1-rmse:1.14966
# [48]	validation_0-rmse:0.75184	validation_1-rmse:1.15228
# [49]	validation_0-rmse:0.75053	validation_1-rmse:1.15527
# [50]	validation_0-rmse:0.74795	validation_1-rmse:1.15631
# [51]	validation_0-rmse:0.74470	validation_1-rmse:1.15679
# [0]	validation_0-rmse:1.59060	validation_1-rmse:1.66541
# [1]	validation_0-rmse:1.50833	validation_1-rmse:1.58023
# [2]	validation_0-rmse:1.43136	validation_1-rmse:1.49810
# [3]	validation_0-rmse:1.36470	validation_1-rmse:1.43276
# [4]	validation_0-rmse:1.30673	validation_1-rmse:1.38476
# [5]	validation_0-rmse:1.25767	validation_1-rmse:1.34168
# [6]	validation_0-rmse:1.22258	validation_1-rmse:1.31792
# [7]	validation_0-rmse:1.18623	validation_1-rmse:1.28769
# [8]	validation_0-rmse:1.15738	validation_1-rmse:1.25553
# [9]	validation_0-rmse:1.12823	validation_1-rmse:1.22884
# [10]	validation_0-rmse:1.10363	validation_1-rmse:1.20956
# [11]	validation_0-rmse:1.07546	validation_1-rmse:1.18785
# [12]	validation_0-rmse:1.05849	validation_1-rmse:1.17171
# [13]	validation_0-rmse:1.03557	validation_1-rmse:1.14701
# [14]	validation_0-rmse:1.01365	validation_1-rmse:1.13410
# [15]	validation_0-rmse:0.99995	validation_1-rmse:1.12294
# [16]	validation_0-rmse:0.98674	validation_1-rmse:1.11169
# [17]	validation_0-rmse:0.97349	validation_1-rmse:1.09967
# [18]	validation_0-rmse:0.95869	validation_1-rmse:1.10396
# [19]	validation_0-rmse:0.94654	validation_1-rmse:1.10356
# [20]	validation_0-rmse:0.93687	validation_1-rmse:1.10795
# [21]	validation_0-rmse:0.92870	validation_1-rmse:1.09630
# [22]	validation_0-rmse:0.92040	validation_1-rmse:1.09819
# [23]	validation_0-rmse:0.91759	validation_1-rmse:1.09790
# [24]	validation_0-rmse:0.90905	validation_1-rmse:1.09288
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [25]	validation_0-rmse:0.90415	validation_1-rmse:1.09207
# [26]	validation_0-rmse:0.89327	validation_1-rmse:1.08357
# [27]	validation_0-rmse:0.88981	validation_1-rmse:1.08019
# [28]	validation_0-rmse:0.88478	validation_1-rmse:1.07306
# [29]	validation_0-rmse:0.87758	validation_1-rmse:1.06757
# [30]	validation_0-rmse:0.87289	validation_1-rmse:1.07247
# [31]	validation_0-rmse:0.86766	validation_1-rmse:1.06269
# [32]	validation_0-rmse:0.86308	validation_1-rmse:1.06156
# [33]	validation_0-rmse:0.85812	validation_1-rmse:1.05867
# [34]	validation_0-rmse:0.85394	validation_1-rmse:1.05223
# [35]	validation_0-rmse:0.84869	validation_1-rmse:1.04808
# [36]	validation_0-rmse:0.84560	validation_1-rmse:1.04886
# [37]	validation_0-rmse:0.83994	validation_1-rmse:1.05282
# [38]	validation_0-rmse:0.83694	validation_1-rmse:1.05794
# [39]	validation_0-rmse:0.83393	validation_1-rmse:1.06428
# [40]	validation_0-rmse:0.83300	validation_1-rmse:1.06249
# [41]	validation_0-rmse:0.82914	validation_1-rmse:1.05868
# [42]	validation_0-rmse:0.82620	validation_1-rmse:1.04668
# [43]	validation_0-rmse:0.82363	validation_1-rmse:1.05509
# [44]	validation_0-rmse:0.82076	validation_1-rmse:1.05618
# [45]	validation_0-rmse:0.81844	validation_1-rmse:1.05396
# [46]	validation_0-rmse:0.81568	validation_1-rmse:1.05174
# [47]	validation_0-rmse:0.81323	validation_1-rmse:1.04446
# [48]	validation_0-rmse:0.80937	validation_1-rmse:1.04379
# [49]	validation_0-rmse:0.80470	validation_1-rmse:1.03275
# [50]	validation_0-rmse:0.80105	validation_1-rmse:1.03985
# [51]	validation_0-rmse:0.79638	validation_1-rmse:1.04018
# [0]	validation_0-rmse:1.56844	validation_1-rmse:1.71143
# [1]	validation_0-rmse:1.48454	validation_1-rmse:1.63615
# [2]	validation_0-rmse:1.40619	validation_1-rmse:1.56676
# [3]	validation_0-rmse:1.35050	validation_1-rmse:1.52076
# [4]	validation_0-rmse:1.30769	validation_1-rmse:1.48230
# [5]	validation_0-rmse:1.25380	validation_1-rmse:1.42661
# [6]	validation_0-rmse:1.20424	validation_1-rmse:1.38908
# [7]	validation_0-rmse:1.15843	validation_1-rmse:1.33907
# [8]	validation_0-rmse:1.12821	validation_1-rmse:1.30571
# [9]	validation_0-rmse:1.10216	validation_1-rmse:1.26970
# [10]	validation_0-rmse:1.07917	validation_1-rmse:1.24551
# [11]	validation_0-rmse:1.06110	validation_1-rmse:1.23535
# [12]	validation_0-rmse:1.03805	validation_1-rmse:1.21306
# [13]	validation_0-rmse:1.01999	validation_1-rmse:1.19720
# [14]	validation_0-rmse:1.00412	validation_1-rmse:1.18851
# [15]	validation_0-rmse:0.98548	validation_1-rmse:1.18151
# [16]	validation_0-rmse:0.96955	validation_1-rmse:1.16985
# [17]	validation_0-rmse:0.95783	validation_1-rmse:1.16579
# [18]	validation_0-rmse:0.94467	validation_1-rmse:1.15497
# [19]	validation_0-rmse:0.93108	validation_1-rmse:1.14822
# [20]	validation_0-rmse:0.92570	validation_1-rmse:1.14327
# [21]	validation_0-rmse:0.91590	validation_1-rmse:1.13721
# [22]	validation_0-rmse:0.90498	validation_1-rmse:1.13752
# [23]	validation_0-rmse:0.89694	validation_1-rmse:1.12984
# [24]	validation_0-rmse:0.88927	validation_1-rmse:1.11866
# [25]	validation_0-rmse:0.88345	validation_1-rmse:1.11340
# [26]	validation_0-rmse:0.87450	validation_1-rmse:1.10915
# [27]	validation_0-rmse:0.86811	validation_1-rmse:1.10775
# [28]	validation_0-rmse:0.86071	validation_1-rmse:1.11127
# [29]	validation_0-rmse:0.85092	validation_1-rmse:1.11043
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [30]	validation_0-rmse:0.84810	validation_1-rmse:1.10851
# [31]	validation_0-rmse:0.84282	validation_1-rmse:1.10515
# [32]	validation_0-rmse:0.83743	validation_1-rmse:1.09538
# [33]	validation_0-rmse:0.83393	validation_1-rmse:1.09307
# [34]	validation_0-rmse:0.82776	validation_1-rmse:1.08904
# [35]	validation_0-rmse:0.82268	validation_1-rmse:1.08442
# [36]	validation_0-rmse:0.81703	validation_1-rmse:1.08869
# [37]	validation_0-rmse:0.81083	validation_1-rmse:1.08534
# [38]	validation_0-rmse:0.80748	validation_1-rmse:1.08256
# [39]	validation_0-rmse:0.80460	validation_1-rmse:1.08349
# [40]	validation_0-rmse:0.80156	validation_1-rmse:1.08418
# [41]	validation_0-rmse:0.79881	validation_1-rmse:1.09129
# [42]	validation_0-rmse:0.79340	validation_1-rmse:1.09288
# [43]	validation_0-rmse:0.79005	validation_1-rmse:1.09471
# [44]	validation_0-rmse:0.78559	validation_1-rmse:1.09751
# [45]	validation_0-rmse:0.78207	validation_1-rmse:1.10404
# [46]	validation_0-rmse:0.77961	validation_1-rmse:1.10420
# [47]	validation_0-rmse:0.77742	validation_1-rmse:1.10219
# [48]	validation_0-rmse:0.77223	validation_1-rmse:1.10019
# [49]	validation_0-rmse:0.76938	validation_1-rmse:1.10068
# [50]	validation_0-rmse:0.76824	validation_1-rmse:1.10029
# [51]	validation_0-rmse:0.76352	validation_1-rmse:1.10248
# [0]	validation_0-rmse:1.61367	validation_1-rmse:1.56451
# [1]	validation_0-rmse:1.53465	validation_1-rmse:1.50115
# [2]	validation_0-rmse:1.46335	validation_1-rmse:1.44721
# [3]	validation_0-rmse:1.40689	validation_1-rmse:1.39999
# [4]	validation_0-rmse:1.34243	validation_1-rmse:1.35318
# [5]	validation_0-rmse:1.29010	validation_1-rmse:1.32005
# [6]	validation_0-rmse:1.23975	validation_1-rmse:1.27911
# [7]	validation_0-rmse:1.19806	validation_1-rmse:1.25195
# [8]	validation_0-rmse:1.15357	validation_1-rmse:1.23533
# [9]	validation_0-rmse:1.12446	validation_1-rmse:1.21680
# [10]	validation_0-rmse:1.09608	validation_1-rmse:1.20346
# [11]	validation_0-rmse:1.06616	validation_1-rmse:1.17698
# [12]	validation_0-rmse:1.04419	validation_1-rmse:1.16378
# [13]	validation_0-rmse:1.02105	validation_1-rmse:1.14345
# [14]	validation_0-rmse:1.00821	validation_1-rmse:1.13383
# [15]	validation_0-rmse:0.98867	validation_1-rmse:1.12657
# [16]	validation_0-rmse:0.97111	validation_1-rmse:1.11336
# [17]	validation_0-rmse:0.95408	validation_1-rmse:1.10401
# [18]	validation_0-rmse:0.94671	validation_1-rmse:1.09829
# [19]	validation_0-rmse:0.93713	validation_1-rmse:1.09930
# [20]	validation_0-rmse:0.92706	validation_1-rmse:1.09728
# [21]	validation_0-rmse:0.91638	validation_1-rmse:1.10743
# [22]	validation_0-rmse:0.90287	validation_1-rmse:1.11019
# [23]	validation_0-rmse:0.89407	validation_1-rmse:1.11087
# [24]	validation_0-rmse:0.88770	validation_1-rmse:1.10783
# [25]	validation_0-rmse:0.87836	validation_1-rmse:1.10464
# [26]	validation_0-rmse:0.86813	validation_1-rmse:1.11017
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [27]	validation_0-rmse:0.86194	validation_1-rmse:1.11429
# [28]	validation_0-rmse:0.85591	validation_1-rmse:1.11246
# [29]	validation_0-rmse:0.84891	validation_1-rmse:1.10439
# [30]	validation_0-rmse:0.84535	validation_1-rmse:1.09873
# [31]	validation_0-rmse:0.84050	validation_1-rmse:1.10246
# [32]	validation_0-rmse:0.83476	validation_1-rmse:1.10197
# [33]	validation_0-rmse:0.82872	validation_1-rmse:1.10365
# [34]	validation_0-rmse:0.82528	validation_1-rmse:1.10436
# [35]	validation_0-rmse:0.81836	validation_1-rmse:1.11240
# [36]	validation_0-rmse:0.81277	validation_1-rmse:1.11481
# [37]	validation_0-rmse:0.80952	validation_1-rmse:1.11346
# [38]	validation_0-rmse:0.80703	validation_1-rmse:1.11520
# [39]	validation_0-rmse:0.80479	validation_1-rmse:1.11125
# [40]	validation_0-rmse:0.79937	validation_1-rmse:1.10931
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 34.4, median: 36.0,
#  pred. interval (P(0.025)-P(0.975)): 12.975-51.0,
#  conf. interval (p-value=0.95): 31.265-39.748
# ***
# Aggregate bias statistic:
#  mean: 2.502, median: 1.839,
#  pred. interval (P(0.025)-P(0.975)): -7.901-15.187,
#  conf. interval (p-value=0.95): 0.162-3.913
# ***
# Aggregate RMSE statistic:
#  mean: 1.037, median: 1.042, pred. interval (P(0.025)-P(0.975)): 0.801-1.278,
#  conf. interval (p-value=0.95): 1.002-1.073
# ***
# Aggregate MSE statistic:
#  mean: 1.089, median: 1.085, pred. interval (P(0.025)-P(0.975)): 0.642-1.634,
#  conf. interval (p-value=0.95): 1.008-1.153
# ***
# Aggregate R^2 statistic:
#  mean: 0.309, median: 0.314, pred. interval (P(0.025)-P(0.975)): 0.09-0.494,
#  conf. interval (p-value=0.95): 0.277-0.345
# ***
# Aggregate bias(%) statistic:
#  mean: -2.294, median: 1.839, pred. interval (P(0.025)-P(0.975)): -17.585-18.525,
#  conf. interval (p-value=0.95): -5.909--0.071
# ***
# Aggregate RMSE(%) statistic:
#  mean: -1.801, median: -1.715, pred. interval (P(0.025)-P(0.975)): -3.205--1.084,
#  conf. interval (p-value=0.95): -1.863--1.591
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.60890
# [1]	validation_0-rmse:1.52042
# [2]	validation_0-rmse:1.45225
# [3]	validation_0-rmse:1.38903
# [4]	validation_0-rmse:1.33632
# [5]	validation_0-rmse:1.28854
# [6]	validation_0-rmse:1.24308
# [7]	validation_0-rmse:1.20466
# [8]	validation_0-rmse:1.16897
# [9]	validation_0-rmse:1.13276
# [10]	validation_0-rmse:1.10273
# [11]	validation_0-rmse:1.08505
# [12]	validation_0-rmse:1.06056
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [13]	validation_0-rmse:1.04093
# [14]	validation_0-rmse:1.02291
# [15]	validation_0-rmse:1.00708
# [16]	validation_0-rmse:0.99087
# [17]	validation_0-rmse:0.97657
# [18]	validation_0-rmse:0.96694
# [19]	validation_0-rmse:0.95761
# [20]	validation_0-rmse:0.94658
# [21]	validation_0-rmse:0.93826
# [22]	validation_0-rmse:0.93007
# [23]	validation_0-rmse:0.91978
# [24]	validation_0-rmse:0.91571
# [25]	validation_0-rmse:0.90957
# [26]	validation_0-rmse:0.90591
# [27]	validation_0-rmse:0.90148
# [28]	validation_0-rmse:0.89479
# [29]	validation_0-rmse:0.88877
# [30]	validation_0-rmse:0.88395
# [31]	validation_0-rmse:0.87955
# [32]	validation_0-rmse:0.87371
# [33]	validation_0-rmse:0.87032
# [34]	validation_0-rmse:0.86739
# [35]	validation_0-rmse:0.86418
# [36]	validation_0-rmse:0.86125
# [37]	validation_0-rmse:0.85828
# [38]	validation_0-rmse:0.85302
# [39]	validation_0-rmse:0.84818
# [40]	validation_0-rmse:0.84315
# [41]	validation_0-rmse:0.84094
# [42]	validation_0-rmse:0.83433
# [43]	validation_0-rmse:0.82997
# [44]	validation_0-rmse:0.82727
# [45]	validation_0-rmse:0.82362
# [46]	validation_0-rmse:0.81935
# [47]	validation_0-rmse:0.81710
# [48]	validation_0-rmse:0.81536
# [49]	validation_0-rmse:0.81320
# [50]	validation_0-rmse:0.81091
# [51]	validation_0-rmse:0.80821
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 51

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  -0.92
# RMSE: 0.8
# Relative RMSE(%):  -1.304
# MSE: 0.7
# R square: 59.7%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: -0.301
# a1: 0.510
# R^2: 0.615
# Uncertainty
# a0: -0.30+/-0.04
# a1: 0.510+/-0.028

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/WORK/GIS and ML algoritms/6_Est_RN&biomass_all_site_Sentinel/Nootbooks/XGB_model_Tag_Cs_2019_ver1.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/WORK/GIS and ML algoritms/6_Est_RN&biomass_all_site_Sentinel/Nootbooks/XGB_model_Tag_Cs_2019_ver1.txt")
