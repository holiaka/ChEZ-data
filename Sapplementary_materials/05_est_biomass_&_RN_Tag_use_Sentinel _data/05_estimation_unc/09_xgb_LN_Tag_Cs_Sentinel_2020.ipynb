# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../05_input_data/Sites_with_Sentinel_bands_data.xlsx'
df = pd.read_excel(site_data, sheet_name='input_2020')
df.head()
# Out:
#   Site # Origin Dominant_s  LN_GS_cub_m  LN_M_stem_kg_m2  \
# 0      1      n      Birch        4.771            1.792
# 1      2      a       Pine        5.808            2.496
# 2      3      a       Pine        5.796            2.546
# 3      4      a       Pine        5.826            2.643
# 4      5      a       Pine        6.059            2.643
#
#    LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  LN_M_foliage_kg_m2  LN_M_AG_kg_m2  \
# 0                -0.211            -0.261              -2.040          1.932
# 1                -0.073             0.392              -0.139          2.674
# 2                 0.030             0.501              -0.030          2.734
# 3                 0.000             0.419              -0.431          2.785
# 4                 0.122             0.647              -0.386          2.809
#
#         X_N36  ...  r2020B04  r2020B05  r2020B06  r2020B07  r2020B08  \
# 0  298987.203  ...  0.254417  0.175280  0.086611  0.797761 -0.749311
# 1  299016.572  ...  0.189826  0.092225  0.047120  0.789129 -0.705355
# 2  299072.773  ...  0.204363  0.093062  0.043824  0.812120 -0.704758
# 3  299152.693  ...  0.187998  0.102872  0.048585  0.762431 -0.695416
# 4  299249.689  ...  0.216271  0.096981  0.044880  0.793606 -0.717562
#
#    r2020B09   r2020B10   r2020B11  r2020B12  r2020B13
# 0  0.491270 -15.527246 -11.385074  0.733806  0.040781
# 1  0.659775 -16.547673 -10.947565  0.661723 -0.102776
# 2  0.631348 -14.341917 -11.884799  0.829603 -0.063200
# 3  0.601894 -14.885610 -11.725163  0.787609 -0.057177
# 4  0.642942 -14.647913 -11.512282  0.785698 -0.073830
#
# [5 rows x 35 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Site #', 'Origin', 'Dominant_s', 'LN_GS_cub_m', 'LN_M_stem_kg_m2', 'LN_M_stem_bark_kg_m2', 'LN_M_crown_kg_m2', 'LN_M_foliage_kg_m2', 'LN_M_AG_kg_m2', 'F_Soil', 'M_Soil', 'X_N36', 'Y_N36', 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'LN_Cs_wood', 'LN_Sr_wood', 'Tag_Cs', 'Tag_Sr', 'LN_Tag_Cs', 'LN_Tag_Sr', 'Cs_2021_kB', 'Sr_2021_kB', 'AEDR_mean', 'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['LN_GS_cub_m', 'LN_M_stem_kg_m2', 'LN_M_stem_bark_kg_m2', 'LN_M_crown_kg_m2', 'LN_M_foliage_kg_m2', 'LN_M_AG_kg_m2', 'LN_Tag_Cs', 'LN_Tag_Sr',
                                  'r2020B01', 'r2020B02', 'r2020B03', 'r2020B04', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11', 'r2020B12'])

# Show the first five columns
select.head()
# Out:
#    LN_GS_cub_m  LN_M_stem_kg_m2  LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  \
# 0        4.771            1.792                -0.211            -0.261
# 1        5.808            2.496                -0.073             0.392
# 2        5.796            2.546                 0.030             0.501
# 3        5.826            2.643                 0.000             0.419
# 4        6.059            2.643                 0.122             0.647
#
#    LN_M_foliage_kg_m2  LN_M_AG_kg_m2  LN_Tag_Cs  LN_Tag_Sr  r2020B01  \
# 0              -2.040          1.932      -0.73       2.58  0.019397
# 1              -0.139          2.674       0.59       2.92  0.019167
# 2              -0.030          2.734       0.78       2.88  0.019568
# 3              -0.431          2.785       0.52       2.72  0.020556
# 4              -0.386          2.809       0.22       2.83  0.019003
#
#    r2020B02  r2020B03  r2020B04  r2020B05  r2020B06  r2020B07  r2020B08  \
# 0  0.035344  0.028616  0.254417  0.175280  0.086611  0.797761 -0.749311
# 1  0.033537  0.022230  0.189826  0.092225  0.047120  0.789129 -0.705355
# 2  0.035957  0.021190  0.204363  0.093062  0.043824  0.812120 -0.704758
# 3  0.033868  0.025284  0.187998  0.102872  0.048585  0.762431 -0.695416
# 4  0.036153  0.024911  0.216271  0.096981  0.044880  0.793606 -0.717562
#
#    r2020B09   r2020B10   r2020B11  r2020B12
# 0  0.491270 -15.527246 -11.385074  0.733806
# 1  0.659775 -16.547673 -10.947565  0.661723
# 2  0.631348 -14.341917 -11.884799  0.829603
# 3  0.601894 -14.885610 -11.725163  0.787609
# 4  0.642942 -14.647913 -11.512282  0.785698

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   LN_GS_cub_m           198 non-null    float64
#  1   LN_M_stem_kg_m2       198 non-null    float64
#  2   LN_M_stem_bark_kg_m2  198 non-null    float64
#  3   LN_M_crown_kg_m2      198 non-null    float64
#  4   LN_M_foliage_kg_m2    198 non-null    float64
#  5   LN_M_AG_kg_m2         198 non-null    float64
#  6   LN_Tag_Cs             198 non-null    float64
#  7   LN_Tag_Sr             198 non-null    float64
#  8   r2020B01              198 non-null    float64
#  9   r2020B02              198 non-null    float64
#  10  r2020B03              198 non-null    float64
#  11  r2020B04              198 non-null    float64
#  12  r2020B05              198 non-null    float64
#  13  r2020B06              198 non-null    float64
#  14  r2020B07              198 non-null    float64
#  15  r2020B08              198 non-null    float64
#  16  r2020B09              198 non-null    float64
#  17  r2020B10              198 non-null    float64
#  18  r2020B11              198 non-null    float64
#  19  r2020B12              198 non-null    float64
# dtypes: float64(20)
# memory usage: 31.1 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_s"])["LN_Tag_Cs", "LN_Tag_Sr"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            LN_Tag_Cs                                                      \
#                count      mean       std   min    25%   50%    75%   max
# Dominant_s
# Alder           13.0 -0.620769  1.079293 -2.05 -1.410 -0.89  0.600  1.11
# Aspen            7.0 -0.957143  1.537441 -2.44 -2.125 -1.39 -0.085  1.55
# Birch           45.0 -1.003778  1.084287 -4.11 -1.330 -0.75 -0.240  0.44
# Oak              9.0 -0.385556  1.633486 -3.73 -1.100  0.61  0.700  1.34
# Pine           123.0 -0.376504  1.240669 -4.68 -1.080 -0.02  0.510  1.65
# Spruce           1.0 -2.410000       NaN -2.41 -2.410 -2.41 -2.410 -2.41
#
#            LN_Tag_Sr
#                count      mean       std   min    25%   50%   75%   max
# Dominant_s
# Alder           13.0  1.115385  0.640971 -0.17  0.520  1.34  1.54  1.79
# Aspen            7.0  2.920000  0.662319  1.96  2.450  3.16  3.32  3.78
# Birch           45.0  2.346889  0.850954 -0.25  2.000  2.47  2.66  4.66
# Oak              9.0  1.760000  1.032945  0.55  1.000  1.47  2.81  3.33
# Pine           123.0  2.481057  0.896095 -0.09  1.865  2.68  3.16  4.30
# Spruce           1.0  1.810000       NaN  1.81  1.810  1.81  1.81  1.81

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        LN_GS_cub_m  LN_M_stem_kg_m2  LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  \
# count   198.000000       198.000000             198.00000        198.000000
# mean      5.237803         2.109995              -0.11297          0.075646
# std       1.091051         1.039582               0.78467          0.711102
# min       1.609000        -1.347000              -2.65900         -2.408000
# 25%       4.914250         1.797000              -0.27075         -0.148000
# 50%       5.517000         2.413000               0.04400          0.289000
# 75%       5.989750         2.798500               0.33250          0.531000
# max       6.457000         3.428000               1.38400          1.756000
#
#        LN_M_foliage_kg_m2  LN_M_AG_kg_m2   LN_Tag_Cs   LN_Tag_Sr    r2020B01  \
# count          198.000000     198.000000  198.000000  198.000000  198.000000
# mean            -0.970066       2.304505   -0.566313    2.340253    0.022479
# std              0.713109       0.928222    1.248087    0.938549    0.005381
# min             -3.507000      -0.693000   -4.680000   -0.250000    0.012648
# 25%             -1.514000       2.001000   -1.327500    1.742500    0.019615
# 50%             -0.788000       2.565000   -0.465000    2.460000    0.021938
# 75%             -0.386000       2.899750    0.380000    2.992500    0.023920
# max              0.157000       3.515000    1.650000    4.660000    0.058966
#
#          r2020B02    r2020B03    r2020B04    r2020B05    r2020B06    r2020B07  \
# count  198.000000  198.000000  198.000000  198.000000  198.000000  198.000000
# mean     0.036321    0.027499    0.213645    0.125537    0.063662    0.767194
# std      0.006531    0.009532    0.042641    0.035475    0.023731    0.078273
# min      0.024838    0.014640    0.124161    0.079896    0.036570    0.381333
# 25%      0.033225    0.022284    0.187070    0.095832    0.046290    0.745438
# 50%      0.035316    0.024743    0.204261    0.115558    0.058209    0.784239
# 75%      0.037919    0.028527    0.236440    0.150857    0.072122    0.808780
# max      0.075169    0.080615    0.369338    0.243667    0.187427    0.885319
#
#          r2020B08    r2020B09    r2020B10    r2020B11    r2020B12
# count  198.000000  198.000000  198.000000  198.000000  198.000000
# mean    -0.703079    0.540963  -16.145709  -10.863669    0.675418
# std      0.060738    0.132304    1.343250    1.161017    0.069250
# min     -0.823403    0.038198  -22.517731  -14.262763    0.492975
# 25%     -0.735205    0.502225  -16.970102  -11.519514    0.628884
# 50%     -0.704881    0.577675  -16.010171  -10.784612    0.667561
# 75%     -0.680539    0.632284  -15.159997  -10.008004    0.720595
# max     -0.410944    0.710583  -13.281957   -7.650135    0.860863

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "LN_Tag_Cs"
indep_variables = ['r2020B04', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      LN_GS_cub_m  LN_M_stem_kg_m2  LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  \
# 0          4.771            1.792                -0.211            -0.261
# 1          5.808            2.496                -0.073             0.392
# 2          5.796            2.546                 0.030             0.501
# 3          5.826            2.643                 0.000             0.419
# 4          6.059            2.643                 0.122             0.647
# ..           ...              ...                   ...               ...
# 193        6.238            3.125                 0.322             0.560
# 194        5.861            2.702                 0.058             0.482
# 195        5.935            2.775                -0.030             0.372
# 196        5.784            2.546                -0.117             0.182
# 197        6.277            2.949                 0.182             0.501
#
#      LN_M_foliage_kg_m2  LN_M_AG_kg_m2  LN_Tag_Cs  LN_Tag_Sr  r2020B01  \
# 0                -2.040          1.932      -0.73       2.58  0.019397
# 1                -0.139          2.674       0.59       2.92  0.019167
# 2                -0.030          2.734       0.78       2.88  0.019568
# 3                -0.431          2.785       0.52       2.72  0.020556
# 4                -0.386          2.809       0.22       2.83  0.019003
# ..                  ...            ...        ...        ...       ...
# 193              -0.301          3.231      -0.03       1.79  0.019099
# 194              -0.386          2.845       0.31       2.87  0.019472
# 195              -0.545          2.896       0.51       1.74  0.021964
# 196              -0.386          2.681       1.61       2.18  0.019709
# 197              -0.315          3.068      -0.41       1.95  0.019602
#
#      r2020B02  r2020B03  r2020B04  r2020B05  r2020B06  r2020B07  r2020B08  \
# 0    0.035344  0.028616  0.254417  0.175280  0.086611  0.797761 -0.749311
# 1    0.033537  0.022230  0.189826  0.092225  0.047120  0.789129 -0.705355
# 2    0.035957  0.021190  0.204363  0.093062  0.043824  0.812120 -0.704758
# 3    0.033868  0.025284  0.187998  0.102872  0.048585  0.762431 -0.695416
# 4    0.036153  0.024911  0.216271  0.096981  0.044880  0.793606 -0.717562
# ..        ...       ...       ...       ...       ...       ...       ...
# 193  0.033500  0.024009  0.183141  0.087021  0.041353  0.768626 -0.690308
# 194  0.033282  0.023425  0.213063  0.097829  0.043719  0.801855 -0.724049
# 195  0.035577  0.028173  0.180433  0.099119  0.050874  0.730297 -0.679586
# 196  0.036504  0.025100  0.219419  0.111967  0.051884  0.794534 -0.709182
# 197  0.032982  0.024029  0.187890  0.088149  0.042660  0.773055 -0.701580
#
#      r2020B09   r2020B10   r2020B11  r2020B12
# 0    0.491270 -15.527246 -11.385074  0.733806
# 1    0.659775 -16.547673 -10.947565  0.661723
# 2    0.631348 -14.341917 -11.884799  0.829603
# 3    0.601894 -14.885610 -11.725163  0.787609
# 4    0.642942 -14.647913 -11.512282  0.785698
# ..        ...        ...        ...       ...
# 193  0.647180 -15.082615  -8.697043  0.576864
# 194  0.616405 -13.816830 -11.614223  0.840547
# 195  0.568144 -17.216035 -10.492416  0.609540
# 196  0.601278 -14.444945 -11.085873  0.771277
# 197  0.607420 -13.819343 -10.713423  0.775819
#
# [198 rows x 20 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    r2020B04  r2020B08  r2020B09   r2020B10   r2020B11
# 0  0.254417 -0.749311  0.491270 -15.527246 -11.385074
# 1  0.189826 -0.705355  0.659775 -16.547673 -10.947565
# 2  0.204363 -0.704758  0.631348 -14.341917 -11.884799
# 3  0.187998 -0.695416  0.601894 -14.885610 -11.725163
# 4  0.216271 -0.717562  0.642942 -14.647913 -11.512282

# %%
# Columns in "y" data collections
y.head()
# Out:
#    LN_Tag_Cs
# 0      -0.73
# 1       0.59
# 2       0.78
# 3       0.52
# 4       0.22

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [-0.17033651990831267, -0.19713344201566207, -0.021972699467242673]
#     Mean: -0.130
#     Std: 0.077
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.31576974 1.08861624 1.30619978]
#     Mean: 1.237
#     Std: 0.105
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.886182922732198, 0.9991264933844409, 1.0075884119522842]
#     Mean: 0.964
#     Std: 0.055
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.4542911037377255                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.46044759309663835                 # gamma
print('Gamma: ' + str(p2))

p3 = 0.012797644174607761                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2            # max_depth
print('Max_depth: ' + str(p4))

p5 = 112          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.43096929834660513                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.4542911037377255
# Gamma: 0.46044759309663835
# Learning_rate: 0.012797644174607761
# Max_depth: 2
# N_estimators: 112
# Subsample: 0.43096929834660513

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.63480	validation_1-rmse:1.59961
# [1]	validation_0-rmse:1.62488	validation_1-rmse:1.59132
# [2]	validation_0-rmse:1.61508	validation_1-rmse:1.58235
# [3]	validation_0-rmse:1.60370	validation_1-rmse:1.57437
# [4]	validation_0-rmse:1.59315	validation_1-rmse:1.56702
# [5]	validation_0-rmse:1.58413	validation_1-rmse:1.55676
# [6]	validation_0-rmse:1.57384	validation_1-rmse:1.54878
# [7]	validation_0-rmse:1.56545	validation_1-rmse:1.54306
# [8]	validation_0-rmse:1.55600	validation_1-rmse:1.53471
# [9]	validation_0-rmse:1.54760	validation_1-rmse:1.52858
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [10]	validation_0-rmse:1.53862	validation_1-rmse:1.52231
# [11]	validation_0-rmse:1.53120	validation_1-rmse:1.51612
# [12]	validation_0-rmse:1.52220	validation_1-rmse:1.50811
# [13]	validation_0-rmse:1.51356	validation_1-rmse:1.50328
# [14]	validation_0-rmse:1.50501	validation_1-rmse:1.49540
# [15]	validation_0-rmse:1.49832	validation_1-rmse:1.48958
# [16]	validation_0-rmse:1.48997	validation_1-rmse:1.48144
# [17]	validation_0-rmse:1.48219	validation_1-rmse:1.47429
# [18]	validation_0-rmse:1.47210	validation_1-rmse:1.46748
# [19]	validation_0-rmse:1.46533	validation_1-rmse:1.46263
# [20]	validation_0-rmse:1.45787	validation_1-rmse:1.45800
# [21]	validation_0-rmse:1.45218	validation_1-rmse:1.45424
# [22]	validation_0-rmse:1.44456	validation_1-rmse:1.44799
# [23]	validation_0-rmse:1.43786	validation_1-rmse:1.44087
# [24]	validation_0-rmse:1.43080	validation_1-rmse:1.43586
# [25]	validation_0-rmse:1.42344	validation_1-rmse:1.43224
# [26]	validation_0-rmse:1.41521	validation_1-rmse:1.42612
# [27]	validation_0-rmse:1.40813	validation_1-rmse:1.42029
# [28]	validation_0-rmse:1.40151	validation_1-rmse:1.41531
# [29]	validation_0-rmse:1.39531	validation_1-rmse:1.41163
# [30]	validation_0-rmse:1.38934	validation_1-rmse:1.40679
# [31]	validation_0-rmse:1.38317	validation_1-rmse:1.40388
# [32]	validation_0-rmse:1.37669	validation_1-rmse:1.39959
# [33]	validation_0-rmse:1.36953	validation_1-rmse:1.39410
# [34]	validation_0-rmse:1.36430	validation_1-rmse:1.39109
# [35]	validation_0-rmse:1.35638	validation_1-rmse:1.38517
# [36]	validation_0-rmse:1.35156	validation_1-rmse:1.38255
# [37]	validation_0-rmse:1.34563	validation_1-rmse:1.37900
# [38]	validation_0-rmse:1.34063	validation_1-rmse:1.37480
# [39]	validation_0-rmse:1.33538	validation_1-rmse:1.37111
# [40]	validation_0-rmse:1.33043	validation_1-rmse:1.36780
# [41]	validation_0-rmse:1.32429	validation_1-rmse:1.36422
# [42]	validation_0-rmse:1.32087	validation_1-rmse:1.36331
# [43]	validation_0-rmse:1.31476	validation_1-rmse:1.35932
# [44]	validation_0-rmse:1.30905	validation_1-rmse:1.35628
# [45]	validation_0-rmse:1.30268	validation_1-rmse:1.35035
# [46]	validation_0-rmse:1.29837	validation_1-rmse:1.34755
# [47]	validation_0-rmse:1.29370	validation_1-rmse:1.34482
# [48]	validation_0-rmse:1.28820	validation_1-rmse:1.34170
# [49]	validation_0-rmse:1.28246	validation_1-rmse:1.33765
# [50]	validation_0-rmse:1.27645	validation_1-rmse:1.33449
# [51]	validation_0-rmse:1.27241	validation_1-rmse:1.33278
# [52]	validation_0-rmse:1.26762	validation_1-rmse:1.33003
# [53]	validation_0-rmse:1.26518	validation_1-rmse:1.32733
# [54]	validation_0-rmse:1.26122	validation_1-rmse:1.32512
# [55]	validation_0-rmse:1.25564	validation_1-rmse:1.32174
# [56]	validation_0-rmse:1.25155	validation_1-rmse:1.31995
# [57]	validation_0-rmse:1.24514	validation_1-rmse:1.31762
# [58]	validation_0-rmse:1.24045	validation_1-rmse:1.31338
# [59]	validation_0-rmse:1.23675	validation_1-rmse:1.31201
# [60]	validation_0-rmse:1.23348	validation_1-rmse:1.31000
# [61]	validation_0-rmse:1.23035	validation_1-rmse:1.30890
# [62]	validation_0-rmse:1.22646	validation_1-rmse:1.30686
# [63]	validation_0-rmse:1.22191	validation_1-rmse:1.30345
# [64]	validation_0-rmse:1.21661	validation_1-rmse:1.29978
# [65]	validation_0-rmse:1.21335	validation_1-rmse:1.29753
# [66]	validation_0-rmse:1.21010	validation_1-rmse:1.29557
# [67]	validation_0-rmse:1.20678	validation_1-rmse:1.29411
# [68]	validation_0-rmse:1.20369	validation_1-rmse:1.29347
# [69]	validation_0-rmse:1.19983	validation_1-rmse:1.29183
# [70]	validation_0-rmse:1.19645	validation_1-rmse:1.29077
# [71]	validation_0-rmse:1.19293	validation_1-rmse:1.29012
# [72]	validation_0-rmse:1.18995	validation_1-rmse:1.28866
# [73]	validation_0-rmse:1.18544	validation_1-rmse:1.28596
# [74]	validation_0-rmse:1.18200	validation_1-rmse:1.28310
# [75]	validation_0-rmse:1.17875	validation_1-rmse:1.28086
# [76]	validation_0-rmse:1.17557	validation_1-rmse:1.28042
# [77]	validation_0-rmse:1.17216	validation_1-rmse:1.27870
# [78]	validation_0-rmse:1.16813	validation_1-rmse:1.27783
# [79]	validation_0-rmse:1.16432	validation_1-rmse:1.27659
# [80]	validation_0-rmse:1.16088	validation_1-rmse:1.27629
# [81]	validation_0-rmse:1.15823	validation_1-rmse:1.27395
# [82]	validation_0-rmse:1.15452	validation_1-rmse:1.27171
# [83]	validation_0-rmse:1.15162	validation_1-rmse:1.27135
# [84]	validation_0-rmse:1.14895	validation_1-rmse:1.27003
# [85]	validation_0-rmse:1.14672	validation_1-rmse:1.26965
# [86]	validation_0-rmse:1.14475	validation_1-rmse:1.26907
# [87]	validation_0-rmse:1.14252	validation_1-rmse:1.26898
# [88]	validation_0-rmse:1.14026	validation_1-rmse:1.26964
# [89]	validation_0-rmse:1.13696	validation_1-rmse:1.26840
# [90]	validation_0-rmse:1.13389	validation_1-rmse:1.26780
# [91]	validation_0-rmse:1.13077	validation_1-rmse:1.26819
# [92]	validation_0-rmse:1.12788	validation_1-rmse:1.26759
# [93]	validation_0-rmse:1.12579	validation_1-rmse:1.26733
# [94]	validation_0-rmse:1.12379	validation_1-rmse:1.26731
# [95]	validation_0-rmse:1.12083	validation_1-rmse:1.26592
# [96]	validation_0-rmse:1.11878	validation_1-rmse:1.26570
# [97]	validation_0-rmse:1.11734	validation_1-rmse:1.26452
# [98]	validation_0-rmse:1.11487	validation_1-rmse:1.26411
# [99]	validation_0-rmse:1.11358	validation_1-rmse:1.26364
# [100]	validation_0-rmse:1.11218	validation_1-rmse:1.26503
# [101]	validation_0-rmse:1.11138	validation_1-rmse:1.26542
# [102]	validation_0-rmse:1.10875	validation_1-rmse:1.26576
# [103]	validation_0-rmse:1.10619	validation_1-rmse:1.26608
# [104]	validation_0-rmse:1.10401	validation_1-rmse:1.26462
# [105]	validation_0-rmse:1.10194	validation_1-rmse:1.26337
# [106]	validation_0-rmse:1.10005	validation_1-rmse:1.26310
# [107]	validation_0-rmse:1.09735	validation_1-rmse:1.26274
# [108]	validation_0-rmse:1.09505	validation_1-rmse:1.26242
# [109]	validation_0-rmse:1.09320	validation_1-rmse:1.26237
# [110]	validation_0-rmse:1.09105	validation_1-rmse:1.26292
# [111]	validation_0-rmse:1.08957	validation_1-rmse:1.26287
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.65892	validation_1-rmse:1.51038
# [1]	validation_0-rmse:1.64970	validation_1-rmse:1.50149
# [2]	validation_0-rmse:1.64050	validation_1-rmse:1.49174
# [3]	validation_0-rmse:1.62985	validation_1-rmse:1.48039
# [4]	validation_0-rmse:1.62038	validation_1-rmse:1.47148
# [5]	validation_0-rmse:1.61150	validation_1-rmse:1.46457
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:1.60329	validation_1-rmse:1.45740
# [7]	validation_0-rmse:1.59419	validation_1-rmse:1.44478
# [8]	validation_0-rmse:1.58403	validation_1-rmse:1.43286
# [9]	validation_0-rmse:1.57412	validation_1-rmse:1.42489
# [10]	validation_0-rmse:1.56437	validation_1-rmse:1.41555
# [11]	validation_0-rmse:1.55468	validation_1-rmse:1.40514
# [12]	validation_0-rmse:1.54459	validation_1-rmse:1.39606
# [13]	validation_0-rmse:1.53626	validation_1-rmse:1.38682
# [14]	validation_0-rmse:1.52927	validation_1-rmse:1.38122
# [15]	validation_0-rmse:1.51878	validation_1-rmse:1.37070
# [16]	validation_0-rmse:1.51030	validation_1-rmse:1.36498
# [17]	validation_0-rmse:1.50143	validation_1-rmse:1.35542
# [18]	validation_0-rmse:1.49325	validation_1-rmse:1.34952
# [19]	validation_0-rmse:1.48538	validation_1-rmse:1.34147
# [20]	validation_0-rmse:1.47907	validation_1-rmse:1.33288
# [21]	validation_0-rmse:1.47172	validation_1-rmse:1.32762
# [22]	validation_0-rmse:1.46477	validation_1-rmse:1.31917
# [23]	validation_0-rmse:1.45911	validation_1-rmse:1.31463
# [24]	validation_0-rmse:1.45044	validation_1-rmse:1.30690
# [25]	validation_0-rmse:1.44346	validation_1-rmse:1.29943
# [26]	validation_0-rmse:1.43689	validation_1-rmse:1.29271
# [27]	validation_0-rmse:1.43201	validation_1-rmse:1.28937
# [28]	validation_0-rmse:1.42778	validation_1-rmse:1.28602
# [29]	validation_0-rmse:1.42057	validation_1-rmse:1.27746
# [30]	validation_0-rmse:1.41575	validation_1-rmse:1.27155
# [31]	validation_0-rmse:1.40960	validation_1-rmse:1.26476
# [32]	validation_0-rmse:1.40242	validation_1-rmse:1.26100
# [33]	validation_0-rmse:1.39795	validation_1-rmse:1.25643
# [34]	validation_0-rmse:1.39276	validation_1-rmse:1.25289
# [35]	validation_0-rmse:1.38742	validation_1-rmse:1.24552
# [36]	validation_0-rmse:1.38342	validation_1-rmse:1.24263
# [37]	validation_0-rmse:1.37661	validation_1-rmse:1.23952
# [38]	validation_0-rmse:1.37160	validation_1-rmse:1.23529
# [39]	validation_0-rmse:1.36536	validation_1-rmse:1.23133
# [40]	validation_0-rmse:1.35913	validation_1-rmse:1.22620
# [41]	validation_0-rmse:1.35290	validation_1-rmse:1.22288
# [42]	validation_0-rmse:1.34753	validation_1-rmse:1.21938
# [43]	validation_0-rmse:1.34280	validation_1-rmse:1.21611
# [44]	validation_0-rmse:1.33787	validation_1-rmse:1.21250
# [45]	validation_0-rmse:1.33290	validation_1-rmse:1.21057
# [46]	validation_0-rmse:1.32876	validation_1-rmse:1.20542
# [47]	validation_0-rmse:1.32485	validation_1-rmse:1.20378
# [48]	validation_0-rmse:1.32061	validation_1-rmse:1.19851
# [49]	validation_0-rmse:1.31668	validation_1-rmse:1.19355
# [50]	validation_0-rmse:1.31212	validation_1-rmse:1.18958
# [51]	validation_0-rmse:1.30764	validation_1-rmse:1.18591
# [52]	validation_0-rmse:1.30379	validation_1-rmse:1.18291
# [53]	validation_0-rmse:1.29942	validation_1-rmse:1.17905
# [54]	validation_0-rmse:1.29475	validation_1-rmse:1.17651
# [55]	validation_0-rmse:1.29083	validation_1-rmse:1.17678
# [56]	validation_0-rmse:1.28807	validation_1-rmse:1.17417
# [57]	validation_0-rmse:1.28511	validation_1-rmse:1.17270
# [58]	validation_0-rmse:1.28305	validation_1-rmse:1.17055
# [59]	validation_0-rmse:1.27990	validation_1-rmse:1.16929
# [60]	validation_0-rmse:1.27600	validation_1-rmse:1.16561
# [61]	validation_0-rmse:1.27171	validation_1-rmse:1.15995
# [62]	validation_0-rmse:1.26806	validation_1-rmse:1.15810
# [63]	validation_0-rmse:1.26420	validation_1-rmse:1.15597
# [64]	validation_0-rmse:1.25989	validation_1-rmse:1.15227
# [65]	validation_0-rmse:1.25706	validation_1-rmse:1.14823
# [66]	validation_0-rmse:1.25377	validation_1-rmse:1.14644
# [67]	validation_0-rmse:1.24903	validation_1-rmse:1.14368
# [68]	validation_0-rmse:1.24501	validation_1-rmse:1.14095
# [69]	validation_0-rmse:1.24137	validation_1-rmse:1.13968
# [70]	validation_0-rmse:1.23791	validation_1-rmse:1.13469
# [71]	validation_0-rmse:1.23489	validation_1-rmse:1.13242
# [72]	validation_0-rmse:1.23344	validation_1-rmse:1.13124
# [73]	validation_0-rmse:1.23003	validation_1-rmse:1.12658
# [74]	validation_0-rmse:1.22739	validation_1-rmse:1.12572
# [75]	validation_0-rmse:1.22505	validation_1-rmse:1.12302
# [76]	validation_0-rmse:1.22269	validation_1-rmse:1.12252
# [77]	validation_0-rmse:1.21953	validation_1-rmse:1.12103
# [78]	validation_0-rmse:1.21689	validation_1-rmse:1.11835
# [79]	validation_0-rmse:1.21402	validation_1-rmse:1.11733
# [80]	validation_0-rmse:1.20982	validation_1-rmse:1.11525
# [81]	validation_0-rmse:1.20701	validation_1-rmse:1.11448
# [82]	validation_0-rmse:1.20345	validation_1-rmse:1.11097
# [83]	validation_0-rmse:1.20035	validation_1-rmse:1.10850
# [84]	validation_0-rmse:1.19689	validation_1-rmse:1.10470
# [85]	validation_0-rmse:1.19372	validation_1-rmse:1.10213
# [86]	validation_0-rmse:1.19085	validation_1-rmse:1.10076
# [87]	validation_0-rmse:1.18847	validation_1-rmse:1.09830
# [88]	validation_0-rmse:1.18655	validation_1-rmse:1.09786
# [89]	validation_0-rmse:1.18348	validation_1-rmse:1.09305
# [90]	validation_0-rmse:1.18127	validation_1-rmse:1.08931
# [91]	validation_0-rmse:1.17792	validation_1-rmse:1.08511
# [92]	validation_0-rmse:1.17590	validation_1-rmse:1.08187
# [93]	validation_0-rmse:1.17370	validation_1-rmse:1.08127
# [94]	validation_0-rmse:1.17174	validation_1-rmse:1.07890
# [95]	validation_0-rmse:1.16849	validation_1-rmse:1.07737
# [96]	validation_0-rmse:1.16662	validation_1-rmse:1.07711
# [97]	validation_0-rmse:1.16477	validation_1-rmse:1.07551
# [98]	validation_0-rmse:1.16192	validation_1-rmse:1.07450
# [99]	validation_0-rmse:1.16026	validation_1-rmse:1.07250
# [100]	validation_0-rmse:1.15815	validation_1-rmse:1.07082
# [101]	validation_0-rmse:1.15628	validation_1-rmse:1.06936
# [102]	validation_0-rmse:1.15421	validation_1-rmse:1.06885
# [103]	validation_0-rmse:1.15214	validation_1-rmse:1.06831
# [104]	validation_0-rmse:1.15039	validation_1-rmse:1.06795
# [105]	validation_0-rmse:1.14768	validation_1-rmse:1.06602
# [106]	validation_0-rmse:1.14580	validation_1-rmse:1.06543
# [107]	validation_0-rmse:1.14408	validation_1-rmse:1.06262
# [108]	validation_0-rmse:1.14264	validation_1-rmse:1.06188
# [109]	validation_0-rmse:1.14083	validation_1-rmse:1.06151
# [110]	validation_0-rmse:1.13928	validation_1-rmse:1.06111
# [111]	validation_0-rmse:1.13716	validation_1-rmse:1.06032
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.57051	validation_1-rmse:1.84208
# [1]	validation_0-rmse:1.56269	validation_1-rmse:1.83414
# [2]	validation_0-rmse:1.55292	validation_1-rmse:1.82489
# [3]	validation_0-rmse:1.54206	validation_1-rmse:1.81451
# [4]	validation_0-rmse:1.53129	validation_1-rmse:1.80670
# [5]	validation_0-rmse:1.52155	validation_1-rmse:1.79875
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:1.51195	validation_1-rmse:1.78878
# [7]	validation_0-rmse:1.50452	validation_1-rmse:1.78255
# [8]	validation_0-rmse:1.49477	validation_1-rmse:1.77381
# [9]	validation_0-rmse:1.48455	validation_1-rmse:1.76463
# [10]	validation_0-rmse:1.47523	validation_1-rmse:1.75441
# [11]	validation_0-rmse:1.46802	validation_1-rmse:1.74794
# [12]	validation_0-rmse:1.46041	validation_1-rmse:1.74094
# [13]	validation_0-rmse:1.44893	validation_1-rmse:1.72973
# [14]	validation_0-rmse:1.44234	validation_1-rmse:1.72503
# [15]	validation_0-rmse:1.43492	validation_1-rmse:1.71835
# [16]	validation_0-rmse:1.42548	validation_1-rmse:1.71005
# [17]	validation_0-rmse:1.41941	validation_1-rmse:1.70201
# [18]	validation_0-rmse:1.41144	validation_1-rmse:1.69487
# [19]	validation_0-rmse:1.40460	validation_1-rmse:1.68849
# [20]	validation_0-rmse:1.39766	validation_1-rmse:1.68215
# [21]	validation_0-rmse:1.38933	validation_1-rmse:1.67527
# [22]	validation_0-rmse:1.38212	validation_1-rmse:1.67165
# [23]	validation_0-rmse:1.37607	validation_1-rmse:1.66474
# [24]	validation_0-rmse:1.36762	validation_1-rmse:1.65779
# [25]	validation_0-rmse:1.35975	validation_1-rmse:1.65085
# [26]	validation_0-rmse:1.35373	validation_1-rmse:1.64689
# [27]	validation_0-rmse:1.34881	validation_1-rmse:1.64309
# [28]	validation_0-rmse:1.34019	validation_1-rmse:1.63449
# [29]	validation_0-rmse:1.33515	validation_1-rmse:1.62997
# [30]	validation_0-rmse:1.32886	validation_1-rmse:1.62454
# [31]	validation_0-rmse:1.32304	validation_1-rmse:1.61963
# [32]	validation_0-rmse:1.31709	validation_1-rmse:1.61311
# [33]	validation_0-rmse:1.31166	validation_1-rmse:1.60666
# [34]	validation_0-rmse:1.30709	validation_1-rmse:1.60077
# [35]	validation_0-rmse:1.30226	validation_1-rmse:1.59979
# [36]	validation_0-rmse:1.29885	validation_1-rmse:1.59780
# [37]	validation_0-rmse:1.29289	validation_1-rmse:1.59291
# [38]	validation_0-rmse:1.28755	validation_1-rmse:1.58937
# [39]	validation_0-rmse:1.28187	validation_1-rmse:1.58224
# [40]	validation_0-rmse:1.27542	validation_1-rmse:1.57556
# [41]	validation_0-rmse:1.27056	validation_1-rmse:1.57176
# [42]	validation_0-rmse:1.26582	validation_1-rmse:1.56716
# [43]	validation_0-rmse:1.25982	validation_1-rmse:1.56119
# [44]	validation_0-rmse:1.25441	validation_1-rmse:1.55807
# [45]	validation_0-rmse:1.25023	validation_1-rmse:1.55558
# [46]	validation_0-rmse:1.24616	validation_1-rmse:1.55238
# [47]	validation_0-rmse:1.24200	validation_1-rmse:1.54716
# [48]	validation_0-rmse:1.23750	validation_1-rmse:1.54173
# [49]	validation_0-rmse:1.23327	validation_1-rmse:1.53662
# [50]	validation_0-rmse:1.22921	validation_1-rmse:1.53306
# [51]	validation_0-rmse:1.22671	validation_1-rmse:1.52966
# [52]	validation_0-rmse:1.22267	validation_1-rmse:1.52538
# [53]	validation_0-rmse:1.21907	validation_1-rmse:1.52036
# [54]	validation_0-rmse:1.21512	validation_1-rmse:1.51698
# [55]	validation_0-rmse:1.21179	validation_1-rmse:1.51228
# [56]	validation_0-rmse:1.20874	validation_1-rmse:1.51006
# [57]	validation_0-rmse:1.20559	validation_1-rmse:1.50675
# [58]	validation_0-rmse:1.20094	validation_1-rmse:1.50270
# [59]	validation_0-rmse:1.19732	validation_1-rmse:1.49973
# [60]	validation_0-rmse:1.19303	validation_1-rmse:1.49644
# [61]	validation_0-rmse:1.18952	validation_1-rmse:1.49393
# [62]	validation_0-rmse:1.18644	validation_1-rmse:1.49106
# [63]	validation_0-rmse:1.18180	validation_1-rmse:1.48798
# [64]	validation_0-rmse:1.17735	validation_1-rmse:1.48485
# [65]	validation_0-rmse:1.17502	validation_1-rmse:1.48325
# [66]	validation_0-rmse:1.17263	validation_1-rmse:1.48029
# [67]	validation_0-rmse:1.16907	validation_1-rmse:1.47598
# [68]	validation_0-rmse:1.16615	validation_1-rmse:1.47295
# [69]	validation_0-rmse:1.16264	validation_1-rmse:1.47135
# [70]	validation_0-rmse:1.15890	validation_1-rmse:1.46911
# [71]	validation_0-rmse:1.15449	validation_1-rmse:1.46644
# [72]	validation_0-rmse:1.15185	validation_1-rmse:1.46436
# [73]	validation_0-rmse:1.14880	validation_1-rmse:1.46161
# [74]	validation_0-rmse:1.14610	validation_1-rmse:1.45901
# [75]	validation_0-rmse:1.14399	validation_1-rmse:1.45787
# [76]	validation_0-rmse:1.14062	validation_1-rmse:1.45534
# [77]	validation_0-rmse:1.13815	validation_1-rmse:1.45228
# [78]	validation_0-rmse:1.13445	validation_1-rmse:1.44921
# [79]	validation_0-rmse:1.12982	validation_1-rmse:1.44610
# [80]	validation_0-rmse:1.12789	validation_1-rmse:1.44549
# [81]	validation_0-rmse:1.12595	validation_1-rmse:1.44347
# [82]	validation_0-rmse:1.12259	validation_1-rmse:1.44193
# [83]	validation_0-rmse:1.11943	validation_1-rmse:1.43894
# [84]	validation_0-rmse:1.11684	validation_1-rmse:1.43757
# [85]	validation_0-rmse:1.11510	validation_1-rmse:1.43683
# [86]	validation_0-rmse:1.11179	validation_1-rmse:1.43487
# [87]	validation_0-rmse:1.10970	validation_1-rmse:1.43394
# [88]	validation_0-rmse:1.10801	validation_1-rmse:1.43400
# [89]	validation_0-rmse:1.10431	validation_1-rmse:1.43313
# [90]	validation_0-rmse:1.10166	validation_1-rmse:1.43121
# [91]	validation_0-rmse:1.09945	validation_1-rmse:1.43002
# [92]	validation_0-rmse:1.09728	validation_1-rmse:1.42865
# [93]	validation_0-rmse:1.09474	validation_1-rmse:1.42731
# [94]	validation_0-rmse:1.09237	validation_1-rmse:1.42554
# [95]	validation_0-rmse:1.08999	validation_1-rmse:1.42408
# [96]	validation_0-rmse:1.08833	validation_1-rmse:1.42322
# [97]	validation_0-rmse:1.08577	validation_1-rmse:1.42059
# [98]	validation_0-rmse:1.08355	validation_1-rmse:1.41835
# [99]	validation_0-rmse:1.08176	validation_1-rmse:1.41700
# [100]	validation_0-rmse:1.07983	validation_1-rmse:1.41658
# [101]	validation_0-rmse:1.07799	validation_1-rmse:1.41495
# [102]	validation_0-rmse:1.07690	validation_1-rmse:1.41412
# [103]	validation_0-rmse:1.07447	validation_1-rmse:1.41152
# [104]	validation_0-rmse:1.07269	validation_1-rmse:1.41106
# [105]	validation_0-rmse:1.07121	validation_1-rmse:1.40969
# [106]	validation_0-rmse:1.06942	validation_1-rmse:1.40843
# [107]	validation_0-rmse:1.06760	validation_1-rmse:1.40770
# [108]	validation_0-rmse:1.06471	validation_1-rmse:1.40627
# [109]	validation_0-rmse:1.06358	validation_1-rmse:1.40443
# [110]	validation_0-rmse:1.06246	validation_1-rmse:1.40417
# [111]	validation_0-rmse:1.06009	validation_1-rmse:1.40301
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.64741	validation_1-rmse:1.56017
# [1]	validation_0-rmse:1.63609	validation_1-rmse:1.54941
# [2]	validation_0-rmse:1.62596	validation_1-rmse:1.53965
# [3]	validation_0-rmse:1.61587	validation_1-rmse:1.53053
# [4]	validation_0-rmse:1.60598	validation_1-rmse:1.52074
# [5]	validation_0-rmse:1.59679	validation_1-rmse:1.51102
# [6]	validation_0-rmse:1.58835	validation_1-rmse:1.50253
# [7]	validation_0-rmse:1.58018	validation_1-rmse:1.49599
# [8]	validation_0-rmse:1.57175	validation_1-rmse:1.48879
# [9]	validation_0-rmse:1.56218	validation_1-rmse:1.48011
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [10]	validation_0-rmse:1.55429	validation_1-rmse:1.47317
# [11]	validation_0-rmse:1.54580	validation_1-rmse:1.46531
# [12]	validation_0-rmse:1.53937	validation_1-rmse:1.45865
# [13]	validation_0-rmse:1.53145	validation_1-rmse:1.45138
# [14]	validation_0-rmse:1.52426	validation_1-rmse:1.44609
# [15]	validation_0-rmse:1.51747	validation_1-rmse:1.44002
# [16]	validation_0-rmse:1.50874	validation_1-rmse:1.43323
# [17]	validation_0-rmse:1.50025	validation_1-rmse:1.42756
# [18]	validation_0-rmse:1.49393	validation_1-rmse:1.42341
# [19]	validation_0-rmse:1.48649	validation_1-rmse:1.41626
# [20]	validation_0-rmse:1.47842	validation_1-rmse:1.40890
# [21]	validation_0-rmse:1.47131	validation_1-rmse:1.40280
# [22]	validation_0-rmse:1.46399	validation_1-rmse:1.39685
# [23]	validation_0-rmse:1.45669	validation_1-rmse:1.39037
# [24]	validation_0-rmse:1.45020	validation_1-rmse:1.38581
# [25]	validation_0-rmse:1.44369	validation_1-rmse:1.38050
# [26]	validation_0-rmse:1.43568	validation_1-rmse:1.37562
# [27]	validation_0-rmse:1.42927	validation_1-rmse:1.36979
# [28]	validation_0-rmse:1.42347	validation_1-rmse:1.36336
# [29]	validation_0-rmse:1.41669	validation_1-rmse:1.35676
# [30]	validation_0-rmse:1.41058	validation_1-rmse:1.35254
# [31]	validation_0-rmse:1.40339	validation_1-rmse:1.34608
# [32]	validation_0-rmse:1.39564	validation_1-rmse:1.33786
# [33]	validation_0-rmse:1.38903	validation_1-rmse:1.33592
# [34]	validation_0-rmse:1.38092	validation_1-rmse:1.33257
# [35]	validation_0-rmse:1.37623	validation_1-rmse:1.32894
# [36]	validation_0-rmse:1.37351	validation_1-rmse:1.32653
# [37]	validation_0-rmse:1.36796	validation_1-rmse:1.32027
# [38]	validation_0-rmse:1.36333	validation_1-rmse:1.31565
# [39]	validation_0-rmse:1.35799	validation_1-rmse:1.31063
# [40]	validation_0-rmse:1.35220	validation_1-rmse:1.30759
# [41]	validation_0-rmse:1.34757	validation_1-rmse:1.30490
# [42]	validation_0-rmse:1.34221	validation_1-rmse:1.30121
# [43]	validation_0-rmse:1.33725	validation_1-rmse:1.29714
# [44]	validation_0-rmse:1.33020	validation_1-rmse:1.29015
# [45]	validation_0-rmse:1.32424	validation_1-rmse:1.28540
# [46]	validation_0-rmse:1.32001	validation_1-rmse:1.28078
# [47]	validation_0-rmse:1.31608	validation_1-rmse:1.27780
# [48]	validation_0-rmse:1.31315	validation_1-rmse:1.27528
# [49]	validation_0-rmse:1.30908	validation_1-rmse:1.27104
# [50]	validation_0-rmse:1.30462	validation_1-rmse:1.26625
# [51]	validation_0-rmse:1.30006	validation_1-rmse:1.26218
# [52]	validation_0-rmse:1.29622	validation_1-rmse:1.26013
# [53]	validation_0-rmse:1.29262	validation_1-rmse:1.25633
# [54]	validation_0-rmse:1.28781	validation_1-rmse:1.25504
# [55]	validation_0-rmse:1.28359	validation_1-rmse:1.25039
# [56]	validation_0-rmse:1.27953	validation_1-rmse:1.24672
# [57]	validation_0-rmse:1.27488	validation_1-rmse:1.24290
# [58]	validation_0-rmse:1.27213	validation_1-rmse:1.24093
# [59]	validation_0-rmse:1.26809	validation_1-rmse:1.23749
# [60]	validation_0-rmse:1.26418	validation_1-rmse:1.23686
# [61]	validation_0-rmse:1.25925	validation_1-rmse:1.23357
# [62]	validation_0-rmse:1.25501	validation_1-rmse:1.23313
# [63]	validation_0-rmse:1.25165	validation_1-rmse:1.22970
# [64]	validation_0-rmse:1.24839	validation_1-rmse:1.22774
# [65]	validation_0-rmse:1.24631	validation_1-rmse:1.22491
# [66]	validation_0-rmse:1.24323	validation_1-rmse:1.22136
# [67]	validation_0-rmse:1.24118	validation_1-rmse:1.21992
# [68]	validation_0-rmse:1.23725	validation_1-rmse:1.21877
# [69]	validation_0-rmse:1.23421	validation_1-rmse:1.21670
# [70]	validation_0-rmse:1.23166	validation_1-rmse:1.21458
# [71]	validation_0-rmse:1.22968	validation_1-rmse:1.21495
# [72]	validation_0-rmse:1.22545	validation_1-rmse:1.21233
# [73]	validation_0-rmse:1.22137	validation_1-rmse:1.21026
# [74]	validation_0-rmse:1.21806	validation_1-rmse:1.20889
# [75]	validation_0-rmse:1.21568	validation_1-rmse:1.20711
# [76]	validation_0-rmse:1.21146	validation_1-rmse:1.20409
# [77]	validation_0-rmse:1.20820	validation_1-rmse:1.20007
# [78]	validation_0-rmse:1.20542	validation_1-rmse:1.19878
# [79]	validation_0-rmse:1.20356	validation_1-rmse:1.19663
# [80]	validation_0-rmse:1.20022	validation_1-rmse:1.19485
# [81]	validation_0-rmse:1.19729	validation_1-rmse:1.19308
# [82]	validation_0-rmse:1.19443	validation_1-rmse:1.19200
# [83]	validation_0-rmse:1.19133	validation_1-rmse:1.18915
# [84]	validation_0-rmse:1.18930	validation_1-rmse:1.18945
# [85]	validation_0-rmse:1.18726	validation_1-rmse:1.18693
# [86]	validation_0-rmse:1.18487	validation_1-rmse:1.18556
# [87]	validation_0-rmse:1.18255	validation_1-rmse:1.18450
# [88]	validation_0-rmse:1.18005	validation_1-rmse:1.18521
# [89]	validation_0-rmse:1.17689	validation_1-rmse:1.18236
# [90]	validation_0-rmse:1.17460	validation_1-rmse:1.18181
# [91]	validation_0-rmse:1.17268	validation_1-rmse:1.18187
# [92]	validation_0-rmse:1.17126	validation_1-rmse:1.18179
# [93]	validation_0-rmse:1.16972	validation_1-rmse:1.18001
# [94]	validation_0-rmse:1.16771	validation_1-rmse:1.17812
# [95]	validation_0-rmse:1.16494	validation_1-rmse:1.17605
# [96]	validation_0-rmse:1.16440	validation_1-rmse:1.17671
# [97]	validation_0-rmse:1.16217	validation_1-rmse:1.17510
# [98]	validation_0-rmse:1.15969	validation_1-rmse:1.17425
# [99]	validation_0-rmse:1.15757	validation_1-rmse:1.17158
# [100]	validation_0-rmse:1.15554	validation_1-rmse:1.17192
# [101]	validation_0-rmse:1.15401	validation_1-rmse:1.17030
# [102]	validation_0-rmse:1.15179	validation_1-rmse:1.16996
# [103]	validation_0-rmse:1.14957	validation_1-rmse:1.16772
# [104]	validation_0-rmse:1.14791	validation_1-rmse:1.16648
# [105]	validation_0-rmse:1.14645	validation_1-rmse:1.16516
# [106]	validation_0-rmse:1.14426	validation_1-rmse:1.16547
# [107]	validation_0-rmse:1.14263	validation_1-rmse:1.16380
# [108]	validation_0-rmse:1.14000	validation_1-rmse:1.16323
# [109]	validation_0-rmse:1.13867	validation_1-rmse:1.16166
# [110]	validation_0-rmse:1.13672	validation_1-rmse:1.16131
# [111]	validation_0-rmse:1.13465	validation_1-rmse:1.15993
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.58884	validation_1-rmse:1.78262
# [1]	validation_0-rmse:1.57928	validation_1-rmse:1.77540
# [2]	validation_0-rmse:1.57045	validation_1-rmse:1.76711
# [3]	validation_0-rmse:1.55999	validation_1-rmse:1.75478
# [4]	validation_0-rmse:1.55111	validation_1-rmse:1.74521
# [5]	validation_0-rmse:1.54441	validation_1-rmse:1.73979
# [6]	validation_0-rmse:1.53660	validation_1-rmse:1.73164
# [7]	validation_0-rmse:1.52819	validation_1-rmse:1.72392
# [8]	validation_0-rmse:1.51918	validation_1-rmse:1.71421
# [9]	validation_0-rmse:1.51078	validation_1-rmse:1.70571
# [10]	validation_0-rmse:1.50370	validation_1-rmse:1.69899
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:1.49719	validation_1-rmse:1.69181
# [12]	validation_0-rmse:1.48852	validation_1-rmse:1.68264
# [13]	validation_0-rmse:1.47990	validation_1-rmse:1.67328
# [14]	validation_0-rmse:1.47367	validation_1-rmse:1.66710
# [15]	validation_0-rmse:1.46485	validation_1-rmse:1.65853
# [16]	validation_0-rmse:1.45780	validation_1-rmse:1.65012
# [17]	validation_0-rmse:1.44968	validation_1-rmse:1.64186
# [18]	validation_0-rmse:1.44355	validation_1-rmse:1.63441
# [19]	validation_0-rmse:1.43803	validation_1-rmse:1.62777
# [20]	validation_0-rmse:1.43137	validation_1-rmse:1.61928
# [21]	validation_0-rmse:1.42570	validation_1-rmse:1.61305
# [22]	validation_0-rmse:1.41882	validation_1-rmse:1.60679
# [23]	validation_0-rmse:1.41274	validation_1-rmse:1.60204
# [24]	validation_0-rmse:1.40655	validation_1-rmse:1.59354
# [25]	validation_0-rmse:1.40122	validation_1-rmse:1.58883
# [26]	validation_0-rmse:1.39611	validation_1-rmse:1.58577
# [27]	validation_0-rmse:1.38899	validation_1-rmse:1.57951
# [28]	validation_0-rmse:1.38222	validation_1-rmse:1.57252
# [29]	validation_0-rmse:1.37457	validation_1-rmse:1.56478
# [30]	validation_0-rmse:1.36850	validation_1-rmse:1.55712
# [31]	validation_0-rmse:1.36230	validation_1-rmse:1.55086
# [32]	validation_0-rmse:1.35569	validation_1-rmse:1.54517
# [33]	validation_0-rmse:1.35029	validation_1-rmse:1.53786
# [34]	validation_0-rmse:1.34585	validation_1-rmse:1.53554
# [35]	validation_0-rmse:1.33970	validation_1-rmse:1.52771
# [36]	validation_0-rmse:1.33461	validation_1-rmse:1.52291
# [37]	validation_0-rmse:1.33176	validation_1-rmse:1.52151
# [38]	validation_0-rmse:1.32639	validation_1-rmse:1.51788
# [39]	validation_0-rmse:1.32056	validation_1-rmse:1.51211
# [40]	validation_0-rmse:1.31618	validation_1-rmse:1.50859
# [41]	validation_0-rmse:1.31111	validation_1-rmse:1.50291
# [42]	validation_0-rmse:1.30723	validation_1-rmse:1.49875
# [43]	validation_0-rmse:1.30188	validation_1-rmse:1.49208
# [44]	validation_0-rmse:1.29776	validation_1-rmse:1.48736
# [45]	validation_0-rmse:1.29368	validation_1-rmse:1.48480
# [46]	validation_0-rmse:1.28905	validation_1-rmse:1.48016
# [47]	validation_0-rmse:1.28452	validation_1-rmse:1.47457
# [48]	validation_0-rmse:1.28151	validation_1-rmse:1.47216
# [49]	validation_0-rmse:1.27715	validation_1-rmse:1.46781
# [50]	validation_0-rmse:1.27265	validation_1-rmse:1.46395
# [51]	validation_0-rmse:1.26837	validation_1-rmse:1.45926
# [52]	validation_0-rmse:1.26458	validation_1-rmse:1.45580
# [53]	validation_0-rmse:1.26085	validation_1-rmse:1.45235
# [54]	validation_0-rmse:1.25870	validation_1-rmse:1.44823
# [55]	validation_0-rmse:1.25506	validation_1-rmse:1.44635
# [56]	validation_0-rmse:1.25106	validation_1-rmse:1.44114
# [57]	validation_0-rmse:1.24516	validation_1-rmse:1.43618
# [58]	validation_0-rmse:1.24128	validation_1-rmse:1.43168
# [59]	validation_0-rmse:1.23837	validation_1-rmse:1.43016
# [60]	validation_0-rmse:1.23405	validation_1-rmse:1.42451
# [61]	validation_0-rmse:1.23079	validation_1-rmse:1.42031
# [62]	validation_0-rmse:1.22621	validation_1-rmse:1.41722
# [63]	validation_0-rmse:1.22342	validation_1-rmse:1.41596
# [64]	validation_0-rmse:1.22017	validation_1-rmse:1.41253
# [65]	validation_0-rmse:1.21623	validation_1-rmse:1.40840
# [66]	validation_0-rmse:1.21275	validation_1-rmse:1.40576
# [67]	validation_0-rmse:1.20930	validation_1-rmse:1.40393
# [68]	validation_0-rmse:1.20628	validation_1-rmse:1.40278
# [69]	validation_0-rmse:1.20359	validation_1-rmse:1.40067
# [70]	validation_0-rmse:1.20114	validation_1-rmse:1.39824
# [71]	validation_0-rmse:1.19780	validation_1-rmse:1.39480
# [72]	validation_0-rmse:1.19464	validation_1-rmse:1.39034
# [73]	validation_0-rmse:1.19217	validation_1-rmse:1.38559
# [74]	validation_0-rmse:1.19016	validation_1-rmse:1.38439
# [75]	validation_0-rmse:1.18719	validation_1-rmse:1.38211
# [76]	validation_0-rmse:1.18491	validation_1-rmse:1.37979
# [77]	validation_0-rmse:1.18208	validation_1-rmse:1.37832
# [78]	validation_0-rmse:1.17913	validation_1-rmse:1.37486
# [79]	validation_0-rmse:1.17785	validation_1-rmse:1.37343
# [80]	validation_0-rmse:1.17445	validation_1-rmse:1.36683
# [81]	validation_0-rmse:1.17158	validation_1-rmse:1.36630
# [82]	validation_0-rmse:1.16919	validation_1-rmse:1.36217
# [83]	validation_0-rmse:1.16628	validation_1-rmse:1.35992
# [84]	validation_0-rmse:1.16406	validation_1-rmse:1.35701
# [85]	validation_0-rmse:1.16259	validation_1-rmse:1.35750
# [86]	validation_0-rmse:1.16011	validation_1-rmse:1.35526
# [87]	validation_0-rmse:1.15856	validation_1-rmse:1.35463
# [88]	validation_0-rmse:1.15644	validation_1-rmse:1.35271
# [89]	validation_0-rmse:1.15374	validation_1-rmse:1.34968
# [90]	validation_0-rmse:1.15145	validation_1-rmse:1.34725
# [91]	validation_0-rmse:1.14936	validation_1-rmse:1.34395
# [92]	validation_0-rmse:1.14636	validation_1-rmse:1.34239
# [93]	validation_0-rmse:1.14383	validation_1-rmse:1.33953
# [94]	validation_0-rmse:1.14246	validation_1-rmse:1.33731
# [95]	validation_0-rmse:1.14029	validation_1-rmse:1.33588
# [96]	validation_0-rmse:1.13808	validation_1-rmse:1.33353
# [97]	validation_0-rmse:1.13598	validation_1-rmse:1.33284
# [98]	validation_0-rmse:1.13393	validation_1-rmse:1.33060
# [99]	validation_0-rmse:1.13230	validation_1-rmse:1.32911
# [100]	validation_0-rmse:1.13130	validation_1-rmse:1.32731
# [101]	validation_0-rmse:1.12865	validation_1-rmse:1.32548
# [102]	validation_0-rmse:1.12702	validation_1-rmse:1.32390
# [103]	validation_0-rmse:1.12565	validation_1-rmse:1.32319
# [104]	validation_0-rmse:1.12289	validation_1-rmse:1.32211
# [105]	validation_0-rmse:1.12008	validation_1-rmse:1.32200
# [106]	validation_0-rmse:1.11837	validation_1-rmse:1.32343
# [107]	validation_0-rmse:1.11622	validation_1-rmse:1.32097
# [108]	validation_0-rmse:1.11346	validation_1-rmse:1.31662
# [109]	validation_0-rmse:1.11216	validation_1-rmse:1.31568
# [110]	validation_0-rmse:1.11034	validation_1-rmse:1.31277
# [111]	validation_0-rmse:1.10924	validation_1-rmse:1.31255
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.63534	validation_1-rmse:1.59571
# [1]	validation_0-rmse:1.62563	validation_1-rmse:1.58671
# [2]	validation_0-rmse:1.61633	validation_1-rmse:1.57841
# [3]	validation_0-rmse:1.60694	validation_1-rmse:1.56951
# [4]	validation_0-rmse:1.59649	validation_1-rmse:1.56388
# [5]	validation_0-rmse:1.58744	validation_1-rmse:1.55614
# [6]	validation_0-rmse:1.57721	validation_1-rmse:1.54787
# [7]	validation_0-rmse:1.56816	validation_1-rmse:1.54018
# [8]	validation_0-rmse:1.56022	validation_1-rmse:1.53190
# [9]	validation_0-rmse:1.55287	validation_1-rmse:1.52703
# [10]	validation_0-rmse:1.54455	validation_1-rmse:1.52020
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:1.53704	validation_1-rmse:1.51149
# [12]	validation_0-rmse:1.52937	validation_1-rmse:1.50573
# [13]	validation_0-rmse:1.52124	validation_1-rmse:1.49755
# [14]	validation_0-rmse:1.51375	validation_1-rmse:1.49223
# [15]	validation_0-rmse:1.50633	validation_1-rmse:1.48517
# [16]	validation_0-rmse:1.49893	validation_1-rmse:1.47795
# [17]	validation_0-rmse:1.49261	validation_1-rmse:1.47147
# [18]	validation_0-rmse:1.48594	validation_1-rmse:1.46706
# [19]	validation_0-rmse:1.47849	validation_1-rmse:1.45969
# [20]	validation_0-rmse:1.47087	validation_1-rmse:1.45238
# [21]	validation_0-rmse:1.46369	validation_1-rmse:1.44630
# [22]	validation_0-rmse:1.45477	validation_1-rmse:1.43890
# [23]	validation_0-rmse:1.44912	validation_1-rmse:1.43412
# [24]	validation_0-rmse:1.44169	validation_1-rmse:1.42854
# [25]	validation_0-rmse:1.43557	validation_1-rmse:1.42237
# [26]	validation_0-rmse:1.42843	validation_1-rmse:1.41822
# [27]	validation_0-rmse:1.42120	validation_1-rmse:1.41045
# [28]	validation_0-rmse:1.41455	validation_1-rmse:1.40507
# [29]	validation_0-rmse:1.40899	validation_1-rmse:1.40094
# [30]	validation_0-rmse:1.40416	validation_1-rmse:1.39497
# [31]	validation_0-rmse:1.39878	validation_1-rmse:1.39033
# [32]	validation_0-rmse:1.39286	validation_1-rmse:1.38582
# [33]	validation_0-rmse:1.38763	validation_1-rmse:1.38003
# [34]	validation_0-rmse:1.38017	validation_1-rmse:1.37493
# [35]	validation_0-rmse:1.37412	validation_1-rmse:1.37100
# [36]	validation_0-rmse:1.36847	validation_1-rmse:1.36769
# [37]	validation_0-rmse:1.36384	validation_1-rmse:1.36439
# [38]	validation_0-rmse:1.35716	validation_1-rmse:1.35930
# [39]	validation_0-rmse:1.35026	validation_1-rmse:1.35337
# [40]	validation_0-rmse:1.34352	validation_1-rmse:1.34889
# [41]	validation_0-rmse:1.33984	validation_1-rmse:1.34696
# [42]	validation_0-rmse:1.33570	validation_1-rmse:1.34566
# [43]	validation_0-rmse:1.33000	validation_1-rmse:1.34222
# [44]	validation_0-rmse:1.32492	validation_1-rmse:1.33926
# [45]	validation_0-rmse:1.32033	validation_1-rmse:1.33599
# [46]	validation_0-rmse:1.31581	validation_1-rmse:1.33122
# [47]	validation_0-rmse:1.31080	validation_1-rmse:1.32911
# [48]	validation_0-rmse:1.30502	validation_1-rmse:1.32526
# [49]	validation_0-rmse:1.30071	validation_1-rmse:1.32056
# [50]	validation_0-rmse:1.29674	validation_1-rmse:1.31865
# [51]	validation_0-rmse:1.29333	validation_1-rmse:1.31619
# [52]	validation_0-rmse:1.28967	validation_1-rmse:1.31387
# [53]	validation_0-rmse:1.28489	validation_1-rmse:1.31129
# [54]	validation_0-rmse:1.28085	validation_1-rmse:1.30809
# [55]	validation_0-rmse:1.27585	validation_1-rmse:1.30515
# [56]	validation_0-rmse:1.27190	validation_1-rmse:1.30233
# [57]	validation_0-rmse:1.26731	validation_1-rmse:1.30094
# [58]	validation_0-rmse:1.26363	validation_1-rmse:1.29959
# [59]	validation_0-rmse:1.25863	validation_1-rmse:1.29578
# [60]	validation_0-rmse:1.25413	validation_1-rmse:1.29359
# [61]	validation_0-rmse:1.25124	validation_1-rmse:1.29118
# [62]	validation_0-rmse:1.24662	validation_1-rmse:1.28820
# [63]	validation_0-rmse:1.24319	validation_1-rmse:1.28673
# [64]	validation_0-rmse:1.24069	validation_1-rmse:1.28646
# [65]	validation_0-rmse:1.23847	validation_1-rmse:1.28386
# [66]	validation_0-rmse:1.23387	validation_1-rmse:1.27985
# [67]	validation_0-rmse:1.23116	validation_1-rmse:1.27874
# [68]	validation_0-rmse:1.22781	validation_1-rmse:1.27799
# [69]	validation_0-rmse:1.22529	validation_1-rmse:1.27592
# [70]	validation_0-rmse:1.22138	validation_1-rmse:1.27252
# [71]	validation_0-rmse:1.21945	validation_1-rmse:1.26889
# [72]	validation_0-rmse:1.21546	validation_1-rmse:1.26695
# [73]	validation_0-rmse:1.21109	validation_1-rmse:1.26502
# [74]	validation_0-rmse:1.20882	validation_1-rmse:1.26429
# [75]	validation_0-rmse:1.20536	validation_1-rmse:1.26197
# [76]	validation_0-rmse:1.20157	validation_1-rmse:1.25824
# [77]	validation_0-rmse:1.19852	validation_1-rmse:1.25635
# [78]	validation_0-rmse:1.19515	validation_1-rmse:1.25241
# [79]	validation_0-rmse:1.19135	validation_1-rmse:1.24851
# [80]	validation_0-rmse:1.18859	validation_1-rmse:1.24609
# [81]	validation_0-rmse:1.18593	validation_1-rmse:1.24528
# [82]	validation_0-rmse:1.18228	validation_1-rmse:1.24272
# [83]	validation_0-rmse:1.17930	validation_1-rmse:1.24167
# [84]	validation_0-rmse:1.17742	validation_1-rmse:1.24335
# [85]	validation_0-rmse:1.17340	validation_1-rmse:1.24101
# [86]	validation_0-rmse:1.17134	validation_1-rmse:1.24061
# [87]	validation_0-rmse:1.17002	validation_1-rmse:1.24048
# [88]	validation_0-rmse:1.16883	validation_1-rmse:1.23938
# [89]	validation_0-rmse:1.16646	validation_1-rmse:1.23671
# [90]	validation_0-rmse:1.16379	validation_1-rmse:1.23586
# [91]	validation_0-rmse:1.16150	validation_1-rmse:1.23258
# [92]	validation_0-rmse:1.15823	validation_1-rmse:1.23058
# [93]	validation_0-rmse:1.15568	validation_1-rmse:1.22879
# [94]	validation_0-rmse:1.15359	validation_1-rmse:1.22759
# [95]	validation_0-rmse:1.15082	validation_1-rmse:1.22626
# [96]	validation_0-rmse:1.14894	validation_1-rmse:1.22523
# [97]	validation_0-rmse:1.14839	validation_1-rmse:1.22456
# [98]	validation_0-rmse:1.14679	validation_1-rmse:1.22301
# [99]	validation_0-rmse:1.14625	validation_1-rmse:1.22280
# [100]	validation_0-rmse:1.14471	validation_1-rmse:1.22174
# [101]	validation_0-rmse:1.14297	validation_1-rmse:1.22189
# [102]	validation_0-rmse:1.14040	validation_1-rmse:1.22011
# [103]	validation_0-rmse:1.13808	validation_1-rmse:1.21802
# [104]	validation_0-rmse:1.13534	validation_1-rmse:1.21736
# [105]	validation_0-rmse:1.13328	validation_1-rmse:1.21687
# [106]	validation_0-rmse:1.13087	validation_1-rmse:1.21396
# [107]	validation_0-rmse:1.12986	validation_1-rmse:1.21317
# [108]	validation_0-rmse:1.12737	validation_1-rmse:1.20998
# [109]	validation_0-rmse:1.12612	validation_1-rmse:1.20990
# [110]	validation_0-rmse:1.12407	validation_1-rmse:1.20995
# [111]	validation_0-rmse:1.12208	validation_1-rmse:1.20983
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.65478	validation_1-rmse:1.52690
# [1]	validation_0-rmse:1.64127	validation_1-rmse:1.51442
# [2]	validation_0-rmse:1.63084	validation_1-rmse:1.50394
# [3]	validation_0-rmse:1.61945	validation_1-rmse:1.49568
# [4]	validation_0-rmse:1.60846	validation_1-rmse:1.48863
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:1.60096	validation_1-rmse:1.48297
# [6]	validation_0-rmse:1.59191	validation_1-rmse:1.47492
# [7]	validation_0-rmse:1.57953	validation_1-rmse:1.46540
# [8]	validation_0-rmse:1.57153	validation_1-rmse:1.45950
# [9]	validation_0-rmse:1.56311	validation_1-rmse:1.45277
# [10]	validation_0-rmse:1.55403	validation_1-rmse:1.44492
# [11]	validation_0-rmse:1.54736	validation_1-rmse:1.43983
# [12]	validation_0-rmse:1.53854	validation_1-rmse:1.43315
# [13]	validation_0-rmse:1.52959	validation_1-rmse:1.42555
# [14]	validation_0-rmse:1.52022	validation_1-rmse:1.42010
# [15]	validation_0-rmse:1.51294	validation_1-rmse:1.41511
# [16]	validation_0-rmse:1.50481	validation_1-rmse:1.40820
# [17]	validation_0-rmse:1.49733	validation_1-rmse:1.40289
# [18]	validation_0-rmse:1.48886	validation_1-rmse:1.39500
# [19]	validation_0-rmse:1.47985	validation_1-rmse:1.38844
# [20]	validation_0-rmse:1.47238	validation_1-rmse:1.38288
# [21]	validation_0-rmse:1.46390	validation_1-rmse:1.37732
# [22]	validation_0-rmse:1.45722	validation_1-rmse:1.37296
# [23]	validation_0-rmse:1.45081	validation_1-rmse:1.36685
# [24]	validation_0-rmse:1.44316	validation_1-rmse:1.36403
# [25]	validation_0-rmse:1.43507	validation_1-rmse:1.35714
# [26]	validation_0-rmse:1.42801	validation_1-rmse:1.35325
# [27]	validation_0-rmse:1.42137	validation_1-rmse:1.34856
# [28]	validation_0-rmse:1.41381	validation_1-rmse:1.34241
# [29]	validation_0-rmse:1.40661	validation_1-rmse:1.33725
# [30]	validation_0-rmse:1.39951	validation_1-rmse:1.33159
# [31]	validation_0-rmse:1.39309	validation_1-rmse:1.32818
# [32]	validation_0-rmse:1.38561	validation_1-rmse:1.32504
# [33]	validation_0-rmse:1.37970	validation_1-rmse:1.32191
# [34]	validation_0-rmse:1.37431	validation_1-rmse:1.32008
# [35]	validation_0-rmse:1.36828	validation_1-rmse:1.31522
# [36]	validation_0-rmse:1.36258	validation_1-rmse:1.31113
# [37]	validation_0-rmse:1.35637	validation_1-rmse:1.30459
# [38]	validation_0-rmse:1.34936	validation_1-rmse:1.29990
# [39]	validation_0-rmse:1.34371	validation_1-rmse:1.29697
# [40]	validation_0-rmse:1.33919	validation_1-rmse:1.29524
# [41]	validation_0-rmse:1.33448	validation_1-rmse:1.29330
# [42]	validation_0-rmse:1.32873	validation_1-rmse:1.29004
# [43]	validation_0-rmse:1.32256	validation_1-rmse:1.28647
# [44]	validation_0-rmse:1.31652	validation_1-rmse:1.28283
# [45]	validation_0-rmse:1.31199	validation_1-rmse:1.28061
# [46]	validation_0-rmse:1.30707	validation_1-rmse:1.27682
# [47]	validation_0-rmse:1.30153	validation_1-rmse:1.27515
# [48]	validation_0-rmse:1.29651	validation_1-rmse:1.27186
# [49]	validation_0-rmse:1.29175	validation_1-rmse:1.26855
# [50]	validation_0-rmse:1.28668	validation_1-rmse:1.26626
# [51]	validation_0-rmse:1.28074	validation_1-rmse:1.26404
# [52]	validation_0-rmse:1.27668	validation_1-rmse:1.26121
# [53]	validation_0-rmse:1.27205	validation_1-rmse:1.25887
# [54]	validation_0-rmse:1.26708	validation_1-rmse:1.25726
# [55]	validation_0-rmse:1.26110	validation_1-rmse:1.25597
# [56]	validation_0-rmse:1.25773	validation_1-rmse:1.25563
# [57]	validation_0-rmse:1.25212	validation_1-rmse:1.25301
# [58]	validation_0-rmse:1.24724	validation_1-rmse:1.25136
# [59]	validation_0-rmse:1.24259	validation_1-rmse:1.24885
# [60]	validation_0-rmse:1.23833	validation_1-rmse:1.24746
# [61]	validation_0-rmse:1.23438	validation_1-rmse:1.24592
# [62]	validation_0-rmse:1.23067	validation_1-rmse:1.24516
# [63]	validation_0-rmse:1.22660	validation_1-rmse:1.24273
# [64]	validation_0-rmse:1.22267	validation_1-rmse:1.24078
# [65]	validation_0-rmse:1.21933	validation_1-rmse:1.23875
# [66]	validation_0-rmse:1.21482	validation_1-rmse:1.23739
# [67]	validation_0-rmse:1.21098	validation_1-rmse:1.23568
# [68]	validation_0-rmse:1.20832	validation_1-rmse:1.23383
# [69]	validation_0-rmse:1.20512	validation_1-rmse:1.23156
# [70]	validation_0-rmse:1.20212	validation_1-rmse:1.23016
# [71]	validation_0-rmse:1.19916	validation_1-rmse:1.22926
# [72]	validation_0-rmse:1.19508	validation_1-rmse:1.22842
# [73]	validation_0-rmse:1.19168	validation_1-rmse:1.22697
# [74]	validation_0-rmse:1.18879	validation_1-rmse:1.22481
# [75]	validation_0-rmse:1.18569	validation_1-rmse:1.22232
# [76]	validation_0-rmse:1.18299	validation_1-rmse:1.22284
# [77]	validation_0-rmse:1.18030	validation_1-rmse:1.22150
# [78]	validation_0-rmse:1.17772	validation_1-rmse:1.21963
# [79]	validation_0-rmse:1.17427	validation_1-rmse:1.21879
# [80]	validation_0-rmse:1.17180	validation_1-rmse:1.21666
# [81]	validation_0-rmse:1.16819	validation_1-rmse:1.21626
# [82]	validation_0-rmse:1.16465	validation_1-rmse:1.21447
# [83]	validation_0-rmse:1.16186	validation_1-rmse:1.21353
# [84]	validation_0-rmse:1.15881	validation_1-rmse:1.21433
# [85]	validation_0-rmse:1.15697	validation_1-rmse:1.21360
# [86]	validation_0-rmse:1.15455	validation_1-rmse:1.21318
# [87]	validation_0-rmse:1.15262	validation_1-rmse:1.21358
# [88]	validation_0-rmse:1.15056	validation_1-rmse:1.21326
# [89]	validation_0-rmse:1.14845	validation_1-rmse:1.21347
# [90]	validation_0-rmse:1.14654	validation_1-rmse:1.21270
# [91]	validation_0-rmse:1.14377	validation_1-rmse:1.21346
# [92]	validation_0-rmse:1.14147	validation_1-rmse:1.21238
# [93]	validation_0-rmse:1.13911	validation_1-rmse:1.21249
# [94]	validation_0-rmse:1.13659	validation_1-rmse:1.21172
# [95]	validation_0-rmse:1.13442	validation_1-rmse:1.21247
# [96]	validation_0-rmse:1.13177	validation_1-rmse:1.21198
# [97]	validation_0-rmse:1.13043	validation_1-rmse:1.21093
# [98]	validation_0-rmse:1.12738	validation_1-rmse:1.20937
# [99]	validation_0-rmse:1.12465	validation_1-rmse:1.20908
# [100]	validation_0-rmse:1.12239	validation_1-rmse:1.20938
# [101]	validation_0-rmse:1.12007	validation_1-rmse:1.20836
# [102]	validation_0-rmse:1.11799	validation_1-rmse:1.20816
# [103]	validation_0-rmse:1.11602	validation_1-rmse:1.20872
# [104]	validation_0-rmse:1.11367	validation_1-rmse:1.20784
# [105]	validation_0-rmse:1.11120	validation_1-rmse:1.20811
# [106]	validation_0-rmse:1.10871	validation_1-rmse:1.20879
# [107]	validation_0-rmse:1.10618	validation_1-rmse:1.20886
# [108]	validation_0-rmse:1.10442	validation_1-rmse:1.20871
# [109]	validation_0-rmse:1.10326	validation_1-rmse:1.20991
# [110]	validation_0-rmse:1.10048	validation_1-rmse:1.21045
# [111]	validation_0-rmse:1.09829	validation_1-rmse:1.21087
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.57460	validation_1-rmse:1.83868
# [1]	validation_0-rmse:1.56674	validation_1-rmse:1.83346
# [2]	validation_0-rmse:1.55771	validation_1-rmse:1.82512
# [3]	validation_0-rmse:1.54881	validation_1-rmse:1.81544
# ...
# [76]	validation_0-rmse:1.15869	validation_1-rmse:1.39661
# [77]	validation_0-rmse:1.15575	validation_1-rmse:1.39369
# [78]	validation_0-rmse:1.15192	validation_1-rmse:1.39125
# [79]	validation_0-rmse:1.14919	validation_1-rmse:1.38918
# [80]	validation_0-rmse:1.14642	validation_1-rmse:1.38768
# [81]	validation_0-rmse:1.14396	validation_1-rmse:1.38496
# [82]	validation_0-rmse:1.13942	validation_1-rmse:1.38160
# [83]	validation_0-rmse:1.13688	validation_1-rmse:1.37928
# [84]	validation_0-rmse:1.13520	validation_1-rmse:1.37793
# [85]	validation_0-rmse:1.13241	validation_1-rmse:1.37530
# [86]	validation_0-rmse:1.12999	validation_1-rmse:1.37221
# [87]	validation_0-rmse:1.12734	validation_1-rmse:1.36900
# [88]	validation_0-rmse:1.12468	validation_1-rmse:1.36717
# [89]	validation_0-rmse:1.12098	validation_1-rmse:1.36499
# [90]	validation_0-rmse:1.11814	validation_1-rmse:1.36305
# [91]	validation_0-rmse:1.11573	validation_1-rmse:1.36055
# [92]	validation_0-rmse:1.11354	validation_1-rmse:1.35971
# [93]	validation_0-rmse:1.11155	validation_1-rmse:1.35827
# [94]	validation_0-rmse:1.10893	validation_1-rmse:1.35665
# [95]	validation_0-rmse:1.10633	validation_1-rmse:1.35469
# [96]	validation_0-rmse:1.10379	validation_1-rmse:1.35264
# [97]	validation_0-rmse:1.10203	validation_1-rmse:1.35147
# [98]	validation_0-rmse:1.09949	validation_1-rmse:1.34805
# [99]	validation_0-rmse:1.09793	validation_1-rmse:1.34785
# [100]	validation_0-rmse:1.09559	validation_1-rmse:1.34684
# [101]	validation_0-rmse:1.09322	validation_1-rmse:1.34393
# [102]	validation_0-rmse:1.09129	validation_1-rmse:1.34179
# [103]	validation_0-rmse:1.08954	validation_1-rmse:1.33998
# [104]	validation_0-rmse:1.08819	validation_1-rmse:1.33955
# [105]	validation_0-rmse:1.08649	validation_1-rmse:1.33813
# [106]	validation_0-rmse:1.08470	validation_1-rmse:1.33570
# [107]	validation_0-rmse:1.08306	validation_1-rmse:1.33553
# [108]	validation_0-rmse:1.08195	validation_1-rmse:1.33404
# [109]	validation_0-rmse:1.07978	validation_1-rmse:1.33378
# [110]	validation_0-rmse:1.07855	validation_1-rmse:1.33472
# [111]	validation_0-rmse:1.07708	validation_1-rmse:1.33155
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.68025	validation_1-rmse:1.40241
# [1]	validation_0-rmse:1.67108	validation_1-rmse:1.39114
# [2]	validation_0-rmse:1.66029	validation_1-rmse:1.38047
# [3]	validation_0-rmse:1.65103	validation_1-rmse:1.37341
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:1.64096	validation_1-rmse:1.36541
# [5]	validation_0-rmse:1.63391	validation_1-rmse:1.35802
# [6]	validation_0-rmse:1.62176	validation_1-rmse:1.34737
# [7]	validation_0-rmse:1.61342	validation_1-rmse:1.33935
# [8]	validation_0-rmse:1.60467	validation_1-rmse:1.33216
# [9]	validation_0-rmse:1.59753	validation_1-rmse:1.32568
# [10]	validation_0-rmse:1.58715	validation_1-rmse:1.31737
# [11]	validation_0-rmse:1.57733	validation_1-rmse:1.30806
# [12]	validation_0-rmse:1.56885	validation_1-rmse:1.30091
# [13]	validation_0-rmse:1.56083	validation_1-rmse:1.29351
# [14]	validation_0-rmse:1.55236	validation_1-rmse:1.28620
# [15]	validation_0-rmse:1.54426	validation_1-rmse:1.27947
# [16]	validation_0-rmse:1.53813	validation_1-rmse:1.27234
# [17]	validation_0-rmse:1.53109	validation_1-rmse:1.26763
# [18]	validation_0-rmse:1.52242	validation_1-rmse:1.26285
# [19]	validation_0-rmse:1.51410	validation_1-rmse:1.25733
# [20]	validation_0-rmse:1.50633	validation_1-rmse:1.25079
# [21]	validation_0-rmse:1.49940	validation_1-rmse:1.24584
# [22]	validation_0-rmse:1.49155	validation_1-rmse:1.23864
# [23]	validation_0-rmse:1.48379	validation_1-rmse:1.23026
# [24]	validation_0-rmse:1.47810	validation_1-rmse:1.22615
# [25]	validation_0-rmse:1.46948	validation_1-rmse:1.22076
# [26]	validation_0-rmse:1.46259	validation_1-rmse:1.21255
# [27]	validation_0-rmse:1.45740	validation_1-rmse:1.20656
# [28]	validation_0-rmse:1.45143	validation_1-rmse:1.20186
# [29]	validation_0-rmse:1.44324	validation_1-rmse:1.19642
# [30]	validation_0-rmse:1.43719	validation_1-rmse:1.19145
# [31]	validation_0-rmse:1.43177	validation_1-rmse:1.18714
# [32]	validation_0-rmse:1.42460	validation_1-rmse:1.18045
# [33]	validation_0-rmse:1.41612	validation_1-rmse:1.17233
# [34]	validation_0-rmse:1.40866	validation_1-rmse:1.16686
# [35]	validation_0-rmse:1.40109	validation_1-rmse:1.16327
# [36]	validation_0-rmse:1.39733	validation_1-rmse:1.15876
# [37]	validation_0-rmse:1.39302	validation_1-rmse:1.15596
# [38]	validation_0-rmse:1.38793	validation_1-rmse:1.15035
# [39]	validation_0-rmse:1.38282	validation_1-rmse:1.14624
# [40]	validation_0-rmse:1.37791	validation_1-rmse:1.14165
# [41]	validation_0-rmse:1.37284	validation_1-rmse:1.13757
# [42]	validation_0-rmse:1.36900	validation_1-rmse:1.13440
# [43]	validation_0-rmse:1.36215	validation_1-rmse:1.13000
# [44]	validation_0-rmse:1.35716	validation_1-rmse:1.12626
# [45]	validation_0-rmse:1.35195	validation_1-rmse:1.12280
# [46]	validation_0-rmse:1.34653	validation_1-rmse:1.11994
# [47]	validation_0-rmse:1.34245	validation_1-rmse:1.11753
# [48]	validation_0-rmse:1.33972	validation_1-rmse:1.11443
# [49]	validation_0-rmse:1.33396	validation_1-rmse:1.10859
# [50]	validation_0-rmse:1.32918	validation_1-rmse:1.10443
# [51]	validation_0-rmse:1.32473	validation_1-rmse:1.10090
# [52]	validation_0-rmse:1.32039	validation_1-rmse:1.09682
# [53]	validation_0-rmse:1.31740	validation_1-rmse:1.09429
# [54]	validation_0-rmse:1.31333	validation_1-rmse:1.09185
# [55]	validation_0-rmse:1.31090	validation_1-rmse:1.08997
# [56]	validation_0-rmse:1.30704	validation_1-rmse:1.08605
# [57]	validation_0-rmse:1.30105	validation_1-rmse:1.08367
# [58]	validation_0-rmse:1.29783	validation_1-rmse:1.08048
# [59]	validation_0-rmse:1.29338	validation_1-rmse:1.07455
# [60]	validation_0-rmse:1.28976	validation_1-rmse:1.07339
# [61]	validation_0-rmse:1.28531	validation_1-rmse:1.07075
# [62]	validation_0-rmse:1.28196	validation_1-rmse:1.06857
# [63]	validation_0-rmse:1.27781	validation_1-rmse:1.06658
# [64]	validation_0-rmse:1.27354	validation_1-rmse:1.06533
# [65]	validation_0-rmse:1.26869	validation_1-rmse:1.06210
# [66]	validation_0-rmse:1.26588	validation_1-rmse:1.06067
# [67]	validation_0-rmse:1.26340	validation_1-rmse:1.05881
# [68]	validation_0-rmse:1.25934	validation_1-rmse:1.05783
# [69]	validation_0-rmse:1.25712	validation_1-rmse:1.05637
# [70]	validation_0-rmse:1.25433	validation_1-rmse:1.05420
# [71]	validation_0-rmse:1.25055	validation_1-rmse:1.04986
# [72]	validation_0-rmse:1.24882	validation_1-rmse:1.04780
# [73]	validation_0-rmse:1.24518	validation_1-rmse:1.04931
# [74]	validation_0-rmse:1.24187	validation_1-rmse:1.04827
# [75]	validation_0-rmse:1.23812	validation_1-rmse:1.04449
# [76]	validation_0-rmse:1.23478	validation_1-rmse:1.04279
# [77]	validation_0-rmse:1.23111	validation_1-rmse:1.04057
# [78]	validation_0-rmse:1.22750	validation_1-rmse:1.03883
# [79]	validation_0-rmse:1.22366	validation_1-rmse:1.03841
# [80]	validation_0-rmse:1.22076	validation_1-rmse:1.03857
# [81]	validation_0-rmse:1.21840	validation_1-rmse:1.03671
# [82]	validation_0-rmse:1.21588	validation_1-rmse:1.03409
# [83]	validation_0-rmse:1.21370	validation_1-rmse:1.03295
# [84]	validation_0-rmse:1.21066	validation_1-rmse:1.03146
# [85]	validation_0-rmse:1.20803	validation_1-rmse:1.02903
# [86]	validation_0-rmse:1.20579	validation_1-rmse:1.02647
# [87]	validation_0-rmse:1.20363	validation_1-rmse:1.02464
# [88]	validation_0-rmse:1.20123	validation_1-rmse:1.02385
# [89]	validation_0-rmse:1.19772	validation_1-rmse:1.02233
# [90]	validation_0-rmse:1.19624	validation_1-rmse:1.02165
# [91]	validation_0-rmse:1.19378	validation_1-rmse:1.01902
# [92]	validation_0-rmse:1.19125	validation_1-rmse:1.01913
# [93]	validation_0-rmse:1.18901	validation_1-rmse:1.01686
# [94]	validation_0-rmse:1.18524	validation_1-rmse:1.01738
# [95]	validation_0-rmse:1.18344	validation_1-rmse:1.01718
# [96]	validation_0-rmse:1.18067	validation_1-rmse:1.01667
# [97]	validation_0-rmse:1.17835	validation_1-rmse:1.01500
# [98]	validation_0-rmse:1.17503	validation_1-rmse:1.01432
# [99]	validation_0-rmse:1.17261	validation_1-rmse:1.01204
# [100]	validation_0-rmse:1.16934	validation_1-rmse:1.01218
# [101]	validation_0-rmse:1.16719	validation_1-rmse:1.01025
# [102]	validation_0-rmse:1.16467	validation_1-rmse:1.01109
# [103]	validation_0-rmse:1.16349	validation_1-rmse:1.01176
# [104]	validation_0-rmse:1.16225	validation_1-rmse:1.01054
# [105]	validation_0-rmse:1.16080	validation_1-rmse:1.00948
# [106]	validation_0-rmse:1.15900	validation_1-rmse:1.01010
# [107]	validation_0-rmse:1.15586	validation_1-rmse:1.00765
# [108]	validation_0-rmse:1.15295	validation_1-rmse:1.00802
# [109]	validation_0-rmse:1.15135	validation_1-rmse:1.00854
# [110]	validation_0-rmse:1.15047	validation_1-rmse:1.00746
# [111]	validation_0-rmse:1.14823	validation_1-rmse:1.00725
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.58317	validation_1-rmse:1.79531
# [1]	validation_0-rmse:1.57421	validation_1-rmse:1.78674
# [2]	validation_0-rmse:1.56356	validation_1-rmse:1.77724
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:1.55661	validation_1-rmse:1.77041
# [4]	validation_0-rmse:1.54679	validation_1-rmse:1.76162
# [5]	validation_0-rmse:1.53920	validation_1-rmse:1.75372
# [6]	validation_0-rmse:1.52936	validation_1-rmse:1.74440
# [7]	validation_0-rmse:1.51886	validation_1-rmse:1.73419
# [8]	validation_0-rmse:1.51061	validation_1-rmse:1.72828
# [9]	validation_0-rmse:1.50376	validation_1-rmse:1.72239
# [10]	validation_0-rmse:1.49447	validation_1-rmse:1.71431
# [11]	validation_0-rmse:1.48682	validation_1-rmse:1.70803
# [12]	validation_0-rmse:1.47827	validation_1-rmse:1.69942
# [13]	validation_0-rmse:1.46914	validation_1-rmse:1.69060
# [14]	validation_0-rmse:1.46103	validation_1-rmse:1.68357
# [15]	validation_0-rmse:1.45238	validation_1-rmse:1.67629
# [16]	validation_0-rmse:1.44509	validation_1-rmse:1.66789
# [17]	validation_0-rmse:1.43776	validation_1-rmse:1.66228
# [18]	validation_0-rmse:1.43107	validation_1-rmse:1.65550
# [19]	validation_0-rmse:1.42457	validation_1-rmse:1.64995
# [20]	validation_0-rmse:1.41740	validation_1-rmse:1.64270
# [21]	validation_0-rmse:1.41110	validation_1-rmse:1.63650
# [22]	validation_0-rmse:1.40600	validation_1-rmse:1.63143
# [23]	validation_0-rmse:1.39833	validation_1-rmse:1.62466
# [24]	validation_0-rmse:1.39348	validation_1-rmse:1.61948
# [25]	validation_0-rmse:1.38850	validation_1-rmse:1.61478
# [26]	validation_0-rmse:1.38261	validation_1-rmse:1.60758
# [27]	validation_0-rmse:1.37591	validation_1-rmse:1.60113
# [28]	validation_0-rmse:1.37022	validation_1-rmse:1.59558
# [29]	validation_0-rmse:1.36390	validation_1-rmse:1.59189
# [30]	validation_0-rmse:1.35780	validation_1-rmse:1.58542
# [31]	validation_0-rmse:1.35123	validation_1-rmse:1.57946
# [32]	validation_0-rmse:1.34710	validation_1-rmse:1.57493
# [33]	validation_0-rmse:1.34022	validation_1-rmse:1.56986
# [34]	validation_0-rmse:1.33578	validation_1-rmse:1.56462
# [35]	validation_0-rmse:1.32988	validation_1-rmse:1.55761
# [36]	validation_0-rmse:1.32526	validation_1-rmse:1.55268
# [37]	validation_0-rmse:1.32030	validation_1-rmse:1.54783
# [38]	validation_0-rmse:1.31619	validation_1-rmse:1.54391
# [39]	validation_0-rmse:1.31084	validation_1-rmse:1.53838
# [40]	validation_0-rmse:1.30568	validation_1-rmse:1.53367
# [41]	validation_0-rmse:1.30031	validation_1-rmse:1.53098
# [42]	validation_0-rmse:1.29429	validation_1-rmse:1.52515
# [43]	validation_0-rmse:1.29144	validation_1-rmse:1.52086
# [44]	validation_0-rmse:1.28687	validation_1-rmse:1.51735
# [45]	validation_0-rmse:1.28198	validation_1-rmse:1.51258
# [46]	validation_0-rmse:1.27768	validation_1-rmse:1.50691
# [47]	validation_0-rmse:1.27212	validation_1-rmse:1.50233
# [48]	validation_0-rmse:1.26751	validation_1-rmse:1.49654
# [49]	validation_0-rmse:1.26229	validation_1-rmse:1.49319
# [50]	validation_0-rmse:1.25935	validation_1-rmse:1.49084
# [51]	validation_0-rmse:1.25551	validation_1-rmse:1.48643
# [52]	validation_0-rmse:1.25149	validation_1-rmse:1.48277
# [53]	validation_0-rmse:1.24629	validation_1-rmse:1.47797
# [54]	validation_0-rmse:1.24196	validation_1-rmse:1.47443
# [55]	validation_0-rmse:1.23859	validation_1-rmse:1.47104
# [56]	validation_0-rmse:1.23448	validation_1-rmse:1.46727
# [57]	validation_0-rmse:1.23144	validation_1-rmse:1.46289
# [58]	validation_0-rmse:1.22787	validation_1-rmse:1.45955
# [59]	validation_0-rmse:1.22290	validation_1-rmse:1.45574
# [60]	validation_0-rmse:1.21801	validation_1-rmse:1.45270
# [61]	validation_0-rmse:1.21336	validation_1-rmse:1.44981
# [62]	validation_0-rmse:1.20953	validation_1-rmse:1.44841
# [63]	validation_0-rmse:1.20710	validation_1-rmse:1.44565
# [64]	validation_0-rmse:1.20253	validation_1-rmse:1.44189
# [65]	validation_0-rmse:1.19787	validation_1-rmse:1.43622
# [66]	validation_0-rmse:1.19378	validation_1-rmse:1.43109
# [67]	validation_0-rmse:1.19109	validation_1-rmse:1.42948
# [68]	validation_0-rmse:1.18818	validation_1-rmse:1.42443
# [69]	validation_0-rmse:1.18508	validation_1-rmse:1.42234
# [70]	validation_0-rmse:1.18138	validation_1-rmse:1.41921
# [71]	validation_0-rmse:1.17766	validation_1-rmse:1.41523
# [72]	validation_0-rmse:1.17408	validation_1-rmse:1.41209
# [73]	validation_0-rmse:1.17177	validation_1-rmse:1.40992
# [74]	validation_0-rmse:1.16771	validation_1-rmse:1.40876
# [75]	validation_0-rmse:1.16607	validation_1-rmse:1.40830
# [76]	validation_0-rmse:1.16315	validation_1-rmse:1.40566
# [77]	validation_0-rmse:1.16051	validation_1-rmse:1.40361
# [78]	validation_0-rmse:1.15707	validation_1-rmse:1.40242
# [79]	validation_0-rmse:1.15492	validation_1-rmse:1.39895
# [80]	validation_0-rmse:1.15210	validation_1-rmse:1.39549
# [81]	validation_0-rmse:1.14894	validation_1-rmse:1.39291
# [82]	validation_0-rmse:1.14721	validation_1-rmse:1.39213
# [83]	validation_0-rmse:1.14373	validation_1-rmse:1.38840
# [84]	validation_0-rmse:1.14158	validation_1-rmse:1.38675
# [85]	validation_0-rmse:1.13952	validation_1-rmse:1.38666
# [86]	validation_0-rmse:1.13727	validation_1-rmse:1.38455
# [87]	validation_0-rmse:1.13447	validation_1-rmse:1.38240
# [88]	validation_0-rmse:1.13174	validation_1-rmse:1.37910
# [89]	validation_0-rmse:1.12937	validation_1-rmse:1.37656
# [90]	validation_0-rmse:1.12704	validation_1-rmse:1.37443
# [91]	validation_0-rmse:1.12426	validation_1-rmse:1.37313
# [92]	validation_0-rmse:1.12045	validation_1-rmse:1.37149
# [93]	validation_0-rmse:1.11882	validation_1-rmse:1.37078
# [94]	validation_0-rmse:1.11725	validation_1-rmse:1.36874
# [95]	validation_0-rmse:1.11430	validation_1-rmse:1.36624
# [96]	validation_0-rmse:1.11298	validation_1-rmse:1.36543
# [97]	validation_0-rmse:1.11068	validation_1-rmse:1.36352
# [98]	validation_0-rmse:1.10830	validation_1-rmse:1.36143
# [99]	validation_0-rmse:1.10684	validation_1-rmse:1.36005
# [100]	validation_0-rmse:1.10437	validation_1-rmse:1.35945
# [101]	validation_0-rmse:1.10214	validation_1-rmse:1.35795
# [102]	validation_0-rmse:1.09942	validation_1-rmse:1.35800
# [103]	validation_0-rmse:1.09777	validation_1-rmse:1.35640
# [104]	validation_0-rmse:1.09593	validation_1-rmse:1.35468
# [105]	validation_0-rmse:1.09420	validation_1-rmse:1.35338
# [106]	validation_0-rmse:1.09168	validation_1-rmse:1.35004
# [107]	validation_0-rmse:1.09025	validation_1-rmse:1.34827
# [108]	validation_0-rmse:1.08805	validation_1-rmse:1.34595
# [109]	validation_0-rmse:1.08681	validation_1-rmse:1.34509
# [110]	validation_0-rmse:1.08452	validation_1-rmse:1.34272
# [111]	validation_0-rmse:1.08295	validation_1-rmse:1.34238
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-4.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.109
# Uncertainty
# a0: -0.2420+/-0.02
# a1: 0.0689+/-0.014

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: r2020B04: mean - 0.105, median - 0.105, CI - [0.088-0.122]
#
# SHAP-values for: r2020B08: mean - 0.089, median - 0.088, CI - [0.075-0.101]
#
# SHAP-values for: r2020B09: mean - 0.058, median - 0.059, CI - [0.048-0.069]
#
# SHAP-values for: r2020B10: mean - 0.09, median - 0.091, CI - [0.074-0.106]
#
# SHAP-values for: r2020B11: mean - 0.053, median - 0.051, CI - [0.041-0.064]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['r2020B04', 'r2020B10', 'r2020B08', 'r2020B09', 'r2020B11'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 109.15, median: 111.0,
#  pred. interval (P(0.025)-P(0.975)): 83.975-111.0,
#  conf. interval (p-value=0.95): 110.101-111.0
# ***
# Aggregate bias statistic:
#  mean: 0.313, median: 0.313,
#  pred. interval (P(0.025)-P(0.975)): -0.015-0.695,
#  conf. interval (p-value=0.95): 0.117-0.49
# ***
# Aggregate RMSE statistic:
#  mean: 1.217, median: 1.201, pred. interval (P(0.025)-P(0.975)): 0.959-1.514,
#  conf. interval (p-value=0.95): 1.084-1.354
# ***
# Aggregate MSE statistic:
#  mean: 1.506, median: 1.444, pred. interval (P(0.025)-P(0.975)): 0.92-2.291,
#  conf. interval (p-value=0.95): 1.176-1.837
# ***
# Aggregate R^2 statistic:
#  mean: 0.012, median: 0.028, pred. interval (P(0.025)-P(0.975)): -0.205-0.146,
#  conf. interval (p-value=0.95): -0.062-0.088
# ***
# Aggregate bias(%) statistic:
#  mean: -46.609, median: -51.999, pred. interval (P(0.025)-P(0.975)): -76.421-4.559,
#  conf. interval (p-value=0.95): -65.79--26.754
# ***
# Aggregate RMSE(%) statistic:
#  mean: -224.479, median: -197.722, pred. interval (P(0.025)-P(0.975)): -438.661--149.942,
#  conf. interval (p-value=0.95): -266.683--169.93
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -0.204, median: -0.188,
#  pred. interval (P(0.025)-P(0.975)): -0.507-0.071,
#  conf. interval (p-value=0.95): -0.35--0.065
# ***
# Aggregate RMSE statistic:
#  mean: 0.953, median: 0.963, pred. interval (P(0.025)-P(0.975)): 0.607-1.355,
#  conf. interval (p-value=0.95): 0.765-1.12
# ***
# Aggregate MSE statistic:
#  mean: 0.946, median: 0.927, pred. interval (P(0.025)-P(0.975)): 0.368-1.837,
#  conf. interval (p-value=0.95): 0.59-1.257
# ***
# Aggregate R^2 statistic:
#  mean: -0.002, median: -0.0, pred. interval (P(0.025)-P(0.975)): -0.164-0.167,
#  conf. interval (p-value=0.95): -0.085-0.072
# ***
# Aggregate bias(%) statistic:
#  mean: -18.985, median: -19.292, pred. interval (P(0.025)-P(0.975)): -40.33-9.305,
#  conf. interval (p-value=0.95): -31.083--7.382
# ***
# Aggregate RMSE(%) statistic:
#  mean: 96.717, median: 96.958, pred. interval (P(0.025)-P(0.975)): 74.304-120.01,
#  conf. interval (p-value=0.95): 83.656-109.398
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-4, -3, -2, -1, 0, 1, 2])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 0.2, 0.5, 1, 2, 5])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.62950
# [1]	validation_0-rmse:1.62057
# [2]	validation_0-rmse:1.61049
# [3]	validation_0-rmse:1.60163
# [4]	validation_0-rmse:1.59283
# [5]	validation_0-rmse:1.58344
# [6]	validation_0-rmse:1.57449
# [7]	validation_0-rmse:1.56748
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:1.56043
# [9]	validation_0-rmse:1.55131
# [10]	validation_0-rmse:1.54315
# [11]	validation_0-rmse:1.53505
# [12]	validation_0-rmse:1.52712
# [13]	validation_0-rmse:1.51868
# [14]	validation_0-rmse:1.51069
# [15]	validation_0-rmse:1.50267
# [16]	validation_0-rmse:1.49616
# [17]	validation_0-rmse:1.48892
# [18]	validation_0-rmse:1.48053
# [19]	validation_0-rmse:1.47427
# [20]	validation_0-rmse:1.46942
# [21]	validation_0-rmse:1.46376
# [22]	validation_0-rmse:1.45752
# [23]	validation_0-rmse:1.45038
# [24]	validation_0-rmse:1.44426
# [25]	validation_0-rmse:1.43608
# [26]	validation_0-rmse:1.42988
# [27]	validation_0-rmse:1.42276
# [28]	validation_0-rmse:1.41589
# [29]	validation_0-rmse:1.41225
# [30]	validation_0-rmse:1.40758
# [31]	validation_0-rmse:1.40143
# [32]	validation_0-rmse:1.39429
# [33]	validation_0-rmse:1.38920
# [34]	validation_0-rmse:1.38386
# [35]	validation_0-rmse:1.37755
# [36]	validation_0-rmse:1.37201
# [37]	validation_0-rmse:1.36740
# [38]	validation_0-rmse:1.36267
# [39]	validation_0-rmse:1.35827
# [40]	validation_0-rmse:1.35229
# [41]	validation_0-rmse:1.34781
# [42]	validation_0-rmse:1.34235
# [43]	validation_0-rmse:1.33751
# [44]	validation_0-rmse:1.33268
# [45]	validation_0-rmse:1.32743
# [46]	validation_0-rmse:1.32255
# [47]	validation_0-rmse:1.31854
# [48]	validation_0-rmse:1.31408
# [49]	validation_0-rmse:1.30908
# [50]	validation_0-rmse:1.30341
# [51]	validation_0-rmse:1.29754
# [52]	validation_0-rmse:1.29204
# [53]	validation_0-rmse:1.28697
# [54]	validation_0-rmse:1.28218
# [55]	validation_0-rmse:1.27708
# [56]	validation_0-rmse:1.27297
# [57]	validation_0-rmse:1.26899
# [58]	validation_0-rmse:1.26534
# [59]	validation_0-rmse:1.26147
# [60]	validation_0-rmse:1.25790
# [61]	validation_0-rmse:1.25373
# [62]	validation_0-rmse:1.24943
# [63]	validation_0-rmse:1.24668
# [64]	validation_0-rmse:1.24330
# [65]	validation_0-rmse:1.23973
# [66]	validation_0-rmse:1.23663
# [67]	validation_0-rmse:1.23280
# [68]	validation_0-rmse:1.22824
# [69]	validation_0-rmse:1.22584
# [70]	validation_0-rmse:1.22234
# [71]	validation_0-rmse:1.21877
# [72]	validation_0-rmse:1.21654
# [73]	validation_0-rmse:1.21394
# [74]	validation_0-rmse:1.21172
# [75]	validation_0-rmse:1.20889
# [76]	validation_0-rmse:1.20710
# [77]	validation_0-rmse:1.20308
# [78]	validation_0-rmse:1.20000
# [79]	validation_0-rmse:1.19846
# [80]	validation_0-rmse:1.19604
# [81]	validation_0-rmse:1.19350
# [82]	validation_0-rmse:1.19127
# [83]	validation_0-rmse:1.18818
# [84]	validation_0-rmse:1.18583
# [85]	validation_0-rmse:1.18272
# [86]	validation_0-rmse:1.18049
# [87]	validation_0-rmse:1.17798
# [88]	validation_0-rmse:1.17571
# [89]	validation_0-rmse:1.17314
# [90]	validation_0-rmse:1.16939
# [91]	validation_0-rmse:1.16650
# [92]	validation_0-rmse:1.16404
# [93]	validation_0-rmse:1.16200
# [94]	validation_0-rmse:1.15941
# [95]	validation_0-rmse:1.15728
# [96]	validation_0-rmse:1.15558
# [97]	validation_0-rmse:1.15340
# [98]	validation_0-rmse:1.15159
# [99]	validation_0-rmse:1.14830
# [100]	validation_0-rmse:1.14633
# [101]	validation_0-rmse:1.14408
# [102]	validation_0-rmse:1.14122
# [103]	validation_0-rmse:1.14021
# [104]	validation_0-rmse:1.13873
# [105]	validation_0-rmse:1.13683
# [106]	validation_0-rmse:1.13518
# [107]	validation_0-rmse:1.13412
# [108]	validation_0-rmse:1.13214
# [109]	validation_0-rmse:1.12977
# [110]	validation_0-rmse:1.12801
# [111]	validation_0-rmse:1.12646
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 111

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.3
# Relative bias(%):  -47.75
# RMSE: 1.1
# Relative RMSE(%):  -198.911
# MSE: 1.3
# R square: 18.1%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-4.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.379
# Uncertainty
# a0: -0.217+/-0.018
# a1: 0.140+/-0.013

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../05_output_data/XGBoost_models/09_LN_Tag_Cs_SENTINEL_2020_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../05_output_data/XGBoost_models/09_LN_Tag_Cs_SENTINEL_2020_XGB_model.txt")
