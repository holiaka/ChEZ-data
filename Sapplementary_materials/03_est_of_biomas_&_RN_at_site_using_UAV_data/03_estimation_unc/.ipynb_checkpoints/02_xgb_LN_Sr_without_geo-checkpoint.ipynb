# %% [markdown]
# ## Processing with RN data obtained from forest sites

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../02_input_data/RN_sites_data.xlsx'
df = pd.read_excel(site_data, sheet_name='RN_filtration_data')
df.head()
# Out:
#    Ідентифікатор    Site # Species  Species_ID  Ntrees at site  % composition  \
# 0             81  001_2021    Pine           0              23     100.000000
# 1            219  002_2021    Pine           0              60      90.178571
# 2            224  003_2021    Pine           0              44     100.000000
# 3            228  004_2021    Pine           0              23     100.000000
# 4            232  005_2021    Pine           0              26     100.000000
#
#         D_cm        H_m    G_m2_ha  N_ha  ...   T_ag_Cs  ln_T_ag_Cs  \
# 0  26.060965  25.423284  49.081648   920  ...  0.781087   -0.247069
# 1   4.303100   4.705979   8.731641  6000  ...  1.549336    0.437826
# 2  28.142898  27.556869  54.703060   880  ...  0.583447   -0.538802
# 3  14.953551   8.506028  40.420188  2300  ...  0.145072   -1.930528
# 4   7.208435   3.425669   2.120687   520  ...  0.254295   -1.369259
#
#      T_ag_Sr  ln_T_ag_Sr  AEDR_count AEDR_mean  AEDR_median  AEDR_std  \
# 0   9.004084    2.197678          26  3.524231        3.530  0.235489
# 1  24.247024    3.188294          15  3.830667        3.780  0.166272
# 2   9.304047    2.230449          28  0.483571        0.475  0.068931
# 3   5.279971    1.663921          20  0.364500        0.365  0.029576
# 4   6.629225    1.891488          18  0.333333        0.345  0.036515
#
#    Distance_km  Azimuth
# 0     5.926403      249
# 1     6.018960      249
# 2    13.046428      189
# 3    12.741627      189
# 4    12.893213      189
#
# [5 rows x 51 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Species', 'Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
#                                     'Origin', 'Origin_ID','A_year', 'D_live_cm', 'H_live_m', 'G_live_m2_ha',
#                                     'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
#                                     'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_A_Cs', 'ln_A_Sr',
#                                     'T_ag_Cs', 'ln_T_ag_Cs', 'T_ag_Sr', 'ln_T_ag_Sr'
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species', 'Species_ID', '% composition', 'D_cm', 'H_m', 'G_m2_ha',
                                    'Origin', 'Origin_ID','A_year',
                                    'F_Soil_ID', 'M_Soil', 'AEDR_mean', 'Distance_km', 'Azimuth',
                                    'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_A_Cs', 'ln_A_Sr', 
                                    'ln_T_ag_Cs', 'ln_T_ag_Sr'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#   Species  Species_ID  % composition       D_cm        H_m    G_m2_ha Origin  \
# 0    Pine           0     100.000000  26.060965  25.423284  49.081648      a
# 1    Pine           0      90.178571   4.303100   4.705979   8.731641      n
# 2    Pine           0     100.000000  28.142898  27.556869  54.703060      n
# 3    Pine           0     100.000000  14.953551   8.506028  40.420188      n
# 4    Pine           0     100.000000   7.208435   3.425669   2.120687      n
#
#    Origin_ID  A_year  F_Soil_ID  M_Soil  AEDR_mean  Distance_km  Azimuth  \
# 0          1      68          1       2   3.524231     5.926403      249
# 1          0      15          1       2   3.830667     6.018960      249
# 2          0      69          1       2   0.483571    13.046428      189
# 3          0      15          2       2   0.364500    12.741627      189
# 4          0      10          2       2   0.333333    12.893213      189
#
#    Cs_2021_kBq_m  Sr_2021_kBq_m   ln_A_Cs    ln_A_Sr  ln_T_ag_Cs  ln_T_ag_Sr
# 0    2842.194109     998.435843  7.705262   9.103868   -0.247069    2.197678
# 1    2930.287815     987.750099  8.420682  10.083724    0.437826    3.188294
# 2     281.088291      65.777826  5.099866   6.416732   -0.538802    2.230449
# 3     289.512268      69.886752  3.737670   5.910797   -1.930528    1.663921
# 4     287.067816      69.993095  4.290459   6.139885   -1.369259    1.891488

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Species        209 non-null    object
#  1   Species_ID     209 non-null    int64
#  2   % composition  209 non-null    float64
#  3   D_cm           209 non-null    float64
#  4   H_m            209 non-null    float64
#  5   G_m2_ha        209 non-null    float64
#  6   Origin         209 non-null    object
#  7   Origin_ID      209 non-null    int64
#  8   A_year         209 non-null    int64
#  9   F_Soil_ID      209 non-null    int64
#  10  M_Soil         209 non-null    int64
#  11  AEDR_mean      209 non-null    float64
#  12  Distance_km    209 non-null    float64
#  13  Azimuth        209 non-null    int64
#  14  Cs_2021_kBq_m  209 non-null    float64
#  15  Sr_2021_kBq_m  209 non-null    float64
#  16  ln_A_Cs        209 non-null    float64
#  17  ln_A_Sr        209 non-null    float64
#  18  ln_T_ag_Cs     209 non-null    float64
#  19  ln_T_ag_Sr     209 non-null    float64
# dtypes: float64(12), int64(6), object(2)
# memory usage: 32.8+ KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species"])["ln_A_Cs", "ln_A_Sr"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#         ln_A_Cs                                                              \
#           count      mean       std       min       25%       50%       75%
# Species
# Alder      13.0  6.249674  1.661129  3.295837  5.840642  6.040255  6.940222
# Aspen       9.0  5.584313  3.039601  2.708050  3.295837  4.204693  6.729824
# Birch      45.0  5.737563  2.249143  2.079442  3.761200  6.173786  7.229839
# Oak         7.0  6.900674  2.917841  2.397895  4.966038  7.753624  9.021902
# Pine      130.0  6.066275  1.963371  1.504077  4.358932  6.564371  7.374614
# Red oak     3.0  3.445685  0.588708  2.833213  3.164860  3.496508  3.751920
# Robinia     1.0  4.394449       NaN  4.394449  4.394449  4.394449  4.394449
# Spruce      1.0  5.176150       NaN  5.176150  5.176150  5.176150  5.176150
#
#                    ln_A_Sr                                                    \
#                max   count      mean       std       min       25%       50%
# Species
# Alder     9.287301    13.0  6.055811  1.449620  4.094345  4.442651  6.302619
indep_variables = ['Species_ID', 'D_cm', 'F_Soil_ID', 'AEDR_mean',
    'Sr_2021_kBq_m']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#     Species  Species_ID  % composition       D_cm        H_m    G_m2_ha  \
# 0      Pine           0     100.000000  26.060965  25.423284  49.081648
# 1      Pine           0      90.178571   4.303100   4.705979   8.731641
# 2      Pine           0     100.000000  28.142898  27.556869  54.703060
# 3      Pine           0     100.000000  14.953551   8.506028  40.420188
# 4      Pine           0     100.000000   7.208435   3.425669   2.120687
# ..      ...         ...            ...        ...        ...        ...
# 204   Aspen           4      99.930119  11.401754  14.676282  17.972410
# 205   Birch           2     100.000000   7.912790  13.818368  19.279495
# 206    Pine           0     100.000000  16.041613  17.515821  31.533411
# 207    Pine           0      96.775081  14.946465  18.178975  44.220927
# 208    Pine           0     100.000000  15.387224  17.673021  55.824342
#
#     Origin  Origin_ID  A_year  F_Soil_ID  M_Soil  AEDR_mean  Distance_km  \
# 0        a          1      68          1       2   3.524231     5.926403
# 1        n          0      15          1       2   3.830667     6.018960
# 2        n          0      69          1       2   0.483571    13.046428
# 3        n          0      15          2       2   0.364500    12.741627
# 4        n          0      10          2       2   0.333333    12.893213
# ..     ...        ...     ...        ...     ...        ...          ...
# 204      n          0      25          2       3  20.051250     5.190617
# 205      n          0      18          2       3  14.987391     4.749715
# 206      a          1      58          1       2   0.650000     7.850538
# 207      a          1      60          1       2   0.649063     7.276525
# 208      a          1      40          1       2   0.628214     7.292122
#
#      Azimuth  Cs_2021_kBq_m  Sr_2021_kBq_m    ln_A_Cs    ln_A_Sr  ln_T_ag_Cs  \
# 0        249    2842.194109     998.435843   7.705262   9.103868   -0.247069
# 1        249    2930.287815     987.750099   8.420682  10.083724    0.437826
# 2        189     281.088291      65.777826   5.099866   6.416732   -0.538802
# 3        189     289.512268      69.886752   3.737670   5.910797   -1.930528
# 4        189     287.067816      69.993095   4.290459   6.139885   -1.369259
# ..       ...            ...            ...        ...        ...         ...
# 204      265   18333.074578    7311.788354  11.366743  11.089805    1.550281
# 205      262   22082.849575    8387.428089   9.539644  11.501865   -0.462912
# 206      106     539.850835     148.369587   6.498282   8.283999    0.206989
# 207       85     519.756852     136.839876   6.720220   8.575462    0.466859
# 208       86     518.079556     135.439932   6.674561   8.216088    0.424433
#
#      ln_T_ag_Sr
# 0      2.197678
# 1      3.188294
# 2      2.230449
# 3      1.663921
# 4      1.891488
# ..          ...
# 204    2.192562
# 205    2.467375
# 206    3.284293
# 207    3.656651
# 208    3.307560
#
# [209 rows x 20 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID       D_cm  F_Soil_ID  AEDR_mean  Sr_2021_kBq_m
# 0           0  26.060965          1   3.524231     998.435843
# 1           0   4.303100          1   3.830667     987.750099
# 2           0  28.142898          1   0.483571      65.777826
# 3           0  14.953551          2   0.364500      69.886752
# 4           0   7.208435          2   0.333333      69.993095

# %%
# Columns in "y" data collections
y.head()
# Out:
#      ln_A_Sr
# 0   9.103868
# 1  10.083724
# 2   6.416732
# 3   5.910797
# 4   6.139885

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.9001702936272359, 0.8150547282422951, 0.8102960845460616]
#     Mean: 0.842
#     Std: 0.041
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.84413884 0.73431336 0.79336352]
#     Mean: 0.791
#     Std: 0.045
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.6629927292182737, 0.6226772861041868, 0.6146598467457025]
#     Mean: 0.633
#     Std: 0.021
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.9482673629905486                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.37070054064216                    # gamma
print('Gamma: ' + str(p2))

p3 = 0.09384234909084563                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 4            # max_depth
print('Max_depth: ' + str(p4))

p5 = 68          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.5729627598530151                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.9482673629905486
# Gamma: 0.37070054064216
# Learning_rate: 0.09384234909084563
# Max_depth: 4
# N_estimators: 68
# Subsample: 0.5729627598530151

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    exp_R_square = r2_score(exp_y_test, exp_y_pred)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:6.52405	validation_1-rmse:6.64279
# [1]	validation_0-rmse:5.96101	validation_1-rmse:6.04840
# [2]	validation_0-rmse:5.42299	validation_1-rmse:5.50388
# [3]	validation_0-rmse:4.93837	validation_1-rmse:4.99005
# [4]	validation_0-rmse:4.52001	validation_1-rmse:4.56022
# [5]	validation_0-rmse:4.12722	validation_1-rmse:4.15152
# [6]	validation_0-rmse:3.77613	validation_1-rmse:3.78338
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:3.45153	validation_1-rmse:3.43642
# [8]	validation_0-rmse:3.15547	validation_1-rmse:3.12135
# [9]	validation_0-rmse:2.90020	validation_1-rmse:2.86098
# [10]	validation_0-rmse:2.66818	validation_1-rmse:2.63388
# [11]	validation_0-rmse:2.45023	validation_1-rmse:2.41981
# [12]	validation_0-rmse:2.25080	validation_1-rmse:2.22132
# [13]	validation_0-rmse:2.08328	validation_1-rmse:2.05524
# [14]	validation_0-rmse:1.92038	validation_1-rmse:1.92106
# [15]	validation_0-rmse:1.77779	validation_1-rmse:1.80968
# [16]	validation_0-rmse:1.64108	validation_1-rmse:1.69137
# [17]	validation_0-rmse:1.52604	validation_1-rmse:1.57698
# [18]	validation_0-rmse:1.41403	validation_1-rmse:1.46928
# [19]	validation_0-rmse:1.31044	validation_1-rmse:1.37960
# [20]	validation_0-rmse:1.22422	validation_1-rmse:1.29874
# [21]	validation_0-rmse:1.13925	validation_1-rmse:1.22602
# [22]	validation_0-rmse:1.06841	validation_1-rmse:1.16962
# [23]	validation_0-rmse:1.01092	validation_1-rmse:1.12404
# [24]	validation_0-rmse:0.95499	validation_1-rmse:1.09376
# [25]	validation_0-rmse:0.90707	validation_1-rmse:1.06708
# [26]	validation_0-rmse:0.85765	validation_1-rmse:1.02647
# [27]	validation_0-rmse:0.81511	validation_1-rmse:1.00047
# [28]	validation_0-rmse:0.77849	validation_1-rmse:0.97231
# [29]	validation_0-rmse:0.74477	validation_1-rmse:0.95131
# [30]	validation_0-rmse:0.71033	validation_1-rmse:0.93055
# [31]	validation_0-rmse:0.67817	validation_1-rmse:0.90041
# [32]	validation_0-rmse:0.65105	validation_1-rmse:0.88957
# [33]	validation_0-rmse:0.62726	validation_1-rmse:0.87576
# [34]	validation_0-rmse:0.60209	validation_1-rmse:0.85347
# [35]	validation_0-rmse:0.58377	validation_1-rmse:0.84030
# [36]	validation_0-rmse:0.56967	validation_1-rmse:0.83769
# [37]	validation_0-rmse:0.55285	validation_1-rmse:0.82390
# [38]	validation_0-rmse:0.53752	validation_1-rmse:0.81046
# [39]	validation_0-rmse:0.52620	validation_1-rmse:0.80161
# [40]	validation_0-rmse:0.51495	validation_1-rmse:0.79887
# [41]	validation_0-rmse:0.50608	validation_1-rmse:0.79491
# [42]	validation_0-rmse:0.49414	validation_1-rmse:0.79159
# [43]	validation_0-rmse:0.48455	validation_1-rmse:0.79042
# [44]	validation_0-rmse:0.47638	validation_1-rmse:0.78365
# [45]	validation_0-rmse:0.47007	validation_1-rmse:0.78217
# [46]	validation_0-rmse:0.46220	validation_1-rmse:0.77637
# [47]	validation_0-rmse:0.45692	validation_1-rmse:0.77078
# [48]	validation_0-rmse:0.45214	validation_1-rmse:0.76852
# [49]	validation_0-rmse:0.44533	validation_1-rmse:0.76361
# [50]	validation_0-rmse:0.43987	validation_1-rmse:0.76342
# [51]	validation_0-rmse:0.43455	validation_1-rmse:0.76215
# [52]	validation_0-rmse:0.43101	validation_1-rmse:0.76136
# [53]	validation_0-rmse:0.42589	validation_1-rmse:0.76165
# [54]	validation_0-rmse:0.42262	validation_1-rmse:0.75986
# [55]	validation_0-rmse:0.41864	validation_1-rmse:0.75960
# [56]	validation_0-rmse:0.41339	validation_1-rmse:0.76054
# [57]	validation_0-rmse:0.41110	validation_1-rmse:0.75591
# [58]	validation_0-rmse:0.40962	validation_1-rmse:0.75623
# [59]	validation_0-rmse:0.40783	validation_1-rmse:0.75572
# [60]	validation_0-rmse:0.40454	validation_1-rmse:0.75523
# [61]	validation_0-rmse:0.40269	validation_1-rmse:0.75444
# [62]	validation_0-rmse:0.39978	validation_1-rmse:0.75440
# [63]	validation_0-rmse:0.39647	validation_1-rmse:0.75323
# [64]	validation_0-rmse:0.39443	validation_1-rmse:0.75466
# [65]	validation_0-rmse:0.39181	validation_1-rmse:0.75063
# [66]	validation_0-rmse:0.38653	validation_1-rmse:0.75356
# [67]	validation_0-rmse:0.38146	validation_1-rmse:0.75289
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:6.56707	validation_1-rmse:6.52700
# [1]	validation_0-rmse:5.99001	validation_1-rmse:5.95215
# [2]	validation_0-rmse:5.46748	validation_1-rmse:5.45599
# [3]	validation_0-rmse:4.99750	validation_1-rmse:4.98319
# [4]	validation_0-rmse:4.56642	validation_1-rmse:4.58543
# [5]	validation_0-rmse:4.17824	validation_1-rmse:4.22048
# [6]	validation_0-rmse:3.81958	validation_1-rmse:3.88122
# [7]	validation_0-rmse:3.49481	validation_1-rmse:3.56315
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:3.19755	validation_1-rmse:3.26023
# [9]	validation_0-rmse:2.93643	validation_1-rmse:2.99762
# [10]	validation_0-rmse:2.70137	validation_1-rmse:2.77455
# [11]	validation_0-rmse:2.48477	validation_1-rmse:2.56250
# [12]	validation_0-rmse:2.28745	validation_1-rmse:2.36449
# [13]	validation_0-rmse:2.10070	validation_1-rmse:2.20151
# [14]	validation_0-rmse:1.94716	validation_1-rmse:2.03891
# [15]	validation_0-rmse:1.80193	validation_1-rmse:1.89700
# [16]	validation_0-rmse:1.66952	validation_1-rmse:1.77184
# [17]	validation_0-rmse:1.54445	validation_1-rmse:1.65722
# [18]	validation_0-rmse:1.43311	validation_1-rmse:1.55380
# [19]	validation_0-rmse:1.34089	validation_1-rmse:1.47406
# [20]	validation_0-rmse:1.24430	validation_1-rmse:1.38808
# [21]	validation_0-rmse:1.15600	validation_1-rmse:1.30911
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:6.62203	validation_1-rmse:6.17069
# [1]	validation_0-rmse:6.02593	validation_1-rmse:5.61060
# [2]	validation_0-rmse:5.51795	validation_1-rmse:5.10918
# [3]	validation_0-rmse:5.03539	validation_1-rmse:4.66745
# [4]	validation_0-rmse:4.60610	validation_1-rmse:4.24575
# [5]	validation_0-rmse:4.20309	validation_1-rmse:3.87083
# [6]	validation_0-rmse:3.83623	validation_1-rmse:3.51538
# [7]	validation_0-rmse:3.51292	validation_1-rmse:3.22425
# [8]	validation_0-rmse:3.22002	validation_1-rmse:2.95354
# [9]	validation_0-rmse:2.95776	validation_1-rmse:2.71996
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [10]	validation_0-rmse:2.71221	validation_1-rmse:2.50848
# [11]	validation_0-rmse:2.49897	validation_1-rmse:2.31516
# [12]	validation_0-rmse:2.30205	validation_1-rmse:2.13376
# [13]	validation_0-rmse:2.13216	validation_1-rmse:1.97744
# [14]	validation_0-rmse:1.96819	validation_1-rmse:1.82417
# [15]	validation_0-rmse:1.81650	validation_1-rmse:1.69911
# [16]	validation_0-rmse:1.67157	validation_1-rmse:1.57024
# [17]	validation_0-rmse:1.55834	validation_1-rmse:1.47999
# [18]	validation_0-rmse:1.45100	validation_1-rmse:1.38534
# [19]	validation_0-rmse:1.34949	validation_1-rmse:1.30710
# [20]	validation_0-rmse:1.25917	validation_1-rmse:1.23221
# [21]	validation_0-rmse:1.17430	validation_1-rmse:1.16759
# [22]	validation_0-rmse:1.09877	validation_1-rmse:1.11015
# [23]	validation_0-rmse:1.01945	validation_1-rmse:1.05352
# [24]	validation_0-rmse:0.95921	validation_1-rmse:1.01067
# [25]	validation_0-rmse:0.90430	validation_1-rmse:0.97306
# [26]	validation_0-rmse:0.84969	validation_1-rmse:0.94279
# [27]	validation_0-rmse:0.81166	validation_1-rmse:0.90917
# [28]	validation_0-rmse:0.77685	validation_1-rmse:0.88454
# [29]	validation_0-rmse:0.73989	validation_1-rmse:0.85626
# [30]	validation_0-rmse:0.71297	validation_1-rmse:0.83233
# [31]	validation_0-rmse:0.67999	validation_1-rmse:0.81644
# [32]	validation_0-rmse:0.65231	validation_1-rmse:0.80353
# [33]	validation_0-rmse:0.63476	validation_1-rmse:0.79711
# [34]	validation_0-rmse:0.61712	validation_1-rmse:0.78663
# [35]	validation_0-rmse:0.59797	validation_1-rmse:0.78278
# [36]	validation_0-rmse:0.58306	validation_1-rmse:0.77093
# [37]	validation_0-rmse:0.56799	validation_1-rmse:0.76742
# [38]	validation_0-rmse:0.55387	validation_1-rmse:0.76944
# [39]	validation_0-rmse:0.54320	validation_1-rmse:0.76403
# [40]	validation_0-rmse:0.53465	validation_1-rmse:0.75791
# [41]	validation_0-rmse:0.52061	validation_1-rmse:0.75382
# [42]	validation_0-rmse:0.51215	validation_1-rmse:0.75605
# [43]	validation_0-rmse:0.50416	validation_1-rmse:0.75055
# [44]	validation_0-rmse:0.50117	validation_1-rmse:0.74926
# [45]	validation_0-rmse:0.49389	validation_1-rmse:0.74888
# [46]	validation_0-rmse:0.48638	validation_1-rmse:0.74519
# [47]	validation_0-rmse:0.48003	validation_1-rmse:0.74199
# [48]	validation_0-rmse:0.47175	validation_1-rmse:0.74610
# [49]	validation_0-rmse:0.46477	validation_1-rmse:0.74802
# [50]	validation_0-rmse:0.46076	validation_1-rmse:0.74148
# [51]	validation_0-rmse:0.45724	validation_1-rmse:0.73835
# [30]	validation_0-rmse:0.73053	validation_1-rmse:0.79452
# [31]	validation_0-rmse:0.70121	validation_1-rmse:0.78008
# [32]	validation_0-rmse:0.67480	validation_1-rmse:0.75599
# [33]	validation_0-rmse:0.64850	validation_1-rmse:0.73854
# [34]	validation_0-rmse:0.62831	validation_1-rmse:0.72366
# [35]	validation_0-rmse:0.60910	validation_1-rmse:0.71044
# [36]	validation_0-rmse:0.59524	validation_1-rmse:0.70628
# [37]	validation_0-rmse:0.57841	validation_1-rmse:0.69174
# [38]	validation_0-rmse:0.56226	validation_1-rmse:0.68796
# [39]	validation_0-rmse:0.54926	validation_1-rmse:0.68218
# [40]	validation_0-rmse:0.53789	validation_1-rmse:0.67291
# [41]	validation_0-rmse:0.52663	validation_1-rmse:0.66555
# [42]	validation_0-rmse:0.51712	validation_1-rmse:0.66690
# [43]	validation_0-rmse:0.50898	validation_1-rmse:0.66772
# [44]	validation_0-rmse:0.50276	validation_1-rmse:0.66666
# [45]	validation_0-rmse:0.49595	validation_1-rmse:0.66887
# [46]	validation_0-rmse:0.48527	validation_1-rmse:0.66788
# [47]	validation_0-rmse:0.47742	validation_1-rmse:0.66866
# [48]	validation_0-rmse:0.47081	validation_1-rmse:0.67039
# [49]	validation_0-rmse:0.46573	validation_1-rmse:0.66828
# [50]	validation_0-rmse:0.45935	validation_1-rmse:0.66896
# [51]	validation_0-rmse:0.45534	validation_1-rmse:0.66951
# [52]	validation_0-rmse:0.45120	validation_1-rmse:0.67276
# [53]	validation_0-rmse:0.44740	validation_1-rmse:0.67086
# [54]	validation_0-rmse:0.44334	validation_1-rmse:0.67114
# [55]	validation_0-rmse:0.43662	validation_1-rmse:0.67218
# [56]	validation_0-rmse:0.43114	validation_1-rmse:0.67453
# [57]	validation_0-rmse:0.42710	validation_1-rmse:0.67340
# [58]	validation_0-rmse:0.42406	validation_1-rmse:0.67411
# [59]	validation_0-rmse:0.41894	validation_1-rmse:0.67844
# [60]	validation_0-rmse:0.41305	validation_1-rmse:0.67339
# [61]	validation_0-rmse:0.40786	validation_1-rmse:0.67588
# [0]	validation_0-rmse:6.34965	validation_1-rmse:7.35840
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:5.78066	validation_1-rmse:6.76003
# [2]	validation_0-rmse:5.27209	validation_1-rmse:6.23826
# [3]	validation_0-rmse:4.81039	validation_1-rmse:5.74253
# [4]	validation_0-rmse:4.40202	validation_1-rmse:5.31056
# [5]	validation_0-rmse:4.01345	validation_1-rmse:4.89988
# [6]	validation_0-rmse:3.66310	validation_1-rmse:4.52440
# [7]	validation_0-rmse:3.34036	validation_1-rmse:4.19007
# [8]	validation_0-rmse:3.05310	validation_1-rmse:3.88182
# [9]	validation_0-rmse:2.80559	validation_1-rmse:3.63631
# [10]	validation_0-rmse:2.57290	validation_1-rmse:3.39722
# [11]	validation_0-rmse:2.35598	validation_1-rmse:3.16800
# [12]	validation_0-rmse:2.15920	validation_1-rmse:2.95897
# [13]	validation_0-rmse:1.98232	validation_1-rmse:2.77169
# [14]	validation_0-rmse:1.83958	validation_1-rmse:2.61980
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:5.34482	validation_1-rmse:5.92628
# [3]	validation_0-rmse:4.86237	validation_1-rmse:5.42000
# [4]	validation_0-rmse:4.45746	validation_1-rmse:5.00413
# [5]	validation_0-rmse:4.06257	validation_1-rmse:4.59462
# [6]	validation_0-rmse:3.71941	validation_1-rmse:4.23905
# [7]	validation_0-rmse:3.40126	validation_1-rmse:3.90971
# [8]	validation_0-rmse:3.11800	validation_1-rmse:3.63196
# [9]	validation_0-rmse:2.85478	validation_1-rmse:3.37196
# [10]	validation_0-rmse:2.61682	validation_1-rmse:3.13703
# [11]	validation_0-rmse:2.40851	validation_1-rmse:2.92040
# [12]	validation_0-rmse:2.21928	validation_1-rmse:2.71836
# [13]	validation_0-rmse:2.04092	validation_1-rmse:2.54096
# [14]	validation_0-rmse:1.87954	validation_1-rmse:2.36650
# ...
# [19]	validation_0-rmse:1.32508	validation_1-rmse:1.43655
# [20]	validation_0-rmse:1.23821	validation_1-rmse:1.36023
# [21]	validation_0-rmse:1.15858	validation_1-rmse:1.30412
# [22]	validation_0-rmse:1.08200	validation_1-rmse:1.24297
# [23]	validation_0-rmse:1.01800	validation_1-rmse:1.19850
# [24]	validation_0-rmse:0.96197	validation_1-rmse:1.14982
# [25]	validation_0-rmse:0.90661	validation_1-rmse:1.10285
# [26]	validation_0-rmse:0.85844	validation_1-rmse:1.06518
# [27]	validation_0-rmse:0.81265	validation_1-rmse:1.04879
# [28]	validation_0-rmse:0.76989	validation_1-rmse:1.04196
# [29]	validation_0-rmse:0.73265	validation_1-rmse:1.01787
# [30]	validation_0-rmse:0.69854	validation_1-rmse:0.99264
# [31]	validation_0-rmse:0.66614	validation_1-rmse:0.96417
# [32]	validation_0-rmse:0.63654	validation_1-rmse:0.94296
# [33]	validation_0-rmse:0.61770	validation_1-rmse:0.93018
# [34]	validation_0-rmse:0.59606	validation_1-rmse:0.91436
# [35]	validation_0-rmse:0.57778	validation_1-rmse:0.90942
# [36]	validation_0-rmse:0.56258	validation_1-rmse:0.90379
# [37]	validation_0-rmse:0.55037	validation_1-rmse:0.89636
# [38]	validation_0-rmse:0.53832	validation_1-rmse:0.88574
# [39]	validation_0-rmse:0.52780	validation_1-rmse:0.87963
# [40]	validation_0-rmse:0.51724	validation_1-rmse:0.87955
# [41]	validation_0-rmse:0.50741	validation_1-rmse:0.87450
# [42]	validation_0-rmse:0.50089	validation_1-rmse:0.86980
# [43]	validation_0-rmse:0.49041	validation_1-rmse:0.86882
# [44]	validation_0-rmse:0.48388	validation_1-rmse:0.86580
# [45]	validation_0-rmse:0.47723	validation_1-rmse:0.86483
# [46]	validation_0-rmse:0.46995	validation_1-rmse:0.86674
# [47]	validation_0-rmse:0.46311	validation_1-rmse:0.87515
# [48]	validation_0-rmse:0.46089	validation_1-rmse:0.87283
# [49]	validation_0-rmse:0.45453	validation_1-rmse:0.86698
# [50]	validation_0-rmse:0.44669	validation_1-rmse:0.86624
# [51]	validation_0-rmse:0.43892	validation_1-rmse:0.86427
# [52]	validation_0-rmse:0.43507	validation_1-rmse:0.86781
# [53]	validation_0-rmse:0.42969	validation_1-rmse:0.86363
# [54]	validation_0-rmse:0.42534	validation_1-rmse:0.86398
# [55]	validation_0-rmse:0.42199	validation_1-rmse:0.86502
# [56]	validation_0-rmse:0.41565	validation_1-rmse:0.85888
# [57]	validation_0-rmse:0.41080	validation_1-rmse:0.86347
# [58]	validation_0-rmse:0.40627	validation_1-rmse:0.86352
# [59]	validation_0-rmse:0.40243	validation_1-rmse:0.86383
# [60]	validation_0-rmse:0.39919	validation_1-rmse:0.86273
# [61]	validation_0-rmse:0.39591	validation_1-rmse:0.85894
# [62]	validation_0-rmse:0.39173	validation_1-rmse:0.86228
# [63]	validation_0-rmse:0.38839	validation_1-rmse:0.85987
# [64]	validation_0-rmse:0.38735	validation_1-rmse:0.86068
# [65]	validation_0-rmse:0.38569	validation_1-rmse:0.85866
# [66]	validation_0-rmse:0.38093	validation_1-rmse:0.85256
# [67]	validation_0-rmse:0.37859	validation_1-rmse:0.84756
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.53108	validation_1-rmse:6.56645
# [1]	validation_0-rmse:5.96764	validation_1-rmse:6.00492
# [2]	validation_0-rmse:5.44608	validation_1-rmse:5.45780
# [3]	validation_0-rmse:4.96091	validation_1-rmse:4.94615
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:4.53938	validation_1-rmse:4.53333
# [5]	validation_0-rmse:4.15566	validation_1-rmse:4.13796
# [6]	validation_0-rmse:3.79999	validation_1-rmse:3.75993
# [7]	validation_0-rmse:3.48595	validation_1-rmse:3.42930
# [8]	validation_0-rmse:3.19250	validation_1-rmse:3.12437
# [9]	validation_0-rmse:2.93576	validation_1-rmse:2.85563
# [10]	validation_0-rmse:2.68745	validation_1-rmse:2.59229
# [11]	validation_0-rmse:2.46062	validation_1-rmse:2.35461
# [12]	validation_0-rmse:2.25785	validation_1-rmse:2.15441
# [13]	validation_0-rmse:2.06478	validation_1-rmse:1.95567
# [14]	validation_0-rmse:1.91079	validation_1-rmse:1.78900
# [15]	validation_0-rmse:1.76185	validation_1-rmse:1.63269
# [16]	validation_0-rmse:1.63526	validation_1-rmse:1.51389
# [17]	validation_0-rmse:1.52064	validation_1-rmse:1.40551
# [18]	validation_0-rmse:1.41067	validation_1-rmse:1.29418
# [19]	validation_0-rmse:1.32094	validation_1-rmse:1.21013
# [20]	validation_0-rmse:1.23888	validation_1-rmse:1.13758
# [21]	validation_0-rmse:1.15651	validation_1-rmse:1.07344
# [22]	validation_0-rmse:1.07944	validation_1-rmse:1.01417
# [23]	validation_0-rmse:1.01606	validation_1-rmse:0.96477
# [24]	validation_0-rmse:0.95749	validation_1-rmse:0.92520
# [25]	validation_0-rmse:0.90074	validation_1-rmse:0.88563
# [26]	validation_0-rmse:0.85261	validation_1-rmse:0.85531
# [27]	validation_0-rmse:0.81512	validation_1-rmse:0.83576
# [28]	validation_0-rmse:0.77979	validation_1-rmse:0.81201
# [29]	validation_0-rmse:0.74766	validation_1-rmse:0.80234
# [30]	validation_0-rmse:0.70991	validation_1-rmse:0.78077
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [9]	validation_0-rmse:2.87099	validation_1-rmse:3.11098
# [10]	validation_0-rmse:2.63084	validation_1-rmse:2.85941
# [11]	validation_0-rmse:2.40635	validation_1-rmse:2.62093
# [12]	validation_0-rmse:2.21386	validation_1-rmse:2.41585
# [13]	validation_0-rmse:2.04204	validation_1-rmse:2.23728
# [14]	validation_0-rmse:1.88694	validation_1-rmse:2.08634
# [15]	validation_0-rmse:1.74772	validation_1-rmse:1.93468
# [16]	validation_0-rmse:1.62692	validation_1-rmse:1.81286
# [17]	validation_0-rmse:1.51098	validation_1-rmse:1.70434
# [18]	validation_0-rmse:1.40102	validation_1-rmse:1.58416
# [19]	validation_0-rmse:1.29614	validation_1-rmse:1.47455
# [20]	validation_0-rmse:1.20762	validation_1-rmse:1.38245
# [21]	validation_0-rmse:1.12434	validation_1-rmse:1.29809
# [22]	validation_0-rmse:1.04778	validation_1-rmse:1.22429
# [23]	validation_0-rmse:0.98535	validation_1-rmse:1.16333
# [24]	validation_0-rmse:0.93701	validation_1-rmse:1.11342
# [25]	validation_0-rmse:0.88187	validation_1-rmse:1.06247
# [26]	validation_0-rmse:0.83181	validation_1-rmse:1.01109
# [27]	validation_0-rmse:0.79305	validation_1-rmse:0.97547
# [28]	validation_0-rmse:0.75360	validation_1-rmse:0.93725
# [29]	validation_0-rmse:0.72224	validation_1-rmse:0.90457
# [30]	validation_0-rmse:0.69372	validation_1-rmse:0.87679
# [31]	validation_0-rmse:0.67072	validation_1-rmse:0.85451
# [32]	validation_0-rmse:0.65223	validation_1-rmse:0.83882
# [33]	validation_0-rmse:0.63196	validation_1-rmse:0.81824
# [34]	validation_0-rmse:0.60834	validation_1-rmse:0.80289
# [35]	validation_0-rmse:0.59273	validation_1-rmse:0.78918
# [36]	validation_0-rmse:0.57737	validation_1-rmse:0.77927
# [37]	validation_0-rmse:0.56413	validation_1-rmse:0.77063
# [38]	validation_0-rmse:0.54681	validation_1-rmse:0.76290
# [39]	validation_0-rmse:0.53412	validation_1-rmse:0.75639
# [40]	validation_0-rmse:0.52278	validation_1-rmse:0.74611
# [41]	validation_0-rmse:0.51502	validation_1-rmse:0.74018
# [42]	validation_0-rmse:0.50213	validation_1-rmse:0.73810
# [43]	validation_0-rmse:0.49590	validation_1-rmse:0.73509
# [44]	validation_0-rmse:0.48573	validation_1-rmse:0.73308
# [45]	validation_0-rmse:0.47874	validation_1-rmse:0.72746
# [46]	validation_0-rmse:0.47203	validation_1-rmse:0.72543
# [47]	validation_0-rmse:0.46555	validation_1-rmse:0.72005
# [48]	validation_0-rmse:0.46030	validation_1-rmse:0.71975
# [49]	validation_0-rmse:0.45633	validation_1-rmse:0.71818
# [50]	validation_0-rmse:0.45270	validation_1-rmse:0.71815
# [51]	validation_0-rmse:0.44840	validation_1-rmse:0.71942
# [52]	validation_0-rmse:0.44443	validation_1-rmse:0.71795
# [53]	validation_0-rmse:0.44057	validation_1-rmse:0.71895
# [54]	validation_0-rmse:0.43588	validation_1-rmse:0.72057
# [55]	validation_0-rmse:0.42885	validation_1-rmse:0.72064
# [56]	validation_0-rmse:0.42525	validation_1-rmse:0.72344
# [57]	validation_0-rmse:0.42240	validation_1-rmse:0.72520
# [58]	validation_0-rmse:0.41828	validation_1-rmse:0.72745
# [59]	validation_0-rmse:0.41449	validation_1-rmse:0.72998
# [60]	validation_0-rmse:0.40953	validation_1-rmse:0.72756
# [61]	validation_0-rmse:0.40302	validation_1-rmse:0.73027
# [62]	validation_0-rmse:0.40090	validation_1-rmse:0.72788
# [63]	validation_0-rmse:0.39778	validation_1-rmse:0.73108
# [64]	validation_0-rmse:0.39429	validation_1-rmse:0.73249
# [65]	validation_0-rmse:0.39082	validation_1-rmse:0.73426
# [66]	validation_0-rmse:0.38774	validation_1-rmse:0.73093
# [67]	validation_0-rmse:0.38398	validation_1-rmse:0.73067
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.66818	validation_1-rmse:5.98533
# [1]	validation_0-rmse:6.07953	validation_1-rmse:5.45037
# [2]	validation_0-rmse:5.55590	validation_1-rmse:4.95093
# [3]	validation_0-rmse:5.06662	validation_1-rmse:4.50078
# [4]	validation_0-rmse:4.63299	validation_1-rmse:4.11890
# [5]	validation_0-rmse:4.22990	validation_1-rmse:3.74369
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:3.87873	validation_1-rmse:3.43498
# [7]	validation_0-rmse:3.54573	validation_1-rmse:3.13992
# [8]	validation_0-rmse:3.25173	validation_1-rmse:2.87024
# [9]	validation_0-rmse:3.00634	validation_1-rmse:2.62708
# [10]	validation_0-rmse:2.76726	validation_1-rmse:2.41996
# [11]	validation_0-rmse:2.54714	validation_1-rmse:2.22403
# [12]	validation_0-rmse:2.35543	validation_1-rmse:2.04534
# [13]	validation_0-rmse:2.17169	validation_1-rmse:1.88854
# [14]	validation_0-rmse:2.01411	validation_1-rmse:1.76105
# [15]	validation_0-rmse:1.86240	validation_1-rmse:1.63849
# [16]	validation_0-rmse:1.72696	validation_1-rmse:1.50602
# [17]	validation_0-rmse:1.60431	validation_1-rmse:1.41952
# [18]	validation_0-rmse:1.49680	validation_1-rmse:1.33611
# [19]	validation_0-rmse:1.38972	validation_1-rmse:1.24876
# [20]	validation_0-rmse:1.29917	validation_1-rmse:1.17166
# [21]	validation_0-rmse:1.22297	validation_1-rmse:1.11159
# [22]	validation_0-rmse:1.14661	validation_1-rmse:1.06469
# [23]	validation_0-rmse:1.07726	validation_1-rmse:1.01048
# [24]	validation_0-rmse:1.00929	validation_1-rmse:0.96067
# [25]	validation_0-rmse:0.95403	validation_1-rmse:0.92073
# [26]	validation_0-rmse:0.90448	validation_1-rmse:0.88400
# [27]	validation_0-rmse:0.86078	validation_1-rmse:0.85346
# [28]	validation_0-rmse:0.82269	validation_1-rmse:0.82921
# [29]	validation_0-rmse:0.78278	validation_1-rmse:0.80055
# [30]	validation_0-rmse:0.74485	validation_1-rmse:0.77026
# [31]	validation_0-rmse:0.71406	validation_1-rmse:0.74747
# [32]	validation_0-rmse:0.69087	validation_1-rmse:0.73811
# [33]	validation_0-rmse:0.67500	validation_1-rmse:0.73047
# [34]	validation_0-rmse:0.65774	validation_1-rmse:0.71825
# [35]	validation_0-rmse:0.63892	validation_1-rmse:0.70466
# [36]	validation_0-rmse:0.62117	validation_1-rmse:0.69317
# [37]	validation_0-rmse:0.60098	validation_1-rmse:0.67597
# [38]	validation_0-rmse:0.58617	validation_1-rmse:0.66682
# [39]	validation_0-rmse:0.57189	validation_1-rmse:0.65907
# [40]	validation_0-rmse:0.56316	validation_1-rmse:0.65118
# [41]	validation_0-rmse:0.55411	validation_1-rmse:0.64661
# [42]	validation_0-rmse:0.54539	validation_1-rmse:0.64145
# [43]	validation_0-rmse:0.53723	validation_1-rmse:0.64206
# [44]	validation_0-rmse:0.52926	validation_1-rmse:0.63446
# [45]	validation_0-rmse:0.52258	validation_1-rmse:0.63448
# [46]	validation_0-rmse:0.51345	validation_1-rmse:0.63023
# [47]	validation_0-rmse:0.50923	validation_1-rmse:0.63385
# [48]	validation_0-rmse:0.50256	validation_1-rmse:0.63250
# [49]	validation_0-rmse:0.49574	validation_1-rmse:0.63944
# [50]	validation_0-rmse:0.48849	validation_1-rmse:0.63955
# [51]	validation_0-rmse:0.48213	validation_1-rmse:0.63569
# [52]	validation_0-rmse:0.47900	validation_1-rmse:0.63577
# [53]	validation_0-rmse:0.47279	validation_1-rmse:0.63254
# [54]	validation_0-rmse:0.46482	validation_1-rmse:0.63218
# [55]	validation_0-rmse:0.45884	validation_1-rmse:0.62410
# [56]	validation_0-rmse:0.45305	validation_1-rmse:0.62133
# [57]	validation_0-rmse:0.44813	validation_1-rmse:0.61387
# [58]	validation_0-rmse:0.44336	validation_1-rmse:0.61362
# [59]	validation_0-rmse:0.43909	validation_1-rmse:0.61019
# [60]	validation_0-rmse:0.43633	validation_1-rmse:0.60943
# [61]	validation_0-rmse:0.43354	validation_1-rmse:0.60821
# [62]	validation_0-rmse:0.43051	validation_1-rmse:0.60678
# [63]	validation_0-rmse:0.42702	validation_1-rmse:0.61118
# [64]	validation_0-rmse:0.42608	validation_1-rmse:0.61144
# [65]	validation_0-rmse:0.42188	validation_1-rmse:0.60636
# [66]	validation_0-rmse:0.41751	validation_1-rmse:0.60273
# [67]	validation_0-rmse:0.41441	validation_1-rmse:0.60045
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(2, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.862
# Uncertainty
# a0: 1.089+/-0.178
# a1: 0.845+/-0.025

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: AEDR_mean: mean - 0.351, median - 0.348, CI - [0.318-0.383]
#
# SHAP-values for: D_cm: mean - 0.221, median - 0.222, CI - [0.198-0.245]
#
# SHAP-values for: F_Soil_ID: mean - 0.175, median - 0.177, CI - [0.153-0.199]
#
# SHAP-values for: Species_ID: mean - 0.093, median - 0.093, CI - [0.074-0.107]
#
# SHAP-values for: Sr_2021_kBq_m: mean - 1.103, median - 1.103, CI - [1.051-1.154]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['Sr_2021_kBq_m', 'AEDR_mean', 'D_cm', 'F_Soil_ID', 'Species_ID'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 60.685, median: 63.0,
#  pred. interval (P(0.025)-P(0.975)): 40.975-67.0,
#  conf. interval (p-value=0.95): 55.684-66.586
# ***
# Aggregate bias statistic:
#  mean: -0.056, median: -0.056,
#  pred. interval (P(0.025)-P(0.975)): -0.31-0.189,
#  conf. interval (p-value=0.95): -0.161-0.052
# ***
# Aggregate RMSE statistic:
#  mean: 0.755, median: 0.762, pred. interval (P(0.025)-P(0.975)): 0.567-0.9,
#  conf. interval (p-value=0.95): 0.668-0.838
# ***
# Aggregate MSE statistic:
#  mean: 0.578, median: 0.58, pred. interval (P(0.025)-P(0.975)): 0.321-0.81,
#  conf. interval (p-value=0.95): 0.448-0.703
# ***
# Aggregate R^2 statistic:
#  mean: 0.854, median: 0.854, pred. interval (P(0.025)-P(0.975)): 0.78-0.92,
#  conf. interval (p-value=0.95): 0.822-0.886
# ***
# Aggregate bias(%) statistic:
#  mean: -0.724, median: -0.755, pred. interval (P(0.025)-P(0.975)): -4.027-2.565,
#  conf. interval (p-value=0.95): -2.126-0.681
# ***
# Aggregate RMSE(%) statistic:
#  mean: 10.212, median: 10.274, pred. interval (P(0.025)-P(0.975)): 7.665-12.757,
#  conf. interval (p-value=0.95): 8.975-11.276
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -7075.644, median: -2135.882,
#  pred. interval (P(0.025)-P(0.975)): -32020.126-755.596,
#  conf. interval (p-value=0.95): -20925.85--760.882
# ***
# Aggregate RMSE statistic:
#  mean: 38721.986, median: 10885.569, pred. interval (P(0.025)-P(0.975)): 3242.594-155337.027,
#  conf. interval (p-value=0.95): 5852.282-127311.193
# ***
# Aggregate MSE statistic:
#  mean: 4638831333.274, median: 118519043.915, pred. interval (P(0.025)-P(0.975)): 10517279.241-24129609006.137,
#  conf. interval (p-value=0.95): 37174446.14-17771963164.286
# ***
# Aggregate R^2 statistic:
#  mean: 0.645, median: 0.737, pred. interval (P(0.025)-P(0.975)): 0.121-0.974,
#  conf. interval (p-value=0.95): 0.276-0.891
# ***
# Aggregate bias(%) statistic:
#  mean: -30.104, median: -24.631, pred. interval (P(0.025)-P(0.975)): -79.569-10.141,
#  conf. interval (p-value=0.95): -66.285--8.925
# ***
# Aggregate RMSE(%) statistic:
#  mean: 169.502, median: 113.664, pred. interval (P(0.025)-P(0.975)): 46.749-467.307,
#  conf. interval (p-value=0.95): 79.057-350.818
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [0, 3, 6, 9, 12, 15])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 1000, 10000, 50000, 100000, 1000000])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:6.54388
# [1]	validation_0-rmse:5.96044
# [2]	validation_0-rmse:5.44956
# [3]	validation_0-rmse:4.96728
# [4]	validation_0-rmse:4.52966
# [5]	validation_0-rmse:4.14037
# [6]	validation_0-rmse:3.78498
# [7]	validation_0-rmse:3.46444
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:3.17135
# [9]	validation_0-rmse:2.90115
# [10]	validation_0-rmse:2.66311
# [11]	validation_0-rmse:2.44642
# [12]	validation_0-rmse:2.25773
# [13]	validation_0-rmse:2.07601
# [14]	validation_0-rmse:1.91630
# [15]	validation_0-rmse:1.77154
# [16]	validation_0-rmse:1.63511
# [17]	validation_0-rmse:1.51463
# [18]	validation_0-rmse:1.40498
# [19]	validation_0-rmse:1.30985
# [20]	validation_0-rmse:1.22575
# [21]	validation_0-rmse:1.14084
# [22]	validation_0-rmse:1.06555
# [23]	validation_0-rmse:1.00401
# [24]	validation_0-rmse:0.94180
# [25]	validation_0-rmse:0.89317
# [26]	validation_0-rmse:0.85055
# [27]	validation_0-rmse:0.81096
# [28]	validation_0-rmse:0.77240
# [29]	validation_0-rmse:0.73596
# [30]	validation_0-rmse:0.70844
# [31]	validation_0-rmse:0.67721
# [32]	validation_0-rmse:0.65588
# [33]	validation_0-rmse:0.63634
# [34]	validation_0-rmse:0.61621
# [35]	validation_0-rmse:0.59988
# [36]	validation_0-rmse:0.58550
# [37]	validation_0-rmse:0.56988
# [38]	validation_0-rmse:0.55678
# [39]	validation_0-rmse:0.54674
# [40]	validation_0-rmse:0.53753
# [41]	validation_0-rmse:0.52888
# [42]	validation_0-rmse:0.51889
# [43]	validation_0-rmse:0.51072
# [44]	validation_0-rmse:0.50388
# [45]	validation_0-rmse:0.49824
# [46]	validation_0-rmse:0.49320
# [47]	validation_0-rmse:0.48725
# [48]	validation_0-rmse:0.47972
# [49]	validation_0-rmse:0.47475
# [50]	validation_0-rmse:0.47178
# [51]	validation_0-rmse:0.46909
# [52]	validation_0-rmse:0.46403
# [53]	validation_0-rmse:0.46161
# [54]	validation_0-rmse:0.45698
# [55]	validation_0-rmse:0.45306
# [56]	validation_0-rmse:0.44866
# [57]	validation_0-rmse:0.44361
# [58]	validation_0-rmse:0.43780
# [59]	validation_0-rmse:0.43332
# [60]	validation_0-rmse:0.42956
# [61]	validation_0-rmse:0.42601
# [62]	validation_0-rmse:0.42333
# [63]	validation_0-rmse:0.42157
# [64]	validation_0-rmse:0.41868
# [65]	validation_0-rmse:0.41654
# [66]	validation_0-rmse:0.41500
# [67]	validation_0-rmse:0.41284
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 67

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.10
# RMSE: 0.4
# Relative RMSE(%):  5.593
# MSE: 0.2
# R square: 95.9%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(2, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.960
# Uncertainty
# a0: 0.51+/-0.10
# a1: 0.930+/-0.013

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../02_output_data/XGBoost_models/02_LN_Sr_content_without_geo_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../02_output_data/XGBoost_models/02_LN_Sr_content_without_geo_XGB_model.txt")
