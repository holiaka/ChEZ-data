# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../03_input_data/input_CHM_&_spectral_data_site2020.xlsx'
df = pd.read_excel(site_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0        4.771            1.792                -0.211            -0.261
# 1        5.808            2.496                -0.073             0.392
# 2        5.796            2.546                 0.030             0.501
# 3        5.826            2.643                 0.000             0.419
# 4        6.059            2.643                 0.122             0.647
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  \
# 0              -2.040          1.932     0.85    12.233545   19.097736    243
# 1              -0.139          2.674     1.00    14.964220   17.704655    248
# 2              -0.030          2.734     1.00    15.329449   17.559893    240
# 3              -0.431          2.785     0.97    15.392742   20.676994    244
# 4              -0.386          2.809     1.00    17.944009   21.851387    243
#
#    contr_g_MAX
# 0  2961.898193
# 1  2218.239746
# 2  2220.297119
# 3  3033.770752
# 4  3003.818848

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
#  9   g_MAX                 103 non-null    int64
#  10  contr_g_MAX           103 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 9.0 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Gs_cub_m", "ln_M_AG_kg_m2"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                  ln_Gs_cub_m                                             \
#                        count      mean       std    min      25%    50%
# Dominant_specias
# Alder                    4.0  5.907250  0.445830  5.342  5.65925  5.985
# Aspen                    1.0  4.956000       NaN  4.956  4.95600  4.956
# Birch                   23.0  4.676174  0.813911  2.398  4.56900  4.949
# Oak                      3.0  5.409667  0.406291  4.956  5.24450  5.533
# Pine                    71.0  4.990775  1.410734  1.609  4.44850  5.642
# Spruce                   1.0  6.431000       NaN  6.431  6.43100  6.431
#
#                                 ln_M_AG_kg_m2                             \
#                      75%    max         count      mean       std    min
# Dominant_specias
# Alder             6.2330  6.317           4.0  2.862250  0.386813  2.407
# Aspen             4.9560  4.956           1.0  1.932000       NaN  1.932
# Birch             5.2930  5.680          23.0  1.855783  0.744496  0.000
# Oak               5.6365  5.740           3.0  2.687333  0.316282  2.398
# Pine              5.9215  6.457          71.0  2.073789  1.174954 -0.693
# Spruce            6.4310  6.431           1.0  3.506000       NaN  3.506
#
#
#                       25%    50%     75%    max
# Dominant_specias
# Alder             2.61775  2.892  3.1365  3.258
# Aspen             1.93200  1.932  1.9320  1.932
# Birch             1.68350  2.001  2.3930  2.803
# Oak               2.51850  2.639  2.8320  3.025
# Pine              1.48500  2.588  2.8620  3.515
# Spruce            3.50600  3.506  3.5060  3.506

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000        103.000000
# mean      4.981961         1.863184             -0.327942         -0.063369
# std       1.264300         1.198731              0.866380          0.795365
# min       1.609000        -1.347000             -2.659000         -2.408000
# 25%       4.677000         1.584500             -0.554000         -0.386500
# 50%       5.342000         2.294000             -0.051000          0.182000
# 75%       5.875000         2.663000              0.207000          0.495000
# max       6.457000         3.428000              1.384000          1.756000
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX  \
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.015971       2.086126    0.808738    13.045021   17.907784
# std              0.799205       1.067542    0.276653     6.609366    7.523377
# min             -3.507000      -0.693000    0.090000     1.293138    2.733019
# 25%             -1.609000       1.758000    0.745000     8.206727   11.615798
# 50%             -0.844000       2.442000    0.960000    13.072916   18.269344
# 75%             -0.364000       2.809000    1.000000    17.432255   22.751595
# max              0.157000       3.515000    1.000000    28.916548   36.355442
#
#             g_MAX  contr_g_MAX
# count  103.000000   103.000000
# mean   240.572816  3008.938899
# std      9.358442   876.023529
# min    194.000000   815.342712
# 25%    236.500000  2464.687256
# 50%    243.000000  2994.793701
# 75%    247.000000  3464.970947
# max    253.000000  6230.940918

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_M_AG_kg_m2"
indep_variables = ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0          4.771            1.792                -0.211            -0.261
# 1          5.808            2.496                -0.073             0.392
# 2          5.796            2.546                 0.030             0.501
# 3          5.826            2.643                 0.000             0.419
# 4          6.059            2.643                 0.122             0.647
# ..           ...              ...                   ...               ...
# 98         5.389            2.366                 0.531             0.182
# 99         2.398           -0.186                -1.309            -1.966
# 100        1.792           -0.968                -2.120            -1.966
# 101        4.836            1.733                -0.386             0.732
# 102        2.944           -0.211                -1.966            -1.470
#
#      ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  \
# 0                -2.040          1.932     0.85    12.233545   19.097736
# 1                -0.139          2.674     1.00    14.964220   17.704655
# 2                -0.030          2.734     1.00    15.329449   17.559893
# 3                -0.431          2.785     0.97    15.392742   20.676994
# 4                -0.386          2.809     1.00    17.944009   21.851387
# ..                  ...            ...      ...          ...         ...
# 98               -1.386          2.493     0.84    11.654902   17.083910
# 99               -3.507          0.000     0.17     4.722706   10.924606
# 100              -2.408         -0.511     0.17     4.620455   10.747827
# 101              -0.041          2.163     0.88     7.371921   11.443830
# 102              -1.609          0.182     0.28     2.765120    8.069081
#
#      g_MAX  contr_g_MAX
# 0      243  2961.898193
# 1      248  2218.239746
# 2      240  2220.297119
# 3      244  3033.770752
# 4      243  3003.818848
# ..     ...          ...
# 98     250  3469.805908
# 99     241  1748.447998
# 100    233  1708.681763
# 101    241  3066.087402
# 102    227  2756.989014
#
# [103 rows x 11 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  contr_g_MAX
# 0     0.85    12.233545   19.097736    243  2961.898193
# 1     1.00    14.964220   17.704655    248  2218.239746
# 2     1.00    15.329449   17.559893    240  2220.297119
# 3     0.97    15.392742   20.676994    244  3033.770752
# 4     1.00    17.944009   21.851387    243  3003.818848

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_AG_kg_m2
# 0          1.932
# 1          2.674
# 2          2.734
# 3          2.785
# 4          2.809

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.9553357434457668, 0.8728067360996858, 0.919880905589116]
#     Mean: 0.916
#     Std: 0.034
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.28691621 0.28538308 0.30299076]
#     Mean: 0.292
#     Std: 0.008
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.2127032654353551, 0.2869637149037684, 0.25950617532300596]
#     Mean: 0.253
#     Std: 0.031
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.9312253577535015                   # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.10732778594492726                  # gamma
print('Gamma: ' + str(p2))

p3 = 0.06328753912936169                  # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 3            # max_depth
print('Max_depth: ' + str(p4))

p5 = 164          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.9595550746273007                   # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.9312253577535015
# Gamma: 0.10732778594492726
# Learning_rate: 0.06328753912936169
# Max_depth: 3
# N_estimators: 164
# Subsample: 0.9595550746273007

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.82716	validation_1-rmse:1.66685
# [1]	validation_0-rmse:1.71853	validation_1-rmse:1.55841
# [2]	validation_0-rmse:1.61714	validation_1-rmse:1.45754
# [3]	validation_0-rmse:1.52116	validation_1-rmse:1.36457
# [4]	validation_0-rmse:1.43108	validation_1-rmse:1.27959
# [5]	validation_0-rmse:1.34816	validation_1-rmse:1.19927
# [6]	validation_0-rmse:1.26928	validation_1-rmse:1.12415
# [7]	validation_0-rmse:1.19469	validation_1-rmse:1.05533
# [8]	validation_0-rmse:1.12517	validation_1-rmse:0.98930
# [9]	validation_0-rmse:1.05939	validation_1-rmse:0.93193
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [10]	validation_0-rmse:0.99847	validation_1-rmse:0.87831
# [11]	validation_0-rmse:0.94126	validation_1-rmse:0.82471
# [12]	validation_0-rmse:0.88807	validation_1-rmse:0.77780
# [13]	validation_0-rmse:0.83805	validation_1-rmse:0.73234
# [14]	validation_0-rmse:0.79076	validation_1-rmse:0.68747
# [15]	validation_0-rmse:0.74603	validation_1-rmse:0.64873
# [16]	validation_0-rmse:0.70487	validation_1-rmse:0.61242
# [17]	validation_0-rmse:0.66578	validation_1-rmse:0.57798
# [18]	validation_0-rmse:0.63033	validation_1-rmse:0.54602
# [19]	validation_0-rmse:0.59585	validation_1-rmse:0.51494
# [20]	validation_0-rmse:0.56329	validation_1-rmse:0.48522
# [21]	validation_0-rmse:0.53373	validation_1-rmse:0.45890
# [22]	validation_0-rmse:0.50486	validation_1-rmse:0.43411
# [23]	validation_0-rmse:0.47851	validation_1-rmse:0.41145
# [24]	validation_0-rmse:0.45429	validation_1-rmse:0.39085
# [25]	validation_0-rmse:0.43071	validation_1-rmse:0.37410
# [26]	validation_0-rmse:0.40827	validation_1-rmse:0.35666
# [27]	validation_0-rmse:0.38916	validation_1-rmse:0.34116
# [28]	validation_0-rmse:0.37036	validation_1-rmse:0.32707
# [29]	validation_0-rmse:0.35279	validation_1-rmse:0.31321
# [30]	validation_0-rmse:0.33680	validation_1-rmse:0.30118
# [31]	validation_0-rmse:0.32070	validation_1-rmse:0.28814
# [32]	validation_0-rmse:0.30635	validation_1-rmse:0.28117
# [33]	validation_0-rmse:0.29291	validation_1-rmse:0.27563
# [20]	validation_0-rmse:0.54723	validation_1-rmse:0.59390
# [21]	validation_0-rmse:0.51855	validation_1-rmse:0.56324
# [22]	validation_0-rmse:0.49100	validation_1-rmse:0.53546
# [23]	validation_0-rmse:0.46580	validation_1-rmse:0.51083
# [24]	validation_0-rmse:0.44156	validation_1-rmse:0.48705
# [25]	validation_0-rmse:0.41899	validation_1-rmse:0.46566
# [26]	validation_0-rmse:0.39921	validation_1-rmse:0.44704
# [27]	validation_0-rmse:0.37988	validation_1-rmse:0.42827
# [28]	validation_0-rmse:0.36216	validation_1-rmse:0.41222
# [29]	validation_0-rmse:0.34557	validation_1-rmse:0.39684
# [30]	validation_0-rmse:0.33017	validation_1-rmse:0.38285
# [31]	validation_0-rmse:0.31589	validation_1-rmse:0.37136
# [32]	validation_0-rmse:0.30231	validation_1-rmse:0.35904
# [33]	validation_0-rmse:0.29041	validation_1-rmse:0.34942
# [34]	validation_0-rmse:0.27831	validation_1-rmse:0.33877
# [35]	validation_0-rmse:0.26713	validation_1-rmse:0.32792
# [36]	validation_0-rmse:0.25728	validation_1-rmse:0.31918
# [37]	validation_0-rmse:0.24831	validation_1-rmse:0.31128
# [38]	validation_0-rmse:0.23998	validation_1-rmse:0.30519
# [39]	validation_0-rmse:0.23187	validation_1-rmse:0.29759
# [40]	validation_0-rmse:0.22436	validation_1-rmse:0.29318
# [41]	validation_0-rmse:0.21816	validation_1-rmse:0.28881
# [42]	validation_0-rmse:0.21240	validation_1-rmse:0.28489
# [43]	validation_0-rmse:0.20680	validation_1-rmse:0.28182
# [44]	validation_0-rmse:0.20123	validation_1-rmse:0.27907
# [45]	validation_0-rmse:0.19645	validation_1-rmse:0.27505
# [46]	validation_0-rmse:0.19184	validation_1-rmse:0.27368
# [47]	validation_0-rmse:0.18785	validation_1-rmse:0.27098
# [48]	validation_0-rmse:0.18388	validation_1-rmse:0.26991
# [49]	validation_0-rmse:0.18055	validation_1-rmse:0.26713
# [50]	validation_0-rmse:0.17803	validation_1-rmse:0.26631
# [51]	validation_0-rmse:0.17578	validation_1-rmse:0.26574
# [52]	validation_0-rmse:0.17261	validation_1-rmse:0.26373
# [53]	validation_0-rmse:0.16925	validation_1-rmse:0.26590
# [54]	validation_0-rmse:0.16742	validation_1-rmse:0.26421
# [55]	validation_0-rmse:0.16592	validation_1-rmse:0.26307
# [56]	validation_0-rmse:0.16384	validation_1-rmse:0.26302
# [57]	validation_0-rmse:0.16191	validation_1-rmse:0.26188
# [58]	validation_0-rmse:0.16049	validation_1-rmse:0.26049
# [59]	validation_0-rmse:0.15934	validation_1-rmse:0.25939
# [60]	validation_0-rmse:0.15772	validation_1-rmse:0.25898
# [61]	validation_0-rmse:0.15674	validation_1-rmse:0.25852
# [62]	validation_0-rmse:0.15581	validation_1-rmse:0.25787
# [63]	validation_0-rmse:0.15495	validation_1-rmse:0.25742
# [64]	validation_0-rmse:0.15413	validation_1-rmse:0.25786
# [65]	validation_0-rmse:0.15382	validation_1-rmse:0.25749
# [66]	validation_0-rmse:0.15362	validation_1-rmse:0.25724
# [54]	validation_0-rmse:0.15808	validation_1-rmse:0.39383
# [55]	validation_0-rmse:0.15641	validation_1-rmse:0.39407
# [56]	validation_0-rmse:0.15458	validation_1-rmse:0.39281
# [57]	validation_0-rmse:0.15322	validation_1-rmse:0.39132
# [58]	validation_0-rmse:0.15194	validation_1-rmse:0.39095
# [59]	validation_0-rmse:0.15059	validation_1-rmse:0.38988
# [60]	validation_0-rmse:0.14945	validation_1-rmse:0.38902
# [61]	validation_0-rmse:0.14835	validation_1-rmse:0.38815
# [62]	validation_0-rmse:0.14793	validation_1-rmse:0.38758
# [63]	validation_0-rmse:0.14697	validation_1-rmse:0.38637
# [64]	validation_0-rmse:0.14609	validation_1-rmse:0.38571
# [65]	validation_0-rmse:0.14586	validation_1-rmse:0.38534
# [66]	validation_0-rmse:0.14504	validation_1-rmse:0.38466
# [67]	validation_0-rmse:0.14424	validation_1-rmse:0.38522
# [68]	validation_0-rmse:0.14344	validation_1-rmse:0.38458
# [69]	validation_0-rmse:0.14329	validation_1-rmse:0.38430
# [70]	validation_0-rmse:0.14313	validation_1-rmse:0.38400
# [71]	validation_0-rmse:0.14300	validation_1-rmse:0.38373
# [72]	validation_0-rmse:0.14289	validation_1-rmse:0.38348
# [73]	validation_0-rmse:0.14278	validation_1-rmse:0.38325
# [74]	validation_0-rmse:0.14268	validation_1-rmse:0.38301
# [75]	validation_0-rmse:0.14261	validation_1-rmse:0.38283
# [76]	validation_0-rmse:0.14202	validation_1-rmse:0.38257
# [77]	validation_0-rmse:0.14195	validation_1-rmse:0.38238
# [78]	validation_0-rmse:0.14190	validation_1-rmse:0.38224
# [79]	validation_0-rmse:0.14184	validation_1-rmse:0.38205
# [80]	validation_0-rmse:0.14180	validation_1-rmse:0.38194
# [81]	validation_0-rmse:0.14176	validation_1-rmse:0.38180
# [82]	validation_0-rmse:0.14113	validation_1-rmse:0.38139
# [83]	validation_0-rmse:0.14109	validation_1-rmse:0.38120
# [84]	validation_0-rmse:0.14105	validation_1-rmse:0.38101
# [85]	validation_0-rmse:0.14103	validation_1-rmse:0.38090
# [86]	validation_0-rmse:0.14102	validation_1-rmse:0.38087
# [87]	validation_0-rmse:0.14100	validation_1-rmse:0.38073
# [88]	validation_0-rmse:0.14100	validation_1-rmse:0.38073
# [89]	validation_0-rmse:0.14099	validation_1-rmse:0.38066
# [90]	validation_0-rmse:0.14097	validation_1-rmse:0.38054
# [91]	validation_0-rmse:0.14096	validation_1-rmse:0.38043
# [92]	validation_0-rmse:0.14096	validation_1-rmse:0.38040
# [93]	validation_0-rmse:0.14095	validation_1-rmse:0.38037
# [94]	validation_0-rmse:0.14095	validation_1-rmse:0.38033
# [95]	validation_0-rmse:0.14095	validation_1-rmse:0.38029
# [96]	validation_0-rmse:0.14094	validation_1-rmse:0.38026
# [97]	validation_0-rmse:0.14094	validation_1-rmse:0.38026
# [98]	validation_0-rmse:0.14094	validation_1-rmse:0.38026
# [99]	validation_0-rmse:0.14094	validation_1-rmse:0.38024
# [100]	validation_0-rmse:0.14094	validation_1-rmse:0.38023
# [101]	validation_0-rmse:0.14094	validation_1-rmse:0.38018
# [102]	validation_0-rmse:0.14094	validation_1-rmse:0.38022
# [103]	validation_0-rmse:0.14094	validation_1-rmse:0.38020
# [104]	validation_0-rmse:0.14094	validation_1-rmse:0.38021
# [105]	validation_0-rmse:0.14094	validation_1-rmse:0.38017
# [106]	validation_0-rmse:0.14094	validation_1-rmse:0.38015
# [107]	validation_0-rmse:0.14093	validation_1-rmse:0.38009
# [108]	validation_0-rmse:0.14093	validation_1-rmse:0.38003
# [109]	validation_0-rmse:0.14093	validation_1-rmse:0.38001
# [110]	validation_0-rmse:0.14093	validation_1-rmse:0.38003
# [111]	validation_0-rmse:0.14093	validation_1-rmse:0.37997
# [112]	validation_0-rmse:0.14093	validation_1-rmse:0.38004
# [113]	validation_0-rmse:0.14093	validation_1-rmse:0.38001
# [114]	validation_0-rmse:0.14093	validation_1-rmse:0.37996
# [115]	validation_0-rmse:0.14093	validation_1-rmse:0.37996
# [116]	validation_0-rmse:0.14093	validation_1-rmse:0.37995
# [117]	validation_0-rmse:0.14041	validation_1-rmse:0.38075
# [118]	validation_0-rmse:0.14042	validation_1-rmse:0.38080
# [119]	validation_0-rmse:0.14042	validation_1-rmse:0.38083
# [120]	validation_0-rmse:0.14042	validation_1-rmse:0.38080
# [121]	validation_0-rmse:0.14042	validation_1-rmse:0.38076
# [122]	validation_0-rmse:0.14041	validation_1-rmse:0.38071
# [123]	validation_0-rmse:0.14041	validation_1-rmse:0.38066
# [124]	validation_0-rmse:0.14041	validation_1-rmse:0.38070
# [125]	validation_0-rmse:0.14041	validation_1-rmse:0.38075
# [126]	validation_0-rmse:0.14042	validation_1-rmse:0.38077
# [127]	validation_0-rmse:0.14041	validation_1-rmse:0.38072
# [128]	validation_0-rmse:0.14041	validation_1-rmse:0.38071
# [129]	validation_0-rmse:0.13939	validation_1-rmse:0.37946
# [130]	validation_0-rmse:0.13939	validation_1-rmse:0.37944
# [131]	validation_0-rmse:0.13939	validation_1-rmse:0.37941
# [132]	validation_0-rmse:0.13939	validation_1-rmse:0.37946
# [133]	validation_0-rmse:0.13939	validation_1-rmse:0.37941
# [134]	validation_0-rmse:0.13939	validation_1-rmse:0.37941
# [135]	validation_0-rmse:0.13939	validation_1-rmse:0.37942
# [136]	validation_0-rmse:0.13939	validation_1-rmse:0.37938
# [137]	validation_0-rmse:0.13939	validation_1-rmse:0.37928
# [138]	validation_0-rmse:0.13939	validation_1-rmse:0.37920
# [139]	validation_0-rmse:0.13939	validation_1-rmse:0.37922
# [140]	validation_0-rmse:0.13939	validation_1-rmse:0.37925
# [141]	validation_0-rmse:0.13939	validation_1-rmse:0.37917
# [142]	validation_0-rmse:0.13939	validation_1-rmse:0.37925
# [143]	validation_0-rmse:0.13939	validation_1-rmse:0.37921
# [144]	validation_0-rmse:0.13939	validation_1-rmse:0.37914
# [145]	validation_0-rmse:0.13939	validation_1-rmse:0.37915
# [146]	validation_0-rmse:0.13939	validation_1-rmse:0.37919
# [147]	validation_0-rmse:0.13939	validation_1-rmse:0.37917
# [148]	validation_0-rmse:0.13940	validation_1-rmse:0.37911
# [149]	validation_0-rmse:0.13939	validation_1-rmse:0.37916
# [150]	validation_0-rmse:0.13939	validation_1-rmse:0.37918
# [151]	validation_0-rmse:0.13939	validation_1-rmse:0.37918
# [152]	validation_0-rmse:0.13939	validation_1-rmse:0.37919
# [153]	validation_0-rmse:0.13939	validation_1-rmse:0.37920
# [154]	validation_0-rmse:0.13939	validation_1-rmse:0.37920
# [155]	validation_0-rmse:0.13939	validation_1-rmse:0.37926
# [156]	validation_0-rmse:0.13939	validation_1-rmse:0.37917
# [157]	validation_0-rmse:0.13939	validation_1-rmse:0.37912
# [158]	validation_0-rmse:0.13939	validation_1-rmse:0.37915
# [159]	validation_0-rmse:0.13940	validation_1-rmse:0.37908
# [160]	validation_0-rmse:0.13939	validation_1-rmse:0.37912
# [161]	validation_0-rmse:0.13939	validation_1-rmse:0.37918
# [162]	validation_0-rmse:0.13939	validation_1-rmse:0.37916
# [163]	validation_0-rmse:0.13939	validation_1-rmse:0.37918
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.80841	validation_1-rmse:1.74838
# [1]	validation_0-rmse:1.70146	validation_1-rmse:1.64809
# [2]	validation_0-rmse:1.60105	validation_1-rmse:1.55015
# [3]	validation_0-rmse:1.50561	validation_1-rmse:1.45883
# [4]	validation_0-rmse:1.41585	validation_1-rmse:1.37544
# [5]	validation_0-rmse:1.33212	validation_1-rmse:1.29264
# [6]	validation_0-rmse:1.25335	validation_1-rmse:1.22037
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:1.17990	validation_1-rmse:1.15337
# [8]	validation_0-rmse:1.11090	validation_1-rmse:1.09080
# [9]	validation_0-rmse:1.04635	validation_1-rmse:1.03183
# [10]	validation_0-rmse:0.98557	validation_1-rmse:0.97886
# [11]	validation_0-rmse:0.92976	validation_1-rmse:0.92533
# [12]	validation_0-rmse:0.87601	validation_1-rmse:0.87813
# [13]	validation_0-rmse:0.82619	validation_1-rmse:0.83643
# [14]	validation_0-rmse:0.77935	validation_1-rmse:0.79584
# [15]	validation_0-rmse:0.73583	validation_1-rmse:0.75864
# [16]	validation_0-rmse:0.69468	validation_1-rmse:0.72557
# [17]	validation_0-rmse:0.65666	validation_1-rmse:0.69778
# [18]	validation_0-rmse:0.62024	validation_1-rmse:0.66755
# [19]	validation_0-rmse:0.58682	validation_1-rmse:0.64122
# [20]	validation_0-rmse:0.55540	validation_1-rmse:0.61602
# [21]	validation_0-rmse:0.52616	validation_1-rmse:0.59319
# [22]	validation_0-rmse:0.49807	validation_1-rmse:0.57261
# [23]	validation_0-rmse:0.47148	validation_1-rmse:0.55634
# [24]	validation_0-rmse:0.44770	validation_1-rmse:0.54015
# [25]	validation_0-rmse:0.42427	validation_1-rmse:0.52293
# [26]	validation_0-rmse:0.40328	validation_1-rmse:0.50742
# [27]	validation_0-rmse:0.38380	validation_1-rmse:0.49674
# [28]	validation_0-rmse:0.36539	validation_1-rmse:0.48544
# [29]	validation_0-rmse:0.34808	validation_1-rmse:0.47705
# [30]	validation_0-rmse:0.33219	validation_1-rmse:0.46827
# [31]	validation_0-rmse:0.31714	validation_1-rmse:0.46055
# [32]	validation_0-rmse:0.30353	validation_1-rmse:0.45449
# [33]	validation_0-rmse:0.29032	validation_1-rmse:0.45185
# [34]	validation_0-rmse:0.27841	validation_1-rmse:0.44442
# [35]	validation_0-rmse:0.26678	validation_1-rmse:0.43776
# [36]	validation_0-rmse:0.25608	validation_1-rmse:0.43037
# [37]	validation_0-rmse:0.24659	validation_1-rmse:0.42378
# [38]	validation_0-rmse:0.23774	validation_1-rmse:0.41853
# [39]	validation_0-rmse:0.23017	validation_1-rmse:0.41689
# [40]	validation_0-rmse:0.22192	validation_1-rmse:0.41412
# [41]	validation_0-rmse:0.21495	validation_1-rmse:0.41012
# [42]	validation_0-rmse:0.20805	validation_1-rmse:0.40892
# [43]	validation_0-rmse:0.20172	validation_1-rmse:0.40622
# [44]	validation_0-rmse:0.19627	validation_1-rmse:0.40474
# [45]	validation_0-rmse:0.19095	validation_1-rmse:0.40257
# [46]	validation_0-rmse:0.18656	validation_1-rmse:0.40056
# [47]	validation_0-rmse:0.18315	validation_1-rmse:0.39921
# [48]	validation_0-rmse:0.17921	validation_1-rmse:0.39821
# [49]	validation_0-rmse:0.17611	validation_1-rmse:0.39698
# [50]	validation_0-rmse:0.17312	validation_1-rmse:0.39519
# [51]	validation_0-rmse:0.17069	validation_1-rmse:0.39625
# [52]	validation_0-rmse:0.16779	validation_1-rmse:0.39320
# [53]	validation_0-rmse:0.16568	validation_1-rmse:0.39194
# [54]	validation_0-rmse:0.16314	validation_1-rmse:0.38925
# [55]	validation_0-rmse:0.16080	validation_1-rmse:0.38653
# [56]	validation_0-rmse:0.15910	validation_1-rmse:0.38728
# [57]	validation_0-rmse:0.15764	validation_1-rmse:0.38651
# [58]	validation_0-rmse:0.15634	validation_1-rmse:0.38666
# [59]	validation_0-rmse:0.15496	validation_1-rmse:0.38590
# [60]	validation_0-rmse:0.15378	validation_1-rmse:0.38366
# [61]	validation_0-rmse:0.15256	validation_1-rmse:0.38290
# [62]	validation_0-rmse:0.15055	validation_1-rmse:0.38068
# [63]	validation_0-rmse:0.15023	validation_1-rmse:0.38118
# [64]	validation_0-rmse:0.14934	validation_1-rmse:0.38140
# [65]	validation_0-rmse:0.14849	validation_1-rmse:0.38173
# [66]	validation_0-rmse:0.14824	validation_1-rmse:0.38221
# [67]	validation_0-rmse:0.14746	validation_1-rmse:0.38188
# [68]	validation_0-rmse:0.14668	validation_1-rmse:0.38198
# [69]	validation_0-rmse:0.14655	validation_1-rmse:0.38230
# [70]	validation_0-rmse:0.14639	validation_1-rmse:0.38270
# [71]	validation_0-rmse:0.14624	validation_1-rmse:0.38310
# [72]	validation_0-rmse:0.14611	validation_1-rmse:0.38345
# [73]	validation_0-rmse:0.14603	validation_1-rmse:0.38372
# [74]	validation_0-rmse:0.14593	validation_1-rmse:0.38403
# [75]	validation_0-rmse:0.14582	validation_1-rmse:0.38445
# [76]	validation_0-rmse:0.14573	validation_1-rmse:0.38476
# [77]	validation_0-rmse:0.14566	validation_1-rmse:0.38506
# [78]	validation_0-rmse:0.14561	validation_1-rmse:0.38531
# [79]	validation_0-rmse:0.14554	validation_1-rmse:0.38565
# [80]	validation_0-rmse:0.14552	validation_1-rmse:0.38575
# [81]	validation_0-rmse:0.14548	validation_1-rmse:0.38596
# [82]	validation_0-rmse:0.14544	validation_1-rmse:0.38620
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#
# [39]	validation_0-rmse:0.22421	validation_1-rmse:0.41282
# [40]	validation_0-rmse:0.21662	validation_1-rmse:0.40907
# [41]	validation_0-rmse:0.20998	validation_1-rmse:0.40669
# [42]	validation_0-rmse:0.20393	validation_1-rmse:0.40390
# [43]	validation_0-rmse:0.19780	validation_1-rmse:0.40122
# [44]	validation_0-rmse:0.19225	validation_1-rmse:0.39863
# [45]	validation_0-rmse:0.18728	validation_1-rmse:0.39665
# [46]	validation_0-rmse:0.18287	validation_1-rmse:0.39480
# [47]	validation_0-rmse:0.17876	validation_1-rmse:0.39314
# [48]	validation_0-rmse:0.17527	validation_1-rmse:0.39150
# [49]	validation_0-rmse:0.17169	validation_1-rmse:0.38948
# [50]	validation_0-rmse:0.16917	validation_1-rmse:0.38813
# [51]	validation_0-rmse:0.16563	validation_1-rmse:0.38756
# [52]	validation_0-rmse:0.16331	validation_1-rmse:0.38643
# [53]	validation_0-rmse:0.16007	validation_1-rmse:0.38527
# [54]	validation_0-rmse:0.15822	validation_1-rmse:0.38412
# [55]	validation_0-rmse:0.15656	validation_1-rmse:0.38314
# [56]	validation_0-rmse:0.15500	validation_1-rmse:0.38225
# [57]	validation_0-rmse:0.15356	validation_1-rmse:0.38049
# [58]	validation_0-rmse:0.15215	validation_1-rmse:0.37998
# [59]	validation_0-rmse:0.15079	validation_1-rmse:0.37932
# [60]	validation_0-rmse:0.14963	validation_1-rmse:0.37911
# [61]	validation_0-rmse:0.14857	validation_1-rmse:0.37921
# [62]	validation_0-rmse:0.14762	validation_1-rmse:0.37896
# [63]	validation_0-rmse:0.14724	validation_1-rmse:0.37925
# [64]	validation_0-rmse:0.14691	validation_1-rmse:0.37952
# [65]	validation_0-rmse:0.14526	validation_1-rmse:0.37905
# [66]	validation_0-rmse:0.14501	validation_1-rmse:0.37930
# [67]	validation_0-rmse:0.14478	validation_1-rmse:0.37955
# [68]	validation_0-rmse:0.14457	validation_1-rmse:0.37980
# [69]	validation_0-rmse:0.14442	validation_1-rmse:0.37999
# [70]	validation_0-rmse:0.14427	validation_1-rmse:0.38021
# [71]	validation_0-rmse:0.14414	validation_1-rmse:0.38039
# [72]	validation_0-rmse:0.14404	validation_1-rmse:0.38056
# [73]	validation_0-rmse:0.14392	validation_1-rmse:0.38077
# [74]	validation_0-rmse:0.14382	validation_1-rmse:0.38097
# [75]	validation_0-rmse:0.14374	validation_1-rmse:0.38112
# [76]	validation_0-rmse:0.14369	validation_1-rmse:0.38124
# [77]	validation_0-rmse:0.14364	validation_1-rmse:0.38136
# [78]	validation_0-rmse:0.14358	validation_1-rmse:0.38149
# [79]	validation_0-rmse:0.14351	validation_1-rmse:0.38168
# [80]	validation_0-rmse:0.14347	validation_1-rmse:0.38180
# [81]	validation_0-rmse:0.14344	validation_1-rmse:0.38192
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.86130	validation_1-rmse:1.51033
# [1]	validation_0-rmse:1.74985	validation_1-rmse:1.42064
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#
# [51]	validation_0-rmse:0.17577	validation_1-rmse:0.31070
# [52]	validation_0-rmse:0.17338	validation_1-rmse:0.30852
# [53]	validation_0-rmse:0.17075	validation_1-rmse:0.30762
# [54]	validation_0-rmse:0.16837	validation_1-rmse:0.30603
# [55]	validation_0-rmse:0.16622	validation_1-rmse:0.30556
# [56]	validation_0-rmse:0.16464	validation_1-rmse:0.30463
# [57]	validation_0-rmse:0.16317	validation_1-rmse:0.30236
# [58]	validation_0-rmse:0.16180	validation_1-rmse:0.30152
# [59]	validation_0-rmse:0.16131	validation_1-rmse:0.30113
# [60]	validation_0-rmse:0.16020	validation_1-rmse:0.30076
# [61]	validation_0-rmse:0.15867	validation_1-rmse:0.30056
# [62]	validation_0-rmse:0.15602	validation_1-rmse:0.29915
# [63]	validation_0-rmse:0.15512	validation_1-rmse:0.29897
# [64]	validation_0-rmse:0.15475	validation_1-rmse:0.29864
# [65]	validation_0-rmse:0.15444	validation_1-rmse:0.29836
# [66]	validation_0-rmse:0.15419	validation_1-rmse:0.29813
# [67]	validation_0-rmse:0.15343	validation_1-rmse:0.29785
# [68]	validation_0-rmse:0.15323	validation_1-rmse:0.29765
# [69]	validation_0-rmse:0.15302	validation_1-rmse:0.29743
# [70]	validation_0-rmse:0.15285	validation_1-rmse:0.29725
# [71]	validation_0-rmse:0.15271	validation_1-rmse:0.29710
# [72]	validation_0-rmse:0.15256	validation_1-rmse:0.29693
# [73]	validation_0-rmse:0.15243	validation_1-rmse:0.29677
# [74]	validation_0-rmse:0.15233	validation_1-rmse:0.29665
# [75]	validation_0-rmse:0.15222	validation_1-rmse:0.29651
# [76]	validation_0-rmse:0.15214	validation_1-rmse:0.29640
# [77]	validation_0-rmse:0.15209	validation_1-rmse:0.29633
# [78]	validation_0-rmse:0.15203	validation_1-rmse:0.29625
# [79]	validation_0-rmse:0.15198	validation_1-rmse:0.29618
# [80]	validation_0-rmse:0.15102	validation_1-rmse:0.29624
# [81]	validation_0-rmse:0.15097	validation_1-rmse:0.29616
# [82]	validation_0-rmse:0.15092	validation_1-rmse:0.29607
# [83]	validation_0-rmse:0.15088	validation_1-rmse:0.29600
# [84]	validation_0-rmse:0.15082	validation_1-rmse:0.29590
# [85]	validation_0-rmse:0.15080	validation_1-rmse:0.29585
# [86]	validation_0-rmse:0.15078	validation_1-rmse:0.29582
# [87]	validation_0-rmse:0.15076	validation_1-rmse:0.29577
# [88]	validation_0-rmse:0.15075	validation_1-rmse:0.29573
# [89]	validation_0-rmse:0.15073	validation_1-rmse:0.29568
# [90]	validation_0-rmse:0.15070	validation_1-rmse:0.29562
# [91]	validation_0-rmse:0.15068	validation_1-rmse:0.29556
# [92]	validation_0-rmse:0.15067	validation_1-rmse:0.29554
# [93]	validation_0-rmse:0.15067	validation_1-rmse:0.29551
# [94]	validation_0-rmse:0.15066	validation_1-rmse:0.29547
# [95]	validation_0-rmse:0.15066	validation_1-rmse:0.29547
# [96]	validation_0-rmse:0.15065	validation_1-rmse:0.29545
# [97]	validation_0-rmse:0.15065	validation_1-rmse:0.29545
# [98]	validation_0-rmse:0.15065	validation_1-rmse:0.29544
# [99]	validation_0-rmse:0.15064	validation_1-rmse:0.29542
# [100]	validation_0-rmse:0.15064	validation_1-rmse:0.29542
# [101]	validation_0-rmse:0.15064	validation_1-rmse:0.29538
# [102]	validation_0-rmse:0.15063	validation_1-rmse:0.29537
# [103]	validation_0-rmse:0.15063	validation_1-rmse:0.29536
# [104]	validation_0-rmse:0.15064	validation_1-rmse:0.29538
# [105]	validation_0-rmse:0.15064	validation_1-rmse:0.29538
# [106]	validation_0-rmse:0.15063	validation_1-rmse:0.29537
# [107]	validation_0-rmse:0.15063	validation_1-rmse:0.29534
# [108]	validation_0-rmse:0.15012	validation_1-rmse:0.29552
# [109]	validation_0-rmse:0.15011	validation_1-rmse:0.29551
# [110]	validation_0-rmse:0.15011	validation_1-rmse:0.29548
# [111]	validation_0-rmse:0.15011	validation_1-rmse:0.29549
# [112]	validation_0-rmse:0.15011	validation_1-rmse:0.29549
# [113]	validation_0-rmse:0.15011	validation_1-rmse:0.29547
# [114]	validation_0-rmse:0.15011	validation_1-rmse:0.29546
# [115]	validation_0-rmse:0.15010	validation_1-rmse:0.29544
# [116]	validation_0-rmse:0.15011	validation_1-rmse:0.29545
# [117]	validation_0-rmse:0.15010	validation_1-rmse:0.29544
# [118]	validation_0-rmse:0.15010	validation_1-rmse:0.29541
# [119]	validation_0-rmse:0.15010	validation_1-rmse:0.29541
# [120]	validation_0-rmse:0.15010	validation_1-rmse:0.29541
# [121]	validation_0-rmse:0.15010	validation_1-rmse:0.29541
# [122]	validation_0-rmse:0.15010	validation_1-rmse:0.29540
# [123]	validation_0-rmse:0.15010	validation_1-rmse:0.29538
# [124]	validation_0-rmse:0.15010	validation_1-rmse:0.29539
# [125]	validation_0-rmse:0.15010	validation_1-rmse:0.29536
# [126]	validation_0-rmse:0.15010	validation_1-rmse:0.29539
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-0.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.934
# Uncertainty
# a0: 0.155+/-0.057
# a1: 0.914+/-0.026

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: %_cover: mean - 0.157, median - 0.156, CI - [0.137-0.178]
#
# SHAP-values for: contr_g_MAX: mean - 0.039, median - 0.038, CI - [0.029-0.049]
#
# SHAP-values for: g_MAX: mean - 0.009, median - 0.008, CI - [0.005-0.012]
#
# SHAP-values for: mf_chm_MAX: mean - 0.28, median - 0.276, CI - [0.214-0.342]
#
# SHAP-values for: mf_chm_MEAN: mean - 0.416, median - 0.417, CI - [0.357-0.469]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['mf_chm_MEAN', 'mf_chm_MAX', '%_cover', 'contr_g_MAX', 'g_MAX'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 104.055, median: 101.0,
#  pred. interval (P(0.025)-P(0.975)): 45.0-163.0,
#  conf. interval (p-value=0.95): 63.974-147.057
# ***
# Aggregate bias statistic:
#  mean: -0.025, median: -0.025,
#  pred. interval (P(0.025)-P(0.975)): -0.124-0.087,
#  conf. interval (p-value=0.95): -0.079-0.022
# ***
# Aggregate RMSE statistic:
#  mean: 0.267, median: 0.261, pred. interval (P(0.025)-P(0.975)): 0.184-0.381,
#  conf. interval (p-value=0.95): 0.227-0.301
# ***
# Aggregate MSE statistic:
#  mean: 0.074, median: 0.068, pred. interval (P(0.025)-P(0.975)): 0.034-0.145,
#  conf. interval (p-value=0.95): 0.052-0.091
# ***
# Aggregate R^2 statistic:
#  mean: 0.922, median: 0.932, pred. interval (P(0.025)-P(0.975)): 0.829-0.97,
#  conf. interval (p-value=0.95): 0.897-0.952
# ***
# Aggregate bias(%) statistic:
#  mean: -1.105, median: -1.227, pred. interval (P(0.025)-P(0.975)): -6.005-4.606,
#  conf. interval (p-value=0.95): -3.647-1.089
# ***
# Aggregate RMSE(%) statistic:
#  mean: 12.993, median: 12.363, pred. interval (P(0.025)-P(0.975)): 7.677-20.114,
#  conf. interval (p-value=0.95): 10.661-15.612
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -0.649, median: -0.588,
#  pred. interval (P(0.025)-P(0.975)): -1.709-0.12,
#  conf. interval (p-value=0.95): -1.119--0.221
# ***
# Aggregate RMSE statistic:
#  mean: 2.702, median: 2.626, pred. interval (P(0.025)-P(0.975)): 1.802-3.789,
#  conf. interval (p-value=0.95): 2.149-3.245
# ***
# Aggregate MSE statistic:
#  mean: 7.639, median: 6.896, pred. interval (P(0.025)-P(0.975)): 3.246-14.359,
#  conf. interval (p-value=0.95): 4.643-10.569
# ***
# Aggregate R^2 statistic:
#  mean: 0.86, median: 0.869, pred. interval (P(0.025)-P(0.975)): 0.723-0.936,
#  conf. interval (p-value=0.95): 0.816-0.912
# ***
# Aggregate bias(%) statistic:
#  mean: -5.363, median: -4.909, pred. interval (P(0.025)-P(0.975)): -11.984-1.155,
#  conf. interval (p-value=0.95): -9.005--2.025
# ***
# Aggregate RMSE(%) statistic:
#  mean: 23.209, median: 22.979, pred. interval (P(0.025)-P(0.975)): 15.039-35.756,
#  conf. interval (p-value=0.95): 19.005-26.763
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-1, 0, 1, 2, 3, 4])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 5, 10, 15, 20, 30])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.79509
# [1]	validation_0-rmse:1.68628
# [2]	validation_0-rmse:1.58674
# [3]	validation_0-rmse:1.49266
# [4]	validation_0-rmse:1.40336
# [5]	validation_0-rmse:1.32012
# [6]	validation_0-rmse:1.24193
# [7]	validation_0-rmse:1.16880
# [8]	validation_0-rmse:1.10041
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#
# [88]	validation_0-rmse:0.14740
# [89]	validation_0-rmse:0.14740
# [90]	validation_0-rmse:0.14739
# [91]	validation_0-rmse:0.14738
# [92]	validation_0-rmse:0.14590
# [93]	validation_0-rmse:0.14589
# [94]	validation_0-rmse:0.14589
# [95]	validation_0-rmse:0.14589
# [96]	validation_0-rmse:0.14588
# [97]	validation_0-rmse:0.14588
# [98]	validation_0-rmse:0.14587
# [99]	validation_0-rmse:0.14587
# [100]	validation_0-rmse:0.14586
# [101]	validation_0-rmse:0.14587
# [102]	validation_0-rmse:0.14586
# [103]	validation_0-rmse:0.14586
# [104]	validation_0-rmse:0.14586
# [105]	validation_0-rmse:0.14586
# [106]	validation_0-rmse:0.14586
# [107]	validation_0-rmse:0.14586
# [108]	validation_0-rmse:0.14586
# [109]	validation_0-rmse:0.14586
# [110]	validation_0-rmse:0.14472
# [111]	validation_0-rmse:0.14471
# [112]	validation_0-rmse:0.14471
# [113]	validation_0-rmse:0.14472
# [114]	validation_0-rmse:0.14471
# [115]	validation_0-rmse:0.14471
# [116]	validation_0-rmse:0.14471
# [117]	validation_0-rmse:0.14471
# [118]	validation_0-rmse:0.14471
# [119]	validation_0-rmse:0.14471
# [120]	validation_0-rmse:0.14471
# [121]	validation_0-rmse:0.14471
# [122]	validation_0-rmse:0.14471
# [123]	validation_0-rmse:0.14471
# [124]	validation_0-rmse:0.14471
# [125]	validation_0-rmse:0.14471
# [126]	validation_0-rmse:0.14471
# [127]	validation_0-rmse:0.14471
# [128]	validation_0-rmse:0.14471
# [129]	validation_0-rmse:0.14471
# [130]	validation_0-rmse:0.14471
# [131]	validation_0-rmse:0.14307
# [132]	validation_0-rmse:0.14307
# [133]	validation_0-rmse:0.14307
# [134]	validation_0-rmse:0.14307
# [135]	validation_0-rmse:0.14307
# [136]	validation_0-rmse:0.14307
# [137]	validation_0-rmse:0.14307
# [138]	validation_0-rmse:0.14307
# [139]	validation_0-rmse:0.14307
# [140]	validation_0-rmse:0.14307
# [141]	validation_0-rmse:0.14307
# [142]	validation_0-rmse:0.14307
# [143]	validation_0-rmse:0.14307
# [144]	validation_0-rmse:0.14307
# [145]	validation_0-rmse:0.14307
# [146]	validation_0-rmse:0.14307
# [147]	validation_0-rmse:0.14307
# [148]	validation_0-rmse:0.14307
# [149]	validation_0-rmse:0.14307
# [150]	validation_0-rmse:0.14307
# [151]	validation_0-rmse:0.14307
# [152]	validation_0-rmse:0.14307
# [153]	validation_0-rmse:0.14307
# [154]	validation_0-rmse:0.14223
# [155]	validation_0-rmse:0.14223
# [156]	validation_0-rmse:0.14223
# [157]	validation_0-rmse:0.14223
# [158]	validation_0-rmse:0.14223
# [159]	validation_0-rmse:0.14223
# [160]	validation_0-rmse:0.14223
# [161]	validation_0-rmse:0.14223
# [162]	validation_0-rmse:0.14223
# [163]	validation_0-rmse:0.14223
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 161

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  0.00
# RMSE: 0.1
# Relative RMSE(%):  6.818
# MSE: 0.0
# R square: 98.2%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-0.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.983
# Uncertainty
# a0: 0.098+/-0.029
# a1: 0.953+/-0.012

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/06_LN_M_AG_CHM_with_RGB_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/06_LN_M_AG_CHM_with_RGB_XGB_model.txt")
