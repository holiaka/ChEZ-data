# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../03_input_data/input_CHM_&_spectral_data_site2020.xlsx'
df = pd.read_excel(site_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0        4.771            1.792                -0.211            -0.261
# 1        5.808            2.496                -0.073             0.392
# 2        5.796            2.546                 0.030             0.501
# 3        5.826            2.643                 0.000             0.419
# 4        6.059            2.643                 0.122             0.647
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  \
# 0              -2.040          1.932     0.85    12.233545   19.097736    243
# 1              -0.139          2.674     1.00    14.964220   17.704655    248
# 2              -0.030          2.734     1.00    15.329449   17.559893    240
# 3              -0.431          2.785     0.97    15.392742   20.676994    244
# 4              -0.386          2.809     1.00    17.944009   21.851387    243
#
#    contr_g_MAX
# 0  2961.898193
# 1  2218.239746
# 2  2220.297119
# 3  3033.770752
# 4  3003.818848

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
#  9   g_MAX                 103 non-null    int64
#  10  contr_g_MAX           103 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 9.0 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Gs_cub_m", "ln_M_AG_kg_m2"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                  ln_Gs_cub_m                                             \
#                        count      mean       std    min      25%    50%
# Dominant_specias
# Alder                    4.0  5.907250  0.445830  5.342  5.65925  5.985
# Aspen                    1.0  4.956000       NaN  4.956  4.95600  4.956
# Birch                   23.0  4.676174  0.813911  2.398  4.56900  4.949
# Oak                      3.0  5.409667  0.406291  4.956  5.24450  5.533
# Pine                    71.0  4.990775  1.410734  1.609  4.44850  5.642
# Spruce                   1.0  6.431000       NaN  6.431  6.43100  6.431
#
#                                 ln_M_AG_kg_m2                             \
#                      75%    max         count      mean       std    min
# Dominant_specias
# Alder             6.2330  6.317           4.0  2.862250  0.386813  2.407
# Aspen             4.9560  4.956           1.0  1.932000       NaN  1.932
# Birch             5.2930  5.680          23.0  1.855783  0.744496  0.000
# Oak               5.6365  5.740           3.0  2.687333  0.316282  2.398
# Pine              5.9215  6.457          71.0  2.073789  1.174954 -0.693
# Spruce            6.4310  6.431           1.0  3.506000       NaN  3.506
#
#
#                       25%    50%     75%    max
# Dominant_specias
# Alder             2.61775  2.892  3.1365  3.258
# Aspen             1.93200  1.932  1.9320  1.932
# Birch             1.68350  2.001  2.3930  2.803
# Oak               2.51850  2.639  2.8320  3.025
# Pine              1.48500  2.588  2.8620  3.515
# Spruce            3.50600  3.506  3.5060  3.506

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000        103.000000
# mean      4.981961         1.863184             -0.327942         -0.063369
# std       1.264300         1.198731              0.866380          0.795365
# min       1.609000        -1.347000             -2.659000         -2.408000
# 25%       4.677000         1.584500             -0.554000         -0.386500
# 50%       5.342000         2.294000             -0.051000          0.182000
# 75%       5.875000         2.663000              0.207000          0.495000
# max       6.457000         3.428000              1.384000          1.756000
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX  \
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.015971       2.086126    0.808738    13.045021   17.907784
# std              0.799205       1.067542    0.276653     6.609366    7.523377
# min             -3.507000      -0.693000    0.090000     1.293138    2.733019
# 25%             -1.609000       1.758000    0.745000     8.206727   11.615798
# 50%             -0.844000       2.442000    0.960000    13.072916   18.269344
# 75%             -0.364000       2.809000    1.000000    17.432255   22.751595
# max              0.157000       3.515000    1.000000    28.916548   36.355442
#
#             g_MAX  contr_g_MAX
# count  103.000000   103.000000
# mean   240.572816  3008.938899
# std      9.358442   876.023529
# min    194.000000   815.342712
# 25%    236.500000  2464.687256
# 50%    243.000000  2994.793701
# 75%    247.000000  3464.970947
# max    253.000000  6230.940918

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_M_crown_kg_m2"
indep_variables = ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0          4.771            1.792                -0.211            -0.261
# 1          5.808            2.496                -0.073             0.392
# 2          5.796            2.546                 0.030             0.501
# 3          5.826            2.643                 0.000             0.419
# 4          6.059            2.643                 0.122             0.647
# ..           ...              ...                   ...               ...
# 98         5.389            2.366                 0.531             0.182
# 99         2.398           -0.186                -1.309            -1.966
# 100        1.792           -0.968                -2.120            -1.966
# 101        4.836            1.733                -0.386             0.732
# 102        2.944           -0.211                -1.966            -1.470
#
#      ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  \
# 0                -2.040          1.932     0.85    12.233545   19.097736
# 1                -0.139          2.674     1.00    14.964220   17.704655
# 2                -0.030          2.734     1.00    15.329449   17.559893
# 3                -0.431          2.785     0.97    15.392742   20.676994
# 4                -0.386          2.809     1.00    17.944009   21.851387
# ..                  ...            ...      ...          ...         ...
# 98               -1.386          2.493     0.84    11.654902   17.083910
# 99               -3.507          0.000     0.17     4.722706   10.924606
# 100              -2.408         -0.511     0.17     4.620455   10.747827
# 101              -0.041          2.163     0.88     7.371921   11.443830
# 102              -1.609          0.182     0.28     2.765120    8.069081
#
#      g_MAX  contr_g_MAX
# 0      243  2961.898193
# 1      248  2218.239746
# 2      240  2220.297119
# 3      244  3033.770752
# 4      243  3003.818848
# ..     ...          ...
# 98     250  3469.805908
# 99     241  1748.447998
# 100    233  1708.681763
# 101    241  3066.087402
# 102    227  2756.989014
#
# [103 rows x 11 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  contr_g_MAX
# 0     0.85    12.233545   19.097736    243  2961.898193
# 1     1.00    14.964220   17.704655    248  2218.239746
# 2     1.00    15.329449   17.559893    240  2220.297119
# 3     0.97    15.392742   20.676994    244  3033.770752
# 4     1.00    17.944009   21.851387    243  3003.818848

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_crown_kg_m2
# 0            -0.261
# 1             0.392
# 2             0.501
# 3             0.419
# 4             0.647

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.7898200358290892, 0.6507334521741883, 0.6671170495460591]
#     Mean: 0.703
#     Std: 0.062
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.39192757 0.33005031 0.41197868]
#     Mean: 0.378
#     Std: 0.035
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.31275819750087597, 0.30123217137596187, 0.2589017283938387]
#     Mean: 0.291
#     Std: 0.023
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.85594906971537                    # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.08026909719227604                 # gamma
print('Gamma: ' + str(p2))

p3 = 0.025467011735823587                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2            # max_depth
print('Max_depth: ' + str(p4))

p5 = 148          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.9895964560219264                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.85594906971537
# Gamma: 0.08026909719227604
# Learning_rate: 0.025467011735823587
# Max_depth: 2
# N_estimators: 148
# Subsample: 0.9895964560219264

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:0.96847	validation_1-rmse:0.88716
# [1]	validation_0-rmse:0.94894	validation_1-rmse:0.87276
# [2]	validation_0-rmse:0.93031	validation_1-rmse:0.85879
# [3]	validation_0-rmse:0.91164	validation_1-rmse:0.84665
# [4]	validation_0-rmse:0.89347	validation_1-rmse:0.83330
# [5]	validation_0-rmse:0.87594	validation_1-rmse:0.81631
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:0.85870	validation_1-rmse:0.80516
# [7]	validation_0-rmse:0.84190	validation_1-rmse:0.79279
# [8]	validation_0-rmse:0.82556	validation_1-rmse:0.78228
# [9]	validation_0-rmse:0.80963	validation_1-rmse:0.77057
# [10]	validation_0-rmse:0.79415	validation_1-rmse:0.76067
# [11]	validation_0-rmse:0.77929	validation_1-rmse:0.74905
# [12]	validation_0-rmse:0.76453	validation_1-rmse:0.73884
# [13]	validation_0-rmse:0.75018	validation_1-rmse:0.72821
# [14]	validation_0-rmse:0.73600	validation_1-rmse:0.71953
# [15]	validation_0-rmse:0.72221	validation_1-rmse:0.71072
# [16]	validation_0-rmse:0.70883	validation_1-rmse:0.70224
# [17]	validation_0-rmse:0.69591	validation_1-rmse:0.69286
# [18]	validation_0-rmse:0.68332	validation_1-rmse:0.68522
# [19]	validation_0-rmse:0.67114	validation_1-rmse:0.67794
# [20]	validation_0-rmse:0.65922	validation_1-rmse:0.66949
# [21]	validation_0-rmse:0.64749	validation_1-rmse:0.66222
# [22]	validation_0-rmse:0.63604	validation_1-rmse:0.65448
# [23]	validation_0-rmse:0.62493	validation_1-rmse:0.64765
# [24]	validation_0-rmse:0.61421	validation_1-rmse:0.64014
# [25]	validation_0-rmse:0.60369	validation_1-rmse:0.63372
# [26]	validation_0-rmse:0.59338	validation_1-rmse:0.62679
# [27]	validation_0-rmse:0.58339	validation_1-rmse:0.62067
# [28]	validation_0-rmse:0.57371	validation_1-rmse:0.61343
# [29]	validation_0-rmse:0.56428	validation_1-rmse:0.60668
# [30]	validation_0-rmse:0.55511	validation_1-rmse:0.60124
# [31]	validation_0-rmse:0.54626	validation_1-rmse:0.59679
# [32]	validation_0-rmse:0.53760	validation_1-rmse:0.59060
# [33]	validation_0-rmse:0.52933	validation_1-rmse:0.58578
# [34]	validation_0-rmse:0.52112	validation_1-rmse:0.58062
# [35]	validation_0-rmse:0.51309	validation_1-rmse:0.57656
# [36]	validation_0-rmse:0.50530	validation_1-rmse:0.57209
# [37]	validation_0-rmse:0.49774	validation_1-rmse:0.56835
# [38]	validation_0-rmse:0.49043	validation_1-rmse:0.56481
# [39]	validation_0-rmse:0.48384	validation_1-rmse:0.56128
# [40]	validation_0-rmse:0.47682	validation_1-rmse:0.55750
# [41]	validation_0-rmse:0.47012	validation_1-rmse:0.55431
# [42]	validation_0-rmse:0.46365	validation_1-rmse:0.54960
# [43]	validation_0-rmse:0.45726	validation_1-rmse:0.54604
# [44]	validation_0-rmse:0.45093	validation_1-rmse:0.54275
# [45]	validation_0-rmse:0.44543	validation_1-rmse:0.53956
# [46]	validation_0-rmse:0.43937	validation_1-rmse:0.53644
# [47]	validation_0-rmse:0.43361	validation_1-rmse:0.53236
# [48]	validation_0-rmse:0.42804	validation_1-rmse:0.52929
# [49]	validation_0-rmse:0.42264	validation_1-rmse:0.52673
# [50]	validation_0-rmse:0.41741	validation_1-rmse:0.52403
# [51]	validation_0-rmse:0.41235	validation_1-rmse:0.52130
# [52]	validation_0-rmse:0.40740	validation_1-rmse:0.51888
# [53]	validation_0-rmse:0.40263	validation_1-rmse:0.51546
# [54]	validation_0-rmse:0.39796	validation_1-rmse:0.51197
# [55]	validation_0-rmse:0.39345	validation_1-rmse:0.50979
# [56]	validation_0-rmse:0.38885	validation_1-rmse:0.50722
# [57]	validation_0-rmse:0.38460	validation_1-rmse:0.50397
# [58]	validation_0-rmse:0.38029	validation_1-rmse:0.50156
# [59]	validation_0-rmse:0.37611	validation_1-rmse:0.49862
# [60]	validation_0-rmse:0.37206	validation_1-rmse:0.49631
# [61]	validation_0-rmse:0.36814	validation_1-rmse:0.49452
# [62]	validation_0-rmse:0.36432	validation_1-rmse:0.49258
# [63]	validation_0-rmse:0.36060	validation_1-rmse:0.49083
# [64]	validation_0-rmse:0.35700	validation_1-rmse:0.48870
# [65]	validation_0-rmse:0.35348	validation_1-rmse:0.48701
# [66]	validation_0-rmse:0.35009	validation_1-rmse:0.48543
# [67]	validation_0-rmse:0.34678	validation_1-rmse:0.48344
# [68]	validation_0-rmse:0.34368	validation_1-rmse:0.48200
# [69]	validation_0-rmse:0.34068	validation_1-rmse:0.47927
# [70]	validation_0-rmse:0.33765	validation_1-rmse:0.47750
# [71]	validation_0-rmse:0.33449	validation_1-rmse:0.47581
# [72]	validation_0-rmse:0.33145	validation_1-rmse:0.47419
# [73]	validation_0-rmse:0.32863	validation_1-rmse:0.47290
# [74]	validation_0-rmse:0.32595	validation_1-rmse:0.47223
# [75]	validation_0-rmse:0.32330	validation_1-rmse:0.47043
# [76]	validation_0-rmse:0.32058	validation_1-rmse:0.46897
# [77]	validation_0-rmse:0.31808	validation_1-rmse:0.46786
# [78]	validation_0-rmse:0.31577	validation_1-rmse:0.46680
# [79]	validation_0-rmse:0.31328	validation_1-rmse:0.46546
# [80]	validation_0-rmse:0.31103	validation_1-rmse:0.46345
# [81]	validation_0-rmse:0.30818	validation_1-rmse:0.45993
# [82]	validation_0-rmse:0.30614	validation_1-rmse:0.45954
# [83]	validation_0-rmse:0.30418	validation_1-rmse:0.45872
# [84]	validation_0-rmse:0.30202	validation_1-rmse:0.45757
# [85]	validation_0-rmse:0.29931	validation_1-rmse:0.45420
# [86]	validation_0-rmse:0.29744	validation_1-rmse:0.45386
# [87]	validation_0-rmse:0.29547	validation_1-rmse:0.45283
# [88]	validation_0-rmse:0.29317	validation_1-rmse:0.44956
# [89]	validation_0-rmse:0.29142	validation_1-rmse:0.44926
# [90]	validation_0-rmse:0.28925	validation_1-rmse:0.44614
# [91]	validation_0-rmse:0.28757	validation_1-rmse:0.44538
# [92]	validation_0-rmse:0.28540	validation_1-rmse:0.44265
# [93]	validation_0-rmse:0.28386	validation_1-rmse:0.44204
# [94]	validation_0-rmse:0.28190	validation_1-rmse:0.43919
# [95]	validation_0-rmse:0.27992	validation_1-rmse:0.43675
# [96]	validation_0-rmse:0.27857	validation_1-rmse:0.43629
# [97]	validation_0-rmse:0.27662	validation_1-rmse:0.43395
# [98]	validation_0-rmse:0.27489	validation_1-rmse:0.43320
# [99]	validation_0-rmse:0.27312	validation_1-rmse:0.43103
# [100]	validation_0-rmse:0.27182	validation_1-rmse:0.43051
# [101]	validation_0-rmse:0.27015	validation_1-rmse:0.42851
# [102]	validation_0-rmse:0.26882	validation_1-rmse:0.42815
# [103]	validation_0-rmse:0.26763	validation_1-rmse:0.42769
# [104]	validation_0-rmse:0.26616	validation_1-rmse:0.42699
# [105]	validation_0-rmse:0.26503	validation_1-rmse:0.42657
# [106]	validation_0-rmse:0.26354	validation_1-rmse:0.42477
# [107]	validation_0-rmse:0.26212	validation_1-rmse:0.42316
# [108]	validation_0-rmse:0.26097	validation_1-rmse:0.42287
# [109]	validation_0-rmse:0.25961	validation_1-rmse:0.42116
# [110]	validation_0-rmse:0.25829	validation_1-rmse:0.41945
# [111]	validation_0-rmse:0.25702	validation_1-rmse:0.41786
# [112]	validation_0-rmse:0.25609	validation_1-rmse:0.41774
# [113]	validation_0-rmse:0.25489	validation_1-rmse:0.41640
# [114]	validation_0-rmse:0.25384	validation_1-rmse:0.41617
# [115]	validation_0-rmse:0.25289	validation_1-rmse:0.41599
# [116]	validation_0-rmse:0.25194	validation_1-rmse:0.41559
# [117]	validation_0-rmse:0.25084	validation_1-rmse:0.41415
# [118]	validation_0-rmse:0.25019	validation_1-rmse:0.41419
# [119]	validation_0-rmse:0.24935	validation_1-rmse:0.41391
# [120]	validation_0-rmse:0.24843	validation_1-rmse:0.41373
# [121]	validation_0-rmse:0.24755	validation_1-rmse:0.41347
# [122]	validation_0-rmse:0.24672	validation_1-rmse:0.41313
# [123]	validation_0-rmse:0.24589	validation_1-rmse:0.41299
# [124]	validation_0-rmse:0.24514	validation_1-rmse:0.41447
# [125]	validation_0-rmse:0.24417	validation_1-rmse:0.41351
# [126]	validation_0-rmse:0.24333	validation_1-rmse:0.41486
# [127]	validation_0-rmse:0.24240	validation_1-rmse:0.41450
# [128]	validation_0-rmse:0.24171	validation_1-rmse:0.41429
# [129]	validation_0-rmse:0.24096	validation_1-rmse:0.41420
# [130]	validation_0-rmse:0.24040	validation_1-rmse:0.41416
# [131]	validation_0-rmse:0.23977	validation_1-rmse:0.41397
# [132]	validation_0-rmse:0.23887	validation_1-rmse:0.41316
# [133]	validation_0-rmse:0.23822	validation_1-rmse:0.41377
# [134]	validation_0-rmse:0.23737	validation_1-rmse:0.41302
# [135]	validation_0-rmse:0.23666	validation_1-rmse:0.41415
# [136]	validation_0-rmse:0.23599	validation_1-rmse:0.41406
# [137]	validation_0-rmse:0.23521	validation_1-rmse:0.41351
# [138]	validation_0-rmse:0.23453	validation_1-rmse:0.41462
# [139]	validation_0-rmse:0.23389	validation_1-rmse:0.41451
# [140]	validation_0-rmse:0.23333	validation_1-rmse:0.41447
# [141]	validation_0-rmse:0.23263	validation_1-rmse:0.41546
# [142]	validation_0-rmse:0.23199	validation_1-rmse:0.41655
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:0.91197	validation_1-rmse:1.09190
# [1]	validation_0-rmse:0.89350	validation_1-rmse:1.06866
# [2]	validation_0-rmse:0.87555	validation_1-rmse:1.04612
# [3]	validation_0-rmse:0.85782	validation_1-rmse:1.02421
# [4]	validation_0-rmse:0.84072	validation_1-rmse:1.00252
# [5]	validation_0-rmse:0.82417	validation_1-rmse:0.98206
# [6]	validation_0-rmse:0.80798	validation_1-rmse:0.96176
# [7]	validation_0-rmse:0.79208	validation_1-rmse:0.94249
# [8]	validation_0-rmse:0.77675	validation_1-rmse:0.92345
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [9]	validation_0-rmse:0.76174	validation_1-rmse:0.90462
# [10]	validation_0-rmse:0.74712	validation_1-rmse:0.88590
# [11]	validation_0-rmse:0.73309	validation_1-rmse:0.86931
# [12]	validation_0-rmse:0.71925	validation_1-rmse:0.85298
# [13]	validation_0-rmse:0.70579	validation_1-rmse:0.83697
# [14]	validation_0-rmse:0.69273	validation_1-rmse:0.82132
# [15]	validation_0-rmse:0.67973	validation_1-rmse:0.80591
# [16]	validation_0-rmse:0.66734	validation_1-rmse:0.79079
# [17]	validation_0-rmse:0.65548	validation_1-rmse:0.77638
# [18]	validation_0-rmse:0.64396	validation_1-rmse:0.76276
# [19]	validation_0-rmse:0.63266	validation_1-rmse:0.75105
# [20]	validation_0-rmse:0.62167	validation_1-rmse:0.73974
# [21]	validation_0-rmse:0.61085	validation_1-rmse:0.72834
# [22]	validation_0-rmse:0.60034	validation_1-rmse:0.71726
# [23]	validation_0-rmse:0.59012	validation_1-rmse:0.70520
# [24]	validation_0-rmse:0.58028	validation_1-rmse:0.69536
# [25]	validation_0-rmse:0.57062	validation_1-rmse:0.68534
# [26]	validation_0-rmse:0.56124	validation_1-rmse:0.67466
# [27]	validation_0-rmse:0.55208	validation_1-rmse:0.66529
# [28]	validation_0-rmse:0.54351	validation_1-rmse:0.65667
# [29]	validation_0-rmse:0.53491	validation_1-rmse:0.64680
# [30]	validation_0-rmse:0.52652	validation_1-rmse:0.63742
# [31]	validation_0-rmse:0.51845	validation_1-rmse:0.62925
# [32]	validation_0-rmse:0.51068	validation_1-rmse:0.62028
# [33]	validation_0-rmse:0.50306	validation_1-rmse:0.61188
# [34]	validation_0-rmse:0.49566	validation_1-rmse:0.60421
# [35]	validation_0-rmse:0.48820	validation_1-rmse:0.59783
# [36]	validation_0-rmse:0.48094	validation_1-rmse:0.59170
# [37]	validation_0-rmse:0.47414	validation_1-rmse:0.58579
# [38]	validation_0-rmse:0.46732	validation_1-rmse:0.58016
# [39]	validation_0-rmse:0.46073	validation_1-rmse:0.57476
# [40]	validation_0-rmse:0.45456	validation_1-rmse:0.56949
# [41]	validation_0-rmse:0.44849	validation_1-rmse:0.56391
# [42]	validation_0-rmse:0.44246	validation_1-rmse:0.55912
# [43]	validation_0-rmse:0.43674	validation_1-rmse:0.55215
# [44]	validation_0-rmse:0.43105	validation_1-rmse:0.54774
# [45]	validation_0-rmse:0.42610	validation_1-rmse:0.54390
# [46]	validation_0-rmse:0.42081	validation_1-rmse:0.53976
# [47]	validation_0-rmse:0.41572	validation_1-rmse:0.53301
# [48]	validation_0-rmse:0.41082	validation_1-rmse:0.52647
# [49]	validation_0-rmse:0.40596	validation_1-rmse:0.52269
# [50]	validation_0-rmse:0.40134	validation_1-rmse:0.51652
# [51]	validation_0-rmse:0.39689	validation_1-rmse:0.51181
# [52]	validation_0-rmse:0.39241	validation_1-rmse:0.50846
# [53]	validation_0-rmse:0.38823	validation_1-rmse:0.50280
# [54]	validation_0-rmse:0.38403	validation_1-rmse:0.49964
# [55]	validation_0-rmse:0.38003	validation_1-rmse:0.49516
# [56]	validation_0-rmse:0.37618	validation_1-rmse:0.49082
# [57]	validation_0-rmse:0.37239	validation_1-rmse:0.48803
# [58]	validation_0-rmse:0.36871	validation_1-rmse:0.48536
# [59]	validation_0-rmse:0.36507	validation_1-rmse:0.48270
# [60]	validation_0-rmse:0.36168	validation_1-rmse:0.47889
# [61]	validation_0-rmse:0.35834	validation_1-rmse:0.47656
# [62]	validation_0-rmse:0.35503	validation_1-rmse:0.47231
# [63]	validation_0-rmse:0.35197	validation_1-rmse:0.46871
# [64]	validation_0-rmse:0.34893	validation_1-rmse:0.46648
# [65]	validation_0-rmse:0.34591	validation_1-rmse:0.46373
# [66]	validation_0-rmse:0.34299	validation_1-rmse:0.45991
# [67]	validation_0-rmse:0.34017	validation_1-rmse:0.45794
# [68]	validation_0-rmse:0.33754	validation_1-rmse:0.45514
# [69]	validation_0-rmse:0.33494	validation_1-rmse:0.45297
# [70]	validation_0-rmse:0.33243	validation_1-rmse:0.45134
# [71]	validation_0-rmse:0.33003	validation_1-rmse:0.44978
# [72]	validation_0-rmse:0.32770	validation_1-rmse:0.44822
# [73]	validation_0-rmse:0.32546	validation_1-rmse:0.44680
# [74]	validation_0-rmse:0.32319	validation_1-rmse:0.44363
# [75]	validation_0-rmse:0.32110	validation_1-rmse:0.44227
# [76]	validation_0-rmse:0.31909	validation_1-rmse:0.44118
# [77]	validation_0-rmse:0.31700	validation_1-rmse:0.44004
# [78]	validation_0-rmse:0.31511	validation_1-rmse:0.43780
# [79]	validation_0-rmse:0.31319	validation_1-rmse:0.43694
# [80]	validation_0-rmse:0.31115	validation_1-rmse:0.43521
# [81]	validation_0-rmse:0.30943	validation_1-rmse:0.43394
# [82]	validation_0-rmse:0.30777	validation_1-rmse:0.43168
# [83]	validation_0-rmse:0.30615	validation_1-rmse:0.43053
# [84]	validation_0-rmse:0.30455	validation_1-rmse:0.42810
# [85]	validation_0-rmse:0.30306	validation_1-rmse:0.42531
# [86]	validation_0-rmse:0.30159	validation_1-rmse:0.42306
# [87]	validation_0-rmse:0.30014	validation_1-rmse:0.42277
# [88]	validation_0-rmse:0.29873	validation_1-rmse:0.42254
# [89]	validation_0-rmse:0.29716	validation_1-rmse:0.42136
# [90]	validation_0-rmse:0.29586	validation_1-rmse:0.42103
# [91]	validation_0-rmse:0.29449	validation_1-rmse:0.41902
# [92]	validation_0-rmse:0.29327	validation_1-rmse:0.41881
# [93]	validation_0-rmse:0.29200	validation_1-rmse:0.41850
# [94]	validation_0-rmse:0.29073	validation_1-rmse:0.41798
# [95]	validation_0-rmse:0.28924	validation_1-rmse:0.41597
# [96]	validation_0-rmse:0.28812	validation_1-rmse:0.41433
# [97]	validation_0-rmse:0.28683	validation_1-rmse:0.41337
# [98]	validation_0-rmse:0.28553	validation_1-rmse:0.41158
# [99]	validation_0-rmse:0.28442	validation_1-rmse:0.41112
# [100]	validation_0-rmse:0.28325	validation_1-rmse:0.41065
# [101]	validation_0-rmse:0.28224	validation_1-rmse:0.41059
# [102]	validation_0-rmse:0.28112	validation_1-rmse:0.41015
# [103]	validation_0-rmse:0.28012	validation_1-rmse:0.40977
# [104]	validation_0-rmse:0.27906	validation_1-rmse:0.40893
# [105]	validation_0-rmse:0.27810	validation_1-rmse:0.40858
# [106]	validation_0-rmse:0.27687	validation_1-rmse:0.40693
# [107]	validation_0-rmse:0.27569	validation_1-rmse:0.40554
# [108]	validation_0-rmse:0.27424	validation_1-rmse:0.40403
# [109]	validation_0-rmse:0.27314	validation_1-rmse:0.40256
# [110]	validation_0-rmse:0.27232	validation_1-rmse:0.40262
# [111]	validation_0-rmse:0.27128	validation_1-rmse:0.40122
# [112]	validation_0-rmse:0.27050	validation_1-rmse:0.39943
# [113]	validation_0-rmse:0.26950	validation_1-rmse:0.39882
# [114]	validation_0-rmse:0.26862	validation_1-rmse:0.39837
# [115]	validation_0-rmse:0.26777	validation_1-rmse:0.39795
# [116]	validation_0-rmse:0.26694	validation_1-rmse:0.39609
# [117]	validation_0-rmse:0.26601	validation_1-rmse:0.39500
# [118]	validation_0-rmse:0.26507	validation_1-rmse:0.39438
# [119]	validation_0-rmse:0.26425	validation_1-rmse:0.39368
# [120]	validation_0-rmse:0.26348	validation_1-rmse:0.39332
# [121]	validation_0-rmse:0.26273	validation_1-rmse:0.39306
# [122]	validation_0-rmse:0.26198	validation_1-rmse:0.39244
# [123]	validation_0-rmse:0.26124	validation_1-rmse:0.39179
# [124]	validation_0-rmse:0.26055	validation_1-rmse:0.39007
# [125]	validation_0-rmse:0.26003	validation_1-rmse:0.39029
# [126]	validation_0-rmse:0.25929	validation_1-rmse:0.39022
# [127]	validation_0-rmse:0.25854	validation_1-rmse:0.38977
# [128]	validation_0-rmse:0.25805	validation_1-rmse:0.38828
# [129]	validation_0-rmse:0.25756	validation_1-rmse:0.38848
# [130]	validation_0-rmse:0.25694	validation_1-rmse:0.38685
# [131]	validation_0-rmse:0.25628	validation_1-rmse:0.38655
# [132]	validation_0-rmse:0.25555	validation_1-rmse:0.38659
# [133]	validation_0-rmse:0.25498	validation_1-rmse:0.38667
# [134]	validation_0-rmse:0.25451	validation_1-rmse:0.38687
# [135]	validation_0-rmse:0.25389	validation_1-rmse:0.38659
# [136]	validation_0-rmse:0.25345	validation_1-rmse:0.38671
# [137]	validation_0-rmse:0.25301	validation_1-rmse:0.38557
# [138]	validation_0-rmse:0.25258	validation_1-rmse:0.38444
# [139]	validation_0-rmse:0.25216	validation_1-rmse:0.38436
# [140]	validation_0-rmse:0.25156	validation_1-rmse:0.38439
# [141]	validation_0-rmse:0.25096	validation_1-rmse:0.38394
# [142]	validation_0-rmse:0.25054	validation_1-rmse:0.38425
# [143]	validation_0-rmse:0.25014	validation_1-rmse:0.38444
# [144]	validation_0-rmse:0.24974	validation_1-rmse:0.38437
# [145]	validation_0-rmse:0.24936	validation_1-rmse:0.38328
# [146]	validation_0-rmse:0.24899	validation_1-rmse:0.38342
# [147]	validation_0-rmse:0.24861	validation_1-rmse:0.38323
# [0]	validation_0-rmse:0.94214	validation_1-rmse:0.98403
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:0.92323	validation_1-rmse:0.95944
# [2]	validation_0-rmse:0.90489	validation_1-rmse:0.93562
# [3]	validation_0-rmse:0.88663	validation_1-rmse:0.91195
# [4]	validation_0-rmse:0.86887	validation_1-rmse:0.88901
# [5]	validation_0-rmse:0.85185	validation_1-rmse:0.86722
# [6]	validation_0-rmse:0.83499	validation_1-rmse:0.84565
# [7]	validation_0-rmse:0.81858	validation_1-rmse:0.82477
# [8]	validation_0-rmse:0.80258	validation_1-rmse:0.80467
# [9]	validation_0-rmse:0.78714	validation_1-rmse:0.78669
# [10]	validation_0-rmse:0.77211	validation_1-rmse:0.76935
# [11]	validation_0-rmse:0.75768	validation_1-rmse:0.75144
# [12]	validation_0-rmse:0.74328	validation_1-rmse:0.73394
# [13]	validation_0-rmse:0.72940	validation_1-rmse:0.71863
# [14]	validation_0-rmse:0.71566	validation_1-rmse:0.70217
# [15]	validation_0-rmse:0.70213	validation_1-rmse:0.68612
# [16]	validation_0-rmse:0.68920	validation_1-rmse:0.67189
# [17]	validation_0-rmse:0.67666	validation_1-rmse:0.65904
# [18]	validation_0-rmse:0.66446	validation_1-rmse:0.64528
# [19]	validation_0-rmse:0.65282	validation_1-rmse:0.63195
# [20]	validation_0-rmse:0.64150	validation_1-rmse:0.62020
# [21]	validation_0-rmse:0.63017	validation_1-rmse:0.60926
# [22]	validation_0-rmse:0.61916	validation_1-rmse:0.59880
# [23]	validation_0-rmse:0.60846	validation_1-rmse:0.58878
# [24]	validation_0-rmse:0.59832	validation_1-rmse:0.57782
# [25]	validation_0-rmse:0.58819	validation_1-rmse:0.56866
# [26]	validation_0-rmse:0.57835	validation_1-rmse:0.56004
# [27]	validation_0-rmse:0.56877	validation_1-rmse:0.55171
# [28]	validation_0-rmse:0.55963	validation_1-rmse:0.54287
# [29]	validation_0-rmse:0.55072	validation_1-rmse:0.53611
# [30]	validation_0-rmse:0.54203	validation_1-rmse:0.52968
# [31]	validation_0-rmse:0.53334	validation_1-rmse:0.52148
# [32]	validation_0-rmse:0.52511	validation_1-rmse:0.51580
# [33]	validation_0-rmse:0.51723	validation_1-rmse:0.51061
# [34]	validation_0-rmse:0.50934	validation_1-rmse:0.50264
# [35]	validation_0-rmse:0.50153	validation_1-rmse:0.49548
# [36]	validation_0-rmse:0.49396	validation_1-rmse:0.48870
# [37]	validation_0-rmse:0.48670	validation_1-rmse:0.48160
# [38]	validation_0-rmse:0.47962	validation_1-rmse:0.47623
# [39]	validation_0-rmse:0.47273	validation_1-rmse:0.47093
# [40]	validation_0-rmse:0.46603	validation_1-rmse:0.46485
# [41]	validation_0-rmse:0.45959	validation_1-rmse:0.46060
# [42]	validation_0-rmse:0.45329	validation_1-rmse:0.45608
# [43]	validation_0-rmse:0.44696	validation_1-rmse:0.45334
# [44]	validation_0-rmse:0.44079	validation_1-rmse:0.45083
# [45]	validation_0-rmse:0.43469	validation_1-rmse:0.44773
# [46]	validation_0-rmse:0.42912	validation_1-rmse:0.44325
# [47]	validation_0-rmse:0.42373	validation_1-rmse:0.44189
# [48]	validation_0-rmse:0.41852	validation_1-rmse:0.44079
# [49]	validation_0-rmse:0.41335	validation_1-rmse:0.43809
# [50]	validation_0-rmse:0.40847	validation_1-rmse:0.43742
# [51]	validation_0-rmse:0.40376	validation_1-rmse:0.43696
# [52]	validation_0-rmse:0.39894	validation_1-rmse:0.43523
# [53]	validation_0-rmse:0.39452	validation_1-rmse:0.43508
# [54]	validation_0-rmse:0.38997	validation_1-rmse:0.43363
# [55]	validation_0-rmse:0.38563	validation_1-rmse:0.43191
# [56]	validation_0-rmse:0.38143	validation_1-rmse:0.43017
# [57]	validation_0-rmse:0.37729	validation_1-rmse:0.42908
# [58]	validation_0-rmse:0.37330	validation_1-rmse:0.42751
# [59]	validation_0-rmse:0.36943	validation_1-rmse:0.42666
# [60]	validation_0-rmse:0.36551	validation_1-rmse:0.42633
# [61]	validation_0-rmse:0.36194	validation_1-rmse:0.42512
# [62]	validation_0-rmse:0.35825	validation_1-rmse:0.42495
# [63]	validation_0-rmse:0.35492	validation_1-rmse:0.42402
# [64]	validation_0-rmse:0.35146	validation_1-rmse:0.42400
# [65]	validation_0-rmse:0.34811	validation_1-rmse:0.42380
# [66]	validation_0-rmse:0.34509	validation_1-rmse:0.42328
# [67]	validation_0-rmse:0.34193	validation_1-rmse:0.42344
# [68]	validation_0-rmse:0.33912	validation_1-rmse:0.42455
# [69]	validation_0-rmse:0.33641	validation_1-rmse:0.42547
# [70]	validation_0-rmse:0.33342	validation_1-rmse:0.42496
# [71]	validation_0-rmse:0.33055	validation_1-rmse:0.42451
# [72]	validation_0-rmse:0.32778	validation_1-rmse:0.42413
# [73]	validation_0-rmse:0.32508	validation_1-rmse:0.42350
# [74]	validation_0-rmse:0.32253	validation_1-rmse:0.42340
# [75]	validation_0-rmse:0.32005	validation_1-rmse:0.42318
# [76]	validation_0-rmse:0.31765	validation_1-rmse:0.42301
# [77]	validation_0-rmse:0.31561	validation_1-rmse:0.42325
# [78]	validation_0-rmse:0.31316	validation_1-rmse:0.42408
# [79]	validation_0-rmse:0.31099	validation_1-rmse:0.42400
# [80]	validation_0-rmse:0.30887	validation_1-rmse:0.42474
# [81]	validation_0-rmse:0.30696	validation_1-rmse:0.42614
# [82]	validation_0-rmse:0.30515	validation_1-rmse:0.42634
# [83]	validation_0-rmse:0.30358	validation_1-rmse:0.42725
# [84]	validation_0-rmse:0.30198	validation_1-rmse:0.42841
# [85]	validation_0-rmse:0.30025	validation_1-rmse:0.42983
# [86]	validation_0-rmse:0.29848	validation_1-rmse:0.43003
# [87]	validation_0-rmse:0.29672	validation_1-rmse:0.43009
# [88]	validation_0-rmse:0.29504	validation_1-rmse:0.43045
# [89]	validation_0-rmse:0.29343	validation_1-rmse:0.43094
# [90]	validation_0-rmse:0.29185	validation_1-rmse:0.43135
# [91]	validation_0-rmse:0.29018	validation_1-rmse:0.43177
# [92]	validation_0-rmse:0.28859	validation_1-rmse:0.43232
# [93]	validation_0-rmse:0.28707	validation_1-rmse:0.43287
# [94]	validation_0-rmse:0.28566	validation_1-rmse:0.43333
# [95]	validation_0-rmse:0.28432	validation_1-rmse:0.43447
# [0]	validation_0-rmse:0.95293	validation_1-rmse:0.94680
# [1]	validation_0-rmse:0.93379	validation_1-rmse:0.92702
# [2]	validation_0-rmse:0.91515	validation_1-rmse:0.90782
# [3]	validation_0-rmse:0.89692	validation_1-rmse:0.89130
# [4]	validation_0-rmse:0.87921	validation_1-rmse:0.87531
# [5]	validation_0-rmse:0.86206	validation_1-rmse:0.85842
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:0.84528	validation_1-rmse:0.84334
# [7]	validation_0-rmse:0.82892	validation_1-rmse:0.82828
# [8]	validation_0-rmse:0.81301	validation_1-rmse:0.81410
# [9]	validation_0-rmse:0.79751	validation_1-rmse:0.79993
# [10]	validation_0-rmse:0.78245	validation_1-rmse:0.78707
# [11]	validation_0-rmse:0.76749	validation_1-rmse:0.77227
# [12]	validation_0-rmse:0.75316	validation_1-rmse:0.75787
# [13]	validation_0-rmse:0.73928	validation_1-rmse:0.74534
# [14]	validation_0-rmse:0.72563	validation_1-rmse:0.73090
# [15]	validation_0-rmse:0.71240	validation_1-rmse:0.71701
# [16]	validation_0-rmse:0.69951	validation_1-rmse:0.70437
# [17]	validation_0-rmse:0.68705	validation_1-rmse:0.69406
# [18]	validation_0-rmse:0.67494	validation_1-rmse:0.68099
# [19]	validation_0-rmse:0.66317	validation_1-rmse:0.66832
# [20]	validation_0-rmse:0.65172	validation_1-rmse:0.65606
# [21]	validation_0-rmse:0.64043	validation_1-rmse:0.64585
# [22]	validation_0-rmse:0.62945	validation_1-rmse:0.63461
# [23]	validation_0-rmse:0.61878	validation_1-rmse:0.62378
# [24]	validation_0-rmse:0.60852	validation_1-rmse:0.61296
# [25]	validation_0-rmse:0.59844	validation_1-rmse:0.60405
# [26]	validation_0-rmse:0.58863	validation_1-rmse:0.59499
# [27]	validation_0-rmse:0.57909	validation_1-rmse:0.58550
# [28]	validation_0-rmse:0.57000	validation_1-rmse:0.57610
# [29]	validation_0-rmse:0.56103	validation_1-rmse:0.56947
# [30]	validation_0-rmse:0.55231	validation_1-rmse:0.56275
# [31]	validation_0-rmse:0.54380	validation_1-rmse:0.55494
# [32]	validation_0-rmse:0.53558	validation_1-rmse:0.54901
# [33]	validation_0-rmse:0.52763	validation_1-rmse:0.54261
# [34]	validation_0-rmse:0.52007	validation_1-rmse:0.53647
# [35]	validation_0-rmse:0.51229	validation_1-rmse:0.53023
# [36]	validation_0-rmse:0.50473	validation_1-rmse:0.52387
# [37]	validation_0-rmse:0.49741	validation_1-rmse:0.51801
# [38]	validation_0-rmse:0.49040	validation_1-rmse:0.51154
# [39]	validation_0-rmse:0.48362	validation_1-rmse:0.50527
# [40]	validation_0-rmse:0.47691	validation_1-rmse:0.49991
# [41]	validation_0-rmse:0.47051	validation_1-rmse:0.49465
# [42]	validation_0-rmse:0.46417	validation_1-rmse:0.48867
# [43]	validation_0-rmse:0.45808	validation_1-rmse:0.48384
# [44]	validation_0-rmse:0.45206	validation_1-rmse:0.47916
# [45]	validation_0-rmse:0.44668	validation_1-rmse:0.47456
# [46]	validation_0-rmse:0.44107	validation_1-rmse:0.46986
# [47]	validation_0-rmse:0.43574	validation_1-rmse:0.46641
# [48]	validation_0-rmse:0.43062	validation_1-rmse:0.46318
# [49]	validation_0-rmse:0.42546	validation_1-rmse:0.45752
# [50]	validation_0-rmse:0.42061	validation_1-rmse:0.45385
# [51]	validation_0-rmse:0.41593	validation_1-rmse:0.45107
# [52]	validation_0-rmse:0.41114	validation_1-rmse:0.44579
# [53]	validation_0-rmse:0.40673	validation_1-rmse:0.44316
# [54]	validation_0-rmse:0.40228	validation_1-rmse:0.43887
# [55]	validation_0-rmse:0.39798	validation_1-rmse:0.43474
# [56]	validation_0-rmse:0.39382	validation_1-rmse:0.43138
# [57]	validation_0-rmse:0.38980	validation_1-rmse:0.42764
# [58]	validation_0-rmse:0.38580	validation_1-rmse:0.42384
# [59]	validation_0-rmse:0.38194	validation_1-rmse:0.42019
# [60]	validation_0-rmse:0.37824	validation_1-rmse:0.41671
# [61]	validation_0-rmse:0.37462	validation_1-rmse:0.41393
# [62]	validation_0-rmse:0.37112	validation_1-rmse:0.41141
# [63]	validation_0-rmse:0.36774	validation_1-rmse:0.40879
# [64]	validation_0-rmse:0.36446	validation_1-rmse:0.40568
# [65]	validation_0-rmse:0.36127	validation_1-rmse:0.40319
# [66]	validation_0-rmse:0.35817	validation_1-rmse:0.40036
# [67]	validation_0-rmse:0.35504	validation_1-rmse:0.39842
# [68]	validation_0-rmse:0.35222	validation_1-rmse:0.39704
# [69]	validation_0-rmse:0.34953	validation_1-rmse:0.39561
# [70]	validation_0-rmse:0.34665	validation_1-rmse:0.39314
# [71]	validation_0-rmse:0.34387	validation_1-rmse:0.39077
# [72]	validation_0-rmse:0.34131	validation_1-rmse:0.38911
# [73]	validation_0-rmse:0.33870	validation_1-rmse:0.38670
# [74]	validation_0-rmse:0.33639	validation_1-rmse:0.38453
# [75]	validation_0-rmse:0.33395	validation_1-rmse:0.38230
# [76]	validation_0-rmse:0.33164	validation_1-rmse:0.38038
# [77]	validation_0-rmse:0.32914	validation_1-rmse:0.37844
# [78]	validation_0-rmse:0.32681	validation_1-rmse:0.37679
# [79]	validation_0-rmse:0.32463	validation_1-rmse:0.37484
# [80]	validation_0-rmse:0.32221	validation_1-rmse:0.37297
# [81]	validation_0-rmse:0.32029	validation_1-rmse:0.37229
# [82]	validation_0-rmse:0.31846	validation_1-rmse:0.37100
# [83]	validation_0-rmse:0.31578	validation_1-rmse:0.36884
# [84]	validation_0-rmse:0.31381	validation_1-rmse:0.36690
# [85]	validation_0-rmse:0.31122	validation_1-rmse:0.36489
# [86]	validation_0-rmse:0.30945	validation_1-rmse:0.36345
# [87]	validation_0-rmse:0.30772	validation_1-rmse:0.36211
# [88]	validation_0-rmse:0.30533	validation_1-rmse:0.35961
# [89]	validation_0-rmse:0.30386	validation_1-rmse:0.35866
# [90]	validation_0-rmse:0.30227	validation_1-rmse:0.35744
# [91]	validation_0-rmse:0.30042	validation_1-rmse:0.35614
# [92]	validation_0-rmse:0.29893	validation_1-rmse:0.35500
# [93]	validation_0-rmse:0.29752	validation_1-rmse:0.35412
# [94]	validation_0-rmse:0.29596	validation_1-rmse:0.35260
# [95]	validation_0-rmse:0.29385	validation_1-rmse:0.35102
# [96]	validation_0-rmse:0.29261	validation_1-rmse:0.35020
# [97]	validation_0-rmse:0.29073	validation_1-rmse:0.34833
# [98]	validation_0-rmse:0.28941	validation_1-rmse:0.34777
# [99]	validation_0-rmse:0.28817	validation_1-rmse:0.34727
# [100]	validation_0-rmse:0.28709	validation_1-rmse:0.34667
# [101]	validation_0-rmse:0.28523	validation_1-rmse:0.34533
# [102]	validation_0-rmse:0.28356	validation_1-rmse:0.34423
# [103]	validation_0-rmse:0.28249	validation_1-rmse:0.34363
# [104]	validation_0-rmse:0.28082	validation_1-rmse:0.34204
# [105]	validation_0-rmse:0.27989	validation_1-rmse:0.34155
# [106]	validation_0-rmse:0.27837	validation_1-rmse:0.34056
# [107]	validation_0-rmse:0.27677	validation_1-rmse:0.33943
# [108]	validation_0-rmse:0.27520	validation_1-rmse:0.33839
# [109]	validation_0-rmse:0.27373	validation_1-rmse:0.33737
# [110]	validation_0-rmse:0.27232	validation_1-rmse:0.33638
# [111]	validation_0-rmse:0.27099	validation_1-rmse:0.33549
# [112]	validation_0-rmse:0.27023	validation_1-rmse:0.33514
# [113]	validation_0-rmse:0.26894	validation_1-rmse:0.33426
# [114]	validation_0-rmse:0.26814	validation_1-rmse:0.33391
# [115]	validation_0-rmse:0.26738	validation_1-rmse:0.33357
# [116]	validation_0-rmse:0.26664	validation_1-rmse:0.33324
# [117]	validation_0-rmse:0.26545	validation_1-rmse:0.33246
# [118]	validation_0-rmse:0.26459	validation_1-rmse:0.33307
# [119]	validation_0-rmse:0.26398	validation_1-rmse:0.33286
# [120]	validation_0-rmse:0.26332	validation_1-rmse:0.33259
# [121]	validation_0-rmse:0.26273	validation_1-rmse:0.33284
# [122]	validation_0-rmse:0.26202	validation_1-rmse:0.33270
# [123]	validation_0-rmse:0.26108	validation_1-rmse:0.33151
# [124]	validation_0-rmse:0.26049	validation_1-rmse:0.33128
# [125]	validation_0-rmse:0.25939	validation_1-rmse:0.33013
# [126]	validation_0-rmse:0.25850	validation_1-rmse:0.32899
# [127]	validation_0-rmse:0.25738	validation_1-rmse:0.32781
# [128]	validation_0-rmse:0.25689	validation_1-rmse:0.32770
# [129]	validation_0-rmse:0.25588	validation_1-rmse:0.32664
# [130]	validation_0-rmse:0.25536	validation_1-rmse:0.32649
# [131]	validation_0-rmse:0.25490	validation_1-rmse:0.32636
# [132]	validation_0-rmse:0.25398	validation_1-rmse:0.32536
# [133]	validation_0-rmse:0.25328	validation_1-rmse:0.32457
# [134]	validation_0-rmse:0.25236	validation_1-rmse:0.32359
# [135]	validation_0-rmse:0.25190	validation_1-rmse:0.32349
# [136]	validation_0-rmse:0.25147	validation_1-rmse:0.32341
# [137]	validation_0-rmse:0.25102	validation_1-rmse:0.32338
# [138]	validation_0-rmse:0.25039	validation_1-rmse:0.32315
# [139]	validation_0-rmse:0.24952	validation_1-rmse:0.32221
# [140]	validation_0-rmse:0.24878	validation_1-rmse:0.32130
# [141]	validation_0-rmse:0.24817	validation_1-rmse:0.32070
# [142]	validation_0-rmse:0.24776	validation_1-rmse:0.32058
# [143]	validation_0-rmse:0.24690	validation_1-rmse:0.31970
# [144]	validation_0-rmse:0.24650	validation_1-rmse:0.31965
# [145]	validation_0-rmse:0.24613	validation_1-rmse:0.32003
# [146]	validation_0-rmse:0.24573	validation_1-rmse:0.32001
# [147]	validation_0-rmse:0.24520	validation_1-rmse:0.32007
# [0]	validation_0-rmse:0.92410	validation_1-rmse:1.05458
# [1]	validation_0-rmse:0.90571	validation_1-rmse:1.03410
# [2]	validation_0-rmse:0.88782	validation_1-rmse:1.01362
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:0.86997	validation_1-rmse:0.99417
# [4]	validation_0-rmse:0.85260	validation_1-rmse:0.97531
# [5]	validation_0-rmse:0.83610	validation_1-rmse:0.95707
# [6]	validation_0-rmse:0.81961	validation_1-rmse:0.93900
# [7]	validation_0-rmse:0.80358	validation_1-rmse:0.92150
# [8]	validation_0-rmse:0.78796	validation_1-rmse:0.90912
# [9]	validation_0-rmse:0.77278	validation_1-rmse:0.89688
# [10]	validation_0-rmse:0.75802	validation_1-rmse:0.88533
# [11]	validation_0-rmse:0.74394	validation_1-rmse:0.86939
# [12]	validation_0-rmse:0.72971	validation_1-rmse:0.85427
# [13]	validation_0-rmse:0.71609	validation_1-rmse:0.84383
# [14]	validation_0-rmse:0.70277	validation_1-rmse:0.82955
# [15]	validation_0-rmse:0.68999	validation_1-rmse:0.81568
# [16]	validation_0-rmse:0.67737	validation_1-rmse:0.80256
# [17]	validation_0-rmse:0.66513	validation_1-rmse:0.79323
# [18]	validation_0-rmse:0.65350	validation_1-rmse:0.78022
# [19]	validation_0-rmse:0.64216	validation_1-rmse:0.77092
# [20]	validation_0-rmse:0.63114	validation_1-rmse:0.75861
# [21]	validation_0-rmse:0.62011	validation_1-rmse:0.74696
# [22]	validation_0-rmse:0.60938	validation_1-rmse:0.73590
# [23]	validation_0-rmse:0.59895	validation_1-rmse:0.72513
# [24]	validation_0-rmse:0.58907	validation_1-rmse:0.71672
# [25]	validation_0-rmse:0.57916	validation_1-rmse:0.70654
# [26]	validation_0-rmse:0.56954	validation_1-rmse:0.69671
# [27]	validation_0-rmse:0.56025	validation_1-rmse:0.68708
# [28]	validation_0-rmse:0.55129	validation_1-rmse:0.67862
# [29]	validation_0-rmse:0.54242	validation_1-rmse:0.67245
# [30]	validation_0-rmse:0.53373	validation_1-rmse:0.66665
# [31]	validation_0-rmse:0.52563	validation_1-rmse:0.65832
# [32]	validation_0-rmse:0.51752	validation_1-rmse:0.65280
# [33]	validation_0-rmse:0.50961	validation_1-rmse:0.64763
# [34]	validation_0-rmse:0.50197	validation_1-rmse:0.63970
# [35]	validation_0-rmse:0.49463	validation_1-rmse:0.63229
# [36]	validation_0-rmse:0.48728	validation_1-rmse:0.62481
# [37]	validation_0-rmse:0.48015	validation_1-rmse:0.61776
# [38]	validation_0-rmse:0.47349	validation_1-rmse:0.61092
# [39]	validation_0-rmse:0.46709	validation_1-rmse:0.60430
# [40]	validation_0-rmse:0.46048	validation_1-rmse:0.59766
# [41]	validation_0-rmse:0.45438	validation_1-rmse:0.59149
# [42]	validation_0-rmse:0.44849	validation_1-rmse:0.58554
# [43]	validation_0-rmse:0.44237	validation_1-rmse:0.57914
# [44]	validation_0-rmse:0.43644	validation_1-rmse:0.57288
# [45]	validation_0-rmse:0.43076	validation_1-rmse:0.56701
# [46]	validation_0-rmse:0.42540	validation_1-rmse:0.56144
# [47]	validation_0-rmse:0.42005	validation_1-rmse:0.55831
# [48]	validation_0-rmse:0.41490	validation_1-rmse:0.55533
# [49]	validation_0-rmse:0.40948	validation_1-rmse:0.55063
# [50]	validation_0-rmse:0.40463	validation_1-rmse:0.54789
# [51]	validation_0-rmse:0.39996	validation_1-rmse:0.54527
# [52]	validation_0-rmse:0.39534	validation_1-rmse:0.54022
# [53]	validation_0-rmse:0.39094	validation_1-rmse:0.53783
# [54]	validation_0-rmse:0.38662	validation_1-rmse:0.53306
# [55]	validation_0-rmse:0.38244	validation_1-rmse:0.52844
# [56]	validation_0-rmse:0.37839	validation_1-rmse:0.52358
# [57]	validation_0-rmse:0.37447	validation_1-rmse:0.51872
# [58]	validation_0-rmse:0.37067	validation_1-rmse:0.51417
# [59]	validation_0-rmse:0.36704	validation_1-rmse:0.50962
# [60]	validation_0-rmse:0.36328	validation_1-rmse:0.50578
# [61]	validation_0-rmse:0.35989	validation_1-rmse:0.50280
# [62]	validation_0-rmse:0.35635	validation_1-rmse:0.49920
# [63]	validation_0-rmse:0.35309	validation_1-rmse:0.49570
# [64]	validation_0-rmse:0.34977	validation_1-rmse:0.49236
# [65]	validation_0-rmse:0.34657	validation_1-rmse:0.48916
# [66]	validation_0-rmse:0.34367	validation_1-rmse:0.48634
# [67]	validation_0-rmse:0.34066	validation_1-rmse:0.48334
# [68]	validation_0-rmse:0.33784	validation_1-rmse:0.48210
# [69]	validation_0-rmse:0.33514	validation_1-rmse:0.48079
# [70]	validation_0-rmse:0.33247	validation_1-rmse:0.47796
# [71]	validation_0-rmse:0.32990	validation_1-rmse:0.47523
# [72]	validation_0-rmse:0.32744	validation_1-rmse:0.47261
# [73]	validation_0-rmse:0.32488	validation_1-rmse:0.47090
# [74]	validation_0-rmse:0.32260	validation_1-rmse:0.46900
# [75]	validation_0-rmse:0.32030	validation_1-rmse:0.46711
# [76]	validation_0-rmse:0.31808	validation_1-rmse:0.46530
# [77]	validation_0-rmse:0.31579	validation_1-rmse:0.46300
# [78]	validation_0-rmse:0.31327	validation_1-rmse:0.46212
# [79]	validation_0-rmse:0.31117	validation_1-rmse:0.45957
# [80]	validation_0-rmse:0.30891	validation_1-rmse:0.45898
# [81]	validation_0-rmse:0.30663	validation_1-rmse:0.45822
# [82]	validation_0-rmse:0.30458	validation_1-rmse:0.45775
# [83]	validation_0-rmse:0.30273	validation_1-rmse:0.45673
# [84]	validation_0-rmse:0.30058	validation_1-rmse:0.45574
# [85]	validation_0-rmse:0.29859	validation_1-rmse:0.45507
# [86]	validation_0-rmse:0.29700	validation_1-rmse:0.45352
# [87]	validation_0-rmse:0.29535	validation_1-rmse:0.45223
# [88]	validation_0-rmse:0.29356	validation_1-rmse:0.45161
# [89]	validation_0-rmse:0.29212	validation_1-rmse:0.45023
# [90]	validation_0-rmse:0.29063	validation_1-rmse:0.44911
# [91]	validation_0-rmse:0.28903	validation_1-rmse:0.44753
# [92]	validation_0-rmse:0.28762	validation_1-rmse:0.44667
# [93]	validation_0-rmse:0.28615	validation_1-rmse:0.44511
# [94]	validation_0-rmse:0.28484	validation_1-rmse:0.44454
# [95]	validation_0-rmse:0.28329	validation_1-rmse:0.44416
# [96]	validation_0-rmse:0.28192	validation_1-rmse:0.44259
# [97]	validation_0-rmse:0.28053	validation_1-rmse:0.44232
# [98]	validation_0-rmse:0.27898	validation_1-rmse:0.44199
# [99]	validation_0-rmse:0.27784	validation_1-rmse:0.44135
# [100]	validation_0-rmse:0.27683	validation_1-rmse:0.44040
# [101]	validation_0-rmse:0.27571	validation_1-rmse:0.44126
# [102]	validation_0-rmse:0.27448	validation_1-rmse:0.44065
# [103]	validation_0-rmse:0.27335	validation_1-rmse:0.43937
# [104]	validation_0-rmse:0.27217	validation_1-rmse:0.43878
# [105]	validation_0-rmse:0.27107	validation_1-rmse:0.43763
# [106]	validation_0-rmse:0.26980	validation_1-rmse:0.43743
# [107]	validation_0-rmse:0.26863	validation_1-rmse:0.43742
# [108]	validation_0-rmse:0.26731	validation_1-rmse:0.43729
# [109]	validation_0-rmse:0.26615	validation_1-rmse:0.43683
# [110]	validation_0-rmse:0.26504	validation_1-rmse:0.43639
# [111]	validation_0-rmse:0.26378	validation_1-rmse:0.43709
# [112]	validation_0-rmse:0.26261	validation_1-rmse:0.43751
# [113]	validation_0-rmse:0.26158	validation_1-rmse:0.43732
# [114]	validation_0-rmse:0.26087	validation_1-rmse:0.43649
# [115]	validation_0-rmse:0.26010	validation_1-rmse:0.43617
# [116]	validation_0-rmse:0.25930	validation_1-rmse:0.43507
# [117]	validation_0-rmse:0.25837	validation_1-rmse:0.43472
# [118]	validation_0-rmse:0.25748	validation_1-rmse:0.43458
# [119]	validation_0-rmse:0.25654	validation_1-rmse:0.43377
# [120]	validation_0-rmse:0.25550	validation_1-rmse:0.43374
# [121]	validation_0-rmse:0.25480	validation_1-rmse:0.43257
# [122]	validation_0-rmse:0.25383	validation_1-rmse:0.43256
# [123]	validation_0-rmse:0.25287	validation_1-rmse:0.43256
# [124]	validation_0-rmse:0.25221	validation_1-rmse:0.43147
# [125]	validation_0-rmse:0.25144	validation_1-rmse:0.43120
# [126]	validation_0-rmse:0.25055	validation_1-rmse:0.43123
# [127]	validation_0-rmse:0.24988	validation_1-rmse:0.43017
# [128]	validation_0-rmse:0.24938	validation_1-rmse:0.42938
# [129]	validation_0-rmse:0.24854	validation_1-rmse:0.42942
# [130]	validation_0-rmse:0.24771	validation_1-rmse:0.42944
# [131]	validation_0-rmse:0.24724	validation_1-rmse:0.42869
# [132]	validation_0-rmse:0.24626	validation_1-rmse:0.42949
# [133]	validation_0-rmse:0.24553	validation_1-rmse:0.43045
# [134]	validation_0-rmse:0.24485	validation_1-rmse:0.43025
# [135]	validation_0-rmse:0.24408	validation_1-rmse:0.43031
# [136]	validation_0-rmse:0.24337	validation_1-rmse:0.43031
# [137]	validation_0-rmse:0.24286	validation_1-rmse:0.43007
# [138]	validation_0-rmse:0.24244	validation_1-rmse:0.42938
# [139]	validation_0-rmse:0.24219	validation_1-rmse:0.42870
# [140]	validation_0-rmse:0.24166	validation_1-rmse:0.42795
# [141]	validation_0-rmse:0.24095	validation_1-rmse:0.42804
# [142]	validation_0-rmse:0.24061	validation_1-rmse:0.42774
# [143]	validation_0-rmse:0.23999	validation_1-rmse:0.42771
# [144]	validation_0-rmse:0.23934	validation_1-rmse:0.42779
# [145]	validation_0-rmse:0.23900	validation_1-rmse:0.42719
# [146]	validation_0-rmse:0.23839	validation_1-rmse:0.42701
# [147]	validation_0-rmse:0.23769	validation_1-rmse:0.42741
# [0]	validation_0-rmse:0.99247	validation_1-rmse:0.77191
# [1]	validation_0-rmse:0.97172	validation_1-rmse:0.75931
# [2]	validation_0-rmse:0.95153	validation_1-rmse:0.74716
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:0.93167	validation_1-rmse:0.73578
# [4]	validation_0-rmse:0.91234	validation_1-rmse:0.72483
# [5]	validation_0-rmse:0.89371	validation_1-rmse:0.71446
# [6]	validation_0-rmse:0.87540	validation_1-rmse:0.70429
# [7]	validation_0-rmse:0.85759	validation_1-rmse:0.69451
# [8]	validation_0-rmse:0.84027	validation_1-rmse:0.68511
# [9]	validation_0-rmse:0.82341	validation_1-rmse:0.67734
# [10]	validation_0-rmse:0.80703	validation_1-rmse:0.66982
# [11]	validation_0-rmse:0.79112	validation_1-rmse:0.66149
# [12]	validation_0-rmse:0.77558	validation_1-rmse:0.65334
# [13]	validation_0-rmse:0.76049	validation_1-rmse:0.64654
# [14]	validation_0-rmse:0.74578	validation_1-rmse:0.63900
# [15]	validation_0-rmse:0.73144	validation_1-rmse:0.63160
# [16]	validation_0-rmse:0.71753	validation_1-rmse:0.62464
# [17]	validation_0-rmse:0.70388	validation_1-rmse:0.61874
# [18]	validation_0-rmse:0.69084	validation_1-rmse:0.61173
# [19]	validation_0-rmse:0.67807	validation_1-rmse:0.60495
# [20]	validation_0-rmse:0.66564	validation_1-rmse:0.59742
# [21]	validation_0-rmse:0.65349	validation_1-rmse:0.59148
# [22]	validation_0-rmse:0.64166	validation_1-rmse:0.58454
# [23]	validation_0-rmse:0.63014	validation_1-rmse:0.57923
# [24]	validation_0-rmse:0.61891	validation_1-rmse:0.57259
# [25]	validation_0-rmse:0.60798	validation_1-rmse:0.56737
# [26]	validation_0-rmse:0.59733	validation_1-rmse:0.56130
# [27]	validation_0-rmse:0.58694	validation_1-rmse:0.55654
# [28]	validation_0-rmse:0.57732	validation_1-rmse:0.55054
# [29]	validation_0-rmse:0.56750	validation_1-rmse:0.54581
# [30]	validation_0-rmse:0.55800	validation_1-rmse:0.54179
# [31]	validation_0-rmse:0.54859	validation_1-rmse:0.53668
# [32]	validation_0-rmse:0.53949	validation_1-rmse:0.53231
# [33]	validation_0-rmse:0.53077	validation_1-rmse:0.52889
# [34]	validation_0-rmse:0.52213	validation_1-rmse:0.52310
# [35]	validation_0-rmse:0.51368	validation_1-rmse:0.51878
# [36]	validation_0-rmse:0.50547	validation_1-rmse:0.51470
# [37]	validation_0-rmse:0.49752	validation_1-rmse:0.50953
# [38]	validation_0-rmse:0.48977	validation_1-rmse:0.50587
# [39]	validation_0-rmse:0.48224	validation_1-rmse:0.50242
# [40]	validation_0-rmse:0.47485	validation_1-rmse:0.49776
# [41]	validation_0-rmse:0.46778	validation_1-rmse:0.49374
# [42]	validation_0-rmse:0.46088	validation_1-rmse:0.49080
# [43]	validation_0-rmse:0.45417	validation_1-rmse:0.48728
# [44]	validation_0-rmse:0.44765	validation_1-rmse:0.48331
# [45]	validation_0-rmse:0.44135	validation_1-rmse:0.47961
# [46]	validation_0-rmse:0.43513	validation_1-rmse:0.47753
# [47]	validation_0-rmse:0.42920	validation_1-rmse:0.47555
# [48]	validation_0-rmse:0.42355	validation_1-rmse:0.47281
# [49]	validation_0-rmse:0.41791	validation_1-rmse:0.47070
# [50]	validation_0-rmse:0.41251	validation_1-rmse:0.46807
# [51]	validation_0-rmse:0.40731	validation_1-rmse:0.46635
# [52]	validation_0-rmse:0.40216	validation_1-rmse:0.46346
# [53]	validation_0-rmse:0.39727	validation_1-rmse:0.46107
# [54]	validation_0-rmse:0.39238	validation_1-rmse:0.45940
# [55]	validation_0-rmse:0.38767	validation_1-rmse:0.45766
# [56]	validation_0-rmse:0.38311	validation_1-rmse:0.45519
# [57]	validation_0-rmse:0.37867	validation_1-rmse:0.45384
# [58]	validation_0-rmse:0.37438	validation_1-rmse:0.45259
# [59]	validation_0-rmse:0.37024	validation_1-rmse:0.45145
# [60]	validation_0-rmse:0.36623	validation_1-rmse:0.44935
# [61]	validation_0-rmse:0.36232	validation_1-rmse:0.44734
# [62]	validation_0-rmse:0.35840	validation_1-rmse:0.44621
# [63]	validation_0-rmse:0.35474	validation_1-rmse:0.44451
# [64]	validation_0-rmse:0.35106	validation_1-rmse:0.44352
# [65]	validation_0-rmse:0.34763	validation_1-rmse:0.44174
# [66]	validation_0-rmse:0.34419	validation_1-rmse:0.44088
# [67]	validation_0-rmse:0.34087	validation_1-rmse:0.44011
# [68]	validation_0-rmse:0.33779	validation_1-rmse:0.43851
# [69]	validation_0-rmse:0.33461	validation_1-rmse:0.43604
# [70]	validation_0-rmse:0.33164	validation_1-rmse:0.43524
# [71]	validation_0-rmse:0.32873	validation_1-rmse:0.43486
# [72]	validation_0-rmse:0.32597	validation_1-rmse:0.43417
# [73]	validation_0-rmse:0.32331	validation_1-rmse:0.43332
# [74]	validation_0-rmse:0.32050	validation_1-rmse:0.43276
# [75]	validation_0-rmse:0.31787	validation_1-rmse:0.43255
# [76]	validation_0-rmse:0.31534	validation_1-rmse:0.43203
# [77]	validation_0-rmse:0.31309	validation_1-rmse:0.43194
# [78]	validation_0-rmse:0.31088	validation_1-rmse:0.43072
# [79]	validation_0-rmse:0.30869	validation_1-rmse:0.43025
# [80]	validation_0-rmse:0.30639	validation_1-rmse:0.42991
# [81]	validation_0-rmse:0.30437	validation_1-rmse:0.42868
# [82]	validation_0-rmse:0.30227	validation_1-rmse:0.42767
# [83]	validation_0-rmse:0.30032	validation_1-rmse:0.42651
# [84]	validation_0-rmse:0.29827	validation_1-rmse:0.42625
# [85]	validation_0-rmse:0.29651	validation_1-rmse:0.42628
# [86]	validation_0-rmse:0.29471	validation_1-rmse:0.42585
# [87]	validation_0-rmse:0.29286	validation_1-rmse:0.42568
# [88]	validation_0-rmse:0.29122	validation_1-rmse:0.42552
# [89]	validation_0-rmse:0.28950	validation_1-rmse:0.42540
# [90]	validation_0-rmse:0.28796	validation_1-rmse:0.42526
# [91]	validation_0-rmse:0.28642	validation_1-rmse:0.42497
# [92]	validation_0-rmse:0.28480	validation_1-rmse:0.42373
# [93]	validation_0-rmse:0.28353	validation_1-rmse:0.42308
# [94]	validation_0-rmse:0.28199	validation_1-rmse:0.42231
# [95]	validation_0-rmse:0.28072	validation_1-rmse:0.42140
# [96]	validation_0-rmse:0.27949	validation_1-rmse:0.42086
# [97]	validation_0-rmse:0.27827	validation_1-rmse:0.42079
# [98]	validation_0-rmse:0.27705	validation_1-rmse:0.42026
# [99]	validation_0-rmse:0.27576	validation_1-rmse:0.41964
# [100]	validation_0-rmse:0.27459	validation_1-rmse:0.41952
# [101]	validation_0-rmse:0.27355	validation_1-rmse:0.42025
# [102]	validation_0-rmse:0.27237	validation_1-rmse:0.42001
# [103]	validation_0-rmse:0.27131	validation_1-rmse:0.41992
# [104]	validation_0-rmse:0.27026	validation_1-rmse:0.41995
# [105]	validation_0-rmse:0.26940	validation_1-rmse:0.41933
# [106]	validation_0-rmse:0.26835	validation_1-rmse:0.41912
# [107]	validation_0-rmse:0.26747	validation_1-rmse:0.41847
# [108]	validation_0-rmse:0.26667	validation_1-rmse:0.41852
# [109]	validation_0-rmse:0.26583	validation_1-rmse:0.41922
# [110]	validation_0-rmse:0.26502	validation_1-rmse:0.41931
# [111]	validation_0-rmse:0.26424	validation_1-rmse:0.41867
# [112]	validation_0-rmse:0.26341	validation_1-rmse:0.41894
# [113]	validation_0-rmse:0.26210	validation_1-rmse:0.41850
# [114]	validation_0-rmse:0.26125	validation_1-rmse:0.41804
# ...
# [30]	validation_0-rmse:0.56859	validation_1-rmse:0.42519
# [31]	validation_0-rmse:0.55955	validation_1-rmse:0.42131
# [32]	validation_0-rmse:0.55077	validation_1-rmse:0.41479
# [33]	validation_0-rmse:0.54226	validation_1-rmse:0.40861
# [34]	validation_0-rmse:0.53392	validation_1-rmse:0.40483
# [35]	validation_0-rmse:0.52587	validation_1-rmse:0.40165
# [36]	validation_0-rmse:0.51801	validation_1-rmse:0.39780
# [37]	validation_0-rmse:0.51038	validation_1-rmse:0.39428
# [38]	validation_0-rmse:0.50297	validation_1-rmse:0.39143
# [39]	validation_0-rmse:0.49560	validation_1-rmse:0.38746
# [40]	validation_0-rmse:0.48842	validation_1-rmse:0.38408
# [41]	validation_0-rmse:0.48161	validation_1-rmse:0.38144
# [42]	validation_0-rmse:0.47486	validation_1-rmse:0.37790
# [43]	validation_0-rmse:0.46860	validation_1-rmse:0.37460
# [44]	validation_0-rmse:0.46235	validation_1-rmse:0.37195
# [45]	validation_0-rmse:0.45612	validation_1-rmse:0.36847
# [46]	validation_0-rmse:0.45012	validation_1-rmse:0.36587
# [47]	validation_0-rmse:0.44439	validation_1-rmse:0.36273
# [48]	validation_0-rmse:0.43885	validation_1-rmse:0.35936
# [49]	validation_0-rmse:0.43335	validation_1-rmse:0.35717
# [50]	validation_0-rmse:0.42815	validation_1-rmse:0.35456
# [51]	validation_0-rmse:0.42313	validation_1-rmse:0.35173
# [52]	validation_0-rmse:0.41814	validation_1-rmse:0.34992
# [53]	validation_0-rmse:0.41343	validation_1-rmse:0.34740
# [54]	validation_0-rmse:0.40872	validation_1-rmse:0.34625
# [55]	validation_0-rmse:0.40421	validation_1-rmse:0.34441
# [56]	validation_0-rmse:0.39986	validation_1-rmse:0.34311
# [57]	validation_0-rmse:0.39569	validation_1-rmse:0.34214
# [58]	validation_0-rmse:0.39154	validation_1-rmse:0.34092
# [59]	validation_0-rmse:0.38772	validation_1-rmse:0.34009
# [60]	validation_0-rmse:0.38388	validation_1-rmse:0.33859
# [61]	validation_0-rmse:0.38009	validation_1-rmse:0.33786
# [62]	validation_0-rmse:0.37644	validation_1-rmse:0.33732
# [63]	validation_0-rmse:0.37279	validation_1-rmse:0.33620
# [64]	validation_0-rmse:0.36936	validation_1-rmse:0.33529
# [65]	validation_0-rmse:0.36588	validation_1-rmse:0.33451
# [66]	validation_0-rmse:0.36271	validation_1-rmse:0.33366
# [67]	validation_0-rmse:0.35948	validation_1-rmse:0.33298
# [68]	validation_0-rmse:0.35649	validation_1-rmse:0.33196
# [69]	validation_0-rmse:0.35314	validation_1-rmse:0.32985
# [70]	validation_0-rmse:0.35028	validation_1-rmse:0.32955
# [71]	validation_0-rmse:0.34753	validation_1-rmse:0.32972
# [72]	validation_0-rmse:0.34487	validation_1-rmse:0.32952
# [73]	validation_0-rmse:0.34216	validation_1-rmse:0.32883
# [74]	validation_0-rmse:0.33941	validation_1-rmse:0.32723
# [75]	validation_0-rmse:0.33698	validation_1-rmse:0.32740
# [76]	validation_0-rmse:0.33450	validation_1-rmse:0.32666
# [77]	validation_0-rmse:0.33196	validation_1-rmse:0.32519
# [78]	validation_0-rmse:0.32918	validation_1-rmse:0.32309
# [79]	validation_0-rmse:0.32704	validation_1-rmse:0.32339
# [80]	validation_0-rmse:0.32480	validation_1-rmse:0.32295
# [81]	validation_0-rmse:0.32276	validation_1-rmse:0.32252
# [82]	validation_0-rmse:0.32053	validation_1-rmse:0.32132
# [83]	validation_0-rmse:0.31829	validation_1-rmse:0.31974
# [84]	validation_0-rmse:0.31613	validation_1-rmse:0.31817
# [85]	validation_0-rmse:0.31364	validation_1-rmse:0.31640
# [86]	validation_0-rmse:0.31187	validation_1-rmse:0.31614
# [87]	validation_0-rmse:0.31009	validation_1-rmse:0.31598
# [88]	validation_0-rmse:0.30846	validation_1-rmse:0.31584
# [89]	validation_0-rmse:0.30688	validation_1-rmse:0.31563
# [90]	validation_0-rmse:0.30522	validation_1-rmse:0.31529
# [91]	validation_0-rmse:0.30371	validation_1-rmse:0.31501
# [92]	validation_0-rmse:0.30165	validation_1-rmse:0.31348
# [93]	validation_0-rmse:0.30032	validation_1-rmse:0.31329
# [94]	validation_0-rmse:0.29808	validation_1-rmse:0.31193
# [95]	validation_0-rmse:0.29607	validation_1-rmse:0.31056
# [96]	validation_0-rmse:0.29461	validation_1-rmse:0.31050
# [97]	validation_0-rmse:0.29284	validation_1-rmse:0.30904
# [98]	validation_0-rmse:0.29083	validation_1-rmse:0.30790
# [99]	validation_0-rmse:0.28894	validation_1-rmse:0.30685
# [100]	validation_0-rmse:0.28780	validation_1-rmse:0.30678
# [101]	validation_0-rmse:0.28612	validation_1-rmse:0.30577
# [102]	validation_0-rmse:0.28461	validation_1-rmse:0.30475
# [103]	validation_0-rmse:0.28348	validation_1-rmse:0.30473
# [104]	validation_0-rmse:0.28181	validation_1-rmse:0.30411
# [105]	validation_0-rmse:0.28074	validation_1-rmse:0.30411
# [106]	validation_0-rmse:0.27939	validation_1-rmse:0.30322
# [107]	validation_0-rmse:0.27794	validation_1-rmse:0.30244
# [108]	validation_0-rmse:0.27692	validation_1-rmse:0.30309
# [109]	validation_0-rmse:0.27557	validation_1-rmse:0.30241
# [110]	validation_0-rmse:0.27426	validation_1-rmse:0.30167
# [111]	validation_0-rmse:0.27301	validation_1-rmse:0.30109
# [112]	validation_0-rmse:0.27211	validation_1-rmse:0.30115
# [113]	validation_0-rmse:0.27091	validation_1-rmse:0.30051
# [114]	validation_0-rmse:0.26997	validation_1-rmse:0.30051
# [115]	validation_0-rmse:0.26906	validation_1-rmse:0.30051
# [116]	validation_0-rmse:0.26799	validation_1-rmse:0.29985
# [117]	validation_0-rmse:0.26692	validation_1-rmse:0.29941
# [118]	validation_0-rmse:0.26611	validation_1-rmse:0.29941
# [119]	validation_0-rmse:0.26535	validation_1-rmse:0.29949
# [120]	validation_0-rmse:0.26456	validation_1-rmse:0.29950
# [121]	validation_0-rmse:0.26364	validation_1-rmse:0.29974
# [122]	validation_0-rmse:0.26287	validation_1-rmse:0.29975
# [123]	validation_0-rmse:0.26183	validation_1-rmse:0.29954
# [124]	validation_0-rmse:0.26113	validation_1-rmse:0.29956
# [125]	validation_0-rmse:0.26018	validation_1-rmse:0.29944
# [126]	validation_0-rmse:0.25948	validation_1-rmse:0.29946
# [127]	validation_0-rmse:0.25851	validation_1-rmse:0.29937
# [128]	validation_0-rmse:0.25790	validation_1-rmse:0.29946
# [129]	validation_0-rmse:0.25700	validation_1-rmse:0.29913
# [130]	validation_0-rmse:0.25649	validation_1-rmse:0.29915
# [131]	validation_0-rmse:0.25604	validation_1-rmse:0.29925
# [132]	validation_0-rmse:0.25556	validation_1-rmse:0.29928
# [133]	validation_0-rmse:0.25501	validation_1-rmse:0.29937
# [134]	validation_0-rmse:0.25442	validation_1-rmse:0.29940
# [135]	validation_0-rmse:0.25357	validation_1-rmse:0.29938
# [136]	validation_0-rmse:0.25275	validation_1-rmse:0.29925
# [137]	validation_0-rmse:0.25198	validation_1-rmse:0.29897
# [138]	validation_0-rmse:0.25158	validation_1-rmse:0.29909
# [139]	validation_0-rmse:0.25116	validation_1-rmse:0.29911
# [140]	validation_0-rmse:0.25075	validation_1-rmse:0.29915
# [141]	validation_0-rmse:0.25008	validation_1-rmse:0.30031
# [142]	validation_0-rmse:0.24970	validation_1-rmse:0.30008
# [143]	validation_0-rmse:0.24909	validation_1-rmse:0.30038
# [144]	validation_0-rmse:0.24870	validation_1-rmse:0.30041
# [145]	validation_0-rmse:0.24835	validation_1-rmse:0.30019
# [146]	validation_0-rmse:0.24798	validation_1-rmse:0.30022
# [147]	validation_0-rmse:0.24746	validation_1-rmse:0.30026
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:0.94423	validation_1-rmse:0.97897
# [1]	validation_0-rmse:0.92483	validation_1-rmse:0.95887
# [2]	validation_0-rmse:0.90546	validation_1-rmse:0.93885
# [3]	validation_0-rmse:0.88672	validation_1-rmse:0.92536
# [4]	validation_0-rmse:0.86848	validation_1-rmse:0.91094
# [5]	validation_0-rmse:0.85105	validation_1-rmse:0.89824
# [6]	validation_0-rmse:0.83375	validation_1-rmse:0.88504
# [7]	validation_0-rmse:0.81674	validation_1-rmse:0.87957
# [8]	validation_0-rmse:0.80033	validation_1-rmse:0.86793
# [9]	validation_0-rmse:0.78438	validation_1-rmse:0.86003
# [10]	validation_0-rmse:0.76886	validation_1-rmse:0.85230
# [11]	validation_0-rmse:0.75394	validation_1-rmse:0.84805
# [12]	validation_0-rmse:0.73935	validation_1-rmse:0.83774
# [13]	validation_0-rmse:0.72516	validation_1-rmse:0.83090
# [14]	validation_0-rmse:0.71107	validation_1-rmse:0.82119
# [15]	validation_0-rmse:0.69734	validation_1-rmse:0.81681
# [16]	validation_0-rmse:0.68403	validation_1-rmse:0.81277
# [17]	validation_0-rmse:0.67122	validation_1-rmse:0.80682
# [18]	validation_0-rmse:0.65893	validation_1-rmse:0.80343
# [19]	validation_0-rmse:0.64707	validation_1-rmse:0.79151
# [20]	validation_0-rmse:0.63555	validation_1-rmse:0.78322
# [21]	validation_0-rmse:0.62398	validation_1-rmse:0.77972
# [22]	validation_0-rmse:0.61276	validation_1-rmse:0.77635
# [23]	validation_0-rmse:0.60180	validation_1-rmse:0.77236
# [24]	validation_0-rmse:0.59136	validation_1-rmse:0.76840
# [25]	validation_0-rmse:0.58110	validation_1-rmse:0.75995
# [26]	validation_0-rmse:0.57105	validation_1-rmse:0.75630
# [27]	validation_0-rmse:0.56150	validation_1-rmse:0.75277
# [28]	validation_0-rmse:0.55227	validation_1-rmse:0.74940
# [29]	validation_0-rmse:0.54313	validation_1-rmse:0.74261
# [30]	validation_0-rmse:0.53467	validation_1-rmse:0.73609
# [31]	validation_0-rmse:0.52611	validation_1-rmse:0.73317
# [32]	validation_0-rmse:0.51775	validation_1-rmse:0.72698
# [33]	validation_0-rmse:0.50966	validation_1-rmse:0.72101
# [34]	validation_0-rmse:0.50161	validation_1-rmse:0.71741
# [35]	validation_0-rmse:0.49390	validation_1-rmse:0.71105
# [36]	validation_0-rmse:0.48641	validation_1-rmse:0.70765
# [37]	validation_0-rmse:0.47917	validation_1-rmse:0.70434
# [38]	validation_0-rmse:0.47228	validation_1-rmse:0.69885
# [39]	validation_0-rmse:0.46564	validation_1-rmse:0.69655
# [40]	validation_0-rmse:0.45901	validation_1-rmse:0.69112
# [41]	validation_0-rmse:0.45271	validation_1-rmse:0.68843
# [42]	validation_0-rmse:0.44663	validation_1-rmse:0.68350
# [43]	validation_0-rmse:0.44036	validation_1-rmse:0.67781
# [44]	validation_0-rmse:0.43427	validation_1-rmse:0.67228
# [45]	validation_0-rmse:0.42866	validation_1-rmse:0.66702
# [46]	validation_0-rmse:0.42302	validation_1-rmse:0.66196
# [47]	validation_0-rmse:0.41765	validation_1-rmse:0.65786
# [48]	validation_0-rmse:0.41246	validation_1-rmse:0.65325
# [49]	validation_0-rmse:0.40737	validation_1-rmse:0.64983
# [50]	validation_0-rmse:0.40250	validation_1-rmse:0.64610
# [51]	validation_0-rmse:0.39779	validation_1-rmse:0.64248
# [52]	validation_0-rmse:0.39310	validation_1-rmse:0.63930
# [53]	validation_0-rmse:0.38869	validation_1-rmse:0.63752
# [54]	validation_0-rmse:0.38432	validation_1-rmse:0.63336
# [55]	validation_0-rmse:0.38006	validation_1-rmse:0.63043
# [56]	validation_0-rmse:0.37578	validation_1-rmse:0.62634
# [57]	validation_0-rmse:0.37176	validation_1-rmse:0.62437
# [58]	validation_0-rmse:0.36791	validation_1-rmse:0.62156
# [59]	validation_0-rmse:0.36467	validation_1-rmse:0.61979
# [60]	validation_0-rmse:0.36086	validation_1-rmse:0.61545
# [61]	validation_0-rmse:0.35733	validation_1-rmse:0.61344
# [62]	validation_0-rmse:0.35376	validation_1-rmse:0.61214
# [63]	validation_0-rmse:0.35032	validation_1-rmse:0.61059
# [64]	validation_0-rmse:0.34710	validation_1-rmse:0.60815
# [65]	validation_0-rmse:0.34372	validation_1-rmse:0.60469
# [66]	validation_0-rmse:0.34059	validation_1-rmse:0.60360
# [67]	validation_0-rmse:0.33756	validation_1-rmse:0.60256
# [68]	validation_0-rmse:0.33482	validation_1-rmse:0.60091
# [69]	validation_0-rmse:0.33218	validation_1-rmse:0.59814
# [70]	validation_0-rmse:0.32950	validation_1-rmse:0.59611
# [71]	validation_0-rmse:0.32692	validation_1-rmse:0.59417
# [72]	validation_0-rmse:0.32443	validation_1-rmse:0.59225
# [73]	validation_0-rmse:0.32203	validation_1-rmse:0.59040
# [74]	validation_0-rmse:0.31968	validation_1-rmse:0.58844
# [75]	validation_0-rmse:0.31739	validation_1-rmse:0.58786
# [76]	validation_0-rmse:0.31522	validation_1-rmse:0.58614
# [77]	validation_0-rmse:0.31301	validation_1-rmse:0.58503
# [78]	validation_0-rmse:0.31105	validation_1-rmse:0.58375
# [79]	validation_0-rmse:0.30907	validation_1-rmse:0.58213
# [80]	validation_0-rmse:0.30707	validation_1-rmse:0.58035
# [81]	validation_0-rmse:0.30507	validation_1-rmse:0.57797
# [82]	validation_0-rmse:0.30318	validation_1-rmse:0.57563
# [83]	validation_0-rmse:0.30117	validation_1-rmse:0.57322
# [84]	validation_0-rmse:0.29927	validation_1-rmse:0.57086
# [85]	validation_0-rmse:0.29754	validation_1-rmse:0.56880
# [86]	validation_0-rmse:0.29594	validation_1-rmse:0.56732
# [87]	validation_0-rmse:0.29427	validation_1-rmse:0.56682
# [88]	validation_0-rmse:0.29278	validation_1-rmse:0.56594
# [89]	validation_0-rmse:0.29135	validation_1-rmse:0.56456
# [90]	validation_0-rmse:0.28996	validation_1-rmse:0.56328
# [91]	validation_0-rmse:0.28858	validation_1-rmse:0.56160
# [92]	validation_0-rmse:0.28723	validation_1-rmse:0.56117
# [93]	validation_0-rmse:0.28587	validation_1-rmse:0.55929
# [94]	validation_0-rmse:0.28467	validation_1-rmse:0.55816
# [95]	validation_0-rmse:0.28361	validation_1-rmse:0.55776
# [96]	validation_0-rmse:0.28248	validation_1-rmse:0.55647
# [97]	validation_0-rmse:0.28132	validation_1-rmse:0.55631
# [98]	validation_0-rmse:0.28015	validation_1-rmse:0.55755
# [99]	validation_0-rmse:0.27909	validation_1-rmse:0.55631
# [100]	validation_0-rmse:0.27787	validation_1-rmse:0.55579
# [101]	validation_0-rmse:0.27676	validation_1-rmse:0.55447
# [102]	validation_0-rmse:0.27578	validation_1-rmse:0.55378
# [103]	validation_0-rmse:0.27479	validation_1-rmse:0.55272
# [104]	validation_0-rmse:0.27368	validation_1-rmse:0.55108
# [105]	validation_0-rmse:0.27274	validation_1-rmse:0.55018
# [106]	validation_0-rmse:0.27180	validation_1-rmse:0.54955
# [107]	validation_0-rmse:0.27085	validation_1-rmse:0.54837
# [108]	validation_0-rmse:0.27001	validation_1-rmse:0.54735
# [109]	validation_0-rmse:0.26920	validation_1-rmse:0.54725
# [110]	validation_0-rmse:0.26826	validation_1-rmse:0.54576
# [111]	validation_0-rmse:0.26749	validation_1-rmse:0.54518
# [112]	validation_0-rmse:0.26667	validation_1-rmse:0.54449
# [113]	validation_0-rmse:0.26580	validation_1-rmse:0.54308
# [114]	validation_0-rmse:0.26502	validation_1-rmse:0.54288
# [115]	validation_0-rmse:0.26428	validation_1-rmse:0.54268
# [116]	validation_0-rmse:0.26356	validation_1-rmse:0.54213
# [117]	validation_0-rmse:0.26277	validation_1-rmse:0.54080
# [118]	validation_0-rmse:0.26194	validation_1-rmse:0.54126
# [119]	validation_0-rmse:0.26126	validation_1-rmse:0.54063
# [120]	validation_0-rmse:0.26060	validation_1-rmse:0.54046
# [121]	validation_0-rmse:0.25969	validation_1-rmse:0.53966
# [122]	validation_0-rmse:0.25906	validation_1-rmse:0.53833
# [123]	validation_0-rmse:0.25855	validation_1-rmse:0.53822
# [124]	validation_0-rmse:0.25771	validation_1-rmse:0.53708
# [125]	validation_0-rmse:0.25721	validation_1-rmse:0.53650
# [126]	validation_0-rmse:0.25657	validation_1-rmse:0.53572
# [127]	validation_0-rmse:0.25582	validation_1-rmse:0.53509
# [128]	validation_0-rmse:0.25535	validation_1-rmse:0.53454
# [129]	validation_0-rmse:0.25489	validation_1-rmse:0.53400
# [130]	validation_0-rmse:0.25444	validation_1-rmse:0.53391
# [131]	validation_0-rmse:0.25390	validation_1-rmse:0.53343
# [132]	validation_0-rmse:0.25347	validation_1-rmse:0.53334
# [133]	validation_0-rmse:0.25311	validation_1-rmse:0.53290
# [134]	validation_0-rmse:0.25269	validation_1-rmse:0.53281
# [135]	validation_0-rmse:0.25227	validation_1-rmse:0.53240
# [136]	validation_0-rmse:0.25193	validation_1-rmse:0.53198
# [137]	validation_0-rmse:0.25132	validation_1-rmse:0.53107
# [138]	validation_0-rmse:0.25093	validation_1-rmse:0.53087
# [139]	validation_0-rmse:0.25055	validation_1-rmse:0.53081
# [140]	validation_0-rmse:0.25008	validation_1-rmse:0.53075
# [141]	validation_0-rmse:0.24938	validation_1-rmse:0.53071
# [142]	validation_0-rmse:0.24898	validation_1-rmse:0.52946
# [143]	validation_0-rmse:0.24841	validation_1-rmse:0.52973
# [144]	validation_0-rmse:0.24805	validation_1-rmse:0.52969
# [145]	validation_0-rmse:0.24770	validation_1-rmse:0.52925
# [146]	validation_0-rmse:0.24737	validation_1-rmse:0.52921
# [147]	validation_0-rmse:0.24678	validation_1-rmse:0.52931
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-2.4, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.794
# Uncertainty
# a0: 0.012+/-0.032
# a1: 0.742+/-0.038

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: %_cover: mean - 0.19, median - 0.19, CI - [0.164-0.217]
#
# SHAP-values for: contr_g_MAX: mean - 0.074, median - 0.073, CI - [0.058-0.091]
#
# SHAP-values for: g_MAX: mean - 0.006, median - 0.004, CI - [0.001-0.009]
#
# SHAP-values for: mf_chm_MAX: mean - 0.194, median - 0.231, CI - [0.099-0.277]
#
# SHAP-values for: mf_chm_MEAN: mean - 0.173, median - 0.141, CI - [0.109-0.244]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['mf_chm_MAX', '%_cover', 'mf_chm_MEAN', 'contr_g_MAX', 'g_MAX'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 134.64, median: 145.0,
#  pred. interval (P(0.025)-P(0.975)): 69.975-147.0,
#  conf. interval (p-value=0.95): 120.328-146.806
# ***
# Aggregate bias statistic:
#  mean: 0.031, median: 0.033,
#  pred. interval (P(0.025)-P(0.975)): -0.12-0.165,
#  conf. interval (p-value=0.95): -0.029-0.102
# ***
# Aggregate RMSE statistic:
#  mean: 0.359, median: 0.352, pred. interval (P(0.025)-P(0.975)): 0.251-0.486,
#  conf. interval (p-value=0.95): 0.301-0.416
# ***
# Aggregate MSE statistic:
#  mean: 0.133, median: 0.124, pred. interval (P(0.025)-P(0.975)): 0.063-0.236,
#  conf. interval (p-value=0.95): 0.091-0.174
# ***
# Aggregate R^2 statistic:
#  mean: 0.768, median: 0.789, pred. interval (P(0.025)-P(0.975)): 0.555-0.907,
#  conf. interval (p-value=0.95): 0.698-0.848
# ***
# Aggregate bias(%) statistic:
#  mean: 21.41, median: -26.094, pred. interval (P(0.025)-P(0.975)): -462.804-514.128,
#  conf. interval (p-value=0.95): -85.767-47.203
# ***
# Aggregate RMSE(%) statistic:
#  mean: 220.688, median: -162.114, pred. interval (P(0.025)-P(0.975)): -2395.935-7113.506,
#  conf. interval (p-value=0.95): -414.229-497.846
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -0.063, median: -0.05,
#  pred. interval (P(0.025)-P(0.975)): -0.319-0.152,
#  conf. interval (p-value=0.95): -0.184-0.043
# ***
# Aggregate RMSE statistic:
#  mean: 0.504, median: 0.396, pred. interval (P(0.025)-P(0.975)): 0.269-0.967,
#  conf. interval (p-value=0.95): 0.329-0.86
# ***
# Aggregate MSE statistic:
#  mean: 0.313, median: 0.157, pred. interval (P(0.025)-P(0.975)): 0.072-0.936,
#  conf. interval (p-value=0.95): 0.109-0.763
# ***
# Aggregate R^2 statistic:
#  mean: 0.552, median: 0.578, pred. interval (P(0.025)-P(0.975)): 0.257-0.823,
#  conf. interval (p-value=0.95): 0.398-0.71
# ***
# Aggregate bias(%) statistic:
#  mean: -4.455, median: -4.449, pred. interval (P(0.025)-P(0.975)): -23.206-13.396,
#  conf. interval (p-value=0.95): -13.981-4.256
# ***
# Aggregate RMSE(%) statistic:
#  mean: 41.222, median: 34.943, pred. interval (P(0.025)-P(0.975)): 24.261-75.27,
#  conf. interval (p-value=0.95): 29.104-62.218
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-3, -2, -1, 0, 1, 2])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 0.5, 1, 2, 3, 4])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:0.95177
# [1]	validation_0-rmse:0.93239
# [2]	validation_0-rmse:0.91364
# [3]	validation_0-rmse:0.89542
# [4]	validation_0-rmse:0.87771
# [5]	validation_0-rmse:0.86036
# [6]	validation_0-rmse:0.84333
# [7]	validation_0-rmse:0.82688
# [8]	validation_0-rmse:0.81073
# [9]	validation_0-rmse:0.79514
# [10]	validation_0-rmse:0.77979
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:0.76486
# [12]	validation_0-rmse:0.75023
# [13]	validation_0-rmse:0.73611
# [14]	validation_0-rmse:0.72236
# [15]	validation_0-rmse:0.70908
# [16]	validation_0-rmse:0.69604
# [17]	validation_0-rmse:0.68338
# [18]	validation_0-rmse:0.67077
# [19]	validation_0-rmse:0.65876
# [20]	validation_0-rmse:0.64715
# [21]	validation_0-rmse:0.63583
# [22]	validation_0-rmse:0.62450
# [23]	validation_0-rmse:0.61383
# [24]	validation_0-rmse:0.60335
# [25]	validation_0-rmse:0.59317
# [26]	validation_0-rmse:0.58332
# [27]	validation_0-rmse:0.57364
# [28]	validation_0-rmse:0.56435
# [29]	validation_0-rmse:0.55537
# [30]	validation_0-rmse:0.54668
# [31]	validation_0-rmse:0.53807
# [32]	validation_0-rmse:0.52966
# [33]	validation_0-rmse:0.52155
# [34]	validation_0-rmse:0.51362
# [35]	validation_0-rmse:0.50606
# [36]	validation_0-rmse:0.49858
# [37]	validation_0-rmse:0.49137
# [38]	validation_0-rmse:0.48408
# [39]	validation_0-rmse:0.47727
# [40]	validation_0-rmse:0.47069
# [41]	validation_0-rmse:0.46423
# [42]	validation_0-rmse:0.45801
# [43]	validation_0-rmse:0.45176
# [44]	validation_0-rmse:0.44587
# [45]	validation_0-rmse:0.44032
# [46]	validation_0-rmse:0.43479
# [47]	validation_0-rmse:0.42949
# [48]	validation_0-rmse:0.42419
# [49]	validation_0-rmse:0.41915
# [50]	validation_0-rmse:0.41413
# [51]	validation_0-rmse:0.40939
# [52]	validation_0-rmse:0.40484
# [53]	validation_0-rmse:0.40025
# [54]	validation_0-rmse:0.39583
# [55]	validation_0-rmse:0.39159
# [56]	validation_0-rmse:0.38753
# [57]	validation_0-rmse:0.38360
# [58]	validation_0-rmse:0.37968
# [59]	validation_0-rmse:0.37599
# [60]	validation_0-rmse:0.37235
# [61]	validation_0-rmse:0.36889
# [62]	validation_0-rmse:0.36551
# [63]	validation_0-rmse:0.36214
# [64]	validation_0-rmse:0.35913
# [65]	validation_0-rmse:0.35609
# [66]	validation_0-rmse:0.35305
# [67]	validation_0-rmse:0.35014
# [68]	validation_0-rmse:0.34732
# [69]	validation_0-rmse:0.34461
# [70]	validation_0-rmse:0.34195
# [71]	validation_0-rmse:0.33942
# [72]	validation_0-rmse:0.33685
# [73]	validation_0-rmse:0.33405
# [74]	validation_0-rmse:0.33172
# [75]	validation_0-rmse:0.32949
# [76]	validation_0-rmse:0.32740
# [77]	validation_0-rmse:0.32514
# [78]	validation_0-rmse:0.32309
# [79]	validation_0-rmse:0.32073
# [80]	validation_0-rmse:0.31881
# [81]	validation_0-rmse:0.31683
# [82]	validation_0-rmse:0.31467
# [83]	validation_0-rmse:0.31293
# [84]	validation_0-rmse:0.31125
# [85]	validation_0-rmse:0.30905
# [86]	validation_0-rmse:0.30714
# [87]	validation_0-rmse:0.30548
# [88]	validation_0-rmse:0.30326
# [89]	validation_0-rmse:0.30162
# [90]	validation_0-rmse:0.30019
# [91]	validation_0-rmse:0.29869
# [92]	validation_0-rmse:0.29707
# [93]	validation_0-rmse:0.29569
# [94]	validation_0-rmse:0.29438
# [95]	validation_0-rmse:0.29299
# [96]	validation_0-rmse:0.29163
# [97]	validation_0-rmse:0.29047
# [98]	validation_0-rmse:0.28925
# [99]	validation_0-rmse:0.28808
# [100]	validation_0-rmse:0.28642
# [101]	validation_0-rmse:0.28532
# [102]	validation_0-rmse:0.28416
# [103]	validation_0-rmse:0.28292
# [104]	validation_0-rmse:0.28191
# [105]	validation_0-rmse:0.28037
# [106]	validation_0-rmse:0.27939
# [107]	validation_0-rmse:0.27810
# [108]	validation_0-rmse:0.27721
# [109]	validation_0-rmse:0.27616
# [110]	validation_0-rmse:0.27530
# [111]	validation_0-rmse:0.27444
# [112]	validation_0-rmse:0.27364
# [113]	validation_0-rmse:0.27233
# [114]	validation_0-rmse:0.27109
# [115]	validation_0-rmse:0.26987
# [116]	validation_0-rmse:0.26908
# [117]	validation_0-rmse:0.26830
# [118]	validation_0-rmse:0.26751
# [119]	validation_0-rmse:0.26667
# [120]	validation_0-rmse:0.26593
# [121]	validation_0-rmse:0.26482
# [122]	validation_0-rmse:0.26419
# [123]	validation_0-rmse:0.26343
# [124]	validation_0-rmse:0.26281
# [125]	validation_0-rmse:0.26219
# [126]	validation_0-rmse:0.26116
# [127]	validation_0-rmse:0.26050
# [128]	validation_0-rmse:0.25987
# [129]	validation_0-rmse:0.25924
# [130]	validation_0-rmse:0.25878
# [131]	validation_0-rmse:0.25829
# [132]	validation_0-rmse:0.25771
# [133]	validation_0-rmse:0.25713
# [134]	validation_0-rmse:0.25659
# [135]	validation_0-rmse:0.25595
# [136]	validation_0-rmse:0.25541
# [137]	validation_0-rmse:0.25490
# [138]	validation_0-rmse:0.25438
# [139]	validation_0-rmse:0.25401
# [140]	validation_0-rmse:0.25307
# [141]	validation_0-rmse:0.25222
# [142]	validation_0-rmse:0.25169
# [143]	validation_0-rmse:0.25134
# [144]	validation_0-rmse:0.25051
# [145]	validation_0-rmse:0.25002
# [146]	validation_0-rmse:0.24953
# [147]	validation_0-rmse:0.24907
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 147

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  -22.53
# RMSE: 0.2
# Relative RMSE(%):  -393.053
# MSE: 0.1
# R square: 90.1%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-2.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.907
# Uncertainty
# a0: 0.004+/-0.021
# a1: 0.834+/-0.027

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/03_LN_Mbranch_CHM_with_RGB_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/03_LN_Mbranch_CHM_with_RGB_XGB_model.txt")
