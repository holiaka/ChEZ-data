# %% [markdown]
# # *+Processing with CHM & RN & biomass data of other authors+*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25 idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167  0.050549
# 1           3600       8.189          15100  ...   0.040919  0.048889
# 2           4360       8.380          14600  ...   0.042397  0.050463
# 3           3420       8.137          12700  ...   0.043719  0.052974
# 4           2200       7.696          12100  ...   0.040659  0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX  idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966    0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602    0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265    0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465    0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420    0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 159 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
            


# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0       4.8122           1.7630               -0.3147           -0.1590
# 1       5.7589           2.4570               -0.2485            0.3429
# 2       5.8464           2.5153               -0.1054            0.5493
# 3       5.7526           2.6304               -0.0834            0.3900
# 4       5.9480           2.6748                0.0000            0.5715
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  \
# 0             -2.4418         1.9125     0.85    12.233545   19.097736    243
# 1             -0.1997         2.6319     1.00    14.964220   17.704655    248
# 2             -0.2144         2.7020     1.00    15.329449   17.559893    240
# 3             -0.3510         2.7763     0.97    15.392742   20.676994    244
# 4             -0.3711         2.8314     1.00    17.944009   21.851387    243
#
#    contr_g_MAX
# 0  2961.898193
# 1  2218.239746
# 2  2220.297119
# 3  3033.770752
# 4  3003.818848

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
#  9   g_MAX                 103 non-null    int64
#  10  contr_g_MAX           103 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 9.0 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["Gs_cub_m", "M_stem_kg_m2"].describe()
# Out:
# /tmp/ipykernel_16410/594647310.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_specias"])["Gs_cub_m", "M_stem_kg_m2"].describe()
#                  Gs_cub_m                                               \
#                     count        mean         std    min    25%    50%
# Dominant_specias
# Alder                 4.0  380.250000  155.784841  199.0  283.0  386.5
# Aspen                 1.0  148.000000         NaN  148.0  148.0  148.0
# Birch                23.0  135.304348   73.156392   11.0   94.0  138.0
# Oak                   3.0  236.000000   77.504839  158.0  197.5  237.0
# Pine                 71.0  263.281690  185.083625    2.0   97.0  281.0
# Spruce                1.0  619.000000         NaN  619.0  619.0  619.0
#
#                                 M_stem_kg_m2                              \
#                      75%    max        count       mean       std    min
# Dominant_specias
# Alder             483.75  549.0          4.0  16.170000  5.186990   9.90
# Aspen             148.00  148.0          1.0   6.650000       NaN   6.65
# Birch             197.00  280.0         23.0   6.809130  3.677786   0.84
# Oak               275.00  313.0          3.0  13.513333  4.888725   9.59
# Pine              394.00  671.0         71.0  10.550000  7.252887   0.05
# Spruce            619.00  619.0          1.0  23.830000       NaN  23.83
#
#
#                       25%    50%      75%    max
# Dominant_specias
# Alder             12.9225  17.03  20.2775  20.72
# Aspen              6.6500   6.65   6.6500   6.65
# Birch              4.7650   6.19   9.7400  15.47
# Oak               10.7750  11.96  15.4750  18.99
# Pine               3.4400  11.34  16.2250  25.04
# Spruce            23.8300  23.83  23.8300  23.83

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000         103.00000
# mean      4.969534         1.827923             -0.239481           0.05436
# std       1.323782         1.325853              0.893398           0.66008
# min       0.693100        -2.995700             -3.912000          -1.55590
# 25%       4.672800         1.588100             -0.335500          -0.20955
# 50%       5.337500         2.286500             -0.040800           0.24450
# 75%       5.908100         2.730800              0.190600           0.49195
# max       6.508800         3.220500              1.654400           1.41220
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX  \
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.021247       2.095454    0.808738    13.045021   17.907784
# std              0.803748       1.079203    0.276653     6.609366    7.523377
# min             -2.918800      -0.798500    0.090000     1.293138    2.733019
# 25%             -1.629700       1.801400    0.745000     8.206727   11.615798
# 50%             -0.719500       2.458700    0.960000    13.072916   18.269344
# 75%             -0.358800       2.862800    1.000000    17.432255   22.751595
# max              0.114200       3.366600    1.000000    28.916548   36.355442
#
#             g_MAX  contr_g_MAX
# count  103.000000   103.000000
# mean   240.572816  3008.938899
# std      9.358442   876.023529
# min    194.000000   815.342712
# 25%    236.500000  2464.687256
# 50%    243.000000  2994.793701
# 75%    247.000000  3464.970947
# max    253.000000  6230.940918

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
y = pd.DataFrame(select, columns= ['ln_Gs_cub_m'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  contr_g_MAX
# 0     0.85    12.233545   19.097736    243  2961.898193
# 1     1.00    14.964220   17.704655    248  2218.239746
# 2     1.00    15.329449   17.559893    240  2220.297119
# 3     0.97    15.392742   20.676994    244  3033.770752
# 4     1.00    17.944009   21.851387    243  3003.818848

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Gs_cub_m
# 0       4.8122
# 1       5.7589
# 2       5.8464
# 3       5.7526
# 4       5.9480

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.910077131611629, 0.8782296097918755, 0.8934989635759565]
#     Mean: 0.894
#     Std: 0.013
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.48678304 0.46078268 0.42069306]
#     Mean: 0.456
#     Std: 0.027
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.28592639088766914, 0.24632756477804746, 0.3216832837497487]
#     Mean: 0.285
#     Std: 0.031
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.893 (std: 0.040)
# Parameters: {'colsample_bytree': 0.9130074454039081, 'gamma': 0.24554592996534758, 'learning_rate': 0.27944380367938704, 'max_depth': 2, 'n_estimators': 148, 'subsample': 0.7641657082879392}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.6418745 , 0.64918895, 0.17964611, ..., 0.38862028, 0.57427773,
#        0.21545372]), 'std_fit_time': array([0.32549314, 0.13459008, 0.02572048, ..., 0.01125855, 0.01548936,
#        0.00691329]), 'mean_score_time': array([0.00607977, 0.00647836, 0.00793862, ..., 0.00718064, 0.00886736,
#        0.00898099]), 'std_score_time': array([0.00015452, 0.00086791, 0.00337454, ..., 0.00010248, 0.00340269,
#        0.00363287]), 'param_colsample_bytree': masked_array(data=[0.5425934003081949, 0.5178233079505863,
#                    0.709999414194865, ..., 0.8576536204297566,
#                    0.22836396423068084, 0.7184250800696336],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.22607941100895518, 0.28313515320875327,
#                    0.47034753128155493, ..., 0.09051430922425319,
#                    0.39790035472205904, 0.3556202369405121],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.05365434197634083, 0.17810251370775348,
#                    0.28824806806313397, ..., 0.055985103182777024,
#                    0.18835367953878102, 0.15215437162585718],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[4, 3, 2, ..., 2, 2, 4],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[182, 176, 64, ..., 132, 195, 66],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.9549377328803086, 0.856643599260529,
#                    0.9301407000069102, ..., 0.9393507055911878,
#                    0.4776253028819596, 0.45005413700134855],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.5425934003081949, 'gamma': 0.22607941100895518, 'learning_rate': 0.05365434197634083, 'max_depth': 4, 'n_estimators': 182, 'subsample': 0.9549377328803086}, {'colsample_bytree': 0.5178233079505863, 'gamma': 0.28313515320875327, 'learning_rate': 0.17810251370775348, 'max_depth': 3, 'n_estimators': 176, 'subsample': 0.856643599260529}, {'colsample_bytree': 0.709999414194865, 'gamma': 0.47034753128155493, 'learning_rate': 0.28824806806313397, 'max_depth': 2, 'n_estimators': 64, 'subsample': 0.9301407000069102}, {'colsample_bytree': 0.49834493468976354, 'gamma': 0.3819192919846084, 'learning_rate': 0.029215980937149492, 'max_depth': 4, 'n_estimators': 180, 'subsample': 0.3777337600736664}, {'colsample_bytree': 0.20841370559226596, 'gamma': 0.31167735717542017, 'learning_rate': 0.1863542049546432, 'max_depth': 4, 'n_estimators': 156, 'subsample': 0.7316049711835858}, {'colsample_bytree': 0.41152007004826646, 'gamma': 0.3382163696273609, 'learning_rate': 0.07183050696508146, 'max_depth': 2, 'n_estimators': 168, 'subsample': 0.5757161457468931}, {'colsample_bytree': 0.339590319196818, 'gamma': 0.4577242297578857, 'learning_rate': 0.06770777895089533, 'max_depth': 3, 'n_estimators': 180, 'subsample': 0.62132558036736}, {'colsample_bytree': 0.501521062008377, 'gamma': 0.11310848215170588, 'learning_rate': 0.037901749455160526, 'max_depth': 2, 'n_estimators': 198, 'subsample': 0.9547305961167674}, {'colsample_bytree': 0.25729055277325036, 'gamma': 0.0046156627968411135, 'learning_rate': 0.1760086775157165, 'max_depth': 2, 'n_estimators': 136, 'subsample': 0.6025783953365988}, {'colsample_bytree': 0.6993689307675973, 'gamma': 0.41038502714661196, 'learning_rate': 0.2419156409767662, 'max_depth': 4, 'n_estimators': 127, 'subsample': 0.9719265528115566}, {'colsample_bytree': 0.8671654320235677, 'gamma': 0.2559745942163166, 'learning_rate': 0.14839088389316293, 'max_depth': 2, 'n_estimators': 71, 'subsample': 0.5463003145304669}, {'colsample_bytree': 0.1892345601668689, 'gamma': 0.23712360028711765, 'learning_rate': 0.1888600244724193, 'max_depth': 4, 'n_estimators': 182, 'subsample': 0.3371551302652832}, {'colsample_bytree': 0.2872124757914705, 'gamma': 0.18840484627129606, 'learning_rate': 0.12233460555849732, 'max_depth': 4, 'n_estimators': 71, 'subsample': 0.7268819926916179}, {'colsample_bytree': 0.45719713380703253, 'gamma': 0.4980878073573027, 'learning_rate': 0.23204070540130034, 'max_depth': 3, 'n_estimators': 134, 'subsample': 0.5353640569457612}, {'colsample_bytree': 0.6998500565048398, 'gamma': 0.2126836619399004, 'learning_rate': 0.22012286300713024, 'max_depth': 3, 'n_estimators': 102, 'subsample': 0.3860379085580963}, {'colsample_bytree': 0.17978460009416958, 'gamma': 0.3346571031445997, 'learning_rate': 0.2540863218057389, 'max_depth': 2, 'n_estimators': 76, 'subsample': 0.9080013090959744}, {'colsample_bytree': 0.7621616568998613, 'gamma': 0.07940238878682854, 'learning_rate': 0.08855399251317753, 'max_depth': 3, 'n_estimators': 73, 'subsample': 0.5653792023660039}, {'colsample_bytree': 0.37072280003261526, 'gamma': 0.10749810343959548, 'learning_rate': 0.0599279396151888, 'max_depth': 2, 'n_estimators': 74, 'subsample': 0.39481636545412796}, {'colsample_bytree': 0.7619243938801558, 'gamma': 0.23009142107901182, 'learning_rate': 0.19732506907207784, 'max_depth': 4, 'n_estimators': 147, 'subsample': 0.9325419366045917}, {'colsample_bytree': 0.48605417873121387, 'gamma': 0.29615926949973154, 'learning_rate': 0.14389383090042587, 'max_depth': 3, 'n_estimators': 101, 'subsample': 0.7592927544203523}, {'colsample_bytree': 0.14836488591553415, 'gamma': 0.3417511107969023, 'learning_rate': 0.156265647517719, 'max_depth': 3, 'n_estimators': 187, 'subsample': 0.3596964364100486}, {'colsample_bytree': 0.6758828243230574, 'gamma': 0.2608203491597638, 'learning_rate': 0.17545351561693553, 'max_depth': 3, 'n_estimators': 172, 'subsample': 0.38706978480575926}, {'colsample_bytr ...
#        0.89916944]), 'split1_test_score': array([0.88226594, 0.86948452, 0.88931966, ..., 0.88617538, 0.88353679,
#        0.89214785]), 'split2_test_score': array([0.91293374, 0.91045227, 0.89544401, ..., 0.93285768, 0.94558522,
#        0.90707218]), 'split3_test_score': array([0.87802523, 0.87888449, 0.92446126, ..., 0.8867836 , 0.87192549,
#        0.92110407]), 'split4_test_score': array([0.78472671, 0.7528276 , 0.68406736, ..., 0.76053885, 0.82916389,
#        0.66096317]), 'mean_test_score': array([0.87040345, 0.86009417, 0.85411148, ..., 0.86914533, 0.87814306,
#        0.85609134]), 'std_test_score': array([0.04451525, 0.0553328 , 0.08642706, ..., 0.05755055, 0.0382787 ,
#        0.09803724]), 'rank_test_score': array([ 427, 1158, 1590, ...,  514,  108, 1460], dtype=int32), 'split0_train_score': array([0.97887956, 0.97724879, 0.9611514 , ..., 0.9820383 , 0.96594605,
#        0.9683042 ]), 'split1_train_score': array([0.97539626, 0.97249856, 0.95758749, ..., 0.97824006, 0.96378068,
#        0.96035843]), 'split2_train_score': array([0.97644191, 0.97641048, 0.95470383, ..., 0.9791493 , 0.96297882,
#        0.9656256 ]), 'split3_train_score': array([0.97958268, 0.97750831, 0.96627829, ..., 0.9816982 , 0.96500119,
#        0.96807724]), 'split4_train_score': array([0.98197192, 0.97977178, 0.97038337, ..., 0.98689028, 0.96429861,
#        0.97088546]), 'mean_train_score': array([0.97845447, 0.97668758, 0.96202088, ..., 0.98160323, 0.96440107,
#        0.96665018]), 'std_train_score': array([0.00233363, 0.00237173, 0.00569222, ..., 0.00301609, 0.00101639,
#        0.00355938])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.9130074454039081
# Gamma: 0.24554592996534758
# Learning_rate: 0.27944380367938704
# Max_depth: 2
# N_estimators: 148
# Subsample: 0.7641657082879392

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:3.41659	validation_1-rmse:3.32305
# [1]	validation_0-rmse:2.51933	validation_1-rmse:2.36182
# [2]	validation_0-rmse:1.86474	validation_1-rmse:1.69647
# [3]	validation_0-rmse:1.38073	validation_1-rmse:1.22792
# [4]	validation_0-rmse:1.03774	validation_1-rmse:0.90510
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:0.79793	validation_1-rmse:0.66483
# [6]	validation_0-rmse:0.61266	validation_1-rmse:0.52535
# [7]	validation_0-rmse:0.48874	validation_1-rmse:0.42462
# [8]	validation_0-rmse:0.39727	validation_1-rmse:0.38273
# [9]	validation_0-rmse:0.33218	validation_1-rmse:0.36289
# [10]	validation_0-rmse:0.29689	validation_1-rmse:0.35612
# [11]	validation_0-rmse:0.27395	validation_1-rmse:0.35109
# [12]	validation_0-rmse:0.25876	validation_1-rmse:0.35145
# [13]	validation_0-rmse:0.24853	validation_1-rmse:0.35099
# [14]	validation_0-rmse:0.24165	validation_1-rmse:0.35906
# [15]	validation_0-rmse:0.23468	validation_1-rmse:0.36188
# [16]	validation_0-rmse:0.22815	validation_1-rmse:0.35959
# [17]	validation_0-rmse:0.22350	validation_1-rmse:0.35291
# [18]	validation_0-rmse:0.22327	validation_1-rmse:0.35376
# [19]	validation_0-rmse:0.21362	validation_1-rmse:0.36136
# [20]	validation_0-rmse:0.21369	validation_1-rmse:0.36224
# [21]	validation_0-rmse:0.21372	validation_1-rmse:0.36248
# [22]	validation_0-rmse:0.21259	validation_1-rmse:0.37360
# [23]	validation_0-rmse:0.21252	validation_1-rmse:0.37420
# [24]	validation_0-rmse:0.21262	validation_1-rmse:0.37343
# [25]	validation_0-rmse:0.21266	validation_1-rmse:0.37329
# [26]	validation_0-rmse:0.21278	validation_1-rmse:0.37290
# [27]	validation_0-rmse:0.20642	validation_1-rmse:0.37263
# [28]	validation_0-rmse:0.20649	validation_1-rmse:0.37207
# [29]	validation_0-rmse:0.20104	validation_1-rmse:0.37007
# [30]	validation_0-rmse:0.20107	validation_1-rmse:0.37091
# [31]	validation_0-rmse:0.20104	validation_1-rmse:0.37052
# [32]	validation_0-rmse:0.20104	validation_1-rmse:0.37051
# [33]	validation_0-rmse:0.20104	validation_1-rmse:0.37052
# [0]	validation_0-rmse:3.44160	validation_1-rmse:3.29979
# [1]	validation_0-rmse:2.54337	validation_1-rmse:2.40224
# [2]	validation_0-rmse:1.87643	validation_1-rmse:1.72892
# [3]	validation_0-rmse:1.38298	validation_1-rmse:1.27523
# [4]	validation_0-rmse:1.03339	validation_1-rmse:0.94293
# [5]	validation_0-rmse:0.77437	validation_1-rmse:0.71964
# [6]	validation_0-rmse:0.58897	validation_1-rmse:0.58637
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [7]	validation_0-rmse:0.46443	validation_1-rmse:0.49112
# [8]	validation_0-rmse:0.37699	validation_1-rmse:0.43786
# [9]	validation_0-rmse:0.32927	validation_1-rmse:0.41277
# [10]	validation_0-rmse:0.29554	validation_1-rmse:0.41079
# [11]	validation_0-rmse:0.26685	validation_1-rmse:0.41776
# [12]	validation_0-rmse:0.25126	validation_1-rmse:0.42321
# [13]	validation_0-rmse:0.24255	validation_1-rmse:0.42218
# [14]	validation_0-rmse:0.23963	validation_1-rmse:0.42153
# [15]	validation_0-rmse:0.23851	validation_1-rmse:0.42150
# [16]	validation_0-rmse:0.23812	validation_1-rmse:0.42159
# [17]	validation_0-rmse:0.23779	validation_1-rmse:0.42185
# [18]	validation_0-rmse:0.23494	validation_1-rmse:0.41755
# [19]	validation_0-rmse:0.23496	validation_1-rmse:0.41769
# [20]	validation_0-rmse:0.23494	validation_1-rmse:0.41749
# [21]	validation_0-rmse:0.23495	validation_1-rmse:0.41742
# [22]	validation_0-rmse:0.22807	validation_1-rmse:0.41224
# [23]	validation_0-rmse:0.22802	validation_1-rmse:0.41210
# [24]	validation_0-rmse:0.22809	validation_1-rmse:0.41229
# [25]	validation_0-rmse:0.22807	validation_1-rmse:0.41224
# [26]	validation_0-rmse:0.21637	validation_1-rmse:0.40171
# [27]	validation_0-rmse:0.21608	validation_1-rmse:0.40134
# [28]	validation_0-rmse:0.21353	validation_1-rmse:0.41166
# [29]	validation_0-rmse:0.21355	validation_1-rmse:0.41135
# [30]	validation_0-rmse:0.21376	validation_1-rmse:0.41123
# [31]	validation_0-rmse:0.21354	validation_1-rmse:0.41136
# [32]	validation_0-rmse:0.21360	validation_1-rmse:0.41181
# [33]	validation_0-rmse:0.21362	validation_1-rmse:0.41184
# [34]	validation_0-rmse:0.21364	validation_1-rmse:0.41187
# [35]	validation_0-rmse:0.21357	validation_1-rmse:0.41175
# [36]	validation_0-rmse:0.21353	validation_1-rmse:0.41165
# [37]	validation_0-rmse:0.21352	validation_1-rmse:0.41160
# [38]	validation_0-rmse:0.21354	validation_1-rmse:0.41166
# [39]	validation_0-rmse:0.21353	validation_1-rmse:0.41139
# [40]	validation_0-rmse:0.21351	validation_1-rmse:0.41153
# [41]	validation_0-rmse:0.21353	validation_1-rmse:0.41166
# [42]	validation_0-rmse:0.21351	validation_1-rmse:0.41153
# [43]	validation_0-rmse:0.21361	validation_1-rmse:0.41182
# [44]	validation_0-rmse:0.20832	validation_1-rmse:0.41315
# [45]	validation_0-rmse:0.20644	validation_1-rmse:0.41283
# [46]	validation_0-rmse:0.20643	validation_1-rmse:0.41280
# [0]	validation_0-rmse:3.33329	validation_1-rmse:3.80663
# [1]	validation_0-rmse:2.45909	validation_1-rmse:2.89730
# [2]	validation_0-rmse:1.82546	validation_1-rmse:2.22232
# [3]	validation_0-rmse:1.37051	validation_1-rmse:1.71871
# [4]	validation_0-rmse:1.03969	validation_1-rmse:1.33411
# [5]	validation_0-rmse:0.80467	validation_1-rmse:1.07412
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:0.63208	validation_1-rmse:0.86436
# [7]	validation_0-rmse:0.50874	validation_1-rmse:0.70698
# [8]	validation_0-rmse:0.42826	validation_1-rmse:0.61789
# [9]	validation_0-rmse:0.37451	validation_1-rmse:0.53716
# [10]	validation_0-rmse:0.34373	validation_1-rmse:0.48209
# [11]	validation_0-rmse:0.32313	validation_1-rmse:0.46102
# [12]	validation_0-rmse:0.30362	validation_1-rmse:0.42321
# [13]	validation_0-rmse:0.29841	validation_1-rmse:0.40526
# [14]	validation_0-rmse:0.28789	validation_1-rmse:0.37956
# [15]	validation_0-rmse:0.27819	validation_1-rmse:0.37205
# [16]	validation_0-rmse:0.26928	validation_1-rmse:0.36090
# [17]	validation_0-rmse:0.26563	validation_1-rmse:0.35458
# [18]	validation_0-rmse:0.26057	validation_1-rmse:0.34229
# [19]	validation_0-rmse:0.26057	validation_1-rmse:0.34253
# [20]	validation_0-rmse:0.24576	validation_1-rmse:0.34431
# [21]	validation_0-rmse:0.24329	validation_1-rmse:0.34521
# [22]	validation_0-rmse:0.24090	validation_1-rmse:0.32765
# [23]	validation_0-rmse:0.23637	validation_1-rmse:0.33884
# [24]	validation_0-rmse:0.23644	validation_1-rmse:0.33945
# [25]	validation_0-rmse:0.23125	validation_1-rmse:0.33628
# [26]	validation_0-rmse:0.23100	validation_1-rmse:0.33335
# [27]	validation_0-rmse:0.23123	validation_1-rmse:0.33611
# [28]	validation_0-rmse:0.22363	validation_1-rmse:0.32788
# [29]	validation_0-rmse:0.22153	validation_1-rmse:0.33024
# [30]	validation_0-rmse:0.22168	validation_1-rmse:0.33237
# [31]	validation_0-rmse:0.22144	validation_1-rmse:0.32844
# [32]	validation_0-rmse:0.22138	validation_1-rmse:0.32298
# [33]	validation_0-rmse:0.22189	validation_1-rmse:0.31560
# [34]	validation_0-rmse:0.22165	validation_1-rmse:0.31791
# [35]	validation_0-rmse:0.22146	validation_1-rmse:0.32069
# [36]	validation_0-rmse:0.21793	validation_1-rmse:0.32384
# [37]	validation_0-rmse:0.21795	validation_1-rmse:0.32323
# [38]	validation_0-rmse:0.21488	validation_1-rmse:0.32386
# [39]	validation_0-rmse:0.21490	validation_1-rmse:0.32353
# [40]	validation_0-rmse:0.21482	validation_1-rmse:0.32542
# [41]	validation_0-rmse:0.21483	validation_1-rmse:0.32498
# [42]	validation_0-rmse:0.21478	validation_1-rmse:0.32729
# [43]	validation_0-rmse:0.21022	validation_1-rmse:0.32997
# [44]	validation_0-rmse:0.21029	validation_1-rmse:0.32881
# [45]	validation_0-rmse:0.21016	validation_1-rmse:0.33119
# [46]	validation_0-rmse:0.21014	validation_1-rmse:0.33169
# [47]	validation_0-rmse:0.21011	validation_1-rmse:0.33595
# [48]	validation_0-rmse:0.21020	validation_1-rmse:0.33873
# [49]	validation_0-rmse:0.21031	validation_1-rmse:0.34054
# [50]	validation_0-rmse:0.21009	validation_1-rmse:0.33442
# [51]	validation_0-rmse:0.21010	validation_1-rmse:0.33370
# [52]	validation_0-rmse:0.21009	validation_1-rmse:0.33398
# [53]	validation_0-rmse:0.21029	validation_1-rmse:0.32877
# [0]	validation_0-rmse:3.41719	validation_1-rmse:3.51120
# [1]	validation_0-rmse:2.52874	validation_1-rmse:2.66402
# [2]	validation_0-rmse:1.87464	validation_1-rmse:2.00356
# [3]	validation_0-rmse:1.39243	validation_1-rmse:1.52377
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.04107	validation_1-rmse:1.18988
# [5]	validation_0-rmse:0.78318	validation_1-rmse:0.94856
# [6]	validation_0-rmse:0.60671	validation_1-rmse:0.80993
# [7]	validation_0-rmse:0.47667	validation_1-rmse:0.72188
# [8]	validation_0-rmse:0.39327	validation_1-rmse:0.68522
# [9]	validation_0-rmse:0.33311	validation_1-rmse:0.65161
# [10]	validation_0-rmse:0.29358	validation_1-rmse:0.63285
# [11]	validation_0-rmse:0.26664	validation_1-rmse:0.62140
# [12]	validation_0-rmse:0.24976	validation_1-rmse:0.61355
# [13]	validation_0-rmse:0.23497	validation_1-rmse:0.60949
# [14]	validation_0-rmse:0.22903	validation_1-rmse:0.60622
# [15]	validation_0-rmse:0.22297	validation_1-rmse:0.60931
# [16]	validation_0-rmse:0.21988	validation_1-rmse:0.61194
# [17]	validation_0-rmse:0.21989	validation_1-rmse:0.61193
# [18]	validation_0-rmse:0.21958	validation_1-rmse:0.61247
# [19]	validation_0-rmse:0.21970	validation_1-rmse:0.61225
# [20]	validation_0-rmse:0.21295	validation_1-rmse:0.59691
# [21]	validation_0-rmse:0.21276	validation_1-rmse:0.59730
# [22]	validation_0-rmse:0.20635	validation_1-rmse:0.59846
# [23]	validation_0-rmse:0.20609	validation_1-rmse:0.59926
# [24]	validation_0-rmse:0.20631	validation_1-rmse:0.59856
# [25]	validation_0-rmse:0.20620	validation_1-rmse:0.59888
# [26]	validation_0-rmse:0.20599	validation_1-rmse:0.59973
# [27]	validation_0-rmse:0.20599	validation_1-rmse:0.59974
# [28]	validation_0-rmse:0.20593	validation_1-rmse:0.60032
# [29]	validation_0-rmse:0.20592	validation_1-rmse:0.60087
# [30]	validation_0-rmse:0.19723	validation_1-rmse:0.59713
# [31]	validation_0-rmse:0.19718	validation_1-rmse:0.59681
# [32]	validation_0-rmse:0.19712	validation_1-rmse:0.59598
# [33]	validation_0-rmse:0.19711	validation_1-rmse:0.59581
# [34]	validation_0-rmse:0.19716	validation_1-rmse:0.59662
# [35]	validation_0-rmse:0.19713	validation_1-rmse:0.59538
# [36]	validation_0-rmse:0.19719	validation_1-rmse:0.59487
# [37]	validation_0-rmse:0.19713	validation_1-rmse:0.59534
# [38]	validation_0-rmse:0.19379	validation_1-rmse:0.59194
# [39]	validation_0-rmse:0.19361	validation_1-rmse:0.59271
# [40]	validation_0-rmse:0.19367	validation_1-rmse:0.59239
# [41]	validation_0-rmse:0.19353	validation_1-rmse:0.59351
# [42]	validation_0-rmse:0.19047	validation_1-rmse:0.59585
# [43]	validation_0-rmse:0.19045	validation_1-rmse:0.59630
# [44]	validation_0-rmse:0.19044	validation_1-rmse:0.59670
# [45]	validation_0-rmse:0.19044	validation_1-rmse:0.59645
# [46]	validation_0-rmse:0.19046	validation_1-rmse:0.59600
# [47]	validation_0-rmse:0.19045	validation_1-rmse:0.59627
# [48]	validation_0-rmse:0.18508	validation_1-rmse:0.59585
# [49]	validation_0-rmse:0.18499	validation_1-rmse:0.59707
# [50]	validation_0-rmse:0.18499	validation_1-rmse:0.59710
# [51]	validation_0-rmse:0.18499	validation_1-rmse:0.59702
# [52]	validation_0-rmse:0.18503	validation_1-rmse:0.59620
# [53]	validation_0-rmse:0.18500	validation_1-rmse:0.59766
# [54]	validation_0-rmse:0.18499	validation_1-rmse:0.59671
# [55]	validation_0-rmse:0.18499	validation_1-rmse:0.59673
# [56]	validation_0-rmse:0.18499	validation_1-rmse:0.59683
# [57]	validation_0-rmse:0.18501	validation_1-rmse:0.59778
# [58]	validation_0-rmse:0.18499	validation_1-rmse:0.59731
# [0]	validation_0-rmse:3.40908	validation_1-rmse:3.40983
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [1]	validation_0-rmse:2.51499	validation_1-rmse:2.53055
# [2]	validation_0-rmse:1.85430	validation_1-rmse:1.86674
# [3]	validation_0-rmse:1.38029	validation_1-rmse:1.42974
# [4]	validation_0-rmse:1.02640	validation_1-rmse:1.12542
# [5]	validation_0-rmse:0.78539	validation_1-rmse:0.91234
# [6]	validation_0-rmse:0.60434	validation_1-rmse:0.76686
# [7]	validation_0-rmse:0.48125	validation_1-rmse:0.68222
# [8]	validation_0-rmse:0.39448	validation_1-rmse:0.61024
# [9]	validation_0-rmse:0.33918	validation_1-rmse:0.57923
# [10]	validation_0-rmse:0.29960	validation_1-rmse:0.56378
# [11]	validation_0-rmse:0.27650	validation_1-rmse:0.54505
# [12]	validation_0-rmse:0.26157	validation_1-rmse:0.54063
# [13]	validation_0-rmse:0.24726	validation_1-rmse:0.54223
# [14]	validation_0-rmse:0.24290	validation_1-rmse:0.53931
# [15]	validation_0-rmse:0.24180	validation_1-rmse:0.54015
# [16]	validation_0-rmse:0.23103	validation_1-rmse:0.54759
# [17]	validation_0-rmse:0.23039	validation_1-rmse:0.54911
# [18]	validation_0-rmse:0.22104	validation_1-rmse:0.55209
# [19]	validation_0-rmse:0.21582	validation_1-rmse:0.55092
# [20]	validation_0-rmse:0.21588	validation_1-rmse:0.55058
# [21]	validation_0-rmse:0.21571	validation_1-rmse:0.55201
# [22]	validation_0-rmse:0.21570	validation_1-rmse:0.55227
# [23]	validation_0-rmse:0.21570	validation_1-rmse:0.55241
# [24]	validation_0-rmse:0.21572	validation_1-rmse:0.55294
# [25]	validation_0-rmse:0.21570	validation_1-rmse:0.55249
# [26]	validation_0-rmse:0.21572	validation_1-rmse:0.55293
# [27]	validation_0-rmse:0.21572	validation_1-rmse:0.55295
# [28]	validation_0-rmse:0.21579	validation_1-rmse:0.55370
# [29]	validation_0-rmse:0.21571	validation_1-rmse:0.55266
# [30]	validation_0-rmse:0.21257	validation_1-rmse:0.54860
# [31]	validation_0-rmse:0.20868	validation_1-rmse:0.55267
# [32]	validation_0-rmse:0.20871	validation_1-rmse:0.55253
# [33]	validation_0-rmse:0.20866	validation_1-rmse:0.55277
# [34]	validation_0-rmse:0.20873	validation_1-rmse:0.55246
# [0]	validation_0-rmse:3.42687	validation_1-rmse:3.43093
# [1]	validation_0-rmse:2.51765	validation_1-rmse:2.52458
# [2]	validation_0-rmse:1.87099	validation_1-rmse:1.88626
# [3]	validation_0-rmse:1.38528	validation_1-rmse:1.40693
# [4]	validation_0-rmse:1.03421	validation_1-rmse:1.07597
# [5]	validation_0-rmse:0.79783	validation_1-rmse:0.86988
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:0.62644	validation_1-rmse:0.70541
# [7]	validation_0-rmse:0.50710	validation_1-rmse:0.59817
# [8]	validation_0-rmse:0.41284	validation_1-rmse:0.53986
# [9]	validation_0-rmse:0.35450	validation_1-rmse:0.50968
# [10]	validation_0-rmse:0.32269	validation_1-rmse:0.49644
# [11]	validation_0-rmse:0.30122	validation_1-rmse:0.49025
# [12]	validation_0-rmse:0.28059	validation_1-rmse:0.48069
# [13]	validation_0-rmse:0.26861	validation_1-rmse:0.48892
# [14]	validation_0-rmse:0.25885	validation_1-rmse:0.47991
# [15]	validation_0-rmse:0.25382	validation_1-rmse:0.48172
# [16]	validation_0-rmse:0.24701	validation_1-rmse:0.46911
# [17]	validation_0-rmse:0.24246	validation_1-rmse:0.46818
# [18]	validation_0-rmse:0.23880	validation_1-rmse:0.44784
# [19]	validation_0-rmse:0.23252	validation_1-rmse:0.43877
# [20]	validation_0-rmse:0.23223	validation_1-rmse:0.44024
# [21]	validation_0-rmse:0.23216	validation_1-rmse:0.44082
# [22]	validation_0-rmse:0.23208	validation_1-rmse:0.44210
# [23]	validation_0-rmse:0.23209	validation_1-rmse:0.44198
# [24]	validation_0-rmse:0.23211	validation_1-rmse:0.44146
# [25]	validation_0-rmse:0.23208	validation_1-rmse:0.44209
# [26]	validation_0-rmse:0.23209	validation_1-rmse:0.44184
# [27]	validation_0-rmse:0.23217	validation_1-rmse:0.44074
# [28]	validation_0-rmse:0.23214	validation_1-rmse:0.44100
# [29]	validation_0-rmse:0.23209	validation_1-rmse:0.44291
# [30]	validation_0-rmse:0.22638	validation_1-rmse:0.44171
# [31]	validation_0-rmse:0.22643	validation_1-rmse:0.44231
# [32]	validation_0-rmse:0.22249	validation_1-rmse:0.43441
# [33]	validation_0-rmse:0.22249	validation_1-rmse:0.43441
# [34]	validation_0-rmse:0.22249	validation_1-rmse:0.43445
# [35]	validation_0-rmse:0.22251	validation_1-rmse:0.43411
# [36]	validation_0-rmse:0.22259	validation_1-rmse:0.43330
# [37]	validation_0-rmse:0.22254	validation_1-rmse:0.43368
# [38]	validation_0-rmse:0.22266	validation_1-rmse:0.43283
# [39]	validation_0-rmse:0.22254	validation_1-rmse:0.43375
# [40]	validation_0-rmse:0.22254	validation_1-rmse:0.43370
# [41]	validation_0-rmse:0.22248	validation_1-rmse:0.43487
# [42]	validation_0-rmse:0.22248	validation_1-rmse:0.43489
# [43]	validation_0-rmse:0.22249	validation_1-rmse:0.43437
# [44]	validation_0-rmse:0.22257	validation_1-rmse:0.43342
# [45]	validation_0-rmse:0.22252	validation_1-rmse:0.43401
# [46]	validation_0-rmse:0.22248	validation_1-rmse:0.43467
# [47]	validation_0-rmse:0.22255	validation_1-rmse:0.43645
# [48]	validation_0-rmse:0.22254	validation_1-rmse:0.43635
# [49]	validation_0-rmse:0.22251	validation_1-rmse:0.43590
# [50]	validation_0-rmse:0.22248	validation_1-rmse:0.43501
# [51]	validation_0-rmse:0.21732	validation_1-rmse:0.43441
# [52]	validation_0-rmse:0.21744	validation_1-rmse:0.43347
# [53]	validation_0-rmse:0.21729	validation_1-rmse:0.43503
# [54]	validation_0-rmse:0.21731	validation_1-rmse:0.43459
# [55]	validation_0-rmse:0.21728	validation_1-rmse:0.43509
# [56]	validation_0-rmse:0.21728	validation_1-rmse:0.43524
# [57]	validation_0-rmse:0.21729	validation_1-rmse:0.43495
# [0]	validation_0-rmse:3.38679	validation_1-rmse:3.48768
# [1]	validation_0-rmse:2.48501	validation_1-rmse:2.55747
# [2]	validation_0-rmse:1.83720	validation_1-rmse:1.86415
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:1.37048	validation_1-rmse:1.36506
# [4]	validation_0-rmse:1.02418	validation_1-rmse:1.01320
# [5]	validation_0-rmse:0.79105	validation_1-rmse:0.82728
# [6]	validation_0-rmse:0.62261	validation_1-rmse:0.66385
# [7]	validation_0-rmse:0.50698	validation_1-rmse:0.57472
# [8]	validation_0-rmse:0.42016	validation_1-rmse:0.50692
# [9]	validation_0-rmse:0.36720	validation_1-rmse:0.46909
# [10]	validation_0-rmse:0.33192	validation_1-rmse:0.44017
# [11]	validation_0-rmse:0.30848	validation_1-rmse:0.43274
# [12]	validation_0-rmse:0.29090	validation_1-rmse:0.43242
# [13]	validation_0-rmse:0.28541	validation_1-rmse:0.43198
# [14]	validation_0-rmse:0.27536	validation_1-rmse:0.43293
# [15]	validation_0-rmse:0.26749	validation_1-rmse:0.43127
# [16]	validation_0-rmse:0.26119	validation_1-rmse:0.44005
# [17]	validation_0-rmse:0.25788	validation_1-rmse:0.43973
# [18]	validation_0-rmse:0.25757	validation_1-rmse:0.44101
# [19]	validation_0-rmse:0.25443	validation_1-rmse:0.43411
# [20]	validation_0-rmse:0.25181	validation_1-rmse:0.43803
# [21]	validation_0-rmse:0.24454	validation_1-rmse:0.42478
# [22]	validation_0-rmse:0.24449	validation_1-rmse:0.42558
# [23]	validation_0-rmse:0.24451	validation_1-rmse:0.42593
# [24]	validation_0-rmse:0.23366	validation_1-rmse:0.42116
# [25]	validation_0-rmse:0.23213	validation_1-rmse:0.41584
# [26]	validation_0-rmse:0.22781	validation_1-rmse:0.41403
# [27]	validation_0-rmse:0.22576	validation_1-rmse:0.41336
# [28]	validation_0-rmse:0.22581	validation_1-rmse:0.41369
# [29]	validation_0-rmse:0.22581	validation_1-rmse:0.41373
# [30]	validation_0-rmse:0.22116	validation_1-rmse:0.42154
# [31]	validation_0-rmse:0.22092	validation_1-rmse:0.42055
# [32]	validation_0-rmse:0.22087	validation_1-rmse:0.41992
# [33]	validation_0-rmse:0.22089	validation_1-rmse:0.41958
# [34]	validation_0-rmse:0.21852	validation_1-rmse:0.42077
# [35]	validation_0-rmse:0.21180	validation_1-rmse:0.42132
# [36]	validation_0-rmse:0.19954	validation_1-rmse:0.41872
# [37]	validation_0-rmse:0.19956	validation_1-rmse:0.41869
# [38]	validation_0-rmse:0.19949	validation_1-rmse:0.41883
# [39]	validation_0-rmse:0.19937	validation_1-rmse:0.41918
# [40]	validation_0-rmse:0.19937	validation_1-rmse:0.41920
# [41]	validation_0-rmse:0.19241	validation_1-rmse:0.41870
# [42]	validation_0-rmse:0.19240	validation_1-rmse:0.41888
# [43]	validation_0-rmse:0.19240	validation_1-rmse:0.41890
# [44]	validation_0-rmse:0.19242	validation_1-rmse:0.41930
# [45]	validation_0-rmse:0.18634	validation_1-rmse:0.41815
# [46]	validation_0-rmse:0.18637	validation_1-rmse:0.41756
# [0]	validation_0-rmse:3.43871	validation_1-rmse:3.27647
# [1]	validation_0-rmse:2.51715	validation_1-rmse:2.39363
# [2]	validation_0-rmse:1.85861	validation_1-rmse:1.75714
# [3]	validation_0-rmse:1.38674	validation_1-rmse:1.30741
# [4]	validation_0-rmse:1.04508	validation_1-rmse:1.00172
# [5]	validation_0-rmse:0.79189	validation_1-rmse:0.79588
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:0.61277	validation_1-rmse:0.64027
# [7]	validation_0-rmse:0.49253	validation_1-rmse:0.55247
# [8]	validation_0-rmse:0.41134	validation_1-rmse:0.50095
# [9]	validation_0-rmse:0.35733	validation_1-rmse:0.46020
# [10]	validation_0-rmse:0.31936	validation_1-rmse:0.43239
# [11]	validation_0-rmse:0.29585	validation_1-rmse:0.41243
# [12]	validation_0-rmse:0.27798	validation_1-rmse:0.40546
# [13]	validation_0-rmse:0.26884	validation_1-rmse:0.39890
# [14]	validation_0-rmse:0.25933	validation_1-rmse:0.40395
# [15]	validation_0-rmse:0.25329	validation_1-rmse:0.40313
# [16]	validation_0-rmse:0.25257	validation_1-rmse:0.40282
# [17]	validation_0-rmse:0.24868	validation_1-rmse:0.40187
# [18]	validation_0-rmse:0.24858	validation_1-rmse:0.40181
# [19]	validation_0-rmse:0.24530	validation_1-rmse:0.40177
# [20]	validation_0-rmse:0.24526	validation_1-rmse:0.40175
# [21]	validation_0-rmse:0.24368	validation_1-rmse:0.40014
# [22]	validation_0-rmse:0.24315	validation_1-rmse:0.40245
# [23]	validation_0-rmse:0.23890	validation_1-rmse:0.40452
# [24]	validation_0-rmse:0.23892	validation_1-rmse:0.40455
# [25]	validation_0-rmse:0.23896	validation_1-rmse:0.40460
# [26]	validation_0-rmse:0.23422	validation_1-rmse:0.39719
# [27]	validation_0-rmse:0.23450	validation_1-rmse:0.39748
# [28]	validation_0-rmse:0.23486	validation_1-rmse:0.39775
# [29]	validation_0-rmse:0.23645	validation_1-rmse:0.39064
# [30]	validation_0-rmse:0.23361	validation_1-rmse:0.39106
# [31]	validation_0-rmse:0.23314	validation_1-rmse:0.39051
# [32]	validation_0-rmse:0.23241	validation_1-rmse:0.38955
# [33]	validation_0-rmse:0.23214	validation_1-rmse:0.38906
# [34]	validation_0-rmse:0.22947	validation_1-rmse:0.38973
# [35]	validation_0-rmse:0.22283	validation_1-rmse:0.39052
# [36]	validation_0-rmse:0.22270	validation_1-rmse:0.39036
# [37]	validation_0-rmse:0.22247	validation_1-rmse:0.38984
# [38]	validation_0-rmse:0.22250	validation_1-rmse:0.39001
# [39]	validation_0-rmse:0.21866	validation_1-rmse:0.38939
# [40]	validation_0-rmse:0.21866	validation_1-rmse:0.38947
# [41]	validation_0-rmse:0.21885	validation_1-rmse:0.38910
# [42]	validation_0-rmse:0.21879	validation_1-rmse:0.38914
# [43]	validation_0-rmse:0.21409	validation_1-rmse:0.39053
# [44]	validation_0-rmse:0.20851	validation_1-rmse:0.38933
# [45]	validation_0-rmse:0.20837	validation_1-rmse:0.38937
# [46]	validation_0-rmse:0.20830	validation_1-rmse:0.38948
# [47]	validation_0-rmse:0.20830	validation_1-rmse:0.38948
# [48]	validation_0-rmse:0.20169	validation_1-rmse:0.39000
# [49]	validation_0-rmse:0.20172	validation_1-rmse:0.39005
# [50]	validation_0-rmse:0.20171	validation_1-rmse:0.39004
# [51]	validation_0-rmse:0.20168	validation_1-rmse:0.39001
# [52]	validation_0-rmse:0.20172	validation_1-rmse:0.39005
# [0]	validation_0-rmse:3.42733	validation_1-rmse:3.44111
# [1]	validation_0-rmse:2.54766	validation_1-rmse:2.55889
# [2]	validation_0-rmse:1.88234	validation_1-rmse:1.86896
# [3]	validation_0-rmse:1.40078	validation_1-rmse:1.38690
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.05783	validation_1-rmse:1.06229
# [5]	validation_0-rmse:0.81342	validation_1-rmse:0.81304
# [6]	validation_0-rmse:0.63610	validation_1-rmse:0.62628
# [7]	validation_0-rmse:0.51239	validation_1-rmse:0.50247
# [8]	validation_0-rmse:0.42305	validation_1-rmse:0.40375
# [9]	validation_0-rmse:0.36462	validation_1-rmse:0.34960
# [10]	validation_0-rmse:0.32641	validation_1-rmse:0.31260
# [11]	validation_0-rmse:0.30297	validation_1-rmse:0.28484
# [12]	validation_0-rmse:0.28486	validation_1-rmse:0.27942
# [13]	validation_0-rmse:0.27299	validation_1-rmse:0.27178
# [14]	validation_0-rmse:0.27069	validation_1-rmse:0.26737
# [15]	validation_0-rmse:0.26000	validation_1-rmse:0.27910
# [16]	validation_0-rmse:0.25645	validation_1-rmse:0.27636
# [17]	validation_0-rmse:0.24984	validation_1-rmse:0.26854
# [18]	validation_0-rmse:0.24992	validation_1-rmse:0.26883
# [19]	validation_0-rmse:0.23783	validation_1-rmse:0.27103
# [20]	validation_0-rmse:0.23781	validation_1-rmse:0.27071
# [21]	validation_0-rmse:0.23267	validation_1-rmse:0.26855
# [22]	validation_0-rmse:0.23263	validation_1-rmse:0.26886
# [23]	validation_0-rmse:0.22629	validation_1-rmse:0.28219
# [24]	validation_0-rmse:0.22638	validation_1-rmse:0.28301
# [25]	validation_0-rmse:0.22636	validation_1-rmse:0.28290
# [26]	validation_0-rmse:0.22632	validation_1-rmse:0.28265
# [27]	validation_0-rmse:0.22115	validation_1-rmse:0.27736
# [28]	validation_0-rmse:0.22117	validation_1-rmse:0.27763
# [29]	validation_0-rmse:0.22116	validation_1-rmse:0.27745
# [30]	validation_0-rmse:0.22119	validation_1-rmse:0.27776
# [31]	validation_0-rmse:0.22116	validation_1-rmse:0.27742
# [32]	validation_0-rmse:0.21605	validation_1-rmse:0.27350
# [33]	validation_0-rmse:0.21606	validation_1-rmse:0.27363
# [0]	validation_0-rmse:3.42370	validation_1-rmse:3.31939
# [1]	validation_0-rmse:2.52750	validation_1-rmse:2.45803
# [2]	validation_0-rmse:1.87313	validation_1-rmse:1.80092
# [3]	validation_0-rmse:1.39284	validation_1-rmse:1.35338
# [4]	validation_0-rmse:1.03846	validation_1-rmse:1.05014
# [5]	validation_0-rmse:0.79356	validation_1-rmse:0.84569
# [6]	validation_0-rmse:0.61152	validation_1-rmse:0.70477
# [7]	validation_0-rmse:0.48407	validation_1-rmse:0.62701
# [8]	validation_0-rmse:0.39447	validation_1-rmse:0.57461
# [9]	validation_0-rmse:0.33995	validation_1-rmse:0.53611
# [10]	validation_0-rmse:0.30618	validation_1-rmse:0.53089
# [11]	validation_0-rmse:0.28842	validation_1-rmse:0.51604
# [12]	validation_0-rmse:0.26743	validation_1-rmse:0.50429
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [13]	validation_0-rmse:0.25642	validation_1-rmse:0.50458
# [14]	validation_0-rmse:0.25233	validation_1-rmse:0.50042
# [15]	validation_0-rmse:0.24555	validation_1-rmse:0.49781
# [16]	validation_0-rmse:0.24451	validation_1-rmse:0.49635
# [17]	validation_0-rmse:0.24380	validation_1-rmse:0.49516
# [18]	validation_0-rmse:0.23937	validation_1-rmse:0.49930
# [19]	validation_0-rmse:0.23895	validation_1-rmse:0.49843
# [20]	validation_0-rmse:0.23872	validation_1-rmse:0.49783
# [21]	validation_0-rmse:0.23842	validation_1-rmse:0.49605
# [22]	validation_0-rmse:0.23523	validation_1-rmse:0.49611
# [23]	validation_0-rmse:0.23239	validation_1-rmse:0.49691
# [24]	validation_0-rmse:0.22162	validation_1-rmse:0.49695
# [25]	validation_0-rmse:0.22150	validation_1-rmse:0.49653
# [26]	validation_0-rmse:0.22040	validation_1-rmse:0.48997
# [27]	validation_0-rmse:0.21555	validation_1-rmse:0.49198
# [28]	validation_0-rmse:0.21552	validation_1-rmse:0.49142
# [29]	validation_0-rmse:0.21557	validation_1-rmse:0.49059
# [30]	validation_0-rmse:0.21553	validation_1-rmse:0.49093
# [31]	validation_0-rmse:0.21552	validation_1-rmse:0.49156
# [32]	validation_0-rmse:0.21556	validation_1-rmse:0.49210
# [33]	validation_0-rmse:0.20942	validation_1-rmse:0.49681
# [34]	validation_0-rmse:0.20942	validation_1-rmse:0.49682
# [35]	validation_0-rmse:0.20944	validation_1-rmse:0.49694
# [36]	validation_0-rmse:0.20936	validation_1-rmse:0.49594
# [37]	validation_0-rmse:0.20937	validation_1-rmse:0.49553
# [38]	validation_0-rmse:0.20936	validation_1-rmse:0.49596
# [39]	validation_0-rmse:0.20938	validation_1-rmse:0.49534
# [40]	validation_0-rmse:0.20936	validation_1-rmse:0.49584
# [41]	validation_0-rmse:0.20936	validation_1-rmse:0.49602
# [42]	validation_0-rmse:0.20937	validation_1-rmse:0.49623
# [43]	validation_0-rmse:0.20943	validation_1-rmse:0.49692
# [44]	validation_0-rmse:0.20937	validation_1-rmse:0.49633
# [45]	validation_0-rmse:0.20937	validation_1-rmse:0.49632
# [46]	validation_0-rmse:0.20937	validation_1-rmse:0.49553
# [0]	validation_0-rmse:3.38684	validation_1-rmse:3.47053
# [1]	validation_0-rmse:2.48146	validation_1-rmse:2.58578
# [2]	validation_0-rmse:1.83871	validation_1-rmse:1.92063
# [3]	validation_0-rmse:1.35688	validation_1-rmse:1.44792
# [4]	validation_0-rmse:1.01448	validation_1-rmse:1.10087
# [5]	validation_0-rmse:0.77477	validation_1-rmse:0.88068
# [6]	validation_0-rmse:0.59406	validation_1-rmse:0.72102
# [7]	validation_0-rmse:0.47161	validation_1-rmse:0.61862
# [8]	validation_0-rmse:0.38432	validation_1-rmse:0.55358
# [9]	validation_0-rmse:0.33117	validation_1-rmse:0.52210
# [10]	validation_0-rmse:0.28832	validation_1-rmse:0.50651
# [11]	validation_0-rmse:0.26052	validation_1-rmse:0.48586
# [12]	validation_0-rmse:0.24659	validation_1-rmse:0.48199
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [13]	validation_0-rmse:0.23925	validation_1-rmse:0.48026
# [14]	validation_0-rmse:0.23231	validation_1-rmse:0.47191
# [15]	validation_0-rmse:0.22298	validation_1-rmse:0.47016
# [16]	validation_0-rmse:0.21746	validation_1-rmse:0.46118
# [17]	validation_0-rmse:0.21699	validation_1-rmse:0.46013
# [18]	validation_0-rmse:0.21667	validation_1-rmse:0.45921
# [19]	validation_0-rmse:0.21634	validation_1-rmse:0.45757
# [20]	validation_0-rmse:0.21634	validation_1-rmse:0.45747
# [21]	validation_0-rmse:0.21071	validation_1-rmse:0.46242
# [22]	validation_0-rmse:0.21080	validation_1-rmse:0.46325
# [23]	validation_0-rmse:0.20753	validation_1-rmse:0.46088
# [24]	validation_0-rmse:0.20739	validation_1-rmse:0.45998
# [25]	validation_0-rmse:0.20738	validation_1-rmse:0.45925
# [26]	validation_0-rmse:0.20738	validation_1-rmse:0.45940
# [27]	validation_0-rmse:0.20738	validation_1-rmse:0.45985
# [28]	validation_0-rmse:0.20738	validation_1-rmse:0.45990
# [29]	validation_0-rmse:0.20742	validation_1-rmse:0.46028
# [30]	validation_0-rmse:0.20745	validation_1-rmse:0.46047
# [31]	validation_0-rmse:0.20752	validation_1-rmse:0.46085
# [32]	validation_0-rmse:0.20738	validation_1-rmse:0.45994
# [33]	validation_0-rmse:0.20596	validation_1-rmse:0.46634
# [34]	validation_0-rmse:0.20596	validation_1-rmse:0.46611
# [35]	validation_0-rmse:0.20596	validation_1-rmse:0.46643
# [36]	validation_0-rmse:0.20610	validation_1-rmse:0.46521
# [37]	validation_0-rmse:0.20599	validation_1-rmse:0.46572
# [38]	validation_0-rmse:0.20596	validation_1-rmse:0.46627
# [39]	validation_0-rmse:0.20600	validation_1-rmse:0.46678
# [40]	validation_0-rmse:0.20609	validation_1-rmse:0.46730
# [0]	validation_0-rmse:3.41356	validation_1-rmse:3.38906
# [1]	validation_0-rmse:2.52237	validation_1-rmse:2.50874
# [2]	validation_0-rmse:1.86024	validation_1-rmse:1.81582
# [3]	validation_0-rmse:1.38688	validation_1-rmse:1.35698
# [4]	validation_0-rmse:1.03492	validation_1-rmse:1.03606
# [5]	validation_0-rmse:0.79011	validation_1-rmse:0.79212
# [6]	validation_0-rmse:0.62353	validation_1-rmse:0.64262
# [7]	validation_0-rmse:0.49335	validation_1-rmse:0.52580
# [8]	validation_0-rmse:0.40141	validation_1-rmse:0.45058
# [9]	validation_0-rmse:0.33948	validation_1-rmse:0.39624
# [10]	validation_0-rmse:0.30636	validation_1-rmse:0.36531
# [11]	validation_0-rmse:0.28440	validation_1-rmse:0.34648
# [12]	validation_0-rmse:0.27197	validation_1-rmse:0.34605
# [13]	validation_0-rmse:0.26176	validation_1-rmse:0.34078
# [14]	validation_0-rmse:0.25054	validation_1-rmse:0.34431
# [15]	validation_0-rmse:0.24774	validation_1-rmse:0.35105
# [16]	validation_0-rmse:0.24111	validation_1-rmse:0.35243
# [17]	validation_0-rmse:0.23831	validation_1-rmse:0.35238
# [18]	validation_0-rmse:0.23802	validation_1-rmse:0.35158
# [19]	validation_0-rmse:0.23835	validation_1-rmse:0.35246
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [20]	validation_0-rmse:0.22847	validation_1-rmse:0.35315
# [21]	validation_0-rmse:0.22745	validation_1-rmse:0.35151
# [22]	validation_0-rmse:0.22061	validation_1-rmse:0.35325
# [23]	validation_0-rmse:0.22062	validation_1-rmse:0.35327
# [24]	validation_0-rmse:0.22059	validation_1-rmse:0.35316
# [25]	validation_0-rmse:0.22053	validation_1-rmse:0.35291
# [26]	validation_0-rmse:0.22047	validation_1-rmse:0.35251
# [27]	validation_0-rmse:0.21707	validation_1-rmse:0.35166
# [28]	validation_0-rmse:0.21706	validation_1-rmse:0.35123
# [29]	validation_0-rmse:0.21706	validation_1-rmse:0.35139
# [30]	validation_0-rmse:0.21728	validation_1-rmse:0.35011
# [31]	validation_0-rmse:0.21711	validation_1-rmse:0.35075
# [32]	validation_0-rmse:0.21707	validation_1-rmse:0.35171
# [0]	validation_0-rmse:3.45694	validation_1-rmse:3.37361
# [1]	validation_0-rmse:2.54604	validation_1-rmse:2.51214
# [2]	validation_0-rmse:1.87783	validation_1-rmse:1.90480
# [3]	validation_0-rmse:1.38818	validation_1-rmse:1.45263
# [4]	validation_0-rmse:1.04726	validation_1-rmse:1.14887
# [5]	validation_0-rmse:0.78911	validation_1-rmse:0.90234
# [6]	validation_0-rmse:0.60817	validation_1-rmse:0.73788
# [7]	validation_0-rmse:0.48763	validation_1-rmse:0.63117
# [8]	validation_0-rmse:0.40634	validation_1-rmse:0.53828
# [9]	validation_0-rmse:0.35503	validation_1-rmse:0.48602
# [10]	validation_0-rmse:0.31671	validation_1-rmse:0.43162
# [11]	validation_0-rmse:0.29655	validation_1-rmse:0.39209
# [12]	validation_0-rmse:0.27783	validation_1-rmse:0.37688
# [13]	validation_0-rmse:0.26772	validation_1-rmse:0.38128
# [14]	validation_0-rmse:0.25744	validation_1-rmse:0.38587
# [15]	validation_0-rmse:0.25245	validation_1-rmse:0.36652
# [16]	validation_0-rmse:0.24802	validation_1-rmse:0.35593
# [17]	validation_0-rmse:0.24821	validation_1-rmse:0.35848
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [18]	validation_0-rmse:0.24834	validation_1-rmse:0.35981
# [19]	validation_0-rmse:0.24800	validation_1-rmse:0.35572
# [20]	validation_0-rmse:0.24512	validation_1-rmse:0.36096
# [21]	validation_0-rmse:0.24512	validation_1-rmse:0.36188
# [22]	validation_0-rmse:0.24512	validation_1-rmse:0.36178
# [23]	validation_0-rmse:0.24041	validation_1-rmse:0.34532
# [24]	validation_0-rmse:0.24037	validation_1-rmse:0.34195
# [25]	validation_0-rmse:0.24044	validation_1-rmse:0.33926
# [26]	validation_0-rmse:0.24071	validation_1-rmse:0.33556
# [27]	validation_0-rmse:0.24072	validation_1-rmse:0.33543
# [28]	validation_0-rmse:0.24038	validation_1-rmse:0.34131
# [29]	validation_0-rmse:0.23898	validation_1-rmse:0.33707
# [30]	validation_0-rmse:0.23894	validation_1-rmse:0.33787
# [31]	validation_0-rmse:0.23889	validation_1-rmse:0.34072
# [32]	validation_0-rmse:0.23891	validation_1-rmse:0.33883
# [33]	validation_0-rmse:0.23895	validation_1-rmse:0.33774
# [34]	validation_0-rmse:0.23621	validation_1-rmse:0.35011
# [35]	validation_0-rmse:0.23622	validation_1-rmse:0.34959
# [36]	validation_0-rmse:0.23139	validation_1-rmse:0.36513
# [37]	validation_0-rmse:0.23143	validation_1-rmse:0.36647
# [38]	validation_0-rmse:0.23152	validation_1-rmse:0.36831
# [39]	validation_0-rmse:0.23148	validation_1-rmse:0.36764
# [40]	validation_0-rmse:0.23147	validation_1-rmse:0.36727
# [41]	validation_0-rmse:0.22556	validation_1-rmse:0.35250
# [42]	validation_0-rmse:0.22558	validation_1-rmse:0.35166
# [43]	validation_0-rmse:0.22562	validation_1-rmse:0.35084
# [44]	validation_0-rmse:0.22557	validation_1-rmse:0.35203
# [45]	validation_0-rmse:0.22556	validation_1-rmse:0.35229
# [46]	validation_0-rmse:0.22568	validation_1-rmse:0.34981
# [47]	validation_0-rmse:0.22564	validation_1-rmse:0.35045
# [0]	validation_0-rmse:3.37274	validation_1-rmse:3.61584
# [1]	validation_0-rmse:2.50106	validation_1-rmse:2.71254
# [2]	validation_0-rmse:1.83516	validation_1-rmse:2.02728
# [3]	validation_0-rmse:1.37359	validation_1-rmse:1.55731
# [4]	validation_0-rmse:1.04805	validation_1-rmse:1.21866
# [5]	validation_0-rmse:0.80526	validation_1-rmse:0.97083
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:0.63382	validation_1-rmse:0.78120
# [7]	validation_0-rmse:0.50471	validation_1-rmse:0.61468
# [8]	validation_0-rmse:0.42282	validation_1-rmse:0.52305
# [9]	validation_0-rmse:0.36533	validation_1-rmse:0.44705
# [10]	validation_0-rmse:0.32835	validation_1-rmse:0.38468
# [11]	validation_0-rmse:0.30988	validation_1-rmse:0.35054
# [12]	validation_0-rmse:0.29325	validation_1-rmse:0.34330
# [13]	validation_0-rmse:0.27912	validation_1-rmse:0.32791
# [14]	validation_0-rmse:0.26829	validation_1-rmse:0.31227
# [15]	validation_0-rmse:0.26255	validation_1-rmse:0.30179
# [16]	validation_0-rmse:0.26022	validation_1-rmse:0.30075
# [17]	validation_0-rmse:0.25511	validation_1-rmse:0.29110
# [18]	validation_0-rmse:0.25236	validation_1-rmse:0.29282
# [19]	validation_0-rmse:0.25165	validation_1-rmse:0.28727
# [20]	validation_0-rmse:0.24674	validation_1-rmse:0.28951
# [21]	validation_0-rmse:0.24235	validation_1-rmse:0.29891
# [22]	validation_0-rmse:0.24233	validation_1-rmse:0.29782
# [23]	validation_0-rmse:0.23728	validation_1-rmse:0.29055
# [24]	validation_0-rmse:0.23216	validation_1-rmse:0.28551
# [25]	validation_0-rmse:0.22944	validation_1-rmse:0.28139
# [26]	validation_0-rmse:0.22950	validation_1-rmse:0.28094
# [27]	validation_0-rmse:0.22420	validation_1-rmse:0.27944
# [28]	validation_0-rmse:0.22399	validation_1-rmse:0.28141
# [29]	validation_0-rmse:0.22181	validation_1-rmse:0.28709
# [30]	validation_0-rmse:0.21353	validation_1-rmse:0.28376
# [31]	validation_0-rmse:0.21364	validation_1-rmse:0.28735
# [32]	validation_0-rmse:0.21355	validation_1-rmse:0.28557
# [33]	validation_0-rmse:0.21361	validation_1-rmse:0.28187
# [34]	validation_0-rmse:0.21353	validation_1-rmse:0.28400
# [35]	validation_0-rmse:0.21353	validation_1-rmse:0.28426
# [36]	validation_0-rmse:0.21354	validation_1-rmse:0.28350
# [37]	validation_0-rmse:0.21354	validation_1-rmse:0.28349
# [38]	validation_0-rmse:0.21357	validation_1-rmse:0.28250
# [39]	validation_0-rmse:0.21356	validation_1-rmse:0.28282
# [40]	validation_0-rmse:0.21355	validation_1-rmse:0.28573
# [41]	validation_0-rmse:0.21356	validation_1-rmse:0.28587
# [42]	validation_0-rmse:0.21353	validation_1-rmse:0.28451
# [43]	validation_0-rmse:0.21354	validation_1-rmse:0.28531
# [44]	validation_0-rmse:0.21356	validation_1-rmse:0.28267
# [45]	validation_0-rmse:0.21353	validation_1-rmse:0.28493
# [46]	validation_0-rmse:0.21353	validation_1-rmse:0.28471
# [47]	validation_0-rmse:0.21097	validation_1-rmse:0.28785
# [0]	validation_0-rmse:3.39692	validation_1-rmse:3.48601
# [1]	validation_0-rmse:2.48847	validation_1-rmse:2.55269
# [2]	validation_0-rmse:1.84223	validation_1-rmse:1.86339
# [3]	validation_0-rmse:1.37817	validation_1-rmse:1.35727
# [4]	validation_0-rmse:1.03797	validation_1-rmse:1.01726
# [5]	validation_0-rmse:0.79022	validation_1-rmse:0.78029
# [6]	validation_0-rmse:0.61119	validation_1-rmse:0.60137
# [7]	validation_0-rmse:0.48355	validation_1-rmse:0.47585
# [8]	validation_0-rmse:0.40400	validation_1-rmse:0.40027
# [9]	validation_0-rmse:0.34651	validation_1-rmse:0.35045
# [10]	validation_0-rmse:0.31107	validation_1-rmse:0.32595
# [11]	validation_0-rmse:0.28904	validation_1-rmse:0.31226
# [12]	validation_0-rmse:0.27483	validation_1-rmse:0.31042
# [13]	validation_0-rmse:0.26003	validation_1-rmse:0.30865
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [14]	validation_0-rmse:0.25434	validation_1-rmse:0.30875
# [15]	validation_0-rmse:0.25009	validation_1-rmse:0.30812
# [16]	validation_0-rmse:0.24245	validation_1-rmse:0.30462
# [17]	validation_0-rmse:0.23722	validation_1-rmse:0.29720
# [18]	validation_0-rmse:0.23677	validation_1-rmse:0.29724
# [19]	validation_0-rmse:0.23620	validation_1-rmse:0.29748
# [20]	validation_0-rmse:0.23186	validation_1-rmse:0.30704
# [21]	validation_0-rmse:0.22491	validation_1-rmse:0.30882
# [22]	validation_0-rmse:0.22428	validation_1-rmse:0.30743
# [23]	validation_0-rmse:0.21994	validation_1-rmse:0.30661
# [24]	validation_0-rmse:0.22007	validation_1-rmse:0.30714
# [25]	validation_0-rmse:0.21991	validation_1-rmse:0.30636
# [26]	validation_0-rmse:0.21996	validation_1-rmse:0.30574
# [27]	validation_0-rmse:0.21579	validation_1-rmse:0.29344
# [28]	validation_0-rmse:0.21576	validation_1-rmse:0.29361
# [29]	validation_0-rmse:0.21577	validation_1-rmse:0.29374
# [30]	validation_0-rmse:0.21577	validation_1-rmse:0.29374
# [31]	validation_0-rmse:0.21577	validation_1-rmse:0.29373
# [32]	validation_0-rmse:0.21578	validation_1-rmse:0.29380
# [33]	validation_0-rmse:0.21588	validation_1-rmse:0.29414
# [34]	validation_0-rmse:0.21580	validation_1-rmse:0.29387
# [35]	validation_0-rmse:0.21580	validation_1-rmse:0.29340
# [36]	validation_0-rmse:0.21578	validation_1-rmse:0.29349
# [37]	validation_0-rmse:0.21587	validation_1-rmse:0.29328
# [38]	validation_0-rmse:0.21606	validation_1-rmse:0.29314
# [39]	validation_0-rmse:0.21608	validation_1-rmse:0.29313
# [40]	validation_0-rmse:0.21614	validation_1-rmse:0.29311
# [41]	validation_0-rmse:0.21600	validation_1-rmse:0.29317
# [42]	validation_0-rmse:0.21586	validation_1-rmse:0.29330
# [43]	validation_0-rmse:0.21577	validation_1-rmse:0.29373
# [44]	validation_0-rmse:0.21578	validation_1-rmse:0.29382
# [45]	validation_0-rmse:0.21577	validation_1-rmse:0.29374
# [46]	validation_0-rmse:0.21577	validation_1-rmse:0.29350
# [47]	validation_0-rmse:0.21584	validation_1-rmse:0.29333
# [48]	validation_0-rmse:0.21578	validation_1-rmse:0.29349
# [49]	validation_0-rmse:0.21586	validation_1-rmse:0.29330
# [50]	validation_0-rmse:0.21592	validation_1-rmse:0.29323
# [51]	validation_0-rmse:0.21586	validation_1-rmse:0.29330
# [52]	validation_0-rmse:0.21591	validation_1-rmse:0.29324
# [53]	validation_0-rmse:0.21581	validation_1-rmse:0.29339
# [54]	validation_0-rmse:0.21577	validation_1-rmse:0.29371
# [55]	validation_0-rmse:0.21581	validation_1-rmse:0.29394
# [56]	validation_0-rmse:0.21605	validation_1-rmse:0.29451
# [57]	validation_0-rmse:0.21599	validation_1-rmse:0.29441
# [58]	validation_0-rmse:0.21599	validation_1-rmse:0.29439
# [59]	validation_0-rmse:0.21615	validation_1-rmse:0.29470
# [0]	validation_0-rmse:3.45755	validation_1-rmse:3.13408
# [1]	validation_0-rmse:2.55326	validation_1-rmse:2.28825
# [2]	validation_0-rmse:1.89172	validation_1-rmse:1.63612
# [3]	validation_0-rmse:1.41587	validation_1-rmse:1.21934
# [4]	validation_0-rmse:1.04351	validation_1-rmse:0.90121
# [5]	validation_0-rmse:0.79326	validation_1-rmse:0.70878
# [6]	validation_0-rmse:0.60979	validation_1-rmse:0.57941
# [7]	validation_0-rmse:0.48395	validation_1-rmse:0.50974
# [8]	validation_0-rmse:0.39992	validation_1-rmse:0.49712
# [9]	validation_0-rmse:0.33803	validation_1-rmse:0.48733
# [10]	validation_0-rmse:0.31134	validation_1-rmse:0.48979
# [11]	validation_0-rmse:0.29201	validation_1-rmse:0.49492
# [12]	validation_0-rmse:0.27530	validation_1-rmse:0.49030
# [13]	validation_0-rmse:0.26237	validation_1-rmse:0.49572
# [14]	validation_0-rmse:0.25447	validation_1-rmse:0.49977
# [15]	validation_0-rmse:0.24808	validation_1-rmse:0.50067
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [16]	validation_0-rmse:0.24302	validation_1-rmse:0.49939
# [17]	validation_0-rmse:0.23927	validation_1-rmse:0.49982
# [18]	validation_0-rmse:0.23895	validation_1-rmse:0.50396
# [19]	validation_0-rmse:0.23894	validation_1-rmse:0.50353
# [20]	validation_0-rmse:0.23340	validation_1-rmse:0.51216
# [21]	validation_0-rmse:0.23341	validation_1-rmse:0.51141
# [22]	validation_0-rmse:0.23340	validation_1-rmse:0.51168
# [23]	validation_0-rmse:0.22694	validation_1-rmse:0.51299
# [24]	validation_0-rmse:0.22695	validation_1-rmse:0.51319
# ...
# [34]	validation_0-rmse:0.22653	validation_1-rmse:0.36320
# [35]	validation_0-rmse:0.22685	validation_1-rmse:0.36318
# [36]	validation_0-rmse:0.22661	validation_1-rmse:0.36316
# [37]	validation_0-rmse:0.22664	validation_1-rmse:0.36315
# [38]	validation_0-rmse:0.22670	validation_1-rmse:0.36316
# [39]	validation_0-rmse:0.22653	validation_1-rmse:0.36320
# [40]	validation_0-rmse:0.22655	validation_1-rmse:0.36318
# [41]	validation_0-rmse:0.21771	validation_1-rmse:0.36685
# [42]	validation_0-rmse:0.21772	validation_1-rmse:0.36682
# [43]	validation_0-rmse:0.21770	validation_1-rmse:0.36694
# [44]	validation_0-rmse:0.21772	validation_1-rmse:0.36683
# [0]	validation_0-rmse:3.49404	validation_1-rmse:3.07572
# [1]	validation_0-rmse:2.55209	validation_1-rmse:2.22513
# [2]	validation_0-rmse:1.88145	validation_1-rmse:1.63202
# [3]	validation_0-rmse:1.39736	validation_1-rmse:1.24355
# [4]	validation_0-rmse:1.03773	validation_1-rmse:0.95203
# [5]	validation_0-rmse:0.78792	validation_1-rmse:0.77619
# [6]	validation_0-rmse:0.60864	validation_1-rmse:0.63565
# [7]	validation_0-rmse:0.49304	validation_1-rmse:0.56721
# [8]	validation_0-rmse:0.40679	validation_1-rmse:0.50855
# [9]	validation_0-rmse:0.35465	validation_1-rmse:0.50815
# [10]	validation_0-rmse:0.31272	validation_1-rmse:0.51919
# [11]	validation_0-rmse:0.29252	validation_1-rmse:0.50468
# [12]	validation_0-rmse:0.27323	validation_1-rmse:0.48381
# [13]	validation_0-rmse:0.25917	validation_1-rmse:0.45922
# [14]	validation_0-rmse:0.24934	validation_1-rmse:0.45465
# [15]	validation_0-rmse:0.24732	validation_1-rmse:0.45239
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [16]	validation_0-rmse:0.23810	validation_1-rmse:0.44632
# [17]	validation_0-rmse:0.23811	validation_1-rmse:0.44632
# [18]	validation_0-rmse:0.23793	validation_1-rmse:0.44589
# [19]	validation_0-rmse:0.23496	validation_1-rmse:0.47202
# [20]	validation_0-rmse:0.22822	validation_1-rmse:0.47012
# [21]	validation_0-rmse:0.22602	validation_1-rmse:0.47178
# [22]	validation_0-rmse:0.22236	validation_1-rmse:0.46979
# [23]	validation_0-rmse:0.22231	validation_1-rmse:0.46958
# [24]	validation_0-rmse:0.22224	validation_1-rmse:0.46887
# [25]	validation_0-rmse:0.22061	validation_1-rmse:0.46869
# [26]	validation_0-rmse:0.22079	validation_1-rmse:0.46765
# [27]	validation_0-rmse:0.21592	validation_1-rmse:0.46633
# [28]	validation_0-rmse:0.21589	validation_1-rmse:0.46660
# [29]	validation_0-rmse:0.21591	validation_1-rmse:0.46704
# [30]	validation_0-rmse:0.21593	validation_1-rmse:0.46715
# [31]	validation_0-rmse:0.21589	validation_1-rmse:0.46686
# [32]	validation_0-rmse:0.21593	validation_1-rmse:0.46631
# [33]	validation_0-rmse:0.21589	validation_1-rmse:0.46660
# [34]	validation_0-rmse:0.21589	validation_1-rmse:0.46663
# [35]	validation_0-rmse:0.21590	validation_1-rmse:0.46693
# [36]	validation_0-rmse:0.21593	validation_1-rmse:0.46718
# [37]	validation_0-rmse:0.21592	validation_1-rmse:0.46715
# [38]	validation_0-rmse:0.21591	validation_1-rmse:0.46704
# [0]	validation_0-rmse:3.39735	validation_1-rmse:3.50728
# [1]	validation_0-rmse:2.50306	validation_1-rmse:2.59659
# [2]	validation_0-rmse:1.85287	validation_1-rmse:1.93378
# [3]	validation_0-rmse:1.37755	validation_1-rmse:1.44424
# [4]	validation_0-rmse:1.03338	validation_1-rmse:1.09591
# [5]	validation_0-rmse:0.77742	validation_1-rmse:0.84113
# [6]	validation_0-rmse:0.60873	validation_1-rmse:0.69965
# [7]	validation_0-rmse:0.47888	validation_1-rmse:0.59461
# [8]	validation_0-rmse:0.39306	validation_1-rmse:0.54045
# [9]	validation_0-rmse:0.33616	validation_1-rmse:0.50917
# [10]	validation_0-rmse:0.31486	validation_1-rmse:0.50270
# [11]	validation_0-rmse:0.29043	validation_1-rmse:0.50131
# [12]	validation_0-rmse:0.27198	validation_1-rmse:0.49983
# [13]	validation_0-rmse:0.26307	validation_1-rmse:0.49570
# [14]	validation_0-rmse:0.25920	validation_1-rmse:0.49709
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:0.25792	validation_1-rmse:0.49793
# [16]	validation_0-rmse:0.25010	validation_1-rmse:0.49295
# [17]	validation_0-rmse:0.24744	validation_1-rmse:0.48854
# [18]	validation_0-rmse:0.24262	validation_1-rmse:0.49152
# [19]	validation_0-rmse:0.24242	validation_1-rmse:0.49194
# [20]	validation_0-rmse:0.24211	validation_1-rmse:0.49290
# [21]	validation_0-rmse:0.23332	validation_1-rmse:0.48394
# [22]	validation_0-rmse:0.22396	validation_1-rmse:0.49919
# [23]	validation_0-rmse:0.22396	validation_1-rmse:0.49932
# [24]	validation_0-rmse:0.22396	validation_1-rmse:0.49917
# [25]	validation_0-rmse:0.22396	validation_1-rmse:0.49873
# [26]	validation_0-rmse:0.21760	validation_1-rmse:0.51369
# [27]	validation_0-rmse:0.21761	validation_1-rmse:0.51456
# [28]	validation_0-rmse:0.21761	validation_1-rmse:0.51361
# [29]	validation_0-rmse:0.21758	validation_1-rmse:0.51414
# [30]	validation_0-rmse:0.21759	validation_1-rmse:0.51431
# [31]	validation_0-rmse:0.21247	validation_1-rmse:0.51439
# [32]	validation_0-rmse:0.21244	validation_1-rmse:0.51388
# [33]	validation_0-rmse:0.21245	validation_1-rmse:0.51405
# [34]	validation_0-rmse:0.21244	validation_1-rmse:0.51383
# [35]	validation_0-rmse:0.21251	validation_1-rmse:0.51463
# [36]	validation_0-rmse:0.21244	validation_1-rmse:0.51390
# [37]	validation_0-rmse:0.21245	validation_1-rmse:0.51360
# [38]	validation_0-rmse:0.20748	validation_1-rmse:0.50128
# [39]	validation_0-rmse:0.20430	validation_1-rmse:0.49762
# [40]	validation_0-rmse:0.20425	validation_1-rmse:0.49831
# [41]	validation_0-rmse:0.20426	validation_1-rmse:0.49841
# [0]	validation_0-rmse:3.45734	validation_1-rmse:3.31088
# [1]	validation_0-rmse:2.54967	validation_1-rmse:2.41710
# [2]	validation_0-rmse:1.88543	validation_1-rmse:1.79379
# [3]	validation_0-rmse:1.38928	validation_1-rmse:1.33664
# [4]	validation_0-rmse:1.04691	validation_1-rmse:1.04523
# [5]	validation_0-rmse:0.79692	validation_1-rmse:0.85949
# [6]	validation_0-rmse:0.61024	validation_1-rmse:0.73983
# [7]	validation_0-rmse:0.47767	validation_1-rmse:0.63908
# [8]	validation_0-rmse:0.39413	validation_1-rmse:0.61941
# [9]	validation_0-rmse:0.33827	validation_1-rmse:0.59320
# [10]	validation_0-rmse:0.31083	validation_1-rmse:0.56898
# [11]	validation_0-rmse:0.28665	validation_1-rmse:0.57008
# [12]	validation_0-rmse:0.26947	validation_1-rmse:0.56564
# [13]	validation_0-rmse:0.26240	validation_1-rmse:0.55750
# [14]	validation_0-rmse:0.25721	validation_1-rmse:0.55738
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:0.25288	validation_1-rmse:0.54958
# [16]	validation_0-rmse:0.23806	validation_1-rmse:0.57702
# [17]	validation_0-rmse:0.23238	validation_1-rmse:0.58012
# [18]	validation_0-rmse:0.23172	validation_1-rmse:0.58148
# [19]	validation_0-rmse:0.23197	validation_1-rmse:0.58085
# [20]	validation_0-rmse:0.22692	validation_1-rmse:0.56950
# [21]	validation_0-rmse:0.22655	validation_1-rmse:0.57064
# [22]	validation_0-rmse:0.22002	validation_1-rmse:0.58647
# [23]	validation_0-rmse:0.22009	validation_1-rmse:0.58606
# [24]	validation_0-rmse:0.22013	validation_1-rmse:0.58582
# [25]	validation_0-rmse:0.22004	validation_1-rmse:0.58631
# [26]	validation_0-rmse:0.22046	validation_1-rmse:0.58472
# [27]	validation_0-rmse:0.21894	validation_1-rmse:0.58357
# [28]	validation_0-rmse:0.21866	validation_1-rmse:0.58491
# [29]	validation_0-rmse:0.21864	validation_1-rmse:0.58507
# [30]	validation_0-rmse:0.21864	validation_1-rmse:0.58508
# [31]	validation_0-rmse:0.21870	validation_1-rmse:0.58457
# [32]	validation_0-rmse:0.21877	validation_1-rmse:0.58418
# [33]	validation_0-rmse:0.21868	validation_1-rmse:0.58467
# [34]	validation_0-rmse:0.21865	validation_1-rmse:0.58494
# [35]	validation_0-rmse:0.21548	validation_1-rmse:0.58805
# [0]	validation_0-rmse:3.38716	validation_1-rmse:3.42336
# [1]	validation_0-rmse:2.49958	validation_1-rmse:2.58460
# [2]	validation_0-rmse:1.84564	validation_1-rmse:1.93806
# [3]	validation_0-rmse:1.36955	validation_1-rmse:1.47728
# [4]	validation_0-rmse:1.04131	validation_1-rmse:1.16390
# [5]	validation_0-rmse:0.79725	validation_1-rmse:0.94478
# [6]	validation_0-rmse:0.61418	validation_1-rmse:0.80051
# [7]	validation_0-rmse:0.49807	validation_1-rmse:0.69152
# [8]	validation_0-rmse:0.41464	validation_1-rmse:0.62811
# [9]	validation_0-rmse:0.36117	validation_1-rmse:0.58528
# [10]	validation_0-rmse:0.33116	validation_1-rmse:0.55873
# [11]	validation_0-rmse:0.30361	validation_1-rmse:0.53979
# [12]	validation_0-rmse:0.29318	validation_1-rmse:0.53025
# [13]	validation_0-rmse:0.27888	validation_1-rmse:0.52759
# [14]	validation_0-rmse:0.27275	validation_1-rmse:0.52674
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:0.26673	validation_1-rmse:0.53074
# [16]	validation_0-rmse:0.25943	validation_1-rmse:0.53733
# [17]	validation_0-rmse:0.25457	validation_1-rmse:0.52028
# [18]	validation_0-rmse:0.25388	validation_1-rmse:0.52126
# [19]	validation_0-rmse:0.25393	validation_1-rmse:0.51732
# [20]	validation_0-rmse:0.25219	validation_1-rmse:0.52173
# [21]	validation_0-rmse:0.24724	validation_1-rmse:0.52829
# [22]	validation_0-rmse:0.24083	validation_1-rmse:0.51545
# [23]	validation_0-rmse:0.24104	validation_1-rmse:0.51296
# [24]	validation_0-rmse:0.23720	validation_1-rmse:0.50754
# [25]	validation_0-rmse:0.23713	validation_1-rmse:0.50794
# [26]	validation_0-rmse:0.23676	validation_1-rmse:0.51090
# [27]	validation_0-rmse:0.23556	validation_1-rmse:0.51865
# [28]	validation_0-rmse:0.23556	validation_1-rmse:0.51854
# [29]	validation_0-rmse:0.23145	validation_1-rmse:0.52310
# [30]	validation_0-rmse:0.22936	validation_1-rmse:0.52055
# [31]	validation_0-rmse:0.22932	validation_1-rmse:0.51997
# [32]	validation_0-rmse:0.22926	validation_1-rmse:0.51874
# [33]	validation_0-rmse:0.22925	validation_1-rmse:0.51862
# [34]	validation_0-rmse:0.22926	validation_1-rmse:0.51877
# [35]	validation_0-rmse:0.22924	validation_1-rmse:0.51797
# [36]	validation_0-rmse:0.22487	validation_1-rmse:0.52435
# [37]	validation_0-rmse:0.22513	validation_1-rmse:0.52734
# [38]	validation_0-rmse:0.22511	validation_1-rmse:0.52715
# [39]	validation_0-rmse:0.22488	validation_1-rmse:0.52463
# [40]	validation_0-rmse:0.22119	validation_1-rmse:0.53376
# [41]	validation_0-rmse:0.22104	validation_1-rmse:0.53216
# [42]	validation_0-rmse:0.22109	validation_1-rmse:0.53279
# [43]	validation_0-rmse:0.22097	validation_1-rmse:0.52915
# [44]	validation_0-rmse:0.22100	validation_1-rmse:0.53148
# [0]	validation_0-rmse:3.38284	validation_1-rmse:3.53387
# [1]	validation_0-rmse:2.47978	validation_1-rmse:2.61534
# [2]	validation_0-rmse:1.83705	validation_1-rmse:1.99159
# [3]	validation_0-rmse:1.37402	validation_1-rmse:1.52345
# [4]	validation_0-rmse:1.04142	validation_1-rmse:1.19292
# [5]	validation_0-rmse:0.81122	validation_1-rmse:0.94546
# [6]	validation_0-rmse:0.64011	validation_1-rmse:0.75601
# [7]	validation_0-rmse:0.51549	validation_1-rmse:0.63136
# [8]	validation_0-rmse:0.43141	validation_1-rmse:0.53027
# [9]	validation_0-rmse:0.37976	validation_1-rmse:0.46169
# [10]	validation_0-rmse:0.34498	validation_1-rmse:0.41266
# [11]	validation_0-rmse:0.32245	validation_1-rmse:0.39263
# [12]	validation_0-rmse:0.31057	validation_1-rmse:0.36756
# [13]	validation_0-rmse:0.29924	validation_1-rmse:0.36276
# [14]	validation_0-rmse:0.27764	validation_1-rmse:0.34312
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:0.25934	validation_1-rmse:0.35010
# [16]	validation_0-rmse:0.25651	validation_1-rmse:0.34735
# [17]	validation_0-rmse:0.24967	validation_1-rmse:0.33595
# [18]	validation_0-rmse:0.24386	validation_1-rmse:0.33599
# [19]	validation_0-rmse:0.24356	validation_1-rmse:0.33518
# [20]	validation_0-rmse:0.24355	validation_1-rmse:0.33515
# [21]	validation_0-rmse:0.24352	validation_1-rmse:0.33503
# [22]	validation_0-rmse:0.24342	validation_1-rmse:0.33436
# [23]	validation_0-rmse:0.24346	validation_1-rmse:0.33475
# [24]	validation_0-rmse:0.24344	validation_1-rmse:0.33458
# [25]	validation_0-rmse:0.23696	validation_1-rmse:0.34651
# [26]	validation_0-rmse:0.23149	validation_1-rmse:0.34721
# [27]	validation_0-rmse:0.22857	validation_1-rmse:0.34087
# [28]	validation_0-rmse:0.22422	validation_1-rmse:0.34589
# [29]	validation_0-rmse:0.22425	validation_1-rmse:0.34609
# [30]	validation_0-rmse:0.22447	validation_1-rmse:0.34652
# [31]	validation_0-rmse:0.21778	validation_1-rmse:0.33712
# [32]	validation_0-rmse:0.21801	validation_1-rmse:0.33681
# [33]	validation_0-rmse:0.21828	validation_1-rmse:0.33670
# [34]	validation_0-rmse:0.21433	validation_1-rmse:0.32518
# [35]	validation_0-rmse:0.21447	validation_1-rmse:0.32496
# [36]	validation_0-rmse:0.21444	validation_1-rmse:0.32500
# [37]	validation_0-rmse:0.21421	validation_1-rmse:0.32562
# [38]	validation_0-rmse:0.21421	validation_1-rmse:0.32576
# [39]	validation_0-rmse:0.21421	validation_1-rmse:0.32560
# [40]	validation_0-rmse:0.21425	validation_1-rmse:0.32540
# [41]	validation_0-rmse:0.21427	validation_1-rmse:0.32532
# [42]	validation_0-rmse:0.21427	validation_1-rmse:0.32531
# [43]	validation_0-rmse:0.21438	validation_1-rmse:0.32509
# [44]	validation_0-rmse:0.21471	validation_1-rmse:0.32475
# [45]	validation_0-rmse:0.21500	validation_1-rmse:0.32460
# [46]	validation_0-rmse:0.21448	validation_1-rmse:0.32495
# [47]	validation_0-rmse:0.21481	validation_1-rmse:0.32591
# [48]	validation_0-rmse:0.21424	validation_1-rmse:0.32609
# [49]	validation_0-rmse:0.21170	validation_1-rmse:0.32516
# [50]	validation_0-rmse:0.21183	validation_1-rmse:0.32489
# [51]	validation_0-rmse:0.21186	validation_1-rmse:0.32485
# [52]	validation_0-rmse:0.21170	validation_1-rmse:0.32515
# [53]	validation_0-rmse:0.21167	validation_1-rmse:0.32551
# [54]	validation_0-rmse:0.21168	validation_1-rmse:0.32528
# [55]	validation_0-rmse:0.21181	validation_1-rmse:0.32492
# [56]	validation_0-rmse:0.21174	validation_1-rmse:0.32505
# [57]	validation_0-rmse:0.21179	validation_1-rmse:0.32495
# [58]	validation_0-rmse:0.21169	validation_1-rmse:0.32521
# [59]	validation_0-rmse:0.21168	validation_1-rmse:0.32526
# [60]	validation_0-rmse:0.21169	validation_1-rmse:0.32518
# [61]	validation_0-rmse:0.21167	validation_1-rmse:0.32536
# [62]	validation_0-rmse:0.21169	validation_1-rmse:0.32520
# [63]	validation_0-rmse:0.21167	validation_1-rmse:0.32534
# [64]	validation_0-rmse:0.21167	validation_1-rmse:0.32558
# [65]	validation_0-rmse:0.21169	validation_1-rmse:0.32569
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 25.98, median: 21.5,
#  pred. interval (P(0.025)-P(0.975)): 10.0-63.025,
#  conf. interval (p-value=0.95): 17.79-29.644
# ***
# Aggregate bias statistic:
#  mean: -0.422, median: -0.474,
#  pred. interval (P(0.025)-P(0.975)): -3.897-3.183,
#  conf. interval (p-value=0.95): -1.254-0.354
# ***
# Aggregate RMSE statistic:
#  mean: 0.416, median: 0.403, pred. interval (P(0.025)-P(0.975)): 0.237-0.671,
#  conf. interval (p-value=0.95): 0.364-0.454
# ***
# Aggregate MSE statistic:
#  mean: 0.185, median: 0.162, pred. interval (P(0.025)-P(0.975)): 0.056-0.451,
#  conf. interval (p-value=0.95): 0.135-0.21
# ***
# Aggregate R^2 statistic:
#  mean: 0.881, median: 0.89, pred. interval (P(0.025)-P(0.975)): 0.716-0.966,
#  conf. interval (p-value=0.95): 0.866-0.91
# ***
# Aggregate bias(%) statistic:
#  mean: -0.08, median: -0.474, pred. interval (P(0.025)-P(0.975)): -0.783-0.687,
#  conf. interval (p-value=0.95): -0.243-0.072
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.084, median: 0.08, pred. interval (P(0.025)-P(0.975)): 0.046-0.137,
#  conf. interval (p-value=0.95): 0.072-0.092
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:3.40573
# [1]	validation_0-rmse:2.50610
# [2]	validation_0-rmse:1.85665
# [3]	validation_0-rmse:1.37789
# [4]	validation_0-rmse:1.03201
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:0.78542
# [6]	validation_0-rmse:0.60609
# [7]	validation_0-rmse:0.48775
# [8]	validation_0-rmse:0.40643
# [9]	validation_0-rmse:0.34629
# [10]	validation_0-rmse:0.30987
# [11]	validation_0-rmse:0.29283
# [12]	validation_0-rmse:0.27977
# [13]	validation_0-rmse:0.26578
# [14]	validation_0-rmse:0.25909
# [15]	validation_0-rmse:0.25053
# [16]	validation_0-rmse:0.24487
# [17]	validation_0-rmse:0.24226
# [18]	validation_0-rmse:0.23629
# [19]	validation_0-rmse:0.22418
# [20]	validation_0-rmse:0.22412
# [21]	validation_0-rmse:0.22408
# [22]	validation_0-rmse:0.22398
# [23]	validation_0-rmse:0.22399
# [24]	validation_0-rmse:0.22400
# [25]	validation_0-rmse:0.22000
# [26]	validation_0-rmse:0.21551
# [27]	validation_0-rmse:0.21291
# [28]	validation_0-rmse:0.21158
# [29]	validation_0-rmse:0.21156
# [30]	validation_0-rmse:0.21148
# [31]	validation_0-rmse:0.21145
# [32]	validation_0-rmse:0.21152
# [33]	validation_0-rmse:0.20561
# [34]	validation_0-rmse:0.20563
# [35]	validation_0-rmse:0.20561
# [36]	validation_0-rmse:0.20562
# [37]	validation_0-rmse:0.20572
# [38]	validation_0-rmse:0.20577
# [39]	validation_0-rmse:0.20569
# [40]	validation_0-rmse:0.20573
# [41]	validation_0-rmse:0.20569
# [42]	validation_0-rmse:0.20561
# [43]	validation_0-rmse:0.20235
# [44]	validation_0-rmse:0.20233
# [45]	validation_0-rmse:0.20225
# [46]	validation_0-rmse:0.20221
# [47]	validation_0-rmse:0.20229
# [48]	validation_0-rmse:0.20222
# [49]	validation_0-rmse:0.19897
# [50]	validation_0-rmse:0.19912
# [51]	validation_0-rmse:0.19923
# [52]	validation_0-rmse:0.19905
# [53]	validation_0-rmse:0.19887
# [54]	validation_0-rmse:0.19885
# [55]	validation_0-rmse:0.19917
# [56]	validation_0-rmse:0.19896
# [57]	validation_0-rmse:0.19886
# [58]	validation_0-rmse:0.19879
# [59]	validation_0-rmse:0.19879
# [60]	validation_0-rmse:0.19885
# [61]	validation_0-rmse:0.19885
# [62]	validation_0-rmse:0.19889
# [63]	validation_0-rmse:0.19901
# [64]	validation_0-rmse:0.19883
# [65]	validation_0-rmse:0.19881
# [66]	validation_0-rmse:0.19879
# [67]	validation_0-rmse:0.19898
# [68]	validation_0-rmse:0.19885
# [69]	validation_0-rmse:0.19559
# [70]	validation_0-rmse:0.19567
# [71]	validation_0-rmse:0.19567
# [72]	validation_0-rmse:0.19563
# [73]	validation_0-rmse:0.19555
# [74]	validation_0-rmse:0.19554
# [75]	validation_0-rmse:0.19554
# [76]	validation_0-rmse:0.19554
# [77]	validation_0-rmse:0.19556
# [78]	validation_0-rmse:0.19562
# [79]	validation_0-rmse:0.19556
# [80]	validation_0-rmse:0.19558
# [81]	validation_0-rmse:0.19555
# [82]	validation_0-rmse:0.19554
# [83]	validation_0-rmse:0.19560
# [84]	validation_0-rmse:0.19570
# [85]	validation_0-rmse:0.19197
# [86]	validation_0-rmse:0.19199
# [87]	validation_0-rmse:0.19200
# [88]	validation_0-rmse:0.19199
# [89]	validation_0-rmse:0.19198
# [90]	validation_0-rmse:0.19204
# [91]	validation_0-rmse:0.19205
# [92]	validation_0-rmse:0.19197
# [93]	validation_0-rmse:0.19197
# [94]	validation_0-rmse:0.19198
# [95]	validation_0-rmse:0.19201
# [96]	validation_0-rmse:0.19203
# [97]	validation_0-rmse:0.19205
# [98]	validation_0-rmse:0.19212
# [99]	validation_0-rmse:0.19208
# [100]	validation_0-rmse:0.19214
# [101]	validation_0-rmse:0.19201
# [102]	validation_0-rmse:0.19197
# [103]	validation_0-rmse:0.19198
# [104]	validation_0-rmse:0.18878
# [105]	validation_0-rmse:0.18878
# [106]	validation_0-rmse:0.18880
# [107]	validation_0-rmse:0.18878
# [108]	validation_0-rmse:0.18878
# [109]	validation_0-rmse:0.18878
# [110]	validation_0-rmse:0.18880
# [111]	validation_0-rmse:0.18878
# [112]	validation_0-rmse:0.18879
# [113]	validation_0-rmse:0.18883
# [114]	validation_0-rmse:0.18881
# [115]	validation_0-rmse:0.18883
# [116]	validation_0-rmse:0.18880
# [117]	validation_0-rmse:0.18881
# [118]	validation_0-rmse:0.18878
# [119]	validation_0-rmse:0.18878
# [120]	validation_0-rmse:0.18886
# [121]	validation_0-rmse:0.18881
# [122]	validation_0-rmse:0.18884
# [123]	validation_0-rmse:0.18878
# [124]	validation_0-rmse:0.18879
# [125]	validation_0-rmse:0.18895
# [126]	validation_0-rmse:0.18886
# [127]	validation_0-rmse:0.18878
# [128]	validation_0-rmse:0.18879
# [129]	validation_0-rmse:0.18881
# [130]	validation_0-rmse:0.18878
# [131]	validation_0-rmse:0.18879
# [132]	validation_0-rmse:0.18878
# [133]	validation_0-rmse:0.18878
# [134]	validation_0-rmse:0.18878
# [135]	validation_0-rmse:0.18878
# [136]	validation_0-rmse:0.18878
# [137]	validation_0-rmse:0.18881
# [138]	validation_0-rmse:0.18893
# [139]	validation_0-rmse:0.18882
# [140]	validation_0-rmse:0.18878
# [141]	validation_0-rmse:0.18878
# [142]	validation_0-rmse:0.18878
# [143]	validation_0-rmse:0.18878
# [144]	validation_0-rmse:0.18878
# [145]	validation_0-rmse:0.18880
# [146]	validation_0-rmse:0.18880
# [147]	validation_0-rmse:0.18879
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 134

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.00
# RMSE: 0.2
# Relative RMSE(%):  0.038
# MSE: 0.0
# R square: 97.9%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0.001, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.190
# a1: 0.962
# R^2: 0.980
# Uncertainty
# a0: 0.19+/-0.07
# a1: 0.962+/-0.014

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=1) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_GS_XGB_model_with_texture.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_GS_XGB_model_with_texture.txt")
