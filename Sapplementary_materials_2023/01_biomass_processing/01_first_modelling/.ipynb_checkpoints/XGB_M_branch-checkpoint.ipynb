# %% [markdown]
# # Processing with biomass data of other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/1_Estimation of tree biomass/FULL_DB_BIOMASS_OTHER_ALL_AUTHORS.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#    Groups Species  Species_ID Origin  Origin_ID  SI  A_years   H_m  DBH_cm  \
# 0       1    Pine           0      n        0.0   4       50   9.7    14.6
# 1       1    Pine           0      n        0.0   2       65  20.6    20.6
# 2       1    Pine           0      n        0.0   2       50  13.6    15.4
# 3       1    Pine           0      n        0.0   1       60  23.3    22.2
# 4       1    Pine           0      n        0.0   3       65  15.6    16.4
#
#    N_trees  RS(P)  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  Stem_wood_t_ha  \
# 0    486.0   0.35         9.7      43.9           18.9             NaN
# 1    785.0   0.70        32.2     254.0          113.1             NaN
# 2   1745.0   0.93        35.2     190.0           87.8             NaN
# 3    665.0   0.62        29.6     277.7          106.5             NaN
# 4    955.0   0.59        20.4     142.5           67.0             NaN
#
#    Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha
# 0             NaN         8.4           1.6
# 1             NaN        11.5           4.1
# 2             NaN        13.7           4.1
# 3             NaN        14.4           5.4
# 4             NaN        14.2           3.4

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['Groups','Species_ID','Origin_ID','SI','A_years','H_m','DBH_cm','RS(P)',
                                    'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
                                    'Crown_t_ha','Foliage_t_ha'])
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Groups  Species_ID  Origin_ID  SI  A_years   H_m  DBH_cm  RS(P)  \
# 0       1           0        0.0   4       50   9.7    14.6   0.35
# 1       1           0        0.0   2       65  20.6    20.6   0.70
# 2       1           0        0.0   2       50  13.6    15.4   0.93
# 3       1           0        0.0   1       60  23.3    22.2   0.62
# 4       1           0        0.0   3       65  15.6    16.4   0.59
#
#    BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  \
# 0         9.7      43.9           18.9             NaN             NaN
# 1        32.2     254.0          113.1             NaN             NaN
# 2        35.2     190.0           87.8             NaN             NaN
# 3        29.6     277.7          106.5             NaN             NaN
# 4        20.4     142.5           67.0             NaN             NaN
#
#    Crown_t_ha  Foliage_t_ha
# 0         8.4           1.6
# 1        11.5           4.1
# 2        13.7           4.1
# 3        14.4           5.4
# 4        14.2           3.4

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Groups          857 non-null    int64
#  1   Species_ID      857 non-null    int64
#  2   Origin_ID       856 non-null    float64
#  3   SI              857 non-null    int64
#  4   A_years         857 non-null    int64
#  5   H_m             857 non-null    float64
#  6   DBH_cm          856 non-null    float64
#  7   RS(P)           854 non-null    float64
#  8   BA_sq_m_ha      857 non-null    float64
#  9   GS_cub_m        857 non-null    float64
#  10  ALL_STEM_t_ha   855 non-null    float64
#  11  Stem_wood_t_ha  747 non-null    float64
#  12  Stem_bark_t_ha  747 non-null    float64
#  13  Crown_t_ha      843 non-null    float64
#  14  Foliage_t_ha    854 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 100.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species","Origin"])["BA_sq_m_ha","H_m"].describe()
# Out:
# <ipython-input-5-aaa965077f06>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Species","Origin"])["BA_sq_m_ha","H_m"].describe()
#                BA_sq_m_ha                                                     \
#                     count       mean        std   min     25%    50%     75%
# Species Origin
# Alder   a            11.0  27.854545   7.162173  20.6  22.050  28.70  31.250
#         n           104.0  26.243269   9.595284   7.3  18.400  25.65  34.100
# Aspen   n            66.0  23.056061   8.684011   6.9  16.550  20.65  28.125
# Birch   a            29.0  21.127586   8.611201   4.4  12.900  21.90  24.700
#         n            90.0  17.817778   7.397397   3.8  12.150  18.35  23.050
# Oak     a             4.0  25.325000   8.932105  17.8  18.475  23.35  30.200
#         n            87.0  27.529885  10.769446   1.7  20.350  30.10  36.300
# Pine    a           195.0  30.469231  10.685416   4.7  23.250  31.10  38.200
#         n           263.0  27.171863  10.774800   1.0  20.500  28.90  35.000
# Spruce  n             7.0  25.028571   7.756656  15.5  18.050  26.80  31.350
#
#                         H_m                                                   \
#                  max  count       mean       std   min     25%    50%    75%
# Species Origin
# Alder   a       43.4   11.0  20.236364  4.157950  15.4  16.000  21.00  22.90
#         n       43.0  104.0  17.056731  4.874339   5.2  13.100  17.40  20.50
# Aspen   n       48.9   66.0  15.024242  6.264161   2.7  10.325  15.30  19.30
# Birch   a       46.3   29.0  16.320690  7.002162   3.6   9.900  19.40  21.20
#         n       36.5   90.0  14.726667  5.990551   5.8   9.200  14.25  19.35
# Oak     a       36.8    4.0  19.350000  4.792703  13.6  16.900  19.40  21.85
#         n       48.1   87.0  20.870115  7.211427   5.0  15.800  21.60  26.00
# Pine    a       51.5  195.0  16.259487  7.553524   3.5  10.350  15.10  21.95
#         n       51.1  263.0  15.555513  7.296750   1.5  10.700  15.20  20.10
# Spruce  n       34.1    7.0  19.357143  8.967507   8.8  12.150  19.40  24.90
#
#
#                  max
# Species Origin
# Alder   a       27.3
#         n       27.3
# Aspen   n       26.0
# Birch   a       26.5
#         n       27.5
# Oak     a       25.0
#         n       33.8
# Pine    a       34.2
#         n       38.3
# Spruce  n       33.2

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = ["Crown_t_ha"], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      Groups  Species_ID  Origin_ID  SI  A_years   H_m  DBH_cm  RS(P)  \
# 0         1           0        0.0   4       50   9.7    14.6   0.35
# 1         1           0        0.0   2       65  20.6    20.6   0.70
# 2         1           0        0.0   2       50  13.6    15.4   0.93
# 3         1           0        0.0   1       60  23.3    22.2   0.62
# 4         1           0        0.0   3       65  15.6    16.4   0.59
# ..      ...         ...        ...  ..      ...   ...     ...    ...
# 852       2           3        0.0   0        8   7.8     4.4   0.71
# 853       2           3        0.0   0       16  12.7     9.0   0.97
# 854       2           3        0.0   0       15  12.2     8.1   0.99
# 855       2           2        0.0   2       21  14.3    12.4   1.08
# 856       2           2        0.0   1       66  21.1    25.6   0.71
#
#      BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  \
# 0           9.7      43.9           18.9             NaN             NaN
# 1          32.2     254.0          113.1             NaN             NaN
# 2          35.2     190.0           87.8             NaN             NaN
# 3          29.6     277.7          106.5             NaN             NaN
# 4          20.4     142.5           67.0             NaN             NaN
# ..          ...       ...            ...             ...             ...
# 852         9.2      39.8           17.8            15.7             2.1
# 853        20.5     123.6           47.1            42.6             4.5
# 854        20.3     141.7           51.9            47.8             4.1
# 855        25.1     176.5          100.7            84.6            16.1
# 856        21.0     191.6           99.9            80.8            19.1
#
#      Crown_t_ha  Foliage_t_ha
# 0          8.40          1.60
# 1         11.50          4.10
# 2         13.70          4.10
# 3         14.40          5.40
# 4         14.20          3.40
# ..          ...           ...
# 852        2.26          2.04
# 853        2.14          1.21
# 854        2.11          1.16
# 855       16.90          4.74
# 856       16.60          2.13
#
# [843 rows x 15 columns]

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#            Groups  Species_ID   Origin_ID          SI     A_years         H_m  \
# count  843.000000  843.000000  842.000000  843.000000  843.000000  843.000000
# mean     1.379597    1.549229    0.281473    0.837485   45.297746   16.498695
# std      0.485575    1.825104    0.449985    1.643650   33.253512    7.034373
# min      1.000000    0.000000    0.000000   -4.000000    2.000000    1.500000
# 25%      1.000000    0.000000    0.000000    0.000000   23.000000   11.300000
# 50%      1.000000    0.000000    0.000000    1.000000   37.000000   16.200000
# 75%      2.000000    3.000000    1.000000    2.000000   58.000000   21.150000
# max      2.000000    5.000000    1.000000    7.000000  250.000000   38.300000
#
#            DBH_cm       RS(P)  BA_sq_m_ha    GS_cub_m  ALL_STEM_t_ha  \
# count  842.000000  840.000000  843.000000  843.000000     842.000000
# mean    17.188836    0.885012   26.403084  230.015540     103.002375
# std     10.477019    0.289854   10.643571  144.417588      68.743007
# min      1.100000    0.180000    1.000000    2.400000       1.800000
# 25%      9.900000    0.717500   19.050000  116.750000      48.425000
# 50%     15.600000    0.870000   27.000000  207.000000      93.500000
# 75%     22.100000    1.000000   34.550000  320.300000     140.500000
# max     94.000000    2.320000   51.500000  735.000000     363.900000
#
#        Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha
# count      745.000000      745.000000  843.000000    843.000000
# mean        92.682819       12.046040   13.821969      4.768944
# std         61.937108        9.587207   11.567546      2.835636
# min          2.000000        0.300000    0.500000      0.200000
# 25%         42.600000        5.900000    6.610000      2.600000
# 50%         84.600000        9.300000   10.820000      4.320000
# 75%        125.500000       15.300000   16.435000      6.385000
# max        315.200000       65.700000   69.120000     21.730000

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['Species_ID','Origin_ID','H_m','DBH_cm','BA_sq_m_ha'])
y = pd.DataFrame(select, columns= ['Crown_t_ha'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_value = np.random.normal(10, 2, size=count)
    X['Random_col'] = norm_value
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha
# 0           0        0.0   9.7    14.6         9.7
# 1           0        0.0  20.6    20.6        32.2
# 2           0        0.0  13.6    15.4        35.2
# 3           0        0.0  23.3    22.2        29.6
# 4           0        0.0  15.6    16.4        20.4

# %%
# Columns in "y" data collections
y.head()
# Out:
#    Crown_t_ha
# 0         8.4
# 1        11.5
# 2        13.7
# 3        14.4
# 4        14.2

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=4, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.6751316731998337, 0.7985178767838571, 0.6595751881613912, 0.7613325848584621]
#     Mean: 0.724
#     Std: 0.058
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [6.59350267 4.63007062 6.00195897 5.29448987]
#     Mean: 5.630
#     Std: 0.738
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [3.2459983627830074, 3.7238155386685197, 3.758745101707241, 3.5897761823563346]
#     Mean: 3.580
#     Std: 0.203
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=5000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y, eval_metric="rmse")

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 5000 candidates, totalling 25000 fits
# Model with rank: 1
# Mean validation score: 0.540 (std: 0.252)
# Parameters: {'colsample_bytree': 0.7848716719102183, 'gamma': 0.4866695626319013, 'learning_rate': 0.2038298608008555, 'max_depth': 4, 'n_estimators': 172, 'subsample': 0.8630421607056131}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.55432253, 0.64187489, 0.48190441, ..., 0.39516635, 0.46289368,
#        0.50303173]), 'std_fit_time': array([0.02454107, 0.02229551, 0.00309726, ..., 0.01188175, 0.06126196,
#        0.10875442]), 'mean_score_time': array([0.01025004, 0.01036773, 0.01062183, ..., 0.01094222, 0.01092076,
#        0.01117482]), 'std_score_time': array([1.83016375e-04, 7.94320542e-05, 1.66181232e-04, ...,
#        6.17705684e-05, 6.59833056e-05, 3.74803106e-05]), 'param_colsample_bytree': masked_array(data=[0.4651569404413889, 0.30122827149662473,
#                    0.9233505192402007, ..., 0.9491450235284036,
#                    0.32180528537768804, 0.8795740363752246],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.2372973461199871, 0.47762586428847775,
#                    0.14808000907435465, ..., 0.4304797974754092,
#                    0.2000296127183281, 0.07583732688259887],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.1860510082673242, 0.03440676410351101,
#                    0.044629270012362644, ..., 0.1905923668630594,
#                    0.01807602433551755, 0.12413404598606523],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[2, 4, 2, ..., 4, 4, 4],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[170, 190, 142, ..., 99, 118, 112],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.8263998615698704, 0.6900995787562338,
#                    0.9875665185946525, ..., 0.844371042383739,
#                    0.928635382138504, 0.6409974329519188],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.4651569404413889, 'gamma': 0.2372973461199871, 'learning_rate': 0.1860510082673242, 'max_depth': 2, 'n_estimators': 170, 'subsample': 0.8263998615698704}, {'colsample_bytree': 0.30122827149662473, 'gamma': 0.47762586428847775, 'learning_rate': 0.03440676410351101, 'max_depth': 4, 'n_estimators': 190, 'subsample': 0.6900995787562338}, {'colsample_bytree': 0.9233505192402007, 'gamma': 0.14808000907435465, 'learning_rate': 0.044629270012362644, 'max_depth': 2, 'n_estimators': 142, 'subsample': 0.9875665185946525}, {'colsample_bytree': 0.6447468290123687, 'gamma': 0.3396867534353868, 'learning_rate': 0.08513867186565881, 'max_depth': 4, 'n_estimators': 60, 'subsample': 0.7426542945248327}, {'colsample_bytree': 0.39890871760669855, 'gamma': 0.0876470163291303, 'learning_rate': 0.12725741615115904, 'max_depth': 3, 'n_estimators': 104, 'subsample': 0.7514824797183596}, {'colsample_bytree': 0.4269538301880645, 'gamma': 0.18829030906897642, 'learning_rate': 0.03560104120295713, 'max_depth': 2, 'n_estimators': 131, 'subsample': 0.8500143710344477}, {'colsample_bytree': 0.5897337431229399, 'gamma': 0.293640564795215, 'learning_rate': 0.18787275697410777, 'max_depth': 3, 'n_estimators': 159, 'subsample': 0.9770731503174295}, {'colsample_bytree': 0.6897277023581377, 'gamma': 0.18728121783913187, 'learning_rate': 0.0977060606912869, 'max_depth': 4, 'n_estimators': 157, 'subsample': 0.7371820463405088}, {'colsample_bytree': 0.18392026677531248, 'gamma': 0.16107199039120462, 'learning_rate': 0.05981096271306561, 'max_depth': 3, 'n_estimators': 139, 'subsample': 0.5788940360210506}, {'colsample_bytree': 0.6222029738264341, 'gamma': 0.4916274773910138, 'learning_rate': 0.09181335363238204, 'max_depth': 2, 'n_estimators': 97, 'subsample': 0.5627151546039464}, {'colsample_bytree': 0.33747222095176727, 'gamma': 0.452852210247253, 'learning_rate': 0.17716232859325143, 'max_depth': 2, 'n_estimators': 56, 'subsample': 0.45018110918962856}, {'colsample_bytree': 0.7792128778114892, 'gamma': 0.48212699872903514, 'learning_rate': 0.028957705156002947, 'max_depth': 2, 'n_estimators': 94, 'subsample': 0.6978690835133883}, {'colsample_bytree': 0.6015318920513523, 'gamma': 0.17790817799459713, 'learning_rate': 0.20847364393858, 'max_depth': 3, 'n_estimators': 144, 'subsample': 0.4064611812083785}, {'colsample_bytree': 0.0678632005899184, 'gamma': 0.19240601120919493, 'learning_rate': 0.014032739407369467, 'max_depth': 3, 'n_estimators': 148, 'subsample': 0.8358375446749653}, {'colsample_bytree': 0.32891995032306187, 'gamma': 0.03187460494297589, 'learning_rate': 0.2886359695852786, 'max_depth': 3, 'n_estimators': 115, 'subsample': 0.3495081706732355}, {'colsample_bytree': 0.9457032931218579, 'gamma': 0.26908586469606566, 'learning_rate': 0.13069313601228455, 'max_depth': 3, 'n_estimators': 141, 'subsample': 0.9390608858378451}, {'colsample_bytree': 0.8945532724349263, 'gamma': 0.0644295269765433, 'learning_rate': 0.06193739853815723, 'max_depth': 3, 'n_estimators': 116, 'subsample': 0.5647437626166234}, {'colsample_bytree': 0.26276296409770616, 'gamma': 0.19379261656241165, 'learning_rate': 0.19143790571995095, 'max_depth': 3, 'n_estimators': 122, 'subsample': 0.7688001713597399}, {'colsample_bytree': 0.4494352838229029, 'gamma': 0.2984020562152407, 'learning_rate': 0.17657252956390082, 'max_depth': 3, 'n_estimators': 197, 'subsample': 0.5510123141074792}, {'colsample_bytree': 0.5680927302738797, 'gamma': 0.1865293353851321, 'learning_rate': 0.1143735905230529, 'max_depth': 2, 'n_estimators': 56, 'subsample': 0.35737376874386756}, {'colsample_bytree': 0.6279145770386343, 'gamma': 0.2019799703236536, 'learning_rate': 0.13924381995061483, 'max_depth': 2, 'n_estimators': 192, 'subsample': 0.9677310889694244}, {'colsample_bytree': 0.8065926623454859, 'gamma': 0.17252200589304284, 'learning_rate': 0.20015733763763743, 'max_depth': 3, 'n_estimators': 76, 'subsample': 0.9858056204467995}, {'colsample_bytr ...
#        0.7300134 ]), 'split1_test_score': array([0.69119838, 0.52760275, 0.66782719, ..., 0.74183162, 0.36530398,
#        0.75016688]), 'split2_test_score': array([0.39450313, 0.47302003, 0.36082711, ..., 0.33663935, 0.42702086,
#        0.3383779 ]), 'split3_test_score': array([-0.07977573, -1.21404092, -0.25335802, ..., -0.0090355 ,
#        -0.4412592 , -0.0078762 ]), 'split4_test_score': array([0.62364513, 0.47548424, 0.55312375, ..., 0.69288791, 0.36084408,
#        0.65941615]), 'mean_test_score': array([0.4776851 , 0.14827997, 0.41962021, ..., 0.49642283, 0.17763161,
#        0.49401963]), 'std_test_score': array([0.30450955, 0.68145716, 0.36285777, ..., 0.29316757, 0.32062765,
#        0.29147358]), 'rank_test_score': array([ 561, 4098, 2175, ...,  225, 3378,  261], dtype=int32), 'split0_train_score': array([0.81155441, 0.66381832, 0.68361209, ..., 0.94219731, 0.43884041,
#        0.91027732]), 'split1_train_score': array([0.87280443, 0.74388779, 0.79247193, ..., 0.96188691, 0.52976876,
#        0.94589793]), 'split2_train_score': array([0.896652  , 0.76515332, 0.81548393, ..., 0.97077336, 0.55393339,
#        0.95809152]), 'split3_train_score': array([0.90904758, 0.81516931, 0.81134656, ..., 0.97100493, 0.64509955,
#        0.95344776]), 'split4_train_score': array([0.88856194, 0.7764758 , 0.8025018 , ..., 0.96356473, 0.58660042,
#        0.94676985]), 'mean_train_score': array([0.87572407, 0.75290091, 0.78108326, ..., 0.96188545, 0.5508485 ,
#        0.94289688]), 'std_train_score': array([0.0341746 , 0.05019999, 0.04937278, ..., 0.01051288, 0.06806048,
#        0.01691295])}

# %%
# Overwrite parameter data for the next step/stage
p1 = 0.7848716719102183     # colsample_bytree 
p2 = 0.4866695626319013    # gamma
p3 = 0.2038298608008555    # learning_rate
p4 = 4                      # max_depth
p5 = 172                    # n_estimators
p6 = 0.8630421607056131     # subsample

# %% [markdown]
# # Creating a basic XGBoost model

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Generate test and training samples
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Implementation of the scikit-learn API for XGBoost regression
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Show all parameters of XGBoost model
print(xgb_model)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.7848716719102183,
#              enable_categorical=False, eval_metric=['rmse'],
#              gamma=0.4866695626319013, gpu_id=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2038298608008555,
#              max_delta_step=None, max_depth=4, min_child_weight=None,
#              missing=nan, monotone_constraints=None, n_estimators=172,
#              n_jobs=None, num_parallel_tree=None, predictor=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=0.8630421607056131,
#              tree_method=None, validate_parameters=None, verbosity=None)

# %%
# Fitting the model 
xgb_model.fit(X_train, y_train, early_stopping_rounds=100, eval_set=[(X_train, y_train), (X_test, y_test)])
# learning dynamics
y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:14.70907	validation_1-rmse:14.62273
# [1]	validation_0-rmse:12.48356	validation_1-rmse:12.51222
# [2]	validation_0-rmse:10.84709	validation_1-rmse:10.92089
# [3]	validation_0-rmse:9.44151	validation_1-rmse:9.55719
# [4]	validation_0-rmse:8.43515	validation_1-rmse:8.55171
# [5]	validation_0-rmse:7.44749	validation_1-rmse:7.55128
# [6]	validation_0-rmse:6.80858	validation_1-rmse:6.88302
# [7]	validation_0-rmse:6.32459	validation_1-rmse:6.28599
# [8]	validation_0-rmse:5.96717	validation_1-rmse:5.89337
# [9]	validation_0-rmse:5.69034	validation_1-rmse:5.59109
# [10]	validation_0-rmse:5.52722	validation_1-rmse:5.46124
# [11]	validation_0-rmse:5.36937	validation_1-rmse:5.36126
# [12]	validation_0-rmse:5.25566	validation_1-rmse:5.22701
# [13]	validation_0-rmse:5.17251	validation_1-rmse:5.21159
# [14]	validation_0-rmse:5.11715	validation_1-rmse:5.12369
# [15]	validation_0-rmse:5.05086	validation_1-rmse:5.09773
# [16]	validation_0-rmse:4.98315	validation_1-rmse:5.04055
# [17]	validation_0-rmse:4.93185	validation_1-rmse:4.99424
# [18]	validation_0-rmse:4.87430	validation_1-rmse:4.96776
# [19]	validation_0-rmse:4.81393	validation_1-rmse:4.96425
# [20]	validation_0-rmse:4.77907	validation_1-rmse:4.97604
# [21]	validation_0-rmse:4.72838	validation_1-rmse:4.94582
# [22]	validation_0-rmse:4.59734	validation_1-rmse:4.80060
# [23]	validation_0-rmse:4.46652	validation_1-rmse:4.76262
# [24]	validation_0-rmse:4.40943	validation_1-rmse:4.70804
# [25]	validation_0-rmse:4.38780	validation_1-rmse:4.68769
# [26]	validation_0-rmse:4.31402	validation_1-rmse:4.66136
# [27]	validation_0-rmse:4.25298	validation_1-rmse:4.65318
# [28]	validation_0-rmse:4.18429	validation_1-rmse:4.60107
# [29]	validation_0-rmse:4.10007	validation_1-rmse:4.56243
# [30]	validation_0-rmse:4.04581	validation_1-rmse:4.56897
# [31]	validation_0-rmse:3.95783	validation_1-rmse:4.53912
# [32]	validation_0-rmse:3.90848	validation_1-rmse:4.51414
# [33]	validation_0-rmse:3.86911	validation_1-rmse:4.51536
# [34]	validation_0-rmse:3.83785	validation_1-rmse:4.52209
# [35]	validation_0-rmse:3.76973	validation_1-rmse:4.48559
# [36]	validation_0-rmse:3.74520	validation_1-rmse:4.49018
# [37]	validation_0-rmse:3.71426	validation_1-rmse:4.49751
# [38]	validation_0-rmse:3.68050	validation_1-rmse:4.49350
# [39]	validation_0-rmse:3.63468	validation_1-rmse:4.49409
# [40]	validation_0-rmse:3.58946	validation_1-rmse:4.51884
# [41]	validation_0-rmse:3.56536	validation_1-rmse:4.52521
# [42]	validation_0-rmse:3.51310	validation_1-rmse:4.51015
# [43]	validation_0-rmse:3.48757	validation_1-rmse:4.51232
# [44]	validation_0-rmse:3.45812	validation_1-rmse:4.51170
# [45]	validation_0-rmse:3.41489	validation_1-rmse:4.51483
# [46]	validation_0-rmse:3.36474	validation_1-rmse:4.51398
# [47]	validation_0-rmse:3.32504	validation_1-rmse:4.50207
# [48]	validation_0-rmse:3.28466	validation_1-rmse:4.51353
# [49]	validation_0-rmse:3.25657	validation_1-rmse:4.52622
# [50]	validation_0-rmse:3.23396	validation_1-rmse:4.52377
# [51]	validation_0-rmse:3.21188	validation_1-rmse:4.53962
# [52]	validation_0-rmse:3.18617	validation_1-rmse:4.50881
# [53]	validation_0-rmse:3.16054	validation_1-rmse:4.53372
# [54]	validation_0-rmse:3.13249	validation_1-rmse:4.52372
# [55]	validation_0-rmse:3.11126	validation_1-rmse:4.52924
# [56]	validation_0-rmse:3.08279	validation_1-rmse:4.50961
# [57]	validation_0-rmse:3.05370	validation_1-rmse:4.50344
# [58]	validation_0-rmse:3.02232	validation_1-rmse:4.51240
# [59]	validation_0-rmse:2.99155	validation_1-rmse:4.49838
# [60]	validation_0-rmse:2.93927	validation_1-rmse:4.45726
# [61]	validation_0-rmse:2.89842	validation_1-rmse:4.45680
# [62]	validation_0-rmse:2.86564	validation_1-rmse:4.42872
# [63]	validation_0-rmse:2.83388	validation_1-rmse:4.41291
# [64]	validation_0-rmse:2.81987	validation_1-rmse:4.40794
# [65]	validation_0-rmse:2.79517	validation_1-rmse:4.41452
# [66]	validation_0-rmse:2.77594	validation_1-rmse:4.41407
# [67]	validation_0-rmse:2.74434	validation_1-rmse:4.41269
# [68]	validation_0-rmse:2.73243	validation_1-rmse:4.42817
# [69]	validation_0-rmse:2.71848	validation_1-rmse:4.41861
# [70]	validation_0-rmse:2.69544	validation_1-rmse:4.42107
# [71]	validation_0-rmse:2.67423	validation_1-rmse:4.41542
# [72]	validation_0-rmse:2.66924	validation_1-rmse:4.42746
# [73]	validation_0-rmse:2.65059	validation_1-rmse:4.43260
# [74]	validation_0-rmse:2.62193	validation_1-rmse:4.43527
# [75]	validation_0-rmse:2.61381	validation_1-rmse:4.42180
# [76]	validation_0-rmse:2.59082	validation_1-rmse:4.45057
# [77]	validation_0-rmse:2.57687	validation_1-rmse:4.42817
# [78]	validation_0-rmse:2.55718	validation_1-rmse:4.43473
# [79]	validation_0-rmse:2.53972	validation_1-rmse:4.44841
# [80]	validation_0-rmse:2.52408	validation_1-rmse:4.45351
# [81]	validation_0-rmse:2.51560	validation_1-rmse:4.45741
# [82]	validation_0-rmse:2.49873	validation_1-rmse:4.44919
# [83]	validation_0-rmse:2.48554	validation_1-rmse:4.45116
# [84]	validation_0-rmse:2.46827	validation_1-rmse:4.45538
# [85]	validation_0-rmse:2.45750	validation_1-rmse:4.45402
# [86]	validation_0-rmse:2.44039	validation_1-rmse:4.45761
# [87]	validation_0-rmse:2.42427	validation_1-rmse:4.46600
# [88]	validation_0-rmse:2.40514	validation_1-rmse:4.45745
# [89]	validation_0-rmse:2.37310	validation_1-rmse:4.44725
# [90]	validation_0-rmse:2.36155	validation_1-rmse:4.44505
# [91]	validation_0-rmse:2.34439	validation_1-rmse:4.46393
# [92]	validation_0-rmse:2.33195	validation_1-rmse:4.47675
# [93]	validation_0-rmse:2.31704	validation_1-rmse:4.47518
# [94]	validation_0-rmse:2.30690	validation_1-rmse:4.47237
# [95]	validation_0-rmse:2.29293	validation_1-rmse:4.48635
# [96]	validation_0-rmse:2.27456	validation_1-rmse:4.46607
# [97]	validation_0-rmse:2.26631	validation_1-rmse:4.46426
# [98]	validation_0-rmse:2.25615	validation_1-rmse:4.46605
# [99]	validation_0-rmse:2.23541	validation_1-rmse:4.44881
# [100]	validation_0-rmse:2.22700	validation_1-rmse:4.44565
# [101]	validation_0-rmse:2.21050	validation_1-rmse:4.44042
# [102]	validation_0-rmse:2.18145	validation_1-rmse:4.44378
# [103]	validation_0-rmse:2.16720	validation_1-rmse:4.42907
# [104]	validation_0-rmse:2.15021	validation_1-rmse:4.42841
# [105]	validation_0-rmse:2.13944	validation_1-rmse:4.43566
# [106]	validation_0-rmse:2.12030	validation_1-rmse:4.44167
# [107]	validation_0-rmse:2.10100	validation_1-rmse:4.44537
# [108]	validation_0-rmse:2.08322	validation_1-rmse:4.45358
# [109]	validation_0-rmse:2.06646	validation_1-rmse:4.47368
# [110]	validation_0-rmse:2.05458	validation_1-rmse:4.48028
# [111]	validation_0-rmse:2.03109	validation_1-rmse:4.46844
# [112]	validation_0-rmse:2.02234	validation_1-rmse:4.46564
# [113]	validation_0-rmse:2.00346	validation_1-rmse:4.47661
# [114]	validation_0-rmse:1.99279	validation_1-rmse:4.47107
# [115]	validation_0-rmse:1.97301	validation_1-rmse:4.47614
# [116]	validation_0-rmse:1.96393	validation_1-rmse:4.48325
# [117]	validation_0-rmse:1.95049	validation_1-rmse:4.49613
# [118]	validation_0-rmse:1.94322	validation_1-rmse:4.51259
# [119]	validation_0-rmse:1.92725	validation_1-rmse:4.51001
# [120]	validation_0-rmse:1.91472	validation_1-rmse:4.50879
# [121]	validation_0-rmse:1.90125	validation_1-rmse:4.50484
# [122]	validation_0-rmse:1.89470	validation_1-rmse:4.49434
# [123]	validation_0-rmse:1.88096	validation_1-rmse:4.49036
# [124]	validation_0-rmse:1.85552	validation_1-rmse:4.50506
# [125]	validation_0-rmse:1.84656	validation_1-rmse:4.50871
# [126]	validation_0-rmse:1.82588	validation_1-rmse:4.50101
# [127]	validation_0-rmse:1.81464	validation_1-rmse:4.49438
# [128]	validation_0-rmse:1.80393	validation_1-rmse:4.51074
# [129]	validation_0-rmse:1.79304	validation_1-rmse:4.50959
# [130]	validation_0-rmse:1.79015	validation_1-rmse:4.50433
# [131]	validation_0-rmse:1.78750	validation_1-rmse:4.50761
# [132]	validation_0-rmse:1.77981	validation_1-rmse:4.51278
# [133]	validation_0-rmse:1.77673	validation_1-rmse:4.51706
# [134]	validation_0-rmse:1.76253	validation_1-rmse:4.51528
# [135]	validation_0-rmse:1.75371	validation_1-rmse:4.51170
# [136]	validation_0-rmse:1.74729	validation_1-rmse:4.51356
# [137]	validation_0-rmse:1.74081	validation_1-rmse:4.50483
# [138]	validation_0-rmse:1.72997	validation_1-rmse:4.50950
# [139]	validation_0-rmse:1.71761	validation_1-rmse:4.51604
# [140]	validation_0-rmse:1.70434	validation_1-rmse:4.51070
# [141]	validation_0-rmse:1.69609	validation_1-rmse:4.51576
# [142]	validation_0-rmse:1.68448	validation_1-rmse:4.51990
# [143]	validation_0-rmse:1.67776	validation_1-rmse:4.52025
# [144]	validation_0-rmse:1.67221	validation_1-rmse:4.52016
# [145]	validation_0-rmse:1.66641	validation_1-rmse:4.51658
# [146]	validation_0-rmse:1.66295	validation_1-rmse:4.51429
# [147]	validation_0-rmse:1.65285	validation_1-rmse:4.51873
# [148]	validation_0-rmse:1.64712	validation_1-rmse:4.51654
# [149]	validation_0-rmse:1.63819	validation_1-rmse:4.51451
# [150]	validation_0-rmse:1.63607	validation_1-rmse:4.51337
# [151]	validation_0-rmse:1.62622	validation_1-rmse:4.52519
# [152]	validation_0-rmse:1.62098	validation_1-rmse:4.52164
# [153]	validation_0-rmse:1.61684	validation_1-rmse:4.52728
# [154]	validation_0-rmse:1.60520	validation_1-rmse:4.52085
# [155]	validation_0-rmse:1.59997	validation_1-rmse:4.51432
# [156]	validation_0-rmse:1.58702	validation_1-rmse:4.52420
# [157]	validation_0-rmse:1.58234	validation_1-rmse:4.52505
# [158]	validation_0-rmse:1.57352	validation_1-rmse:4.52480
# [159]	validation_0-rmse:1.56772	validation_1-rmse:4.53333
# [160]	validation_0-rmse:1.56022	validation_1-rmse:4.54117
# [161]	validation_0-rmse:1.55361	validation_1-rmse:4.54469
# [162]	validation_0-rmse:1.54381	validation_1-rmse:4.55249
# [163]	validation_0-rmse:1.54040	validation_1-rmse:4.56126

# %%
# Iteration with the best result
optimal_n= xgb_model.best_ntree_limit-1
print("The best iteration: " + str(optimal_n))
# Out:
# The best iteration: 64

# %%
# Preparing data for building a learning graph
results = xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(results['validation_0']['rmse'], label='Train')
plt.plot(results['validation_1']['rmse'], label='Test')
plt.axvline(optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a basic XGBoost model

# %%
# Convert data to 'array' type
conv_y_pred = pd.DataFrame(y_pred) # Double transformation
y_pred2 = conv_y_pred.values
y_test2 = y_test.values

# Intermediate results
n_sample = len(y_pred2)
main_sample = y_test.sum() / n_sample

# Calculation of bias
diff = y_pred2 - y_test2
bias = diff.sum()
print('Bias: %.1f' % (bias/n_sample))
print("Relative bias(%):", " %.2f" % (bias/main_sample))

# Calculation of RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %.1f" % (rmse))
print("Relative RMSE(%):", " %.3f" % (rmse/main_sample))

# Calculation of MSE
mse = mean_squared_error(y_test, y_pred)
print("MSE: %.1f" % (mse))

# Calculation of Square R
R_square = r2_score(y_test, y_pred)
print("R square: %.1f%%" % (R_square * 100.0))
# Out:
# Bias: -0.4
# Relative bias(%):  -5.08
# RMSE: 4.4
# Relative RMSE(%):  0.314
# MSE: 19.4
# R square: 84.4%

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(y_test)
x_test_convert = np.array([None]*n_sample)
for i in range(n_sample):
    x_test_convert[i] = np.float(x_test_conv[i])

x_plot = x_test_convert
y_plot = y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 2.701
# a1: 0.778
# R^2: 0.851
# Uncertainty
# a0: 2.7+/-0.5
# a1: 0.778+/-0.025

# %%
# Comparison of training and testing prediction values for XGBoost model 
y_pred_train = xgb_model.predict(X_train, ntree_limit=xgb_model.best_ntree_limit)

plt.figure(figsize =(8, 5))
plt.scatter(y_train, y_pred_train, alpha=0.5, label='Training data')
plt.scatter(y_test, y_pred, s = 5, c = "red", label='Validation (test) data')
plt.xlabel('Obs.')
plt.ylabel('Predict')
plt.legend(loc='best')
# Out:
# /home/dima/anaconda3/lib/python3.8/site-packages/xgboost/core.py:105: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(xgb_model,num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(xgb_model)
shap_values = explainer.shap_values(X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, X_train, color=shap_values)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %% [markdown]
# # Testing model on new data

# %%
# Load new data (typing)
sp = input('Typing species name - Pine, Spruce, Birch, Alder, Aspen or Oak:')
if sp == 'Pine':
    sdID = 0
    print ('You typed "Pine".')
elif sp == 'Spruce':
    sdID = 1
    print ('You typed "Spruce".')
elif sp == 'Birch':
    sdID = 2
    print ('You typed "Birch".')
elif sp == 'Alder':
    sdID = 3
    print ('You typed "Alder".')
elif sp == 'Aspen':
    sdID = 4
    print ('You typed "Aspen".')
elif sp == 'Oak':
    sdID = 5
    print ('You typed "Oak".')
elif sp != 'Pine' or 'Spruce' or 'Birch' or 'Alder' or 'Aspen' or 'Oak':
    print ('No correctly specie name!')
else:
    print('\nTyping mistake!!!')

ori = input('Typing origin: n - nutural, a - artificial:')
if ori == 'n':
    orID = 0
    print ('You typed "n".')
elif ori == 'a':
    orID = 1
    print ('You typed "a".')
else:
    print('\nTyping mistake!!!')
    
dbh = float(input('Typing DBH (cm):'))

h = float(input('Typing H (m):'))

ba = float(input('Typing BA(or G) (sq.m/ha):'))

# Create new dataframe
new_data = []
new_data.append([sdID, orID, h, dbh, ba])
new_X = pd.DataFrame(new_data, columns=['Species_ID', 'Origin_ID', 'H_m', 'DBH_cm', 'BA_sq_m_sq_m'])

# Present the result based on the entered data
y_pred_new = xgb_model.predict(new_X)
out0 = str(y_pred_new)
out = out0[1:6]
print('\n', 20*'-', '\n Output result: ' + out)
# Out:
# Typing species name - Pine, Spruce, Birch, Alder, Aspen or Oak: Pine
# You typed "Pine".
# Typing origin: n - nutural, a - artificial: n
# You typed "n".
# Typing DBH (cm): 30
# Typing H (m): 35
# Typing BA(or G) (sq.m/ha): 50
#  --------------------
#  Output result: 27.79

# %% [markdown]
# # Save XGBoost model

# %%
# Save to JSON
xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/1_Estimation of tree biomass/xgb_model_M_brench.json")
# Save to text format
xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/1_Estimation of tree biomass/xgb_model_M_brench.txt")
