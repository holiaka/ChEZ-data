# %% [markdown]
# ## Processing with aboveground biomass data based on my fieldworks and other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
input_data = './FULL_DB_BIOMASS_OTHER_ALL_AUTHORS.csv'
df = pd.read_csv(input_data)
df.head()
# Out:
#    Groups Species  Species_ID Origin  Origin_ID  SI  A_years   H_m  DBH_cm  \
# 0       1    Pine           0      n        0.0   4       50   9.7    14.6
# 1       1    Pine           0      n        0.0   2       65  20.6    20.6
# 2       1    Pine           0      n        0.0   2       50  13.6    15.4
# 3       1    Pine           0      n        0.0   1       60  23.3    22.2
# 4       1    Pine           0      n        0.0   3       65  15.6    16.4
#
#    N_trees  ...  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  \
# 0    486.0  ...             NaN             NaN         8.4           1.6
# 1    785.0  ...             NaN             NaN        11.5           4.1
# 2   1745.0  ...             NaN             NaN        13.7           4.1
# 3    665.0  ...             NaN             NaN        14.4           5.4
# 4    955.0  ...             NaN             NaN        14.2           3.4
#
#    LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  \
# 0         3.78              2.94                NaN                NaN
# 1         5.54              4.73                NaN                NaN
# 2         5.25              4.48                NaN                NaN
# 3         5.63              4.67                NaN                NaN
# 4         4.96              4.20                NaN                NaN
#
#    LN_Crown_t_ha  LN_Foliage_t_ha
# 0           2.13             0.47
# 1           2.44             1.41
# 2           2.62             1.41
# 3           2.67             1.69
# 4           2.65             1.22
#
# [5 rows x 24 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
#
# 'Groups','Species_ID','Origin_ID','SI','A_years','H_m','DBH_cm','RS(P)',          'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
# 'Crown_t_ha','Foliage_t_ha'
# 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species_ID','Origin_ID','H_m','DBH_cm', 'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
'Crown_t_ha','Foliage_t_ha', 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0           0        0.0   9.7    14.6         9.7      43.9           18.9
# 1           0        0.0  20.6    20.6        32.2     254.0          113.1
# 2           0        0.0  13.6    15.4        35.2     190.0           87.8
# 3           0        0.0  23.3    22.2        29.6     277.7          106.5
# 4           0        0.0  15.6    16.4        20.4     142.5           67.0
#
#    Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0             NaN             NaN         8.4           1.6         3.78
# 1             NaN             NaN        11.5           4.1         5.54
# 2             NaN             NaN        13.7           4.1         5.25
# 3             NaN             NaN        14.4           5.4         5.63
# 4             NaN             NaN        14.2           3.4         4.96
#
#    LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0              2.94                NaN                NaN           2.13
# 1              4.73                NaN                NaN           2.44
# 2              4.48                NaN                NaN           2.62
# 3              4.67                NaN                NaN           2.67
# 4              4.20                NaN                NaN           2.65
#
#    LN_Foliage_t_ha
# 0             0.47
# 1             1.41
# 2             1.41
# 3             1.69
# 4             1.22

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Species_ID         857 non-null    int64
#  1   Origin_ID          856 non-null    float64
#  2   H_m                857 non-null    float64
#  3   DBH_cm             856 non-null    float64
#  4   BA_sq_m_ha         857 non-null    float64
#  5   GS_cub_m           857 non-null    float64
#  6   ALL_STEM_t_ha      855 non-null    float64
#  7   Stem_wood_t_ha     747 non-null    float64
#  8   Stem_bark_t_ha     747 non-null    float64
#  9   Crown_t_ha         843 non-null    float64
#  10  Foliage_t_ha       854 non-null    float64
#  11  LN_GS_cub_m        857 non-null    float64
#  12  LN_ALL_STEM_t_ha   855 non-null    float64
#  13  LN_Stem_wood_t_ha  747 non-null    float64
#  14  LN_Stem_bark_t_ha  747 non-null    float64
#  15  LN_Crown_t_ha      843 non-null    float64
#  16  LN_Foliage_t_ha    854 non-null    float64
# dtypes: float64(16), int64(1)
# memory usage: 113.9 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species_ID"])["Stem_bark_t_ha", "ALL_STEM_t_ha"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            Stem_bark_t_ha                                                    \
#                     count       mean        std  min     25%    50%     75%
# Species_ID
# 0                   371.0   7.894070   4.128113  0.3   4.900   7.70  10.350
# 1                     7.0  34.728571  23.382095  8.3  13.950  35.70  52.750
# 2                   120.0  11.320000   7.552123  0.8   6.375   9.45  15.250
# 3                   115.0  15.307826   8.294197  2.1   7.950  15.30  21.450
# 4                    66.0  11.296970   6.528234  1.6   6.500   9.25  16.575
# 5                    68.0  29.010294  12.702287  2.5  18.400  29.70  39.675
#
#                  ALL_STEM_t_ha                                              \
#              max         count        mean        std   min     25%    50%
# Species_ID
# 0           23.2         457.0   97.049891  61.854506   1.8  47.500   92.7
# 1           65.7           7.0  123.814286  61.879895  46.3  70.650  133.9
# 2           38.8         120.0   74.495000  44.523333   5.1  37.275   68.1
# 3           41.1         115.0  107.607826  55.589186  11.0  62.700  106.8
# 4           28.7          66.0   84.946970  58.875162   8.2  40.750   61.2
# 5           48.8          90.0  173.065556  99.100647   5.0  93.075  161.3
#
#
#                 75%    max
# Species_ID
# 0           135.900  310.7
# 1           174.550  196.1
# 2           103.075  193.5
# 3           145.450  251.6
# 4           125.000  245.4
# 5           253.375  363.9

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID   Origin_ID         H_m      DBH_cm  BA_sq_m_ha    GS_cub_m  \
# count  857.000000  856.000000  857.000000  856.000000  857.000000  857.000000
# mean     1.529755    0.279206   16.452275   17.132243   26.329988  229.013069
# std      1.823872    0.448871    7.039954   10.439115   10.629993  144.362106
# min      0.000000    0.000000    1.500000    1.100000    1.000000    2.400000
# 25%      0.000000    0.000000   11.200000    9.900000   19.000000  116.000000
# 50%      0.000000    0.000000   16.100000   15.500000   26.800000  206.000000
# 75%      3.000000    1.000000   21.200000   22.100000   34.500000  320.000000
# max      5.000000    1.000000   38.300000   94.000000   51.500000  735.000000
#
#        ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  \
# count     855.000000      747.000000      747.000000  843.000000
# mean      102.590877       92.779518       12.060107   13.821969
# std        68.758819       61.992238        9.595428   11.567546
# min         1.800000        2.000000        0.300000    0.500000
# 25%        47.500000       42.900000        5.950000    6.610000
# 50%        93.500000       84.600000        9.300000   10.820000
# 75%       140.500000      125.500000       15.300000   16.435000
# max       363.900000      315.200000       65.700000   69.120000
#
#        Foliage_t_ha  LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  \
# count    854.000000   857.000000        855.000000         747.000000
# mean       4.749356     5.166919          4.343766           4.246975
# std        2.826586     0.839680          0.869479           0.854856
# min        0.200000     0.880000          0.590000           0.690000
# 25%        2.600000     4.750000          3.860000           3.760000
# 50%        4.300000     5.330000          4.540000           4.440000
# 75%        6.367500     5.770000          4.950000           4.830000
# max       21.730000     6.600000          5.900000           5.750000
#
#        LN_Stem_bark_t_ha  LN_Crown_t_ha  LN_Foliage_t_ha
# count         747.000000     843.000000       854.000000
# mean            2.201232       2.318149         1.364906
# std             0.806766       0.829446         0.672551
# min            -1.200000      -0.690000        -1.610000
# 25%             1.780000       1.890000         0.960000
# 50%             2.230000       2.380000         1.460000
# 75%             2.730000       2.800000         1.850000
# max             4.190000       4.240000         3.080000

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "Stem_bark_t_ha"
indep_variables = ['Species_ID','Origin_ID','H_m','DBH_cm','BA_sq_m_ha']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 10            5        0.0  18.2    19.6        18.3     159.0          101.8
# 11            1        0.0   8.8     5.2        15.5     105.0           46.3
# 12            1        0.0  10.2     6.7        16.2     122.0           54.1
# 13            1        0.0  14.1    10.0        19.9     194.0           87.2
# 14            1        0.0  19.4    15.9        26.8     299.0          133.9
# ..          ...        ...   ...     ...         ...       ...            ...
# 852           3        0.0   7.8     4.4         9.2      39.8           17.8
# 853           3        0.0  12.7     9.0        20.5     123.6           47.1
# 854           3        0.0  12.2     8.1        20.3     141.7           51.9
# 855           2        0.0  14.3    12.4        25.1     176.5          100.7
# 856           2        0.0  21.1    25.6        21.0     191.6           99.9
#
#      Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 10             85.4            16.4       20.40          2.60         5.07
# 11             38.0             8.3       18.48         17.22         4.65
# 12             45.0             9.1       24.64         19.28         4.80
# 13             68.4            18.8       30.65         21.73         5.27
# 14             98.2            35.7       42.76         20.03         5.70
# ..              ...             ...         ...           ...          ...
# 852            15.7             2.1        2.26          2.04         3.68
# 853            42.6             4.5        2.14          1.21         4.82
# 854            47.8             4.1        2.11          1.16         4.95
# 855            84.6            16.1       16.90          4.74         5.17
# 856            80.8            19.1       16.60          2.13         5.26
#
#      LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 10               4.62               4.45               2.80           3.02
# 11               3.84               3.64               2.12           2.92
# 12               3.99               3.81               2.21           3.20
# 13               4.47               4.23               2.93           3.42
# 14               4.90               4.59               3.58           3.76
# ..                ...                ...                ...            ...
# 852              2.88               2.75               0.74           0.82
# 853              3.85               3.75               1.50           0.76
# 854              3.95               3.87               1.41           0.75
# 855              4.61               4.44               2.78           2.83
# 856              4.60               4.39               2.95           2.81
#
#      LN_Foliage_t_ha
# 10              0.96
# 11              2.85
# 12              2.96
# 13              3.08
# 14              3.00
# ..               ...
# 852             0.71
# 853             0.19
# 854             0.15
# 855             1.56
# 856             0.76
#
# [747 rows x 17 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#     Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha
# 10           5        0.0  18.2    19.6        18.3
# 11           1        0.0   8.8     5.2        15.5
# 12           1        0.0  10.2     6.7        16.2
# 13           1        0.0  14.1    10.0        19.9
# 14           1        0.0  19.4    15.9        26.8

# %%
# Columns in "y" data collections
y.head()
# Out:
#     Stem_bark_t_ha
# 10            16.4
# 11             8.3
# 12             9.1
# 13            18.8
# 14            35.7

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.8918944519135216, 0.834512659748259, 0.8783374312194229]
#     Mean: 0.868
#     Std: 0.024
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [3.74716684 3.44502502 3.26565012]
#     Mean: 3.486
#     Std: 0.199
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [2.277107512855147, 2.2106343861085826, 2.040357042627641]
#     Mean: 2.176
#     Std: 0.100
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.6618637554923994                 # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.17264037949538136                # gamma
print('Gamma: ' + str(p2))

p3 = 0.24268238044305301                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 3            # max_depth
print('Max_depth: ' + str(p4))

p5 = 76         # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.6733615714796921                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.6618637554923994
# Gamma: 0.17264037949538136
# Learning_rate: 0.24268238044305301
# Max_depth: 3
# N_estimators: 76
# Subsample: 0.6733615714796921

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:12.42307	validation_1-rmse:9.69618
# [1]	validation_0-rmse:10.07378	validation_1-rmse:7.59365
# [2]	validation_0-rmse:8.26368	validation_1-rmse:6.07041
# [3]	validation_0-rmse:7.01391	validation_1-rmse:5.03221
# [4]	validation_0-rmse:6.07968	validation_1-rmse:4.14944
# [5]	validation_0-rmse:5.31671	validation_1-rmse:3.64073
# [6]	validation_0-rmse:4.72984	validation_1-rmse:3.24319
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:4.34634	validation_1-rmse:2.99128
# [8]	validation_0-rmse:4.03565	validation_1-rmse:2.81517
# [9]	validation_0-rmse:3.87774	validation_1-rmse:2.75402
# [10]	validation_0-rmse:3.70521	validation_1-rmse:2.71268
# [11]	validation_0-rmse:3.56991	validation_1-rmse:2.64753
# [12]	validation_0-rmse:3.48585	validation_1-rmse:2.59171
# [13]	validation_0-rmse:3.36987	validation_1-rmse:2.56922
# [14]	validation_0-rmse:3.32723	validation_1-rmse:2.55654
# [15]	validation_0-rmse:3.27275	validation_1-rmse:2.53354
# [16]	validation_0-rmse:3.25704	validation_1-rmse:2.53113
# [17]	validation_0-rmse:3.21742	validation_1-rmse:2.53700
# [18]	validation_0-rmse:3.13428	validation_1-rmse:2.54937
# [19]	validation_0-rmse:3.12237	validation_1-rmse:2.54049
# [20]	validation_0-rmse:3.09153	validation_1-rmse:2.53804
# [21]	validation_0-rmse:3.05897	validation_1-rmse:2.53088
# [22]	validation_0-rmse:3.03414	validation_1-rmse:2.52381
# [23]	validation_0-rmse:3.02103	validation_1-rmse:2.52343
# [24]	validation_0-rmse:2.97676	validation_1-rmse:2.51769
# [25]	validation_0-rmse:2.90165	validation_1-rmse:2.51831
# [26]	validation_0-rmse:2.84947	validation_1-rmse:2.48405
# [27]	validation_0-rmse:2.80284	validation_1-rmse:2.47684
# [28]	validation_0-rmse:2.79162	validation_1-rmse:2.48440
# [29]	validation_0-rmse:2.77595	validation_1-rmse:2.48271
# [30]	validation_0-rmse:2.75083	validation_1-rmse:2.45987
# [31]	validation_0-rmse:2.73943	validation_1-rmse:2.45383
# [32]	validation_0-rmse:2.71849	validation_1-rmse:2.44339
# [33]	validation_0-rmse:2.71240	validation_1-rmse:2.44546
# [34]	validation_0-rmse:2.70144	validation_1-rmse:2.43867
# [35]	validation_0-rmse:2.69202	validation_1-rmse:2.43897
# [36]	validation_0-rmse:2.67314	validation_1-rmse:2.41258
# [37]	validation_0-rmse:2.64767	validation_1-rmse:2.39339
# [38]	validation_0-rmse:2.61119	validation_1-rmse:2.37457
# [39]	validation_0-rmse:2.58546	validation_1-rmse:2.38860
# [40]	validation_0-rmse:2.55274	validation_1-rmse:2.41185
# [41]	validation_0-rmse:2.53159	validation_1-rmse:2.40671
# [42]	validation_0-rmse:2.51434	validation_1-rmse:2.37840
# [43]	validation_0-rmse:2.49843	validation_1-rmse:2.38674
# [44]	validation_0-rmse:2.46949	validation_1-rmse:2.39077
# [45]	validation_0-rmse:2.45828	validation_1-rmse:2.39606
# [46]	validation_0-rmse:2.44060	validation_1-rmse:2.41279
# [47]	validation_0-rmse:2.43392	validation_1-rmse:2.42131
# [48]	validation_0-rmse:2.40854	validation_1-rmse:2.42119
# [49]	validation_0-rmse:2.39050	validation_1-rmse:2.42498
# [50]	validation_0-rmse:2.38138	validation_1-rmse:2.42623
# [51]	validation_0-rmse:2.36107	validation_1-rmse:2.42179
# [52]	validation_0-rmse:2.35001	validation_1-rmse:2.43741
# [53]	validation_0-rmse:2.33586	validation_1-rmse:2.41635
# [54]	validation_0-rmse:2.32773	validation_1-rmse:2.42643
# [55]	validation_0-rmse:2.32525	validation_1-rmse:2.43464
# [56]	validation_0-rmse:2.31289	validation_1-rmse:2.42466
# [57]	validation_0-rmse:2.28906	validation_1-rmse:2.40918
# [58]	validation_0-rmse:2.27970	validation_1-rmse:2.42315
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:11.78981	validation_1-rmse:12.81842
# [1]	validation_0-rmse:9.38663	validation_1-rmse:10.67648
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:7.70571	validation_1-rmse:9.23588
# [3]	validation_0-rmse:6.44487	validation_1-rmse:8.08232
# [4]	validation_0-rmse:5.48530	validation_1-rmse:7.18136
# [5]	validation_0-rmse:4.80930	validation_1-rmse:6.54225
# [6]	validation_0-rmse:4.33088	validation_1-rmse:6.17567
# [7]	validation_0-rmse:3.97778	validation_1-rmse:5.83857
# [8]	validation_0-rmse:3.79716	validation_1-rmse:5.48258
# [9]	validation_0-rmse:3.62987	validation_1-rmse:5.29839
# [10]	validation_0-rmse:3.53389	validation_1-rmse:5.19911
# [11]	validation_0-rmse:3.42267	validation_1-rmse:5.04752
# [12]	validation_0-rmse:3.36509	validation_1-rmse:5.01189
# [13]	validation_0-rmse:3.29015	validation_1-rmse:4.94481
# [14]	validation_0-rmse:3.24467	validation_1-rmse:4.88459
# [15]	validation_0-rmse:3.19093	validation_1-rmse:4.79315
# [16]	validation_0-rmse:3.15967	validation_1-rmse:4.76983
# [17]	validation_0-rmse:3.09817	validation_1-rmse:4.68875
# [18]	validation_0-rmse:3.04016	validation_1-rmse:4.64988
# [19]	validation_0-rmse:3.02041	validation_1-rmse:4.62359
# [20]	validation_0-rmse:2.92223	validation_1-rmse:4.38539
# [21]	validation_0-rmse:2.87347	validation_1-rmse:4.37556
# [22]	validation_0-rmse:2.83788	validation_1-rmse:4.35982
# [23]	validation_0-rmse:2.81207	validation_1-rmse:4.34806
# [24]	validation_0-rmse:2.79485	validation_1-rmse:4.31230
# [25]	validation_0-rmse:2.77926	validation_1-rmse:4.30718
# [26]	validation_0-rmse:2.77024	validation_1-rmse:4.28998
# [27]	validation_0-rmse:2.74793	validation_1-rmse:4.27415
# [28]	validation_0-rmse:2.74004	validation_1-rmse:4.26844
# [29]	validation_0-rmse:2.71701	validation_1-rmse:4.24549
# [30]	validation_0-rmse:2.68113	validation_1-rmse:4.22890
# [31]	validation_0-rmse:2.66091	validation_1-rmse:4.16044
# [32]	validation_0-rmse:2.63252	validation_1-rmse:4.16941
# [33]	validation_0-rmse:2.61153	validation_1-rmse:4.14790
# [34]	validation_0-rmse:2.60041	validation_1-rmse:4.15326
# [35]	validation_0-rmse:2.57637	validation_1-rmse:4.17218
# [36]	validation_0-rmse:2.53547	validation_1-rmse:4.15356
# [37]	validation_0-rmse:2.51787	validation_1-rmse:4.11618
# [38]	validation_0-rmse:2.48570	validation_1-rmse:4.10972
# [39]	validation_0-rmse:2.46214	validation_1-rmse:4.09205
# [40]	validation_0-rmse:2.44243	validation_1-rmse:4.09555
# [41]	validation_0-rmse:2.42638	validation_1-rmse:4.11122
# [42]	validation_0-rmse:2.41294	validation_1-rmse:4.08430
# [43]	validation_0-rmse:2.40487	validation_1-rmse:4.08382
# [44]	validation_0-rmse:2.37343	validation_1-rmse:3.96098
# [45]	validation_0-rmse:2.35985	validation_1-rmse:3.94284
# [46]	validation_0-rmse:2.34804	validation_1-rmse:3.93017
# [47]	validation_0-rmse:2.33448	validation_1-rmse:3.93895
# [48]	validation_0-rmse:2.32546	validation_1-rmse:3.91511
# [49]	validation_0-rmse:2.30613	validation_1-rmse:3.92600
# [50]	validation_0-rmse:2.29120	validation_1-rmse:3.92498
# [51]	validation_0-rmse:2.28178	validation_1-rmse:3.87642
# [52]	validation_0-rmse:2.26825	validation_1-rmse:3.86137
# [53]	validation_0-rmse:2.26261	validation_1-rmse:3.86513
# [54]	validation_0-rmse:2.25091	validation_1-rmse:3.87753
# [55]	validation_0-rmse:2.24147	validation_1-rmse:3.86885
# [56]	validation_0-rmse:2.23090	validation_1-rmse:3.85185
# [57]	validation_0-rmse:2.21183	validation_1-rmse:3.85016
# [58]	validation_0-rmse:2.20222	validation_1-rmse:3.85640
# [59]	validation_0-rmse:2.19273	validation_1-rmse:3.86012
# [60]	validation_0-rmse:2.18498	validation_1-rmse:3.84809
# [61]	validation_0-rmse:2.16455	validation_1-rmse:3.84210
# [62]	validation_0-rmse:2.15705	validation_1-rmse:3.84270
# [63]	validation_0-rmse:2.14107	validation_1-rmse:3.84659
# [64]	validation_0-rmse:2.11971	validation_1-rmse:3.82257
# [65]	validation_0-rmse:2.11428	validation_1-rmse:3.84841
# [66]	validation_0-rmse:2.10865	validation_1-rmse:3.84837
# [67]	validation_0-rmse:2.10635	validation_1-rmse:3.84696
# [68]	validation_0-rmse:2.09747	validation_1-rmse:3.83778
# [69]	validation_0-rmse:2.09114	validation_1-rmse:3.83787
# [70]	validation_0-rmse:2.08245	validation_1-rmse:3.84260
# [71]	validation_0-rmse:2.07821	validation_1-rmse:3.83369
# [72]	validation_0-rmse:2.05871	validation_1-rmse:3.77192
# [73]	validation_0-rmse:2.05315	validation_1-rmse:3.77145
# [74]	validation_0-rmse:2.04886	validation_1-rmse:3.76574
# [75]	validation_0-rmse:2.04100	validation_1-rmse:3.77838
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:12.43374	validation_1-rmse:9.71247
# [1]	validation_0-rmse:10.05685	validation_1-rmse:7.79793
# [2]	validation_0-rmse:8.23591	validation_1-rmse:6.34306
# [3]	validation_0-rmse:6.87542	validation_1-rmse:5.46781
# [4]	validation_0-rmse:5.80857	validation_1-rmse:4.83587
# [5]	validation_0-rmse:5.16322	validation_1-rmse:4.43091
# [6]	validation_0-rmse:4.54708	validation_1-rmse:4.18295
# [7]	validation_0-rmse:4.15057	validation_1-rmse:4.08106
# [8]	validation_0-rmse:3.81258	validation_1-rmse:3.92464
# [9]	validation_0-rmse:3.65334	validation_1-rmse:3.88655
# [10]	validation_0-rmse:3.53336	validation_1-rmse:3.84943
# [11]	validation_0-rmse:3.39574	validation_1-rmse:3.81408
# [12]	validation_0-rmse:3.31107	validation_1-rmse:3.80975
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [13]	validation_0-rmse:3.25270	validation_1-rmse:3.78988
# [14]	validation_0-rmse:3.18441	validation_1-rmse:3.74635
# [15]	validation_0-rmse:3.05782	validation_1-rmse:3.68589
# [16]	validation_0-rmse:3.01010	validation_1-rmse:3.67178
# [17]	validation_0-rmse:2.94534	validation_1-rmse:3.62841
# [18]	validation_0-rmse:2.89340	validation_1-rmse:3.61132
# [19]	validation_0-rmse:2.86049	validation_1-rmse:3.62595
# [20]	validation_0-rmse:2.78138	validation_1-rmse:3.59877
# [21]	validation_0-rmse:2.74332	validation_1-rmse:3.56963
# [22]	validation_0-rmse:2.71757	validation_1-rmse:3.55738
# [23]	validation_0-rmse:2.69306	validation_1-rmse:3.55474
# [24]	validation_0-rmse:2.66652	validation_1-rmse:3.55787
# [25]	validation_0-rmse:2.62678	validation_1-rmse:3.54025
# [26]	validation_0-rmse:2.59447	validation_1-rmse:3.52104
# [27]	validation_0-rmse:2.55965	validation_1-rmse:3.50392
# [28]	validation_0-rmse:2.53697	validation_1-rmse:3.56607
# [29]	validation_0-rmse:2.51330	validation_1-rmse:3.56140
# [30]	validation_0-rmse:2.47706	validation_1-rmse:3.55699
# [31]	validation_0-rmse:2.46317	validation_1-rmse:3.55581
# [32]	validation_0-rmse:2.45089	validation_1-rmse:3.55984
# [33]	validation_0-rmse:2.43148	validation_1-rmse:3.54716
# [34]	validation_0-rmse:2.39981	validation_1-rmse:3.47058
# [35]	validation_0-rmse:2.38706	validation_1-rmse:3.48092
# [36]	validation_0-rmse:2.37730	validation_1-rmse:3.50681
# [37]	validation_0-rmse:2.36615	validation_1-rmse:3.50687
# [38]	validation_0-rmse:2.35086	validation_1-rmse:3.46334
# [39]	validation_0-rmse:2.33840	validation_1-rmse:3.46503
# [40]	validation_0-rmse:2.31454	validation_1-rmse:3.42962
# [41]	validation_0-rmse:2.29833	validation_1-rmse:3.41569
# [42]	validation_0-rmse:2.28391	validation_1-rmse:3.41355
# [43]	validation_0-rmse:2.25091	validation_1-rmse:3.47026
# [44]	validation_0-rmse:2.22667	validation_1-rmse:3.43529
# [45]	validation_0-rmse:2.21807	validation_1-rmse:3.42315
# [46]	validation_0-rmse:2.19621	validation_1-rmse:3.43696
# [47]	validation_0-rmse:2.18319	validation_1-rmse:3.43119
# [48]	validation_0-rmse:2.17031	validation_1-rmse:3.42332
# [49]	validation_0-rmse:2.15588	validation_1-rmse:3.41475
# [50]	validation_0-rmse:2.13437	validation_1-rmse:3.38306
# [51]	validation_0-rmse:2.11454	validation_1-rmse:3.36971
# [52]	validation_0-rmse:2.10604	validation_1-rmse:3.36282
# [53]	validation_0-rmse:2.08746	validation_1-rmse:3.33718
# [54]	validation_0-rmse:2.08250	validation_1-rmse:3.32925
# [55]	validation_0-rmse:2.05898	validation_1-rmse:3.32188
# [56]	validation_0-rmse:2.05193	validation_1-rmse:3.31457
# [57]	validation_0-rmse:2.04197	validation_1-rmse:3.28784
# [58]	validation_0-rmse:2.03571	validation_1-rmse:3.28617
# [59]	validation_0-rmse:2.02478	validation_1-rmse:3.28285
# [60]	validation_0-rmse:2.01823	validation_1-rmse:3.28828
# [61]	validation_0-rmse:2.00740	validation_1-rmse:3.29358
# [62]	validation_0-rmse:2.00429	validation_1-rmse:3.29796
# [63]	validation_0-rmse:1.99626	validation_1-rmse:3.31445
# [64]	validation_0-rmse:1.98841	validation_1-rmse:3.29815
# [65]	validation_0-rmse:1.98201	validation_1-rmse:3.30016
# [66]	validation_0-rmse:1.97501	validation_1-rmse:3.30544
# [67]	validation_0-rmse:1.96790	validation_1-rmse:3.31505
# [68]	validation_0-rmse:1.94943	validation_1-rmse:3.29525
# [69]	validation_0-rmse:1.94332	validation_1-rmse:3.30711
# [70]	validation_0-rmse:1.94065	validation_1-rmse:3.30863
# [71]	validation_0-rmse:1.93355	validation_1-rmse:3.30311
# [72]	validation_0-rmse:1.91608	validation_1-rmse:3.29018
# [73]	validation_0-rmse:1.91128	validation_1-rmse:3.28981
# [74]	validation_0-rmse:1.90770	validation_1-rmse:3.29391
# [75]	validation_0-rmse:1.90301	validation_1-rmse:3.29135
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:12.06017	validation_1-rmse:11.70739
# [1]	validation_0-rmse:9.67847	validation_1-rmse:9.07495
# [2]	validation_0-rmse:8.00047	validation_1-rmse:7.32549
# [3]	validation_0-rmse:6.85151	validation_1-rmse:5.99616
# [4]	validation_0-rmse:5.82214	validation_1-rmse:4.78973
# [5]	validation_0-rmse:5.28943	validation_1-rmse:4.21925
# [6]	validation_0-rmse:4.66304	validation_1-rmse:3.78876
# [7]	validation_0-rmse:4.33304	validation_1-rmse:3.43588
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:4.02494	validation_1-rmse:3.21479
# [9]	validation_0-rmse:3.82810	validation_1-rmse:3.15607
# [10]	validation_0-rmse:3.60548	validation_1-rmse:3.10760
# [11]	validation_0-rmse:3.47289	validation_1-rmse:2.98649
# [12]	validation_0-rmse:3.40482	validation_1-rmse:2.94003
# [13]	validation_0-rmse:3.23452	validation_1-rmse:2.92141
# [14]	validation_0-rmse:3.15044	validation_1-rmse:2.92070
# [15]	validation_0-rmse:3.09591	validation_1-rmse:2.88550
# [16]	validation_0-rmse:3.06909	validation_1-rmse:2.90172
# [17]	validation_0-rmse:3.03223	validation_1-rmse:2.87946
# [18]	validation_0-rmse:3.00496	validation_1-rmse:2.87331
# [19]	validation_0-rmse:2.97233	validation_1-rmse:2.88492
# [20]	validation_0-rmse:2.93569	validation_1-rmse:2.90974
# [21]	validation_0-rmse:2.87158	validation_1-rmse:2.88491
# [22]	validation_0-rmse:2.83512	validation_1-rmse:2.89151
# [23]	validation_0-rmse:2.81657	validation_1-rmse:2.88532
# [24]	validation_0-rmse:2.79325	validation_1-rmse:2.85131
# [25]	validation_0-rmse:2.70381	validation_1-rmse:2.87737
# [26]	validation_0-rmse:2.69105	validation_1-rmse:2.86914
# [27]	validation_0-rmse:2.67920	validation_1-rmse:2.85648
# [28]	validation_0-rmse:2.63419	validation_1-rmse:2.86660
# [29]	validation_0-rmse:2.62629	validation_1-rmse:2.85762
# [30]	validation_0-rmse:2.59368	validation_1-rmse:2.87015
# [31]	validation_0-rmse:2.57265	validation_1-rmse:2.87583
# [32]	validation_0-rmse:2.55742	validation_1-rmse:2.87355
# [33]	validation_0-rmse:2.55083	validation_1-rmse:2.87043
# [34]	validation_0-rmse:2.52528	validation_1-rmse:2.85488
# [35]	validation_0-rmse:2.49407	validation_1-rmse:2.85068
# [36]	validation_0-rmse:2.48691	validation_1-rmse:2.85230
# [37]	validation_0-rmse:2.46571	validation_1-rmse:2.84919
# [38]	validation_0-rmse:2.43569	validation_1-rmse:2.84633
# [39]	validation_0-rmse:2.42811	validation_1-rmse:2.84013
# [40]	validation_0-rmse:2.41640	validation_1-rmse:2.83982
# [41]	validation_0-rmse:2.40109	validation_1-rmse:2.82637
# [42]	validation_0-rmse:2.37619	validation_1-rmse:2.83559
# [43]	validation_0-rmse:2.35980	validation_1-rmse:2.82666
# [44]	validation_0-rmse:2.33772	validation_1-rmse:2.82132
# [45]	validation_0-rmse:2.33150	validation_1-rmse:2.83331
# [46]	validation_0-rmse:2.31702	validation_1-rmse:2.83419
# [47]	validation_0-rmse:2.30807	validation_1-rmse:2.82977
# [48]	validation_0-rmse:2.29325	validation_1-rmse:2.82695
# [49]	validation_0-rmse:2.28885	validation_1-rmse:2.82216
# [50]	validation_0-rmse:2.27389	validation_1-rmse:2.81890
# [51]	validation_0-rmse:2.26507	validation_1-rmse:2.80237
# [52]	validation_0-rmse:2.22712	validation_1-rmse:2.80423
# [53]	validation_0-rmse:2.22018	validation_1-rmse:2.79835
# [54]	validation_0-rmse:2.21104	validation_1-rmse:2.80813
# [55]	validation_0-rmse:2.20544	validation_1-rmse:2.81027
# [56]	validation_0-rmse:2.18560	validation_1-rmse:2.81393
# [57]	validation_0-rmse:2.17491	validation_1-rmse:2.82379
# [58]	validation_0-rmse:2.15509	validation_1-rmse:2.82907
# [59]	validation_0-rmse:2.15073	validation_1-rmse:2.82372
# [60]	validation_0-rmse:2.13377	validation_1-rmse:2.82074
# [61]	validation_0-rmse:2.11943	validation_1-rmse:2.81945
# [62]	validation_0-rmse:2.10025	validation_1-rmse:2.81222
# [63]	validation_0-rmse:2.08518	validation_1-rmse:2.82220
# [64]	validation_0-rmse:2.07784	validation_1-rmse:2.82363
# [65]	validation_0-rmse:2.05965	validation_1-rmse:2.81401
# [66]	validation_0-rmse:2.05516	validation_1-rmse:2.81304
# [67]	validation_0-rmse:2.04933	validation_1-rmse:2.81268
# [68]	validation_0-rmse:2.03277	validation_1-rmse:2.80866
# [69]	validation_0-rmse:2.02235	validation_1-rmse:2.81458
# [70]	validation_0-rmse:2.00673	validation_1-rmse:2.80740
# [71]	validation_0-rmse:1.99330	validation_1-rmse:2.82503
# [72]	validation_0-rmse:1.98413	validation_1-rmse:2.83177
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:11.84021	validation_1-rmse:12.54725
# [1]	validation_0-rmse:9.52625	validation_1-rmse:10.33684
# [2]	validation_0-rmse:7.81443	validation_1-rmse:8.29281
# [3]	validation_0-rmse:6.62602	validation_1-rmse:7.19168
# [4]	validation_0-rmse:5.64537	validation_1-rmse:6.15093
# [5]	validation_0-rmse:5.10821	validation_1-rmse:5.63243
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:4.52499	validation_1-rmse:5.04984
# [7]	validation_0-rmse:4.11783	validation_1-rmse:4.58886
# [8]	validation_0-rmse:3.81276	validation_1-rmse:4.17451
# [9]	validation_0-rmse:3.63985	validation_1-rmse:4.06220
# [10]	validation_0-rmse:3.49323	validation_1-rmse:3.94238
# [11]	validation_0-rmse:3.39973	validation_1-rmse:3.81808
# [12]	validation_0-rmse:3.30439	validation_1-rmse:3.74355
# [13]	validation_0-rmse:3.14266	validation_1-rmse:3.54876
# [14]	validation_0-rmse:3.08779	validation_1-rmse:3.47655
# [15]	validation_0-rmse:3.02063	validation_1-rmse:3.44035
# [16]	validation_0-rmse:2.99925	validation_1-rmse:3.42830
# [17]	validation_0-rmse:2.96782	validation_1-rmse:3.45599
# [18]	validation_0-rmse:2.89607	validation_1-rmse:3.38487
# [19]	validation_0-rmse:2.87553	validation_1-rmse:3.36809
# [20]	validation_0-rmse:2.84735	validation_1-rmse:3.35823
# [21]	validation_0-rmse:2.82422	validation_1-rmse:3.35759
# [22]	validation_0-rmse:2.78188	validation_1-rmse:3.31301
# [23]	validation_0-rmse:2.74426	validation_1-rmse:3.26508
# [24]	validation_0-rmse:2.72670	validation_1-rmse:3.26767
# [25]	validation_0-rmse:2.71740	validation_1-rmse:3.27726
# [26]	validation_0-rmse:2.70246	validation_1-rmse:3.27382
# [27]	validation_0-rmse:2.65230	validation_1-rmse:3.27809
# [28]	validation_0-rmse:2.62475	validation_1-rmse:3.25363
# [29]	validation_0-rmse:2.59032	validation_1-rmse:3.25465
# [30]	validation_0-rmse:2.54504	validation_1-rmse:3.22084
# [31]	validation_0-rmse:2.52190	validation_1-rmse:3.22644
# [32]	validation_0-rmse:2.50184	validation_1-rmse:3.24133
# [33]	validation_0-rmse:2.47705	validation_1-rmse:3.23438
# [34]	validation_0-rmse:2.46422	validation_1-rmse:3.23980
# [35]	validation_0-rmse:2.43862	validation_1-rmse:3.23447
# [36]	validation_0-rmse:2.42127	validation_1-rmse:3.23576
# [37]	validation_0-rmse:2.41120	validation_1-rmse:3.23773
# [38]	validation_0-rmse:2.37814	validation_1-rmse:3.23068
# [39]	validation_0-rmse:2.36078	validation_1-rmse:3.21159
# [40]	validation_0-rmse:2.35412	validation_1-rmse:3.21240
# [41]	validation_0-rmse:2.32232	validation_1-rmse:3.19370
# [42]	validation_0-rmse:2.29965	validation_1-rmse:3.15566
# [43]	validation_0-rmse:2.27897	validation_1-rmse:3.14514
# [44]	validation_0-rmse:2.26061	validation_1-rmse:3.14848
# [45]	validation_0-rmse:2.25437	validation_1-rmse:3.15958
# [46]	validation_0-rmse:2.23958	validation_1-rmse:3.15110
# [47]	validation_0-rmse:2.23288	validation_1-rmse:3.14945
# [48]	validation_0-rmse:2.20571	validation_1-rmse:3.15977
# [49]	validation_0-rmse:2.19561	validation_1-rmse:3.17334
# [50]	validation_0-rmse:2.18669	validation_1-rmse:3.18040
# [51]	validation_0-rmse:2.16689	validation_1-rmse:3.17285
# [52]	validation_0-rmse:2.14387	validation_1-rmse:3.15194
# [53]	validation_0-rmse:2.13608	validation_1-rmse:3.13862
# [54]	validation_0-rmse:2.12975	validation_1-rmse:3.14448
# [55]	validation_0-rmse:2.12530	validation_1-rmse:3.11389
# [56]	validation_0-rmse:2.12309	validation_1-rmse:3.11302
# [57]	validation_0-rmse:2.10155	validation_1-rmse:3.10136
# [58]	validation_0-rmse:2.09168	validation_1-rmse:3.12555
# [59]	validation_0-rmse:2.08646	validation_1-rmse:3.12984
# [60]	validation_0-rmse:2.07884	validation_1-rmse:3.12774
# [61]	validation_0-rmse:2.06116	validation_1-rmse:3.13143
# [62]	validation_0-rmse:2.05342	validation_1-rmse:3.12963
# [63]	validation_0-rmse:2.04358	validation_1-rmse:3.12895
# [64]	validation_0-rmse:2.02761	validation_1-rmse:3.12835
# [65]	validation_0-rmse:2.01205	validation_1-rmse:3.11711
# [66]	validation_0-rmse:1.99962	validation_1-rmse:3.10421
# [67]	validation_0-rmse:1.99169	validation_1-rmse:3.10260
# [68]	validation_0-rmse:1.98275	validation_1-rmse:3.09605
# [69]	validation_0-rmse:1.97090	validation_1-rmse:3.10533
# [70]	validation_0-rmse:1.96388	validation_1-rmse:3.11096
# [71]	validation_0-rmse:1.95349	validation_1-rmse:3.10330
# [72]	validation_0-rmse:1.93617	validation_1-rmse:3.10872
# [73]	validation_0-rmse:1.92475	validation_1-rmse:3.10120
# [74]	validation_0-rmse:1.91290	validation_1-rmse:3.11207
# [75]	validation_0-rmse:1.90425	validation_1-rmse:3.11694
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:11.74958	validation_1-rmse:13.02125
# [1]	validation_0-rmse:9.58694	validation_1-rmse:10.74994
# [2]	validation_0-rmse:7.81109	validation_1-rmse:8.83696
# [3]	validation_0-rmse:6.71733	validation_1-rmse:7.69391
# [4]	validation_0-rmse:5.69135	validation_1-rmse:6.52993
# [5]	validation_0-rmse:5.09961	validation_1-rmse:5.96667
# [6]	validation_0-rmse:4.54143	validation_1-rmse:5.31858
# [7]	validation_0-rmse:4.17235	validation_1-rmse:4.94642
# [8]	validation_0-rmse:3.84427	validation_1-rmse:4.57173
# [9]	validation_0-rmse:3.69699	validation_1-rmse:4.44825
# [10]	validation_0-rmse:3.56259	validation_1-rmse:4.32518
# [11]	validation_0-rmse:3.45827	validation_1-rmse:4.19912
# [12]	validation_0-rmse:3.35520	validation_1-rmse:4.14843
# [13]	validation_0-rmse:3.20547	validation_1-rmse:4.10343
# [14]	validation_0-rmse:3.17315	validation_1-rmse:4.04752
# [15]	validation_0-rmse:3.12881	validation_1-rmse:4.01115
# [16]	validation_0-rmse:3.09875	validation_1-rmse:3.94220
# [17]	validation_0-rmse:3.04613	validation_1-rmse:3.90880
# [18]	validation_0-rmse:2.96675	validation_1-rmse:3.79824
# [19]	validation_0-rmse:2.94309	validation_1-rmse:3.79241
# [20]	validation_0-rmse:2.86945	validation_1-rmse:3.71277
# [21]	validation_0-rmse:2.83585	validation_1-rmse:3.70208
# [22]	validation_0-rmse:2.79299	validation_1-rmse:3.68465
# [23]	validation_0-rmse:2.76670	validation_1-rmse:3.67914
# [24]	validation_0-rmse:2.73773	validation_1-rmse:3.67938
# [25]	validation_0-rmse:2.72624	validation_1-rmse:3.67421
# [26]	validation_0-rmse:2.70715	validation_1-rmse:3.66335
# [27]	validation_0-rmse:2.66173	validation_1-rmse:3.59236
# [28]	validation_0-rmse:2.64428	validation_1-rmse:3.56638
# [29]	validation_0-rmse:2.61173	validation_1-rmse:3.54551
# [30]	validation_0-rmse:2.58646	validation_1-rmse:3.54490
# [31]	validation_0-rmse:2.57238	validation_1-rmse:3.55234
# [32]	validation_0-rmse:2.53085	validation_1-rmse:3.51786
# [33]	validation_0-rmse:2.50938	validation_1-rmse:3.51003
# [34]	validation_0-rmse:2.49332	validation_1-rmse:3.49159
# [35]	validation_0-rmse:2.48323	validation_1-rmse:3.48059
# [36]	validation_0-rmse:2.45950	validation_1-rmse:3.47656
# [37]	validation_0-rmse:2.43880	validation_1-rmse:3.48678
# [38]	validation_0-rmse:2.41181	validation_1-rmse:3.44539
# [39]	validation_0-rmse:2.39984	validation_1-rmse:3.44566
# [40]	validation_0-rmse:2.39075	validation_1-rmse:3.45849
# [41]	validation_0-rmse:2.36581	validation_1-rmse:3.46343
# [42]	validation_0-rmse:2.36017	validation_1-rmse:3.47251
# [43]	validation_0-rmse:2.33988	validation_1-rmse:3.42518
# [44]	validation_0-rmse:2.31832	validation_1-rmse:3.37505
# [45]	validation_0-rmse:2.30777	validation_1-rmse:3.36456
# [46]	validation_0-rmse:2.29933	validation_1-rmse:3.35768
# [47]	validation_0-rmse:2.29417	validation_1-rmse:3.35915
# [48]	validation_0-rmse:2.28324	validation_1-rmse:3.35051
# [49]	validation_0-rmse:2.26275	validation_1-rmse:3.34704
# [50]	validation_0-rmse:2.25575	validation_1-rmse:3.35246
# [51]	validation_0-rmse:2.24342	validation_1-rmse:3.36966
# [52]	validation_0-rmse:2.22313	validation_1-rmse:3.35535
# [53]	validation_0-rmse:2.19598	validation_1-rmse:3.31994
# [54]	validation_0-rmse:2.18444	validation_1-rmse:3.31270
# [55]	validation_0-rmse:2.16187	validation_1-rmse:3.24922
# [56]	validation_0-rmse:2.15725	validation_1-rmse:3.24129
# [57]	validation_0-rmse:2.15210	validation_1-rmse:3.24529
# [58]	validation_0-rmse:2.13542	validation_1-rmse:3.23479
# [59]	validation_0-rmse:2.12219	validation_1-rmse:3.24020
# [60]	validation_0-rmse:2.09711	validation_1-rmse:3.25443
# [61]	validation_0-rmse:2.08455	validation_1-rmse:3.25815
# [62]	validation_0-rmse:2.07707	validation_1-rmse:3.25729
# [63]	validation_0-rmse:2.05929	validation_1-rmse:3.24887
# [64]	validation_0-rmse:2.05117	validation_1-rmse:3.24649
# [65]	validation_0-rmse:2.04281	validation_1-rmse:3.24303
# [66]	validation_0-rmse:2.04030	validation_1-rmse:3.24221
# [67]	validation_0-rmse:2.02037	validation_1-rmse:3.23700
# [68]	validation_0-rmse:2.00955	validation_1-rmse:3.23292
# [69]	validation_0-rmse:1.98671	validation_1-rmse:3.20826
# [70]	validation_0-rmse:1.98293	validation_1-rmse:3.21232
# [71]	validation_0-rmse:1.98099	validation_1-rmse:3.21452
# [72]	validation_0-rmse:1.97280	validation_1-rmse:3.21087
# [73]	validation_0-rmse:1.96401	validation_1-rmse:3.22305
# [74]	validation_0-rmse:1.95477	validation_1-rmse:3.23021
# [75]	validation_0-rmse:1.95276	validation_1-rmse:3.23455
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:12.35881	validation_1-rmse:10.05992
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:10.01994	validation_1-rmse:7.91074
# [2]	validation_0-rmse:8.14304	validation_1-rmse:6.49436
# [3]	validation_0-rmse:6.86135	validation_1-rmse:5.47902
# [4]	validation_0-rmse:5.82445	validation_1-rmse:4.66782
# [5]	validation_0-rmse:5.12755	validation_1-rmse:4.31403
# [6]	validation_0-rmse:4.56865	validation_1-rmse:4.02241
# [7]	validation_0-rmse:4.16071	validation_1-rmse:3.78780
# [8]	validation_0-rmse:3.90064	validation_1-rmse:3.68333
# [9]	validation_0-rmse:3.72191	validation_1-rmse:3.66607
# [10]	validation_0-rmse:3.63321	validation_1-rmse:3.72185
# [11]	validation_0-rmse:3.49850	validation_1-rmse:3.71090
# [12]	validation_0-rmse:3.39579	validation_1-rmse:3.66713
# [13]	validation_0-rmse:3.22525	validation_1-rmse:3.56982
# [14]	validation_0-rmse:3.17639	validation_1-rmse:3.55739
# [15]	validation_0-rmse:3.06049	validation_1-rmse:3.55503
# [16]	validation_0-rmse:3.03566	validation_1-rmse:3.54897
# [17]	validation_0-rmse:2.99978	validation_1-rmse:3.56605
# [18]	validation_0-rmse:2.95552	validation_1-rmse:3.54221
# [19]	validation_0-rmse:2.93468	validation_1-rmse:3.52822
# [20]	validation_0-rmse:2.88639	validation_1-rmse:3.51129
# [21]	validation_0-rmse:2.85430	validation_1-rmse:3.53265
# [22]	validation_0-rmse:2.83287	validation_1-rmse:3.56422
# [23]	validation_0-rmse:2.80424	validation_1-rmse:3.54460
# [24]	validation_0-rmse:2.77613	validation_1-rmse:3.54527
# [25]	validation_0-rmse:2.71442	validation_1-rmse:3.55540
# [26]	validation_0-rmse:2.70036	validation_1-rmse:3.54769
# [27]	validation_0-rmse:2.67202	validation_1-rmse:3.62140
# [28]	validation_0-rmse:2.65844	validation_1-rmse:3.61152
# [29]	validation_0-rmse:2.64302	validation_1-rmse:3.60974
# [30]	validation_0-rmse:2.61610	validation_1-rmse:3.61993
# [31]	validation_0-rmse:2.60246	validation_1-rmse:3.66702
# [32]	validation_0-rmse:2.58306	validation_1-rmse:3.65836
# [33]	validation_0-rmse:2.56027	validation_1-rmse:3.64612
# [34]	validation_0-rmse:2.52635	validation_1-rmse:3.64934
# [35]	validation_0-rmse:2.51723	validation_1-rmse:3.65960
# [36]	validation_0-rmse:2.49872	validation_1-rmse:3.63855
# [37]	validation_0-rmse:2.48875	validation_1-rmse:3.62701
# [38]	validation_0-rmse:2.45868	validation_1-rmse:3.64464
# [39]	validation_0-rmse:2.44257	validation_1-rmse:3.65273
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:11.88627	validation_1-rmse:12.56619
# [1]	validation_0-rmse:9.62077	validation_1-rmse:10.17765
# [2]	validation_0-rmse:8.05244	validation_1-rmse:8.41714
# [3]	validation_0-rmse:6.86331	validation_1-rmse:7.12612
# [4]	validation_0-rmse:5.91903	validation_1-rmse:6.16033
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:5.20333	validation_1-rmse:5.35513
# [6]	validation_0-rmse:4.67307	validation_1-rmse:4.91822
# [7]	validation_0-rmse:4.29224	validation_1-rmse:4.48817
# [8]	validation_0-rmse:3.90333	validation_1-rmse:4.24730
# [9]	validation_0-rmse:3.73825	validation_1-rmse:4.09455
# [10]	validation_0-rmse:3.54338	validation_1-rmse:3.88096
# [11]	validation_0-rmse:3.36543	validation_1-rmse:3.80656
# [12]	validation_0-rmse:3.27793	validation_1-rmse:3.72397
# [13]	validation_0-rmse:3.20693	validation_1-rmse:3.68178
# [14]	validation_0-rmse:3.17113	validation_1-rmse:3.64015
# [15]	validation_0-rmse:3.09481	validation_1-rmse:3.57056
# [16]	validation_0-rmse:3.08026	validation_1-rmse:3.58488
# [17]	validation_0-rmse:3.04139	validation_1-rmse:3.55644
# [18]	validation_0-rmse:3.01018	validation_1-rmse:3.56284
# [19]	validation_0-rmse:2.98440	validation_1-rmse:3.55290
# [20]	validation_0-rmse:2.96291	validation_1-rmse:3.55357
# [21]	validation_0-rmse:2.89657	validation_1-rmse:3.58157
# [22]	validation_0-rmse:2.85273	validation_1-rmse:3.48285
# [23]	validation_0-rmse:2.82588	validation_1-rmse:3.47848
# [24]	validation_0-rmse:2.79823	validation_1-rmse:3.48828
# [25]	validation_0-rmse:2.77016	validation_1-rmse:3.46906
# [26]	validation_0-rmse:2.75630	validation_1-rmse:3.49190
# [27]	validation_0-rmse:2.74002	validation_1-rmse:3.49354
# [28]	validation_0-rmse:2.70922	validation_1-rmse:3.47911
# [29]	validation_0-rmse:2.67370	validation_1-rmse:3.46794
# [30]	validation_0-rmse:2.66247	validation_1-rmse:3.46977
# [31]	validation_0-rmse:2.62739	validation_1-rmse:3.47414
# [32]	validation_0-rmse:2.57860	validation_1-rmse:3.46155
# [33]	validation_0-rmse:2.56490	validation_1-rmse:3.45790
# [34]	validation_0-rmse:2.53713	validation_1-rmse:3.44621
# [35]	validation_0-rmse:2.52749	validation_1-rmse:3.45413
# [36]	validation_0-rmse:2.51749	validation_1-rmse:3.46057
# [37]	validation_0-rmse:2.50460	validation_1-rmse:3.44684
# [38]	validation_0-rmse:2.47493	validation_1-rmse:3.44349
# [39]	validation_0-rmse:2.46301	validation_1-rmse:3.44413
# [40]	validation_0-rmse:2.44710	validation_1-rmse:3.42361
# [41]	validation_0-rmse:2.41884	validation_1-rmse:3.44786
# [42]	validation_0-rmse:2.39227	validation_1-rmse:3.39986
# [43]	validation_0-rmse:2.35961	validation_1-rmse:3.37187
# [44]	validation_0-rmse:2.34388	validation_1-rmse:3.36891
# [45]	validation_0-rmse:2.33604	validation_1-rmse:3.36453
# [46]	validation_0-rmse:2.32059	validation_1-rmse:3.37057
# [47]	validation_0-rmse:2.30576	validation_1-rmse:3.37351
# [48]	validation_0-rmse:2.28968	validation_1-rmse:3.40023
# [49]	validation_0-rmse:2.27517	validation_1-rmse:3.41201
# [50]	validation_0-rmse:2.26909	validation_1-rmse:3.42145
# [51]	validation_0-rmse:2.26000	validation_1-rmse:3.42762
# [52]	validation_0-rmse:2.24719	validation_1-rmse:3.42936
# [53]	validation_0-rmse:2.24047	validation_1-rmse:3.43258
# [54]	validation_0-rmse:2.22765	validation_1-rmse:3.42423
# [55]	validation_0-rmse:2.20692	validation_1-rmse:3.44808
# [56]	validation_0-rmse:2.18108	validation_1-rmse:3.41323
# [57]	validation_0-rmse:2.17152	validation_1-rmse:3.41470
# [58]	validation_0-rmse:2.16126	validation_1-rmse:3.40986
# [59]	validation_0-rmse:2.14907	validation_1-rmse:3.39821
# [60]	validation_0-rmse:2.13590	validation_1-rmse:3.38827
# [61]	validation_0-rmse:2.12270	validation_1-rmse:3.37418
# [62]	validation_0-rmse:2.11994	validation_1-rmse:3.36142
# [63]	validation_0-rmse:2.10992	validation_1-rmse:3.35253
# [64]	validation_0-rmse:2.09692	validation_1-rmse:3.32596
# [65]	validation_0-rmse:2.08397	validation_1-rmse:3.33219
# [66]	validation_0-rmse:2.07479	validation_1-rmse:3.32593
# [67]	validation_0-rmse:2.07127	validation_1-rmse:3.31995
# [68]	validation_0-rmse:2.05133	validation_1-rmse:3.36120
# [69]	validation_0-rmse:2.02428	validation_1-rmse:3.35389
# [70]	validation_0-rmse:2.00345	validation_1-rmse:3.35244
# [71]	validation_0-rmse:1.99811	validation_1-rmse:3.34336
# [72]	validation_0-rmse:1.99374	validation_1-rmse:3.33319
# [73]	validation_0-rmse:1.98851	validation_1-rmse:3.33759
# [74]	validation_0-rmse:1.97491	validation_1-rmse:3.32778
# [75]	validation_0-rmse:1.96924	validation_1-rmse:3.32347
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:11.88759	validation_1-rmse:12.50163
# [1]	validation_0-rmse:9.49403	validation_1-rmse:10.32067
# [2]	validation_0-rmse:7.62694	validation_1-rmse:8.67148
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:6.40894	validation_1-rmse:7.71339
# [4]	validation_0-rmse:5.43289	validation_1-rmse:6.93701
# [5]	validation_0-rmse:4.74587	validation_1-rmse:6.46485
# [6]	validation_0-rmse:4.21273	validation_1-rmse:6.04993
# [7]	validation_0-rmse:3.84752	validation_1-rmse:5.80418
# [8]	validation_0-rmse:3.59146	validation_1-rmse:5.58655
# [9]	validation_0-rmse:3.41518	validation_1-rmse:5.54691
# [10]	validation_0-rmse:3.29673	validation_1-rmse:5.28566
# [11]	validation_0-rmse:3.19410	validation_1-rmse:5.23419
# [12]	validation_0-rmse:3.09351	validation_1-rmse:5.17785
# [13]	validation_0-rmse:3.02803	validation_1-rmse:5.12309
# [14]	validation_0-rmse:2.98547	validation_1-rmse:5.10971
# [15]	validation_0-rmse:2.96087	validation_1-rmse:5.11651
# [16]	validation_0-rmse:2.92297	validation_1-rmse:5.09139
# [17]	validation_0-rmse:2.82152	validation_1-rmse:4.89111
# [18]	validation_0-rmse:2.78983	validation_1-rmse:4.88033
# [19]	validation_0-rmse:2.77296	validation_1-rmse:4.85906
# [20]	validation_0-rmse:2.70285	validation_1-rmse:4.72177
# [21]	validation_0-rmse:2.66899	validation_1-rmse:4.64879
# [22]	validation_0-rmse:2.62331	validation_1-rmse:4.63926
# [23]	validation_0-rmse:2.59246	validation_1-rmse:4.64127
# [24]	validation_0-rmse:2.57729	validation_1-rmse:4.61890
# [25]	validation_0-rmse:2.54878	validation_1-rmse:4.57627
# [26]	validation_0-rmse:2.52459	validation_1-rmse:4.55363
# [27]	validation_0-rmse:2.48955	validation_1-rmse:4.47111
# [28]	validation_0-rmse:2.47897	validation_1-rmse:4.47411
# [29]	validation_0-rmse:2.43390	validation_1-rmse:4.41599
# [30]	validation_0-rmse:2.40900	validation_1-rmse:4.39771
# [31]	validation_0-rmse:2.39633	validation_1-rmse:4.40775
# [32]	validation_0-rmse:2.37799	validation_1-rmse:4.41338
# [33]	validation_0-rmse:2.36280	validation_1-rmse:4.38973
# [34]	validation_0-rmse:2.35019	validation_1-rmse:4.37124
# [35]	validation_0-rmse:2.33620	validation_1-rmse:4.34090
# [36]	validation_0-rmse:2.31444	validation_1-rmse:4.31208
# [37]	validation_0-rmse:2.29660	validation_1-rmse:4.32834
# [38]	validation_0-rmse:2.28299	validation_1-rmse:4.31020
# [39]	validation_0-rmse:2.27371	validation_1-rmse:4.29032
# [40]	validation_0-rmse:2.25077	validation_1-rmse:4.29881
# [41]	validation_0-rmse:2.24108	validation_1-rmse:4.29780
# [42]	validation_0-rmse:2.22284	validation_1-rmse:4.28095
# [43]	validation_0-rmse:2.20534	validation_1-rmse:4.29147
# [44]	validation_0-rmse:2.18931	validation_1-rmse:4.28238
# [45]	validation_0-rmse:2.17153	validation_1-rmse:4.28617
# [46]	validation_0-rmse:2.16051	validation_1-rmse:4.28448
# [47]	validation_0-rmse:2.13932	validation_1-rmse:4.27939
# [48]	validation_0-rmse:2.12507	validation_1-rmse:4.26843
# [49]	validation_0-rmse:2.11542	validation_1-rmse:4.25759
# [50]	validation_0-rmse:2.11062	validation_1-rmse:4.25381
# [51]	validation_0-rmse:2.09076	validation_1-rmse:4.27005
# [52]	validation_0-rmse:2.07924	validation_1-rmse:4.27851
# [53]	validation_0-rmse:2.07141	validation_1-rmse:4.27797
# [54]	validation_0-rmse:2.06579	validation_1-rmse:4.27527
# [55]	validation_0-rmse:2.06027	validation_1-rmse:4.29422
# [56]	validation_0-rmse:2.05322	validation_1-rmse:4.28738
# [57]	validation_0-rmse:2.03896	validation_1-rmse:4.28109
# [58]	validation_0-rmse:2.02378	validation_1-rmse:4.27594
# [59]	validation_0-rmse:2.01301	validation_1-rmse:4.28353
# [60]	validation_0-rmse:1.99732	validation_1-rmse:4.25119
# [61]	validation_0-rmse:1.98509	validation_1-rmse:4.24597
# [62]	validation_0-rmse:1.97725	validation_1-rmse:4.24047
# [63]	validation_0-rmse:1.97190	validation_1-rmse:4.24248
# [64]	validation_0-rmse:1.95900	validation_1-rmse:4.23859
# [65]	validation_0-rmse:1.94539	validation_1-rmse:4.23370
# [66]	validation_0-rmse:1.93806	validation_1-rmse:4.23854
# [67]	validation_0-rmse:1.93084	validation_1-rmse:4.20755
# [68]	validation_0-rmse:1.92290	validation_1-rmse:4.20375
# [69]	validation_0-rmse:1.90622	validation_1-rmse:4.20617
# [70]	validation_0-rmse:1.89255	validation_1-rmse:4.19370
# [71]	validation_0-rmse:1.88601	validation_1-rmse:4.19157
# [72]	validation_0-rmse:1.87922	validation_1-rmse:4.17813
# [73]	validation_0-rmse:1.87818	validation_1-rmse:4.19090
# [74]	validation_0-rmse:1.86280	validation_1-rmse:4.18716
# [75]	validation_0-rmse:1.85316	validation_1-rmse:4.14237
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:11.76130	validation_1-rmse:13.15841
# [1]	validation_0-rmse:9.55618	validation_1-rmse:10.85434
# [2]	validation_0-rmse:7.80077	validation_1-rmse:9.22143
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:6.54512	validation_1-rmse:8.01990
# [4]	validation_0-rmse:5.53857	validation_1-rmse:7.12982
# [5]	validation_0-rmse:4.93504	validation_1-rmse:6.57844
# [6]	validation_0-rmse:4.37834	validation_1-rmse:5.76343
# [7]	validation_0-rmse:4.00572	validation_1-rmse:5.40881
# [8]	validation_0-rmse:3.74561	validation_1-rmse:5.24436
# [9]	validation_0-rmse:3.59974	validation_1-rmse:5.17127
# [10]	validation_0-rmse:3.50326	validation_1-rmse:5.07530
# [11]	validation_0-rmse:3.35857	validation_1-rmse:4.94389
# [12]	validation_0-rmse:3.30943	validation_1-rmse:4.91026
# [13]	validation_0-rmse:3.20615	validation_1-rmse:4.89531
# [14]	validation_0-rmse:3.17072	validation_1-rmse:4.89275
# [15]	validation_0-rmse:3.09017	validation_1-rmse:4.63090
# [16]	validation_0-rmse:3.01156	validation_1-rmse:4.63400
# [17]	validation_0-rmse:2.93338	validation_1-rmse:4.36969
# [18]	validation_0-rmse:2.90922	validation_1-rmse:4.38215
# [19]	validation_0-rmse:2.88297	validation_1-rmse:4.39461
# [20]	validation_0-rmse:2.84559	validation_1-rmse:4.35907
# [21]	validation_0-rmse:2.80456	validation_1-rmse:4.38365
# [22]	validation_0-rmse:2.78494	validation_1-rmse:4.37300
# [23]	validation_0-rmse:2.76248	validation_1-rmse:4.37533
# [24]	validation_0-rmse:2.74344	validation_1-rmse:4.36398
# [25]	validation_0-rmse:2.71548	validation_1-rmse:4.26392
# [26]	validation_0-rmse:2.66894	validation_1-rmse:4.20011
# [27]	validation_0-rmse:2.63086	validation_1-rmse:4.00732
# [28]	validation_0-rmse:2.62427	validation_1-rmse:4.00056
# [29]	validation_0-rmse:2.59964	validation_1-rmse:4.03561
# [30]	validation_0-rmse:2.56558	validation_1-rmse:4.01833
# [31]	validation_0-rmse:2.55803	validation_1-rmse:4.01254
# [32]	validation_0-rmse:2.53982	validation_1-rmse:4.02330
# [33]	validation_0-rmse:2.52832	validation_1-rmse:4.02245
# [34]	validation_0-rmse:2.49584	validation_1-rmse:4.00401
# [35]	validation_0-rmse:2.47928	validation_1-rmse:4.00379
# [36]	validation_0-rmse:2.47046	validation_1-rmse:3.99855
# [37]	validation_0-rmse:2.45092	validation_1-rmse:4.02568
# [38]	validation_0-rmse:2.44169	validation_1-rmse:4.03461
# [39]	validation_0-rmse:2.42884	validation_1-rmse:4.04836
# [40]	validation_0-rmse:2.40368	validation_1-rmse:3.99393
# [41]	validation_0-rmse:2.36430	validation_1-rmse:3.99491
# [42]	validation_0-rmse:2.34783	validation_1-rmse:4.01483
# [43]	validation_0-rmse:2.33201	validation_1-rmse:4.01575
# [44]	validation_0-rmse:2.30853	validation_1-rmse:3.95937
# [45]	validation_0-rmse:2.28757	validation_1-rmse:3.97180
# [46]	validation_0-rmse:2.28532	validation_1-rmse:4.01201
# [47]	validation_0-rmse:2.26982	validation_1-rmse:4.00852
# [48]	validation_0-rmse:2.24149	validation_1-rmse:4.00281
# [49]	validation_0-rmse:2.22864	validation_1-rmse:4.00572
# [50]	validation_0-rmse:2.21994	validation_1-rmse:3.98824
# [51]	validation_0-rmse:2.21037	validation_1-rmse:4.01059
# [52]	validation_0-rmse:2.18314	validation_1-rmse:3.95798
# [53]	validation_0-rmse:2.17050	validation_1-rmse:3.95646
# [54]	validation_0-rmse:2.15732	validation_1-rmse:3.95570
# [55]	validation_0-rmse:2.14236	validation_1-rmse:3.93809
# [56]	validation_0-rmse:2.13583	validation_1-rmse:3.94307
# [57]	validation_0-rmse:2.13483	validation_1-rmse:3.93847
# [58]	validation_0-rmse:2.11280	validation_1-rmse:3.96098
# [59]	validation_0-rmse:2.10638	validation_1-rmse:3.96065
# [60]	validation_0-rmse:2.08713	validation_1-rmse:3.99457
# [61]	validation_0-rmse:2.07057	validation_1-rmse:4.00262
# [62]	validation_0-rmse:2.05565	validation_1-rmse:3.98148
# [63]	validation_0-rmse:2.04584	validation_1-rmse:3.98957
# [64]	validation_0-rmse:2.01989	validation_1-rmse:4.00929
# [65]	validation_0-rmse:2.00218	validation_1-rmse:4.01077
# [66]	validation_0-rmse:1.99203	validation_1-rmse:4.01608
# [67]	validation_0-rmse:1.98406	validation_1-rmse:4.01342
# [68]	validation_0-rmse:1.98042	validation_1-rmse:4.00823
# [69]	validation_0-rmse:1.96347	validation_1-rmse:4.00643
# [70]	validation_0-rmse:1.95292	validation_1-rmse:3.97212
# [71]	validation_0-rmse:1.94449	validation_1-rmse:3.96345
# [72]	validation_0-rmse:1.93461	validation_1-rmse:3.96567
# [73]	validation_0-rmse:1.92171	validation_1-rmse:3.93381
# [74]	validation_0-rmse:1.91160	validation_1-rmse:3.93113
# [75]	validation_0-rmse:1.89302	validation_1-rmse:3.92946
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:11.93755	validation_1-rmse:12.04594
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:9.61883	validation_1-rmse:10.00365
# [2]	validation_0-rmse:7.97898	validation_1-rmse:8.61958
# [3]	validation_0-rmse:6.70344	validation_1-rmse:7.48813
# [4]	validation_0-rmse:5.70459	validation_1-rmse:6.69191
# [5]	validation_0-rmse:5.03192	validation_1-rmse:6.29158
# [6]	validation_0-rmse:4.49473	validation_1-rmse:5.89676
# [7]	validation_0-rmse:4.10859	validation_1-rmse:5.51297
# [8]	validation_0-rmse:3.82543	validation_1-rmse:5.33659
# [9]	validation_0-rmse:3.69157	validation_1-rmse:5.24995
# [10]	validation_0-rmse:3.56344	validation_1-rmse:5.17165
# [11]	validation_0-rmse:3.40657	validation_1-rmse:5.01210
# [12]	validation_0-rmse:3.33355	validation_1-rmse:4.95780
# [13]	validation_0-rmse:3.22552	validation_1-rmse:4.83661
# [14]	validation_0-rmse:3.15707	validation_1-rmse:4.81607
# [15]	validation_0-rmse:3.10449	validation_1-rmse:4.79237
# [16]	validation_0-rmse:3.07426	validation_1-rmse:4.77807
# [17]	validation_0-rmse:2.99552	validation_1-rmse:4.73012
# [18]	validation_0-rmse:2.95682	validation_1-rmse:4.71402
# [19]	validation_0-rmse:2.92283	validation_1-rmse:4.72871
# [20]	validation_0-rmse:2.86921	validation_1-rmse:4.74748
# [21]	validation_0-rmse:2.77790	validation_1-rmse:4.63617
# [22]	validation_0-rmse:2.73995	validation_1-rmse:4.56499
# [23]	validation_0-rmse:2.72570	validation_1-rmse:4.56727
# [24]	validation_0-rmse:2.70024	validation_1-rmse:4.55203
# [25]	validation_0-rmse:2.66964	validation_1-rmse:4.51492
# [26]	validation_0-rmse:2.63224	validation_1-rmse:4.47266
# [27]	validation_0-rmse:2.58342	validation_1-rmse:4.40445
# [28]	validation_0-rmse:2.54518	validation_1-rmse:4.38023
# [29]	validation_0-rmse:2.52767	validation_1-rmse:4.36700
# [30]	validation_0-rmse:2.49969	validation_1-rmse:4.35479
# [31]	validation_0-rmse:2.48697	validation_1-rmse:4.35184
# [32]	validation_0-rmse:2.46650	validation_1-rmse:4.34158
# [33]	validation_0-rmse:2.45467	validation_1-rmse:4.30660
# [34]	validation_0-rmse:2.42939	validation_1-rmse:4.31163
# [35]	validation_0-rmse:2.41017	validation_1-rmse:4.30656
# [36]	validation_0-rmse:2.38227	validation_1-rmse:4.31739
# [37]	validation_0-rmse:2.35847	validation_1-rmse:4.29459
# [38]	validation_0-rmse:2.33524	validation_1-rmse:4.31878
# [39]	validation_0-rmse:2.32981	validation_1-rmse:4.32039
# [40]	validation_0-rmse:2.31450	validation_1-rmse:4.31254
# [41]	validation_0-rmse:2.29236	validation_1-rmse:4.31240
# [42]	validation_0-rmse:2.27162	validation_1-rmse:4.30503
# [43]	validation_0-rmse:2.23892	validation_1-rmse:4.26550
# [44]	validation_0-rmse:2.21111	validation_1-rmse:4.27623
# [45]	validation_0-rmse:2.18342	validation_1-rmse:4.26570
# [46]	validation_0-rmse:2.17220	validation_1-rmse:4.26893
# [47]	validation_0-rmse:2.16276	validation_1-rmse:4.26346
# [48]	validation_0-rmse:2.15104	validation_1-rmse:4.25631
# [49]	validation_0-rmse:2.14433	validation_1-rmse:4.25433
# [50]	validation_0-rmse:2.12425	validation_1-rmse:4.26128
# [51]	validation_0-rmse:2.11626	validation_1-rmse:4.24962
# [52]	validation_0-rmse:2.10017	validation_1-rmse:4.26198
# [53]	validation_0-rmse:2.09523	validation_1-rmse:4.25642
# [54]	validation_0-rmse:2.08640	validation_1-rmse:4.25020
# [55]	validation_0-rmse:2.07768	validation_1-rmse:4.25121
# [56]	validation_0-rmse:2.06523	validation_1-rmse:4.24240
# [57]	validation_0-rmse:2.06153	validation_1-rmse:4.24071
# [58]	validation_0-rmse:2.05377	validation_1-rmse:4.21285
# [59]	validation_0-rmse:2.04735	validation_1-rmse:4.21352
# ...
# [15]	validation_0-rmse:3.07314	validation_1-rmse:3.64306
# [16]	validation_0-rmse:3.03856	validation_1-rmse:3.61654
# [17]	validation_0-rmse:2.99961	validation_1-rmse:3.59958
# [18]	validation_0-rmse:2.94456	validation_1-rmse:3.61050
# [19]	validation_0-rmse:2.89229	validation_1-rmse:3.77099
# [20]	validation_0-rmse:2.85200	validation_1-rmse:3.76607
# [21]	validation_0-rmse:2.81127	validation_1-rmse:3.75867
# [22]	validation_0-rmse:2.75686	validation_1-rmse:3.76421
# [23]	validation_0-rmse:2.74574	validation_1-rmse:3.74945
# [24]	validation_0-rmse:2.72573	validation_1-rmse:3.74630
# [25]	validation_0-rmse:2.66502	validation_1-rmse:3.66510
# [26]	validation_0-rmse:2.64759	validation_1-rmse:3.66134
# [27]	validation_0-rmse:2.63898	validation_1-rmse:3.66676
# [28]	validation_0-rmse:2.60457	validation_1-rmse:3.61411
# [29]	validation_0-rmse:2.57242	validation_1-rmse:3.57707
# [30]	validation_0-rmse:2.53510	validation_1-rmse:3.55665
# [31]	validation_0-rmse:2.50452	validation_1-rmse:3.54547
# [32]	validation_0-rmse:2.48669	validation_1-rmse:3.53585
# [33]	validation_0-rmse:2.46657	validation_1-rmse:3.57346
# [34]	validation_0-rmse:2.44304	validation_1-rmse:3.56480
# [35]	validation_0-rmse:2.41066	validation_1-rmse:3.57191
# [36]	validation_0-rmse:2.39150	validation_1-rmse:3.56636
# [37]	validation_0-rmse:2.37439	validation_1-rmse:3.55404
# [38]	validation_0-rmse:2.35737	validation_1-rmse:3.52639
# [39]	validation_0-rmse:2.35072	validation_1-rmse:3.51851
# [40]	validation_0-rmse:2.32986	validation_1-rmse:3.50116
# [41]	validation_0-rmse:2.30937	validation_1-rmse:3.53018
# [42]	validation_0-rmse:2.30333	validation_1-rmse:3.52436
# [43]	validation_0-rmse:2.29048	validation_1-rmse:3.53328
# [44]	validation_0-rmse:2.27870	validation_1-rmse:3.51128
# [45]	validation_0-rmse:2.26053	validation_1-rmse:3.51552
# [46]	validation_0-rmse:2.23724	validation_1-rmse:3.50393
# [47]	validation_0-rmse:2.22580	validation_1-rmse:3.54879
# [48]	validation_0-rmse:2.21380	validation_1-rmse:3.54307
# [49]	validation_0-rmse:2.20819	validation_1-rmse:3.53639
# [50]	validation_0-rmse:2.19655	validation_1-rmse:3.53798
# [51]	validation_0-rmse:2.18251	validation_1-rmse:3.52141
# [52]	validation_0-rmse:2.15772	validation_1-rmse:3.51096
# [53]	validation_0-rmse:2.14352	validation_1-rmse:3.51894
# [54]	validation_0-rmse:2.12826	validation_1-rmse:3.51383
# [55]	validation_0-rmse:2.12074	validation_1-rmse:3.52570
# [56]	validation_0-rmse:2.08995	validation_1-rmse:3.49631
# [57]	validation_0-rmse:2.07671	validation_1-rmse:3.49574
# [58]	validation_0-rmse:2.05953	validation_1-rmse:3.51073
# [59]	validation_0-rmse:2.04427	validation_1-rmse:3.49346
# [60]	validation_0-rmse:2.01285	validation_1-rmse:3.47658
# [61]	validation_0-rmse:1.99906	validation_1-rmse:3.47450
# [62]	validation_0-rmse:1.98862	validation_1-rmse:3.47966
# [63]	validation_0-rmse:1.95266	validation_1-rmse:3.47095
# [64]	validation_0-rmse:1.93621	validation_1-rmse:3.46216
# [65]	validation_0-rmse:1.92269	validation_1-rmse:3.46361
# [66]	validation_0-rmse:1.91669	validation_1-rmse:3.47094
# [67]	validation_0-rmse:1.89425	validation_1-rmse:3.45746
# [68]	validation_0-rmse:1.88436	validation_1-rmse:3.45446
# [69]	validation_0-rmse:1.86091	validation_1-rmse:3.42878
# [70]	validation_0-rmse:1.84459	validation_1-rmse:3.45105
# [71]	validation_0-rmse:1.83149	validation_1-rmse:3.42112
# [72]	validation_0-rmse:1.81645	validation_1-rmse:3.42923
# [73]	validation_0-rmse:1.80854	validation_1-rmse:3.44541
# [74]	validation_0-rmse:1.80053	validation_1-rmse:3.43097
# [75]	validation_0-rmse:1.79864	validation_1-rmse:3.43748
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:12.08256	validation_1-rmse:11.81163
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:9.79306	validation_1-rmse:9.38965
# [2]	validation_0-rmse:8.04007	validation_1-rmse:7.58490
# [3]	validation_0-rmse:6.77365	validation_1-rmse:6.40384
# [4]	validation_0-rmse:5.75580	validation_1-rmse:5.50658
# [5]	validation_0-rmse:5.10725	validation_1-rmse:4.88488
# [6]	validation_0-rmse:4.56677	validation_1-rmse:4.45956
# [7]	validation_0-rmse:4.16266	validation_1-rmse:4.15811
# [8]	validation_0-rmse:3.84589	validation_1-rmse:3.80800
# [9]	validation_0-rmse:3.64302	validation_1-rmse:3.56403
# [10]	validation_0-rmse:3.46333	validation_1-rmse:3.49127
# [11]	validation_0-rmse:3.33690	validation_1-rmse:3.41067
# [12]	validation_0-rmse:3.28050	validation_1-rmse:3.35857
# [13]	validation_0-rmse:3.22013	validation_1-rmse:3.33961
# [14]	validation_0-rmse:3.13106	validation_1-rmse:3.33733
# [15]	validation_0-rmse:3.07731	validation_1-rmse:3.22447
# [16]	validation_0-rmse:3.05331	validation_1-rmse:3.19512
# [17]	validation_0-rmse:3.00242	validation_1-rmse:3.22081
# [18]	validation_0-rmse:2.98491	validation_1-rmse:3.15043
# [19]	validation_0-rmse:2.94712	validation_1-rmse:3.14263
# [20]	validation_0-rmse:2.92191	validation_1-rmse:3.14195
# [21]	validation_0-rmse:2.84263	validation_1-rmse:3.27837
# [22]	validation_0-rmse:2.81664	validation_1-rmse:3.30010
# [23]	validation_0-rmse:2.80210	validation_1-rmse:3.29422
# [24]	validation_0-rmse:2.75535	validation_1-rmse:3.32063
# [25]	validation_0-rmse:2.72055	validation_1-rmse:3.28221
# [26]	validation_0-rmse:2.68123	validation_1-rmse:3.30571
# [27]	validation_0-rmse:2.65212	validation_1-rmse:3.34666
# [28]	validation_0-rmse:2.60022	validation_1-rmse:3.31694
# [29]	validation_0-rmse:2.58455	validation_1-rmse:3.30646
# [30]	validation_0-rmse:2.57193	validation_1-rmse:3.31519
# [31]	validation_0-rmse:2.56427	validation_1-rmse:3.31301
# [32]	validation_0-rmse:2.53895	validation_1-rmse:3.37774
# [33]	validation_0-rmse:2.51998	validation_1-rmse:3.36208
# [34]	validation_0-rmse:2.49954	validation_1-rmse:3.33999
# [35]	validation_0-rmse:2.48301	validation_1-rmse:3.34435
# [36]	validation_0-rmse:2.46471	validation_1-rmse:3.34904
# [37]	validation_0-rmse:2.44269	validation_1-rmse:3.33298
# [38]	validation_0-rmse:2.43584	validation_1-rmse:3.33195
# [39]	validation_0-rmse:2.41678	validation_1-rmse:3.31331
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:11.78224	validation_1-rmse:13.16638
# [1]	validation_0-rmse:9.47609	validation_1-rmse:10.73473
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:7.77384	validation_1-rmse:8.97676
# [3]	validation_0-rmse:6.60230	validation_1-rmse:7.74167
# [4]	validation_0-rmse:5.63439	validation_1-rmse:6.65208
# [5]	validation_0-rmse:4.92811	validation_1-rmse:5.91037
# [6]	validation_0-rmse:4.41704	validation_1-rmse:5.24933
# [7]	validation_0-rmse:4.08389	validation_1-rmse:4.90316
# [8]	validation_0-rmse:3.84212	validation_1-rmse:4.67315
# [9]	validation_0-rmse:3.70053	validation_1-rmse:4.54303
# [10]	validation_0-rmse:3.55304	validation_1-rmse:4.37492
# [11]	validation_0-rmse:3.45917	validation_1-rmse:4.30732
# [12]	validation_0-rmse:3.37570	validation_1-rmse:4.26252
# [13]	validation_0-rmse:3.25689	validation_1-rmse:4.06463
# [14]	validation_0-rmse:3.18564	validation_1-rmse:4.01473
# [15]	validation_0-rmse:3.08494	validation_1-rmse:3.88170
# [16]	validation_0-rmse:3.06987	validation_1-rmse:3.86738
# [17]	validation_0-rmse:3.02635	validation_1-rmse:3.83617
# [18]	validation_0-rmse:2.96738	validation_1-rmse:3.87445
# [19]	validation_0-rmse:2.93405	validation_1-rmse:3.86211
# [20]	validation_0-rmse:2.87039	validation_1-rmse:3.78484
# [21]	validation_0-rmse:2.83899	validation_1-rmse:3.76145
# [22]	validation_0-rmse:2.79535	validation_1-rmse:3.67753
# [23]	validation_0-rmse:2.73589	validation_1-rmse:3.70096
# [24]	validation_0-rmse:2.69036	validation_1-rmse:3.69467
# [25]	validation_0-rmse:2.66552	validation_1-rmse:3.68552
# [26]	validation_0-rmse:2.65331	validation_1-rmse:3.68306
# [27]	validation_0-rmse:2.63474	validation_1-rmse:3.68633
# [28]	validation_0-rmse:2.62589	validation_1-rmse:3.67381
# [29]	validation_0-rmse:2.59684	validation_1-rmse:3.68862
# [30]	validation_0-rmse:2.56105	validation_1-rmse:3.63693
# [31]	validation_0-rmse:2.55084	validation_1-rmse:3.63302
# [32]	validation_0-rmse:2.53754	validation_1-rmse:3.62207
# [33]	validation_0-rmse:2.51111	validation_1-rmse:3.61655
# [34]	validation_0-rmse:2.48050	validation_1-rmse:3.62869
# [35]	validation_0-rmse:2.45427	validation_1-rmse:3.61960
# [36]	validation_0-rmse:2.44782	validation_1-rmse:3.61559
# [37]	validation_0-rmse:2.42654	validation_1-rmse:3.59892
# [38]	validation_0-rmse:2.40862	validation_1-rmse:3.59897
# [39]	validation_0-rmse:2.37775	validation_1-rmse:3.59269
# [40]	validation_0-rmse:2.37276	validation_1-rmse:3.58091
# [41]	validation_0-rmse:2.35385	validation_1-rmse:3.55693
# [42]	validation_0-rmse:2.34061	validation_1-rmse:3.55963
# [43]	validation_0-rmse:2.33585	validation_1-rmse:3.56598
# [44]	validation_0-rmse:2.30997	validation_1-rmse:3.57210
# [45]	validation_0-rmse:2.29084	validation_1-rmse:3.55647
# [46]	validation_0-rmse:2.28801	validation_1-rmse:3.58465
# [47]	validation_0-rmse:2.27405	validation_1-rmse:3.57512
# [48]	validation_0-rmse:2.25659	validation_1-rmse:3.57106
# [49]	validation_0-rmse:2.24504	validation_1-rmse:3.56391
# [50]	validation_0-rmse:2.23564	validation_1-rmse:3.57321
# [51]	validation_0-rmse:2.22322	validation_1-rmse:3.57299
# [52]	validation_0-rmse:2.20924	validation_1-rmse:3.54984
# [53]	validation_0-rmse:2.19971	validation_1-rmse:3.54933
# [54]	validation_0-rmse:2.18895	validation_1-rmse:3.56507
# [55]	validation_0-rmse:2.18446	validation_1-rmse:3.56476
# [56]	validation_0-rmse:2.15269	validation_1-rmse:3.57611
# [57]	validation_0-rmse:2.13324	validation_1-rmse:3.58491
# [58]	validation_0-rmse:2.12175	validation_1-rmse:3.58565
# [59]	validation_0-rmse:2.10988	validation_1-rmse:3.59019
# [60]	validation_0-rmse:2.09404	validation_1-rmse:3.58588
# [61]	validation_0-rmse:2.08194	validation_1-rmse:3.57786
# [62]	validation_0-rmse:2.07077	validation_1-rmse:3.57507
# [63]	validation_0-rmse:2.06355	validation_1-rmse:3.58217
# [64]	validation_0-rmse:2.04748	validation_1-rmse:3.56665
# [65]	validation_0-rmse:2.04174	validation_1-rmse:3.55023
# [66]	validation_0-rmse:2.02867	validation_1-rmse:3.55403
# [67]	validation_0-rmse:2.00612	validation_1-rmse:3.53878
# [68]	validation_0-rmse:1.99390	validation_1-rmse:3.50928
# [69]	validation_0-rmse:1.98229	validation_1-rmse:3.47277
# [70]	validation_0-rmse:1.96534	validation_1-rmse:3.46810
# [71]	validation_0-rmse:1.95374	validation_1-rmse:3.49086
# [72]	validation_0-rmse:1.94593	validation_1-rmse:3.46958
# [73]	validation_0-rmse:1.94561	validation_1-rmse:3.46447
# [74]	validation_0-rmse:1.93539	validation_1-rmse:3.47139
# [75]	validation_0-rmse:1.92475	validation_1-rmse:3.45444
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:11.90838	validation_1-rmse:12.45361
# [1]	validation_0-rmse:9.51958	validation_1-rmse:10.05967
# [2]	validation_0-rmse:7.95376	validation_1-rmse:8.27098
# [3]	validation_0-rmse:6.79251	validation_1-rmse:6.92410
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:5.86190	validation_1-rmse:5.97724
# [5]	validation_0-rmse:5.09658	validation_1-rmse:5.21838
# [6]	validation_0-rmse:4.58292	validation_1-rmse:4.66700
# [7]	validation_0-rmse:4.19918	validation_1-rmse:4.36175
# [8]	validation_0-rmse:3.84992	validation_1-rmse:4.15111
# [9]	validation_0-rmse:3.68307	validation_1-rmse:4.05125
# [10]	validation_0-rmse:3.52371	validation_1-rmse:3.83770
# [11]	validation_0-rmse:3.37850	validation_1-rmse:3.78068
# [12]	validation_0-rmse:3.29746	validation_1-rmse:3.71186
# [13]	validation_0-rmse:3.20386	validation_1-rmse:3.70419
# [14]	validation_0-rmse:3.14162	validation_1-rmse:3.70717
# [15]	validation_0-rmse:3.09212	validation_1-rmse:3.69572
# [16]	validation_0-rmse:3.03149	validation_1-rmse:3.70605
# [17]	validation_0-rmse:2.98728	validation_1-rmse:3.67139
# [18]	validation_0-rmse:2.95902	validation_1-rmse:3.65659
# [19]	validation_0-rmse:2.89801	validation_1-rmse:3.69822
# [20]	validation_0-rmse:2.84373	validation_1-rmse:3.70652
# [21]	validation_0-rmse:2.82102	validation_1-rmse:3.70294
# [22]	validation_0-rmse:2.79381	validation_1-rmse:3.68304
# [23]	validation_0-rmse:2.78200	validation_1-rmse:3.67690
# [24]	validation_0-rmse:2.76533	validation_1-rmse:3.65246
# [25]	validation_0-rmse:2.72640	validation_1-rmse:3.62533
# [26]	validation_0-rmse:2.71156	validation_1-rmse:3.63960
# [27]	validation_0-rmse:2.65996	validation_1-rmse:3.55080
# [28]	validation_0-rmse:2.64964	validation_1-rmse:3.53454
# [29]	validation_0-rmse:2.58095	validation_1-rmse:3.48352
# [30]	validation_0-rmse:2.56258	validation_1-rmse:3.47778
# [31]	validation_0-rmse:2.55381	validation_1-rmse:3.47722
# [32]	validation_0-rmse:2.54737	validation_1-rmse:3.47213
# [33]	validation_0-rmse:2.52248	validation_1-rmse:3.46611
# [34]	validation_0-rmse:2.50672	validation_1-rmse:3.45264
# [35]	validation_0-rmse:2.48999	validation_1-rmse:3.45551
# [36]	validation_0-rmse:2.46113	validation_1-rmse:3.42107
# [37]	validation_0-rmse:2.45202	validation_1-rmse:3.42736
# [38]	validation_0-rmse:2.43263	validation_1-rmse:3.42667
# [39]	validation_0-rmse:2.42467	validation_1-rmse:3.41592
# [40]	validation_0-rmse:2.41615	validation_1-rmse:3.41381
# [41]	validation_0-rmse:2.37783	validation_1-rmse:3.35583
# [42]	validation_0-rmse:2.35931	validation_1-rmse:3.32254
# [43]	validation_0-rmse:2.32404	validation_1-rmse:3.28575
# [44]	validation_0-rmse:2.30177	validation_1-rmse:3.24751
# [45]	validation_0-rmse:2.28387	validation_1-rmse:3.25699
# [46]	validation_0-rmse:2.26455	validation_1-rmse:3.25832
# [47]	validation_0-rmse:2.25084	validation_1-rmse:3.25186
# [48]	validation_0-rmse:2.23075	validation_1-rmse:3.24573
# [49]	validation_0-rmse:2.22470	validation_1-rmse:3.25279
# [50]	validation_0-rmse:2.21420	validation_1-rmse:3.25458
# [51]	validation_0-rmse:2.20775	validation_1-rmse:3.24862
# [52]	validation_0-rmse:2.19296	validation_1-rmse:3.23522
# [53]	validation_0-rmse:2.17541	validation_1-rmse:3.24576
# [54]	validation_0-rmse:2.15735	validation_1-rmse:3.21493
# [55]	validation_0-rmse:2.14711	validation_1-rmse:3.21120
# [56]	validation_0-rmse:2.12830	validation_1-rmse:3.23172
# [57]	validation_0-rmse:2.12624	validation_1-rmse:3.22690
# [58]	validation_0-rmse:2.10150	validation_1-rmse:3.20923
# [59]	validation_0-rmse:2.09346	validation_1-rmse:3.20600
# [60]	validation_0-rmse:2.08618	validation_1-rmse:3.20691
# [61]	validation_0-rmse:2.07173	validation_1-rmse:3.19983
# [62]	validation_0-rmse:2.05865	validation_1-rmse:3.19804
# [63]	validation_0-rmse:2.05227	validation_1-rmse:3.19962
# [64]	validation_0-rmse:2.02683	validation_1-rmse:3.17938
# [65]	validation_0-rmse:2.01259	validation_1-rmse:3.16437
# [66]	validation_0-rmse:2.00990	validation_1-rmse:3.16369
# [67]	validation_0-rmse:1.99890	validation_1-rmse:3.14428
# [68]	validation_0-rmse:1.99130	validation_1-rmse:3.14225
# [69]	validation_0-rmse:1.96807	validation_1-rmse:3.14995
# [70]	validation_0-rmse:1.95996	validation_1-rmse:3.14297
# [71]	validation_0-rmse:1.95778	validation_1-rmse:3.14301
# [72]	validation_0-rmse:1.93455	validation_1-rmse:3.15605
# [73]	validation_0-rmse:1.92758	validation_1-rmse:3.13153
# [74]	validation_0-rmse:1.91050	validation_1-rmse:3.13776
# [75]	validation_0-rmse:1.89626	validation_1-rmse:3.13555
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(0.6, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.871
# Uncertainty
# a0: 1.732+/-0.184
# a1: 0.8551+/-0.012

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: BA_sq_m_ha: mean - 2.953, median - 2.953, CI - [2.805-3.114]
#
# SHAP-values for: DBH_cm: mean - 0.629, median - 0.621, CI - [0.526-0.722]
#
# SHAP-values for: H_m: mean - 2.285, median - 2.293, CI - [2.08-2.512]
#
# SHAP-values for: Origin_ID: mean - 0.135, median - 0.138, CI - [0.089-0.173]
#
# SHAP-values for: Species_ID: mean - 4.573, median - 4.59, CI - [4.413-4.716]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['Species_ID', 'BA_sq_m_ha', 'H_m', 'DBH_cm', 'Origin_ID'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 54.14, median: 61.0,
#  pred. interval (P(0.025)-P(0.975)): 15.975-75.0,
#  conf. interval (p-value=0.95): 33.074-72.794
# ***
# Aggregate bias statistic:
#  mean: -0.01, median: -0.016,
#  pred. interval (P(0.025)-P(0.975)): -0.703-0.557,
#  conf. interval (p-value=0.95): -0.257-0.262
# ***
# Aggregate RMSE statistic:
#  mean: 3.401, median: 3.381, pred. interval (P(0.025)-P(0.975)): 2.774-4.192,
#  conf. interval (p-value=0.95): 3.076-3.733
# ***
# Aggregate MSE statistic:
#  mean: 11.729, median: 11.429, pred. interval (P(0.025)-P(0.975)): 7.696-17.569,
#  conf. interval (p-value=0.95): 9.47-13.953
# ***
# Aggregate R^2 statistic:
#  mean: 0.867, median: 0.873, pred. interval (P(0.025)-P(0.975)): 0.794-0.922,
#  conf. interval (p-value=0.95): 0.838-0.897
# ***
# Aggregate bias(%) statistic:
#  mean: -0.014, median: -0.131, pred. interval (P(0.025)-P(0.975)): -5.367-4.966,
#  conf. interval (p-value=0.95): -1.998-2.213
# ***
# Aggregate RMSE(%) statistic:
#  mean: 28.348, median: 27.975, pred. interval (P(0.025)-P(0.975)): 22.575-34.665,
#  conf. interval (p-value=0.95): 25.624-31.036
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing

results_y['residuals'] = results_y[predictor] - results_y[0]

results_y['residuals_%'] =  results_y['residuals'] / results_y[predictor] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Distribution of empiric values')
axs[1].hist(results_y[0])
axs[1].set_title('Distribution of predicted values')
# plt.show()
# Out:
# Text(0.5, 1.0, 'Distribution of predicted values')

# %%
# INPORTANT  - added your intervals
intervals = pd.cut(results_y[predictor], [0, 10, 20, 30, 40, 50])

grouped = results_y.groupby(intervals)

max_obs_in_group = len(results_y)    
    
pre = pd.DataFrame()
pre_rel = pd.DataFrame()

pre = pre.assign(row_number=range(max_obs_in_group))
pre_rel = pre_rel.assign(row_number=range(max_obs_in_group))

for i in range(len(list(grouped))):
    pre[list(grouped)[i][0]] = pd.Series(list(grouped)[i][1]['residuals'])
    pre_rel[list(grouped)[i][0]] = pd.Series(list(grouped)[i][1]['residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre[list(pre.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel[(pre_rel.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:12.03166
# [1]	validation_0-rmse:10.04039
# [2]	validation_0-rmse:8.17338
# [3]	validation_0-rmse:6.95438
# [4]	validation_0-rmse:5.92730
# [5]	validation_0-rmse:5.08137
# [6]	validation_0-rmse:4.58025
# [7]	validation_0-rmse:4.16023
# [8]	validation_0-rmse:3.86307
# [9]	validation_0-rmse:3.71766
# [10]	validation_0-rmse:3.55090
# [11]	validation_0-rmse:3.47380
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [12]	validation_0-rmse:3.39712
# [13]	validation_0-rmse:3.28470
# [14]	validation_0-rmse:3.25427
# [15]	validation_0-rmse:3.17358
# [16]	validation_0-rmse:3.08852
# [17]	validation_0-rmse:3.05597
# [18]	validation_0-rmse:3.03085
# [19]	validation_0-rmse:2.99067
# [20]	validation_0-rmse:2.96072
# [21]	validation_0-rmse:2.93471
# [22]	validation_0-rmse:2.91035
# [23]	validation_0-rmse:2.88487
# [24]	validation_0-rmse:2.83973
# [25]	validation_0-rmse:2.81534
# [26]	validation_0-rmse:2.77918
# [27]	validation_0-rmse:2.75733
# [28]	validation_0-rmse:2.74878
# [29]	validation_0-rmse:2.72504
# [30]	validation_0-rmse:2.71152
# [31]	validation_0-rmse:2.69510
# [32]	validation_0-rmse:2.66531
# [33]	validation_0-rmse:2.61672
# [34]	validation_0-rmse:2.59978
# [35]	validation_0-rmse:2.58655
# [36]	validation_0-rmse:2.55748
# [37]	validation_0-rmse:2.54397
# [38]	validation_0-rmse:2.53056
# [39]	validation_0-rmse:2.50721
# [40]	validation_0-rmse:2.48015
# [41]	validation_0-rmse:2.43752
# [42]	validation_0-rmse:2.42913
# [43]	validation_0-rmse:2.42024
# [44]	validation_0-rmse:2.41516
# [45]	validation_0-rmse:2.40386
# [46]	validation_0-rmse:2.39588
# [47]	validation_0-rmse:2.37979
# [48]	validation_0-rmse:2.37236
# [49]	validation_0-rmse:2.34597
# [50]	validation_0-rmse:2.33289
# [51]	validation_0-rmse:2.32167
# [52]	validation_0-rmse:2.31641
# [53]	validation_0-rmse:2.31042
# [54]	validation_0-rmse:2.29039
# [55]	validation_0-rmse:2.26517
# [56]	validation_0-rmse:2.25187
# [57]	validation_0-rmse:2.23637
# [58]	validation_0-rmse:2.22404
# [59]	validation_0-rmse:2.21155
# [60]	validation_0-rmse:2.19688
# [61]	validation_0-rmse:2.18048
# [62]	validation_0-rmse:2.16849
# [63]	validation_0-rmse:2.15990
# [64]	validation_0-rmse:2.15642
# [65]	validation_0-rmse:2.15486
# [66]	validation_0-rmse:2.14389
# [67]	validation_0-rmse:2.12613
# [68]	validation_0-rmse:2.11480
# [69]	validation_0-rmse:2.10649
# [70]	validation_0-rmse:2.09355
# [71]	validation_0-rmse:2.08609
# [72]	validation_0-rmse:2.07073
# [73]	validation_0-rmse:2.06583
# [74]	validation_0-rmse:2.05319
# [75]	validation_0-rmse:2.04343
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 75

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  0.14
# RMSE: 2.0
# Relative RMSE(%):  16.944
# MSE: 4.2
# R square: 95.5%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0.9, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.955
# Uncertainty
# a0: 0.75+/-0.12
# a1: 0.939+/-0.007

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [18, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../01_output_data/XGBoost_models/03_M_stem_bark_other_authors_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../01_output_data/XGBoost_models/03_M_stem_bark_other_authors_XGB_model.txt")
