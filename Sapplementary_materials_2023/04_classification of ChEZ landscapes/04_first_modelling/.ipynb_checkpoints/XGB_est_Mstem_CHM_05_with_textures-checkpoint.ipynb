# %% [markdown]
# # *+Processing with CHM & RN & biomass data of other authors+*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25 idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167  0.050549
# 1           3600       8.189          15100  ...   0.040919  0.048889
# 2           4360       8.380          14600  ...   0.042397  0.050463
# 3           3420       8.137          12700  ...   0.043719  0.052974
# 4           2200       7.696          12100  ...   0.040659  0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX  idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966    0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602    0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265    0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465    0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420    0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 159 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
            


# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0       4.8122           1.7630               -0.3147           -0.1590
# 1       5.7589           2.4570               -0.2485            0.3429
# 2       5.8464           2.5153               -0.1054            0.5493
# 3       5.7526           2.6304               -0.0834            0.3900
# 4       5.9480           2.6748                0.0000            0.5715
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  \
# 0             -2.4418         1.9125     0.85    12.233545   19.097736    243
# 1             -0.1997         2.6319     1.00    14.964220   17.704655    248
# 2             -0.2144         2.7020     1.00    15.329449   17.559893    240
# 3             -0.3510         2.7763     0.97    15.392742   20.676994    244
# 4             -0.3711         2.8314     1.00    17.944009   21.851387    243
#
#    contr_g_MAX
# 0  2961.898193
# 1  2218.239746
# 2  2220.297119
# 3  3033.770752
# 4  3003.818848

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
#  9   g_MAX                 103 non-null    int64
#  10  contr_g_MAX           103 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 9.0 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["Gs_cub_m", "M_stem_kg_m2"].describe()
# Out:
# /tmp/ipykernel_62223/594647310.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_specias"])["Gs_cub_m", "M_stem_kg_m2"].describe()
#                  Gs_cub_m                                               \
#                     count        mean         std    min    25%    50%
# Dominant_specias
# Alder                 4.0  380.250000  155.784841  199.0  283.0  386.5
# Aspen                 1.0  148.000000         NaN  148.0  148.0  148.0
# Birch                23.0  135.304348   73.156392   11.0   94.0  138.0
# Oak                   3.0  236.000000   77.504839  158.0  197.5  237.0
# Pine                 71.0  263.281690  185.083625    2.0   97.0  281.0
# Spruce                1.0  619.000000         NaN  619.0  619.0  619.0
#
#                                 M_stem_kg_m2                              \
#                      75%    max        count       mean       std    min
# Dominant_specias
# Alder             483.75  549.0          4.0  16.170000  5.186990   9.90
# Aspen             148.00  148.0          1.0   6.650000       NaN   6.65
# Birch             197.00  280.0         23.0   6.809130  3.677786   0.84
# Oak               275.00  313.0          3.0  13.513333  4.888725   9.59
# Pine              394.00  671.0         71.0  10.550000  7.252887   0.05
# Spruce            619.00  619.0          1.0  23.830000       NaN  23.83
#
#
#                       25%    50%      75%    max
# Dominant_specias
# Alder             12.9225  17.03  20.2775  20.72
# Aspen              6.6500   6.65   6.6500   6.65
# Birch              4.7650   6.19   9.7400  15.47
# Oak               10.7750  11.96  15.4750  18.99
# Pine               3.4400  11.34  16.2250  25.04
# Spruce            23.8300  23.83  23.8300  23.83

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000         103.00000
# mean      4.969534         1.827923             -0.239481           0.05436
# std       1.323782         1.325853              0.893398           0.66008
# min       0.693100        -2.995700             -3.912000          -1.55590
# 25%       4.672800         1.588100             -0.335500          -0.20955
# 50%       5.337500         2.286500             -0.040800           0.24450
# 75%       5.908100         2.730800              0.190600           0.49195
# max       6.508800         3.220500              1.654400           1.41220
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX  \
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.021247       2.095454    0.808738    13.045021   17.907784
# std              0.803748       1.079203    0.276653     6.609366    7.523377
# min             -2.918800      -0.798500    0.090000     1.293138    2.733019
# 25%             -1.629700       1.801400    0.745000     8.206727   11.615798
# 50%             -0.719500       2.458700    0.960000    13.072916   18.269344
# 75%             -0.358800       2.862800    1.000000    17.432255   22.751595
# max              0.114200       3.366600    1.000000    28.916548   36.355442
#
#             g_MAX  contr_g_MAX
# count  103.000000   103.000000
# mean   240.572816  3008.938899
# std      9.358442   876.023529
# min    194.000000   815.342712
# 25%    236.500000  2464.687256
# 50%    243.000000  2994.793701
# 75%    247.000000  3464.970947
# max    253.000000  6230.940918

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
y = pd.DataFrame(select, columns= ['ln_M_stem_kg_m2'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  contr_g_MAX
# 0     0.85    12.233545   19.097736    243  2961.898193
# 1     1.00    14.964220   17.704655    248  2218.239746
# 2     1.00    15.329449   17.559893    240  2220.297119
# 3     0.97    15.392742   20.676994    244  3033.770752
# 4     1.00    17.944009   21.851387    243  3003.818848

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_stem_kg_m2
# 0           1.7630
# 1           2.4570
# 2           2.5153
# 3           2.6304
# 4           2.6748

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.9113322667142122, 0.7359440120580841, 0.8895828281348285]
#     Mean: 0.846
#     Std: 0.078
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.35316506 0.6615474  0.29410175]
#     Mean: 0.436
#     Std: 0.161
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.2829081795057229, 0.2635193348912632, 0.30278695279526086]
#     Mean: 0.283
#     Std: 0.016
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.883 (std: 0.064)
# Parameters: {'colsample_bytree': 0.80110549223012, 'gamma': 0.04458503693712479, 'learning_rate': 0.16079094589246523, 'max_depth': 4, 'n_estimators': 90, 'subsample': 0.8298291034528749}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.18070893, 0.33524165, 0.5766192 , ..., 0.57572756, 0.34253392,
#        0.34733086]), 'std_fit_time': array([0.03974849, 0.14161637, 0.27550646, ..., 0.0348629 , 0.00549316,
#        0.02071961]), 'mean_score_time': array([0.00618372, 0.00664992, 0.00606375, ..., 0.00921931, 0.00925155,
#        0.00926499]), 'std_score_time': array([1.10121368e-04, 9.22060857e-04, 1.44832440e-04, ...,
#        1.47870270e-05, 3.83501009e-05, 3.21189383e-05]), 'param_colsample_bytree': masked_array(data=[0.33976994782182907, 0.579962523691845,
#                    0.4889331483820407, ..., 0.27789822892915067,
#                    0.34711630416120187, 0.3460201238041099],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.22578825157388277, 0.4259349338736759,
#                    0.1755819212464747, ..., 0.04844686787410196,
#                    0.09399189134675867, 0.3514952568678728],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.3070687410471766, 0.015754417962048965,
#                    0.14257943750666693, ..., 0.24080586100920448,
#                    0.021430886874865385, 0.2849108722587719],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[2, 4, 3, ..., 3, 3, 3],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[64, 84, 179, ..., 143, 85, 82],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.8654596230844644, 0.7142105511837593,
#                    0.5237237917908807, ..., 0.9676957150036751,
#                    0.9064611117123227, 0.5229630463289339],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.33976994782182907, 'gamma': 0.22578825157388277, 'learning_rate': 0.3070687410471766, 'max_depth': 2, 'n_estimators': 64, 'subsample': 0.8654596230844644}, {'colsample_bytree': 0.579962523691845, 'gamma': 0.4259349338736759, 'learning_rate': 0.015754417962048965, 'max_depth': 4, 'n_estimators': 84, 'subsample': 0.7142105511837593}, {'colsample_bytree': 0.4889331483820407, 'gamma': 0.1755819212464747, 'learning_rate': 0.14257943750666693, 'max_depth': 3, 'n_estimators': 179, 'subsample': 0.5237237917908807}, {'colsample_bytree': 0.45407149019550974, 'gamma': 0.29775738599180956, 'learning_rate': 0.2152116066916998, 'max_depth': 2, 'n_estimators': 66, 'subsample': 0.34656651106683384}, {'colsample_bytree': 0.7735181551876542, 'gamma': 0.34627658207585, 'learning_rate': 0.27657958539836136, 'max_depth': 2, 'n_estimators': 59, 'subsample': 0.5240772020616559}, {'colsample_bytree': 0.9151453642702757, 'gamma': 0.4919579678319336, 'learning_rate': 0.11052120199400217, 'max_depth': 2, 'n_estimators': 183, 'subsample': 0.7111868202769988}, {'colsample_bytree': 0.3463044572837223, 'gamma': 0.260533344809038, 'learning_rate': 0.2236985354669913, 'max_depth': 2, 'n_estimators': 183, 'subsample': 0.5585186653407597}, {'colsample_bytree': 0.2079689226011166, 'gamma': 0.0001397201584146801, 'learning_rate': 0.10714012361074836, 'max_depth': 4, 'n_estimators': 114, 'subsample': 0.8156566571702921},
#        0.81111567]), 'mean_test_score': array([0.84856602, 0.64789343, 0.82195858, ..., 0.83752049, 0.69129089,
#        0.82871958]), 'std_test_score': array([0.06161827, 0.06827881, 0.10873162, ..., 0.04254162, 0.02787546,
#        0.02890681]), 'rank_test_score': array([1245, 2959, 2598, ..., 1948, 2948, 2394], dtype=int32), 'split0_train_score': array([0.97295554, 0.76285999, 0.98221039, ..., 0.99014858, 0.81624578,
#        0.96728683]), 'split1_train_score': array([0.96726499, 0.73835814, 0.98113081, ..., 0.98845301, 0.81390525,
#        0.96512165]), 'split2_train_score': array([0.964995  , 0.76112022, 0.98204214, ..., 0.99083095, 0.81561269,
#        0.9626778 ]), 'split3_train_score': array([0.96637529, 0.76804913, 0.98369248, ..., 0.99000142, 0.83732039,
#        0.96805039]), 'split4_train_score': array([0.9763276 , 0.76751861, 0.98642231, ..., 0.99195386, 0.83701086,
#        0.97102569]), 'mean_train_score': array([0.96958368, 0.75958122, 0.98309963, ..., 0.99027756, 0.824019  ,
#        0.96683247]), 'std_train_score': array([0.00432611, 0.01093842, 0.00185348, ..., 0.00114351, 0.0107619 ,
#        0.00280931])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.80110549223012
# Gamma: 0.04458503693712479
# Learning_rate: 0.16079094589246523
# Max_depth: 4
# N_estimators: 90
# Subsample: 0.8298291034528749

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:1.62352	validation_1-rmse:1.50085
# [1]	validation_0-rmse:1.39355	validation_1-rmse:1.27500
# [2]	validation_0-rmse:1.19792	validation_1-rmse:1.08484
# [3]	validation_0-rmse:1.03195	validation_1-rmse:0.93894
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:0.88874	validation_1-rmse:0.80394
# [5]	validation_0-rmse:0.76910	validation_1-rmse:0.69871
# [6]	validation_0-rmse:0.66629	validation_1-rmse:0.60072
# [7]	validation_0-rmse:0.58273	validation_1-rmse:0.52120
# [8]	validation_0-rmse:0.50946	validation_1-rmse:0.46079
# [9]	validation_0-rmse:0.45173	validation_1-rmse:0.41359
# [10]	validation_0-rmse:0.40103	validation_1-rmse:0.37801
# [11]	validation_0-rmse:0.35840	validation_1-rmse:0.34782
# [12]	validation_0-rmse:0.32425	validation_1-rmse:0.31716
# [13]	validation_0-rmse:0.29455	validation_1-rmse:0.29179
# [14]	validation_0-rmse:0.26954	validation_1-rmse:0.26903
# [15]	validation_0-rmse:0.25404	validation_1-rmse:0.25709
# [16]	validation_0-rmse:0.23606	validation_1-rmse:0.24682
# [17]	validation_0-rmse:0.21608	validation_1-rmse:0.24015
# [18]	validation_0-rmse:0.20533	validation_1-rmse:0.22873
# [19]	validation_0-rmse:0.19081	validation_1-rmse:0.22300
# [20]	validation_0-rmse:0.18208	validation_1-rmse:0.22023
# [21]	validation_0-rmse:0.17141	validation_1-rmse:0.21907
# [22]	validation_0-rmse:0.16287	validation_1-rmse:0.21683
# [23]	validation_0-rmse:0.15641	validation_1-rmse:0.21418
# [24]	validation_0-rmse:0.15263	validation_1-rmse:0.21009
# [25]	validation_0-rmse:0.14635	validation_1-rmse:0.21010
# [26]	validation_0-rmse:0.13834	validation_1-rmse:0.20719
# [27]	validation_0-rmse:0.13747	validation_1-rmse:0.20830
# [28]	validation_0-rmse:0.13425	validation_1-rmse:0.20973
# [29]	validation_0-rmse:0.13070	validation_1-rmse:0.20766
# [30]	validation_0-rmse:0.12474	validation_1-rmse:0.19780
# [31]	validation_0-rmse:0.12312	validation_1-rmse:0.19778
# [32]	validation_0-rmse:0.12058	validation_1-rmse:0.19636
# [33]	validation_0-rmse:0.11719	validation_1-rmse:0.19359
# [34]	validation_0-rmse:0.11536	validation_1-rmse:0.19335
# [35]	validation_0-rmse:0.11471	validation_1-rmse:0.19523
# [36]	validation_0-rmse:0.11471	validation_1-rmse:0.19502
# [37]	validation_0-rmse:0.11322	validation_1-rmse:0.19680
# [1]	validation_0-rmse:1.33175	validation_1-rmse:1.56164
# [2]	validation_0-rmse:1.14369	validation_1-rmse:1.39221
# [3]	validation_0-rmse:0.98648	validation_1-rmse:1.24364
# [4]	validation_0-rmse:0.85484	validation_1-rmse:1.13063
# [5]	validation_0-rmse:0.74250	validation_1-rmse:1.01210
# [6]	validation_0-rmse:0.64496	validation_1-rmse:0.92610
# [7]	validation_0-rmse:0.56139	validation_1-rmse:0.86322
# [8]	validation_0-rmse:0.48910	validation_1-rmse:0.78725
# [9]	validation_0-rmse:0.42690	validation_1-rmse:0.74521
# [10]	validation_0-rmse:0.37926	validation_1-rmse:0.72198
# [11]	validation_0-rmse:0.33856	validation_1-rmse:0.69591
# [12]	validation_0-rmse:0.30169	validation_1-rmse:0.65942
# [13]	validation_0-rmse:0.27324	validation_1-rmse:0.63214
# [14]	validation_0-rmse:0.24548	validation_1-rmse:0.60642
# [15]	validation_0-rmse:0.22205	validation_1-rmse:0.59767
# [16]	validation_0-rmse:0.20314	validation_1-rmse:0.57872
# [17]	validation_0-rmse:0.19038	validation_1-rmse:0.58125
# [18]	validation_0-rmse:0.17537	validation_1-rmse:0.56595
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [19]	validation_0-rmse:0.16457	validation_1-rmse:0.55902
# [20]	validation_0-rmse:0.15484	validation_1-rmse:0.54887
# [21]	validation_0-rmse:0.14660	validation_1-rmse:0.54140
# [22]	validation_0-rmse:0.13947	validation_1-rmse:0.53508
# [23]	validation_0-rmse:0.13335	validation_1-rmse:0.52705
# [24]	validation_0-rmse:0.12769	validation_1-rmse:0.52828
# [25]	validation_0-rmse:0.12541	validation_1-rmse:0.52847
# [26]	validation_0-rmse:0.12395	validation_1-rmse:0.52496
# [27]	validation_0-rmse:0.12225	validation_1-rmse:0.52708
# [28]	validation_0-rmse:0.11909	validation_1-rmse:0.52753
# [29]	validation_0-rmse:0.11540	validation_1-rmse:0.52312
# [30]	validation_0-rmse:0.11181	validation_1-rmse:0.52475
# [31]	validation_0-rmse:0.10981	validation_1-rmse:0.52189
# [32]	validation_0-rmse:0.10914	validation_1-rmse:0.52133
# [33]	validation_0-rmse:0.10912	validation_1-rmse:0.52143
# [34]	validation_0-rmse:0.10909	validation_1-rmse:0.52168
# [35]	validation_0-rmse:0.10910	validation_1-rmse:0.52159
# [36]	validation_0-rmse:0.10775	validation_1-rmse:0.52174
# [37]	validation_0-rmse:0.10648	validation_1-rmse:0.52071
# [38]	validation_0-rmse:0.10463	validation_1-rmse:0.52385
# [39]	validation_0-rmse:0.10209	validation_1-rmse:0.51962
# [40]	validation_0-rmse:0.10211	validation_1-rmse:0.51935
# [41]	validation_0-rmse:0.10210	validation_1-rmse:0.51951
# [42]	validation_0-rmse:0.10211	validation_1-rmse:0.51936
# [43]	validation_0-rmse:0.10137	validation_1-rmse:0.51950
# [44]	validation_0-rmse:0.09807	validation_1-rmse:0.52162
# [45]	validation_0-rmse:0.09805	validation_1-rmse:0.52181
# [46]	validation_0-rmse:0.09805	validation_1-rmse:0.52191
# [47]	validation_0-rmse:0.09807	validation_1-rmse:0.52161
# [34]	validation_0-rmse:0.10632	validation_1-rmse:0.76073
# [35]	validation_0-rmse:0.10627	validation_1-rmse:0.76097
# [36]	validation_0-rmse:0.10415	validation_1-rmse:0.76314
# [37]	validation_0-rmse:0.10275	validation_1-rmse:0.76086
# [38]	validation_0-rmse:0.10216	validation_1-rmse:0.76164
# [39]	validation_0-rmse:0.09933	validation_1-rmse:0.76248
# [40]	validation_0-rmse:0.09816	validation_1-rmse:0.76319
# [41]	validation_0-rmse:0.09815	validation_1-rmse:0.76330
# [42]	validation_0-rmse:0.09814	validation_1-rmse:0.76334
# [43]	validation_0-rmse:0.09819	validation_1-rmse:0.76296
# [44]	validation_0-rmse:0.09815	validation_1-rmse:0.76328
# [45]	validation_0-rmse:0.09814	validation_1-rmse:0.76337
# [46]	validation_0-rmse:0.09682	validation_1-rmse:0.76325
# [47]	validation_0-rmse:0.09683	validation_1-rmse:0.76321
# [0]	validation_0-rmse:1.61447	validation_1-rmse:1.57016
# [1]	validation_0-rmse:1.38134	validation_1-rmse:1.38456
# [2]	validation_0-rmse:1.18463	validation_1-rmse:1.21875
# [3]	validation_0-rmse:1.02112	validation_1-rmse:1.07548
# [4]	validation_0-rmse:0.88438	validation_1-rmse:0.96421
# [5]	validation_0-rmse:0.76015	validation_1-rmse:0.88455
# [6]	validation_0-rmse:0.65703	validation_1-rmse:0.83522
# [7]	validation_0-rmse:0.57185	validation_1-rmse:0.78044
# [8]	validation_0-rmse:0.50084	validation_1-rmse:0.73992
# [9]	validation_0-rmse:0.43845	validation_1-rmse:0.71627
# [10]	validation_0-rmse:0.39103	validation_1-rmse:0.68936
# [11]	validation_0-rmse:0.34463	validation_1-rmse:0.67157
# [12]	validation_0-rmse:0.30651	validation_1-rmse:0.65799
# [13]	validation_0-rmse:0.27587	validation_1-rmse:0.65596
# [14]	validation_0-rmse:0.25282	validation_1-rmse:0.64788
# [15]	validation_0-rmse:0.22975	validation_1-rmse:0.64103
# [16]	validation_0-rmse:0.21155	validation_1-rmse:0.63449
# [17]	validation_0-rmse:0.19479	validation_1-rmse:0.63890
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [18]	validation_0-rmse:0.18347	validation_1-rmse:0.63499
# [19]	validation_0-rmse:0.17326	validation_1-rmse:0.62948
# [20]	validation_0-rmse:0.16262	validation_1-rmse:0.62835
# [21]	validation_0-rmse:0.15489	validation_1-rmse:0.62718
# [22]	validation_0-rmse:0.14931	validation_1-rmse:0.62553
# [23]	validation_0-rmse:0.14366	validation_1-rmse:0.62504
# [24]	validation_0-rmse:0.13751	validation_1-rmse:0.62329
# [25]	validation_0-rmse:0.13147	validation_1-rmse:0.62213
# [26]	validation_0-rmse:0.12743	validation_1-rmse:0.62198
# [27]	validation_0-rmse:0.12479	validation_1-rmse:0.62124
# [28]	validation_0-rmse:0.12325	validation_1-rmse:0.62150
# [29]	validation_0-rmse:0.11922	validation_1-rmse:0.62292
# [30]	validation_0-rmse:0.11603	validation_1-rmse:0.62237
# [31]	validation_0-rmse:0.11343	validation_1-rmse:0.62294
# [32]	validation_0-rmse:0.11263	validation_1-rmse:0.62491
# [33]	validation_0-rmse:0.11261	validation_1-rmse:0.62490
# [11]	validation_0-rmse:0.36823	validation_1-rmse:0.36676
# ...
# [9]	validation_0-rmse:0.45310	validation_1-rmse:0.40062
# [10]	validation_0-rmse:0.40859	validation_1-rmse:0.37084
# [11]	validation_0-rmse:0.36874	validation_1-rmse:0.34638
# [12]	validation_0-rmse:0.32818	validation_1-rmse:0.32511
# [13]	validation_0-rmse:0.29537	validation_1-rmse:0.31046
# [14]	validation_0-rmse:0.27094	validation_1-rmse:0.30345
# [15]	validation_0-rmse:0.24440	validation_1-rmse:0.30356
# [16]	validation_0-rmse:0.22531	validation_1-rmse:0.30090
# [17]	validation_0-rmse:0.21191	validation_1-rmse:0.30616
# [18]	validation_0-rmse:0.19907	validation_1-rmse:0.30812
# [19]	validation_0-rmse:0.18478	validation_1-rmse:0.30593
# [20]	validation_0-rmse:0.17538	validation_1-rmse:0.30378
# [21]	validation_0-rmse:0.16367	validation_1-rmse:0.30526
# [22]	validation_0-rmse:0.15593	validation_1-rmse:0.30814
# [23]	validation_0-rmse:0.14896	validation_1-rmse:0.30857
# [24]	validation_0-rmse:0.14292	validation_1-rmse:0.30861
# [25]	validation_0-rmse:0.13744	validation_1-rmse:0.30865
# [26]	validation_0-rmse:0.13321	validation_1-rmse:0.30897
# [27]	validation_0-rmse:0.12856	validation_1-rmse:0.30845
# [28]	validation_0-rmse:0.12557	validation_1-rmse:0.31046
# [29]	validation_0-rmse:0.11878	validation_1-rmse:0.30890
# [30]	validation_0-rmse:0.11757	validation_1-rmse:0.31318
# [31]	validation_0-rmse:0.11341	validation_1-rmse:0.31417
# [32]	validation_0-rmse:0.10953	validation_1-rmse:0.31659
# [33]	validation_0-rmse:0.10729	validation_1-rmse:0.31664
# [34]	validation_0-rmse:0.10592	validation_1-rmse:0.31644
# [35]	validation_0-rmse:0.10473	validation_1-rmse:0.31622
# [36]	validation_0-rmse:0.10382	validation_1-rmse:0.31619
# [0]	validation_0-rmse:1.60426	validation_1-rmse:1.57324
# [1]	validation_0-rmse:1.37964	validation_1-rmse:1.38920
# [2]	validation_0-rmse:1.18384	validation_1-rmse:1.20757
# [3]	validation_0-rmse:1.01541	validation_1-rmse:1.08775
# [4]	validation_0-rmse:0.87110	validation_1-rmse:0.95837
# [5]	validation_0-rmse:0.76041	validation_1-rmse:0.87121
# [6]	validation_0-rmse:0.65590	validation_1-rmse:0.78114
# [7]	validation_0-rmse:0.57309	validation_1-rmse:0.71990
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [8]	validation_0-rmse:0.49779	validation_1-rmse:0.67221
# [9]	validation_0-rmse:0.43832	validation_1-rmse:0.64872
# [10]	validation_0-rmse:0.38392	validation_1-rmse:0.62892
# [11]	validation_0-rmse:0.34075	validation_1-rmse:0.59297
# [12]	validation_0-rmse:0.30572	validation_1-rmse:0.56884
# [13]	validation_0-rmse:0.27344	validation_1-rmse:0.56110
# [14]	validation_0-rmse:0.24600	validation_1-rmse:0.54842
# [15]	validation_0-rmse:0.22438	validation_1-rmse:0.53536
# [16]	validation_0-rmse:0.20567	validation_1-rmse:0.53643
# [17]	validation_0-rmse:0.18981	validation_1-rmse:0.53700
# [18]	validation_0-rmse:0.17441	validation_1-rmse:0.53465
# [19]	validation_0-rmse:0.16251	validation_1-rmse:0.53208
# [20]	validation_0-rmse:0.15213	validation_1-rmse:0.52833
# [21]	validation_0-rmse:0.14255	validation_1-rmse:0.52818
# [22]	validation_0-rmse:0.13541	validation_1-rmse:0.52903
# [23]	validation_0-rmse:0.12948	validation_1-rmse:0.52855
# [24]	validation_0-rmse:0.12374	validation_1-rmse:0.52125
# [25]	validation_0-rmse:0.11985	validation_1-rmse:0.51979
# [26]	validation_0-rmse:0.11792	validation_1-rmse:0.51912
# [27]	validation_0-rmse:0.11559	validation_1-rmse:0.51258
# [28]	validation_0-rmse:0.11318	validation_1-rmse:0.51149
# [29]	validation_0-rmse:0.11232	validation_1-rmse:0.51175
# [30]	validation_0-rmse:0.10942	validation_1-rmse:0.51155
# [31]	validation_0-rmse:0.10860	validation_1-rmse:0.51252
# [32]	validation_0-rmse:0.10581	validation_1-rmse:0.51450
# [33]	validation_0-rmse:0.10580	validation_1-rmse:0.51446
# [34]	validation_0-rmse:0.10445	validation_1-rmse:0.51766
# [35]	validation_0-rmse:0.10234	validation_1-rmse:0.51691
# [36]	validation_0-rmse:0.10233	validation_1-rmse:0.51690
# [37]	validation_0-rmse:0.10043	validation_1-rmse:0.51647
# [38]	validation_0-rmse:0.10042	validation_1-rmse:0.51640
# [39]	validation_0-rmse:0.09773	validation_1-rmse:0.52063
# [40]	validation_0-rmse:0.09772	validation_1-rmse:0.52058
# [41]	validation_0-rmse:0.09772	validation_1-rmse:0.52060
# [42]	validation_0-rmse:0.09773	validation_1-rmse:0.52066
# [43]	validation_0-rmse:0.09773	validation_1-rmse:0.52067
# [44]	validation_0-rmse:0.09775	validation_1-rmse:0.52073
# [45]	validation_0-rmse:0.09777	validation_1-rmse:0.52078
# [46]	validation_0-rmse:0.09576	validation_1-rmse:0.52045
# [47]	validation_0-rmse:0.09577	validation_1-rmse:0.52047
# [48]	validation_0-rmse:0.09572	validation_1-rmse:0.52039
# [0]	validation_0-rmse:1.55541	validation_1-rmse:1.77766
# [1]	validation_0-rmse:1.33727	validation_1-rmse:1.56921
# [2]	validation_0-rmse:1.15280	validation_1-rmse:1.38355
# [3]	validation_0-rmse:0.98931	validation_1-rmse:1.24244
# [4]	validation_0-rmse:0.85660	validation_1-rmse:1.12871
# [5]	validation_0-rmse:0.74264	validation_1-rmse:1.00617
# [6]	validation_0-rmse:0.65027	validation_1-rmse:0.92635
# [7]	validation_0-rmse:0.56850	validation_1-rmse:0.83965
# [8]	validation_0-rmse:0.49593	validation_1-rmse:0.76237
# [9]	validation_0-rmse:0.43369	validation_1-rmse:0.72312
# [10]	validation_0-rmse:0.38157	validation_1-rmse:0.70024
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
#
# [21]	validation_0-rmse:0.16198	validation_1-rmse:0.36353
# [22]	validation_0-rmse:0.15755	validation_1-rmse:0.36341
# [23]	validation_0-rmse:0.15073	validation_1-rmse:0.36409
# [24]	validation_0-rmse:0.14639	validation_1-rmse:0.36527
# [25]	validation_0-rmse:0.13947	validation_1-rmse:0.36478
# [26]	validation_0-rmse:0.13626	validation_1-rmse:0.36651
# [27]	validation_0-rmse:0.13198	validation_1-rmse:0.36608
# [28]	validation_0-rmse:0.12827	validation_1-rmse:0.36896
# [29]	validation_0-rmse:0.12566	validation_1-rmse:0.36706
# [30]	validation_0-rmse:0.12107	validation_1-rmse:0.36588
# [31]	validation_0-rmse:0.11786	validation_1-rmse:0.36142
# [32]	validation_0-rmse:0.11204	validation_1-rmse:0.35473
# [33]	validation_0-rmse:0.11197	validation_1-rmse:0.35410
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 37.41, median: 28.0,
#  pred. interval (P(0.025)-P(0.975)): 14.0-88.0,
#  conf. interval (p-value=0.95): 23.636-44.148
# ***
# Aggregate bias statistic:
#  mean: -0.318, median: -0.427,
#  pred. interval (P(0.025)-P(0.975)): -5.358-5.219,
#  conf. interval (p-value=0.95): -1.392-0.881
# ***
# Aggregate RMSE statistic:
#  mean: 0.425, median: 0.386, pred. interval (P(0.025)-P(0.975)): 0.216-0.78,
#  conf. interval (p-value=0.95): 0.333-0.466
# ***
# Aggregate MSE statistic:
#  mean: 0.205, median: 0.149, pred. interval (P(0.025)-P(0.975)): 0.047-0.609,
#  conf. interval (p-value=0.95): 0.115-0.225
# ***
# Aggregate R^2 statistic:
#  mean: 0.885, median: 0.891, pred. interval (P(0.025)-P(0.975)): 0.747-0.969,
#  conf. interval (p-value=0.95): 0.862-0.914
# ***
# Aggregate bias(%) statistic:
#  mean: -0.079, median: -0.427, pred. interval (P(0.025)-P(0.975)): -2.708-3.991,
#  conf. interval (p-value=0.95): -0.785-0.523
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.253, median: 0.221, pred. interval (P(0.025)-P(0.975)): 0.103-0.555,
#  conf. interval (p-value=0.95): 0.184-0.286
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.59910
# [1]	validation_0-rmse:1.36763
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-rmse:1.17330
# [3]	validation_0-rmse:1.00645
# [4]	validation_0-rmse:0.86906
# [5]	validation_0-rmse:0.74974
# [6]	validation_0-rmse:0.64998
# [7]	validation_0-rmse:0.56972
# [8]	validation_0-rmse:0.50322
# [9]	validation_0-rmse:0.43946
# [10]	validation_0-rmse:0.39049
# [11]	validation_0-rmse:0.35084
# [12]	validation_0-rmse:0.31567
# [13]	validation_0-rmse:0.28670
# [14]	validation_0-rmse:0.25972
# [15]	validation_0-rmse:0.23687
# [16]	validation_0-rmse:0.21843
# [17]	validation_0-rmse:0.20695
# [18]	validation_0-rmse:0.19412
# [19]	validation_0-rmse:0.18465
# [20]	validation_0-rmse:0.17760
# [21]	validation_0-rmse:0.16860
# [22]	validation_0-rmse:0.16172
# [23]	validation_0-rmse:0.15612
# [24]	validation_0-rmse:0.14939
# [25]	validation_0-rmse:0.14787
# [26]	validation_0-rmse:0.14231
# [27]	validation_0-rmse:0.13912
# [28]	validation_0-rmse:0.13401
# [29]	validation_0-rmse:0.13105
# [30]	validation_0-rmse:0.12875
# [31]	validation_0-rmse:0.12554
# [32]	validation_0-rmse:0.12229
# [33]	validation_0-rmse:0.12024
# [34]	validation_0-rmse:0.11936
# [35]	validation_0-rmse:0.11695
# [36]	validation_0-rmse:0.11589
# [37]	validation_0-rmse:0.11251
# [38]	validation_0-rmse:0.11165
# [39]	validation_0-rmse:0.11124
# [40]	validation_0-rmse:0.11011
# [41]	validation_0-rmse:0.10677
# [42]	validation_0-rmse:0.10677
# [43]	validation_0-rmse:0.10678
# [44]	validation_0-rmse:0.10678
# [45]	validation_0-rmse:0.10678
# [46]	validation_0-rmse:0.10677
# [47]	validation_0-rmse:0.10633
# [48]	validation_0-rmse:0.10632
# [49]	validation_0-rmse:0.10549
# [50]	validation_0-rmse:0.10549
# [51]	validation_0-rmse:0.10465
# [52]	validation_0-rmse:0.10464
# [53]	validation_0-rmse:0.10250
# [54]	validation_0-rmse:0.10136
# [55]	validation_0-rmse:0.10141
# [56]	validation_0-rmse:0.10139
# [57]	validation_0-rmse:0.10138
# [58]	validation_0-rmse:0.10014
# [59]	validation_0-rmse:0.10013
# [60]	validation_0-rmse:0.10013
# [61]	validation_0-rmse:0.10014
# [62]	validation_0-rmse:0.10016
# [63]	validation_0-rmse:0.10019
# [64]	validation_0-rmse:0.10014
# [65]	validation_0-rmse:0.09922
# [66]	validation_0-rmse:0.09920
# [67]	validation_0-rmse:0.09921
# [68]	validation_0-rmse:0.09731
# [69]	validation_0-rmse:0.09730
# [70]	validation_0-rmse:0.09730
# [71]	validation_0-rmse:0.09731
# [72]	validation_0-rmse:0.09730
# [73]	validation_0-rmse:0.09730
# [74]	validation_0-rmse:0.09731
# [75]	validation_0-rmse:0.09730
# [76]	validation_0-rmse:0.09730
# [77]	validation_0-rmse:0.09731
# [78]	validation_0-rmse:0.09731
# [79]	validation_0-rmse:0.09595
# [80]	validation_0-rmse:0.09595
# [81]	validation_0-rmse:0.09596
# [82]	validation_0-rmse:0.09455
# [83]	validation_0-rmse:0.09455
# [84]	validation_0-rmse:0.09456
# [85]	validation_0-rmse:0.09454
# [86]	validation_0-rmse:0.09386
# [87]	validation_0-rmse:0.09385
# [88]	validation_0-rmse:0.09384
# [89]	validation_0-rmse:0.09384
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 89

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.04
# RMSE: 0.1
# Relative RMSE(%):  0.051
# MSE: 0.0
# R square: 99.5%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.028
# a1: 0.984
# R^2: 0.995
# Uncertainty
# a0: 0.028+/-0.016
# a1: 0.984+/-0.007

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=1) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Mstem_XGB_model_with_texture.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Mstem_XGB_model_with_texture.txt")
