# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25 idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167  0.050549
# 1           3600       8.189          15100  ...   0.040919  0.048889
# 2           4360       8.380          14600  ...   0.042397  0.050463
# 3           3420       8.137          12700  ...   0.043719  0.052974
# 4           2200       7.696          12100  ...   0.040659  0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX  idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966    0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602    0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265    0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465    0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420    0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 159 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
            


# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0       4.8122           1.7630               -0.3147           -0.1590
# 1       5.7589           2.4570               -0.2485            0.3429
# 2       5.8464           2.5153               -0.1054            0.5493
# 3       5.7526           2.6304               -0.0834            0.3900
# 4       5.9480           2.6748                0.0000            0.5715
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  \
# 0             -2.4418         1.9125     0.85    12.233545   19.097736    243
# 1             -0.1997         2.6319     1.00    14.964220   17.704655    248
# 2             -0.2144         2.7020     1.00    15.329449   17.559893    240
# 3             -0.3510         2.7763     0.97    15.392742   20.676994    244
# 4             -0.3711         2.8314     1.00    17.944009   21.851387    243
#
#    contr_g_MAX
# 0  2961.898193
# 1  2218.239746
# 2  2220.297119
# 3  3033.770752
# 4  3003.818848

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
#  9   g_MAX                 103 non-null    int64
#  10  contr_g_MAX           103 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 9.0 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["M_crown_kg_m2", "M_foliage_kg_m2"].describe()
# Out:
# /tmp/ipykernel_134150/4127234604.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_specias"])["M_crown_kg_m2", "M_foliage_kg_m2"].describe()
#                  M_crown_kg_m2                                             \
#                          count      mean       std    min      25%    50%
# Dominant_specias
# Alder                      4.0  1.059000  0.593217  0.476  0.68825  0.958
# Aspen                      1.0  1.173000       NaN  1.173  1.17300  1.173
# Birch                     23.0  1.039609  0.409105  0.303  0.77850  1.049
# Oak                        3.0  2.085000  1.209736  1.344  1.38700  1.430
# Pine                      71.0  1.272141  0.638357  0.211  0.82000  1.381
# Spruce                     1.0  4.105000       NaN  4.105  4.10500  4.105
#
#                                  M_foliage_kg_m2                             \
#                       75%    max           count      mean       std    min
# Dominant_specias
# Alder             1.32875  1.844             4.0  0.312000  0.145801  0.130
# Aspen             1.17300  1.173             1.0  0.168000       NaN  0.168
# Birch             1.29450  1.816            23.0  0.189304  0.080503  0.054
# Oak               2.45550  3.481             3.0  0.294333  0.078621  0.205
# Pine              1.67050  2.735            71.0  0.569746  0.267121  0.059
# Spruce            4.10500  4.105             1.0  1.043000       NaN  1.043
#
#
#                       25%     50%      75%    max
# Dominant_specias
# Alder             0.26875  0.3155  0.35875  0.487
# Aspen             0.16800  0.1680  0.16800  0.168
# Birch             0.12500  0.1850  0.25450  0.399
# Oak               0.26500  0.3250  0.33900  0.353
# Pine              0.41950  0.6390  0.74550  1.121
# Spruce            1.04300  1.0430  1.04300  1.043

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000         103.00000
# mean      4.969534         1.827923             -0.239481           0.05436
# std       1.323782         1.325853              0.893398           0.66008
# min       0.693100        -2.995700             -3.912000          -1.55590
# 25%       4.672800         1.588100             -0.335500          -0.20955
# 50%       5.337500         2.286500             -0.040800           0.24450
# 75%       5.908100         2.730800              0.190600           0.49195
# max       6.508800         3.220500              1.654400           1.41220
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX  \
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.021247       2.095454    0.808738    13.045021   17.907784
# std              0.803748       1.079203    0.276653     6.609366    7.523377
# min             -2.918800      -0.798500    0.090000     1.293138    2.733019
# 25%             -1.629700       1.801400    0.745000     8.206727   11.615798
# 50%             -0.719500       2.458700    0.960000    13.072916   18.269344
# 75%             -0.358800       2.862800    1.000000    17.432255   22.751595
# max              0.114200       3.366600    1.000000    28.916548   36.355442
#
#             g_MAX  contr_g_MAX
# count  103.000000   103.000000
# mean   240.572816  3008.938899
# std      9.358442   876.023529
# min    194.000000   815.342712
# 25%    236.500000  2464.687256
# 50%    243.000000  2994.793701
# 75%    247.000000  3464.970947
# max    253.000000  6230.940918

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
y = pd.DataFrame(select, columns= ['ln_M_foliage_kg_m2'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  contr_g_MAX
# 0     0.85    12.233545   19.097736    243  2961.898193
# 1     1.00    14.964220   17.704655    248  2218.239746
# 2     1.00    15.329449   17.559893    240  2220.297119
# 3     0.97    15.392742   20.676994    244  3033.770752
# 4     1.00    17.944009   21.851387    243  3003.818848

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_foliage_kg_m2
# 0             -2.4418
# 1             -0.1997
# 2             -0.2144
# 3             -0.3510
# 4             -0.3711

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.1875870155688948, 0.4751893952507644, 0.23359211198595975]
#     Mean: 0.299
#     Std: 0.126
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.78012753 0.65236496 0.68685055]
#     Mean: 0.706
#     Std: 0.054
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.5041027575878587, 0.4647692907186116, 0.5911452765696188]
#     Mean: 0.520
#     Std: 0.053
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.433 (std: 0.133)
# Parameters: {'colsample_bytree': 0.6164078606364067, 'gamma': 0.46457263110215186, 'learning_rate': 0.026157819305236585, 'max_depth': 4, 'n_estimators': 151, 'subsample': 0.458494354105843}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.59528966, 0.19520125, 0.47870846, ..., 0.346492  , 0.36388288,
#        0.32884688]), 'std_fit_time': array([0.35147488, 0.04124906, 0.01337526, ..., 0.01829928, 0.02920578,
#        0.00514235]), 'mean_score_time': array([0.00800924, 0.00657277, 0.00607419, ..., 0.00660477, 0.00663056,
#        0.00667357]), 'std_score_time': array([3.61438492e-03, 9.79027097e-04, 7.98169001e-05, ...,
#        3.89869712e-05, 3.30650039e-05, 8.73074383e-05]), 'param_colsample_bytree': masked_array(data=[0.42676288293839354, 0.4681873450747208,
#                    0.33361755428832435, ..., 0.7178550756098159,
#                    0.7439544862570652, 0.05737781288399858],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.08943053848224025, 0.011274712564443956,
#                    0.32006230984363165, ..., 0.18329105480341984,
#                    0.3281600244137463, 0.186322541553182],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.07537926992379852, 0.03012497986420145,
#                    0.16009468385566442, ..., 0.17617067305045328,
#                    0.034906192799941636, 0.19452057615693027],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[2, 2, 3, ..., 3, 2, 4],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[159, 65, 192, ..., 122, 129, 117],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.9963614522202717, 0.5892204871754582,
#                    0.507119447675856, ..., 0.9195278057347873,
#                    0.8434213404442219, 0.7876618829947653],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.42676288293839354, 'gamma': 0.08943053848224025, 'learning_rate': 0.07537926992379852, 'max_depth': 2, 'n_estimators': 159, 'subsample': 0.9963614522202717}, {'colsample_bytree': 0.4681873450747208, 'gamma': 0.011274712564443956, 'learning_rate': 0.03012497986420145, 'max_depth': 2, 'n_estimators': 65, 'subsample': 0.5892204871754582}, {'colsample_bytree': 0.33361755428832435, 'gamma': 0.32006230984363165, 'learning_rate': 0.16009468385566442, 'max_depth': 3, 'n_estimators': 192, 'subsample': 0.507119447675856}, {'colsample_bytree': 0.4489177686668841, 'gamma': 0.36971943999816986, 'learning_rate': 0.12953697558142155, 'max_depth': 2, 'n_estimators': 151, 'subsample': 0.46448069914787704}, {'colsample_bytree': 0.3313512419597476, 'gamma': 0.1727583184892626, 'learning_rate': 0.18793026286060646, 'max_depth': 4, 'n_estimators': 154, 'subsample': 0.8382262399078861}, {'colsample_bytree': 0.2695065408878641, 'gamma': 0.03776628692878414, 'learning_rate': 0.10174681984470091, 'max_depth': 3, 'n_estimators': 174, 'subsample': 0.8513718581296621}, {'colsample_bytree': 0.12643532857048295, 'gamma': 0.3890082938381259, 'learning_rate': 0.23814415072908732, 'max_depth': 4, 'n_estimators': 177, 'subsample': 0.4285231120134809}, {'colsample_bytree': 0.6098057929462096, 'gamma': 0.39467951149483244, 'learning_rate': 0.13858744129777797, 'max_depth': 2, 'n_estimators': 76, 'subsample': 0.777203102691939}, {'colsample_bytree': 0.3636499004955811, 'gamma': 0.26323291450605957, 'learning_rate': 0.06575053526075171, 'max_depth': 4, 'n_estimators': 190, 'subsample': 0.3050446144710008}, {'colsample_bytree': 0.7580576287624456, 'gamma': 0.492310268223941, 'learning_rate': 0.11010898270402486, 'max_depth': 2, 'n_estimators': 95, 'subsample': 0.7551734226431268}, {'colsample_bytree': 0.7660092458333727, 'gamma': 0.01975041898984664, 'learning_rate': 0.11533582338290693, 'max_depth': 2, 'n_estimators': 87, 'subsample': 0.7547539648627224}, {'colsample_bytree': 0.39134664130766866, 'gamma': 0.3233493304526105, 'learning_rate': 0.2482861656544526, 'max_depth': 3, 'n_estimators': 140, 'subsample': 0.6631635888227632}, {'colsample_bytree': 0.3116527445044568, 'gamma': 0.07387866949808064, 'learning_rate': 0.11264166062410524, 'max_depth': 3, 'n_estimators': 68, 'subsample': 0.3989930660552617}, {'colsample_bytree': 0.8325474650699936, 'gamma': 0.3513975219368034, 'learning_rate': 0.18123194771233614, 'max_depth': 2, 'n_estimators': 144, 'subsample': 0.844005094898483}, {'colsample_bytree': 0.08516300766354004, 'gamma': 0.29109652330412605, 'learning_rate': 0.28082897917467425, 'max_depth': 4, 'n_estimators': 87, 'subsample': 0.3001168044566088}, {'colsample_bytree': 0.6883435021191568, 'gamma': 0.2161666345590254, 'learning_rate': 0.053065730378611814, 'max_depth': 3, 'n_estimators': 125, 'subsample': 0.5038152808885834}, {'colsample_bytree': 0.7997605390094952, 'gamma': 0.24347390594739138, 'learning_rate': 0.07548843388554866, 'max_depth': 2, 'n_estimators': 153, 'subsample': 0.775775582694008}, {'colsample_bytree': 0.642835508638805, 'gamma': 0.27201656614103265, 'learning_rate': 0.04516353945412961, 'max_depth': 3, 'n_estimators': 54, 'subsample': 0.576050883020636}, {'colsample_bytree': 0.5316215891322306, 'gamma': 0.15558763486327837, 'learning_rate': 0.2202431839051598, 'max_depth': 4, 'n_estimators': 68, 'subsample': 0.9364778032907133}, {'colsample_bytree': 0.7364370034959834, 'gamma': 0.17842507634105953, 'learning_rate': 0.24341396863265655, 'max_depth': 4, 'n_estimators': 151, 'subsample': 0.4750249076522133}, {'colsample_bytree': 0.19987023901232137, 'gamma': 0.42432703730907234, 'learning_rate': 0.28442767553481807, 'max_depth': 4, 'n_estimators': 58, 'subsample': 0.46832680289733575}, {'colsample_bytree': 0.5410591354395936, 'gamma': 0.14257778192909593, 'learning_rate': 0.17621232147141985, 'max_depth': 4, 'n_estimators': 73, 'subsample': 0.33925010567332226}, {'colsample_bytr ...
#        0.28493945]), 'split1_test_score': array([0.53713433, 0.61806259, 0.4114894 , ..., 0.53591657, 0.59366565,
#        0.42976473]), 'split2_test_score': array([0.31736816, 0.28747879, 0.29444324, ..., 0.29373567, 0.3719471 ,
#        0.33105823]), 'split3_test_score': array([0.14350158, 0.26410511, 0.25551466, ..., 0.35577006, 0.30805001,
#        0.27587116]), 'split4_test_score': array([0.17260166, 0.15960607, 0.24452965, ..., 0.17482115, 0.25092952,
#        0.34375449]), 'mean_test_score': array([0.30424941, 0.2930106 , 0.32348193, ..., 0.33959159, 0.38716963,
#        0.33307761]), 'std_test_score': array([0.1412308 , 0.17264804, 0.07372505, ..., 0.11667118, 0.11685355,
#        0.05487501]), 'rank_test_score': array([1849, 2092, 1322, ...,  909,  167, 1065], dtype=int32), 'split0_train_score': array([0.89119979, 0.50638846, 0.88339838, ..., 0.94022587, 0.76730953,
#        0.91902529]), 'split1_train_score': array([0.86865317, 0.4919734 , 0.89280342, ..., 0.93874732, 0.7538496 ,
#        0.92729236]), 'split2_train_score': array([0.89385402, 0.53145345, 0.89203126, ..., 0.93372972, 0.78081177,
#        0.93328162]), 'split3_train_score': array([0.88741811, 0.51563578, 0.87860466, ..., 0.93123607, 0.75987462,
#        0.92806887]), 'split4_train_score': array([0.88104915, 0.53368329, 0.87937561, ..., 0.93406364, 0.79122986,
#        0.92008579]), 'mean_train_score': array([0.88443485, 0.51582688, 0.88524267, ..., 0.93560052, 0.77061508,
#        0.92555079]), 'std_train_score': array([0.00898787, 0.01562786, 0.00608501, ..., 0.00335281, 0.01368435,
#        0.00532143])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.6164078606364067
# Gamma: 0.46457263110215186
# Learning_rate: 0.026157819305236585
# Max_depth: 4
# N_estimators: 151
# Subsample: 0.458494354105843

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:1.69334	validation_1-rmse:1.64139
# [1]	validation_0-rmse:1.65705	validation_1-rmse:1.60933
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-rmse:1.62257	validation_1-rmse:1.57486
# [3]	validation_0-rmse:1.58843	validation_1-rmse:1.54014
# [4]	validation_0-rmse:1.55781	validation_1-rmse:1.50793
# [5]	validation_0-rmse:1.52679	validation_1-rmse:1.47620
# [6]	validation_0-rmse:1.49527	validation_1-rmse:1.44550
# [7]	validation_0-rmse:1.46012	validation_1-rmse:1.41127
# [8]	validation_0-rmse:1.43134	validation_1-rmse:1.38326
# [9]	validation_0-rmse:1.40492	validation_1-rmse:1.35539
# [10]	validation_0-rmse:1.37659	validation_1-rmse:1.32957
# [11]	validation_0-rmse:1.34888	validation_1-rmse:1.30117
# [12]	validation_0-rmse:1.32278	validation_1-rmse:1.27707
# [13]	validation_0-rmse:1.29275	validation_1-rmse:1.24739
# [14]	validation_0-rmse:1.26927	validation_1-rmse:1.22435
# [15]	validation_0-rmse:1.24423	validation_1-rmse:1.20037
# [16]	validation_0-rmse:1.21823	validation_1-rmse:1.17487
# [17]	validation_0-rmse:1.19205	validation_1-rmse:1.14814
# [18]	validation_0-rmse:1.17059	validation_1-rmse:1.12773
# [19]	validation_0-rmse:1.14793	validation_1-rmse:1.10664
# [20]	validation_0-rmse:1.12746	validation_1-rmse:1.08913
# [21]	validation_0-rmse:1.10501	validation_1-rmse:1.06726
# [22]	validation_0-rmse:1.08374	validation_1-rmse:1.04743
# [23]	validation_0-rmse:1.06535	validation_1-rmse:1.02777
# [24]	validation_0-rmse:1.04620	validation_1-rmse:1.00860
# [25]	validation_0-rmse:1.02715	validation_1-rmse:0.99028
# [26]	validation_0-rmse:1.01248	validation_1-rmse:0.97771
# [27]	validation_0-rmse:0.99806	validation_1-rmse:0.96612
# [28]	validation_0-rmse:0.97749	validation_1-rmse:0.94436
# [29]	validation_0-rmse:0.96696	validation_1-rmse:0.93418
# [30]	validation_0-rmse:0.95095	validation_1-rmse:0.91976
# [31]	validation_0-rmse:0.93409	validation_1-rmse:0.90561
# [32]	validation_0-rmse:0.91922	validation_1-rmse:0.89512
# [33]	validation_0-rmse:0.90251	validation_1-rmse:0.88144
# [34]	validation_0-rmse:0.88649	validation_1-rmse:0.86824
# [35]	validation_0-rmse:0.86942	validation_1-rmse:0.85121
# [36]	validation_0-rmse:0.85706	validation_1-rmse:0.84101
# [37]	validation_0-rmse:0.84173	validation_1-rmse:0.82642
# [38]	validation_0-rmse:0.82943	validation_1-rmse:0.81587
# [39]	validation_0-rmse:0.81824	validation_1-rmse:0.80627
# [40]	validation_0-rmse:0.80519	validation_1-rmse:0.79741
# [41]	validation_0-rmse:0.79175	validation_1-rmse:0.78691
# [42]	validation_0-rmse:0.78080	validation_1-rmse:0.77558
# [43]	validation_0-rmse:0.77258	validation_1-rmse:0.77082
# [44]	validation_0-rmse:0.76153	validation_1-rmse:0.75920
# [45]	validation_0-rmse:0.75144	validation_1-rmse:0.75108
# [46]	validation_0-rmse:0.74115	validation_1-rmse:0.74568
# [47]	validation_0-rmse:0.72918	validation_1-rmse:0.74183
# [48]	validation_0-rmse:0.71762	validation_1-rmse:0.73589
# [49]	validation_0-rmse:0.70594	validation_1-rmse:0.72654
# [50]	validation_0-rmse:0.69624	validation_1-rmse:0.72130
# [51]	validation_0-rmse:0.68927	validation_1-rmse:0.72075
# [52]	validation_0-rmse:0.67964	validation_1-rmse:0.71075
# [53]	validation_0-rmse:0.66927	validation_1-rmse:0.70447
# [54]	validation_0-rmse:0.66033	validation_1-rmse:0.69458
# [55]	validation_0-rmse:0.65233	validation_1-rmse:0.68700
# [56]	validation_0-rmse:0.64699	validation_1-rmse:0.68849
# [57]	validation_0-rmse:0.63854	validation_1-rmse:0.68105
# [58]	validation_0-rmse:0.63028	validation_1-rmse:0.67738
# [59]	validation_0-rmse:0.62210	validation_1-rmse:0.67046
# [60]	validation_0-rmse:0.61341	validation_1-rmse:0.66222
# [61]	validation_0-rmse:0.60607	validation_1-rmse:0.66137
# [62]	validation_0-rmse:0.59845	validation_1-rmse:0.65647
# [63]	validation_0-rmse:0.59386	validation_1-rmse:0.65205
# [64]	validation_0-rmse:0.58673	validation_1-rmse:0.64737
# [65]	validation_0-rmse:0.58042	validation_1-rmse:0.64172
# [66]	validation_0-rmse:0.57651	validation_1-rmse:0.64031
# [67]	validation_0-rmse:0.57020	validation_1-rmse:0.63915
# [68]	validation_0-rmse:0.56520	validation_1-rmse:0.63674
# [69]	validation_0-rmse:0.56144	validation_1-rmse:0.63511
# [70]	validation_0-rmse:0.55553	validation_1-rmse:0.63404
# [71]	validation_0-rmse:0.55114	validation_1-rmse:0.63204
# [72]	validation_0-rmse:0.54532	validation_1-rmse:0.62824
# [73]	validation_0-rmse:0.53951	validation_1-rmse:0.62344
# [74]	validation_0-rmse:0.53322	validation_1-rmse:0.62149
# [75]	validation_0-rmse:0.52820	validation_1-rmse:0.62028
# [76]	validation_0-rmse:0.52096	validation_1-rmse:0.61749
# [77]	validation_0-rmse:0.51674	validation_1-rmse:0.61252
# [78]	validation_0-rmse:0.51282	validation_1-rmse:0.61188
# [79]	validation_0-rmse:0.50771	validation_1-rmse:0.60852
# [80]	validation_0-rmse:0.50168	validation_1-rmse:0.60354
# [81]	validation_0-rmse:0.49766	validation_1-rmse:0.60182
# [82]	validation_0-rmse:0.49277	validation_1-rmse:0.59857
# [83]	validation_0-rmse:0.48692	validation_1-rmse:0.59914
# [84]	validation_0-rmse:0.48258	validation_1-rmse:0.59698
# [85]	validation_0-rmse:0.48017	validation_1-rmse:0.59795
# [86]	validation_0-rmse:0.47818	validation_1-rmse:0.59893
# [87]	validation_0-rmse:0.47575	validation_1-rmse:0.59721
# [88]	validation_0-rmse:0.47213	validation_1-rmse:0.59608
# [89]	validation_0-rmse:0.46805	validation_1-rmse:0.59004
# [90]	validation_0-rmse:0.46517	validation_1-rmse:0.58893
# [91]	validation_0-rmse:0.46365	validation_1-rmse:0.58885
# [92]	validation_0-rmse:0.45967	validation_1-rmse:0.58887
# [93]	validation_0-rmse:0.45765	validation_1-rmse:0.58561
# [94]	validation_0-rmse:0.45475	validation_1-rmse:0.58313
# [95]	validation_0-rmse:0.45328	validation_1-rmse:0.58331
# [96]	validation_0-rmse:0.45107	validation_1-rmse:0.58382
# [97]	validation_0-rmse:0.44927	validation_1-rmse:0.58485
# [98]	validation_0-rmse:0.44603	validation_1-rmse:0.58351
# [99]	validation_0-rmse:0.44240	validation_1-rmse:0.58456
# [100]	validation_0-rmse:0.44030	validation_1-rmse:0.58322
# [101]	validation_0-rmse:0.43706	validation_1-rmse:0.58202
# [102]	validation_0-rmse:0.43256	validation_1-rmse:0.57927
# [103]	validation_0-rmse:0.42994	validation_1-rmse:0.57934
# [104]	validation_0-rmse:0.42795	validation_1-rmse:0.57959
# [105]	validation_0-rmse:0.42551	validation_1-rmse:0.57917
# [106]	validation_0-rmse:0.42392	validation_1-rmse:0.58036
# [107]	validation_0-rmse:0.42245	validation_1-rmse:0.58085
# [108]	validation_0-rmse:0.42073	validation_1-rmse:0.58163
# [109]	validation_0-rmse:0.41884	validation_1-rmse:0.58209
# [110]	validation_0-rmse:0.41841	validation_1-rmse:0.58224
# [111]	validation_0-rmse:0.41647	validation_1-rmse:0.58130
# [112]	validation_0-rmse:0.41549	validation_1-rmse:0.58162
# [113]	validation_0-rmse:0.41436	validation_1-rmse:0.58249
# [114]	validation_0-rmse:0.41260	validation_1-rmse:0.58406
# [115]	validation_0-rmse:0.41041	validation_1-rmse:0.58370
# [116]	validation_0-rmse:0.40992	validation_1-rmse:0.58394
# [117]	validation_0-rmse:0.40872	validation_1-rmse:0.58463
# [118]	validation_0-rmse:0.40705	validation_1-rmse:0.58590
# [119]	validation_0-rmse:0.40601	validation_1-rmse:0.58866
# [120]	validation_0-rmse:0.40460	validation_1-rmse:0.58832
# [121]	validation_0-rmse:0.40334	validation_1-rmse:0.58881
# [122]	validation_0-rmse:0.40167	validation_1-rmse:0.58609
# [123]	validation_0-rmse:0.40091	validation_1-rmse:0.58702
# [124]	validation_0-rmse:0.39914	validation_1-rmse:0.58544
# [125]	validation_0-rmse:0.39878	validation_1-rmse:0.58569
# [0]	validation_0-rmse:1.66752	validation_1-rmse:1.72911
# [1]	validation_0-rmse:1.63195	validation_1-rmse:1.69543
# [2]	validation_0-rmse:1.59933	validation_1-rmse:1.65862
# [3]	validation_0-rmse:1.56447	validation_1-rmse:1.62883
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.52886	validation_1-rmse:1.59926
# [5]	validation_0-rmse:1.50216	validation_1-rmse:1.57629
# [6]	validation_0-rmse:1.47139	validation_1-rmse:1.54190
# [7]	validation_0-rmse:1.43895	validation_1-rmse:1.50999
# [8]	validation_0-rmse:1.40812	validation_1-rmse:1.48355
# [9]	validation_0-rmse:1.38063	validation_1-rmse:1.45869
# [10]	validation_0-rmse:1.35448	validation_1-rmse:1.43290
# [11]	validation_0-rmse:1.32767	validation_1-rmse:1.40454
# [12]	validation_0-rmse:1.30045	validation_1-rmse:1.38120
# [13]	validation_0-rmse:1.27433	validation_1-rmse:1.35664
# [14]	validation_0-rmse:1.24602	validation_1-rmse:1.32572
# [15]	validation_0-rmse:1.21994	validation_1-rmse:1.29820
# [16]	validation_0-rmse:1.19736	validation_1-rmse:1.27148
# [17]	validation_0-rmse:1.17528	validation_1-rmse:1.24871
# [18]	validation_0-rmse:1.15040	validation_1-rmse:1.22386
# [19]	validation_0-rmse:1.12808	validation_1-rmse:1.20027
# [20]	validation_0-rmse:1.10911	validation_1-rmse:1.18694
# [21]	validation_0-rmse:1.08751	validation_1-rmse:1.16453
# [22]	validation_0-rmse:1.06997	validation_1-rmse:1.14792
# [23]	validation_0-rmse:1.04918	validation_1-rmse:1.12606
# [24]	validation_0-rmse:1.03012	validation_1-rmse:1.10656
# [25]	validation_0-rmse:1.01369	validation_1-rmse:1.09094
# [26]	validation_0-rmse:0.99851	validation_1-rmse:1.07561
# [27]	validation_0-rmse:0.98450	validation_1-rmse:1.06356
# [28]	validation_0-rmse:0.96526	validation_1-rmse:1.04344
# [29]	validation_0-rmse:0.94905	validation_1-rmse:1.02589
# [30]	validation_0-rmse:0.93097	validation_1-rmse:1.01022
# [31]	validation_0-rmse:0.91644	validation_1-rmse:0.99579
# [32]	validation_0-rmse:0.90289	validation_1-rmse:0.98210
# [33]	validation_0-rmse:0.88958	validation_1-rmse:0.97358
# [34]	validation_0-rmse:0.87492	validation_1-rmse:0.95884
# [35]	validation_0-rmse:0.85846	validation_1-rmse:0.93986
# [36]	validation_0-rmse:0.84400	validation_1-rmse:0.92492
# [37]	validation_0-rmse:0.83034	validation_1-rmse:0.91153
# [38]	validation_0-rmse:0.81741	validation_1-rmse:0.89676
# [39]	validation_0-rmse:0.80500	validation_1-rmse:0.88806
# [40]	validation_0-rmse:0.79415	validation_1-rmse:0.88004
# [41]	validation_0-rmse:0.78257	validation_1-rmse:0.86906
# [42]	validation_0-rmse:0.77005	validation_1-rmse:0.85825
# [43]	validation_0-rmse:0.76139	validation_1-rmse:0.84629
# [44]	validation_0-rmse:0.75418	validation_1-rmse:0.83952
# [45]	validation_0-rmse:0.74429	validation_1-rmse:0.83106
# [46]	validation_0-rmse:0.73286	validation_1-rmse:0.81917
# [47]	validation_0-rmse:0.72430	validation_1-rmse:0.81316
# [48]	validation_0-rmse:0.71398	validation_1-rmse:0.80657
# [49]	validation_0-rmse:0.70127	validation_1-rmse:0.79505
# [50]	validation_0-rmse:0.69120	validation_1-rmse:0.79059
# [51]	validation_0-rmse:0.68249	validation_1-rmse:0.78442
# [52]	validation_0-rmse:0.67570	validation_1-rmse:0.77634
# [53]	validation_0-rmse:0.66711	validation_1-rmse:0.76925
# [54]	validation_0-rmse:0.65871	validation_1-rmse:0.76382
# [55]	validation_0-rmse:0.65036	validation_1-rmse:0.75774
# [56]	validation_0-rmse:0.64547	validation_1-rmse:0.75177
# [57]	validation_0-rmse:0.63754	validation_1-rmse:0.74446
# [58]	validation_0-rmse:0.63188	validation_1-rmse:0.73940
# [59]	validation_0-rmse:0.62374	validation_1-rmse:0.73104
# [60]	validation_0-rmse:0.61517	validation_1-rmse:0.72518
# [61]	validation_0-rmse:0.60622	validation_1-rmse:0.71551
# [62]	validation_0-rmse:0.59852	validation_1-rmse:0.70928
# [63]	validation_0-rmse:0.59093	validation_1-rmse:0.70412
# [64]	validation_0-rmse:0.58345	validation_1-rmse:0.69780
# [65]	validation_0-rmse:0.58021	validation_1-rmse:0.69494
# [66]	validation_0-rmse:0.57555	validation_1-rmse:0.68868
# [67]	validation_0-rmse:0.57006	validation_1-rmse:0.68383
# [68]	validation_0-rmse:0.56531	validation_1-rmse:0.67856
# [69]	validation_0-rmse:0.55942	validation_1-rmse:0.67596
# [70]	validation_0-rmse:0.55384	validation_1-rmse:0.67289
# [71]	validation_0-rmse:0.54700	validation_1-rmse:0.66643
# [72]	validation_0-rmse:0.54254	validation_1-rmse:0.66079
# [73]	validation_0-rmse:0.53837	validation_1-rmse:0.65818
# [74]	validation_0-rmse:0.53333	validation_1-rmse:0.65325
# [75]	validation_0-rmse:0.52788	validation_1-rmse:0.65167
# [76]	validation_0-rmse:0.52125	validation_1-rmse:0.64500
# [77]	validation_0-rmse:0.51754	validation_1-rmse:0.64009
# [78]	validation_0-rmse:0.51155	validation_1-rmse:0.63993
# [79]	validation_0-rmse:0.50626	validation_1-rmse:0.63503
# [80]	validation_0-rmse:0.50174	validation_1-rmse:0.63135
# [81]	validation_0-rmse:0.49913	validation_1-rmse:0.62984
# [82]	validation_0-rmse:0.49472	validation_1-rmse:0.62828
# [83]	validation_0-rmse:0.49013	validation_1-rmse:0.62403
# [84]	validation_0-rmse:0.48574	validation_1-rmse:0.62186
# [85]	validation_0-rmse:0.48185	validation_1-rmse:0.61811
# [86]	validation_0-rmse:0.47763	validation_1-rmse:0.61356
# [87]	validation_0-rmse:0.47326	validation_1-rmse:0.60911
# [88]	validation_0-rmse:0.46915	validation_1-rmse:0.60445
# [89]	validation_0-rmse:0.46602	validation_1-rmse:0.60485
# [90]	validation_0-rmse:0.46246	validation_1-rmse:0.60262
# [91]	validation_0-rmse:0.46006	validation_1-rmse:0.60029
# [92]	validation_0-rmse:0.45634	validation_1-rmse:0.59991
# [93]	validation_0-rmse:0.45428	validation_1-rmse:0.59888
# [94]	validation_0-rmse:0.45211	validation_1-rmse:0.59848
# [95]	validation_0-rmse:0.44938	validation_1-rmse:0.59579
# [96]	validation_0-rmse:0.44627	validation_1-rmse:0.59534
# [97]	validation_0-rmse:0.44544	validation_1-rmse:0.59700
# [98]	validation_0-rmse:0.44410	validation_1-rmse:0.59519
# [99]	validation_0-rmse:0.44085	validation_1-rmse:0.59431
# [100]	validation_0-rmse:0.43807	validation_1-rmse:0.59396
# [101]	validation_0-rmse:0.43432	validation_1-rmse:0.59182
# [102]	validation_0-rmse:0.43171	validation_1-rmse:0.59035
# [103]	validation_0-rmse:0.42961	validation_1-rmse:0.58967
# [104]	validation_0-rmse:0.42821	validation_1-rmse:0.58880
# [105]	validation_0-rmse:0.42621	validation_1-rmse:0.58751
# [106]	validation_0-rmse:0.42381	validation_1-rmse:0.58589
# [107]	validation_0-rmse:0.42109	validation_1-rmse:0.58625
# [108]	validation_0-rmse:0.42017	validation_1-rmse:0.58420
# [109]	validation_0-rmse:0.41915	validation_1-rmse:0.58386
# [110]	validation_0-rmse:0.41656	validation_1-rmse:0.58447
# [111]	validation_0-rmse:0.41494	validation_1-rmse:0.58451
# [112]	validation_0-rmse:0.41424	validation_1-rmse:0.58398
# [113]	validation_0-rmse:0.41350	validation_1-rmse:0.58378
# [114]	validation_0-rmse:0.41117	validation_1-rmse:0.58114
# [115]	validation_0-rmse:0.40921	validation_1-rmse:0.58043
# [116]	validation_0-rmse:0.40676	validation_1-rmse:0.57696
# [117]	validation_0-rmse:0.40677	validation_1-rmse:0.57696
# [118]	validation_0-rmse:0.40584	validation_1-rmse:0.57650
# [119]	validation_0-rmse:0.40389	validation_1-rmse:0.57580
# [120]	validation_0-rmse:0.40264	validation_1-rmse:0.57692
# [121]	validation_0-rmse:0.40015	validation_1-rmse:0.57903
# [122]	validation_0-rmse:0.39913	validation_1-rmse:0.58039
# [123]	validation_0-rmse:0.39920	validation_1-rmse:0.57749
# [124]	validation_0-rmse:0.39661	validation_1-rmse:0.57767
# [125]	validation_0-rmse:0.39504	validation_1-rmse:0.57783
# [126]	validation_0-rmse:0.39432	validation_1-rmse:0.57753
# [127]	validation_0-rmse:0.39390	validation_1-rmse:0.57782
# [128]	validation_0-rmse:0.39141	validation_1-rmse:0.57798
# [129]	validation_0-rmse:0.39043	validation_1-rmse:0.57730
# [130]	validation_0-rmse:0.39023	validation_1-rmse:0.57715
# [131]	validation_0-rmse:0.38834	validation_1-rmse:0.57610
# [132]	validation_0-rmse:0.38656	validation_1-rmse:0.57630
# [133]	validation_0-rmse:0.38518	validation_1-rmse:0.57497
# [134]	validation_0-rmse:0.38456	validation_1-rmse:0.57432
# [135]	validation_0-rmse:0.38478	validation_1-rmse:0.57448
# [136]	validation_0-rmse:0.38452	validation_1-rmse:0.57502
# [137]	validation_0-rmse:0.38222	validation_1-rmse:0.57529
# [138]	validation_0-rmse:0.38106	validation_1-rmse:0.57405
# [139]	validation_0-rmse:0.37935	validation_1-rmse:0.57512
# [140]	validation_0-rmse:0.37784	validation_1-rmse:0.57602
# [141]	validation_0-rmse:0.37631	validation_1-rmse:0.57529
# [142]	validation_0-rmse:0.37559	validation_1-rmse:0.57509
# [143]	validation_0-rmse:0.37485	validation_1-rmse:0.57264
# [144]	validation_0-rmse:0.37461	validation_1-rmse:0.57246
# [145]	validation_0-rmse:0.37438	validation_1-rmse:0.57228
# [146]	validation_0-rmse:0.37343	validation_1-rmse:0.57163
# [147]	validation_0-rmse:0.37344	validation_1-rmse:0.57164
# [148]	validation_0-rmse:0.37281	validation_1-rmse:0.57269
# [149]	validation_0-rmse:0.37178	validation_1-rmse:0.57246
# [150]	validation_0-rmse:0.37036	validation_1-rmse:0.57068
# [0]	validation_0-rmse:1.73543	validation_1-rmse:1.44937
# [1]	validation_0-rmse:1.69913	validation_1-rmse:1.41723
# [2]	validation_0-rmse:1.66264	validation_1-rmse:1.38441
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:1.62995	validation_1-rmse:1.35913
# [4]	validation_0-rmse:1.59420	validation_1-rmse:1.32998
# [5]	validation_0-rmse:1.55946	validation_1-rmse:1.30079
# [6]	validation_0-rmse:1.52598	validation_1-rmse:1.26946
# [7]	validation_0-rmse:1.49102	validation_1-rmse:1.24183
# [8]	validation_0-rmse:1.45936	validation_1-rmse:1.21161
# [9]	validation_0-rmse:1.43130	validation_1-rmse:1.19005
# [10]	validation_0-rmse:1.40024	validation_1-rmse:1.16356
# [11]	validation_0-rmse:1.37252	validation_1-rmse:1.13983
# [12]	validation_0-rmse:1.34722	validation_1-rmse:1.11855
# [13]	validation_0-rmse:1.32020	validation_1-rmse:1.09839
# [14]	validation_0-rmse:1.29257	validation_1-rmse:1.07321
# [15]	validation_0-rmse:1.26961	validation_1-rmse:1.04996
# [16]	validation_0-rmse:1.24720	validation_1-rmse:1.03140
# [17]	validation_0-rmse:1.22234	validation_1-rmse:1.01390
# [18]	validation_0-rmse:1.19617	validation_1-rmse:0.98942
# [19]	validation_0-rmse:1.17228	validation_1-rmse:0.97240
# [20]	validation_0-rmse:1.15014	validation_1-rmse:0.95454
# [21]	validation_0-rmse:1.12756	validation_1-rmse:0.93670
# [22]	validation_0-rmse:1.10480	validation_1-rmse:0.91952
# [23]	validation_0-rmse:1.08287	validation_1-rmse:0.89886
# [24]	validation_0-rmse:1.06222	validation_1-rmse:0.88262
# [25]	validation_0-rmse:1.04539	validation_1-rmse:0.86878
# [26]	validation_0-rmse:1.02667	validation_1-rmse:0.85088
# [27]	validation_0-rmse:1.00957	validation_1-rmse:0.84140
# [28]	validation_0-rmse:0.98961	validation_1-rmse:0.82272
# [29]	validation_0-rmse:0.97181	validation_1-rmse:0.81027
# [30]	validation_0-rmse:0.95648	validation_1-rmse:0.79466
# [31]	validation_0-rmse:0.94274	validation_1-rmse:0.78562
# [32]	validation_0-rmse:0.92507	validation_1-rmse:0.76930
# [33]	validation_0-rmse:0.90983	validation_1-rmse:0.76278
# [34]	validation_0-rmse:0.89488	validation_1-rmse:0.75423
# [35]	validation_0-rmse:0.87973	validation_1-rmse:0.74207
# [36]	validation_0-rmse:0.86578	validation_1-rmse:0.72858
# [37]	validation_0-rmse:0.85292	validation_1-rmse:0.72040
# [38]	validation_0-rmse:0.83466	validation_1-rmse:0.70612
# [39]	validation_0-rmse:0.82185	validation_1-rmse:0.70223
# [40]	validation_0-rmse:0.80954	validation_1-rmse:0.69516
# [41]	validation_0-rmse:0.79641	validation_1-rmse:0.68389
# [42]	validation_0-rmse:0.78221	validation_1-rmse:0.67262
# [43]	validation_0-rmse:0.77175	validation_1-rmse:0.66563
# [44]	validation_0-rmse:0.75805	validation_1-rmse:0.65645
# [45]	validation_0-rmse:0.74887	validation_1-rmse:0.64921
# [46]	validation_0-rmse:0.73932	validation_1-rmse:0.64163
# [47]	validation_0-rmse:0.72908	validation_1-rmse:0.63897
# [48]	validation_0-rmse:0.71873	validation_1-rmse:0.63397
# [49]	validation_0-rmse:0.71039	validation_1-rmse:0.63193
# [50]	validation_0-rmse:0.70070	validation_1-rmse:0.62342
# [51]	validation_0-rmse:0.69533	validation_1-rmse:0.61766
# [52]	validation_0-rmse:0.68421	validation_1-rmse:0.61023
# [53]	validation_0-rmse:0.67314	validation_1-rmse:0.60250
# [54]	validation_0-rmse:0.66453	validation_1-rmse:0.59823
# [55]	validation_0-rmse:0.65548	validation_1-rmse:0.59036
# [56]	validation_0-rmse:0.64984	validation_1-rmse:0.58831
# [57]	validation_0-rmse:0.64198	validation_1-rmse:0.58140
# [58]	validation_0-rmse:0.63585	validation_1-rmse:0.58063
# [59]	validation_0-rmse:0.62763	validation_1-rmse:0.57779
# [60]	validation_0-rmse:0.61935	validation_1-rmse:0.57162
# [61]	validation_0-rmse:0.61203	validation_1-rmse:0.56793
# [62]	validation_0-rmse:0.60242	validation_1-rmse:0.55994
# [63]	validation_0-rmse:0.59555	validation_1-rmse:0.55433
# [64]	validation_0-rmse:0.58804	validation_1-rmse:0.54855
# [65]	validation_0-rmse:0.58284	validation_1-rmse:0.54282
# [66]	validation_0-rmse:0.57803	validation_1-rmse:0.53782
# [67]	validation_0-rmse:0.57019	validation_1-rmse:0.53143
# [68]	validation_0-rmse:0.56623	validation_1-rmse:0.52750
# [69]	validation_0-rmse:0.55936	validation_1-rmse:0.52642
# [70]	validation_0-rmse:0.55476	validation_1-rmse:0.52512
# [71]	validation_0-rmse:0.55053	validation_1-rmse:0.52276
# [72]	validation_0-rmse:0.54385	validation_1-rmse:0.52136
# [73]	validation_0-rmse:0.53786	validation_1-rmse:0.51956
# [74]	validation_0-rmse:0.53229	validation_1-rmse:0.51466
# [75]	validation_0-rmse:0.52716	validation_1-rmse:0.51414
# [76]	validation_0-rmse:0.52334	validation_1-rmse:0.51254
# [77]	validation_0-rmse:0.51852	validation_1-rmse:0.51018
# [78]	validation_0-rmse:0.51359	validation_1-rmse:0.50596
# [79]	validation_0-rmse:0.50963	validation_1-rmse:0.50500
# [80]	validation_0-rmse:0.50610	validation_1-rmse:0.50231
# [81]	validation_0-rmse:0.50383	validation_1-rmse:0.50279
# [82]	validation_0-rmse:0.49897	validation_1-rmse:0.50114
# [83]	validation_0-rmse:0.49637	validation_1-rmse:0.50130
# [84]	validation_0-rmse:0.49206	validation_1-rmse:0.49942
# [85]	validation_0-rmse:0.48988	validation_1-rmse:0.49756
# [86]	validation_0-rmse:0.48608	validation_1-rmse:0.49761
# [87]	validation_0-rmse:0.48176	validation_1-rmse:0.49758
# [88]	validation_0-rmse:0.47860	validation_1-rmse:0.49521
# [89]	validation_0-rmse:0.47565	validation_1-rmse:0.49237
# [90]	validation_0-rmse:0.47222	validation_1-rmse:0.49210
# [91]	validation_0-rmse:0.46902	validation_1-rmse:0.48710
# [92]	validation_0-rmse:0.46666	validation_1-rmse:0.48494
# [93]	validation_0-rmse:0.46475	validation_1-rmse:0.48402
# [94]	validation_0-rmse:0.46254	validation_1-rmse:0.47999
# [95]	validation_0-rmse:0.46144	validation_1-rmse:0.47995
# [96]	validation_0-rmse:0.45797	validation_1-rmse:0.47688
# [97]	validation_0-rmse:0.45676	validation_1-rmse:0.47655
# [98]	validation_0-rmse:0.45432	validation_1-rmse:0.47596
# [99]	validation_0-rmse:0.45029	validation_1-rmse:0.47533
# [100]	validation_0-rmse:0.44781	validation_1-rmse:0.47307
# [101]	validation_0-rmse:0.44502	validation_1-rmse:0.47547
# [102]	validation_0-rmse:0.44489	validation_1-rmse:0.47626
# [103]	validation_0-rmse:0.44168	validation_1-rmse:0.47552
# [104]	validation_0-rmse:0.44055	validation_1-rmse:0.47625
# [105]	validation_0-rmse:0.43784	validation_1-rmse:0.47504
# [106]	validation_0-rmse:0.43619	validation_1-rmse:0.47498
# [107]	validation_0-rmse:0.43483	validation_1-rmse:0.47384
# [108]	validation_0-rmse:0.43284	validation_1-rmse:0.47262
# [109]	validation_0-rmse:0.43155	validation_1-rmse:0.47202
# [110]	validation_0-rmse:0.42970	validation_1-rmse:0.47173
# [111]	validation_0-rmse:0.42888	validation_1-rmse:0.46962
# [112]	validation_0-rmse:0.42729	validation_1-rmse:0.46671
# [113]	validation_0-rmse:0.42513	validation_1-rmse:0.46388
# [114]	validation_0-rmse:0.42249	validation_1-rmse:0.46247
# [115]	validation_0-rmse:0.42124	validation_1-rmse:0.46467
# [116]	validation_0-rmse:0.42048	validation_1-rmse:0.46423
# [117]	validation_0-rmse:0.41938	validation_1-rmse:0.46548
# [118]	validation_0-rmse:0.41744	validation_1-rmse:0.46782
# [119]	validation_0-rmse:0.41511	validation_1-rmse:0.46791
# [120]	validation_0-rmse:0.41344	validation_1-rmse:0.46818
# [121]	validation_0-rmse:0.41183	validation_1-rmse:0.46626
# [122]	validation_0-rmse:0.40960	validation_1-rmse:0.46597
# [123]	validation_0-rmse:0.40882	validation_1-rmse:0.46436
# [124]	validation_0-rmse:0.40747	validation_1-rmse:0.46381
# [125]	validation_0-rmse:0.40569	validation_1-rmse:0.46184
# [126]	validation_0-rmse:0.40537	validation_1-rmse:0.46159
# [127]	validation_0-rmse:0.40440	validation_1-rmse:0.46137
# [128]	validation_0-rmse:0.40179	validation_1-rmse:0.46205
# [129]	validation_0-rmse:0.40005	validation_1-rmse:0.46302
# [130]	validation_0-rmse:0.39760	validation_1-rmse:0.46287
# [131]	validation_0-rmse:0.39589	validation_1-rmse:0.46326
# [132]	validation_0-rmse:0.39574	validation_1-rmse:0.46321
# [133]	validation_0-rmse:0.39472	validation_1-rmse:0.46282
# [134]	validation_0-rmse:0.39226	validation_1-rmse:0.46424
# [135]	validation_0-rmse:0.39267	validation_1-rmse:0.46438
# [136]	validation_0-rmse:0.39101	validation_1-rmse:0.46522
# [137]	validation_0-rmse:0.39007	validation_1-rmse:0.46634
# [138]	validation_0-rmse:0.38847	validation_1-rmse:0.46783
# [139]	validation_0-rmse:0.38796	validation_1-rmse:0.46751
# [140]	validation_0-rmse:0.38675	validation_1-rmse:0.46766
# [141]	validation_0-rmse:0.38503	validation_1-rmse:0.46615
# [142]	validation_0-rmse:0.38495	validation_1-rmse:0.46613
# [143]	validation_0-rmse:0.38439	validation_1-rmse:0.46642
# [144]	validation_0-rmse:0.38307	validation_1-rmse:0.46756
# [145]	validation_0-rmse:0.38225	validation_1-rmse:0.46888
# [146]	validation_0-rmse:0.38142	validation_1-rmse:0.46651
# [0]	validation_0-rmse:1.67038	validation_1-rmse:1.71787
# [1]	validation_0-rmse:1.63293	validation_1-rmse:1.67850
# [2]	validation_0-rmse:1.59529	validation_1-rmse:1.64021
# [3]	validation_0-rmse:1.56042	validation_1-rmse:1.60490
# [4]	validation_0-rmse:1.52827	validation_1-rmse:1.57608
# [5]	validation_0-rmse:1.49608	validation_1-rmse:1.54387
# [6]	validation_0-rmse:1.46456	validation_1-rmse:1.51244
# [7]	validation_0-rmse:1.43222	validation_1-rmse:1.47817
# [8]	validation_0-rmse:1.40172	validation_1-rmse:1.44618
# [9]	validation_0-rmse:1.37412	validation_1-rmse:1.42073
# [10]	validation_0-rmse:1.34405	validation_1-rmse:1.39056
# [11]	validation_0-rmse:1.31397	validation_1-rmse:1.36102
# [12]	validation_0-rmse:1.28906	validation_1-rmse:1.33628
# [13]	validation_0-rmse:1.26106	validation_1-rmse:1.31021
# [14]	validation_0-rmse:1.23573	validation_1-rmse:1.28357
# [15]	validation_0-rmse:1.20960	validation_1-rmse:1.25841
# [16]	validation_0-rmse:1.18383	validation_1-rmse:1.23207
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [17]	validation_0-rmse:1.15860	validation_1-rmse:1.20757
# [18]	validation_0-rmse:1.13776	validation_1-rmse:1.18835
# [19]	validation_0-rmse:1.11516	validation_1-rmse:1.16772
# [20]	validation_0-rmse:1.09528	validation_1-rmse:1.15042
# [21]	validation_0-rmse:1.07387	validation_1-rmse:1.13175
# [22]	validation_0-rmse:1.05160	validation_1-rmse:1.11140
# [23]	validation_0-rmse:1.03053	validation_1-rmse:1.08995
# [24]	validation_0-rmse:1.01153	validation_1-rmse:1.07220
# [25]	validation_0-rmse:0.99241	validation_1-rmse:1.05379
# [26]	validation_0-rmse:0.97374	validation_1-rmse:1.03863
# [27]	validation_0-rmse:0.95796	validation_1-rmse:1.02484
# [28]	validation_0-rmse:0.93889	validation_1-rmse:1.00707
# [29]	validation_0-rmse:0.92542	validation_1-rmse:0.99499
# [30]	validation_0-rmse:0.90925	validation_1-rmse:0.98036
# [31]	validation_0-rmse:0.89397	validation_1-rmse:0.96754
# [32]	validation_0-rmse:0.87796	validation_1-rmse:0.95510
# [33]	validation_0-rmse:0.86146	validation_1-rmse:0.94665
# [34]	validation_0-rmse:0.84804	validation_1-rmse:0.93729
# [35]	validation_0-rmse:0.83341	validation_1-rmse:0.92672
# [36]	validation_0-rmse:0.82100	validation_1-rmse:0.91833
# [37]	validation_0-rmse:0.80823	validation_1-rmse:0.90784
# [38]	validation_0-rmse:0.79479	validation_1-rmse:0.89257
# [39]	validation_0-rmse:0.78392	validation_1-rmse:0.88757
# [40]	validation_0-rmse:0.77046	validation_1-rmse:0.87958
# [41]	validation_0-rmse:0.75829	validation_1-rmse:0.87153
# [42]	validation_0-rmse:0.74526	validation_1-rmse:0.86338
# [43]	validation_0-rmse:0.73438	validation_1-rmse:0.85726
# [44]	validation_0-rmse:0.72357	validation_1-rmse:0.84971
# [45]	validation_0-rmse:0.71152	validation_1-rmse:0.84066
# [46]	validation_0-rmse:0.70095	validation_1-rmse:0.83513
# [47]	validation_0-rmse:0.69044	validation_1-rmse:0.82877
# [48]	validation_0-rmse:0.68024	validation_1-rmse:0.82258
# [49]	validation_0-rmse:0.66961	validation_1-rmse:0.81596
# [50]	validation_0-rmse:0.66044	validation_1-rmse:0.81173
# [51]	validation_0-rmse:0.65220	validation_1-rmse:0.80694
# [52]	validation_0-rmse:0.64454	validation_1-rmse:0.80305
# [53]	validation_0-rmse:0.63713	validation_1-rmse:0.79809
# [54]	validation_0-rmse:0.62945	validation_1-rmse:0.79455
# [55]	validation_0-rmse:0.62189	validation_1-rmse:0.78908
# [56]	validation_0-rmse:0.61110	validation_1-rmse:0.78441
# [57]	validation_0-rmse:0.60208	validation_1-rmse:0.78158
# [58]	validation_0-rmse:0.59203	validation_1-rmse:0.77899
# [59]	validation_0-rmse:0.58431	validation_1-rmse:0.77436
# [60]	validation_0-rmse:0.57563	validation_1-rmse:0.77192
# [61]	validation_0-rmse:0.56750	validation_1-rmse:0.76891
# [62]	validation_0-rmse:0.56105	validation_1-rmse:0.76691
# [63]	validation_0-rmse:0.55409	validation_1-rmse:0.76489
# [64]	validation_0-rmse:0.54769	validation_1-rmse:0.76252
# [65]	validation_0-rmse:0.54142	validation_1-rmse:0.76069
# [66]	validation_0-rmse:0.53543	validation_1-rmse:0.76094
# [67]	validation_0-rmse:0.52864	validation_1-rmse:0.75785
# [68]	validation_0-rmse:0.52284	validation_1-rmse:0.75825
# [69]	validation_0-rmse:0.51682	validation_1-rmse:0.75771
# [70]	validation_0-rmse:0.51211	validation_1-rmse:0.75717
# [71]	validation_0-rmse:0.50626	validation_1-rmse:0.75390
# [72]	validation_0-rmse:0.50178	validation_1-rmse:0.75137
# [73]	validation_0-rmse:0.49724	validation_1-rmse:0.75182
# [74]	validation_0-rmse:0.49259	validation_1-rmse:0.75150
# [75]	validation_0-rmse:0.48626	validation_1-rmse:0.75054
# [76]	validation_0-rmse:0.48038	validation_1-rmse:0.75129
# [77]	validation_0-rmse:0.47649	validation_1-rmse:0.74958
# [78]	validation_0-rmse:0.47292	validation_1-rmse:0.74840
# [79]	validation_0-rmse:0.46894	validation_1-rmse:0.74835
# [80]	validation_0-rmse:0.46367	validation_1-rmse:0.74881
# [81]	validation_0-rmse:0.46114	validation_1-rmse:0.74944
# [82]	validation_0-rmse:0.45793	validation_1-rmse:0.74767
# [83]	validation_0-rmse:0.45390	validation_1-rmse:0.74605
# [84]	validation_0-rmse:0.45072	validation_1-rmse:0.74487
# [85]	validation_0-rmse:0.44688	validation_1-rmse:0.74651
# [86]	validation_0-rmse:0.44464	validation_1-rmse:0.74764
# [87]	validation_0-rmse:0.44132	validation_1-rmse:0.74895
# [88]	validation_0-rmse:0.43941	validation_1-rmse:0.74814
# [89]	validation_0-rmse:0.43705	validation_1-rmse:0.74798
# [90]	validation_0-rmse:0.43415	validation_1-rmse:0.74930
# [91]	validation_0-rmse:0.43250	validation_1-rmse:0.75029
# [92]	validation_0-rmse:0.43010	validation_1-rmse:0.74997
# [93]	validation_0-rmse:0.42677	validation_1-rmse:0.74936
# [94]	validation_0-rmse:0.42504	validation_1-rmse:0.75105
# [95]	validation_0-rmse:0.42315	validation_1-rmse:0.75249
# [96]	validation_0-rmse:0.42063	validation_1-rmse:0.75360
# [97]	validation_0-rmse:0.41909	validation_1-rmse:0.75406
# [98]	validation_0-rmse:0.41653	validation_1-rmse:0.75480
# [99]	validation_0-rmse:0.41487	validation_1-rmse:0.75268
# [100]	validation_0-rmse:0.41402	validation_1-rmse:0.75309
# [101]	validation_0-rmse:0.41098	validation_1-rmse:0.75275
# [102]	validation_0-rmse:0.40955	validation_1-rmse:0.75351
# [103]	validation_0-rmse:0.40697	validation_1-rmse:0.75485
# [104]	validation_0-rmse:0.40609	validation_1-rmse:0.75532
# [0]	validation_0-rmse:1.70303	validation_1-rmse:1.58499
# [1]	validation_0-rmse:1.66851	validation_1-rmse:1.55198
# [2]	validation_0-rmse:1.63146	validation_1-rmse:1.51687
# [3]	validation_0-rmse:1.59254	validation_1-rmse:1.47667
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.55949	validation_1-rmse:1.44470
# [5]	validation_0-rmse:1.52531	validation_1-rmse:1.41262
# [6]	validation_0-rmse:1.49422	validation_1-rmse:1.38132
# [7]	validation_0-rmse:1.46031	validation_1-rmse:1.34878
# [8]	validation_0-rmse:1.43350	validation_1-rmse:1.32139
# [9]	validation_0-rmse:1.40622	validation_1-rmse:1.29541
# [10]	validation_0-rmse:1.37890	validation_1-rmse:1.27007
# [11]	validation_0-rmse:1.35227	validation_1-rmse:1.24406
# [12]	validation_0-rmse:1.32278	validation_1-rmse:1.21507
# [13]	validation_0-rmse:1.29647	validation_1-rmse:1.19269
# [14]	validation_0-rmse:1.26957	validation_1-rmse:1.16789
# [15]	validation_0-rmse:1.24569	validation_1-rmse:1.14459
# [16]	validation_0-rmse:1.22208	validation_1-rmse:1.12210
# [17]	validation_0-rmse:1.19727	validation_1-rmse:1.10143
# [18]	validation_0-rmse:1.17161	validation_1-rmse:1.07671
# [19]	validation_0-rmse:1.14982	validation_1-rmse:1.05520
# [20]	validation_0-rmse:1.13091	validation_1-rmse:1.03848
# [21]	validation_0-rmse:1.10750	validation_1-rmse:1.01595
# [22]	validation_0-rmse:1.08568	validation_1-rmse:0.99331
# [23]	validation_0-rmse:1.06511	validation_1-rmse:0.97296
# [24]	validation_0-rmse:1.04406	validation_1-rmse:0.95391
# [25]	validation_0-rmse:1.02543	validation_1-rmse:0.93622
# [26]	validation_0-rmse:1.00789	validation_1-rmse:0.91981
# [27]	validation_0-rmse:0.99078	validation_1-rmse:0.90395
# [28]	validation_0-rmse:0.97542	validation_1-rmse:0.88949
# [29]	validation_0-rmse:0.95703	validation_1-rmse:0.87289
# [30]	validation_0-rmse:0.94222	validation_1-rmse:0.85950
# [31]	validation_0-rmse:0.92574	validation_1-rmse:0.85067
# [32]	validation_0-rmse:0.91130	validation_1-rmse:0.84204
# [33]	validation_0-rmse:0.89462	validation_1-rmse:0.82872
# [34]	validation_0-rmse:0.88143	validation_1-rmse:0.81647
# [35]	validation_0-rmse:0.86912	validation_1-rmse:0.80604
# [36]	validation_0-rmse:0.85595	validation_1-rmse:0.79440
# [37]	validation_0-rmse:0.84434	validation_1-rmse:0.78299
# [38]	validation_0-rmse:0.83549	validation_1-rmse:0.77073
# [39]	validation_0-rmse:0.82203	validation_1-rmse:0.75972
# [40]	validation_0-rmse:0.81010	validation_1-rmse:0.75601
# [41]	validation_0-rmse:0.79510	validation_1-rmse:0.74319
# [42]	validation_0-rmse:0.78252	validation_1-rmse:0.72941
# [43]	validation_0-rmse:0.76908	validation_1-rmse:0.71757
# [44]	validation_0-rmse:0.75791	validation_1-rmse:0.70791
# [45]	validation_0-rmse:0.74656	validation_1-rmse:0.69823
# [46]	validation_0-rmse:0.73646	validation_1-rmse:0.68962
# [47]	validation_0-rmse:0.72539	validation_1-rmse:0.67901
# [48]	validation_0-rmse:0.71714	validation_1-rmse:0.67066
# [49]	validation_0-rmse:0.70561	validation_1-rmse:0.66061
# [50]	validation_0-rmse:0.69802	validation_1-rmse:0.65678
# [51]	validation_0-rmse:0.69016	validation_1-rmse:0.65150
# [52]	validation_0-rmse:0.68302	validation_1-rmse:0.64496
# [53]	validation_0-rmse:0.67533	validation_1-rmse:0.64508
# [54]	validation_0-rmse:0.67019	validation_1-rmse:0.63732
# [55]	validation_0-rmse:0.66033	validation_1-rmse:0.62994
# [56]	validation_0-rmse:0.65171	validation_1-rmse:0.62256
# [57]	validation_0-rmse:0.64430	validation_1-rmse:0.61739
# [58]	validation_0-rmse:0.63735	validation_1-rmse:0.61213
# [59]	validation_0-rmse:0.62962	validation_1-rmse:0.60496
# [60]	validation_0-rmse:0.62229	validation_1-rmse:0.60002
# [61]	validation_0-rmse:0.61661	validation_1-rmse:0.59465
# [62]	validation_0-rmse:0.60831	validation_1-rmse:0.58746
# [63]	validation_0-rmse:0.60223	validation_1-rmse:0.58157
# [64]	validation_0-rmse:0.59585	validation_1-rmse:0.58279
# [65]	validation_0-rmse:0.59249	validation_1-rmse:0.57892
# [66]	validation_0-rmse:0.58707	validation_1-rmse:0.57931
# [67]	validation_0-rmse:0.58234	validation_1-rmse:0.57948
# [68]	validation_0-rmse:0.57573	validation_1-rmse:0.57464
# [69]	validation_0-rmse:0.56983	validation_1-rmse:0.57133
# [70]	validation_0-rmse:0.56581	validation_1-rmse:0.56837
# [71]	validation_0-rmse:0.55806	validation_1-rmse:0.56416
# [72]	validation_0-rmse:0.55185	validation_1-rmse:0.56012
# [73]	validation_0-rmse:0.54745	validation_1-rmse:0.55566
# [74]	validation_0-rmse:0.54293	validation_1-rmse:0.55099
# [75]	validation_0-rmse:0.53683	validation_1-rmse:0.54729
# [76]	validation_0-rmse:0.53225	validation_1-rmse:0.54429
# [77]	validation_0-rmse:0.52653	validation_1-rmse:0.53980
# [78]	validation_0-rmse:0.52431	validation_1-rmse:0.54016
# [79]	validation_0-rmse:0.52031	validation_1-rmse:0.53698
# [80]	validation_0-rmse:0.51691	validation_1-rmse:0.53411
# [81]	validation_0-rmse:0.51349	validation_1-rmse:0.53233
# [82]	validation_0-rmse:0.50963	validation_1-rmse:0.53213
# [83]	validation_0-rmse:0.50667	validation_1-rmse:0.53113
# [84]	validation_0-rmse:0.50377	validation_1-rmse:0.52815
# [85]	validation_0-rmse:0.50015	validation_1-rmse:0.52596
# [86]	validation_0-rmse:0.49534	validation_1-rmse:0.52438
# [87]	validation_0-rmse:0.49209	validation_1-rmse:0.52195
# [88]	validation_0-rmse:0.48842	validation_1-rmse:0.51844
# [89]	validation_0-rmse:0.48609	validation_1-rmse:0.51877
# [90]	validation_0-rmse:0.48298	validation_1-rmse:0.51758
# [91]	validation_0-rmse:0.47916	validation_1-rmse:0.51658
# [92]	validation_0-rmse:0.47550	validation_1-rmse:0.51679
# [93]	validation_0-rmse:0.47271	validation_1-rmse:0.51574
# [94]	validation_0-rmse:0.46885	validation_1-rmse:0.51220
# [95]	validation_0-rmse:0.46659	validation_1-rmse:0.51170
# [96]	validation_0-rmse:0.46555	validation_1-rmse:0.51262
# [97]	validation_0-rmse:0.46255	validation_1-rmse:0.51106
# [98]	validation_0-rmse:0.46101	validation_1-rmse:0.51154
# [99]	validation_0-rmse:0.45758	validation_1-rmse:0.50985
# [100]	validation_0-rmse:0.45265	validation_1-rmse:0.51149
# [101]	validation_0-rmse:0.45123	validation_1-rmse:0.51128
# [102]	validation_0-rmse:0.44840	validation_1-rmse:0.51129
# [103]	validation_0-rmse:0.44655	validation_1-rmse:0.51200
# [104]	validation_0-rmse:0.44482	validation_1-rmse:0.50815
# [105]	validation_0-rmse:0.44291	validation_1-rmse:0.50576
# [106]	validation_0-rmse:0.44115	validation_1-rmse:0.50419
# [107]	validation_0-rmse:0.43878	validation_1-rmse:0.50374
# [108]	validation_0-rmse:0.43787	validation_1-rmse:0.50640
# [109]	validation_0-rmse:0.43575	validation_1-rmse:0.50642
# [110]	validation_0-rmse:0.43367	validation_1-rmse:0.50812
# [111]	validation_0-rmse:0.43181	validation_1-rmse:0.50630
# [112]	validation_0-rmse:0.43084	validation_1-rmse:0.50645
# [113]	validation_0-rmse:0.42977	validation_1-rmse:0.50599
# [114]	validation_0-rmse:0.42795	validation_1-rmse:0.50442
# [115]	validation_0-rmse:0.42636	validation_1-rmse:0.50417
# [116]	validation_0-rmse:0.42482	validation_1-rmse:0.50318
# [117]	validation_0-rmse:0.42309	validation_1-rmse:0.50670
# [118]	validation_0-rmse:0.42191	validation_1-rmse:0.50952
# [119]	validation_0-rmse:0.42036	validation_1-rmse:0.50871
# [120]	validation_0-rmse:0.41869	validation_1-rmse:0.50694
# [121]	validation_0-rmse:0.41707	validation_1-rmse:0.50755
# [122]	validation_0-rmse:0.41579	validation_1-rmse:0.50590
# [123]	validation_0-rmse:0.41477	validation_1-rmse:0.50492
# [124]	validation_0-rmse:0.41283	validation_1-rmse:0.50466
# [125]	validation_0-rmse:0.41120	validation_1-rmse:0.50302
# [126]	validation_0-rmse:0.41099	validation_1-rmse:0.50312
# [127]	validation_0-rmse:0.41027	validation_1-rmse:0.50223
# [128]	validation_0-rmse:0.40908	validation_1-rmse:0.50345
# [129]	validation_0-rmse:0.40781	validation_1-rmse:0.50240
# [130]	validation_0-rmse:0.40676	validation_1-rmse:0.50039
# [131]	validation_0-rmse:0.40562	validation_1-rmse:0.50120
# [132]	validation_0-rmse:0.40406	validation_1-rmse:0.50131
# [133]	validation_0-rmse:0.40276	validation_1-rmse:0.50120
# [134]	validation_0-rmse:0.40239	validation_1-rmse:0.50354
# [135]	validation_0-rmse:0.40234	validation_1-rmse:0.50358
# [136]	validation_0-rmse:0.40204	validation_1-rmse:0.50382
# [137]	validation_0-rmse:0.40106	validation_1-rmse:0.50470
# [138]	validation_0-rmse:0.40047	validation_1-rmse:0.50525
# [139]	validation_0-rmse:0.40055	validation_1-rmse:0.50517
# [140]	validation_0-rmse:0.39997	validation_1-rmse:0.50451
# [141]	validation_0-rmse:0.39884	validation_1-rmse:0.50531
# [142]	validation_0-rmse:0.39737	validation_1-rmse:0.50460
# [143]	validation_0-rmse:0.39564	validation_1-rmse:0.50534
# [144]	validation_0-rmse:0.39411	validation_1-rmse:0.50638
# [145]	validation_0-rmse:0.39300	validation_1-rmse:0.50746
# [146]	validation_0-rmse:0.39113	validation_1-rmse:0.50763
# [147]	validation_0-rmse:0.39053	validation_1-rmse:0.50796
# [148]	validation_0-rmse:0.38992	validation_1-rmse:0.50767
# [149]	validation_0-rmse:0.38830	validation_1-rmse:0.50821
# [150]	validation_0-rmse:0.38675	validation_1-rmse:0.50762
# [0]	validation_0-rmse:1.66362	validation_1-rmse:1.75329
# [1]	validation_0-rmse:1.62883	validation_1-rmse:1.71740
# [2]	validation_0-rmse:1.59546	validation_1-rmse:1.68404
# [3]	validation_0-rmse:1.56176	validation_1-rmse:1.64880
# [4]	validation_0-rmse:1.52605	validation_1-rmse:1.61184
# [5]	validation_0-rmse:1.49265	validation_1-rmse:1.57984
# [6]	validation_0-rmse:1.45878	validation_1-rmse:1.54703
# [7]	validation_0-rmse:1.42783	validation_1-rmse:1.51592
# [8]	validation_0-rmse:1.39897	validation_1-rmse:1.48417
# [9]	validation_0-rmse:1.37188	validation_1-rmse:1.45756
# [10]	validation_0-rmse:1.34432	validation_1-rmse:1.43106
# [11]	validation_0-rmse:1.31991	validation_1-rmse:1.40739
# [12]	validation_0-rmse:1.29300	validation_1-rmse:1.38131
# [13]	validation_0-rmse:1.27015	validation_1-rmse:1.35996
# [14]	validation_0-rmse:1.24156	validation_1-rmse:1.33382
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:1.21593	validation_1-rmse:1.31011
# [16]	validation_0-rmse:1.19060	validation_1-rmse:1.28777
# [17]	validation_0-rmse:1.17197	validation_1-rmse:1.26758
# [18]	validation_0-rmse:1.14473	validation_1-rmse:1.24130
# [19]	validation_0-rmse:1.12292	validation_1-rmse:1.22148
# [20]	validation_0-rmse:1.10014	validation_1-rmse:1.19838
# [21]	validation_0-rmse:1.08189	validation_1-rmse:1.17925
# [22]	validation_0-rmse:1.06188	validation_1-rmse:1.15824
# [23]	validation_0-rmse:1.04254	validation_1-rmse:1.13999
# [24]	validation_0-rmse:1.02624	validation_1-rmse:1.12403
# [25]	validation_0-rmse:1.00903	validation_1-rmse:1.10704
# [26]	validation_0-rmse:0.99159	validation_1-rmse:1.09003
# [27]	validation_0-rmse:0.97042	validation_1-rmse:1.06831
# [28]	validation_0-rmse:0.95278	validation_1-rmse:1.04918
# [29]	validation_0-rmse:0.93698	validation_1-rmse:1.03573
# [30]	validation_0-rmse:0.92128	validation_1-rmse:1.02021
# [31]	validation_0-rmse:0.90449	validation_1-rmse:1.00267
# [32]	validation_0-rmse:0.88723	validation_1-rmse:0.98435
# [33]	validation_0-rmse:0.87054	validation_1-rmse:0.96568
# [34]	validation_0-rmse:0.85650	validation_1-rmse:0.94978
# [35]	validation_0-rmse:0.84333	validation_1-rmse:0.93490
# [36]	validation_0-rmse:0.82947	validation_1-rmse:0.92201
# [37]	validation_0-rmse:0.81797	validation_1-rmse:0.91278
# [38]	validation_0-rmse:0.80163	validation_1-rmse:0.89840
# [39]	validation_0-rmse:0.79067	validation_1-rmse:0.88773
# [40]	validation_0-rmse:0.77757	validation_1-rmse:0.87376
# [41]	validation_0-rmse:0.76465	validation_1-rmse:0.86060
# [42]	validation_0-rmse:0.75607	validation_1-rmse:0.85198
# [43]	validation_0-rmse:0.74458	validation_1-rmse:0.84265
# [44]	validation_0-rmse:0.73244	validation_1-rmse:0.83034
# [45]	validation_0-rmse:0.72127	validation_1-rmse:0.82073
# [46]	validation_0-rmse:0.71206	validation_1-rmse:0.81424
# [47]	validation_0-rmse:0.70129	validation_1-rmse:0.80342
# [48]	validation_0-rmse:0.69218	validation_1-rmse:0.79401
# [49]	validation_0-rmse:0.68414	validation_1-rmse:0.78811
# [50]	validation_0-rmse:0.67665	validation_1-rmse:0.78132
# [51]	validation_0-rmse:0.66843	validation_1-rmse:0.77728
# [52]	validation_0-rmse:0.65991	validation_1-rmse:0.76958
# [53]	validation_0-rmse:0.64981	validation_1-rmse:0.75990
# [54]	validation_0-rmse:0.64212	validation_1-rmse:0.75276
# [55]	validation_0-rmse:0.63341	validation_1-rmse:0.74493
# [56]	validation_0-rmse:0.62512	validation_1-rmse:0.73937
# [57]	validation_0-rmse:0.61622	validation_1-rmse:0.73015
# [58]	validation_0-rmse:0.60905	validation_1-rmse:0.72626
# [59]	validation_0-rmse:0.60287	validation_1-rmse:0.72368
# [60]	validation_0-rmse:0.59409	validation_1-rmse:0.71463
# [61]	validation_0-rmse:0.58779	validation_1-rmse:0.70964
# [62]	validation_0-rmse:0.58045	validation_1-rmse:0.70385
# [63]	validation_0-rmse:0.57488	validation_1-rmse:0.69919
# [64]	validation_0-rmse:0.57006	validation_1-rmse:0.69250
# [65]	validation_0-rmse:0.56429	validation_1-rmse:0.68980
# [66]	validation_0-rmse:0.55854	validation_1-rmse:0.68316
# [67]	validation_0-rmse:0.55131	validation_1-rmse:0.67626
# [68]	validation_0-rmse:0.54441	validation_1-rmse:0.66728
# [69]	validation_0-rmse:0.53914	validation_1-rmse:0.66086
# [70]	validation_0-rmse:0.53381	validation_1-rmse:0.65820
# [71]	validation_0-rmse:0.53029	validation_1-rmse:0.65569
# [72]	validation_0-rmse:0.52365	validation_1-rmse:0.64863
# [73]	validation_0-rmse:0.52067	validation_1-rmse:0.64471
# [74]	validation_0-rmse:0.51442	validation_1-rmse:0.63993
# [75]	validation_0-rmse:0.50783	validation_1-rmse:0.63712
# [76]	validation_0-rmse:0.50359	validation_1-rmse:0.63288
# [77]	validation_0-rmse:0.49857	validation_1-rmse:0.62895
# [78]	validation_0-rmse:0.49435	validation_1-rmse:0.62622
# [79]	validation_0-rmse:0.49055	validation_1-rmse:0.62351
# [80]	validation_0-rmse:0.48685	validation_1-rmse:0.62223
# [81]	validation_0-rmse:0.48235	validation_1-rmse:0.62198
# [82]	validation_0-rmse:0.48134	validation_1-rmse:0.62008
# [83]	validation_0-rmse:0.47924	validation_1-rmse:0.61770
# [84]	validation_0-rmse:0.47538	validation_1-rmse:0.61606
# [85]	validation_0-rmse:0.47348	validation_1-rmse:0.61460
# [86]	validation_0-rmse:0.46976	validation_1-rmse:0.61472
# [87]	validation_0-rmse:0.46871	validation_1-rmse:0.61451
# [88]	validation_0-rmse:0.46385	validation_1-rmse:0.61308
# [89]	validation_0-rmse:0.46090	validation_1-rmse:0.61397
# [90]	validation_0-rmse:0.45894	validation_1-rmse:0.61148
# [91]	validation_0-rmse:0.45741	validation_1-rmse:0.61054
# [92]	validation_0-rmse:0.45414	validation_1-rmse:0.60890
# [93]	validation_0-rmse:0.45018	validation_1-rmse:0.60583
# [94]	validation_0-rmse:0.44879	validation_1-rmse:0.60288
# [95]	validation_0-rmse:0.44782	validation_1-rmse:0.60265
# [96]	validation_0-rmse:0.44608	validation_1-rmse:0.60080
# [97]	validation_0-rmse:0.44315	validation_1-rmse:0.60111
# [98]	validation_0-rmse:0.44098	validation_1-rmse:0.59930
# [99]	validation_0-rmse:0.43738	validation_1-rmse:0.59877
# [100]	validation_0-rmse:0.43528	validation_1-rmse:0.60062
# [101]	validation_0-rmse:0.43350	validation_1-rmse:0.59768
# [102]	validation_0-rmse:0.43054	validation_1-rmse:0.59633
# [103]	validation_0-rmse:0.42772	validation_1-rmse:0.59467
# [104]	validation_0-rmse:0.42629	validation_1-rmse:0.59369
# [105]	validation_0-rmse:0.42359	validation_1-rmse:0.59188
# [106]	validation_0-rmse:0.42061	validation_1-rmse:0.59207
# [107]	validation_0-rmse:0.41894	validation_1-rmse:0.59080
# [108]	validation_0-rmse:0.41796	validation_1-rmse:0.58972
# [109]	validation_0-rmse:0.41684	validation_1-rmse:0.59013
# [110]	validation_0-rmse:0.41456	validation_1-rmse:0.59079
# [111]	validation_0-rmse:0.41368	validation_1-rmse:0.58942
# [112]	validation_0-rmse:0.41225	validation_1-rmse:0.58708
# [113]	validation_0-rmse:0.41131	validation_1-rmse:0.58820
# [114]	validation_0-rmse:0.40768	validation_1-rmse:0.58930
# [115]	validation_0-rmse:0.40626	validation_1-rmse:0.58843
# ...
# [34]	validation_0-rmse:0.84850	validation_1-rmse:1.16585
# [35]	validation_0-rmse:0.83193	validation_1-rmse:1.14620
# [36]	validation_0-rmse:0.82140	validation_1-rmse:1.13421
# [37]	validation_0-rmse:0.80904	validation_1-rmse:1.12038
# [38]	validation_0-rmse:0.79578	validation_1-rmse:1.10749
# [39]	validation_0-rmse:0.78335	validation_1-rmse:1.09252
# [40]	validation_0-rmse:0.77383	validation_1-rmse:1.08178
# [41]	validation_0-rmse:0.76434	validation_1-rmse:1.06955
# [42]	validation_0-rmse:0.75250	validation_1-rmse:1.05422
# [43]	validation_0-rmse:0.74209	validation_1-rmse:1.04201
# [44]	validation_0-rmse:0.73289	validation_1-rmse:1.03150
# [45]	validation_0-rmse:0.72335	validation_1-rmse:1.02040
# [46]	validation_0-rmse:0.71164	validation_1-rmse:1.00773
# [47]	validation_0-rmse:0.70100	validation_1-rmse:0.99361
# [48]	validation_0-rmse:0.68977	validation_1-rmse:0.98274
# [49]	validation_0-rmse:0.68099	validation_1-rmse:0.97126
# [50]	validation_0-rmse:0.67302	validation_1-rmse:0.96259
# [51]	validation_0-rmse:0.66690	validation_1-rmse:0.95736
# [52]	validation_0-rmse:0.65717	validation_1-rmse:0.94796
# [53]	validation_0-rmse:0.65102	validation_1-rmse:0.94150
# [54]	validation_0-rmse:0.64182	validation_1-rmse:0.93341
# [55]	validation_0-rmse:0.63406	validation_1-rmse:0.92353
# [56]	validation_0-rmse:0.62821	validation_1-rmse:0.91532
# [57]	validation_0-rmse:0.62046	validation_1-rmse:0.90965
# [58]	validation_0-rmse:0.61128	validation_1-rmse:0.89825
# [59]	validation_0-rmse:0.60375	validation_1-rmse:0.88992
# [60]	validation_0-rmse:0.59664	validation_1-rmse:0.87858
# [61]	validation_0-rmse:0.58958	validation_1-rmse:0.86937
# [62]	validation_0-rmse:0.58308	validation_1-rmse:0.85989
# [63]	validation_0-rmse:0.57548	validation_1-rmse:0.85103
# [64]	validation_0-rmse:0.56866	validation_1-rmse:0.84327
# [65]	validation_0-rmse:0.56380	validation_1-rmse:0.83432
# [66]	validation_0-rmse:0.56101	validation_1-rmse:0.83363
# [67]	validation_0-rmse:0.55380	validation_1-rmse:0.82480
# [68]	validation_0-rmse:0.54923	validation_1-rmse:0.82213
# [69]	validation_0-rmse:0.54288	validation_1-rmse:0.81493
# [70]	validation_0-rmse:0.53649	validation_1-rmse:0.80627
# [71]	validation_0-rmse:0.53042	validation_1-rmse:0.80247
# [72]	validation_0-rmse:0.52462	validation_1-rmse:0.79718
# [73]	validation_0-rmse:0.51929	validation_1-rmse:0.79271
# [74]	validation_0-rmse:0.51522	validation_1-rmse:0.78785
# [75]	validation_0-rmse:0.51047	validation_1-rmse:0.78343
# [76]	validation_0-rmse:0.50680	validation_1-rmse:0.78155
# [77]	validation_0-rmse:0.50253	validation_1-rmse:0.77419
# [78]	validation_0-rmse:0.49803	validation_1-rmse:0.76938
# [79]	validation_0-rmse:0.49379	validation_1-rmse:0.76546
# [80]	validation_0-rmse:0.48871	validation_1-rmse:0.75979
# [81]	validation_0-rmse:0.48561	validation_1-rmse:0.75539
# [82]	validation_0-rmse:0.48173	validation_1-rmse:0.75040
# [83]	validation_0-rmse:0.47843	validation_1-rmse:0.74901
# [84]	validation_0-rmse:0.47582	validation_1-rmse:0.74558
# [85]	validation_0-rmse:0.47347	validation_1-rmse:0.74268
# [86]	validation_0-rmse:0.47050	validation_1-rmse:0.73850
# [87]	validation_0-rmse:0.46710	validation_1-rmse:0.73540
# [88]	validation_0-rmse:0.46435	validation_1-rmse:0.73284
# [89]	validation_0-rmse:0.46128	validation_1-rmse:0.72867
# [90]	validation_0-rmse:0.46007	validation_1-rmse:0.72788
# [91]	validation_0-rmse:0.45871	validation_1-rmse:0.72570
# [92]	validation_0-rmse:0.45417	validation_1-rmse:0.71849
# [93]	validation_0-rmse:0.45100	validation_1-rmse:0.71470
# [94]	validation_0-rmse:0.44850	validation_1-rmse:0.71040
# [95]	validation_0-rmse:0.44654	validation_1-rmse:0.70737
# [96]	validation_0-rmse:0.44432	validation_1-rmse:0.70379
# [97]	validation_0-rmse:0.44111	validation_1-rmse:0.70198
# [98]	validation_0-rmse:0.43873	validation_1-rmse:0.70002
# [99]	validation_0-rmse:0.43677	validation_1-rmse:0.69873
# [100]	validation_0-rmse:0.43423	validation_1-rmse:0.69708
# [101]	validation_0-rmse:0.43062	validation_1-rmse:0.69432
# [102]	validation_0-rmse:0.42826	validation_1-rmse:0.69001
# [103]	validation_0-rmse:0.42585	validation_1-rmse:0.68713
# [104]	validation_0-rmse:0.42533	validation_1-rmse:0.68595
# [105]	validation_0-rmse:0.42124	validation_1-rmse:0.68040
# [106]	validation_0-rmse:0.41826	validation_1-rmse:0.67693
# [107]	validation_0-rmse:0.41534	validation_1-rmse:0.67654
# [108]	validation_0-rmse:0.41510	validation_1-rmse:0.67733
# [109]	validation_0-rmse:0.41295	validation_1-rmse:0.67657
# [110]	validation_0-rmse:0.41083	validation_1-rmse:0.67757
# [111]	validation_0-rmse:0.40952	validation_1-rmse:0.67597
# [112]	validation_0-rmse:0.40717	validation_1-rmse:0.67268
# [113]	validation_0-rmse:0.40538	validation_1-rmse:0.67339
# [114]	validation_0-rmse:0.40340	validation_1-rmse:0.67139
# [115]	validation_0-rmse:0.40228	validation_1-rmse:0.67082
# [116]	validation_0-rmse:0.39970	validation_1-rmse:0.67157
# [117]	validation_0-rmse:0.39915	validation_1-rmse:0.67009
# [118]	validation_0-rmse:0.39783	validation_1-rmse:0.66957
# [119]	validation_0-rmse:0.39640	validation_1-rmse:0.66795
# [120]	validation_0-rmse:0.39586	validation_1-rmse:0.66854
# [121]	validation_0-rmse:0.39534	validation_1-rmse:0.66892
# [122]	validation_0-rmse:0.39472	validation_1-rmse:0.66831
# [123]	validation_0-rmse:0.39264	validation_1-rmse:0.66630
# [124]	validation_0-rmse:0.39037	validation_1-rmse:0.66479
# [125]	validation_0-rmse:0.38784	validation_1-rmse:0.66751
# [126]	validation_0-rmse:0.38641	validation_1-rmse:0.66458
# [127]	validation_0-rmse:0.38602	validation_1-rmse:0.66415
# [128]	validation_0-rmse:0.38427	validation_1-rmse:0.66186
# [129]	validation_0-rmse:0.38228	validation_1-rmse:0.65851
# [130]	validation_0-rmse:0.38147	validation_1-rmse:0.65697
# [131]	validation_0-rmse:0.37997	validation_1-rmse:0.65527
# [132]	validation_0-rmse:0.37854	validation_1-rmse:0.65472
# [133]	validation_0-rmse:0.37809	validation_1-rmse:0.65448
# [134]	validation_0-rmse:0.37809	validation_1-rmse:0.65446
# [135]	validation_0-rmse:0.37705	validation_1-rmse:0.65450
# [136]	validation_0-rmse:0.37592	validation_1-rmse:0.65048
# [137]	validation_0-rmse:0.37391	validation_1-rmse:0.65038
# [138]	validation_0-rmse:0.37306	validation_1-rmse:0.65004
# [139]	validation_0-rmse:0.37202	validation_1-rmse:0.64903
# [140]	validation_0-rmse:0.37061	validation_1-rmse:0.64830
# [141]	validation_0-rmse:0.37051	validation_1-rmse:0.64783
# [142]	validation_0-rmse:0.36982	validation_1-rmse:0.64720
# [143]	validation_0-rmse:0.36956	validation_1-rmse:0.64591
# [144]	validation_0-rmse:0.36775	validation_1-rmse:0.64514
# [145]	validation_0-rmse:0.36692	validation_1-rmse:0.64605
# [146]	validation_0-rmse:0.36510	validation_1-rmse:0.64443
# [147]	validation_0-rmse:0.36369	validation_1-rmse:0.64378
# [148]	validation_0-rmse:0.36315	validation_1-rmse:0.64307
# [149]	validation_0-rmse:0.36283	validation_1-rmse:0.64418
# [150]	validation_0-rmse:0.36227	validation_1-rmse:0.64415
# [0]	validation_0-rmse:1.61265	validation_1-rmse:1.93510
# [1]	validation_0-rmse:1.58030	validation_1-rmse:1.90407
# [2]	validation_0-rmse:1.54638	validation_1-rmse:1.86726
# [3]	validation_0-rmse:1.50892	validation_1-rmse:1.82591
# [4]	validation_0-rmse:1.47554	validation_1-rmse:1.79332
# [5]	validation_0-rmse:1.44411	validation_1-rmse:1.76012
# [6]	validation_0-rmse:1.41482	validation_1-rmse:1.72744
# [7]	validation_0-rmse:1.38542	validation_1-rmse:1.70136
# [8]	validation_0-rmse:1.35598	validation_1-rmse:1.66974
# [9]	validation_0-rmse:1.32560	validation_1-rmse:1.64139
# [10]	validation_0-rmse:1.30270	validation_1-rmse:1.61910
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [11]	validation_0-rmse:1.27595	validation_1-rmse:1.58906
# [12]	validation_0-rmse:1.25130	validation_1-rmse:1.56485
# [13]	validation_0-rmse:1.22666	validation_1-rmse:1.53849
# [14]	validation_0-rmse:1.20063	validation_1-rmse:1.50977
# [15]	validation_0-rmse:1.17527	validation_1-rmse:1.48331
# [16]	validation_0-rmse:1.15181	validation_1-rmse:1.45777
# [17]	validation_0-rmse:1.13131	validation_1-rmse:1.43484
# [18]	validation_0-rmse:1.10941	validation_1-rmse:1.41180
# [19]	validation_0-rmse:1.08911	validation_1-rmse:1.39101
# [20]	validation_0-rmse:1.06752	validation_1-rmse:1.36749
# [21]	validation_0-rmse:1.04597	validation_1-rmse:1.34267
# [22]	validation_0-rmse:1.02750	validation_1-rmse:1.32316
# [23]	validation_0-rmse:1.00887	validation_1-rmse:1.30308
# [24]	validation_0-rmse:0.99062	validation_1-rmse:1.28543
# [25]	validation_0-rmse:0.97421	validation_1-rmse:1.26730
# [26]	validation_0-rmse:0.95808	validation_1-rmse:1.24891
# [27]	validation_0-rmse:0.94176	validation_1-rmse:1.23007
# [28]	validation_0-rmse:0.92762	validation_1-rmse:1.21389
# [29]	validation_0-rmse:0.91527	validation_1-rmse:1.20294
# [30]	validation_0-rmse:0.90004	validation_1-rmse:1.18779
# [31]	validation_0-rmse:0.88207	validation_1-rmse:1.17189
# [32]	validation_0-rmse:0.86817	validation_1-rmse:1.16049
# [33]	validation_0-rmse:0.85438	validation_1-rmse:1.14510
# [34]	validation_0-rmse:0.84121	validation_1-rmse:1.13240
# [35]	validation_0-rmse:0.82520	validation_1-rmse:1.11396
# [36]	validation_0-rmse:0.80922	validation_1-rmse:1.09638
# [37]	validation_0-rmse:0.79626	validation_1-rmse:1.08352
# [38]	validation_0-rmse:0.78280	validation_1-rmse:1.07089
# [39]	validation_0-rmse:0.77020	validation_1-rmse:1.05623
# [40]	validation_0-rmse:0.75914	validation_1-rmse:1.04457
# [41]	validation_0-rmse:0.74827	validation_1-rmse:1.03174
# [42]	validation_0-rmse:0.73853	validation_1-rmse:1.02155
# [43]	validation_0-rmse:0.72576	validation_1-rmse:1.00974
# [44]	validation_0-rmse:0.71651	validation_1-rmse:0.99776
# [45]	validation_0-rmse:0.70545	validation_1-rmse:0.98403
# [46]	validation_0-rmse:0.69533	validation_1-rmse:0.97359
# [47]	validation_0-rmse:0.68771	validation_1-rmse:0.96335
# [48]	validation_0-rmse:0.67929	validation_1-rmse:0.95538
# [49]	validation_0-rmse:0.66955	validation_1-rmse:0.94763
# [50]	validation_0-rmse:0.66483	validation_1-rmse:0.94184
# [51]	validation_0-rmse:0.65655	validation_1-rmse:0.93656
# [52]	validation_0-rmse:0.64808	validation_1-rmse:0.92737
# [53]	validation_0-rmse:0.64161	validation_1-rmse:0.92213
# [54]	validation_0-rmse:0.63418	validation_1-rmse:0.91388
# [55]	validation_0-rmse:0.62718	validation_1-rmse:0.90340
# [56]	validation_0-rmse:0.62109	validation_1-rmse:0.89772
# [57]	validation_0-rmse:0.61258	validation_1-rmse:0.89045
# [58]	validation_0-rmse:0.60544	validation_1-rmse:0.88393
# [59]	validation_0-rmse:0.59961	validation_1-rmse:0.87664
# [60]	validation_0-rmse:0.59436	validation_1-rmse:0.87077
# [61]	validation_0-rmse:0.58972	validation_1-rmse:0.86535
# [62]	validation_0-rmse:0.58121	validation_1-rmse:0.85381
# [63]	validation_0-rmse:0.57451	validation_1-rmse:0.84700
# [64]	validation_0-rmse:0.56802	validation_1-rmse:0.84292
# [65]	validation_0-rmse:0.56236	validation_1-rmse:0.83877
# [66]	validation_0-rmse:0.55607	validation_1-rmse:0.83608
# [67]	validation_0-rmse:0.55052	validation_1-rmse:0.82909
# [68]	validation_0-rmse:0.54423	validation_1-rmse:0.82425
# [69]	validation_0-rmse:0.53979	validation_1-rmse:0.81840
# [70]	validation_0-rmse:0.53545	validation_1-rmse:0.81395
# [71]	validation_0-rmse:0.53011	validation_1-rmse:0.80858
# [72]	validation_0-rmse:0.52726	validation_1-rmse:0.80565
# [73]	validation_0-rmse:0.52348	validation_1-rmse:0.80068
# [74]	validation_0-rmse:0.51825	validation_1-rmse:0.79426
# [75]	validation_0-rmse:0.51491	validation_1-rmse:0.79305
# [76]	validation_0-rmse:0.51079	validation_1-rmse:0.79134
# [77]	validation_0-rmse:0.50690	validation_1-rmse:0.78554
# [78]	validation_0-rmse:0.50405	validation_1-rmse:0.78390
# [79]	validation_0-rmse:0.50047	validation_1-rmse:0.78073
# [80]	validation_0-rmse:0.49727	validation_1-rmse:0.77686
# [81]	validation_0-rmse:0.49165	validation_1-rmse:0.77047
# [82]	validation_0-rmse:0.48918	validation_1-rmse:0.76502
# [83]	validation_0-rmse:0.48441	validation_1-rmse:0.75855
# [84]	validation_0-rmse:0.48046	validation_1-rmse:0.75468
# [85]	validation_0-rmse:0.47596	validation_1-rmse:0.75257
# [86]	validation_0-rmse:0.47289	validation_1-rmse:0.74817
# [87]	validation_0-rmse:0.46918	validation_1-rmse:0.74399
# [88]	validation_0-rmse:0.46351	validation_1-rmse:0.74348
# [89]	validation_0-rmse:0.46131	validation_1-rmse:0.74258
# [90]	validation_0-rmse:0.45892	validation_1-rmse:0.73994
# [91]	validation_0-rmse:0.45680	validation_1-rmse:0.73559
# [92]	validation_0-rmse:0.45339	validation_1-rmse:0.73344
# [93]	validation_0-rmse:0.45156	validation_1-rmse:0.73003
# [94]	validation_0-rmse:0.44808	validation_1-rmse:0.72662
# [95]	validation_0-rmse:0.44422	validation_1-rmse:0.72386
# [96]	validation_0-rmse:0.44137	validation_1-rmse:0.72072
# [97]	validation_0-rmse:0.43921	validation_1-rmse:0.71842
# [98]	validation_0-rmse:0.43861	validation_1-rmse:0.71863
# [99]	validation_0-rmse:0.43649	validation_1-rmse:0.71567
# [100]	validation_0-rmse:0.43347	validation_1-rmse:0.71290
# [101]	validation_0-rmse:0.43194	validation_1-rmse:0.71373
# [102]	validation_0-rmse:0.43124	validation_1-rmse:0.71291
# [103]	validation_0-rmse:0.43037	validation_1-rmse:0.71036
# [104]	validation_0-rmse:0.42663	validation_1-rmse:0.70857
# [105]	validation_0-rmse:0.42533	validation_1-rmse:0.70684
# [106]	validation_0-rmse:0.42444	validation_1-rmse:0.70537
# [107]	validation_0-rmse:0.42249	validation_1-rmse:0.70657
# [108]	validation_0-rmse:0.41848	validation_1-rmse:0.70708
# [109]	validation_0-rmse:0.41706	validation_1-rmse:0.70601
# [110]	validation_0-rmse:0.41600	validation_1-rmse:0.70640
# [111]	validation_0-rmse:0.41529	validation_1-rmse:0.70360
# [112]	validation_0-rmse:0.41322	validation_1-rmse:0.70186
# [113]	validation_0-rmse:0.41140	validation_1-rmse:0.69893
# [114]	validation_0-rmse:0.41026	validation_1-rmse:0.69884
# [115]	validation_0-rmse:0.40914	validation_1-rmse:0.69574
# [116]	validation_0-rmse:0.40764	validation_1-rmse:0.69562
# [117]	validation_0-rmse:0.40527	validation_1-rmse:0.69682
# [118]	validation_0-rmse:0.40461	validation_1-rmse:0.69564
# [119]	validation_0-rmse:0.40219	validation_1-rmse:0.69179
# [120]	validation_0-rmse:0.40127	validation_1-rmse:0.69108
# [121]	validation_0-rmse:0.39941	validation_1-rmse:0.68957
# [122]	validation_0-rmse:0.39798	validation_1-rmse:0.68803
# [123]	validation_0-rmse:0.39764	validation_1-rmse:0.68756
# [124]	validation_0-rmse:0.39645	validation_1-rmse:0.68486
# [125]	validation_0-rmse:0.39449	validation_1-rmse:0.68212
# [126]	validation_0-rmse:0.39199	validation_1-rmse:0.67906
# [127]	validation_0-rmse:0.38953	validation_1-rmse:0.67541
# [128]	validation_0-rmse:0.38975	validation_1-rmse:0.67573
# [129]	validation_0-rmse:0.38829	validation_1-rmse:0.67396
# [130]	validation_0-rmse:0.38652	validation_1-rmse:0.67148
# [131]	validation_0-rmse:0.38514	validation_1-rmse:0.66789
# [132]	validation_0-rmse:0.38417	validation_1-rmse:0.66639
# [133]	validation_0-rmse:0.38105	validation_1-rmse:0.66852
# [134]	validation_0-rmse:0.37975	validation_1-rmse:0.66806
# [135]	validation_0-rmse:0.37794	validation_1-rmse:0.66806
# [136]	validation_0-rmse:0.37818	validation_1-rmse:0.66842
# [137]	validation_0-rmse:0.37779	validation_1-rmse:0.66869
# [138]	validation_0-rmse:0.37690	validation_1-rmse:0.66655
# [139]	validation_0-rmse:0.37489	validation_1-rmse:0.66655
# [140]	validation_0-rmse:0.37373	validation_1-rmse:0.66380
# [141]	validation_0-rmse:0.37164	validation_1-rmse:0.66164
# [142]	validation_0-rmse:0.37148	validation_1-rmse:0.66137
# [143]	validation_0-rmse:0.37007	validation_1-rmse:0.66015
# [144]	validation_0-rmse:0.36964	validation_1-rmse:0.65886
# [145]	validation_0-rmse:0.36847	validation_1-rmse:0.65679
# [146]	validation_0-rmse:0.36831	validation_1-rmse:0.65651
# [147]	validation_0-rmse:0.36715	validation_1-rmse:0.65829
# [148]	validation_0-rmse:0.36679	validation_1-rmse:0.65740
# [149]	validation_0-rmse:0.36664	validation_1-rmse:0.65713
# [150]	validation_0-rmse:0.36644	validation_1-rmse:0.65675
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 130.86, median: 142.0,
#  pred. interval (P(0.025)-P(0.975)): 74.975-150.0,
#  conf. interval (p-value=0.95): 126.218-145.491
# ***
# Aggregate bias statistic:
#  mean: 1.878, median: 1.624,
#  pred. interval (P(0.025)-P(0.975)): -1.592-6.986,
#  conf. interval (p-value=0.95): 0.713-2.695
# ***
# Aggregate RMSE statistic:
#  mean: 0.587, median: 0.596, pred. interval (P(0.025)-P(0.975)): 0.406-0.749,
#  conf. interval (p-value=0.95): 0.551-0.63
# ***
# Aggregate MSE statistic:
#  mean: 0.352, median: 0.356, pred. interval (P(0.025)-P(0.975)): 0.165-0.56,
#  conf. interval (p-value=0.95): 0.306-0.398
# ***
# Aggregate R^2 statistic:
#  mean: 0.419, median: 0.44, pred. interval (P(0.025)-P(0.975)): 0.066-0.7,
#  conf. interval (p-value=0.95): 0.36-0.511
# ***
# Aggregate bias(%) statistic:
#  mean: -1.657, median: 1.624, pred. interval (P(0.025)-P(0.975)): -5.537-1.596,
#  conf. interval (p-value=0.95): -2.395--0.598
# ***
# Aggregate RMSE(%) statistic:
#  mean: -0.576, median: -0.578, pred. interval (P(0.025)-P(0.975)): -0.731--0.391,
#  conf. interval (p-value=0.95): -0.618--0.532
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.68042
# [1]	validation_0-rmse:1.64278
# [2]	validation_0-rmse:1.60820
# [3]	validation_0-rmse:1.57495
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.53914
# [5]	validation_0-rmse:1.50505
# [6]	validation_0-rmse:1.47166
# [7]	validation_0-rmse:1.44153
# [8]	validation_0-rmse:1.41110
# [9]	validation_0-rmse:1.38419
# [10]	validation_0-rmse:1.35667
# [11]	validation_0-rmse:1.33053
# [12]	validation_0-rmse:1.30405
# [13]	validation_0-rmse:1.28098
# [14]	validation_0-rmse:1.25570
# [15]	validation_0-rmse:1.23196
# [16]	validation_0-rmse:1.20841
# [17]	validation_0-rmse:1.18468
# [18]	validation_0-rmse:1.16068
# [19]	validation_0-rmse:1.13835
# [20]	validation_0-rmse:1.11710
# [21]	validation_0-rmse:1.09278
# [22]	validation_0-rmse:1.07339
# [23]	validation_0-rmse:1.05381
# [24]	validation_0-rmse:1.03646
# [25]	validation_0-rmse:1.02061
# [26]	validation_0-rmse:1.00333
# [27]	validation_0-rmse:0.99094
# [28]	validation_0-rmse:0.97323
# [29]	validation_0-rmse:0.95577
# [30]	validation_0-rmse:0.93808
# [31]	validation_0-rmse:0.92316
# [32]	validation_0-rmse:0.90700
# [33]	validation_0-rmse:0.89014
# [34]	validation_0-rmse:0.87548
# [35]	validation_0-rmse:0.85931
# [36]	validation_0-rmse:0.84504
# [37]	validation_0-rmse:0.83218
# [38]	validation_0-rmse:0.81859
# [39]	validation_0-rmse:0.80567
# [40]	validation_0-rmse:0.79541
# [41]	validation_0-rmse:0.78475
# [42]	validation_0-rmse:0.77214
# [43]	validation_0-rmse:0.75969
# [44]	validation_0-rmse:0.74746
# [45]	validation_0-rmse:0.73670
# [46]	validation_0-rmse:0.72861
# [47]	validation_0-rmse:0.71691
# [48]	validation_0-rmse:0.70697
# [49]	validation_0-rmse:0.69788
# [50]	validation_0-rmse:0.68983
# [51]	validation_0-rmse:0.67976
# [52]	validation_0-rmse:0.67159
# [53]	validation_0-rmse:0.66135
# [54]	validation_0-rmse:0.65503
# [55]	validation_0-rmse:0.64861
# [56]	validation_0-rmse:0.63918
# [57]	validation_0-rmse:0.63171
# [58]	validation_0-rmse:0.62406
# [59]	validation_0-rmse:0.61854
# [60]	validation_0-rmse:0.60969
# [61]	validation_0-rmse:0.60256
# [62]	validation_0-rmse:0.59606
# [63]	validation_0-rmse:0.58946
# [64]	validation_0-rmse:0.58117
# [65]	validation_0-rmse:0.57540
# [66]	validation_0-rmse:0.56852
# [67]	validation_0-rmse:0.56158
# [68]	validation_0-rmse:0.55602
# [69]	validation_0-rmse:0.54949
# [70]	validation_0-rmse:0.54455
# [71]	validation_0-rmse:0.53904
# [72]	validation_0-rmse:0.53180
# [73]	validation_0-rmse:0.52791
# [74]	validation_0-rmse:0.52337
# [75]	validation_0-rmse:0.51909
# [76]	validation_0-rmse:0.51447
# [77]	validation_0-rmse:0.51097
# [78]	validation_0-rmse:0.50626
# [79]	validation_0-rmse:0.50308
# [80]	validation_0-rmse:0.49863
# [81]	validation_0-rmse:0.49457
# [82]	validation_0-rmse:0.49001
# [83]	validation_0-rmse:0.48692
# [84]	validation_0-rmse:0.48483
# [85]	validation_0-rmse:0.48169
# [86]	validation_0-rmse:0.47835
# [87]	validation_0-rmse:0.47348
# [88]	validation_0-rmse:0.46972
# [89]	validation_0-rmse:0.46669
# [90]	validation_0-rmse:0.46340
# [91]	validation_0-rmse:0.46073
# [92]	validation_0-rmse:0.45878
# [93]	validation_0-rmse:0.45639
# [94]	validation_0-rmse:0.45587
# [95]	validation_0-rmse:0.45267
# [96]	validation_0-rmse:0.45016
# [97]	validation_0-rmse:0.44773
# [98]	validation_0-rmse:0.44492
# [99]	validation_0-rmse:0.44348
# [100]	validation_0-rmse:0.44099
# [101]	validation_0-rmse:0.43874
# [102]	validation_0-rmse:0.43553
# [103]	validation_0-rmse:0.43278
# [104]	validation_0-rmse:0.42947
# [105]	validation_0-rmse:0.42838
# [106]	validation_0-rmse:0.42732
# [107]	validation_0-rmse:0.42559
# [108]	validation_0-rmse:0.42391
# [109]	validation_0-rmse:0.42208
# [110]	validation_0-rmse:0.42019
# [111]	validation_0-rmse:0.41934
# [112]	validation_0-rmse:0.41856
# [113]	validation_0-rmse:0.41696
# [114]	validation_0-rmse:0.41559
# [115]	validation_0-rmse:0.41456
# [116]	validation_0-rmse:0.41304
# [117]	validation_0-rmse:0.41276
# [118]	validation_0-rmse:0.41070
# [119]	validation_0-rmse:0.40948
# [120]	validation_0-rmse:0.40929
# [121]	validation_0-rmse:0.40818
# [122]	validation_0-rmse:0.40725
# [123]	validation_0-rmse:0.40584
# [124]	validation_0-rmse:0.40383
# [125]	validation_0-rmse:0.40279
# [126]	validation_0-rmse:0.40055
# [127]	validation_0-rmse:0.39952
# [128]	validation_0-rmse:0.39851
# [129]	validation_0-rmse:0.39720
# [130]	validation_0-rmse:0.39621
# [131]	validation_0-rmse:0.39451
# [132]	validation_0-rmse:0.39298
# [133]	validation_0-rmse:0.39281
# [134]	validation_0-rmse:0.39123
# [135]	validation_0-rmse:0.38997
# [136]	validation_0-rmse:0.39000
# [137]	validation_0-rmse:0.38946
# [138]	validation_0-rmse:0.38799
# [139]	validation_0-rmse:0.38668
# [140]	validation_0-rmse:0.38593
# [141]	validation_0-rmse:0.38335
# [142]	validation_0-rmse:0.38261
# [143]	validation_0-rmse:0.38242
# [144]	validation_0-rmse:0.38073
# [145]	validation_0-rmse:0.37977
# [146]	validation_0-rmse:0.37942
# [147]	validation_0-rmse:0.37886
# [148]	validation_0-rmse:0.37768
# [149]	validation_0-rmse:0.37769
# [150]	validation_0-rmse:0.37660
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 150

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  -4.61
# RMSE: 0.4
# Relative RMSE(%):  -0.369
# MSE: 0.1
# R square: 77.8%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: -0.301
# a1: 0.661
# R^2: 0.809
# Uncertainty
# a0: -0.30+/-0.04
# a1: 0.661+/-0.032

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Mfoliage_XGB_model_with_texture.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Mfoliage_XGB_model_with_texture.txt")
