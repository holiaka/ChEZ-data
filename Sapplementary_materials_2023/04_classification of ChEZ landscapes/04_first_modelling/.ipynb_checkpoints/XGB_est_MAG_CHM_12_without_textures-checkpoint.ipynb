# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25 idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167  0.050549
# 1           3600       8.189          15100  ...   0.040919  0.048889
# 2           4360       8.380          14600  ...   0.042397  0.050463
# 3           3420       8.137          12700  ...   0.043719  0.052974
# 4           2200       7.696          12100  ...   0.040659  0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX  idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966    0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602    0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265    0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465    0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420    0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 159 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX'])
            


# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0       4.8122           1.7630               -0.3147           -0.1590
# 1       5.7589           2.4570               -0.2485            0.3429
# 2       5.8464           2.5153               -0.1054            0.5493
# 3       5.7526           2.6304               -0.0834            0.3900
# 4       5.9480           2.6748                0.0000            0.5715
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX
# 0             -2.4418         1.9125     0.85    12.233545   19.097736
# 1             -0.1997         2.6319     1.00    14.964220   17.704655
# 2             -0.2144         2.7020     1.00    15.329449   17.559893
# 3             -0.3510         2.7763     0.97    15.392742   20.676994
# 4             -0.3711         2.8314     1.00    17.944009   21.851387

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
# dtypes: float64(9)
# memory usage: 7.4 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["M_stem_kg_m2", "M_AG_kg_m2"].describe()
# Out:
# /tmp/ipykernel_156017/2044788461.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_specias"])["M_stem_kg_m2", "M_AG_kg_m2"].describe()
#                  M_stem_kg_m2                                              \
#                         count       mean       std    min      25%    50%
# Dominant_specias
# Alder                     4.0  16.170000  5.186990   9.90  12.9225  17.03
# Aspen                     1.0   6.650000       NaN   6.65   6.6500   6.65
# Birch                    23.0   6.809130  3.677786   0.84   4.7650   6.19
# Oak                       3.0  13.513333  4.888725   9.59  10.7750  11.96
# Pine                     71.0  10.550000  7.252887   0.05   3.4400  11.34
# Spruce                    1.0  23.830000       NaN  23.83  23.8300  23.83
#
#                                  M_AG_kg_m2                              \
#                       75%    max      count       mean       std    min
# Dominant_specias
# Alder             20.2775  20.72        4.0  17.542500  5.837530  10.51
# Aspen              6.6500   6.65        1.0   7.990000       NaN   7.99
# Birch              9.7400  15.47       23.0   8.037826  4.112894   1.20
# Oak               15.4750  18.99        3.0  15.896667  6.100798  11.35
# Pine              16.2250  25.04       71.0  12.391408  7.988880   0.45
# Spruce            23.8300  23.83        1.0  28.980000       NaN  28.98
#
#
#                      25%    50%      75%    max
# Dominant_specias
# Alder             13.885  18.39  22.0475  22.88
# Aspen              7.990   7.99   7.9900   7.99
# Birch              5.725   7.40  11.1650  17.55
# Oak               12.430  13.51  18.1700  22.83
# Pine               4.675  13.24  18.7700  28.43
# Spruce            28.980  28.98  28.9800  28.98

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000         103.00000
# mean      4.969534         1.827923             -0.239481           0.05436
# std       1.323782         1.325853              0.893398           0.66008
# min       0.693100        -2.995700             -3.912000          -1.55590
# 25%       4.672800         1.588100             -0.335500          -0.20955
# 50%       5.337500         2.286500             -0.040800           0.24450
# 75%       5.908100         2.730800              0.190600           0.49195
# max       6.508800         3.220500              1.654400           1.41220
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.021247       2.095454    0.808738    13.045021   17.907784
# std              0.803748       1.079203    0.276653     6.609366    7.523377
# min             -2.918800      -0.798500    0.090000     1.293138    2.733019
# 25%             -1.629700       1.801400    0.745000     8.206727   11.615798
# 50%             -0.719500       2.458700    0.960000    13.072916   18.269344
# 75%             -0.358800       2.862800    1.000000    17.432255   22.751595
# max              0.114200       3.366600    1.000000    28.916548   36.355442

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX'])
y = pd.DataFrame(select, columns= ['ln_M_AG_kg_m2'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX
# 0     0.85    12.233545   19.097736
# 1     1.00    14.964220   17.704655
# 2     1.00    15.329449   17.559893
# 3     0.97    15.392742   20.676994
# 4     1.00    17.944009   21.851387

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_AG_kg_m2
# 0         1.9125
# 1         2.6319
# 2         2.7020
# 3         2.7763
# 4         2.8314

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.9208806780843541, 0.8790108660372605, 0.8428328844351755]
#     Mean: 0.881
#     Std: 0.032
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.41601784 0.30929677 0.3613128 ]
#     Mean: 0.362
#     Std: 0.044
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.22461380808029857, 0.3106448587810292, 0.30872793707461915]
#     Mean: 0.281
#     Std: 0.040
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.907 (std: 0.040)
# Parameters: {'colsample_bytree': 0.7795639195981962, 'gamma': 0.15523860064497264, 'learning_rate': 0.06954076966186808, 'max_depth': 3, 'n_estimators': 97, 'subsample': 0.9601329811614894}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.2503551 , 0.37035422, 0.47983375, ..., 0.36319842, 0.66626511,
#        0.25491848]), 'std_fit_time': array([0.02674356, 0.03211786, 0.02301134, ..., 0.00510877, 0.01824932,
#        0.03408302]), 'mean_score_time': array([0.00607314, 0.00816545, 0.00623674, ..., 0.00939598, 0.00911474,
#        0.01111426]), 'std_score_time': array([1.93860819e-04, 3.60790373e-03, 3.21539729e-04, ...,
#        6.61927983e-04, 5.53728882e-05, 3.45600274e-03]), 'param_colsample_bytree': masked_array(data=[0.06594178514635496, 0.8343606626118883,
#                    0.17880110203770455, ..., 0.8004381546405727,
#                    0.7350771589314328, 0.3524784619579375],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.07856263611015041, 0.036957473703963684,
#                    0.348825570957259, ..., 0.19471147691106644,
#                    0.07914354100790333, 0.2556837359632102],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.2582703250528092, 0.3050233087888659,
#                    0.18382980659393103, ..., 0.18445680480597457,
#                    0.19016295759182775, 0.16412029289002697],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[3, 2, 2, ..., 3, 2, 2],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[95, 143, 193, ..., 90, 168, 55],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.5501756625094777, 0.7216766420417304,
#                    0.6544376398932696, ..., 0.5698655982507261,
#                    0.6668804683295183, 0.8201810231116213],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.06594178514635496, 'gamma': 0.07856263611015041, 'learning_rate': 0.2582703250528092, 'max_depth': 3, 'n_estimators': 95, 'subsample': 0.5501756625094777}, {'colsample_bytree': 0.8343606626118883, 'gamma': 0.036957473703963684, 'learning_rate': 0.3050233087888659, 'max_depth': 2, 'n_estimators': 143, 'subsample': 0.7216766420417304}, {'colsample_bytree': 0.17880110203770455, 'gamma': 0.348825570957259, 'learning_rate': 0.18382980659393103, 'max_depth': 2, 'n_estimators': 193, 'subsample': 0.6544376398932696}, {'colsample_bytree': 0.9274515080676274, 'gamma': 0.47250669936373885, 'learning_rate': 0.09726449928962298, 'max_depth': 4, 'n_estimators': 101, 'subsample': 0.9581986012859334}, {'colsample_bytree': 0.1927463277237172, 'gamma': 0.269890597735634, 'learning_rate': 0.25182510280402454, 'max_depth': 4, 'n_estimators': 104, 'subsample': 0.40280837654080537}, {'colsample_bytree': 0.24931652380190716, 'gamma': 0.2766008274753218, 'learning_rate': 0.18984594716385947, 'max_depth': 4, 'n_estimators': 198, 'subsample': 0.8146796663997418}, {'colsample_bytree': 0.5676324185432848, 'gamma': 0.31660387331344064, 'learning_rate': 0.06148729996256006, 'max_depth': 2, 'n_estimators': 86, 'subsample': 0.8675931514699586}, {'colsample_bytree': 0.6815756585347524, 'gamma': 0.12081065656272721, 'learning_rate': 0.2202899528082921, 'max_depth': 4, 'n_estimators': 136, 'subsample': 0.5890079963721662}, {'colsample_bytree': 0.7926541862530478, 'gamma': 0.33967179669961023, 'learning_rate': 0.061710559936242707, 'max_depth': 4, 'n_estimators': 138, 'subsample': 0.8633814108995526}, {'colsample_bytree': 0.4771122476655456, 'gamma': 0.3892947468366241, 'learning_rate': 0.14190881227639549, 'max_depth': 4, 'n_estimators': 180, 'subsample': 0.7657700897697982}, {'colsample_bytree': 0.5967264541394923, 'gamma': 0.09102127858771297, 'learning_rate': 0.11855650740509781, 'max_depth': 3, 'n_estimators': 155, 'subsample': 0.5204075394000403}, {'colsample_bytree': 0.7761100062474006, 'gamma': 0.27475776391849593, 'learning_rate': 0.2747812347504741, 'max_depth': 4, 'n_estimators': 150, 'subsample': 0.6887978198149238}, {'colsample_bytree': 0.2597940318336554, 'gamma': 0.21069371320445512, 'learning_rate': 0.25724658228455316, 'max_depth': 3, 'n_estimators': 119, 'subsample': 0.41825283795358253}, {'colsample_bytree': 0.4243990667729612, 'gamma': 0.07346938289150978, 'learning_rate': 0.19354628621737383, 'max_depth': 2, 'n_estimators': 141, 'subsample': 0.642398029044435}, {'colsample_bytree': 0.23266060274518569, 'gamma': 0.21063010134822813, 'learning_rate': 0.2850006623029074, 'max_depth': 2, 'n_estimators': 163, 'subsample': 0.874079014746191}, {'colsample_bytree': 0.45173873670340925, 'gamma': 0.14714074312057324, 'learning_rate': 0.28327843368187433, 'max_depth': 2, 'n_estimators': 167, 'subsample': 0.41839617871852736}, {'colsample_bytree': 0.7919614000735854, 'gamma': 0.3565630882083143, 'learning_rate': 0.23544483630977636, 'max_depth': 4, 'n_estimators': 96, 'subsample': 0.7215694820264787}, {'colsample_bytree': 0.9378682326014501, 'gamma': 0.3745859448522708, 'learning_rate': 0.08947913296149963, 'max_depth': 3, 'n_estimators': 130, 'subsample': 0.663057146053209}, {'colsample_bytree': 0.26573289407914585, 'gamma': 0.4013449592188484, 'learning_rate': 0.06460131360310117, 'max_depth': 4, 'n_estimators': 125, 'subsample': 0.33588155586435087}, {'colsample_bytree': 0.622679737048299, 'gamma': 0.2689668585667877, 'learning_rate': 0.28869704267395074, 'max_depth': 3, 'n_estimators': 126, 'subsample': 0.31991758209458654}, {'colsample_bytree': 0.3320050174595917, 'gamma': 0.2713173186796376, 'learning_rate': 0.1063961404132983, 'max_depth': 4, 'n_estimators': 99, 'subsample': 0.6538459684794405}, {'colsample_bytree': 0.17686846954088936, 'gamma': 0.10764293480098058, 'learning_rate': 0.2933062062619801, 'max_depth': 3, 'n_estimators': 161, 'subsample': 0.6134179715480522}, {'colsample_by ...
#        0.91179766]), 'split1_test_score': array([0.89173899, 0.90393628, 0.92596373, ..., 0.93797491, 0.92945818,
#        0.92710055]), 'split2_test_score': array([0.86274374, 0.88146433, 0.89942768, ..., 0.89585758, 0.89910648,
#        0.89329185]), 'split3_test_score': array([0.8634167 , 0.93456216, 0.91560552, ..., 0.91941666, 0.92476987,
#        0.91185824]), 'split4_test_score': array([0.80107537, 0.66802558, 0.81860608, ..., 0.60715927, 0.72609317,
#        0.82665275]), 'mean_test_score': array([0.85475441, 0.86144993, 0.88577284, ..., 0.85938385, 0.87943171,
#        0.89414021]), 'std_test_score': array([0.02962487, 0.09829161, 0.03866719, ..., 0.1270249 , 0.07736255,
#        0.03540445]), 'rank_test_score': array([2730, 2580, 1066, ..., 2632, 1595,  170], dtype=int32), 'split0_train_score': array([0.98157597, 0.99168012, 0.95515692, ..., 0.97003967, 0.98442263,
#        0.95460073]), 'split1_train_score': array([0.97963561, 0.98874725, 0.9524531 , ..., 0.96540494, 0.98170772,
#        0.94934498]), 'split2_train_score': array([0.98021177, 0.99087398, 0.95189591, ..., 0.96781417, 0.98143734,
#        0.95272573]), 'split3_train_score': array([0.98094919, 0.99109024, 0.95252286, ..., 0.97290905, 0.98279692,
#        0.94907104]), 'split4_train_score': array([0.98195392, 0.99176692, 0.96180807, ..., 0.97182752, 0.9855194 ,
#        0.95930314]), 'mean_train_score': array([0.98086529, 0.9908317 , 0.95476737, ..., 0.96959907, 0.9831768 ,
#        0.95300912]), 'std_train_score': array([0.00085281, 0.00109618, 0.00369762, ..., 0.00271634, 0.00157278,
#        0.0037726 ])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.7795639195981962
# Gamma: 0.15523860064497264
# Learning_rate: 0.06954076966186808
# Max_depth: 3
# N_estimators: 97
# Subsample: 0.9601329811614894

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:1.79641	validation_1-rmse:1.80563
# [1]	validation_0-rmse:1.67900	validation_1-rmse:1.68762
# [2]	validation_0-rmse:1.57029	validation_1-rmse:1.57762
# [3]	validation_0-rmse:1.46803	validation_1-rmse:1.47444
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.37413	validation_1-rmse:1.37949
# [5]	validation_0-rmse:1.28537	validation_1-rmse:1.28901
# [6]	validation_0-rmse:1.20291	validation_1-rmse:1.20840
# [7]	validation_0-rmse:1.12694	validation_1-rmse:1.13087
# [8]	validation_0-rmse:1.05688	validation_1-rmse:1.06075
# [9]	validation_0-rmse:0.99118	validation_1-rmse:0.99545
# [10]	validation_0-rmse:0.93016	validation_1-rmse:0.93519
# [11]	validation_0-rmse:0.87309	validation_1-rmse:0.88018
# [12]	validation_0-rmse:0.81999	validation_1-rmse:0.82662
# [13]	validation_0-rmse:0.77107	validation_1-rmse:0.78172
# [14]	validation_0-rmse:0.72557	validation_1-rmse:0.73789
# [15]	validation_0-rmse:0.68250	validation_1-rmse:0.69426
# [16]	validation_0-rmse:0.64239	validation_1-rmse:0.65526
# [17]	validation_0-rmse:0.60597	validation_1-rmse:0.62230
# [18]	validation_0-rmse:0.57231	validation_1-rmse:0.59303
# [19]	validation_0-rmse:0.53976	validation_1-rmse:0.56173
# [20]	validation_0-rmse:0.51006	validation_1-rmse:0.53395
# [21]	validation_0-rmse:0.48301	validation_1-rmse:0.50865
# [22]	validation_0-rmse:0.45734	validation_1-rmse:0.48358
# [23]	validation_0-rmse:0.43428	validation_1-rmse:0.46191
# [24]	validation_0-rmse:0.41181	validation_1-rmse:0.44025
# [25]	validation_0-rmse:0.39138	validation_1-rmse:0.41968
# [26]	validation_0-rmse:0.37360	validation_1-rmse:0.40109
# [27]	validation_0-rmse:0.35520	validation_1-rmse:0.38616
# [28]	validation_0-rmse:0.33991	validation_1-rmse:0.37336
# [29]	validation_0-rmse:0.32519	validation_1-rmse:0.36068
# [30]	validation_0-rmse:0.31145	validation_1-rmse:0.35056
# [31]	validation_0-rmse:0.29989	validation_1-rmse:0.34030
# [32]	validation_0-rmse:0.28946	validation_1-rmse:0.32866
# [33]	validation_0-rmse:0.27950	validation_1-rmse:0.31916
# [34]	validation_0-rmse:0.27036	validation_1-rmse:0.31076
# [35]	validation_0-rmse:0.26264	validation_1-rmse:0.30251
# [36]	validation_0-rmse:0.25613	validation_1-rmse:0.29805
# [37]	validation_0-rmse:0.24852	validation_1-rmse:0.29072
# [38]	validation_0-rmse:0.24239	validation_1-rmse:0.28638
# [39]	validation_0-rmse:0.23712	validation_1-rmse:0.28237
# [40]	validation_0-rmse:0.23297	validation_1-rmse:0.27919
# [41]	validation_0-rmse:0.22834	validation_1-rmse:0.27481
# [42]	validation_0-rmse:0.22423	validation_1-rmse:0.27115
# [43]	validation_0-rmse:0.21978	validation_1-rmse:0.26703
# [44]	validation_0-rmse:0.21649	validation_1-rmse:0.26583
# [45]	validation_0-rmse:0.21400	validation_1-rmse:0.26332
# [46]	validation_0-rmse:0.21185	validation_1-rmse:0.26192
# [47]	validation_0-rmse:0.20994	validation_1-rmse:0.26111
# [48]	validation_0-rmse:0.20753	validation_1-rmse:0.25823
# [49]	validation_0-rmse:0.20604	validation_1-rmse:0.25687
# [50]	validation_0-rmse:0.20457	validation_1-rmse:0.25658
# [51]	validation_0-rmse:0.20315	validation_1-rmse:0.25485
# [52]	validation_0-rmse:0.20189	validation_1-rmse:0.25408
# [53]	validation_0-rmse:0.19979	validation_1-rmse:0.25399
# [54]	validation_0-rmse:0.19933	validation_1-rmse:0.25339
# [55]	validation_0-rmse:0.19896	validation_1-rmse:0.25288
# [56]	validation_0-rmse:0.19792	validation_1-rmse:0.25209
# [57]	validation_0-rmse:0.19699	validation_1-rmse:0.25090
# [58]	validation_0-rmse:0.19613	validation_1-rmse:0.25046
# [59]	validation_0-rmse:0.19441	validation_1-rmse:0.25053
# [60]	validation_0-rmse:0.19421	validation_1-rmse:0.25020
# [61]	validation_0-rmse:0.19399	validation_1-rmse:0.24982
# [62]	validation_0-rmse:0.19383	validation_1-rmse:0.24951
# [63]	validation_0-rmse:0.19370	validation_1-rmse:0.24928
# [64]	validation_0-rmse:0.19360	validation_1-rmse:0.24907
# [65]	validation_0-rmse:0.19349	validation_1-rmse:0.24883
# [66]	validation_0-rmse:0.19342	validation_1-rmse:0.24869
# [67]	validation_0-rmse:0.19332	validation_1-rmse:0.24846
# [68]	validation_0-rmse:0.19327	validation_1-rmse:0.24833
# [69]	validation_0-rmse:0.19323	validation_1-rmse:0.24824
# [70]	validation_0-rmse:0.19319	validation_1-rmse:0.24812
# [71]	validation_0-rmse:0.19315	validation_1-rmse:0.24800
# [72]	validation_0-rmse:0.19313	validation_1-rmse:0.24793
# [73]	validation_0-rmse:0.19310	validation_1-rmse:0.24785
# [74]	validation_0-rmse:0.19307	validation_1-rmse:0.24776
# [75]	validation_0-rmse:0.19306	validation_1-rmse:0.24770
# [76]	validation_0-rmse:0.19304	validation_1-rmse:0.24766
# [77]	validation_0-rmse:0.19302	validation_1-rmse:0.24756
# [78]	validation_0-rmse:0.19232	validation_1-rmse:0.24776
# [79]	validation_0-rmse:0.19231	validation_1-rmse:0.24772
# [80]	validation_0-rmse:0.19229	validation_1-rmse:0.24764
# [81]	validation_0-rmse:0.19228	validation_1-rmse:0.24759
# [82]	validation_0-rmse:0.19169	validation_1-rmse:0.24787
# [83]	validation_0-rmse:0.19168	validation_1-rmse:0.24781
# [84]	validation_0-rmse:0.19168	validation_1-rmse:0.24779
# [85]	validation_0-rmse:0.19168	validation_1-rmse:0.24776
# [86]	validation_0-rmse:0.19167	validation_1-rmse:0.24774
# [87]	validation_0-rmse:0.19167	validation_1-rmse:0.24774
# [88]	validation_0-rmse:0.19168	validation_1-rmse:0.24777
# [89]	validation_0-rmse:0.19167	validation_1-rmse:0.24775
# [90]	validation_0-rmse:0.19167	validation_1-rmse:0.24773
# [91]	validation_0-rmse:0.19168	validation_1-rmse:0.24778
# [92]	validation_0-rmse:0.19167	validation_1-rmse:0.24772
# [93]	validation_0-rmse:0.19168	validation_1-rmse:0.24776
# [94]	validation_0-rmse:0.19168	validation_1-rmse:0.24778
# [95]	validation_0-rmse:0.19168	validation_1-rmse:0.24776
# [96]	validation_0-rmse:0.19167	validation_1-rmse:0.24773
# [0]	validation_0-rmse:1.77400	validation_1-rmse:1.90188
# [1]	validation_0-rmse:1.65721	validation_1-rmse:1.78810
# [2]	validation_0-rmse:1.55006	validation_1-rmse:1.68769
# [3]	validation_0-rmse:1.44848	validation_1-rmse:1.58798
# [4]	validation_0-rmse:1.35554	validation_1-rmse:1.49314
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:1.26805	validation_1-rmse:1.40815
# [6]	validation_0-rmse:1.18617	validation_1-rmse:1.32954
# [7]	validation_0-rmse:1.11066	validation_1-rmse:1.25918
# [8]	validation_0-rmse:1.03994	validation_1-rmse:1.18972
# [9]	validation_0-rmse:0.97411	validation_1-rmse:1.12713
# [10]	validation_0-rmse:0.91332	validation_1-rmse:1.07320
# [11]	validation_0-rmse:0.85514	validation_1-rmse:1.01639
# [12]	validation_0-rmse:0.80097	validation_1-rmse:0.96551
# [13]	validation_0-rmse:0.75174	validation_1-rmse:0.91951
# [14]	validation_0-rmse:0.70589	validation_1-rmse:0.87574
# [15]	validation_0-rmse:0.66431	validation_1-rmse:0.84008
# [16]	validation_0-rmse:0.62521	validation_1-rmse:0.80191
# [17]	validation_0-rmse:0.58892	validation_1-rmse:0.76734
# [18]	validation_0-rmse:0.55555	validation_1-rmse:0.73857
# [19]	validation_0-rmse:0.52453	validation_1-rmse:0.70575
# [20]	validation_0-rmse:0.49514	validation_1-rmse:0.68029
# [21]	validation_0-rmse:0.46866	validation_1-rmse:0.65610
# [22]	validation_0-rmse:0.44360	validation_1-rmse:0.63210
# [23]	validation_0-rmse:0.42041	validation_1-rmse:0.61381
# [24]	validation_0-rmse:0.39826	validation_1-rmse:0.58888
# [25]	validation_0-rmse:0.37904	validation_1-rmse:0.57129
# [26]	validation_0-rmse:0.36125	validation_1-rmse:0.55341
# [27]	validation_0-rmse:0.34262	validation_1-rmse:0.53395
# [28]	validation_0-rmse:0.32812	validation_1-rmse:0.51967
# [29]	validation_0-rmse:0.31393	validation_1-rmse:0.50366
# [30]	validation_0-rmse:0.30105	validation_1-rmse:0.49064
# [31]	validation_0-rmse:0.28961	validation_1-rmse:0.48520
# [32]	validation_0-rmse:0.27981	validation_1-rmse:0.47352
# [33]	validation_0-rmse:0.27061	validation_1-rmse:0.46253
# [34]	validation_0-rmse:0.26141	validation_1-rmse:0.45635
# [35]	validation_0-rmse:0.25382	validation_1-rmse:0.45030
# [36]	validation_0-rmse:0.24589	validation_1-rmse:0.44596
# [37]	validation_0-rmse:0.23927	validation_1-rmse:0.43988
# [38]	validation_0-rmse:0.23343	validation_1-rmse:0.43434
# [39]	validation_0-rmse:0.22810	validation_1-rmse:0.42794
# [40]	validation_0-rmse:0.22389	validation_1-rmse:0.42412
# [41]	validation_0-rmse:0.21994	validation_1-rmse:0.42082
# [42]	validation_0-rmse:0.21515	validation_1-rmse:0.41595
# [43]	validation_0-rmse:0.21041	validation_1-rmse:0.40954
# [44]	validation_0-rmse:0.20768	validation_1-rmse:0.40716
# [45]	validation_0-rmse:0.20497	validation_1-rmse:0.40558
# [46]	validation_0-rmse:0.20283	validation_1-rmse:0.40283
# [47]	validation_0-rmse:0.20071	validation_1-rmse:0.39936
# [48]	validation_0-rmse:0.19881	validation_1-rmse:0.39760
# [49]	validation_0-rmse:0.19702	validation_1-rmse:0.39514
# [50]	validation_0-rmse:0.19484	validation_1-rmse:0.39096
# [51]	validation_0-rmse:0.19347	validation_1-rmse:0.39036
# [52]	validation_0-rmse:0.19284	validation_1-rmse:0.38960
# [53]	validation_0-rmse:0.19168	validation_1-rmse:0.38916
# [54]	validation_0-rmse:0.19056	validation_1-rmse:0.38718
# [55]	validation_0-rmse:0.18949	validation_1-rmse:0.38521
# [56]	validation_0-rmse:0.18863	validation_1-rmse:0.38492
# [57]	validation_0-rmse:0.18836	validation_1-rmse:0.38449
# [58]	validation_0-rmse:0.18813	validation_1-rmse:0.38411
# [59]	validation_0-rmse:0.18728	validation_1-rmse:0.38204
# [60]	validation_0-rmse:0.18637	validation_1-rmse:0.37993
# [61]	validation_0-rmse:0.18618	validation_1-rmse:0.37955
# [62]	validation_0-rmse:0.18604	validation_1-rmse:0.37927
# [63]	validation_0-rmse:0.18596	validation_1-rmse:0.37910
# [64]	validation_0-rmse:0.18586	validation_1-rmse:0.37887
# [65]	validation_0-rmse:0.18575	validation_1-rmse:0.37859
# [66]	validation_0-rmse:0.18568	validation_1-rmse:0.37841
# [67]	validation_0-rmse:0.18561	validation_1-rmse:0.37824
# [68]	validation_0-rmse:0.18555	validation_1-rmse:0.37804
# [69]	validation_0-rmse:0.18550	validation_1-rmse:0.37789
# [70]	validation_0-rmse:0.18546	validation_1-rmse:0.37776
# [71]	validation_0-rmse:0.18543	validation_1-rmse:0.37767
# [72]	validation_0-rmse:0.18541	validation_1-rmse:0.37757
# [73]	validation_0-rmse:0.18539	validation_1-rmse:0.37750
# [74]	validation_0-rmse:0.18537	validation_1-rmse:0.37742
# [75]	validation_0-rmse:0.18535	validation_1-rmse:0.37733
# [76]	validation_0-rmse:0.18535	validation_1-rmse:0.37734
# [77]	validation_0-rmse:0.18533	validation_1-rmse:0.37726
# [78]	validation_0-rmse:0.18530	validation_1-rmse:0.37713
# [79]	validation_0-rmse:0.18529	validation_1-rmse:0.37707
# [80]	validation_0-rmse:0.18528	validation_1-rmse:0.37699
# [81]	validation_0-rmse:0.18527	validation_1-rmse:0.37693
# [82]	validation_0-rmse:0.18525	validation_1-rmse:0.37683
# [83]	validation_0-rmse:0.18525	validation_1-rmse:0.37683
# [84]	validation_0-rmse:0.18525	validation_1-rmse:0.37684
# [85]	validation_0-rmse:0.18524	validation_1-rmse:0.37678
# [86]	validation_0-rmse:0.18464	validation_1-rmse:0.37619
# [87]	validation_0-rmse:0.18464	validation_1-rmse:0.37620
# [88]	validation_0-rmse:0.18463	validation_1-rmse:0.37606
# [89]	validation_0-rmse:0.18462	validation_1-rmse:0.37602
# [90]	validation_0-rmse:0.18462	validation_1-rmse:0.37598
# [91]	validation_0-rmse:0.18296	validation_1-rmse:0.37516
# [92]	validation_0-rmse:0.18296	validation_1-rmse:0.37513
# [93]	validation_0-rmse:0.18296	validation_1-rmse:0.37508
# [94]	validation_0-rmse:0.18295	validation_1-rmse:0.37506
# [95]	validation_0-rmse:0.18296	validation_1-rmse:0.37508
# [96]	validation_0-rmse:0.18296	validation_1-rmse:0.37511
# [0]	validation_0-rmse:1.83457	validation_1-rmse:1.65084
# [1]	validation_0-rmse:1.71556	validation_1-rmse:1.55010
# [2]	validation_0-rmse:1.60421	validation_1-rmse:1.45245
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:1.49968	validation_1-rmse:1.36470
# [4]	validation_0-rmse:1.40334	validation_1-rmse:1.27925
# [5]	validation_0-rmse:1.31329	validation_1-rmse:1.20208
# [6]	validation_0-rmse:1.22907	validation_1-rmse:1.13190
# [7]	validation_0-rmse:1.15133	validation_1-rmse:1.06384
# [8]	validation_0-rmse:1.07940	validation_1-rmse:1.00544
# [9]	validation_0-rmse:1.01191	validation_1-rmse:0.94428
# [10]	validation_0-rmse:0.94927	validation_1-rmse:0.89071
# [11]	validation_0-rmse:0.88976	validation_1-rmse:0.84195
# [12]	validation_0-rmse:0.83474	validation_1-rmse:0.79213
# [13]	validation_0-rmse:0.78469	validation_1-rmse:0.75266
# [14]	validation_0-rmse:0.73673	validation_1-rmse:0.71426
# [15]	validation_0-rmse:0.69255	validation_1-rmse:0.67672
# [16]	validation_0-rmse:0.65108	validation_1-rmse:0.64163
# [17]	validation_0-rmse:0.61250	validation_1-rmse:0.60858
# [18]	validation_0-rmse:0.57653	validation_1-rmse:0.58075
# [19]	validation_0-rmse:0.54284	validation_1-rmse:0.55313
# [20]	validation_0-rmse:0.51237	validation_1-rmse:0.52841
# [21]	validation_0-rmse:0.48414	validation_1-rmse:0.50523
# [22]	validation_0-rmse:0.45741	validation_1-rmse:0.48726
# [23]	validation_0-rmse:0.43283	validation_1-rmse:0.46853
# [24]	validation_0-rmse:0.40928	validation_1-rmse:0.45282
# [25]	validation_0-rmse:0.38848	validation_1-rmse:0.43808
# [26]	validation_0-rmse:0.36930	validation_1-rmse:0.42475
# [27]	validation_0-rmse:0.35034	validation_1-rmse:0.41180
# [28]	validation_0-rmse:0.33424	validation_1-rmse:0.40213
# [29]	validation_0-rmse:0.31901	validation_1-rmse:0.39239
# [30]	validation_0-rmse:0.30645	validation_1-rmse:0.38510
# [31]	validation_0-rmse:0.29432	validation_1-rmse:0.37826
# [32]	validation_0-rmse:0.28280	validation_1-rmse:0.37198
# [33]	validation_0-rmse:0.27277	validation_1-rmse:0.36726
# [34]	validation_0-rmse:0.26235	validation_1-rmse:0.36247
# [35]	validation_0-rmse:0.25282	validation_1-rmse:0.35724
# [36]	validation_0-rmse:0.24517	validation_1-rmse:0.35193
# [37]	validation_0-rmse:0.23831	validation_1-rmse:0.34778
# [38]	validation_0-rmse:0.23143	validation_1-rmse:0.34464
# [39]	validation_0-rmse:0.22599	validation_1-rmse:0.34167
# [40]	validation_0-rmse:0.21987	validation_1-rmse:0.33897
# [41]	validation_0-rmse:0.21548	validation_1-rmse:0.33684
# [42]	validation_0-rmse:0.21093	validation_1-rmse:0.33517
# [43]	validation_0-rmse:0.20671	validation_1-rmse:0.33447
# [44]	validation_0-rmse:0.20374	validation_1-rmse:0.33299
# [45]	validation_0-rmse:0.20073	validation_1-rmse:0.33174
# [46]	validation_0-rmse:0.19755	validation_1-rmse:0.33072
# [47]	validation_0-rmse:0.19527	validation_1-rmse:0.32992
# [48]	validation_0-rmse:0.19339	validation_1-rmse:0.32911
# [49]	validation_0-rmse:0.19138	validation_1-rmse:0.32883
# [50]	validation_0-rmse:0.18968	validation_1-rmse:0.32748
# [51]	validation_0-rmse:0.18802	validation_1-rmse:0.32611
# [52]	validation_0-rmse:0.18660	validation_1-rmse:0.32592
# [53]	validation_0-rmse:0.18524	validation_1-rmse:0.32569
# [54]	validation_0-rmse:0.18473	validation_1-rmse:0.32486
# [55]	validation_0-rmse:0.18431	validation_1-rmse:0.32413
# [56]	validation_0-rmse:0.18393	validation_1-rmse:0.32345
# [57]	validation_0-rmse:0.18279	validation_1-rmse:0.32260
# [58]	validation_0-rmse:0.18176	validation_1-rmse:0.32236
# [59]	validation_0-rmse:0.18152	validation_1-rmse:0.32186
# [60]	validation_0-rmse:0.18057	validation_1-rmse:0.32114
# [61]	validation_0-rmse:0.18037	validation_1-rmse:0.32069
# [62]	validation_0-rmse:0.18025	validation_1-rmse:0.32038
# [63]	validation_0-rmse:0.18009	validation_1-rmse:0.32000
# [64]	validation_0-rmse:0.17996	validation_1-rmse:0.31965
# [65]	validation_0-rmse:0.17985	validation_1-rmse:0.31933
# [66]	validation_0-rmse:0.17972	validation_1-rmse:0.31894
# [67]	validation_0-rmse:0.17894	validation_1-rmse:0.31856
# [68]	validation_0-rmse:0.17885	validation_1-rmse:0.31825
# [69]	validation_0-rmse:0.17814	validation_1-rmse:0.31876
# [70]	validation_0-rmse:0.17808	validation_1-rmse:0.31854
# [71]	validation_0-rmse:0.17801	validation_1-rmse:0.31824
# [72]	validation_0-rmse:0.17797	validation_1-rmse:0.31804
# [73]	validation_0-rmse:0.17793	validation_1-rmse:0.31785
# [74]	validation_0-rmse:0.17791	validation_1-rmse:0.31774
# [75]	validation_0-rmse:0.17789	validation_1-rmse:0.31762
# [76]	validation_0-rmse:0.17723	validation_1-rmse:0.31759
# [77]	validation_0-rmse:0.17721	validation_1-rmse:0.31751
# [78]	validation_0-rmse:0.17719	validation_1-rmse:0.31737
# [79]	validation_0-rmse:0.17717	validation_1-rmse:0.31723
# [80]	validation_0-rmse:0.17715	validation_1-rmse:0.31709
# [81]	validation_0-rmse:0.17714	validation_1-rmse:0.31700
# [82]	validation_0-rmse:0.17712	validation_1-rmse:0.31690
# [83]	validation_0-rmse:0.17712	validation_1-rmse:0.31686
# [84]	validation_0-rmse:0.17712	validation_1-rmse:0.31682
# [85]	validation_0-rmse:0.17710	validation_1-rmse:0.31670
# [86]	validation_0-rmse:0.17578	validation_1-rmse:0.31789
# [87]	validation_0-rmse:0.17578	validation_1-rmse:0.31789
# [88]	validation_0-rmse:0.17577	validation_1-rmse:0.31779
# [89]	validation_0-rmse:0.17577	validation_1-rmse:0.31778
# [90]	validation_0-rmse:0.17577	validation_1-rmse:0.31779
# [91]	validation_0-rmse:0.17576	validation_1-rmse:0.31768
# [92]	validation_0-rmse:0.17576	validation_1-rmse:0.31766
# [93]	validation_0-rmse:0.17575	validation_1-rmse:0.31757
# [94]	validation_0-rmse:0.17575	validation_1-rmse:0.31751
# [95]	validation_0-rmse:0.17508	validation_1-rmse:0.31803
# [96]	validation_0-rmse:0.17507	validation_1-rmse:0.31795
# [0]	validation_0-rmse:1.84114	validation_1-rmse:1.60592
# [1]	validation_0-rmse:1.71947	validation_1-rmse:1.49724
# [2]	validation_0-rmse:1.60782	validation_1-rmse:1.39251
# [3]	validation_0-rmse:1.50217	validation_1-rmse:1.29775
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.40546	validation_1-rmse:1.20728
# [5]	validation_0-rmse:1.31451	validation_1-rmse:1.12693
# [6]	validation_0-rmse:1.22949	validation_1-rmse:1.05147
# [7]	validation_0-rmse:1.15210	validation_1-rmse:0.98198
# [8]	validation_0-rmse:1.07917	validation_1-rmse:0.91313
# [9]	validation_0-rmse:1.01150	validation_1-rmse:0.85310
# [10]	validation_0-rmse:0.94843	validation_1-rmse:0.79861
# [11]	validation_0-rmse:0.89016	validation_1-rmse:0.74735
# [12]	validation_0-rmse:0.83481	validation_1-rmse:0.69825
# [13]	validation_0-rmse:0.78514	validation_1-rmse:0.65624
# [14]	validation_0-rmse:0.73778	validation_1-rmse:0.61736
# [15]	validation_0-rmse:0.69294	validation_1-rmse:0.58093
# [16]	validation_0-rmse:0.65119	validation_1-rmse:0.54612
# [17]	validation_0-rmse:0.61374	validation_1-rmse:0.51634
# [18]	validation_0-rmse:0.57769	validation_1-rmse:0.48633
# [19]	validation_0-rmse:0.54429	validation_1-rmse:0.45936
# [20]	validation_0-rmse:0.51428	validation_1-rmse:0.43504
# [21]	validation_0-rmse:0.48590	validation_1-rmse:0.41574
# [22]	validation_0-rmse:0.46031	validation_1-rmse:0.39622
# [23]	validation_0-rmse:0.43613	validation_1-rmse:0.37748
# [24]	validation_0-rmse:0.41284	validation_1-rmse:0.35986
# [25]	validation_0-rmse:0.39112	validation_1-rmse:0.34509
# [26]	validation_0-rmse:0.37227	validation_1-rmse:0.33179
# [27]	validation_0-rmse:0.35368	validation_1-rmse:0.31992
# [28]	validation_0-rmse:0.33762	validation_1-rmse:0.30817
# [29]	validation_0-rmse:0.32294	validation_1-rmse:0.30030
# [30]	validation_0-rmse:0.30962	validation_1-rmse:0.29079
# [31]	validation_0-rmse:0.29825	validation_1-rmse:0.28445
# [32]	validation_0-rmse:0.28716	validation_1-rmse:0.27865
# [33]	validation_0-rmse:0.27656	validation_1-rmse:0.27178
# [34]	validation_0-rmse:0.26766	validation_1-rmse:0.26715
# [35]	validation_0-rmse:0.25888	validation_1-rmse:0.26346
# [36]	validation_0-rmse:0.25126	validation_1-rmse:0.25782
# [37]	validation_0-rmse:0.24494	validation_1-rmse:0.25462
# [38]	validation_0-rmse:0.23849	validation_1-rmse:0.25217
# [39]	validation_0-rmse:0.23175	validation_1-rmse:0.24782
# [40]	validation_0-rmse:0.22624	validation_1-rmse:0.24481
# [41]	validation_0-rmse:0.22209	validation_1-rmse:0.24315
# [42]	validation_0-rmse:0.21765	validation_1-rmse:0.24297
# [43]	validation_0-rmse:0.21428	validation_1-rmse:0.24129
# [44]	validation_0-rmse:0.21060	validation_1-rmse:0.24144
# [45]	validation_0-rmse:0.20782	validation_1-rmse:0.24198
# [46]	validation_0-rmse:0.20531	validation_1-rmse:0.24094
# [47]	validation_0-rmse:0.20297	validation_1-rmse:0.23993
# [48]	validation_0-rmse:0.20097	validation_1-rmse:0.23926
# [49]	validation_0-rmse:0.19916	validation_1-rmse:0.23829
# [50]	validation_0-rmse:0.19748	validation_1-rmse:0.23747
# [51]	validation_0-rmse:0.19585	validation_1-rmse:0.23834
# [52]	validation_0-rmse:0.19457	validation_1-rmse:0.23861
# [53]	validation_0-rmse:0.19327	validation_1-rmse:0.23814
# [54]	validation_0-rmse:0.19276	validation_1-rmse:0.23861
# [55]	validation_0-rmse:0.19230	validation_1-rmse:0.23910
# [56]	validation_0-rmse:0.19132	validation_1-rmse:0.23926
# [57]	validation_0-rmse:0.19099	validation_1-rmse:0.23968
# [58]	validation_0-rmse:0.19000	validation_1-rmse:0.23928
# [59]	validation_0-rmse:0.18921	validation_1-rmse:0.23790
# [60]	validation_0-rmse:0.18897	validation_1-rmse:0.23830
# [61]	validation_0-rmse:0.18875	validation_1-rmse:0.23871
# [62]	validation_0-rmse:0.18801	validation_1-rmse:0.23829
# [63]	validation_0-rmse:0.18781	validation_1-rmse:0.23870
# [64]	validation_0-rmse:0.18768	validation_1-rmse:0.23903
# [65]	validation_0-rmse:0.18754	validation_1-rmse:0.23939
# [66]	validation_0-rmse:0.18747	validation_1-rmse:0.23960
# [67]	validation_0-rmse:0.18735	validation_1-rmse:0.23998
# [68]	validation_0-rmse:0.18652	validation_1-rmse:0.24041
# [69]	validation_0-rmse:0.18649	validation_1-rmse:0.24050
# [0]	validation_0-rmse:1.83406	validation_1-rmse:1.64640
# [1]	validation_0-rmse:1.71383	validation_1-rmse:1.53662
# [2]	validation_0-rmse:1.60235	validation_1-rmse:1.43791
# [3]	validation_0-rmse:1.49774	validation_1-rmse:1.34393
# [4]	validation_0-rmse:1.40101	validation_1-rmse:1.25898
# [5]	validation_0-rmse:1.30970	validation_1-rmse:1.17716
# [6]	validation_0-rmse:1.22539	validation_1-rmse:1.10209
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [7]	validation_0-rmse:1.14774	validation_1-rmse:1.03187
# [8]	validation_0-rmse:1.07507	validation_1-rmse:0.97208
# [9]	validation_0-rmse:1.00742	validation_1-rmse:0.91322
# [10]	validation_0-rmse:0.94452	validation_1-rmse:0.86258
# [11]	validation_0-rmse:0.88386	validation_1-rmse:0.81103
# [12]	validation_0-rmse:0.82884	validation_1-rmse:0.76522
# [13]	validation_0-rmse:0.77756	validation_1-rmse:0.72459
# [14]	validation_0-rmse:0.73035	validation_1-rmse:0.68665
# [15]	validation_0-rmse:0.68617	validation_1-rmse:0.65108
# [16]	validation_0-rmse:0.64473	validation_1-rmse:0.61801
# [17]	validation_0-rmse:0.60674	validation_1-rmse:0.58889
# [18]	validation_0-rmse:0.57156	validation_1-rmse:0.56487
# [19]	validation_0-rmse:0.53832	validation_1-rmse:0.54108
# [20]	validation_0-rmse:0.50798	validation_1-rmse:0.52073
# [21]	validation_0-rmse:0.48042	validation_1-rmse:0.50074
# [22]	validation_0-rmse:0.45477	validation_1-rmse:0.48344
# [23]	validation_0-rmse:0.43058	validation_1-rmse:0.46978
# [24]	validation_0-rmse:0.40747	validation_1-rmse:0.45615
# [25]	validation_0-rmse:0.38601	validation_1-rmse:0.44480
# [26]	validation_0-rmse:0.36687	validation_1-rmse:0.43232
# [27]	validation_0-rmse:0.34928	validation_1-rmse:0.42231
# [28]	validation_0-rmse:0.33338	validation_1-rmse:0.41484
# [29]	validation_0-rmse:0.31862	validation_1-rmse:0.40761
# [30]	validation_0-rmse:0.30604	validation_1-rmse:0.40000
# [31]	validation_0-rmse:0.29328	validation_1-rmse:0.39205
# [32]	validation_0-rmse:0.28140	validation_1-rmse:0.38884
# [33]	validation_0-rmse:0.27130	validation_1-rmse:0.38382
# [34]	validation_0-rmse:0.26220	validation_1-rmse:0.37929
# [35]	validation_0-rmse:0.25356	validation_1-rmse:0.37697
# [36]	validation_0-rmse:0.24612	validation_1-rmse:0.37257
# [37]	validation_0-rmse:0.23912	validation_1-rmse:0.37264
# [38]	validation_0-rmse:0.23329	validation_1-rmse:0.37152
# [39]	validation_0-rmse:0.22825	validation_1-rmse:0.36909
# [40]	validation_0-rmse:0.22366	validation_1-rmse:0.36676
# [41]	validation_0-rmse:0.21924	validation_1-rmse:0.36629
# [42]	validation_0-rmse:0.21548	validation_1-rmse:0.36534
# [43]	validation_0-rmse:0.21119	validation_1-rmse:0.36657
# [44]	validation_0-rmse:0.20711	validation_1-rmse:0.36373
# [45]	validation_0-rmse:0.20424	validation_1-rmse:0.36261
# [46]	validation_0-rmse:0.20172	validation_1-rmse:0.36137
# [47]	validation_0-rmse:0.19866	validation_1-rmse:0.36084
# [48]	validation_0-rmse:0.19673	validation_1-rmse:0.36028
# [49]	validation_0-rmse:0.19390	validation_1-rmse:0.35958
# [50]	validation_0-rmse:0.19204	validation_1-rmse:0.35888
# [51]	validation_0-rmse:0.19036	validation_1-rmse:0.35849
# [52]	validation_0-rmse:0.18966	validation_1-rmse:0.35824
# [53]	validation_0-rmse:0.18909	validation_1-rmse:0.35805
# [54]	validation_0-rmse:0.18785	validation_1-rmse:0.35771
# [55]	validation_0-rmse:0.18737	validation_1-rmse:0.35755
# [56]	validation_0-rmse:0.18624	validation_1-rmse:0.35735
# [57]	validation_0-rmse:0.18515	validation_1-rmse:0.35731
# [58]	validation_0-rmse:0.18423	validation_1-rmse:0.35719
# [59]	validation_0-rmse:0.18397	validation_1-rmse:0.35713
# [60]	validation_0-rmse:0.18302	validation_1-rmse:0.35656
# [61]	validation_0-rmse:0.18278	validation_1-rmse:0.35651
# [62]	validation_0-rmse:0.18262	validation_1-rmse:0.35648
# [63]	validation_0-rmse:0.18245	validation_1-rmse:0.35645
# [64]	validation_0-rmse:0.18231	validation_1-rmse:0.35643
# [65]	validation_0-rmse:0.18221	validation_1-rmse:0.35642
# [66]	validation_0-rmse:0.18211	validation_1-rmse:0.35641
# [67]	validation_0-rmse:0.18201	validation_1-rmse:0.35640
# [68]	validation_0-rmse:0.18191	validation_1-rmse:0.35640
# [69]	validation_0-rmse:0.18185	validation_1-rmse:0.35640
# [70]	validation_0-rmse:0.18179	validation_1-rmse:0.35640
# [71]	validation_0-rmse:0.18172	validation_1-rmse:0.35640
# [72]	validation_0-rmse:0.18168	validation_1-rmse:0.35641
# [73]	validation_0-rmse:0.18165	validation_1-rmse:0.35642
# [74]	validation_0-rmse:0.18161	validation_1-rmse:0.35642
# [75]	validation_0-rmse:0.18095	validation_1-rmse:0.35584
# [76]	validation_0-rmse:0.18092	validation_1-rmse:0.35585
# [77]	validation_0-rmse:0.18089	validation_1-rmse:0.35585
# [78]	validation_0-rmse:0.18086	validation_1-rmse:0.35587
# [79]	validation_0-rmse:0.18084	validation_1-rmse:0.35588
# [80]	validation_0-rmse:0.18084	validation_1-rmse:0.35588
# [81]	validation_0-rmse:0.18082	validation_1-rmse:0.35589
# [82]	validation_0-rmse:0.18081	validation_1-rmse:0.35590
# [83]	validation_0-rmse:0.18080	validation_1-rmse:0.35591
# [84]	validation_0-rmse:0.18079	validation_1-rmse:0.35592
# [85]	validation_0-rmse:0.18079	validation_1-rmse:0.35592
# [86]	validation_0-rmse:0.18078	validation_1-rmse:0.35593
# [87]	validation_0-rmse:0.18077	validation_1-rmse:0.35593
# [88]	validation_0-rmse:0.18077	validation_1-rmse:0.35594
# [89]	validation_0-rmse:0.18077	validation_1-rmse:0.35594
# [90]	validation_0-rmse:0.18076	validation_1-rmse:0.35595
# [91]	validation_0-rmse:0.18076	validation_1-rmse:0.35596
# [92]	validation_0-rmse:0.18076	validation_1-rmse:0.35597
# [93]	validation_0-rmse:0.18075	validation_1-rmse:0.35597
# [94]	validation_0-rmse:0.18075	validation_1-rmse:0.35597
# [95]	validation_0-rmse:0.18075	validation_1-rmse:0.35597
# [0]	validation_0-rmse:1.85625	validation_1-rmse:1.55031
# [1]	validation_0-rmse:1.73460	validation_1-rmse:1.45348
# [2]	validation_0-rmse:1.62230	validation_1-rmse:1.35728
# [3]	validation_0-rmse:1.51624	validation_1-rmse:1.27067
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.41883	validation_1-rmse:1.19335
# [5]	validation_0-rmse:1.32708	validation_1-rmse:1.11677
# [6]	validation_0-rmse:1.24187	validation_1-rmse:1.04559
# [7]	validation_0-rmse:1.16286	validation_1-rmse:0.97813
# [8]	validation_0-rmse:1.08983	validation_1-rmse:0.92176
# [9]	validation_0-rmse:1.01997	validation_1-rmse:0.86844
# [10]	validation_0-rmse:0.95656	validation_1-rmse:0.81269
# [11]	validation_0-rmse:0.89734	validation_1-rmse:0.76553
# [12]	validation_0-rmse:0.84139	validation_1-rmse:0.72304
# [13]	validation_0-rmse:0.79016	validation_1-rmse:0.68230
# [14]	validation_0-rmse:0.74243	validation_1-rmse:0.64552
# [15]	validation_0-rmse:0.69705	validation_1-rmse:0.60631
# [16]	validation_0-rmse:0.65543	validation_1-rmse:0.57491
# [17]	validation_0-rmse:0.61715	validation_1-rmse:0.54541
# [18]	validation_0-rmse:0.58127	validation_1-rmse:0.51829
# [19]	validation_0-rmse:0.54720	validation_1-rmse:0.49203
# [20]	validation_0-rmse:0.51641	validation_1-rmse:0.46914
# [21]	validation_0-rmse:0.48765	validation_1-rmse:0.44764
# [22]	validation_0-rmse:0.46159	validation_1-rmse:0.42857
# [23]	validation_0-rmse:0.43772	validation_1-rmse:0.41433
# [24]	validation_0-rmse:0.41455	validation_1-rmse:0.39698
# [25]	validation_0-rmse:0.39276	validation_1-rmse:0.38024
# [26]	validation_0-rmse:0.37295	validation_1-rmse:0.36423
# [27]	validation_0-rmse:0.35518	validation_1-rmse:0.35406
# [28]	validation_0-rmse:0.33840	validation_1-rmse:0.34439
# [29]	validation_0-rmse:0.32288	validation_1-rmse:0.33460
# [30]	validation_0-rmse:0.30980	validation_1-rmse:0.32763
# [31]	validation_0-rmse:0.29692	validation_1-rmse:0.32135
# [32]	validation_0-rmse:0.28655	validation_1-rmse:0.31231
# [33]	validation_0-rmse:0.27623	validation_1-rmse:0.30453
# [34]	validation_0-rmse:0.26605	validation_1-rmse:0.30000
# [35]	validation_0-rmse:0.25719	validation_1-rmse:0.29373
# [36]	validation_0-rmse:0.24888	validation_1-rmse:0.29094
# [37]	validation_0-rmse:0.24094	validation_1-rmse:0.28598
# [38]	validation_0-rmse:0.23446	validation_1-rmse:0.28125
# [39]	validation_0-rmse:0.22799	validation_1-rmse:0.27935
# [40]	validation_0-rmse:0.22352	validation_1-rmse:0.27877
# [41]	validation_0-rmse:0.21886	validation_1-rmse:0.27619
# [42]	validation_0-rmse:0.21522	validation_1-rmse:0.27385
# [43]	validation_0-rmse:0.21069	validation_1-rmse:0.27245
# [44]	validation_0-rmse:0.20781	validation_1-rmse:0.27071
# [45]	validation_0-rmse:0.20506	validation_1-rmse:0.26987
# [46]	validation_0-rmse:0.20268	validation_1-rmse:0.26980
# [47]	validation_0-rmse:0.19975	validation_1-rmse:0.26868
# [48]	validation_0-rmse:0.19779	validation_1-rmse:0.26678
# [49]	validation_0-rmse:0.19572	validation_1-rmse:0.26690
# [50]	validation_0-rmse:0.19405	validation_1-rmse:0.26537
# [51]	validation_0-rmse:0.19168	validation_1-rmse:0.26422
# [52]	validation_0-rmse:0.19109	validation_1-rmse:0.26410
# [53]	validation_0-rmse:0.18973	validation_1-rmse:0.26259
# [54]	validation_0-rmse:0.18852	validation_1-rmse:0.26223
# [55]	validation_0-rmse:0.18807	validation_1-rmse:0.26219
# [56]	validation_0-rmse:0.18766	validation_1-rmse:0.26217
# [57]	validation_0-rmse:0.18740	validation_1-rmse:0.26217
# [58]	validation_0-rmse:0.18703	validation_1-rmse:0.26219
# [59]	validation_0-rmse:0.18623	validation_1-rmse:0.26127
# [60]	validation_0-rmse:0.18520	validation_1-rmse:0.26105
# [61]	validation_0-rmse:0.18431	validation_1-rmse:0.26086
# [62]	validation_0-rmse:0.18416	validation_1-rmse:0.26089
# [63]	validation_0-rmse:0.18244	validation_1-rmse:0.26054
# [64]	validation_0-rmse:0.18231	validation_1-rmse:0.26059
# [65]	validation_0-rmse:0.18218	validation_1-rmse:0.26065
# [66]	validation_0-rmse:0.18210	validation_1-rmse:0.26069
# [67]	validation_0-rmse:0.18135	validation_1-rmse:0.26057
# [68]	validation_0-rmse:0.18128	validation_1-rmse:0.26062
# [69]	validation_0-rmse:0.18119	validation_1-rmse:0.26069
# [70]	validation_0-rmse:0.18114	validation_1-rmse:0.26074
# [71]	validation_0-rmse:0.18109	validation_1-rmse:0.26079
# [72]	validation_0-rmse:0.18105	validation_1-rmse:0.26083
# [73]	validation_0-rmse:0.18102	validation_1-rmse:0.26088
# [74]	validation_0-rmse:0.18100	validation_1-rmse:0.26091
# [75]	validation_0-rmse:0.18098	validation_1-rmse:0.26094
# [76]	validation_0-rmse:0.18095	validation_1-rmse:0.26098
# [77]	validation_0-rmse:0.18041	validation_1-rmse:0.26021
# [78]	validation_0-rmse:0.18038	validation_1-rmse:0.26027
# [79]	validation_0-rmse:0.18038	validation_1-rmse:0.26028
# [80]	validation_0-rmse:0.18038	validation_1-rmse:0.26028
# [81]	validation_0-rmse:0.18036	validation_1-rmse:0.26031
# [82]	validation_0-rmse:0.18035	validation_1-rmse:0.26035
# [83]	validation_0-rmse:0.18033	validation_1-rmse:0.26040
# [84]	validation_0-rmse:0.18032	validation_1-rmse:0.26043
# [85]	validation_0-rmse:0.18030	validation_1-rmse:0.26050
# [86]	validation_0-rmse:0.18029	validation_1-rmse:0.26055
# [87]	validation_0-rmse:0.18029	validation_1-rmse:0.26056
# [88]	validation_0-rmse:0.18027	validation_1-rmse:0.26064
# [89]	validation_0-rmse:0.18027	validation_1-rmse:0.26065
# [90]	validation_0-rmse:0.18027	validation_1-rmse:0.26067
# [91]	validation_0-rmse:0.18027	validation_1-rmse:0.26068
# [92]	validation_0-rmse:0.18027	validation_1-rmse:0.26070
# [93]	validation_0-rmse:0.18026	validation_1-rmse:0.26074
# [94]	validation_0-rmse:0.18026	validation_1-rmse:0.26077
# [95]	validation_0-rmse:0.18026	validation_1-rmse:0.26078
# [96]	validation_0-rmse:0.18026	validation_1-rmse:0.26078
# [0]	validation_0-rmse:1.74423	validation_1-rmse:1.99865
# [1]	validation_0-rmse:1.63044	validation_1-rmse:1.87418
# [2]	validation_0-rmse:1.52515	validation_1-rmse:1.75740
# [3]	validation_0-rmse:1.42656	validation_1-rmse:1.64930
# [4]	validation_0-rmse:1.33563	validation_1-rmse:1.54501
# [5]	validation_0-rmse:1.24977	validation_1-rmse:1.45095
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:1.17006	validation_1-rmse:1.36292
# [7]	validation_0-rmse:1.09595	validation_1-rmse:1.27926
# [8]	validation_0-rmse:1.02764	validation_1-rmse:1.20230
# [9]	validation_0-rmse:0.96349	validation_1-rmse:1.13280
# [10]	validation_0-rmse:0.90434	validation_1-rmse:1.06577
# [11]	validation_0-rmse:0.84863	validation_1-rmse:1.00649
# [12]	validation_0-rmse:0.79658	validation_1-rmse:0.94885
# [13]	validation_0-rmse:0.74951	validation_1-rmse:0.90099
# [14]	validation_0-rmse:0.70463	validation_1-rmse:0.85205
# [15]	validation_0-rmse:0.66345	validation_1-rmse:0.80468
# [16]	validation_0-rmse:0.62491	validation_1-rmse:0.76394
# [17]	validation_0-rmse:0.58850	validation_1-rmse:0.72452
# [18]	validation_0-rmse:0.55633	validation_1-rmse:0.69001
# [19]	validation_0-rmse:0.52499	validation_1-rmse:0.65444
# [20]	validation_0-rmse:0.49616	validation_1-rmse:0.62135
# [21]	validation_0-rmse:0.46896	validation_1-rmse:0.59105
# [22]	validation_0-rmse:0.44506	validation_1-rmse:0.56263
# [23]	validation_0-rmse:0.42255	validation_1-rmse:0.53756
# [24]	validation_0-rmse:0.40109	validation_1-rmse:0.51417
# [25]	validation_0-rmse:0.38118	validation_1-rmse:0.49373
# [26]	validation_0-rmse:0.36246	validation_1-rmse:0.47208
# [27]	validation_0-rmse:0.34631	validation_1-rmse:0.45176
# [28]	validation_0-rmse:0.33097	validation_1-rmse:0.43116
# [29]	validation_0-rmse:0.31508	validation_1-rmse:0.41640
# [30]	validation_0-rmse:0.30243	validation_1-rmse:0.39896
# [31]	validation_0-rmse:0.29058	validation_1-rmse:0.38358
# [32]	validation_0-rmse:0.27926	validation_1-rmse:0.37185
# [33]	validation_0-rmse:0.26980	validation_1-rmse:0.36208
# [34]	validation_0-rmse:0.26134	validation_1-rmse:0.34956
# [35]	validation_0-rmse:0.25302	validation_1-rmse:0.34028
# [36]	validation_0-rmse:0.24573	validation_1-rmse:0.32961
# [37]	validation_0-rmse:0.23935	validation_1-rmse:0.32245
# [38]	validation_0-rmse:0.23336	validation_1-rmse:0.31615
# [39]	validation_0-rmse:0.22717	validation_1-rmse:0.31010
# [40]	validation_0-rmse:0.22301	validation_1-rmse:0.30590
# [41]	validation_0-rmse:0.21899	validation_1-rmse:0.30066
# [42]	validation_0-rmse:0.21516	validation_1-rmse:0.29650
# [43]	validation_0-rmse:0.21175	validation_1-rmse:0.29273
# [44]	validation_0-rmse:0.20906	validation_1-rmse:0.28874
# [45]	validation_0-rmse:0.20582	validation_1-rmse:0.28434
# [46]	validation_0-rmse:0.20284	validation_1-rmse:0.27889
# [47]	validation_0-rmse:0.20008	validation_1-rmse:0.27496
# [48]	validation_0-rmse:0.19833	validation_1-rmse:0.27318
# [49]	validation_0-rmse:0.19681	validation_1-rmse:0.27074
# [50]	validation_0-rmse:0.19523	validation_1-rmse:0.26816
# [51]	validation_0-rmse:0.19444	validation_1-rmse:0.26591
# [52]	validation_0-rmse:0.19310	validation_1-rmse:0.26347
# [53]	validation_0-rmse:0.19271	validation_1-rmse:0.26222
# [54]	validation_0-rmse:0.19170	validation_1-rmse:0.26036
# [55]	validation_0-rmse:0.19075	validation_1-rmse:0.25834
# [56]	validation_0-rmse:0.19048	validation_1-rmse:0.25732
# [57]	validation_0-rmse:0.18935	validation_1-rmse:0.25483
# [58]	validation_0-rmse:0.18850	validation_1-rmse:0.25339
# [59]	validation_0-rmse:0.18770	validation_1-rmse:0.25124
# [60]	validation_0-rmse:0.18755	validation_1-rmse:0.25053
# [61]	validation_0-rmse:0.18677	validation_1-rmse:0.24845
# [62]	validation_0-rmse:0.18668	validation_1-rmse:0.24796
# [63]	validation_0-rmse:0.18658	validation_1-rmse:0.24745
# [64]	validation_0-rmse:0.18649	validation_1-rmse:0.24690
# [65]	validation_0-rmse:0.18641	validation_1-rmse:0.24642
# [66]	validation_0-rmse:0.18633	validation_1-rmse:0.24591
# [67]	validation_0-rmse:0.18629	validation_1-rmse:0.24562
# [68]	validation_0-rmse:0.18624	validation_1-rmse:0.24527
# [69]	validation_0-rmse:0.18621	validation_1-rmse:0.24499
# [70]	validation_0-rmse:0.18616	validation_1-rmse:0.24463
# [71]	validation_0-rmse:0.18611	validation_1-rmse:0.24420
# [72]	validation_0-rmse:0.18608	validation_1-rmse:0.24391
# [73]	validation_0-rmse:0.18605	validation_1-rmse:0.24354
# [74]	validation_0-rmse:0.18603	validation_1-rmse:0.24331
# [75]	validation_0-rmse:0.18600	validation_1-rmse:0.24299
# [76]	validation_0-rmse:0.18598	validation_1-rmse:0.24267
# [77]	validation_0-rmse:0.18518	validation_1-rmse:0.24216
# [78]	validation_0-rmse:0.18517	validation_1-rmse:0.24210
# [79]	validation_0-rmse:0.18516	validation_1-rmse:0.24187
# [80]	validation_0-rmse:0.18514	validation_1-rmse:0.24152
# [81]	validation_0-rmse:0.18513	validation_1-rmse:0.24139
# [82]	validation_0-rmse:0.18513	validation_1-rmse:0.24135
# [83]	validation_0-rmse:0.18511	validation_1-rmse:0.24104
# [84]	validation_0-rmse:0.18510	validation_1-rmse:0.24077
# [85]	validation_0-rmse:0.18510	validation_1-rmse:0.24067
# [86]	validation_0-rmse:0.18510	validation_1-rmse:0.24053
# [87]	validation_0-rmse:0.18510	validation_1-rmse:0.24050
# [88]	validation_0-rmse:0.18441	validation_1-rmse:0.23910
# [89]	validation_0-rmse:0.18441	validation_1-rmse:0.23905
# [90]	validation_0-rmse:0.18441	validation_1-rmse:0.23909
# [91]	validation_0-rmse:0.18440	validation_1-rmse:0.23899
# [92]	validation_0-rmse:0.18441	validation_1-rmse:0.23900
# [93]	validation_0-rmse:0.18441	validation_1-rmse:0.23909
# [94]	validation_0-rmse:0.18440	validation_1-rmse:0.23896
# [95]	validation_0-rmse:0.18440	validation_1-rmse:0.23878
# [96]	validation_0-rmse:0.18440	validation_1-rmse:0.23863
# [0]	validation_0-rmse:1.76310	validation_1-rmse:1.93653
# [1]	validation_0-rmse:1.64824	validation_1-rmse:1.81159
# [2]	validation_0-rmse:1.54236	validation_1-rmse:1.69414
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:1.44365	validation_1-rmse:1.58540
# [4]	validation_0-rmse:1.35193	validation_1-rmse:1.48499
# [5]	validation_0-rmse:1.26481	validation_1-rmse:1.38964
# [6]	validation_0-rmse:1.18425	validation_1-rmse:1.30011
# [7]	validation_0-rmse:1.10982	validation_1-rmse:1.21968
# [8]	validation_0-rmse:1.04113	validation_1-rmse:1.14279
# [9]	validation_0-rmse:0.97575	validation_1-rmse:1.07016
# [10]	validation_0-rmse:0.91608	validation_1-rmse:1.00258
# [11]	validation_0-rmse:0.85930	validation_1-rmse:0.94000
# [12]	validation_0-rmse:0.80695	validation_1-rmse:0.88072
# [13]	validation_0-rmse:0.75870	validation_1-rmse:0.82989
# [14]	validation_0-rmse:0.71313	validation_1-rmse:0.78344
# [15]	validation_0-rmse:0.67200	validation_1-rmse:0.73776
# [16]	validation_0-rmse:0.63212	validation_1-rmse:0.69087
# [17]	validation_0-rmse:0.59638	validation_1-rmse:0.65170
# [18]	validation_0-rmse:0.56339	validation_1-rmse:0.61420
# [19]	validation_0-rmse:0.53204	validation_1-rmse:0.57997
# [20]	validation_0-rmse:0.50243	validation_1-rmse:0.54925
# [21]	validation_0-rmse:0.47611	validation_1-rmse:0.52417
# [22]	validation_0-rmse:0.45130	validation_1-rmse:0.49890
# [23]	validation_0-rmse:0.42884	validation_1-rmse:0.47431
# [24]	validation_0-rmse:0.40736	validation_1-rmse:0.44963
# [25]	validation_0-rmse:0.38750	validation_1-rmse:0.42769
# [26]	validation_0-rmse:0.36988	validation_1-rmse:0.40987
# [27]	validation_0-rmse:0.35318	validation_1-rmse:0.39132
# [28]	validation_0-rmse:0.33730	validation_1-rmse:0.37570
# [29]	validation_0-rmse:0.32335	validation_1-rmse:0.36025
# [30]	validation_0-rmse:0.31051	validation_1-rmse:0.34777
# [31]	validation_0-rmse:0.29949	validation_1-rmse:0.33858
# [32]	validation_0-rmse:0.28931	validation_1-rmse:0.32854
# [33]	validation_0-rmse:0.28129	validation_1-rmse:0.32077
# [34]	validation_0-rmse:0.27218	validation_1-rmse:0.31334
# [35]	validation_0-rmse:0.26540	validation_1-rmse:0.30702
# [36]	validation_0-rmse:0.25820	validation_1-rmse:0.30191
# [37]	validation_0-rmse:0.25167	validation_1-rmse:0.29824
# [38]	validation_0-rmse:0.24533	validation_1-rmse:0.29170
# [39]	validation_0-rmse:0.23988	validation_1-rmse:0.28670
# [40]	validation_0-rmse:0.23416	validation_1-rmse:0.28386
# [41]	validation_0-rmse:0.23032	validation_1-rmse:0.28059
# [42]	validation_0-rmse:0.22693	validation_1-rmse:0.27769
# [43]	validation_0-rmse:0.22280	validation_1-rmse:0.27499
# [44]	validation_0-rmse:0.22002	validation_1-rmse:0.27276
# [45]	validation_0-rmse:0.21755	validation_1-rmse:0.27077
# [46]	validation_0-rmse:0.21533	validation_1-rmse:0.26904
# [47]	validation_0-rmse:0.21239	validation_1-rmse:0.26729
# [48]	validation_0-rmse:0.21063	validation_1-rmse:0.26666
# [49]	validation_0-rmse:0.20795	validation_1-rmse:0.26529
# [50]	validation_0-rmse:0.20629	validation_1-rmse:0.26383
# [51]	validation_0-rmse:0.20480	validation_1-rmse:0.26253
# [52]	validation_0-rmse:0.20351	validation_1-rmse:0.26300
# [53]	validation_0-rmse:0.20226	validation_1-rmse:0.26221
# [54]	validation_0-rmse:0.20187	validation_1-rmse:0.26213
# [55]	validation_0-rmse:0.20153	validation_1-rmse:0.26206
# [56]	validation_0-rmse:0.20124	validation_1-rmse:0.26202
# [57]	validation_0-rmse:0.20025	validation_1-rmse:0.26069
# [58]	validation_0-rmse:0.20011	validation_1-rmse:0.26069
# [59]	validation_0-rmse:0.19925	validation_1-rmse:0.26148
# [60]	validation_0-rmse:0.19839	validation_1-rmse:0.26083
# [61]	validation_0-rmse:0.19826	validation_1-rmse:0.26085
# [62]	validation_0-rmse:0.19813	validation_1-rmse:0.26087
# [63]	validation_0-rmse:0.19794	validation_1-rmse:0.26093
# [64]	validation_0-rmse:0.19783	validation_1-rmse:0.26096
# [65]	validation_0-rmse:0.19776	validation_1-rmse:0.26100
# [66]	validation_0-rmse:0.19768	validation_1-rmse:0.26104
# [67]	validation_0-rmse:0.19757	validation_1-rmse:0.26110
# [68]	validation_0-rmse:0.19754	validation_1-rmse:0.26113
# [69]	validation_0-rmse:0.19685	validation_1-rmse:0.26042
# [70]	validation_0-rmse:0.19681	validation_1-rmse:0.26047
# [71]	validation_0-rmse:0.19627	validation_1-rmse:0.26065
# [72]	validation_0-rmse:0.19625	validation_1-rmse:0.26068
# [73]	validation_0-rmse:0.19619	validation_1-rmse:0.26077
# [74]	validation_0-rmse:0.19616	validation_1-rmse:0.26082
# [75]	validation_0-rmse:0.19614	validation_1-rmse:0.26087
# [76]	validation_0-rmse:0.19611	validation_1-rmse:0.26093
# [77]	validation_0-rmse:0.19609	validation_1-rmse:0.26098
# [78]	validation_0-rmse:0.19608	validation_1-rmse:0.26102
# [79]	validation_0-rmse:0.19607	validation_1-rmse:0.26105
# [80]	validation_0-rmse:0.19605	validation_1-rmse:0.26113
# [81]	validation_0-rmse:0.19604	validation_1-rmse:0.26116
# [82]	validation_0-rmse:0.19604	validation_1-rmse:0.26116
# [83]	validation_0-rmse:0.19604	validation_1-rmse:0.26118
# [84]	validation_0-rmse:0.19603	validation_1-rmse:0.26121
# [85]	validation_0-rmse:0.19603	validation_1-rmse:0.26122
# [86]	validation_0-rmse:0.19602	validation_1-rmse:0.26127
# [87]	validation_0-rmse:0.19602	validation_1-rmse:0.26130
# [88]	validation_0-rmse:0.19437	validation_1-rmse:0.26359
# [0]	validation_0-rmse:1.85298	validation_1-rmse:1.55329
# [1]	validation_0-rmse:1.73187	validation_1-rmse:1.44891
# [2]	validation_0-rmse:1.61901	validation_1-rmse:1.34330
# [3]	validation_0-rmse:1.51211	validation_1-rmse:1.24342
# [4]	validation_0-rmse:1.41470	validation_1-rmse:1.15750
# [5]	validation_0-rmse:1.32362	validation_1-rmse:1.08189
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:1.23869	validation_1-rmse:1.00693
# [7]	validation_0-rmse:1.16085	validation_1-rmse:0.93639
# [8]	validation_0-rmse:1.08730	validation_1-rmse:0.88045
# [9]	validation_0-rmse:1.01944	validation_1-rmse:0.82870
# [10]	validation_0-rmse:0.95547	validation_1-rmse:0.77385
# [11]	validation_0-rmse:0.89477	validation_1-rmse:0.72389
# [12]	validation_0-rmse:0.83983	validation_1-rmse:0.68043
# [13]	validation_0-rmse:0.78799	validation_1-rmse:0.63872
# [14]	validation_0-rmse:0.73985	validation_1-rmse:0.60189
# [15]	validation_0-rmse:0.69542	validation_1-rmse:0.56844
# [16]	validation_0-rmse:0.65408	validation_1-rmse:0.53697
# [17]	validation_0-rmse:0.61572	validation_1-rmse:0.51036
# [18]	validation_0-rmse:0.58007	validation_1-rmse:0.48589
# [19]	validation_0-rmse:0.54556	validation_1-rmse:0.46149
# [20]	validation_0-rmse:0.51453	validation_1-rmse:0.43992
# [21]	validation_0-rmse:0.48605	validation_1-rmse:0.42234
# [22]	validation_0-rmse:0.45916	validation_1-rmse:0.40589
# [23]	validation_0-rmse:0.43399	validation_1-rmse:0.39240
# [24]	validation_0-rmse:0.41143	validation_1-rmse:0.38079
# [25]	validation_0-rmse:0.39008	validation_1-rmse:0.37086
# [26]	validation_0-rmse:0.36952	validation_1-rmse:0.36211
# [27]	validation_0-rmse:0.35135	validation_1-rmse:0.35223
# [28]	validation_0-rmse:0.33525	validation_1-rmse:0.34480
# [29]	validation_0-rmse:0.31963	validation_1-rmse:0.33815
# [30]	validation_0-rmse:0.30598	validation_1-rmse:0.33255
# [31]	validation_0-rmse:0.29309	validation_1-rmse:0.32714
# [32]	validation_0-rmse:0.28059	validation_1-rmse:0.32370
# [33]	validation_0-rmse:0.27065	validation_1-rmse:0.32233
# [34]	validation_0-rmse:0.26086	validation_1-rmse:0.31945
# [35]	validation_0-rmse:0.25225	validation_1-rmse:0.31902
# ...
# [84]	validation_0-rmse:0.18531	validation_1-rmse:0.21939
# [85]	validation_0-rmse:0.18532	validation_1-rmse:0.21939
# [86]	validation_0-rmse:0.18530	validation_1-rmse:0.21937
# [87]	validation_0-rmse:0.18529	validation_1-rmse:0.21936
# [88]	validation_0-rmse:0.18529	validation_1-rmse:0.21936
# [89]	validation_0-rmse:0.18529	validation_1-rmse:0.21935
# [90]	validation_0-rmse:0.18528	validation_1-rmse:0.21933
# [91]	validation_0-rmse:0.18527	validation_1-rmse:0.21932
# [92]	validation_0-rmse:0.18527	validation_1-rmse:0.21932
# [93]	validation_0-rmse:0.18358	validation_1-rmse:0.21957
# [94]	validation_0-rmse:0.18357	validation_1-rmse:0.21956
# [95]	validation_0-rmse:0.18357	validation_1-rmse:0.21956
# [96]	validation_0-rmse:0.18357	validation_1-rmse:0.21956
# [0]	validation_0-rmse:1.75926	validation_1-rmse:1.95600
# [1]	validation_0-rmse:1.64489	validation_1-rmse:1.82884
# [2]	validation_0-rmse:1.53879	validation_1-rmse:1.71662
# [3]	validation_0-rmse:1.43951	validation_1-rmse:1.60840
# [4]	validation_0-rmse:1.34794	validation_1-rmse:1.50989
# [5]	validation_0-rmse:1.26283	validation_1-rmse:1.41604
# [6]	validation_0-rmse:1.18305	validation_1-rmse:1.32940
# [7]	validation_0-rmse:1.11016	validation_1-rmse:1.25177
# [8]	validation_0-rmse:1.04132	validation_1-rmse:1.17691
# [9]	validation_0-rmse:0.97624	validation_1-rmse:1.10649
# [10]	validation_0-rmse:0.91672	validation_1-rmse:1.04394
# [11]	validation_0-rmse:0.86142	validation_1-rmse:0.98033
# [12]	validation_0-rmse:0.80962	validation_1-rmse:0.92294
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [13]	validation_0-rmse:0.76149	validation_1-rmse:0.87068
# [14]	validation_0-rmse:0.71582	validation_1-rmse:0.82253
# [15]	validation_0-rmse:0.67405	validation_1-rmse:0.77946
# [16]	validation_0-rmse:0.63543	validation_1-rmse:0.73724
# [17]	validation_0-rmse:0.59937	validation_1-rmse:0.69860
# [18]	validation_0-rmse:0.56699	validation_1-rmse:0.66385
# [19]	validation_0-rmse:0.53467	validation_1-rmse:0.62661
# [20]	validation_0-rmse:0.50634	validation_1-rmse:0.59691
# [21]	validation_0-rmse:0.47998	validation_1-rmse:0.56914
# [22]	validation_0-rmse:0.45496	validation_1-rmse:0.54244
# [23]	validation_0-rmse:0.43269	validation_1-rmse:0.51929
# [24]	validation_0-rmse:0.41047	validation_1-rmse:0.49479
# [25]	validation_0-rmse:0.39012	validation_1-rmse:0.47421
# [26]	validation_0-rmse:0.37233	validation_1-rmse:0.45596
# [27]	validation_0-rmse:0.35535	validation_1-rmse:0.43768
# [28]	validation_0-rmse:0.34033	validation_1-rmse:0.42295
# [29]	validation_0-rmse:0.32599	validation_1-rmse:0.40673
# [30]	validation_0-rmse:0.31331	validation_1-rmse:0.39418
# [31]	validation_0-rmse:0.30120	validation_1-rmse:0.38450
# [32]	validation_0-rmse:0.29022	validation_1-rmse:0.37362
# [33]	validation_0-rmse:0.28045	validation_1-rmse:0.36297
# [34]	validation_0-rmse:0.27238	validation_1-rmse:0.35429
# [35]	validation_0-rmse:0.26397	validation_1-rmse:0.34593
# [36]	validation_0-rmse:0.25683	validation_1-rmse:0.33873
# [37]	validation_0-rmse:0.25072	validation_1-rmse:0.33198
# [38]	validation_0-rmse:0.24476	validation_1-rmse:0.32650
# [39]	validation_0-rmse:0.23977	validation_1-rmse:0.32098
# [40]	validation_0-rmse:0.23335	validation_1-rmse:0.31618
# [41]	validation_0-rmse:0.22885	validation_1-rmse:0.31073
# [42]	validation_0-rmse:0.22550	validation_1-rmse:0.30697
# [43]	validation_0-rmse:0.22246	validation_1-rmse:0.30348
# [44]	validation_0-rmse:0.21939	validation_1-rmse:0.29992
# [45]	validation_0-rmse:0.21699	validation_1-rmse:0.29903
# [46]	validation_0-rmse:0.21408	validation_1-rmse:0.29693
# [47]	validation_0-rmse:0.21132	validation_1-rmse:0.29367
# [48]	validation_0-rmse:0.20886	validation_1-rmse:0.29148
# [49]	validation_0-rmse:0.20664	validation_1-rmse:0.28902
# [50]	validation_0-rmse:0.20518	validation_1-rmse:0.28722
# [51]	validation_0-rmse:0.20361	validation_1-rmse:0.28519
# [52]	validation_0-rmse:0.20245	validation_1-rmse:0.28365
# [53]	validation_0-rmse:0.20203	validation_1-rmse:0.28311
# [54]	validation_0-rmse:0.20101	validation_1-rmse:0.28174
# [55]	validation_0-rmse:0.20067	validation_1-rmse:0.28128
# [56]	validation_0-rmse:0.19982	validation_1-rmse:0.28113
# [57]	validation_0-rmse:0.19884	validation_1-rmse:0.28027
# [58]	validation_0-rmse:0.19863	validation_1-rmse:0.27996
# [59]	validation_0-rmse:0.19756	validation_1-rmse:0.27835
# [60]	validation_0-rmse:0.19740	validation_1-rmse:0.27809
# [61]	validation_0-rmse:0.19658	validation_1-rmse:0.27704
# [62]	validation_0-rmse:0.19643	validation_1-rmse:0.27676
# [63]	validation_0-rmse:0.19633	validation_1-rmse:0.27658
# [64]	validation_0-rmse:0.19624	validation_1-rmse:0.27642
# [65]	validation_0-rmse:0.19616	validation_1-rmse:0.27624
# [66]	validation_0-rmse:0.19610	validation_1-rmse:0.27613
# [67]	validation_0-rmse:0.19545	validation_1-rmse:0.27570
# [68]	validation_0-rmse:0.19541	validation_1-rmse:0.27560
# [69]	validation_0-rmse:0.19537	validation_1-rmse:0.27551
# [70]	validation_0-rmse:0.19534	validation_1-rmse:0.27542
# [71]	validation_0-rmse:0.19530	validation_1-rmse:0.27532
# [72]	validation_0-rmse:0.19527	validation_1-rmse:0.27523
# [73]	validation_0-rmse:0.19524	validation_1-rmse:0.27514
# [74]	validation_0-rmse:0.19521	validation_1-rmse:0.27504
# [75]	validation_0-rmse:0.19520	validation_1-rmse:0.27500
# [76]	validation_0-rmse:0.19519	validation_1-rmse:0.27497
# [77]	validation_0-rmse:0.19518	validation_1-rmse:0.27493
# [78]	validation_0-rmse:0.19454	validation_1-rmse:0.27563
# [79]	validation_0-rmse:0.19453	validation_1-rmse:0.27559
# [80]	validation_0-rmse:0.19451	validation_1-rmse:0.27552
# [81]	validation_0-rmse:0.19451	validation_1-rmse:0.27549
# [82]	validation_0-rmse:0.19388	validation_1-rmse:0.27474
# [83]	validation_0-rmse:0.19387	validation_1-rmse:0.27471
# [84]	validation_0-rmse:0.19387	validation_1-rmse:0.27471
# [85]	validation_0-rmse:0.19387	validation_1-rmse:0.27469
# [86]	validation_0-rmse:0.19386	validation_1-rmse:0.27463
# [87]	validation_0-rmse:0.19386	validation_1-rmse:0.27466
# [88]	validation_0-rmse:0.19387	validation_1-rmse:0.27468
# [89]	validation_0-rmse:0.19386	validation_1-rmse:0.27466
# [90]	validation_0-rmse:0.19385	validation_1-rmse:0.27457
# [91]	validation_0-rmse:0.19385	validation_1-rmse:0.27456
# [92]	validation_0-rmse:0.19385	validation_1-rmse:0.27453
# [93]	validation_0-rmse:0.19384	validation_1-rmse:0.27447
# [94]	validation_0-rmse:0.19384	validation_1-rmse:0.27446
# [95]	validation_0-rmse:0.19384	validation_1-rmse:0.27450
# [96]	validation_0-rmse:0.19384	validation_1-rmse:0.27447
# [0]	validation_0-rmse:1.83513	validation_1-rmse:1.64152
# [1]	validation_0-rmse:1.71495	validation_1-rmse:1.53327
# [2]	validation_0-rmse:1.60306	validation_1-rmse:1.43675
# [3]	validation_0-rmse:1.49940	validation_1-rmse:1.34130
# [4]	validation_0-rmse:1.40238	validation_1-rmse:1.25661
# [5]	validation_0-rmse:1.31182	validation_1-rmse:1.17795
# [6]	validation_0-rmse:1.22779	validation_1-rmse:1.10494
# [7]	validation_0-rmse:1.15037	validation_1-rmse:1.03866
# [8]	validation_0-rmse:1.07761	validation_1-rmse:0.97591
# [9]	validation_0-rmse:1.00909	validation_1-rmse:0.91529
# [10]	validation_0-rmse:0.94595	validation_1-rmse:0.86036
# [11]	validation_0-rmse:0.88692	validation_1-rmse:0.80763
# [12]	validation_0-rmse:0.83113	validation_1-rmse:0.75958
# [13]	validation_0-rmse:0.78051	validation_1-rmse:0.71947
# [14]	validation_0-rmse:0.73279	validation_1-rmse:0.67760
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:0.68892	validation_1-rmse:0.64101
# [16]	validation_0-rmse:0.64727	validation_1-rmse:0.60577
# [17]	validation_0-rmse:0.60912	validation_1-rmse:0.57515
# [18]	validation_0-rmse:0.57286	validation_1-rmse:0.54400
# [19]	validation_0-rmse:0.53856	validation_1-rmse:0.51626
# [20]	validation_0-rmse:0.50773	validation_1-rmse:0.49064
# [21]	validation_0-rmse:0.47957	validation_1-rmse:0.47044
# [22]	validation_0-rmse:0.45297	validation_1-rmse:0.45066
# [23]	validation_0-rmse:0.42912	validation_1-rmse:0.43282
# [24]	validation_0-rmse:0.40627	validation_1-rmse:0.41593
# [25]	validation_0-rmse:0.38519	validation_1-rmse:0.40289
# [26]	validation_0-rmse:0.36592	validation_1-rmse:0.39197
# [27]	validation_0-rmse:0.34762	validation_1-rmse:0.38283
# [28]	validation_0-rmse:0.33150	validation_1-rmse:0.37299
# [29]	validation_0-rmse:0.31575	validation_1-rmse:0.36455
# [30]	validation_0-rmse:0.30196	validation_1-rmse:0.35732
# [31]	validation_0-rmse:0.28944	validation_1-rmse:0.35087
# [32]	validation_0-rmse:0.27827	validation_1-rmse:0.34527
# [33]	validation_0-rmse:0.26806	validation_1-rmse:0.34071
# [34]	validation_0-rmse:0.25826	validation_1-rmse:0.33791
# [35]	validation_0-rmse:0.24988	validation_1-rmse:0.33481
# [36]	validation_0-rmse:0.24253	validation_1-rmse:0.33338
# [37]	validation_0-rmse:0.23546	validation_1-rmse:0.33054
# [38]	validation_0-rmse:0.22891	validation_1-rmse:0.32834
# [39]	validation_0-rmse:0.22304	validation_1-rmse:0.32747
# [40]	validation_0-rmse:0.21760	validation_1-rmse:0.32679
# [41]	validation_0-rmse:0.21331	validation_1-rmse:0.32536
# [42]	validation_0-rmse:0.20863	validation_1-rmse:0.32572
# [43]	validation_0-rmse:0.20440	validation_1-rmse:0.32537
# [44]	validation_0-rmse:0.20123	validation_1-rmse:0.32548
# [45]	validation_0-rmse:0.19845	validation_1-rmse:0.32574
# [46]	validation_0-rmse:0.19406	validation_1-rmse:0.32651
# [47]	validation_0-rmse:0.19158	validation_1-rmse:0.32662
# [48]	validation_0-rmse:0.18956	validation_1-rmse:0.32707
# [49]	validation_0-rmse:0.18761	validation_1-rmse:0.32715
# [50]	validation_0-rmse:0.18582	validation_1-rmse:0.32727
# [51]	validation_0-rmse:0.18427	validation_1-rmse:0.32731
# [52]	validation_0-rmse:0.18275	validation_1-rmse:0.32746
# [53]	validation_0-rmse:0.18143	validation_1-rmse:0.32800
# [54]	validation_0-rmse:0.18091	validation_1-rmse:0.32823
# [55]	validation_0-rmse:0.18048	validation_1-rmse:0.32844
# [56]	validation_0-rmse:0.17942	validation_1-rmse:0.32858
# [57]	validation_0-rmse:0.17830	validation_1-rmse:0.32915
# [58]	validation_0-rmse:0.17803	validation_1-rmse:0.32934
# [59]	validation_0-rmse:0.17774	validation_1-rmse:0.32957
# [60]	validation_0-rmse:0.17750	validation_1-rmse:0.32978
# [61]	validation_0-rmse:0.17731	validation_1-rmse:0.32997
# [0]	validation_0-rmse:1.75350	validation_1-rmse:1.96879
# [1]	validation_0-rmse:1.63748	validation_1-rmse:1.84327
# [2]	validation_0-rmse:1.53152	validation_1-rmse:1.72282
# [3]	validation_0-rmse:1.43176	validation_1-rmse:1.61369
# [4]	validation_0-rmse:1.33986	validation_1-rmse:1.50922
# [5]	validation_0-rmse:1.25389	validation_1-rmse:1.41264
# [6]	validation_0-rmse:1.17365	validation_1-rmse:1.32286
# [7]	validation_0-rmse:1.10021	validation_1-rmse:1.23940
# [8]	validation_0-rmse:1.03056	validation_1-rmse:1.16630
# [9]	validation_0-rmse:0.96492	validation_1-rmse:1.09226
# [10]	validation_0-rmse:0.90498	validation_1-rmse:1.02703
# [11]	validation_0-rmse:0.84835	validation_1-rmse:0.96325
# [12]	validation_0-rmse:0.79541	validation_1-rmse:0.90540
# [13]	validation_0-rmse:0.74646	validation_1-rmse:0.85566
# [14]	validation_0-rmse:0.70140	validation_1-rmse:0.80938
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:0.65997	validation_1-rmse:0.76354
# [16]	validation_0-rmse:0.62081	validation_1-rmse:0.72211
# [17]	validation_0-rmse:0.58464	validation_1-rmse:0.68533
# [18]	validation_0-rmse:0.55207	validation_1-rmse:0.65532
# [19]	validation_0-rmse:0.52059	validation_1-rmse:0.62149
# [20]	validation_0-rmse:0.49160	validation_1-rmse:0.59198
# [21]	validation_0-rmse:0.46475	validation_1-rmse:0.56694
# [22]	validation_0-rmse:0.43918	validation_1-rmse:0.54265
# [23]	validation_0-rmse:0.41644	validation_1-rmse:0.52256
# [24]	validation_0-rmse:0.39459	validation_1-rmse:0.50125
# [25]	validation_0-rmse:0.37522	validation_1-rmse:0.48216
# [26]	validation_0-rmse:0.35772	validation_1-rmse:0.46551
# [27]	validation_0-rmse:0.34165	validation_1-rmse:0.45284
# [28]	validation_0-rmse:0.32614	validation_1-rmse:0.44146
# [29]	validation_0-rmse:0.31222	validation_1-rmse:0.42788
# [30]	validation_0-rmse:0.30019	validation_1-rmse:0.41859
# [31]	validation_0-rmse:0.28927	validation_1-rmse:0.40954
# [32]	validation_0-rmse:0.27846	validation_1-rmse:0.40135
# [33]	validation_0-rmse:0.26930	validation_1-rmse:0.39661
# [34]	validation_0-rmse:0.26016	validation_1-rmse:0.39062
# [35]	validation_0-rmse:0.25153	validation_1-rmse:0.38608
# [36]	validation_0-rmse:0.24436	validation_1-rmse:0.38245
# [37]	validation_0-rmse:0.23773	validation_1-rmse:0.37668
# [38]	validation_0-rmse:0.23196	validation_1-rmse:0.37159
# [39]	validation_0-rmse:0.22636	validation_1-rmse:0.36943
# [40]	validation_0-rmse:0.22181	validation_1-rmse:0.36775
# [41]	validation_0-rmse:0.21787	validation_1-rmse:0.36486
# [42]	validation_0-rmse:0.21369	validation_1-rmse:0.36136
# [43]	validation_0-rmse:0.20980	validation_1-rmse:0.35773
# [44]	validation_0-rmse:0.20707	validation_1-rmse:0.35659
# [45]	validation_0-rmse:0.20441	validation_1-rmse:0.35478
# [46]	validation_0-rmse:0.20206	validation_1-rmse:0.35356
# [47]	validation_0-rmse:0.19935	validation_1-rmse:0.35279
# [48]	validation_0-rmse:0.19746	validation_1-rmse:0.35084
# [49]	validation_0-rmse:0.19567	validation_1-rmse:0.34994
# [50]	validation_0-rmse:0.19386	validation_1-rmse:0.34821
# [51]	validation_0-rmse:0.19235	validation_1-rmse:0.34872
# [52]	validation_0-rmse:0.19112	validation_1-rmse:0.34839
# [53]	validation_0-rmse:0.18978	validation_1-rmse:0.34708
# [54]	validation_0-rmse:0.18862	validation_1-rmse:0.34584
# [55]	validation_0-rmse:0.18753	validation_1-rmse:0.34466
# [56]	validation_0-rmse:0.18721	validation_1-rmse:0.34502
# [57]	validation_0-rmse:0.18625	validation_1-rmse:0.34405
# [58]	validation_0-rmse:0.18602	validation_1-rmse:0.34436
# [59]	validation_0-rmse:0.18578	validation_1-rmse:0.34470
# [60]	validation_0-rmse:0.18558	validation_1-rmse:0.34502
# [61]	validation_0-rmse:0.18483	validation_1-rmse:0.34361
# [62]	validation_0-rmse:0.18462	validation_1-rmse:0.34401
# [63]	validation_0-rmse:0.18450	validation_1-rmse:0.34426
# [64]	validation_0-rmse:0.18438	validation_1-rmse:0.34453
# [65]	validation_0-rmse:0.18430	validation_1-rmse:0.34473
# [66]	validation_0-rmse:0.18420	validation_1-rmse:0.34498
# [67]	validation_0-rmse:0.18411	validation_1-rmse:0.34525
# [68]	validation_0-rmse:0.18403	validation_1-rmse:0.34550
# [69]	validation_0-rmse:0.18400	validation_1-rmse:0.34561
# [70]	validation_0-rmse:0.18395	validation_1-rmse:0.34580
# [71]	validation_0-rmse:0.18323	validation_1-rmse:0.34572
# [72]	validation_0-rmse:0.18319	validation_1-rmse:0.34588
# [73]	validation_0-rmse:0.18315	validation_1-rmse:0.34607
# [74]	validation_0-rmse:0.18313	validation_1-rmse:0.34618
# [75]	validation_0-rmse:0.18310	validation_1-rmse:0.34635
# [76]	validation_0-rmse:0.18309	validation_1-rmse:0.34641
# [77]	validation_0-rmse:0.18308	validation_1-rmse:0.34653
# [78]	validation_0-rmse:0.18307	validation_1-rmse:0.34659
# [79]	validation_0-rmse:0.18306	validation_1-rmse:0.34663
# [80]	validation_0-rmse:0.18305	validation_1-rmse:0.34673
# [81]	validation_0-rmse:0.18304	validation_1-rmse:0.34683
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 77.715, median: 86.0,
#  pred. interval (P(0.025)-P(0.975)): 40.925-96.0,
#  conf. interval (p-value=0.95): 71.598-90.364
# ***
# Aggregate bias statistic:
#  mean: -0.427, median: -0.365,
#  pred. interval (P(0.025)-P(0.975)): -2.981-2.058,
#  conf. interval (p-value=0.95): -0.915-0.109
# ***
# Aggregate RMSE statistic:
#  mean: 0.306, median: 0.302, pred. interval (P(0.025)-P(0.975)): 0.211-0.443,
#  conf. interval (p-value=0.95): 0.28-0.326
# ***
# Aggregate MSE statistic:
#  mean: 0.097, median: 0.091, pred. interval (P(0.025)-P(0.975)): 0.044-0.196,
#  conf. interval (p-value=0.95): 0.079-0.107
# ***
# Aggregate R^2 statistic:
#  mean: 0.908, median: 0.912, pred. interval (P(0.025)-P(0.975)): 0.826-0.958,
#  conf. interval (p-value=0.95): 0.895-0.927
# ***
# Aggregate bias(%) statistic:
#  mean: -0.184, median: -0.365, pred. interval (P(0.025)-P(0.975)): -1.386-1.049,
#  conf. interval (p-value=0.95): -0.435-0.064
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.15, median: 0.145, pred. interval (P(0.025)-P(0.975)): 0.094-0.245,
#  conf. interval (p-value=0.95): 0.132-0.162
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.79824
# [1]	validation_0-rmse:1.67877
# [2]	validation_0-rmse:1.57018
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:1.46715
# [4]	validation_0-rmse:1.37199
# [5]	validation_0-rmse:1.28282
# [6]	validation_0-rmse:1.19990
# [7]	validation_0-rmse:1.12305
# [8]	validation_0-rmse:1.05230
# [9]	validation_0-rmse:0.98502
# [10]	validation_0-rmse:0.92371
# [11]	validation_0-rmse:0.86537
# [12]	validation_0-rmse:0.81199
# [13]	validation_0-rmse:0.76186
# [14]	validation_0-rmse:0.71521
# [15]	validation_0-rmse:0.67288
# [16]	validation_0-rmse:0.63291
# [17]	validation_0-rmse:0.59575
# [18]	validation_0-rmse:0.56208
# [19]	validation_0-rmse:0.53017
# [20]	validation_0-rmse:0.50060
# [21]	validation_0-rmse:0.47207
# [22]	validation_0-rmse:0.44594
# [23]	validation_0-rmse:0.42245
# [24]	validation_0-rmse:0.40087
# [25]	validation_0-rmse:0.38010
# [26]	validation_0-rmse:0.36201
# [27]	validation_0-rmse:0.34424
# [28]	validation_0-rmse:0.32907
# [29]	validation_0-rmse:0.31371
# [30]	validation_0-rmse:0.30063
# [31]	validation_0-rmse:0.28891
# [32]	validation_0-rmse:0.27779
# [33]	validation_0-rmse:0.26821
# [34]	validation_0-rmse:0.25941
# [35]	validation_0-rmse:0.25135
# [36]	validation_0-rmse:0.24446
# [37]	validation_0-rmse:0.23782
# [38]	validation_0-rmse:0.23271
# [39]	validation_0-rmse:0.22744
# [40]	validation_0-rmse:0.22230
# [41]	validation_0-rmse:0.21775
# [42]	validation_0-rmse:0.21428
# [43]	validation_0-rmse:0.21121
# [44]	validation_0-rmse:0.20836
# [45]	validation_0-rmse:0.20531
# [46]	validation_0-rmse:0.20241
# [47]	validation_0-rmse:0.20066
# [48]	validation_0-rmse:0.19887
# [49]	validation_0-rmse:0.19718
# [50]	validation_0-rmse:0.19587
# [51]	validation_0-rmse:0.19460
# [52]	validation_0-rmse:0.19389
# [53]	validation_0-rmse:0.19268
# [54]	validation_0-rmse:0.19162
# [55]	validation_0-rmse:0.19005
# [56]	validation_0-rmse:0.18916
# [57]	validation_0-rmse:0.18837
# [58]	validation_0-rmse:0.18756
# [59]	validation_0-rmse:0.18736
# [60]	validation_0-rmse:0.18713
# [61]	validation_0-rmse:0.18696
# [62]	validation_0-rmse:0.18680
# [63]	validation_0-rmse:0.18671
# [64]	validation_0-rmse:0.18664
# [65]	validation_0-rmse:0.18655
# [66]	validation_0-rmse:0.18594
# [67]	validation_0-rmse:0.18585
# [68]	validation_0-rmse:0.18580
# [69]	validation_0-rmse:0.18577
# [70]	validation_0-rmse:0.18572
# [71]	validation_0-rmse:0.18569
# [72]	validation_0-rmse:0.18566
# [73]	validation_0-rmse:0.18563
# [74]	validation_0-rmse:0.18509
# [75]	validation_0-rmse:0.18508
# [76]	validation_0-rmse:0.18452
# [77]	validation_0-rmse:0.18451
# [78]	validation_0-rmse:0.18450
# [79]	validation_0-rmse:0.18449
# [80]	validation_0-rmse:0.18448
# [81]	validation_0-rmse:0.18448
# [82]	validation_0-rmse:0.18448
# [83]	validation_0-rmse:0.18447
# [84]	validation_0-rmse:0.18447
# [85]	validation_0-rmse:0.18446
# [86]	validation_0-rmse:0.18445
# [87]	validation_0-rmse:0.18445
# [88]	validation_0-rmse:0.18445
# [89]	validation_0-rmse:0.18445
# [90]	validation_0-rmse:0.18445
# [91]	validation_0-rmse:0.18444
# [92]	validation_0-rmse:0.18444
# [93]	validation_0-rmse:0.18444
# [94]	validation_0-rmse:0.18444
# [95]	validation_0-rmse:0.18444
# [96]	validation_0-rmse:0.18444
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 96

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.06
# RMSE: 0.2
# Relative RMSE(%):  0.088
# MSE: 0.0
# R square: 97.1%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.139
# a1: 0.933
# R^2: 0.972
# Uncertainty
# a0: 0.14+/-0.04
# a1: 0.933+/-0.016

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=1) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_MAG_XGB_model_without_texture.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_MAG_XGB_model_without_texture.txt")
