# %% [markdown]
# # *+Processing with CHM & RN & biomass data of other authors+*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25 idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167  0.050549
# 1           3600       8.189          15100  ...   0.040919  0.048889
# 2           4360       8.380          14600  ...   0.042397  0.050463
# 3           3420       8.137          12700  ...   0.043719  0.052974
# 4           2200       7.696          12100  ...   0.040659  0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX  idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966    0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602    0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265    0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465    0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420    0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 159 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX'])
            


# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0       4.8122           1.7630               -0.3147           -0.1590
# 1       5.7589           2.4570               -0.2485            0.3429
# 2       5.8464           2.5153               -0.1054            0.5493
# 3       5.7526           2.6304               -0.0834            0.3900
# 4       5.9480           2.6748                0.0000            0.5715
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX
# 0             -2.4418         1.9125     0.85    12.233545   19.097736
# 1             -0.1997         2.6319     1.00    14.964220   17.704655
# 2             -0.2144         2.7020     1.00    15.329449   17.559893
# 3             -0.3510         2.7763     0.97    15.392742   20.676994
# 4             -0.3711         2.8314     1.00    17.944009   21.851387

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
# dtypes: float64(9)
# memory usage: 7.4 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["Gs_cub_m", "M_stem_kg_m2"].describe()
# Out:
# /tmp/ipykernel_58588/594647310.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_specias"])["Gs_cub_m", "M_stem_kg_m2"].describe()
#                  Gs_cub_m                                               \
#                     count        mean         std    min    25%    50%
# Dominant_specias
# Alder                 4.0  380.250000  155.784841  199.0  283.0  386.5
# Aspen                 1.0  148.000000         NaN  148.0  148.0  148.0
# Birch                23.0  135.304348   73.156392   11.0   94.0  138.0
# Oak                   3.0  236.000000   77.504839  158.0  197.5  237.0
# Pine                 71.0  263.281690  185.083625    2.0   97.0  281.0
# Spruce                1.0  619.000000         NaN  619.0  619.0  619.0
#
#                                 M_stem_kg_m2                              \
#                      75%    max        count       mean       std    min
# Dominant_specias
# Alder             483.75  549.0          4.0  16.170000  5.186990   9.90
# Aspen             148.00  148.0          1.0   6.650000       NaN   6.65
# Birch             197.00  280.0         23.0   6.809130  3.677786   0.84
# Oak               275.00  313.0          3.0  13.513333  4.888725   9.59
# Pine              394.00  671.0         71.0  10.550000  7.252887   0.05
# Spruce            619.00  619.0          1.0  23.830000       NaN  23.83
#
#
#                       25%    50%      75%    max
# Dominant_specias
# Alder             12.9225  17.03  20.2775  20.72
# Aspen              6.6500   6.65   6.6500   6.65
# Birch              4.7650   6.19   9.7400  15.47
# Oak               10.7750  11.96  15.4750  18.99
# Pine               3.4400  11.34  16.2250  25.04
# Spruce            23.8300  23.83  23.8300  23.83

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000         103.00000
# mean      4.969534         1.827923             -0.239481           0.05436
# std       1.323782         1.325853              0.893398           0.66008
# min       0.693100        -2.995700             -3.912000          -1.55590
# 25%       4.672800         1.588100             -0.335500          -0.20955
# 50%       5.337500         2.286500             -0.040800           0.24450
# 75%       5.908100         2.730800              0.190600           0.49195
# max       6.508800         3.220500              1.654400           1.41220
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.021247       2.095454    0.808738    13.045021   17.907784
# std              0.803748       1.079203    0.276653     6.609366    7.523377
# min             -2.918800      -0.798500    0.090000     1.293138    2.733019
# 25%             -1.629700       1.801400    0.745000     8.206727   11.615798
# 50%             -0.719500       2.458700    0.960000    13.072916   18.269344
# 75%             -0.358800       2.862800    1.000000    17.432255   22.751595
# max              0.114200       3.366600    1.000000    28.916548   36.355442

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX'])
y = pd.DataFrame(select, columns= ['ln_Gs_cub_m'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX
# 0     0.85    12.233545   19.097736
# 1     1.00    14.964220   17.704655
# 2     1.00    15.329449   17.559893
# 3     0.97    15.392742   20.676994
# 4     1.00    17.944009   21.851387

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Gs_cub_m
# 0       4.8122
# 1       5.7589
# 2       5.8464
# 3       5.7526
# 4       5.9480

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.9014921433430301, 0.9288163678919694, 0.8390361434225562]
#     Mean: 0.890
#     Std: 0.038
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.46636262 0.40208094 0.41148334]
#     Mean: 0.427
#     Std: 0.028
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.33802548915863034, 0.2543755283692304, 0.35670620172164025]
#     Mean: 0.316
#     Std: 0.044
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.895 (std: 0.038)
# Parameters: {'colsample_bytree': 0.8441358793414397, 'gamma': 0.21354596382063146, 'learning_rate': 0.09419852841923904, 'max_depth': 3, 'n_estimators': 65, 'subsample': 0.31114930117673584}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.37088375, 0.36904945, 0.35657272, ..., 0.51076164, 0.31954703,
#        0.51066537]), 'std_fit_time': array([0.03977393, 0.01700542, 0.01948195, ..., 0.02610495, 0.03676653,
#        0.02110748]), 'mean_score_time': array([0.00626979, 0.00585775, 0.00611615, ..., 0.00909901, 0.0091228 ,
#        0.00913706]), 'std_score_time': array([4.33824513e-04, 5.27407333e-05, 1.69082113e-04, ...,
#        4.86025498e-05, 5.11220584e-05, 1.31876780e-04]), 'param_colsample_bytree': masked_array(data=[0.7095799474804438, 0.4704592808513056,
#                    0.4215908025691558, ..., 0.7870782686877795,
#                    0.5928127835635464, 0.2571993426814599],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.16453328080185597, 0.03071711850390174,
#                    0.07541309402769697, ..., 0.3478665270656583,
#                    0.027331918815287237, 0.3285109217735473],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.11179432381458727, 0.27049046435538365,
#                    0.2039652102425822, ..., 0.2525851371253096,
#                    0.20905599893414892, 0.1724099512726706],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[2, 3, 3, ..., 4, 4, 3],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[135, 149, 137, ..., 122, 72, 125],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.32641187802673527, 0.8726639176396593,
#                    0.735496043325476, ..., 0.8401240280780864,
#                    0.6966085545254583, 0.5089911691318719],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.7095799474804438, 'gamma': 0.16453328080185597, 'learning_rate': 0.11179432381458727, 'max_depth': 2, 'n_estimators': 135, 'subsample': 0.32641187802673527}, {'colsample_bytree': 0.4704592808513056, 'gamma': 0.03071711850390174, 'learning_rate': 0.27049046435538365, 'max_depth': 3, 'n_estimators': 149, 'subsample': 0.8726639176396593}, {'colsample_bytree': 0.4215908025691558, 'gamma': 0.07541309402769697, 'learning_rate': 0.2039652102425822, 'max_depth': 3, 'n_estimators': 137, 'subsample': 0.735496043325476}, {'colsample_bytree': 0.6857519899621295, 'gamma': 0.3248943375623811, 'learning_rate': 0.08984231876415824, 'max_depth': 3, 'n_estimators': 78, 'subsample': 0.8132461936607815}, {'colsample_bytree': 0.6888555906557845, 'gamma': 0.1386504379208836, 'learning_rate': 0.1570720375492604, 'max_depth': 4, 'n_estimators': 168, 'subsample': 0.6046989447520732}, {'colsample_bytree': 0.8007879301625206, 'gamma': 0.20244337840521714, 'learning_rate': 0.23934734747131747, 'max_depth': 3, 'n_estimators': 96, 'subsample': 0.6219954910928303}, {'colsample_bytree': 0.4967839848370884, 'gamma': 0.3106885387161256, 'learning_rate': 0.26676620297556164, 'max_depth': 3, 'n_estimators': 193, 'subsample': 0.9711829801803231}, {'colsample_bytree': 0.8769701919747076, 'gamma': 0.2741736141445914, 'learning_rate': 0.10717668617674664, 'max_depth': 4, 'n_estimators': 155, 'subsample': 0.5788440510888962}, {'colsample_bytree': 0.9462139417490263, 'gamma': 0.022819184346115073, 'learning_rate': 0.08255447147330189, 'max_depth': 2, 'n_estimators': 164, 'subsample': 0.8166365849124737}, {'colsample_bytree': 0.3316418070460002, 'gamma': 0.4817232884769312, 'learning_rate': 0.16760420522391625, 'max_depth': 4, 'n_estimators': 193, 'subsample': 0.9983152451429924}, {'colsample_bytree': 0.5424264682935015, 'gamma': 0.16870253385109735, 'learning_rate': 0.027299665505002256, 'max_depth': 2, 'n_estimators': 56, 'subsample': 0.5121393573756792}, {'colsample_bytree': 0.5131377414005358, 'gamma': 0.02520409931232631, 'learning_rate': 0.03377963218478003, 'max_depth': 2, 'n_estimators': 182, 'subsample': 0.8979695564959083}, {'colsample_bytree': 0.7099016846208461, 'gamma': 0.48043676921306155, 'learning_rate': 0.2995028842781296, 'max_depth': 4, 'n_estimators': 110, 'subsample': 0.8336572226370536}, {'colsample_bytree': 0.36188217412341633, 'gamma': 0.3085117495458022, 'learning_rate': 0.21919409403916476, 'max_depth': 2, 'n_estimators': 180, 'subsample': 0.7552000306730318}, {'colsample_bytree': 0.2753825010185269, 'gamma': 0.33380588920778753, 'learning_rate': 0.02966944976201715, 'max_depth': 2, 'n_estimators': 194, 'subsample': 0.8364129313052142}, {'colsample_bytree': 0.056606266429152056, 'gamma': 0.12912877073647216, 'learning_rate': 0.1922767328095645, 'max_depth': 2, 'n_estimators': 119, 'subsample': 0.7032608731170413}, {'colsample_bytree': 0.15454433181307276, 'gamma': 0.04480940676593076, 'learning_rate': 0.28475537041273785, 'max_depth': 2, 'n_estimators': 159, 'subsample': 0.8395973971017756}, {'colsample_bytree': 0.15926865004272686, 'gamma': 0.08542466493532519, 'learning_rate': 0.27779214944932407, 'max_depth': 4, 'n_estimators': 73, 'subsample': 0.7573627577680008}, {'colsample_bytree': 0.6141529808048627, 'gamma': 0.4387144611127579, 'learning_rate': 0.12153330150037732, 'max_depth': 4, 'n_estimators': 141, 'subsample': 0.4321036297018154}, {'colsample_bytree': 0.29533386978790543, 'gamma': 0.2215728204483024, 'learning_rate': 0.08233552407298189, 'max_depth': 3, 'n_estimators': 57, 'subsample': 0.4064638195744483}, {'colsample_bytree': 0.4065309408994717, 'gamma': 0.07782855758176987, 'learning_rate': 0.15493811764516066, 'max_depth': 4, 'n_estimators': 84, 'subsample': 0.8306740571379592}, {'colsample_bytree': 0.6130042573515094, 'gamma': 0.2912907075444913, 'learning_rate': 0.15656747643278746, 'max_depth': 4, 'n_estimators': 140, 'subsample': 0.8355188873759514}, {'colsample_b ...
#        0.83643642]), 'split1_test_score': array([0.8827574 , 0.82556539, 0.86285688, ..., 0.87294578, 0.87356744,
#        0.86843319]), 'split2_test_score': array([0.9248184 , 0.91780686, 0.92810788, ..., 0.93165787, 0.91687683,
#        0.88340075]), 'split3_test_score': array([0.91691865, 0.87212729, 0.88334831, ..., 0.91791327, 0.85988034,
#        0.92249579]), 'split4_test_score': array([0.76628395, 0.83217507, 0.82831278, ..., 0.62914808, 0.81806288,
#        0.85137747]), 'mean_test_score': array([0.87579233, 0.85081144, 0.87280101, ..., 0.85403578, 0.86549348,
#        0.87242872]), 'std_test_score': array([0.05707725, 0.03975261, 0.0327983 , ..., 0.11418845, 0.03171038,
#        0.02960291]), 'rank_test_score': array([1172, 2600, 1453, ..., 2518, 1993, 1486], dtype=int32), 'split0_train_score': array([0.97341735, 0.99432509, 0.98872049, ..., 0.97406912, 0.99378478,
#        0.96385745]), 'split1_train_score': array([0.96821185, 0.9928914 , 0.98678045, ..., 0.96889024, 0.99256319,
#        0.96403022]), 'split2_train_score': array([0.96777553, 0.99355488, 0.98807059, ..., 0.96819514, 0.99357569,
#        0.96479618]), 'split3_train_score': array([0.96943239, 0.99405806, 0.98814471, ..., 0.97276754, 0.99306121,
#        0.96391444]), 'split4_train_score': array([0.97241814, 0.99377533, 0.98849911, ..., 0.97467408, 0.99324537,
#        0.96592815]), 'mean_train_score': array([0.97025105, 0.99372095, 0.98804307, ..., 0.97171922, 0.99324605,
#        0.96450529]), 'std_train_score': array([0.00226621, 0.00048935, 0.00067411, ..., 0.00267486, 0.00042411,
#        0.00078786])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.8441358793414397
# Gamma: 0.21354596382063146
# Learning_rate: 0.09419852841923904
# Max_depth: 3
# N_estimators: 65
# Subsample: 0.31114930117673584

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:4.25167	validation_1-rmse:4.33975
# [1]	validation_0-rmse:3.89413	validation_1-rmse:3.98585
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-rmse:3.53507	validation_1-rmse:3.61553
# [3]	validation_0-rmse:3.22191	validation_1-rmse:3.31714
# [4]	validation_0-rmse:2.94753	validation_1-rmse:3.03583
# [5]	validation_0-rmse:2.69456	validation_1-rmse:2.79653
# [6]	validation_0-rmse:2.46311	validation_1-rmse:2.56655
# [7]	validation_0-rmse:2.25552	validation_1-rmse:2.35321
# [8]	validation_0-rmse:2.05715	validation_1-rmse:2.15598
# [9]	validation_0-rmse:1.88383	validation_1-rmse:1.98281
# [10]	validation_0-rmse:1.73278	validation_1-rmse:1.82556
# [11]	validation_0-rmse:1.60483	validation_1-rmse:1.69258
# [12]	validation_0-rmse:1.46819	validation_1-rmse:1.55575
# [13]	validation_0-rmse:1.35840	validation_1-rmse:1.45564
# [14]	validation_0-rmse:1.25211	validation_1-rmse:1.36072
# [15]	validation_0-rmse:1.15550	validation_1-rmse:1.27481
# [16]	validation_0-rmse:1.06764	validation_1-rmse:1.19401
# [17]	validation_0-rmse:0.98752	validation_1-rmse:1.11359
# [18]	validation_0-rmse:0.91467	validation_1-rmse:1.04032
# [19]	validation_0-rmse:0.84698	validation_1-rmse:0.97441
# [20]	validation_0-rmse:0.78437	validation_1-rmse:0.91151
# [21]	validation_0-rmse:0.72865	validation_1-rmse:0.85723
# [22]	validation_0-rmse:0.67941	validation_1-rmse:0.80680
# [23]	validation_0-rmse:0.63346	validation_1-rmse:0.75968
# [24]	validation_0-rmse:0.59504	validation_1-rmse:0.72388
# [25]	validation_0-rmse:0.55835	validation_1-rmse:0.69017
# [26]	validation_0-rmse:0.52303	validation_1-rmse:0.66782
# [27]	validation_0-rmse:0.49632	validation_1-rmse:0.64136
# [28]	validation_0-rmse:0.47008	validation_1-rmse:0.62233
# [29]	validation_0-rmse:0.44686	validation_1-rmse:0.59093
# [30]	validation_0-rmse:0.43452	validation_1-rmse:0.58579
# [31]	validation_0-rmse:0.41844	validation_1-rmse:0.57018
# [32]	validation_0-rmse:0.40389	validation_1-rmse:0.56130
# [33]	validation_0-rmse:0.39312	validation_1-rmse:0.54985
# [34]	validation_0-rmse:0.38270	validation_1-rmse:0.54174
# [35]	validation_0-rmse:0.37208	validation_1-rmse:0.54601
# [36]	validation_0-rmse:0.36108	validation_1-rmse:0.53586
# [37]	validation_0-rmse:0.35131	validation_1-rmse:0.52103
# [38]	validation_0-rmse:0.34489	validation_1-rmse:0.51372
# [39]	validation_0-rmse:0.33921	validation_1-rmse:0.50048
# [40]	validation_0-rmse:0.33409	validation_1-rmse:0.49457
# [41]	validation_0-rmse:0.32632	validation_1-rmse:0.48829
# [42]	validation_0-rmse:0.32179	validation_1-rmse:0.48818
# [43]	validation_0-rmse:0.31897	validation_1-rmse:0.48442
# [44]	validation_0-rmse:0.31578	validation_1-rmse:0.47702
# [45]	validation_0-rmse:0.31279	validation_1-rmse:0.47841
# [46]	validation_0-rmse:0.30893	validation_1-rmse:0.47192
# [47]	validation_0-rmse:0.30634	validation_1-rmse:0.46812
# [48]	validation_0-rmse:0.29879	validation_1-rmse:0.46672
# [49]	validation_0-rmse:0.29822	validation_1-rmse:0.46569
# [50]	validation_0-rmse:0.29378	validation_1-rmse:0.45977
# [51]	validation_0-rmse:0.28914	validation_1-rmse:0.45602
# [52]	validation_0-rmse:0.28799	validation_1-rmse:0.45755
# [53]	validation_0-rmse:0.28636	validation_1-rmse:0.44895
# [54]	validation_0-rmse:0.28595	validation_1-rmse:0.44710
# [55]	validation_0-rmse:0.28524	validation_1-rmse:0.44598
# [56]	validation_0-rmse:0.28265	validation_1-rmse:0.43868
# [57]	validation_0-rmse:0.27883	validation_1-rmse:0.44563
# [58]	validation_0-rmse:0.27696	validation_1-rmse:0.44497
# [59]	validation_0-rmse:0.27673	validation_1-rmse:0.44424
# [60]	validation_0-rmse:0.27604	validation_1-rmse:0.43746
# [61]	validation_0-rmse:0.27575	validation_1-rmse:0.43604
# [62]	validation_0-rmse:0.27388	validation_1-rmse:0.43415
# [63]	validation_0-rmse:0.27302	validation_1-rmse:0.43229
# [64]	validation_0-rmse:0.27111	validation_1-rmse:0.43040
# [0]	validation_0-rmse:4.35891	validation_1-rmse:3.81636
# [1]	validation_0-rmse:3.97387	validation_1-rmse:3.49088
# [2]	validation_0-rmse:3.62345	validation_1-rmse:3.21093
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:3.32175	validation_1-rmse:2.93315
# [4]	validation_0-rmse:3.04761	validation_1-rmse:2.69184
# [5]	validation_0-rmse:2.77426	validation_1-rmse:2.44461
# [6]	validation_0-rmse:2.51864	validation_1-rmse:2.23513
# [7]	validation_0-rmse:2.30712	validation_1-rmse:2.06765
# [8]	validation_0-rmse:2.10464	validation_1-rmse:1.89275
# [9]	validation_0-rmse:1.93687	validation_1-rmse:1.75133
# [10]	validation_0-rmse:1.77871	validation_1-rmse:1.61639
# [11]	validation_0-rmse:1.62516	validation_1-rmse:1.49042
# [12]	validation_0-rmse:1.48775	validation_1-rmse:1.37437
# [13]	validation_0-rmse:1.37114	validation_1-rmse:1.29315
# [14]	validation_0-rmse:1.25476	validation_1-rmse:1.19836
# [15]	validation_0-rmse:1.16697	validation_1-rmse:1.13511
# [16]	validation_0-rmse:1.08293	validation_1-rmse:1.07376
# [17]	validation_0-rmse:1.00454	validation_1-rmse:1.01639
# [18]	validation_0-rmse:0.92850	validation_1-rmse:0.96188
# [19]	validation_0-rmse:0.85243	validation_1-rmse:0.90709
# [20]	validation_0-rmse:0.78799	validation_1-rmse:0.85911
# [21]	validation_0-rmse:0.74227	validation_1-rmse:0.83975
# [22]	validation_0-rmse:0.69099	validation_1-rmse:0.80181
# [23]	validation_0-rmse:0.64015	validation_1-rmse:0.77385
# [24]	validation_0-rmse:0.60446	validation_1-rmse:0.75933
# [25]	validation_0-rmse:0.57055	validation_1-rmse:0.72608
# [26]	validation_0-rmse:0.53903	validation_1-rmse:0.70647
# [27]	validation_0-rmse:0.50497	validation_1-rmse:0.68739
# [28]	validation_0-rmse:0.47600	validation_1-rmse:0.67855
# [29]	validation_0-rmse:0.44996	validation_1-rmse:0.66591
# [30]	validation_0-rmse:0.43474	validation_1-rmse:0.65906
# [31]	validation_0-rmse:0.41356	validation_1-rmse:0.64876
# [32]	validation_0-rmse:0.39273	validation_1-rmse:0.63505
# [33]	validation_0-rmse:0.38094	validation_1-rmse:0.63104
# [34]	validation_0-rmse:0.37188	validation_1-rmse:0.62906
# [35]	validation_0-rmse:0.35954	validation_1-rmse:0.63410
# [36]	validation_0-rmse:0.34703	validation_1-rmse:0.63222
# [37]	validation_0-rmse:0.33742	validation_1-rmse:0.62879
# [38]	validation_0-rmse:0.33137	validation_1-rmse:0.63188
# [39]	validation_0-rmse:0.32330	validation_1-rmse:0.63159
# [40]	validation_0-rmse:0.31554	validation_1-rmse:0.62850
# [41]	validation_0-rmse:0.31177	validation_1-rmse:0.62673
# [42]	validation_0-rmse:0.30958	validation_1-rmse:0.63577
# [43]	validation_0-rmse:0.30471	validation_1-rmse:0.63412
# [44]	validation_0-rmse:0.30224	validation_1-rmse:0.64039
# [45]	validation_0-rmse:0.29938	validation_1-rmse:0.63622
# [46]	validation_0-rmse:0.29662	validation_1-rmse:0.63526
# [47]	validation_0-rmse:0.29589	validation_1-rmse:0.63680
# [48]	validation_0-rmse:0.29346	validation_1-rmse:0.64022
# [49]	validation_0-rmse:0.29129	validation_1-rmse:0.63521
# [50]	validation_0-rmse:0.29043	validation_1-rmse:0.63530
# [51]	validation_0-rmse:0.28935	validation_1-rmse:0.63624
# [52]	validation_0-rmse:0.28656	validation_1-rmse:0.63584
# [53]	validation_0-rmse:0.28548	validation_1-rmse:0.63560
# [54]	validation_0-rmse:0.28410	validation_1-rmse:0.63536
# [55]	validation_0-rmse:0.28087	validation_1-rmse:0.63574
# [56]	validation_0-rmse:0.27733	validation_1-rmse:0.63413
# [57]	validation_0-rmse:0.27575	validation_1-rmse:0.62817
# [58]	validation_0-rmse:0.27532	validation_1-rmse:0.62797
# [59]	validation_0-rmse:0.27496	validation_1-rmse:0.62780
# [60]	validation_0-rmse:0.27389	validation_1-rmse:0.62638
# [61]	validation_0-rmse:0.27400	validation_1-rmse:0.62643
# [62]	validation_0-rmse:0.27308	validation_1-rmse:0.62699
# [63]	validation_0-rmse:0.26942	validation_1-rmse:0.61505
# [64]	validation_0-rmse:0.26932	validation_1-rmse:0.61499
# [0]	validation_0-rmse:4.21950	validation_1-rmse:4.40483
# [1]	validation_0-rmse:3.84628	validation_1-rmse:4.01610
# [2]	validation_0-rmse:3.50929	validation_1-rmse:3.66129
# [3]	validation_0-rmse:3.20254	validation_1-rmse:3.33423
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:2.92666	validation_1-rmse:3.04389
# [5]	validation_0-rmse:2.67664	validation_1-rmse:2.78740
# [6]	validation_0-rmse:2.44628	validation_1-rmse:2.54796
# [7]	validation_0-rmse:2.22780	validation_1-rmse:2.31761
# [8]	validation_0-rmse:2.04561	validation_1-rmse:2.12845
# [9]	validation_0-rmse:1.88397	validation_1-rmse:1.96152
# [10]	validation_0-rmse:1.73802	validation_1-rmse:1.81205
# [11]	validation_0-rmse:1.60281	validation_1-rmse:1.65945
# [12]	validation_0-rmse:1.46596	validation_1-rmse:1.51399
# [13]	validation_0-rmse:1.34896	validation_1-rmse:1.39069
# [14]	validation_0-rmse:1.25959	validation_1-rmse:1.29792
# [15]	validation_0-rmse:1.15891	validation_1-rmse:1.18716
# [16]	validation_0-rmse:1.07097	validation_1-rmse:1.09222
# [17]	validation_0-rmse:0.99744	validation_1-rmse:1.02410
# [18]	validation_0-rmse:0.92377	validation_1-rmse:0.95184
# [19]	validation_0-rmse:0.85703	validation_1-rmse:0.88134
# [20]	validation_0-rmse:0.79178	validation_1-rmse:0.81814
# [21]	validation_0-rmse:0.73709	validation_1-rmse:0.76127
# [22]	validation_0-rmse:0.68385	validation_1-rmse:0.71203
# [23]	validation_0-rmse:0.63707	validation_1-rmse:0.67368
# [24]	validation_0-rmse:0.59369	validation_1-rmse:0.64452
# [25]	validation_0-rmse:0.56799	validation_1-rmse:0.62296
# [26]	validation_0-rmse:0.53756	validation_1-rmse:0.59072
# [27]	validation_0-rmse:0.51026	validation_1-rmse:0.55919
# [28]	validation_0-rmse:0.47842	validation_1-rmse:0.54069
# [29]	validation_0-rmse:0.45781	validation_1-rmse:0.52669
# [30]	validation_0-rmse:0.44106	validation_1-rmse:0.51531
# [31]	validation_0-rmse:0.42511	validation_1-rmse:0.50426
# [32]	validation_0-rmse:0.41238	validation_1-rmse:0.49061
# [33]	validation_0-rmse:0.39802	validation_1-rmse:0.48721
# [34]	validation_0-rmse:0.38366	validation_1-rmse:0.47401
# [35]	validation_0-rmse:0.37418	validation_1-rmse:0.47207
# [36]	validation_0-rmse:0.36117	validation_1-rmse:0.46203
# [37]	validation_0-rmse:0.35644	validation_1-rmse:0.46078
# [38]	validation_0-rmse:0.34697	validation_1-rmse:0.45595
# [39]	validation_0-rmse:0.33915	validation_1-rmse:0.45095
# [40]	validation_0-rmse:0.32895	validation_1-rmse:0.45056
# [41]	validation_0-rmse:0.32360	validation_1-rmse:0.44443
# [42]	validation_0-rmse:0.31778	validation_1-rmse:0.44347
# [43]	validation_0-rmse:0.31658	validation_1-rmse:0.44196
# [44]	validation_0-rmse:0.31287	validation_1-rmse:0.43894
# [45]	validation_0-rmse:0.30999	validation_1-rmse:0.43484
# [46]	validation_0-rmse:0.30593	validation_1-rmse:0.43531
# [47]	validation_0-rmse:0.30313	validation_1-rmse:0.44149
# [48]	validation_0-rmse:0.29841	validation_1-rmse:0.44416
# [49]	validation_0-rmse:0.29584	validation_1-rmse:0.44374
# [50]	validation_0-rmse:0.29338	validation_1-rmse:0.44665
# [51]	validation_0-rmse:0.29187	validation_1-rmse:0.44801
# [52]	validation_0-rmse:0.29156	validation_1-rmse:0.44484
# [53]	validation_0-rmse:0.28809	validation_1-rmse:0.44248
# [54]	validation_0-rmse:0.28834	validation_1-rmse:0.44215
# [55]	validation_0-rmse:0.28780	validation_1-rmse:0.44291
# [56]	validation_0-rmse:0.28774	validation_1-rmse:0.44300
# [57]	validation_0-rmse:0.28513	validation_1-rmse:0.44416
# [58]	validation_0-rmse:0.28102	validation_1-rmse:0.44808
# [59]	validation_0-rmse:0.27888	validation_1-rmse:0.44611
# [60]	validation_0-rmse:0.27703	validation_1-rmse:0.44969
# [61]	validation_0-rmse:0.27493	validation_1-rmse:0.44589
# [62]	validation_0-rmse:0.27369	validation_1-rmse:0.44201
# [63]	validation_0-rmse:0.27280	validation_1-rmse:0.44069
# [64]	validation_0-rmse:0.27095	validation_1-rmse:0.43638
# [0]	validation_0-rmse:4.23932	validation_1-rmse:4.31545
# [1]	validation_0-rmse:3.87495	validation_1-rmse:3.96010
# [2]	validation_0-rmse:3.53828	validation_1-rmse:3.63421
# [3]	validation_0-rmse:3.23224	validation_1-rmse:3.33161
# [4]	validation_0-rmse:2.95785	validation_1-rmse:3.05999
# [5]	validation_0-rmse:2.69947	validation_1-rmse:2.81001
# [6]	validation_0-rmse:2.48805	validation_1-rmse:2.60835
# [7]	validation_0-rmse:2.27151	validation_1-rmse:2.40010
# [8]	validation_0-rmse:2.06838	validation_1-rmse:2.20313
# [9]	validation_0-rmse:1.88840	validation_1-rmse:2.03139
# [10]	validation_0-rmse:1.73100	validation_1-rmse:1.87884
# [11]	validation_0-rmse:1.58401	validation_1-rmse:1.74393
# [12]	validation_0-rmse:1.44944	validation_1-rmse:1.60843
# [13]	validation_0-rmse:1.33025	validation_1-rmse:1.49228
# [14]	validation_0-rmse:1.22153	validation_1-rmse:1.38937
# [15]	validation_0-rmse:1.12428	validation_1-rmse:1.29817
# [16]	validation_0-rmse:1.04113	validation_1-rmse:1.21177
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [17]	validation_0-rmse:0.96306	validation_1-rmse:1.13236
# [18]	validation_0-rmse:0.89316	validation_1-rmse:1.06643
# [19]	validation_0-rmse:0.82552	validation_1-rmse:1.00041
# [20]	validation_0-rmse:0.76406	validation_1-rmse:0.94518
# [21]	validation_0-rmse:0.71646	validation_1-rmse:0.90103
# [22]	validation_0-rmse:0.66567	validation_1-rmse:0.85782
# [23]	validation_0-rmse:0.62544	validation_1-rmse:0.81925
# [24]	validation_0-rmse:0.58384	validation_1-rmse:0.78268
# [25]	validation_0-rmse:0.54463	validation_1-rmse:0.74847
# [26]	validation_0-rmse:0.50766	validation_1-rmse:0.71183
# [27]	validation_0-rmse:0.47923	validation_1-rmse:0.68739
# [28]	validation_0-rmse:0.45443	validation_1-rmse:0.66732
# [29]	validation_0-rmse:0.43085	validation_1-rmse:0.64436
# [30]	validation_0-rmse:0.41516	validation_1-rmse:0.62985
# [31]	validation_0-rmse:0.39545	validation_1-rmse:0.61945
# [32]	validation_0-rmse:0.37948	validation_1-rmse:0.60700
# [33]	validation_0-rmse:0.36559	validation_1-rmse:0.59411
# [34]	validation_0-rmse:0.35287	validation_1-rmse:0.58479
# [35]	validation_0-rmse:0.34430	validation_1-rmse:0.57795
# [36]	validation_0-rmse:0.33408	validation_1-rmse:0.56856
# [37]	validation_0-rmse:0.32955	validation_1-rmse:0.57221
# [38]	validation_0-rmse:0.32419	validation_1-rmse:0.56914
# [39]	validation_0-rmse:0.31696	validation_1-rmse:0.56555
# [40]	validation_0-rmse:0.31208	validation_1-rmse:0.56158
# [41]	validation_0-rmse:0.30607	validation_1-rmse:0.55121
# [42]	validation_0-rmse:0.30114	validation_1-rmse:0.55005
# [43]	validation_0-rmse:0.29808	validation_1-rmse:0.55445
# [44]	validation_0-rmse:0.29523	validation_1-rmse:0.54769
# [45]	validation_0-rmse:0.29283	validation_1-rmse:0.54972
# [46]	validation_0-rmse:0.28863	validation_1-rmse:0.54604
# [47]	validation_0-rmse:0.28522	validation_1-rmse:0.54536
# [48]	validation_0-rmse:0.27997	validation_1-rmse:0.54441
# [49]	validation_0-rmse:0.27769	validation_1-rmse:0.54258
# [50]	validation_0-rmse:0.27632	validation_1-rmse:0.54180
# [51]	validation_0-rmse:0.27047	validation_1-rmse:0.53709
# [52]	validation_0-rmse:0.26779	validation_1-rmse:0.53797
# [53]	validation_0-rmse:0.26752	validation_1-rmse:0.53782
# [54]	validation_0-rmse:0.26694	validation_1-rmse:0.54162
# [55]	validation_0-rmse:0.26668	validation_1-rmse:0.54149
# [56]	validation_0-rmse:0.26485	validation_1-rmse:0.53756
# [57]	validation_0-rmse:0.26286	validation_1-rmse:0.53192
# [58]	validation_0-rmse:0.26053	validation_1-rmse:0.52865
# [59]	validation_0-rmse:0.25882	validation_1-rmse:0.53070
# [60]	validation_0-rmse:0.25618	validation_1-rmse:0.53007
# [61]	validation_0-rmse:0.25616	validation_1-rmse:0.53006
# [62]	validation_0-rmse:0.25350	validation_1-rmse:0.53219
# [63]	validation_0-rmse:0.25261	validation_1-rmse:0.53529
# [64]	validation_0-rmse:0.25023	validation_1-rmse:0.53784
# [0]	validation_0-rmse:4.24799	validation_1-rmse:4.27740
# [1]	validation_0-rmse:3.87064	validation_1-rmse:3.89870
# [2]	validation_0-rmse:3.52140	validation_1-rmse:3.55615
# [3]	validation_0-rmse:3.21507	validation_1-rmse:3.27256
# [4]	validation_0-rmse:2.94523	validation_1-rmse:3.02087
# [5]	validation_0-rmse:2.69461	validation_1-rmse:2.77195
# [6]	validation_0-rmse:2.46085	validation_1-rmse:2.53675
# [7]	validation_0-rmse:2.25452	validation_1-rmse:2.33194
# [8]	validation_0-rmse:2.06202	validation_1-rmse:2.14589
# [9]	validation_0-rmse:1.89396	validation_1-rmse:1.98422
# [10]	validation_0-rmse:1.73805	validation_1-rmse:1.84013
# [11]	validation_0-rmse:1.60649	validation_1-rmse:1.71520
# [12]	validation_0-rmse:1.46492	validation_1-rmse:1.57860
# [13]	validation_0-rmse:1.34629	validation_1-rmse:1.46586
# [14]	validation_0-rmse:1.23660	validation_1-rmse:1.36654
# [15]	validation_0-rmse:1.13936	validation_1-rmse:1.28733
# [16]	validation_0-rmse:1.04328	validation_1-rmse:1.20787
# [17]	validation_0-rmse:0.96063	validation_1-rmse:1.13390
# [18]	validation_0-rmse:0.89912	validation_1-rmse:1.08186
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [19]	validation_0-rmse:0.83741	validation_1-rmse:1.02377
# [20]	validation_0-rmse:0.76696	validation_1-rmse:0.95945
# [21]	validation_0-rmse:0.70715	validation_1-rmse:0.90795
# [22]	validation_0-rmse:0.65403	validation_1-rmse:0.86540
# [23]	validation_0-rmse:0.61064	validation_1-rmse:0.83302
# [24]	validation_0-rmse:0.56629	validation_1-rmse:0.79917
# [25]	validation_0-rmse:0.52972	validation_1-rmse:0.77525
# [26]	validation_0-rmse:0.50576	validation_1-rmse:0.76036
# [27]	validation_0-rmse:0.47280	validation_1-rmse:0.74047
# [28]	validation_0-rmse:0.44502	validation_1-rmse:0.71706
# [29]	validation_0-rmse:0.42028	validation_1-rmse:0.70485
# [30]	validation_0-rmse:0.39981	validation_1-rmse:0.69369
# [31]	validation_0-rmse:0.37630	validation_1-rmse:0.67932
# [32]	validation_0-rmse:0.36466	validation_1-rmse:0.67419
# [33]	validation_0-rmse:0.35563	validation_1-rmse:0.67018
# [34]	validation_0-rmse:0.34498	validation_1-rmse:0.66565
# [35]	validation_0-rmse:0.33649	validation_1-rmse:0.66223
# [36]	validation_0-rmse:0.32589	validation_1-rmse:0.65661
# [37]	validation_0-rmse:0.31697	validation_1-rmse:0.64726
# [38]	validation_0-rmse:0.30922	validation_1-rmse:0.64519
# [39]	validation_0-rmse:0.30145	validation_1-rmse:0.63605
# [40]	validation_0-rmse:0.29597	validation_1-rmse:0.63294
# [41]	validation_0-rmse:0.28988	validation_1-rmse:0.63047
# [42]	validation_0-rmse:0.28393	validation_1-rmse:0.63042
# [43]	validation_0-rmse:0.27857	validation_1-rmse:0.62123
# [44]	validation_0-rmse:0.27576	validation_1-rmse:0.62659
# [45]	validation_0-rmse:0.27374	validation_1-rmse:0.62605
# [46]	validation_0-rmse:0.27033	validation_1-rmse:0.62387
# [47]	validation_0-rmse:0.26967	validation_1-rmse:0.62371
# [48]	validation_0-rmse:0.26840	validation_1-rmse:0.62342
# [49]	validation_0-rmse:0.26444	validation_1-rmse:0.62116
# [50]	validation_0-rmse:0.26420	validation_1-rmse:0.62111
# [51]	validation_0-rmse:0.26039	validation_1-rmse:0.61946
# [52]	validation_0-rmse:0.26014	validation_1-rmse:0.62245
# [53]	validation_0-rmse:0.25878	validation_1-rmse:0.61672
# [54]	validation_0-rmse:0.25798	validation_1-rmse:0.61301
# [55]	validation_0-rmse:0.25472	validation_1-rmse:0.61388
# [56]	validation_0-rmse:0.25364	validation_1-rmse:0.61384
# [57]	validation_0-rmse:0.25210	validation_1-rmse:0.61106
# [58]	validation_0-rmse:0.25212	validation_1-rmse:0.61106
# [59]	validation_0-rmse:0.24895	validation_1-rmse:0.61611
# [60]	validation_0-rmse:0.24677	validation_1-rmse:0.61750
# [61]	validation_0-rmse:0.24616	validation_1-rmse:0.62220
# [62]	validation_0-rmse:0.24384	validation_1-rmse:0.62244
# [63]	validation_0-rmse:0.24478	validation_1-rmse:0.62416
# [64]	validation_0-rmse:0.24473	validation_1-rmse:0.62420
# [0]	validation_0-rmse:4.28214	validation_1-rmse:4.19136
# [1]	validation_0-rmse:3.90424	validation_1-rmse:3.80388
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-rmse:3.55733	validation_1-rmse:3.44973
# [3]	validation_0-rmse:3.26222	validation_1-rmse:3.17620
# [4]	validation_0-rmse:2.99047	validation_1-rmse:2.92577
# [5]	validation_0-rmse:2.73070	validation_1-rmse:2.66109
# [6]	validation_0-rmse:2.49629	validation_1-rmse:2.42145
# [7]	validation_0-rmse:2.28311	validation_1-rmse:2.22408
# [8]	validation_0-rmse:2.08234	validation_1-rmse:2.02218
# [9]	validation_0-rmse:1.91653	validation_1-rmse:1.85008
# [10]	validation_0-rmse:1.75105	validation_1-rmse:1.68967
# [11]	validation_0-rmse:1.60085	validation_1-rmse:1.54892
# [12]	validation_0-rmse:1.46910	validation_1-rmse:1.42578
# [13]	validation_0-rmse:1.33964	validation_1-rmse:1.30805
# [14]	validation_0-rmse:1.24504	validation_1-rmse:1.21468
# [15]	validation_0-rmse:1.14329	validation_1-rmse:1.12384
# [16]	validation_0-rmse:1.05458	validation_1-rmse:1.06038
# [17]	validation_0-rmse:0.97340	validation_1-rmse:0.99421
# [18]	validation_0-rmse:0.90489	validation_1-rmse:0.93766
# [19]	validation_0-rmse:0.83485	validation_1-rmse:0.88683
# [20]	validation_0-rmse:0.77380	validation_1-rmse:0.84034
# [21]	validation_0-rmse:0.72404	validation_1-rmse:0.79956
# [22]	validation_0-rmse:0.67133	validation_1-rmse:0.76272
# [23]	validation_0-rmse:0.62279	validation_1-rmse:0.72737
# [24]	validation_0-rmse:0.57560	validation_1-rmse:0.69562
# [25]	validation_0-rmse:0.53887	validation_1-rmse:0.67711
# [26]	validation_0-rmse:0.51433	validation_1-rmse:0.66154
# [27]	validation_0-rmse:0.48469	validation_1-rmse:0.64421
# [28]	validation_0-rmse:0.46077	validation_1-rmse:0.63064
# [29]	validation_0-rmse:0.44007	validation_1-rmse:0.61882
# [30]	validation_0-rmse:0.41737	validation_1-rmse:0.60880
# [31]	validation_0-rmse:0.39596	validation_1-rmse:0.59969
# [32]	validation_0-rmse:0.38231	validation_1-rmse:0.59504
# [33]	validation_0-rmse:0.36327	validation_1-rmse:0.58799
# [34]	validation_0-rmse:0.35082	validation_1-rmse:0.58357
# [35]	validation_0-rmse:0.33812	validation_1-rmse:0.57017
# [36]	validation_0-rmse:0.32781	validation_1-rmse:0.57041
# [37]	validation_0-rmse:0.31862	validation_1-rmse:0.56836
# [38]	validation_0-rmse:0.30999	validation_1-rmse:0.56567
# [39]	validation_0-rmse:0.30180	validation_1-rmse:0.56320
# [40]	validation_0-rmse:0.29427	validation_1-rmse:0.56347
# [41]	validation_0-rmse:0.28799	validation_1-rmse:0.56896
# [42]	validation_0-rmse:0.28299	validation_1-rmse:0.56820
# [43]	validation_0-rmse:0.28157	validation_1-rmse:0.56829
# [44]	validation_0-rmse:0.27685	validation_1-rmse:0.56651
# [45]	validation_0-rmse:0.27249	validation_1-rmse:0.56297
# [46]	validation_0-rmse:0.26555	validation_1-rmse:0.56442
# [47]	validation_0-rmse:0.26280	validation_1-rmse:0.56118
# [48]	validation_0-rmse:0.25981	validation_1-rmse:0.56000
# [49]	validation_0-rmse:0.26018	validation_1-rmse:0.55701
# [50]	validation_0-rmse:0.25643	validation_1-rmse:0.55665
# [51]	validation_0-rmse:0.25406	validation_1-rmse:0.55513
# [52]	validation_0-rmse:0.25319	validation_1-rmse:0.55540
# [53]	validation_0-rmse:0.25235	validation_1-rmse:0.55360
# [54]	validation_0-rmse:0.25193	validation_1-rmse:0.55370
# [55]	validation_0-rmse:0.25081	validation_1-rmse:0.55405
# [56]	validation_0-rmse:0.25028	validation_1-rmse:0.55468
# [57]	validation_0-rmse:0.24805	validation_1-rmse:0.55541
# [58]	validation_0-rmse:0.24790	validation_1-rmse:0.55667
# [59]	validation_0-rmse:0.24662	validation_1-rmse:0.55522
# [60]	validation_0-rmse:0.24556	validation_1-rmse:0.55535
# [61]	validation_0-rmse:0.24455	validation_1-rmse:0.55456
# [62]	validation_0-rmse:0.24442	validation_1-rmse:0.55470
# [63]	validation_0-rmse:0.24415	validation_1-rmse:0.55506
# [64]	validation_0-rmse:0.24247	validation_1-rmse:0.56000
# [0]	validation_0-rmse:4.27944	validation_1-rmse:4.14725
# [1]	validation_0-rmse:3.90334	validation_1-rmse:3.76728
# [2]	validation_0-rmse:3.56845	validation_1-rmse:3.42495
# [3]	validation_0-rmse:3.25789	validation_1-rmse:3.12339
# [4]	validation_0-rmse:2.97939	validation_1-rmse:2.84737
# [5]	validation_0-rmse:2.72071	validation_1-rmse:2.58721
# [6]	validation_0-rmse:2.49656	validation_1-rmse:2.36313
# [7]	validation_0-rmse:2.27623	validation_1-rmse:2.15016
# [8]	validation_0-rmse:2.08141	validation_1-rmse:1.94854
# [9]	validation_0-rmse:1.91315	validation_1-rmse:1.78283
# [10]	validation_0-rmse:1.74633	validation_1-rmse:1.62565
# [11]	validation_0-rmse:1.60649	validation_1-rmse:1.49531
# [12]	validation_0-rmse:1.46919	validation_1-rmse:1.36153
# [13]	validation_0-rmse:1.34340	validation_1-rmse:1.23776
# [14]	validation_0-rmse:1.23394	validation_1-rmse:1.13560
# [15]	validation_0-rmse:1.13537	validation_1-rmse:1.03245
# [16]	validation_0-rmse:1.06017	validation_1-rmse:0.96139
# [17]	validation_0-rmse:0.97734	validation_1-rmse:0.88219
# [18]	validation_0-rmse:0.90114	validation_1-rmse:0.80902
# [19]	validation_0-rmse:0.83508	validation_1-rmse:0.74555
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [20]	validation_0-rmse:0.77264	validation_1-rmse:0.68601
# [21]	validation_0-rmse:0.71506	validation_1-rmse:0.62959
# [22]	validation_0-rmse:0.67036	validation_1-rmse:0.59119
# [23]	validation_0-rmse:0.62542	validation_1-rmse:0.55158
# [24]	validation_0-rmse:0.59050	validation_1-rmse:0.52528
# [25]	validation_0-rmse:0.56014	validation_1-rmse:0.50346
# [26]	validation_0-rmse:0.52958	validation_1-rmse:0.48686
# [27]	validation_0-rmse:0.50133	validation_1-rmse:0.47561
# [28]	validation_0-rmse:0.47434	validation_1-rmse:0.46568
# [29]	validation_0-rmse:0.45143	validation_1-rmse:0.45196
# [30]	validation_0-rmse:0.43671	validation_1-rmse:0.44089
# [31]	validation_0-rmse:0.41848	validation_1-rmse:0.43463
# [32]	validation_0-rmse:0.40429	validation_1-rmse:0.43688
# [33]	validation_0-rmse:0.38390	validation_1-rmse:0.43727
# [34]	validation_0-rmse:0.37499	validation_1-rmse:0.43501
# [35]	validation_0-rmse:0.36597	validation_1-rmse:0.43736
# [36]	validation_0-rmse:0.35900	validation_1-rmse:0.43529
# [37]	validation_0-rmse:0.34779	validation_1-rmse:0.42889
# [38]	validation_0-rmse:0.33427	validation_1-rmse:0.41930
# [39]	validation_0-rmse:0.32505	validation_1-rmse:0.41339
# [40]	validation_0-rmse:0.31651	validation_1-rmse:0.41066
# [41]	validation_0-rmse:0.31190	validation_1-rmse:0.40868
# [42]	validation_0-rmse:0.30235	validation_1-rmse:0.41701
# [43]	validation_0-rmse:0.29497	validation_1-rmse:0.41925
# [44]	validation_0-rmse:0.29223	validation_1-rmse:0.42240
# [45]	validation_0-rmse:0.28672	validation_1-rmse:0.43104
# [46]	validation_0-rmse:0.28257	validation_1-rmse:0.42585
# [47]	validation_0-rmse:0.28019	validation_1-rmse:0.42588
# [48]	validation_0-rmse:0.27552	validation_1-rmse:0.42087
# [49]	validation_0-rmse:0.27202	validation_1-rmse:0.42034
# [50]	validation_0-rmse:0.26709	validation_1-rmse:0.42034
# [51]	validation_0-rmse:0.26451	validation_1-rmse:0.42055
# [52]	validation_0-rmse:0.26346	validation_1-rmse:0.42026
# [53]	validation_0-rmse:0.25965	validation_1-rmse:0.42493
# [54]	validation_0-rmse:0.25821	validation_1-rmse:0.42271
# [55]	validation_0-rmse:0.25685	validation_1-rmse:0.42235
# [56]	validation_0-rmse:0.25572	validation_1-rmse:0.41828
# [57]	validation_0-rmse:0.25352	validation_1-rmse:0.41505
# [58]	validation_0-rmse:0.25177	validation_1-rmse:0.41713
# [59]	validation_0-rmse:0.25167	validation_1-rmse:0.41714
# [60]	validation_0-rmse:0.24987	validation_1-rmse:0.41923
# [0]	validation_0-rmse:4.29988	validation_1-rmse:4.11485
# [1]	validation_0-rmse:3.93897	validation_1-rmse:3.77556
# [2]	validation_0-rmse:3.57250	validation_1-rmse:3.42923
# [3]	validation_0-rmse:3.25357	validation_1-rmse:3.13855
# [4]	validation_0-rmse:2.97213	validation_1-rmse:2.86965
# [5]	validation_0-rmse:2.72848	validation_1-rmse:2.62931
# [6]	validation_0-rmse:2.50496	validation_1-rmse:2.41755
# [7]	validation_0-rmse:2.30781	validation_1-rmse:2.23560
# [8]	validation_0-rmse:2.11939	validation_1-rmse:2.06055
# [9]	validation_0-rmse:1.94400	validation_1-rmse:1.90663
# [10]	validation_0-rmse:1.78300	validation_1-rmse:1.75947
# [11]	validation_0-rmse:1.64282	validation_1-rmse:1.62428
# [12]	validation_0-rmse:1.51398	validation_1-rmse:1.50700
# [13]	validation_0-rmse:1.39006	validation_1-rmse:1.38977
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [14]	validation_0-rmse:1.28492	validation_1-rmse:1.28702
# [15]	validation_0-rmse:1.17604	validation_1-rmse:1.18290
# [16]	validation_0-rmse:1.07441	validation_1-rmse:1.08779
# [17]	validation_0-rmse:0.98589	validation_1-rmse:1.00755
# [18]	validation_0-rmse:0.91074	validation_1-rmse:0.93822
# [19]	validation_0-rmse:0.84655	validation_1-rmse:0.88507
# [20]	validation_0-rmse:0.78690	validation_1-rmse:0.83025
# [21]	validation_0-rmse:0.73387	validation_1-rmse:0.78295
# [22]	validation_0-rmse:0.68361	validation_1-rmse:0.73961
# [23]	validation_0-rmse:0.63877	validation_1-rmse:0.70002
# [24]	validation_0-rmse:0.59919	validation_1-rmse:0.66599
# [25]	validation_0-rmse:0.56511	validation_1-rmse:0.63883
# [26]	validation_0-rmse:0.52849	validation_1-rmse:0.61110
# [27]	validation_0-rmse:0.49965	validation_1-rmse:0.59111
# [28]	validation_0-rmse:0.47374	validation_1-rmse:0.57705
# [29]	validation_0-rmse:0.44653	validation_1-rmse:0.56307
# [30]	validation_0-rmse:0.42689	validation_1-rmse:0.54922
# [31]	validation_0-rmse:0.40608	validation_1-rmse:0.53748
# [32]	validation_0-rmse:0.39014	validation_1-rmse:0.52382
# [33]	validation_0-rmse:0.37216	validation_1-rmse:0.51816
# [34]	validation_0-rmse:0.36103	validation_1-rmse:0.51053
# [35]	validation_0-rmse:0.34780	validation_1-rmse:0.49492
# [36]	validation_0-rmse:0.33884	validation_1-rmse:0.48823
# [37]	validation_0-rmse:0.32786	validation_1-rmse:0.48266
# [38]	validation_0-rmse:0.32236	validation_1-rmse:0.48162
# [39]	validation_0-rmse:0.31528	validation_1-rmse:0.47608
# [40]	validation_0-rmse:0.31116	validation_1-rmse:0.46683
# [41]	validation_0-rmse:0.30079	validation_1-rmse:0.47130
# [42]	validation_0-rmse:0.29528	validation_1-rmse:0.46023
# [43]	validation_0-rmse:0.29203	validation_1-rmse:0.45779
# [44]	validation_0-rmse:0.28532	validation_1-rmse:0.46304
# [45]	validation_0-rmse:0.28174	validation_1-rmse:0.46099
# [46]	validation_0-rmse:0.27648	validation_1-rmse:0.46020
# [47]	validation_0-rmse:0.27227	validation_1-rmse:0.46470
# [48]	validation_0-rmse:0.26900	validation_1-rmse:0.46489
# [49]	validation_0-rmse:0.26587	validation_1-rmse:0.46854
# [50]	validation_0-rmse:0.26495	validation_1-rmse:0.46929
# [51]	validation_0-rmse:0.26434	validation_1-rmse:0.46990
# [52]	validation_0-rmse:0.26336	validation_1-rmse:0.47119
# [53]	validation_0-rmse:0.26375	validation_1-rmse:0.47061
# [54]	validation_0-rmse:0.26141	validation_1-rmse:0.47553
# [55]	validation_0-rmse:0.25903	validation_1-rmse:0.48094
# [56]	validation_0-rmse:0.25856	validation_1-rmse:0.48604
# [57]	validation_0-rmse:0.25758	validation_1-rmse:0.49161
# [58]	validation_0-rmse:0.25633	validation_1-rmse:0.49557
# [59]	validation_0-rmse:0.25603	validation_1-rmse:0.49899
# [60]	validation_0-rmse:0.25595	validation_1-rmse:0.49938
# [61]	validation_0-rmse:0.25387	validation_1-rmse:0.50419
# [62]	validation_0-rmse:0.25249	validation_1-rmse:0.50290
# [0]	validation_0-rmse:4.25388	validation_1-rmse:4.31156
# [1]	validation_0-rmse:3.90092	validation_1-rmse:3.95629
# [2]	validation_0-rmse:3.57259	validation_1-rmse:3.61254
# [3]	validation_0-rmse:3.26870	validation_1-rmse:3.30031
# [4]	validation_0-rmse:2.99495	validation_1-rmse:3.01516
# [5]	validation_0-rmse:2.73893	validation_1-rmse:2.75023
# [6]	validation_0-rmse:2.50895	validation_1-rmse:2.51925
# [7]	validation_0-rmse:2.30842	validation_1-rmse:2.31511
# [8]	validation_0-rmse:2.08868	validation_1-rmse:2.09425
# [9]	validation_0-rmse:1.91946	validation_1-rmse:1.92694
# [10]	validation_0-rmse:1.76309	validation_1-rmse:1.76613
# [11]	validation_0-rmse:1.62363	validation_1-rmse:1.62804
# [12]	validation_0-rmse:1.48332	validation_1-rmse:1.47531
# [13]	validation_0-rmse:1.36638	validation_1-rmse:1.35012
# [14]	validation_0-rmse:1.24640	validation_1-rmse:1.23094
# [15]	validation_0-rmse:1.13900	validation_1-rmse:1.12120
# [16]	validation_0-rmse:1.05021	validation_1-rmse:1.03322
# [17]	validation_0-rmse:0.96672	validation_1-rmse:0.95570
# [18]	validation_0-rmse:0.89865	validation_1-rmse:0.90150
# [19]	validation_0-rmse:0.83237	validation_1-rmse:0.83245
# [20]	validation_0-rmse:0.76919	validation_1-rmse:0.77188
# [21]	validation_0-rmse:0.70812	validation_1-rmse:0.71727
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [22]	validation_0-rmse:0.65357	validation_1-rmse:0.67102
# [23]	validation_0-rmse:0.60305	validation_1-rmse:0.63527
# [24]	validation_0-rmse:0.56631	validation_1-rmse:0.60249
# [25]	validation_0-rmse:0.52921	validation_1-rmse:0.56717
# [26]	validation_0-rmse:0.50322	validation_1-rmse:0.55324
# [27]	validation_0-rmse:0.47259	validation_1-rmse:0.52737
# [28]	validation_0-rmse:0.45164	validation_1-rmse:0.50837
# [29]	validation_0-rmse:0.43057	validation_1-rmse:0.49418
# [30]	validation_0-rmse:0.41795	validation_1-rmse:0.48278
# [31]	validation_0-rmse:0.40120	validation_1-rmse:0.47145
# [32]	validation_0-rmse:0.39086	validation_1-rmse:0.46350
# [33]	validation_0-rmse:0.37871	validation_1-rmse:0.45626
# [34]	validation_0-rmse:0.36879	validation_1-rmse:0.45216
# [35]	validation_0-rmse:0.35827	validation_1-rmse:0.44683
# [36]	validation_0-rmse:0.34890	validation_1-rmse:0.43939
# [37]	validation_0-rmse:0.33911	validation_1-rmse:0.43603
# [38]	validation_0-rmse:0.33351	validation_1-rmse:0.42793
# [39]	validation_0-rmse:0.32516	validation_1-rmse:0.42078
# [40]	validation_0-rmse:0.32009	validation_1-rmse:0.41574
# [41]	validation_0-rmse:0.31226	validation_1-rmse:0.41659
# [42]	validation_0-rmse:0.30519	validation_1-rmse:0.41056
# [43]	validation_0-rmse:0.30120	validation_1-rmse:0.40499
# [44]	validation_0-rmse:0.29920	validation_1-rmse:0.40281
# [45]	validation_0-rmse:0.29784	validation_1-rmse:0.40619
# [46]	validation_0-rmse:0.29409	validation_1-rmse:0.40460
# [47]	validation_0-rmse:0.29140	validation_1-rmse:0.40375
# [48]	validation_0-rmse:0.28648	validation_1-rmse:0.39583
# [49]	validation_0-rmse:0.28208	validation_1-rmse:0.39664
# [50]	validation_0-rmse:0.28119	validation_1-rmse:0.39637
# [51]	validation_0-rmse:0.27752	validation_1-rmse:0.39617
# [52]	validation_0-rmse:0.27521	validation_1-rmse:0.39256
# [53]	validation_0-rmse:0.27377	validation_1-rmse:0.38963
# [54]	validation_0-rmse:0.27313	validation_1-rmse:0.38965
# [55]	validation_0-rmse:0.27300	validation_1-rmse:0.38968
# [56]	validation_0-rmse:0.27066	validation_1-rmse:0.38581
# [57]	validation_0-rmse:0.27043	validation_1-rmse:0.38602
# [58]	validation_0-rmse:0.26656	validation_1-rmse:0.38780
# [59]	validation_0-rmse:0.26453	validation_1-rmse:0.38829
# [60]	validation_0-rmse:0.26453	validation_1-rmse:0.38841
# [61]	validation_0-rmse:0.26455	validation_1-rmse:0.38816
# [62]	validation_0-rmse:0.26318	validation_1-rmse:0.38830
# [63]	validation_0-rmse:0.26318	validation_1-rmse:0.38827
# [64]	validation_0-rmse:0.26129	validation_1-rmse:0.38462
# [0]	validation_0-rmse:4.26572	validation_1-rmse:4.20920
# [1]	validation_0-rmse:3.89988	validation_1-rmse:3.83962
# [2]	validation_0-rmse:3.56284	validation_1-rmse:3.50366
# [3]	validation_0-rmse:3.24681	validation_1-rmse:3.18853
# [4]	validation_0-rmse:2.97602	validation_1-rmse:2.90538
# [5]	validation_0-rmse:2.72507	validation_1-rmse:2.65656
# [6]	validation_0-rmse:2.49481	validation_1-rmse:2.43270
# [7]	validation_0-rmse:2.29119	validation_1-rmse:2.23252
# [8]	validation_0-rmse:2.08975	validation_1-rmse:2.02223
# [9]	validation_0-rmse:1.92603	validation_1-rmse:1.86062
# [10]	validation_0-rmse:1.77898	validation_1-rmse:1.71443
# [11]	validation_0-rmse:1.63508	validation_1-rmse:1.56510
# [12]	validation_0-rmse:1.50780	validation_1-rmse:1.43861
# [13]	validation_0-rmse:1.38902	validation_1-rmse:1.32204
# [14]	validation_0-rmse:1.27090	validation_1-rmse:1.20483
# [15]	validation_0-rmse:1.17266	validation_1-rmse:1.10926
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [16]	validation_0-rmse:1.07656	validation_1-rmse:1.01176
# [17]	validation_0-rmse:0.98750	validation_1-rmse:0.92682
# [18]	validation_0-rmse:0.91571	validation_1-rmse:0.85253
# [19]	validation_0-rmse:0.85320	validation_1-rmse:0.79579
# [20]	validation_0-rmse:0.79129	validation_1-rmse:0.73799
# [21]	validation_0-rmse:0.73564	validation_1-rmse:0.68603
# [22]	validation_0-rmse:0.69178	validation_1-rmse:0.64116
# [23]	validation_0-rmse:0.64881	validation_1-rmse:0.60823
# [24]	validation_0-rmse:0.60812	validation_1-rmse:0.56896
# [25]	validation_0-rmse:0.57233	validation_1-rmse:0.53590
# [26]	validation_0-rmse:0.53378	validation_1-rmse:0.49867
# [27]	validation_0-rmse:0.50123	validation_1-rmse:0.47085
# [28]	validation_0-rmse:0.48036	validation_1-rmse:0.45382
# [29]	validation_0-rmse:0.45773	validation_1-rmse:0.43705
# [30]	validation_0-rmse:0.44396	validation_1-rmse:0.42334
# [31]	validation_0-rmse:0.42222	validation_1-rmse:0.40599
# [32]	validation_0-rmse:0.40228	validation_1-rmse:0.39289
# [33]	validation_0-rmse:0.38392	validation_1-rmse:0.37970
# [34]	validation_0-rmse:0.37279	validation_1-rmse:0.36668
# [35]	validation_0-rmse:0.35948	validation_1-rmse:0.36086
# [36]	validation_0-rmse:0.35077	validation_1-rmse:0.35558
# [37]	validation_0-rmse:0.34398	validation_1-rmse:0.35308
# [38]	validation_0-rmse:0.33525	validation_1-rmse:0.35691
# [39]	validation_0-rmse:0.32599	validation_1-rmse:0.35368
# [40]	validation_0-rmse:0.31965	validation_1-rmse:0.34522
# [41]	validation_0-rmse:0.31406	validation_1-rmse:0.34572
# [42]	validation_0-rmse:0.31059	validation_1-rmse:0.34589
# [43]	validation_0-rmse:0.30690	validation_1-rmse:0.34622
# [44]	validation_0-rmse:0.30549	validation_1-rmse:0.34608
# [45]	validation_0-rmse:0.30206	validation_1-rmse:0.34469
# [46]	validation_0-rmse:0.29822	validation_1-rmse:0.34511
# [47]	validation_0-rmse:0.29556	validation_1-rmse:0.34577
# [48]	validation_0-rmse:0.29190	validation_1-rmse:0.34700
# [49]	validation_0-rmse:0.28910	validation_1-rmse:0.34477
# [50]	validation_0-rmse:0.28628	validation_1-rmse:0.34603
# [51]	validation_0-rmse:0.28257	validation_1-rmse:0.34356
# [52]	validation_0-rmse:0.27971	validation_1-rmse:0.34704
# [53]	validation_0-rmse:0.27602	validation_1-rmse:0.34700
# [54]	validation_0-rmse:0.27594	validation_1-rmse:0.34725
# [55]	validation_0-rmse:0.27356	validation_1-rmse:0.34784
# [56]	validation_0-rmse:0.26939	validation_1-rmse:0.34801
# [57]	validation_0-rmse:0.26527	validation_1-rmse:0.35203
# [58]	validation_0-rmse:0.26177	validation_1-rmse:0.35259
# [59]	validation_0-rmse:0.25817	validation_1-rmse:0.35459
# [60]	validation_0-rmse:0.25573	validation_1-rmse:0.35366
# [61]	validation_0-rmse:0.25497	validation_1-rmse:0.35537
# [62]	validation_0-rmse:0.25236	validation_1-rmse:0.35682
# [63]	validation_0-rmse:0.25189	validation_1-rmse:0.35699
# [64]	validation_0-rmse:0.25041	validation_1-rmse:0.35998
# [0]	validation_0-rmse:4.23075	validation_1-rmse:4.33739
# [1]	validation_0-rmse:3.85688	validation_1-rmse:3.96941
# [2]	validation_0-rmse:3.51755	validation_1-rmse:3.60979
# [3]	validation_0-rmse:3.22698	validation_1-rmse:3.31037
# [4]	validation_0-rmse:2.95481	validation_1-rmse:3.01820
# [5]	validation_0-rmse:2.69699	validation_1-rmse:2.74646
# [6]	validation_0-rmse:2.46623	validation_1-rmse:2.51572
# [7]	validation_0-rmse:2.25575	validation_1-rmse:2.29603
# [8]	validation_0-rmse:2.06582	validation_1-rmse:2.10444
# [9]	validation_0-rmse:1.88908	validation_1-rmse:1.92095
# [10]	validation_0-rmse:1.73387	validation_1-rmse:1.76000
# [11]	validation_0-rmse:1.59345	validation_1-rmse:1.60583
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [12]	validation_0-rmse:1.46046	validation_1-rmse:1.46282
# [13]	validation_0-rmse:1.33928	validation_1-rmse:1.33707
# [14]	validation_0-rmse:1.23777	validation_1-rmse:1.23236
# [15]	validation_0-rmse:1.14582	validation_1-rmse:1.14039
# [16]	validation_0-rmse:1.06109	validation_1-rmse:1.05298
# [17]	validation_0-rmse:0.97323	validation_1-rmse:0.95728
# [18]	validation_0-rmse:0.91064	validation_1-rmse:0.89384
# [19]	validation_0-rmse:0.84449	validation_1-rmse:0.82166
# [20]	validation_0-rmse:0.78673	validation_1-rmse:0.76147
# [21]	validation_0-rmse:0.73322	validation_1-rmse:0.70595
# [22]	validation_0-rmse:0.68604	validation_1-rmse:0.65197
# [23]	validation_0-rmse:0.63715	validation_1-rmse:0.60038
# [24]	validation_0-rmse:0.59711	validation_1-rmse:0.55558
# [25]	validation_0-rmse:0.56317	validation_1-rmse:0.51824
# [26]	validation_0-rmse:0.53468	validation_1-rmse:0.49235
# [27]	validation_0-rmse:0.50720	validation_1-rmse:0.46504
# [28]	validation_0-rmse:0.48144	validation_1-rmse:0.43628
# [29]	validation_0-rmse:0.45641	validation_1-rmse:0.41859
# [30]	validation_0-rmse:0.43257	validation_1-rmse:0.39309
# [31]	validation_0-rmse:0.41995	validation_1-rmse:0.37761
# [32]	validation_0-rmse:0.41036	validation_1-rmse:0.36514
# [33]	validation_0-rmse:0.39680	validation_1-rmse:0.35684
# [34]	validation_0-rmse:0.38393	validation_1-rmse:0.33816
# [35]	validation_0-rmse:0.37181	validation_1-rmse:0.32649
# [36]	validation_0-rmse:0.36830	validation_1-rmse:0.32260
# [37]	validation_0-rmse:0.35969	validation_1-rmse:0.31359
# [38]	validation_0-rmse:0.35179	validation_1-rmse:0.30983
# [39]	validation_0-rmse:0.34446	validation_1-rmse:0.30182
# [40]	validation_0-rmse:0.34158	validation_1-rmse:0.30478
# [41]	validation_0-rmse:0.33643	validation_1-rmse:0.30838
# [42]	validation_0-rmse:0.32795	validation_1-rmse:0.30342
# [43]	validation_0-rmse:0.32557	validation_1-rmse:0.30003
# [44]	validation_0-rmse:0.32013	validation_1-rmse:0.29528
# [45]	validation_0-rmse:0.31586	validation_1-rmse:0.28999
# [46]	validation_0-rmse:0.31145	validation_1-rmse:0.28356
# [47]	validation_0-rmse:0.30843	validation_1-rmse:0.28314
# [48]	validation_0-rmse:0.30507	validation_1-rmse:0.27939
# [49]	validation_0-rmse:0.30325	validation_1-rmse:0.27764
# [50]	validation_0-rmse:0.30205	validation_1-rmse:0.27579
# [51]	validation_0-rmse:0.29898	validation_1-rmse:0.27584
# [52]	validation_0-rmse:0.29937	validation_1-rmse:0.27399
# [53]	validation_0-rmse:0.29918	validation_1-rmse:0.27305
# [54]	validation_0-rmse:0.29653	validation_1-rmse:0.27147
# [55]	validation_0-rmse:0.29575	validation_1-rmse:0.27339
# [56]	validation_0-rmse:0.29050	validation_1-rmse:0.27649
# [57]	validation_0-rmse:0.28655	validation_1-rmse:0.28204
# [58]	validation_0-rmse:0.28481	validation_1-rmse:0.28117
# [59]	validation_0-rmse:0.28346	validation_1-rmse:0.27602
# [60]	validation_0-rmse:0.28084	validation_1-rmse:0.27560
# [61]	validation_0-rmse:0.27821	validation_1-rmse:0.27323
# [62]	validation_0-rmse:0.27439	validation_1-rmse:0.27914
# [63]	validation_0-rmse:0.27177	validation_1-rmse:0.27455
# [64]	validation_0-rmse:0.27156	validation_1-rmse:0.27457
# [0]	validation_0-rmse:4.23794	validation_1-rmse:4.38488
# [1]	validation_0-rmse:3.86962	validation_1-rmse:4.00069
# [2]	validation_0-rmse:3.54088	validation_1-rmse:3.65295
# [3]	validation_0-rmse:3.23018	validation_1-rmse:3.32973
# [4]	validation_0-rmse:2.95686	validation_1-rmse:3.04761
# [5]	validation_0-rmse:2.70400	validation_1-rmse:2.77874
# [6]	validation_0-rmse:2.50969	validation_1-rmse:2.57011
# [7]	validation_0-rmse:2.28884	validation_1-rmse:2.33918
# [8]	validation_0-rmse:2.09899	validation_1-rmse:2.13283
# [9]	validation_0-rmse:1.92869	validation_1-rmse:1.94088
# [10]	validation_0-rmse:1.78107	validation_1-rmse:1.78715
# [11]	validation_0-rmse:1.63022	validation_1-rmse:1.62884
# [12]	validation_0-rmse:1.49484	validation_1-rmse:1.49310
# [13]	validation_0-rmse:1.37681	validation_1-rmse:1.38048
# [14]	validation_0-rmse:1.27214	validation_1-rmse:1.26289
# [15]	validation_0-rmse:1.17927	validation_1-rmse:1.15947
# [16]	validation_0-rmse:1.08657	validation_1-rmse:1.06196
# [17]	validation_0-rmse:1.00447	validation_1-rmse:0.97092
# [18]	validation_0-rmse:0.92797	validation_1-rmse:0.88531
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [19]	validation_0-rmse:0.86429	validation_1-rmse:0.80774
# [20]	validation_0-rmse:0.79525	validation_1-rmse:0.73279
# [21]	validation_0-rmse:0.74554	validation_1-rmse:0.67666
# [22]	validation_0-rmse:0.69251	validation_1-rmse:0.61686
# [23]	validation_0-rmse:0.65139	validation_1-rmse:0.57283
# [24]	validation_0-rmse:0.60884	validation_1-rmse:0.52592
# [25]	validation_0-rmse:0.57419	validation_1-rmse:0.49316
# [26]	validation_0-rmse:0.54799	validation_1-rmse:0.46413
# [27]	validation_0-rmse:0.52445	validation_1-rmse:0.44534
# [28]	validation_0-rmse:0.50242	validation_1-rmse:0.42261
# [29]	validation_0-rmse:0.47158	validation_1-rmse:0.38841
# [30]	validation_0-rmse:0.45640	validation_1-rmse:0.38087
# [31]	validation_0-rmse:0.44042	validation_1-rmse:0.36658
# [32]	validation_0-rmse:0.43134	validation_1-rmse:0.35528
# [33]	validation_0-rmse:0.41540	validation_1-rmse:0.33797
# [34]	validation_0-rmse:0.40115	validation_1-rmse:0.32436
# [35]	validation_0-rmse:0.39239	validation_1-rmse:0.31580
# [36]	validation_0-rmse:0.38210	validation_1-rmse:0.31264
# [37]	validation_0-rmse:0.37663	validation_1-rmse:0.29851
# [38]	validation_0-rmse:0.36535	validation_1-rmse:0.28752
# [39]	validation_0-rmse:0.35752	validation_1-rmse:0.28159
# [40]	validation_0-rmse:0.35296	validation_1-rmse:0.27864
# [41]	validation_0-rmse:0.34466	validation_1-rmse:0.27222
# [42]	validation_0-rmse:0.34164	validation_1-rmse:0.27441
# [43]	validation_0-rmse:0.33697	validation_1-rmse:0.26919
# [44]	validation_0-rmse:0.33121	validation_1-rmse:0.26595
# ...
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [13]	validation_0-rmse:1.37267	validation_1-rmse:1.38349
# [14]	validation_0-rmse:1.26154	validation_1-rmse:1.27565
# [15]	validation_0-rmse:1.15822	validation_1-rmse:1.16025
# [16]	validation_0-rmse:1.06704	validation_1-rmse:1.07051
# [17]	validation_0-rmse:0.98194	validation_1-rmse:0.97823
# [18]	validation_0-rmse:0.91327	validation_1-rmse:0.91326
# [19]	validation_0-rmse:0.85073	validation_1-rmse:0.83899
# [20]	validation_0-rmse:0.78651	validation_1-rmse:0.77170
# [21]	validation_0-rmse:0.72923	validation_1-rmse:0.72558
# [22]	validation_0-rmse:0.68456	validation_1-rmse:0.67368
# [23]	validation_0-rmse:0.64107	validation_1-rmse:0.63719
# [24]	validation_0-rmse:0.59889	validation_1-rmse:0.59853
# [25]	validation_0-rmse:0.56242	validation_1-rmse:0.55837
# [26]	validation_0-rmse:0.52806	validation_1-rmse:0.52287
# [27]	validation_0-rmse:0.50018	validation_1-rmse:0.49711
# [28]	validation_0-rmse:0.47781	validation_1-rmse:0.48090
# [29]	validation_0-rmse:0.45767	validation_1-rmse:0.46668
# [30]	validation_0-rmse:0.43772	validation_1-rmse:0.44751
# [31]	validation_0-rmse:0.41715	validation_1-rmse:0.42729
# [32]	validation_0-rmse:0.40444	validation_1-rmse:0.41309
# [33]	validation_0-rmse:0.39130	validation_1-rmse:0.39660
# [34]	validation_0-rmse:0.37624	validation_1-rmse:0.38443
# [35]	validation_0-rmse:0.36256	validation_1-rmse:0.37227
# [36]	validation_0-rmse:0.35386	validation_1-rmse:0.36607
# [37]	validation_0-rmse:0.34435	validation_1-rmse:0.35939
# [38]	validation_0-rmse:0.33824	validation_1-rmse:0.35137
# [39]	validation_0-rmse:0.33148	validation_1-rmse:0.34600
# [40]	validation_0-rmse:0.32732	validation_1-rmse:0.34183
# [41]	validation_0-rmse:0.32129	validation_1-rmse:0.33151
# [42]	validation_0-rmse:0.31573	validation_1-rmse:0.32539
# [43]	validation_0-rmse:0.31335	validation_1-rmse:0.32912
# [44]	validation_0-rmse:0.31055	validation_1-rmse:0.32317
# [45]	validation_0-rmse:0.30722	validation_1-rmse:0.31998
# [46]	validation_0-rmse:0.30271	validation_1-rmse:0.31950
# [47]	validation_0-rmse:0.29947	validation_1-rmse:0.32483
# [48]	validation_0-rmse:0.29686	validation_1-rmse:0.32012
# [49]	validation_0-rmse:0.29200	validation_1-rmse:0.31316
# [50]	validation_0-rmse:0.29108	validation_1-rmse:0.30714
# [51]	validation_0-rmse:0.28825	validation_1-rmse:0.30467
# [52]	validation_0-rmse:0.28966	validation_1-rmse:0.30815
# [53]	validation_0-rmse:0.28798	validation_1-rmse:0.30548
# [54]	validation_0-rmse:0.28693	validation_1-rmse:0.30484
# [55]	validation_0-rmse:0.28653	validation_1-rmse:0.30825
# [56]	validation_0-rmse:0.28549	validation_1-rmse:0.30576
# [57]	validation_0-rmse:0.28499	validation_1-rmse:0.30931
# [58]	validation_0-rmse:0.28505	validation_1-rmse:0.30586
# [59]	validation_0-rmse:0.28497	validation_1-rmse:0.30481
# [60]	validation_0-rmse:0.28185	validation_1-rmse:0.30391
# [61]	validation_0-rmse:0.28183	validation_1-rmse:0.30318
# [62]	validation_0-rmse:0.28184	validation_1-rmse:0.30214
# [63]	validation_0-rmse:0.27814	validation_1-rmse:0.29740
# [64]	validation_0-rmse:0.27643	validation_1-rmse:0.30447
# [0]	validation_0-rmse:4.25526	validation_1-rmse:4.17434
# [1]	validation_0-rmse:3.87036	validation_1-rmse:3.80259
# [2]	validation_0-rmse:3.53608	validation_1-rmse:3.47971
# [3]	validation_0-rmse:3.23108	validation_1-rmse:3.18286
# [4]	validation_0-rmse:2.94370	validation_1-rmse:2.90030
# [5]	validation_0-rmse:2.68151	validation_1-rmse:2.64334
# [6]	validation_0-rmse:2.44061	validation_1-rmse:2.42367
# [7]	validation_0-rmse:2.23647	validation_1-rmse:2.22033
# [8]	validation_0-rmse:2.04336	validation_1-rmse:2.03029
# [9]	validation_0-rmse:1.87874	validation_1-rmse:1.87657
# [10]	validation_0-rmse:1.72492	validation_1-rmse:1.72487
# [11]	validation_0-rmse:1.58224	validation_1-rmse:1.58885
# [12]	validation_0-rmse:1.44919	validation_1-rmse:1.46677
# [13]	validation_0-rmse:1.32995	validation_1-rmse:1.35304
# [14]	validation_0-rmse:1.20981	validation_1-rmse:1.25495
# [15]	validation_0-rmse:1.10448	validation_1-rmse:1.16203
# [16]	validation_0-rmse:1.01735	validation_1-rmse:1.08580
# [17]	validation_0-rmse:0.93307	validation_1-rmse:1.01225
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [18]	validation_0-rmse:0.86850	validation_1-rmse:0.95568
# [19]	validation_0-rmse:0.80179	validation_1-rmse:0.89852
# [20]	validation_0-rmse:0.74296	validation_1-rmse:0.85538
# [21]	validation_0-rmse:0.69647	validation_1-rmse:0.82641
# [22]	validation_0-rmse:0.64597	validation_1-rmse:0.78896
# [23]	validation_0-rmse:0.60782	validation_1-rmse:0.76221
# [24]	validation_0-rmse:0.56608	validation_1-rmse:0.73105
# [25]	validation_0-rmse:0.52930	validation_1-rmse:0.71174
# [26]	validation_0-rmse:0.49621	validation_1-rmse:0.69086
# [27]	validation_0-rmse:0.46729	validation_1-rmse:0.66097
# [28]	validation_0-rmse:0.44753	validation_1-rmse:0.64968
# [29]	validation_0-rmse:0.43035	validation_1-rmse:0.63948
# [30]	validation_0-rmse:0.41536	validation_1-rmse:0.63133
# [31]	validation_0-rmse:0.40010	validation_1-rmse:0.62782
# [32]	validation_0-rmse:0.38405	validation_1-rmse:0.61961
# [33]	validation_0-rmse:0.36954	validation_1-rmse:0.61104
# [34]	validation_0-rmse:0.35862	validation_1-rmse:0.61582
# [35]	validation_0-rmse:0.34872	validation_1-rmse:0.61083
# [36]	validation_0-rmse:0.33529	validation_1-rmse:0.60979
# [37]	validation_0-rmse:0.32902	validation_1-rmse:0.60367
# [38]	validation_0-rmse:0.31689	validation_1-rmse:0.58395
# [39]	validation_0-rmse:0.31008	validation_1-rmse:0.58339
# [40]	validation_0-rmse:0.30439	validation_1-rmse:0.58576
# [41]	validation_0-rmse:0.29990	validation_1-rmse:0.58538
# [42]	validation_0-rmse:0.29150	validation_1-rmse:0.57648
# [43]	validation_0-rmse:0.28712	validation_1-rmse:0.57768
# [44]	validation_0-rmse:0.28515	validation_1-rmse:0.57762
# [45]	validation_0-rmse:0.28121	validation_1-rmse:0.57590
# [46]	validation_0-rmse:0.27895	validation_1-rmse:0.57720
# [47]	validation_0-rmse:0.27490	validation_1-rmse:0.57427
# [48]	validation_0-rmse:0.27278	validation_1-rmse:0.57266
# [49]	validation_0-rmse:0.27001	validation_1-rmse:0.57824
# [50]	validation_0-rmse:0.26850	validation_1-rmse:0.57659
# [51]	validation_0-rmse:0.26778	validation_1-rmse:0.57311
# [52]	validation_0-rmse:0.26557	validation_1-rmse:0.55802
# [53]	validation_0-rmse:0.26420	validation_1-rmse:0.54940
# [54]	validation_0-rmse:0.26397	validation_1-rmse:0.54966
# [55]	validation_0-rmse:0.26294	validation_1-rmse:0.54855
# [56]	validation_0-rmse:0.26268	validation_1-rmse:0.55485
# [57]	validation_0-rmse:0.26248	validation_1-rmse:0.55514
# [58]	validation_0-rmse:0.26315	validation_1-rmse:0.54777
# [59]	validation_0-rmse:0.26054	validation_1-rmse:0.55102
# [60]	validation_0-rmse:0.25892	validation_1-rmse:0.54958
# [61]	validation_0-rmse:0.25862	validation_1-rmse:0.55011
# [62]	validation_0-rmse:0.25679	validation_1-rmse:0.55065
# [63]	validation_0-rmse:0.25692	validation_1-rmse:0.55032
# [64]	validation_0-rmse:0.25673	validation_1-rmse:0.55088
# [0]	validation_0-rmse:4.25817	validation_1-rmse:4.21736
# [1]	validation_0-rmse:3.89123	validation_1-rmse:3.86706
# [2]	validation_0-rmse:3.55226	validation_1-rmse:3.53186
# [3]	validation_0-rmse:3.25344	validation_1-rmse:3.22272
# [4]	validation_0-rmse:2.99030	validation_1-rmse:2.99427
# [5]	validation_0-rmse:2.74268	validation_1-rmse:2.74934
# [6]	validation_0-rmse:2.51151	validation_1-rmse:2.53410
# [7]	validation_0-rmse:2.28404	validation_1-rmse:2.30090
# [8]	validation_0-rmse:2.07721	validation_1-rmse:2.08579
# [9]	validation_0-rmse:1.90774	validation_1-rmse:1.92972
# [10]	validation_0-rmse:1.75327	validation_1-rmse:1.77596
# [11]	validation_0-rmse:1.62139	validation_1-rmse:1.63752
# [12]	validation_0-rmse:1.47681	validation_1-rmse:1.50628
# [13]	validation_0-rmse:1.35269	validation_1-rmse:1.39535
# [14]	validation_0-rmse:1.25049	validation_1-rmse:1.30777
# [15]	validation_0-rmse:1.15985	validation_1-rmse:1.22064
# [16]	validation_0-rmse:1.07550	validation_1-rmse:1.14419
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [17]	validation_0-rmse:0.99890	validation_1-rmse:1.07890
# [18]	validation_0-rmse:0.93715	validation_1-rmse:1.01241
# [19]	validation_0-rmse:0.85791	validation_1-rmse:0.94509
# [20]	validation_0-rmse:0.79390	validation_1-rmse:0.89074
# [21]	validation_0-rmse:0.74297	validation_1-rmse:0.84097
# [22]	validation_0-rmse:0.69511	validation_1-rmse:0.80370
# [23]	validation_0-rmse:0.65352	validation_1-rmse:0.76176
# [24]	validation_0-rmse:0.61325	validation_1-rmse:0.72209
# [25]	validation_0-rmse:0.57242	validation_1-rmse:0.68551
# [26]	validation_0-rmse:0.54116	validation_1-rmse:0.65156
# [27]	validation_0-rmse:0.51201	validation_1-rmse:0.62377
# [28]	validation_0-rmse:0.48234	validation_1-rmse:0.59494
# [29]	validation_0-rmse:0.45382	validation_1-rmse:0.56888
# [30]	validation_0-rmse:0.42966	validation_1-rmse:0.55388
# [31]	validation_0-rmse:0.41376	validation_1-rmse:0.53689
# [32]	validation_0-rmse:0.40436	validation_1-rmse:0.52425
# [33]	validation_0-rmse:0.38955	validation_1-rmse:0.51304
# [34]	validation_0-rmse:0.37514	validation_1-rmse:0.50705
# [35]	validation_0-rmse:0.36408	validation_1-rmse:0.50201
# [36]	validation_0-rmse:0.34987	validation_1-rmse:0.48625
# [37]	validation_0-rmse:0.34392	validation_1-rmse:0.47647
# [38]	validation_0-rmse:0.33668	validation_1-rmse:0.45841
# [39]	validation_0-rmse:0.32602	validation_1-rmse:0.44698
# [40]	validation_0-rmse:0.31990	validation_1-rmse:0.44234
# [41]	validation_0-rmse:0.31364	validation_1-rmse:0.44476
# [42]	validation_0-rmse:0.30801	validation_1-rmse:0.43424
# [43]	validation_0-rmse:0.30597	validation_1-rmse:0.43006
# [44]	validation_0-rmse:0.30087	validation_1-rmse:0.41940
# [45]	validation_0-rmse:0.29608	validation_1-rmse:0.42436
# [46]	validation_0-rmse:0.28936	validation_1-rmse:0.41790
# [47]	validation_0-rmse:0.28555	validation_1-rmse:0.41205
# [48]	validation_0-rmse:0.28202	validation_1-rmse:0.40437
# [49]	validation_0-rmse:0.28020	validation_1-rmse:0.40946
# [50]	validation_0-rmse:0.27744	validation_1-rmse:0.41501
# [51]	validation_0-rmse:0.27713	validation_1-rmse:0.41754
# [52]	validation_0-rmse:0.27510	validation_1-rmse:0.41482
# [53]	validation_0-rmse:0.27464	validation_1-rmse:0.41334
# [54]	validation_0-rmse:0.27562	validation_1-rmse:0.41652
# [55]	validation_0-rmse:0.27378	validation_1-rmse:0.41719
# [56]	validation_0-rmse:0.27052	validation_1-rmse:0.40999
# [57]	validation_0-rmse:0.26822	validation_1-rmse:0.40634
# [58]	validation_0-rmse:0.26814	validation_1-rmse:0.40489
# [59]	validation_0-rmse:0.26670	validation_1-rmse:0.40450
# [60]	validation_0-rmse:0.26130	validation_1-rmse:0.40676
# [61]	validation_0-rmse:0.25966	validation_1-rmse:0.39669
# [62]	validation_0-rmse:0.25839	validation_1-rmse:0.39109
# [63]	validation_0-rmse:0.25824	validation_1-rmse:0.39474
# [64]	validation_0-rmse:0.25802	validation_1-rmse:0.39319
# [0]	validation_0-rmse:4.31653	validation_1-rmse:4.01763
# [1]	validation_0-rmse:3.92927	validation_1-rmse:3.62929
# [2]	validation_0-rmse:3.57250	validation_1-rmse:3.28099
# [3]	validation_0-rmse:3.26066	validation_1-rmse:2.97478
# [4]	validation_0-rmse:2.98749	validation_1-rmse:2.71029
# [5]	validation_0-rmse:2.72842	validation_1-rmse:2.45326
# [6]	validation_0-rmse:2.49886	validation_1-rmse:2.25915
# [7]	validation_0-rmse:2.28352	validation_1-rmse:2.05108
# [8]	validation_0-rmse:2.08353	validation_1-rmse:1.86974
# [9]	validation_0-rmse:1.91506	validation_1-rmse:1.72244
# [10]	validation_0-rmse:1.75304	validation_1-rmse:1.56536
# [11]	validation_0-rmse:1.60721	validation_1-rmse:1.42074
# [12]	validation_0-rmse:1.46710	validation_1-rmse:1.29066
# [13]	validation_0-rmse:1.34995	validation_1-rmse:1.18020
# [14]	validation_0-rmse:1.24181	validation_1-rmse:1.09410
# [15]	validation_0-rmse:1.13847	validation_1-rmse:1.01164
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [16]	validation_0-rmse:1.04849	validation_1-rmse:0.94087
# [17]	validation_0-rmse:0.96819	validation_1-rmse:0.87783
# [18]	validation_0-rmse:0.90423	validation_1-rmse:0.82884
# [19]	validation_0-rmse:0.83545	validation_1-rmse:0.77706
# [20]	validation_0-rmse:0.77247	validation_1-rmse:0.73429
# [21]	validation_0-rmse:0.72741	validation_1-rmse:0.69353
# [22]	validation_0-rmse:0.67506	validation_1-rmse:0.66216
# [23]	validation_0-rmse:0.63156	validation_1-rmse:0.63519
# [24]	validation_0-rmse:0.59046	validation_1-rmse:0.61211
# [25]	validation_0-rmse:0.56011	validation_1-rmse:0.58992
# [26]	validation_0-rmse:0.53519	validation_1-rmse:0.58457
# [27]	validation_0-rmse:0.50196	validation_1-rmse:0.56147
# [28]	validation_0-rmse:0.48068	validation_1-rmse:0.54785
# [29]	validation_0-rmse:0.45742	validation_1-rmse:0.53844
# [30]	validation_0-rmse:0.43710	validation_1-rmse:0.53111
# [31]	validation_0-rmse:0.41736	validation_1-rmse:0.52607
# [32]	validation_0-rmse:0.40524	validation_1-rmse:0.52149
# [33]	validation_0-rmse:0.38930	validation_1-rmse:0.50720
# [34]	validation_0-rmse:0.37204	validation_1-rmse:0.50227
# [35]	validation_0-rmse:0.35912	validation_1-rmse:0.49192
# [36]	validation_0-rmse:0.34552	validation_1-rmse:0.48618
# [37]	validation_0-rmse:0.33831	validation_1-rmse:0.48425
# [38]	validation_0-rmse:0.32754	validation_1-rmse:0.47854
# [39]	validation_0-rmse:0.31909	validation_1-rmse:0.48210
# [40]	validation_0-rmse:0.31285	validation_1-rmse:0.48416
# [41]	validation_0-rmse:0.30844	validation_1-rmse:0.47970
# [42]	validation_0-rmse:0.30113	validation_1-rmse:0.48442
# [43]	validation_0-rmse:0.30062	validation_1-rmse:0.48465
# [44]	validation_0-rmse:0.29517	validation_1-rmse:0.47891
# [45]	validation_0-rmse:0.29221	validation_1-rmse:0.48596
# [46]	validation_0-rmse:0.29138	validation_1-rmse:0.48683
# [47]	validation_0-rmse:0.28913	validation_1-rmse:0.47884
# [48]	validation_0-rmse:0.28432	validation_1-rmse:0.48494
# [49]	validation_0-rmse:0.27985	validation_1-rmse:0.47510
# [50]	validation_0-rmse:0.27686	validation_1-rmse:0.47609
# [51]	validation_0-rmse:0.27465	validation_1-rmse:0.48053
# [52]	validation_0-rmse:0.27324	validation_1-rmse:0.48489
# [53]	validation_0-rmse:0.27273	validation_1-rmse:0.48503
# [54]	validation_0-rmse:0.27191	validation_1-rmse:0.48535
# [55]	validation_0-rmse:0.26882	validation_1-rmse:0.47493
# [56]	validation_0-rmse:0.26853	validation_1-rmse:0.47514
# [57]	validation_0-rmse:0.26863	validation_1-rmse:0.47506
# [58]	validation_0-rmse:0.26785	validation_1-rmse:0.48190
# [59]	validation_0-rmse:0.26397	validation_1-rmse:0.47382
# [60]	validation_0-rmse:0.25997	validation_1-rmse:0.47110
# [61]	validation_0-rmse:0.25986	validation_1-rmse:0.47126
# [62]	validation_0-rmse:0.25952	validation_1-rmse:0.46920
# [63]	validation_0-rmse:0.25860	validation_1-rmse:0.47568
# [64]	validation_0-rmse:0.25859	validation_1-rmse:0.47572
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 56.48, median: 59.0,
#  pred. interval (P(0.025)-P(0.975)): 39.95-64.0,
#  conf. interval (p-value=0.95): 54.199-61.182
# ***
# Aggregate bias statistic:
#  mean: -0.573, median: -0.36,
#  pred. interval (P(0.025)-P(0.975)): -4.354-3.261,
#  conf. interval (p-value=0.95): -1.249-0.355
# ***
# Aggregate RMSE statistic:
#  mean: 0.42, median: 0.411, pred. interval (P(0.025)-P(0.975)): 0.254-0.616,
#  conf. interval (p-value=0.95): 0.368-0.465
# ***
# Aggregate MSE statistic:
#  mean: 0.187, median: 0.169, pred. interval (P(0.025)-P(0.975)): 0.064-0.379,
#  conf. interval (p-value=0.95): 0.138-0.22
# ***
# Aggregate R^2 statistic:
#  mean: 0.882, median: 0.891, pred. interval (P(0.025)-P(0.975)): 0.773-0.958,
#  conf. interval (p-value=0.95): 0.866-0.909
# ***
# Aggregate bias(%) statistic:
#  mean: -0.108, median: -0.36, pred. interval (P(0.025)-P(0.975)): -0.886-0.677,
#  conf. interval (p-value=0.95): -0.247-0.067
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.085, median: 0.082, pred. interval (P(0.025)-P(0.975)): 0.048-0.142,
#  conf. interval (p-value=0.95): 0.073-0.095
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:4.23909
# [1]	validation_0-rmse:3.87975
# [2]	validation_0-rmse:3.53334
# [3]	validation_0-rmse:3.21809
# [4]	validation_0-rmse:2.93634
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:2.68949
# [6]	validation_0-rmse:2.45295
# [7]	validation_0-rmse:2.24432
# [8]	validation_0-rmse:2.07622
# [9]	validation_0-rmse:1.90839
# [10]	validation_0-rmse:1.74670
# [11]	validation_0-rmse:1.59706
# [12]	validation_0-rmse:1.47235
# [13]	validation_0-rmse:1.35021
# [14]	validation_0-rmse:1.24017
# [15]	validation_0-rmse:1.14167
# [16]	validation_0-rmse:1.04616
# [17]	validation_0-rmse:0.96746
# [18]	validation_0-rmse:0.89492
# [19]	validation_0-rmse:0.83211
# [20]	validation_0-rmse:0.77125
# [21]	validation_0-rmse:0.72767
# [22]	validation_0-rmse:0.67653
# [23]	validation_0-rmse:0.63928
# [24]	validation_0-rmse:0.60215
# [25]	validation_0-rmse:0.56788
# [26]	validation_0-rmse:0.53609
# [27]	validation_0-rmse:0.50588
# [28]	validation_0-rmse:0.48060
# [29]	validation_0-rmse:0.45898
# [30]	validation_0-rmse:0.43636
# [31]	validation_0-rmse:0.41922
# [32]	validation_0-rmse:0.40521
# [33]	validation_0-rmse:0.39518
# [34]	validation_0-rmse:0.38393
# [35]	validation_0-rmse:0.37678
# [36]	validation_0-rmse:0.36649
# [37]	validation_0-rmse:0.35948
# [38]	validation_0-rmse:0.34708
# [39]	validation_0-rmse:0.33829
# [40]	validation_0-rmse:0.33046
# [41]	validation_0-rmse:0.32255
# [42]	validation_0-rmse:0.31803
# [43]	validation_0-rmse:0.31650
# [44]	validation_0-rmse:0.31258
# [45]	validation_0-rmse:0.30842
# [46]	validation_0-rmse:0.30255
# [47]	validation_0-rmse:0.29838
# [48]	validation_0-rmse:0.29400
# [49]	validation_0-rmse:0.29153
# [50]	validation_0-rmse:0.29028
# [51]	validation_0-rmse:0.28774
# [52]	validation_0-rmse:0.28703
# [53]	validation_0-rmse:0.28694
# [54]	validation_0-rmse:0.28700
# [55]	validation_0-rmse:0.28471
# [56]	validation_0-rmse:0.28469
# [57]	validation_0-rmse:0.28283
# [58]	validation_0-rmse:0.28244
# [59]	validation_0-rmse:0.28138
# [60]	validation_0-rmse:0.27978
# [61]	validation_0-rmse:0.27902
# [62]	validation_0-rmse:0.27800
# [63]	validation_0-rmse:0.27793
# [64]	validation_0-rmse:0.27297
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 64

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  0.06
# RMSE: 0.3
# Relative RMSE(%):  0.055
# MSE: 0.1
# R square: 95.7%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0.001, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.372
# a1: 0.926
# R^2: 0.958
# Uncertainty
# a0: 0.37+/-0.10
# a1: 0.926+/-0.019

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_GS_XGB_model_without_texture.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_GS_XGB_model_without_texture.txt")
