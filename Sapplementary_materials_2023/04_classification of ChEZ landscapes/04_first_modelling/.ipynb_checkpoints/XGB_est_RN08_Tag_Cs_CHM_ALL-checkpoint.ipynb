# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25  idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167   0.050549
# 1           3600       8.189          15100  ...   0.040919   0.048889
# 2           4360       8.380          14600  ...   0.042397   0.050463
# 3           3420       8.137          12700  ...   0.043719   0.052974
# 4           2200       7.696          12100  ...   0.040659   0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966   0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602   0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265   0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465   0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420   0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 163 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN'])

# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           1912            784      -0.73       2.58
# 1       8.189       9.622           2005            818       0.59       2.92
# 2       8.380       9.589           2001            818       0.78       2.88
# 3       8.137       9.449           2040            833       0.52       2.72
# 4       7.696       9.401           1758            717       0.22       2.83
#
#    AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  \
# 0       2.33    0.445070     13  35.145074   360.273487    0.488754
# 1       2.47   12.465903     24  36.135511   323.958625    0.501683
# 2       2.44   13.028298     18  35.938764   299.438354    0.540056
# 3       2.55    2.128231     15  35.908361   319.773395    0.480991
# 4       2.14   12.171553      8  38.062522   353.104284    0.505257
#
#    corr_r_MIN
# 0    0.072792
# 1    0.098347
# 2    0.187811
# 3    0.020686
# 4    0.106549

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   mf_chm_MIN     103 non-null    float64
#  8   r_MIN          103 non-null    int64
#  9   b_STD          103 non-null    float64
#  10  contr_r_STD    103 non-null    float64
#  11  corr_r_Q25     103 non-null    float64
#  12  corr_r_MIN     103 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 10.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
# /tmp/ipykernel_24092/725619848.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3014.359223    1136.436893   -0.251845
# std       1.64946    1.472424    4988.505540    2019.773384    1.104536
# min       3.52600    6.075000     423.000000      98.000000   -3.030000
# 25%       6.31900    7.664000     635.500000     199.500000   -0.725000
# 50%       6.95700    8.472000    1145.000000     362.000000   -0.020000
# 75%       7.91350    9.421000    2423.500000     966.000000    0.520000
# max      11.36700   13.864000   25173.000000   10477.000000    1.650000
#
#         ln_Tag_Sr   AEDR_mean  mf_chm_MIN       r_MIN       b_STD  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     2.464854    3.570291    3.368496   11.378641   35.164575
# std      0.904757    6.089170    4.845054    9.139568    5.338700
# min      0.390000    0.480000   -0.018586    2.000000   20.570709
# 25%      1.805000    0.710000    0.482279    5.000000   31.746440
# 50%      2.600000    1.290000    0.642883    8.000000   36.135511
# 75%      3.160000    2.960000    3.921804   15.000000   39.139044
# max      4.660000   36.590000   17.862923   56.000000   45.825416
#
#        contr_r_STD  corr_r_Q25  corr_r_MIN
# count   103.000000  103.000000  103.000000
# mean    327.115078    0.393571    0.073579
# std     167.617957    0.151801    0.056017
# min       0.091058    0.033797   -0.062450
# 25%     283.887328    0.407228    0.027204
# 50%     353.034542    0.449670    0.063714
# 75%     448.017711    0.476635    0.110983
# max     652.546648    0.555648    0.241284

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN'])
y = pd.DataFrame(select, columns= ['ln_Tag_Cs'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  corr_r_MIN
# 0    0.445070     13  35.145074   360.273487    0.488754    0.072792
# 1   12.465903     24  36.135511   323.958625    0.501683    0.098347
# 2   13.028298     18  35.938764   299.438354    0.540056    0.187811
# 3    2.128231     15  35.908361   319.773395    0.480991    0.020686
# 4   12.171553      8  38.062522   353.104284    0.505257    0.106549

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Tag_Cs
# 0      -0.73
# 1       0.59
# 2       0.78
# 3       0.52
# 4       0.22

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.01947918879666144, -0.2302728811567658, 0.12268748707969968]
#     Mean: -0.029
#     Std: 0.148
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.19417892 1.20802602 1.21615029]
#     Mean: 1.206
#     Std: 0.009
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.9159772532305547, 0.7328078853075994, 0.870108718661701]
#     Mean: 0.840
#     Std: 0.078
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: -0.005 (std: 0.172)
# Parameters: {'colsample_bytree': 0.6121347432766997, 'gamma': 0.14283253781452027, 'learning_rate': 0.02424561467798947, 'max_depth': 3, 'n_estimators': 59, 'subsample': 0.49943035086288745}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.26524897, 0.29281597, 0.15273051, ..., 0.55946584, 0.68677678,
#        0.20648446]), 'std_fit_time': array([0.02268336, 0.00609447, 0.01192915, ..., 0.02131049, 0.35164246,
#        0.01106516]), 'mean_score_time': array([0.00693207, 0.00626631, 0.00617161, ..., 0.00753717, 0.00713716,
#        0.00712428]), 'std_score_time': array([1.68217698e-03, 2.22671792e-04, 3.01071221e-05, ...,
#        4.17391049e-04, 2.66626600e-05, 2.13299233e-05]), 'param_colsample_bytree': masked_array(data=[0.3650012440173263, 0.5953902100331591,
#                    0.7226919246143971, ..., 0.38498618420347797,
#                    0.07264840976796555, 0.0736660192409675],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.12681014192644907, 0.49679635970092506,
#                    0.43399453307254393, ..., 0.1845517140635537,
#                    0.2683307985510262, 0.3228216653264759],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.2997978777223208, 0.17957422898898986,
#                    0.19078155181156184, ..., 0.2605194397901553,
#                    0.06385148241798436, 0.03564028244900213],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[4, 2, 4, ..., 2, 2, 3],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[97, 121, 54, ..., 187, 180, 66],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.5668931607940861, 0.7290483133043693,
#                    0.59580931513677, ..., 0.7172854820916787,
#                    0.38183292054548473, 0.3594061324694714],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.3650012440173263, 'gamma': 0.12681014192644907, 'learning_rate': 0.2997978777223208, 'max_depth': 4, 'n_estimators': 97, 'subsample': 0.5668931607940861}, {'colsample_bytree': 0.5953902100331591, 'gamma': 0.49679635970092506, 'learning_rate': 0.17957422898898986, 'max_depth': 2, 'n_estimators': 121, 'subsample': 0.7290483133043693}, {'colsample_bytree': 0.7226919246143971, 'gamma': 0.43399453307254393, 'learning_rate': 0.19078155181156184, 'max_depth': 4, 'n_estimators': 54, 'subsample': 0.59580931513677}, {'colsample_bytree': 0.6103951630917562, 'gamma': 0.2323754850438049, 'learning_rate': 0.29625132169132595, 'max_depth': 4, 'n_estimators': 61, 'subsample': 0.45053915414818335}, {'colsample_bytree': 0.48292253188504963, 'gamma': 0.28548319604696026, 'learning_rate': 0.2359208713984065, '
#        -0.55625523, -0.06558671]), 'split1_test_score': array([-0.01623019,  0.08104922,  0.25197384, ...,  0.0769392 ,
#         0.34519104,  0.22151106]), 'split2_test_score': array([ 0.06165231,  0.02073188,  0.06679471, ..., -0.04098613,
#        -0.02999448,  0.05629804]), 'split3_test_score': array([-1.94559528, -1.08776029, -1.35300627, ..., -2.13434147,
#        -2.24888765, -0.83900233]), 'split4_test_score': array([ 0.09305261, -0.00928079, -0.09784667, ..., -0.0617683 ,
#         0.05107152, -0.09101311]), 'mean_test_score': array([-0.45392681, -0.44370273, -0.32811306, ..., -0.74104919,
#        -0.48777496, -0.14355861]), 'std_test_score': array([0.77223509, 0.58348887, 0.57068629, ..., 0.91742679, 0.92735735,
#        0.36488386]), 'rank_test_score': array([1445, 1402,  820, ..., 2456, 1614,  209], dtype=int32), 'split0_train_score': array([0.98252258, 0.90604391, 0.93525904, ..., 0.96961934, 0.73172593,
#        0.47735195]), 'split1_train_score': array([0.98104267, 0.88595413, 0.92101914, ..., 0.95971237, 0.68850294,
#        0.43388477]), 'split2_train_score': array([0.97475632, 0.87748513, 0.90989284, ..., 0.95616132, 0.76930976,
#        0.4843481 ]), 'split3_train_score': array([0.98296701, 0.90206547, 0.92764975, ..., 0.96481626, 0.75600858,
#        0.48702262]), 'split4_train_score': array([0.9747341 , 0.8660414 , 0.91603304, ..., 0.95529007, 0.74735055,
#        0.47042674]), 'mean_train_score': array([0.97920454, 0.88751801, 0.92197076, ..., 0.96111987, 0.73857955,
#        0.47060684]), 'std_train_score': array([0.00369637, 0.0149612 , 0.00884158, ..., 0.00541219, 0.02785565,
#        0.01924754])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.6121347432766997
# Gamma: 0.14283253781452027
# Learning_rate: 0.02424561467798947
# Max_depth: 3
# N_estimators: 59
# Subsample: 0.49943035086288745

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:1.36645	validation_1-rmse:1.09401
# [1]	validation_0-rmse:1.35010	validation_1-rmse:1.08467
# [2]	validation_0-rmse:1.33560	validation_1-rmse:1.07334
# [3]	validation_0-rmse:1.31818	validation_1-rmse:1.06677
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.30078	validation_1-rmse:1.05468
# [5]	validation_0-rmse:1.28786	validation_1-rmse:1.05302
# [6]	validation_0-rmse:1.27809	validation_1-rmse:1.04830
# [7]	validation_0-rmse:1.26249	validation_1-rmse:1.03604
# [8]	validation_0-rmse:1.24562	validation_1-rmse:1.03417
# [9]	validation_0-rmse:1.22900	validation_1-rmse:1.02230
# [10]	validation_0-rmse:1.21757	validation_1-rmse:1.01089
# [11]	validation_0-rmse:1.20117	validation_1-rmse:1.00017
# [12]	validation_0-rmse:1.18961	validation_1-rmse:0.99778
# [13]	validation_0-rmse:1.17386	validation_1-rmse:0.99116
# [14]	validation_0-rmse:1.16003	validation_1-rmse:0.98473
# [15]	validation_0-rmse:1.14986	validation_1-rmse:0.97862
# [16]	validation_0-rmse:1.13587	validation_1-rmse:0.96916
# [17]	validation_0-rmse:1.12511	validation_1-rmse:0.96049
# [18]	validation_0-rmse:1.11423	validation_1-rmse:0.95313
# [19]	validation_0-rmse:1.10026	validation_1-rmse:0.94812
# [20]	validation_0-rmse:1.08971	validation_1-rmse:0.94032
# [21]	validation_0-rmse:1.07898	validation_1-rmse:0.93312
# [22]	validation_0-rmse:1.06771	validation_1-rmse:0.92410
# [23]	validation_0-rmse:1.05819	validation_1-rmse:0.92133
# [24]	validation_0-rmse:1.04621	validation_1-rmse:0.91512
# [25]	validation_0-rmse:1.03502	validation_1-rmse:0.91064
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [16]	validation_0-rmse:1.17736	validation_1-rmse:0.68946
# [17]	validation_0-rmse:1.16394	validation_1-rmse:0.69137
# [18]	validation_0-rmse:1.15039	validation_1-rmse:0.68682
# [19]	validation_0-rmse:1.13814	validation_1-rmse:0.68511
# [20]	validation_0-rmse:1.12443	validation_1-rmse:0.68602
# [21]	validation_0-rmse:1.11299	validation_1-rmse:0.68646
# [22]	validation_0-rmse:1.10374	validation_1-rmse:0.68533
# [23]	validation_0-rmse:1.09264	validation_1-rmse:0.68687
# [24]	validation_0-rmse:1.07914	validation_1-rmse:0.68773
# [25]	validation_0-rmse:1.06565	validation_1-rmse:0.69184
# [26]	validation_0-rmse:1.05891	validation_1-rmse:0.69183
# [27]	validation_0-rmse:1.04541	validation_1-rmse:0.69631
# [28]	validation_0-rmse:1.03231	validation_1-rmse:0.69796
# [29]	validation_0-rmse:1.01994	validation_1-rmse:0.69973
# [30]	validation_0-rmse:1.00871	validation_1-rmse:0.70204
# [31]	validation_0-rmse:0.99702	validation_1-rmse:0.69903
# [32]	validation_0-rmse:0.98585	validation_1-rmse:0.69643
# [33]	validation_0-rmse:0.97509	validation_1-rmse:0.69775
# [34]	validation_0-rmse:0.96285	validation_1-rmse:0.69702
# [35]	validation_0-rmse:0.95716	validation_1-rmse:0.69845
# [36]	validation_0-rmse:0.94851	validation_1-rmse:0.69820
# [37]	validation_0-rmse:0.93743	validation_1-rmse:0.70164
# [38]	validation_0-rmse:0.92603	validation_1-rmse:0.70521
# [39]	validation_0-rmse:0.91596	validation_1-rmse:0.70443
# [0]	validation_0-rmse:1.43351	validation_1-rmse:0.64357
# [1]	validation_0-rmse:1.41587	validation_1-rmse:0.64693
# [2]	validation_0-rmse:1.39620	validation_1-rmse:0.64234
# [3]	validation_0-rmse:1.38335	validation_1-rmse:0.63967
# [4]	validation_0-rmse:1.36356	validation_1-rmse:0.64179
# [5]	validation_0-rmse:1.34445	validation_1-rmse:0.63825
# [6]	validation_0-rmse:1.33330	validation_1-rmse:0.63532
# [7]	validation_0-rmse:1.31224	validation_1-rmse:0.63696
# [8]	validation_0-rmse:1.29735	validation_1-rmse:0.63835
# [9]	validation_0-rmse:1.27940	validation_1-rmse:0.64693
# [10]	validation_0-rmse:1.26976	validation_1-rmse:0.64440
# [11]	validation_0-rmse:1.25691	validation_1-rmse:0.64584
# [12]	validation_0-rmse:1.23872	validation_1-rmse:0.64949
# [13]	validation_0-rmse:1.22125	validation_1-rmse:0.65308
# [14]	validation_0-rmse:1.20592	validation_1-rmse:0.65820
# [15]	validation_0-rmse:1.18962	validation_1-rmse:0.65968
# [16]	validation_0-rmse:1.17543	validation_1-rmse:0.66489
# [17]	validation_0-rmse:1.15942	validation_1-rmse:0.66763
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
#
# [10]	validation_0-rmse:1.15483	validation_1-rmse:1.30393
# [11]	validation_0-rmse:1.13918	validation_1-rmse:1.29588
# [12]	validation_0-rmse:1.12784	validation_1-rmse:1.29156
# [13]	validation_0-rmse:1.11277	validation_1-rmse:1.27940
# [14]	validation_0-rmse:1.10005	validation_1-rmse:1.27329
# [15]	validation_0-rmse:1.09133	validation_1-rmse:1.27365
# [16]	validation_0-rmse:1.08079	validation_1-rmse:1.26695
# [17]	validation_0-rmse:1.06643	validation_1-rmse:1.26091
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [18]	validation_0-rmse:1.05678	validation_1-rmse:1.25654
# [19]	validation_0-rmse:1.04852	validation_1-rmse:1.25245
# [20]	validation_0-rmse:1.03664	validation_1-rmse:1.25250
# [21]	validation_0-rmse:1.03062	validation_1-rmse:1.24648
# [22]	validation_0-rmse:1.02090	validation_1-rmse:1.23756
# [23]	validation_0-rmse:1.01028	validation_1-rmse:1.23153
# [24]	validation_0-rmse:1.00138	validation_1-rmse:1.22995
# [25]	validation_0-rmse:0.99202	validation_1-rmse:1.22886
# [26]	validation_0-rmse:0.98673	validation_1-rmse:1.23017
# [27]	validation_0-rmse:0.97571	validation_1-rmse:1.22661
# [28]	validation_0-rmse:0.96438	validation_1-rmse:1.21795
# [29]	validation_0-rmse:0.95259	validation_1-rmse:1.21070
# [30]	validation_0-rmse:0.94097	validation_1-rmse:1.21048
# [31]	validation_0-rmse:0.92903	validation_1-rmse:1.20590
# [32]	validation_0-rmse:0.91772	validation_1-rmse:1.20653
# [33]	validation_0-rmse:0.90814	validation_1-rmse:1.20195
# [34]	validation_0-rmse:0.90100	validation_1-rmse:1.20125
# [35]	validation_0-rmse:0.89214	validation_1-rmse:1.19040
# [36]	validation_0-rmse:0.88390	validation_1-rmse:1.18986
# [37]	validation_0-rmse:0.87390	validation_1-rmse:1.18445
# [38]	validation_0-rmse:0.86571	validation_1-rmse:1.17808
# [39]	validation_0-rmse:0.85642	validation_1-rmse:1.17055
# [40]	validation_0-rmse:0.84700	validation_1-rmse:1.15970
# [41]	validation_0-rmse:0.83962	validation_1-rmse:1.15444
# [42]	validation_0-rmse:0.83304	validation_1-rmse:1.14919
# [43]	validation_0-rmse:0.82681	validation_1-rmse:1.14870
# [44]	validation_0-rmse:0.82115	validation_1-rmse:1.14243
# [45]	validation_0-rmse:0.81657	validation_1-rmse:1.13738
# [46]	validation_0-rmse:0.81167	validation_1-rmse:1.13283
# [47]	validation_0-rmse:0.80342	validation_1-rmse:1.13155
# [48]	validation_0-rmse:0.79689	validation_1-rmse:1.12596
# [49]	validation_0-rmse:0.79283	validation_1-rmse:1.12325
# [50]	validation_0-rmse:0.78768	validation_1-rmse:1.11631
# [51]	validation_0-rmse:0.78136	validation_1-rmse:1.10992
# [52]	validation_0-rmse:0.77624	validation_1-rmse:1.11128
# [53]	validation_0-rmse:0.77037	validation_1-rmse:1.10693
# [54]	validation_0-rmse:0.76296	validation_1-rmse:1.10405
# [55]	validation_0-rmse:0.75548	validation_1-rmse:1.10891
# [56]	validation_0-rmse:0.74834	validation_1-rmse:1.10600
# [57]	validation_0-rmse:0.74274	validation_1-rmse:1.10280
# [58]	validation_0-rmse:0.73755	validation_1-rmse:1.09918
# [0]	validation_0-rmse:1.29809	validation_1-rmse:1.38732
# [1]	validation_0-rmse:1.28329	validation_1-rmse:1.37825
# [2]	validation_0-rmse:1.26626	validation_1-rmse:1.36578
# [3]	validation_0-rmse:1.25057	validation_1-rmse:1.35093
# [4]	validation_0-rmse:1.23482	validation_1-rmse:1.34001
# [5]	validation_0-rmse:1.22064	validation_1-rmse:1.32415
# [6]	validation_0-rmse:1.21180	validation_1-rmse:1.31299
# [7]	validation_0-rmse:1.19798	validation_1-rmse:1.30067
# [8]	validation_0-rmse:1.18712	validation_1-rmse:1.28937
# [9]	validation_0-rmse:1.17000	validation_1-rmse:1.27901
# [10]	validation_0-rmse:1.15557	validation_1-rmse:1.26452
# [11]	validation_0-rmse:1.14203	validation_1-rmse:1.25061
# [12]	validation_0-rmse:1.13314	validation_1-rmse:1.24426
# [13]	validation_0-rmse:1.12237	validation_1-rmse:1.23615
# [14]	validation_0-rmse:1.10910	validation_1-rmse:1.22831
# [15]	validation_0-rmse:1.09362	validation_1-rmse:1.22139
# [16]	validation_0-rmse:1.08067	validation_1-rmse:1.21373
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [17]	validation_0-rmse:1.06796	validation_1-rmse:1.20755
# [18]	validation_0-rmse:1.06202	validation_1-rmse:1.20713
# [19]	validation_0-rmse:1.04998	validation_1-rmse:1.19906
# [20]	validation_0-rmse:1.03836	validation_1-rmse:1.19082
# [21]	validation_0-rmse:1.02531	validation_1-rmse:1.18277
# [22]	validation_0-rmse:1.01639	validation_1-rmse:1.17238
# [23]	validation_0-rmse:1.00295	validation_1-rmse:1.16325
# [24]	validation_0-rmse:0.99227	validation_1-rmse:1.15331
# [25]	validation_0-rmse:0.98656	validation_1-rmse:1.14938
# [26]	validation_0-rmse:0.97934	validation_1-rmse:1.14459
# [27]	validation_0-rmse:0.97131	validation_1-rmse:1.14150
# [28]	validation_0-rmse:0.96168	validation_1-rmse:1.13203
# [29]	validation_0-rmse:0.95185	validation_1-rmse:1.12647
# [30]	validation_0-rmse:0.94757	validation_1-rmse:1.12071
# [31]	validation_0-rmse:0.93776	validation_1-rmse:1.10940
# [32]	validation_0-rmse:0.92876	validation_1-rmse:1.10138
# [33]	validation_0-rmse:0.91979	validation_1-rmse:1.10115
# [34]	validation_0-rmse:0.91128	validation_1-rmse:1.09694
# [35]	validation_0-rmse:0.90652	validation_1-rmse:1.08959
# [36]	validation_0-rmse:0.89862	validation_1-rmse:1.08221
# [37]	validation_0-rmse:0.89009	validation_1-rmse:1.07259
# [38]	validation_0-rmse:0.87893	validation_1-rmse:1.06769
# [39]	validation_0-rmse:0.87438	validation_1-rmse:1.06372
# [40]	validation_0-rmse:0.86770	validation_1-rmse:1.05878
# [41]	validation_0-rmse:0.85952	validation_1-rmse:1.05654
# [42]	validation_0-rmse:0.85383	validation_1-rmse:1.05159
# [43]	validation_0-rmse:0.84921	validation_1-rmse:1.04930
# [44]	validation_0-rmse:0.84633	validation_1-rmse:1.04842
# [45]	validation_0-rmse:0.83809	validation_1-rmse:1.04116
# [46]	validation_0-rmse:0.83419	validation_1-rmse:1.03679
# [47]	validation_0-rmse:0.82673	validation_1-rmse:1.03706
# [48]	validation_0-rmse:0.82091	validation_1-rmse:1.03348
# [49]	validation_0-rmse:0.81797	validation_1-rmse:1.02887
# [50]	validation_0-rmse:0.81146	validation_1-rmse:1.02688
# [51]	validation_0-rmse:0.80502	validation_1-rmse:1.02191
# [52]	validation_0-rmse:0.80147	validation_1-rmse:1.01892
# [53]	validation_0-rmse:0.79638	validation_1-rmse:1.01542
# [54]	validation_0-rmse:0.79037	validation_1-rmse:1.01009
# [55]	validation_0-rmse:0.78425	validation_1-rmse:1.00460
# [56]	validation_0-rmse:0.78106	validation_1-rmse:1.00076
# [57]	validation_0-rmse:0.77703	validation_1-rmse:0.99827
# [58]	validation_0-rmse:0.77290	validation_1-rmse:0.99249
# [0]	validation_0-rmse:1.27486	validation_1-rmse:1.46423
# [1]	validation_0-rmse:1.26080	validation_1-rmse:1.44664
# [2]	validation_0-rmse:1.24839	validation_1-rmse:1.44111
# [3]	validation_0-rmse:1.23806	validation_1-rmse:1.43279
# [4]	validation_0-rmse:1.22459	validation_1-rmse:1.42216
# [5]	validation_0-rmse:1.21220	validation_1-rmse:1.41517
# [6]	validation_0-rmse:1.19720	validation_1-rmse:1.39641
# [7]	validation_0-rmse:1.18505	validation_1-rmse:1.38772
# [8]	validation_0-rmse:1.17125	validation_1-rmse:1.36875
# [9]	validation_0-rmse:1.15892	validation_1-rmse:1.35594
# [10]	validation_0-rmse:1.15020	validation_1-rmse:1.35014
# [11]	validation_0-rmse:1.13904	validation_1-rmse:1.33331
# [12]	validation_0-rmse:1.12470	validation_1-rmse:1.32722
# [13]	validation_0-rmse:1.11236	validation_1-rmse:1.31854
# [14]	validation_0-rmse:1.09975	validation_1-rmse:1.30628
# [15]	validation_0-rmse:1.08929	validation_1-rmse:1.29547
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [16]	validation_0-rmse:1.08066	validation_1-rmse:1.28570
# [17]	validation_0-rmse:1.07253	validation_1-rmse:1.27802
# [18]	validation_0-rmse:1.06373	validation_1-rmse:1.26866
# [19]	validation_0-rmse:1.05216	validation_1-rmse:1.26618
# [20]	validation_0-rmse:1.04203	validation_1-rmse:1.26115
# [21]	validation_0-rmse:1.03108	validation_1-rmse:1.25435
# [22]	validation_0-rmse:1.02465	validation_1-rmse:1.24544
# [23]	validation_0-rmse:1.01561	validation_1-rmse:1.23299
# [24]	validation_0-rmse:1.00695	validation_1-rmse:1.22049
# [25]	validation_0-rmse:0.99739	validation_1-rmse:1.21087
# [26]	validation_0-rmse:0.98872	validation_1-rmse:1.20169
# [27]	validation_0-rmse:0.97782	validation_1-rmse:1.18621
# [28]	validation_0-rmse:0.97058	validation_1-rmse:1.17836
# [29]	validation_0-rmse:0.96584	validation_1-rmse:1.17455
# [30]	validation_0-rmse:0.96134	validation_1-rmse:1.16843
# [31]	validation_0-rmse:0.95356	validation_1-rmse:1.16002
# [32]	validation_0-rmse:0.94695	validation_1-rmse:1.15090
# [33]	validation_0-rmse:0.93981	validation_1-rmse:1.14476
# [34]	validation_0-rmse:0.93064	validation_1-rmse:1.13330
# [35]	validation_0-rmse:0.92185	validation_1-rmse:1.13112
# [36]	validation_0-rmse:0.91542	validation_1-rmse:1.12620
# [37]	validation_0-rmse:0.90815	validation_1-rmse:1.12294
# [38]	validation_0-rmse:0.89985	validation_1-rmse:1.11631
# [39]	validation_0-rmse:0.89453	validation_1-rmse:1.11739
# [40]	validation_0-rmse:0.88583	validation_1-rmse:1.11370
# [41]	validation_0-rmse:0.88302	validation_1-rmse:1.11134
# [42]	validation_0-rmse:0.87460	validation_1-rmse:1.10345
# [43]	validation_0-rmse:0.87027	validation_1-rmse:1.09927
# [44]	validation_0-rmse:0.86601	validation_1-rmse:1.09482
# [45]	validation_0-rmse:0.85889	validation_1-rmse:1.08682
# [46]	validation_0-rmse:0.85193	validation_1-rmse:1.07707
# [47]	validation_0-rmse:0.84621	validation_1-rmse:1.06831
# [48]	validation_0-rmse:0.83892	validation_1-rmse:1.06721
# [49]	validation_0-rmse:0.83351	validation_1-rmse:1.06070
# [50]	validation_0-rmse:0.82882	validation_1-rmse:1.05438
# [51]	validation_0-rmse:0.82404	validation_1-rmse:1.05026
# [52]	validation_0-rmse:0.81875	validation_1-rmse:1.04423
# [53]	validation_0-rmse:0.81454	validation_1-rmse:1.04355
# [54]	validation_0-rmse:0.80901	validation_1-rmse:1.03518
# [55]	validation_0-rmse:0.80616	validation_1-rmse:1.03451
# [56]	validation_0-rmse:0.80138	validation_1-rmse:1.02889
# [57]	validation_0-rmse:0.79756	validation_1-rmse:1.02678
# [58]	validation_0-rmse:0.79135	validation_1-rmse:1.02512
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 53.56, median: 58.0,
#  pred. interval (P(0.025)-P(0.975)): 17.0-58.0,
#  conf. interval (p-value=0.95): 54.945-58.0
# ***
# Aggregate bias statistic:
#  mean: 5.817, median: 5.789,
#  pred. interval (P(0.025)-P(0.975)): -2.339-14.095,
#  conf. interval (p-value=0.95): 3.763-7.833
# ***
# Aggregate RMSE statistic:
#  mean: 1.01, median: 1.03, pred. interval (P(0.025)-P(0.975)): 0.641-1.314,
#  conf. interval (p-value=0.95): 0.943-1.091
# ***
# Aggregate MSE statistic:
#  mean: 1.049, median: 1.062, pred. interval (P(0.025)-P(0.975)): 0.411-1.725,
#  conf. interval (p-value=0.95): 0.9-1.194
# ***
# Aggregate R^2 statistic:
#  mean: 0.087, median: 0.108, pred. interval (P(0.025)-P(0.975)): -0.292-0.37,
#  conf. interval (p-value=0.95): 0.03-0.165
# ***
# Aggregate bias(%) statistic:
#  mean: -13.862, median: 5.789, pred. interval (P(0.025)-P(0.975)): -41.7-19.193,
#  conf. interval (p-value=0.95): -22.874--16.619
# ***
# Aggregate RMSE(%) statistic:
#  mean: -3.808, median: -2.96, pred. interval (P(0.025)-P(0.975)): -16.95-19.105,
#  conf. interval (p-value=0.95): -4.203--2.405
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.31774
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [1]	validation_0-rmse:1.30350
# [2]	validation_0-rmse:1.29618
# [3]	validation_0-rmse:1.28181
# [4]	validation_0-rmse:1.26521
# [5]	validation_0-rmse:1.25136
# [6]	validation_0-rmse:1.23565
# [7]	validation_0-rmse:1.22636
# [8]	validation_0-rmse:1.21490
# [9]	validation_0-rmse:1.20101
# [10]	validation_0-rmse:1.18945
# [11]	validation_0-rmse:1.17863
# [12]	validation_0-rmse:1.16754
# [13]	validation_0-rmse:1.15197
# [14]	validation_0-rmse:1.13861
# [15]	validation_0-rmse:1.12634
# [16]	validation_0-rmse:1.11961
# [17]	validation_0-rmse:1.11138
# [18]	validation_0-rmse:1.10337
# [19]	validation_0-rmse:1.09259
# [20]	validation_0-rmse:1.08240
# [21]	validation_0-rmse:1.07297
# [22]	validation_0-rmse:1.06102
# [23]	validation_0-rmse:1.05244
# [24]	validation_0-rmse:1.04164
# [25]	validation_0-rmse:1.03152
# [26]	validation_0-rmse:1.02064
# [27]	validation_0-rmse:1.01118
# [28]	validation_0-rmse:0.99915
# [29]	validation_0-rmse:0.98676
# [30]	validation_0-rmse:0.98337
# [31]	validation_0-rmse:0.97921
# [32]	validation_0-rmse:0.97074
# [33]	validation_0-rmse:0.96556
# [34]	validation_0-rmse:0.95638
# [35]	validation_0-rmse:0.94624
# [36]	validation_0-rmse:0.93732
# [37]	validation_0-rmse:0.93060
# [38]	validation_0-rmse:0.92563
# [39]	validation_0-rmse:0.92090
# [40]	validation_0-rmse:0.91251
# [41]	validation_0-rmse:0.90501
# [42]	validation_0-rmse:0.90127
# [43]	validation_0-rmse:0.89249
# [44]	validation_0-rmse:0.88523
# [45]	validation_0-rmse:0.87593
# [46]	validation_0-rmse:0.86748
# [47]	validation_0-rmse:0.86403
# [48]	validation_0-rmse:0.85957
# [49]	validation_0-rmse:0.84982
# [50]	validation_0-rmse:0.84243
# [51]	validation_0-rmse:0.83632
# [52]	validation_0-rmse:0.83084
# [53]	validation_0-rmse:0.82551
# [54]	validation_0-rmse:0.82057
# [55]	validation_0-rmse:0.81386
# [56]	validation_0-rmse:0.80704
# [57]	validation_0-rmse:0.80068
# [58]	validation_0-rmse:0.79695
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 58

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.2
# Relative bias(%):  -88.49
# RMSE: 0.8
# Relative RMSE(%):  -3.164
# MSE: 0.6
# R square: 47.4%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.049
# a1: 0.336
# R^2: 0.711
# Uncertainty
# a0: 0.049+/-0.024
# a1: 0.336+/-0.021

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Tag_Cs_XGB_model.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Tag_Cs_XGB_model.txt")
