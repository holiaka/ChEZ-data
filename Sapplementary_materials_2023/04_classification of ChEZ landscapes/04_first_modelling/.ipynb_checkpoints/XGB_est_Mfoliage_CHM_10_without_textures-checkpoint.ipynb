# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25 idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167  0.050549
# 1           3600       8.189          15100  ...   0.040919  0.048889
# 2           4360       8.380          14600  ...   0.042397  0.050463
# 3           3420       8.137          12700  ...   0.043719  0.052974
# 4           2200       7.696          12100  ...   0.040659  0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX  idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966    0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602    0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265    0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465    0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420    0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 159 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX'])
            


# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0       4.8122           1.7630               -0.3147           -0.1590
# 1       5.7589           2.4570               -0.2485            0.3429
# 2       5.8464           2.5153               -0.1054            0.5493
# 3       5.7526           2.6304               -0.0834            0.3900
# 4       5.9480           2.6748                0.0000            0.5715
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX
# 0             -2.4418         1.9125     0.85    12.233545   19.097736
# 1             -0.1997         2.6319     1.00    14.964220   17.704655
# 2             -0.2144         2.7020     1.00    15.329449   17.559893
# 3             -0.3510         2.7763     0.97    15.392742   20.676994
# 4             -0.3711         2.8314     1.00    17.944009   21.851387

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
# dtypes: float64(9)
# memory usage: 7.4 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["M_crown_kg_m2", "M_foliage_kg_m2"].describe()
# Out:
# /tmp/ipykernel_74157/4127234604.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_specias"])["M_crown_kg_m2", "M_foliage_kg_m2"].describe()
#                  M_crown_kg_m2                                             \
#                          count      mean       std    min      25%    50%
# Dominant_specias
# Alder                      4.0  1.059000  0.593217  0.476  0.68825  0.958
# Aspen                      1.0  1.173000       NaN  1.173  1.17300  1.173
# Birch                     23.0  1.039609  0.409105  0.303  0.77850  1.049
# Oak                        3.0  2.085000  1.209736  1.344  1.38700  1.430
# Pine                      71.0  1.272141  0.638357  0.211  0.82000  1.381
# Spruce                     1.0  4.105000       NaN  4.105  4.10500  4.105
#
#                                  M_foliage_kg_m2                             \
#                       75%    max           count      mean       std    min
# Dominant_specias
# Alder             1.32875  1.844             4.0  0.312000  0.145801  0.130
# Aspen             1.17300  1.173             1.0  0.168000       NaN  0.168
# Birch             1.29450  1.816            23.0  0.189304  0.080503  0.054
# Oak               2.45550  3.481             3.0  0.294333  0.078621  0.205
# Pine              1.67050  2.735            71.0  0.569746  0.267121  0.059
# Spruce            4.10500  4.105             1.0  1.043000       NaN  1.043
#
#
#                       25%     50%      75%    max
# Dominant_specias
# Alder             0.26875  0.3155  0.35875  0.487
# Aspen             0.16800  0.1680  0.16800  0.168
# Birch             0.12500  0.1850  0.25450  0.399
# Oak               0.26500  0.3250  0.33900  0.353
# Pine              0.41950  0.6390  0.74550  1.121
# Spruce            1.04300  1.0430  1.04300  1.043

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000         103.00000
# mean      4.969534         1.827923             -0.239481           0.05436
# std       1.323782         1.325853              0.893398           0.66008
# min       0.693100        -2.995700             -3.912000          -1.55590
# 25%       4.672800         1.588100             -0.335500          -0.20955
# 50%       5.337500         2.286500             -0.040800           0.24450
# 75%       5.908100         2.730800              0.190600           0.49195
# max       6.508800         3.220500              1.654400           1.41220
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.021247       2.095454    0.808738    13.045021   17.907784
# std              0.803748       1.079203    0.276653     6.609366    7.523377
# min             -2.918800      -0.798500    0.090000     1.293138    2.733019
# 25%             -1.629700       1.801400    0.745000     8.206727   11.615798
# 50%             -0.719500       2.458700    0.960000    13.072916   18.269344
# 75%             -0.358800       2.862800    1.000000    17.432255   22.751595
# max              0.114200       3.366600    1.000000    28.916548   36.355442

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX'])
y = pd.DataFrame(select, columns= ['ln_M_foliage_kg_m2'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX
# 0     0.85    12.233545   19.097736
# 1     1.00    14.964220   17.704655
# 2     1.00    15.329449   17.559893
# 3     0.97    15.392742   20.676994
# 4     1.00    17.944009   21.851387

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_foliage_kg_m2
# 0             -2.4418
# 1             -0.1997
# 2             -0.2144
# 3             -0.3510
# 4             -0.3711

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.5728688328155451, 0.11643690221019276, -0.3782735071804235]
#     Mean: 0.104
#     Std: 0.388
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.80539851 0.62627373 0.68743042]
#     Mean: 0.706
#     Std: 0.074
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.38899815364701407, 0.6381455989816609, 0.7000330474362653]
#     Mean: 0.576
#     Std: 0.134
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.450 (std: 0.039)
# Parameters: {'colsample_bytree': 0.08270651843099497, 'gamma': 0.37667147001915574, 'learning_rate': 0.22099222373646055, 'max_depth': 2, 'n_estimators': 60, 'subsample': 0.7889095515871503}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.52069492, 0.56884131, 0.24184804, ..., 0.35267615, 0.3215795 ,
#        0.33901978]), 'std_fit_time': array([0.05323328, 0.21585232, 0.11906085, ..., 0.00094221, 0.03494454,
#        0.00568471]), 'mean_score_time': array([0.00693541, 0.00606956, 0.00747838, ..., 0.00641003, 0.00647593,
#        0.00639577]), 'std_score_time': array([1.66425454e-03, 1.84513406e-04, 2.81414396e-03, ...,
#        7.78061198e-05, 2.14131689e-04, 5.56255429e-05]), 'param_colsample_bytree': masked_array(data=[0.4844551641632446, 0.5992033239095588,
#                    0.15735527958875192, ..., 0.9468552644375015,
#                    0.47335414623995337, 0.4737699075762361],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.31976078046174944, 0.35056772383741996,
#                    0.038703288886958453, ..., 0.23779599879348362,
#                    0.4052138446760852, 0.4224140803968975],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.20781849833485624, 0.1680770809195475,
#                    0.043729136627369096, ..., 0.14068979400712353,
#                    0.10336749011884942, 0.15928355773191463],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[3, 3, 3, ..., 4, 2, 2],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[190, 181, 69, ..., 126, 113, 125],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.7242296249761365, 0.7445945221770587,
#                    0.7220894834445644, ..., 0.7965884195769118,
#                    0.9675414448430657, 0.3225678159707822],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.4844551641632446, 'gamma': 0.31976078046174944, 'learning_rate': 0.20781849833485624, 'max_depth': 3, 'n_estimators': 190, 'subsample': 0.7242296249761365}, {'colsample_bytree': 0.5992033239095588, 'gamma': 0.35056772383741996, 'learning_rate': 0.1680770809195475, 'max_depth': 3, 'n_estimators': 181, 'subsample': 0.7445945221770587}, {'colsample_bytree': 0.15735527958875192, 'gamma': 0.038703288886958453, 'learning_rate': 0.043729136627369096, 'max_depth': 3, 'n_estimators': 69, 'subsample': 0.7220894834445644}, {'colsample_bytree': 0.8701330771332408, 'gamma': 0.4679502082847501, 'learning_rate': 0.031944366673596195, 'max_depth': 3, 'n_estimators': 104, 'subsample': 0.3586632231509181}, {'colsample_bytree': 0.19329624350371782, 'gamma': 0.3043105101018239, 'learning_rate': 0.20590813996298604, 'max_depth': 2, 'n_estimators': 199, 'subsample': 0.6720628531875972}, {'colsample_bytree': 0.6603394650465568, 'gamma': 0.07756717240093713, 'learning_rate': 0.14833075834715503, 'max_depth': 4, 'n_estimators': 60, 'subsample': 0.36471868004991675}, {'colsample_bytree': 0.38299324596338713, 'gamma': 0.3942969262491913, 'learning_rate': 0.025078249288611944, 'max_depth': 4, 'n_estimators': 155, 'subsample': 0.7406860778574147}, {'colsample_bytree': 0.20423304576329349, 'gamma': 0.03485680339549724, 'learning_rate': 0.21354045095168048, 'max_depth': 4, 'n_estimators': 58, 'subsample': 0.4476369983351666}, {'colsample_bytree': 0.5245484205757085, 'gamma': 0.026094214753261458, 'learning_rate': 0.08073369783286308, 'max_depth': 3, 'n_estimators': 60, 'subsample': 0.5500427904313439}, {'colsample_bytree': 0.3735351193241686, 'gamma': 0.4074764094568243, 'learning_rate': 0.23907081820770126, 'max_depth': 2, 'n_estimators': 92, 'subsample': 0.3348114995331823}, {'colsample_bytree': 0.17925824481586217, 'gamma': 0.47598662105346423, 'learning_rate': 0.24781891287087662, 'max_depth': 4, 'n_estimators': 60, 'subsample': 0.4128771055584003}, {'colsample_bytree': 0.17641919612177537, 'gamma': 0.1760351870252389, 'learning_rate': 0.2973250272202967, 'max_depth': 4, 'n_estimators': 77, 'subsample': 0.47018242667437815}, {'colsample_bytree': 0.21468464147293465, 'gamma': 0.3755304481620288, 'learning_rate': 0.2430573062867646, 'max_depth': 4, 'n_estimators': 192, 'subsample': 0.655056299863608}, {'colsample_bytree': 0.6293748853682786, 'gamma': 0.4439374253068927, 'learning_rate': 0.0631114339936, 'max_depth': 2, 'n_estimators': 53, 'subsample': 0.5522575277021177}, {'colsample_bytree': 0.48541832858419054, 'gamma': 0.2080031683515261, 'learning_rate': 0.05744148866103571, 'max_depth': 4, 'n_estimators': 84, 'subsample': 0.34740703853584093}, {'colsample_bytree': 0.22365235530079786, 'gamma': 0.24379707488343594, 'learning_rate': 0.05948470633663042, 'max_depth': 4, 'n_estimators': 163, 'subsample': 0.5736753442261793}, {'colsample_bytree': 0.32293162136447845, 'gamma': 0.43236271902228784, 'learning_rate': 0.059474826945534756, 'max_depth': 3, 'n_estimators': 106, 'subsample': 0.7380168648011165}, {'colsample_bytree': 0.08072791638312404, 'gamma': 0.15763708304248863, 'learning_rate': 0.15980942757814873, 'max_depth': 4, 'n_estimators': 144, 'subsample': 0.4345677037115596}, {'colsample_bytree': 0.1953580965043123, 'gamma': 0.18397068781528536, 'learning_rate': 0.2840764530454229, 'max_depth': 3, 'n_estimators': 60, 'subsample': 0.7904500201498773}, {'colsample_bytree': 0.6806403238189288, 'gamma': 0.07981569119582538, 'learning_rate': 0.23904542502198634, 'max_depth': 4, 'n_estimators': 135, 'subsample': 0.6960296970343266}, {'colsample_bytree': 0.08399458376125032, 'gamma': 0.24078812702086927, 'learning_rate': 0.15650233056830926, 'max_depth': 4, 'n_estimators': 155, 'subsample': 0.7982534488847104}, {'colsample_bytree': 0.42525806755634077, 'gamma': 0.05906868384007907, 'learning_rate': 0.05433867969680414, 'max_depth': 2, 'n_estimators': 68, 'subsample': 0.5204163405796801}, {'colsam ...
#        0.53733739]), 'split1_test_score': array([0.54752369, 0.53583966, 0.55952295, ..., 0.4691451 , 0.61570495,
#        0.51602997]), 'split2_test_score': array([0.42864022, 0.36436126, 0.31334624, ..., 0.3285607 , 0.42182687,
#        0.42415167]), 'split3_test_score': array([0.38530388, 0.39913792, 0.37619412, ..., 0.4815821 , 0.37791989,
#        0.320582  ]), 'split4_test_score': array([0.25300685, 0.32858781, 0.25100859, ..., 0.209123  , 0.32776442,
#        0.12140878]), 'mean_test_score': array([0.39432887, 0.39476334, 0.35261402, ..., 0.36456564, 0.40849572,
#        0.38390196]), 'std_test_score': array([0.09600009, 0.0743152 , 0.11248461, ..., 0.10099248, 0.11180135,
#        0.15200814]), 'rank_test_score': array([ 809,  797, 1864, ..., 1616,  360, 1125], dtype=int32), 'split0_train_score': array([0.86850447, 0.85680119, 0.65557258, ..., 0.90562855, 0.73684917,
#        0.75138211]), 'split1_train_score': array([0.87064399, 0.86545576, 0.66385085, ..., 0.9164387 , 0.74692141,
#        0.73006684]), 'split2_train_score': array([0.87228989, 0.85790681, 0.70113678, ..., 0.90860831, 0.77344583,
#        0.77530014]), 'split3_train_score': array([0.88488225, 0.85909213, 0.70192402, ..., 0.90728809, 0.73134223,
#        0.76470606]), 'split4_train_score': array([0.86028418, 0.83618621, 0.70156662, ..., 0.90283844, 0.72438464,
#        0.76189476]), 'mean_train_score': array([0.87132096, 0.85508842, 0.68481017, ..., 0.90816042, 0.74258866,
#        0.75666998]), 'std_train_score': array([0.00793787, 0.00991647, 0.02066084, ..., 0.00456564, 0.01709823,
#        0.01532742])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.08270651843099497
# Gamma: 0.37667147001915574
# Learning_rate: 0.22099222373646055
# Max_depth: 2
# N_estimators: 60
# Subsample: 0.7889095515871503

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:1.37725	validation_1-rmse:1.51315
# [1]	validation_0-rmse:1.14626	validation_1-rmse:1.29077
# [2]	validation_0-rmse:0.95362	validation_1-rmse:1.06853
# [3]	validation_0-rmse:0.82028	validation_1-rmse:0.92510
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:0.73819	validation_1-rmse:0.83930
# [5]	validation_0-rmse:0.67745	validation_1-rmse:0.78778
# [6]	validation_0-rmse:0.63041	validation_1-rmse:0.75279
# [7]	validation_0-rmse:0.58562	validation_1-rmse:0.70307
# [8]	validation_0-rmse:0.55679	validation_1-rmse:0.68049
# [9]	validation_0-rmse:0.53533	validation_1-rmse:0.66748
# [10]	validation_0-rmse:0.51198	validation_1-rmse:0.63695
# [11]	validation_0-rmse:0.49581	validation_1-rmse:0.63648
# [12]	validation_0-rmse:0.49472	validation_1-rmse:0.63478
# [13]	validation_0-rmse:0.48314	validation_1-rmse:0.63137
# [14]	validation_0-rmse:0.47424	validation_1-rmse:0.61819
# [15]	validation_0-rmse:0.46734	validation_1-rmse:0.62623
# [16]	validation_0-rmse:0.46244	validation_1-rmse:0.62852
# [17]	validation_0-rmse:0.45919	validation_1-rmse:0.62278
# [18]	validation_0-rmse:0.45914	validation_1-rmse:0.62256
# [19]	validation_0-rmse:0.45463	validation_1-rmse:0.61621
# [20]	validation_0-rmse:0.45089	validation_1-rmse:0.61780
# [21]	validation_0-rmse:0.44627	validation_1-rmse:0.61178
# [22]	validation_0-rmse:0.44244	validation_1-rmse:0.60648
# [23]	validation_0-rmse:0.44251	validation_1-rmse:0.60564
# [24]	validation_0-rmse:0.43372	validation_1-rmse:0.59649
# [25]	validation_0-rmse:0.43030	validation_1-rmse:0.59161
# [26]	validation_0-rmse:0.42814	validation_1-rmse:0.59193
# [27]	validation_0-rmse:0.42295	validation_1-rmse:0.59314
# [28]	validation_0-rmse:0.42096	validation_1-rmse:0.58593
# [29]	validation_0-rmse:0.41901	validation_1-rmse:0.57655
# [30]	validation_0-rmse:0.41709	validation_1-rmse:0.57798
# [31]	validation_0-rmse:0.41708	validation_1-rmse:0.57788
# [32]	validation_0-rmse:0.41156	validation_1-rmse:0.56944
# [33]	validation_0-rmse:0.41157	validation_1-rmse:0.56954
# [34]	validation_0-rmse:0.40843	validation_1-rmse:0.57029
# [35]	validation_0-rmse:0.40850	validation_1-rmse:0.57015
# [36]	validation_0-rmse:0.40279	validation_1-rmse:0.57024
# [37]	validation_0-rmse:0.39817	validation_1-rmse:0.57050
# [38]	validation_0-rmse:0.39370	validation_1-rmse:0.56488
# [39]	validation_0-rmse:0.39369	validation_1-rmse:0.56492
# [40]	validation_0-rmse:0.39377	validation_1-rmse:0.56470
# [41]	validation_0-rmse:0.39360	validation_1-rmse:0.56546
# [42]	validation_0-rmse:0.39366	validation_1-rmse:0.56502
# [43]	validation_0-rmse:0.39359	validation_1-rmse:0.56555
# [44]	validation_0-rmse:0.39238	validation_1-rmse:0.56503
# [45]	validation_0-rmse:0.39235	validation_1-rmse:0.56520
# [46]	validation_0-rmse:0.39237	validation_1-rmse:0.56505
# [47]	validation_0-rmse:0.39151	validation_1-rmse:0.55710
# [48]	validation_0-rmse:0.38758	validation_1-rmse:0.56259
# [49]	validation_0-rmse:0.38593	validation_1-rmse:0.55521
# [50]	validation_0-rmse:0.38358	validation_1-rmse:0.55347
# [51]	validation_0-rmse:0.38049	validation_1-rmse:0.54892
# [52]	validation_0-rmse:0.38053	validation_1-rmse:0.54886
# [53]	validation_0-rmse:0.38056	validation_1-rmse:0.54882
# [54]	validation_0-rmse:0.38045	validation_1-rmse:0.54900
# [55]	validation_0-rmse:0.38045	validation_1-rmse:0.54899
# [56]	validation_0-rmse:0.37846	validation_1-rmse:0.54923
# [57]	validation_0-rmse:0.37844	validation_1-rmse:0.54926
# [58]	validation_0-rmse:0.37841	validation_1-rmse:0.54934
# [59]	validation_0-rmse:0.37849	validation_1-rmse:0.54917
# [0]	validation_0-rmse:1.42147	validation_1-rmse:1.27344
# [1]	validation_0-rmse:1.20248	validation_1-rmse:1.08386
# [2]	validation_0-rmse:1.00488	validation_1-rmse:0.90467
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:0.86735	validation_1-rmse:0.77112
# [4]	validation_0-rmse:0.76032	validation_1-rmse:0.68376
# [5]	validation_0-rmse:0.68623	validation_1-rmse:0.62793
# [6]	validation_0-rmse:0.63238	validation_1-rmse:0.58916
# [7]	validation_0-rmse:0.58495	validation_1-rmse:0.55331
# [8]	validation_0-rmse:0.55984	validation_1-rmse:0.54350
# [9]	validation_0-rmse:0.54297	validation_1-rmse:0.53948
# [10]	validation_0-rmse:0.52730	validation_1-rmse:0.53451
# [11]	validation_0-rmse:0.51227	validation_1-rmse:0.52532
# [12]	validation_0-rmse:0.50396	validation_1-rmse:0.52260
# [13]	validation_0-rmse:0.49766	validation_1-rmse:0.52595
# [14]	validation_0-rmse:0.49693	validation_1-rmse:0.52773
# [15]	validation_0-rmse:0.48854	validation_1-rmse:0.52840
# [16]	validation_0-rmse:0.48144	validation_1-rmse:0.53879
# [17]	validation_0-rmse:0.48125	validation_1-rmse:0.53937
# [18]	validation_0-rmse:0.47775	validation_1-rmse:0.53926
# [19]	validation_0-rmse:0.47259	validation_1-rmse:0.52896
# [20]	validation_0-rmse:0.46263	validation_1-rmse:0.51979
# [21]	validation_0-rmse:0.46230	validation_1-rmse:0.51043
# [22]	validation_0-rmse:0.45511	validation_1-rmse:0.51964
# [23]	validation_0-rmse:0.45518	validation_1-rmse:0.51969
# [24]	validation_0-rmse:0.44622	validation_1-rmse:0.51166
# [25]	validation_0-rmse:0.44128	validation_1-rmse:0.50960
# [26]	validation_0-rmse:0.43714	validation_1-rmse:0.51851
# [27]	validation_0-rmse:0.43505	validation_1-rmse:0.52612
# [28]	validation_0-rmse:0.43495	validation_1-rmse:0.52599
# [29]	validation_0-rmse:0.43498	validation_1-rmse:0.52604
# [30]	validation_0-rmse:0.43179	validation_1-rmse:0.53428
# [31]	validation_0-rmse:0.43178	validation_1-rmse:0.53417
# [32]	validation_0-rmse:0.42799	validation_1-rmse:0.54046
# [33]	validation_0-rmse:0.42798	validation_1-rmse:0.54046
# [34]	validation_0-rmse:0.42800	validation_1-rmse:0.54045
# [35]	validation_0-rmse:0.42388	validation_1-rmse:0.54157
# [36]	validation_0-rmse:0.42408	validation_1-rmse:0.54164
# [37]	validation_0-rmse:0.41844	validation_1-rmse:0.55374
# [38]	validation_0-rmse:0.41546	validation_1-rmse:0.55494
# [39]	validation_0-rmse:0.41563	validation_1-rmse:0.55500
# [40]	validation_0-rmse:0.41441	validation_1-rmse:0.55338
# [41]	validation_0-rmse:0.41443	validation_1-rmse:0.55339
# [42]	validation_0-rmse:0.40866	validation_1-rmse:0.55396
# [43]	validation_0-rmse:0.40867	validation_1-rmse:0.55395
# [44]	validation_0-rmse:0.40867	validation_1-rmse:0.55395
# [0]	validation_0-rmse:1.38255	validation_1-rmse:1.49297
# [1]	validation_0-rmse:1.14927	validation_1-rmse:1.21947
# [2]	validation_0-rmse:0.97446	validation_1-rmse:1.00157
# [3]	validation_0-rmse:0.83972	validation_1-rmse:0.81912
# [4]	validation_0-rmse:0.77417	validation_1-rmse:0.78655
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:0.69081	validation_1-rmse:0.66811
# [6]	validation_0-rmse:0.63390	validation_1-rmse:0.58395
# [7]	validation_0-rmse:0.59058	validation_1-rmse:0.54603
# [8]	validation_0-rmse:0.56390	validation_1-rmse:0.52801
# [9]	validation_0-rmse:0.54945	validation_1-rmse:0.53219
# [10]	validation_0-rmse:0.53143	validation_1-rmse:0.52976
# [11]	validation_0-rmse:0.51281	validation_1-rmse:0.54601
# [12]	validation_0-rmse:0.50252	validation_1-rmse:0.55841
# [13]	validation_0-rmse:0.50119	validation_1-rmse:0.56616
# [14]	validation_0-rmse:0.49270	validation_1-rmse:0.57381
# [15]	validation_0-rmse:0.49228	validation_1-rmse:0.57538
# [16]	validation_0-rmse:0.47808	validation_1-rmse:0.58959
# [17]	validation_0-rmse:0.47478	validation_1-rmse:0.59139
# [18]	validation_0-rmse:0.46681	validation_1-rmse:0.61414
# [19]	validation_0-rmse:0.46338	validation_1-rmse:0.61404
# [20]	validation_0-rmse:0.45838	validation_1-rmse:0.61613
# [21]	validation_0-rmse:0.45259	validation_1-rmse:0.61314
# [22]	validation_0-rmse:0.44784	validation_1-rmse:0.61216
# [23]	validation_0-rmse:0.44488	validation_1-rmse:0.61575
# [24]	validation_0-rmse:0.43773	validation_1-rmse:0.61911
# [25]	validation_0-rmse:0.43492	validation_1-rmse:0.62245
# [26]	validation_0-rmse:0.43030	validation_1-rmse:0.61378
# [27]	validation_0-rmse:0.42786	validation_1-rmse:0.62282
# [28]	validation_0-rmse:0.42331	validation_1-rmse:0.61631
# [0]	validation_0-rmse:1.42940	validation_1-rmse:1.30050
# [1]	validation_0-rmse:1.17360	validation_1-rmse:1.04951
# [2]	validation_0-rmse:0.98596	validation_1-rmse:0.91054
# [3]	validation_0-rmse:0.85004	validation_1-rmse:0.78591
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:0.74431	validation_1-rmse:0.70361
# [5]	validation_0-rmse:0.66863	validation_1-rmse:0.66454
# [6]	validation_0-rmse:0.61156	validation_1-rmse:0.61231
# [7]	validation_0-rmse:0.57097	validation_1-rmse:0.59752
# [8]	validation_0-rmse:0.54958	validation_1-rmse:0.58704
# [9]	validation_0-rmse:0.53597	validation_1-rmse:0.58466
# [10]	validation_0-rmse:0.51590	validation_1-rmse:0.57844
# [11]	validation_0-rmse:0.50337	validation_1-rmse:0.58586
# [12]	validation_0-rmse:0.49367	validation_1-rmse:0.57965
# [13]	validation_0-rmse:0.48272	validation_1-rmse:0.58550
# [14]	validation_0-rmse:0.46983	validation_1-rmse:0.60232
# [15]	validation_0-rmse:0.46864	validation_1-rmse:0.60537
# [16]	validation_0-rmse:0.46383	validation_1-rmse:0.59859
# [17]	validation_0-rmse:0.46107	validation_1-rmse:0.60036
# [18]	validation_0-rmse:0.45399	validation_1-rmse:0.59639
# [19]	validation_0-rmse:0.44492	validation_1-rmse:0.59952
# [20]	validation_0-rmse:0.44517	validation_1-rmse:0.59966
# [21]	validation_0-rmse:0.43980	validation_1-rmse:0.59940
# [22]	validation_0-rmse:0.43685	validation_1-rmse:0.60494
# [23]	validation_0-rmse:0.42815	validation_1-rmse:0.61980
# [24]	validation_0-rmse:0.42050	validation_1-rmse:0.62639
# [25]	validation_0-rmse:0.41127	validation_1-rmse:0.64146
# [26]	validation_0-rmse:0.40660	validation_1-rmse:0.64135
# [27]	validation_0-rmse:0.39659	validation_1-rmse:0.65070
# [28]	validation_0-rmse:0.39657	validation_1-rmse:0.65068
# [29]	validation_0-rmse:0.39203	validation_1-rmse:0.63294
# [0]	validation_0-rmse:1.36885	validation_1-rmse:1.53824
# [1]	validation_0-rmse:1.13688	validation_1-rmse:1.27593
# [2]	validation_0-rmse:0.94627	validation_1-rmse:1.07105
# [3]	validation_0-rmse:0.82874	validation_1-rmse:0.94249
# [4]	validation_0-rmse:0.72634	validation_1-rmse:0.83554
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:0.65590	validation_1-rmse:0.77131
# [6]	validation_0-rmse:0.60833	validation_1-rmse:0.72561
# [7]	validation_0-rmse:0.56688	validation_1-rmse:0.68888
# [8]	validation_0-rmse:0.54744	validation_1-rmse:0.66667
# [9]	validation_0-rmse:0.53599	validation_1-rmse:0.65443
# [10]	validation_0-rmse:0.51741	validation_1-rmse:0.64439
# [11]	validation_0-rmse:0.50341	validation_1-rmse:0.62740
# [12]	validation_0-rmse:0.50149	validation_1-rmse:0.62414
# [13]	validation_0-rmse:0.49334	validation_1-rmse:0.62472
# [14]	validation_0-rmse:0.49233	validation_1-rmse:0.62265
# [15]	validation_0-rmse:0.48667	validation_1-rmse:0.62715
# [16]	validation_0-rmse:0.48037	validation_1-rmse:0.62536
# [17]	validation_0-rmse:0.47675	validation_1-rmse:0.61776
# [18]	validation_0-rmse:0.47015	validation_1-rmse:0.61947
# [19]	validation_0-rmse:0.46758	validation_1-rmse:0.61251
# [20]	validation_0-rmse:0.46078	validation_1-rmse:0.60494
# [21]	validation_0-rmse:0.45206	validation_1-rmse:0.60322
# [22]	validation_0-rmse:0.45225	validation_1-rmse:0.60453
# [23]	validation_0-rmse:0.44891	validation_1-rmse:0.61165
# [24]	validation_0-rmse:0.44449	validation_1-rmse:0.61553
# [25]	validation_0-rmse:0.43339	validation_1-rmse:0.61542
# [26]	validation_0-rmse:0.42829	validation_1-rmse:0.62603
# [27]	validation_0-rmse:0.42634	validation_1-rmse:0.63222
# [28]	validation_0-rmse:0.42117	validation_1-rmse:0.63649
# [29]	validation_0-rmse:0.42024	validation_1-rmse:0.63501
# [30]	validation_0-rmse:0.41698	validation_1-rmse:0.63158
# [31]	validation_0-rmse:0.41450	validation_1-rmse:0.63289
# [32]	validation_0-rmse:0.41079	validation_1-rmse:0.63495
# [33]	validation_0-rmse:0.40620	validation_1-rmse:0.63725
# [34]	validation_0-rmse:0.40470	validation_1-rmse:0.63444
# [35]	validation_0-rmse:0.40196	validation_1-rmse:0.64175
# [36]	validation_0-rmse:0.39799	validation_1-rmse:0.63996
# [37]	validation_0-rmse:0.39187	validation_1-rmse:0.64114
# [38]	validation_0-rmse:0.38832	validation_1-rmse:0.64034
# [39]	validation_0-rmse:0.38019	validation_1-rmse:0.62886
# [40]	validation_0-rmse:0.37917	validation_1-rmse:0.62711
# [41]	validation_0-rmse:0.37917	validation_1-rmse:0.62674
# [0]	validation_0-rmse:1.41502	validation_1-rmse:1.34045
# [1]	validation_0-rmse:1.16045	validation_1-rmse:1.11813
# [2]	validation_0-rmse:0.97154	validation_1-rmse:0.96302
# [3]	validation_0-rmse:0.82411	validation_1-rmse:0.84530
# [4]	validation_0-rmse:0.74104	validation_1-rmse:0.80027
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:0.66448	validation_1-rmse:0.75194
# [6]	validation_0-rmse:0.61312	validation_1-rmse:0.72760
# [7]	validation_0-rmse:0.56883	validation_1-rmse:0.69153
# [8]	validation_0-rmse:0.54086	validation_1-rmse:0.67996
# [9]	validation_0-rmse:0.51085	validation_1-rmse:0.69004
# [10]	validation_0-rmse:0.48821	validation_1-rmse:0.67178
# [11]	validation_0-rmse:0.47605	validation_1-rmse:0.67207
# [12]	validation_0-rmse:0.46871	validation_1-rmse:0.67115
# [13]	validation_0-rmse:0.46412	validation_1-rmse:0.68035
# [14]	validation_0-rmse:0.46049	validation_1-rmse:0.68290
# [15]	validation_0-rmse:0.45153	validation_1-rmse:0.68461
# [16]	validation_0-rmse:0.44141	validation_1-rmse:0.67737
# [17]	validation_0-rmse:0.44092	validation_1-rmse:0.67765
# [18]	validation_0-rmse:0.44074	validation_1-rmse:0.67782
# [19]	validation_0-rmse:0.44057	validation_1-rmse:0.67803
# [20]	validation_0-rmse:0.44032	validation_1-rmse:0.67860
# [21]	validation_0-rmse:0.43795	validation_1-rmse:0.67462
# [22]	validation_0-rmse:0.43037	validation_1-rmse:0.67367
# [23]	validation_0-rmse:0.42782	validation_1-rmse:0.67019
# [24]	validation_0-rmse:0.42786	validation_1-rmse:0.67009
# [25]	validation_0-rmse:0.42777	validation_1-rmse:0.67038
# [26]	validation_0-rmse:0.42777	validation_1-rmse:0.67040
# [27]	validation_0-rmse:0.42313	validation_1-rmse:0.67216
# [28]	validation_0-rmse:0.41833	validation_1-rmse:0.68474
# [29]	validation_0-rmse:0.41520	validation_1-rmse:0.67929
# [30]	validation_0-rmse:0.41295	validation_1-rmse:0.67850
# [31]	validation_0-rmse:0.40453	validation_1-rmse:0.67116
# [32]	validation_0-rmse:0.40043	validation_1-rmse:0.66693
# [33]	validation_0-rmse:0.39891	validation_1-rmse:0.66482
# [34]	validation_0-rmse:0.39343	validation_1-rmse:0.66363
# [35]	validation_0-rmse:0.39343	validation_1-rmse:0.66371
# [36]	validation_0-rmse:0.39343	validation_1-rmse:0.66364
# [37]	validation_0-rmse:0.39304	validation_1-rmse:0.66286
# [38]	validation_0-rmse:0.39304	validation_1-rmse:0.66283
# [39]	validation_0-rmse:0.38797	validation_1-rmse:0.66288
# [40]	validation_0-rmse:0.38803	validation_1-rmse:0.66308
# [41]	validation_0-rmse:0.38684	validation_1-rmse:0.66227
# [42]	validation_0-rmse:0.38697	validation_1-rmse:0.66268
# [43]	validation_0-rmse:0.38678	validation_1-rmse:0.66201
# [44]	validation_0-rmse:0.38681	validation_1-rmse:0.66215
# [45]	validation_0-rmse:0.38696	validation_1-rmse:0.66107
# [46]	validation_0-rmse:0.38271	validation_1-rmse:0.65581
# [47]	validation_0-rmse:0.37833	validation_1-rmse:0.65999
# [48]	validation_0-rmse:0.37834	validation_1-rmse:0.65990
# [49]	validation_0-rmse:0.37376	validation_1-rmse:0.65480
# [50]	validation_0-rmse:0.37373	validation_1-rmse:0.65511
# [51]	validation_0-rmse:0.37374	validation_1-rmse:0.65494
# [52]	validation_0-rmse:0.37378	validation_1-rmse:0.65471
# [53]	validation_0-rmse:0.37375	validation_1-rmse:0.65482
# [54]	validation_0-rmse:0.37375	validation_1-rmse:0.65482
# [55]	validation_0-rmse:0.37374	validation_1-rmse:0.65488
# [56]	validation_0-rmse:0.37098	validation_1-rmse:0.64834
# [57]	validation_0-rmse:0.37095	validation_1-rmse:0.64795
# [58]	validation_0-rmse:0.37095	validation_1-rmse:0.64800
# [59]	validation_0-rmse:0.36965	validation_1-rmse:0.64058
# [0]	validation_0-rmse:1.37940	validation_1-rmse:1.42961
# [1]	validation_0-rmse:1.15679	validation_1-rmse:1.22077
# [2]	validation_0-rmse:0.97581	validation_1-rmse:1.02743
# [3]	validation_0-rmse:0.84598	validation_1-rmse:0.88397
# [4]	validation_0-rmse:0.75812	validation_1-rmse:0.79018
# [5]	validation_0-rmse:0.69450	validation_1-rmse:0.71537
# [6]	validation_0-rmse:0.63933	validation_1-rmse:0.67483
# [7]	validation_0-rmse:0.59746	validation_1-rmse:0.62551
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [8]	validation_0-rmse:0.57138	validation_1-rmse:0.59079
# [9]	validation_0-rmse:0.55846	validation_1-rmse:0.57983
# [10]	validation_0-rmse:0.53744	validation_1-rmse:0.55685
# [11]	validation_0-rmse:0.52359	validation_1-rmse:0.54571
# [12]	validation_0-rmse:0.50912	validation_1-rmse:0.52967
# [13]	validation_0-rmse:0.50072	validation_1-rmse:0.52139
# [14]	validation_0-rmse:0.49390	validation_1-rmse:0.51711
# [15]	validation_0-rmse:0.48456	validation_1-rmse:0.50701
# [16]	validation_0-rmse:0.47639	validation_1-rmse:0.50451
# [17]	validation_0-rmse:0.47304	validation_1-rmse:0.50085
# [18]	validation_0-rmse:0.45997	validation_1-rmse:0.50818
# [19]	validation_0-rmse:0.45554	validation_1-rmse:0.50684
# [20]	validation_0-rmse:0.45139	validation_1-rmse:0.50248
# [21]	validation_0-rmse:0.44550	validation_1-rmse:0.50130
# [22]	validation_0-rmse:0.44550	validation_1-rmse:0.50142
# [23]	validation_0-rmse:0.44086	validation_1-rmse:0.50033
# [24]	validation_0-rmse:0.43398	validation_1-rmse:0.49020
# [25]	validation_0-rmse:0.42960	validation_1-rmse:0.48890
# [26]	validation_0-rmse:0.42949	validation_1-rmse:0.48795
# [27]	validation_0-rmse:0.42922	validation_1-rmse:0.49512
# [28]	validation_0-rmse:0.42625	validation_1-rmse:0.49811
# [29]	validation_0-rmse:0.42254	validation_1-rmse:0.48783
# [30]	validation_0-rmse:0.42199	validation_1-rmse:0.48899
# [31]	validation_0-rmse:0.42208	validation_1-rmse:0.48953
# [32]	validation_0-rmse:0.41702	validation_1-rmse:0.48101
# [33]	validation_0-rmse:0.41380	validation_1-rmse:0.47612
# [34]	validation_0-rmse:0.41289	validation_1-rmse:0.47638
# [35]	validation_0-rmse:0.41288	validation_1-rmse:0.47641
# [36]	validation_0-rmse:0.41283	validation_1-rmse:0.47682
# [37]	validation_0-rmse:0.41283	validation_1-rmse:0.47675
# [38]	validation_0-rmse:0.41167	validation_1-rmse:0.47625
# [39]	validation_0-rmse:0.41162	validation_1-rmse:0.47648
# [40]	validation_0-rmse:0.40710	validation_1-rmse:0.46974
# [41]	validation_0-rmse:0.40525	validation_1-rmse:0.46495
# [42]	validation_0-rmse:0.40150	validation_1-rmse:0.46322
# [43]	validation_0-rmse:0.40169	validation_1-rmse:0.46380
# [44]	validation_0-rmse:0.39801	validation_1-rmse:0.46355
# [45]	validation_0-rmse:0.39804	validation_1-rmse:0.46364
# [46]	validation_0-rmse:0.39788	validation_1-rmse:0.46280
# [47]	validation_0-rmse:0.39789	validation_1-rmse:0.46291
# [48]	validation_0-rmse:0.39794	validation_1-rmse:0.46326
# [49]	validation_0-rmse:0.39791	validation_1-rmse:0.46305
# [50]	validation_0-rmse:0.39312	validation_1-rmse:0.46181
# [51]	validation_0-rmse:0.39310	validation_1-rmse:0.46166
# [52]	validation_0-rmse:0.39133	validation_1-rmse:0.46327
# [53]	validation_0-rmse:0.39106	validation_1-rmse:0.46887
# [54]	validation_0-rmse:0.39105	validation_1-rmse:0.46881
# [55]	validation_0-rmse:0.39103	validation_1-rmse:0.46861
# [56]	validation_0-rmse:0.39110	validation_1-rmse:0.46907
# [57]	validation_0-rmse:0.38701	validation_1-rmse:0.47022
# [58]	validation_0-rmse:0.38493	validation_1-rmse:0.46705
# [59]	validation_0-rmse:0.38493	validation_1-rmse:0.46700
# [0]	validation_0-rmse:1.45009	validation_1-rmse:1.12633
# [1]	validation_0-rmse:1.19195	validation_1-rmse:0.89199
# [2]	validation_0-rmse:0.99976	validation_1-rmse:0.72103
# [3]	validation_0-rmse:0.85746	validation_1-rmse:0.62004
# [4]	validation_0-rmse:0.75889	validation_1-rmse:0.55031
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:0.68672	validation_1-rmse:0.52235
# [6]	validation_0-rmse:0.64114	validation_1-rmse:0.50970
# [7]	validation_0-rmse:0.59247	validation_1-rmse:0.49746
# [8]	validation_0-rmse:0.56379	validation_1-rmse:0.49421
# [9]	validation_0-rmse:0.54408	validation_1-rmse:0.49335
# [10]	validation_0-rmse:0.52562	validation_1-rmse:0.50109
# [11]	validation_0-rmse:0.50878	validation_1-rmse:0.51115
# [12]	validation_0-rmse:0.50055	validation_1-rmse:0.52125
# [13]	validation_0-rmse:0.49567	validation_1-rmse:0.51620
# [14]	validation_0-rmse:0.49246	validation_1-rmse:0.53225
# [15]	validation_0-rmse:0.49176	validation_1-rmse:0.53437
# [16]	validation_0-rmse:0.48663	validation_1-rmse:0.53297
# [17]	validation_0-rmse:0.48077	validation_1-rmse:0.52721
# [18]	validation_0-rmse:0.47708	validation_1-rmse:0.52633
# [19]	validation_0-rmse:0.47318	validation_1-rmse:0.52605
# [20]	validation_0-rmse:0.46725	validation_1-rmse:0.52684
# [21]	validation_0-rmse:0.46308	validation_1-rmse:0.53147
# [22]	validation_0-rmse:0.45663	validation_1-rmse:0.52198
# [23]	validation_0-rmse:0.45313	validation_1-rmse:0.51315
# [24]	validation_0-rmse:0.44515	validation_1-rmse:0.51180
# [25]	validation_0-rmse:0.44111	validation_1-rmse:0.51368
# [26]	validation_0-rmse:0.44114	validation_1-rmse:0.51285
# [27]	validation_0-rmse:0.43111	validation_1-rmse:0.51694
# [28]	validation_0-rmse:0.42742	validation_1-rmse:0.51994
# [29]	validation_0-rmse:0.42744	validation_1-rmse:0.51885
# [0]	validation_0-rmse:1.44491	validation_1-rmse:1.08679
# [1]	validation_0-rmse:1.19266	validation_1-rmse:0.87917
# [2]	validation_0-rmse:1.00416	validation_1-rmse:0.73891
# [3]	validation_0-rmse:0.86552	validation_1-rmse:0.65129
# [4]	validation_0-rmse:0.75606	validation_1-rmse:0.60427
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:0.68013	validation_1-rmse:0.58554
# [6]	validation_0-rmse:0.61987	validation_1-rmse:0.58609
# [7]	validation_0-rmse:0.57756	validation_1-rmse:0.58692
# [8]	validation_0-rmse:0.55553	validation_1-rmse:0.59375
# [9]	validation_0-rmse:0.53862	validation_1-rmse:0.61169
# [10]	validation_0-rmse:0.52152	validation_1-rmse:0.62300
# [11]	validation_0-rmse:0.51779	validation_1-rmse:0.62710
# [12]	validation_0-rmse:0.50488	validation_1-rmse:0.62923
# [13]	validation_0-rmse:0.49771	validation_1-rmse:0.63461
# [14]	validation_0-rmse:0.49368	validation_1-rmse:0.64665
# [15]	validation_0-rmse:0.48983	validation_1-rmse:0.64782
# [16]	validation_0-rmse:0.47907	validation_1-rmse:0.65237
# [17]	validation_0-rmse:0.47722	validation_1-rmse:0.65724
# [18]	validation_0-rmse:0.46848	validation_1-rmse:0.67056
# [19]	validation_0-rmse:0.46255	validation_1-rmse:0.66929
# [20]	validation_0-rmse:0.46254	validation_1-rmse:0.66972
# [21]	validation_0-rmse:0.46253	validation_1-rmse:0.67082
# [22]	validation_0-rmse:0.45674	validation_1-rmse:0.66413
# [23]	validation_0-rmse:0.45675	validation_1-rmse:0.66235
# [24]	validation_0-rmse:0.44460	validation_1-rmse:0.65989
# [25]	validation_0-rmse:0.44321	validation_1-rmse:0.65874
# [0]	validation_0-rmse:1.36805	validation_1-rmse:1.53978
# [1]	validation_0-rmse:1.12901	validation_1-rmse:1.30794
# [2]	validation_0-rmse:0.94350	validation_1-rmse:1.12255
# [3]	validation_0-rmse:0.80581	validation_1-rmse:0.99379
# [4]	validation_0-rmse:0.71253	validation_1-rmse:0.92495
# [5]	validation_0-rmse:0.64632	validation_1-rmse:0.87991
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:0.59527	validation_1-rmse:0.82771
# [7]	validation_0-rmse:0.54150	validation_1-rmse:0.79371
# [8]	validation_0-rmse:0.51855	validation_1-rmse:0.79165
# [9]	validation_0-rmse:0.49900	validation_1-rmse:0.78169
# [10]	validation_0-rmse:0.48500	validation_1-rmse:0.76927
# [11]	validation_0-rmse:0.46783	validation_1-rmse:0.75075
# [12]	validation_0-rmse:0.46007	validation_1-rmse:0.74239
# [13]	validation_0-rmse:0.45819	validation_1-rmse:0.73994
# [14]	validation_0-rmse:0.45359	validation_1-rmse:0.73692
# [15]	validation_0-rmse:0.45080	validation_1-rmse:0.74184
# [16]	validation_0-rmse:0.44358	validation_1-rmse:0.73375
# [17]	validation_0-rmse:0.44356	validation_1-rmse:0.73364
# [18]	validation_0-rmse:0.44119	validation_1-rmse:0.73581
# [19]	validation_0-rmse:0.44109	validation_1-rmse:0.73549
# [20]	validation_0-rmse:0.44119	validation_1-rmse:0.73582
# [21]	validation_0-rmse:0.43649	validation_1-rmse:0.73381
# [22]	validation_0-rmse:0.43048	validation_1-rmse:0.74780
# [23]	validation_0-rmse:0.42642	validation_1-rmse:0.75461
# [24]	validation_0-rmse:0.42028	validation_1-rmse:0.75466
# [25]	validation_0-rmse:0.42040	validation_1-rmse:0.75507
# [26]	validation_0-rmse:0.41314	validation_1-rmse:0.75443
# [27]	validation_0-rmse:0.40974	validation_1-rmse:0.74195
# [28]	validation_0-rmse:0.40437	validation_1-rmse:0.74407
# [29]	validation_0-rmse:0.40439	validation_1-rmse:0.74370
# [30]	validation_0-rmse:0.40443	validation_1-rmse:0.74351
# [31]	validation_0-rmse:0.40299	validation_1-rmse:0.75226
# [32]	validation_0-rmse:0.40250	validation_1-rmse:0.75178
# [33]	validation_0-rmse:0.40283	validation_1-rmse:0.75161
# [34]	validation_0-rmse:0.40219	validation_1-rmse:0.75206
# [35]	validation_0-rmse:0.39758	validation_1-rmse:0.74412
# [36]	validation_0-rmse:0.39756	validation_1-rmse:0.74414
# [37]	validation_0-rmse:0.39416	validation_1-rmse:0.74922
# [0]	validation_0-rmse:1.40327	validation_1-rmse:1.37025
# [1]	validation_0-rmse:1.16264	validation_1-rmse:1.13899
# [2]	validation_0-rmse:0.97116	validation_1-rmse:0.97035
# [3]	validation_0-rmse:0.84941	validation_1-rmse:0.86865
# [4]	validation_0-rmse:0.74717	validation_1-rmse:0.76047
# [5]	validation_0-rmse:0.67477	validation_1-rmse:0.68896
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:0.63373	validation_1-rmse:0.65052
# [7]	validation_0-rmse:0.58345	validation_1-rmse:0.62512
# [8]	validation_0-rmse:0.55941	validation_1-rmse:0.60379
# [9]	validation_0-rmse:0.54508	validation_1-rmse:0.58994
# [10]	validation_0-rmse:0.52298	validation_1-rmse:0.58672
# [11]	validation_0-rmse:0.51347	validation_1-rmse:0.57613
# [12]	validation_0-rmse:0.50435	validation_1-rmse:0.55829
# [13]	validation_0-rmse:0.50206	validation_1-rmse:0.55579
# [14]	validation_0-rmse:0.49775	validation_1-rmse:0.55581
# [15]	validation_0-rmse:0.49427	validation_1-rmse:0.55461
# [16]	validation_0-rmse:0.48661	validation_1-rmse:0.55822
# [17]	validation_0-rmse:0.48241	validation_1-rmse:0.55641
# [18]	validation_0-rmse:0.47421	validation_1-rmse:0.56032
# [19]	validation_0-rmse:0.46193	validation_1-rmse:0.56162
# [20]	validation_0-rmse:0.45879	validation_1-rmse:0.56160
# [21]	validation_0-rmse:0.45691	validation_1-rmse:0.56356
# [22]	validation_0-rmse:0.45675	validation_1-rmse:0.56330
# [23]	validation_0-rmse:0.45270	validation_1-rmse:0.55511
# [24]	validation_0-rmse:0.44425	validation_1-rmse:0.55101
# [25]	validation_0-rmse:0.43816	validation_1-rmse:0.55126
# [26]	validation_0-rmse:0.43570	validation_1-rmse:0.55786
# [27]	validation_0-rmse:0.43299	validation_1-rmse:0.55766
# [28]	validation_0-rmse:0.43301	validation_1-rmse:0.55774
# [29]	validation_0-rmse:0.42573	validation_1-rmse:0.55681
# [30]	validation_0-rmse:0.42441	validation_1-rmse:0.55785
# [31]	validation_0-rmse:0.41912	validation_1-rmse:0.55659
# [32]	validation_0-rmse:0.41260	validation_1-rmse:0.55616
# [33]	validation_0-rmse:0.40482	validation_1-rmse:0.56992
# [34]	validation_0-rmse:0.40508	validation_1-rmse:0.57075
# [35]	validation_0-rmse:0.40021	validation_1-rmse:0.56960
# [36]	validation_0-rmse:0.40003	validation_1-rmse:0.56921
# [37]	validation_0-rmse:0.39980	validation_1-rmse:0.56850
# [38]	validation_0-rmse:0.39609	validation_1-rmse:0.57729
# [39]	validation_0-rmse:0.39077	validation_1-rmse:0.57212
# [40]	validation_0-rmse:0.38779	validation_1-rmse:0.57375
# [41]	validation_0-rmse:0.38772	validation_1-rmse:0.57325
# [42]	validation_0-rmse:0.38451	validation_1-rmse:0.57759
# [43]	validation_0-rmse:0.38455	validation_1-rmse:0.57789
# [0]	validation_0-rmse:1.44145	validation_1-rmse:1.26807
# [1]	validation_0-rmse:1.18879	validation_1-rmse:1.04250
# [2]	validation_0-rmse:0.99366	validation_1-rmse:0.90152
# [3]	validation_0-rmse:0.85846	validation_1-rmse:0.80492
# [4]	validation_0-rmse:0.74437	validation_1-rmse:0.74013
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-rmse:0.65692	validation_1-rmse:0.70198
# [6]	validation_0-rmse:0.60481	validation_1-rmse:0.68944
# [7]	validation_0-rmse:0.55613	validation_1-rmse:0.67121
# [8]	validation_0-rmse:0.52792	validation_1-rmse:0.66845
# [9]	validation_0-rmse:0.50364	validation_1-rmse:0.66562
# [10]	validation_0-rmse:0.48800	validation_1-rmse:0.66386
# [11]	validation_0-rmse:0.48162	validation_1-rmse:0.66508
# [12]	validation_0-rmse:0.47320	validation_1-rmse:0.66252
# [13]	validation_0-rmse:0.46225	validation_1-rmse:0.65544
# [14]	validation_0-rmse:0.45763	validation_1-rmse:0.66196
# [15]	validation_0-rmse:0.45641	validation_1-rmse:0.66333
# [16]	validation_0-rmse:0.45489	validation_1-rmse:0.66602
# [17]	validation_0-rmse:0.45180	validation_1-rmse:0.66889
# [18]	validation_0-rmse:0.44616	validation_1-rmse:0.69182
# [19]	validation_0-rmse:0.43960	validation_1-rmse:0.69101
# [20]	validation_0-rmse:0.43290	validation_1-rmse:0.70091
# [21]	validation_0-rmse:0.42933	validation_1-rmse:0.71441
# [22]	validation_0-rmse:0.42204	validation_1-rmse:0.71803
# [23]	validation_0-rmse:0.41883	validation_1-rmse:0.71797
# [24]	validation_0-rmse:0.41205	validation_1-rmse:0.71721
# [25]	validation_0-rmse:0.41216	validation_1-rmse:0.71644
# [26]	validation_0-rmse:0.41023	validation_1-rmse:0.72740
# [27]	validation_0-rmse:0.40787	validation_1-rmse:0.72791
# [28]	validation_0-rmse:0.40802	validation_1-rmse:0.72673
# [29]	validation_0-rmse:0.40801	validation_1-rmse:0.72679
# [30]	validation_0-rmse:0.40552	validation_1-rmse:0.72055
# [31]	validation_0-rmse:0.40200	validation_1-rmse:0.71849
# [32]	validation_0-rmse:0.39899	validation_1-rmse:0.71496
# [0]	validation_0-rmse:1.44124	validation_1-rmse:1.23422
# [1]	validation_0-rmse:1.18849	validation_1-rmse:1.01385
# [2]	validation_0-rmse:0.99731	validation_1-rmse:0.85218
# [3]	validation_0-rmse:0.86281	validation_1-rmse:0.73033
# [4]	validation_0-rmse:0.75986	validation_1-rmse:0.64410
# [5]	validation_0-rmse:0.68786	validation_1-rmse:0.59273
# [6]	validation_0-rmse:0.63661	validation_1-rmse:0.57095
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [7]	validation_0-rmse:0.59088	validation_1-rmse:0.54685
# [8]	validation_0-rmse:0.56950	validation_1-rmse:0.54154
# [9]	validation_0-rmse:0.55631	validation_1-rmse:0.54132
# [10]	validation_0-rmse:0.53727	validation_1-rmse:0.52783
# [11]	validation_0-rmse:0.52429	validation_1-rmse:0.53093
# [12]	validation_0-rmse:0.51713	validation_1-rmse:0.53002
# [13]	validation_0-rmse:0.50011	validation_1-rmse:0.52830
# [14]	validation_0-rmse:0.49151	validation_1-rmse:0.53416
# [15]	validation_0-rmse:0.48750	validation_1-rmse:0.52506
# [16]	validation_0-rmse:0.47923	validation_1-rmse:0.51660
# [17]	validation_0-rmse:0.47918	validation_1-rmse:0.51690
# [18]	validation_0-rmse:0.47541	validation_1-rmse:0.51582
# [19]	validation_0-rmse:0.47538	validation_1-rmse:0.51615
# [20]	validation_0-rmse:0.47128	validation_1-rmse:0.51319
# [21]	validation_0-rmse:0.46380	validation_1-rmse:0.51730
# [22]	validation_0-rmse:0.46022	validation_1-rmse:0.52393
# [23]	validation_0-rmse:0.45746	validation_1-rmse:0.52361
# [24]	validation_0-rmse:0.44797	validation_1-rmse:0.52300
# [25]	validation_0-rmse:0.43868	validation_1-rmse:0.52962
# [26]	validation_0-rmse:0.43869	validation_1-rmse:0.52990
# [27]	validation_0-rmse:0.43883	validation_1-rmse:0.53203
# [28]	validation_0-rmse:0.43473	validation_1-rmse:0.53102
# [29]	validation_0-rmse:0.43472	validation_1-rmse:0.53178
# [30]	validation_0-rmse:0.43152	validation_1-rmse:0.53570
# [31]	validation_0-rmse:0.43152	validation_1-rmse:0.53476
# [32]	validation_0-rmse:0.42554	validation_1-rmse:0.53048
# [33]	validation_0-rmse:0.42272	validation_1-rmse:0.52247
# [34]	validation_0-rmse:0.41765	validation_1-rmse:0.53570
# [35]	validation_0-rmse:0.41477	validation_1-rmse:0.53401
# [36]	validation_0-rmse:0.41481	validation_1-rmse:0.53306
# [37]	validation_0-rmse:0.41113	validation_1-rmse:0.54616
# [38]	validation_0-rmse:0.40572	validation_1-rmse:0.54319
# [39]	validation_0-rmse:0.40424	validation_1-rmse:0.54489
# [40]	validation_0-rmse:0.40361	validation_1-rmse:0.54747
# [0]	validation_0-rmse:1.39677	validation_1-rmse:1.39610
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [1]	validation_0-rmse:1.16140	validation_1-rmse:1.18978
# [2]	validation_0-rmse:0.96514	validation_1-rmse:1.01066
# [3]	validation_0-rmse:0.83842	validation_1-rmse:0.91214
# [4]	validation_0-rmse:0.73741	validation_1-rmse:0.83733
# [5]	validation_0-rmse:0.66733	validation_1-rmse:0.78899
# [6]	validation_0-rmse:0.62169	validation_1-rmse:0.74145
# [7]	validation_0-rmse:0.58180	validation_1-rmse:0.71909
# [8]	validation_0-rmse:0.55187	validation_1-rmse:0.69739
# [9]	validation_0-rmse:0.53621	validation_1-rmse:0.68767
# [10]	validation_0-rmse:0.51555	validation_1-rmse:0.67870
# [11]	validation_0-rmse:0.50822	validation_1-rmse:0.67794
# [12]	validation_0-rmse:0.49888	validation_1-rmse:0.67238
# [13]	validation_0-rmse:0.48980	validation_1-rmse:0.68171
# [14]	validation_0-rmse:0.48036	validation_1-rmse:0.69008
# [15]	validation_0-rmse:0.47634	validation_1-rmse:0.68504
# [16]	validation_0-rmse:0.47061	validation_1-rmse:0.67696
# [17]	validation_0-rmse:0.46255	validation_1-rmse:0.68239
# [18]	validation_0-rmse:0.45825	validation_1-rmse:0.66505
# [19]	validation_0-rmse:0.45420	validation_1-rmse:0.64629
# [20]	validation_0-rmse:0.45285	validation_1-rmse:0.64032
# [21]	validation_0-rmse:0.45033	validation_1-rmse:0.64396
# [22]	validation_0-rmse:0.44600	validation_1-rmse:0.63579
# [23]	validation_0-rmse:0.43750	validation_1-rmse:0.64393
# [24]	validation_0-rmse:0.43018	validation_1-rmse:0.64510
# [25]	validation_0-rmse:0.43017	validation_1-rmse:0.64558
# [26]	validation_0-rmse:0.42754	validation_1-rmse:0.64680
# [27]	validation_0-rmse:0.42229	validation_1-rmse:0.65685
# [28]	validation_0-rmse:0.41819	validation_1-rmse:0.66242
# [29]	validation_0-rmse:0.41295	validation_1-rmse:0.65944
# [30]	validation_0-rmse:0.40864	validation_1-rmse:0.65678
# [31]	validation_0-rmse:0.40554	validation_1-rmse:0.66909
# [32]	validation_0-rmse:0.39884	validation_1-rmse:0.66910
# [33]	validation_0-rmse:0.39470	validation_1-rmse:0.67089
# [34]	validation_0-rmse:0.39472	validation_1-rmse:0.67018
# [35]	validation_0-rmse:0.39471	validation_1-rmse:0.67035
# [36]	validation_0-rmse:0.39113	validation_1-rmse:0.67235
# [37]	validation_0-rmse:0.38690	validation_1-rmse:0.66323
# [38]	validation_0-rmse:0.38687	validation_1-rmse:0.66342
# [39]	validation_0-rmse:0.38686	validation_1-rmse:0.66348
# [40]	validation_0-rmse:0.38687	validation_1-rmse:0.66342
# [41]	validation_0-rmse:0.38678	validation_1-rmse:0.66403
# [0]	validation_0-rmse:1.42375	validation_1-rmse:1.34367
# [1]	validation_0-rmse:1.18628	validation_1-rmse:1.09675
# [2]	validation_0-rmse:0.99727	validation_1-rmse:0.89503
# [3]	validation_0-rmse:0.86242	validation_1-rmse:0.74017
# [4]	validation_0-rmse:0.76361	validation_1-rmse:0.62711
# [5]	validation_0-rmse:0.69748	validation_1-rmse:0.56527
# [6]	validation_0-rmse:0.64655	validation_1-rmse:0.51924
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [7]	validation_0-rmse:0.60329	validation_1-rmse:0.47468
# [8]	validation_0-rmse:0.57913	validation_1-rmse:0.45630
# [9]	validation_0-rmse:0.56128	validation_1-rmse:0.45712
# [10]	validation_0-rmse:0.54024	validation_1-rmse:0.45145
# [11]	validation_0-rmse:0.53196	validation_1-rmse:0.44899
# [12]	validation_0-rmse:0.52375	validation_1-rmse:0.45878
# [13]	validation_0-rmse:0.51888	validation_1-rmse:0.46455
# [14]	validation_0-rmse:0.50879	validation_1-rmse:0.45618
# [15]	validation_0-rmse:0.50026	validation_1-rmse:0.45620
# [16]	validation_0-rmse:0.49239	validation_1-rmse:0.45018
# [17]	validation_0-rmse:0.48804	validation_1-rmse:0.45225
# [18]	validation_0-rmse:0.48389	validation_1-rmse:0.44768
# [19]	validation_0-rmse:0.47045	validation_1-rmse:0.44930
# [20]	validation_0-rmse:0.46638	validation_1-rmse:0.46165
# [21]	validation_0-rmse:0.45994	validation_1-rmse:0.46711
# [22]	validation_0-rmse:0.45638	validation_1-rmse:0.46928
# [23]	validation_0-rmse:0.45241	validation_1-rmse:0.48100
# [24]	validation_0-rmse:0.44764	validation_1-rmse:0.46905
# [25]	validation_0-rmse:0.44486	validation_1-rmse:0.47414
# [26]	validation_0-rmse:0.44143	validation_1-rmse:0.47613
# [27]	validation_0-rmse:0.44146	validation_1-rmse:0.47397
# [28]	validation_0-rmse:0.43674	validation_1-rmse:0.47726
# [29]	validation_0-rmse:0.42824	validation_1-rmse:0.47924
# [30]	validation_0-rmse:0.42404	validation_1-rmse:0.47922
# [31]	validation_0-rmse:0.42087	validation_1-rmse:0.47787
# [32]	validation_0-rmse:0.41791	validation_1-rmse:0.47247
# [33]	validation_0-rmse:0.41539	validation_1-rmse:0.46521
# [34]	validation_0-rmse:0.41540	validation_1-rmse:0.46493
# [35]	validation_0-rmse:0.41224	validation_1-rmse:0.46471
# [36]	validation_0-rmse:0.40827	validation_1-rmse:0.47286
# [37]	validation_0-rmse:0.40734	validation_1-rmse:0.47602
# [38]	validation_0-rmse:0.40734	validation_1-rmse:0.47621
# [0]	validation_0-rmse:1.43854	validation_1-rmse:1.26263
# [1]	validation_0-rmse:1.18196	validation_1-rmse:1.05322
# [2]	validation_0-rmse:0.98373	validation_1-rmse:0.92835
# [3]	validation_0-rmse:0.84734	validation_1-rmse:0.83934
# [4]	validation_0-rmse:0.75348	validation_1-rmse:0.77228
# [5]	validation_0-rmse:0.67318	validation_1-rmse:0.71894
# [6]	validation_0-rmse:0.61736	validation_1-rmse:0.68917
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [7]	validation_0-rmse:0.55851	validation_1-rmse:0.68085
# [8]	validation_0-rmse:0.53438	validation_1-rmse:0.66880
# [9]	validation_0-rmse:0.52137	validation_1-rmse:0.66386
# [10]	validation_0-rmse:0.50278	validation_1-rmse:0.65552
# [11]	validation_0-rmse:0.49196	validation_1-rmse:0.65673
# [12]	validation_0-rmse:0.48308	validation_1-rmse:0.66780
# [13]	validation_0-rmse:0.47092	validation_1-rmse:0.66701
# [14]	validation_0-rmse:0.46745	validation_1-rmse:0.66751
# [15]	validation_0-rmse:0.46445	validation_1-rmse:0.66773
# [16]	validation_0-rmse:0.46035	validation_1-rmse:0.66783
# [17]	validation_0-rmse:0.45134	validation_1-rmse:0.66925
# [18]	validation_0-rmse:0.45045	validation_1-rmse:0.66176
# [19]	validation_0-rmse:0.45065	validation_1-rmse:0.66134
# [20]	validation_0-rmse:0.44680	validation_1-rmse:0.66667
# [21]	validation_0-rmse:0.44676	validation_1-rmse:0.66675
# [22]	validation_0-rmse:0.43724	validation_1-rmse:0.65665
# [23]	validation_0-rmse:0.43728	validation_1-rmse:0.65648
# [24]	validation_0-rmse:0.42995	validation_1-rmse:0.66145
# [25]	validation_0-rmse:0.42682	validation_1-rmse:0.66242
# [26]	validation_0-rmse:0.42257	validation_1-rmse:0.66154
# [27]	validation_0-rmse:0.42256	validation_1-rmse:0.66161
# [28]	validation_0-rmse:0.41915	validation_1-rmse:0.66070
# [29]	validation_0-rmse:0.41915	validation_1-rmse:0.66105
# [30]	validation_0-rmse:0.41428	validation_1-rmse:0.66656
# [0]	validation_0-rmse:1.44325	validation_1-rmse:1.25630
# [1]	validation_0-rmse:1.19926	validation_1-rmse:1.03403
# [2]	validation_0-rmse:0.99581	validation_1-rmse:0.85511
# [3]	validation_0-rmse:0.86088	validation_1-rmse:0.74776
# [4]	validation_0-rmse:0.75264	validation_1-rmse:0.68135
# [5]	validation_0-rmse:0.67600	validation_1-rmse:0.63893
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:0.63149	validation_1-rmse:0.60630
# [7]	validation_0-rmse:0.58315	validation_1-rmse:0.58974
# [8]	validation_0-rmse:0.56302	validation_1-rmse:0.57297
# [9]	validation_0-rmse:0.53488	validation_1-rmse:0.57687
# [10]	validation_0-rmse:0.51398	validation_1-rmse:0.57690
# [11]	validation_0-rmse:0.49797	validation_1-rmse:0.58803
# [12]	validation_0-rmse:0.48360	validation_1-rmse:0.59767
# [13]	validation_0-rmse:0.47639	validation_1-rmse:0.59567
# [14]	validation_0-rmse:0.47388	validation_1-rmse:0.60136
# [15]	validation_0-rmse:0.46761	validation_1-rmse:0.59933
# [16]	validation_0-rmse:0.46043	validation_1-rmse:0.60206
# [17]	validation_0-rmse:0.45658	validation_1-rmse:0.59602
# [18]	validation_0-rmse:0.45428	validation_1-rmse:0.59806
# [19]	validation_0-rmse:0.44857	validation_1-rmse:0.59824
# [20]	validation_0-rmse:0.44481	validation_1-rmse:0.59907
# [21]	validation_0-rmse:0.43948	validation_1-rmse:0.60284
# [22]	validation_0-rmse:0.43732	validation_1-rmse:0.60265
# [23]	validation_0-rmse:0.43176	validation_1-rmse:0.62056
# [24]	validation_0-rmse:0.42441	validation_1-rmse:0.62636
# [25]	validation_0-rmse:0.42432	validation_1-rmse:0.63006
# [26]	validation_0-rmse:0.42439	validation_1-rmse:0.62673
# [27]	validation_0-rmse:0.41571	validation_1-rmse:0.62077
# [28]	validation_0-rmse:0.40579	validation_1-rmse:0.62197
# [0]	validation_0-rmse:1.41014	validation_1-rmse:1.32720
# [1]	validation_0-rmse:1.16485	validation_1-rmse:1.10006
# [2]	validation_0-rmse:0.97322	validation_1-rmse:0.89459
# [3]	validation_0-rmse:0.84056	validation_1-rmse:0.77866
# [4]	validation_0-rmse:0.74740	validation_1-rmse:0.67821
# [5]	validation_0-rmse:0.68281	validation_1-rmse:0.63800
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:0.63796	validation_1-rmse:0.61461
# [7]	validation_0-rmse:0.58808	validation_1-rmse:0.57994
# [8]	validation_0-rmse:0.56802	validation_1-rmse:0.58236
# [9]	validation_0-rmse:0.54782	validation_1-rmse:0.57443
# [10]	validation_0-rmse:0.52533	validation_1-rmse:0.55135
# [11]	validation_0-rmse:0.51379	validation_1-rmse:0.55431
# [12]	validation_0-rmse:0.50299	validation_1-rmse:0.56160
# [13]	validation_0-rmse:0.49886	validation_1-rmse:0.55675
# [14]	validation_0-rmse:0.48712	validation_1-rmse:0.52522
# [15]	validation_0-rmse:0.48363	validation_1-rmse:0.53749
# [16]	validation_0-rmse:0.47352	validation_1-rmse:0.53983
# [17]	validation_0-rmse:0.46843	validation_1-rmse:0.55073
# [18]	validation_0-rmse:0.46180	validation_1-rmse:0.54906
# [19]	validation_0-rmse:0.45463	validation_1-rmse:0.55660
# [20]	validation_0-rmse:0.45057	validation_1-rmse:0.55604
# [21]	validation_0-rmse:0.44404	validation_1-rmse:0.56092
# [22]	validation_0-rmse:0.44138	validation_1-rmse:0.56291
# [23]	validation_0-rmse:0.44134	validation_1-rmse:0.56353
# [24]	validation_0-rmse:0.43328	validation_1-rmse:0.56621
# [25]	validation_0-rmse:0.43325	validation_1-rmse:0.56684
# [26]	validation_0-rmse:0.43166	validation_1-rmse:0.55972
# [27]	validation_0-rmse:0.42725	validation_1-rmse:0.55369
# [28]	validation_0-rmse:0.42744	validation_1-rmse:0.55258
# ...
#   warnings.warn(
# [2]	validation_0-rmse:1.00875	validation_1-rmse:0.76820
# [3]	validation_0-rmse:0.86463	validation_1-rmse:0.67988
# [4]	validation_0-rmse:0.75381	validation_1-rmse:0.59364
# [5]	validation_0-rmse:0.69537	validation_1-rmse:0.57445
# [6]	validation_0-rmse:0.63912	validation_1-rmse:0.54176
# [7]	validation_0-rmse:0.59707	validation_1-rmse:0.52471
# [8]	validation_0-rmse:0.57322	validation_1-rmse:0.52323
# [9]	validation_0-rmse:0.55034	validation_1-rmse:0.51139
# [10]	validation_0-rmse:0.53598	validation_1-rmse:0.50796
# [11]	validation_0-rmse:0.52601	validation_1-rmse:0.51398
# [12]	validation_0-rmse:0.51181	validation_1-rmse:0.51044
# [13]	validation_0-rmse:0.50320	validation_1-rmse:0.51983
# [14]	validation_0-rmse:0.50077	validation_1-rmse:0.53864
# [15]	validation_0-rmse:0.49845	validation_1-rmse:0.54400
# [16]	validation_0-rmse:0.49016	validation_1-rmse:0.54745
# [17]	validation_0-rmse:0.48015	validation_1-rmse:0.55491
# [18]	validation_0-rmse:0.47580	validation_1-rmse:0.54771
# [19]	validation_0-rmse:0.46980	validation_1-rmse:0.55015
# [20]	validation_0-rmse:0.46297	validation_1-rmse:0.55548
# [21]	validation_0-rmse:0.45364	validation_1-rmse:0.54423
# [22]	validation_0-rmse:0.45371	validation_1-rmse:0.54329
# [23]	validation_0-rmse:0.44734	validation_1-rmse:0.54686
# [24]	validation_0-rmse:0.44064	validation_1-rmse:0.54413
# [25]	validation_0-rmse:0.43366	validation_1-rmse:0.54863
# [26]	validation_0-rmse:0.42970	validation_1-rmse:0.54685
# [27]	validation_0-rmse:0.42295	validation_1-rmse:0.54273
# [28]	validation_0-rmse:0.41890	validation_1-rmse:0.54648
# [29]	validation_0-rmse:0.41893	validation_1-rmse:0.54580
# [0]	validation_0-rmse:1.41635	validation_1-rmse:1.34984
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [1]	validation_0-rmse:1.17197	validation_1-rmse:1.09919
# [2]	validation_0-rmse:0.99049	validation_1-rmse:0.90986
# [3]	validation_0-rmse:0.85199	validation_1-rmse:0.77650
# [4]	validation_0-rmse:0.76265	validation_1-rmse:0.69302
# [5]	validation_0-rmse:0.69026	validation_1-rmse:0.63532
# [6]	validation_0-rmse:0.63312	validation_1-rmse:0.58551
# [7]	validation_0-rmse:0.59324	validation_1-rmse:0.56031
# [8]	validation_0-rmse:0.57097	validation_1-rmse:0.54581
# [9]	validation_0-rmse:0.55180	validation_1-rmse:0.54051
# [10]	validation_0-rmse:0.53393	validation_1-rmse:0.54270
# [11]	validation_0-rmse:0.51515	validation_1-rmse:0.54623
# [12]	validation_0-rmse:0.50713	validation_1-rmse:0.55107
# [13]	validation_0-rmse:0.50217	validation_1-rmse:0.55229
# [14]	validation_0-rmse:0.49157	validation_1-rmse:0.55676
# [15]	validation_0-rmse:0.48533	validation_1-rmse:0.55737
# [16]	validation_0-rmse:0.47498	validation_1-rmse:0.56571
# [17]	validation_0-rmse:0.47442	validation_1-rmse:0.56648
# [18]	validation_0-rmse:0.47249	validation_1-rmse:0.56530
# [19]	validation_0-rmse:0.46593	validation_1-rmse:0.56837
# [20]	validation_0-rmse:0.46353	validation_1-rmse:0.57569
# [21]	validation_0-rmse:0.46169	validation_1-rmse:0.57812
# [22]	validation_0-rmse:0.45938	validation_1-rmse:0.57547
# [23]	validation_0-rmse:0.45150	validation_1-rmse:0.57618
# [24]	validation_0-rmse:0.44630	validation_1-rmse:0.57417
# [25]	validation_0-rmse:0.44044	validation_1-rmse:0.57806
# [26]	validation_0-rmse:0.43698	validation_1-rmse:0.57659
# [27]	validation_0-rmse:0.43196	validation_1-rmse:0.56730
# [28]	validation_0-rmse:0.42943	validation_1-rmse:0.56884
# [29]	validation_0-rmse:0.42942	validation_1-rmse:0.57045
# [0]	validation_0-rmse:1.45287	validation_1-rmse:1.17746
# [1]	validation_0-rmse:1.19459	validation_1-rmse:0.97463
# [2]	validation_0-rmse:0.99914	validation_1-rmse:0.83105
# [3]	validation_0-rmse:0.84835	validation_1-rmse:0.71942
# [4]	validation_0-rmse:0.75050	validation_1-rmse:0.65764
# [5]	validation_0-rmse:0.68853	validation_1-rmse:0.60850
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:0.63523	validation_1-rmse:0.61009
# [7]	validation_0-rmse:0.57710	validation_1-rmse:0.61532
# [8]	validation_0-rmse:0.55205	validation_1-rmse:0.60627
# [9]	validation_0-rmse:0.53209	validation_1-rmse:0.60371
# [10]	validation_0-rmse:0.51338	validation_1-rmse:0.61446
# [11]	validation_0-rmse:0.50341	validation_1-rmse:0.60590
# [12]	validation_0-rmse:0.49418	validation_1-rmse:0.59454
# [13]	validation_0-rmse:0.48589	validation_1-rmse:0.58697
# [14]	validation_0-rmse:0.48194	validation_1-rmse:0.58231
# [15]	validation_0-rmse:0.48014	validation_1-rmse:0.58202
# [16]	validation_0-rmse:0.47353	validation_1-rmse:0.58531
# [17]	validation_0-rmse:0.46801	validation_1-rmse:0.58435
# [18]	validation_0-rmse:0.46037	validation_1-rmse:0.58850
# [19]	validation_0-rmse:0.45129	validation_1-rmse:0.58737
# [20]	validation_0-rmse:0.44718	validation_1-rmse:0.59023
# [21]	validation_0-rmse:0.43836	validation_1-rmse:0.58453
# [22]	validation_0-rmse:0.43871	validation_1-rmse:0.58482
# [23]	validation_0-rmse:0.43088	validation_1-rmse:0.57350
# [24]	validation_0-rmse:0.42385	validation_1-rmse:0.57344
# [25]	validation_0-rmse:0.42374	validation_1-rmse:0.57328
# [26]	validation_0-rmse:0.41412	validation_1-rmse:0.56632
# [27]	validation_0-rmse:0.41148	validation_1-rmse:0.56522
# [28]	validation_0-rmse:0.40632	validation_1-rmse:0.56166
# [29]	validation_0-rmse:0.40277	validation_1-rmse:0.55936
# [30]	validation_0-rmse:0.40230	validation_1-rmse:0.57347
# [31]	validation_0-rmse:0.40229	validation_1-rmse:0.57349
# [32]	validation_0-rmse:0.39548	validation_1-rmse:0.57384
# [33]	validation_0-rmse:0.39015	validation_1-rmse:0.57412
# [34]	validation_0-rmse:0.38744	validation_1-rmse:0.56487
# [35]	validation_0-rmse:0.38354	validation_1-rmse:0.56804
# [36]	validation_0-rmse:0.38368	validation_1-rmse:0.56786
# [37]	validation_0-rmse:0.37907	validation_1-rmse:0.57266
# [38]	validation_0-rmse:0.37907	validation_1-rmse:0.57265
# [39]	validation_0-rmse:0.37908	validation_1-rmse:0.57263
# [40]	validation_0-rmse:0.37793	validation_1-rmse:0.56328
# [41]	validation_0-rmse:0.37799	validation_1-rmse:0.56375
# [42]	validation_0-rmse:0.37796	validation_1-rmse:0.56366
# [43]	validation_0-rmse:0.37073	validation_1-rmse:0.57563
# [44]	validation_0-rmse:0.37068	validation_1-rmse:0.57528
# [45]	validation_0-rmse:0.37068	validation_1-rmse:0.57527
# [46]	validation_0-rmse:0.37072	validation_1-rmse:0.57505
# [47]	validation_0-rmse:0.36724	validation_1-rmse:0.58153
# [48]	validation_0-rmse:0.36726	validation_1-rmse:0.58144
# [0]	validation_0-rmse:1.44860	validation_1-rmse:1.12492
# [1]	validation_0-rmse:1.18919	validation_1-rmse:0.94042
# [2]	validation_0-rmse:0.99985	validation_1-rmse:0.81615
# [3]	validation_0-rmse:0.86308	validation_1-rmse:0.72545
# [4]	validation_0-rmse:0.76255	validation_1-rmse:0.66312
# [5]	validation_0-rmse:0.69096	validation_1-rmse:0.62183
# [6]	validation_0-rmse:0.64386	validation_1-rmse:0.58872
# [7]	validation_0-rmse:0.59628	validation_1-rmse:0.56402
# [8]	validation_0-rmse:0.57513	validation_1-rmse:0.55196
# [9]	validation_0-rmse:0.55940	validation_1-rmse:0.54566
# [10]	validation_0-rmse:0.54212	validation_1-rmse:0.54471
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [11]	validation_0-rmse:0.52900	validation_1-rmse:0.52945
# [12]	validation_0-rmse:0.52513	validation_1-rmse:0.53031
# [13]	validation_0-rmse:0.51492	validation_1-rmse:0.52909
# [14]	validation_0-rmse:0.50910	validation_1-rmse:0.53231
# [15]	validation_0-rmse:0.50604	validation_1-rmse:0.53337
# [16]	validation_0-rmse:0.49830	validation_1-rmse:0.53637
# [17]	validation_0-rmse:0.49350	validation_1-rmse:0.53530
# [18]	validation_0-rmse:0.48582	validation_1-rmse:0.53482
# [19]	validation_0-rmse:0.48349	validation_1-rmse:0.53645
# [20]	validation_0-rmse:0.47896	validation_1-rmse:0.52985
# [21]	validation_0-rmse:0.47316	validation_1-rmse:0.53034
# [22]	validation_0-rmse:0.47290	validation_1-rmse:0.53181
# [23]	validation_0-rmse:0.46497	validation_1-rmse:0.52256
# [24]	validation_0-rmse:0.45380	validation_1-rmse:0.52020
# [25]	validation_0-rmse:0.45375	validation_1-rmse:0.52036
# [26]	validation_0-rmse:0.45229	validation_1-rmse:0.52159
# [27]	validation_0-rmse:0.44741	validation_1-rmse:0.51740
# [28]	validation_0-rmse:0.44098	validation_1-rmse:0.51279
# [29]	validation_0-rmse:0.43703	validation_1-rmse:0.50756
# [30]	validation_0-rmse:0.43290	validation_1-rmse:0.50761
# [31]	validation_0-rmse:0.43290	validation_1-rmse:0.50838
# [32]	validation_0-rmse:0.42810	validation_1-rmse:0.50728
# [33]	validation_0-rmse:0.42490	validation_1-rmse:0.50697
# [34]	validation_0-rmse:0.41966	validation_1-rmse:0.51048
# [35]	validation_0-rmse:0.41986	validation_1-rmse:0.51105
# [36]	validation_0-rmse:0.41962	validation_1-rmse:0.51034
# [37]	validation_0-rmse:0.41631	validation_1-rmse:0.51353
# [38]	validation_0-rmse:0.41389	validation_1-rmse:0.50889
# [39]	validation_0-rmse:0.41411	validation_1-rmse:0.50950
# [40]	validation_0-rmse:0.41381	validation_1-rmse:0.50862
# [41]	validation_0-rmse:0.41419	validation_1-rmse:0.50970
# [42]	validation_0-rmse:0.41054	validation_1-rmse:0.50877
# [43]	validation_0-rmse:0.40305	validation_1-rmse:0.51202
# [44]	validation_0-rmse:0.40057	validation_1-rmse:0.51299
# [45]	validation_0-rmse:0.39678	validation_1-rmse:0.51598
# [46]	validation_0-rmse:0.39674	validation_1-rmse:0.51579
# [47]	validation_0-rmse:0.39670	validation_1-rmse:0.51557
# [48]	validation_0-rmse:0.39371	validation_1-rmse:0.51874
# [49]	validation_0-rmse:0.39374	validation_1-rmse:0.51858
# [50]	validation_0-rmse:0.38988	validation_1-rmse:0.51850
# [51]	validation_0-rmse:0.38990	validation_1-rmse:0.51869
# [52]	validation_0-rmse:0.38989	validation_1-rmse:0.51862
# [0]	validation_0-rmse:1.43497	validation_1-rmse:1.31848
# [1]	validation_0-rmse:1.18288	validation_1-rmse:1.12724
# [2]	validation_0-rmse:0.98405	validation_1-rmse:0.98137
# [3]	validation_0-rmse:0.83776	validation_1-rmse:0.88838
# [4]	validation_0-rmse:0.75599	validation_1-rmse:0.84480
# [5]	validation_0-rmse:0.68312	validation_1-rmse:0.79093
# [6]	validation_0-rmse:0.62539	validation_1-rmse:0.74896
# [7]	validation_0-rmse:0.57752	validation_1-rmse:0.72591
# [8]	validation_0-rmse:0.55171	validation_1-rmse:0.72188
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [9]	validation_0-rmse:0.53593	validation_1-rmse:0.70872
# [10]	validation_0-rmse:0.51460	validation_1-rmse:0.70449
# [11]	validation_0-rmse:0.50087	validation_1-rmse:0.69415
# [12]	validation_0-rmse:0.49636	validation_1-rmse:0.68746
# [13]	validation_0-rmse:0.49387	validation_1-rmse:0.68723
# [14]	validation_0-rmse:0.48384	validation_1-rmse:0.70596
# [15]	validation_0-rmse:0.48199	validation_1-rmse:0.70360
# [16]	validation_0-rmse:0.46855	validation_1-rmse:0.69939
# [17]	validation_0-rmse:0.46800	validation_1-rmse:0.69860
# [18]	validation_0-rmse:0.45870	validation_1-rmse:0.69890
# [19]	validation_0-rmse:0.45799	validation_1-rmse:0.69778
# [20]	validation_0-rmse:0.45475	validation_1-rmse:0.69924
# [21]	validation_0-rmse:0.43907	validation_1-rmse:0.70341
# [22]	validation_0-rmse:0.43887	validation_1-rmse:0.70257
# [23]	validation_0-rmse:0.43887	validation_1-rmse:0.70239
# [24]	validation_0-rmse:0.43175	validation_1-rmse:0.70242
# [25]	validation_0-rmse:0.43174	validation_1-rmse:0.70248
# [26]	validation_0-rmse:0.43192	validation_1-rmse:0.70401
# [27]	validation_0-rmse:0.43170	validation_1-rmse:0.70279
# [28]	validation_0-rmse:0.43193	validation_1-rmse:0.69782
# [29]	validation_0-rmse:0.41825	validation_1-rmse:0.70847
# [30]	validation_0-rmse:0.41500	validation_1-rmse:0.71535
# [31]	validation_0-rmse:0.41198	validation_1-rmse:0.71277
# [32]	validation_0-rmse:0.40775	validation_1-rmse:0.71602
# [0]	validation_0-rmse:1.41208	validation_1-rmse:1.34594
# [1]	validation_0-rmse:1.16811	validation_1-rmse:1.13636
# [2]	validation_0-rmse:0.97642	validation_1-rmse:0.95935
# [3]	validation_0-rmse:0.83109	validation_1-rmse:0.85076
# [4]	validation_0-rmse:0.72627	validation_1-rmse:0.77034
# [5]	validation_0-rmse:0.65495	validation_1-rmse:0.72362
# [6]	validation_0-rmse:0.60475	validation_1-rmse:0.69994
# [7]	validation_0-rmse:0.56435	validation_1-rmse:0.65782
# [8]	validation_0-rmse:0.54157	validation_1-rmse:0.64886
# [9]	validation_0-rmse:0.52478	validation_1-rmse:0.64133
# [10]	validation_0-rmse:0.50868	validation_1-rmse:0.63124
# [11]	validation_0-rmse:0.49834	validation_1-rmse:0.63699
# [12]	validation_0-rmse:0.48972	validation_1-rmse:0.64269
# [13]	validation_0-rmse:0.47943	validation_1-rmse:0.63590
# [14]	validation_0-rmse:0.47010	validation_1-rmse:0.62830
# [15]	validation_0-rmse:0.46937	validation_1-rmse:0.62897
# [16]	validation_0-rmse:0.46557	validation_1-rmse:0.62199
# [17]	validation_0-rmse:0.46291	validation_1-rmse:0.61942
# [18]	validation_0-rmse:0.45484	validation_1-rmse:0.62119
# [19]	validation_0-rmse:0.45163	validation_1-rmse:0.62285
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [20]	validation_0-rmse:0.44643	validation_1-rmse:0.62529
# [21]	validation_0-rmse:0.44648	validation_1-rmse:0.62580
# [22]	validation_0-rmse:0.44643	validation_1-rmse:0.62531
# [23]	validation_0-rmse:0.44377	validation_1-rmse:0.62595
# [24]	validation_0-rmse:0.43618	validation_1-rmse:0.61388
# [25]	validation_0-rmse:0.43008	validation_1-rmse:0.62386
# [26]	validation_0-rmse:0.42763	validation_1-rmse:0.63143
# [27]	validation_0-rmse:0.42577	validation_1-rmse:0.63422
# [28]	validation_0-rmse:0.41937	validation_1-rmse:0.64490
# [29]	validation_0-rmse:0.41501	validation_1-rmse:0.64654
# [30]	validation_0-rmse:0.41429	validation_1-rmse:0.65251
# [31]	validation_0-rmse:0.41180	validation_1-rmse:0.65640
# [32]	validation_0-rmse:0.40822	validation_1-rmse:0.65136
# [33]	validation_0-rmse:0.40511	validation_1-rmse:0.64663
# [34]	validation_0-rmse:0.40548	validation_1-rmse:0.64776
# [35]	validation_0-rmse:0.40518	validation_1-rmse:0.64688
# [36]	validation_0-rmse:0.40289	validation_1-rmse:0.65310
# [37]	validation_0-rmse:0.40289	validation_1-rmse:0.65310
# [38]	validation_0-rmse:0.39907	validation_1-rmse:0.64666
# [39]	validation_0-rmse:0.39510	validation_1-rmse:0.64528
# [40]	validation_0-rmse:0.39109	validation_1-rmse:0.64406
# [41]	validation_0-rmse:0.39112	validation_1-rmse:0.64419
# [42]	validation_0-rmse:0.38761	validation_1-rmse:0.64828
# [43]	validation_0-rmse:0.38373	validation_1-rmse:0.64412
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 23.955, median: 17.0,
#  pred. interval (P(0.025)-P(0.975)): 7.0-58.0,
#  conf. interval (p-value=0.95): 13.945-29.29
# ***
# Aggregate bias statistic:
#  mean: 1.212, median: 0.877,
#  pred. interval (P(0.025)-P(0.975)): -2.099-5.981,
#  conf. interval (p-value=0.95): 0.137-1.873
# ***
# Aggregate RMSE statistic:
#  mean: 0.587, median: 0.583, pred. interval (P(0.025)-P(0.975)): 0.44-0.752,
#  conf. interval (p-value=0.95): 0.552-0.62
# ***
# Aggregate MSE statistic:
#  mean: 0.351, median: 0.34, pred. interval (P(0.025)-P(0.975)): 0.193-0.566,
#  conf. interval (p-value=0.95): 0.306-0.386
# ***
# Aggregate R^2 statistic:
#  mean: 0.406, median: 0.434, pred. interval (P(0.025)-P(0.975)): 0.021-0.674,
#  conf. interval (p-value=0.95): 0.345-0.498
# ***
# Aggregate bias(%) statistic:
#  mean: -0.982, median: 0.877, pred. interval (P(0.025)-P(0.975)): -4.475-2.447,
#  conf. interval (p-value=0.95): -1.73--0.145
# ***
# Aggregate RMSE(%) statistic:
#  mean: -0.584, median: -0.569, pred. interval (P(0.025)-P(0.975)): -0.823--0.429,
#  conf. interval (p-value=0.95): -0.616--0.534
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.39652
# [1]	validation_0-rmse:1.16317
# [2]	validation_0-rmse:0.98086
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:0.84690
# [4]	validation_0-rmse:0.74721
# [5]	validation_0-rmse:0.68001
# [6]	validation_0-rmse:0.63793
# [7]	validation_0-rmse:0.60819
# [8]	validation_0-rmse:0.57572
# [9]	validation_0-rmse:0.56046
# [10]	validation_0-rmse:0.55144
# [11]	validation_0-rmse:0.53959
# [12]	validation_0-rmse:0.52481
# [13]	validation_0-rmse:0.51882
# [14]	validation_0-rmse:0.51022
# [15]	validation_0-rmse:0.50452
# [16]	validation_0-rmse:0.49637
# [17]	validation_0-rmse:0.48497
# [18]	validation_0-rmse:0.48201
# [19]	validation_0-rmse:0.48205
# [20]	validation_0-rmse:0.47569
# [21]	validation_0-rmse:0.46853
# [22]	validation_0-rmse:0.46379
# [23]	validation_0-rmse:0.45215
# [24]	validation_0-rmse:0.44575
# [25]	validation_0-rmse:0.44235
# [26]	validation_0-rmse:0.43949
# [27]	validation_0-rmse:0.43969
# [28]	validation_0-rmse:0.43586
# [29]	validation_0-rmse:0.42993
# [30]	validation_0-rmse:0.42609
# [31]	validation_0-rmse:0.42491
# [32]	validation_0-rmse:0.42081
# [33]	validation_0-rmse:0.41441
# [34]	validation_0-rmse:0.41113
# [35]	validation_0-rmse:0.40580
# [36]	validation_0-rmse:0.40374
# [37]	validation_0-rmse:0.40368
# [38]	validation_0-rmse:0.40327
# [39]	validation_0-rmse:0.40010
# [40]	validation_0-rmse:0.39778
# [41]	validation_0-rmse:0.39764
# [42]	validation_0-rmse:0.39761
# [43]	validation_0-rmse:0.39760
# [44]	validation_0-rmse:0.39527
# [45]	validation_0-rmse:0.39218
# [46]	validation_0-rmse:0.38713
# [47]	validation_0-rmse:0.38717
# [48]	validation_0-rmse:0.38717
# [49]	validation_0-rmse:0.38177
# [50]	validation_0-rmse:0.37776
# [51]	validation_0-rmse:0.37676
# [52]	validation_0-rmse:0.37657
# [53]	validation_0-rmse:0.37657
# [54]	validation_0-rmse:0.37653
# [55]	validation_0-rmse:0.37352
# [56]	validation_0-rmse:0.37320
# [57]	validation_0-rmse:0.36581
# [58]	validation_0-rmse:0.36577
# [59]	validation_0-rmse:0.36317
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 59

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  -0.83
# RMSE: 0.4
# Relative RMSE(%):  -0.356
# MSE: 0.1
# R square: 79.4%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: -0.306
# a1: 0.692
# R^2: 0.811
# Uncertainty
# a0: -0.31+/-0.04
# a1: 0.692+/-0.033

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Mfoliage_XGB_model_without_texture.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Mfoliage_XGB_model_without_texture.txt")
