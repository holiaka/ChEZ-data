# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25 idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167  0.050549
# 1           3600       8.189          15100  ...   0.040919  0.048889
# 2           4360       8.380          14600  ...   0.042397  0.050463
# 3           3420       8.137          12700  ...   0.043719  0.052974
# 4           2200       7.696          12100  ...   0.040659  0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX  idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966    0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602    0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265    0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465    0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420    0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 159 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
            


# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0       4.8122           1.7630               -0.3147           -0.1590
# 1       5.7589           2.4570               -0.2485            0.3429
# 2       5.8464           2.5153               -0.1054            0.5493
# 3       5.7526           2.6304               -0.0834            0.3900
# 4       5.9480           2.6748                0.0000            0.5715
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  \
# 0             -2.4418         1.9125     0.85    12.233545   19.097736    243
# 1             -0.1997         2.6319     1.00    14.964220   17.704655    248
# 2             -0.2144         2.7020     1.00    15.329449   17.559893    240
# 3             -0.3510         2.7763     0.97    15.392742   20.676994    244
# 4             -0.3711         2.8314     1.00    17.944009   21.851387    243
#
#    contr_g_MAX
# 0  2961.898193
# 1  2218.239746
# 2  2220.297119
# 3  3033.770752
# 4  3003.818848

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
#  9   g_MAX                 103 non-null    int64
#  10  contr_g_MAX           103 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 9.0 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["M_crown_kg_m2", "M_foliage_kg_m2"].describe()
# Out:
# /tmp/ipykernel_45251/4127234604.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_specias"])["M_crown_kg_m2", "M_foliage_kg_m2"].describe()
#                  M_crown_kg_m2                                             \
#                          count      mean       std    min      25%    50%
# Dominant_specias
# Alder                      4.0  1.059000  0.593217  0.476  0.68825  0.958
# Aspen                      1.0  1.173000       NaN  1.173  1.17300  1.173
# Birch                     23.0  1.039609  0.409105  0.303  0.77850  1.049
# Oak                        3.0  2.085000  1.209736  1.344  1.38700  1.430
# Pine                      71.0  1.272141  0.638357  0.211  0.82000  1.381
# Spruce                     1.0  4.105000       NaN  4.105  4.10500  4.105
#
#                                  M_foliage_kg_m2                             \
#                       75%    max           count      mean       std    min
# Dominant_specias
# Alder             1.32875  1.844             4.0  0.312000  0.145801  0.130
# Aspen             1.17300  1.173             1.0  0.168000       NaN  0.168
# Birch             1.29450  1.816            23.0  0.189304  0.080503  0.054
# Oak               2.45550  3.481             3.0  0.294333  0.078621  0.205
# Pine              1.67050  2.735            71.0  0.569746  0.267121  0.059
# Spruce            4.10500  4.105             1.0  1.043000       NaN  1.043
#
#
#                       25%     50%      75%    max
# Dominant_specias
# Alder             0.26875  0.3155  0.35875  0.487
# Aspen             0.16800  0.1680  0.16800  0.168
# Birch             0.12500  0.1850  0.25450  0.399
# Oak               0.26500  0.3250  0.33900  0.353
# Pine              0.41950  0.6390  0.74550  1.121
# Spruce            1.04300  1.0430  1.04300  1.043

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000         103.00000
# mean      4.969534         1.827923             -0.239481           0.05436
# std       1.323782         1.325853              0.893398           0.66008
# min       0.693100        -2.995700             -3.912000          -1.55590
# 25%       4.672800         1.588100             -0.335500          -0.20955
# 50%       5.337500         2.286500             -0.040800           0.24450
# 75%       5.908100         2.730800              0.190600           0.49195
# max       6.508800         3.220500              1.654400           1.41220
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX  \
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.021247       2.095454    0.808738    13.045021   17.907784
# std              0.803748       1.079203    0.276653     6.609366    7.523377
# min             -2.918800      -0.798500    0.090000     1.293138    2.733019
# 25%             -1.629700       1.801400    0.745000     8.206727   11.615798
# 50%             -0.719500       2.458700    0.960000    13.072916   18.269344
# 75%             -0.358800       2.862800    1.000000    17.432255   22.751595
# max              0.114200       3.366600    1.000000    28.916548   36.355442
#
#             g_MAX  contr_g_MAX
# count  103.000000   103.000000
# mean   240.572816  3008.938899
# std      9.358442   876.023529
# min    194.000000   815.342712
# 25%    236.500000  2464.687256
# 50%    243.000000  2994.793701
# 75%    247.000000  3464.970947
# max    253.000000  6230.940918

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX', 'g_MAX', 'contr_g_MAX'])
y = pd.DataFrame(select, columns= ['ln_M_crown_kg_m2'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX  g_MAX  contr_g_MAX
# 0     0.85    12.233545   19.097736    243  2961.898193
# 1     1.00    14.964220   17.704655    248  2218.239746
# 2     1.00    15.329449   17.559893    240  2220.297119
# 3     0.97    15.392742   20.676994    244  3033.770752
# 4     1.00    17.944009   21.851387    243  3003.818848

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_crown_kg_m2
# 0           -0.1590
# 1            0.3429
# 2            0.5493
# 3            0.3900
# 4            0.5715

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.4857145861685255, 0.6965931361183302, 0.7701667425154118]
#     Mean: 0.651
#     Std: 0.121
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.34638832 0.31021741 0.39816616]
#     Mean: 0.352
#     Std: 0.036
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.2495433629894257, 0.2853292822862373, 0.23422561151564997]
#     Mean: 0.256
#     Std: 0.021
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# Model with rank: 1
# Mean validation score: 0.749 (std: 0.094)
# Parameters: {'colsample_bytree': 0.85594906971537, 'gamma': 0.08026909719227604, 'learning_rate': 0.025467011735823587, 'max_depth': 2, 'n_estimators': 148, 'subsample': 0.9895964560219264}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.5359448 , 0.16929121, 0.41212034, ..., 1.08853397, 1.13672686,
#        0.4295126 ]), 'std_fit_time': array([0.10308871, 0.00500866, 0.03053475, ..., 0.02775956, 0.13618024,
#        0.01046564]), 'mean_score_time': array([0.00651722, 0.00732684, 0.00618687, ..., 0.01353898, 0.01293626,
#        0.01384263]), 'std_score_time': array([4.96432241e-04, 1.16837888e-03, 1.47654349e-04, ...,
#        1.66946600e-03, 2.07308429e-03, 8.94903303e-05]), 'param_colsample_bytree': masked_array(data=[0.2948694155118738, 0.3849130617402233,
#                    0.6285613821342273, ..., 0.33928537517786045,
#                    0.5391234766660582, 0.7069105313040233],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.3459388703771634, 0.42301191513701464,
#                    0.4815455890847236, ..., 0.3188591766814472,
#                    0.12080511102022001, 0.3296164286830339],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.0505106946026016, 0.28927537841641543,
#                    0.139640972656061, ..., 0.16342528281789775,
#                    0.22039464881368562, 0.23518799352884795],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[4, 2, 3, ..., 4, 4, 2],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[171, 61, 156, ..., 165, 151, 70],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.8534360315362524, 0.46440239668022576,
#                    0.3646922218454872, ..., 0.916791200482463,
#                    0.8401973317254854, 0.7333871053146314],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.2948694155118738, 'gamma': 0.3459388703771634, 'learning_rate': 0.0505106946026016, 'max_depth': 4, 'n_estimators': 171, 'subsample': 0.8534360315362524}, {'colsample_bytree': 0.3849130617402233, 'gamma': 0.42301191513701464, 'learning_rate': 0.28927537841641543, 'max_depth': 2, 'n_estimators': 61, 'subsample': 0.46440239668022576}, {'colsample_bytree': 0.6285613821342273, 'gamma': 0.4815455890847236, 'learning_rate': 0.139640972656061, 'max_depth': 3, 'n_estimators': 156, 'subsample': 0.3646922218454872}, {'colsample_bytree': 0.05613887096622329, 'gamma': 0.3375243697803263, 'learning_rate': 0.17781985559043376, 'max_depth': 3, 'n_estimators': 147, 'subsample': 0.4830904676653845}, {'colsample_bytree': 0.4665311708253381, 'gamma': 0.4117392685678642, 'learning_rate': 0.27215202453998794, 'max_depth': 4, 'n_estimators': 139, 'subsample': 0.47648344062405135}, {'colsample_bytree': 0.5457125144347209, 'gamma': 0.04392102955675331, 'learning_rate': 0.1666150518030775, 'max_depth': 3, 'n_estimators': 93, 'subsample': 0.8768368352473885}, {'colsample_bytree': 0.8598258780043755, 'gamma': 0.1261188525009685, 'learning_rate': 0.13337273338412559, 'max_depth': 2, 'n_estimators': 103, 'subsample': 0.5400824087551346}, {'colsample_bytree': 0.37285251727244734, 'gamma': 0.38208242977362455, 'learning_rate': 0.2556745992231691, 'max_depth': 4, 'n_estimators': 177, 'subsample': 0.40777543613947764}, {'colsample_bytree': 0.17789947919065913, 'gamma': 0.11030899963234136, 'learning_rate': 0.2855691624656558, 'max_depth': 2, 'n_estimators': 156, 'subsample': 0.4007215568230228}, {'colsample_bytree': 0.39053078390526846, 'gamma': 0.3026617484241071, 'learning_rate': 0.25482088793875446, 'max_depth': 4, 'n_estimators': 117, 'subsample': 0.7346394688062639}, {'colsample_bytree': 0.9014058208679978, 'gamma': 0.3212656013295632, 'learning_rate': 0.2269582431736108, 'max_depth': 2, 'n_estimators': 133, 'subsample': 0.8365148057377478}, {'colsample_bytree': 0.8093190173838517, 'gamma': 0.32398091812695806, 'learning_rate': 0.11629381224686992, 'max_depth': 2, 'n_estimators': 53, 'subsample': 0.7499056766723649}, {'colsample_bytree': 0.7444376921894198, 'gamma': 0.18803314448995567, 'learning_rate': 0.22028685145093382, 'max_depth': 4, 'n_estimators': 166, 'subsample': 0.9365965516797263}, {'colsample_bytree': 0.3719051043558956, 'gamma': 0.3065647677335565, 'learning_rate': 0.1521357535965826, 'max_depth': 2, 'n_estimators': 181, 'subsample': 0.5578411464191684}, {'colsample_bytree': 0.06352456219634454, 'gamma': 0.04408875786359279, 'learning_rate': 0.06610628328171787, 'max_depth': 3, 'n_estimators': 160, 'subsample': 0.5352969948613069}, {'colsample_bytree': 0.2630096919190101, 'gamma': 0.3814497529725326, 'learning_rate': 0.23043922056770613, 'max_depth': 3, 'n_estimators': 165, 'subsample': 0.557966526664758}, {'colsample_bytree': 0.5727177117613513, 'gamma': 0.04166242465510994, 'learning_rate': 0.034137426227266364, 'max_depth': 2, 'n_estimators': 98, 'subsample': 0.48630318393796856}, {'colsample_bytree': 0.20364600065565763, 'gamma': 0.14515539550335083, 'learning_rate': 0.16773814747321877, 'max_depth': 2, 'n_estimators': 105, 'subsample': 0.8634794520191929}, {'colsample_bytree': 0.606863293070262, 'gamma': 0.4057821670262215, 'learning_rate': 0.2788099078425861, 'max_depth': 3, 'n_estimators': 197, 'subsample': 0.42828129956922933}, {'colsample_bytree': 0.3002043461640296, 'gamma': 0.14396023374477773, 'learning_rate': 0.13309298288816773, 'max_depth': 4, 'n_estimators': 68, 'subsample': 0.5891824024741561}, {'colsample_bytree': 0.8347165716846181, 'gamma': 0.056891777246004915, 'learning_rate': 0.15326040386494416, 'max_depth': 2, 'n_estimators': 119, 'subsample': 0.6184483238908351}, {'colsample_bytree': 0.518471998062109, 'gamma': 0.0784238711769672, 'learning_rate': 0.18452896876794506, 'max_depth': 2, 'n_estimators': 172, 'subsample': 0.45462179535058195}, {'colsample_bytr ...
#        0.72148816]), 'split1_test_score': array([0.78818026, 0.76751555, 0.80840912, ..., 0.76676898, 0.85184343,
#        0.88929257]), 'split2_test_score': array([0.58251844, 0.585912  , 0.56640015, ..., 0.60973437, 0.54402191,
#        0.55405455]), 'split3_test_score': array([0.56595887, 0.49010908, 0.54731764, ..., 0.55330486, 0.5741967 ,
#        0.62501496]), 'split4_test_score': array([0.78513945, 0.78459855, 0.65400658, ..., 0.77612426, 0.65521476,
#        0.63107909]), 'mean_test_score': array([0.70189666, 0.66213162, 0.66254427, ..., 0.68944407, 0.68279041,
#        0.68418587]), 'std_test_score': array([0.10436889, 0.11128424, 0.09935066, ..., 0.0906288 , 0.1196664 ,
#        0.11551269]), 'rank_test_score': array([ 905, 2142, 2127, ..., 1361, 1585, 1545], dtype=int32), 'split0_train_score': array([0.85429966, 0.83899759, 0.86238813, ..., 0.8742352 , 0.95677509,
#        0.8869353 ]), 'split1_train_score': array([0.85308799, 0.8252122 , 0.83359634, ..., 0.87061185, 0.9534738 ,
#        0.86578039]), 'split2_train_score': array([0.86473902, 0.82464413, 0.86392588, ..., 0.87853071, 0.95299901,
#        0.89163801]), 'split3_train_score': array([0.87504701, 0.84892485, 0.86448792, ..., 0.87246681, 0.95389046,
#        0.89317894]), 'split4_train_score': array([0.85831315, 0.84449707, 0.86223536, ..., 0.85972812, 0.95934334,
#        0.88683616]), 'mean_train_score': array([0.86109737, 0.83645517, 0.85732673, ..., 0.87111454, 0.95529634,
#        0.88487376]), 'std_train_score': array([0.00807422, 0.00992506, 0.01189685, ..., 0.0062685 , 0.00241416,
#        0.00987308])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.85594906971537
# Gamma: 0.08026909719227604
# Learning_rate: 0.025467011735823587
# Max_depth: 2
# N_estimators: 148
# Subsample: 0.9895964560219264

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:0.82507	validation_1-rmse:0.55287
# [1]	validation_0-rmse:0.80806	validation_1-rmse:0.54099
# [2]	validation_0-rmse:0.79151	validation_1-rmse:0.53038
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:0.77540	validation_1-rmse:0.52014
# [4]	validation_0-rmse:0.75992	validation_1-rmse:0.51079
# [5]	validation_0-rmse:0.74465	validation_1-rmse:0.50124
# [6]	validation_0-rmse:0.72979	validation_1-rmse:0.49029
# [7]	validation_0-rmse:0.71533	validation_1-rmse:0.48142
# [8]	validation_0-rmse:0.70125	validation_1-rmse:0.47104
# [9]	validation_0-rmse:0.68754	validation_1-rmse:0.46211
# [10]	validation_0-rmse:0.67420	validation_1-rmse:0.45310
# [11]	validation_0-rmse:0.66123	validation_1-rmse:0.44550
# [12]	validation_0-rmse:0.64861	validation_1-rmse:0.43823
# [13]	validation_0-rmse:0.63644	validation_1-rmse:0.43034
# [14]	validation_0-rmse:0.62447	validation_1-rmse:0.42201
# [15]	validation_0-rmse:0.61329	validation_1-rmse:0.41426
# [16]	validation_0-rmse:0.60197	validation_1-rmse:0.40787
# [17]	validation_0-rmse:0.59102	validation_1-rmse:0.40118
# [18]	validation_0-rmse:0.58013	validation_1-rmse:0.39550
# [19]	validation_0-rmse:0.56973	validation_1-rmse:0.38938
# [20]	validation_0-rmse:0.55964	validation_1-rmse:0.38433
# [21]	validation_0-rmse:0.54979	validation_1-rmse:0.37854
# [22]	validation_0-rmse:0.54023	validation_1-rmse:0.37374
# [23]	validation_0-rmse:0.53095	validation_1-rmse:0.36868
# [24]	validation_0-rmse:0.52193	validation_1-rmse:0.36392
# [25]	validation_0-rmse:0.51318	validation_1-rmse:0.35981
# [26]	validation_0-rmse:0.50466	validation_1-rmse:0.35482
# [27]	validation_0-rmse:0.49636	validation_1-rmse:0.34994
# [28]	validation_0-rmse:0.48842	validation_1-rmse:0.34513
# [29]	validation_0-rmse:0.48062	validation_1-rmse:0.34083
# [30]	validation_0-rmse:0.47305	validation_1-rmse:0.33700
# [31]	validation_0-rmse:0.46572	validation_1-rmse:0.33383
# [32]	validation_0-rmse:0.45865	validation_1-rmse:0.32978
# [33]	validation_0-rmse:0.45174	validation_1-rmse:0.32636
# [34]	validation_0-rmse:0.44501	validation_1-rmse:0.32348
# [35]	validation_0-rmse:0.43849	validation_1-rmse:0.32059
# [36]	validation_0-rmse:0.43200	validation_1-rmse:0.31732
# [37]	validation_0-rmse:0.42582	validation_1-rmse:0.31427
# [38]	validation_0-rmse:0.41971	validation_1-rmse:0.31221
# [39]	validation_0-rmse:0.41376	validation_1-rmse:0.30966
# [40]	validation_0-rmse:0.40765	validation_1-rmse:0.30666
# [41]	validation_0-rmse:0.40206	validation_1-rmse:0.30513
# [42]	validation_0-rmse:0.39654	validation_1-rmse:0.30249
# [43]	validation_0-rmse:0.39136	validation_1-rmse:0.29930
# [44]	validation_0-rmse:0.38589	validation_1-rmse:0.29691
# [45]	validation_0-rmse:0.38064	validation_1-rmse:0.29473
# [46]	validation_0-rmse:0.37547	validation_1-rmse:0.29263
# [47]	validation_0-rmse:0.37084	validation_1-rmse:0.29029
# [48]	validation_0-rmse:0.36639	validation_1-rmse:0.28821
# [49]	validation_0-rmse:0.36172	validation_1-rmse:0.28652
# [50]	validation_0-rmse:0.35754	validation_1-rmse:0.28621
# [51]	validation_0-rmse:0.35347	validation_1-rmse:0.28514
# [52]	validation_0-rmse:0.34944	validation_1-rmse:0.28422
# [53]	validation_0-rmse:0.34565	validation_1-rmse:0.28413
# [54]	validation_0-rmse:0.34163	validation_1-rmse:0.28296
# [55]	validation_0-rmse:0.33775	validation_1-rmse:0.28190
# [56]	validation_0-rmse:0.33401	validation_1-rmse:0.28093
# [57]	validation_0-rmse:0.33037	validation_1-rmse:0.28006
# [58]	validation_0-rmse:0.32686	validation_1-rmse:0.27913
# [59]	validation_0-rmse:0.32367	validation_1-rmse:0.27952
# [60]	validation_0-rmse:0.32039	validation_1-rmse:0.27889
# [61]	validation_0-rmse:0.31721	validation_1-rmse:0.27823
# [62]	validation_0-rmse:0.31416	validation_1-rmse:0.27767
# [63]	validation_0-rmse:0.31121	validation_1-rmse:0.27726
# [64]	validation_0-rmse:0.30837	validation_1-rmse:0.27686
# [65]	validation_0-rmse:0.30567	validation_1-rmse:0.27668
# [66]	validation_0-rmse:0.30301	validation_1-rmse:0.27646
# [67]	validation_0-rmse:0.30046	validation_1-rmse:0.27627
# [68]	validation_0-rmse:0.29804	validation_1-rmse:0.27690
# [69]	validation_0-rmse:0.29579	validation_1-rmse:0.27696
# [70]	validation_0-rmse:0.29347	validation_1-rmse:0.27700
# [71]	validation_0-rmse:0.29124	validation_1-rmse:0.27709
# [72]	validation_0-rmse:0.28911	validation_1-rmse:0.27723
# [73]	validation_0-rmse:0.28703	validation_1-rmse:0.27729
# [74]	validation_0-rmse:0.28501	validation_1-rmse:0.27738
# [75]	validation_0-rmse:0.28308	validation_1-rmse:0.27807
# [76]	validation_0-rmse:0.28124	validation_1-rmse:0.27878
# [77]	validation_0-rmse:0.27941	validation_1-rmse:0.27877
# [78]	validation_0-rmse:0.27770	validation_1-rmse:0.27913
# [79]	validation_0-rmse:0.27604	validation_1-rmse:0.27985
# [80]	validation_0-rmse:0.27442	validation_1-rmse:0.28029
# [81]	validation_0-rmse:0.27281	validation_1-rmse:0.28064
# [82]	validation_0-rmse:0.27121	validation_1-rmse:0.28135
# [83]	validation_0-rmse:0.26972	validation_1-rmse:0.28176
# [84]	validation_0-rmse:0.26829	validation_1-rmse:0.28261
# [85]	validation_0-rmse:0.26694	validation_1-rmse:0.28308
# [86]	validation_0-rmse:0.26561	validation_1-rmse:0.28347
# [0]	validation_0-rmse:0.83007	validation_1-rmse:0.51898
# [1]	validation_0-rmse:0.81318	validation_1-rmse:0.50350
# [2]	validation_0-rmse:0.79674	validation_1-rmse:0.48831
# [3]	validation_0-rmse:0.78072	validation_1-rmse:0.47330
# [4]	validation_0-rmse:0.76520	validation_1-rmse:0.46086
# [5]	validation_0-rmse:0.75002	validation_1-rmse:0.44732
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:0.73529	validation_1-rmse:0.43568
# [7]	validation_0-rmse:0.72089	validation_1-rmse:0.42269
# [8]	validation_0-rmse:0.70691	validation_1-rmse:0.41187
# [9]	validation_0-rmse:0.69329	validation_1-rmse:0.40033
# [10]	validation_0-rmse:0.68001	validation_1-rmse:0.38848
# [11]	validation_0-rmse:0.66684	validation_1-rmse:0.37918
# [12]	validation_0-rmse:0.65426	validation_1-rmse:0.36992
# [13]	validation_0-rmse:0.64203	validation_1-rmse:0.35951
# [14]	validation_0-rmse:0.63024	validation_1-rmse:0.35099
# [15]	validation_0-rmse:0.61863	validation_1-rmse:0.34305
# [16]	validation_0-rmse:0.60737	validation_1-rmse:0.33504
# [17]	validation_0-rmse:0.59637	validation_1-rmse:0.32618
# [18]	validation_0-rmse:0.58592	validation_1-rmse:0.31798
# [19]	validation_0-rmse:0.57555	validation_1-rmse:0.31002
# [20]	validation_0-rmse:0.56547	validation_1-rmse:0.30364
# [21]	validation_0-rmse:0.55565	validation_1-rmse:0.29592
# [22]	validation_0-rmse:0.54611	validation_1-rmse:0.29007
# [23]	validation_0-rmse:0.53685	validation_1-rmse:0.28406
# [24]	validation_0-rmse:0.52785	validation_1-rmse:0.27786
# [25]	validation_0-rmse:0.51911	validation_1-rmse:0.27283
# [26]	validation_0-rmse:0.51060	validation_1-rmse:0.26684
# [27]	validation_0-rmse:0.50234	validation_1-rmse:0.26183
# [28]	validation_0-rmse:0.49430	validation_1-rmse:0.25693
# [29]	validation_0-rmse:0.48651	validation_1-rmse:0.25244
# [30]	validation_0-rmse:0.47888	validation_1-rmse:0.24779
# [31]	validation_0-rmse:0.47156	validation_1-rmse:0.24435
# [32]	validation_0-rmse:0.46432	validation_1-rmse:0.24129
# [33]	validation_0-rmse:0.45747	validation_1-rmse:0.23771
# [34]	validation_0-rmse:0.45082	validation_1-rmse:0.23546
# [35]	validation_0-rmse:0.44380	validation_1-rmse:0.23361
# [36]	validation_0-rmse:0.43700	validation_1-rmse:0.23193
# [37]	validation_0-rmse:0.43043	validation_1-rmse:0.23043
# [38]	validation_0-rmse:0.42446	validation_1-rmse:0.22837
# [39]	validation_0-rmse:0.41846	validation_1-rmse:0.22638
# [40]	validation_0-rmse:0.41285	validation_1-rmse:0.22529
# [41]	validation_0-rmse:0.40717	validation_1-rmse:0.22395
# [42]	validation_0-rmse:0.40185	validation_1-rmse:0.22268
# [43]	validation_0-rmse:0.39613	validation_1-rmse:0.22261
# [44]	validation_0-rmse:0.39091	validation_1-rmse:0.22134
# [45]	validation_0-rmse:0.38577	validation_1-rmse:0.22053
# [46]	validation_0-rmse:0.38068	validation_1-rmse:0.22018
# [47]	validation_0-rmse:0.37593	validation_1-rmse:0.21994
# [48]	validation_0-rmse:0.37135	validation_1-rmse:0.21938
# [49]	validation_0-rmse:0.36670	validation_1-rmse:0.21938
# [50]	validation_0-rmse:0.36240	validation_1-rmse:0.21957
# [51]	validation_0-rmse:0.35835	validation_1-rmse:0.21937
# [52]	validation_0-rmse:0.35399	validation_1-rmse:0.22051
# [53]	validation_0-rmse:0.35010	validation_1-rmse:0.22105
# [54]	validation_0-rmse:0.34611	validation_1-rmse:0.22143
# [55]	validation_0-rmse:0.34227	validation_1-rmse:0.22186
# [56]	validation_0-rmse:0.33856	validation_1-rmse:0.22301
# [57]	validation_0-rmse:0.33482	validation_1-rmse:0.22346
# [58]	validation_0-rmse:0.33136	validation_1-rmse:0.22480
# [59]	validation_0-rmse:0.32809	validation_1-rmse:0.22525
# [60]	validation_0-rmse:0.32486	validation_1-rmse:0.22662
# [61]	validation_0-rmse:0.32175	validation_1-rmse:0.22730
# [62]	validation_0-rmse:0.31875	validation_1-rmse:0.22870
# [63]	validation_0-rmse:0.31585	validation_1-rmse:0.22942
# [64]	validation_0-rmse:0.31303	validation_1-rmse:0.23018
# [65]	validation_0-rmse:0.31034	validation_1-rmse:0.23103
# [66]	validation_0-rmse:0.30779	validation_1-rmse:0.23210
# [67]	validation_0-rmse:0.30524	validation_1-rmse:0.23269
# [68]	validation_0-rmse:0.30274	validation_1-rmse:0.23362
# [69]	validation_0-rmse:0.30032	validation_1-rmse:0.23491
# [70]	validation_0-rmse:0.29797	validation_1-rmse:0.23559
# [0]	validation_0-rmse:0.80729	validation_1-rmse:0.64826
# [1]	validation_0-rmse:0.79107	validation_1-rmse:0.63413
# [2]	validation_0-rmse:0.77545	validation_1-rmse:0.62054
# [3]	validation_0-rmse:0.76003	validation_1-rmse:0.60706
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:0.74502	validation_1-rmse:0.59407
# [5]	validation_0-rmse:0.73049	validation_1-rmse:0.58161
# [6]	validation_0-rmse:0.71629	validation_1-rmse:0.56936
# [7]	validation_0-rmse:0.70250	validation_1-rmse:0.55763
# [8]	validation_0-rmse:0.68908	validation_1-rmse:0.54610
# [9]	validation_0-rmse:0.67619	validation_1-rmse:0.53667
# [10]	validation_0-rmse:0.66368	validation_1-rmse:0.52725
# [11]	validation_0-rmse:0.65132	validation_1-rmse:0.51661
# [12]	validation_0-rmse:0.63946	validation_1-rmse:0.50634
# [13]	validation_0-rmse:0.62801	validation_1-rmse:0.49787
# [14]	validation_0-rmse:0.61663	validation_1-rmse:0.48811
# [15]	validation_0-rmse:0.60568	validation_1-rmse:0.47866
# [16]	validation_0-rmse:0.59500	validation_1-rmse:0.46945
# [17]	validation_0-rmse:0.58488	validation_1-rmse:0.46173
# [18]	validation_0-rmse:0.57484	validation_1-rmse:0.45325
# [19]	validation_0-rmse:0.56510	validation_1-rmse:0.44527
# [20]	validation_0-rmse:0.55565	validation_1-rmse:0.43735
# [21]	validation_0-rmse:0.54642	validation_1-rmse:0.42931
# [22]	validation_0-rmse:0.53747	validation_1-rmse:0.42170
# [23]	validation_0-rmse:0.52879	validation_1-rmse:0.41416
# [24]	validation_0-rmse:0.52040	validation_1-rmse:0.40748
# [25]	validation_0-rmse:0.51223	validation_1-rmse:0.40059
# [26]	validation_0-rmse:0.50431	validation_1-rmse:0.39377
# [27]	validation_0-rmse:0.49662	validation_1-rmse:0.38731
# [28]	validation_0-rmse:0.48931	validation_1-rmse:0.38150
# [29]	validation_0-rmse:0.48206	validation_1-rmse:0.37589
# [30]	validation_0-rmse:0.47498	validation_1-rmse:0.37019
# [31]	validation_0-rmse:0.46818	validation_1-rmse:0.36536
# [32]	validation_0-rmse:0.46146	validation_1-rmse:0.36036
# [33]	validation_0-rmse:0.45490	validation_1-rmse:0.35595
# [34]	validation_0-rmse:0.44865	validation_1-rmse:0.35096
# [35]	validation_0-rmse:0.44244	validation_1-rmse:0.34630
# [36]	validation_0-rmse:0.43644	validation_1-rmse:0.34229
# [37]	validation_0-rmse:0.43036	validation_1-rmse:0.33751
# [38]	validation_0-rmse:0.42444	validation_1-rmse:0.33305
# [39]	validation_0-rmse:0.41947	validation_1-rmse:0.32785
# [40]	validation_0-rmse:0.41417	validation_1-rmse:0.32330
# [41]	validation_0-rmse:0.40871	validation_1-rmse:0.31933
# [42]	validation_0-rmse:0.40363	validation_1-rmse:0.31615
# [43]	validation_0-rmse:0.39852	validation_1-rmse:0.31210
# [44]	validation_0-rmse:0.39371	validation_1-rmse:0.30825
# [45]	validation_0-rmse:0.38918	validation_1-rmse:0.30504
# [46]	validation_0-rmse:0.38480	validation_1-rmse:0.30200
# [47]	validation_0-rmse:0.38042	validation_1-rmse:0.29861
# [48]	validation_0-rmse:0.37617	validation_1-rmse:0.29599
# [49]	validation_0-rmse:0.37181	validation_1-rmse:0.29261
# [50]	validation_0-rmse:0.36783	validation_1-rmse:0.28931
# [51]	validation_0-rmse:0.36397	validation_1-rmse:0.28670
# [52]	validation_0-rmse:0.35999	validation_1-rmse:0.28366
# [53]	validation_0-rmse:0.35636	validation_1-rmse:0.28064
# [54]	validation_0-rmse:0.35262	validation_1-rmse:0.27782
# [55]	validation_0-rmse:0.34898	validation_1-rmse:0.27521
# [56]	validation_0-rmse:0.34547	validation_1-rmse:0.27276
# [57]	validation_0-rmse:0.34209	validation_1-rmse:0.27089
# [58]	validation_0-rmse:0.33880	validation_1-rmse:0.26878
# [59]	validation_0-rmse:0.33563	validation_1-rmse:0.26711
# [60]	validation_0-rmse:0.33267	validation_1-rmse:0.26462
# [61]	validation_0-rmse:0.32971	validation_1-rmse:0.26245
# [62]	validation_0-rmse:0.32663	validation_1-rmse:0.26141
# [63]	validation_0-rmse:0.32387	validation_1-rmse:0.25910
# [64]	validation_0-rmse:0.32103	validation_1-rmse:0.25767
# [65]	validation_0-rmse:0.31835	validation_1-rmse:0.25562
# [66]	validation_0-rmse:0.31566	validation_1-rmse:0.25454
# [67]	validation_0-rmse:0.31318	validation_1-rmse:0.25301
# [68]	validation_0-rmse:0.31085	validation_1-rmse:0.25190
# [69]	validation_0-rmse:0.30861	validation_1-rmse:0.25061
# [70]	validation_0-rmse:0.30620	validation_1-rmse:0.25015
# [71]	validation_0-rmse:0.30388	validation_1-rmse:0.24996
# [72]	validation_0-rmse:0.30173	validation_1-rmse:0.24903
# [73]	validation_0-rmse:0.29957	validation_1-rmse:0.24876
# [74]	validation_0-rmse:0.29749	validation_1-rmse:0.24825
# [75]	validation_0-rmse:0.29549	validation_1-rmse:0.24830
# [76]	validation_0-rmse:0.29356	validation_1-rmse:0.24819
# [77]	validation_0-rmse:0.29178	validation_1-rmse:0.24751
# [78]	validation_0-rmse:0.28998	validation_1-rmse:0.24694
# [79]	validation_0-rmse:0.28798	validation_1-rmse:0.24704
# [80]	validation_0-rmse:0.28631	validation_1-rmse:0.24613
# [81]	validation_0-rmse:0.28473	validation_1-rmse:0.24480
# [82]	validation_0-rmse:0.28276	validation_1-rmse:0.24367
# [83]	validation_0-rmse:0.28098	validation_1-rmse:0.24241
# [84]	validation_0-rmse:0.27926	validation_1-rmse:0.24155
# [85]	validation_0-rmse:0.27796	validation_1-rmse:0.24168
# [86]	validation_0-rmse:0.27645	validation_1-rmse:0.24192
# [87]	validation_0-rmse:0.27496	validation_1-rmse:0.24100
# [88]	validation_0-rmse:0.27330	validation_1-rmse:0.24229
# [89]	validation_0-rmse:0.27214	validation_1-rmse:0.24216
# [90]	validation_0-rmse:0.27102	validation_1-rmse:0.24304
# [91]	validation_0-rmse:0.26975	validation_1-rmse:0.24228
# [92]	validation_0-rmse:0.26828	validation_1-rmse:0.24305
# [93]	validation_0-rmse:0.26733	validation_1-rmse:0.24241
# [94]	validation_0-rmse:0.26631	validation_1-rmse:0.24333
# [95]	validation_0-rmse:0.26535	validation_1-rmse:0.24272
# [96]	validation_0-rmse:0.26443	validation_1-rmse:0.24268
# [97]	validation_0-rmse:0.26314	validation_1-rmse:0.24384
# [98]	validation_0-rmse:0.26183	validation_1-rmse:0.24502
# [99]	validation_0-rmse:0.26097	validation_1-rmse:0.24506
# [100]	validation_0-rmse:0.25996	validation_1-rmse:0.24499
# [101]	validation_0-rmse:0.25914	validation_1-rmse:0.24449
# [102]	validation_0-rmse:0.25800	validation_1-rmse:0.24552
# [103]	validation_0-rmse:0.25725	validation_1-rmse:0.24556
# [104]	validation_0-rmse:0.25612	validation_1-rmse:0.24687
# [105]	validation_0-rmse:0.25526	validation_1-rmse:0.24744
# [106]	validation_0-rmse:0.25455	validation_1-rmse:0.24704
# [0]	validation_0-rmse:0.78255	validation_1-rmse:0.76063
# [1]	validation_0-rmse:0.76704	validation_1-rmse:0.74673
# [2]	validation_0-rmse:0.75192	validation_1-rmse:0.73297
# [3]	validation_0-rmse:0.73714	validation_1-rmse:0.71982
# [4]	validation_0-rmse:0.72269	validation_1-rmse:0.70611
# [5]	validation_0-rmse:0.70878	validation_1-rmse:0.69342
# [6]	validation_0-rmse:0.69510	validation_1-rmse:0.68052
# [7]	validation_0-rmse:0.68180	validation_1-rmse:0.66847
# [8]	validation_0-rmse:0.66886	validation_1-rmse:0.65635
# [9]	validation_0-rmse:0.65631	validation_1-rmse:0.64471
# [10]	validation_0-rmse:0.64413	validation_1-rmse:0.63326
# [11]	validation_0-rmse:0.63231	validation_1-rmse:0.62251
# [12]	validation_0-rmse:0.62070	validation_1-rmse:0.61146
# [13]	validation_0-rmse:0.60944	validation_1-rmse:0.60196
# [14]	validation_0-rmse:0.59834	validation_1-rmse:0.59053
# [15]	validation_0-rmse:0.58756	validation_1-rmse:0.58079
# [16]	validation_0-rmse:0.57719	validation_1-rmse:0.57144
# [17]	validation_0-rmse:0.56685	validation_1-rmse:0.56174
# [18]	validation_0-rmse:0.55709	validation_1-rmse:0.55262
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [19]	validation_0-rmse:0.54765	validation_1-rmse:0.54383
# [20]	validation_0-rmse:0.53849	validation_1-rmse:0.53550
# [21]	validation_0-rmse:0.52942	validation_1-rmse:0.52751
# [22]	validation_0-rmse:0.52062	validation_1-rmse:0.51970
# [23]	validation_0-rmse:0.51206	validation_1-rmse:0.51252
# [24]	validation_0-rmse:0.50334	validation_1-rmse:0.50421
# [25]	validation_0-rmse:0.49523	validation_1-rmse:0.49711
# [26]	validation_0-rmse:0.48734	validation_1-rmse:0.48996
# [27]	validation_0-rmse:0.47911	validation_1-rmse:0.48229
# [28]	validation_0-rmse:0.47108	validation_1-rmse:0.47493
# [29]	validation_0-rmse:0.46380	validation_1-rmse:0.46841
# [30]	validation_0-rmse:0.45666	validation_1-rmse:0.46272
# [31]	validation_0-rmse:0.44943	validation_1-rmse:0.45628
# [32]	validation_0-rmse:0.44255	validation_1-rmse:0.44967
# [33]	validation_0-rmse:0.43605	validation_1-rmse:0.44449
# [34]	validation_0-rmse:0.42920	validation_1-rmse:0.43869
# [35]	validation_0-rmse:0.42270	validation_1-rmse:0.43321
# [36]	validation_0-rmse:0.41640	validation_1-rmse:0.42829
# [37]	validation_0-rmse:0.41019	validation_1-rmse:0.42330
# [38]	validation_0-rmse:0.40456	validation_1-rmse:0.41841
# [39]	validation_0-rmse:0.39882	validation_1-rmse:0.41386
# [40]	validation_0-rmse:0.39315	validation_1-rmse:0.40950
# [41]	validation_0-rmse:0.38799	validation_1-rmse:0.40510
# [42]	validation_0-rmse:0.38292	validation_1-rmse:0.40109
# [43]	validation_0-rmse:0.37780	validation_1-rmse:0.39760
# [44]	validation_0-rmse:0.37297	validation_1-rmse:0.39361
# [45]	validation_0-rmse:0.36803	validation_1-rmse:0.39025
# [46]	validation_0-rmse:0.36339	validation_1-rmse:0.38629
# [47]	validation_0-rmse:0.35895	validation_1-rmse:0.38356
# [48]	validation_0-rmse:0.35472	validation_1-rmse:0.38027
# [49]	validation_0-rmse:0.35035	validation_1-rmse:0.37791
# [50]	validation_0-rmse:0.34629	validation_1-rmse:0.37554
# [51]	validation_0-rmse:0.34237	validation_1-rmse:0.37259
# [52]	validation_0-rmse:0.33837	validation_1-rmse:0.37054
# [53]	validation_0-rmse:0.33468	validation_1-rmse:0.36850
# [54]	validation_0-rmse:0.33085	validation_1-rmse:0.36632
# [55]	validation_0-rmse:0.32717	validation_1-rmse:0.36430
# [56]	validation_0-rmse:0.32361	validation_1-rmse:0.36241
# [57]	validation_0-rmse:0.32030	validation_1-rmse:0.36105
# [58]	validation_0-rmse:0.31695	validation_1-rmse:0.35908
# [59]	validation_0-rmse:0.31398	validation_1-rmse:0.35722
# [60]	validation_0-rmse:0.31084	validation_1-rmse:0.35584
# [61]	validation_0-rmse:0.30780	validation_1-rmse:0.35428
# [62]	validation_0-rmse:0.30486	validation_1-rmse:0.35271
# [63]	validation_0-rmse:0.30202	validation_1-rmse:0.35170
# [64]	validation_0-rmse:0.29932	validation_1-rmse:0.34992
# [65]	validation_0-rmse:0.29664	validation_1-rmse:0.34903
# [66]	validation_0-rmse:0.29419	validation_1-rmse:0.34836
# [67]	validation_0-rmse:0.29168	validation_1-rmse:0.34767
# [68]	validation_0-rmse:0.28930	validation_1-rmse:0.34688
# [69]	validation_0-rmse:0.28678	validation_1-rmse:0.34534
# [70]	validation_0-rmse:0.28453	validation_1-rmse:0.34450
# [71]	validation_0-rmse:0.28237	validation_1-rmse:0.34333
# [72]	validation_0-rmse:0.28021	validation_1-rmse:0.34292
# [73]	validation_0-rmse:0.27817	validation_1-rmse:0.34260
# [74]	validation_0-rmse:0.27610	validation_1-rmse:0.34222
# [75]	validation_0-rmse:0.27416	validation_1-rmse:0.34179
# [76]	validation_0-rmse:0.27229	validation_1-rmse:0.34092
# [77]	validation_0-rmse:0.27054	validation_1-rmse:0.34056
# [78]	validation_0-rmse:0.26877	validation_1-rmse:0.34025
# [79]	validation_0-rmse:0.26707	validation_1-rmse:0.33985
# [80]	validation_0-rmse:0.26541	validation_1-rmse:0.33943
# [81]	validation_0-rmse:0.26358	validation_1-rmse:0.33859
# [82]	validation_0-rmse:0.26185	validation_1-rmse:0.33819
# [83]	validation_0-rmse:0.26027	validation_1-rmse:0.33796
# [84]	validation_0-rmse:0.25876	validation_1-rmse:0.33742
# [85]	validation_0-rmse:0.25711	validation_1-rmse:0.33673
# [86]	validation_0-rmse:0.25559	validation_1-rmse:0.33645
# [87]	validation_0-rmse:0.25414	validation_1-rmse:0.33633
# [88]	validation_0-rmse:0.25266	validation_1-rmse:0.33573
# [89]	validation_0-rmse:0.25132	validation_1-rmse:0.33553
# [90]	validation_0-rmse:0.24993	validation_1-rmse:0.33499
# [91]	validation_0-rmse:0.24868	validation_1-rmse:0.33517
# [92]	validation_0-rmse:0.24738	validation_1-rmse:0.33468
# [93]	validation_0-rmse:0.24615	validation_1-rmse:0.33455
# [94]	validation_0-rmse:0.24492	validation_1-rmse:0.33411
# [95]	validation_0-rmse:0.24379	validation_1-rmse:0.33410
# [96]	validation_0-rmse:0.24267	validation_1-rmse:0.33410
# [97]	validation_0-rmse:0.24157	validation_1-rmse:0.33438
# [98]	validation_0-rmse:0.24054	validation_1-rmse:0.33519
# [99]	validation_0-rmse:0.23947	validation_1-rmse:0.33483
# [100]	validation_0-rmse:0.23848	validation_1-rmse:0.33488
# [101]	validation_0-rmse:0.23738	validation_1-rmse:0.33447
# [102]	validation_0-rmse:0.23640	validation_1-rmse:0.33416
# [103]	validation_0-rmse:0.23556	validation_1-rmse:0.33420
# [104]	validation_0-rmse:0.23466	validation_1-rmse:0.33428
# [105]	validation_0-rmse:0.23383	validation_1-rmse:0.33429
# [106]	validation_0-rmse:0.23295	validation_1-rmse:0.33401
# [107]	validation_0-rmse:0.23201	validation_1-rmse:0.33367
# [108]	validation_0-rmse:0.23120	validation_1-rmse:0.33364
# [109]	validation_0-rmse:0.23045	validation_1-rmse:0.33363
# [110]	validation_0-rmse:0.22965	validation_1-rmse:0.33373
# [111]	validation_0-rmse:0.22877	validation_1-rmse:0.33342
# [112]	validation_0-rmse:0.22802	validation_1-rmse:0.33352
# [113]	validation_0-rmse:0.22733	validation_1-rmse:0.33352
# [114]	validation_0-rmse:0.22660	validation_1-rmse:0.33334
# [115]	validation_0-rmse:0.22581	validation_1-rmse:0.33437
# [116]	validation_0-rmse:0.22505	validation_1-rmse:0.33567
# [117]	validation_0-rmse:0.22442	validation_1-rmse:0.33569
# [118]	validation_0-rmse:0.22380	validation_1-rmse:0.33570
# [119]	validation_0-rmse:0.22325	validation_1-rmse:0.33581
# [120]	validation_0-rmse:0.22258	validation_1-rmse:0.33566
# [121]	validation_0-rmse:0.22202	validation_1-rmse:0.33568
# [122]	validation_0-rmse:0.22138	validation_1-rmse:0.33609
# [123]	validation_0-rmse:0.22087	validation_1-rmse:0.33620
# [124]	validation_0-rmse:0.22027	validation_1-rmse:0.33616
# [125]	validation_0-rmse:0.21978	validation_1-rmse:0.33628
# [126]	validation_0-rmse:0.21921	validation_1-rmse:0.33614
# [127]	validation_0-rmse:0.21847	validation_1-rmse:0.33616
# [128]	validation_0-rmse:0.21783	validation_1-rmse:0.33632
# [129]	validation_0-rmse:0.21737	validation_1-rmse:0.33644
# [130]	validation_0-rmse:0.21691	validation_1-rmse:0.33646
# [131]	validation_0-rmse:0.21631	validation_1-rmse:0.33664
# [132]	validation_0-rmse:0.21583	validation_1-rmse:0.33668
# [133]	validation_0-rmse:0.21541	validation_1-rmse:0.33668
# [134]	validation_0-rmse:0.21477	validation_1-rmse:0.33637
# [0]	validation_0-rmse:0.82411	validation_1-rmse:0.56050
# [1]	validation_0-rmse:0.80688	validation_1-rmse:0.55273
# [2]	validation_0-rmse:0.79028	validation_1-rmse:0.54523
# [3]	validation_0-rmse:0.77382	validation_1-rmse:0.53895
# [4]	validation_0-rmse:0.75781	validation_1-rmse:0.53292
# [5]	validation_0-rmse:0.74236	validation_1-rmse:0.52618
# [6]	validation_0-rmse:0.72719	validation_1-rmse:0.52060
# [7]	validation_0-rmse:0.71245	validation_1-rmse:0.51544
# [8]	validation_0-rmse:0.69809	validation_1-rmse:0.51030
# [9]	validation_0-rmse:0.68412	validation_1-rmse:0.50538
# [10]	validation_0-rmse:0.67054	validation_1-rmse:0.50066
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [11]	validation_0-rmse:0.65758	validation_1-rmse:0.49532
# [12]	validation_0-rmse:0.64442	validation_1-rmse:0.49086
# [13]	validation_0-rmse:0.63194	validation_1-rmse:0.48672
# [14]	validation_0-rmse:0.61977	validation_1-rmse:0.48272
# [15]	validation_0-rmse:0.60806	validation_1-rmse:0.47908
# [16]	validation_0-rmse:0.59655	validation_1-rmse:0.47542
# [17]	validation_0-rmse:0.58531	validation_1-rmse:0.47190
# [18]	validation_0-rmse:0.57427	validation_1-rmse:0.46668
# [19]	validation_0-rmse:0.56376	validation_1-rmse:0.46155
# [20]	validation_0-rmse:0.55357	validation_1-rmse:0.45664
# [21]	validation_0-rmse:0.54351	validation_1-rmse:0.45360
# [22]	validation_0-rmse:0.53376	validation_1-rmse:0.45070
# [23]	validation_0-rmse:0.52430	validation_1-rmse:0.44800
# [24]	validation_0-rmse:0.51521	validation_1-rmse:0.44484
# [25]	validation_0-rmse:0.50631	validation_1-rmse:0.44231
# [26]	validation_0-rmse:0.49764	validation_1-rmse:0.43996
# [27]	validation_0-rmse:0.48922	validation_1-rmse:0.43778
# [28]	validation_0-rmse:0.48130	validation_1-rmse:0.43416
# [29]	validation_0-rmse:0.47331	validation_1-rmse:0.43198
# [30]	validation_0-rmse:0.46556	validation_1-rmse:0.42912
# [31]	validation_0-rmse:0.45817	validation_1-rmse:0.42678
# [32]	validation_0-rmse:0.45086	validation_1-rmse:0.42557
# [33]	validation_0-rmse:0.44409	validation_1-rmse:0.42400
# [34]	validation_0-rmse:0.43708	validation_1-rmse:0.42218
# [35]	validation_0-rmse:0.43015	validation_1-rmse:0.41925
# [36]	validation_0-rmse:0.42345	validation_1-rmse:0.41643
# [37]	validation_0-rmse:0.41713	validation_1-rmse:0.41423
# [38]	validation_0-rmse:0.41112	validation_1-rmse:0.41155
# [39]	validation_0-rmse:0.40544	validation_1-rmse:0.40851
# [40]	validation_0-rmse:0.39940	validation_1-rmse:0.40688
# [41]	validation_0-rmse:0.39359	validation_1-rmse:0.40488
# [42]	validation_0-rmse:0.38832	validation_1-rmse:0.40339
# [43]	validation_0-rmse:0.38285	validation_1-rmse:0.40116
# [44]	validation_0-rmse:0.37742	validation_1-rmse:0.39903
# [45]	validation_0-rmse:0.37237	validation_1-rmse:0.39745
# [46]	validation_0-rmse:0.36722	validation_1-rmse:0.39526
# [47]	validation_0-rmse:0.36233	validation_1-rmse:0.39335
# [48]	validation_0-rmse:0.35771	validation_1-rmse:0.39245
# [49]	validation_0-rmse:0.35300	validation_1-rmse:0.39062
# [50]	validation_0-rmse:0.34855	validation_1-rmse:0.38891
# [51]	validation_0-rmse:0.34425	validation_1-rmse:0.38728
# [52]	validation_0-rmse:0.34009	validation_1-rmse:0.38567
# [53]	validation_0-rmse:0.33605	validation_1-rmse:0.38480
# [54]	validation_0-rmse:0.33193	validation_1-rmse:0.38313
# [55]	validation_0-rmse:0.32796	validation_1-rmse:0.38153
# [56]	validation_0-rmse:0.32413	validation_1-rmse:0.37990
# [57]	validation_0-rmse:0.32050	validation_1-rmse:0.37872
# [58]	validation_0-rmse:0.31692	validation_1-rmse:0.37721
# [59]	validation_0-rmse:0.31342	validation_1-rmse:0.37621
# [60]	validation_0-rmse:0.31007	validation_1-rmse:0.37522
# [61]	validation_0-rmse:0.30683	validation_1-rmse:0.37397
# [62]	validation_0-rmse:0.30366	validation_1-rmse:0.37243
# [63]	validation_0-rmse:0.30061	validation_1-rmse:0.37153
# [64]	validation_0-rmse:0.29767	validation_1-rmse:0.37040
# [65]	validation_0-rmse:0.29471	validation_1-rmse:0.36992
# [66]	validation_0-rmse:0.29194	validation_1-rmse:0.36935
# [67]	validation_0-rmse:0.28920	validation_1-rmse:0.36802
# [68]	validation_0-rmse:0.28656	validation_1-rmse:0.36675
# [69]	validation_0-rmse:0.28427	validation_1-rmse:0.36678
# [70]	validation_0-rmse:0.28187	validation_1-rmse:0.36615
# [71]	validation_0-rmse:0.27956	validation_1-rmse:0.36561
# [72]	validation_0-rmse:0.27733	validation_1-rmse:0.36552
# [73]	validation_0-rmse:0.27531	validation_1-rmse:0.36541
# [74]	validation_0-rmse:0.27315	validation_1-rmse:0.36535
# [75]	validation_0-rmse:0.27112	validation_1-rmse:0.36488
# [76]	validation_0-rmse:0.26916	validation_1-rmse:0.36432
# [77]	validation_0-rmse:0.26719	validation_1-rmse:0.36395
# [78]	validation_0-rmse:0.26524	validation_1-rmse:0.36302
# [79]	validation_0-rmse:0.26345	validation_1-rmse:0.36310
# [80]	validation_0-rmse:0.26160	validation_1-rmse:0.36229
# [81]	validation_0-rmse:0.26001	validation_1-rmse:0.36234
# [82]	validation_0-rmse:0.25832	validation_1-rmse:0.36236
# [83]	validation_0-rmse:0.25658	validation_1-rmse:0.36148
# [84]	validation_0-rmse:0.25487	validation_1-rmse:0.36097
# [85]	validation_0-rmse:0.25328	validation_1-rmse:0.35998
# [86]	validation_0-rmse:0.25194	validation_1-rmse:0.36027
# [87]	validation_0-rmse:0.25064	validation_1-rmse:0.36055
# [88]	validation_0-rmse:0.24934	validation_1-rmse:0.36041
# [89]	validation_0-rmse:0.24796	validation_1-rmse:0.35997
# [90]	validation_0-rmse:0.24678	validation_1-rmse:0.35990
# [91]	validation_0-rmse:0.24550	validation_1-rmse:0.35946
# [92]	validation_0-rmse:0.24438	validation_1-rmse:0.35952
# [93]	validation_0-rmse:0.24308	validation_1-rmse:0.35936
# [94]	validation_0-rmse:0.24193	validation_1-rmse:0.35950
# [95]	validation_0-rmse:0.24069	validation_1-rmse:0.35893
# [96]	validation_0-rmse:0.23971	validation_1-rmse:0.35916
# [97]	validation_0-rmse:0.23878	validation_1-rmse:0.35895
# [98]	validation_0-rmse:0.23787	validation_1-rmse:0.35920
# [99]	validation_0-rmse:0.23698	validation_1-rmse:0.35926
# [100]	validation_0-rmse:0.23611	validation_1-rmse:0.35930
# [101]	validation_0-rmse:0.23527	validation_1-rmse:0.35938
# [102]	validation_0-rmse:0.23447	validation_1-rmse:0.35939
# [103]	validation_0-rmse:0.23357	validation_1-rmse:0.35941
# [104]	validation_0-rmse:0.23263	validation_1-rmse:0.35915
# [105]	validation_0-rmse:0.23185	validation_1-rmse:0.35918
# [106]	validation_0-rmse:0.23113	validation_1-rmse:0.35925
# [107]	validation_0-rmse:0.23043	validation_1-rmse:0.35929
# [108]	validation_0-rmse:0.22954	validation_1-rmse:0.35885
# [109]	validation_0-rmse:0.22888	validation_1-rmse:0.35890
# [110]	validation_0-rmse:0.22779	validation_1-rmse:0.35846
# [111]	validation_0-rmse:0.22699	validation_1-rmse:0.35804
# [112]	validation_0-rmse:0.22639	validation_1-rmse:0.35829
# [113]	validation_0-rmse:0.22537	validation_1-rmse:0.35797
# [114]	validation_0-rmse:0.22480	validation_1-rmse:0.35803
# [115]	validation_0-rmse:0.22425	validation_1-rmse:0.35809
# [116]	validation_0-rmse:0.22331	validation_1-rmse:0.35781
# [117]	validation_0-rmse:0.22239	validation_1-rmse:0.35744
# [118]	validation_0-rmse:0.22152	validation_1-rmse:0.35722
# [119]	validation_0-rmse:0.22103	validation_1-rmse:0.35729
# [120]	validation_0-rmse:0.22055	validation_1-rmse:0.35755
# [121]	validation_0-rmse:0.22006	validation_1-rmse:0.35733
# [122]	validation_0-rmse:0.21937	validation_1-rmse:0.35700
# [123]	validation_0-rmse:0.21893	validation_1-rmse:0.35728
# [124]	validation_0-rmse:0.21848	validation_1-rmse:0.35734
# [125]	validation_0-rmse:0.21769	validation_1-rmse:0.35719
# [126]	validation_0-rmse:0.21687	validation_1-rmse:0.35726
# [127]	validation_0-rmse:0.21648	validation_1-rmse:0.35749
# [128]	validation_0-rmse:0.21608	validation_1-rmse:0.35762
# [129]	validation_0-rmse:0.21543	validation_1-rmse:0.35771
# [130]	validation_0-rmse:0.21506	validation_1-rmse:0.35779
# [131]	validation_0-rmse:0.21469	validation_1-rmse:0.35786
# [132]	validation_0-rmse:0.21407	validation_1-rmse:0.35835
# [133]	validation_0-rmse:0.21334	validation_1-rmse:0.35900
# [134]	validation_0-rmse:0.21278	validation_1-rmse:0.35884
# [135]	validation_0-rmse:0.21208	validation_1-rmse:0.35874
# [136]	validation_0-rmse:0.21162	validation_1-rmse:0.35850
# [137]	validation_0-rmse:0.21096	validation_1-rmse:0.35839
# [138]	validation_0-rmse:0.21038	validation_1-rmse:0.35872
# [139]	validation_0-rmse:0.20979	validation_1-rmse:0.35920
# [140]	validation_0-rmse:0.20915	validation_1-rmse:0.35910
# [141]	validation_0-rmse:0.20882	validation_1-rmse:0.35921
# [0]	validation_0-rmse:0.82403	validation_1-rmse:0.56022
# [1]	validation_0-rmse:0.80737	validation_1-rmse:0.54761
# [2]	validation_0-rmse:0.79117	validation_1-rmse:0.53627
# [3]	validation_0-rmse:0.77537	validation_1-rmse:0.52433
# [4]	validation_0-rmse:0.76001	validation_1-rmse:0.51277
# [5]	validation_0-rmse:0.74506	validation_1-rmse:0.50237
# [6]	validation_0-rmse:0.73050	validation_1-rmse:0.48965
# [7]	validation_0-rmse:0.71630	validation_1-rmse:0.47949
# [8]	validation_0-rmse:0.70250	validation_1-rmse:0.46803
# [9]	validation_0-rmse:0.68906	validation_1-rmse:0.45726
# [10]	validation_0-rmse:0.67598	validation_1-rmse:0.44713
# [11]	validation_0-rmse:0.66322	validation_1-rmse:0.43846
# [12]	validation_0-rmse:0.65064	validation_1-rmse:0.42940
# [13]	validation_0-rmse:0.63856	validation_1-rmse:0.41958
# [14]	validation_0-rmse:0.62679	validation_1-rmse:0.41153
# [15]	validation_0-rmse:0.61558	validation_1-rmse:0.40318
# [16]	validation_0-rmse:0.60445	validation_1-rmse:0.39572
# [17]	validation_0-rmse:0.59366	validation_1-rmse:0.38757
# [18]	validation_0-rmse:0.58316	validation_1-rmse:0.38079
# [19]	validation_0-rmse:0.57296	validation_1-rmse:0.37347
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [20]	validation_0-rmse:0.56306	validation_1-rmse:0.36720
# [21]	validation_0-rmse:0.55336	validation_1-rmse:0.36030
# [22]	validation_0-rmse:0.54395	validation_1-rmse:0.35444
# [23]	validation_0-rmse:0.53483	validation_1-rmse:0.34880
# [24]	validation_0-rmse:0.52597	validation_1-rmse:0.34278
# [25]	validation_0-rmse:0.51736	validation_1-rmse:0.33764
# [26]	validation_0-rmse:0.50898	validation_1-rmse:0.33150
# [27]	validation_0-rmse:0.50088	validation_1-rmse:0.32686
# [28]	validation_0-rmse:0.49315	validation_1-rmse:0.32151
# [29]	validation_0-rmse:0.48539	validation_1-rmse:0.31697
# [30]	validation_0-rmse:0.47789	validation_1-rmse:0.31310
# [31]	validation_0-rmse:0.47068	validation_1-rmse:0.30866
# [32]	validation_0-rmse:0.46362	validation_1-rmse:0.30479
# [33]	validation_0-rmse:0.45677	validation_1-rmse:0.30087
# [34]	validation_0-rmse:0.44957	validation_1-rmse:0.29756
# [35]	validation_0-rmse:0.44320	validation_1-rmse:0.29486
# [36]	validation_0-rmse:0.43687	validation_1-rmse:0.29224
# [37]	validation_0-rmse:0.43079	validation_1-rmse:0.28944
# [38]	validation_0-rmse:0.42487	validation_1-rmse:0.28628
# [39]	validation_0-rmse:0.41915	validation_1-rmse:0.28333
# [40]	validation_0-rmse:0.41352	validation_1-rmse:0.28068
# [41]	validation_0-rmse:0.40801	validation_1-rmse:0.27815
# [42]	validation_0-rmse:0.40255	validation_1-rmse:0.27595
# [43]	validation_0-rmse:0.39745	validation_1-rmse:0.27470
# [44]	validation_0-rmse:0.39241	validation_1-rmse:0.27343
# [45]	validation_0-rmse:0.38699	validation_1-rmse:0.27200
# [46]	validation_0-rmse:0.38184	validation_1-rmse:0.27058
# [47]	validation_0-rmse:0.37726	validation_1-rmse:0.26923
# [48]	validation_0-rmse:0.37273	validation_1-rmse:0.26706
# [49]	validation_0-rmse:0.36802	validation_1-rmse:0.26641
# [50]	validation_0-rmse:0.36384	validation_1-rmse:0.26516
# [51]	validation_0-rmse:0.35980	validation_1-rmse:0.26377
# [52]	validation_0-rmse:0.35545	validation_1-rmse:0.26350
# [53]	validation_0-rmse:0.35164	validation_1-rmse:0.26196
# [54]	validation_0-rmse:0.34756	validation_1-rmse:0.26181
# [55]	validation_0-rmse:0.34364	validation_1-rmse:0.26152
# [56]	validation_0-rmse:0.33986	validation_1-rmse:0.26135
# [57]	validation_0-rmse:0.33661	validation_1-rmse:0.26140
# [58]	validation_0-rmse:0.33301	validation_1-rmse:0.26161
# [59]	validation_0-rmse:0.32976	validation_1-rmse:0.26130
# [60]	validation_0-rmse:0.32663	validation_1-rmse:0.26111
# [61]	validation_0-rmse:0.32341	validation_1-rmse:0.26085
# [62]	validation_0-rmse:0.32023	validation_1-rmse:0.26088
# [63]	validation_0-rmse:0.31738	validation_1-rmse:0.26092
# [64]	validation_0-rmse:0.31439	validation_1-rmse:0.26149
# [65]	validation_0-rmse:0.31155	validation_1-rmse:0.26096
# [66]	validation_0-rmse:0.30878	validation_1-rmse:0.26137
# [67]	validation_0-rmse:0.30608	validation_1-rmse:0.26207
# [68]	validation_0-rmse:0.30356	validation_1-rmse:0.26214
# [69]	validation_0-rmse:0.30111	validation_1-rmse:0.26262
# [70]	validation_0-rmse:0.29872	validation_1-rmse:0.26278
# [71]	validation_0-rmse:0.29642	validation_1-rmse:0.26299
# [72]	validation_0-rmse:0.29420	validation_1-rmse:0.26306
# [73]	validation_0-rmse:0.29200	validation_1-rmse:0.26311
# [74]	validation_0-rmse:0.28988	validation_1-rmse:0.26282
# [75]	validation_0-rmse:0.28785	validation_1-rmse:0.26279
# [76]	validation_0-rmse:0.28591	validation_1-rmse:0.26278
# [77]	validation_0-rmse:0.28402	validation_1-rmse:0.26327
# [78]	validation_0-rmse:0.28215	validation_1-rmse:0.26366
# [79]	validation_0-rmse:0.28032	validation_1-rmse:0.26392
# [80]	validation_0-rmse:0.27841	validation_1-rmse:0.26455
# [81]	validation_0-rmse:0.27668	validation_1-rmse:0.26449
# [0]	validation_0-rmse:0.80334	validation_1-rmse:0.66876
# [1]	validation_0-rmse:0.78719	validation_1-rmse:0.65593
# [2]	validation_0-rmse:0.77148	validation_1-rmse:0.64346
# [3]	validation_0-rmse:0.75604	validation_1-rmse:0.62926
# [4]	validation_0-rmse:0.74102	validation_1-rmse:0.61546
# [5]	validation_0-rmse:0.72654	validation_1-rmse:0.60398
# [6]	validation_0-rmse:0.71232	validation_1-rmse:0.59093
# [7]	validation_0-rmse:0.69848	validation_1-rmse:0.57914
# [8]	validation_0-rmse:0.68501	validation_1-rmse:0.56681
# [9]	validation_0-rmse:0.67192	validation_1-rmse:0.55577
# [10]	validation_0-rmse:0.65921	validation_1-rmse:0.54515
# [11]	validation_0-rmse:0.64695	validation_1-rmse:0.53507
# [12]	validation_0-rmse:0.63487	validation_1-rmse:0.52412
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [13]	validation_0-rmse:0.62315	validation_1-rmse:0.51457
# [14]	validation_0-rmse:0.61173	validation_1-rmse:0.50427
# [15]	validation_0-rmse:0.60070	validation_1-rmse:0.49439
# [16]	validation_0-rmse:0.58994	validation_1-rmse:0.48478
# [17]	validation_0-rmse:0.57944	validation_1-rmse:0.47640
# [18]	validation_0-rmse:0.56928	validation_1-rmse:0.46900
# [19]	validation_0-rmse:0.55944	validation_1-rmse:0.46114
# [20]	validation_0-rmse:0.54988	validation_1-rmse:0.45448
# [21]	validation_0-rmse:0.54042	validation_1-rmse:0.44698
# [22]	validation_0-rmse:0.53133	validation_1-rmse:0.43900
# [23]	validation_0-rmse:0.52251	validation_1-rmse:0.43130
# [24]	validation_0-rmse:0.51397	validation_1-rmse:0.42560
# [25]	validation_0-rmse:0.50571	validation_1-rmse:0.41861
# [26]	validation_0-rmse:0.49752	validation_1-rmse:0.41291
# [27]	validation_0-rmse:0.48948	validation_1-rmse:0.40622
# [28]	validation_0-rmse:0.48195	validation_1-rmse:0.40077
# [29]	validation_0-rmse:0.47445	validation_1-rmse:0.39451
# [30]	validation_0-rmse:0.46726	validation_1-rmse:0.38939
# [31]	validation_0-rmse:0.46029	validation_1-rmse:0.38524
# [32]	validation_0-rmse:0.45343	validation_1-rmse:0.38037
# [33]	validation_0-rmse:0.44679	validation_1-rmse:0.37497
# [34]	validation_0-rmse:0.44047	validation_1-rmse:0.37058
# [35]	validation_0-rmse:0.43422	validation_1-rmse:0.36684
# [36]	validation_0-rmse:0.42819	validation_1-rmse:0.36202
# [37]	validation_0-rmse:0.42246	validation_1-rmse:0.35774
# [38]	validation_0-rmse:0.41681	validation_1-rmse:0.35486
# [39]	validation_0-rmse:0.41136	validation_1-rmse:0.35130
# [40]	validation_0-rmse:0.40594	validation_1-rmse:0.34717
# [41]	validation_0-rmse:0.40081	validation_1-rmse:0.34474
# [42]	validation_0-rmse:0.39586	validation_1-rmse:0.34243
# [43]	validation_0-rmse:0.39095	validation_1-rmse:0.33952
# [44]	validation_0-rmse:0.38613	validation_1-rmse:0.33597
# [45]	validation_0-rmse:0.38150	validation_1-rmse:0.33380
# [46]	validation_0-rmse:0.37678	validation_1-rmse:0.32994
# [47]	validation_0-rmse:0.37248	validation_1-rmse:0.32758
# [48]	validation_0-rmse:0.36815	validation_1-rmse:0.32422
# [49]	validation_0-rmse:0.36383	validation_1-rmse:0.32191
# [50]	validation_0-rmse:0.35991	validation_1-rmse:0.31929
# [51]	validation_0-rmse:0.35595	validation_1-rmse:0.31641
# [52]	validation_0-rmse:0.35194	validation_1-rmse:0.31387
# [53]	validation_0-rmse:0.34835	validation_1-rmse:0.31156
# [54]	validation_0-rmse:0.34464	validation_1-rmse:0.30881
# [55]	validation_0-rmse:0.34101	validation_1-rmse:0.30589
# [56]	validation_0-rmse:0.33755	validation_1-rmse:0.30407
# [57]	validation_0-rmse:0.33410	validation_1-rmse:0.30144
# [58]	validation_0-rmse:0.33086	validation_1-rmse:0.29949
# [59]	validation_0-rmse:0.32774	validation_1-rmse:0.29735
# [60]	validation_0-rmse:0.32465	validation_1-rmse:0.29492
# [61]	validation_0-rmse:0.32175	validation_1-rmse:0.29384
# [62]	validation_0-rmse:0.31886	validation_1-rmse:0.29203
# [63]	validation_0-rmse:0.31605	validation_1-rmse:0.28999
# [64]	validation_0-rmse:0.31328	validation_1-rmse:0.28854
# [65]	validation_0-rmse:0.31057	validation_1-rmse:0.28773
# [66]	validation_0-rmse:0.30800	validation_1-rmse:0.28592
# [67]	validation_0-rmse:0.30554	validation_1-rmse:0.28472
# [68]	validation_0-rmse:0.30322	validation_1-rmse:0.28412
# [69]	validation_0-rmse:0.30092	validation_1-rmse:0.28347
# [70]	validation_0-rmse:0.29866	validation_1-rmse:0.28271
# [71]	validation_0-rmse:0.29643	validation_1-rmse:0.28176
# [72]	validation_0-rmse:0.29437	validation_1-rmse:0.28134
# [73]	validation_0-rmse:0.29232	validation_1-rmse:0.28074
# [74]	validation_0-rmse:0.29029	validation_1-rmse:0.27966
# [75]	validation_0-rmse:0.28831	validation_1-rmse:0.27888
# [76]	validation_0-rmse:0.28640	validation_1-rmse:0.27761
# [77]	validation_0-rmse:0.28455	validation_1-rmse:0.27670
# [78]	validation_0-rmse:0.28278	validation_1-rmse:0.27641
# [79]	validation_0-rmse:0.28104	validation_1-rmse:0.27597
# [80]	validation_0-rmse:0.27929	validation_1-rmse:0.27535
# [81]	validation_0-rmse:0.27764	validation_1-rmse:0.27496
# [82]	validation_0-rmse:0.27607	validation_1-rmse:0.27431
# [83]	validation_0-rmse:0.27454	validation_1-rmse:0.27396
# [84]	validation_0-rmse:0.27296	validation_1-rmse:0.27379
# [85]	validation_0-rmse:0.27151	validation_1-rmse:0.27348
# [86]	validation_0-rmse:0.27024	validation_1-rmse:0.27342
# [87]	validation_0-rmse:0.26882	validation_1-rmse:0.27287
# [88]	validation_0-rmse:0.26740	validation_1-rmse:0.27275
# [89]	validation_0-rmse:0.26611	validation_1-rmse:0.27219
# [90]	validation_0-rmse:0.26496	validation_1-rmse:0.27211
# [91]	validation_0-rmse:0.26372	validation_1-rmse:0.27181
# [92]	validation_0-rmse:0.26250	validation_1-rmse:0.27191
# [93]	validation_0-rmse:0.26129	validation_1-rmse:0.27201
# [94]	validation_0-rmse:0.26007	validation_1-rmse:0.27186
# [95]	validation_0-rmse:0.25887	validation_1-rmse:0.27184
# [96]	validation_0-rmse:0.25775	validation_1-rmse:0.27120
# [97]	validation_0-rmse:0.25666	validation_1-rmse:0.27116
# [98]	validation_0-rmse:0.25578	validation_1-rmse:0.27083
# [99]	validation_0-rmse:0.25473	validation_1-rmse:0.27079
# [100]	validation_0-rmse:0.25378	validation_1-rmse:0.27021
# [101]	validation_0-rmse:0.25294	validation_1-rmse:0.27039
# [102]	validation_0-rmse:0.25198	validation_1-rmse:0.27036
# [103]	validation_0-rmse:0.25112	validation_1-rmse:0.26984
# [104]	validation_0-rmse:0.25020	validation_1-rmse:0.26982
# [105]	validation_0-rmse:0.24945	validation_1-rmse:0.27003
# [106]	validation_0-rmse:0.24852	validation_1-rmse:0.27010
# [107]	validation_0-rmse:0.24780	validation_1-rmse:0.27034
# [108]	validation_0-rmse:0.24694	validation_1-rmse:0.27050
# [109]	validation_0-rmse:0.24599	validation_1-rmse:0.27077
# [110]	validation_0-rmse:0.24532	validation_1-rmse:0.27103
# [111]	validation_0-rmse:0.24442	validation_1-rmse:0.27131
# [112]	validation_0-rmse:0.24372	validation_1-rmse:0.27131
# [113]	validation_0-rmse:0.24311	validation_1-rmse:0.27142
# [114]	validation_0-rmse:0.24239	validation_1-rmse:0.27144
# [115]	validation_0-rmse:0.24170	validation_1-rmse:0.27147
# [116]	validation_0-rmse:0.24104	validation_1-rmse:0.27150
# [117]	validation_0-rmse:0.24042	validation_1-rmse:0.27180
# [118]	validation_0-rmse:0.23988	validation_1-rmse:0.27209
# [119]	validation_0-rmse:0.23930	validation_1-rmse:0.27241
# [120]	validation_0-rmse:0.23867	validation_1-rmse:0.27259
# [121]	validation_0-rmse:0.23805	validation_1-rmse:0.27251
# [122]	validation_0-rmse:0.23752	validation_1-rmse:0.27283
# [123]	validation_0-rmse:0.23702	validation_1-rmse:0.27297
# [124]	validation_0-rmse:0.23649	validation_1-rmse:0.27300
# [0]	validation_0-rmse:0.77997	validation_1-rmse:0.77101
# [1]	validation_0-rmse:0.76452	validation_1-rmse:0.75690
# [2]	validation_0-rmse:0.74943	validation_1-rmse:0.74312
# [3]	validation_0-rmse:0.73465	validation_1-rmse:0.72972
# [4]	validation_0-rmse:0.72026	validation_1-rmse:0.71674
# [5]	validation_0-rmse:0.70645	validation_1-rmse:0.70407
# [6]	validation_0-rmse:0.69284	validation_1-rmse:0.69178
# [7]	validation_0-rmse:0.67964	validation_1-rmse:0.67975
# [8]	validation_0-rmse:0.66679	validation_1-rmse:0.66812
# [9]	validation_0-rmse:0.65443	validation_1-rmse:0.65602
# [10]	validation_0-rmse:0.64244	validation_1-rmse:0.64425
# [11]	validation_0-rmse:0.63077	validation_1-rmse:0.63374
# [12]	validation_0-rmse:0.61949	validation_1-rmse:0.62340
# [13]	validation_0-rmse:0.60849	validation_1-rmse:0.61195
# [14]	validation_0-rmse:0.59781	validation_1-rmse:0.60218
# [15]	validation_0-rmse:0.58733	validation_1-rmse:0.59276
# [16]	validation_0-rmse:0.57714	validation_1-rmse:0.58335
# [17]	validation_0-rmse:0.56728	validation_1-rmse:0.57301
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [18]	validation_0-rmse:0.55774	validation_1-rmse:0.56472
# [19]	validation_0-rmse:0.54848	validation_1-rmse:0.55650
# [20]	validation_0-rmse:0.53949	validation_1-rmse:0.54718
# [21]	validation_0-rmse:0.53065	validation_1-rmse:0.53898
# [22]	validation_0-rmse:0.52208	validation_1-rmse:0.52991
# [23]	validation_0-rmse:0.51376	validation_1-rmse:0.52213
# [24]	validation_0-rmse:0.50573	validation_1-rmse:0.51398
# [25]	validation_0-rmse:0.49788	validation_1-rmse:0.50682
# [26]	validation_0-rmse:0.48989	validation_1-rmse:0.50012
# [27]	validation_0-rmse:0.48248	validation_1-rmse:0.49574
# [28]	validation_0-rmse:0.47522	validation_1-rmse:0.48820
# [29]	validation_0-rmse:0.46818	validation_1-rmse:0.48059
# [30]	validation_0-rmse:0.46139	validation_1-rmse:0.47318
# [31]	validation_0-rmse:0.45436	validation_1-rmse:0.46825
# [32]	validation_0-rmse:0.44764	validation_1-rmse:0.46123
# ...
# [28]	validation_0-rmse:0.46358	validation_1-rmse:0.53762
# [29]	validation_0-rmse:0.45676	validation_1-rmse:0.53056
# [30]	validation_0-rmse:0.45012	validation_1-rmse:0.52379
# [31]	validation_0-rmse:0.44377	validation_1-rmse:0.51699
# [32]	validation_0-rmse:0.43747	validation_1-rmse:0.51046
# [33]	validation_0-rmse:0.43121	validation_1-rmse:0.50404
# [34]	validation_0-rmse:0.42499	validation_1-rmse:0.49725
# [35]	validation_0-rmse:0.41886	validation_1-rmse:0.49048
# [36]	validation_0-rmse:0.41308	validation_1-rmse:0.48453
# [37]	validation_0-rmse:0.40731	validation_1-rmse:0.47861
# [38]	validation_0-rmse:0.40189	validation_1-rmse:0.47216
# [39]	validation_0-rmse:0.39688	validation_1-rmse:0.46679
# [40]	validation_0-rmse:0.39193	validation_1-rmse:0.46152
# [41]	validation_0-rmse:0.38695	validation_1-rmse:0.45560
# [42]	validation_0-rmse:0.38236	validation_1-rmse:0.45066
# [43]	validation_0-rmse:0.37765	validation_1-rmse:0.44574
# [44]	validation_0-rmse:0.37306	validation_1-rmse:0.44007
# [45]	validation_0-rmse:0.36872	validation_1-rmse:0.43551
# [46]	validation_0-rmse:0.36410	validation_1-rmse:0.43063
# [47]	validation_0-rmse:0.35989	validation_1-rmse:0.42622
# [48]	validation_0-rmse:0.35589	validation_1-rmse:0.42152
# [49]	validation_0-rmse:0.35172	validation_1-rmse:0.41697
# [50]	validation_0-rmse:0.34788	validation_1-rmse:0.41303
# [51]	validation_0-rmse:0.34417	validation_1-rmse:0.40911
# [52]	validation_0-rmse:0.34030	validation_1-rmse:0.40482
# [53]	validation_0-rmse:0.33680	validation_1-rmse:0.40122
# [54]	validation_0-rmse:0.33319	validation_1-rmse:0.39772
# [55]	validation_0-rmse:0.32970	validation_1-rmse:0.39415
# [56]	validation_0-rmse:0.32635	validation_1-rmse:0.39094
# [57]	validation_0-rmse:0.32324	validation_1-rmse:0.38735
# [58]	validation_0-rmse:0.32008	validation_1-rmse:0.38396
# [59]	validation_0-rmse:0.31722	validation_1-rmse:0.38095
# [60]	validation_0-rmse:0.31435	validation_1-rmse:0.37797
# [61]	validation_0-rmse:0.31158	validation_1-rmse:0.37509
# [62]	validation_0-rmse:0.30879	validation_1-rmse:0.37240
# [63]	validation_0-rmse:0.30619	validation_1-rmse:0.36998
# [64]	validation_0-rmse:0.30357	validation_1-rmse:0.36724
# [65]	validation_0-rmse:0.30106	validation_1-rmse:0.36462
# [66]	validation_0-rmse:0.29860	validation_1-rmse:0.36226
# [67]	validation_0-rmse:0.29631	validation_1-rmse:0.35978
# [68]	validation_0-rmse:0.29409	validation_1-rmse:0.35708
# [69]	validation_0-rmse:0.29188	validation_1-rmse:0.35446
# [70]	validation_0-rmse:0.28979	validation_1-rmse:0.35254
# [71]	validation_0-rmse:0.28779	validation_1-rmse:0.35034
# [72]	validation_0-rmse:0.28586	validation_1-rmse:0.34858
# [73]	validation_0-rmse:0.28372	validation_1-rmse:0.34639
# [74]	validation_0-rmse:0.28179	validation_1-rmse:0.34495
# [75]	validation_0-rmse:0.28004	validation_1-rmse:0.34312
# [76]	validation_0-rmse:0.27834	validation_1-rmse:0.34163
# [77]	validation_0-rmse:0.27666	validation_1-rmse:0.33979
# [78]	validation_0-rmse:0.27499	validation_1-rmse:0.33770
# [79]	validation_0-rmse:0.27349	validation_1-rmse:0.33640
# [80]	validation_0-rmse:0.27164	validation_1-rmse:0.33495
# [81]	validation_0-rmse:0.27006	validation_1-rmse:0.33302
# [82]	validation_0-rmse:0.26862	validation_1-rmse:0.33176
# [83]	validation_0-rmse:0.26713	validation_1-rmse:0.32987
# [84]	validation_0-rmse:0.26551	validation_1-rmse:0.32834
# [85]	validation_0-rmse:0.26412	validation_1-rmse:0.32658
# [86]	validation_0-rmse:0.26281	validation_1-rmse:0.32543
# [87]	validation_0-rmse:0.26138	validation_1-rmse:0.32386
# [88]	validation_0-rmse:0.26017	validation_1-rmse:0.32267
# [89]	validation_0-rmse:0.25881	validation_1-rmse:0.32117
# [90]	validation_0-rmse:0.25750	validation_1-rmse:0.31952
# [91]	validation_0-rmse:0.25623	validation_1-rmse:0.31879
# [92]	validation_0-rmse:0.25512	validation_1-rmse:0.31796
# [93]	validation_0-rmse:0.25392	validation_1-rmse:0.31750
# [94]	validation_0-rmse:0.25291	validation_1-rmse:0.31683
# [95]	validation_0-rmse:0.25203	validation_1-rmse:0.31600
# [96]	validation_0-rmse:0.25114	validation_1-rmse:0.31511
# [97]	validation_0-rmse:0.24986	validation_1-rmse:0.31398
# [98]	validation_0-rmse:0.24897	validation_1-rmse:0.31357
# [99]	validation_0-rmse:0.24818	validation_1-rmse:0.31272
# [100]	validation_0-rmse:0.24743	validation_1-rmse:0.31191
# [101]	validation_0-rmse:0.24669	validation_1-rmse:0.31103
# [102]	validation_0-rmse:0.24581	validation_1-rmse:0.31029
# [103]	validation_0-rmse:0.24513	validation_1-rmse:0.30970
# [104]	validation_0-rmse:0.24442	validation_1-rmse:0.30894
# [105]	validation_0-rmse:0.24345	validation_1-rmse:0.30868
# [106]	validation_0-rmse:0.24255	validation_1-rmse:0.30790
# [107]	validation_0-rmse:0.24193	validation_1-rmse:0.30716
# [108]	validation_0-rmse:0.24119	validation_1-rmse:0.30613
# [109]	validation_0-rmse:0.24019	validation_1-rmse:0.30534
# [110]	validation_0-rmse:0.23924	validation_1-rmse:0.30461
# [111]	validation_0-rmse:0.23868	validation_1-rmse:0.30416
# [112]	validation_0-rmse:0.23796	validation_1-rmse:0.30403
# [113]	validation_0-rmse:0.23743	validation_1-rmse:0.30362
# [114]	validation_0-rmse:0.23659	validation_1-rmse:0.30298
# [115]	validation_0-rmse:0.23586	validation_1-rmse:0.30303
# [116]	validation_0-rmse:0.23500	validation_1-rmse:0.30290
# [117]	validation_0-rmse:0.23452	validation_1-rmse:0.30235
# [118]	validation_0-rmse:0.23393	validation_1-rmse:0.30152
# [119]	validation_0-rmse:0.23333	validation_1-rmse:0.30084
# [120]	validation_0-rmse:0.23268	validation_1-rmse:0.30094
# [121]	validation_0-rmse:0.23223	validation_1-rmse:0.30066
# [122]	validation_0-rmse:0.23158	validation_1-rmse:0.30009
# [123]	validation_0-rmse:0.23108	validation_1-rmse:0.29998
# [124]	validation_0-rmse:0.23037	validation_1-rmse:0.29995
# [125]	validation_0-rmse:0.22997	validation_1-rmse:0.29950
# [126]	validation_0-rmse:0.22957	validation_1-rmse:0.29943
# [127]	validation_0-rmse:0.22898	validation_1-rmse:0.29946
# [128]	validation_0-rmse:0.22861	validation_1-rmse:0.29922
# [129]	validation_0-rmse:0.22797	validation_1-rmse:0.29879
# [130]	validation_0-rmse:0.22719	validation_1-rmse:0.29907
# [131]	validation_0-rmse:0.22684	validation_1-rmse:0.29886
# [132]	validation_0-rmse:0.22620	validation_1-rmse:0.29844
# [133]	validation_0-rmse:0.22573	validation_1-rmse:0.29912
# [134]	validation_0-rmse:0.22498	validation_1-rmse:0.29940
# [135]	validation_0-rmse:0.22461	validation_1-rmse:0.29901
# [136]	validation_0-rmse:0.22430	validation_1-rmse:0.29883
# [137]	validation_0-rmse:0.22358	validation_1-rmse:0.29912
# [138]	validation_0-rmse:0.22328	validation_1-rmse:0.29895
# [139]	validation_0-rmse:0.22298	validation_1-rmse:0.29861
# [140]	validation_0-rmse:0.22269	validation_1-rmse:0.29830
# [141]	validation_0-rmse:0.22230	validation_1-rmse:0.29845
# [142]	validation_0-rmse:0.22187	validation_1-rmse:0.29911
# [143]	validation_0-rmse:0.22157	validation_1-rmse:0.29888
# [144]	validation_0-rmse:0.22090	validation_1-rmse:0.29916
# [145]	validation_0-rmse:0.22053	validation_1-rmse:0.29931
# [146]	validation_0-rmse:0.21989	validation_1-rmse:0.29959
# [147]	validation_0-rmse:0.21933	validation_1-rmse:0.29964
# [0]	validation_0-rmse:0.72371	validation_1-rmse:0.96143
# [1]	validation_0-rmse:0.70951	validation_1-rmse:0.94271
# [2]	validation_0-rmse:0.69567	validation_1-rmse:0.92494
# [3]	validation_0-rmse:0.68221	validation_1-rmse:0.90717
# [4]	validation_0-rmse:0.66895	validation_1-rmse:0.89048
# [5]	validation_0-rmse:0.65623	validation_1-rmse:0.87421
# [6]	validation_0-rmse:0.64367	validation_1-rmse:0.85840
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [7]	validation_0-rmse:0.63162	validation_1-rmse:0.84281
# [8]	validation_0-rmse:0.61973	validation_1-rmse:0.82784
# [9]	validation_0-rmse:0.60833	validation_1-rmse:0.81140
# [10]	validation_0-rmse:0.59723	validation_1-rmse:0.79537
# [11]	validation_0-rmse:0.58644	validation_1-rmse:0.78224
# [12]	validation_0-rmse:0.57595	validation_1-rmse:0.76871
# [13]	validation_0-rmse:0.56567	validation_1-rmse:0.75440
# [14]	validation_0-rmse:0.55558	validation_1-rmse:0.74170
# [15]	validation_0-rmse:0.54585	validation_1-rmse:0.72956
# [16]	validation_0-rmse:0.53632	validation_1-rmse:0.71769
# [17]	validation_0-rmse:0.52708	validation_1-rmse:0.70448
# [18]	validation_0-rmse:0.51821	validation_1-rmse:0.69379
# [19]	validation_0-rmse:0.50960	validation_1-rmse:0.68110
# [20]	validation_0-rmse:0.50122	validation_1-rmse:0.67105
# [21]	validation_0-rmse:0.49294	validation_1-rmse:0.66061
# [22]	validation_0-rmse:0.48488	validation_1-rmse:0.64925
# [23]	validation_0-rmse:0.47705	validation_1-rmse:0.63967
# [24]	validation_0-rmse:0.46956	validation_1-rmse:0.62865
# [25]	validation_0-rmse:0.46217	validation_1-rmse:0.61962
# [26]	validation_0-rmse:0.45496	validation_1-rmse:0.60933
# [27]	validation_0-rmse:0.44802	validation_1-rmse:0.60081
# [28]	validation_0-rmse:0.44135	validation_1-rmse:0.59140
# [29]	validation_0-rmse:0.43474	validation_1-rmse:0.58219
# [30]	validation_0-rmse:0.42848	validation_1-rmse:0.57329
# [31]	validation_0-rmse:0.42236	validation_1-rmse:0.56585
# [32]	validation_0-rmse:0.41631	validation_1-rmse:0.55746
# [33]	validation_0-rmse:0.41029	validation_1-rmse:0.54915
# [34]	validation_0-rmse:0.40456	validation_1-rmse:0.54207
# [35]	validation_0-rmse:0.39900	validation_1-rmse:0.53519
# [36]	validation_0-rmse:0.39364	validation_1-rmse:0.52780
# [37]	validation_0-rmse:0.38844	validation_1-rmse:0.52160
# [38]	validation_0-rmse:0.38350	validation_1-rmse:0.51481
# [39]	validation_0-rmse:0.37868	validation_1-rmse:0.50910
# [40]	validation_0-rmse:0.37396	validation_1-rmse:0.50345
# [41]	validation_0-rmse:0.36945	validation_1-rmse:0.49695
# [42]	validation_0-rmse:0.36507	validation_1-rmse:0.49110
# [43]	validation_0-rmse:0.36073	validation_1-rmse:0.48531
# [44]	validation_0-rmse:0.35654	validation_1-rmse:0.48047
# [45]	validation_0-rmse:0.35250	validation_1-rmse:0.47534
# [46]	validation_0-rmse:0.34856	validation_1-rmse:0.47031
# [47]	validation_0-rmse:0.34475	validation_1-rmse:0.46569
# [48]	validation_0-rmse:0.34108	validation_1-rmse:0.46120
# [49]	validation_0-rmse:0.33739	validation_1-rmse:0.45671
# [50]	validation_0-rmse:0.33392	validation_1-rmse:0.45260
# [51]	validation_0-rmse:0.33057	validation_1-rmse:0.44869
# [52]	validation_0-rmse:0.32717	validation_1-rmse:0.44463
# [53]	validation_0-rmse:0.32401	validation_1-rmse:0.44032
# [54]	validation_0-rmse:0.32081	validation_1-rmse:0.43653
# [55]	validation_0-rmse:0.31771	validation_1-rmse:0.43288
# [56]	validation_0-rmse:0.31472	validation_1-rmse:0.42935
# [57]	validation_0-rmse:0.31181	validation_1-rmse:0.42628
# [58]	validation_0-rmse:0.30899	validation_1-rmse:0.42310
# [59]	validation_0-rmse:0.30624	validation_1-rmse:0.42025
# [60]	validation_0-rmse:0.30360	validation_1-rmse:0.41725
# [61]	validation_0-rmse:0.30103	validation_1-rmse:0.41465
# [62]	validation_0-rmse:0.29833	validation_1-rmse:0.41193
# [63]	validation_0-rmse:0.29592	validation_1-rmse:0.40901
# [64]	validation_0-rmse:0.29338	validation_1-rmse:0.40651
# [65]	validation_0-rmse:0.29092	validation_1-rmse:0.40415
# [66]	validation_0-rmse:0.28870	validation_1-rmse:0.40175
# [67]	validation_0-rmse:0.28656	validation_1-rmse:0.39943
# [68]	validation_0-rmse:0.28430	validation_1-rmse:0.39733
# [69]	validation_0-rmse:0.28220	validation_1-rmse:0.39609
# [70]	validation_0-rmse:0.28024	validation_1-rmse:0.39434
# [71]	validation_0-rmse:0.27834	validation_1-rmse:0.39268
# [72]	validation_0-rmse:0.27651	validation_1-rmse:0.39107
# [73]	validation_0-rmse:0.27455	validation_1-rmse:0.38940
# [74]	validation_0-rmse:0.27267	validation_1-rmse:0.38775
# [75]	validation_0-rmse:0.27098	validation_1-rmse:0.38612
# [76]	validation_0-rmse:0.26936	validation_1-rmse:0.38482
# [77]	validation_0-rmse:0.26762	validation_1-rmse:0.38323
# [78]	validation_0-rmse:0.26583	validation_1-rmse:0.38165
# [79]	validation_0-rmse:0.26432	validation_1-rmse:0.38017
# [80]	validation_0-rmse:0.26285	validation_1-rmse:0.37860
# [81]	validation_0-rmse:0.26127	validation_1-rmse:0.37745
# [82]	validation_0-rmse:0.25989	validation_1-rmse:0.37601
# [83]	validation_0-rmse:0.25845	validation_1-rmse:0.37517
# [84]	validation_0-rmse:0.25709	validation_1-rmse:0.37440
# [85]	validation_0-rmse:0.25580	validation_1-rmse:0.37279
# [86]	validation_0-rmse:0.25444	validation_1-rmse:0.37120
# [87]	validation_0-rmse:0.25304	validation_1-rmse:0.37033
# [88]	validation_0-rmse:0.25184	validation_1-rmse:0.36928
# [89]	validation_0-rmse:0.25080	validation_1-rmse:0.36807
# [90]	validation_0-rmse:0.24967	validation_1-rmse:0.36711
# [91]	validation_0-rmse:0.24853	validation_1-rmse:0.36682
# [92]	validation_0-rmse:0.24745	validation_1-rmse:0.36570
# [93]	validation_0-rmse:0.24627	validation_1-rmse:0.36478
# [94]	validation_0-rmse:0.24510	validation_1-rmse:0.36466
# [95]	validation_0-rmse:0.24410	validation_1-rmse:0.36375
# [96]	validation_0-rmse:0.24308	validation_1-rmse:0.36311
# [97]	validation_0-rmse:0.24197	validation_1-rmse:0.36291
# [98]	validation_0-rmse:0.24093	validation_1-rmse:0.36274
# [99]	validation_0-rmse:0.23990	validation_1-rmse:0.36228
# [100]	validation_0-rmse:0.23902	validation_1-rmse:0.36171
# [101]	validation_0-rmse:0.23816	validation_1-rmse:0.36090
# [102]	validation_0-rmse:0.23720	validation_1-rmse:0.36070
# [103]	validation_0-rmse:0.23628	validation_1-rmse:0.36052
# [104]	validation_0-rmse:0.23538	validation_1-rmse:0.36050
# [105]	validation_0-rmse:0.23446	validation_1-rmse:0.35992
# [106]	validation_0-rmse:0.23378	validation_1-rmse:0.35923
# [107]	validation_0-rmse:0.23309	validation_1-rmse:0.35858
# [108]	validation_0-rmse:0.23224	validation_1-rmse:0.35776
# [109]	validation_0-rmse:0.23160	validation_1-rmse:0.35717
# [110]	validation_0-rmse:0.23098	validation_1-rmse:0.35657
# [111]	validation_0-rmse:0.23038	validation_1-rmse:0.35603
# [112]	validation_0-rmse:0.22962	validation_1-rmse:0.35602
# [113]	validation_0-rmse:0.22904	validation_1-rmse:0.35541
# [114]	validation_0-rmse:0.22833	validation_1-rmse:0.35477
# [115]	validation_0-rmse:0.22769	validation_1-rmse:0.35447
# [116]	validation_0-rmse:0.22713	validation_1-rmse:0.35379
# [117]	validation_0-rmse:0.22663	validation_1-rmse:0.35360
# [118]	validation_0-rmse:0.22587	validation_1-rmse:0.35379
# [119]	validation_0-rmse:0.22521	validation_1-rmse:0.35390
# [120]	validation_0-rmse:0.22453	validation_1-rmse:0.35416
# [121]	validation_0-rmse:0.22399	validation_1-rmse:0.35356
# [122]	validation_0-rmse:0.22335	validation_1-rmse:0.35384
# [123]	validation_0-rmse:0.22274	validation_1-rmse:0.35412
# [124]	validation_0-rmse:0.22227	validation_1-rmse:0.35367
# [125]	validation_0-rmse:0.22181	validation_1-rmse:0.35325
# [126]	validation_0-rmse:0.22113	validation_1-rmse:0.35317
# [127]	validation_0-rmse:0.22041	validation_1-rmse:0.35281
# [128]	validation_0-rmse:0.21997	validation_1-rmse:0.35262
# [129]	validation_0-rmse:0.21954	validation_1-rmse:0.35224
# [130]	validation_0-rmse:0.21888	validation_1-rmse:0.35233
# [131]	validation_0-rmse:0.21846	validation_1-rmse:0.35217
# [132]	validation_0-rmse:0.21802	validation_1-rmse:0.35220
# [133]	validation_0-rmse:0.21748	validation_1-rmse:0.35239
# [134]	validation_0-rmse:0.21668	validation_1-rmse:0.35207
# [135]	validation_0-rmse:0.21626	validation_1-rmse:0.35211
# [136]	validation_0-rmse:0.21582	validation_1-rmse:0.35207
# [137]	validation_0-rmse:0.21543	validation_1-rmse:0.35213
# [138]	validation_0-rmse:0.21507	validation_1-rmse:0.35194
# [139]	validation_0-rmse:0.21471	validation_1-rmse:0.35163
# [140]	validation_0-rmse:0.21433	validation_1-rmse:0.35147
# [141]	validation_0-rmse:0.21380	validation_1-rmse:0.35118
# [142]	validation_0-rmse:0.21347	validation_1-rmse:0.35102
# [143]	validation_0-rmse:0.21301	validation_1-rmse:0.35093
# [144]	validation_0-rmse:0.21266	validation_1-rmse:0.35080
# [145]	validation_0-rmse:0.21236	validation_1-rmse:0.35067
# [146]	validation_0-rmse:0.21203	validation_1-rmse:0.35075
# [147]	validation_0-rmse:0.21169	validation_1-rmse:0.35066
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 123.345, median: 135.0,
#  pred. interval (P(0.025)-P(0.975)): 58.975-147.0,
#  conf. interval (p-value=0.95): 116.6-140.237
# ***
# Aggregate bias statistic:
#  mean: 0.529, median: 0.555,
#  pred. interval (P(0.025)-P(0.975)): -2.022-3.472,
#  conf. interval (p-value=0.95): -0.117-1.088
# ***
# Aggregate RMSE statistic:
#  mean: 0.314, median: 0.31, pred. interval (P(0.025)-P(0.975)): 0.219-0.42,
#  conf. interval (p-value=0.95): 0.288-0.334
# ***
# Aggregate MSE statistic:
#  mean: 0.101, median: 0.096, pred. interval (P(0.025)-P(0.975)): 0.048-0.176,
#  conf. interval (p-value=0.95): 0.083-0.112
# ***
# Aggregate R^2 statistic:
#  mean: 0.733, median: 0.749, pred. interval (P(0.025)-P(0.975)): 0.446-0.874,
#  conf. interval (p-value=0.95): 0.7-0.782
# ***
# Aggregate bias(%) statistic:
#  mean: -42.223, median: 0.555, pred. interval (P(0.025)-P(0.975)): -136.674-142.78,
#  conf. interval (p-value=0.95): -11.703-2.086
# ***
# Aggregate RMSE(%) statistic:
#  mean: 1.416, median: 1.708, pred. interval (P(0.025)-P(0.975)): -28.441-34.642,
#  conf. interval (p-value=0.95): -0.271-3.92
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:0.77764
# [1]	validation_0-rmse:0.76196
# [2]	validation_0-rmse:0.74668
# [3]	validation_0-rmse:0.73185
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:0.71744
# [5]	validation_0-rmse:0.70329
# [6]	validation_0-rmse:0.68954
# [7]	validation_0-rmse:0.67617
# [8]	validation_0-rmse:0.66319
# [9]	validation_0-rmse:0.65064
# [10]	validation_0-rmse:0.63836
# [11]	validation_0-rmse:0.62645
# [12]	validation_0-rmse:0.61463
# [13]	validation_0-rmse:0.60339
# [14]	validation_0-rmse:0.59229
# [15]	validation_0-rmse:0.58171
# [16]	validation_0-rmse:0.57136
# [17]	validation_0-rmse:0.56131
# [18]	validation_0-rmse:0.55132
# [19]	validation_0-rmse:0.54183
# [20]	validation_0-rmse:0.53264
# [21]	validation_0-rmse:0.52353
# [22]	validation_0-rmse:0.51489
# [23]	validation_0-rmse:0.50649
# [24]	validation_0-rmse:0.49831
# [25]	validation_0-rmse:0.49037
# [26]	validation_0-rmse:0.48267
# [27]	validation_0-rmse:0.47520
# [28]	validation_0-rmse:0.46799
# [29]	validation_0-rmse:0.46102
# [30]	validation_0-rmse:0.45427
# [31]	validation_0-rmse:0.44766
# [32]	validation_0-rmse:0.44126
# [33]	validation_0-rmse:0.43504
# [34]	validation_0-rmse:0.42902
# [35]	validation_0-rmse:0.42325
# [36]	validation_0-rmse:0.41760
# [37]	validation_0-rmse:0.41197
# [38]	validation_0-rmse:0.40651
# [39]	validation_0-rmse:0.40128
# [40]	validation_0-rmse:0.39629
# [41]	validation_0-rmse:0.39132
# [42]	validation_0-rmse:0.38638
# [43]	validation_0-rmse:0.38148
# [44]	validation_0-rmse:0.37693
# [45]	validation_0-rmse:0.37271
# [46]	validation_0-rmse:0.36831
# [47]	validation_0-rmse:0.36419
# [48]	validation_0-rmse:0.36007
# [49]	validation_0-rmse:0.35620
# [50]	validation_0-rmse:0.35246
# [51]	validation_0-rmse:0.34863
# [52]	validation_0-rmse:0.34504
# [53]	validation_0-rmse:0.34162
# [54]	validation_0-rmse:0.33818
# [55]	validation_0-rmse:0.33491
# [56]	validation_0-rmse:0.33168
# [57]	validation_0-rmse:0.32879
# [58]	validation_0-rmse:0.32572
# [59]	validation_0-rmse:0.32274
# [60]	validation_0-rmse:0.31990
# [61]	validation_0-rmse:0.31708
# [62]	validation_0-rmse:0.31448
# [63]	validation_0-rmse:0.31190
# [64]	validation_0-rmse:0.30945
# [65]	validation_0-rmse:0.30703
# [66]	validation_0-rmse:0.30471
# [67]	validation_0-rmse:0.30253
# [68]	validation_0-rmse:0.30027
# [69]	validation_0-rmse:0.29810
# [70]	validation_0-rmse:0.29611
# [71]	validation_0-rmse:0.29407
# [72]	validation_0-rmse:0.29204
# [73]	validation_0-rmse:0.29013
# [74]	validation_0-rmse:0.28827
# [75]	validation_0-rmse:0.28638
# [76]	validation_0-rmse:0.28468
# [77]	validation_0-rmse:0.28303
# [78]	validation_0-rmse:0.28138
# [79]	validation_0-rmse:0.27975
# [80]	validation_0-rmse:0.27818
# [81]	validation_0-rmse:0.27672
# [82]	validation_0-rmse:0.27513
# [83]	validation_0-rmse:0.27369
# [84]	validation_0-rmse:0.27229
# [85]	validation_0-rmse:0.27098
# [86]	validation_0-rmse:0.26970
# [87]	validation_0-rmse:0.26846
# [88]	validation_0-rmse:0.26737
# [89]	validation_0-rmse:0.26607
# [90]	validation_0-rmse:0.26493
# [91]	validation_0-rmse:0.26393
# [92]	validation_0-rmse:0.26281
# [93]	validation_0-rmse:0.26188
# [94]	validation_0-rmse:0.26083
# [95]	validation_0-rmse:0.25975
# [96]	validation_0-rmse:0.25868
# [97]	validation_0-rmse:0.25777
# [98]	validation_0-rmse:0.25697
# [99]	validation_0-rmse:0.25592
# [100]	validation_0-rmse:0.25513
# [101]	validation_0-rmse:0.25423
# [102]	validation_0-rmse:0.25334
# [103]	validation_0-rmse:0.25263
# [104]	validation_0-rmse:0.25176
# [105]	validation_0-rmse:0.25106
# [106]	validation_0-rmse:0.25012
# [107]	validation_0-rmse:0.24948
# [108]	validation_0-rmse:0.24871
# [109]	validation_0-rmse:0.24800
# [110]	validation_0-rmse:0.24741
# [111]	validation_0-rmse:0.24684
# [112]	validation_0-rmse:0.24617
# [113]	validation_0-rmse:0.24564
# [114]	validation_0-rmse:0.24501
# [115]	validation_0-rmse:0.24451
# [116]	validation_0-rmse:0.24380
# [117]	validation_0-rmse:0.24314
# [118]	validation_0-rmse:0.24254
# [119]	validation_0-rmse:0.24208
# [120]	validation_0-rmse:0.24151
# [121]	validation_0-rmse:0.24107
# [122]	validation_0-rmse:0.24064
# [123]	validation_0-rmse:0.24002
# [124]	validation_0-rmse:0.23958
# [125]	validation_0-rmse:0.23906
# [126]	validation_0-rmse:0.23867
# [127]	validation_0-rmse:0.23815
# [128]	validation_0-rmse:0.23765
# [129]	validation_0-rmse:0.23715
# [130]	validation_0-rmse:0.23678
# [131]	validation_0-rmse:0.23623
# [132]	validation_0-rmse:0.23588
# [133]	validation_0-rmse:0.23552
# [134]	validation_0-rmse:0.23519
# [135]	validation_0-rmse:0.23474
# [136]	validation_0-rmse:0.23423
# [137]	validation_0-rmse:0.23381
# [138]	validation_0-rmse:0.23332
# [139]	validation_0-rmse:0.23302
# [140]	validation_0-rmse:0.23255
# [141]	validation_0-rmse:0.23199
# [142]	validation_0-rmse:0.23167
# [143]	validation_0-rmse:0.23131
# [144]	validation_0-rmse:0.23097
# [145]	validation_0-rmse:0.23043
# [146]	validation_0-rmse:0.23014
# [147]	validation_0-rmse:0.22985
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 147

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  19.05
# RMSE: 0.2
# Relative RMSE(%):  4.228
# MSE: 0.1
# R square: 87.8%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-2, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.020
# a1: 0.809
# R^2: 0.884
# Uncertainty
# a0: 0.020+/-0.019
# a1: 0.809+/-0.029

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Mbranch_XGB_model_with_texture.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Mbranch_XGB_model_with_texture.txt")
