# %% [markdown]
# # *+Processing with Sentinel bands & RN & biomass data of other authors+*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
input_data = '/home/dima/Desktop/WORK/GIS and ML algoritms/6_Est_RN&biomass_all_site_Sentinel/Pre_GIS_data/Site_with_Sentinel_bands_data_2020.csv'
df = pd.read_csv(input_data)
df.head()
# Out:
#   Site # Origin Dominant_s  N_trees at  A_year  D_live_cm  H_live_m  \
# 0      1      n      Birch          57      35       13.5      17.3
# 1      2      a       Pine          25      58       15.0      16.9
# 2      3      a       Pine          32      58       13.7      16.8
# 3      4      a       Pine          63      58       20.3      18.4
# 4      5      a       Pine          53      58       17.5      19.9
#
#    G_live_m2_  f_Gs_cub_m  f_M_stem_kg_m2  ...  r2019B03  r2019B04  r2019B05  \
# 0        15.1         123            5.83  ...  0.030628  0.266210  0.166299
# 1        39.0         317           11.67  ...  0.027934  0.183349  0.102656
# 2        42.8         346           12.37  ...  0.026123  0.184066  0.099625
# 3        38.8         315           13.88  ...  0.027390  0.177221  0.102540
# 4        48.3         383           14.51  ...  0.025702  0.183705  0.101394
#
#    r2019B06  r2019B07  r2019B08  r2019B09   r2019B10   r2019B11  r2019B12
# 0  0.081316  0.793351 -0.733693  0.532051 -15.396488 -11.262037  0.731937
# 1  0.052144  0.735493 -0.655456  0.557000 -16.012156  -9.364664  0.584920
# 2  0.050684  0.751436 -0.650575  0.568148 -13.609903  -9.726108  0.715177
# 3  0.052198  0.732404 -0.648310  0.544717 -14.321650 -10.457536  0.730390
# 4  0.050437  0.754481 -0.660382  0.569112 -13.934375 -11.393335  0.817430
#
# [5 rows x 63 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
#
# 'Site #', 'Origin', 'Dominant_s', 'N_trees at', 'A_year', 'D_live_cm', 'H_live_m', 'G_live_m2_', 'f_Gs_cub_m', 'f_M_stem_kg_m2', 'f_M_stem_bark_kg_m2', 'f_M_crown_kg_m2', 'f_M_foliage_kg_m2', 'f_M_AG_kg_m2', 'Ln_Gs_cub_m', 'Ln_M_stem_kg_m2', 'Ln_M_stem_bark_kg_m2', 'Ln_M_crown_kg_m2', 'Ln_M_foliage_kg_m2', 'Ln_M_AG_kg_m2', 'F_Soil', 'M_Soil', 'X_N36', 'Y_N36', 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'Ln_Cs_wood', 'Ln_Sr_wood', 'Tag_Cs', 'Tag_Sr', 'Ln_Tag_Cs', 'Ln_Tag_Sr', 'Cs_2021_kB', 'Sr_2021_kB', 'AEDR_count', 'AEDR_mean', 'Distance_k', 'Azimuth', 'r2020B01', 'r2020B02', 'r2020B03', 'r2020B04', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11', 'r2020B12', 'r2020B13', 'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Ln_Gs_cub_m', 'Ln_M_stem_kg_m2', 'Ln_M_stem_bark_kg_m2', 'Ln_M_crown_kg_m2', 'Ln_M_foliage_kg_m2', 'Ln_M_AG_kg_m2', 'Ln_Cs_wood', 'Ln_Sr_wood', 'Ln_Tag_Cs', 'Ln_Tag_Sr', 'r2020B01', 'r2020B02', 'r2020B03', 'r2020B04', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11', 'r2020B12'])
            


# Show the first five columns
select.head()
# Out:
#    Ln_Gs_cub_m  Ln_M_stem_kg_m2  Ln_M_stem_bark_kg_m2  Ln_M_crown_kg_m2  \
# 0         4.81             1.76                 -0.31             -0.16
# 1         5.76             2.46                 -0.25              0.34
# 2         5.85             2.52                 -0.11              0.55
# 3         5.75             2.63                 -0.08              0.39
# 4         5.95             2.67                  0.00              0.57
#
#    Ln_M_foliage_kg_m2  Ln_M_AG_kg_m2  Ln_Cs_wood  Ln_Sr_wood  Ln_Tag_Cs  \
# 0               -2.44           1.91         6.8         9.2       -0.7
# 1               -0.20           2.63         8.2         9.6        0.6
# 2               -0.21           2.70         8.4         9.6        0.8
# 3               -0.35           2.78         8.1         9.4        0.5
# 4               -0.37           2.83         7.7         9.4        0.2
#
#    Ln_Tag_Sr  ...  r2020B03  r2020B04  r2020B05  r2020B06  r2020B07  r2020B08  \
# 0        2.6  ...  0.028616  0.254417  0.175280  0.086611  0.797761 -0.749311
# 1        2.9  ...  0.022230  0.189826  0.092225  0.047120  0.789129 -0.705355
# 2        2.9  ...  0.021190  0.204363  0.093062  0.043824  0.812120 -0.704758
# 3        2.7  ...  0.025284  0.187998  0.102872  0.048585  0.762431 -0.695416
# 4        2.8  ...  0.024911  0.216271  0.096981  0.044880  0.793606 -0.717562
#
#    r2020B09   r2020B10   r2020B11  r2020B12
# 0  0.491270 -15.527246 -11.385074  0.733806
# 1  0.659775 -16.547673 -10.947565  0.661723
# 2  0.631348 -14.341917 -11.884799  0.829603
# 3  0.601894 -14.885610 -11.725163  0.787609
# 4  0.642942 -14.647913 -11.512282  0.785698
#
# [5 rows x 22 columns]

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ln_Gs_cub_m           198 non-null    float64
#  1   Ln_M_stem_kg_m2       198 non-null    float64
#  2   Ln_M_stem_bark_kg_m2  198 non-null    float64
#  3   Ln_M_crown_kg_m2      198 non-null    float64
#  4   Ln_M_foliage_kg_m2    198 non-null    float64
#  5   Ln_M_AG_kg_m2         198 non-null    float64
#  6   Ln_Cs_wood            198 non-null    float64
#  7   Ln_Sr_wood            198 non-null    float64
#  8   Ln_Tag_Cs             198 non-null    float64
#  9   Ln_Tag_Sr             198 non-null    float64
#  10  r2020B01              198 non-null    float64
#  11  r2020B02              198 non-null    float64
#  12  r2020B03              198 non-null    float64
#  13  r2020B04              198 non-null    float64
#  14  r2020B05              198 non-null    float64
#  15  r2020B06              198 non-null    float64
#  16  r2020B07              198 non-null    float64
#  17  r2020B08              198 non-null    float64
#  18  r2020B09              198 non-null    float64
#  19  r2020B10              198 non-null    float64
#  20  r2020B11              198 non-null    float64
#  21  r2020B12              198 non-null    float64
# dtypes: float64(22)
# memory usage: 34.2 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_s"])["f_Gs_cub_m", "f_M_stem_kg_m2"].describe()
# Out:
# /tmp/ipykernel_13389/4147815954.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_s"])["f_Gs_cub_m", "f_M_stem_kg_m2"].describe()
#            f_Gs_cub_m                                                      \
#                 count        mean         std    min    25%    50%    75%
# Dominant_s
# Alder            13.0  393.153846  113.795757  199.0  311.0  434.0  462.0
# Aspen             7.0  241.571429  134.878782  121.0  147.0  194.0  321.0
# Birch            45.0  164.622222   83.668254   11.0  107.0  157.0  222.0
# Oak               9.0  199.777778   88.192655   79.0  112.0  220.0  255.0
# Pine            123.0  304.699187  185.582068    2.0  150.5  319.0  457.5
# Spruce            1.0  619.000000         NaN  619.0  619.0  619.0  619.0
#
#                   f_M_stem_kg_m2                                             \
#               max          count       mean       std    min     25%    50%
# Dominant_s
# Alder       558.0           13.0  16.823846  4.334304   9.90  13.560  16.96
# Aspen       440.0            7.0  11.862857  7.997334   4.64   6.470   9.79
# Birch       346.0           45.0   8.030444  4.090891   0.84   4.960   7.75
# Oak         313.0            9.0  10.728889  4.976167   3.59   5.870  11.72
# Pine        671.0          123.0  11.991789  7.094609   0.05   6.285  12.37
# Spruce      619.0            1.0  23.830000       NaN  23.83  23.830  23.83
#
#
#                75%    max
# Dominant_s
# Alder       20.130  24.29
# Aspen       14.810  26.05
# Birch       10.990  17.00
# Oak         13.590  18.99
# Pine        17.645  25.37
# Spruce      23.830  23.83

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Ln_Gs_cub_m  Ln_M_stem_kg_m2  Ln_M_stem_bark_kg_m2  Ln_M_crown_kg_m2  \
# count   198.000000       198.000000            198.000000        198.000000
# mean      5.234646         2.081717             -0.039242          0.171313
# std       1.129652         1.126519              0.789675          0.588506
# min       0.690000        -3.000000             -3.910000         -1.560000
# 25%       4.960000         1.812500             -0.190000         -0.025000
# 50%       5.510000         2.420000              0.060000          0.310000
# 75%       5.987500         2.807500              0.387500          0.530000
# max       6.510000         3.260000              1.650000          1.410000
#
#        Ln_M_foliage_kg_m2  Ln_M_AG_kg_m2  Ln_Cs_wood  Ln_Sr_wood   Ln_Tag_Cs  \
# count          198.000000     198.000000  198.000000  198.000000  198.000000
# mean            -0.953081       2.305758    6.052020    7.395960   -0.566667
# std              0.719719       0.931192    2.089707    2.070848    1.250989
# min             -2.920000      -0.800000    1.600000    2.400000   -4.700000
# 25%             -1.525000       2.052500    4.300000    5.800000   -1.300000
# 50%             -0.690000       2.580000    6.400000    7.600000   -0.500000
# 75%             -0.360000       2.937500    7.400000    8.800000    0.400000
# max              0.110000       3.390000   11.400000   13.900000    1.700000
#
#         Ln_Tag_Sr  ...    r2020B03    r2020B04    r2020B05    r2020B06  \
# count  198.000000  ...  198.000000  198.000000  198.000000  198.000000
# mean     2.342424  ...    0.027499    0.213645    0.125537    0.063662
# std      0.939283  ...    0.009532    0.042641    0.035475    0.023731
# min     -0.300000  ...    0.014640    0.124161    0.079896    0.036570
# 25%      1.700000  ...    0.022284    0.187070    0.095832    0.046290
# 50%      2.500000  ...    0.024743    0.204261    0.115558    0.058209
# 75%      3.000000  ...    0.028527    0.236440    0.150857    0.072122
# max      4.700000  ...    0.080615    0.369338    0.243667    0.187427
#
#          r2020B07    r2020B08    r2020B09    r2020B10    r2020B11    r2020B12
# count  198.000000  198.000000  198.000000  198.000000  198.000000  198.000000
# mean     0.767194   -0.703079    0.540963  -16.145709  -10.863669    0.675418
# std      0.078273    0.060738    0.132304    1.343250    1.161017    0.069250
# min      0.381333   -0.823403    0.038198  -22.517731  -14.262763    0.492975
# 25%      0.745438   -0.735205    0.502225  -16.970102  -11.519514    0.628884
# 50%      0.784239   -0.704881    0.577675  -16.010171  -10.784612    0.667561
# 75%      0.808780   -0.680539    0.632284  -15.159997  -10.008004    0.720595
# max      0.885319   -0.410944    0.710583  -13.281957   -7.650135    0.860863
#
# [8 rows x 22 columns]

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['r2020B01', 'r2020B02', 'r2020B03', 'r2020B04', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11', 'r2020B12'])
y = pd.DataFrame(select, columns= ['Ln_Gs_cub_m'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): Yes
# Selected "Yes"!!! A new column with random values was created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    r2020B01  r2020B02  r2020B03  r2020B04  r2020B05  r2020B06  r2020B07  \
# 0  0.019397  0.035344  0.028616  0.254417  0.175280  0.086611  0.797761
# 1  0.019167  0.033537  0.022230  0.189826  0.092225  0.047120  0.789129
# 2  0.019568  0.035957  0.021190  0.204363  0.093062  0.043824  0.812120
# 3  0.020556  0.033868  0.025284  0.187998  0.102872  0.048585  0.762431
# 4  0.019003  0.036153  0.024911  0.216271  0.096981  0.044880  0.793606
#
#    r2020B08  r2020B09   r2020B10   r2020B11  r2020B12    Random1    Random2  \
# 0 -0.749311  0.491270 -15.527246 -11.385074  0.733806  11.300272  12.860114
# 1 -0.705355  0.659775 -16.547673 -10.947565  0.661723   8.931385  10.243870
# 2 -0.704758  0.631348 -14.341917 -11.884799  0.829603   7.807805  10.025252
# 3 -0.695416  0.601894 -14.885610 -11.725163  0.787609  12.417101   9.619136
# 4 -0.717562  0.642942 -14.647913 -11.512282  0.785698  10.442962  12.274498
#
#      Random3    Random4    Random5
# 0   8.252012  11.074835   9.289168
# 1  14.016751   8.410922   8.727581
# 2  10.656628  13.441815   8.512182
# 3  10.123670   8.908937   8.717069
# 4   8.107338  11.916705  10.112965

# %%
# Columns in "y" data collections
y.head()
# Out:
#    Ln_Gs_cub_m
# 0         4.81
# 1         5.76
# 2         5.85
# 3         5.75
# 4         5.95

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.4381130688915549, 0.37473943512068564, 0.19193887614087324]
#     Mean: 0.335
#     Std: 0.104
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.0451353  1.04660636 0.77016729]
#     Mean: 0.954
#     Std: 0.130
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.657338080478437, 0.5621287820555948, 0.6128254642631069]
#     Mean: 0.611
#     Std: 0.039
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=30, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Model with rank: 1
# Mean validation score: 0.259 (std: 0.268)
# Parameters: {'colsample_bytree': 0.29391839003737935, 'gamma': 0.20669710682521147, 'learning_rate': 0.06673744398245225, 'max_depth': 2, 'n_estimators': 88, 'subsample': 0.8193440961990077}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.17613664, 0.33106756, 0.13411727, 0.13987713, 0.17829151,
#        0.36699891, 0.14157634, 0.2776834 , 0.15147114, 0.14084654,
#        0.22675643, 0.30220685, 0.21145163, 0.15429945, 0.19862571,
#        0.2264729 , 0.23321829, 0.13580108, 0.32060304, 0.38127398,
#        0.14900765, 0.3238256 , 0.23593135, 0.12317014, 0.1347548 ,
#        0.25355344, 0.2385963 , 0.30311313, 0.30441661, 0.24235606]), 'std_fit_time': array([0.05910452, 0.01268192, 0.00848528, 0.00646768, 0.06969727,
#        0.06453788, 0.00927532, 0.0069226 , 0.00149796, 0.00537925,
#        0.01113801, 0.00774679, 0.01103298, 0.00713835, 0.08033316,
#        0.0829265 , 0.05250703, 0.01000631, 0.01324821, 0.03006485,
#        0.01401734, 0.01101754, 0.01368933, 0.00796589, 0.01158607,
#        0.01720264, 0.03713527, 0.01885691, 0.10723716, 0.00423911]), 'mean_score_time': array([0.00471592, 0.00471616, 0.00452261, 0.00455551, 0.00570774,
#        0.00489826, 0.00457482, 0.00460734, 0.00445871, 0.00450635,
#        0.00458374, 0.00466185, 0.0048533 , 0.00492468, 0.00583611,
#        0.00589523, 0.00520744, 0.00468159, 0.00496402, 0.00505085,
#        0.00457449, 0.00470643, 0.00467906, 0.00462184, 0.00466614,
#        0.0046011 , 0.00480695, 0.00501852, 0.00491104, 0.00463448]), 'std_score_time': array([1.17669267e-04, 5.73423201e-05, 1.24808007e-04, 1.62299034e-04,
#        2.25153764e-03, 2.50502551e-04, 2.17387357e-04, 1.36809442e-04,
p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.29391839003737935
# Gamma: 0.20669710682521147
# Learning_rate: 0.06673744398245225
# Max_depth: 2
# N_estimators: 88
# Subsample: 0.8193440961990077

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:4.56408	validation_1-rmse:4.53270
# [1]	validation_0-rmse:4.27385	validation_1-rmse:4.24424
# [2]	validation_0-rmse:4.00203	validation_1-rmse:3.98367
# [3]	validation_0-rmse:3.75030	validation_1-rmse:3.73829
# [4]	validation_0-rmse:3.51549	validation_1-rmse:3.50968
# [5]	validation_0-rmse:3.29777	validation_1-rmse:3.29733
# [6]	validation_0-rmse:3.09357	validation_1-rmse:3.09498
# [7]	validation_0-rmse:2.90372	validation_1-rmse:2.90915
# [8]	validation_0-rmse:2.72695	validation_1-rmse:2.73726
# [9]	validation_0-rmse:2.56162	validation_1-rmse:2.57506
# [10]	validation_0-rmse:2.41188	validation_1-rmse:2.43090
# [11]	validation_0-rmse:2.26746	validation_1-rmse:2.29638
# [12]	validation_0-rmse:2.13602	validation_1-rmse:2.16615
# [13]	validation_0-rmse:2.00999	validation_1-rmse:2.04463
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
#
# [52]	validation_0-rmse:0.52971	validation_1-rmse:1.15761
# [53]	validation_0-rmse:0.52573	validation_1-rmse:1.15933
# [54]	validation_0-rmse:0.52053	validation_1-rmse:1.15375
# [55]	validation_0-rmse:0.51514	validation_1-rmse:1.15214
# [56]	validation_0-rmse:0.51233	validation_1-rmse:1.15252
# [57]	validation_0-rmse:0.50808	validation_1-rmse:1.15349
# [58]	validation_0-rmse:0.50364	validation_1-rmse:1.15445
# [59]	validation_0-rmse:0.50044	validation_1-rmse:1.15226
# [60]	validation_0-rmse:0.49674	validation_1-rmse:1.15087
# [61]	validation_0-rmse:0.49491	validation_1-rmse:1.14959
# [62]	validation_0-rmse:0.49165	validation_1-rmse:1.14674
# [63]	validation_0-rmse:0.48883	validation_1-rmse:1.14721
# [64]	validation_0-rmse:0.48673	validation_1-rmse:1.14734
# [65]	validation_0-rmse:0.48500	validation_1-rmse:1.14787
# [66]	validation_0-rmse:0.48151	validation_1-rmse:1.14637
# [67]	validation_0-rmse:0.47922	validation_1-rmse:1.14199
# [68]	validation_0-rmse:0.47702	validation_1-rmse:1.14106
# [69]	validation_0-rmse:0.47402	validation_1-rmse:1.14050
# [70]	validation_0-rmse:0.47118	validation_1-rmse:1.14195
# [71]	validation_0-rmse:0.46964	validation_1-rmse:1.14145
# [72]	validation_0-rmse:0.46687	validation_1-rmse:1.13979
# [73]	validation_0-rmse:0.46545	validation_1-rmse:1.13980
# [74]	validation_0-rmse:0.46490	validation_1-rmse:1.14059
# [75]	validation_0-rmse:0.46269	validation_1-rmse:1.14021
# [76]	validation_0-rmse:0.45901	validation_1-rmse:1.14053
# [77]	validation_0-rmse:0.45562	validation_1-rmse:1.14095
# [78]	validation_0-rmse:0.45405	validation_1-rmse:1.13922
# [79]	validation_0-rmse:0.45375	validation_1-rmse:1.13967
# [80]	validation_0-rmse:0.45239	validation_1-rmse:1.13895
# [81]	validation_0-rmse:0.45100	validation_1-rmse:1.13786
# [82]	validation_0-rmse:0.44986	validation_1-rmse:1.13807
# [83]	validation_0-rmse:0.44744	validation_1-rmse:1.13844
# [84]	validation_0-rmse:0.44667	validation_1-rmse:1.13953
# [85]	validation_0-rmse:0.44457	validation_1-rmse:1.13827
# [86]	validation_0-rmse:0.44370	validation_1-rmse:1.13718
# [87]	validation_0-rmse:0.44011	validation_1-rmse:1.13786
# [0]	validation_0-rmse:4.52129	validation_1-rmse:4.68903
# [1]	validation_0-rmse:4.23335	validation_1-rmse:4.39731
# [2]	validation_0-rmse:3.96481	validation_1-rmse:4.12213
# [3]	validation_0-rmse:3.71660	validation_1-rmse:3.86694
# [4]	validation_0-rmse:3.48551	validation_1-rmse:3.63234
# [5]	validation_0-rmse:3.26722	validation_1-rmse:3.40558
# [6]	validation_0-rmse:3.06525	validation_1-rmse:3.20085
# [7]	validation_0-rmse:2.87731	validation_1-rmse:3.00641
# [8]	validation_0-rmse:2.70491	validation_1-rmse:2.83205
# [9]	validation_0-rmse:2.54051	validation_1-rmse:2.66628
# [61]	validation_0-rmse:0.53013	validation_1-rmse:0.81334
# [62]	validation_0-rmse:0.52858	validation_1-rmse:0.81160
# [63]	validation_0-rmse:0.52579	validation_1-rmse:0.80965
# [64]	validation_0-rmse:0.52322	validation_1-rmse:0.80954
# [65]	validation_0-rmse:0.52123	validation_1-rmse:0.80955
# [66]	validation_0-rmse:0.51881	validation_1-rmse:0.80969
# [67]	validation_0-rmse:0.51666	validation_1-rmse:0.80962
# [68]	validation_0-rmse:0.51485	validation_1-rmse:0.80935
# [69]	validation_0-rmse:0.51189	validation_1-rmse:0.80928
# [70]	validation_0-rmse:0.50981	validation_1-rmse:0.80903
# [71]	validation_0-rmse:0.50781	validation_1-rmse:0.80726
# [72]	validation_0-rmse:0.50579	validation_1-rmse:0.80609
# [73]	validation_0-rmse:0.50409	validation_1-rmse:0.80671
# [74]	validation_0-rmse:0.50163	validation_1-rmse:0.80685
# [75]	validation_0-rmse:0.49881	validation_1-rmse:0.80824
# [76]	validation_0-rmse:0.49640	validation_1-rmse:0.80624
# [77]	validation_0-rmse:0.49379	validation_1-rmse:0.80428
# [78]	validation_0-rmse:0.49211	validation_1-rmse:0.80415
# [79]	validation_0-rmse:0.49021	validation_1-rmse:0.80409
# [80]	validation_0-rmse:0.48776	validation_1-rmse:0.80674
# [81]	validation_0-rmse:0.48531	validation_1-rmse:0.80846
# [82]	validation_0-rmse:0.48403	validation_1-rmse:0.80852
# [83]	validation_0-rmse:0.48231	validation_1-rmse:0.80813
# [84]	validation_0-rmse:0.48104	validation_1-rmse:0.80823
# [85]	validation_0-rmse:0.47984	validation_1-rmse:0.80903
# [86]	validation_0-rmse:0.47807	validation_1-rmse:0.80805
# ...
#   warnings.warn(
# [5]	validation_0-rmse:3.27130	validation_1-rmse:3.38479
# [6]	validation_0-rmse:3.07395	validation_1-rmse:3.17866
# [7]	validation_0-rmse:2.88771	validation_1-rmse:2.98136
# [8]	validation_0-rmse:2.71459	validation_1-rmse:2.80026
# [9]	validation_0-rmse:2.55145	validation_1-rmse:2.63682
# [10]	validation_0-rmse:2.40266	validation_1-rmse:2.47475
# [11]	validation_0-rmse:2.25918	validation_1-rmse:2.33027
# [12]	validation_0-rmse:2.12593	validation_1-rmse:2.19383
# [13]	validation_0-rmse:2.00310	validation_1-rmse:2.06266
# [14]	validation_0-rmse:1.88941	validation_1-rmse:1.93871
# [15]	validation_0-rmse:1.78441	validation_1-rmse:1.82838
# [16]	validation_0-rmse:1.68890	validation_1-rmse:1.72287
# [17]	validation_0-rmse:1.59792	validation_1-rmse:1.62704
# [18]	validation_0-rmse:1.51195	validation_1-rmse:1.53274
# [19]	validation_0-rmse:1.43685	validation_1-rmse:1.45144
# [20]	validation_0-rmse:1.36655	validation_1-rmse:1.37289
# [21]	validation_0-rmse:1.30115	validation_1-rmse:1.30035
# [22]	validation_0-rmse:1.24189	validation_1-rmse:1.23417
# [23]	validation_0-rmse:1.18564	validation_1-rmse:1.17518
# [24]	validation_0-rmse:1.13331	validation_1-rmse:1.11496
# [76]	validation_0-rmse:0.53853	validation_1-rmse:0.67841
# [77]	validation_0-rmse:0.53496	validation_1-rmse:0.68010
# [78]	validation_0-rmse:0.53151	validation_1-rmse:0.67934
# [79]	validation_0-rmse:0.52892	validation_1-rmse:0.67903
# [80]	validation_0-rmse:0.52588	validation_1-rmse:0.68028
# [81]	validation_0-rmse:0.52410	validation_1-rmse:0.68208
# [82]	validation_0-rmse:0.52235	validation_1-rmse:0.68199
# [83]	validation_0-rmse:0.51911	validation_1-rmse:0.68321
# [84]	validation_0-rmse:0.51711	validation_1-rmse:0.68347
# [85]	validation_0-rmse:0.51607	validation_1-rmse:0.68440
# [86]	validation_0-rmse:0.51471	validation_1-rmse:0.68331
# [87]	validation_0-rmse:0.51325	validation_1-rmse:0.68409
# [0]	validation_0-rmse:4.56785	validation_1-rmse:4.50239
# [1]	validation_0-rmse:4.26973	validation_1-rmse:4.20281
# [2]	validation_0-rmse:3.99857	validation_1-rmse:3.93645
# [3]	validation_0-rmse:3.74893	validation_1-rmse:3.70711
# [4]	validation_0-rmse:3.51138	validation_1-rmse:3.46879
# [5]	validation_0-rmse:3.28964	validation_1-rmse:3.25315
# [6]	validation_0-rmse:3.08472	validation_1-rmse:3.04443
# [7]	validation_0-rmse:2.89303	validation_1-rmse:2.86117
# [8]	validation_0-rmse:2.71632	validation_1-rmse:2.68163
# [9]	validation_0-rmse:2.55004	validation_1-rmse:2.52486
# [10]	validation_0-rmse:2.39933	validation_1-rmse:2.37634
# [11]	validation_0-rmse:2.25539	validation_1-rmse:2.24161
# [12]	validation_0-rmse:2.12078	validation_1-rmse:2.11168
# [13]	validation_0-rmse:1.99549	validation_1-rmse:1.98858
# [14]	validation_0-rmse:1.88430	validation_1-rmse:1.88825
# [15]	validation_0-rmse:1.77965	validation_1-rmse:1.79673
# [16]	validation_0-rmse:1.67989	validation_1-rmse:1.71110
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [17]	validation_0-rmse:1.58609	validation_1-rmse:1.61938
# [18]	validation_0-rmse:1.50130	validation_1-rmse:1.54369
# [19]	validation_0-rmse:1.42382	validation_1-rmse:1.47619
# [20]	validation_0-rmse:1.35030	validation_1-rmse:1.40705
# [21]	validation_0-rmse:1.28834	validation_1-rmse:1.35278
# [22]	validation_0-rmse:1.22420	validation_1-rmse:1.28963
# [23]	validation_0-rmse:1.16608	validation_1-rmse:1.24050
# [24]	validation_0-rmse:1.11153	validation_1-rmse:1.19415
# [25]	validation_0-rmse:1.06261	validation_1-rmse:1.15768
# [26]	validation_0-rmse:1.01772	validation_1-rmse:1.12839
# [27]	validation_0-rmse:0.97315	validation_1-rmse:1.08957
# [28]	validation_0-rmse:0.93534	validation_1-rmse:1.05754
# [29]	validation_0-rmse:0.89992	validation_1-rmse:1.02472
# [30]	validation_0-rmse:0.86773	validation_1-rmse:1.00418
# [31]	validation_0-rmse:0.83992	validation_1-rmse:0.98043
# [32]	validation_0-rmse:0.81251	validation_1-rmse:0.95734
# [33]	validation_0-rmse:0.79054	validation_1-rmse:0.94662
# [34]	validation_0-rmse:0.76877	validation_1-rmse:0.92770
# [35]	validation_0-rmse:0.75017	validation_1-rmse:0.91646
# [36]	validation_0-rmse:0.73396	validation_1-rmse:0.90400
# [37]	validation_0-rmse:0.71905	validation_1-rmse:0.89109
# [38]	validation_0-rmse:0.70341	validation_1-rmse:0.87980
# [39]	validation_0-rmse:0.69037	validation_1-rmse:0.87723
# [40]	validation_0-rmse:0.67680	validation_1-rmse:0.87078
# [41]	validation_0-rmse:0.66546	validation_1-rmse:0.86591
# [42]	validation_0-rmse:0.65712	validation_1-rmse:0.86163
# [43]	validation_0-rmse:0.64671	validation_1-rmse:0.85467
# [44]	validation_0-rmse:0.63673	validation_1-rmse:0.85133
# [45]	validation_0-rmse:0.62999	validation_1-rmse:0.84599
# [46]	validation_0-rmse:0.62575	validation_1-rmse:0.84538
# [47]	validation_0-rmse:0.61710	validation_1-rmse:0.84251
# [48]	validation_0-rmse:0.61172	validation_1-rmse:0.84068
# [49]	validation_0-rmse:0.60549	validation_1-rmse:0.83902
# [50]	validation_0-rmse:0.59898	validation_1-rmse:0.83852
# [51]	validation_0-rmse:0.59179	validation_1-rmse:0.83421
# [52]	validation_0-rmse:0.58788	validation_1-rmse:0.83137
# [53]	validation_0-rmse:0.58356	validation_1-rmse:0.82934
# [54]	validation_0-rmse:0.57910	validation_1-rmse:0.82756
# [55]	validation_0-rmse:0.57581	validation_1-rmse:0.82887
# [56]	validation_0-rmse:0.57266	validation_1-rmse:0.82762
# [57]	validation_0-rmse:0.56959	validation_1-rmse:0.82623
# [58]	validation_0-rmse:0.56487	validation_1-rmse:0.82460
# [59]	validation_0-rmse:0.56102	validation_1-rmse:0.82141
# [60]	validation_0-rmse:0.55735	validation_1-rmse:0.82050
# [61]	validation_0-rmse:0.55318	validation_1-rmse:0.81760
# [62]	validation_0-rmse:0.55078	validation_1-rmse:0.81586
# [63]	validation_0-rmse:0.54738	validation_1-rmse:0.81345
# [64]	validation_0-rmse:0.54448	validation_1-rmse:0.81112
# [65]	validation_0-rmse:0.54230	validation_1-rmse:0.81097
# [66]	validation_0-rmse:0.53898	validation_1-rmse:0.81227
# [67]	validation_0-rmse:0.53717	validation_1-rmse:0.81232
# [68]	validation_0-rmse:0.53540	validation_1-rmse:0.81176
# [69]	validation_0-rmse:0.53362	validation_1-rmse:0.81099
# [70]	validation_0-rmse:0.53078	validation_1-rmse:0.81451
# [71]	validation_0-rmse:0.52907	validation_1-rmse:0.81585
# [72]	validation_0-rmse:0.52752	validation_1-rmse:0.81533
# [73]	validation_0-rmse:0.52507	validation_1-rmse:0.81537
# [74]	validation_0-rmse:0.52277	validation_1-rmse:0.81257
# [75]	validation_0-rmse:0.52081	validation_1-rmse:0.81197
# [76]	validation_0-rmse:0.51871	validation_1-rmse:0.81227
# [77]	validation_0-rmse:0.51583	validation_1-rmse:0.81239
# [78]	validation_0-rmse:0.51315	validation_1-rmse:0.81295
# [79]	validation_0-rmse:0.51179	validation_1-rmse:0.81116
# [80]	validation_0-rmse:0.51032	validation_1-rmse:0.81075
# [81]	validation_0-rmse:0.50913	validation_1-rmse:0.81228
# [82]	validation_0-rmse:0.50725	validation_1-rmse:0.81107
# [83]	validation_0-rmse:0.50415	validation_1-rmse:0.81011
# [84]	validation_0-rmse:0.50253	validation_1-rmse:0.80919
# [85]	validation_0-rmse:0.50062	validation_1-rmse:0.80894
# [86]	validation_0-rmse:0.49898	validation_1-rmse:0.80730
# [87]	validation_0-rmse:0.49550	validation_1-rmse:0.80600
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 69.785, median: 73.0,
#  pred. interval (P(0.025)-P(0.975)): 40.975-87.0,
#  conf. interval (p-value=0.95): 66.359-77.427
# ***
# Aggregate bias statistic:
#  mean: -2.593, median: -2.345,
#  pred. interval (P(0.025)-P(0.975)): -12.77-5.561,
#  conf. interval (p-value=0.95): -3.952--1.084
# ***
# Aggregate RMSE statistic:
#  mean: 0.82, median: 0.815, pred. interval (P(0.025)-P(0.975)): 0.595-1.073,
#  conf. interval (p-value=0.95): 0.776-0.858
# ***
# Aggregate MSE statistic:
#  mean: 0.689, median: 0.664, pred. interval (P(0.025)-P(0.975)): 0.354-1.152,
#  conf. interval (p-value=0.95): 0.606-0.74
# ***
# Aggregate R^2 statistic:
#  mean: 0.423, median: 0.456, pred. interval (P(0.025)-P(0.975)): 0.005-0.711,
#  conf. interval (p-value=0.95): 0.388-0.501
# ***
# Aggregate bias(%) statistic:
#  mean: -0.482, median: -2.345, pred. interval (P(0.025)-P(0.975)): -2.414-1.088,
#  conf. interval (p-value=0.95): -0.764--0.211
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.158, median: 0.157, pred. interval (P(0.025)-P(0.975)): 0.109-0.212,
#  conf. interval (p-value=0.95): 0.148-0.166
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:4.55351
# [1]	validation_0-rmse:4.26181
# [2]	validation_0-rmse:3.99210
# [3]	validation_0-rmse:3.73948
# [4]	validation_0-rmse:3.50289
# [5]	validation_0-rmse:3.28539
# [6]	validation_0-rmse:3.07961
# [7]	validation_0-rmse:2.88992
# [8]	validation_0-rmse:2.71468
# [9]	validation_0-rmse:2.55140
# [10]	validation_0-rmse:2.39975
# [11]	validation_0-rmse:2.25702
# [12]	validation_0-rmse:2.12475
# [13]	validation_0-rmse:2.00328
# [14]	validation_0-rmse:1.88826
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:1.78060
# [16]	validation_0-rmse:1.68487
# [17]	validation_0-rmse:1.59151
# [18]	validation_0-rmse:1.50667
# [19]	validation_0-rmse:1.42985
# [20]	validation_0-rmse:1.35894
# [21]	validation_0-rmse:1.29052
# [22]	validation_0-rmse:1.22849
# [23]	validation_0-rmse:1.17239
# [24]	validation_0-rmse:1.11880
# [25]	validation_0-rmse:1.06871
# [26]	validation_0-rmse:1.02486
# [27]	validation_0-rmse:0.98680
# [28]	validation_0-rmse:0.95396
# [29]	validation_0-rmse:0.91914
# [30]	validation_0-rmse:0.88913
# [31]	validation_0-rmse:0.86174
# [32]	validation_0-rmse:0.83525
# [33]	validation_0-rmse:0.81343
# [34]	validation_0-rmse:0.79040
# [35]	validation_0-rmse:0.77112
# [36]	validation_0-rmse:0.75590
# [37]	validation_0-rmse:0.73793
# [38]	validation_0-rmse:0.72420
# [39]	validation_0-rmse:0.71057
# [40]	validation_0-rmse:0.69824
# [41]	validation_0-rmse:0.68669
# [42]	validation_0-rmse:0.67769
# [43]	validation_0-rmse:0.66939
# [44]	validation_0-rmse:0.65939
# [45]	validation_0-rmse:0.64940
# [46]	validation_0-rmse:0.64080
# [47]	validation_0-rmse:0.63591
# [48]	validation_0-rmse:0.62925
# [49]	validation_0-rmse:0.62350
# [50]	validation_0-rmse:0.61755
# [51]	validation_0-rmse:0.61189
# [52]	validation_0-rmse:0.60685
# [53]	validation_0-rmse:0.60190
# [54]	validation_0-rmse:0.59753
# [55]	validation_0-rmse:0.59379
# [56]	validation_0-rmse:0.59135
# [57]	validation_0-rmse:0.58661
# [58]	validation_0-rmse:0.58397
# [59]	validation_0-rmse:0.58200
# [60]	validation_0-rmse:0.57845
# [61]	validation_0-rmse:0.57549
# [62]	validation_0-rmse:0.57356
# [63]	validation_0-rmse:0.57211
# [64]	validation_0-rmse:0.56916
# [65]	validation_0-rmse:0.56743
# [66]	validation_0-rmse:0.56323
# [67]	validation_0-rmse:0.56034
# [68]	validation_0-rmse:0.55784
# [69]	validation_0-rmse:0.55626
# [70]	validation_0-rmse:0.55430
# [71]	validation_0-rmse:0.55066
# [72]	validation_0-rmse:0.54955
# [73]	validation_0-rmse:0.54791
# [74]	validation_0-rmse:0.54632
# [75]	validation_0-rmse:0.54504
# [76]	validation_0-rmse:0.54284
# [77]	validation_0-rmse:0.54115
# [78]	validation_0-rmse:0.53761
# [79]	validation_0-rmse:0.53449
# [80]	validation_0-rmse:0.53357
# [81]	validation_0-rmse:0.53048
# [82]	validation_0-rmse:0.52921
# [83]	validation_0-rmse:0.52878
# [84]	validation_0-rmse:0.52641
# [85]	validation_0-rmse:0.52421
# [86]	validation_0-rmse:0.52211
# [87]	validation_0-rmse:0.52066
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 87

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.24
# RMSE: 0.5
# Relative RMSE(%):  0.099
# MSE: 0.3
# R square: 78.6%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 1.596
# a1: 0.694
# R^2: 0.801
# Uncertainty
# a0: 1.60+/-0.13
# a1: 0.694+/-0.025

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=1) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/WORK/GIS and ML algoritms/6_Est_RN&biomass_all_site_Sentinel/2020/Nootbooks/XGB_model_GS_Sentinel_data_2020.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/WORK/GIS and ML algoritms/6_Est_RN&biomass_all_site_Sentinel/2020/Nootbooks/XGB_model_GS_Sentinel_data_2020.txt")
