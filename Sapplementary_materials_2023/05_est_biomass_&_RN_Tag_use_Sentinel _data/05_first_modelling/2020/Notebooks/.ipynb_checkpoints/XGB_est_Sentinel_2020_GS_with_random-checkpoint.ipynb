# %% [markdown]
# # *+Processing with Sentinel bands & RN & biomass data of other authors+*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
input_data = '/home/dima/Desktop/WORK/GIS and ML algoritms/6_Est_RN&biomass_all_site_Sentinel/Pre_GIS_data/Site_with_Sentinel_bands_data_2020.csv'
df = pd.read_csv(input_data)
df.head()
# Out:
#   Site # Origin Dominant_s  N_trees at  A_year  D_live_cm  H_live_m  \
# 0      1      n      Birch          57      35       13.5      17.3
# 1      2      a       Pine          25      58       15.0      16.9
# 2      3      a       Pine          32      58       13.7      16.8
# 3      4      a       Pine          63      58       20.3      18.4
# 4      5      a       Pine          53      58       17.5      19.9
#
#    G_live_m2_  f_Gs_cub_m  f_M_stem_kg_m2  ...  r2019B03  r2019B04  r2019B05  \
# 0        15.1         123            5.83  ...  0.030628  0.266210  0.166299
# 1        39.0         317           11.67  ...  0.027934  0.183349  0.102656
# 2        42.8         346           12.37  ...  0.026123  0.184066  0.099625
# 3        38.8         315           13.88  ...  0.027390  0.177221  0.102540
# 4        48.3         383           14.51  ...  0.025702  0.183705  0.101394
#
#    r2019B06  r2019B07  r2019B08  r2019B09   r2019B10   r2019B11  r2019B12
# 0  0.081316  0.793351 -0.733693  0.532051 -15.396488 -11.262037  0.731937
# 1  0.052144  0.735493 -0.655456  0.557000 -16.012156  -9.364664  0.584920
# 2  0.050684  0.751436 -0.650575  0.568148 -13.609903  -9.726108  0.715177
# 3  0.052198  0.732404 -0.648310  0.544717 -14.321650 -10.457536  0.730390
# 4  0.050437  0.754481 -0.660382  0.569112 -13.934375 -11.393335  0.817430
#
# [5 rows x 63 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
#
# 'Site #', 'Origin', 'Dominant_s', 'N_trees at', 'A_year', 'D_live_cm', 'H_live_m', 'G_live_m2_', 'f_Gs_cub_m', 'f_M_stem_kg_m2', 'f_M_stem_bark_kg_m2', 'f_M_crown_kg_m2', 'f_M_foliage_kg_m2', 'f_M_AG_kg_m2', 'Ln_Gs_cub_m', 'Ln_M_stem_kg_m2', 'Ln_M_stem_bark_kg_m2', 'Ln_M_crown_kg_m2', 'Ln_M_foliage_kg_m2', 'Ln_M_AG_kg_m2', 'F_Soil', 'M_Soil', 'X_N36', 'Y_N36', 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'Ln_Cs_wood', 'Ln_Sr_wood', 'Tag_Cs', 'Tag_Sr', 'Ln_Tag_Cs', 'Ln_Tag_Sr', 'Cs_2021_kB', 'Sr_2021_kB', 'AEDR_count', 'AEDR_mean', 'Distance_k', 'Azimuth', 'r2020B01', 'r2020B02', 'r2020B03', 'r2020B04', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11', 'r2020B12', 'r2020B13', 'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Ln_Gs_cub_m', 'Ln_M_stem_kg_m2', 'Ln_M_stem_bark_kg_m2', 'Ln_M_crown_kg_m2', 'Ln_M_foliage_kg_m2', 'Ln_M_AG_kg_m2', 'Ln_Cs_wood', 'Ln_Sr_wood', 'Ln_Tag_Cs', 'Ln_Tag_Sr', 'r2020B01', 'r2020B02', 'r2020B03', 'r2020B04', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11', 'r2020B12'])
            


# Show the first five columns
select.head()
# Out:
#    Ln_Gs_cub_m  Ln_M_stem_kg_m2  Ln_M_stem_bark_kg_m2  Ln_M_crown_kg_m2  \
# 0         4.81             1.76                 -0.31             -0.16
# 1         5.76             2.46                 -0.25              0.34
# 2         5.85             2.52                 -0.11              0.55
# 3         5.75             2.63                 -0.08              0.39
# 4         5.95             2.67                  0.00              0.57
#
#    Ln_M_foliage_kg_m2  Ln_M_AG_kg_m2  Ln_Cs_wood  Ln_Sr_wood  Ln_Tag_Cs  \
# 0               -2.44           1.91         6.8         9.2       -0.7
# 1               -0.20           2.63         8.2         9.6        0.6
# 2               -0.21           2.70         8.4         9.6        0.8
# 3               -0.35           2.78         8.1         9.4        0.5
# 4               -0.37           2.83         7.7         9.4        0.2
#
#    Ln_Tag_Sr  ...  r2020B03  r2020B04  r2020B05  r2020B06  r2020B07  r2020B08  \
# 0        2.6  ...  0.028616  0.254417  0.175280  0.086611  0.797761 -0.749311
# 1        2.9  ...  0.022230  0.189826  0.092225  0.047120  0.789129 -0.705355
# 2        2.9  ...  0.021190  0.204363  0.093062  0.043824  0.812120 -0.704758
# 3        2.7  ...  0.025284  0.187998  0.102872  0.048585  0.762431 -0.695416
# 4        2.8  ...  0.024911  0.216271  0.096981  0.044880  0.793606 -0.717562
#
#    r2020B09   r2020B10   r2020B11  r2020B12
# 0  0.491270 -15.527246 -11.385074  0.733806
# 1  0.659775 -16.547673 -10.947565  0.661723
# 2  0.631348 -14.341917 -11.884799  0.829603
# 3  0.601894 -14.885610 -11.725163  0.787609
# 4  0.642942 -14.647913 -11.512282  0.785698
#
# [5 rows x 22 columns]

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ln_Gs_cub_m           198 non-null    float64
#  1   Ln_M_stem_kg_m2       198 non-null    float64
#  2   Ln_M_stem_bark_kg_m2  198 non-null    float64
#  3   Ln_M_crown_kg_m2      198 non-null    float64
#  4   Ln_M_foliage_kg_m2    198 non-null    float64
#  5   Ln_M_AG_kg_m2         198 non-null    float64
#  6   Ln_Cs_wood            198 non-null    float64
#  7   Ln_Sr_wood            198 non-null    float64
#  8   Ln_Tag_Cs             198 non-null    float64
#  9   Ln_Tag_Sr             198 non-null    float64
#  10  r2020B01              198 non-null    float64
#  11  r2020B02              198 non-null    float64
#  12  r2020B03              198 non-null    float64
#  13  r2020B04              198 non-null    float64
#  14  r2020B05              198 non-null    float64
#  15  r2020B06              198 non-null    float64
#  16  r2020B07              198 non-null    float64
#  17  r2020B08              198 non-null    float64
#  18  r2020B09              198 non-null    float64
#  19  r2020B10              198 non-null    float64
#  20  r2020B11              198 non-null    float64
#  21  r2020B12              198 non-null    float64
# dtypes: float64(22)
# memory usage: 34.2 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_s"])["f_Gs_cub_m", "f_M_stem_kg_m2"].describe()
# Out:
# /tmp/ipykernel_14293/4147815954.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_s"])["f_Gs_cub_m", "f_M_stem_kg_m2"].describe()
#            f_Gs_cub_m                                                      \
#                 count        mean         std    min    25%    50%    75%
# Dominant_s
# Alder            13.0  393.153846  113.795757  199.0  311.0  434.0  462.0
# Aspen             7.0  241.571429  134.878782  121.0  147.0  194.0  321.0
# Birch            45.0  164.622222   83.668254   11.0  107.0  157.0  222.0
# Oak               9.0  199.777778   88.192655   79.0  112.0  220.0  255.0
# Pine            123.0  304.699187  185.582068    2.0  150.5  319.0  457.5
# Spruce            1.0  619.000000         NaN  619.0  619.0  619.0  619.0
#
#                   f_M_stem_kg_m2                                             \
#               max          count       mean       std    min     25%    50%
# Dominant_s
# Alder       558.0           13.0  16.823846  4.334304   9.90  13.560  16.96
# Aspen       440.0            7.0  11.862857  7.997334   4.64   6.470   9.79
# Birch       346.0           45.0   8.030444  4.090891   0.84   4.960   7.75
# Oak         313.0            9.0  10.728889  4.976167   3.59   5.870  11.72
# Pine        671.0          123.0  11.991789  7.094609   0.05   6.285  12.37
# Spruce      619.0            1.0  23.830000       NaN  23.83  23.830  23.83
#
#
#                75%    max
# Dominant_s
# Alder       20.130  24.29
# Aspen       14.810  26.05
# Birch       10.990  17.00
# Oak         13.590  18.99
# Pine        17.645  25.37
# Spruce      23.830  23.83

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Ln_Gs_cub_m  Ln_M_stem_kg_m2  Ln_M_stem_bark_kg_m2  Ln_M_crown_kg_m2  \
# count   198.000000       198.000000            198.000000        198.000000
# mean      5.234646         2.081717             -0.039242          0.171313
# std       1.129652         1.126519              0.789675          0.588506
# min       0.690000        -3.000000             -3.910000         -1.560000
# 25%       4.960000         1.812500             -0.190000         -0.025000
# 50%       5.510000         2.420000              0.060000          0.310000
# 75%       5.987500         2.807500              0.387500          0.530000
# max       6.510000         3.260000              1.650000          1.410000
#
#        Ln_M_foliage_kg_m2  Ln_M_AG_kg_m2  Ln_Cs_wood  Ln_Sr_wood   Ln_Tag_Cs  \
# count          198.000000     198.000000  198.000000  198.000000  198.000000
# mean            -0.953081       2.305758    6.052020    7.395960   -0.566667
# std              0.719719       0.931192    2.089707    2.070848    1.250989
# min             -2.920000      -0.800000    1.600000    2.400000   -4.700000
# 25%             -1.525000       2.052500    4.300000    5.800000   -1.300000
# 50%             -0.690000       2.580000    6.400000    7.600000   -0.500000
# 75%             -0.360000       2.937500    7.400000    8.800000    0.400000
# max              0.110000       3.390000   11.400000   13.900000    1.700000
#
#         Ln_Tag_Sr  ...    r2020B03    r2020B04    r2020B05    r2020B06  \
# count  198.000000  ...  198.000000  198.000000  198.000000  198.000000
# mean     2.342424  ...    0.027499    0.213645    0.125537    0.063662
# std      0.939283  ...    0.009532    0.042641    0.035475    0.023731
# min     -0.300000  ...    0.014640    0.124161    0.079896    0.036570
# 25%      1.700000  ...    0.022284    0.187070    0.095832    0.046290
# 50%      2.500000  ...    0.024743    0.204261    0.115558    0.058209
# 75%      3.000000  ...    0.028527    0.236440    0.150857    0.072122
# max      4.700000  ...    0.080615    0.369338    0.243667    0.187427
#
#          r2020B07    r2020B08    r2020B09    r2020B10    r2020B11    r2020B12
# count  198.000000  198.000000  198.000000  198.000000  198.000000  198.000000
# mean     0.767194   -0.703079    0.540963  -16.145709  -10.863669    0.675418
# std      0.078273    0.060738    0.132304    1.343250    1.161017    0.069250
# min      0.381333   -0.823403    0.038198  -22.517731  -14.262763    0.492975
# 25%      0.745438   -0.735205    0.502225  -16.970102  -11.519514    0.628884
# 50%      0.784239   -0.704881    0.577675  -16.010171  -10.784612    0.667561
# 75%      0.808780   -0.680539    0.632284  -15.159997  -10.008004    0.720595
# max      0.885319   -0.410944    0.710583  -13.281957   -7.650135    0.860863
#
# [8 rows x 22 columns]

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['r2020B01', 'r2020B02', 'r2020B03', 'r2020B04', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11', 'r2020B12'])
y = pd.DataFrame(select, columns= ['Ln_Gs_cub_m'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): Yes
# Selected "Yes"!!! A new column with random values was created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    r2020B01  r2020B02  r2020B03  r2020B04  r2020B05  r2020B06  r2020B07  \
# 0  0.019397  0.035344  0.028616  0.254417  0.175280  0.086611  0.797761
# 1  0.019167  0.033537  0.022230  0.189826  0.092225  0.047120  0.789129
# 2  0.019568  0.035957  0.021190  0.204363  0.093062  0.043824  0.812120
# 3  0.020556  0.033868  0.025284  0.187998  0.102872  0.048585  0.762431
# 4  0.019003  0.036153  0.024911  0.216271  0.096981  0.044880  0.793606
#
#    r2020B08  r2020B09   r2020B10   r2020B11  r2020B12    Random1    Random2  \
# 0 -0.749311  0.491270 -15.527246 -11.385074  0.733806  10.831841   7.100551
# 1 -0.705355  0.659775 -16.547673 -10.947565  0.661723   9.079558  10.382053
# 2 -0.704758  0.631348 -14.341917 -11.884799  0.829603   9.323759   7.630186
# 3 -0.695416  0.601894 -14.885610 -11.725163  0.787609  12.426172  12.911118
# 4 -0.717562  0.642942 -14.647913 -11.512282  0.785698  16.477968  10.487548
#
#      Random3   Random4    Random5
# 0   8.708463  9.297817  11.210073
# 1   9.502301  6.375306  11.899413
# 2   9.265072  9.718460   7.913394
# 3   9.515435  6.602942   8.910265
# 4  10.790586  7.324897   8.938949

# %%
# Columns in "y" data collections
y.head()
# Out:
#    Ln_Gs_cub_m
# 0         4.81
# 1         5.76
# 2         5.85
# 3         5.75
# 4         5.95

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.04171237166681052, 0.49485149258132144, -0.1328956515409634]
#     Mean: 0.135
#     Std: 0.265
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.89242017 1.03634489 0.70144175]
#     Mean: 0.877
#     Std: 0.137
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.6825789722529325, 0.6850618145682594, 0.6572129142284393]
#     Mean: 0.675
#     Std: 0.013
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=30, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Model with rank: 1
# Mean validation score: 0.211 (std: 0.330)
# Parameters: {'colsample_bytree': 0.36313267236912883, 'gamma': 0.15237050158797383, 'learning_rate': 0.1257683926198745, 'max_depth': 4, 'n_estimators': 65, 'subsample': 0.894815316258655}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.36334791, 0.23031516, 0.28066754, 0.12565637, 0.27377048,
#        0.09818153, 0.30635486, 0.30100427, 0.2013638 , 0.28105021,
#        0.2015923 , 0.33200746, 0.26985159, 0.10182414, 0.12957172,
#        0.40507879, 0.12878046, 0.17144189, 0.19459338, 0.41149464,
#        0.12711883, 0.33716393, 0.31634908, 0.20484624, 0.20740795,
#        0.17535772, 0.26652775, 0.24171844, 0.27845964, 0.32284069]), 'std_fit_time': array([0.04954298, 0.06168289, 0.01127533, 0.00915413, 0.01463045,
#        0.00364514, 0.12019841, 0.06262548, 0.00707055, 0.01519299,
#        0.03220194, 0.02198782, 0.02142798, 0.00898599, 0.00482226,
#        0.18056449, 0.02141876, 0.0245392 , 0.01213239, 0.08668103,
#        0.02420276, 0.04335744, 0.03926881, 0.00880505, 0.00911713,
#        0.0197139 , 0.01756771, 0.0092095 , 0.01968298, 0.03147478]), 'mean_score_time': array([0.00478549, 0.00494127, 0.00483665, 0.00460486, 0.00483146,
#        0.00452404, 0.00503311, 0.00465574, 0.00708728, 0.00490189,
#        0.00585313, 0.00458679, 0.00454726, 0.00448685, 0.00453272,
#        0.00513091, 0.00508313, 0.00488391, 0.00531373, 0.00474358,
#        0.00591021, 0.00480137, 0.00888829, 0.0048038 , 0.00474157,
#        0.00476904, 0.00470452, 0.00464358, 0.00486012, 0.00635414]), 'std_score_time': array([8.28749840e-05, 2.99395431e-04, 1.68729258e-04, 8.86895836e-05,
#        1.88224762e-04, 1.23802061e-04, 4.95453876e-04, 2.64949880e-05,
#        5.01020801e-03, 5.33064596e-04, 2.22638958e-03, 5.18713797e-05,
#        7.82348107e-05, 1.44925898e-04, 9.97550401e-05, 4.54409265e-04,
#        7.30124586e-04, 2.10700447e-04, 9.13247976e-04, 8.14461038e-05,
#        2.48156273e-03, 2.05602296e-04, 7.30392782e-03, 1.45232152e-04,
#        0.95053539, 0.96841186, 0.9559319 , 0.95517935, 0.96277591,
#        0.96609473, 0.95708438, 0.96370636, 0.94632177, 0.96811915,
#        0.96133639, 0.93003512, 0.9735268 , 0.97244654, 0.83419139,
#        0.83901139, 0.9478534 , 0.98014425, 0.95678475, 0.97771411,
#        0.95821064, 0.98220253, 0.66939321, 0.95699656, 0.98594158]), 'split4_train_score': array([0.96461654, 0.97051771, 0.74261308, 0.9742116 , 0.98576166,
#        0.9486045 , 0.96676544, 0.95325009, 0.94978692, 0.95972858,
#        0.96631363, 0.95985088, 0.96325296, 0.94085887, 0.96712413,
#        0.96049185, 0.92700977, 0.97108646, 0.97033217, 0.8332756 ,
#        0.82851075, 0.94330238, 0.98032073, 0.95560275, 0.97893895,
#        0.95560315, 0.98264801, 0.67280272, 0.9507525 , 0.98632621]), 'mean_train_score': array([0.95977462, 0.96618564, 0.73569683, 0.97501072, 0.98580264,
#        0.94575861, 0.96507285, 0.95542095, 0.94419346, 0.9563016 ,
#        0.96208598, 0.95239682, 0.96511637, 0.93772427, 0.96312811,
#        0.9541774 , 0.92378026, 0.96979957, 0.96889761, 0.83477552,
#        0.84164039, 0.94069499, 0.97597356, 0.95435987, 0.97500572,
#        0.94924104, 0.98018295, 0.654636  , 0.94834883, 0.98345222]), 'std_train_score': array([0.00469342, 0.00274527, 0.01334048, 0.00275694, 0.00155858,
#        0.00590368, 0.00250282, 0.00563409, 0.00833055, 0.00631674,
#        0.00494212, 0.00674503, 0.00258143, 0.00886833, 0.00559806,
#        0.00700606, 0.00400156, 0.0037242 , 0.00260214, 0.01851595,
#        0.0176675 , 0.00874   , 0.00446671, 0.00413287, 0.0037858 ,
#        0.00820149, 0.00262405, 0.02009714, 0.0061054 , 0.00259588])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.36313267236912883
# Gamma: 0.15237050158797383
# Learning_rate: 0.1257683926198745
# Max_depth: 4
# N_estimators: 65
# Subsample: 0.894815316258655

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(30):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:4.30770	validation_1-rmse:4.17071
# [1]	validation_0-rmse:3.79209	validation_1-rmse:3.68133
# [2]	validation_0-rmse:3.34278	validation_1-rmse:3.24076
# [3]	validation_0-rmse:2.94853	validation_1-rmse:2.86688
# [4]	validation_0-rmse:2.59756	validation_1-rmse:2.54057
# [5]	validation_0-rmse:2.29525	validation_1-rmse:2.25809
# [6]	validation_0-rmse:2.03492	validation_1-rmse:2.00844
# [7]	validation_0-rmse:1.80561	validation_1-rmse:1.80043
# [8]	validation_0-rmse:1.60285	validation_1-rmse:1.62846
# [9]	validation_0-rmse:1.42400	validation_1-rmse:1.48210
# [10]	validation_0-rmse:1.27288	validation_1-rmse:1.36553
# [11]	validation_0-rmse:1.14365	validation_1-rmse:1.26712
# [12]	validation_0-rmse:1.02676	validation_1-rmse:1.19092
# [13]	validation_0-rmse:0.92976	validation_1-rmse:1.13059
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [14]	validation_0-rmse:0.84713	validation_1-rmse:1.08051
# [15]	validation_0-rmse:0.77243	validation_1-rmse:1.03793
# [16]	validation_0-rmse:0.70378	validation_1-rmse:1.00157
# [17]	validation_0-rmse:0.64770	validation_1-rmse:0.97045
# [18]	validation_0-rmse:0.59672	validation_1-rmse:0.94861
# [19]	validation_0-rmse:0.55382	validation_1-rmse:0.93861
# [20]	validation_0-rmse:0.51885	validation_1-rmse:0.93288
# [21]	validation_0-rmse:0.48777	validation_1-rmse:0.92543
# [22]	validation_0-rmse:0.46047	validation_1-rmse:0.91925
# [23]	validation_0-rmse:0.43497	validation_1-rmse:0.91984
# [24]	validation_0-rmse:0.41092	validation_1-rmse:0.92249
# [25]	validation_0-rmse:0.38982	validation_1-rmse:0.91970
# [26]	validation_0-rmse:0.37317	validation_1-rmse:0.92105
# [43]	validation_0-rmse:0.23106	validation_1-rmse:0.76710
# [44]	validation_0-rmse:0.22807	validation_1-rmse:0.76509
# [45]	validation_0-rmse:0.22293	validation_1-rmse:0.76413
# [46]	validation_0-rmse:0.21928	validation_1-rmse:0.76270
# [47]	validation_0-rmse:0.21583	validation_1-rmse:0.76071
# [48]	validation_0-rmse:0.21285	validation_1-rmse:0.76229
# [49]	validation_0-rmse:0.20917	validation_1-rmse:0.76355
# [50]	validation_0-rmse:0.20411	validation_1-rmse:0.76206
# [51]	validation_0-rmse:0.20069	validation_1-rmse:0.76239
# [52]	validation_0-rmse:0.20068	validation_1-rmse:0.76236
# [53]	validation_0-rmse:0.19809	validation_1-rmse:0.76368
# [54]	validation_0-rmse:0.19347	validation_1-rmse:0.76108
# [55]	validation_0-rmse:0.19347	validation_1-rmse:0.76110
# [56]	validation_0-rmse:0.19055	validation_1-rmse:0.76242
# ...
# [2]	validation_0-rmse:3.33088	validation_1-rmse:3.31073
# [3]	validation_0-rmse:2.93868	validation_1-rmse:2.92634
# [4]	validation_0-rmse:2.59939	validation_1-rmse:2.59776
# [5]	validation_0-rmse:2.30223	validation_1-rmse:2.32047
# [6]	validation_0-rmse:2.02943	validation_1-rmse:2.06632
# [7]	validation_0-rmse:1.79824	validation_1-rmse:1.84507
# [8]	validation_0-rmse:1.59609	validation_1-rmse:1.65976
# [9]	validation_0-rmse:1.42031	validation_1-rmse:1.50466
# [10]	validation_0-rmse:1.26535	validation_1-rmse:1.37943
# [11]	validation_0-rmse:1.13276	validation_1-rmse:1.27747
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [12]	validation_0-rmse:1.01698	validation_1-rmse:1.17300
# [13]	validation_0-rmse:0.91593	validation_1-rmse:1.10496
# [14]	validation_0-rmse:0.82858	validation_1-rmse:1.04693
# [15]	validation_0-rmse:0.75255	validation_1-rmse:0.99115
# [16]	validation_0-rmse:0.68691	validation_1-rmse:0.94294
# [17]	validation_0-rmse:0.63053	validation_1-rmse:0.91511
# [18]	validation_0-rmse:0.57555	validation_1-rmse:0.88847
# [19]	validation_0-rmse:0.53078	validation_1-rmse:0.86934
# [20]	validation_0-rmse:0.49594	validation_1-rmse:0.85207
# [21]	validation_0-rmse:0.46542	validation_1-rmse:0.83569
# [22]	validation_0-rmse:0.43581	validation_1-rmse:0.82637
# [23]	validation_0-rmse:0.41466	validation_1-rmse:0.81353
# [24]	validation_0-rmse:0.38857	validation_1-rmse:0.80302
# [25]	validation_0-rmse:0.36931	validation_1-rmse:0.80059
# [26]	validation_0-rmse:0.35053	validation_1-rmse:0.79490
# [27]	validation_0-rmse:0.33401	validation_1-rmse:0.78940
# [28]	validation_0-rmse:0.32419	validation_1-rmse:0.78751
# [29]	validation_0-rmse:0.31386	validation_1-rmse:0.78529
# [30]	validation_0-rmse:0.30338	validation_1-rmse:0.78320
# [31]	validation_0-rmse:0.29408	validation_1-rmse:0.78447
# [32]	validation_0-rmse:0.28548	validation_1-rmse:0.78230
# [33]	validation_0-rmse:0.28008	validation_1-rmse:0.78343
# [34]	validation_0-rmse:0.26974	validation_1-rmse:0.78639
# [35]	validation_0-rmse:0.26346	validation_1-rmse:0.78605
# [36]	validation_0-rmse:0.25563	validation_1-rmse:0.78437
# [37]	validation_0-rmse:0.24801	validation_1-rmse:0.78107
# [38]	validation_0-rmse:0.23922	validation_1-rmse:0.78502
# [39]	validation_0-rmse:0.23470	validation_1-rmse:0.78327
# [40]	validation_0-rmse:0.22918	validation_1-rmse:0.78584
# [41]	validation_0-rmse:0.22472	validation_1-rmse:0.78548
# [42]	validation_0-rmse:0.21864	validation_1-rmse:0.78532
# [43]	validation_0-rmse:0.21572	validation_1-rmse:0.78695
# [44]	validation_0-rmse:0.21331	validation_1-rmse:0.78854
# [45]	validation_0-rmse:0.20963	validation_1-rmse:0.79034
# [46]	validation_0-rmse:0.20442	validation_1-rmse:0.79106
# [47]	validation_0-rmse:0.20002	validation_1-rmse:0.78907
# [48]	validation_0-rmse:0.19568	validation_1-rmse:0.78643
# [49]	validation_0-rmse:0.19565	validation_1-rmse:0.78634
# [50]	validation_0-rmse:0.19353	validation_1-rmse:0.78596
# [51]	validation_0-rmse:0.19043	validation_1-rmse:0.78481
# [52]	validation_0-rmse:0.18704	validation_1-rmse:0.78194
# [53]	validation_0-rmse:0.18555	validation_1-rmse:0.78356
# [54]	validation_0-rmse:0.18423	validation_1-rmse:0.78456
# [55]	validation_0-rmse:0.18188	validation_1-rmse:0.78451
# [56]	validation_0-rmse:0.17881	validation_1-rmse:0.78078
# [57]	validation_0-rmse:0.17752	validation_1-rmse:0.77999
# [58]	validation_0-rmse:0.17560	validation_1-rmse:0.77932
# [59]	validation_0-rmse:0.17267	validation_1-rmse:0.77847
# [60]	validation_0-rmse:0.17228	validation_1-rmse:0.78056
# [61]	validation_0-rmse:0.16996	validation_1-rmse:0.78059
# [62]	validation_0-rmse:0.16710	validation_1-rmse:0.78088
# [63]	validation_0-rmse:0.16710	validation_1-rmse:0.78081
# [64]	validation_0-rmse:0.16710	validation_1-rmse:0.78088
# [0]	validation_0-rmse:4.24610	validation_1-rmse:4.44448
# [1]	validation_0-rmse:3.73365	validation_1-rmse:3.93288
# [2]	validation_0-rmse:3.29287	validation_1-rmse:3.48132
# [3]	validation_0-rmse:2.90314	validation_1-rmse:3.08868
# [4]	validation_0-rmse:2.56316	validation_1-rmse:2.74104
# [5]	validation_0-rmse:2.26107	validation_1-rmse:2.44403
# [6]	validation_0-rmse:2.00181	validation_1-rmse:2.19309
# [7]	validation_0-rmse:1.77648	validation_1-rmse:1.96744
# [8]	validation_0-rmse:1.58135	validation_1-rmse:1.77090
# [9]	validation_0-rmse:1.40367	validation_1-rmse:1.61032
# [10]	validation_0-rmse:1.25644	validation_1-rmse:1.46034
# [11]	validation_0-rmse:1.12656	validation_1-rmse:1.34053
# [12]	validation_0-rmse:1.01605	validation_1-rmse:1.23637
# [13]	validation_0-rmse:0.91505	validation_1-rmse:1.14954
# [14]	validation_0-rmse:0.83170	validation_1-rmse:1.08818
# [15]	validation_0-rmse:0.75542	validation_1-rmse:1.03365
# [16]	validation_0-rmse:0.68955	validation_1-rmse:0.97944
# [17]	validation_0-rmse:0.63618	validation_1-rmse:0.93861
# [18]	validation_0-rmse:0.58486	validation_1-rmse:0.89872
# [19]	validation_0-rmse:0.53804	validation_1-rmse:0.86930
# [20]	validation_0-rmse:0.50124	validation_1-rmse:0.84790
# [21]	validation_0-rmse:0.46570	validation_1-rmse:0.82609
# [22]	validation_0-rmse:0.43927	validation_1-rmse:0.80788
# [23]	validation_0-rmse:0.41375	validation_1-rmse:0.80061
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [24]	validation_0-rmse:0.39368	validation_1-rmse:0.79126
# [25]	validation_0-rmse:0.37390	validation_1-rmse:0.77885
# [26]	validation_0-rmse:0.35619	validation_1-rmse:0.77282
# [27]	validation_0-rmse:0.34095	validation_1-rmse:0.76565
# [28]	validation_0-rmse:0.32870	validation_1-rmse:0.75670
# [29]	validation_0-rmse:0.31432	validation_1-rmse:0.74729
# [30]	validation_0-rmse:0.30339	validation_1-rmse:0.74492
# [31]	validation_0-rmse:0.29605	validation_1-rmse:0.74389
# [32]	validation_0-rmse:0.28600	validation_1-rmse:0.73958
# [33]	validation_0-rmse:0.27894	validation_1-rmse:0.73518
# [34]	validation_0-rmse:0.27345	validation_1-rmse:0.73089
# [35]	validation_0-rmse:0.26607	validation_1-rmse:0.72802
# [36]	validation_0-rmse:0.25642	validation_1-rmse:0.72806
# [37]	validation_0-rmse:0.25053	validation_1-rmse:0.73027
# [38]	validation_0-rmse:0.24447	validation_1-rmse:0.72927
# [39]	validation_0-rmse:0.23958	validation_1-rmse:0.72922
# [40]	validation_0-rmse:0.23375	validation_1-rmse:0.73185
# [41]	validation_0-rmse:0.22814	validation_1-rmse:0.73181
# [42]	validation_0-rmse:0.22258	validation_1-rmse:0.72996
# [43]	validation_0-rmse:0.21699	validation_1-rmse:0.72921
# [44]	validation_0-rmse:0.21567	validation_1-rmse:0.72896
# [45]	validation_0-rmse:0.21054	validation_1-rmse:0.72887
# [46]	validation_0-rmse:0.20761	validation_1-rmse:0.72987
# [47]	validation_0-rmse:0.20574	validation_1-rmse:0.72929
# [48]	validation_0-rmse:0.20441	validation_1-rmse:0.72865
# [49]	validation_0-rmse:0.20283	validation_1-rmse:0.72921
# [50]	validation_0-rmse:0.19851	validation_1-rmse:0.73043
# [51]	validation_0-rmse:0.19635	validation_1-rmse:0.73221
# [52]	validation_0-rmse:0.19285	validation_1-rmse:0.73015
# [53]	validation_0-rmse:0.18940	validation_1-rmse:0.73199
# [54]	validation_0-rmse:0.18845	validation_1-rmse:0.73166
# [55]	validation_0-rmse:0.18652	validation_1-rmse:0.73222
# [0]	validation_0-rmse:4.30112	validation_1-rmse:4.18930
# [1]	validation_0-rmse:3.78510	validation_1-rmse:3.68526
# [2]	validation_0-rmse:3.33356	validation_1-rmse:3.24797
# [3]	validation_0-rmse:2.94307	validation_1-rmse:2.87591
# [4]	validation_0-rmse:2.59501	validation_1-rmse:2.53301
# [5]	validation_0-rmse:2.29091	validation_1-rmse:2.26287
# [6]	validation_0-rmse:2.02603	validation_1-rmse:2.03577
# [7]	validation_0-rmse:1.79669	validation_1-rmse:1.82474
# [8]	validation_0-rmse:1.59252	validation_1-rmse:1.66283
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [9]	validation_0-rmse:1.41410	validation_1-rmse:1.51883
# [10]	validation_0-rmse:1.26408	validation_1-rmse:1.39488
# [11]	validation_0-rmse:1.13277	validation_1-rmse:1.28544
# [12]	validation_0-rmse:1.01535	validation_1-rmse:1.20371
# [13]	validation_0-rmse:0.91427	validation_1-rmse:1.14010
# [14]	validation_0-rmse:0.82609	validation_1-rmse:1.08117
# [15]	validation_0-rmse:0.74823	validation_1-rmse:1.03352
# [16]	validation_0-rmse:0.68147	validation_1-rmse:0.99807
# [17]	validation_0-rmse:0.62494	validation_1-rmse:0.97058
# [18]	validation_0-rmse:0.57698	validation_1-rmse:0.94219
# [19]	validation_0-rmse:0.53639	validation_1-rmse:0.92160
# [20]	validation_0-rmse:0.49622	validation_1-rmse:0.91172
# [21]	validation_0-rmse:0.46464	validation_1-rmse:0.90210
# [22]	validation_0-rmse:0.43565	validation_1-rmse:0.90151
# [23]	validation_0-rmse:0.41390	validation_1-rmse:0.89318
# [24]	validation_0-rmse:0.39255	validation_1-rmse:0.89009
# [25]	validation_0-rmse:0.37307	validation_1-rmse:0.89030
# [26]	validation_0-rmse:0.35637	validation_1-rmse:0.89169
# [27]	validation_0-rmse:0.34027	validation_1-rmse:0.89182
# [28]	validation_0-rmse:0.32337	validation_1-rmse:0.88985
# [29]	validation_0-rmse:0.31530	validation_1-rmse:0.89194
# [30]	validation_0-rmse:0.30389	validation_1-rmse:0.88557
# [31]	validation_0-rmse:0.29403	validation_1-rmse:0.88188
# [32]	validation_0-rmse:0.28265	validation_1-rmse:0.88587
# [33]	validation_0-rmse:0.27210	validation_1-rmse:0.88680
# [34]	validation_0-rmse:0.26336	validation_1-rmse:0.88693
# [35]	validation_0-rmse:0.25376	validation_1-rmse:0.88689
# [36]	validation_0-rmse:0.24888	validation_1-rmse:0.88750
# [37]	validation_0-rmse:0.24199	validation_1-rmse:0.88338
# [38]	validation_0-rmse:0.23553	validation_1-rmse:0.88040
# [39]	validation_0-rmse:0.23046	validation_1-rmse:0.88092
# [40]	validation_0-rmse:0.22637	validation_1-rmse:0.88205
# [41]	validation_0-rmse:0.22393	validation_1-rmse:0.88219
# [42]	validation_0-rmse:0.21811	validation_1-rmse:0.88310
# [43]	validation_0-rmse:0.21371	validation_1-rmse:0.87973
# [44]	validation_0-rmse:0.21007	validation_1-rmse:0.88013
# [45]	validation_0-rmse:0.20579	validation_1-rmse:0.88463
# [46]	validation_0-rmse:0.20006	validation_1-rmse:0.88435
# [47]	validation_0-rmse:0.19838	validation_1-rmse:0.88428
# [48]	validation_0-rmse:0.19444	validation_1-rmse:0.88236
# [49]	validation_0-rmse:0.19061	validation_1-rmse:0.88232
# [50]	validation_0-rmse:0.18720	validation_1-rmse:0.88344
# [51]	validation_0-rmse:0.18585	validation_1-rmse:0.88124
# [52]	validation_0-rmse:0.18585	validation_1-rmse:0.88125
# [53]	validation_0-rmse:0.18460	validation_1-rmse:0.88145
# [54]	validation_0-rmse:0.18191	validation_1-rmse:0.88488
# [55]	validation_0-rmse:0.17987	validation_1-rmse:0.88369
# [56]	validation_0-rmse:0.17660	validation_1-rmse:0.88316
# [57]	validation_0-rmse:0.17660	validation_1-rmse:0.88313
# [58]	validation_0-rmse:0.17661	validation_1-rmse:0.88312
# [59]	validation_0-rmse:0.17448	validation_1-rmse:0.88400
# [60]	validation_0-rmse:0.17446	validation_1-rmse:0.88406
# [61]	validation_0-rmse:0.17231	validation_1-rmse:0.88430
# [62]	validation_0-rmse:0.17021	validation_1-rmse:0.88672
# [63]	validation_0-rmse:0.17021	validation_1-rmse:0.88674
# [0]	validation_0-rmse:4.27215	validation_1-rmse:4.29231
# [1]	validation_0-rmse:3.75386	validation_1-rmse:3.77101
# [2]	validation_0-rmse:3.30429	validation_1-rmse:3.32175
# [3]	validation_0-rmse:2.91208	validation_1-rmse:2.92969
# [4]	validation_0-rmse:2.57168	validation_1-rmse:2.60113
# [5]	validation_0-rmse:2.27363	validation_1-rmse:2.30926
# [6]	validation_0-rmse:2.00831	validation_1-rmse:2.05334
# [7]	validation_0-rmse:1.77942	validation_1-rmse:1.83734
# [8]	validation_0-rmse:1.57712	validation_1-rmse:1.66587
# [9]	validation_0-rmse:1.40188	validation_1-rmse:1.50976
# [10]	validation_0-rmse:1.25169	validation_1-rmse:1.37697
# [11]	validation_0-rmse:1.11853	validation_1-rmse:1.26776
# [12]	validation_0-rmse:1.00143	validation_1-rmse:1.17902
# [13]	validation_0-rmse:0.89937	validation_1-rmse:1.09823
# [14]	validation_0-rmse:0.81270	validation_1-rmse:1.04654
# [15]	validation_0-rmse:0.73763	validation_1-rmse:0.99406
# [16]	validation_0-rmse:0.67598	validation_1-rmse:0.95286
# [17]	validation_0-rmse:0.61826	validation_1-rmse:0.92785
# [18]	validation_0-rmse:0.56920	validation_1-rmse:0.90111
# [19]	validation_0-rmse:0.52569	validation_1-rmse:0.88364
# [20]	validation_0-rmse:0.48660	validation_1-rmse:0.86646
# [21]	validation_0-rmse:0.45554	validation_1-rmse:0.86212
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [22]	validation_0-rmse:0.42821	validation_1-rmse:0.85473
# [23]	validation_0-rmse:0.40582	validation_1-rmse:0.84751
# [24]	validation_0-rmse:0.38152	validation_1-rmse:0.84436
# [25]	validation_0-rmse:0.35833	validation_1-rmse:0.84106
# [26]	validation_0-rmse:0.34209	validation_1-rmse:0.83503
# [27]	validation_0-rmse:0.32447	validation_1-rmse:0.83367
# [28]	validation_0-rmse:0.31145	validation_1-rmse:0.83489
# [29]	validation_0-rmse:0.30232	validation_1-rmse:0.83126
# [30]	validation_0-rmse:0.29021	validation_1-rmse:0.83139
# [31]	validation_0-rmse:0.28121	validation_1-rmse:0.82833
# [32]	validation_0-rmse:0.26870	validation_1-rmse:0.82674
# [33]	validation_0-rmse:0.26119	validation_1-rmse:0.82715
# [34]	validation_0-rmse:0.25185	validation_1-rmse:0.83031
# [35]	validation_0-rmse:0.24390	validation_1-rmse:0.83033
# [36]	validation_0-rmse:0.23837	validation_1-rmse:0.82567
# [37]	validation_0-rmse:0.23192	validation_1-rmse:0.82501
# [38]	validation_0-rmse:0.22399	validation_1-rmse:0.82084
# [39]	validation_0-rmse:0.21761	validation_1-rmse:0.82047
# [40]	validation_0-rmse:0.21279	validation_1-rmse:0.81834
# [41]	validation_0-rmse:0.20867	validation_1-rmse:0.81780
# [42]	validation_0-rmse:0.20500	validation_1-rmse:0.81765
# [43]	validation_0-rmse:0.20203	validation_1-rmse:0.81755
# [44]	validation_0-rmse:0.19598	validation_1-rmse:0.81904
# [45]	validation_0-rmse:0.19089	validation_1-rmse:0.82357
# [46]	validation_0-rmse:0.18640	validation_1-rmse:0.82170
# [47]	validation_0-rmse:0.18341	validation_1-rmse:0.82155
# [48]	validation_0-rmse:0.18252	validation_1-rmse:0.82252
# [49]	validation_0-rmse:0.18100	validation_1-rmse:0.82314
# [50]	validation_0-rmse:0.17766	validation_1-rmse:0.82310
# [51]	validation_0-rmse:0.17623	validation_1-rmse:0.82378
# [52]	validation_0-rmse:0.17436	validation_1-rmse:0.82545
# [53]	validation_0-rmse:0.17436	validation_1-rmse:0.82545
# [54]	validation_0-rmse:0.17135	validation_1-rmse:0.82697
# [55]	validation_0-rmse:0.16735	validation_1-rmse:0.82529
# [56]	validation_0-rmse:0.16735	validation_1-rmse:0.82529
# [57]	validation_0-rmse:0.16735	validation_1-rmse:0.82530
# [58]	validation_0-rmse:0.16608	validation_1-rmse:0.82629
# [59]	validation_0-rmse:0.16491	validation_1-rmse:0.82682
# [60]	validation_0-rmse:0.16491	validation_1-rmse:0.82682
# [61]	validation_0-rmse:0.16319	validation_1-rmse:0.82575
# [62]	validation_0-rmse:0.16151	validation_1-rmse:0.82791
# [63]	validation_0-rmse:0.16151	validation_1-rmse:0.82791
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 42.6, median: 43.0,
#  pred. interval (P(0.025)-P(0.975)): 25.725-63.275,
#  conf. interval (p-value=0.95): 38.459-47.111
# ***
# Aggregate bias statistic:
#  mean: -3.934, median: -4.239,
#  pred. interval (P(0.025)-P(0.975)): -10.004-3.67,
#  conf. interval (p-value=0.95): -5.338--2.829
# ***
# Aggregate RMSE statistic:
#  mean: 0.832, median: 0.844, pred. interval (P(0.025)-P(0.975)): 0.559-1.084,
#  conf. interval (p-value=0.95): 0.807-0.877
# ***
# Aggregate MSE statistic:
#  mean: 0.71, median: 0.712, pred. interval (P(0.025)-P(0.975)): 0.313-1.175,
#  conf. interval (p-value=0.95): 0.654-0.771
# ***
# Aggregate R^2 statistic:
#  mean: 0.357, median: 0.356, pred. interval (P(0.025)-P(0.975)): 0.059-0.663,
#  conf. interval (p-value=0.95): 0.294-0.406
# ***
# Aggregate bias(%) statistic:
#  mean: -0.736, median: -4.239, pred. interval (P(0.025)-P(0.975)): -1.845-0.705,
#  conf. interval (p-value=0.95): -1.006--0.532
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.158, median: 0.156, pred. interval (P(0.025)-P(0.975)): 0.106-0.216,
#  conf. interval (p-value=0.95): 0.149-0.164
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:4.28058
# [1]	validation_0-rmse:3.76979
# [2]	validation_0-rmse:3.32169
# [3]	validation_0-rmse:2.93077
# [4]	validation_0-rmse:2.59105
# [5]	validation_0-rmse:2.29134
# [6]	validation_0-rmse:2.02728
# [7]	validation_0-rmse:1.79865
# [8]	validation_0-rmse:1.60301
# [9]	validation_0-rmse:1.43322
# [10]	validation_0-rmse:1.28799
# [11]	validation_0-rmse:1.16011
# [12]	validation_0-rmse:1.04789
# [13]	validation_0-rmse:0.95020
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [14]	validation_0-rmse:0.86408
# [15]	validation_0-rmse:0.79021
# [16]	validation_0-rmse:0.72746
# [17]	validation_0-rmse:0.67043
# [18]	validation_0-rmse:0.62345
# [19]	validation_0-rmse:0.58683
# [20]	validation_0-rmse:0.55130
# [21]	validation_0-rmse:0.51471
# [22]	validation_0-rmse:0.48495
# [23]	validation_0-rmse:0.46024
# [24]	validation_0-rmse:0.43906
# [25]	validation_0-rmse:0.41811
# [26]	validation_0-rmse:0.40182
# [27]	validation_0-rmse:0.38660
# [28]	validation_0-rmse:0.37485
# [29]	validation_0-rmse:0.36364
# [30]	validation_0-rmse:0.35278
# [31]	validation_0-rmse:0.34370
# [32]	validation_0-rmse:0.33654
# [33]	validation_0-rmse:0.32981
# [34]	validation_0-rmse:0.31852
# [35]	validation_0-rmse:0.30792
# [36]	validation_0-rmse:0.30133
# [37]	validation_0-rmse:0.29403
# [38]	validation_0-rmse:0.29048
# [39]	validation_0-rmse:0.28492
# [40]	validation_0-rmse:0.28040
# [41]	validation_0-rmse:0.27473
# [42]	validation_0-rmse:0.26997
# [43]	validation_0-rmse:0.26645
# [44]	validation_0-rmse:0.26174
# [45]	validation_0-rmse:0.25780
# [46]	validation_0-rmse:0.25525
# [47]	validation_0-rmse:0.25152
# [48]	validation_0-rmse:0.24820
# [49]	validation_0-rmse:0.24426
# [50]	validation_0-rmse:0.24174
# [51]	validation_0-rmse:0.23652
# [52]	validation_0-rmse:0.23287
# [53]	validation_0-rmse:0.22964
# [54]	validation_0-rmse:0.22232
# [55]	validation_0-rmse:0.21759
# [56]	validation_0-rmse:0.21265
# [57]	validation_0-rmse:0.20793
# [58]	validation_0-rmse:0.20594
# [59]	validation_0-rmse:0.20145
# [60]	validation_0-rmse:0.19784
# [61]	validation_0-rmse:0.19595
# [62]	validation_0-rmse:0.19363
# [63]	validation_0-rmse:0.19143
# [64]	validation_0-rmse:0.18836
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 64

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  0.10
# RMSE: 0.2
# Relative RMSE(%):  0.036
# MSE: 0.0
# R square: 97.2%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.480
# a1: 0.909
# R^2: 0.977
# Uncertainty
# a0: 0.48+/-0.05
# a1: 0.909+/-0.010

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=1) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/WORK/GIS and ML algoritms/6_Est_RN&biomass_all_site_Sentinel/2020/Nootbooks/XGB_model_GS_Sentinel_data_2020.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/WORK/GIS and ML algoritms/6_Est_RN&biomass_all_site_Sentinel/2020/Nootbooks/XGB_model_GS_Sentinel_data_2020.txt")
