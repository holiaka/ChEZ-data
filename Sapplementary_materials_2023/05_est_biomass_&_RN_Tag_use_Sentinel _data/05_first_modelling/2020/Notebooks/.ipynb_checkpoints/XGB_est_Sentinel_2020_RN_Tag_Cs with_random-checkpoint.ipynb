# %% [markdown]
# # *+Processing with Sentinel bands & RN & biomass data of other authors+*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
input_data = '/home/dima/Desktop/WORK/GIS and ML algoritms/6_Est_RN&biomass_all_site_Sentinel/Pre_GIS_data/Site_with_Sentinel_bands_data_2020.csv'
df = pd.read_csv(input_data)
df.head()
# Out:
#   Site # Origin Dominant_s  N_trees at  A_year  D_live_cm  H_live_m  \
# 0      1      n      Birch          57      35       13.5      17.3
# 1      2      a       Pine          25      58       15.0      16.9
# 2      3      a       Pine          32      58       13.7      16.8
# 3      4      a       Pine          63      58       20.3      18.4
# 4      5      a       Pine          53      58       17.5      19.9
#
#    G_live_m2_  f_Gs_cub_m  f_M_stem_kg_m2  ...  r2019B03  r2019B04  r2019B05  \
# 0        15.1         123            5.83  ...  0.030628  0.266210  0.166299
# 1        39.0         317           11.67  ...  0.027934  0.183349  0.102656
# 2        42.8         346           12.37  ...  0.026123  0.184066  0.099625
# 3        38.8         315           13.88  ...  0.027390  0.177221  0.102540
# 4        48.3         383           14.51  ...  0.025702  0.183705  0.101394
#
#    r2019B06  r2019B07  r2019B08  r2019B09   r2019B10   r2019B11  r2019B12
# 0  0.081316  0.793351 -0.733693  0.532051 -15.396488 -11.262037  0.731937
# 1  0.052144  0.735493 -0.655456  0.557000 -16.012156  -9.364664  0.584920
# 2  0.050684  0.751436 -0.650575  0.568148 -13.609903  -9.726108  0.715177
# 3  0.052198  0.732404 -0.648310  0.544717 -14.321650 -10.457536  0.730390
# 4  0.050437  0.754481 -0.660382  0.569112 -13.934375 -11.393335  0.817430
#
# [5 rows x 63 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
#
# 'Site #', 'Origin', 'Dominant_s', 'N_trees at', 'A_year', 'D_live_cm', 'H_live_m', 'G_live_m2_', 'f_Gs_cub_m', 'f_M_stem_kg_m2', 'f_M_stem_bark_kg_m2', 'f_M_crown_kg_m2', 'f_M_foliage_kg_m2', 'f_M_AG_kg_m2', 'Ln_Gs_cub_m', 'Ln_M_stem_kg_m2', 'Ln_M_stem_bark_kg_m2', 'Ln_M_crown_kg_m2', 'Ln_M_foliage_kg_m2', 'Ln_M_AG_kg_m2', 'F_Soil', 'M_Soil', 'X_N36', 'Y_N36', 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'Ln_Cs_wood', 'Ln_Sr_wood', 'Tag_Cs', 'Tag_Sr', 'Ln_Tag_Cs', 'Ln_Tag_Sr', 'Cs_2021_kB', 'Sr_2021_kB', 'AEDR_count', 'AEDR_mean', 'Distance_k', 'Azimuth', 'r2020B01', 'r2020B02', 'r2020B03', 'r2020B04', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11', 'r2020B12', 'r2020B13', 'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Ln_Gs_cub_m', 'Ln_M_stem_kg_m2', 'Ln_M_stem_bark_kg_m2', 'Ln_M_crown_kg_m2', 'Ln_M_foliage_kg_m2', 'Ln_M_AG_kg_m2', 'Ln_Cs_wood', 'Ln_Sr_wood', 'Ln_Tag_Cs', 'Ln_Tag_Sr', 'r2020B01', 'r2020B02', 'r2020B03', 'r2020B04', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11', 'r2020B12'])
            


# Show the first five columns
select.head()
# Out:
#    Ln_Gs_cub_m  Ln_M_stem_kg_m2  Ln_M_stem_bark_kg_m2  Ln_M_crown_kg_m2  \
# 0         4.81             1.76                 -0.31             -0.16
# 1         5.76             2.46                 -0.25              0.34
# 2         5.85             2.52                 -0.11              0.55
# 3         5.75             2.63                 -0.08              0.39
# 4         5.95             2.67                  0.00              0.57
#
#    Ln_M_foliage_kg_m2  Ln_M_AG_kg_m2  Ln_Cs_wood  Ln_Sr_wood  Ln_Tag_Cs  \
# 0               -2.44           1.91         6.8         9.2       -0.7
# 1               -0.20           2.63         8.2         9.6        0.6
# 2               -0.21           2.70         8.4         9.6        0.8
# 3               -0.35           2.78         8.1         9.4        0.5
# 4               -0.37           2.83         7.7         9.4        0.2
#
#    Ln_Tag_Sr  ...  r2020B03  r2020B04  r2020B05  r2020B06  r2020B07  r2020B08  \
# 0        2.6  ...  0.028616  0.254417  0.175280  0.086611  0.797761 -0.749311
# 1        2.9  ...  0.022230  0.189826  0.092225  0.047120  0.789129 -0.705355
# 2        2.9  ...  0.021190  0.204363  0.093062  0.043824  0.812120 -0.704758
# 3        2.7  ...  0.025284  0.187998  0.102872  0.048585  0.762431 -0.695416
# 4        2.8  ...  0.024911  0.216271  0.096981  0.044880  0.793606 -0.717562
#
#    r2020B09   r2020B10   r2020B11  r2020B12
# 0  0.491270 -15.527246 -11.385074  0.733806
# 1  0.659775 -16.547673 -10.947565  0.661723
# 2  0.631348 -14.341917 -11.884799  0.829603
# 3  0.601894 -14.885610 -11.725163  0.787609
# 4  0.642942 -14.647913 -11.512282  0.785698
#
# [5 rows x 22 columns]

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ln_Gs_cub_m           198 non-null    float64
#  1   Ln_M_stem_kg_m2       198 non-null    float64
#  2   Ln_M_stem_bark_kg_m2  198 non-null    float64
#  3   Ln_M_crown_kg_m2      198 non-null    float64
#  4   Ln_M_foliage_kg_m2    198 non-null    float64
#  5   Ln_M_AG_kg_m2         198 non-null    float64
#  6   Ln_Cs_wood            198 non-null    float64
#  7   Ln_Sr_wood            198 non-null    float64
#  8   Ln_Tag_Cs             198 non-null    float64
#  9   Ln_Tag_Sr             198 non-null    float64
#  10  r2020B01              198 non-null    float64
#  11  r2020B02              198 non-null    float64
#  12  r2020B03              198 non-null    float64
#  13  r2020B04              198 non-null    float64
#  14  r2020B05              198 non-null    float64
#  15  r2020B06              198 non-null    float64
#  16  r2020B07              198 non-null    float64
#  17  r2020B08              198 non-null    float64
#  18  r2020B09              198 non-null    float64
#  19  r2020B10              198 non-null    float64
#  20  r2020B11              198 non-null    float64
#  21  r2020B12              198 non-null    float64
# dtypes: float64(22)
# memory usage: 34.2 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_s"])["f_Gs_cub_m", "f_M_stem_kg_m2"].describe()
# Out:
# /tmp/ipykernel_65390/4147815954.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Dominant_s"])["f_Gs_cub_m", "f_M_stem_kg_m2"].describe()
#            f_Gs_cub_m                                                      \
#                 count        mean         std    min    25%    50%    75%
# Dominant_s
# Alder            13.0  393.153846  113.795757  199.0  311.0  434.0  462.0
# Aspen             7.0  241.571429  134.878782  121.0  147.0  194.0  321.0
# Birch            45.0  164.622222   83.668254   11.0  107.0  157.0  222.0
# Oak               9.0  199.777778   88.192655   79.0  112.0  220.0  255.0
# Pine            123.0  304.699187  185.582068    2.0  150.5  319.0  457.5
# Spruce            1.0  619.000000         NaN  619.0  619.0  619.0  619.0
#
#                   f_M_stem_kg_m2                                             \
#               max          count       mean       std    min     25%    50%
# Dominant_s
# Alder       558.0           13.0  16.823846  4.334304   9.90  13.560  16.96
# Aspen       440.0            7.0  11.862857  7.997334   4.64   6.470   9.79
# Birch       346.0           45.0   8.030444  4.090891   0.84   4.960   7.75
# Oak         313.0            9.0  10.728889  4.976167   3.59   5.870  11.72
# Pine        671.0          123.0  11.991789  7.094609   0.05   6.285  12.37
# Spruce      619.0            1.0  23.830000       NaN  23.83  23.830  23.83
#
#
#                75%    max
# Dominant_s
# Alder       20.130  24.29
# Aspen       14.810  26.05
# Birch       10.990  17.00
# Oak         13.590  18.99
# Pine        17.645  25.37
# Spruce      23.830  23.83

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Ln_Gs_cub_m  Ln_M_stem_kg_m2  Ln_M_stem_bark_kg_m2  Ln_M_crown_kg_m2  \
# count   198.000000       198.000000            198.000000        198.000000
# mean      5.234646         2.081717             -0.039242          0.171313
# std       1.129652         1.126519              0.789675          0.588506
# min       0.690000        -3.000000             -3.910000         -1.560000
# 25%       4.960000         1.812500             -0.190000         -0.025000
# 50%       5.510000         2.420000              0.060000          0.310000
# 75%       5.987500         2.807500              0.387500          0.530000
# max       6.510000         3.260000              1.650000          1.410000
#
#        Ln_M_foliage_kg_m2  Ln_M_AG_kg_m2  Ln_Cs_wood  Ln_Sr_wood   Ln_Tag_Cs  \
# count          198.000000     198.000000  198.000000  198.000000  198.000000
# mean            -0.953081       2.305758    6.052020    7.395960   -0.566667
# std              0.719719       0.931192    2.089707    2.070848    1.250989
# min             -2.920000      -0.800000    1.600000    2.400000   -4.700000
# 25%             -1.525000       2.052500    4.300000    5.800000   -1.300000
# 50%             -0.690000       2.580000    6.400000    7.600000   -0.500000
# 75%             -0.360000       2.937500    7.400000    8.800000    0.400000
# max              0.110000       3.390000   11.400000   13.900000    1.700000
#
#         Ln_Tag_Sr  ...    r2020B03    r2020B04    r2020B05    r2020B06  \
# count  198.000000  ...  198.000000  198.000000  198.000000  198.000000
# mean     2.342424  ...    0.027499    0.213645    0.125537    0.063662
# std      0.939283  ...    0.009532    0.042641    0.035475    0.023731
# min     -0.300000  ...    0.014640    0.124161    0.079896    0.036570
# 25%      1.700000  ...    0.022284    0.187070    0.095832    0.046290
# 50%      2.500000  ...    0.024743    0.204261    0.115558    0.058209
# 75%      3.000000  ...    0.028527    0.236440    0.150857    0.072122
# max      4.700000  ...    0.080615    0.369338    0.243667    0.187427
#
#          r2020B07    r2020B08    r2020B09    r2020B10    r2020B11    r2020B12
# count  198.000000  198.000000  198.000000  198.000000  198.000000  198.000000
# mean     0.767194   -0.703079    0.540963  -16.145709  -10.863669    0.675418
# std      0.078273    0.060738    0.132304    1.343250    1.161017    0.069250
# min      0.381333   -0.823403    0.038198  -22.517731  -14.262763    0.492975
# 25%      0.745438   -0.735205    0.502225  -16.970102  -11.519514    0.628884
# 50%      0.784239   -0.704881    0.577675  -16.010171  -10.784612    0.667561
# 75%      0.808780   -0.680539    0.632284  -15.159997  -10.008004    0.720595
# max      0.885319   -0.410944    0.710583  -13.281957   -7.650135    0.860863
#
# [8 rows x 22 columns]

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['r2020B01', 'r2020B02', 'r2020B03', 'r2020B04', 'r2020B05', 'r2020B06', 'r2020B07', 'r2020B08', 'r2020B09', 'r2020B10', 'r2020B11', 'r2020B12'])
y = pd.DataFrame(select, columns= ['Ln_Tag_Cs'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): Yes
# Selected "Yes"!!! A new column with random values was created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    r2020B01  r2020B02  r2020B03  r2020B04  r2020B05  r2020B06  r2020B07  \
# 0  0.019397  0.035344  0.028616  0.254417  0.175280  0.086611  0.797761
# 1  0.019167  0.033537  0.022230  0.189826  0.092225  0.047120  0.789129
# 2  0.019568  0.035957  0.021190  0.204363  0.093062  0.043824  0.812120
# 3  0.020556  0.033868  0.025284  0.187998  0.102872  0.048585  0.762431
# 4  0.019003  0.036153  0.024911  0.216271  0.096981  0.044880  0.793606
#
#    r2020B08  r2020B09   r2020B10   r2020B11  r2020B12   Random1    Random2  \
# 0 -0.749311  0.491270 -15.527246 -11.385074  0.733806  9.515847  10.556638
# 1 -0.705355  0.659775 -16.547673 -10.947565  0.661723  6.641196  11.109696
# 2 -0.704758  0.631348 -14.341917 -11.884799  0.829603  9.133153   9.454157
# 3 -0.695416  0.601894 -14.885610 -11.725163  0.787609  7.383897   8.913101
# 4 -0.717562  0.642942 -14.647913 -11.512282  0.785698  8.145767  11.030491
#
#      Random3    Random4    Random5
# 0   7.721285   9.817326   8.186003
# 1  12.766873  11.740616   9.412334
# 2  12.355118   6.788709   9.724785
# 3   9.256466  12.249604   9.949343
# 4  10.155532   7.480789  10.198235

# %%
# Columns in "y" data collections
y.head()
# Out:
#    Ln_Tag_Cs
# 0       -0.7
# 1        0.6
# 2        0.8
# 3        0.5
# 4        0.2

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.19255616005224852, -0.3841971513820921, 0.11667857778238222]
#     Mean: -0.025
#     Std: 0.256
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.31699966 1.29820642 1.23599847]
#     Mean: 1.284
#     Std: 0.035
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.9891909105759679, 1.1506592743776063, 0.8014503114489896]
#     Mean: 0.980
#     Std: 0.143
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=30, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Model with rank: 1
# Mean validation score: -0.352 (std: 0.372)
# Parameters: {'colsample_bytree': 0.5249847999101293, 'gamma': 0.14640724059354632, 'learning_rate': 0.010237149347074894, 'max_depth': 3, 'n_estimators': 142, 'subsample': 0.47038852303159023}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.19663105, 0.1132905 , 0.10970736, 0.3095191 , 0.43723068,
#        0.40288506, 0.27061186, 0.15366106, 0.18880777, 0.1326726 ,
#        0.14278097, 0.14472494, 0.30336356, 0.48110232, 0.57272868,
#        0.21611471, 0.38990302, 0.14366946, 0.09532318, 0.24296355,
#        0.11721034, 0.18650064, 0.44961209, 0.37695422, 0.36857028,
#        0.22559905, 0.17369223, 0.68714309, 0.60343781, 0.33941269]), 'std_fit_time': array([0.11192042, 0.00613853, 0.00404735, 0.01560825, 0.15662407,
#        0.14306825, 0.00372912, 0.00443869, 0.00458071, 0.0054287 ,
#        0.04915596, 0.00893883, 0.0506326 , 0.12540898, 0.18311749,
#        0.08892522, 0.18948767, 0.04487473, 0.0043787 , 0.01398509,
#        0.01950477, 0.00320207, 0.13111848, 0.08378345, 0.12828346,
#        0.04047813, 0.01883933, 0.13039016, 0.15124552, 0.16609972]), 'mean_score_time': array([0.00493355, 0.00472078, 0.0046597 , 0.00527749, 0.0049015 ,
#        0.00479841, 0.00467691, 0.00472503, 0.00452619, 0.00458627,
#        0.00610738, 0.0046648 , 0.00524621, 0.00487781, 0.0048069 ,
#        0.00497684, 0.00516505, 0.00599322, 0.00449896, 0.00477738,
#        0.00491467, 0.00475197, 0.00642805, 0.0049912 , 0.00698776,
#        0.00730958, 0.00489411, 0.01128607, 0.00718813, 0.00500031]), 'std_score_time': array([2.28674586e-04, 1.39807533e-04, 9.48697935e-05, 7.44052041e-04,
#        1.54334562e-04, 8.01050946e-05, 3.94686386e-05, 1.66923071e-04,

#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.4045089922218873, 0.40802191179443575,
#                    0.6794503816937079, 0.4917637745575348,
#                    0.9120691747331893, 0.7404486853319046,
#                    0.7770724162299896, 0.9364859164174251,
#                    0.410691478626399, 0.6294463724732489,
#                    0.7252855813331633, 0.5333381460947125,
#                    0.47038852303159023, 0.4998085460019538,
#                    0.5467657645620869, 0.9427273383754313,
#                    0.5523716944470691, 0.37104064624961963,
#                    0.370206941857202, 0.9182728345148001,
#                    0.5431884649893388, 0.9884004092204008,
#                    0.9311867963581133, 0.3938795592371508,
#                    0.7233415728805959, 0.6126369118706618,
#                    0.6503831072173435, 0.6241334565684945,
#                    0.6387214242936456, 0.6715881762240189],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.7206789484886941, 'gamma': 0.00260588817607299, 'learning_rate': 0.07708153119085254, 'max_depth': 3, 'n_estimators': 66, 'subsample': 0.4045089922218873}, {'colsample_bytree': 0.4402600230251608, 'gamma': 0.019123209554365694, 'learning_rate': 0.30659955664697586, 'max_depth': 2, 'n_estimators': 61, 'subsample': 0.40802191179443575}, {'colsample_bytree': 0.3133152386477042, 'gamma': 0.168738433337684, 'learning_rate': 0.09269584598593911, 'max_depth': 2, 'n_estimators': 61, 'subsample': 0.6794503816937079}, {'colsample_bytree': 0.4099634084427884, 'gamma': 0.00661886144009266, 'learning_rate': 0.293058619253173, 'max_depth': 2, 'n_estimators': 172, 'subsample': 0.4917637745575348}, {'colsample_bytree': 0.754925338306735, 'gamma': 0.283085829820326, 'learning_rate': 0.08368790619189218, 'max_depth': 4, 'n_estimators': 198, 'subsample': 0.9120691747331893}, {'colsample_bytree': 0.8985692708100653, 'gamma': 0.04350033801780179, 'learning_rate': 0.08050948991987472, 'max_depth': 3, 'n_estimators': 167, 'subsample': 0.7404486853319046}, {'colsample_bytree': 0.43392343711475406, 'gamma': 0.34886931824757983, 'learning_rate': 0.029065191474473707, 'max_depth': 2, 'n_estimators': 164, 'subsample': 0.7770724162299896}, {'colsample_bytree': 0.6949377902195797, 'gamma': 0.35300629886284446, 'learning_rate': 0.239747360317747, 'max_depth': 2, 'n_estimators': 86, 'subsample': 0.9364859164174251}, {'colsample_bytree': 0.3451387959924707, 'gamma': 0.4324920365638726, 'learning_rate': 0.21061145545113313, 'max_depth': 2, 'n_estimators': 112, 'subsample': 0.410691478626399}, {'colsample_bytree': 0.11067456050713143, 'gamma': 0.37894377161534226, 'learning_rate': 0.23144414702058966, 'max_depth': 3, 'n_estimators': 73, 'subsample': 0.6294463724732489}, {'colsample_bytree': 0.37539410018184005, 'gamma': 0.044276453308111696, 'learning_rate': 0.2310374087325446, 'max_depth': 4, 'n_estimators': 51, 'subsample': 0.7252855813331633}, {'colsample_bytree': 0.17689166232698433, 'gamma': 0.18359184157216452, 'learning_rate': 0.12672694208813348, 'max_depth': 2, 'n_estimators': 80, 'subsample': 0.5333381460947125}, {'colsample_bytree': 0.5249847999101293, 'gamma': 0.14640724059354632, 'learning_rate': 0.010237149347074894, 'max_depth': 3, 'n_estimators': 142, 'subsample': 
#        0.98338032, 0.84092519, 0.98414517, 0.9705991 , 0.96463473]), 'split2_train_score': array([0.7800903 , 0.83915783, 0.63769116, 0.98795953, 0.97993742,
#        0.97975304, 0.61960386, 0.93235112, 0.90309049, 0.90432334,
#        0.9895045 , 0.72992638, 0.3781207 , 0.85283889, 0.97412785,
#        0.52810341, 0.99112005, 0.94303998, 0.38972864, 0.9266272 ,
#        0.54707192, 0.79577333, 0.78587649, 0.97466827, 0.51473227,
#        0.98193678, 0.85385753, 0.98232303, 0.97252512, 0.96692987]), 'split3_train_score': array([0.78261367, 0.84357343, 0.61649657, 0.98773389, 0.9741319 ,
#        0.97509982, 0.6076958 , 0.9171724 , 0.89510249, 0.89632999,
#        0.98890104, 0.72061562, 0.39781519, 0.83854477, 0.97152002,
#        0.4816136 , 0.98703009, 0.93654438, 0.40572162, 0.9253805 ,
#        0.57186553, 0.79457247, 0.77794525, 0.97102047, 0.53024838,
#        0.97779911, 0.84433863, 0.97910072, 0.96657447, 0.95949442]), 'split4_train_score': array([0.74516199, 0.7975409 , 0.57690404, 0.98503958, 0.97108585,
#        0.97289287, 0.56447939, 0.90527135, 0.88698035, 0.89146615,
#        0.98516684, 0.68573097, 0.35961176, 0.83467994, 0.96868067,
#        0.4523456 , 0.98904996, 0.93019341, 0.31461985, 0.91413951,
#        0.54615306, 0.75465719, 0.73747483, 0.96696241, 0.49475559,
#        0.98047859, 0.82448855, 0.97987849, 0.96426952, 0.95776305]), 'mean_train_score': array([0.7622545 , 0.83645324, 0.60700563, 0.98664397, 0.97646331,
#        0.97786862, 0.59468476, 0.91669165, 0.8944898 , 0.89236577,
#        0.98860127, 0.71466442, 0.37302992, 0.84246975, 0.97292006,
#        0.49346571, 0.9894796 , 0.9409813 , 0.36698887, 0.92507243,
#        0.55734995, 0.77223326, 0.76761073, 0.97232612, 0.50513968,
#        0.98156324, 0.84015781, 0.98196357, 0.96965065, 0.96306168]), 'std_train_score': array([0.01579666, 0.02039078, 0.02060675, 0.00115604, 0.00349907,
#        0.00357967, 0.01924921, 0.00880831, 0.00552671, 0.0112104 ,
#        0.00175051, 0.01527574, 0.01382543, 0.00629514, 0.00272529,
#        0.02652311, 0.00145865, 0.0067595 , 0.03116511, 0.00706226,
#        0.00977282, 0.020452  , 0.01704004, 0.00323577, 0.01640923,
#        0.00227387, 0.00959321, 0.00215523, 0.00371642, 0.00374076])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.5249847999101293
# Gamma: 0.14640724059354632
# Learning_rate: 0.010237149347074894
# Max_depth: 3
# N_estimators: 142
# Subsample: 0.47038852303159023

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(30):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:1.64471	validation_1-rmse:1.58622
# [1]	validation_0-rmse:1.63729	validation_1-rmse:1.57654
# [2]	validation_0-rmse:1.62975	validation_1-rmse:1.56934
# [3]	validation_0-rmse:1.62070	validation_1-rmse:1.56042
# [4]	validation_0-rmse:1.61272	validation_1-rmse:1.55180
# [5]	validation_0-rmse:1.60464	validation_1-rmse:1.54498
# [6]	validation_0-rmse:1.59597	validation_1-rmse:1.53647
# [7]	validation_0-rmse:1.58645	validation_1-rmse:1.52816
# [8]	validation_0-rmse:1.57909	validation_1-rmse:1.52196
# [9]	validation_0-rmse:1.57089	validation_1-rmse:1.51551
# [10]	validation_0-rmse:1.56343	validation_1-rmse:1.50877
# [11]	validation_0-rmse:1.55511	validation_1-rmse:1.49996
# [12]	validation_0-rmse:1.54660	validation_1-rmse:1.49277
# [13]	validation_0-rmse:1.53927	validation_1-rmse:1.48641
# [14]	validation_0-rmse:1.53084	validation_1-rmse:1.47984
# [15]	validation_0-rmse:1.52336	validation_1-rmse:1.47474
# [16]	validation_0-rmse:1.51441	validation_1-rmse:1.46890
# [17]	validation_0-rmse:1.51086	validation_1-rmse:1.46454
# [18]	validation_0-rmse:1.50429	validation_1-rmse:1.46058
# [19]	validation_0-rmse:1.49867	validation_1-rmse:1.45510
# [20]	validation_0-rmse:1.49301	validation_1-rmse:1.44899
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
#
# [64]	validation_0-rmse:1.26074	validation_1-rmse:1.22944
# [65]	validation_0-rmse:1.25584	validation_1-rmse:1.22546
# [66]	validation_0-rmse:1.25125	validation_1-rmse:1.22173
# [67]	validation_0-rmse:1.24634	validation_1-rmse:1.22058
# [68]	validation_0-rmse:1.24188	validation_1-rmse:1.21833
# [69]	validation_0-rmse:1.23843	validation_1-rmse:1.21407
# [70]	validation_0-rmse:1.23420	validation_1-rmse:1.21259
# [71]	validation_0-rmse:1.23145	validation_1-rmse:1.20922
# [72]	validation_0-rmse:1.22689	validation_1-rmse:1.20533
# [73]	validation_0-rmse:1.22281	validation_1-rmse:1.19973
# [74]	validation_0-rmse:1.21953	validation_1-rmse:1.19795
# [75]	validation_0-rmse:1.21530	validation_1-rmse:1.19493
# [76]	validation_0-rmse:1.21191	validation_1-rmse:1.19271
# [77]	validation_0-rmse:1.20817	validation_1-rmse:1.18871
# [78]	validation_0-rmse:1.20450	validation_1-rmse:1.18553
# [79]	validation_0-rmse:1.20189	validation_1-rmse:1.18322
# [80]	validation_0-rmse:1.19713	validation_1-rmse:1.17850
# [81]	validation_0-rmse:1.19492	validation_1-rmse:1.17722
# [82]	validation_0-rmse:1.19179	validation_1-rmse:1.17620
# [83]	validation_0-rmse:1.18836	validation_1-rmse:1.17267
# [84]	validation_0-rmse:1.18462	validation_1-rmse:1.16720
# [85]	validation_0-rmse:1.18274	validation_1-rmse:1.16570
# [86]	validation_0-rmse:1.17945	validation_1-rmse:1.16392
# [87]	validation_0-rmse:1.17564	validation_1-rmse:1.15968
# [88]	validation_0-rmse:1.17210	validation_1-rmse:1.15668
# [89]	validation_0-rmse:1.16913	validation_1-rmse:1.15563
# [90]	validation_0-rmse:1.16580	validation_1-rmse:1.15414
# [91]	validation_0-rmse:1.16261	validation_1-rmse:1.15258
# [92]	validation_0-rmse:1.15946	validation_1-rmse:1.14966
# [93]	validation_0-rmse:1.15605	validation_1-rmse:1.14566
# [94]	validation_0-rmse:1.15335	validation_1-rmse:1.14426
# [95]	validation_0-rmse:1.15106	validation_1-rmse:1.14091
# [96]	validation_0-rmse:1.14778	validation_1-rmse:1.13982
# [97]	validation_0-rmse:1.14417	validation_1-rmse:1.13558
# [98]	validation_0-rmse:1.14178	validation_1-rmse:1.13787
# [99]	validation_0-rmse:1.13863	validation_1-rmse:1.13608
# [100]	validation_0-rmse:1.13506	validation_1-rmse:1.13322
# [101]	validation_0-rmse:1.13208	validation_1-rmse:1.13062
# [102]	validation_0-rmse:1.13015	validation_1-rmse:1.12805
# [103]	validation_0-rmse:1.12687	validation_1-rmse:1.12500
# [104]	validation_0-rmse:1.12402	validation_1-rmse:1.12258
# [105]	validation_0-rmse:1.12126	validation_1-rmse:1.12080
# [106]	validation_0-rmse:1.11823	validation_1-rmse:1.11787
# [107]	validation_0-rmse:1.11597	validation_1-rmse:1.11661
# [108]	validation_0-rmse:1.11342	validation_1-rmse:1.11487
# [109]	validation_0-rmse:1.11055	validation_1-rmse:1.11363
# [51]	validation_0-rmse:1.31604	validation_1-rmse:1.18307
# [52]	validation_0-rmse:1.30998	validation_1-rmse:1.18152
# [53]	validation_0-rmse:1.30472	validation_1-rmse:1.18060
# [54]	validation_0-rmse:1.30182	validation_1-rmse:1.17940
# [55]	validation_0-rmse:1.29601	validation_1-rmse:1.17715
# [56]	validation_0-rmse:1.29022	validation_1-rmse:1.17391
# [57]	validation_0-rmse:1.28598	validation_1-rmse:1.17434
# [58]	validation_0-rmse:1.27966	validation_1-rmse:1.17200
# [59]	validation_0-rmse:1.27458	validation_1-rmse:1.16984
# [60]	validation_0-rmse:1.26916	validation_1-rmse:1.16889
# [61]	validation_0-rmse:1.26329	validation_1-rmse:1.16777
# [62]	validation_0-rmse:1.25854	validation_1-rmse:1.16495
# [63]	validation_0-rmse:1.25473	validation_1-rmse:1.16338
# [64]	validation_0-rmse:1.25004	validation_1-rmse:1.16268
# [65]	validation_0-rmse:1.24479	validation_1-rmse:1.16079
# [66]	validation_0-rmse:1.23969	validation_1-rmse:1.16053
# [67]	validation_0-rmse:1.23482	validation_1-rmse:1.16157
# [68]	validation_0-rmse:1.23049	validation_1-rmse:1.16319
# [69]	validation_0-rmse:1.22528	validation_1-rmse:1.15976
# [70]	validation_0-rmse:1.22109	validation_1-rmse:1.15769
# [71]	validation_0-rmse:1.21638	validation_1-rmse:1.15571
# [72]	validation_0-rmse:1.21204	validation_1-rmse:1.15485
# [73]	validation_0-rmse:1.20890	validation_1-rmse:1.15403
# [74]	validation_0-rmse:1.20439	validation_1-rmse:1.15398
# [75]	validation_0-rmse:1.20241	validation_1-rmse:1.15297
# [76]	validation_0-rmse:1.19769	validation_1-rmse:1.15169
# [77]	validation_0-rmse:1.19433	validation_1-rmse:1.15111
# [78]	validation_0-rmse:1.18983	validation_1-rmse:1.15003
# [79]	validation_0-rmse:1.18624	validation_1-rmse:1.14916
# [80]	validation_0-rmse:1.18254	validation_1-rmse:1.14887
# [81]	validation_0-rmse:1.17856	validation_1-rmse:1.14534
# [82]	validation_0-rmse:1.17404	validation_1-rmse:1.14493
# [83]	validation_0-rmse:1.16996	validation_1-rmse:1.14475
# [84]	validation_0-rmse:1.16610	validation_1-rmse:1.14488
# [85]	validation_0-rmse:1.16121	validation_1-rmse:1.14518
# [86]	validation_0-rmse:1.15812	validation_1-rmse:1.14490
# [87]	validation_0-rmse:1.15433	validation_1-rmse:1.14375
# [88]	validation_0-rmse:1.15024	validation_1-rmse:1.14111
# [89]	validation_0-rmse:1.14633	validation_1-rmse:1.13983
# [90]	validation_0-rmse:1.14297	validation_1-rmse:1.13994
# [91]	validation_0-rmse:1.13844	validation_1-rmse:1.13754
# [92]	validation_0-rmse:1.13448	validation_1-rmse:1.13573
# [93]	validation_0-rmse:1.13059	validation_1-rmse:1.13493
# [94]	validation_0-rmse:1.12761	validation_1-rmse:1.13426
# [95]	validation_0-rmse:1.12386	validation_1-rmse:1.13356
# [96]	validation_0-rmse:1.12062	validation_1-rmse:1.13212
# [97]	validation_0-rmse:1.11777	validation_1-rmse:1.13194
# [98]	validation_0-rmse:1.11447	validation_1-rmse:1.13149
# [99]	validation_0-rmse:1.11181	validation_1-rmse:1.13179
# [100]	validation_0-rmse:1.10959	validation_1-rmse:1.13068
# [101]	validation_0-rmse:1.10633	validation_1-rmse:1.12936
# [102]	validation_0-rmse:1.10389	validation_1-rmse:1.12968
# [103]	validation_0-rmse:1.09985	validation_1-rmse:1.12958
# [104]	validation_0-rmse:1.09631	validation_1-rmse:1.12928
# [105]	validation_0-rmse:1.09450	validation_1-rmse:1.13030
# [106]	validation_0-rmse:1.09100	validation_1-rmse:1.13047
# [107]	validation_0-rmse:1.08822	validation_1-rmse:1.13127
# [108]	validation_0-rmse:1.08421	validation_1-rmse:1.13173
# [109]	validation_0-rmse:1.08160	validation_1-rmse:1.13183
# [110]	validation_0-rmse:1.07946	validation_1-rmse:1.13176
# [111]	validation_0-rmse:1.07667	validation_1-rmse:1.13098
# [112]	validation_0-rmse:1.07370	validation_1-rmse:1.13081
# [113]	validation_0-rmse:1.07146	validation_1-rmse:1.13020
# [114]	validation_0-rmse:1.06851	validation_1-rmse:1.12846
# [115]	validation_0-rmse:1.06523	validation_1-rmse:1.13139
# [116]	validation_0-rmse:1.06143	validation_1-rmse:1.12968
# [117]	validation_0-rmse:1.05825	validation_1-rmse:1.12877
# [118]	validation_0-rmse:1.05574	validation_1-rmse:1.12820
# [119]	validation_0-rmse:1.05323	validation_1-rmse:1.12750
# [120]	validation_0-rmse:1.05066	validation_1-rmse:1.12554
# [121]	validation_0-rmse:1.04773	validation_1-rmse:1.12693
# [122]	validation_0-rmse:1.04597	validation_1-rmse:1.12569
# [123]	validation_0-rmse:1.04280	validation_1-rmse:1.12496
# [124]	validation_0-rmse:1.04083	validation_1-rmse:1.12278
# [125]	validation_0-rmse:1.03822	validation_1-rmse:1.12133
# [126]	validation_0-rmse:1.03550	validation_1-rmse:1.12052
# [127]	validation_0-rmse:1.03197	validation_1-rmse:1.11982
# [128]	validation_0-rmse:1.02955	validation_1-rmse:1.11957
# [129]	validation_0-rmse:1.02793	validation_1-rmse:1.11798
# [130]	validation_0-rmse:1.02600	validation_1-rmse:1.11771
# [131]	validation_0-rmse:1.02491	validation_1-rmse:1.11807
# [132]	validation_0-rmse:1.02269	validation_1-rmse:1.11802
# [133]	validation_0-rmse:1.01988	validation_1-rmse:1.11892
# [134]	validation_0-rmse:1.01711	validation_1-rmse:1.11855
# [135]	validation_0-rmse:1.01585	validation_1-rmse:1.11826
# [136]	validation_0-rmse:1.01338	validation_1-rmse:1.11810
# [137]	validation_0-rmse:1.01009	validation_1-rmse:1.11730
# [138]	validation_0-rmse:1.00840	validation_1-rmse:1.11693
# [139]	validation_0-rmse:1.00578	validation_1-rmse:1.11706
# [140]	validation_0-rmse:1.00279	validation_1-rmse:1.11774
# [141]	validation_0-rmse:1.00067	validation_1-rmse:1.11664
# [0]	validation_0-rmse:1.65182	validation_1-rmse:1.55530
# [72]	validation_0-rmse:1.18131	validation_1-rmse:1.43886
# [73]	validation_0-rmse:1.17825	validation_1-rmse:1.43810
# [74]	validation_0-rmse:1.17360	validation_1-rmse:1.43533
# [75]	validation_0-rmse:1.16906	validation_1-rmse:1.43409
# [76]	validation_0-rmse:1.16395	validation_1-rmse:1.43054
# [77]	validation_0-rmse:1.16077	validation_1-rmse:1.42996
# [78]	validation_0-rmse:1.15690	validation_1-rmse:1.42740
# [79]	validation_0-rmse:1.15238	validation_1-rmse:1.42415
# [80]	validation_0-rmse:1.14833	validation_1-rmse:1.42253
# [81]	validation_0-rmse:1.14345	validation_1-rmse:1.42045
# [82]	validation_0-rmse:1.14083	validation_1-rmse:1.41977
# [83]	validation_0-rmse:1.13691	validation_1-rmse:1.41916
# [84]	validation_0-rmse:1.13340	validation_1-rmse:1.41975
# [85]	validation_0-rmse:1.13007	validation_1-rmse:1.41961
# [86]	validation_0-rmse:1.12674	validation_1-rmse:1.41831
# [87]	validation_0-rmse:1.12320	validation_1-rmse:1.41374
# [88]	validation_0-rmse:1.11954	validation_1-rmse:1.41195
# [89]	validation_0-rmse:1.11627	validation_1-rmse:1.40945
# [90]	validation_0-rmse:1.11218	validation_1-rmse:1.40714
# [91]	validation_0-rmse:1.10822	validation_1-rmse:1.40561
# [92]	validation_0-rmse:1.10410	validation_1-rmse:1.40404
# [93]	validation_0-rmse:1.10055	validation_1-rmse:1.40177
# [94]	validation_0-rmse:1.09630	validation_1-rmse:1.40039
# [95]	validation_0-rmse:1.09462	validation_1-rmse:1.40034
# [96]	validation_0-rmse:1.09162	validation_1-rmse:1.39964
# [97]	validation_0-rmse:1.08924	validation_1-rmse:1.40025
# [98]	validation_0-rmse:1.08630	validation_1-rmse:1.39931
# [99]	validation_0-rmse:1.08342	validation_1-rmse:1.39837
# [100]	validation_0-rmse:1.08030	validation_1-rmse:1.39730
# [101]	validation_0-rmse:1.07716	validation_1-rmse:1.39707
# [102]	validation_0-rmse:1.07410	validation_1-rmse:1.39706
# [103]	validation_0-rmse:1.07095	validation_1-rmse:1.39640
# [104]	validation_0-rmse:1.06781	validation_1-rmse:1.39421
# [105]	validation_0-rmse:1.06544	validation_1-rmse:1.39301
# [106]	validation_0-rmse:1.06241	validation_1-rmse:1.39353
# [107]	validation_0-rmse:1.06052	validation_1-rmse:1.39359
# [108]	validation_0-rmse:1.05819	validation_1-rmse:1.39332
# [109]	validation_0-rmse:1.05466	validation_1-rmse:1.39154
# [110]	validation_0-rmse:1.05033	validation_1-rmse:1.38917
# [111]	validation_0-rmse:1.04744	validation_1-rmse:1.38800
# [112]	validation_0-rmse:1.04446	validation_1-rmse:1.38735
# [113]	validation_0-rmse:1.04180	validation_1-rmse:1.38729
# [114]	validation_0-rmse:1.03880	validation_1-rmse:1.38754
# [115]	validation_0-rmse:1.03644	validation_1-rmse:1.38610
# [116]	validation_0-rmse:1.03436	validation_1-rmse:1.38457
# [117]	validation_0-rmse:1.03161	validation_1-rmse:1.38373
# [118]	validation_0-rmse:1.02972	validation_1-rmse:1.38342
# [119]	validation_0-rmse:1.02690	validation_1-rmse:1.38286
# [120]	validation_0-rmse:1.02384	validation_1-rmse:1.38226
# [121]	validation_0-rmse:1.02095	validation_1-rmse:1.38043
# [122]	validation_0-rmse:1.01885	validation_1-rmse:1.37866
# [123]	validation_0-rmse:1.01590	validation_1-rmse:1.37683
# [124]	validation_0-rmse:1.01397	validation_1-rmse:1.37611
# [125]	validation_0-rmse:1.01169	validation_1-rmse:1.37612
# [126]	validation_0-rmse:1.00959	validation_1-rmse:1.37618
# [127]	validation_0-rmse:1.00673	validation_1-rmse:1.37291
# [128]	validation_0-rmse:1.00374	validation_1-rmse:1.36990
# [129]	validation_0-rmse:1.00179	validation_1-rmse:1.37030
# [130]	validation_0-rmse:0.99938	validation_1-rmse:1.36825
# [131]	validation_0-rmse:0.99697	validation_1-rmse:1.36718
# [132]	validation_0-rmse:0.99577	validation_1-rmse:1.36663
# [133]	validation_0-rmse:0.99288	validation_1-rmse:1.36545
# [134]	validation_0-rmse:0.99156	validation_1-rmse:1.36512
# [135]	validation_0-rmse:0.99024	validation_1-rmse:1.36503
# [136]	validation_0-rmse:0.98800	validation_1-rmse:1.36529
# [137]	validation_0-rmse:0.98625	validation_1-rmse:1.36453
# [138]	validation_0-rmse:0.98428	validation_1-rmse:1.36555
# [139]	validation_0-rmse:0.98279	validation_1-rmse:1.36274
# [140]	validation_0-rmse:0.98018	validation_1-rmse:1.36276
# [141]	validation_0-rmse:0.97771	validation_1-rmse:1.36254
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 137.933, median: 140.0,
#  pred. interval (P(0.025)-P(0.975)): 114.475-141.0,
#  conf. interval (p-value=0.95): 139.368-140.316
# ***
# Aggregate bias statistic:
#  mean: 11.675, median: 12.098,
#  pred. interval (P(0.025)-P(0.975)): 0.88-23.806,
#  conf. interval (p-value=0.95): 10.211-13.637
# ***
# Aggregate RMSE statistic:
#  mean: 1.19, median: 1.18, pred. interval (P(0.025)-P(0.975)): 1.038-1.393,
#  conf. interval (p-value=0.95): 1.154-1.212
# ***
# Aggregate MSE statistic:
#  mean: 1.426, median: 1.392, pred. interval (P(0.025)-P(0.975)): 1.079-1.942,
#  conf. interval (p-value=0.95): 1.334-1.471
# ***
# Aggregate R^2 statistic:
#  mean: 0.009, median: 0.012, pred. interval (P(0.025)-P(0.975)): -0.197-0.114,
#  conf. interval (p-value=0.95): -0.012-0.04
# ***
# Aggregate bias(%) statistic:
#  mean: -18.753, median: 12.098, pred. interval (P(0.025)-P(0.975)): -29.276--4.231,
#  conf. interval (p-value=0.95): -21.787--17.756
# ***
# Aggregate RMSE(%) statistic:
#  mean: -2.363, median: -1.949, pred. interval (P(0.025)-P(0.975)): -6.457--1.472,
#  conf. interval (p-value=0.95): -2.151--1.889
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.63336
# [1]	validation_0-rmse:1.62580
# [2]	validation_0-rmse:1.61694
# [3]	validation_0-rmse:1.60880
# [4]	validation_0-rmse:1.60165
# [5]	validation_0-rmse:1.59342
# [6]	validation_0-rmse:1.58467
# [7]	validation_0-rmse:1.57684
# [8]	validation_0-rmse:1.56956
# [9]	validation_0-rmse:1.56080
# [10]	validation_0-rmse:1.55235
# [11]	validation_0-rmse:1.54316
# [12]	validation_0-rmse:1.53571
# [13]	validation_0-rmse:1.52885
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
#
# [88]	validation_0-rmse:1.14342
# [89]	validation_0-rmse:1.13968
# [90]	validation_0-rmse:1.13500
# [91]	validation_0-rmse:1.13160
# [92]	validation_0-rmse:1.12886
# [93]	validation_0-rmse:1.12560
# [94]	validation_0-rmse:1.12188
# [95]	validation_0-rmse:1.11966
# [96]	validation_0-rmse:1.11723
# [97]	validation_0-rmse:1.11464
# [98]	validation_0-rmse:1.11231
# [99]	validation_0-rmse:1.10832
# [100]	validation_0-rmse:1.10591
# [101]	validation_0-rmse:1.10358
# [102]	validation_0-rmse:1.10088
# [103]	validation_0-rmse:1.09850
# [104]	validation_0-rmse:1.09492
# [105]	validation_0-rmse:1.09197
# [106]	validation_0-rmse:1.08863
# [107]	validation_0-rmse:1.08575
# [108]	validation_0-rmse:1.08274
# [109]	validation_0-rmse:1.08042
# [110]	validation_0-rmse:1.07728
# [111]	validation_0-rmse:1.07530
# [112]	validation_0-rmse:1.07386
# [113]	validation_0-rmse:1.06963
# [114]	validation_0-rmse:1.06647
# [115]	validation_0-rmse:1.06406
# [116]	validation_0-rmse:1.06143
# [117]	validation_0-rmse:1.05959
# [118]	validation_0-rmse:1.05732
# [119]	validation_0-rmse:1.05471
# [120]	validation_0-rmse:1.05236
# [121]	validation_0-rmse:1.04886
# [122]	validation_0-rmse:1.04705
# [123]	validation_0-rmse:1.04470
# [124]	validation_0-rmse:1.04155
# [125]	validation_0-rmse:1.03889
# [126]	validation_0-rmse:1.03640
# [127]	validation_0-rmse:1.03485
# [128]	validation_0-rmse:1.03281
# [129]	validation_0-rmse:1.03057
# [130]	validation_0-rmse:1.02744
# [131]	validation_0-rmse:1.02423
# [132]	validation_0-rmse:1.02222
# [133]	validation_0-rmse:1.02126
# [134]	validation_0-rmse:1.01920
# [135]	validation_0-rmse:1.01672
# [136]	validation_0-rmse:1.01419
# [137]	validation_0-rmse:1.01175
# [138]	validation_0-rmse:1.00928
# [139]	validation_0-rmse:1.00727
# [140]	validation_0-rmse:1.00611
# [141]	validation_0-rmse:1.00332
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 141

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.3
# Relative bias(%):  -94.29
# RMSE: 1.0
# Relative RMSE(%):  -1.771
# MSE: 1.0
# R square: 35.4%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: -0.158
# a1: 0.245
# R^2: 0.673
# Uncertainty
# a0: -0.158+/-0.017
# a1: 0.245+/-0.012

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=1) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/WORK/GIS and ML algoritms/6_Est_RN&biomass_all_site_Sentinel/2020/Nootbooks/.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/WORK/GIS and ML algoritms/6_Est_RN&biomass_all_site_Sentinel/2020/Nootbooks/.txt")
