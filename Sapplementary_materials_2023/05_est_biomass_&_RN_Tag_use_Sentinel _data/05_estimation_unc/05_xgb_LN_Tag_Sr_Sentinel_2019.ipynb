# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../05_input_data/Sites_with_Sentinel_bands_data.xlsx'
df = pd.read_excel(site_data, sheet_name='input_2019')
df.head()
# Out:
#   Site # Origin Dominant_s  LN_GS_cub_m  LN_M_stem_kg_m2  \
# 0      1      n      Birch        4.771            1.792
# 1      2      a       Pine        5.808            2.496
# 2      3      a       Pine        5.796            2.546
# 3      4      a       Pine        5.826            2.643
# 4      5      a       Pine        6.059            2.643
#
#    LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  LN_M_foliage_kg_m2  LN_M_AG_kg_m2  \
# 0                -0.211            -0.261              -2.040          1.932
# 1                -0.073             0.392              -0.139          2.674
# 2                 0.030             0.501              -0.030          2.734
# 3                 0.000             0.419              -0.431          2.785
# 4                 0.122             0.647              -0.386          2.809
#
#         X_N36  ...  r2019B03  r2019B04  r2019B05  r2019B06  r2019B07  \
# 0  298987.203  ...  0.030628  0.266210  0.166299  0.081316  0.793351
# 1  299016.572  ...  0.027934  0.183349  0.102656  0.052144  0.735493
# 2  299072.773  ...  0.026123  0.184066  0.099625  0.050684  0.751436
# 3  299152.693  ...  0.027390  0.177221  0.102540  0.052198  0.732404
# 4  299249.689  ...  0.025702  0.183705  0.101394  0.050437  0.754481
#
#    r2019B08  r2019B09   r2019B10   r2019B11  r2019B12
# 0 -0.733693  0.532051 -15.396488 -11.262037  0.731937
# 1 -0.655456  0.557000 -16.012156  -9.364664  0.584920
# 2 -0.650575  0.568148 -13.609903  -9.726108  0.715177
# 3 -0.648310  0.544717 -14.321650 -10.457536  0.730390
# 4 -0.660382  0.569112 -13.934375 -11.393335  0.817430
#
# [5 rows x 34 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Site #', 'Origin', 'Dominant_s', 'LN_GS_cub_m', 'LN_M_stem_kg_m2', 'LN_M_stem_bark_kg_m2', 'LN_M_crown_kg_m2', 'LN_M_foliage_kg_m2', 'LN_M_AG_kg_m2', 'F_Soil', 'M_Soil', 'X_N36', 'Y_N36', 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'LN_Cs_wood', 'LN_Sr_wood', 'Tag_Cs', 'Tag_Sr', 'LN_Tag_Cs', 'LN_Tag_Sr', 'Cs_2021_kB', 'Sr_2021_kB', 'AEDR_mean', 'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['LN_GS_cub_m', 'LN_M_stem_kg_m2', 'LN_M_stem_bark_kg_m2', 'LN_M_crown_kg_m2', 'LN_M_foliage_kg_m2', 'LN_M_AG_kg_m2', 'LN_Tag_Cs', 'LN_Tag_Sr',
                                  'r2019B01', 'r2019B02', 'r2019B03', 'r2019B04', 'r2019B05', 'r2019B06', 'r2019B07', 'r2019B08', 'r2019B09', 'r2019B10', 'r2019B11', 'r2019B12'])

# Show the first five columns
select.head()
# Out:
#    LN_GS_cub_m  LN_M_stem_kg_m2  LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  \
# 0        4.771            1.792                -0.211            -0.261
# 1        5.808            2.496                -0.073             0.392
# 2        5.796            2.546                 0.030             0.501
# 3        5.826            2.643                 0.000             0.419
# 4        6.059            2.643                 0.122             0.647
#
#    LN_M_foliage_kg_m2  LN_M_AG_kg_m2  LN_Tag_Cs  LN_Tag_Sr  r2019B01  \
# 0              -2.040          1.932      -0.73       2.58  0.025483
# 1              -0.139          2.674       0.59       2.92  0.024075
# 2              -0.030          2.734       0.78       2.88  0.022492
# 3              -0.431          2.785       0.52       2.72  0.023742
# 4              -0.386          2.809       0.22       2.83  0.022916
#
#    r2019B02  r2019B03  r2019B04  r2019B05  r2019B06  r2019B07  r2019B08  \
# 0  0.040910  0.030628  0.266210  0.166299  0.081316  0.793351 -0.733693
# 1  0.038164  0.027934  0.183349  0.102656  0.052144  0.735493 -0.655456
# 2  0.038968  0.026123  0.184066  0.099625  0.050684  0.751436 -0.650575
# 3  0.037811  0.027390  0.177221  0.102540  0.052198  0.732404 -0.648310
# 4  0.037557  0.025702  0.183705  0.101394  0.050437  0.754481 -0.660382
#
#    r2019B09   r2019B10   r2019B11  r2019B12
# 0  0.532051 -15.396488 -11.262037  0.731937
# 1  0.557000 -16.012156  -9.364664  0.584920
# 2  0.568148 -13.609903  -9.726108  0.715177
# 3  0.544717 -14.321650 -10.457536  0.730390
# 4  0.569112 -13.934375 -11.393335  0.817430

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   LN_GS_cub_m           205 non-null    float64
#  1   LN_M_stem_kg_m2       205 non-null    float64
#  2   LN_M_stem_bark_kg_m2  205 non-null    float64
#  3   LN_M_crown_kg_m2      205 non-null    float64
#  4   LN_M_foliage_kg_m2    205 non-null    float64
#  5   LN_M_AG_kg_m2         205 non-null    float64
#  6   LN_Tag_Cs             205 non-null    float64
#  7   LN_Tag_Sr             205 non-null    float64
#  8   r2019B01              205 non-null    float64
#  9   r2019B02              205 non-null    float64
#  10  r2019B03              205 non-null    float64
#  11  r2019B04              205 non-null    float64
#  12  r2019B05              205 non-null    float64
#  13  r2019B06              205 non-null    float64
#  14  r2019B07              205 non-null    float64
#  15  r2019B08              205 non-null    float64
#  16  r2019B09              205 non-null    float64
#  17  r2019B10              205 non-null    float64
#  18  r2019B11              205 non-null    float64
#  19  r2019B12              205 non-null    float64
# dtypes: float64(20)
# memory usage: 32.2 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_s"])["LN_Tag_Cs", "LN_Tag_Sr"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            LN_Tag_Cs                                                        \
#                count      mean       std   min     25%   50%     75%   max
# Dominant_s
# Alder           13.0 -0.620769  1.079293 -2.05 -1.4100 -0.89  0.6000  1.11
# Aspen            7.0 -0.957143  1.537441 -2.44 -2.1250 -1.39 -0.0850  1.55
# Birch           45.0 -1.003778  1.084287 -4.11 -1.3300 -0.75 -0.2400  0.44
# Oak              9.0 -0.385556  1.633486 -3.73 -1.1000  0.61  0.7000  1.34
# Pine           130.0 -0.469923  1.290716 -4.68 -1.3175 -0.05  0.4675  1.65
# Spruce           1.0 -2.410000       NaN -2.41 -2.4100 -2.41 -2.4100 -2.41
#
#            LN_Tag_Sr
#                count      mean       std   min    25%   50%     75%   max
# Dominant_s
# Alder           13.0  1.115385  0.640971 -0.17  0.520  1.34  1.5400  1.79
# Aspen            7.0  2.920000  0.662319  1.96  2.450  3.16  3.3200  3.78
# Birch           45.0  2.346889  0.850954 -0.25  2.000  2.47  2.6600  4.66
# Oak              9.0  1.760000  1.032945  0.55  1.000  1.47  2.8100  3.33
# Pine           130.0  2.423462  0.925829 -0.09  1.805  2.59  3.1425  4.30
# Spruce           1.0  1.810000       NaN  1.81  1.810  1.81  1.8100  1.81

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        LN_GS_cub_m  LN_M_stem_kg_m2  LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  \
# count   205.000000       205.000000            205.000000        205.000000
# mean      5.226868         2.098585             -0.124595          0.077888
# std       1.088124         1.036242              0.780555          0.704301
# min       1.609000        -1.347000             -2.659000         -2.408000
# 25%       4.875000         1.783000             -0.315000         -0.151000
# 50%       5.501000         2.408000              0.039000          0.285000
# 75%       5.971000         2.788000              0.315000          0.531000
# max       6.457000         3.428000              1.384000          1.756000
#
#        LN_M_foliage_kg_m2  LN_M_AG_kg_m2   LN_Tag_Cs   LN_Tag_Sr    r2019B01  \
# count          205.000000     205.000000  205.000000  205.000000  205.000000
# mean            -0.960395       2.296215   -0.619073    2.308537    0.023623
# std              0.708678       0.923930    1.272242    0.950740    0.006540
# min             -3.507000      -0.693000   -4.680000   -0.250000    0.014194
# 25%             -1.514000       2.001000   -1.390000    1.700000    0.019895
# 50%             -0.777000       2.565000   -0.480000    2.420000    0.022415
# 75%             -0.386000       2.896000    0.340000    2.970000    0.025339
# max              0.157000       3.515000    1.650000    4.660000    0.059051
#
#          r2019B02    r2019B03    r2019B04    r2019B05    r2019B06    r2019B07  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.038592    0.028895    0.219361    0.131344    0.068068    0.759654
# std      0.007341    0.010704    0.049137    0.036023    0.026479    0.091469
# min      0.026402    0.015301    0.140309    0.078918    0.035914    0.363395
# 25%      0.034516    0.022685    0.183403    0.102471    0.051182    0.727961
# 50%      0.036966    0.026123    0.199665    0.121704    0.060839    0.771691
# 75%      0.040237    0.030628    0.250913    0.153232    0.078586    0.814177
# max      0.077038    0.081675    0.423326    0.252487    0.196544    0.914709
#
#          r2019B08    r2019B09    r2019B10    r2019B11    r2019B12
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean    -0.692408    0.526662  -15.737088  -10.490763    0.668847
# std      0.070703    0.144729    1.547144    1.471517    0.081010
# min     -0.849155   -0.037478  -22.820204  -16.820473    0.386847
# 25%     -0.735660    0.470852  -16.494671  -11.364958    0.615553
# 50%     -0.693779    0.562326  -15.454248  -10.299303    0.666882
# 75%     -0.660039    0.626609  -14.760403   -9.547850    0.728737
# max     -0.389420    0.740912  -12.365163   -5.703308    0.877743

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "LN_Tag_Sr"
indep_variables = ['r2019B04', 'r2019B07', 'r2019B09', 'r2019B10']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      LN_GS_cub_m  LN_M_stem_kg_m2  LN_M_stem_bark_kg_m2  LN_M_crown_kg_m2  \
# 0          4.771            1.792                -0.211            -0.261
# 1          5.808            2.496                -0.073             0.392
# 2          5.796            2.546                 0.030             0.501
# 3          5.826            2.643                 0.000             0.419
# 4          6.059            2.643                 0.122             0.647
# ..           ...              ...                   ...               ...
# 200        6.238            3.125                 0.322             0.560
# 201        5.861            2.702                 0.058             0.482
# 202        5.935            2.775                -0.030             0.372
# 203        5.784            2.546                -0.117             0.182
# 204        6.277            2.949                 0.182             0.501
#
#      LN_M_foliage_kg_m2  LN_M_AG_kg_m2  LN_Tag_Cs  LN_Tag_Sr  r2019B01  \
# 0                -2.040          1.932      -0.73       2.58  0.025483
# 1                -0.139          2.674       0.59       2.92  0.024075
# 2                -0.030          2.734       0.78       2.88  0.022492
# 3                -0.431          2.785       0.52       2.72  0.023742
# 4                -0.386          2.809       0.22       2.83  0.022916
# ..                  ...            ...        ...        ...       ...
# 200              -0.301          3.231      -0.03       1.79  0.021045
# 201              -0.386          2.845       0.31       2.87  0.019699
# 202              -0.545          2.896       0.51       1.74  0.020443
# 203              -0.386          2.681       1.61       2.18  0.020905
# 204              -0.315          3.068      -0.41       1.95  0.020603
#
#      r2019B02  r2019B03  r2019B04  r2019B05  r2019B06  r2019B07  r2019B08  \
# 0    0.040910  0.030628  0.266210  0.166299  0.081316  0.793351 -0.733693
# 1    0.038164  0.027934  0.183349  0.102656  0.052144  0.735493 -0.655456
# 2    0.038968  0.026123  0.184066  0.099625  0.050684  0.751436 -0.650575
# 3    0.037811  0.027390  0.177221  0.102540  0.052198  0.732404 -0.648310
# 4    0.037557  0.025702  0.183705  0.101394  0.050437  0.754481 -0.660382
# ..        ...       ...       ...       ...       ...       ...       ...
# 200  0.035508  0.026143  0.199300  0.095774  0.045219  0.768490 -0.697576
# 201  0.034608  0.022056  0.208607  0.097603  0.044494  0.808730 -0.715291
# 202  0.036471  0.027264  0.177812  0.105252  0.054239  0.733975 -0.659608
# 203  0.037477  0.024510  0.213548  0.117474  0.055805  0.794069 -0.701348
# 204  0.035681  0.024394  0.196295  0.093705  0.046686  0.778950 -0.692400
#
#      r2019B09   r2019B10   r2019B11  r2019B12
# 0    0.532051 -15.396488 -11.262037  0.731937
# 1    0.557000 -16.012156  -9.364664  0.584920
# 2    0.568148 -13.609903  -9.726108  0.715177
# 3    0.544717 -14.321650 -10.457536  0.730390
# 4    0.569112 -13.934375 -11.393335  0.817430
# ..        ...        ...        ...       ...
# 200  0.629676 -14.238754  -8.134297  0.571699
# 201  0.648211 -12.803756 -11.046638  0.862806
# 202  0.532328 -16.458857 -10.048693  0.610619
# 203  0.585421 -13.451569 -10.497206  0.785254
# 204  0.615253 -13.836473 -10.086078  0.729378
#
# [205 rows x 20 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    r2019B04  r2019B07  r2019B09   r2019B10
# 0  0.266210  0.793351  0.532051 -15.396488
# 1  0.183349  0.735493  0.557000 -16.012156
# 2  0.184066  0.751436  0.568148 -13.609903
# 3  0.177221  0.732404  0.544717 -14.321650
# 4  0.183705  0.754481  0.569112 -13.934375

# %%
# Columns in "y" data collections
y.head()
# Out:
#    LN_Tag_Sr
# 0       2.58
# 1       2.92
# 2       2.88
# 3       2.72
# 4       2.83

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.27152745581162296, 0.09565666152088848, 0.088971568200235]
#     Mean: 0.152
#     Std: 0.085
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.88428719 0.87898834 0.9030678 ]
#     Mean: 0.889
#     Std: 0.010
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.6795839965689009, 0.6311375976310057, 0.711168671355528]
#     Mean: 0.674
#     Std: 0.033
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.6635123862719116                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.1551614448931099                 # gamma
print('Gamma: ' + str(p2))

p3 = 0.0639228267117087                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2            # max_depth
print('Max_depth: ' + str(p4))

p5 = 80          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.9875215009929939                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.6635123862719116
# Gamma: 0.1551614448931099
# Learning_rate: 0.0639228267117087
# Max_depth: 2
# N_estimators: 80
# Subsample: 0.9875215009929939

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.89428	validation_1-rmse:2.09298
# [1]	validation_0-rmse:1.79519	validation_1-rmse:1.99743
# [2]	validation_0-rmse:1.70540	validation_1-rmse:1.90836
# [3]	validation_0-rmse:1.62058	validation_1-rmse:1.82054
# [4]	validation_0-rmse:1.54146	validation_1-rmse:1.73760
# [5]	validation_0-rmse:1.46887	validation_1-rmse:1.66239
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:1.40152	validation_1-rmse:1.59175
# [7]	validation_0-rmse:1.33915	validation_1-rmse:1.53078
# [8]	validation_0-rmse:1.28178	validation_1-rmse:1.47453
# [9]	validation_0-rmse:1.22852	validation_1-rmse:1.41825
# [10]	validation_0-rmse:1.17978	validation_1-rmse:1.37060
# [11]	validation_0-rmse:1.13520	validation_1-rmse:1.32708
# [12]	validation_0-rmse:1.09365	validation_1-rmse:1.28606
# [13]	validation_0-rmse:1.05635	validation_1-rmse:1.24668
# [14]	validation_0-rmse:1.02076	validation_1-rmse:1.21377
# [15]	validation_0-rmse:0.98962	validation_1-rmse:1.18344
# [16]	validation_0-rmse:0.96052	validation_1-rmse:1.15237
# [17]	validation_0-rmse:0.93478	validation_1-rmse:1.12688
# [18]	validation_0-rmse:0.91033	validation_1-rmse:1.10371
# [19]	validation_0-rmse:0.88871	validation_1-rmse:1.08317
# [20]	validation_0-rmse:0.86882	validation_1-rmse:1.06365
# [21]	validation_0-rmse:0.85095	validation_1-rmse:1.04351
# [22]	validation_0-rmse:0.83463	validation_1-rmse:1.02321
# [23]	validation_0-rmse:0.81960	validation_1-rmse:1.00936
# [24]	validation_0-rmse:0.80506	validation_1-rmse:0.99509
# [25]	validation_0-rmse:0.79298	validation_1-rmse:0.98389
# [26]	validation_0-rmse:0.78083	validation_1-rmse:0.96736
# [27]	validation_0-rmse:0.77123	validation_1-rmse:0.95686
# [28]	validation_0-rmse:0.76113	validation_1-rmse:0.94553
# [29]	validation_0-rmse:0.75130	validation_1-rmse:0.93588
# [30]	validation_0-rmse:0.74204	validation_1-rmse:0.92543
# [31]	validation_0-rmse:0.73533	validation_1-rmse:0.91801
# [32]	validation_0-rmse:0.72884	validation_1-rmse:0.91217
# [33]	validation_0-rmse:0.72248	validation_1-rmse:0.90418
# [34]	validation_0-rmse:0.71601	validation_1-rmse:0.89582
# [35]	validation_0-rmse:0.70948	validation_1-rmse:0.89109
# [36]	validation_0-rmse:0.70430	validation_1-rmse:0.88441
# [37]	validation_0-rmse:0.69948	validation_1-rmse:0.87960
# [38]	validation_0-rmse:0.69567	validation_1-rmse:0.87768
# [39]	validation_0-rmse:0.69222	validation_1-rmse:0.87461
# [40]	validation_0-rmse:0.68750	validation_1-rmse:0.87054
# [41]	validation_0-rmse:0.68310	validation_1-rmse:0.86515
# [42]	validation_0-rmse:0.67955	validation_1-rmse:0.86313
# [43]	validation_0-rmse:0.67720	validation_1-rmse:0.86005
# [44]	validation_0-rmse:0.67523	validation_1-rmse:0.85649
# [45]	validation_0-rmse:0.67332	validation_1-rmse:0.85316
# [46]	validation_0-rmse:0.66898	validation_1-rmse:0.84748
# [47]	validation_0-rmse:0.66612	validation_1-rmse:0.84556
# [48]	validation_0-rmse:0.66337	validation_1-rmse:0.84292
# [49]	validation_0-rmse:0.66082	validation_1-rmse:0.84065
# [50]	validation_0-rmse:0.65854	validation_1-rmse:0.83863
# [51]	validation_0-rmse:0.65498	validation_1-rmse:0.83399
# [52]	validation_0-rmse:0.65298	validation_1-rmse:0.83226
# [53]	validation_0-rmse:0.65083	validation_1-rmse:0.83064
# [54]	validation_0-rmse:0.64900	validation_1-rmse:0.82900
# [55]	validation_0-rmse:0.64742	validation_1-rmse:0.82765
# [56]	validation_0-rmse:0.64563	validation_1-rmse:0.82320
# [57]	validation_0-rmse:0.64203	validation_1-rmse:0.82682
# [58]	validation_0-rmse:0.64067	validation_1-rmse:0.82579
# [59]	validation_0-rmse:0.63934	validation_1-rmse:0.82426
# [60]	validation_0-rmse:0.63765	validation_1-rmse:0.82236
# [61]	validation_0-rmse:0.63617	validation_1-rmse:0.82075
# [62]	validation_0-rmse:0.63505	validation_1-rmse:0.81990
# [63]	validation_0-rmse:0.63309	validation_1-rmse:0.82011
# [64]	validation_0-rmse:0.63009	validation_1-rmse:0.81724
# [65]	validation_0-rmse:0.62680	validation_1-rmse:0.81991
# [66]	validation_0-rmse:0.62597	validation_1-rmse:0.81892
# [67]	validation_0-rmse:0.62305	validation_1-rmse:0.82164
# [68]	validation_0-rmse:0.62108	validation_1-rmse:0.81895
# [69]	validation_0-rmse:0.61973	validation_1-rmse:0.81862
# [70]	validation_0-rmse:0.61818	validation_1-rmse:0.81888
# [71]	validation_0-rmse:0.61564	validation_1-rmse:0.82236
# [72]	validation_0-rmse:0.61354	validation_1-rmse:0.82007
# [73]	validation_0-rmse:0.61077	validation_1-rmse:0.81932
# [74]	validation_0-rmse:0.60829	validation_1-rmse:0.81923
# [75]	validation_0-rmse:0.60740	validation_1-rmse:0.81861
# [76]	validation_0-rmse:0.60511	validation_1-rmse:0.82038
# [77]	validation_0-rmse:0.60273	validation_1-rmse:0.81738
# [78]	validation_0-rmse:0.60187	validation_1-rmse:0.81643
# [79]	validation_0-rmse:0.60053	validation_1-rmse:0.81687
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.88336	validation_1-rmse:2.12534
# [1]	validation_0-rmse:1.78464	validation_1-rmse:2.02258
# [2]	validation_0-rmse:1.69398	validation_1-rmse:1.92824
# [3]	validation_0-rmse:1.60875	validation_1-rmse:1.84271
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:1.52948	validation_1-rmse:1.76433
# [5]	validation_0-rmse:1.45645	validation_1-rmse:1.68798
# [6]	validation_0-rmse:1.38863	validation_1-rmse:1.62185
# [7]	validation_0-rmse:1.32666	validation_1-rmse:1.55829
# [8]	validation_0-rmse:1.26829	validation_1-rmse:1.50349
# [9]	validation_0-rmse:1.21465	validation_1-rmse:1.44967
# [10]	validation_0-rmse:1.16510	validation_1-rmse:1.40424
# [11]	validation_0-rmse:1.11981	validation_1-rmse:1.36321
# [12]	validation_0-rmse:1.07832	validation_1-rmse:1.32079
# [13]	validation_0-rmse:1.04043	validation_1-rmse:1.28331
# [14]	validation_0-rmse:1.00531	validation_1-rmse:1.24930
# [15]	validation_0-rmse:0.97369	validation_1-rmse:1.21855
# [16]	validation_0-rmse:0.94471	validation_1-rmse:1.19047
# [17]	validation_0-rmse:0.91896	validation_1-rmse:1.16562
# [18]	validation_0-rmse:0.89483	validation_1-rmse:1.14194
# [19]	validation_0-rmse:0.87263	validation_1-rmse:1.12022
# [20]	validation_0-rmse:0.85373	validation_1-rmse:1.10150
# [21]	validation_0-rmse:0.83482	validation_1-rmse:1.08652
# [22]	validation_0-rmse:0.81812	validation_1-rmse:1.07165
# [23]	validation_0-rmse:0.80245	validation_1-rmse:1.05910
# [24]	validation_0-rmse:0.78786	validation_1-rmse:1.04632
# [25]	validation_0-rmse:0.77486	validation_1-rmse:1.03685
# [26]	validation_0-rmse:0.76395	validation_1-rmse:1.02588
# [27]	validation_0-rmse:0.75302	validation_1-rmse:1.01792
# [28]	validation_0-rmse:0.74326	validation_1-rmse:1.00690
# [29]	validation_0-rmse:0.73355	validation_1-rmse:0.99807
# [30]	validation_0-rmse:0.72506	validation_1-rmse:0.98965
# [31]	validation_0-rmse:0.71756	validation_1-rmse:0.98440
# [32]	validation_0-rmse:0.70994	validation_1-rmse:0.97258
# [33]	validation_0-rmse:0.70312	validation_1-rmse:0.96825
# [34]	validation_0-rmse:0.69770	validation_1-rmse:0.96116
# [35]	validation_0-rmse:0.69299	validation_1-rmse:0.95415
# [36]	validation_0-rmse:0.68899	validation_1-rmse:0.95180
# [37]	validation_0-rmse:0.68509	validation_1-rmse:0.94581
# [38]	validation_0-rmse:0.68135	validation_1-rmse:0.94256
# [39]	validation_0-rmse:0.67801	validation_1-rmse:0.94218
# [40]	validation_0-rmse:0.67388	validation_1-rmse:0.93881
# [41]	validation_0-rmse:0.66933	validation_1-rmse:0.93484
# [42]	validation_0-rmse:0.66628	validation_1-rmse:0.93401
# [43]	validation_0-rmse:0.66369	validation_1-rmse:0.92996
# [44]	validation_0-rmse:0.66134	validation_1-rmse:0.92820
# [45]	validation_0-rmse:0.65922	validation_1-rmse:0.92488
# [46]	validation_0-rmse:0.65610	validation_1-rmse:0.92267
# [47]	validation_0-rmse:0.65263	validation_1-rmse:0.91687
# [48]	validation_0-rmse:0.65014	validation_1-rmse:0.91646
# [49]	validation_0-rmse:0.64653	validation_1-rmse:0.91351
# [50]	validation_0-rmse:0.64177	validation_1-rmse:0.91157
# [51]	validation_0-rmse:0.63846	validation_1-rmse:0.90859
# [52]	validation_0-rmse:0.63535	validation_1-rmse:0.90589
# [53]	validation_0-rmse:0.63261	validation_1-rmse:0.90098
# [54]	validation_0-rmse:0.62907	validation_1-rmse:0.89871
# [55]	validation_0-rmse:0.62611	validation_1-rmse:0.89850
# [56]	validation_0-rmse:0.62261	validation_1-rmse:0.89737
# [57]	validation_0-rmse:0.61994	validation_1-rmse:0.89688
# [58]	validation_0-rmse:0.61726	validation_1-rmse:0.89671
# [59]	validation_0-rmse:0.61486	validation_1-rmse:0.89632
# [60]	validation_0-rmse:0.61312	validation_1-rmse:0.89784
# [61]	validation_0-rmse:0.61078	validation_1-rmse:0.89380
# [62]	validation_0-rmse:0.60980	validation_1-rmse:0.89111
# [63]	validation_0-rmse:0.60824	validation_1-rmse:0.89257
# [64]	validation_0-rmse:0.60496	validation_1-rmse:0.89258
# [65]	validation_0-rmse:0.60267	validation_1-rmse:0.89185
# [66]	validation_0-rmse:0.60103	validation_1-rmse:0.89235
# [67]	validation_0-rmse:0.59993	validation_1-rmse:0.89011
# [68]	validation_0-rmse:0.59853	validation_1-rmse:0.89186
# [69]	validation_0-rmse:0.59640	validation_1-rmse:0.89039
# [70]	validation_0-rmse:0.59447	validation_1-rmse:0.88907
# [71]	validation_0-rmse:0.59353	validation_1-rmse:0.88779
# [72]	validation_0-rmse:0.59043	validation_1-rmse:0.88685
# [73]	validation_0-rmse:0.58848	validation_1-rmse:0.88504
# [74]	validation_0-rmse:0.58720	validation_1-rmse:0.88594
# [75]	validation_0-rmse:0.58434	validation_1-rmse:0.88512
# [76]	validation_0-rmse:0.58272	validation_1-rmse:0.88397
# [77]	validation_0-rmse:0.58028	validation_1-rmse:0.88208
# [78]	validation_0-rmse:0.57861	validation_1-rmse:0.88267
# [79]	validation_0-rmse:0.57677	validation_1-rmse:0.88103
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.95263	validation_1-rmse:1.85102
# [1]	validation_0-rmse:1.85162	validation_1-rmse:1.74529
# [2]	validation_0-rmse:1.75868	validation_1-rmse:1.65279
# [3]	validation_0-rmse:1.67141	validation_1-rmse:1.56161
# [4]	validation_0-rmse:1.58932	validation_1-rmse:1.47559
# [5]	validation_0-rmse:1.51607	validation_1-rmse:1.39837
# [6]	validation_0-rmse:1.44613	validation_1-rmse:1.32333
# [7]	validation_0-rmse:1.38288	validation_1-rmse:1.26205
# [8]	validation_0-rmse:1.32417	validation_1-rmse:1.20338
# [9]	validation_0-rmse:1.26851	validation_1-rmse:1.14466
# [10]	validation_0-rmse:1.21855	validation_1-rmse:1.09853
# [11]	validation_0-rmse:1.17245	validation_1-rmse:1.05680
# [12]	validation_0-rmse:1.13073	validation_1-rmse:1.01931
# [13]	validation_0-rmse:1.09177	validation_1-rmse:0.97918
# [14]	validation_0-rmse:1.05557	validation_1-rmse:0.94456
# [15]	validation_0-rmse:1.02203	validation_1-rmse:0.91743
# [16]	validation_0-rmse:0.99150	validation_1-rmse:0.89317
# [17]	validation_0-rmse:0.96435	validation_1-rmse:0.87169
# [18]	validation_0-rmse:0.93893	validation_1-rmse:0.84985
# [19]	validation_0-rmse:0.91535	validation_1-rmse:0.83231
# [20]	validation_0-rmse:0.89437	validation_1-rmse:0.81740
# [21]	validation_0-rmse:0.87569	validation_1-rmse:0.80677
# [22]	validation_0-rmse:0.85868	validation_1-rmse:0.79766
# [23]	validation_0-rmse:0.84276	validation_1-rmse:0.78611
# [24]	validation_0-rmse:0.82696	validation_1-rmse:0.77455
# [25]	validation_0-rmse:0.81267	validation_1-rmse:0.76581
# [26]	validation_0-rmse:0.80002	validation_1-rmse:0.75846
# [27]	validation_0-rmse:0.78909	validation_1-rmse:0.75325
# [28]	validation_0-rmse:0.77946	validation_1-rmse:0.74809
# [29]	validation_0-rmse:0.77000	validation_1-rmse:0.74118
# [30]	validation_0-rmse:0.76073	validation_1-rmse:0.74113
# [31]	validation_0-rmse:0.75290	validation_1-rmse:0.74004
# [32]	validation_0-rmse:0.74492	validation_1-rmse:0.73817
# [33]	validation_0-rmse:0.73846	validation_1-rmse:0.73859
# [34]	validation_0-rmse:0.73174	validation_1-rmse:0.73754
# [35]	validation_0-rmse:0.72598	validation_1-rmse:0.73654
# [36]	validation_0-rmse:0.71983	validation_1-rmse:0.73464
# [37]	validation_0-rmse:0.71506	validation_1-rmse:0.73559
# [38]	validation_0-rmse:0.71043	validation_1-rmse:0.73762
# [39]	validation_0-rmse:0.70618	validation_1-rmse:0.73975
# [40]	validation_0-rmse:0.70099	validation_1-rmse:0.73883
# [41]	validation_0-rmse:0.69573	validation_1-rmse:0.73580
# [42]	validation_0-rmse:0.69146	validation_1-rmse:0.73334
# [43]	validation_0-rmse:0.68765	validation_1-rmse:0.73306
# [44]	validation_0-rmse:0.68485	validation_1-rmse:0.73539
# [45]	validation_0-rmse:0.68227	validation_1-rmse:0.73601
# [46]	validation_0-rmse:0.67704	validation_1-rmse:0.73535
# [47]	validation_0-rmse:0.67311	validation_1-rmse:0.73518
# [48]	validation_0-rmse:0.67087	validation_1-rmse:0.73540
# [49]	validation_0-rmse:0.66781	validation_1-rmse:0.73323
# [50]	validation_0-rmse:0.66427	validation_1-rmse:0.73383
# [51]	validation_0-rmse:0.66103	validation_1-rmse:0.73417
# [52]	validation_0-rmse:0.65784	validation_1-rmse:0.73586
# [53]	validation_0-rmse:0.65425	validation_1-rmse:0.73609
# [54]	validation_0-rmse:0.65074	validation_1-rmse:0.73554
# [55]	validation_0-rmse:0.64749	validation_1-rmse:0.73812
# [56]	validation_0-rmse:0.64458	validation_1-rmse:0.73883
# [57]	validation_0-rmse:0.64181	validation_1-rmse:0.74140
# [58]	validation_0-rmse:0.64081	validation_1-rmse:0.74189
# [59]	validation_0-rmse:0.63887	validation_1-rmse:0.74506
# [60]	validation_0-rmse:0.63728	validation_1-rmse:0.74298
# [61]	validation_0-rmse:0.63426	validation_1-rmse:0.74392
# [62]	validation_0-rmse:0.63176	validation_1-rmse:0.74593
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.93483	validation_1-rmse:1.93095
# [1]	validation_0-rmse:1.83563	validation_1-rmse:1.83048
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:1.74441	validation_1-rmse:1.72931
# [3]	validation_0-rmse:1.65893	validation_1-rmse:1.64087
# [4]	validation_0-rmse:1.57871	validation_1-rmse:1.55913
# [5]	validation_0-rmse:1.50596	validation_1-rmse:1.48319
# [6]	validation_0-rmse:1.43787	validation_1-rmse:1.41420
# [7]	validation_0-rmse:1.37607	validation_1-rmse:1.34339
# [8]	validation_0-rmse:1.31860	validation_1-rmse:1.28303
# [9]	validation_0-rmse:1.26453	validation_1-rmse:1.22790
# [10]	validation_0-rmse:1.21576	validation_1-rmse:1.17607
# [11]	validation_0-rmse:1.17143	validation_1-rmse:1.12837
# [12]	validation_0-rmse:1.13056	validation_1-rmse:1.08225
# [13]	validation_0-rmse:1.09295	validation_1-rmse:1.04197
# [14]	validation_0-rmse:1.05779	validation_1-rmse:1.00642
# [15]	validation_0-rmse:1.02595	validation_1-rmse:0.97064
# [16]	validation_0-rmse:0.99752	validation_1-rmse:0.93886
# [17]	validation_0-rmse:0.97214	validation_1-rmse:0.91075
# [18]	validation_0-rmse:0.94769	validation_1-rmse:0.88627
# [19]	validation_0-rmse:0.92479	validation_1-rmse:0.86349
# [20]	validation_0-rmse:0.90521	validation_1-rmse:0.83968
# [21]	validation_0-rmse:0.88737	validation_1-rmse:0.82277
# [22]	validation_0-rmse:0.87200	validation_1-rmse:0.80450
# [23]	validation_0-rmse:0.85677	validation_1-rmse:0.78975
# [24]	validation_0-rmse:0.84119	validation_1-rmse:0.77342
# [25]	validation_0-rmse:0.82701	validation_1-rmse:0.76157
# [26]	validation_0-rmse:0.81454	validation_1-rmse:0.74639
# [27]	validation_0-rmse:0.80468	validation_1-rmse:0.73490
# [28]	validation_0-rmse:0.79533	validation_1-rmse:0.72756
# [29]	validation_0-rmse:0.78532	validation_1-rmse:0.71743
# [30]	validation_0-rmse:0.77532	validation_1-rmse:0.70513
# [31]	validation_0-rmse:0.76777	validation_1-rmse:0.69974
# [32]	validation_0-rmse:0.76006	validation_1-rmse:0.69074
# [33]	validation_0-rmse:0.75439	validation_1-rmse:0.68557
# [34]	validation_0-rmse:0.74653	validation_1-rmse:0.68218
# [35]	validation_0-rmse:0.74099	validation_1-rmse:0.67742
# [36]	validation_0-rmse:0.73397	validation_1-rmse:0.67276
# [37]	validation_0-rmse:0.72928	validation_1-rmse:0.66811
# [38]	validation_0-rmse:0.72558	validation_1-rmse:0.66484
# [39]	validation_0-rmse:0.72218	validation_1-rmse:0.66087
# [40]	validation_0-rmse:0.71656	validation_1-rmse:0.65842
# [41]	validation_0-rmse:0.71117	validation_1-rmse:0.65416
# [42]	validation_0-rmse:0.70870	validation_1-rmse:0.65140
# [43]	validation_0-rmse:0.70568	validation_1-rmse:0.65111
# [44]	validation_0-rmse:0.70353	validation_1-rmse:0.64940
# [45]	validation_0-rmse:0.70159	validation_1-rmse:0.64767
# [46]	validation_0-rmse:0.69684	validation_1-rmse:0.64543
# [47]	validation_0-rmse:0.69254	validation_1-rmse:0.64348
# [48]	validation_0-rmse:0.68954	validation_1-rmse:0.64544
# [49]	validation_0-rmse:0.68673	validation_1-rmse:0.64445
# [50]	validation_0-rmse:0.68096	validation_1-rmse:0.64240
# [51]	validation_0-rmse:0.67747	validation_1-rmse:0.64112
# [52]	validation_0-rmse:0.67462	validation_1-rmse:0.63977
# [53]	validation_0-rmse:0.67155	validation_1-rmse:0.63971
# [54]	validation_0-rmse:0.66754	validation_1-rmse:0.63633
# [55]	validation_0-rmse:0.66588	validation_1-rmse:0.63539
# [56]	validation_0-rmse:0.66278	validation_1-rmse:0.63469
# [57]	validation_0-rmse:0.65991	validation_1-rmse:0.63390
# [58]	validation_0-rmse:0.65845	validation_1-rmse:0.63325
# [59]	validation_0-rmse:0.65711	validation_1-rmse:0.63264
# [60]	validation_0-rmse:0.65438	validation_1-rmse:0.63274
# [61]	validation_0-rmse:0.65148	validation_1-rmse:0.63066
# [62]	validation_0-rmse:0.65025	validation_1-rmse:0.63009
# [63]	validation_0-rmse:0.64793	validation_1-rmse:0.62991
# [64]	validation_0-rmse:0.64522	validation_1-rmse:0.62642
# [65]	validation_0-rmse:0.64337	validation_1-rmse:0.62583
# [66]	validation_0-rmse:0.64160	validation_1-rmse:0.62525
# [67]	validation_0-rmse:0.63863	validation_1-rmse:0.62262
# [68]	validation_0-rmse:0.63584	validation_1-rmse:0.62454
# [69]	validation_0-rmse:0.63404	validation_1-rmse:0.62410
# [70]	validation_0-rmse:0.63255	validation_1-rmse:0.62367
# [71]	validation_0-rmse:0.63156	validation_1-rmse:0.62549
# [72]	validation_0-rmse:0.62764	validation_1-rmse:0.62528
# [73]	validation_0-rmse:0.62601	validation_1-rmse:0.62530
# [74]	validation_0-rmse:0.62374	validation_1-rmse:0.62515
# [75]	validation_0-rmse:0.62117	validation_1-rmse:0.62378
# [76]	validation_0-rmse:0.61915	validation_1-rmse:0.62655
# [77]	validation_0-rmse:0.61829	validation_1-rmse:0.62823
# [78]	validation_0-rmse:0.61599	validation_1-rmse:0.62838
# [79]	validation_0-rmse:0.61380	validation_1-rmse:0.62857
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.94148	validation_1-rmse:1.89590
# [1]	validation_0-rmse:1.83906	validation_1-rmse:1.79305
# [2]	validation_0-rmse:1.74568	validation_1-rmse:1.70382
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:1.65680	validation_1-rmse:1.62463
# [4]	validation_0-rmse:1.57404	validation_1-rmse:1.54686
# [5]	validation_0-rmse:1.49885	validation_1-rmse:1.48031
# [6]	validation_0-rmse:1.42804	validation_1-rmse:1.41511
# [7]	validation_0-rmse:1.36491	validation_1-rmse:1.35675
# [8]	validation_0-rmse:1.30473	validation_1-rmse:1.30331
# [9]	validation_0-rmse:1.24841	validation_1-rmse:1.25543
# [10]	validation_0-rmse:1.19791	validation_1-rmse:1.21407
# [11]	validation_0-rmse:1.15163	validation_1-rmse:1.17660
# [12]	validation_0-rmse:1.10912	validation_1-rmse:1.14068
# [13]	validation_0-rmse:1.06956	validation_1-rmse:1.11016
# [14]	validation_0-rmse:1.03203	validation_1-rmse:1.08367
# [15]	validation_0-rmse:0.99927	validation_1-rmse:1.05929
# [16]	validation_0-rmse:0.96980	validation_1-rmse:1.03736
# [17]	validation_0-rmse:0.94234	validation_1-rmse:1.01589
# [18]	validation_0-rmse:0.91678	validation_1-rmse:0.99697
# [19]	validation_0-rmse:0.89304	validation_1-rmse:0.98396
# [20]	validation_0-rmse:0.87200	validation_1-rmse:0.96971
# [21]	validation_0-rmse:0.85207	validation_1-rmse:0.95835
# [22]	validation_0-rmse:0.83488	validation_1-rmse:0.94794
# [23]	validation_0-rmse:0.81756	validation_1-rmse:0.93779
# [24]	validation_0-rmse:0.80156	validation_1-rmse:0.92830
# [25]	validation_0-rmse:0.78714	validation_1-rmse:0.92043
# [26]	validation_0-rmse:0.77502	validation_1-rmse:0.91244
# [27]	validation_0-rmse:0.76225	validation_1-rmse:0.90605
# [28]	validation_0-rmse:0.75139	validation_1-rmse:0.90204
# [29]	validation_0-rmse:0.74081	validation_1-rmse:0.89757
# [30]	validation_0-rmse:0.73196	validation_1-rmse:0.89414
# [31]	validation_0-rmse:0.72376	validation_1-rmse:0.89122
# [32]	validation_0-rmse:0.71638	validation_1-rmse:0.88808
# [33]	validation_0-rmse:0.70824	validation_1-rmse:0.88504
# [34]	validation_0-rmse:0.70082	validation_1-rmse:0.88321
# [35]	validation_0-rmse:0.69472	validation_1-rmse:0.88230
# [36]	validation_0-rmse:0.68829	validation_1-rmse:0.88063
# [37]	validation_0-rmse:0.68207	validation_1-rmse:0.87896
# [38]	validation_0-rmse:0.67735	validation_1-rmse:0.87804
# [39]	validation_0-rmse:0.67178	validation_1-rmse:0.87703
# [40]	validation_0-rmse:0.66575	validation_1-rmse:0.87758
# [41]	validation_0-rmse:0.65995	validation_1-rmse:0.87931
# [42]	validation_0-rmse:0.65576	validation_1-rmse:0.87868
# [43]	validation_0-rmse:0.65270	validation_1-rmse:0.87853
# [44]	validation_0-rmse:0.64952	validation_1-rmse:0.87813
# [45]	validation_0-rmse:0.64694	validation_1-rmse:0.87834
# [46]	validation_0-rmse:0.64260	validation_1-rmse:0.88011
# [47]	validation_0-rmse:0.63904	validation_1-rmse:0.87985
# [48]	validation_0-rmse:0.63585	validation_1-rmse:0.87966
# [49]	validation_0-rmse:0.63296	validation_1-rmse:0.87921
# [50]	validation_0-rmse:0.62918	validation_1-rmse:0.87910
# [51]	validation_0-rmse:0.62548	validation_1-rmse:0.88383
# [52]	validation_0-rmse:0.62210	validation_1-rmse:0.88377
# [53]	validation_0-rmse:0.61883	validation_1-rmse:0.88459
# [54]	validation_0-rmse:0.61628	validation_1-rmse:0.88376
# [55]	validation_0-rmse:0.61403	validation_1-rmse:0.88355
# [56]	validation_0-rmse:0.61101	validation_1-rmse:0.88805
# [57]	validation_0-rmse:0.60901	validation_1-rmse:0.88789
# [58]	validation_0-rmse:0.60724	validation_1-rmse:0.88777
# [59]	validation_0-rmse:0.60552	validation_1-rmse:0.88771
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.91967	validation_1-rmse:1.99391
# [1]	validation_0-rmse:1.81904	validation_1-rmse:1.89333
# [2]	validation_0-rmse:1.72663	validation_1-rmse:1.80300
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:1.63993	validation_1-rmse:1.71957
# [4]	validation_0-rmse:1.56007	validation_1-rmse:1.63792
# [5]	validation_0-rmse:1.48608	validation_1-rmse:1.56170
# [6]	validation_0-rmse:1.41829	validation_1-rmse:1.49219
# [7]	validation_0-rmse:1.35641	validation_1-rmse:1.43215
# [8]	validation_0-rmse:1.29726	validation_1-rmse:1.38128
# [9]	validation_0-rmse:1.24349	validation_1-rmse:1.33400
# [10]	validation_0-rmse:1.19327	validation_1-rmse:1.29178
# [11]	validation_0-rmse:1.14747	validation_1-rmse:1.25498
# [12]	validation_0-rmse:1.10532	validation_1-rmse:1.21605
# [13]	validation_0-rmse:1.06630	validation_1-rmse:1.18070
# [14]	validation_0-rmse:1.02947	validation_1-rmse:1.14722
# [15]	validation_0-rmse:0.99621	validation_1-rmse:1.12287
# [16]	validation_0-rmse:0.96614	validation_1-rmse:1.09952
# [17]	validation_0-rmse:0.93904	validation_1-rmse:1.07886
# [18]	validation_0-rmse:0.91404	validation_1-rmse:1.05701
# [19]	validation_0-rmse:0.89169	validation_1-rmse:1.03905
# [20]	validation_0-rmse:0.87180	validation_1-rmse:1.02515
# [21]	validation_0-rmse:0.85331	validation_1-rmse:1.01592
# [22]	validation_0-rmse:0.83663	validation_1-rmse:1.00807
# [23]	validation_0-rmse:0.82122	validation_1-rmse:0.99499
# [24]	validation_0-rmse:0.80554	validation_1-rmse:0.98656
# [25]	validation_0-rmse:0.79253	validation_1-rmse:0.97536
# [26]	validation_0-rmse:0.77989	validation_1-rmse:0.96451
# [27]	validation_0-rmse:0.76876	validation_1-rmse:0.95828
# [28]	validation_0-rmse:0.75939	validation_1-rmse:0.95714
# [29]	validation_0-rmse:0.75086	validation_1-rmse:0.95362
# [30]	validation_0-rmse:0.74218	validation_1-rmse:0.94595
# [31]	validation_0-rmse:0.73531	validation_1-rmse:0.94234
# [32]	validation_0-rmse:0.72822	validation_1-rmse:0.93662
# [33]	validation_0-rmse:0.72258	validation_1-rmse:0.93471
# [34]	validation_0-rmse:0.71545	validation_1-rmse:0.92670
# [35]	validation_0-rmse:0.70938	validation_1-rmse:0.92241
# [36]	validation_0-rmse:0.70355	validation_1-rmse:0.91775
# [37]	validation_0-rmse:0.69953	validation_1-rmse:0.91661
# [38]	validation_0-rmse:0.69547	validation_1-rmse:0.91662
# [39]	validation_0-rmse:0.69197	validation_1-rmse:0.91632
# [40]	validation_0-rmse:0.68856	validation_1-rmse:0.91370
# [41]	validation_0-rmse:0.68536	validation_1-rmse:0.90989
# [42]	validation_0-rmse:0.68263	validation_1-rmse:0.91247
# [43]	validation_0-rmse:0.68004	validation_1-rmse:0.91237
# [44]	validation_0-rmse:0.67755	validation_1-rmse:0.91196
# [45]	validation_0-rmse:0.67519	validation_1-rmse:0.91294
# [46]	validation_0-rmse:0.67025	validation_1-rmse:0.90812
# [47]	validation_0-rmse:0.66705	validation_1-rmse:0.90835
# [48]	validation_0-rmse:0.66251	validation_1-rmse:0.91190
# [49]	validation_0-rmse:0.66084	validation_1-rmse:0.91513
# [50]	validation_0-rmse:0.65705	validation_1-rmse:0.91149
# [51]	validation_0-rmse:0.65288	validation_1-rmse:0.90781
# [52]	validation_0-rmse:0.64940	validation_1-rmse:0.90622
# [53]	validation_0-rmse:0.64599	validation_1-rmse:0.90561
# [54]	validation_0-rmse:0.64280	validation_1-rmse:0.90441
# [55]	validation_0-rmse:0.64113	validation_1-rmse:0.90325
# [56]	validation_0-rmse:0.63766	validation_1-rmse:0.89943
# [57]	validation_0-rmse:0.63366	validation_1-rmse:0.90434
# [58]	validation_0-rmse:0.63224	validation_1-rmse:0.90335
# [59]	validation_0-rmse:0.62940	validation_1-rmse:0.90404
# [60]	validation_0-rmse:0.62684	validation_1-rmse:0.90268
# [61]	validation_0-rmse:0.62384	validation_1-rmse:0.89988
# [62]	validation_0-rmse:0.62026	validation_1-rmse:0.90509
# [63]	validation_0-rmse:0.61749	validation_1-rmse:0.90191
# [64]	validation_0-rmse:0.61500	validation_1-rmse:0.90090
# [65]	validation_0-rmse:0.61236	validation_1-rmse:0.89604
# [66]	validation_0-rmse:0.61138	validation_1-rmse:0.89696
# [67]	validation_0-rmse:0.60902	validation_1-rmse:0.89248
# [68]	validation_0-rmse:0.60814	validation_1-rmse:0.89345
# [69]	validation_0-rmse:0.60523	validation_1-rmse:0.89538
# [70]	validation_0-rmse:0.60285	validation_1-rmse:0.89298
# [71]	validation_0-rmse:0.60173	validation_1-rmse:0.89210
# [72]	validation_0-rmse:0.59962	validation_1-rmse:0.88797
# [73]	validation_0-rmse:0.59844	validation_1-rmse:0.88798
# [74]	validation_0-rmse:0.59740	validation_1-rmse:0.88802
# [75]	validation_0-rmse:0.59516	validation_1-rmse:0.88593
# [76]	validation_0-rmse:0.59262	validation_1-rmse:0.88793
# [77]	validation_0-rmse:0.59045	validation_1-rmse:0.88707
# [78]	validation_0-rmse:0.58821	validation_1-rmse:0.88907
# [79]	validation_0-rmse:0.58616	validation_1-rmse:0.88755
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.93515	validation_1-rmse:1.93035
# [1]	validation_0-rmse:1.83476	validation_1-rmse:1.83379
# [2]	validation_0-rmse:1.74253	validation_1-rmse:1.74482
# [3]	validation_0-rmse:1.65433	validation_1-rmse:1.66283
# [4]	validation_0-rmse:1.57241	validation_1-rmse:1.58832
# [5]	validation_0-rmse:1.49698	validation_1-rmse:1.51894
# [6]	validation_0-rmse:1.42619	validation_1-rmse:1.45646
# [7]	validation_0-rmse:1.36332	validation_1-rmse:1.39631
# [8]	validation_0-rmse:1.30441	validation_1-rmse:1.34113
# [9]	validation_0-rmse:1.24948	validation_1-rmse:1.28922
# [10]	validation_0-rmse:1.19956	validation_1-rmse:1.24311
# [11]	validation_0-rmse:1.15405	validation_1-rmse:1.20111
# [12]	validation_0-rmse:1.11216	validation_1-rmse:1.16296
# [13]	validation_0-rmse:1.07303	validation_1-rmse:1.12766
# [14]	validation_0-rmse:1.03756	validation_1-rmse:1.09532
# [15]	validation_0-rmse:1.00442	validation_1-rmse:1.06690
# [16]	validation_0-rmse:0.97477	validation_1-rmse:1.04147
# [17]	validation_0-rmse:0.94775	validation_1-rmse:1.01784
# [18]	validation_0-rmse:0.92301	validation_1-rmse:0.99509
# [19]	validation_0-rmse:0.89856	validation_1-rmse:0.97232
# [20]	validation_0-rmse:0.87762	validation_1-rmse:0.95519
# [21]	validation_0-rmse:0.85825	validation_1-rmse:0.93932
# [22]	validation_0-rmse:0.84122	validation_1-rmse:0.92584
# [23]	validation_0-rmse:0.82300	validation_1-rmse:0.91620
# [24]	validation_0-rmse:0.80756	validation_1-rmse:0.90973
# [25]	validation_0-rmse:0.79300	validation_1-rmse:0.89761
# [26]	validation_0-rmse:0.77999	validation_1-rmse:0.88702
# [27]	validation_0-rmse:0.77011	validation_1-rmse:0.88054
# [28]	validation_0-rmse:0.76028	validation_1-rmse:0.87160
# [29]	validation_0-rmse:0.74781	validation_1-rmse:0.86751
# [30]	validation_0-rmse:0.73720	validation_1-rmse:0.86378
# [31]	validation_0-rmse:0.73047	validation_1-rmse:0.85969
# [32]	validation_0-rmse:0.72155	validation_1-rmse:0.85953
# [33]	validation_0-rmse:0.71467	validation_1-rmse:0.85466
# [34]	validation_0-rmse:0.70594	validation_1-rmse:0.85338
# [35]	validation_0-rmse:0.70046	validation_1-rmse:0.84962
# [36]	validation_0-rmse:0.69369	validation_1-rmse:0.85068
# [37]	validation_0-rmse:0.69000	validation_1-rmse:0.84898
# [38]	validation_0-rmse:0.68577	validation_1-rmse:0.84631
# [39]	validation_0-rmse:0.68199	validation_1-rmse:0.84402
# [40]	validation_0-rmse:0.67598	validation_1-rmse:0.83963
# [41]	validation_0-rmse:0.67072	validation_1-rmse:0.84090
# [42]	validation_0-rmse:0.66773	validation_1-rmse:0.84001
# [43]	validation_0-rmse:0.66429	validation_1-rmse:0.84039
# [44]	validation_0-rmse:0.66113	validation_1-rmse:0.84085
# [45]	validation_0-rmse:0.65900	validation_1-rmse:0.84054
# [46]	validation_0-rmse:0.65492	validation_1-rmse:0.84223
# [47]	validation_0-rmse:0.65038	validation_1-rmse:0.83915
# [48]	validation_0-rmse:0.64737	validation_1-rmse:0.83800
# [49]	validation_0-rmse:0.64507	validation_1-rmse:0.83733
# [50]	validation_0-rmse:0.64199	validation_1-rmse:0.83910
# [51]	validation_0-rmse:0.63857	validation_1-rmse:0.84184
# [52]	validation_0-rmse:0.63554	validation_1-rmse:0.84255
# [53]	validation_0-rmse:0.63235	validation_1-rmse:0.84136
# [54]	validation_0-rmse:0.62983	validation_1-rmse:0.84211
# [55]	validation_0-rmse:0.62821	validation_1-rmse:0.84386
# [56]	validation_0-rmse:0.62558	validation_1-rmse:0.84593
# [57]	validation_0-rmse:0.62413	validation_1-rmse:0.84765
# [58]	validation_0-rmse:0.62283	validation_1-rmse:0.84936
# [59]	validation_0-rmse:0.62166	validation_1-rmse:0.85104
# [60]	validation_0-rmse:0.61907	validation_1-rmse:0.85031
# [61]	validation_0-rmse:0.61513	validation_1-rmse:0.85216
# [62]	validation_0-rmse:0.61413	validation_1-rmse:0.85288
# [63]	validation_0-rmse:0.61175	validation_1-rmse:0.85378
# [64]	validation_0-rmse:0.60805	validation_1-rmse:0.85431
# [65]	validation_0-rmse:0.60610	validation_1-rmse:0.85383
# [66]	validation_0-rmse:0.60427	validation_1-rmse:0.84941
# [67]	validation_0-rmse:0.60100	validation_1-rmse:0.85019
# [68]	validation_0-rmse:0.59962	validation_1-rmse:0.85021
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.90612	validation_1-rmse:2.04369
# [1]	validation_0-rmse:1.80758	validation_1-rmse:1.93426
# [2]	validation_0-rmse:1.71787	validation_1-rmse:1.83828
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:1.63337	validation_1-rmse:1.75177
# [4]	validation_0-rmse:1.55329	validation_1-rmse:1.67169
# [5]	validation_0-rmse:1.48010	validation_1-rmse:1.59660
# [6]	validation_0-rmse:1.41222	validation_1-rmse:1.52925
# [7]	validation_0-rmse:1.35049	validation_1-rmse:1.46287
# [8]	validation_0-rmse:1.29264	validation_1-rmse:1.40574
# [9]	validation_0-rmse:1.23893	validation_1-rmse:1.35251
# [10]	validation_0-rmse:1.19033	validation_1-rmse:1.30444
# [11]	validation_0-rmse:1.14583	validation_1-rmse:1.26538
# [12]	validation_0-rmse:1.10494	validation_1-rmse:1.21878
# [13]	validation_0-rmse:1.06712	validation_1-rmse:1.18087
# [14]	validation_0-rmse:1.03252	validation_1-rmse:1.14014
# [15]	validation_0-rmse:1.00123	validation_1-rmse:1.10171
# [16]	validation_0-rmse:0.97136	validation_1-rmse:1.06907
# [17]	validation_0-rmse:0.94578	validation_1-rmse:1.03884
# [18]	validation_0-rmse:0.92188	validation_1-rmse:1.01028
# [19]	validation_0-rmse:0.89801	validation_1-rmse:0.98521
# [20]	validation_0-rmse:0.87798	validation_1-rmse:0.95957
# [21]	validation_0-rmse:0.86027	validation_1-rmse:0.94112
# [22]	validation_0-rmse:0.84408	validation_1-rmse:0.92830
# [23]	validation_0-rmse:0.82701	validation_1-rmse:0.91063
# [24]	validation_0-rmse:0.81257	validation_1-rmse:0.89591
# [25]	validation_0-rmse:0.79833	validation_1-rmse:0.88132
# [26]	validation_0-rmse:0.78700	validation_1-rmse:0.86792
# [27]	validation_0-rmse:0.77513	validation_1-rmse:0.85650
# [28]	validation_0-rmse:0.76566	validation_1-rmse:0.84799
# [29]	validation_0-rmse:0.75589	validation_1-rmse:0.83817
# [30]	validation_0-rmse:0.74771	validation_1-rmse:0.82718
# [31]	validation_0-rmse:0.74042	validation_1-rmse:0.82108
# [32]	validation_0-rmse:0.73187	validation_1-rmse:0.81344
# [33]	validation_0-rmse:0.72446	validation_1-rmse:0.80733
# [34]	validation_0-rmse:0.71659	validation_1-rmse:0.80223
# [35]	validation_0-rmse:0.71031	validation_1-rmse:0.79713
# [36]	validation_0-rmse:0.70426	validation_1-rmse:0.79001
# [37]	validation_0-rmse:0.69875	validation_1-rmse:0.78624
# [38]	validation_0-rmse:0.69473	validation_1-rmse:0.78470
# [39]	validation_0-rmse:0.69112	validation_1-rmse:0.78307
# [40]	validation_0-rmse:0.68463	validation_1-rmse:0.78198
# [41]	validation_0-rmse:0.68131	validation_1-rmse:0.78001
# [42]	validation_0-rmse:0.67742	validation_1-rmse:0.77784
# [43]	validation_0-rmse:0.67477	validation_1-rmse:0.77748
# [44]	validation_0-rmse:0.67206	validation_1-rmse:0.77598
# [45]	validation_0-rmse:0.66890	validation_1-rmse:0.77723
# [46]	validation_0-rmse:0.66363	validation_1-rmse:0.77557
# [47]	validation_0-rmse:0.65889	validation_1-rmse:0.77413
# [48]	validation_0-rmse:0.65594	validation_1-rmse:0.77299
# [49]	validation_0-rmse:0.65329	validation_1-rmse:0.77199
# [50]	validation_0-rmse:0.64978	validation_1-rmse:0.77099
# [51]	validation_0-rmse:0.64591	validation_1-rmse:0.77008
# [52]	validation_0-rmse:0.64279	validation_1-rmse:0.76664
# [53]	validation_0-rmse:0.63991	validation_1-rmse:0.76583
# [54]	validation_0-rmse:0.63733	validation_1-rmse:0.76526
# [55]	validation_0-rmse:0.63535	validation_1-rmse:0.76468
# [56]	validation_0-rmse:0.63244	validation_1-rmse:0.76152
# [57]	validation_0-rmse:0.63069	validation_1-rmse:0.76120
# [58]	validation_0-rmse:0.62915	validation_1-rmse:0.76098
# [59]	validation_0-rmse:0.62774	validation_1-rmse:0.76070
# [60]	validation_0-rmse:0.62493	validation_1-rmse:0.76045
# [61]	validation_0-rmse:0.62256	validation_1-rmse:0.75855
# [62]	validation_0-rmse:0.62132	validation_1-rmse:0.75848
# [63]	validation_0-rmse:0.61872	validation_1-rmse:0.75832
# [64]	validation_0-rmse:0.61660	validation_1-rmse:0.75687
# [65]	validation_0-rmse:0.61348	validation_1-rmse:0.75358
# [66]	validation_0-rmse:0.61203	validation_1-rmse:0.75563
# [67]	validation_0-rmse:0.61098	validation_1-rmse:0.75559
# [68]	validation_0-rmse:0.60998	validation_1-rmse:0.75481
# [69]	validation_0-rmse:0.60791	validation_1-rmse:0.75694
# [70]	validation_0-rmse:0.60498	validation_1-rmse:0.75526
# [71]	validation_0-rmse:0.60275	validation_1-rmse:0.75350
# [72]	validation_0-rmse:0.60011	validation_1-rmse:0.75122
# [73]	validation_0-rmse:0.59914	validation_1-rmse:0.75108
# [74]	validation_0-rmse:0.59813	validation_1-rmse:0.75076
# [75]	validation_0-rmse:0.59651	validation_1-rmse:0.75099
# [76]	validation_0-rmse:0.59464	validation_1-rmse:0.75319
# [77]	validation_0-rmse:0.59232	validation_1-rmse:0.75073
# [78]	validation_0-rmse:0.59141	validation_1-rmse:0.75043
# [79]	validation_0-rmse:0.58950	validation_1-rmse:0.75094
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.93626	validation_1-rmse:1.91530
# [1]	validation_0-rmse:1.83365	validation_1-rmse:1.81508
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:1.73851	validation_1-rmse:1.72981
# [3]	validation_0-rmse:1.64907	validation_1-rmse:1.64140
# [4]	validation_0-rmse:1.56737	validation_1-rmse:1.56099
# [5]	validation_0-rmse:1.49069	validation_1-rmse:1.49603
# [6]	validation_0-rmse:1.42076	validation_1-rmse:1.42918
# [7]	validation_0-rmse:1.35610	validation_1-rmse:1.37637
# [8]	validation_0-rmse:1.29527	validation_1-rmse:1.32307
# [9]	validation_0-rmse:1.23994	validation_1-rmse:1.27260
# [10]	validation_0-rmse:1.18868	validation_1-rmse:1.22962
# [11]	validation_0-rmse:1.14176	validation_1-rmse:1.19215
# [12]	validation_0-rmse:1.09882	validation_1-rmse:1.16252
# [13]	validation_0-rmse:1.05907	validation_1-rmse:1.13495
# [14]	validation_0-rmse:1.02308	validation_1-rmse:1.10610
# [15]	validation_0-rmse:0.98954	validation_1-rmse:1.08402
# [16]	validation_0-rmse:0.95906	validation_1-rmse:1.06552
# [17]	validation_0-rmse:0.93131	validation_1-rmse:1.05019
# [18]	validation_0-rmse:0.90670	validation_1-rmse:1.03181
# [19]	validation_0-rmse:0.88304	validation_1-rmse:1.01748
# [20]	validation_0-rmse:0.86165	validation_1-rmse:1.00547
# [21]	validation_0-rmse:0.84222	validation_1-rmse:0.99548
# [22]	validation_0-rmse:0.82521	validation_1-rmse:0.98721
# [23]	validation_0-rmse:0.80808	validation_1-rmse:0.97487
# [24]	validation_0-rmse:0.79225	validation_1-rmse:0.96887
# [25]	validation_0-rmse:0.77959	validation_1-rmse:0.96129
# [26]	validation_0-rmse:0.76682	validation_1-rmse:0.95265
# [27]	validation_0-rmse:0.75377	validation_1-rmse:0.94918
# [28]	validation_0-rmse:0.74372	validation_1-rmse:0.94493
# [29]	validation_0-rmse:0.73391	validation_1-rmse:0.93929
# [30]	validation_0-rmse:0.72323	validation_1-rmse:0.93693
# [31]	validation_0-rmse:0.71632	validation_1-rmse:0.93686
# [32]	validation_0-rmse:0.70853	validation_1-rmse:0.93256
# [33]	validation_0-rmse:0.70129	validation_1-rmse:0.93250
# [34]	validation_0-rmse:0.69475	validation_1-rmse:0.92844
# [35]	validation_0-rmse:0.68772	validation_1-rmse:0.92843
# [36]	validation_0-rmse:0.68200	validation_1-rmse:0.92592
# [37]	validation_0-rmse:0.67641	validation_1-rmse:0.92672
# [38]	validation_0-rmse:0.67103	validation_1-rmse:0.92989
# [39]	validation_0-rmse:0.66780	validation_1-rmse:0.93221
# [40]	validation_0-rmse:0.66233	validation_1-rmse:0.93288
# [41]	validation_0-rmse:0.65841	validation_1-rmse:0.92854
# [42]	validation_0-rmse:0.65432	validation_1-rmse:0.92984
# [43]	validation_0-rmse:0.65190	validation_1-rmse:0.93135
# [44]	validation_0-rmse:0.64974	validation_1-rmse:0.93393
# [45]	validation_0-rmse:0.64707	validation_1-rmse:0.93332
# [46]	validation_0-rmse:0.64426	validation_1-rmse:0.92989
# [47]	validation_0-rmse:0.64146	validation_1-rmse:0.93052
# [48]	validation_0-rmse:0.63827	validation_1-rmse:0.93174
# [49]	validation_0-rmse:0.63525	validation_1-rmse:0.93320
# [50]	validation_0-rmse:0.63259	validation_1-rmse:0.93444
# [51]	validation_0-rmse:0.62897	validation_1-rmse:0.93295
# [52]	validation_0-rmse:0.62657	validation_1-rmse:0.93424
# [53]	validation_0-rmse:0.62356	validation_1-rmse:0.93227
# [54]	validation_0-rmse:0.62181	validation_1-rmse:0.93150
# [55]	validation_0-rmse:0.61984	validation_1-rmse:0.93259
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.94259	validation_1-rmse:1.88763
# [1]	validation_0-rmse:1.84110	validation_1-rmse:1.78360
# [2]	validation_0-rmse:1.74838	validation_1-rmse:1.68582
# [3]	validation_0-rmse:1.66043	validation_1-rmse:1.59950
# [4]	validation_0-rmse:1.57815	validation_1-rmse:1.52257
# [5]	validation_0-rmse:1.50251	validation_1-rmse:1.44884
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:1.43295	validation_1-rmse:1.38540
# [7]	validation_0-rmse:1.36980	validation_1-rmse:1.31951
# [8]	validation_0-rmse:1.30984	validation_1-rmse:1.26546
# [9]	validation_0-rmse:1.25500	validation_1-rmse:1.21614
# [10]	validation_0-rmse:1.20440	validation_1-rmse:1.17178
# [11]	validation_0-rmse:1.15800	validation_1-rmse:1.13211
# [12]	validation_0-rmse:1.11584	validation_1-rmse:1.09479
# [13]	validation_0-rmse:1.07623	validation_1-rmse:1.05977
# [14]	validation_0-rmse:1.04054	validation_1-rmse:1.02637
# [15]	validation_0-rmse:1.00778	validation_1-rmse:0.99864
# [16]	validation_0-rmse:0.97772	validation_1-rmse:0.97128
# [17]	validation_0-rmse:0.95067	validation_1-rmse:0.94683
# [18]	validation_0-rmse:0.92557	validation_1-rmse:0.92569
# [19]	validation_0-rmse:0.90317	validation_1-rmse:0.90722
# [20]	validation_0-rmse:0.88339	validation_1-rmse:0.89289
# [21]	validation_0-rmse:0.86475	validation_1-rmse:0.88166
# [22]	validation_0-rmse:0.84778	validation_1-rmse:0.87527
# [23]	validation_0-rmse:0.83267	validation_1-rmse:0.86254
# [24]	validation_0-rmse:0.81679	validation_1-rmse:0.85661
# [25]	validation_0-rmse:0.80394	validation_1-rmse:0.84789
# [26]	validation_0-rmse:0.79121	validation_1-rmse:0.83812
# [27]	validation_0-rmse:0.77950	validation_1-rmse:0.83319
# [28]	validation_0-rmse:0.76934	validation_1-rmse:0.82802
# [29]	validation_0-rmse:0.75994	validation_1-rmse:0.82263
# [30]	validation_0-rmse:0.75022	validation_1-rmse:0.81759
# [31]	validation_0-rmse:0.74320	validation_1-rmse:0.81822
# [32]	validation_0-rmse:0.73548	validation_1-rmse:0.81214
# [33]	validation_0-rmse:0.72959	validation_1-rmse:0.81007
# [34]	validation_0-rmse:0.72370	validation_1-rmse:0.80639
# [35]	validation_0-rmse:0.71709	validation_1-rmse:0.80582
# [36]	validation_0-rmse:0.71135	validation_1-rmse:0.80024
# [37]	validation_0-rmse:0.70581	validation_1-rmse:0.79956
# [38]	validation_0-rmse:0.70186	validation_1-rmse:0.79845
# [39]	validation_0-rmse:0.69809	validation_1-rmse:0.79731
# [40]	validation_0-rmse:0.69370	validation_1-rmse:0.79532
# [41]	validation_0-rmse:0.68941	validation_1-rmse:0.79365
# [42]	validation_0-rmse:0.68646	validation_1-rmse:0.79356
# [43]	validation_0-rmse:0.68318	validation_1-rmse:0.79257
# [44]	validation_0-rmse:0.68031	validation_1-rmse:0.79233
# [45]	validation_0-rmse:0.67825	validation_1-rmse:0.79238
# [46]	validation_0-rmse:0.67391	validation_1-rmse:0.79465
# [47]	validation_0-rmse:0.66888	validation_1-rmse:0.79827
# [48]	validation_0-rmse:0.66593	validation_1-rmse:0.79852
# [49]	validation_0-rmse:0.66320	validation_1-rmse:0.79901
# [50]	validation_0-rmse:0.66086	validation_1-rmse:0.79857
# [51]	validation_0-rmse:0.65756	validation_1-rmse:0.79984
# [52]	validation_0-rmse:0.65349	validation_1-rmse:0.79970
# [53]	validation_0-rmse:0.65092	validation_1-rmse:0.79698
# [54]	validation_0-rmse:0.64826	validation_1-rmse:0.79457
# [55]	validation_0-rmse:0.64634	validation_1-rmse:0.79412
# [56]	validation_0-rmse:0.64379	validation_1-rmse:0.79108
# [57]	validation_0-rmse:0.64207	validation_1-rmse:0.79142
# [58]	validation_0-rmse:0.64051	validation_1-rmse:0.79101
# [59]	validation_0-rmse:0.63907	validation_1-rmse:0.79130
# [60]	validation_0-rmse:0.63686	validation_1-rmse:0.78846
# [61]	validation_0-rmse:0.63266	validation_1-rmse:0.79077
# [62]	validation_0-rmse:0.63148	validation_1-rmse:0.79141
# [63]	validation_0-rmse:0.62783	validation_1-rmse:0.79568
# [64]	validation_0-rmse:0.62433	validation_1-rmse:0.79830
# [65]	validation_0-rmse:0.62134	validation_1-rmse:0.79582
# [66]	validation_0-rmse:0.61957	validation_1-rmse:0.79549
# [67]	validation_0-rmse:0.61836	validation_1-rmse:0.79513
# [68]	validation_0-rmse:0.61727	validation_1-rmse:0.79527
# [69]	validation_0-rmse:0.61591	validation_1-rmse:0.79659
# [70]	validation_0-rmse:0.61286	validation_1-rmse:0.79858
# [71]	validation_0-rmse:0.61013	validation_1-rmse:0.80047
# [72]	validation_0-rmse:0.60903	validation_1-rmse:0.80010
# [73]	validation_0-rmse:0.60753	validation_1-rmse:0.80041
# [74]	validation_0-rmse:0.60616	validation_1-rmse:0.80083
# [75]	validation_0-rmse:0.60527	validation_1-rmse:0.80092
# [76]	validation_0-rmse:0.60425	validation_1-rmse:0.80207
# [77]	validation_0-rmse:0.60183	validation_1-rmse:0.79935
# [78]	validation_0-rmse:0.59987	validation_1-rmse:0.80007
# [79]	validation_0-rmse:0.59723	validation_1-rmse:0.80371
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.96267	validation_1-rmse:1.80668
# [1]	validation_0-rmse:1.86000	validation_1-rmse:1.70614
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:1.76323	validation_1-rmse:1.61254
# [3]	validation_0-rmse:1.67446	validation_1-rmse:1.53267
# [4]	validation_0-rmse:1.59063	validation_1-rmse:1.45343
# [5]	validation_0-rmse:1.51404	validation_1-rmse:1.38212
# [6]	validation_0-rmse:1.44239	validation_1-rmse:1.31588
# [7]	validation_0-rmse:1.37727	validation_1-rmse:1.25552
# [8]	validation_0-rmse:1.31695	validation_1-rmse:1.20263
# [9]	validation_0-rmse:1.26053	validation_1-rmse:1.15278
# [10]	validation_0-rmse:1.20970	validation_1-rmse:1.11076
# [11]	validation_0-rmse:1.16268	validation_1-rmse:1.07243
# [12]	validation_0-rmse:1.11837	validation_1-rmse:1.03632
# [13]	validation_0-rmse:1.07875	validation_1-rmse:1.00481
# [14]	validation_0-rmse:1.04226	validation_1-rmse:0.98220
# [15]	validation_0-rmse:1.00921	validation_1-rmse:0.95837
# [16]	validation_0-rmse:0.97890	validation_1-rmse:0.93722
# [17]	validation_0-rmse:0.95142	validation_1-rmse:0.92066
# [18]	validation_0-rmse:0.92604	validation_1-rmse:0.90675
# [19]	validation_0-rmse:0.90240	validation_1-rmse:0.89055
# [20]	validation_0-rmse:0.87983	validation_1-rmse:0.87896
# [21]	validation_0-rmse:0.86026	validation_1-rmse:0.86804
# [22]	validation_0-rmse:0.84244	validation_1-rmse:0.85872
# [23]	validation_0-rmse:0.82476	validation_1-rmse:0.85090
# [24]	validation_0-rmse:0.80946	validation_1-rmse:0.84648
# [25]	validation_0-rmse:0.79435	validation_1-rmse:0.84096
# [26]	validation_0-rmse:0.78090	validation_1-rmse:0.83651
# [27]	validation_0-rmse:0.76984	validation_1-rmse:0.83170
# [28]	validation_0-rmse:0.75981	validation_1-rmse:0.83007
# [29]	validation_0-rmse:0.74908	validation_1-rmse:0.82740
# [30]	validation_0-rmse:0.74047	validation_1-rmse:0.82648
# [31]	validation_0-rmse:0.73261	validation_1-rmse:0.82483
# [32]	validation_0-rmse:0.72452	validation_1-rmse:0.82381
# [33]	validation_0-rmse:0.71653	validation_1-rmse:0.82343
# [34]	validation_0-rmse:0.71025	validation_1-rmse:0.82310
# [35]	validation_0-rmse:0.70348	validation_1-rmse:0.82325
# [36]	validation_0-rmse:0.69759	validation_1-rmse:0.82310
# ...
# [32]	validation_0-rmse:0.73187	validation_1-rmse:0.81699
# [33]	validation_0-rmse:0.72514	validation_1-rmse:0.82089
# [34]	validation_0-rmse:0.71853	validation_1-rmse:0.81786
# [35]	validation_0-rmse:0.71206	validation_1-rmse:0.82001
# [36]	validation_0-rmse:0.70666	validation_1-rmse:0.81748
# [37]	validation_0-rmse:0.70107	validation_1-rmse:0.81969
# [38]	validation_0-rmse:0.69667	validation_1-rmse:0.82234
# [39]	validation_0-rmse:0.69270	validation_1-rmse:0.82369
# [40]	validation_0-rmse:0.68832	validation_1-rmse:0.82375
# [41]	validation_0-rmse:0.68214	validation_1-rmse:0.82660
# [42]	validation_0-rmse:0.67849	validation_1-rmse:0.82941
# [43]	validation_0-rmse:0.67504	validation_1-rmse:0.82985
# [44]	validation_0-rmse:0.67253	validation_1-rmse:0.83065
# [45]	validation_0-rmse:0.66951	validation_1-rmse:0.83120
# [46]	validation_0-rmse:0.66455	validation_1-rmse:0.83138
# [47]	validation_0-rmse:0.66074	validation_1-rmse:0.83141
# [48]	validation_0-rmse:0.65764	validation_1-rmse:0.83594
# [49]	validation_0-rmse:0.65525	validation_1-rmse:0.83829
# [50]	validation_0-rmse:0.65071	validation_1-rmse:0.83750
# [51]	validation_0-rmse:0.64803	validation_1-rmse:0.84088
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.90296	validation_1-rmse:2.05936
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.80354	validation_1-rmse:1.96421
# [2]	validation_0-rmse:1.71277	validation_1-rmse:1.87529
# [3]	validation_0-rmse:1.62605	validation_1-rmse:1.79508
# [4]	validation_0-rmse:1.54787	validation_1-rmse:1.71844
# [5]	validation_0-rmse:1.47253	validation_1-rmse:1.64941
# [6]	validation_0-rmse:1.40480	validation_1-rmse:1.58237
# [7]	validation_0-rmse:1.34328	validation_1-rmse:1.52154
# [8]	validation_0-rmse:1.28464	validation_1-rmse:1.46881
# [9]	validation_0-rmse:1.23147	validation_1-rmse:1.41777
# [10]	validation_0-rmse:1.18178	validation_1-rmse:1.37278
# [11]	validation_0-rmse:1.13635	validation_1-rmse:1.33313
# [12]	validation_0-rmse:1.09582	validation_1-rmse:1.29356
# [13]	validation_0-rmse:1.05747	validation_1-rmse:1.25635
# [14]	validation_0-rmse:1.02253	validation_1-rmse:1.22352
# [15]	validation_0-rmse:0.99073	validation_1-rmse:1.19537
# [16]	validation_0-rmse:0.96124	validation_1-rmse:1.16934
# [17]	validation_0-rmse:0.93453	validation_1-rmse:1.14635
# [18]	validation_0-rmse:0.90958	validation_1-rmse:1.12330
# [19]	validation_0-rmse:0.88789	validation_1-rmse:1.10368
# [20]	validation_0-rmse:0.86775	validation_1-rmse:1.08764
# [21]	validation_0-rmse:0.84960	validation_1-rmse:1.07217
# [22]	validation_0-rmse:0.83320	validation_1-rmse:1.05821
# [23]	validation_0-rmse:0.81730	validation_1-rmse:1.04133
# [24]	validation_0-rmse:0.80279	validation_1-rmse:1.02910
# [25]	validation_0-rmse:0.79004	validation_1-rmse:1.01720
# [26]	validation_0-rmse:0.77802	validation_1-rmse:1.00408
# [27]	validation_0-rmse:0.76738	validation_1-rmse:0.99642
# [28]	validation_0-rmse:0.75809	validation_1-rmse:0.98978
# [29]	validation_0-rmse:0.74883	validation_1-rmse:0.98280
# [30]	validation_0-rmse:0.73822	validation_1-rmse:0.96998
# [31]	validation_0-rmse:0.73041	validation_1-rmse:0.96526
# [32]	validation_0-rmse:0.72353	validation_1-rmse:0.95915
# [33]	validation_0-rmse:0.71774	validation_1-rmse:0.95531
# [34]	validation_0-rmse:0.71132	validation_1-rmse:0.94847
# [35]	validation_0-rmse:0.70656	validation_1-rmse:0.94546
# [36]	validation_0-rmse:0.70138	validation_1-rmse:0.93934
# [37]	validation_0-rmse:0.69635	validation_1-rmse:0.93381
# [38]	validation_0-rmse:0.69252	validation_1-rmse:0.93343
# [39]	validation_0-rmse:0.68854	validation_1-rmse:0.93285
# [40]	validation_0-rmse:0.68362	validation_1-rmse:0.93037
# [41]	validation_0-rmse:0.68057	validation_1-rmse:0.92914
# [42]	validation_0-rmse:0.67654	validation_1-rmse:0.92520
# [43]	validation_0-rmse:0.67373	validation_1-rmse:0.92525
# [44]	validation_0-rmse:0.67159	validation_1-rmse:0.92606
# [45]	validation_0-rmse:0.66961	validation_1-rmse:0.92526
# [46]	validation_0-rmse:0.66613	validation_1-rmse:0.92406
# [47]	validation_0-rmse:0.66299	validation_1-rmse:0.92320
# [48]	validation_0-rmse:0.66075	validation_1-rmse:0.91938
# [49]	validation_0-rmse:0.65776	validation_1-rmse:0.91679
# [50]	validation_0-rmse:0.65505	validation_1-rmse:0.91155
# [51]	validation_0-rmse:0.65092	validation_1-rmse:0.90789
# [52]	validation_0-rmse:0.64850	validation_1-rmse:0.90297
# [53]	validation_0-rmse:0.64428	validation_1-rmse:0.89988
# [54]	validation_0-rmse:0.64205	validation_1-rmse:0.89280
# [55]	validation_0-rmse:0.64043	validation_1-rmse:0.88939
# [56]	validation_0-rmse:0.63782	validation_1-rmse:0.88643
# [57]	validation_0-rmse:0.63639	validation_1-rmse:0.88333
# [58]	validation_0-rmse:0.63506	validation_1-rmse:0.88033
# [59]	validation_0-rmse:0.63353	validation_1-rmse:0.87927
# [60]	validation_0-rmse:0.63117	validation_1-rmse:0.87937
# [61]	validation_0-rmse:0.62908	validation_1-rmse:0.87995
# [62]	validation_0-rmse:0.62797	validation_1-rmse:0.87745
# [63]	validation_0-rmse:0.62600	validation_1-rmse:0.87852
# [64]	validation_0-rmse:0.62433	validation_1-rmse:0.87622
# [65]	validation_0-rmse:0.62106	validation_1-rmse:0.87137
# [66]	validation_0-rmse:0.62016	validation_1-rmse:0.87207
# [67]	validation_0-rmse:0.61871	validation_1-rmse:0.86675
# [68]	validation_0-rmse:0.61732	validation_1-rmse:0.86685
# [69]	validation_0-rmse:0.61619	validation_1-rmse:0.86480
# [70]	validation_0-rmse:0.61475	validation_1-rmse:0.86417
# [71]	validation_0-rmse:0.61380	validation_1-rmse:0.86189
# [72]	validation_0-rmse:0.61100	validation_1-rmse:0.85775
# [73]	validation_0-rmse:0.61010	validation_1-rmse:0.85595
# [74]	validation_0-rmse:0.60929	validation_1-rmse:0.85429
# [75]	validation_0-rmse:0.60795	validation_1-rmse:0.85261
# [76]	validation_0-rmse:0.60663	validation_1-rmse:0.85335
# [77]	validation_0-rmse:0.60542	validation_1-rmse:0.85168
# [78]	validation_0-rmse:0.60412	validation_1-rmse:0.85000
# [79]	validation_0-rmse:0.60236	validation_1-rmse:0.84919
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.92013	validation_1-rmse:1.99265
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.82062	validation_1-rmse:1.88994
# [2]	validation_0-rmse:1.73091	validation_1-rmse:1.80261
# [3]	validation_0-rmse:1.64509	validation_1-rmse:1.71466
# [4]	validation_0-rmse:1.56517	validation_1-rmse:1.63048
# [5]	validation_0-rmse:1.49232	validation_1-rmse:1.55575
# [6]	validation_0-rmse:1.42385	validation_1-rmse:1.48320
# [7]	validation_0-rmse:1.36286	validation_1-rmse:1.42589
# [8]	validation_0-rmse:1.30475	validation_1-rmse:1.36745
# [9]	validation_0-rmse:1.25107	validation_1-rmse:1.31001
# [10]	validation_0-rmse:1.20209	validation_1-rmse:1.25870
# [11]	validation_0-rmse:1.15727	validation_1-rmse:1.21432
# [12]	validation_0-rmse:1.11645	validation_1-rmse:1.17517
# [13]	validation_0-rmse:1.07824	validation_1-rmse:1.13610
# [14]	validation_0-rmse:1.04316	validation_1-rmse:1.09900
# [15]	validation_0-rmse:1.01060	validation_1-rmse:1.06699
# [16]	validation_0-rmse:0.98160	validation_1-rmse:1.04007
# [17]	validation_0-rmse:0.95416	validation_1-rmse:1.01335
# [18]	validation_0-rmse:0.92847	validation_1-rmse:0.99242
# [19]	validation_0-rmse:0.90482	validation_1-rmse:0.97312
# [20]	validation_0-rmse:0.88429	validation_1-rmse:0.95332
# [21]	validation_0-rmse:0.86668	validation_1-rmse:0.93318
# [22]	validation_0-rmse:0.85087	validation_1-rmse:0.91777
# [23]	validation_0-rmse:0.83479	validation_1-rmse:0.90548
# [24]	validation_0-rmse:0.81992	validation_1-rmse:0.88948
# [25]	validation_0-rmse:0.80625	validation_1-rmse:0.87927
# [26]	validation_0-rmse:0.79463	validation_1-rmse:0.86708
# [27]	validation_0-rmse:0.78236	validation_1-rmse:0.85989
# [28]	validation_0-rmse:0.77260	validation_1-rmse:0.85158
# [29]	validation_0-rmse:0.76295	validation_1-rmse:0.84468
# [30]	validation_0-rmse:0.75226	validation_1-rmse:0.83233
# [31]	validation_0-rmse:0.74459	validation_1-rmse:0.82612
# [32]	validation_0-rmse:0.73718	validation_1-rmse:0.82159
# [33]	validation_0-rmse:0.72936	validation_1-rmse:0.81690
# [34]	validation_0-rmse:0.72259	validation_1-rmse:0.81028
# [35]	validation_0-rmse:0.71725	validation_1-rmse:0.80806
# [36]	validation_0-rmse:0.71180	validation_1-rmse:0.80510
# [37]	validation_0-rmse:0.70542	validation_1-rmse:0.80403
# [38]	validation_0-rmse:0.70171	validation_1-rmse:0.79971
# [39]	validation_0-rmse:0.69844	validation_1-rmse:0.79645
# [40]	validation_0-rmse:0.69322	validation_1-rmse:0.79267
# [41]	validation_0-rmse:0.68905	validation_1-rmse:0.79025
# [42]	validation_0-rmse:0.68525	validation_1-rmse:0.79031
# [43]	validation_0-rmse:0.68291	validation_1-rmse:0.78894
# [44]	validation_0-rmse:0.68081	validation_1-rmse:0.78770
# [45]	validation_0-rmse:0.67780	validation_1-rmse:0.78756
# [46]	validation_0-rmse:0.67407	validation_1-rmse:0.78419
# [47]	validation_0-rmse:0.67104	validation_1-rmse:0.78302
# [48]	validation_0-rmse:0.66813	validation_1-rmse:0.78482
# [49]	validation_0-rmse:0.66539	validation_1-rmse:0.78593
# [50]	validation_0-rmse:0.66292	validation_1-rmse:0.78716
# [51]	validation_0-rmse:0.65951	validation_1-rmse:0.78366
# [52]	validation_0-rmse:0.65736	validation_1-rmse:0.78511
# [53]	validation_0-rmse:0.65361	validation_1-rmse:0.78300
# [54]	validation_0-rmse:0.64996	validation_1-rmse:0.78445
# [55]	validation_0-rmse:0.64807	validation_1-rmse:0.78587
# [56]	validation_0-rmse:0.64498	validation_1-rmse:0.78314
# [57]	validation_0-rmse:0.64331	validation_1-rmse:0.78472
# [58]	validation_0-rmse:0.64180	validation_1-rmse:0.78634
# [59]	validation_0-rmse:0.63819	validation_1-rmse:0.79098
# [60]	validation_0-rmse:0.63562	validation_1-rmse:0.78860
# [61]	validation_0-rmse:0.63336	validation_1-rmse:0.78821
# [62]	validation_0-rmse:0.63205	validation_1-rmse:0.79000
# [63]	validation_0-rmse:0.62943	validation_1-rmse:0.78925
# [64]	validation_0-rmse:0.62650	validation_1-rmse:0.78787
# [65]	validation_0-rmse:0.62259	validation_1-rmse:0.78491
# [66]	validation_0-rmse:0.62022	validation_1-rmse:0.78768
# [67]	validation_0-rmse:0.61726	validation_1-rmse:0.78911
# [68]	validation_0-rmse:0.61649	validation_1-rmse:0.78908
# [69]	validation_0-rmse:0.61474	validation_1-rmse:0.79064
# [70]	validation_0-rmse:0.61287	validation_1-rmse:0.79036
# [71]	validation_0-rmse:0.60973	validation_1-rmse:0.79500
# [72]	validation_0-rmse:0.60857	validation_1-rmse:0.79664
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.92739	validation_1-rmse:1.95627
# [1]	validation_0-rmse:1.82655	validation_1-rmse:1.85810
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:1.73474	validation_1-rmse:1.76390
# [3]	validation_0-rmse:1.64885	validation_1-rmse:1.67564
# [4]	validation_0-rmse:1.56891	validation_1-rmse:1.59275
# [5]	validation_0-rmse:1.49478	validation_1-rmse:1.51763
# [6]	validation_0-rmse:1.42755	validation_1-rmse:1.44724
# [7]	validation_0-rmse:1.36590	validation_1-rmse:1.38857
# [8]	validation_0-rmse:1.30683	validation_1-rmse:1.33374
# [9]	validation_0-rmse:1.25303	validation_1-rmse:1.28625
# [10]	validation_0-rmse:1.20284	validation_1-rmse:1.24023
# [11]	validation_0-rmse:1.15679	validation_1-rmse:1.19825
# [12]	validation_0-rmse:1.11549	validation_1-rmse:1.16211
# [13]	validation_0-rmse:1.07690	validation_1-rmse:1.12659
# [14]	validation_0-rmse:1.04098	validation_1-rmse:1.09760
# [15]	validation_0-rmse:1.00758	validation_1-rmse:1.06713
# [16]	validation_0-rmse:0.97759	validation_1-rmse:1.04098
# [17]	validation_0-rmse:0.95050	validation_1-rmse:1.01990
# [18]	validation_0-rmse:0.92557	validation_1-rmse:1.00096
# [19]	validation_0-rmse:0.90334	validation_1-rmse:0.98194
# [20]	validation_0-rmse:0.88329	validation_1-rmse:0.96787
# [21]	validation_0-rmse:0.86491	validation_1-rmse:0.95253
# [22]	validation_0-rmse:0.84806	validation_1-rmse:0.93742
# [23]	validation_0-rmse:0.83293	validation_1-rmse:0.92333
# [24]	validation_0-rmse:0.81762	validation_1-rmse:0.90825
# [25]	validation_0-rmse:0.80456	validation_1-rmse:0.89524
# [26]	validation_0-rmse:0.79265	validation_1-rmse:0.88424
# [27]	validation_0-rmse:0.78178	validation_1-rmse:0.87960
# [28]	validation_0-rmse:0.77229	validation_1-rmse:0.87321
# [29]	validation_0-rmse:0.76242	validation_1-rmse:0.86595
# [30]	validation_0-rmse:0.75361	validation_1-rmse:0.86610
# [31]	validation_0-rmse:0.74680	validation_1-rmse:0.86088
# [32]	validation_0-rmse:0.73955	validation_1-rmse:0.85334
# [33]	validation_0-rmse:0.73090	validation_1-rmse:0.84799
# [34]	validation_0-rmse:0.72493	validation_1-rmse:0.84644
# [35]	validation_0-rmse:0.71754	validation_1-rmse:0.84210
# [36]	validation_0-rmse:0.71019	validation_1-rmse:0.84035
# [37]	validation_0-rmse:0.70389	validation_1-rmse:0.83690
# [38]	validation_0-rmse:0.70006	validation_1-rmse:0.83436
# [39]	validation_0-rmse:0.69652	validation_1-rmse:0.83261
# [40]	validation_0-rmse:0.69249	validation_1-rmse:0.83087
# [41]	validation_0-rmse:0.68680	validation_1-rmse:0.83085
# [42]	validation_0-rmse:0.68268	validation_1-rmse:0.82882
# [43]	validation_0-rmse:0.68022	validation_1-rmse:0.82785
# [44]	validation_0-rmse:0.67791	validation_1-rmse:0.82690
# [45]	validation_0-rmse:0.67584	validation_1-rmse:0.82603
# [46]	validation_0-rmse:0.67219	validation_1-rmse:0.82459
# [47]	validation_0-rmse:0.66771	validation_1-rmse:0.82552
# [48]	validation_0-rmse:0.66459	validation_1-rmse:0.82444
# [49]	validation_0-rmse:0.66154	validation_1-rmse:0.82363
# [50]	validation_0-rmse:0.65892	validation_1-rmse:0.82289
# [51]	validation_0-rmse:0.65588	validation_1-rmse:0.82240
# [52]	validation_0-rmse:0.65355	validation_1-rmse:0.82180
# [53]	validation_0-rmse:0.65065	validation_1-rmse:0.82193
# [54]	validation_0-rmse:0.64870	validation_1-rmse:0.82161
# [55]	validation_0-rmse:0.64686	validation_1-rmse:0.82123
# [56]	validation_0-rmse:0.64335	validation_1-rmse:0.82266
# [57]	validation_0-rmse:0.64170	validation_1-rmse:0.82237
# [58]	validation_0-rmse:0.64023	validation_1-rmse:0.82355
# [59]	validation_0-rmse:0.63885	validation_1-rmse:0.82314
# [60]	validation_0-rmse:0.63548	validation_1-rmse:0.82105
# [61]	validation_0-rmse:0.63244	validation_1-rmse:0.81900
# [62]	validation_0-rmse:0.63114	validation_1-rmse:0.81850
# [63]	validation_0-rmse:0.62785	validation_1-rmse:0.82067
# [64]	validation_0-rmse:0.62474	validation_1-rmse:0.82047
# [65]	validation_0-rmse:0.62238	validation_1-rmse:0.81612
# [66]	validation_0-rmse:0.62076	validation_1-rmse:0.81729
# [67]	validation_0-rmse:0.61864	validation_1-rmse:0.81338
# [68]	validation_0-rmse:0.61667	validation_1-rmse:0.81186
# [69]	validation_0-rmse:0.61484	validation_1-rmse:0.81438
# [70]	validation_0-rmse:0.61281	validation_1-rmse:0.81495
# [71]	validation_0-rmse:0.61178	validation_1-rmse:0.81483
# [72]	validation_0-rmse:0.60881	validation_1-rmse:0.81290
# [73]	validation_0-rmse:0.60750	validation_1-rmse:0.81275
# [74]	validation_0-rmse:0.60631	validation_1-rmse:0.81261
# [75]	validation_0-rmse:0.60353	validation_1-rmse:0.80973
# [76]	validation_0-rmse:0.60170	validation_1-rmse:0.81234
# [77]	validation_0-rmse:0.59976	validation_1-rmse:0.80888
# [78]	validation_0-rmse:0.59894	validation_1-rmse:0.80997
# [79]	validation_0-rmse:0.59647	validation_1-rmse:0.81194
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-0.3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.294
# Uncertainty
# a0: 1.589+/-0.082
# a1: 0.293+/-0.032

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: r2019B04: mean - 0.112, median - 0.11, CI - [0.091-0.134]
#
# SHAP-values for: r2019B07: mean - 0.201, median - 0.202, CI - [0.181-0.225]
#
# SHAP-values for: r2019B09: mean - 0.205, median - 0.205, CI - [0.178-0.232]
#
# SHAP-values for: r2019B10: mean - 0.114, median - 0.115, CI - [0.088-0.138]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=[ 'r2019B09', 'r2019B07', 'r2019B10', 'r2019B04'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 64.405, median: 71.0,
#  pred. interval (P(0.025)-P(0.975)): 30.975-79.0,
#  conf. interval (p-value=0.95): 45.813-78.155
# ***
# Aggregate bias statistic:
#  mean: -0.047, median: -0.039,
#  pred. interval (P(0.025)-P(0.975)): -0.269-0.165,
#  conf. interval (p-value=0.95): -0.137-0.046
# ***
# Aggregate RMSE statistic:
#  mean: 0.793, median: 0.798, pred. interval (P(0.025)-P(0.975)): 0.63-0.948,
#  conf. interval (p-value=0.95): 0.716-0.864
# ***
# Aggregate MSE statistic:
#  mean: 0.635, median: 0.637, pred. interval (P(0.025)-P(0.975)): 0.397-0.898,
#  conf. interval (p-value=0.95): 0.514-0.746
# ***
# Aggregate R^2 statistic:
#  mean: 0.27, median: 0.289, pred. interval (P(0.025)-P(0.975)): -0.022-0.464,
#  conf. interval (p-value=0.95): 0.17-0.366
# ***
# Aggregate bias(%) statistic:
#  mean: -1.832, median: -1.78, pred. interval (P(0.025)-P(0.975)): -10.685-7.765,
#  conf. interval (p-value=0.95): -5.816-2.065
# ***
# Aggregate RMSE(%) statistic:
#  mean: 34.419, median: 34.627, pred. interval (P(0.025)-P(0.975)): 27.347-42.954,
#  conf. interval (p-value=0.95): 30.244-38.128
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -4.061, median: -3.799,
#  pred. interval (P(0.025)-P(0.975)): -7.317--1.15,
#  conf. interval (p-value=0.95): -5.59--2.638
# ***
# Aggregate RMSE statistic:
#  mean: 12.41, median: 11.796, pred. interval (P(0.025)-P(0.975)): 7.315-19.012,
#  conf. interval (p-value=0.95): 9.23-16.008
# ***
# Aggregate MSE statistic:
#  mean: 165.779, median: 139.155, pred. interval (P(0.025)-P(0.975)): 53.505-361.494,
#  conf. interval (p-value=0.95): 85.974-258.355
# ***
# Aggregate R^2 statistic:
#  mean: 0.167, median: 0.171, pred. interval (P(0.025)-P(0.975)): -0.056-0.416,
#  conf. interval (p-value=0.95): 0.075-0.266
# ***
# Aggregate bias(%) statistic:
#  mean: -26.337, median: -26.379, pred. interval (P(0.025)-P(0.975)): -40.296--9.839,
#  conf. interval (p-value=0.95): -33.211--19.754
# ***
# Aggregate RMSE(%) statistic:
#  mean: 81.749, median: 79.441, pred. interval (P(0.025)-P(0.975)): 57.503-112.913,
#  conf. interval (p-value=0.95): 66.192-95.91
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [0, 1, 2, 3, 4])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 5, 10, 20, 30, 50, 100])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.93297
# [1]	validation_0-rmse:1.83165
# [2]	validation_0-rmse:1.73792
# [3]	validation_0-rmse:1.65055
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:1.57026
# [5]	validation_0-rmse:1.49606
# [6]	validation_0-rmse:1.42699
# [7]	validation_0-rmse:1.36370
# [8]	validation_0-rmse:1.30507
# [9]	validation_0-rmse:1.25142
# [10]	validation_0-rmse:1.20276
# [11]	validation_0-rmse:1.15725
# [12]	validation_0-rmse:1.11469
# [13]	validation_0-rmse:1.07463
# [14]	validation_0-rmse:1.03965
# [15]	validation_0-rmse:1.00800
# [16]	validation_0-rmse:0.97898
# [17]	validation_0-rmse:0.95171
# [18]	validation_0-rmse:0.92703
# [19]	validation_0-rmse:0.90502
# [20]	validation_0-rmse:0.88472
# [21]	validation_0-rmse:0.86683
# [22]	validation_0-rmse:0.84864
# [23]	validation_0-rmse:0.83231
# [24]	validation_0-rmse:0.81746
# [25]	validation_0-rmse:0.80544
# [26]	validation_0-rmse:0.79435
# [27]	validation_0-rmse:0.78297
# [28]	validation_0-rmse:0.77358
# [29]	validation_0-rmse:0.76515
# [30]	validation_0-rmse:0.75750
# [31]	validation_0-rmse:0.74991
# [32]	validation_0-rmse:0.74295
# [33]	validation_0-rmse:0.73752
# [34]	validation_0-rmse:0.73228
# [35]	validation_0-rmse:0.72763
# [36]	validation_0-rmse:0.72225
# [37]	validation_0-rmse:0.71773
# [38]	validation_0-rmse:0.71253
# [39]	validation_0-rmse:0.70873
# [40]	validation_0-rmse:0.70438
# [41]	validation_0-rmse:0.70011
# [42]	validation_0-rmse:0.69495
# [43]	validation_0-rmse:0.69097
# [44]	validation_0-rmse:0.68814
# [45]	validation_0-rmse:0.68383
# [46]	validation_0-rmse:0.68104
# [47]	validation_0-rmse:0.67888
# [48]	validation_0-rmse:0.67589
# [49]	validation_0-rmse:0.67302
# [50]	validation_0-rmse:0.67037
# [51]	validation_0-rmse:0.66792
# [52]	validation_0-rmse:0.66649
# [53]	validation_0-rmse:0.66441
# [54]	validation_0-rmse:0.66132
# [55]	validation_0-rmse:0.65969
# [56]	validation_0-rmse:0.65760
# [57]	validation_0-rmse:0.65444
# [58]	validation_0-rmse:0.65291
# [59]	validation_0-rmse:0.64973
# [60]	validation_0-rmse:0.64604
# [61]	validation_0-rmse:0.64325
# [62]	validation_0-rmse:0.63997
# [63]	validation_0-rmse:0.63875
# [64]	validation_0-rmse:0.63692
# [65]	validation_0-rmse:0.63478
# [66]	validation_0-rmse:0.63364
# [67]	validation_0-rmse:0.63239
# [68]	validation_0-rmse:0.62911
# [69]	validation_0-rmse:0.62704
# [70]	validation_0-rmse:0.62596
# [71]	validation_0-rmse:0.62307
# [72]	validation_0-rmse:0.62195
# [73]	validation_0-rmse:0.62008
# [74]	validation_0-rmse:0.61862
# [75]	validation_0-rmse:0.61586
# [76]	validation_0-rmse:0.61417
# [77]	validation_0-rmse:0.61151
# [78]	validation_0-rmse:0.60950
# [79]	validation_0-rmse:0.60796
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 79

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.44
# RMSE: 0.6
# Relative RMSE(%):  26.335
# MSE: 0.4
# R square: 58.9%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-0.3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.626
# Uncertainty
# a0: 1.20+/-0.06
# a1: 0.474+/-0.026

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../05_output_data/XGBoost_models/05_LN_Tag_Sr_SENTINEL_2019_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../05_output_data/XGBoost_models/05_LN_Tag_Sr_SENTINEL_2019_XGB_model.txt")
