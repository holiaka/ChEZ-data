# %% [markdown]
# ## Processing with aboveground biomass data based on my fieldworks and other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
input_data = './FULL_DB_BIOMASS_OTHER_ALL_AUTHORS.csv'
df = pd.read_csv(input_data)
df.head()
# Out:
#    Groups Species  Species_ID Origin  Origin_ID  SI  A_years   H_m  DBH_cm  \
# 0       1    Pine           0      n        0.0   4       50   9.7    14.6
# 1       1    Pine           0      n        0.0   2       65  20.6    20.6
# 2       1    Pine           0      n        0.0   2       50  13.6    15.4
# 3       1    Pine           0      n        0.0   1       60  23.3    22.2
# 4       1    Pine           0      n        0.0   3       65  15.6    16.4
#
#    N_trees  ...  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  \
# 0    486.0  ...             NaN             NaN         8.4           1.6
# 1    785.0  ...             NaN             NaN        11.5           4.1
# 2   1745.0  ...             NaN             NaN        13.7           4.1
# 3    665.0  ...             NaN             NaN        14.4           5.4
# 4    955.0  ...             NaN             NaN        14.2           3.4
#
#    LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  \
# 0         3.78              2.94                NaN                NaN
# 1         5.54              4.73                NaN                NaN
# 2         5.25              4.48                NaN                NaN
# 3         5.63              4.67                NaN                NaN
# 4         4.96              4.20                NaN                NaN
#
#    LN_Crown_t_ha  LN_Foliage_t_ha
# 0           2.13             0.47
# 1           2.44             1.41
# 2           2.62             1.41
# 3           2.67             1.69
# 4           2.65             1.22
#
# [5 rows x 24 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
#
# 'Groups','Species_ID','Origin_ID','SI','A_years','H_m','DBH_cm','RS(P)',          'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
# 'Crown_t_ha','Foliage_t_ha'
# 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species_ID','Origin_ID','H_m','DBH_cm', 'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
'Crown_t_ha','Foliage_t_ha', 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0           0        0.0   9.7    14.6         9.7      43.9           18.9
# 1           0        0.0  20.6    20.6        32.2     254.0          113.1
# 2           0        0.0  13.6    15.4        35.2     190.0           87.8
# 3           0        0.0  23.3    22.2        29.6     277.7          106.5
# 4           0        0.0  15.6    16.4        20.4     142.5           67.0
#
#    Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0             NaN             NaN         8.4           1.6         3.78
# 1             NaN             NaN        11.5           4.1         5.54
# 2             NaN             NaN        13.7           4.1         5.25
# 3             NaN             NaN        14.4           5.4         5.63
# 4             NaN             NaN        14.2           3.4         4.96
#
#    LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0              2.94                NaN                NaN           2.13
# 1              4.73                NaN                NaN           2.44
# 2              4.48                NaN                NaN           2.62
# 3              4.67                NaN                NaN           2.67
# 4              4.20                NaN                NaN           2.65
#
#    LN_Foliage_t_ha
# 0             0.47
# 1             1.41
# 2             1.41
# 3             1.69
# 4             1.22

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Species_ID         857 non-null    int64
#  1   Origin_ID          856 non-null    float64
#  2   H_m                857 non-null    float64
#  3   DBH_cm             856 non-null    float64
#  4   BA_sq_m_ha         857 non-null    float64
#  5   GS_cub_m           857 non-null    float64
#  6   ALL_STEM_t_ha      855 non-null    float64
#  7   Stem_wood_t_ha     747 non-null    float64
#  8   Stem_bark_t_ha     747 non-null    float64
#  9   Crown_t_ha         843 non-null    float64
#  10  Foliage_t_ha       854 non-null    float64
#  11  LN_GS_cub_m        857 non-null    float64
#  12  LN_ALL_STEM_t_ha   855 non-null    float64
#  13  LN_Stem_wood_t_ha  747 non-null    float64
#  14  LN_Stem_bark_t_ha  747 non-null    float64
#  15  LN_Crown_t_ha      843 non-null    float64
#  16  LN_Foliage_t_ha    854 non-null    float64
# dtypes: float64(16), int64(1)
# memory usage: 113.9 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species_ID"])["Foliage_t_ha", "ALL_STEM_t_ha"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            Foliage_t_ha                                                       \
#                   count       mean       std   min      25%     50%      75%
# Species_ID
# 0                 456.0   5.913969  2.521710  0.20   4.1275   5.925   7.5900
# 1                   7.0  15.540000  5.273942  8.32  11.1000  17.220  19.6550
# 2                 120.0   2.630833  2.251376  0.33   1.3625   2.200   3.5525
# 3                 115.0   2.746783  1.336990  0.80   1.8000   2.380   3.4200
# 4                  66.0   3.630455  1.363152  0.93   2.6050   3.520   4.3475
# 5                  90.0   4.213444  1.790589  0.52   2.7275   4.345   5.6850
#
#                   ALL_STEM_t_ha                                              \
#               max         count        mean        std   min     25%    50%
# Species_ID
# 0           14.70         457.0   97.049891  61.854506   1.8  47.500   92.7
# 1           21.73           7.0  123.814286  61.879895  46.3  70.650  133.9
# 2           16.10         120.0   74.495000  44.523333   5.1  37.275   68.1
# 3            7.58         115.0  107.607826  55.589186  11.0  62.700  106.8
# 4            8.57          66.0   84.946970  58.875162   8.2  40.750   61.2
# 5            6.84          90.0  173.065556  99.100647   5.0  93.075  161.3
#
#
#                 75%    max
# Species_ID
# 0           135.900  310.7
# 1           174.550  196.1
# 2           103.075  193.5
# 3           145.450  251.6
# 4           125.000  245.4
# 5           253.375  363.9

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID   Origin_ID         H_m      DBH_cm  BA_sq_m_ha    GS_cub_m  \
# count  857.000000  856.000000  857.000000  856.000000  857.000000  857.000000
# mean     1.529755    0.279206   16.452275   17.132243   26.329988  229.013069
# std      1.823872    0.448871    7.039954   10.439115   10.629993  144.362106
# min      0.000000    0.000000    1.500000    1.100000    1.000000    2.400000
# 25%      0.000000    0.000000   11.200000    9.900000   19.000000  116.000000
# 50%      0.000000    0.000000   16.100000   15.500000   26.800000  206.000000
# 75%      3.000000    1.000000   21.200000   22.100000   34.500000  320.000000
# max      5.000000    1.000000   38.300000   94.000000   51.500000  735.000000
#
#        ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  \
# count     855.000000      747.000000      747.000000  843.000000
# mean      102.590877       92.779518       12.060107   13.821969
# std        68.758819       61.992238        9.595428   11.567546
# min         1.800000        2.000000        0.300000    0.500000
# 25%        47.500000       42.900000        5.950000    6.610000
# 50%        93.500000       84.600000        9.300000   10.820000
# 75%       140.500000      125.500000       15.300000   16.435000
# max       363.900000      315.200000       65.700000   69.120000
#
#        Foliage_t_ha  LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  \
# count    854.000000   857.000000        855.000000         747.000000
# mean       4.749356     5.166919          4.343766           4.246975
# std        2.826586     0.839680          0.869479           0.854856
# min        0.200000     0.880000          0.590000           0.690000
# 25%        2.600000     4.750000          3.860000           3.760000
# 50%        4.300000     5.330000          4.540000           4.440000
# 75%        6.367500     5.770000          4.950000           4.830000
# max       21.730000     6.600000          5.900000           5.750000
#
#        LN_Stem_bark_t_ha  LN_Crown_t_ha  LN_Foliage_t_ha
# count         747.000000     843.000000       854.000000
# mean            2.201232       2.318149         1.364906
# std             0.806766       0.829446         0.672551
# min            -1.200000      -0.690000        -1.610000
# 25%             1.780000       1.890000         0.960000
# 50%             2.230000       2.380000         1.460000
# 75%             2.730000       2.800000         1.850000
# max             4.190000       4.240000         3.080000

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "Foliage_t_ha"
indep_variables = ['Species_ID','Origin_ID','H_m','DBH_cm','BA_sq_m_ha']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0             0        0.0   9.7    14.6         9.7      43.9           18.9
# 1             0        0.0  20.6    20.6        32.2     254.0          113.1
# 2             0        0.0  13.6    15.4        35.2     190.0           87.8
# 3             0        0.0  23.3    22.2        29.6     277.7          106.5
# 4             0        0.0  15.6    16.4        20.4     142.5           67.0
# ..          ...        ...   ...     ...         ...       ...            ...
# 852           3        0.0   7.8     4.4         9.2      39.8           17.8
# 853           3        0.0  12.7     9.0        20.5     123.6           47.1
# 854           3        0.0  12.2     8.1        20.3     141.7           51.9
# 855           2        0.0  14.3    12.4        25.1     176.5          100.7
# 856           2        0.0  21.1    25.6        21.0     191.6           99.9
#
#      Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0               NaN             NaN        8.40          1.60         3.78
# 1               NaN             NaN       11.50          4.10         5.54
# 2               NaN             NaN       13.70          4.10         5.25
# 3               NaN             NaN       14.40          5.40         5.63
# 4               NaN             NaN       14.20          3.40         4.96
# ..              ...             ...         ...           ...          ...
# 852            15.7             2.1        2.26          2.04         3.68
# 853            42.6             4.5        2.14          1.21         4.82
# 854            47.8             4.1        2.11          1.16         4.95
# 855            84.6            16.1       16.90          4.74         5.17
# 856            80.8            19.1       16.60          2.13         5.26
#
#      LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0                2.94                NaN                NaN           2.13
# 1                4.73                NaN                NaN           2.44
# 2                4.48                NaN                NaN           2.62
# 3                4.67                NaN                NaN           2.67
# 4                4.20                NaN                NaN           2.65
# ..                ...                ...                ...            ...
# 852              2.88               2.75               0.74           0.82
# 853              3.85               3.75               1.50           0.76
# 854              3.95               3.87               1.41           0.75
# 855              4.61               4.44               2.78           2.83
# 856              4.60               4.39               2.95           2.81
#
#      LN_Foliage_t_ha
# 0               0.47
# 1               1.41
# 2               1.41
# 3               1.69
# 4               1.22
# ..               ...
# 852             0.71
# 853             0.19
# 854             0.15
# 855             1.56
# 856             0.76
#
# [854 rows x 17 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha
# 0           0        0.0   9.7    14.6         9.7
# 1           0        0.0  20.6    20.6        32.2
# 2           0        0.0  13.6    15.4        35.2
# 3           0        0.0  23.3    22.2        29.6
# 4           0        0.0  15.6    16.4        20.4

# %%
# Columns in "y" data collections
y.head()
# Out:
#    Foliage_t_ha
# 0           1.6
# 1           4.1
# 2           4.1
# 3           5.4
# 4           3.4

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.5190133620034707, 0.5729092841561335, 0.5957036088339955]
#     Mean: 0.563
#     Std: 0.032
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.93198453 1.72519671 1.790532  ]
#     Mean: 1.816
#     Std: 0.086
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [1.2899832011210293, 1.2641557251277722, 1.285303666146708]
#     Mean: 1.280
#     Std: 0.011
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.7735899887742076                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.04912605539468079                 # gamma
print('Gamma: ' + str(p2))

p3 = 0.10427950972801546                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 4            # max_depth
print('Max_depth: ' + str(p4))

p5 = 169         # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.9736807477035929                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.7735899887742076
# Gamma: 0.04912605539468079
# Learning_rate: 0.10427950972801546
# Max_depth: 4
# N_estimators: 169
# Subsample: 0.9736807477035929

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:4.58937	validation_1-rmse:4.97282
# [1]	validation_0-rmse:4.23380	validation_1-rmse:4.59868
# [2]	validation_0-rmse:3.93535	validation_1-rmse:4.27777
# [3]	validation_0-rmse:3.66059	validation_1-rmse:3.98429
# [4]	validation_0-rmse:3.38983	validation_1-rmse:3.71457
# [5]	validation_0-rmse:3.14891	validation_1-rmse:3.49125
# [6]	validation_0-rmse:2.94318	validation_1-rmse:3.30007
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:2.77290	validation_1-rmse:3.12732
# [8]	validation_0-rmse:2.64228	validation_1-rmse:2.98883
# [9]	validation_0-rmse:2.51059	validation_1-rmse:2.86284
# [10]	validation_0-rmse:2.41647	validation_1-rmse:2.76463
# [11]	validation_0-rmse:2.29757	validation_1-rmse:2.66113
# [12]	validation_0-rmse:2.18956	validation_1-rmse:2.57949
# [13]	validation_0-rmse:2.09509	validation_1-rmse:2.50587
# [14]	validation_0-rmse:2.02018	validation_1-rmse:2.44797
# [15]	validation_0-rmse:1.94965	validation_1-rmse:2.39498
# [16]	validation_0-rmse:1.89506	validation_1-rmse:2.35051
# [17]	validation_0-rmse:1.84659	validation_1-rmse:2.30881
# [18]	validation_0-rmse:1.79635	validation_1-rmse:2.27307
# [19]	validation_0-rmse:1.75962	validation_1-rmse:2.24144
# [20]	validation_0-rmse:1.71821	validation_1-rmse:2.21488
# [21]	validation_0-rmse:1.68173	validation_1-rmse:2.19113
# [22]	validation_0-rmse:1.65184	validation_1-rmse:2.17328
# [23]	validation_0-rmse:1.62880	validation_1-rmse:2.15303
# [24]	validation_0-rmse:1.60805	validation_1-rmse:2.13833
# [25]	validation_0-rmse:1.58079	validation_1-rmse:2.12184
# [26]	validation_0-rmse:1.56766	validation_1-rmse:2.11143
# [27]	validation_0-rmse:1.54482	validation_1-rmse:2.11120
# [28]	validation_0-rmse:1.52831	validation_1-rmse:2.10406
# [29]	validation_0-rmse:1.51578	validation_1-rmse:2.09425
# [30]	validation_0-rmse:1.50471	validation_1-rmse:2.08686
# [31]	validation_0-rmse:1.49145	validation_1-rmse:2.08466
# [32]	validation_0-rmse:1.47717	validation_1-rmse:2.08315
# [33]	validation_0-rmse:1.46420	validation_1-rmse:2.07735
# [34]	validation_0-rmse:1.45502	validation_1-rmse:2.07305
# [35]	validation_0-rmse:1.44442	validation_1-rmse:2.06938
# [36]	validation_0-rmse:1.43487	validation_1-rmse:2.06626
# [37]	validation_0-rmse:1.42672	validation_1-rmse:2.06388
# [38]	validation_0-rmse:1.41748	validation_1-rmse:2.04949
# [39]	validation_0-rmse:1.40564	validation_1-rmse:2.04650
# [40]	validation_0-rmse:1.40034	validation_1-rmse:2.04451
# [41]	validation_0-rmse:1.39369	validation_1-rmse:2.04333
# [42]	validation_0-rmse:1.38707	validation_1-rmse:2.03959
# [43]	validation_0-rmse:1.38054	validation_1-rmse:2.03984
# [44]	validation_0-rmse:1.37352	validation_1-rmse:2.02979
# [45]	validation_0-rmse:1.37121	validation_1-rmse:2.02675
# [46]	validation_0-rmse:1.36600	validation_1-rmse:2.02602
# [47]	validation_0-rmse:1.36045	validation_1-rmse:2.02160
# [48]	validation_0-rmse:1.35179	validation_1-rmse:2.02220
# [49]	validation_0-rmse:1.34737	validation_1-rmse:2.02119
# [50]	validation_0-rmse:1.34171	validation_1-rmse:2.01806
# [51]	validation_0-rmse:1.33839	validation_1-rmse:2.02189
# [52]	validation_0-rmse:1.33381	validation_1-rmse:2.01914
# [53]	validation_0-rmse:1.33051	validation_1-rmse:2.02001
# [54]	validation_0-rmse:1.32683	validation_1-rmse:2.01953
# [55]	validation_0-rmse:1.31842	validation_1-rmse:2.01450
# [56]	validation_0-rmse:1.31686	validation_1-rmse:2.01193
# [57]	validation_0-rmse:1.31240	validation_1-rmse:2.01170
# [58]	validation_0-rmse:1.30707	validation_1-rmse:2.00813
# [59]	validation_0-rmse:1.30286	validation_1-rmse:2.00669
# [60]	validation_0-rmse:1.30149	validation_1-rmse:2.00486
# [61]	validation_0-rmse:1.29657	validation_1-rmse:1.99784
# [62]	validation_0-rmse:1.28771	validation_1-rmse:1.99633
# [63]	validation_0-rmse:1.27963	validation_1-rmse:1.99632
# [64]	validation_0-rmse:1.27510	validation_1-rmse:1.99375
# [65]	validation_0-rmse:1.26822	validation_1-rmse:1.99138
# [66]	validation_0-rmse:1.26443	validation_1-rmse:1.99209
# [67]	validation_0-rmse:1.26342	validation_1-rmse:1.99048
# [68]	validation_0-rmse:1.25827	validation_1-rmse:1.98802
# [69]	validation_0-rmse:1.25385	validation_1-rmse:1.98692
# [70]	validation_0-rmse:1.24999	validation_1-rmse:1.98798
# [71]	validation_0-rmse:1.24651	validation_1-rmse:1.98634
# [72]	validation_0-rmse:1.24444	validation_1-rmse:1.98529
# [73]	validation_0-rmse:1.24338	validation_1-rmse:1.98443
# [74]	validation_0-rmse:1.23873	validation_1-rmse:1.98464
# [75]	validation_0-rmse:1.23366	validation_1-rmse:1.98417
# [76]	validation_0-rmse:1.22249	validation_1-rmse:1.98204
# [77]	validation_0-rmse:1.21625	validation_1-rmse:1.97984
# [78]	validation_0-rmse:1.21033	validation_1-rmse:1.97780
# [79]	validation_0-rmse:1.20543	validation_1-rmse:1.98015
# [80]	validation_0-rmse:1.20254	validation_1-rmse:1.98150
# [81]	validation_0-rmse:1.19679	validation_1-rmse:1.97918
# [82]	validation_0-rmse:1.19166	validation_1-rmse:1.97802
# [83]	validation_0-rmse:1.18914	validation_1-rmse:1.97853
# [84]	validation_0-rmse:1.18032	validation_1-rmse:1.97601
# [85]	validation_0-rmse:1.17367	validation_1-rmse:1.97605
# [86]	validation_0-rmse:1.17117	validation_1-rmse:1.97590
# [87]	validation_0-rmse:1.16766	validation_1-rmse:1.97353
# [88]	validation_0-rmse:1.16484	validation_1-rmse:1.97252
# [89]	validation_0-rmse:1.16356	validation_1-rmse:1.97233
# [90]	validation_0-rmse:1.16293	validation_1-rmse:1.97164
# [91]	validation_0-rmse:1.16237	validation_1-rmse:1.97076
# [92]	validation_0-rmse:1.16131	validation_1-rmse:1.97008
# [93]	validation_0-rmse:1.15364	validation_1-rmse:1.96846
# [94]	validation_0-rmse:1.15051	validation_1-rmse:1.96888
# [95]	validation_0-rmse:1.14697	validation_1-rmse:1.96715
# [96]	validation_0-rmse:1.14648	validation_1-rmse:1.96630
# [97]	validation_0-rmse:1.13955	validation_1-rmse:1.96366
# [98]	validation_0-rmse:1.13861	validation_1-rmse:1.96328
# [99]	validation_0-rmse:1.13654	validation_1-rmse:1.96334
# [100]	validation_0-rmse:1.13190	validation_1-rmse:1.96505
# [101]	validation_0-rmse:1.13121	validation_1-rmse:1.96477
# [102]	validation_0-rmse:1.13047	validation_1-rmse:1.96451
# [103]	validation_0-rmse:1.12681	validation_1-rmse:1.96618
# [104]	validation_0-rmse:1.12491	validation_1-rmse:1.96655
# [105]	validation_0-rmse:1.12215	validation_1-rmse:1.96489
# [106]	validation_0-rmse:1.11642	validation_1-rmse:1.96483
# [107]	validation_0-rmse:1.11371	validation_1-rmse:1.96338
# [108]	validation_0-rmse:1.11108	validation_1-rmse:1.96325
# [109]	validation_0-rmse:1.10481	validation_1-rmse:1.96144
# [110]	validation_0-rmse:1.10301	validation_1-rmse:1.96540
# [111]	validation_0-rmse:1.10101	validation_1-rmse:1.96646
# [112]	validation_0-rmse:1.09575	validation_1-rmse:1.96740
# [113]	validation_0-rmse:1.09374	validation_1-rmse:1.96918
# [114]	validation_0-rmse:1.09080	validation_1-rmse:1.96836
# [115]	validation_0-rmse:1.08699	validation_1-rmse:1.96972
# [116]	validation_0-rmse:1.08195	validation_1-rmse:1.97150
# [117]	validation_0-rmse:1.08028	validation_1-rmse:1.97179
# [118]	validation_0-rmse:1.07723	validation_1-rmse:1.97187
# [119]	validation_0-rmse:1.07478	validation_1-rmse:1.97261
# [120]	validation_0-rmse:1.07067	validation_1-rmse:1.97221
# [121]	validation_0-rmse:1.06435	validation_1-rmse:1.96885
# [122]	validation_0-rmse:1.06394	validation_1-rmse:1.96876
# [123]	validation_0-rmse:1.05960	validation_1-rmse:1.96973
# [124]	validation_0-rmse:1.05096	validation_1-rmse:1.97002
# [125]	validation_0-rmse:1.04884	validation_1-rmse:1.96943
# [126]	validation_0-rmse:1.04793	validation_1-rmse:1.96953
# [127]	validation_0-rmse:1.04385	validation_1-rmse:1.97049
# [128]	validation_0-rmse:1.04037	validation_1-rmse:1.97169
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:4.68262	validation_1-rmse:4.59207
# [1]	validation_0-rmse:4.31911	validation_1-rmse:4.24604
# [2]	validation_0-rmse:4.01567	validation_1-rmse:3.94087
# [3]	validation_0-rmse:3.73124	validation_1-rmse:3.65839
# [4]	validation_0-rmse:3.45813	validation_1-rmse:3.40776
# [5]	validation_0-rmse:3.21606	validation_1-rmse:3.19059
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:3.00857	validation_1-rmse:3.00194
# [7]	validation_0-rmse:2.83844	validation_1-rmse:2.84558
# [8]	validation_0-rmse:2.70820	validation_1-rmse:2.72289
# [9]	validation_0-rmse:2.58234	validation_1-rmse:2.60386
# [10]	validation_0-rmse:2.48616	validation_1-rmse:2.51725
# [11]	validation_0-rmse:2.36653	validation_1-rmse:2.42600
# [12]	validation_0-rmse:2.26703	validation_1-rmse:2.34635
# [13]	validation_0-rmse:2.18222	validation_1-rmse:2.27866
# [14]	validation_0-rmse:2.10558	validation_1-rmse:2.21894
# [15]	validation_0-rmse:2.04435	validation_1-rmse:2.17050
# [16]	validation_0-rmse:1.99265	validation_1-rmse:2.13188
# [17]	validation_0-rmse:1.94678	validation_1-rmse:2.09145
# [18]	validation_0-rmse:1.90049	validation_1-rmse:2.05892
# [19]	validation_0-rmse:1.86483	validation_1-rmse:2.03810
# [20]	validation_0-rmse:1.82636	validation_1-rmse:2.00485
# [21]	validation_0-rmse:1.79385	validation_1-rmse:1.98187
# [22]	validation_0-rmse:1.76931	validation_1-rmse:1.96297
# [23]	validation_0-rmse:1.74634	validation_1-rmse:1.94703
# [24]	validation_0-rmse:1.71917	validation_1-rmse:1.91290
# [25]	validation_0-rmse:1.69999	validation_1-rmse:1.89390
# [26]	validation_0-rmse:1.68561	validation_1-rmse:1.88731
# [27]	validation_0-rmse:1.66548	validation_1-rmse:1.87439
# [28]	validation_0-rmse:1.64321	validation_1-rmse:1.84883
# [29]	validation_0-rmse:1.62192	validation_1-rmse:1.84095
# [30]	validation_0-rmse:1.60606	validation_1-rmse:1.83993
# [31]	validation_0-rmse:1.59466	validation_1-rmse:1.83708
# [32]	validation_0-rmse:1.57970	validation_1-rmse:1.81253
# [33]	validation_0-rmse:1.56932	validation_1-rmse:1.80652
# [34]	validation_0-rmse:1.55856	validation_1-rmse:1.79503
# [35]	validation_0-rmse:1.54639	validation_1-rmse:1.79600
# [36]	validation_0-rmse:1.53870	validation_1-rmse:1.79205
# [37]	validation_0-rmse:1.52954	validation_1-rmse:1.78978
# [38]	validation_0-rmse:1.52123	validation_1-rmse:1.78285
# [39]	validation_0-rmse:1.50179	validation_1-rmse:1.76664
# [40]	validation_0-rmse:1.49465	validation_1-rmse:1.76556
# [41]	validation_0-rmse:1.48974	validation_1-rmse:1.76075
# [42]	validation_0-rmse:1.48258	validation_1-rmse:1.75065
# [43]	validation_0-rmse:1.47648	validation_1-rmse:1.74532
# [44]	validation_0-rmse:1.46776	validation_1-rmse:1.74214
# [45]	validation_0-rmse:1.46616	validation_1-rmse:1.74123
# [46]	validation_0-rmse:1.45752	validation_1-rmse:1.72566
# [47]	validation_0-rmse:1.44464	validation_1-rmse:1.71417
# [48]	validation_0-rmse:1.44354	validation_1-rmse:1.71448
# [49]	validation_0-rmse:1.43652	validation_1-rmse:1.71521
# [50]	validation_0-rmse:1.43471	validation_1-rmse:1.71164
# [51]	validation_0-rmse:1.42656	validation_1-rmse:1.71127
# [52]	validation_0-rmse:1.42111	validation_1-rmse:1.71329
# [53]	validation_0-rmse:1.41556	validation_1-rmse:1.71217
# [54]	validation_0-rmse:1.40744	validation_1-rmse:1.71039
# [55]	validation_0-rmse:1.39949	validation_1-rmse:1.71159
# [56]	validation_0-rmse:1.39626	validation_1-rmse:1.71191
# [57]	validation_0-rmse:1.39350	validation_1-rmse:1.71044
# [58]	validation_0-rmse:1.38904	validation_1-rmse:1.70967
# [59]	validation_0-rmse:1.38416	validation_1-rmse:1.70666
# [60]	validation_0-rmse:1.38299	validation_1-rmse:1.70834
# [61]	validation_0-rmse:1.37310	validation_1-rmse:1.71140
# [62]	validation_0-rmse:1.36909	validation_1-rmse:1.71198
# [63]	validation_0-rmse:1.36249	validation_1-rmse:1.71142
# [64]	validation_0-rmse:1.35834	validation_1-rmse:1.70611
# [65]	validation_0-rmse:1.35343	validation_1-rmse:1.70669
# [66]	validation_0-rmse:1.34688	validation_1-rmse:1.70660
# [67]	validation_0-rmse:1.34387	validation_1-rmse:1.70592
# [68]	validation_0-rmse:1.33824	validation_1-rmse:1.70977
# [69]	validation_0-rmse:1.33177	validation_1-rmse:1.71415
# [70]	validation_0-rmse:1.32474	validation_1-rmse:1.71312
# [71]	validation_0-rmse:1.32198	validation_1-rmse:1.71386
# [72]	validation_0-rmse:1.31764	validation_1-rmse:1.71695
# [73]	validation_0-rmse:1.31084	validation_1-rmse:1.71674
# [74]	validation_0-rmse:1.30596	validation_1-rmse:1.71747
# [75]	validation_0-rmse:1.30273	validation_1-rmse:1.71408
# [76]	validation_0-rmse:1.29998	validation_1-rmse:1.71012
# [77]	validation_0-rmse:1.29269	validation_1-rmse:1.70996
# [78]	validation_0-rmse:1.29021	validation_1-rmse:1.71051
# [79]	validation_0-rmse:1.28576	validation_1-rmse:1.70793
# [80]	validation_0-rmse:1.28533	validation_1-rmse:1.70818
# [81]	validation_0-rmse:1.28044	validation_1-rmse:1.70518
# [82]	validation_0-rmse:1.27507	validation_1-rmse:1.70793
# [83]	validation_0-rmse:1.26895	validation_1-rmse:1.71019
# [84]	validation_0-rmse:1.26422	validation_1-rmse:1.71145
# [85]	validation_0-rmse:1.26329	validation_1-rmse:1.71243
# [86]	validation_0-rmse:1.26157	validation_1-rmse:1.71302
# [87]	validation_0-rmse:1.25351	validation_1-rmse:1.70013
# [88]	validation_0-rmse:1.25163	validation_1-rmse:1.70025
# [89]	validation_0-rmse:1.24687	validation_1-rmse:1.69929
# [90]	validation_0-rmse:1.23931	validation_1-rmse:1.69932
# [91]	validation_0-rmse:1.23504	validation_1-rmse:1.69821
# [92]	validation_0-rmse:1.23027	validation_1-rmse:1.69931
# [93]	validation_0-rmse:1.22552	validation_1-rmse:1.69947
# [94]	validation_0-rmse:1.21952	validation_1-rmse:1.69198
# [95]	validation_0-rmse:1.21415	validation_1-rmse:1.69367
# [96]	validation_0-rmse:1.21013	validation_1-rmse:1.69317
# [97]	validation_0-rmse:1.20153	validation_1-rmse:1.69653
# [98]	validation_0-rmse:1.19541	validation_1-rmse:1.68483
# [99]	validation_0-rmse:1.19041	validation_1-rmse:1.68500
# [100]	validation_0-rmse:1.18562	validation_1-rmse:1.68367
# [101]	validation_0-rmse:1.18354	validation_1-rmse:1.68485
# [102]	validation_0-rmse:1.17900	validation_1-rmse:1.68822
# [103]	validation_0-rmse:1.17293	validation_1-rmse:1.68808
# [104]	validation_0-rmse:1.16755	validation_1-rmse:1.68940
# [105]	validation_0-rmse:1.16573	validation_1-rmse:1.69161
# [106]	validation_0-rmse:1.16367	validation_1-rmse:1.68883
# [107]	validation_0-rmse:1.16051	validation_1-rmse:1.69038
# [108]	validation_0-rmse:1.15896	validation_1-rmse:1.69000
# [109]	validation_0-rmse:1.15795	validation_1-rmse:1.68899
# [110]	validation_0-rmse:1.15533	validation_1-rmse:1.68823
# [111]	validation_0-rmse:1.15184	validation_1-rmse:1.68763
# [112]	validation_0-rmse:1.14654	validation_1-rmse:1.68783
# [113]	validation_0-rmse:1.14154	validation_1-rmse:1.68886
# [114]	validation_0-rmse:1.14099	validation_1-rmse:1.68914
# [115]	validation_0-rmse:1.13647	validation_1-rmse:1.68682
# [116]	validation_0-rmse:1.13025	validation_1-rmse:1.68695
# [117]	validation_0-rmse:1.12763	validation_1-rmse:1.68747
# [118]	validation_0-rmse:1.12279	validation_1-rmse:1.67860
# [119]	validation_0-rmse:1.12138	validation_1-rmse:1.67522
# [120]	validation_0-rmse:1.11917	validation_1-rmse:1.67418
# [121]	validation_0-rmse:1.11514	validation_1-rmse:1.67472
# [122]	validation_0-rmse:1.11165	validation_1-rmse:1.67402
# [123]	validation_0-rmse:1.10979	validation_1-rmse:1.67395
# [124]	validation_0-rmse:1.10604	validation_1-rmse:1.67228
# [125]	validation_0-rmse:1.09856	validation_1-rmse:1.66431
# [126]	validation_0-rmse:1.09321	validation_1-rmse:1.66099
# [127]	validation_0-rmse:1.09171	validation_1-rmse:1.66022
# [128]	validation_0-rmse:1.08854	validation_1-rmse:1.65233
# [129]	validation_0-rmse:1.08573	validation_1-rmse:1.65234
# [130]	validation_0-rmse:1.08132	validation_1-rmse:1.65468
# [131]	validation_0-rmse:1.07807	validation_1-rmse:1.65528
# [132]	validation_0-rmse:1.07468	validation_1-rmse:1.65720
# [133]	validation_0-rmse:1.06914	validation_1-rmse:1.65837
# [134]	validation_0-rmse:1.06372	validation_1-rmse:1.65144
# [135]	validation_0-rmse:1.05473	validation_1-rmse:1.65336
# [136]	validation_0-rmse:1.05190	validation_1-rmse:1.65418
# [137]	validation_0-rmse:1.05035	validation_1-rmse:1.65495
# [138]	validation_0-rmse:1.04904	validation_1-rmse:1.65544
# [139]	validation_0-rmse:1.04689	validation_1-rmse:1.65578
# [140]	validation_0-rmse:1.04290	validation_1-rmse:1.65703
# [141]	validation_0-rmse:1.04012	validation_1-rmse:1.65685
# [142]	validation_0-rmse:1.03666	validation_1-rmse:1.65787
# [143]	validation_0-rmse:1.03041	validation_1-rmse:1.65791
# [144]	validation_0-rmse:1.02718	validation_1-rmse:1.65248
# [145]	validation_0-rmse:1.02484	validation_1-rmse:1.64702
# [146]	validation_0-rmse:1.02111	validation_1-rmse:1.64492
# [147]	validation_0-rmse:1.01740	validation_1-rmse:1.64792
# [148]	validation_0-rmse:1.01386	validation_1-rmse:1.64662
# [149]	validation_0-rmse:1.01119	validation_1-rmse:1.64691
# [150]	validation_0-rmse:1.00857	validation_1-rmse:1.64331
# [151]	validation_0-rmse:1.00399	validation_1-rmse:1.64011
# [152]	validation_0-rmse:1.00098	validation_1-rmse:1.64135
# [153]	validation_0-rmse:0.99899	validation_1-rmse:1.64186
# [154]	validation_0-rmse:0.99467	validation_1-rmse:1.63697
# [155]	validation_0-rmse:0.99180	validation_1-rmse:1.63752
# [156]	validation_0-rmse:0.98523	validation_1-rmse:1.63755
# [157]	validation_0-rmse:0.98381	validation_1-rmse:1.63758
# [158]	validation_0-rmse:0.97906	validation_1-rmse:1.63795
# [159]	validation_0-rmse:0.97487	validation_1-rmse:1.63863
# [160]	validation_0-rmse:0.96954	validation_1-rmse:1.63962
# [161]	validation_0-rmse:0.96772	validation_1-rmse:1.64032
# [162]	validation_0-rmse:0.96591	validation_1-rmse:1.63964
# [163]	validation_0-rmse:0.96185	validation_1-rmse:1.64047
# [164]	validation_0-rmse:0.95894	validation_1-rmse:1.63935
# [165]	validation_0-rmse:0.95841	validation_1-rmse:1.63997
# [166]	validation_0-rmse:0.95678	validation_1-rmse:1.63810
# [167]	validation_0-rmse:0.95196	validation_1-rmse:1.63750
# [168]	validation_0-rmse:0.94848	validation_1-rmse:1.63460
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:4.68204	validation_1-rmse:4.60838
# [1]	validation_0-rmse:4.32056	validation_1-rmse:4.24982
# [2]	validation_0-rmse:4.01700	validation_1-rmse:3.94549
# [3]	validation_0-rmse:3.73207	validation_1-rmse:3.68096
# [4]	validation_0-rmse:3.46303	validation_1-rmse:3.40296
# [5]	validation_0-rmse:3.22039	validation_1-rmse:3.16012
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:3.01588	validation_1-rmse:2.95035
# [7]	validation_0-rmse:2.83940	validation_1-rmse:2.78741
# [8]	validation_0-rmse:2.70452	validation_1-rmse:2.66731
# [9]	validation_0-rmse:2.57864	validation_1-rmse:2.55342
# [10]	validation_0-rmse:2.47996	validation_1-rmse:2.46738
# [11]	validation_0-rmse:2.36140	validation_1-rmse:2.37410
# [12]	validation_0-rmse:2.26469	validation_1-rmse:2.27235
# [13]	validation_0-rmse:2.18459	validation_1-rmse:2.19011
# [14]	validation_0-rmse:2.09994	validation_1-rmse:2.11150
# [15]	validation_0-rmse:2.04045	validation_1-rmse:2.05382
# [16]	validation_0-rmse:1.98261	validation_1-rmse:2.00186
# [17]	validation_0-rmse:1.93775	validation_1-rmse:1.96328
# [18]	validation_0-rmse:1.88983	validation_1-rmse:1.92951
# [19]	validation_0-rmse:1.85377	validation_1-rmse:1.90528
# [20]	validation_0-rmse:1.81947	validation_1-rmse:1.88374
# [21]	validation_0-rmse:1.78992	validation_1-rmse:1.86249
# [22]	validation_0-rmse:1.76506	validation_1-rmse:1.85299
# [23]	validation_0-rmse:1.73644	validation_1-rmse:1.83690
# [24]	validation_0-rmse:1.71233	validation_1-rmse:1.82635
# [25]	validation_0-rmse:1.69377	validation_1-rmse:1.81889
# [26]	validation_0-rmse:1.67526	validation_1-rmse:1.81034
# [27]	validation_0-rmse:1.65890	validation_1-rmse:1.80086
# [28]	validation_0-rmse:1.64384	validation_1-rmse:1.79343
# [29]	validation_0-rmse:1.62845	validation_1-rmse:1.78926
# [30]	validation_0-rmse:1.61499	validation_1-rmse:1.78225
# [31]	validation_0-rmse:1.60380	validation_1-rmse:1.77593
# [32]	validation_0-rmse:1.59387	validation_1-rmse:1.77210
# [33]	validation_0-rmse:1.57682	validation_1-rmse:1.76345
# [34]	validation_0-rmse:1.56675	validation_1-rmse:1.76022
# [35]	validation_0-rmse:1.55362	validation_1-rmse:1.75533
# [36]	validation_0-rmse:1.54333	validation_1-rmse:1.75071
# [37]	validation_0-rmse:1.53859	validation_1-rmse:1.74994
# [38]	validation_0-rmse:1.52451	validation_1-rmse:1.74498
# [39]	validation_0-rmse:1.51597	validation_1-rmse:1.74318
# [40]	validation_0-rmse:1.51048	validation_1-rmse:1.74248
# [41]	validation_0-rmse:1.50368	validation_1-rmse:1.74126
# [42]	validation_0-rmse:1.49979	validation_1-rmse:1.73645
# [43]	validation_0-rmse:1.48893	validation_1-rmse:1.73787
# [44]	validation_0-rmse:1.47980	validation_1-rmse:1.73607
# [45]	validation_0-rmse:1.47541	validation_1-rmse:1.73540
# [46]	validation_0-rmse:1.47265	validation_1-rmse:1.73382
# [47]	validation_0-rmse:1.45839	validation_1-rmse:1.73144
# [48]	validation_0-rmse:1.45699	validation_1-rmse:1.73112
# [49]	validation_0-rmse:1.44522	validation_1-rmse:1.72973
# [50]	validation_0-rmse:1.44267	validation_1-rmse:1.72861
# [51]	validation_0-rmse:1.43682	validation_1-rmse:1.72819
# [52]	validation_0-rmse:1.43518	validation_1-rmse:1.72672
# [53]	validation_0-rmse:1.42580	validation_1-rmse:1.72592
# [54]	validation_0-rmse:1.42426	validation_1-rmse:1.72508
# [55]	validation_0-rmse:1.41626	validation_1-rmse:1.72602
# [56]	validation_0-rmse:1.40907	validation_1-rmse:1.72122
# [57]	validation_0-rmse:1.40256	validation_1-rmse:1.71996
# [58]	validation_0-rmse:1.39316	validation_1-rmse:1.72089
# [59]	validation_0-rmse:1.38484	validation_1-rmse:1.71968
# [60]	validation_0-rmse:1.38195	validation_1-rmse:1.71700
# [61]	validation_0-rmse:1.37441	validation_1-rmse:1.71427
# [62]	validation_0-rmse:1.36946	validation_1-rmse:1.71487
# [63]	validation_0-rmse:1.36012	validation_1-rmse:1.71319
# [64]	validation_0-rmse:1.35502	validation_1-rmse:1.71362
# [65]	validation_0-rmse:1.34655	validation_1-rmse:1.71168
# [66]	validation_0-rmse:1.33566	validation_1-rmse:1.70876
# [67]	validation_0-rmse:1.33307	validation_1-rmse:1.70900
# [68]	validation_0-rmse:1.32489	validation_1-rmse:1.70587
# [69]	validation_0-rmse:1.31951	validation_1-rmse:1.70335
# [70]	validation_0-rmse:1.31061	validation_1-rmse:1.70381
# [71]	validation_0-rmse:1.30748	validation_1-rmse:1.70442
# [72]	validation_0-rmse:1.30454	validation_1-rmse:1.70422
# [73]	validation_0-rmse:1.29944	validation_1-rmse:1.70459
# [74]	validation_0-rmse:1.29539	validation_1-rmse:1.70358
# [75]	validation_0-rmse:1.29145	validation_1-rmse:1.70353
# [76]	validation_0-rmse:1.28680	validation_1-rmse:1.70355
# [77]	validation_0-rmse:1.28618	validation_1-rmse:1.70349
# [78]	validation_0-rmse:1.28331	validation_1-rmse:1.70565
# [79]	validation_0-rmse:1.28143	validation_1-rmse:1.70610
# [80]	validation_0-rmse:1.27588	validation_1-rmse:1.70366
# [81]	validation_0-rmse:1.27272	validation_1-rmse:1.70352
# [82]	validation_0-rmse:1.26775	validation_1-rmse:1.70282
# [83]	validation_0-rmse:1.26171	validation_1-rmse:1.69821
# [84]	validation_0-rmse:1.25914	validation_1-rmse:1.69819
# [85]	validation_0-rmse:1.25797	validation_1-rmse:1.69786
# [86]	validation_0-rmse:1.25384	validation_1-rmse:1.69301
# [87]	validation_0-rmse:1.24760	validation_1-rmse:1.69540
# [88]	validation_0-rmse:1.24355	validation_1-rmse:1.69584
# [89]	validation_0-rmse:1.23923	validation_1-rmse:1.69496
# [90]	validation_0-rmse:1.23371	validation_1-rmse:1.69379
# [91]	validation_0-rmse:1.22933	validation_1-rmse:1.69051
# [92]	validation_0-rmse:1.22462	validation_1-rmse:1.69009
# [93]	validation_0-rmse:1.21921	validation_1-rmse:1.68869
# [94]	validation_0-rmse:1.21613	validation_1-rmse:1.68724
# [95]	validation_0-rmse:1.21202	validation_1-rmse:1.68653
# [96]	validation_0-rmse:1.20724	validation_1-rmse:1.68531
# [97]	validation_0-rmse:1.20004	validation_1-rmse:1.68082
# [98]	validation_0-rmse:1.19220	validation_1-rmse:1.68008
# [99]	validation_0-rmse:1.18955	validation_1-rmse:1.68022
# [100]	validation_0-rmse:1.18039	validation_1-rmse:1.67752
# [101]	validation_0-rmse:1.17454	validation_1-rmse:1.66924
# [102]	validation_0-rmse:1.17060	validation_1-rmse:1.66972
# [103]	validation_0-rmse:1.16732	validation_1-rmse:1.67004
# [104]	validation_0-rmse:1.16647	validation_1-rmse:1.66939
# [105]	validation_0-rmse:1.16158	validation_1-rmse:1.66960
# [106]	validation_0-rmse:1.15927	validation_1-rmse:1.66974
# [107]	validation_0-rmse:1.15640	validation_1-rmse:1.67009
# [108]	validation_0-rmse:1.15578	validation_1-rmse:1.66985
# [109]	validation_0-rmse:1.14922	validation_1-rmse:1.67046
# [110]	validation_0-rmse:1.14408	validation_1-rmse:1.67357
# [111]	validation_0-rmse:1.14172	validation_1-rmse:1.67420
# [112]	validation_0-rmse:1.13435	validation_1-rmse:1.67197
# [113]	validation_0-rmse:1.12896	validation_1-rmse:1.67059
# [114]	validation_0-rmse:1.12281	validation_1-rmse:1.67313
# [115]	validation_0-rmse:1.12226	validation_1-rmse:1.67288
# [116]	validation_0-rmse:1.11833	validation_1-rmse:1.67423
# [117]	validation_0-rmse:1.11785	validation_1-rmse:1.67402
# [118]	validation_0-rmse:1.11482	validation_1-rmse:1.67349
# [119]	validation_0-rmse:1.11015	validation_1-rmse:1.67366
# [120]	validation_0-rmse:1.10601	validation_1-rmse:1.67631
# [121]	validation_0-rmse:1.10036	validation_1-rmse:1.68063
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:4.69738	validation_1-rmse:4.49294
# [1]	validation_0-rmse:4.33683	validation_1-rmse:4.11412
# [2]	validation_0-rmse:4.03468	validation_1-rmse:3.81462
# [3]	validation_0-rmse:3.74699	validation_1-rmse:3.51694
# [4]	validation_0-rmse:3.47126	validation_1-rmse:3.23786
# [5]	validation_0-rmse:3.22753	validation_1-rmse:2.99651
# [6]	validation_0-rmse:3.01884	validation_1-rmse:2.81066
# [7]	validation_0-rmse:2.85477	validation_1-rmse:2.63482
# [8]	validation_0-rmse:2.72647	validation_1-rmse:2.51427
# [9]	validation_0-rmse:2.60093	validation_1-rmse:2.39643
# [10]	validation_0-rmse:2.50774	validation_1-rmse:2.31117
# [11]	validation_0-rmse:2.37409	validation_1-rmse:2.20046
# [12]	validation_0-rmse:2.26639	validation_1-rmse:2.12581
# [13]	validation_0-rmse:2.17322	validation_1-rmse:2.05884
# [14]	validation_0-rmse:2.09686	validation_1-rmse:2.00376
# [15]	validation_0-rmse:2.02966	validation_1-rmse:1.96298
# [16]	validation_0-rmse:1.96477	validation_1-rmse:1.92851
# [17]	validation_0-rmse:1.91728	validation_1-rmse:1.89572
# [18]	validation_0-rmse:1.87055	validation_1-rmse:1.87095
# [19]	validation_0-rmse:1.82692	validation_1-rmse:1.84483
# [20]	validation_0-rmse:1.79470	validation_1-rmse:1.81266
# [21]	validation_0-rmse:1.76076	validation_1-rmse:1.78415
# [22]	validation_0-rmse:1.73179	validation_1-rmse:1.76624
# [23]	validation_0-rmse:1.70963	validation_1-rmse:1.75824
# [24]	validation_0-rmse:1.68509	validation_1-rmse:1.75536
# [25]	validation_0-rmse:1.66711	validation_1-rmse:1.74698
# [26]	validation_0-rmse:1.64917	validation_1-rmse:1.74447
# [27]	validation_0-rmse:1.63183	validation_1-rmse:1.73237
# [28]	validation_0-rmse:1.61636	validation_1-rmse:1.71917
# [29]	validation_0-rmse:1.60226	validation_1-rmse:1.71396
# [30]	validation_0-rmse:1.59015	validation_1-rmse:1.71189
# [31]	validation_0-rmse:1.57601	validation_1-rmse:1.70944
# [32]	validation_0-rmse:1.56302	validation_1-rmse:1.70465
# [33]	validation_0-rmse:1.55171	validation_1-rmse:1.70424
# [34]	validation_0-rmse:1.53673	validation_1-rmse:1.69948
# [35]	validation_0-rmse:1.52755	validation_1-rmse:1.69744
# [36]	validation_0-rmse:1.51704	validation_1-rmse:1.69584
# [37]	validation_0-rmse:1.50933	validation_1-rmse:1.69045
# [38]	validation_0-rmse:1.49894	validation_1-rmse:1.68310
# [39]	validation_0-rmse:1.49140	validation_1-rmse:1.68023
# [40]	validation_0-rmse:1.48528	validation_1-rmse:1.67727
# [41]	validation_0-rmse:1.47453	validation_1-rmse:1.67961
# [42]	validation_0-rmse:1.46803	validation_1-rmse:1.68010
# [43]	validation_0-rmse:1.45896	validation_1-rmse:1.68238
# [44]	validation_0-rmse:1.45177	validation_1-rmse:1.67895
# [45]	validation_0-rmse:1.44575	validation_1-rmse:1.67900
# [46]	validation_0-rmse:1.44270	validation_1-rmse:1.67654
# [47]	validation_0-rmse:1.43648	validation_1-rmse:1.67648
# [48]	validation_0-rmse:1.43240	validation_1-rmse:1.67871
# [49]	validation_0-rmse:1.42407	validation_1-rmse:1.68477
# [50]	validation_0-rmse:1.41907	validation_1-rmse:1.68625
# [51]	validation_0-rmse:1.41313	validation_1-rmse:1.68240
# [52]	validation_0-rmse:1.40854	validation_1-rmse:1.68947
# [53]	validation_0-rmse:1.39489	validation_1-rmse:1.68982
# [54]	validation_0-rmse:1.38598	validation_1-rmse:1.69268
# [55]	validation_0-rmse:1.37561	validation_1-rmse:1.69368
# [56]	validation_0-rmse:1.36552	validation_1-rmse:1.68990
# [57]	validation_0-rmse:1.35748	validation_1-rmse:1.68858
# [58]	validation_0-rmse:1.35322	validation_1-rmse:1.69038
# [59]	validation_0-rmse:1.34796	validation_1-rmse:1.68813
# [60]	validation_0-rmse:1.34690	validation_1-rmse:1.68855
# [61]	validation_0-rmse:1.33878	validation_1-rmse:1.68954
# [62]	validation_0-rmse:1.33239	validation_1-rmse:1.69109
# [63]	validation_0-rmse:1.33022	validation_1-rmse:1.69256
# [64]	validation_0-rmse:1.32810	validation_1-rmse:1.69257
# [65]	validation_0-rmse:1.32467	validation_1-rmse:1.69402
# [66]	validation_0-rmse:1.31838	validation_1-rmse:1.69643
# [67]	validation_0-rmse:1.31473	validation_1-rmse:1.69590
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:4.53043	validation_1-rmse:5.20416
# [1]	validation_0-rmse:4.17540	validation_1-rmse:4.87112
# [2]	validation_0-rmse:3.87739	validation_1-rmse:4.58820
# [3]	validation_0-rmse:3.59399	validation_1-rmse:4.32741
# [4]	validation_0-rmse:3.33585	validation_1-rmse:4.04762
# [5]	validation_0-rmse:3.10530	validation_1-rmse:3.79265
# [6]	validation_0-rmse:2.90918	validation_1-rmse:3.57472
# [7]	validation_0-rmse:2.73088	validation_1-rmse:3.42445
# [8]	validation_0-rmse:2.59746	validation_1-rmse:3.30495
# [9]	validation_0-rmse:2.46957	validation_1-rmse:3.20838
# [10]	validation_0-rmse:2.37398	validation_1-rmse:3.12463
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:2.26897	validation_1-rmse:3.01018
# [12]	validation_0-rmse:2.17868	validation_1-rmse:2.90034
# [13]	validation_0-rmse:2.10140	validation_1-rmse:2.81179
# [14]	validation_0-rmse:2.03522	validation_1-rmse:2.73467
# [15]	validation_0-rmse:1.96738	validation_1-rmse:2.66636
# [16]	validation_0-rmse:1.91897	validation_1-rmse:2.60470
# [17]	validation_0-rmse:1.87752	validation_1-rmse:2.54678
# [18]	validation_0-rmse:1.82765	validation_1-rmse:2.49507
# [19]	validation_0-rmse:1.79410	validation_1-rmse:2.45356
# [20]	validation_0-rmse:1.75829	validation_1-rmse:2.42242
# [21]	validation_0-rmse:1.71741	validation_1-rmse:2.39964
# [22]	validation_0-rmse:1.68686	validation_1-rmse:2.38070
# [23]	validation_0-rmse:1.65944	validation_1-rmse:2.34680
# [24]	validation_0-rmse:1.63828	validation_1-rmse:2.32393
# [25]	validation_0-rmse:1.61827	validation_1-rmse:2.31257
# [26]	validation_0-rmse:1.60160	validation_1-rmse:2.30241
# [27]	validation_0-rmse:1.57941	validation_1-rmse:2.29047
# [28]	validation_0-rmse:1.56514	validation_1-rmse:2.27853
# [29]	validation_0-rmse:1.54493	validation_1-rmse:2.26763
# [30]	validation_0-rmse:1.53148	validation_1-rmse:2.25970
# [31]	validation_0-rmse:1.52077	validation_1-rmse:2.23983
# [32]	validation_0-rmse:1.50605	validation_1-rmse:2.23604
# [33]	validation_0-rmse:1.49082	validation_1-rmse:2.23245
# [34]	validation_0-rmse:1.47659	validation_1-rmse:2.23067
# [35]	validation_0-rmse:1.46785	validation_1-rmse:2.22485
# [36]	validation_0-rmse:1.45966	validation_1-rmse:2.21311
# [37]	validation_0-rmse:1.45228	validation_1-rmse:2.20942
# [38]	validation_0-rmse:1.44759	validation_1-rmse:2.20927
# [39]	validation_0-rmse:1.43734	validation_1-rmse:2.20242
# [40]	validation_0-rmse:1.43135	validation_1-rmse:2.20276
# [41]	validation_0-rmse:1.42332	validation_1-rmse:2.20441
# [42]	validation_0-rmse:1.42125	validation_1-rmse:2.20166
# [43]	validation_0-rmse:1.40619	validation_1-rmse:2.20176
# [44]	validation_0-rmse:1.39523	validation_1-rmse:2.19955
# [45]	validation_0-rmse:1.38808	validation_1-rmse:2.19703
# [46]	validation_0-rmse:1.38156	validation_1-rmse:2.18555
# [47]	validation_0-rmse:1.37560	validation_1-rmse:2.18566
# [48]	validation_0-rmse:1.37409	validation_1-rmse:2.18518
# [49]	validation_0-rmse:1.37274	validation_1-rmse:2.18500
# [50]	validation_0-rmse:1.37119	validation_1-rmse:2.18408
# [51]	validation_0-rmse:1.36551	validation_1-rmse:2.18665
# [52]	validation_0-rmse:1.36106	validation_1-rmse:2.18524
# [53]	validation_0-rmse:1.35433	validation_1-rmse:2.18409
# [54]	validation_0-rmse:1.35255	validation_1-rmse:2.18313
# [55]	validation_0-rmse:1.34563	validation_1-rmse:2.18386
# [56]	validation_0-rmse:1.34199	validation_1-rmse:2.18245
# [57]	validation_0-rmse:1.33525	validation_1-rmse:2.18004
# [58]	validation_0-rmse:1.32873	validation_1-rmse:2.18174
# [59]	validation_0-rmse:1.32234	validation_1-rmse:2.18348
# [60]	validation_0-rmse:1.32114	validation_1-rmse:2.18178
# [61]	validation_0-rmse:1.31335	validation_1-rmse:2.18157
# [62]	validation_0-rmse:1.30924	validation_1-rmse:2.18436
# [63]	validation_0-rmse:1.30654	validation_1-rmse:2.18358
# [64]	validation_0-rmse:1.29722	validation_1-rmse:2.17249
# [65]	validation_0-rmse:1.29070	validation_1-rmse:2.16214
# [66]	validation_0-rmse:1.29001	validation_1-rmse:2.16074
# [67]	validation_0-rmse:1.28475	validation_1-rmse:2.16251
# [68]	validation_0-rmse:1.27821	validation_1-rmse:2.15777
# [69]	validation_0-rmse:1.27274	validation_1-rmse:2.15597
# [70]	validation_0-rmse:1.26811	validation_1-rmse:2.15913
# [71]	validation_0-rmse:1.26488	validation_1-rmse:2.15928
# [72]	validation_0-rmse:1.26074	validation_1-rmse:2.15631
# [73]	validation_0-rmse:1.25960	validation_1-rmse:2.15724
# [74]	validation_0-rmse:1.25668	validation_1-rmse:2.15773
# [75]	validation_0-rmse:1.25201	validation_1-rmse:2.15841
# [76]	validation_0-rmse:1.24791	validation_1-rmse:2.15695
# [77]	validation_0-rmse:1.24430	validation_1-rmse:2.15603
# [78]	validation_0-rmse:1.24068	validation_1-rmse:2.15597
# [79]	validation_0-rmse:1.23666	validation_1-rmse:2.15654
# [80]	validation_0-rmse:1.23254	validation_1-rmse:2.15551
# [81]	validation_0-rmse:1.22889	validation_1-rmse:2.15458
# [82]	validation_0-rmse:1.22206	validation_1-rmse:2.15337
# [83]	validation_0-rmse:1.21843	validation_1-rmse:2.15401
# [84]	validation_0-rmse:1.21099	validation_1-rmse:2.16015
# [85]	validation_0-rmse:1.20609	validation_1-rmse:2.15947
# [86]	validation_0-rmse:1.20314	validation_1-rmse:2.15913
# [87]	validation_0-rmse:1.19823	validation_1-rmse:2.15705
# [88]	validation_0-rmse:1.19492	validation_1-rmse:2.15489
# [89]	validation_0-rmse:1.18841	validation_1-rmse:2.15764
# [90]	validation_0-rmse:1.18520	validation_1-rmse:2.15812
# [91]	validation_0-rmse:1.17911	validation_1-rmse:2.15783
# [92]	validation_0-rmse:1.17377	validation_1-rmse:2.15751
# [93]	validation_0-rmse:1.16585	validation_1-rmse:2.15683
# [94]	validation_0-rmse:1.16219	validation_1-rmse:2.15646
# [95]	validation_0-rmse:1.15944	validation_1-rmse:2.14928
# [96]	validation_0-rmse:1.15727	validation_1-rmse:2.14917
# [97]	validation_0-rmse:1.15228	validation_1-rmse:2.14904
# [98]	validation_0-rmse:1.14813	validation_1-rmse:2.14818
# [99]	validation_0-rmse:1.14560	validation_1-rmse:2.14851
# [100]	validation_0-rmse:1.13620	validation_1-rmse:2.14780
# [101]	validation_0-rmse:1.13294	validation_1-rmse:2.14745
# [102]	validation_0-rmse:1.13093	validation_1-rmse:2.14513
# [103]	validation_0-rmse:1.12869	validation_1-rmse:2.14625
# [104]	validation_0-rmse:1.12206	validation_1-rmse:2.14517
# [105]	validation_0-rmse:1.11190	validation_1-rmse:2.14297
# [106]	validation_0-rmse:1.10635	validation_1-rmse:2.14393
# [107]	validation_0-rmse:1.10416	validation_1-rmse:2.14594
# [108]	validation_0-rmse:1.09857	validation_1-rmse:2.14854
# [109]	validation_0-rmse:1.09572	validation_1-rmse:2.14853
# [110]	validation_0-rmse:1.09379	validation_1-rmse:2.15060
# [111]	validation_0-rmse:1.08740	validation_1-rmse:2.14623
# [112]	validation_0-rmse:1.08541	validation_1-rmse:2.14625
# [113]	validation_0-rmse:1.08495	validation_1-rmse:2.14621
# [114]	validation_0-rmse:1.08224	validation_1-rmse:2.14595
# [115]	validation_0-rmse:1.07863	validation_1-rmse:2.14582
# [116]	validation_0-rmse:1.07495	validation_1-rmse:2.14756
# [117]	validation_0-rmse:1.06966	validation_1-rmse:2.14730
# [118]	validation_0-rmse:1.06061	validation_1-rmse:2.14164
# [119]	validation_0-rmse:1.05837	validation_1-rmse:2.14199
# [120]	validation_0-rmse:1.05588	validation_1-rmse:2.14228
# [121]	validation_0-rmse:1.05180	validation_1-rmse:2.14317
# [122]	validation_0-rmse:1.04692	validation_1-rmse:2.14023
# [123]	validation_0-rmse:1.04533	validation_1-rmse:2.14009
# [124]	validation_0-rmse:1.04437	validation_1-rmse:2.13998
# [125]	validation_0-rmse:1.04274	validation_1-rmse:2.14221
# [126]	validation_0-rmse:1.03927	validation_1-rmse:2.14035
# [127]	validation_0-rmse:1.03272	validation_1-rmse:2.14015
# [128]	validation_0-rmse:1.03077	validation_1-rmse:2.14102
# [129]	validation_0-rmse:1.02549	validation_1-rmse:2.13810
# [130]	validation_0-rmse:1.02228	validation_1-rmse:2.13965
# [131]	validation_0-rmse:1.02054	validation_1-rmse:2.14112
# [132]	validation_0-rmse:1.01691	validation_1-rmse:2.14241
# [133]	validation_0-rmse:1.01444	validation_1-rmse:2.14448
# [134]	validation_0-rmse:1.01306	validation_1-rmse:2.14399
# [135]	validation_0-rmse:1.01037	validation_1-rmse:2.14303
# [136]	validation_0-rmse:1.00484	validation_1-rmse:2.14221
# [137]	validation_0-rmse:0.99996	validation_1-rmse:2.14128
# [138]	validation_0-rmse:0.99797	validation_1-rmse:2.14126
# [139]	validation_0-rmse:0.99538	validation_1-rmse:2.13962
# [140]	validation_0-rmse:0.99342	validation_1-rmse:2.14094
# [141]	validation_0-rmse:0.99257	validation_1-rmse:2.14094
# [142]	validation_0-rmse:0.98978	validation_1-rmse:2.14111
# [143]	validation_0-rmse:0.98868	validation_1-rmse:2.14252
# [144]	validation_0-rmse:0.98387	validation_1-rmse:2.13849
# [145]	validation_0-rmse:0.98126	validation_1-rmse:2.13887
# [146]	validation_0-rmse:0.97520	validation_1-rmse:2.13792
# [147]	validation_0-rmse:0.97067	validation_1-rmse:2.13647
# [148]	validation_0-rmse:0.96733	validation_1-rmse:2.13600
# [149]	validation_0-rmse:0.96368	validation_1-rmse:2.13452
# [150]	validation_0-rmse:0.96176	validation_1-rmse:2.13414
# [151]	validation_0-rmse:0.95973	validation_1-rmse:2.13404
# [152]	validation_0-rmse:0.95771	validation_1-rmse:2.13298
# [153]	validation_0-rmse:0.95290	validation_1-rmse:2.13558
# [154]	validation_0-rmse:0.94733	validation_1-rmse:2.13395
# [155]	validation_0-rmse:0.94269	validation_1-rmse:2.13323
# [156]	validation_0-rmse:0.94118	validation_1-rmse:2.13257
# [157]	validation_0-rmse:0.93801	validation_1-rmse:2.13378
# [158]	validation_0-rmse:0.93336	validation_1-rmse:2.12866
# [159]	validation_0-rmse:0.93298	validation_1-rmse:2.12921
# [160]	validation_0-rmse:0.92825	validation_1-rmse:2.12894
# [161]	validation_0-rmse:0.92609	validation_1-rmse:2.13186
# [162]	validation_0-rmse:0.92228	validation_1-rmse:2.13117
# [163]	validation_0-rmse:0.91985	validation_1-rmse:2.13100
# [164]	validation_0-rmse:0.91832	validation_1-rmse:2.13263
# [165]	validation_0-rmse:0.91544	validation_1-rmse:2.13284
# [166]	validation_0-rmse:0.91198	validation_1-rmse:2.13074
# [167]	validation_0-rmse:0.90776	validation_1-rmse:2.13072
# [168]	validation_0-rmse:0.90620	validation_1-rmse:2.13114
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:4.56355	validation_1-rmse:5.07916
# [1]	validation_0-rmse:4.20504	validation_1-rmse:4.72120
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:3.90576	validation_1-rmse:4.43360
# [3]	validation_0-rmse:3.61535	validation_1-rmse:4.14990
# [4]	validation_0-rmse:3.35209	validation_1-rmse:3.87113
# [5]	validation_0-rmse:3.11517	validation_1-rmse:3.61684
# [6]	validation_0-rmse:2.91505	validation_1-rmse:3.40960
# [7]	validation_0-rmse:2.74069	validation_1-rmse:3.25525
# [8]	validation_0-rmse:2.61442	validation_1-rmse:3.13510
# [9]	validation_0-rmse:2.48456	validation_1-rmse:3.01699
# [10]	validation_0-rmse:2.39024	validation_1-rmse:2.93126
# [11]	validation_0-rmse:2.28090	validation_1-rmse:2.80668
# [12]	validation_0-rmse:2.19146	validation_1-rmse:2.71048
# [13]	validation_0-rmse:2.11486	validation_1-rmse:2.63905
# [14]	validation_0-rmse:2.04509	validation_1-rmse:2.56573
# [15]	validation_0-rmse:1.98394	validation_1-rmse:2.49122
# [16]	validation_0-rmse:1.93526	validation_1-rmse:2.44200
# [17]	validation_0-rmse:1.89381	validation_1-rmse:2.39260
# [18]	validation_0-rmse:1.85236	validation_1-rmse:2.35181
# [19]	validation_0-rmse:1.81595	validation_1-rmse:2.32929
# [20]	validation_0-rmse:1.77915	validation_1-rmse:2.29411
# [21]	validation_0-rmse:1.74378	validation_1-rmse:2.26886
# [22]	validation_0-rmse:1.71436	validation_1-rmse:2.24706
# [23]	validation_0-rmse:1.69401	validation_1-rmse:2.22499
# [24]	validation_0-rmse:1.67503	validation_1-rmse:2.20615
# [25]	validation_0-rmse:1.65293	validation_1-rmse:2.19902
# [26]	validation_0-rmse:1.63813	validation_1-rmse:2.19124
# [27]	validation_0-rmse:1.61844	validation_1-rmse:2.16844
# [28]	validation_0-rmse:1.60253	validation_1-rmse:2.14823
# [29]	validation_0-rmse:1.58564	validation_1-rmse:2.14428
# [30]	validation_0-rmse:1.57285	validation_1-rmse:2.14254
# [31]	validation_0-rmse:1.56022	validation_1-rmse:2.12789
# [32]	validation_0-rmse:1.54622	validation_1-rmse:2.12279
# [33]	validation_0-rmse:1.53707	validation_1-rmse:2.11778
# [34]	validation_0-rmse:1.52723	validation_1-rmse:2.11004
# [35]	validation_0-rmse:1.52224	validation_1-rmse:2.10465
# [36]	validation_0-rmse:1.51112	validation_1-rmse:2.08916
# [37]	validation_0-rmse:1.50044	validation_1-rmse:2.08266
# [38]	validation_0-rmse:1.48981	validation_1-rmse:2.08189
# [39]	validation_0-rmse:1.47883	validation_1-rmse:2.07141
# [40]	validation_0-rmse:1.46871	validation_1-rmse:2.07340
# [41]	validation_0-rmse:1.45795	validation_1-rmse:2.07470
# [42]	validation_0-rmse:1.45035	validation_1-rmse:2.07245
# [43]	validation_0-rmse:1.44089	validation_1-rmse:2.06118
# [44]	validation_0-rmse:1.42759	validation_1-rmse:2.06495
# [45]	validation_0-rmse:1.42353	validation_1-rmse:2.06530
# [46]	validation_0-rmse:1.41337	validation_1-rmse:2.04725
# [47]	validation_0-rmse:1.40567	validation_1-rmse:2.04668
# [48]	validation_0-rmse:1.40313	validation_1-rmse:2.04783
# [49]	validation_0-rmse:1.39759	validation_1-rmse:2.04765
# [50]	validation_0-rmse:1.39455	validation_1-rmse:2.03718
# [51]	validation_0-rmse:1.38713	validation_1-rmse:2.03368
# [52]	validation_0-rmse:1.38311	validation_1-rmse:2.03354
# [53]	validation_0-rmse:1.37691	validation_1-rmse:2.02264
# [54]	validation_0-rmse:1.37044	validation_1-rmse:2.02136
# [55]	validation_0-rmse:1.36518	validation_1-rmse:2.02053
# [56]	validation_0-rmse:1.35914	validation_1-rmse:2.02113
# [57]	validation_0-rmse:1.35620	validation_1-rmse:2.02271
# [58]	validation_0-rmse:1.34934	validation_1-rmse:2.02211
# [59]	validation_0-rmse:1.34163	validation_1-rmse:2.02297
# [60]	validation_0-rmse:1.33757	validation_1-rmse:2.02479
# [61]	validation_0-rmse:1.33252	validation_1-rmse:2.02738
# [62]	validation_0-rmse:1.32942	validation_1-rmse:2.02637
# [63]	validation_0-rmse:1.32191	validation_1-rmse:2.02025
# [64]	validation_0-rmse:1.31700	validation_1-rmse:2.01837
# [65]	validation_0-rmse:1.31072	validation_1-rmse:2.01826
# [66]	validation_0-rmse:1.30323	validation_1-rmse:2.01693
# [67]	validation_0-rmse:1.29956	validation_1-rmse:2.01914
# [68]	validation_0-rmse:1.29444	validation_1-rmse:2.02333
# [69]	validation_0-rmse:1.28704	validation_1-rmse:2.02829
# [70]	validation_0-rmse:1.27907	validation_1-rmse:2.02894
# [71]	validation_0-rmse:1.27538	validation_1-rmse:2.03014
# [72]	validation_0-rmse:1.27211	validation_1-rmse:2.03227
# [73]	validation_0-rmse:1.27082	validation_1-rmse:2.03213
# [74]	validation_0-rmse:1.26623	validation_1-rmse:2.03006
# [75]	validation_0-rmse:1.25983	validation_1-rmse:2.02868
# [76]	validation_0-rmse:1.25554	validation_1-rmse:2.02937
# [77]	validation_0-rmse:1.24904	validation_1-rmse:2.02954
# [78]	validation_0-rmse:1.24516	validation_1-rmse:2.02883
# [79]	validation_0-rmse:1.24460	validation_1-rmse:2.02873
# [80]	validation_0-rmse:1.24409	validation_1-rmse:2.02911
# [81]	validation_0-rmse:1.23859	validation_1-rmse:2.02918
# [82]	validation_0-rmse:1.23598	validation_1-rmse:2.02881
# [83]	validation_0-rmse:1.23363	validation_1-rmse:2.03048
# [84]	validation_0-rmse:1.22867	validation_1-rmse:2.02502
# [85]	validation_0-rmse:1.22370	validation_1-rmse:2.02479
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:4.75770	validation_1-rmse:4.25194
# [1]	validation_0-rmse:4.38910	validation_1-rmse:3.89949
# [2]	validation_0-rmse:4.07677	validation_1-rmse:3.59328
# [3]	validation_0-rmse:3.78349	validation_1-rmse:3.31167
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:3.50663	validation_1-rmse:3.06167
# [5]	validation_0-rmse:3.26030	validation_1-rmse:2.84496
# [6]	validation_0-rmse:3.04949	validation_1-rmse:2.65669
# [7]	validation_0-rmse:2.87645	validation_1-rmse:2.49338
# [8]	validation_0-rmse:2.74172	validation_1-rmse:2.38489
# [9]	validation_0-rmse:2.61258	validation_1-rmse:2.27995
# [10]	validation_0-rmse:2.51436	validation_1-rmse:2.20089
# [11]	validation_0-rmse:2.39455	validation_1-rmse:2.11417
# [12]	validation_0-rmse:2.29399	validation_1-rmse:2.04506
# [13]	validation_0-rmse:2.20947	validation_1-rmse:1.98706
# [14]	validation_0-rmse:2.13321	validation_1-rmse:1.93984
# [15]	validation_0-rmse:2.07010	validation_1-rmse:1.90395
# [16]	validation_0-rmse:2.01853	validation_1-rmse:1.87794
# [17]	validation_0-rmse:1.97173	validation_1-rmse:1.85658
# [18]	validation_0-rmse:1.92415	validation_1-rmse:1.83543
# [19]	validation_0-rmse:1.88148	validation_1-rmse:1.81917
# [20]	validation_0-rmse:1.84823	validation_1-rmse:1.79596
# [21]	validation_0-rmse:1.80632	validation_1-rmse:1.77788
# [22]	validation_0-rmse:1.78281	validation_1-rmse:1.76689
# [23]	validation_0-rmse:1.75133	validation_1-rmse:1.75743
# [24]	validation_0-rmse:1.72500	validation_1-rmse:1.75190
# [25]	validation_0-rmse:1.70507	validation_1-rmse:1.74363
# [26]	validation_0-rmse:1.68330	validation_1-rmse:1.73954
# [27]	validation_0-rmse:1.66298	validation_1-rmse:1.73308
# [28]	validation_0-rmse:1.64834	validation_1-rmse:1.73104
# [29]	validation_0-rmse:1.62368	validation_1-rmse:1.72822
# [30]	validation_0-rmse:1.60437	validation_1-rmse:1.72578
# [31]	validation_0-rmse:1.59236	validation_1-rmse:1.72492
# [32]	validation_0-rmse:1.58086	validation_1-rmse:1.72107
# [33]	validation_0-rmse:1.57022	validation_1-rmse:1.71854
# [34]	validation_0-rmse:1.55261	validation_1-rmse:1.71633
# [35]	validation_0-rmse:1.54027	validation_1-rmse:1.71730
# [36]	validation_0-rmse:1.53100	validation_1-rmse:1.71224
# [37]	validation_0-rmse:1.51677	validation_1-rmse:1.70733
# [38]	validation_0-rmse:1.50997	validation_1-rmse:1.70663
# [39]	validation_0-rmse:1.50123	validation_1-rmse:1.70478
# [40]	validation_0-rmse:1.49209	validation_1-rmse:1.70601
# [41]	validation_0-rmse:1.48307	validation_1-rmse:1.70206
# [42]	validation_0-rmse:1.47715	validation_1-rmse:1.70334
# [43]	validation_0-rmse:1.47123	validation_1-rmse:1.70606
# [44]	validation_0-rmse:1.46367	validation_1-rmse:1.70691
# [45]	validation_0-rmse:1.46180	validation_1-rmse:1.70375
# [46]	validation_0-rmse:1.46014	validation_1-rmse:1.70097
# [47]	validation_0-rmse:1.44732	validation_1-rmse:1.69966
# ...
# [9]	validation_0-rmse:2.55190	validation_1-rmse:2.65515
# [10]	validation_0-rmse:2.45351	validation_1-rmse:2.57391
# [11]	validation_0-rmse:2.33637	validation_1-rmse:2.47243
# [12]	validation_0-rmse:2.23032	validation_1-rmse:2.38993
# [13]	validation_0-rmse:2.14414	validation_1-rmse:2.31893
# [14]	validation_0-rmse:2.06770	validation_1-rmse:2.25496
# [15]	validation_0-rmse:1.99675	validation_1-rmse:2.20655
# [16]	validation_0-rmse:1.93439	validation_1-rmse:2.15980
# [17]	validation_0-rmse:1.88824	validation_1-rmse:2.11959
# [18]	validation_0-rmse:1.83828	validation_1-rmse:2.08351
# [19]	validation_0-rmse:1.80378	validation_1-rmse:2.05345
# [20]	validation_0-rmse:1.76517	validation_1-rmse:2.01951
# [21]	validation_0-rmse:1.73639	validation_1-rmse:1.99296
# [22]	validation_0-rmse:1.71202	validation_1-rmse:1.97582
# [23]	validation_0-rmse:1.69022	validation_1-rmse:1.95778
# [24]	validation_0-rmse:1.66526	validation_1-rmse:1.94366
# [25]	validation_0-rmse:1.64483	validation_1-rmse:1.92826
# [26]	validation_0-rmse:1.62702	validation_1-rmse:1.92389
# [27]	validation_0-rmse:1.60106	validation_1-rmse:1.92148
# [28]	validation_0-rmse:1.58846	validation_1-rmse:1.91676
# [29]	validation_0-rmse:1.57588	validation_1-rmse:1.91496
# [30]	validation_0-rmse:1.56193	validation_1-rmse:1.90549
# [31]	validation_0-rmse:1.54443	validation_1-rmse:1.89545
# [32]	validation_0-rmse:1.53370	validation_1-rmse:1.89136
# [33]	validation_0-rmse:1.51572	validation_1-rmse:1.88069
# [34]	validation_0-rmse:1.50834	validation_1-rmse:1.88038
# [35]	validation_0-rmse:1.50072	validation_1-rmse:1.88032
# [36]	validation_0-rmse:1.49585	validation_1-rmse:1.87512
# [37]	validation_0-rmse:1.48619	validation_1-rmse:1.87643
# [38]	validation_0-rmse:1.47746	validation_1-rmse:1.86795
# [39]	validation_0-rmse:1.45937	validation_1-rmse:1.86002
# [40]	validation_0-rmse:1.45211	validation_1-rmse:1.85868
# [41]	validation_0-rmse:1.44679	validation_1-rmse:1.85411
# [42]	validation_0-rmse:1.44369	validation_1-rmse:1.85222
# [43]	validation_0-rmse:1.44034	validation_1-rmse:1.84726
# [44]	validation_0-rmse:1.43766	validation_1-rmse:1.84342
# [45]	validation_0-rmse:1.43525	validation_1-rmse:1.84226
# [46]	validation_0-rmse:1.42743	validation_1-rmse:1.83489
# [47]	validation_0-rmse:1.42132	validation_1-rmse:1.83152
# [48]	validation_0-rmse:1.42003	validation_1-rmse:1.83219
# [49]	validation_0-rmse:1.41107	validation_1-rmse:1.83450
# [50]	validation_0-rmse:1.40395	validation_1-rmse:1.83167
# [51]	validation_0-rmse:1.39820	validation_1-rmse:1.83392
# [52]	validation_0-rmse:1.39279	validation_1-rmse:1.83364
# [53]	validation_0-rmse:1.38513	validation_1-rmse:1.83194
# [54]	validation_0-rmse:1.37491	validation_1-rmse:1.82700
# [55]	validation_0-rmse:1.36919	validation_1-rmse:1.82622
# [56]	validation_0-rmse:1.36614	validation_1-rmse:1.82636
# [57]	validation_0-rmse:1.35746	validation_1-rmse:1.82023
# [58]	validation_0-rmse:1.35062	validation_1-rmse:1.81680
# [59]	validation_0-rmse:1.34554	validation_1-rmse:1.81874
# [60]	validation_0-rmse:1.34162	validation_1-rmse:1.82166
# [61]	validation_0-rmse:1.33475	validation_1-rmse:1.82204
# [62]	validation_0-rmse:1.32814	validation_1-rmse:1.82031
# [63]	validation_0-rmse:1.31654	validation_1-rmse:1.81698
# [64]	validation_0-rmse:1.31065	validation_1-rmse:1.81880
# [65]	validation_0-rmse:1.30517	validation_1-rmse:1.82472
# [66]	validation_0-rmse:1.30370	validation_1-rmse:1.82389
# [67]	validation_0-rmse:1.30018	validation_1-rmse:1.82616
# [68]	validation_0-rmse:1.29445	validation_1-rmse:1.82503
# [69]	validation_0-rmse:1.28654	validation_1-rmse:1.82463
# [70]	validation_0-rmse:1.28237	validation_1-rmse:1.82799
# [71]	validation_0-rmse:1.27699	validation_1-rmse:1.82861
# [72]	validation_0-rmse:1.26974	validation_1-rmse:1.82587
# [73]	validation_0-rmse:1.26335	validation_1-rmse:1.81892
# [74]	validation_0-rmse:1.25882	validation_1-rmse:1.81884
# [75]	validation_0-rmse:1.25283	validation_1-rmse:1.81772
# [76]	validation_0-rmse:1.24313	validation_1-rmse:1.81791
# [77]	validation_0-rmse:1.23740	validation_1-rmse:1.81232
# [78]	validation_0-rmse:1.23417	validation_1-rmse:1.81195
# [79]	validation_0-rmse:1.23206	validation_1-rmse:1.81172
# [80]	validation_0-rmse:1.23019	validation_1-rmse:1.80976
# [81]	validation_0-rmse:1.22907	validation_1-rmse:1.80814
# [82]	validation_0-rmse:1.22668	validation_1-rmse:1.80949
# [83]	validation_0-rmse:1.22414	validation_1-rmse:1.80932
# [84]	validation_0-rmse:1.22250	validation_1-rmse:1.80779
# [85]	validation_0-rmse:1.21973	validation_1-rmse:1.80706
# [86]	validation_0-rmse:1.21908	validation_1-rmse:1.80778
# [87]	validation_0-rmse:1.21816	validation_1-rmse:1.80684
# [88]	validation_0-rmse:1.21132	validation_1-rmse:1.80276
# [89]	validation_0-rmse:1.20760	validation_1-rmse:1.80100
# [90]	validation_0-rmse:1.20147	validation_1-rmse:1.79962
# [91]	validation_0-rmse:1.19735	validation_1-rmse:1.79947
# [92]	validation_0-rmse:1.18869	validation_1-rmse:1.79585
# [93]	validation_0-rmse:1.18259	validation_1-rmse:1.79323
# [94]	validation_0-rmse:1.17625	validation_1-rmse:1.79409
# [95]	validation_0-rmse:1.17576	validation_1-rmse:1.79418
# [96]	validation_0-rmse:1.17099	validation_1-rmse:1.79068
# [97]	validation_0-rmse:1.17009	validation_1-rmse:1.78937
# [98]	validation_0-rmse:1.16245	validation_1-rmse:1.78248
# [99]	validation_0-rmse:1.16207	validation_1-rmse:1.78234
# [100]	validation_0-rmse:1.15912	validation_1-rmse:1.78109
# [101]	validation_0-rmse:1.15559	validation_1-rmse:1.78320
# [102]	validation_0-rmse:1.14983	validation_1-rmse:1.78324
# [103]	validation_0-rmse:1.14692	validation_1-rmse:1.78402
# [104]	validation_0-rmse:1.14237	validation_1-rmse:1.78410
# [105]	validation_0-rmse:1.14202	validation_1-rmse:1.78463
# [106]	validation_0-rmse:1.14098	validation_1-rmse:1.78402
# [107]	validation_0-rmse:1.13886	validation_1-rmse:1.78705
# [108]	validation_0-rmse:1.13508	validation_1-rmse:1.78832
# [109]	validation_0-rmse:1.12939	validation_1-rmse:1.78824
# [110]	validation_0-rmse:1.12406	validation_1-rmse:1.78557
# [111]	validation_0-rmse:1.12013	validation_1-rmse:1.78378
# [112]	validation_0-rmse:1.11368	validation_1-rmse:1.78359
# [113]	validation_0-rmse:1.10763	validation_1-rmse:1.78241
# [114]	validation_0-rmse:1.10175	validation_1-rmse:1.78180
# [115]	validation_0-rmse:1.09817	validation_1-rmse:1.78151
# [116]	validation_0-rmse:1.09678	validation_1-rmse:1.78083
# [117]	validation_0-rmse:1.09231	validation_1-rmse:1.77951
# [118]	validation_0-rmse:1.08517	validation_1-rmse:1.77053
# [119]	validation_0-rmse:1.08126	validation_1-rmse:1.77051
# [120]	validation_0-rmse:1.07717	validation_1-rmse:1.76822
# [121]	validation_0-rmse:1.07408	validation_1-rmse:1.76864
# [122]	validation_0-rmse:1.06873	validation_1-rmse:1.76867
# [123]	validation_0-rmse:1.06612	validation_1-rmse:1.76523
# [124]	validation_0-rmse:1.06198	validation_1-rmse:1.76523
# [125]	validation_0-rmse:1.06046	validation_1-rmse:1.76425
# [126]	validation_0-rmse:1.05759	validation_1-rmse:1.76533
# [127]	validation_0-rmse:1.05182	validation_1-rmse:1.76589
# [128]	validation_0-rmse:1.04789	validation_1-rmse:1.76412
# [129]	validation_0-rmse:1.04710	validation_1-rmse:1.76463
# [130]	validation_0-rmse:1.04032	validation_1-rmse:1.76426
# [131]	validation_0-rmse:1.03921	validation_1-rmse:1.76456
# [132]	validation_0-rmse:1.03482	validation_1-rmse:1.76322
# [133]	validation_0-rmse:1.03119	validation_1-rmse:1.76204
# [134]	validation_0-rmse:1.02664	validation_1-rmse:1.76096
# [135]	validation_0-rmse:1.02282	validation_1-rmse:1.76284
# [136]	validation_0-rmse:1.02190	validation_1-rmse:1.76221
# [137]	validation_0-rmse:1.01679	validation_1-rmse:1.76067
# [138]	validation_0-rmse:1.01111	validation_1-rmse:1.76043
# [139]	validation_0-rmse:1.00898	validation_1-rmse:1.75959
# [140]	validation_0-rmse:1.00445	validation_1-rmse:1.75390
# [141]	validation_0-rmse:1.00133	validation_1-rmse:1.75281
# [142]	validation_0-rmse:0.99780	validation_1-rmse:1.75108
# [143]	validation_0-rmse:0.99396	validation_1-rmse:1.75188
# [144]	validation_0-rmse:0.99210	validation_1-rmse:1.74839
# [145]	validation_0-rmse:0.98918	validation_1-rmse:1.75038
# [146]	validation_0-rmse:0.98688	validation_1-rmse:1.75114
# [147]	validation_0-rmse:0.98529	validation_1-rmse:1.74980
# [148]	validation_0-rmse:0.98223	validation_1-rmse:1.74956
# [149]	validation_0-rmse:0.97853	validation_1-rmse:1.75062
# [150]	validation_0-rmse:0.97599	validation_1-rmse:1.74880
# [151]	validation_0-rmse:0.96999	validation_1-rmse:1.74928
# [152]	validation_0-rmse:0.96576	validation_1-rmse:1.74857
# [153]	validation_0-rmse:0.96525	validation_1-rmse:1.74841
# [154]	validation_0-rmse:0.96465	validation_1-rmse:1.74743
# [155]	validation_0-rmse:0.96251	validation_1-rmse:1.74731
# [156]	validation_0-rmse:0.95986	validation_1-rmse:1.74933
# [157]	validation_0-rmse:0.95515	validation_1-rmse:1.74985
# [158]	validation_0-rmse:0.95161	validation_1-rmse:1.74716
# [159]	validation_0-rmse:0.94986	validation_1-rmse:1.74672
# [160]	validation_0-rmse:0.94652	validation_1-rmse:1.74437
# [161]	validation_0-rmse:0.94377	validation_1-rmse:1.74600
# [162]	validation_0-rmse:0.94302	validation_1-rmse:1.74512
# [163]	validation_0-rmse:0.94034	validation_1-rmse:1.74475
# [164]	validation_0-rmse:0.93844	validation_1-rmse:1.74460
# [165]	validation_0-rmse:0.93702	validation_1-rmse:1.74467
# [166]	validation_0-rmse:0.93635	validation_1-rmse:1.74463
# [167]	validation_0-rmse:0.93528	validation_1-rmse:1.74510
# [168]	validation_0-rmse:0.93172	validation_1-rmse:1.74467
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:4.51137	validation_1-rmse:5.28166
# [1]	validation_0-rmse:4.15367	validation_1-rmse:4.95838
# [2]	validation_0-rmse:3.85600	validation_1-rmse:4.67463
# [3]	validation_0-rmse:3.57611	validation_1-rmse:4.41820
# [4]	validation_0-rmse:3.31145	validation_1-rmse:4.14955
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:3.08007	validation_1-rmse:3.90968
# [6]	validation_0-rmse:2.88219	validation_1-rmse:3.70062
# [7]	validation_0-rmse:2.71352	validation_1-rmse:3.53989
# [8]	validation_0-rmse:2.58349	validation_1-rmse:3.41618
# [9]	validation_0-rmse:2.44766	validation_1-rmse:3.30906
# [10]	validation_0-rmse:2.34760	validation_1-rmse:3.22731
# [11]	validation_0-rmse:2.24101	validation_1-rmse:3.10959
# [12]	validation_0-rmse:2.14029	validation_1-rmse:3.00120
# [13]	validation_0-rmse:2.06309	validation_1-rmse:2.91267
# [14]	validation_0-rmse:1.99636	validation_1-rmse:2.83520
# [15]	validation_0-rmse:1.92895	validation_1-rmse:2.76321
# [16]	validation_0-rmse:1.87315	validation_1-rmse:2.70241
# [17]	validation_0-rmse:1.83216	validation_1-rmse:2.64859
# [18]	validation_0-rmse:1.79068	validation_1-rmse:2.59572
# [19]	validation_0-rmse:1.75270	validation_1-rmse:2.56316
# [20]	validation_0-rmse:1.71954	validation_1-rmse:2.53600
# [21]	validation_0-rmse:1.68463	validation_1-rmse:2.51600
# [22]	validation_0-rmse:1.66057	validation_1-rmse:2.50081
# [23]	validation_0-rmse:1.63160	validation_1-rmse:2.46869
# [24]	validation_0-rmse:1.60764	validation_1-rmse:2.43895
# [25]	validation_0-rmse:1.59118	validation_1-rmse:2.41337
# [26]	validation_0-rmse:1.57614	validation_1-rmse:2.40345
# [27]	validation_0-rmse:1.55733	validation_1-rmse:2.39378
# [28]	validation_0-rmse:1.54082	validation_1-rmse:2.38288
# [29]	validation_0-rmse:1.52615	validation_1-rmse:2.37586
# [30]	validation_0-rmse:1.51067	validation_1-rmse:2.36786
# [31]	validation_0-rmse:1.49857	validation_1-rmse:2.35059
# [32]	validation_0-rmse:1.48797	validation_1-rmse:2.34570
# [33]	validation_0-rmse:1.47298	validation_1-rmse:2.32640
# [34]	validation_0-rmse:1.46258	validation_1-rmse:2.32184
# [35]	validation_0-rmse:1.45592	validation_1-rmse:2.31722
# [36]	validation_0-rmse:1.44825	validation_1-rmse:2.30217
# [37]	validation_0-rmse:1.44172	validation_1-rmse:2.29990
# [38]	validation_0-rmse:1.43708	validation_1-rmse:2.29566
# [39]	validation_0-rmse:1.43348	validation_1-rmse:2.29343
# [40]	validation_0-rmse:1.42688	validation_1-rmse:2.28871
# [41]	validation_0-rmse:1.41956	validation_1-rmse:2.28537
# [42]	validation_0-rmse:1.41675	validation_1-rmse:2.28620
# [43]	validation_0-rmse:1.40784	validation_1-rmse:2.28565
# [44]	validation_0-rmse:1.40140	validation_1-rmse:2.28223
# [45]	validation_0-rmse:1.39682	validation_1-rmse:2.28281
# [46]	validation_0-rmse:1.38646	validation_1-rmse:2.28442
# [47]	validation_0-rmse:1.37662	validation_1-rmse:2.28271
# [48]	validation_0-rmse:1.37127	validation_1-rmse:2.28513
# [49]	validation_0-rmse:1.36054	validation_1-rmse:2.28571
# [50]	validation_0-rmse:1.35491	validation_1-rmse:2.28260
# [51]	validation_0-rmse:1.34661	validation_1-rmse:2.26896
# [52]	validation_0-rmse:1.34053	validation_1-rmse:2.26025
# [53]	validation_0-rmse:1.33335	validation_1-rmse:2.26033
# [54]	validation_0-rmse:1.32861	validation_1-rmse:2.25759
# [55]	validation_0-rmse:1.32031	validation_1-rmse:2.25667
# [56]	validation_0-rmse:1.31512	validation_1-rmse:2.25894
# [57]	validation_0-rmse:1.31243	validation_1-rmse:2.25801
# [58]	validation_0-rmse:1.30703	validation_1-rmse:2.25855
# [59]	validation_0-rmse:1.30062	validation_1-rmse:2.25728
# [60]	validation_0-rmse:1.29522	validation_1-rmse:2.25878
# [61]	validation_0-rmse:1.29081	validation_1-rmse:2.25908
# [62]	validation_0-rmse:1.28339	validation_1-rmse:2.26165
# [63]	validation_0-rmse:1.27851	validation_1-rmse:2.26206
# [64]	validation_0-rmse:1.26886	validation_1-rmse:2.25685
# [65]	validation_0-rmse:1.26432	validation_1-rmse:2.25715
# [66]	validation_0-rmse:1.26140	validation_1-rmse:2.25636
# [67]	validation_0-rmse:1.25533	validation_1-rmse:2.25584
# [68]	validation_0-rmse:1.25210	validation_1-rmse:2.25440
# [69]	validation_0-rmse:1.24840	validation_1-rmse:2.25459
# [70]	validation_0-rmse:1.24626	validation_1-rmse:2.25438
# [71]	validation_0-rmse:1.24253	validation_1-rmse:2.25403
# [72]	validation_0-rmse:1.23870	validation_1-rmse:2.25266
# [73]	validation_0-rmse:1.23757	validation_1-rmse:2.25294
# [74]	validation_0-rmse:1.23025	validation_1-rmse:2.25175
# [75]	validation_0-rmse:1.22622	validation_1-rmse:2.25421
# [76]	validation_0-rmse:1.21783	validation_1-rmse:2.25489
# [77]	validation_0-rmse:1.21017	validation_1-rmse:2.25506
# [78]	validation_0-rmse:1.20612	validation_1-rmse:2.25581
# [79]	validation_0-rmse:1.19971	validation_1-rmse:2.25585
# [80]	validation_0-rmse:1.19329	validation_1-rmse:2.25562
# [81]	validation_0-rmse:1.18802	validation_1-rmse:2.25566
# [82]	validation_0-rmse:1.18420	validation_1-rmse:2.25540
# [83]	validation_0-rmse:1.17913	validation_1-rmse:2.24753
# [84]	validation_0-rmse:1.17712	validation_1-rmse:2.24704
# [85]	validation_0-rmse:1.17366	validation_1-rmse:2.24554
# [86]	validation_0-rmse:1.17297	validation_1-rmse:2.24511
# [87]	validation_0-rmse:1.16738	validation_1-rmse:2.24352
# [88]	validation_0-rmse:1.16414	validation_1-rmse:2.24492
# [89]	validation_0-rmse:1.16121	validation_1-rmse:2.24379
# [90]	validation_0-rmse:1.16017	validation_1-rmse:2.24488
# [91]	validation_0-rmse:1.15925	validation_1-rmse:2.24546
# [92]	validation_0-rmse:1.15564	validation_1-rmse:2.24574
# [93]	validation_0-rmse:1.15179	validation_1-rmse:2.24560
# [94]	validation_0-rmse:1.14909	validation_1-rmse:2.24497
# [95]	validation_0-rmse:1.14563	validation_1-rmse:2.24579
# [96]	validation_0-rmse:1.14138	validation_1-rmse:2.24630
# [97]	validation_0-rmse:1.13862	validation_1-rmse:2.24740
# [98]	validation_0-rmse:1.13501	validation_1-rmse:2.24748
# [99]	validation_0-rmse:1.13349	validation_1-rmse:2.24666
# [100]	validation_0-rmse:1.12839	validation_1-rmse:2.24580
# [101]	validation_0-rmse:1.12529	validation_1-rmse:2.24413
# [102]	validation_0-rmse:1.12214	validation_1-rmse:2.24406
# [103]	validation_0-rmse:1.11830	validation_1-rmse:2.24777
# [104]	validation_0-rmse:1.11509	validation_1-rmse:2.24799
# [105]	validation_0-rmse:1.10927	validation_1-rmse:2.24797
# [106]	validation_0-rmse:1.10801	validation_1-rmse:2.24854
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['16%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(0.0, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.589
# Uncertainty
# a0: 2.111+/-0.089
# a1: 0.5530+/-0.016

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: BA_sq_m_ha: mean - 0.862, median - 0.868, CI - [0.82-0.906]
#
# SHAP-values for: DBH_cm: mean - 0.28, median - 0.29, CI - [0.227-0.335]
#
# SHAP-values for: H_m: mean - 0.411, median - 0.407, CI - [0.359-0.471]
#
# SHAP-values for: Origin_ID: mean - 0.29, median - 0.288, CI - [0.255-0.326]
#
# SHAP-values for: Species_ID: mean - 0.96, median - 0.96, CI - [0.92-0.999]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['Species_ID', 'BA_sq_m_ha', 'H_m', 'DBH_cm', 'Origin_ID'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 104.865, median: 100.0,
#  pred. interval (P(0.025)-P(0.975)): 33.95-168.0,
#  conf. interval (p-value=0.95): 59.727-158.172
# ***
# Aggregate bias statistic:
#  mean: -0.009, median: -0.01,
#  pred. interval (P(0.025)-P(0.975)): -0.279-0.226,
#  conf. interval (p-value=0.95): -0.125-0.109
# ***
# Aggregate RMSE statistic:
#  mean: 1.8, median: 1.785, pred. interval (P(0.025)-P(0.975)): 1.51-2.245,
#  conf. interval (p-value=0.95): 1.658-1.937
# ***
# Aggregate MSE statistic:
#  mean: 3.274, median: 3.186, pred. interval (P(0.025)-P(0.975)): 2.28-5.041,
#  conf. interval (p-value=0.95): 2.749-3.755
# ***
# Aggregate R^2 statistic:
#  mean: 0.582, median: 0.588, pred. interval (P(0.025)-P(0.975)): 0.427-0.698,
#  conf. interval (p-value=0.95): 0.53-0.643
# ***
# Aggregate bias(%) statistic:
#  mean: -0.128, median: -0.01, pred. interval (P(0.025)-P(0.975)): -5.646-4.921,
#  conf. interval (p-value=0.95): -2.475-2.337
# ***
# Aggregate RMSE(%) statistic:
#  mean: 37.936, median: 37.527, pred. interval (P(0.025)-P(0.975)): 31.783-46.069,
#  conf. interval (p-value=0.95): 35.221-40.399
# ***

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:4.66659
# [1]	validation_0-rmse:4.32147
# [2]	validation_0-rmse:3.97998
# [3]	validation_0-rmse:3.69776
# [4]	validation_0-rmse:3.44039
# [5]	validation_0-rmse:3.21498
# [6]	validation_0-rmse:3.00323
# [7]	validation_0-rmse:2.82095
# [8]	validation_0-rmse:2.67025
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [9]	validation_0-rmse:2.52443
# [10]	validation_0-rmse:2.39730
# [11]	validation_0-rmse:2.29144
# [12]	validation_0-rmse:2.20205
# [13]	validation_0-rmse:2.12872
# [14]	validation_0-rmse:2.05640
# [15]	validation_0-rmse:2.01034
# [16]	validation_0-rmse:1.96310
# [17]	validation_0-rmse:1.93051
# [18]	validation_0-rmse:1.88997
# [19]	validation_0-rmse:1.85345
# [20]	validation_0-rmse:1.81425
# [21]	validation_0-rmse:1.78549
# [22]	validation_0-rmse:1.76452
# [23]	validation_0-rmse:1.75150
# [24]	validation_0-rmse:1.72664
# [25]	validation_0-rmse:1.70214
# [26]	validation_0-rmse:1.68688
# [27]	validation_0-rmse:1.66863
# [28]	validation_0-rmse:1.65334
# [29]	validation_0-rmse:1.64331
# [30]	validation_0-rmse:1.63272
# [31]	validation_0-rmse:1.62005
# [32]	validation_0-rmse:1.60534
# [33]	validation_0-rmse:1.59502
# [34]	validation_0-rmse:1.58321
# [35]	validation_0-rmse:1.57040
# [36]	validation_0-rmse:1.56401
# [37]	validation_0-rmse:1.55668
# [38]	validation_0-rmse:1.55381
# [39]	validation_0-rmse:1.54923
# [40]	validation_0-rmse:1.53942
# [41]	validation_0-rmse:1.53700
# [42]	validation_0-rmse:1.52623
# [43]	validation_0-rmse:1.52156
# [44]	validation_0-rmse:1.51287
# [45]	validation_0-rmse:1.50747
# [46]	validation_0-rmse:1.50090
# [47]	validation_0-rmse:1.49630
# [48]	validation_0-rmse:1.49196
# [49]	validation_0-rmse:1.49048
# [50]	validation_0-rmse:1.48638
# [51]	validation_0-rmse:1.48500
# [52]	validation_0-rmse:1.48382
# [53]	validation_0-rmse:1.47842
# [54]	validation_0-rmse:1.46544
# [55]	validation_0-rmse:1.46073
# [56]	validation_0-rmse:1.45326
# [57]	validation_0-rmse:1.44997
# [58]	validation_0-rmse:1.43970
# [59]	validation_0-rmse:1.43429
# [60]	validation_0-rmse:1.42874
# [61]	validation_0-rmse:1.41898
# [62]	validation_0-rmse:1.41448
# [63]	validation_0-rmse:1.40715
# [64]	validation_0-rmse:1.40303
# [65]	validation_0-rmse:1.39951
# [66]	validation_0-rmse:1.39317
# [67]	validation_0-rmse:1.38863
# [68]	validation_0-rmse:1.38371
# [69]	validation_0-rmse:1.38166
# [70]	validation_0-rmse:1.38094
# [71]	validation_0-rmse:1.37313
# [72]	validation_0-rmse:1.36792
# [73]	validation_0-rmse:1.36616
# [74]	validation_0-rmse:1.35915
# [75]	validation_0-rmse:1.35116
# [76]	validation_0-rmse:1.34822
# [77]	validation_0-rmse:1.34381
# [78]	validation_0-rmse:1.33926
# [79]	validation_0-rmse:1.33578
# [80]	validation_0-rmse:1.33139
# [81]	validation_0-rmse:1.32270
# [82]	validation_0-rmse:1.32193
# [83]	validation_0-rmse:1.31818
# [84]	validation_0-rmse:1.31562
# [85]	validation_0-rmse:1.31242
# [86]	validation_0-rmse:1.30977
# [87]	validation_0-rmse:1.30339
# [88]	validation_0-rmse:1.30295
# [89]	validation_0-rmse:1.29886
# [90]	validation_0-rmse:1.29425
# [91]	validation_0-rmse:1.28884
# [92]	validation_0-rmse:1.28512
# [93]	validation_0-rmse:1.28039
# [94]	validation_0-rmse:1.27784
# [95]	validation_0-rmse:1.27576
# [96]	validation_0-rmse:1.27239
# [97]	validation_0-rmse:1.27200
# [98]	validation_0-rmse:1.27167
# [99]	validation_0-rmse:1.27082
# [100]	validation_0-rmse:1.26285
# [101]	validation_0-rmse:1.25980
# [102]	validation_0-rmse:1.25440
# [103]	validation_0-rmse:1.25107
# [104]	validation_0-rmse:1.24885
# [105]	validation_0-rmse:1.24811
# [106]	validation_0-rmse:1.24455
# [107]	validation_0-rmse:1.24165
# [108]	validation_0-rmse:1.23749
# [109]	validation_0-rmse:1.23307
# [110]	validation_0-rmse:1.22866
# [111]	validation_0-rmse:1.22146
# [112]	validation_0-rmse:1.21677
# [113]	validation_0-rmse:1.21072
# [114]	validation_0-rmse:1.20703
# [115]	validation_0-rmse:1.19864
# [116]	validation_0-rmse:1.19568
# [117]	validation_0-rmse:1.19540
# [118]	validation_0-rmse:1.19043
# [119]	validation_0-rmse:1.18016
# [120]	validation_0-rmse:1.17274
# [121]	validation_0-rmse:1.16876
# [122]	validation_0-rmse:1.16745
# [123]	validation_0-rmse:1.16329
# [124]	validation_0-rmse:1.15844
# [125]	validation_0-rmse:1.15623
# [126]	validation_0-rmse:1.15233
# [127]	validation_0-rmse:1.14855
# [128]	validation_0-rmse:1.14475
# [129]	validation_0-rmse:1.14225
# [130]	validation_0-rmse:1.13988
# [131]	validation_0-rmse:1.13325
# [132]	validation_0-rmse:1.12704
# [133]	validation_0-rmse:1.12662
# [134]	validation_0-rmse:1.12364
# [135]	validation_0-rmse:1.12151
# [136]	validation_0-rmse:1.11678
# [137]	validation_0-rmse:1.11293
# [138]	validation_0-rmse:1.10880
# [139]	validation_0-rmse:1.10698
# [140]	validation_0-rmse:1.10379
# [141]	validation_0-rmse:1.10207
# [142]	validation_0-rmse:1.09864
# [143]	validation_0-rmse:1.09544
# [144]	validation_0-rmse:1.09253
# [145]	validation_0-rmse:1.09015
# [146]	validation_0-rmse:1.08626
# [147]	validation_0-rmse:1.08254
# [148]	validation_0-rmse:1.07656
# [149]	validation_0-rmse:1.06999
# [150]	validation_0-rmse:1.06842
# [151]	validation_0-rmse:1.06642
# [152]	validation_0-rmse:1.06004
# [153]	validation_0-rmse:1.05404
# [154]	validation_0-rmse:1.04881
# [155]	validation_0-rmse:1.04842
# [156]	validation_0-rmse:1.04661
# [157]	validation_0-rmse:1.04507
# [158]	validation_0-rmse:1.04078
# [159]	validation_0-rmse:1.03628
# [160]	validation_0-rmse:1.03403
# [161]	validation_0-rmse:1.03180
# [162]	validation_0-rmse:1.02916
# [163]	validation_0-rmse:1.02681
# [164]	validation_0-rmse:1.02344
# [165]	validation_0-rmse:1.02177
# [166]	validation_0-rmse:1.01984
# [167]	validation_0-rmse:1.01410
# [168]	validation_0-rmse:1.01286
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 168

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.01
# RMSE: 1.0
# Relative RMSE(%):  21.326
# MSE: 1.0
# R square: 87.1%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0.0, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.883
# Uncertainty
# a0: 1.03+/-0.05
# a1: 0.782+/-0.010

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../01_output_data/XGBoost_models/05_M_foliage_other_authors_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../01_output_data/XGBoost_models/05_M_foliage_other_authors_XGB_model.txt")
