# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25  idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167   0.050549
# 1           3600       8.189          15100  ...   0.040919   0.048889
# 2           4360       8.380          14600  ...   0.042397   0.050463
# 3           3420       8.137          12700  ...   0.043719   0.052974
# 4           2200       7.696          12100  ...   0.040659   0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966   0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602   0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265   0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465   0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420   0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 163 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                     'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 
                                    'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 
                                    'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75'])
            


# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           1912            784      -0.73       2.58
# 1       8.189       9.622           2005            818       0.59       2.92
# 2       8.380       9.589           2001            818       0.78       2.88
# 3       8.137       9.449           2040            833       0.52       2.72
# 4       7.696       9.401           1758            717       0.22       2.83
#
#    AEDR_mean  contr_r_MIN  contr_r_MAX  contr_r_MEAN  ...  contr_g_Q25  \
# 0       2.33     9.481502  2933.677734    777.847542  ...   541.256531
# 1       2.47    19.005865  1899.343872    833.407834  ...   647.693115
# 2       2.44    94.267365  1968.408691    773.760888  ...   588.255676
# 3       2.55     7.355157  2904.958740    711.545976  ...   505.498962
# 4       2.14    13.352172  3133.709961    806.127650  ...   590.198303
#
#    contr_g_Q50  contr_g_Q75  contr_b_MIN  contr_b_MAX  contr_b_MEAN  \
# 0   758.050110  1005.026367     9.379507  2713.600586    714.067764
# 1   887.856567  1150.706665    21.591255  1793.493042    766.078570
# 2   807.596130  1068.899292    80.702988  1761.097900    712.133098
# 3   732.743347   998.011780     9.797089  2518.435303    667.910072
# 4   842.132568  1103.787231    14.283794  2525.819336    755.761384
#
#    contr_b_STD  contr_b_Q25  contr_b_Q50  contr_b_Q75
# 0   332.963753   491.215576   684.545654   905.462463
# 1   293.868420   563.713623   752.421997   964.777466
# 2   272.526176   512.197632   689.422424   889.748047
# 3   299.595643   447.296204   641.451294   856.946899
# 4   327.599176   527.639099   746.745300   968.327698
#
# [5 rows x 28 columns]

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   contr_r_MIN    103 non-null    float64
#  8   contr_r_MAX    103 non-null    float64
#  9   contr_r_MEAN   103 non-null    float64
#  10  contr_r_STD    103 non-null    float64
#  11  contr_r_Q25    103 non-null    float64
#  12  contr_r_Q50    103 non-null    float64
#  13  contr_r_Q75    103 non-null    float64
#  14  contr_g_MIN    103 non-null    float64
#  15  contr_g_MAX    103 non-null    float64
#  16  contr_g_MEAN   103 non-null    float64
#  17  contr_g_STD    103 non-null    float64
#  18  contr_g_Q25    103 non-null    float64
#  19  contr_g_Q50    103 non-null    float64
#  20  contr_g_Q75    103 non-null    float64
#  21  contr_b_MIN    103 non-null    float64
#  22  contr_b_MAX    103 non-null    float64
#  23  contr_b_MEAN   103 non-null    float64
#  24  contr_b_STD    103 non-null    float64
#  25  contr_b_Q25    103 non-null    float64
#  26  contr_b_Q50    103 non-null    float64
#  27  contr_b_Q75    103 non-null    float64
# dtypes: float64(26), int64(2)
# memory usage: 22.7 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
# /tmp/ipykernel_7460/725619848.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3014.359223    1136.436893   -0.251845
# std       1.64946    1.472424    4988.505540    2019.773384    1.104536
# min       3.52600    6.075000     423.000000      98.000000   -3.030000
# 25%       6.31900    7.664000     635.500000     199.500000   -0.725000
# 50%       6.95700    8.472000    1145.000000     362.000000   -0.020000
# 75%       7.91350    9.421000    2423.500000     966.000000    0.520000
# max      11.36700   13.864000   25173.000000   10477.000000    1.650000
#
#         ln_Tag_Sr   AEDR_mean  contr_r_MIN  contr_r_MAX  contr_r_MEAN  ...  \
# count  103.000000  103.000000   103.000000   103.000000    103.000000  ...
# mean     2.464854    3.570291    29.534919  2511.986354    766.000754  ...
# std      0.904757    6.089170    49.649243  1340.330498    402.724570  ...
# min      0.390000    0.480000    -0.027178     0.805054      0.417302  ...
# 25%      1.805000    0.710000     1.742763  1978.231751    633.735958  ...
# 50%      2.600000    1.290000     7.970921  2722.256592    858.911069  ...
# 75%      3.160000    2.960000    33.764453  3268.150146   1065.068586  ...
# max      4.660000   36.590000   249.526947  6225.004394   1586.523806  ...
#
#        contr_g_Q25  contr_g_Q50  contr_g_Q75  contr_b_MIN  contr_b_MAX  \
# count   103.000000   103.000000   103.000000   103.000000   103.000000
# mean    641.169153   901.502855  1180.985742    32.391008  2712.352866
# std     240.919219   300.935943   358.329636    46.420771   864.116297
# min     128.989090   186.037750   262.800140     0.531948   832.155518
# 25%     495.765656   723.074707   979.669098     5.277856  2123.614868
# 50%     640.676514   901.381104  1202.431396    15.266269  2601.248047
# 75%     842.500641  1117.960938  1428.865540    46.832664  3045.944336
# max    1251.066162  1681.644287  2124.060303   246.557938  6252.923340
#
#        contr_b_MEAN  contr_b_STD  contr_b_Q25  contr_b_Q50  contr_b_Q75
# count    103.000000   103.000000   103.000000   103.000000   103.000000
# mean     827.695538   349.854034   584.146224   811.233079  1047.783981
# std      251.466656    93.673105   216.532754   263.192567   306.704451
# min      199.382755   109.232976   120.188545   175.167770   252.607666
# 25%      667.868117   292.544440   447.856689   639.053284   855.619751
# 50%      831.486847   341.904211   563.713623   815.357056  1063.953491
# 75%     1039.339119   427.359073   759.041443  1030.824829  1273.864319
# max     1462.557110   588.661708  1150.023315  1473.567871  1833.971802
#
# [8 rows x 28 columns]

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75'])
y = pd.DataFrame(select, columns= ['ln_Tag_Cs'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): Yes
# Selected "Yes"!!! A new column with random values was created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    contr_r_MIN  contr_r_MAX  contr_r_MEAN  contr_r_STD  contr_r_Q25  \
# 0     9.481502  2933.677734    777.847542   360.273487   536.306519
# 1    19.005865  1899.343872    833.407834   323.958625   603.536560
# 2    94.267365  1968.408691    773.760888   299.438354   551.243347
# 3     7.355157  2904.958740    711.545976   319.773395   475.958679
# 4    13.352172  3133.709961    806.127650   353.104284   557.816040
#
#    contr_r_Q50  contr_r_Q75  contr_g_MIN  contr_g_MAX  contr_g_MEAN  ...  \
# 0   746.253296   982.211853     9.634772  2961.898193    793.726915  ...
# 1   815.666809  1054.089966    17.242392  2218.239746    907.262181  ...
# 2   745.311951   971.663940    81.325912  2220.297119    841.001715  ...
# 3   681.415588   912.117859     7.830567  3033.770752    772.110070  ...
# 4   790.760193  1027.114380    13.923030  3003.818848    862.516837  ...
#
#    contr_b_MEAN  contr_b_STD  contr_b_Q25  contr_b_Q50  contr_b_Q75  \
# 0    714.067764   332.963753   491.215576   684.545654   905.462463
# 1    766.078570   293.868420   563.713623   752.421997   964.777466
# 2    712.133098   272.526176   512.197632   689.422424   889.748047
# 3    667.910072   299.595643   447.296204   641.451294   856.946899
# 4    755.761384   327.599176   527.639099   746.745300   968.327698
#
#      Random1    Random2    Random3    Random4    Random5
# 0  12.824010   8.305600   9.607411   8.239326  10.802564
# 1  10.329417   9.534188   8.786029  14.174154  11.595471
# 2  10.765645  10.936020  10.677544   8.992943   9.916622
# 3  13.132316  13.309456   9.346222  12.147518   8.933207
# 4   8.207639   7.492557  11.661707  11.411830  10.110982
#
# [5 rows x 26 columns]

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Tag_Cs
# 0      -0.73
# 1       0.59
# 2       0.78
# 3       0.52
# 4       0.22

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [-0.3055616164503976, -0.17783601657592585, -0.3745622229857761]
#     Mean: -0.286
#     Std: 0.081
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.36064011 1.04813414 1.26944058]
#     Mean: 1.226
#     Std: 0.131
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.937955553495458, 1.0588193725044015, 0.8868610469410744]
#     Mean: 0.961
#     Std: 0.072
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=10, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Model with rank: 1
# Mean validation score: -0.278 (std: 0.484)
# Parameters: {'colsample_bytree': 0.8857900632173091, 'gamma': 0.39973305905552464, 'learning_rate': 0.03517999981274761, 'max_depth': 4, 'n_estimators': 50, 'subsample': 0.3537467343753268}

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.82923489, 0.59003539, 0.29996238, 0.5643539 , 0.64290566,
#        1.14996405, 2.33941488, 0.3806695 , 0.23847723, 0.58632617]), 'std_fit_time': array([0.45674261, 0.19251996, 0.08941209, 0.31403315, 0.06851629,
#        0.92366902, 1.94114004, 0.03829231, 0.02926348, 0.14062738]), 'mean_score_time': array([0.00700088, 0.00986991, 0.00966268, 0.00836778, 0.00878649,
#        0.00741305, 0.01403565, 0.00856996, 0.00893621, 0.00869923]), 'std_score_time': array([7.83211964e-05, 4.66391564e-03, 4.30526444e-03, 1.98864759e-03,
#        2.74982318e-03, 1.64288055e-04, 7.37687084e-03, 9.36950520e-04,
#        1.90577098e-03, 7.16325713e-04]), 'param_colsample_bytree': masked_array(data=[0.8027994562742725, 0.25223683913921335,
#                    0.4789416029367035, 0.8122248189155293,
#                    0.09835619928879202, 0.4294026838476892,
#                    0.13346308074540789, 0.6682778336291495,
#                    0.8857900632173091, 0.6793089487215305],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.4847157713767124, 0.251829589195992,
#                    0.19065103570704744, 0.22334394276320668,
#                    0.30063053858887606, 0.24259888744506425,
#                    0.35116131826637065, 0.143858499806426,
#                    0.39973305905552464, 0.017306819498902948],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.12574512397611531, 0.1075796893123027,
#                    0.1607803101740019, 0.08879287243511644,
#                    0.06081030330757092, 0.2923746027965398,
#                    0.11984236479927556, 0.05958319007958053,
#                    0.03517999981274761, 0.1876595048099063],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[3, 3, 3, 2, 2, 4, 4, 2, 4, 2],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[192, 103, 68, 92, 117, 165, 184, 85, 50, 118],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.7375012746512098, 0.404688809107525,
#                    0.5556511669406553, 0.9363286582867978,
#                    0.6809905801436336, 0.843730154752478,
#                    0.7222610267270448, 0.408277822612403,
#                    0.3537467343753268, 0.35254922241492115],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.8027994562742725, 'gamma': 0.4847157713767124, 'learning_rate': 0.12574512397611531, 'max_depth': 3, 'n_estimators': 192, 'subsample': 0.7375012746512098}, {'colsample_bytree': 0.25223683913921335, 'gamma': 0.251829589195992, 'learning_rate': 0.1075796893123027, 'max_depth': 3, 'n_estimators': 103, 'subsample': 0.404688809107525}, {'colsample_bytree': 0.4789416029367035, 'gamma': 0.19065103570704744, 'learning_rate': 0.1607803101740019, 'max_depth': 3, 'n_estimators': 68, 'subsample': 0.5556511669406553}, {'colsample_bytree': 0.8122248189155293, 'gamma': 0.22334394276320668, 'learning_rate': 0.08879287243511644, 'max_depth': 2, 'n_estimators': 92, 'subsample': 0.9363286582867978}, {'colsample_bytree': 0.09835619928879202, 'gamma': 0.30063053858887606, 'learning_rate': 0.06081030330757092, 'max_depth': 2, 'n_estimators': 117, 'subsample': 0.6809905801436336}, {'colsample_bytree': 0.4294026838476892, 'gamma': 0.24259888744506425, 'learning_rate': 0.2923746027965398, 'max_depth': 4, 'n_estimators': 165, 'subsample': 0.843730154752478}, {'colsample_bytree': 0.13346308074540789, 'gamma': 0.35116131826637065, 'learning_rate': 0.11984236479927556, 'max_depth': 4, 'n_estimators': 184, 'subsample': 0.7222610267270448}, {'colsample_bytree': 0.6682778336291495, 'gamma': 0.143858499806426, 'learning_rate': 0.05958319007958053, 'max_depth': 2, 'n_estimators': 85, 'subsample': 0.408277822612403}, {'colsample_bytree': 0.8857900632173091, 'gamma': 0.39973305905552464, 'learning_rate': 0.03517999981274761, 'max_depth': 4, 'n_estimators': 50, 'subsample': 0.3537467343753268}, {'colsample_bytree': 0.6793089487215305, 'gamma': 0.017306819498902948, 'learning_rate': 0.1876595048099063, 'max_depth': 2, 'n_estimators': 118, 'subsample': 0.35254922241492115}], 'split0_test_score': array([-0.89369902, -1.70536024, -1.24699095, -1.13799823, -0.83961214,
#        -1.20964029, -1.32172934, -0.77215971, -0.2187681 , -2.90497491]), 'split1_test_score': array([-0.11429827, -0.3465442 , -0.10558111,  0.00555201, -0.03117962,
#        -0.37586551, -0.00063003,  0.0182439 ,  0.31229909,  0.19857226]), 'split2_test_score': array([-0.07094638,  0.05857041, -0.00291369, -0.10680983, -0.01589991,
#         0.15205145,  0.03657258,  0.0622286 ,  0.0025456 , -0.36325546]), 'split3_test_score': array([-3.45680155, -2.6339221 , -3.31332203, -3.35528862, -1.29700564,
#        -2.97105272, -1.39892492, -3.14199422, -1.13539944, -5.7375223 ]), 'split4_test_score': array([-0.20518265, -0.22685421, -0.35361861, -0.20833615, -0.14874579,
#        -0.24546742, -0.19815862, -0.25682687, -0.35204971, -0.26025673]), 'mean_test_score': array([-0.94818557, -0.97082207, -1.00448528, -0.96057617, -0.46648862,
#        -0.9299949 , -0.57657407, -0.81810166, -0.27827451, -1.81348743]), 'std_test_score': array([1.28942568, 1.03036964, 1.23485529, 1.26446131, 0.51428869,
#        1.11270662, 0.64534888, 1.19933915, 0.48400084, 2.24292118]), 'rank_test_score': array([ 6,  8,  9,  7,  2,  5,  3,  4,  1, 10], dtype=int32), 'split0_train_score': array([0.95859844, 0.94373272, 0.96758415, 0.88710708, 0.75590697,
#        0.97948093, 0.96119814, 0.73362264, 0.56462702, 0.96779985]), 'split1_train_score': array([0.95282023, 0.93217276, 0.96677545, 0.86994039, 0.72890342,
#        0.9788054 , 0.95806994, 0.71163117, 0.53240955, 0.95387904]), 'split2_train_score': array([0.9421779 , 0.93139535, 0.96191118, 0.89499096, 0.75353839,
#        0.97194491, 0.94886556, 0.7423012 , 0.57711763, 0.96714139]), 'split3_train_score': array([0.95349605, 0.92772358, 0.95930755, 0.86522327, 0.74127127,
#        0.97662725, 0.9584362 , 0.70161731, 0.57115781, 0.95644375]), 'split4_train_score': array([0.94023898, 0.91502506, 0.95688578, 0.88754237, 0.77201525,
#        0.97175384, 0.94285811, 0.71453842, 0.55972957, 0.9602103 ]), 'mean_train_score': array([0.94946632, 0.93000989, 0.96249282, 0.88096081, 0.75032706,
#        0.97572247, 0.95388559, 0.72074215, 0.56100832, 0.96109487]), 'std_train_score': array([0.00705901, 0.00921614, 0.00415177, 0.01137593, 0.01451072,
#        0.00330058, 0.00690646, 0.01495296, 0.01546054, 0.00558571])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.8857900632173091
# Gamma: 0.39973305905552464
# Learning_rate: 0.03517999981274761
# Max_depth: 4
# N_estimators: 50
# Subsample: 0.3537467343753268

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(30):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:1.39965	validation_1-rmse:0.93597
# [1]	validation_0-rmse:1.37043	validation_1-rmse:0.91574
# [2]	validation_0-rmse:1.35073	validation_1-rmse:0.91557
# [3]	validation_0-rmse:1.33329	validation_1-rmse:0.90371
# [4]	validation_0-rmse:1.31176	validation_1-rmse:0.89204
# [5]	validation_0-rmse:1.28511	validation_1-rmse:0.88513
# [6]	validation_0-rmse:1.25989	validation_1-rmse:0.87529
# [7]	validation_0-rmse:1.23380	validation_1-rmse:0.86261
# [8]	validation_0-rmse:1.22372	validation_1-rmse:0.86049
# [9]	validation_0-rmse:1.20066	validation_1-rmse:0.85110
# [10]	validation_0-rmse:1.19132	validation_1-rmse:0.85083
# [11]	validation_0-rmse:1.18281	validation_1-rmse:0.85441
# [12]	validation_0-rmse:1.16448	validation_1-rmse:0.84827
# [13]	validation_0-rmse:1.14679	validation_1-rmse:0.84913
# [14]	validation_0-rmse:1.13742	validation_1-rmse:0.85334
# [15]	validation_0-rmse:1.11139	validation_1-rmse:0.85415
# [16]	validation_0-rmse:1.10296	validation_1-rmse:0.85377
# [17]	validation_0-rmse:1.08956	validation_1-rmse:0.85505
# [18]	validation_0-rmse:1.07749	validation_1-rmse:0.86389
# [19]	validation_0-rmse:1.06904	validation_1-rmse:0.86393
# [20]	validation_0-rmse:1.06223	validation_1-rmse:0.85899
# [21]	validation_0-rmse:1.04905	validation_1-rmse:0.86860
# [22]	validation_0-rmse:1.03433	validation_1-rmse:0.87302
# [23]	validation_0-rmse:1.02358	validation_1-rmse:0.87219
# [24]	validation_0-rmse:0.99940	validation_1-rmse:0.86894
# [25]	validation_0-rmse:0.98341	validation_1-rmse:0.86738
# [26]	validation_0-rmse:0.97537	validation_1-rmse:0.86918
# [27]	validation_0-rmse:0.96220	validation_1-rmse:0.88247
# [28]	validation_0-rmse:0.94988	validation_1-rmse:0.88215
# [29]	validation_0-rmse:0.94393	validation_1-rmse:0.88929
# [30]	validation_0-rmse:0.93256	validation_1-rmse:0.89839
# [31]	validation_0-rmse:0.92201	validation_1-rmse:0.89179
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:1.25614	validation_1-rmse:1.48832
# [1]	validation_0-rmse:1.23637	validation_1-rmse:1.47807
# [2]	validation_0-rmse:1.21743	validation_1-rmse:1.46289
# [3]	validation_0-rmse:1.21319	validation_1-rmse:1.46110
# [4]	validation_0-rmse:1.19670	validation_1-rmse:1.44854
# [5]	validation_0-rmse:1.17757	validation_1-rmse:1.44033
# [6]	validation_0-rmse:1.16508	validation_1-rmse:1.43173
# [7]	validation_0-rmse:1.15211	validation_1-rmse:1.42487
# [8]	validation_0-rmse:1.12968	validation_1-rmse:1.40758
# [9]	validation_0-rmse:1.11846	validation_1-rmse:1.40295
# [10]	validation_0-rmse:1.11130	validation_1-rmse:1.38981
# [11]	validation_0-rmse:1.08975	validation_1-rmse:1.37751
# [12]	validation_0-rmse:1.07766	validation_1-rmse:1.35905
# [13]	validation_0-rmse:1.06198	validation_1-rmse:1.35668
# [14]	validation_0-rmse:1.04176	validation_1-rmse:1.33863
# [15]	validation_0-rmse:1.02920	validation_1-rmse:1.32558
# [16]	validation_0-rmse:1.01581	validation_1-rmse:1.32422
# [17]	validation_0-rmse:1.00022	validation_1-rmse:1.32079
# [18]	validation_0-rmse:0.99282	validation_1-rmse:1.31858
# [19]	validation_0-rmse:0.98690	validation_1-rmse:1.31762
# [20]	validation_0-rmse:0.96898	validation_1-rmse:1.30604
# [21]	validation_0-rmse:0.96568	validation_1-rmse:1.30531
# [22]	validation_0-rmse:0.95440	validation_1-rmse:1.30777
# [23]	validation_0-rmse:0.94989	validation_1-rmse:1.30908
# [24]	validation_0-rmse:0.94079	validation_1-rmse:1.30238
# [25]	validation_0-rmse:0.93591	validation_1-rmse:1.29374
# [26]	validation_0-rmse:0.92563	validation_1-rmse:1.29178
# [27]	validation_0-rmse:0.91994	validation_1-rmse:1.28554
# [28]	validation_0-rmse:0.90923	validation_1-rmse:1.28192
# [29]	validation_0-rmse:0.90678	validation_1-rmse:1.28439
# [30]	validation_0-rmse:0.89686	validation_1-rmse:1.27396
# [31]	validation_0-rmse:0.88645	validation_1-rmse:1.26770
# [32]	validation_0-rmse:0.87763	validation_1-rmse:1.25254
# [33]	validation_0-rmse:0.86760	validation_1-rmse:1.25213
# [34]	validation_0-rmse:0.86648	validation_1-rmse:1.25352
# [35]	validation_0-rmse:0.85618	validation_1-rmse:1.24288
# [36]	validation_0-rmse:0.84129	validation_1-rmse:1.23707
# [37]	validation_0-rmse:0.82738	validation_1-rmse:1.23446
# [38]	validation_0-rmse:0.81900	validation_1-rmse:1.23282
# [39]	validation_0-rmse:0.81365	validation_1-rmse:1.23423
# [40]	validation_0-rmse:0.80255	validation_1-rmse:1.22457
# [41]	validation_0-rmse:0.79791	validation_1-rmse:1.21783
# [42]	validation_0-rmse:0.79223	validation_1-rmse:1.21680
# [43]	validation_0-rmse:0.78694	validation_1-rmse:1.21724
# [44]	validation_0-rmse:0.78545	validation_1-rmse:1.21286
# [45]	validation_0-rmse:0.78205	validation_1-rmse:1.21064
# [46]	validation_0-rmse:0.77206	validation_1-rmse:1.20548
# [47]	validation_0-rmse:0.76783	validation_1-rmse:1.20952
# [48]	validation_0-rmse:0.76289	validation_1-rmse:1.21167
# [49]	validation_0-rmse:0.75612	validation_1-rmse:1.21592
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:1.31388	validation_1-rmse:1.26421
# [1]	validation_0-rmse:1.28943	validation_1-rmse:1.24571
# [2]	validation_0-rmse:1.26732	validation_1-rmse:1.23047
# [3]	validation_0-rmse:1.25574	validation_1-rmse:1.22645
# [4]	validation_0-rmse:1.23177	validation_1-rmse:1.20803
# [5]	validation_0-rmse:1.20775	validation_1-rmse:1.20563
# [6]	validation_0-rmse:1.19010	validation_1-rmse:1.19188
# [7]	validation_0-rmse:1.17701	validation_1-rmse:1.18802
# [8]	validation_0-rmse:1.14562	validation_1-rmse:1.17562
# [9]	validation_0-rmse:1.12736	validation_1-rmse:1.17349
# [10]	validation_0-rmse:1.11054	validation_1-rmse:1.16313
# [11]	validation_0-rmse:1.09896	validation_1-rmse:1.15494
# [12]	validation_0-rmse:1.07784	validation_1-rmse:1.14429
# [13]	validation_0-rmse:1.05991	validation_1-rmse:1.13877
# [14]	validation_0-rmse:1.04804	validation_1-rmse:1.12953
# [15]	validation_0-rmse:1.02913	validation_1-rmse:1.12125
# [16]	validation_0-rmse:1.01240	validation_1-rmse:1.12730
# [17]	validation_0-rmse:0.99429	validation_1-rmse:1.12956
# [18]	validation_0-rmse:0.98273	validation_1-rmse:1.12476
# [19]	validation_0-rmse:0.96985	validation_1-rmse:1.12405
# [20]	validation_0-rmse:0.95689	validation_1-rmse:1.12143
# [21]	validation_0-rmse:0.94502	validation_1-rmse:1.11762
# [22]	validation_0-rmse:0.93632	validation_1-rmse:1.11855
# [23]	validation_0-rmse:0.92298	validation_1-rmse:1.11609
# [24]	validation_0-rmse:0.91352	validation_1-rmse:1.10653
# [25]	validation_0-rmse:0.90499	validation_1-rmse:1.10874
# [26]	validation_0-rmse:0.89262	validation_1-rmse:1.10714
# [27]	validation_0-rmse:0.88484	validation_1-rmse:1.10734
# [28]	validation_0-rmse:0.87647	validation_1-rmse:1.11220
# [29]	validation_0-rmse:0.86876	validation_1-rmse:1.10739
# [30]	validation_0-rmse:0.85492	validation_1-rmse:1.09892
# [31]	validation_0-rmse:0.84886	validation_1-rmse:1.09420
# [32]	validation_0-rmse:0.83847	validation_1-rmse:1.09177
# [33]	validation_0-rmse:0.82924	validation_1-rmse:1.09118
# [34]	validation_0-rmse:0.82342	validation_1-rmse:1.09623
# [35]	validation_0-rmse:0.81863	validation_1-rmse:1.09506
# [36]	validation_0-rmse:0.81030	validation_1-rmse:1.09343
# [37]	validation_0-rmse:0.79948	validation_1-rmse:1.09524
# [38]	validation_0-rmse:0.78769	validation_1-rmse:1.09490
# [39]	validation_0-rmse:0.77816	validation_1-rmse:1.09216
# [40]	validation_0-rmse:0.77224	validation_1-rmse:1.08776
# [41]	validation_0-rmse:0.76727	validation_1-rmse:1.08877
# [42]	validation_0-rmse:0.76510	validation_1-rmse:1.08875
# [43]	validation_0-rmse:0.75823	validation_1-rmse:1.08996
# [44]	validation_0-rmse:0.74811	validation_1-rmse:1.09148
# [45]	validation_0-rmse:0.73983	validation_1-rmse:1.09511
# [46]	validation_0-rmse:0.73160	validation_1-rmse:1.09629
# [47]	validation_0-rmse:0.72908	validation_1-rmse:1.09488
# [48]	validation_0-rmse:0.72177	validation_1-rmse:1.09899
# [49]	validation_0-rmse:0.71492	validation_1-rmse:1.10049
# [0]	validation_0-rmse:1.22051	validation_1-rmse:1.65343
# [1]	validation_0-rmse:1.21191	validation_1-rmse:1.65012
# [2]	validation_0-rmse:1.18889	validation_1-rmse:1.64616
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:1.17859	validation_1-rmse:1.63254
# [4]	validation_0-rmse:1.15869	validation_1-rmse:1.61674
# [5]	validation_0-rmse:1.14083	validation_1-rmse:1.58831
# [6]	validation_0-rmse:1.11707	validation_1-rmse:1.56609
# [7]	validation_0-rmse:1.10353	validation_1-rmse:1.56048
# [8]	validation_0-rmse:1.08577	validation_1-rmse:1.55130
# [9]	validation_0-rmse:1.05967	validation_1-rmse:1.53279
# [10]	validation_0-rmse:1.04471	validation_1-rmse:1.51947
# [11]	validation_0-rmse:1.03915	validation_1-rmse:1.52059
# [12]	validation_0-rmse:1.02614	validation_1-rmse:1.52382
# [13]	validation_0-rmse:1.01665	validation_1-rmse:1.50926
# [14]	validation_0-rmse:1.00098	validation_1-rmse:1.49969
# [15]	validation_0-rmse:0.98643	validation_1-rmse:1.48116
# [16]	validation_0-rmse:0.97855	validation_1-rmse:1.48062
# [17]	validation_0-rmse:0.97338	validation_1-rmse:1.47681
# [18]	validation_0-rmse:0.97099	validation_1-rmse:1.47290
# [19]	validation_0-rmse:0.96952	validation_1-rmse:1.46823
# [20]	validation_0-rmse:0.96574	validation_1-rmse:1.46932
# [21]	validation_0-rmse:0.96696	validation_1-rmse:1.47822
# [22]	validation_0-rmse:0.95245	validation_1-rmse:1.46759
# [23]	validation_0-rmse:0.93696	validation_1-rmse:1.44707
# [24]	validation_0-rmse:0.93532	validation_1-rmse:1.44869
# [25]	validation_0-rmse:0.93401	validation_1-rmse:1.44659
# [26]	validation_0-rmse:0.92809	validation_1-rmse:1.44556
# [27]	validation_0-rmse:0.90866	validation_1-rmse:1.43374
# [28]	validation_0-rmse:0.89449	validation_1-rmse:1.41347
# [29]	validation_0-rmse:0.88168	validation_1-rmse:1.40923
# [30]	validation_0-rmse:0.87856	validation_1-rmse:1.40655
# [31]	validation_0-rmse:0.86700	validation_1-rmse:1.39716
# [32]	validation_0-rmse:0.86155	validation_1-rmse:1.39534
# [33]	validation_0-rmse:0.84577	validation_1-rmse:1.39512
# [34]	validation_0-rmse:0.83477	validation_1-rmse:1.39770
# [35]	validation_0-rmse:0.82292	validation_1-rmse:1.39800
# [36]	validation_0-rmse:0.80770	validation_1-rmse:1.38940
# [37]	validation_0-rmse:0.79748	validation_1-rmse:1.38238
# [38]	validation_0-rmse:0.79096	validation_1-rmse:1.37454
# [39]	validation_0-rmse:0.78092	validation_1-rmse:1.36224
# [40]	validation_0-rmse:0.76993	validation_1-rmse:1.35182
# [41]	validation_0-rmse:0.76116	validation_1-rmse:1.34732
# [42]	validation_0-rmse:0.75568	validation_1-rmse:1.34532
# [43]	validation_0-rmse:0.74914	validation_1-rmse:1.34119
# [44]	validation_0-rmse:0.73928	validation_1-rmse:1.33766
# [45]	validation_0-rmse:0.73706	validation_1-rmse:1.32843
# [46]	validation_0-rmse:0.72289	validation_1-rmse:1.32812
# [47]	validation_0-rmse:0.71352	validation_1-rmse:1.32794
# [48]	validation_0-rmse:0.70499	validation_1-rmse:1.32381
# [49]	validation_0-rmse:0.69922	validation_1-rmse:1.32743
# [0]	validation_0-rmse:1.33706	validation_1-rmse:1.21246
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [1]	validation_0-rmse:1.32347	validation_1-rmse:1.19210
# [2]	validation_0-rmse:1.30337	validation_1-rmse:1.17460
# [3]	validation_0-rmse:1.27560	validation_1-rmse:1.17015
# [4]	validation_0-rmse:1.25480	validation_1-rmse:1.16301
# [5]	validation_0-rmse:1.23033	validation_1-rmse:1.15618
# [6]	validation_0-rmse:1.20819	validation_1-rmse:1.14647
# [7]	validation_0-rmse:1.18802	validation_1-rmse:1.11619
# [8]	validation_0-rmse:1.18025	validation_1-rmse:1.11859
# [9]	validation_0-rmse:1.16794	validation_1-rmse:1.10759
# [10]	validation_0-rmse:1.14926	validation_1-rmse:1.09635
# [11]	validation_0-rmse:1.12231	validation_1-rmse:1.07439
# [12]	validation_0-rmse:1.10781	validation_1-rmse:1.07017
# [13]	validation_0-rmse:1.08820	validation_1-rmse:1.05588
# [14]	validation_0-rmse:1.07943	validation_1-rmse:1.05020
# [15]	validation_0-rmse:1.06163	validation_1-rmse:1.04314
# [16]	validation_0-rmse:1.04753	validation_1-rmse:1.04612
# [17]	validation_0-rmse:1.03399	validation_1-rmse:1.05247
# [18]	validation_0-rmse:1.01937	validation_1-rmse:1.03139
# [19]	validation_0-rmse:1.01274	validation_1-rmse:1.03309
# [20]	validation_0-rmse:1.00455	validation_1-rmse:1.02724
# [21]	validation_0-rmse:0.99796	validation_1-rmse:1.02744
# [22]	validation_0-rmse:0.98570	validation_1-rmse:1.01604
# [23]	validation_0-rmse:0.97211	validation_1-rmse:1.01562
# [24]	validation_0-rmse:0.96564	validation_1-rmse:1.01289
# [25]	validation_0-rmse:0.95636	validation_1-rmse:1.00075
# [26]	validation_0-rmse:0.95258	validation_1-rmse:1.00613
# [27]	validation_0-rmse:0.94316	validation_1-rmse:0.99896
# [28]	validation_0-rmse:0.92576	validation_1-rmse:1.00073
# [29]	validation_0-rmse:0.91929	validation_1-rmse:1.00659
# [30]	validation_0-rmse:0.91575	validation_1-rmse:1.00811
# [31]	validation_0-rmse:0.90163	validation_1-rmse:1.00433
# [32]	validation_0-rmse:0.89519	validation_1-rmse:1.00287
# [33]	validation_0-rmse:0.88416	validation_1-rmse:1.01379
# [34]	validation_0-rmse:0.87346	validation_1-rmse:1.00527
# [35]	validation_0-rmse:0.86270	validation_1-rmse:1.01303
# [36]	validation_0-rmse:0.85391	validation_1-rmse:1.00681
# [37]	validation_0-rmse:0.84645	validation_1-rmse:1.00802
# [38]	validation_0-rmse:0.83465	validation_1-rmse:1.00408
# [39]	validation_0-rmse:0.82310	validation_1-rmse:1.00567
# [40]	validation_0-rmse:0.81604	validation_1-rmse:0.99820
# [41]	validation_0-rmse:0.81386	validation_1-rmse:1.00055
# [42]	validation_0-rmse:0.81181	validation_1-rmse:1.00599
# [43]	validation_0-rmse:0.80724	validation_1-rmse:1.01510
# [44]	validation_0-rmse:0.80313	validation_1-rmse:1.00997
# [45]	validation_0-rmse:0.80258	validation_1-rmse:1.01108
# [46]	validation_0-rmse:0.79260	validation_1-rmse:1.01510
# [47]	validation_0-rmse:0.78615	validation_1-rmse:1.02287
# [48]	validation_0-rmse:0.77824	validation_1-rmse:1.02911
# [49]	validation_0-rmse:0.77212	validation_1-rmse:1.02821
# [0]	validation_0-rmse:1.31304	validation_1-rmse:1.30414
# [1]	validation_0-rmse:1.28701	validation_1-rmse:1.28310
# [2]	validation_0-rmse:1.26959	validation_1-rmse:1.26964
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:1.25074	validation_1-rmse:1.25617
# [4]	validation_0-rmse:1.22955	validation_1-rmse:1.23901
# [5]	validation_0-rmse:1.20801	validation_1-rmse:1.23153
# [6]	validation_0-rmse:1.19133	validation_1-rmse:1.21068
# [7]	validation_0-rmse:1.17291	validation_1-rmse:1.19821
# [8]	validation_0-rmse:1.14819	validation_1-rmse:1.17867
# [9]	validation_0-rmse:1.13190	validation_1-rmse:1.16955
# [10]	validation_0-rmse:1.11239	validation_1-rmse:1.16145
# [11]	validation_0-rmse:1.10381	validation_1-rmse:1.16226
# [12]	validation_0-rmse:1.08110	validation_1-rmse:1.15067
# [13]	validation_0-rmse:1.07328	validation_1-rmse:1.14410
# [14]	validation_0-rmse:1.05887	validation_1-rmse:1.13970
# [15]	validation_0-rmse:1.04195	validation_1-rmse:1.13507
# [16]	validation_0-rmse:1.02747	validation_1-rmse:1.12889
# [17]	validation_0-rmse:1.01537	validation_1-rmse:1.13158
# [18]	validation_0-rmse:0.99740	validation_1-rmse:1.11668
# [19]	validation_0-rmse:0.98967	validation_1-rmse:1.11315
# [20]	validation_0-rmse:0.97733	validation_1-rmse:1.11287
# [21]	validation_0-rmse:0.96577	validation_1-rmse:1.11663
# [22]	validation_0-rmse:0.95475	validation_1-rmse:1.11541
# [23]	validation_0-rmse:0.94289	validation_1-rmse:1.11559
# [24]	validation_0-rmse:0.93252	validation_1-rmse:1.11130
# [25]	validation_0-rmse:0.92459	validation_1-rmse:1.10977
# [26]	validation_0-rmse:0.91037	validation_1-rmse:1.09397
# [27]	validation_0-rmse:0.89894	validation_1-rmse:1.08414
# [28]	validation_0-rmse:0.89108	validation_1-rmse:1.08845
# [29]	validation_0-rmse:0.87958	validation_1-rmse:1.08727
# [30]	validation_0-rmse:0.86969	validation_1-rmse:1.08806
# [31]	validation_0-rmse:0.85670	validation_1-rmse:1.07787
# [32]	validation_0-rmse:0.84842	validation_1-rmse:1.07432
# [33]	validation_0-rmse:0.83598	validation_1-rmse:1.06994
# [34]	validation_0-rmse:0.83211	validation_1-rmse:1.06746
# [35]	validation_0-rmse:0.82783	validation_1-rmse:1.06579
# [36]	validation_0-rmse:0.81984	validation_1-rmse:1.06709
# [37]	validation_0-rmse:0.81174	validation_1-rmse:1.06189
# [38]	validation_0-rmse:0.80518	validation_1-rmse:1.06105
# [39]	validation_0-rmse:0.79996	validation_1-rmse:1.06226
# [40]	validation_0-rmse:0.79559	validation_1-rmse:1.06204
# [41]	validation_0-rmse:0.78973	validation_1-rmse:1.06348
# [42]	validation_0-rmse:0.78597	validation_1-rmse:1.06400
# [43]	validation_0-rmse:0.77537	validation_1-rmse:1.06471
# [44]	validation_0-rmse:0.77059	validation_1-rmse:1.06252
# [45]	validation_0-rmse:0.76168	validation_1-rmse:1.06358
# [46]	validation_0-rmse:0.75517	validation_1-rmse:1.06462
# [47]	validation_0-rmse:0.74952	validation_1-rmse:1.06312
# [48]	validation_0-rmse:0.74226	validation_1-rmse:1.06156
# [49]	validation_0-rmse:0.73632	validation_1-rmse:1.06240
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:1.37690	validation_1-rmse:0.95898
# [1]	validation_0-rmse:1.35296	validation_1-rmse:0.94712
# [2]	validation_0-rmse:1.32946	validation_1-rmse:0.92429
# [3]	validation_0-rmse:1.30812	validation_1-rmse:0.90153
# [4]	validation_0-rmse:1.28268	validation_1-rmse:0.89326
# [5]	validation_0-rmse:1.26122	validation_1-rmse:0.88004
# [6]	validation_0-rmse:1.22996	validation_1-rmse:0.85332
# [7]	validation_0-rmse:1.21018	validation_1-rmse:0.83855
# [8]	validation_0-rmse:1.18906	validation_1-rmse:0.82622
# [9]	validation_0-rmse:1.17380	validation_1-rmse:0.82665
# [10]	validation_0-rmse:1.15806	validation_1-rmse:0.81717
# [11]	validation_0-rmse:1.13801	validation_1-rmse:0.81604
# [12]	validation_0-rmse:1.12084	validation_1-rmse:0.81473
# [13]	validation_0-rmse:1.10588	validation_1-rmse:0.81423
# [14]	validation_0-rmse:1.09220	validation_1-rmse:0.81408
# [15]	validation_0-rmse:1.07972	validation_1-rmse:0.82032
# [16]	validation_0-rmse:1.06230	validation_1-rmse:0.82046
# [17]	validation_0-rmse:1.04646	validation_1-rmse:0.81297
# [18]	validation_0-rmse:1.03181	validation_1-rmse:0.81189
# [19]	validation_0-rmse:1.01501	validation_1-rmse:0.80366
# [20]	validation_0-rmse:0.99967	validation_1-rmse:0.80727
# [21]	validation_0-rmse:0.99006	validation_1-rmse:0.80445
# [22]	validation_0-rmse:0.97376	validation_1-rmse:0.79775
# [23]	validation_0-rmse:0.97030	validation_1-rmse:0.79571
# [24]	validation_0-rmse:0.95737	validation_1-rmse:0.80317
# [25]	validation_0-rmse:0.94660	validation_1-rmse:0.80219
# [26]	validation_0-rmse:0.93630	validation_1-rmse:0.81191
# [27]	validation_0-rmse:0.92956	validation_1-rmse:0.80774
# [28]	validation_0-rmse:0.91668	validation_1-rmse:0.80649
# [29]	validation_0-rmse:0.91120	validation_1-rmse:0.80631
# [30]	validation_0-rmse:0.90117	validation_1-rmse:0.80754
# [31]	validation_0-rmse:0.89014	validation_1-rmse:0.80321
# [32]	validation_0-rmse:0.88671	validation_1-rmse:0.80011
# [33]	validation_0-rmse:0.87447	validation_1-rmse:0.80526
# [34]	validation_0-rmse:0.86705	validation_1-rmse:0.80555
# [35]	validation_0-rmse:0.86340	validation_1-rmse:0.80820
# [36]	validation_0-rmse:0.85535	validation_1-rmse:0.79722
# [37]	validation_0-rmse:0.85157	validation_1-rmse:0.80097
# [38]	validation_0-rmse:0.83915	validation_1-rmse:0.80407
# [39]	validation_0-rmse:0.83329	validation_1-rmse:0.80906
# [40]	validation_0-rmse:0.82490	validation_1-rmse:0.81210
# [41]	validation_0-rmse:0.81514	validation_1-rmse:0.81384
# [42]	validation_0-rmse:0.80654	validation_1-rmse:0.81924
# [0]	validation_0-rmse:1.27567	validation_1-rmse:1.49615
# [1]	validation_0-rmse:1.25018	validation_1-rmse:1.48195
# [2]	validation_0-rmse:1.23003	validation_1-rmse:1.48152
# [3]	validation_0-rmse:1.21227	validation_1-rmse:1.46384
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.19282	validation_1-rmse:1.45618
# [5]	validation_0-rmse:1.18136	validation_1-rmse:1.45448
# [6]	validation_0-rmse:1.15089	validation_1-rmse:1.43791
# [7]	validation_0-rmse:1.13318	validation_1-rmse:1.42353
# [8]	validation_0-rmse:1.12082	validation_1-rmse:1.41285
# [9]	validation_0-rmse:1.10371	validation_1-rmse:1.39287
# [10]	validation_0-rmse:1.09258	validation_1-rmse:1.37525
# [11]	validation_0-rmse:1.07910	validation_1-rmse:1.36276
# [12]	validation_0-rmse:1.07401	validation_1-rmse:1.36182
# [13]	validation_0-rmse:1.06048	validation_1-rmse:1.36052
# [14]	validation_0-rmse:1.05527	validation_1-rmse:1.36022
# [15]	validation_0-rmse:1.04634	validation_1-rmse:1.35745
# [16]	validation_0-rmse:1.02956	validation_1-rmse:1.35252
# [17]	validation_0-rmse:1.01515	validation_1-rmse:1.33644
# [18]	validation_0-rmse:0.99754	validation_1-rmse:1.31755
# [19]	validation_0-rmse:0.98954	validation_1-rmse:1.31253
# [20]	validation_0-rmse:0.98270	validation_1-rmse:1.30739
# [21]	validation_0-rmse:0.97303	validation_1-rmse:1.29993
# [22]	validation_0-rmse:0.96224	validation_1-rmse:1.28886
# [23]	validation_0-rmse:0.95251	validation_1-rmse:1.27496
# [24]	validation_0-rmse:0.94894	validation_1-rmse:1.27725
# [25]	validation_0-rmse:0.93398	validation_1-rmse:1.26856
# [26]	validation_0-rmse:0.93093	validation_1-rmse:1.26468
# [27]	validation_0-rmse:0.92262	validation_1-rmse:1.25875
# [28]	validation_0-rmse:0.90674	validation_1-rmse:1.26585
# [29]	validation_0-rmse:0.89530	validation_1-rmse:1.25772
# [30]	validation_0-rmse:0.89124	validation_1-rmse:1.26118
# [31]	validation_0-rmse:0.87399	validation_1-rmse:1.23451
# [32]	validation_0-rmse:0.86596	validation_1-rmse:1.22528
# [33]	validation_0-rmse:0.85414	validation_1-rmse:1.21364
# [34]	validation_0-rmse:0.84428	validation_1-rmse:1.21107
# [35]	validation_0-rmse:0.83228	validation_1-rmse:1.20329
# [36]	validation_0-rmse:0.81765	validation_1-rmse:1.20314
# [37]	validation_0-rmse:0.80865	validation_1-rmse:1.18730
# [38]	validation_0-rmse:0.79979	validation_1-rmse:1.19074
# [39]	validation_0-rmse:0.78792	validation_1-rmse:1.18603
# [40]	validation_0-rmse:0.78248	validation_1-rmse:1.18415
# [41]	validation_0-rmse:0.77781	validation_1-rmse:1.18037
# [42]	validation_0-rmse:0.76927	validation_1-rmse:1.17220
# [43]	validation_0-rmse:0.76401	validation_1-rmse:1.16790
# [44]	validation_0-rmse:0.75818	validation_1-rmse:1.16329
# [45]	validation_0-rmse:0.75531	validation_1-rmse:1.16383
# [46]	validation_0-rmse:0.74878	validation_1-rmse:1.16352
# [47]	validation_0-rmse:0.74531	validation_1-rmse:1.16546
# [48]	validation_0-rmse:0.73890	validation_1-rmse:1.15980
# [49]	validation_0-rmse:0.73144	validation_1-rmse:1.16458
# [0]	validation_0-rmse:1.30124	validation_1-rmse:1.34604
# [1]	validation_0-rmse:1.27792	validation_1-rmse:1.31462
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-rmse:1.25718	validation_1-rmse:1.29387
# [3]	validation_0-rmse:1.23718	validation_1-rmse:1.28347
# [4]	validation_0-rmse:1.21761	validation_1-rmse:1.26427
# [5]	validation_0-rmse:1.20075	validation_1-rmse:1.25408
# [6]	validation_0-rmse:1.17851	validation_1-rmse:1.24257
# [7]	validation_0-rmse:1.16722	validation_1-rmse:1.21764
# [8]	validation_0-rmse:1.15125	validation_1-rmse:1.20440
# [9]	validation_0-rmse:1.14288	validation_1-rmse:1.18750
# [10]	validation_0-rmse:1.13457	validation_1-rmse:1.16768
# [11]	validation_0-rmse:1.12849	validation_1-rmse:1.16159
# [12]	validation_0-rmse:1.10991	validation_1-rmse:1.13239
# [13]	validation_0-rmse:1.08892	validation_1-rmse:1.11346
# [14]	validation_0-rmse:1.07688	validation_1-rmse:1.10914
# [15]	validation_0-rmse:1.06314	validation_1-rmse:1.09422
# [16]	validation_0-rmse:1.05279	validation_1-rmse:1.08764
# [17]	validation_0-rmse:1.04697	validation_1-rmse:1.08541
# [18]	validation_0-rmse:1.03624	validation_1-rmse:1.06882
# [19]	validation_0-rmse:1.02177	validation_1-rmse:1.06270
# [20]	validation_0-rmse:1.01379	validation_1-rmse:1.06338
# [21]	validation_0-rmse:1.00713	validation_1-rmse:1.05412
# [22]	validation_0-rmse:0.99857	validation_1-rmse:1.05835
# [23]	validation_0-rmse:0.99120	validation_1-rmse:1.05296
# [24]	validation_0-rmse:0.98572	validation_1-rmse:1.05335
# [25]	validation_0-rmse:0.97187	validation_1-rmse:1.04441
# [26]	validation_0-rmse:0.96528	validation_1-rmse:1.04273
# [27]	validation_0-rmse:0.96030	validation_1-rmse:1.04109
# [28]	validation_0-rmse:0.94928	validation_1-rmse:1.02832
# [29]	validation_0-rmse:0.94002	validation_1-rmse:1.02888
# [30]	validation_0-rmse:0.93200	validation_1-rmse:1.02121
# [31]	validation_0-rmse:0.91783	validation_1-rmse:1.01488
# [32]	validation_0-rmse:0.91524	validation_1-rmse:1.01044
# [33]	validation_0-rmse:0.90116	validation_1-rmse:1.00287
# [34]	validation_0-rmse:0.88858	validation_1-rmse:0.98450
# [35]	validation_0-rmse:0.88405	validation_1-rmse:0.98807
# [36]	validation_0-rmse:0.87102	validation_1-rmse:0.97201
# [37]	validation_0-rmse:0.86310	validation_1-rmse:0.95429
# [38]	validation_0-rmse:0.85759	validation_1-rmse:0.94912
# [39]	validation_0-rmse:0.84777	validation_1-rmse:0.93448
# [40]	validation_0-rmse:0.84021	validation_1-rmse:0.92916
# [41]	validation_0-rmse:0.83777	validation_1-rmse:0.92809
# [42]	validation_0-rmse:0.83799	validation_1-rmse:0.93231
# [43]	validation_0-rmse:0.82850	validation_1-rmse:0.91882
# [44]	validation_0-rmse:0.82319	validation_1-rmse:0.91361
# [45]	validation_0-rmse:0.81257	validation_1-rmse:0.91049
# [46]	validation_0-rmse:0.80471	validation_1-rmse:0.89582
# [47]	validation_0-rmse:0.79745	validation_1-rmse:0.89204
# [48]	validation_0-rmse:0.79140	validation_1-rmse:0.88728
# [49]	validation_0-rmse:0.78208	validation_1-rmse:0.88444
# [0]	validation_0-rmse:1.34214	validation_1-rmse:1.15359
# [1]	validation_0-rmse:1.32212	validation_1-rmse:1.13716
# [2]	validation_0-rmse:1.30196	validation_1-rmse:1.11815
# [3]	validation_0-rmse:1.28422	validation_1-rmse:1.10600
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.26291	validation_1-rmse:1.08684
# [5]	validation_0-rmse:1.24554	validation_1-rmse:1.07222
# [6]	validation_0-rmse:1.22099	validation_1-rmse:1.04990
# [7]	validation_0-rmse:1.20846	validation_1-rmse:1.04117
# [8]	validation_0-rmse:1.18774	validation_1-rmse:1.02682
# [9]	validation_0-rmse:1.17238	validation_1-rmse:1.01728
# [10]	validation_0-rmse:1.15922	validation_1-rmse:1.00728
# [11]	validation_0-rmse:1.14368	validation_1-rmse:0.99608
# [12]	validation_0-rmse:1.12718	validation_1-rmse:0.98160
# [13]	validation_0-rmse:1.10823	validation_1-rmse:0.98441
# [14]	validation_0-rmse:1.08637	validation_1-rmse:0.97835
# [15]	validation_0-rmse:1.06772	validation_1-rmse:0.97579
# [16]	validation_0-rmse:1.05078	validation_1-rmse:0.97062
# [17]	validation_0-rmse:1.03282	validation_1-rmse:0.96122
# [18]	validation_0-rmse:1.01982	validation_1-rmse:0.96015
# [19]	validation_0-rmse:1.00486	validation_1-rmse:0.95635
# [20]	validation_0-rmse:0.98878	validation_1-rmse:0.96088
# [21]	validation_0-rmse:0.98387	validation_1-rmse:0.95936
# [22]	validation_0-rmse:0.96640	validation_1-rmse:0.96101
# [23]	validation_0-rmse:0.95833	validation_1-rmse:0.96113
# [24]	validation_0-rmse:0.95064	validation_1-rmse:0.95981
# [25]	validation_0-rmse:0.93857	validation_1-rmse:0.95654
# [26]	validation_0-rmse:0.92627	validation_1-rmse:0.95854
# [27]	validation_0-rmse:0.91989	validation_1-rmse:0.96247
# [28]	validation_0-rmse:0.91206	validation_1-rmse:0.96318
# [29]	validation_0-rmse:0.90503	validation_1-rmse:0.95748
# [30]	validation_0-rmse:0.89746	validation_1-rmse:0.95526
# [31]	validation_0-rmse:0.89171	validation_1-rmse:0.95633
# [32]	validation_0-rmse:0.88480	validation_1-rmse:0.95733
# [33]	validation_0-rmse:0.87197	validation_1-rmse:0.96015
# [34]	validation_0-rmse:0.85820	validation_1-rmse:0.96617
# [35]	validation_0-rmse:0.85693	validation_1-rmse:0.96707
# [36]	validation_0-rmse:0.85385	validation_1-rmse:0.96873
# [37]	validation_0-rmse:0.84605	validation_1-rmse:0.96911
# [38]	validation_0-rmse:0.83182	validation_1-rmse:0.97409
# [39]	validation_0-rmse:0.82215	validation_1-rmse:0.97859
# [40]	validation_0-rmse:0.81257	validation_1-rmse:0.98013
# [41]	validation_0-rmse:0.80702	validation_1-rmse:0.97756
# [42]	validation_0-rmse:0.79933	validation_1-rmse:0.97942
# [43]	validation_0-rmse:0.79264	validation_1-rmse:0.98312
# [44]	validation_0-rmse:0.78567	validation_1-rmse:0.98925
# [45]	validation_0-rmse:0.78156	validation_1-rmse:0.99016
# [46]	validation_0-rmse:0.77264	validation_1-rmse:0.99887
# [47]	validation_0-rmse:0.76829	validation_1-rmse:0.98924
# [48]	validation_0-rmse:0.75903	validation_1-rmse:0.99840
# [49]	validation_0-rmse:0.75306	validation_1-rmse:1.00236
# [0]	validation_0-rmse:1.39317	validation_1-rmse:0.91237
# [1]	validation_0-rmse:1.37543	validation_1-rmse:0.90911
# [2]	validation_0-rmse:1.35078	validation_1-rmse:0.88719
# [3]	validation_0-rmse:1.32235	validation_1-rmse:0.86041
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:1.29438	validation_1-rmse:0.83560
# [5]	validation_0-rmse:1.27835	validation_1-rmse:0.82304
# [6]	validation_0-rmse:1.26566	validation_1-rmse:0.81143
# [7]	validation_0-rmse:1.24127	validation_1-rmse:0.78803
# [8]	validation_0-rmse:1.22141	validation_1-rmse:0.78004
# [9]	validation_0-rmse:1.20227	validation_1-rmse:0.76539
# [10]	validation_0-rmse:1.18981	validation_1-rmse:0.75433
# [11]	validation_0-rmse:1.18433	validation_1-rmse:0.75292
# [12]	validation_0-rmse:1.16202	validation_1-rmse:0.74026
# [13]	validation_0-rmse:1.14070	validation_1-rmse:0.73063
# [14]	validation_0-rmse:1.13496	validation_1-rmse:0.73141
# [15]	validation_0-rmse:1.11802	validation_1-rmse:0.72019
# [16]	validation_0-rmse:1.10098	validation_1-rmse:0.71121
# [17]	validation_0-rmse:1.08493	validation_1-rmse:0.70499
# [18]	validation_0-rmse:1.06615	validation_1-rmse:0.69829
# [19]	validation_0-rmse:1.04992	validation_1-rmse:0.69183
# [20]	validation_0-rmse:1.03724	validation_1-rmse:0.69358
# [21]	validation_0-rmse:1.03187	validation_1-rmse:0.69443
# [22]	validation_0-rmse:1.01983	validation_1-rmse:0.69259
# [23]	validation_0-rmse:1.00790	validation_1-rmse:0.68164
# [24]	validation_0-rmse:0.99758	validation_1-rmse:0.68393
# [25]	validation_0-rmse:0.98585	validation_1-rmse:0.68900
# [26]	validation_0-rmse:0.97559	validation_1-rmse:0.68892
# [27]	validation_0-rmse:0.96808	validation_1-rmse:0.69789
# [28]	validation_0-rmse:0.95415	validation_1-rmse:0.69013
# [29]	validation_0-rmse:0.94434	validation_1-rmse:0.68814
# [30]	validation_0-rmse:0.93170	validation_1-rmse:0.69369
# [31]	validation_0-rmse:0.92423	validation_1-rmse:0.69697
# [32]	validation_0-rmse:0.90914	validation_1-rmse:0.69811
# [33]	validation_0-rmse:0.90203	validation_1-rmse:0.70456
# [34]	validation_0-rmse:0.88585	validation_1-rmse:0.71073
# [35]	validation_0-rmse:0.87968	validation_1-rmse:0.71375
# [36]	validation_0-rmse:0.87385	validation_1-rmse:0.71677
# [37]	validation_0-rmse:0.86556	validation_1-rmse:0.71921
# [38]	validation_0-rmse:0.86098	validation_1-rmse:0.72277
# [39]	validation_0-rmse:0.85340	validation_1-rmse:0.72225
# [40]	validation_0-rmse:0.84936	validation_1-rmse:0.73405
# [41]	validation_0-rmse:0.84257	validation_1-rmse:0.74180
# [42]	validation_0-rmse:0.83349	validation_1-rmse:0.74847
# [0]	validation_0-rmse:1.26454	validation_1-rmse:1.46273
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [1]	validation_0-rmse:1.24360	validation_1-rmse:1.45244
# [2]	validation_0-rmse:1.22361	validation_1-rmse:1.43472
# [3]	validation_0-rmse:1.20338	validation_1-rmse:1.42264
# [4]	validation_0-rmse:1.18765	validation_1-rmse:1.41603
# [5]	validation_0-rmse:1.17199	validation_1-rmse:1.40895
# [6]	validation_0-rmse:1.15847	validation_1-rmse:1.40429
# [7]	validation_0-rmse:1.14211	validation_1-rmse:1.39868
# [8]	validation_0-rmse:1.11431	validation_1-rmse:1.38117
# [9]	validation_0-rmse:1.10158	validation_1-rmse:1.36820
# [10]	validation_0-rmse:1.08874	validation_1-rmse:1.36478
# [11]	validation_0-rmse:1.07540	validation_1-rmse:1.36050
# [12]	validation_0-rmse:1.05853	validation_1-rmse:1.34720
# [13]	validation_0-rmse:1.04279	validation_1-rmse:1.34342
# [14]	validation_0-rmse:1.02839	validation_1-rmse:1.34158
# [15]	validation_0-rmse:1.00753	validation_1-rmse:1.32573
# [16]	validation_0-rmse:0.98896	validation_1-rmse:1.31172
# [17]	validation_0-rmse:0.97411	validation_1-rmse:1.30468
# [18]	validation_0-rmse:0.97208	validation_1-rmse:1.30010
# [19]	validation_0-rmse:0.96518	validation_1-rmse:1.29970
# [20]	validation_0-rmse:0.95097	validation_1-rmse:1.28866
# [21]	validation_0-rmse:0.94673	validation_1-rmse:1.28424
# [22]	validation_0-rmse:0.93683	validation_1-rmse:1.27731
# [23]	validation_0-rmse:0.92054	validation_1-rmse:1.27416
# [24]	validation_0-rmse:0.90520	validation_1-rmse:1.25701
# [25]	validation_0-rmse:0.89215	validation_1-rmse:1.25169
# [26]	validation_0-rmse:0.88885	validation_1-rmse:1.25433
# [27]	validation_0-rmse:0.87885	validation_1-rmse:1.26680
# [28]	validation_0-rmse:0.86536	validation_1-rmse:1.27089
# [29]	validation_0-rmse:0.85695	validation_1-rmse:1.25961
# [30]	validation_0-rmse:0.85152	validation_1-rmse:1.25919
# [31]	validation_0-rmse:0.84198	validation_1-rmse:1.25127
# [32]	validation_0-rmse:0.83404	validation_1-rmse:1.24128
# [33]	validation_0-rmse:0.82705	validation_1-rmse:1.23246
# [34]	validation_0-rmse:0.81833	validation_1-rmse:1.23856
# [35]	validation_0-rmse:0.81555	validation_1-rmse:1.24014
# [36]	validation_0-rmse:0.80465	validation_1-rmse:1.23664
# [37]	validation_0-rmse:0.79976	validation_1-rmse:1.23685
# [38]	validation_0-rmse:0.78944	validation_1-rmse:1.23835
# [39]	validation_0-rmse:0.78054	validation_1-rmse:1.23482
# [40]	validation_0-rmse:0.77417	validation_1-rmse:1.23639
# [41]	validation_0-rmse:0.76478	validation_1-rmse:1.23250
# [42]	validation_0-rmse:0.75976	validation_1-rmse:1.22775
# [43]	validation_0-rmse:0.75723	validation_1-rmse:1.22777
# [44]	validation_0-rmse:0.74703	validation_1-rmse:1.23407
# [45]	validation_0-rmse:0.74168	validation_1-rmse:1.23410
# [46]	validation_0-rmse:0.74063	validation_1-rmse:1.23861
# [47]	validation_0-rmse:0.73531	validation_1-rmse:1.23370
# [48]	validation_0-rmse:0.72672	validation_1-rmse:1.22892
# [49]	validation_0-rmse:0.72250	validation_1-rmse:1.22353
# [0]	validation_0-rmse:1.27365	validation_1-rmse:1.44801
# [1]	validation_0-rmse:1.26299	validation_1-rmse:1.44884
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-rmse:1.24662	validation_1-rmse:1.41079
# [3]	validation_0-rmse:1.22528	validation_1-rmse:1.38554
# [4]	validation_0-rmse:1.20535	validation_1-rmse:1.37568
# [5]	validation_0-rmse:1.18365	validation_1-rmse:1.36227
# [6]	validation_0-rmse:1.16238	validation_1-rmse:1.34144
# [7]	validation_0-rmse:1.14178	validation_1-rmse:1.31933
# [8]	validation_0-rmse:1.12357	validation_1-rmse:1.30951
# [9]	validation_0-rmse:1.11497	validation_1-rmse:1.30794
# [10]	validation_0-rmse:1.10383	validation_1-rmse:1.29708
# [11]	validation_0-rmse:1.09478	validation_1-rmse:1.28919
# [12]	validation_0-rmse:1.07193	validation_1-rmse:1.27385
# [13]	validation_0-rmse:1.05285	validation_1-rmse:1.26160
# [14]	validation_0-rmse:1.03958	validation_1-rmse:1.25731
# [15]	validation_0-rmse:1.02324	validation_1-rmse:1.24645
# [16]	validation_0-rmse:1.01152	validation_1-rmse:1.23469
# [17]	validation_0-rmse:1.00138	validation_1-rmse:1.22535
# [18]	validation_0-rmse:0.99244	validation_1-rmse:1.22355
# [19]	validation_0-rmse:0.98693	validation_1-rmse:1.22114
# [20]	validation_0-rmse:0.97510	validation_1-rmse:1.21954
# [21]	validation_0-rmse:0.96358	validation_1-rmse:1.21716
# [22]	validation_0-rmse:0.95637	validation_1-rmse:1.20217
# [23]	validation_0-rmse:0.94285	validation_1-rmse:1.19427
# [24]	validation_0-rmse:0.92864	validation_1-rmse:1.18370
# [25]	validation_0-rmse:0.91310	validation_1-rmse:1.17201
# [26]	validation_0-rmse:0.90233	validation_1-rmse:1.16671
# [27]	validation_0-rmse:0.89436	validation_1-rmse:1.16296
# [28]	validation_0-rmse:0.88363	validation_1-rmse:1.15914
# [29]	validation_0-rmse:0.87884	validation_1-rmse:1.14995
# [30]	validation_0-rmse:0.86969	validation_1-rmse:1.14213
# [31]	validation_0-rmse:0.85749	validation_1-rmse:1.12993
# [32]	validation_0-rmse:0.85123	validation_1-rmse:1.13235
# [33]	validation_0-rmse:0.84403	validation_1-rmse:1.12636
# [34]	validation_0-rmse:0.83143	validation_1-rmse:1.11608
# [35]	validation_0-rmse:0.82456	validation_1-rmse:1.10783
# [36]	validation_0-rmse:0.82189	validation_1-rmse:1.10546
# [37]	validation_0-rmse:0.81980	validation_1-rmse:1.10509
# [38]	validation_0-rmse:0.81303	validation_1-rmse:1.10086
# [39]	validation_0-rmse:0.80498	validation_1-rmse:1.10185
# [40]	validation_0-rmse:0.79859	validation_1-rmse:1.09819
# [41]	validation_0-rmse:0.79600	validation_1-rmse:1.09905
# [42]	validation_0-rmse:0.78921	validation_1-rmse:1.09130
# [43]	validation_0-rmse:0.78473	validation_1-rmse:1.08974
# [44]	validation_0-rmse:0.77874	validation_1-rmse:1.08595
# [45]	validation_0-rmse:0.76619	validation_1-rmse:1.07829
# [46]	validation_0-rmse:0.75940	validation_1-rmse:1.08282
# [47]	validation_0-rmse:0.75626	validation_1-rmse:1.07793
# [48]	validation_0-rmse:0.75012	validation_1-rmse:1.07845
# [49]	validation_0-rmse:0.74391	validation_1-rmse:1.07177
# [0]	validation_0-rmse:1.26394	validation_1-rmse:1.47652
# [1]	validation_0-rmse:1.23595	validation_1-rmse:1.45883
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-rmse:1.21529	validation_1-rmse:1.44004
# [3]	validation_0-rmse:1.20506	validation_1-rmse:1.42963
# [4]	validation_0-rmse:1.18325	validation_1-rmse:1.40937
# [5]	validation_0-rmse:1.15940	validation_1-rmse:1.38281
# [6]	validation_0-rmse:1.14514	validation_1-rmse:1.37114
# [7]	validation_0-rmse:1.12045	validation_1-rmse:1.35304
# [8]	validation_0-rmse:1.10568	validation_1-rmse:1.34092
# [9]	validation_0-rmse:1.08014	validation_1-rmse:1.32675
# [10]	validation_0-rmse:1.06500	validation_1-rmse:1.31536
# [11]	validation_0-rmse:1.06025	validation_1-rmse:1.31212
# [12]	validation_0-rmse:1.04341	validation_1-rmse:1.30559
# [13]	validation_0-rmse:1.02850	validation_1-rmse:1.29029
# [14]	validation_0-rmse:1.01732	validation_1-rmse:1.29341
# [15]	validation_0-rmse:1.00535	validation_1-rmse:1.29761
# [16]	validation_0-rmse:0.99350	validation_1-rmse:1.28445
# [17]	validation_0-rmse:0.97632	validation_1-rmse:1.27109
# [18]	validation_0-rmse:0.96805	validation_1-rmse:1.26670
# [19]	validation_0-rmse:0.95727	validation_1-rmse:1.25324
# [20]	validation_0-rmse:0.94610	validation_1-rmse:1.24101
# [21]	validation_0-rmse:0.94195	validation_1-rmse:1.23775
# [22]	validation_0-rmse:0.92519	validation_1-rmse:1.22863
# [23]	validation_0-rmse:0.91528	validation_1-rmse:1.22019
# [24]	validation_0-rmse:0.90404	validation_1-rmse:1.21520
# [25]	validation_0-rmse:0.89849	validation_1-rmse:1.21475
# [26]	validation_0-rmse:0.89101	validation_1-rmse:1.20925
# [27]	validation_0-rmse:0.88756	validation_1-rmse:1.20975
# [28]	validation_0-rmse:0.88164	validation_1-rmse:1.20313
# [29]	validation_0-rmse:0.87101	validation_1-rmse:1.19903
# [30]	validation_0-rmse:0.86439	validation_1-rmse:1.19595
# [31]	validation_0-rmse:0.85845	validation_1-rmse:1.19522
# [32]	validation_0-rmse:0.84687	validation_1-rmse:1.19069
# [33]	validation_0-rmse:0.83044	validation_1-rmse:1.17951
# [34]	validation_0-rmse:0.82530	validation_1-rmse:1.17944
# [35]	validation_0-rmse:0.81536	validation_1-rmse:1.15772
# [36]	validation_0-rmse:0.81064	validation_1-rmse:1.15560
# [37]	validation_0-rmse:0.80190	validation_1-rmse:1.14642
# [38]	validation_0-rmse:0.79244	validation_1-rmse:1.14576
# [39]	validation_0-rmse:0.78365	validation_1-rmse:1.14302
# [40]	validation_0-rmse:0.77481	validation_1-rmse:1.13666
# [41]	validation_0-rmse:0.77065	validation_1-rmse:1.13369
# [42]	validation_0-rmse:0.76389	validation_1-rmse:1.12778
# [43]	validation_0-rmse:0.76321	validation_1-rmse:1.12734
# [44]	validation_0-rmse:0.75818	validation_1-rmse:1.12463
# [45]	validation_0-rmse:0.75211	validation_1-rmse:1.12348
# [46]	validation_0-rmse:0.74511	validation_1-rmse:1.12134
# [47]	validation_0-rmse:0.73497	validation_1-rmse:1.12233
# [48]	validation_0-rmse:0.72816	validation_1-rmse:1.12052
# [49]	validation_0-rmse:0.72442	validation_1-rmse:1.11652
# [0]	validation_0-rmse:1.39935	validation_1-rmse:0.88355
# [1]	validation_0-rmse:1.37787	validation_1-rmse:0.87209
# [2]	validation_0-rmse:1.35184	validation_1-rmse:0.86431
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [3]	validation_0-rmse:1.33280	validation_1-rmse:0.85870
# [4]	validation_0-rmse:1.31326	validation_1-rmse:0.85442
# [5]	validation_0-rmse:1.29461	validation_1-rmse:0.84392
# [6]	validation_0-rmse:1.27734	validation_1-rmse:0.82585
# [7]	validation_0-rmse:1.25859	validation_1-rmse:0.81515
# [8]	validation_0-rmse:1.23231	validation_1-rmse:0.80560
# [9]	validation_0-rmse:1.21190	validation_1-rmse:0.79358
# [10]	validation_0-rmse:1.19930	validation_1-rmse:0.78386
# [11]	validation_0-rmse:1.18215	validation_1-rmse:0.77643
# [12]	validation_0-rmse:1.16394	validation_1-rmse:0.76472
# [13]	validation_0-rmse:1.14892	validation_1-rmse:0.76958
# [14]	validation_0-rmse:1.12479	validation_1-rmse:0.75378
# [15]	validation_0-rmse:1.10559	validation_1-rmse:0.74544
# [16]	validation_0-rmse:1.09460	validation_1-rmse:0.74305
# [17]	validation_0-rmse:1.07402	validation_1-rmse:0.73315
# [18]	validation_0-rmse:1.06426	validation_1-rmse:0.73309
# [19]	validation_0-rmse:1.04772	validation_1-rmse:0.72436
# [20]	validation_0-rmse:1.03477	validation_1-rmse:0.72088
# [21]	validation_0-rmse:1.02903	validation_1-rmse:0.70638
# [22]	validation_0-rmse:1.01160	validation_1-rmse:0.69596
# [23]	validation_0-rmse:0.99701	validation_1-rmse:0.68775
# [24]	validation_0-rmse:0.98563	validation_1-rmse:0.69313
# [25]	validation_0-rmse:0.97619	validation_1-rmse:0.70173
# [26]	validation_0-rmse:0.96978	validation_1-rmse:0.69782
# [27]	validation_0-rmse:0.96233	validation_1-rmse:0.69671
# [28]	validation_0-rmse:0.95120	validation_1-rmse:0.70058
# [29]	validation_0-rmse:0.93684	validation_1-rmse:0.70063
# [30]	validation_0-rmse:0.92235	validation_1-rmse:0.69535
# [31]	validation_0-rmse:0.90565	validation_1-rmse:0.69558
# [32]	validation_0-rmse:0.90223	validation_1-rmse:0.69380
# [33]	validation_0-rmse:0.88978	validation_1-rmse:0.69299
# [34]	validation_0-rmse:0.88287	validation_1-rmse:0.69278
# [35]	validation_0-rmse:0.87367	validation_1-rmse:0.68595
# [36]	validation_0-rmse:0.87014	validation_1-rmse:0.69291
# [37]	validation_0-rmse:0.85988	validation_1-rmse:0.69269
# [38]	validation_0-rmse:0.84622	validation_1-rmse:0.69478
# [39]	validation_0-rmse:0.83976	validation_1-rmse:0.70279
# [40]	validation_0-rmse:0.83489	validation_1-rmse:0.70462
# [41]	validation_0-rmse:0.82823	validation_1-rmse:0.70303
# [42]	validation_0-rmse:0.81868	validation_1-rmse:0.70128
# [43]	validation_0-rmse:0.80991	validation_1-rmse:0.70151
# [44]	validation_0-rmse:0.80303	validation_1-rmse:0.70411
# [45]	validation_0-rmse:0.79351	validation_1-rmse:0.70556
# [46]	validation_0-rmse:0.78606	validation_1-rmse:0.71074
# [47]	validation_0-rmse:0.78302	validation_1-rmse:0.71613
# [48]	validation_0-rmse:0.77689	validation_1-rmse:0.71686
# [49]	validation_0-rmse:0.77526	validation_1-rmse:0.71933
# [0]	validation_0-rmse:1.37551	validation_1-rmse:1.01002
# [1]	validation_0-rmse:1.34511	validation_1-rmse:1.00063
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-rmse:1.32216	validation_1-rmse:0.98820
# [3]	validation_0-rmse:1.29660	validation_1-rmse:0.98713
# [4]	validation_0-rmse:1.26768	validation_1-rmse:0.97325
# ...
# [11]	validation_0-rmse:1.14201	validation_1-rmse:1.13202
# [12]	validation_0-rmse:1.12553	validation_1-rmse:1.11711
# [13]	validation_0-rmse:1.11111	validation_1-rmse:1.10624
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [14]	validation_0-rmse:1.09086	validation_1-rmse:1.09057
# [15]	validation_0-rmse:1.07880	validation_1-rmse:1.07543
# [16]	validation_0-rmse:1.06743	validation_1-rmse:1.07263
# [17]	validation_0-rmse:1.04995	validation_1-rmse:1.07251
# [18]	validation_0-rmse:1.03756	validation_1-rmse:1.07119
# [19]	validation_0-rmse:1.02671	validation_1-rmse:1.06513
# [20]	validation_0-rmse:1.01924	validation_1-rmse:1.06205
# [21]	validation_0-rmse:1.00298	validation_1-rmse:1.05097
# [22]	validation_0-rmse:0.98883	validation_1-rmse:1.03716
# [23]	validation_0-rmse:0.97659	validation_1-rmse:1.04359
# [24]	validation_0-rmse:0.96521	validation_1-rmse:1.03445
# [25]	validation_0-rmse:0.95248	validation_1-rmse:1.02781
# [26]	validation_0-rmse:0.94826	validation_1-rmse:1.02728
# [27]	validation_0-rmse:0.93986	validation_1-rmse:1.01736
# [28]	validation_0-rmse:0.93009	validation_1-rmse:0.99904
# [29]	validation_0-rmse:0.92241	validation_1-rmse:0.99152
# [30]	validation_0-rmse:0.90991	validation_1-rmse:0.98060
# [31]	validation_0-rmse:0.90084	validation_1-rmse:0.97862
# [32]	validation_0-rmse:0.89653	validation_1-rmse:0.98079
# [33]	validation_0-rmse:0.88146	validation_1-rmse:0.97123
# [34]	validation_0-rmse:0.87336	validation_1-rmse:0.97189
# [35]	validation_0-rmse:0.86759	validation_1-rmse:0.97732
# [36]	validation_0-rmse:0.86055	validation_1-rmse:0.97211
# [37]	validation_0-rmse:0.85313	validation_1-rmse:0.96713
# [38]	validation_0-rmse:0.85073	validation_1-rmse:0.96213
# [39]	validation_0-rmse:0.84514	validation_1-rmse:0.95719
# [40]	validation_0-rmse:0.83791	validation_1-rmse:0.94483
# [41]	validation_0-rmse:0.83059	validation_1-rmse:0.95478
# [42]	validation_0-rmse:0.82355	validation_1-rmse:0.95833
# [43]	validation_0-rmse:0.81424	validation_1-rmse:0.95639
# [44]	validation_0-rmse:0.80653	validation_1-rmse:0.95106
# [45]	validation_0-rmse:0.79890	validation_1-rmse:0.94117
# [46]	validation_0-rmse:0.79444	validation_1-rmse:0.94292
# [47]	validation_0-rmse:0.78621	validation_1-rmse:0.94006
# [48]	validation_0-rmse:0.77556	validation_1-rmse:0.94106
# [49]	validation_0-rmse:0.77427	validation_1-rmse:0.94011
# [0]	validation_0-rmse:1.20119	validation_1-rmse:1.68366
# [1]	validation_0-rmse:1.17929	validation_1-rmse:1.66585
# [2]	validation_0-rmse:1.16448	validation_1-rmse:1.65568
# [3]	validation_0-rmse:1.14411	validation_1-rmse:1.63200
# [4]	validation_0-rmse:1.13188	validation_1-rmse:1.62772
# [5]	validation_0-rmse:1.11700	validation_1-rmse:1.60417
# [6]	validation_0-rmse:1.10207	validation_1-rmse:1.58236
# [7]	validation_0-rmse:1.08653	validation_1-rmse:1.55303
# [8]	validation_0-rmse:1.07283	validation_1-rmse:1.53947
# [9]	validation_0-rmse:1.05860	validation_1-rmse:1.52751
# [10]	validation_0-rmse:1.04615	validation_1-rmse:1.52573
# [11]	validation_0-rmse:1.03962	validation_1-rmse:1.51117
# [12]	validation_0-rmse:1.02526	validation_1-rmse:1.49740
# [13]	validation_0-rmse:1.00552	validation_1-rmse:1.47222
# [14]	validation_0-rmse:0.99233	validation_1-rmse:1.45023
# [15]	validation_0-rmse:0.98145	validation_1-rmse:1.45021
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [16]	validation_0-rmse:0.97327	validation_1-rmse:1.44650
# [17]	validation_0-rmse:0.95820	validation_1-rmse:1.43374
# [18]	validation_0-rmse:0.94568	validation_1-rmse:1.40897
# [19]	validation_0-rmse:0.93848	validation_1-rmse:1.39642
# [20]	validation_0-rmse:0.93058	validation_1-rmse:1.38210
# [21]	validation_0-rmse:0.92723	validation_1-rmse:1.38118
# [22]	validation_0-rmse:0.91796	validation_1-rmse:1.37639
# [23]	validation_0-rmse:0.91081	validation_1-rmse:1.36506
# [24]	validation_0-rmse:0.89580	validation_1-rmse:1.34896
# [25]	validation_0-rmse:0.88917	validation_1-rmse:1.33763
# [26]	validation_0-rmse:0.88349	validation_1-rmse:1.32454
# [27]	validation_0-rmse:0.87969	validation_1-rmse:1.32705
# [28]	validation_0-rmse:0.87367	validation_1-rmse:1.31731
# [29]	validation_0-rmse:0.86644	validation_1-rmse:1.30499
# [30]	validation_0-rmse:0.85670	validation_1-rmse:1.28941
# [31]	validation_0-rmse:0.85153	validation_1-rmse:1.28677
# [32]	validation_0-rmse:0.84475	validation_1-rmse:1.27224
# [33]	validation_0-rmse:0.83903	validation_1-rmse:1.27031
# [34]	validation_0-rmse:0.82552	validation_1-rmse:1.26878
# [35]	validation_0-rmse:0.82525	validation_1-rmse:1.27087
# [36]	validation_0-rmse:0.81969	validation_1-rmse:1.26134
# [37]	validation_0-rmse:0.81872	validation_1-rmse:1.26349
# [38]	validation_0-rmse:0.81193	validation_1-rmse:1.25182
# [39]	validation_0-rmse:0.80381	validation_1-rmse:1.24277
# [40]	validation_0-rmse:0.79959	validation_1-rmse:1.23523
# [41]	validation_0-rmse:0.79428	validation_1-rmse:1.22315
# [42]	validation_0-rmse:0.78809	validation_1-rmse:1.21679
# [43]	validation_0-rmse:0.77863	validation_1-rmse:1.19817
# [44]	validation_0-rmse:0.77202	validation_1-rmse:1.20272
# [45]	validation_0-rmse:0.76778	validation_1-rmse:1.20313
# [46]	validation_0-rmse:0.76031	validation_1-rmse:1.18664
# [47]	validation_0-rmse:0.75378	validation_1-rmse:1.17818
# [48]	validation_0-rmse:0.74488	validation_1-rmse:1.17921
# [49]	validation_0-rmse:0.74017	validation_1-rmse:1.17348
# [0]	validation_0-rmse:1.37117	validation_1-rmse:1.04809
# [1]	validation_0-rmse:1.33986	validation_1-rmse:1.02439
# [2]	validation_0-rmse:1.31524	validation_1-rmse:1.01335
# [3]	validation_0-rmse:1.30137	validation_1-rmse:0.99667
# [4]	validation_0-rmse:1.28069	validation_1-rmse:0.98645
# [5]	validation_0-rmse:1.26244	validation_1-rmse:0.97835
# [6]	validation_0-rmse:1.25373	validation_1-rmse:0.97188
# [7]	validation_0-rmse:1.23109	validation_1-rmse:0.97018
# [8]	validation_0-rmse:1.21551	validation_1-rmse:0.96387
# [9]	validation_0-rmse:1.20062	validation_1-rmse:0.95637
# [10]	validation_0-rmse:1.19040	validation_1-rmse:0.95390
# [11]	validation_0-rmse:1.17890	validation_1-rmse:0.94572
# [12]	validation_0-rmse:1.16294	validation_1-rmse:0.94421
# [13]	validation_0-rmse:1.13919	validation_1-rmse:0.94603
# [14]	validation_0-rmse:1.13639	validation_1-rmse:0.94498
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:1.11973	validation_1-rmse:0.92095
# [16]	validation_0-rmse:1.09871	validation_1-rmse:0.91153
# [17]	validation_0-rmse:1.07710	validation_1-rmse:0.90537
# [18]	validation_0-rmse:1.06539	validation_1-rmse:0.90388
# [19]	validation_0-rmse:1.04833	validation_1-rmse:0.89811
# [20]	validation_0-rmse:1.03088	validation_1-rmse:0.89428
# [21]	validation_0-rmse:1.01313	validation_1-rmse:0.89290
# [22]	validation_0-rmse:0.99731	validation_1-rmse:0.88825
# [23]	validation_0-rmse:0.98114	validation_1-rmse:0.87973
# [24]	validation_0-rmse:0.96872	validation_1-rmse:0.87876
# [25]	validation_0-rmse:0.95785	validation_1-rmse:0.88206
# [26]	validation_0-rmse:0.94809	validation_1-rmse:0.88443
# [27]	validation_0-rmse:0.93618	validation_1-rmse:0.88541
# [28]	validation_0-rmse:0.92886	validation_1-rmse:0.88427
# [29]	validation_0-rmse:0.91592	validation_1-rmse:0.88339
# [30]	validation_0-rmse:0.90447	validation_1-rmse:0.88349
# [31]	validation_0-rmse:0.89565	validation_1-rmse:0.88268
# [32]	validation_0-rmse:0.88736	validation_1-rmse:0.88492
# [33]	validation_0-rmse:0.87858	validation_1-rmse:0.88642
# [34]	validation_0-rmse:0.86341	validation_1-rmse:0.87969
# [35]	validation_0-rmse:0.86071	validation_1-rmse:0.88460
# [36]	validation_0-rmse:0.85002	validation_1-rmse:0.88770
# [37]	validation_0-rmse:0.84182	validation_1-rmse:0.87933
# [38]	validation_0-rmse:0.83217	validation_1-rmse:0.87912
# [39]	validation_0-rmse:0.82486	validation_1-rmse:0.87555
# [40]	validation_0-rmse:0.82096	validation_1-rmse:0.87248
# [41]	validation_0-rmse:0.81458	validation_1-rmse:0.86999
# [42]	validation_0-rmse:0.80460	validation_1-rmse:0.86910
# [43]	validation_0-rmse:0.79601	validation_1-rmse:0.86412
# [44]	validation_0-rmse:0.79073	validation_1-rmse:0.86353
# [45]	validation_0-rmse:0.78616	validation_1-rmse:0.86626
# [46]	validation_0-rmse:0.78059	validation_1-rmse:0.86115
# [47]	validation_0-rmse:0.77382	validation_1-rmse:0.86538
# [48]	validation_0-rmse:0.76362	validation_1-rmse:0.87085
# [49]	validation_0-rmse:0.75656	validation_1-rmse:0.86787
# [0]	validation_0-rmse:1.33352	validation_1-rmse:1.28130
# [1]	validation_0-rmse:1.31797	validation_1-rmse:1.25710
# [2]	validation_0-rmse:1.29528	validation_1-rmse:1.23474
# [3]	validation_0-rmse:1.27979	validation_1-rmse:1.21497
# [4]	validation_0-rmse:1.26096	validation_1-rmse:1.19742
# [5]	validation_0-rmse:1.24860	validation_1-rmse:1.18294
# [6]	validation_0-rmse:1.23435	validation_1-rmse:1.17902
# [7]	validation_0-rmse:1.22120	validation_1-rmse:1.16337
# [8]	validation_0-rmse:1.19710	validation_1-rmse:1.13808
# [9]	validation_0-rmse:1.18433	validation_1-rmse:1.12740
# [10]	validation_0-rmse:1.16080	validation_1-rmse:1.10801
# [11]	validation_0-rmse:1.15125	validation_1-rmse:1.09325
# [12]	validation_0-rmse:1.14392	validation_1-rmse:1.09392
# [13]	validation_0-rmse:1.13140	validation_1-rmse:1.08869
# [14]	validation_0-rmse:1.12674	validation_1-rmse:1.08809
# [15]	validation_0-rmse:1.10652	validation_1-rmse:1.06599
# [16]	validation_0-rmse:1.09182	validation_1-rmse:1.04817
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [17]	validation_0-rmse:1.07571	validation_1-rmse:1.02884
# [18]	validation_0-rmse:1.06673	validation_1-rmse:1.01695
# [19]	validation_0-rmse:1.06238	validation_1-rmse:1.00942
# [20]	validation_0-rmse:1.05129	validation_1-rmse:0.99341
# [21]	validation_0-rmse:1.04019	validation_1-rmse:0.99502
# [22]	validation_0-rmse:1.02759	validation_1-rmse:0.99194
# [23]	validation_0-rmse:1.01372	validation_1-rmse:0.97780
# [24]	validation_0-rmse:0.99951	validation_1-rmse:0.97753
# [25]	validation_0-rmse:0.99807	validation_1-rmse:0.97826
# [26]	validation_0-rmse:0.98617	validation_1-rmse:0.97870
# [27]	validation_0-rmse:0.97743	validation_1-rmse:0.96875
# [28]	validation_0-rmse:0.95730	validation_1-rmse:0.94866
# [29]	validation_0-rmse:0.95120	validation_1-rmse:0.94368
# [30]	validation_0-rmse:0.94859	validation_1-rmse:0.94259
# [31]	validation_0-rmse:0.94408	validation_1-rmse:0.93666
# [32]	validation_0-rmse:0.93139	validation_1-rmse:0.93373
# [33]	validation_0-rmse:0.91539	validation_1-rmse:0.93138
# [34]	validation_0-rmse:0.90498	validation_1-rmse:0.92497
# [35]	validation_0-rmse:0.90141	validation_1-rmse:0.92411
# [36]	validation_0-rmse:0.89355	validation_1-rmse:0.92046
# [37]	validation_0-rmse:0.87798	validation_1-rmse:0.90410
# [38]	validation_0-rmse:0.86901	validation_1-rmse:0.89955
# [39]	validation_0-rmse:0.85740	validation_1-rmse:0.89899
# [40]	validation_0-rmse:0.84662	validation_1-rmse:0.89626
# [41]	validation_0-rmse:0.84354	validation_1-rmse:0.89738
# [42]	validation_0-rmse:0.83602	validation_1-rmse:0.89533
# [43]	validation_0-rmse:0.83421	validation_1-rmse:0.89347
# [44]	validation_0-rmse:0.82624	validation_1-rmse:0.88813
# [45]	validation_0-rmse:0.82280	validation_1-rmse:0.89074
# [46]	validation_0-rmse:0.81279	validation_1-rmse:0.88307
# [47]	validation_0-rmse:0.80840	validation_1-rmse:0.88149
# [48]	validation_0-rmse:0.79581	validation_1-rmse:0.87103
# [49]	validation_0-rmse:0.78939	validation_1-rmse:0.86961
# [0]	validation_0-rmse:1.19250	validation_1-rmse:1.66725
# [1]	validation_0-rmse:1.17077	validation_1-rmse:1.63956
# [2]	validation_0-rmse:1.15108	validation_1-rmse:1.62126
# [3]	validation_0-rmse:1.13027	validation_1-rmse:1.59565
# [4]	validation_0-rmse:1.11473	validation_1-rmse:1.57623
# [5]	validation_0-rmse:1.09678	validation_1-rmse:1.55089
# [6]	validation_0-rmse:1.08902	validation_1-rmse:1.54996
# [7]	validation_0-rmse:1.07826	validation_1-rmse:1.53937
# [8]	validation_0-rmse:1.06258	validation_1-rmse:1.51736
# [9]	validation_0-rmse:1.05120	validation_1-rmse:1.50583
# [10]	validation_0-rmse:1.03493	validation_1-rmse:1.49281
# [11]	validation_0-rmse:1.02901	validation_1-rmse:1.48347
# [12]	validation_0-rmse:1.01760	validation_1-rmse:1.48017
# [13]	validation_0-rmse:1.00284	validation_1-rmse:1.47047
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [14]	validation_0-rmse:0.99711	validation_1-rmse:1.47249
# [15]	validation_0-rmse:0.97874	validation_1-rmse:1.45414
# [16]	validation_0-rmse:0.96617	validation_1-rmse:1.43508
# [17]	validation_0-rmse:0.94421	validation_1-rmse:1.42507
# [18]	validation_0-rmse:0.93613	validation_1-rmse:1.41199
# [19]	validation_0-rmse:0.92337	validation_1-rmse:1.39397
# [20]	validation_0-rmse:0.90943	validation_1-rmse:1.38337
# [21]	validation_0-rmse:0.89550	validation_1-rmse:1.36610
# [22]	validation_0-rmse:0.88178	validation_1-rmse:1.35034
# [23]	validation_0-rmse:0.86790	validation_1-rmse:1.33632
# [24]	validation_0-rmse:0.85888	validation_1-rmse:1.32899
# [25]	validation_0-rmse:0.84602	validation_1-rmse:1.31146
# [26]	validation_0-rmse:0.84212	validation_1-rmse:1.31609
# [27]	validation_0-rmse:0.83511	validation_1-rmse:1.30722
# [28]	validation_0-rmse:0.83165	validation_1-rmse:1.31436
# [29]	validation_0-rmse:0.82969	validation_1-rmse:1.31672
# [30]	validation_0-rmse:0.82120	validation_1-rmse:1.30554
# [31]	validation_0-rmse:0.81162	validation_1-rmse:1.29550
# [32]	validation_0-rmse:0.80555	validation_1-rmse:1.28756
# [33]	validation_0-rmse:0.79628	validation_1-rmse:1.28053
# [34]	validation_0-rmse:0.79031	validation_1-rmse:1.26962
# [35]	validation_0-rmse:0.78606	validation_1-rmse:1.25671
# [36]	validation_0-rmse:0.78056	validation_1-rmse:1.25876
# [37]	validation_0-rmse:0.77538	validation_1-rmse:1.24620
# [38]	validation_0-rmse:0.76699	validation_1-rmse:1.24379
# [39]	validation_0-rmse:0.76209	validation_1-rmse:1.24288
# [40]	validation_0-rmse:0.76047	validation_1-rmse:1.24519
# [41]	validation_0-rmse:0.75484	validation_1-rmse:1.24788
# [42]	validation_0-rmse:0.74754	validation_1-rmse:1.23351
# [43]	validation_0-rmse:0.74247	validation_1-rmse:1.23227
# [44]	validation_0-rmse:0.73935	validation_1-rmse:1.23833
# [45]	validation_0-rmse:0.73591	validation_1-rmse:1.24386
# [46]	validation_0-rmse:0.72753	validation_1-rmse:1.24162
# [47]	validation_0-rmse:0.72434	validation_1-rmse:1.25099
# [48]	validation_0-rmse:0.71845	validation_1-rmse:1.24172
# [49]	validation_0-rmse:0.71564	validation_1-rmse:1.23669
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 41.0, median: 45.5,
#  pred. interval (P(0.025)-P(0.975)): 19.975-49.0,
#  conf. interval (p-value=0.95): 38.735-47.028
# ***
# Aggregate bias statistic:
#  mean: 4.024, median: 3.218,
#  pred. interval (P(0.025)-P(0.975)): -3.15-13.714,
#  conf. interval (p-value=0.95): 1.549-5.601
# ***
# Aggregate RMSE statistic:
#  mean: 1.016, median: 1.064, pred. interval (P(0.025)-P(0.975)): 0.685-1.333,
#  conf. interval (p-value=0.95): 0.962-1.129
# ***
# Aggregate MSE statistic:
#  mean: 1.068, median: 1.132, pred. interval (P(0.025)-P(0.975)): 0.469-1.778,
#  conf. interval (p-value=0.95): 0.939-1.279
# ***
# Aggregate R^2 statistic:
#  mean: 0.054, median: 0.063, pred. interval (P(0.025)-P(0.975)): -0.378-0.278,
#  conf. interval (p-value=0.95): 0.023-0.129
# ***
# Aggregate bias(%) statistic:
#  mean: -13.061, median: 3.218, pred. interval (P(0.025)-P(0.975)): -53.329-51.95,
#  conf. interval (p-value=0.95): -17.177--10.076
# ***
# Aggregate RMSE(%) statistic:
#  mean: -3.729, median: -2.86, pred. interval (P(0.025)-P(0.975)): -28.435-18.551,
#  conf. interval (p-value=0.95): -4.771--1.547
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.31284
# [1]	validation_0-rmse:1.29394
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-rmse:1.27536
# [3]	validation_0-rmse:1.25818
# [4]	validation_0-rmse:1.23302
# [5]	validation_0-rmse:1.21570
# [6]	validation_0-rmse:1.19232
# [7]	validation_0-rmse:1.17669
# [8]	validation_0-rmse:1.16456
# [9]	validation_0-rmse:1.13970
# [10]	validation_0-rmse:1.13238
# [11]	validation_0-rmse:1.11602
# [12]	validation_0-rmse:1.10240
# [13]	validation_0-rmse:1.08785
# [14]	validation_0-rmse:1.06933
# [15]	validation_0-rmse:1.05835
# [16]	validation_0-rmse:1.04349
# [17]	validation_0-rmse:1.03289
# [18]	validation_0-rmse:1.02023
# [19]	validation_0-rmse:1.00295
# [20]	validation_0-rmse:0.98930
# [21]	validation_0-rmse:0.97998
# [22]	validation_0-rmse:0.96323
# [23]	validation_0-rmse:0.95047
# [24]	validation_0-rmse:0.93688
# [25]	validation_0-rmse:0.93140
# [26]	validation_0-rmse:0.91805
# [27]	validation_0-rmse:0.90767
# [28]	validation_0-rmse:0.89793
# [29]	validation_0-rmse:0.88431
# [30]	validation_0-rmse:0.88250
# [31]	validation_0-rmse:0.88001
# [32]	validation_0-rmse:0.86672
# [33]	validation_0-rmse:0.86088
# [34]	validation_0-rmse:0.85065
# [35]	validation_0-rmse:0.84345
# [36]	validation_0-rmse:0.83544
# [37]	validation_0-rmse:0.82923
# [38]	validation_0-rmse:0.82194
# [39]	validation_0-rmse:0.81342
# [40]	validation_0-rmse:0.80850
# [41]	validation_0-rmse:0.80188
# [42]	validation_0-rmse:0.79843
# [43]	validation_0-rmse:0.79476
# [44]	validation_0-rmse:0.78412
# [45]	validation_0-rmse:0.77292
# [46]	validation_0-rmse:0.76222
# [47]	validation_0-rmse:0.75860
# [48]	validation_0-rmse:0.75170
# [49]	validation_0-rmse:0.74407
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 49

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.2
# Relative bias(%):  -67.25
# RMSE: 0.7
# Relative RMSE(%):  -2.954
# MSE: 0.6
# R square: 54.2%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-3, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 0.008
# a1: 0.380
# R^2: 0.739
# Uncertainty
# a0: 0.008+/-0.025
# a1: 0.380+/-0.022

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=1) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Cs_XGB_model.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/UAV_ln_Cs_XGB_model.txt")
