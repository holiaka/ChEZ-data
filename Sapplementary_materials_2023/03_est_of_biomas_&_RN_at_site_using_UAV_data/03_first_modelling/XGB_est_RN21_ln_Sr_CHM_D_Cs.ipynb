# %% [markdown]
# # *+ Processing with CHM & RN & biomass data +*

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load biomass dataset
biomass_data = '/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/Main_CHM_spectral_Site2020.csv'
df = pd.read_csv(biomass_data)
df.head()
# Out:
#   Site #    WGS84 N   WGS 84 E Origin  Origin_ID Dominant_specias  Species_ID  \
# 0      1  51.435741  30.107979      n          0            Birch           2
# 1      2  51.434093  30.108523      a          1             Pine           0
# 2      3  51.434163  30.109196      a          1             Pine           0
# 3      4  51.434217  30.110484      a          1             Pine           0
# 4      5  51.434056  30.111980      a          1             Pine           0
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ...  idm_g_Q25  idm_g_Q50  \
# 0            920       6.824          10300  ...   0.042167   0.050549
# 1           3600       8.189          15100  ...   0.040919   0.048889
# 2           4360       8.380          14600  ...   0.042397   0.050463
# 3           3420       8.137          12700  ...   0.043719   0.052974
# 4           2200       7.696          12100  ...   0.040659   0.049303
#
#    idm_g_Q75  idm_b_MIN  idm_b_MAX idm_b_MEAN  idm_b_STD  idm_b_Q25  \
# 0   0.062270   0.017730   0.408966   0.059749   0.030217   0.043539
# 1   0.060698   0.020078   0.258602   0.057223   0.025515   0.043035
# 2   0.060603   0.020761   0.156265   0.056571   0.016629   0.045142
# 3   0.066027   0.017239   0.327465   0.060880   0.023964   0.046111
# 4   0.061803   0.014276   0.274420   0.057902   0.024283   0.043045
#
#    idm_b_Q50  idm_b_Q75
# 0   0.052312   0.064544
# 1   0.050941   0.062608
# 2   0.053495   0.064635
# 3   0.055601   0.069182
# 4   0.051566   0.065078
#
# [5 rows x 163 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'ln_Tag_Cs', 'ln_Tag_Sr',
# 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth',
# 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2',
# 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
# '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75',
# 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75',
# 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75',
# 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75',
# 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75',
# 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75',
# 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75',
# 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75',
# 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75',
# 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75',
# 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75',
# 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75',
# 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75',
# 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75',
# 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75',
# 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75',
# 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns= ['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'r_MIN', 'contr_b_MAX', 'contr_b_STD'])

# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           1912            784      -0.73       2.58
# 1       8.189       9.622           2005            818       0.59       2.92
# 2       8.380       9.589           2001            818       0.78       2.88
# 3       8.137       9.449           2040            833       0.52       2.72
# 4       7.696       9.401           1758            717       0.22       2.83
#
#    AEDR_mean  r_MIN  contr_b_MAX  contr_b_STD
# 0       2.33     13  2713.600586   332.963753
# 1       2.47     24  1793.493042   293.868420
# 2       2.44     18  1761.097900   272.526176
# 3       2.55     15  2518.435303   299.595643
# 4       2.14      8  2525.819336   327.599176

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   r_MIN          103 non-null    int64
#  8   contr_b_MAX    103 non-null    float64
#  9   contr_b_STD    103 non-null    float64
# dtypes: float64(7), int64(3)
# memory usage: 8.2 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
# Out:
# /tmp/ipykernel_12248/725619848.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Dominant_specias'])['Cs_wood_Bq/kg', 'Sr_wood_Bq/kg'].describe()
#                  Cs_wood_Bq/kg                                                \
#                          count          mean          std      min       25%
# Dominant_specias
# Alder                      4.0   3353.250000  4978.217444    360.0    864.75
# Aspen                      1.0  86400.000000          NaN  86400.0  86400.00
# Birch                     23.0   4489.043478  7412.075967     93.0    565.00
# Oak                        3.0   2550.000000  2248.088077    420.0   1375.00
# Pine                      71.0   3452.535211  7193.888267     34.0    590.00
# Spruce                     1.0    177.000000          NaN    177.0    177.00
#
#                                             Sr_wood_Bq/kg                \
#                       50%      75%      max         count          mean
# Dominant_specias
# Alder              1126.5   3615.0  10800.0           4.0   1534.000000
# Aspen             86400.0  86400.0  86400.0           1.0  65500.000000
# Birch              1360.0   3079.5  30700.0          23.0  67957.695652
# Oak                2330.0   3615.0   4900.0           3.0   2143.333333
# Pine               1040.0   2200.0  35200.0          71.0  15541.450704
# Spruce              177.0    177.0    177.0           1.0   2400.000000
#
#
#                             std      min      25%      50%      75%        max
# Dominant_specias
# Alder                734.881396    526.0   1219.0   1755.0   2070.0     2100.0
# Aspen                       NaN  65500.0  65500.0  65500.0  65500.0    65500.0
# Birch             217382.739246   1260.0   4450.0   8030.0  20784.0  1050000.0
# Oak                 1338.220211    710.0   1535.0   2360.0   2860.0     3360.0
# Pine               41295.160700    435.0   2090.0   4780.0  11750.0   323600.0
# Spruce                      NaN   2400.0   2400.0   2400.0   2400.0     2400.0

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3014.359223    1136.436893   -0.251845
# std       1.64946    1.472424    4988.505540    2019.773384    1.104536
# min       3.52600    6.075000     423.000000      98.000000   -3.030000
# 25%       6.31900    7.664000     635.500000     199.500000   -0.725000
# 50%       6.95700    8.472000    1145.000000     362.000000   -0.020000
# 75%       7.91350    9.421000    2423.500000     966.000000    0.520000
# max      11.36700   13.864000   25173.000000   10477.000000    1.650000
#
#         ln_Tag_Sr   AEDR_mean       r_MIN  contr_b_MAX  contr_b_STD
# count  103.000000  103.000000  103.000000   103.000000   103.000000
# mean     2.464854    3.570291   11.378641  2712.352866   349.854034
# std      0.904757    6.089170    9.139568   864.116297    93.673105
# min      0.390000    0.480000    2.000000   832.155518   109.232976
# 25%      1.805000    0.710000    5.000000  2123.614868   292.544440
# 50%      2.600000    1.290000    8.000000  2601.248047   341.904211
# 75%      3.160000    2.960000   15.000000  3045.944336   427.359073
# max      4.660000   36.590000   56.000000  6252.923340   588.661708

# %%
# Correlation matrix

import seaborn as sns # for correlation heatmap

def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap="YlGnBu",
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}
                )
    plt.show();
    
correlation_heatmap(select)

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns= ['Sr_2021_kBq_m'])
y = pd.DataFrame(select, columns= ['ln_Sr_wood'])

# %%
# Add to 'X' data colection new colomns with sintetic/random data: selest "Yes" or "No".
question=input("Choose an option - Add a synthetic column with random values!!! (Yes or No):")

if question == 'Yes':
    count = y.count()
    norm_random_1 = np.random.normal(10, 2, size=count)
    norm_random_2 = np.random.normal(10, 2, size=count)
    norm_random_3 = np.random.normal(10, 2, size=count)
    norm_random_4 = np.random.normal(10, 2, size=count)
    norm_random_5 = np.random.normal(10, 2, size=count)
    X['Random1'] = norm_random_1
    X['Random2'] = norm_random_2
    X['Random3'] = norm_random_3
    X['Random4'] = norm_random_4
    X['Random5'] = norm_random_5
    
    print('Selected "Yes"!!! A new column with random values was created.')
elif question == 'No':
    print('Selected "No"!!! A new column with random values was not created.')
else:
    print('Error!!! Typed no corectly text!!!')
# Out:
# Choose an option - Add a synthetic column with random values!!! (Yes or No): No
# Selected "No"!!! A new column with random values was not created.

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Sr_2021_kBq_m
# 0            784
# 1            818
# 2            818
# 3            833
# 4            717

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Sr_wood
# 0       9.240
# 1       9.622
# 2       9.589
# 3       9.449
# 4       9.401

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.6038154642747919, 0.3980379260198702, 0.46348756701242577]
#     Mean: 0.488
#     Std: 0.086
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.0210975 1.0353713 0.9500468]
#     Mean: 1.002
#     Std: 0.037
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.7815956770760673, 0.9025491156858555, 0.6930539112091063]
#     Mean: 0.792
#     Std: 0.086
#
#  --------------------

# %% [markdown]
# # Find optimal hyperparameters for XGBoost model

# %%
# Create function for present of hyperparameters and main scores
def report_best_scores(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            global hps
            hps =  results['params'][candidate]
            print("")

# %%
# Tuning XGBoost parameters
xgb_model = xgb.XGBRegressor(objective="reg:squarederror", eval_metric="rmse")
params = {
    "colsample_bytree": uniform(0.05, 0.9),
    "gamma": uniform(0, 0.5),
    "learning_rate": uniform(0.01, 0.3), # default 0.1 
    "max_depth": randint(2, 5), # default 3
    "n_estimators": randint(50, 200), # default 100
    "subsample": uniform(0.3, 0.7)
}

search = RandomizedSearchCV(xgb_model, param_distributions=params, n_iter=3000, cv=5, verbose=1, n_jobs=1, return_train_score=True)

search.fit(X, y)

report_best_scores(search.cv_results_, 1)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits

# %%
# All output data for XGBoost models after tuning parameters
print(search.cv_results_)
# Out:
# {'mean_fit_time': array([0.62661786, 0.44367533, 0.43662949, ..., 0.32803645, 0.53257494,
#        0.3016736 ]), 'std_fit_time': array([0.11489514, 0.01793304, 0.0146984 , ..., 0.00418012, 0.07270512,
#        0.00377819]), 'mean_score_time': array([0.00793076, 0.00623107, 0.00609131, ..., 0.00682335, 0.00722179,
#        0.00688133]), 'std_score_time': array([4.24676668e-03, 5.18115094e-04, 4.92153700e-05, ...,
#        3.83942458e-05, 4.35020309e-04, 8.61158667e-05]), 'param_colsample_bytree': masked_array(data=[0.4915787611156235, 0.10394014047289618,
#                    0.43468623290003156, ..., 0.11371512268771333,
#                    0.41724436270172655, 0.47725946122916046],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_gamma': masked_array(data=[0.38578149884241764, 0.3083698834106356,
#                    0.42377416205074886, ..., 0.2159222984003749,
#                    0.3739619769748155, 0.13959748110693265],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_learning_rate': masked_array(data=[0.073889465629877, 0.19428284877819324,
#                    0.15318945278461757, ..., 0.048745729058998336,
#                    0.07746535116426875, 0.10386789473939553],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_depth': masked_array(data=[2, 3, 2, ..., 3, 3, 4],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[189, 176, 178, ..., 114, 165, 101],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'param_subsample': masked_array(data=[0.7861599700005475, 0.795927840730838,
#                    0.7849245968544833, ..., 0.6197241575941973,
#                    0.44776849784057815, 0.6698604036577345],
#              mask=[False, False, False, ..., False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'colsample_bytree': 0.4915787611156235, 'gamma': 0.38578149884241764, 'learning_rate': 0.073889465629877, 'max_depth': 2, 'n_estimators': 189, 'subsample': 0.7861599700005475}, {'colsample_bytree': 0.10394014047289618, 'gamma': 0.3083698834106356, 'learning_rate': 0.19428284877819324, 'max_depth': 3, 'n_estimators': 176, 'subsample': 0.795927840730838}, {'colsample_bytree': 0.43468623290003156, 'gamma': 0.42377416205074886, 'learning_rate': 0.15318945278461757, 'max_depth': 2, 'n_estimators': 178, 'subsample': 0.7849245968544833}, {'colsample_bytree': 0.8257536398090622, 'gamma': 0.10804050424163808, 'learning_rate': 0.2178221871184632, 'max_depth': 2, 'n_estimators': 123, 'subsample': 0.587733665168481}, {'colsample_bytree': 0.06708681392047874, 'gamma': 0.08046023845472183, 'learning_rate': 0.021081851651097994, 'max_depth': 2, 'n_estimators': 161, 'subsample': 0.4690349184806939}, {'colsample_bytree': 0.062092917316308595, 'gamma': 0.27615255999826216, 'learning_rate': 0.19564419096229693, 'max_depth': 2, 'n_estimators': 120, 'subsample': 0.7553745289679372}, {'colsample_bytree': 0.409985124662211, 'gamma': 0.11058645122547722, 'learning_rate': 0.040448459466585505, 'max_depth': 4, 'n_estimators': 140, 'subsample': 0.8298360308302681}, {'colsample_bytree': 0.1080391474245473, 'gamma': 0.4243826200598938, 'learning_rate': 0.07958351640890059, 'max_depth': 2, 'n_estimators': 107, 'subsample': 0.33008429199809086}, {'colsample_bytree': 0.45634241223375477, 'gamma': 0.06410970473718097, 'learning_rate': 0.07004643686362773, 'max_depth': 4, 'n_estimators': 110, 'subsample': 0.4316592617246231}, {'colsample_bytree': 0.8090465655413356, 'gamma': 0.41701648195980195, 'learning_rate': 0.28563768405264695, 'max_depth': 3, 'n_estimators': 87, 'subsample': 0.44047210969450995}, {'colsample_bytree': 0.15161766511699204, 'gamma': 0.09256873071367694, 'learning_rate': 0.12097334784365343, 'max_depth': 2, 'n_estimators': 123, 'subsample': 0.8541841377047543}, {'colsample_bytree': 0.3453370710608234, 'gamma': 0.2971631655278197, 'learning_rate': 0.2702225501931643, 'max_depth': 2, 'n_estimators': 99, 'subsample': 0.6496816573301805}, {'colsample_bytree': 0.5053857696353655, 'gamma': 0.2628627440142279, 'learning_rate': 0.15386423095979532, 'max_depth': 3, 'n_estimators': 52, 'subsample': 0.5314499606535792}, {'colsample_bytree': 0.6013058136963249, 'gamma': 0.34537136812443003, 'learning_rate': 0.27840932305717586, 'max_depth': 4, 'n_estimators': 112, 'subsample': 0.8855264724095295}, {'colsample_bytree': 0.3812413940514897, 'gamma': 0.14255248872964427, 'learning_rate': 0.06719473706503622, 'max_depth': 2, 'n_estimators': 93, 'subsample': 0.7919236652781214}, {'colsample_bytree': 0.1662739562856535, 'gamma': 0.09529832648828712, 'learning_rate': 0.2274420315774319, 'max_depth': 4, 'n_estimators': 175, 'subsample': 0.6235245755326083}, {'colsample_bytree': 0.9231113731120585, 'gamma': 0.3526731636364009, 'learning_rate': 0.12579405150779222, 'max_depth': 3, 'n_estimators': 152, 'subsample': 0.5547329863974186}, {'colsample_bytree': 0.10146209989138996, 'gamma': 0.20112797410305355, 'learning_rate': 0.2057242203648604, 'max_depth': 4, 'n_estimators': 64, 'subsample': 0.635317789435513}, {'colsample_bytree': 0.9345369720703129, 'gamma': 0.003899223710945754, 'learning_rate': 0.1412184781195142, 'max_depth': 4, 'n_estimators': 195, 'subsample': 0.8175189745942342}, {'colsample_bytree': 0.18537215344725289, 'gamma': 0.4207992167750061, 'learning_rate': 0.0996057351414354, 'max_depth': 3, 'n_estimators': 168, 'subsample': 0.6489284716528858}, {'colsample_bytree': 0.12600982808749112, 'gamma': 0.4889764373629116, 'learning_rate': 0.1563880464746751, 'max_depth': 3, 'n_estimators': 67, 'subsample': 0.8459310593903342}, {'colsample_bytree': 0.07525944019039925, 'gamma': 0.3207428780969947, 'learning_rate': 0.05826363260531643, 'max_depth': 4, 'n_estimators': 132, 'subsample': 0.39793851375013517}, {'colsample_ ...
#        -0.05988882, -0.07269539]), 'split1_test_score': array([ 0.05625417, -0.04790404,  0.13123226, ..., -0.10105789,
#         0.09544586,  0.01901627]), 'split2_test_score': array([0.22583238, 0.11545397, 0.21857354, ..., 0.26777208, 0.17757311,
#        0.10013942]), 'split3_test_score': array([0.67674703, 0.66886998, 0.66528954, ..., 0.64051225, 0.64553693,
#        0.66586359]), 'split4_test_score': array([0.68834846, 0.64694225, 0.67726605, ..., 0.72583259, 0.67364816,
#        0.59946425]), 'mean_test_score': array([0.38642923, 0.26297121, 0.35193972, ..., 0.39823156, 0.30646305,
#        0.26235763]), 'std_test_score': array([0.25319626, 0.32877638, 0.26514986, ..., 0.29526804, 0.29837914,
#        0.30797669]), 'rank_test_score': array([ 267, 1521,  656, ...,  138, 1157, 1532], dtype=int32), 'split0_train_score': array([0.89351025, 0.94490802, 0.91609715, ..., 0.86218815, 0.90778871,
#        0.94729869]), 'split1_train_score': array([0.88748353, 0.94657751, 0.91611047, ..., 0.86346156, 0.90576665,
#        0.94431814]), 'split2_train_score': array([0.88213206, 0.93957758, 0.90419983, ..., 0.86247144, 0.90394987,
#        0.94101363]), 'split3_train_score': array([0.8510954 , 0.91782046, 0.87501148, ..., 0.81205965, 0.86247576,
#        0.92803459]), 'split4_train_score': array([0.86989105, 0.93253968, 0.89892589, ..., 0.83940218, 0.89121688,
#        0.93989734]), 'mean_train_score': array([0.87682246, 0.93628465, 0.90206896, ..., 0.84791659, 0.89423958,
#        0.94011248]), 'std_train_score': array([0.01503502, 0.01045084, 0.01510285, ..., 0.02007676, 0.01690455,
#        0.00657363])}

# %%
# Overwrite hyperparameters data for the next step/stage
p1 = hps['colsample_bytree']     # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = hps['gamma']                # gamma
print('Gamma: ' + str(p2))

p3 = hps['learning_rate']        # learning_rate
print('Learning_rate: ' + str(p3))

p4 = hps['max_depth']            # max_depth
print('Max_depth: ' + str(p4))

p5 = hps['n_estimators']         # n_estimators
print('N_estimators: ' + str(p5))

p6 = hps['subsample']            # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.567640749675812
# Gamma: 0.07387036752295428
# Learning_rate: 0.11447010678160813
# Max_depth: 2
# N_estimators: 90
# Subsample: 0.7983544034380838

# %% [markdown]
# # Estimation of a basic XGBoost model using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()
    rel_bias = bias/y_mean_sample
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample    
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Add values to lists    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
# Out:
# [0]	validation_0-rmse:7.29799	validation_1-rmse:7.77444
# [1]	validation_0-rmse:6.50133	validation_1-rmse:6.95766
# [2]	validation_0-rmse:5.79010	validation_1-rmse:6.23073
# [3]	validation_0-rmse:5.17057	validation_1-rmse:5.61605
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [4]	validation_0-rmse:4.61605	validation_1-rmse:5.04727
# [5]	validation_0-rmse:4.13151	validation_1-rmse:4.56985
# [6]	validation_0-rmse:3.69794	validation_1-rmse:4.12348
# [7]	validation_0-rmse:3.31756	validation_1-rmse:3.74794
# [8]	validation_0-rmse:2.97500	validation_1-rmse:3.40409
# [9]	validation_0-rmse:2.67205	validation_1-rmse:3.10323
# [10]	validation_0-rmse:2.40409	validation_1-rmse:2.83914
# [11]	validation_0-rmse:2.17539	validation_1-rmse:2.60440
# [12]	validation_0-rmse:1.97115	validation_1-rmse:2.40143
# [13]	validation_0-rmse:1.78845	validation_1-rmse:2.21923
# [14]	validation_0-rmse:1.62951	validation_1-rmse:2.05995
# [15]	validation_0-rmse:1.48408	validation_1-rmse:1.90714
# [16]	validation_0-rmse:1.37051	validation_1-rmse:1.78862
# [17]	validation_0-rmse:1.26612	validation_1-rmse:1.67562
# [18]	validation_0-rmse:1.18236	validation_1-rmse:1.59445
# [19]	validation_0-rmse:1.10132	validation_1-rmse:1.49963
# [20]	validation_0-rmse:1.02842	validation_1-rmse:1.41984
# [21]	validation_0-rmse:0.96874	validation_1-rmse:1.34885
# [22]	validation_0-rmse:0.92154	validation_1-rmse:1.29580
# [23]	validation_0-rmse:0.88138	validation_1-rmse:1.24599
# [24]	validation_0-rmse:0.85092	validation_1-rmse:1.20531
# [25]	validation_0-rmse:0.82436	validation_1-rmse:1.17193
# [26]	validation_0-rmse:0.79974	validation_1-rmse:1.13591
# [27]	validation_0-rmse:0.77757	validation_1-rmse:1.10858
# [28]	validation_0-rmse:0.75949	validation_1-rmse:1.08351
# [29]	validation_0-rmse:0.73968	validation_1-rmse:1.05373
# [30]	validation_0-rmse:0.72269	validation_1-rmse:1.03453
# [31]	validation_0-rmse:0.70537	validation_1-rmse:1.01523
# [32]	validation_0-rmse:0.69691	validation_1-rmse:1.00482
# [33]	validation_0-rmse:0.68941	validation_1-rmse:0.99623
# [34]	validation_0-rmse:0.68380	validation_1-rmse:0.98609
# [35]	validation_0-rmse:0.67096	validation_1-rmse:0.97151
# [36]	validation_0-rmse:0.66665	validation_1-rmse:0.95895
# [37]	validation_0-rmse:0.66280	validation_1-rmse:0.94467
# [38]	validation_0-rmse:0.65762	validation_1-rmse:0.93420
# [39]	validation_0-rmse:0.64894	validation_1-rmse:0.91864
# [40]	validation_0-rmse:0.64535	validation_1-rmse:0.91062
# [41]	validation_0-rmse:0.64251	validation_1-rmse:0.90520
# [42]	validation_0-rmse:0.63776	validation_1-rmse:0.89873
# [43]	validation_0-rmse:0.63188	validation_1-rmse:0.89119
# [44]	validation_0-rmse:0.62932	validation_1-rmse:0.88534
# [45]	validation_0-rmse:0.62670	validation_1-rmse:0.88674
# [46]	validation_0-rmse:0.62452	validation_1-rmse:0.88282
# [47]	validation_0-rmse:0.62317	validation_1-rmse:0.87814
# [48]	validation_0-rmse:0.61934	validation_1-rmse:0.87399
# [49]	validation_0-rmse:0.61599	validation_1-rmse:0.87236
# [50]	validation_0-rmse:0.61472	validation_1-rmse:0.86696
# [51]	validation_0-rmse:0.61023	validation_1-rmse:0.86522
# [52]	validation_0-rmse:0.60905	validation_1-rmse:0.86158
# [53]	validation_0-rmse:0.60457	validation_1-rmse:0.85683
# [54]	validation_0-rmse:0.59862	validation_1-rmse:0.85018
# [55]	validation_0-rmse:0.59400	validation_1-rmse:0.84967
# [56]	validation_0-rmse:0.59187	validation_1-rmse:0.85038
# [57]	validation_0-rmse:0.58858	validation_1-rmse:0.84840
# [58]	validation_0-rmse:0.58747	validation_1-rmse:0.84411
# [59]	validation_0-rmse:0.58700	validation_1-rmse:0.84355
# [60]	validation_0-rmse:0.58638	validation_1-rmse:0.83933
# [61]	validation_0-rmse:0.58541	validation_1-rmse:0.83816
# [62]	validation_0-rmse:0.58215	validation_1-rmse:0.83784
# [63]	validation_0-rmse:0.57734	validation_1-rmse:0.83754
# [64]	validation_0-rmse:0.57660	validation_1-rmse:0.83567
# [65]	validation_0-rmse:0.57400	validation_1-rmse:0.83513
# [66]	validation_0-rmse:0.57271	validation_1-rmse:0.83661
# [67]	validation_0-rmse:0.57080	validation_1-rmse:0.84166
# [68]	validation_0-rmse:0.56754	validation_1-rmse:0.84057
# [69]	validation_0-rmse:0.56492	validation_1-rmse:0.84114
# [70]	validation_0-rmse:0.56275	validation_1-rmse:0.83496
# [71]	validation_0-rmse:0.56201	validation_1-rmse:0.83250
# [72]	validation_0-rmse:0.55894	validation_1-rmse:0.83072
# [73]	validation_0-rmse:0.55679	validation_1-rmse:0.82998
# [74]	validation_0-rmse:0.55366	validation_1-rmse:0.83138
# [75]	validation_0-rmse:0.55121	validation_1-rmse:0.83221
# [76]	validation_0-rmse:0.55061	validation_1-rmse:0.83013
# [77]	validation_0-rmse:0.54782	validation_1-rmse:0.82941
# [78]	validation_0-rmse:0.54596	validation_1-rmse:0.82802
# [79]	validation_0-rmse:0.54540	validation_1-rmse:0.82555
# [80]	validation_0-rmse:0.54283	validation_1-rmse:0.82442
# [81]	validation_0-rmse:0.53995	validation_1-rmse:0.82486
# [82]	validation_0-rmse:0.53929	validation_1-rmse:0.82537
# [83]	validation_0-rmse:0.53750	validation_1-rmse:0.82442
# [84]	validation_0-rmse:0.53547	validation_1-rmse:0.82861
# [85]	validation_0-rmse:0.53316	validation_1-rmse:0.82748
# [86]	validation_0-rmse:0.52868	validation_1-rmse:0.82621
# [87]	validation_0-rmse:0.52853	validation_1-rmse:0.82752
# [88]	validation_0-rmse:0.52709	validation_1-rmse:0.82894
# [89]	validation_0-rmse:0.52651	validation_1-rmse:0.82546
# [0]	validation_0-rmse:7.42378	validation_1-rmse:7.18374
# [1]	validation_0-rmse:6.61740	validation_1-rmse:6.38053
# [2]	validation_0-rmse:5.90790	validation_1-rmse:5.68917
# [3]	validation_0-rmse:5.26172	validation_1-rmse:5.06262
# [4]	validation_0-rmse:4.70126	validation_1-rmse:4.50315
# [5]	validation_0-rmse:4.21554	validation_1-rmse:4.01741
# [6]	validation_0-rmse:3.77970	validation_1-rmse:3.58139
# [7]	validation_0-rmse:3.38380	validation_1-rmse:3.19690
# [8]	validation_0-rmse:3.03947	validation_1-rmse:2.85388
# [9]	validation_0-rmse:2.72929	validation_1-rmse:2.55527
# [10]	validation_0-rmse:2.45185	validation_1-rmse:2.28916
# [11]	validation_0-rmse:2.22100	validation_1-rmse:2.07244
# [12]	validation_0-rmse:2.01148	validation_1-rmse:1.87106
# [13]	validation_0-rmse:1.82292	validation_1-rmse:1.68733
# [14]	validation_0-rmse:1.65295	validation_1-rmse:1.52018
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [15]	validation_0-rmse:1.51771	validation_1-rmse:1.38945
# [16]	validation_0-rmse:1.40775	validation_1-rmse:1.27528
# [17]	validation_0-rmse:1.29412	validation_1-rmse:1.16824
# [18]	validation_0-rmse:1.20447	validation_1-rmse:1.07764
# [19]	validation_0-rmse:1.12583	validation_1-rmse:1.00916
# [20]	validation_0-rmse:1.06021	validation_1-rmse:0.94542
# [21]	validation_0-rmse:1.00202	validation_1-rmse:0.89569
# [22]	validation_0-rmse:0.95325	validation_1-rmse:0.85018
# [23]	validation_0-rmse:0.90972	validation_1-rmse:0.81966
# [24]	validation_0-rmse:0.87339	validation_1-rmse:0.78659
# [25]	validation_0-rmse:0.84381	validation_1-rmse:0.76113
# [26]	validation_0-rmse:0.81956	validation_1-rmse:0.74338
# [27]	validation_0-rmse:0.79812	validation_1-rmse:0.72730
# [28]	validation_0-rmse:0.77822	validation_1-rmse:0.71083
# [29]	validation_0-rmse:0.76529	validation_1-rmse:0.69852
# [30]	validation_0-rmse:0.75132	validation_1-rmse:0.68790
# [31]	validation_0-rmse:0.73157	validation_1-rmse:0.67686
# [32]	validation_0-rmse:0.72079	validation_1-rmse:0.67460
# [33]	validation_0-rmse:0.71254	validation_1-rmse:0.67134
# [34]	validation_0-rmse:0.70055	validation_1-rmse:0.67794
# [35]	validation_0-rmse:0.69505	validation_1-rmse:0.67412
# [36]	validation_0-rmse:0.68792	validation_1-rmse:0.67028
# [37]	validation_0-rmse:0.68344	validation_1-rmse:0.67135
# [38]	validation_0-rmse:0.68034	validation_1-rmse:0.66606
# [39]	validation_0-rmse:0.67003	validation_1-rmse:0.66781
# [40]	validation_0-rmse:0.66097	validation_1-rmse:0.67690
# [41]	validation_0-rmse:0.65288	validation_1-rmse:0.67787
# [42]	validation_0-rmse:0.64826	validation_1-rmse:0.67626
# [43]	validation_0-rmse:0.64629	validation_1-rmse:0.67870
# [44]	validation_0-rmse:0.64202	validation_1-rmse:0.68242
# [45]	validation_0-rmse:0.64156	validation_1-rmse:0.67971
# [46]	validation_0-rmse:0.63932	validation_1-rmse:0.67610
# [47]	validation_0-rmse:0.63693	validation_1-rmse:0.67993
# [48]	validation_0-rmse:0.62962	validation_1-rmse:0.68415
# [49]	validation_0-rmse:0.62516	validation_1-rmse:0.69039
# [50]	validation_0-rmse:0.62296	validation_1-rmse:0.68761
# [51]	validation_0-rmse:0.61878	validation_1-rmse:0.68209
# [52]	validation_0-rmse:0.61451	validation_1-rmse:0.68350
# [53]	validation_0-rmse:0.60943	validation_1-rmse:0.68753
# [54]	validation_0-rmse:0.60777	validation_1-rmse:0.68680
# [55]	validation_0-rmse:0.60580	validation_1-rmse:0.68669
# [56]	validation_0-rmse:0.60446	validation_1-rmse:0.68596
# [57]	validation_0-rmse:0.59769	validation_1-rmse:0.68610
# [58]	validation_0-rmse:0.59398	validation_1-rmse:0.69074
# [0]	validation_0-rmse:7.29603	validation_1-rmse:7.68896
# [1]	validation_0-rmse:6.51117	validation_1-rmse:6.89765
# [2]	validation_0-rmse:5.80393	validation_1-rmse:6.12751
# [3]	validation_0-rmse:5.17677	validation_1-rmse:5.46413
# [4]	validation_0-rmse:4.63039	validation_1-rmse:4.86536
# [5]	validation_0-rmse:4.14092	validation_1-rmse:4.36228
# [6]	validation_0-rmse:3.71284	validation_1-rmse:3.92095
# [7]	validation_0-rmse:3.33687	validation_1-rmse:3.50567
# [8]	validation_0-rmse:2.99382	validation_1-rmse:3.14946
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [9]	validation_0-rmse:2.70393	validation_1-rmse:2.82827
# [10]	validation_0-rmse:2.43615	validation_1-rmse:2.55477
# [11]	validation_0-rmse:2.20461	validation_1-rmse:2.31000
# [12]	validation_0-rmse:1.99270	validation_1-rmse:2.07264
# [13]	validation_0-rmse:1.80833	validation_1-rmse:1.85492
# [14]	validation_0-rmse:1.65959	validation_1-rmse:1.67918
# [15]	validation_0-rmse:1.51900	validation_1-rmse:1.51665
# [16]	validation_0-rmse:1.41040	validation_1-rmse:1.39431
# [17]	validation_0-rmse:1.29798	validation_1-rmse:1.26405
# [18]	validation_0-rmse:1.22540	validation_1-rmse:1.18194
# [19]	validation_0-rmse:1.14986	validation_1-rmse:1.12034
# [20]	validation_0-rmse:1.07846	validation_1-rmse:1.03668
# [21]	validation_0-rmse:1.01752	validation_1-rmse:0.98525
# [22]	validation_0-rmse:0.97911	validation_1-rmse:0.93879
# [23]	validation_0-rmse:0.93633	validation_1-rmse:0.89414
# [24]	validation_0-rmse:0.89753	validation_1-rmse:0.84845
# [25]	validation_0-rmse:0.87001	validation_1-rmse:0.83649
# [26]	validation_0-rmse:0.84236	validation_1-rmse:0.80538
# [27]	validation_0-rmse:0.81899	validation_1-rmse:0.78016
# [28]	validation_0-rmse:0.79704	validation_1-rmse:0.76005
# [29]	validation_0-rmse:0.78017	validation_1-rmse:0.74651
# [30]	validation_0-rmse:0.76367	validation_1-rmse:0.73792
# [31]	validation_0-rmse:0.75065	validation_1-rmse:0.72996
# [32]	validation_0-rmse:0.73724	validation_1-rmse:0.71967
# [33]	validation_0-rmse:0.71691	validation_1-rmse:0.70747
# [34]	validation_0-rmse:0.71057	validation_1-rmse:0.70611
# [35]	validation_0-rmse:0.70291	validation_1-rmse:0.70452
# [36]	validation_0-rmse:0.69570	validation_1-rmse:0.70088
# [37]	validation_0-rmse:0.68277	validation_1-rmse:0.70341
# [38]	validation_0-rmse:0.67313	validation_1-rmse:0.69916
# [39]	validation_0-rmse:0.66296	validation_1-rmse:0.70152
# [40]	validation_0-rmse:0.65749	validation_1-rmse:0.70635
# [41]	validation_0-rmse:0.65175	validation_1-rmse:0.70478
# [42]	validation_0-rmse:0.64772	validation_1-rmse:0.70891
# [43]	validation_0-rmse:0.64292	validation_1-rmse:0.70933
# [44]	validation_0-rmse:0.63879	validation_1-rmse:0.70991
# [45]	validation_0-rmse:0.63483	validation_1-rmse:0.71081
# [46]	validation_0-rmse:0.63210	validation_1-rmse:0.71221
# [47]	validation_0-rmse:0.63022	validation_1-rmse:0.71992
# [48]	validation_0-rmse:0.62802	validation_1-rmse:0.72435
# [49]	validation_0-rmse:0.62302	validation_1-rmse:0.72892
# [50]	validation_0-rmse:0.61697	validation_1-rmse:0.72915
# [51]	validation_0-rmse:0.61115	validation_1-rmse:0.72905
# [52]	validation_0-rmse:0.60635	validation_1-rmse:0.73102
# [53]	validation_0-rmse:0.60192	validation_1-rmse:0.73641
# [54]	validation_0-rmse:0.59730	validation_1-rmse:0.74183
# [55]	validation_0-rmse:0.59373	validation_1-rmse:0.74313
# [56]	validation_0-rmse:0.59167	validation_1-rmse:0.74436
# [57]	validation_0-rmse:0.58761	validation_1-rmse:0.74896
# [0]	validation_0-rmse:7.49715	validation_1-rmse:6.96303
# [1]	validation_0-rmse:6.68198	validation_1-rmse:6.18993
# [2]	validation_0-rmse:5.95233	validation_1-rmse:5.50727
# [3]	validation_0-rmse:5.31575	validation_1-rmse:4.91034
# [4]	validation_0-rmse:4.74571	validation_1-rmse:4.35460
# [5]	validation_0-rmse:4.24799	validation_1-rmse:3.88824
# [6]	validation_0-rmse:3.80520	validation_1-rmse:3.46467
# [7]	validation_0-rmse:3.42000	validation_1-rmse:3.10181
# [8]	validation_0-rmse:3.06185	validation_1-rmse:2.76108
# [9]	validation_0-rmse:2.76187	validation_1-rmse:2.48761
# [10]	validation_0-rmse:2.47992	validation_1-rmse:2.22637
# [11]	validation_0-rmse:2.25079	validation_1-rmse:2.02660
# [12]	validation_0-rmse:2.04284	validation_1-rmse:1.84253
# [13]	validation_0-rmse:1.85615	validation_1-rmse:1.67580
# [14]	validation_0-rmse:1.69500	validation_1-rmse:1.52913
# [15]	validation_0-rmse:1.55364	validation_1-rmse:1.41643
# [16]	validation_0-rmse:1.42973	validation_1-rmse:1.31518
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [17]	validation_0-rmse:1.32159	validation_1-rmse:1.23101
# [18]	validation_0-rmse:1.23254	validation_1-rmse:1.15073
# [19]	validation_0-rmse:1.15697	validation_1-rmse:1.07831
# [20]	validation_0-rmse:1.08930	validation_1-rmse:1.02638
# [21]	validation_0-rmse:1.02430	validation_1-rmse:0.98024
# [22]	validation_0-rmse:0.97170	validation_1-rmse:0.94350
# [23]	validation_0-rmse:0.93315	validation_1-rmse:0.92250
# [24]	validation_0-rmse:0.89743	validation_1-rmse:0.90486
# [25]	validation_0-rmse:0.86808	validation_1-rmse:0.88278
# [26]	validation_0-rmse:0.83918	validation_1-rmse:0.86899
# [27]	validation_0-rmse:0.81565	validation_1-rmse:0.85930
# [28]	validation_0-rmse:0.79600	validation_1-rmse:0.84088
# [29]	validation_0-rmse:0.77720	validation_1-rmse:0.83611
# [30]	validation_0-rmse:0.76063	validation_1-rmse:0.83264
# [31]	validation_0-rmse:0.74564	validation_1-rmse:0.82256
# [32]	validation_0-rmse:0.73400	validation_1-rmse:0.81075
# [33]	validation_0-rmse:0.72395	validation_1-rmse:0.80763
# [34]	validation_0-rmse:0.71319	validation_1-rmse:0.80017
# [35]	validation_0-rmse:0.70536	validation_1-rmse:0.79159
# [36]	validation_0-rmse:0.69462	validation_1-rmse:0.77973
# [37]	validation_0-rmse:0.68839	validation_1-rmse:0.77416
# [38]	validation_0-rmse:0.68415	validation_1-rmse:0.76993
# [39]	validation_0-rmse:0.67639	validation_1-rmse:0.75696
# [40]	validation_0-rmse:0.67068	validation_1-rmse:0.75675
# [41]	validation_0-rmse:0.66550	validation_1-rmse:0.75406
# [42]	validation_0-rmse:0.66080	validation_1-rmse:0.74913
# [43]	validation_0-rmse:0.65761	validation_1-rmse:0.75032
# [44]	validation_0-rmse:0.65581	validation_1-rmse:0.75280
# [45]	validation_0-rmse:0.65372	validation_1-rmse:0.75403
# [46]	validation_0-rmse:0.64362	validation_1-rmse:0.73995
# [47]	validation_0-rmse:0.63653	validation_1-rmse:0.73394
# [48]	validation_0-rmse:0.63437	validation_1-rmse:0.73804
# [49]	validation_0-rmse:0.62623	validation_1-rmse:0.72450
# [50]	validation_0-rmse:0.62395	validation_1-rmse:0.72237
# [51]	validation_0-rmse:0.62005	validation_1-rmse:0.71946
# [52]	validation_0-rmse:0.61815	validation_1-rmse:0.71493
# [53]	validation_0-rmse:0.61669	validation_1-rmse:0.71658
# [54]	validation_0-rmse:0.61400	validation_1-rmse:0.71656
# [55]	validation_0-rmse:0.60986	validation_1-rmse:0.70868
# [56]	validation_0-rmse:0.60400	validation_1-rmse:0.71103
# [57]	validation_0-rmse:0.60253	validation_1-rmse:0.70801
# [58]	validation_0-rmse:0.60115	validation_1-rmse:0.70442
# [59]	validation_0-rmse:0.59970	validation_1-rmse:0.70302
# [60]	validation_0-rmse:0.59654	validation_1-rmse:0.70680
# [61]	validation_0-rmse:0.59435	validation_1-rmse:0.70168
# [62]	validation_0-rmse:0.59042	validation_1-rmse:0.70235
# [63]	validation_0-rmse:0.58797	validation_1-rmse:0.70140
# [64]	validation_0-rmse:0.58541	validation_1-rmse:0.70253
# [65]	validation_0-rmse:0.58494	validation_1-rmse:0.70314
# [66]	validation_0-rmse:0.58204	validation_1-rmse:0.70278
# [67]	validation_0-rmse:0.57799	validation_1-rmse:0.69659
# [68]	validation_0-rmse:0.57603	validation_1-rmse:0.69074
# [69]	validation_0-rmse:0.57570	validation_1-rmse:0.69093
# [70]	validation_0-rmse:0.57450	validation_1-rmse:0.68854
# [71]	validation_0-rmse:0.57176	validation_1-rmse:0.68627
# [72]	validation_0-rmse:0.56849	validation_1-rmse:0.68216
# [73]	validation_0-rmse:0.56778	validation_1-rmse:0.68082
# [74]	validation_0-rmse:0.56609	validation_1-rmse:0.68141
# [75]	validation_0-rmse:0.56535	validation_1-rmse:0.68014
# [76]	validation_0-rmse:0.56484	validation_1-rmse:0.67800
# [77]	validation_0-rmse:0.56343	validation_1-rmse:0.67858
# [78]	validation_0-rmse:0.56230	validation_1-rmse:0.67510
# [79]	validation_0-rmse:0.56080	validation_1-rmse:0.67415
# [80]	validation_0-rmse:0.55870	validation_1-rmse:0.67165
# [81]	validation_0-rmse:0.55664	validation_1-rmse:0.67507
# [82]	validation_0-rmse:0.55103	validation_1-rmse:0.67672
# [83]	validation_0-rmse:0.54777	validation_1-rmse:0.67441
# [84]	validation_0-rmse:0.54721	validation_1-rmse:0.67364
# [85]	validation_0-rmse:0.54460	validation_1-rmse:0.67121
# [86]	validation_0-rmse:0.54255	validation_1-rmse:0.66929
# [87]	validation_0-rmse:0.54244	validation_1-rmse:0.66724
# [88]	validation_0-rmse:0.54182	validation_1-rmse:0.66379
# [89]	validation_0-rmse:0.53828	validation_1-rmse:0.66654
# [0]	validation_0-rmse:7.52489	validation_1-rmse:6.72864
# [1]	validation_0-rmse:6.70398	validation_1-rmse:5.95658
# [2]	validation_0-rmse:5.97958	validation_1-rmse:5.28434
# [3]	validation_0-rmse:5.33308	validation_1-rmse:4.67396
# [4]	validation_0-rmse:4.75783	validation_1-rmse:4.14200
# [5]	validation_0-rmse:4.24892	validation_1-rmse:3.66667
# [6]	validation_0-rmse:3.79623	validation_1-rmse:3.25538
# [7]	validation_0-rmse:3.40067	validation_1-rmse:2.88632
# [8]	validation_0-rmse:3.05253	validation_1-rmse:2.56507
# [9]	validation_0-rmse:2.73625	validation_1-rmse:2.28380
# [10]	validation_0-rmse:2.46924	validation_1-rmse:2.04988
# [11]	validation_0-rmse:2.23247	validation_1-rmse:1.83431
# [12]	validation_0-rmse:2.02189	validation_1-rmse:1.65021
# [13]	validation_0-rmse:1.83833	validation_1-rmse:1.51440
# [14]	validation_0-rmse:1.66895	validation_1-rmse:1.37270
# [15]	validation_0-rmse:1.52743	validation_1-rmse:1.25837
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [16]	validation_0-rmse:1.39849	validation_1-rmse:1.15339
# [17]	validation_0-rmse:1.29373	validation_1-rmse:1.08189
# [18]	validation_0-rmse:1.19920	validation_1-rmse:1.00868
# [19]	validation_0-rmse:1.12143	validation_1-rmse:0.96246
# [20]	validation_0-rmse:1.05354	validation_1-rmse:0.92281
# [21]	validation_0-rmse:0.99654	validation_1-rmse:0.88275
# [22]	validation_0-rmse:0.94481	validation_1-rmse:0.85849
# [23]	validation_0-rmse:0.90120	validation_1-rmse:0.83869
# [24]	validation_0-rmse:0.85873	validation_1-rmse:0.82388
# [25]	validation_0-rmse:0.82274	validation_1-rmse:0.81310
# [26]	validation_0-rmse:0.79605	validation_1-rmse:0.80581
# [27]	validation_0-rmse:0.77275	validation_1-rmse:0.80331
# [28]	validation_0-rmse:0.75590	validation_1-rmse:0.79516
# [29]	validation_0-rmse:0.73406	validation_1-rmse:0.78540
# [30]	validation_0-rmse:0.71295	validation_1-rmse:0.78708
# [31]	validation_0-rmse:0.70215	validation_1-rmse:0.78784
# [32]	validation_0-rmse:0.69330	validation_1-rmse:0.78405
# [33]	validation_0-rmse:0.68186	validation_1-rmse:0.78796
# [34]	validation_0-rmse:0.67563	validation_1-rmse:0.78623
# [35]	validation_0-rmse:0.66266	validation_1-rmse:0.79314
# [36]	validation_0-rmse:0.65306	validation_1-rmse:0.80259
# [37]	validation_0-rmse:0.64446	validation_1-rmse:0.80896
# [38]	validation_0-rmse:0.64002	validation_1-rmse:0.80872
# [39]	validation_0-rmse:0.62804	validation_1-rmse:0.79658
# [40]	validation_0-rmse:0.61635	validation_1-rmse:0.79236
# [41]	validation_0-rmse:0.61268	validation_1-rmse:0.79146
# [42]	validation_0-rmse:0.60961	validation_1-rmse:0.79418
# [43]	validation_0-rmse:0.60662	validation_1-rmse:0.79293
# [44]	validation_0-rmse:0.60413	validation_1-rmse:0.79230
# [45]	validation_0-rmse:0.59361	validation_1-rmse:0.79003
# [46]	validation_0-rmse:0.59158	validation_1-rmse:0.79209
# [47]	validation_0-rmse:0.58680	validation_1-rmse:0.79768
# [48]	validation_0-rmse:0.58501	validation_1-rmse:0.79688
# [49]	validation_0-rmse:0.58018	validation_1-rmse:0.80158
# [50]	validation_0-rmse:0.57705	validation_1-rmse:0.80805
# [51]	validation_0-rmse:0.57538	validation_1-rmse:0.80737
# [52]	validation_0-rmse:0.57440	validation_1-rmse:0.80429
# [0]	validation_0-rmse:7.37479	validation_1-rmse:7.47200
# [1]	validation_0-rmse:6.57972	validation_1-rmse:6.67888
# [2]	validation_0-rmse:5.85773	validation_1-rmse:5.95813
# [3]	validation_0-rmse:5.22822	validation_1-rmse:5.33356
# [4]	validation_0-rmse:4.66430	validation_1-rmse:4.74850
# [5]	validation_0-rmse:4.17423	validation_1-rmse:4.24162
# [6]	validation_0-rmse:3.73498	validation_1-rmse:3.78653
# [7]	validation_0-rmse:3.35112	validation_1-rmse:3.40086
# [8]	validation_0-rmse:3.00223	validation_1-rmse:3.03533
# [9]	validation_0-rmse:2.69830	validation_1-rmse:2.72882
# [10]	validation_0-rmse:2.43335	validation_1-rmse:2.44632
# [11]	validation_0-rmse:2.20285	validation_1-rmse:2.20452
# [12]	validation_0-rmse:1.99639	validation_1-rmse:1.99856
# [13]	validation_0-rmse:1.80728	validation_1-rmse:1.79293
# [14]	validation_0-rmse:1.65024	validation_1-rmse:1.62963
# [15]	validation_0-rmse:1.50621	validation_1-rmse:1.48579
# [16]	validation_0-rmse:1.39721	validation_1-rmse:1.37179
# [17]	validation_0-rmse:1.29498	validation_1-rmse:1.27710
# [18]	validation_0-rmse:1.20366	validation_1-rmse:1.18798
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [19]	validation_0-rmse:1.13154	validation_1-rmse:1.11849
# [20]	validation_0-rmse:1.06519	validation_1-rmse:1.05905
# [21]	validation_0-rmse:1.00276	validation_1-rmse:0.99373
# [22]	validation_0-rmse:0.95277	validation_1-rmse:0.95040
# [23]	validation_0-rmse:0.90951	validation_1-rmse:0.91602
# [24]	validation_0-rmse:0.87514	validation_1-rmse:0.88698
# [25]	validation_0-rmse:0.84386	validation_1-rmse:0.85927
# [26]	validation_0-rmse:0.81349	validation_1-rmse:0.82733
# [27]	validation_0-rmse:0.79130	validation_1-rmse:0.81275
# [28]	validation_0-rmse:0.77250	validation_1-rmse:0.79912
# [29]	validation_0-rmse:0.75380	validation_1-rmse:0.78103
# [30]	validation_0-rmse:0.73979	validation_1-rmse:0.76898
# [31]	validation_0-rmse:0.72371	validation_1-rmse:0.75667
# [32]	validation_0-rmse:0.71446	validation_1-rmse:0.74950
# [33]	validation_0-rmse:0.69708	validation_1-rmse:0.73447
# [34]	validation_0-rmse:0.69065	validation_1-rmse:0.73395
# [35]	validation_0-rmse:0.68363	validation_1-rmse:0.73314
# [36]	validation_0-rmse:0.67678	validation_1-rmse:0.72695
# [37]	validation_0-rmse:0.67282	validation_1-rmse:0.72252
# [38]	validation_0-rmse:0.66780	validation_1-rmse:0.72038
# [39]	validation_0-rmse:0.66363	validation_1-rmse:0.71734
# [40]	validation_0-rmse:0.65962	validation_1-rmse:0.71753
# [41]	validation_0-rmse:0.65699	validation_1-rmse:0.71529
# [42]	validation_0-rmse:0.65356	validation_1-rmse:0.71451
# [43]	validation_0-rmse:0.64938	validation_1-rmse:0.71236
# [44]	validation_0-rmse:0.64773	validation_1-rmse:0.71408
# [45]	validation_0-rmse:0.63792	validation_1-rmse:0.70675
# [46]	validation_0-rmse:0.63576	validation_1-rmse:0.70730
# [47]	validation_0-rmse:0.63346	validation_1-rmse:0.70632
# [48]	validation_0-rmse:0.63191	validation_1-rmse:0.70398
# [49]	validation_0-rmse:0.63001	validation_1-rmse:0.70263
# [50]	validation_0-rmse:0.62583	validation_1-rmse:0.70238
# [51]	validation_0-rmse:0.62502	validation_1-rmse:0.70299
# [52]	validation_0-rmse:0.61792	validation_1-rmse:0.69837
# [53]	validation_0-rmse:0.61496	validation_1-rmse:0.70193
# [54]	validation_0-rmse:0.61073	validation_1-rmse:0.69797
# [55]	validation_0-rmse:0.60941	validation_1-rmse:0.69752
# [56]	validation_0-rmse:0.60307	validation_1-rmse:0.69576
# [57]	validation_0-rmse:0.59931	validation_1-rmse:0.69628
# [58]	validation_0-rmse:0.59803	validation_1-rmse:0.69605
# [59]	validation_0-rmse:0.59542	validation_1-rmse:0.70070
# [60]	validation_0-rmse:0.59164	validation_1-rmse:0.69956
# [61]	validation_0-rmse:0.58883	validation_1-rmse:0.70028
# [62]	validation_0-rmse:0.58678	validation_1-rmse:0.69702
# [63]	validation_0-rmse:0.58580	validation_1-rmse:0.69800
# [64]	validation_0-rmse:0.58299	validation_1-rmse:0.69768
# [65]	validation_0-rmse:0.58087	validation_1-rmse:0.69577
# [66]	validation_0-rmse:0.57814	validation_1-rmse:0.69742
# [67]	validation_0-rmse:0.57316	validation_1-rmse:0.69486
# [68]	validation_0-rmse:0.57281	validation_1-rmse:0.69454
# [69]	validation_0-rmse:0.56842	validation_1-rmse:0.68230
# [70]	validation_0-rmse:0.56523	validation_1-rmse:0.68187
# [71]	validation_0-rmse:0.56277	validation_1-rmse:0.67967
# [72]	validation_0-rmse:0.56052	validation_1-rmse:0.68084
# [73]	validation_0-rmse:0.55953	validation_1-rmse:0.68096
# [74]	validation_0-rmse:0.55887	validation_1-rmse:0.68458
# [75]	validation_0-rmse:0.55791	validation_1-rmse:0.68628
# [76]	validation_0-rmse:0.55527	validation_1-rmse:0.68937
# [77]	validation_0-rmse:0.55460	validation_1-rmse:0.68990
# [78]	validation_0-rmse:0.55282	validation_1-rmse:0.68605
# [79]	validation_0-rmse:0.55192	validation_1-rmse:0.68747
# [80]	validation_0-rmse:0.55104	validation_1-rmse:0.68700
# [81]	validation_0-rmse:0.54931	validation_1-rmse:0.68384
# [82]	validation_0-rmse:0.54636	validation_1-rmse:0.68248
# [83]	validation_0-rmse:0.54339	validation_1-rmse:0.68142
# [84]	validation_0-rmse:0.54163	validation_1-rmse:0.68199
# [85]	validation_0-rmse:0.54076	validation_1-rmse:0.68400
# [86]	validation_0-rmse:0.53905	validation_1-rmse:0.68765
# [87]	validation_0-rmse:0.53851	validation_1-rmse:0.68704
# [88]	validation_0-rmse:0.53529	validation_1-rmse:0.68749
# [89]	validation_0-rmse:0.53248	validation_1-rmse:0.68722
# [0]	validation_0-rmse:7.39596	validation_1-rmse:7.38940
# [1]	validation_0-rmse:6.59838	validation_1-rmse:6.60987
# [2]	validation_0-rmse:5.87699	validation_1-rmse:5.89013
# [3]	validation_0-rmse:5.24540	validation_1-rmse:5.27704
# [4]	validation_0-rmse:4.68533	validation_1-rmse:4.71101
# [5]	validation_0-rmse:4.19914	validation_1-rmse:4.22066
# [6]	validation_0-rmse:3.75194	validation_1-rmse:3.78188
# [7]	validation_0-rmse:3.35663	validation_1-rmse:3.38021
# [8]	validation_0-rmse:3.01166	validation_1-rmse:3.02861
# [9]	validation_0-rmse:2.72438	validation_1-rmse:2.73731
# [10]	validation_0-rmse:2.46044	validation_1-rmse:2.47206
# [11]	validation_0-rmse:2.22420	validation_1-rmse:2.22556
# [12]	validation_0-rmse:2.02153	validation_1-rmse:2.01429
# [13]	validation_0-rmse:1.84748	validation_1-rmse:1.83376
# [14]	validation_0-rmse:1.69250	validation_1-rmse:1.67298
# [15]	validation_0-rmse:1.55041	validation_1-rmse:1.52315
# [16]	validation_0-rmse:1.42871	validation_1-rmse:1.40151
# [17]	validation_0-rmse:1.32787	validation_1-rmse:1.29890
# [18]	validation_0-rmse:1.23466	validation_1-rmse:1.21081
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [19]	validation_0-rmse:1.15597	validation_1-rmse:1.12888
# [20]	validation_0-rmse:1.08638	validation_1-rmse:1.06432
# [21]	validation_0-rmse:1.02656	validation_1-rmse:1.00969
# [22]	validation_0-rmse:0.97339	validation_1-rmse:0.96124
# [23]	validation_0-rmse:0.92664	validation_1-rmse:0.91916
# [24]	validation_0-rmse:0.89005	validation_1-rmse:0.88463
# [25]	validation_0-rmse:0.84947	validation_1-rmse:0.85920
# [26]	validation_0-rmse:0.82597	validation_1-rmse:0.84435
# [27]	validation_0-rmse:0.80388	validation_1-rmse:0.81626
# [28]	validation_0-rmse:0.78447	validation_1-rmse:0.80077
# [29]	validation_0-rmse:0.76913	validation_1-rmse:0.78796
# [30]	validation_0-rmse:0.75722	validation_1-rmse:0.78334
# [31]	validation_0-rmse:0.73995	validation_1-rmse:0.77623
# [32]	validation_0-rmse:0.73021	validation_1-rmse:0.76919
# [33]	validation_0-rmse:0.71887	validation_1-rmse:0.76421
# [34]	validation_0-rmse:0.70596	validation_1-rmse:0.75746
# [35]	validation_0-rmse:0.69448	validation_1-rmse:0.75152
# [36]	validation_0-rmse:0.68870	validation_1-rmse:0.74732
# [37]	validation_0-rmse:0.68353	validation_1-rmse:0.74760
# [38]	validation_0-rmse:0.67944	validation_1-rmse:0.74722
# [39]	validation_0-rmse:0.67505	validation_1-rmse:0.74148
# [40]	validation_0-rmse:0.67043	validation_1-rmse:0.73847
# [41]	validation_0-rmse:0.66712	validation_1-rmse:0.73183
# [42]	validation_0-rmse:0.66483	validation_1-rmse:0.73390
# [43]	validation_0-rmse:0.66029	validation_1-rmse:0.72872
# [44]	validation_0-rmse:0.65848	validation_1-rmse:0.73155
# [45]	validation_0-rmse:0.65175	validation_1-rmse:0.71914
# [46]	validation_0-rmse:0.64581	validation_1-rmse:0.71413
# [47]	validation_0-rmse:0.64267	validation_1-rmse:0.71145
# [48]	validation_0-rmse:0.64039	validation_1-rmse:0.71034
# [49]	validation_0-rmse:0.63390	validation_1-rmse:0.71038
# [50]	validation_0-rmse:0.62876	validation_1-rmse:0.70020
# [51]	validation_0-rmse:0.62513	validation_1-rmse:0.70864
# [52]	validation_0-rmse:0.62117	validation_1-rmse:0.70548
# [53]	validation_0-rmse:0.61612	validation_1-rmse:0.69943
# [54]	validation_0-rmse:0.61213	validation_1-rmse:0.70077
# [55]	validation_0-rmse:0.60863	validation_1-rmse:0.69471
# [56]	validation_0-rmse:0.60700	validation_1-rmse:0.69592
# [57]	validation_0-rmse:0.60483	validation_1-rmse:0.69374
# [58]	validation_0-rmse:0.60254	validation_1-rmse:0.69484
# [59]	validation_0-rmse:0.60242	validation_1-rmse:0.69358
# [60]	validation_0-rmse:0.59861	validation_1-rmse:0.69912
# [61]	validation_0-rmse:0.59769	validation_1-rmse:0.69876
# [62]	validation_0-rmse:0.59682	validation_1-rmse:0.70060
# [63]	validation_0-rmse:0.59419	validation_1-rmse:0.70624
# [64]	validation_0-rmse:0.58993	validation_1-rmse:0.70188
# [65]	validation_0-rmse:0.58746	validation_1-rmse:0.70914
# [66]	validation_0-rmse:0.58423	validation_1-rmse:0.71438
# [67]	validation_0-rmse:0.58185	validation_1-rmse:0.71229
# [68]	validation_0-rmse:0.58089	validation_1-rmse:0.71689
# [69]	validation_0-rmse:0.57754	validation_1-rmse:0.71330
# [70]	validation_0-rmse:0.57671	validation_1-rmse:0.71475
# [71]	validation_0-rmse:0.57302	validation_1-rmse:0.70832
# [72]	validation_0-rmse:0.57023	validation_1-rmse:0.70884
# [73]	validation_0-rmse:0.56863	validation_1-rmse:0.71387
# [74]	validation_0-rmse:0.56671	validation_1-rmse:0.71796
# [75]	validation_0-rmse:0.56492	validation_1-rmse:0.71772
# [76]	validation_0-rmse:0.56266	validation_1-rmse:0.72050
# [77]	validation_0-rmse:0.56014	validation_1-rmse:0.71597
# [78]	validation_0-rmse:0.55788	validation_1-rmse:0.71451
# [0]	validation_0-rmse:7.39419	validation_1-rmse:7.31066
# [1]	validation_0-rmse:6.59126	validation_1-rmse:6.52859
# [2]	validation_0-rmse:5.87139	validation_1-rmse:5.84604
# [3]	validation_0-rmse:5.22188	validation_1-rmse:5.21454
# [4]	validation_0-rmse:4.66537	validation_1-rmse:4.69059
# [5]	validation_0-rmse:4.17517	validation_1-rmse:4.21310
# [6]	validation_0-rmse:3.73648	validation_1-rmse:3.80280
# [7]	validation_0-rmse:3.33990	validation_1-rmse:3.41508
# [8]	validation_0-rmse:2.99632	validation_1-rmse:3.09979
# [9]	validation_0-rmse:2.69053	validation_1-rmse:2.82148
# [10]	validation_0-rmse:2.42189	validation_1-rmse:2.57919
# [11]	validation_0-rmse:2.18152	validation_1-rmse:2.36283
# [12]	validation_0-rmse:1.96785	validation_1-rmse:2.18476
# [13]	validation_0-rmse:1.78639	validation_1-rmse:2.02154
# [14]	validation_0-rmse:1.62764	validation_1-rmse:1.88033
# [15]	validation_0-rmse:1.48838	validation_1-rmse:1.75869
# [16]	validation_0-rmse:1.36676	validation_1-rmse:1.66085
# [17]	validation_0-rmse:1.26179	validation_1-rmse:1.56461
# [18]	validation_0-rmse:1.16974	validation_1-rmse:1.48719
# [19]	validation_0-rmse:1.08197	validation_1-rmse:1.41350
# [20]	validation_0-rmse:1.01165	validation_1-rmse:1.35048
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [21]	validation_0-rmse:0.95213	validation_1-rmse:1.29266
# [22]	validation_0-rmse:0.90590	validation_1-rmse:1.25471
# [23]	validation_0-rmse:0.86125	validation_1-rmse:1.21379
# [24]	validation_0-rmse:0.82618	validation_1-rmse:1.17224
# [25]	validation_0-rmse:0.78989	validation_1-rmse:1.13235
# [26]	validation_0-rmse:0.76490	validation_1-rmse:1.10776
# [27]	validation_0-rmse:0.73773	validation_1-rmse:1.07558
# [28]	validation_0-rmse:0.72347	validation_1-rmse:1.05299
# [29]	validation_0-rmse:0.70440	validation_1-rmse:1.03849
# [30]	validation_0-rmse:0.69176	validation_1-rmse:1.02287
# [31]	validation_0-rmse:0.68082	validation_1-rmse:1.01127
# [32]	validation_0-rmse:0.66563	validation_1-rmse:0.99279
# [33]	validation_0-rmse:0.65700	validation_1-rmse:0.97757
# [34]	validation_0-rmse:0.64843	validation_1-rmse:0.97348
# [35]	validation_0-rmse:0.64289	validation_1-rmse:0.96176
# [36]	validation_0-rmse:0.63339	validation_1-rmse:0.95375
# [37]	validation_0-rmse:0.63041	validation_1-rmse:0.94596
# [38]	validation_0-rmse:0.62490	validation_1-rmse:0.94047
# [39]	validation_0-rmse:0.62112	validation_1-rmse:0.93280
# [40]	validation_0-rmse:0.61801	validation_1-rmse:0.92231
# [41]	validation_0-rmse:0.61461	validation_1-rmse:0.91975
# [42]	validation_0-rmse:0.60807	validation_1-rmse:0.91815
# [43]	validation_0-rmse:0.60648	validation_1-rmse:0.91305
# [44]	validation_0-rmse:0.60006	validation_1-rmse:0.91096
# [45]	validation_0-rmse:0.59857	validation_1-rmse:0.90549
# [46]	validation_0-rmse:0.59672	validation_1-rmse:0.90014
# [47]	validation_0-rmse:0.59171	validation_1-rmse:0.89794
# [48]	validation_0-rmse:0.59062	validation_1-rmse:0.89415
# [49]	validation_0-rmse:0.58991	validation_1-rmse:0.89091
# [50]	validation_0-rmse:0.58576	validation_1-rmse:0.89162
# [51]	validation_0-rmse:0.58366	validation_1-rmse:0.89121
# [52]	validation_0-rmse:0.58236	validation_1-rmse:0.88682
# [53]	validation_0-rmse:0.57955	validation_1-rmse:0.89036
# [54]	validation_0-rmse:0.57851	validation_1-rmse:0.88590
# [55]	validation_0-rmse:0.57405	validation_1-rmse:0.88700
# [56]	validation_0-rmse:0.57309	validation_1-rmse:0.88441
# [57]	validation_0-rmse:0.57147	validation_1-rmse:0.88300
# [58]	validation_0-rmse:0.56793	validation_1-rmse:0.88018
# [59]	validation_0-rmse:0.56647	validation_1-rmse:0.87877
# [60]	validation_0-rmse:0.56175	validation_1-rmse:0.88211
# [61]	validation_0-rmse:0.55727	validation_1-rmse:0.87869
# [62]	validation_0-rmse:0.55664	validation_1-rmse:0.87504
# [63]	validation_0-rmse:0.55326	validation_1-rmse:0.86844
# [64]	validation_0-rmse:0.54991	validation_1-rmse:0.87310
# [65]	validation_0-rmse:0.54795	validation_1-rmse:0.87435
# [66]	validation_0-rmse:0.54733	validation_1-rmse:0.87333
# [67]	validation_0-rmse:0.54390	validation_1-rmse:0.87441
# [68]	validation_0-rmse:0.54227	validation_1-rmse:0.87767
# [69]	validation_0-rmse:0.53975	validation_1-rmse:0.88300
# [70]	validation_0-rmse:0.53706	validation_1-rmse:0.87768
# [71]	validation_0-rmse:0.53532	validation_1-rmse:0.88180
# [72]	validation_0-rmse:0.53033	validation_1-rmse:0.88039
# [73]	validation_0-rmse:0.52783	validation_1-rmse:0.87367
# [74]	validation_0-rmse:0.52728	validation_1-rmse:0.87731
# [75]	validation_0-rmse:0.52482	validation_1-rmse:0.87988
# [76]	validation_0-rmse:0.52303	validation_1-rmse:0.88253
# [77]	validation_0-rmse:0.52091	validation_1-rmse:0.88297
# [78]	validation_0-rmse:0.52026	validation_1-rmse:0.88020
# [79]	validation_0-rmse:0.51848	validation_1-rmse:0.88162
# [80]	validation_0-rmse:0.51708	validation_1-rmse:0.87520
# [81]	validation_0-rmse:0.51533	validation_1-rmse:0.87426
# [82]	validation_0-rmse:0.51266	validation_1-rmse:0.87463
# [0]	validation_0-rmse:7.39408	validation_1-rmse:7.34623
# [1]	validation_0-rmse:6.59506	validation_1-rmse:6.53616
# [2]	validation_0-rmse:5.89075	validation_1-rmse:5.83000
# [3]	validation_0-rmse:5.25345	validation_1-rmse:5.19544
# [4]	validation_0-rmse:4.69935	validation_1-rmse:4.65277
# [5]	validation_0-rmse:4.19966	validation_1-rmse:4.14327
# [6]	validation_0-rmse:3.76579	validation_1-rmse:3.70134
# [7]	validation_0-rmse:3.38065	validation_1-rmse:3.30457
# [8]	validation_0-rmse:3.03239	validation_1-rmse:2.95672
# [9]	validation_0-rmse:2.72856	validation_1-rmse:2.65410
# [10]	validation_0-rmse:2.46386	validation_1-rmse:2.39122
# [11]	validation_0-rmse:2.22364	validation_1-rmse:2.15462
# [12]	validation_0-rmse:2.00937	validation_1-rmse:1.95660
# [13]	validation_0-rmse:1.81941	validation_1-rmse:1.77856
# [14]	validation_0-rmse:1.64923	validation_1-rmse:1.61789
# [15]	validation_0-rmse:1.50330	validation_1-rmse:1.48706
# [16]	validation_0-rmse:1.38203	validation_1-rmse:1.37725
# [17]	validation_0-rmse:1.27671	validation_1-rmse:1.27903
# [18]	validation_0-rmse:1.18743	validation_1-rmse:1.20263
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [19]	validation_0-rmse:1.11112	validation_1-rmse:1.13780
# [20]	validation_0-rmse:1.04636	validation_1-rmse:1.08727
# [21]	validation_0-rmse:0.99076	validation_1-rmse:1.03866
# [22]	validation_0-rmse:0.93236	validation_1-rmse:0.98961
# [23]	validation_0-rmse:0.89595	validation_1-rmse:0.96407
# [24]	validation_0-rmse:0.86364	validation_1-rmse:0.94138
# [25]	validation_0-rmse:0.83419	validation_1-rmse:0.92092
# [26]	validation_0-rmse:0.80627	validation_1-rmse:0.90266
# [27]	validation_0-rmse:0.77767	validation_1-rmse:0.87773
# [28]	validation_0-rmse:0.76147	validation_1-rmse:0.86832
# [29]	validation_0-rmse:0.74652	validation_1-rmse:0.86287
# [30]	validation_0-rmse:0.73447	validation_1-rmse:0.85905
# [31]	validation_0-rmse:0.72308	validation_1-rmse:0.85361
# [32]	validation_0-rmse:0.70920	validation_1-rmse:0.83927
# [33]	validation_0-rmse:0.69056	validation_1-rmse:0.82943
# [34]	validation_0-rmse:0.67920	validation_1-rmse:0.82710
# [35]	validation_0-rmse:0.67363	validation_1-rmse:0.82573
# [36]	validation_0-rmse:0.65842	validation_1-rmse:0.83093
# [37]	validation_0-rmse:0.65049	validation_1-rmse:0.82059
# [38]	validation_0-rmse:0.63955	validation_1-rmse:0.81902
# [39]	validation_0-rmse:0.63061	validation_1-rmse:0.82590
# [40]	validation_0-rmse:0.62161	validation_1-rmse:0.83141
# [41]	validation_0-rmse:0.61438	validation_1-rmse:0.83686
# [42]	validation_0-rmse:0.61138	validation_1-rmse:0.83610
# [43]	validation_0-rmse:0.60246	validation_1-rmse:0.83711
# [44]	validation_0-rmse:0.59683	validation_1-rmse:0.84096
# [45]	validation_0-rmse:0.59421	validation_1-rmse:0.84069
# [46]	validation_0-rmse:0.58862	validation_1-rmse:0.84773
# [47]	validation_0-rmse:0.58343	validation_1-rmse:0.85535
# [48]	validation_0-rmse:0.58142	validation_1-rmse:0.85270
# [49]	validation_0-rmse:0.58002	validation_1-rmse:0.85670
# [50]	validation_0-rmse:0.57369	validation_1-rmse:0.85396
# [51]	validation_0-rmse:0.57198	validation_1-rmse:0.85388
# [52]	validation_0-rmse:0.56714	validation_1-rmse:0.85520
# [53]	validation_0-rmse:0.56321	validation_1-rmse:0.86005
# [54]	validation_0-rmse:0.55912	validation_1-rmse:0.86200
# [55]	validation_0-rmse:0.55607	validation_1-rmse:0.86512
# [56]	validation_0-rmse:0.55440	validation_1-rmse:0.86155
# [57]	validation_0-rmse:0.55338	validation_1-rmse:0.85859
# [58]	validation_0-rmse:0.55180	validation_1-rmse:0.86186
# [0]	validation_0-rmse:7.43080	validation_1-rmse:7.17158
# [1]	validation_0-rmse:6.61012	validation_1-rmse:6.39603
# [2]	validation_0-rmse:5.89989	validation_1-rmse:5.72680
# [3]	validation_0-rmse:5.26265	validation_1-rmse:5.11439
# [4]	validation_0-rmse:4.70157	validation_1-rmse:4.58731
# [5]	validation_0-rmse:4.20784	validation_1-rmse:4.11808
# [6]	validation_0-rmse:3.76707	validation_1-rmse:3.70611
# [7]	validation_0-rmse:3.37531	validation_1-rmse:3.34551
# [8]	validation_0-rmse:3.03618	validation_1-rmse:3.02547
# [9]	validation_0-rmse:2.72946	validation_1-rmse:2.74208
# [10]	validation_0-rmse:2.45386	validation_1-rmse:2.48437
# [11]	validation_0-rmse:2.22621	validation_1-rmse:2.28639
# [12]	validation_0-rmse:2.01721	validation_1-rmse:2.09480
# [13]	validation_0-rmse:1.83401	validation_1-rmse:1.92622
# [14]	validation_0-rmse:1.66521	validation_1-rmse:1.77925
# [15]	validation_0-rmse:1.52474	validation_1-rmse:1.65830
# [16]	validation_0-rmse:1.40333	validation_1-rmse:1.55316
# [17]	validation_0-rmse:1.29239	validation_1-rmse:1.44842
# [18]	validation_0-rmse:1.19567	validation_1-rmse:1.36625
# [19]	validation_0-rmse:1.11761	validation_1-rmse:1.29913
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [20]	validation_0-rmse:1.05103	validation_1-rmse:1.23408
# [21]	validation_0-rmse:0.98963	validation_1-rmse:1.17638
# [22]	validation_0-rmse:0.93443	validation_1-rmse:1.12775
# [23]	validation_0-rmse:0.89677	validation_1-rmse:1.09079
# [24]	validation_0-rmse:0.85979	validation_1-rmse:1.05000
# [25]	validation_0-rmse:0.83125	validation_1-rmse:1.01965
# [26]	validation_0-rmse:0.80623	validation_1-rmse:0.99100
# [27]	validation_0-rmse:0.78118	validation_1-rmse:0.95687
# [28]	validation_0-rmse:0.76151	validation_1-rmse:0.94649
# [29]	validation_0-rmse:0.74562	validation_1-rmse:0.93966
# [30]	validation_0-rmse:0.72487	validation_1-rmse:0.91483
# [31]	validation_0-rmse:0.71345	validation_1-rmse:0.89938
# [32]	validation_0-rmse:0.70292	validation_1-rmse:0.88976
# [33]	validation_0-rmse:0.69045	validation_1-rmse:0.88052
# [34]	validation_0-rmse:0.67708	validation_1-rmse:0.86955
# [35]	validation_0-rmse:0.66804	validation_1-rmse:0.85654
# [36]	validation_0-rmse:0.66272	validation_1-rmse:0.85194
# [37]	validation_0-rmse:0.65598	validation_1-rmse:0.85294
# [38]	validation_0-rmse:0.65086	validation_1-rmse:0.84630
# [39]	validation_0-rmse:0.64582	validation_1-rmse:0.83879
# [40]	validation_0-rmse:0.64091	validation_1-rmse:0.83530
# [41]	validation_0-rmse:0.63746	validation_1-rmse:0.83159
# [42]	validation_0-rmse:0.62730	validation_1-rmse:0.82673
# [43]	validation_0-rmse:0.62449	validation_1-rmse:0.82841
# [44]	validation_0-rmse:0.61730	validation_1-rmse:0.81886
# [45]	validation_0-rmse:0.61234	validation_1-rmse:0.82006
# [46]	validation_0-rmse:0.60988	validation_1-rmse:0.81957
# [47]	validation_0-rmse:0.60693	validation_1-rmse:0.81819
# [48]	validation_0-rmse:0.60456	validation_1-rmse:0.81755
# [49]	validation_0-rmse:0.59837	validation_1-rmse:0.81790
# [50]	validation_0-rmse:0.59047	validation_1-rmse:0.81527
# [51]	validation_0-rmse:0.58869	validation_1-rmse:0.81644
# [52]	validation_0-rmse:0.58640	validation_1-rmse:0.81415
# [53]	validation_0-rmse:0.58300	validation_1-rmse:0.81418
# [54]	validation_0-rmse:0.58152	validation_1-rmse:0.81094
# [55]	validation_0-rmse:0.58011	validation_1-rmse:0.81219
# [56]	validation_0-rmse:0.57806	validation_1-rmse:0.81585
# [57]	validation_0-rmse:0.57605	validation_1-rmse:0.81192
# [58]	validation_0-rmse:0.57251	validation_1-rmse:0.81318
# [59]	validation_0-rmse:0.57244	validation_1-rmse:0.81378
# [60]	validation_0-rmse:0.56840	validation_1-rmse:0.81095
# [61]	validation_0-rmse:0.56706	validation_1-rmse:0.80935
# [62]	validation_0-rmse:0.56439	validation_1-rmse:0.80878
# [63]	validation_0-rmse:0.56310	validation_1-rmse:0.81038
# [64]	validation_0-rmse:0.55744	validation_1-rmse:0.81056
# [65]	validation_0-rmse:0.55438	validation_1-rmse:0.81629
# [66]	validation_0-rmse:0.55023	validation_1-rmse:0.81469
# [67]	validation_0-rmse:0.54903	validation_1-rmse:0.81330
# [68]	validation_0-rmse:0.54847	validation_1-rmse:0.81551
# [69]	validation_0-rmse:0.54688	validation_1-rmse:0.82251
# [70]	validation_0-rmse:0.54583	validation_1-rmse:0.82087
# [71]	validation_0-rmse:0.54357	validation_1-rmse:0.82461
# [72]	validation_0-rmse:0.54218	validation_1-rmse:0.82504
# [73]	validation_0-rmse:0.53786	validation_1-rmse:0.82531
# [74]	validation_0-rmse:0.53542	validation_1-rmse:0.82123
# [75]	validation_0-rmse:0.53251	validation_1-rmse:0.82275
# [76]	validation_0-rmse:0.53074	validation_1-rmse:0.82363
# [77]	validation_0-rmse:0.52776	validation_1-rmse:0.82709
# [78]	validation_0-rmse:0.52550	validation_1-rmse:0.83035
# [79]	validation_0-rmse:0.52362	validation_1-rmse:0.83096
# [80]	validation_0-rmse:0.52298	validation_1-rmse:0.82995
# [81]	validation_0-rmse:0.52222	validation_1-rmse:0.83064
# [0]	validation_0-rmse:7.28394	validation_1-rmse:7.76631
# [1]	validation_0-rmse:6.50230	validation_1-rmse:6.99503
# [2]	validation_0-rmse:5.80185	validation_1-rmse:6.27938
# [3]	validation_0-rmse:5.17887	validation_1-rmse:5.64516
# [4]	validation_0-rmse:4.63654	validation_1-rmse:5.09385
# [5]	validation_0-rmse:4.14488	validation_1-rmse:4.59081
# [6]	validation_0-rmse:3.72152	validation_1-rmse:4.16212
# [7]	validation_0-rmse:3.33601	validation_1-rmse:3.76986
# [8]	validation_0-rmse:2.99277	validation_1-rmse:3.38667
# [9]	validation_0-rmse:2.68667	validation_1-rmse:3.05872
# [10]	validation_0-rmse:2.42149	validation_1-rmse:2.77224
# [11]	validation_0-rmse:2.19075	validation_1-rmse:2.55038
# [12]	validation_0-rmse:1.97921	validation_1-rmse:2.31808
# [13]	validation_0-rmse:1.79841	validation_1-rmse:2.10973
# [14]	validation_0-rmse:1.64386	validation_1-rmse:1.94707
# [15]	validation_0-rmse:1.51012	validation_1-rmse:1.81544
# [16]	validation_0-rmse:1.38852	validation_1-rmse:1.69030
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [17]	validation_0-rmse:1.28776	validation_1-rmse:1.57256
# ...
# [13]	validation_0-rmse:1.78701	validation_1-rmse:2.11493
# [14]	validation_0-rmse:1.62638	validation_1-rmse:1.95371
# [15]	validation_0-rmse:1.47922	validation_1-rmse:1.80135
# [16]	validation_0-rmse:1.35924	validation_1-rmse:1.68471
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [17]	validation_0-rmse:1.25338	validation_1-rmse:1.58252
# [18]	validation_0-rmse:1.15995	validation_1-rmse:1.48459
# [19]	validation_0-rmse:1.08660	validation_1-rmse:1.41562
# [20]	validation_0-rmse:1.01768	validation_1-rmse:1.34588
# [21]	validation_0-rmse:0.96237	validation_1-rmse:1.29059
# [22]	validation_0-rmse:0.91072	validation_1-rmse:1.23732
# [23]	validation_0-rmse:0.87198	validation_1-rmse:1.19501
# [24]	validation_0-rmse:0.82778	validation_1-rmse:1.14728
# [25]	validation_0-rmse:0.80117	validation_1-rmse:1.11754
# [26]	validation_0-rmse:0.77571	validation_1-rmse:1.08619
# [27]	validation_0-rmse:0.75678	validation_1-rmse:1.06442
# [28]	validation_0-rmse:0.74255	validation_1-rmse:1.04724
# [29]	validation_0-rmse:0.72544	validation_1-rmse:1.04226
# [30]	validation_0-rmse:0.71215	validation_1-rmse:1.02512
# [31]	validation_0-rmse:0.70040	validation_1-rmse:1.01063
# [32]	validation_0-rmse:0.69104	validation_1-rmse:0.99882
# [33]	validation_0-rmse:0.67547	validation_1-rmse:0.98633
# [34]	validation_0-rmse:0.66209	validation_1-rmse:0.98075
# [35]	validation_0-rmse:0.65055	validation_1-rmse:0.97570
# [36]	validation_0-rmse:0.64173	validation_1-rmse:0.96586
# [37]	validation_0-rmse:0.63072	validation_1-rmse:0.95737
# [38]	validation_0-rmse:0.62231	validation_1-rmse:0.95168
# [39]	validation_0-rmse:0.61790	validation_1-rmse:0.94578
# [40]	validation_0-rmse:0.60982	validation_1-rmse:0.94272
# [41]	validation_0-rmse:0.60685	validation_1-rmse:0.93635
# [42]	validation_0-rmse:0.60395	validation_1-rmse:0.93364
# [43]	validation_0-rmse:0.60191	validation_1-rmse:0.93291
# [44]	validation_0-rmse:0.60019	validation_1-rmse:0.92505
# [45]	validation_0-rmse:0.59904	validation_1-rmse:0.92785
# [46]	validation_0-rmse:0.59739	validation_1-rmse:0.92081
# [47]	validation_0-rmse:0.59399	validation_1-rmse:0.91604
# [48]	validation_0-rmse:0.59269	validation_1-rmse:0.91027
# [49]	validation_0-rmse:0.59114	validation_1-rmse:0.91084
# [50]	validation_0-rmse:0.58709	validation_1-rmse:0.91018
# [51]	validation_0-rmse:0.58570	validation_1-rmse:0.90839
# [52]	validation_0-rmse:0.58148	validation_1-rmse:0.90528
# [53]	validation_0-rmse:0.58015	validation_1-rmse:0.90691
# [54]	validation_0-rmse:0.57772	validation_1-rmse:0.89673
# [55]	validation_0-rmse:0.57677	validation_1-rmse:0.89690
# [56]	validation_0-rmse:0.57531	validation_1-rmse:0.89231
# [57]	validation_0-rmse:0.57123	validation_1-rmse:0.89077
# [58]	validation_0-rmse:0.56701	validation_1-rmse:0.88972
# [59]	validation_0-rmse:0.56475	validation_1-rmse:0.88943
# [60]	validation_0-rmse:0.56103	validation_1-rmse:0.88838
# [61]	validation_0-rmse:0.56005	validation_1-rmse:0.88315
# [62]	validation_0-rmse:0.55787	validation_1-rmse:0.88864
# [63]	validation_0-rmse:0.55469	validation_1-rmse:0.88744
# [64]	validation_0-rmse:0.55088	validation_1-rmse:0.88653
# [65]	validation_0-rmse:0.54719	validation_1-rmse:0.88498
# [66]	validation_0-rmse:0.54484	validation_1-rmse:0.88109
# [67]	validation_0-rmse:0.54068	validation_1-rmse:0.88208
# [68]	validation_0-rmse:0.53838	validation_1-rmse:0.88400
# [69]	validation_0-rmse:0.53449	validation_1-rmse:0.88828
# [70]	validation_0-rmse:0.53355	validation_1-rmse:0.88858
# [71]	validation_0-rmse:0.53245	validation_1-rmse:0.88849
# [72]	validation_0-rmse:0.53033	validation_1-rmse:0.88582
# [73]	validation_0-rmse:0.52580	validation_1-rmse:0.88455
# [74]	validation_0-rmse:0.52385	validation_1-rmse:0.88530
# [75]	validation_0-rmse:0.52066	validation_1-rmse:0.88511
# [76]	validation_0-rmse:0.51839	validation_1-rmse:0.88733
# [77]	validation_0-rmse:0.51740	validation_1-rmse:0.88839
# [78]	validation_0-rmse:0.51470	validation_1-rmse:0.89219
# [79]	validation_0-rmse:0.51174	validation_1-rmse:0.89450
# [80]	validation_0-rmse:0.51082	validation_1-rmse:0.89327
# [81]	validation_0-rmse:0.50872	validation_1-rmse:0.89193
# [82]	validation_0-rmse:0.50446	validation_1-rmse:0.89381
# [83]	validation_0-rmse:0.50311	validation_1-rmse:0.89343
# [84]	validation_0-rmse:0.50194	validation_1-rmse:0.89282
# [85]	validation_0-rmse:0.50012	validation_1-rmse:0.89749
# [86]	validation_0-rmse:0.49921	validation_1-rmse:0.89671
# [0]	validation_0-rmse:7.26847	validation_1-rmse:7.84264
# [1]	validation_0-rmse:6.47514	validation_1-rmse:7.01703
# [2]	validation_0-rmse:5.78955	validation_1-rmse:6.33705
# [3]	validation_0-rmse:5.15390	validation_1-rmse:5.67436
# [4]	validation_0-rmse:4.60786	validation_1-rmse:5.10469
# [5]	validation_0-rmse:4.11977	validation_1-rmse:4.61182
# [6]	validation_0-rmse:3.68615	validation_1-rmse:4.16705
# [7]	validation_0-rmse:3.29915	validation_1-rmse:3.76293
# [8]	validation_0-rmse:2.95804	validation_1-rmse:3.41003
# [9]	validation_0-rmse:2.66422	validation_1-rmse:3.10769
# [10]	validation_0-rmse:2.40576	validation_1-rmse:2.84189
# [11]	validation_0-rmse:2.16401	validation_1-rmse:2.59774
# [12]	validation_0-rmse:1.96370	validation_1-rmse:2.39038
# [13]	validation_0-rmse:1.78240	validation_1-rmse:2.19278
# [14]	validation_0-rmse:1.62528	validation_1-rmse:2.02934
# [15]	validation_0-rmse:1.48815	validation_1-rmse:1.88468
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [16]	validation_0-rmse:1.37172	validation_1-rmse:1.76488
# [17]	validation_0-rmse:1.26300	validation_1-rmse:1.64747
# [18]	validation_0-rmse:1.17326	validation_1-rmse:1.55688
# [19]	validation_0-rmse:1.09475	validation_1-rmse:1.47111
# [20]	validation_0-rmse:1.02449	validation_1-rmse:1.39302
# [21]	validation_0-rmse:0.96724	validation_1-rmse:1.33125
# [22]	validation_0-rmse:0.92045	validation_1-rmse:1.29220
# [23]	validation_0-rmse:0.87892	validation_1-rmse:1.25038
# [24]	validation_0-rmse:0.84150	validation_1-rmse:1.20622
# [25]	validation_0-rmse:0.81317	validation_1-rmse:1.16946
# [26]	validation_0-rmse:0.78619	validation_1-rmse:1.13895
# [27]	validation_0-rmse:0.75892	validation_1-rmse:1.10509
# [28]	validation_0-rmse:0.74350	validation_1-rmse:1.08159
# [29]	validation_0-rmse:0.72584	validation_1-rmse:1.05857
# [30]	validation_0-rmse:0.71111	validation_1-rmse:1.03765
# [31]	validation_0-rmse:0.69916	validation_1-rmse:1.01509
# [32]	validation_0-rmse:0.68482	validation_1-rmse:0.99804
# [33]	validation_0-rmse:0.67581	validation_1-rmse:0.98218
# [34]	validation_0-rmse:0.66818	validation_1-rmse:0.96686
# [35]	validation_0-rmse:0.66060	validation_1-rmse:0.94897
# [36]	validation_0-rmse:0.64870	validation_1-rmse:0.94948
# [37]	validation_0-rmse:0.64411	validation_1-rmse:0.93948
# [38]	validation_0-rmse:0.63760	validation_1-rmse:0.93097
# [39]	validation_0-rmse:0.62899	validation_1-rmse:0.93147
# [40]	validation_0-rmse:0.62208	validation_1-rmse:0.93603
# [41]	validation_0-rmse:0.61473	validation_1-rmse:0.92987
# [42]	validation_0-rmse:0.60958	validation_1-rmse:0.93263
# [43]	validation_0-rmse:0.60342	validation_1-rmse:0.93728
# [44]	validation_0-rmse:0.59738	validation_1-rmse:0.93134
# [45]	validation_0-rmse:0.59390	validation_1-rmse:0.92498
# [46]	validation_0-rmse:0.59183	validation_1-rmse:0.91698
# [47]	validation_0-rmse:0.58580	validation_1-rmse:0.92018
# [48]	validation_0-rmse:0.58310	validation_1-rmse:0.91276
# [49]	validation_0-rmse:0.57870	validation_1-rmse:0.91490
# [50]	validation_0-rmse:0.57477	validation_1-rmse:0.91840
# [51]	validation_0-rmse:0.57246	validation_1-rmse:0.91720
# [52]	validation_0-rmse:0.57088	validation_1-rmse:0.91252
# [53]	validation_0-rmse:0.56939	validation_1-rmse:0.90644
# [54]	validation_0-rmse:0.56798	validation_1-rmse:0.90012
# [55]	validation_0-rmse:0.56472	validation_1-rmse:0.89695
# [56]	validation_0-rmse:0.55969	validation_1-rmse:0.89135
# [57]	validation_0-rmse:0.55648	validation_1-rmse:0.88312
# [58]	validation_0-rmse:0.55529	validation_1-rmse:0.88448
# [59]	validation_0-rmse:0.55409	validation_1-rmse:0.88113
# [60]	validation_0-rmse:0.55285	validation_1-rmse:0.87882
# [61]	validation_0-rmse:0.54879	validation_1-rmse:0.87710
# [62]	validation_0-rmse:0.54793	validation_1-rmse:0.87383
# [63]	validation_0-rmse:0.54469	validation_1-rmse:0.87981
# [64]	validation_0-rmse:0.54310	validation_1-rmse:0.88316
# [65]	validation_0-rmse:0.54093	validation_1-rmse:0.88385
# [66]	validation_0-rmse:0.53793	validation_1-rmse:0.88822
# [67]	validation_0-rmse:0.53502	validation_1-rmse:0.88221
# [68]	validation_0-rmse:0.53313	validation_1-rmse:0.87838
# [69]	validation_0-rmse:0.53148	validation_1-rmse:0.87824
# [70]	validation_0-rmse:0.52942	validation_1-rmse:0.87904
# [71]	validation_0-rmse:0.52738	validation_1-rmse:0.87810
# [72]	validation_0-rmse:0.52558	validation_1-rmse:0.87700
# [73]	validation_0-rmse:0.52226	validation_1-rmse:0.87795
# [74]	validation_0-rmse:0.52167	validation_1-rmse:0.87598
# [75]	validation_0-rmse:0.51905	validation_1-rmse:0.87532
# [76]	validation_0-rmse:0.51839	validation_1-rmse:0.87175
# [77]	validation_0-rmse:0.51680	validation_1-rmse:0.87400
# [78]	validation_0-rmse:0.51529	validation_1-rmse:0.87487
# [79]	validation_0-rmse:0.51457	validation_1-rmse:0.87301
# [80]	validation_0-rmse:0.51191	validation_1-rmse:0.87958
# [81]	validation_0-rmse:0.51020	validation_1-rmse:0.87938
# [82]	validation_0-rmse:0.50832	validation_1-rmse:0.87591
# [83]	validation_0-rmse:0.50712	validation_1-rmse:0.87172
# [84]	validation_0-rmse:0.50448	validation_1-rmse:0.86660
# [85]	validation_0-rmse:0.50290	validation_1-rmse:0.86292
# [86]	validation_0-rmse:0.50197	validation_1-rmse:0.85902
# [87]	validation_0-rmse:0.49894	validation_1-rmse:0.85888
# [88]	validation_0-rmse:0.49790	validation_1-rmse:0.85789
# [89]	validation_0-rmse:0.49632	validation_1-rmse:0.85641
# [0]	validation_0-rmse:7.28156	validation_1-rmse:7.79073
# [1]	validation_0-rmse:6.48403	validation_1-rmse:6.97661
# [2]	validation_0-rmse:5.78225	validation_1-rmse:6.26488
# [3]	validation_0-rmse:5.14873	validation_1-rmse:5.61984
# [4]	validation_0-rmse:4.59526	validation_1-rmse:5.03000
# [5]	validation_0-rmse:4.10532	validation_1-rmse:4.51129
# [6]	validation_0-rmse:3.66466	validation_1-rmse:4.06330
# [7]	validation_0-rmse:3.28417	validation_1-rmse:3.67982
# [8]	validation_0-rmse:2.94882	validation_1-rmse:3.31441
# [9]	validation_0-rmse:2.65600	validation_1-rmse:2.99824
# [10]	validation_0-rmse:2.37906	validation_1-rmse:2.71001
# [11]	validation_0-rmse:2.14328	validation_1-rmse:2.45300
# [12]	validation_0-rmse:1.94584	validation_1-rmse:2.25320
# [13]	validation_0-rmse:1.76840	validation_1-rmse:2.07530
# [14]	validation_0-rmse:1.62478	validation_1-rmse:1.93121
# [15]	validation_0-rmse:1.49420	validation_1-rmse:1.80159
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [16]	validation_0-rmse:1.37000	validation_1-rmse:1.66256
# [17]	validation_0-rmse:1.27129	validation_1-rmse:1.55290
# [18]	validation_0-rmse:1.18183	validation_1-rmse:1.44788
# [19]	validation_0-rmse:1.10269	validation_1-rmse:1.35033
# [20]	validation_0-rmse:1.03762	validation_1-rmse:1.27331
# [21]	validation_0-rmse:0.98216	validation_1-rmse:1.20733
# [22]	validation_0-rmse:0.93016	validation_1-rmse:1.14776
# [23]	validation_0-rmse:0.89309	validation_1-rmse:1.10166
# [24]	validation_0-rmse:0.85658	validation_1-rmse:1.05721
# [25]	validation_0-rmse:0.82737	validation_1-rmse:1.01917
# [26]	validation_0-rmse:0.80612	validation_1-rmse:0.99138
# [27]	validation_0-rmse:0.77565	validation_1-rmse:0.96222
# [28]	validation_0-rmse:0.75584	validation_1-rmse:0.94710
# [29]	validation_0-rmse:0.74650	validation_1-rmse:0.93327
# [30]	validation_0-rmse:0.73404	validation_1-rmse:0.91312
# [31]	validation_0-rmse:0.72356	validation_1-rmse:0.89598
# [32]	validation_0-rmse:0.70728	validation_1-rmse:0.88668
# [33]	validation_0-rmse:0.69994	validation_1-rmse:0.87808
# [34]	validation_0-rmse:0.68532	validation_1-rmse:0.87331
# [35]	validation_0-rmse:0.68044	validation_1-rmse:0.86599
# [36]	validation_0-rmse:0.67417	validation_1-rmse:0.86307
# [37]	validation_0-rmse:0.67071	validation_1-rmse:0.85849
# [38]	validation_0-rmse:0.66276	validation_1-rmse:0.85858
# [39]	validation_0-rmse:0.65940	validation_1-rmse:0.84969
# [40]	validation_0-rmse:0.65697	validation_1-rmse:0.85016
# [41]	validation_0-rmse:0.65444	validation_1-rmse:0.84449
# [42]	validation_0-rmse:0.65276	validation_1-rmse:0.83821
# [43]	validation_0-rmse:0.64604	validation_1-rmse:0.82530
# [44]	validation_0-rmse:0.64409	validation_1-rmse:0.82118
# [45]	validation_0-rmse:0.64154	validation_1-rmse:0.81377
# [46]	validation_0-rmse:0.63671	validation_1-rmse:0.81471
# [47]	validation_0-rmse:0.63541	validation_1-rmse:0.81057
# [48]	validation_0-rmse:0.62850	validation_1-rmse:0.80839
# [49]	validation_0-rmse:0.62613	validation_1-rmse:0.80384
# [50]	validation_0-rmse:0.62363	validation_1-rmse:0.79822
# [51]	validation_0-rmse:0.62273	validation_1-rmse:0.79148
# [52]	validation_0-rmse:0.62143	validation_1-rmse:0.78788
# [53]	validation_0-rmse:0.62066	validation_1-rmse:0.79095
# [54]	validation_0-rmse:0.61565	validation_1-rmse:0.79155
# [55]	validation_0-rmse:0.61333	validation_1-rmse:0.78973
# [56]	validation_0-rmse:0.61105	validation_1-rmse:0.78706
# [57]	validation_0-rmse:0.60990	validation_1-rmse:0.78861
# [58]	validation_0-rmse:0.60554	validation_1-rmse:0.78771
# [59]	validation_0-rmse:0.60233	validation_1-rmse:0.78768
# [60]	validation_0-rmse:0.59787	validation_1-rmse:0.78623
# [61]	validation_0-rmse:0.59697	validation_1-rmse:0.78323
# [62]	validation_0-rmse:0.59332	validation_1-rmse:0.78185
# [63]	validation_0-rmse:0.59248	validation_1-rmse:0.77907
# [64]	validation_0-rmse:0.58957	validation_1-rmse:0.77472
# [65]	validation_0-rmse:0.58709	validation_1-rmse:0.77246
# [66]	validation_0-rmse:0.58507	validation_1-rmse:0.76794
# [67]	validation_0-rmse:0.58081	validation_1-rmse:0.76522
# [68]	validation_0-rmse:0.57810	validation_1-rmse:0.76409
# [69]	validation_0-rmse:0.57769	validation_1-rmse:0.76277
# [70]	validation_0-rmse:0.57375	validation_1-rmse:0.76073
# [71]	validation_0-rmse:0.56896	validation_1-rmse:0.76306
# [72]	validation_0-rmse:0.56863	validation_1-rmse:0.76105
# [73]	validation_0-rmse:0.56547	validation_1-rmse:0.76286
# [74]	validation_0-rmse:0.56313	validation_1-rmse:0.75871
# [75]	validation_0-rmse:0.56255	validation_1-rmse:0.75565
# [76]	validation_0-rmse:0.56002	validation_1-rmse:0.75681
# [77]	validation_0-rmse:0.55717	validation_1-rmse:0.75904
# [78]	validation_0-rmse:0.55366	validation_1-rmse:0.75951
# [79]	validation_0-rmse:0.55137	validation_1-rmse:0.76146
# [80]	validation_0-rmse:0.54936	validation_1-rmse:0.75766
# [81]	validation_0-rmse:0.54697	validation_1-rmse:0.75888
# [82]	validation_0-rmse:0.54474	validation_1-rmse:0.76027
# [83]	validation_0-rmse:0.54417	validation_1-rmse:0.76063
# [84]	validation_0-rmse:0.54327	validation_1-rmse:0.75810
# [85]	validation_0-rmse:0.54129	validation_1-rmse:0.75902
# [86]	validation_0-rmse:0.53933	validation_1-rmse:0.76024
# [87]	validation_0-rmse:0.53722	validation_1-rmse:0.75995
# [88]	validation_0-rmse:0.53328	validation_1-rmse:0.75820
# [89]	validation_0-rmse:0.53123	validation_1-rmse:0.75806
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# Intermedia ratio for calculation CI
CIR=2/(n_sample**0.5)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 59.29, median: 60.0,
#  pred. interval (P(0.025)-P(0.975)): 28.0-89.0,
#  conf. interval (p-value=0.95): 49.526-70.474
# ***
# Aggregate bias statistic:
#  mean: -1.056, median: -1.008,
#  pred. interval (P(0.025)-P(0.975)): -7.454-5.453,
#  conf. interval (p-value=0.95): -2.424-0.338
# ***
# Aggregate RMSE statistic:
#  mean: 0.77, median: 0.776, pred. interval (P(0.025)-P(0.975)): 0.563-0.97,
#  conf. interval (p-value=0.95): 0.727-0.822
# ***
# Aggregate MSE statistic:
#  mean: 0.605, median: 0.602, pred. interval (P(0.025)-P(0.975)): 0.317-0.941,
#  conf. interval (p-value=0.95): 0.531-0.678
# ***
# Aggregate R^2 statistic:
#  mean: 0.691, median: 0.709, pred. interval (P(0.025)-P(0.975)): 0.368-0.869,
#  conf. interval (p-value=0.95): 0.657-0.749
# ***
# Aggregate bias(%) statistic:
#  mean: -0.116, median: -1.008, pred. interval (P(0.025)-P(0.975)): -0.836-0.629,
#  conf. interval (p-value=0.95): -0.278-0.041
# ***
# Aggregate RMSE(%) statistic:
#  mean: 0.089, median: 0.089, pred. interval (P(0.025)-P(0.975)): 0.065-0.114,
#  conf. interval (p-value=0.95): 0.084-0.094
# ***

# %% [markdown]
# # ***Training on all data***

# %% [markdown]
# # Creating a final XGBoost model

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:7.37483
# [1]	validation_0-rmse:6.57132
# [2]	validation_0-rmse:5.86739
# [3]	validation_0-rmse:5.23793
# [4]	validation_0-rmse:4.67479
# [5]	validation_0-rmse:4.17402
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [6]	validation_0-rmse:3.74099
# [7]	validation_0-rmse:3.35082
# [8]	validation_0-rmse:3.00130
# [9]	validation_0-rmse:2.70123
# [10]	validation_0-rmse:2.43863
# [11]	validation_0-rmse:2.20060
# [12]	validation_0-rmse:1.99291
# [13]	validation_0-rmse:1.81623
# [14]	validation_0-rmse:1.66054
# [15]	validation_0-rmse:1.51952
# [16]	validation_0-rmse:1.39539
# [17]	validation_0-rmse:1.29652
# [18]	validation_0-rmse:1.20692
# [19]	validation_0-rmse:1.12909
# [20]	validation_0-rmse:1.06101
# [21]	validation_0-rmse:1.00294
# [22]	validation_0-rmse:0.94895
# [23]	validation_0-rmse:0.90697
# [24]	validation_0-rmse:0.87573
# [25]	validation_0-rmse:0.84766
# [26]	validation_0-rmse:0.82221
# [27]	validation_0-rmse:0.80092
# [28]	validation_0-rmse:0.78214
# [29]	validation_0-rmse:0.76686
# [30]	validation_0-rmse:0.75276
# [31]	validation_0-rmse:0.73770
# [32]	validation_0-rmse:0.72793
# [33]	validation_0-rmse:0.71844
# [34]	validation_0-rmse:0.70903
# [35]	validation_0-rmse:0.70368
# [36]	validation_0-rmse:0.69549
# [37]	validation_0-rmse:0.68997
# [38]	validation_0-rmse:0.68080
# [39]	validation_0-rmse:0.67768
# [40]	validation_0-rmse:0.66903
# [41]	validation_0-rmse:0.66016
# [42]	validation_0-rmse:0.65773
# [43]	validation_0-rmse:0.65599
# [44]	validation_0-rmse:0.64580
# [45]	validation_0-rmse:0.64402
# [46]	validation_0-rmse:0.64212
# [47]	validation_0-rmse:0.64037
# [48]	validation_0-rmse:0.63902
# [49]	validation_0-rmse:0.63590
# [50]	validation_0-rmse:0.63028
# [51]	validation_0-rmse:0.62906
# [52]	validation_0-rmse:0.62396
# [53]	validation_0-rmse:0.62126
# [54]	validation_0-rmse:0.61970
# [55]	validation_0-rmse:0.61428
# [56]	validation_0-rmse:0.61240
# [57]	validation_0-rmse:0.60828
# [58]	validation_0-rmse:0.60626
# [59]	validation_0-rmse:0.60169
# [60]	validation_0-rmse:0.59691
# [61]	validation_0-rmse:0.59294
# [62]	validation_0-rmse:0.59158
# [63]	validation_0-rmse:0.58858
# [64]	validation_0-rmse:0.58505
# [65]	validation_0-rmse:0.58388
# [66]	validation_0-rmse:0.58136
# [67]	validation_0-rmse:0.58032
# [68]	validation_0-rmse:0.57879
# [69]	validation_0-rmse:0.57804
# [70]	validation_0-rmse:0.57785
# [71]	validation_0-rmse:0.57479
# [72]	validation_0-rmse:0.57349
# [73]	validation_0-rmse:0.57284
# [74]	validation_0-rmse:0.57126
# [75]	validation_0-rmse:0.57034
# [76]	validation_0-rmse:0.56801
# [77]	validation_0-rmse:0.56733
# [78]	validation_0-rmse:0.56379
# [79]	validation_0-rmse:0.56183
# [80]	validation_0-rmse:0.55971
# [81]	validation_0-rmse:0.55724
# [82]	validation_0-rmse:0.55455
# [83]	validation_0-rmse:0.55408
# [84]	validation_0-rmse:0.55357
# [85]	validation_0-rmse:0.55319
# [86]	validation_0-rmse:0.55161
# [87]	validation_0-rmse:0.55012
# [88]	validation_0-rmse:0.54743
# [89]	validation_0-rmse:0.54563
# /home/dima/anaconda3/lib/python3.9/site-packages/xgboost/core.py:90: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 89

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()
print('Bias: %.1f' % (f_bias/f_n_sample))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.02
# RMSE: 0.5
# Relative RMSE(%):  0.063
# MSE: 0.3
# R square: 86.1%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties
# retrieve parameter values
a0 = popt[0]
a1 = popt[1]
print('Optimal values of regression parameters')
print(f'a0: {a0:.3f}')
print(f'a1: {a1:.3f}')

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
f_r2 = round(r2, 3)
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(6, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# Optimal values of regression parameters
# a0: 1.569
# a1: 0.819
# R^2: 0.864
# Uncertainty
# a0: 1.57+/-0.28
# a1: 0.819+/-0.032

# %% [markdown]
# # ***Analisys output final the model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [12, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # SHAP method

# %%
# Load SHAP`s library
import shap

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/.json")
# Save to text format
f_xgb_model.save_model("/home/dima/Desktop/JupyterLab/GIS and ML algoritms/5_Processing_data_for_level_sites/.txt")
