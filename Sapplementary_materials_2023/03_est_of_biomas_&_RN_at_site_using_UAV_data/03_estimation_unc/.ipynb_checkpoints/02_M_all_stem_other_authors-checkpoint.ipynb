# %% [markdown]
# ## Processing with aboveground biomass data based on my fieldworks and other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
input_data = './FULL_DB_BIOMASS_OTHER_ALL_AUTHORS.csv'
df = pd.read_csv(input_data)
df.head()
# Out:
#    Groups Species  Species_ID Origin  Origin_ID  SI  A_years   H_m  DBH_cm  \
# 0       1    Pine           0      n        0.0   4       50   9.7    14.6
# 1       1    Pine           0      n        0.0   2       65  20.6    20.6
# 2       1    Pine           0      n        0.0   2       50  13.6    15.4
# 3       1    Pine           0      n        0.0   1       60  23.3    22.2
# 4       1    Pine           0      n        0.0   3       65  15.6    16.4
#
#    N_trees  ...  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  \
# 0    486.0  ...             NaN             NaN         8.4           1.6
# 1    785.0  ...             NaN             NaN        11.5           4.1
# 2   1745.0  ...             NaN             NaN        13.7           4.1
# 3    665.0  ...             NaN             NaN        14.4           5.4
# 4    955.0  ...             NaN             NaN        14.2           3.4
#
#    LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  \
# 0         3.78              2.94                NaN                NaN
# 1         5.54              4.73                NaN                NaN
# 2         5.25              4.48                NaN                NaN
# 3         5.63              4.67                NaN                NaN
# 4         4.96              4.20                NaN                NaN
#
#    LN_Crown_t_ha  LN_Foliage_t_ha
# 0           2.13             0.47
# 1           2.44             1.41
# 2           2.62             1.41
# 3           2.67             1.69
# 4           2.65             1.22
#
# [5 rows x 24 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
#
# 'Groups','Species_ID','Origin_ID','SI','A_years','H_m','DBH_cm','RS(P)',          'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
# 'Crown_t_ha','Foliage_t_ha'
# 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species_ID','Origin_ID','H_m','DBH_cm', 'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
'Crown_t_ha','Foliage_t_ha', 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0           0        0.0   9.7    14.6         9.7      43.9           18.9
# 1           0        0.0  20.6    20.6        32.2     254.0          113.1
# 2           0        0.0  13.6    15.4        35.2     190.0           87.8
# 3           0        0.0  23.3    22.2        29.6     277.7          106.5
# 4           0        0.0  15.6    16.4        20.4     142.5           67.0
#
#    Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0             NaN             NaN         8.4           1.6         3.78
# 1             NaN             NaN        11.5           4.1         5.54
# 2             NaN             NaN        13.7           4.1         5.25
# 3             NaN             NaN        14.4           5.4         5.63
# 4             NaN             NaN        14.2           3.4         4.96
#
#    LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0              2.94                NaN                NaN           2.13
# 1              4.73                NaN                NaN           2.44
# 2              4.48                NaN                NaN           2.62
# 3              4.67                NaN                NaN           2.67
# 4              4.20                NaN                NaN           2.65
#
#    LN_Foliage_t_ha
# 0             0.47
# 1             1.41
# 2             1.41
# 3             1.69
# 4             1.22

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Species_ID         857 non-null    int64
#  1   Origin_ID          856 non-null    float64
#  2   H_m                857 non-null    float64
#  3   DBH_cm             856 non-null    float64
#  4   BA_sq_m_ha         857 non-null    float64
#  5   GS_cub_m           857 non-null    float64
#  6   ALL_STEM_t_ha      855 non-null    float64
#  7   Stem_wood_t_ha     747 non-null    float64
#  8   Stem_bark_t_ha     747 non-null    float64
#  9   Crown_t_ha         843 non-null    float64
#  10  Foliage_t_ha       854 non-null    float64
#  11  LN_GS_cub_m        857 non-null    float64
#  12  LN_ALL_STEM_t_ha   855 non-null    float64
#  13  LN_Stem_wood_t_ha  747 non-null    float64
#  14  LN_Stem_bark_t_ha  747 non-null    float64
#  15  LN_Crown_t_ha      843 non-null    float64
#  16  LN_Foliage_t_ha    854 non-null    float64
# dtypes: float64(16), int64(1)
# memory usage: 113.9 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species_ID"])["LN_GS_cub_m", "ALL_STEM_t_ha"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            LN_GS_cub_m                                                         \
#                  count      mean       std   min     25%    50%     75%   max
# Species_ID
# 0                458.0  5.192052  0.897136  0.88  4.8350  5.415  5.8075  6.60
# 1                  7.0  5.490000  0.589463  4.65  5.0350  5.700  5.9650  6.08
# 2                120.0  4.741667  0.702628  2.31  4.2150  4.855  5.3025  5.92
# 3                115.0  5.345478  0.624346  3.32  4.9250  5.500  5.8000  6.31
# 4                 66.0  5.057273  0.732497  3.05  4.6175  5.010  5.6675  6.26
# 5                 91.0  5.430220  0.830515  2.20  5.0700  5.610  6.0300  6.40
#
#            ALL_STEM_t_ha                                                       \
#                    count        mean        std   min     25%    50%      75%
# Species_ID
# 0                  457.0   97.049891  61.854506   1.8  47.500   92.7  135.900
# 1                    7.0  123.814286  61.879895  46.3  70.650  133.9  174.550
# 2                  120.0   74.495000  44.523333   5.1  37.275   68.1  103.075
# 3                  115.0  107.607826  55.589186  11.0  62.700  106.8  145.450
# 4                   66.0   84.946970  58.875162   8.2  40.750   61.2  125.000
# 5                   90.0  173.065556  99.100647   5.0  93.075  161.3  253.375
#
#
#               max
# Species_ID
# 0           310.7
# 1           196.1
# 2           193.5
# 3           251.6
# 4           245.4
# 5           363.9

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID   Origin_ID         H_m      DBH_cm  BA_sq_m_ha    GS_cub_m  \
# count  857.000000  856.000000  857.000000  856.000000  857.000000  857.000000
# mean     1.529755    0.279206   16.452275   17.132243   26.329988  229.013069
# std      1.823872    0.448871    7.039954   10.439115   10.629993  144.362106
# min      0.000000    0.000000    1.500000    1.100000    1.000000    2.400000
# 25%      0.000000    0.000000   11.200000    9.900000   19.000000  116.000000
# 50%      0.000000    0.000000   16.100000   15.500000   26.800000  206.000000
# 75%      3.000000    1.000000   21.200000   22.100000   34.500000  320.000000
# max      5.000000    1.000000   38.300000   94.000000   51.500000  735.000000
#
#        ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  \
# count     855.000000      747.000000      747.000000  843.000000
# mean      102.590877       92.779518       12.060107   13.821969
# std        68.758819       61.992238        9.595428   11.567546
# min         1.800000        2.000000        0.300000    0.500000
# 25%        47.500000       42.900000        5.950000    6.610000
# 50%        93.500000       84.600000        9.300000   10.820000
# 75%       140.500000      125.500000       15.300000   16.435000
# max       363.900000      315.200000       65.700000   69.120000
#
#        Foliage_t_ha  LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  \
# count    854.000000   857.000000        855.000000         747.000000
# mean       4.749356     5.166919          4.343766           4.246975
# std        2.826586     0.839680          0.869479           0.854856
# min        0.200000     0.880000          0.590000           0.690000
# 25%        2.600000     4.750000          3.860000           3.760000
# 50%        4.300000     5.330000          4.540000           4.440000
# 75%        6.367500     5.770000          4.950000           4.830000
# max       21.730000     6.600000          5.900000           5.750000
#
#        LN_Stem_bark_t_ha  LN_Crown_t_ha  LN_Foliage_t_ha
# count         747.000000     843.000000       854.000000
# mean            2.201232       2.318149         1.364906
# std             0.806766       0.829446         0.672551
# min            -1.200000      -0.690000        -1.610000
# 25%             1.780000       1.890000         0.960000
# 50%             2.230000       2.380000         1.460000
# 75%             2.730000       2.800000         1.850000
# max             4.190000       4.240000         3.080000

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ALL_STEM_t_ha"
indep_variables = ['Species_ID','Origin_ID','H_m','DBH_cm','BA_sq_m_ha']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0             0        0.0   9.7    14.6         9.7      43.9           18.9
# 1             0        0.0  20.6    20.6        32.2     254.0          113.1
# 2             0        0.0  13.6    15.4        35.2     190.0           87.8
# 3             0        0.0  23.3    22.2        29.6     277.7          106.5
# 4             0        0.0  15.6    16.4        20.4     142.5           67.0
# ..          ...        ...   ...     ...         ...       ...            ...
# 852           3        0.0   7.8     4.4         9.2      39.8           17.8
# 853           3        0.0  12.7     9.0        20.5     123.6           47.1
# 854           3        0.0  12.2     8.1        20.3     141.7           51.9
# 855           2        0.0  14.3    12.4        25.1     176.5          100.7
# 856           2        0.0  21.1    25.6        21.0     191.6           99.9
#
#      Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0               NaN             NaN        8.40          1.60         3.78
# 1               NaN             NaN       11.50          4.10         5.54
# 2               NaN             NaN       13.70          4.10         5.25
# 3               NaN             NaN       14.40          5.40         5.63
# 4               NaN             NaN       14.20          3.40         4.96
# ..              ...             ...         ...           ...          ...
# 852            15.7             2.1        2.26          2.04         3.68
# 853            42.6             4.5        2.14          1.21         4.82
# 854            47.8             4.1        2.11          1.16         4.95
# 855            84.6            16.1       16.90          4.74         5.17
# 856            80.8            19.1       16.60          2.13         5.26
#
#      LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0                2.94                NaN                NaN           2.13
# 1                4.73                NaN                NaN           2.44
# 2                4.48                NaN                NaN           2.62
# 3                4.67                NaN                NaN           2.67
# 4                4.20                NaN                NaN           2.65
# ..                ...                ...                ...            ...
# 852              2.88               2.75               0.74           0.82
# 853              3.85               3.75               1.50           0.76
# 854              3.95               3.87               1.41           0.75
# 855              4.61               4.44               2.78           2.83
# 856              4.60               4.39               2.95           2.81
#
#      LN_Foliage_t_ha
# 0               0.47
# 1               1.41
# 2               1.41
# 3               1.69
# 4               1.22
# ..               ...
# 852             0.71
# 853             0.19
# 854             0.15
# 855             1.56
# 856             0.76
#
# [855 rows x 17 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha
# 0           0        0.0   9.7    14.6         9.7
# 1           0        0.0  20.6    20.6        32.2
# 2           0        0.0  13.6    15.4        35.2
# 3           0        0.0  23.3    22.2        29.6
# 4           0        0.0  15.6    16.4        20.4

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ALL_STEM_t_ha
# 0           18.9
# 1          113.1
# 2           87.8
# 3          106.5
# 4           67.0

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.9375202869137623, 0.9444660155630333, 0.9320657680152117]
#     Mean: 0.938
#     Std: 0.005
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [18.4061905  16.37526339 16.08940776]
#     Mean: 16.957
#     Std: 1.031
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [11.82992913145768, 11.131049746463173, 10.90391886418326]
#     Mean: 11.288
#     Std: 0.394
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.7658578011184654                 # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.19219571931631796                # gamma
print('Gamma: ' + str(p2))

p3 = 0.28748915735552544                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2            # max_depth
print('Max_depth: ' + str(p4))

p5 = 199         # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.9585132255045361                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.7658578011184654
# Gamma: 0.19219571931631796
# Learning_rate: 0.28748915735552544
# Max_depth: 2
# N_estimators: 199
# Subsample: 0.9585132255045361

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
        
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:92.37004	validation_1-rmse:85.35987
# [1]	validation_0-rmse:70.43656	validation_1-rmse:64.30789
# [2]	validation_0-rmse:55.41604	validation_1-rmse:50.01132
# [3]	validation_0-rmse:42.78286	validation_1-rmse:38.52273
# [4]	validation_0-rmse:35.81096	validation_1-rmse:32.74088
# [5]	validation_0-rmse:29.50274	validation_1-rmse:27.25494
# [6]	validation_0-rmse:25.39687	validation_1-rmse:24.43267
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:22.68731	validation_1-rmse:22.38991
# [8]	validation_0-rmse:20.92445	validation_1-rmse:21.18665
# [9]	validation_0-rmse:19.81765	validation_1-rmse:20.54859
# [10]	validation_0-rmse:18.99895	validation_1-rmse:20.36540
# [11]	validation_0-rmse:18.37852	validation_1-rmse:20.03645
# [12]	validation_0-rmse:17.78878	validation_1-rmse:19.65180
# [13]	validation_0-rmse:17.47386	validation_1-rmse:19.71240
# [14]	validation_0-rmse:17.20980	validation_1-rmse:19.69205
# [15]	validation_0-rmse:16.97805	validation_1-rmse:19.47696
# [16]	validation_0-rmse:16.60162	validation_1-rmse:19.36179
# [17]	validation_0-rmse:16.43448	validation_1-rmse:19.00632
# [18]	validation_0-rmse:16.23375	validation_1-rmse:19.18999
# [19]	validation_0-rmse:16.13003	validation_1-rmse:19.19947
# [20]	validation_0-rmse:16.00348	validation_1-rmse:19.19495
# [21]	validation_0-rmse:15.90892	validation_1-rmse:18.91714
# [22]	validation_0-rmse:15.83860	validation_1-rmse:18.92627
# [23]	validation_0-rmse:15.72661	validation_1-rmse:19.14311
# [24]	validation_0-rmse:15.55297	validation_1-rmse:19.12732
# [25]	validation_0-rmse:15.46259	validation_1-rmse:19.18113
# [26]	validation_0-rmse:15.31868	validation_1-rmse:19.14639
# [27]	validation_0-rmse:15.25313	validation_1-rmse:18.92428
# [28]	validation_0-rmse:15.17417	validation_1-rmse:19.08052
# [62]	validation_0-rmse:12.72794	validation_1-rmse:16.86068
# [63]	validation_0-rmse:12.63082	validation_1-rmse:16.89759
# [64]	validation_0-rmse:12.60096	validation_1-rmse:16.85129
# [65]	validation_0-rmse:12.51241	validation_1-rmse:16.92689
# [66]	validation_0-rmse:12.48586	validation_1-rmse:16.92896
# [67]	validation_0-rmse:12.46775	validation_1-rmse:16.89007
# [68]	validation_0-rmse:12.45556	validation_1-rmse:16.91460
# [69]	validation_0-rmse:12.39702	validation_1-rmse:16.88174
# [70]	validation_0-rmse:12.28895	validation_1-rmse:16.80424
# [71]	validation_0-rmse:12.24086	validation_1-rmse:16.75015
# [72]	validation_0-rmse:12.19513	validation_1-rmse:16.74339
# [73]	validation_0-rmse:12.15849	validation_1-rmse:16.77510
# [74]	validation_0-rmse:12.05828	validation_1-rmse:16.94612
# [75]	validation_0-rmse:12.02920	validation_1-rmse:17.00406
# [76]	validation_0-rmse:11.98360	validation_1-rmse:16.99430
# [77]	validation_0-rmse:11.93263	validation_1-rmse:16.93653
# [78]	validation_0-rmse:11.89960	validation_1-rmse:16.89520
# [79]	validation_0-rmse:11.86981	validation_1-rmse:16.89790
# [80]	validation_0-rmse:11.84311	validation_1-rmse:16.89505
# [81]	validation_0-rmse:11.81085	validation_1-rmse:16.87797
# [82]	validation_0-rmse:11.76448	validation_1-rmse:16.78262
# [83]	validation_0-rmse:11.75569	validation_1-rmse:16.78695
# [84]	validation_0-rmse:11.70941	validation_1-rmse:16.78932
# [85]	validation_0-rmse:11.65486	validation_1-rmse:16.78776
# [86]	validation_0-rmse:11.62573	validation_1-rmse:16.74874
# [87]	validation_0-rmse:11.56176	validation_1-rmse:16.70083
# [88]	validation_0-rmse:11.49958	validation_1-rmse:16.76830
# [89]	validation_0-rmse:11.47870	validation_1-rmse:16.77235
# [90]	validation_0-rmse:11.43528	validation_1-rmse:16.81010
# [91]	validation_0-rmse:11.42903	validation_1-rmse:16.80915
# [92]	validation_0-rmse:11.36515	validation_1-rmse:16.83118
# [93]	validation_0-rmse:11.33230	validation_1-rmse:16.79540
# [94]	validation_0-rmse:11.29041	validation_1-rmse:16.78335
# [95]	validation_0-rmse:11.27534	validation_1-rmse:16.77386
# [96]	validation_0-rmse:11.25563	validation_1-rmse:16.77579
# [97]	validation_0-rmse:11.23604	validation_1-rmse:16.75380
# [98]	validation_0-rmse:11.21392	validation_1-rmse:16.74853
# [99]	validation_0-rmse:11.20629	validation_1-rmse:16.74915
# [100]	validation_0-rmse:11.19098	validation_1-rmse:16.71045
# [101]	validation_0-rmse:11.14895	validation_1-rmse:16.74269
# [102]	validation_0-rmse:11.13056	validation_1-rmse:16.70137
# [103]	validation_0-rmse:11.09538	validation_1-rmse:16.65573
# [104]	validation_0-rmse:11.04584	validation_1-rmse:16.58223
# [105]	validation_0-rmse:11.02882	validation_1-rmse:16.58423
# [106]	validation_0-rmse:11.01712	validation_1-rmse:16.56921
# [107]	validation_0-rmse:11.00944	validation_1-rmse:16.56213
# [108]	validation_0-rmse:10.97683	validation_1-rmse:16.60477
# [59]	validation_0-rmse:12.05199	validation_1-rmse:18.31020
# [60]	validation_0-rmse:11.97548	validation_1-rmse:18.21733
# [61]	validation_0-rmse:11.90338	validation_1-rmse:18.16556
# [62]	validation_0-rmse:11.88809	validation_1-rmse:18.16899
# [63]	validation_0-rmse:11.87631	validation_1-rmse:18.17245
# [64]	validation_0-rmse:11.87038	validation_1-rmse:18.15362
# [65]	validation_0-rmse:11.85134	validation_1-rmse:18.13456
# [66]	validation_0-rmse:11.80525	validation_1-rmse:18.08002
# [67]	validation_0-rmse:11.77541	validation_1-rmse:18.02627
# [68]	validation_0-rmse:11.75406	validation_1-rmse:17.98147
# [69]	validation_0-rmse:11.71251	validation_1-rmse:18.15153
# [70]	validation_0-rmse:11.68246	validation_1-rmse:18.16160
# [71]	validation_0-rmse:11.62970	validation_1-rmse:18.14461
# [72]	validation_0-rmse:11.58153	validation_1-rmse:18.16847
# [73]	validation_0-rmse:11.54319	validation_1-rmse:18.10941
# [74]	validation_0-rmse:11.50534	validation_1-rmse:18.03293
# [75]	validation_0-rmse:11.48868	validation_1-rmse:18.02227
# [76]	validation_0-rmse:11.41547	validation_1-rmse:18.09440
# [77]	validation_0-rmse:11.36512	validation_1-rmse:17.98355
# [78]	validation_0-rmse:11.35468	validation_1-rmse:17.99488
# [79]	validation_0-rmse:11.32382	validation_1-rmse:17.99594
# [80]	validation_0-rmse:11.27156	validation_1-rmse:17.98697
# [81]	validation_0-rmse:11.22836	validation_1-rmse:18.08672
# [82]	validation_0-rmse:11.22108	validation_1-rmse:18.08853
# [83]	validation_0-rmse:11.16073	validation_1-rmse:18.07864
# [84]	validation_0-rmse:11.11546	validation_1-rmse:17.95429
# [85]	validation_0-rmse:11.09250	validation_1-rmse:17.83516
# [86]	validation_0-rmse:11.06322	validation_1-rmse:17.89721
# [87]	validation_0-rmse:11.01412	validation_1-rmse:17.95304
# [88]	validation_0-rmse:11.01028	validation_1-rmse:17.95096
# [89]	validation_0-rmse:10.95957	validation_1-rmse:17.85314
# [90]	validation_0-rmse:10.91414	validation_1-rmse:17.80248
# [91]	validation_0-rmse:10.91657	validation_1-rmse:17.80458
# [92]	validation_0-rmse:10.89562	validation_1-rmse:17.76310
# [93]	validation_0-rmse:10.88601	validation_1-rmse:17.75451
# [94]	validation_0-rmse:10.87872	validation_1-rmse:17.75949
# [95]	validation_0-rmse:10.81649	validation_1-rmse:17.72169
# [96]	validation_0-rmse:10.79099	validation_1-rmse:17.70479
# [97]	validation_0-rmse:10.76402	validation_1-rmse:17.69916
# [98]	validation_0-rmse:10.75285	validation_1-rmse:17.70108
# [99]	validation_0-rmse:10.70239	validation_1-rmse:17.70676
# [100]	validation_0-rmse:10.67644	validation_1-rmse:17.67701
# [101]	validation_0-rmse:10.66109	validation_1-rmse:17.66325
# [102]	validation_0-rmse:10.64288	validation_1-rmse:17.65402
# [103]	validation_0-rmse:10.61373	validation_1-rmse:17.69439
# [104]	validation_0-rmse:10.58788	validation_1-rmse:17.67060
# [105]	validation_0-rmse:10.56786	validation_1-rmse:17.63910
# [106]	validation_0-rmse:10.54825	validation_1-rmse:17.65080
# [107]	validation_0-rmse:10.52557	validation_1-rmse:17.68806
# [108]	validation_0-rmse:10.51756	validation_1-rmse:17.69350
# [109]	validation_0-rmse:10.48952	validation_1-rmse:17.69255
# [110]	validation_0-rmse:10.43773	validation_1-rmse:17.66040
# [111]	validation_0-rmse:10.36520	validation_1-rmse:17.65360
# [112]	validation_0-rmse:10.34685	validation_1-rmse:17.69202
# [113]	validation_0-rmse:10.33907	validation_1-rmse:17.69861
# [114]	validation_0-rmse:10.30036	validation_1-rmse:17.69212
# [115]	validation_0-rmse:10.29284	validation_1-rmse:17.66179
# [116]	validation_0-rmse:10.25942	validation_1-rmse:17.76342
# [117]	validation_0-rmse:10.23412	validation_1-rmse:17.65743
# [118]	validation_0-rmse:10.22857	validation_1-rmse:17.65106
# [119]	validation_0-rmse:10.21548	validation_1-rmse:17.64202
# [120]	validation_0-rmse:10.18743	validation_1-rmse:17.64618
# [121]	validation_0-rmse:10.18265	validation_1-rmse:17.64167
# [122]	validation_0-rmse:10.15294	validation_1-rmse:17.62878
# [123]	validation_0-rmse:10.14556	validation_1-rmse:17.62676
# [124]	validation_0-rmse:10.13346	validation_1-rmse:17.63016
# [125]	validation_0-rmse:10.11773	validation_1-rmse:17.62096
# [126]	validation_0-rmse:10.07416	validation_1-rmse:17.56807
# [127]	validation_0-rmse:10.05542	validation_1-rmse:17.55417
# [128]	validation_0-rmse:10.04910	validation_1-rmse:17.55958
# [129]	validation_0-rmse:10.03442	validation_1-rmse:17.54260
# [130]	validation_0-rmse:10.00141	validation_1-rmse:17.56113
# [131]	validation_0-rmse:9.98947	validation_1-rmse:17.55558
# [132]	validation_0-rmse:9.95074	validation_1-rmse:17.55619
# [133]	validation_0-rmse:9.92446	validation_1-rmse:17.49890
# [134]	validation_0-rmse:9.89489	validation_1-rmse:17.49106
# [135]	validation_0-rmse:9.84555	validation_1-rmse:17.48299
# [136]	validation_0-rmse:9.81918	validation_1-rmse:17.50975
# [137]	validation_0-rmse:9.80612	validation_1-rmse:17.48601
# [138]	validation_0-rmse:9.75980	validation_1-rmse:17.47078
# [139]	validation_0-rmse:9.76051	validation_1-rmse:17.47246
# [140]	validation_0-rmse:9.72663	validation_1-rmse:17.45156
# [141]	validation_0-rmse:9.70076	validation_1-rmse:17.41895
# [142]	validation_0-rmse:9.67131	validation_1-rmse:17.40779
# [143]	validation_0-rmse:9.63989	validation_1-rmse:17.45856
# [144]	validation_0-rmse:9.61706	validation_1-rmse:17.49244
# [145]	validation_0-rmse:9.59620	validation_1-rmse:17.49175
# [146]	validation_0-rmse:9.56525	validation_1-rmse:17.47085
# [147]	validation_0-rmse:9.56046	validation_1-rmse:17.47429
# [148]	validation_0-rmse:9.51362	validation_1-rmse:17.44679
# [149]	validation_0-rmse:9.50793	validation_1-rmse:17.44882
# [150]	validation_0-rmse:9.49444	validation_1-rmse:17.44775
# [151]	validation_0-rmse:9.48443	validation_1-rmse:17.44110
# [152]	validation_0-rmse:9.43445	validation_1-rmse:17.45215
# [21]	validation_0-rmse:15.16800	validation_1-rmse:19.95667
# [22]	validation_0-rmse:15.05816	validation_1-rmse:19.96378
# [23]	validation_0-rmse:14.91661	validation_1-rmse:20.07282
# [24]	validation_0-rmse:14.76974	validation_1-rmse:20.10173
# [25]	validation_0-rmse:14.65259	validation_1-rmse:20.10907
# [26]	validation_0-rmse:14.53871	validation_1-rmse:20.16822
# [27]	validation_0-rmse:14.46331	validation_1-rmse:20.05737
# [28]	validation_0-rmse:14.28178	validation_1-rmse:19.88768
# [29]	validation_0-rmse:14.21079	validation_1-rmse:19.83556
# [30]	validation_0-rmse:14.10527	validation_1-rmse:19.74433
# [31]	validation_0-rmse:13.93540	validation_1-rmse:19.74246
# [32]	validation_0-rmse:13.88839	validation_1-rmse:19.65829
# [33]	validation_0-rmse:13.83493	validation_1-rmse:19.76226
# [34]	validation_0-rmse:13.78987	validation_1-rmse:19.84451
# [35]	validation_0-rmse:13.70582	validation_1-rmse:19.74793
# [36]	validation_0-rmse:13.65505	validation_1-rmse:19.80449
# [37]	validation_0-rmse:13.62899	validation_1-rmse:19.76015
# [38]	validation_0-rmse:13.56893	validation_1-rmse:19.80114
# [39]	validation_0-rmse:13.48207	validation_1-rmse:19.74662
# [40]	validation_0-rmse:13.44431	validation_1-rmse:19.81805
# [41]	validation_0-rmse:13.36970	validation_1-rmse:19.75937
# [42]	validation_0-rmse:13.32502	validation_1-rmse:19.75503
# [43]	validation_0-rmse:13.22131	validation_1-rmse:19.75024
# [44]	validation_0-rmse:13.18270	validation_1-rmse:19.66102
# [45]	validation_0-rmse:13.09045	validation_1-rmse:19.60346
# [46]	validation_0-rmse:13.02345	validation_1-rmse:19.60093
# [47]	validation_0-rmse:12.97765	validation_1-rmse:19.62165
# [48]	validation_0-rmse:12.88961	validation_1-rmse:19.61280
# [49]	validation_0-rmse:12.78261	validation_1-rmse:19.67760
# [50]	validation_0-rmse:12.73515	validation_1-rmse:19.60603
# [51]	validation_0-rmse:12.62339	validation_1-rmse:19.58175
# [52]	validation_0-rmse:12.54933	validation_1-rmse:19.61347
# [53]	validation_0-rmse:12.50403	validation_1-rmse:19.61075
# [54]	validation_0-rmse:12.44952	validation_1-rmse:19.69567
# [55]	validation_0-rmse:12.42546	validation_1-rmse:19.60976
# [56]	validation_0-rmse:12.36723	validation_1-rmse:19.59483
# [57]	validation_0-rmse:12.35247	validation_1-rmse:19.60014
# [58]	validation_0-rmse:12.26528	validation_1-rmse:19.59488
# [59]	validation_0-rmse:12.21811	validation_1-rmse:19.56482
# [60]	validation_0-rmse:12.15465	validation_1-rmse:19.52429
# [61]	validation_0-rmse:12.10253	validation_1-rmse:19.45704
# [62]	validation_0-rmse:12.05462	validation_1-rmse:19.38760
# [63]	validation_0-rmse:12.02129	validation_1-rmse:19.34870
# [64]	validation_0-rmse:11.97270	validation_1-rmse:19.30253
# [65]	validation_0-rmse:11.95409	validation_1-rmse:19.29700
# [66]	validation_0-rmse:11.88598	validation_1-rmse:19.28491
# [67]	validation_0-rmse:11.77800	validation_1-rmse:19.30532
# [67]	validation_0-rmse:11.47798	validation_1-rmse:20.90070
# [68]	validation_0-rmse:11.45853	validation_1-rmse:20.93987
# [69]	validation_0-rmse:11.44707	validation_1-rmse:20.92638
# [70]	validation_0-rmse:11.42981	validation_1-rmse:20.88213
# [71]	validation_0-rmse:11.40030	validation_1-rmse:20.77398
# [72]	validation_0-rmse:11.35584	validation_1-rmse:20.73740
# [73]	validation_0-rmse:11.30834	validation_1-rmse:20.79187
# [74]	validation_0-rmse:11.27019	validation_1-rmse:20.81130
# [75]	validation_0-rmse:11.24169	validation_1-rmse:20.80897
# [76]	validation_0-rmse:11.20867	validation_1-rmse:20.75737
# [77]	validation_0-rmse:11.16863	validation_1-rmse:20.70953
# [78]	validation_0-rmse:11.10969	validation_1-rmse:20.71230
# [79]	validation_0-rmse:11.07412	validation_1-rmse:20.69784
# [80]	validation_0-rmse:11.04771	validation_1-rmse:20.62989
# [81]	validation_0-rmse:11.01284	validation_1-rmse:20.52079
# [82]	validation_0-rmse:10.98764	validation_1-rmse:20.52380
# [83]	validation_0-rmse:10.94185	validation_1-rmse:20.51177
# [84]	validation_0-rmse:10.90113	validation_1-rmse:20.51788
# [85]	validation_0-rmse:10.87034	validation_1-rmse:20.58103
# [86]	validation_0-rmse:10.84513	validation_1-rmse:20.55286
# [87]	validation_0-rmse:10.80710	validation_1-rmse:20.53742
# [88]	validation_0-rmse:10.78146	validation_1-rmse:20.48028
# [89]	validation_0-rmse:10.75902	validation_1-rmse:20.44874
# [90]	validation_0-rmse:10.74266	validation_1-rmse:20.44527
# [91]	validation_0-rmse:10.67114	validation_1-rmse:20.45801
# [92]	validation_0-rmse:10.66124	validation_1-rmse:20.48061
# [93]	validation_0-rmse:10.62686	validation_1-rmse:20.43374
# [94]	validation_0-rmse:10.61952	validation_1-rmse:20.42466
# [95]	validation_0-rmse:10.60198	validation_1-rmse:20.32684
# [96]	validation_0-rmse:10.52938	validation_1-rmse:20.29242
# [97]	validation_0-rmse:10.52243	validation_1-rmse:20.32093
# [98]	validation_0-rmse:10.48145	validation_1-rmse:20.30960
# [99]	validation_0-rmse:10.46996	validation_1-rmse:20.29647
# [100]	validation_0-rmse:10.43517	validation_1-rmse:20.24101
# [101]	validation_0-rmse:10.41963	validation_1-rmse:20.27324
# [102]	validation_0-rmse:10.39814	validation_1-rmse:20.18288
# [103]	validation_0-rmse:10.36644	validation_1-rmse:20.12926
# [104]	validation_0-rmse:10.33464	validation_1-rmse:20.16647
# [105]	validation_0-rmse:10.27175	validation_1-rmse:20.13603
# [106]	validation_0-rmse:10.25059	validation_1-rmse:20.11032
# [107]	validation_0-rmse:10.24038	validation_1-rmse:20.10198
# [108]	validation_0-rmse:10.20799	validation_1-rmse:20.14443
# [109]	validation_0-rmse:10.19335	validation_1-rmse:20.18552
# [110]	validation_0-rmse:10.16942	validation_1-rmse:20.24883
# [111]	validation_0-rmse:10.13650	validation_1-rmse:20.22769
# [112]	validation_0-rmse:10.10530	validation_1-rmse:20.18799
# [113]	validation_0-rmse:10.09567	validation_1-rmse:20.16523
# [114]	validation_0-rmse:10.07765	validation_1-rmse:20.15638
# [115]	validation_0-rmse:10.06624	validation_1-rmse:20.16355
# [116]	validation_0-rmse:10.05605	validation_1-rmse:20.10637
# [117]	validation_0-rmse:10.03832	validation_1-rmse:20.16461
# [118]	validation_0-rmse:10.03226	validation_1-rmse:20.20147
# [119]	validation_0-rmse:10.00996	validation_1-rmse:20.21313
# [120]	validation_0-rmse:9.99980	validation_1-rmse:20.16457
# [121]	validation_0-rmse:9.98065	validation_1-rmse:20.18295
# [122]	validation_0-rmse:9.95304	validation_1-rmse:20.14467
# [123]	validation_0-rmse:9.92864	validation_1-rmse:20.13610
# [124]	validation_0-rmse:9.89268	validation_1-rmse:20.11972
# [125]	validation_0-rmse:9.85907	validation_1-rmse:20.06487
# [126]	validation_0-rmse:9.83141	validation_1-rmse:20.08556
# [127]	validation_0-rmse:9.82837	validation_1-rmse:20.01333
# [128]	validation_0-rmse:9.80726	validation_1-rmse:20.00973
# [129]	validation_0-rmse:9.77747	validation_1-rmse:20.01009
# [130]	validation_0-rmse:9.76707	validation_1-rmse:20.08137
# [131]	validation_0-rmse:9.76361	validation_1-rmse:20.08430
# [132]	validation_0-rmse:9.72589	validation_1-rmse:20.11387
# [133]	validation_0-rmse:9.69240	validation_1-rmse:20.09812
# [134]	validation_0-rmse:9.67012	validation_1-rmse:20.11231
# [135]	validation_0-rmse:9.63530	validation_1-rmse:20.10778
# [136]	validation_0-rmse:9.60840	validation_1-rmse:20.13725
# [137]	validation_0-rmse:9.58216	validation_1-rmse:20.12876
# [138]	validation_0-rmse:9.57491	validation_1-rmse:20.18496
# [139]	validation_0-rmse:9.56902	validation_1-rmse:20.11010
# [140]	validation_0-rmse:9.54635	validation_1-rmse:20.13285
# [141]	validation_0-rmse:9.52569	validation_1-rmse:20.09341
# [142]	validation_0-rmse:9.49465	validation_1-rmse:20.06101
# [143]	validation_0-rmse:9.47909	validation_1-rmse:20.05453
# [144]	validation_0-rmse:9.44895	validation_1-rmse:20.05355
# [145]	validation_0-rmse:9.42780	validation_1-rmse:20.05261
# [146]	validation_0-rmse:9.40848	validation_1-rmse:20.07586
# [147]	validation_0-rmse:9.39622	validation_1-rmse:20.10535
# [148]	validation_0-rmse:9.38863	validation_1-rmse:20.07672
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:92.55494	validation_1-rmse:87.42418
# [1]	validation_0-rmse:69.91555	validation_1-rmse:66.76102
# [2]	validation_0-rmse:54.09401	validation_1-rmse:52.20192
# [3]	validation_0-rmse:41.98251	validation_1-rmse:41.85078
# [4]	validation_0-rmse:34.54259	validation_1-rmse:34.82945
# [5]	validation_0-rmse:28.51591	validation_1-rmse:29.06046
# [6]	validation_0-rmse:24.66393	validation_1-rmse:25.64252
# [7]	validation_0-rmse:22.24327	validation_1-rmse:23.37246
# [8]	validation_0-rmse:20.67239	validation_1-rmse:21.96992
# [9]	validation_0-rmse:19.80218	validation_1-rmse:20.93092
# [10]	validation_0-rmse:18.95644	validation_1-rmse:19.96777
# [11]	validation_0-rmse:18.13095	validation_1-rmse:19.08075
# [105]	validation_0-rmse:10.79138	validation_1-rmse:15.20608
# [106]	validation_0-rmse:10.76891	validation_1-rmse:15.20100
# [107]	validation_0-rmse:10.73861	validation_1-rmse:15.18257
# [108]	validation_0-rmse:10.72089	validation_1-rmse:15.14398
# [109]	validation_0-rmse:10.70770	validation_1-rmse:15.15107
# [110]	validation_0-rmse:10.67901	validation_1-rmse:15.15330
# [111]	validation_0-rmse:10.67478	validation_1-rmse:15.15076
# [112]	validation_0-rmse:10.63718	validation_1-rmse:15.12585
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['16%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(1, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.939
# Uncertainty
# a0: 6.29+/-1.012
# a1: 0.9397+/-0.008

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: BA_sq_m_ha: mean - 25.594, median - 25.58, CI - [24.991-26.312]
#
# SHAP-values for: DBH_cm: mean - 3.635, median - 3.527, CI - [2.938-4.222]
#
# SHAP-values for: H_m: mean - 33.953, median - 34.432, CI - [31.68-35.787]
#
# SHAP-values for: Origin_ID: mean - 0.427, median - 0.367, CI - [0.189-0.677]
#
# SHAP-values for: Species_ID: mean - 8.453, median - 8.494, CI - [8.044-8.942]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['H_m', 'BA_sq_m_ha', 'Species_ID', 'DBH_cm', 'Origin_ID'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# %%
# Output calculated stat
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Aggregate optimal number of iterations statistic:
#  mean: 92.98, median: 88.5,
#  pred. interval (P(0.025)-P(0.975)): 24.0-184.125,
#  conf. interval (p-value=0.95): 56.748-130.234
# ***
# Aggregate bias statistic:
#  mean: 0.12, median: -0.017,
#  pred. interval (P(0.025)-P(0.975)): -2.711-3.086,
#  conf. interval (p-value=0.95): -1.159-1.482
# ***
# Aggregate RMSE statistic:
#  mean: 16.806, median: 16.601, pred. interval (P(0.025)-P(0.975)): 14.037-20.061,
#  conf. interval (p-value=0.95): 15.425-18.438
# ***
# Aggregate MSE statistic:
#  mean: 284.872, median: 275.599, pred. interval (P(0.025)-P(0.975)): 197.028-402.433,
#  conf. interval (p-value=0.95): 238.085-340.353
# ***
# Aggregate R^2 statistic:
#  mean: 0.938, median: 0.94, pred. interval (P(0.025)-P(0.975)): 0.911-0.959,
#  conf. interval (p-value=0.95): 0.927-0.949
# ***
# Aggregate bias(%) statistic:
#  mean: 0.13, median: -0.017, pred. interval (P(0.025)-P(0.975)): -2.566-3.18,
#  conf. interval (p-value=0.95): -1.125-1.447
# ***
# Aggregate RMSE(%) statistic:
#  mean: 16.441, median: 16.364, pred. interval (P(0.025)-P(0.975)): 13.919-19.566,
#  conf. interval (p-value=0.95): 15.152-17.743
# ***

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:91.47957
# [1]	validation_0-rmse:68.99065
# [2]	validation_0-rmse:53.25968
# [3]	validation_0-rmse:41.94202
# [4]	validation_0-rmse:34.15165
# [5]	validation_0-rmse:28.50616
# [6]	validation_0-rmse:24.93936
# [7]	validation_0-rmse:22.75687
# [8]	validation_0-rmse:20.87945
# [9]	validation_0-rmse:19.86507
# [10]	validation_0-rmse:18.98112
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [11]	validation_0-rmse:18.46729
# [12]	validation_0-rmse:17.95234
# [13]	validation_0-rmse:17.54962
# [14]	validation_0-rmse:17.31783
# [15]	validation_0-rmse:16.89449
# [16]	validation_0-rmse:16.63002
# [17]	validation_0-rmse:16.51595
# [18]	validation_0-rmse:16.32756
# [19]	validation_0-rmse:16.23229
# [20]	validation_0-rmse:16.12745
# [21]	validation_0-rmse:15.95686
# [22]	validation_0-rmse:15.89077
# [23]	validation_0-rmse:15.79260
# [24]	validation_0-rmse:15.66782
# [25]	validation_0-rmse:15.54923
# [26]	validation_0-rmse:15.42540
# [27]	validation_0-rmse:15.29382
# [28]	validation_0-rmse:15.11063
# [29]	validation_0-rmse:15.03550
# [30]	validation_0-rmse:14.99136
# [31]	validation_0-rmse:14.95431
# [32]	validation_0-rmse:14.84599
# [33]	validation_0-rmse:14.73727
# [34]	validation_0-rmse:14.66033
# [35]	validation_0-rmse:14.60389
# [36]	validation_0-rmse:14.45579
# [37]	validation_0-rmse:14.26415
# [38]	validation_0-rmse:14.21655
# [39]	validation_0-rmse:14.14399
# [40]	validation_0-rmse:14.07029
# [41]	validation_0-rmse:14.04078
# [42]	validation_0-rmse:13.97596
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 198

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.03
# RMSE: 9.6
# Relative RMSE(%):  9.344
# MSE: 91.9
# R square: 98.1%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0.9, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.981
# Uncertainty
# a0: 2.4+/-0.6
# a1: 0.977+/-0.005

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [18, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../01_output_data/XGBoost_models/02_M_all_stem_other_authors_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../01_output_data/XGBoost_models/02_M_all_stem_other_authors_XGB_model.txt")
