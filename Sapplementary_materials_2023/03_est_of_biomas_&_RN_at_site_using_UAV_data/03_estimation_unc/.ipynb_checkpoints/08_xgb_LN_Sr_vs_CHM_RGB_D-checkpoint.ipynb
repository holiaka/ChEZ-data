# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../03_input_data/input_CHM_&_spectral_data_site2020.xlsx'
df = pd.read_excel(site_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'ln_Tag_Cs', 'ln_Tag_Sr', 'AEDR_mean',
                                    'mf_chm_MIN', 'r_MIN', 'b_STD', 'contr_r_STD', 'corr_r_Q25', 'corr_r_MIN'])
            
# Show the first five columns
select.head()
# Out:
#    ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  ln_Tag_Sr  \
# 0       6.824       9.240           1912            784     -0.731      2.576
# 1       8.189       9.622           2005            818      0.585      2.915
# 2       8.380       9.589           2001            818      0.779      2.882
# 3       8.137       9.449           2040            833      0.517      2.724
# 4       7.696       9.401           1758            717      0.224      2.826
#
#    AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  corr_r_Q25  \
# 0       2.33    0.445070     13  35.145074   360.273487    0.488754
# 1       2.47   12.465903     24  36.135511   323.958625    0.501683
# 2       2.44   13.028298     18  35.938764   299.438354    0.540056
# 3       2.55    2.128231     15  35.908361   319.773395    0.480991
# 4       2.14   12.171553      8  38.062522   353.104284    0.505257
#
#    corr_r_MIN
# 0    0.072792
# 1    0.098347
# 2    0.187811
# 3    0.020686
# 4    0.106549

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ln_Cs_wood     103 non-null    float64
#  1   ln_Sr_wood     103 non-null    float64
#  2   Cs_2021_kBq_m  103 non-null    int64
#  3   Sr_2021_kBq_m  103 non-null    int64
#  4   ln_Tag_Cs      103 non-null    float64
#  5   ln_Tag_Sr      103 non-null    float64
#  6   AEDR_mean      103 non-null    float64
#  7   mf_chm_MIN     103 non-null    float64
#  8   r_MIN          103 non-null    int64
#  9   b_STD          103 non-null    float64
#  10  contr_r_STD    103 non-null    float64
#  11  corr_r_Q25     103 non-null    float64
#  12  corr_r_MIN     103 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 10.6 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Cs_wood", "ln_Sr_wood"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                  ln_Cs_wood                                                 \
#                       count       mean       std     min      25%      50%
# Dominant_specias
# Alder                   4.0   7.305000  1.427622   5.886   6.6765   7.0235
# Aspen                   1.0  11.367000       NaN  11.367  11.3670  11.3670
# Birch                  23.0   7.304652  1.533182   4.533   6.3365   7.2150
# Oak                     3.0   7.430333  1.260072   6.040   6.8970   7.7540
# Pine                   71.0   6.901690  1.650166   3.526   6.3790   6.9470
# Spruce                  1.0   5.176000       NaN   5.176   5.1760   5.1760
#
#                                   ln_Sr_wood                               \
#                       75%     max      count       mean       std     min
# Dominant_specias
# Alder              7.6520   9.287        4.0   7.206000  0.650057   6.265
# Aspen             11.3670  11.367        1.0  11.090000       NaN  11.090
# Birch              8.0320  10.332       23.0   9.345478  1.626360   7.139
# Oak                8.1255   8.497        3.0   7.483667  0.815040   6.565
# Pine               7.6960  10.469       71.0   8.542592  1.359020   6.075
# Spruce             5.1760   5.176        1.0   7.783000       NaN   7.783
#
#
#                       25%      50%      75%     max
# Dominant_specias
# Alder              7.0255   7.4545   7.6350   7.650
# Aspen             11.0900  11.0900  11.0900  11.090
# Birch              8.4000   8.9910   9.9365  13.864
# Oak                7.1655   7.7660   7.9430   8.120
# Pine               7.6450   8.4720   9.3710  12.687
# Spruce             7.7830   7.7830   7.7830   7.783

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m   ln_Tag_Cs  \
# count   103.00000  103.000000     103.000000     103.000000  103.000000
# mean      7.04933    8.656485    3014.359223    1136.436893   -0.252563
# std       1.64946    1.472424    4988.505540    2019.773384    1.104610
# min       3.52600    6.075000     423.000000      98.000000   -3.033000
# 25%       6.31900    7.664000     635.500000     199.500000   -0.727500
# 50%       6.95700    8.472000    1145.000000     362.000000   -0.025000
# 75%       7.91350    9.421000    2423.500000     966.000000    0.516500
# max      11.36700   13.864000   25173.000000   10477.000000    1.652000
#
#         ln_Tag_Sr   AEDR_mean  mf_chm_MIN       r_MIN       b_STD  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000
# mean     2.464709    3.570291    3.368496   11.378641   35.164575
# std      0.904675    6.089170    4.845054    9.139568    5.338700
# min      0.391000    0.480000   -0.018586    2.000000   20.570709
# 25%      1.803000    0.710000    0.482279    5.000000   31.746440
# 50%      2.603000    1.290000    0.642883    8.000000   36.135511
# 75%      3.159000    2.960000    3.921804   15.000000   39.139044
# max      4.659000   36.590000   17.862923   56.000000   45.825416
#
#        contr_r_STD  corr_r_Q25  corr_r_MIN
# count   103.000000  103.000000  103.000000
# mean    327.115078    0.393571    0.073579
# std     167.617957    0.151801    0.056017
# min       0.091058    0.033797   -0.062450
# 25%     283.887328    0.407228    0.027204
# 50%     353.034542    0.449670    0.063714
# 75%     448.017711    0.476635    0.110983
# max     652.546648    0.555648    0.241284

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_Cs_wood"
indep_variables = ['contr_r_STD', 'corr_r_Q25', 'AEDR_mean']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Cs_wood  ln_Sr_wood  Cs_2021_kBq_m  Sr_2021_kBq_m  ln_Tag_Cs  \
# 0         6.824       9.240           1912            784     -0.731
# 1         8.189       9.622           2005            818      0.585
# 2         8.380       9.589           2001            818      0.779
# 3         8.137       9.449           2040            833      0.517
# 4         7.696       9.401           1758            717      0.224
# ..          ...         ...            ...            ...        ...
# 98        8.071       8.434           2548           1012      0.228
# 99        7.993      10.042           2267            908      0.266
# 100       8.343      10.488           2441            975      0.543
# 101       3.638       6.399            632            269     -2.811
# 102       4.787       6.877            676            292     -1.728
#
#      ln_Tag_Sr  AEDR_mean  mf_chm_MIN  r_MIN      b_STD  contr_r_STD  \
# 0        2.576       2.33    0.445070     13  35.145074   360.273487
# 1        2.915       2.47   12.465903     24  36.135511   323.958625
# 2        2.882       2.44   13.028298     18  35.938764   299.438354
# 3        2.724       2.55    2.128231     15  35.908361   319.773395
# 4        2.826       2.14   12.171553      8  38.062522   353.104284
# ..         ...        ...         ...    ...        ...          ...
# 98       1.514       2.92    0.528681      3  32.852994   329.221211
# 99       3.230       2.78    0.422647     18  27.970146   268.895699
# 100      3.606       2.92    0.426717     19  30.529613   251.314791
# 101      0.805       0.75    0.476680      6  37.245047   477.751734
# 102      1.199       0.78    0.410141      2  38.454424   412.535053
#
#      corr_r_Q25  corr_r_MIN
# 0      0.488754    0.072792
# 1      0.501683    0.098347
# 2      0.540056    0.187811
# 3      0.480991    0.020686
# 4      0.505257    0.106549
# ..          ...         ...
# 98     0.478581    0.079646
# 99     0.467111    0.063714
# 100    0.501777    0.128376
# 101    0.467443    0.129664
# 102    0.480964    0.157460
#
# [103 rows x 13 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    contr_r_STD  corr_r_Q25  AEDR_mean
# 0   360.273487    0.488754       2.33
# 1   323.958625    0.501683       2.47
# 2   299.438354    0.540056       2.44
# 3   319.773395    0.480991       2.55
# 4   353.104284    0.505257       2.14

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_Cs_wood
# 0       6.824
# 1       8.189
# 2       8.380
# 3       8.137
# 4       7.696

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.2695461185752447, 0.6235901941445616, 0.5264226015768465]
#     Mean: 0.473
#     Std: 0.149
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [1.16937229 0.91191117 1.16845602]
#     Mean: 1.083
#     Std: 0.121
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.9138592914581299, 0.7785130062664256, 0.8290936979406021]
#     Mean: 0.840
#     Std: 0.056
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.9212602280924751                   # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.2075762813132193                  # gamma
print('Gamma: ' + str(p2))

p3 = 0.047829301314752076                # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2            # max_depth
print('Max_depth: ' + str(p4))

p5 = 125           # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.5305811756183811                   # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.9212602280924751
# Gamma: 0.2075762813132193
# Learning_rate: 0.047829301314752076
# Max_depth: 2
# N_estimators: 125
# Subsample: 0.5305811756183811

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:6.39110	validation_1-rmse:6.72688
# [1]	validation_0-rmse:6.10892	validation_1-rmse:6.43475
# [2]	validation_0-rmse:5.83195	validation_1-rmse:6.15437
# [3]	validation_0-rmse:5.57187	validation_1-rmse:5.88357
# [4]	validation_0-rmse:5.33724	validation_1-rmse:5.64581
# [5]	validation_0-rmse:5.10020	validation_1-rmse:5.39951
# [6]	validation_0-rmse:4.87856	validation_1-rmse:5.17123
# [7]	validation_0-rmse:4.68105	validation_1-rmse:4.96326
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:4.47868	validation_1-rmse:4.75303
# [9]	validation_0-rmse:4.28712	validation_1-rmse:4.55661
# [10]	validation_0-rmse:4.10061	validation_1-rmse:4.36389
# [11]	validation_0-rmse:3.93452	validation_1-rmse:4.18348
# [12]	validation_0-rmse:3.77898	validation_1-rmse:4.02449
# [13]	validation_0-rmse:3.62101	validation_1-rmse:3.86206
# [14]	validation_0-rmse:3.47455	validation_1-rmse:3.71034
# [15]	validation_0-rmse:3.34287	validation_1-rmse:3.57600
# [16]	validation_0-rmse:3.20421	validation_1-rmse:3.42395
# [17]	validation_0-rmse:3.07658	validation_1-rmse:3.28511
# [18]	validation_0-rmse:2.95946	validation_1-rmse:3.16101
# [19]	validation_0-rmse:2.84135	validation_1-rmse:3.03910
# [20]	validation_0-rmse:2.72447	validation_1-rmse:2.91804
# [21]	validation_0-rmse:2.60502	validation_1-rmse:2.79611
# [22]	validation_0-rmse:2.50992	validation_1-rmse:2.69871
# [23]	validation_0-rmse:2.42414	validation_1-rmse:2.60737
# [24]	validation_0-rmse:2.33254	validation_1-rmse:2.50757
# [25]	validation_0-rmse:2.23845	validation_1-rmse:2.40616
# [26]	validation_0-rmse:2.16573	validation_1-rmse:2.33166
# [27]	validation_0-rmse:2.09120	validation_1-rmse:2.25396
# [28]	validation_0-rmse:2.01886	validation_1-rmse:2.17631
# [29]	validation_0-rmse:1.95196	validation_1-rmse:2.10711
# [30]	validation_0-rmse:1.88521	validation_1-rmse:2.04287
# [31]	validation_0-rmse:1.81881	validation_1-rmse:1.97904
# [32]	validation_0-rmse:1.74921	validation_1-rmse:1.90245
# [33]	validation_0-rmse:1.69149	validation_1-rmse:1.83494
# [34]	validation_0-rmse:1.64198	validation_1-rmse:1.78759
# [35]	validation_0-rmse:1.59192	validation_1-rmse:1.73304
# [36]	validation_0-rmse:1.54044	validation_1-rmse:1.67945
# [37]	validation_0-rmse:1.49430	validation_1-rmse:1.63280
# [38]	validation_0-rmse:1.44893	validation_1-rmse:1.58690
# [39]	validation_0-rmse:1.40756	validation_1-rmse:1.54539
# [40]	validation_0-rmse:1.36981	validation_1-rmse:1.50893
# [41]	validation_0-rmse:1.33353	validation_1-rmse:1.46893
# [42]	validation_0-rmse:1.29747	validation_1-rmse:1.43350
# [43]	validation_0-rmse:1.26378	validation_1-rmse:1.39883
# [44]	validation_0-rmse:1.23112	validation_1-rmse:1.36016
# [45]	validation_0-rmse:1.19822	validation_1-rmse:1.32588
# [46]	validation_0-rmse:1.16939	validation_1-rmse:1.29566
# [47]	validation_0-rmse:1.14488	validation_1-rmse:1.27122
# [48]	validation_0-rmse:1.12118	validation_1-rmse:1.24697
# [49]	validation_0-rmse:1.10232	validation_1-rmse:1.22398
# [50]	validation_0-rmse:1.07567	validation_1-rmse:1.19818
# [51]	validation_0-rmse:1.04994	validation_1-rmse:1.17479
# [52]	validation_0-rmse:1.03213	validation_1-rmse:1.15579
# [53]	validation_0-rmse:1.01971	validation_1-rmse:1.14379
# [54]	validation_0-rmse:1.00239	validation_1-rmse:1.12770
# [55]	validation_0-rmse:0.98460	validation_1-rmse:1.11038
# [56]	validation_0-rmse:0.97054	validation_1-rmse:1.09841
# [57]	validation_0-rmse:0.95633	validation_1-rmse:1.08679
# [58]	validation_0-rmse:0.94829	validation_1-rmse:1.08148
# [59]	validation_0-rmse:0.93789	validation_1-rmse:1.07672
# [60]	validation_0-rmse:0.92668	validation_1-rmse:1.06453
# [61]	validation_0-rmse:0.91641	validation_1-rmse:1.05949
# [62]	validation_0-rmse:0.90258	validation_1-rmse:1.04432
# [63]	validation_0-rmse:0.89320	validation_1-rmse:1.03727
# [64]	validation_0-rmse:0.88085	validation_1-rmse:1.02922
# [65]	validation_0-rmse:0.87220	validation_1-rmse:1.01988
# [66]	validation_0-rmse:0.86616	validation_1-rmse:1.01283
# [67]	validation_0-rmse:0.85446	validation_1-rmse:1.01172
# [68]	validation_0-rmse:0.84679	validation_1-rmse:1.00644
# [69]	validation_0-rmse:0.83974	validation_1-rmse:0.99421
# [70]	validation_0-rmse:0.82917	validation_1-rmse:0.99195
# [71]	validation_0-rmse:0.82178	validation_1-rmse:0.99151
# [72]	validation_0-rmse:0.81253	validation_1-rmse:0.98953
# [73]	validation_0-rmse:0.81033	validation_1-rmse:0.99021
# [74]	validation_0-rmse:0.80381	validation_1-rmse:0.98825
# [75]	validation_0-rmse:0.79752	validation_1-rmse:0.98693
# [76]	validation_0-rmse:0.79599	validation_1-rmse:0.98202
# [77]	validation_0-rmse:0.79019	validation_1-rmse:0.98074
# [78]	validation_0-rmse:0.78627	validation_1-rmse:0.98160
# [79]	validation_0-rmse:0.78035	validation_1-rmse:0.98056
# [80]	validation_0-rmse:0.77676	validation_1-rmse:0.98024
# [81]	validation_0-rmse:0.77291	validation_1-rmse:0.98430
# [82]	validation_0-rmse:0.76942	validation_1-rmse:0.98898
# [83]	validation_0-rmse:0.75831	validation_1-rmse:0.98647
# [84]	validation_0-rmse:0.75393	validation_1-rmse:0.98433
# [85]	validation_0-rmse:0.74972	validation_1-rmse:0.98279
# [86]	validation_0-rmse:0.74717	validation_1-rmse:0.98013
# [87]	validation_0-rmse:0.74521	validation_1-rmse:0.97580
# [88]	validation_0-rmse:0.74031	validation_1-rmse:0.97586
# [89]	validation_0-rmse:0.73766	validation_1-rmse:0.97548
# [90]	validation_0-rmse:0.73346	validation_1-rmse:0.97561
# [91]	validation_0-rmse:0.72648	validation_1-rmse:0.97386
# [92]	validation_0-rmse:0.72148	validation_1-rmse:0.97348
# [93]	validation_0-rmse:0.71938	validation_1-rmse:0.97720
# [94]	validation_0-rmse:0.71679	validation_1-rmse:0.97659
# [95]	validation_0-rmse:0.71531	validation_1-rmse:0.97901
# [96]	validation_0-rmse:0.71295	validation_1-rmse:0.97979
# [97]	validation_0-rmse:0.71105	validation_1-rmse:0.97763
# [98]	validation_0-rmse:0.70906	validation_1-rmse:0.96892
# [99]	validation_0-rmse:0.70836	validation_1-rmse:0.96949
# [100]	validation_0-rmse:0.70664	validation_1-rmse:0.96814
# [101]	validation_0-rmse:0.70463	validation_1-rmse:0.97392
# [102]	validation_0-rmse:0.70288	validation_1-rmse:0.96374
# [103]	validation_0-rmse:0.70144	validation_1-rmse:0.96323
# [104]	validation_0-rmse:0.69637	validation_1-rmse:0.96326
# [105]	validation_0-rmse:0.69490	validation_1-rmse:0.95809
# [106]	validation_0-rmse:0.69350	validation_1-rmse:0.95754
# [107]	validation_0-rmse:0.69213	validation_1-rmse:0.96208
# [108]	validation_0-rmse:0.68919	validation_1-rmse:0.96812
# [109]	validation_0-rmse:0.68782	validation_1-rmse:0.96748
# [110]	validation_0-rmse:0.68610	validation_1-rmse:0.96804
# [111]	validation_0-rmse:0.68467	validation_1-rmse:0.97686
# [112]	validation_0-rmse:0.68177	validation_1-rmse:0.98059
# [113]	validation_0-rmse:0.67925	validation_1-rmse:0.97854
# [114]	validation_0-rmse:0.67747	validation_1-rmse:0.97577
# [115]	validation_0-rmse:0.67598	validation_1-rmse:0.98199
# [116]	validation_0-rmse:0.67504	validation_1-rmse:0.98441
# [117]	validation_0-rmse:0.67279	validation_1-rmse:0.98527
# [118]	validation_0-rmse:0.67065	validation_1-rmse:0.98590
# [119]	validation_0-rmse:0.66833	validation_1-rmse:0.98737
# [120]	validation_0-rmse:0.66672	validation_1-rmse:0.98388
# [121]	validation_0-rmse:0.66571	validation_1-rmse:0.98244
# [122]	validation_0-rmse:0.66466	validation_1-rmse:0.98101
# [123]	validation_0-rmse:0.66082	validation_1-rmse:0.98413
# [124]	validation_0-rmse:0.65925	validation_1-rmse:0.98188
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.44899	validation_1-rmse:6.46480
# [1]	validation_0-rmse:6.16374	validation_1-rmse:6.18575
# [2]	validation_0-rmse:5.89175	validation_1-rmse:5.90434
# [3]	validation_0-rmse:5.62807	validation_1-rmse:5.64515
# [4]	validation_0-rmse:5.38432	validation_1-rmse:5.40199
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:5.15144	validation_1-rmse:5.15531
# [6]	validation_0-rmse:4.93039	validation_1-rmse:4.93789
# [7]	validation_0-rmse:4.71162	validation_1-rmse:4.71146
# [8]	validation_0-rmse:4.51242	validation_1-rmse:4.51135
# [9]	validation_0-rmse:4.32223	validation_1-rmse:4.31684
# [10]	validation_0-rmse:4.14072	validation_1-rmse:4.11124
# [11]	validation_0-rmse:3.97210	validation_1-rmse:3.94327
# [12]	validation_0-rmse:3.80888	validation_1-rmse:3.77774
# [13]	validation_0-rmse:3.64818	validation_1-rmse:3.60679
# [14]	validation_0-rmse:3.49677	validation_1-rmse:3.45975
# [15]	validation_0-rmse:3.34998	validation_1-rmse:3.31396
# [16]	validation_0-rmse:3.22009	validation_1-rmse:3.18596
# [17]	validation_0-rmse:3.09379	validation_1-rmse:3.04481
# [18]	validation_0-rmse:2.98068	validation_1-rmse:2.93174
# [19]	validation_0-rmse:2.86517	validation_1-rmse:2.81450
# [20]	validation_0-rmse:2.76168	validation_1-rmse:2.70575
# [21]	validation_0-rmse:2.65232	validation_1-rmse:2.60301
# [22]	validation_0-rmse:2.54695	validation_1-rmse:2.49076
# [23]	validation_0-rmse:2.44381	validation_1-rmse:2.38718
# [24]	validation_0-rmse:2.35602	validation_1-rmse:2.29633
# [25]	validation_0-rmse:2.26865	validation_1-rmse:2.21354
# [26]	validation_0-rmse:2.19165	validation_1-rmse:2.13724
# [27]	validation_0-rmse:2.11458	validation_1-rmse:2.05846
# [28]	validation_0-rmse:2.04418	validation_1-rmse:1.98786
# [29]	validation_0-rmse:1.98177	validation_1-rmse:1.92540
# [30]	validation_0-rmse:1.92128	validation_1-rmse:1.86700
# [31]	validation_0-rmse:1.85097	validation_1-rmse:1.79709
# [32]	validation_0-rmse:1.79049	validation_1-rmse:1.73706
# [33]	validation_0-rmse:1.73450	validation_1-rmse:1.66915
# [34]	validation_0-rmse:1.67986	validation_1-rmse:1.61292
# [35]	validation_0-rmse:1.63084	validation_1-rmse:1.55750
# [36]	validation_0-rmse:1.56873	validation_1-rmse:1.50316
# [37]	validation_0-rmse:1.52205	validation_1-rmse:1.45427
# [38]	validation_0-rmse:1.47745	validation_1-rmse:1.40411
# [39]	validation_0-rmse:1.43202	validation_1-rmse:1.35909
# [40]	validation_0-rmse:1.39556	validation_1-rmse:1.32340
# [41]	validation_0-rmse:1.35764	validation_1-rmse:1.28883
# [42]	validation_0-rmse:1.32414	validation_1-rmse:1.25062
# [43]	validation_0-rmse:1.29205	validation_1-rmse:1.21674
# [44]	validation_0-rmse:1.26101	validation_1-rmse:1.19024
# [45]	validation_0-rmse:1.23286	validation_1-rmse:1.17061
# [46]	validation_0-rmse:1.20066	validation_1-rmse:1.13561
# [47]	validation_0-rmse:1.16660	validation_1-rmse:1.10546
# [48]	validation_0-rmse:1.14262	validation_1-rmse:1.07718
# [49]	validation_0-rmse:1.12359	validation_1-rmse:1.05768
# [50]	validation_0-rmse:1.09642	validation_1-rmse:1.03299
# [51]	validation_0-rmse:1.07394	validation_1-rmse:1.01035
# [52]	validation_0-rmse:1.05632	validation_1-rmse:0.99479
# [53]	validation_0-rmse:1.04204	validation_1-rmse:0.97882
# [54]	validation_0-rmse:1.02945	validation_1-rmse:0.96563
# [55]	validation_0-rmse:1.01541	validation_1-rmse:0.95380
# [56]	validation_0-rmse:1.00435	validation_1-rmse:0.94624
# [57]	validation_0-rmse:0.98752	validation_1-rmse:0.93250
# [58]	validation_0-rmse:0.97605	validation_1-rmse:0.92519
# [59]	validation_0-rmse:0.96456	validation_1-rmse:0.91163
# [60]	validation_0-rmse:0.94662	validation_1-rmse:0.89176
# [61]	validation_0-rmse:0.93387	validation_1-rmse:0.88029
# [62]	validation_0-rmse:0.92283	validation_1-rmse:0.86667
# [63]	validation_0-rmse:0.91287	validation_1-rmse:0.85650
# [64]	validation_0-rmse:0.90689	validation_1-rmse:0.85206
# [65]	validation_0-rmse:0.89891	validation_1-rmse:0.84388
# [66]	validation_0-rmse:0.88643	validation_1-rmse:0.84267
# [67]	validation_0-rmse:0.87528	validation_1-rmse:0.83651
# [68]	validation_0-rmse:0.87047	validation_1-rmse:0.83480
# [69]	validation_0-rmse:0.86593	validation_1-rmse:0.83144
# [70]	validation_0-rmse:0.85785	validation_1-rmse:0.82996
# [71]	validation_0-rmse:0.85219	validation_1-rmse:0.81974
# [72]	validation_0-rmse:0.84751	validation_1-rmse:0.81525
# [73]	validation_0-rmse:0.84347	validation_1-rmse:0.81201
# [74]	validation_0-rmse:0.83438	validation_1-rmse:0.80104
# [75]	validation_0-rmse:0.83070	validation_1-rmse:0.79980
# [76]	validation_0-rmse:0.82415	validation_1-rmse:0.79745
# [77]	validation_0-rmse:0.81848	validation_1-rmse:0.79059
# [78]	validation_0-rmse:0.81533	validation_1-rmse:0.78689
# [79]	validation_0-rmse:0.80863	validation_1-rmse:0.77889
# [80]	validation_0-rmse:0.80645	validation_1-rmse:0.77735
# [81]	validation_0-rmse:0.80221	validation_1-rmse:0.77418
# [82]	validation_0-rmse:0.79497	validation_1-rmse:0.76343
# [83]	validation_0-rmse:0.79348	validation_1-rmse:0.76227
# [84]	validation_0-rmse:0.78675	validation_1-rmse:0.75458
# [85]	validation_0-rmse:0.78352	validation_1-rmse:0.75523
# [86]	validation_0-rmse:0.77989	validation_1-rmse:0.75496
# [87]	validation_0-rmse:0.77209	validation_1-rmse:0.75985
# [88]	validation_0-rmse:0.76889	validation_1-rmse:0.75390
# [89]	validation_0-rmse:0.76330	validation_1-rmse:0.75777
# [90]	validation_0-rmse:0.76032	validation_1-rmse:0.75830
# [91]	validation_0-rmse:0.75710	validation_1-rmse:0.76376
# [92]	validation_0-rmse:0.75402	validation_1-rmse:0.76588
# [93]	validation_0-rmse:0.75175	validation_1-rmse:0.76504
# [94]	validation_0-rmse:0.74993	validation_1-rmse:0.76736
# [95]	validation_0-rmse:0.74858	validation_1-rmse:0.76727
# [96]	validation_0-rmse:0.74614	validation_1-rmse:0.76517
# [97]	validation_0-rmse:0.74068	validation_1-rmse:0.75961
# [98]	validation_0-rmse:0.73819	validation_1-rmse:0.76092
# [99]	validation_0-rmse:0.73692	validation_1-rmse:0.76118
# [100]	validation_0-rmse:0.73604	validation_1-rmse:0.76286
# [101]	validation_0-rmse:0.73594	validation_1-rmse:0.76289
# [102]	validation_0-rmse:0.73366	validation_1-rmse:0.76403
# [103]	validation_0-rmse:0.73087	validation_1-rmse:0.76561
# [104]	validation_0-rmse:0.72679	validation_1-rmse:0.76142
# [105]	validation_0-rmse:0.72525	validation_1-rmse:0.76167
# [106]	validation_0-rmse:0.72484	validation_1-rmse:0.76369
# [107]	validation_0-rmse:0.72200	validation_1-rmse:0.76575
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.56133	validation_1-rmse:5.97886
# [1]	validation_0-rmse:6.27944	validation_1-rmse:5.70802
# [2]	validation_0-rmse:5.99785	validation_1-rmse:5.44754
# [3]	validation_0-rmse:5.75297	validation_1-rmse:5.19965
# [4]	validation_0-rmse:5.50082	validation_1-rmse:4.94448
# [5]	validation_0-rmse:5.25866	validation_1-rmse:4.72462
# [6]	validation_0-rmse:5.02757	validation_1-rmse:4.51644
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:4.81069	validation_1-rmse:4.30458
# [8]	validation_0-rmse:4.60727	validation_1-rmse:4.11750
# [9]	validation_0-rmse:4.40181	validation_1-rmse:3.93102
# [10]	validation_0-rmse:4.20853	validation_1-rmse:3.74854
# [11]	validation_0-rmse:4.03170	validation_1-rmse:3.58972
# [12]	validation_0-rmse:3.86530	validation_1-rmse:3.44574
# [13]	validation_0-rmse:3.70497	validation_1-rmse:3.29369
# [14]	validation_0-rmse:3.55223	validation_1-rmse:3.15619
# [15]	validation_0-rmse:3.40347	validation_1-rmse:3.01693
# [16]	validation_0-rmse:3.25790	validation_1-rmse:2.88601
# [17]	validation_0-rmse:3.13149	validation_1-rmse:2.77116
# [18]	validation_0-rmse:3.00798	validation_1-rmse:2.65541
# [19]	validation_0-rmse:2.89360	validation_1-rmse:2.54135
# [20]	validation_0-rmse:2.77253	validation_1-rmse:2.43356
# [21]	validation_0-rmse:2.65055	validation_1-rmse:2.32791
# [22]	validation_0-rmse:2.54697	validation_1-rmse:2.24520
# [23]	validation_0-rmse:2.45074	validation_1-rmse:2.16744
# [24]	validation_0-rmse:2.35587	validation_1-rmse:2.08388
# [25]	validation_0-rmse:2.26386	validation_1-rmse:2.01266
# [26]	validation_0-rmse:2.17371	validation_1-rmse:1.93852
# [27]	validation_0-rmse:2.09672	validation_1-rmse:1.88223
# [28]	validation_0-rmse:2.02554	validation_1-rmse:1.82870
# [29]	validation_0-rmse:1.95107	validation_1-rmse:1.75837
# [30]	validation_0-rmse:1.87971	validation_1-rmse:1.69938
# [31]	validation_0-rmse:1.81171	validation_1-rmse:1.64670
# [32]	validation_0-rmse:1.74828	validation_1-rmse:1.59899
# [33]	validation_0-rmse:1.68547	validation_1-rmse:1.55335
# [34]	validation_0-rmse:1.63275	validation_1-rmse:1.51731
# [35]	validation_0-rmse:1.57512	validation_1-rmse:1.47496
# [36]	validation_0-rmse:1.53111	validation_1-rmse:1.44639
# [37]	validation_0-rmse:1.48462	validation_1-rmse:1.40498
# [38]	validation_0-rmse:1.44327	validation_1-rmse:1.38104
# [39]	validation_0-rmse:1.40276	validation_1-rmse:1.34777
# [40]	validation_0-rmse:1.35954	validation_1-rmse:1.31665
# [41]	validation_0-rmse:1.32056	validation_1-rmse:1.29117
# [42]	validation_0-rmse:1.27890	validation_1-rmse:1.26497
# [43]	validation_0-rmse:1.24043	validation_1-rmse:1.23671
# [44]	validation_0-rmse:1.20490	validation_1-rmse:1.21493
# [45]	validation_0-rmse:1.16827	validation_1-rmse:1.18882
# [46]	validation_0-rmse:1.14146	validation_1-rmse:1.17025
# [47]	validation_0-rmse:1.11185	validation_1-rmse:1.14432
# [48]	validation_0-rmse:1.08683	validation_1-rmse:1.13144
# [49]	validation_0-rmse:1.06481	validation_1-rmse:1.11812
# [50]	validation_0-rmse:1.04041	validation_1-rmse:1.09854
# [51]	validation_0-rmse:1.01989	validation_1-rmse:1.08337
# [52]	validation_0-rmse:1.00300	validation_1-rmse:1.07464
# [53]	validation_0-rmse:0.98428	validation_1-rmse:1.06205
# [54]	validation_0-rmse:0.96958	validation_1-rmse:1.05464
# [55]	validation_0-rmse:0.95606	validation_1-rmse:1.04771
# [56]	validation_0-rmse:0.94248	validation_1-rmse:1.04157
# [57]	validation_0-rmse:0.92944	validation_1-rmse:1.03630
# [58]	validation_0-rmse:0.91374	validation_1-rmse:1.03213
# [59]	validation_0-rmse:0.90305	validation_1-rmse:1.02555
# [60]	validation_0-rmse:0.89239	validation_1-rmse:1.01931
# [61]	validation_0-rmse:0.87738	validation_1-rmse:1.01833
# [62]	validation_0-rmse:0.86721	validation_1-rmse:1.01358
# [63]	validation_0-rmse:0.86005	validation_1-rmse:1.01234
# [64]	validation_0-rmse:0.85241	validation_1-rmse:1.00837
# [65]	validation_0-rmse:0.84132	validation_1-rmse:1.00053
# [66]	validation_0-rmse:0.83137	validation_1-rmse:0.99841
# [67]	validation_0-rmse:0.82210	validation_1-rmse:0.99431
# [68]	validation_0-rmse:0.81540	validation_1-rmse:0.99309
# [69]	validation_0-rmse:0.80761	validation_1-rmse:0.99174
# [70]	validation_0-rmse:0.80241	validation_1-rmse:0.98905
# [71]	validation_0-rmse:0.79568	validation_1-rmse:0.98985
# [72]	validation_0-rmse:0.78908	validation_1-rmse:0.99080
# [73]	validation_0-rmse:0.78360	validation_1-rmse:0.98917
# [74]	validation_0-rmse:0.77917	validation_1-rmse:0.98885
# [75]	validation_0-rmse:0.77151	validation_1-rmse:0.98731
# [76]	validation_0-rmse:0.76587	validation_1-rmse:0.98617
# [77]	validation_0-rmse:0.76105	validation_1-rmse:0.99302
# [78]	validation_0-rmse:0.75768	validation_1-rmse:0.98762
# [79]	validation_0-rmse:0.75471	validation_1-rmse:0.98553
# [80]	validation_0-rmse:0.75260	validation_1-rmse:0.98671
# [81]	validation_0-rmse:0.74937	validation_1-rmse:0.98755
# [82]	validation_0-rmse:0.74418	validation_1-rmse:0.97801
# [83]	validation_0-rmse:0.74011	validation_1-rmse:0.97451
# [84]	validation_0-rmse:0.73726	validation_1-rmse:0.97478
# [85]	validation_0-rmse:0.73484	validation_1-rmse:0.97715
# [86]	validation_0-rmse:0.73345	validation_1-rmse:0.97516
# [87]	validation_0-rmse:0.73150	validation_1-rmse:0.97712
# [88]	validation_0-rmse:0.72948	validation_1-rmse:0.97909
# [89]	validation_0-rmse:0.72445	validation_1-rmse:0.97951
# [90]	validation_0-rmse:0.72221	validation_1-rmse:0.97563
# [91]	validation_0-rmse:0.71769	validation_1-rmse:0.98027
# [92]	validation_0-rmse:0.71267	validation_1-rmse:0.98180
# [93]	validation_0-rmse:0.71189	validation_1-rmse:0.97616
# [94]	validation_0-rmse:0.70757	validation_1-rmse:0.97521
# [95]	validation_0-rmse:0.70677	validation_1-rmse:0.97200
# [96]	validation_0-rmse:0.70444	validation_1-rmse:0.97259
# [97]	validation_0-rmse:0.70168	validation_1-rmse:0.97174
# [98]	validation_0-rmse:0.70054	validation_1-rmse:0.97158
# [99]	validation_0-rmse:0.69846	validation_1-rmse:0.97350
# [100]	validation_0-rmse:0.69641	validation_1-rmse:0.97281
# [101]	validation_0-rmse:0.69236	validation_1-rmse:0.97666
# [102]	validation_0-rmse:0.68983	validation_1-rmse:0.98560
# [103]	validation_0-rmse:0.68766	validation_1-rmse:0.98482
# [104]	validation_0-rmse:0.68601	validation_1-rmse:0.98402
# [105]	validation_0-rmse:0.68467	validation_1-rmse:0.98472
# [106]	validation_0-rmse:0.68165	validation_1-rmse:0.98579
# [107]	validation_0-rmse:0.67865	validation_1-rmse:0.98172
# [108]	validation_0-rmse:0.67667	validation_1-rmse:0.98254
# [109]	validation_0-rmse:0.67580	validation_1-rmse:0.98640
# [110]	validation_0-rmse:0.67384	validation_1-rmse:0.98673
# [111]	validation_0-rmse:0.67304	validation_1-rmse:0.99006
# [112]	validation_0-rmse:0.67077	validation_1-rmse:0.98890
# [113]	validation_0-rmse:0.66891	validation_1-rmse:0.98854
# [114]	validation_0-rmse:0.66644	validation_1-rmse:0.98350
# [115]	validation_0-rmse:0.66369	validation_1-rmse:0.98854
# [116]	validation_0-rmse:0.66132	validation_1-rmse:0.98877
# [117]	validation_0-rmse:0.65778	validation_1-rmse:0.98912
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.56661	validation_1-rmse:5.94497
# [1]	validation_0-rmse:6.27590	validation_1-rmse:5.65860
# [2]	validation_0-rmse:6.00134	validation_1-rmse:5.38742
# [3]	validation_0-rmse:5.73805	validation_1-rmse:5.13846
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:5.49036	validation_1-rmse:4.90301
# [5]	validation_0-rmse:5.25101	validation_1-rmse:4.70049
# [6]	validation_0-rmse:5.02488	validation_1-rmse:4.48047
# [7]	validation_0-rmse:4.79994	validation_1-rmse:4.26827
# [8]	validation_0-rmse:4.59626	validation_1-rmse:4.06958
# [9]	validation_0-rmse:4.39839	validation_1-rmse:3.90286
# [10]	validation_0-rmse:4.20603	validation_1-rmse:3.71806
# [11]	validation_0-rmse:4.02856	validation_1-rmse:3.55919
# [12]	validation_0-rmse:3.85470	validation_1-rmse:3.41059
# [13]	validation_0-rmse:3.68704	validation_1-rmse:3.25644
# [14]	validation_0-rmse:3.54199	validation_1-rmse:3.13994
# [15]	validation_0-rmse:3.39644	validation_1-rmse:3.00724
# [16]	validation_0-rmse:3.25340	validation_1-rmse:2.90431
# [17]	validation_0-rmse:3.12465	validation_1-rmse:2.80052
# [18]	validation_0-rmse:2.99891	validation_1-rmse:2.68308
# [19]	validation_0-rmse:2.88463	validation_1-rmse:2.59169
# [20]	validation_0-rmse:2.76431	validation_1-rmse:2.50133
# [21]	validation_0-rmse:2.65296	validation_1-rmse:2.41370
# [22]	validation_0-rmse:2.55317	validation_1-rmse:2.32550
# [23]	validation_0-rmse:2.45134	validation_1-rmse:2.23658
# [24]	validation_0-rmse:2.35479	validation_1-rmse:2.17128
# [25]	validation_0-rmse:2.26605	validation_1-rmse:2.09744
# [26]	validation_0-rmse:2.18890	validation_1-rmse:2.02790
# [27]	validation_0-rmse:2.11061	validation_1-rmse:1.97593
# [28]	validation_0-rmse:2.03259	validation_1-rmse:1.92407
# [29]	validation_0-rmse:1.95547	validation_1-rmse:1.87419
# [30]	validation_0-rmse:1.88352	validation_1-rmse:1.81601
# [31]	validation_0-rmse:1.81848	validation_1-rmse:1.77725
# [32]	validation_0-rmse:1.75286	validation_1-rmse:1.72797
# [33]	validation_0-rmse:1.69292	validation_1-rmse:1.68448
# [34]	validation_0-rmse:1.63679	validation_1-rmse:1.64054
# [35]	validation_0-rmse:1.58339	validation_1-rmse:1.61198
# [36]	validation_0-rmse:1.53168	validation_1-rmse:1.57378
# [37]	validation_0-rmse:1.48436	validation_1-rmse:1.54702
# [38]	validation_0-rmse:1.43228	validation_1-rmse:1.51737
# [39]	validation_0-rmse:1.39367	validation_1-rmse:1.49100
# [40]	validation_0-rmse:1.34839	validation_1-rmse:1.46403
# [41]	validation_0-rmse:1.30958	validation_1-rmse:1.44735
# [42]	validation_0-rmse:1.27395	validation_1-rmse:1.42478
# [43]	validation_0-rmse:1.22872	validation_1-rmse:1.40182
# [44]	validation_0-rmse:1.19310	validation_1-rmse:1.38073
# [45]	validation_0-rmse:1.16455	validation_1-rmse:1.36178
# [46]	validation_0-rmse:1.12794	validation_1-rmse:1.34626
# [47]	validation_0-rmse:1.09354	validation_1-rmse:1.33039
# [48]	validation_0-rmse:1.06682	validation_1-rmse:1.31580
# [49]	validation_0-rmse:1.04197	validation_1-rmse:1.31318
# [50]	validation_0-rmse:1.02353	validation_1-rmse:1.30702
# [51]	validation_0-rmse:1.00000	validation_1-rmse:1.29475
# [52]	validation_0-rmse:0.98080	validation_1-rmse:1.28991
# [53]	validation_0-rmse:0.95904	validation_1-rmse:1.27575
# [54]	validation_0-rmse:0.94032	validation_1-rmse:1.27665
# [55]	validation_0-rmse:0.92776	validation_1-rmse:1.26794
# [56]	validation_0-rmse:0.91141	validation_1-rmse:1.25905
# [57]	validation_0-rmse:0.89706	validation_1-rmse:1.25682
# [58]	validation_0-rmse:0.88357	validation_1-rmse:1.26182
# [59]	validation_0-rmse:0.87073	validation_1-rmse:1.25557
# [60]	validation_0-rmse:0.85651	validation_1-rmse:1.24646
# [61]	validation_0-rmse:0.84099	validation_1-rmse:1.23251
# [62]	validation_0-rmse:0.83204	validation_1-rmse:1.23035
# [63]	validation_0-rmse:0.82200	validation_1-rmse:1.22735
# [64]	validation_0-rmse:0.81134	validation_1-rmse:1.22585
# [65]	validation_0-rmse:0.80006	validation_1-rmse:1.22441
# [66]	validation_0-rmse:0.79291	validation_1-rmse:1.22195
# [67]	validation_0-rmse:0.78560	validation_1-rmse:1.22281
# [68]	validation_0-rmse:0.77747	validation_1-rmse:1.21998
# [69]	validation_0-rmse:0.76940	validation_1-rmse:1.21718
# [70]	validation_0-rmse:0.76197	validation_1-rmse:1.21246
# [71]	validation_0-rmse:0.75473	validation_1-rmse:1.20791
# [72]	validation_0-rmse:0.74801	validation_1-rmse:1.20447
# [73]	validation_0-rmse:0.74244	validation_1-rmse:1.20828
# [74]	validation_0-rmse:0.73706	validation_1-rmse:1.21011
# [75]	validation_0-rmse:0.73033	validation_1-rmse:1.20863
# [76]	validation_0-rmse:0.72333	validation_1-rmse:1.20580
# [77]	validation_0-rmse:0.71772	validation_1-rmse:1.20196
# [78]	validation_0-rmse:0.71255	validation_1-rmse:1.19665
# [79]	validation_0-rmse:0.70940	validation_1-rmse:1.19935
# [80]	validation_0-rmse:0.70525	validation_1-rmse:1.20488
# [81]	validation_0-rmse:0.69941	validation_1-rmse:1.20590
# [82]	validation_0-rmse:0.69564	validation_1-rmse:1.21008
# [83]	validation_0-rmse:0.68858	validation_1-rmse:1.20806
# [84]	validation_0-rmse:0.68543	validation_1-rmse:1.20383
# [85]	validation_0-rmse:0.68296	validation_1-rmse:1.20442
# [86]	validation_0-rmse:0.68097	validation_1-rmse:1.20618
# [87]	validation_0-rmse:0.67752	validation_1-rmse:1.20782
# [88]	validation_0-rmse:0.67763	validation_1-rmse:1.20595
# [89]	validation_0-rmse:0.67506	validation_1-rmse:1.20566
# [90]	validation_0-rmse:0.67135	validation_1-rmse:1.20318
# [91]	validation_0-rmse:0.66906	validation_1-rmse:1.20462
# [92]	validation_0-rmse:0.66533	validation_1-rmse:1.20474
# [93]	validation_0-rmse:0.66200	validation_1-rmse:1.20712
# [94]	validation_0-rmse:0.65864	validation_1-rmse:1.20982
# [95]	validation_0-rmse:0.65652	validation_1-rmse:1.21160
# [96]	validation_0-rmse:0.65563	validation_1-rmse:1.21619
# [97]	validation_0-rmse:0.65493	validation_1-rmse:1.21496
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.36864	validation_1-rmse:6.86248
# [1]	validation_0-rmse:6.08819	validation_1-rmse:6.58028
# [2]	validation_0-rmse:5.82058	validation_1-rmse:6.31214
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:5.57437	validation_1-rmse:6.07193
# [4]	validation_0-rmse:5.32451	validation_1-rmse:5.83085
# [5]	validation_0-rmse:5.09214	validation_1-rmse:5.59880
# [6]	validation_0-rmse:4.87993	validation_1-rmse:5.38701
# [7]	validation_0-rmse:4.67352	validation_1-rmse:5.19076
# [8]	validation_0-rmse:4.47179	validation_1-rmse:4.98957
# [9]	validation_0-rmse:4.29103	validation_1-rmse:4.80578
# [10]	validation_0-rmse:4.10647	validation_1-rmse:4.62881
# [11]	validation_0-rmse:3.93433	validation_1-rmse:4.46157
# [12]	validation_0-rmse:3.76298	validation_1-rmse:4.30236
# [13]	validation_0-rmse:3.60565	validation_1-rmse:4.14573
# [14]	validation_0-rmse:3.45278	validation_1-rmse:3.99271
# [15]	validation_0-rmse:3.31256	validation_1-rmse:3.86276
# [16]	validation_0-rmse:3.18371	validation_1-rmse:3.74306
# [17]	validation_0-rmse:3.05101	validation_1-rmse:3.60853
# [18]	validation_0-rmse:2.92789	validation_1-rmse:3.48833
# [19]	validation_0-rmse:2.81748	validation_1-rmse:3.38506
# [20]	validation_0-rmse:2.70214	validation_1-rmse:3.26838
# [21]	validation_0-rmse:2.58814	validation_1-rmse:3.15170
# [22]	validation_0-rmse:2.48822	validation_1-rmse:3.05143
# [23]	validation_0-rmse:2.38592	validation_1-rmse:2.95603
# [24]	validation_0-rmse:2.29362	validation_1-rmse:2.87190
# [25]	validation_0-rmse:2.20375	validation_1-rmse:2.78736
# [26]	validation_0-rmse:2.11930	validation_1-rmse:2.70353
# [27]	validation_0-rmse:2.04298	validation_1-rmse:2.63703
# [28]	validation_0-rmse:1.96797	validation_1-rmse:2.56182
# [29]	validation_0-rmse:1.89057	validation_1-rmse:2.48922
# [30]	validation_0-rmse:1.82294	validation_1-rmse:2.42268
# [31]	validation_0-rmse:1.75957	validation_1-rmse:2.35922
# [32]	validation_0-rmse:1.70282	validation_1-rmse:2.30673
# [33]	validation_0-rmse:1.64857	validation_1-rmse:2.26059
# [34]	validation_0-rmse:1.60575	validation_1-rmse:2.21258
# [35]	validation_0-rmse:1.55592	validation_1-rmse:2.16520
# [36]	validation_0-rmse:1.50378	validation_1-rmse:2.11170
# [37]	validation_0-rmse:1.46191	validation_1-rmse:2.07445
# [38]	validation_0-rmse:1.41391	validation_1-rmse:2.02577
# [39]	validation_0-rmse:1.36501	validation_1-rmse:1.97780
# [40]	validation_0-rmse:1.32401	validation_1-rmse:1.93730
# [41]	validation_0-rmse:1.29360	validation_1-rmse:1.91158
# [42]	validation_0-rmse:1.25415	validation_1-rmse:1.87307
# [43]	validation_0-rmse:1.21264	validation_1-rmse:1.83553
# [44]	validation_0-rmse:1.18173	validation_1-rmse:1.80798
# [45]	validation_0-rmse:1.14971	validation_1-rmse:1.77403
# [46]	validation_0-rmse:1.12348	validation_1-rmse:1.74806
# [47]	validation_0-rmse:1.10175	validation_1-rmse:1.73243
# [48]	validation_0-rmse:1.07425	validation_1-rmse:1.70731
# [49]	validation_0-rmse:1.05270	validation_1-rmse:1.69464
# [50]	validation_0-rmse:1.03250	validation_1-rmse:1.67400
# [51]	validation_0-rmse:1.01546	validation_1-rmse:1.65747
# [52]	validation_0-rmse:0.99543	validation_1-rmse:1.63839
# [53]	validation_0-rmse:0.97770	validation_1-rmse:1.62001
# [54]	validation_0-rmse:0.96081	validation_1-rmse:1.60447
# [55]	validation_0-rmse:0.94556	validation_1-rmse:1.58905
# [56]	validation_0-rmse:0.92797	validation_1-rmse:1.57417
# [57]	validation_0-rmse:0.91392	validation_1-rmse:1.56508
# [58]	validation_0-rmse:0.90011	validation_1-rmse:1.55266
# [59]	validation_0-rmse:0.88897	validation_1-rmse:1.54301
# [60]	validation_0-rmse:0.87640	validation_1-rmse:1.53229
# [61]	validation_0-rmse:0.86675	validation_1-rmse:1.51516
# [62]	validation_0-rmse:0.85499	validation_1-rmse:1.50307
# [63]	validation_0-rmse:0.84617	validation_1-rmse:1.49736
# [64]	validation_0-rmse:0.83426	validation_1-rmse:1.48975
# [65]	validation_0-rmse:0.82315	validation_1-rmse:1.47776
# [66]	validation_0-rmse:0.81567	validation_1-rmse:1.47097
# [67]	validation_0-rmse:0.80761	validation_1-rmse:1.46279
# [68]	validation_0-rmse:0.80036	validation_1-rmse:1.45195
# [69]	validation_0-rmse:0.79292	validation_1-rmse:1.44063
# [70]	validation_0-rmse:0.78381	validation_1-rmse:1.43136
# [71]	validation_0-rmse:0.77562	validation_1-rmse:1.42297
# [72]	validation_0-rmse:0.77021	validation_1-rmse:1.41569
# [73]	validation_0-rmse:0.76358	validation_1-rmse:1.41138
# [74]	validation_0-rmse:0.75926	validation_1-rmse:1.40338
# [75]	validation_0-rmse:0.75372	validation_1-rmse:1.39541
# [76]	validation_0-rmse:0.74852	validation_1-rmse:1.39341
# [77]	validation_0-rmse:0.74326	validation_1-rmse:1.38657
# [78]	validation_0-rmse:0.73858	validation_1-rmse:1.37875
# [79]	validation_0-rmse:0.73405	validation_1-rmse:1.37262
# [80]	validation_0-rmse:0.73177	validation_1-rmse:1.37076
# [81]	validation_0-rmse:0.72529	validation_1-rmse:1.36253
# [82]	validation_0-rmse:0.72075	validation_1-rmse:1.36265
# [83]	validation_0-rmse:0.71592	validation_1-rmse:1.35386
# [84]	validation_0-rmse:0.71172	validation_1-rmse:1.35097
# [85]	validation_0-rmse:0.70879	validation_1-rmse:1.34584
# [86]	validation_0-rmse:0.70555	validation_1-rmse:1.34503
# [87]	validation_0-rmse:0.70042	validation_1-rmse:1.33792
# [88]	validation_0-rmse:0.69645	validation_1-rmse:1.33657
# [89]	validation_0-rmse:0.69421	validation_1-rmse:1.33679
# [90]	validation_0-rmse:0.69161	validation_1-rmse:1.33622
# [91]	validation_0-rmse:0.68853	validation_1-rmse:1.33377
# [92]	validation_0-rmse:0.68350	validation_1-rmse:1.32976
# [93]	validation_0-rmse:0.68120	validation_1-rmse:1.32697
# [94]	validation_0-rmse:0.67596	validation_1-rmse:1.31377
# [95]	validation_0-rmse:0.67132	validation_1-rmse:1.31465
# [96]	validation_0-rmse:0.66870	validation_1-rmse:1.31181
# [97]	validation_0-rmse:0.66565	validation_1-rmse:1.30452
# [98]	validation_0-rmse:0.66503	validation_1-rmse:1.30420
# [99]	validation_0-rmse:0.66388	validation_1-rmse:1.30448
# [100]	validation_0-rmse:0.66090	validation_1-rmse:1.30491
# [101]	validation_0-rmse:0.65903	validation_1-rmse:1.30131
# [102]	validation_0-rmse:0.65766	validation_1-rmse:1.30306
# [103]	validation_0-rmse:0.65475	validation_1-rmse:1.30216
# [104]	validation_0-rmse:0.65358	validation_1-rmse:1.29869
# [105]	validation_0-rmse:0.65085	validation_1-rmse:1.30281
# [106]	validation_0-rmse:0.64825	validation_1-rmse:1.30258
# [107]	validation_0-rmse:0.64697	validation_1-rmse:1.30360
# [108]	validation_0-rmse:0.64428	validation_1-rmse:1.30327
# [109]	validation_0-rmse:0.64334	validation_1-rmse:1.30385
# [110]	validation_0-rmse:0.64017	validation_1-rmse:1.30103
# [111]	validation_0-rmse:0.63815	validation_1-rmse:1.29934
# [112]	validation_0-rmse:0.63723	validation_1-rmse:1.30044
# [113]	validation_0-rmse:0.63602	validation_1-rmse:1.29843
# [114]	validation_0-rmse:0.63303	validation_1-rmse:1.29232
# [115]	validation_0-rmse:0.63170	validation_1-rmse:1.29330
# [116]	validation_0-rmse:0.62590	validation_1-rmse:1.28366
# [117]	validation_0-rmse:0.62441	validation_1-rmse:1.28398
# [118]	validation_0-rmse:0.62214	validation_1-rmse:1.28171
# [119]	validation_0-rmse:0.62012	validation_1-rmse:1.27870
# [120]	validation_0-rmse:0.61799	validation_1-rmse:1.28007
# [121]	validation_0-rmse:0.61532	validation_1-rmse:1.28041
# [122]	validation_0-rmse:0.61316	validation_1-rmse:1.28189
# [123]	validation_0-rmse:0.61002	validation_1-rmse:1.27668
# [124]	validation_0-rmse:0.60768	validation_1-rmse:1.27533
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:6.53669	validation_1-rmse:6.14995
# [1]	validation_0-rmse:6.26168	validation_1-rmse:5.88938
# [2]	validation_0-rmse:5.99236	validation_1-rmse:5.64999
# [3]	validation_0-rmse:5.74276	validation_1-rmse:5.41228
# [4]	validation_0-rmse:5.49771	validation_1-rmse:5.17165
# [5]	validation_0-rmse:5.26963	validation_1-rmse:4.96507
# [6]	validation_0-rmse:5.03608	validation_1-rmse:4.73705
# [7]	validation_0-rmse:4.82877	validation_1-rmse:4.54258
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:4.61674	validation_1-rmse:4.33665
# [9]	validation_0-rmse:4.43372	validation_1-rmse:4.15751
# [10]	validation_0-rmse:4.24233	validation_1-rmse:3.98539
# [11]	validation_0-rmse:4.05402	validation_1-rmse:3.80398
# [12]	validation_0-rmse:3.88668	validation_1-rmse:3.64261
# [13]	validation_0-rmse:3.73213	validation_1-rmse:3.48907
# [14]	validation_0-rmse:3.57592	validation_1-rmse:3.35741
# [15]	validation_0-rmse:3.43382	validation_1-rmse:3.22472
# [16]	validation_0-rmse:3.29299	validation_1-rmse:3.09603
# [17]	validation_0-rmse:3.15064	validation_1-rmse:2.95892
# [18]	validation_0-rmse:3.03050	validation_1-rmse:2.85922
# [19]	validation_0-rmse:2.91528	validation_1-rmse:2.75923
# [20]	validation_0-rmse:2.79813	validation_1-rmse:2.65547
# [21]	validation_0-rmse:2.69627	validation_1-rmse:2.56388
# [22]	validation_0-rmse:2.59360	validation_1-rmse:2.47540
# [23]	validation_0-rmse:2.49638	validation_1-rmse:2.39279
# [24]	validation_0-rmse:2.40858	validation_1-rmse:2.32575
# [25]	validation_0-rmse:2.32404	validation_1-rmse:2.26044
# [26]	validation_0-rmse:2.23330	validation_1-rmse:2.17922
# [27]	validation_0-rmse:2.16099	validation_1-rmse:2.11498
# [28]	validation_0-rmse:2.07700	validation_1-rmse:2.05106
# [29]	validation_0-rmse:2.00155	validation_1-rmse:1.99011
# [30]	validation_0-rmse:1.93158	validation_1-rmse:1.93491
# [31]	validation_0-rmse:1.86205	validation_1-rmse:1.88078
# [32]	validation_0-rmse:1.79787	validation_1-rmse:1.82970
# [33]	validation_0-rmse:1.73684	validation_1-rmse:1.78022
# [34]	validation_0-rmse:1.67989	validation_1-rmse:1.74613
# [35]	validation_0-rmse:1.62315	validation_1-rmse:1.70743
# [36]	validation_0-rmse:1.57182	validation_1-rmse:1.67547
# [37]	validation_0-rmse:1.51935	validation_1-rmse:1.63750
# [38]	validation_0-rmse:1.47449	validation_1-rmse:1.60391
# [39]	validation_0-rmse:1.43098	validation_1-rmse:1.57424
# [40]	validation_0-rmse:1.38660	validation_1-rmse:1.55084
# [41]	validation_0-rmse:1.34538	validation_1-rmse:1.52334
# [42]	validation_0-rmse:1.30999	validation_1-rmse:1.50063
# [43]	validation_0-rmse:1.27187	validation_1-rmse:1.46827
# [44]	validation_0-rmse:1.23917	validation_1-rmse:1.44572
# [45]	validation_0-rmse:1.20658	validation_1-rmse:1.42569
# [46]	validation_0-rmse:1.17492	validation_1-rmse:1.40504
# [47]	validation_0-rmse:1.14746	validation_1-rmse:1.38573
# [48]	validation_0-rmse:1.12213	validation_1-rmse:1.36972
# [49]	validation_0-rmse:1.09607	validation_1-rmse:1.34612
# [50]	validation_0-rmse:1.07234	validation_1-rmse:1.33044
# [51]	validation_0-rmse:1.04580	validation_1-rmse:1.31044
# [52]	validation_0-rmse:1.02734	validation_1-rmse:1.30031
# [53]	validation_0-rmse:1.00937	validation_1-rmse:1.29148
# [54]	validation_0-rmse:0.99057	validation_1-rmse:1.27799
# [55]	validation_0-rmse:0.97641	validation_1-rmse:1.26915
# [56]	validation_0-rmse:0.95781	validation_1-rmse:1.26595
# [57]	validation_0-rmse:0.94410	validation_1-rmse:1.25587
# [58]	validation_0-rmse:0.93211	validation_1-rmse:1.24833
# [59]	validation_0-rmse:0.91948	validation_1-rmse:1.24096
# [60]	validation_0-rmse:0.90359	validation_1-rmse:1.22042
# [61]	validation_0-rmse:0.88748	validation_1-rmse:1.20103
# [62]	validation_0-rmse:0.87799	validation_1-rmse:1.20141
# [63]	validation_0-rmse:0.86882	validation_1-rmse:1.20074
# [64]	validation_0-rmse:0.86088	validation_1-rmse:1.20015
# [65]	validation_0-rmse:0.85418	validation_1-rmse:1.20529
# [66]	validation_0-rmse:0.84250	validation_1-rmse:1.19147
# [67]	validation_0-rmse:0.83316	validation_1-rmse:1.19191
# [68]	validation_0-rmse:0.82583	validation_1-rmse:1.19065
# [69]	validation_0-rmse:0.81812	validation_1-rmse:1.19250
# [70]	validation_0-rmse:0.81396	validation_1-rmse:1.19344
# [71]	validation_0-rmse:0.80809	validation_1-rmse:1.19110
# [72]	validation_0-rmse:0.80435	validation_1-rmse:1.19362
# [73]	validation_0-rmse:0.79872	validation_1-rmse:1.19072
# [74]	validation_0-rmse:0.79258	validation_1-rmse:1.18042
# [75]	validation_0-rmse:0.78840	validation_1-rmse:1.16908
# [76]	validation_0-rmse:0.78585	validation_1-rmse:1.16166
# [77]	validation_0-rmse:0.78153	validation_1-rmse:1.15952
# [78]	validation_0-rmse:0.77879	validation_1-rmse:1.15579
# [79]	validation_0-rmse:0.77323	validation_1-rmse:1.15851
# [80]	validation_0-rmse:0.76754	validation_1-rmse:1.15930
# [81]	validation_0-rmse:0.76298	validation_1-rmse:1.16282
# [82]	validation_0-rmse:0.76121	validation_1-rmse:1.16354
# [83]	validation_0-rmse:0.75752	validation_1-rmse:1.16733
# [84]	validation_0-rmse:0.75350	validation_1-rmse:1.16219
# [85]	validation_0-rmse:0.75160	validation_1-rmse:1.16404
# [86]	validation_0-rmse:0.74688	validation_1-rmse:1.16716
# [87]	validation_0-rmse:0.74212	validation_1-rmse:1.17288
# [88]	validation_0-rmse:0.73955	validation_1-rmse:1.16981
# [89]	validation_0-rmse:0.73511	validation_1-rmse:1.17030
# [90]	validation_0-rmse:0.73266	validation_1-rmse:1.16908
# [91]	validation_0-rmse:0.72788	validation_1-rmse:1.16612
# [92]	validation_0-rmse:0.72293	validation_1-rmse:1.15747
# [93]	validation_0-rmse:0.72044	validation_1-rmse:1.15589
# [94]	validation_0-rmse:0.71920	validation_1-rmse:1.15833
# [95]	validation_0-rmse:0.71616	validation_1-rmse:1.15424
# [96]	validation_0-rmse:0.71469	validation_1-rmse:1.16034
# [97]	validation_0-rmse:0.71113	validation_1-rmse:1.16224
# [98]	validation_0-rmse:0.71041	validation_1-rmse:1.15847
# [99]	validation_0-rmse:0.70811	validation_1-rmse:1.16084
# [100]	validation_0-rmse:0.70738	validation_1-rmse:1.16098
# [101]	validation_0-rmse:0.70605	validation_1-rmse:1.16114
# [102]	validation_0-rmse:0.70302	validation_1-rmse:1.16510
# [103]	validation_0-rmse:0.70041	validation_1-rmse:1.15533
# [104]	validation_0-rmse:0.69731	validation_1-rmse:1.15452
# [105]	validation_0-rmse:0.69487	validation_1-rmse:1.15160
# [106]	validation_0-rmse:0.69155	validation_1-rmse:1.14829
# [107]	validation_0-rmse:0.68812	validation_1-rmse:1.14542
# [108]	validation_0-rmse:0.68590	validation_1-rmse:1.14183
# [109]	validation_0-rmse:0.68439	validation_1-rmse:1.14056
# [110]	validation_0-rmse:0.68334	validation_1-rmse:1.13780
# [111]	validation_0-rmse:0.68143	validation_1-rmse:1.14004
# [112]	validation_0-rmse:0.68042	validation_1-rmse:1.14226
# [113]	validation_0-rmse:0.67891	validation_1-rmse:1.14246
# [114]	validation_0-rmse:0.67728	validation_1-rmse:1.13917
# [115]	validation_0-rmse:0.67676	validation_1-rmse:1.13503
# [116]	validation_0-rmse:0.67532	validation_1-rmse:1.12681
# [117]	validation_0-rmse:0.67450	validation_1-rmse:1.12795
# [118]	validation_0-rmse:0.67352	validation_1-rmse:1.12521
# [119]	validation_0-rmse:0.67208	validation_1-rmse:1.12360
# [120]	validation_0-rmse:0.67195	validation_1-rmse:1.12537
# [121]	validation_0-rmse:0.66963	validation_1-rmse:1.12205
# [122]	validation_0-rmse:0.66795	validation_1-rmse:1.12159
# [123]	validation_0-rmse:0.66664	validation_1-rmse:1.11677
# [124]	validation_0-rmse:0.66370	validation_1-rmse:1.11723
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.41458	validation_1-rmse:6.59709
# [1]	validation_0-rmse:6.12292	validation_1-rmse:6.30806
# [2]	validation_0-rmse:5.86381	validation_1-rmse:6.04790
# [3]	validation_0-rmse:5.60238	validation_1-rmse:5.79817
# [4]	validation_0-rmse:5.35524	validation_1-rmse:5.54976
# [5]	validation_0-rmse:5.13389	validation_1-rmse:5.32998
# [6]	validation_0-rmse:4.92414	validation_1-rmse:5.12640
# [7]	validation_0-rmse:4.70735	validation_1-rmse:4.91299
# [8]	validation_0-rmse:4.50315	validation_1-rmse:4.72373
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [9]	validation_0-rmse:4.31343	validation_1-rmse:4.53436
# [10]	validation_0-rmse:4.13451	validation_1-rmse:4.36520
# [11]	validation_0-rmse:3.96020	validation_1-rmse:4.19636
# [12]	validation_0-rmse:3.78735	validation_1-rmse:4.02330
# [13]	validation_0-rmse:3.61454	validation_1-rmse:3.85284
# [14]	validation_0-rmse:3.46574	validation_1-rmse:3.71150
# [15]	validation_0-rmse:3.33235	validation_1-rmse:3.58636
# [16]	validation_0-rmse:3.19600	validation_1-rmse:3.45008
# [17]	validation_0-rmse:3.06517	validation_1-rmse:3.30885
# [18]	validation_0-rmse:2.94524	validation_1-rmse:3.18785
# [19]	validation_0-rmse:2.83415	validation_1-rmse:3.07701
# [20]	validation_0-rmse:2.72347	validation_1-rmse:2.96909
# [21]	validation_0-rmse:2.62592	validation_1-rmse:2.87472
# [22]	validation_0-rmse:2.53050	validation_1-rmse:2.77684
# [23]	validation_0-rmse:2.43564	validation_1-rmse:2.69881
# [24]	validation_0-rmse:2.33765	validation_1-rmse:2.60149
# [25]	validation_0-rmse:2.25534	validation_1-rmse:2.51435
# [26]	validation_0-rmse:2.17469	validation_1-rmse:2.43289
# [27]	validation_0-rmse:2.10124	validation_1-rmse:2.35858
# [28]	validation_0-rmse:2.01852	validation_1-rmse:2.27057
# [29]	validation_0-rmse:1.94932	validation_1-rmse:2.20622
# [30]	validation_0-rmse:1.88408	validation_1-rmse:2.13501
# [31]	validation_0-rmse:1.82452	validation_1-rmse:2.06790
# [32]	validation_0-rmse:1.75635	validation_1-rmse:2.00578
# [33]	validation_0-rmse:1.70228	validation_1-rmse:1.96137
# [34]	validation_0-rmse:1.64908	validation_1-rmse:1.91451
# [35]	validation_0-rmse:1.59289	validation_1-rmse:1.86920
# [36]	validation_0-rmse:1.54765	validation_1-rmse:1.81746
# [37]	validation_0-rmse:1.49978	validation_1-rmse:1.77482
# [38]	validation_0-rmse:1.45409	validation_1-rmse:1.72424
# [39]	validation_0-rmse:1.41060	validation_1-rmse:1.67835
# [40]	validation_0-rmse:1.37244	validation_1-rmse:1.64452
# [41]	validation_0-rmse:1.33403	validation_1-rmse:1.61616
# [42]	validation_0-rmse:1.29781	validation_1-rmse:1.58753
# [43]	validation_0-rmse:1.26442	validation_1-rmse:1.55738
# [44]	validation_0-rmse:1.24022	validation_1-rmse:1.53216
# [45]	validation_0-rmse:1.21486	validation_1-rmse:1.51565
# [46]	validation_0-rmse:1.18739	validation_1-rmse:1.49581
# [47]	validation_0-rmse:1.15707	validation_1-rmse:1.46839
# [48]	validation_0-rmse:1.12833	validation_1-rmse:1.43528
# [49]	validation_0-rmse:1.10575	validation_1-rmse:1.41070
# [50]	validation_0-rmse:1.08310	validation_1-rmse:1.38510
# [51]	validation_0-rmse:1.06316	validation_1-rmse:1.36081
# [52]	validation_0-rmse:1.04230	validation_1-rmse:1.33413
# [53]	validation_0-rmse:1.02652	validation_1-rmse:1.31753
# [54]	validation_0-rmse:1.00271	validation_1-rmse:1.30159
# [55]	validation_0-rmse:0.98994	validation_1-rmse:1.29858
# [56]	validation_0-rmse:0.97445	validation_1-rmse:1.27946
# [57]	validation_0-rmse:0.95968	validation_1-rmse:1.26370
# [58]	validation_0-rmse:0.94540	validation_1-rmse:1.24704
# [59]	validation_0-rmse:0.93323	validation_1-rmse:1.23149
# [60]	validation_0-rmse:0.91692	validation_1-rmse:1.21039
# [61]	validation_0-rmse:0.90104	validation_1-rmse:1.19088
# [62]	validation_0-rmse:0.89150	validation_1-rmse:1.17904
# [63]	validation_0-rmse:0.88074	validation_1-rmse:1.16909
# [64]	validation_0-rmse:0.87107	validation_1-rmse:1.15241
# [65]	validation_0-rmse:0.86603	validation_1-rmse:1.15668
# [66]	validation_0-rmse:0.85419	validation_1-rmse:1.14188
# [67]	validation_0-rmse:0.84526	validation_1-rmse:1.12644
# [68]	validation_0-rmse:0.83548	validation_1-rmse:1.12873
# [69]	validation_0-rmse:0.82623	validation_1-rmse:1.12233
# [70]	validation_0-rmse:0.81928	validation_1-rmse:1.11876
# [71]	validation_0-rmse:0.81202	validation_1-rmse:1.11311
# [72]	validation_0-rmse:0.80654	validation_1-rmse:1.10804
# [73]	validation_0-rmse:0.79766	validation_1-rmse:1.09241
# [74]	validation_0-rmse:0.79192	validation_1-rmse:1.09148
# [75]	validation_0-rmse:0.78389	validation_1-rmse:1.08223
# [76]	validation_0-rmse:0.77842	validation_1-rmse:1.07586
# [77]	validation_0-rmse:0.77419	validation_1-rmse:1.07553
# [78]	validation_0-rmse:0.77057	validation_1-rmse:1.07087
# [79]	validation_0-rmse:0.76352	validation_1-rmse:1.06214
# [80]	validation_0-rmse:0.75915	validation_1-rmse:1.05508
# [81]	validation_0-rmse:0.75464	validation_1-rmse:1.05113
# [82]	validation_0-rmse:0.75405	validation_1-rmse:1.05534
# [83]	validation_0-rmse:0.74824	validation_1-rmse:1.04027
# [84]	validation_0-rmse:0.74493	validation_1-rmse:1.03733
# [85]	validation_0-rmse:0.74247	validation_1-rmse:1.03432
# [86]	validation_0-rmse:0.73982	validation_1-rmse:1.02975
# [87]	validation_0-rmse:0.73420	validation_1-rmse:1.02920
# [88]	validation_0-rmse:0.73142	validation_1-rmse:1.02863
# [89]	validation_0-rmse:0.72549	validation_1-rmse:1.01968
# [90]	validation_0-rmse:0.72231	validation_1-rmse:1.01453
# [91]	validation_0-rmse:0.71771	validation_1-rmse:1.00518
# [92]	validation_0-rmse:0.71447	validation_1-rmse:1.00503
# [93]	validation_0-rmse:0.71192	validation_1-rmse:0.99948
# ...
# [43]	validation_0-rmse:1.27584	validation_1-rmse:1.21595
# [44]	validation_0-rmse:1.24386	validation_1-rmse:1.18623
# [45]	validation_0-rmse:1.21252	validation_1-rmse:1.15452
# [46]	validation_0-rmse:1.18129	validation_1-rmse:1.12420
# [47]	validation_0-rmse:1.15205	validation_1-rmse:1.09026
# [48]	validation_0-rmse:1.12393	validation_1-rmse:1.06715
# [49]	validation_0-rmse:1.10229	validation_1-rmse:1.04379
# [50]	validation_0-rmse:1.07700	validation_1-rmse:1.01319
# [51]	validation_0-rmse:1.05657	validation_1-rmse:0.99230
# [52]	validation_0-rmse:1.03381	validation_1-rmse:0.96879
# [53]	validation_0-rmse:1.01408	validation_1-rmse:0.95601
# [54]	validation_0-rmse:1.00325	validation_1-rmse:0.94769
# [55]	validation_0-rmse:0.98930	validation_1-rmse:0.93528
# [56]	validation_0-rmse:0.97411	validation_1-rmse:0.93061
# [57]	validation_0-rmse:0.96033	validation_1-rmse:0.91598
# [58]	validation_0-rmse:0.94855	validation_1-rmse:0.90849
# [59]	validation_0-rmse:0.93735	validation_1-rmse:0.90462
# [60]	validation_0-rmse:0.92012	validation_1-rmse:0.89049
# [61]	validation_0-rmse:0.90481	validation_1-rmse:0.87885
# [62]	validation_0-rmse:0.89500	validation_1-rmse:0.87225
# [63]	validation_0-rmse:0.88299	validation_1-rmse:0.87240
# [64]	validation_0-rmse:0.87672	validation_1-rmse:0.86395
# [65]	validation_0-rmse:0.86711	validation_1-rmse:0.85665
# [66]	validation_0-rmse:0.85980	validation_1-rmse:0.84949
# [67]	validation_0-rmse:0.85287	validation_1-rmse:0.84683
# [68]	validation_0-rmse:0.84529	validation_1-rmse:0.84258
# [69]	validation_0-rmse:0.83629	validation_1-rmse:0.84504
# [70]	validation_0-rmse:0.82483	validation_1-rmse:0.83829
# [71]	validation_0-rmse:0.81602	validation_1-rmse:0.83493
# [72]	validation_0-rmse:0.81024	validation_1-rmse:0.83516
# [73]	validation_0-rmse:0.80600	validation_1-rmse:0.83630
# [74]	validation_0-rmse:0.79764	validation_1-rmse:0.82987
# [75]	validation_0-rmse:0.79138	validation_1-rmse:0.82735
# [76]	validation_0-rmse:0.78878	validation_1-rmse:0.82592
# [77]	validation_0-rmse:0.78267	validation_1-rmse:0.82823
# [78]	validation_0-rmse:0.77770	validation_1-rmse:0.83494
# [79]	validation_0-rmse:0.77309	validation_1-rmse:0.83734
# [80]	validation_0-rmse:0.76952	validation_1-rmse:0.84248
# [81]	validation_0-rmse:0.76643	validation_1-rmse:0.84572
# [82]	validation_0-rmse:0.76160	validation_1-rmse:0.84178
# [83]	validation_0-rmse:0.75871	validation_1-rmse:0.84176
# [84]	validation_0-rmse:0.75197	validation_1-rmse:0.83356
# [85]	validation_0-rmse:0.74656	validation_1-rmse:0.83091
# [86]	validation_0-rmse:0.74289	validation_1-rmse:0.83280
# [87]	validation_0-rmse:0.74005	validation_1-rmse:0.83334
# [88]	validation_0-rmse:0.73787	validation_1-rmse:0.83520
# [89]	validation_0-rmse:0.73351	validation_1-rmse:0.83040
# [90]	validation_0-rmse:0.73050	validation_1-rmse:0.83174
# [91]	validation_0-rmse:0.72660	validation_1-rmse:0.83568
# [92]	validation_0-rmse:0.72466	validation_1-rmse:0.83696
# [93]	validation_0-rmse:0.72147	validation_1-rmse:0.84059
# [94]	validation_0-rmse:0.71717	validation_1-rmse:0.83939
# [95]	validation_0-rmse:0.71541	validation_1-rmse:0.83718
# [96]	validation_0-rmse:0.71241	validation_1-rmse:0.83871
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.41233	validation_1-rmse:6.71253
# [1]	validation_0-rmse:6.12192	validation_1-rmse:6.40091
# [2]	validation_0-rmse:5.86079	validation_1-rmse:6.13269
# [3]	validation_0-rmse:5.61210	validation_1-rmse:5.88097
# [4]	validation_0-rmse:5.35459	validation_1-rmse:5.60037
# [5]	validation_0-rmse:5.12983	validation_1-rmse:5.37086
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:4.90717	validation_1-rmse:5.12262
# [7]	validation_0-rmse:4.69930	validation_1-rmse:4.88866
# [8]	validation_0-rmse:4.49659	validation_1-rmse:4.66118
# [9]	validation_0-rmse:4.31303	validation_1-rmse:4.47230
# [10]	validation_0-rmse:4.13784	validation_1-rmse:4.29571
# [11]	validation_0-rmse:3.97516	validation_1-rmse:4.13205
# [12]	validation_0-rmse:3.80532	validation_1-rmse:3.95670
# [13]	validation_0-rmse:3.63260	validation_1-rmse:3.76615
# [14]	validation_0-rmse:3.47816	validation_1-rmse:3.61578
# [15]	validation_0-rmse:3.32989	validation_1-rmse:3.44738
# [16]	validation_0-rmse:3.19990	validation_1-rmse:3.31461
# [17]	validation_0-rmse:3.07291	validation_1-rmse:3.19111
# [18]	validation_0-rmse:2.95663	validation_1-rmse:3.07183
# [19]	validation_0-rmse:2.83142	validation_1-rmse:2.94171
# [20]	validation_0-rmse:2.71912	validation_1-rmse:2.81945
# [21]	validation_0-rmse:2.61922	validation_1-rmse:2.70068
# [22]	validation_0-rmse:2.52486	validation_1-rmse:2.60755
# [23]	validation_0-rmse:2.44101	validation_1-rmse:2.52021
# [24]	validation_0-rmse:2.33782	validation_1-rmse:2.41573
# [25]	validation_0-rmse:2.25056	validation_1-rmse:2.33316
# [26]	validation_0-rmse:2.16376	validation_1-rmse:2.24276
# [27]	validation_0-rmse:2.08394	validation_1-rmse:2.15969
# [28]	validation_0-rmse:2.00546	validation_1-rmse:2.06872
# [29]	validation_0-rmse:1.94021	validation_1-rmse:1.99966
# [30]	validation_0-rmse:1.87822	validation_1-rmse:1.94030
# [31]	validation_0-rmse:1.81098	validation_1-rmse:1.86250
# [32]	validation_0-rmse:1.75086	validation_1-rmse:1.80284
# [33]	validation_0-rmse:1.69076	validation_1-rmse:1.74118
# [34]	validation_0-rmse:1.63494	validation_1-rmse:1.69244
# [35]	validation_0-rmse:1.58725	validation_1-rmse:1.64485
# [36]	validation_0-rmse:1.53601	validation_1-rmse:1.58955
# [37]	validation_0-rmse:1.48931	validation_1-rmse:1.54533
# [38]	validation_0-rmse:1.44403	validation_1-rmse:1.49765
# [39]	validation_0-rmse:1.40500	validation_1-rmse:1.46134
# [40]	validation_0-rmse:1.37874	validation_1-rmse:1.43150
# [41]	validation_0-rmse:1.34410	validation_1-rmse:1.39652
# [42]	validation_0-rmse:1.31049	validation_1-rmse:1.36417
# [43]	validation_0-rmse:1.27617	validation_1-rmse:1.32928
# [44]	validation_0-rmse:1.24407	validation_1-rmse:1.30016
# [45]	validation_0-rmse:1.20909	validation_1-rmse:1.27066
# [46]	validation_0-rmse:1.17740	validation_1-rmse:1.24184
# [47]	validation_0-rmse:1.14372	validation_1-rmse:1.21102
# [48]	validation_0-rmse:1.11501	validation_1-rmse:1.19019
# [49]	validation_0-rmse:1.08910	validation_1-rmse:1.16446
# [50]	validation_0-rmse:1.06255	validation_1-rmse:1.14447
# [51]	validation_0-rmse:1.04624	validation_1-rmse:1.13395
# [52]	validation_0-rmse:1.02253	validation_1-rmse:1.12303
# [53]	validation_0-rmse:1.00385	validation_1-rmse:1.10863
# [54]	validation_0-rmse:0.98435	validation_1-rmse:1.09536
# [55]	validation_0-rmse:0.96330	validation_1-rmse:1.08213
# [56]	validation_0-rmse:0.94480	validation_1-rmse:1.06396
# [57]	validation_0-rmse:0.93108	validation_1-rmse:1.05289
# [58]	validation_0-rmse:0.91847	validation_1-rmse:1.04159
# [59]	validation_0-rmse:0.90623	validation_1-rmse:1.03478
# [60]	validation_0-rmse:0.88965	validation_1-rmse:1.03091
# [61]	validation_0-rmse:0.87689	validation_1-rmse:1.02045
# [62]	validation_0-rmse:0.86638	validation_1-rmse:1.01291
# [63]	validation_0-rmse:0.85672	validation_1-rmse:1.00702
# [64]	validation_0-rmse:0.84700	validation_1-rmse:1.00270
# [65]	validation_0-rmse:0.84069	validation_1-rmse:1.00395
# [66]	validation_0-rmse:0.83397	validation_1-rmse:1.00207
# [67]	validation_0-rmse:0.82789	validation_1-rmse:1.00245
# [68]	validation_0-rmse:0.82091	validation_1-rmse:1.00069
# [69]	validation_0-rmse:0.81358	validation_1-rmse:1.00367
# [70]	validation_0-rmse:0.79827	validation_1-rmse:1.00383
# [71]	validation_0-rmse:0.79069	validation_1-rmse:1.00088
# [72]	validation_0-rmse:0.78658	validation_1-rmse:1.00345
# [73]	validation_0-rmse:0.78042	validation_1-rmse:1.00857
# [74]	validation_0-rmse:0.77066	validation_1-rmse:1.01264
# [75]	validation_0-rmse:0.76484	validation_1-rmse:1.00954
# [76]	validation_0-rmse:0.75806	validation_1-rmse:1.01002
# [77]	validation_0-rmse:0.74800	validation_1-rmse:1.01171
# [78]	validation_0-rmse:0.74246	validation_1-rmse:1.01836
# [79]	validation_0-rmse:0.73784	validation_1-rmse:1.02277
# [80]	validation_0-rmse:0.73451	validation_1-rmse:1.02319
# [81]	validation_0-rmse:0.73158	validation_1-rmse:1.01690
# [82]	validation_0-rmse:0.72593	validation_1-rmse:1.01823
# [83]	validation_0-rmse:0.72079	validation_1-rmse:1.01996
# [84]	validation_0-rmse:0.71728	validation_1-rmse:1.02004
# [85]	validation_0-rmse:0.71479	validation_1-rmse:1.02178
# [86]	validation_0-rmse:0.71310	validation_1-rmse:1.02243
# [87]	validation_0-rmse:0.70671	validation_1-rmse:1.02467
# [88]	validation_0-rmse:0.70469	validation_1-rmse:1.02426
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:6.53247	validation_1-rmse:6.15134
# [1]	validation_0-rmse:6.24833	validation_1-rmse:5.88497
# [2]	validation_0-rmse:5.96731	validation_1-rmse:5.62186
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:5.70079	validation_1-rmse:5.35738
# [4]	validation_0-rmse:5.45606	validation_1-rmse:5.13116
# [5]	validation_0-rmse:5.22199	validation_1-rmse:4.89499
# [6]	validation_0-rmse:4.99222	validation_1-rmse:4.66011
# [7]	validation_0-rmse:4.78044	validation_1-rmse:4.47090
# [8]	validation_0-rmse:4.56876	validation_1-rmse:4.27296
# [9]	validation_0-rmse:4.37802	validation_1-rmse:4.11044
# [10]	validation_0-rmse:4.19323	validation_1-rmse:3.94656
# [11]	validation_0-rmse:4.01649	validation_1-rmse:3.79558
# [12]	validation_0-rmse:3.84273	validation_1-rmse:3.64638
# [13]	validation_0-rmse:3.68181	validation_1-rmse:3.50162
# [14]	validation_0-rmse:3.52328	validation_1-rmse:3.36420
# [15]	validation_0-rmse:3.37235	validation_1-rmse:3.20831
# [16]	validation_0-rmse:3.23934	validation_1-rmse:3.09532
# [17]	validation_0-rmse:3.10658	validation_1-rmse:2.97552
# [18]	validation_0-rmse:2.97671	validation_1-rmse:2.86088
# [19]	validation_0-rmse:2.85424	validation_1-rmse:2.73908
# [20]	validation_0-rmse:2.73848	validation_1-rmse:2.63494
# [21]	validation_0-rmse:2.62916	validation_1-rmse:2.53351
# [22]	validation_0-rmse:2.52932	validation_1-rmse:2.44822
# [23]	validation_0-rmse:2.43268	validation_1-rmse:2.36030
# [24]	validation_0-rmse:2.33636	validation_1-rmse:2.28307
# [25]	validation_0-rmse:2.25116	validation_1-rmse:2.19395
# [26]	validation_0-rmse:2.16443	validation_1-rmse:2.11570
# [27]	validation_0-rmse:2.08239	validation_1-rmse:2.04480
# [28]	validation_0-rmse:2.00354	validation_1-rmse:1.97403
# [29]	validation_0-rmse:1.93564	validation_1-rmse:1.92564
# [30]	validation_0-rmse:1.87025	validation_1-rmse:1.86386
# [31]	validation_0-rmse:1.80184	validation_1-rmse:1.80619
# [32]	validation_0-rmse:1.74110	validation_1-rmse:1.76104
# [33]	validation_0-rmse:1.68269	validation_1-rmse:1.70371
# [34]	validation_0-rmse:1.62532	validation_1-rmse:1.65307
# [35]	validation_0-rmse:1.57670	validation_1-rmse:1.61468
# [36]	validation_0-rmse:1.52435	validation_1-rmse:1.57443
# [37]	validation_0-rmse:1.47645	validation_1-rmse:1.53630
# [38]	validation_0-rmse:1.42794	validation_1-rmse:1.49962
# [39]	validation_0-rmse:1.38302	validation_1-rmse:1.46656
# [40]	validation_0-rmse:1.34910	validation_1-rmse:1.43226
# [41]	validation_0-rmse:1.31454	validation_1-rmse:1.41302
# [42]	validation_0-rmse:1.28343	validation_1-rmse:1.38773
# [43]	validation_0-rmse:1.25936	validation_1-rmse:1.37682
# [44]	validation_0-rmse:1.22249	validation_1-rmse:1.34084
# [45]	validation_0-rmse:1.19437	validation_1-rmse:1.31821
# [46]	validation_0-rmse:1.16889	validation_1-rmse:1.30177
# [47]	validation_0-rmse:1.14123	validation_1-rmse:1.27813
# [48]	validation_0-rmse:1.11232	validation_1-rmse:1.25931
# [49]	validation_0-rmse:1.08660	validation_1-rmse:1.22910
# [50]	validation_0-rmse:1.05999	validation_1-rmse:1.20794
# [51]	validation_0-rmse:1.03973	validation_1-rmse:1.19362
# [52]	validation_0-rmse:1.01852	validation_1-rmse:1.18182
# [53]	validation_0-rmse:1.00169	validation_1-rmse:1.17639
# [54]	validation_0-rmse:0.98267	validation_1-rmse:1.16586
# [55]	validation_0-rmse:0.96489	validation_1-rmse:1.15538
# [56]	validation_0-rmse:0.95178	validation_1-rmse:1.14820
# [57]	validation_0-rmse:0.93642	validation_1-rmse:1.14393
# [58]	validation_0-rmse:0.92281	validation_1-rmse:1.13441
# [59]	validation_0-rmse:0.91452	validation_1-rmse:1.13440
# [60]	validation_0-rmse:0.90109	validation_1-rmse:1.12470
# [61]	validation_0-rmse:0.88920	validation_1-rmse:1.12903
# [62]	validation_0-rmse:0.87595	validation_1-rmse:1.12079
# [63]	validation_0-rmse:0.86925	validation_1-rmse:1.11494
# [64]	validation_0-rmse:0.85714	validation_1-rmse:1.10025
# [65]	validation_0-rmse:0.85017	validation_1-rmse:1.09780
# [66]	validation_0-rmse:0.84272	validation_1-rmse:1.09331
# [67]	validation_0-rmse:0.83391	validation_1-rmse:1.08641
# [68]	validation_0-rmse:0.82751	validation_1-rmse:1.08567
# [69]	validation_0-rmse:0.82189	validation_1-rmse:1.08330
# [70]	validation_0-rmse:0.81072	validation_1-rmse:1.07098
# [71]	validation_0-rmse:0.80417	validation_1-rmse:1.07364
# [72]	validation_0-rmse:0.79988	validation_1-rmse:1.07237
# [73]	validation_0-rmse:0.79378	validation_1-rmse:1.06494
# [74]	validation_0-rmse:0.78830	validation_1-rmse:1.06065
# [75]	validation_0-rmse:0.78115	validation_1-rmse:1.04797
# [76]	validation_0-rmse:0.77599	validation_1-rmse:1.04698
# [77]	validation_0-rmse:0.77200	validation_1-rmse:1.04215
# [78]	validation_0-rmse:0.76792	validation_1-rmse:1.04482
# [79]	validation_0-rmse:0.76510	validation_1-rmse:1.04494
# [80]	validation_0-rmse:0.76175	validation_1-rmse:1.04352
# [81]	validation_0-rmse:0.75713	validation_1-rmse:1.03877
# [82]	validation_0-rmse:0.75440	validation_1-rmse:1.03514
# [83]	validation_0-rmse:0.75168	validation_1-rmse:1.03475
# [84]	validation_0-rmse:0.74799	validation_1-rmse:1.03258
# [85]	validation_0-rmse:0.74450	validation_1-rmse:1.03159
# [86]	validation_0-rmse:0.74272	validation_1-rmse:1.03117
# [87]	validation_0-rmse:0.73976	validation_1-rmse:1.02807
# [88]	validation_0-rmse:0.73739	validation_1-rmse:1.02957
# [89]	validation_0-rmse:0.73504	validation_1-rmse:1.02951
# [90]	validation_0-rmse:0.73261	validation_1-rmse:1.03066
# [91]	validation_0-rmse:0.73068	validation_1-rmse:1.02941
# [92]	validation_0-rmse:0.72721	validation_1-rmse:1.02993
# [93]	validation_0-rmse:0.72459	validation_1-rmse:1.02668
# [94]	validation_0-rmse:0.72404	validation_1-rmse:1.02490
# [95]	validation_0-rmse:0.71887	validation_1-rmse:1.01409
# [96]	validation_0-rmse:0.71580	validation_1-rmse:1.01330
# [97]	validation_0-rmse:0.71226	validation_1-rmse:1.01000
# [98]	validation_0-rmse:0.71052	validation_1-rmse:1.01196
# [99]	validation_0-rmse:0.70647	validation_1-rmse:1.02228
# [100]	validation_0-rmse:0.70242	validation_1-rmse:1.02776
# [101]	validation_0-rmse:0.70085	validation_1-rmse:1.03308
# [102]	validation_0-rmse:0.69934	validation_1-rmse:1.03109
# [103]	validation_0-rmse:0.69562	validation_1-rmse:1.04410
# [104]	validation_0-rmse:0.69389	validation_1-rmse:1.04518
# [105]	validation_0-rmse:0.69016	validation_1-rmse:1.03548
# [106]	validation_0-rmse:0.68714	validation_1-rmse:1.04198
# [107]	validation_0-rmse:0.68507	validation_1-rmse:1.04321
# [108]	validation_0-rmse:0.68294	validation_1-rmse:1.04565
# [109]	validation_0-rmse:0.68088	validation_1-rmse:1.04300
# [110]	validation_0-rmse:0.67811	validation_1-rmse:1.03617
# [111]	validation_0-rmse:0.67635	validation_1-rmse:1.03978
# [112]	validation_0-rmse:0.67450	validation_1-rmse:1.03578
# [113]	validation_0-rmse:0.67374	validation_1-rmse:1.03568
# [114]	validation_0-rmse:0.67075	validation_1-rmse:1.03547
# [115]	validation_0-rmse:0.66986	validation_1-rmse:1.03846
# [116]	validation_0-rmse:0.66642	validation_1-rmse:1.04072
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(3.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.622
# Uncertainty
# a0: 2.56+/-0.319
# a1: 0.623+/-0.045

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: AEDR_mean: mean - 0.712, median - 0.711, CI - [0.664-0.769]
#
# SHAP-values for: contr_r_STD: mean - 0.36, median - 0.36, CI - [0.309-0.407]
#
# SHAP-values for: corr_r_Q25: mean - 0.238, median - 0.24, CI - [0.187-0.281]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['AEDR_mean', 'contr_r_STD', 'corr_r_Q25'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 100.31, median: 101.0,
#  pred. interval (P(0.025)-P(0.975)): 60.975-124.0,
#  conf. interval (p-value=0.95): 80.229-121.012
# ***
# Aggregate bias statistic:
#  mean: -0.103, median: -0.083,
#  pred. interval (P(0.025)-P(0.975)): -0.529-0.247,
#  conf. interval (p-value=0.95): -0.286-0.07
# ***
# Aggregate RMSE statistic:
#  mean: 0.999, median: 1.002, pred. interval (P(0.025)-P(0.975)): 0.722-1.237,
#  conf. interval (p-value=0.95): 0.871-1.125
# ***
# Aggregate MSE statistic:
#  mean: 1.019, median: 1.005, pred. interval (P(0.025)-P(0.975)): 0.521-1.531,
#  conf. interval (p-value=0.95): 0.761-1.266
# ***
# Aggregate R^2 statistic:
#  mean: 0.572, median: 0.602, pred. interval (P(0.025)-P(0.975)): 0.201-0.801,
#  conf. interval (p-value=0.95): 0.415-0.715
# ***
# Aggregate bias(%) statistic:
#  mean: -1.389, median: -1.196, pred. interval (P(0.025)-P(0.975)): -7.198-3.722,
#  conf. interval (p-value=0.95): -3.914-0.993
# ***
# Aggregate RMSE(%) statistic:
#  mean: 14.226, median: 14.204, pred. interval (P(0.025)-P(0.975)): 9.969-18.291,
#  conf. interval (p-value=0.95): 12.476-16.142
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -1753.67, median: -1177.029,
#  pred. interval (P(0.025)-P(0.975)): -5538.738-166.426,
#  conf. interval (p-value=0.95): -3484.207--466.737
# ***
# Aggregate RMSE statistic:
#  mean: 6667.546, median: 4360.203, pred. interval (P(0.025)-P(0.975)): 1255.661-17073.999,
#  conf. interval (p-value=0.95): 2592.003-14789.541
# ***
# Aggregate MSE statistic:
#  mean: 74265039.161, median: 19011382.437, pred. interval (P(0.025)-P(0.975)): 1576693.94-291521427.315,
#  conf. interval (p-value=0.95): 7054067.265-230405484.506
# ***
# Aggregate R^2 statistic:
#  mean: 0.489, median: 0.572, pred. interval (P(0.025)-P(0.975)): 0.021-0.827,
#  conf. interval (p-value=0.95): 0.278-0.713
# ***
# Aggregate bias(%) statistic:
#  mean: -33.206, median: -34.183, pred. interval (P(0.025)-P(0.975)): -66.606-5.512,
#  conf. interval (p-value=0.95): -54.472--15.32
# ***
# Aggregate RMSE(%) statistic:
#  mean: 134.281, median: 113.985, pred. interval (P(0.025)-P(0.975)): 68.02-267.471,
#  conf. interval (p-value=0.95): 86.376-199.23
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [4, 5, 6, 7, 8, 9, 10, 11])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 500, 1000, 5000, 10000, 20000, 50000, 1000000])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:6.44343
# [1]	validation_0-rmse:6.15729
# [2]	validation_0-rmse:5.88313
# [3]	validation_0-rmse:5.63401
# [4]	validation_0-rmse:5.39570
# [5]	validation_0-rmse:5.16145
# [6]	validation_0-rmse:4.94512
# [7]	validation_0-rmse:4.73580
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [8]	validation_0-rmse:4.53614
# [9]	validation_0-rmse:4.34605
# [10]	validation_0-rmse:4.14875
# [11]	validation_0-rmse:3.98343
# [12]	validation_0-rmse:3.81627
# [13]	validation_0-rmse:3.65920
# [14]	validation_0-rmse:3.51691
# [15]	validation_0-rmse:3.38093
# [16]	validation_0-rmse:3.23580
# [17]	validation_0-rmse:3.09623
# [18]	validation_0-rmse:2.96535
# [19]	validation_0-rmse:2.85211
# [20]	validation_0-rmse:2.74315
# [21]	validation_0-rmse:2.64493
# [22]	validation_0-rmse:2.54381
# [23]	validation_0-rmse:2.44432
# [24]	validation_0-rmse:2.35571
# [25]	validation_0-rmse:2.26210
# [26]	validation_0-rmse:2.18047
# [27]	validation_0-rmse:2.09735
# [28]	validation_0-rmse:2.02378
# [29]	validation_0-rmse:1.95036
# [30]	validation_0-rmse:1.87743
# [31]	validation_0-rmse:1.80674
# [32]	validation_0-rmse:1.74255
# [33]	validation_0-rmse:1.68379
# [34]	validation_0-rmse:1.62750
# [35]	validation_0-rmse:1.57570
# [36]	validation_0-rmse:1.52823
# [37]	validation_0-rmse:1.48134
# [38]	validation_0-rmse:1.43350
# [39]	validation_0-rmse:1.38840
# [40]	validation_0-rmse:1.35060
# [41]	validation_0-rmse:1.31335
# [42]	validation_0-rmse:1.27640
# [43]	validation_0-rmse:1.24309
# [44]	validation_0-rmse:1.21513
# [45]	validation_0-rmse:1.18559
# [46]	validation_0-rmse:1.15496
# [47]	validation_0-rmse:1.12771
# [48]	validation_0-rmse:1.10356
# [49]	validation_0-rmse:1.08957
# [50]	validation_0-rmse:1.07256
# [51]	validation_0-rmse:1.05068
# [52]	validation_0-rmse:1.03228
# [53]	validation_0-rmse:1.01373
# [54]	validation_0-rmse:0.99900
# [55]	validation_0-rmse:0.98265
# [56]	validation_0-rmse:0.96579
# [57]	validation_0-rmse:0.95105
# [58]	validation_0-rmse:0.93523
# [59]	validation_0-rmse:0.92409
# [60]	validation_0-rmse:0.91345
# [61]	validation_0-rmse:0.90458
# [62]	validation_0-rmse:0.89474
# [63]	validation_0-rmse:0.88369
# [64]	validation_0-rmse:0.87285
# [65]	validation_0-rmse:0.86500
# [66]	validation_0-rmse:0.85927
# [67]	validation_0-rmse:0.85265
# [68]	validation_0-rmse:0.84499
# [69]	validation_0-rmse:0.83667
# [70]	validation_0-rmse:0.83085
# [71]	validation_0-rmse:0.82594
# [72]	validation_0-rmse:0.81812
# [73]	validation_0-rmse:0.81243
# [74]	validation_0-rmse:0.80804
# [75]	validation_0-rmse:0.80330
# [76]	validation_0-rmse:0.79892
# [77]	validation_0-rmse:0.79130
# [78]	validation_0-rmse:0.78656
# [79]	validation_0-rmse:0.78319
# [80]	validation_0-rmse:0.78027
# [81]	validation_0-rmse:0.77595
# [82]	validation_0-rmse:0.76931
# [83]	validation_0-rmse:0.76722
# [84]	validation_0-rmse:0.76437
# [85]	validation_0-rmse:0.76129
# [86]	validation_0-rmse:0.75757
# [87]	validation_0-rmse:0.75564
# [88]	validation_0-rmse:0.75502
# [89]	validation_0-rmse:0.75208
# [90]	validation_0-rmse:0.74954
# [91]	validation_0-rmse:0.74581
# [92]	validation_0-rmse:0.74324
# [93]	validation_0-rmse:0.74052
# [94]	validation_0-rmse:0.73873
# [95]	validation_0-rmse:0.73722
# [96]	validation_0-rmse:0.73532
# [97]	validation_0-rmse:0.73370
# [98]	validation_0-rmse:0.72950
# [99]	validation_0-rmse:0.72801
# [100]	validation_0-rmse:0.72731
# [101]	validation_0-rmse:0.72625
# [102]	validation_0-rmse:0.72455
# [103]	validation_0-rmse:0.72321
# [104]	validation_0-rmse:0.72172
# [105]	validation_0-rmse:0.72125
# [106]	validation_0-rmse:0.71927
# [107]	validation_0-rmse:0.71841
# [108]	validation_0-rmse:0.71526
# [109]	validation_0-rmse:0.71394
# [110]	validation_0-rmse:0.71194
# [111]	validation_0-rmse:0.71045
# [112]	validation_0-rmse:0.70603
# [113]	validation_0-rmse:0.70341
# [114]	validation_0-rmse:0.70237
# [115]	validation_0-rmse:0.70093
# [116]	validation_0-rmse:0.69693
# [117]	validation_0-rmse:0.69388
# [118]	validation_0-rmse:0.69179
# [119]	validation_0-rmse:0.69047
# [120]	validation_0-rmse:0.68967
# [121]	validation_0-rmse:0.68853
# [122]	validation_0-rmse:0.68673
# [123]	validation_0-rmse:0.68390
# [124]	validation_0-rmse:0.68140
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 124

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.36
# RMSE: 0.7
# Relative RMSE(%):  9.666
# MSE: 0.5
# R square: 82.8%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(3.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.835
# Uncertainty
# a0: 1.69+/-0.24
# a1: 0.757+/-0.033

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/07_LN_Cs_vs_CHM_RGB_AEDR_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/07_LN_Cs_vs_CHM_RGB_AEDR_XGB_model.txt")
