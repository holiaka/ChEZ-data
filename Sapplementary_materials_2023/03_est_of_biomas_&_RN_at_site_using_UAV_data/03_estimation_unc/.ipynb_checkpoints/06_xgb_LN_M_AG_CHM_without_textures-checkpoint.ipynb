# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../03_input_data/input_CHM_&_spectral_data_site2020.xlsx'
df = pd.read_excel(site_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0        4.771            1.792                -0.211            -0.261
# 1        5.808            2.496                -0.073             0.392
# 2        5.796            2.546                 0.030             0.501
# 3        5.826            2.643                 0.000             0.419
# 4        6.059            2.643                 0.122             0.647
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX
# 0              -2.040          1.932     0.85    12.233545   19.097736
# 1              -0.139          2.674     1.00    14.964220   17.704655
# 2              -0.030          2.734     1.00    15.329449   17.559893
# 3              -0.431          2.785     0.97    15.392742   20.676994
# 4              -0.386          2.809     1.00    17.944009   21.851387

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
# dtypes: float64(9)
# memory usage: 7.4 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Gs_cub_m", "ln_M_AG_kg_m2"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                  ln_Gs_cub_m                                             \
#                        count      mean       std    min      25%    50%
# Dominant_specias
# Alder                    4.0  5.907250  0.445830  5.342  5.65925  5.985
# Aspen                    1.0  4.956000       NaN  4.956  4.95600  4.956
# Birch                   23.0  4.676174  0.813911  2.398  4.56900  4.949
# Oak                      3.0  5.409667  0.406291  4.956  5.24450  5.533
# Pine                    71.0  4.990775  1.410734  1.609  4.44850  5.642
# Spruce                   1.0  6.431000       NaN  6.431  6.43100  6.431
#
#                                 ln_M_AG_kg_m2                             \
#                      75%    max         count      mean       std    min
# Dominant_specias
# Alder             6.2330  6.317           4.0  2.862250  0.386813  2.407
# Aspen             4.9560  4.956           1.0  1.932000       NaN  1.932
# Birch             5.2930  5.680          23.0  1.855783  0.744496  0.000
# Oak               5.6365  5.740           3.0  2.687333  0.316282  2.398
# Pine              5.9215  6.457          71.0  2.073789  1.174954 -0.693
# Spruce            6.4310  6.431           1.0  3.506000       NaN  3.506
#
#
#                       25%    50%     75%    max
# Dominant_specias
# Alder             2.61775  2.892  3.1365  3.258
# Aspen             1.93200  1.932  1.9320  1.932
# Birch             1.68350  2.001  2.3930  2.803
# Oak               2.51850  2.639  2.8320  3.025
# Pine              1.48500  2.588  2.8620  3.515
# Spruce            3.50600  3.506  3.5060  3.506

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000        103.000000
# mean      4.981961         1.863184             -0.327942         -0.063369
# std       1.264300         1.198731              0.866380          0.795365
# min       1.609000        -1.347000             -2.659000         -2.408000
# 25%       4.677000         1.584500             -0.554000         -0.386500
# 50%       5.342000         2.294000             -0.051000          0.182000
# 75%       5.875000         2.663000              0.207000          0.495000
# max       6.457000         3.428000              1.384000          1.756000
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.015971       2.086126    0.808738    13.045021   17.907784
# std              0.799205       1.067542    0.276653     6.609366    7.523377
# min             -3.507000      -0.693000    0.090000     1.293138    2.733019
# 25%             -1.609000       1.758000    0.745000     8.206727   11.615798
# 50%             -0.844000       2.442000    0.960000    13.072916   18.269344
# 75%             -0.364000       2.809000    1.000000    17.432255   22.751595
# max              0.157000       3.515000    1.000000    28.916548   36.355442

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_M_AG_kg_m2"
indep_variables = ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0          4.771            1.792                -0.211            -0.261
# 1          5.808            2.496                -0.073             0.392
# 2          5.796            2.546                 0.030             0.501
# 3          5.826            2.643                 0.000             0.419
# 4          6.059            2.643                 0.122             0.647
# ..           ...              ...                   ...               ...
# 98         5.389            2.366                 0.531             0.182
# 99         2.398           -0.186                -1.309            -1.966
# 100        1.792           -0.968                -2.120            -1.966
# 101        4.836            1.733                -0.386             0.732
# 102        2.944           -0.211                -1.966            -1.470
#
#      ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX
# 0                -2.040          1.932     0.85    12.233545   19.097736
# 1                -0.139          2.674     1.00    14.964220   17.704655
# 2                -0.030          2.734     1.00    15.329449   17.559893
# 3                -0.431          2.785     0.97    15.392742   20.676994
# 4                -0.386          2.809     1.00    17.944009   21.851387
# ..                  ...            ...      ...          ...         ...
# 98               -1.386          2.493     0.84    11.654902   17.083910
# 99               -3.507          0.000     0.17     4.722706   10.924606
# 100              -2.408         -0.511     0.17     4.620455   10.747827
# 101              -0.041          2.163     0.88     7.371921   11.443830
# 102              -1.609          0.182     0.28     2.765120    8.069081
#
# [103 rows x 9 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX
# 0     0.85    12.233545   19.097736
# 1     1.00    14.964220   17.704655
# 2     1.00    15.329449   17.559893
# 3     0.97    15.392742   20.676994
# 4     1.00    17.944009   21.851387

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_foliage_kg_m2
# 0              -2.040
# 1              -0.139
# 2              -0.030
# 3              -0.431
# 4              -0.386

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [-0.09647077811773319, 0.05129978682436509, 0.3735171848707257]
#     Mean: 0.109
#     Std: 0.196
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.6593457  0.72967602 0.73594606]
#     Mean: 0.708
#     Std: 0.035
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.6826245987858092, 0.4909497808807475, 0.5177188246705953]
#     Mean: 0.564
#     Std: 0.085
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.7795639195981962                   # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.15523860064497264                  # gamma
print('Gamma: ' + str(p2))

p3 = 0.06954076966186808                  # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 3            # max_depth
print('Max_depth: ' + str(p4))

p5 = 97          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.9601329811614894                    # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.08270651843099497
# Gamma: 0.37667147001915574
# Learning_rate: 0.22099222373646055
# Max_depth: 2
# N_estimators: 60
# Subsample: 0.7889095515871503

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:1.37265	validation_1-rmse:1.56446
# [1]	validation_0-rmse:1.13010	validation_1-rmse:1.30924
# [2]	validation_0-rmse:0.94790	validation_1-rmse:1.15306
# [3]	validation_0-rmse:0.81933	validation_1-rmse:0.98973
# [4]	validation_0-rmse:0.73189	validation_1-rmse:0.88513
# [5]	validation_0-rmse:0.66475	validation_1-rmse:0.82219
# [6]	validation_0-rmse:0.62652	validation_1-rmse:0.77714
# [7]	validation_0-rmse:0.58482	validation_1-rmse:0.73559
# [8]	validation_0-rmse:0.56323	validation_1-rmse:0.70817
# [9]	validation_0-rmse:0.54274	validation_1-rmse:0.67927
# [10]	validation_0-rmse:0.51905	validation_1-rmse:0.65362
# [11]	validation_0-rmse:0.50405	validation_1-rmse:0.64710
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [12]	validation_0-rmse:0.49756	validation_1-rmse:0.63822
# [13]	validation_0-rmse:0.48546	validation_1-rmse:0.63017
# [14]	validation_0-rmse:0.47680	validation_1-rmse:0.61585
# [15]	validation_0-rmse:0.47132	validation_1-rmse:0.61018
# [16]	validation_0-rmse:0.45734	validation_1-rmse:0.59912
# [17]	validation_0-rmse:0.45445	validation_1-rmse:0.59517
# [18]	validation_0-rmse:0.44896	validation_1-rmse:0.59316
# [19]	validation_0-rmse:0.44473	validation_1-rmse:0.59432
# [20]	validation_0-rmse:0.44138	validation_1-rmse:0.59124
# [21]	validation_0-rmse:0.43861	validation_1-rmse:0.58143
# [22]	validation_0-rmse:0.43358	validation_1-rmse:0.58117
# [23]	validation_0-rmse:0.43023	validation_1-rmse:0.58002
# [24]	validation_0-rmse:0.42471	validation_1-rmse:0.57898
# [25]	validation_0-rmse:0.42463	validation_1-rmse:0.57796
# [26]	validation_0-rmse:0.41881	validation_1-rmse:0.58789
# [27]	validation_0-rmse:0.41245	validation_1-rmse:0.58148
# [28]	validation_0-rmse:0.41248	validation_1-rmse:0.58070
# [29]	validation_0-rmse:0.41245	validation_1-rmse:0.58159
# [30]	validation_0-rmse:0.40704	validation_1-rmse:0.58211
# [31]	validation_0-rmse:0.40701	validation_1-rmse:0.58061
# [32]	validation_0-rmse:0.40269	validation_1-rmse:0.56626
# [33]	validation_0-rmse:0.39966	validation_1-rmse:0.55901
# [34]	validation_0-rmse:0.39978	validation_1-rmse:0.55822
# [35]	validation_0-rmse:0.39454	validation_1-rmse:0.55837
# [36]	validation_0-rmse:0.39453	validation_1-rmse:0.55839
# [37]	validation_0-rmse:0.39454	validation_1-rmse:0.55834
# [38]	validation_0-rmse:0.39165	validation_1-rmse:0.55773
# [39]	validation_0-rmse:0.39151	validation_1-rmse:0.55845
# [40]	validation_0-rmse:0.38723	validation_1-rmse:0.56145
# [41]	validation_0-rmse:0.38709	validation_1-rmse:0.56278
# [42]	validation_0-rmse:0.38545	validation_1-rmse:0.56844
# [43]	validation_0-rmse:0.38546	validation_1-rmse:0.56943
# [44]	validation_0-rmse:0.38550	validation_1-rmse:0.57040
# [45]	validation_0-rmse:0.38546	validation_1-rmse:0.56952
# [46]	validation_0-rmse:0.38278	validation_1-rmse:0.57396
# [47]	validation_0-rmse:0.37844	validation_1-rmse:0.56910
# [48]	validation_0-rmse:0.37688	validation_1-rmse:0.57545
# [49]	validation_0-rmse:0.37362	validation_1-rmse:0.57382
# [50]	validation_0-rmse:0.37362	validation_1-rmse:0.57308
# [51]	validation_0-rmse:0.37004	validation_1-rmse:0.56402
# [52]	validation_0-rmse:0.36995	validation_1-rmse:0.56216
# [53]	validation_0-rmse:0.36995	validation_1-rmse:0.56243
# [54]	validation_0-rmse:0.36995	validation_1-rmse:0.56210
# [55]	validation_0-rmse:0.36995	validation_1-rmse:0.56190
# [56]	validation_0-rmse:0.36999	validation_1-rmse:0.56092
# [57]	validation_0-rmse:0.36676	validation_1-rmse:0.55926
# [58]	validation_0-rmse:0.36464	validation_1-rmse:0.55129
# [59]	validation_0-rmse:0.36471	validation_1-rmse:0.55039
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.40963	validation_1-rmse:1.35747
# [1]	validation_0-rmse:1.17484	validation_1-rmse:1.16371
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:0.98865	validation_1-rmse:1.00271
# [3]	validation_0-rmse:0.85319	validation_1-rmse:0.91363
# [4]	validation_0-rmse:0.74459	validation_1-rmse:0.84073
# [5]	validation_0-rmse:0.68003	validation_1-rmse:0.79109
# [6]	validation_0-rmse:0.62258	validation_1-rmse:0.75873
# [7]	validation_0-rmse:0.57516	validation_1-rmse:0.72980
# [8]	validation_0-rmse:0.54219	validation_1-rmse:0.70882
# [9]	validation_0-rmse:0.52174	validation_1-rmse:0.68520
# [10]	validation_0-rmse:0.50055	validation_1-rmse:0.69072
# [11]	validation_0-rmse:0.49013	validation_1-rmse:0.68247
# [12]	validation_0-rmse:0.47840	validation_1-rmse:0.68137
# [13]	validation_0-rmse:0.46708	validation_1-rmse:0.66420
# [14]	validation_0-rmse:0.45701	validation_1-rmse:0.66064
# [15]	validation_0-rmse:0.45316	validation_1-rmse:0.65422
# [16]	validation_0-rmse:0.44452	validation_1-rmse:0.64927
# [17]	validation_0-rmse:0.43847	validation_1-rmse:0.64616
# [18]	validation_0-rmse:0.43343	validation_1-rmse:0.64877
# [19]	validation_0-rmse:0.42901	validation_1-rmse:0.64954
# [20]	validation_0-rmse:0.42427	validation_1-rmse:0.66096
# [21]	validation_0-rmse:0.42100	validation_1-rmse:0.65744
# [22]	validation_0-rmse:0.41678	validation_1-rmse:0.65888
# [23]	validation_0-rmse:0.41003	validation_1-rmse:0.65638
# [24]	validation_0-rmse:0.40317	validation_1-rmse:0.65462
# [25]	validation_0-rmse:0.39743	validation_1-rmse:0.66116
# [26]	validation_0-rmse:0.39749	validation_1-rmse:0.65990
# [27]	validation_0-rmse:0.39685	validation_1-rmse:0.66147
# [28]	validation_0-rmse:0.39663	validation_1-rmse:0.66302
# [29]	validation_0-rmse:0.39490	validation_1-rmse:0.65867
# [30]	validation_0-rmse:0.39065	validation_1-rmse:0.65741
# [31]	validation_0-rmse:0.39058	validation_1-rmse:0.65668
# [32]	validation_0-rmse:0.38663	validation_1-rmse:0.65468
# [33]	validation_0-rmse:0.38350	validation_1-rmse:0.65271
# [34]	validation_0-rmse:0.37690	validation_1-rmse:0.65064
# [35]	validation_0-rmse:0.37677	validation_1-rmse:0.65162
# [36]	validation_0-rmse:0.37689	validation_1-rmse:0.65067
# [37]	validation_0-rmse:0.37283	validation_1-rmse:0.64975
# [0]	validation_0-rmse:1.38867	validation_1-rmse:1.42943
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.15883	validation_1-rmse:1.20723
# [2]	validation_0-rmse:0.97393	validation_1-rmse:1.00953
# [3]	validation_0-rmse:0.85080	validation_1-rmse:0.89383
# [4]	validation_0-rmse:0.75939	validation_1-rmse:0.79758
# [5]	validation_0-rmse:0.69632	validation_1-rmse:0.74228
# [6]	validation_0-rmse:0.63648	validation_1-rmse:0.67999
# [7]	validation_0-rmse:0.59072	validation_1-rmse:0.61777
# [8]	validation_0-rmse:0.57304	validation_1-rmse:0.58133
# [9]	validation_0-rmse:0.55651	validation_1-rmse:0.56445
# [10]	validation_0-rmse:0.53622	validation_1-rmse:0.57091
# [11]	validation_0-rmse:0.52429	validation_1-rmse:0.56975
# [12]	validation_0-rmse:0.50762	validation_1-rmse:0.56378
# [13]	validation_0-rmse:0.50513	validation_1-rmse:0.55549
# [14]	validation_0-rmse:0.49284	validation_1-rmse:0.55311
# [15]	validation_0-rmse:0.48884	validation_1-rmse:0.54032
# [16]	validation_0-rmse:0.48197	validation_1-rmse:0.54728
# [17]	validation_0-rmse:0.47112	validation_1-rmse:0.54660
# [18]	validation_0-rmse:0.46149	validation_1-rmse:0.53470
# [19]	validation_0-rmse:0.45638	validation_1-rmse:0.53760
# [20]	validation_0-rmse:0.45162	validation_1-rmse:0.54118
# [21]	validation_0-rmse:0.44848	validation_1-rmse:0.54455
# [22]	validation_0-rmse:0.44848	validation_1-rmse:0.54444
# [23]	validation_0-rmse:0.44865	validation_1-rmse:0.54229
# [24]	validation_0-rmse:0.43939	validation_1-rmse:0.54127
# [25]	validation_0-rmse:0.43496	validation_1-rmse:0.54440
# [26]	validation_0-rmse:0.43300	validation_1-rmse:0.54640
# [27]	validation_0-rmse:0.43325	validation_1-rmse:0.54312
# [28]	validation_0-rmse:0.42688	validation_1-rmse:0.54729
# [29]	validation_0-rmse:0.42689	validation_1-rmse:0.54709
# [30]	validation_0-rmse:0.42281	validation_1-rmse:0.55072
# [31]	validation_0-rmse:0.42115	validation_1-rmse:0.53534
# [32]	validation_0-rmse:0.40954	validation_1-rmse:0.53751
# [33]	validation_0-rmse:0.40474	validation_1-rmse:0.53613
# [34]	validation_0-rmse:0.40483	validation_1-rmse:0.53360
# [35]	validation_0-rmse:0.39581	validation_1-rmse:0.53347
# [36]	validation_0-rmse:0.39353	validation_1-rmse:0.53424
# [37]	validation_0-rmse:0.38960	validation_1-rmse:0.53704
# [38]	validation_0-rmse:0.38973	validation_1-rmse:0.53603
# [39]	validation_0-rmse:0.38593	validation_1-rmse:0.52669
# [40]	validation_0-rmse:0.38179	validation_1-rmse:0.52128
# [41]	validation_0-rmse:0.37972	validation_1-rmse:0.52328
# [42]	validation_0-rmse:0.37966	validation_1-rmse:0.52195
# [43]	validation_0-rmse:0.37686	validation_1-rmse:0.51770
# [44]	validation_0-rmse:0.37320	validation_1-rmse:0.51379
# [45]	validation_0-rmse:0.37326	validation_1-rmse:0.51182
# [46]	validation_0-rmse:0.37027	validation_1-rmse:0.51102
# [47]	validation_0-rmse:0.37014	validation_1-rmse:0.51299
# [48]	validation_0-rmse:0.37017	validation_1-rmse:0.51201
# [49]	validation_0-rmse:0.36712	validation_1-rmse:0.50718
# [50]	validation_0-rmse:0.36529	validation_1-rmse:0.50570
# [51]	validation_0-rmse:0.36135	validation_1-rmse:0.50577
# [52]	validation_0-rmse:0.36143	validation_1-rmse:0.50460
# [53]	validation_0-rmse:0.36134	validation_1-rmse:0.50593
# [54]	validation_0-rmse:0.35916	validation_1-rmse:0.50139
# [55]	validation_0-rmse:0.35911	validation_1-rmse:0.50024
# [56]	validation_0-rmse:0.35466	validation_1-rmse:0.50407
# [57]	validation_0-rmse:0.35370	validation_1-rmse:0.49425
# [58]	validation_0-rmse:0.35370	validation_1-rmse:0.49413
# [59]	validation_0-rmse:0.35373	validation_1-rmse:0.49370
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.44594	validation_1-rmse:1.15574
# [1]	validation_0-rmse:1.19610	validation_1-rmse:0.97661
# [2]	validation_0-rmse:0.99271	validation_1-rmse:0.84438
# [3]	validation_0-rmse:0.86250	validation_1-rmse:0.76583
# [4]	validation_0-rmse:0.74890	validation_1-rmse:0.70557
# [5]	validation_0-rmse:0.67413	validation_1-rmse:0.66780
# [6]	validation_0-rmse:0.62476	validation_1-rmse:0.65771
# [7]	validation_0-rmse:0.57536	validation_1-rmse:0.63625
# [8]	validation_0-rmse:0.55122	validation_1-rmse:0.63086
# [9]	validation_0-rmse:0.52657	validation_1-rmse:0.62790
# [10]	validation_0-rmse:0.51315	validation_1-rmse:0.61990
# [11]	validation_0-rmse:0.49580	validation_1-rmse:0.61605
# [12]	validation_0-rmse:0.48617	validation_1-rmse:0.61648
# [13]	validation_0-rmse:0.47951	validation_1-rmse:0.61653
# [14]	validation_0-rmse:0.47070	validation_1-rmse:0.60510
# [15]	validation_0-rmse:0.46155	validation_1-rmse:0.59760
# [16]	validation_0-rmse:0.45637	validation_1-rmse:0.59442
# [17]	validation_0-rmse:0.45310	validation_1-rmse:0.59200
# [18]	validation_0-rmse:0.44785	validation_1-rmse:0.59346
# [19]	validation_0-rmse:0.44280	validation_1-rmse:0.59063
# [20]	validation_0-rmse:0.43489	validation_1-rmse:0.59116
# [21]	validation_0-rmse:0.43147	validation_1-rmse:0.59006
# [22]	validation_0-rmse:0.42522	validation_1-rmse:0.59964
# [23]	validation_0-rmse:0.42514	validation_1-rmse:0.60042
# [24]	validation_0-rmse:0.41802	validation_1-rmse:0.59243
# [25]	validation_0-rmse:0.41629	validation_1-rmse:0.59767
# [26]	validation_0-rmse:0.41122	validation_1-rmse:0.58930
# [27]	validation_0-rmse:0.41121	validation_1-rmse:0.59077
# [28]	validation_0-rmse:0.40661	validation_1-rmse:0.58561
# [29]	validation_0-rmse:0.40676	validation_1-rmse:0.58722
# [30]	validation_0-rmse:0.40295	validation_1-rmse:0.58512
# [31]	validation_0-rmse:0.40291	validation_1-rmse:0.58357
# [32]	validation_0-rmse:0.39933	validation_1-rmse:0.58538
# [33]	validation_0-rmse:0.39382	validation_1-rmse:0.57390
# [34]	validation_0-rmse:0.38959	validation_1-rmse:0.58665
# [35]	validation_0-rmse:0.38446	validation_1-rmse:0.58947
# [36]	validation_0-rmse:0.38448	validation_1-rmse:0.58938
# [37]	validation_0-rmse:0.38438	validation_1-rmse:0.59005
# [38]	validation_0-rmse:0.38127	validation_1-rmse:0.58559
# [39]	validation_0-rmse:0.38118	validation_1-rmse:0.58709
# [40]	validation_0-rmse:0.38121	validation_1-rmse:0.58637
# [41]	validation_0-rmse:0.37624	validation_1-rmse:0.58870
# [42]	validation_0-rmse:0.37624	validation_1-rmse:0.58880
# [43]	validation_0-rmse:0.37629	validation_1-rmse:0.58760
# [44]	validation_0-rmse:0.37623	validation_1-rmse:0.58901
# [45]	validation_0-rmse:0.37241	validation_1-rmse:0.58944
# [46]	validation_0-rmse:0.37247	validation_1-rmse:0.58801
# [47]	validation_0-rmse:0.36811	validation_1-rmse:0.58922
# [48]	validation_0-rmse:0.36187	validation_1-rmse:0.59359
# [49]	validation_0-rmse:0.36189	validation_1-rmse:0.59303
# [50]	validation_0-rmse:0.35776	validation_1-rmse:0.60230
# [51]	validation_0-rmse:0.35516	validation_1-rmse:0.60639
# [52]	validation_0-rmse:0.35517	validation_1-rmse:0.60669
# [53]	validation_0-rmse:0.35517	validation_1-rmse:0.60586
# [0]	validation_0-rmse:1.37111	validation_1-rmse:1.51115
# [1]	validation_0-rmse:1.14153	validation_1-rmse:1.31254
# [2]	validation_0-rmse:0.94799	validation_1-rmse:1.17017
# [3]	validation_0-rmse:0.81021	validation_1-rmse:1.03860
# [4]	validation_0-rmse:0.71131	validation_1-rmse:0.94774
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:0.64270	validation_1-rmse:0.88050
# [6]	validation_0-rmse:0.59851	validation_1-rmse:0.83183
# [7]	validation_0-rmse:0.55261	validation_1-rmse:0.80139
# [8]	validation_0-rmse:0.52188	validation_1-rmse:0.78168
# [9]	validation_0-rmse:0.50541	validation_1-rmse:0.75438
# [10]	validation_0-rmse:0.48853	validation_1-rmse:0.75277
# [11]	validation_0-rmse:0.48054	validation_1-rmse:0.74251
# [12]	validation_0-rmse:0.47155	validation_1-rmse:0.75008
# [13]	validation_0-rmse:0.45954	validation_1-rmse:0.73859
# [14]	validation_0-rmse:0.45169	validation_1-rmse:0.73407
# [15]	validation_0-rmse:0.44481	validation_1-rmse:0.73716
# [16]	validation_0-rmse:0.43839	validation_1-rmse:0.73166
# [17]	validation_0-rmse:0.43520	validation_1-rmse:0.73522
# [18]	validation_0-rmse:0.42904	validation_1-rmse:0.74583
# [19]	validation_0-rmse:0.42415	validation_1-rmse:0.73666
# [20]	validation_0-rmse:0.42249	validation_1-rmse:0.73452
# [21]	validation_0-rmse:0.41094	validation_1-rmse:0.74787
# [22]	validation_0-rmse:0.41089	validation_1-rmse:0.74656
# [23]	validation_0-rmse:0.40702	validation_1-rmse:0.74945
# [24]	validation_0-rmse:0.40018	validation_1-rmse:0.75169
# [25]	validation_0-rmse:0.40018	validation_1-rmse:0.75178
# [26]	validation_0-rmse:0.40018	validation_1-rmse:0.75115
# [27]	validation_0-rmse:0.39556	validation_1-rmse:0.75702
# [28]	validation_0-rmse:0.39335	validation_1-rmse:0.75727
# [29]	validation_0-rmse:0.39152	validation_1-rmse:0.76938
# [30]	validation_0-rmse:0.38167	validation_1-rmse:0.77338
# [31]	validation_0-rmse:0.37974	validation_1-rmse:0.77585
# [32]	validation_0-rmse:0.37400	validation_1-rmse:0.77509
# [33]	validation_0-rmse:0.37099	validation_1-rmse:0.77654
# [34]	validation_0-rmse:0.37083	validation_1-rmse:0.77135
# [35]	validation_0-rmse:0.37023	validation_1-rmse:0.77707
# [0]	validation_0-rmse:1.39844	validation_1-rmse:1.34738
# [1]	validation_0-rmse:1.16242	validation_1-rmse:1.11369
# [2]	validation_0-rmse:0.97521	validation_1-rmse:0.94411
# [3]	validation_0-rmse:0.85016	validation_1-rmse:0.83031
# [4]	validation_0-rmse:0.76046	validation_1-rmse:0.75005
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:0.69634	validation_1-rmse:0.69681
# [6]	validation_0-rmse:0.64468	validation_1-rmse:0.66147
# [7]	validation_0-rmse:0.59358	validation_1-rmse:0.63223
# [8]	validation_0-rmse:0.56830	validation_1-rmse:0.60610
# [9]	validation_0-rmse:0.55411	validation_1-rmse:0.58635
# [10]	validation_0-rmse:0.52938	validation_1-rmse:0.57484
# [11]	validation_0-rmse:0.51578	validation_1-rmse:0.57360
# [12]	validation_0-rmse:0.50424	validation_1-rmse:0.56219
# [13]	validation_0-rmse:0.50195	validation_1-rmse:0.56852
# [14]	validation_0-rmse:0.49583	validation_1-rmse:0.55430
# [15]	validation_0-rmse:0.49174	validation_1-rmse:0.55433
# [16]	validation_0-rmse:0.48614	validation_1-rmse:0.53731
# [17]	validation_0-rmse:0.47654	validation_1-rmse:0.53697
# [18]	validation_0-rmse:0.46415	validation_1-rmse:0.54833
# [19]	validation_0-rmse:0.45842	validation_1-rmse:0.54255
# [20]	validation_0-rmse:0.45406	validation_1-rmse:0.53932
# [21]	validation_0-rmse:0.44954	validation_1-rmse:0.53725
# [22]	validation_0-rmse:0.44791	validation_1-rmse:0.53711
# [23]	validation_0-rmse:0.44503	validation_1-rmse:0.53920
# [24]	validation_0-rmse:0.43188	validation_1-rmse:0.53394
# [25]	validation_0-rmse:0.42898	validation_1-rmse:0.53589
# [26]	validation_0-rmse:0.42898	validation_1-rmse:0.53601
# [27]	validation_0-rmse:0.41863	validation_1-rmse:0.54632
# [28]	validation_0-rmse:0.41415	validation_1-rmse:0.55119
# [29]	validation_0-rmse:0.41034	validation_1-rmse:0.54920
# [30]	validation_0-rmse:0.41030	validation_1-rmse:0.54889
# [31]	validation_0-rmse:0.40495	validation_1-rmse:0.54932
# [32]	validation_0-rmse:0.39947	validation_1-rmse:0.55575
# [33]	validation_0-rmse:0.39456	validation_1-rmse:0.55153
# [34]	validation_0-rmse:0.39438	validation_1-rmse:0.55018
# [35]	validation_0-rmse:0.39442	validation_1-rmse:0.54878
# [36]	validation_0-rmse:0.39345	validation_1-rmse:0.54436
# [37]	validation_0-rmse:0.39362	validation_1-rmse:0.54366
# [38]	validation_0-rmse:0.38868	validation_1-rmse:0.54445
# [39]	validation_0-rmse:0.38433	validation_1-rmse:0.54189
# [40]	validation_0-rmse:0.38059	validation_1-rmse:0.53568
# [41]	validation_0-rmse:0.38057	validation_1-rmse:0.53606
# [42]	validation_0-rmse:0.38057	validation_1-rmse:0.53602
# [43]	validation_0-rmse:0.37942	validation_1-rmse:0.55367
# [0]	validation_0-rmse:1.39481	validation_1-rmse:1.49383
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.16351	validation_1-rmse:1.24960
# [2]	validation_0-rmse:0.97304	validation_1-rmse:1.05530
# [3]	validation_0-rmse:0.84690	validation_1-rmse:0.92165
# [4]	validation_0-rmse:0.75553	validation_1-rmse:0.82956
# [5]	validation_0-rmse:0.69064	validation_1-rmse:0.77260
# [6]	validation_0-rmse:0.64508	validation_1-rmse:0.73090
# [7]	validation_0-rmse:0.60137	validation_1-rmse:0.69785
# [8]	validation_0-rmse:0.57811	validation_1-rmse:0.67317
# [9]	validation_0-rmse:0.55533	validation_1-rmse:0.65511
# [10]	validation_0-rmse:0.53149	validation_1-rmse:0.61404
# [11]	validation_0-rmse:0.51628	validation_1-rmse:0.59079
# [12]	validation_0-rmse:0.50242	validation_1-rmse:0.57444
# [13]	validation_0-rmse:0.49573	validation_1-rmse:0.56487
# [14]	validation_0-rmse:0.48437	validation_1-rmse:0.56327
# [15]	validation_0-rmse:0.47774	validation_1-rmse:0.55915
# [16]	validation_0-rmse:0.47200	validation_1-rmse:0.55243
# [17]	validation_0-rmse:0.47166	validation_1-rmse:0.55122
# [18]	validation_0-rmse:0.47061	validation_1-rmse:0.54377
# [19]	validation_0-rmse:0.46063	validation_1-rmse:0.53371
# [20]	validation_0-rmse:0.45543	validation_1-rmse:0.54804
# [21]	validation_0-rmse:0.45599	validation_1-rmse:0.54378
# [22]	validation_0-rmse:0.44549	validation_1-rmse:0.55199
# [23]	validation_0-rmse:0.44012	validation_1-rmse:0.55452
# [24]	validation_0-rmse:0.43235	validation_1-rmse:0.55377
# [25]	validation_0-rmse:0.42688	validation_1-rmse:0.55472
# [26]	validation_0-rmse:0.42368	validation_1-rmse:0.55508
# [27]	validation_0-rmse:0.41952	validation_1-rmse:0.54434
# [28]	validation_0-rmse:0.41389	validation_1-rmse:0.54728
# [29]	validation_0-rmse:0.41017	validation_1-rmse:0.53759
# [30]	validation_0-rmse:0.40296	validation_1-rmse:0.54954
# [31]	validation_0-rmse:0.40296	validation_1-rmse:0.54908
# [32]	validation_0-rmse:0.39325	validation_1-rmse:0.54921
# [33]	validation_0-rmse:0.38630	validation_1-rmse:0.54729
# [34]	validation_0-rmse:0.38193	validation_1-rmse:0.55337
# [35]	validation_0-rmse:0.38193	validation_1-rmse:0.55353
# [36]	validation_0-rmse:0.37879	validation_1-rmse:0.55751
# [37]	validation_0-rmse:0.37880	validation_1-rmse:0.55681
# [38]	validation_0-rmse:0.37597	validation_1-rmse:0.55714
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.39788	validation_1-rmse:1.35804
# [1]	validation_0-rmse:1.16868	validation_1-rmse:1.12364
# [2]	validation_0-rmse:0.99608	validation_1-rmse:0.93022
# [3]	validation_0-rmse:0.87216	validation_1-rmse:0.81569
# [4]	validation_0-rmse:0.77659	validation_1-rmse:0.72695
# [5]	validation_0-rmse:0.69531	validation_1-rmse:0.64184
# [6]	validation_0-rmse:0.63681	validation_1-rmse:0.60566
# [7]	validation_0-rmse:0.59063	validation_1-rmse:0.57630
# [8]	validation_0-rmse:0.56254	validation_1-rmse:0.56861
# [9]	validation_0-rmse:0.53269	validation_1-rmse:0.54479
# [10]	validation_0-rmse:0.51035	validation_1-rmse:0.52965
# [11]	validation_0-rmse:0.49348	validation_1-rmse:0.53079
# [12]	validation_0-rmse:0.48004	validation_1-rmse:0.53908
# [13]	validation_0-rmse:0.46830	validation_1-rmse:0.53586
# [14]	validation_0-rmse:0.45680	validation_1-rmse:0.53559
# [15]	validation_0-rmse:0.45252	validation_1-rmse:0.53514
# [16]	validation_0-rmse:0.44319	validation_1-rmse:0.53353
# [17]	validation_0-rmse:0.44032	validation_1-rmse:0.53616
# [18]	validation_0-rmse:0.44021	validation_1-rmse:0.53684
# [19]	validation_0-rmse:0.43574	validation_1-rmse:0.53907
# [20]	validation_0-rmse:0.42994	validation_1-rmse:0.54720
# [21]	validation_0-rmse:0.42329	validation_1-rmse:0.54553
# [22]	validation_0-rmse:0.42077	validation_1-rmse:0.54538
# [23]	validation_0-rmse:0.42027	validation_1-rmse:0.56198
# [24]	validation_0-rmse:0.41392	validation_1-rmse:0.55830
# [25]	validation_0-rmse:0.41403	validation_1-rmse:0.55736
# [26]	validation_0-rmse:0.40888	validation_1-rmse:0.55817
# [27]	validation_0-rmse:0.40889	validation_1-rmse:0.55887
# [28]	validation_0-rmse:0.40888	validation_1-rmse:0.55777
# [29]	validation_0-rmse:0.40540	validation_1-rmse:0.57103
# [30]	validation_0-rmse:0.39839	validation_1-rmse:0.56409
# [0]	validation_0-rmse:1.42022	validation_1-rmse:1.28499
# [1]	validation_0-rmse:1.18506	validation_1-rmse:1.03047
# [2]	validation_0-rmse:0.99453	validation_1-rmse:0.84430
# [3]	validation_0-rmse:0.86210	validation_1-rmse:0.72555
# [4]	validation_0-rmse:0.75516	validation_1-rmse:0.63129
# [5]	validation_0-rmse:0.69183	validation_1-rmse:0.58524
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:0.64713	validation_1-rmse:0.55769
# [7]	validation_0-rmse:0.60908	validation_1-rmse:0.52419
# [8]	validation_0-rmse:0.58289	validation_1-rmse:0.52362
# [9]	validation_0-rmse:0.55799	validation_1-rmse:0.52977
# [10]	validation_0-rmse:0.53457	validation_1-rmse:0.51177
# [11]	validation_0-rmse:0.51789	validation_1-rmse:0.51068
# [12]	validation_0-rmse:0.51017	validation_1-rmse:0.50593
# [13]	validation_0-rmse:0.49928	validation_1-rmse:0.50920
# [14]	validation_0-rmse:0.48965	validation_1-rmse:0.51805
# [15]	validation_0-rmse:0.48062	validation_1-rmse:0.52205
# [16]	validation_0-rmse:0.46513	validation_1-rmse:0.52387
# [17]	validation_0-rmse:0.46060	validation_1-rmse:0.52870
# [18]	validation_0-rmse:0.45511	validation_1-rmse:0.52999
# [19]	validation_0-rmse:0.45514	validation_1-rmse:0.52833
# [20]	validation_0-rmse:0.45192	validation_1-rmse:0.53242
# [21]	validation_0-rmse:0.44729	validation_1-rmse:0.54947
# [22]	validation_0-rmse:0.44185	validation_1-rmse:0.54437
# [23]	validation_0-rmse:0.43828	validation_1-rmse:0.54824
# [24]	validation_0-rmse:0.43286	validation_1-rmse:0.54209
# [25]	validation_0-rmse:0.43043	validation_1-rmse:0.54492
# [26]	validation_0-rmse:0.43042	validation_1-rmse:0.54532
# [27]	validation_0-rmse:0.42508	validation_1-rmse:0.53823
# [28]	validation_0-rmse:0.42293	validation_1-rmse:0.54199
# [29]	validation_0-rmse:0.42283	validation_1-rmse:0.54653
# [30]	validation_0-rmse:0.41845	validation_1-rmse:0.54964
# [31]	validation_0-rmse:0.41440	validation_1-rmse:0.55125
# [32]	validation_0-rmse:0.41062	validation_1-rmse:0.54335
# [0]	validation_0-rmse:1.42383	validation_1-rmse:1.28606
# [1]	validation_0-rmse:1.17908	validation_1-rmse:1.05920
# [2]	validation_0-rmse:0.98413	validation_1-rmse:0.89894
# [3]	validation_0-rmse:0.85974	validation_1-rmse:0.80874
# [4]	validation_0-rmse:0.75551	validation_1-rmse:0.72500
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:0.68898	validation_1-rmse:0.68438
# [6]	validation_0-rmse:0.63187	validation_1-rmse:0.66597
# [7]	validation_0-rmse:0.58132	validation_1-rmse:0.63806
# [8]	validation_0-rmse:0.55027	validation_1-rmse:0.62041
# [9]	validation_0-rmse:0.53581	validation_1-rmse:0.61861
# [10]	validation_0-rmse:0.50431	validation_1-rmse:0.61205
# [11]	validation_0-rmse:0.49207	validation_1-rmse:0.61341
# [12]	validation_0-rmse:0.48367	validation_1-rmse:0.61088
# [13]	validation_0-rmse:0.47222	validation_1-rmse:0.60425
# [14]	validation_0-rmse:0.45981	validation_1-rmse:0.60564
# [15]	validation_0-rmse:0.45834	validation_1-rmse:0.60811
# [16]	validation_0-rmse:0.45135	validation_1-rmse:0.61030
# [17]	validation_0-rmse:0.44407	validation_1-rmse:0.60030
# [18]	validation_0-rmse:0.43618	validation_1-rmse:0.60071
# [19]	validation_0-rmse:0.42889	validation_1-rmse:0.60085
# [20]	validation_0-rmse:0.42376	validation_1-rmse:0.60262
# [21]	validation_0-rmse:0.41369	validation_1-rmse:0.61406
# [22]	validation_0-rmse:0.40910	validation_1-rmse:0.61034
# [23]	validation_0-rmse:0.40896	validation_1-rmse:0.61190
# [24]	validation_0-rmse:0.40057	validation_1-rmse:0.61772
# [25]	validation_0-rmse:0.39535	validation_1-rmse:0.61714
# [26]	validation_0-rmse:0.38932	validation_1-rmse:0.61709
# [27]	validation_0-rmse:0.38422	validation_1-rmse:0.61506
# [28]	validation_0-rmse:0.38078	validation_1-rmse:0.61005
# [29]	validation_0-rmse:0.37690	validation_1-rmse:0.61180
# [30]	validation_0-rmse:0.37757	validation_1-rmse:0.61738
# [31]	validation_0-rmse:0.37097	validation_1-rmse:0.61974
# [32]	validation_0-rmse:0.36256	validation_1-rmse:0.61522
# [33]	validation_0-rmse:0.35674	validation_1-rmse:0.61881
# [34]	validation_0-rmse:0.35676	validation_1-rmse:0.61840
# [35]	validation_0-rmse:0.35687	validation_1-rmse:0.61715
# [36]	validation_0-rmse:0.35186	validation_1-rmse:0.61700
# [0]	validation_0-rmse:1.46413	validation_1-rmse:1.02362
# [1]	validation_0-rmse:1.22563	validation_1-rmse:0.82401
# [2]	validation_0-rmse:1.02339	validation_1-rmse:0.65634
# [3]	validation_0-rmse:0.88425	validation_1-rmse:0.56680
# [4]	validation_0-rmse:0.78192	validation_1-rmse:0.51375
# [5]	validation_0-rmse:0.71701	validation_1-rmse:0.48819
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:0.67028	validation_1-rmse:0.48582
# [7]	validation_0-rmse:0.61552	validation_1-rmse:0.47889
# [8]	validation_0-rmse:0.59045	validation_1-rmse:0.48978
# [9]	validation_0-rmse:0.56991	validation_1-rmse:0.50130
# [10]	validation_0-rmse:0.54231	validation_1-rmse:0.50734
# [11]	validation_0-rmse:0.52817	validation_1-rmse:0.51195
# [12]	validation_0-rmse:0.51855	validation_1-rmse:0.52172
# [13]	validation_0-rmse:0.50558	validation_1-rmse:0.52454
# [14]	validation_0-rmse:0.49862	validation_1-rmse:0.54593
# [15]	validation_0-rmse:0.49233	validation_1-rmse:0.54681
# [16]	validation_0-rmse:0.47830	validation_1-rmse:0.54307
# [17]	validation_0-rmse:0.47424	validation_1-rmse:0.54645
# [18]	validation_0-rmse:0.46743	validation_1-rmse:0.56728
# [19]	validation_0-rmse:0.46374	validation_1-rmse:0.56821
# [20]	validation_0-rmse:0.45341	validation_1-rmse:0.56320
# [21]	validation_0-rmse:0.44363	validation_1-rmse:0.55804
# [22]	validation_0-rmse:0.44342	validation_1-rmse:0.56249
# [23]	validation_0-rmse:0.44338	validation_1-rmse:0.56461
# [24]	validation_0-rmse:0.43493	validation_1-rmse:0.56565
# [25]	validation_0-rmse:0.43083	validation_1-rmse:0.56766
# [26]	validation_0-rmse:0.42515	validation_1-rmse:0.56701
# [0]	validation_0-rmse:1.35848	validation_1-rmse:1.57928
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:1.12741	validation_1-rmse:1.34959
# [2]	validation_0-rmse:0.93954	validation_1-rmse:1.16272
# [3]	validation_0-rmse:0.80897	validation_1-rmse:1.03747
# [4]	validation_0-rmse:0.71594	validation_1-rmse:0.94791
# [5]	validation_0-rmse:0.64553	validation_1-rmse:0.88005
# [6]	validation_0-rmse:0.59475	validation_1-rmse:0.83259
# [7]	validation_0-rmse:0.55192	validation_1-rmse:0.78233
# [8]	validation_0-rmse:0.52700	validation_1-rmse:0.75658
# [9]	validation_0-rmse:0.51208	validation_1-rmse:0.73643
# [10]	validation_0-rmse:0.49318	validation_1-rmse:0.71274
# [11]	validation_0-rmse:0.47800	validation_1-rmse:0.70251
# [12]	validation_0-rmse:0.47208	validation_1-rmse:0.69901
# [13]	validation_0-rmse:0.46504	validation_1-rmse:0.68815
# [14]	validation_0-rmse:0.46335	validation_1-rmse:0.68429
# [15]	validation_0-rmse:0.46149	validation_1-rmse:0.67849
# [16]	validation_0-rmse:0.45032	validation_1-rmse:0.67518
# [17]	validation_0-rmse:0.43964	validation_1-rmse:0.67304
# [18]	validation_0-rmse:0.43503	validation_1-rmse:0.66990
# [19]	validation_0-rmse:0.42886	validation_1-rmse:0.66813
# [20]	validation_0-rmse:0.41416	validation_1-rmse:0.67163
# [21]	validation_0-rmse:0.41217	validation_1-rmse:0.66911
# [22]	validation_0-rmse:0.40681	validation_1-rmse:0.67593
# [23]	validation_0-rmse:0.40676	validation_1-rmse:0.67470
# [24]	validation_0-rmse:0.39788	validation_1-rmse:0.66570
# [25]	validation_0-rmse:0.39414	validation_1-rmse:0.67051
# [26]	validation_0-rmse:0.38981	validation_1-rmse:0.66776
# [27]	validation_0-rmse:0.38007	validation_1-rmse:0.64667
# [28]	validation_0-rmse:0.37511	validation_1-rmse:0.65588
# [29]	validation_0-rmse:0.37072	validation_1-rmse:0.65640
# [30]	validation_0-rmse:0.36676	validation_1-rmse:0.65392
# [31]	validation_0-rmse:0.36044	validation_1-rmse:0.65440
# [32]	validation_0-rmse:0.35262	validation_1-rmse:0.64652
# [33]	validation_0-rmse:0.34707	validation_1-rmse:0.64776
# [34]	validation_0-rmse:0.34704	validation_1-rmse:0.64966
# [35]	validation_0-rmse:0.34223	validation_1-rmse:0.65519
# [36]	validation_0-rmse:0.34220	validation_1-rmse:0.65444
# [37]	validation_0-rmse:0.34223	validation_1-rmse:0.65521
# [38]	validation_0-rmse:0.33930	validation_1-rmse:0.65252
# [39]	validation_0-rmse:0.33925	validation_1-rmse:0.64961
# [40]	validation_0-rmse:0.33926	validation_1-rmse:0.64933
# [41]	validation_0-rmse:0.33483	validation_1-rmse:0.64931
# [42]	validation_0-rmse:0.33480	validation_1-rmse:0.65064
# [43]	validation_0-rmse:0.33570	validation_1-rmse:0.66048
# [44]	validation_0-rmse:0.33565	validation_1-rmse:0.65889
# [45]	validation_0-rmse:0.33571	validation_1-rmse:0.66070
# [46]	validation_0-rmse:0.33567	validation_1-rmse:0.65979
# [47]	validation_0-rmse:0.33043	validation_1-rmse:0.65138
# [48]	validation_0-rmse:0.33041	validation_1-rmse:0.65334
# [49]	validation_0-rmse:0.33041	validation_1-rmse:0.65317
# [50]	validation_0-rmse:0.32105	validation_1-rmse:0.65842
# [51]	validation_0-rmse:0.32112	validation_1-rmse:0.65518
# [0]	validation_0-rmse:1.33565	validation_1-rmse:1.62764
# [1]	validation_0-rmse:1.11322	validation_1-rmse:1.40205
# [2]	validation_0-rmse:0.92859	validation_1-rmse:1.21806
# [3]	validation_0-rmse:0.80047	validation_1-rmse:1.08775
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:0.70997	validation_1-rmse:1.00126
# [5]	validation_0-rmse:0.63894	validation_1-rmse:0.93296
# [6]	validation_0-rmse:0.59395	validation_1-rmse:0.87863
# [7]	validation_0-rmse:0.55108	validation_1-rmse:0.84105
# [8]	validation_0-rmse:0.52464	validation_1-rmse:0.81539
# [9]	validation_0-rmse:0.50973	validation_1-rmse:0.79729
# [10]	validation_0-rmse:0.49576	validation_1-rmse:0.78658
# [11]	validation_0-rmse:0.47943	validation_1-rmse:0.75526
# [12]	validation_0-rmse:0.46752	validation_1-rmse:0.73680
# [13]	validation_0-rmse:0.45797	validation_1-rmse:0.72145
# [14]	validation_0-rmse:0.45739	validation_1-rmse:0.71919
# [15]	validation_0-rmse:0.45314	validation_1-rmse:0.71166
# [16]	validation_0-rmse:0.44399	validation_1-rmse:0.69621
# [17]	validation_0-rmse:0.44160	validation_1-rmse:0.69075
# [18]	validation_0-rmse:0.43741	validation_1-rmse:0.68203
# [19]	validation_0-rmse:0.43491	validation_1-rmse:0.67859
# [20]	validation_0-rmse:0.42944	validation_1-rmse:0.67320
# [21]	validation_0-rmse:0.42932	validation_1-rmse:0.67183
# [22]	validation_0-rmse:0.42525	validation_1-rmse:0.66895
# [23]	validation_0-rmse:0.42197	validation_1-rmse:0.66701
# [24]	validation_0-rmse:0.41694	validation_1-rmse:0.66501
# [25]	validation_0-rmse:0.41294	validation_1-rmse:0.66350
# [26]	validation_0-rmse:0.40765	validation_1-rmse:0.66567
# [27]	validation_0-rmse:0.40449	validation_1-rmse:0.66134
# [28]	validation_0-rmse:0.39720	validation_1-rmse:0.67059
# [29]	validation_0-rmse:0.39310	validation_1-rmse:0.67471
# [30]	validation_0-rmse:0.38945	validation_1-rmse:0.67668
# [31]	validation_0-rmse:0.38942	validation_1-rmse:0.67757
# [32]	validation_0-rmse:0.38948	validation_1-rmse:0.68156
# [33]	validation_0-rmse:0.38961	validation_1-rmse:0.68331
# [34]	validation_0-rmse:0.38786	validation_1-rmse:0.68756
# [35]	validation_0-rmse:0.38175	validation_1-rmse:0.68881
# [36]	validation_0-rmse:0.38174	validation_1-rmse:0.68870
# [37]	validation_0-rmse:0.38183	validation_1-rmse:0.68949
# [38]	validation_0-rmse:0.37785	validation_1-rmse:0.68364
# [39]	validation_0-rmse:0.37787	validation_1-rmse:0.68393
# [40]	validation_0-rmse:0.37286	validation_1-rmse:0.69038
# [41]	validation_0-rmse:0.37271	validation_1-rmse:0.68865
# [42]	validation_0-rmse:0.37278	validation_1-rmse:0.68956
# [43]	validation_0-rmse:0.37270	validation_1-rmse:0.68853
# [44]	validation_0-rmse:0.37052	validation_1-rmse:0.69299
# [45]	validation_0-rmse:0.37046	validation_1-rmse:0.69121
# [46]	validation_0-rmse:0.37051	validation_1-rmse:0.69268
# [47]	validation_0-rmse:0.37046	validation_1-rmse:0.69066
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.40627	validation_1-rmse:1.38330
# [1]	validation_0-rmse:1.16614	validation_1-rmse:1.16227
# [2]	validation_0-rmse:0.98509	validation_1-rmse:0.99032
# [3]	validation_0-rmse:0.85634	validation_1-rmse:0.88164
# [4]	validation_0-rmse:0.76355	validation_1-rmse:0.78167
# [5]	validation_0-rmse:0.68940	validation_1-rmse:0.71415
# [6]	validation_0-rmse:0.64136	validation_1-rmse:0.66680
# [7]	validation_0-rmse:0.60029	validation_1-rmse:0.64101
# [8]	validation_0-rmse:0.57119	validation_1-rmse:0.60781
# [9]	validation_0-rmse:0.55423	validation_1-rmse:0.59652
# [10]	validation_0-rmse:0.52971	validation_1-rmse:0.58736
# [11]	validation_0-rmse:0.51694	validation_1-rmse:0.58023
# [12]	validation_0-rmse:0.49955	validation_1-rmse:0.57115
# [13]	validation_0-rmse:0.48869	validation_1-rmse:0.56330
# [14]	validation_0-rmse:0.48234	validation_1-rmse:0.56552
# [15]	validation_0-rmse:0.47819	validation_1-rmse:0.56829
# [16]	validation_0-rmse:0.47092	validation_1-rmse:0.56277
# [17]	validation_0-rmse:0.46339	validation_1-rmse:0.57075
# [18]	validation_0-rmse:0.45386	validation_1-rmse:0.55487
# [19]	validation_0-rmse:0.44512	validation_1-rmse:0.55844
# [20]	validation_0-rmse:0.44055	validation_1-rmse:0.55778
# [21]	validation_0-rmse:0.43322	validation_1-rmse:0.55652
# [22]	validation_0-rmse:0.43276	validation_1-rmse:0.55678
# [23]	validation_0-rmse:0.43277	validation_1-rmse:0.55712
# [24]	validation_0-rmse:0.42195	validation_1-rmse:0.55698
# [25]	validation_0-rmse:0.41887	validation_1-rmse:0.55680
# [26]	validation_0-rmse:0.41883	validation_1-rmse:0.55670
# [27]	validation_0-rmse:0.41393	validation_1-rmse:0.54281
# [28]	validation_0-rmse:0.40742	validation_1-rmse:0.53995
# [29]	validation_0-rmse:0.40375	validation_1-rmse:0.53872
# [30]	validation_0-rmse:0.40147	validation_1-rmse:0.53709
# [31]	validation_0-rmse:0.40009	validation_1-rmse:0.53490
# [32]	validation_0-rmse:0.39301	validation_1-rmse:0.53254
# [33]	validation_0-rmse:0.38879	validation_1-rmse:0.53251
# [34]	validation_0-rmse:0.38535	validation_1-rmse:0.53064
# [35]	validation_0-rmse:0.37948	validation_1-rmse:0.51396
# [36]	validation_0-rmse:0.37946	validation_1-rmse:0.51420
# [37]	validation_0-rmse:0.37948	validation_1-rmse:0.51433
# [38]	validation_0-rmse:0.37946	validation_1-rmse:0.51424
# [39]	validation_0-rmse:0.37183	validation_1-rmse:0.52252
# [40]	validation_0-rmse:0.37183	validation_1-rmse:0.52252
# [41]	validation_0-rmse:0.37181	validation_1-rmse:0.52283
# [42]	validation_0-rmse:0.37186	validation_1-rmse:0.52300
# [43]	validation_0-rmse:0.36926	validation_1-rmse:0.52415
# [44]	validation_0-rmse:0.36918	validation_1-rmse:0.52387
# [45]	validation_0-rmse:0.36645	validation_1-rmse:0.52398
# [46]	validation_0-rmse:0.36362	validation_1-rmse:0.52512
# [47]	validation_0-rmse:0.36198	validation_1-rmse:0.52128
# [48]	validation_0-rmse:0.36195	validation_1-rmse:0.52124
# [49]	validation_0-rmse:0.35630	validation_1-rmse:0.52144
# [50]	validation_0-rmse:0.35340	validation_1-rmse:0.50885
# [51]	validation_0-rmse:0.35334	validation_1-rmse:0.50894
# [52]	validation_0-rmse:0.35332	validation_1-rmse:0.50897
# [53]	validation_0-rmse:0.35349	validation_1-rmse:0.50877
# [54]	validation_0-rmse:0.35327	validation_1-rmse:0.50921
# [55]	validation_0-rmse:0.35328	validation_1-rmse:0.50911
# [56]	validation_0-rmse:0.35327	validation_1-rmse:0.50925
# [57]	validation_0-rmse:0.34483	validation_1-rmse:0.50971
# [58]	validation_0-rmse:0.34239	validation_1-rmse:0.50703
# [59]	validation_0-rmse:0.34246	validation_1-rmse:0.50730
# [0]	validation_0-rmse:1.44772	validation_1-rmse:1.13745
# [1]	validation_0-rmse:1.19289	validation_1-rmse:0.92668
# [2]	validation_0-rmse:1.00290	validation_1-rmse:0.77353
# [3]	validation_0-rmse:0.87155	validation_1-rmse:0.67350
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:0.76815	validation_1-rmse:0.60806
# [5]	validation_0-rmse:0.69107	validation_1-rmse:0.57044
# [6]	validation_0-rmse:0.64098	validation_1-rmse:0.55514
# [7]	validation_0-rmse:0.59289	validation_1-rmse:0.53286
# [8]	validation_0-rmse:0.56856	validation_1-rmse:0.52603
# [9]	validation_0-rmse:0.54230	validation_1-rmse:0.52652
# [10]	validation_0-rmse:0.53134	validation_1-rmse:0.52360
# [11]	validation_0-rmse:0.52187	validation_1-rmse:0.52544
# [12]	validation_0-rmse:0.50742	validation_1-rmse:0.52476
# [13]	validation_0-rmse:0.50325	validation_1-rmse:0.52824
# [14]	validation_0-rmse:0.49099	validation_1-rmse:0.52797
# [15]	validation_0-rmse:0.49038	validation_1-rmse:0.53047
# [16]	validation_0-rmse:0.48393	validation_1-rmse:0.53065
# [17]	validation_0-rmse:0.47531	validation_1-rmse:0.53063
# [18]	validation_0-rmse:0.47039	validation_1-rmse:0.52014
# [19]	validation_0-rmse:0.46389	validation_1-rmse:0.52552
# [20]	validation_0-rmse:0.46118	validation_1-rmse:0.52587
# [21]	validation_0-rmse:0.45475	validation_1-rmse:0.53597
# [22]	validation_0-rmse:0.45320	validation_1-rmse:0.54140
# [23]	validation_0-rmse:0.44888	validation_1-rmse:0.53987
# [24]	validation_0-rmse:0.43847	validation_1-rmse:0.53371
# [25]	validation_0-rmse:0.43763	validation_1-rmse:0.54004
# [26]	validation_0-rmse:0.43747	validation_1-rmse:0.54196
# [27]	validation_0-rmse:0.43435	validation_1-rmse:0.53737
# [28]	validation_0-rmse:0.43106	validation_1-rmse:0.54129
# [29]	validation_0-rmse:0.42385	validation_1-rmse:0.53801
# [30]	validation_0-rmse:0.41507	validation_1-rmse:0.54647
# [31]	validation_0-rmse:0.41074	validation_1-rmse:0.55103
# [32]	validation_0-rmse:0.40365	validation_1-rmse:0.54514
# [33]	validation_0-rmse:0.39697	validation_1-rmse:0.54054
# [34]	validation_0-rmse:0.39116	validation_1-rmse:0.53585
# [35]	validation_0-rmse:0.39115	validation_1-rmse:0.53747
# [36]	validation_0-rmse:0.38780	validation_1-rmse:0.54079
# [37]	validation_0-rmse:0.38664	validation_1-rmse:0.54553
# [0]	validation_0-rmse:1.40137	validation_1-rmse:1.34011
# [1]	validation_0-rmse:1.16004	validation_1-rmse:1.10432
# [2]	validation_0-rmse:0.96803	validation_1-rmse:0.91627
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:0.83152	validation_1-rmse:0.78395
# [4]	validation_0-rmse:0.73188	validation_1-rmse:0.72100
# [5]	validation_0-rmse:0.66659	validation_1-rmse:0.67597
# [6]	validation_0-rmse:0.62730	validation_1-rmse:0.64042
# [7]	validation_0-rmse:0.58328	validation_1-rmse:0.60372
# [8]	validation_0-rmse:0.56430	validation_1-rmse:0.58807
# [9]	validation_0-rmse:0.54086	validation_1-rmse:0.58460
# [10]	validation_0-rmse:0.51562	validation_1-rmse:0.56183
# [11]	validation_0-rmse:0.50564	validation_1-rmse:0.55594
# [12]	validation_0-rmse:0.49572	validation_1-rmse:0.55299
# [13]	validation_0-rmse:0.48665	validation_1-rmse:0.55036
# [14]	validation_0-rmse:0.48060	validation_1-rmse:0.55219
# [15]	validation_0-rmse:0.47201	validation_1-rmse:0.56671
# [16]	validation_0-rmse:0.45763	validation_1-rmse:0.55920
# [17]	validation_0-rmse:0.44805	validation_1-rmse:0.55463
# [18]	validation_0-rmse:0.44442	validation_1-rmse:0.54973
# [19]	validation_0-rmse:0.43772	validation_1-rmse:0.54842
# [20]	validation_0-rmse:0.42736	validation_1-rmse:0.54601
# [21]	validation_0-rmse:0.42387	validation_1-rmse:0.54060
# [22]	validation_0-rmse:0.42257	validation_1-rmse:0.53831
# [23]	validation_0-rmse:0.41971	validation_1-rmse:0.53882
# [24]	validation_0-rmse:0.41084	validation_1-rmse:0.53372
# [25]	validation_0-rmse:0.40667	validation_1-rmse:0.53159
# [26]	validation_0-rmse:0.40048	validation_1-rmse:0.53536
# [27]	validation_0-rmse:0.40054	validation_1-rmse:0.53550
# [28]	validation_0-rmse:0.39658	validation_1-rmse:0.54241
# [29]	validation_0-rmse:0.39656	validation_1-rmse:0.54236
# [30]	validation_0-rmse:0.39664	validation_1-rmse:0.54251
# [31]	validation_0-rmse:0.39350	validation_1-rmse:0.53895
# [32]	validation_0-rmse:0.38766	validation_1-rmse:0.53543
# [33]	validation_0-rmse:0.37975	validation_1-rmse:0.53066
# [34]	validation_0-rmse:0.37797	validation_1-rmse:0.52976
# [35]	validation_0-rmse:0.37706	validation_1-rmse:0.53072
# [36]	validation_0-rmse:0.37424	validation_1-rmse:0.53382
# [37]	validation_0-rmse:0.37424	validation_1-rmse:0.53379
# [38]	validation_0-rmse:0.37428	validation_1-rmse:0.53396
# [39]	validation_0-rmse:0.37254	validation_1-rmse:0.53173
# [40]	validation_0-rmse:0.37259	validation_1-rmse:0.53193
# [41]	validation_0-rmse:0.37099	validation_1-rmse:0.53003
# [42]	validation_0-rmse:0.37099	validation_1-rmse:0.53001
# [43]	validation_0-rmse:0.36849	validation_1-rmse:0.52523
# [44]	validation_0-rmse:0.36850	validation_1-rmse:0.52517
# [45]	validation_0-rmse:0.36602	validation_1-rmse:0.52746
# [46]	validation_0-rmse:0.36587	validation_1-rmse:0.52762
# [47]	validation_0-rmse:0.36394	validation_1-rmse:0.53188
# [48]	validation_0-rmse:0.36394	validation_1-rmse:0.53184
# [49]	validation_0-rmse:0.36397	validation_1-rmse:0.53157
# [50]	validation_0-rmse:0.36127	validation_1-rmse:0.52827
# [51]	validation_0-rmse:0.35873	validation_1-rmse:0.52301
# [52]	validation_0-rmse:0.35570	validation_1-rmse:0.52091
# [53]	validation_0-rmse:0.35241	validation_1-rmse:0.52034
# [54]	validation_0-rmse:0.34937	validation_1-rmse:0.52243
# [55]	validation_0-rmse:0.34941	validation_1-rmse:0.52268
# [56]	validation_0-rmse:0.34941	validation_1-rmse:0.52270
# [57]	validation_0-rmse:0.34955	validation_1-rmse:0.50600
# [58]	validation_0-rmse:0.34661	validation_1-rmse:0.50324
# [59]	validation_0-rmse:0.34659	validation_1-rmse:0.50308
# [0]	validation_0-rmse:1.43211	validation_1-rmse:1.24910
# [1]	validation_0-rmse:1.19634	validation_1-rmse:1.02013
# [2]	validation_0-rmse:0.99623	validation_1-rmse:0.86338
# [3]	validation_0-rmse:0.85721	validation_1-rmse:0.73521
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
# [3]	validation_0-rmse:0.84531	validation_1-rmse:0.80351
# [4]	validation_0-rmse:0.76552	validation_1-rmse:0.73812
# [5]	validation_0-rmse:0.69730	validation_1-rmse:0.69575
# [6]	validation_0-rmse:0.64311	validation_1-rmse:0.68189
# [7]	validation_0-rmse:0.58902	validation_1-rmse:0.62870
# [8]	validation_0-rmse:0.56141	validation_1-rmse:0.61970
# [9]	validation_0-rmse:0.54045	validation_1-rmse:0.61539
# [10]	validation_0-rmse:0.51792	validation_1-rmse:0.60875
# [11]	validation_0-rmse:0.49855	validation_1-rmse:0.62998
# [12]	validation_0-rmse:0.48584	validation_1-rmse:0.63526
# [13]	validation_0-rmse:0.48052	validation_1-rmse:0.64010
# [14]	validation_0-rmse:0.47699	validation_1-rmse:0.65068
# [15]	validation_0-rmse:0.47375	validation_1-rmse:0.65529
# [16]	validation_0-rmse:0.46921	validation_1-rmse:0.67242
# [17]	validation_0-rmse:0.46510	validation_1-rmse:0.66862
# [18]	validation_0-rmse:0.46470	validation_1-rmse:0.66987
# [19]	validation_0-rmse:0.45535	validation_1-rmse:0.67137
# [20]	validation_0-rmse:0.44980	validation_1-rmse:0.66284
# [21]	validation_0-rmse:0.44420	validation_1-rmse:0.66429
# [22]	validation_0-rmse:0.44393	validation_1-rmse:0.66622
# [23]	validation_0-rmse:0.43723	validation_1-rmse:0.66345
# [24]	validation_0-rmse:0.43097	validation_1-rmse:0.65796
# [25]	validation_0-rmse:0.42541	validation_1-rmse:0.66426
# [26]	validation_0-rmse:0.42102	validation_1-rmse:0.66216
# [27]	validation_0-rmse:0.41977	validation_1-rmse:0.66415
# [28]	validation_0-rmse:0.41599	validation_1-rmse:0.67071
# [29]	validation_0-rmse:0.41211	validation_1-rmse:0.66831
# [30]	validation_0-rmse:0.40863	validation_1-rmse:0.67060
# [0]	validation_0-rmse:1.33240	validation_1-rmse:1.67386
# [1]	validation_0-rmse:1.12060	validation_1-rmse:1.44753
# [2]	validation_0-rmse:0.94160	validation_1-rmse:1.22288
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:0.81475	validation_1-rmse:1.07804
# [4]	validation_0-rmse:0.72937	validation_1-rmse:0.97192
# [5]	validation_0-rmse:0.66837	validation_1-rmse:0.89909
# [6]	validation_0-rmse:0.62918	validation_1-rmse:0.84241
# [7]	validation_0-rmse:0.59199	validation_1-rmse:0.78068
# [8]	validation_0-rmse:0.56938	validation_1-rmse:0.75261
# [9]	validation_0-rmse:0.54530	validation_1-rmse:0.71324
# [10]	validation_0-rmse:0.52902	validation_1-rmse:0.67859
# [11]	validation_0-rmse:0.50997	validation_1-rmse:0.66534
# [12]	validation_0-rmse:0.49950	validation_1-rmse:0.65859
# [13]	validation_0-rmse:0.48702	validation_1-rmse:0.65424
# [14]	validation_0-rmse:0.47812	validation_1-rmse:0.65572
# [15]	validation_0-rmse:0.47027	validation_1-rmse:0.64237
# [16]	validation_0-rmse:0.46964	validation_1-rmse:0.63805
# [17]	validation_0-rmse:0.46956	validation_1-rmse:0.63738
# [18]	validation_0-rmse:0.46317	validation_1-rmse:0.64136
# [19]	validation_0-rmse:0.45428	validation_1-rmse:0.64109
# [20]	validation_0-rmse:0.44840	validation_1-rmse:0.63855
# [21]	validation_0-rmse:0.44040	validation_1-rmse:0.64159
# [22]	validation_0-rmse:0.43521	validation_1-rmse:0.63529
# [23]	validation_0-rmse:0.43519	validation_1-rmse:0.63648
# [24]	validation_0-rmse:0.42563	validation_1-rmse:0.62523
# [25]	validation_0-rmse:0.42021	validation_1-rmse:0.61436
# [26]	validation_0-rmse:0.42019	validation_1-rmse:0.61457
# [27]	validation_0-rmse:0.41719	validation_1-rmse:0.60608
# [28]	validation_0-rmse:0.41536	validation_1-rmse:0.60575
# [29]	validation_0-rmse:0.40719	validation_1-rmse:0.61520
# [30]	validation_0-rmse:0.40421	validation_1-rmse:0.61969
# [31]	validation_0-rmse:0.40420	validation_1-rmse:0.62077
# [32]	validation_0-rmse:0.39921	validation_1-rmse:0.61498
# [33]	validation_0-rmse:0.39921	validation_1-rmse:0.61426
# [34]	validation_0-rmse:0.39927	validation_1-rmse:0.61672
# [35]	validation_0-rmse:0.39926	validation_1-rmse:0.61287
# [36]	validation_0-rmse:0.39931	validation_1-rmse:0.61203
# [37]	validation_0-rmse:0.39510	validation_1-rmse:0.61788
# [38]	validation_0-rmse:0.39110	validation_1-rmse:0.61599
# [39]	validation_0-rmse:0.38433	validation_1-rmse:0.61323
# [40]	validation_0-rmse:0.38438	validation_1-rmse:0.61470
# [41]	validation_0-rmse:0.38440	validation_1-rmse:0.61512
# [42]	validation_0-rmse:0.38442	validation_1-rmse:0.61546
# [43]	validation_0-rmse:0.37954	validation_1-rmse:0.61505
# [44]	validation_0-rmse:0.37954	validation_1-rmse:0.61344
# [45]	validation_0-rmse:0.37721	validation_1-rmse:0.61191
# [46]	validation_0-rmse:0.37471	validation_1-rmse:0.61555
# [47]	validation_0-rmse:0.37308	validation_1-rmse:0.60883
# [48]	validation_0-rmse:0.36928	validation_1-rmse:0.60285
# [49]	validation_0-rmse:0.36531	validation_1-rmse:0.62030
# [50]	validation_0-rmse:0.36303	validation_1-rmse:0.61793
# [51]	validation_0-rmse:0.36302	validation_1-rmse:0.61875
# [52]	validation_0-rmse:0.36302	validation_1-rmse:0.61863
# [53]	validation_0-rmse:0.36304	validation_1-rmse:0.61958
# [54]	validation_0-rmse:0.36306	validation_1-rmse:0.61680
# [55]	validation_0-rmse:0.36308	validation_1-rmse:0.61652
# [56]	validation_0-rmse:0.36302	validation_1-rmse:0.61809
# [57]	validation_0-rmse:0.35868	validation_1-rmse:0.61104
# [58]	validation_0-rmse:0.35868	validation_1-rmse:0.61052
# [59]	validation_0-rmse:0.35868	validation_1-rmse:0.61093
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.38350	validation_1-rmse:1.43503
# [1]	validation_0-rmse:1.14057	validation_1-rmse:1.19174
# [2]	validation_0-rmse:0.94915	validation_1-rmse:1.02102
# [3]	validation_0-rmse:0.81765	validation_1-rmse:0.91386
# [4]	validation_0-rmse:0.73708	validation_1-rmse:0.83982
# [5]	validation_0-rmse:0.68056	validation_1-rmse:0.79539
# [6]	validation_0-rmse:0.63157	validation_1-rmse:0.74763
# [7]	validation_0-rmse:0.58908	validation_1-rmse:0.71657
# [8]	validation_0-rmse:0.55686	validation_1-rmse:0.66846
# [9]	validation_0-rmse:0.53796	validation_1-rmse:0.64371
# [10]	validation_0-rmse:0.50841	validation_1-rmse:0.62441
# [11]	validation_0-rmse:0.48981	validation_1-rmse:0.60728
# [12]	validation_0-rmse:0.48048	validation_1-rmse:0.59189
# [13]	validation_0-rmse:0.47498	validation_1-rmse:0.57880
# [14]	validation_0-rmse:0.46645	validation_1-rmse:0.57466
# [15]	validation_0-rmse:0.46507	validation_1-rmse:0.57239
# [16]	validation_0-rmse:0.46347	validation_1-rmse:0.57175
# [17]	validation_0-rmse:0.46022	validation_1-rmse:0.56407
# [18]	validation_0-rmse:0.45714	validation_1-rmse:0.56231
# [19]	validation_0-rmse:0.45196	validation_1-rmse:0.55932
# [20]	validation_0-rmse:0.44382	validation_1-rmse:0.56143
# [21]	validation_0-rmse:0.43898	validation_1-rmse:0.56379
# [22]	validation_0-rmse:0.43869	validation_1-rmse:0.56007
# [23]	validation_0-rmse:0.43662	validation_1-rmse:0.56015
# [24]	validation_0-rmse:0.42755	validation_1-rmse:0.55697
# [25]	validation_0-rmse:0.41992	validation_1-rmse:0.54664
# [26]	validation_0-rmse:0.41964	validation_1-rmse:0.54795
# [27]	validation_0-rmse:0.41207	validation_1-rmse:0.54755
# [28]	validation_0-rmse:0.40958	validation_1-rmse:0.54714
# [29]	validation_0-rmse:0.40458	validation_1-rmse:0.54708
# [30]	validation_0-rmse:0.40081	validation_1-rmse:0.54637
# [31]	validation_0-rmse:0.39658	validation_1-rmse:0.55090
# [32]	validation_0-rmse:0.38544	validation_1-rmse:0.54310
# [33]	validation_0-rmse:0.37631	validation_1-rmse:0.54054
# [34]	validation_0-rmse:0.37611	validation_1-rmse:0.54133
# [35]	validation_0-rmse:0.37155	validation_1-rmse:0.54697
# [36]	validation_0-rmse:0.36843	validation_1-rmse:0.54882
# [37]	validation_0-rmse:0.36848	validation_1-rmse:0.54860
# [38]	validation_0-rmse:0.36116	validation_1-rmse:0.54631
# [39]	validation_0-rmse:0.35801	validation_1-rmse:0.54592
# [40]	validation_0-rmse:0.35806	validation_1-rmse:0.54561
# [41]	validation_0-rmse:0.35796	validation_1-rmse:0.54674
# [42]	validation_0-rmse:0.35805	validation_1-rmse:0.54564
# [43]	validation_0-rmse:0.35805	validation_1-rmse:0.54568
# [44]	validation_0-rmse:0.35799	validation_1-rmse:0.54613
# [45]	validation_0-rmse:0.35455	validation_1-rmse:0.54468
# [46]	validation_0-rmse:0.35454	validation_1-rmse:0.54443
# [47]	validation_0-rmse:0.35318	validation_1-rmse:0.54640
# [48]	validation_0-rmse:0.34918	validation_1-rmse:0.54033
# [49]	validation_0-rmse:0.34519	validation_1-rmse:0.54144
# [50]	validation_0-rmse:0.34210	validation_1-rmse:0.54180
# [51]	validation_0-rmse:0.33762	validation_1-rmse:0.54146
# [52]	validation_0-rmse:0.33764	validation_1-rmse:0.54132
# [53]	validation_0-rmse:0.33773	validation_1-rmse:0.54068
# [54]	validation_0-rmse:0.33770	validation_1-rmse:0.54086
# [55]	validation_0-rmse:0.33772	validation_1-rmse:0.54075
# [56]	validation_0-rmse:0.33773	validation_1-rmse:0.54069
# [57]	validation_0-rmse:0.33338	validation_1-rmse:0.54219
# [58]	validation_0-rmse:0.33344	validation_1-rmse:0.54178
# [59]	validation_0-rmse:0.33331	validation_1-rmse:0.54286
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.41899	validation_1-rmse:1.31673
# [1]	validation_0-rmse:1.18642	validation_1-rmse:1.10659
# [2]	validation_0-rmse:1.00007	validation_1-rmse:0.93063
# [3]	validation_0-rmse:0.86625	validation_1-rmse:0.81918
# [4]	validation_0-rmse:0.78330	validation_1-rmse:0.73798
# [5]	validation_0-rmse:0.70189	validation_1-rmse:0.68691
# [6]	validation_0-rmse:0.64642	validation_1-rmse:0.62735
# [7]	validation_0-rmse:0.59236	validation_1-rmse:0.57859
# [8]	validation_0-rmse:0.56556	validation_1-rmse:0.57318
# [9]	validation_0-rmse:0.54096	validation_1-rmse:0.57917
# [10]	validation_0-rmse:0.51403	validation_1-rmse:0.56640
# [11]	validation_0-rmse:0.49953	validation_1-rmse:0.55959
# [12]	validation_0-rmse:0.49245	validation_1-rmse:0.57468
# [13]	validation_0-rmse:0.49077	validation_1-rmse:0.57416
# [14]	validation_0-rmse:0.48430	validation_1-rmse:0.57097
# [15]	validation_0-rmse:0.47985	validation_1-rmse:0.57655
# [16]	validation_0-rmse:0.47129	validation_1-rmse:0.57245
# [17]	validation_0-rmse:0.47140	validation_1-rmse:0.57242
# [18]	validation_0-rmse:0.46554	validation_1-rmse:0.57324
# [19]	validation_0-rmse:0.45949	validation_1-rmse:0.55207
# [20]	validation_0-rmse:0.45342	validation_1-rmse:0.54793
# [21]	validation_0-rmse:0.44924	validation_1-rmse:0.54712
# [22]	validation_0-rmse:0.44549	validation_1-rmse:0.54740
# [23]	validation_0-rmse:0.44540	validation_1-rmse:0.54766
# [24]	validation_0-rmse:0.43629	validation_1-rmse:0.54735
# [25]	validation_0-rmse:0.43634	validation_1-rmse:0.54708
# [26]	validation_0-rmse:0.43020	validation_1-rmse:0.53436
# [27]	validation_0-rmse:0.42939	validation_1-rmse:0.54057
# [28]	validation_0-rmse:0.42938	validation_1-rmse:0.54012
# [29]	validation_0-rmse:0.42823	validation_1-rmse:0.53061
# [30]	validation_0-rmse:0.42825	validation_1-rmse:0.53030
# [31]	validation_0-rmse:0.42823	validation_1-rmse:0.53045
# [32]	validation_0-rmse:0.42434	validation_1-rmse:0.52570
# [33]	validation_0-rmse:0.42222	validation_1-rmse:0.52434
# [34]	validation_0-rmse:0.41648	validation_1-rmse:0.52816
# [35]	validation_0-rmse:0.41128	validation_1-rmse:0.54677
# [36]	validation_0-rmse:0.40694	validation_1-rmse:0.55025
# [37]	validation_0-rmse:0.40507	validation_1-rmse:0.55101
# [38]	validation_0-rmse:0.40183	validation_1-rmse:0.55237
# [39]	validation_0-rmse:0.39823	validation_1-rmse:0.53616
# [40]	validation_0-rmse:0.39826	validation_1-rmse:0.53584
# [41]	validation_0-rmse:0.39827	validation_1-rmse:0.53583
# [42]	validation_0-rmse:0.39659	validation_1-rmse:0.55418
# [43]	validation_0-rmse:0.39647	validation_1-rmse:0.55446
# [44]	validation_0-rmse:0.39644	validation_1-rmse:0.55479
# [45]	validation_0-rmse:0.39673	validation_1-rmse:0.55585
# [46]	validation_0-rmse:0.39662	validation_1-rmse:0.55556
# [47]	validation_0-rmse:0.39664	validation_1-rmse:0.55562
# [48]	validation_0-rmse:0.39649	validation_1-rmse:0.55515
# [49]	validation_0-rmse:0.39649	validation_1-rmse:0.55515
# [50]	validation_0-rmse:0.39611	validation_1-rmse:0.54970
# [51]	validation_0-rmse:0.39605	validation_1-rmse:0.54950
# [52]	validation_0-rmse:0.39598	validation_1-rmse:0.54908
# [53]	validation_0-rmse:0.39599	validation_1-rmse:0.54890
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.36395	validation_1-rmse:1.51609
# [1]	validation_0-rmse:1.14841	validation_1-rmse:1.28461
# [2]	validation_0-rmse:0.97203	validation_1-rmse:1.06445
# [3]	validation_0-rmse:0.85189	validation_1-rmse:0.91635
# [4]	validation_0-rmse:0.77549	validation_1-rmse:0.83637
# [5]	validation_0-rmse:0.70296	validation_1-rmse:0.76098
# [6]	validation_0-rmse:0.65342	validation_1-rmse:0.70769
# [7]	validation_0-rmse:0.60021	validation_1-rmse:0.61766
# [8]	validation_0-rmse:0.57657	validation_1-rmse:0.59305
# [9]	validation_0-rmse:0.55252	validation_1-rmse:0.57158
# [10]	validation_0-rmse:0.52762	validation_1-rmse:0.53016
# [11]	validation_0-rmse:0.51409	validation_1-rmse:0.52219
# [12]	validation_0-rmse:0.50185	validation_1-rmse:0.51027
# [13]	validation_0-rmse:0.49525	validation_1-rmse:0.50521
# [14]	validation_0-rmse:0.48659	validation_1-rmse:0.50221
# [15]	validation_0-rmse:0.48133	validation_1-rmse:0.49810
# [16]	validation_0-rmse:0.47842	validation_1-rmse:0.49506
# [17]	validation_0-rmse:0.46945	validation_1-rmse:0.49634
# [18]	validation_0-rmse:0.45983	validation_1-rmse:0.48612
# [19]	validation_0-rmse:0.45975	validation_1-rmse:0.48593
# [20]	validation_0-rmse:0.45669	validation_1-rmse:0.47681
# [21]	validation_0-rmse:0.45013	validation_1-rmse:0.46639
# [22]	validation_0-rmse:0.44826	validation_1-rmse:0.46422
# [23]	validation_0-rmse:0.44431	validation_1-rmse:0.46567
# [24]	validation_0-rmse:0.43766	validation_1-rmse:0.45373
# [25]	validation_0-rmse:0.43104	validation_1-rmse:0.46853
# [26]	validation_0-rmse:0.43115	validation_1-rmse:0.46896
# [27]	validation_0-rmse:0.42367	validation_1-rmse:0.46726
# [28]	validation_0-rmse:0.42016	validation_1-rmse:0.47765
# [29]	validation_0-rmse:0.41841	validation_1-rmse:0.47538
# [30]	validation_0-rmse:0.41844	validation_1-rmse:0.47440
# [31]	validation_0-rmse:0.41859	validation_1-rmse:0.47405
# [32]	validation_0-rmse:0.41552	validation_1-rmse:0.47282
# [33]	validation_0-rmse:0.41561	validation_1-rmse:0.47346
# [34]	validation_0-rmse:0.41216	validation_1-rmse:0.47441
# [35]	validation_0-rmse:0.41031	validation_1-rmse:0.47886
# [36]	validation_0-rmse:0.40969	validation_1-rmse:0.47837
# [37]	validation_0-rmse:0.40969	validation_1-rmse:0.47834
# [38]	validation_0-rmse:0.40549	validation_1-rmse:0.47828
# [39]	validation_0-rmse:0.39928	validation_1-rmse:0.47675
# [40]	validation_0-rmse:0.39915	validation_1-rmse:0.47647
# [41]	validation_0-rmse:0.39793	validation_1-rmse:0.47666
# [42]	validation_0-rmse:0.39786	validation_1-rmse:0.47629
# [43]	validation_0-rmse:0.39137	validation_1-rmse:0.47499
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-3.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.473
# Uncertainty
# a0: -0.526+/-0.057
# a1: 0.439+/-0.045

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: %_cover: mean - 0.257, median - 0.255, CI - [0.229-0.291]
#
# SHAP-values for: mf_chm_MAX: mean - 0.127, median - 0.128, CI - [0.091-0.16]
#
# SHAP-values for: mf_chm_MEAN: mean - 0.17, median - 0.173, CI - [0.14-0.201]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 27.465, median: 22.0,
#  pred. interval (P(0.025)-P(0.975)): 7.0-59.0,
#  conf. interval (p-value=0.95): 11.163-46.383
# ***
# Aggregate bias statistic:
#  mean: 0.051, median: 0.052,
#  pred. interval (P(0.025)-P(0.975)): -0.141-0.294,
#  conf. interval (p-value=0.95): -0.041-0.143
# ***
# Aggregate RMSE statistic:
#  mean: 0.571, median: 0.566, pred. interval (P(0.025)-P(0.975)): 0.418-0.762,
#  conf. interval (p-value=0.95): 0.486-0.653
# ***
# Aggregate MSE statistic:
#  mean: 0.335, median: 0.32, pred. interval (P(0.025)-P(0.975)): 0.175-0.58,
#  conf. interval (p-value=0.95): 0.237-0.427
# ***
# Aggregate R^2 statistic:
#  mean: 0.431, median: 0.464, pred. interval (P(0.025)-P(0.975)): 0.079-0.708,
#  conf. interval (p-value=0.95): 0.28-0.568
# ***
# Aggregate bias(%) statistic:
#  mean: -3.925, median: -5.28, pred. interval (P(0.025)-P(0.975)): -22.886-18.835,
#  conf. interval (p-value=0.95): -12.856-4.731
# ***
# Aggregate RMSE(%) statistic:
#  mean: -56.393, median: -56.392, pred. interval (P(0.025)-P(0.975)): -76.546--37.735,
#  conf. interval (p-value=0.95): -63.492--48.182
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -0.044, median: -0.04,
#  pred. interval (P(0.025)-P(0.975)): -0.13-0.05,
#  conf. interval (p-value=0.95): -0.087--0.007
# ***
# Aggregate RMSE statistic:
#  mean: 0.23, median: 0.229, pred. interval (P(0.025)-P(0.975)): 0.164-0.305,
#  conf. interval (p-value=0.95): 0.199-0.258
# ***
# Aggregate MSE statistic:
#  mean: 0.054, median: 0.052, pred. interval (P(0.025)-P(0.975)): 0.027-0.093,
#  conf. interval (p-value=0.95): 0.04-0.066
# ***
# Aggregate R^2 statistic:
#  mean: 0.326, median: 0.336, pred. interval (P(0.025)-P(0.975)): -0.029-0.609,
#  conf. interval (p-value=0.95): 0.186-0.478
# ***
# Aggregate bias(%) statistic:
#  mean: -8.69, median: -9.0, pred. interval (P(0.025)-P(0.975)): -23.679-12.602,
#  conf. interval (p-value=0.95): -17.434--1.675
# ***
# Aggregate RMSE(%) statistic:
#  mean: 49.888, median: 49.284, pred. interval (P(0.025)-P(0.975)): 36.061-64.972,
#  conf. interval (p-value=0.95): 43.061-57.256
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-3, -2, -1, -0.5, 0, 0.5])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 0.25, 0.5, 0.75, 1])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.38931
# [1]	validation_0-rmse:1.15779
# [2]	validation_0-rmse:0.98037
# [3]	validation_0-rmse:0.84993
# [4]	validation_0-rmse:0.75630
# [5]	validation_0-rmse:0.68945
# [6]	validation_0-rmse:0.64696
# [7]	validation_0-rmse:0.60571
# [8]	validation_0-rmse:0.56664
# [9]	validation_0-rmse:0.55521
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [10]	validation_0-rmse:0.53561
# [11]	validation_0-rmse:0.52153
# [12]	validation_0-rmse:0.50070
# [13]	validation_0-rmse:0.49390
# [14]	validation_0-rmse:0.48329
# [15]	validation_0-rmse:0.47647
# [16]	validation_0-rmse:0.47086
# [17]	validation_0-rmse:0.46062
# [18]	validation_0-rmse:0.45279
# [19]	validation_0-rmse:0.45284
# [20]	validation_0-rmse:0.45029
# [21]	validation_0-rmse:0.44564
# [22]	validation_0-rmse:0.44211
# [23]	validation_0-rmse:0.43131
# [24]	validation_0-rmse:0.42488
# [25]	validation_0-rmse:0.42153
# [26]	validation_0-rmse:0.41918
# [27]	validation_0-rmse:0.41661
# [28]	validation_0-rmse:0.41287
# [29]	validation_0-rmse:0.40605
# [30]	validation_0-rmse:0.40313
# [31]	validation_0-rmse:0.39907
# [32]	validation_0-rmse:0.39515
# [33]	validation_0-rmse:0.39089
# [34]	validation_0-rmse:0.38821
# [35]	validation_0-rmse:0.38695
# [36]	validation_0-rmse:0.38562
# [37]	validation_0-rmse:0.38331
# [38]	validation_0-rmse:0.38338
# [39]	validation_0-rmse:0.37923
# [40]	validation_0-rmse:0.37951
# [41]	validation_0-rmse:0.37923
# [42]	validation_0-rmse:0.37915
# [43]	validation_0-rmse:0.37921
# [44]	validation_0-rmse:0.37601
# [45]	validation_0-rmse:0.37162
# [46]	validation_0-rmse:0.37160
# [47]	validation_0-rmse:0.37161
# [48]	validation_0-rmse:0.36896
# [49]	validation_0-rmse:0.36492
# [50]	validation_0-rmse:0.36493
# [51]	validation_0-rmse:0.36291
# [52]	validation_0-rmse:0.36033
# [53]	validation_0-rmse:0.36035
# [54]	validation_0-rmse:0.35901
# [55]	validation_0-rmse:0.35559
# [56]	validation_0-rmse:0.35328
# [57]	validation_0-rmse:0.35329
# [58]	validation_0-rmse:0.35328
# [59]	validation_0-rmse:0.35329
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 58

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  -0.32
# RMSE: 0.4
# Relative RMSE(%):  -34.772
# MSE: 0.1
# R square: 80.3%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-3.5, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.817
# Uncertainty
# a0: -0.29+/-0.04
# a1: 0.710+/-0.033

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/06_LN_M_AG_CHM_without_RGB_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/06_LN_M_AG_CHM_without_RGB_XGB_model.txt")
