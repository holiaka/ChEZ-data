# %% [markdown]
# ## Est. of growing stock, biomass and RN content use UAV survey

# %% [markdown]
# # Load all data from .xlsx file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
site_data = '../03_input_data/input_CHM_&_spectral_data_site2020.xlsx'
df = pd.read_excel(site_data, sheet_name='input')
df.head()
# Out:
#   Site #        S_m2    WGS84 N   WGS 84 E Origin Dominant_specias  \
# 0      1  500.343869  51.435741  30.107979      n            Birch
# 1      2   99.932806  51.434093  30.108523      a             Pine
# 2      3   99.932806  51.434163  30.109196      a             Pine
# 3      4  500.343869  51.434217  30.110484      a             Pine
# 4      5  249.965218  51.434056  30.111980      a             Pine
#
#    Cs_wood_Bq/kg  ln_Cs_wood  Sr_wood_Bq/kg  ln_Sr_wood  ...  idm_g_Q25  \
# 0            920       6.824          10300       9.240  ...   0.042167
# 1           3600       8.189          15100       9.622  ...   0.040919
# 2           4360       8.380          14600       9.589  ...   0.042397
# 3           3420       8.137          12700       9.449  ...   0.043719
# 4           2200       7.696          12100       9.401  ...   0.040659
#
#    idm_g_Q50  idm_g_Q75  idm_b_MIN idm_b_MAX  idm_b_MEAN  idm_b_STD  \
# 0   0.050549   0.062270   0.017730  0.408966    0.059749   0.030217
# 1   0.048889   0.060698   0.020078  0.258602    0.057223   0.025515
# 2   0.050463   0.060603   0.020761  0.156265    0.056571   0.016629
# 3   0.052974   0.066027   0.017239  0.327465    0.060880   0.023964
# 4   0.049303   0.061803   0.014276  0.274420    0.057902   0.024283
#
#    idm_b_Q25  idm_b_Q50  idm_b_Q75
# 0   0.043539   0.052312   0.064544
# 1   0.043035   0.050941   0.062608
# 2   0.045142   0.053495   0.064635
# 3   0.046111   0.055601   0.069182
# 4   0.043045   0.051566   0.065078
#
# [5 rows x 164 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
# 'Cs_wood_Bq/kg', 'Sr_wood_Bq/kg', 'ln_Cs_wood', 'ln_Sr_wood', 'Cs_2021_kBq_m', 'Sr_2021_kBq_m', 'AEDR_mean', 'Distance_km', 'Azimuth', 'Gs_cub_m', 'M_stem_kg_m2', 'M_stem_bark_kg_m2', 'M_crown_kg_m2', 'M_foliage_kg_m2', 'M_AG_kg_m2', 'ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2', '%_cover', 'af_chm_MIN', 'af_chm_MAX', 'af_chm_MEAN', 'af_chm_STD', 'af_chm_Q25', 'af_chm_Q50', 'af_chm_Q75', 'mf_chm_MIN', 'mf_chm_MAX', 'mf_chm_MEAN', 'mf_chm_STD', 'mf_chm_Q25', 'mf_chm_Q50', 'mf_chm_Q75', 'r_MIN', 'r_MAX', 'r_MEAN', 'r_STD', 'r_Q25', 'r_Q50', 'r_Q75', 'g_MIN', 'g_MAX', 'g_MEAN', 'g_STD', 'g_Q25', 'g_Q50', 'g_Q75', 'b_MIN', 'b_MAX', 'b_MEAN', 'b_STD', 'b_Q25', 'b_Q50', 'b_Q75', 'asm_r__MIN', 'asm_r_MAX', 'asm_r_MEAN', 'asm_r_STD', 'asm_r_Q25', 'asm_r_Q50', 'asm_r_Q75', 'asm_g__MIN', 'asm_g_MAX', 'asm_g_MEAN', 'asm_g_STD', 'asm_g_Q25', 'asm_g_Q50', 'asm_g_Q75', 'asm_b__MIN', 'asm_b_MAX', 'asm_b_MEAN', 'asm_b_STD', 'asm_b_Q25', 'asm_b_Q50', 'asm_b_Q75', 'contr_r_MIN', 'contr_r_MAX', 'contr_r_MEAN', 'contr_r_STD', 'contr_r_Q25', 'contr_r_Q50', 'contr_r_Q75', 'contr_g_MIN', 'contr_g_MAX', 'contr_g_MEAN', 'contr_g_STD', 'contr_g_Q25', 'contr_g_Q50', 'contr_g_Q75', 'contr_b_MIN', 'contr_b_MAX', 'contr_b_MEAN', 'contr_b_STD', 'contr_b_Q25', 'contr_b_Q50', 'contr_b_Q75', 'corr_r_MIN', 'corr_r_MAX', 'corr_r_MEAN', 'corr_r_STD', 'corr_r_Q25', 'corr_r_Q50', 'corr_r_Q75', 'corr_g_MIN', 'corr_g_MAX', 'corr_g_MEAN', 'corr_g_STD', 'corr_g_Q25', 'corr_g_Q50', 'corr_g_Q75', 'corr_b_MIN', 'corr_b_MAX', 'corr_b_MEAN', 'corr_b_STD', 'corr_b_Q25', 'corr_b_Q50', 'corr_b_Q75', 'idm_r_MIN', 'idm_r_MAX', 'idm_r_MEAN', 'idm_r_STD', 'idm_r_Q25', 'idm_r_Q50', 'idm_r_Q75', 'idm_g_MIN', 'idm_g_MAX', 'idm_g_MEAN', 'idm_g_STD', 'idm_g_Q25', 'idm_g_Q50', 'idm_g_Q75', 'idm_b_MIN', 'idm_b_MAX', 'idm_b_MEAN', 'idm_b_STD', 'idm_b_Q25', 'idm_b_Q50', 'idm_b_Q75'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['ln_Gs_cub_m', 'ln_M_stem_kg_m2', 'ln_M_stem_bark_kg_m2', 'ln_M_crown_kg_m2', 'ln_M_foliage_kg_m2', 'ln_M_AG_kg_m2',
                                    '%_cover', 'mf_chm_MEAN', 'mf_chm_MAX'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0        4.771            1.792                -0.211            -0.261
# 1        5.808            2.496                -0.073             0.392
# 2        5.796            2.546                 0.030             0.501
# 3        5.826            2.643                 0.000             0.419
# 4        6.059            2.643                 0.122             0.647
#
#    ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX
# 0              -2.040          1.932     0.85    12.233545   19.097736
# 1              -0.139          2.674     1.00    14.964220   17.704655
# 2              -0.030          2.734     1.00    15.329449   17.559893
# 3              -0.431          2.785     0.97    15.392742   20.676994
# 4              -0.386          2.809     1.00    17.944009   21.851387

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ln_Gs_cub_m           103 non-null    float64
#  1   ln_M_stem_kg_m2       103 non-null    float64
#  2   ln_M_stem_bark_kg_m2  103 non-null    float64
#  3   ln_M_crown_kg_m2      103 non-null    float64
#  4   ln_M_foliage_kg_m2    103 non-null    float64
#  5   ln_M_AG_kg_m2         103 non-null    float64
#  6   %_cover               103 non-null    float64
#  7   mf_chm_MEAN           103 non-null    float64
#  8   mf_chm_MAX            103 non-null    float64
# dtypes: float64(9)
# memory usage: 7.4 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Dominant_specias"])["ln_Gs_cub_m", "ln_M_AG_kg_m2"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                  ln_Gs_cub_m                                             \
#                        count      mean       std    min      25%    50%
# Dominant_specias
# Alder                    4.0  5.907250  0.445830  5.342  5.65925  5.985
# Aspen                    1.0  4.956000       NaN  4.956  4.95600  4.956
# Birch                   23.0  4.676174  0.813911  2.398  4.56900  4.949
# Oak                      3.0  5.409667  0.406291  4.956  5.24450  5.533
# Pine                    71.0  4.990775  1.410734  1.609  4.44850  5.642
# Spruce                   1.0  6.431000       NaN  6.431  6.43100  6.431
#
#                                 ln_M_AG_kg_m2                             \
#                      75%    max         count      mean       std    min
# Dominant_specias
# Alder             6.2330  6.317           4.0  2.862250  0.386813  2.407
# Aspen             4.9560  4.956           1.0  1.932000       NaN  1.932
# Birch             5.2930  5.680          23.0  1.855783  0.744496  0.000
# Oak               5.6365  5.740           3.0  2.687333  0.316282  2.398
# Pine              5.9215  6.457          71.0  2.073789  1.174954 -0.693
# Spruce            6.4310  6.431           1.0  3.506000       NaN  3.506
#
#
#                       25%    50%     75%    max
# Dominant_specias
# Alder             2.61775  2.892  3.1365  3.258
# Aspen             1.93200  1.932  1.9320  1.932
# Birch             1.68350  2.001  2.3930  2.803
# Oak               2.51850  2.639  2.8320  3.025
# Pine              1.48500  2.588  2.8620  3.515
# Spruce            3.50600  3.506  3.5060  3.506

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# count   103.000000       103.000000            103.000000        103.000000
# mean      4.981961         1.863184             -0.327942         -0.063369
# std       1.264300         1.198731              0.866380          0.795365
# min       1.609000        -1.347000             -2.659000         -2.408000
# 25%       4.677000         1.584500             -0.554000         -0.386500
# 50%       5.342000         2.294000             -0.051000          0.182000
# 75%       5.875000         2.663000              0.207000          0.495000
# max       6.457000         3.428000              1.384000          1.756000
#
#        ln_M_foliage_kg_m2  ln_M_AG_kg_m2     %_cover  mf_chm_MEAN  mf_chm_MAX
# count          103.000000     103.000000  103.000000   103.000000  103.000000
# mean            -1.015971       2.086126    0.808738    13.045021   17.907784
# std              0.799205       1.067542    0.276653     6.609366    7.523377
# min             -3.507000      -0.693000    0.090000     1.293138    2.733019
# 25%             -1.609000       1.758000    0.745000     8.206727   11.615798
# 50%             -0.844000       2.442000    0.960000    13.072916   18.269344
# 75%             -0.364000       2.809000    1.000000    17.432255   22.751595
# max              0.157000       3.515000    1.000000    28.916548   36.355442

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "ln_M_stem_bark_kg_m2"
indep_variables = ['%_cover', 'mf_chm_MEAN', 'mf_chm_MAX']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      ln_Gs_cub_m  ln_M_stem_kg_m2  ln_M_stem_bark_kg_m2  ln_M_crown_kg_m2  \
# 0          4.771            1.792                -0.211            -0.261
# 1          5.808            2.496                -0.073             0.392
# 2          5.796            2.546                 0.030             0.501
# 3          5.826            2.643                 0.000             0.419
# 4          6.059            2.643                 0.122             0.647
# ..           ...              ...                   ...               ...
# 98         5.389            2.366                 0.531             0.182
# 99         2.398           -0.186                -1.309            -1.966
# 100        1.792           -0.968                -2.120            -1.966
# 101        4.836            1.733                -0.386             0.732
# 102        2.944           -0.211                -1.966            -1.470
#
#      ln_M_foliage_kg_m2  ln_M_AG_kg_m2  %_cover  mf_chm_MEAN  mf_chm_MAX
# 0                -2.040          1.932     0.85    12.233545   19.097736
# 1                -0.139          2.674     1.00    14.964220   17.704655
# 2                -0.030          2.734     1.00    15.329449   17.559893
# 3                -0.431          2.785     0.97    15.392742   20.676994
# 4                -0.386          2.809     1.00    17.944009   21.851387
# ..                  ...            ...      ...          ...         ...
# 98               -1.386          2.493     0.84    11.654902   17.083910
# 99               -3.507          0.000     0.17     4.722706   10.924606
# 100              -2.408         -0.511     0.17     4.620455   10.747827
# 101              -0.041          2.163     0.88     7.371921   11.443830
# 102              -1.609          0.182     0.28     2.765120    8.069081
#
# [103 rows x 9 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    %_cover  mf_chm_MEAN  mf_chm_MAX
# 0     0.85    12.233545   19.097736
# 1     1.00    14.964220   17.704655
# 2     1.00    15.329449   17.559893
# 3     0.97    15.392742   20.676994
# 4     1.00    17.944009   21.851387

# %%
# Columns in "y" data collections
y.head()
# Out:
#    ln_M_stem_bark_kg_m2
# 0                -0.211
# 1                -0.073
# 2                 0.030
# 3                 0.000
# 4                 0.122

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.8988798010219068, 0.83704984779637, 0.7952593971042]
#     Mean: 0.844
#     Std: 0.043
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.36962308 0.36261249 0.40218753]
#     Mean: 0.378
#     Std: 0.017
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.2790350122430495, 0.27920708228472396, 0.2478691317154204]
#     Mean: 0.269
#     Std: 0.015
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.11041965568115941                  # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.3525913743740846                   # gamma
print('Gamma: ' + str(p2))

p3 = 0.26871095873422957                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 2            # max_depth
print('Max_depth: ' + str(p4))

p5 = 67          # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.4342275742971686                   # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.11041965568115941
# Gamma: 0.3525913743740846
# Learning_rate: 0.26871095873422957
# Max_depth: 2
# N_estimators: 67
# Subsample: 0.4342275742971686

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    diff_with_mean = []
    exp_diff_with_mean = []
    
    for i in range(n_sample):
        interm = y_test2[i][0] - y_mean_sample
        diff_with_mean.append(interm**2)

    RSS = np.sum((y_test2 - y_pred2)**2)
    TSS = (np.sum(diff_with_mean))
    R_square = 1 - (RSS / TSS)
    
    for i in range(n_sample):
        exp_interm = exp_y_test2[i][0] - exp_y_mean_sample
        exp_diff_with_mean.append(exp_interm**2)

    exp_RSS = np.sum((exp_y_test2 - exp_y_pred2)**2)
    exp_TSS = np.sum(exp_diff_with_mean)
    
    exp_R_square = 1 - (exp_RSS / exp_TSS)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)    
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:0.98555	validation_1-rmse:1.07811
# [1]	validation_0-rmse:0.76998	validation_1-rmse:0.83949
# [2]	validation_0-rmse:0.66930	validation_1-rmse:0.72810
# [3]	validation_0-rmse:0.55023	validation_1-rmse:0.60155
# [4]	validation_0-rmse:0.45387	validation_1-rmse:0.50889
# [5]	validation_0-rmse:0.41956	validation_1-rmse:0.47290
# [6]	validation_0-rmse:0.36699	validation_1-rmse:0.42440
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [7]	validation_0-rmse:0.35055	validation_1-rmse:0.40545
# [8]	validation_0-rmse:0.33876	validation_1-rmse:0.38867
# [9]	validation_0-rmse:0.31832	validation_1-rmse:0.36976
# [10]	validation_0-rmse:0.31084	validation_1-rmse:0.36242
# [11]	validation_0-rmse:0.30653	validation_1-rmse:0.36407
# [12]	validation_0-rmse:0.30559	validation_1-rmse:0.36195
# [13]	validation_0-rmse:0.30504	validation_1-rmse:0.36031
# [14]	validation_0-rmse:0.29311	validation_1-rmse:0.35201
# [15]	validation_0-rmse:0.28629	validation_1-rmse:0.34829
# [16]	validation_0-rmse:0.28074	validation_1-rmse:0.35220
# [17]	validation_0-rmse:0.28081	validation_1-rmse:0.35263
# [18]	validation_0-rmse:0.27594	validation_1-rmse:0.35386
# [19]	validation_0-rmse:0.27684	validation_1-rmse:0.35671
# [20]	validation_0-rmse:0.27131	validation_1-rmse:0.34992
# [21]	validation_0-rmse:0.27086	validation_1-rmse:0.34776
# [22]	validation_0-rmse:0.27084	validation_1-rmse:0.34757
# [23]	validation_0-rmse:0.27102	validation_1-rmse:0.34562
# [24]	validation_0-rmse:0.27123	validation_1-rmse:0.34508
# [25]	validation_0-rmse:0.27085	validation_1-rmse:0.34647
# [26]	validation_0-rmse:0.27099	validation_1-rmse:0.34571
# [27]	validation_0-rmse:0.27123	validation_1-rmse:0.34508
# [28]	validation_0-rmse:0.26628	validation_1-rmse:0.34179
# [29]	validation_0-rmse:0.26309	validation_1-rmse:0.34686
# [30]	validation_0-rmse:0.26244	validation_1-rmse:0.34790
# [31]	validation_0-rmse:0.26221	validation_1-rmse:0.34937
# [32]	validation_0-rmse:0.25820	validation_1-rmse:0.34785
# [33]	validation_0-rmse:0.25835	validation_1-rmse:0.35132
# [34]	validation_0-rmse:0.25808	validation_1-rmse:0.35002
# [35]	validation_0-rmse:0.25822	validation_1-rmse:0.35079
# [36]	validation_0-rmse:0.25824	validation_1-rmse:0.35089
# [37]	validation_0-rmse:0.25919	validation_1-rmse:0.35363
# [38]	validation_0-rmse:0.25896	validation_1-rmse:0.35310
# [39]	validation_0-rmse:0.25904	validation_1-rmse:0.35328
# [40]	validation_0-rmse:0.25830	validation_1-rmse:0.35112
# [41]	validation_0-rmse:0.25803	validation_1-rmse:0.34878
# [42]	validation_0-rmse:0.25802	validation_1-rmse:0.34925
# [43]	validation_0-rmse:0.25882	validation_1-rmse:0.34672
# [44]	validation_0-rmse:0.25858	validation_1-rmse:0.34703
# [45]	validation_0-rmse:0.25803	validation_1-rmse:0.34892
# [46]	validation_0-rmse:0.25809	validation_1-rmse:0.35009
# [47]	validation_0-rmse:0.25232	validation_1-rmse:0.35208
# [48]	validation_0-rmse:0.25193	validation_1-rmse:0.35294
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.03918	validation_1-rmse:0.77533
# [1]	validation_0-rmse:0.79709	validation_1-rmse:0.63472
# [2]	validation_0-rmse:0.68617	validation_1-rmse:0.56140
# [3]	validation_0-rmse:0.57131	validation_1-rmse:0.52796
# [4]	validation_0-rmse:0.47354	validation_1-rmse:0.49286
# [5]	validation_0-rmse:0.40383	validation_1-rmse:0.46715
# [6]	validation_0-rmse:0.34010	validation_1-rmse:0.43915
# [7]	validation_0-rmse:0.33349	validation_1-rmse:0.42886
# [8]	validation_0-rmse:0.30316	validation_1-rmse:0.40785
# [9]	validation_0-rmse:0.28821	validation_1-rmse:0.40220
# [10]	validation_0-rmse:0.28733	validation_1-rmse:0.40027
# [11]	validation_0-rmse:0.27956	validation_1-rmse:0.39920
# [12]	validation_0-rmse:0.27385	validation_1-rmse:0.39792
# [13]	validation_0-rmse:0.26567	validation_1-rmse:0.40068
# [14]	validation_0-rmse:0.25840	validation_1-rmse:0.38564
# [15]	validation_0-rmse:0.25799	validation_1-rmse:0.38250
# [16]	validation_0-rmse:0.25313	validation_1-rmse:0.37481
# [17]	validation_0-rmse:0.25303	validation_1-rmse:0.37630
# [18]	validation_0-rmse:0.24923	validation_1-rmse:0.38404
# [19]	validation_0-rmse:0.24912	validation_1-rmse:0.38255
# [20]	validation_0-rmse:0.24908	validation_1-rmse:0.37990
# [21]	validation_0-rmse:0.24907	validation_1-rmse:0.38098
# [22]	validation_0-rmse:0.24922	validation_1-rmse:0.37744
# [23]	validation_0-rmse:0.24961	validation_1-rmse:0.38702
# [24]	validation_0-rmse:0.24912	validation_1-rmse:0.38258
# [25]	validation_0-rmse:0.24499	validation_1-rmse:0.38359
# [26]	validation_0-rmse:0.24503	validation_1-rmse:0.38163
# [27]	validation_0-rmse:0.24531	validation_1-rmse:0.37866
# [28]	validation_0-rmse:0.24515	validation_1-rmse:0.37998
# [29]	validation_0-rmse:0.24511	validation_1-rmse:0.38040
# [30]	validation_0-rmse:0.24570	validation_1-rmse:0.39092
# [31]	validation_0-rmse:0.24499	validation_1-rmse:0.38265
# [32]	validation_0-rmse:0.24513	validation_1-rmse:0.38663
# [33]	validation_0-rmse:0.24499	validation_1-rmse:0.38399
# [34]	validation_0-rmse:0.24505	validation_1-rmse:0.38555
# [35]	validation_0-rmse:0.24507	validation_1-rmse:0.38584
# [36]	validation_0-rmse:0.24500	validation_1-rmse:0.38232
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.01444	validation_1-rmse:0.89060
# [1]	validation_0-rmse:0.81931	validation_1-rmse:0.74362
# [2]	validation_0-rmse:0.69694	validation_1-rmse:0.64092
# [3]	validation_0-rmse:0.58018	validation_1-rmse:0.55236
# [4]	validation_0-rmse:0.50051	validation_1-rmse:0.49911
# [5]	validation_0-rmse:0.42142	validation_1-rmse:0.44832
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [6]	validation_0-rmse:0.37547	validation_1-rmse:0.40905
# [7]	validation_0-rmse:0.36419	validation_1-rmse:0.40762
# [8]	validation_0-rmse:0.32700	validation_1-rmse:0.39477
# [9]	validation_0-rmse:0.29805	validation_1-rmse:0.38382
# [10]	validation_0-rmse:0.29444	validation_1-rmse:0.38458
# [11]	validation_0-rmse:0.28261	validation_1-rmse:0.37905
# [12]	validation_0-rmse:0.27369	validation_1-rmse:0.37458
# [13]	validation_0-rmse:0.26767	validation_1-rmse:0.37181
# [14]	validation_0-rmse:0.26696	validation_1-rmse:0.37285
# [15]	validation_0-rmse:0.26658	validation_1-rmse:0.37372
# [16]	validation_0-rmse:0.26630	validation_1-rmse:0.37493
# [17]	validation_0-rmse:0.25295	validation_1-rmse:0.37027
# [18]	validation_0-rmse:0.25303	validation_1-rmse:0.36984
# [19]	validation_0-rmse:0.25308	validation_1-rmse:0.37344
# [20]	validation_0-rmse:0.25311	validation_1-rmse:0.37362
# [21]	validation_0-rmse:0.25302	validation_1-rmse:0.37310
# [22]	validation_0-rmse:0.25315	validation_1-rmse:0.37382
# [23]	validation_0-rmse:0.25359	validation_1-rmse:0.37542
# [24]	validation_0-rmse:0.25384	validation_1-rmse:0.37613
# [25]	validation_0-rmse:0.25316	validation_1-rmse:0.37387
# [26]	validation_0-rmse:0.24698	validation_1-rmse:0.36904
# [27]	validation_0-rmse:0.24752	validation_1-rmse:0.37274
# [28]	validation_0-rmse:0.24722	validation_1-rmse:0.37157
# [29]	validation_0-rmse:0.24713	validation_1-rmse:0.37109
# [30]	validation_0-rmse:0.24707	validation_1-rmse:0.37074
# [31]	validation_0-rmse:0.24751	validation_1-rmse:0.37268
# [32]	validation_0-rmse:0.24709	validation_1-rmse:0.37081
# [33]	validation_0-rmse:0.24698	validation_1-rmse:0.36985
# [34]	validation_0-rmse:0.24699	validation_1-rmse:0.36889
# [35]	validation_0-rmse:0.24721	validation_1-rmse:0.36755
# [36]	validation_0-rmse:0.24707	validation_1-rmse:0.36817
# [37]	validation_0-rmse:0.24699	validation_1-rmse:0.36888
# [38]	validation_0-rmse:0.24717	validation_1-rmse:0.37129
# [39]	validation_0-rmse:0.24798	validation_1-rmse:0.37409
# [40]	validation_0-rmse:0.24770	validation_1-rmse:0.37329
# [41]	validation_0-rmse:0.24759	validation_1-rmse:0.37297
# [42]	validation_0-rmse:0.24708	validation_1-rmse:0.37077
# [43]	validation_0-rmse:0.24716	validation_1-rmse:0.37125
# [44]	validation_0-rmse:0.24746	validation_1-rmse:0.37252
# [45]	validation_0-rmse:0.24745	validation_1-rmse:0.37248
# [46]	validation_0-rmse:0.24785	validation_1-rmse:0.37372
# [47]	validation_0-rmse:0.24702	validation_1-rmse:0.36853
# [48]	validation_0-rmse:0.24707	validation_1-rmse:0.36818
# [49]	validation_0-rmse:0.24699	validation_1-rmse:0.36890
# [50]	validation_0-rmse:0.24718	validation_1-rmse:0.37138
# [51]	validation_0-rmse:0.24548	validation_1-rmse:0.37955
# [52]	validation_0-rmse:0.24652	validation_1-rmse:0.38251
# [53]	validation_0-rmse:0.24510	validation_1-rmse:0.37788
# [54]	validation_0-rmse:0.24489	validation_1-rmse:0.37575
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.00330	validation_1-rmse:0.83117
# [1]	validation_0-rmse:0.78035	validation_1-rmse:0.66959
# [2]	validation_0-rmse:0.65921	validation_1-rmse:0.57013
# [3]	validation_0-rmse:0.54153	validation_1-rmse:0.48780
# [4]	validation_0-rmse:0.46140	validation_1-rmse:0.43228
# [5]	validation_0-rmse:0.39306	validation_1-rmse:0.39530
# [6]	validation_0-rmse:0.35135	validation_1-rmse:0.37639
# [7]	validation_0-rmse:0.34004	validation_1-rmse:0.37543
# [8]	validation_0-rmse:0.31416	validation_1-rmse:0.36547
# [9]	validation_0-rmse:0.29987	validation_1-rmse:0.35814
# [10]	validation_0-rmse:0.29729	validation_1-rmse:0.36109
# [11]	validation_0-rmse:0.28928	validation_1-rmse:0.35456
# [12]	validation_0-rmse:0.28154	validation_1-rmse:0.34883
# [13]	validation_0-rmse:0.28154	validation_1-rmse:0.34849
# [14]	validation_0-rmse:0.27400	validation_1-rmse:0.34343
# [15]	validation_0-rmse:0.26954	validation_1-rmse:0.34317
# [16]	validation_0-rmse:0.26948	validation_1-rmse:0.34137
# [17]	validation_0-rmse:0.26957	validation_1-rmse:0.34116
# [18]	validation_0-rmse:0.26938	validation_1-rmse:0.34217
# [19]	validation_0-rmse:0.26947	validation_1-rmse:0.34140
# [20]	validation_0-rmse:0.26938	validation_1-rmse:0.34193
# [21]	validation_0-rmse:0.26910	validation_1-rmse:0.34498
# [22]	validation_0-rmse:0.26635	validation_1-rmse:0.34616
# [23]	validation_0-rmse:0.26650	validation_1-rmse:0.34662
# [24]	validation_0-rmse:0.25683	validation_1-rmse:0.34715
# [25]	validation_0-rmse:0.25242	validation_1-rmse:0.34412
# [26]	validation_0-rmse:0.25234	validation_1-rmse:0.34395
# [27]	validation_0-rmse:0.25225	validation_1-rmse:0.34370
# [28]	validation_0-rmse:0.25221	validation_1-rmse:0.34359
# [29]	validation_0-rmse:0.25217	validation_1-rmse:0.34341
# [30]	validation_0-rmse:0.25223	validation_1-rmse:0.34364
# [31]	validation_0-rmse:0.25223	validation_1-rmse:0.34364
# [32]	validation_0-rmse:0.25246	validation_1-rmse:0.34419
# [33]	validation_0-rmse:0.25277	validation_1-rmse:0.34475
# [34]	validation_0-rmse:0.25108	validation_1-rmse:0.33848
# [35]	validation_0-rmse:0.25102	validation_1-rmse:0.33821
# [36]	validation_0-rmse:0.25125	validation_1-rmse:0.33883
# [37]	validation_0-rmse:0.25146	validation_1-rmse:0.33914
# [38]	validation_0-rmse:0.25112	validation_1-rmse:0.33859
# [39]	validation_0-rmse:0.25114	validation_1-rmse:0.33863
# [40]	validation_0-rmse:0.25113	validation_1-rmse:0.33801
# [41]	validation_0-rmse:0.25134	validation_1-rmse:0.33795
# [42]	validation_0-rmse:0.25214	validation_1-rmse:0.33811
# [43]	validation_0-rmse:0.25182	validation_1-rmse:0.33802
# [44]	validation_0-rmse:0.24670	validation_1-rmse:0.34251
# [45]	validation_0-rmse:0.24602	validation_1-rmse:0.34202
# [46]	validation_0-rmse:0.24403	validation_1-rmse:0.34338
# [47]	validation_0-rmse:0.24404	validation_1-rmse:0.34338
# [48]	validation_0-rmse:0.24374	validation_1-rmse:0.34343
# [49]	validation_0-rmse:0.23794	validation_1-rmse:0.34389
# [50]	validation_0-rmse:0.23807	validation_1-rmse:0.34362
# [51]	validation_0-rmse:0.23265	validation_1-rmse:0.34604
# [52]	validation_0-rmse:0.23204	validation_1-rmse:0.34621
# [53]	validation_0-rmse:0.23250	validation_1-rmse:0.34605
# [54]	validation_0-rmse:0.23211	validation_1-rmse:0.34617
# [55]	validation_0-rmse:0.23205	validation_1-rmse:0.34621
# [56]	validation_0-rmse:0.23205	validation_1-rmse:0.34620
# [57]	validation_0-rmse:0.23189	validation_1-rmse:0.34671
# [58]	validation_0-rmse:0.23189	validation_1-rmse:0.34673
# [59]	validation_0-rmse:0.23203	validation_1-rmse:0.34716
# [60]	validation_0-rmse:0.23195	validation_1-rmse:0.34698
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:1.04380	validation_1-rmse:0.73221
# [1]	validation_0-rmse:0.82412	validation_1-rmse:0.62107
# [2]	validation_0-rmse:0.70963	validation_1-rmse:0.57251
# [3]	validation_0-rmse:0.56414	validation_1-rmse:0.50833
# [4]	validation_0-rmse:0.48654	validation_1-rmse:0.47288
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:0.41848	validation_1-rmse:0.46573
# [6]	validation_0-rmse:0.37212	validation_1-rmse:0.46513
# [7]	validation_0-rmse:0.35181	validation_1-rmse:0.47417
# [8]	validation_0-rmse:0.31955	validation_1-rmse:0.45335
# [9]	validation_0-rmse:0.30659	validation_1-rmse:0.45935
# [10]	validation_0-rmse:0.30417	validation_1-rmse:0.46321
# [11]	validation_0-rmse:0.30219	validation_1-rmse:0.46867
# [12]	validation_0-rmse:0.29734	validation_1-rmse:0.46547
# [13]	validation_0-rmse:0.28023	validation_1-rmse:0.46724
# [14]	validation_0-rmse:0.28113	validation_1-rmse:0.46339
# [15]	validation_0-rmse:0.28139	validation_1-rmse:0.46266
# [16]	validation_0-rmse:0.27156	validation_1-rmse:0.44998
# [17]	validation_0-rmse:0.27201	validation_1-rmse:0.44844
# [18]	validation_0-rmse:0.27273	validation_1-rmse:0.44667
# [19]	validation_0-rmse:0.26642	validation_1-rmse:0.44466
# [20]	validation_0-rmse:0.26529	validation_1-rmse:0.44740
# [21]	validation_0-rmse:0.26478	validation_1-rmse:0.44986
# [22]	validation_0-rmse:0.26463	validation_1-rmse:0.45201
# [23]	validation_0-rmse:0.25869	validation_1-rmse:0.44911
# [24]	validation_0-rmse:0.25893	validation_1-rmse:0.44747
# [25]	validation_0-rmse:0.25919	validation_1-rmse:0.44641
# [26]	validation_0-rmse:0.25970	validation_1-rmse:0.44496
# [27]	validation_0-rmse:0.25426	validation_1-rmse:0.44981
# [28]	validation_0-rmse:0.25416	validation_1-rmse:0.45041
# [29]	validation_0-rmse:0.25402	validation_1-rmse:0.45386
# [30]	validation_0-rmse:0.25406	validation_1-rmse:0.45129
# [31]	validation_0-rmse:0.25232	validation_1-rmse:0.45343
# [32]	validation_0-rmse:0.25231	validation_1-rmse:0.45453
# [33]	validation_0-rmse:0.25263	validation_1-rmse:0.45082
# [34]	validation_0-rmse:0.25268	validation_1-rmse:0.45060
# [35]	validation_0-rmse:0.25272	validation_1-rmse:0.45041
# [36]	validation_0-rmse:0.25221	validation_1-rmse:0.45403
# [37]	validation_0-rmse:0.25012	validation_1-rmse:0.45075
# [38]	validation_0-rmse:0.24985	validation_1-rmse:0.45240
# [39]	validation_0-rmse:0.24977	validation_1-rmse:0.45390
# [0]	validation_0-rmse:1.02410	validation_1-rmse:0.84713
# [1]	validation_0-rmse:0.81812	validation_1-rmse:0.67107
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:0.71306	validation_1-rmse:0.57299
# [3]	validation_0-rmse:0.58868	validation_1-rmse:0.46125
# [4]	validation_0-rmse:0.49829	validation_1-rmse:0.39172
# [5]	validation_0-rmse:0.42004	validation_1-rmse:0.34351
# [6]	validation_0-rmse:0.36996	validation_1-rmse:0.32705
# [7]	validation_0-rmse:0.35380	validation_1-rmse:0.32014
# [8]	validation_0-rmse:0.32414	validation_1-rmse:0.30793
# [9]	validation_0-rmse:0.30472	validation_1-rmse:0.30516
# [10]	validation_0-rmse:0.30205	validation_1-rmse:0.29345
# [11]	validation_0-rmse:0.30046	validation_1-rmse:0.29223
# [12]	validation_0-rmse:0.29005	validation_1-rmse:0.29173
# [13]	validation_0-rmse:0.28202	validation_1-rmse:0.29269
# [14]	validation_0-rmse:0.27395	validation_1-rmse:0.29438
# [15]	validation_0-rmse:0.27059	validation_1-rmse:0.29826
# [16]	validation_0-rmse:0.27087	validation_1-rmse:0.29843
# [17]	validation_0-rmse:0.27056	validation_1-rmse:0.29823
# [18]	validation_0-rmse:0.27056	validation_1-rmse:0.29820
# [19]	validation_0-rmse:0.27076	validation_1-rmse:0.29844
# [20]	validation_0-rmse:0.27091	validation_1-rmse:0.29860
# [21]	validation_0-rmse:0.27099	validation_1-rmse:0.29867
# [22]	validation_0-rmse:0.26608	validation_1-rmse:0.30255
# [23]	validation_0-rmse:0.26583	validation_1-rmse:0.30229
# [24]	validation_0-rmse:0.26589	validation_1-rmse:0.30236
# [25]	validation_0-rmse:0.26583	validation_1-rmse:0.30228
# [26]	validation_0-rmse:0.26501	validation_1-rmse:0.30815
# [27]	validation_0-rmse:0.26502	validation_1-rmse:0.30810
# [28]	validation_0-rmse:0.26519	validation_1-rmse:0.30856
# [29]	validation_0-rmse:0.26546	validation_1-rmse:0.30895
# [30]	validation_0-rmse:0.26572	validation_1-rmse:0.30928
# [31]	validation_0-rmse:0.26512	validation_1-rmse:0.30845
# [32]	validation_0-rmse:0.26516	validation_1-rmse:0.30851
# [0]	validation_0-rmse:0.87382	validation_1-rmse:1.26948
# [1]	validation_0-rmse:0.68239	validation_1-rmse:1.05491
# [2]	validation_0-rmse:0.56968	validation_1-rmse:0.96370
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:0.46780	validation_1-rmse:0.83487
# [4]	validation_0-rmse:0.42501	validation_1-rmse:0.78581
# [5]	validation_0-rmse:0.35939	validation_1-rmse:0.69490
# [6]	validation_0-rmse:0.33027	validation_1-rmse:0.64612
# [7]	validation_0-rmse:0.32131	validation_1-rmse:0.62982
# [8]	validation_0-rmse:0.30243	validation_1-rmse:0.59091
# [9]	validation_0-rmse:0.28886	validation_1-rmse:0.55482
# [10]	validation_0-rmse:0.28705	validation_1-rmse:0.54751
# [11]	validation_0-rmse:0.28692	validation_1-rmse:0.54678
# [12]	validation_0-rmse:0.27676	validation_1-rmse:0.53478
# [13]	validation_0-rmse:0.27646	validation_1-rmse:0.53179
# [14]	validation_0-rmse:0.27643	validation_1-rmse:0.53133
# [15]	validation_0-rmse:0.27170	validation_1-rmse:0.52275
# [16]	validation_0-rmse:0.27156	validation_1-rmse:0.52138
# [17]	validation_0-rmse:0.27145	validation_1-rmse:0.51867
# [18]	validation_0-rmse:0.27196	validation_1-rmse:0.52468
# [19]	validation_0-rmse:0.27186	validation_1-rmse:0.52399
# [20]	validation_0-rmse:0.27194	validation_1-rmse:0.52451
# [21]	validation_0-rmse:0.27237	validation_1-rmse:0.52688
# [22]	validation_0-rmse:0.27151	validation_1-rmse:0.52053
# [23]	validation_0-rmse:0.26712	validation_1-rmse:0.49246
# [24]	validation_0-rmse:0.26710	validation_1-rmse:0.49478
# [25]	validation_0-rmse:0.26754	validation_1-rmse:0.49975
# [26]	validation_0-rmse:0.26764	validation_1-rmse:0.50033
# [27]	validation_0-rmse:0.26778	validation_1-rmse:0.50114
# [28]	validation_0-rmse:0.26109	validation_1-rmse:0.47827
# [29]	validation_0-rmse:0.26077	validation_1-rmse:0.47649
# [30]	validation_0-rmse:0.26053	validation_1-rmse:0.47465
# [31]	validation_0-rmse:0.26033	validation_1-rmse:0.46955
# [32]	validation_0-rmse:0.26036	validation_1-rmse:0.46877
# [33]	validation_0-rmse:0.26038	validation_1-rmse:0.46852
# [34]	validation_0-rmse:0.26033	validation_1-rmse:0.47205
# [35]	validation_0-rmse:0.26075	validation_1-rmse:0.46587
# [36]	validation_0-rmse:0.25484	validation_1-rmse:0.45558
# [37]	validation_0-rmse:0.25478	validation_1-rmse:0.45486
# [38]	validation_0-rmse:0.25470	validation_1-rmse:0.45150
# [39]	validation_0-rmse:0.25469	validation_1-rmse:0.45259
# [40]	validation_0-rmse:0.25469	validation_1-rmse:0.45187
# [41]	validation_0-rmse:0.25469	validation_1-rmse:0.45250
# [42]	validation_0-rmse:0.25474	validation_1-rmse:0.45067
# [43]	validation_0-rmse:0.25494	validation_1-rmse:0.44857
# [44]	validation_0-rmse:0.25480	validation_1-rmse:0.44978
# [45]	validation_0-rmse:0.25373	validation_1-rmse:0.45454
# [46]	validation_0-rmse:0.24930	validation_1-rmse:0.45720
# [47]	validation_0-rmse:0.24931	validation_1-rmse:0.46051
# [48]	validation_0-rmse:0.24961	validation_1-rmse:0.46358
# [49]	validation_0-rmse:0.24942	validation_1-rmse:0.46201
# [50]	validation_0-rmse:0.25065	validation_1-rmse:0.46874
# [51]	validation_0-rmse:0.25043	validation_1-rmse:0.46785
# [52]	validation_0-rmse:0.24974	validation_1-rmse:0.46447
# [53]	validation_0-rmse:0.24937	validation_1-rmse:0.46148
# [54]	validation_0-rmse:0.24931	validation_1-rmse:0.46050
# [55]	validation_0-rmse:0.24927	validation_1-rmse:0.45799
# [56]	validation_0-rmse:0.24929	validation_1-rmse:0.45723
# [57]	validation_0-rmse:0.24926	validation_1-rmse:0.45869
# [58]	validation_0-rmse:0.24926	validation_1-rmse:0.45887
# [59]	validation_0-rmse:0.24926	validation_1-rmse:0.45813
# [60]	validation_0-rmse:0.24449	validation_1-rmse:0.45365
# [61]	validation_0-rmse:0.24450	validation_1-rmse:0.45617
# [62]	validation_0-rmse:0.24509	validation_1-rmse:0.46109
# [63]	validation_0-rmse:0.24613	validation_1-rmse:0.46544
# [0]	validation_0-rmse:1.01148	validation_1-rmse:0.93416
# [1]	validation_0-rmse:0.78293	validation_1-rmse:0.71246
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:0.64631	validation_1-rmse:0.58931
# [3]	validation_0-rmse:0.53444	validation_1-rmse:0.48705
# [4]	validation_0-rmse:0.46596	validation_1-rmse:0.42141
# [5]	validation_0-rmse:0.41176	validation_1-rmse:0.38324
# [6]	validation_0-rmse:0.38786	validation_1-rmse:0.36762
# [7]	validation_0-rmse:0.38172	validation_1-rmse:0.36658
# [8]	validation_0-rmse:0.35758	validation_1-rmse:0.35953
# [9]	validation_0-rmse:0.35528	validation_1-rmse:0.36026
# [10]	validation_0-rmse:0.34526	validation_1-rmse:0.36107
# [11]	validation_0-rmse:0.34525	validation_1-rmse:0.36108
# [12]	validation_0-rmse:0.32423	validation_1-rmse:0.36063
# [13]	validation_0-rmse:0.30231	validation_1-rmse:0.36088
# [14]	validation_0-rmse:0.29379	validation_1-rmse:0.35491
# [15]	validation_0-rmse:0.28209	validation_1-rmse:0.34550
# [16]	validation_0-rmse:0.27427	validation_1-rmse:0.34685
# [17]	validation_0-rmse:0.27075	validation_1-rmse:0.34910
# [18]	validation_0-rmse:0.27073	validation_1-rmse:0.34878
# [19]	validation_0-rmse:0.27076	validation_1-rmse:0.34789
# [20]	validation_0-rmse:0.27075	validation_1-rmse:0.34912
# [21]	validation_0-rmse:0.27073	validation_1-rmse:0.34857
# [22]	validation_0-rmse:0.27077	validation_1-rmse:0.34928
# [23]	validation_0-rmse:0.27073	validation_1-rmse:0.34869
# [24]	validation_0-rmse:0.27093	validation_1-rmse:0.35042
# [25]	validation_0-rmse:0.27077	validation_1-rmse:0.34777
# [26]	validation_0-rmse:0.27118	validation_1-rmse:0.34617
# [27]	validation_0-rmse:0.27119	validation_1-rmse:0.34613
# [28]	validation_0-rmse:0.27095	validation_1-rmse:0.34678
# [29]	validation_0-rmse:0.27132	validation_1-rmse:0.34588
# [30]	validation_0-rmse:0.27073	validation_1-rmse:0.34836
# [31]	validation_0-rmse:0.26421	validation_1-rmse:0.34570
# [32]	validation_0-rmse:0.26529	validation_1-rmse:0.34426
# [33]	validation_0-rmse:0.26435	validation_1-rmse:0.34538
# [34]	validation_0-rmse:0.26466	validation_1-rmse:0.34488
# [35]	validation_0-rmse:0.26456	validation_1-rmse:0.34502
# [36]	validation_0-rmse:0.26402	validation_1-rmse:0.33948
# [37]	validation_0-rmse:0.25974	validation_1-rmse:0.34238
# [38]	validation_0-rmse:0.26011	validation_1-rmse:0.34191
# [39]	validation_0-rmse:0.25822	validation_1-rmse:0.34618
# [40]	validation_0-rmse:0.25774	validation_1-rmse:0.34720
# [41]	validation_0-rmse:0.25766	validation_1-rmse:0.34752
# [42]	validation_0-rmse:0.25757	validation_1-rmse:0.34871
# [43]	validation_0-rmse:0.25758	validation_1-rmse:0.34813
# [44]	validation_0-rmse:0.25765	validation_1-rmse:0.34957
# [45]	validation_0-rmse:0.25799	validation_1-rmse:0.35109
# [46]	validation_0-rmse:0.25762	validation_1-rmse:0.34934
# [47]	validation_0-rmse:0.25757	validation_1-rmse:0.34857
# [48]	validation_0-rmse:0.25771	validation_1-rmse:0.34994
# [49]	validation_0-rmse:0.25844	validation_1-rmse:0.35238
# [50]	validation_0-rmse:0.25812	validation_1-rmse:0.35149
# [51]	validation_0-rmse:0.25768	validation_1-rmse:0.34978
# [52]	validation_0-rmse:0.25759	validation_1-rmse:0.34913
# [53]	validation_0-rmse:0.25757	validation_1-rmse:0.34877
# [54]	validation_0-rmse:0.25781	validation_1-rmse:0.35042
# [55]	validation_0-rmse:0.25822	validation_1-rmse:0.35180
# [0]	validation_0-rmse:0.87081	validation_1-rmse:1.41681
# [1]	validation_0-rmse:0.70729	validation_1-rmse:1.20599
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:0.64042	validation_1-rmse:1.11641
# [3]	validation_0-rmse:0.55114	validation_1-rmse:0.99404
# [4]	validation_0-rmse:0.46987	validation_1-rmse:0.87904
# [5]	validation_0-rmse:0.40535	validation_1-rmse:0.78369
# [6]	validation_0-rmse:0.36029	validation_1-rmse:0.70607
# [7]	validation_0-rmse:0.33514	validation_1-rmse:0.64862
# [8]	validation_0-rmse:0.30810	validation_1-rmse:0.59717
# [9]	validation_0-rmse:0.30636	validation_1-rmse:0.59282
# [10]	validation_0-rmse:0.30396	validation_1-rmse:0.58486
# [11]	validation_0-rmse:0.29472	validation_1-rmse:0.57352
# [12]	validation_0-rmse:0.28833	validation_1-rmse:0.55309
# [13]	validation_0-rmse:0.27192	validation_1-rmse:0.51780
# [14]	validation_0-rmse:0.26099	validation_1-rmse:0.49185
# [15]	validation_0-rmse:0.25267	validation_1-rmse:0.47033
# [16]	validation_0-rmse:0.24849	validation_1-rmse:0.45598
# [17]	validation_0-rmse:0.24780	validation_1-rmse:0.45404
# [18]	validation_0-rmse:0.24656	validation_1-rmse:0.44922
# [19]	validation_0-rmse:0.24677	validation_1-rmse:0.45029
# [20]	validation_0-rmse:0.24750	validation_1-rmse:0.45311
# [21]	validation_0-rmse:0.24624	validation_1-rmse:0.44668
# [22]	validation_0-rmse:0.24618	validation_1-rmse:0.44536
# [23]	validation_0-rmse:0.24633	validation_1-rmse:0.44265
# [24]	validation_0-rmse:0.24623	validation_1-rmse:0.44369
# [25]	validation_0-rmse:0.24620	validation_1-rmse:0.44584
# [26]	validation_0-rmse:0.24636	validation_1-rmse:0.44784
# [27]	validation_0-rmse:0.24414	validation_1-rmse:0.43263
# [28]	validation_0-rmse:0.24425	validation_1-rmse:0.43428
# [29]	validation_0-rmse:0.24471	validation_1-rmse:0.43701
# [30]	validation_0-rmse:0.24415	validation_1-rmse:0.43163
# [31]	validation_0-rmse:0.24415	validation_1-rmse:0.43166
# [32]	validation_0-rmse:0.24414	validation_1-rmse:0.43220
# [33]	validation_0-rmse:0.24415	validation_1-rmse:0.43158
# [34]	validation_0-rmse:0.24422	validation_1-rmse:0.43068
# [35]	validation_0-rmse:0.24453	validation_1-rmse:0.42882
# [36]	validation_0-rmse:0.24506	validation_1-rmse:0.42712
# [37]	validation_0-rmse:0.24602	validation_1-rmse:0.42522
# [38]	validation_0-rmse:0.24446	validation_1-rmse:0.42911
# [39]	validation_0-rmse:0.24414	validation_1-rmse:0.43219
# [40]	validation_0-rmse:0.24416	validation_1-rmse:0.43148
# [41]	validation_0-rmse:0.24416	validation_1-rmse:0.43307
# [42]	validation_0-rmse:0.24416	validation_1-rmse:0.43146
# [43]	validation_0-rmse:0.24439	validation_1-rmse:0.42948
# [44]	validation_0-rmse:0.24456	validation_1-rmse:0.42868
# [45]	validation_0-rmse:0.24447	validation_1-rmse:0.42905
# [46]	validation_0-rmse:0.24457	validation_1-rmse:0.42866
# [47]	validation_0-rmse:0.24481	validation_1-rmse:0.42782
# [48]	validation_0-rmse:0.24428	validation_1-rmse:0.43018
# [49]	validation_0-rmse:0.24534	validation_1-rmse:0.42647
# [50]	validation_0-rmse:0.24533	validation_1-rmse:0.42650
# [51]	validation_0-rmse:0.24446	validation_1-rmse:0.42912
# [52]	validation_0-rmse:0.24437	validation_1-rmse:0.42960
# [53]	validation_0-rmse:0.24497	validation_1-rmse:0.42736
# [54]	validation_0-rmse:0.24423	validation_1-rmse:0.43051
# [55]	validation_0-rmse:0.24435	validation_1-rmse:0.42970
# [56]	validation_0-rmse:0.24417	validation_1-rmse:0.43327
# [0]	validation_0-rmse:0.92069	validation_1-rmse:1.29465
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:0.74199	validation_1-rmse:1.05238
# [2]	validation_0-rmse:0.64707	validation_1-rmse:0.98741
# [3]	validation_0-rmse:0.52176	validation_1-rmse:0.78504
# [4]	validation_0-rmse:0.48423	validation_1-rmse:0.73293
# [5]	validation_0-rmse:0.40173	validation_1-rmse:0.59697
# [6]	validation_0-rmse:0.37302	validation_1-rmse:0.54724
# [7]	validation_0-rmse:0.36604	validation_1-rmse:0.53875
# [8]	validation_0-rmse:0.33960	validation_1-rmse:0.49756
# [9]	validation_0-rmse:0.32465	validation_1-rmse:0.46517
# [10]	validation_0-rmse:0.31398	validation_1-rmse:0.43979
# [11]	validation_0-rmse:0.31362	validation_1-rmse:0.43785
# [12]	validation_0-rmse:0.29193	validation_1-rmse:0.38923
# [13]	validation_0-rmse:0.29190	validation_1-rmse:0.38886
# [14]	validation_0-rmse:0.28111	validation_1-rmse:0.36924
# [15]	validation_0-rmse:0.27207	validation_1-rmse:0.35435
# [16]	validation_0-rmse:0.27233	validation_1-rmse:0.35636
# [17]	validation_0-rmse:0.27217	validation_1-rmse:0.35532
# [18]	validation_0-rmse:0.27202	validation_1-rmse:0.35373
# [19]	validation_0-rmse:0.27204	validation_1-rmse:0.35402
# [20]	validation_0-rmse:0.26298	validation_1-rmse:0.34393
# [21]	validation_0-rmse:0.26331	validation_1-rmse:0.34179
# [22]	validation_0-rmse:0.26306	validation_1-rmse:0.34311
# [23]	validation_0-rmse:0.26300	validation_1-rmse:0.34370
# [24]	validation_0-rmse:0.26311	validation_1-rmse:0.34276
# [25]	validation_0-rmse:0.26149	validation_1-rmse:0.34014
# [26]	validation_0-rmse:0.26196	validation_1-rmse:0.33905
# [27]	validation_0-rmse:0.26224	validation_1-rmse:0.33854
# [28]	validation_0-rmse:0.26158	validation_1-rmse:0.33990
# [29]	validation_0-rmse:0.26079	validation_1-rmse:0.34341
# [30]	validation_0-rmse:0.26076	validation_1-rmse:0.34610
# [31]	validation_0-rmse:0.26086	validation_1-rmse:0.34278
# [32]	validation_0-rmse:0.26082	validation_1-rmse:0.34306
# [33]	validation_0-rmse:0.25658	validation_1-rmse:0.35716
# [34]	validation_0-rmse:0.25167	validation_1-rmse:0.35319
# [35]	validation_0-rmse:0.25183	validation_1-rmse:0.35050
# [36]	validation_0-rmse:0.25170	validation_1-rmse:0.35160
# [37]	validation_0-rmse:0.25203	validation_1-rmse:0.34946
# [38]	validation_0-rmse:0.25167	validation_1-rmse:0.35286
# [39]	validation_0-rmse:0.25168	validation_1-rmse:0.35200
# [40]	validation_0-rmse:0.24827	validation_1-rmse:0.34290
# [41]	validation_0-rmse:0.24828	validation_1-rmse:0.34353
# [42]	validation_0-rmse:0.24829	validation_1-rmse:0.34228
# [43]	validation_0-rmse:0.24827	validation_1-rmse:0.34267
# [44]	validation_0-rmse:0.24829	validation_1-rmse:0.34391
# [45]	validation_0-rmse:0.24833	validation_1-rmse:0.34173
# [46]	validation_0-rmse:0.24827	validation_1-rmse:0.34303
# [47]	validation_0-rmse:0.24834	validation_1-rmse:0.34165
# [0]	validation_0-rmse:1.07606	validation_1-rmse:0.53773
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:0.83500	validation_1-rmse:0.46670
# [2]	validation_0-rmse:0.69375	validation_1-rmse:0.43509
# [3]	validation_0-rmse:0.55943	validation_1-rmse:0.37941
# [4]	validation_0-rmse:0.47521	validation_1-rmse:0.38033
# [5]	validation_0-rmse:0.41573	validation_1-rmse:0.36929
# [6]	validation_0-rmse:0.35806	validation_1-rmse:0.36506
# [7]	validation_0-rmse:0.34921	validation_1-rmse:0.36424
# [8]	validation_0-rmse:0.31860	validation_1-rmse:0.36196
# [9]	validation_0-rmse:0.30136	validation_1-rmse:0.36710
# [10]	validation_0-rmse:0.29799	validation_1-rmse:0.36194
# [11]	validation_0-rmse:0.28746	validation_1-rmse:0.36124
# [12]	validation_0-rmse:0.28211	validation_1-rmse:0.34901
# [13]	validation_0-rmse:0.26814	validation_1-rmse:0.34750
# [14]	validation_0-rmse:0.26879	validation_1-rmse:0.34722
# [15]	validation_0-rmse:0.27003	validation_1-rmse:0.34716
# [16]	validation_0-rmse:0.26435	validation_1-rmse:0.34716
# [17]	validation_0-rmse:0.26450	validation_1-rmse:0.34718
# [18]	validation_0-rmse:0.26379	validation_1-rmse:0.34716
# [19]	validation_0-rmse:0.26336	validation_1-rmse:0.34734
# [20]	validation_0-rmse:0.26318	validation_1-rmse:0.34793
# [21]	validation_0-rmse:0.26321	validation_1-rmse:0.34810
# [22]	validation_0-rmse:0.26323	validation_1-rmse:0.34751
# [23]	validation_0-rmse:0.26319	validation_1-rmse:0.34799
# [24]	validation_0-rmse:0.26319	validation_1-rmse:0.34798
# [25]	validation_0-rmse:0.25891	validation_1-rmse:0.35154
# [26]	validation_0-rmse:0.25888	validation_1-rmse:0.35089
# [27]	validation_0-rmse:0.25865	validation_1-rmse:0.35129
# [28]	validation_0-rmse:0.25161	validation_1-rmse:0.34388
# [29]	validation_0-rmse:0.25168	validation_1-rmse:0.34389
# [30]	validation_0-rmse:0.25049	validation_1-rmse:0.33547
# [31]	validation_0-rmse:0.25077	validation_1-rmse:0.33573
# [32]	validation_0-rmse:0.25057	validation_1-rmse:0.33555
# [33]	validation_0-rmse:0.25053	validation_1-rmse:0.33551
# [34]	validation_0-rmse:0.25066	validation_1-rmse:0.33564
# [35]	validation_0-rmse:0.25047	validation_1-rmse:0.33544
# [36]	validation_0-rmse:0.25048	validation_1-rmse:0.33543
# [37]	validation_0-rmse:0.25050	validation_1-rmse:0.33548
# [38]	validation_0-rmse:0.25048	validation_1-rmse:0.33546
# [39]	validation_0-rmse:0.25055	validation_1-rmse:0.33554
# [40]	validation_0-rmse:0.25064	validation_1-rmse:0.33562
# [41]	validation_0-rmse:0.25061	validation_1-rmse:0.33549
# [42]	validation_0-rmse:0.25047	validation_1-rmse:0.33543
# [43]	validation_0-rmse:0.25048	validation_1-rmse:0.33546
# [44]	validation_0-rmse:0.25067	validation_1-rmse:0.33553
# [45]	validation_0-rmse:0.25068	validation_1-rmse:0.33553
# [46]	validation_0-rmse:0.25049	validation_1-rmse:0.33547
# [47]	validation_0-rmse:0.25052	validation_1-rmse:0.33551
# [48]	validation_0-rmse:0.25054	validation_1-rmse:0.33545
# [49]	validation_0-rmse:0.25047	validation_1-rmse:0.33543
# [50]	validation_0-rmse:0.24838	validation_1-rmse:0.34528
# [51]	validation_0-rmse:0.24863	validation_1-rmse:0.34554
# [52]	validation_0-rmse:0.24841	validation_1-rmse:0.34522
# [53]	validation_0-rmse:0.24871	validation_1-rmse:0.34536
# [54]	validation_0-rmse:0.24935	validation_1-rmse:0.34574
# [55]	validation_0-rmse:0.24544	validation_1-rmse:0.34810
# [56]	validation_0-rmse:0.24686	validation_1-rmse:0.34919
# [57]	validation_0-rmse:0.24477	validation_1-rmse:0.34758
# [58]	validation_0-rmse:0.24391	validation_1-rmse:0.34688
# [59]	validation_0-rmse:0.24463	validation_1-rmse:0.34747
# [60]	validation_0-rmse:0.24387	validation_1-rmse:0.34685
# [61]	validation_0-rmse:0.24383	validation_1-rmse:0.34682
# [62]	validation_0-rmse:0.24377	validation_1-rmse:0.34677
# [63]	validation_0-rmse:0.24365	validation_1-rmse:0.34666
# [64]	validation_0-rmse:0.24440	validation_1-rmse:0.34729
# [65]	validation_0-rmse:0.24481	validation_1-rmse:0.34761
# [66]	validation_0-rmse:0.24330	validation_1-rmse:0.34625
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.00810	validation_1-rmse:0.91201
# [1]	validation_0-rmse:0.77785	validation_1-rmse:0.72676
# [2]	validation_0-rmse:0.66382	validation_1-rmse:0.67627
# [3]	validation_0-rmse:0.52482	validation_1-rmse:0.58468
# [4]	validation_0-rmse:0.44714	validation_1-rmse:0.55342
# [5]	validation_0-rmse:0.37384	validation_1-rmse:0.49067
# [6]	validation_0-rmse:0.33648	validation_1-rmse:0.46009
# [7]	validation_0-rmse:0.33397	validation_1-rmse:0.46035
# [8]	validation_0-rmse:0.29607	validation_1-rmse:0.43801
# [9]	validation_0-rmse:0.27968	validation_1-rmse:0.43795
# [10]	validation_0-rmse:0.27277	validation_1-rmse:0.44145
# [11]	validation_0-rmse:0.26594	validation_1-rmse:0.44280
# [12]	validation_0-rmse:0.26480	validation_1-rmse:0.44392
# [13]	validation_0-rmse:0.25450	validation_1-rmse:0.42731
# [14]	validation_0-rmse:0.25289	validation_1-rmse:0.43144
# [15]	validation_0-rmse:0.25240	validation_1-rmse:0.43429
# [16]	validation_0-rmse:0.24765	validation_1-rmse:0.43295
# [17]	validation_0-rmse:0.24758	validation_1-rmse:0.43451
# [18]	validation_0-rmse:0.24800	validation_1-rmse:0.43048
# [19]	validation_0-rmse:0.24766	validation_1-rmse:0.43280
# [20]	validation_0-rmse:0.24682	validation_1-rmse:0.42702
# [21]	validation_0-rmse:0.24725	validation_1-rmse:0.43184
# [22]	validation_0-rmse:0.24691	validation_1-rmse:0.42915
# [23]	validation_0-rmse:0.24682	validation_1-rmse:0.42674
# [24]	validation_0-rmse:0.24684	validation_1-rmse:0.42600
# [25]	validation_0-rmse:0.24686	validation_1-rmse:0.42847
# [26]	validation_0-rmse:0.24697	validation_1-rmse:0.42415
# [27]	validation_0-rmse:0.24684	validation_1-rmse:0.42599
# [28]	validation_0-rmse:0.24699	validation_1-rmse:0.42406
# [29]	validation_0-rmse:0.24683	validation_1-rmse:0.42616
# [30]	validation_0-rmse:0.24742	validation_1-rmse:0.43279
# [31]	validation_0-rmse:0.24617	validation_1-rmse:0.43745
# [32]	validation_0-rmse:0.24596	validation_1-rmse:0.43648
# [33]	validation_0-rmse:0.24535	validation_1-rmse:0.43263
# [34]	validation_0-rmse:0.24518	validation_1-rmse:0.42985
# [35]	validation_0-rmse:0.24518	validation_1-rmse:0.43013
# [36]	validation_0-rmse:0.24518	validation_1-rmse:0.42889
# [37]	validation_0-rmse:0.24518	validation_1-rmse:0.42957
# [38]	validation_0-rmse:0.24520	validation_1-rmse:0.43065
# [39]	validation_0-rmse:0.24549	validation_1-rmse:0.43378
# [40]	validation_0-rmse:0.24523	validation_1-rmse:0.43123
# [41]	validation_0-rmse:0.24532	validation_1-rmse:0.43233
# [42]	validation_0-rmse:0.24527	validation_1-rmse:0.43177
# [43]	validation_0-rmse:0.24519	validation_1-rmse:0.43031
# [44]	validation_0-rmse:0.24630	validation_1-rmse:0.43798
# [45]	validation_0-rmse:0.24617	validation_1-rmse:0.43744
# [46]	validation_0-rmse:0.24535	validation_1-rmse:0.43270
# [47]	validation_0-rmse:0.24517	validation_1-rmse:0.42950
# [48]	validation_0-rmse:0.24518	validation_1-rmse:0.43012
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:0.92501	validation_1-rmse:1.03682
# [1]	validation_0-rmse:0.73101	validation_1-rmse:0.80078
# [2]	validation_0-rmse:0.66629	validation_1-rmse:0.71675
# [3]	validation_0-rmse:0.55091	validation_1-rmse:0.60331
# [4]	validation_0-rmse:0.46585	validation_1-rmse:0.51082
# [5]	validation_0-rmse:0.39936	validation_1-rmse:0.45017
# [6]	validation_0-rmse:0.36358	validation_1-rmse:0.41601
# [7]	validation_0-rmse:0.35922	validation_1-rmse:0.41304
# [8]	validation_0-rmse:0.33832	validation_1-rmse:0.38922
# [9]	validation_0-rmse:0.32332	validation_1-rmse:0.37949
# [10]	validation_0-rmse:0.32187	validation_1-rmse:0.37954
# [11]	validation_0-rmse:0.31918	validation_1-rmse:0.37362
# [12]	validation_0-rmse:0.30443	validation_1-rmse:0.37173
# [13]	validation_0-rmse:0.28846	validation_1-rmse:0.36968
# [14]	validation_0-rmse:0.28138	validation_1-rmse:0.36114
# [15]	validation_0-rmse:0.28104	validation_1-rmse:0.36274
# [16]	validation_0-rmse:0.28209	validation_1-rmse:0.36020
# [17]	validation_0-rmse:0.27754	validation_1-rmse:0.35778
# [18]	validation_0-rmse:0.27718	validation_1-rmse:0.35997
# [19]	validation_0-rmse:0.27741	validation_1-rmse:0.36129
# [20]	validation_0-rmse:0.27765	validation_1-rmse:0.36213
# [21]	validation_0-rmse:0.27834	validation_1-rmse:0.36392
# [22]	validation_0-rmse:0.27283	validation_1-rmse:0.36377
# [23]	validation_0-rmse:0.26701	validation_1-rmse:0.36610
# [24]	validation_0-rmse:0.26658	validation_1-rmse:0.36384
# [25]	validation_0-rmse:0.26470	validation_1-rmse:0.36786
# [26]	validation_0-rmse:0.26447	validation_1-rmse:0.36543
# [27]	validation_0-rmse:0.26449	validation_1-rmse:0.36606
# [28]	validation_0-rmse:0.26458	validation_1-rmse:0.36399
# [29]	validation_0-rmse:0.26456	validation_1-rmse:0.36692
# [30]	validation_0-rmse:0.26541	validation_1-rmse:0.37063
# [31]	validation_0-rmse:0.26759	validation_1-rmse:0.36747
# [32]	validation_0-rmse:0.26757	validation_1-rmse:0.36880
# [33]	validation_0-rmse:0.26071	validation_1-rmse:0.36441
# [34]	validation_0-rmse:0.26072	validation_1-rmse:0.36596
# [35]	validation_0-rmse:0.26069	validation_1-rmse:0.36502
# [36]	validation_0-rmse:0.26074	validation_1-rmse:0.36622
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:1.04391	validation_1-rmse:0.90632
# [1]	validation_0-rmse:0.81887	validation_1-rmse:0.67719
# [2]	validation_0-rmse:0.69876	validation_1-rmse:0.54987
# [3]	validation_0-rmse:0.56775	validation_1-rmse:0.43985
# [4]	validation_0-rmse:0.47869	validation_1-rmse:0.37262
# [5]	validation_0-rmse:0.44709	validation_1-rmse:0.34633
# [6]	validation_0-rmse:0.40820	validation_1-rmse:0.33026
# [7]	validation_0-rmse:0.39500	validation_1-rmse:0.32225
# [8]	validation_0-rmse:0.35205	validation_1-rmse:0.30410
# [9]	validation_0-rmse:0.32505	validation_1-rmse:0.29132
# [10]	validation_0-rmse:0.32218	validation_1-rmse:0.29019
# [11]	validation_0-rmse:0.32228	validation_1-rmse:0.29022
# [12]	validation_0-rmse:0.30941	validation_1-rmse:0.28431
# [13]	validation_0-rmse:0.30216	validation_1-rmse:0.28221
# [14]	validation_0-rmse:0.29145	validation_1-rmse:0.28007
# [15]	validation_0-rmse:0.28697	validation_1-rmse:0.28622
# [16]	validation_0-rmse:0.28026	validation_1-rmse:0.29408
# [17]	validation_0-rmse:0.28039	validation_1-rmse:0.29353
# [18]	validation_0-rmse:0.28022	validation_1-rmse:0.29576
# [19]	validation_0-rmse:0.27168	validation_1-rmse:0.29310
# [20]	validation_0-rmse:0.27147	validation_1-rmse:0.29413
# [21]	validation_0-rmse:0.27161	validation_1-rmse:0.29332
# [22]	validation_0-rmse:0.27240	validation_1-rmse:0.29189
# [23]	validation_0-rmse:0.26560	validation_1-rmse:0.28758
# [24]	validation_0-rmse:0.26524	validation_1-rmse:0.28826
# [25]	validation_0-rmse:0.26505	validation_1-rmse:0.28891
# [26]	validation_0-rmse:0.26492	validation_1-rmse:0.28993
# [27]	validation_0-rmse:0.26493	validation_1-rmse:0.28976
# [28]	validation_0-rmse:0.26493	validation_1-rmse:0.28967
# [29]	validation_0-rmse:0.26511	validation_1-rmse:0.28864
# [30]	validation_0-rmse:0.26504	validation_1-rmse:0.29176
# [31]	validation_0-rmse:0.26495	validation_1-rmse:0.29109
# [32]	validation_0-rmse:0.26491	validation_1-rmse:0.29023
# [33]	validation_0-rmse:0.26492	validation_1-rmse:0.28991
# [34]	validation_0-rmse:0.26494	validation_1-rmse:0.28955
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:1.01425	validation_1-rmse:0.81040
# [1]	validation_0-rmse:0.80518	validation_1-rmse:0.62299
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:0.68070	validation_1-rmse:0.52715
# [3]	validation_0-rmse:0.58256	validation_1-rmse:0.42900
# [4]	validation_0-rmse:0.50181	validation_1-rmse:0.37497
# [5]	validation_0-rmse:0.45592	validation_1-rmse:0.33385
# [6]	validation_0-rmse:0.39096	validation_1-rmse:0.30339
# [7]	validation_0-rmse:0.37841	validation_1-rmse:0.29434
# [8]	validation_0-rmse:0.34446	validation_1-rmse:0.29298
# [9]	validation_0-rmse:0.32284	validation_1-rmse:0.29468
# [10]	validation_0-rmse:0.31927	validation_1-rmse:0.28985
# [11]	validation_0-rmse:0.31434	validation_1-rmse:0.29371
# [12]	validation_0-rmse:0.30603	validation_1-rmse:0.29791
# [13]	validation_0-rmse:0.29557	validation_1-rmse:0.29738
# [14]	validation_0-rmse:0.29079	validation_1-rmse:0.29177
# [15]	validation_0-rmse:0.29101	validation_1-rmse:0.29220
# [16]	validation_0-rmse:0.28995	validation_1-rmse:0.28984
# [17]	validation_0-rmse:0.28959	validation_1-rmse:0.28835
# [18]	validation_0-rmse:0.28868	validation_1-rmse:0.29841
# [19]	validation_0-rmse:0.28874	validation_1-rmse:0.29801
# [20]	validation_0-rmse:0.28871	validation_1-rmse:0.29905
# [21]	validation_0-rmse:0.28667	validation_1-rmse:0.29659
# [22]	validation_0-rmse:0.28371	validation_1-rmse:0.30322
# [23]	validation_0-rmse:0.28390	validation_1-rmse:0.30399
# [24]	validation_0-rmse:0.28389	validation_1-rmse:0.30395
# [25]	validation_0-rmse:0.28388	validation_1-rmse:0.30393
# [26]	validation_0-rmse:0.28151	validation_1-rmse:0.30656
# [27]	validation_0-rmse:0.28157	validation_1-rmse:0.30673
# [28]	validation_0-rmse:0.27372	validation_1-rmse:0.31213
# [29]	validation_0-rmse:0.27344	validation_1-rmse:0.30976
# [30]	validation_0-rmse:0.27360	validation_1-rmse:0.30867
# [31]	validation_0-rmse:0.27344	validation_1-rmse:0.30978
# [32]	validation_0-rmse:0.27351	validation_1-rmse:0.31105
# [33]	validation_0-rmse:0.26532	validation_1-rmse:0.28419
# [34]	validation_0-rmse:0.26174	validation_1-rmse:0.28713
# [35]	validation_0-rmse:0.26191	validation_1-rmse:0.28775
# [36]	validation_0-rmse:0.26142	validation_1-rmse:0.28572
# [37]	validation_0-rmse:0.26126	validation_1-rmse:0.28418
# [38]	validation_0-rmse:0.26129	validation_1-rmse:0.28326
# [39]	validation_0-rmse:0.26140	validation_1-rmse:0.28256
# [40]	validation_0-rmse:0.26225	validation_1-rmse:0.28089
# [41]	validation_0-rmse:0.26216	validation_1-rmse:0.28100
# [42]	validation_0-rmse:0.26144	validation_1-rmse:0.28241
# [43]	validation_0-rmse:0.26181	validation_1-rmse:0.28149
# [44]	validation_0-rmse:0.26178	validation_1-rmse:0.28156
# [45]	validation_0-rmse:0.26151	validation_1-rmse:0.28217
# [46]	validation_0-rmse:0.26126	validation_1-rmse:0.28364
# ...
# [30]	validation_0-rmse:0.26376	validation_1-rmse:0.28041
# [31]	validation_0-rmse:0.26391	validation_1-rmse:0.28521
# [32]	validation_0-rmse:0.26378	validation_1-rmse:0.28181
# [33]	validation_0-rmse:0.26381	validation_1-rmse:0.28295
# [0]	validation_0-rmse:0.98740	validation_1-rmse:0.96787
# [1]	validation_0-rmse:0.81533	validation_1-rmse:0.79886
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:0.68359	validation_1-rmse:0.64590
# [3]	validation_0-rmse:0.57659	validation_1-rmse:0.54036
# [4]	validation_0-rmse:0.48626	validation_1-rmse:0.46808
# [5]	validation_0-rmse:0.42674	validation_1-rmse:0.40247
# [6]	validation_0-rmse:0.38610	validation_1-rmse:0.36524
# [7]	validation_0-rmse:0.37089	validation_1-rmse:0.35155
# [8]	validation_0-rmse:0.34932	validation_1-rmse:0.33768
# [9]	validation_0-rmse:0.32224	validation_1-rmse:0.31337
# [10]	validation_0-rmse:0.32079	validation_1-rmse:0.31106
# [11]	validation_0-rmse:0.31055	validation_1-rmse:0.30544
# [12]	validation_0-rmse:0.30732	validation_1-rmse:0.30612
# [13]	validation_0-rmse:0.29995	validation_1-rmse:0.29982
# [14]	validation_0-rmse:0.29459	validation_1-rmse:0.30025
# [15]	validation_0-rmse:0.29500	validation_1-rmse:0.30089
# [16]	validation_0-rmse:0.29038	validation_1-rmse:0.29093
# [17]	validation_0-rmse:0.29179	validation_1-rmse:0.29357
# [18]	validation_0-rmse:0.29015	validation_1-rmse:0.29041
# [19]	validation_0-rmse:0.29112	validation_1-rmse:0.29240
# [20]	validation_0-rmse:0.29235	validation_1-rmse:0.29449
# [21]	validation_0-rmse:0.29103	validation_1-rmse:0.29222
# [22]	validation_0-rmse:0.29193	validation_1-rmse:0.29395
# [23]	validation_0-rmse:0.29121	validation_1-rmse:0.29233
# [24]	validation_0-rmse:0.29087	validation_1-rmse:0.29061
# [25]	validation_0-rmse:0.29158	validation_1-rmse:0.28982
# [26]	validation_0-rmse:0.29151	validation_1-rmse:0.28984
# [27]	validation_0-rmse:0.29379	validation_1-rmse:0.29030
# [28]	validation_0-rmse:0.29176	validation_1-rmse:0.29440
# [29]	validation_0-rmse:0.29157	validation_1-rmse:0.29448
# [30]	validation_0-rmse:0.29160	validation_1-rmse:0.29446
# [31]	validation_0-rmse:0.29167	validation_1-rmse:0.29443
# [32]	validation_0-rmse:0.29324	validation_1-rmse:0.29455
# [33]	validation_0-rmse:0.28250	validation_1-rmse:0.28976
# [34]	validation_0-rmse:0.28116	validation_1-rmse:0.29198
# [35]	validation_0-rmse:0.28291	validation_1-rmse:0.29258
# [36]	validation_0-rmse:0.28240	validation_1-rmse:0.29236
# [37]	validation_0-rmse:0.28285	validation_1-rmse:0.29255
# [38]	validation_0-rmse:0.28096	validation_1-rmse:0.29195
# [39]	validation_0-rmse:0.28051	validation_1-rmse:0.29194
# [40]	validation_0-rmse:0.28020	validation_1-rmse:0.29203
# [41]	validation_0-rmse:0.27984	validation_1-rmse:0.29247
# [42]	validation_0-rmse:0.28029	validation_1-rmse:0.29199
# [43]	validation_0-rmse:0.27986	validation_1-rmse:0.29242
# [44]	validation_0-rmse:0.27983	validation_1-rmse:0.29311
# [45]	validation_0-rmse:0.27926	validation_1-rmse:0.30013
# [46]	validation_0-rmse:0.27435	validation_1-rmse:0.31138
# [47]	validation_0-rmse:0.27396	validation_1-rmse:0.31004
# [48]	validation_0-rmse:0.27414	validation_1-rmse:0.31082
# [49]	validation_0-rmse:0.27439	validation_1-rmse:0.31148
# [50]	validation_0-rmse:0.27395	validation_1-rmse:0.30936
# [51]	validation_0-rmse:0.27399	validation_1-rmse:0.30919
# [52]	validation_0-rmse:0.27396	validation_1-rmse:0.30931
# [53]	validation_0-rmse:0.27394	validation_1-rmse:0.30942
# [0]	validation_0-rmse:1.04156	validation_1-rmse:0.82616
# [1]	validation_0-rmse:0.81567	validation_1-rmse:0.61876
# [2]	validation_0-rmse:0.75731	validation_1-rmse:0.57140
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:0.61262	validation_1-rmse:0.46289
# [4]	validation_0-rmse:0.50632	validation_1-rmse:0.38198
# [5]	validation_0-rmse:0.42704	validation_1-rmse:0.31549
# [6]	validation_0-rmse:0.37394	validation_1-rmse:0.28232
# [7]	validation_0-rmse:0.35072	validation_1-rmse:0.25187
# [8]	validation_0-rmse:0.32449	validation_1-rmse:0.24406
# [9]	validation_0-rmse:0.31261	validation_1-rmse:0.23399
# [10]	validation_0-rmse:0.31342	validation_1-rmse:0.23557
# [11]	validation_0-rmse:0.30268	validation_1-rmse:0.24072
# [12]	validation_0-rmse:0.29565	validation_1-rmse:0.24975
# [13]	validation_0-rmse:0.28800	validation_1-rmse:0.26465
# [14]	validation_0-rmse:0.28000	validation_1-rmse:0.25803
# [15]	validation_0-rmse:0.27703	validation_1-rmse:0.25994
# [16]	validation_0-rmse:0.27698	validation_1-rmse:0.26134
# [17]	validation_0-rmse:0.27099	validation_1-rmse:0.25831
# [18]	validation_0-rmse:0.27087	validation_1-rmse:0.25911
# [19]	validation_0-rmse:0.26664	validation_1-rmse:0.28022
# [20]	validation_0-rmse:0.26661	validation_1-rmse:0.28230
# [21]	validation_0-rmse:0.26672	validation_1-rmse:0.27948
# [22]	validation_0-rmse:0.26691	validation_1-rmse:0.27850
# [23]	validation_0-rmse:0.26662	validation_1-rmse:0.28055
# [24]	validation_0-rmse:0.26203	validation_1-rmse:0.27509
# [25]	validation_0-rmse:0.26218	validation_1-rmse:0.27752
# [26]	validation_0-rmse:0.26207	validation_1-rmse:0.27629
# [27]	validation_0-rmse:0.26215	validation_1-rmse:0.27726
# [28]	validation_0-rmse:0.26235	validation_1-rmse:0.27874
# [0]	validation_0-rmse:1.02019	validation_1-rmse:0.90053
# [1]	validation_0-rmse:0.80594	validation_1-rmse:0.69403
# [2]	validation_0-rmse:0.69149	validation_1-rmse:0.60239
# [3]	validation_0-rmse:0.56847	validation_1-rmse:0.48530
# [4]	validation_0-rmse:0.47645	validation_1-rmse:0.42009
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:0.40186	validation_1-rmse:0.38065
# [6]	validation_0-rmse:0.37572	validation_1-rmse:0.34653
# [7]	validation_0-rmse:0.36971	validation_1-rmse:0.34037
# [8]	validation_0-rmse:0.33426	validation_1-rmse:0.32533
# [9]	validation_0-rmse:0.32027	validation_1-rmse:0.30956
# [10]	validation_0-rmse:0.31699	validation_1-rmse:0.30651
# [11]	validation_0-rmse:0.30256	validation_1-rmse:0.28948
# [12]	validation_0-rmse:0.29350	validation_1-rmse:0.29072
# [13]	validation_0-rmse:0.28024	validation_1-rmse:0.29086
# [14]	validation_0-rmse:0.27793	validation_1-rmse:0.29707
# [15]	validation_0-rmse:0.27784	validation_1-rmse:0.29697
# [16]	validation_0-rmse:0.27786	validation_1-rmse:0.29699
# [17]	validation_0-rmse:0.27774	validation_1-rmse:0.29683
# [18]	validation_0-rmse:0.27789	validation_1-rmse:0.29703
# [19]	validation_0-rmse:0.27783	validation_1-rmse:0.29695
# [20]	validation_0-rmse:0.27780	validation_1-rmse:0.29692
# [21]	validation_0-rmse:0.27802	validation_1-rmse:0.29700
# [22]	validation_0-rmse:0.27835	validation_1-rmse:0.29727
# [23]	validation_0-rmse:0.27917	validation_1-rmse:0.29796
# [24]	validation_0-rmse:0.27800	validation_1-rmse:0.29698
# [25]	validation_0-rmse:0.27774	validation_1-rmse:0.29682
# [26]	validation_0-rmse:0.27042	validation_1-rmse:0.30445
# [27]	validation_0-rmse:0.26545	validation_1-rmse:0.31460
# [28]	validation_0-rmse:0.26359	validation_1-rmse:0.31617
# [29]	validation_0-rmse:0.26323	validation_1-rmse:0.31679
# [30]	validation_0-rmse:0.26116	validation_1-rmse:0.31175
# [0]	validation_0-rmse:0.99102	validation_1-rmse:0.75444
# [1]	validation_0-rmse:0.78187	validation_1-rmse:0.58749
# [2]	validation_0-rmse:0.65936	validation_1-rmse:0.51900
# [3]	validation_0-rmse:0.54852	validation_1-rmse:0.45092
# [4]	validation_0-rmse:0.47501	validation_1-rmse:0.40358
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [5]	validation_0-rmse:0.41521	validation_1-rmse:0.37371
# [6]	validation_0-rmse:0.36885	validation_1-rmse:0.36748
# [7]	validation_0-rmse:0.35510	validation_1-rmse:0.36682
# [8]	validation_0-rmse:0.32859	validation_1-rmse:0.36679
# [9]	validation_0-rmse:0.31106	validation_1-rmse:0.35436
# [10]	validation_0-rmse:0.31102	validation_1-rmse:0.35437
# [11]	validation_0-rmse:0.30886	validation_1-rmse:0.35585
# [12]	validation_0-rmse:0.29928	validation_1-rmse:0.36090
# [13]	validation_0-rmse:0.28496	validation_1-rmse:0.35945
# [14]	validation_0-rmse:0.27961	validation_1-rmse:0.35774
# [15]	validation_0-rmse:0.27981	validation_1-rmse:0.35726
# [16]	validation_0-rmse:0.27988	validation_1-rmse:0.35713
# [17]	validation_0-rmse:0.27834	validation_1-rmse:0.35830
# [18]	validation_0-rmse:0.27846	validation_1-rmse:0.35801
# [19]	validation_0-rmse:0.27813	validation_1-rmse:0.35903
# [20]	validation_0-rmse:0.27825	validation_1-rmse:0.35855
# [21]	validation_0-rmse:0.27805	validation_1-rmse:0.36145
# [22]	validation_0-rmse:0.27805	validation_1-rmse:0.36146
# [23]	validation_0-rmse:0.27801	validation_1-rmse:0.36103
# [24]	validation_0-rmse:0.27720	validation_1-rmse:0.35752
# [25]	validation_0-rmse:0.27703	validation_1-rmse:0.35701
# [26]	validation_0-rmse:0.27035	validation_1-rmse:0.35234
# [27]	validation_0-rmse:0.27024	validation_1-rmse:0.35172
# [28]	validation_0-rmse:0.27017	validation_1-rmse:0.35107
# [29]	validation_0-rmse:0.27016	validation_1-rmse:0.35098
# [30]	validation_0-rmse:0.27087	validation_1-rmse:0.35405
# [31]	validation_0-rmse:0.27039	validation_1-rmse:0.35250
# [32]	validation_0-rmse:0.26376	validation_1-rmse:0.33760
# [33]	validation_0-rmse:0.26439	validation_1-rmse:0.33592
# [34]	validation_0-rmse:0.26470	validation_1-rmse:0.33555
# [35]	validation_0-rmse:0.26386	validation_1-rmse:0.33709
# [36]	validation_0-rmse:0.26413	validation_1-rmse:0.33634
# [37]	validation_0-rmse:0.26413	validation_1-rmse:0.33635
# [38]	validation_0-rmse:0.26172	validation_1-rmse:0.34012
# [39]	validation_0-rmse:0.26230	validation_1-rmse:0.33888
# [40]	validation_0-rmse:0.25585	validation_1-rmse:0.33862
# [41]	validation_0-rmse:0.25582	validation_1-rmse:0.33866
# [42]	validation_0-rmse:0.25567	validation_1-rmse:0.33893
# [43]	validation_0-rmse:0.25547	validation_1-rmse:0.33996
# [44]	validation_0-rmse:0.25547	validation_1-rmse:0.33983
# [45]	validation_0-rmse:0.25547	validation_1-rmse:0.34018
# [46]	validation_0-rmse:0.25251	validation_1-rmse:0.34412
# [47]	validation_0-rmse:0.25252	validation_1-rmse:0.34408
# [48]	validation_0-rmse:0.25269	validation_1-rmse:0.34563
# [49]	validation_0-rmse:0.24849	validation_1-rmse:0.34094
# [50]	validation_0-rmse:0.24859	validation_1-rmse:0.34118
# [51]	validation_0-rmse:0.24797	validation_1-rmse:0.33939
# [52]	validation_0-rmse:0.24786	validation_1-rmse:0.33798
# [53]	validation_0-rmse:0.24808	validation_1-rmse:0.33721
# [0]	validation_0-rmse:1.03789	validation_1-rmse:0.87208
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [1]	validation_0-rmse:0.81985	validation_1-rmse:0.72309
# [2]	validation_0-rmse:0.70099	validation_1-rmse:0.61448
# [3]	validation_0-rmse:0.59894	validation_1-rmse:0.53730
# [4]	validation_0-rmse:0.50190	validation_1-rmse:0.45660
# [5]	validation_0-rmse:0.44727	validation_1-rmse:0.42075
# [6]	validation_0-rmse:0.40066	validation_1-rmse:0.37673
# [7]	validation_0-rmse:0.39073	validation_1-rmse:0.36199
# [8]	validation_0-rmse:0.35299	validation_1-rmse:0.31767
# [9]	validation_0-rmse:0.34624	validation_1-rmse:0.30820
# [10]	validation_0-rmse:0.33524	validation_1-rmse:0.29536
# [11]	validation_0-rmse:0.33237	validation_1-rmse:0.28977
# [12]	validation_0-rmse:0.32129	validation_1-rmse:0.27681
# [13]	validation_0-rmse:0.31144	validation_1-rmse:0.26721
# [14]	validation_0-rmse:0.31178	validation_1-rmse:0.26801
# [15]	validation_0-rmse:0.30328	validation_1-rmse:0.25444
# [16]	validation_0-rmse:0.29562	validation_1-rmse:0.25005
# [17]	validation_0-rmse:0.29510	validation_1-rmse:0.24844
# [18]	validation_0-rmse:0.29327	validation_1-rmse:0.25526
# [19]	validation_0-rmse:0.29099	validation_1-rmse:0.24942
# [20]	validation_0-rmse:0.28999	validation_1-rmse:0.24582
# [21]	validation_0-rmse:0.28996	validation_1-rmse:0.24564
# [22]	validation_0-rmse:0.28962	validation_1-rmse:0.24318
# [23]	validation_0-rmse:0.28970	validation_1-rmse:0.24411
# [24]	validation_0-rmse:0.28963	validation_1-rmse:0.24186
# [25]	validation_0-rmse:0.28969	validation_1-rmse:0.24398
# [26]	validation_0-rmse:0.28977	validation_1-rmse:0.24461
# [27]	validation_0-rmse:0.29005	validation_1-rmse:0.24609
# [28]	validation_0-rmse:0.28960	validation_1-rmse:0.24257
# [29]	validation_0-rmse:0.28441	validation_1-rmse:0.23191
# [30]	validation_0-rmse:0.28275	validation_1-rmse:0.22578
# [31]	validation_0-rmse:0.28265	validation_1-rmse:0.22433
# [32]	validation_0-rmse:0.28286	validation_1-rmse:0.22653
# [33]	validation_0-rmse:0.28282	validation_1-rmse:0.22624
# [34]	validation_0-rmse:0.28281	validation_1-rmse:0.22619
# [35]	validation_0-rmse:0.28281	validation_1-rmse:0.22256
# [36]	validation_0-rmse:0.28340	validation_1-rmse:0.21902
# [37]	validation_0-rmse:0.28336	validation_1-rmse:0.21840
# [38]	validation_0-rmse:0.28334	validation_1-rmse:0.21775
# [39]	validation_0-rmse:0.28377	validation_1-rmse:0.22211
# [40]	validation_0-rmse:0.28349	validation_1-rmse:0.22007
# [41]	validation_0-rmse:0.28394	validation_1-rmse:0.22307
# [42]	validation_0-rmse:0.28334	validation_1-rmse:0.21775
# [43]	validation_0-rmse:0.28363	validation_1-rmse:0.21439
# [44]	validation_0-rmse:0.28443	validation_1-rmse:0.21219
# [45]	validation_0-rmse:0.28456	validation_1-rmse:0.21197
# [46]	validation_0-rmse:0.28053	validation_1-rmse:0.20708
# [47]	validation_0-rmse:0.28011	validation_1-rmse:0.21578
# [48]	validation_0-rmse:0.28011	validation_1-rmse:0.21567
# [49]	validation_0-rmse:0.28115	validation_1-rmse:0.21302
# [50]	validation_0-rmse:0.28079	validation_1-rmse:0.21337
# [51]	validation_0-rmse:0.27625	validation_1-rmse:0.21948
# [52]	validation_0-rmse:0.27645	validation_1-rmse:0.21937
# [53]	validation_0-rmse:0.27713	validation_1-rmse:0.21925
# [54]	validation_0-rmse:0.27645	validation_1-rmse:0.21937
# [55]	validation_0-rmse:0.27570	validation_1-rmse:0.22045
# [56]	validation_0-rmse:0.27245	validation_1-rmse:0.21457
# [57]	validation_0-rmse:0.27248	validation_1-rmse:0.21440
# [58]	validation_0-rmse:0.27269	validation_1-rmse:0.21379
# [59]	validation_0-rmse:0.27280	validation_1-rmse:0.21360
# [60]	validation_0-rmse:0.27276	validation_1-rmse:0.21366
# [61]	validation_0-rmse:0.27241	validation_1-rmse:0.21496
# [62]	validation_0-rmse:0.27293	validation_1-rmse:0.21837
# [63]	validation_0-rmse:0.27360	validation_1-rmse:0.22041
# [64]	validation_0-rmse:0.27289	validation_1-rmse:0.21820
# [65]	validation_0-rmse:0.27246	validation_1-rmse:0.21614
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
# Preprocessing
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['84%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(-2.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.850
# Uncertainty
# a0: -0.035+/-0.032
# a1: 0.847+/-0.032

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: %_cover: mean - 0.205, median - 0.203, CI - [0.176-0.236]
#
# SHAP-values for: mf_chm_MAX: mean - 0.194, median - 0.195, CI - [0.166-0.225]
#
# SHAP-values for: mf_chm_MEAN: mean - 0.29, median - 0.29, CI - [0.26-0.318]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['mf_chm_MEAN', '%_cover', 'mf_chm_MAX'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_rel_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 28.85, median: 26.0,
#  pred. interval (P(0.025)-P(0.975)): 6.0-65.0,
#  conf. interval (p-value=0.95): 12.309-46.915
# ***
# Aggregate bias statistic:
#  mean: 0.013, median: 0.006,
#  pred. interval (P(0.025)-P(0.975)): -0.126-0.174,
#  conf. interval (p-value=0.95): -0.047-0.069
# ***
# Aggregate RMSE statistic:
#  mean: 0.322, median: 0.323, pred. interval (P(0.025)-P(0.975)): 0.198-0.445,
#  conf. interval (p-value=0.95): 0.27-0.375
# ***
# Aggregate MSE statistic:
#  mean: 0.108, median: 0.104, pred. interval (P(0.025)-P(0.975)): 0.039-0.198,
#  conf. interval (p-value=0.95): 0.073-0.141
# ***
# Aggregate R^2 statistic:
#  mean: 0.825, median: 0.845, pred. interval (P(0.025)-P(0.975)): 0.573-0.936,
#  conf. interval (p-value=0.95): 0.77-0.891
# ***
# Aggregate bias(%) statistic:
#  mean: 3.009, median: -1.933, pred. interval (P(0.025)-P(0.975)): -63.404-78.463,
#  conf. interval (p-value=0.95): -20.188-16.78
# ***
# Aggregate RMSE(%) statistic:
#  mean: -155.917, median: -102.62, pred. interval (P(0.025)-P(0.975)): -755.006--37.822,
#  conf. interval (p-value=0.95): -173.06--64.945
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -0.033, median: -0.025,
#  pred. interval (P(0.025)-P(0.975)): -0.227-0.135,
#  conf. interval (p-value=0.95): -0.112-0.052
# ***
# Aggregate RMSE statistic:
#  mean: 0.367, median: 0.33, pred. interval (P(0.025)-P(0.975)): 0.16-0.687,
#  conf. interval (p-value=0.95): 0.227-0.509
# ***
# Aggregate MSE statistic:
#  mean: 0.159, median: 0.109, pred. interval (P(0.025)-P(0.975)): 0.026-0.472,
#  conf. interval (p-value=0.95): 0.053-0.263
# ***
# Aggregate R^2 statistic:
#  mean: 0.607, median: 0.6, pred. interval (P(0.025)-P(0.975)): 0.322-0.879,
#  conf. interval (p-value=0.95): 0.448-0.765
# ***
# Aggregate bias(%) statistic:
#  mean: -2.683, median: -2.539, pred. interval (P(0.025)-P(0.975)): -20.031-17.006,
#  conf. interval (p-value=0.95): -11.226-5.808
# ***
# Aggregate RMSE(%) statistic:
#  mean: 37.763, median: 35.317, pred. interval (P(0.025)-P(0.975)): 18.57-62.006,
#  conf. interval (p-value=0.95): 25.465-51.375
# ***

# %% [markdown]
# # Analysis of residuals distributions dependents on empirical values of predicted parameter

# %%
# Preprocessing
results_y['T_exp_empiric'] = np.exp(results_y[predictor])
results_y['T_exp_pred'] = np.exp(results_y[0])

results_y['ln_residuals'] = results_y[predictor] - results_y[0]
results_y['T_exp_residuals'] = results_y['T_exp_empiric'] - results_y['T_exp_pred']
results_y['ln_residuals_%'] =  results_y['ln_residuals'] / results_y[predictor] * 100
results_y['T_exp_residuals_%'] = results_y['T_exp_residuals'] / results_y['T_exp_empiric'] * 100

# plt.hist(results_y[predictor])
# plt.hist(results_y[predictor])
fig, axs = plt.subplots(1, 2)
axs[0].hist(results_y[predictor])
axs[0].set_title('Logarithmically transformed data')
axs[1].hist(results_y['T_exp_empiric'], log=True)
axs[1].set_title('In typical state')
# plt.show()
# Out:
# Text(0.5, 1.0, 'In typical state')

# %%
# INPORTANT  - added your intervals
ln_intervals = pd.cut(results_y[predictor], [-3, -2, -1, 0, 1, 2])
T_exp_intervals = pd.cut(results_y['T_exp_empiric'], [0, 0.5, 1, 1.5, 2, 4])

ln_grouped = results_y.groupby(ln_intervals)
T_exp_grouped = results_y.groupby(T_exp_intervals) 

max_obs_in_group = len(results_y)    
    
pre_ln = pd.DataFrame()
pre_T_exp = pd.DataFrame()
pre_rel_ln = pd.DataFrame()
pre_rel_T_exp = pd.DataFrame()

pre_ln = pre_ln.assign(row_number=range(max_obs_in_group))
pre_T_exp = pre_T_exp.assign(row_number=range(max_obs_in_group))
pre_rel_ln = pre_rel_ln.assign(row_number=range(max_obs_in_group))
pre_rel_T_exp = pre_rel_T_exp.assign(row_number=range(max_obs_in_group))

for i in range(len(list(ln_grouped))):
    pre_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals'])
    pre_rel_ln[list(ln_grouped)[i][0]] = pd.Series(list(ln_grouped)[i][1]['ln_residuals_%'])

for i in range(len(list(T_exp_grouped))):
    pre_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals'])
    pre_rel_T_exp[list(T_exp_grouped)[i][0]] = pd.Series(list(T_exp_grouped)[i][1]['T_exp_residuals_%'])

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_ln[list(pre_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_ln[(pre_rel_ln.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of residuals versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_T_exp[list(pre_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Plots of relative residuals (in %) versus predicted values
sns.set(font_scale=1.2)
sns.violinplot(data=pre_rel_T_exp[(pre_rel_T_exp.columns)[1:]], inner="box", palette="Spectral")
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:1.01299
# [1]	validation_0-rmse:0.79014
# [2]	validation_0-rmse:0.65252
# [3]	validation_0-rmse:0.54041
# [4]	validation_0-rmse:0.45789
# [5]	validation_0-rmse:0.39697
# [6]	validation_0-rmse:0.36288
# [7]	validation_0-rmse:0.35558
# [8]	validation_0-rmse:0.34213
# [9]	validation_0-rmse:0.32777
# [10]	validation_0-rmse:0.32264
# [11]	validation_0-rmse:0.30437
# [12]	validation_0-rmse:0.29778
# [13]	validation_0-rmse:0.28983
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [14]	validation_0-rmse:0.28981
# [15]	validation_0-rmse:0.28378
# [16]	validation_0-rmse:0.27762
# [17]	validation_0-rmse:0.27917
# [18]	validation_0-rmse:0.27333
# [19]	validation_0-rmse:0.26880
# [20]	validation_0-rmse:0.26909
# [21]	validation_0-rmse:0.27037
# [22]	validation_0-rmse:0.27008
# [23]	validation_0-rmse:0.26969
# [24]	validation_0-rmse:0.26988
# [25]	validation_0-rmse:0.26517
# [26]	validation_0-rmse:0.26308
# [27]	validation_0-rmse:0.26257
# [28]	validation_0-rmse:0.26255
# [29]	validation_0-rmse:0.26255
# [30]	validation_0-rmse:0.26264
# [31]	validation_0-rmse:0.26255
# [32]	validation_0-rmse:0.26257
# [33]	validation_0-rmse:0.26258
# [34]	validation_0-rmse:0.26255
# [35]	validation_0-rmse:0.26257
# [36]	validation_0-rmse:0.26256
# [37]	validation_0-rmse:0.26272
# [38]	validation_0-rmse:0.25870
# [39]	validation_0-rmse:0.25889
# [40]	validation_0-rmse:0.25868
# [41]	validation_0-rmse:0.25415
# [42]	validation_0-rmse:0.25401
# [43]	validation_0-rmse:0.25455
# [44]	validation_0-rmse:0.25473
# [45]	validation_0-rmse:0.25447
# [46]	validation_0-rmse:0.25413
# [47]	validation_0-rmse:0.25469
# [48]	validation_0-rmse:0.25425
# [49]	validation_0-rmse:0.25380
# [50]	validation_0-rmse:0.25431
# [51]	validation_0-rmse:0.25379
# [52]	validation_0-rmse:0.25375
# [53]	validation_0-rmse:0.25384
# [54]	validation_0-rmse:0.25376
# [55]	validation_0-rmse:0.25407
# [56]	validation_0-rmse:0.25403
# [57]	validation_0-rmse:0.25254
# [58]	validation_0-rmse:0.25247
# [59]	validation_0-rmse:0.25247
# [60]	validation_0-rmse:0.25326
# [61]	validation_0-rmse:0.25276
# [62]	validation_0-rmse:0.25241
# [63]	validation_0-rmse:0.25248
# [64]	validation_0-rmse:0.25270
# [65]	validation_0-rmse:0.25256
# [66]	validation_0-rmse:0.25269
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 62

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: 0.0
# Relative bias(%):  -1.01
# RMSE: 0.3
# Relative RMSE(%):  -76.967
# MSE: 0.1
# R square: 91.4%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(-2.7, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.914
# Uncertainty
# a0: -0.028+/-0.025
# a1: 0.905+/-0.028

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=3) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [30, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../03_output_data/XGBoost_models/03_LN_MstemBark_CHM_without_RGB_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../03_output_data/XGBoost_models/03_LN_MstemBark_CHM_without_RGB_XGB_model.txt")
