# %% [markdown]
# ## Processing with aboveground biomass data based on my fieldworks and other authors

# %% [markdown]
# # Load all data from .csv file

# %%
# Import main libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import shap

# %%
# Load biomass dataset
input_data = './FULL_DB_BIOMASS_OTHER_ALL_AUTHORS.csv'
df = pd.read_csv(input_data)
df.head()
# Out:
#    Groups Species  Species_ID Origin  Origin_ID  SI  A_years   H_m  DBH_cm  \
# 0       1    Pine           0      n        0.0   4       50   9.7    14.6
# 1       1    Pine           0      n        0.0   2       65  20.6    20.6
# 2       1    Pine           0      n        0.0   2       50  13.6    15.4
# 3       1    Pine           0      n        0.0   1       60  23.3    22.2
# 4       1    Pine           0      n        0.0   3       65  15.6    16.4
#
#    N_trees  ...  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  \
# 0    486.0  ...             NaN             NaN         8.4           1.6
# 1    785.0  ...             NaN             NaN        11.5           4.1
# 2   1745.0  ...             NaN             NaN        13.7           4.1
# 3    665.0  ...             NaN             NaN        14.4           5.4
# 4    955.0  ...             NaN             NaN        14.2           3.4
#
#    LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  \
# 0         3.78              2.94                NaN                NaN
# 1         5.54              4.73                NaN                NaN
# 2         5.25              4.48                NaN                NaN
# 3         5.63              4.67                NaN                NaN
# 4         4.96              4.20                NaN                NaN
#
#    LN_Crown_t_ha  LN_Foliage_t_ha
# 0           2.13             0.47
# 1           2.44             1.41
# 2           2.62             1.41
# 3           2.67             1.69
# 4           2.65             1.22
#
# [5 rows x 24 columns]

# %% [markdown]
# # List of all parameters for est. of bioproductivity and RN content
# """
#
# All parameters:
#
# 'Groups','Species_ID','Origin_ID','SI','A_years','H_m','DBH_cm','RS(P)',          'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
# 'Crown_t_ha','Foliage_t_ha'
# 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'
#
# """

# %%
# Selecting main working parameters
select = pd.DataFrame(df, columns=['Species_ID','Origin_ID','H_m','DBH_cm', 'BA_sq_m_ha','GS_cub_m','ALL_STEM_t_ha','Stem_wood_t_ha','Stem_bark_t_ha',
'Crown_t_ha','Foliage_t_ha', 'LN_GS_cub_m', 'LN_ALL_STEM_t_ha', 'LN_Stem_wood_t_ha', 'LN_Stem_bark_t_ha', 'LN_Crown_t_ha', 'LN_Foliage_t_ha'])
            
'''
In "Species_ID" column: "0" is Pine, "1" is Spruce, "2" is Birch, "3" is Alder, "4" is Aspen, "5" is Oak
In "Origin_ID" column: "0.0" is nutural stand, "1.0" is artificial stand
'''

# Show the first five columns
select.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0           0        0.0   9.7    14.6         9.7      43.9           18.9
# 1           0        0.0  20.6    20.6        32.2     254.0          113.1
# 2           0        0.0  13.6    15.4        35.2     190.0           87.8
# 3           0        0.0  23.3    22.2        29.6     277.7          106.5
# 4           0        0.0  15.6    16.4        20.4     142.5           67.0
#
#    Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0             NaN             NaN         8.4           1.6         3.78
# 1             NaN             NaN        11.5           4.1         5.54
# 2             NaN             NaN        13.7           4.1         5.25
# 3             NaN             NaN        14.4           5.4         5.63
# 4             NaN             NaN        14.2           3.4         4.96
#
#    LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0              2.94                NaN                NaN           2.13
# 1              4.73                NaN                NaN           2.44
# 2              4.48                NaN                NaN           2.62
# 3              4.67                NaN                NaN           2.67
# 4              4.20                NaN                NaN           2.65
#
#    LN_Foliage_t_ha
# 0             0.47
# 1             1.41
# 2             1.41
# 3             1.69
# 4             1.22

# %% [markdown]
# # Pre-analysis of parameters

# %%
# Information on all columns of data frame
select.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857 entries, 0 to 856
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Species_ID         857 non-null    int64
#  1   Origin_ID          856 non-null    float64
#  2   H_m                857 non-null    float64
#  3   DBH_cm             856 non-null    float64
#  4   BA_sq_m_ha         857 non-null    float64
#  5   GS_cub_m           857 non-null    float64
#  6   ALL_STEM_t_ha      855 non-null    float64
#  7   Stem_wood_t_ha     747 non-null    float64
#  8   Stem_bark_t_ha     747 non-null    float64
#  9   Crown_t_ha         843 non-null    float64
#  10  Foliage_t_ha       854 non-null    float64
#  11  LN_GS_cub_m        857 non-null    float64
#  12  LN_ALL_STEM_t_ha   855 non-null    float64
#  13  LN_Stem_wood_t_ha  747 non-null    float64
#  14  LN_Stem_bark_t_ha  747 non-null    float64
#  15  LN_Crown_t_ha      843 non-null    float64
#  16  LN_Foliage_t_ha    854 non-null    float64
# dtypes: float64(16), int64(1)
# memory usage: 113.9 KB

# %%
# Discribe statistic of forest sites by species and origin
df.groupby(["Species_ID"])["LN_GS_cub_m", "ALL_STEM_t_ha"].describe()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            LN_GS_cub_m                                                         \
#                  count      mean       std   min     25%    50%     75%   max
# Species_ID
# 0                458.0  5.192052  0.897136  0.88  4.8350  5.415  5.8075  6.60
# 1                  7.0  5.490000  0.589463  4.65  5.0350  5.700  5.9650  6.08
# 2                120.0  4.741667  0.702628  2.31  4.2150  4.855  5.3025  5.92
# 3                115.0  5.345478  0.624346  3.32  4.9250  5.500  5.8000  6.31
# 4                 66.0  5.057273  0.732497  3.05  4.6175  5.010  5.6675  6.26
# 5                 91.0  5.430220  0.830515  2.20  5.0700  5.610  6.0300  6.40
#
#            ALL_STEM_t_ha                                                       \
#                    count        mean        std   min     25%    50%      75%
# Species_ID
# 0                  457.0   97.049891  61.854506   1.8  47.500   92.7  135.900
# 1                    7.0  123.814286  61.879895  46.3  70.650  133.9  174.550
# 2                  120.0   74.495000  44.523333   5.1  37.275   68.1  103.075
# 3                  115.0  107.607826  55.589186  11.0  62.700  106.8  145.450
# 4                   66.0   84.946970  58.875162   8.2  40.750   61.2  125.000
# 5                   90.0  173.065556  99.100647   5.0  93.075  161.3  253.375
#
#
#               max
# Species_ID
# 0           310.7
# 1           196.1
# 2           193.5
# 3           251.6
# 4           245.4
# 5           363.9

# %%
# Descriptive statistics of main parameters
select.describe()
# Out:
#        Species_ID   Origin_ID         H_m      DBH_cm  BA_sq_m_ha    GS_cub_m  \
# count  857.000000  856.000000  857.000000  856.000000  857.000000  857.000000
# mean     1.529755    0.279206   16.452275   17.132243   26.329988  229.013069
# std      1.823872    0.448871    7.039954   10.439115   10.629993  144.362106
# min      0.000000    0.000000    1.500000    1.100000    1.000000    2.400000
# 25%      0.000000    0.000000   11.200000    9.900000   19.000000  116.000000
# 50%      0.000000    0.000000   16.100000   15.500000   26.800000  206.000000
# 75%      3.000000    1.000000   21.200000   22.100000   34.500000  320.000000
# max      5.000000    1.000000   38.300000   94.000000   51.500000  735.000000
#
#        ALL_STEM_t_ha  Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  \
# count     855.000000      747.000000      747.000000  843.000000
# mean      102.590877       92.779518       12.060107   13.821969
# std        68.758819       61.992238        9.595428   11.567546
# min         1.800000        2.000000        0.300000    0.500000
# 25%        47.500000       42.900000        5.950000    6.610000
# 50%        93.500000       84.600000        9.300000   10.820000
# 75%       140.500000      125.500000       15.300000   16.435000
# max       363.900000      315.200000       65.700000   69.120000
#
#        Foliage_t_ha  LN_GS_cub_m  LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  \
# count    854.000000   857.000000        855.000000         747.000000
# mean       4.749356     5.166919          4.343766           4.246975
# std        2.826586     0.839680          0.869479           0.854856
# min        0.200000     0.880000          0.590000           0.690000
# 25%        2.600000     4.750000          3.860000           3.760000
# 50%        4.300000     5.330000          4.540000           4.440000
# 75%        6.367500     5.770000          4.950000           4.830000
# max       21.730000     6.600000          5.900000           5.750000
#
#        LN_Stem_bark_t_ha  LN_Crown_t_ha  LN_Foliage_t_ha
# count         747.000000     843.000000       854.000000
# mean            2.201232       2.318149         1.364906
# std             0.806766       0.829446         0.672551
# min            -1.200000      -0.690000        -1.610000
# 25%             1.780000       1.890000         0.960000
# 50%             2.230000       2.380000         1.460000
# 75%             2.730000       2.800000         1.850000
# max             4.190000       4.240000         3.080000

# %% [markdown]
# # Selecting working columns for the XGBoost algorithms

# %%
# Choosing the predictor and independent variables
predictor = "LN_ALL_STEM_t_ha"
indep_variables = ['Species_ID','Origin_ID','H_m','DBH_cm','BA_sq_m_ha']

# %%
# Delete empty rows from the working column in a dataframe
nan_value = float("NaN")
select.replace("", nan_value, inplace=True)
select.dropna(subset = [predictor], inplace=True) # IMPOTANT - input name of column
print(select)
# Out:
#      Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha  GS_cub_m  ALL_STEM_t_ha  \
# 0             0        0.0   9.7    14.6         9.7      43.9           18.9
# 1             0        0.0  20.6    20.6        32.2     254.0          113.1
# 2             0        0.0  13.6    15.4        35.2     190.0           87.8
# 3             0        0.0  23.3    22.2        29.6     277.7          106.5
# 4             0        0.0  15.6    16.4        20.4     142.5           67.0
# ..          ...        ...   ...     ...         ...       ...            ...
# 852           3        0.0   7.8     4.4         9.2      39.8           17.8
# 853           3        0.0  12.7     9.0        20.5     123.6           47.1
# 854           3        0.0  12.2     8.1        20.3     141.7           51.9
# 855           2        0.0  14.3    12.4        25.1     176.5          100.7
# 856           2        0.0  21.1    25.6        21.0     191.6           99.9
#
#      Stem_wood_t_ha  Stem_bark_t_ha  Crown_t_ha  Foliage_t_ha  LN_GS_cub_m  \
# 0               NaN             NaN        8.40          1.60         3.78
# 1               NaN             NaN       11.50          4.10         5.54
# 2               NaN             NaN       13.70          4.10         5.25
# 3               NaN             NaN       14.40          5.40         5.63
# 4               NaN             NaN       14.20          3.40         4.96
# ..              ...             ...         ...           ...          ...
# 852            15.7             2.1        2.26          2.04         3.68
# 853            42.6             4.5        2.14          1.21         4.82
# 854            47.8             4.1        2.11          1.16         4.95
# 855            84.6            16.1       16.90          4.74         5.17
# 856            80.8            19.1       16.60          2.13         5.26
#
#      LN_ALL_STEM_t_ha  LN_Stem_wood_t_ha  LN_Stem_bark_t_ha  LN_Crown_t_ha  \
# 0                2.94                NaN                NaN           2.13
# 1                4.73                NaN                NaN           2.44
# 2                4.48                NaN                NaN           2.62
# 3                4.67                NaN                NaN           2.67
# 4                4.20                NaN                NaN           2.65
# ..                ...                ...                ...            ...
# 852              2.88               2.75               0.74           0.82
# 853              3.85               3.75               1.50           0.76
# 854              3.95               3.87               1.41           0.75
# 855              4.61               4.44               2.78           2.83
# 856              4.60               4.39               2.95           2.81
#
#      LN_Foliage_t_ha
# 0               0.47
# 1               1.41
# 2               1.41
# 3               1.69
# 4               1.22
# ..               ...
# 852             0.71
# 853             0.19
# 854             0.15
# 855             1.56
# 856             0.76
#
# [855 rows x 17 columns]

# %%
# We select independent variables and predicting parameter 
X = pd.DataFrame(select, columns=indep_variables)
y = pd.DataFrame(select, columns=[predictor])

# %%
# Columns in "X" data collections
X.head()
# Out:
#    Species_ID  Origin_ID   H_m  DBH_cm  BA_sq_m_ha
# 0           0        0.0   9.7    14.6         9.7
# 1           0        0.0  20.6    20.6        32.2
# 2           0        0.0  13.6    15.4        35.2
# 3           0        0.0  23.3    22.2        29.6
# 4           0        0.0  15.6    16.4        20.4

# %%
# Columns in "y" data collections
y.head()
# Out:
#    LN_ALL_STEM_t_ha
# 0              2.94
# 1              4.73
# 2              4.48
# 3              4.67
# 4              4.20

# %% [markdown]
# # Create first XGBoost model for estimate varibiality of output stats

# %%
#  Importing the main library for building model and its analysis
import xgboost as xgb
from scipy.stats import uniform, randint
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold, RandomizedSearchCV, train_test_split
from sklearn.datasets import make_classification

# %%
# K-Folds cross-validation for estimation "quality" of input data for building model
X_kfold = pd.DataFrame(X).to_numpy()
y_kfold = pd.DataFrame(y).to_numpy()

# %%
# Function for comparing datasets on homogeneity 
def display_scores(scores):
    print("    Scores: {0}\n    Mean: {1:.3f}\n    Std: {2:.3f}".format(scores, np.mean(scores), np.std(scores)))

# %%
# Output results of K-Folds cross-validation for XGBoost model
kfold = KFold(n_splits=3, shuffle=True)
scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(r2_score(y_test, y_pred))
    
print('R square (R2): \n')
display_scores((scores))
print('\n', 20*'-')


scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
      
    scores.append(mean_squared_error(y_test, y_pred))
    
print('Root-mean-square error (RMSE): \n')
display_scores(np.sqrt(scores))
print('\n', 20*'-')

scores = []
for train_index, test_index in kfold.split(X_kfold):   
    X_train, X_test = X_kfold[train_index], X_kfold[test_index]
    y_train, y_test = y_kfold[train_index], y_kfold[test_index]

    xgb_model = xgb.XGBRegressor(objective="reg:squarederror")
    xgb_model.fit(X_train, y_train)
    
    y_pred = xgb_model.predict(X_test)
    
    scores.append(mean_absolute_error(y_test, y_pred))

print('Mean absolute error (MAE): \n')
display_scores((scores))
print('\n', 20*'-')
# Out:
# R square (R2):
#
#     Scores: [0.9458698354892303, 0.9611497137309991, 0.960052365010866]
#     Mean: 0.956
#     Std: 0.007
#
#  --------------------
# Root-mean-square error (RMSE):
#
#     Scores: [0.19306379 0.19642109 0.1722032 ]
#     Mean: 0.187
#     Std: 0.011
#
#  --------------------
# Mean absolute error (MAE):
#
#     Scores: [0.11447030525040208, 0.12043736742253885, 0.12279052981995697]
#     Mean: 0.119
#     Std: 0.004
#
#  --------------------

# %% [markdown]
# # Add optimal hyperparameters for XGBoost model

# %%
# Hyperparameters data for the next step/stage
p1 = 0.8944536735419889                 # colsample_bytree
print('Colsample_bytree: ' + str(p1))

p2 = 0.04791876153524799                # gamma
print('Gamma: ' + str(p2))

p3 = 0.10132522643422313                 # learning_rate
print('Learning_rate: ' + str(p3))

p4 = 3            # max_depth
print('Max_depth: ' + str(p4))

p5 = 108         # n_estimators
print('N_estimators: ' + str(p5))

p6 = 0.7379908073261374                  # subsample
print('Subsample: ' + str(p6))
# Out:
# Colsample_bytree: 0.8944536735419889
# Gamma: 0.04791876153524799
# Learning_rate: 0.10132522643422313
# Max_depth: 3
# N_estimators: 108
# Subsample: 0.7379908073261374

# %% [markdown]
# # Estimation of predictive quality to basic XGBoost models using Loops

# %%
# Create DMatrix (is an internal data structure) 
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
# Aggregate parameters
aggr_y=[]
aggr_y_pred=[]

aggr_optimal_n=[]
aggr_bias=[]
aggr_rel_bias=[]
aggr_rmse=[]
aggr_rel_rmse=[]
aggr_mse=[]
aggr_R_square=[]

exp_aggr_optimal_n=[]
exp_aggr_bias=[]
exp_aggr_rel_bias=[]
exp_aggr_rmse=[]
exp_aggr_rel_rmse=[]
exp_aggr_mse=[]
exp_aggr_R_square=[]

aggr_Shap_values=pd.DataFrame()

# Body loop
for i in range(200):
    
    # Generate test and training samples
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    #exp_y_train = np.exp(y_train)
    exp_y_test = np.exp(y_test)
    
    # Implementation of the scikit-learn API for XGBoost regression
    xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])
    
    # Fitting the model 
    xgb_model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_train, y_train), (X_test, y_test)])
    
    # learning dynamics
    y_pred = xgb_model.predict(X_test, ntree_limit=xgb_model.best_ntree_limit)
    
    exp_y_pred = np.exp(y_pred)
    
    # Iteration with the best result
    optimal_n= xgb_model.best_ntree_limit-1
    
    # Convert data to 'array' type
    conv_y_pred = pd.DataFrame(y_pred) # Double transformation
    y_pred2 = conv_y_pred.values
    y_test2 = y_test.values
    
    exp_y_pred2 = np.exp(y_pred2)
    exp_y_test2 = np.exp(y_test2)
    
    # Intermediate results
    n_sample = len(y_pred2)
    y_mean_sample = y_test.sum() / n_sample
    
    exp_y_mean_sample = exp_y_test.sum() / n_sample
    
    # Calculation of bias
    diff = y_pred2 - y_test2
    bias = diff.sum()/n_sample
    rel_bias = bias/y_mean_sample*100
    
    exp_diff = exp_y_pred2 - exp_y_test2
    exp_bias = exp_diff.sum()/n_sample
    exp_rel_bias = exp_bias/exp_y_mean_sample*100
    
    # Calculation of RMSE
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rel_rmse = rmse/y_mean_sample*100 
    
    exp_rmse = np.sqrt(mean_squared_error(exp_y_test, exp_y_pred))
    exp_rel_rmse = exp_rmse/exp_y_mean_sample*100 
    
    # Calculation of MSE
    mse = mean_squared_error(y_test, y_pred)   
    
    exp_mse = mean_squared_error(exp_y_test, exp_y_pred)
    
    # Calculation of Square R
    R_square = r2_score(y_test, y_pred)
    
    exp_R_square = r2_score(exp_y_test, exp_y_pred)
    
    #Calculation of SHAP-values
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_train)
    vals= np.abs(shap_values).mean(0)
    feature_importance = pd.DataFrame(list(zip(X_train.columns,vals)),columns=['Feature','Importance'])
       
    
    #Add values to lists
    aggr_y.append(y_test)
    aggr_y_pred.append(conv_y_pred)
    
    aggr_optimal_n.append(optimal_n)
    aggr_bias.append(bias)
    aggr_rel_bias.append(rel_bias)
    aggr_rmse.append(rmse)
    aggr_rel_rmse.append(rel_rmse)
    aggr_mse.append(mse)
    aggr_R_square.append(R_square)
    
    exp_aggr_bias.append(exp_bias)
    exp_aggr_rel_bias.append(exp_rel_bias)
    exp_aggr_rmse.append(exp_rmse)
    exp_aggr_rel_rmse.append(exp_rel_rmse)
    exp_aggr_mse.append(exp_mse)
    exp_aggr_R_square.append(exp_R_square)
    
    aggr_Shap_values = aggr_Shap_values.append(feature_importance, ignore_index=True)
    
# Intermedia data to calculate CI
n_train = len(y_train)
n_test = len(y_test)
# Out:
# [0]	validation_0-rmse:3.55337	validation_1-rmse:3.52771
# [1]	validation_0-rmse:3.19948	validation_1-rmse:3.17579
# [2]	validation_0-rmse:2.88195	validation_1-rmse:2.86027
# [3]	validation_0-rmse:2.59644	validation_1-rmse:2.57281
# [4]	validation_0-rmse:2.33726	validation_1-rmse:2.31374
# [5]	validation_0-rmse:2.10616	validation_1-rmse:2.08356
# [6]	validation_0-rmse:1.89808	validation_1-rmse:1.87444
# [7]	validation_0-rmse:1.71340	validation_1-rmse:1.69044
# [8]	validation_0-rmse:1.54528	validation_1-rmse:1.52095
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [9]	validation_0-rmse:1.39412	validation_1-rmse:1.36884
# [10]	validation_0-rmse:1.25833	validation_1-rmse:1.23347
# [11]	validation_0-rmse:1.13540	validation_1-rmse:1.11111
# [12]	validation_0-rmse:1.02558	validation_1-rmse:1.00193
# [13]	validation_0-rmse:0.92656	validation_1-rmse:0.90480
# [14]	validation_0-rmse:0.83744	validation_1-rmse:0.81589
# [15]	validation_0-rmse:0.75778	validation_1-rmse:0.73744
# [16]	validation_0-rmse:0.68622	validation_1-rmse:0.66717
# [17]	validation_0-rmse:0.62213	validation_1-rmse:0.60448
# [18]	validation_0-rmse:0.56505	validation_1-rmse:0.54929
# [19]	validation_0-rmse:0.51461	validation_1-rmse:0.50081
# [20]	validation_0-rmse:0.46997	validation_1-rmse:0.45852
# [21]	validation_0-rmse:0.42857	validation_1-rmse:0.41881
# [22]	validation_0-rmse:0.39230	validation_1-rmse:0.38453
# [23]	validation_0-rmse:0.35999	validation_1-rmse:0.35466
# [24]	validation_0-rmse:0.33159	validation_1-rmse:0.32876
# [25]	validation_0-rmse:0.30632	validation_1-rmse:0.30570
# [26]	validation_0-rmse:0.28342	validation_1-rmse:0.28530
# [27]	validation_0-rmse:0.26367	validation_1-rmse:0.26879
# [28]	validation_0-rmse:0.24595	validation_1-rmse:0.25393
# [29]	validation_0-rmse:0.23074	validation_1-rmse:0.24150
# [30]	validation_0-rmse:0.21799	validation_1-rmse:0.23170
# [31]	validation_0-rmse:0.20648	validation_1-rmse:0.22333
# [32]	validation_0-rmse:0.19631	validation_1-rmse:0.21551
# [33]	validation_0-rmse:0.18752	validation_1-rmse:0.20902
# [34]	validation_0-rmse:0.18033	validation_1-rmse:0.20449
# [35]	validation_0-rmse:0.17378	validation_1-rmse:0.20016
# [36]	validation_0-rmse:0.16821	validation_1-rmse:0.19641
# [37]	validation_0-rmse:0.16348	validation_1-rmse:0.19354
# [38]	validation_0-rmse:0.15970	validation_1-rmse:0.19132
# [39]	validation_0-rmse:0.15615	validation_1-rmse:0.18987
# [40]	validation_0-rmse:0.15323	validation_1-rmse:0.18858
# [41]	validation_0-rmse:0.15039	validation_1-rmse:0.18729
# [42]	validation_0-rmse:0.14849	validation_1-rmse:0.18683
# [43]	validation_0-rmse:0.14681	validation_1-rmse:0.18571
# [44]	validation_0-rmse:0.14511	validation_1-rmse:0.18497
# [45]	validation_0-rmse:0.14361	validation_1-rmse:0.18436
# [46]	validation_0-rmse:0.14220	validation_1-rmse:0.18395
# [47]	validation_0-rmse:0.14074	validation_1-rmse:0.18324
# [48]	validation_0-rmse:0.13963	validation_1-rmse:0.18296
# [49]	validation_0-rmse:0.13845	validation_1-rmse:0.18226
# [50]	validation_0-rmse:0.13766	validation_1-rmse:0.18243
# [51]	validation_0-rmse:0.13661	validation_1-rmse:0.18225
# [52]	validation_0-rmse:0.13602	validation_1-rmse:0.18219
# [53]	validation_0-rmse:0.13540	validation_1-rmse:0.18211
# [54]	validation_0-rmse:0.13466	validation_1-rmse:0.18173
# [55]	validation_0-rmse:0.13403	validation_1-rmse:0.18170
# [56]	validation_0-rmse:0.13331	validation_1-rmse:0.18145
# [57]	validation_0-rmse:0.13291	validation_1-rmse:0.18153
# [58]	validation_0-rmse:0.13246	validation_1-rmse:0.18122
# [59]	validation_0-rmse:0.13161	validation_1-rmse:0.18081
# [60]	validation_0-rmse:0.13102	validation_1-rmse:0.18088
# [61]	validation_0-rmse:0.13045	validation_1-rmse:0.18075
# [62]	validation_0-rmse:0.13022	validation_1-rmse:0.18080
# [63]	validation_0-rmse:0.12992	validation_1-rmse:0.18083
# [64]	validation_0-rmse:0.12961	validation_1-rmse:0.18083
# [65]	validation_0-rmse:0.12915	validation_1-rmse:0.18134
# [66]	validation_0-rmse:0.12893	validation_1-rmse:0.18166
# [67]	validation_0-rmse:0.12866	validation_1-rmse:0.18183
# [68]	validation_0-rmse:0.12832	validation_1-rmse:0.18145
# [69]	validation_0-rmse:0.12766	validation_1-rmse:0.18153
# [70]	validation_0-rmse:0.12744	validation_1-rmse:0.18151
# [71]	validation_0-rmse:0.12707	validation_1-rmse:0.18138
# [72]	validation_0-rmse:0.12616	validation_1-rmse:0.18128
# [73]	validation_0-rmse:0.12574	validation_1-rmse:0.18123
# [74]	validation_0-rmse:0.12537	validation_1-rmse:0.18081
# [75]	validation_0-rmse:0.12513	validation_1-rmse:0.18063
# [76]	validation_0-rmse:0.12475	validation_1-rmse:0.18070
# [77]	validation_0-rmse:0.12450	validation_1-rmse:0.18115
# [78]	validation_0-rmse:0.12426	validation_1-rmse:0.18125
# [79]	validation_0-rmse:0.12399	validation_1-rmse:0.18126
# [80]	validation_0-rmse:0.12336	validation_1-rmse:0.18100
# [81]	validation_0-rmse:0.12310	validation_1-rmse:0.18130
# [82]	validation_0-rmse:0.12275	validation_1-rmse:0.18132
# [83]	validation_0-rmse:0.12259	validation_1-rmse:0.18141
# [84]	validation_0-rmse:0.12219	validation_1-rmse:0.18113
# [85]	validation_0-rmse:0.12219	validation_1-rmse:0.18116
# [86]	validation_0-rmse:0.12219	validation_1-rmse:0.18119
# [87]	validation_0-rmse:0.12182	validation_1-rmse:0.18080
# [88]	validation_0-rmse:0.12149	validation_1-rmse:0.18076
# [89]	validation_0-rmse:0.12131	validation_1-rmse:0.18060
# [90]	validation_0-rmse:0.12102	validation_1-rmse:0.18055
# [91]	validation_0-rmse:0.12049	validation_1-rmse:0.18087
# [92]	validation_0-rmse:0.12003	validation_1-rmse:0.18149
# [93]	validation_0-rmse:0.11999	validation_1-rmse:0.18148
# [94]	validation_0-rmse:0.11972	validation_1-rmse:0.18129
# [95]	validation_0-rmse:0.11915	validation_1-rmse:0.18137
# [96]	validation_0-rmse:0.11910	validation_1-rmse:0.18125
# [97]	validation_0-rmse:0.11879	validation_1-rmse:0.18087
# [98]	validation_0-rmse:0.11863	validation_1-rmse:0.18076
# [99]	validation_0-rmse:0.11822	validation_1-rmse:0.18039
# [100]	validation_0-rmse:0.11803	validation_1-rmse:0.18028
# [101]	validation_0-rmse:0.11793	validation_1-rmse:0.18036
# [102]	validation_0-rmse:0.11764	validation_1-rmse:0.18039
# [103]	validation_0-rmse:0.11738	validation_1-rmse:0.18034
# [104]	validation_0-rmse:0.11696	validation_1-rmse:0.18065
# [105]	validation_0-rmse:0.11696	validation_1-rmse:0.18066
# [106]	validation_0-rmse:0.11681	validation_1-rmse:0.18054
# [107]	validation_0-rmse:0.11681	validation_1-rmse:0.18053
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:3.53762	validation_1-rmse:3.59143
# [1]	validation_0-rmse:3.18469	validation_1-rmse:3.23780
# [2]	validation_0-rmse:2.86822	validation_1-rmse:2.91762
# [3]	validation_0-rmse:2.58384	validation_1-rmse:2.63075
# [4]	validation_0-rmse:2.32776	validation_1-rmse:2.37074
# [5]	validation_0-rmse:2.09771	validation_1-rmse:2.13415
# [6]	validation_0-rmse:1.88988	validation_1-rmse:1.92474
# [7]	validation_0-rmse:1.70525	validation_1-rmse:1.73708
# [8]	validation_0-rmse:1.53853	validation_1-rmse:1.56798
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [9]	validation_0-rmse:1.38780	validation_1-rmse:1.41510
# [10]	validation_0-rmse:1.25266	validation_1-rmse:1.27815
# [11]	validation_0-rmse:1.13099	validation_1-rmse:1.15506
# [12]	validation_0-rmse:1.02162	validation_1-rmse:1.04362
# [13]	validation_0-rmse:0.92292	validation_1-rmse:0.94410
# [14]	validation_0-rmse:0.83477	validation_1-rmse:0.85443
# [15]	validation_0-rmse:0.75613	validation_1-rmse:0.77393
# [16]	validation_0-rmse:0.68555	validation_1-rmse:0.70272
# [17]	validation_0-rmse:0.62289	validation_1-rmse:0.64051
# [18]	validation_0-rmse:0.56466	validation_1-rmse:0.58097
# [19]	validation_0-rmse:0.51493	validation_1-rmse:0.53105
# [20]	validation_0-rmse:0.46999	validation_1-rmse:0.48646
# [21]	validation_0-rmse:0.42834	validation_1-rmse:0.44636
# [22]	validation_0-rmse:0.39161	validation_1-rmse:0.40974
# [23]	validation_0-rmse:0.35997	validation_1-rmse:0.37884
# [24]	validation_0-rmse:0.33186	validation_1-rmse:0.35124
# [25]	validation_0-rmse:0.30759	validation_1-rmse:0.32684
# [26]	validation_0-rmse:0.28594	validation_1-rmse:0.30532
# [27]	validation_0-rmse:0.26628	validation_1-rmse:0.28655
# [28]	validation_0-rmse:0.24885	validation_1-rmse:0.26966
# [29]	validation_0-rmse:0.23392	validation_1-rmse:0.25549
# [30]	validation_0-rmse:0.22116	validation_1-rmse:0.24308
# [31]	validation_0-rmse:0.20998	validation_1-rmse:0.23305
# [32]	validation_0-rmse:0.20031	validation_1-rmse:0.22463
# [33]	validation_0-rmse:0.19193	validation_1-rmse:0.21683
# [34]	validation_0-rmse:0.18491	validation_1-rmse:0.21001
# [35]	validation_0-rmse:0.17859	validation_1-rmse:0.20339
# [36]	validation_0-rmse:0.17316	validation_1-rmse:0.19824
# [37]	validation_0-rmse:0.16860	validation_1-rmse:0.19375
# [38]	validation_0-rmse:0.16506	validation_1-rmse:0.19146
# [39]	validation_0-rmse:0.16169	validation_1-rmse:0.18821
# [40]	validation_0-rmse:0.15887	validation_1-rmse:0.18627
# [41]	validation_0-rmse:0.15632	validation_1-rmse:0.18373
# [42]	validation_0-rmse:0.15439	validation_1-rmse:0.18176
# [43]	validation_0-rmse:0.15245	validation_1-rmse:0.18037
# [44]	validation_0-rmse:0.15073	validation_1-rmse:0.17915
# [45]	validation_0-rmse:0.14930	validation_1-rmse:0.17868
# [46]	validation_0-rmse:0.14791	validation_1-rmse:0.17858
# [47]	validation_0-rmse:0.14655	validation_1-rmse:0.17763
# [48]	validation_0-rmse:0.14541	validation_1-rmse:0.17720
# [49]	validation_0-rmse:0.14431	validation_1-rmse:0.17652
# [50]	validation_0-rmse:0.14353	validation_1-rmse:0.17607
# [51]	validation_0-rmse:0.14266	validation_1-rmse:0.17552
# [52]	validation_0-rmse:0.14191	validation_1-rmse:0.17447
# [53]	validation_0-rmse:0.14098	validation_1-rmse:0.17365
# [54]	validation_0-rmse:0.14026	validation_1-rmse:0.17338
# [55]	validation_0-rmse:0.13908	validation_1-rmse:0.17298
# [56]	validation_0-rmse:0.13857	validation_1-rmse:0.17229
# [57]	validation_0-rmse:0.13805	validation_1-rmse:0.17249
# [58]	validation_0-rmse:0.13763	validation_1-rmse:0.17228
# [59]	validation_0-rmse:0.13716	validation_1-rmse:0.17228
# [60]	validation_0-rmse:0.13655	validation_1-rmse:0.17135
# [61]	validation_0-rmse:0.13589	validation_1-rmse:0.17107
# [62]	validation_0-rmse:0.13545	validation_1-rmse:0.17072
# [63]	validation_0-rmse:0.13509	validation_1-rmse:0.17157
# [64]	validation_0-rmse:0.13465	validation_1-rmse:0.17168
# [65]	validation_0-rmse:0.13422	validation_1-rmse:0.17218
# [66]	validation_0-rmse:0.13395	validation_1-rmse:0.17233
# [67]	validation_0-rmse:0.13356	validation_1-rmse:0.17236
# [68]	validation_0-rmse:0.13297	validation_1-rmse:0.17240
# [69]	validation_0-rmse:0.13251	validation_1-rmse:0.17211
# [70]	validation_0-rmse:0.13215	validation_1-rmse:0.17270
# [71]	validation_0-rmse:0.13144	validation_1-rmse:0.17252
# [72]	validation_0-rmse:0.13113	validation_1-rmse:0.17215
# [73]	validation_0-rmse:0.13046	validation_1-rmse:0.17127
# [74]	validation_0-rmse:0.13028	validation_1-rmse:0.17130
# [75]	validation_0-rmse:0.12988	validation_1-rmse:0.17114
# [76]	validation_0-rmse:0.12938	validation_1-rmse:0.17110
# [77]	validation_0-rmse:0.12913	validation_1-rmse:0.17134
# [78]	validation_0-rmse:0.12900	validation_1-rmse:0.17143
# [79]	validation_0-rmse:0.12866	validation_1-rmse:0.17119
# [80]	validation_0-rmse:0.12855	validation_1-rmse:0.17075
# [81]	validation_0-rmse:0.12819	validation_1-rmse:0.17089
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:3.55334	validation_1-rmse:3.51810
# [1]	validation_0-rmse:3.19995	validation_1-rmse:3.16992
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [2]	validation_0-rmse:2.88073	validation_1-rmse:2.85451
# [3]	validation_0-rmse:2.59534	validation_1-rmse:2.56774
# [4]	validation_0-rmse:2.33846	validation_1-rmse:2.31490
# [5]	validation_0-rmse:2.10634	validation_1-rmse:2.08443
# [6]	validation_0-rmse:1.89776	validation_1-rmse:1.87698
# [7]	validation_0-rmse:1.71119	validation_1-rmse:1.68949
# [8]	validation_0-rmse:1.54287	validation_1-rmse:1.52143
# [9]	validation_0-rmse:1.39135	validation_1-rmse:1.37316
# [10]	validation_0-rmse:1.25511	validation_1-rmse:1.23923
# [11]	validation_0-rmse:1.13314	validation_1-rmse:1.11971
# [12]	validation_0-rmse:1.02329	validation_1-rmse:1.01008
# [13]	validation_0-rmse:0.92468	validation_1-rmse:0.91391
# [14]	validation_0-rmse:0.83578	validation_1-rmse:0.82551
# [15]	validation_0-rmse:0.75663	validation_1-rmse:0.74819
# [16]	validation_0-rmse:0.68539	validation_1-rmse:0.67773
# [17]	validation_0-rmse:0.62171	validation_1-rmse:0.61637
# [18]	validation_0-rmse:0.56476	validation_1-rmse:0.56146
# [19]	validation_0-rmse:0.51367	validation_1-rmse:0.51304
# [20]	validation_0-rmse:0.46870	validation_1-rmse:0.46988
# [21]	validation_0-rmse:0.42775	validation_1-rmse:0.43189
# [22]	validation_0-rmse:0.39104	validation_1-rmse:0.39693
# [23]	validation_0-rmse:0.35903	validation_1-rmse:0.36682
# [24]	validation_0-rmse:0.33098	validation_1-rmse:0.34147
# [25]	validation_0-rmse:0.30552	validation_1-rmse:0.31895
# [26]	validation_0-rmse:0.28307	validation_1-rmse:0.29795
# [27]	validation_0-rmse:0.26257	validation_1-rmse:0.28034
# [28]	validation_0-rmse:0.24537	validation_1-rmse:0.26581
# [29]	validation_0-rmse:0.22973	validation_1-rmse:0.25276
# [30]	validation_0-rmse:0.21707	validation_1-rmse:0.24272
# [31]	validation_0-rmse:0.20529	validation_1-rmse:0.23356
# [32]	validation_0-rmse:0.19545	validation_1-rmse:0.22565
# [33]	validation_0-rmse:0.18684	validation_1-rmse:0.21908
# [34]	validation_0-rmse:0.17949	validation_1-rmse:0.21402
# [35]	validation_0-rmse:0.17279	validation_1-rmse:0.20950
# [36]	validation_0-rmse:0.16754	validation_1-rmse:0.20599
# [37]	validation_0-rmse:0.16290	validation_1-rmse:0.20285
# [38]	validation_0-rmse:0.15866	validation_1-rmse:0.20014
# [39]	validation_0-rmse:0.15522	validation_1-rmse:0.19799
# [40]	validation_0-rmse:0.15249	validation_1-rmse:0.19619
# [41]	validation_0-rmse:0.15002	validation_1-rmse:0.19534
# [42]	validation_0-rmse:0.14823	validation_1-rmse:0.19448
# [43]	validation_0-rmse:0.14631	validation_1-rmse:0.19346
# [44]	validation_0-rmse:0.14484	validation_1-rmse:0.19270
# [45]	validation_0-rmse:0.14340	validation_1-rmse:0.19256
# [46]	validation_0-rmse:0.14195	validation_1-rmse:0.19164
# [47]	validation_0-rmse:0.14102	validation_1-rmse:0.19110
# [48]	validation_0-rmse:0.14002	validation_1-rmse:0.19081
# [49]	validation_0-rmse:0.13889	validation_1-rmse:0.19107
# [50]	validation_0-rmse:0.13763	validation_1-rmse:0.19128
# [51]	validation_0-rmse:0.13665	validation_1-rmse:0.19063
# [52]	validation_0-rmse:0.13567	validation_1-rmse:0.19054
# [53]	validation_0-rmse:0.13525	validation_1-rmse:0.19093
# [54]	validation_0-rmse:0.13462	validation_1-rmse:0.19077
# [55]	validation_0-rmse:0.13429	validation_1-rmse:0.19076
# [56]	validation_0-rmse:0.13359	validation_1-rmse:0.19003
# [57]	validation_0-rmse:0.13298	validation_1-rmse:0.19006
# [58]	validation_0-rmse:0.13246	validation_1-rmse:0.19033
# [59]	validation_0-rmse:0.13208	validation_1-rmse:0.19024
# [60]	validation_0-rmse:0.13174	validation_1-rmse:0.19014
# [61]	validation_0-rmse:0.13140	validation_1-rmse:0.19036
# [62]	validation_0-rmse:0.13100	validation_1-rmse:0.19039
# [63]	validation_0-rmse:0.13071	validation_1-rmse:0.19086
# [64]	validation_0-rmse:0.13013	validation_1-rmse:0.19075
# [65]	validation_0-rmse:0.12977	validation_1-rmse:0.19073
# [66]	validation_0-rmse:0.12935	validation_1-rmse:0.19086
# [67]	validation_0-rmse:0.12881	validation_1-rmse:0.19044
# [68]	validation_0-rmse:0.12852	validation_1-rmse:0.19039
# [69]	validation_0-rmse:0.12835	validation_1-rmse:0.19048
# [70]	validation_0-rmse:0.12812	validation_1-rmse:0.19053
# [71]	validation_0-rmse:0.12754	validation_1-rmse:0.19130
# [72]	validation_0-rmse:0.12708	validation_1-rmse:0.19156
# [73]	validation_0-rmse:0.12663	validation_1-rmse:0.19143
# [74]	validation_0-rmse:0.12621	validation_1-rmse:0.19172
# [75]	validation_0-rmse:0.12598	validation_1-rmse:0.19171
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:3.54593	validation_1-rmse:3.55371
# [1]	validation_0-rmse:3.19356	validation_1-rmse:3.19561
# [2]	validation_0-rmse:2.87718	validation_1-rmse:2.87555
# [3]	validation_0-rmse:2.59296	validation_1-rmse:2.59032
# [4]	validation_0-rmse:2.33520	validation_1-rmse:2.33492
# [5]	validation_0-rmse:2.10402	validation_1-rmse:2.10253
# [6]	validation_0-rmse:1.89696	validation_1-rmse:1.89330
# [7]	validation_0-rmse:1.70940	validation_1-rmse:1.70279
# [8]	validation_0-rmse:1.54203	validation_1-rmse:1.53400
# [9]	validation_0-rmse:1.39078	validation_1-rmse:1.38263
# [10]	validation_0-rmse:1.25356	validation_1-rmse:1.24529
# [11]	validation_0-rmse:1.13167	validation_1-rmse:1.12556
# [12]	validation_0-rmse:1.02266	validation_1-rmse:1.01657
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [13]	validation_0-rmse:0.92477	validation_1-rmse:0.91816
# [14]	validation_0-rmse:0.83723	validation_1-rmse:0.83052
# [15]	validation_0-rmse:0.75892	validation_1-rmse:0.75347
# [16]	validation_0-rmse:0.68704	validation_1-rmse:0.68292
# [17]	validation_0-rmse:0.62387	validation_1-rmse:0.62055
# [18]	validation_0-rmse:0.56692	validation_1-rmse:0.56456
# [19]	validation_0-rmse:0.51637	validation_1-rmse:0.51361
# [20]	validation_0-rmse:0.47166	validation_1-rmse:0.47013
# [21]	validation_0-rmse:0.43029	validation_1-rmse:0.42945
# [22]	validation_0-rmse:0.39342	validation_1-rmse:0.39464
# [23]	validation_0-rmse:0.36124	validation_1-rmse:0.36383
# [24]	validation_0-rmse:0.33342	validation_1-rmse:0.33723
# [25]	validation_0-rmse:0.30872	validation_1-rmse:0.31315
# [26]	validation_0-rmse:0.28655	validation_1-rmse:0.29180
# [27]	validation_0-rmse:0.26705	validation_1-rmse:0.27365
# [28]	validation_0-rmse:0.24944	validation_1-rmse:0.25693
# [29]	validation_0-rmse:0.23460	validation_1-rmse:0.24296
# [30]	validation_0-rmse:0.22223	validation_1-rmse:0.23080
# [31]	validation_0-rmse:0.21081	validation_1-rmse:0.22009
# [32]	validation_0-rmse:0.20093	validation_1-rmse:0.21102
# [33]	validation_0-rmse:0.19244	validation_1-rmse:0.20343
# [34]	validation_0-rmse:0.18526	validation_1-rmse:0.19708
# [35]	validation_0-rmse:0.17871	validation_1-rmse:0.19115
# [36]	validation_0-rmse:0.17314	validation_1-rmse:0.18641
# [37]	validation_0-rmse:0.16861	validation_1-rmse:0.18268
# [38]	validation_0-rmse:0.16460	validation_1-rmse:0.17928
# [39]	validation_0-rmse:0.16125	validation_1-rmse:0.17616
# [40]	validation_0-rmse:0.15831	validation_1-rmse:0.17327
# [41]	validation_0-rmse:0.15583	validation_1-rmse:0.17100
# [42]	validation_0-rmse:0.15382	validation_1-rmse:0.16939
# [43]	validation_0-rmse:0.15166	validation_1-rmse:0.16781
# [44]	validation_0-rmse:0.15015	validation_1-rmse:0.16660
# [45]	validation_0-rmse:0.14865	validation_1-rmse:0.16583
# [46]	validation_0-rmse:0.14694	validation_1-rmse:0.16448
# [47]	validation_0-rmse:0.14614	validation_1-rmse:0.16403
# [48]	validation_0-rmse:0.14518	validation_1-rmse:0.16361
# [49]	validation_0-rmse:0.14406	validation_1-rmse:0.16312
# [50]	validation_0-rmse:0.14324	validation_1-rmse:0.16295
# [51]	validation_0-rmse:0.14235	validation_1-rmse:0.16241
# [52]	validation_0-rmse:0.14153	validation_1-rmse:0.16176
# [53]	validation_0-rmse:0.14111	validation_1-rmse:0.16167
# [54]	validation_0-rmse:0.14062	validation_1-rmse:0.16090
# [55]	validation_0-rmse:0.14017	validation_1-rmse:0.16068
# [56]	validation_0-rmse:0.13926	validation_1-rmse:0.16019
# [57]	validation_0-rmse:0.13852	validation_1-rmse:0.15998
# [58]	validation_0-rmse:0.13792	validation_1-rmse:0.15930
# [59]	validation_0-rmse:0.13695	validation_1-rmse:0.15886
# [60]	validation_0-rmse:0.13627	validation_1-rmse:0.15847
# [61]	validation_0-rmse:0.13595	validation_1-rmse:0.15820
# [62]	validation_0-rmse:0.13543	validation_1-rmse:0.15768
# [63]	validation_0-rmse:0.13492	validation_1-rmse:0.15782
# [64]	validation_0-rmse:0.13427	validation_1-rmse:0.15760
# [65]	validation_0-rmse:0.13369	validation_1-rmse:0.15724
# [66]	validation_0-rmse:0.13323	validation_1-rmse:0.15702
# [67]	validation_0-rmse:0.13290	validation_1-rmse:0.15705
# [68]	validation_0-rmse:0.13234	validation_1-rmse:0.15667
# [69]	validation_0-rmse:0.13214	validation_1-rmse:0.15641
# [70]	validation_0-rmse:0.13171	validation_1-rmse:0.15608
# [71]	validation_0-rmse:0.13135	validation_1-rmse:0.15582
# [72]	validation_0-rmse:0.13074	validation_1-rmse:0.15569
# [73]	validation_0-rmse:0.13068	validation_1-rmse:0.15561
# [74]	validation_0-rmse:0.13036	validation_1-rmse:0.15552
# [75]	validation_0-rmse:0.13014	validation_1-rmse:0.15539
# [76]	validation_0-rmse:0.12971	validation_1-rmse:0.15566
# [77]	validation_0-rmse:0.12946	validation_1-rmse:0.15559
# [78]	validation_0-rmse:0.12932	validation_1-rmse:0.15537
# [79]	validation_0-rmse:0.12883	validation_1-rmse:0.15530
# [80]	validation_0-rmse:0.12852	validation_1-rmse:0.15537
# [81]	validation_0-rmse:0.12823	validation_1-rmse:0.15522
# [82]	validation_0-rmse:0.12788	validation_1-rmse:0.15515
# [83]	validation_0-rmse:0.12763	validation_1-rmse:0.15505
# [84]	validation_0-rmse:0.12708	validation_1-rmse:0.15559
# [85]	validation_0-rmse:0.12695	validation_1-rmse:0.15542
# [86]	validation_0-rmse:0.12678	validation_1-rmse:0.15523
# [87]	validation_0-rmse:0.12619	validation_1-rmse:0.15479
# [88]	validation_0-rmse:0.12599	validation_1-rmse:0.15480
# [89]	validation_0-rmse:0.12575	validation_1-rmse:0.15481
# [90]	validation_0-rmse:0.12558	validation_1-rmse:0.15447
# [91]	validation_0-rmse:0.12520	validation_1-rmse:0.15441
# [92]	validation_0-rmse:0.12498	validation_1-rmse:0.15429
# [93]	validation_0-rmse:0.12468	validation_1-rmse:0.15421
# [94]	validation_0-rmse:0.12437	validation_1-rmse:0.15431
# [95]	validation_0-rmse:0.12404	validation_1-rmse:0.15427
# [96]	validation_0-rmse:0.12382	validation_1-rmse:0.15416
# [97]	validation_0-rmse:0.12341	validation_1-rmse:0.15404
# [98]	validation_0-rmse:0.12291	validation_1-rmse:0.15415
# [99]	validation_0-rmse:0.12277	validation_1-rmse:0.15407
# [100]	validation_0-rmse:0.12245	validation_1-rmse:0.15378
# [101]	validation_0-rmse:0.12213	validation_1-rmse:0.15335
# [102]	validation_0-rmse:0.12190	validation_1-rmse:0.15340
# [103]	validation_0-rmse:0.12190	validation_1-rmse:0.15340
# [104]	validation_0-rmse:0.12179	validation_1-rmse:0.15316
# [105]	validation_0-rmse:0.12157	validation_1-rmse:0.15346
# [106]	validation_0-rmse:0.12130	validation_1-rmse:0.15344
# [107]	validation_0-rmse:0.12099	validation_1-rmse:0.15298
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:3.52850	validation_1-rmse:3.63007
# [1]	validation_0-rmse:3.17691	validation_1-rmse:3.27096
# [2]	validation_0-rmse:2.86135	validation_1-rmse:2.94858
# [3]	validation_0-rmse:2.57643	validation_1-rmse:2.65610
# [4]	validation_0-rmse:2.32083	validation_1-rmse:2.39703
# [5]	validation_0-rmse:2.09280	validation_1-rmse:2.16445
# [6]	validation_0-rmse:1.88515	validation_1-rmse:1.95302
# [7]	validation_0-rmse:1.69970	validation_1-rmse:1.76170
# [8]	validation_0-rmse:1.53243	validation_1-rmse:1.59053
# [9]	validation_0-rmse:1.38185	validation_1-rmse:1.43629
# [10]	validation_0-rmse:1.24695	validation_1-rmse:1.29877
# [11]	validation_0-rmse:1.12646	validation_1-rmse:1.17585
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [12]	validation_0-rmse:1.01738	validation_1-rmse:1.06483
# [13]	validation_0-rmse:0.92004	validation_1-rmse:0.96541
# [14]	validation_0-rmse:0.83224	validation_1-rmse:0.87534
# [15]	validation_0-rmse:0.75381	validation_1-rmse:0.79482
# [16]	validation_0-rmse:0.68358	validation_1-rmse:0.72336
# [17]	validation_0-rmse:0.62079	validation_1-rmse:0.65951
# [18]	validation_0-rmse:0.56367	validation_1-rmse:0.60124
# [19]	validation_0-rmse:0.51224	validation_1-rmse:0.55030
# [20]	validation_0-rmse:0.46762	validation_1-rmse:0.50616
# [21]	validation_0-rmse:0.42661	validation_1-rmse:0.46477
# [22]	validation_0-rmse:0.39061	validation_1-rmse:0.42811
# [23]	validation_0-rmse:0.35871	validation_1-rmse:0.39599
# [24]	validation_0-rmse:0.33035	validation_1-rmse:0.36835
# [25]	validation_0-rmse:0.30507	validation_1-rmse:0.34270
# [26]	validation_0-rmse:0.28277	validation_1-rmse:0.32040
# [27]	validation_0-rmse:0.26370	validation_1-rmse:0.30113
# [28]	validation_0-rmse:0.24623	validation_1-rmse:0.28454
# [29]	validation_0-rmse:0.23130	validation_1-rmse:0.26980
# [30]	validation_0-rmse:0.21894	validation_1-rmse:0.25763
# [31]	validation_0-rmse:0.20754	validation_1-rmse:0.24648
# [32]	validation_0-rmse:0.19729	validation_1-rmse:0.23611
# [33]	validation_0-rmse:0.18845	validation_1-rmse:0.22689
# [34]	validation_0-rmse:0.18102	validation_1-rmse:0.21929
# [35]	validation_0-rmse:0.17490	validation_1-rmse:0.21293
# [36]	validation_0-rmse:0.16931	validation_1-rmse:0.20694
# [37]	validation_0-rmse:0.16436	validation_1-rmse:0.20229
# [38]	validation_0-rmse:0.16034	validation_1-rmse:0.19818
# [39]	validation_0-rmse:0.15694	validation_1-rmse:0.19498
# [40]	validation_0-rmse:0.15392	validation_1-rmse:0.19193
# [41]	validation_0-rmse:0.15165	validation_1-rmse:0.18977
# [42]	validation_0-rmse:0.14974	validation_1-rmse:0.18753
# [43]	validation_0-rmse:0.14758	validation_1-rmse:0.18564
# [44]	validation_0-rmse:0.14583	validation_1-rmse:0.18378
# [45]	validation_0-rmse:0.14434	validation_1-rmse:0.18273
# [46]	validation_0-rmse:0.14320	validation_1-rmse:0.18141
# [47]	validation_0-rmse:0.14183	validation_1-rmse:0.18033
# [48]	validation_0-rmse:0.14070	validation_1-rmse:0.17952
# [49]	validation_0-rmse:0.13993	validation_1-rmse:0.17861
# [50]	validation_0-rmse:0.13917	validation_1-rmse:0.17746
# [51]	validation_0-rmse:0.13835	validation_1-rmse:0.17705
# [52]	validation_0-rmse:0.13776	validation_1-rmse:0.17613
# [53]	validation_0-rmse:0.13701	validation_1-rmse:0.17595
# [54]	validation_0-rmse:0.13596	validation_1-rmse:0.17555
# [55]	validation_0-rmse:0.13538	validation_1-rmse:0.17494
# [56]	validation_0-rmse:0.13447	validation_1-rmse:0.17400
# [57]	validation_0-rmse:0.13410	validation_1-rmse:0.17364
# [58]	validation_0-rmse:0.13360	validation_1-rmse:0.17323
# [59]	validation_0-rmse:0.13293	validation_1-rmse:0.17250
# [60]	validation_0-rmse:0.13253	validation_1-rmse:0.17205
# [61]	validation_0-rmse:0.13200	validation_1-rmse:0.17161
# [62]	validation_0-rmse:0.13169	validation_1-rmse:0.17147
# [63]	validation_0-rmse:0.13147	validation_1-rmse:0.17140
# [64]	validation_0-rmse:0.13104	validation_1-rmse:0.17118
# [65]	validation_0-rmse:0.13045	validation_1-rmse:0.17056
# [66]	validation_0-rmse:0.13020	validation_1-rmse:0.17095
# [67]	validation_0-rmse:0.12985	validation_1-rmse:0.17072
# [68]	validation_0-rmse:0.12962	validation_1-rmse:0.17051
# [69]	validation_0-rmse:0.12920	validation_1-rmse:0.17047
# [70]	validation_0-rmse:0.12896	validation_1-rmse:0.17021
# [71]	validation_0-rmse:0.12854	validation_1-rmse:0.16976
# [72]	validation_0-rmse:0.12809	validation_1-rmse:0.16914
# [73]	validation_0-rmse:0.12742	validation_1-rmse:0.16862
# [74]	validation_0-rmse:0.12714	validation_1-rmse:0.16846
# [75]	validation_0-rmse:0.12695	validation_1-rmse:0.16846
# [76]	validation_0-rmse:0.12644	validation_1-rmse:0.16809
# [77]	validation_0-rmse:0.12602	validation_1-rmse:0.16811
# [78]	validation_0-rmse:0.12558	validation_1-rmse:0.16775
# [79]	validation_0-rmse:0.12512	validation_1-rmse:0.16740
# [80]	validation_0-rmse:0.12484	validation_1-rmse:0.16736
# [81]	validation_0-rmse:0.12470	validation_1-rmse:0.16732
# [82]	validation_0-rmse:0.12449	validation_1-rmse:0.16688
# [83]	validation_0-rmse:0.12437	validation_1-rmse:0.16688
# [84]	validation_0-rmse:0.12406	validation_1-rmse:0.16660
# [85]	validation_0-rmse:0.12382	validation_1-rmse:0.16595
# [86]	validation_0-rmse:0.12350	validation_1-rmse:0.16585
# [87]	validation_0-rmse:0.12314	validation_1-rmse:0.16540
# [88]	validation_0-rmse:0.12289	validation_1-rmse:0.16521
# [89]	validation_0-rmse:0.12264	validation_1-rmse:0.16483
# [90]	validation_0-rmse:0.12233	validation_1-rmse:0.16466
# [91]	validation_0-rmse:0.12203	validation_1-rmse:0.16445
# [92]	validation_0-rmse:0.12176	validation_1-rmse:0.16397
# [93]	validation_0-rmse:0.12156	validation_1-rmse:0.16392
# [94]	validation_0-rmse:0.12122	validation_1-rmse:0.16383
# [95]	validation_0-rmse:0.12096	validation_1-rmse:0.16350
# [96]	validation_0-rmse:0.12096	validation_1-rmse:0.16350
# [97]	validation_0-rmse:0.12067	validation_1-rmse:0.16349
# [98]	validation_0-rmse:0.12042	validation_1-rmse:0.16307
# [99]	validation_0-rmse:0.12022	validation_1-rmse:0.16300
# [100]	validation_0-rmse:0.12007	validation_1-rmse:0.16285
# [101]	validation_0-rmse:0.11984	validation_1-rmse:0.16272
# [102]	validation_0-rmse:0.11981	validation_1-rmse:0.16293
# [103]	validation_0-rmse:0.11965	validation_1-rmse:0.16300
# [104]	validation_0-rmse:0.11940	validation_1-rmse:0.16328
# [105]	validation_0-rmse:0.11907	validation_1-rmse:0.16309
# [106]	validation_0-rmse:0.11899	validation_1-rmse:0.16299
# [107]	validation_0-rmse:0.11899	validation_1-rmse:0.16300
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:3.55084	validation_1-rmse:3.54647
# [1]	validation_0-rmse:3.19864	validation_1-rmse:3.19931
# [2]	validation_0-rmse:2.88134	validation_1-rmse:2.88747
# [3]	validation_0-rmse:2.59691	validation_1-rmse:2.60688
# [4]	validation_0-rmse:2.33910	validation_1-rmse:2.35107
# [5]	validation_0-rmse:2.10759	validation_1-rmse:2.12275
# [6]	validation_0-rmse:1.89909	validation_1-rmse:1.91505
# [7]	validation_0-rmse:1.71266	validation_1-rmse:1.72931
# [8]	validation_0-rmse:1.54343	validation_1-rmse:1.56446
# [9]	validation_0-rmse:1.39135	validation_1-rmse:1.41256
# [10]	validation_0-rmse:1.25469	validation_1-rmse:1.27499
# [11]	validation_0-rmse:1.13243	validation_1-rmse:1.15250
# [12]	validation_0-rmse:1.02280	validation_1-rmse:1.04390
# [13]	validation_0-rmse:0.92486	validation_1-rmse:0.94716
# [14]	validation_0-rmse:0.83631	validation_1-rmse:0.85998
# [15]	validation_0-rmse:0.75711	validation_1-rmse:0.78145
# [16]	validation_0-rmse:0.68607	validation_1-rmse:0.71005
# [17]	validation_0-rmse:0.62359	validation_1-rmse:0.64917
# [18]	validation_0-rmse:0.56674	validation_1-rmse:0.59204
# [19]	validation_0-rmse:0.51688	validation_1-rmse:0.54318
# [20]	validation_0-rmse:0.47218	validation_1-rmse:0.49864
# [21]	validation_0-rmse:0.43080	validation_1-rmse:0.45663
# [22]	validation_0-rmse:0.39391	validation_1-rmse:0.42078
# [23]	validation_0-rmse:0.36140	validation_1-rmse:0.38931
# [24]	validation_0-rmse:0.33302	validation_1-rmse:0.36150
# [25]	validation_0-rmse:0.30817	validation_1-rmse:0.33728
# [26]	validation_0-rmse:0.28594	validation_1-rmse:0.31513
# [27]	validation_0-rmse:0.26596	validation_1-rmse:0.29419
# [28]	validation_0-rmse:0.24845	validation_1-rmse:0.27602
# [29]	validation_0-rmse:0.23364	validation_1-rmse:0.26091
# [30]	validation_0-rmse:0.22099	validation_1-rmse:0.24828
# [31]	validation_0-rmse:0.20948	validation_1-rmse:0.23664
# [32]	validation_0-rmse:0.19995	validation_1-rmse:0.22716
# [33]	validation_0-rmse:0.19133	validation_1-rmse:0.21783
# [34]	validation_0-rmse:0.18438	validation_1-rmse:0.21053
# [35]	validation_0-rmse:0.17816	validation_1-rmse:0.20515
# [36]	validation_0-rmse:0.17288	validation_1-rmse:0.19928
# [37]	validation_0-rmse:0.16835	validation_1-rmse:0.19427
# [38]	validation_0-rmse:0.16450	validation_1-rmse:0.19000
# [39]	validation_0-rmse:0.16139	validation_1-rmse:0.18664
# [40]	validation_0-rmse:0.15844	validation_1-rmse:0.18353
# [41]	validation_0-rmse:0.15618	validation_1-rmse:0.18085
# [42]	validation_0-rmse:0.15433	validation_1-rmse:0.17856
# [43]	validation_0-rmse:0.15216	validation_1-rmse:0.17650
# [44]	validation_0-rmse:0.15068	validation_1-rmse:0.17512
# [45]	validation_0-rmse:0.14935	validation_1-rmse:0.17404
# [46]	validation_0-rmse:0.14794	validation_1-rmse:0.17300
# [47]	validation_0-rmse:0.14676	validation_1-rmse:0.17184
# [48]	validation_0-rmse:0.14578	validation_1-rmse:0.17062
# [49]	validation_0-rmse:0.14506	validation_1-rmse:0.16954
# [50]	validation_0-rmse:0.14423	validation_1-rmse:0.16905
# [51]	validation_0-rmse:0.14352	validation_1-rmse:0.16810
# [52]	validation_0-rmse:0.14255	validation_1-rmse:0.16823
# [53]	validation_0-rmse:0.14139	validation_1-rmse:0.16723
# [54]	validation_0-rmse:0.14075	validation_1-rmse:0.16699
# [55]	validation_0-rmse:0.13996	validation_1-rmse:0.16634
# [56]	validation_0-rmse:0.13928	validation_1-rmse:0.16622
# [57]	validation_0-rmse:0.13847	validation_1-rmse:0.16535
# [58]	validation_0-rmse:0.13784	validation_1-rmse:0.16493
# [59]	validation_0-rmse:0.13740	validation_1-rmse:0.16497
# [60]	validation_0-rmse:0.13715	validation_1-rmse:0.16479
# [61]	validation_0-rmse:0.13670	validation_1-rmse:0.16440
# [62]	validation_0-rmse:0.13607	validation_1-rmse:0.16408
# [63]	validation_0-rmse:0.13575	validation_1-rmse:0.16355
# [64]	validation_0-rmse:0.13536	validation_1-rmse:0.16303
# [65]	validation_0-rmse:0.13460	validation_1-rmse:0.16266
# [66]	validation_0-rmse:0.13397	validation_1-rmse:0.16210
# [67]	validation_0-rmse:0.13372	validation_1-rmse:0.16272
# [68]	validation_0-rmse:0.13318	validation_1-rmse:0.16216
# [69]	validation_0-rmse:0.13300	validation_1-rmse:0.16217
# [70]	validation_0-rmse:0.13264	validation_1-rmse:0.16213
# [71]	validation_0-rmse:0.13220	validation_1-rmse:0.16207
# [72]	validation_0-rmse:0.13180	validation_1-rmse:0.16178
# [73]	validation_0-rmse:0.13143	validation_1-rmse:0.16172
# [74]	validation_0-rmse:0.13112	validation_1-rmse:0.16173
# [75]	validation_0-rmse:0.13066	validation_1-rmse:0.16158
# [76]	validation_0-rmse:0.13050	validation_1-rmse:0.16177
# [77]	validation_0-rmse:0.13010	validation_1-rmse:0.16177
# [78]	validation_0-rmse:0.12993	validation_1-rmse:0.16217
# [79]	validation_0-rmse:0.12950	validation_1-rmse:0.16153
# [80]	validation_0-rmse:0.12891	validation_1-rmse:0.16159
# [81]	validation_0-rmse:0.12876	validation_1-rmse:0.16168
# [82]	validation_0-rmse:0.12821	validation_1-rmse:0.16124
# [83]	validation_0-rmse:0.12816	validation_1-rmse:0.16097
# [84]	validation_0-rmse:0.12799	validation_1-rmse:0.16154
# [85]	validation_0-rmse:0.12778	validation_1-rmse:0.16146
# [86]	validation_0-rmse:0.12740	validation_1-rmse:0.16132
# [87]	validation_0-rmse:0.12709	validation_1-rmse:0.16133
# [88]	validation_0-rmse:0.12697	validation_1-rmse:0.16141
# [89]	validation_0-rmse:0.12655	validation_1-rmse:0.16129
# [90]	validation_0-rmse:0.12625	validation_1-rmse:0.16122
# [91]	validation_0-rmse:0.12605	validation_1-rmse:0.16131
# [92]	validation_0-rmse:0.12555	validation_1-rmse:0.16112
# [93]	validation_0-rmse:0.12510	validation_1-rmse:0.16127
# [94]	validation_0-rmse:0.12455	validation_1-rmse:0.16143
# [95]	validation_0-rmse:0.12423	validation_1-rmse:0.16134
# [96]	validation_0-rmse:0.12423	validation_1-rmse:0.16134
# [97]	validation_0-rmse:0.12366	validation_1-rmse:0.16103
# [98]	validation_0-rmse:0.12332	validation_1-rmse:0.16100
# [99]	validation_0-rmse:0.12313	validation_1-rmse:0.16103
# [100]	validation_0-rmse:0.12310	validation_1-rmse:0.16089
# [101]	validation_0-rmse:0.12287	validation_1-rmse:0.16077
# [102]	validation_0-rmse:0.12256	validation_1-rmse:0.16080
# [103]	validation_0-rmse:0.12225	validation_1-rmse:0.16066
# [104]	validation_0-rmse:0.12212	validation_1-rmse:0.16062
# [105]	validation_0-rmse:0.12175	validation_1-rmse:0.16068
# [106]	validation_0-rmse:0.12160	validation_1-rmse:0.16056
# [107]	validation_0-rmse:0.12135	validation_1-rmse:0.16038
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [0]	validation_0-rmse:3.56083	validation_1-rmse:3.49692
# [1]	validation_0-rmse:3.20792	validation_1-rmse:3.15023
# [2]	validation_0-rmse:2.88896	validation_1-rmse:2.83453
# [3]	validation_0-rmse:2.60220	validation_1-rmse:2.55314
# [4]	validation_0-rmse:2.34409	validation_1-rmse:2.29659
# [5]	validation_0-rmse:2.11122	validation_1-rmse:2.06914
# [6]	validation_0-rmse:1.90159	validation_1-rmse:1.86386
# [7]	validation_0-rmse:1.71493	validation_1-rmse:1.68042
# [8]	validation_0-rmse:1.54706	validation_1-rmse:1.51795
# [9]	validation_0-rmse:1.39557	validation_1-rmse:1.37019
# [10]	validation_0-rmse:1.25906	validation_1-rmse:1.23636
# [11]	validation_0-rmse:1.13669	validation_1-rmse:1.11694
# [12]	validation_0-rmse:1.02721	validation_1-rmse:1.01061
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [13]	validation_0-rmse:0.92854	validation_1-rmse:0.91356
# [14]	validation_0-rmse:0.84045	validation_1-rmse:0.82644
# [15]	validation_0-rmse:0.76009	validation_1-rmse:0.74847
# [16]	validation_0-rmse:0.68822	validation_1-rmse:0.67799
# [17]	validation_0-rmse:0.62370	validation_1-rmse:0.61608
# [18]	validation_0-rmse:0.56702	validation_1-rmse:0.56076
# [19]	validation_0-rmse:0.51518	validation_1-rmse:0.51131
# [20]	validation_0-rmse:0.47007	validation_1-rmse:0.46830
# [21]	validation_0-rmse:0.42940	validation_1-rmse:0.42895
# [22]	validation_0-rmse:0.39375	validation_1-rmse:0.39447
# [23]	validation_0-rmse:0.36176	validation_1-rmse:0.36414
# [24]	validation_0-rmse:0.33431	validation_1-rmse:0.33800
# [25]	validation_0-rmse:0.30936	validation_1-rmse:0.31431
# [26]	validation_0-rmse:0.28664	validation_1-rmse:0.29361
# [27]	validation_0-rmse:0.26704	validation_1-rmse:0.27487
# [28]	validation_0-rmse:0.24871	validation_1-rmse:0.25832
# [29]	validation_0-rmse:0.23411	validation_1-rmse:0.24435
# [30]	validation_0-rmse:0.22111	validation_1-rmse:0.23266
# [31]	validation_0-rmse:0.20964	validation_1-rmse:0.22193
# [32]	validation_0-rmse:0.19993	validation_1-rmse:0.21332
# [33]	validation_0-rmse:0.19125	validation_1-rmse:0.20593
# [34]	validation_0-rmse:0.18400	validation_1-rmse:0.19951
# [35]	validation_0-rmse:0.17772	validation_1-rmse:0.19441
# [36]	validation_0-rmse:0.17220	validation_1-rmse:0.18889
# [37]	validation_0-rmse:0.16765	validation_1-rmse:0.18503
# [38]	validation_0-rmse:0.16381	validation_1-rmse:0.18149
# [39]	validation_0-rmse:0.16028	validation_1-rmse:0.17858
# [40]	validation_0-rmse:0.15747	validation_1-rmse:0.17650
# [41]	validation_0-rmse:0.15513	validation_1-rmse:0.17444
# [42]	validation_0-rmse:0.15294	validation_1-rmse:0.17244
# [43]	validation_0-rmse:0.15122	validation_1-rmse:0.17104
# [44]	validation_0-rmse:0.15007	validation_1-rmse:0.16988
# [45]	validation_0-rmse:0.14849	validation_1-rmse:0.16783
# [46]	validation_0-rmse:0.14736	validation_1-rmse:0.16716
# [47]	validation_0-rmse:0.14660	validation_1-rmse:0.16695
# [48]	validation_0-rmse:0.14573	validation_1-rmse:0.16648
# [49]	validation_0-rmse:0.14472	validation_1-rmse:0.16609
# [50]	validation_0-rmse:0.14392	validation_1-rmse:0.16500
# [51]	validation_0-rmse:0.14279	validation_1-rmse:0.16496
# [52]	validation_0-rmse:0.14208	validation_1-rmse:0.16446
# [53]	validation_0-rmse:0.14113	validation_1-rmse:0.16453
# [54]	validation_0-rmse:0.14061	validation_1-rmse:0.16364
# [55]	validation_0-rmse:0.14020	validation_1-rmse:0.16306
# [56]	validation_0-rmse:0.13935	validation_1-rmse:0.16262
# [57]	validation_0-rmse:0.13889	validation_1-rmse:0.16215
# [58]	validation_0-rmse:0.13848	validation_1-rmse:0.16201
# [59]	validation_0-rmse:0.13741	validation_1-rmse:0.16179
# [60]	validation_0-rmse:0.13685	validation_1-rmse:0.16107
# [61]	validation_0-rmse:0.13599	validation_1-rmse:0.16084
# [62]	validation_0-rmse:0.13551	validation_1-rmse:0.16054
# [63]	validation_0-rmse:0.13510	validation_1-rmse:0.15970
# [64]	validation_0-rmse:0.13437	validation_1-rmse:0.15975
# [65]	validation_0-rmse:0.13386	validation_1-rmse:0.15945
# [66]	validation_0-rmse:0.13341	validation_1-rmse:0.15895
# [67]	validation_0-rmse:0.13293	validation_1-rmse:0.15900
# [68]	validation_0-rmse:0.13275	validation_1-rmse:0.15941
# [69]	validation_0-rmse:0.13257	validation_1-rmse:0.15934
# [70]	validation_0-rmse:0.13232	validation_1-rmse:0.15938
# [71]	validation_0-rmse:0.13171	validation_1-rmse:0.15984
# [72]	validation_0-rmse:0.13136	validation_1-rmse:0.16065
# [73]	validation_0-rmse:0.13080	validation_1-rmse:0.16078
# [74]	validation_0-rmse:0.13034	validation_1-rmse:0.16007
# [75]	validation_0-rmse:0.13010	validation_1-rmse:0.15990
# [76]	validation_0-rmse:0.12969	validation_1-rmse:0.15923
# [77]	validation_0-rmse:0.12941	validation_1-rmse:0.15930
# [78]	validation_0-rmse:0.12912	validation_1-rmse:0.15906
# [79]	validation_0-rmse:0.12879	validation_1-rmse:0.15904
# [80]	validation_0-rmse:0.12840	validation_1-rmse:0.15875
# [81]	validation_0-rmse:0.12775	validation_1-rmse:0.15860
# [82]	validation_0-rmse:0.12718	validation_1-rmse:0.15912
# [83]	validation_0-rmse:0.12708	validation_1-rmse:0.15917
# [84]	validation_0-rmse:0.12681	validation_1-rmse:0.15850
# [85]	validation_0-rmse:0.12660	validation_1-rmse:0.15863
# [86]	validation_0-rmse:0.12616	validation_1-rmse:0.15871
# [87]	validation_0-rmse:0.12581	validation_1-rmse:0.15813
# [88]	validation_0-rmse:0.12562	validation_1-rmse:0.15789
# [89]	validation_0-rmse:0.12545	validation_1-rmse:0.15777
# [90]	validation_0-rmse:0.12504	validation_1-rmse:0.15722
# [91]	validation_0-rmse:0.12504	validation_1-rmse:0.15722
# [92]	validation_0-rmse:0.12454	validation_1-rmse:0.15729
# [93]	validation_0-rmse:0.12412	validation_1-rmse:0.15708
# [94]	validation_0-rmse:0.12402	validation_1-rmse:0.15691
# [95]	validation_0-rmse:0.12373	validation_1-rmse:0.15648
# [96]	validation_0-rmse:0.12341	validation_1-rmse:0.15637
# [97]	validation_0-rmse:0.12303	validation_1-rmse:0.15627
# [98]	validation_0-rmse:0.12250	validation_1-rmse:0.15672
# [99]	validation_0-rmse:0.12209	validation_1-rmse:0.15665
# [100]	validation_0-rmse:0.12160	validation_1-rmse:0.15684
# [101]	validation_0-rmse:0.12149	validation_1-rmse:0.15655
# [102]	validation_0-rmse:0.12119	validation_1-rmse:0.15673
# [103]	validation_0-rmse:0.12106	validation_1-rmse:0.15687
# [104]	validation_0-rmse:0.12080	validation_1-rmse:0.15717
# [105]	validation_0-rmse:0.12072	validation_1-rmse:0.15741
# [106]	validation_0-rmse:0.12051	validation_1-rmse:0.15734
# [107]	validation_0-rmse:0.12021	validation_1-rmse:0.15694
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [0]	validation_0-rmse:3.53643	validation_1-rmse:3.59742
# [1]	validation_0-rmse:3.18518	validation_1-rmse:3.24300
# [2]	validation_0-rmse:2.86956	validation_1-rmse:2.91995
# [3]	validation_0-rmse:2.58492	validation_1-rmse:2.62893
# [4]	validation_0-rmse:2.32790	validation_1-rmse:2.36635
# [5]	validation_0-rmse:2.09684	validation_1-rmse:2.13075
# [6]	validation_0-rmse:1.88867	validation_1-rmse:1.91746
# [7]	validation_0-rmse:1.70454	validation_1-rmse:1.72728
# [8]	validation_0-rmse:1.53881	validation_1-rmse:1.55624
# [9]	validation_0-rmse:1.38759	validation_1-rmse:1.40179
# [10]	validation_0-rmse:1.25214	validation_1-rmse:1.26483
# [11]	validation_0-rmse:1.13044	validation_1-rmse:1.14169
# [12]	validation_0-rmse:1.02121	validation_1-rmse:1.03178
# [13]	validation_0-rmse:0.92306	validation_1-rmse:0.93045
# [14]	validation_0-rmse:0.83479	validation_1-rmse:0.84129
# [15]	validation_0-rmse:0.75623	validation_1-rmse:0.76127
# [16]	validation_0-rmse:0.68473	validation_1-rmse:0.68854
# [17]	validation_0-rmse:0.62238	validation_1-rmse:0.62586
# [18]	validation_0-rmse:0.56555	validation_1-rmse:0.56853
# [19]	validation_0-rmse:0.51576	validation_1-rmse:0.51990
# [20]	validation_0-rmse:0.47148	validation_1-rmse:0.47558
# [21]	validation_0-rmse:0.42952	validation_1-rmse:0.43404
# [22]	validation_0-rmse:0.39241	validation_1-rmse:0.39632
# [23]	validation_0-rmse:0.35980	validation_1-rmse:0.36209
# [24]	validation_0-rmse:0.33174	validation_1-rmse:0.33464
# [25]	validation_0-rmse:0.30644	validation_1-rmse:0.31004
# [26]	validation_0-rmse:0.28395	validation_1-rmse:0.28687
# [27]	validation_0-rmse:0.26443	validation_1-rmse:0.26742
# [28]	validation_0-rmse:0.24727	validation_1-rmse:0.25017
# [29]	validation_0-rmse:0.23185	validation_1-rmse:0.23497
# [30]	validation_0-rmse:0.21943	validation_1-rmse:0.22373
# [31]	validation_0-rmse:0.20844	validation_1-rmse:0.21295
# [32]	validation_0-rmse:0.19892	validation_1-rmse:0.20429
# [33]	validation_0-rmse:0.19055	validation_1-rmse:0.19642
# [34]	validation_0-rmse:0.18389	validation_1-rmse:0.19082
# [35]	validation_0-rmse:0.17779	validation_1-rmse:0.18484
# [36]	validation_0-rmse:0.17238	validation_1-rmse:0.18012
# [37]	validation_0-rmse:0.16729	validation_1-rmse:0.17592
# [38]	validation_0-rmse:0.16353	validation_1-rmse:0.17306
# [39]	validation_0-rmse:0.16030	validation_1-rmse:0.17047
# [40]	validation_0-rmse:0.15727	validation_1-rmse:0.16811
# [41]	validation_0-rmse:0.15454	validation_1-rmse:0.16587
# [42]	validation_0-rmse:0.15245	validation_1-rmse:0.16410
# [43]	validation_0-rmse:0.15059	validation_1-rmse:0.16268
# [44]	validation_0-rmse:0.14905	validation_1-rmse:0.16149
# [45]	validation_0-rmse:0.14789	validation_1-rmse:0.16108
# [46]	validation_0-rmse:0.14678	validation_1-rmse:0.16026
# [47]	validation_0-rmse:0.14544	validation_1-rmse:0.16037
# [48]	validation_0-rmse:0.14410	validation_1-rmse:0.15978
# [49]	validation_0-rmse:0.14304	validation_1-rmse:0.15910
# [50]	validation_0-rmse:0.14243	validation_1-rmse:0.15887
# [51]	validation_0-rmse:0.14182	validation_1-rmse:0.15865
# [52]	validation_0-rmse:0.14090	validation_1-rmse:0.15848
# [53]	validation_0-rmse:0.14031	validation_1-rmse:0.15815
# [54]	validation_0-rmse:0.13961	validation_1-rmse:0.15771
# [55]	validation_0-rmse:0.13875	validation_1-rmse:0.15788
# [56]	validation_0-rmse:0.13826	validation_1-rmse:0.15791
# [57]	validation_0-rmse:0.13785	validation_1-rmse:0.15774
# [58]	validation_0-rmse:0.13756	validation_1-rmse:0.15785
# [59]	validation_0-rmse:0.13698	validation_1-rmse:0.15759
# [60]	validation_0-rmse:0.13629	validation_1-rmse:0.15740
# [61]	validation_0-rmse:0.13580	validation_1-rmse:0.15720
# [62]	validation_0-rmse:0.13533	validation_1-rmse:0.15700
# [63]	validation_0-rmse:0.13468	validation_1-rmse:0.15616
# [64]	validation_0-rmse:0.13409	validation_1-rmse:0.15687
# [65]	validation_0-rmse:0.13391	validation_1-rmse:0.15683
# [66]	validation_0-rmse:0.13342	validation_1-rmse:0.15672
# [67]	validation_0-rmse:0.13324	validation_1-rmse:0.15658
# [68]	validation_0-rmse:0.13266	validation_1-rmse:0.15648
# [69]	validation_0-rmse:0.13194	validation_1-rmse:0.15671
# [70]	validation_0-rmse:0.13156	validation_1-rmse:0.15647
# [71]	validation_0-rmse:0.13145	validation_1-rmse:0.15657
# [72]	validation_0-rmse:0.13116	validation_1-rmse:0.15647
# [73]	validation_0-rmse:0.13083	validation_1-rmse:0.15617
# [74]	validation_0-rmse:0.13044	validation_1-rmse:0.15638
# [75]	validation_0-rmse:0.13012	validation_1-rmse:0.15634
# [76]	validation_0-rmse:0.12957	validation_1-rmse:0.15575
# [77]	validation_0-rmse:0.12943	validation_1-rmse:0.15578
# [78]	validation_0-rmse:0.12858	validation_1-rmse:0.15661
# [79]	validation_0-rmse:0.12808	validation_1-rmse:0.15661
# [80]	validation_0-rmse:0.12750	validation_1-rmse:0.15637
# [81]	validation_0-rmse:0.12727	validation_1-rmse:0.15578
# [82]	validation_0-rmse:0.12692	validation_1-rmse:0.15537
# [83]	validation_0-rmse:0.12655	validation_1-rmse:0.15509
# [84]	validation_0-rmse:0.12589	validation_1-rmse:0.15596
# [85]	validation_0-rmse:0.12561	validation_1-rmse:0.15578
# [86]	validation_0-rmse:0.12534	validation_1-rmse:0.15596
# [87]	validation_0-rmse:0.12503	validation_1-rmse:0.15602
# ...
# [59]	validation_0-rmse:0.14084	validation_1-rmse:0.15072
# [60]	validation_0-rmse:0.14036	validation_1-rmse:0.15061
# [61]	validation_0-rmse:0.13995	validation_1-rmse:0.15059
# [62]	validation_0-rmse:0.13955	validation_1-rmse:0.15026
# [63]	validation_0-rmse:0.13909	validation_1-rmse:0.15028
# [64]	validation_0-rmse:0.13871	validation_1-rmse:0.14998
# [65]	validation_0-rmse:0.13845	validation_1-rmse:0.15008
# [66]	validation_0-rmse:0.13791	validation_1-rmse:0.15028
# [67]	validation_0-rmse:0.13732	validation_1-rmse:0.14981
# [68]	validation_0-rmse:0.13668	validation_1-rmse:0.14974
# [69]	validation_0-rmse:0.13650	validation_1-rmse:0.14980
# [70]	validation_0-rmse:0.13621	validation_1-rmse:0.15006
# [71]	validation_0-rmse:0.13572	validation_1-rmse:0.14995
# [72]	validation_0-rmse:0.13545	validation_1-rmse:0.14953
# [73]	validation_0-rmse:0.13541	validation_1-rmse:0.14961
# [74]	validation_0-rmse:0.13522	validation_1-rmse:0.14986
# [75]	validation_0-rmse:0.13484	validation_1-rmse:0.14966
# [76]	validation_0-rmse:0.13461	validation_1-rmse:0.14957
# [77]	validation_0-rmse:0.13437	validation_1-rmse:0.14972
# [78]	validation_0-rmse:0.13393	validation_1-rmse:0.14944
# [79]	validation_0-rmse:0.13373	validation_1-rmse:0.14923
# [80]	validation_0-rmse:0.13341	validation_1-rmse:0.14855
# [81]	validation_0-rmse:0.13289	validation_1-rmse:0.14856
# [82]	validation_0-rmse:0.13229	validation_1-rmse:0.14827
# [83]	validation_0-rmse:0.13193	validation_1-rmse:0.14907
# [84]	validation_0-rmse:0.13164	validation_1-rmse:0.14896
# [85]	validation_0-rmse:0.13136	validation_1-rmse:0.14896
# [86]	validation_0-rmse:0.13119	validation_1-rmse:0.14928
# [87]	validation_0-rmse:0.13104	validation_1-rmse:0.14952
# [88]	validation_0-rmse:0.13064	validation_1-rmse:0.14968
# [89]	validation_0-rmse:0.13058	validation_1-rmse:0.14959
# [90]	validation_0-rmse:0.13033	validation_1-rmse:0.14961
# [91]	validation_0-rmse:0.13027	validation_1-rmse:0.14911
# [92]	validation_0-rmse:0.13006	validation_1-rmse:0.14913
# [93]	validation_0-rmse:0.12988	validation_1-rmse:0.14911
# [94]	validation_0-rmse:0.12932	validation_1-rmse:0.14886
# [95]	validation_0-rmse:0.12923	validation_1-rmse:0.14889
# [96]	validation_0-rmse:0.12888	validation_1-rmse:0.14914
# [97]	validation_0-rmse:0.12883	validation_1-rmse:0.14869
# [98]	validation_0-rmse:0.12864	validation_1-rmse:0.14867
# [99]	validation_0-rmse:0.12843	validation_1-rmse:0.14869
# [100]	validation_0-rmse:0.12799	validation_1-rmse:0.14853
# [101]	validation_0-rmse:0.12788	validation_1-rmse:0.14889
# [102]	validation_0-rmse:0.12779	validation_1-rmse:0.14868
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:3.55301	validation_1-rmse:3.52002
# [1]	validation_0-rmse:3.19796	validation_1-rmse:3.16868
# [2]	validation_0-rmse:2.88025	validation_1-rmse:2.85347
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [3]	validation_0-rmse:2.59481	validation_1-rmse:2.57198
# [4]	validation_0-rmse:2.33712	validation_1-rmse:2.31534
# [5]	validation_0-rmse:2.10545	validation_1-rmse:2.08585
# [6]	validation_0-rmse:1.89679	validation_1-rmse:1.88017
# [7]	validation_0-rmse:1.71064	validation_1-rmse:1.69606
# [8]	validation_0-rmse:1.54277	validation_1-rmse:1.53043
# [9]	validation_0-rmse:1.39185	validation_1-rmse:1.38307
# [10]	validation_0-rmse:1.25566	validation_1-rmse:1.24833
# [11]	validation_0-rmse:1.13360	validation_1-rmse:1.12949
# [12]	validation_0-rmse:1.02461	validation_1-rmse:1.02160
# [13]	validation_0-rmse:0.92586	validation_1-rmse:0.92435
# [14]	validation_0-rmse:0.83762	validation_1-rmse:0.83808
# [15]	validation_0-rmse:0.75820	validation_1-rmse:0.75989
# [16]	validation_0-rmse:0.68683	validation_1-rmse:0.69061
# [17]	validation_0-rmse:0.62357	validation_1-rmse:0.62819
# [18]	validation_0-rmse:0.56680	validation_1-rmse:0.57314
# [19]	validation_0-rmse:0.51553	validation_1-rmse:0.52336
# [20]	validation_0-rmse:0.47038	validation_1-rmse:0.47957
# [21]	validation_0-rmse:0.42908	validation_1-rmse:0.43993
# [22]	validation_0-rmse:0.39205	validation_1-rmse:0.40502
# [23]	validation_0-rmse:0.35925	validation_1-rmse:0.37426
# [24]	validation_0-rmse:0.33119	validation_1-rmse:0.34853
# [25]	validation_0-rmse:0.30592	validation_1-rmse:0.32491
# [26]	validation_0-rmse:0.28335	validation_1-rmse:0.30433
# [27]	validation_0-rmse:0.26330	validation_1-rmse:0.28661
# [28]	validation_0-rmse:0.24545	validation_1-rmse:0.27087
# [29]	validation_0-rmse:0.23004	validation_1-rmse:0.25726
# [30]	validation_0-rmse:0.21770	validation_1-rmse:0.24597
# [31]	validation_0-rmse:0.20660	validation_1-rmse:0.23675
# [32]	validation_0-rmse:0.19689	validation_1-rmse:0.22834
# [33]	validation_0-rmse:0.18823	validation_1-rmse:0.22072
# [34]	validation_0-rmse:0.18114	validation_1-rmse:0.21439
# [35]	validation_0-rmse:0.17481	validation_1-rmse:0.20944
# [36]	validation_0-rmse:0.16930	validation_1-rmse:0.20483
# [37]	validation_0-rmse:0.16478	validation_1-rmse:0.20148
# [38]	validation_0-rmse:0.16084	validation_1-rmse:0.19862
# [39]	validation_0-rmse:0.15733	validation_1-rmse:0.19557
# [40]	validation_0-rmse:0.15468	validation_1-rmse:0.19368
# [41]	validation_0-rmse:0.15230	validation_1-rmse:0.19183
# [42]	validation_0-rmse:0.15021	validation_1-rmse:0.18999
# [43]	validation_0-rmse:0.14805	validation_1-rmse:0.18844
# [44]	validation_0-rmse:0.14660	validation_1-rmse:0.18771
# [45]	validation_0-rmse:0.14535	validation_1-rmse:0.18712
# [46]	validation_0-rmse:0.14399	validation_1-rmse:0.18562
# [47]	validation_0-rmse:0.14305	validation_1-rmse:0.18499
# [48]	validation_0-rmse:0.14192	validation_1-rmse:0.18436
# [49]	validation_0-rmse:0.14094	validation_1-rmse:0.18396
# [50]	validation_0-rmse:0.13993	validation_1-rmse:0.18341
# [51]	validation_0-rmse:0.13869	validation_1-rmse:0.18294
# [52]	validation_0-rmse:0.13784	validation_1-rmse:0.18263
# [53]	validation_0-rmse:0.13694	validation_1-rmse:0.18191
# [54]	validation_0-rmse:0.13598	validation_1-rmse:0.18176
# [55]	validation_0-rmse:0.13506	validation_1-rmse:0.18189
# [56]	validation_0-rmse:0.13409	validation_1-rmse:0.18196
# [57]	validation_0-rmse:0.13344	validation_1-rmse:0.18208
# [58]	validation_0-rmse:0.13327	validation_1-rmse:0.18181
# [59]	validation_0-rmse:0.13280	validation_1-rmse:0.18132
# [60]	validation_0-rmse:0.13243	validation_1-rmse:0.18092
# [61]	validation_0-rmse:0.13201	validation_1-rmse:0.18078
# [62]	validation_0-rmse:0.13157	validation_1-rmse:0.18048
# [63]	validation_0-rmse:0.13093	validation_1-rmse:0.18002
# [64]	validation_0-rmse:0.13066	validation_1-rmse:0.17988
# [65]	validation_0-rmse:0.13032	validation_1-rmse:0.18019
# [66]	validation_0-rmse:0.13012	validation_1-rmse:0.18074
# [67]	validation_0-rmse:0.12953	validation_1-rmse:0.18066
# [68]	validation_0-rmse:0.12904	validation_1-rmse:0.18069
# [69]	validation_0-rmse:0.12857	validation_1-rmse:0.18077
# [70]	validation_0-rmse:0.12829	validation_1-rmse:0.18057
# [71]	validation_0-rmse:0.12808	validation_1-rmse:0.18061
# [72]	validation_0-rmse:0.12755	validation_1-rmse:0.18025
# [73]	validation_0-rmse:0.12725	validation_1-rmse:0.18046
# [74]	validation_0-rmse:0.12706	validation_1-rmse:0.17959
# [75]	validation_0-rmse:0.12686	validation_1-rmse:0.17954
# [76]	validation_0-rmse:0.12644	validation_1-rmse:0.17936
# [77]	validation_0-rmse:0.12597	validation_1-rmse:0.17965
# [78]	validation_0-rmse:0.12555	validation_1-rmse:0.17949
# [79]	validation_0-rmse:0.12505	validation_1-rmse:0.17964
# [80]	validation_0-rmse:0.12489	validation_1-rmse:0.17933
# [81]	validation_0-rmse:0.12458	validation_1-rmse:0.17944
# [82]	validation_0-rmse:0.12442	validation_1-rmse:0.17947
# [83]	validation_0-rmse:0.12412	validation_1-rmse:0.17939
# [84]	validation_0-rmse:0.12394	validation_1-rmse:0.17984
# [85]	validation_0-rmse:0.12375	validation_1-rmse:0.17954
# [86]	validation_0-rmse:0.12349	validation_1-rmse:0.17927
# [87]	validation_0-rmse:0.12321	validation_1-rmse:0.17918
# [88]	validation_0-rmse:0.12302	validation_1-rmse:0.17943
# [89]	validation_0-rmse:0.12288	validation_1-rmse:0.17959
# [90]	validation_0-rmse:0.12266	validation_1-rmse:0.17963
# [91]	validation_0-rmse:0.12247	validation_1-rmse:0.17949
# [92]	validation_0-rmse:0.12225	validation_1-rmse:0.17932
# [93]	validation_0-rmse:0.12225	validation_1-rmse:0.17933
# [94]	validation_0-rmse:0.12213	validation_1-rmse:0.17989
# [95]	validation_0-rmse:0.12190	validation_1-rmse:0.17953
# [96]	validation_0-rmse:0.12154	validation_1-rmse:0.17951
# [97]	validation_0-rmse:0.12139	validation_1-rmse:0.17975
# [98]	validation_0-rmse:0.12126	validation_1-rmse:0.17981
# [99]	validation_0-rmse:0.12068	validation_1-rmse:0.18042
# [100]	validation_0-rmse:0.12045	validation_1-rmse:0.18030
# [101]	validation_0-rmse:0.12015	validation_1-rmse:0.18050
# [102]	validation_0-rmse:0.12015	validation_1-rmse:0.18047
# [103]	validation_0-rmse:0.12009	validation_1-rmse:0.18041
# [104]	validation_0-rmse:0.11951	validation_1-rmse:0.18014
# [105]	validation_0-rmse:0.11951	validation_1-rmse:0.18013
# [106]	validation_0-rmse:0.11915	validation_1-rmse:0.17984
# [107]	validation_0-rmse:0.11886	validation_1-rmse:0.18041
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# [0]	validation_0-rmse:3.56771	validation_1-rmse:3.47177
# [1]	validation_0-rmse:3.21288	validation_1-rmse:3.12821
# [2]	validation_0-rmse:2.89404	validation_1-rmse:2.81975
# [3]	validation_0-rmse:2.60685	validation_1-rmse:2.53691
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [4]	validation_0-rmse:2.34912	validation_1-rmse:2.28672
# [5]	validation_0-rmse:2.11670	validation_1-rmse:2.06135
# [6]	validation_0-rmse:1.90858	validation_1-rmse:1.85585
# [7]	validation_0-rmse:1.72121	validation_1-rmse:1.67025
# [8]	validation_0-rmse:1.55220	validation_1-rmse:1.50424
# [9]	validation_0-rmse:1.40062	validation_1-rmse:1.35721
# [10]	validation_0-rmse:1.26434	validation_1-rmse:1.22647
# [11]	validation_0-rmse:1.14037	validation_1-rmse:1.10761
# [12]	validation_0-rmse:1.02948	validation_1-rmse:1.00024
# [13]	validation_0-rmse:0.93099	validation_1-rmse:0.90376
# [14]	validation_0-rmse:0.84255	validation_1-rmse:0.81624
# [15]	validation_0-rmse:0.76248	validation_1-rmse:0.74013
# [16]	validation_0-rmse:0.69079	validation_1-rmse:0.67076
# [17]	validation_0-rmse:0.62710	validation_1-rmse:0.61116
# [18]	validation_0-rmse:0.56996	validation_1-rmse:0.55651
# [19]	validation_0-rmse:0.51985	validation_1-rmse:0.50928
# [20]	validation_0-rmse:0.47347	validation_1-rmse:0.46537
# [21]	validation_0-rmse:0.43245	validation_1-rmse:0.42631
# [22]	validation_0-rmse:0.39689	validation_1-rmse:0.39325
# [23]	validation_0-rmse:0.36449	validation_1-rmse:0.36242
# [24]	validation_0-rmse:0.33584	validation_1-rmse:0.33614
# [25]	validation_0-rmse:0.31097	validation_1-rmse:0.31207
# [26]	validation_0-rmse:0.28844	validation_1-rmse:0.29193
# [27]	validation_0-rmse:0.26849	validation_1-rmse:0.27325
# [28]	validation_0-rmse:0.25142	validation_1-rmse:0.25807
# [29]	validation_0-rmse:0.23629	validation_1-rmse:0.24454
# [30]	validation_0-rmse:0.22340	validation_1-rmse:0.23271
# [31]	validation_0-rmse:0.21211	validation_1-rmse:0.22332
# [32]	validation_0-rmse:0.20242	validation_1-rmse:0.21543
# [33]	validation_0-rmse:0.19415	validation_1-rmse:0.20888
# [34]	validation_0-rmse:0.18716	validation_1-rmse:0.20210
# [35]	validation_0-rmse:0.18127	validation_1-rmse:0.19667
# [36]	validation_0-rmse:0.17598	validation_1-rmse:0.19199
# [37]	validation_0-rmse:0.17139	validation_1-rmse:0.18782
# [38]	validation_0-rmse:0.16743	validation_1-rmse:0.18456
# [39]	validation_0-rmse:0.16404	validation_1-rmse:0.18138
# [40]	validation_0-rmse:0.16135	validation_1-rmse:0.17926
# [41]	validation_0-rmse:0.15907	validation_1-rmse:0.17721
# [42]	validation_0-rmse:0.15722	validation_1-rmse:0.17564
# [43]	validation_0-rmse:0.15514	validation_1-rmse:0.17432
# [44]	validation_0-rmse:0.15348	validation_1-rmse:0.17206
# [45]	validation_0-rmse:0.15197	validation_1-rmse:0.17035
# [46]	validation_0-rmse:0.15063	validation_1-rmse:0.16908
# [47]	validation_0-rmse:0.14961	validation_1-rmse:0.16830
# [48]	validation_0-rmse:0.14848	validation_1-rmse:0.16731
# [49]	validation_0-rmse:0.14762	validation_1-rmse:0.16646
# [50]	validation_0-rmse:0.14678	validation_1-rmse:0.16599
# [51]	validation_0-rmse:0.14608	validation_1-rmse:0.16529
# [52]	validation_0-rmse:0.14530	validation_1-rmse:0.16388
# [53]	validation_0-rmse:0.14452	validation_1-rmse:0.16326
# [54]	validation_0-rmse:0.14392	validation_1-rmse:0.16253
# [55]	validation_0-rmse:0.14337	validation_1-rmse:0.16149
# [56]	validation_0-rmse:0.14276	validation_1-rmse:0.16126
# [57]	validation_0-rmse:0.14216	validation_1-rmse:0.16056
# [58]	validation_0-rmse:0.14139	validation_1-rmse:0.15973
# [59]	validation_0-rmse:0.14060	validation_1-rmse:0.15934
# [60]	validation_0-rmse:0.14031	validation_1-rmse:0.15907
# [61]	validation_0-rmse:0.14013	validation_1-rmse:0.15914
# [62]	validation_0-rmse:0.13957	validation_1-rmse:0.15899
# [63]	validation_0-rmse:0.13906	validation_1-rmse:0.15831
# [64]	validation_0-rmse:0.13875	validation_1-rmse:0.15821
# [65]	validation_0-rmse:0.13817	validation_1-rmse:0.15759
# [66]	validation_0-rmse:0.13774	validation_1-rmse:0.15790
# [67]	validation_0-rmse:0.13739	validation_1-rmse:0.15744
# [68]	validation_0-rmse:0.13699	validation_1-rmse:0.15697
# [69]	validation_0-rmse:0.13667	validation_1-rmse:0.15620
# [70]	validation_0-rmse:0.13593	validation_1-rmse:0.15556
# [71]	validation_0-rmse:0.13571	validation_1-rmse:0.15569
# [72]	validation_0-rmse:0.13531	validation_1-rmse:0.15567
# [73]	validation_0-rmse:0.13512	validation_1-rmse:0.15549
# [74]	validation_0-rmse:0.13463	validation_1-rmse:0.15501
# [75]	validation_0-rmse:0.13407	validation_1-rmse:0.15456
# [76]	validation_0-rmse:0.13362	validation_1-rmse:0.15445
# [77]	validation_0-rmse:0.13346	validation_1-rmse:0.15433
# [78]	validation_0-rmse:0.13290	validation_1-rmse:0.15348
# [79]	validation_0-rmse:0.13261	validation_1-rmse:0.15352
# [80]	validation_0-rmse:0.13240	validation_1-rmse:0.15341
# [81]	validation_0-rmse:0.13200	validation_1-rmse:0.15272
# [82]	validation_0-rmse:0.13168	validation_1-rmse:0.15247
# [83]	validation_0-rmse:0.13145	validation_1-rmse:0.15226
# [84]	validation_0-rmse:0.13131	validation_1-rmse:0.15250
# [85]	validation_0-rmse:0.13086	validation_1-rmse:0.15294
# [86]	validation_0-rmse:0.13064	validation_1-rmse:0.15289
# [87]	validation_0-rmse:0.13024	validation_1-rmse:0.15169
# [88]	validation_0-rmse:0.12993	validation_1-rmse:0.15175
# [89]	validation_0-rmse:0.12966	validation_1-rmse:0.15187
# [90]	validation_0-rmse:0.12953	validation_1-rmse:0.15170
# [91]	validation_0-rmse:0.12952	validation_1-rmse:0.15170
# [92]	validation_0-rmse:0.12912	validation_1-rmse:0.15175
# [93]	validation_0-rmse:0.12880	validation_1-rmse:0.15112
# [94]	validation_0-rmse:0.12838	validation_1-rmse:0.15061
# [95]	validation_0-rmse:0.12816	validation_1-rmse:0.15050
# [96]	validation_0-rmse:0.12772	validation_1-rmse:0.15036
# [97]	validation_0-rmse:0.12746	validation_1-rmse:0.14977
# [98]	validation_0-rmse:0.12719	validation_1-rmse:0.14959
# [99]	validation_0-rmse:0.12694	validation_1-rmse:0.14972
# [100]	validation_0-rmse:0.12667	validation_1-rmse:0.15000
# [101]	validation_0-rmse:0.12643	validation_1-rmse:0.15032
# [102]	validation_0-rmse:0.12604	validation_1-rmse:0.15039
# [103]	validation_0-rmse:0.12599	validation_1-rmse:0.15029
# [104]	validation_0-rmse:0.12597	validation_1-rmse:0.15027
# [105]	validation_0-rmse:0.12576	validation_1-rmse:0.15005
# [106]	validation_0-rmse:0.12575	validation_1-rmse:0.15006
# [107]	validation_0-rmse:0.12544	validation_1-rmse:0.15049
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %% [markdown]
# # Create plot with predicted values for test samples (after 200 iteration)

# %%
pd_aggr_y = pd.concat(aggr_y, join="inner")
pd_aggr_y['Obs'] = pd_aggr_y.index

pd_aggr_y_pred = pd.concat(aggr_y_pred, join="inner")

results_y = pd.concat([pd_aggr_y.reset_index(), pd_aggr_y_pred.reset_index()], axis=1)

n_all_y = len(results_y['Obs'])

stat_y = results_y.groupby(['Obs'])[predictor, 0].describe(percentiles=[.16, .5, .84])

l_sd_y_pred = stat_y[0]['50%'] - stat_y[0]['16%']
t_sd_y_pred = stat_y[0]['16%'] - stat_y[0]['50%']

n_stat_y = len(stat_y[0]['50%'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
"""
Assessment of linear approximation between observations and 
predict values and estimation of parameters uncertainties for this regression
"""
# Load libraries elements
from scipy.optimize import curve_fit   
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc
except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

# %%
# Convert input data
x_test_conv = np.array(results_y[predictor])
x_test_convert = np.array([None]*n_all_y)
for i in range(n_all_y):
    x_test_convert[i] = np.float64(x_test_conv[i])

x_plot = x_test_convert
y_plot = results_y[0]
n = n_all_y

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
index_a0 = str(a0).find('+/-')
index_a1 = str(a1).find('+/-')
am_a0 = str(a0)[0:index_a0]
ci_a0 = str(a0)[index_a0+3:]
am_a1 = str(a1)[0:index_a1]
ci_a1 = str(a1)[index_a1+3:]

print('Uncertainty')
print(f'a0: {am_a0}+/-{round(float(ci_a0)*(n_all_y/n_stat_y)**0.5, 3)}')
print(f'a1: {am_a1}+/-{round(float(ci_a1)*(n_all_y/n_stat_y)**0.5, 3)}')

# plot data
plt.figure(figsize =(8, 5))
plt.errorbar(stat_y[predictor]['mean'], stat_y[0]['50%'], yerr=[list(l_sd_y_pred), list(t_sd_y_pred)], c = 'red', fmt='o', lw=1, ms=2, label='Observations')
plt.yscale('linear')

# calculate regression confidence interval
px = np.linspace(0.6, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std * (n_all_y**0.5)/(n_stat_y**0.5), c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.963
# Uncertainty
# a0: 0.178+/-0.032
# a1: 0.9584+/-0.006

# %% [markdown]
# # Uncertainty parameters and confidence intervals

# %%
# Intermedia ratio for calculation CI
CIR = 2/((n_test + n_train)/n_test)**0.5

# %%
# Statistic for SHAP-values

number_iteration = len(aggr_Shap_values.groupby(['Feature']))
shap_list = aggr_Shap_values.groupby(['Feature'])


for i in range(number_iteration):
    itr_mean = round(np.mean(list(shap_list)[i][1].iloc[0:, 1]), 3)
    itr_Q50 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.50), 3)
    itr_Q16 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.16), 3)
    itr_Q84 = round(np.quantile(list(shap_list)[i][1].iloc[0:, 1], 0.84), 3)
    itr_l = (itr_Q50 - itr_Q16)*CIR
    l_CI = itr_Q50 - itr_l
    itr_t = (itr_Q84 - itr_Q50)*CIR
    t_CI = itr_Q50 + itr_t    
    print(f"SHAP-values for: {list(shap_list)[i][0]}: mean - {itr_mean}, median - {itr_Q50}, CI - [{round(l_CI, 3)}-{round(t_CI, 3)}]\n")
# Out:
# SHAP-values for: BA_sq_m_ha: mean - 0.308, median - 0.307, CI - [0.297-0.319]
#
# SHAP-values for: DBH_cm: mean - 0.063, median - 0.061, CI - [0.045-0.082]
#
# SHAP-values for: H_m: mean - 0.359, median - 0.36, CI - [0.341-0.378]
#
# SHAP-values for: Origin_ID: mean - 0.003, median - 0.003, CI - [0.002-0.005]
#
# SHAP-values for: Species_ID: mean - 0.08, median - 0.08, CI - [0.076-0.084]

# %%
sns.set(font_scale=1.2)
sns.violinplot(x="Importance", y="Feature", data=aggr_Shap_values, inner="box", palette="Spectral", order=['H_m', 'BA_sq_m_ha', 'Species_ID', 'DBH_cm', 'Origin_ID'])
sns.set(rc={'figure.figsize':(8,4)})
plt.show()

# %%
# Aggregate stat
# optimal number of iterations
aggr_optimal_n_mean = np.mean(aggr_optimal_n)
aggr_optimal_n_Q025 = np.quantile(aggr_optimal_n, 0.025)
aggr_optimal_n_Q16 = np.quantile(aggr_optimal_n, 0.16)
aggr_optimal_n_Q50 = np.quantile(aggr_optimal_n, 0.50)
aggr_optimal_n_Q84 = np.quantile(aggr_optimal_n, 0.84)
aggr_optimal_n_Q975 = np.quantile(aggr_optimal_n, 0.975)

# bias
aggr_bias_mean = np.mean(aggr_bias)
aggr_bias_Q025 = np.quantile(aggr_bias, 0.025)
aggr_bias_Q16 = np.quantile(aggr_bias, 0.16)
aggr_bias_Q50 = np.quantile(aggr_bias, 0.50)
aggr_bias_Q84 = np.quantile(aggr_bias, 0.84)
aggr_bias_Q975 = np.quantile(aggr_bias, 0.975)

aggr_rel_bias_mean = np.mean(aggr_rel_bias)
aggr_rel_bias_Q025 = np.quantile(aggr_rel_bias, 0.025)
aggr_rel_bias_Q16 = np.quantile(aggr_rel_bias, 0.16)
aggr_rel_bias_Q50 = np.quantile(aggr_rel_bias, 0.50)
aggr_rel_bias_Q84 = np.quantile(aggr_rel_bias, 0.84)
aggr_rel_bias_Q975 = np.quantile(aggr_rel_bias, 0.975)

# RMSE
aggr_rmse_mean = np.mean(aggr_rmse)
aggr_rmse_Q025 = np.quantile(aggr_rmse, 0.025)
aggr_rmse_Q16 = np.quantile(aggr_rmse, 0.16)
aggr_rmse_Q50 = np.quantile(aggr_rmse, 0.50)
aggr_rmse_Q84 = np.quantile(aggr_rmse, 0.84)
aggr_rmse_Q975 = np.quantile(aggr_rmse, 0.975)

aggr_rel_rmse_mean = np.mean(aggr_rel_rmse)
aggr_rel_rmse_Q025 = np.quantile(aggr_rel_rmse, 0.025)
aggr_rel_rmse_Q16 = np.quantile(aggr_rel_rmse, 0.16)
aggr_rel_rmse_Q50 = np.quantile(aggr_rel_rmse, 0.50)
aggr_rel_rmse_Q84 = np.quantile(aggr_rel_rmse, 0.84)
aggr_rel_rmse_Q975 = np.quantile(aggr_rel_rmse, 0.975)

# MSE
aggr_mse_mean = np.mean(aggr_mse)
aggr_mse_Q025 = np.quantile(aggr_mse, 0.025)
aggr_mse_Q16 = np.quantile(aggr_mse, 0.16)
aggr_mse_Q50 = np.quantile(aggr_mse, 0.50)
aggr_mse_Q84 = np.quantile(aggr_mse, 0.84)
aggr_mse_Q975 = np.quantile(aggr_mse, 0.975)

# R-square
aggr_R_square_mean = np.mean(aggr_R_square)
aggr_R_square_Q025 = np.quantile(aggr_R_square, 0.025)
aggr_R_square_Q16 = np.quantile(aggr_R_square, 0.16)
aggr_R_square_Q50 = np.quantile(aggr_R_square, 0.50)
aggr_R_square_Q84 = np.quantile(aggr_R_square, 0.84)
aggr_R_square_Q975 = np.quantile(aggr_R_square, 0.975)

# exp_bias
exp_aggr_bias_mean = np.mean(exp_aggr_bias)
exp_aggr_bias_Q025 = np.quantile(exp_aggr_bias, 0.025)
exp_aggr_bias_Q16 = np.quantile(exp_aggr_bias, 0.16)
exp_aggr_bias_Q50 = np.quantile(exp_aggr_bias, 0.50)
exp_aggr_bias_Q84 = np.quantile(exp_aggr_bias, 0.84)
exp_aggr_bias_Q975 = np.quantile(exp_aggr_bias, 0.975)

exp_aggr_rel_bias_mean = np.mean(exp_aggr_rel_bias)
exp_aggr_rel_bias_Q025 = np.quantile(exp_aggr_rel_bias, 0.025)
exp_aggr_rel_bias_Q16 = np.quantile(exp_aggr_rel_bias, 0.16)
exp_aggr_rel_bias_Q50 = np.quantile(exp_aggr_rel_bias, 0.50)
exp_aggr_rel_bias_Q84 = np.quantile(exp_aggr_rel_bias, 0.84)
exp_aggr_rel_bias_Q975 = np.quantile(exp_aggr_rel_bias, 0.975)

# exp_RMSE
exp_aggr_rmse_mean = np.mean(exp_aggr_rmse)
exp_aggr_rmse_Q025 = np.quantile(exp_aggr_rmse, 0.025)
exp_aggr_rmse_Q16 = np.quantile(exp_aggr_rmse, 0.16)
exp_aggr_rmse_Q50 = np.quantile(exp_aggr_rmse, 0.50)
exp_aggr_rmse_Q84 = np.quantile(exp_aggr_rmse, 0.84)
exp_aggr_rmse_Q975 = np.quantile(exp_aggr_rmse, 0.975)

exp_aggr_rel_rmse_mean = np.mean(exp_aggr_rel_rmse)
exp_aggr_rel_rmse_Q025 = np.quantile(exp_aggr_rel_rmse, 0.025)
exp_aggr_rel_rmse_Q16 = np.quantile(exp_aggr_rel_rmse, 0.16)
exp_aggr_rel_rmse_Q50 = np.quantile(exp_aggr_rel_rmse, 0.50)
exp_aggr_rel_rmse_Q84 = np.quantile(exp_aggr_rel_rmse, 0.84)
exp_aggr_rel_rmse_Q975 = np.quantile(exp_aggr_rel_rmse, 0.975)

# exp_MSE
exp_aggr_mse_mean = np.mean(exp_aggr_mse)
exp_aggr_mse_Q025 = np.quantile(exp_aggr_mse, 0.025)
exp_aggr_mse_Q16 = np.quantile(exp_aggr_mse, 0.16)
exp_aggr_mse_Q50 = np.quantile(exp_aggr_mse, 0.50)
exp_aggr_mse_Q84 = np.quantile(exp_aggr_mse, 0.84)
exp_aggr_mse_Q975 = np.quantile(exp_aggr_mse, 0.975)

# exp_R-square
exp_aggr_R_square_mean = np.mean(exp_aggr_R_square)
exp_aggr_R_square_Q025 = np.quantile(exp_aggr_R_square, 0.025)
exp_aggr_R_square_Q16 = np.quantile(exp_aggr_R_square, 0.16)
exp_aggr_R_square_Q50 = np.quantile(exp_aggr_R_square, 0.50)
exp_aggr_R_square_Q84 = np.quantile(exp_aggr_R_square, 0.84)
exp_aggr_R_square_Q975 = np.quantile(exp_aggr_R_square, 0.975)

# %%
# Output calculated stat
print("Logarithmically transformed predictive values:")
print(f"Aggregate optimal number of iterations statistic: \n mean: {round(aggr_optimal_n_mean, 3)}, median: {round(aggr_optimal_n_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_optimal_n_Q025, 3)}-{round(aggr_optimal_n_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_optimal_n_Q50-((aggr_optimal_n_Q50-aggr_optimal_n_Q16)*CIR), 3)}-{round(aggr_optimal_n_Q50+((aggr_optimal_n_Q84-aggr_optimal_n_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias statistic: \n mean: {round(aggr_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(aggr_bias_Q025, 3)}-{round(aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_bias_Q50-((aggr_bias_Q50-aggr_bias_Q16)*CIR), 3)}-{round(aggr_bias_Q50+((aggr_bias_Q84-aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(aggr_rmse_mean, 3)}, median: {round(aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rmse_Q025, 3)}-{round(aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rmse_Q50-((aggr_rmse_Q50-aggr_rmse_Q16)*CIR), 3)}-{round(aggr_rmse_Q50+((aggr_rmse_Q84-aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(aggr_mse_mean, 3)}, median: {round(aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_mse_Q025, 3)}-{round(aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_mse_Q50-((aggr_mse_Q50-aggr_mse_Q16)*CIR), 3)}-{round(aggr_mse_Q50+((aggr_mse_Q84-aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(aggr_R_square_mean, 3)}, median: {round(aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_R_square_Q025, 3)}-{round(aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_R_square_Q50-((aggr_R_square_Q50-aggr_R_square_Q16)*CIR), 3)}-{round(aggr_R_square_Q50+((aggr_R_square_Q84-aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(aggr_rel_bias_mean, 3)}, median: {round(aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_bias_Q025, 3)}-{round(aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_bias_Q50-((aggr_rel_bias_Q50-aggr_rel_bias_Q16)*CIR), 3)}-{round(aggr_rel_bias_Q50+((aggr_rel_bias_Q84-aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(aggr_rel_rmse_mean, 3)}, median: {round(aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(aggr_rel_rmse_Q025, 3)}-{round(aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(aggr_rel_rmse_Q50-((aggr_rel_rmse_Q50-aggr_rel_rmse_Q16)*CIR), 3)}-{round(aggr_rel_rmse_Q50+((aggr_rel_rmse_Q84-aggr_rel_rmse_Q50)*CIR), 3)} \n***")

print("\nTransformed predictive values into the primary state:")
print(f"Aggregate bias statistic: \n mean: {round(exp_aggr_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)},\n pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_bias_Q025, 3)}-{round(exp_aggr_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_bias_Q50-((exp_aggr_bias_Q50-exp_aggr_bias_Q16)*CIR), 3)}-{round(exp_aggr_bias_Q50+((exp_aggr_bias_Q84-exp_aggr_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE statistic: \n mean: {round(exp_aggr_rmse_mean, 3)}, median: {round(exp_aggr_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rmse_Q025, 3)}-{round(exp_aggr_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rmse_Q50-((exp_aggr_rmse_Q50-exp_aggr_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rmse_Q50+((exp_aggr_rmse_Q84-exp_aggr_rmse_Q50)*CIR), 3)} \n***")
print(f"Aggregate MSE statistic: \n mean: {round(exp_aggr_mse_mean, 3)}, median: {round(exp_aggr_mse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_mse_Q025, 3)}-{round(exp_aggr_mse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_mse_Q50-((exp_aggr_mse_Q50-exp_aggr_mse_Q16)*CIR), 3)}-{round(exp_aggr_mse_Q50+((exp_aggr_mse_Q84-exp_aggr_mse_Q50)*CIR), 3)} \n***")
print(f"Aggregate R^2 statistic: \n mean: {round(exp_aggr_R_square_mean, 3)}, median: {round(exp_aggr_R_square_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_R_square_Q025, 3)}-{round(exp_aggr_R_square_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_R_square_Q50-((exp_aggr_R_square_Q50-exp_aggr_R_square_Q16)*CIR), 3)}-{round(exp_aggr_R_square_Q50+((exp_aggr_R_square_Q84-exp_aggr_R_square_Q50)*CIR), 3)} \n***")
print(f"Aggregate bias(%) statistic: \n mean: {round(exp_aggr_rel_bias_mean, 3)}, median: {round(exp_aggr_bias_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_bias_Q025, 3)}-{round(exp_aggr_rel_bias_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_bias_Q50-((exp_aggr_rel_bias_Q50-exp_aggr_rel_bias_Q16)*CIR), 3)}-{round(exp_aggr_rel_bias_Q50+((exp_aggr_rel_bias_Q84-exp_aggr_rel_bias_Q50)*CIR), 3)} \n***")
print(f"Aggregate RMSE(%) statistic: \n mean: {round(exp_aggr_rel_rmse_mean, 3)}, median: {round(exp_aggr_rel_rmse_Q50, 3)}, pred. interval (P(0.025)-P(0.975)): {round(exp_aggr_rel_rmse_Q025, 3)}-{round(exp_aggr_rel_rmse_Q975, 3)}, \n conf. interval (p-value=0.95): {round(exp_aggr_rel_rmse_Q50-((exp_aggr_rel_rmse_Q50-exp_aggr_rel_rmse_Q16)*CIR), 3)}-{round(exp_aggr_rel_rmse_Q50+((exp_aggr_rel_rmse_Q84-exp_aggr_rel_rmse_Q50)*CIR), 3)} \n***")
# Out:
# Logarithmically transformed predictive values:
# Aggregate optimal number of iterations statistic:
#  mean: 97.815, median: 104.0,
#  pred. interval (P(0.025)-P(0.975)): 60.975-107.0,
#  conf. interval (p-value=0.95): 87.006-106.683
# ***
# Aggregate bias statistic:
#  mean: -0.002, median: -0.002,
#  pred. interval (P(0.025)-P(0.975)): -0.029-0.025,
#  conf. interval (p-value=0.95): -0.016-0.011
# ***
# Aggregate RMSE statistic:
#  mean: 0.167, median: 0.167, pred. interval (P(0.025)-P(0.975)): 0.138-0.198,
#  conf. interval (p-value=0.95): 0.151-0.183
# ***
# Aggregate MSE statistic:
#  mean: 0.028, median: 0.028, pred. interval (P(0.025)-P(0.975)): 0.019-0.039,
#  conf. interval (p-value=0.95): 0.023-0.033
# ***
# Aggregate R^2 statistic:
#  mean: 0.962, median: 0.963, pred. interval (P(0.025)-P(0.975)): 0.946-0.974,
#  conf. interval (p-value=0.95): 0.956-0.969
# ***
# Aggregate bias(%) statistic:
#  mean: -0.045, median: -0.002, pred. interval (P(0.025)-P(0.975)): -0.664-0.574,
#  conf. interval (p-value=0.95): -0.353-0.257
# ***
# Aggregate RMSE(%) statistic:
#  mean: 3.859, median: 3.852, pred. interval (P(0.025)-P(0.975)): 3.193-4.581,
#  conf. interval (p-value=0.95): 3.496-4.247
# ***
#
# Transformed predictive values into the primary state:
# Aggregate bias statistic:
#  mean: -1.514, median: -1.589,
#  pred. interval (P(0.025)-P(0.975)): -4.173-0.986,
#  conf. interval (p-value=0.95): -2.663--0.293
# ***
# Aggregate RMSE statistic:
#  mean: 16.107, median: 15.919, pred. interval (P(0.025)-P(0.975)): 13.326-19.629,
#  conf. interval (p-value=0.95): 14.574-17.704
# ***
# Aggregate MSE statistic:
#  mean: 262.41, median: 253.403, pred. interval (P(0.025)-P(0.975)): 177.596-385.295,
#  conf. interval (p-value=0.95): 212.629-313.794
# ***
# Aggregate R^2 statistic:
#  mean: 0.944, median: 0.945, pred. interval (P(0.025)-P(0.975)): 0.915-0.961,
#  conf. interval (p-value=0.95): 0.934-0.954
# ***
# Aggregate bias(%) statistic:
#  mean: -1.472, median: -1.589, pred. interval (P(0.025)-P(0.975)): -3.857-1.033,
#  conf. interval (p-value=0.95): -2.606--0.286
# ***
# Aggregate RMSE(%) statistic:
#  mean: 15.774, median: 15.528, pred. interval (P(0.025)-P(0.975)): 13.286-19.23,
#  conf. interval (p-value=0.95): 14.322-17.163
# ***

# %% [markdown]
# # ***Creating final XGBoost model using all obs. for its training***

# %%
# Generate test and training samples
f_X_train = X
f_y_train = y

# %%
# Implementation of the scikit-learn API for XGBoost regression
f_xgb_model = xgb.XGBRegressor(objective='reg:squarederror', colsample_bytree=p1, gamma=p2, learning_rate=p3, 
                          max_depth=p4, n_estimators=p5, subsample=p6, eval_metric=["rmse"])

# %%
# Fitting the model 
f_xgb_model.fit(f_X_train, f_y_train, early_stopping_rounds=20, eval_set=[(f_X_train, f_y_train)])
# learning dynamics
f_y_pred = f_xgb_model.predict(f_X_train, ntree_limit=f_xgb_model.best_ntree_limit)
# Out:
# [0]	validation_0-rmse:3.54711
# [1]	validation_0-rmse:3.19420
# [2]	validation_0-rmse:2.87675
# [3]	validation_0-rmse:2.59163
# [4]	validation_0-rmse:2.33379
# [5]	validation_0-rmse:2.10195
# [6]	validation_0-rmse:1.89329
# [7]	validation_0-rmse:1.70655
# [8]	validation_0-rmse:1.53890
# [9]	validation_0-rmse:1.38844
# [10]	validation_0-rmse:1.25264
# [11]	validation_0-rmse:1.13035
# [12]	validation_0-rmse:1.02076
# [13]	validation_0-rmse:0.92279
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# [14]	validation_0-rmse:0.83478
# [15]	validation_0-rmse:0.75536
# [16]	validation_0-rmse:0.68454
# [17]	validation_0-rmse:0.62079
# [18]	validation_0-rmse:0.56389
# [19]	validation_0-rmse:0.51293
# [20]	validation_0-rmse:0.46730
# [21]	validation_0-rmse:0.42601
# [22]	validation_0-rmse:0.38978
# [23]	validation_0-rmse:0.35850
# [24]	validation_0-rmse:0.33007
# [25]	validation_0-rmse:0.30466
# [26]	validation_0-rmse:0.28281
# [27]	validation_0-rmse:0.26339
# [28]	validation_0-rmse:0.24652
# [29]	validation_0-rmse:0.23197
# [30]	validation_0-rmse:0.21890
# [31]	validation_0-rmse:0.20712
# [32]	validation_0-rmse:0.19752
# [33]	validation_0-rmse:0.18926
# [34]	validation_0-rmse:0.18251
# [35]	validation_0-rmse:0.17600
# [36]	validation_0-rmse:0.17055
# [37]	validation_0-rmse:0.16608
# [38]	validation_0-rmse:0.16256
# [39]	validation_0-rmse:0.15896
# [40]	validation_0-rmse:0.15601
# [41]	validation_0-rmse:0.15364
# [42]	validation_0-rmse:0.15138
# [43]	validation_0-rmse:0.14978
# [44]	validation_0-rmse:0.14775
# [45]	validation_0-rmse:0.14650
# [46]	validation_0-rmse:0.14540
# [47]	validation_0-rmse:0.14431
# [48]	validation_0-rmse:0.14324
# [49]	validation_0-rmse:0.14240
# [50]	validation_0-rmse:0.14151
# [51]	validation_0-rmse:0.14078
# [52]	validation_0-rmse:0.14012
# [53]	validation_0-rmse:0.13954
# [54]	validation_0-rmse:0.13891
# [55]	validation_0-rmse:0.13845
# [56]	validation_0-rmse:0.13786
# [57]	validation_0-rmse:0.13750
# [58]	validation_0-rmse:0.13665
# [59]	validation_0-rmse:0.13620
# [60]	validation_0-rmse:0.13535
# [61]	validation_0-rmse:0.13521
# [62]	validation_0-rmse:0.13464
# [63]	validation_0-rmse:0.13421
# [64]	validation_0-rmse:0.13366
# [65]	validation_0-rmse:0.13310
# [66]	validation_0-rmse:0.13271
# [67]	validation_0-rmse:0.13237
# [68]	validation_0-rmse:0.13213
# [69]	validation_0-rmse:0.13175
# [70]	validation_0-rmse:0.13156
# [71]	validation_0-rmse:0.13090
# [72]	validation_0-rmse:0.13067
# [73]	validation_0-rmse:0.13011
# [74]	validation_0-rmse:0.12985
# [75]	validation_0-rmse:0.12950
# [76]	validation_0-rmse:0.12918
# [77]	validation_0-rmse:0.12892
# [78]	validation_0-rmse:0.12863
# [79]	validation_0-rmse:0.12835
# [80]	validation_0-rmse:0.12809
# [81]	validation_0-rmse:0.12794
# [82]	validation_0-rmse:0.12767
# [83]	validation_0-rmse:0.12728
# [84]	validation_0-rmse:0.12704
# [85]	validation_0-rmse:0.12671
# [86]	validation_0-rmse:0.12655
# [87]	validation_0-rmse:0.12655
# [88]	validation_0-rmse:0.12634
# [89]	validation_0-rmse:0.12610
# [90]	validation_0-rmse:0.12589
# [91]	validation_0-rmse:0.12573
# [92]	validation_0-rmse:0.12551
# [93]	validation_0-rmse:0.12508
# [94]	validation_0-rmse:0.12508
# [95]	validation_0-rmse:0.12494
# [96]	validation_0-rmse:0.12475
# [97]	validation_0-rmse:0.12457
# [98]	validation_0-rmse:0.12429
# [99]	validation_0-rmse:0.12407
# [100]	validation_0-rmse:0.12378
# [101]	validation_0-rmse:0.12350
# [102]	validation_0-rmse:0.12338
# [103]	validation_0-rmse:0.12331
# [104]	validation_0-rmse:0.12310
# [105]	validation_0-rmse:0.12275
# [106]	validation_0-rmse:0.12264
# [107]	validation_0-rmse:0.12258
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Iteration with the best result
f_optimal_n = f_xgb_model.best_ntree_limit-1
print("The best iteration: " + str(f_optimal_n))
# Out:
# The best iteration: 107

# %%
# Preparing data for building a learning graph
f_results = f_xgb_model.evals_result()

# %%
# Learning curves for the XGBoost model 
plt.figure(figsize=(10,7))
plt.yscale("log")
plt.plot(f_results['validation_0']['rmse'], label='Train')
plt.axvline(f_optimal_n, color="gray", label="Optimal iteration")
plt.xlabel("Boosting iteration, pcs")
plt.ylabel("Loss functions - RMSE")
plt.legend()

# %% [markdown]
# # Estimation of a final XGBoost model

# %%
# Convert data to 'array' type
f_conv_y_pred = pd.DataFrame(f_y_pred) # Double transformation
f_y_pred2 = f_conv_y_pred.values
f_y_train2 = f_y_train.values

# Intermediate results
f_n_sample = len(f_y_pred2)
f_main_sample = f_y_train.sum() / f_n_sample

# Calculation of bias
f_diff = f_y_pred2 - f_y_train2
f_bias = f_diff.sum()/f_n_sample
print('Bias: %.1f' % (f_bias))
print("Relative bias(%):", " %.2f" % (f_bias/f_main_sample*100))

# Calculation of RMSE
f_rmse = np.sqrt(mean_squared_error(f_y_train, f_y_pred))
print("RMSE: %.1f" % (f_rmse))
print("Relative RMSE(%):", " %.3f" % (f_rmse/f_main_sample*100))

# Calculation of MSE
f_mse = mean_squared_error(f_y_train, f_y_pred)
print("MSE: %.1f" % (f_mse))

# Calculation of Square R
f_R_square = r2_score(f_y_train, f_y_pred)
print("R square: %.1f%%" % (f_R_square * 100.0))
# Out:
# Bias: -0.0
# Relative bias(%):  -0.02
# RMSE: 0.1
# Relative RMSE(%):  2.822
# MSE: 0.0
# R square: 98.0%

# %%
# Convert input data
f_x_train_conv = np.array(f_y_train)
f_x_train_convert = np.array([None]*f_n_sample)
for i in range(f_n_sample):
    f_x_train_convert[i] = float(f_x_train_conv[i])

x_plot = f_x_train_convert
y_plot = f_y_pred
n = len(y_plot)

# Function for fitting a linear curve and estimating its parameters
def f(x_plot, a0, a1):
    return a0 + a1 * x_plot

popt, pcov = curve_fit(f, x_plot, y_plot)

# %%
# Building linear a graph and calculation uncertainties

# retrieve parameter values
a0 = popt[0]
a1 = popt[1]

# compute r^2
r2 = 1.0-(sum((y_plot-f(x_plot, a0, a1)) ** 2)/((n - 1.0)*np.var(y_plot, ddof = 1)))
print(f'R^2: {r2:.3f}')

# calculate parameter confidence interval
a0, a1 = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a0: ' + str(a0))
print('a1: ' + str(a1))

# plot data
plt.figure(figsize =(8, 5))
plt.scatter(x_plot, y_plot, s = 10, c = 'red', label='Observations', marker = 'o')
plt.yscale('linear')

# estimation uncertenlies intervals
def predband(x_plot, xd, yd, p, func, conf=0.95):
    # x_plot = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x_plot - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x_plot, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

# calculate regression confidence interval
px = np.linspace(0.9, max(x_plot), 100)
py = a0 + a1 * px
nom = unp.nominal_values(py)
std = unp.std_devs(py)

lpb, upb = predband(px, x_plot, y_plot, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Predicted values = a0 + a1 * Observed values')

# uncertainty lines (95% confidence)
plt.plot(px, nom - 1.96 * std, c='gray',\
         label='95% Confidence Interval')
plt.plot(px, nom + 1.96 * std, c='gray')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='95% Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('Predicted values')
plt.xlabel('Observed values')
plt.grid(True)
plt.legend(loc='best')
plt.title('Empiric obs. vs Predict values', fontsize=20, color="black")
plt.show()
# Out:
# R^2: 0.980
# Uncertainty
# a0: 0.108+/-0.021
# a1: 0.975+/-0.005

# %% [markdown]
# # ***Analisys output final model***

# %%
# Visualize the Decision tree (individual obs.)
xgb.plot_tree(f_xgb_model, num_trees=0) # "num_trees" is number of obs.
plt.rcParams['figure.figsize'] = [18, 45]
plt.show()

# %%
# Importance is calculated as: ”weight” is the number of times a feature appears in a trees
xgb.plot_importance(f_xgb_model, importance_type='weight')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Importance is calculated as: ”gain” is the average gain of splits which use the feature
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="gain")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key], 1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='gain', show_values=True)

# %%
# Importance is calculated as: "cover” is the average coverage of splits which use the feature where coverage is defined as the number of samples affected by the split
# Get the booster from the xgbmodel
booster = f_xgb_model.get_booster()

# Get the importance dictionary (by gain) from the booster
importance = booster.get_score(importance_type="cover")

# make your changes
for key in importance.keys():
    importance[key] = round(importance[key],1)

# provide the importance dictionary to the plotting function
ax = xgb.plot_importance(importance, importance_type='cover', show_values=True)

# %% [markdown]
# # Est. of SHAP values for final models

# %%
# Сreate an уxplainer object
explainer = shap.TreeExplainer(f_xgb_model)
shap_values = explainer.shap_values(f_X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
# Mean absolute value of the SHAP values for each feature 
shap.summary_plot(shap_values, f_X_train, plot_type="bar")

# %%
# Graph that summarises the effects of all the features
shap.summary_plot(shap_values, f_X_train)

# %%
# Create a dependence scatter plot to show the effect of a single feature across the whole dataset
for name in X_train.columns:
    shap.dependence_plot(name, shap_values, f_X_train, color=shap_values)

# %% [markdown]
# # *Save XGBoost model*

# %%
# Save to JSON
f_xgb_model.save_model("../01_output_data/XGBoost_models/02_LN_M_all_stem_other_authors_XGB_model.json")
# Save to text format
f_xgb_model.save_model("../01_output_data/XGBoost_models/02_LN_M_all_stem_other_authors_XGB_model.txt")
